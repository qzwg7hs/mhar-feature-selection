# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.11.0+cu126
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## Configuration

# %%
FEATURE_DIR = Path("features_noise_0.5_40")

RESULTS_ROOT = Path("results_noise_0.5_40")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

N_POPULATION = 20
MAX_ITERATIONS = 30

TARGET_FEATURE_PERCENTAGE = 0.5

EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   TOTAL: 8039
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, ")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 86.71%, F1: 86.93%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 35.2s
#     Test Acc: 88.46%, F1: 88.40%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 6.4s
#     Test Acc: 84.97%, F1: 85.01%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 197.3s
#     Test Acc: 51.05%, F1: 51.35%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10103649043839642']
# ['At iteration 1 the best fitness is 0.09147339314937081']
# ['At iteration 2 the best fitness is 0.09147339314937081']
# ['At iteration 3 the best fitness is 0.09147339314937081']
# ['At iteration 4 the best fitness is 0.09147339314937081']
# ['At iteration 5 the best fitness is 0.09147339314937081']
# ['At iteration 6 the best fitness is 0.09147339314937081']
# ['At iteration 7 the best fitness is 0.09147339314937081']
# ['At iteration 8 the best fitness is 0.09147339314937081']
# ['At iteration 9 the best fitness is 0.09147339314937081']
# ['At iteration 10 the best fitness is 0.09147339314937081']
# ['At iteration 11 the best fitness is 0.09147339314937081']
# ['At iteration 12 the best fitness is 0.09147339314937081']
# ['At iteration 13 the best fitness is 0.09147339314937081']
# ['At iteration 14 the best fitness is 0.09147339314937081']
# ['At iteration 15 the best fitness is 0.09147339314937081']
# ['At iteration 16 the best fitness is 0.09147339314937081']
# ['At iteration 17 the best fitness is 0.09147339314937081']
# ['At iteration 18 the best fitness is 0.09147339314937081']
# ['At iteration 19 the best fitness is 0.09147339314937081']
# ['At iteration 20 the best fitness is 0.09147339314937081']
# ['At iteration 21 the best fitness is 0.09147339314937081']
# ['At iteration 22 the best fitness is 0.09147339314937081']
# ['At iteration 23 the best fitness is 0.09147339314937081']
# ['At iteration 24 the best fitness is 0.09147339314937081']
# ['At iteration 25 the best fitness is 0.09147339314937081']
# ['At iteration 26 the best fitness is 0.09147339314937081']
# ['At iteration 27 the best fitness is 0.09147339314937081']
# ['At iteration 28 the best fitness is 0.09147339314937081']
# ['At iteration 29 the best fitness is 0.09147339314937081']
#       Selected: 1479/3043 (48.6%), Fitness: 0.0915, Time: 1856.7s
#       Modality: D=48%, S=50%, Sk=48%,
#     Test Acc: 82.87%, F1: 82.92%, Features: 1479/3043 (48.6%), Model: 3.425MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09559769565520473']
# ['At iteration 10 the best fitness is 0.08736552179700387']
# ['At iteration 20 the best fitness is 0.08283044045449561']
#       Selected: 1537/3043 (50.5%), Fitness: 0.0828, Time: 3661.9s
#       Modality: D=50%, S=51%, Sk=51%,
#     Test Acc: 81.82%, F1: 81.36%, Features: 1537/3043 (50.5%), Model: 3.538MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09658356486322313']
# ['At iteration 2 the best fitness is 0.09658356486322313']
# ['At iteration 3 the best fitness is 0.09658356486322313']
# ['At iteration 4 the best fitness is 0.09658356486322313']
# ['At iteration 5 the best fitness is 0.09658356486322313']
# ['At iteration 6 the best fitness is 0.09658356486322313']
# ['At iteration 7 the best fitness is 0.09658356486322313']
# ['At iteration 8 the best fitness is 0.09216350159498368']
# ['At iteration 9 the best fitness is 0.09216350159498368']
# ['At iteration 10 the best fitness is 0.09147339314937081']
# ['At iteration 11 the best fitness is 0.09147339314937081']
# ['At iteration 12 the best fitness is 0.09147339314937081']
# ['At iteration 13 the best fitness is 0.09147339314937081']
# ['At iteration 14 the best fitness is 0.09147339314937081']
# ['At iteration 15 the best fitness is 0.09147339314937081']
# ['At iteration 16 the best fitness is 0.09147339314937081']
# ['At iteration 17 the best fitness is 0.09147339314937081']
# ['At iteration 18 the best fitness is 0.09147339314937081']
# ['At iteration 19 the best fitness is 0.09147339314937081']
# ['At iteration 20 the best fitness is 0.09147339314937081']
# ['At iteration 21 the best fitness is 0.09147339314937081']
# ['At iteration 22 the best fitness is 0.09147339314937081']
# ['At iteration 23 the best fitness is 0.09147339314937081']
# ['At iteration 24 the best fitness is 0.09093116508496069']
# ['At iteration 25 the best fitness is 0.09093116508496069']
# ['At iteration 26 the best fitness is 0.09093116508496069']
# ['At iteration 27 the best fitness is 0.08748053987127268']
# ['At iteration 28 the best fitness is 0.08748053987127268']
# ['At iteration 29 the best fitness is 0.08748053987127268']
# ['At iteration 30 the best fitness is 0.08748053987127268']
#       Selected: 1528/3043 (50.2%), Fitness: 0.0875, Time: 1861.0s
#       Modality: D=53%, S=51%, Sk=49%,
#     Test Acc: 82.52%, F1: 82.69%, Features: 1528/3043 (50.2%), Model: 3.521MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11104322887103041']
# ['At iteration 1 the best fitness is 0.11145400770770475']
# ['At iteration 2 the best fitness is 0.10185804811174509']
# ['At iteration 3 the best fitness is 0.11086248618289371']
# ['At iteration 4 the best fitness is 0.12525642557683309']
# ['At iteration 5 the best fitness is 0.11158545693544053']
# ['At iteration 6 the best fitness is 0.10185804811174509']
# ['At iteration 7 the best fitness is 0.11147043886117172']
# ['At iteration 8 the best fitness is 0.10665602790972492']
# ['At iteration 9 the best fitness is 0.10668889021665887']
# ['At iteration 10 the best fitness is 0.11638343673342025']
# ['At iteration 11 the best fitness is 0.11158545693544053']
# ['At iteration 12 the best fitness is 0.09236067543658737']
# ['At iteration 13 the best fitness is 0.11145400770770475']
# ['At iteration 14 the best fitness is 0.10673818367705978']
# ['At iteration 15 the best fitness is 0.1114868700146387']
# ['At iteration 16 the best fitness is 0.1019730661860139']
# ['At iteration 17 the best fitness is 0.11153616347503961']
# ['At iteration 18 the best fitness is 0.10194020387907995']
# ['At iteration 19 the best fitness is 0.10194020387907995']
# ['At iteration 20 the best fitness is 0.10675461483052676']
# ['At iteration 21 the best fitness is 0.11155259462850659']
# ['At iteration 22 the best fitness is 0.11151973232157264']
# ['At iteration 23 the best fitness is 0.11155259462850659']
# ['At iteration 24 the best fitness is 0.10195663503254693']
# ['At iteration 25 the best fitness is 0.10677104598399373']
# ['At iteration 26 the best fitness is 0.1019730661860139']
# ['At iteration 27 the best fitness is 0.1019730661860139']
# ['At iteration 28 the best fitness is 0.09237710659005434']
# ['At iteration 29 the best fitness is 0.11156902578197356']
#       Selected: 1534/3043 (50.4%), Fitness: 0.1116, Time: 1821.4s
#       Modality: D=49%, S=52%, Sk=50%,
#     Test Acc: 87.76%, F1: 88.12%, Features: 1534/3043 (50.4%), Model: 3.532MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.11539756752540185
# At iteration 2 the best fitness is 0.1114868700146387
# At iteration 3 the best fitness is 0.1057358833155744
# At iteration 4 the best fitness is 0.11158545693544053
# At iteration 5 the best fitness is 0.08310977006343416
# At iteration 6 the best fitness is 0.10177589234441023
# At iteration 7 the best fitness is 0.09190060313951212
# At iteration 8 the best fitness is 0.09280431658019565
# At iteration 9 the best fitness is 0.08726693487620202
# At iteration 10 the best fitness is 0.0963535287146855
# At iteration 11 the best fitness is 0.08792418101488096
# At iteration 12 the best fitness is 0.10606450638491388
# At iteration 13 the best fitness is 0.09666572063055799
# At iteration 14 the best fitness is 0.0880227679356828
# At iteration 15 the best fitness is 0.07254437241292318
# At iteration 16 the best fitness is 0.08749697102473966
# At iteration 17 the best fitness is 0.09173629160484238
# At iteration 18 the best fitness is 0.08700403642073046
# At iteration 19 the best fitness is 0.08700403642073046
# At iteration 20 the best fitness is 0.07302087586346541
# At iteration 21 the best fitness is 0.09180201621871027
# At iteration 22 the best fitness is 0.0917855850652433
# At iteration 23 the best fitness is 0.09175272275830935
# At iteration 24 the best fitness is 0.09658356486322313
# At iteration 25 the best fitness is 0.09651784024935524
# At iteration 26 the best fitness is 0.07732592105743603
# At iteration 27 the best fitness is 0.09620564833348275
# At iteration 28 the best fitness is 0.09163770468404053
# At iteration 29 the best fitness is 0.08182814009301023
# At iteration 30 the best fitness is 0.08688901834646164
#       Selected: 1492/3043 (49.0%), Fitness: 0.0869, Time: 1799.6s
#       Modality: D=50%, S=49%, Sk=49%,
#     Test Acc: 85.31%, F1: 85.26%, Features: 1492/3043 (49.0%), Model: 3.450MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11682707787702853']
# ['At iteration 1 the best fitness is 0.11682707787702853']
# ['At iteration 2 the best fitness is 0.10465142718675416']
# ['At iteration 3 the best fitness is 0.10465142718675416']
# ['At iteration 4 the best fitness is 0.089501654733334']
# ['At iteration 5 the best fitness is 0.089501654733334']
# ['At iteration 6 the best fitness is 0.089501654733334']
# ['At iteration 7 the best fitness is 0.089501654733334']
# ['At iteration 8 the best fitness is 0.089501654733334']
# ['At iteration 9 the best fitness is 0.089501654733334']
# ['At iteration 10 the best fitness is 0.089501654733334']
# ['At iteration 11 the best fitness is 0.08738203593609443']
# ['At iteration 12 the best fitness is 0.08738203593609443']
# ['At iteration 13 the best fitness is 0.08273193651931737']
# ['At iteration 14 the best fitness is 0.08273193651931737']
# ['At iteration 15 the best fitness is 0.08273193651931737']
# ['At iteration 16 the best fitness is 0.07757247134506413']
# ['At iteration 17 the best fitness is 0.07757247134506413']
# ['At iteration 18 the best fitness is 0.07757247134506413']
# ['At iteration 19 the best fitness is 0.07757247134506413']
# ['At iteration 20 the best fitness is 0.07757247134506413']
# ['At iteration 21 the best fitness is 0.07757247134506413']
# ['At iteration 22 the best fitness is 0.07757247134506413']
# ['At iteration 23 the best fitness is 0.07757247134506413']
# ['At iteration 24 the best fitness is 0.07757247134506413']
# ['At iteration 25 the best fitness is 0.07757247134506413']
# ['At iteration 26 the best fitness is 0.07757247134506413']
# ['At iteration 27 the best fitness is 0.07757247134506413']
# ['At iteration 28 the best fitness is 0.07757247134506413']
# ['At iteration 29 the best fitness is 0.07757247134506413']
#       Selected: 1217/3043 (40.0%), Fitness: 0.0776, Time: 1767.2s
#       Modality: D=42%, S=39%, Sk=40%,
#     Test Acc: 84.97%, F1: 84.80%, Features: 1217/3043 (40.0%), Model: 2.913MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.10714896251373413']
# ['At iteration 1 the best fitness is 0.10714896251373413']
# ['At iteration 2 the best fitness is 0.10714896251373413']
# ['At iteration 3 the best fitness is 0.10714896251373413']
# ['At iteration 4 the best fitness is 0.10714896251373413']
# ['At iteration 5 the best fitness is 0.10162792897758396']
# ['At iteration 6 the best fitness is 0.09804593752178375']
# ['At iteration 7 the best fitness is 0.09804593752178375']
# ['At iteration 8 the best fitness is 0.09804593752178375']
# ['At iteration 9 the best fitness is 0.09804593752178375']
# ['At iteration 10 the best fitness is 0.09758586522470851']
# ['At iteration 11 the best fitness is 0.09758586522470851']
# ['At iteration 12 the best fitness is 0.09758586522470851']
# ['At iteration 13 the best fitness is 0.09758586522470851']
# ['At iteration 14 the best fitness is 0.09758586522470851']
# ['At iteration 15 the best fitness is 0.09758586522470851']
# ['At iteration 16 the best fitness is 0.07887069844020222']
# ['At iteration 17 the best fitness is 0.07014567296361576']
# ['At iteration 18 the best fitness is 0.07014567296361576']
# ['At iteration 19 the best fitness is 0.07014567296361576']
# ['At iteration 20 the best fitness is 0.07014567296361576']
# ['At iteration 21 the best fitness is 0.07014567296361576']
# ['At iteration 22 the best fitness is 0.07014567296361576']
# ['At iteration 23 the best fitness is 0.07014567296361576']
# ['At iteration 24 the best fitness is 0.07014567296361576']
# ['At iteration 25 the best fitness is 0.07014567296361576']
# ['At iteration 26 the best fitness is 0.07014567296361576']
# ['At iteration 27 the best fitness is 0.07014567296361576']
# ['At iteration 28 the best fitness is 0.07014567296361576']
# ['At iteration 29 the best fitness is 0.07014567296361576']
#       Selected: 473/3043 (15.5%), Fitness: 0.0701, Time: 2267.3s
#       Modality: D=15%, S=15%, Sk=16%,
#     Test Acc: 85.31%, F1: 85.34%, Features: 473/3043 (15.5%), Model: 1.460MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11105966002449738']
# ['At iteration 1 the best fitness is 0.11105966002449738']
# ['At iteration 2 the best fitness is 0.11089534848982766']
# ['At iteration 3 the best fitness is 0.11089534848982766']
# ['At iteration 4 the best fitness is 0.11061601888088911']
# ['At iteration 5 the best fitness is 0.11061601888088911']
# ['At iteration 6 the best fitness is 0.1104352761927524']
# ['At iteration 7 the best fitness is 0.1104352761927524']
# ['At iteration 8 the best fitness is 0.1104352761927524']
# ['At iteration 9 the best fitness is 0.10583447023637625']
# ['At iteration 10 the best fitness is 0.10583447023637625']
# ['At iteration 11 the best fitness is 0.10583447023637625']
# ['At iteration 12 the best fitness is 0.10167730542360838']
# ['At iteration 13 the best fitness is 0.10167730542360838']
# ['At iteration 14 the best fitness is 0.10167730542360838']
# ['At iteration 15 the best fitness is 0.10167730542360838']
# ['At iteration 16 the best fitness is 0.10167730542360838']
# ['At iteration 17 the best fitness is 0.10167730542360838']
# ['At iteration 18 the best fitness is 0.10161158080974049']
# ['At iteration 19 the best fitness is 0.10161158080974049']
# ['At iteration 20 the best fitness is 0.10161158080974049']
# ['At iteration 21 the best fitness is 0.10161158080974049']
# ['At iteration 22 the best fitness is 0.10161158080974049']
# ['At iteration 23 the best fitness is 0.09666572063055799']
# ['At iteration 24 the best fitness is 0.09666572063055799']
# ['At iteration 25 the best fitness is 0.09666572063055799']
# ['At iteration 26 the best fitness is 0.09666572063055799']
# ['At iteration 27 the best fitness is 0.09666572063055799']
# ['At iteration 28 the best fitness is 0.09666572063055799']
# ['At iteration 29 the best fitness is 0.09666572063055799']
#       Selected: 1503/3043 (49.4%), Fitness: 0.0967, Time: 1868.1s
#       Modality: D=47%, S=50%, Sk=50%,
#     Test Acc: 81.47%, F1: 81.49%, Features: 1503/3043 (49.4%), Model: 3.472MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1015458561958726']
# ['At iteration 2 the best fitness is 0.1015458561958726']
# ['At iteration 3 the best fitness is 0.1015458561958726']
# ['At iteration 4 the best fitness is 0.1015458561958726']
# ['At iteration 5 the best fitness is 0.1015458561958726']
# ['At iteration 6 the best fitness is 0.1015458561958726']
# ['At iteration 7 the best fitness is 0.1015458561958726']
# ['At iteration 8 the best fitness is 0.1015458561958726']
# ['At iteration 9 the best fitness is 0.1015458561958726']
# ['At iteration 10 the best fitness is 0.1015458561958726']
# ['At iteration 11 the best fitness is 0.1015458561958726']
# ['At iteration 12 the best fitness is 0.1015458561958726']
# ['At iteration 13 the best fitness is 0.1015458561958726']
# ['At iteration 14 the best fitness is 0.1015458561958726']
# ['At iteration 15 the best fitness is 0.09737226022963785']
# ['At iteration 16 the best fitness is 0.09737226022963785']
# ['At iteration 17 the best fitness is 0.09737226022963785']
# ['At iteration 18 the best fitness is 0.09737226022963785']
# ['At iteration 19 the best fitness is 0.09737226022963785']
# ['At iteration 20 the best fitness is 0.09737226022963785']
# ['At iteration 21 the best fitness is 0.09737226022963785']
# ['At iteration 22 the best fitness is 0.09264000504552591']
# ['At iteration 23 the best fitness is 0.09264000504552591']
# ['At iteration 24 the best fitness is 0.09264000504552591']
# ['At iteration 25 the best fitness is 0.09264000504552591']
# ['At iteration 26 the best fitness is 0.09264000504552591']
# ['At iteration 27 the best fitness is 0.09264000504552591']
# ['At iteration 28 the best fitness is 0.09264000504552591']
# ['At iteration 29 the best fitness is 0.09250855581779013']
#       Selected: 1542/3043 (50.7%), Fitness: 0.0925, Time: 1748.4s
#       Modality: D=49%, S=51%, Sk=51%,
#     Test Acc: 83.92%, F1: 83.78%, Features: 1542/3043 (50.7%), Model: 3.548MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10236741386922127']
# ['At iteration 2 the best fitness is 0.10143083812160378']
# ['At iteration 3 the best fitness is 0.10143083812160378']
# ['At iteration 4 the best fitness is 0.09173629160484238']
# ['At iteration 5 the best fitness is 0.09173629160484238']
# ['At iteration 6 the best fitness is 0.09173629160484238']
# ['At iteration 7 the best fitness is 0.09173629160484238']
# ['At iteration 8 the best fitness is 0.09173629160484238']
# ['At iteration 9 the best fitness is 0.09173629160484238']
# ['At iteration 10 the best fitness is 0.09173629160484238']
# ['At iteration 11 the best fitness is 0.08656039527712217']
# ['At iteration 12 the best fitness is 0.08656039527712217']
# ['At iteration 13 the best fitness is 0.08656039527712217']
# ['At iteration 14 the best fitness is 0.08656039527712217']
# ['At iteration 15 the best fitness is 0.08656039527712217']
# ['At iteration 16 the best fitness is 0.08656039527712217']
# ['At iteration 17 the best fitness is 0.08656039527712217']
# ['At iteration 18 the best fitness is 0.08656039527712217']
# ['At iteration 19 the best fitness is 0.08656039527712217']
# ['At iteration 20 the best fitness is 0.08656039527712217']
# ['At iteration 21 the best fitness is 0.08656039527712217']
# ['At iteration 22 the best fitness is 0.07703016029503051']
# ['At iteration 23 the best fitness is 0.07703016029503051']
# ['At iteration 24 the best fitness is 0.07703016029503051']
# ['At iteration 25 the best fitness is 0.07703016029503051']
# ['At iteration 26 the best fitness is 0.07703016029503051']
# ['At iteration 27 the best fitness is 0.07703016029503051']
# ['At iteration 28 the best fitness is 0.07703016029503051']
# ['At iteration 29 the best fitness is 0.07703016029503051']
# ['At iteration 30 the best fitness is 0.07703016029503051']
#       Selected: 1476/3043 (48.5%), Fitness: 0.0770, Time: 1959.6s
#       Modality: D=45%, S=47%, Sk=50%,
#     Test Acc: 82.87%, F1: 82.95%, Features: 1476/3043 (48.5%), Model: 3.419MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10604807523144691']
# ['At iteration 2 the best fitness is 0.10604807523144691']
# ['At iteration 3 the best fitness is 0.10106935274533037']
# ['At iteration 4 the best fitness is 0.10077359198292485']
# ['At iteration 5 the best fitness is 0.10077359198292485']
# ['At iteration 6 the best fitness is 0.10077359198292485']
# ['At iteration 7 the best fitness is 0.09170342929790844']
# ['At iteration 8 the best fitness is 0.09170342929790844']
# ['At iteration 9 the best fitness is 0.09170342929790844']
# ['At iteration 10 the best fitness is 0.09170342929790844']
# ['At iteration 11 the best fitness is 0.09170342929790844']
# ['At iteration 12 the best fitness is 0.09170342929790844']
# ['At iteration 13 the best fitness is 0.09170342929790844']
# ['At iteration 14 the best fitness is 0.09170342929790844']
# ['At iteration 15 the best fitness is 0.09170342929790844']
# ['At iteration 16 the best fitness is 0.09170342929790844']
# ['At iteration 17 the best fitness is 0.09170342929790844']
# ['At iteration 18 the best fitness is 0.09170342929790844']
# ['At iteration 19 the best fitness is 0.09170342929790844']
# ['At iteration 20 the best fitness is 0.09170342929790844']
# ['At iteration 21 the best fitness is 0.09170342929790844']
# ['At iteration 22 the best fitness is 0.09167056699097449']
# ['At iteration 23 the best fitness is 0.09167056699097449']
# ['At iteration 24 the best fitness is 0.09167056699097449']
# ['At iteration 25 the best fitness is 0.09167056699097449']
# ['At iteration 26 the best fitness is 0.09167056699097449']
# ['At iteration 27 the best fitness is 0.08670827565832492']
# ['At iteration 28 the best fitness is 0.08670827565832492']
# ['At iteration 29 the best fitness is 0.08670827565832492']
# ['At iteration 30 the best fitness is 0.08670827565832492']
#       Selected: 1481/3043 (48.7%), Fitness: 0.0867, Time: 1970.4s
#       Modality: D=45%, S=49%, Sk=49%,
#     Test Acc: 86.36%, F1: 86.32%, Features: 1481/3043 (48.7%), Model: 3.429MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10233455156228732']
# ['At iteration 1 the best fitness is 0.10233455156228732']
# ['At iteration 2 the best fitness is 0.10233455156228732']
# ['At iteration 3 the best fitness is 0.10233455156228732']
# ['At iteration 4 the best fitness is 0.10233455156228732']
# ['At iteration 5 the best fitness is 0.10233455156228732']
# ['At iteration 6 the best fitness is 0.10233455156228732']
# ['At iteration 7 the best fitness is 0.10233455156228732']
# ['At iteration 8 the best fitness is 0.10233455156228732']
# ['At iteration 9 the best fitness is 0.09776669089846872']
# ['At iteration 10 the best fitness is 0.09776669089846872']
# ['At iteration 11 the best fitness is 0.08526241713885487']
# ['At iteration 12 the best fitness is 0.08526241713885487']
# ['At iteration 13 the best fitness is 0.08526241713885487']
# ['At iteration 14 the best fitness is 0.08526241713885487']
# ['At iteration 15 the best fitness is 0.08526241713885487']
# ['At iteration 16 the best fitness is 0.08526241713885487']
# ['At iteration 17 the best fitness is 0.08526241713885487']
# ['At iteration 18 the best fitness is 0.08526241713885487']
# ['At iteration 19 the best fitness is 0.08526241713885487']
# ['At iteration 20 the best fitness is 0.08526241713885487']
# ['At iteration 21 the best fitness is 0.08526241713885487']
# ['At iteration 22 the best fitness is 0.08526241713885487']
# ['At iteration 23 the best fitness is 0.08526241713885487']
# ['At iteration 24 the best fitness is 0.08526241713885487']
# ['At iteration 25 the best fitness is 0.08526241713885487']
# ['At iteration 26 the best fitness is 0.08526241713885487']
# ['At iteration 27 the best fitness is 0.08526241713885487']
# ['At iteration 28 the best fitness is 0.08526241713885487']
# ['At iteration 29 the best fitness is 0.08526241713885487']
#       Selected: 1101/3043 (36.2%), Fitness: 0.0853, Time: 1929.6s
#       Modality: D=38%, S=37%, Sk=36%,
#     Test Acc: 80.77%, F1: 80.89%, Features: 1101/3043 (36.2%), Model: 2.687MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10131582004733497']
# ['At iteration 2 the best fitness is 0.10131582004733497']
# ['At iteration 3 the best fitness is 0.10131582004733497']
# ['At iteration 4 the best fitness is 0.10131582004733497']
# ['At iteration 5 the best fitness is 0.10131582004733497']
# ['At iteration 6 the best fitness is 0.10131582004733497']
# ['At iteration 7 the best fitness is 0.10131582004733497']
# ['At iteration 8 the best fitness is 0.10131582004733497']
# ['At iteration 9 the best fitness is 0.10131582004733497']
# ['At iteration 10 the best fitness is 0.10131582004733497']
# ['At iteration 11 the best fitness is 0.10131582004733497']
# ['At iteration 12 the best fitness is 0.10131582004733497']
# ['At iteration 13 the best fitness is 0.10131582004733497']
# ['At iteration 14 the best fitness is 0.10131582004733497']
# ['At iteration 15 the best fitness is 0.10131582004733497']
# ['At iteration 16 the best fitness is 0.10131582004733497']
# ['At iteration 17 the best fitness is 0.10131582004733497']
# ['At iteration 18 the best fitness is 0.10131582004733497']
# ['At iteration 19 the best fitness is 0.10131582004733497']
# ['At iteration 20 the best fitness is 0.10131582004733497']
# ['At iteration 21 the best fitness is 0.10131582004733497']
# ['At iteration 22 the best fitness is 0.10131582004733497']
# ['At iteration 23 the best fitness is 0.10131582004733497']
# ['At iteration 24 the best fitness is 0.10131582004733497']
# ['At iteration 25 the best fitness is 0.10131582004733497']
# ['At iteration 26 the best fitness is 0.10131582004733497']
# ['At iteration 27 the best fitness is 0.10131582004733497']
# ['At iteration 28 the best fitness is 0.10131582004733497']
# ['At iteration 29 the best fitness is 0.10131582004733497']
#       Selected: 1494/3043 (49.1%), Fitness: 0.1013, Time: 4929.3s
#       Modality: D=50%, S=47%, Sk=50%,
#     Test Acc: 83.92%, F1: 83.73%, Features: 1494/3043 (49.1%), Model: 3.454MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09599204333841209']
# ['At iteration 1 the best fitness is 0.09599204333841209']
# ['At iteration 2 the best fitness is 0.09599204333841209']
# ['At iteration 3 the best fitness is 0.09599204333841209']
# ['At iteration 4 the best fitness is 0.09599204333841209']
# ['At iteration 5 the best fitness is 0.09599204333841209']
# ['At iteration 6 the best fitness is 0.09599204333841209']
# ['At iteration 7 the best fitness is 0.09599204333841209']
# ['At iteration 8 the best fitness is 0.09599204333841209']
# ['At iteration 9 the best fitness is 0.09599204333841209']
# ['At iteration 10 the best fitness is 0.09599204333841209']
# ['At iteration 11 the best fitness is 0.09599204333841209']
# ['At iteration 12 the best fitness is 0.09599204333841209']
# ['At iteration 13 the best fitness is 0.09599204333841209']
# ['At iteration 14 the best fitness is 0.09599204333841209']
# ['At iteration 15 the best fitness is 0.09599204333841209']
# ['At iteration 16 the best fitness is 0.09599204333841209']
# ['At iteration 17 the best fitness is 0.09599204333841209']
# ['At iteration 18 the best fitness is 0.09599204333841209']
# ['At iteration 19 the best fitness is 0.09599204333841209']
# ['At iteration 20 the best fitness is 0.09599204333841209']
# ['At iteration 21 the best fitness is 0.09599204333841209']
# ['At iteration 22 the best fitness is 0.09599204333841209']
# ['At iteration 23 the best fitness is 0.09599204333841209']
# ['At iteration 24 the best fitness is 0.09599204333841209']
# ['At iteration 25 the best fitness is 0.09599204333841209']
# ['At iteration 26 the best fitness is 0.09599204333841209']
# ['At iteration 27 the best fitness is 0.09599204333841209']
# ['At iteration 28 the best fitness is 0.09599204333841209']
# ['At iteration 29 the best fitness is 0.09599204333841209']
#       Selected: 1462/3043 (48.0%), Fitness: 0.0960, Time: 1837.8s
#       Modality: D=48%, S=47%, Sk=48%,
#     Test Acc: 82.17%, F1: 82.25%, Features: 1462/3043 (48.0%), Model: 3.392MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 85.89%, F1: 85.45%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 52.6s
#     Test Acc: 90.04%, F1: 90.00%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 10.2s
#     Test Acc: 88.80%, F1: 88.36%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 332.0s
#     Test Acc: 51.87%, F1: 51.56%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10162801196320746']
# ['At iteration 1 the best fitness is 0.10162801196320746']
# ['At iteration 2 the best fitness is 0.10162801196320746']
# ['At iteration 3 the best fitness is 0.08269899122675983']
# ['At iteration 4 the best fitness is 0.08269899122675983']
# ['At iteration 5 the best fitness is 0.08269899122675983']
# ['At iteration 6 the best fitness is 0.08269899122675983']
# ['At iteration 7 the best fitness is 0.08269899122675983']
# ['At iteration 8 the best fitness is 0.08269899122675983']
# ['At iteration 9 the best fitness is 0.08269899122675983']
# ['At iteration 10 the best fitness is 0.08269899122675983']
# ['At iteration 11 the best fitness is 0.08269899122675983']
# ['At iteration 12 the best fitness is 0.08269899122675983']
# ['At iteration 13 the best fitness is 0.08269899122675983']
# ['At iteration 14 the best fitness is 0.08269899122675983']
# ['At iteration 15 the best fitness is 0.08269899122675983']
# ['At iteration 16 the best fitness is 0.08269899122675983']
# ['At iteration 17 the best fitness is 0.08269899122675983']
# ['At iteration 18 the best fitness is 0.08269899122675983']
# ['At iteration 19 the best fitness is 0.08269899122675983']
# ['At iteration 20 the best fitness is 0.08269899122675983']
# ['At iteration 21 the best fitness is 0.08269899122675983']
# ['At iteration 22 the best fitness is 0.08269899122675983']
# ['At iteration 23 the best fitness is 0.08269899122675983']
# ['At iteration 24 the best fitness is 0.08269899122675983']
# ['At iteration 25 the best fitness is 0.08269899122675983']
# ['At iteration 26 the best fitness is 0.08269899122675983']
# ['At iteration 27 the best fitness is 0.08269899122675983']
# ['At iteration 28 the best fitness is 0.08269899122675983']
# ['At iteration 29 the best fitness is 0.08269899122675983']
#       Selected: 1529/3043 (50.2%), Fitness: 0.0827, Time: 2116.3s
#       Modality: D=53%, S=50%, Sk=50%,
#     Test Acc: 88.80%, F1: 88.71%, Features: 1529/3043 (50.2%), Model: 3.523MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11050100080662029']
# ['At iteration 10 the best fitness is 0.10570302100864046']
# ['At iteration 20 the best fitness is 0.09199919006031396']
#       Selected: 1511/3043 (49.7%), Fitness: 0.0920, Time: 4146.3s
#       Modality: D=51%, S=46%, Sk=50%,
#     Test Acc: 85.48%, F1: 85.31%, Features: 1511/3043 (49.7%), Model: 3.487MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10706680674639925']
# ['At iteration 2 the best fitness is 0.10706680674639925']
# ['At iteration 3 the best fitness is 0.10706680674639925']
# ['At iteration 4 the best fitness is 0.10706680674639925']
# ['At iteration 5 the best fitness is 0.10706680674639925']
# ['At iteration 6 the best fitness is 0.10706680674639925']
# ['At iteration 7 the best fitness is 0.1056208652413056']
# ['At iteration 8 the best fitness is 0.09204848352071487']
# ['At iteration 9 the best fitness is 0.09204848352071487']
# ['At iteration 10 the best fitness is 0.0872176414158011']
# ['At iteration 11 the best fitness is 0.0872176414158011']
# ['At iteration 12 the best fitness is 0.0872176414158011']
# ['At iteration 13 the best fitness is 0.0872176414158011']
# ['At iteration 14 the best fitness is 0.0872176414158011']
# ['At iteration 15 the best fitness is 0.0872176414158011']
# ['At iteration 16 the best fitness is 0.0872176414158011']
# ['At iteration 17 the best fitness is 0.0872176414158011']
# ['At iteration 18 the best fitness is 0.08700403642073046']
# ['At iteration 19 the best fitness is 0.08700403642073046']
# ['At iteration 20 the best fitness is 0.08700403642073046']
# ['At iteration 21 the best fitness is 0.08700403642073046']
# ['At iteration 22 the best fitness is 0.08700403642073046']
# ['At iteration 23 the best fitness is 0.08700403642073046']
# ['At iteration 24 the best fitness is 0.08700403642073046']
# ['At iteration 25 the best fitness is 0.08700403642073046']
# ['At iteration 26 the best fitness is 0.08700403642073046']
# ['At iteration 27 the best fitness is 0.08700403642073046']
# ['At iteration 28 the best fitness is 0.08700403642073046']
# ['At iteration 29 the best fitness is 0.08682329373259375']
# ['At iteration 30 the best fitness is 0.08682329373259375']
#       Selected: 1488/3043 (48.9%), Fitness: 0.0868, Time: 2087.5s
#       Modality: D=48%, S=51%, Sk=48%,
#     Test Acc: 83.82%, F1: 83.74%, Features: 1488/3043 (48.9%), Model: 3.442MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11628484981261841']
# ['At iteration 1 the best fitness is 0.10189091041867904']
# ['At iteration 2 the best fitness is 0.11531541175806698']
# ['At iteration 3 the best fitness is 0.08728336602966899']
# ['At iteration 4 the best fitness is 0.11081319272249279']
# ['At iteration 5 the best fitness is 0.10581803908290928']
# ['At iteration 6 the best fitness is 0.10608093753838085']
# ['At iteration 7 the best fitness is 0.09145696199590383']
# ['At iteration 8 the best fitness is 0.09618921718001577']
# ['At iteration 9 the best fitness is 0.096041336798813']
# ['At iteration 10 the best fitness is 0.10567015870170651']
# ['At iteration 11 the best fitness is 0.10571945216210743']
# ['At iteration 12 the best fitness is 0.1010529215918634']
# ['At iteration 13 the best fitness is 0.09145696199590383']
# ['At iteration 14 the best fitness is 0.11056672542048818']
# ['At iteration 15 the best fitness is 0.10100362813146248']
# ['At iteration 16 the best fitness is 0.10576874562250835']
# ['At iteration 17 the best fitness is 0.1009871969779955']
# ['At iteration 18 the best fitness is 0.1058016079294423']
# ['At iteration 19 the best fitness is 0.09618921718001577']
# ['At iteration 20 the best fitness is 0.09140766853550292']
# ['At iteration 21 the best fitness is 0.10103649043839642']
# ['At iteration 22 the best fitness is 0.10583447023637625']
# ['At iteration 23 the best fitness is 0.1010529215918634']
# ['At iteration 24 the best fitness is 0.10583447023637625']
# ['At iteration 25 the best fitness is 0.10103649043839642']
# ['At iteration 26 the best fitness is 0.10103649043839642']
# ['At iteration 27 the best fitness is 0.10100362813146248']
# ['At iteration 28 the best fitness is 0.11061601888088911']
# ['At iteration 29 the best fitness is 0.11063245003435608']
#       Selected: 1477/3043 (48.5%), Fitness: 0.1106, Time: 1861.6s
#       Modality: D=45%, S=49%, Sk=49%,
#     Test Acc: 87.55%, F1: 87.38%, Features: 1477/3043 (48.5%), Model: 3.421MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.12090208692246153
# At iteration 2 the best fitness is 0.10650814752852215
# At iteration 3 the best fitness is 0.11127326501956804
# At iteration 4 the best fitness is 0.1163505744264863
# At iteration 5 the best fitness is 0.1019730661860139
# At iteration 6 the best fitness is 0.0924099688969883
# At iteration 7 the best fitness is 0.1116018880889075
# At iteration 8 the best fitness is 0.11620269404528355
# At iteration 9 the best fitness is 0.11107609117796435
# At iteration 10 the best fitness is 0.12547003057190373
# At iteration 11 the best fitness is 0.12565077326004043
# At iteration 12 the best fitness is 0.11620269404528355
# At iteration 13 the best fitness is 0.11132255847996896
# At iteration 14 the best fitness is 0.11096107310369555
# At iteration 15 the best fitness is 0.11161831924237448
# At iteration 16 the best fitness is 0.12072134423432483
# At iteration 17 the best fitness is 0.11174976847011027
# At iteration 18 the best fitness is 0.10668889021665887
# At iteration 19 the best fitness is 0.09735582907617088
# At iteration 20 the best fitness is 0.08274828468716075
# At iteration 21 the best fitness is 0.09249212466432316
# At iteration 22 the best fitness is 0.09683003216522773
# At iteration 23 the best fitness is 0.09710936177416628
# At iteration 24 the best fitness is 0.1017265988840093
# At iteration 25 the best fitness is 0.0920320523672479
# At iteration 26 the best fitness is 0.09681360101176076
# At iteration 27 the best fitness is 0.10673818367705978
# At iteration 28 the best fitness is 0.10672175252359281
# At iteration 29 the best fitness is 0.10675461483052676
# At iteration 30 the best fitness is 0.10609736869184783
#       Selected: 1493/3043 (49.1%), Fitness: 0.1061, Time: 1862.8s
#       Modality: D=45%, S=53%, Sk=49%,
#     Test Acc: 84.65%, F1: 84.28%, Features: 1493/3043 (49.1%), Model: 3.452MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.12027770309071655']
# ['At iteration 1 the best fitness is 0.115923364436345']
# ['At iteration 2 the best fitness is 0.115923364436345']
# ['At iteration 3 the best fitness is 0.115923364436345']
# ['At iteration 4 the best fitness is 0.10782272279150362']
# ['At iteration 5 the best fitness is 0.10782272279150362']
# ['At iteration 6 the best fitness is 0.10772413587070179']
# ['At iteration 7 the best fitness is 0.10695187165775404']
# ['At iteration 8 the best fitness is 0.10695187165775404']
# ['At iteration 9 the best fitness is 0.10695187165775404']
# ['At iteration 10 the best fitness is 0.09692870207165308']
# ['At iteration 11 the best fitness is 0.09692870207165308']
# ['At iteration 12 the best fitness is 0.09692870207165308']
# ['At iteration 13 the best fitness is 0.09692870207165308']
# ['At iteration 14 the best fitness is 0.09692870207165308']
# ['At iteration 15 the best fitness is 0.09692870207165308']
# ['At iteration 16 the best fitness is 0.09602498863096953']
# ['At iteration 17 the best fitness is 0.09602498863096953']
# ['At iteration 18 the best fitness is 0.09602498863096953']
# ['At iteration 19 the best fitness is 0.09602498863096953']
# ['At iteration 20 the best fitness is 0.09167064997659809']
# ['At iteration 21 the best fitness is 0.09167064997659809']
# ['At iteration 22 the best fitness is 0.09167064997659809']
# ['At iteration 23 the best fitness is 0.0916049253627302']
# ['At iteration 24 the best fitness is 0.0916049253627302']
# ['At iteration 25 the best fitness is 0.0916049253627302']
# ['At iteration 26 the best fitness is 0.0916049253627302']
# ['At iteration 27 the best fitness is 0.0916049253627302']
# ['At iteration 28 the best fitness is 0.0916049253627302']
# ['At iteration 29 the best fitness is 0.0916049253627302']
#       Selected: 1195/3043 (39.3%), Fitness: 0.0916, Time: 1849.6s
#       Modality: D=38%, S=39%, Sk=40%,
#     Test Acc: 86.31%, F1: 86.46%, Features: 1195/3043 (39.3%), Model: 2.870MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.11667919749582577']
# ['At iteration 1 the best fitness is 0.11667919749582577']
# ['At iteration 2 the best fitness is 0.11667919749582577']
# ['At iteration 3 the best fitness is 0.11667919749582577']
# ['At iteration 4 the best fitness is 0.11667919749582577']
# ['At iteration 5 the best fitness is 0.11521690782288874']
# ['At iteration 6 the best fitness is 0.0988348818450692']
# ['At iteration 7 the best fitness is 0.0988348818450692']
# ['At iteration 8 the best fitness is 0.09382329705201871']
# ['At iteration 9 the best fitness is 0.08974828800658571']
# ['At iteration 10 the best fitness is 0.08974828800658571']
# ['At iteration 11 the best fitness is 0.08974828800658571']
# ['At iteration 12 the best fitness is 0.08974828800658571']
# ['At iteration 13 the best fitness is 0.08974828800658571']
# ['At iteration 14 the best fitness is 0.08974828800658571']
# ['At iteration 15 the best fitness is 0.08974828800658571']
# ['At iteration 16 the best fitness is 0.08974828800658571']
# ['At iteration 17 the best fitness is 0.08974828800658571']
# ['At iteration 18 the best fitness is 0.08904174840750585']
# ['At iteration 19 the best fitness is 0.08348793555004534']
# ['At iteration 20 the best fitness is 0.08348793555004534']
# ['At iteration 21 the best fitness is 0.08348793555004534']
# ['At iteration 22 the best fitness is 0.08348793555004534']
# ['At iteration 23 the best fitness is 0.08348793555004534']
# ['At iteration 24 the best fitness is 0.08348793555004534']
# ['At iteration 25 the best fitness is 0.08348793555004534']
# ['At iteration 26 the best fitness is 0.08348793555004534']
# ['At iteration 27 the best fitness is 0.08348793555004534']
# ['At iteration 28 the best fitness is 0.08348793555004534']
# ['At iteration 29 the best fitness is 0.08348793555004534']
#       Selected: 701/3043 (23.0%), Fitness: 0.0835, Time: 2543.0s
#       Modality: D=24%, S=24%, Sk=23%,
#     Test Acc: 84.65%, F1: 83.90%, Features: 701/3043 (23.0%), Model: 1.905MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.12060632616005601']
# ['At iteration 1 the best fitness is 0.12060632616005601']
# ['At iteration 2 the best fitness is 0.12008052924911286']
# ['At iteration 3 the best fitness is 0.11633414327301933']
# ['At iteration 4 the best fitness is 0.11135542078690291']
# ['At iteration 5 the best fitness is 0.11135542078690291']
# ['At iteration 6 the best fitness is 0.11135542078690291']
# ['At iteration 7 the best fitness is 0.11135542078690291']
# ['At iteration 8 the best fitness is 0.11135542078690291']
# ['At iteration 9 the best fitness is 0.11135542078690291']
# ['At iteration 10 the best fitness is 0.11135542078690291']
# ['At iteration 11 the best fitness is 0.10187447926521206']
# ['At iteration 12 the best fitness is 0.10187447926521206']
# ['At iteration 13 the best fitness is 0.10187447926521206']
# ['At iteration 14 the best fitness is 0.10187447926521206']
# ['At iteration 15 the best fitness is 0.10187447926521206']
# ['At iteration 16 the best fitness is 0.10187447926521206']
# ['At iteration 17 the best fitness is 0.09747084715043969']
# ['At iteration 18 the best fitness is 0.09747084715043969']
# ['At iteration 19 the best fitness is 0.09747084715043969']
# ['At iteration 20 the best fitness is 0.09747084715043969']
# ['At iteration 21 the best fitness is 0.09747084715043969']
# ['At iteration 22 the best fitness is 0.09747084715043969']
# ['At iteration 23 the best fitness is 0.09747084715043969']
# ['At iteration 24 the best fitness is 0.09747084715043969']
# ['At iteration 25 the best fitness is 0.09747084715043969']
# ['At iteration 26 the best fitness is 0.09747084715043969']
# ['At iteration 27 the best fitness is 0.09747084715043969']
# ['At iteration 28 the best fitness is 0.09747084715043969']
# ['At iteration 29 the best fitness is 0.09747084715043969']
#       Selected: 1552/3043 (51.0%), Fitness: 0.0975, Time: 1962.9s
#       Modality: D=52%, S=49%, Sk=51%,
#     Test Acc: 88.38%, F1: 87.99%, Features: 1552/3043 (51.0%), Model: 3.567MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.11587407097594407']
# ['At iteration 2 the best fitness is 0.11587407097594407']
# ['At iteration 3 the best fitness is 0.1017265988840093']
# ['At iteration 4 the best fitness is 0.1017265988840093']
# ['At iteration 5 the best fitness is 0.09288647234753052']
# ['At iteration 6 the best fitness is 0.09288647234753052']
# ['At iteration 7 the best fitness is 0.09288647234753052']
# ['At iteration 8 the best fitness is 0.0787061379486618']
# ['At iteration 9 the best fitness is 0.0787061379486618']
# ['At iteration 10 the best fitness is 0.0787061379486618']
# ['At iteration 11 the best fitness is 0.0787061379486618']
# ['At iteration 12 the best fitness is 0.0787061379486618']
# ['At iteration 13 the best fitness is 0.0787061379486618']
# ['At iteration 14 the best fitness is 0.0787061379486618']
# ['At iteration 15 the best fitness is 0.0787061379486618']
# ['At iteration 16 the best fitness is 0.0787061379486618']
# ['At iteration 17 the best fitness is 0.0787061379486618']
# ['At iteration 18 the best fitness is 0.0787061379486618']
# ['At iteration 19 the best fitness is 0.0787061379486618']
# ['At iteration 20 the best fitness is 0.0787061379486618']
# ['At iteration 21 the best fitness is 0.0787061379486618']
# ['At iteration 22 the best fitness is 0.0787061379486618']
# ['At iteration 23 the best fitness is 0.0787061379486618']
# ['At iteration 24 the best fitness is 0.0787061379486618']
# ['At iteration 25 the best fitness is 0.0787061379486618']
# ['At iteration 26 the best fitness is 0.0787061379486618']
# ['At iteration 27 the best fitness is 0.0787061379486618']
# ['At iteration 28 the best fitness is 0.0787061379486618']
# ['At iteration 29 the best fitness is 0.0787061379486618']
#       Selected: 1578/3043 (51.9%), Fitness: 0.0787, Time: 1790.8s
#       Modality: D=51%, S=54%, Sk=51%,
#     Test Acc: 84.65%, F1: 84.43%, Features: 1578/3043 (51.9%), Model: 3.618MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.11158545693544053']
# ['At iteration 2 the best fitness is 0.11158545693544053']
# ['At iteration 3 the best fitness is 0.11158545693544053']
# ['At iteration 4 the best fitness is 0.11158545693544053']
# ['At iteration 5 the best fitness is 0.11158545693544053']
# ['At iteration 6 the best fitness is 0.11158545693544053']
# ['At iteration 7 the best fitness is 0.11158545693544053']
# ['At iteration 8 the best fitness is 0.1014144069681368']
# ['At iteration 9 the best fitness is 0.1014144069681368']
# ['At iteration 10 the best fitness is 0.1014144069681368']
# ['At iteration 11 the best fitness is 0.1014144069681368']
# ['At iteration 12 the best fitness is 0.1014144069681368']
# ['At iteration 13 the best fitness is 0.1014144069681368']
# ['At iteration 14 the best fitness is 0.1014144069681368']
# ['At iteration 15 the best fitness is 0.1014144069681368']
# ['At iteration 16 the best fitness is 0.1014144069681368']
# ...
# ['At iteration 13 the best fitness is 0.100195537544163']
# ['At iteration 14 the best fitness is 0.100195537544163']
# ['At iteration 15 the best fitness is 0.100195537544163']
# ['At iteration 16 the best fitness is 0.100195537544163']
# ['At iteration 17 the best fitness is 0.100195537544163']
# ['At iteration 18 the best fitness is 0.100195537544163']
# ['At iteration 19 the best fitness is 0.100195537544163']
# ['At iteration 20 the best fitness is 0.100195537544163']
# ['At iteration 21 the best fitness is 0.100195537544163']
# ['At iteration 22 the best fitness is 0.100195537544163']
# ['At iteration 23 the best fitness is 0.100195537544163']
# ['At iteration 24 the best fitness is 0.100195537544163']
# ['At iteration 25 the best fitness is 0.100195537544163']
# ['At iteration 26 the best fitness is 0.100195537544163']
# ['At iteration 27 the best fitness is 0.100195537544163']
# ['At iteration 28 the best fitness is 0.100195537544163']
# ['At iteration 29 the best fitness is 0.09457921929521947']
#       Selected: 958/3043 (31.5%), Fitness: 0.0946, Time: 2300.6s
#       Modality: D=33%, S=33%, Sk=30%,
#     Test Acc: 83.33%, F1: 82.62%, Features: 958/3043 (31.5%), Model: 2.407MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11987692316083573']
# ['At iteration 1 the best fitness is 0.11485055831832255']
# ['At iteration 2 the best fitness is 0.11110582344623332']
# ['At iteration 3 the best fitness is 0.11110582344623332']
# ['At iteration 4 the best fitness is 0.11100723652543149']
# ['At iteration 5 the best fitness is 0.11100723652543149']
# ['At iteration 6 the best fitness is 0.11100723652543149']
# ['At iteration 7 the best fitness is 0.11100723652543149']
# ['At iteration 8 the best fitness is 0.11100723652543149']
# ['At iteration 9 the best fitness is 0.11100723652543149']
# ['At iteration 10 the best fitness is 0.11100723652543149']
# ['At iteration 11 the best fitness is 0.11095794306503057']
# ['At iteration 12 the best fitness is 0.11095794306503057']
# ['At iteration 13 the best fitness is 0.11095794306503057']
# ['At iteration 14 the best fitness is 0.11095794306503057']
# ['At iteration 15 the best fitness is 0.11095794306503057']
# ['At iteration 16 the best fitness is 0.11095794306503057']
# ['At iteration 17 the best fitness is 0.11095794306503057']
# ['At iteration 18 the best fitness is 0.11095794306503057']
# ['At iteration 19 the best fitness is 0.11095794306503057']
# ['At iteration 20 the best fitness is 0.10704889665827158']
# ['At iteration 21 the best fitness is 0.10704889665827158']
# ['At iteration 22 the best fitness is 0.10704889665827158']
# ['At iteration 23 the best fitness is 0.10704889665827158']
# ['At iteration 24 the best fitness is 0.10704889665827158']
# ['At iteration 25 the best fitness is 0.10704889665827158']
# ['At iteration 26 the best fitness is 0.10704889665827158']
# ['At iteration 27 the best fitness is 0.10704889665827158']
# ['At iteration 28 the best fitness is 0.10704889665827158']
# ['At iteration 29 the best fitness is 0.10704889665827158']
#       Selected: 1477/3043 (48.5%), Fitness: 0.1070, Time: 1928.6s
#       Modality: D=49%, S=49%, Sk=48%,
#     Test Acc: 87.37%, F1: 87.02%, Features: 1477/3043 (48.5%), Model: 3.421MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.12365452033985894']
# ['At iteration 2 the best fitness is 0.12365452033985894']
# ['At iteration 3 the best fitness is 0.11961402470536417']
# ['At iteration 4 the best fitness is 0.11220671072852054']
# ['At iteration 5 the best fitness is 0.09261218523432459']
# ['At iteration 6 the best fitness is 0.09261218523432459']
# ['At iteration 7 the best fitness is 0.09261218523432459']
# ['At iteration 8 the best fitness is 0.09261218523432459']
# ['At iteration 9 the best fitness is 0.09261218523432459']
# ['At iteration 10 the best fitness is 0.09261218523432459']
# ['At iteration 11 the best fitness is 0.09261218523432459']
# ['At iteration 12 the best fitness is 0.09261218523432459']
# ['At iteration 13 the best fitness is 0.09261218523432459']
# ['At iteration 14 the best fitness is 0.09261218523432459']
# ['At iteration 15 the best fitness is 0.09261218523432459']
# ['At iteration 16 the best fitness is 0.09261218523432459']
# ['At iteration 17 the best fitness is 0.09261218523432459']
# ['At iteration 18 the best fitness is 0.09261218523432459']
# ['At iteration 19 the best fitness is 0.09261218523432459']
# ['At iteration 20 the best fitness is 0.09261218523432459']
# ['At iteration 21 the best fitness is 0.09261218523432459']
# ['At iteration 22 the best fitness is 0.09261218523432459']
# ['At iteration 23 the best fitness is 0.09261218523432459']
# ['At iteration 24 the best fitness is 0.09261218523432459']
# ['At iteration 25 the best fitness is 0.09261218523432459']
# ['At iteration 26 the best fitness is 0.09261218523432459']
# ['At iteration 27 the best fitness is 0.09261218523432459']
# ['At iteration 28 the best fitness is 0.09261218523432459']
# ['At iteration 29 the best fitness is 0.09261218523432459']
#       Selected: 1558/3043 (51.2%), Fitness: 0.0926, Time: 1832.2s
#       Modality: D=51%, S=53%, Sk=51%,
#     Test Acc: 84.85%, F1: 84.50%, Features: 1558/3043 (51.2%), Model: 3.579MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.11954830009149627']
# ['At iteration 2 the best fitness is 0.11954830009149627']
# ['At iteration 3 the best fitness is 0.11514631908072809']
# ['At iteration 4 the best fitness is 0.10368207831592272']
# ['At iteration 5 the best fitness is 0.10368207831592272']
# ['At iteration 6 the best fitness is 0.10368207831592272']
# ['At iteration 7 the best fitness is 0.10368207831592272']
# ['At iteration 8 the best fitness is 0.10368207831592272']
# ['At iteration 9 the best fitness is 0.10368207831592272']
# ['At iteration 10 the best fitness is 0.10368207831592272']
# ['At iteration 11 the best fitness is 0.10036455343397477']
# ['At iteration 12 the best fitness is 0.10036455343397477']
# ['At iteration 13 the best fitness is 0.10036455343397477']
# ['At iteration 14 the best fitness is 0.10036455343397477']
# ['At iteration 15 the best fitness is 0.10036455343397477']
# ['At iteration 16 the best fitness is 0.10036455343397477']
# ['At iteration 17 the best fitness is 0.10036455343397477']
# ['At iteration 18 the best fitness is 0.09645550702721567']
# ['At iteration 19 the best fitness is 0.09645550702721567']
# ['At iteration 20 the best fitness is 0.09645550702721567']
# ['At iteration 21 the best fitness is 0.09645550702721567']
# ['At iteration 22 the best fitness is 0.09645550702721567']
# ['At iteration 23 the best fitness is 0.09645550702721567']
# ['At iteration 24 the best fitness is 0.09645550702721567']
# ['At iteration 25 the best fitness is 0.09645550702721567']
# ['At iteration 26 the best fitness is 0.09645550702721567']
# ['At iteration 27 the best fitness is 0.09645550702721567']
# ['At iteration 28 the best fitness is 0.09645550702721567']
# ['At iteration 29 the best fitness is 0.09645550702721567']
# ['At iteration 30 the best fitness is 0.09645550702721567']
#       Selected: 1552/3043 (51.0%), Fitness: 0.0965, Time: 1876.5s
#       Modality: D=51%, S=53%, Sk=50%,
#     Test Acc: 81.31%, F1: 80.04%, Features: 1552/3043 (51.0%), Model: 3.567MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.12731709944461334']
# ['At iteration 2 the best fitness is 0.11943328201722746']
# ['At iteration 3 the best fitness is 0.11509702562032717']
# ['At iteration 4 the best fitness is 0.11496557639259138']
# ['At iteration 5 the best fitness is 0.10373137177632363']
# ['At iteration 6 the best fitness is 0.10373137177632363']
# ['At iteration 7 the best fitness is 0.10373137177632363']
# ['At iteration 8 the best fitness is 0.10373137177632363']
# ['At iteration 9 the best fitness is 0.10373137177632363']
# ['At iteration 10 the best fitness is 0.10373137177632363']
# ['At iteration 11 the best fitness is 0.10373137177632363']
# ['At iteration 12 the best fitness is 0.10373137177632363']
# ['At iteration 13 the best fitness is 0.10373137177632363']
# ['At iteration 14 the best fitness is 0.10359992254858785']
# ['At iteration 15 the best fitness is 0.10359992254858785']
# ['At iteration 16 the best fitness is 0.10359992254858785']
# ['At iteration 17 the best fitness is 0.10359992254858785']
# ['At iteration 18 the best fitness is 0.10359992254858785']
# ['At iteration 19 the best fitness is 0.10359992254858785']
# ['At iteration 20 the best fitness is 0.10359992254858785']
# ['At iteration 21 the best fitness is 0.10359992254858785']
# ['At iteration 22 the best fitness is 0.10359992254858785']
# ['At iteration 23 the best fitness is 0.10359992254858785']
# ['At iteration 24 the best fitness is 0.10359992254858785']
# ['At iteration 25 the best fitness is 0.10359992254858785']
# ['At iteration 26 the best fitness is 0.09982232536956465']
# ['At iteration 27 the best fitness is 0.09982232536956465']
# ['At iteration 28 the best fitness is 0.09982232536956465']
# ['At iteration 29 the best fitness is 0.09982232536956465']
# ['At iteration 30 the best fitness is 0.09982232536956465']
#       Selected: 1517/3043 (49.9%), Fitness: 0.0998, Time: 1857.1s
#       Modality: D=46%, S=51%, Sk=50%,
#     Test Acc: 85.35%, F1: 84.62%, Features: 1517/3043 (49.9%), Model: 3.499MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1316040623811128']
# ['At iteration 1 the best fitness is 0.105553661692777']
# ['At iteration 2 the best fitness is 0.105553661692777']
# ['At iteration 3 the best fitness is 0.105553661692777']
# ['At iteration 4 the best fitness is 0.105553661692777']
# ['At iteration 5 the best fitness is 0.105553661692777']
# ['At iteration 6 the best fitness is 0.105553661692777']
# ['At iteration 7 the best fitness is 0.105553661692777']
# ['At iteration 8 the best fitness is 0.105553661692777']
# ['At iteration 9 the best fitness is 0.105553661692777']
# ['At iteration 10 the best fitness is 0.105553661692777']
# ['At iteration 11 the best fitness is 0.10335031900982189']
# ['At iteration 12 the best fitness is 0.10335031900982189']
# ['At iteration 13 the best fitness is 0.10335031900982189']
# ['At iteration 14 the best fitness is 0.10335031900982189']
# ['At iteration 15 the best fitness is 0.10335031900982189']
# ['At iteration 16 the best fitness is 0.10335031900982189']
# ['At iteration 17 the best fitness is 0.10335031900982189']
# ['At iteration 18 the best fitness is 0.10335031900982189']
# ['At iteration 19 the best fitness is 0.10335031900982189']
# ['At iteration 20 the best fitness is 0.10335031900982189']
# ['At iteration 21 the best fitness is 0.10335031900982189']
# ['At iteration 22 the best fitness is 0.10335031900982189']
# ['At iteration 23 the best fitness is 0.10335031900982189']
# ['At iteration 24 the best fitness is 0.10335031900982189']
# ['At iteration 25 the best fitness is 0.10335031900982189']
# ['At iteration 26 the best fitness is 0.10335031900982189']
# ['At iteration 27 the best fitness is 0.09175306089890004']
# ['At iteration 28 the best fitness is 0.08774542757133921']
# ['At iteration 29 the best fitness is 0.08774542757133921']
#       Selected: 782/3043 (25.7%), Fitness: 0.0877, Time: 1833.6s
#       Modality: D=28%, S=27%, Sk=25%,
#     Test Acc: 82.83%, F1: 81.41%, Features: 782/3043 (25.7%), Model: 2.064MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.11496557639259138']
# ['At iteration 2 the best fitness is 0.11496557639259138']
# ['At iteration 3 the best fitness is 0.11496557639259138']
# ['At iteration 4 the best fitness is 0.09182348986790986']
# ['At iteration 5 the best fitness is 0.09182348986790986']
# ['At iteration 6 the best fitness is 0.09182348986790986']
# ['At iteration 7 the best fitness is 0.09182348986790986']
# ['At iteration 8 the best fitness is 0.09182348986790986']
# ['At iteration 9 the best fitness is 0.09182348986790986']
# ['At iteration 10 the best fitness is 0.09182348986790986']
# ['At iteration 11 the best fitness is 0.09182348986790986']
# ['At iteration 12 the best fitness is 0.09182348986790986']
# ['At iteration 13 the best fitness is 0.09182348986790986']
# ['At iteration 14 the best fitness is 0.09182348986790986']
# ['At iteration 15 the best fitness is 0.09182348986790986']
# ['At iteration 16 the best fitness is 0.09182348986790986']
# ['At iteration 17 the best fitness is 0.09182348986790986']
# ['At iteration 18 the best fitness is 0.09182348986790986']
# ['At iteration 19 the best fitness is 0.09182348986790986']
# ['At iteration 20 the best fitness is 0.09182348986790986']
# ['At iteration 21 the best fitness is 0.09182348986790986']
# ['At iteration 22 the best fitness is 0.09182348986790986']
# ['At iteration 23 the best fitness is 0.09182348986790986']
# ['At iteration 24 the best fitness is 0.09182348986790986']
# ['At iteration 25 the best fitness is 0.09182348986790986']
# ['At iteration 26 the best fitness is 0.09182348986790986']
# ['At iteration 27 the best fitness is 0.09182348986790986']
# ['At iteration 28 the best fitness is 0.09182348986790986']
# ['At iteration 29 the best fitness is 0.09182348986790986']
#       Selected: 1510/3043 (49.6%), Fitness: 0.0918, Time: 4442.5s
#       Modality: D=49%, S=53%, Sk=49%,
#     Test Acc: 80.30%, F1: 79.95%, Features: 1510/3043 (49.6%), Model: 3.485MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1351844857185323']
# ['At iteration 1 the best fitness is 0.1351844857185323']
# ['At iteration 2 the best fitness is 0.1269916126120352']
# ['At iteration 3 the best fitness is 0.12493771842866354']
# ['At iteration 4 the best fitness is 0.12493771842866354']
# ['At iteration 5 the best fitness is 0.12493771842866354']
# ['At iteration 6 the best fitness is 0.12493771842866354']
# ['At iteration 7 the best fitness is 0.12493771842866354']
# ['At iteration 8 the best fitness is 0.12493771842866354']
# ['At iteration 9 the best fitness is 0.12493771842866354']
# ['At iteration 10 the best fitness is 0.12493771842866354']
# ['At iteration 11 the best fitness is 0.12493771842866354']
# ['At iteration 12 the best fitness is 0.12429847156183225']
# ['At iteration 13 the best fitness is 0.11399613833803995']
# ['At iteration 14 the best fitness is 0.11399613833803995']
# ['At iteration 15 the best fitness is 0.11399613833803995']
# ['At iteration 16 the best fitness is 0.11399613833803995']
# ['At iteration 17 the best fitness is 0.11399613833803995']
# ['At iteration 18 the best fitness is 0.11399613833803995']
# ['At iteration 19 the best fitness is 0.11399613833803995']
# ['At iteration 20 the best fitness is 0.11399613833803995']
# ['At iteration 21 the best fitness is 0.11399613833803995']
# ['At iteration 22 the best fitness is 0.11399613833803995']
# ['At iteration 23 the best fitness is 0.11399613833803995']
# ['At iteration 24 the best fitness is 0.11399613833803995']
# ['At iteration 25 the best fitness is 0.11399613833803995']
# ['At iteration 26 the best fitness is 0.11399613833803995']
# ['At iteration 27 the best fitness is 0.11399613833803995']
# ['At iteration 28 the best fitness is 0.11399613833803995']
# ['At iteration 29 the best fitness is 0.11399613833803995']
#       Selected: 1420/3043 (46.7%), Fitness: 0.1140, Time: 1313.9s
#       Modality: D=47%, S=45%, Sk=47%,
#     Test Acc: 86.36%, F1: 86.30%, Features: 1420/3043 (46.7%), Model: 3.310MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879}, Total: 3043
# Results table: (90, 32)
# Methods: 18, Folds per method: {'baseline': 5, 'lasso': 5, 'meta_BAT': 5, 'meta_CS': 5, 'meta_DE': 5, 'meta_FFA': 5, 'meta_GA': 5, 'meta_GWO': 5, 'meta_HHO': 5, 'meta_JAYA': 5, 'meta_MFO': 5, 'meta_MVO': 5, 'meta_PSO': 5, 'meta_SCA': 5, 'meta_SSA': 5, 'meta_WOA': 5, 'mutual_info': 5, 'rfe': 5}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          86.713287         90.909091     86.927063
# 1  baseline     2          85.892116         93.434343     85.450069
# 2  baseline     3          83.636364         91.919192     81.884883
# 3  baseline     4          79.545455         96.464646     77.438076
# 4  baseline     5          89.898990         89.211618     89.614163
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        86.927063            89.156641         86.713287               3043
# 1        85.409455            86.904145         85.950413               3043
# 2        81.884883            83.144358         83.636364               3043
# 3        77.438076            84.435514         79.545455               3043
# 4        89.614163            91.611040         89.898990               3043
#
#    Features Total  ...  N Test  depth_retained  depth_total  \
# 0            3043  ...     286             512          512
# 1            3043  ...     241             512          512
# 2            3043  ...     220             512          512
# 3            3043  ...     220             512          512
# 4            3043  ...     198             512          512
#
#    depth_retention_%  sensor_retained  sensor_total  sensor_retention_%  \
# 0              100.0              652           652               100.0
# 1              100.0              652           652               100.0
# 2              100.0              652           652               100.0
# 3              100.0              652           652               100.0
# 4              100.0              652           652               100.0
#
#    skeleton_retained  skeleton_total  skeleton_retention_%
# 0               1879            1879                 100.0
# 1               1879            1879                 100.0
# 2               1879            1879                 100.0
# 3               1879            1879                 100.0
# 4               1879            1879                 100.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              85.14              3.85              84.26              4.73                  3043.0                      100.00              0.00                34.41                34.41          1697046.0                  6.48                        0.00               56.48
# mutual_info              87.39              2.70              86.67              3.82                  1521.0                       49.98             41.65                29.20                70.85           917782.0                  3.51                       50.02               38.46
#         rfe              86.24              4.18              85.56              4.37                  1521.0                       49.98              8.64                28.72                37.36           917782.0                  3.51                       50.02               38.46
#       lasso              52.54              5.96              51.57              6.98                  1521.0                       49.98            260.21                28.61               288.82           917782.0                  3.51                       50.02               38.46
#    meta_BAT              83.18              5.70              82.15              6.52                  1510.8                       49.65           1948.73                31.82              1980.55           912559.6                  3.49                       50.35               38.43
#     meta_CS              83.92              2.68              83.12              2.81                  1523.6                       50.07           3972.00                32.46              4004.46           919113.2                  3.51                       49.93               38.52
#     meta_DE              83.09              2.31              82.26              2.83                  1506.6                       49.51           2019.44                31.88              2051.32           910409.2                  3.48                       50.49               38.42
#    meta_FFA              85.97              2.64              85.51              3.10                  1529.8                       50.27           1893.99                31.38              1925.37           922287.6                  3.52                       49.73               38.63
#     meta_GA              83.81              4.78              82.98              5.35                  1507.6                       49.54           1868.75                31.03              1899.78           910921.2                  3.48                       50.46               38.43
#    meta_GWO              84.70              1.76              83.96              2.69                  1207.8                       39.69           1852.16                30.41              1882.57           757423.6                  2.90                       60.31               35.12
#    meta_HHO              82.93              3.75              81.79              4.84                   973.0                       31.98           2442.62                31.47              2474.09           637206.0                  2.44                       68.02               32.47
#   meta_JAYA              83.81              4.36              82.93              5.29                  1499.4                       49.27           1947.92                31.21              1979.12           906722.8                  3.46                       50.73               38.42
#    meta_MFO              83.14              2.57              82.28              3.28                  1556.0                       51.13           1822.25                31.23              1853.49           935702.0                  3.58                       48.87               38.88
#    meta_MVO              82.00              3.13              80.92              3.91                  1499.0                       49.26           1908.92                31.51              1940.44           906518.0                  3.46                       50.74               38.42
#    meta_PSO              84.01              2.25              83.33              2.85                  1506.0                       49.49           1897.88                31.34              1929.21           910102.0                  3.48                       50.51               38.39
#    meta_SCA              81.24              2.69              80.18              3.35                   820.4                       26.96           1862.88                29.92              1892.80           559074.8                  2.14                       73.04               30.50
#    meta_SSA              82.60              2.49              82.22              2.89                  1515.2                       49.79           4714.26                28.90              4743.16           914812.4                  3.50                       50.21               38.50
#    meta_WOA              83.83              2.50              83.38              2.87                  1171.6                       38.50           1660.82                28.38              1689.20           738889.2                  2.82                       61.50               34.57

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# C:\Users\aruay.amangeldi\AppData\Local\Temp\ipykernel_27284\2859632419.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# C:\Users\aruay.amangeldi\AppData\Local\Temp\ipykernel_27284\514708896.py:16: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
# C:\Users\aruay.amangeldi\AppData\Local\Temp\ipykernel_27284\514708896.py:27: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
# C:\Users\aruay.amangeldi\AppData\Local\Temp\ipykernel_27284\514708896.py:38: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_FFA
#     F1 Macro:           88.12%
#     F1 Weighted:        88.12%
#     Test Accuracy:      87.76%
#     Feature Retention:  50.41% (1534/3043)
#     Modality Retention: depth=49.2%, sensor=51.5%, skeleton=50.3%
#
#   Fold 2: Best = meta_BAT
#     F1 Macro:           88.71%
#     F1 Weighted:        88.70%
#     Test Accuracy:      88.80%
#     Feature Retention:  50.25% (1529/3043)
#     Modality Retention: depth=53.1%, sensor=49.5%, skeleton=49.7%
#
#   Fold 3: Best = meta_GA
#     F1 Macro:           86.65%
#     F1 Weighted:        86.65%
#     Test Accuracy:      87.27%
#     Feature Retention:  49.52% (1507/3043)
#     Modality Retention: depth=47.9%, sensor=51.2%, skeleton=49.4%
#
#   Fold 4: Best = meta_WOA
#     F1 Macro:           85.15%
#     F1 Weighted:        85.15%
#     Test Accuracy:      85.91%
#     Feature Retention:  33.29% (1013/3043)
#     Modality Retention: depth=33.6%, sensor=34.8%, skeleton=32.7%
#
#   Fold 5: Best = meta_JAYA
#     F1 Macro:           87.02%
#     F1 Weighted:        87.02%
#     Test Accuracy:      87.37%
#     Feature Retention:  48.54% (1477/3043)
#     Modality Retention: depth=48.8%, sensor=48.6%, skeleton=48.4%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 87.13% ± 1.38%
#
#   Average F1 Weighted         : 87.13% ± 1.38%
#
#   Average Test Accuracy       : 87.42% ± 1.04%
#
#   Average Feature Retention   : 46.40% ± 7.37%
#
#   Average Modality-wise Feature Retention:
#            depth: 46.52% ± 7.50%
#           sensor: 47.15% ± 7.00%
#         skeleton: 46.11% ± 7.54%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%
#     1           meta_FFA         88.12            88.12              87.76                  50.41              49.22               51.53                 50.35
#     2           meta_BAT         88.71            88.70              88.80                  50.25              53.12               49.54                 49.71
#     3            meta_GA         86.65            86.65              87.27                  49.52              47.85               51.23                 49.39
#     4           meta_WOA         85.15            85.15              85.91                  33.29              33.59               34.82                 32.68
#     5          meta_JAYA         87.02            87.02              87.37                  48.54              48.83               48.62                 48.43
#
# Saved to: results_noise_0.5_40\best_metaheuristic_per_fold.csv
