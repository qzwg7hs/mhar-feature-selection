# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.11.0+cu126
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## Configuration

# %%
FEATURE_DIR = Path("features_noise_1.0_30")

RESULTS_ROOT = Path("results_noise_1.0_30")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

N_POPULATION = 20
MAX_ITERATIONS = 30

TARGET_FEATURE_PERCENTAGE = 0.5

EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   TOTAL: 8039
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, ")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 73.78%, F1: 74.03%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 33.0s
#     Test Acc: 77.27%, F1: 77.88%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 8.0s
#     Test Acc: 80.42%, F1: 80.61%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 189.4s
#     Test Acc: 36.01%, F1: 35.32%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.12113212307099916']
# ['At iteration 1 the best fitness is 0.12113212307099916']
# ['At iteration 2 the best fitness is 0.12113212307099916']
# ['At iteration 3 the best fitness is 0.12113212307099916']
# ['At iteration 4 the best fitness is 0.12113212307099916']
# ['At iteration 5 the best fitness is 0.12113212307099916']
# ['At iteration 6 the best fitness is 0.1163505744264863']
# ['At iteration 7 the best fitness is 0.1163505744264863']
# ['At iteration 8 the best fitness is 0.1163505744264863']
# ['At iteration 9 the best fitness is 0.1163505744264863']
# ['At iteration 10 the best fitness is 0.1163505744264863']
# ['At iteration 11 the best fitness is 0.11631771211955236']
# ['At iteration 12 the best fitness is 0.11631771211955236']
# ['At iteration 13 the best fitness is 0.11631771211955236']
# ['At iteration 14 the best fitness is 0.11631771211955236']
# ['At iteration 15 the best fitness is 0.11631771211955236']
# ['At iteration 16 the best fitness is 0.11631771211955236']
# ['At iteration 17 the best fitness is 0.11631771211955236']
# ['At iteration 18 the best fitness is 0.11631771211955236']
# ['At iteration 19 the best fitness is 0.11631771211955236']
# ['At iteration 20 the best fitness is 0.11631771211955236']
# ['At iteration 21 the best fitness is 0.11631771211955236']
# ['At iteration 22 the best fitness is 0.11621912519875052']
# ['At iteration 23 the best fitness is 0.11621912519875052']
# ['At iteration 24 the best fitness is 0.11621912519875052']
# ['At iteration 25 the best fitness is 0.11621912519875052']
# ['At iteration 26 the best fitness is 0.11621912519875052']
# ['At iteration 27 the best fitness is 0.11621912519875052']
# ['At iteration 28 the best fitness is 0.11621912519875052']
# ['At iteration 29 the best fitness is 0.11621912519875052']
#       Selected: 1525/3043 (50.1%), Fitness: 0.1162, Time: 1870.4s
#       Modality: D=49%, S=51%, Sk=50%,
#     Test Acc: 79.37%, F1: 79.97%, Features: 1525/3043 (50.1%), Model: 3.515MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1114868700146387']
# ['At iteration 10 the best fitness is 0.1114868700146387']
# ['At iteration 20 the best fitness is 0.1114868700146387']
#       Selected: 1529/3043 (50.2%), Fitness: 0.1115, Time: 3664.6s
#       Modality: D=53%, S=49%, Sk=50%,
#     Test Acc: 76.92%, F1: 77.81%, Features: 1529/3043 (50.2%), Model: 3.523MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1254864617253707']
# ['At iteration 2 the best fitness is 0.1254864617253707']
# ['At iteration 3 the best fitness is 0.12185509382354599']
# ['At iteration 4 the best fitness is 0.12185509382354599']
# ['At iteration 5 the best fitness is 0.12185509382354599']
# ['At iteration 6 the best fitness is 0.12185509382354599']
# ['At iteration 7 the best fitness is 0.12185509382354599']
# ['At iteration 8 the best fitness is 0.12075420654125878']
# ['At iteration 9 the best fitness is 0.12075420654125878']
# ['At iteration 10 the best fitness is 0.12075420654125878']
# ['At iteration 11 the best fitness is 0.12075420654125878']
# ['At iteration 12 the best fitness is 0.1206720507739239']
# ['At iteration 13 the best fitness is 0.1206720507739239']
# ['At iteration 14 the best fitness is 0.1206720507739239']
# ['At iteration 15 the best fitness is 0.12040915231845234']
# ['At iteration 16 the best fitness is 0.11193051115824698']
# ['At iteration 17 the best fitness is 0.11193051115824698']
# ['At iteration 18 the best fitness is 0.09766802099204337']
# ['At iteration 19 the best fitness is 0.09766802099204337']
# ['At iteration 20 the best fitness is 0.09766802099204337']
# ['At iteration 21 the best fitness is 0.09766802099204337']
# ['At iteration 22 the best fitness is 0.09766802099204337']
# ['At iteration 23 the best fitness is 0.09766802099204337']
# ['At iteration 24 the best fitness is 0.09766802099204337']
# ['At iteration 25 the best fitness is 0.09766802099204337']
# ['At iteration 26 the best fitness is 0.09766802099204337']
# ['At iteration 27 the best fitness is 0.09763515868510943']
# ['At iteration 28 the best fitness is 0.09763515868510943']
# ['At iteration 29 the best fitness is 0.09763515868510943']
# ['At iteration 30 the best fitness is 0.09763515868510943']
#       Selected: 1562/3043 (51.3%), Fitness: 0.0976, Time: 2018.8s
#       Modality: D=50%, S=54%, Sk=51%,
#     Test Acc: 80.07%, F1: 80.83%, Features: 1562/3043 (51.3%), Model: 3.587MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.12062275731352298']
# ['At iteration 1 the best fitness is 0.1311059991966992']
# ['At iteration 2 the best fitness is 0.14945992956180268']
# ['At iteration 3 the best fitness is 0.13534531977680184']
# ['At iteration 4 the best fitness is 0.14020902418864956']
# ['At iteration 5 the best fitness is 0.13025157921641659']
# ['At iteration 6 the best fitness is 0.1252399944233661']
# ['At iteration 7 the best fitness is 0.13976538304504127']
# ['At iteration 8 the best fitness is 0.130005111914412']
# ['At iteration 9 the best fitness is 0.12998868076094502']
# ['At iteration 10 the best fitness is 0.13472093594505685']
# ['At iteration 11 the best fitness is 0.1394860534361027']
# ['At iteration 12 the best fitness is 0.12995581845401108']
# ['At iteration 13 the best fitness is 0.12022840963031563']
# ['At iteration 14 the best fitness is 0.12985723153320922']
# ['At iteration 15 the best fitness is 0.12979150691934133']
# ['At iteration 16 the best fitness is 0.14415258400634676']
# ['At iteration 17 the best fitness is 0.13940389766876785']
# ['At iteration 18 the best fitness is 0.12504282058176241']
# ['At iteration 19 the best fitness is 0.12027770309071655']
# ['At iteration 20 the best fitness is 0.12509211404216336']
# ['At iteration 21 the best fitness is 0.14423473977368162']
# ['At iteration 22 the best fitness is 0.11544686098580277']
# ['At iteration 23 the best fitness is 0.12509211404216336']
# ['At iteration 24 the best fitness is 0.12507568288869636']
# ['At iteration 25 the best fitness is 0.11064888118782305']
# ['At iteration 26 the best fitness is 0.12985723153320922']
# ['At iteration 27 the best fitness is 0.12026127193724957']
# ['At iteration 28 the best fitness is 0.13465521133118896']
# ['At iteration 29 the best fitness is 0.12987366268667622']
#       Selected: 1480/3043 (48.6%), Fitness: 0.1299, Time: 2028.0s
#       Modality: D=48%, S=50%, Sk=48%,
#     Test Acc: 77.97%, F1: 78.47%, Features: 1480/3043 (48.6%), Model: 3.427MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.13562464938574037
# At iteration 2 the best fitness is 0.1299229561470771
# At iteration 3 the best fitness is 0.1299229561470771
# At iteration 4 the best fitness is 0.1447605366846248
# At iteration 5 the best fitness is 0.14006114380744678
# At iteration 6 the best fitness is 0.13555892477187248
# At iteration 7 the best fitness is 0.12573292902737532
# At iteration 8 the best fitness is 0.12578222248777624
# At iteration 9 the best fitness is 0.11595622674327895
# At iteration 10 the best fitness is 0.13532888862333486
# At iteration 11 the best fitness is 0.1303830284441524
# At iteration 12 the best fitness is 0.11138828309383686
# At iteration 13 the best fitness is 0.13062949574615698
# At iteration 14 the best fitness is 0.12551932403230465
# At iteration 15 the best fitness is 0.11595622674327895
# At iteration 16 the best fitness is 0.11649845480768907
# At iteration 17 the best fitness is 0.13013656114214778
# At iteration 18 the best fitness is 0.1396339338173055
# At iteration 19 the best fitness is 0.1300708365282799
# At iteration 20 the best fitness is 0.12128000345220191
# At iteration 21 the best fitness is 0.12504282058176241
# At iteration 22 the best fitness is 0.12573292902737532
# At iteration 23 the best fitness is 0.11651488596115604
# At iteration 24 the best fitness is 0.12108282961059824
# At iteration 25 the best fitness is 0.13557535592533945
# At iteration 26 the best fitness is 0.12606155209671477
# At iteration 27 the best fitness is 0.12558504864617254
# At iteration 28 the best fitness is 0.11082962387595977
# At iteration 29 the best fitness is 0.11577548405514224
# At iteration 30 the best fitness is 0.1257986536412432
#       Selected: 1524/3043 (50.1%), Fitness: 0.1258, Time: 2175.0s
#       Modality: D=48%, S=51%, Sk=50%,
#     Test Acc: 79.72%, F1: 80.76%, Features: 1524/3043 (50.1%), Model: 3.513MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1253714436511019']
# ['At iteration 1 the best fitness is 0.1253714436511019']
# ['At iteration 2 the best fitness is 0.1253714436511019']
# ['At iteration 3 the best fitness is 0.1253714436511019']
# ['At iteration 4 the best fitness is 0.12359687907666878']
# ['At iteration 5 the best fitness is 0.11403378178764306']
# ['At iteration 6 the best fitness is 0.11403378178764306']
# ['At iteration 7 the best fitness is 0.11403378178764306']
# ['At iteration 8 the best fitness is 0.10238392800831184']
# ['At iteration 9 the best fitness is 0.10238392800831184']
# ['At iteration 10 the best fitness is 0.10238392800831184']
# ['At iteration 11 the best fitness is 0.10238392800831184']
# ['At iteration 12 the best fitness is 0.10238392800831184']
# ['At iteration 13 the best fitness is 0.10238392800831184']
# ['At iteration 14 the best fitness is 0.10238392800831184']
# ['At iteration 15 the best fitness is 0.10238392800831184']
# ['At iteration 16 the best fitness is 0.10238392800831184']
# ['At iteration 17 the best fitness is 0.10238392800831184']
# ['At iteration 18 the best fitness is 0.10238392800831184']
# ['At iteration 19 the best fitness is 0.10238392800831184']
# ['At iteration 20 the best fitness is 0.10238392800831184']
# ['At iteration 21 the best fitness is 0.10238392800831184']
# ['At iteration 22 the best fitness is 0.10238392800831184']
# ['At iteration 23 the best fitness is 0.10238392800831184']
# ['At iteration 24 the best fitness is 0.10238392800831184']
# ['At iteration 25 the best fitness is 0.10238392800831184']
# ['At iteration 26 the best fitness is 0.10238392800831184']
# ['At iteration 27 the best fitness is 0.10238392800831184']
# ['At iteration 28 the best fitness is 0.10238392800831184']
# ['At iteration 29 the best fitness is 0.10238392800831184']
#       Selected: 1267/3043 (41.6%), Fitness: 0.1024, Time: 1953.0s
#       Modality: D=44%, S=43%, Sk=41%,
#     Test Acc: 79.02%, F1: 79.56%, Features: 1267/3043 (41.6%), Model: 3.011MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.1303665972906854']
# ['At iteration 1 the best fitness is 0.1303665972906854']
# ['At iteration 2 the best fitness is 0.1303665972906854']
# ['At iteration 3 the best fitness is 0.12170721344234323']
# ['At iteration 4 the best fitness is 0.12170721344234323']
# ['At iteration 5 the best fitness is 0.12170721344234323']
# ['At iteration 6 the best fitness is 0.12170721344234323']
# ['At iteration 7 the best fitness is 0.12170721344234323']
# ['At iteration 8 the best fitness is 0.12170721344234323']
# ['At iteration 9 the best fitness is 0.12170721344234323']
# ['At iteration 10 the best fitness is 0.12170721344234323']
# ['At iteration 11 the best fitness is 0.12170721344234323']
# ['At iteration 12 the best fitness is 0.12170721344234323']
# ['At iteration 13 the best fitness is 0.12170721344234323']
# ['At iteration 14 the best fitness is 0.12170721344234323']
# ['At iteration 15 the best fitness is 0.12170721344234323']
# ['At iteration 16 the best fitness is 0.12170721344234323']
# ['At iteration 17 the best fitness is 0.12170721344234323']
# ['At iteration 18 the best fitness is 0.11799368977318364']
# ['At iteration 19 the best fitness is 0.11799368977318364']
# ['At iteration 20 the best fitness is 0.11799368977318364']
# ['At iteration 21 the best fitness is 0.11799368977318364']
# ['At iteration 22 the best fitness is 0.11799368977318364']
# ['At iteration 23 the best fitness is 0.1128341416133069']
# ['At iteration 24 the best fitness is 0.1128341416133069']
# ['At iteration 25 the best fitness is 0.1128341416133069']
# ['At iteration 26 the best fitness is 0.1128341416133069']
# ['At iteration 27 the best fitness is 0.1128341416133069']
# ['At iteration 28 the best fitness is 0.1128341416133069']
# ['At iteration 29 the best fitness is 0.1128341416133069']
#       Selected: 1903/3043 (62.5%), Fitness: 0.1128, Time: 2591.6s
#       Modality: D=63%, S=62%, Sk=63%,
#     Test Acc: 80.07%, F1: 80.16%, Features: 1903/3043 (62.5%), Model: 4.253MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13961750266383852']
# ['At iteration 1 the best fitness is 0.12035985885805141']
# ['At iteration 2 the best fitness is 0.12035985885805141']
# ['At iteration 3 the best fitness is 0.12035985885805141']
# ['At iteration 4 the best fitness is 0.1158576398224771']
# ['At iteration 5 the best fitness is 0.1158576398224771']
# ['At iteration 6 the best fitness is 0.11557831021353855']
# ['At iteration 7 the best fitness is 0.11557831021353855']
# ['At iteration 8 the best fitness is 0.11557831021353855']
# ['At iteration 9 the best fitness is 0.11094464195022857']
# ['At iteration 10 the best fitness is 0.11094464195022857']
# ['At iteration 11 the best fitness is 0.11094464195022857']
# ['At iteration 12 the best fitness is 0.11094464195022857']
# ['At iteration 13 the best fitness is 0.11094464195022857']
# ['At iteration 14 the best fitness is 0.11094464195022857']
# ['At iteration 15 the best fitness is 0.11094464195022857']
# ['At iteration 16 the best fitness is 0.11094464195022857']
# ['At iteration 17 the best fitness is 0.11094464195022857']
# ['At iteration 18 the best fitness is 0.10184161695827812']
# ['At iteration 19 the best fitness is 0.10184161695827812']
# ['At iteration 20 the best fitness is 0.10184161695827812']
# ['At iteration 21 the best fitness is 0.10184161695827812']
# ['At iteration 22 the best fitness is 0.10184161695827812']
# ['At iteration 23 the best fitness is 0.10184161695827812']
# ['At iteration 24 the best fitness is 0.10184161695827812']
# ['At iteration 25 the best fitness is 0.10184161695827812']
# ['At iteration 26 the best fitness is 0.10184161695827812']
# ['At iteration 27 the best fitness is 0.10184161695827812']
# ['At iteration 28 the best fitness is 0.10184161695827812']
# ['At iteration 29 the best fitness is 0.10184161695827812']
#       Selected: 1526/3043 (50.1%), Fitness: 0.1018, Time: 2039.5s
#       Modality: D=54%, S=50%, Sk=49%,
#     Test Acc: 82.52%, F1: 82.82%, Features: 1526/3043 (50.1%), Model: 3.517MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.135854685534278']
# ['At iteration 2 the best fitness is 0.11621912519875052']
# ['At iteration 3 the best fitness is 0.11621912519875052']
# ['At iteration 4 the best fitness is 0.11621912519875052']
# ['At iteration 5 the best fitness is 0.11621912519875052']
# ['At iteration 6 the best fitness is 0.11621912519875052']
# ['At iteration 7 the best fitness is 0.11621912519875052']
# ['At iteration 8 the best fitness is 0.11621912519875052']
# ['At iteration 9 the best fitness is 0.11621912519875052']
# ['At iteration 10 the best fitness is 0.11621912519875052']
# ['At iteration 11 the best fitness is 0.11621912519875052']
# ['At iteration 12 the best fitness is 0.11621912519875052']
# ['At iteration 13 the best fitness is 0.11621912519875052']
# ['At iteration 14 the best fitness is 0.11621912519875052']
# ['At iteration 15 the best fitness is 0.11621912519875052']
# ['At iteration 16 the best fitness is 0.11286708690586446']
# ['At iteration 17 the best fitness is 0.11286708690586446']
# ['At iteration 18 the best fitness is 0.11286708690586446']
# ['At iteration 19 the best fitness is 0.11286708690586446']
# ['At iteration 20 the best fitness is 0.09809523098218469']
# ['At iteration 21 the best fitness is 0.09809523098218469']
# ['At iteration 22 the best fitness is 0.09809523098218469']
# ['At iteration 23 the best fitness is 0.09809523098218469']
# ['At iteration 24 the best fitness is 0.09809523098218469']
# ['At iteration 25 the best fitness is 0.09809523098218469']
# ['At iteration 26 the best fitness is 0.09809523098218469']
# ['At iteration 27 the best fitness is 0.09809523098218469']
# ['At iteration 28 the best fitness is 0.09809523098218469']
# ['At iteration 29 the best fitness is 0.09809523098218469']
#       Selected: 1590/3043 (52.3%), Fitness: 0.0981, Time: 1906.1s
#       Modality: D=53%, S=54%, Sk=51%,
#     Test Acc: 79.02%, F1: 79.59%, Features: 1590/3043 (52.3%), Model: 3.642MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1447605366846248']
# ['At iteration 2 the best fitness is 0.1303008726768175']
# ['At iteration 3 the best fitness is 0.12601225863631385']
# ['At iteration 4 the best fitness is 0.12547003057190373']
# ['At iteration 5 the best fitness is 0.12547003057190373']
# ['At iteration 6 the best fitness is 0.12106639845713127']
# ['At iteration 7 the best fitness is 0.12106639845713127']
# ['At iteration 8 the best fitness is 0.12106639845713127']
# ['At iteration 9 the best fitness is 0.12106639845713127']
# ['At iteration 10 the best fitness is 0.11603838251061381']
# ['At iteration 11 the best fitness is 0.11595622674327895']
# ['At iteration 12 the best fitness is 0.106606734449324']
# ['At iteration 13 the best fitness is 0.106606734449324']
# ['At iteration 14 the best fitness is 0.106606734449324']
# ['At iteration 15 the best fitness is 0.106606734449324']
# ['At iteration 16 the best fitness is 0.106606734449324']
# ['At iteration 17 the best fitness is 0.106606734449324']
# ['At iteration 18 the best fitness is 0.106606734449324']
# ['At iteration 19 the best fitness is 0.106606734449324']
# ['At iteration 20 the best fitness is 0.106606734449324']
# ['At iteration 21 the best fitness is 0.106606734449324']
# ['At iteration 22 the best fitness is 0.106606734449324']
# ['At iteration 23 the best fitness is 0.106606734449324']
# ['At iteration 24 the best fitness is 0.106606734449324']
# ['At iteration 25 the best fitness is 0.106606734449324']
# ['At iteration 26 the best fitness is 0.106606734449324']
# ['At iteration 27 the best fitness is 0.10647528522158821']
# ['At iteration 28 the best fitness is 0.10647528522158821']
# ['At iteration 29 the best fitness is 0.10647528522158821']
# ['At iteration 30 the best fitness is 0.10647528522158821']
#       Selected: 1516/3043 (49.8%), Fitness: 0.1065, Time: 1969.1s
#       Modality: D=52%, S=50%, Sk=49%,
#     Test Acc: 77.97%, F1: 79.21%, Features: 1516/3043 (49.8%), Model: 3.497MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.14027474880251745']
# ['At iteration 2 the best fitness is 0.14027474880251745']
# ['At iteration 3 the best fitness is 0.14027474880251745']
# ['At iteration 4 the best fitness is 0.14014329957478167']
# ['At iteration 5 the best fitness is 0.14014329957478167']
# ['At iteration 6 the best fitness is 0.14014329957478167']
# ['At iteration 7 the best fitness is 0.14014329957478167']
# ['At iteration 8 the best fitness is 0.13544390669760367']
# ['At iteration 9 the best fitness is 0.13463878017772196']
# ['At iteration 10 the best fitness is 0.13005440537481291']
# ['At iteration 11 the best fitness is 0.1162355563522175']
# ['At iteration 12 the best fitness is 0.1162355563522175']
# ['At iteration 13 the best fitness is 0.1162355563522175']
# ['At iteration 14 the best fitness is 0.1162355563522175']
# ['At iteration 15 the best fitness is 0.1162355563522175']
# ['At iteration 16 the best fitness is 0.1162355563522175']
# ['At iteration 17 the best fitness is 0.1162355563522175']
# ['At iteration 18 the best fitness is 0.1162355563522175']
# ['At iteration 19 the best fitness is 0.1162355563522175']
# ['At iteration 20 the best fitness is 0.1162355563522175']
# ['At iteration 21 the best fitness is 0.1162355563522175']
# ['At iteration 22 the best fitness is 0.1162355563522175']
# ['At iteration 23 the best fitness is 0.1162355563522175']
# ['At iteration 24 the best fitness is 0.1162355563522175']
# ['At iteration 25 the best fitness is 0.1162355563522175']
# ['At iteration 26 the best fitness is 0.11140471424730383']
# ['At iteration 27 the best fitness is 0.11140471424730383']
# ['At iteration 28 the best fitness is 0.11140471424730383']
# ['At iteration 29 the best fitness is 0.11140471424730383']
# ['At iteration 30 the best fitness is 0.11140471424730383']
#       Selected: 1524/3043 (50.1%), Fitness: 0.1114, Time: 1916.1s
#       Modality: D=52%, S=49%, Sk=50%,
#     Test Acc: 77.62%, F1: 78.21%, Features: 1524/3043 (50.1%), Model: 3.513MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13961750266383852']
# ['At iteration 1 the best fitness is 0.11873317466482104']
# ['At iteration 2 the best fitness is 0.11873317466482104']
# ['At iteration 3 the best fitness is 0.11873317466482104']
# ['At iteration 4 the best fitness is 0.11050108379224378']
# ['At iteration 5 the best fitness is 0.11050108379224378']
# ['At iteration 6 the best fitness is 0.11050108379224378']
# ['At iteration 7 the best fitness is 0.11050108379224378']
# ['At iteration 8 the best fitness is 0.11050108379224378']
# ['At iteration 9 the best fitness is 0.11004109448079213']
# ['At iteration 10 the best fitness is 0.11004109448079213']
# ['At iteration 11 the best fitness is 0.11004109448079213']
# ['At iteration 12 the best fitness is 0.09305103283907096']
# ['At iteration 13 the best fitness is 0.09305103283907096']
# ['At iteration 14 the best fitness is 0.09305103283907096']
# ['At iteration 15 the best fitness is 0.09305103283907096']
# ['At iteration 16 the best fitness is 0.09305103283907096']
# ['At iteration 17 the best fitness is 0.09305103283907096']
# ['At iteration 18 the best fitness is 0.09305103283907096']
# ['At iteration 19 the best fitness is 0.09305103283907096']
# ['At iteration 20 the best fitness is 0.09305103283907096']
# ['At iteration 21 the best fitness is 0.08163121520827735']
# ['At iteration 22 the best fitness is 0.08163121520827735']
# ['At iteration 23 the best fitness is 0.08163121520827735']
# ['At iteration 24 the best fitness is 0.08163121520827735']
# ['At iteration 25 the best fitness is 0.08163121520827735']
# ['At iteration 26 the best fitness is 0.08163121520827735']
# ['At iteration 27 the best fitness is 0.08163121520827735']
# ['At iteration 28 the best fitness is 0.08163121520827735']
# ['At iteration 29 the best fitness is 0.08163121520827735']
#       Selected: 588/3043 (19.3%), Fitness: 0.0816, Time: 1817.4s
#       Modality: D=19%, S=22%, Sk=19%,
#     Test Acc: 73.43%, F1: 73.38%, Features: 588/3043 (19.3%), Model: 1.685MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.12538787480456887']
# ['At iteration 2 the best fitness is 0.12538787480456887']
# ['At iteration 3 the best fitness is 0.12538787480456887']
# ['At iteration 4 the best fitness is 0.12538787480456887']
# ['At iteration 5 the best fitness is 0.12538787480456887']
# ['At iteration 6 the best fitness is 0.12538787480456887']
# ['At iteration 7 the best fitness is 0.12538787480456887']
# ['At iteration 8 the best fitness is 0.11577548405514224']
# ['At iteration 9 the best fitness is 0.11119110925223318']
# ['At iteration 10 the best fitness is 0.11119110925223318']
# ['At iteration 11 the best fitness is 0.11119110925223318']
# ['At iteration 12 the best fitness is 0.11119110925223318']
# ['At iteration 13 the best fitness is 0.11119110925223318']
# ['At iteration 14 the best fitness is 0.11119110925223318']
# ['At iteration 15 the best fitness is 0.11119110925223318']
# ['At iteration 16 the best fitness is 0.11119110925223318']
# ['At iteration 17 the best fitness is 0.11119110925223318']
# ['At iteration 18 the best fitness is 0.11119110925223318']
# ['At iteration 19 the best fitness is 0.11119110925223318']
# ['At iteration 20 the best fitness is 0.11119110925223318']
# ['At iteration 21 the best fitness is 0.11119110925223318']
# ['At iteration 22 the best fitness is 0.11119110925223318']
# ['At iteration 23 the best fitness is 0.11119110925223318']
# ['At iteration 24 the best fitness is 0.11119110925223318']
# ['At iteration 25 the best fitness is 0.11119110925223318']
# ['At iteration 26 the best fitness is 0.11119110925223318']
# ['At iteration 27 the best fitness is 0.11119110925223318']
# ['At iteration 28 the best fitness is 0.11119110925223318']
# ['At iteration 29 the best fitness is 0.11119110925223318']
#       Selected: 1511/3043 (49.7%), Fitness: 0.1112, Time: 4730.8s
#       Modality: D=47%, S=51%, Sk=50%,
#     Test Acc: 79.02%, F1: 78.95%, Features: 1511/3043 (49.7%), Model: 3.487MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13593684130161288']
# ['At iteration 1 the best fitness is 0.11855259794793155']
# ['At iteration 2 the best fitness is 0.11855259794793155']
# ['At iteration 3 the best fitness is 0.11855259794793155']
# ['At iteration 4 the best fitness is 0.11855259794793155']
# ['At iteration 5 the best fitness is 0.11736955489830946']
# ['At iteration 6 the best fitness is 0.11736955489830946']
# ['At iteration 7 the best fitness is 0.11736955489830946']
# ['At iteration 8 the best fitness is 0.11736955489830946']
# ['At iteration 9 the best fitness is 0.11736955489830946']
# ['At iteration 10 the best fitness is 0.11736955489830946']
# ['At iteration 11 the best fitness is 0.11736955489830946']
# ['At iteration 12 the best fitness is 0.11736955489830946']
# ['At iteration 13 the best fitness is 0.11736955489830946']
# ['At iteration 14 the best fitness is 0.11736955489830946']
# ['At iteration 15 the best fitness is 0.11736955489830946']
# ['At iteration 16 the best fitness is 0.11736955489830946']
# ['At iteration 17 the best fitness is 0.11132280743683966']
# ['At iteration 18 the best fitness is 0.11132280743683966']
# ['At iteration 19 the best fitness is 0.11132280743683966']
# ['At iteration 20 the best fitness is 0.11132280743683966']
# ['At iteration 21 the best fitness is 0.11132280743683966']
# ['At iteration 22 the best fitness is 0.11132280743683966']
# ['At iteration 23 the best fitness is 0.11132280743683966']
# ['At iteration 24 the best fitness is 0.11132280743683966']
# ['At iteration 25 the best fitness is 0.11132280743683966']
# ['At iteration 26 the best fitness is 0.11132280743683966']
# ['At iteration 27 the best fitness is 0.11132280743683966']
# ['At iteration 28 the best fitness is 0.11132280743683966']
# ['At iteration 29 the best fitness is 0.11132280743683966']
#       Selected: 643/3043 (21.1%), Fitness: 0.1113, Time: 1663.3s
#       Modality: D=20%, S=22%, Sk=21%,
#     Test Acc: 77.97%, F1: 78.30%, Features: 643/3043 (21.1%), Model: 1.792MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 81.33%, F1: 80.96%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 37.2s
#     Test Acc: 87.97%, F1: 87.60%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 8.0s
#     Test Acc: 88.38%, F1: 87.94%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#       Selected: 1521/3043 (50.0%), Time: 259.7s
#     Test Acc: 36.51%, F1: 36.18%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.12114855422446613']
# ['At iteration 1 the best fitness is 0.1019730661860139']
# ['At iteration 2 the best fitness is 0.1019730661860139']
# ['At iteration 3 the best fitness is 0.1019730661860139']
# ['At iteration 4 the best fitness is 0.1019730661860139']
# ['At iteration 5 the best fitness is 0.1019730661860139']
# ['At iteration 6 the best fitness is 0.1019730661860139']
# ['At iteration 7 the best fitness is 0.1019730661860139']
# ['At iteration 8 the best fitness is 0.1019730661860139']
# ['At iteration 9 the best fitness is 0.1019730661860139']
# ['At iteration 10 the best fitness is 0.1019730661860139']
# ['At iteration 11 the best fitness is 0.1019730661860139']
# ['At iteration 12 the best fitness is 0.1019730661860139']
# ['At iteration 13 the best fitness is 0.1019730661860139']
# ['At iteration 14 the best fitness is 0.1019730661860139']
# ['At iteration 15 the best fitness is 0.1019730661860139']
# ['At iteration 16 the best fitness is 0.1019730661860139']
# ['At iteration 17 the best fitness is 0.1019730661860139']
# ['At iteration 18 the best fitness is 0.1019730661860139']
# ['At iteration 19 the best fitness is 0.1019730661860139']
# ['At iteration 20 the best fitness is 0.1019730661860139']
# ['At iteration 21 the best fitness is 0.1019730661860139']
# ['At iteration 22 the best fitness is 0.1019730661860139']
# ['At iteration 23 the best fitness is 0.1019730661860139']
# ['At iteration 24 the best fitness is 0.1019730661860139']
# ['At iteration 25 the best fitness is 0.1019730661860139']
# ['At iteration 26 the best fitness is 0.1019730661860139']
# ['At iteration 27 the best fitness is 0.10194020387907995']
# ['At iteration 28 the best fitness is 0.10194020387907995']
# ['At iteration 29 the best fitness is 0.10194020387907995']
#       Selected: 1532/3043 (50.3%), Fitness: 0.1019, Time: 1866.8s
#       Modality: D=50%, S=51%, Sk=50%,
#     Test Acc: 82.57%, F1: 82.23%, Features: 1532/3043 (50.3%), Model: 3.528MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1349345409401275']
# ['At iteration 10 the best fitness is 0.11582477751554315']
# ['At iteration 20 the best fitness is 0.11582477751554315']
#       Selected: 1559/3043 (51.2%), Fitness: 0.1072, Time: 3910.7s
#       Modality: D=47%, S=52%, Sk=52%,
#     Test Acc: 79.67%, F1: 79.40%, Features: 1559/3043 (51.2%), Model: 3.581MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1260451209432478']
# ['At iteration 2 the best fitness is 0.1260451209432478']
# ['At iteration 3 the best fitness is 0.1260451209432478']
# ['At iteration 4 the best fitness is 0.1260451209432478']
# ['At iteration 5 the best fitness is 0.1260451209432478']
# ['At iteration 6 the best fitness is 0.1260451209432478']
# ['At iteration 7 the best fitness is 0.12561791095310648']
# ['At iteration 8 the best fitness is 0.12561791095310648']
# ['At iteration 9 the best fitness is 0.12077063769472575']
# ['At iteration 10 the best fitness is 0.12077063769472575']
# ['At iteration 11 the best fitness is 0.11628484981261841']
# ['At iteration 12 the best fitness is 0.11628484981261841']
# ['At iteration 13 the best fitness is 0.11628484981261841']
# ['At iteration 14 the best fitness is 0.11628484981261841']
# ['At iteration 15 the best fitness is 0.11628484981261841']
# ['At iteration 16 the best fitness is 0.11628484981261841']
# ['At iteration 17 the best fitness is 0.11628484981261841']
# ['At iteration 18 the best fitness is 0.11628484981261841']
# ['At iteration 19 the best fitness is 0.11628484981261841']
# ['At iteration 20 the best fitness is 0.11628484981261841']
# ['At iteration 21 the best fitness is 0.10138154466120286']
# ['At iteration 22 the best fitness is 0.10138154466120286']
# ['At iteration 23 the best fitness is 0.10138154466120286']
# ['At iteration 24 the best fitness is 0.10138154466120286']
# ['At iteration 25 the best fitness is 0.10138154466120286']
# ['At iteration 26 the best fitness is 0.10138154466120286']
# ['At iteration 27 the best fitness is 0.10138154466120286']
# ['At iteration 28 the best fitness is 0.10138154466120286']
# ['At iteration 29 the best fitness is 0.10138154466120286']
# ['At iteration 30 the best fitness is 0.10138154466120286']
#       Selected: 1498/3043 (49.2%), Fitness: 0.1014, Time: 2092.1s
#       Modality: D=50%, S=52%, Sk=48%,
#     Test Acc: 85.06%, F1: 85.04%, Features: 1498/3043 (49.2%), Model: 3.462MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.14029117995598442']
# ['At iteration 1 the best fitness is 0.13513171478173117']
# ['At iteration 2 the best fitness is 0.13066235805309093']
# ['At iteration 3 the best fitness is 0.09732296676923693']
# ['At iteration 4 the best fitness is 0.11584120866901013']
# ['At iteration 5 the best fitness is 0.10634383599385243']
# ['At iteration 6 the best fitness is 0.11593979558981198']
# ['At iteration 7 the best fitness is 0.11132255847996896']
# ['At iteration 8 the best fitness is 0.09222922620885159']
# ['At iteration 9 the best fitness is 0.10198949733948087']
# ['At iteration 10 the best fitness is 0.1066724590631919']
# ['At iteration 11 the best fitness is 0.1066724590631919']
# ['At iteration 12 the best fitness is 0.11621912519875052']
# ['At iteration 13 the best fitness is 0.1114211454007708']
# ['At iteration 14 the best fitness is 0.10662316560279098']
# ['At iteration 15 the best fitness is 0.10180875465134417']
# ['At iteration 16 the best fitness is 0.09707649946723233']
# ['At iteration 17 the best fitness is 0.11147043886117172']
# ['At iteration 18 the best fitness is 0.11145400770770475']
# ['At iteration 19 the best fitness is 0.10665602790972492']
# ['At iteration 20 the best fitness is 0.106606734449324']
# ['At iteration 21 the best fitness is 0.09702720600683142']
# ['At iteration 22 the best fitness is 0.11143757655423778']
# ['At iteration 23 the best fitness is 0.10665602790972492']
# ['At iteration 24 the best fitness is 0.10663959675625795']
# ['At iteration 25 the best fitness is 0.11145400770770475']
# ['At iteration 26 the best fitness is 0.10665602790972492']
# ['At iteration 27 the best fitness is 0.11145400770770475']
# ['At iteration 28 the best fitness is 0.11145400770770475']
# ['At iteration 29 the best fitness is 0.11625198750568447']
#       Selected: 1527/3043 (50.2%), Fitness: 0.1163, Time: 1977.6s
#       Modality: D=49%, S=51%, Sk=50%,
#     Test Acc: 80.91%, F1: 80.88%, Features: 1527/3043 (50.2%), Model: 3.519MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.13590397899467893
# At iteration 2 the best fitness is 0.12622586363138452
# At iteration 3 the best fitness is 0.12645589977992214
# At iteration 4 the best fitness is 0.12142788383340468
# At iteration 5 the best fitness is 0.12111569191753219
# At iteration 6 the best fitness is 0.10724754943453596
# At iteration 7 the best fitness is 0.1262915882452524
# At iteration 8 the best fitness is 0.12571649787390834
# At iteration 9 the best fitness is 0.12050773923925417
# At iteration 10 the best fitness is 0.12100067384326338
# At iteration 11 the best fitness is 0.12640660631952122
# At iteration 12 the best fitness is 0.12101710499673035
# At iteration 13 the best fitness is 0.12570006672044137
# At iteration 14 the best fitness is 0.1161041071244817
# At iteration 15 the best fitness is 0.12111569191753219
# At iteration 16 the best fitness is 0.11102679771756344
# At iteration 17 the best fitness is 0.1209185180759285
# At iteration 18 the best fitness is 0.12571649787390834
# At iteration 19 the best fitness is 0.13051447767188817
# At iteration 20 the best fitness is 0.11648202365422208
# At iteration 21 the best fitness is 0.11625198750568447
# At iteration 22 the best fitness is 0.1165970417284909
# At iteration 23 the best fitness is 0.12563434210657348
# At iteration 24 the best fitness is 0.12581508479471018
# At iteration 25 the best fitness is 0.11598908905021289
# At iteration 26 the best fitness is 0.11605481366408078
# At iteration 27 the best fitness is 0.12553575518577162
# At iteration 28 the best fitness is 0.11138828309383686
# At iteration 29 the best fitness is 0.11138828309383686
# At iteration 30 the best fitness is 0.13069522036002487
#       Selected: 1530/3043 (50.3%), Fitness: 0.1307, Time: 1976.7s
#       Modality: D=52%, S=55%, Sk=48%,
#     Test Acc: 81.74%, F1: 81.70%, Features: 1530/3043 (50.3%), Model: 3.525MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1451713155212991']
# ['At iteration 1 the best fitness is 0.12898638039945964']
# ['At iteration 2 the best fitness is 0.12898638039945964']
# ['At iteration 3 the best fitness is 0.127524007740899']
# ['At iteration 4 the best fitness is 0.12689962390915402']
# ['At iteration 5 the best fitness is 0.10249894608258066']
# ['At iteration 6 the best fitness is 0.10249894608258066']
# ['At iteration 7 the best fitness is 0.10249894608258066']
# ['At iteration 8 the best fitness is 0.10249894608258066']
# ['At iteration 9 the best fitness is 0.10249894608258066']
# ['At iteration 10 the best fitness is 0.10249894608258066']
# ['At iteration 11 the best fitness is 0.10249894608258066']
# ['At iteration 12 the best fitness is 0.10249894608258066']
# ['At iteration 13 the best fitness is 0.10249894608258066']
# ['At iteration 14 the best fitness is 0.10249894608258066']
# ['At iteration 15 the best fitness is 0.10249894608258066']
# ['At iteration 16 the best fitness is 0.10083939958241633']
# ['At iteration 17 the best fitness is 0.10083939958241633']
# ['At iteration 18 the best fitness is 0.10083939958241633']
# ['At iteration 19 the best fitness is 0.10083939958241633']
# ['At iteration 20 the best fitness is 0.10083939958241633']
# ['At iteration 21 the best fitness is 0.10083939958241633']
# ['At iteration 22 the best fitness is 0.08688910133208523']
# ['At iteration 23 the best fitness is 0.08688910133208523']
# ['At iteration 24 the best fitness is 0.08688910133208523']
# ['At iteration 25 the best fitness is 0.08688910133208523']
# ['At iteration 26 the best fitness is 0.08688910133208523']
# ['At iteration 27 the best fitness is 0.08688910133208523']
# ['At iteration 28 the best fitness is 0.08688910133208523']
# ['At iteration 29 the best fitness is 0.08688910133208523']
#       Selected: 1200/3043 (39.4%), Fitness: 0.0869, Time: 1924.5s
#       Modality: D=38%, S=39%, Sk=40%,
#     Test Acc: 79.67%, F1: 79.95%, Features: 1200/3043 (39.4%), Model: 2.880MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.13077737612735973']
# ['At iteration 1 the best fitness is 0.13077737612735973']
# ['At iteration 2 the best fitness is 0.13077737612735973']
# ['At iteration 3 the best fitness is 0.13077737612735973']
# ['At iteration 4 the best fitness is 0.13077737612735973']
# ['At iteration 5 the best fitness is 0.12445129905695139']
# ['At iteration 6 the best fitness is 0.12445129905695139']
# ['At iteration 7 the best fitness is 0.12445129905695139']
# ['At iteration 8 the best fitness is 0.12445129905695139']
# ['At iteration 9 the best fitness is 0.12445129905695139']
# ['At iteration 10 the best fitness is 0.11897964196682564']
# ['At iteration 11 the best fitness is 0.11654774826808999']
# ['At iteration 12 the best fitness is 0.11654774826808999']
# ['At iteration 13 the best fitness is 0.11654774826808999']
# ['At iteration 14 the best fitness is 0.11654774826808999']
# ['At iteration 15 the best fitness is 0.11654774826808999']
# ['At iteration 16 the best fitness is 0.11654774826808999']
# ['At iteration 17 the best fitness is 0.11654774826808999']
# ['At iteration 18 the best fitness is 0.11654774826808999']
# ['At iteration 19 the best fitness is 0.11419809332231279']
# ['At iteration 20 the best fitness is 0.11419809332231279']
# ['At iteration 21 the best fitness is 0.11419809332231279']
# ['At iteration 22 the best fitness is 0.11419809332231279']
# ['At iteration 23 the best fitness is 0.11419809332231279']
# ['At iteration 24 the best fitness is 0.11419809332231279']
# ['At iteration 25 the best fitness is 0.11419809332231279']
# ['At iteration 26 the best fitness is 0.11419809332231279']
# ['At iteration 27 the best fitness is 0.11419809332231279']
# ['At iteration 28 the best fitness is 0.11419809332231279']
# ['At iteration 29 the best fitness is 0.11419809332231279']
#       Selected: 1402/3043 (46.1%), Fitness: 0.1142, Time: 2772.8s
#       Modality: D=42%, S=48%, Sk=47%,
#     Test Acc: 79.25%, F1: 78.52%, Features: 1402/3043 (46.1%), Model: 3.275MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13118815496403408']
# ['At iteration 1 the best fitness is 0.1109282107967616']
# ['At iteration 2 the best fitness is 0.1109282107967616']
# ['At iteration 3 the best fitness is 0.1109282107967616']
# ['At iteration 4 the best fitness is 0.1109282107967616']
# ['At iteration 5 the best fitness is 0.1109282107967616']
# ['At iteration 6 the best fitness is 0.1109282107967616']
# ['At iteration 7 the best fitness is 0.1109282107967616']
# ['At iteration 8 the best fitness is 0.1109282107967616']
# ['At iteration 9 the best fitness is 0.1109282107967616']
# ['At iteration 10 the best fitness is 0.1109282107967616']
# ['At iteration 11 the best fitness is 0.1109282107967616']
# ['At iteration 12 the best fitness is 0.1109282107967616']
# ['At iteration 13 the best fitness is 0.1109282107967616']
# ['At iteration 14 the best fitness is 0.1109282107967616']
# ['At iteration 15 the best fitness is 0.1109282107967616']
# ['At iteration 16 the best fitness is 0.1109282107967616']
# ['At iteration 17 the best fitness is 0.1109282107967616']
# ['At iteration 18 the best fitness is 0.1109282107967616']
# ['At iteration 19 the best fitness is 0.1109282107967616']
# ['At iteration 20 the best fitness is 0.1109282107967616']
# ['At iteration 21 the best fitness is 0.1109282107967616']
# ['At iteration 22 the best fitness is 0.1109282107967616']
# ['At iteration 23 the best fitness is 0.1109282107967616']
# ['At iteration 24 the best fitness is 0.1109282107967616']
# ['At iteration 25 the best fitness is 0.1109282107967616']
# ['At iteration 26 the best fitness is 0.1109282107967616']
# ['At iteration 27 the best fitness is 0.1109282107967616']
# ['At iteration 28 the best fitness is 0.1109282107967616']
# ['At iteration 29 the best fitness is 0.1109282107967616']
#       Selected: 1495/3043 (49.1%), Fitness: 0.1109, Time: 2069.1s
#       Modality: D=48%, S=52%, Sk=48%,
#     Test Acc: 84.65%, F1: 84.11%, Features: 1495/3043 (49.1%), Model: 3.456MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.12599582748284688']
# ['At iteration 2 the best fitness is 0.12599582748284688']
# ['At iteration 3 the best fitness is 0.12596296517591293']
# ['At iteration 4 the best fitness is 0.12596296517591293']
# ['At iteration 5 the best fitness is 0.12596296517591293']
# ['At iteration 6 the best fitness is 0.12596296517591293']
# ['At iteration 7 the best fitness is 0.11189764885131302']
# ['At iteration 8 the best fitness is 0.11189764885131302']
# ['At iteration 9 the best fitness is 0.11189764885131302']
# ['At iteration 10 the best fitness is 0.1075926036573424']
# ['At iteration 11 the best fitness is 0.1075926036573424']
# ['At iteration 12 the best fitness is 0.1075926036573424']
# ['At iteration 13 the best fitness is 0.1075926036573424']
# ['At iteration 14 the best fitness is 0.1075926036573424']
# ['At iteration 15 the best fitness is 0.1075926036573424']
# ['At iteration 16 the best fitness is 0.1075926036573424']
# ['At iteration 17 the best fitness is 0.1075926036573424']
# ['At iteration 18 the best fitness is 0.1075926036573424']
# ['At iteration 19 the best fitness is 0.1075926036573424']
# ['At iteration 20 the best fitness is 0.1075926036573424']
# ['At iteration 21 the best fitness is 0.1075926036573424']
# ['At iteration 22 the best fitness is 0.1075926036573424']
# ['At iteration 23 the best fitness is 0.1075926036573424']
# ['At iteration 24 the best fitness is 0.1075926036573424']
# ['At iteration 25 the best fitness is 0.1075926036573424']
# ['At iteration 26 the best fitness is 0.1075926036573424']
# ['At iteration 27 the best fitness is 0.1075926036573424']
# ['At iteration 28 the best fitness is 0.1075926036573424']
# ['At iteration 29 the best fitness is 0.1075926036573424']
#       Selected: 1584/3043 (52.1%), Fitness: 0.1076, Time: 1928.6s
#       Modality: D=53%, S=51%, Sk=52%,
#     Test Acc: 82.99%, F1: 82.26%, Features: 1584/3043 (52.1%), Model: 3.630MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.149246324566732']
# ['At iteration 2 the best fitness is 0.14538492051636975']
# ...
# ['At iteration 13 the best fitness is 0.15487759813353']
# ['At iteration 14 the best fitness is 0.1508535336525022']
# ['At iteration 15 the best fitness is 0.1508535336525022']
# ['At iteration 16 the best fitness is 0.1508535336525022']
# ['At iteration 17 the best fitness is 0.1508535336525022']
# ['At iteration 18 the best fitness is 0.1508535336525022']
# ['At iteration 19 the best fitness is 0.1508535336525022']
# ['At iteration 20 the best fitness is 0.1508535336525022']
# ['At iteration 21 the best fitness is 0.1508535336525022']
# ['At iteration 22 the best fitness is 0.1508535336525022']
# ['At iteration 23 the best fitness is 0.1508535336525022']
# ['At iteration 24 the best fitness is 0.1508535336525022']
# ['At iteration 25 the best fitness is 0.1508535336525022']
# ['At iteration 26 the best fitness is 0.1508535336525022']
# ['At iteration 27 the best fitness is 0.1508535336525022']
# ['At iteration 28 the best fitness is 0.1508535336525022']
# ['At iteration 29 the best fitness is 0.1508535336525022']
#       Selected: 1504/3043 (49.4%), Fitness: 0.1509, Time: 2611.5s
#       Modality: D=49%, S=48%, Sk=50%,
#     Test Acc: 80.30%, F1: 77.55%, Features: 1504/3043 (49.4%), Model: 3.474MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.15072208442476642']
# ['At iteration 1 the best fitness is 0.15072208442476642']
# ['At iteration 2 the best fitness is 0.13459296419372127']
# ['At iteration 3 the best fitness is 0.13459296419372127']
# ['At iteration 4 the best fitness is 0.13459296419372127']
# ['At iteration 5 the best fitness is 0.13459296419372127']
# ['At iteration 6 the best fitness is 0.13459296419372127']
# ['At iteration 7 the best fitness is 0.13459296419372127']
# ['At iteration 8 the best fitness is 0.13459296419372127']
# ['At iteration 9 the best fitness is 0.13459296419372127']
# ['At iteration 10 the best fitness is 0.13459296419372127']
# ['At iteration 11 the best fitness is 0.13459296419372127']
# ['At iteration 12 the best fitness is 0.13459296419372127']
# ['At iteration 13 the best fitness is 0.13459296419372127']
# ['At iteration 14 the best fitness is 0.13459296419372127']
# ['At iteration 15 the best fitness is 0.13459296419372127']
# ['At iteration 16 the best fitness is 0.13056889971269348']
# ['At iteration 17 the best fitness is 0.13056889971269348']
# ['At iteration 18 the best fitness is 0.13056889971269348']
# ['At iteration 19 the best fitness is 0.13056889971269348']
# ['At iteration 20 the best fitness is 0.13056889971269348']
# ['At iteration 21 the best fitness is 0.13056889971269348']
# ['At iteration 22 the best fitness is 0.13056889971269348']
# ['At iteration 23 the best fitness is 0.13056889971269348']
# ['At iteration 24 the best fitness is 0.13056889971269348']
# ['At iteration 25 the best fitness is 0.13056889971269348']
# ['At iteration 26 the best fitness is 0.13056889971269348']
# ['At iteration 27 the best fitness is 0.1264626794643307']
# ['At iteration 28 the best fitness is 0.1264626794643307']
# ['At iteration 29 the best fitness is 0.1264626794643307']
#       Selected: 1459/3043 (47.9%), Fitness: 0.1265, Time: 1947.0s
#       Modality: D=46%, S=48%, Sk=48%,
#     Test Acc: 77.78%, F1: 76.81%, Features: 1459/3043 (47.9%), Model: 3.386MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.15517335889593553']
# ['At iteration 2 the best fitness is 0.15517335889593553']
# ['At iteration 3 the best fitness is 0.14339692621525765']
# ['At iteration 4 the best fitness is 0.14339692621525765']
# ['At iteration 5 the best fitness is 0.14339692621525765']
# ['At iteration 6 the best fitness is 0.14339692621525765']
# ['At iteration 7 the best fitness is 0.14339692621525765']
# ['At iteration 8 the best fitness is 0.14339692621525765']
# ['At iteration 9 the best fitness is 0.14339692621525765']
# ['At iteration 10 the best fitness is 0.14339692621525765']
# ['At iteration 11 the best fitness is 0.14339692621525765']
# ['At iteration 12 the best fitness is 0.1361867860800177']
# ['At iteration 13 the best fitness is 0.1361867860800177']
# ['At iteration 14 the best fitness is 0.1361867860800177']
# ['At iteration 15 the best fitness is 0.1361867860800177']
# ['At iteration 16 the best fitness is 0.1361867860800177']
# ['At iteration 17 the best fitness is 0.13211342813858898']
# ['At iteration 18 the best fitness is 0.12808936365756107']
# ['At iteration 19 the best fitness is 0.12808936365756107']
# ['At iteration 20 the best fitness is 0.12725137483074542']
# ['At iteration 21 the best fitness is 0.12725137483074542']
# ['At iteration 22 the best fitness is 0.1241145926369342']
# ['At iteration 23 the best fitness is 0.12399957456266537']
# ['At iteration 24 the best fitness is 0.12399957456266537']
# ['At iteration 25 the best fitness is 0.12399957456266537']
# ['At iteration 26 the best fitness is 0.12399957456266537']
# ['At iteration 27 the best fitness is 0.11990978546776968']
# ['At iteration 28 the best fitness is 0.11990978546776968']
# ['At iteration 29 the best fitness is 0.11990978546776968']
#       Selected: 1540/3043 (50.6%), Fitness: 0.1199, Time: 1832.7s
#       Modality: D=52%, S=52%, Sk=50%,
#     Test Acc: 87.88%, F1: 87.61%, Features: 1540/3043 (50.6%), Model: 3.544MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1389785140510225']
# ['At iteration 2 the best fitness is 0.1389785140510225']
# ['At iteration 3 the best fitness is 0.1389785140510225']
# ['At iteration 4 the best fitness is 0.1389785140510225']
# ['At iteration 5 the best fitness is 0.13822268099154172']
# ['At iteration 6 the best fitness is 0.13822268099154172']
# ['At iteration 7 the best fitness is 0.13822268099154172']
# ['At iteration 8 the best fitness is 0.13822268099154172']
# ['At iteration 9 the best fitness is 0.1266434221524674']
# ['At iteration 10 the best fitness is 0.12647911061779768']
# ['At iteration 11 the best fitness is 0.12647911061779768']
# ['At iteration 12 the best fitness is 0.12647911061779768']
# ['At iteration 13 the best fitness is 0.12647911061779768']
# ['At iteration 14 the best fitness is 0.12647911061779768']
# ['At iteration 15 the best fitness is 0.12647911061779768']
# ['At iteration 16 the best fitness is 0.12647911061779768']
# ['At iteration 17 the best fitness is 0.12647911061779768']
# ['At iteration 18 the best fitness is 0.12647911061779768']
# ['At iteration 19 the best fitness is 0.12647911061779768']
# ['At iteration 20 the best fitness is 0.12647911061779768']
# ['At iteration 21 the best fitness is 0.12647911061779768']
# ['At iteration 22 the best fitness is 0.12647911061779768']
# ['At iteration 23 the best fitness is 0.12647911061779768']
# ['At iteration 24 the best fitness is 0.12647911061779768']
# ['At iteration 25 the best fitness is 0.12647911061779768']
# ['At iteration 26 the best fitness is 0.12647911061779768']
# ['At iteration 27 the best fitness is 0.12647911061779768']
# ['At iteration 28 the best fitness is 0.12647911061779768']
# ['At iteration 29 the best fitness is 0.12647911061779768']
# ['At iteration 30 the best fitness is 0.12647911061779768']
#       Selected: 1460/3043 (48.0%), Fitness: 0.1265, Time: 1862.1s
#       Modality: D=49%, S=49%, Sk=47%,
#     Test Acc: 86.36%, F1: 85.54%, Features: 1460/3043 (48.0%), Model: 3.388MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.15477901121272816']
# ['At iteration 2 the best fitness is 0.1465994330229368']
# ['At iteration 3 the best fitness is 0.1426903866161778']
# ['At iteration 4 the best fitness is 0.13051960625229256']
# ['At iteration 5 the best fitness is 0.13051960625229256']
# ['At iteration 6 the best fitness is 0.13051960625229256']
# ['At iteration 7 the best fitness is 0.13051960625229256']
# ['At iteration 8 the best fitness is 0.13051960625229256']
# ['At iteration 9 the best fitness is 0.13051960625229256']
# ['At iteration 10 the best fitness is 0.13051960625229256']
# ['At iteration 11 the best fitness is 0.13051960625229256']
# ['At iteration 12 the best fitness is 0.13051960625229256']
# ['At iteration 13 the best fitness is 0.13051960625229256']
# ['At iteration 14 the best fitness is 0.13051960625229256']
# ['At iteration 15 the best fitness is 0.13051960625229256']
# ['At iteration 16 the best fitness is 0.13051960625229256']
# ['At iteration 17 the best fitness is 0.13051960625229256']
# ['At iteration 18 the best fitness is 0.12662699099900043']
# ['At iteration 19 the best fitness is 0.12662699099900043']
# ['At iteration 20 the best fitness is 0.12662699099900043']
# ['At iteration 21 the best fitness is 0.12662699099900043']
# ['At iteration 22 the best fitness is 0.12662699099900043']
# ['At iteration 23 the best fitness is 0.12662699099900043']
# ['At iteration 24 the best fitness is 0.12662699099900043']
# ['At iteration 25 the best fitness is 0.12662699099900043']
# ['At iteration 26 the best fitness is 0.12662699099900043']
# ['At iteration 27 the best fitness is 0.12662699099900043']
# ['At iteration 28 the best fitness is 0.12662699099900043']
# ['At iteration 29 the best fitness is 0.12662699099900043']
# ['At iteration 30 the best fitness is 0.12662699099900043']
#       Selected: 1469/3043 (48.3%), Fitness: 0.1266, Time: 1884.3s
#       Modality: D=49%, S=48%, Sk=48%,
#     Test Acc: 83.33%, F1: 81.69%, Features: 1469/3043 (48.3%), Model: 3.405MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.14306830314591817']
# ['At iteration 1 the best fitness is 0.14306830314591817']
# ['At iteration 2 the best fitness is 0.13703963794191965']
# ['At iteration 3 the best fitness is 0.13703963794191965']
# ['At iteration 4 the best fitness is 0.13703963794191965']
# ['At iteration 5 the best fitness is 0.13703963794191965']
# ['At iteration 6 the best fitness is 0.13703963794191965']
# ['At iteration 7 the best fitness is 0.13703963794191965']
# ['At iteration 8 the best fitness is 0.11006752454105263']
# ['At iteration 9 the best fitness is 0.11006752454105263']
# ['At iteration 10 the best fitness is 0.11006752454105263']
# ['At iteration 11 the best fitness is 0.11006752454105263']
# ['At iteration 12 the best fitness is 0.11006752454105263']
# ['At iteration 13 the best fitness is 0.11006752454105263']
# ['At iteration 14 the best fitness is 0.11006752454105263']
# ['At iteration 15 the best fitness is 0.11006752454105263']
# ['At iteration 16 the best fitness is 0.11006752454105263']
# ['At iteration 17 the best fitness is 0.11006752454105263']
# ['At iteration 18 the best fitness is 0.11006752454105263']
# ['At iteration 19 the best fitness is 0.11006752454105263']
# ['At iteration 20 the best fitness is 0.11006752454105263']
# ['At iteration 21 the best fitness is 0.11006752454105263']
# ['At iteration 22 the best fitness is 0.11006752454105263']
# ['At iteration 23 the best fitness is 0.11006752454105263']
# ['At iteration 24 the best fitness is 0.11006752454105263']
# ['At iteration 25 the best fitness is 0.11006752454105263']
# ['At iteration 26 the best fitness is 0.11006752454105263']
# ['At iteration 27 the best fitness is 0.11006752454105263']
# ['At iteration 28 the best fitness is 0.11006752454105263']
# ['At iteration 29 the best fitness is 0.11006752454105263']
#       Selected: 941/3043 (30.9%), Fitness: 0.1101, Time: 1840.3s
#       Modality: D=30%, S=32%, Sk=31%,
#     Test Acc: 85.35%, F1: 84.46%, Features: 941/3043 (30.9%), Model: 2.374MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1352666414858672']
# ['At iteration 2 the best fitness is 0.1352666414858672']
# ['At iteration 3 the best fitness is 0.1352666414858672']
# ['At iteration 4 the best fitness is 0.1352666414858672']
# ['At iteration 5 the best fitness is 0.1352666414858672']
# ['At iteration 6 the best fitness is 0.1352666414858672']
# ['At iteration 7 the best fitness is 0.1352666414858672']
# ['At iteration 8 the best fitness is 0.1352666414858672']
# ['At iteration 9 the best fitness is 0.1352666414858672']
# ['At iteration 10 the best fitness is 0.1352666414858672']
# ['At iteration 11 the best fitness is 0.1352666414858672']
# ['At iteration 12 the best fitness is 0.1310454031632357']
# ['At iteration 13 the best fitness is 0.1310454031632357']
# ['At iteration 14 the best fitness is 0.1310454031632357']
# ['At iteration 15 the best fitness is 0.1310454031632357']
# ['At iteration 16 the best fitness is 0.1310454031632357']
# ['At iteration 17 the best fitness is 0.1310454031632357']
# ['At iteration 18 the best fitness is 0.1310454031632357']
# ['At iteration 19 the best fitness is 0.1310454031632357']
# ['At iteration 20 the best fitness is 0.1310454031632357']
# ['At iteration 21 the best fitness is 0.1310454031632357']
# ['At iteration 22 the best fitness is 0.1310454031632357']
# ['At iteration 23 the best fitness is 0.1310454031632357']
# ['At iteration 24 the best fitness is 0.12345734649825525']
# ['At iteration 25 the best fitness is 0.12345734649825525']
# ['At iteration 26 the best fitness is 0.12345734649825525']
# ['At iteration 27 the best fitness is 0.12345734649825525']
# ['At iteration 28 the best fitness is 0.12345734649825525']
# ['At iteration 29 the best fitness is 0.12345734649825525']
#       Selected: 1516/3043 (49.8%), Fitness: 0.1235, Time: 3998.9s
#       Modality: D=51%, S=50%, Sk=50%,
#     Test Acc: 84.85%, F1: 84.42%, Features: 1516/3043 (49.8%), Model: 3.497MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13541452186706995']
# ['At iteration 1 the best fitness is 0.13541452186706995']
# ['At iteration 2 the best fitness is 0.13541452186706995']
# ['At iteration 3 the best fitness is 0.13541452186706995']
# ['At iteration 4 the best fitness is 0.13541452186706995']
# ['At iteration 5 the best fitness is 0.13541452186706995']
# ['At iteration 6 the best fitness is 0.13541452186706995']
# ['At iteration 7 the best fitness is 0.1309350894441088']
# ['At iteration 8 the best fitness is 0.1309350894441088']
# ['At iteration 9 the best fitness is 0.1309350894441088']
# ['At iteration 10 the best fitness is 0.1309350894441088']
# ['At iteration 11 the best fitness is 0.1309350894441088']
# ['At iteration 12 the best fitness is 0.1309350894441088']
# ['At iteration 13 the best fitness is 0.1309350894441088']
# ['At iteration 14 the best fitness is 0.1309350894441088']
# ['At iteration 15 the best fitness is 0.1309350894441088']
# ['At iteration 16 the best fitness is 0.1309350894441088']
# ['At iteration 17 the best fitness is 0.1309350894441088']
# ['At iteration 18 the best fitness is 0.1309350894441088']
# ['At iteration 19 the best fitness is 0.1309350894441088']
# ['At iteration 20 the best fitness is 0.1309350894441088']
# ['At iteration 21 the best fitness is 0.1309350894441088']
# ['At iteration 22 the best fitness is 0.1309350894441088']
# ['At iteration 23 the best fitness is 0.1309350894441088']
# ['At iteration 24 the best fitness is 0.1309350894441088']
# ['At iteration 25 the best fitness is 0.1309350894441088']
# ['At iteration 26 the best fitness is 0.1309350894441088']
# ['At iteration 27 the best fitness is 0.1309350894441088']
# ['At iteration 28 the best fitness is 0.1309350894441088']
# ['At iteration 29 the best fitness is 0.1309350894441088']
#       Selected: 2211/3043 (72.7%), Fitness: 0.1309, Time: 1064.6s
#       Modality: D=73%, S=74%, Sk=72%,
#     Test Acc: 83.84%, F1: 82.02%, Features: 2211/3043 (72.7%), Model: 4.855MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879}, Total: 3043
# Results table: (90, 32)
# Methods: 18, Folds per method: {'baseline': 5, 'lasso': 5, 'meta_BAT': 5, 'meta_CS': 5, 'meta_DE': 5, 'meta_FFA': 5, 'meta_GA': 5, 'meta_GWO': 5, 'meta_HHO': 5, 'meta_JAYA': 5, 'meta_MFO': 5, 'meta_MVO': 5, 'meta_PSO': 5, 'meta_SCA': 5, 'meta_SSA': 5, 'meta_WOA': 5, 'mutual_info': 5, 'rfe': 5}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          73.776224         90.909091     74.032714
# 1  baseline     2          81.327801         89.898990     80.959173
# 2  baseline     3          80.454545         88.383838     79.778442
# 3  baseline     4          75.000000         91.919192     73.717494
# 4  baseline     5          88.888889         87.136929     88.153641
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        74.032714            78.899575         73.776224               3043
# 1        80.902004            83.034428         81.363636               3043
# 2        79.778442            82.865578         80.454545               3043
# 3        73.717494            77.805667         75.000000               3043
# 4        88.153641            90.822473         88.888889               3043
#
#    Features Total  ...  N Test  depth_retained  depth_total  \
# 0            3043  ...     286             512          512
# 1            3043  ...     241             512          512
# 2            3043  ...     220             512          512
# 3            3043  ...     220             512          512
# 4            3043  ...     198             512          512
#
#    depth_retention_%  sensor_retained  sensor_total  sensor_retention_%  \
# 0              100.0              652           652               100.0
# 1              100.0              652           652               100.0
# 2              100.0              652           652               100.0
# 3              100.0              652           652               100.0
# 4              100.0              652           652               100.0
#
#    skeleton_retained  skeleton_total  skeleton_retention_%
# 0               1879            1879                 100.0
# 1               1879            1879                 100.0
# 2               1879            1879                 100.0
# 3               1879            1879                 100.0
# 4               1879            1879                 100.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              79.89              6.01              79.33              5.92                  3043.0                      100.00              0.00                36.44                36.44          1697046.0                  6.48                        0.00               56.48
# mutual_info              83.07              5.37              82.31              5.49                  1521.0                       49.98             39.16                31.82                70.98           917782.0                  3.51                       50.02               38.46
#         rfe              82.32              5.28              81.18              5.62                  1521.0                       49.98              8.30                31.00                39.30           917782.0                  3.51                       50.02               38.46
#       lasso              39.21              5.50              37.82              5.37                  1521.0                       49.98            248.05                26.98               275.03           917782.0                  3.51                       50.02               38.46
#    meta_BAT              78.28              4.49              77.91              4.63                  1509.4                       49.60           1939.84                30.85              1970.69           911842.8                  3.48                       50.40               38.43
#     meta_CS              79.14              5.54              78.80              5.89                  1524.6                       50.10           3856.20                31.14              3887.34           919625.2                  3.51                       49.90               38.55
#     meta_DE              80.79              6.95              80.59              7.01                  1526.4                       50.16           2002.63                32.94              2035.57           920546.8                  3.52                       49.84               38.60
#    meta_FFA              77.87              3.63              77.32              4.10                  1509.8                       49.62           1990.19                32.45              2022.64           912047.6                  3.49                       50.38               38.44
#     meta_GA              80.41              5.41              80.01              6.10                  1516.4                       49.83           1983.38                32.08              2015.46           915426.8                  3.50                       50.17               38.47
#    meta_GWO              80.47              4.62              80.06              5.17                  1231.2                       40.46           1913.51                31.17              1944.68           769404.4                  2.94                       59.54               35.79
#    meta_HHO              77.93              2.77              77.00              2.71                  1483.6                       48.75           2700.13                32.37              2732.50           898633.2                  3.43                       51.25               39.05
#   meta_JAYA              79.90              4.50              78.91              5.55                  1519.2                       49.92           2013.39                31.79              2045.18           916860.4                  3.50                       50.08               38.58
#    meta_MFO              81.80              5.15              81.46              5.45                  1577.2                       51.83           1877.05                31.86              1908.91           946556.4                  3.62                       48.17               39.13
#    meta_MVO              81.00              4.04              80.55              4.33                  1494.6                       49.12           1936.55                31.41              1967.96           904265.2                  3.46                       50.88               38.36
#    meta_PSO              79.11              3.28              78.12              3.80                  1514.2                       49.76           1897.85                30.98              1928.83           914300.4                  3.49                       50.24               38.49
#    meta_SCA              75.85              7.40              75.22              7.68                   793.6                       26.08           1817.23                29.31              1846.54           545353.2                  2.09                       73.92               30.27
#    meta_SSA              80.99              3.14              80.21              3.72                  1527.8                       50.21           4584.37                28.13              4612.51           921263.6                  3.52                       49.79               38.56
#    meta_WOA              80.22              3.99              79.40              4.42                  1484.4                       48.78           1672.80                29.23              1702.03           899042.8                  3.44                       51.22               38.25

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# C:\Users\aruay.amangeldi\AppData\Local\Temp\ipykernel_30596\2859632419.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# c:\Users\aruay.amangeldi\Desktop\mhar-feature-selection\.venv\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# C:\Users\aruay.amangeldi\AppData\Local\Temp\ipykernel_30596\514708896.py:16: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
# C:\Users\aruay.amangeldi\AppData\Local\Temp\ipykernel_30596\514708896.py:27: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
# C:\Users\aruay.amangeldi\AppData\Local\Temp\ipykernel_30596\514708896.py:38: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_JAYA
#     F1 Macro:           82.82%
#     F1 Weighted:        82.82%
#     Test Accuracy:      82.52%
#     Feature Retention:  50.15% (1526/3043)
#     Modality Retention: depth=53.5%, sensor=50.2%, skeleton=49.2%
#
#   Fold 2: Best = meta_DE
#     F1 Macro:           85.04%
#     F1 Weighted:        85.00%
#     Test Accuracy:      85.06%
#     Feature Retention:  49.23% (1498/3043)
#     Modality Retention: depth=50.2%, sensor=52.3%, skeleton=47.9%
#
#   Fold 3: Best = meta_MFO
#     F1 Macro:           84.59%
#     F1 Weighted:        84.59%
#     Test Accuracy:      84.55%
#     Feature Retention:  51.23% (1559/3043)
#     Modality Retention: depth=51.4%, sensor=51.2%, skeleton=51.2%
#
#   Fold 4: Best = meta_SSA
#     F1 Macro:           75.26%
#     F1 Weighted:        75.26%
#     Test Accuracy:      77.73%
#     Feature Retention:  50.25% (1529/3043)
#     Modality Retention: depth=51.2%, sensor=51.1%, skeleton=49.7%
#
#   Fold 5: Best = meta_DE
#     F1 Macro:           87.66%
#     F1 Weighted:        87.66%
#     Test Accuracy:      88.38%
#     Feature Retention:  51.23% (1559/3043)
#     Modality Retention: depth=49.0%, sensor=47.7%, skeleton=53.1%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 83.07% ± 4.70%
#
#   Average F1 Weighted         : 83.07% ± 4.69%
#
#   Average Test Accuracy       : 83.65% ± 3.92%
#
#   Average Feature Retention   : 50.42% ± 0.84%
#
#   Average Modality-wise Feature Retention:
#            depth: 51.05% ± 1.66%
#           sensor: 50.49% ± 1.74%
#         skeleton: 50.22% ± 1.98%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%
#     1          meta_JAYA         82.82            82.82              82.52                  50.15              53.52               50.15                 49.23
#     2            meta_DE         85.04            85.00              85.06                  49.23              50.20               52.30                 47.90
#     3           meta_MFO         84.59            84.59              84.55                  51.23              51.37               51.23                 51.20
#     4           meta_SSA         75.26            75.26              77.73                  50.25              51.17               51.07                 49.71
#     5            meta_DE         87.66            87.66              88.38                  51.23              49.02               47.70                 53.06
#
# Saved to: results_noise_1.0_30\best_metaheuristic_per_fold.csv
