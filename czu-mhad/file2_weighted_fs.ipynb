# %% [markdown]
# # File 2: Feature Selection on Weighted Early Fusion Features
#
# **Prerequisite:** Run File 1 first (`file1_weighted_fusion.ipynb`) to generate `best_weights_per_fold.pkl`.
#
# **Pipeline:**
# 1. Load the best modality weights per fold from File 1
# 2. For each fold, apply those weights to scale the concatenated features
# 3. Run the full feature selection comparison on the **weighted** features:
#    - Baseline (all weighted features, no FS)
#    - Mutual Information
#    - RFE
#    - LASSO
#    - 14 EvoloPy metaheuristics

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")
WEIGHTS_DIR = Path("results_weighted_fusion")

RESULTS_ROOT = Path("results_weighted_fs")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton']
N_MODALITIES = len(MODALITY_NAMES)

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")


# Load best weights from File 1
best_weights_per_fold = joblib.load(WEIGHTS_DIR / "best_weights_per_fold.pkl")

print(f"\n{'=' * 60}")
print("LOADED BEST WEIGHTS PER FOLD FROM FILE 1:")
print(f"{'=' * 60}")
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']:25s} | Val: {info['val_acc']*100:.2f}% | [{w_str}]")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   TOTAL: 8039
#
# Depth PCA target: 512
#
# ============================================================
# LOADED BEST WEIGHTS PER FOLD FROM FILE 1:
# ============================================================
#   Fold 1: weighted_PSO              | Val: 99.49% | [depth=0.974, sensor=0.803, skeleton=0.211]
#   Fold 2: weighted_MVO              | Val: 100.00% | [depth=0.644, sensor=0.817, skeleton=0.856]
#   Fold 3: weighted_GWO              | Val: 100.00% | [depth=0.104, sensor=0.765, skeleton=0.710]
#   Fold 4: weighted_BAT              | Val: 100.00% | [depth=0.459, sensor=0.591, skeleton=0.542]
#   Fold 5: weighted_HHO              | Val: 96.68% | [depth=0.732, sensor=0.752, skeleton=0.041]

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # KernelPCA on depth modality only
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                random_state=42, n_jobs=-1)
            X_tr = pca_obj.fit_transform(X_tr)
            X_v  = pca_obj.transform(X_v)
            X_te = pca_obj.transform(X_te)
            print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)


def apply_modality_weights(X, weights, modality_dims):
    """Apply per-modality scalar weights to concatenated feature matrix.
    modality_dims is a list of per-modality dimensions (post-KernelPCA)."""
    X_weighted = X.copy()
    start_idx = 0
    for i, dim in enumerate(modality_dims):
        end_idx = start_idx + dim
        X_weighted[:, start_idx:end_idx] *= weights[i]
        start_idx = end_idx
    return X_weighted


def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, ")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Get best weights for this fold
        fold_weights = best_weights_per_fold[fold_idx]['weights']
        fold_weight_method = best_weights_per_fold[fold_idx]['method']
        w_str = ', '.join([f"{MODALITY_NAMES[i]}={fold_weights[i]:.3f}" for i in range(N_MODALITIES)])
        print(f"  Applying weights from {fold_weight_method}: [{w_str}]")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_modality_dims = [fold_feature_dims[n] for n in MODALITY_NAMES]
        fold_total_features = sum(fold_feature_dims.values())
        
        # =================================================================
        # Step 2: Apply modality weights from File 1 (AFTER normalization)
        # =================================================================
        X_train = apply_modality_weights(X_train, fold_weights, fold_modality_dims)
        X_val   = apply_modality_weights(X_val,   fold_weights, fold_modality_dims)
        X_test  = apply_modality_weights(X_test,  fold_weights, fold_modality_dims)

        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Applying weights from weighted_PSO: [depth=0.974, sensor=0.803, skeleton=0.211]
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 96.15%, F1: 96.08%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 30.7s
#     Test Acc: 98.25%, F1: 98.28%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 4.9s
#     Test Acc: 97.55%, F1: 97.58%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 86.0s
#     Test Acc: 91.61%, F1: 91.39%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02905036231523254']
# ['At iteration 1 the best fitness is 0.028688876938959128']
# ['At iteration 2 the best fitness is 0.028688876938959128']
# ['At iteration 3 the best fitness is 0.028688876938959128']
# ['At iteration 4 the best fitness is 0.028688876938959128']
# ['At iteration 5 the best fitness is 0.028688876938959128']
# ['At iteration 6 the best fitness is 0.028672445785492152']
# ['At iteration 7 the best fitness is 0.028672445785492152']
# ['At iteration 8 the best fitness is 0.028672445785492152']
# ['At iteration 9 the best fitness is 0.02865601463202518']
# ['At iteration 10 the best fitness is 0.02865601463202518']
# ['At iteration 11 the best fitness is 0.028639583478558207']
# ['At iteration 12 the best fitness is 0.028639583478558207']
# ['At iteration 13 the best fitness is 0.028639583478558207']
# ['At iteration 14 the best fitness is 0.028639583478558207']
# ['At iteration 15 the best fitness is 0.028639583478558207']
# ['At iteration 16 the best fitness is 0.028639583478558207']
# ['At iteration 17 the best fitness is 0.028639583478558207']
# ['At iteration 18 the best fitness is 0.028639583478558207']
# ['At iteration 19 the best fitness is 0.028639583478558207']
# ['At iteration 20 the best fitness is 0.028639583478558207']
# ['At iteration 21 the best fitness is 0.028639583478558207']
# ['At iteration 22 the best fitness is 0.028639583478558207']
# ['At iteration 23 the best fitness is 0.028639583478558207']
# ['At iteration 24 the best fitness is 0.028639583478558207']
# ['At iteration 25 the best fitness is 0.028639583478558207']
# ['At iteration 26 the best fitness is 0.028639583478558207']
# ['At iteration 27 the best fitness is 0.028639583478558207']
# ['At iteration 28 the best fitness is 0.028639583478558207']
# ['At iteration 29 the best fitness is 0.028639583478558207']
#       Selected: 1451/3043 (47.7%), Fitness: 0.0286, Time: 779.2s
#       Modality: D=47%, S=46%, Sk=48%,
#     Test Acc: 95.10%, F1: 95.05%, Features: 1451/3043 (47.7%), Model: 3.370MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02533683864607296']
# ['At iteration 1 the best fitness is 0.02533683864607296']
# ['At iteration 2 the best fitness is 0.02533683864607296']
# ['At iteration 3 the best fitness is 0.02533683864607296']
# ['At iteration 4 the best fitness is 0.02533683864607296']
# ['At iteration 5 the best fitness is 0.02533683864607296']
# ['At iteration 6 the best fitness is 0.02533683864607296']
# ['At iteration 7 the best fitness is 0.02533683864607296']
# ['At iteration 8 the best fitness is 0.02533683864607296']
# ['At iteration 9 the best fitness is 0.02533683864607296']
# ['At iteration 10 the best fitness is 0.02533683864607296']
# ['At iteration 11 the best fitness is 0.02533683864607296']
# ['At iteration 12 the best fitness is 0.02533683864607296']
# ['At iteration 13 the best fitness is 0.02533683864607296']
# ['At iteration 14 the best fitness is 0.02533683864607296']
# ['At iteration 15 the best fitness is 0.02477817942819586']
# ['At iteration 16 the best fitness is 0.02477817942819586']
# ['At iteration 17 the best fitness is 0.02477817942819586']
# ['At iteration 18 the best fitness is 0.02477817942819586']
# ['At iteration 19 the best fitness is 0.02477817942819586']
# ['At iteration 20 the best fitness is 0.02477817942819586']
# ['At iteration 21 the best fitness is 0.02477817942819586']
# ['At iteration 22 the best fitness is 0.02477817942819586']
# ['At iteration 23 the best fitness is 0.02477817942819586']
# ['At iteration 24 the best fitness is 0.02423595136378574']
# ['At iteration 25 the best fitness is 0.02423595136378574']
# ['At iteration 26 the best fitness is 0.02423595136378574']
# ['At iteration 27 the best fitness is 0.02423595136378574']
# ['At iteration 28 the best fitness is 0.02423595136378574']
# ['At iteration 29 the best fitness is 0.02423595136378574']
#       Selected: 1475/3043 (48.5%), Fitness: 0.0242, Time: 1582.7s
#       Modality: D=50%, S=48%, Sk=48%,
#     Test Acc: 95.10%, F1: 95.10%, Features: 1475/3043 (48.5%), Model: 3.417MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02923110500336925']
# ['At iteration 2 the best fitness is 0.02923110500336925']
# ['At iteration 3 the best fitness is 0.02923110500336925']
# ['At iteration 4 the best fitness is 0.02923110500336925']
# ['At iteration 5 the best fitness is 0.029165380389501352']
# ['At iteration 6 the best fitness is 0.029132518082567407']
# ['At iteration 7 the best fitness is 0.029132518082567407']
# ['At iteration 8 the best fitness is 0.029132518082567407']
# ['At iteration 9 the best fitness is 0.028886050780562805']
# ['At iteration 10 the best fitness is 0.028886050780562805']
# ['At iteration 11 the best fitness is 0.028886050780562805']
# ['At iteration 12 the best fitness is 0.024104502136049952']
# ['At iteration 13 the best fitness is 0.024104502136049952']
# ['At iteration 14 the best fitness is 0.024104502136049952']
# ['At iteration 15 the best fitness is 0.024104502136049952']
# ['At iteration 16 the best fitness is 0.024104502136049952']
# ['At iteration 17 the best fitness is 0.024104502136049952']
# ['At iteration 18 the best fitness is 0.024104502136049952']
# ['At iteration 19 the best fitness is 0.024104502136049952']
# ['At iteration 20 the best fitness is 0.024104502136049952']
# ['At iteration 21 the best fitness is 0.024104502136049952']
# ['At iteration 22 the best fitness is 0.024104502136049952']
# ['At iteration 23 the best fitness is 0.024104502136049952']
# ['At iteration 24 the best fitness is 0.024104502136049952']
# ['At iteration 25 the best fitness is 0.024104502136049952']
# ['At iteration 26 the best fitness is 0.024104502136049952']
# ['At iteration 27 the best fitness is 0.024104502136049952']
# ['At iteration 28 the best fitness is 0.024104502136049952']
# ['At iteration 29 the best fitness is 0.024104502136049952']
# ['At iteration 30 the best fitness is 0.024104502136049952']
#       Selected: 1467/3043 (48.2%), Fitness: 0.0241, Time: 785.3s
#       Modality: D=50%, S=49%, Sk=47%,
#     Test Acc: 94.76%, F1: 94.80%, Features: 1467/3043 (48.2%), Model: 3.401MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02949400345884082']
# ['At iteration 1 the best fitness is 0.029017500008298596']
# ['At iteration 2 the best fitness is 0.02423595136378574']
# ['At iteration 3 the best fitness is 0.029756901914312395']
# ['At iteration 4 the best fitness is 0.029116086929100435']
# ['At iteration 5 the best fitness is 0.02905036231523254']
# ['At iteration 6 the best fitness is 0.028869619627095833']
# ['At iteration 7 the best fitness is 0.029116086929100435']
# ['At iteration 8 the best fitness is 0.02885318847362886']
# ['At iteration 9 the best fitness is 0.02885318847362886']
# ['At iteration 10 the best fitness is 0.02885318847362886']
# ['At iteration 11 the best fitness is 0.02885318847362886']
# ['At iteration 12 the best fitness is 0.02885318847362886']
# ['At iteration 13 the best fitness is 0.02885318847362886']
# ['At iteration 14 the best fitness is 0.02878746385976097']
# ['At iteration 15 the best fitness is 0.02878746385976097']
# ['At iteration 16 the best fitness is 0.023956621754847193']
# ['At iteration 17 the best fitness is 0.02398948406178114']
# ['At iteration 18 the best fitness is 0.02878746385976097']
# ['At iteration 19 the best fitness is 0.023956621754847193']
# ['At iteration 20 the best fitness is 0.02873817039936005']
# ['At iteration 21 the best fitness is 0.02873817039936005']
# ['At iteration 22 the best fitness is 0.02875460155282702']
# ['At iteration 23 the best fitness is 0.02873817039936005']
# ['At iteration 24 the best fitness is 0.02873817039936005']
# ['At iteration 25 the best fitness is 0.02873817039936005']
# ['At iteration 26 the best fitness is 0.02873817039936005']
# ['At iteration 27 the best fitness is 0.02873817039936005']
# ['At iteration 28 the best fitness is 0.02873817039936005']
# ['At iteration 29 the best fitness is 0.02873817039936005']
#       Selected: 1457/3043 (47.9%), Fitness: 0.0287, Time: 748.9s
#       Modality: D=46%, S=49%, Sk=48%,
#     Test Acc: 97.55%, F1: 97.57%, Features: 1457/3043 (47.9%), Model: 3.382MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.030233405364854624
# At iteration 2 the best fitness is 0.03416053402908476
# At iteration 3 the best fitness is 0.029477572305373848
# At iteration 4 the best fitness is 0.02957615922617569
# At iteration 5 the best fitness is 0.029756901914312395
# At iteration 6 the best fitness is 0.029855488835114238
# At iteration 7 the best fitness is 0.029362554231105037
# At iteration 8 the best fitness is 0.029362554231105037
# At iteration 9 the best fitness is 0.029395416538038982
# At iteration 10 the best fitness is 0.029263967310303195
# At iteration 11 the best fitness is 0.02505750903713441
# At iteration 12 the best fitness is 0.02928039846377017
# At iteration 13 the best fitness is 0.029395416538038982
# At iteration 14 the best fitness is 0.024942490962865594
# At iteration 15 the best fitness is 0.02928039846377017
# At iteration 16 the best fitness is 0.029296829617237143
# At iteration 17 the best fitness is 0.02433453828458758
# At iteration 18 the best fitness is 0.029116086929100435
# At iteration 19 the best fitness is 0.029099655775633462
# At iteration 20 the best fitness is 0.029066793468699517
# At iteration 21 the best fitness is 0.025188958264870193
# At iteration 22 the best fitness is 0.02908322462216649
# At iteration 23 the best fitness is 0.028984637701364648
# At iteration 24 the best fitness is 0.02435096943805455
# At iteration 25 the best fitness is 0.02908322462216649
# At iteration 26 the best fitness is 0.028984637701364648
# At iteration 27 the best fitness is 0.02908322462216649
# At iteration 28 the best fitness is 0.025303976339139007
# At iteration 29 the best fitness is 0.029066793468699517
# At iteration 30 the best fitness is 0.02905036231523254
#       Selected: 1476/3043 (48.5%), Fitness: 0.0291, Time: 739.5s
#       Modality: D=50%, S=49%, Sk=48%,
#     Test Acc: 96.50%, F1: 96.52%, Features: 1476/3043 (48.5%), Model: 3.419MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024548143279658236']
# ['At iteration 1 the best fitness is 0.024548143279658236']
# ['At iteration 2 the best fitness is 0.024548143279658236']
# ['At iteration 3 the best fitness is 0.022642129477489323']
# ['At iteration 4 the best fitness is 0.022642129477489323']
# ['At iteration 5 the best fitness is 0.022642129477489323']
# ['At iteration 6 the best fitness is 0.022642129477489323']
# ['At iteration 7 the best fitness is 0.022642129477489323']
# ['At iteration 8 the best fitness is 0.022642129477489323']
# ['At iteration 9 the best fitness is 0.022642129477489323']
# ['At iteration 10 the best fitness is 0.022642129477489323']
# ['At iteration 11 the best fitness is 0.022642129477489323']
# ['At iteration 12 the best fitness is 0.022642129477489323']
# ['At iteration 13 the best fitness is 0.022642129477489323']
# ['At iteration 14 the best fitness is 0.022642129477489323']
# ['At iteration 15 the best fitness is 0.022642129477489323']
# ['At iteration 16 the best fitness is 0.022642129477489323']
# ['At iteration 17 the best fitness is 0.022642129477489323']
# ['At iteration 18 the best fitness is 0.022642129477489323']
# ['At iteration 19 the best fitness is 0.022642129477489323']
# ['At iteration 20 the best fitness is 0.022642129477489323']
# ['At iteration 21 the best fitness is 0.022642129477489323']
# ['At iteration 22 the best fitness is 0.022642129477489323']
# ['At iteration 23 the best fitness is 0.022642129477489323']
# ['At iteration 24 the best fitness is 0.022642129477489323']
# ['At iteration 25 the best fitness is 0.022461386789352614']
# ['At iteration 26 the best fitness is 0.022461386789352614']
# ['At iteration 27 the best fitness is 0.022461386789352614']
# ['At iteration 28 the best fitness is 0.022461386789352614']
# ['At iteration 29 the best fitness is 0.022461386789352614']
#       Selected: 1367/3043 (44.9%), Fitness: 0.0225, Time: 749.8s
#       Modality: D=47%, S=43%, Sk=45%,
#     Test Acc: 96.15%, F1: 96.29%, Features: 1367/3043 (44.9%), Model: 3.206MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.029247536156836222']
# ['At iteration 1 the best fitness is 0.01759801431999919']
# ['At iteration 2 the best fitness is 0.01759801431999919']
# ['At iteration 3 the best fitness is 0.016151989829281933']
# ['At iteration 4 the best fitness is 0.016151989829281933']
# ['At iteration 5 the best fitness is 0.016151989829281933']
# ['At iteration 6 the best fitness is 0.016151989829281933']
# ['At iteration 7 the best fitness is 0.010713195046090248']
# ['At iteration 8 the best fitness is 0.010713195046090248']
# ['At iteration 9 the best fitness is 0.010713195046090248']
# ['At iteration 10 the best fitness is 0.010713195046090248']
# ['At iteration 11 the best fitness is 0.010713195046090248']
# ['At iteration 12 the best fitness is 0.010713195046090248']
# ['At iteration 13 the best fitness is 0.010713195046090248']
# ['At iteration 14 the best fitness is 0.010713195046090248']
# ['At iteration 15 the best fitness is 0.010713195046090248']
# ['At iteration 16 the best fitness is 0.010713195046090248']
# ['At iteration 17 the best fitness is 0.010713195046090248']
# ['At iteration 18 the best fitness is 0.010713195046090248']
# ['At iteration 19 the best fitness is 0.010713195046090248']
# ['At iteration 20 the best fitness is 0.010713195046090248']
# ['At iteration 21 the best fitness is 0.010713195046090248']
# ['At iteration 22 the best fitness is 0.010713195046090248']
# ['At iteration 23 the best fitness is 0.010647470432222354']
# ['At iteration 24 the best fitness is 0.005800197173841604']
# ['At iteration 25 the best fitness is 0.005800197173841604']
# ['At iteration 26 the best fitness is 0.005800197173841604']
# ['At iteration 27 the best fitness is 0.005800197173841604']
# ['At iteration 28 the best fitness is 0.005800197173841604']
# ['At iteration 29 the best fitness is 0.005800197173841604']
#       Selected: 353/3043 (11.6%), Fitness: 0.0058, Time: 943.6s
#       Modality: D=10%, S=14%, Sk=11%,
#     Test Acc: 96.50%, F1: 96.50%, Features: 353/3043 (11.6%), Model: 1.226MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02928039846377017']
# ['At iteration 1 the best fitness is 0.02928039846377017']
# ['At iteration 2 the best fitness is 0.029165380389501352']
# ['At iteration 3 the best fitness is 0.029165380389501352']
# ['At iteration 4 the best fitness is 0.029165380389501352']
# ['At iteration 5 the best fitness is 0.029165380389501352']
# ['At iteration 6 the best fitness is 0.029165380389501352']
# ['At iteration 7 the best fitness is 0.029165380389501352']
# ['At iteration 8 the best fitness is 0.029165380389501352']
# ['At iteration 9 the best fitness is 0.029165380389501352']
# ['At iteration 10 the best fitness is 0.029165380389501352']
# ['At iteration 11 the best fitness is 0.029165380389501352']
# ['At iteration 12 the best fitness is 0.028968206547897675']
# ['At iteration 13 the best fitness is 0.028968206547897675']
# ['At iteration 14 the best fitness is 0.028803895013227943']
# ['At iteration 15 the best fitness is 0.028803895013227943']
# ['At iteration 16 the best fitness is 0.028721739245893073']
# ['At iteration 17 the best fitness is 0.028278098102284793']
# ['At iteration 18 the best fitness is 0.028278098102284793']
# ['At iteration 19 the best fitness is 0.02458100558659218']
# ['At iteration 20 the best fitness is 0.024318107131120606']
# ['At iteration 21 the best fitness is 0.024318107131120606']
# ['At iteration 22 the best fitness is 0.024318107131120606']
# ['At iteration 23 the best fitness is 0.024318107131120606']
# ['At iteration 24 the best fitness is 0.024318107131120606']
# ['At iteration 25 the best fitness is 0.02428524482418666']
# ['At iteration 26 the best fitness is 0.02428524482418666']
# ['At iteration 27 the best fitness is 0.02428524482418666']
# ['At iteration 28 the best fitness is 0.02428524482418666']
# ['At iteration 29 the best fitness is 0.02428524482418666']
#       Selected: 1478/3043 (48.6%), Fitness: 0.0243, Time: 783.8s
#       Modality: D=50%, S=50%, Sk=48%,
#     Test Acc: 96.50%, F1: 96.49%, Features: 1478/3043 (48.6%), Model: 3.423MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02972403960737845']
# ['At iteration 2 the best fitness is 0.02962545268657661']
# ['At iteration 3 the best fitness is 0.029592590379642663']
# ['At iteration 4 the best fitness is 0.029592590379642663']
# ['At iteration 5 the best fitness is 0.029592590379642663']
# ['At iteration 6 the best fitness is 0.025123233651002302']
# ['At iteration 7 the best fitness is 0.025123233651002302']
# ['At iteration 8 the best fitness is 0.025123233651002302']
# ['At iteration 9 the best fitness is 0.025123233651002302']
# ['At iteration 10 the best fitness is 0.025123233651002302']
# ['At iteration 11 the best fitness is 0.025123233651002302']
# ['At iteration 12 the best fitness is 0.025123233651002302']
# ['At iteration 13 the best fitness is 0.025123233651002302']
# ['At iteration 14 the best fitness is 0.025123233651002302']
# ['At iteration 15 the best fitness is 0.025123233651002302']
# ['At iteration 16 the best fitness is 0.025123233651002302']
# ['At iteration 17 the best fitness is 0.024942490962865594']
# ['At iteration 18 the best fitness is 0.024942490962865594']
# ['At iteration 19 the best fitness is 0.024942490962865594']
# ['At iteration 20 the best fitness is 0.024663161353927047']
# ['At iteration 21 the best fitness is 0.024663161353927047']
# ['At iteration 22 the best fitness is 0.024663161353927047']
# ['At iteration 23 the best fitness is 0.024663161353927047']
# ['At iteration 24 the best fitness is 0.024663161353927047']
# ['At iteration 25 the best fitness is 0.024663161353927047']
# ['At iteration 26 the best fitness is 0.024663161353927047']
# ['At iteration 27 the best fitness is 0.024663161353927047']
# ['At iteration 28 the best fitness is 0.024663161353927047']
# ['At iteration 29 the best fitness is 0.024663161353927047']
#       Selected: 1501/3043 (49.3%), Fitness: 0.0247, Time: 720.3s
#       Modality: D=51%, S=48%, Sk=49%,
#     Test Acc: 96.50%, F1: 96.45%, Features: 1501/3043 (49.3%), Model: 3.468MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.029214673849902274']
# ['At iteration 2 the best fitness is 0.029214673849902274']
# ['At iteration 3 the best fitness is 0.02914894923603438']
# ['At iteration 4 the best fitness is 0.028886050780562805']
# ['At iteration 5 the best fitness is 0.02878746385976097']
# ['At iteration 6 the best fitness is 0.02878746385976097']
# ['At iteration 7 the best fitness is 0.028475271943888474']
# ['At iteration 8 the best fitness is 0.028475271943888474']
# ['At iteration 9 the best fitness is 0.028475271943888474']
# ['At iteration 10 the best fitness is 0.028475271943888474']
# ['At iteration 11 the best fitness is 0.028425978483487553']
# ['At iteration 12 the best fitness is 0.028425978483487553']
# ['At iteration 13 the best fitness is 0.028376685023086632']
# ['At iteration 14 the best fitness is 0.028343822716152683']
# ['At iteration 15 the best fitness is 0.028343822716152683']
# ['At iteration 16 the best fitness is 0.028245235795350848']
# ['At iteration 17 the best fitness is 0.028245235795350848']
# ['At iteration 18 the best fitness is 0.028228804641883872']
# ['At iteration 19 the best fitness is 0.028130217721082033']
# ['At iteration 20 the best fitness is 0.028048061953747164']
# ['At iteration 21 the best fitness is 0.02803163080028019']
# ['At iteration 22 the best fitness is 0.0279659061864123']
# ['At iteration 23 the best fitness is 0.0279659061864123']
# ['At iteration 24 the best fitness is 0.027949475032945325']
# ['At iteration 25 the best fitness is 0.02791661272601138']
# ['At iteration 26 the best fitness is 0.027900181572544404']
# ['At iteration 27 the best fitness is 0.02788375041907743']
# ['At iteration 28 the best fitness is 0.02788375041907743']
# ['At iteration 29 the best fitness is 0.02788375041907743']
# ['At iteration 30 the best fitness is 0.02783445695867651']
#       Selected: 1402/3043 (46.1%), Fitness: 0.0278, Time: 715.9s
#       Modality: D=47%, S=45%, Sk=46%,
#     Test Acc: 96.85%, F1: 96.84%, Features: 1402/3043 (46.1%), Model: 3.275MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.028869619627095833']
# ['At iteration 2 the best fitness is 0.028869619627095833']
# ['At iteration 3 the best fitness is 0.028869619627095833']
# ['At iteration 4 the best fitness is 0.0287053080924261']
# ['At iteration 5 the best fitness is 0.0287053080924261']
# ['At iteration 6 the best fitness is 0.0287053080924261']
# ['At iteration 7 the best fitness is 0.0287053080924261']
# ['At iteration 8 the best fitness is 0.028245235795350848']
# ['At iteration 9 the best fitness is 0.028245235795350848']
# ['At iteration 10 the best fitness is 0.028245235795350848']
# ['At iteration 11 the best fitness is 0.028245235795350848']
# ['At iteration 12 the best fitness is 0.028245235795350848']
# ['At iteration 13 the best fitness is 0.028228804641883872']
# ['At iteration 14 the best fitness is 0.028195942334949927']
# ['At iteration 15 the best fitness is 0.028048061953747164']
# ['At iteration 16 the best fitness is 0.028048061953747164']
# ['At iteration 17 the best fitness is 0.028048061953747164']
# ['At iteration 18 the best fitness is 0.02801519964681322']
# ['At iteration 19 the best fitness is 0.02801519964681322']
# ['At iteration 20 the best fitness is 0.02801519964681322']
# ['At iteration 21 the best fitness is 0.027801594651742565']
# ['At iteration 22 the best fitness is 0.027801594651742565']
# ['At iteration 23 the best fitness is 0.027768732344808617']
# ['At iteration 24 the best fitness is 0.02748940273587007']
# ['At iteration 25 the best fitness is 0.02748940273587007']
# ['At iteration 26 the best fitness is 0.02748940273587007']
# ['At iteration 27 the best fitness is 0.02748940273587007']
# ['At iteration 28 the best fitness is 0.02748940273587007']
# ['At iteration 29 the best fitness is 0.02748940273587007']
# ['At iteration 30 the best fitness is 0.02748940273587007']
#       Selected: 1381/3043 (45.4%), Fitness: 0.0275, Time: 729.1s
#       Modality: D=46%, S=45%, Sk=45%,
#     Test Acc: 95.45%, F1: 95.58%, Features: 1381/3043 (45.4%), Model: 3.233MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02962545268657661']
# ['At iteration 1 the best fitness is 0.023299375616168256']
# ['At iteration 2 the best fitness is 0.023299375616168256']
# ['At iteration 3 the best fitness is 0.021935672864033067']
# ['At iteration 4 the best fitness is 0.021935672864033067']
# ['At iteration 5 the best fitness is 0.02025969521040178']
# ['At iteration 6 the best fitness is 0.02025969521040178']
# ['At iteration 7 the best fitness is 0.01845226832903471']
# ['At iteration 8 the best fitness is 0.017942902571558533']
# ['At iteration 9 the best fitness is 0.0172856564328796']
# ['At iteration 10 the best fitness is 0.016677703754601585']
# ['At iteration 11 the best fitness is 0.01564254108618226']
# ['At iteration 12 the best fitness is 0.015198899942573979']
# ['At iteration 13 the best fitness is 0.013440766521607828']
# ['At iteration 14 the best fitness is 0.013440766521607828']
# ['At iteration 15 the best fitness is 0.013440766521607828']
# ['At iteration 16 the best fitness is 0.013440766521607828']
# ['At iteration 17 the best fitness is 0.013440766521607828']
# ['At iteration 18 the best fitness is 0.008051265198816956']
# ['At iteration 19 the best fitness is 0.008051265198816956']
# ['At iteration 20 the best fitness is 0.008051265198816956']
# ['At iteration 21 the best fitness is 0.008051265198816956']
# ['At iteration 22 the best fitness is 0.008051265198816956']
# ['At iteration 23 the best fitness is 0.008051265198816956']
# ['At iteration 24 the best fitness is 0.007443312520538942']
# ['At iteration 25 the best fitness is 0.007443312520538942']
# ['At iteration 26 the best fitness is 0.007443312520538942']
# ['At iteration 27 the best fitness is 0.007443312520538942']
# ['At iteration 28 the best fitness is 0.007443312520538942']
# ['At iteration 29 the best fitness is 0.007443312520538942']
#       Selected: 453/3043 (14.9%), Fitness: 0.0074, Time: 737.1s
#       Modality: D=17%, S=12%, Sk=15%,
#     Test Acc: 95.80%, F1: 96.04%, Features: 453/3043 (14.9%), Model: 1.421MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0291982426964353']
# ['At iteration 2 the best fitness is 0.0291982426964353']
# ['At iteration 3 the best fitness is 0.0291982426964353']
# ['At iteration 4 the best fitness is 0.0291982426964353']
# ['At iteration 5 the best fitness is 0.02426881367071969']
# ['At iteration 6 the best fitness is 0.02426881367071969']
# ['At iteration 7 the best fitness is 0.02426881367071969']
# ['At iteration 8 the best fitness is 0.02426881367071969']
# ['At iteration 9 the best fitness is 0.02426881367071969']
# ['At iteration 10 the best fitness is 0.02426881367071969']
# ['At iteration 11 the best fitness is 0.02426881367071969']
# ['At iteration 12 the best fitness is 0.02426881367071969']
# ['At iteration 13 the best fitness is 0.02426881367071969']
# ['At iteration 14 the best fitness is 0.02426881367071969']
# ['At iteration 15 the best fitness is 0.02426881367071969']
# ['At iteration 16 the best fitness is 0.02426881367071969']
# ['At iteration 17 the best fitness is 0.02426881367071969']
# ['At iteration 18 the best fitness is 0.02426881367071969']
# ['At iteration 19 the best fitness is 0.02426881367071969']
# ['At iteration 20 the best fitness is 0.02426881367071969']
# ['At iteration 21 the best fitness is 0.02426881367071969']
# ['At iteration 22 the best fitness is 0.02426881367071969']
# ['At iteration 23 the best fitness is 0.02426881367071969']
# ['At iteration 24 the best fitness is 0.02426881367071969']
# ['At iteration 25 the best fitness is 0.02426881367071969']
# ['At iteration 26 the best fitness is 0.02426881367071969']
# ['At iteration 27 the best fitness is 0.02426881367071969']
# ['At iteration 28 the best fitness is 0.02426881367071969']
# ['At iteration 29 the best fitness is 0.02426881367071969']
#       Selected: 1477/3043 (48.5%), Fitness: 0.0243, Time: 1950.8s
#       Modality: D=46%, S=51%, Sk=48%,
#     Test Acc: 96.50%, F1: 96.55%, Features: 1477/3043 (48.5%), Model: 3.421MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02972403960737845']
# ['At iteration 1 the best fitness is 0.00933289516924088']
# ['At iteration 2 the best fitness is 0.00933289516924088']
# ['At iteration 3 the best fitness is 0.00933289516924088']
# ['At iteration 4 the best fitness is 0.00928360170883996']
# ['At iteration 5 the best fitness is 0.00928360170883996']
# ['At iteration 6 the best fitness is 0.00928360170883996']
# ['At iteration 7 the best fitness is 0.00928360170883996']
# ['At iteration 8 the best fitness is 0.00928360170883996']
# ['At iteration 9 the best fitness is 0.00928360170883996']
# ['At iteration 10 the best fitness is 0.00928360170883996']
# ['At iteration 11 the best fitness is 0.00928360170883996']
# ['At iteration 12 the best fitness is 0.00928360170883996']
# ['At iteration 13 the best fitness is 0.00928360170883996']
# ['At iteration 14 the best fitness is 0.00928360170883996']
# ['At iteration 15 the best fitness is 0.00928360170883996']
# ['At iteration 16 the best fitness is 0.00928360170883996']
# ['At iteration 17 the best fitness is 0.00928360170883996']
# ['At iteration 18 the best fitness is 0.00928360170883996']
# ['At iteration 19 the best fitness is 0.00928360170883996']
# ['At iteration 20 the best fitness is 0.00928360170883996']
# ['At iteration 21 the best fitness is 0.00928360170883996']
# ['At iteration 22 the best fitness is 0.009201445941505093']
# ['At iteration 23 the best fitness is 0.009201445941505093']
# ['At iteration 24 the best fitness is 0.009201445941505093']
# ['At iteration 25 the best fitness is 0.009201445941505093']
# ['At iteration 26 the best fitness is 0.009201445941505093']
# ['At iteration 27 the best fitness is 0.009201445941505093']
# ['At iteration 28 the best fitness is 0.009201445941505093']
# ['At iteration 29 the best fitness is 0.009004272099901412']
#       Selected: 548/3043 (18.0%), Fitness: 0.0090, Time: 681.0s
#       Modality: D=16%, S=19%, Sk=18%,
#     Test Acc: 97.55%, F1: 97.57%, Features: 548/3043 (18.0%), Model: 1.607MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Applying weights from weighted_MVO: [depth=0.644, sensor=0.817, skeleton=0.856]
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 93.36%, F1: 93.41%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 29.8s
#     Test Acc: 92.95%, F1: 93.34%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 4.9s
#     Test Acc: 92.95%, F1: 93.09%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 176.4s
#     Test Acc: 93.36%, F1: 93.33%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024219520210318767']
# ['At iteration 1 the best fitness is 0.024088070982582976']
# ['At iteration 2 the best fitness is 0.024088070982582976']
# ['At iteration 3 the best fitness is 0.024088070982582976']
# ['At iteration 4 the best fitness is 0.024088070982582976']
# ['At iteration 5 the best fitness is 0.024071639829116004']
# ['At iteration 6 the best fitness is 0.024071639829116004']
# ['At iteration 7 the best fitness is 0.02405520867564903']
# ['At iteration 8 the best fitness is 0.024022346368715086']
# ['At iteration 9 the best fitness is 0.024022346368715086']
# ['At iteration 10 the best fitness is 0.024022346368715086']
# ['At iteration 11 the best fitness is 0.024022346368715086']
# ['At iteration 12 the best fitness is 0.024022346368715086']
# ['At iteration 13 the best fitness is 0.024022346368715086']
# ['At iteration 14 the best fitness is 0.024022346368715086']
# ['At iteration 15 the best fitness is 0.024022346368715086']
# ['At iteration 16 the best fitness is 0.024005915215248114']
# ['At iteration 17 the best fitness is 0.024005915215248114']
# ['At iteration 18 the best fitness is 0.024005915215248114']
# ['At iteration 19 the best fitness is 0.024005915215248114']
# ['At iteration 20 the best fitness is 0.024005915215248114']
# ['At iteration 21 the best fitness is 0.02398948406178114']
# ['At iteration 22 the best fitness is 0.02398948406178114']
# ['At iteration 23 the best fitness is 0.02398948406178114']
# ['At iteration 24 the best fitness is 0.02398948406178114']
# ['At iteration 25 the best fitness is 0.02398948406178114']
# ['At iteration 26 the best fitness is 0.02398948406178114']
# ['At iteration 27 the best fitness is 0.02398948406178114']
# ['At iteration 28 the best fitness is 0.02398948406178114']
# ['At iteration 29 the best fitness is 0.02398948406178114']
#       Selected: 1460/3043 (48.0%), Fitness: 0.0240, Time: 825.6s
#       Modality: D=50%, S=48%, Sk=48%,
#     Test Acc: 92.12%, F1: 92.34%, Features: 1460/3043 (48.0%), Model: 3.388MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024449556358856393']
# ['At iteration 1 the best fitness is 0.024449556358856393']
# ['At iteration 2 the best fitness is 0.024137364442983898']
# ['At iteration 3 the best fitness is 0.024137364442983898']
# ['At iteration 4 the best fitness is 0.02380874137364443']
# ['At iteration 5 the best fitness is 0.02380874137364443']
# ['At iteration 6 the best fitness is 0.02380874137364443']
# ['At iteration 7 the best fitness is 0.02380874137364443']
# ['At iteration 8 the best fitness is 0.02380874137364443']
# ['At iteration 9 the best fitness is 0.02380874137364443']
# ['At iteration 10 the best fitness is 0.02380874137364443']
# ['At iteration 11 the best fitness is 0.02371015445284259']
# ['At iteration 12 the best fitness is 0.02371015445284259']
# ['At iteration 13 the best fitness is 0.02371015445284259']
# ['At iteration 14 the best fitness is 0.02371015445284259']
# ['At iteration 15 the best fitness is 0.02371015445284259']
# ['At iteration 16 the best fitness is 0.02371015445284259']
# ['At iteration 17 the best fitness is 0.02371015445284259']
# ['At iteration 18 the best fitness is 0.023693723299375618']
# ['At iteration 19 the best fitness is 0.023693723299375618']
# ['At iteration 20 the best fitness is 0.023693723299375618']
# ['At iteration 21 the best fitness is 0.023693723299375618']
# ['At iteration 22 the best fitness is 0.02336510023003615']
# ['At iteration 23 the best fitness is 0.02336510023003615']
# ['At iteration 24 the best fitness is 0.02336510023003615']
# ['At iteration 25 the best fitness is 0.02336510023003615']
# ['At iteration 26 the best fitness is 0.02336510023003615']
# ['At iteration 27 the best fitness is 0.02336510023003615']
# ['At iteration 28 the best fitness is 0.02336510023003615']
# ['At iteration 29 the best fitness is 0.02336510023003615']
#       Selected: 1422/3043 (46.7%), Fitness: 0.0234, Time: 1613.4s
#       Modality: D=48%, S=47%, Sk=46%,
#     Test Acc: 92.12%, F1: 92.09%, Features: 1422/3043 (46.7%), Model: 3.314MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02428524482418666']
# ['At iteration 2 the best fitness is 0.023841603680578378']
# ['At iteration 3 the best fitness is 0.023726585606309566']
# ['At iteration 4 the best fitness is 0.023726585606309566']
# ['At iteration 5 the best fitness is 0.023529411764705882']
# ['At iteration 6 the best fitness is 0.023529411764705882']
# ['At iteration 7 the best fitness is 0.023266513309234307']
# ['At iteration 8 the best fitness is 0.023266513309234307']
# ['At iteration 9 the best fitness is 0.023135064081498524']
# ['At iteration 10 the best fitness is 0.023135064081498524']
# ['At iteration 11 the best fitness is 0.023135064081498524']
# ['At iteration 12 the best fitness is 0.023135064081498524']
# ['At iteration 13 the best fitness is 0.023135064081498524']
# ['At iteration 14 the best fitness is 0.023135064081498524']
# ['At iteration 15 the best fitness is 0.022954321393361815']
# ['At iteration 16 the best fitness is 0.02287216562602695']
# ['At iteration 17 the best fitness is 0.02287216562602695']
# ['At iteration 18 the best fitness is 0.022790009858692083']
# ['At iteration 19 the best fitness is 0.02262569832402235']
# ['At iteration 20 the best fitness is 0.022527111403220508']
# ['At iteration 21 the best fitness is 0.022329937561616827']
# ['At iteration 22 the best fitness is 0.022329937561616827']
# ['At iteration 23 the best fitness is 0.022329937561616827']
# ['At iteration 24 the best fitness is 0.022329937561616827']
# ['At iteration 25 the best fitness is 0.022329937561616827']
# ['At iteration 26 the best fitness is 0.022329937561616827']
# ['At iteration 27 the best fitness is 0.02224778179428196']
# ['At iteration 28 the best fitness is 0.02224778179428196']
# ['At iteration 29 the best fitness is 0.02224778179428196']
# ['At iteration 30 the best fitness is 0.02224778179428196']
#       Selected: 1354/3043 (44.5%), Fitness: 0.0222, Time: 781.5s
#       Modality: D=45%, S=44%, Sk=45%,
#     Test Acc: 93.36%, F1: 93.41%, Features: 1354/3043 (44.5%), Model: 3.181MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02420308905685179']
# ['At iteration 1 the best fitness is 0.024696023660860992']
# ['At iteration 2 the best fitness is 0.02443312520538942']
# ['At iteration 3 the best fitness is 0.02435096943805455']
# ['At iteration 4 the best fitness is 0.024219520210318767']
# ['At iteration 5 the best fitness is 0.024088070982582976']
# ['At iteration 6 the best fitness is 0.02374301675977654']
# ['At iteration 7 the best fitness is 0.02374301675977654']
# ['At iteration 8 the best fitness is 0.023677292145908645']
# ['At iteration 9 the best fitness is 0.02356227407163983']
# ['At iteration 10 the best fitness is 0.02356227407163983']
# ['At iteration 11 the best fitness is 0.02356227407163983']
# ['At iteration 12 the best fitness is 0.023496549457771937']
# ['At iteration 13 the best fitness is 0.02344725599737102']
# ['At iteration 14 the best fitness is 0.02344725599737102']
# ['At iteration 15 the best fitness is 0.02344725599737102']
# ['At iteration 16 the best fitness is 0.02344725599737102']
# ['At iteration 17 the best fitness is 0.02344725599737102']
# ['At iteration 18 the best fitness is 0.02344725599737102']
# ['At iteration 19 the best fitness is 0.02344725599737102']
# ['At iteration 20 the best fitness is 0.023430824843904043']
# ['At iteration 21 the best fitness is 0.02341439369043707']
# ['At iteration 22 the best fitness is 0.02341439369043707']
# ['At iteration 23 the best fitness is 0.02341439369043707']
# ['At iteration 24 the best fitness is 0.02341439369043707']
# ['At iteration 25 the best fitness is 0.02341439369043707']
# ['At iteration 26 the best fitness is 0.02341439369043707']
# ['At iteration 27 the best fitness is 0.02341439369043707']
# ['At iteration 28 the best fitness is 0.02341439369043707']
# ['At iteration 29 the best fitness is 0.02341439369043707']
#       Selected: 1425/3043 (46.8%), Fitness: 0.0234, Time: 777.9s
#       Modality: D=42%, S=45%, Sk=49%,
#     Test Acc: 92.53%, F1: 92.78%, Features: 1425/3043 (46.8%), Model: 3.319MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024022346368715086
# At iteration 2 the best fitness is 0.024022346368715086
# At iteration 3 the best fitness is 0.02418665790338482
# At iteration 4 the best fitness is 0.02418665790338482
# At iteration 5 the best fitness is 0.02418665790338482
# At iteration 6 the best fitness is 0.024088070982582976
# At iteration 7 the best fitness is 0.024088070982582976
# At iteration 8 the best fitness is 0.024088070982582976
# At iteration 9 the best fitness is 0.02405520867564903
# At iteration 10 the best fitness is 0.023660860992441673
# At iteration 11 the best fitness is 0.023660860992441673
# At iteration 12 the best fitness is 0.023627998685507724
# At iteration 13 the best fitness is 0.023595136378573776
# At iteration 14 the best fitness is 0.023595136378573776
# At iteration 15 the best fitness is 0.023496549457771937
# At iteration 16 the best fitness is 0.023480118304304964
# At iteration 17 the best fitness is 0.023200788695366417
# At iteration 18 the best fitness is 0.023085770621097602
# At iteration 19 the best fitness is 0.023085770621097602
# At iteration 20 the best fitness is 0.023003614853762736
# At iteration 21 the best fitness is 0.022954321393361815
# At iteration 22 the best fitness is 0.022954321393361815
# At iteration 23 the best fitness is 0.022954321393361815
# At iteration 24 the best fitness is 0.022954321393361815
# At iteration 25 the best fitness is 0.02287216562602695
# At iteration 26 the best fitness is 0.022806441012159055
# At iteration 27 the best fitness is 0.022806441012159055
# At iteration 28 the best fitness is 0.02274071639829116
# At iteration 29 the best fitness is 0.02269142293789024
# At iteration 30 the best fitness is 0.02269142293789024
#       Selected: 1381/3043 (45.4%), Fitness: 0.0227, Time: 763.1s
#       Modality: D=43%, S=45%, Sk=46%,
#     Test Acc: 92.53%, F1: 92.63%, Features: 1381/3043 (45.4%), Model: 3.233MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024219520210318767']
# ['At iteration 1 the best fitness is 0.023167926388432472']
# ['At iteration 2 the best fitness is 0.0220999014130792']
# ['At iteration 3 the best fitness is 0.02093328951692409']
# ['At iteration 4 the best fitness is 0.020276043378245154']
# ['At iteration 5 the best fitness is 0.019355898784094647']
# ['At iteration 6 the best fitness is 0.018419323036477163']
# ['At iteration 7 the best fitness is 0.017597765363128494']
# ['At iteration 8 the best fitness is 0.017186986526454156']
# ['At iteration 9 the best fitness is 0.01583963194216234']
# ['At iteration 10 the best fitness is 0.015511008872822874']
# ['At iteration 11 the best fitness is 0.01462372658560631']
# ['At iteration 12 the best fitness is 0.014065067367729216']
# ['At iteration 13 the best fitness is 0.013654288531054881']
# ['At iteration 14 the best fitness is 0.013128491620111732']
# ['At iteration 15 the best fitness is 0.012832730857706212']
# ['At iteration 16 the best fitness is 0.012635557016102531']
# ['At iteration 17 the best fitness is 0.012602694709168583']
# ['At iteration 18 the best fitness is 0.012405520867564905']
# ['At iteration 19 the best fitness is 0.012109760105159384']
# ['At iteration 20 the best fitness is 0.012044035491291488']
# ['At iteration 21 the best fitness is 0.011846861649687809']
# ['At iteration 22 the best fitness is 0.011797568189286888']
# ['At iteration 23 the best fitness is 0.011715412421952022']
# ['At iteration 24 the best fitness is 0.011616825501150181']
# ['At iteration 25 the best fitness is 0.011501807426881368']
# ['At iteration 26 the best fitness is 0.01137035819914558']
# ['At iteration 27 the best fitness is 0.011288202431810715']
# ['At iteration 28 the best fitness is 0.011238908971409793']
# ['At iteration 29 the best fitness is 0.011238908971409793']
#       Selected: 684/3043 (22.5%), Fitness: 0.0112, Time: 741.8s
#       Modality: D=18%, S=24%, Sk=23%,
#     Test Acc: 92.53%, F1: 92.64%, Features: 684/3043 (22.5%), Model: 1.872MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.024153795596450874']
# ['At iteration 1 the best fitness is 0.010745974367400593']
# ['At iteration 2 the best fitness is 0.01025303976339139']
# ['At iteration 3 the best fitness is 0.01025303976339139']
# ['At iteration 4 the best fitness is 0.01025303976339139']
# ['At iteration 5 the best fitness is 0.009267170555372987']
# ['At iteration 6 the best fitness is 0.0058823529411764705']
# ['At iteration 7 the best fitness is 0.0058823529411764705']
# ['At iteration 8 the best fitness is 0.005734472559973711']
# ['At iteration 9 the best fitness is 0.004765034505422281']
# ['At iteration 10 the best fitness is 0.004765034505422281']
# ['At iteration 11 the best fitness is 0.004765034505422281']
# ['At iteration 12 the best fitness is 0.004765034505422281']
# ['At iteration 13 the best fitness is 0.004765034505422281']
# ['At iteration 14 the best fitness is 0.004765034505422281']
# ['At iteration 15 the best fitness is 0.004682878738087414']
# ['At iteration 16 the best fitness is 0.004682878738087414']
# ['At iteration 17 the best fitness is 0.004288531054880053']
# ['At iteration 18 the best fitness is 0.004288531054880053']
# ['At iteration 19 the best fitness is 0.004288531054880053']
# ['At iteration 20 the best fitness is 0.004272099901413079']
# ['At iteration 21 the best fitness is 0.0042392375944791325']
# ['At iteration 22 the best fitness is 0.004074926059809399']
# ['At iteration 23 the best fitness is 0.004058494906342426']
# ['At iteration 24 the best fitness is 0.004058494906342426']
# ['At iteration 25 the best fitness is 0.004058494906342426']
# ['At iteration 26 the best fitness is 0.004058494906342426']
# ['At iteration 27 the best fitness is 0.0037955964508708515']
# ['At iteration 28 the best fitness is 0.0037955964508708515']
# ['At iteration 29 the best fitness is 0.003713440683535985']
#       Selected: 226/3043 (7.4%), Fitness: 0.0037, Time: 934.3s
#       Modality: D=8%, S=8%, Sk=7%,
#     Test Acc: 87.97%, F1: 88.62%, Features: 226/3043 (7.4%), Model: 0.811MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023874465987512323']
# ['At iteration 1 the best fitness is 0.023775879066710484']
# ['At iteration 2 the best fitness is 0.023775879066710484']
# ['At iteration 3 the best fitness is 0.023775879066710484']
# ['At iteration 4 the best fitness is 0.023775879066710484']
# ['At iteration 5 the best fitness is 0.02375944791324351']
# ['At iteration 6 the best fitness is 0.02371015445284259']
# ['At iteration 7 the best fitness is 0.02361156753204075']
# ['At iteration 8 the best fitness is 0.02361156753204075']
# ['At iteration 9 the best fitness is 0.02361156753204075']
# ['At iteration 10 the best fitness is 0.02361156753204075']
# ['At iteration 11 the best fitness is 0.02361156753204075']
# ['At iteration 12 the best fitness is 0.02361156753204075']
# ['At iteration 13 the best fitness is 0.023496549457771937']
# ['At iteration 14 the best fitness is 0.023496549457771937']
# ['At iteration 15 the best fitness is 0.023496549457771937']
# ['At iteration 16 the best fitness is 0.023496549457771937']
# ['At iteration 17 the best fitness is 0.023496549457771937']
# ['At iteration 18 the best fitness is 0.023496549457771937']
# ['At iteration 19 the best fitness is 0.023348669076569177']
# ['At iteration 20 the best fitness is 0.023348669076569177']
# ...
# ['At iteration 15 the best fitness is 0.04708070900768106']
# ['At iteration 16 the best fitness is 0.04708070900768106']
# ['At iteration 17 the best fitness is 0.04708070900768106']
# ['At iteration 18 the best fitness is 0.04708070900768106']
# ['At iteration 19 the best fitness is 0.04708070900768106']
# ['At iteration 20 the best fitness is 0.04708070900768106']
# ['At iteration 21 the best fitness is 0.04708070900768106']
# ['At iteration 22 the best fitness is 0.04708070900768106']
# ['At iteration 23 the best fitness is 0.04008417386751176']
# ['At iteration 24 the best fitness is 0.04008417386751176']
# ['At iteration 25 the best fitness is 0.04008417386751176']
# ['At iteration 26 the best fitness is 0.04008417386751176']
# ['At iteration 27 the best fitness is 0.04008417386751176']
# ['At iteration 28 the best fitness is 0.04008417386751176']
# ['At iteration 29 the best fitness is 0.04008417386751176']
#       Selected: 1240/3043 (40.7%), Fitness: 0.0401, Time: 1031.4s
#       Modality: D=39%, S=40%, Sk=41%,
#     Test Acc: 90.91%, F1: 88.76%, Features: 1240/3043 (40.7%), Model: 2.958MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04916903361636736']
# ['At iteration 1 the best fitness is 0.04916903361636736']
# ['At iteration 2 the best fitness is 0.04916903361636736']
# ['At iteration 3 the best fitness is 0.04916903361636736']
# ['At iteration 4 the best fitness is 0.04916903361636736']
# ['At iteration 5 the best fitness is 0.04844606286382053']
# ['At iteration 6 the best fitness is 0.04844606286382053']
# ['At iteration 7 the best fitness is 0.04844606286382053']
# ['At iteration 8 the best fitness is 0.04844606286382053']
# ['At iteration 9 the best fitness is 0.04844606286382053']
# ['At iteration 10 the best fitness is 0.04844606286382053']
# ['At iteration 11 the best fitness is 0.04844606286382053']
# ['At iteration 12 the best fitness is 0.04844606286382053']
# ['At iteration 13 the best fitness is 0.04471775914519825']
# ['At iteration 14 the best fitness is 0.04471775914519825']
# ['At iteration 15 the best fitness is 0.04471775914519825']
# ['At iteration 16 the best fitness is 0.04471775914519825']
# ['At iteration 17 the best fitness is 0.04471775914519825']
# ['At iteration 18 the best fitness is 0.04432341146199089']
# ['At iteration 19 the best fitness is 0.04052938312950072']
# ['At iteration 20 the best fitness is 0.04052938312950072']
# ['At iteration 21 the best fitness is 0.04052938312950072']
# ['At iteration 22 the best fitness is 0.04052938312950072']
# ['At iteration 23 the best fitness is 0.04052938312950072']
# ['At iteration 24 the best fitness is 0.04005287967895849']
# ['At iteration 25 the best fitness is 0.04005287967895849']
# ['At iteration 26 the best fitness is 0.04005287967895849']
# ['At iteration 27 the best fitness is 0.04005287967895849']
# ['At iteration 28 the best fitness is 0.04005287967895849']
# ['At iteration 29 the best fitness is 0.04005287967895849']
#       Selected: 1478/3043 (48.6%), Fitness: 0.0401, Time: 831.6s
#       Modality: D=47%, S=48%, Sk=49%,
#     Test Acc: 94.95%, F1: 93.43%, Features: 1478/3043 (48.6%), Model: 3.423MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05616556875653666']
# ['At iteration 2 the best fitness is 0.04773952326474067']
# ['At iteration 3 the best fitness is 0.04773952326474067']
# ['At iteration 4 the best fitness is 0.04773952326474067']
# ['At iteration 5 the best fitness is 0.04773952326474067']
# ['At iteration 6 the best fitness is 0.04773952326474067']
# ['At iteration 7 the best fitness is 0.04773952326474067']
# ['At iteration 8 the best fitness is 0.04773952326474067']
# ['At iteration 9 the best fitness is 0.04773952326474067']
# ['At iteration 10 the best fitness is 0.04773952326474067']
# ['At iteration 11 the best fitness is 0.04773952326474067']
# ['At iteration 12 the best fitness is 0.04773952326474067']
# ['At iteration 13 the best fitness is 0.04773952326474067']
# ['At iteration 14 the best fitness is 0.043764752244113796']
# ['At iteration 15 the best fitness is 0.043764752244113796']
# ['At iteration 16 the best fitness is 0.043764752244113796']
# ['At iteration 17 the best fitness is 0.043764752244113796']
# ['At iteration 18 the best fitness is 0.043764752244113796']
# ['At iteration 19 the best fitness is 0.043764752244113796']
# ['At iteration 20 the best fitness is 0.043764752244113796']
# ['At iteration 21 the best fitness is 0.043764752244113796']
# ['At iteration 22 the best fitness is 0.043764752244113796']
# ['At iteration 23 the best fitness is 0.043764752244113796']
# ['At iteration 24 the best fitness is 0.04340326686784038']
# ['At iteration 25 the best fitness is 0.04340326686784038']
# ['At iteration 26 the best fitness is 0.04340326686784038']
# ['At iteration 27 the best fitness is 0.04340326686784038']
# ['At iteration 28 the best fitness is 0.04340326686784038']
# ['At iteration 29 the best fitness is 0.04340326686784038']
#       Selected: 1442/3043 (47.4%), Fitness: 0.0434, Time: 785.5s
#       Modality: D=47%, S=47%, Sk=48%,
#     Test Acc: 94.95%, F1: 94.59%, Features: 1442/3043 (47.4%), Model: 3.353MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.052157935428975837']
# ['At iteration 2 the best fitness is 0.05184574351310334']
# ['At iteration 3 the best fitness is 0.05184574351310334']
# ['At iteration 4 the best fitness is 0.05184574351310334']
# ['At iteration 5 the best fitness is 0.05184574351310334']
# ['At iteration 6 the best fitness is 0.05184574351310334']
# ['At iteration 7 the best fitness is 0.05184574351310334']
# ['At iteration 8 the best fitness is 0.05178001889923545']
# ['At iteration 9 the best fitness is 0.04815030210141501']
# ['At iteration 10 the best fitness is 0.04815030210141501']
# ['At iteration 11 the best fitness is 0.04815030210141501']
# ['At iteration 12 the best fitness is 0.04815030210141501']
# ['At iteration 13 the best fitness is 0.04412623762038721']
# ['At iteration 14 the best fitness is 0.04412623762038721']
# ['At iteration 15 the best fitness is 0.04412623762038721']
# ['At iteration 16 the best fitness is 0.04412623762038721']
# ['At iteration 17 the best fitness is 0.04412623762038721']
# ['At iteration 18 the best fitness is 0.04412623762038721']
# ['At iteration 19 the best fitness is 0.04412623762038721']
# ['At iteration 20 the best fitness is 0.04412623762038721']
# ['At iteration 21 the best fitness is 0.04412623762038721']
# ['At iteration 22 the best fitness is 0.04412623762038721']
# ['At iteration 23 the best fitness is 0.04412623762038721']
# ['At iteration 24 the best fitness is 0.04412623762038721']
# ['At iteration 25 the best fitness is 0.04412623762038721']
# ['At iteration 26 the best fitness is 0.04412623762038721']
# ['At iteration 27 the best fitness is 0.04412623762038721']
# ['At iteration 28 the best fitness is 0.04412623762038721']
# ['At iteration 29 the best fitness is 0.04412623762038721']
# ['At iteration 30 the best fitness is 0.04412623762038721']
#       Selected: 1486/3043 (48.8%), Fitness: 0.0441, Time: 807.8s
#       Modality: D=46%, S=47%, Sk=50%,
#     Test Acc: 91.92%, F1: 90.28%, Features: 1486/3043 (48.8%), Model: 3.439MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04916903361636736']
# ['At iteration 2 the best fitness is 0.04916903361636736']
# ['At iteration 3 the best fitness is 0.04916903361636736']
# ['At iteration 4 the best fitness is 0.04916903361636736']
# ['At iteration 5 the best fitness is 0.04916903361636736']
# ['At iteration 6 the best fitness is 0.04916903361636736']
# ['At iteration 7 the best fitness is 0.04916903361636736']
# ['At iteration 8 the best fitness is 0.04916903361636736']
# ['At iteration 9 the best fitness is 0.04916903361636736']
# ['At iteration 10 the best fitness is 0.04916903361636736']
# ['At iteration 11 the best fitness is 0.04916903361636736']
# ['At iteration 12 the best fitness is 0.04916903361636736']
# ['At iteration 13 the best fitness is 0.04916903361636736']
# ['At iteration 14 the best fitness is 0.04916903361636736']
# ['At iteration 15 the best fitness is 0.048363907096485664']
# ['At iteration 16 the best fitness is 0.048363907096485664']
# ['At iteration 17 the best fitness is 0.048363907096485664']
# ['At iteration 18 the best fitness is 0.048363907096485664']
# ['At iteration 19 the best fitness is 0.048363907096485664']
# ['At iteration 20 the best fitness is 0.048363907096485664']
# ['At iteration 21 the best fitness is 0.048363907096485664']
# ['At iteration 22 the best fitness is 0.048363907096485664']
# ['At iteration 23 the best fitness is 0.048363907096485664']
# ['At iteration 24 the best fitness is 0.048363907096485664']
# ['At iteration 25 the best fitness is 0.048363907096485664']
# ['At iteration 26 the best fitness is 0.048363907096485664']
# ['At iteration 27 the best fitness is 0.048363907096485664']
# ['At iteration 28 the best fitness is 0.048363907096485664']
# ['At iteration 29 the best fitness is 0.048363907096485664']
# ['At iteration 30 the best fitness is 0.048363907096485664']
#       Selected: 1504/3043 (49.4%), Fitness: 0.0484, Time: 804.9s
#       Modality: D=48%, S=52%, Sk=49%,
#     Test Acc: 94.95%, F1: 94.28%, Features: 1504/3043 (49.4%), Model: 3.474MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.056066981835734817']
# ['At iteration 1 the best fitness is 0.0512542219882923']
# ['At iteration 2 the best fitness is 0.05003831663173627']
# ['At iteration 3 the best fitness is 0.047836542067161834']
# ['At iteration 4 the best fitness is 0.047836542067161834']
# ['At iteration 5 the best fitness is 0.047836542067161834']
# ['At iteration 6 the best fitness is 0.047836542067161834']
# ['At iteration 7 the best fitness is 0.047836542067161834']
# ['At iteration 8 the best fitness is 0.046487619364489335']
# ['At iteration 9 the best fitness is 0.046487619364489335']
# ['At iteration 10 the best fitness is 0.046487619364489335']
# ['At iteration 11 the best fitness is 0.046487619364489335']
# ['At iteration 12 the best fitness is 0.046487619364489335']
# ['At iteration 13 the best fitness is 0.046487619364489335']
# ['At iteration 14 the best fitness is 0.046487619364489335']
# ['At iteration 15 the best fitness is 0.04297135252255704']
# ['At iteration 16 the best fitness is 0.04221551946307626']
# ['At iteration 17 the best fitness is 0.04221551946307626']
# ['At iteration 18 the best fitness is 0.037435621922567684']
# ['At iteration 19 the best fitness is 0.037435621922567684']
# ['At iteration 20 the best fitness is 0.03280360476326187']
# ['At iteration 21 the best fitness is 0.03267215553552608']
# ['At iteration 22 the best fitness is 0.03267215553552608']
# ['At iteration 23 the best fitness is 0.03267215553552608']
# ['At iteration 24 the best fitness is 0.03267215553552608']
# ['At iteration 25 the best fitness is 0.03267215553552608']
# ['At iteration 26 the best fitness is 0.03267215553552608']
# ['At iteration 27 the best fitness is 0.03267215553552608']
# ['At iteration 28 the best fitness is 0.03267215553552608']
# ['At iteration 29 the best fitness is 0.03219565208498386']
#       Selected: 520/3043 (17.1%), Fitness: 0.0322, Time: 763.4s
#       Modality: D=18%, S=17%, Sk=17%,
#     Test Acc: 93.43%, F1: 92.39%, Features: 520/3043 (17.1%), Model: 1.552MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05271659464685293']
# ['At iteration 2 the best fitness is 0.05271659464685293']
# ['At iteration 3 the best fitness is 0.05271659464685293']
# ['At iteration 4 the best fitness is 0.04841320055688658']
# ['At iteration 5 the best fitness is 0.04841320055688658']
# ['At iteration 6 the best fitness is 0.0449970887541368']
# ['At iteration 7 the best fitness is 0.0449970887541368']
# ['At iteration 8 the best fitness is 0.0449970887541368']
# ['At iteration 9 the best fitness is 0.04498065760066983']
# ['At iteration 10 the best fitness is 0.04498065760066983']
# ['At iteration 11 the best fitness is 0.04481634606600009']
# ['At iteration 12 the best fitness is 0.04481634606600009']
# ['At iteration 13 the best fitness is 0.04481634606600009']
# ['At iteration 14 the best fitness is 0.04120306042164663']
# ['At iteration 15 the best fitness is 0.04102231773350992']
# ['At iteration 16 the best fitness is 0.03706397786634991']
# ['At iteration 17 the best fitness is 0.03706397786634991']
# ['At iteration 18 the best fitness is 0.03706397786634991']
# ['At iteration 19 the best fitness is 0.03706397786634991']
# ['At iteration 20 the best fitness is 0.03706397786634991']
# ['At iteration 21 the best fitness is 0.03706397786634991']
# ['At iteration 22 the best fitness is 0.03706397786634991']
# ['At iteration 23 the best fitness is 0.03706397786634991']
# ['At iteration 24 the best fitness is 0.03706397786634991']
# ['At iteration 25 the best fitness is 0.03706397786634991']
# ['At iteration 26 the best fitness is 0.03706397786634991']
# ['At iteration 27 the best fitness is 0.03706397786634991']
# ['At iteration 28 the best fitness is 0.03706397786634991']
# ['At iteration 29 the best fitness is 0.03706397786634991']
#       Selected: 1536/3043 (50.5%), Fitness: 0.0371, Time: 2022.1s
#       Modality: D=53%, S=51%, Sk=50%,
#     Test Acc: 96.46%, F1: 96.41%, Features: 1536/3043 (50.5%), Model: 3.536MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05281518156765477']
# ['At iteration 1 the best fitness is 0.038421491130586086']
# ['At iteration 2 the best fitness is 0.01984412903296181']
# ['At iteration 3 the best fitness is 0.01984412903296181']
# ['At iteration 4 the best fitness is 0.01984412903296181']
# ['At iteration 5 the best fitness is 0.01984412903296181']
# ['At iteration 6 the best fitness is 0.01984412903296181']
# ['At iteration 7 the best fitness is 0.01984412903296181']
# ['At iteration 8 the best fitness is 0.01984412903296181']
# ['At iteration 9 the best fitness is 0.01984412903296181']
# ['At iteration 10 the best fitness is 0.01984412903296181']
# ['At iteration 11 the best fitness is 0.01984412903296181']
# ['At iteration 12 the best fitness is 0.01984412903296181']
# ['At iteration 13 the best fitness is 0.01984412903296181']
# ['At iteration 14 the best fitness is 0.01984412903296181']
# ['At iteration 15 the best fitness is 0.01984412903296181']
# ['At iteration 16 the best fitness is 0.01984412903296181']
# ['At iteration 17 the best fitness is 0.01984412903296181']
# ['At iteration 18 the best fitness is 0.01984412903296181']
# ['At iteration 19 the best fitness is 0.01984412903296181']
# ['At iteration 20 the best fitness is 0.01984412903296181']
# ['At iteration 21 the best fitness is 0.01984412903296181']
# ['At iteration 22 the best fitness is 0.01984412903296181']
# ['At iteration 23 the best fitness is 0.01984412903296181']
# ['At iteration 24 the best fitness is 0.01984412903296181']
# ['At iteration 25 the best fitness is 0.01984412903296181']
# ['At iteration 26 the best fitness is 0.01984412903296181']
# ['At iteration 27 the best fitness is 0.01984412903296181']
# ['At iteration 28 the best fitness is 0.01984412903296181']
# ['At iteration 29 the best fitness is 0.01984412903296181']
#       Selected: 488/3043 (16.0%), Fitness: 0.0198, Time: 745.2s
#       Modality: D=17%, S=14%, Sk=16%,
#     Test Acc: 94.44%, F1: 94.26%, Features: 488/3043 (16.0%), Model: 1.489MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879}, Total: 3043
# Results table: (90, 32)
# Methods: 18, Folds per method: {'baseline': 5, 'lasso': 5, 'meta_BAT': 5, 'meta_CS': 5, 'meta_DE': 5, 'meta_FFA': 5, 'meta_GA': 5, 'meta_GWO': 5, 'meta_HHO': 5, 'meta_JAYA': 5, 'meta_MFO': 5, 'meta_MVO': 5, 'meta_PSO': 5, 'meta_SCA': 5, 'meta_SSA': 5, 'meta_WOA': 5, 'mutual_info': 5, 'rfe': 5}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          96.153846         99.494949     96.081729
# 1  baseline     2          93.360996        100.000000     93.406464
# 2  baseline     3          96.818182        100.000000     96.754267
# 3  baseline     4          91.363636        100.000000     90.529265
# 4  baseline     5          92.424242         96.680498     90.439290
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        96.081729            96.723485         96.153846               3043
# 1        93.400944            94.530186         93.347107               3043
# 2        96.754267            97.488875         96.818182               3043
# 3        90.529265            93.536299         91.363636               3043
# 4        90.439290            91.103896         92.424242               3043
#
#    Features Total  ...  N Test  depth_retained  depth_total  \
# 0            3043  ...     286             512          512
# 1            3043  ...     241             512          512
# 2            3043  ...     220             512          512
# 3            3043  ...     220             512          512
# 4            3043  ...     198             512          512
#
#    depth_retention_%  sensor_retained  sensor_total  sensor_retention_%  \
# 0              100.0              652           652               100.0
# 1              100.0              652           652               100.0
# 2              100.0              652           652               100.0
# 3              100.0              652           652               100.0
# 4              100.0              652           652               100.0
#
#    skeleton_retained  skeleton_total  skeleton_retention_%
# 0               1879            1879                 100.0
# 1               1879            1879                 100.0
# 2               1879            1879                 100.0
# 3               1879            1879                 100.0
# 4               1879            1879                 100.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              94.02              2.37              93.44              2.98                  3043.0                      100.00              0.00                17.14                17.14          1697046.0                  6.48                        0.00               55.48
# mutual_info              93.94              2.82              93.32              3.46                  1521.0                       49.98             30.43                13.73                44.15           917782.0                  3.51                       50.02               37.46
#         rfe              95.60              2.56              95.53              2.56                  1521.0                       49.98              4.99                13.62                18.61           917782.0                  3.51                       50.02               37.46
#       lasso              94.51              2.61              94.34              2.64                  1521.0                       49.98             91.49                13.74               105.23           917782.0                  3.51                       50.02               37.46
#    meta_BAT              94.13              2.08              93.87              2.15                  1454.2                       47.79            824.74                13.66               838.40           883580.4                  3.38                       52.21               37.19
#     meta_CS              94.68              3.18              94.23              3.49                  1452.0                       47.72           1632.47                13.87              1646.34           882454.0                  3.37                       52.28               37.18
#     meta_DE              94.22              2.52              93.97              2.81                  1397.6                       45.93            816.78                13.52               830.30           854601.2                  3.27                       54.07               36.96
#    meta_FFA              94.88              2.97              94.71              3.13                  1425.4                       46.84            788.21                13.57               801.78           868834.8                  3.32                       53.16               37.07
#     meta_GA              95.40              2.34              95.20              2.54                  1436.2                       47.20            782.77                13.48               796.25           874364.4                  3.34                       52.80               37.11
#    meta_GWO              94.45              1.73              94.31              1.78                   928.0                       30.50            768.36                12.80               781.17           614166.0                  2.35                       69.50               31.03
#    meta_HHO              91.44              3.50              90.91              3.54                   475.4                       15.62            984.28                12.61               996.88           350722.8                  1.34                       84.38               24.55
#   meta_JAYA              94.87              1.58              94.48              1.71                  1418.0                       46.60            821.30                13.72               835.02           865046.0                  3.31                       53.40               37.04
#    meta_MFO              94.90              2.54              94.75              2.59                  1432.6                       47.08            769.54                13.72               783.27           872521.2                  3.33                       52.92               37.10
#    meta_MVO              93.83              3.67              93.28              4.16                  1395.0                       45.84            800.26                13.49               813.76           853270.0                  3.26                       54.16               36.95
#    meta_PSO              95.12              2.20              95.01              2.23                  1366.4                       44.90            789.91                13.64               803.55           838626.8                  3.20                       55.10               36.83
#    meta_SCA              92.04              3.83              91.52              4.23                   345.8                       11.36            767.80                12.60               780.39           309764.6                  1.19                       88.64               23.64
#    meta_SSA              95.74              2.59              95.60              2.67                  1422.2                       46.74           2019.21                13.59              2032.79           867196.4                  3.31                       53.26               37.08
#    meta_WOA              93.75              4.28              93.63              4.49                   403.6                       13.26            697.01                12.51               709.51           328266.6                  1.26                       86.74               24.05

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
print("=" * 80)
print("FILE 2 COMPLETE — FEATURE SELECTION ON WEIGHTED FEATURES")
print("=" * 80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nModality weights used (from File 1):")
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']} -> [{w_str}]")

print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'=' * 80}")
print("RESULTS (sorted by mean test accuracy):")
print("=" * 80)
for _, row in df_summary.iterrows():
    print(f"  {row['Method']:20s} | Acc: {row['Mean Test Acc (%)']:6.2f}% "
          f"(+/-{row['Std Test Acc (%)']:.2f}) | F1: {row['Mean F1 Macro (%)']:6.2f}% "
          f"| Feat: {row['Mean Feature Retention (%)']:.1f}%")
# Out:
# ================================================================================
# FILE 2 COMPLETE — FEATURE SELECTION ON WEIGHTED FEATURES
# ================================================================================
#
# Output directory: results_weighted_fs
#
# Modality weights used (from File 1):
#   Fold 1: weighted_PSO -> [depth=0.974, sensor=0.803, skeleton=0.211]
#   Fold 2: weighted_MVO -> [depth=0.644, sensor=0.817, skeleton=0.856]
#   Fold 3: weighted_GWO -> [depth=0.104, sensor=0.765, skeleton=0.710]
#   Fold 4: weighted_BAT -> [depth=0.459, sensor=0.591, skeleton=0.542]
#   Fold 5: weighted_HHO -> [depth=0.732, sensor=0.752, skeleton=0.041]
#
# Per-method folders:
#   results_weighted_fs/baseline/ (10 files)
#   results_weighted_fs/mutual_info/ (10 files)
#   results_weighted_fs/rfe/ (10 files)
#   results_weighted_fs/lasso/ (10 files)
#   results_weighted_fs/meta_BAT/ (10 files)
#   results_weighted_fs/meta_CS/ (10 files)
#   results_weighted_fs/meta_DE/ (10 files)
#   results_weighted_fs/meta_FFA/ (10 files)
#   results_weighted_fs/meta_GA/ (10 files)
#   results_weighted_fs/meta_GWO/ (10 files)
#   results_weighted_fs/meta_HHO/ (10 files)
#   results_weighted_fs/meta_JAYA/ (10 files)
#   results_weighted_fs/meta_MFO/ (10 files)
#   results_weighted_fs/meta_MVO/ (10 files)
#   results_weighted_fs/meta_PSO/ (10 files)
#   results_weighted_fs/meta_SCA/ (10 files)
#   results_weighted_fs/meta_SSA/ (10 files)
#   results_weighted_fs/meta_WOA/ (10 files)
#
# Plots directory: results_weighted_fs/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_folds_results.csv
#   summary_all_methods.csv
#
# ================================================================================
# RESULTS (sorted by mean test accuracy):
# ================================================================================
#   baseline             | Acc:  94.02% (+/-2.37) | F1:  93.44% | Feat: 100.0%
#   mutual_info          | Acc:  93.94% (+/-2.82) | F1:  93.32% | Feat: 50.0%
#   rfe                  | Acc:  95.60% (+/-2.56) | F1:  95.53% | Feat: 50.0%
#   lasso                | Acc:  94.51% (+/-2.61) | F1:  94.34% | Feat: 50.0%
#   meta_BAT             | Acc:  94.13% (+/-2.08) | F1:  93.87% | Feat: 47.8%
#   meta_CS              | Acc:  94.68% (+/-3.18) | F1:  94.23% | Feat: 47.7%
#   meta_DE              | Acc:  94.22% (+/-2.52) | F1:  93.97% | Feat: 45.9%
#   meta_FFA             | Acc:  94.88% (+/-2.97) | F1:  94.71% | Feat: 46.8%
#   meta_GA              | Acc:  95.40% (+/-2.34) | F1:  95.20% | Feat: 47.2%
#   meta_GWO             | Acc:  94.45% (+/-1.73) | F1:  94.31% | Feat: 30.5%
#   meta_HHO             | Acc:  91.44% (+/-3.50) | F1:  90.91% | Feat: 15.6%
#   meta_JAYA            | Acc:  94.87% (+/-1.58) | F1:  94.48% | Feat: 46.6%
#   meta_MFO             | Acc:  94.90% (+/-2.54) | F1:  94.75% | Feat: 47.1%
#   meta_MVO             | Acc:  93.83% (+/-3.67) | F1:  93.28% | Feat: 45.8%
#   meta_PSO             | Acc:  95.12% (+/-2.20) | F1:  95.01% | Feat: 44.9%
#   meta_SCA             | Acc:  92.04% (+/-3.83) | F1:  91.52% | Feat: 11.4%
#   meta_SSA             | Acc:  95.74% (+/-2.59) | F1:  95.60% | Feat: 46.7%
#   meta_WOA             | Acc:  93.75% (+/-4.28) | F1:  93.63% | Feat: 13.3%

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_FFA
#     F1 Macro:           97.57%
#     F1 Weighted:        97.57%
#     Test Accuracy:      97.55%
#     Feature Retention:  47.88% (1457/3043)
#     Modality Retention: depth=46.3%, sensor=48.6%, skeleton=48.1%
#
#   Fold 2: Best = meta_JAYA
#     F1 Macro:           93.47%
#     F1 Weighted:        93.46%
#     Test Accuracy:      93.36%
#     Feature Retention:  45.94% (1398/3043)
#     Modality Retention: depth=48.0%, sensor=42.2%, skeleton=46.7%
#
#   Fold 3: Best = meta_CS
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  47.03% (1431/3043)
#     Modality Retention: depth=46.1%, sensor=47.4%, skeleton=47.2%
#
#   Fold 4: Best = meta_GA
#     F1 Macro:           96.28%
#     F1 Weighted:        96.28%
#     Test Accuracy:      96.36%
#     Feature Retention:  46.47% (1414/3043)
#     Modality Retention: depth=47.1%, sensor=45.7%, skeleton=46.6%
#
#   Fold 5: Best = meta_SSA
#     F1 Macro:           96.41%
#     F1 Weighted:        96.41%
#     Test Accuracy:      96.46%
#     Feature Retention:  50.48% (1536/3043)
#     Modality Retention: depth=53.1%, sensor=50.9%, skeleton=49.6%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 96.74% ± 2.36%
#
#   Average F1 Weighted         : 96.74% ± 2.37%
#
#   Average Test Accuracy       : 96.75% ± 2.39%
#
#   Average Feature Retention   : 47.56% ± 1.78%
#
#   Average Modality-wise Feature Retention:
#            depth: 48.12% ± 2.90%
#           sensor: 46.96% ± 3.28%
#         skeleton: 47.61% ± 1.26%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%
#     1           meta_FFA         97.57            97.57              97.55                  47.88              46.29               48.62                 48.06
#     2          meta_JAYA         93.47            93.46              93.36                  45.94              48.05               42.18                 46.67
#     3            meta_CS        100.00           100.00             100.00                  47.03              46.09               47.39                 47.15
#     4            meta_GA         96.28            96.28              96.36                  46.47              47.07               45.71                 46.57
#     5           meta_SSA         96.41            96.41              96.46                  50.48              53.12               50.92                 49.60
#
# Saved to: results_weighted_fs/best_metaheuristic_per_fold.csv
