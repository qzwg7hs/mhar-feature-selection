# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
# # **Transformer Encoder (Modality-Token) Model**
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# **Model:** Transformer Encoder with modality tokens — each modality (depth, sensor, skeleton) is treated as a separate token.
# Feature selection masks are applied per-modality before projection.

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_transformer")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   TOTAL: 8039
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Transformer Encoder with Modality Tokens)

# %%
import math

class MultiModalDataset(Dataset):
    """Dataset that returns per-modality features as separate tensors + label."""
    def __init__(self, X_feat_list, labels, feature_dims, feature_mask=None):
        """
        X_feat_list : list of dicts with keys 'depth_feat', 'sensor_feat', 'skeleton_feat'
        labels      : np.array of int labels
        feature_dims: dict {modality_name: dim} — used to split a unified masked vector
        feature_mask: optional boolean mask over the concatenated feature vector
        """
        self.labels = torch.LongTensor(labels)
        self.modality_names = list(feature_dims.keys())  # fixed order

        # Build per-modality arrays
        modality_arrays = {m: [] for m in self.modality_names}

        for sample in X_feat_list:
            concat = np.concatenate([
                sample['depth_feat'],
                sample['sensor_feat'],
                sample['skeleton_feat']
            ])
            if feature_mask is not None:
                concat = concat[feature_mask]

            # Split back into per-modality chunks
            # When a mask is applied, we need per-modality sizes from the mask
            if feature_mask is not None:
                start = 0
                for m_name in self.modality_names:
                    m_dim = feature_dims[m_name]  # original dim
                    modality_arrays[m_name].append(concat[start:start + m_dim])
                    start += m_dim
            else:
                start = 0
                for m_name in self.modality_names:
                    m_dim = feature_dims[m_name]
                    modality_arrays[m_name].append(concat[start:start + m_dim])
                    start += m_dim

        self.modality_tensors = {}
        for m_name in self.modality_names:
            self.modality_tensors[m_name] = torch.FloatTensor(np.array(modality_arrays[m_name]))

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        # Return dict of modality tensors + label
        mod_feats = {m: self.modality_tensors[m][idx] for m in self.modality_names}
        return mod_feats, self.labels[idx]


class MultiModalDatasetFromUnified(Dataset):
    """Dataset that takes a pre-built unified (and optionally masked) numpy array
    and splits it back into per-modality chunks for the Transformer.
    This is the drop-in replacement used wherever the original code passes
    a unified numpy matrix (after scaling, after feature selection, etc.)."""

    def __init__(self, X_unified, labels, modality_dims_after_mask):
        """
        X_unified              : np.array (N, total_selected_features)
        labels                 : np.array (N,)
        modality_dims_after_mask: dict {modality: dim_after_mask} — how many features
                                  each modality contributes AFTER masking
        """
        self.labels = torch.LongTensor(labels)
        self.modality_names = list(modality_dims_after_mask.keys())

        self.modality_tensors = {}
        start = 0
        for m_name in self.modality_names:
            m_dim = modality_dims_after_mask[m_name]
            self.modality_tensors[m_name] = torch.FloatTensor(X_unified[:, start:start + m_dim])
            start += m_dim

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        mod_feats = {m: self.modality_tensors[m][idx] for m in self.modality_names}
        return mod_feats, self.labels[idx]


def get_modality_dims_after_mask(feature_mask, feature_dims):
    """Given a boolean mask over the concatenated feature vector,
    compute how many features survive per modality."""
    dims = {}
    start = 0
    for m_name, m_dim in feature_dims.items():
        dims[m_name] = int(np.sum(feature_mask[start:start + m_dim]))
        start += m_dim
    return dims


class ModalityTokenTransformer(nn.Module):
    """
    Transformer Encoder that treats each modality as a separate token.

    1. Each modality is projected to a shared embedding dimension via a
       modality-specific linear layer.
    2. A learnable modality-type embedding is added.
    3. A learnable [CLS] token is prepended.
    4. Tokens pass through a standard Transformer encoder.
    5. The [CLS] output is fed to a classification head.
    """

    def __init__(self, modality_dims, num_classes, d_model=128, nhead=4,
                 num_layers=2, dim_feedforward=256, dropout=0.3):
        """
        modality_dims : dict {modality_name: feature_dim_after_mask}
        """
        super().__init__()
        self.modality_names = list(modality_dims.keys())
        self.d_model = d_model
        self.num_modalities = len(self.modality_names)

        # Per-modality projection to d_model
        self.modality_projections = nn.ModuleDict()
        for m_name, m_dim in modality_dims.items():
            if m_dim > 0:
                self.modality_projections[m_name] = nn.Sequential(
                    nn.Linear(m_dim, d_model),
                    nn.LayerNorm(d_model),
                    nn.ReLU(),
                    nn.Dropout(dropout),
                )
            else:
                # If mask removed all features from this modality, use a dummy
                self.modality_projections[m_name] = None

        # Learnable modality-type embeddings (one per modality)
        self.modality_embeddings = nn.Embedding(self.num_modalities, d_model)

        # Learnable [CLS] token
        self.cls_token = nn.Parameter(torch.randn(1, 1, d_model) * 0.02)

        # Transformer encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
            activation='gelu',
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer, num_layers=num_layers
        )

        # Classification head (from [CLS] token)
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model // 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, num_classes),
        )

    def forward(self, modality_dict):
        """
        modality_dict: dict {modality_name: tensor (B, m_dim)}
        Returns: logits (B, num_classes)
        """
        batch_size = None
        tokens = []

        for idx, m_name in enumerate(self.modality_names):
            proj = self.modality_projections[m_name]
            if proj is None:
                continue  # skip modalities with 0 features after masking

            x = modality_dict[m_name]  # (B, m_dim)
            if batch_size is None:
                batch_size = x.size(0)

            token = proj(x)  # (B, d_model)
            # Add modality embedding
            mod_emb = self.modality_embeddings(
                torch.tensor(idx, device=x.device)
            )  # (d_model,)
            token = token + mod_emb  # (B, d_model)
            tokens.append(token.unsqueeze(1))  # (B, 1, d_model)

        if len(tokens) == 0:
            # Edge case: all modalities masked out
            # Return uniform logits
            device = self.cls_token.device
            return torch.zeros(batch_size or 1, self.classifier[-1].out_features, device=device)

        # Concatenate modality tokens: (B, num_active_modalities, d_model)
        tokens = torch.cat(tokens, dim=1)

        # Prepend [CLS] token
        cls = self.cls_token.expand(tokens.size(0), -1, -1)  # (B, 1, d_model)
        tokens = torch.cat([cls, tokens], dim=1)  # (B, 1 + num_mod, d_model)

        # Transformer
        encoded = self.transformer_encoder(tokens)  # (B, 1 + num_mod, d_model)

        # Take [CLS] output
        cls_output = encoded[:, 0, :]  # (B, d_model)

        return self.classifier(cls_output)


print("Transformer Encoder (Modality-Token) model defined")
print("Datasets: MultiModalDatasetFromUnified, MultiModalDataset")
# Out:
# Transformer Encoder (Modality-Token) model defined
# Datasets: MultiModalDatasetFromUnified, MultiModalDataset

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.

    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}

    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]

        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]

        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler

        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'.")

        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]

    # Concatenate: depth | sensor | skeleton 
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)

    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " +
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")

    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []

    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])

        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]

        unified_features.append(feat_vector)

    return np.array(unified_features)


def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}

    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100

        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx

    return retention


def build_transformer_dataloader(X_unified, y, feature_mask, feature_dims, batch_size, shuffle=False):
    """Build a DataLoader that feeds the Transformer model from unified numpy arrays.

    This splits the unified (and optionally masked) feature vector back into
    per-modality chunks so the Transformer can process each as a token.
    """
    mod_dims = get_modality_dims_after_mask(feature_mask, feature_dims)
    dataset = MultiModalDatasetFromUnified(X_unified, y, mod_dims)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)


def collate_modality_batch_to_device(batch, device):
    """Move a modality-dict batch to device."""
    mod_feats, labels = batch
    mod_feats = {k: v.to(device) for k, v in mod_feats.items()}
    labels = labels.to(device)
    return mod_feats, labels


def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    model.train()
    for epoch in range(num_epochs):
        for batch in train_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            optimizer.zero_grad()
            outputs = model(mod_feats)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for batch in val_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            outputs = model(mod_feats)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.cpu().numpy())
        val_acc = accuracy_score(val_true, val_preds)

        # Test
        test_preds, test_true = [], []
        for batch in test_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            outputs = model(mod_feats)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.cpu().numpy())
        test_acc = accuracy_score(test_true, test_preds)

    return val_acc, test_acc


def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)


def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0


def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)


print("Helper functions defined (with per-modality normalization + depth KernelPCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth KernelPCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for batch in train_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            optimizer.zero_grad()
            outputs = model(mod_feats)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for batch in val_loader:
                mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
                outputs = model(mod_feats)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())

    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)

    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for batch in val_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            outputs = model(mod_feats)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.cpu().numpy())

        # Test
        test_preds, test_true = [], []
        for batch in test_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            outputs = model(mod_feats)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.cpu().numpy())

    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)

    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined (Transformer-compatible)")
# Out:
# Enhanced evaluation function defined (Transformer-compatible)

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# (Updated for Transformer Encoder model)
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation (Transformer-compatible)"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    best_val_loss = float('inf')
    best_val_acc = 0.0

    for epoch in range(epochs):
        model.train()
        for batch in train_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, device)
            optimizer.zero_grad()
            loss = criterion(model(mod_feats), labels)
            loss.backward()
            optimizer.step()

        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for batch in val_loader:
                mod_feats, labels = collate_modality_batch_to_device(batch, device)
                outputs = model(mod_feats)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)

        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc

    return best_val_loss, best_val_acc


# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations

    # Use passed feature_dims if available, otherwise fall back to global FEATURE_DIMS
    fold_feature_dims = feature_dims if feature_dims is not None else FEATURE_DIMS

    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0

            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]

            # Get per-modality dims after this mask
            mod_dims = get_modality_dims_after_mask(binary_mask, fold_feature_dims)

            train_dataset = MultiModalDatasetFromUnified(X_tr_sel, y_train, mod_dims)
            val_dataset = MultiModalDatasetFromUnified(X_val_sel, y_val, mod_dims)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

            model = ModalityTokenTransformer(mod_dims, num_classes).to(DEVICE)

            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )

            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()

            eval_count[0] += 1

            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness

        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0

    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")

    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats, feature_dims)

    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start

    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, ")

    return results


print("All EvoloPy metaheuristic runners defined (Transformer model)")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined (Transformer model)
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")

    start_time = time.time()

    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)

    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]

    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True

    execution_time = time.time() - start_time

    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")

    start_time = time.time()

    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)

    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)

    binary_mask = selector.support_

    execution_time = time.time() - start_time

    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results


print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. KernelPCA on depth modality (fit on train only)
    3. Concatenation AFTER normalization+PCA
    Uses ModalityTokenTransformer instead of SimpleNN.
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS (Transformer Model)")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)

    num_classes = len(np.unique(y))

    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}

    # Build sample indices for GroupKFold
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))

    gkf = GroupKFold(n_splits=N_FOLDS)

    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")

        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]

        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv

        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]

        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")

        # =================================================================
        # Per-modality normalization + depth KernelPCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )

        fold_total_features = sum(fold_feature_dims.values())

        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)

        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")

            fs_start_time = time.time()

            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")

            fs_time = time.time() - fs_start_time

            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]

            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)

            # Build per-modality dims after mask
            mod_dims = get_modality_dims_after_mask(feature_mask, fold_feature_dims)

            # Build Transformer model
            model = ModalityTokenTransformer(mod_dims, num_classes).to(DEVICE)

            # Build DataLoaders (splits unified back to per-modality)
            train_dataset = MultiModalDatasetFromUnified(X_train_sel, y[train_idx], mod_dims)
            val_dataset = MultiModalDatasetFromUnified(X_val_sel, y[val_idx], mod_dims)
            test_dataset = MultiModalDatasetFromUnified(X_test_sel, y[test_idx], mod_dims)

            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()

            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )

            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention',
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0}
                               for m, d in fold_feature_dims.items()}

            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }

            master_results[method_name][fold_idx] = fold_result

            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v

            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)

            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)

            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")

            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()

    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED (Transformer Model)")
    print(f"{'='*80}")

    return master_results


print("Per-fold experiment runner defined (Transformer)")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined (Transformer)
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS (Transformer Model)
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 97.55%, F1: 97.53%, Features: 3043/3043 (100.0%), Model: 2.541MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 32.9s
#     Test Acc: 96.50%, F1: 96.52%, Features: 1521/3043 (50.0%), Model: 1.798MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 5.5s
#     Test Acc: 97.55%, F1: 97.43%, Features: 1521/3043 (50.0%), Model: 1.798MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 181.9s
#     Test Acc: 92.31%, F1: 91.84%, Features: 1521/3043 (50.0%), Model: 1.798MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0243838317449885']
# ['At iteration 1 the best fitness is 0.023677292145908645']
# ['At iteration 2 the best fitness is 0.023677292145908645']
# ['At iteration 3 the best fitness is 0.023677292145908645']
# ['At iteration 4 the best fitness is 0.023677292145908645']
# ['At iteration 5 the best fitness is 0.023677292145908645']
# ['At iteration 6 the best fitness is 0.023660860992441673']
# ['At iteration 7 the best fitness is 0.023660860992441673']
# ['At iteration 8 the best fitness is 0.02356227407163983']
# ['At iteration 9 the best fitness is 0.02356227407163983']
# ['At iteration 10 the best fitness is 0.02356227407163983']
# ['At iteration 11 the best fitness is 0.023545842918172855']
# ['At iteration 12 the best fitness is 0.023545842918172855']
# ['At iteration 13 the best fitness is 0.023545842918172855']
# ['At iteration 14 the best fitness is 0.023496549457771937']
# ['At iteration 15 the best fitness is 0.023496549457771937']
# ['At iteration 16 the best fitness is 0.023496549457771937']
# ['At iteration 17 the best fitness is 0.023496549457771937']
# ['At iteration 18 the best fitness is 0.023496549457771937']
# ['At iteration 19 the best fitness is 0.023496549457771937']
# ['At iteration 20 the best fitness is 0.023496549457771937']
# ['At iteration 21 the best fitness is 0.023496549457771937']
# ['At iteration 22 the best fitness is 0.023496549457771937']
# ['At iteration 23 the best fitness is 0.023496549457771937']
# ['At iteration 24 the best fitness is 0.023496549457771937']
# ['At iteration 25 the best fitness is 0.023496549457771937']
# ['At iteration 26 the best fitness is 0.023496549457771937']
# ['At iteration 27 the best fitness is 0.023496549457771937']
# ['At iteration 28 the best fitness is 0.023496549457771937']
# ['At iteration 29 the best fitness is 0.023496549457771937']
#       Selected: 1430/3043 (47.0%), Fitness: 0.0235, Time: 3575.2s
#       Modality: D=46%, S=46%, Sk=48%,
#     Test Acc: 99.30%, F1: 99.30%, Features: 1430/3043 (47.0%), Model: 1.753MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023660860992441673']
# ['At iteration 1 the best fitness is 0.023660860992441673']
# ['At iteration 2 the best fitness is 0.023660860992441673']
# ['At iteration 3 the best fitness is 0.023660860992441673']
# ['At iteration 4 the best fitness is 0.023660860992441673']
# ['At iteration 5 the best fitness is 0.023660860992441673']
# ['At iteration 6 the best fitness is 0.023660860992441673']
# ['At iteration 7 the best fitness is 0.023660860992441673']
# ['At iteration 8 the best fitness is 0.023660860992441673']
# ['At iteration 9 the best fitness is 0.023644429838974697']
# ['At iteration 10 the best fitness is 0.023644429838974697']
# ['At iteration 11 the best fitness is 0.023644429838974697']
# ['At iteration 12 the best fitness is 0.023644429838974697']
# ['At iteration 13 the best fitness is 0.023463687150837992']
# ['At iteration 14 the best fitness is 0.023463687150837992']
# ['At iteration 15 the best fitness is 0.023463687150837992']
# ['At iteration 16 the best fitness is 0.023463687150837992']
# ['At iteration 17 the best fitness is 0.023463687150837992']
# ['At iteration 18 the best fitness is 0.023463687150837992']
# ['At iteration 19 the best fitness is 0.023463687150837992']
# ['At iteration 20 the best fitness is 0.023463687150837992']
# ['At iteration 21 the best fitness is 0.023463687150837992']
# ['At iteration 22 the best fitness is 0.023463687150837992']
# ['At iteration 23 the best fitness is 0.023250082155767335']
# ['At iteration 24 the best fitness is 0.023250082155767335']
# ['At iteration 25 the best fitness is 0.023250082155767335']
# ['At iteration 26 the best fitness is 0.02321721984883339']
# ['At iteration 27 the best fitness is 0.02321721984883339']
# ['At iteration 28 the best fitness is 0.02321721984883339']
# ['At iteration 29 the best fitness is 0.023184357541899445']
#       Selected: 1411/3043 (46.4%), Fitness: 0.0232, Time: 6785.8s
#       Modality: D=48%, S=47%, Sk=46%,
#     Test Acc: 97.90%, F1: 97.90%, Features: 1411/3043 (46.4%), Model: 1.744MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024465987512323366']
# ['At iteration 2 the best fitness is 0.024367400591521524']
# ['At iteration 3 the best fitness is 0.02374301675977654']
# ['At iteration 4 the best fitness is 0.02374301675977654']
# ['At iteration 5 the best fitness is 0.02374301675977654']
# ['At iteration 6 the best fitness is 0.02374301675977654']
# ['At iteration 7 the best fitness is 0.02371015445284259']
# ['At iteration 8 the best fitness is 0.02361156753204075']
# ['At iteration 9 the best fitness is 0.02361156753204075']
# ['At iteration 10 the best fitness is 0.023529411764705882']
# ['At iteration 11 the best fitness is 0.023529411764705882']
# ['At iteration 12 the best fitness is 0.023184357541899445']
# ['At iteration 13 the best fitness is 0.023102201774564575']
# ['At iteration 14 the best fitness is 0.023102201774564575']
# ['At iteration 15 the best fitness is 0.023102201774564575']
# ['At iteration 16 the best fitness is 0.023102201774564575']
# ['At iteration 17 the best fitness is 0.023102201774564575']
# ['At iteration 18 the best fitness is 0.023102201774564575']
# ['At iteration 19 the best fitness is 0.02306933946763063']
# ['At iteration 20 the best fitness is 0.02306933946763063']
# ['At iteration 21 the best fitness is 0.02306933946763063']
# ['At iteration 22 the best fitness is 0.022757147551758134']
# ['At iteration 23 the best fitness is 0.022724285244824186']
# ['At iteration 24 the best fitness is 0.022724285244824186']
# ['At iteration 25 the best fitness is 0.02257640486362143']
# ['At iteration 26 the best fitness is 0.02257640486362143']
# ['At iteration 27 the best fitness is 0.02257640486362143']
# ['At iteration 28 the best fitness is 0.02249424909628656']
# ['At iteration 29 the best fitness is 0.02249424909628656']
# ['At iteration 30 the best fitness is 0.02249424909628656']
#       Selected: 1369/3043 (45.0%), Fitness: 0.0225, Time: 3334.3s
#       Modality: D=45%, S=44%, Sk=45%,
#     Test Acc: 97.55%, F1: 97.51%, Features: 1369/3043 (45.0%), Model: 1.723MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023956621754847193']
# ['At iteration 1 the best fitness is 0.023956621754847193']
# ['At iteration 2 the best fitness is 0.024104502136049952']
# ['At iteration 3 the best fitness is 0.02380874137364443']
# ['At iteration 4 the best fitness is 0.023775879066710484']
# ['At iteration 5 the best fitness is 0.023775879066710484']
# ['At iteration 6 the best fitness is 0.023463687150837992']
# ['At iteration 7 the best fitness is 0.02351298061123891']
# ['At iteration 8 the best fitness is 0.023480118304304964']
# ['At iteration 9 the best fitness is 0.023299375616168256']
# ['At iteration 10 the best fitness is 0.023381531383503122']
# ['At iteration 11 the best fitness is 0.023381531383503122']
# ['At iteration 12 the best fitness is 0.02344725599737102']
# ['At iteration 13 the best fitness is 0.023381531383503122']
# ['At iteration 14 the best fitness is 0.023348669076569177']
# ['At iteration 15 the best fitness is 0.02341439369043707']
# ['At iteration 16 the best fitness is 0.023381531383503122']
# ['At iteration 17 the best fitness is 0.023332237923102205']
# ['At iteration 18 the best fitness is 0.023381531383503122']
# ['At iteration 19 the best fitness is 0.02336510023003615']
# ['At iteration 20 the best fitness is 0.02336510023003615']
# ['At iteration 21 the best fitness is 0.02336510023003615']
# ['At iteration 22 the best fitness is 0.02336510023003615']
# ['At iteration 23 the best fitness is 0.02336510023003615']
# ['At iteration 24 the best fitness is 0.02336510023003615']
# ['At iteration 25 the best fitness is 0.02336510023003615']
# ['At iteration 26 the best fitness is 0.02336510023003615']
# ['At iteration 27 the best fitness is 0.02336510023003615']
# ['At iteration 28 the best fitness is 0.02336510023003615']
# ['At iteration 29 the best fitness is 0.02336510023003615']
#       Selected: 1422/3043 (46.7%), Fitness: 0.0234, Time: 3214.3s
#       Modality: D=50%, S=46%, Sk=46%,
#     Test Acc: 97.20%, F1: 97.17%, Features: 1422/3043 (46.7%), Model: 1.749MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024613867893526126
# At iteration 2 the best fitness is 0.024663161353927047
# At iteration 3 the best fitness is 0.02433453828458758
# At iteration 4 the best fitness is 0.02385803483404535
# At iteration 5 the best fitness is 0.02385803483404535
# At iteration 6 the best fitness is 0.024219520210318767
# At iteration 7 the best fitness is 0.024170226749917846
# At iteration 8 the best fitness is 0.024170226749917846
# At iteration 9 the best fitness is 0.024170226749917846
# At iteration 10 the best fitness is 0.024104502136049952
# At iteration 11 the best fitness is 0.024104502136049952
# At iteration 12 the best fitness is 0.024104502136049952
# At iteration 13 the best fitness is 0.024104502136049952
# At iteration 14 the best fitness is 0.024071639829116004
# At iteration 15 the best fitness is 0.024071639829116004
# At iteration 16 the best fitness is 0.023973052908314165
# At iteration 17 the best fitness is 0.023825172527111405
# At iteration 18 the best fitness is 0.023693723299375618
# At iteration 19 the best fitness is 0.023874465987512323
# At iteration 20 the best fitness is 0.02380874137364443
# At iteration 21 the best fitness is 0.02380874137364443
# At iteration 22 the best fitness is 0.02380874137364443
# At iteration 23 the best fitness is 0.02371015445284259
# At iteration 24 the best fitness is 0.02380874137364443
# At iteration 25 the best fitness is 0.02380874137364443
# At iteration 26 the best fitness is 0.023726585606309566
# At iteration 27 the best fitness is 0.023726585606309566
# At iteration 28 the best fitness is 0.023726585606309566
# At iteration 29 the best fitness is 0.02375944791324351
# At iteration 30 the best fitness is 0.023677292145908645
#       Selected: 1441/3043 (47.4%), Fitness: 0.0237, Time: 3243.1s
#       Modality: D=50%, S=47%, Sk=47%,
#     Test Acc: 97.55%, F1: 97.47%, Features: 1441/3043 (47.4%), Model: 1.759MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024745317121261913']
# ['At iteration 1 the best fitness is 0.023052908314163654']
# ['At iteration 2 the best fitness is 0.022280644101215906']
# ['At iteration 3 the best fitness is 0.021409792967466316']
# ['At iteration 4 the best fitness is 0.02039106145251397']
# ['At iteration 5 the best fitness is 0.01953664147223135']
# ['At iteration 6 the best fitness is 0.018370029576076242']
# ['At iteration 7 the best fitness is 0.017564903056194545']
# ['At iteration 8 the best fitness is 0.01690765691751561']
# ['At iteration 9 the best fitness is 0.016579033848176144']
# ['At iteration 10 the best fitness is 0.015872494249096286']
# ['At iteration 11 the best fitness is 0.0152481104173513']
# ['At iteration 12 the best fitness is 0.014492277357870523']
# ['At iteration 13 the best fitness is 0.014492277357870523']
# ['At iteration 14 the best fitness is 0.014492277357870523']
# ['At iteration 15 the best fitness is 0.014196516595465003']
# ['At iteration 16 the best fitness is 0.013867893526125536']
# ['At iteration 17 the best fitness is 0.013867893526125536']
# ['At iteration 18 the best fitness is 0.013835031219191588']
# ['At iteration 19 the best fitness is 0.013391390075583307']
# ['At iteration 20 the best fitness is 0.013391390075583307']
# ['At iteration 21 the best fitness is 0.013391390075583307']
# ['At iteration 22 the best fitness is 0.013292803154781466']
# ['At iteration 23 the best fitness is 0.013292803154781466']
# ['At iteration 24 the best fitness is 0.013292803154781466']
# ['At iteration 25 the best fitness is 0.013292803154781466']
# ['At iteration 26 the best fitness is 0.013292803154781466']
# ['At iteration 27 the best fitness is 0.013292803154781466']
# ['At iteration 28 the best fitness is 0.013128491620111732']
# ['At iteration 29 the best fitness is 0.013128491620111732']
#       Selected: 799/3043 (26.3%), Fitness: 0.0131, Time: 3201.4s
#       Modality: D=25%, S=26%, Sk=27%,
#     Test Acc: 95.80%, F1: 95.63%, Features: 799/3043 (26.3%), Model: 1.445MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.02453171212619126']
# ['At iteration 1 the best fitness is 0.012964180085442']
# ['At iteration 2 the best fitness is 0.012964180085442']
# ['At iteration 3 the best fitness is 0.011912669249179303']
# ['At iteration 4 the best fitness is 0.011912669249179303']
# ['At iteration 5 the best fitness is 0.011912669249179303']
# ['At iteration 6 the best fitness is 0.011912669249179303']
# ['At iteration 7 the best fitness is 0.011912669249179303']
# ['At iteration 8 the best fitness is 0.011912669249179303']
# ['At iteration 9 the best fitness is 0.011912669249179303']
# ['At iteration 10 the best fitness is 0.011912669249179303']
# ['At iteration 11 the best fitness is 0.011912669249179303']
# ['At iteration 12 the best fitness is 0.009316464015773908']
# ['At iteration 13 the best fitness is 0.009316464015773908']
# ['At iteration 14 the best fitness is 0.009316464015773908']
# ['At iteration 15 the best fitness is 0.009316464015773908']
# ['At iteration 16 the best fitness is 0.009316464015773908']
# ['At iteration 17 the best fitness is 0.009316464015773908']
# ['At iteration 18 the best fitness is 0.009316464015773908']
# ['At iteration 19 the best fitness is 0.009300032862306934']
# ['At iteration 20 the best fitness is 0.009300032862306934']
# ['At iteration 21 the best fitness is 0.009300032862306934']
# ['At iteration 22 the best fitness is 0.009300032862306934']
# ['At iteration 23 the best fitness is 0.008133420966151824']
# ['At iteration 24 the best fitness is 0.007246138678935261']
# ['At iteration 25 the best fitness is 0.007246138678935261']
# ['At iteration 26 the best fitness is 0.007246138678935261']
# ['At iteration 27 the best fitness is 0.007246138678935261']
# ['At iteration 28 the best fitness is 0.007246138678935261']
# ['At iteration 29 the best fitness is 0.007246138678935261']
#       Selected: 441/3043 (14.5%), Fitness: 0.0072, Time: 4246.4s
#       Modality: D=13%, S=12%, Sk=16%,
#     Test Acc: 96.50%, F1: 96.50%, Features: 441/3043 (14.5%), Model: 1.270MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023825172527111405']
# ['At iteration 1 the best fitness is 0.023792310220177457']
# ['At iteration 2 the best fitness is 0.023775879066710484']
# ['At iteration 3 the best fitness is 0.023775879066710484']
# ['At iteration 4 the best fitness is 0.023578705225106803']
# ['At iteration 5 the best fitness is 0.02356227407163983']
# ['At iteration 6 the best fitness is 0.02356227407163983']
# ['At iteration 7 the best fitness is 0.023430824843904043']
# ['At iteration 8 the best fitness is 0.023430824843904043']
# ['At iteration 9 the best fitness is 0.023167926388432472']
# ['At iteration 10 the best fitness is 0.023167926388432472']
# ['At iteration 11 the best fitness is 0.023085770621097602']
# ['At iteration 12 the best fitness is 0.023085770621097602']
# ['At iteration 13 the best fitness is 0.023085770621097602']
# ['At iteration 14 the best fitness is 0.023052908314163654']
# ['At iteration 15 the best fitness is 0.023052908314163654']
# ['At iteration 16 the best fitness is 0.023052908314163654']
# ['At iteration 17 the best fitness is 0.02303647716069668']
# ['At iteration 18 the best fitness is 0.023003614853762736']
# ['At iteration 19 the best fitness is 0.023003614853762736']
# ['At iteration 20 the best fitness is 0.023003614853762736']
# ['At iteration 21 the best fitness is 0.023003614853762736']
# ['At iteration 22 the best fitness is 0.023003614853762736']
# ['At iteration 23 the best fitness is 0.023003614853762736']
# ['At iteration 24 the best fitness is 0.023003614853762736']
# ['At iteration 25 the best fitness is 0.022954321393361815']
# ['At iteration 26 the best fitness is 0.022954321393361815']
# ['At iteration 27 the best fitness is 0.022954321393361815']
# ['At iteration 28 the best fitness is 0.02287216562602695']
# ['At iteration 29 the best fitness is 0.022839303319093004']
#       Selected: 1390/3043 (45.7%), Fitness: 0.0228, Time: 3341.2s
#       Modality: D=48%, S=46%, Sk=45%,
#     Test Acc: 96.85%, F1: 96.84%, Features: 1390/3043 (45.7%), Model: 1.734MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02423595136378574']
# ['At iteration 2 the best fitness is 0.02423595136378574']
# ['At iteration 3 the best fitness is 0.02423595136378574']
# ['At iteration 4 the best fitness is 0.02385803483404535']
# ['At iteration 5 the best fitness is 0.02385803483404535']
# ['At iteration 6 the best fitness is 0.02385803483404535']
# ['At iteration 7 the best fitness is 0.02385803483404535']
# ['At iteration 8 the best fitness is 0.02385803483404535']
# ['At iteration 9 the best fitness is 0.02385803483404535']
# ['At iteration 10 the best fitness is 0.02385803483404535']
# ['At iteration 11 the best fitness is 0.02385803483404535']
# ['At iteration 12 the best fitness is 0.02385803483404535']
# ['At iteration 13 the best fitness is 0.02385803483404535']
# ['At iteration 14 the best fitness is 0.02385803483404535']
# ['At iteration 15 the best fitness is 0.02385803483404535']
# ['At iteration 16 the best fitness is 0.02385803483404535']
# ['At iteration 17 the best fitness is 0.02385803483404535']
# ['At iteration 18 the best fitness is 0.02385803483404535']
# ['At iteration 19 the best fitness is 0.02385803483404535']
# ['At iteration 20 the best fitness is 0.02385803483404535']
# ['At iteration 21 the best fitness is 0.02385803483404535']
# ['At iteration 22 the best fitness is 0.023627998685507724']
# ['At iteration 23 the best fitness is 0.023381531383503122']
# ['At iteration 24 the best fitness is 0.023381531383503122']
# ['At iteration 25 the best fitness is 0.023381531383503122']
# ['At iteration 26 the best fitness is 0.023381531383503122']
# ['At iteration 27 the best fitness is 0.023250082155767335']
# ['At iteration 28 the best fitness is 0.023250082155767335']
# ['At iteration 29 the best fitness is 0.023184357541899445']
#       Selected: 1411/3043 (46.4%), Fitness: 0.0232, Time: 3118.2s
#       Modality: D=44%, S=48%, Sk=46%,
#     Test Acc: 96.50%, F1: 96.45%, Features: 1411/3043 (46.4%), Model: 1.744MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02423595136378574']
# ['At iteration 2 the best fitness is 0.02420308905685179']
# ['At iteration 3 the best fitness is 0.023775879066710484']
# ['At iteration 4 the best fitness is 0.023775879066710484']
# ['At iteration 5 the best fitness is 0.023775879066710484']
# ['At iteration 6 the best fitness is 0.023775879066710484']
# ['At iteration 7 the best fitness is 0.023775879066710484']
# ['At iteration 8 the best fitness is 0.023775879066710484']
# ['At iteration 9 the best fitness is 0.02375944791324351']
# ['At iteration 10 the best fitness is 0.023677292145908645']
# ['At iteration 11 the best fitness is 0.023677292145908645']
# ['At iteration 12 the best fitness is 0.023677292145908645']
# ['At iteration 13 the best fitness is 0.023677292145908645']
# ['At iteration 14 the best fitness is 0.023430824843904043']
# ['At iteration 15 the best fitness is 0.023430824843904043']
# ['At iteration 16 the best fitness is 0.023381531383503122']
# ['At iteration 17 the best fitness is 0.023381531383503122']
# ['At iteration 18 the best fitness is 0.02331580676963523']
# ['At iteration 19 the best fitness is 0.02331580676963523']
# ['At iteration 20 the best fitness is 0.02331580676963523']
# ['At iteration 21 the best fitness is 0.02331580676963523']
# ['At iteration 22 the best fitness is 0.023299375616168256']
# ['At iteration 23 the best fitness is 0.023299375616168256']
# ['At iteration 24 the best fitness is 0.023233651002300362']
# ['At iteration 25 the best fitness is 0.023233651002300362']
# ['At iteration 26 the best fitness is 0.023233651002300362']
# ['At iteration 27 the best fitness is 0.02321721984883339']
# ['At iteration 28 the best fitness is 0.02321721984883339']
# ['At iteration 29 the best fitness is 0.023135064081498524']
# ['At iteration 30 the best fitness is 0.023102201774564575']
#       Selected: 1406/3043 (46.2%), Fitness: 0.0231, Time: 3235.7s
#       Modality: D=46%, S=46%, Sk=47%,
#     Test Acc: 95.45%, F1: 95.38%, Features: 1406/3043 (46.2%), Model: 1.742MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024120933289516925']
# ['At iteration 2 the best fitness is 0.024120933289516925']
# ['At iteration 3 the best fitness is 0.024120933289516925']
# ['At iteration 4 the best fitness is 0.024120933289516925']
# ['At iteration 5 the best fitness is 0.023956621754847193']
# ['At iteration 6 the best fitness is 0.023956621754847193']
# ['At iteration 7 the best fitness is 0.023644429838974697']
# ['At iteration 8 the best fitness is 0.023644429838974697']
# ['At iteration 9 the best fitness is 0.02344725599737102']
# ['At iteration 10 the best fitness is 0.02344725599737102']
# ['At iteration 11 the best fitness is 0.023397962536970098']
# ['At iteration 12 the best fitness is 0.02321721984883339']
# ['At iteration 13 the best fitness is 0.023135064081498524']
# ['At iteration 14 the best fitness is 0.023135064081498524']
# ['At iteration 15 the best fitness is 0.023135064081498524']
# ['At iteration 16 the best fitness is 0.023052908314163654']
# ['At iteration 17 the best fitness is 0.023052908314163654']
# ['At iteration 18 the best fitness is 0.02303647716069668']
# ['At iteration 19 the best fitness is 0.02292145908642787']
# ['At iteration 20 the best fitness is 0.02262569832402235']
# ['At iteration 21 the best fitness is 0.02262569832402235']
# ['At iteration 22 the best fitness is 0.02257640486362143']
# ['At iteration 23 the best fitness is 0.02257640486362143']
# ['At iteration 24 the best fitness is 0.022477817942819587']
# ['At iteration 25 the best fitness is 0.022477817942819587']
# ['At iteration 26 the best fitness is 0.022477817942819587']
# ['At iteration 27 the best fitness is 0.022477817942819587']
# ['At iteration 28 the best fitness is 0.02239566217548472']
# ['At iteration 29 the best fitness is 0.02239566217548472']
# ['At iteration 30 the best fitness is 0.0223463687150838']
#       Selected: 1360/3043 (44.7%), Fitness: 0.0223, Time: 3196.7s
#       Modality: D=44%, S=47%, Sk=44%,
#     Test Acc: 93.71%, F1: 93.47%, Features: 1360/3043 (44.7%), Model: 1.719MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024745317121261913']
# ['At iteration 1 the best fitness is 0.020456786066381863']
# ['At iteration 2 the best fitness is 0.02039106145251397']
# ['At iteration 3 the best fitness is 0.016874794610581664']
# ['At iteration 4 the best fitness is 0.01385146237265856']
# ['At iteration 5 the best fitness is 0.011929017417022675']
# ['At iteration 6 the best fitness is 0.011929017417022675']
# ['At iteration 7 the best fitness is 0.01151823858034834']
# ['At iteration 8 the best fitness is 0.009267170555372987']
# ['At iteration 9 the best fitness is 0.009267170555372987']
# ['At iteration 10 the best fitness is 0.009004272099901412']
# ['At iteration 11 the best fitness is 0.008905685179099574']
# ['At iteration 12 the best fitness is 0.007279000985869208']
# ['At iteration 13 the best fitness is 0.007279000985869208']
# ['At iteration 14 the best fitness is 0.006325994084784752']
# ['At iteration 15 the best fitness is 0.006325994084784752']
# ['At iteration 16 the best fitness is 0.006243838317449886']
# ['At iteration 17 the best fitness is 0.005898784094643444']
# ['At iteration 18 the best fitness is 0.005307262569832403']
# ['At iteration 19 the best fitness is 0.005307262569832403']
# ['At iteration 20 the best fitness is 0.005307262569832403']
# ['At iteration 21 the best fitness is 0.005307262569832403']
# ['At iteration 22 the best fitness is 0.005307262569832403']
# ['At iteration 23 the best fitness is 0.005307262569832403']
# ['At iteration 24 the best fitness is 0.005077226421294775']
# ['At iteration 25 the best fitness is 0.005077226421294775']
# ['At iteration 26 the best fitness is 0.005077226421294775']
# ['At iteration 27 the best fitness is 0.005077226421294775']
# ['At iteration 28 the best fitness is 0.0050279329608938555']
# ['At iteration 29 the best fitness is 0.0049457771935589884']
#       Selected: 301/3043 (9.9%), Fitness: 0.0049, Time: 2943.9s
#       Modality: D=11%, S=10%, Sk=10%,
#     Test Acc: 92.66%, F1: 92.51%, Features: 301/3043 (9.9%), Model: 1.202MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023677292145908645']
# ['At iteration 2 the best fitness is 0.023677292145908645']
# ['At iteration 3 the best fitness is 0.023677292145908645']
# ['At iteration 4 the best fitness is 0.023677292145908645']
# ['At iteration 5 the best fitness is 0.023677292145908645']
# ['At iteration 6 the best fitness is 0.023677292145908645']
# ['At iteration 7 the best fitness is 0.023677292145908645']
# ['At iteration 8 the best fitness is 0.023677292145908645']
# ['At iteration 9 the best fitness is 0.023677292145908645']
# ['At iteration 10 the best fitness is 0.023677292145908645']
# ['At iteration 11 the best fitness is 0.023677292145908645']
# ['At iteration 12 the best fitness is 0.023677292145908645']
# ['At iteration 13 the best fitness is 0.023677292145908645']
# ['At iteration 14 the best fitness is 0.02361156753204075']
# ['At iteration 15 the best fitness is 0.023381531383503122']
# ['At iteration 16 the best fitness is 0.023381531383503122']
# ['At iteration 17 the best fitness is 0.023381531383503122']
# ['At iteration 18 the best fitness is 0.023332237923102205']
# ['At iteration 19 the best fitness is 0.023299375616168256']
# ['At iteration 20 the best fitness is 0.023250082155767335']
# ['At iteration 21 the best fitness is 0.023250082155767335']
# ['At iteration 22 the best fitness is 0.023250082155767335']
# ['At iteration 23 the best fitness is 0.023250082155767335']
# ['At iteration 24 the best fitness is 0.023250082155767335']
# ['At iteration 25 the best fitness is 0.023250082155767335']
# ['At iteration 26 the best fitness is 0.023250082155767335']
# ['At iteration 27 the best fitness is 0.023250082155767335']
# ['At iteration 28 the best fitness is 0.023250082155767335']
# ['At iteration 29 the best fitness is 0.023250082155767335']
#       Selected: 1415/3043 (46.5%), Fitness: 0.0233, Time: 6406.6s
#       Modality: D=47%, S=49%, Sk=45%,
#     Test Acc: 97.90%, F1: 97.89%, Features: 1415/3043 (46.5%), Model: 1.746MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024449556358856393']
# ['At iteration 1 the best fitness is 0.01286567615026376']
# ['At iteration 2 the best fitness is 0.012405603853188504']
# ['At iteration 3 the best fitness is 0.008281384332978186']
# ['At iteration 4 the best fitness is 0.00218534341110746']
# ['At iteration 5 the best fitness is 0.00218534341110746']
# ['At iteration 6 the best fitness is 0.00218534341110746']
# ['At iteration 7 the best fitness is 0.00218534341110746']
# ['At iteration 8 the best fitness is 0.00218534341110746']
# ['At iteration 9 the best fitness is 0.00218534341110746']
# ['At iteration 10 the best fitness is 0.00218534341110746']
# ['At iteration 11 the best fitness is 0.00218534341110746']
# ['At iteration 12 the best fitness is 0.00218534341110746']
# ['At iteration 13 the best fitness is 0.00218534341110746']
# ['At iteration 14 the best fitness is 0.00218534341110746']
# ['At iteration 15 the best fitness is 0.00218534341110746']
# ['At iteration 16 the best fitness is 0.00218534341110746']
# ['At iteration 17 the best fitness is 0.00218534341110746']
# ['At iteration 18 the best fitness is 0.00218534341110746']
# ['At iteration 19 the best fitness is 0.00218534341110746']
# ['At iteration 20 the best fitness is 0.00218534341110746']
# ['At iteration 21 the best fitness is 0.00218534341110746']
# ['At iteration 22 the best fitness is 0.00218534341110746']
# ['At iteration 23 the best fitness is 0.00218534341110746']
# ['At iteration 24 the best fitness is 0.00218534341110746']
# ['At iteration 25 the best fitness is 0.00218534341110746']
# ['At iteration 26 the best fitness is 0.00218534341110746']
# ['At iteration 27 the best fitness is 0.00218534341110746']
# ['At iteration 28 the best fitness is 0.00218534341110746']
# ['At iteration 29 the best fitness is 0.0020703253368386464']
#       Selected: 126/3043 (4.1%), Fitness: 0.0021, Time: 2403.5s
#       Modality: D=3%, S=4%, Sk=4%,
#     Test Acc: 89.86%, F1: 89.02%, Features: 126/3043 (4.1%), Model: 1.117MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 90.04%, F1: 90.40%, Features: 3043/3043 (100.0%), Model: 2.541MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 29.2s
#     Test Acc: 86.31%, F1: 86.92%, Features: 1521/3043 (50.0%), Model: 1.798MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 4.8s
#     Test Acc: 90.04%, F1: 89.50%, Features: 1521/3043 (50.0%), Model: 1.798MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 172.9s
#     Test Acc: 88.38%, F1: 88.35%, Features: 1521/3043 (50.0%), Model: 1.798MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024613867893526126']
# ['At iteration 1 the best fitness is 0.024613867893526126']
# ['At iteration 2 the best fitness is 0.02458100558659218']
# ['At iteration 3 the best fitness is 0.024400262898455472']
# ['At iteration 4 the best fitness is 0.0243838317449885']
# ['At iteration 5 the best fitness is 0.02403877752218206']
# ['At iteration 6 the best fitness is 0.024005915215248114']
# ['At iteration 7 the best fitness is 0.023973052908314165']
# ['At iteration 8 the best fitness is 0.023956621754847193']
# ['At iteration 9 the best fitness is 0.02394019060138022']
# ['At iteration 10 the best fitness is 0.02394019060138022']
# ['At iteration 11 the best fitness is 0.02394019060138022']
# ['At iteration 12 the best fitness is 0.02394019060138022']
# ['At iteration 13 the best fitness is 0.02394019060138022']
# ['At iteration 14 the best fitness is 0.02394019060138022']
# ['At iteration 15 the best fitness is 0.02394019060138022']
# ['At iteration 16 the best fitness is 0.02394019060138022']
# ['At iteration 17 the best fitness is 0.02394019060138022']
# ['At iteration 18 the best fitness is 0.02394019060138022']
# ['At iteration 19 the best fitness is 0.02394019060138022']
# ['At iteration 20 the best fitness is 0.02394019060138022']
# ['At iteration 21 the best fitness is 0.02394019060138022']
# ['At iteration 22 the best fitness is 0.02394019060138022']
# ['At iteration 23 the best fitness is 0.02394019060138022']
# ['At iteration 24 the best fitness is 0.02394019060138022']
# ['At iteration 25 the best fitness is 0.02394019060138022']
# ['At iteration 26 the best fitness is 0.02394019060138022']
# ['At iteration 27 the best fitness is 0.02394019060138022']
# ['At iteration 28 the best fitness is 0.02394019060138022']
# ['At iteration 29 the best fitness is 0.02394019060138022']
#       Selected: 1457/3043 (47.9%), Fitness: 0.0239, Time: 2754.8s
#       Modality: D=49%, S=48%, Sk=47%,
#     Test Acc: 92.12%, F1: 92.26%, Features: 1457/3043 (47.9%), Model: 1.766MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024104502136049952']
# ['At iteration 1 the best fitness is 0.024104502136049952']
# ['At iteration 2 the best fitness is 0.024104502136049952']
# ['At iteration 3 the best fitness is 0.024104502136049952']
# ['At iteration 4 the best fitness is 0.024104502136049952']
# ['At iteration 5 the best fitness is 0.024104502136049952']
# ['At iteration 6 the best fitness is 0.024104502136049952']
# ['At iteration 7 the best fitness is 0.024104502136049952']
# ['At iteration 8 the best fitness is 0.024104502136049952']
# ['At iteration 9 the best fitness is 0.02405520867564903']
# ['At iteration 10 the best fitness is 0.02405520867564903']
# ['At iteration 11 the best fitness is 0.02405520867564903']
# ['At iteration 12 the best fitness is 0.023923759447913244']
# ['At iteration 13 the best fitness is 0.023923759447913244']
# ['At iteration 14 the best fitness is 0.02371015445284259']
# ['At iteration 15 the best fitness is 0.02371015445284259']
# ['At iteration 16 the best fitness is 0.02371015445284259']
# ['At iteration 17 the best fitness is 0.02371015445284259']
# ['At iteration 18 the best fitness is 0.02371015445284259']
# ['At iteration 19 the best fitness is 0.02371015445284259']
# ['At iteration 20 the best fitness is 0.02371015445284259']
# ['At iteration 21 the best fitness is 0.023660860992441673']
# ['At iteration 22 the best fitness is 0.023660860992441673']
# ['At iteration 23 the best fitness is 0.023660860992441673']
# ['At iteration 24 the best fitness is 0.023660860992441673']
# ['At iteration 25 the best fitness is 0.023660860992441673']
# ['At iteration 26 the best fitness is 0.023660860992441673']
# ['At iteration 27 the best fitness is 0.023660860992441673']
# ['At iteration 28 the best fitness is 0.023660860992441673']
# ['At iteration 29 the best fitness is 0.023660860992441673']
#       Selected: 1440/3043 (47.3%), Fitness: 0.0237, Time: 5435.3s
#       Modality: D=51%, S=46%, Sk=47%,
#     Test Acc: 89.63%, F1: 89.58%, Features: 1440/3043 (47.3%), Model: 1.758MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02458100558659218']
# ['At iteration 2 the best fitness is 0.023923759447913244']
# ['At iteration 3 the best fitness is 0.02375944791324351']
# ['At iteration 4 the best fitness is 0.023595136378573776']
# ['At iteration 5 the best fitness is 0.023595136378573776']
# ['At iteration 6 the best fitness is 0.023595136378573776']
# ['At iteration 7 the best fitness is 0.023595136378573776']
# ['At iteration 8 the best fitness is 0.023595136378573776']
# ['At iteration 9 the best fitness is 0.023595136378573776']
# ['At iteration 10 the best fitness is 0.023595136378573776']
# ['At iteration 11 the best fitness is 0.02341439369043707']
# ['At iteration 12 the best fitness is 0.02341439369043707']
# ['At iteration 13 the best fitness is 0.02341439369043707']
# ['At iteration 14 the best fitness is 0.02341439369043707']
# ['At iteration 15 the best fitness is 0.02341439369043707']
# ['At iteration 16 the best fitness is 0.02336510023003615']
# ['At iteration 17 the best fitness is 0.02336510023003615']
# ['At iteration 18 the best fitness is 0.02336510023003615']
# ['At iteration 19 the best fitness is 0.02336510023003615']
# ['At iteration 20 the best fitness is 0.023282944462701283']
# ['At iteration 21 the best fitness is 0.023282944462701283']
# ['At iteration 22 the best fitness is 0.023282944462701283']
# ['At iteration 23 the best fitness is 0.023282944462701283']
# ['At iteration 24 the best fitness is 0.023282944462701283']
# ['At iteration 25 the best fitness is 0.023282944462701283']
# ['At iteration 26 the best fitness is 0.02306933946763063']
# ['At iteration 27 the best fitness is 0.022707854091357213']
# ['At iteration 28 the best fitness is 0.022707854091357213']
# ['At iteration 29 the best fitness is 0.022707854091357213']
# ['At iteration 30 the best fitness is 0.022707854091357213']
#       Selected: 1382/3043 (45.4%), Fitness: 0.0227, Time: 2783.8s
#       Modality: D=43%, S=47%, Sk=46%,
#     Test Acc: 89.63%, F1: 89.34%, Features: 1382/3043 (45.4%), Model: 1.730MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024301675977653633']
# ['At iteration 1 the best fitness is 0.024153795596450874']
# ['At iteration 2 the best fitness is 0.024153795596450874']
# ['At iteration 3 the best fitness is 0.024120933289516925']
# ['At iteration 4 the best fitness is 0.024120933289516925']
# ['At iteration 5 the best fitness is 0.02375944791324351']
# ['At iteration 6 the best fitness is 0.02398948406178114']
# ['At iteration 7 the best fitness is 0.0238908971409793']
# ['At iteration 8 the best fitness is 0.023693723299375618']
# ['At iteration 9 the best fitness is 0.02380874137364443']
# ['At iteration 10 the best fitness is 0.02374301675977654']
# ['At iteration 11 the best fitness is 0.02374301675977654']
# ['At iteration 12 the best fitness is 0.023693723299375618']
# ['At iteration 13 the best fitness is 0.023677292145908645']
# ['At iteration 14 the best fitness is 0.023677292145908645']
# ['At iteration 15 the best fitness is 0.023627998685507724']
# ['At iteration 16 the best fitness is 0.023660860992441673']
# ['At iteration 17 the best fitness is 0.023660860992441673']
# ['At iteration 18 the best fitness is 0.023660860992441673']
# ['At iteration 19 the best fitness is 0.023644429838974697']
# ['At iteration 20 the best fitness is 0.023644429838974697']
# ['At iteration 21 the best fitness is 0.023627998685507724']
# ['At iteration 22 the best fitness is 0.023644429838974697']
# ['At iteration 23 the best fitness is 0.023644429838974697']
# ['At iteration 24 the best fitness is 0.023644429838974697']
# ['At iteration 25 the best fitness is 0.023644429838974697']
# ['At iteration 26 the best fitness is 0.023644429838974697']
# ['At iteration 27 the best fitness is 0.023644429838974697']
# ['At iteration 28 the best fitness is 0.023644429838974697']
# ['At iteration 29 the best fitness is 0.023644429838974697']
#       Selected: 1439/3043 (47.3%), Fitness: 0.0236, Time: 2679.7s
#       Modality: D=48%, S=47%, Sk=47%,
#     Test Acc: 90.46%, F1: 90.62%, Features: 1439/3043 (47.3%), Model: 1.758MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.025090371344068354
# At iteration 2 the best fitness is 0.024153795596450874
# At iteration 3 the best fitness is 0.025747617482747287
# At iteration 4 the best fitness is 0.024088070982582976
# At iteration 5 the best fitness is 0.02385803483404535
# At iteration 6 the best fitness is 0.02371015445284259
# At iteration 7 the best fitness is 0.023578705225106803
# At iteration 8 the best fitness is 0.023578705225106803
# At iteration 9 the best fitness is 0.023578705225106803
# At iteration 10 the best fitness is 0.023578705225106803
# At iteration 11 the best fitness is 0.02361156753204075
# At iteration 12 the best fitness is 0.02371015445284259
# At iteration 13 the best fitness is 0.023348669076569177
# At iteration 14 the best fitness is 0.02321721984883339
# At iteration 15 the best fitness is 0.02321721984883339
# At iteration 16 the best fitness is 0.022970752546828788
# At iteration 17 the best fitness is 0.022839303319093004
# At iteration 18 the best fitness is 0.022839303319093004
# At iteration 19 the best fitness is 0.023250082155767335
# At iteration 20 the best fitness is 0.02311863292803155
# At iteration 21 the best fitness is 0.02306933946763063
# At iteration 22 the best fitness is 0.023085770621097602
# At iteration 23 the best fitness is 0.023430824843904043
# At iteration 24 the best fitness is 0.02311863292803155
# At iteration 25 the best fitness is 0.02311863292803155
# At iteration 26 the best fitness is 0.02311863292803155
# At iteration 27 the best fitness is 0.023167926388432472
# At iteration 28 the best fitness is 0.023167926388432472
# At iteration 29 the best fitness is 0.023167926388432472
# At iteration 30 the best fitness is 0.02302004600722971
#       Selected: 1401/3043 (46.0%), Fitness: 0.0230, Time: 2689.7s
#       Modality: D=45%, S=48%, Sk=46%,
#     Test Acc: 89.21%, F1: 88.94%, Features: 1401/3043 (46.0%), Model: 1.739MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025238251725271117']
# ['At iteration 1 the best fitness is 0.024005915215248114']
# ['At iteration 2 the best fitness is 0.02302004600722971']
# ['At iteration 3 the best fitness is 0.02175484719027276']
# ['At iteration 4 the best fitness is 0.02152481104173513']
# ['At iteration 5 the best fitness is 0.020046007229707525']
# ['At iteration 6 the best fitness is 0.01899441340782123']
# ['At iteration 7 the best fitness is 0.018452185343411108']
# ['At iteration 8 the best fitness is 0.017663489976996388']
# ['At iteration 9 the best fitness is 0.01720341767992113']
# ['At iteration 10 the best fitness is 0.016792638843246797']
# ['At iteration 11 the best fitness is 0.01616825501150181']
# ['At iteration 12 the best fitness is 0.015708182714426554']
# ['At iteration 13 the best fitness is 0.01534669733815314']
# ['At iteration 14 the best fitness is 0.015050936575747617']
# ['At iteration 15 the best fitness is 0.014952349654945777']
# ['At iteration 16 the best fitness is 0.014459415050936576']
# ['At iteration 17 the best fitness is 0.01424581005586592']
# ['At iteration 18 the best fitness is 0.01424581005586592']
# ['At iteration 19 the best fitness is 0.014229378902398948']
# ['At iteration 20 the best fitness is 0.013999342753861322']
# ['At iteration 21 the best fitness is 0.013900755833059482']
# ['At iteration 22 the best fitness is 0.01385146237265856']
# ['At iteration 23 the best fitness is 0.013703581991455802']
# ['At iteration 24 the best fitness is 0.013489976996385149']
# ['At iteration 25 the best fitness is 0.013440683535984228']
# ['At iteration 26 the best fitness is 0.013424252382517252']
# ['At iteration 27 the best fitness is 0.013407821229050279']
# ['At iteration 28 the best fitness is 0.013342096615182387']
# ['At iteration 29 the best fitness is 0.013325665461715415']
#       Selected: 811/3043 (26.7%), Fitness: 0.0133, Time: 2655.3s
#       Modality: D=24%, S=29%, Sk=27%,
#     Test Acc: 86.72%, F1: 87.01%, Features: 811/3043 (26.7%), Model: 1.451MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.02433453828458758']
# ['At iteration 1 the best fitness is 0.02433453828458758']
# ['At iteration 2 the best fitness is 0.02147560056695781']
# ['At iteration 3 the best fitness is 0.020752546828787383']
# ['At iteration 4 the best fitness is 0.01789369209678111']
# ['At iteration 5 the best fitness is 0.01789369209678111']
# ['At iteration 6 the best fitness is 0.01789369209678111']
# ['At iteration 7 the best fitness is 0.01789369209678111']
# ['At iteration 8 the best fitness is 0.01373652728401335']
# ['At iteration 9 the best fitness is 0.01373652728401335']
# ['At iteration 10 the best fitness is 0.01373652728401335']
# ['At iteration 11 the best fitness is 0.01373652728401335']
# ['At iteration 12 the best fitness is 0.01373652728401335']
# ['At iteration 13 the best fitness is 0.01373652728401335']
# ['At iteration 14 the best fitness is 0.01373652728401335']
# ['At iteration 15 the best fitness is 0.01373652728401335']
# ['At iteration 16 the best fitness is 0.01373652728401335']
# ['At iteration 17 the best fitness is 0.013440766521607828']
# ['At iteration 18 the best fitness is 0.01194553155611325']
# ['At iteration 19 the best fitness is 0.01194553155611325']
# ['At iteration 20 the best fitness is 0.01194553155611325']
# ['At iteration 21 the best fitness is 0.01194553155611325']
# ['At iteration 22 the best fitness is 0.01194553155611325']
# ['At iteration 23 the best fitness is 0.009447996229133296']
# ['At iteration 24 the best fitness is 0.009447996229133296']
# ['At iteration 25 the best fitness is 0.009447996229133296']
# ['At iteration 26 the best fitness is 0.009447996229133296']
# ['At iteration 27 the best fitness is 0.009447996229133296']
# ['At iteration 28 the best fitness is 0.009447996229133296']
# ['At iteration 29 the best fitness is 0.009234391234062642']
#       Selected: 270/3043 (8.9%), Fitness: 0.0092, Time: 3170.5s
#       Modality: D=8%, S=9%, Sk=9%,
#     Test Acc: 86.72%, F1: 86.22%, Features: 270/3043 (8.9%), Model: 1.187MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023578705225106803']
# ['At iteration 1 the best fitness is 0.023578705225106803']
# ['At iteration 2 the best fitness is 0.023578705225106803']
# ['At iteration 3 the best fitness is 0.023545842918172855']
# ['At iteration 4 the best fitness is 0.023545842918172855']
# ['At iteration 5 the best fitness is 0.023545842918172855']
# ['At iteration 6 the best fitness is 0.023545842918172855']
# ['At iteration 7 the best fitness is 0.023545842918172855']
# ['At iteration 8 the best fitness is 0.023545842918172855']
# ['At iteration 9 the best fitness is 0.023545842918172855']
# ['At iteration 10 the best fitness is 0.023545842918172855']
# ['At iteration 11 the best fitness is 0.023529411764705882']
# ['At iteration 12 the best fitness is 0.023529411764705882']
# ['At iteration 13 the best fitness is 0.023496549457771937']
# ['At iteration 14 the best fitness is 0.023496549457771937']
# ['At iteration 15 the best fitness is 0.023496549457771937']
# ['At iteration 16 the best fitness is 0.02344725599737102']
# ['At iteration 17 the best fitness is 0.02344725599737102']
# ['At iteration 18 the best fitness is 0.02344725599737102']
# ['At iteration 19 the best fitness is 0.02344725599737102']
# ['At iteration 20 the best fitness is 0.02344725599737102']
# ['At iteration 21 the best fitness is 0.02344725599737102']
# ...
# ['At iteration 14 the best fitness is 0.08433402012373135']
# ['At iteration 15 the best fitness is 0.08433402012373135']
# ['At iteration 16 the best fitness is 0.08433402012373135']
# ['At iteration 17 the best fitness is 0.08433402012373135']
# ['At iteration 18 the best fitness is 0.08433402012373135']
# ['At iteration 19 the best fitness is 0.08433402012373135']
# ['At iteration 20 the best fitness is 0.08372606744545334']
# ['At iteration 21 the best fitness is 0.08372606744545334']
# ['At iteration 22 the best fitness is 0.08107594738212859']
# ['At iteration 23 the best fitness is 0.08107594738212859']
# ['At iteration 24 the best fitness is 0.08107594738212859']
# ['At iteration 25 the best fitness is 0.08107594738212859']
# ['At iteration 26 the best fitness is 0.0771817640104559']
# ['At iteration 27 the best fitness is 0.0771817640104559']
# ['At iteration 28 the best fitness is 0.0715983080684463']
# ['At iteration 29 the best fitness is 0.0715983080684463']
#       Selected: 519/3043 (17.1%), Fitness: 0.0716, Time: 4140.7s
#       Modality: D=17%, S=18%, Sk=17%,
#     Test Acc: 95.45%, F1: 95.41%, Features: 519/3043 (17.1%), Model: 1.308MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0882102042235564']
# ['At iteration 1 the best fitness is 0.08786515000074996']
# ['At iteration 2 the best fitness is 0.08786515000074996']
# ['At iteration 3 the best fitness is 0.08014564410803382']
# ['At iteration 4 the best fitness is 0.08004705718723198']
# ['At iteration 5 the best fitness is 0.08004705718723198']
# ['At iteration 6 the best fitness is 0.08004705718723198']
# ['At iteration 7 the best fitness is 0.08004705718723198']
# ['At iteration 8 the best fitness is 0.08004705718723198']
# ['At iteration 9 the best fitness is 0.08004705718723198']
# ['At iteration 10 the best fitness is 0.08004705718723198']
# ['At iteration 11 the best fitness is 0.08004705718723198']
# ['At iteration 12 the best fitness is 0.08004705718723198']
# ['At iteration 13 the best fitness is 0.08004705718723198']
# ['At iteration 14 the best fitness is 0.07626946000820879']
# ['At iteration 15 the best fitness is 0.07626946000820879']
# ['At iteration 16 the best fitness is 0.07626946000820879']
# ['At iteration 17 the best fitness is 0.07626946000820879']
# ['At iteration 18 the best fitness is 0.07626946000820879']
# ['At iteration 19 the best fitness is 0.07626946000820879']
# ['At iteration 20 the best fitness is 0.07626946000820879']
# ['At iteration 21 the best fitness is 0.07626946000820879']
# ['At iteration 22 the best fitness is 0.07626946000820879']
# ['At iteration 23 the best fitness is 0.07626946000820879']
# ['At iteration 24 the best fitness is 0.07626946000820879']
# ['At iteration 25 the best fitness is 0.07626946000820879']
# ['At iteration 26 the best fitness is 0.07626946000820879']
# ['At iteration 27 the best fitness is 0.07626946000820879']
# ['At iteration 28 the best fitness is 0.07626946000820879']
# ['At iteration 29 the best fitness is 0.07626946000820879']
#       Selected: 1523/3043 (50.0%), Fitness: 0.0763, Time: 3021.0s
#       Modality: D=49%, S=48%, Sk=51%,
#     Test Acc: 99.49%, F1: 99.49%, Features: 1523/3043 (50.0%), Model: 1.799MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09951013345369215']
# ['At iteration 2 the best fitness is 0.07988274565256225']
# ['At iteration 3 the best fitness is 0.07988274565256225']
# ['At iteration 4 the best fitness is 0.07988274565256225']
# ['At iteration 5 the best fitness is 0.07988274565256225']
# ['At iteration 6 the best fitness is 0.07988274565256225']
# ['At iteration 7 the best fitness is 0.07988274565256225']
# ['At iteration 8 the best fitness is 0.07988274565256225']
# ['At iteration 9 the best fitness is 0.07988274565256225']
# ['At iteration 10 the best fitness is 0.07988274565256225']
# ['At iteration 11 the best fitness is 0.07313267781439756']
# ['At iteration 12 the best fitness is 0.07313267781439756']
# ['At iteration 13 the best fitness is 0.07313267781439756']
# ['At iteration 14 the best fitness is 0.07313267781439756']
# ['At iteration 15 the best fitness is 0.07313267781439756']
# ['At iteration 16 the best fitness is 0.07313267781439756']
# ['At iteration 17 the best fitness is 0.07313267781439756']
# ['At iteration 18 the best fitness is 0.07313267781439756']
# ['At iteration 19 the best fitness is 0.07313267781439756']
# ['At iteration 20 the best fitness is 0.07313267781439756']
# ['At iteration 21 the best fitness is 0.07313267781439756']
# ['At iteration 22 the best fitness is 0.07313267781439756']
# ['At iteration 23 the best fitness is 0.07313267781439756']
# ['At iteration 24 the best fitness is 0.07313267781439756']
# ['At iteration 25 the best fitness is 0.07313267781439756']
# ['At iteration 26 the best fitness is 0.07313267781439756']
# ['At iteration 27 the best fitness is 0.07313267781439756']
# ['At iteration 28 the best fitness is 0.07313267781439756']
# ['At iteration 29 the best fitness is 0.07313267781439756']
#       Selected: 1572/3043 (51.7%), Fitness: 0.0731, Time: 2852.6s
#       Modality: D=52%, S=50%, Sk=52%,
#     Test Acc: 97.98%, F1: 97.97%, Features: 1572/3043 (51.7%), Model: 1.823MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08029352448923659']
# ['At iteration 2 the best fitness is 0.08029352448923659']
# ['At iteration 3 the best fitness is 0.08029352448923659']
# ['At iteration 4 the best fitness is 0.07994847026643015']
# ['At iteration 5 the best fitness is 0.07994847026643015']
# ['At iteration 6 the best fitness is 0.07994847026643015']
# ['At iteration 7 the best fitness is 0.07994847026643015']
# ['At iteration 8 the best fitness is 0.07994847026643015']
# ['At iteration 9 the best fitness is 0.07600656155273722']
# ['At iteration 10 the best fitness is 0.07600656155273722']
# ['At iteration 11 the best fitness is 0.07600656155273722']
# ['At iteration 12 the best fitness is 0.07600656155273722']
# ['At iteration 13 the best fitness is 0.07600656155273722']
# ['At iteration 14 the best fitness is 0.07600656155273722']
# ['At iteration 15 the best fitness is 0.07600656155273722']
# ['At iteration 16 the best fitness is 0.07600656155273722']
# ['At iteration 17 the best fitness is 0.07600656155273722']
# ['At iteration 18 the best fitness is 0.07600656155273722']
# ['At iteration 19 the best fitness is 0.07600656155273722']
# ['At iteration 20 the best fitness is 0.07600656155273722']
# ['At iteration 21 the best fitness is 0.07600656155273722']
# ['At iteration 22 the best fitness is 0.07600656155273722']
# ['At iteration 23 the best fitness is 0.07600656155273722']
# ['At iteration 24 the best fitness is 0.07600656155273722']
# ['At iteration 25 the best fitness is 0.07600656155273722']
# ['At iteration 26 the best fitness is 0.07600656155273722']
# ['At iteration 27 the best fitness is 0.07600656155273722']
# ['At iteration 28 the best fitness is 0.07600656155273722']
# ['At iteration 29 the best fitness is 0.07203179053211034']
# ['At iteration 30 the best fitness is 0.07203179053211034']
#       Selected: 1505/3043 (49.5%), Fitness: 0.0720, Time: 2943.5s
#       Modality: D=48%, S=48%, Sk=51%,
#     Test Acc: 98.48%, F1: 98.45%, Features: 1505/3043 (49.5%), Model: 1.790MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0916756094867071']
# ['At iteration 2 the best fitness is 0.08806232384235363']
# ['At iteration 3 the best fitness is 0.08806232384235363']
# ['At iteration 4 the best fitness is 0.08426829550986346']
# ['At iteration 5 the best fitness is 0.08426829550986346']
# ['At iteration 6 the best fitness is 0.08426829550986346']
# ['At iteration 7 the best fitness is 0.08426829550986346']
# ['At iteration 8 the best fitness is 0.08426829550986346']
# ['At iteration 9 the best fitness is 0.08052356063777422']
# ['At iteration 10 the best fitness is 0.08052356063777422']
# ['At iteration 11 the best fitness is 0.08052356063777422']
# ['At iteration 12 the best fitness is 0.07599013039927024']
# ['At iteration 13 the best fitness is 0.07599013039927024']
# ['At iteration 14 the best fitness is 0.07599013039927024']
# ['At iteration 15 the best fitness is 0.07599013039927024']
# ['At iteration 16 the best fitness is 0.07599013039927024']
# ['At iteration 17 the best fitness is 0.07599013039927024']
# ['At iteration 18 the best fitness is 0.07599013039927024']
# ['At iteration 19 the best fitness is 0.07599013039927024']
# ['At iteration 20 the best fitness is 0.07599013039927024']
# ['At iteration 21 the best fitness is 0.07599013039927024']
# ['At iteration 22 the best fitness is 0.07599013039927024']
# ['At iteration 23 the best fitness is 0.07599013039927024']
# ['At iteration 24 the best fitness is 0.07599013039927024']
# ['At iteration 25 the best fitness is 0.07599013039927024']
# ['At iteration 26 the best fitness is 0.07599013039927024']
# ['At iteration 27 the best fitness is 0.07599013039927024']
# ['At iteration 28 the best fitness is 0.07599013039927024']
# ['At iteration 29 the best fitness is 0.07599013039927024']
# ['At iteration 30 the best fitness is 0.07599013039927024']
#       Selected: 1506/3043 (49.5%), Fitness: 0.0760, Time: 2967.7s
#       Modality: D=50%, S=56%, Sk=47%,
#     Test Acc: 94.95%, F1: 94.68%, Features: 1506/3043 (49.5%), Model: 1.790MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09234928677885301']
# ['At iteration 1 the best fitness is 0.09032825490241528']
# ['At iteration 2 the best fitness is 0.08916164300626017']
# ['At iteration 3 the best fitness is 0.0869270061347518']
# ['At iteration 4 the best fitness is 0.08267133738680568']
# ['At iteration 5 the best fitness is 0.08267133738680568']
# ['At iteration 6 the best fitness is 0.08267133738680568']
# ['At iteration 7 the best fitness is 0.0644718918189219']
# ['At iteration 8 the best fitness is 0.0644718918189219']
# ['At iteration 9 the best fitness is 0.0644718918189219']
# ['At iteration 10 the best fitness is 0.0644718918189219']
# ['At iteration 11 the best fitness is 0.0644718918189219']
# ['At iteration 12 the best fitness is 0.0644718918189219']
# ['At iteration 13 the best fitness is 0.0644718918189219']
# ['At iteration 14 the best fitness is 0.0644718918189219']
# ['At iteration 15 the best fitness is 0.0644718918189219']
# ['At iteration 16 the best fitness is 0.0644718918189219']
# ['At iteration 17 the best fitness is 0.0644718918189219']
# ['At iteration 18 the best fitness is 0.0644718918189219']
# ['At iteration 19 the best fitness is 0.0644718918189219']
# ['At iteration 20 the best fitness is 0.0644718918189219']
# ['At iteration 21 the best fitness is 0.0644718918189219']
# ['At iteration 22 the best fitness is 0.0644718918189219']
# ['At iteration 23 the best fitness is 0.0644718918189219']
# ['At iteration 24 the best fitness is 0.0644718918189219']
# ['At iteration 25 the best fitness is 0.0644718918189219']
# ['At iteration 26 the best fitness is 0.0644718918189219']
# ['At iteration 27 the best fitness is 0.0644718918189219']
# ['At iteration 28 the best fitness is 0.0644718918189219']
# ['At iteration 29 the best fitness is 0.0644718918189219']
#       Selected: 805/3043 (26.5%), Fitness: 0.0645, Time: 2900.1s
#       Modality: D=25%, S=27%, Sk=27%,
#     Test Acc: 94.44%, F1: 94.41%, Features: 805/3043 (26.5%), Model: 1.448MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08395610359399097']
# ['At iteration 2 the best fitness is 0.08086861486058065']
# ['At iteration 3 the best fitness is 0.08086861486058065']
# ['At iteration 4 the best fitness is 0.08086861486058065']
# ['At iteration 5 the best fitness is 0.08086861486058065']
# ['At iteration 6 the best fitness is 0.08024423102883567']
# ['At iteration 7 the best fitness is 0.08024423102883567']
# ['At iteration 8 the best fitness is 0.08024423102883567']
# ['At iteration 9 the best fitness is 0.08024423102883567']
# ['At iteration 10 the best fitness is 0.08024423102883567']
# ['At iteration 11 the best fitness is 0.08024423102883567']
# ['At iteration 12 the best fitness is 0.08024423102883567']
# ['At iteration 13 the best fitness is 0.08024423102883567']
# ['At iteration 14 the best fitness is 0.08024423102883567']
# ['At iteration 15 the best fitness is 0.07631875346860971']
# ['At iteration 16 the best fitness is 0.07631875346860971']
# ['At iteration 17 the best fitness is 0.07631875346860971']
# ['At iteration 18 the best fitness is 0.07631875346860971']
# ['At iteration 19 the best fitness is 0.07631875346860971']
# ['At iteration 20 the best fitness is 0.07631875346860971']
# ['At iteration 21 the best fitness is 0.07631875346860971']
# ['At iteration 22 the best fitness is 0.07631875346860971']
# ['At iteration 23 the best fitness is 0.07631875346860971']
# ['At iteration 24 the best fitness is 0.07262331205692138']
# ['At iteration 25 the best fitness is 0.07262331205692138']
# ['At iteration 26 the best fitness is 0.07262331205692138']
# ['At iteration 27 the best fitness is 0.0723604136014498']
# ['At iteration 28 the best fitness is 0.0723604136014498']
# ['At iteration 29 the best fitness is 0.0723604136014498']
#       Selected: 1525/3043 (50.1%), Fitness: 0.0724, Time: 7390.9s
#       Modality: D=50%, S=53%, Sk=49%,
#     Test Acc: 97.47%, F1: 97.37%, Features: 1525/3043 (50.1%), Model: 1.800MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07579295655766656']
# ['At iteration 1 the best fitness is 0.07314597273110317']
# ['At iteration 2 the best fitness is 0.07314597273110317']
# ['At iteration 3 the best fitness is 0.07314597273110317']
# ['At iteration 4 the best fitness is 0.07314597273110317']
# ['At iteration 5 the best fitness is 0.07314597273110317']
# ['At iteration 6 the best fitness is 0.07314597273110317']
# ['At iteration 7 the best fitness is 0.07314597273110317']
# ['At iteration 8 the best fitness is 0.07314597273110317']
# ['At iteration 9 the best fitness is 0.07314597273110317']
# ['At iteration 10 the best fitness is 0.07314597273110317']
# ['At iteration 11 the best fitness is 0.07314597273110317']
# ['At iteration 12 the best fitness is 0.07314597273110317']
# ['At iteration 13 the best fitness is 0.07314597273110317']
# ['At iteration 14 the best fitness is 0.07314597273110317']
# ['At iteration 15 the best fitness is 0.07314597273110317']
# ['At iteration 16 the best fitness is 0.07314597273110317']
# ['At iteration 17 the best fitness is 0.07314597273110317']
# ['At iteration 18 the best fitness is 0.07314597273110317']
# ['At iteration 19 the best fitness is 0.07314597273110317']
# ['At iteration 20 the best fitness is 0.07314597273110317']
# ['At iteration 21 the best fitness is 0.07314597273110317']
# ['At iteration 22 the best fitness is 0.07314597273110317']
# ['At iteration 23 the best fitness is 0.07314597273110317']
# ['At iteration 24 the best fitness is 0.07314597273110317']
# ['At iteration 25 the best fitness is 0.07314597273110317']
# ['At iteration 26 the best fitness is 0.07314597273110317']
# ['At iteration 27 the best fitness is 0.07314597273110317']
# ['At iteration 28 the best fitness is 0.07314597273110317']
# ['At iteration 29 the best fitness is 0.07314597273110317']
#       Selected: 1093/3043 (35.9%), Fitness: 0.0731, Time: 2335.6s
#       Modality: D=34%, S=37%, Sk=36%,
#     Test Acc: 94.95%, F1: 93.43%, Features: 1093/3043 (35.9%), Model: 1.589MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED (Transformer Model)
# ================================================================================

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879}, Total: 3043
# Results table: (90, 32)
# Methods: 18, Folds per method: {'baseline': 5, 'lasso': 5, 'meta_BAT': 5, 'meta_CS': 5, 'meta_DE': 5, 'meta_FFA': 5, 'meta_GA': 5, 'meta_GWO': 5, 'meta_HHO': 5, 'meta_JAYA': 5, 'meta_MFO': 5, 'meta_MVO': 5, 'meta_PSO': 5, 'meta_SCA': 5, 'meta_SSA': 5, 'meta_WOA': 5, 'mutual_info': 5, 'rfe': 5}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          97.552448        100.000000     97.529969
# 1  baseline     2          90.041494        100.000000     90.401814
# 2  baseline     3          90.909091        100.000000     88.249549
# 3  baseline     4          89.545455        100.000000     87.963283
# 4  baseline     5         100.000000         93.775934    100.000000
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        97.529969            97.935606         97.552448               3043
# 1        90.383826            92.705211         90.041322               3043
# 2        88.249549            90.335170         90.909091               3043
# 3        87.963283            89.025482         89.545455               3043
# 4       100.000000           100.000000        100.000000               3043
#
#    Features Total  ...  N Test  depth_retained  depth_total  \
# 0            3043  ...     286             512          512
# 1            3043  ...     241             512          512
# 2            3043  ...     220             512          512
# 3            3043  ...     220             512          512
# 4            3043  ...     198             512          512
#
#    depth_retention_%  sensor_retained  sensor_total  sensor_retention_%  \
# 0              100.0              652           652               100.0
# 1              100.0              652           652               100.0
# 2              100.0              652           652               100.0
# 3              100.0              652           652               100.0
# 4              100.0              652           652               100.0
#
#    skeleton_retained  skeleton_total  skeleton_retention_%
# 0               1879            1879                 100.0
# 1               1879            1879                 100.0
# 2               1879            1879                 100.0
# 3               1879            1879                 100.0
# 4               1879            1879                 100.0
#
# [5 rows x 32 columns]

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              93.61              4.82              92.83              5.57                  3043.0                      100.00              0.00                49.25                49.25           666070.0                  2.54                        0.00               31.88
# mutual_info              93.28              5.71              92.55              6.31                  1521.0                       49.98             29.93                46.32                76.25           471254.0                  1.80                       50.02               27.23
#         rfe              93.69              2.78              92.92              3.04                  1521.0                       49.98              5.29                46.16                51.45           471254.0                  1.80                       50.02               27.23
#       lasso              92.50              3.04              92.02              3.11                  1521.0                       49.98            180.71                45.84               226.56           471254.0                  1.80                       50.02               27.23
#    meta_BAT              95.72              4.34              95.56              4.61                  1463.6                       48.10           2914.80                46.56              2961.36           463906.8                  1.77                       51.90               27.06
#     meta_CS              94.41              5.22              93.97              5.73                  1437.8                       47.25           5659.56                46.30              5705.86           460604.4                  1.76                       52.75               26.98
#     meta_DE              94.32              5.92              93.94              6.50                  1396.4                       45.89           2853.95                45.82              2899.76           455305.2                  1.74                       54.11               26.85
#    meta_FFA              96.60              3.62              96.62              3.55                  1459.0                       47.95           2753.94                45.75              2799.69           463318.0                  1.77                       52.05               27.04
#     meta_GA              95.53              4.76              95.31              4.99                  1448.4                       47.60           2762.51                45.94              2808.45           461961.2                  1.76                       52.40               27.01
#    meta_GWO              92.71              4.08              92.27              4.05                   901.6                       29.63           2735.86                45.60              2781.47           391970.8                  1.50                       70.37               25.51
#    meta_HHO              94.46              4.41              94.30              4.60                   368.0                       12.09           3573.40                44.20              3617.60           323670.0                  1.23                       87.91               24.31
#   meta_JAYA              93.68              4.75              93.03              5.11                  1430.2                       47.00           2783.20                45.17              2828.37           459631.6                  1.75                       53.00               26.95
#    meta_MFO              95.30              4.36              95.30              4.27                  1452.4                       47.73           2636.11                46.86              2682.97           462473.2                  1.76                       52.27               27.02
#    meta_MVO              92.75              7.31              92.21              8.31                  1407.0                       46.24           2820.15                47.14              2867.29           456662.0                  1.74                       53.76               26.88
#    meta_PSO              93.94              3.59              93.82              3.51                  1376.2                       45.23           2795.24                46.91              2842.16           452719.6                  1.73                       54.77               26.79
#    meta_SCA              91.70              5.61              91.17              6.56                   423.0                       13.90           2704.23                43.39              2747.62           330710.0                  1.26                       86.10               24.43
#    meta_SSA              94.69              5.03              94.44              5.49                  1406.8                       46.23           6706.95                43.84              6750.79           456636.4                  1.74                       53.77               26.88
#    meta_WOA              91.61              4.73              90.84              4.74                   409.8                       13.47           2402.49                41.36              2443.85           329020.4                  1.26                       86.53               24.42

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_transformer
#
# Per-method folders:
#   results_transformer/baseline/ (10 files)
#   results_transformer/mutual_info/ (10 files)
#   results_transformer/rfe/ (10 files)
#   results_transformer/lasso/ (10 files)
#   results_transformer/meta_BAT/ (10 files)
#   results_transformer/meta_CS/ (10 files)
#   results_transformer/meta_DE/ (10 files)
#   results_transformer/meta_FFA/ (10 files)
#   results_transformer/meta_GA/ (10 files)
#   results_transformer/meta_GWO/ (10 files)
#   results_transformer/meta_HHO/ (10 files)
#   results_transformer/meta_JAYA/ (10 files)
#   results_transformer/meta_MFO/ (10 files)
#   results_transformer/meta_MVO/ (10 files)
#   results_transformer/meta_PSO/ (10 files)
#   results_transformer/meta_SCA/ (10 files)
#   results_transformer/meta_SSA/ (10 files)
#   results_transformer/meta_WOA/ (10 files)
#
# Plots directory: results_transformer/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_folds_results.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   meta_FFA            : 96.60% ± 3.62% (Features: 48.0%)
#   meta_BAT            : 95.72% ± 4.34% (Features: 48.1%)
#   meta_GA             : 95.53% ± 4.76% (Features: 47.6%)
#   meta_MFO            : 95.30% ± 4.36% (Features: 47.7%)
#   meta_SSA            : 94.69% ± 5.03% (Features: 46.2%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_BAT
#     F1 Macro:           99.30%
#     F1 Weighted:        99.30%
#     Test Accuracy:      99.30%
#     Feature Retention:  46.99% (1430/3043)
#     Modality Retention: depth=45.5%, sensor=46.0%, skeleton=47.7%
#
#   Fold 2: Best = meta_BAT
#     F1 Macro:           92.26%
#     F1 Weighted:        92.28%
#     Test Accuracy:      92.12%
#     Feature Retention:  47.88% (1457/3043)
#     Modality Retention: depth=49.0%, sensor=48.3%, skeleton=47.4%
#
#   Fold 3: Best = meta_FFA
#     F1 Macro:           99.54%
#     F1 Weighted:        99.54%
#     Test Accuracy:      99.55%
#     Feature Retention:  48.37% (1472/3043)
#     Modality Retention: depth=49.2%, sensor=48.8%, skeleton=48.0%
#
#   Fold 4: Best = meta_FFA
#     F1 Macro:           96.78%
#     F1 Weighted:        96.78%
#     Test Accuracy:      96.82%
#     Feature Retention:  46.83% (1425/3043)
#     Modality Retention: depth=45.3%, sensor=47.9%, skeleton=46.9%
#
#   Fold 5: Best = meta_CS
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  49.00% (1491/3043)
#     Modality Retention: depth=48.4%, sensor=50.5%, skeleton=48.6%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 97.58% ± 3.22%
#
#   Average F1 Weighted         : 97.58% ± 3.22%
#
#   Average Test Accuracy       : 97.56% ± 3.28%
#
#   Average Feature Retention   : 47.81% ± 0.92%
#
#   Average Modality-wise Feature Retention:
#            depth: 47.50% ± 1.93%
#           sensor: 48.28% ± 1.61%
#         skeleton: 47.74% ± 0.66%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%
#     1           meta_BAT         99.30            99.30              99.30                  46.99              45.51               46.01                 47.74
#     2           meta_BAT         92.26            92.28              92.12                  47.88              49.02               48.31                 47.42
#     3           meta_FFA         99.54            99.54              99.55                  48.37              49.22               48.77                 48.00
#     4           meta_FFA         96.78            96.78              96.82                  46.83              45.31               47.85                 46.89
#     5            meta_CS        100.00           100.00             100.00                  49.00              48.44               50.46                 48.64
#
# Saved to: results_transformer/best_metaheuristic_per_fold.csv
