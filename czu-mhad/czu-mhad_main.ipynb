# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

from sklearn.feature_selection import mutual_info_classif, RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.11.0+cu126
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## Configuration

# %%
FEATURE_DIR = Path("features")

RESULTS_ROOT = Path("results")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512
DEPTH_DR_METHOD = 'kernel_pca'

N_POPULATION = 20
MAX_ITERATIONS = 30

TARGET_FEATURE_PERCENTAGE = 0.5

EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   TOTAL: 8039
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx, depth_pca_dim=None):
    # Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.

    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    eval_count = [0] 
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    modality_ret = calculate_modality_retention(binary_mask, feature_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, ")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    print("    Running Mutual Information...")
    
    start_time = time.time()

    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top 50% features
    k = int(total_features * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(total_features, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, feature_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    print("    Running RFE...")
    
    start_time = time.time()
    
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top 50% features
    k = int(total_features * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, feature_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    print("    Running LASSO...")
    start_time = time.time()

    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    target_count = int(total_features * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(total_features, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, feature_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    master_results = {m: {} for m in ALL_METHODS}
    
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        

        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            
            # convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 97.20%, F1: 97.17%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 40.1s
#     Test Acc: 97.20%, F1: 97.20%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 9.0s
#     Test Acc: 93.36%, F1: 93.51%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 242.7s
#     Test Acc: 98.25%, F1: 98.24%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.028672445785492152']
# ['At iteration 1 the best fitness is 0.028606721171624258']
# ['At iteration 2 the best fitness is 0.028606721171624258']
# ['At iteration 3 the best fitness is 0.028573858864690313']
# ['At iteration 4 the best fitness is 0.02855742771122334']
# ['At iteration 5 the best fitness is 0.02855742771122334']
# ['At iteration 6 the best fitness is 0.02850813425082242']
# ['At iteration 7 the best fitness is 0.02850813425082242']
# ['At iteration 8 the best fitness is 0.028491703097355447']
# ['At iteration 9 the best fitness is 0.028475271943888474']
# ['At iteration 10 the best fitness is 0.028475271943888474']
# ['At iteration 11 the best fitness is 0.028475271943888474']
# ['At iteration 12 the best fitness is 0.028475271943888474']
# ['At iteration 13 the best fitness is 0.028475271943888474']
# ['At iteration 14 the best fitness is 0.028475271943888474']
# ['At iteration 15 the best fitness is 0.0284588407904215']
# ['At iteration 16 the best fitness is 0.028442409636954526']
# ['At iteration 17 the best fitness is 0.028442409636954526']
# ['At iteration 18 the best fitness is 0.028442409636954526']
# ['At iteration 19 the best fitness is 0.028442409636954526']
# ['At iteration 20 the best fitness is 0.028442409636954526']
# ['At iteration 21 the best fitness is 0.028442409636954526']
# ['At iteration 22 the best fitness is 0.028442409636954526']
# ['At iteration 23 the best fitness is 0.028425978483487553']
# ['At iteration 24 the best fitness is 0.028425978483487553']
# ['At iteration 25 the best fitness is 0.028425978483487553']
# ['At iteration 26 the best fitness is 0.028425978483487553']
# ['At iteration 27 the best fitness is 0.028425978483487553']
# ['At iteration 28 the best fitness is 0.028425978483487553']
# ['At iteration 29 the best fitness is 0.028425978483487553']
#       Selected: 1438/3043 (47.3%), Fitness: 0.0284, Time: 2131.1s
#       Modality: D=44%, S=50%, Sk=47%,
#     Test Acc: 98.60%, F1: 98.60%, Features: 1438/3043 (47.3%), Model: 3.345MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024745317121261913']
# ['At iteration 10 the best fitness is 0.02403877752218206']
# ['At iteration 20 the best fitness is 0.02403877752218206']
#       Selected: 1436/3043 (47.2%), Fitness: 0.0236, Time: 4217.2s
#       Modality: D=47%, S=47%, Sk=47%,
#     Test Acc: 96.85%, F1: 96.84%, Features: 1436/3043 (47.2%), Model: 3.341MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.029263967310303195']
# ['At iteration 2 the best fitness is 0.029263967310303195']
# ['At iteration 3 the best fitness is 0.029099655775633462']
# ['At iteration 4 the best fitness is 0.028688876938959128']
# ['At iteration 5 the best fitness is 0.028623152325091234']
# ['At iteration 6 the best fitness is 0.028623152325091234']
# ['At iteration 7 the best fitness is 0.0284588407904215']
# ['At iteration 8 the best fitness is 0.02831096040921874']
# ['At iteration 9 the best fitness is 0.027998768493346246']
# ['At iteration 10 the best fitness is 0.027998768493346246']
# ['At iteration 11 the best fitness is 0.027998768493346246']
# ['At iteration 12 the best fitness is 0.027998768493346246']
# ['At iteration 13 the best fitness is 0.02344725599737102']
# ['At iteration 14 the best fitness is 0.02344725599737102']
# ['At iteration 15 the best fitness is 0.02344725599737102']
# ['At iteration 16 the best fitness is 0.02344725599737102']
# ['At iteration 17 the best fitness is 0.02344725599737102']
# ['At iteration 18 the best fitness is 0.022773578705225107']
# ['At iteration 19 the best fitness is 0.022773578705225107']
# ['At iteration 20 the best fitness is 0.022773578705225107']
# ['At iteration 21 the best fitness is 0.022773578705225107']
# ['At iteration 22 the best fitness is 0.022773578705225107']
# ['At iteration 23 the best fitness is 0.022773578705225107']
# ['At iteration 24 the best fitness is 0.022773578705225107']
# ['At iteration 25 the best fitness is 0.022773578705225107']
# ['At iteration 26 the best fitness is 0.022773578705225107']
# ['At iteration 27 the best fitness is 0.022773578705225107']
# ['At iteration 28 the best fitness is 0.022773578705225107']
# ['At iteration 29 the best fitness is 0.022773578705225107']
# ['At iteration 30 the best fitness is 0.022773578705225107']
#       Selected: 1386/3043 (45.5%), Fitness: 0.0228, Time: 2131.4s
#       Modality: D=51%, S=43%, Sk=45%,
#     Test Acc: 98.25%, F1: 98.25%, Features: 1386/3043 (45.5%), Model: 3.243MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.028721739245893073']
# ['At iteration 1 the best fitness is 0.028935344240963726']
# ['At iteration 2 the best fitness is 0.024482418665790342']
# ['At iteration 3 the best fitness is 0.028771032706293994']
# ['At iteration 4 the best fitness is 0.028590290018157286']
# ['At iteration 5 the best fitness is 0.028475271943888474']
# ['At iteration 6 the best fitness is 0.02831096040921874']
# ['At iteration 7 the best fitness is 0.02831096040921874']
# ['At iteration 8 the best fitness is 0.028278098102284793']
# ['At iteration 9 the best fitness is 0.028228804641883872']
# ['At iteration 10 the best fitness is 0.028228804641883872']
# ['At iteration 11 the best fitness is 0.028228804641883872']
# ['At iteration 12 the best fitness is 0.0282123734884169']
# ['At iteration 13 the best fitness is 0.02817951118148295']
# ['At iteration 14 the best fitness is 0.028130217721082033']
# ['At iteration 15 the best fitness is 0.028130217721082033']
# ['At iteration 16 the best fitness is 0.028130217721082033']
# ['At iteration 17 the best fitness is 0.028130217721082033']
# ['At iteration 18 the best fitness is 0.028113786567615057']
# ['At iteration 19 the best fitness is 0.028080924260681112']
# ['At iteration 20 the best fitness is 0.028064493107214136']
# ['At iteration 21 the best fitness is 0.028064493107214136']
# ['At iteration 22 the best fitness is 0.028064493107214136']
# ['At iteration 23 the best fitness is 0.028064493107214136']
# ['At iteration 24 the best fitness is 0.028064493107214136']
# ['At iteration 25 the best fitness is 0.028064493107214136']
# ['At iteration 26 the best fitness is 0.028064493107214136']
# ['At iteration 27 the best fitness is 0.028064493107214136']
# ['At iteration 28 the best fitness is 0.028064493107214136']
# ['At iteration 29 the best fitness is 0.028064493107214136']
#       Selected: 1416/3043 (46.5%), Fitness: 0.0281, Time: 2055.2s
#       Modality: D=44%, S=47%, Sk=47%,
#     Test Acc: 97.55%, F1: 97.56%, Features: 1416/3043 (46.5%), Model: 3.302MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.028803895013227943
# At iteration 2 the best fitness is 0.02433453828458758
# At iteration 3 the best fitness is 0.028623152325091234
# At iteration 4 the best fitness is 0.028573858864690313
# At iteration 5 the best fitness is 0.028573858864690313
# At iteration 6 the best fitness is 0.028475271943888474
# At iteration 7 the best fitness is 0.028540996557756368
# At iteration 8 the best fitness is 0.028475271943888474
# At iteration 9 the best fitness is 0.028343822716152683
# At iteration 10 the best fitness is 0.023545842918172855
# At iteration 11 the best fitness is 0.02403877752218206
# At iteration 12 the best fitness is 0.02453171212619126
# At iteration 13 the best fitness is 0.028376685023086632
# At iteration 14 the best fitness is 0.02831096040921874
# At iteration 15 the best fitness is 0.0282123734884169
# At iteration 16 the best fitness is 0.028146648874549006
# At iteration 17 the best fitness is 0.028146648874549006
# At iteration 18 the best fitness is 0.028146648874549006
# At iteration 19 the best fitness is 0.028146648874549006
# At iteration 20 the best fitness is 0.028146648874549006
# At iteration 21 the best fitness is 0.028146648874549006
# At iteration 22 the best fitness is 0.024071639829116004
# At iteration 23 the best fitness is 0.028080924260681112
# At iteration 24 the best fitness is 0.028080924260681112
# At iteration 25 the best fitness is 0.027801594651742565
# At iteration 26 the best fitness is 0.027801594651742565
# At iteration 27 the best fitness is 0.027801594651742565
# At iteration 28 the best fitness is 0.027670145424006778
# At iteration 29 the best fitness is 0.027670145424006778
# At iteration 30 the best fitness is 0.027670145424006778
#       Selected: 1392/3043 (45.7%), Fitness: 0.0277, Time: 2046.9s
#       Modality: D=44%, S=46%, Sk=46%,
#     Test Acc: 97.55%, F1: 97.55%, Features: 1392/3043 (45.7%), Model: 3.255MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02878746385976097']
# ['At iteration 1 the best fitness is 0.027357953508134282']
# ['At iteration 2 the best fitness is 0.026799294290257188']
# ['At iteration 3 the best fitness is 0.021344068353598422']
# ['At iteration 4 the best fitness is 0.020111731843575422']
# ['At iteration 5 the best fitness is 0.020111731843575422']
# ['At iteration 6 the best fitness is 0.020111731843575422']
# ['At iteration 7 the best fitness is 0.020111731843575422']
# ['At iteration 8 the best fitness is 0.020111731843575422']
# ['At iteration 9 the best fitness is 0.020111731843575422']
# ['At iteration 10 the best fitness is 0.01856720341767992']
# ['At iteration 11 the best fitness is 0.01856720341767992']
# ['At iteration 12 the best fitness is 0.01856720341767992']
# ['At iteration 13 the best fitness is 0.01856720341767992']
# ['At iteration 14 the best fitness is 0.01856720341767992']
# ['At iteration 15 the best fitness is 0.01856720341767992']
# ['At iteration 16 the best fitness is 0.01856720341767992']
# ['At iteration 17 the best fitness is 0.01856720341767992']
# ['At iteration 18 the best fitness is 0.01856720341767992']
# ['At iteration 19 the best fitness is 0.01856720341767992']
# ['At iteration 20 the best fitness is 0.01856720341767992']
# ['At iteration 21 the best fitness is 0.01856720341767992']
# ['At iteration 22 the best fitness is 0.01856720341767992']
# ['At iteration 23 the best fitness is 0.01856720341767992']
# ['At iteration 24 the best fitness is 0.01856720341767992']
# ['At iteration 25 the best fitness is 0.01856720341767992']
# ['At iteration 26 the best fitness is 0.01856720341767992']
# ['At iteration 27 the best fitness is 0.01856720341767992']
# ['At iteration 28 the best fitness is 0.01856720341767992']
# ['At iteration 29 the best fitness is 0.01856720341767992']
#       Selected: 1130/3043 (37.1%), Fitness: 0.0186, Time: 1990.5s
#       Modality: D=34%, S=39%, Sk=38%,
#     Test Acc: 97.20%, F1: 97.20%, Features: 1130/3043 (37.1%), Model: 2.743MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.028918913087496754']
# ['At iteration 1 the best fitness is 0.019323285434031397']
# ['At iteration 2 the best fitness is 0.012750658075994946']
# ['At iteration 3 the best fitness is 0.012750658075994946']
# ['At iteration 4 the best fitness is 0.012027687323448118']
# ['At iteration 5 the best fitness is 0.005520867564903057']
# ['At iteration 6 the best fitness is 0.005520867564903057']
# ['At iteration 7 the best fitness is 0.005520867564903057']
# ['At iteration 8 the best fitness is 0.005520867564903057']
# ['At iteration 9 the best fitness is 0.005520867564903057']
# ['At iteration 10 the best fitness is 0.005520867564903057']
# ['At iteration 11 the best fitness is 0.005520867564903057']
# ['At iteration 12 the best fitness is 0.005520867564903057']
# ['At iteration 13 the best fitness is 0.005520867564903057']
# ['At iteration 14 the best fitness is 0.005520867564903057']
# ['At iteration 15 the best fitness is 0.005520867564903057']
# ['At iteration 16 the best fitness is 0.005520867564903057']
# ['At iteration 17 the best fitness is 0.005520867564903057']
# ['At iteration 18 the best fitness is 0.005488005257969109']
# ['At iteration 19 the best fitness is 0.005488005257969109']
# ['At iteration 20 the best fitness is 0.005488005257969109']
# ['At iteration 21 the best fitness is 0.005488005257969109']
# ['At iteration 22 the best fitness is 0.005488005257969109']
# ['At iteration 23 the best fitness is 0.005488005257969109']
# ['At iteration 24 the best fitness is 0.005356556030233323']
# ['At iteration 25 the best fitness is 0.005356556030233323']
# ['At iteration 26 the best fitness is 0.005356556030233323']
# ['At iteration 27 the best fitness is 0.005356556030233323']
# ['At iteration 28 the best fitness is 0.005356556030233323']
# ['At iteration 29 the best fitness is 0.005356556030233323']
#       Selected: 326/3043 (10.7%), Fitness: 0.0054, Time: 2787.0s
#       Modality: D=11%, S=11%, Sk=11%,
#     Test Acc: 96.50%, F1: 96.50%, Features: 326/3043 (10.7%), Model: 1.173MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.028524565404289395']
# ['At iteration 1 the best fitness is 0.02850813425082242']
# ['At iteration 2 the best fitness is 0.02850813425082242']
# ['At iteration 3 the best fitness is 0.02850813425082242']
# ['At iteration 4 the best fitness is 0.028491703097355447']
# ['At iteration 5 the best fitness is 0.028475271943888474']
# ['At iteration 6 the best fitness is 0.028475271943888474']
# ['At iteration 7 the best fitness is 0.028475271943888474']
# ['At iteration 8 the best fitness is 0.028442409636954526']
# ['At iteration 9 the best fitness is 0.023973052908314165']
# ['At iteration 10 the best fitness is 0.023973052908314165']
# ['At iteration 11 the best fitness is 0.023973052908314165']
# ['At iteration 12 the best fitness is 0.023973052908314165']
# ['At iteration 13 the best fitness is 0.023973052908314165']
# ['At iteration 14 the best fitness is 0.023973052908314165']
# ['At iteration 15 the best fitness is 0.023973052908314165']
# ['At iteration 16 the best fitness is 0.023973052908314165']
# ['At iteration 17 the best fitness is 0.023973052908314165']
# ['At iteration 18 the best fitness is 0.023973052908314165']
# ['At iteration 19 the best fitness is 0.023973052908314165']
# ['At iteration 20 the best fitness is 0.023973052908314165']
# ['At iteration 21 the best fitness is 0.023973052908314165']
# ['At iteration 22 the best fitness is 0.023973052908314165']
# ['At iteration 23 the best fitness is 0.023973052908314165']
# ['At iteration 24 the best fitness is 0.023973052908314165']
# ['At iteration 25 the best fitness is 0.023973052908314165']
# ['At iteration 26 the best fitness is 0.023973052908314165']
# ['At iteration 27 the best fitness is 0.023973052908314165']
# ['At iteration 28 the best fitness is 0.023973052908314165']
# ['At iteration 29 the best fitness is 0.023973052908314165']
#       Selected: 1459/3043 (47.9%), Fitness: 0.0240, Time: 2128.3s
#       Modality: D=51%, S=49%, Sk=47%,
#     Test Acc: 98.25%, F1: 98.25%, Features: 1459/3043 (47.9%), Model: 3.386MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.029444709998439903']
# ['At iteration 2 the best fitness is 0.02937898538457201']
# ['At iteration 3 the best fitness is 0.024843904042063755']
# ['At iteration 4 the best fitness is 0.024843904042063755']
# ['At iteration 5 the best fitness is 0.024843904042063755']
# ['At iteration 6 the best fitness is 0.024843904042063755']
# ['At iteration 7 the best fitness is 0.024843904042063755']
# ['At iteration 8 the best fitness is 0.024843904042063755']
# ['At iteration 9 the best fitness is 0.024843904042063755']
# ['At iteration 10 the best fitness is 0.024843904042063755']
# ['At iteration 11 the best fitness is 0.024843904042063755']
# ['At iteration 12 the best fitness is 0.024843904042063755']
# ['At iteration 13 the best fitness is 0.024843904042063755']
# ['At iteration 14 the best fitness is 0.02472888596779494']
# ['At iteration 15 the best fitness is 0.02472888596779494']
# ['At iteration 16 the best fitness is 0.02472888596779494']
# ['At iteration 17 the best fitness is 0.02472888596779494']
# ['At iteration 18 the best fitness is 0.02467959250739402']
# ['At iteration 19 the best fitness is 0.02467959250739402']
# ['At iteration 20 the best fitness is 0.02467959250739402']
# ['At iteration 21 the best fitness is 0.02467959250739402']
# ['At iteration 22 the best fitness is 0.024104502136049952']
# ['At iteration 23 the best fitness is 0.024104502136049952']
# ['At iteration 24 the best fitness is 0.024104502136049952']
# ['At iteration 25 the best fitness is 0.024104502136049952']
# ['At iteration 26 the best fitness is 0.024104502136049952']
# ['At iteration 27 the best fitness is 0.024104502136049952']
# ['At iteration 28 the best fitness is 0.024104502136049952']
# ['At iteration 29 the best fitness is 0.024104502136049952']
#       Selected: 1467/3043 (48.2%), Fitness: 0.0241, Time: 1867.4s
#       Modality: D=45%, S=49%, Sk=49%,
#     Test Acc: 98.60%, F1: 98.60%, Features: 1467/3043 (48.2%), Model: 3.401MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02923110500336925']
# ['At iteration 2 the best fitness is 0.02890248193402978']
# ['At iteration 3 the best fitness is 0.028771032706293994']
# ['At iteration 4 the best fitness is 0.025090371344068354']
# ['At iteration 5 the best fitness is 0.025090371344068354']
# ['At iteration 6 the best fitness is 0.025090371344068354']
# ['At iteration 7 the best fitness is 0.025090371344068354']
# ['At iteration 8 the best fitness is 0.025090371344068354']
# ['At iteration 9 the best fitness is 0.025090371344068354']
# ['At iteration 10 the best fitness is 0.025090371344068354']
# ['At iteration 11 the best fitness is 0.024696023660860992']
# ['At iteration 12 the best fitness is 0.024696023660860992']
# ['At iteration 13 the best fitness is 0.024696023660860992']
# ['At iteration 14 the best fitness is 0.024696023660860992']
# ['At iteration 15 the best fitness is 0.024696023660860992']
# ['At iteration 16 the best fitness is 0.024696023660860992']
# ['At iteration 17 the best fitness is 0.024564574433125208']
# ['At iteration 18 the best fitness is 0.02435096943805455']
# ['At iteration 19 the best fitness is 0.02435096943805455']
# ['At iteration 20 the best fitness is 0.02435096943805455']
# ['At iteration 21 the best fitness is 0.02435096943805455']
# ['At iteration 22 the best fitness is 0.02435096943805455']
# ['At iteration 23 the best fitness is 0.02435096943805455']
# ['At iteration 24 the best fitness is 0.02435096943805455']
# ['At iteration 25 the best fitness is 0.02435096943805455']
# ['At iteration 26 the best fitness is 0.02435096943805455']
# ['At iteration 27 the best fitness is 0.02435096943805455']
# ['At iteration 28 the best fitness is 0.02435096943805455']
# ['At iteration 29 the best fitness is 0.02435096943805455']
# ['At iteration 30 the best fitness is 0.02435096943805455']
#       Selected: 1482/3043 (48.7%), Fitness: 0.0244, Time: 2006.7s
#       Modality: D=50%, S=50%, Sk=48%,
#     Test Acc: 98.60%, F1: 98.60%, Features: 1482/3043 (48.7%), Model: 3.431MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.029247536156836222']
# ['At iteration 2 the best fitness is 0.02865601463202518']
# ['At iteration 3 the best fitness is 0.028573858864690313']
# ['At iteration 4 the best fitness is 0.028425978483487553']
# ['At iteration 5 the best fitness is 0.028343822716152683']
# ['At iteration 6 the best fitness is 0.028343822716152683']
# ['At iteration 7 the best fitness is 0.028146648874549006']
# ['At iteration 8 the best fitness is 0.027818025805209538']
# ['At iteration 9 the best fitness is 0.027818025805209538']
# ['At iteration 10 the best fitness is 0.027818025805209538']
# ['At iteration 11 the best fitness is 0.0277194388844077']
# ['At iteration 12 the best fitness is 0.0277194388844077']
# ['At iteration 13 the best fitness is 0.027653714270539805']
# ['At iteration 14 the best fitness is 0.027555127349737963']
# ['At iteration 15 the best fitness is 0.027555127349737963']
# ['At iteration 16 the best fitness is 0.02748940273587007']
# ['At iteration 17 the best fitness is 0.027456540428936124']
# ['At iteration 18 the best fitness is 0.027160779666530604']
# ['At iteration 19 the best fitness is 0.027029330438794814']
# ['At iteration 20 the best fitness is 0.027029330438794814']
# ['At iteration 21 the best fitness is 0.027029330438794814']
# ['At iteration 22 the best fitness is 0.022264212947748933']
# ['At iteration 23 the best fitness is 0.022264212947748933']
# ['At iteration 24 the best fitness is 0.022264212947748933']
# ['At iteration 25 the best fitness is 0.022264212947748933']
# ['At iteration 26 the best fitness is 0.022264212947748933']
# ['At iteration 27 the best fitness is 0.022264212947748933']
# ['At iteration 28 the best fitness is 0.022264212947748933']
# ['At iteration 29 the best fitness is 0.022264212947748933']
# ['At iteration 30 the best fitness is 0.022264212947748933']
#       Selected: 1355/3043 (44.5%), Fitness: 0.0223, Time: 2066.2s
#       Modality: D=46%, S=46%, Sk=44%,
#     Test Acc: 96.50%, F1: 96.54%, Features: 1355/3043 (44.5%), Model: 3.183MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02923110500336925']
# ['At iteration 1 the best fitness is 0.027407246968535203']
# ['At iteration 2 the best fitness is 0.02292154207205147']
# ['At iteration 3 the best fitness is 0.019553155611321926']
# ['At iteration 4 the best fitness is 0.01661189615511009']
# ['At iteration 5 the best fitness is 0.01661189615511009']
# ['At iteration 6 the best fitness is 0.01661189615511009']
# ['At iteration 7 the best fitness is 0.013539270456786066']
# ['At iteration 8 the best fitness is 0.013539270456786066']
# ['At iteration 9 the best fitness is 0.013539270456786066']
# ['At iteration 10 the best fitness is 0.01137035819914558']
# ['At iteration 11 the best fitness is 0.010055865921787711']
# ['At iteration 12 the best fitness is 0.010055865921787711']
# ['At iteration 13 the best fitness is 0.010055865921787711']
# ['At iteration 14 the best fitness is 0.010055865921787711']
# ['At iteration 15 the best fitness is 0.00846204403549129']
# ['At iteration 16 the best fitness is 0.008297732500821558']
# ['At iteration 17 the best fitness is 0.0072954321393361825']
# ['At iteration 18 the best fitness is 0.007213276372001315']
# ['At iteration 19 the best fitness is 0.007213276372001315']
# ['At iteration 20 the best fitness is 0.007081827144265528']
# ['At iteration 21 the best fitness is 0.006178113703581992']
# ['At iteration 22 the best fitness is 0.006178113703581992']
# ['At iteration 23 the best fitness is 0.006178113703581992']
# ['At iteration 24 the best fitness is 0.006178113703581992']
# ['At iteration 25 the best fitness is 0.006178113703581992']
# ['At iteration 26 the best fitness is 0.006178113703581992']
# ['At iteration 27 the best fitness is 0.006178113703581992']
# ['At iteration 28 the best fitness is 0.006178113703581992']
# ['At iteration 29 the best fitness is 0.006178113703581992']
#       Selected: 376/3043 (12.4%), Fitness: 0.0062, Time: 2109.3s
#       Modality: D=15%, S=14%, Sk=11%,
#     Test Acc: 96.85%, F1: 96.91%, Features: 376/3043 (12.4%), Model: 1.271MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02885318847362886']
# ['At iteration 2 the best fitness is 0.02885318847362886']
# ['At iteration 3 the best fitness is 0.02885318847362886']
# ['At iteration 4 the best fitness is 0.028672445785492152']
# ['At iteration 5 the best fitness is 0.02836025386961966']
# ['At iteration 6 the best fitness is 0.023595136378573776']
# ['At iteration 7 the best fitness is 0.023595136378573776']
# ['At iteration 8 the best fitness is 0.023595136378573776']
# ['At iteration 9 the best fitness is 0.02356227407163983']
# ['At iteration 10 the best fitness is 0.02356227407163983']
# ['At iteration 11 the best fitness is 0.02356227407163983']
# ['At iteration 12 the best fitness is 0.02356227407163983']
# ['At iteration 13 the best fitness is 0.02356227407163983']
# ['At iteration 14 the best fitness is 0.023381531383503122']
# ['At iteration 15 the best fitness is 0.023381531383503122']
# ['At iteration 16 the best fitness is 0.023381531383503122']
# ['At iteration 17 the best fitness is 0.023381531383503122']
# ['At iteration 18 the best fitness is 0.023381531383503122']
# ['At iteration 19 the best fitness is 0.023348669076569177']
# ['At iteration 20 the best fitness is 0.023348669076569177']
# ['At iteration 21 the best fitness is 0.023348669076569177']
# ['At iteration 22 the best fitness is 0.023348669076569177']
# ['At iteration 23 the best fitness is 0.023348669076569177']
# ['At iteration 24 the best fitness is 0.023348669076569177']
# ['At iteration 25 the best fitness is 0.023348669076569177']
# ['At iteration 26 the best fitness is 0.023348669076569177']
# ['At iteration 27 the best fitness is 0.023348669076569177']
# ['At iteration 28 the best fitness is 0.023348669076569177']
# ['At iteration 29 the best fitness is 0.023348669076569177']
#       Selected: 1421/3043 (46.7%), Fitness: 0.0233, Time: 5187.2s
#       Modality: D=48%, S=47%, Sk=46%,
#     Test Acc: 97.90%, F1: 97.88%, Features: 1421/3043 (46.7%), Model: 3.312MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.029214673849902274']
# ['At iteration 1 the best fitness is 0.018665873324105367']
# ['At iteration 2 the best fitness is 0.015166120621263528']
# ['At iteration 3 the best fitness is 0.01072962619955722']
# ['At iteration 4 the best fitness is 0.01072962619955722']
# ['At iteration 5 the best fitness is 0.01038457197675078']
# ['At iteration 6 the best fitness is 0.01038457197675078']
# ['At iteration 7 the best fitness is 0.01038457197675078']
# ['At iteration 8 the best fitness is 0.01038457197675078']
# ['At iteration 9 the best fitness is 0.01038457197675078']
# ['At iteration 10 the best fitness is 0.01038457197675078']
# ['At iteration 11 the best fitness is 0.01038457197675078']
# ['At iteration 12 the best fitness is 0.01038457197675078']
# ['At iteration 13 the best fitness is 0.01038457197675078']
# ['At iteration 14 the best fitness is 0.010351709669816831']
# ['At iteration 15 the best fitness is 0.010351709669816831']
# ['At iteration 16 the best fitness is 0.010351709669816831']
# ['At iteration 17 the best fitness is 0.009924499679675524']
# ['At iteration 18 the best fitness is 0.009924499679675524']
# ['At iteration 19 the best fitness is 0.009924499679675524']
# ['At iteration 20 the best fitness is 0.009924499679675524']
# ['At iteration 21 the best fitness is 0.009924499679675524']
# ['At iteration 22 the best fitness is 0.009924499679675524']
# ['At iteration 23 the best fitness is 0.009480858536067243']
# ['At iteration 24 the best fitness is 0.009480858536067243']
# ['At iteration 25 the best fitness is 0.009480858536067243']
# ['At iteration 26 the best fitness is 0.009480858536067243']
# ['At iteration 27 the best fitness is 0.009480858536067243']
# ['At iteration 28 the best fitness is 0.009201528927128695']
# ['At iteration 29 the best fitness is 0.009201528927128695']
#       Selected: 268/3043 (8.8%), Fitness: 0.0092, Time: 2113.5s
#       Modality: D=9%, S=9%, Sk=9%,
#     Test Acc: 96.50%, F1: 96.54%, Features: 268/3043 (8.8%), Model: 1.060MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 93.36%, F1: 93.47%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 44.6s
#     Test Acc: 93.36%, F1: 93.77%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 9.5s
#     Test Acc: 91.70%, F1: 92.13%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 273.7s
#     Test Acc: 90.46%, F1: 90.62%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023923759447913244']
# ['At iteration 1 the best fitness is 0.02390732829444627']
# ['At iteration 2 the best fitness is 0.023841603680578378']
# ['At iteration 3 the best fitness is 0.023841603680578378']
# ['At iteration 4 the best fitness is 0.023578705225106803']
# ['At iteration 5 the best fitness is 0.023578705225106803']
# ['At iteration 6 the best fitness is 0.023578705225106803']
# ['At iteration 7 the best fitness is 0.023578705225106803']
# ['At iteration 8 the best fitness is 0.023578705225106803']
# ['At iteration 9 the best fitness is 0.023578705225106803']
# ['At iteration 10 the best fitness is 0.023578705225106803']
# ['At iteration 11 the best fitness is 0.023578705225106803']
# ['At iteration 12 the best fitness is 0.023578705225106803']
# ['At iteration 13 the best fitness is 0.02356227407163983']
# ['At iteration 14 the best fitness is 0.02356227407163983']
# ['At iteration 15 the best fitness is 0.02356227407163983']
# ['At iteration 16 the best fitness is 0.02356227407163983']
# ['At iteration 17 the best fitness is 0.02356227407163983']
# ['At iteration 18 the best fitness is 0.02356227407163983']
# ['At iteration 19 the best fitness is 0.02356227407163983']
# ['At iteration 20 the best fitness is 0.02356227407163983']
# ['At iteration 21 the best fitness is 0.02356227407163983']
# ['At iteration 22 the best fitness is 0.02356227407163983']
# ['At iteration 23 the best fitness is 0.02356227407163983']
# ['At iteration 24 the best fitness is 0.02356227407163983']
# ['At iteration 25 the best fitness is 0.02356227407163983']
# ['At iteration 26 the best fitness is 0.02356227407163983']
# ['At iteration 27 the best fitness is 0.02356227407163983']
# ['At iteration 28 the best fitness is 0.02356227407163983']
# ['At iteration 29 the best fitness is 0.02356227407163983']
#       Selected: 1434/3043 (47.1%), Fitness: 0.0236, Time: 2191.9s
#       Modality: D=48%, S=47%, Sk=47%,
#     Test Acc: 93.36%, F1: 93.42%, Features: 1434/3043 (47.1%), Model: 3.337MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02394019060138022']
# ['At iteration 10 the best fitness is 0.023874465987512323']
# ['At iteration 20 the best fitness is 0.02385803483404535']
#       Selected: 1428/3043 (46.9%), Fitness: 0.0235, Time: 4367.1s
#       Modality: D=45%, S=49%, Sk=47%,
#     Test Acc: 92.12%, F1: 92.19%, Features: 1428/3043 (46.9%), Model: 3.325MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023841603680578378']
# ['At iteration 2 the best fitness is 0.023792310220177457']
# ['At iteration 3 the best fitness is 0.023792310220177457']
# ['At iteration 4 the best fitness is 0.023792310220177457']
# ['At iteration 5 the best fitness is 0.023496549457771937']
# ['At iteration 6 the best fitness is 0.023496549457771937']
# ['At iteration 7 the best fitness is 0.023167926388432472']
# ['At iteration 8 the best fitness is 0.023167926388432472']
# ['At iteration 9 the best fitness is 0.023167926388432472']
# ['At iteration 10 the best fitness is 0.023167926388432472']
# ['At iteration 11 the best fitness is 0.023167926388432472']
# ['At iteration 12 the best fitness is 0.022905027932960897']
# ['At iteration 13 the best fitness is 0.022905027932960897']
# ['At iteration 14 the best fitness is 0.022905027932960897']
# ['At iteration 15 the best fitness is 0.022905027932960897']
# ['At iteration 16 the best fitness is 0.02274071639829116']
# ['At iteration 17 the best fitness is 0.02274071639829116']
# ['At iteration 18 the best fitness is 0.02274071639829116']
# ['At iteration 19 the best fitness is 0.02274071639829116']
# ['At iteration 20 the best fitness is 0.02274071639829116']
# ['At iteration 21 the best fitness is 0.02254354255668748']
# ['At iteration 22 the best fitness is 0.022527111403220508']
# ['At iteration 23 the best fitness is 0.022510680249753532']
# ['At iteration 24 the best fitness is 0.022510680249753532']
# ['At iteration 25 the best fitness is 0.022461386789352614']
# ['At iteration 26 the best fitness is 0.0223463687150838']
# ['At iteration 27 the best fitness is 0.022280644101215906']
# ['At iteration 28 the best fitness is 0.022264212947748933']
# ['At iteration 29 the best fitness is 0.022264212947748933']
# ['At iteration 30 the best fitness is 0.022264212947748933']
#       Selected: 1355/3043 (44.5%), Fitness: 0.0223, Time: 2398.5s
#       Modality: D=46%, S=44%, Sk=44%,
#     Test Acc: 92.53%, F1: 92.60%, Features: 1355/3043 (44.5%), Model: 3.183MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02420308905685179']
# ['At iteration 1 the best fitness is 0.02420308905685179']
# ['At iteration 2 the best fitness is 0.02390732829444627']
# ['At iteration 3 the best fitness is 0.0238908971409793']
# ['At iteration 4 the best fitness is 0.02385803483404535']
# ['At iteration 5 the best fitness is 0.023430824843904043']
# ['At iteration 6 the best fitness is 0.023430824843904043']
# ['At iteration 7 the best fitness is 0.023430824843904043']
# ['At iteration 8 the best fitness is 0.023430824843904043']
# ['At iteration 9 the best fitness is 0.02331580676963523']
# ['At iteration 10 the best fitness is 0.02331580676963523']
# ['At iteration 11 the best fitness is 0.023348669076569177']
# ['At iteration 12 the best fitness is 0.023348669076569177']
# ['At iteration 13 the best fitness is 0.023299375616168256']
# ['At iteration 14 the best fitness is 0.023299375616168256']
# ['At iteration 15 the best fitness is 0.023299375616168256']
# ['At iteration 16 the best fitness is 0.023299375616168256']
# ['At iteration 17 the best fitness is 0.023233651002300362']
# ['At iteration 18 the best fitness is 0.023233651002300362']
# ['At iteration 19 the best fitness is 0.02321721984883339']
# ['At iteration 20 the best fitness is 0.02321721984883339']
# ['At iteration 21 the best fitness is 0.02321721984883339']
# ['At iteration 22 the best fitness is 0.023200788695366417']
# ['At iteration 23 the best fitness is 0.023200788695366417']
# ['At iteration 24 the best fitness is 0.023200788695366417']
# ['At iteration 25 the best fitness is 0.023200788695366417']
# ['At iteration 26 the best fitness is 0.023200788695366417']
# ['At iteration 27 the best fitness is 0.023200788695366417']
# ['At iteration 28 the best fitness is 0.023200788695366417']
# ['At iteration 29 the best fitness is 0.023200788695366417']
#       Selected: 1412/3043 (46.4%), Fitness: 0.0232, Time: 2498.0s
#       Modality: D=45%, S=48%, Sk=46%,
#     Test Acc: 91.70%, F1: 91.85%, Features: 1412/3043 (46.4%), Model: 3.294MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024252382517252712
# At iteration 2 the best fitness is 0.02418665790338482
# At iteration 3 the best fitness is 0.024153795596450874
# At iteration 4 the best fitness is 0.02405520867564903
# At iteration 5 the best fitness is 0.02405520867564903
# At iteration 6 the best fitness is 0.02405520867564903
# At iteration 7 the best fitness is 0.023841603680578378
# At iteration 8 the best fitness is 0.023841603680578378
# At iteration 9 the best fitness is 0.023841603680578378
# At iteration 10 the best fitness is 0.023841603680578378
# At iteration 11 the best fitness is 0.02380874137364443
# At iteration 12 the best fitness is 0.023578705225106803
# At iteration 13 the best fitness is 0.023578705225106803
# At iteration 14 the best fitness is 0.02351298061123891
# At iteration 15 the best fitness is 0.02351298061123891
# At iteration 16 the best fitness is 0.02351298061123891
# At iteration 17 the best fitness is 0.023463687150837992
# At iteration 18 the best fitness is 0.023463687150837992
# At iteration 19 the best fitness is 0.023463687150837992
# At iteration 20 the best fitness is 0.023463687150837992
# At iteration 21 the best fitness is 0.023430824843904043
# At iteration 22 the best fitness is 0.023430824843904043
# At iteration 23 the best fitness is 0.02341439369043707
# At iteration 24 the best fitness is 0.023348669076569177
# At iteration 25 the best fitness is 0.023332237923102205
# At iteration 26 the best fitness is 0.023332237923102205
# At iteration 27 the best fitness is 0.023332237923102205
# At iteration 28 the best fitness is 0.02331580676963523
# At iteration 29 the best fitness is 0.02331580676963523
# At iteration 30 the best fitness is 0.023299375616168256
#       Selected: 1418/3043 (46.6%), Fitness: 0.0233, Time: 2437.2s
#       Modality: D=45%, S=45%, Sk=47%,
#     Test Acc: 92.12%, F1: 92.21%, Features: 1418/3043 (46.6%), Model: 3.306MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02375944791324351']
# ['At iteration 1 the best fitness is 0.02292145908642787']
# ['At iteration 2 the best fitness is 0.02170555372987184']
# ['At iteration 3 the best fitness is 0.020900427209990143']
# ['At iteration 4 the best fitness is 0.019651659546500166']
# ['At iteration 5 the best fitness is 0.019010844561288206']
# ['At iteration 6 the best fitness is 0.017893526125534014']
# ['At iteration 7 the best fitness is 0.016825501150180746']
# ['At iteration 8 the best fitness is 0.016233979625369703']
# ['At iteration 9 the best fitness is 0.015379559645087085']
# ['At iteration 10 the best fitness is 0.014919487348011832']
# ['At iteration 11 the best fitness is 0.01427867236279987']
# ['At iteration 12 the best fitness is 0.014196516595465003']
# ['At iteration 13 the best fitness is 0.013522839303319094']
# ['At iteration 14 the best fitness is 0.01335852776864936']
# ['At iteration 15 the best fitness is 0.012997042392375946']
# ['At iteration 16 the best fitness is 0.01253697009530069']
# ['At iteration 17 the best fitness is 0.01238908971409793']
# ['At iteration 18 the best fitness is 0.012356227407163984']
# ['At iteration 19 the best fitness is 0.012159053565560303']
# ['At iteration 20 the best fitness is 0.012027604337824516']
# ['At iteration 21 the best fitness is 0.011929017417022675']
# ['At iteration 22 the best fitness is 0.011846861649687809']
# ['At iteration 23 the best fitness is 0.011600394347683209']
# ['At iteration 24 the best fitness is 0.011583963194216236']
# ['At iteration 25 the best fitness is 0.011583963194216236']
# ['At iteration 26 the best fitness is 0.011583963194216236']
# ['At iteration 27 the best fitness is 0.011583963194216236']
# ['At iteration 28 the best fitness is 0.011583963194216236']
# ['At iteration 29 the best fitness is 0.011583963194216236']
#       Selected: 705/3043 (23.2%), Fitness: 0.0116, Time: 2340.5s
#       Modality: D=23%, S=24%, Sk=23%,
#     Test Acc: 87.97%, F1: 87.19%, Features: 705/3043 (23.2%), Model: 1.913MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.024465987512323366']
# ['At iteration 1 the best fitness is 0.010811698981268485']
# ['At iteration 2 the best fitness is 0.010811698981268485']
# ['At iteration 3 the best fitness is 0.010170883996056524']
# ['At iteration 4 the best fitness is 0.006457443312520539']
# ['At iteration 5 the best fitness is 0.006457443312520539']
# ['At iteration 6 the best fitness is 0.006457443312520539']
# ['At iteration 7 the best fitness is 0.006457443312520539']
# ['At iteration 8 the best fitness is 0.006457443312520539']
# ['At iteration 9 the best fitness is 0.006457443312520539']
# ['At iteration 10 the best fitness is 0.006457443312520539']
# ['At iteration 11 the best fitness is 0.006457443312520539']
# ['At iteration 12 the best fitness is 0.006457443312520539']
# ['At iteration 13 the best fitness is 0.006457443312520539']
# ['At iteration 14 the best fitness is 0.005948077555044364']
# ['At iteration 15 the best fitness is 0.005948077555044364']
# ['At iteration 16 the best fitness is 0.005948077555044364']
# ['At iteration 17 the best fitness is 0.005948077555044364']
# ['At iteration 18 the best fitness is 0.005948077555044364']
# ['At iteration 19 the best fitness is 0.005948077555044364']
# ['At iteration 20 the best fitness is 0.005948077555044364']
# ['At iteration 21 the best fitness is 0.005931646401577392']
# ['At iteration 22 the best fitness is 0.0058823529411764705']
# ['At iteration 23 the best fitness is 0.0058823529411764705']
# ['At iteration 24 the best fitness is 0.005783766020374631']
# ['At iteration 25 the best fitness is 0.005783766020374631']
# ['At iteration 26 the best fitness is 0.0056523167926388436']
# ['At iteration 27 the best fitness is 0.005603023332237923']
# ['At iteration 28 the best fitness is 0.005603023332237923']
# ['At iteration 29 the best fitness is 0.005603023332237923']
#       Selected: 341/3043 (11.2%), Fitness: 0.0056, Time: 3345.1s
#       Modality: D=10%, S=11%, Sk=12%,
#     Test Acc: 91.29%, F1: 91.28%, Features: 341/3043 (11.2%), Model: 1.202MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02375944791324351']
# ['At iteration 1 the best fitness is 0.02375944791324351']
# ['At iteration 2 the best fitness is 0.02375944791324351']
# ['At iteration 3 the best fitness is 0.02375944791324351']
# ['At iteration 4 the best fitness is 0.023660860992441673']
# ['At iteration 5 the best fitness is 0.023660860992441673']
# ['At iteration 6 the best fitness is 0.023660860992441673']
# ['At iteration 7 the best fitness is 0.02351298061123891']
# ['At iteration 8 the best fitness is 0.02351298061123891']
# ['At iteration 9 the best fitness is 0.02351298061123891']
# ['At iteration 10 the best fitness is 0.02351298061123891']
# ['At iteration 11 the best fitness is 0.02351298061123891']
# ['At iteration 12 the best fitness is 0.023381531383503122']
# ['At iteration 13 the best fitness is 0.023167926388432472']
# ['At iteration 14 the best fitness is 0.02298718370029576']
# ['At iteration 15 the best fitness is 0.02292145908642787']
# ['At iteration 16 the best fitness is 0.02292145908642787']
# ['At iteration 17 the best fitness is 0.02292145908642787']
# ['At iteration 18 the best fitness is 0.02292145908642787']
# ['At iteration 19 the best fitness is 0.02292145908642787']
# ['At iteration 20 the best fitness is 0.02292145908642787']
# ['At iteration 21 the best fitness is 0.02292145908642787']
# ['At iteration 22 the best fitness is 0.022855734472559976']
# ['At iteration 23 the best fitness is 0.022839303319093004']
# ['At iteration 24 the best fitness is 0.022839303319093004']
# ['At iteration 25 the best fitness is 0.022839303319093004']
# ['At iteration 26 the best fitness is 0.022806441012159055']
# ['At iteration 27 the best fitness is 0.022806441012159055']
# ['At iteration 28 the best fitness is 0.022806441012159055']
# ['At iteration 29 the best fitness is 0.022806441012159055']
#       Selected: 1388/3043 (45.6%), Fitness: 0.0228, Time: 2249.9s
#       Modality: D=41%, S=49%, Sk=46%,
#     Test Acc: 93.36%, F1: 93.43%, Features: 1388/3043 (45.6%), Model: 3.247MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024367400591521524']
# ['At iteration 2 the best fitness is 0.02435096943805455']
# ['At iteration 3 the best fitness is 0.02435096943805455']
# ['At iteration 4 the best fitness is 0.02435096943805455']
# ['At iteration 5 the best fitness is 0.02433453828458758']
# ['At iteration 6 the best fitness is 0.02420308905685179']
# ['At iteration 7 the best fitness is 0.02420308905685179']
# ['At iteration 8 the best fitness is 0.02420308905685179']
# ['At iteration 9 the best fitness is 0.02420308905685179']
# ['At iteration 10 the best fitness is 0.02420308905685179']
# ['At iteration 11 the best fitness is 0.02420308905685179']
# ['At iteration 12 the best fitness is 0.02420308905685179']
# ['At iteration 13 the best fitness is 0.02420308905685179']
# ['At iteration 14 the best fitness is 0.023841603680578378']
# ['At iteration 15 the best fitness is 0.023841603680578378']
# ['At iteration 16 the best fitness is 0.023841603680578378']
# ['At iteration 17 the best fitness is 0.023841603680578378']
# ['At iteration 18 the best fitness is 0.023841603680578378']
# ['At iteration 19 the best fitness is 0.023578705225106803']
# ['At iteration 20 the best fitness is 0.023578705225106803']
# ['At iteration 21 the best fitness is 0.023578705225106803']
# ['At iteration 22 the best fitness is 0.023348669076569177']
# ['At iteration 23 the best fitness is 0.023348669076569177']
# ['At iteration 24 the best fitness is 0.023250082155767335']
# ['At iteration 25 the best fitness is 0.02321721984883339']
# ['At iteration 26 the best fitness is 0.02321721984883339']
# ['At iteration 27 the best fitness is 0.023102201774564575']
# ['At iteration 28 the best fitness is 0.023102201774564575']
# ['At iteration 29 the best fitness is 0.023102201774564575']
#       Selected: 1406/3043 (46.2%), Fitness: 0.0231, Time: 2019.4s
#       Modality: D=44%, S=48%, Sk=46%,
#     Test Acc: 93.78%, F1: 93.84%, Features: 1406/3043 (46.2%), Model: 3.282MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0243838317449885']
# ['At iteration 2 the best fitness is 0.024252382517252712']
# ['At iteration 3 the best fitness is 0.024137364442983898']
# ['At iteration 4 the best fitness is 0.024022346368715086']
# ['At iteration 5 the best fitness is 0.02374301675977654']
# ['At iteration 6 the best fitness is 0.023726585606309566']
# ...
# ['At iteration 14 the best fitness is 0.06195792533847497']
# ['At iteration 15 the best fitness is 0.06195792533847497']
# ['At iteration 16 the best fitness is 0.06195792533847497']
# ['At iteration 17 the best fitness is 0.06195792533847497']
# ['At iteration 18 the best fitness is 0.06195792533847497']
# ['At iteration 19 the best fitness is 0.06195792533847497']
# ['At iteration 20 the best fitness is 0.06195792533847497']
# ['At iteration 21 the best fitness is 0.06195792533847497']
# ['At iteration 22 the best fitness is 0.06195792533847497']
# ['At iteration 23 the best fitness is 0.06195792533847497']
# ['At iteration 24 the best fitness is 0.06195792533847497']
# ['At iteration 25 the best fitness is 0.06195792533847497']
# ['At iteration 26 the best fitness is 0.06195792533847497']
# ['At iteration 27 the best fitness is 0.06195792533847497']
# ['At iteration 28 the best fitness is 0.06195792533847497']
# ['At iteration 29 the best fitness is 0.06195792533847497']
#       Selected: 652/3043 (21.4%), Fitness: 0.0620, Time: 3308.5s
#       Modality: D=21%, S=22%, Sk=21%,
#     Test Acc: 97.98%, F1: 97.93%, Features: 652/3043 (21.4%), Model: 1.810MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08277306054436889']
# ['At iteration 1 the best fitness is 0.08259231785623218']
# ['At iteration 2 the best fitness is 0.08259231785623218']
# ['At iteration 3 the best fitness is 0.08259231785623218']
# ['At iteration 4 the best fitness is 0.08231298824729363']
# ['At iteration 5 the best fitness is 0.08223083247995877']
# ['At iteration 6 the best fitness is 0.08223083247995877']
# ['At iteration 7 the best fitness is 0.07773026454838874']
# ['At iteration 8 the best fitness is 0.07773026454838874']
# ['At iteration 9 the best fitness is 0.07773026454838874']
# ['At iteration 10 the best fitness is 0.07773026454838874']
# ['At iteration 11 the best fitness is 0.07773026454838874']
# ['At iteration 12 the best fitness is 0.07773026454838874']
# ['At iteration 13 the best fitness is 0.07773026454838874']
# ['At iteration 14 the best fitness is 0.07773026454838874']
# ['At iteration 15 the best fitness is 0.07773026454838874']
# ['At iteration 16 the best fitness is 0.07773026454838874']
# ['At iteration 17 the best fitness is 0.07773026454838874']
# ['At iteration 18 the best fitness is 0.07773026454838874']
# ['At iteration 19 the best fitness is 0.07773026454838874']
# ['At iteration 20 the best fitness is 0.07773026454838874']
# ['At iteration 21 the best fitness is 0.07773026454838874']
# ['At iteration 22 the best fitness is 0.07773026454838874']
# ['At iteration 23 the best fitness is 0.07773026454838874']
# ['At iteration 24 the best fitness is 0.07773026454838874']
# ['At iteration 25 the best fitness is 0.07751665955331809']
# ['At iteration 26 the best fitness is 0.07751665955331809']
# ['At iteration 27 the best fitness is 0.07751665955331809']
# ['At iteration 28 the best fitness is 0.07740164147904927']
# ['At iteration 29 the best fitness is 0.07740164147904927']
#       Selected: 1352/3043 (44.4%), Fitness: 0.0774, Time: 2375.0s
#       Modality: D=47%, S=44%, Sk=44%,
#     Test Acc: 99.49%, F1: 99.49%, Features: 1352/3043 (44.4%), Model: 3.177MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08456405627226898']
# ['At iteration 2 the best fitness is 0.08398896590092492']
# ['At iteration 3 the best fitness is 0.08382465436625518']
# ['At iteration 4 the best fitness is 0.08382465436625518']
# ['At iteration 5 the best fitness is 0.08052356063777422']
# ['At iteration 6 the best fitness is 0.07672953230528404']
# ['At iteration 7 the best fitness is 0.07672953230528404']
# ['At iteration 8 the best fitness is 0.07672953230528404']
# ['At iteration 9 the best fitness is 0.07672953230528404']
# ['At iteration 10 the best fitness is 0.07672953230528404']
# ['At iteration 11 the best fitness is 0.07672953230528404']
# ['At iteration 12 the best fitness is 0.07672953230528404']
# ['At iteration 13 the best fitness is 0.07672953230528404']
# ['At iteration 14 the best fitness is 0.07672953230528404']
# ['At iteration 15 the best fitness is 0.07672953230528404']
# ['At iteration 16 the best fitness is 0.07672953230528404']
# ['At iteration 17 the best fitness is 0.07672953230528404']
# ['At iteration 18 the best fitness is 0.07672953230528404']
# ['At iteration 19 the best fitness is 0.07672953230528404']
# ['At iteration 20 the best fitness is 0.07672953230528404']
# ['At iteration 21 the best fitness is 0.07672953230528404']
# ['At iteration 22 the best fitness is 0.07672953230528404']
# ['At iteration 23 the best fitness is 0.07672953230528404']
# ['At iteration 24 the best fitness is 0.07672953230528404']
# ['At iteration 25 the best fitness is 0.07672953230528404']
# ['At iteration 26 the best fitness is 0.07672953230528404']
# ['At iteration 27 the best fitness is 0.07672953230528404']
# ['At iteration 28 the best fitness is 0.07672953230528404']
# ['At iteration 29 the best fitness is 0.07672953230528404']
#       Selected: 1551/3043 (51.0%), Fitness: 0.0767, Time: 2172.8s
#       Modality: D=51%, S=51%, Sk=51%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 1551/3043 (51.0%), Model: 3.566MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08413684628212768']
# ['At iteration 2 the best fitness is 0.0804742671773733']
# ['At iteration 3 the best fitness is 0.08021136872190172']
# ['At iteration 4 the best fitness is 0.0799813325733641']
# ['At iteration 5 the best fitness is 0.0799813325733641']
# ['At iteration 6 the best fitness is 0.07953769142975581']
# ['At iteration 7 the best fitness is 0.0755793515625959']
# ['At iteration 8 the best fitness is 0.0755793515625959']
# ['At iteration 9 the best fitness is 0.0755793515625959']
# ['At iteration 10 the best fitness is 0.0755793515625959']
# ['At iteration 11 the best fitness is 0.0755793515625959']
# ['At iteration 12 the best fitness is 0.0755793515625959']
# ['At iteration 13 the best fitness is 0.0755793515625959']
# ['At iteration 14 the best fitness is 0.0755793515625959']
# ['At iteration 15 the best fitness is 0.0755793515625959']
# ['At iteration 16 the best fitness is 0.0755793515625959']
# ['At iteration 17 the best fitness is 0.0755793515625959']
# ['At iteration 18 the best fitness is 0.0755793515625959']
# ['At iteration 19 the best fitness is 0.0755793515625959']
# ['At iteration 20 the best fitness is 0.0755793515625959']
# ['At iteration 21 the best fitness is 0.0755793515625959']
# ['At iteration 22 the best fitness is 0.0755793515625959']
# ['At iteration 23 the best fitness is 0.07554648925566196']
# ['At iteration 24 the best fitness is 0.07554648925566196']
# ['At iteration 25 the best fitness is 0.07554648925566196']
# ['At iteration 26 the best fitness is 0.07554648925566196']
# ['At iteration 27 the best fitness is 0.07554648925566196']
# ['At iteration 28 the best fitness is 0.07554648925566196']
# ['At iteration 29 the best fitness is 0.07554648925566196']
# ['At iteration 30 the best fitness is 0.07549719579526104']
#       Selected: 1476/3043 (48.5%), Fitness: 0.0755, Time: 2550.5s
#       Modality: D=53%, S=51%, Sk=46%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 1476/3043 (48.5%), Model: 3.419MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08423543320292952']
# ['At iteration 2 the best fitness is 0.08402182820785886']
# ['At iteration 3 the best fitness is 0.08001419488029804']
# ['At iteration 4 the best fitness is 0.08001419488029804']
# ['At iteration 5 the best fitness is 0.07968557181095857']
# ['At iteration 6 the best fitness is 0.07932408643468515']
# ['At iteration 7 the best fitness is 0.07927479297428423']
# ['At iteration 8 the best fitness is 0.07927479297428423']
# ['At iteration 9 the best fitness is 0.0752178661863225']
# ['At iteration 10 the best fitness is 0.0752178661863225']
# ['At iteration 11 the best fitness is 0.0752178661863225']
# ['At iteration 12 the best fitness is 0.0752178661863225']
# ['At iteration 13 the best fitness is 0.0752178661863225']
# ['At iteration 14 the best fitness is 0.0752178661863225']
# ['At iteration 15 the best fitness is 0.0752178661863225']
# ['At iteration 16 the best fitness is 0.0752178661863225']
# ['At iteration 17 the best fitness is 0.0752178661863225']
# ['At iteration 18 the best fitness is 0.0752178661863225']
# ['At iteration 19 the best fitness is 0.0752178661863225']
# ['At iteration 20 the best fitness is 0.0752178661863225']
# ['At iteration 21 the best fitness is 0.0752178661863225']
# ['At iteration 22 the best fitness is 0.0752178661863225']
# ['At iteration 23 the best fitness is 0.0752178661863225']
# ['At iteration 24 the best fitness is 0.0752178661863225']
# ['At iteration 25 the best fitness is 0.07520143503285552']
# ['At iteration 26 the best fitness is 0.07520143503285552']
# ['At iteration 27 the best fitness is 0.07520143503285552']
# ['At iteration 28 the best fitness is 0.07520143503285552']
# ['At iteration 29 the best fitness is 0.07520143503285552']
# ['At iteration 30 the best fitness is 0.07520143503285552']
#       Selected: 1458/3043 (47.9%), Fitness: 0.0752, Time: 2490.2s
#       Modality: D=44%, S=50%, Sk=48%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 1458/3043 (47.9%), Model: 3.384MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08269090477703402']
# ['At iteration 1 the best fitness is 0.07887887717269619']
# ['At iteration 2 the best fitness is 0.07887887717269619']
# ['At iteration 3 the best fitness is 0.07794230142507871']
# ['At iteration 4 the best fitness is 0.07445889689008035']
# ['At iteration 5 the best fitness is 0.07199422387003435']
# ['At iteration 6 the best fitness is 0.0700404847258452']
# ['At iteration 7 the best fitness is 0.06642563096311105']
# ['At iteration 8 the best fitness is 0.06642563096311105']
# ['At iteration 9 the best fitness is 0.06532474368082383']
# ['At iteration 10 the best fitness is 0.06532474368082383']
# ['At iteration 11 the best fitness is 0.06056127729378223']
# ['At iteration 12 the best fitness is 0.06056127729378223']
# ['At iteration 13 the best fitness is 0.0601504984571079']
# ['At iteration 14 the best fitness is 0.05972328846696659']
# ['At iteration 15 the best fitness is 0.0596575638530987']
# ['At iteration 16 the best fitness is 0.05566636167900484']
# ['At iteration 17 the best fitness is 0.05566636167900484']
# ['At iteration 18 the best fitness is 0.05566636167900484']
# ['At iteration 19 the best fitness is 0.05566636167900484']
# ['At iteration 20 the best fitness is 0.05566636167900484']
# ['At iteration 21 the best fitness is 0.05566636167900484']
# ['At iteration 22 the best fitness is 0.05566636167900484']
# ['At iteration 23 the best fitness is 0.05566636167900484']
# ['At iteration 24 the best fitness is 0.05566636167900484']
# ['At iteration 25 the best fitness is 0.05495982207992499']
# ['At iteration 26 the best fitness is 0.05495982207992499']
# ['At iteration 27 the best fitness is 0.05495982207992499']
# ['At iteration 28 the best fitness is 0.05495982207992499']
# ['At iteration 29 the best fitness is 0.054779079391788284']
#       Selected: 455/3043 (15.0%), Fitness: 0.0548, Time: 2314.8s
#       Modality: D=16%, S=18%, Sk=14%,
#     Test Acc: 97.98%, F1: 97.97%, Features: 455/3043 (15.0%), Model: 1.425MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08323313284144414']
# ['At iteration 2 the best fitness is 0.08323313284144414']
# ['At iteration 3 the best fitness is 0.08026066218230264']
# ['At iteration 4 the best fitness is 0.08026066218230264']
# ['At iteration 5 the best fitness is 0.08026066218230264']
# ['At iteration 6 the best fitness is 0.08026066218230264']
# ['At iteration 7 the best fitness is 0.08026066218230264']
# ['At iteration 8 the best fitness is 0.08026066218230264']
# ['At iteration 9 the best fitness is 0.08026066218230264']
# ['At iteration 10 the best fitness is 0.08026066218230264']
# ['At iteration 11 the best fitness is 0.08026066218230264']
# ['At iteration 12 the best fitness is 0.07971843411789252']
# ['At iteration 13 the best fitness is 0.07958698489015673']
# ['At iteration 14 the best fitness is 0.07948839796935489']
# ['At iteration 15 the best fitness is 0.079422673355487']
# ['At iteration 16 the best fitness is 0.079422673355487']
# ['At iteration 17 the best fitness is 0.07924193066735029']
# ['At iteration 18 the best fitness is 0.07924193066735029']
# ['At iteration 19 the best fitness is 0.07924193066735029']
# ['At iteration 20 the best fitness is 0.07924193066735029']
# ['At iteration 21 the best fitness is 0.07924193066735029']
# ['At iteration 22 the best fitness is 0.07924193066735029']
# ['At iteration 23 the best fitness is 0.07924193066735029']
# ['At iteration 24 the best fitness is 0.07924193066735029']
# ['At iteration 25 the best fitness is 0.07924193066735029']
# ['At iteration 26 the best fitness is 0.07924193066735029']
# ['At iteration 27 the best fitness is 0.07530002195365736']
# ['At iteration 28 the best fitness is 0.07530002195365736']
# ['At iteration 29 the best fitness is 0.07530002195365736']
#       Selected: 1464/3043 (48.1%), Fitness: 0.0753, Time: 5442.3s
#       Modality: D=50%, S=49%, Sk=47%,
#     Test Acc: 96.46%, F1: 95.83%, Features: 1464/3043 (48.1%), Model: 3.396MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08361104937118453']
# ['At iteration 1 the best fitness is 0.0699238985331957']
# ['At iteration 2 the best fitness is 0.06790286665675797']
# ['At iteration 3 the best fitness is 0.06790286665675797']
# ['At iteration 4 the best fitness is 0.06535760598775778']
# ['At iteration 5 the best fitness is 0.061415697274064845']
# ['At iteration 6 the best fitness is 0.061415697274064845']
# ['At iteration 7 the best fitness is 0.061415697274064845']
# ['At iteration 8 the best fitness is 0.061415697274064845']
# ['At iteration 9 the best fitness is 0.061415697274064845']
# ['At iteration 10 the best fitness is 0.061415697274064845']
# ['At iteration 11 the best fitness is 0.061415697274064845']
# ['At iteration 12 the best fitness is 0.061415697274064845']
# ['At iteration 13 the best fitness is 0.061415697274064845']
# ['At iteration 14 the best fitness is 0.061415697274064845']
# ['At iteration 15 the best fitness is 0.061415697274064845']
# ['At iteration 16 the best fitness is 0.061415697274064845']
# ['At iteration 17 the best fitness is 0.061415697274064845']
# ['At iteration 18 the best fitness is 0.061415697274064845']
# ['At iteration 19 the best fitness is 0.061415697274064845']
# ['At iteration 20 the best fitness is 0.061415697274064845']
# ['At iteration 21 the best fitness is 0.061415697274064845']
# ['At iteration 22 the best fitness is 0.061415697274064845']
# ['At iteration 23 the best fitness is 0.061415697274064845']
# ['At iteration 24 the best fitness is 0.061415697274064845']
# ['At iteration 25 the best fitness is 0.061415697274064845']
# ['At iteration 26 the best fitness is 0.061415697274064845']
# ['At iteration 27 the best fitness is 0.061415697274064845']
# ['At iteration 28 the best fitness is 0.061415697274064845']
# ['At iteration 29 the best fitness is 0.061415697274064845']
#       Selected: 619/3043 (20.3%), Fitness: 0.0614, Time: 2107.4s
#       Modality: D=21%, S=19%, Sk=20%,
#     Test Acc: 97.98%, F1: 97.89%, Features: 619/3043 (20.3%), Model: 1.745MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879}, Total: 3043
# Results table: (90, 32)
# Methods: 18, Folds per method: {'baseline': 5, 'lasso': 5, 'meta_BAT': 5, 'meta_CS': 5, 'meta_DE': 5, 'meta_FFA': 5, 'meta_GA': 5, 'meta_GWO': 5, 'meta_HHO': 5, 'meta_JAYA': 5, 'meta_MFO': 5, 'meta_MVO': 5, 'meta_PSO': 5, 'meta_SCA': 5, 'meta_SSA': 5, 'meta_WOA': 5, 'mutual_info': 5, 'rfe': 5}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          97.202797         99.494949     97.171348
# 1  baseline     2          93.360996        100.000000     93.470962
# 2  baseline     3          98.636364        100.000000     98.604976
# 3  baseline     4          92.727273        100.000000     92.241265
# 4  baseline     5          98.989899         94.190871     98.986772
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        97.171348            97.753533         97.202797               3043
# 1        93.465710            94.759585         93.347107               3043
# 2        98.604976            98.951049         98.636364               3043
# 3        92.241265            94.724026         92.727273               3043
# 4        98.986772            99.090909         98.989899               3043
#
#    Features Total  ...  N Test  depth_retained  depth_total  \
# 0            3043  ...     286             512          512
# 1            3043  ...     241             512          512
# 2            3043  ...     220             512          512
# 3            3043  ...     220             512          512
# 4            3043  ...     198             512          512
#
#    depth_retention_%  sensor_retained  sensor_total  sensor_retention_%  \
# 0              100.0              652           652               100.0
# 1              100.0              652           652               100.0
# 2              100.0              652           652               100.0
# 3              100.0              652           652               100.0
# 4              100.0              652           652               100.0
#
#    skeleton_retained  skeleton_total  skeleton_retention_%
# 0               1879            1879                 100.0
# 1               1879            1879                 100.0
# 2               1879            1879                 100.0
# 3               1879            1879                 100.0
# 4               1879            1879                 100.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              96.18              2.95              96.10              3.06                  3043.0                      100.00              0.00                39.00                39.00          1697046.0                  6.48                        0.00               56.48
# mutual_info              94.75              3.73              94.13              4.50                  1521.0                       49.98             42.89                35.33                78.22           917782.0                  3.51                       50.02               38.46
#         rfe              94.83              3.12              94.60              3.12                  1521.0                       49.98              9.44                35.25                44.69           917782.0                  3.51                       50.02               38.46
#       lasso              96.42              3.44              96.43              3.36                  1521.0                       49.98            268.15                35.21               303.36           917782.0                  3.51                       50.02               38.46
#    meta_BAT              96.76              3.23              96.67              3.34                  1442.2                       47.39           2220.61                35.05              2255.66           877436.4                  3.35                       52.61               38.14
#     meta_CS              96.98              3.15              96.98              3.13                  1445.8                       47.51           4392.76                36.83              4429.60           879279.6                  3.36                       52.49               38.15
#     meta_DE              97.06              2.70              97.07              2.68                  1367.4                       44.94           2350.84                38.03              2388.87           839138.8                  3.21                       55.06               37.84
#    meta_FFA              95.49              3.97              95.21              4.35                  1423.6                       46.78           2306.52                37.52              2344.04           867913.2                  3.32                       53.22               38.06
#     meta_GA              95.39              3.33              95.18              3.54                  1404.4                       46.15           2279.55                37.17              2316.73           858082.8                  3.28                       53.85               37.99
#    meta_GWO              95.49              4.63              95.29              4.94                   848.6                       27.89           2194.26                35.13              2229.39           573513.2                  2.19                       72.11               30.83
#    meta_HHO              94.70              2.72              94.51              2.81                   352.8                       11.59           3175.63                39.52              3215.16           297769.0                  1.14                       88.41               24.30
#   meta_JAYA              97.22              2.72              97.22              2.71                  1390.8                       45.70           2342.60                37.56              2380.16           851119.6                  3.25                       54.30               37.93
#    meta_MFO              96.75              3.48              96.67              3.61                  1441.2                       47.36           2072.40                32.51              2104.91           876924.4                  3.35                       52.64               38.18
#    meta_MVO              96.58              3.67              96.46              3.85                  1406.6                       46.22           2230.67                36.97              2267.65           859209.2                  3.28                       53.78               37.99
#    meta_PSO              95.90              2.75              95.78              2.80                  1359.4                       44.67           2327.27                37.38              2364.65           835042.8                  3.19                       55.33               37.80
#    meta_SCA              95.22              3.64              95.04              3.98                   325.8                       10.71           2317.03                39.21              2356.25           297379.6                  1.14                       89.29               24.12
#    meta_SSA              95.29              3.40              94.96              3.71                  1405.4                       46.18           5473.17                35.01              5508.19           858594.8                  3.28                       53.82               37.99
#    meta_WOA              95.82              1.55              95.76              1.58                   318.8                       10.48           2182.60                37.40              2220.00           275270.0                  1.06                       89.52               23.61

# %% [markdown]
# ## Comprehensive Visualizations

# %%
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

fig, axes = plt.subplots(2, 1, figsize=(18, 10))

axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})

start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")


df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")


print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_MVO
#     F1 Macro:           98.60%
#     F1 Weighted:        98.60%
#     Test Accuracy:      98.60%
#     Feature Retention:  48.70% (1482/3043)
#     Modality Retention: depth=49.8%, sensor=50.2%, skeleton=47.9%
#
#   Fold 2: Best = meta_WOA
#     F1 Macro:           94.62%
#     F1 Weighted:        94.61%
#     Test Accuracy:      94.61%
#     Feature Retention:  10.09% (307/3043)
#     Modality Retention: depth=10.0%, sensor=9.4%, skeleton=10.4%
#
#   Fold 3: Best = meta_CS
#     F1 Macro:           99.54%
#     F1 Weighted:        99.54%
#     Test Accuracy:      99.55%
#     Feature Retention:  46.99% (1430/3043)
#     Modality Retention: depth=46.9%, sensor=46.2%, skeleton=47.3%
#
#   Fold 4: Best = meta_DE
#     F1 Macro:           96.79%
#     F1 Weighted:        96.79%
#     Test Accuracy:      96.82%
#     Feature Retention:  43.05% (1310/3043)
#     Modality Retention: depth=38.7%, sensor=44.8%, skeleton=43.6%
#
#   Fold 5: Best = meta_BAT
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  48.11% (1464/3043)
#     Modality Retention: depth=49.4%, sensor=49.1%, skeleton=47.4%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 97.91% ± 2.21%
#
#   Average F1 Weighted         : 97.91% ± 2.22%
#
#   Average Test Accuracy       : 97.91% ± 2.22%
#
#   Average Feature Retention   : 39.39% ± 16.53%
#
#   Average Modality-wise Feature Retention:
#            depth: 38.95% ± 16.81%
#           sensor: 39.91% ± 17.22%
#         skeleton: 39.33% ± 16.27%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%
#     1           meta_MVO         98.60            98.60              98.60                  48.70              49.80               50.15                 47.90
#     2           meta_WOA         94.62            94.61              94.61                  10.09               9.96                9.36                 10.38
#     3            meta_CS         99.54            99.54              99.55                  46.99              46.88               46.17                 47.31
#     4            meta_DE         96.79            96.79              96.82                  43.05              38.67               44.79                 43.64
#     5           meta_BAT        100.00           100.00             100.00                  48.11              49.41               49.08                 47.42
#
# Saved to: results\best_metaheuristic_per_fold.csv

# %%
import pandas as pd

csv_path = RESULTS_ROOT / "all_folds_results.csv"
df_all = pd.read_csv(csv_path)

print(df_all.shape)
print(df_all.head(20).to_string())
# Out:
# (90, 32)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Orig Dataset (MB)  Opt Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  N Train  N Val  N Test  depth_retained  depth_total  depth_retention_%  sensor_retained  sensor_total  sensor_retention_%  skeleton_retained  skeleton_total  skeleton_retention_%
# 0      baseline     1          97.202797         99.494949     97.171348        97.171348            97.753533         97.202797               3043            3043             100.000000     0.000000       38.695834       38.695896       1697046         6.479591          27.046928         27.046928               0.000000      56.484375      681    198     286             512          512         100.000000              652           652          100.000000               1879            1879            100.000000
# 1      baseline     2          93.360996        100.000000     93.470962        93.465710            94.759585         93.347107               3043            3043             100.000000     0.000000       37.671922       37.671970       1697046         6.479591          27.046928         27.046928               0.000000      56.484375      726    198     241             512          512         100.000000              652           652          100.000000               1879            1879            100.000000
# 2      baseline     3          98.636364        100.000000     98.604976        98.604976            98.951049         98.636364               3043            3043             100.000000     0.000000       40.072634       40.072680       1697046         6.479591          27.046928         27.046928               0.000000      56.484375      747    198     220             512          512         100.000000              652           652          100.000000               1879            1879            100.000000
# 3      baseline     4          92.727273        100.000000     92.241265        92.241265            94.724026         92.727273               3043            3043             100.000000     0.000000       39.910861       39.910898       1697046         6.479591          27.046928         27.046928               0.000000      56.484375      747    198     220             512          512         100.000000              652           652          100.000000               1879            1879            100.000000
# 4      baseline     5          98.989899         94.190871     98.986772        98.986772            99.090909         98.989899               3043            3043             100.000000     0.000000       38.660383       38.660451       1697046         6.479591          27.046928         27.046928               0.000000      56.484375      726    241     198             512          512         100.000000              652           652          100.000000               1879            1879            100.000000
# 5   mutual_info     1          97.202797        100.000000     97.201651        97.201651            97.753533         97.202797               1521            3043              49.983569    40.128983       34.056680       74.186461        917782         3.506935          27.046928         13.519020              50.016431      38.464844      681    198     286               7          512           1.367188              394           652           60.429448               1120            1879             59.606173
# 6   mutual_info     2          93.360996        100.000000     93.766761        93.762736            95.586610         93.347107               1521            3043              49.983569    44.648219       34.327031       78.976454        917782         3.506935          27.046928         13.519020              50.016431      38.464844      726    198     241              13          512           2.539062              346           652           53.067485               1162            1879             61.841405
# 7   mutual_info     3          91.363636        100.000000     89.547367        89.547367            90.428322         91.363636               1521            3043              49.983569    44.236936       36.446905       80.684259        917782         3.506935          27.046928         13.519020              50.016431      38.464844      747    198     220              11          512           2.148438              374           652           57.361963               1136            1879             60.457690
# 8   mutual_info     4          91.818182        100.000000     90.149237        90.149237            90.385675         91.818182               1521            3043              49.983569    42.762521       37.122238       79.885335        917782         3.506935          27.046928         13.519020              50.016431      38.464844      747    198     220              12          512           2.343750              353           652           54.141104               1156            1879             61.522086
# 9   mutual_info     5         100.000000         93.775934    100.000000       100.000000           100.000000        100.000000               1521            3043              49.983569    42.692568       34.673123       77.373699        917782         3.506935          27.046928         13.519020              50.016431      38.464844      726    241     198              13          512           2.539062              346           652           53.067485               1162            1879             61.841405
# 10          rfe     1          93.356643         99.494949     93.508777        93.508777            94.725483         93.356643               1521            3043              49.983569     9.031615       34.009645       43.041676        917782         3.506935          27.046928         13.519020              50.016431      38.464844      681    198     286               0          512           0.000000              435           652           66.717791               1086            1879             57.796700
# 11          rfe     2          91.701245        100.000000     92.126558        92.135381            93.972921         91.694215               1521            3043              49.983569     9.542273       34.360485       43.903298        917782         3.506935          27.046928         13.519020              50.016431      38.464844      726    198     241               0          512           0.000000              311           652           47.699387               1210            1879             64.395955
# 12          rfe     3          94.545455        100.000000     93.021120        93.021120            92.424242         94.545455               1521            3043              49.983569     9.490447       35.912451       45.403865        917782         3.506935          27.046928         13.519020              50.016431      38.464844      747    198     220               0          512           0.000000              421           652           64.570552               1100            1879             58.541778
# 13          rfe     4          94.545455        100.000000     94.357080        94.357080            95.629371         94.545455               1521            3043              49.983569     9.716074       35.727305       45.444691        917782         3.506935          27.046928         13.519020              50.016431      38.464844      747    198     220               1          512           0.195312              397           652           60.889571               1123            1879             59.765833
# 14          rfe     5         100.000000         92.946058    100.000000       100.000000           100.000000        100.000000               1521            3043              49.983569     9.417130       36.254091       45.671762        917782         3.506935          27.046928         13.519020              50.016431      38.464844      726    241     198               0          512           0.000000              311           652           47.699387               1210            1879             64.395955
# 15        lasso     1          98.251748         97.979798     98.236558        98.236558            98.498377         98.251748               1521            3043              49.983569   242.718735       34.294116      277.013321        917782         3.506935          27.046928         13.519020              50.016431      38.464844      681    198     286               3          512           0.585938                5           652            0.766871               1513            1879             80.521554
# 16        lasso     2          90.456432        100.000000     90.623377        90.625964            92.952805         90.454545               1521            3043              49.983569   273.700375       34.778115      308.479055        917782         3.506935          27.046928         13.519020              50.016431      38.464844      726    198     241               5          512           0.976562                5           652            0.766871               1511            1879             80.415114
# 17        lasso     3          99.090909         97.979798     99.088631        99.088631            99.173554         99.090909               1521            3043              49.983569   276.273711       35.837081      312.111709        917782         3.506935          27.046928         13.519020              50.016431      38.464844      747    198     220               5          512           0.976562                4           652            0.613497               1512            1879             80.468334
# 18        lasso     4          96.818182         98.989899     96.803942        96.803942            97.658402         96.818182               1521            3043              49.983569   274.774765       35.989746      310.765773        917782         3.506935          27.046928         13.519020              50.016431      38.464844      747    198     220               2          512           0.390625                4           652            0.613497               1515            1879             80.627994
# 19        lasso     5          97.474747         91.701245     97.383901        97.383901            97.809917         97.474747               1521            3043              49.983569   273.267695       35.169926      308.438387        917782         3.506935          27.046928         13.519020              50.016431      38.464844      726    241     198               5          512           0.976562                5           652            0.766871               1511            1879             80.415114

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.patches import ConnectionPatch
from scipy.stats import gaussian_kde


def plot_quadrant_scatter_with_zoom(df_all, ALL_METHODS,
                                     zoom_ret_range=(40, 60),
                                     zoom_acc_range=None):
    """
    Top: zoomed-in view of the crowded region (large, spacious).
    Bottom: full scatter with quadrant shading + marginals.
    Connected by red dashed rectangle + lines.
    """
    meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

    summary = df_all[df_all['Method'] != 'baseline'].groupby('Method').agg(
        acc_mean=('Test Accuracy (%)', 'mean'),
        acc_std=('Test Accuracy (%)', 'std'),
        ret_mean=('Feature Retention (%)', 'mean'),
        ret_std=('Feature Retention (%)', 'std'),
    )
    meta_summary = summary.loc[summary.index.isin(meta_methods)]

    ret_mid = meta_summary['ret_mean'].median()
    acc_mid = meta_summary['acc_mean'].median()

    # Auto zoom accuracy range
    crowded = meta_summary[(meta_summary['ret_mean'] >= zoom_ret_range[0]) &
                            (meta_summary['ret_mean'] <= zoom_ret_range[1])]
    if zoom_acc_range is None and len(crowded) > 0:
        pad_y = max(3.0, (crowded['acc_mean'].max() - crowded['acc_mean'].min()) * 0.5)
        zoom_acc_range = (crowded['acc_mean'].min() - pad_y,
                          crowded['acc_mean'].max() + pad_y)

    # =====================================================================
    # Figure layout
    # =====================================================================
    fig = plt.figure(figsize=(12, 16))
    outer_gs = gridspec.GridSpec(2, 1, height_ratios=[1, 1.3], hspace=0.18)

    # TOP: Zoom panel
    ax_zoom = fig.add_subplot(outer_gs[0])

    # BOTTOM: Main scatter + marginals
    inner_gs = gridspec.GridSpecFromSubplotSpec(
        2, 2, subplot_spec=outer_gs[1],
        width_ratios=[4, 1], height_ratios=[1, 4],
        hspace=0.05, wspace=0.05
    )
    ax_main = fig.add_subplot(inner_gs[1, 0])
    ax_top = fig.add_subplot(inner_gs[0, 0], sharex=ax_main)
    ax_right = fig.add_subplot(inner_gs[1, 1], sharey=ax_main)

    xlim = (meta_summary['ret_mean'].min() - 8, meta_summary['ret_mean'].max() + 8)
    ylim = (meta_summary['acc_mean'].min() - 3, meta_summary['acc_mean'].max() + 3)

    # --- Quadrant shading ---
    quadrant_info = {
        'Aggressive\nSelectors':   {'x': (xlim[0], ret_mid), 'y': (ylim[0], acc_mid), 'color': '#ffcccc'},
        'Ideal':                    {'x': (xlim[0], ret_mid), 'y': (acc_mid, ylim[1]), 'color': '#ccffcc'},
        'Conservative\nSelectors':  {'x': (ret_mid, xlim[1]), 'y': (acc_mid, ylim[1]), 'color': '#cce5ff'},
        'Over-retaining':           {'x': (ret_mid, xlim[1]), 'y': (ylim[0], acc_mid), 'color': '#fff2cc'},
    }
    for label, q in quadrant_info.items():
        rect = plt.Rectangle((q['x'][0], q['y'][0]),
                               q['x'][1] - q['x'][0], q['y'][1] - q['y'][0],
                               facecolor=q['color'], alpha=0.3, zorder=0)
        ax_main.add_patch(rect)
        cx = (q['x'][0] + q['x'][1]) / 2
        cy = (q['y'][0] + q['y'][1]) / 2
        ax_main.text(cx, cy, label, ha='center', va='center', fontsize=8,
                      fontstyle='italic', alpha=0.5, zorder=1)

    ax_main.axvline(ret_mid, color='gray', linestyle=':', linewidth=1, alpha=0.5)
    ax_main.axhline(acc_mid, color='gray', linestyle=':', linewidth=1, alpha=0.5)

    # --- Consistent colors ---
    color_map = {}
    for i, method in enumerate(meta_methods):
        color_map[method] = plt.cm.tab20(i / max(len(meta_methods), 1))

    # --- Plot helper ---
    def plot_point(ax, method, show_label=True, fontsize=9, offset=(10, 10)):
        if method not in summary.index:
            return
        row = summary.loc[method]
        short = method.replace('meta_', '')
        color = color_map.get(method, 'black')
        marker = 'o'
        ms = 9
        mec = color

        ax.errorbar(row['ret_mean'], row['acc_mean'],
                     xerr=row['ret_std'], yerr=row['acc_std'],
                     fmt=marker, markersize=ms, capsize=3, alpha=0.85,
                     color=color, markeredgecolor=mec,
                     markeredgewidth=0.5, zorder=5)
        if show_label:
            style = 'normal'
            txt_color = 'black'
            ax.annotate(short, (row['ret_mean'], row['acc_mean']),
                         textcoords="offset points", xytext=offset,
                         fontsize=fontsize, fontweight='bold',
                         fontstyle=style, color=txt_color, zorder=6)

    # --- Main scatter: label only non-crowded points ---
    for method in meta_methods:
        if method not in summary.index:
            continue
        row = summary.loc[method]
        in_crowd = (zoom_ret_range[0] <= row['ret_mean'] <= zoom_ret_range[1])
        plot_point(ax_main, method, show_label=not in_crowd, fontsize=9)


    # Zoom rectangle on main
    zoom_rect = plt.Rectangle((zoom_ret_range[0], zoom_acc_range[0]),
                                zoom_ret_range[1] - zoom_ret_range[0],
                                zoom_acc_range[1] - zoom_acc_range[0],
                                fill=False, edgecolor='red', linewidth=2,
                                linestyle='--', zorder=10)
    ax_main.add_patch(zoom_rect)

    ax_main.set_xlabel('Feature Retention (%)', fontsize=12)
    ax_main.set_ylabel('Test Accuracy (%)', fontsize=12)
    ax_main.set_xlim(xlim)
    ax_main.set_ylim(ylim)
    ax_main.grid(alpha=0.2)

    # =====================================================================
    # Zoom panel
    # =====================================================================
    ax_zoom.set_xlim(zoom_ret_range)
    ax_zoom.set_ylim(zoom_acc_range)
    ax_zoom.set_facecolor('#fafafa')
    ax_zoom.grid(alpha=0.3)
    ax_zoom.set_xlabel('Feature Retention (%)', fontsize=11)
    ax_zoom.set_ylabel('Test Accuracy (%)', fontsize=11)
    ax_zoom.set_title('Zoomed View — Crowded Region', fontsize=13,
                       fontweight='bold', pad=10)
    for spine in ax_zoom.spines.values():
        spine.set_edgecolor('red')
        spine.set_linewidth(2)
        spine.set_linestyle('--')

    # Collect crowded methods, sort by retention so we can alternate offsets
    crowded_methods = []
    for method in meta_methods:
        if method not in summary.index:
            continue
        row = summary.loc[method]
        if zoom_ret_range[0] <= row['ret_mean'] <= zoom_ret_range[1]:
            crowded_methods.append((method, row['ret_mean'], row['acc_mean']))

    crowded_methods.sort(key=lambda x: (x[1], x[2]))

    # Calculate scale factors
    x_span = ax_zoom.get_xlim()[1] - ax_zoom.get_xlim()[0]
    y_span = ax_zoom.get_ylim()[1] - ax_zoom.get_ylim()[0]

    # Scale offsets relative to axis span
    offset_patterns = [
        (0.03 * x_span + 10, 0.03 * y_span),    # upper-right
        (0.03 * x_span + 10, -0.03 * y_span),   # lower-right
        (-0.03 * x_span + 10, 0.03 * y_span),   # upper-left
        (-0.03 * x_span + 10, -0.03 * y_span),  # lower-left
        (0.03 * x_span + 10, 0),                # right
        (-0.03 * x_span + 10, 0),               # left
    ]

    for i, (method, ret_val, acc_val) in enumerate(crowded_methods):
        offset = offset_patterns[i % len(offset_patterns)]

        if method == 'meta_CS':
            offset = (offset[0] - 5, offset[1] - 15)

        if method == 'meta_SSA':
            offset = (offset[0], offset[1] - 5)

        if method == 'meta_MFO':
            offset = (offset[0] - 15, offset[1] + 7)

        if method == 'meta_BAT':
            offset = (offset[0], offset[1] - 5)

        plot_point(ax_zoom, method, show_label=True, fontsize=11, offset=offset)

    # Quadrant lines in zoom if they fall in range
    if zoom_ret_range[0] < ret_mid < zoom_ret_range[1]:
        ax_zoom.axvline(ret_mid, color='gray', linestyle=':', linewidth=1, alpha=0.4)
    if zoom_acc_range[0] < acc_mid < zoom_acc_range[1]:
        ax_zoom.axhline(acc_mid, color='gray', linestyle=':', linewidth=1, alpha=0.4)

    # --- Connection lines ---
    con_left = ConnectionPatch(
        xyA=(zoom_ret_range[0], zoom_acc_range[1]),
        xyB=(zoom_ret_range[0], zoom_acc_range[0]),
        coordsA="data", coordsB="data",
        axesA=ax_main, axesB=ax_zoom,
        color="red", linewidth=1.2, linestyle='--', alpha=0.4)
    fig.add_artist(con_left)

    con_right = ConnectionPatch(
        xyA=(zoom_ret_range[1], zoom_acc_range[1]),
        xyB=(zoom_ret_range[1], zoom_acc_range[0]),
        coordsA="data", coordsB="data",
        axesA=ax_main, axesB=ax_zoom,
        color="red", linewidth=1.2, linestyle='--', alpha=0.4)
    fig.add_artist(con_right)

    # --- Marginal KDE: top ---
    ret_vals = meta_summary['ret_mean'].values
    if len(ret_vals) > 2:
        kde_x = gaussian_kde(ret_vals, bw_method=0.4)
        x_grid = np.linspace(xlim[0], xlim[1], 200)
        ax_top.fill_between(x_grid, kde_x(x_grid), alpha=0.3, color='steelblue')
        ax_top.plot(x_grid, kde_x(x_grid), color='steelblue', linewidth=1.5)
    ax_top.axvline(ret_mid, color='gray', linestyle=':', linewidth=1, alpha=0.5)
    ax_top.set_ylabel('Density', fontsize=9)
    ax_top.tick_params(labelbottom=False)
    ax_top.set_title('Accuracy–Retention Trade-off with Quadrant Analysis (CZU-MHAD)',
                      fontsize=13, pad=10)

    # --- Marginal KDE: right ---
    acc_vals = meta_summary['acc_mean'].values
    if len(acc_vals) > 2:
        kde_y = gaussian_kde(acc_vals, bw_method=0.4)
        y_grid = np.linspace(ylim[0], ylim[1], 200)
        ax_right.fill_betweenx(y_grid, kde_y(y_grid), alpha=0.3, color='steelblue')
        ax_right.plot(kde_y(y_grid), y_grid, color='steelblue', linewidth=1.5)
    ax_right.axhline(acc_mid, color='gray', linestyle=':', linewidth=1, alpha=0.5)
    ax_right.set_xlabel('Density', fontsize=9)
    ax_right.tick_params(labelleft=False)

    plt.savefig(PLOTS_DIR / 'nfl_quadrant_scatter_zoom.png', dpi=300, bbox_inches='tight')
    plt.show()


plot_quadrant_scatter_with_zoom(
     df_all, ALL_METHODS,
     zoom_ret_range=(45.5, 47.65),
     zoom_acc_range=None
)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.patches import ConnectionPatch
from scipy.stats import gaussian_kde


def plot_quadrant_scatter_with_zoom(df_all, ALL_METHODS,
                                     zoom_ret_range=(40, 60),
                                     zoom_acc_range=None):
    """
    Left: full scatter with quadrant shading + marginals.
    Right: zoomed-in view of the crowded region (large, spacious).
    Connected by red dashed rectangle + lines.
    """
    meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

    summary = df_all[df_all['Method'] != 'baseline'].groupby('Method').agg(
        acc_mean=('Test Accuracy (%)', 'mean'),
        acc_std=('Test Accuracy (%)', 'std'),
        ret_mean=('Feature Retention (%)', 'mean'),
        ret_std=('Feature Retention (%)', 'std'),
    )
    meta_summary = summary.loc[summary.index.isin(meta_methods)]

    ret_mid = meta_summary['ret_mean'].median()
    acc_mid = meta_summary['acc_mean'].median()

    # Auto zoom accuracy range
    crowded = meta_summary[(meta_summary['ret_mean'] >= zoom_ret_range[0]) &
                            (meta_summary['ret_mean'] <= zoom_ret_range[1])]
    if zoom_acc_range is None and len(crowded) > 0:
        pad_y = max(3.0, (crowded['acc_mean'].max() - crowded['acc_mean'].min()) * 0.5)
        zoom_acc_range = (crowded['acc_mean'].min() - pad_y,
                          crowded['acc_mean'].max() + pad_y)

    # =====================================================================
    # Figure layout
    # =====================================================================
    fig = plt.figure(figsize=(20, 10))
    outer_gs = gridspec.GridSpec(1, 2, width_ratios=[1.3, 1], hspace=0.18, wspace=0.18)

    # RIGHT: Zoom panel
    ax_zoom = fig.add_subplot(outer_gs[1])

    # LEFT: Main scatter + marginals
    inner_gs = gridspec.GridSpecFromSubplotSpec(
        2, 2, subplot_spec=outer_gs[0],
        width_ratios=[4, 1], height_ratios=[1, 4],
        hspace=0.05, wspace=0.05
    )
    ax_main = fig.add_subplot(inner_gs[1, 0])
    ax_top = fig.add_subplot(inner_gs[0, 0], sharex=ax_main)
    ax_right = fig.add_subplot(inner_gs[1, 1], sharey=ax_main)

    xlim = (meta_summary['ret_mean'].min() - 8, meta_summary['ret_mean'].max() + 8)
    ylim = (meta_summary['acc_mean'].min() - 3, meta_summary['acc_mean'].max() + 3)

    # --- Quadrant shading ---
    quadrant_info = {
        'Aggressive\nSelectors':   {'x': (xlim[0], ret_mid), 'y': (ylim[0], acc_mid), 'color': '#ffcccc'},
        'Ideal':                    {'x': (xlim[0], ret_mid), 'y': (acc_mid, ylim[1]), 'color': '#ccffcc'},
        'Conservative\nSelectors':  {'x': (ret_mid, xlim[1]), 'y': (acc_mid, ylim[1]), 'color': '#cce5ff'},
        'Over-retaining':           {'x': (ret_mid, xlim[1]), 'y': (ylim[0], acc_mid), 'color': '#fff2cc'},
    }
    for label, q in quadrant_info.items():
        rect = plt.Rectangle((q['x'][0], q['y'][0]),
                               q['x'][1] - q['x'][0], q['y'][1] - q['y'][0],
                               facecolor=q['color'], alpha=0.3, zorder=0)
        ax_main.add_patch(rect)
        cx = (q['x'][0] + q['x'][1]) / 2
        cy = (q['y'][0] + q['y'][1]) / 2
        ax_main.text(cx, cy, label, ha='center', va='center', fontsize=8,
                      fontstyle='italic', alpha=0.5, zorder=1)

    ax_main.axvline(ret_mid, color='gray', linestyle=':', linewidth=1, alpha=0.5)
    ax_main.axhline(acc_mid, color='gray', linestyle=':', linewidth=1, alpha=0.5)

    # --- Consistent colors ---
    color_map = {}
    for i, method in enumerate(meta_methods):
        color_map[method] = plt.cm.tab20(i / max(len(meta_methods), 1))

    # --- Plot helper ---
    def plot_point(ax, method, show_label=True, fontsize=9, offset=(10, 10)):
        if method not in summary.index:
            return
        row = summary.loc[method]
        short = method.replace('meta_', '')
        color = color_map.get(method, 'black')
        marker = 'o'
        ms = 9
        mec = color

        ax.errorbar(row['ret_mean'], row['acc_mean'],
                     xerr=row['ret_std'], yerr=row['acc_std'],
                     fmt=marker, markersize=ms, capsize=3, alpha=0.85,
                     color=color, markeredgecolor=mec,
                     markeredgewidth=0.5, zorder=5)
        if show_label:
            style = 'normal'
            txt_color = 'black'
            ax.annotate(short, (row['ret_mean'], row['acc_mean']),
                         textcoords="offset points", xytext=offset,
                         fontsize=fontsize, fontweight='bold',
                         fontstyle=style, color=txt_color, zorder=6)

    # --- Main scatter: label only non-crowded points ---
    for method in meta_methods:
        if method not in summary.index:
            continue
        row = summary.loc[method]
        in_crowd = (zoom_ret_range[0] <= row['ret_mean'] <= zoom_ret_range[1])
        plot_point(ax_main, method, show_label=not in_crowd, fontsize=9)


    # Zoom rectangle on main
    zoom_rect = plt.Rectangle((zoom_ret_range[0], zoom_acc_range[0]),
                                zoom_ret_range[1] - zoom_ret_range[0],
                                zoom_acc_range[1] - zoom_acc_range[0],
                                fill=False, edgecolor='red', linewidth=2,
                                linestyle='--', zorder=10)
    ax_main.add_patch(zoom_rect)

    ax_main.set_xlabel('Feature Retention (%)', fontsize=12)
    ax_main.set_ylabel('Test Accuracy (%)', fontsize=12)
    ax_main.set_xlim(xlim)
    ax_main.set_ylim(ylim)
    ax_main.grid(alpha=0.2)

    # =====================================================================
    # Zoom panel
    # =====================================================================
    ax_zoom.set_xlim(zoom_ret_range)
    ax_zoom.set_ylim(zoom_acc_range)
    ax_zoom.set_facecolor('#fafafa')
    ax_zoom.grid(alpha=0.3)
    ax_zoom.set_xlabel('Feature Retention (%)', fontsize=11)
    ax_zoom.set_ylabel('Test Accuracy (%)', fontsize=11)
    ax_zoom.set_title('Zoomed View — Crowded Region', fontsize=13,
                       fontweight='bold', pad=10)
    for spine in ax_zoom.spines.values():
        spine.set_edgecolor('red')
        spine.set_linewidth(2)
        spine.set_linestyle('--')

    # Collect crowded methods, sort by retention so we can alternate offsets
    crowded_methods = []
    for method in meta_methods:
        if method not in summary.index:
            continue
        row = summary.loc[method]
        if zoom_ret_range[0] <= row['ret_mean'] <= zoom_ret_range[1]:
            crowded_methods.append((method, row['ret_mean'], row['acc_mean']))

    crowded_methods.sort(key=lambda x: (x[1], x[2]))

    # Calculate scale factors
    x_span = ax_zoom.get_xlim()[1] - ax_zoom.get_xlim()[0]
    y_span = ax_zoom.get_ylim()[1] - ax_zoom.get_ylim()[0]

    # Scale offsets relative to axis span
    offset_patterns = [
        (0.03 * x_span + 10, 0.03 * y_span),    # upper-right
        (0.03 * x_span + 10, -0.03 * y_span),   # lower-right
        (-0.03 * x_span + 10, 0.03 * y_span),   # upper-left
        (-0.03 * x_span + 10, -0.03 * y_span),  # lower-left
        (0.03 * x_span + 10, 0),                # right
        (-0.03 * x_span + 10, 0),               # left
    ]

    for i, (method, ret_val, acc_val) in enumerate(crowded_methods):
        offset = offset_patterns[i % len(offset_patterns)]

        if method == 'meta_CS':
            offset = (offset[0] - 5, offset[1] - 15)

        if method == 'meta_SSA':
            offset = (offset[0], offset[1] - 5)

        if method == 'meta_MFO':
            offset = (offset[0] - 15, offset[1] + 7)

        if method == 'meta_BAT':
            offset = (offset[0], offset[1] - 10)

        plot_point(ax_zoom, method, show_label=True, fontsize=11, offset=offset)

    # Quadrant lines in zoom if they fall in range
    if zoom_ret_range[0] < ret_mid < zoom_ret_range[1]:
        ax_zoom.axvline(ret_mid, color='gray', linestyle=':', linewidth=1, alpha=0.4)
    if zoom_acc_range[0] < acc_mid < zoom_acc_range[1]:
        ax_zoom.axhline(acc_mid, color='gray', linestyle=':', linewidth=1, alpha=0.4)

    # --- Connection lines (now left→right instead of bottom→top) ---
    con_top = ConnectionPatch(
        xyA=(zoom_ret_range[1], zoom_acc_range[1]),
        xyB=(zoom_ret_range[0], zoom_acc_range[1]),
        coordsA="data", coordsB="data",
        axesA=ax_main, axesB=ax_zoom,
        color="red", linewidth=1.2, linestyle='--', alpha=0.4)
    fig.add_artist(con_top)

    con_bottom = ConnectionPatch(
        xyA=(zoom_ret_range[1], zoom_acc_range[0]),
        xyB=(zoom_ret_range[0], zoom_acc_range[0]),
        coordsA="data", coordsB="data",
        axesA=ax_main, axesB=ax_zoom,
        color="red", linewidth=1.2, linestyle='--', alpha=0.4)
    fig.add_artist(con_bottom)

    # --- Marginal KDE: top ---
    ret_vals = meta_summary['ret_mean'].values
    if len(ret_vals) > 2:
        kde_x = gaussian_kde(ret_vals, bw_method=0.4)
        x_grid = np.linspace(xlim[0], xlim[1], 200)
        ax_top.fill_between(x_grid, kde_x(x_grid), alpha=0.3, color='steelblue')
        ax_top.plot(x_grid, kde_x(x_grid), color='steelblue', linewidth=1.5)
    ax_top.axvline(ret_mid, color='gray', linestyle=':', linewidth=1, alpha=0.5)
    ax_top.set_ylabel('Density', fontsize=9)
    ax_top.tick_params(labelbottom=False)
    ax_top.set_title('Accuracy–Retention Trade-off with Quadrant Analysis (CZU-MHAD)',
                      fontsize=13, pad=10)

    # --- Marginal KDE: right ---
    acc_vals = meta_summary['acc_mean'].values
    if len(acc_vals) > 2:
        kde_y = gaussian_kde(acc_vals, bw_method=0.4)
        y_grid = np.linspace(ylim[0], ylim[1], 200)
        ax_right.fill_betweenx(y_grid, kde_y(y_grid), alpha=0.3, color='steelblue')
        ax_right.plot(kde_y(y_grid), y_grid, color='steelblue', linewidth=1.5)
    ax_right.axhline(acc_mid, color='gray', linestyle=':', linewidth=1, alpha=0.5)
    ax_right.set_xlabel('Density', fontsize=9)
    ax_right.tick_params(labelleft=False)

    plt.savefig(PLOTS_DIR / 'nfl_quadrant_scatter_zoom_right.png', dpi=300, bbox_inches='tight')
    plt.show()


plot_quadrant_scatter_with_zoom(
     df_all, ALL_METHODS,
     zoom_ret_range=(45.5, 47.65),
     zoom_acc_range=None
)

# %% [markdown]
# ### Statistical significance: per-fold results

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from scipy.stats import wilcoxon, ttest_rel

RESULTS_ROOT = Path("results")

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

baseline_f1 = (
    df_all[df_all['Method'] == 'baseline']
    .sort_values('Fold')
    ['F1 Macro (%)']
    .values
)

meta_methods = [m for m in df_all['Method'].unique() if m.startswith('meta_')]
combined_meta_f1 = (
    df_all[df_all['Method'].isin(meta_methods)]
    .loc[lambda d: d.groupby('Fold')['F1 Macro (%)'].transform('max') == d['F1 Macro (%)']]
    .drop_duplicates('Fold')
    .sort_values('Fold')
    ['F1 Macro (%)']
    .values
)

n_folds = len(baseline_f1)
assert len(combined_meta_f1) == n_folds, "Fold count mismatch between methods"

diff = combined_meta_f1 - baseline_f1

fold_df = pd.DataFrame({
    'Fold':              np.arange(1, n_folds + 1),
    'Baseline F1 (%)':  baseline_f1,
    'Combined Meta F1 (%)': combined_meta_f1,
    'Δ F1 (%)':         diff,
})

pd.set_option('display.float_format', '{:.2f}'.format)
print("=" * 60)
print("PER-FOLD F1 MACRO: Baseline vs. Best Combined Metaheuristic")
print("=" * 60)
print(fold_df.to_string(index=False))
print(f"\n  Baseline        — Mean: {baseline_f1.mean():.2f}%  Std: {baseline_f1.std():.2f}%")
print(f"  Combined Meta   — Mean: {combined_meta_f1.mean():.2f}%  Std: {combined_meta_f1.std():.2f}%")
print(f"  Mean            — {diff.mean():+.2f}%  (positive = meta better)")

try:
    _,      w_p_one  = wilcoxon(combined_meta_f1, baseline_f1, zero_method='wilcox', alternative='greater')
except ValueError as e:
    w_stat, w_p_one = np.nan, np.nan
    print(f"\n  [Wilcoxon] Could not compute: {e}")

t_stat, t_p_two = ttest_rel(combined_meta_f1, baseline_f1)
t_p_one         = t_p_two / 2 if t_stat > 0 else 1 - t_p_two / 2

cohens_d = diff.mean() / diff.std(ddof=1)

def effect_label(d):
    d = abs(d)
    if d < 0.2:  return "negligible"
    if d < 0.5:  return "small"
    if d < 0.8:  return "medium"
    return "large"

def sig_stars(p):
    if np.isnan(p): return "n/a"
    if p < 0.001:   return "*** (p<0.001)"
    if p < 0.01:    return "**  (p<0.01)"
    if p < 0.05:    return "*   (p<0.05)"
    if p < 0.1:     return "†   (p<0.10, trend)"
    return "n.s."

print("\n" + "=" * 60)
print("STATISTICAL SIGNIFICANCE RESULTS")
print("=" * 60)

print(f"\n  Wilcoxon signed-rank test")
print(f"    W statistic      : {w_stat}")
print(f"    p-value (1-sided): {w_p_one:.4f}  {sig_stars(w_p_one)}")

print(f"\n  Paired t-test (parametric)")
print(f"    t statistic      : {t_stat:.4f}")
print(f"    p-value (1-sided): {t_p_one:.4f}  {sig_stars(t_p_one)}")

print(f"\n    Effect size (Cohen's d, paired)")
print(f"    d = {cohens_d:.4f}  → {effect_label(cohens_d)}")

print(f"\nInterpretation")
alpha = 0.05
primary_p = w_p_one
if not np.isnan(primary_p) and primary_p < alpha:
    print(f"Combined metaheuristic is significantly BETTER than baseline")
    print(f"(Wilcoxon one-sided p={primary_p:.4f} < α={alpha})")
elif not np.isnan(primary_p) and primary_p < 0.10:
    print(f"Trend toward improvement but not significant at α={alpha}")
    print(f"(Wilcoxon one-sided p={primary_p:.4f})")
else:
    print(f"No statistically significant improvement over baseline")
    print(f"(Wilcoxon one-sided p={primary_p:.4f} ≥ α={alpha})")

results_dict = {
    'wilcoxon_W':       w_stat,
    'wilcoxon_p_one':   w_p_one,
    't_stat':           t_stat,
    't_p_two':          t_p_two,
    't_p_one':          t_p_one,
    'cohens_d':         cohens_d,
    'baseline_mean_f1': baseline_f1.mean(),
    'meta_mean_f1':     combined_meta_f1.mean(),
    'mean_delta_f1':    diff.mean(),
}
pd.DataFrame([results_dict]).round(4).to_csv(
    RESULTS_ROOT / "significance_test_results.csv", index=False
)
print(f"\nSaved → {RESULTS_ROOT / 'significance_test_results.csv'}")
# Out:
# ============================================================
# PER-FOLD F1 MACRO: Baseline vs. Best Combined Metaheuristic
# ============================================================
#  Fold  Baseline F1 (%)  Combined Meta F1 (%)  Δ F1 (%)
#     1            97.17                 98.60      1.43
#     2            93.47                 94.62      1.14
#     3            98.60                 99.54      0.94
#     4            92.24                 96.79      4.55
#     5            98.99                100.00      1.01
#
#   Baseline        — Mean: 96.10%  Std: 2.74%
#   Combined Meta   — Mean: 97.91%  Std: 1.98%
#   Mean            — +1.81%  (positive = meta better)
#
# ============================================================
# STATISTICAL SIGNIFICANCE RESULTS
# ============================================================
#
#   Wilcoxon signed-rank test
#     W statistic      : 0.0
#     p-value (1-sided): 0.0312  *   (p<0.05)
#
#   Paired t-test (parametric)
#     t statistic      : 2.6347
#     p-value (1-sided): 0.0289  *   (p<0.05)
#
#     Effect size (Cohen's d, paired)
#     d = 1.1783  → large
#
# Interpretation
# Combined metaheuristic is significantly BETTER than baseline
# (Wilcoxon one-sided p=0.0312 < α=0.05)
#
# Saved → results\significance_test_results.csv
