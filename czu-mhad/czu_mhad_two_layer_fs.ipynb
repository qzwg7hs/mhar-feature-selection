# %% [markdown]
# # CZU-MHAD: Two-Layer Feature Selection (Per-Modality → Combined)
#
# ## Overview
# This notebook implements a **two-layer feature selection** pipeline:
#
# **Layer 1 (already done):** Feature selection was run independently on each modality (depth, sensor, skeleton). Results are stored in:
# - `results_depth/`
# - `results_inertial/`
# - `results_skeleton/`
#
# **Layer 2 (this notebook):**
# 1. **Combine** the selected features from each modality into a unified feature set
# 2. **Evaluate** the combined features (Layer 1 result) on HAR
# 3. **Run a second layer** of feature selection on the combined set
#
# ### Combination Strategy:
# - **Standard methods** (mutual_info, rfe, lasso): Combine features selected by the *same* method across all 3 modalities. Then run the same FS method again on the combined set.
# - **Metaheuristics**: For each fold, find the *best* metaheuristic (highest test F1) per modality. Combine those best-selected features. Then run all 14 metaheuristics on that combined set.
# - **Baseline**: Combine all baseline (all features) from each modality = full feature set.
#
# All results saved in `results_two_layer/`.

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Layer 1 results directories (already computed)
LAYER1_DIRS = {
    'depth': Path("results_depth"),
    'sensor': Path("results_inertial"),
    'skeleton': Path("results_skeleton"),
}

# Master output directory for two-layer results
RESULTS_ROOT = Path("results_two_layer")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters (same as original)
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of combined features)
TARGET_FEATURE_PERCENTAGE = 0.5

DEPTH_PCA_DIM = 512
DEPTH_DR_METHOD = 'kernel_pca'

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

STANDARD_METHODS = ['mutual_info', 'rfe', 'lasso']
META_METHODS = [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]
# For layer 2, we have: baseline, 3 standard methods, and meta_best (which runs all 14 metas)
# Output method names for layer 2:
ALL_METHODS_L2 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS_L2:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)
# Also create combined_layer1 directory
(RESULTS_ROOT / "combined_layer1").mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection (Layer 2): {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Layer 1 dirs: {list(LAYER1_DIRS.keys())}")

# Verify layer 1 directories exist
for mod, d in LAYER1_DIRS.items():
    if d.exists():
        print(f"  ✓ {d} exists")
    else:
        print(f"  ✗ {d} MISSING!")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection (Layer 2): 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Layer 1 dirs: ['depth', 'sensor', 'skeleton']
#   ✓ results_depth exists
#   ✓ results_inertial exists
#   ✓ results_skeleton exists

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions
first_sample = X_feat[0]
# NOTE: depth is reduced from its raw size to DEPTH_PCA_DIM via KernelPCA.
# FEATURE_DIMS (and therefore TOTAL_FEATURES / MODALITY_OFFSETS) must reflect
# the POST-PCA depth dimension (512), not the raw depth dimension.
FEATURE_DIMS = {
    'depth': DEPTH_PCA_DIM,  # After KernelPCA: 512 (not raw depth size)
    'sensor': first_sample['sensor_feat'].shape[0],
    'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions (depth = post-KernelPCA):")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")

# Compute modality offsets in the unified feature vector
MODALITY_OFFSETS = {}
offset = 0
for mod, dim in FEATURE_DIMS.items():
    MODALITY_OFFSETS[mod] = (offset, offset + dim)
    offset += dim
print(f"\nModality offsets in unified vector:")
for mod, (s, e) in MODALITY_OFFSETS.items():
    print(f"  {mod}: [{s}, {e})")

# Store raw per-modality feature dims (before PCA)
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat']
MODALITY_NAMES = list(FEATURE_DIMS.keys())
RAW_FEATURE_DIMS = {name: first_sample[key].shape[0] for key, name in zip(MODALITY_KEYS, MODALITY_NAMES)}

# Store per-modality arrays (N_samples x D_modality) for per-modality pipeline
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before depth PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  Depth PCA target: {DEPTH_PCA_DIM}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions (depth = post-KernelPCA):
#   depth: 512
#   sensor: 652
#   skeleton: 1879
#   TOTAL: 3043
#
# Modality offsets in unified vector:
#   depth: [0, 512)
#   sensor: [512, 1164)
#   skeleton: [1164, 3043)
#
# Raw feature dimensions (before depth PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)

def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> KernelPCA on depth -> concatenate.

    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA
        pca_obj: fitted KernelPCA object (or None)
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    pca_obj = None
    feature_dims = {}

    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]

        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]

        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)

        # KernelPCA on depth only
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                random_state=42, n_jobs=-1)
            X_tr = pca_obj.fit_transform(X_tr)
            X_v  = pca_obj.transform(X_v)
            X_te = pca_obj.transform(X_te)
            print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]

    # Concatenate: depth | sensor | skeleton
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)

    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " +
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")

    return X_train, X_val, X_test, feature_dims, pca_obj


print("Helper functions defined (with per-modality normalization + KernelPCA on depth)")
# Out:
# Helper functions defined (with per-modality normalization + KernelPCA on depth)

# %% [markdown]
# ## Enhanced Evaluation

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Load Layer 1 Results (Pre-computed Per-Modality Feature Selection)
#
# Load the feature masks from each modality's per-fold results.

# %%
def load_layer1_masks():
    """
    Load all Layer 1 feature masks from per-modality results directories.
    
    Returns:
        layer1_masks: dict[modality][method][fold_idx] = binary_mask (numpy bool array)
        layer1_results: dict[modality][method][fold_idx] = json_results (dict)
    """
    layer1_masks = {}
    layer1_results = {}
    
    all_methods_l1 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]
    
    for modality, results_dir in LAYER1_DIRS.items():
        layer1_masks[modality] = {}
        layer1_results[modality] = {}
        
        for method in all_methods_l1:
            layer1_masks[modality][method] = {}
            layer1_results[modality][method] = {}
            
            method_dir = results_dir / method
            if not method_dir.exists():
                print(f"  WARNING: {method_dir} does not exist!")
                continue
            
            for fold_idx in range(N_FOLDS):
                mask_path = method_dir / f"fold_{fold_idx+1}_mask.npy"
                json_path = method_dir / f"fold_{fold_idx+1}.json"
                
                if mask_path.exists():
                    mask = np.load(mask_path)
                    layer1_masks[modality][method][fold_idx] = mask
                else:
                    print(f"  WARNING: Missing mask: {mask_path}")
                
                if json_path.exists():
                    with open(json_path) as f:
                        layer1_results[modality][method][fold_idx] = json_lib.load(f)
    
    return layer1_masks, layer1_results

layer1_masks, layer1_results = load_layer1_masks()

# Summary
print("\n" + "="*80)
print("LAYER 1 MASKS LOADED")
print("="*80)
modalities = list(LAYER1_DIRS.keys())
all_methods_l1 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for modality in modalities:
    n_loaded = sum(
        len(layer1_masks[modality].get(m, {})) 
        for m in all_methods_l1
    )
    print(f"  {modality}: {n_loaded} fold-masks loaded across {len(all_methods_l1)} methods")
# Out:
# ================================================================================
# LAYER 1 MASKS LOADED
# ================================================================================
#   depth: 85 fold-masks loaded across 17 methods
#   sensor: 85 fold-masks loaded across 17 methods
#   skeleton: 85 fold-masks loaded across 17 methods

# %% [markdown]
# ## Combine Layer 1 Selected Features Into Unified Masks
#
# ### Strategy:
# - **Standard methods** (mutual_info, rfe, lasso): For each fold, take the selected features from the same method in each modality and combine them (union into unified feature space).
# - **Metaheuristics**: For each fold, find the best metaheuristic per modality (highest test accuracy), then combine those best-selected features.
# - **Baseline**: All features from all modalities (full feature set).
#
# The combined mask is over the full unified feature space (depth + sensor + skeleton).

# %%
def build_combined_mask_standard(method, fold_idx):
    """
    For a standard method, combine selected features from the same method 
    across all 3 modalities into a unified mask over the full feature space
    (post-KernelPCA; depth slot = DEPTH_PCA_DIM = 512).

    The Layer-1 depth mask is already 512-long because FS was run on the
    KernelPCA components, so it is placed directly like any other modality.
    """
    unified_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    
    for modality in modalities:
        if method not in layer1_masks[modality]:
            continue
        if fold_idx not in layer1_masks[modality][method]:
            continue
        
        mod_mask = layer1_masks[modality][method][fold_idx]
        start, end = MODALITY_OFFSETS[modality]
        mod_dim = end - start
        
        # The modality mask length should match the modality dimension
        if len(mod_mask) == mod_dim:
            unified_mask[start:end] = mod_mask
        else:
            print(f"  WARNING: {modality}/{method}/fold_{fold_idx+1} mask length "
                  f"{len(mod_mask)} != expected {mod_dim}")
    
    return unified_mask


def find_best_meta_per_modality(fold_idx):
    """
    For a given fold, find which metaheuristic gave the highest test accuracy
    in each modality. Returns dict[modality] = (best_method_name, test_acc).
    """
    best_per_mod = {}
    
    for modality in modalities:
        best_method = None
        best_acc = -1.0
        
        for method in META_METHODS:
            if method not in layer1_results[modality]:
                continue
            if fold_idx not in layer1_results[modality][method]:
                continue
            
            result = layer1_results[modality][method][fold_idx]
            test_acc = result.get('test_acc', 0)
            
            if test_acc > best_acc:
                best_acc = test_acc
                best_method = method
        
        best_per_mod[modality] = (best_method, best_acc)
    
    return best_per_mod


def build_combined_mask_best_meta(fold_idx):
    """
    For metaheuristics: find best meta per modality for this fold,
    then combine their selected features into a unified mask
    (post-KernelPCA space; depth slot = DEPTH_PCA_DIM = 512).

    The Layer-1 depth mask is already 512-long because FS was run on the
    KernelPCA components, so it is placed directly like any other modality.
    """
    unified_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    best_per_mod = find_best_meta_per_modality(fold_idx)
    
    for modality in modalities:
        best_method, best_acc = best_per_mod[modality]
        if best_method is None:
            print(f"  WARNING: No meta results for {modality} fold {fold_idx+1}")
            continue
        
        mod_mask = layer1_masks[modality][best_method][fold_idx]
        start, end = MODALITY_OFFSETS[modality]
        mod_dim = end - start
        
        if len(mod_mask) == mod_dim:
            unified_mask[start:end] = mod_mask
        else:
            print(f"  WARNING: {modality}/{best_method}/fold_{fold_idx+1} mask length "
                  f"{len(mod_mask)} != expected {mod_dim}")
    
    return unified_mask, best_per_mod


# Build all combined masks
combined_masks = {}  # method -> {fold_idx: mask}

# Standard methods
for method in STANDARD_METHODS:
    combined_masks[method] = {}
    for fold_idx in range(N_FOLDS):
        combined_masks[method][fold_idx] = build_combined_mask_standard(method, fold_idx)

# Best metaheuristic combination
combined_masks['meta_best'] = {}
meta_best_info = {}  # fold_idx -> best_per_mod
for fold_idx in range(N_FOLDS):
    mask, best_per_mod = build_combined_mask_best_meta(fold_idx)
    combined_masks['meta_best'][fold_idx] = mask
    meta_best_info[fold_idx] = best_per_mod

# Print summary
print("="*80)
print("COMBINED LAYER 1 MASKS SUMMARY")
print("="*80)

for method in STANDARD_METHODS + ['meta_best']:
    avg_selected = np.mean([np.sum(combined_masks[method][f]) for f in range(N_FOLDS)])
    print(f"  {method:15s}: avg {avg_selected:.0f}/{TOTAL_FEATURES} features selected "
          f"({avg_selected/TOTAL_FEATURES*100:.1f}%)")

print("\nBest metaheuristic per modality per fold:")
for fold_idx in range(N_FOLDS):
    info = meta_best_info[fold_idx]
    parts = [f"{mod}={info[mod][0]}({info[mod][1]*100:.1f}%)" for mod in modalities]
    print(f"  Fold {fold_idx+1}: {', '.join(parts)}")
# Out:
# ================================================================================
# COMBINED LAYER 1 MASKS SUMMARY
# ================================================================================
#   mutual_info    : avg 1521/3043 features selected (50.0%)
#   rfe            : avg 1521/3043 features selected (50.0%)
#   lasso          : avg 1521/3043 features selected (50.0%)
#   meta_best      : avg 1729/3043 features selected (56.8%)
#
# Best metaheuristic per modality per fold:
#   Fold 1: depth=meta_HHO(72.4%), sensor=meta_GWO(87.4%), skeleton=meta_MVO(97.9%)
#   Fold 2: depth=meta_WOA(75.1%), sensor=meta_DE(89.2%), skeleton=meta_HHO(88.0%)
#   Fold 3: depth=meta_WOA(65.0%), sensor=meta_SSA(85.5%), skeleton=meta_MVO(98.6%)
#   Fold 4: depth=meta_HHO(52.7%), sensor=meta_JAYA(81.4%), skeleton=meta_GWO(95.5%)
#   Fold 5: depth=meta_HHO(62.6%), sensor=meta_WOA(87.9%), skeleton=meta_CS(95.5%)

# %% [markdown]
# ## Evaluate Combined Layer 1 Features (Before Second Layer FS)
#
# Train and evaluate the neural network on the combined features from Layer 1,
# **without** any additional feature selection. This shows the HAR performance
# of simply combining per-modality selected features.

# %%
def evaluate_combined_layer1():
    """
    Evaluate combined Layer 1 features (no second-layer FS yet).
    This gives us the baseline performance of the combined per-modality selections.
    """
    print("="*80)
    print("EVALUATING COMBINED LAYER 1 FEATURES (before Layer 2 FS)")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    dummy_X = np.zeros((len(y), 1))

    layer1_eval_results = {}  # method -> {fold_idx: metrics}
    
    methods_to_eval = STANDARD_METHODS + ['meta_best']
    
    for method in methods_to_eval:
        layer1_eval_results[method] = {}
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*60}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*60}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]

        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv

        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]

        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")

        # Per-modality normalization + KernelPCA on depth (fit on train only)
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )

        y_train = y[train_idx]
        y_val   = y[val_idx]
        y_test  = y[test_idx]

        # Rebuild unified offsets for this fold (post-PCA dims may differ from FEATURE_DIMS)
        fold_offsets = {}
        offset = 0
        for mod_name, dim in fold_feature_dims.items():
            fold_offsets[mod_name] = (offset, offset + dim)
            offset += dim
        fold_total_features = sum(fold_feature_dims.values())

        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)

        for method in methods_to_eval:
            print(f"\n  --- Combined L1: {method.upper()} ---")

            # The combined L1 mask is already in post-PCA space (depth slot = 512),
            # because FEATURE_DIMS['depth'] = DEPTH_PCA_DIM and the saved L1 depth
            # masks are 512-long (FS ran on KernelPCA components). No remapping needed.
            feature_mask = combined_masks[method][fold_idx].copy()
            assert len(feature_mask) == fold_total_features, (
                f"Mask length {len(feature_mask)} != fold_total_features {fold_total_features}"
            )

            X_train_sel = X_train[:, feature_mask]
            X_val_sel   = X_val[:, feature_mask]
            X_test_sel  = X_test[:, feature_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            modality_ret = calculate_modality_retention(feature_mask, fold_feature_dims)
            
            fold_result = {
                'fold': fold_idx,
                'method': f'combined_L1_{method}',
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
            }
            
            layer1_eval_results[method][fold_idx] = fold_result
            
            # Save
            save_dir = RESULTS_ROOT / "combined_layer1"
            fold_save = {k: v for k, v in fold_result.items() if k != 'feature_mask'}
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(save_dir / f"combined_L1_{method}_fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(save_dir / f"combined_L1_{method}_fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%)")
            
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    return layer1_eval_results

layer1_eval_results = evaluate_combined_layer1()
# Out:
# ================================================================================
# EVALUATING COMBINED LAYER 1 FEATURES (before Layer 2 FS)
# ================================================================================
#
# ############################################################
# # FOLD 1/5
# ############################################################
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 98.95%, F1: 98.95%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 97.20%, F1: 97.21%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 95.45%, F1: 95.46%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 97.90%, F1: 97.90%, Features: 1694/3043 (55.7%)
#
# ############################################################
# # FOLD 2/5
# ############################################################
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 92.95%, F1: 93.04%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 93.78%, F1: 93.93%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 92.53%, F1: 92.75%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 90.87%, F1: 91.07%, Features: 2024/3043 (66.5%)
#
# ############################################################
# # FOLD 3/5
# ############################################################
#   Train: 747, Val: 198, Test: 220
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 95.00%, F1: 94.79%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 98.64%, F1: 98.60%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 99.55%, F1: 99.54%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 96.36%, F1: 95.92%, Features: 1751/3043 (57.5%)
#
# ############################################################
# # FOLD 4/5
# ############################################################
#   Train: 747, Val: 198, Test: 220
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 91.82%, F1: 90.60%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 93.18%, F1: 92.59%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 90.91%, F1: 89.33%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 90.91%, F1: 90.08%, Features: 1413/3043 (46.4%)
#
# ############################################################
# # FOLD 5/5
# ############################################################
#   Train: 726, Val: 241, Test: 198
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 96.46%, F1: 95.83%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 98.99%, F1: 98.98%, Features: 1521/3043 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 99.49%, F1: 99.49%, Features: 1765/3043 (58.0%)

# %% [markdown]
# ## Layer 1 Combined Results Summary

# %%
print("\n" + "="*80)
print("COMBINED LAYER 1 RESULTS SUMMARY")
print("="*80)

methods_to_eval = STANDARD_METHODS + ['meta_best']

rows = []
for method in methods_to_eval:
    accs = []
    f1s = []
    feats = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in layer1_eval_results[method]:
            r = layer1_eval_results[method][fold_idx]
            accs.append(r['test_acc'] * 100)
            f1s.append(r['test_f1_macro'] * 100)
            feats.append(r['num_features_selected'])
    
    if accs:
        rows.append({
            'Method': f'Combined_L1_{method}',
            'Mean Test Acc (%)': np.mean(accs),
            'Std Test Acc (%)': np.std(accs),
            'Mean F1 Macro (%)': np.mean(f1s),
            'Mean Features': np.mean(feats),
            'Mean Retention (%)': np.mean(feats) / TOTAL_FEATURES * 100,
        })

df_l1_summary = pd.DataFrame(rows).round(2)
print(df_l1_summary.to_string(index=False))

# Save
df_l1_summary.to_csv(RESULTS_ROOT / "combined_layer1_summary.csv", index=False)
print(f"\nSaved: combined_layer1_summary.csv")
# Out:
# ================================================================================
# COMBINED LAYER 1 RESULTS SUMMARY
# ================================================================================
#                  Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Mean Features  Mean Retention (%)
# Combined_L1_mutual_info              95.74              3.23              95.47         1521.0               49.98
#         Combined_L1_rfe              95.85              2.07              95.64         1521.0               49.98
#       Combined_L1_lasso              95.49              3.42              95.21         1521.0               49.98
#   Combined_L1_meta_best              95.11              3.58              94.89         1729.4               56.83
#
# Saved: combined_layer1_summary.csv

# %% [markdown]
# ## Feature Selection Methods for Layer 2
#
# These are the same FS methods as the original notebook, but now they operate
# on the **combined Layer 1 features** (a subset of the full feature space).

# %%
def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


def create_fitness_function_evolopy_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Create fitness function for EvoloPy Layer 2"""
    eval_count = [0]
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            alpha = 0.95
            beta = 0.05
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def run_evolopy_optimizer_l2(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run any EvoloPy optimizer on Layer 2 features"""
    print(f"    Running EvoloPy {optimizer_name} (Layer 2)...")
    print(f"      Features: {n_features_l2}, Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_features_l2, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    
    return results


def run_mutual_info_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run Mutual Information feature selection on Layer 2"""
    print("    Running Mutual Information (Layer 2)...")
    
    start_time = time.time()
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    k = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_features_l2, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run RFE feature selection on Layer 2"""
    print("    Running RFE (Layer 2)...")
    
    start_time = time.time()
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    k = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    step = max(1, min(50, n_features_l2 // 10))
    selector = RFE(estimator, n_features_to_select=k, step=step)
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    execution_time = time.time() - start_time
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run LASSO feature selection on Layer 2"""
    print("    Running LASSO (Layer 2)...")
    start_time = time.time()

    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    target_count = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_features_l2, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Layer 2 feature selection methods defined")
# Out:
# Layer 2 feature selection methods defined

# %% [markdown]
# ## Main Layer 2 Experiment Runner
#
# ### Process for each fold:
# 1. **Standard methods** (mutual_info, rfe, lasso):
#    - Take combined L1 mask → extract those features from unified data
#    - Run the *same* FS method on this subset
#    - The L2 mask is relative to the L1-selected features; map back to unified space
#
# 2. **Metaheuristics**:
#    - Take combined best-meta L1 mask → extract those features
#    - Run ALL 14 metaheuristics on this subset

# %%
def save_fold_result(fold_result, method_name, fold_idx):
    """Save a fold result to disk"""
    fold_dir = RESULTS_ROOT / method_name
    fold_dir.mkdir(exist_ok=True)
    
    fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
    fold_save_clean = {}
    for k, v in fold_save.items():
        if isinstance(v, np.ndarray):
            fold_save_clean[k] = v.tolist()
        elif isinstance(v, (np.floating, np.integer)):
            fold_save_clean[k] = float(v)
        elif isinstance(v, dict):
            fold_save_clean[k] = {}
            for kk, vv in v.items():
                if isinstance(vv, dict):
                    fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                else:
                    fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
            
        else:
            fold_save_clean[k] = v
    
    with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
        json_lib.dump(fold_save_clean, f, indent=2, default=str)
    
    np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", fold_result['feature_mask'])


def run_layer2_experiments():
    """
    Run Layer 2 feature selection on combined Layer 1 features.
    """
    print("="*80)
    print("STARTING LAYER 2 FEATURE SELECTION EXPERIMENTS")
    print("="*80)
    
    num_classes = len(np.unique(y))

    master_results = {m: {} for m in ALL_METHODS_L2}

    gkf = GroupKFold(n_splits=N_FOLDS)
    dummy_X = np.zeros((len(y), 1))

    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")

        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]

        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv

        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]

        y_train = y[train_idx]
        y_val   = y[val_idx]
        y_test  = y[test_idx]

        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")

        # Per-modality normalization + KernelPCA on depth (fit on train only)
        X_train_norm, X_val_norm, X_test_norm, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )

        # Rebuild unified offsets for this fold (post-PCA dims may differ from FEATURE_DIMS)
        fold_offsets = {}
        offset = 0
        for mod_name, dim in fold_feature_dims.items():
            fold_offsets[mod_name] = (offset, offset + dim)
            offset += dim
        fold_total_features = sum(fold_feature_dims.values())

        orig_dataset_size_mb = get_dataset_size_mb(X_train_norm) + get_dataset_size_mb(X_val_norm) + get_dataset_size_mb(X_test_norm)
        
        # =================================================================
        # STANDARD METHODS: mutual_info, rfe, lasso
        # =================================================================
        for std_method in STANDARD_METHODS:
            print(f"\n  --- Layer 2: {std_method.upper()} ---")
            
            # The combined L1 mask is already in post-PCA space (depth slot = 512),
            # because FEATURE_DIMS['depth'] = DEPTH_PCA_DIM and the saved L1 depth
            # masks are 512-long (FS ran on KernelPCA components). Use directly.
            fold_l1_mask = combined_masks[std_method][fold_idx].copy()

            l1_indices = np.where(fold_l1_mask)[0]
            n_l1_features = len(l1_indices)

            print(f"    L1 combined features: {n_l1_features}/{fold_total_features}")

            # Extract L1-selected features
            X_train_l1 = X_train_norm[:, fold_l1_mask]
            X_val_l1   = X_val_norm[:, fold_l1_mask]
            X_test_l1  = X_test_norm[:, fold_l1_mask]
            
            fs_start_time = time.time()
            
            # Run Layer 2 FS on the L1-selected features
            if std_method == 'mutual_info':
                fs_results = run_mutual_info_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            elif std_method == 'rfe':
                fs_results = run_rfe_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            elif std_method == 'lasso':
                fs_results = run_lasso_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            
            fs_time = time.time() - fs_start_time
            
            # L2 mask is relative to L1 features; map back to unified space
            l2_mask_relative = fs_results['mask']
            
            # Final mask in fold space
            final_mask = np.zeros(fold_total_features, dtype=bool)
            final_mask[l1_indices[l2_mask_relative]] = True

            # Apply final mask
            X_train_sel = X_train_norm[:, final_mask]
            X_val_sel   = X_val_norm[:, final_mask]
            X_test_sel  = X_test_norm[:, final_mask]

            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)

            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()

            eval_metrics = train_and_evaluate_full(model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes)
            modality_ret = calculate_modality_retention(final_mask, fold_feature_dims)

            fold_result = {
                'fold': fold_idx, 'method': std_method,
                'l1_method': std_method, 'l1_features': n_l1_features,
                'val_acc': eval_metrics['val_acc'], 'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'], 'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'], 'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(final_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(final_mask) / fold_total_features * 100),
                'modality_retention': modality_ret, 'feature_mask': final_mask,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'], 'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb, 'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': None, 'best_fitness': None,
            }
            
            master_results[std_method][fold_idx] = fold_result
            save_fold_result(fold_result, std_method, fold_idx)
            
            print(f"    L2 Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(final_mask)}/{fold_total_features} "
                  f"({np.sum(final_mask)/fold_total_features*100:.1f}%)")

            del model, train_dataset, val_dataset, test_dataset, train_loader, val_loader, test_loader
            torch.cuda.empty_cache(); gc.collect()

        # =================================================================
        # METAHEURISTICS: Run all 14 on combined best-meta L1 features
        # =================================================================
        # The combined L1 mask is already in post-PCA space (depth slot = 512),
        # because FEATURE_DIMS['depth'] = DEPTH_PCA_DIM and the saved L1 depth
        # masks are 512-long (FS ran on KernelPCA components). Use directly.
        fold_l1_mask_meta = combined_masks['meta_best'][fold_idx].copy()

        l1_indices_meta = np.where(fold_l1_mask_meta)[0]
        n_l1_meta_features = len(l1_indices_meta)

        print(f"\n  --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---")
        print(f"    L1 combined best-meta features: {n_l1_meta_features}/{fold_total_features}")
        best_info = meta_best_info[fold_idx]
        for mod in modalities:
            print(f"      {mod}: {best_info[mod][0]} (acc={best_info[mod][1]*100:.1f}%)")

        X_train_l1_meta = X_train_norm[:, fold_l1_mask_meta]
        X_val_l1_meta   = X_val_norm[:, fold_l1_mask_meta]
        X_test_l1_meta  = X_test_norm[:, fold_l1_mask_meta]
        
        for opt_name, opt_func in EVOLOPY_OPTIMIZERS.items():
            method_name = f'meta_{opt_name}'
            print(f"\n  --- Layer 2: {method_name.upper()} ---")
            
            fs_start_time = time.time()
            fs_results = run_evolopy_optimizer_l2(
                opt_name, opt_func, 
                X_train_l1_meta, y_train, X_val_l1_meta, y_val, 
                num_classes, n_l1_meta_features
            )
            fs_time = time.time() - fs_start_time
            
            l2_mask_relative = fs_results['mask']

            # Final mask in fold space
            final_mask = np.zeros(fold_total_features, dtype=bool)
            final_mask[l1_indices_meta[l2_mask_relative]] = True

            X_train_sel = X_train_norm[:, final_mask]
            X_val_sel   = X_val_norm[:, final_mask]
            X_test_sel  = X_test_norm[:, final_mask]

            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)

            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()

            eval_metrics = train_and_evaluate_full(model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes)
            modality_ret = calculate_modality_retention(final_mask, fold_feature_dims)

            fold_result = {
                'fold': fold_idx, 'method': method_name,
                'l1_method': 'meta_best', 'l1_features': n_l1_meta_features,
                'l1_best_per_modality': {mod: {'method': best_info[mod][0], 'acc': best_info[mod][1]} for mod in modalities},
                'val_acc': eval_metrics['val_acc'], 'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'], 'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'], 'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(final_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(final_mask) / fold_total_features * 100),
                'modality_retention': modality_ret, 'feature_mask': final_mask,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'], 'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb, 'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            save_fold_result(fold_result, method_name, fold_idx)
            
            print(f"    L2 Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(final_mask)}/{fold_total_features} "
                  f"({np.sum(final_mask)/fold_total_features*100:.1f}%)")

            del model, train_dataset, val_dataset, test_dataset, train_loader, val_loader, test_loader
            torch.cuda.empty_cache(); gc.collect()

    print(f"\n{'='*80}")
    print("ALL LAYER 2 EXPERIMENTS COMPLETED")
    print(f"{'='*80}")

    return master_results

print("Layer 2 experiment runner defined")
# Out:
# Layer 2 experiment runner defined

# %% [markdown]
# ## Run Layer 2 Experiments

# %%
master_results = run_layer2_experiments()
# Out:
# ================================================================================
# STARTING LAYER 2 FEATURE SELECTION EXPERIMENTS
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- Layer 2: MUTUAL_INFO ---
#     L1 combined features: 1521/3043
#     Running Mutual Information (Layer 2)...
#       Selected: 760/1521 (50.0%), Time: 15.2s
#     L2 Test Acc: 98.25%, F1: 98.24%, Features: 760/3043 (25.0%)
#
#   --- Layer 2: RFE ---
#     L1 combined features: 1521/3043
#     Running RFE (Layer 2)...
#       Selected: 760/1521 (50.0%), Time: 2.5s
#     L2 Test Acc: 97.55%, F1: 97.54%, Features: 760/3043 (25.0%)
#
#   --- Layer 2: LASSO ---
#     L1 combined features: 1521/3043
#     Running LASSO (Layer 2)...
#       Selected: 760/1521 (50.0%), Time: 75.9s
#     L2 Test Acc: 91.96%, F1: 92.23%, Features: 760/3043 (25.0%)
#
#   --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---
#     L1 combined best-meta features: 1694/3043
#       depth: meta_HHO (acc=72.4%)
#       sensor: meta_GWO (acc=87.4%)
#       skeleton: meta_MVO (acc=97.9%)
#
#   --- Layer 2: META_BAT ---
#     Running EvoloPy BAT (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02888298570116755']
# ['At iteration 1 the best fitness is 0.028705890069526466']
# ['At iteration 2 the best fitness is 0.028705890069526466']
# ['At iteration 3 the best fitness is 0.028705890069526466']
# ['At iteration 4 the best fitness is 0.028705890069526466']
# ['At iteration 5 the best fitness is 0.028705890069526466']
# ['At iteration 6 the best fitness is 0.02861734225370592']
# ['At iteration 7 the best fitness is 0.02861734225370592']
# ['At iteration 8 the best fitness is 0.028528794437885377']
# ['At iteration 9 the best fitness is 0.028528794437885377']
# ['At iteration 10 the best fitness is 0.02849927849927853']
# ['At iteration 11 the best fitness is 0.028440246622064836']
# ['At iteration 12 the best fitness is 0.028440246622064836']
# ['At iteration 13 the best fitness is 0.02841073068345799']
# ['At iteration 14 the best fitness is 0.02838121474485114']
# ['At iteration 15 the best fitness is 0.02838121474485114']
# ['At iteration 16 the best fitness is 0.02838121474485114']
# ['At iteration 17 the best fitness is 0.02838121474485114']
# ['At iteration 18 the best fitness is 0.02838121474485114']
# ['At iteration 19 the best fitness is 0.02838121474485114']
# ['At iteration 20 the best fitness is 0.02838121474485114']
# ['At iteration 21 the best fitness is 0.02838121474485114']
# ['At iteration 22 the best fitness is 0.02838121474485114']
# ['At iteration 23 the best fitness is 0.02838121474485114']
# ['At iteration 24 the best fitness is 0.02838121474485114']
# ['At iteration 25 the best fitness is 0.02838121474485114']
# ['At iteration 26 the best fitness is 0.02838121474485114']
# ['At iteration 27 the best fitness is 0.02838121474485114']
# ['At iteration 28 the best fitness is 0.02838121474485114']
# ['At iteration 29 the best fitness is 0.02838121474485114']
#       Selected: 799/1694 (47.2%), Fitness: 0.0284, Time: 1011.7s
#     L2 Test Acc: 97.90%, F1: 97.89%, Features: 799/3043 (26.3%)
#
#   --- Layer 2: META_CS ---
#     Running EvoloPy CS (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02861734225370592']
# ['At iteration 1 the best fitness is 0.02861734225370592']
# ['At iteration 2 the best fitness is 0.02861734225370592']
# ['At iteration 3 the best fitness is 0.02849927849927853']
# ['At iteration 4 the best fitness is 0.02426210153482881']
# ['At iteration 5 the best fitness is 0.02426210153482881']
# ['At iteration 6 the best fitness is 0.02426210153482881']
# ['At iteration 7 the best fitness is 0.02426210153482881']
# ['At iteration 8 the best fitness is 0.02426210153482881']
# ['At iteration 9 the best fitness is 0.02426210153482881']
# ['At iteration 10 the best fitness is 0.02426210153482881']
# ['At iteration 11 the best fitness is 0.02426210153482881']
# ['At iteration 12 the best fitness is 0.02426210153482881']
# ['At iteration 13 the best fitness is 0.02426210153482881']
# ['At iteration 14 the best fitness is 0.02426210153482881']
# ['At iteration 15 the best fitness is 0.02426210153482881']
# ['At iteration 16 the best fitness is 0.02426210153482881']
# ['At iteration 17 the best fitness is 0.02426210153482881']
# ['At iteration 18 the best fitness is 0.02426210153482881']
# ['At iteration 19 the best fitness is 0.02426210153482881']
# ['At iteration 20 the best fitness is 0.02426210153482881']
# ['At iteration 21 the best fitness is 0.02426210153482881']
# ['At iteration 22 the best fitness is 0.02426210153482881']
# ['At iteration 23 the best fitness is 0.02426210153482881']
# ['At iteration 24 the best fitness is 0.02426210153482881']
# ['At iteration 25 the best fitness is 0.02426210153482881']
# ['At iteration 26 the best fitness is 0.02426210153482881']
# ['At iteration 27 the best fitness is 0.02426210153482881']
# ['At iteration 28 the best fitness is 0.02426210153482881']
# ['At iteration 29 the best fitness is 0.02426210153482881']
#       Selected: 822/1694 (48.5%), Fitness: 0.0243, Time: 1976.7s
#     L2 Test Acc: 97.20%, F1: 97.18%, Features: 822/3043 (27.0%)
#
#   --- Layer 2: META_DE ---
#     Running EvoloPy DE (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.028971533516988095']
# ['At iteration 2 the best fitness is 0.028942017578381246']
# ['At iteration 3 the best fitness is 0.028942017578381246']
# ['At iteration 4 the best fitness is 0.028735406008133315']
# ['At iteration 5 the best fitness is 0.028705890069526466']
# ['At iteration 6 the best fitness is 0.028322182867637446']
# ['At iteration 7 the best fitness is 0.028322182867637446']
# ['At iteration 8 the best fitness is 0.028174603174603206']
# ['At iteration 9 the best fitness is 0.028174603174603206']
# ['At iteration 10 the best fitness is 0.0276138003410731']
# ['At iteration 11 the best fitness is 0.0276138003410731']
# ['At iteration 12 the best fitness is 0.0276138003410731']
# ['At iteration 13 the best fitness is 0.024380165289256198']
# ['At iteration 14 the best fitness is 0.024380165289256198']
# ['At iteration 15 the best fitness is 0.024380165289256198']
# ['At iteration 16 the best fitness is 0.024380165289256198']
# ['At iteration 17 the best fitness is 0.024380165289256198']
# ['At iteration 18 the best fitness is 0.023317591499409682']
# ['At iteration 19 the best fitness is 0.023317591499409682']
# ['At iteration 20 the best fitness is 0.023317591499409682']
# ['At iteration 21 the best fitness is 0.023317591499409682']
# ['At iteration 22 the best fitness is 0.023317591499409682']
# ['At iteration 23 the best fitness is 0.022727272727272728']
# ['At iteration 24 the best fitness is 0.022727272727272728']
# ['At iteration 25 the best fitness is 0.022727272727272728']
# ['At iteration 26 the best fitness is 0.022727272727272728']
# ['At iteration 27 the best fitness is 0.022727272727272728']
# ['At iteration 28 the best fitness is 0.022727272727272728']
# ['At iteration 29 the best fitness is 0.022727272727272728']
# ['At iteration 30 the best fitness is 0.022727272727272728']
#       Selected: 770/1694 (45.5%), Fitness: 0.0227, Time: 1002.1s
#     L2 Test Acc: 96.85%, F1: 96.83%, Features: 770/3043 (25.3%)
#
#   --- Layer 2: META_FFA ---
#     Running EvoloPy FFA (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.028027023481568967']
# ['At iteration 1 the best fitness is 0.028735406008133315']
# ['At iteration 2 the best fitness is 0.028027023481568967']
# ['At iteration 3 the best fitness is 0.028027023481568967']
# ['At iteration 4 the best fitness is 0.027702348156893642']
# ['At iteration 5 the best fitness is 0.027525252525252557']
# ['At iteration 6 the best fitness is 0.022874852420306967']
# ['At iteration 7 the best fitness is 0.02725960907779093']
# ['At iteration 8 the best fitness is 0.027230093139184078']
# ['At iteration 9 the best fitness is 0.027230093139184078']
# ['At iteration 10 the best fitness is 0.027230093139184078']
# ['At iteration 11 the best fitness is 0.022933884297520662']
# ['At iteration 12 the best fitness is 0.022609208972845338']
# ['At iteration 13 the best fitness is 0.022638724911452187']
# ['At iteration 14 the best fitness is 0.022491145218417948']
# ['At iteration 15 the best fitness is 0.022491145218417948']
# ['At iteration 16 the best fitness is 0.027289125016397776']
# ['At iteration 17 the best fitness is 0.022491145218417948']
# ['At iteration 18 the best fitness is 0.022491145218417948']
# ['At iteration 19 the best fitness is 0.022491145218417948']
# ['At iteration 20 the best fitness is 0.022491145218417948']
# ['At iteration 21 the best fitness is 0.022520661157024793']
# ['At iteration 22 the best fitness is 0.022520661157024793']
# ['At iteration 23 the best fitness is 0.027318640955004622']
# ['At iteration 24 the best fitness is 0.027289125016397776']
# ['At iteration 25 the best fitness is 0.022491145218417948']
# ['At iteration 26 the best fitness is 0.022491145218417948']
# ['At iteration 27 the best fitness is 0.027289125016397776']
# ['At iteration 28 the best fitness is 0.022491145218417948']
# ['At iteration 29 the best fitness is 0.022491145218417948']
#       Selected: 762/1694 (45.0%), Fitness: 0.0225, Time: 966.7s
#     L2 Test Acc: 98.25%, F1: 98.26%, Features: 762/3043 (25.0%)
#
#   --- Layer 2: META_GA ---
#     Running EvoloPy GA (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.028823953823953856
# At iteration 2 the best fitness is 0.029119113210022335
# At iteration 3 the best fitness is 0.02900104945559494
# At iteration 4 the best fitness is 0.029178145087236027
# At iteration 5 the best fitness is 0.02926669290305657
# At iteration 6 the best fitness is 0.028823953823953856
# At iteration 7 the best fitness is 0.028676374130919616
# At iteration 8 the best fitness is 0.028528794437885377
# At iteration 9 the best fitness is 0.028292666929030597
# At iteration 10 the best fitness is 0.028528794437885377
# At iteration 11 the best fitness is 0.02835169880624429
# At iteration 12 the best fitness is 0.0237603305785124
# At iteration 13 the best fitness is 0.02811557129738951
# At iteration 14 the best fitness is 0.02811557129738951
# At iteration 15 the best fitness is 0.02790895972714158
# At iteration 16 the best fitness is 0.027407188770825167
# At iteration 17 the best fitness is 0.027407188770825167
# At iteration 18 the best fitness is 0.027407188770825167
# At iteration 19 the best fitness is 0.0276138003410731
# At iteration 20 the best fitness is 0.022963400236127512
# At iteration 21 the best fitness is 0.02746622064803886
# At iteration 22 the best fitness is 0.027200577200577232
# At iteration 23 the best fitness is 0.027200577200577232
# At iteration 24 the best fitness is 0.027200577200577232
# At iteration 25 the best fitness is 0.027171061261970386
# At iteration 26 the best fitness is 0.027171061261970386
# At iteration 27 the best fitness is 0.02696444969172245
# At iteration 28 the best fitness is 0.02696444969172245
# At iteration 29 the best fitness is 0.02696444969172245
# At iteration 30 the best fitness is 0.02696444969172245
#       Selected: 751/1694 (44.3%), Fitness: 0.0270, Time: 974.1s
#     L2 Test Acc: 98.60%, F1: 98.62%, Features: 751/3043 (24.7%)
#
#   --- Layer 2: META_GWO ---
#     Running EvoloPy GWO (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.028705890069526466']
# ['At iteration 1 the best fitness is 0.026787354060081366']
# ['At iteration 2 the best fitness is 0.022756788665879574']
# ['At iteration 3 the best fitness is 0.022756788665879574']
# ['At iteration 4 the best fitness is 0.022756788665879574']
# ['At iteration 5 the best fitness is 0.01959858323494687']
# ['At iteration 6 the best fitness is 0.018978748524203073']
# ['At iteration 7 the best fitness is 0.017886658795749705']
# ['At iteration 8 the best fitness is 0.017532467532467535']
# ['At iteration 9 the best fitness is 0.01697166469893743']
# ['At iteration 10 the best fitness is 0.016292798110979927']
# ['At iteration 11 the best fitness is 0.01617473435655254']
# ['At iteration 12 the best fitness is 0.015495867768595043']
# ['At iteration 13 the best fitness is 0.015495867768595043']
# ['At iteration 14 the best fitness is 0.014994096812278632']
# ['At iteration 15 the best fitness is 0.014492325855962222']
# ['At iteration 16 the best fitness is 0.014197166469893744']
# ['At iteration 17 the best fitness is 0.013842975206611572']
# ['At iteration 18 the best fitness is 0.013813459268004723']
# ['At iteration 19 the best fitness is 0.013518299881936247']
# ['At iteration 20 the best fitness is 0.013252656434474618']
# ['At iteration 21 the best fitness is 0.013046044864226683']
# ['At iteration 22 the best fitness is 0.012927981109799293']
# ['At iteration 23 the best fitness is 0.01283943329397875']
# ['At iteration 24 the best fitness is 0.012750885478158206']
# ['At iteration 25 the best fitness is 0.012691853600944512']
# ['At iteration 26 the best fitness is 0.012662337662337661']
# ['At iteration 27 the best fitness is 0.012426210153482881']
# ['At iteration 28 the best fitness is 0.012426210153482881']
# ['At iteration 29 the best fitness is 0.012337662337662338']
#       Selected: 418/1694 (24.7%), Fitness: 0.0123, Time: 1002.8s
#     L2 Test Acc: 96.15%, F1: 96.19%, Features: 418/3043 (13.7%)
#
#   --- Layer 2: META_HHO ---
#     Running EvoloPy HHO (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.0288534697625607']
# ['At iteration 1 the best fitness is 0.0276138003410731']
# ['At iteration 2 the best fitness is 0.02662665617211067']
# ['At iteration 3 the best fitness is 0.02235996326905421']
# ['At iteration 4 the best fitness is 0.01641414141414137']
# ['At iteration 5 the best fitness is 0.01641414141414137']
# ['At iteration 6 the best fitness is 0.01641414141414137']
# ['At iteration 7 the best fitness is 0.01641414141414137']
# ['At iteration 8 the best fitness is 0.01641414141414137']
# ['At iteration 9 the best fitness is 0.01641414141414137']
# ['At iteration 10 the best fitness is 0.01641414141414137']
# ['At iteration 11 the best fitness is 0.01641414141414137']
# ['At iteration 12 the best fitness is 0.012901744719926495']
# ['At iteration 13 the best fitness is 0.012901744719926495']
# ['At iteration 14 the best fitness is 0.012901744719926495']
# ['At iteration 15 the best fitness is 0.012901744719926495']
# ['At iteration 16 the best fitness is 0.012901744719926495']
# ['At iteration 17 the best fitness is 0.012872228781319647']
# ['At iteration 18 the best fitness is 0.012872228781319647']
# ['At iteration 19 the best fitness is 0.012872228781319647']
# ['At iteration 20 the best fitness is 0.012872228781319647']
# ['At iteration 21 the best fitness is 0.012872228781319647']
# ['At iteration 22 the best fitness is 0.01259018759018762']
# ['At iteration 23 the best fitness is 0.01247212383576023']
# ['At iteration 24 the best fitness is 0.011527613800341105']
# ['At iteration 25 the best fitness is 0.011527613800341105']
# ['At iteration 26 the best fitness is 0.011409550045913715']
# ['At iteration 27 the best fitness is 0.011409550045913715']
# ['At iteration 28 the best fitness is 0.01132100223009317']
# ['At iteration 29 the best fitness is 0.01132100223009317']
#       Selected: 221/1694 (13.0%), Fitness: 0.0113, Time: 1144.2s
#     L2 Test Acc: 96.50%, F1: 96.57%, Features: 221/3043 (7.3%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02861734225370592']
# ['At iteration 1 the best fitness is 0.028469762560671685']
# ['At iteration 2 the best fitness is 0.028469762560671685']
# ['At iteration 3 the best fitness is 0.028469762560671685']
# ['At iteration 4 the best fitness is 0.028469762560671685']
# ['At iteration 5 the best fitness is 0.028469762560671685']
# ['At iteration 6 the best fitness is 0.028027023481568967']
# ['At iteration 7 the best fitness is 0.028027023481568967']
# ['At iteration 8 the best fitness is 0.028027023481568967']
# ['At iteration 9 the best fitness is 0.028027023481568967']
# ['At iteration 10 the best fitness is 0.027938475665748426']
# ['At iteration 11 the best fitness is 0.027938475665748426']
# ['At iteration 12 the best fitness is 0.027879443788534727']
# ['At iteration 13 the best fitness is 0.027879443788534727']
# ['At iteration 14 the best fitness is 0.027879443788534727']
# ['At iteration 15 the best fitness is 0.02784992784992788']
# ['At iteration 16 the best fitness is 0.027643316279679947']
# ['At iteration 17 the best fitness is 0.027643316279679947']
# ['At iteration 18 the best fitness is 0.027643316279679947']
# ['At iteration 19 the best fitness is 0.027584284402466255']
# ['At iteration 20 the best fitness is 0.027407188770825167']
# ['At iteration 21 the best fitness is 0.027407188770825167']
# ['At iteration 22 the best fitness is 0.027407188770825167']
# ['At iteration 23 the best fitness is 0.027407188770825167']
# ['At iteration 24 the best fitness is 0.027407188770825167']
# ['At iteration 25 the best fitness is 0.027407188770825167']
# ['At iteration 26 the best fitness is 0.027407188770825167']
# ['At iteration 27 the best fitness is 0.027407188770825167']
# ['At iteration 28 the best fitness is 0.027407188770825167']
# ['At iteration 29 the best fitness is 0.027407188770825167']
#       Selected: 766/1694 (45.2%), Fitness: 0.0274, Time: 935.8s
#     L2 Test Acc: 97.55%, F1: 97.57%, Features: 766/3043 (25.2%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02906008133280864']
# ['At iteration 2 the best fitness is 0.02906008133280864']
# ['At iteration 3 the best fitness is 0.02906008133280864']
# ['At iteration 4 the best fitness is 0.02888298570116755']
# ['At iteration 5 the best fitness is 0.02888298570116755']
# ['At iteration 6 the best fitness is 0.02888298570116755']
# ['At iteration 7 the best fitness is 0.02888298570116755']
# ['At iteration 8 the best fitness is 0.02888298570116755']
# ['At iteration 9 the best fitness is 0.02888298570116755']
# ['At iteration 10 the best fitness is 0.0256198347107438']
# ['At iteration 11 the best fitness is 0.0256198347107438']
# ['At iteration 12 the best fitness is 0.0256198347107438']
# ['At iteration 13 the best fitness is 0.0256198347107438']
# ['At iteration 14 the best fitness is 0.0256198347107438']
# ['At iteration 15 the best fitness is 0.0256198347107438']
# ['At iteration 16 the best fitness is 0.0256198347107438']
# ['At iteration 17 the best fitness is 0.0256198347107438']
# ['At iteration 18 the best fitness is 0.0256198347107438']
# ['At iteration 19 the best fitness is 0.0256198347107438']
# ['At iteration 20 the best fitness is 0.0256198347107438']
# ['At iteration 21 the best fitness is 0.024144037780401417']
# ['At iteration 22 the best fitness is 0.024144037780401417']
# ['At iteration 23 the best fitness is 0.024144037780401417']
# ['At iteration 24 the best fitness is 0.024144037780401417']
# ['At iteration 25 the best fitness is 0.024144037780401417']
# ['At iteration 26 the best fitness is 0.024144037780401417']
# ['At iteration 27 the best fitness is 0.024144037780401417']
# ['At iteration 28 the best fitness is 0.024144037780401417']
# ['At iteration 29 the best fitness is 0.024144037780401417']
#       Selected: 818/1694 (48.3%), Fitness: 0.0241, Time: 877.4s
#     L2 Test Acc: 96.85%, F1: 96.85%, Features: 818/3043 (26.9%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.028971533516988095']
# ['At iteration 2 the best fitness is 0.028587826315099076']
# ['At iteration 3 the best fitness is 0.028587826315099076']
# ['At iteration 4 the best fitness is 0.028587826315099076']
# ['At iteration 5 the best fitness is 0.028440246622064836']
# ['At iteration 6 the best fitness is 0.028440246622064836']
# ['At iteration 7 the best fitness is 0.028292666929030597']
# ['At iteration 8 the best fitness is 0.028292666929030597']
# ['At iteration 9 the best fitness is 0.028233635051816905']
# ['At iteration 10 the best fitness is 0.028174603174603206']
# ['At iteration 11 the best fitness is 0.027702348156893642']
# ['At iteration 12 the best fitness is 0.027702348156893642']
# ['At iteration 13 the best fitness is 0.027289125016397776']
# ['At iteration 14 the best fitness is 0.023465171192443922']
# ['At iteration 15 the best fitness is 0.023465171192443922']
# ['At iteration 16 the best fitness is 0.023465171192443922']
# ['At iteration 17 the best fitness is 0.023465171192443922']
# ['At iteration 18 the best fitness is 0.023465171192443922']
# ['At iteration 19 the best fitness is 0.023465171192443922']
# ['At iteration 20 the best fitness is 0.023465171192443922']
# ['At iteration 21 the best fitness is 0.023465171192443922']
# ['At iteration 22 the best fitness is 0.023465171192443922']
# ['At iteration 23 the best fitness is 0.023465171192443922']
# ['At iteration 24 the best fitness is 0.023465171192443922']
# ['At iteration 25 the best fitness is 0.023465171192443922']
# ['At iteration 26 the best fitness is 0.023465171192443922']
# ['At iteration 27 the best fitness is 0.023465171192443922']
# ['At iteration 28 the best fitness is 0.023465171192443922']
# ['At iteration 29 the best fitness is 0.023465171192443922']
# ['At iteration 30 the best fitness is 0.023465171192443922']
#       Selected: 795/1694 (46.9%), Fitness: 0.0235, Time: 906.8s
#     L2 Test Acc: 98.25%, F1: 98.21%, Features: 795/3043 (26.1%)
#
#   --- Layer 2: META_PSO ---
#     Running EvoloPy PSO (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02826315099042375']
# ['At iteration 2 the best fitness is 0.02790895972714158']
# ['At iteration 3 the best fitness is 0.02790895972714158']
# ['At iteration 4 the best fitness is 0.02790895972714158']
# ['At iteration 5 the best fitness is 0.027790895972714186']
# ['At iteration 6 the best fitness is 0.0276138003410731']
# ['At iteration 7 the best fitness is 0.027318640955004622']
# ['At iteration 8 the best fitness is 0.027171061261970386']
# ['At iteration 9 the best fitness is 0.027171061261970386']
# ['At iteration 10 the best fitness is 0.027171061261970386']
# ['At iteration 11 the best fitness is 0.027171061261970386']
# ['At iteration 12 the best fitness is 0.027171061261970386']
# ['At iteration 13 the best fitness is 0.027171061261970386']
# ['At iteration 14 the best fitness is 0.027082513446149842']
# ['At iteration 15 the best fitness is 0.027082513446149842']
# ['At iteration 16 the best fitness is 0.027023481568936147']
# ['At iteration 17 the best fitness is 0.026669290305653973']
# ['At iteration 18 the best fitness is 0.026669290305653973']
# ['At iteration 19 the best fitness is 0.02658074248983343']
# ['At iteration 20 the best fitness is 0.026285583103764956']
# ['At iteration 21 the best fitness is 0.026285583103764956']
# ['At iteration 22 the best fitness is 0.026285583103764956']
# ['At iteration 23 the best fitness is 0.026285583103764956']
# ['At iteration 24 the best fitness is 0.026285583103764956']
# ['At iteration 25 the best fitness is 0.026256067165158107']
# ['At iteration 26 the best fitness is 0.026108487472123867']
# ['At iteration 27 the best fitness is 0.025901875901875933']
# ['At iteration 28 the best fitness is 0.025813328086055392']
# ['At iteration 29 the best fitness is 0.025813328086055392']
# ['At iteration 30 the best fitness is 0.025783812147448543']
#       Selected: 711/1694 (42.0%), Fitness: 0.0258, Time: 900.7s
#     L2 Test Acc: 97.90%, F1: 97.89%, Features: 711/3043 (23.4%)
#
#   --- Layer 2: META_SCA ---
#     Running EvoloPy SCA (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02941427259609081']
# ['At iteration 1 the best fitness is 0.025783812147448543']
# ['At iteration 2 the best fitness is 0.025311557129738982']
# ['At iteration 3 the best fitness is 0.022418995146267905']
# ['At iteration 4 the best fitness is 0.02200577200577204']
# ['At iteration 5 the best fitness is 0.0192607897153352']
# ['At iteration 6 the best fitness is 0.0192607897153352']
# ['At iteration 7 the best fitness is 0.013547815820543095']
# ['At iteration 8 the best fitness is 0.013547815820543095']
# ['At iteration 9 the best fitness is 0.013547815820543095']
# ['At iteration 10 the best fitness is 0.013547815820543095']
# ['At iteration 11 the best fitness is 0.013547815820543095']
# ['At iteration 12 the best fitness is 0.013547815820543095']
# ['At iteration 13 the best fitness is 0.010448642266824085']
# ['At iteration 14 the best fitness is 0.009386068476977568']
# ['At iteration 15 the best fitness is 0.008293978748524203']
# ['At iteration 16 the best fitness is 0.008293978748524203']
# ['At iteration 17 the best fitness is 0.007378984651711925']
# ['At iteration 18 the best fitness is 0.007378984651711925']
# ['At iteration 19 the best fitness is 0.007378984651711925']
# ['At iteration 20 the best fitness is 0.007378984651711925']
# ['At iteration 21 the best fitness is 0.006316410861865407']
# ['At iteration 22 the best fitness is 0.006316410861865407']
# ['At iteration 23 the best fitness is 0.006316410861865407']
# ['At iteration 24 the best fitness is 0.006316410861865407']
# ['At iteration 25 the best fitness is 0.006316410861865407']
# ['At iteration 26 the best fitness is 0.006316410861865407']
# ['At iteration 27 the best fitness is 0.006316410861865407']
# ['At iteration 28 the best fitness is 0.006316410861865407']
# ['At iteration 29 the best fitness is 0.006316410861865407']
#       Selected: 214/1694 (12.6%), Fitness: 0.0063, Time: 930.0s
#     L2 Test Acc: 96.15%, F1: 96.12%, Features: 214/3043 (7.0%)
#
#   --- Layer 2: META_SSA ---
#     Running EvoloPy SSA (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02426210153482881']
# ['At iteration 2 the best fitness is 0.02426210153482881']
# ['At iteration 3 the best fitness is 0.02426210153482881']
# ['At iteration 4 the best fitness is 0.02426210153482881']
# ['At iteration 5 the best fitness is 0.02426210153482881']
# ['At iteration 6 the best fitness is 0.02426210153482881']
# ['At iteration 7 the best fitness is 0.02426210153482881']
# ['At iteration 8 the best fitness is 0.02426210153482881']
# ['At iteration 9 the best fitness is 0.02426210153482881']
# ['At iteration 10 the best fitness is 0.02426210153482881']
# ['At iteration 11 the best fitness is 0.02426210153482881']
# ['At iteration 12 the best fitness is 0.02426210153482881']
# ['At iteration 13 the best fitness is 0.02426210153482881']
# ['At iteration 14 the best fitness is 0.02426210153482881']
# ['At iteration 15 the best fitness is 0.02426210153482881']
# ['At iteration 16 the best fitness is 0.02426210153482881']
# ['At iteration 17 the best fitness is 0.02426210153482881']
# ['At iteration 18 the best fitness is 0.02426210153482881']
# ['At iteration 19 the best fitness is 0.02426210153482881']
# ['At iteration 20 the best fitness is 0.02426210153482881']
# ['At iteration 21 the best fitness is 0.02426210153482881']
# ['At iteration 22 the best fitness is 0.02426210153482881']
# ['At iteration 23 the best fitness is 0.02426210153482881']
# ['At iteration 24 the best fitness is 0.02426210153482881']
# ['At iteration 25 the best fitness is 0.02426210153482881']
# ['At iteration 26 the best fitness is 0.02426210153482881']
# ['At iteration 27 the best fitness is 0.02426210153482881']
# ['At iteration 28 the best fitness is 0.02426210153482881']
# ['At iteration 29 the best fitness is 0.02426210153482881']
#       Selected: 822/1694 (48.5%), Fitness: 0.0243, Time: 2269.8s
#     L2 Test Acc: 96.85%, F1: 96.86%, Features: 822/3043 (27.0%)
#
#   --- Layer 2: META_WOA ---
#     Running EvoloPy WOA (Layer 2)...
#       Features: 1694, Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02900104945559494']
# ['At iteration 1 the best fitness is 0.019083694083694112']
# ['At iteration 2 the best fitness is 0.019083694083694112']
# ['At iteration 3 the best fitness is 0.019083694083694112']
# ['At iteration 4 the best fitness is 0.019083694083694112']
# ['At iteration 5 the best fitness is 0.01697166469893743']
# ['At iteration 6 the best fitness is 0.01697166469893743']
# ['At iteration 7 the best fitness is 0.01697166469893743']
# ['At iteration 8 the best fitness is 0.01697166469893743']
# ['At iteration 9 the best fitness is 0.01697166469893743']
# ['At iteration 10 the best fitness is 0.016735537190082646']
# ['At iteration 11 the best fitness is 0.016735537190082646']
# ['At iteration 12 the best fitness is 0.016735537190082646']
# ['At iteration 13 the best fitness is 0.016735537190082646']
# ['At iteration 14 the best fitness is 0.016735537190082646']
# ['At iteration 15 the best fitness is 0.016735537190082646']
# ['At iteration 16 the best fitness is 0.016735537190082646']
# ['At iteration 17 the best fitness is 0.016735537190082646']
# ['At iteration 18 the best fitness is 0.016735537190082646']
# ['At iteration 19 the best fitness is 0.016735537190082646']
# ['At iteration 20 the best fitness is 0.016735537190082646']
# ['At iteration 21 the best fitness is 0.016735537190082646']
# ['At iteration 22 the best fitness is 0.016086186540731996']
# ['At iteration 23 the best fitness is 0.016086186540731996']
# ['At iteration 24 the best fitness is 0.016086186540731996']
# ['At iteration 25 the best fitness is 0.016086186540731996']
# ['At iteration 26 the best fitness is 0.014817001180637543']
# ['At iteration 27 the best fitness is 0.014698937426210154']
# ['At iteration 28 the best fitness is 0.014698937426210154']
# ['At iteration 29 the best fitness is 0.014698937426210154']
#       Selected: 498/1694 (29.4%), Fitness: 0.0147, Time: 894.0s
#     L2 Test Acc: 97.55%, F1: 97.57%, Features: 498/3043 (16.4%)
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- Layer 2: MUTUAL_INFO ---
#     L1 combined features: 1521/3043
#     Running Mutual Information (Layer 2)...
#       Selected: 760/1521 (50.0%), Time: 15.6s
#     L2 Test Acc: 92.95%, F1: 93.35%, Features: 760/3043 (25.0%)
#
#   --- Layer 2: RFE ---
#     L1 combined features: 1521/3043
#     Running RFE (Layer 2)...
#       Selected: 760/1521 (50.0%), Time: 2.3s
#     L2 Test Acc: 93.36%, F1: 93.67%, Features: 760/3043 (25.0%)
#
#   --- Layer 2: LASSO ---
#     L1 combined features: 1521/3043
#     Running LASSO (Layer 2)...
#       Selected: 760/1521 (50.0%), Time: 79.7s
#     L2 Test Acc: 92.12%, F1: 92.05%, Features: 760/3043 (25.0%)
#
#   --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---
#     L1 combined best-meta features: 2024/3043
#       depth: meta_WOA (acc=75.1%)
#       sensor: meta_DE (acc=89.2%)
#       skeleton: meta_HHO (acc=88.0%)
#
#   --- Layer 2: META_BAT ---
#     Running EvoloPy BAT (Layer 2)...
#       Features: 2024, Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024209486166007904']
# ['At iteration 1 the best fitness is 0.02391304347826087']
# ['At iteration 2 the best fitness is 0.023789525691699606']
# ['At iteration 3 the best fitness is 0.023764822134387353']
# ['At iteration 4 the best fitness is 0.023764822134387353']
# ['At iteration 5 the best fitness is 0.02356719367588933']
# ['At iteration 6 the best fitness is 0.023542490118577078']
# ['At iteration 7 the best fitness is 0.023542490118577078']
# ['At iteration 8 the best fitness is 0.023542490118577078']
# ['At iteration 9 the best fitness is 0.023517786561264825']
# ['At iteration 10 the best fitness is 0.023517786561264825']
# ['At iteration 11 the best fitness is 0.023517786561264825']
# ['At iteration 12 the best fitness is 0.023517786561264825']
# ['At iteration 13 the best fitness is 0.023517786561264825']
# ['At iteration 14 the best fitness is 0.023517786561264825']
# ['At iteration 15 the best fitness is 0.023517786561264825']
# ['At iteration 16 the best fitness is 0.023517786561264825']
# ['At iteration 17 the best fitness is 0.023517786561264825']
# ['At iteration 18 the best fitness is 0.023517786561264825']
# ['At iteration 19 the best fitness is 0.023517786561264825']
# ['At iteration 20 the best fitness is 0.023517786561264825']
# ['At iteration 21 the best fitness is 0.023517786561264825']
# ['At iteration 22 the best fitness is 0.023517786561264825']
# ['At iteration 23 the best fitness is 0.023517786561264825']
# ['At iteration 24 the best fitness is 0.023517786561264825']
# ['At iteration 25 the best fitness is 0.023517786561264825']
# ['At iteration 26 the best fitness is 0.023517786561264825']
# ['At iteration 27 the best fitness is 0.023517786561264825']
# ['At iteration 28 the best fitness is 0.023517786561264825']
# ['At iteration 29 the best fitness is 0.023517786561264825']
#       Selected: 952/2024 (47.0%), Fitness: 0.0235, Time: 978.9s
#     L2 Test Acc: 91.29%, F1: 91.47%, Features: 952/3043 (31.3%)
#
#   --- Layer 2: META_CS ---
#     Running EvoloPy CS (Layer 2)...
#       Features: 2024, Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02401185770750988']
# ['At iteration 1 the best fitness is 0.02401185770750988']
# ['At iteration 2 the best fitness is 0.02401185770750988']
# ['At iteration 3 the best fitness is 0.023888339920948617']
# ['At iteration 4 the best fitness is 0.023888339920948617']
# ['At iteration 5 the best fitness is 0.023888339920948617']
# ['At iteration 6 the best fitness is 0.023789525691699606']
# ['At iteration 7 the best fitness is 0.023789525691699606']
# ['At iteration 8 the best fitness is 0.023789525691699606']
# ['At iteration 9 the best fitness is 0.023789525691699606']
# ['At iteration 10 the best fitness is 0.023789525691699606']
# ['At iteration 11 the best fitness is 0.023789525691699606']
# ['At iteration 12 the best fitness is 0.023690711462450595']
# ['At iteration 13 the best fitness is 0.023690711462450595']
# ['At iteration 14 the best fitness is 0.023690711462450595']
# ['At iteration 15 the best fitness is 0.023591897233201584']
# ['At iteration 16 the best fitness is 0.023591897233201584']
# ['At iteration 17 the best fitness is 0.023591897233201584']
# ['At iteration 18 the best fitness is 0.023591897233201584']
# ['At iteration 19 the best fitness is 0.023591897233201584']
# ['At iteration 20 the best fitness is 0.023591897233201584']
# ['At iteration 21 the best fitness is 0.02356719367588933']
# ['At iteration 22 the best fitness is 0.023270750988142293']
# ['At iteration 23 the best fitness is 0.023270750988142293']
# ['At iteration 24 the best fitness is 0.023097826086956524']
# ['At iteration 25 the best fitness is 0.023097826086956524']
# ['At iteration 26 the best fitness is 0.023097826086956524']
# ['At iteration 27 the best fitness is 0.023097826086956524']
# ['At iteration 28 the best fitness is 0.023097826086956524']
# ['At iteration 29 the best fitness is 0.023097826086956524']
#       Selected: 935/2024 (46.2%), Fitness: 0.0231, Time: 1929.1s
#     L2 Test Acc: 92.12%, F1: 92.54%, Features: 935/3043 (30.7%)
#
#   --- Layer 2: META_DE ---
#     Running EvoloPy DE (Layer 2)...
#       Features: 2024, Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024036561264822134']
# ['At iteration 2 the best fitness is 0.024036561264822134']
# ['At iteration 3 the best fitness is 0.02398715415019763']
# ['At iteration 4 the best fitness is 0.023418972332015814']
# ['At iteration 5 the best fitness is 0.023418972332015814']
# ['At iteration 6 the best fitness is 0.023418972332015814']
# ['At iteration 7 the best fitness is 0.023369565217391308']
# ['At iteration 8 the best fitness is 0.023369565217391308']
# ['At iteration 9 the best fitness is 0.023295454545454546']
# ['At iteration 10 the best fitness is 0.02314723320158103']
# ['At iteration 11 the best fitness is 0.023048418972332018']
# ['At iteration 12 the best fitness is 0.022776679841897234']
# ['At iteration 13 the best fitness is 0.022776679841897234']
# ['At iteration 14 the best fitness is 0.02257905138339921']
# ['At iteration 15 the best fitness is 0.02238142292490119']
# ['At iteration 16 the best fitness is 0.02238142292490119']
# ['At iteration 17 the best fitness is 0.02238142292490119']
# ['At iteration 18 the best fitness is 0.02238142292490119']
# ['At iteration 19 the best fitness is 0.022356719367588936']
# ['At iteration 20 the best fitness is 0.022134387351778657']
# ['At iteration 21 the best fitness is 0.022134387351778657']
# ['At iteration 22 the best fitness is 0.022134387351778657']
# ['At iteration 23 the best fitness is 0.02176383399209486']
# ['At iteration 24 the best fitness is 0.02176383399209486']
# ['At iteration 25 the best fitness is 0.02176383399209486']
# ['At iteration 26 the best fitness is 0.021689723320158102']
# ['At iteration 27 the best fitness is 0.021689723320158102']
# ['At iteration 28 the best fitness is 0.02141798418972332']
# ['At iteration 29 the best fitness is 0.02124505928853755']
# ['At iteration 30 the best fitness is 0.02097332015810277']
#       Selected: 849/2024 (41.9%), Fitness: 0.0210, Time: 976.9s
#     L2 Test Acc: 90.87%, F1: 91.04%, Features: 849/3043 (27.9%)
#
#   --- Layer 2: META_FFA ---
#     Running EvoloPy FFA (Layer 2)...
#       Features: 2024, Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02398715415019763']
# ['At iteration 1 the best fitness is 0.023937747035573123']
# ['At iteration 2 the best fitness is 0.023888339920948617']
# ['At iteration 3 the best fitness is 0.023443675889328067']
# ['At iteration 4 the best fitness is 0.023443675889328067']
# ['At iteration 5 the best fitness is 0.023344861660079055']
# ['At iteration 6 the best fitness is 0.023344861660079055']
# ['At iteration 7 the best fitness is 0.023344861660079055']
# ['At iteration 8 the best fitness is 0.023344861660079055']
# ['At iteration 9 the best fitness is 0.023196640316205535']
# ['At iteration 10 the best fitness is 0.023196640316205535']
# ['At iteration 11 the best fitness is 0.02307312252964427']
# ['At iteration 12 the best fitness is 0.022949604743083007']
# ['At iteration 13 the best fitness is 0.022949604743083007']
# ['At iteration 14 the best fitness is 0.022949604743083007']
# ['At iteration 15 the best fitness is 0.022949604743083007']
# ['At iteration 16 the best fitness is 0.0229001976284585']
# ['At iteration 17 the best fitness is 0.022850790513833995']
# ['At iteration 18 the best fitness is 0.022850790513833995']
# ['At iteration 19 the best fitness is 0.022850790513833995']
# ['At iteration 20 the best fitness is 0.022850790513833995']
# ['At iteration 21 the best fitness is 0.022850790513833995']
# ['At iteration 22 the best fitness is 0.022850790513833995']
# ['At iteration 23 the best fitness is 0.022850790513833995']
# ['At iteration 24 the best fitness is 0.022850790513833995']
# ['At iteration 25 the best fitness is 0.022850790513833995']
# ['At iteration 26 the best fitness is 0.022850790513833995']
# ['At iteration 27 the best fitness is 0.022850790513833995']
# ['At iteration 28 the best fitness is 0.022850790513833995']
# ['At iteration 29 the best fitness is 0.022850790513833995']
#       Selected: 925/2024 (45.7%), Fitness: 0.0229, Time: 944.4s
#     L2 Test Acc: 90.87%, F1: 90.96%, Features: 925/3043 (30.4%)
#
#   --- Layer 2: META_GA ---
#     Running EvoloPy GA (Layer 2)...
#       Features: 2024, Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024876482213438737
# At iteration 2 the best fitness is 0.024876482213438737
# At iteration 3 the best fitness is 0.024876482213438737
# At iteration 4 the best fitness is 0.024876482213438737
# At iteration 5 the best fitness is 0.024876482213438737
# At iteration 6 the best fitness is 0.024876482213438737
# At iteration 7 the best fitness is 0.024876482213438737
# At iteration 8 the best fitness is 0.024876482213438737
# At iteration 9 the best fitness is 0.024555335968379447
# At iteration 10 the best fitness is 0.024555335968379447
# At iteration 11 the best fitness is 0.024555335968379447
# At iteration 12 the best fitness is 0.024555335968379447
# At iteration 13 the best fitness is 0.0245800395256917
# At iteration 14 the best fitness is 0.02440711462450593
# At iteration 15 the best fitness is 0.024382411067193677
# At iteration 16 the best fitness is 0.024382411067193677
# At iteration 17 the best fitness is 0.024382411067193677
# At iteration 18 the best fitness is 0.024209486166007904
# At iteration 19 the best fitness is 0.024209486166007904
# At iteration 20 the best fitness is 0.024209486166007904
# At iteration 21 the best fitness is 0.02418478260869565
# At iteration 22 the best fitness is 0.02418478260869565
# At iteration 23 the best fitness is 0.02418478260869565
# At iteration 24 the best fitness is 0.02418478260869565
# At iteration 25 the best fitness is 0.024061264822134387
# At iteration 26 the best fitness is 0.02401185770750988
# At iteration 27 the best fitness is 0.02391304347826087
# At iteration 28 the best fitness is 0.02391304347826087
# At iteration 29 the best fitness is 0.023962450592885376
# At iteration 30 the best fitness is 0.02391304347826087
#       Selected: 968/2024 (47.8%), Fitness: 0.0239, Time: 948.8s
#     L2 Test Acc: 89.63%, F1: 89.73%, Features: 968/3043 (31.8%)
#
#   --- Layer 2: META_GWO ---
#     Running EvoloPy GWO (Layer 2)...
#       Features: 2024, Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02440711462450593']
# ['At iteration 1 the best fitness is 0.023616600790513836']
# ['At iteration 2 the best fitness is 0.022776679841897234']
# ['At iteration 3 the best fitness is 0.020948616600790518']
# ['At iteration 4 the best fitness is 0.020009881422924904']
# ['At iteration 5 the best fitness is 0.018651185770750988']
# ['At iteration 6 the best fitness is 0.0179100790513834']
# ['At iteration 7 the best fitness is 0.017045454545454544']
# ['At iteration 8 the best fitness is 0.01608201581027668']
# ['At iteration 9 the best fitness is 0.015513833992094862']
# ['At iteration 10 the best fitness is 0.014649209486166007']
# ['At iteration 11 the best fitness is 0.014426877470355731']
# ['At iteration 12 the best fitness is 0.014056324110671937']
# ['At iteration 13 the best fitness is 0.01341403162055336']
# ['At iteration 14 the best fitness is 0.012944664031620555']
# ['At iteration 15 the best fitness is 0.012623517786561265']
# ['At iteration 16 the best fitness is 0.012475296442687748']
# ['At iteration 17 the best fitness is 0.011857707509881424']
# ['At iteration 18 the best fitness is 0.011808300395256918']
# ['At iteration 19 the best fitness is 0.011808300395256918']
# ['At iteration 20 the best fitness is 0.011610671936758894']
# ['At iteration 21 the best fitness is 0.011437747035573124']
# ['At iteration 22 the best fitness is 0.011437747035573124']
# ['At iteration 23 the best fitness is 0.011338932806324111']
# ['At iteration 24 the best fitness is 0.011141304347826087']
# ['At iteration 25 the best fitness is 0.010968379446640317']
# ['At iteration 26 the best fitness is 0.01091897233201581']
# ['At iteration 27 the best fitness is 0.010844861660079051']
# ['At iteration 28 the best fitness is 0.010844861660079051']
# ['At iteration 29 the best fitness is 0.010820158102766798']
#       Selected: 438/2024 (21.6%), Fitness: 0.0108, Time: 958.2s
#     L2 Test Acc: 89.63%, F1: 89.91%, Features: 438/3043 (14.4%)
#
#   --- Layer 2: META_HHO ---
#     Running EvoloPy HHO (Layer 2)...
#       Features: 2024, Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.024555335968379447']
# ['At iteration 1 the best fitness is 0.02209595959595955']
# ['At iteration 2 the best fitness is 0.016309837505489713']
# ['At iteration 3 the best fitness is 0.016309837505489713']
# ['At iteration 4 the best fitness is 0.016309837505489713']
# ['At iteration 5 the best fitness is 0.016309837505489713']
# ['At iteration 6 the best fitness is 0.014426877470355731']
# ['At iteration 7 the best fitness is 0.014426877470355731']
# ['At iteration 8 the best fitness is 0.014426877470355731']
# ['At iteration 9 the best fitness is 0.014402173913043478']
# ['At iteration 10 the best fitness is 0.00923913043478261']
# ['At iteration 11 the best fitness is 0.007682806324110673']
# ['At iteration 12 the best fitness is 0.007089920948616601']
# ['At iteration 13 the best fitness is 0.005410079051383399']
# ['At iteration 14 the best fitness is 0.005410079051383399']
# ['At iteration 15 the best fitness is 0.005410079051383399']
# ['At iteration 16 the best fitness is 0.005410079051383399']
# ['At iteration 17 the best fitness is 0.005410079051383399']
# ['At iteration 18 the best fitness is 0.005335968379446641']
# ['At iteration 19 the best fitness is 0.00516304347826087']
# ['At iteration 20 the best fitness is 0.00516304347826087']
# ['At iteration 21 the best fitness is 0.00516304347826087']
# ['At iteration 22 the best fitness is 0.00516304347826087']
# ['At iteration 23 the best fitness is 0.00516304347826087']
# ['At iteration 24 the best fitness is 0.00516304347826087']
# ['At iteration 25 the best fitness is 0.005138339920948617']
# ['At iteration 26 the best fitness is 0.005138339920948617']
# ['At iteration 27 the best fitness is 0.005138339920948617']
# ['At iteration 28 the best fitness is 0.005138339920948617']
# ['At iteration 29 the best fitness is 0.005138339920948617']
#       Selected: 208/2024 (10.3%), Fitness: 0.0051, Time: 1321.3s
#     L2 Test Acc: 90.87%, F1: 90.86%, Features: 208/3043 (6.8%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 2024, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023937747035573123']
# ['At iteration 1 the best fitness is 0.023937747035573123']
# ['At iteration 2 the best fitness is 0.023937747035573123']
# ['At iteration 3 the best fitness is 0.023937747035573123']
# ['At iteration 4 the best fitness is 0.023937747035573123']
# ['At iteration 5 the best fitness is 0.023937747035573123']
# ['At iteration 6 the best fitness is 0.023937747035573123']
# ['At iteration 7 the best fitness is 0.023690711462450595']
# ['At iteration 8 the best fitness is 0.023690711462450595']
# ['At iteration 9 the best fitness is 0.023690711462450595']
# ['At iteration 10 the best fitness is 0.023690711462450595']
# ['At iteration 11 the best fitness is 0.023690711462450595']
# ['At iteration 12 the best fitness is 0.023666007905138342']
# ['At iteration 13 the best fitness is 0.02364130434782609']
# ['At iteration 14 the best fitness is 0.02364130434782609']
# ['At iteration 15 the best fitness is 0.02356719367588933']
# ['At iteration 16 the best fitness is 0.02356719367588933']
# ['At iteration 17 the best fitness is 0.02356719367588933']
# ['At iteration 18 the best fitness is 0.02356719367588933']
# ['At iteration 19 the best fitness is 0.02356719367588933']
# ['At iteration 20 the best fitness is 0.023369565217391308']
# ['At iteration 21 the best fitness is 0.023369565217391308']
# ['At iteration 22 the best fitness is 0.023369565217391308']
# ['At iteration 23 the best fitness is 0.023369565217391308']
# ['At iteration 24 the best fitness is 0.023369565217391308']
# ['At iteration 25 the best fitness is 0.023369565217391308']
# ['At iteration 26 the best fitness is 0.023369565217391308']
# ['At iteration 27 the best fitness is 0.023369565217391308']
# ['At iteration 28 the best fitness is 0.023320158102766803']
# ['At iteration 29 the best fitness is 0.02307312252964427']
#       Selected: 934/2024 (46.1%), Fitness: 0.0231, Time: 976.8s
#     L2 Test Acc: 91.70%, F1: 91.84%, Features: 934/3043 (30.7%)
#
# ...
# ['At iteration 7 the best fitness is 0.06569663700586556']
# ['At iteration 8 the best fitness is 0.06547000811068143']
# ['At iteration 9 the best fitness is 0.06547000811068143']
# ['At iteration 10 the best fitness is 0.06547000811068143']
# ['At iteration 11 the best fitness is 0.06547000811068143']
# ['At iteration 12 the best fitness is 0.06547000811068143']
# ['At iteration 13 the best fitness is 0.06547000811068143']
# ['At iteration 14 the best fitness is 0.06152809939698849']
# ['At iteration 15 the best fitness is 0.06152809939698849']
# ['At iteration 16 the best fitness is 0.06152809939698849']
# ['At iteration 17 the best fitness is 0.06152809939698849']
# ['At iteration 18 the best fitness is 0.06152809939698849']
# ['At iteration 19 the best fitness is 0.06152809939698849']
# ['At iteration 20 the best fitness is 0.06152809939698849']
# ['At iteration 21 the best fitness is 0.06152809939698849']
# ['At iteration 22 the best fitness is 0.06152809939698849']
# ['At iteration 23 the best fitness is 0.06152809939698849']
# ['At iteration 24 the best fitness is 0.06152809939698849']
# ['At iteration 25 the best fitness is 0.06152809939698849']
# ['At iteration 26 the best fitness is 0.06152809939698849']
# ['At iteration 27 the best fitness is 0.06152809939698849']
# ['At iteration 28 the best fitness is 0.06152809939698849']
# ['At iteration 29 the best fitness is 0.06152809939698849']
#       Selected: 363/1765 (20.6%), Fitness: 0.0615, Time: 994.8s
#     L2 Test Acc: 99.49%, F1: 99.49%, Features: 363/3043 (11.9%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 1765, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08031420074524234']
# ['At iteration 1 the best fitness is 0.08031420074524234']
# ['At iteration 2 the best fitness is 0.08031420074524234']
# ['At iteration 3 the best fitness is 0.08031420074524234']
# ['At iteration 4 the best fitness is 0.08031420074524234']
# ['At iteration 5 the best fitness is 0.08031420074524234']
# ['At iteration 6 the best fitness is 0.08031420074524234']
# ['At iteration 7 the best fitness is 0.08031420074524234']
# ['At iteration 8 the best fitness is 0.08031420074524234']
# ['At iteration 9 the best fitness is 0.08031420074524234']
# ['At iteration 10 the best fitness is 0.08031420074524234']
# ['At iteration 11 the best fitness is 0.08031420074524234']
# ['At iteration 12 the best fitness is 0.08031420074524234']
# ['At iteration 13 the best fitness is 0.08014422907385424']
# ['At iteration 14 the best fitness is 0.08014422907385424']
# ['At iteration 15 the best fitness is 0.08014422907385424']
# ['At iteration 16 the best fitness is 0.08014422907385424']
# ['At iteration 17 the best fitness is 0.08014422907385424']
# ['At iteration 18 the best fitness is 0.079747628507282']
# ['At iteration 19 the best fitness is 0.079747628507282']
# ['At iteration 20 the best fitness is 0.079747628507282']
# ['At iteration 21 the best fitness is 0.079747628507282']
# ['At iteration 22 the best fitness is 0.079747628507282']
# ['At iteration 23 the best fitness is 0.079747628507282']
# ['At iteration 24 the best fitness is 0.079747628507282']
# ['At iteration 25 the best fitness is 0.079747628507282']
# ['At iteration 26 the best fitness is 0.07971929989538398']
# ['At iteration 27 the best fitness is 0.07971929989538398']
# ['At iteration 28 the best fitness is 0.07971929989538398']
# ['At iteration 29 the best fitness is 0.07971929989538398']
#       Selected: 866/1765 (49.1%), Fitness: 0.0797, Time: 748.1s
#     L2 Test Acc: 97.98%, F1: 97.94%, Features: 866/3043 (28.5%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 1765, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08368953722097493']
# ['At iteration 2 the best fitness is 0.08133403077357095']
# ['At iteration 3 the best fitness is 0.07730713622418396']
# ['At iteration 4 the best fitness is 0.07730713622418396']
# ['At iteration 5 the best fitness is 0.07730713622418396']
# ['At iteration 6 the best fitness is 0.07730713622418396']
# ['At iteration 7 the best fitness is 0.07730713622418396']
# ['At iteration 8 the best fitness is 0.07730713622418396']
# ['At iteration 9 the best fitness is 0.0771938217765919']
# ['At iteration 10 the best fitness is 0.07671223537432562']
# ['At iteration 11 the best fitness is 0.07671223537432562']
# ['At iteration 12 the best fitness is 0.07671223537432562']
# ['At iteration 13 the best fitness is 0.07671223537432562']
# ['At iteration 14 the best fitness is 0.07620232036016131']
# ['At iteration 15 the best fitness is 0.07620232036016131']
# ['At iteration 16 the best fitness is 0.07620232036016131']
# ['At iteration 17 the best fitness is 0.07291196972012276']
# ['At iteration 18 the best fitness is 0.07291196972012276']
# ['At iteration 19 the best fitness is 0.07291196972012276']
# ['At iteration 20 the best fitness is 0.07291196972012276']
# ['At iteration 21 the best fitness is 0.07291196972012276']
# ['At iteration 22 the best fitness is 0.07291196972012276']
# ['At iteration 23 the best fitness is 0.07291196972012276']
# ['At iteration 24 the best fitness is 0.07291196972012276']
# ['At iteration 25 the best fitness is 0.07291196972012276']
# ['At iteration 26 the best fitness is 0.07291196972012276']
# ['At iteration 27 the best fitness is 0.07291196972012276']
# ['At iteration 28 the best fitness is 0.07291196972012276']
# ['At iteration 29 the best fitness is 0.07291196972012276']
#       Selected: 904/1765 (51.2%), Fitness: 0.0729, Time: 703.4s
#     L2 Test Acc: 98.48%, F1: 98.48%, Features: 904/3043 (29.7%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 1765, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08354789416148484']
# ['At iteration 2 the best fitness is 0.0796059854477919']
# ['At iteration 3 the best fitness is 0.0796059854477919']
# ['At iteration 4 the best fitness is 0.0796059854477919']
# ['At iteration 5 the best fitness is 0.0789260987622395']
# ['At iteration 6 the best fitness is 0.0789260987622395']
# ['At iteration 7 the best fitness is 0.0789260987622395']
# ['At iteration 8 the best fitness is 0.0789260987622395']
# ['At iteration 9 the best fitness is 0.0789260987622395']
# ['At iteration 10 the best fitness is 0.0789260987622395']
# ['At iteration 11 the best fitness is 0.0789260987622395']
# ['At iteration 12 the best fitness is 0.0789260987622395']
# ['At iteration 13 the best fitness is 0.0789260987622395']
# ['At iteration 14 the best fitness is 0.0789260987622395']
# ['At iteration 15 the best fitness is 0.0789260987622395']
# ['At iteration 16 the best fitness is 0.0789260987622395']
# ['At iteration 17 the best fitness is 0.0789260987622395']
# ['At iteration 18 the best fitness is 0.0789260987622395']
# ['At iteration 19 the best fitness is 0.0789260987622395']
# ['At iteration 20 the best fitness is 0.0789260987622395']
# ['At iteration 21 the best fitness is 0.0789260987622395']
# ['At iteration 22 the best fitness is 0.0789260987622395']
# ['At iteration 23 the best fitness is 0.0789260987622395']
# ['At iteration 24 the best fitness is 0.07889777015034148']
# ['At iteration 25 the best fitness is 0.07886944153844347']
# ['At iteration 26 the best fitness is 0.07886944153844347']
# ['At iteration 27 the best fitness is 0.0787561270908514']
# ['At iteration 28 the best fitness is 0.0787561270908514']
# ['At iteration 29 the best fitness is 0.0787561270908514']
# ['At iteration 30 the best fitness is 0.0787561270908514']
#       Selected: 832/1765 (47.1%), Fitness: 0.0788, Time: 728.4s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 832/3043 (27.3%)
#
#   --- Layer 2: META_PSO ---
#     Running EvoloPy PSO (Layer 2)...
#       Features: 1765, Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08405780917564915']
# ['At iteration 2 the best fitness is 0.07600402007687518']
# ['At iteration 3 the best fitness is 0.07600402007687518']
# ['At iteration 4 the best fitness is 0.07600402007687518']
# ['At iteration 5 the best fitness is 0.07600402007687518']
# ['At iteration 6 the best fitness is 0.07600402007687518']
# ['At iteration 7 the best fitness is 0.07600402007687518']
# ['At iteration 8 the best fitness is 0.07600402007687518']
# ['At iteration 9 the best fitness is 0.07600402007687518']
# ['At iteration 10 the best fitness is 0.07600402007687518']
# ['At iteration 11 the best fitness is 0.07600402007687518']
# ['At iteration 12 the best fitness is 0.07580571979358906']
# ['At iteration 13 the best fitness is 0.07515416171993466']
# ['At iteration 14 the best fitness is 0.07515416171993466']
# ['At iteration 15 the best fitness is 0.07515416171993466']
# ['At iteration 16 the best fitness is 0.07166551079661002']
# ['At iteration 17 the best fitness is 0.07166551079661002']
# ['At iteration 18 the best fitness is 0.07166551079661002']
# ['At iteration 19 the best fitness is 0.07166551079661002']
# ['At iteration 20 the best fitness is 0.07166551079661002']
# ['At iteration 21 the best fitness is 0.07166551079661002']
# ['At iteration 22 the best fitness is 0.07166551079661002']
# ['At iteration 23 the best fitness is 0.07166551079661002']
# ['At iteration 24 the best fitness is 0.07166551079661002']
# ['At iteration 25 the best fitness is 0.07166551079661002']
# ['At iteration 26 the best fitness is 0.07166551079661002']
# ['At iteration 27 the best fitness is 0.07149553912522191']
# ['At iteration 28 the best fitness is 0.07149553912522191']
# ['At iteration 29 the best fitness is 0.07149553912522191']
# ['At iteration 30 the best fitness is 0.07149553912522191']
#       Selected: 854/1765 (48.4%), Fitness: 0.0715, Time: 722.5s
#     L2 Test Acc: 98.48%, F1: 98.47%, Features: 854/3043 (28.1%)
#
#   --- Layer 2: META_SCA ---
#     Running EvoloPy SCA (Layer 2)...
#       Features: 1765, Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07937935655260778']
# ['At iteration 1 the best fitness is 0.07937935655260778']
# ['At iteration 2 the best fitness is 0.07937935655260778']
# ['At iteration 3 the best fitness is 0.07937935655260778']
# ['At iteration 4 the best fitness is 0.07558332255827349']
# ['At iteration 5 the best fitness is 0.07558332255827349']
# ['At iteration 6 the best fitness is 0.07394026306818852']
# ['At iteration 7 the best fitness is 0.07394026306818852']
# ['At iteration 8 the best fitness is 0.07144734522116301']
# ['At iteration 9 the best fitness is 0.07011590046195622']
# ['At iteration 10 the best fitness is 0.06969097128348596']
# ['At iteration 11 the best fitness is 0.06762298261493072']
# ['At iteration 12 the best fitness is 0.06595159451294771']
# ['At iteration 13 the best fitness is 0.06595159451294771']
# ['At iteration 14 the best fitness is 0.06595159451294771']
# ['At iteration 15 the best fitness is 0.06595159451294771']
# ['At iteration 16 the best fitness is 0.06595159451294771']
# ['At iteration 17 the best fitness is 0.0605365979805579']
# ['At iteration 18 the best fitness is 0.0605365979805579']
# ['At iteration 19 the best fitness is 0.0605365979805579']
# ['At iteration 20 the best fitness is 0.0605365979805579']
# ['At iteration 21 the best fitness is 0.0605365979805579']
# ['At iteration 22 the best fitness is 0.0605365979805579']
# ['At iteration 23 the best fitness is 0.0605365979805579']
# ['At iteration 24 the best fitness is 0.0605365979805579']
# ['At iteration 25 the best fitness is 0.0605365979805579']
# ['At iteration 26 the best fitness is 0.0605365979805579']
# ['At iteration 27 the best fitness is 0.0605365979805579']
# ['At iteration 28 the best fitness is 0.0605365979805579']
# ['At iteration 29 the best fitness is 0.0605365979805579']
#       Selected: 328/1765 (18.6%), Fitness: 0.0605, Time: 731.5s
#     L2 Test Acc: 94.95%, F1: 94.69%, Features: 328/3043 (10.8%)
#
#   --- Layer 2: META_SSA ---
#     Running EvoloPy SSA (Layer 2)...
#       Features: 1765, Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08014422907385424']
# ['At iteration 2 the best fitness is 0.08014422907385424']
# ['At iteration 3 the best fitness is 0.08014422907385424']
# ['At iteration 4 the best fitness is 0.08014422907385424']
# ['At iteration 5 the best fitness is 0.08014422907385424']
# ['At iteration 6 the best fitness is 0.08014422907385424']
# ['At iteration 7 the best fitness is 0.08014422907385424']
# ['At iteration 8 the best fitness is 0.08003091462626216']
# ['At iteration 9 the best fitness is 0.07997425740246614']
# ['At iteration 10 the best fitness is 0.07971929989538398']
# ['At iteration 11 the best fitness is 0.07971929989538398']
# ['At iteration 12 the best fitness is 0.07971929989538398']
# ['At iteration 13 the best fitness is 0.07589070562928311']
# ['At iteration 14 the best fitness is 0.0755224336746089']
# ['At iteration 15 the best fitness is 0.0755224336746089']
# ['At iteration 16 the best fitness is 0.0755224336746089']
# ['At iteration 17 the best fitness is 0.07160885357281398']
# ['At iteration 18 the best fitness is 0.07160885357281398']
# ['At iteration 19 the best fitness is 0.07160885357281398']
# ['At iteration 20 the best fitness is 0.07160885357281398']
# ['At iteration 21 the best fitness is 0.07160885357281398']
# ['At iteration 22 the best fitness is 0.07160885357281398']
# ['At iteration 23 the best fitness is 0.07160885357281398']
# ['At iteration 24 the best fitness is 0.07160885357281398']
# ['At iteration 25 the best fitness is 0.07160885357281398']
# ['At iteration 26 the best fitness is 0.07160885357281398']
# ['At iteration 27 the best fitness is 0.07160885357281398']
# ['At iteration 28 the best fitness is 0.07160885357281398']
# ['At iteration 29 the best fitness is 0.07160885357281398']
#       Selected: 858/1765 (48.6%), Fitness: 0.0716, Time: 1814.6s
#     L2 Test Acc: 96.97%, F1: 96.69%, Features: 858/3043 (28.2%)
#
#   --- Layer 2: META_WOA ---
#     Running EvoloPy WOA (Layer 2)...
#       Features: 1765, Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08405780917564915']
# ['At iteration 1 the best fitness is 0.07582687809293191']
# ['At iteration 2 the best fitness is 0.07145580854090015']
# ['At iteration 3 the best fitness is 0.07145580854090015']
# ['At iteration 4 the best fitness is 0.07145580854090015']
# ['At iteration 5 the best fitness is 0.07145580854090015']
# ['At iteration 6 the best fitness is 0.06867537291502591']
# ['At iteration 7 the best fitness is 0.06867537291502591']
# ['At iteration 8 the best fitness is 0.06867537291502591']
# ['At iteration 9 the best fitness is 0.06867537291502591']
# ['At iteration 10 the best fitness is 0.06867537291502591']
# ['At iteration 11 the best fitness is 0.06867537291502591']
# ['At iteration 12 the best fitness is 0.06867537291502591']
# ['At iteration 13 the best fitness is 0.06867537291502591']
# ['At iteration 14 the best fitness is 0.06861871569122988']
# ['At iteration 15 the best fitness is 0.06861871569122988']
# ['At iteration 16 the best fitness is 0.06861871569122988']
# ['At iteration 17 the best fitness is 0.06861871569122988']
# ['At iteration 18 the best fitness is 0.06861871569122988']
# ['At iteration 19 the best fitness is 0.06467680697753694']
# ['At iteration 20 the best fitness is 0.06467680697753694']
# ['At iteration 21 the best fitness is 0.06467680697753694']
# ['At iteration 22 the best fitness is 0.06467680697753694']
# ['At iteration 23 the best fitness is 0.06467680697753694']
# ['At iteration 24 the best fitness is 0.06467680697753694']
# ['At iteration 25 the best fitness is 0.06467680697753694']
# ['At iteration 26 the best fitness is 0.06467680697753694']
# ['At iteration 27 the best fitness is 0.06467680697753694']
# ['At iteration 28 the best fitness is 0.06467680697753694']
# ['At iteration 29 the best fitness is 0.06467680697753694']
#       Selected: 335/1765 (19.0%), Fitness: 0.0647, Time: 700.1s
#     L2 Test Acc: 95.96%, F1: 95.87%, Features: 335/3043 (11.0%)
#
# ================================================================================
# ALL LAYER 2 EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
rows = []

for method_name in ALL_METHODS_L2:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'L1 Features': r.get('l1_features', TOTAL_FEATURES),
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_two_layer/all_results_per_fold.csv
# Shape: (85, 27)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  L1 Features  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected
# 0   mutual_info     1            98.2517          100.0000       98.2366          98.2366              98.4984           98.2517                760            3043                24.9754         1521      15.2376         14.5401         29.7778        528150           2.0206                27.0469                  6.7551                75.0246        29.2329               0.1953               1               35.4294              231                 28.1001                528
# 1   mutual_info     2            92.9461          100.0000       93.3535          93.3478              95.1734           92.9339                760            3043                24.9754         1521      15.6491         15.2493         30.8985        528150           2.0206                27.0469                  6.7551                75.0246        29.2329               0.7812               4               29.9080              195                 29.8563                561
# 2   mutual_info     3            96.3636          100.0000       96.0916          96.0916              97.4690           96.3636                760            3043                24.9754         1521      15.3104         15.7195         31.0301        528150           2.0206                27.0469                  6.7551                75.0246        29.2329               0.1953               1               33.1288              216                 28.8984                543
# 3   mutual_info     4            90.0000          100.0000       88.9808          88.9808              93.0659           90.0000                760            3043                24.9754         1521      14.5499         12.1302         26.6802        528150           2.0206                27.0469                  6.7551                75.0246        29.2329               0.7812               4               30.3681              198                 29.6966                558
# 4   mutual_info     5            95.9596           93.3610       95.8604          95.8604              96.9008           95.9596                760            3043                24.9754         1521      14.5387         11.6062         26.1450        528150           2.0206                27.0469                  6.7551                75.0246        29.2329               0.7812               4               29.9080              195                 29.8563                561
# 5           rfe     1            97.5524          100.0000       97.5362          97.5362              97.8490           97.5524                760            3043                24.9754         1521       2.4536         15.4871         17.9409        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              10.9375              56               31.2883              204                 26.6099                500
# 6           rfe     2            93.3610          100.0000       93.6714          93.6670              95.3030           93.3471                760            3043                24.9754         1521       2.3279         15.1640         17.4922        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              19.5312             100               24.2331              158                 26.7163                502
# 7           rfe     3            99.0909          100.0000       99.0886          99.0886              99.1736           99.0909                760            3043                24.9754         1521       2.4404         15.7424         18.1830        528150           2.0206                27.0469                  6.7551                75.0246        29.2329               7.6172              39               34.2025              223                 26.5035                498
# 8           rfe     4            89.0909          100.0000       86.9373          86.9373              88.4552           89.0909                760            3043                24.9754         1521       2.2736         12.2795         14.5534        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              10.9375              56               31.5951              206                 26.5035                498
# 9           rfe     5            98.4848           94.1909       98.4416          98.4416              98.8636           98.4848                760            3043                24.9754         1521       2.1559         11.9994         14.1555        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              19.5312             100               24.2331              158                 26.7163                502
# 10        lasso     1            91.9580           96.4646       92.2315          92.2315              94.2578           91.9580                760            3043                24.9754         1521      75.9403         15.0189         90.9594        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              45.8984             235               49.5399              323                 10.7504                202
# 11        lasso     2            92.1162           97.9798       92.0522          92.0192              93.1315           92.1488                760            3043                24.9754         1521      79.6533         15.2465         94.8999        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              45.8984             235               49.5399              323                 10.7504                202
# 12        lasso     3            93.6364          100.0000       93.1673          93.1673              95.5506           93.6364                760            3043                24.9754         1521      81.2277         15.7483         96.9762        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              46.2891             237               49.3865              322                 10.6972                201
# 13        lasso     4            90.0000           98.9899       88.8203          88.8203              93.4752           90.0000                760            3043                24.9754         1521      79.2245         12.3776         91.6022        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              45.5078             233               49.3865              322                 10.9101                205
# 14        lasso     5            96.9697           93.3610       96.9455          96.9455              97.1606           96.9697                760            3043                24.9754         1521      76.5999         11.9467         88.5467        528150           2.0206                27.0469                  6.7551                75.0246        29.2329              45.8984             235               49.5399              323                 10.7504                202
# 15     meta_BAT     1            97.9021          100.0000       97.8860          97.8860              98.1602           97.9021                799            3043                26.2570         1694    1011.6530         15.2543       1026.9074        548118           2.0968                27.0469                  7.1017                73.7430        29.6929              40.4297             207               20.8589              136                 24.2682                456
# 16     meta_BAT     2            91.2863          100.0000       91.4743          91.5045              93.0644           91.2397                952            3043                31.2849         2024     978.9005         15.5912        994.4917        626454           2.3956                27.0469                  8.4616                68.7151        31.5044              47.0703             241               19.3252              126                 31.1336                585
# 17     meta_BAT     3            98.6364          100.0000       98.6050          98.6050              98.9510           98.6364                820            3043                26.9471         1751    1015.1050         15.9116       1031.0166        558870           2.1378                27.0469                  7.2884                73.0529        29.9414              46.2891             237               22.3926              146                 23.2571                437
# 18     meta_BAT     4            95.4545          100.0000       95.4797          95.4797              96.3597           95.4545                619            3043                20.3418         1413     745.8957         11.9677        757.8635        455958           1.7452                27.0469                  5.5018                79.6582        28.1143              34.9609             179               22.0859              144                 15.7531                296
# 19     meta_BAT     5            99.4949           93.3610       99.4934          99.4934              99.5455           99.4949                821            3043                26.9800         1765     749.4229         12.2585        761.6814        559382           2.1397                27.0469                  7.2972                73.0200        29.9536              40.0391             205               23.9264              156                 24.4811                460

# %% [markdown]
# ## Per-Method Summary Table

# %%
summary_rows = []
for method_name in ALL_METHODS_L2:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean L1 Features': method_df['L1 Features'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean L1 Features  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
# mutual_info              94.70              3.25              94.50              3.54                   760.0                       24.98            1521.0             15.06                13.85                28.91           528150.0                  2.02                       75.02               29.23
#         rfe              95.52              4.23              95.14              5.04                   760.0                       24.98            1521.0              2.33                14.13                16.46           528150.0                  2.02                       75.02               29.23
#       lasso              92.94              2.60              92.64              2.91                   760.0                       24.98            1521.0             78.53                14.07                92.60           528150.0                  2.02                       75.02               29.23
#    meta_BAT              96.55              3.31              96.59              3.22                   802.2                       26.36            1729.4            900.20                14.20               914.39           549756.4                  2.10                       73.64               29.84
#     meta_CS              95.67              3.49              95.65              3.51                   806.0                       26.49            1729.4           1767.80                14.10              1781.90           551702.0                  2.11                       73.51               29.88
#     meta_DE              94.26              4.81              94.07              5.09                   769.0                       25.27            1729.4            896.00                14.08               910.09           532758.0                  2.04                       74.73               29.47
#    meta_FFA              95.13              4.39              95.01              4.52                   790.0                       25.96            1729.4            863.64                14.19               877.83           543510.0                  2.08                       74.04               29.69
#     meta_GA              95.45              4.17              95.33              4.20                   791.4                       26.01            1729.4            866.65                14.68               881.32           544226.8                  2.08                       73.99               29.74
#    meta_GWO              93.84              4.58              93.61              4.93                   429.6                       14.12            1729.4            881.03                14.54               895.57           358985.2                  1.38                       85.88               25.43
#    meta_HHO              94.46              3.71              94.20              4.00                   246.4                        8.10            1729.4           1124.92                14.40              1139.32           214882.0                  0.82                       91.90               22.30
#   meta_JAYA              94.99              4.57              94.72              5.08                   792.6                       26.05            1729.4            881.93                14.07               895.99           544841.2                  2.08                       73.95               29.73
#    meta_MFO              95.67              3.48              95.60              3.59                   816.6                       26.84            1729.4            827.78                14.00               841.78           557129.2                  2.13                       73.16               30.00
#    meta_MVO              95.73              3.57              95.58              3.60                   775.4                       25.48            1729.4            816.56                13.28               829.83           536034.8                  2.05                       74.52               29.56
#    meta_PSO              96.16              2.88              96.16              2.82                   752.8                       24.74            1729.4            802.79                13.33               816.12           524463.6                  2.01                       75.26               29.32
#    meta_SCA              93.74              2.51              93.53              2.65                   222.0                        7.30            1729.4            820.60                13.49               834.09           191489.6                  0.74                       92.70               21.83
#    meta_SSA              94.77              3.09              94.72              2.93                   792.4                       26.04            1729.4           2022.50                13.28              2035.78           544738.8                  2.08                       73.96               29.74
#    meta_WOA              94.35              3.41              94.24              3.48                   346.8                       11.40            1729.4            790.52                13.76               804.29           309806.6                  1.19                       88.60               24.23

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS_L2)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Two-Layer FS: Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Two-Layer FS: Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Two-Layer FS: Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention scatter
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS_L2:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Two-Layer FS: Accuracy vs Feature Retention', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap
# ============================================================================
modality_data = {}
for method in ALL_METHODS_L2:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS_L2)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Two-Layer FS: Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Layer 2 Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Metaheuristics-only comparison
# ============================================================================
meta_method_names = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

if len(meta_method_names) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_method_names)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_method_names)
    bars = axes[0].bar(range(len(meta_method_names)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_method_names))))
    axes[0].set_xticks(range(len(meta_method_names)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_method_names], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Two-Layer FS Metaheuristics: Test Accuracy', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_method_names)
    bars2 = axes[1].bar(range(len(meta_method_names)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_method_names))))
    axes[1].set_xticks(range(len(meta_method_names)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_method_names], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Two-Layer FS Metaheuristics: Feature Retention', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '07_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 07_metaheuristics_comparison.png")
# Out:
# Saved: 07_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 8: Convergence curves for metaheuristics
# ============================================================================
meta_method_names = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

if len(meta_method_names) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_method_names:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Layer 2 Metaheuristic Convergence Curves (averaged)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_convergence_curves.png")
# Out:
# Saved: 08_convergence_curves.png

# %%
# ============================================================================
# PLOT 9: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods_plot = ['mutual_info', 'rfe', 'lasso']
meta_methods_plot = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

all_std = df_all[df_all['Method'].isin(standard_methods_plot)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods_plot)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

all_std_f = df_all[(df_all['Method'].isin(standard_methods_plot)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods_plot)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

all_std_t = df_all[(df_all['Method'].isin(standard_methods_plot)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods_plot)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '09_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 09_standard_vs_metaheuristics.png")
# Out:
# Saved: 09_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 10: Per-fold accuracy line plot
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS_L2:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Two-Layer FS: Test Accuracy Across Folds', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_per_fold_accuracy_lines.png")
# Out:
# Saved: 10_per_fold_accuracy_lines.png

# %% [markdown]
# ## Best Metaheuristic Per Fold (Layer 2)

# %%
meta_methods_l2 = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD - LAYER 2")
print("=" * 90)

best_per_fold = []

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods_l2:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Test F1 Macro (%)': best_result['test_f1_macro'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Test F1 Macro:      {fold_entry['Test F1 Macro (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

df_best_meta = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold - Layer 2)")
print("=" * 90)

if len(df_best_meta) > 0:
    avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
    std_test_acc = df_best_meta['Test Accuracy (%)'].std()
    avg_test_f1_macro = df_best_meta['Test F1 Macro (%)'].mean()
    std_test_f1_macro = df_best_meta['Test F1 Macro (%)'].std()
    avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
    std_feat_ret = df_best_meta['Feature Retention (%)'].std()

    print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
    print(f"  Average Test F1 Macro:     {avg_test_f1_macro:.2f}% ± {std_test_f1_macro:.2f}%")
    print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

    print(f"\n  Average Modality-wise Feature Retention:")
    for mod in modality_names:
        col = f'{mod} Retention (%)'
        if col in df_best_meta.columns:
            avg_mod = df_best_meta[col].mean()
            std_mod = df_best_meta[col].std()
            print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

    csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
    df_best_meta.to_csv(csv_path, index=False)
    print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD - LAYER 2
# ==========================================================================================
#
#   Fold 1: Best = meta_GA
#     Test Accuracy:      98.60%
#     Test F1 Macro:      98.62%
#     Feature Retention:  24.68% (751/3043)
#     Modality Retention: depth=41.0%, sensor=18.6%, skeleton=22.4%
#
#   Fold 2: Best = meta_CS
#     Test Accuracy:      92.12%
#     Test F1 Macro:      92.54%
#     Feature Retention:  30.73% (935/3043)
#     Modality Retention: depth=43.8%, sensor=19.3%, skeleton=31.1%
#
#   Fold 3: Best = meta_FFA
#     Test Accuracy:      99.55%
#     Test F1 Macro:      99.54%
#     Feature Retention:  25.30% (770/3043)
#     Modality Retention: depth=43.6%, sensor=21.2%, skeleton=21.8%
#
#   Fold 4: Best = meta_BAT
#     Test Accuracy:      95.45%
#     Test F1 Macro:      95.48%
#     Feature Retention:  20.34% (619/3043)
#     Modality Retention: depth=35.0%, sensor=22.1%, skeleton=15.8%
#
#   Fold 5: Best = meta_MVO
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  27.34% (832/3043)
#     Modality Retention: depth=41.6%, sensor=24.4%, skeleton=24.5%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold - Layer 2)
# ==========================================================================================
#
#   Average Test Accuracy:     97.14% ± 3.32%
#   Average Test F1 Macro:     97.24% ± 3.16%
#   Average Feature Retention: 25.68% ± 3.80%
#
#   Average Modality-wise Feature Retention:
#          depth: 40.98% ± 3.57%
#         sensor: 21.10% ± 2.31%
#       skeleton: 23.10% ± 5.54%
#
# Saved to: results_two_layer/best_metaheuristic_per_fold.csv
