# %% [markdown]
# # File 1: Weighted Early Fusion — Learn Modality Weights
#
# **Goal:** Instead of simple concatenation (equal contribution), learn optimal per-modality
# scalar weights using all 14 EvoloPy metaheuristics.
#
# **Search space:** 3 continuous values in [0, 1] — one weight per modality (depth, sensor, skeleton).
#
# **Pipeline per fold:**
# 1. Metaheuristic optimizes `[w_depth, w_sensor, w_skeleton]` using quick fitness evaluations
# 2. Apply learned weights → train full classifier → evaluate
#
# **Outputs saved:**
# - Best weights per fold (per optimizer)
# - Best-overall weights per fold (best optimizer chosen per fold by val accuracy)
# - Baseline (unweighted) results for comparison
# - All results CSVs, plots, and a `best_weights_per_fold.pkl` for File 2

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# EvoloPy imports
sys.path.append('../../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

RESULTS_ROOT = Path("results_weighted_fusion")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Training hyperparameters (same as original)
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001

DEPTH_PCA_DIM = 512
DEPTH_DR_METHOD = 'kernel_pca'

# Metaheuristic hyperparameters
N_POPULATION = 20
MAX_ITERATIONS = 30
FITNESS_EPOCHS = 15  # quick training during fitness evaluation

# All 14 EvoloPy optimizers
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline'] + [f'weighted_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  Fitness epochs: {FITNESS_EPOCHS}")
print(f"  Depth DR: {DEPTH_DR_METHOD} -> {DEPTH_PCA_DIM} dims")
print(f"  Optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Metaheuristic pop: 20, iter: 30
#   Fitness epochs: 15
#   Depth DR: kernel_pca -> 512 dims
#   Optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 15

# %% [markdown]
# ## Load Data

# %%
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")

print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

first_sample = X_feat[0]
MODALITY_KEYS   = ['depth_feat', 'sensor_feat', 'skeleton_feat']
MODALITY_NAMES  = ['depth', 'sensor', 'skeleton']
N_MODALITIES    = len(MODALITY_NAMES)

# Raw (pre-DR) per-modality dims
RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality) for fold-wise processing
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before depth DR):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")
print(f"\nDepth KernelPCA target: {DEPTH_PCA_DIM}")

TOTAL_FEATURES = RAW_FEATURE_DIMS['sensor'] + RAW_FEATURE_DIMS['skeleton'] + DEPTH_PCA_DIM
print(f"\nTotal features (all modalities combined): {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Raw feature dimensions (before depth DR):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   TOTAL: 8039
#
# Depth KernelPCA target: 512
#
# Total features (all modalities combined): 3043

# %% [markdown]
# ## Model & Dataset

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (same as original)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)


print("Model and dataset defined")
# Out:
# Model and dataset defined

# %% [markdown]
# ## Helper Functions

# %%
# ─── Per-modality pipeline (split → normalize per modality → KernelPCA on depth → concat) ───

def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline:
      1. Split raw arrays into train / val / test by index
      2. Fit StandardScaler on train, apply to val and test — per modality separately
      3. Apply KernelPCA (rbf) on depth modality only (fit on train, transform val & test)
      4. Concatenate: depth | sensor | skeleton 

    Returns:
        X_train, X_val, X_test : normalized (and KernelPCA-reduced) concatenated arrays
        fold_feature_dims       : dict {modality: dim} AFTER KernelPCA (used for apply_modality_weights)
        pca_obj                 : fitted KernelPCA object (or None)
    """
    modality_train = {}
    modality_val   = {}
    modality_test  = {}
    scalers        = {}
    pca_obj        = None
    fold_feature_dims = {}

    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]

        # 1. Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]

        # 2. Per-modality normalization — fit on train only
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler

        # 3. KernelPCA on depth only
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                random_state=42, n_jobs=-1)
            X_tr = pca_obj.fit_transform(X_tr)
            X_v  = pca_obj.transform(X_v)
            X_te = pca_obj.transform(X_te)
            print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        fold_feature_dims[name] = X_tr.shape[1]

    # 4. Concatenate
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)

    total = sum(fold_feature_dims.values())
    print(f"    Feature dims after processing: " +
          " | ".join(f"{n}={fold_feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")

    return X_train, X_val, X_test, fold_feature_dims, pca_obj


def apply_modality_weights(X, weights, modality_dims):
    """Apply per-modality scalar weights to concatenated feature matrix.

    Args:
        X            : (N, TOTAL_FEATURES) — already concatenated and scaled
        weights      : (N_MODALITIES,)    — one weight per modality
        modality_dims: list of ints        — feature count per modality (post-DR)
    Returns:
        Weighted copy of X
    """
    X_weighted = X.copy()
    start_idx = 0
    for i, dim in enumerate(modality_dims):
        end_idx = start_idx + dim
        X_weighted[:, start_idx:end_idx] *= weights[i]
        start_idx = end_idx
    return X_weighted


def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)


print("Helper functions defined (per-modality normalization + KernelPCA on depth)")
# Out:
# Helper functions defined (per-modality normalization + KernelPCA on depth)

# %% [markdown]
# ## Fitness Function & Quick Training

# %%
def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation.
    Returns val_loss (continuous) and val_acc.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


def create_fitness_modality_weights(X_train, y_train, X_val, y_val, num_classes, modality_dims=None):
    """Fitness function for optimizing 4 modality weights.
    
    Uses VALIDATION LOSS (continuous) instead of (1 - accuracy).
    
    Why: With only 4 dimensions and ~107 val samples, many weight
    combinations achieve 100% val accuracy -> fitness=0.0 -> optimizer
    cannot differentiate. Val loss is continuous and always provides
    a gradient signal even when accuracy is saturated.
    """
    eval_count = [0]
    _modality_dims = modality_dims  # captured in closure
    
    def fitness(solution):
        try:
            weights = np.clip(solution, 0.0, 1.0)
            
            # Apply modality weights
            X_tr_w = apply_modality_weights(X_train, weights, _modality_dims)
            X_val_w = apply_modality_weights(X_val, weights, _modality_dims)
            
            train_ds = MultiModalDataset(X_tr_w, y_train)
            val_ds = MultiModalDataset(X_val_w, y_val)
            train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE)
            
            model = SimpleNN(TOTAL_FEATURES, num_classes).to(DEVICE)
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=FITNESS_EPOCHS, lr=1e-3, device=DEVICE
            )
            
            del model, train_ds, val_ds, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Use val_loss directly as fitness (continuous, always differentiable)
            # Even when accuracy=100%, loss still varies between solutions
            fitness_val = val_loss
            return fitness_val
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 100.0
    
    return fitness


def run_weight_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, modality_dims=None):
    """Run a single metaheuristic to optimize modality weights."""
    print(f"    Running weighted_{optimizer_name}...")
    print(f"      Search dim: {N_MODALITIES}, Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_modality_weights(X_train, y_train, X_val, y_val, num_classes, modality_dims=modality_dims)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, N_MODALITIES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    learned_weights = np.clip(solution.bestIndividual, 0.0, 1.0)
    convergence = (solution.convergence.tolist()
                   if hasattr(solution.convergence, 'tolist')
                   else list(solution.convergence))
    
    results = {
        'modality_weights': learned_weights,
        'convergence': convergence,
        'best_fitness': float(convergence[-1]) if len(convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'method': f'weighted_{optimizer_name}'
    }
    
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={learned_weights[i]:.3f}" for i in range(N_MODALITIES)])
    print(f"      Weights: {w_str}")
    print(f"      Best fitness: {results['best_fitness']:.6f}, Time: {exec_time:.1f}s")
    
    return results


print("Fitness function and weight optimizer runner defined")
print("NOTE: Using val_loss as fitness (continuous signal, not accuracy)")
# Out:
# Fitness function and weight optimizer runner defined
# NOTE: Using val_loss as fitness (continuous signal, not accuracy)

# %% [markdown]
# ## Full Training & Evaluation

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics (same as original)"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_val_loss = float('inf')
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)
        epoch_val_acc = val_correct / val_total

        # Also track val loss for this epoch
        epoch_val_loss = 0.0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                labels = labels.to(DEVICE)
                outputs = model(features)
                epoch_val_loss += nn.CrossEntropyLoss()(outputs, labels).item()
        epoch_val_loss /= len(val_loader)

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_val_loss = epoch_val_loss
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'val_loss': best_val_loss,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics


print("Full train/eval function defined")
# Out:
# Full train/eval function defined

# %% [markdown]
# ## Main Experiment Runner

# %%
def run_weighted_fusion_all_folds():
    """
    Run baseline + 14 weighted metaheuristics across all 8 LOSO folds.

    Fold logic (adapted from utd_mhad_main.ipynb):
      - GroupKFold: one subject held out as TEST per fold
      - Within remaining subjects, the LAST subject is held out as VAL
      - Per-modality normalization: StandardScaler fit on train, applied to val & test
      - KernelPCA (rbf) on depth modality only (DEPTH_PCA_DIM), fit on train only
      - apply_modality_weights uses per-fold modality_dims (post-KernelPCA)
    """
    print("=" * 80)
    print("WEIGHTED EARLY FUSION: MODALITY WEIGHT OPTIMIZATION")
    print(f"Methods: baseline + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth DR: {DEPTH_DR_METHOD} -> {DEPTH_PCA_DIM} dims")
    print("=" * 80)

    num_classes = len(np.unique(y))

    master_results = {m: {} for m in ALL_METHODS}

    # Use dummy_X for GroupKFold index splitting (matching utd_mhad_main style)
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    gkf = GroupKFold(n_splits=N_FOLDS)

    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#' * 80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#' * 80}")

        # ── Subject-based val split within train_val ──────────────────────────
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]          # last subject → val

        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv

        train_idx_fold = train_val_idx[train_mask_in_tv]
        val_idx_fold   = train_val_idx[val_mask_in_tv]

        print(f"  Test subject : {np.unique(subjects[test_idx])}")
        print(f"  Val  subject : {val_subject}")
        print(f"  Train: {len(train_idx_fold)}, Val: {len(val_idx_fold)}, Test: {len(test_idx)}")

        # ── Per-modality normalization + KernelPCA on depth ─────────────────────
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx_fold, val_idx_fold, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )

        y_train = y[train_idx_fold]
        y_val   = y[val_idx_fold]
        y_test  = y[test_idx]

        fold_modality_dims  = [fold_feature_dims[n] for n in MODALITY_NAMES]
        fold_total_features = sum(fold_modality_dims)

        orig_dataset_size_mb = (get_dataset_size_mb(X_train) +
                                get_dataset_size_mb(X_val) +
                                get_dataset_size_mb(X_test))

        # ── Run each method ───────────────────────────────────────────────────
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")

            fs_start_time = time.time()

            if method_name == 'baseline':
                modality_weights = np.ones(N_MODALITIES)
                weight_results = {
                    'modality_weights': modality_weights,
                    'execution_time': 0,
                    'convergence': None,
                    'best_fitness': None,
                    'method': 'baseline'
                }
            else:
                opt_name = method_name.replace('weighted_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                weight_results = run_weight_optimizer(
                    opt_name, opt_func,
                    X_train, y_train, X_val, y_val, num_classes,
                    modality_dims=fold_modality_dims
                )
                modality_weights = weight_results['modality_weights']

            fs_time = time.time() - fs_start_time

            # Apply weights (using fold-specific dims, post-KernelPCA)
            X_train_w = apply_modality_weights(X_train, modality_weights, fold_modality_dims)
            X_val_w   = apply_modality_weights(X_val,   modality_weights, fold_modality_dims)
            X_test_w  = apply_modality_weights(X_test,  modality_weights, fold_modality_dims)

            # Build and train final model
            model = SimpleNN(fold_total_features, num_classes).to(DEVICE)

            train_dataset = MultiModalDataset(X_train_w, y_train)
            val_dataset   = MultiModalDataset(X_val_w,   y_val)
            test_dataset  = MultiModalDataset(X_test_w,  y_test)

            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE)
            test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE)

            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()

            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )

            # Compile fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                'val_acc': eval_metrics['val_acc'],
                'val_loss': eval_metrics['val_loss'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                'modality_weights': modality_weights,
                'fold_feature_dims': fold_feature_dims,
                'fold_total_features': fold_total_features,
                'weight_optimization_time': weight_results['execution_time'],
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': weight_results.get('convergence', None),
                'best_fitness': weight_results.get('best_fitness', None),
                'test_preds': eval_metrics['test_preds'],
                'test_true': eval_metrics['test_true'],
            }

            master_results[method_name][fold_idx] = fold_result

            # Save per-fold result
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items()
                         if k not in ['test_preds', 'test_true']}
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                else:
                    fold_save_clean[k] = v

            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)

            # Save weights as npy for easy loading
            np.save(fold_dir / f"fold_{fold_idx+1}_weights.npy", modality_weights)

            w_str = ', '.join([f"{MODALITY_NAMES[i]}={modality_weights[i]:.3f}"
                               for i in range(N_MODALITIES)])
            print(f"    Weights: [{w_str}]")
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")

            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()

    print(f"\n{'=' * 80}")
    print("ALL WEIGHTED FUSION EXPERIMENTS COMPLETED")
    print(f"{'=' * 80}")

    return master_results


print("Main experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth DR: {DEPTH_DR_METHOD} -> {DEPTH_PCA_DIM} dims")
# Out:
# Main experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth DR: kernel_pca -> 512 dims

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_weighted_fusion_all_folds()
# Out:
# ================================================================================
# WEIGHTED EARLY FUSION: MODALITY WEIGHT OPTIMIZATION
# Methods: baseline + 14 metaheuristics = 15 total
# Folds: 5
# Per-modality normalization: ENABLED
# Depth DR: kernel_pca -> 512 dims
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Test subject : ['cx']
#   Val  subject : zyh
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000]
#     Test Acc: 97.90%, F1: 97.90%, Model: 6.480MB
#
#   --- WEIGHTED_BAT ---
#     Running weighted_BAT...
#       Search dim: 3, Pop: 20, Iter: 30
# BAT is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.03398999894436981']
# ['At iteration 1 the best fitness is 0.03198022508461561']
# ['At iteration 2 the best fitness is 0.03198022508461561']
# ['At iteration 3 the best fitness is 0.03198022508461561']
# ['At iteration 4 the best fitness is 0.017738186488194124']
# ['At iteration 5 the best fitness is 0.017738186488194124']
# ['At iteration 6 the best fitness is 0.017738186488194124']
# ['At iteration 7 the best fitness is 0.017738186488194124']
# ['At iteration 8 the best fitness is 0.017738186488194124']
# ['At iteration 9 the best fitness is 0.017738186488194124']
# ['At iteration 10 the best fitness is 0.017707624805292914']
# ['At iteration 11 the best fitness is 0.017707624805292914']
# ['At iteration 12 the best fitness is 0.017707624805292914']
# ['At iteration 13 the best fitness is 0.017707624805292914']
# ['At iteration 14 the best fitness is 0.017707624805292914']
# ['At iteration 15 the best fitness is 0.017707624805292914']
# ['At iteration 16 the best fitness is 0.017707624805292914']
# ['At iteration 17 the best fitness is 0.017707624805292914']
# ['At iteration 18 the best fitness is 0.017707624805292914']
# ['At iteration 19 the best fitness is 0.017707624805292914']
# ['At iteration 20 the best fitness is 0.017707624805292914']
# ['At iteration 21 the best fitness is 0.017707624805292914']
# ['At iteration 22 the best fitness is 0.017707624805292914']
# ['At iteration 23 the best fitness is 0.017707624805292914']
# ['At iteration 24 the best fitness is 0.017707624805292914']
# ['At iteration 25 the best fitness is 0.017707624805292914']
# ['At iteration 26 the best fitness is 0.017707624805292914']
# ['At iteration 27 the best fitness is 0.017707624805292914']
# ['At iteration 28 the best fitness is 0.017707624805292914']
# ['At iteration 29 the best fitness is 0.017707624805292914']
#       Weights: depth=0.000, sensor=1.000, skeleton=1.000
#       Best fitness: 0.017708, Time: 472.5s
#     Weights: [depth=0.000, sensor=1.000, skeleton=1.000]
#     Test Acc: 97.55%, F1: 97.54%, Model: 6.480MB
#
#   --- WEIGHTED_CS ---
#     Running weighted_CS...
#       Search dim: 3, Pop: 20, Iter: 30
# CS is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.03385031236601727']
# ['At iteration 1 the best fitness is 0.03385031236601727']
# ['At iteration 2 the best fitness is 0.026869947955544506']
# ['At iteration 3 the best fitness is 0.026869947955544506']
# ['At iteration 4 the best fitness is 0.026869947955544506']
# ['At iteration 5 the best fitness is 0.026185903565159867']
# ['At iteration 6 the best fitness is 0.026185903565159867']
# ['At iteration 7 the best fitness is 0.026185903565159867']
# ['At iteration 8 the best fitness is 0.026185903565159867']
# ['At iteration 9 the best fitness is 0.026185903565159867']
# ['At iteration 10 the best fitness is 0.02612621909273522']
# ['At iteration 11 the best fitness is 0.02612621909273522']
# ['At iteration 12 the best fitness is 0.02612621909273522']
# ['At iteration 13 the best fitness is 0.02612621909273522']
# ['At iteration 14 the best fitness is 0.02612621909273522']
# ['At iteration 15 the best fitness is 0.02612621909273522']
# ['At iteration 16 the best fitness is 0.02612621909273522']
# ['At iteration 17 the best fitness is 0.02612621909273522']
# ['At iteration 18 the best fitness is 0.01871187625718968']
# ['At iteration 19 the best fitness is 0.01871187625718968']
# ['At iteration 20 the best fitness is 0.01871187625718968']
# ['At iteration 21 the best fitness is 0.01871187625718968']
# ['At iteration 22 the best fitness is 0.01871187625718968']
# ['At iteration 23 the best fitness is 0.01871187625718968']
# ['At iteration 24 the best fitness is 0.01871187625718968']
# ['At iteration 25 the best fitness is 0.01871187625718968']
# ['At iteration 26 the best fitness is 0.01871187625718968']
# ['At iteration 27 the best fitness is 0.01871187625718968']
# ['At iteration 28 the best fitness is 0.01871187625718968']
# ['At iteration 29 the best fitness is 0.01871187625718968']
#       Weights: depth=0.694, sensor=0.279, skeleton=0.172
#       Best fitness: 0.018712, Time: 1019.4s
#     Weights: [depth=0.694, sensor=0.279, skeleton=0.172]
#     Test Acc: 96.85%, F1: 96.87%, Model: 6.480MB
#
#   --- WEIGHTED_DE ---
#     Running weighted_DE...
#       Search dim: 3, Pop: 20, Iter: 30
# DE is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.031540596059390476']
# ['At iteration 2 the best fitness is 0.031540596059390476']
# ['At iteration 3 the best fitness is 0.031540596059390476']
# ['At iteration 4 the best fitness is 0.03127986937761307']
# ['At iteration 5 the best fitness is 0.03127986937761307']
# ['At iteration 6 the best fitness is 0.03127986937761307']
# ['At iteration 7 the best fitness is 0.03127986937761307']
# ['At iteration 8 the best fitness is 0.03127986937761307']
# ['At iteration 9 the best fitness is 0.03127986937761307']
# ['At iteration 10 the best fitness is 0.03127986937761307']
# ['At iteration 11 the best fitness is 0.03127986937761307']
# ['At iteration 12 the best fitness is 0.03127986937761307']
# ['At iteration 13 the best fitness is 0.03127986937761307']
# ['At iteration 14 the best fitness is 0.03127986937761307']
# ['At iteration 15 the best fitness is 0.03127986937761307']
# ['At iteration 16 the best fitness is 0.03127986937761307']
# ['At iteration 17 the best fitness is 0.029938891862652132']
# ['At iteration 18 the best fitness is 0.026048167209540094']
# ['At iteration 19 the best fitness is 0.026048167209540094']
# ['At iteration 20 the best fitness is 0.026048167209540094']
# ['At iteration 21 the best fitness is 0.026048167209540094']
# ['At iteration 22 the best fitness is 0.026048167209540094']
# ['At iteration 23 the best fitness is 0.020453301657523428']
# ['At iteration 24 the best fitness is 0.020453301657523428']
# ['At iteration 25 the best fitness is 0.020453301657523428']
# ['At iteration 26 the best fitness is 0.020453301657523428']
# ['At iteration 27 the best fitness is 0.020453301657523428']
# ['At iteration 28 the best fitness is 0.020453301657523428']
# ['At iteration 29 the best fitness is 0.020453301657523428']
# ['At iteration 30 the best fitness is 0.020453301657523428']
#       Weights: depth=0.911, sensor=0.962, skeleton=0.666
#       Best fitness: 0.020453, Time: 505.9s
#     Weights: [depth=0.911, sensor=0.962, skeleton=0.666]
#     Test Acc: 97.90%, F1: 97.90%, Model: 6.480MB
#
#   --- WEIGHTED_FFA ---
#     Running weighted_FFA...
#       Search dim: 3, Pop: 20, Iter: 30
# FFA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.03228178347593972']
# ['At iteration 1 the best fitness is 0.032959887491805215']
# ['At iteration 2 the best fitness is 0.03516094386577606']
# ['At iteration 3 the best fitness is 0.034940552365567']
# ['At iteration 4 the best fitness is 0.034387457849723954']
# ['At iteration 5 the best fitness is 0.03202616809202092']
# ['At iteration 6 the best fitness is 0.031606302330536504']
# ['At iteration 7 the best fitness is 0.02583931546126093']
# ['At iteration 8 the best fitness is 0.0365927465526121']
# ['At iteration 9 the best fitness is 0.03580392464729292']
# ['At iteration 10 the best fitness is 0.030497504198657616']
# ['At iteration 11 the best fitness is 0.030046460551342795']
# ['At iteration 12 the best fitness is 0.03096554641212736']
# ['At iteration 13 the best fitness is 0.025838583574763367']
# ['At iteration 14 the best fitness is 0.03338505181350878']
# ['At iteration 15 the best fitness is 0.028163062342043434']
# ['At iteration 16 the best fitness is 0.03200945697192635']
# ['At iteration 17 the best fitness is 0.03055304807743856']
# ['At iteration 18 the best fitness is 0.03575967578217387']
# ['At iteration 19 the best fitness is 0.027434767889125005']
# ['At iteration 20 the best fitness is 0.03372934427378433']
# ['At iteration 21 the best fitness is 0.02315154724887439']
# ['At iteration 22 the best fitness is 0.028914027448211397']
# ['At iteration 23 the best fitness is 0.03631077620333859']
# ['At iteration 24 the best fitness is 0.02170459959389908']
# ['At iteration 25 the best fitness is 0.027793246587472304']
# ['At iteration 26 the best fitness is 0.03804009115057332']
# ['At iteration 27 the best fitness is 0.03211173295442547']
# ['At iteration 28 the best fitness is 0.025850563177040646']
# ['At iteration 29 the best fitness is 0.03076119108923844']
#       Weights: depth=0.097, sensor=0.896, skeleton=0.789
#       Best fitness: 0.030761, Time: 495.7s
#     Weights: [depth=0.097, sensor=0.896, skeleton=0.789]
#     Test Acc: 96.85%, F1: 96.84%, Model: 6.480MB
#
#   --- WEIGHTED_GA ---
#     Running weighted_GA...
#       Search dim: 3, Pop: 20, Iter: 30
# GA is optimizing  "fitness"
# At iteration 1 the best fitness is 0.04191896665309157
# At iteration 2 the best fitness is 0.035859340602265935
# At iteration 3 the best fitness is 0.024281827001167194
# At iteration 4 the best fitness is 0.03421205548303468
# At iteration 5 the best fitness is 0.03701137455313334
# At iteration 6 the best fitness is 0.03873730111601097
# At iteration 7 the best fitness is 0.03005412713225399
# At iteration 8 the best fitness is 0.03282835268016372
# At iteration 9 the best fitness is 0.03671257443992155
# At iteration 10 the best fitness is 0.03371615481695959
# At iteration 11 the best fitness is 0.02734751334147794
# At iteration 12 the best fitness is 0.029128754711044685
# At iteration 13 the best fitness is 0.035997506098023484
# At iteration 14 the best fitness is 0.033820976702762504
# At iteration 15 the best fitness is 0.03979316456908626
# At iteration 16 the best fitness is 0.023949018014328822
# At iteration 17 the best fitness is 0.04112849038626466
# At iteration 18 the best fitness is 0.027048519479909112
# At iteration 19 the best fitness is 0.03118869023663657
# At iteration 20 the best fitness is 0.02161883270101888
# At iteration 21 the best fitness is 0.03528933260323746
# At iteration 22 the best fitness is 0.03574191260018519
# At iteration 23 the best fitness is 0.031189631803759506
# At iteration 24 the best fitness is 0.03984577541372606
# At iteration 25 the best fitness is 0.033105036443365474
# At iteration 26 the best fitness is 0.030148508891995465
# At iteration 27 the best fitness is 0.036367389905665605
# At iteration 28 the best fitness is 0.03389286928411041
# At iteration 29 the best fitness is 0.03930020924391491
# At iteration 30 the best fitness is 0.018894761268581663
#       Weights: depth=0.229, sensor=0.838, skeleton=0.987
#       Best fitness: 0.018895, Time: 506.2s
#     Weights: [depth=0.229, sensor=0.838, skeleton=0.987]
#     Test Acc: 95.80%, F1: 95.89%, Model: 6.480MB
#
#   --- WEIGHTED_GWO ---
#     Running weighted_GWO...
#       Search dim: 3, Pop: 20, Iter: 30
# GWO is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.03575682267546654']
# ['At iteration 1 the best fitness is 0.02855568439034479']
# ['At iteration 2 the best fitness is 0.02662257929997785']
# ['At iteration 3 the best fitness is 0.02662257929997785']
# ['At iteration 4 the best fitness is 0.026146021937685355']
# ['At iteration 5 the best fitness is 0.026146021937685355']
# ['At iteration 6 the best fitness is 0.026146021937685355']
# ['At iteration 7 the best fitness is 0.026146021937685355']
# ['At iteration 8 the best fitness is 0.026146021937685355']
# ['At iteration 9 the best fitness is 0.026146021937685355']
# ['At iteration 10 the best fitness is 0.026146021937685355']
# ['At iteration 11 the best fitness is 0.026146021937685355']
# ['At iteration 12 the best fitness is 0.026146021937685355']
# ['At iteration 13 the best fitness is 0.026146021937685355']
# ['At iteration 14 the best fitness is 0.026146021937685355']
# ['At iteration 15 the best fitness is 0.026146021937685355']
# ['At iteration 16 the best fitness is 0.026146021937685355']
# ['At iteration 17 the best fitness is 0.026146021937685355']
# ['At iteration 18 the best fitness is 0.026146021937685355']
# ['At iteration 19 the best fitness is 0.026146021937685355']
# ['At iteration 20 the best fitness is 0.026146021937685355']
# ['At iteration 21 the best fitness is 0.026146021937685355']
# ['At iteration 22 the best fitness is 0.026146021937685355']
# ['At iteration 23 the best fitness is 0.026146021937685355']
# ['At iteration 24 the best fitness is 0.026146021937685355']
# ['At iteration 25 the best fitness is 0.026146021937685355']
# ['At iteration 26 the best fitness is 0.026146021937685355']
# ['At iteration 27 the best fitness is 0.026146021937685355']
# ['At iteration 28 the best fitness is 0.026146021937685355']
# ['At iteration 29 the best fitness is 0.026146021937685355']
#       Weights: depth=0.745, sensor=0.236, skeleton=0.282
#       Best fitness: 0.026146, Time: 488.0s
#     Weights: [depth=0.745, sensor=0.236, skeleton=0.282]
#     Test Acc: 98.25%, F1: 98.24%, Model: 6.480MB
#
#   --- WEIGHTED_HHO ---
#     Running weighted_HHO...
#       Search dim: 3, Pop: 20, Iter: 30
# HHO is now tackling  "fitness"
# ['At iteration 0 the best fitness is 0.034440248273313046']
# ['At iteration 1 the best fitness is 0.034440248273313046']
# ['At iteration 2 the best fitness is 0.034440248273313046']
# ['At iteration 3 the best fitness is 0.029895252814250334']
# ['At iteration 4 the best fitness is 0.029895252814250334']
# ['At iteration 5 the best fitness is 0.029895252814250334']
# ['At iteration 6 the best fitness is 0.029895252814250334']
# ['At iteration 7 the best fitness is 0.029270298280087963']
# ['At iteration 8 the best fitness is 0.029270298280087963']
# ['At iteration 9 the best fitness is 0.025489150247137462']
# ['At iteration 10 the best fitness is 0.025489150247137462']
# ['At iteration 11 the best fitness is 0.025489150247137462']
# ['At iteration 12 the best fitness is 0.025489150247137462']
# ['At iteration 13 the best fitness is 0.025489150247137462']
# ['At iteration 14 the best fitness is 0.025489150247137462']
# ['At iteration 15 the best fitness is 0.025489150247137462']
# ['At iteration 16 the best fitness is 0.025489150247137462']
# ['At iteration 17 the best fitness is 0.025489150247137462']
# ['At iteration 18 the best fitness is 0.025489150247137462']
# ['At iteration 19 the best fitness is 0.025489150247137462']
# ['At iteration 20 the best fitness is 0.025489150247137462']
# ['At iteration 21 the best fitness is 0.025489150247137462']
# ['At iteration 22 the best fitness is 0.025489150247137462']
# ['At iteration 23 the best fitness is 0.025489150247137462']
# ['At iteration 24 the best fitness is 0.023873675148934126']
# ['At iteration 25 the best fitness is 0.023873675148934126']
# ['At iteration 26 the best fitness is 0.023873675148934126']
# ['At iteration 27 the best fitness is 0.023873675148934126']
# ['At iteration 28 the best fitness is 0.023873675148934126']
# ['At iteration 29 the best fitness is 0.023873675148934126']
#       Weights: depth=1.000, sensor=1.000, skeleton=0.627
#       Best fitness: 0.023874, Time: 799.7s
#     Weights: [depth=1.000, sensor=1.000, skeleton=0.627]
#     Test Acc: 97.90%, F1: 97.90%, Model: 6.480MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 3, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.023555437701621225']
# ['At iteration 1 the best fitness is 0.023555437701621225']
# ['At iteration 2 the best fitness is 0.023555437701621225']
# ['At iteration 3 the best fitness is 0.023555437701621225']
# ['At iteration 4 the best fitness is 0.023555437701621225']
# ['At iteration 5 the best fitness is 0.023555437701621225']
# ['At iteration 6 the best fitness is 0.023555437701621225']
# ['At iteration 7 the best fitness is 0.023555437701621225']
# ['At iteration 8 the best fitness is 0.023555437701621225']
# ['At iteration 9 the best fitness is 0.023555437701621225']
# ['At iteration 10 the best fitness is 0.023555437701621225']
# ['At iteration 11 the best fitness is 0.023555437701621225']
# ['At iteration 12 the best fitness is 0.023555437701621225']
# ['At iteration 13 the best fitness is 0.023555437701621225']
# ['At iteration 14 the best fitness is 0.023555437701621225']
# ['At iteration 15 the best fitness is 0.023555437701621225']
# ['At iteration 16 the best fitness is 0.023555437701621225']
# ['At iteration 17 the best fitness is 0.023555437701621225']
# ['At iteration 18 the best fitness is 0.023555437701621225']
# ['At iteration 19 the best fitness is 0.023555437701621225']
# ['At iteration 20 the best fitness is 0.023555437701621225']
# ['At iteration 21 the best fitness is 0.023215431054787978']
# ['At iteration 22 the best fitness is 0.023215431054787978']
# ['At iteration 23 the best fitness is 0.023215431054787978']
# ['At iteration 24 the best fitness is 0.023215431054787978']
# ['At iteration 25 the best fitness is 0.023215431054787978']
# ['At iteration 26 the best fitness is 0.023215431054787978']
# ['At iteration 27 the best fitness is 0.023215431054787978']
# ['At iteration 28 the best fitness is 0.023215431054787978']
# ['At iteration 29 the best fitness is 0.023215431054787978']
#       Weights: depth=0.197, sensor=0.815, skeleton=0.702
#       Best fitness: 0.023215, Time: 514.0s
#     Weights: [depth=0.197, sensor=0.815, skeleton=0.702]
#     Test Acc: 98.25%, F1: 98.24%, Model: 6.480MB
#
#   --- WEIGHTED_MFO ---
#     Running weighted_MFO...
#       Search dim: 3, Pop: 20, Iter: 30
# MFO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.033694014219301086']
# ['At iteration 2 the best fitness is 0.033694014219301086']
# ['At iteration 3 the best fitness is 0.03018660271274192']
# ['At iteration 4 the best fitness is 0.03018660271274192']
# ['At iteration 5 the best fitness is 0.03018660271274192']
# ['At iteration 6 the best fitness is 0.02648873726970383']
# ['At iteration 7 the best fitness is 0.02648873726970383']
# ['At iteration 8 the best fitness is 0.02648873726970383']
# ['At iteration 9 the best fitness is 0.02648873726970383']
# ['At iteration 10 the best fitness is 0.02648873726970383']
# ['At iteration 11 the best fitness is 0.02648873726970383']
# ['At iteration 12 the best fitness is 0.02648873726970383']
# ['At iteration 13 the best fitness is 0.02648873726970383']
# ['At iteration 14 the best fitness is 0.02648873726970383']
# ['At iteration 15 the best fitness is 0.02648873726970383']
# ['At iteration 16 the best fitness is 0.02648873726970383']
# ['At iteration 17 the best fitness is 0.02648873726970383']
# ['At iteration 18 the best fitness is 0.02648873726970383']
# ['At iteration 19 the best fitness is 0.02648873726970383']
# ['At iteration 20 the best fitness is 0.02648873726970383']
# ['At iteration 21 the best fitness is 0.02648873726970383']
# ['At iteration 22 the best fitness is 0.02648873726970383']
# ['At iteration 23 the best fitness is 0.02648873726970383']
# ['At iteration 24 the best fitness is 0.02648873726970383']
# ['At iteration 25 the best fitness is 0.02648873726970383']
# ['At iteration 26 the best fitness is 0.02648873726970383']
# ['At iteration 27 the best fitness is 0.023041486673589264']
# ['At iteration 28 the best fitness is 0.023041486673589264']
# ['At iteration 29 the best fitness is 0.023041486673589264']
#       Weights: depth=0.800, sensor=0.998, skeleton=0.693
#       Best fitness: 0.023041, Time: 471.4s
#     Weights: [depth=0.800, sensor=0.998, skeleton=0.693]
#     Test Acc: 97.20%, F1: 97.22%, Model: 6.480MB
#
#   --- WEIGHTED_MVO ---
#     Running weighted_MVO...
#       Search dim: 3, Pop: 20, Iter: 30
# MVO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.039535803287955265']
# ['At iteration 2 the best fitness is 0.03642929544938462']
# ['At iteration 3 the best fitness is 0.02634204026045544']
# ['At iteration 4 the best fitness is 0.02634204026045544']
# ['At iteration 5 the best fitness is 0.02634204026045544']
# ['At iteration 6 the best fitness is 0.02634204026045544']
# ['At iteration 7 the best fitness is 0.02634204026045544']
# ['At iteration 8 the best fitness is 0.02634204026045544']
# ['At iteration 9 the best fitness is 0.02634204026045544']
# ['At iteration 10 the best fitness is 0.02634204026045544']
# ['At iteration 11 the best fitness is 0.02634204026045544']
# ['At iteration 12 the best fitness is 0.02634204026045544']
# ['At iteration 13 the best fitness is 0.02634204026045544']
# ['At iteration 14 the best fitness is 0.02634204026045544']
# ['At iteration 15 the best fitness is 0.02634204026045544']
# ['At iteration 16 the best fitness is 0.0258849929086864']
# ['At iteration 17 the best fitness is 0.0258849929086864']
# ['At iteration 18 the best fitness is 0.0258849929086864']
# ['At iteration 19 the best fitness is 0.0258849929086864']
# ['At iteration 20 the best fitness is 0.0258849929086864']
# ['At iteration 21 the best fitness is 0.0258849929086864']
# ['At iteration 22 the best fitness is 0.0258849929086864']
# ['At iteration 23 the best fitness is 0.0258849929086864']
# ['At iteration 24 the best fitness is 0.0258849929086864']
# ['At iteration 25 the best fitness is 0.0258849929086864']
# ['At iteration 26 the best fitness is 0.0258849929086864']
# ['At iteration 27 the best fitness is 0.0258849929086864']
# ['At iteration 28 the best fitness is 0.0258849929086864']
# ['At iteration 29 the best fitness is 0.0258849929086864']
# ['At iteration 30 the best fitness is 0.0258849929086864']
#       Weights: depth=0.605, sensor=0.371, skeleton=0.578
#       Best fitness: 0.025885, Time: 508.3s
#     Weights: [depth=0.605, sensor=0.371, skeleton=0.578]
#     Test Acc: 98.60%, F1: 98.60%, Model: 6.480MB
#
#   --- WEIGHTED_PSO ---
#     Running weighted_PSO...
#       Search dim: 3, Pop: 20, Iter: 30
# PSO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.03217220971626895']
# ['At iteration 2 the best fitness is 0.03217220971626895']
# ['At iteration 3 the best fitness is 0.03217220971626895']
# ['At iteration 4 the best fitness is 0.03217220971626895']
# ['At iteration 5 the best fitness is 0.03217220971626895']
# ['At iteration 6 the best fitness is 0.03217220971626895']
# ['At iteration 7 the best fitness is 0.03217220971626895']
# ['At iteration 8 the best fitness is 0.03217220971626895']
# ['At iteration 9 the best fitness is 0.03217220971626895']
# ['At iteration 10 the best fitness is 0.02793399936386517']
# ['At iteration 11 the best fitness is 0.02793399936386517']
# ['At iteration 12 the best fitness is 0.02793399936386517']
# ['At iteration 13 the best fitness is 0.02793399936386517']
# ['At iteration 14 the best fitness is 0.02793399936386517']
# ['At iteration 15 the best fitness is 0.02793399936386517']
# ['At iteration 16 the best fitness is 0.02793399936386517']
# ['At iteration 17 the best fitness is 0.02793399936386517']
# ['At iteration 18 the best fitness is 0.02793399936386517']
# ['At iteration 19 the best fitness is 0.02583188041379409']
# ['At iteration 20 the best fitness is 0.02583188041379409']
# ['At iteration 21 the best fitness is 0.02583188041379409']
# ['At iteration 22 the best fitness is 0.02583188041379409']
# ['At iteration 23 the best fitness is 0.02583188041379409']
# ['At iteration 24 the best fitness is 0.02583188041379409']
# ['At iteration 25 the best fitness is 0.02583188041379409']
# ['At iteration 26 the best fitness is 0.02583188041379409']
# ['At iteration 27 the best fitness is 0.02583188041379409']
# ['At iteration 28 the best fitness is 0.02583188041379409']
# ['At iteration 29 the best fitness is 0.02583188041379409']
# ['At iteration 30 the best fitness is 0.02583188041379409']
#       Weights: depth=0.974, sensor=0.803, skeleton=0.211
#       Best fitness: 0.025832, Time: 495.0s
#     Weights: [depth=0.974, sensor=0.803, skeleton=0.211]
#     Test Acc: 96.85%, F1: 96.89%, Model: 6.480MB
#
#   --- WEIGHTED_SCA ---
#     Running weighted_SCA...
#       Search dim: 3, Pop: 20, Iter: 30
# SCA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.026583171715693816']
# ['At iteration 1 the best fitness is 0.026583171715693816']
# ['At iteration 2 the best fitness is 0.026583171715693816']
# ['At iteration 3 the best fitness is 0.026583171715693816']
# ['At iteration 4 the best fitness is 0.026583171715693816']
# ['At iteration 5 the best fitness is 0.026583171715693816']
# ['At iteration 6 the best fitness is 0.026583171715693816']
# ['At iteration 7 the best fitness is 0.026583171715693816']
# ['At iteration 8 the best fitness is 0.026583171715693816']
# ['At iteration 9 the best fitness is 0.026583171715693816']
# ['At iteration 10 the best fitness is 0.026583171715693816']
# ['At iteration 11 the best fitness is 0.025869064099554504']
# ['At iteration 12 the best fitness is 0.025869064099554504']
# ['At iteration 13 the best fitness is 0.025869064099554504']
# ['At iteration 14 the best fitness is 0.025869064099554504']
# ['At iteration 15 the best fitness is 0.025869064099554504']
# ['At iteration 16 the best fitness is 0.025869064099554504']
# ['At iteration 17 the best fitness is 0.025869064099554504']
# ['At iteration 18 the best fitness is 0.025869064099554504']
# ['At iteration 19 the best fitness is 0.025869064099554504']
# ['At iteration 20 the best fitness is 0.025869064099554504']
# ['At iteration 21 the best fitness is 0.025869064099554504']
# ['At iteration 22 the best fitness is 0.025869064099554504']
# ['At iteration 23 the best fitness is 0.025869064099554504']
# ['At iteration 24 the best fitness is 0.025869064099554504']
# ['At iteration 25 the best fitness is 0.025869064099554504']
# ['At iteration 26 the best fitness is 0.025869064099554504']
# ['At iteration 27 the best fitness is 0.025869064099554504']
# ['At iteration 28 the best fitness is 0.025869064099554504']
# ['At iteration 29 the best fitness is 0.025869064099554504']
#       Weights: depth=0.085, sensor=0.687, skeleton=0.463
#       Best fitness: 0.025869, Time: 488.7s
#     Weights: [depth=0.085, sensor=0.687, skeleton=0.463]
#     Test Acc: 97.20%, F1: 97.15%, Model: 6.480MB
#
#   --- WEIGHTED_SSA ---
#     Running weighted_SSA...
#       Search dim: 3, Pop: 20, Iter: 30
# SSA is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.028505596864436353']
# ['At iteration 2 the best fitness is 0.028505596864436353']
# ['At iteration 3 the best fitness is 0.028505596864436353']
# ['At iteration 4 the best fitness is 0.02734086163608091']
# ['At iteration 5 the best fitness is 0.02734086163608091']
# ['At iteration 6 the best fitness is 0.02734086163608091']
# ['At iteration 7 the best fitness is 0.025155437711094106']
# ['At iteration 8 the best fitness is 0.025155437711094106']
# ['At iteration 9 the best fitness is 0.025155437711094106']
# ['At iteration 10 the best fitness is 0.025155437711094106']
# ['At iteration 11 the best fitness is 0.025155437711094106']
# ['At iteration 12 the best fitness is 0.025155437711094106']
# ['At iteration 13 the best fitness is 0.025155437711094106']
# ['At iteration 14 the best fitness is 0.025155437711094106']
# ['At iteration 15 the best fitness is 0.025155437711094106']
# ['At iteration 16 the best fitness is 0.024730406302426542']
# ['At iteration 17 the best fitness is 0.024730406302426542']
# ['At iteration 18 the best fitness is 0.024730406302426542']
# ['At iteration 19 the best fitness is 0.024730406302426542']
# ['At iteration 20 the best fitness is 0.023086779484791414']
# ['At iteration 21 the best fitness is 0.023086779484791414']
# ['At iteration 22 the best fitness is 0.023086779484791414']
# ['At iteration 23 the best fitness is 0.023086779484791414']
# ['At iteration 24 the best fitness is 0.023086779484791414']
# ['At iteration 25 the best fitness is 0.023086779484791414']
# ['At iteration 26 the best fitness is 0.023086779484791414']
# ['At iteration 27 the best fitness is 0.023086779484791414']
# ['At iteration 28 the best fitness is 0.023086779484791414']
# ['At iteration 29 the best fitness is 0.023086779484791414']
#       Weights: depth=0.214, sensor=0.759, skeleton=0.627
#       Best fitness: 0.023087, Time: 1182.6s
#     Weights: [depth=0.214, sensor=0.759, skeleton=0.627]
#     Test Acc: 96.85%, F1: 96.81%, Model: 6.480MB
#
#   --- WEIGHTED_WOA ---
#     Running weighted_WOA...
#       Search dim: 3, Pop: 20, Iter: 30
# WOA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.04241992164004062']
# ['At iteration 1 the best fitness is 0.02695239202252456']
# ['At iteration 2 the best fitness is 0.02695239202252456']
# ['At iteration 3 the best fitness is 0.021382671115653857']
# ['At iteration 4 the best fitness is 0.021382671115653857']
# ['At iteration 5 the best fitness is 0.021382671115653857']
# ['At iteration 6 the best fitness is 0.021382671115653857']
# ['At iteration 7 the best fitness is 0.021382671115653857']
# ['At iteration 8 the best fitness is 0.021382671115653857']
# ['At iteration 9 the best fitness is 0.021382671115653857']
# ['At iteration 10 the best fitness is 0.021382671115653857']
# ['At iteration 11 the best fitness is 0.021382671115653857']
# ['At iteration 12 the best fitness is 0.021382671115653857']
# ['At iteration 13 the best fitness is 0.021382671115653857']
# ['At iteration 14 the best fitness is 0.021382671115653857']
# ['At iteration 15 the best fitness is 0.021382671115653857']
# ['At iteration 16 the best fitness is 0.021382671115653857']
# ['At iteration 17 the best fitness is 0.021382671115653857']
# ['At iteration 18 the best fitness is 0.021382671115653857']
# ['At iteration 19 the best fitness is 0.021382671115653857']
# ['At iteration 20 the best fitness is 0.021382671115653857']
# ['At iteration 21 the best fitness is 0.021382671115653857']
# ['At iteration 22 the best fitness is 0.021382671115653857']
# ['At iteration 23 the best fitness is 0.021382671115653857']
# ['At iteration 24 the best fitness is 0.021382671115653857']
# ['At iteration 25 the best fitness is 0.021382671115653857']
# ['At iteration 26 the best fitness is 0.021382671115653857']
# ['At iteration 27 the best fitness is 0.021382671115653857']
# ['At iteration 28 the best fitness is 0.021382671115653857']
# ['At iteration 29 the best fitness is 0.021382671115653857']
#       Weights: depth=1.000, sensor=1.000, skeleton=1.000
#       Best fitness: 0.021383, Time: 453.3s
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000]
#     Test Acc: 97.20%, F1: 97.20%, Model: 6.480MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Test subject : ['qyh']
#   Val  subject : zyh
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000]
#     Test Acc: 92.53%, F1: 92.75%, Model: 6.480MB
#
#   --- WEIGHTED_BAT ---
#     Running weighted_BAT...
#       Search dim: 3, Pop: 20, Iter: 30
# BAT is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.014421637569155012']
# ['At iteration 1 the best fitness is 0.014421637569155012']
# ['At iteration 2 the best fitness is 0.014421637569155012']
# ['At iteration 3 the best fitness is 0.013853161396192653']
# ['At iteration 4 the best fitness is 0.013853161396192653']
# ['At iteration 5 the best fitness is 0.013853161396192653']
# ['At iteration 6 the best fitness is 0.013853161396192653']
# ['At iteration 7 the best fitness is 0.013853161396192653']
# ['At iteration 8 the best fitness is 0.013853161396192653']
# ['At iteration 9 the best fitness is 0.013853161396192653']
# ['At iteration 10 the best fitness is 0.013853161396192653']
# ['At iteration 11 the best fitness is 0.013853161396192653']
# ['At iteration 12 the best fitness is 0.013853161396192653']
# ['At iteration 13 the best fitness is 0.013853161396192653']
# ['At iteration 14 the best fitness is 0.013853161396192653']
# ['At iteration 15 the best fitness is 0.013853161396192653']
# ['At iteration 16 the best fitness is 0.013853161396192653']
# ['At iteration 17 the best fitness is 0.013853161396192653']
# ['At iteration 18 the best fitness is 0.013853161396192653']
# ['At iteration 19 the best fitness is 0.013853161396192653']
# ['At iteration 20 the best fitness is 0.013853161396192653']
# ['At iteration 21 the best fitness is 0.013853161396192653']
# ['At iteration 22 the best fitness is 0.013853161396192653']
# ['At iteration 23 the best fitness is 0.013853161396192653']
# ['At iteration 24 the best fitness is 0.013853161396192653']
# ['At iteration 25 the best fitness is 0.013853161396192653']
# ['At iteration 26 the best fitness is 0.013853161396192653']
# ['At iteration 27 the best fitness is 0.013853161396192653']
# ['At iteration 28 the best fitness is 0.013853161396192653']
# ['At iteration 29 the best fitness is 0.013853161396192653']
#       Weights: depth=0.314, sensor=0.350, skeleton=0.423
#       Best fitness: 0.013853, Time: 496.0s
#     Weights: [depth=0.314, sensor=0.350, skeleton=0.423]
#     Test Acc: 92.95%, F1: 93.10%, Model: 6.480MB
#
#   --- WEIGHTED_CS ---
#     Running weighted_CS...
#       Search dim: 3, Pop: 20, Iter: 30
# CS is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.01805196749046445']
# ['At iteration 1 the best fitness is 0.01805196749046445']
# ['At iteration 2 the best fitness is 0.016880986147693226']
# ['At iteration 3 the best fitness is 0.014463286381214857']
# ['At iteration 4 the best fitness is 0.014463286381214857']
# ['At iteration 5 the best fitness is 0.014463286381214857']
# ['At iteration 6 the best fitness is 0.014359681401401758']
# ['At iteration 7 the best fitness is 0.014359681401401758']
# ['At iteration 8 the best fitness is 0.014359681401401758']
# ['At iteration 9 the best fitness is 0.014359681401401758']
# ['At iteration 10 the best fitness is 0.014359681401401758']
# ['At iteration 11 the best fitness is 0.014359681401401758']
# ['At iteration 12 the best fitness is 0.012348915915936232']
# ['At iteration 13 the best fitness is 0.012348915915936232']
# ['At iteration 14 the best fitness is 0.012348915915936232']
# ['At iteration 15 the best fitness is 0.012348915915936232']
# ['At iteration 16 the best fitness is 0.012348915915936232']
# ['At iteration 17 the best fitness is 0.012348915915936232']
# ['At iteration 18 the best fitness is 0.012348915915936232']
# ['At iteration 19 the best fitness is 0.012348915915936232']
# ['At iteration 20 the best fitness is 0.012348915915936232']
# ['At iteration 21 the best fitness is 0.012348915915936232']
# ['At iteration 22 the best fitness is 0.012348915915936232']
# ['At iteration 23 the best fitness is 0.012348915915936232']
# ['At iteration 24 the best fitness is 0.012348915915936232']
# ['At iteration 25 the best fitness is 0.012348915915936232']
# ['At iteration 26 the best fitness is 0.012348915915936232']
# ['At iteration 27 the best fitness is 0.012348915915936232']
# ['At iteration 28 the best fitness is 0.012348915915936232']
# ['At iteration 29 the best fitness is 0.012348915915936232']
#       Weights: depth=0.556, sensor=0.417, skeleton=0.620
#       Best fitness: 0.012349, Time: 974.4s
#     Weights: [depth=0.556, sensor=0.417, skeleton=0.620]
#     Test Acc: 92.95%, F1: 93.09%, Model: 6.480MB
#
#   --- WEIGHTED_DE ---
#     Running weighted_DE...
#       Search dim: 3, Pop: 20, Iter: 30
# DE is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.015802976675331593']
# ['At iteration 2 the best fitness is 0.015802976675331593']
# ['At iteration 3 the best fitness is 0.015802976675331593']
# ['At iteration 4 the best fitness is 0.015494312026671']
# ['At iteration 5 the best fitness is 0.015494312026671']
# ['At iteration 6 the best fitness is 0.015435531602374144']
# ['At iteration 7 the best fitness is 0.015435531602374144']
# ['At iteration 8 the best fitness is 0.015435531602374144']
# ['At iteration 9 the best fitness is 0.015435531602374144']
# ['At iteration 10 the best fitness is 0.015435531602374144']
# ['At iteration 11 the best fitness is 0.015435531602374144']
# ['At iteration 12 the best fitness is 0.014438014178137695']
# ['At iteration 13 the best fitness is 0.014438014178137695']
# ['At iteration 14 the best fitness is 0.014438014178137695']
# ['At iteration 15 the best fitness is 0.014438014178137695']
# ['At iteration 16 the best fitness is 0.014438014178137695']
# ['At iteration 17 the best fitness is 0.014438014178137695']
# ['At iteration 18 the best fitness is 0.014438014178137695']
# ['At iteration 19 the best fitness is 0.014438014178137695']
# ['At iteration 20 the best fitness is 0.014022684256945337']
# ['At iteration 21 the best fitness is 0.014022684256945337']
# ['At iteration 22 the best fitness is 0.014022684256945337']
# ['At iteration 23 the best fitness is 0.014022684256945337']
# ['At iteration 24 the best fitness is 0.014022684256945337']
# ['At iteration 25 the best fitness is 0.014022684256945337']
# ['At iteration 26 the best fitness is 0.014022684256945337']
# ['At iteration 27 the best fitness is 0.014022684256945337']
# ['At iteration 28 the best fitness is 0.014022684256945337']
# ['At iteration 29 the best fitness is 0.014022684256945337']
# ['At iteration 30 the best fitness is 0.014022684256945337']
#       Weights: depth=0.811, sensor=0.554, skeleton=0.988
#       Best fitness: 0.014023, Time: 495.0s
#     Weights: [depth=0.811, sensor=0.554, skeleton=0.988]
#     Test Acc: 92.12%, F1: 92.27%, Model: 6.480MB
#
#   --- WEIGHTED_FFA ---
#     Running weighted_FFA...
#       Search dim: 3, Pop: 20, Iter: 30
# FFA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.01853572390973568']
# ['At iteration 1 the best fitness is 0.016387532465159893']
# ['At iteration 2 the best fitness is 0.014923963496195418']
# ['At iteration 3 the best fitness is 0.01563737794224705']
# ['At iteration 4 the best fitness is 0.017477689909615686']
# ['At iteration 5 the best fitness is 0.018231411797127554']
# ['At iteration 6 the best fitness is 0.015000960656574793']
# ['At iteration 7 the best fitness is 0.015196944254317455']
# ['At iteration 8 the best fitness is 0.014555899825479304']
# ['At iteration 9 the best fitness is 0.01676716928237251']
# ['At iteration 10 the best fitness is 0.01629782421514392']
# ['At iteration 11 the best fitness is 0.01522422774827906']
# ['At iteration 12 the best fitness is 0.013600193030600036']
# ['At iteration 13 the best fitness is 0.013147933009479727']
# ['At iteration 14 the best fitness is 0.013871830488954271']
# ['At iteration 15 the best fitness is 0.013811161408999137']
# ['At iteration 16 the best fitness is 0.01441793077226196']
# ['At iteration 17 the best fitness is 0.015136862373245614']
# ['At iteration 18 the best fitness is 0.01619949537728514']
# ['At iteration 19 the best fitness is 0.015451101852314813']
# ['At iteration 20 the best fitness is 0.014376806361334664']
# ['At iteration 21 the best fitness is 0.014297833067498036']
# ['At iteration 22 the best fitness is 0.01564794938479151']
# ['At iteration 23 the best fitness is 0.016042488361043588']
# ['At iteration 24 the best fitness is 0.01598932853500758']
# ['At iteration 25 the best fitness is 0.013088909376944815']
# ['At iteration 26 the best fitness is 0.016394705045968294']
# ['At iteration 27 the best fitness is 0.013965655583888292']
# ['At iteration 28 the best fitness is 0.0160859917689647']
# ['At iteration 29 the best fitness is 0.014240304274218423']
#       Weights: depth=0.000, sensor=0.256, skeleton=0.343
#       Best fitness: 0.014240, Time: 478.2s
#     Weights: [depth=0.000, sensor=0.256, skeleton=0.343]
#     Test Acc: 92.53%, F1: 92.67%, Model: 6.480MB
#
#   --- WEIGHTED_GA ---
#     Running weighted_GA...
#       Search dim: 3, Pop: 20, Iter: 30
# GA is optimizing  "fitness"
# At iteration 1 the best fitness is 0.017349528281816413
# At iteration 2 the best fitness is 0.015883839456364512
# At iteration 3 the best fitness is 0.01502074088369097
# At iteration 4 the best fitness is 0.015472074904079949
# At iteration 5 the best fitness is 0.014917408382253987
# At iteration 6 the best fitness is 0.017694083641150167
# At iteration 7 the best fitness is 0.016919522413185666
# At iteration 8 the best fitness is 0.017616504271115576
# At iteration 9 the best fitness is 0.01460166834294796
# At iteration 10 the best fitness is 0.01628788068358387
# At iteration 11 the best fitness is 0.017028450899358307
# At iteration 12 the best fitness is 0.017189942566411837
# At iteration 13 the best fitness is 0.012647363024630718
# At iteration 14 the best fitness is 0.015774379085217203
# At iteration 15 the best fitness is 0.01732757474694933
# At iteration 16 the best fitness is 0.014830781080360924
# At iteration 17 the best fitness is 0.016970291334603513
# At iteration 18 the best fitness is 0.015348916008536304
# At iteration 19 the best fitness is 0.016697497173611606
# At iteration 20 the best fitness is 0.017063674849591086
# At iteration 21 the best fitness is 0.016802324181688682
# At iteration 22 the best fitness is 0.015213265482868468
# At iteration 23 the best fitness is 0.016504717791186913
# At iteration 24 the best fitness is 0.015336539263703994
# At iteration 25 the best fitness is 0.018477403425744603
# At iteration 26 the best fitness is 0.0157784543532346
# At iteration 27 the best fitness is 0.01548309251666069
# At iteration 28 the best fitness is 0.01665198496942009
# At iteration 29 the best fitness is 0.017013086139091423
# At iteration 30 the best fitness is 0.01423733841095652
#       Weights: depth=0.307, sensor=0.614, skeleton=0.883
#       Best fitness: 0.014237, Time: 478.8s
#     Weights: [depth=0.307, sensor=0.614, skeleton=0.883]
#     Test Acc: 91.29%, F1: 91.35%, Model: 6.480MB
#
#   --- WEIGHTED_GWO ---
#     Running weighted_GWO...
#       Search dim: 3, Pop: 20, Iter: 30
# GWO is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.018833949230611324']
# ['At iteration 1 the best fitness is 0.01707447094044515']
# ['At iteration 2 the best fitness is 0.015672600029834678']
# ['At iteration 3 the best fitness is 0.015672600029834678']
# ['At iteration 4 the best fitness is 0.015672600029834678']
# ['At iteration 5 the best fitness is 0.015672600029834678']
# ['At iteration 6 the best fitness is 0.015672600029834678']
# ['At iteration 7 the best fitness is 0.015672600029834678']
# ['At iteration 8 the best fitness is 0.015672600029834678']
# ['At iteration 9 the best fitness is 0.015672600029834678']
# ['At iteration 10 the best fitness is 0.015072801948658057']
# ['At iteration 11 the best fitness is 0.015064384921320848']
# ['At iteration 12 the best fitness is 0.014242899338049548']
# ['At iteration 13 the best fitness is 0.014242899338049548']
# ['At iteration 14 the best fitness is 0.014242899338049548']
# ['At iteration 15 the best fitness is 0.014128294906445913']
# ['At iteration 16 the best fitness is 0.014128294906445913']
# ['At iteration 17 the best fitness is 0.014128294906445913']
# ['At iteration 18 the best fitness is 0.014128294906445913']
# ['At iteration 19 the best fitness is 0.014128294906445913']
# ['At iteration 20 the best fitness is 0.014128294906445913']
# ['At iteration 21 the best fitness is 0.014128294906445913']
# ['At iteration 22 the best fitness is 0.014128294906445913']
# ['At iteration 23 the best fitness is 0.014128294906445913']
# ['At iteration 24 the best fitness is 0.013674557807722263']
# ['At iteration 25 the best fitness is 0.013674557807722263']
# ['At iteration 26 the best fitness is 0.013674557807722263']
# ['At iteration 27 the best fitness is 0.013674557807722263']
# ['At iteration 28 the best fitness is 0.013674557807722263']
# ['At iteration 29 the best fitness is 0.013674557807722263']
#       Weights: depth=0.421, sensor=0.708, skeleton=0.726
#       Best fitness: 0.013675, Time: 478.6s
#     Weights: [depth=0.421, sensor=0.708, skeleton=0.726]
#     Test Acc: 92.12%, F1: 92.31%, Model: 6.480MB
#
#   --- WEIGHTED_HHO ---
#     Running weighted_HHO...
#       Search dim: 3, Pop: 20, Iter: 30
# HHO is now tackling  "fitness"
# ['At iteration 0 the best fitness is 0.018883435986936092']
# ['At iteration 1 the best fitness is 0.015759417321532965']
# ['At iteration 2 the best fitness is 0.015759417321532965']
# ['At iteration 3 the best fitness is 0.015759417321532965']
# ['At iteration 4 the best fitness is 0.014166438353380986']
# ['At iteration 5 the best fitness is 0.014166438353380986']
# ['At iteration 6 the best fitness is 0.014166438353380986']
# ['At iteration 7 the best fitness is 0.014166438353380986']
# ['At iteration 8 the best fitness is 0.014166438353380986']
# ['At iteration 9 the best fitness is 0.014166438353380986']
# ['At iteration 10 the best fitness is 0.014166438353380986']
# ['At iteration 11 the best fitness is 0.014166438353380986']
# ['At iteration 12 the best fitness is 0.014166438353380986']
# ['At iteration 13 the best fitness is 0.014166438353380986']
# ['At iteration 14 the best fitness is 0.014166438353380986']
# ['At iteration 15 the best fitness is 0.014166438353380986']
# ['At iteration 16 the best fitness is 0.014166438353380986']
# ['At iteration 17 the best fitness is 0.014166438353380986']
# ['At iteration 18 the best fitness is 0.014166438353380986']
# ['At iteration 19 the best fitness is 0.014166438353380986']
# ['At iteration 20 the best fitness is 0.014166438353380986']
# ['At iteration 21 the best fitness is 0.014166438353380986']
# ['At iteration 22 the best fitness is 0.014166438353380986']
# ['At iteration 23 the best fitness is 0.014166438353380986']
# ['At iteration 24 the best fitness is 0.014166438353380986']
# ['At iteration 25 the best fitness is 0.014086255271519934']
# ['At iteration 26 the best fitness is 0.014086255271519934']
# ['At iteration 27 the best fitness is 0.014086255271519934']
# ['At iteration 28 the best fitness is 0.014086255271519934']
# ['At iteration 29 the best fitness is 0.014086255271519934']
#       Weights: depth=0.000, sensor=0.016, skeleton=0.025
#       Best fitness: 0.014086, Time: 758.0s
#     Weights: [depth=0.000, sensor=0.016, skeleton=0.025]
#     Test Acc: 92.53%, F1: 92.71%, Model: 6.480MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 3, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.01896374300122261']
# ['At iteration 1 the best fitness is 0.01896374300122261']
# ['At iteration 2 the best fitness is 0.01639780049611415']
# ['At iteration 3 the best fitness is 0.014251335158145853']
# ['At iteration 4 the best fitness is 0.014251335158145853']
# ['At iteration 5 the best fitness is 0.014251335158145853']
# ['At iteration 6 the best fitness is 0.014251335158145853']
# ['At iteration 7 the best fitness is 0.014251335158145853']
# ['At iteration 8 the best fitness is 0.014251335158145853']
# ['At iteration 9 the best fitness is 0.014251335158145853']
# ['At iteration 10 the best fitness is 0.014251335158145853']
# ['At iteration 11 the best fitness is 0.014251335158145853']
# ['At iteration 12 the best fitness is 0.014251335158145853']
# ['At iteration 13 the best fitness is 0.014251335158145853']
# ['At iteration 14 the best fitness is 0.014251335158145853']
# ['At iteration 15 the best fitness is 0.014251335158145853']
# ['At iteration 16 the best fitness is 0.014251335158145853']
# ['At iteration 17 the best fitness is 0.014251335158145853']
# ['At iteration 18 the best fitness is 0.014251335158145853']
# ['At iteration 19 the best fitness is 0.014251335158145853']
# ['At iteration 20 the best fitness is 0.014251335158145853']
# ['At iteration 21 the best fitness is 0.014251335158145853']
# ['At iteration 22 the best fitness is 0.014251335158145853']
# ['At iteration 23 the best fitness is 0.014251335158145853']
# ['At iteration 24 the best fitness is 0.014251335158145853']
# ['At iteration 25 the best fitness is 0.014251335158145853']
# ['At iteration 26 the best fitness is 0.014251335158145853']
# ['At iteration 27 the best fitness is 0.014251335158145853']
# ['At iteration 28 the best fitness is 0.014251335158145853']
# ['At iteration 29 the best fitness is 0.014251335158145853']
#       Weights: depth=0.428, sensor=0.301, skeleton=0.588
#       Best fitness: 0.014251, Time: 491.9s
#     Weights: [depth=0.428, sensor=0.301, skeleton=0.588]
#     Test Acc: 93.36%, F1: 93.51%, Model: 6.480MB
#
# ...
# ['At iteration 14 the best fitness is 0.15584010677412152']
# ['At iteration 15 the best fitness is 0.15584010677412152']
# ['At iteration 16 the best fitness is 0.15584010677412152']
# ['At iteration 17 the best fitness is 0.15584010677412152']
# ['At iteration 18 the best fitness is 0.15584010677412152']
# ['At iteration 19 the best fitness is 0.15584010677412152']
# ['At iteration 20 the best fitness is 0.15584010677412152']
# ['At iteration 21 the best fitness is 0.15584010677412152']
# ['At iteration 22 the best fitness is 0.15584010677412152']
# ['At iteration 23 the best fitness is 0.15584010677412152']
# ['At iteration 24 the best fitness is 0.15584010677412152']
# ['At iteration 25 the best fitness is 0.15584010677412152']
# ['At iteration 26 the best fitness is 0.15584010677412152']
# ['At iteration 27 the best fitness is 0.15584010677412152']
# ['At iteration 28 the best fitness is 0.15584010677412152']
# ['At iteration 29 the best fitness is 0.15584010677412152']
#       Weights: depth=0.732, sensor=0.752, skeleton=0.041
#       Best fitness: 0.155840, Time: 819.1s
#     Weights: [depth=0.732, sensor=0.752, skeleton=0.041]
#     Test Acc: 94.95%, F1: 94.53%, Model: 6.480MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 3, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.187603659927845']
# ['At iteration 1 the best fitness is 0.1826863707974553']
# ['At iteration 2 the best fitness is 0.16563755716197193']
# ['At iteration 3 the best fitness is 0.16563755716197193']
# ['At iteration 4 the best fitness is 0.1643742574378848']
# ['At iteration 5 the best fitness is 0.1643742574378848']
# ['At iteration 6 the best fitness is 0.1643742574378848']
# ['At iteration 7 the best fitness is 0.1643742574378848']
# ['At iteration 8 the best fitness is 0.1643742574378848']
# ['At iteration 9 the best fitness is 0.15894176065921783']
# ['At iteration 10 the best fitness is 0.15894176065921783']
# ['At iteration 11 the best fitness is 0.15894176065921783']
# ['At iteration 12 the best fitness is 0.15894176065921783']
# ['At iteration 13 the best fitness is 0.15894176065921783']
# ['At iteration 14 the best fitness is 0.15894176065921783']
# ['At iteration 15 the best fitness is 0.15894176065921783']
# ['At iteration 16 the best fitness is 0.15894176065921783']
# ['At iteration 17 the best fitness is 0.15894176065921783']
# ['At iteration 18 the best fitness is 0.15894176065921783']
# ['At iteration 19 the best fitness is 0.15894176065921783']
# ['At iteration 20 the best fitness is 0.15894176065921783']
# ['At iteration 21 the best fitness is 0.15894176065921783']
# ['At iteration 22 the best fitness is 0.15894176065921783']
# ['At iteration 23 the best fitness is 0.15894176065921783']
# ['At iteration 24 the best fitness is 0.15894176065921783']
# ['At iteration 25 the best fitness is 0.15894176065921783']
# ['At iteration 26 the best fitness is 0.15894176065921783']
# ['At iteration 27 the best fitness is 0.15894176065921783']
# ['At iteration 28 the best fitness is 0.15894176065921783']
# ['At iteration 29 the best fitness is 0.15894176065921783']
#       Weights: depth=0.862, sensor=0.577, skeleton=0.034
#       Best fitness: 0.158942, Time: 503.6s
#     Weights: [depth=0.862, sensor=0.577, skeleton=0.034]
#     Test Acc: 91.41%, F1: 89.81%, Model: 6.480MB
#
#   --- WEIGHTED_MFO ---
#     Running weighted_MFO...
#       Search dim: 3, Pop: 20, Iter: 30
# MFO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.18206594279035926']
# ['At iteration 2 the best fitness is 0.18206594279035926']
# ['At iteration 3 the best fitness is 0.18206594279035926']
# ['At iteration 4 the best fitness is 0.17866496788337827']
# ['At iteration 5 the best fitness is 0.17866496788337827']
# ['At iteration 6 the best fitness is 0.1756905778311193']
# ['At iteration 7 the best fitness is 0.1756905778311193']
# ['At iteration 8 the best fitness is 0.1756905778311193']
# ['At iteration 9 the best fitness is 0.17121648788452148']
# ['At iteration 10 the best fitness is 0.17121648788452148']
# ['At iteration 11 the best fitness is 0.16670496994629502']
# ['At iteration 12 the best fitness is 0.16670496994629502']
# ['At iteration 13 the best fitness is 0.16482730861753225']
# ['At iteration 14 the best fitness is 0.16482730861753225']
# ['At iteration 15 the best fitness is 0.16482730861753225']
# ['At iteration 16 the best fitness is 0.16482730861753225']
# ['At iteration 17 the best fitness is 0.16482730861753225']
# ['At iteration 18 the best fitness is 0.16482730861753225']
# ['At iteration 19 the best fitness is 0.16482730861753225']
# ['At iteration 20 the best fitness is 0.1537436917424202']
# ['At iteration 21 the best fitness is 0.1537436917424202']
# ['At iteration 22 the best fitness is 0.1537436917424202']
# ['At iteration 23 the best fitness is 0.1537436917424202']
# ['At iteration 24 the best fitness is 0.1537436917424202']
# ['At iteration 25 the best fitness is 0.1537436917424202']
# ['At iteration 26 the best fitness is 0.1537436917424202']
# ['At iteration 27 the best fitness is 0.1537436917424202']
# ['At iteration 28 the best fitness is 0.1537436917424202']
# ['At iteration 29 the best fitness is 0.1537436917424202']
#       Weights: depth=0.238, sensor=0.526, skeleton=0.041
#       Best fitness: 0.153744, Time: 468.1s
#     Weights: [depth=0.238, sensor=0.526, skeleton=0.041]
#     Test Acc: 95.45%, F1: 95.03%, Model: 6.480MB
#
#   --- WEIGHTED_MVO ---
#     Running weighted_MVO...
#       Search dim: 3, Pop: 20, Iter: 30
# MVO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.19355564936995506']
# ['At iteration 2 the best fitness is 0.16934377327561378']
# ['At iteration 3 the best fitness is 0.16643505450338125']
# ['At iteration 4 the best fitness is 0.16643505450338125']
# ['At iteration 5 the best fitness is 0.16366905206814408']
# ['At iteration 6 the best fitness is 0.16366905206814408']
# ['At iteration 7 the best fitness is 0.16366905206814408']
# ['At iteration 8 the best fitness is 0.15764704952016473']
# ['At iteration 9 the best fitness is 0.15764704952016473']
# ['At iteration 10 the best fitness is 0.15764704952016473']
# ['At iteration 11 the best fitness is 0.15764704952016473']
# ['At iteration 12 the best fitness is 0.15764704952016473']
# ['At iteration 13 the best fitness is 0.15764704952016473']
# ['At iteration 14 the best fitness is 0.15764704952016473']
# ['At iteration 15 the best fitness is 0.15764704952016473']
# ['At iteration 16 the best fitness is 0.15764704952016473']
# ['At iteration 17 the best fitness is 0.15764704952016473']
# ['At iteration 18 the best fitness is 0.15764704952016473']
# ['At iteration 19 the best fitness is 0.15764704952016473']
# ['At iteration 20 the best fitness is 0.15764704952016473']
# ['At iteration 21 the best fitness is 0.15764704952016473']
# ['At iteration 22 the best fitness is 0.15764704952016473']
# ['At iteration 23 the best fitness is 0.15764704952016473']
# ['At iteration 24 the best fitness is 0.15764704952016473']
# ['At iteration 25 the best fitness is 0.15764704952016473']
# ['At iteration 26 the best fitness is 0.15502279298380017']
# ['At iteration 27 the best fitness is 0.15502279298380017']
# ['At iteration 28 the best fitness is 0.15502279298380017']
# ['At iteration 29 the best fitness is 0.15502279298380017']
# ['At iteration 30 the best fitness is 0.15502279298380017']
#       Weights: depth=0.844, sensor=0.849, skeleton=0.061
#       Best fitness: 0.155023, Time: 476.1s
#     Weights: [depth=0.844, sensor=0.849, skeleton=0.061]
#     Test Acc: 94.95%, F1: 94.53%, Model: 6.480MB
#
#   --- WEIGHTED_PSO ---
#     Running weighted_PSO...
#       Search dim: 3, Pop: 20, Iter: 30
# PSO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.1750220323447138']
# ['At iteration 2 the best fitness is 0.17033143248409033']
# ['At iteration 3 the best fitness is 0.17033143248409033']
# ['At iteration 4 the best fitness is 0.17033143248409033']
# ['At iteration 5 the best fitness is 0.16447359323501587']
# ['At iteration 6 the best fitness is 0.16447359323501587']
# ['At iteration 7 the best fitness is 0.16447359323501587']
# ['At iteration 8 the best fitness is 0.16447359323501587']
# ['At iteration 9 the best fitness is 0.16447359323501587']
# ['At iteration 10 the best fitness is 0.16447359323501587']
# ['At iteration 11 the best fitness is 0.16447359323501587']
# ['At iteration 12 the best fitness is 0.16447359323501587']
# ['At iteration 13 the best fitness is 0.1609096610918641']
# ['At iteration 14 the best fitness is 0.1609096610918641']
# ['At iteration 15 the best fitness is 0.1609096610918641']
# ['At iteration 16 the best fitness is 0.1609096610918641']
# ['At iteration 17 the best fitness is 0.1609096610918641']
# ['At iteration 18 the best fitness is 0.1609096610918641']
# ['At iteration 19 the best fitness is 0.15352109260857105']
# ['At iteration 20 the best fitness is 0.15352109260857105']
# ['At iteration 21 the best fitness is 0.15352109260857105']
# ['At iteration 22 the best fitness is 0.15352109260857105']
# ['At iteration 23 the best fitness is 0.15352109260857105']
# ['At iteration 24 the best fitness is 0.15352109260857105']
# ['At iteration 25 the best fitness is 0.15352109260857105']
# ['At iteration 26 the best fitness is 0.15352109260857105']
# ['At iteration 27 the best fitness is 0.15352109260857105']
# ['At iteration 28 the best fitness is 0.15352109260857105']
# ['At iteration 29 the best fitness is 0.15352109260857105']
# ['At iteration 30 the best fitness is 0.15352109260857105']
#       Weights: depth=0.023, sensor=0.815, skeleton=0.050
#       Best fitness: 0.153521, Time: 472.3s
#     Weights: [depth=0.023, sensor=0.815, skeleton=0.050]
#     Test Acc: 93.94%, F1: 93.51%, Model: 6.480MB
#
#   --- WEIGHTED_SCA ---
#     Running weighted_SCA...
#       Search dim: 3, Pop: 20, Iter: 30
# SCA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.17887966753914952']
# ['At iteration 1 the best fitness is 0.17887966753914952']
# ['At iteration 2 the best fitness is 0.17887966753914952']
# ['At iteration 3 the best fitness is 0.17887966753914952']
# ['At iteration 4 the best fitness is 0.1690153470262885']
# ['At iteration 5 the best fitness is 0.1690153470262885']
# ['At iteration 6 the best fitness is 0.1690153470262885']
# ['At iteration 7 the best fitness is 0.15958662796765566']
# ['At iteration 8 the best fitness is 0.15958662796765566']
# ['At iteration 9 the best fitness is 0.15958662796765566']
# ['At iteration 10 the best fitness is 0.15958662796765566']
# ['At iteration 11 the best fitness is 0.15958662796765566']
# ['At iteration 12 the best fitness is 0.15958662796765566']
# ['At iteration 13 the best fitness is 0.15958662796765566']
# ['At iteration 14 the best fitness is 0.15958662796765566']
# ['At iteration 15 the best fitness is 0.15958662796765566']
# ['At iteration 16 the best fitness is 0.15958662796765566']
# ['At iteration 17 the best fitness is 0.15958662796765566']
# ['At iteration 18 the best fitness is 0.15958662796765566']
# ['At iteration 19 the best fitness is 0.15958662796765566']
# ['At iteration 20 the best fitness is 0.15958662796765566']
# ['At iteration 21 the best fitness is 0.15958662796765566']
# ['At iteration 22 the best fitness is 0.15626132488250732']
# ['At iteration 23 the best fitness is 0.15626132488250732']
# ['At iteration 24 the best fitness is 0.15626132488250732']
# ['At iteration 25 the best fitness is 0.15626132488250732']
# ['At iteration 26 the best fitness is 0.15626132488250732']
# ['At iteration 27 the best fitness is 0.15626132488250732']
# ['At iteration 28 the best fitness is 0.15626132488250732']
# ['At iteration 29 the best fitness is 0.15626132488250732']
#       Weights: depth=0.000, sensor=1.000, skeleton=0.063
#       Best fitness: 0.156261, Time: 488.4s
#     Weights: [depth=0.000, sensor=1.000, skeleton=0.063]
#     Test Acc: 96.46%, F1: 96.32%, Model: 6.480MB
#
#   --- WEIGHTED_SSA ---
#     Running weighted_SSA...
#       Search dim: 3, Pop: 20, Iter: 30
# SSA is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.16742158588021994']
# ['At iteration 2 the best fitness is 0.16742158588021994']
# ['At iteration 3 the best fitness is 0.16742158588021994']
# ['At iteration 4 the best fitness is 0.16742158588021994']
# ['At iteration 5 the best fitness is 0.16742158588021994']
# ['At iteration 6 the best fitness is 0.16742158588021994']
# ['At iteration 7 the best fitness is 0.16742158588021994']
# ['At iteration 8 the best fitness is 0.16742158588021994']
# ['At iteration 9 the best fitness is 0.16742158588021994']
# ['At iteration 10 the best fitness is 0.16742158588021994']
# ['At iteration 11 the best fitness is 0.16742158588021994']
# ['At iteration 12 the best fitness is 0.16742158588021994']
# ['At iteration 13 the best fitness is 0.1614604494534433']
# ['At iteration 14 the best fitness is 0.1614604494534433']
# ['At iteration 15 the best fitness is 0.1614604494534433']
# ['At iteration 16 the best fitness is 0.1614604494534433']
# ['At iteration 17 the best fitness is 0.15809323266148567']
# ['At iteration 18 the best fitness is 0.15809323266148567']
# ['At iteration 19 the best fitness is 0.15809323266148567']
# ['At iteration 20 the best fitness is 0.1540611474774778']
# ['At iteration 21 the best fitness is 0.1540611474774778']
# ['At iteration 22 the best fitness is 0.1540611474774778']
# ['At iteration 23 the best fitness is 0.1540611474774778']
# ['At iteration 24 the best fitness is 0.1540611474774778']
# ['At iteration 25 the best fitness is 0.1540611474774778']
# ['At iteration 26 the best fitness is 0.1540611474774778']
# ['At iteration 27 the best fitness is 0.1540611474774778']
# ['At iteration 28 the best fitness is 0.1540611474774778']
# ['At iteration 29 the best fitness is 0.1540611474774778']
#       Weights: depth=0.682, sensor=0.984, skeleton=0.052
#       Best fitness: 0.154061, Time: 1225.1s
#     Weights: [depth=0.682, sensor=0.984, skeleton=0.052]
#     Test Acc: 95.96%, F1: 95.73%, Model: 6.480MB
#
#   --- WEIGHTED_WOA ---
#     Running weighted_WOA...
#       Search dim: 3, Pop: 20, Iter: 30
# WOA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.18518005218356848']
# ['At iteration 1 the best fitness is 0.17396449763327837']
# ['At iteration 2 the best fitness is 0.17396449763327837']
# ['At iteration 3 the best fitness is 0.1439120899885893']
# ['At iteration 4 the best fitness is 0.1439120899885893']
# ['At iteration 5 the best fitness is 0.1439120899885893']
# ['At iteration 6 the best fitness is 0.1439120899885893']
# ['At iteration 7 the best fitness is 0.1439120899885893']
# ['At iteration 8 the best fitness is 0.1439120899885893']
# ['At iteration 9 the best fitness is 0.1439120899885893']
# ['At iteration 10 the best fitness is 0.1439120899885893']
# ['At iteration 11 the best fitness is 0.1439120899885893']
# ['At iteration 12 the best fitness is 0.1439120899885893']
# ['At iteration 13 the best fitness is 0.1439120899885893']
# ['At iteration 14 the best fitness is 0.1439120899885893']
# ['At iteration 15 the best fitness is 0.1439120899885893']
# ['At iteration 16 the best fitness is 0.1439120899885893']
# ['At iteration 17 the best fitness is 0.1439120899885893']
# ['At iteration 18 the best fitness is 0.1439120899885893']
# ['At iteration 19 the best fitness is 0.1439120899885893']
# ['At iteration 20 the best fitness is 0.1439120899885893']
# ['At iteration 21 the best fitness is 0.1439120899885893']
# ['At iteration 22 the best fitness is 0.1439120899885893']
# ['At iteration 23 the best fitness is 0.1439120899885893']
# ['At iteration 24 the best fitness is 0.1439120899885893']
# ['At iteration 25 the best fitness is 0.1439120899885893']
# ['At iteration 26 the best fitness is 0.1439120899885893']
# ['At iteration 27 the best fitness is 0.1439120899885893']
# ['At iteration 28 the best fitness is 0.1439120899885893']
# ['At iteration 29 the best fitness is 0.1439120899885893']
#       Weights: depth=0.069, sensor=0.794, skeleton=0.055
#       Best fitness: 0.143912, Time: 488.5s
#     Weights: [depth=0.069, sensor=0.794, skeleton=0.055]
#     Test Acc: 95.45%, F1: 94.81%, Model: 6.480MB
#
# ================================================================================
# ALL WEIGHTED FUSION EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Per-Fold Results CSV

# %%
rows = []
for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'Val Loss': r.get('val_loss', float('inf')),
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Weight Opt Time (s)': r['weight_optimization_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality weights
        mod_w = r['modality_weights']
        for i, mod_name in enumerate(MODALITY_NAMES):
            row[f'w_{mod_name}'] = mod_w[i]
        
        rows.append(row)

df_all = pd.DataFrame(rows).round(4)
df_all.to_csv(RESULTS_ROOT / "all_results_per_fold.csv", index=False)
print(f"Saved: {RESULTS_ROOT / 'all_results_per_fold.csv'}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved: results_weighted_fusion/all_results_per_fold.csv
# Shape: (75, 18)
#           Method  Fold  Test Accuracy (%)  Val Accuracy (%)  Val Loss  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Weight Opt Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  GPU Peak (MB)  w_depth  w_sensor  w_skeleton
# 0       baseline     1            97.9021           99.4949    0.1690       97.9004          97.9004              98.2170           97.9021               0.0000         18.9049         18.9049       1697046           6.4796        55.4844   1.0000    1.0000      1.0000
# 1       baseline     2            92.5311          100.0000    0.0949       92.7474          92.7391              94.3459           92.5207               0.0000         17.8699         17.8700       1697046           6.4796        55.4844   1.0000    1.0000      1.0000
# 2       baseline     3            93.6364          100.0000    0.2032       92.0455          92.0455              91.8831           93.6364               0.0000         18.3333         18.3333       1697046           6.4796        55.4844   1.0000    1.0000      1.0000
# 3       baseline     4            90.9091          100.0000    0.1633       89.8377          89.8377              93.9901           90.9091               0.0000         18.2451         18.2451       1697046           6.4796        55.4844   1.0000    1.0000      1.0000
# 4       baseline     5            99.4949           93.7759    0.4375       99.4934          99.4934              99.5455           99.4949               0.0000         18.2365         18.2365       1697046           6.4796        55.4844   1.0000    1.0000      1.0000
# 5   weighted_BAT     1            97.5524           99.4949    0.2689       97.5407          97.5407              97.9708           97.5524             472.4897         17.5198        490.0097       1697046           6.4796        55.4844   0.0000    1.0000      1.0000
# 6   weighted_BAT     2            92.9461          100.0000    0.1261       93.1030          93.0962              94.4632           92.9339             496.0029         17.9296        513.9325       1697046           6.4796        55.4844   0.3143    0.3503      0.4228
# 7   weighted_BAT     3            97.7273          100.0000    0.1877       97.5758          97.5758              98.4848           97.7273             516.3963         18.6014        534.9978       1697046           6.4796        55.4844   0.4021    0.8267      0.5061
# 8   weighted_BAT     4            95.4545          100.0000    0.0618       95.4030          95.4030              96.1101           95.4545             514.5237         18.4931        533.0168       1697046           6.4796        55.4844   0.4586    0.5914      0.5416
# 9   weighted_BAT     5            95.9596           96.6805    0.1675       95.7052          95.7052              97.2403           95.9596             507.1254         18.0808        525.2063       1697046           6.4796        55.4844   0.3858    0.7208      0.0609
# 10   weighted_CS     1            96.8531           99.4949    0.1688       96.8687          96.8687              97.1206           96.8531            1019.4271         17.3167       1036.7438       1697046           6.4796        55.4844   0.6942    0.2794      0.1717
# 11   weighted_CS     2            92.9461          100.0000    0.1528       93.0851          93.0782              94.4288           92.9339             974.4093         17.6528        992.0621       1697046           6.4796        55.4844   0.5559    0.4171      0.6197
# 12   weighted_CS     3            98.1818          100.0000    0.0740       98.1493          98.1493              98.5378           98.1818            1017.4381         18.4411       1035.8793       1697046           6.4796        55.4844   0.8811    0.9958      0.5453
# 13   weighted_CS     4            93.6364          100.0000    0.1137       93.1635          93.1635              95.4424           93.6364            1011.7901         18.3329       1030.1230       1697046           6.4796        55.4844   0.2527    0.7476      0.4155
# 14   weighted_CS     5            95.4545           97.5104    0.1735       95.1986          95.1986              96.7857           95.4545             997.4051         18.3511       1015.7563       1697046           6.4796        55.4844   0.6400    0.6339      0.0520
# 15   weighted_DE     1            97.9021           99.4949    0.0837       97.9004          97.9004              98.2170           97.9021             505.8687         19.6231        525.4919       1697046           6.4796        55.4844   0.9112    0.9616      0.6657
# 16   weighted_DE     2            92.1162          100.0000    0.0490       92.2725          92.2623              93.6882           92.1074             494.9512         17.6141        512.5654       1697046           6.4796        55.4844   0.8106    0.5538      0.9875
# 17   weighted_DE     3            99.5455          100.0000    0.1130       99.5443          99.5443              99.5868           99.5455             515.8564         18.1671        534.0236       1697046           6.4796        55.4844   1.0000    0.7938      0.5191
# 18   weighted_DE     4            89.0909          100.0000    0.1930       87.6810          87.6810              91.1087           89.0909             513.8334         18.1469        531.9804       1697046           6.4796        55.4844   0.0821    1.0000      0.8154
# 19   weighted_DE     5            95.9596           97.9253    0.1444       95.7052          95.7052              97.2403           95.9596             507.5570         18.1548        525.7118       1697046           6.4796        55.4844   0.1534    0.5320      0.0354

# %% [markdown]
# ## Summary Table

# %%
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Weight Opt Time (s)': method_df['Weight Opt Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    
    for mod_name in MODALITY_NAMES:
        row[f'Mean w_{mod_name}'] = method_df[f'w_{mod_name}'].mean()
        row[f'Std w_{mod_name}'] = method_df[f'w_{mod_name}'].std()
    
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary = df_summary.sort_values('Mean Test Acc (%)', ascending=False)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#        Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Weight Opt Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean GPU Peak (MB)  Mean w_depth  Std w_depth  Mean w_sensor  Std w_sensor  Mean w_skeleton  Std w_skeleton
#  weighted_SCA              96.05              2.18              96.01              2.09                    485.89                17.64               503.52               55.48          0.22         0.44           0.89          0.15             0.62            0.37
#  weighted_BAT              95.93              1.94              95.87              1.84                    501.31                18.12               519.43               55.48          0.31         0.18           0.70          0.25             0.51            0.34
#  weighted_SSA              95.42              2.55              95.26              2.68                   1212.23                17.98              1230.21               55.48          0.50         0.38           0.91          0.09             0.65            0.38
#   weighted_CS              95.41              2.18              95.29              2.24                   1004.09                18.02              1022.11               55.48          0.60         0.23           0.61          0.28             0.36            0.24
#  weighted_HHO              95.35              3.09              95.10              3.33                    790.47                18.17               808.65               55.48          0.49         0.40           0.49          0.40             0.24            0.25
#  weighted_WOA              95.13              3.77              94.71              4.25                    484.20                17.90               502.10               55.48          0.64         0.39           0.80          0.20             0.63            0.39
#  weighted_FFA              95.03              2.38              94.92              2.43                    492.16                18.07               510.23               55.48          0.44         0.52           0.79          0.30             0.50            0.30
#   weighted_DE              94.92              4.28              94.62              4.74                    507.61                18.34               525.95               55.48          0.59         0.44           0.77          0.22             0.60            0.36
#      baseline              94.89              3.65              94.40              4.10                      0.00                18.32                18.32               55.48          1.00         0.00           1.00          0.00             1.00            0.00
#  weighted_MVO              94.84              3.27              94.66              3.45                    491.35                17.92               509.27               55.48          0.68         0.26           0.77          0.24             0.56            0.30
#  weighted_PSO              94.66              3.97              94.34              4.41                    485.82                17.99               503.81               55.48          0.57         0.50           0.84          0.17             0.48            0.34
#  weighted_GWO              94.48              3.99              94.23              4.29                    489.41                18.81               508.23               55.48          0.39         0.27           0.67          0.25             0.50            0.31
# weighted_JAYA              94.06              3.17              93.42              3.78                    508.57                18.30               526.87               55.48          0.35         0.32           0.68          0.24             0.59            0.33
#  weighted_MFO              93.58              3.06              92.82              3.80                    473.62                17.96               491.59               55.48          0.48         0.40           0.75          0.23             0.53            0.28
#   weighted_GA              92.69              2.71              92.10              3.32                    493.40                17.94               511.34               55.48          0.52         0.28           0.61          0.14             0.57            0.39

# %% [markdown]
# ## Select Best Weights Per Fold
#
# For each fold, pick the metaheuristic whose weighted fusion achieved the **highest val accuracy**.
# Save these best weights so File 2 can load and apply them.

# %%
best_weights_per_fold = {}  # {fold_idx: {'weights': array, 'method': str, 'val_loss': float, ...}}

weighted_methods = [m for m in ALL_METHODS if m != 'baseline']

print("=" * 80)
print("BEST WEIGHTED METHOD PER FOLD (selected by lowest val loss)")
print("=" * 80)

for fold_idx in range(N_FOLDS):
    best_val_loss = float('inf')
    best_method = None
    best_weights = None
    best_test_acc = None
    best_val_acc = None
    
    for method_name in weighted_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['val_loss'] < best_val_loss:
                best_val_loss = r['val_loss']
                best_method = method_name
                best_weights = r['modality_weights'].copy()
                best_test_acc = r['test_acc']
                best_val_acc = r['val_acc']
    
    best_weights_per_fold[fold_idx] = {
        'weights': best_weights,
        'method': best_method,
        'val_loss': best_val_loss,
        'val_acc': best_val_acc,
        'test_acc': best_test_acc,
    }
    
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={best_weights[i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {best_method} | Val loss: {best_val_loss:.6f} | "
          f"Val acc: {best_val_acc*100:.2f}% | Test: {best_test_acc*100:.2f}% | Weights: [{w_str}]")

# Compare with baseline
print(f"\n  {'---' * 20}")
print(f"  Baseline comparison:")
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        bl = master_results['baseline'][fold_idx]
        bw = best_weights_per_fold[fold_idx]
        diff = bw['test_acc'] - bl['test_acc']
        print(f"    Fold {fold_idx+1}: Baseline={bl['test_acc']*100:.2f}%, "
              f"Best weighted={bw['test_acc']*100:.2f}%, Diff={diff*100:+.2f}%")

# Save for File 2
save_obj = {}
for fold_idx, info in best_weights_per_fold.items():
    save_obj[fold_idx] = {
        'weights': info['weights'],
        'method': info['method'],
        'val_loss': info['val_loss'],
        'val_acc': info['val_acc'],
        'test_acc': info['test_acc'],
    }

joblib.dump(save_obj, RESULTS_ROOT / "best_weights_per_fold.pkl")
print(f"\nSaved: {RESULTS_ROOT / 'best_weights_per_fold.pkl'}")
print("This file will be loaded by File 2 for weighted feature selection.")
# Out:
# ================================================================================
# BEST WEIGHTED METHOD PER FOLD (selected by lowest val loss)
# ================================================================================
#   Fold 1: weighted_PSO | Val loss: 0.056728 | Val acc: 99.49% | Test: 96.85% | Weights: [depth=0.974, sensor=0.803, skeleton=0.211]
#   Fold 2: weighted_MVO | Val loss: 0.025869 | Val acc: 100.00% | Test: 92.95% | Weights: [depth=0.644, sensor=0.817, skeleton=0.856]
#   Fold 3: weighted_GWO | Val loss: 0.060154 | Val acc: 100.00% | Test: 99.09% | Weights: [depth=0.104, sensor=0.765, skeleton=0.710]
#   Fold 4: weighted_BAT | Val loss: 0.061832 | Val acc: 100.00% | Test: 95.45% | Weights: [depth=0.459, sensor=0.591, skeleton=0.542]
#   Fold 5: weighted_HHO | Val loss: 0.141761 | Val acc: 96.68% | Test: 94.95% | Weights: [depth=0.732, sensor=0.752, skeleton=0.041]
#
#   ------------------------------------------------------------
#   Baseline comparison:
#     Fold 1: Baseline=97.90%, Best weighted=96.85%, Diff=-1.05%
#     Fold 2: Baseline=92.53%, Best weighted=92.95%, Diff=+0.41%
#     Fold 3: Baseline=93.64%, Best weighted=99.09%, Diff=+5.45%
#     Fold 4: Baseline=90.91%, Best weighted=95.45%, Diff=+4.55%
#     Fold 5: Baseline=99.49%, Best weighted=94.95%, Diff=-4.55%
#
# Saved: results_weighted_fusion/best_weights_per_fold.pkl
# This file will be loaded by File 2 for weighted feature selection.

# %% [markdown]
# ## Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy comparison (box plot)
# ============================================================================
fig, ax = plt.subplots(figsize=(18, 7))
order = df_summary['Method'].tolist()
sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax,
              color='black', alpha=0.5, size=4)
ax.set_title('Weighted Early Fusion: Test Accuracy Comparison', fontsize=14)
ax.set_ylabel('Test Accuracy (%)')
plt.xticks(rotation=60, ha='right')
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'accuracy_boxplot.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 2: Learned modality weights heatmap (all methods x folds)
# ============================================================================
for mod_name in MODALITY_NAMES:
    fig, ax = plt.subplots(figsize=(12, 8))
    pivot = df_all[df_all['Method'] != 'baseline'].pivot_table(
        values=f'w_{mod_name}', index='Method', columns='Fold'
    )
    sns.heatmap(pivot, annot=True, fmt='.3f', cmap='YlOrRd', ax=ax,
                vmin=0, vmax=1, linewidths=0.5, cbar_kws={'label': 'Weight'})
    ax.set_title(f'Learned Weight for {mod_name.upper()} Modality', fontsize=14)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'weights_heatmap_{mod_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
# ============================================================================
# PLOT 3: Average modality weights bar chart (all optimizers)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))

weight_methods = [m for m in ALL_METHODS if m != 'baseline']
x = np.arange(len(weight_methods))
width = 0.18
colors = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']

for i, mod_name in enumerate(MODALITY_NAMES):
    means, stds = [], []
    for method in weight_methods:
        mdf = df_all[df_all['Method'] == method]
        means.append(mdf[f'w_{mod_name}'].mean())
        stds.append(mdf[f'w_{mod_name}'].std())
    ax.bar(x + i * width, means, width, yerr=stds, capsize=2,
           label=mod_name, color=colors[i], alpha=0.8)

ax.set_ylabel('Weight', fontsize=12)
ax.set_title('Average Learned Modality Weights by Optimizer', fontsize=14)
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels([m.replace('weighted_', '') for m in weight_methods], rotation=45, ha='right')
ax.legend()
ax.set_ylim(0, 1.15)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'avg_modality_weights_bar.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 4: Improvement over baseline
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 6))

baseline_mean = df_summary[df_summary['Method'] == 'baseline']['Mean Test Acc (%)'].values[0]

improvements = []
method_labels = []
for _, row in df_summary.iterrows():
    if row['Method'] == 'baseline':
        continue
    improvements.append(row['Mean Test Acc (%)'] - baseline_mean)
    method_labels.append(row['Method'].replace('weighted_', ''))

colors_imp = ['green' if x >= 0 else 'red' for x in improvements]
bars = ax.bar(range(len(improvements)), improvements, color=colors_imp, alpha=0.7)
ax.axhline(y=0, color='black', linewidth=0.8)
ax.set_xticks(range(len(improvements)))
ax.set_xticklabels(method_labels, rotation=45, ha='right')
ax.set_ylabel('Accuracy Improvement over Baseline (%)', fontsize=12)
ax.set_title('Weighted Fusion vs Simple Concatenation', fontsize=14)

for bar, val in zip(bars, improvements):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            f'{val:+.2f}%', ha='center', va='bottom' if val >= 0 else 'top', fontsize=9)

plt.tight_layout()
plt.savefig(PLOTS_DIR / 'improvement_over_baseline.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 5: Convergence curves
# ============================================================================
fig, ax = plt.subplots(figsize=(14, 8))

for method in weight_methods:
    all_conv = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            conv = master_results[method][fold_idx].get('convergence', None)
            if conv is not None and len(conv) > 0:
                all_conv.append(conv)
    
    if len(all_conv) > 0:
        min_len = min(len(c) for c in all_conv)
        all_conv_arr = np.array([c[:min_len] for c in all_conv])
        mean_conv = np.mean(all_conv_arr, axis=0)
        ax.plot(range(1, min_len + 1), mean_conv,
                label=method.replace('weighted_', ''), linewidth=2)

ax.set_xlabel('Iteration', fontsize=12)
ax.set_ylabel('Fitness (lower is better)', fontsize=12)
ax.set_title('Weight Optimization Convergence (averaged across folds)', fontsize=14)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'convergence_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 6: Best weights per fold (the ones that will be used in File 2)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 6))

fold_labels = [f"Fold {i+1}\n({best_weights_per_fold[i]['method'].replace('weighted_', '')})" 
               for i in range(N_FOLDS)]
x = np.arange(N_FOLDS)
width = 0.18
colors = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']

for i, mod_name in enumerate(MODALITY_NAMES):
    weights = [best_weights_per_fold[fold_idx]['weights'][i] for fold_idx in range(N_FOLDS)]
    ax.bar(x + i * width, weights, width, label=mod_name, color=colors[i], alpha=0.8)

ax.set_ylabel('Weight', fontsize=12)
ax.set_title('Best Learned Modality Weights Per Fold (used in File 2)', fontsize=14)
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels(fold_labels, fontsize=9)
ax.legend()
ax.set_ylim(0, 1.15)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'best_weights_per_fold.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Final Summary

# %%
print("=" * 80)
print("FILE 1 COMPLETE — WEIGHTED EARLY FUSION")
print("=" * 80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")
print(f"\nPlots:")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\n{'=' * 80}")
print("RESULTS (sorted by mean test accuracy):")
print("=" * 80)
for _, row in df_summary.iterrows():
    w_str = ' | '.join([f"{m}={row[f'Mean w_{m}']:.3f}" for m in MODALITY_NAMES])
    print(f"  {row['Method']:25s} | Acc: {row['Mean Test Acc (%)']:6.2f}% "
          f"(+/-{row['Std Test Acc (%)']:.2f}) | {w_str}")

print(f"\n{'=' * 80}")
print("BEST WEIGHTS PER FOLD (to be used in File 2):")
print("=" * 80)
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']:25s} | Val loss: {info['val_loss']:.6f} | Val acc: {info['val_acc']*100:.2f}% | [{w_str}]")

print(f"\nKey output for File 2: {RESULTS_ROOT / 'best_weights_per_fold.pkl'}")
# Out:
# ================================================================================
# FILE 1 COMPLETE — WEIGHTED EARLY FUSION
# ================================================================================
#
# Output directory: results_weighted_fusion
#
# CSV files:
#   all_results_per_fold.csv
#   summary_all_methods.csv
#
# Plots:
#   accuracy_boxplot.png
#   avg_modality_weights_bar.png
#   best_weights_per_fold.png
#   convergence_curves.png
#   improvement_over_baseline.png
#   weights_heatmap_depth.png
#   weights_heatmap_sensor.png
#   weights_heatmap_skeleton.png
#
# ================================================================================
# RESULTS (sorted by mean test accuracy):
# ================================================================================
#   weighted_SCA              | Acc:  96.05% (+/-2.18) | depth=0.220 | sensor=0.890 | skeleton=0.620
#   weighted_BAT              | Acc:  95.93% (+/-1.94) | depth=0.310 | sensor=0.700 | skeleton=0.510
#   weighted_SSA              | Acc:  95.42% (+/-2.55) | depth=0.500 | sensor=0.910 | skeleton=0.650
#   weighted_CS               | Acc:  95.41% (+/-2.18) | depth=0.600 | sensor=0.610 | skeleton=0.360
#   weighted_HHO              | Acc:  95.35% (+/-3.09) | depth=0.490 | sensor=0.490 | skeleton=0.240
#   weighted_WOA              | Acc:  95.13% (+/-3.77) | depth=0.640 | sensor=0.800 | skeleton=0.630
#   weighted_FFA              | Acc:  95.03% (+/-2.38) | depth=0.440 | sensor=0.790 | skeleton=0.500
#   weighted_DE               | Acc:  94.92% (+/-4.28) | depth=0.590 | sensor=0.770 | skeleton=0.600
#   baseline                  | Acc:  94.89% (+/-3.65) | depth=1.000 | sensor=1.000 | skeleton=1.000
#   weighted_MVO              | Acc:  94.84% (+/-3.27) | depth=0.680 | sensor=0.770 | skeleton=0.560
#   weighted_PSO              | Acc:  94.66% (+/-3.97) | depth=0.570 | sensor=0.840 | skeleton=0.480
#   weighted_GWO              | Acc:  94.48% (+/-3.99) | depth=0.390 | sensor=0.670 | skeleton=0.500
#   weighted_JAYA             | Acc:  94.06% (+/-3.17) | depth=0.350 | sensor=0.680 | skeleton=0.590
#   weighted_MFO              | Acc:  93.58% (+/-3.06) | depth=0.480 | sensor=0.750 | skeleton=0.530
#   weighted_GA               | Acc:  92.69% (+/-2.71) | depth=0.520 | sensor=0.610 | skeleton=0.570
#
# ================================================================================
# BEST WEIGHTS PER FOLD (to be used in File 2):
# ================================================================================
#   Fold 1: weighted_PSO              | Val loss: 0.056728 | Val acc: 99.49% | [depth=0.974, sensor=0.803, skeleton=0.211]
#   Fold 2: weighted_MVO              | Val loss: 0.025869 | Val acc: 100.00% | [depth=0.644, sensor=0.817, skeleton=0.856]
#   Fold 3: weighted_GWO              | Val loss: 0.060154 | Val acc: 100.00% | [depth=0.104, sensor=0.765, skeleton=0.710]
#   Fold 4: weighted_BAT              | Val loss: 0.061832 | Val acc: 100.00% | [depth=0.459, sensor=0.591, skeleton=0.542]
#   Fold 5: weighted_HHO              | Val loss: 0.141761 | Val acc: 96.68% | [depth=0.732, sensor=0.752, skeleton=0.041]
#
# Key output for File 2: results_weighted_fusion/best_weights_per_fold.pkl
