# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.11.0+cu126
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## Configuration

# %%
FEATURE_DIR = Path("features_noise_10")

RESULTS_ROOT = Path("results_noise_10")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

N_POPULATION = 20
MAX_ITERATIONS = 30

TARGET_FEATURE_PERCENTAGE = 0.5

EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   TOTAL: 8039
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, ")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 681, Val: 198, Test: 286
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 94.76%, F1: 94.64%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 55.2s
#     Test Acc: 95.45%, F1: 95.48%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 10.0s
#     Test Acc: 94.41%, F1: 94.51%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 293.8s
#     Test Acc: 83.57%, F1: 82.81%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.038613459604258146']
# ['At iteration 1 the best fitness is 0.038613459604258146']
# ['At iteration 2 the best fitness is 0.03373332403894345']
# ['At iteration 3 the best fitness is 0.03373332403894345']
# ['At iteration 4 the best fitness is 0.03373332403894345']
# ['At iteration 5 the best fitness is 0.033716892885476475']
# ['At iteration 6 the best fitness is 0.033716892885476475']
# ['At iteration 7 the best fitness is 0.033716892885476475']
# ['At iteration 8 the best fitness is 0.033716892885476475']
# ['At iteration 9 the best fitness is 0.033716892885476475']
# ['At iteration 10 the best fitness is 0.033716892885476475']
# ['At iteration 11 the best fitness is 0.033716892885476475']
# ['At iteration 12 the best fitness is 0.033716892885476475']
# ['At iteration 13 the best fitness is 0.033716892885476475']
# ['At iteration 14 the best fitness is 0.033716892885476475']
# ['At iteration 15 the best fitness is 0.033716892885476475']
# ['At iteration 16 the best fitness is 0.033716892885476475']
# ['At iteration 17 the best fitness is 0.033716892885476475']
# ['At iteration 18 the best fitness is 0.033716892885476475']
# ['At iteration 19 the best fitness is 0.033716892885476475']
# ['At iteration 20 the best fitness is 0.033716892885476475']
# ['At iteration 21 the best fitness is 0.033716892885476475']
# ['At iteration 22 the best fitness is 0.033716892885476475']
# ['At iteration 23 the best fitness is 0.033716892885476475']
# ['At iteration 24 the best fitness is 0.033716892885476475']
# ['At iteration 25 the best fitness is 0.033716892885476475']
# ['At iteration 26 the best fitness is 0.033716892885476475']
# ['At iteration 27 the best fitness is 0.033716892885476475']
# ['At iteration 28 the best fitness is 0.033716892885476475']
# ['At iteration 29 the best fitness is 0.033716892885476475']
#       Selected: 1468/3043 (48.2%), Fitness: 0.0337, Time: 2588.2s
#       Modality: D=45%, S=50%, Sk=48%,
#     Test Acc: 94.76%, F1: 94.95%, Features: 1468/3043 (48.2%), Model: 3.403MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.038465579223055386']
# ['At iteration 10 the best fitness is 0.03366759942507556']
# ['At iteration 20 the best fitness is 0.03366759942507556']
#       Selected: 1465/3043 (48.1%), Fitness: 0.0337, Time: 4505.4s
#       Modality: D=44%, S=49%, Sk=49%,
#     Test Acc: 94.41%, F1: 94.52%, Features: 1465/3043 (48.1%), Model: 3.398MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.029691177300444502']
# ['At iteration 2 the best fitness is 0.029691177300444502']
# ['At iteration 3 the best fitness is 0.029691177300444502']
# ['At iteration 4 the best fitness is 0.029247536156836222']
# ['At iteration 5 the best fitness is 0.029247536156836222']
# ['At iteration 6 the best fitness is 0.029247536156836222']
# ['At iteration 7 the best fitness is 0.029247536156836222']
# ['At iteration 8 the best fitness is 0.029247536156836222']
# ['At iteration 9 the best fitness is 0.029247536156836222']
# ['At iteration 10 the best fitness is 0.029247536156836222']
# ['At iteration 11 the best fitness is 0.029247536156836222']
# ['At iteration 12 the best fitness is 0.029247536156836222']
# ['At iteration 13 the best fitness is 0.029247536156836222']
# ['At iteration 14 the best fitness is 0.029247536156836222']
# ['At iteration 15 the best fitness is 0.029247536156836222']
# ['At iteration 16 the best fitness is 0.029247536156836222']
# ['At iteration 17 the best fitness is 0.029247536156836222']
# ['At iteration 18 the best fitness is 0.029247536156836222']
# ['At iteration 19 the best fitness is 0.029247536156836222']
# ['At iteration 20 the best fitness is 0.029247536156836222']
# ['At iteration 21 the best fitness is 0.029247536156836222']
# ['At iteration 22 the best fitness is 0.029247536156836222']
# ['At iteration 23 the best fitness is 0.029116086929100435']
# ['At iteration 24 the best fitness is 0.029116086929100435']
# ['At iteration 25 the best fitness is 0.029116086929100435']
# ['At iteration 26 the best fitness is 0.029116086929100435']
# ['At iteration 27 the best fitness is 0.029116086929100435']
# ['At iteration 28 the best fitness is 0.029116086929100435']
# ['At iteration 29 the best fitness is 0.029116086929100435']
# ['At iteration 30 the best fitness is 0.029116086929100435']
#       Selected: 1480/3043 (48.6%), Fitness: 0.0291, Time: 2120.1s
#       Modality: D=50%, S=50%, Sk=48%,
#     Test Acc: 95.10%, F1: 95.04%, Features: 1480/3043 (48.6%), Model: 3.427MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.038909220366663666']
# ['At iteration 1 the best fitness is 0.03978007150041326']
# ['At iteration 2 the best fitness is 0.039057100747866426']
# ['At iteration 3 the best fitness is 0.029756901914312395']
# ['At iteration 4 the best fitness is 0.039352861510271946']
# ['At iteration 5 the best fitness is 0.039057100747866426']
# ['At iteration 6 the best fitness is 0.03917211882213524']
# ['At iteration 7 the best fitness is 0.029740470760845423']
# ['At iteration 8 the best fitness is 0.0342591209498866']
# ['At iteration 9 the best fitness is 0.034472725944957254']
# ['At iteration 10 the best fitness is 0.029411847691505955']
# ['At iteration 11 the best fitness is 0.029592590379642663']
# ['At iteration 12 the best fitness is 0.034423432484556336']
# ['At iteration 13 the best fitness is 0.03908996305480037']
# ['At iteration 14 the best fitness is 0.03443986363802331']
# ['At iteration 15 the best fitness is 0.034390570177622384']
# ['At iteration 16 the best fitness is 0.03429198325682054']
# ['At iteration 17 the best fitness is 0.029444709998439903']
# ['At iteration 18 the best fitness is 0.029461141151906876']
# ['At iteration 19 the best fitness is 0.03429198325682054']
# ['At iteration 20 the best fitness is 0.03430841441028752']
# ['At iteration 21 the best fitness is 0.03908996305480037']
# ['At iteration 22 the best fitness is 0.03430841441028752']
# ['At iteration 23 the best fitness is 0.03910639420826735']
# ['At iteration 24 the best fitness is 0.03430841441028752']
# ['At iteration 25 the best fitness is 0.034324845563754494']
# ['At iteration 26 the best fitness is 0.03430841441028752']
# ['At iteration 27 the best fitness is 0.03430841441028752']
# ['At iteration 28 the best fitness is 0.03430841441028752']
# ['At iteration 29 the best fitness is 0.03430841441028752']
#       Selected: 1504/3043 (49.4%), Fitness: 0.0343, Time: 2052.7s
#       Modality: D=52%, S=50%, Sk=48%,
#     Test Acc: 93.36%, F1: 93.46%, Features: 1504/3043 (49.4%), Model: 3.474MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.04472593167959584
# At iteration 2 the best fitness is 0.03917211882213524
# At iteration 3 the best fitness is 0.04375649362504441
# At iteration 4 the best fitness is 0.04472593167959584
# At iteration 5 the best fitness is 0.03895851382706459
# At iteration 6 the best fitness is 0.034571312865759096
# At iteration 7 the best fitness is 0.04421656592211967
# At iteration 8 the best fitness is 0.044693069372661896
# At iteration 9 the best fitness is 0.035228559004438026
# At iteration 10 the best fitness is 0.03948431073800773
# At iteration 11 the best fitness is 0.044627344758794
# At iteration 12 the best fitness is 0.034686330940027904
# At iteration 13 the best fitness is 0.04009226341628575
# At iteration 14 the best fitness is 0.039319999203338
# At iteration 15 the best fitness is 0.039665053426144445
# At iteration 16 the best fitness is 0.03964862227267747
# At iteration 17 the best fitness is 0.03519569669750408
# At iteration 18 the best fitness is 0.03999367649548391
# At iteration 19 the best fitness is 0.03483421132123067
# At iteration 20 the best fitness is 0.04001010764895088
# At iteration 21 the best fitness is 0.03552431976684355
# At iteration 22 the best fitness is 0.039139256515201296
# At iteration 23 the best fitness is 0.03504781631630132
# At iteration 24 the best fitness is 0.03529428361830592
# At iteration 25 the best fitness is 0.035162834390570136
# At iteration 26 the best fitness is 0.035080678623235266
# At iteration 27 the best fitness is 0.039369292663738925
# At iteration 28 the best fitness is 0.03504781631630132
# At iteration 29 the best fitness is 0.034867073628164616
# At iteration 30 the best fitness is 0.03923784343600314
#       Selected: 1512/3043 (49.7%), Fitness: 0.0392, Time: 2051.3s
#       Modality: D=46%, S=53%, Sk=50%,
#     Test Acc: 94.06%, F1: 94.11%, Features: 1512/3043 (49.7%), Model: 3.489MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0443808774567894']
# ['At iteration 1 the best fitness is 0.04392080515971415']
# ['At iteration 2 the best fitness is 0.038695615371593016']
# ['At iteration 3 the best fitness is 0.038695615371593016']
# ['At iteration 4 the best fitness is 0.03675673926249016']
# ['At iteration 5 the best fitness is 0.03105504602382679']
# ['At iteration 6 the best fitness is 0.03105504602382679']
# ['At iteration 7 the best fitness is 0.03105504602382679']
# ['At iteration 8 the best fitness is 0.03031564411781299']
# ['At iteration 9 the best fitness is 0.03031564411781299']
# ['At iteration 10 the best fitness is 0.029822709513803787']
# ['At iteration 11 the best fitness is 0.02954337990486524']
# ['At iteration 12 the best fitness is 0.02954337990486524']
# ['At iteration 13 the best fitness is 0.029411930677129453']
# ['At iteration 14 the best fitness is 0.028458923776044996']
# ['At iteration 15 the best fitness is 0.028458923776044996']
# ['At iteration 16 the best fitness is 0.028458923776044996']
# ['At iteration 17 the best fitness is 0.02832747454830921']
# ['At iteration 18 the best fitness is 0.028228887627507367']
# ['At iteration 19 the best fitness is 0.028228887627507367']
# ['At iteration 20 the best fitness is 0.027965989172035792']
# ['At iteration 21 the best fitness is 0.027965989172035792']
# ['At iteration 22 the best fitness is 0.023052991299787256']
# ['At iteration 23 the best fitness is 0.023052991299787256']
# ['At iteration 24 the best fitness is 0.023003697839386338']
# ['At iteration 25 the best fitness is 0.023003697839386338']
# ['At iteration 26 the best fitness is 0.022987266685919366']
# ['At iteration 27 the best fitness is 0.022987266685919366']
# ['At iteration 28 the best fitness is 0.022987266685919366']
# ['At iteration 29 the best fitness is 0.022987266685919366']
#       Selected: 1107/3043 (36.4%), Fitness: 0.0230, Time: 1918.9s
#       Modality: D=41%, S=38%, Sk=35%,
#     Test Acc: 94.06%, F1: 94.08%, Features: 1107/3043 (36.4%), Model: 2.698MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.0388270645993288']
# ['At iteration 1 the best fitness is 0.0388270645993288']
# ['At iteration 2 the best fitness is 0.0388270645993288']
# ['At iteration 3 the best fitness is 0.0388270645993288']
# ['At iteration 4 the best fitness is 0.0388270645993288']
# ['At iteration 5 the best fitness is 0.0388270645993288']
# ['At iteration 6 the best fitness is 0.0388270645993288']
# ['At iteration 7 the best fitness is 0.0388270645993288']
# ['At iteration 8 the best fitness is 0.0388270645993288']
# ['At iteration 9 the best fitness is 0.0388270645993288']
# ['At iteration 10 the best fitness is 0.0388270645993288']
# ['At iteration 11 the best fitness is 0.0388270645993288']
# ['At iteration 12 the best fitness is 0.0388270645993288']
# ['At iteration 13 the best fitness is 0.0388270645993288']
# ['At iteration 14 the best fitness is 0.0388270645993288']
# ['At iteration 15 the best fitness is 0.0388270645993288']
# ['At iteration 16 the best fitness is 0.0388270645993288']
# ['At iteration 17 the best fitness is 0.0388270645993288']
# ['At iteration 18 the best fitness is 0.0388270645993288']
# ['At iteration 19 the best fitness is 0.0388270645993288']
# ['At iteration 20 the best fitness is 0.0388270645993288']
# ['At iteration 21 the best fitness is 0.0388270645993288']
# ['At iteration 22 the best fitness is 0.0388270645993288']
# ['At iteration 23 the best fitness is 0.0388270645993288']
# ['At iteration 24 the best fitness is 0.0388270645993288']
# ['At iteration 25 the best fitness is 0.0388270645993288']
# ['At iteration 26 the best fitness is 0.0388270645993288']
# ['At iteration 27 the best fitness is 0.0388270645993288']
# ['At iteration 28 the best fitness is 0.0388270645993288']
# ['At iteration 29 the best fitness is 0.0388270645993288']
#       Selected: 1487/3043 (48.9%), Fitness: 0.0388, Time: 2315.7s
#       Modality: D=48%, S=48%, Sk=49%,
#     Test Acc: 93.01%, F1: 93.01%, Features: 1487/3043 (48.9%), Model: 3.441MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03900780728746551']
# ['At iteration 1 the best fitness is 0.03900780728746551']
# ['At iteration 2 the best fitness is 0.03900780728746551']
# ['At iteration 3 the best fitness is 0.03900780728746551']
# ['At iteration 4 the best fitness is 0.03480134901429672']
# ['At iteration 5 the best fitness is 0.03480134901429672']
# ['At iteration 6 the best fitness is 0.03480134901429672']
# ['At iteration 7 the best fitness is 0.03480134901429672']
# ['At iteration 8 the best fitness is 0.03480134901429672']
# ['At iteration 9 the best fitness is 0.03480134901429672']
# ['At iteration 10 the best fitness is 0.03480134901429672']
# ['At iteration 11 the best fitness is 0.03480134901429672']
# ['At iteration 12 the best fitness is 0.03480134901429672']
# ['At iteration 13 the best fitness is 0.03480134901429672']
# ['At iteration 14 the best fitness is 0.03480134901429672']
# ['At iteration 15 the best fitness is 0.03480134901429672']
# ['At iteration 16 the best fitness is 0.03480134901429672']
# ['At iteration 17 the best fitness is 0.03480134901429672']
# ['At iteration 18 the best fitness is 0.03480134901429672']
# ['At iteration 19 the best fitness is 0.03480134901429672']
# ['At iteration 20 the best fitness is 0.03480134901429672']
# ['At iteration 21 the best fitness is 0.03480134901429672']
# ['At iteration 22 the best fitness is 0.03480134901429672']
# ['At iteration 23 the best fitness is 0.03480134901429672']
# ['At iteration 24 the best fitness is 0.03480134901429672']
# ['At iteration 25 the best fitness is 0.03480134901429672']
# ['At iteration 26 the best fitness is 0.03480134901429672']
# ['At iteration 27 the best fitness is 0.03480134901429672']
# ['At iteration 28 the best fitness is 0.03480134901429672']
# ['At iteration 29 the best fitness is 0.03480134901429672']
#       Selected: 1534/3043 (50.4%), Fitness: 0.0348, Time: 1850.8s
#       Modality: D=50%, S=48%, Sk=51%,
#     Test Acc: 94.41%, F1: 94.45%, Features: 1534/3043 (50.4%), Model: 3.532MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04352645747650678']
# ['At iteration 2 the best fitness is 0.03971434688654536']
# ['At iteration 3 the best fitness is 0.03971434688654536']
# ['At iteration 4 the best fitness is 0.03971434688654536']
# ['At iteration 5 the best fitness is 0.03971434688654536']
# ['At iteration 6 the best fitness is 0.03910639420826735']
# ['At iteration 7 the best fitness is 0.0348177801677637']
# ['At iteration 8 the best fitness is 0.0348177801677637']
# ['At iteration 9 the best fitness is 0.034407001331089364']
# ['At iteration 10 the best fitness is 0.034407001331089364']
# ['At iteration 11 the best fitness is 0.034407001331089364']
# ['At iteration 12 the best fitness is 0.034407001331089364']
# ['At iteration 13 the best fitness is 0.034407001331089364']
# ['At iteration 14 the best fitness is 0.034407001331089364']
# ['At iteration 15 the best fitness is 0.034407001331089364']
# ['At iteration 16 the best fitness is 0.034407001331089364']
# ['At iteration 17 the best fitness is 0.034407001331089364']
# ['At iteration 18 the best fitness is 0.034407001331089364']
# ['At iteration 19 the best fitness is 0.034407001331089364']
# ['At iteration 20 the best fitness is 0.034407001331089364']
# ['At iteration 21 the best fitness is 0.034407001331089364']
# ['At iteration 22 the best fitness is 0.034407001331089364']
# ['At iteration 23 the best fitness is 0.034407001331089364']
# ['At iteration 24 the best fitness is 0.034407001331089364']
# ['At iteration 25 the best fitness is 0.034407001331089364']
# ['At iteration 26 the best fitness is 0.034407001331089364']
# ['At iteration 27 the best fitness is 0.034407001331089364']
# ['At iteration 28 the best fitness is 0.034407001331089364']
# ['At iteration 29 the best fitness is 0.034407001331089364']
#       Selected: 1510/3043 (49.6%), Fitness: 0.0344, Time: 1732.6s
#       Modality: D=49%, S=50%, Sk=50%,
#     Test Acc: 95.10%, F1: 95.14%, Features: 1510/3043 (49.6%), Model: 3.485MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04411797900131783']
# ['At iteration 2 the best fitness is 0.03892565152013064']
# ['At iteration 3 the best fitness is 0.03892565152013064']
# ['At iteration 4 the best fitness is 0.03892565152013064']
# ['At iteration 5 the best fitness is 0.03892565152013064']
# ['At iteration 6 the best fitness is 0.03411124056868384']
# ['At iteration 7 the best fitness is 0.03411124056868384']
# ['At iteration 8 the best fitness is 0.03399622249441502']
# ['At iteration 9 the best fitness is 0.03381547980627832']
# ['At iteration 10 the best fitness is 0.03381547980627832']
# ['At iteration 11 the best fitness is 0.03366759942507556']
# ['At iteration 12 the best fitness is 0.03366759942507556']
# ['At iteration 13 the best fitness is 0.03366759942507556']
# ['At iteration 14 the best fitness is 0.03366759942507556']
# ['At iteration 15 the best fitness is 0.03366759942507556']
# ['At iteration 16 the best fitness is 0.03366759942507556']
# ['At iteration 17 the best fitness is 0.0291982426964353']
# ['At iteration 18 the best fitness is 0.0291982426964353']
# ['At iteration 19 the best fitness is 0.0291982426964353']
# ['At iteration 20 the best fitness is 0.0291982426964353']
# ['At iteration 21 the best fitness is 0.0291982426964353']
# ['At iteration 22 the best fitness is 0.0291982426964353']
# ['At iteration 23 the best fitness is 0.0291982426964353']
# ['At iteration 24 the best fitness is 0.0291982426964353']
# ['At iteration 25 the best fitness is 0.0291982426964353']
# ['At iteration 26 the best fitness is 0.0291982426964353']
# ['At iteration 27 the best fitness is 0.0291982426964353']
# ['At iteration 28 the best fitness is 0.0291982426964353']
# ['At iteration 29 the best fitness is 0.0291982426964353']
# ['At iteration 30 the best fitness is 0.0291982426964353']
#       Selected: 1485/3043 (48.8%), Fitness: 0.0292, Time: 1790.9s
#       Modality: D=48%, S=48%, Sk=49%,
#     Test Acc: 92.66%, F1: 92.81%, Features: 1485/3043 (48.8%), Model: 3.437MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03923784343600314']
# ['At iteration 2 the best fitness is 0.03923784343600314']
# ['At iteration 3 the best fitness is 0.03923784343600314']
# ['At iteration 4 the best fitness is 0.0388270645993288']
# ['At iteration 5 the best fitness is 0.034784917860829746']
# ['At iteration 6 the best fitness is 0.034784917860829746']
# ['At iteration 7 the best fitness is 0.034784917860829746']
# ['At iteration 8 the best fitness is 0.034784917860829746']
# ['At iteration 9 the best fitness is 0.034784917860829746']
# ['At iteration 10 the best fitness is 0.034637037479626986']
# ['At iteration 11 the best fitness is 0.034637037479626986']
# ['At iteration 12 the best fitness is 0.029658314993510557']
# ['At iteration 13 the best fitness is 0.029658314993510557']
# ['At iteration 14 the best fitness is 0.029658314993510557']
# ['At iteration 15 the best fitness is 0.029658314993510557']
# ['At iteration 16 the best fitness is 0.029658314993510557']
# ['At iteration 17 the best fitness is 0.029658314993510557']
# ['At iteration 18 the best fitness is 0.029658314993510557']
# ['At iteration 19 the best fitness is 0.029658314993510557']
# ['At iteration 20 the best fitness is 0.029658314993510557']
# ['At iteration 21 the best fitness is 0.029658314993510557']
# ['At iteration 22 the best fitness is 0.029658314993510557']
# ['At iteration 23 the best fitness is 0.029658314993510557']
# ['At iteration 24 the best fitness is 0.029658314993510557']
# ['At iteration 25 the best fitness is 0.029658314993510557']
# ['At iteration 26 the best fitness is 0.029658314993510557']
# ['At iteration 27 the best fitness is 0.029658314993510557']
# ['At iteration 28 the best fitness is 0.029658314993510557']
# ['At iteration 29 the best fitness is 0.029658314993510557']
# ['At iteration 30 the best fitness is 0.029658314993510557']
#       Selected: 1513/3043 (49.7%), Fitness: 0.0297, Time: 1795.1s
#       Modality: D=48%, S=47%, Sk=51%,
#     Test Acc: 93.71%, F1: 93.74%, Features: 1513/3043 (49.7%), Model: 3.491MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04883380303196279']
# ['At iteration 1 the best fitness is 0.041883342129809445']
# ['At iteration 2 the best fitness is 0.041883342129809445']
# ['At iteration 3 the best fitness is 0.041883342129809445']
# ['At iteration 4 the best fitness is 0.041883342129809445']
# ['At iteration 5 the best fitness is 0.03746336184719361']
# ['At iteration 6 the best fitness is 0.026635065741210946']
# ['At iteration 7 the best fitness is 0.026635065741210946']
# ['At iteration 8 the best fitness is 0.026635065741210946']
# ['At iteration 9 the best fitness is 0.026635065741210946']
# ['At iteration 10 the best fitness is 0.026635065741210946']
# ['At iteration 11 the best fitness is 0.026635065741210946']
# ['At iteration 12 the best fitness is 0.021853600082321695']
# ['At iteration 13 the best fitness is 0.021853600082321695']
# ['At iteration 14 the best fitness is 0.020884162027770267']
# ['At iteration 15 the best fitness is 0.020884162027770267']
# ['At iteration 16 the best fitness is 0.020884162027770267']
# ['At iteration 17 the best fitness is 0.018600231695860964']
# ['At iteration 18 the best fitness is 0.018600231695860964']
# ['At iteration 19 the best fitness is 0.018600231695860964']
# ['At iteration 20 the best fitness is 0.018600231695860964']
# ['At iteration 21 the best fitness is 0.018600231695860964']
# ['At iteration 22 the best fitness is 0.018600231695860964']
# ['At iteration 23 the best fitness is 0.018403057854257283']
# ['At iteration 24 the best fitness is 0.018403057854257283']
# ['At iteration 25 the best fitness is 0.018403057854257283']
# ['At iteration 26 the best fitness is 0.018403057854257283']
# ['At iteration 27 the best fitness is 0.018403057854257283']
# ['At iteration 28 the best fitness is 0.018403057854257283']
# ['At iteration 29 the best fitness is 0.018403057854257283']
#       Selected: 536/3043 (17.6%), Fitness: 0.0184, Time: 1721.6s
#       Modality: D=17%, S=17%, Sk=18%,
#     Test Acc: 88.46%, F1: 88.52%, Features: 536/3043 (17.6%), Model: 1.583MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.034390570177622384']
# ['At iteration 2 the best fitness is 0.034390570177622384']
# ['At iteration 3 the best fitness is 0.034390570177622384']
# ['At iteration 4 the best fitness is 0.034390570177622384']
# ['At iteration 5 the best fitness is 0.030019800369783974']
# ['At iteration 6 the best fitness is 0.030019800369783974']
# ['At iteration 7 the best fitness is 0.030019800369783974']
# ['At iteration 8 the best fitness is 0.030019800369783974']
# ['At iteration 9 the best fitness is 0.030019800369783974']
# ['At iteration 10 the best fitness is 0.030019800369783974']
# ['At iteration 11 the best fitness is 0.030019800369783974']
# ['At iteration 12 the best fitness is 0.030019800369783974']
# ['At iteration 13 the best fitness is 0.030019800369783974']
# ['At iteration 14 the best fitness is 0.030019800369783974']
# ['At iteration 15 the best fitness is 0.030019800369783974']
# ['At iteration 16 the best fitness is 0.030019800369783974']
# ['At iteration 17 the best fitness is 0.030019800369783974']
# ['At iteration 18 the best fitness is 0.030019800369783974']
# ['At iteration 19 the best fitness is 0.030019800369783974']
# ['At iteration 20 the best fitness is 0.030019800369783974']
# ['At iteration 21 the best fitness is 0.030019800369783974']
# ['At iteration 22 the best fitness is 0.030019800369783974']
# ['At iteration 23 the best fitness is 0.030019800369783974']
# ['At iteration 24 the best fitness is 0.030019800369783974']
# ['At iteration 25 the best fitness is 0.030019800369783974']
# ['At iteration 26 the best fitness is 0.030019800369783974']
# ['At iteration 27 the best fitness is 0.030019800369783974']
# ['At iteration 28 the best fitness is 0.030019800369783974']
# ['At iteration 29 the best fitness is 0.030019800369783974']
#       Selected: 1535/3043 (50.4%), Fitness: 0.0300, Time: 4503.1s
#       Modality: D=52%, S=49%, Sk=51%,
#     Test Acc: 94.06%, F1: 94.11%, Features: 1535/3043 (50.4%), Model: 3.534MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.044890243214265574']
# ['At iteration 1 the best fitness is 0.030973139213362724']
# ['At iteration 2 the best fitness is 0.020144843107380066']
# ['At iteration 3 the best fitness is 0.012619208848259159']
# ['At iteration 4 the best fitness is 0.012619208848259159']
# ['At iteration 5 the best fitness is 0.012619208848259159']
# ['At iteration 6 the best fitness is 0.012619208848259159']
# ['At iteration 7 the best fitness is 0.012619208848259159']
# ['At iteration 8 the best fitness is 0.012619208848259159']
# ['At iteration 9 the best fitness is 0.012619208848259159']
# ['At iteration 10 the best fitness is 0.012504190773990346']
# ['At iteration 11 the best fitness is 0.012504190773990346']
# ['At iteration 12 the best fitness is 0.012504190773990346']
# ['At iteration 13 the best fitness is 0.012504190773990346']
# ['At iteration 14 the best fitness is 0.012504190773990346']
# ['At iteration 15 the best fitness is 0.012504190773990346']
# ['At iteration 16 the best fitness is 0.012504190773990346']
# ['At iteration 17 the best fitness is 0.012504190773990346']
# ['At iteration 18 the best fitness is 0.012504190773990346']
# ['At iteration 19 the best fitness is 0.012504190773990346']
# ['At iteration 20 the best fitness is 0.012504190773990346']
# ['At iteration 21 the best fitness is 0.012504190773990346']
# ['At iteration 22 the best fitness is 0.012504190773990346']
# ['At iteration 23 the best fitness is 0.012504190773990346']
# ['At iteration 24 the best fitness is 0.012504190773990346']
# ['At iteration 25 the best fitness is 0.012504190773990346']
# ['At iteration 26 the best fitness is 0.012504190773990346']
# ['At iteration 27 the best fitness is 0.012504190773990346']
# ['At iteration 28 the best fitness is 0.012504190773990346']
# ['At iteration 29 the best fitness is 0.012504190773990346']
#       Selected: 469/3043 (15.4%), Fitness: 0.0125, Time: 1748.6s
#       Modality: D=17%, S=16%, Sk=15%,
#     Test Acc: 95.45%, F1: 95.45%, Features: 469/3043 (15.4%), Model: 1.452MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 726, Val: 198, Test: 241
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | TOTAL=3043
#
#   --- BASELINE ---
#     Test Acc: 92.12%, F1: 92.17%, Features: 3043/3043 (100.0%), Model: 6.480MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1521/3043 (50.0%), Time: 36.5s
#     Test Acc: 91.29%, F1: 91.32%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1521/3043 (50.0%), Time: 6.6s
#     Test Acc: 89.21%, F1: 89.41%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1521/3043 (50.0%), Time: 214.6s
#     Test Acc: 75.10%, F1: 75.37%, Features: 1521/3043 (50.0%), Model: 3.507MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03940215497067287']
# ['At iteration 1 the best fitness is 0.034637037479626986']
# ['At iteration 2 the best fitness is 0.034637037479626986']
# ['At iteration 3 the best fitness is 0.034637037479626986']
# ['At iteration 4 the best fitness is 0.034637037479626986']
# ['At iteration 5 the best fitness is 0.034637037479626986']
# ['At iteration 6 the best fitness is 0.034620606326160014']
# ['At iteration 7 the best fitness is 0.034620606326160014']
# ['At iteration 8 the best fitness is 0.034620606326160014']
# ['At iteration 9 the best fitness is 0.034620606326160014']
# ['At iteration 10 the best fitness is 0.034620606326160014']
# ['At iteration 11 the best fitness is 0.034620606326160014']
# ['At iteration 12 the best fitness is 0.034620606326160014']
# ['At iteration 13 the best fitness is 0.034620606326160014']
# ['At iteration 14 the best fitness is 0.034620606326160014']
# ['At iteration 15 the best fitness is 0.034620606326160014']
# ['At iteration 16 the best fitness is 0.034620606326160014']
# ['At iteration 17 the best fitness is 0.034620606326160014']
# ['At iteration 18 the best fitness is 0.034620606326160014']
# ['At iteration 19 the best fitness is 0.034620606326160014']
# ['At iteration 20 the best fitness is 0.034620606326160014']
# ['At iteration 21 the best fitness is 0.034620606326160014']
# ['At iteration 22 the best fitness is 0.034620606326160014']
# ['At iteration 23 the best fitness is 0.034620606326160014']
# ['At iteration 24 the best fitness is 0.034620606326160014']
# ['At iteration 25 the best fitness is 0.034620606326160014']
# ['At iteration 26 the best fitness is 0.034620606326160014']
# ['At iteration 27 the best fitness is 0.034620606326160014']
# ['At iteration 28 the best fitness is 0.034620606326160014']
# ['At iteration 29 the best fitness is 0.034620606326160014']
#       Selected: 1523/3043 (50.0%), Fitness: 0.0346, Time: 1901.5s
#       Modality: D=52%, S=52%, Sk=49%,
#     Test Acc: 91.29%, F1: 91.36%, Features: 1523/3043 (50.0%), Model: 3.511MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04344430170917192']
# ['At iteration 10 the best fitness is 0.033946929034014105']
# ['At iteration 20 the best fitness is 0.029510434612307797']
#       Selected: 1504/3043 (49.4%), Fitness: 0.0295, Time: 3817.6s
#       Modality: D=50%, S=50%, Sk=49%,
#     Test Acc: 89.63%, F1: 89.63%, Features: 1504/3043 (49.4%), Model: 3.474MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0438879428527802']
# ['At iteration 2 the best fitness is 0.0438879428527802']
# ['At iteration 3 the best fitness is 0.0438879428527802']
# ['At iteration 4 the best fitness is 0.0438879428527802']
# ['At iteration 5 the best fitness is 0.0438879428527802']
# ['At iteration 6 the best fitness is 0.04369076901117652']
# ['At iteration 7 the best fitness is 0.04369076901117652']
# ['At iteration 8 the best fitness is 0.038547734990390256']
# ['At iteration 9 the best fitness is 0.038547734990390256']
# ['At iteration 10 the best fitness is 0.03396336018748108']
# ['At iteration 11 the best fitness is 0.03378261749934437']
# ['At iteration 12 the best fitness is 0.03378261749934437']
# ['At iteration 13 the best fitness is 0.03378261749934437']
# ['At iteration 14 the best fitness is 0.03378261749934437']
# ['At iteration 15 the best fitness is 0.03378261749934437']
# ['At iteration 16 the best fitness is 0.0337661863458774']
# ['At iteration 17 the best fitness is 0.0337661863458774']
# ['At iteration 18 the best fitness is 0.0337661863458774']
# ['At iteration 19 the best fitness is 0.0337661863458774']
# ['At iteration 20 the best fitness is 0.0337661863458774']
# ['At iteration 21 the best fitness is 0.0337661863458774']
# ['At iteration 22 the best fitness is 0.0337661863458774']
# ['At iteration 23 the best fitness is 0.0337661863458774']
# ['At iteration 24 the best fitness is 0.0337661863458774']
# ['At iteration 25 the best fitness is 0.0337661863458774']
# ['At iteration 26 the best fitness is 0.0337661863458774']
# ['At iteration 27 the best fitness is 0.028951775394430702']
# ['At iteration 28 the best fitness is 0.028951775394430702']
# ['At iteration 29 the best fitness is 0.028951775394430702']
# ['At iteration 30 the best fitness is 0.028951775394430702']
#       Selected: 1470/3043 (48.3%), Fitness: 0.0290, Time: 2110.2s
#       Modality: D=48%, S=48%, Sk=48%,
#     Test Acc: 92.12%, F1: 92.37%, Features: 1470/3043 (48.3%), Model: 3.407MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05872552339032786']
# ['At iteration 1 the best fitness is 0.04847231765568938']
# ['At iteration 2 the best fitness is 0.043855080545846255']
# ['At iteration 3 the best fitness is 0.048653060343826084']
# ['At iteration 4 the best fitness is 0.048373730734887536']
# ['At iteration 5 the best fitness is 0.05345104014180581']
# ['At iteration 6 the best fitness is 0.04842302419528846']
# ['At iteration 7 the best fitness is 0.053286728607136076']
# ['At iteration 8 the best fitness is 0.04891595879929766']
# ['At iteration 9 the best fitness is 0.0438222182389123']
# ['At iteration 10 the best fitness is 0.029428278844972927']
# ['At iteration 11 the best fitness is 0.03915568766866827']
# ['At iteration 12 the best fitness is 0.04405225438744993']
# ['At iteration 13 the best fitness is 0.03912282536173432']
# ['At iteration 14 the best fitness is 0.04390437400624718']
# ['At iteration 15 the best fitness is 0.0438222182389123']
# ['At iteration 16 the best fitness is 0.02932969192417109']
# ['At iteration 17 the best fitness is 0.03895851382706459']
# ['At iteration 18 the best fitness is 0.048570904576491214']
# ['At iteration 19 the best fitness is 0.03900780728746551']
# ['At iteration 20 the best fitness is 0.03895851382706459']
# ['At iteration 21 the best fitness is 0.03420982748948568']
# ['At iteration 22 the best fitness is 0.03422625864295265']
# ['At iteration 23 the best fitness is 0.04862019803689213']
# ['At iteration 24 the best fitness is 0.03900780728746551']
# ['At iteration 25 the best fitness is 0.038991376133998536']
# ['At iteration 26 the best fitness is 0.03419339633601871']
# ['At iteration 27 the best fitness is 0.03419339633601871']
# ['At iteration 28 the best fitness is 0.04378935593197836']
# ['At iteration 29 the best fitness is 0.048587335729958187']
#       Selected: 1497/3043 (49.2%), Fitness: 0.0486, Time: 1848.4s
#       Modality: D=46%, S=48%, Sk=50%,
#     Test Acc: 87.97%, F1: 88.22%, Features: 1497/3043 (49.2%), Model: 3.460MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.053500333602206726
# At iteration 2 the best fitness is 0.03917211882213524
# At iteration 3 the best fitness is 0.04405225438744993
# At iteration 4 the best fitness is 0.04357575093690771
# At iteration 5 the best fitness is 0.03918854997560221
# At iteration 6 the best fitness is 0.03894208267359762
# At iteration 7 the best fitness is 0.03894208267359762
# At iteration 8 the best fitness is 0.030003369216316994
# At iteration 9 the best fitness is 0.04839016188835451
# At iteration 10 the best fitness is 0.030003369216316994
# At iteration 11 the best fitness is 0.04372363131811047
# At iteration 12 the best fitness is 0.04326355902103521
# At iteration 13 the best fitness is 0.03366759942507556
# At iteration 14 the best fitness is 0.04336214594183706
# At iteration 15 the best fitness is 0.04355931978344073
# At iteration 16 the best fitness is 0.03879420229239485
# At iteration 17 the best fitness is 0.04362504439730863
# At iteration 18 the best fitness is 0.03879420229239485
# At iteration 19 the best fitness is 0.03897494498053156
# At iteration 20 the best fitness is 0.04308281633289851
# At iteration 21 the best fitness is 0.033585443657740695
# At iteration 22 the best fitness is 0.02932969192417109
# At iteration 23 the best fitness is 0.033569012504273715
# At iteration 24 the best fitness is 0.033569012504273715
# At iteration 25 the best fitness is 0.02878746385976097
# At iteration 26 the best fitness is 0.029214673849902274
# At iteration 27 the best fitness is 0.029132518082567407
# At iteration 28 the best fitness is 0.03393049788054713
# At iteration 29 the best fitness is 0.03373332403894345
# At iteration 30 the best fitness is 0.0337004617320095
#       Selected: 1467/3043 (48.2%), Fitness: 0.0337, Time: 1861.7s
#       Modality: D=49%, S=49%, Sk=48%,
#     Test Acc: 87.55%, F1: 88.09%, Features: 1467/3043 (48.2%), Model: 3.401MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05330315976060305']
# ['At iteration 1 the best fitness is 0.04260631288235628']
# ['At iteration 2 the best fitness is 0.032681730217057156']
# ['At iteration 3 the best fitness is 0.032681730217057156']
# ['At iteration 4 the best fitness is 0.031104339484227708']
# ['At iteration 5 the best fitness is 0.029592673365266157']
# ['At iteration 6 the best fitness is 0.029592673365266157']
# ['At iteration 7 the best fitness is 0.024153878582074476']
# ['At iteration 8 the best fitness is 0.024153878582074476']
# ['At iteration 9 the best fitness is 0.024153878582074476']
# ['At iteration 10 the best fitness is 0.024153878582074476']
# ['At iteration 11 the best fitness is 0.02398956704740474']
# ['At iteration 12 the best fitness is 0.02398956704740474']
# ['At iteration 13 the best fitness is 0.023184440527523043']
# ['At iteration 14 the best fitness is 0.023184440527523043']
# ['At iteration 15 the best fitness is 0.023036560146320283']
# ['At iteration 16 the best fitness is 0.023036560146320283']
# ['At iteration 17 the best fitness is 0.023036560146320283']
# ['At iteration 18 the best fitness is 0.023036560146320283']
# ['At iteration 19 the best fitness is 0.023036560146320283']
# ['At iteration 20 the best fitness is 0.023036560146320283']
# ['At iteration 21 the best fitness is 0.023036560146320283']
# ['At iteration 22 the best fitness is 0.023036560146320283']
# ['At iteration 23 the best fitness is 0.018797239566217552']
# ['At iteration 24 the best fitness is 0.018797239566217552']
# ['At iteration 25 the best fitness is 0.018797239566217552']
# ['At iteration 26 the best fitness is 0.018797239566217552']
# ['At iteration 27 the best fitness is 0.018797239566217552']
# ['At iteration 28 the best fitness is 0.018797239566217552']
# ['At iteration 29 the best fitness is 0.018797239566217552']
#       Selected: 1144/3043 (37.6%), Fitness: 0.0188, Time: 1820.1s
#       Modality: D=37%, S=40%, Sk=37%,
#     Test Acc: 87.97%, F1: 88.16%, Features: 1144/3043 (37.6%), Model: 2.771MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.04824228150715175']
# ['At iteration 1 the best fitness is 0.04811083227941596']
# ['At iteration 2 the best fitness is 0.04811083227941596']
# ['At iteration 3 the best fitness is 0.04811083227941596']
# ['At iteration 4 the best fitness is 0.03708536233182962']
# ['At iteration 5 the best fitness is 0.03708536233182962']
# ['At iteration 6 the best fitness is 0.03708536233182962']
# ['At iteration 7 the best fitness is 0.03708536233182962']
# ['At iteration 8 the best fitness is 0.032287382533849794']
# ['At iteration 9 the best fitness is 0.032287382533849794']
# ['At iteration 10 the best fitness is 0.032287382533849794']
# ['At iteration 11 the best fitness is 0.032287382533849794']
# ['At iteration 12 the best fitness is 0.032287382533849794']
# ['At iteration 13 the best fitness is 0.032287382533849794']
# ['At iteration 14 the best fitness is 0.032287382533849794']
# ['At iteration 15 the best fitness is 0.032287382533849794']
# ['At iteration 16 the best fitness is 0.032287382533849794']
# ['At iteration 17 the best fitness is 0.027472971582403097']
# ['At iteration 18 the best fitness is 0.027472971582403097']
# ['At iteration 19 the best fitness is 0.027472971582403097']
# ['At iteration 20 the best fitness is 0.027472971582403097']
# ['At iteration 21 the best fitness is 0.027472971582403097']
# ['At iteration 22 the best fitness is 0.027472971582403097']
# ['At iteration 23 the best fitness is 0.027472971582403097']
# ['At iteration 24 the best fitness is 0.027472971582403097']
# ['At iteration 25 the best fitness is 0.027472971582403097']
# ['At iteration 26 the best fitness is 0.027472971582403097']
# ['At iteration 27 the best fitness is 0.027472971582403097']
# ['At iteration 28 the best fitness is 0.027472971582403097']
# ['At iteration 29 the best fitness is 0.027472971582403097']
#       Selected: 1380/3043 (45.3%), Fitness: 0.0275, Time: 2514.3s
#       Modality: D=45%, S=46%, Sk=45%,
#     Test Acc: 89.21%, F1: 89.09%, Features: 1380/3043 (45.3%), Model: 3.232MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05338531552793792']
# ['At iteration 1 the best fitness is 0.05338531552793792']
# ['At iteration 2 the best fitness is 0.05338531552793792']
# ['At iteration 3 the best fitness is 0.05338531552793792']
# ['At iteration 4 the best fitness is 0.05338531552793792']
# ['At iteration 5 the best fitness is 0.04960606724491054']
# ['At iteration 6 the best fitness is 0.04014155687668667']
# ['At iteration 7 the best fitness is 0.04014155687668667']
# ['At iteration 8 the best fitness is 0.04014155687668667']
# ['At iteration 9 the best fitness is 0.04014155687668667']
# ['At iteration 10 the best fitness is 0.04014155687668667']
# ['At iteration 11 the best fitness is 0.04014155687668667']
# ['At iteration 12 the best fitness is 0.04014155687668667']
# ['At iteration 13 the best fitness is 0.04014155687668667']
# ['At iteration 14 the best fitness is 0.04014155687668667']
# ['At iteration 15 the best fitness is 0.04014155687668667']
# ['At iteration 16 the best fitness is 0.04014155687668667']
# ['At iteration 17 the best fitness is 0.04014155687668667']
# ['At iteration 18 the best fitness is 0.04014155687668667']
# ['At iteration 19 the best fitness is 0.04014155687668667']
# ['At iteration 20 the best fitness is 0.04014155687668667']
# ['At iteration 21 the best fitness is 0.03992795188161601']
# ['At iteration 22 the best fitness is 0.03991152072814904']
# ['At iteration 23 the best fitness is 0.030759202275797773']
# ['At iteration 24 the best fitness is 0.030759202275797773']
# ['At iteration 25 the best fitness is 0.030759202275797773']
# ['At iteration 26 the best fitness is 0.030759202275797773']
# ['At iteration 27 the best fitness is 0.030759202275797773']
# ['At iteration 28 the best fitness is 0.030759202275797773']
# ['At iteration 29 the best fitness is 0.030759202275797773']
#       Selected: 1580/3043 (51.9%), Fitness: 0.0308, Time: 2215.6s
#       Modality: D=51%, S=52%, Sk=52%,
#     Test Acc: 89.63%, F1: 89.76%, Features: 1580/3043 (51.9%), Model: 3.622MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04871878495769398']
# ['At iteration 2 the best fitness is 0.04871878495769398']
# ['At iteration 3 the best fitness is 0.04871878495769398']
# ['At iteration 4 the best fitness is 0.03582008052924907']
# ['At iteration 5 the best fitness is 0.03582008052924907']
# ['At iteration 6 the best fitness is 0.03582008052924907']
# ['At iteration 7 the best fitness is 0.03582008052924907']
# ['At iteration 8 the best fitness is 0.03582008052924907']
# ['At iteration 9 the best fitness is 0.03582008052924907']
# ['At iteration 10 the best fitness is 0.03582008052924907']
# ['At iteration 11 the best fitness is 0.03582008052924907']
# ['At iteration 12 the best fitness is 0.03582008052924907']
# ['At iteration 13 the best fitness is 0.03582008052924907']
# ['At iteration 14 the best fitness is 0.03582008052924907']
# ['At iteration 15 the best fitness is 0.03485064247469764']
# ['At iteration 16 the best fitness is 0.03485064247469764']
# ['At iteration 17 the best fitness is 0.03485064247469764']
# ['At iteration 18 the best fitness is 0.03485064247469764']
# ['At iteration 19 the best fitness is 0.03485064247469764']
# ['At iteration 20 the best fitness is 0.03485064247469764']
# ['At iteration 21 the best fitness is 0.03485064247469764']
# ['At iteration 22 the best fitness is 0.03485064247469764']
# ['At iteration 23 the best fitness is 0.03485064247469764']
# ['At iteration 24 the best fitness is 0.030479872666859226']
# ['At iteration 25 the best fitness is 0.030479872666859226']
# ['At iteration 26 the best fitness is 0.030479872666859226']
# ['At iteration 27 the best fitness is 0.030479872666859226']
# ['At iteration 28 the best fitness is 0.030479872666859226']
# ['At iteration 29 the best fitness is 0.030414148052991332']
#       Selected: 1559/3043 (51.2%), Fitness: 0.0304, Time: 2133.7s
#       Modality: D=51%, S=51%, Sk=51%,
#     Test Acc: 90.04%, F1: 90.11%, Features: 1559/3043 (51.2%), Model: 3.581MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04908027033396739']
# ['At iteration 2 the best fitness is 0.044463033224124274']
# ['At iteration 3 the best fitness is 0.03994438303508299']
# ['At iteration 4 the best fitness is 0.03979650265388023']
# ['At iteration 5 the best fitness is 0.03979650265388023']
# ['At iteration 6 the best fitness is 0.03979650265388023']
# ['At iteration 7 the best fitness is 0.03979650265388023']
# ['At iteration 8 the best fitness is 0.035228559004438026']
# ['At iteration 9 the best fitness is 0.03519569669750408']
# ...
# ['At iteration 14 the best fitness is 0.09197137024911262']
# ['At iteration 15 the best fitness is 0.09197137024911262']
# ['At iteration 16 the best fitness is 0.09197137024911262']
# ['At iteration 17 the best fitness is 0.09197137024911262']
# ['At iteration 18 the best fitness is 0.09197137024911262']
# ['At iteration 19 the best fitness is 0.09197137024911262']
# ['At iteration 20 the best fitness is 0.09197137024911262']
# ['At iteration 21 the best fitness is 0.09197137024911262']
# ['At iteration 22 the best fitness is 0.09197137024911262']
# ['At iteration 23 the best fitness is 0.09197137024911262']
# ['At iteration 24 the best fitness is 0.09197137024911262']
# ['At iteration 25 the best fitness is 0.09197137024911262']
# ['At iteration 26 the best fitness is 0.09197137024911262']
# ['At iteration 27 the best fitness is 0.09197137024911262']
# ['At iteration 28 the best fitness is 0.09197137024911262']
# ['At iteration 29 the best fitness is 0.09197137024911262']
#       Selected: 1519/3043 (49.9%), Fitness: 0.0920, Time: 2517.4s
#       Modality: D=52%, S=51%, Sk=49%,
#     Test Acc: 92.93%, F1: 92.64%, Features: 1519/3043 (49.9%), Model: 3.503MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09271077215512642']
# ['At iteration 1 the best fitness is 0.09271077215512642']
# ['At iteration 2 the best fitness is 0.09271077215512642']
# ['At iteration 3 the best fitness is 0.09211925063031538']
# ['At iteration 4 the best fitness is 0.09211925063031538']
# ['At iteration 5 the best fitness is 0.08840737806516008']
# ['At iteration 6 the best fitness is 0.08840737806516008']
# ['At iteration 7 the best fitness is 0.07668023884488312']
# ['At iteration 8 the best fitness is 0.07668023884488312']
# ['At iteration 9 the best fitness is 0.07668023884488312']
# ['At iteration 10 the best fitness is 0.07668023884488312']
# ['At iteration 11 the best fitness is 0.07668023884488312']
# ['At iteration 12 the best fitness is 0.07668023884488312']
# ['At iteration 13 the best fitness is 0.07668023884488312']
# ['At iteration 14 the best fitness is 0.07668023884488312']
# ['At iteration 15 the best fitness is 0.07668023884488312']
# ['At iteration 16 the best fitness is 0.07668023884488312']
# ['At iteration 17 the best fitness is 0.07668023884488312']
# ['At iteration 18 the best fitness is 0.07668023884488312']
# ['At iteration 19 the best fitness is 0.07668023884488312']
# ['At iteration 20 the best fitness is 0.07668023884488312']
# ['At iteration 21 the best fitness is 0.07668023884488312']
# ['At iteration 22 the best fitness is 0.07668023884488312']
# ['At iteration 23 the best fitness is 0.07668023884488312']
# ['At iteration 24 the best fitness is 0.07668023884488312']
# ['At iteration 25 the best fitness is 0.07668023884488312']
# ['At iteration 26 the best fitness is 0.07668023884488312']
# ['At iteration 27 the best fitness is 0.07668023884488312']
# ['At iteration 28 the best fitness is 0.07668023884488312']
# ['At iteration 29 the best fitness is 0.07668023884488312']
#       Selected: 1548/3043 (50.9%), Fitness: 0.0767, Time: 1998.1s
#       Modality: D=55%, S=51%, Sk=50%,
#     Test Acc: 95.96%, F1: 95.89%, Features: 1548/3043 (50.9%), Model: 3.560MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09998663690423439']
# ['At iteration 2 the best fitness is 0.08827592883742429']
# ['At iteration 3 the best fitness is 0.08827592883742429']
# ['At iteration 4 the best fitness is 0.08827592883742429']
# ['At iteration 5 the best fitness is 0.08827592883742429']
# ['At iteration 6 the best fitness is 0.08827592883742429']
# ['At iteration 7 the best fitness is 0.08827592883742429']
# ['At iteration 8 the best fitness is 0.08827592883742429']
# ['At iteration 9 the best fitness is 0.08827592883742429']
# ['At iteration 10 the best fitness is 0.08827592883742429']
# ['At iteration 11 the best fitness is 0.08816091076315548']
# ['At iteration 12 the best fitness is 0.08816091076315548']
# ['At iteration 13 the best fitness is 0.08816091076315548']
# ['At iteration 14 the best fitness is 0.08816091076315548']
# ['At iteration 15 the best fitness is 0.08078645909324579']
# ['At iteration 16 the best fitness is 0.08078645909324579']
# ['At iteration 17 the best fitness is 0.08078645909324579']
# ['At iteration 18 the best fitness is 0.08078645909324579']
# ['At iteration 19 the best fitness is 0.08078645909324579']
# ['At iteration 20 the best fitness is 0.08078645909324579']
# ['At iteration 21 the best fitness is 0.08078645909324579']
# ['At iteration 22 the best fitness is 0.07654878961714734']
# ['At iteration 23 the best fitness is 0.07654878961714734']
# ['At iteration 24 the best fitness is 0.07577652540419959']
# ['At iteration 25 the best fitness is 0.07577652540419959']
# ['At iteration 26 the best fitness is 0.07577652540419959']
# ['At iteration 27 the best fitness is 0.07577652540419959']
# ['At iteration 28 the best fitness is 0.07577652540419959']
# ['At iteration 29 the best fitness is 0.07577652540419959']
#       Selected: 1493/3043 (49.1%), Fitness: 0.0758, Time: 1911.9s
#       Modality: D=46%, S=51%, Sk=49%,
#     Test Acc: 92.93%, F1: 92.39%, Features: 1493/3043 (49.1%), Model: 3.452MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.099608720374494']
# ['At iteration 2 the best fitness is 0.09566681166080096']
# ['At iteration 3 the best fitness is 0.09566681166080096']
# ['At iteration 4 the best fitness is 0.091741334100575']
# ['At iteration 5 the best fitness is 0.08738864655020773']
# ['At iteration 6 the best fitness is 0.08738864655020773']
# ['At iteration 7 the best fitness is 0.08738864655020773']
# ['At iteration 8 the best fitness is 0.08316740822757625']
# ['At iteration 9 the best fitness is 0.08316740822757625']
# ['At iteration 10 the best fitness is 0.08316740822757625']
# ['At iteration 11 the best fitness is 0.08316740822757625']
# ['At iteration 12 the best fitness is 0.08316740822757625']
# ['At iteration 13 the best fitness is 0.08316740822757625']
# ['At iteration 14 the best fitness is 0.08316740822757625']
# ['At iteration 15 the best fitness is 0.08316740822757625']
# ['At iteration 16 the best fitness is 0.08316740822757625']
# ['At iteration 17 the best fitness is 0.08315097707410928']
# ['At iteration 18 the best fitness is 0.08315097707410928']
# ['At iteration 19 the best fitness is 0.07919263720694937']
# ['At iteration 20 the best fitness is 0.07919263720694937']
# ['At iteration 21 the best fitness is 0.07919263720694937']
# ['At iteration 22 the best fitness is 0.07919263720694937']
# ['At iteration 23 the best fitness is 0.07538217772099222']
# ['At iteration 24 the best fitness is 0.07538217772099222']
# ['At iteration 25 the best fitness is 0.07538217772099222']
# ['At iteration 26 the best fitness is 0.07538217772099222']
# ['At iteration 27 the best fitness is 0.07538217772099222']
# ['At iteration 28 the best fitness is 0.07538217772099222']
# ['At iteration 29 the best fitness is 0.07538217772099222']
# ['At iteration 30 the best fitness is 0.07538217772099222']
#       Selected: 1469/3043 (48.3%), Fitness: 0.0754, Time: 2188.9s
#       Modality: D=48%, S=44%, Sk=50%,
#     Test Acc: 93.43%, F1: 93.24%, Features: 1469/3043 (48.3%), Model: 3.405MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10714748357907342']
# ['At iteration 2 the best fitness is 0.09533818859146148']
# ['At iteration 3 the best fitness is 0.09533818859146148']
# ['At iteration 4 the best fitness is 0.08733935308980681']
# ['At iteration 5 the best fitness is 0.08733935308980681']
# ['At iteration 6 the best fitness is 0.08733935308980681']
# ['At iteration 7 the best fitness is 0.08733935308980681']
# ['At iteration 8 the best fitness is 0.08733935308980681']
# ['At iteration 9 the best fitness is 0.08733935308980681']
# ['At iteration 10 the best fitness is 0.08733935308980681']
# ['At iteration 11 the best fitness is 0.08733935308980681']
# ['At iteration 12 the best fitness is 0.08733935308980681']
# ['At iteration 13 the best fitness is 0.08733935308980681']
# ['At iteration 14 the best fitness is 0.08733935308980681']
# ['At iteration 15 the best fitness is 0.08733935308980681']
# ['At iteration 16 the best fitness is 0.08733935308980681']
# ['At iteration 17 the best fitness is 0.08733935308980681']
# ['At iteration 18 the best fitness is 0.08733935308980681']
# ['At iteration 19 the best fitness is 0.08733935308980681']
# ['At iteration 20 the best fitness is 0.08733935308980681']
# ['At iteration 21 the best fitness is 0.08733935308980681']
# ['At iteration 22 the best fitness is 0.08733935308980681']
# ['At iteration 23 the best fitness is 0.08733935308980681']
# ['At iteration 24 the best fitness is 0.08733935308980681']
# ['At iteration 25 the best fitness is 0.08733935308980681']
# ['At iteration 26 the best fitness is 0.08733935308980681']
# ['At iteration 27 the best fitness is 0.08733935308980681']
# ['At iteration 28 the best fitness is 0.08733935308980681']
# ['At iteration 29 the best fitness is 0.08733935308980681']
# ['At iteration 30 the best fitness is 0.08733935308980681']
#       Selected: 1477/3043 (48.5%), Fitness: 0.0873, Time: 1981.7s
#       Modality: D=49%, S=50%, Sk=48%,
#     Test Acc: 91.92%, F1: 91.56%, Features: 1477/3043 (48.5%), Model: 3.421MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09170847179364104']
# ['At iteration 1 the best fitness is 0.09170847179364104']
# ['At iteration 2 the best fitness is 0.09170847179364104']
# ['At iteration 3 the best fitness is 0.0880936180309069']
# ['At iteration 4 the best fitness is 0.08305082203492675']
# ['At iteration 5 the best fitness is 0.07879515328698064']
# ['At iteration 6 the best fitness is 0.07879515328698064']
# ['At iteration 7 the best fitness is 0.07879515328698064']
# ['At iteration 8 the best fitness is 0.07879515328698064']
# ['At iteration 9 the best fitness is 0.07879515328698064']
# ['At iteration 10 the best fitness is 0.07879515328698064']
# ['At iteration 11 the best fitness is 0.07490096991530795']
# ['At iteration 12 the best fitness is 0.07490096991530795']
# ['At iteration 13 the best fitness is 0.07490096991530795']
# ['At iteration 14 the best fitness is 0.06530831252735686']
# ['At iteration 15 the best fitness is 0.06530831252735686']
# ['At iteration 16 the best fitness is 0.06530831252735686']
# ['At iteration 17 the best fitness is 0.06530831252735686']
# ['At iteration 18 the best fitness is 0.06530831252735686']
# ['At iteration 19 the best fitness is 0.06530831252735686']
# ['At iteration 20 the best fitness is 0.06530831252735686']
# ['At iteration 21 the best fitness is 0.06530831252735686']
# ['At iteration 22 the best fitness is 0.06530831252735686']
# ['At iteration 23 the best fitness is 0.06530831252735686']
# ['At iteration 24 the best fitness is 0.06530831252735686']
# ['At iteration 25 the best fitness is 0.06530831252735686']
# ['At iteration 26 the best fitness is 0.06530831252735686']
# ['At iteration 27 the best fitness is 0.06530831252735686']
# ['At iteration 28 the best fitness is 0.06427314985893753']
# ['At iteration 29 the best fitness is 0.06427314985893753']
#       Selected: 553/3043 (18.2%), Fitness: 0.0643, Time: 1872.0s
#       Modality: D=18%, S=20%, Sk=18%,
#     Test Acc: 92.42%, F1: 91.97%, Features: 553/3043 (18.2%), Model: 1.616MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08745437116407562']
# ['At iteration 2 the best fitness is 0.08745437116407562']
# ['At iteration 3 the best fitness is 0.08745437116407562']
# ['At iteration 4 the best fitness is 0.08745437116407562']
# ['At iteration 5 the best fitness is 0.08745437116407562']
# ['At iteration 6 the best fitness is 0.07700886191422258']
# ['At iteration 7 the best fitness is 0.07700886191422258']
# ['At iteration 8 the best fitness is 0.07700886191422258']
# ['At iteration 9 the best fitness is 0.07700886191422258']
# ['At iteration 10 the best fitness is 0.07700886191422258']
# ['At iteration 11 the best fitness is 0.07700886191422258']
# ['At iteration 12 the best fitness is 0.07700886191422258']
# ['At iteration 13 the best fitness is 0.07700886191422258']
# ['At iteration 14 the best fitness is 0.07700886191422258']
# ['At iteration 15 the best fitness is 0.07700886191422258']
# ['At iteration 16 the best fitness is 0.07700886191422258']
# ['At iteration 17 the best fitness is 0.07700886191422258']
# ['At iteration 18 the best fitness is 0.07700886191422258']
# ['At iteration 19 the best fitness is 0.07700886191422258']
# ['At iteration 20 the best fitness is 0.07700886191422258']
# ['At iteration 21 the best fitness is 0.07700886191422258']
# ['At iteration 22 the best fitness is 0.07700886191422258']
# ['At iteration 23 the best fitness is 0.07700886191422258']
# ['At iteration 24 the best fitness is 0.07700886191422258']
# ['At iteration 25 the best fitness is 0.07306695320052965']
# ['At iteration 26 the best fitness is 0.07306695320052965']
# ['At iteration 27 the best fitness is 0.07306695320052965']
# ['At iteration 28 the best fitness is 0.07306695320052965']
# ['At iteration 29 the best fitness is 0.07306695320052965']
#       Selected: 1568/3043 (51.5%), Fitness: 0.0731, Time: 4871.4s
#       Modality: D=53%, S=52%, Sk=51%,
#     Test Acc: 94.44%, F1: 94.08%, Features: 1568/3043 (51.5%), Model: 3.599MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09269434100165945']
# ['At iteration 1 the best fitness is 0.08595443184343912']
# ['At iteration 2 the best fitness is 0.08595443184343912']
# ['At iteration 3 the best fitness is 0.08595443184343912']
# ['At iteration 4 the best fitness is 0.07846653021764118']
# ['At iteration 5 the best fitness is 0.0752311611030281']
# ['At iteration 6 the best fitness is 0.0752311611030281']
# ['At iteration 7 the best fitness is 0.0752311611030281']
# ['At iteration 8 the best fitness is 0.0752311611030281']
# ['At iteration 9 the best fitness is 0.0752311611030281']
# ['At iteration 10 the best fitness is 0.0752311611030281']
# ['At iteration 11 the best fitness is 0.0752311611030281']
# ['At iteration 12 the best fitness is 0.0752311611030281']
# ['At iteration 13 the best fitness is 0.0752311611030281']
# ['At iteration 14 the best fitness is 0.07396596228607115']
# ['At iteration 15 the best fitness is 0.0738180819048684']
# ['At iteration 16 the best fitness is 0.0738180819048684']
# ['At iteration 17 the best fitness is 0.0738180819048684']
# ['At iteration 18 the best fitness is 0.0732594226869913']
# ['At iteration 19 the best fitness is 0.0732594226869913']
# ['At iteration 20 the best fitness is 0.0732594226869913']
# ['At iteration 21 the best fitness is 0.0732594226869913']
# ['At iteration 22 the best fitness is 0.0732594226869913']
# ['At iteration 23 the best fitness is 0.0732594226869913']
# ['At iteration 24 the best fitness is 0.0732594226869913']
# ['At iteration 25 the best fitness is 0.0732594226869913']
# ['At iteration 26 the best fitness is 0.0732594226869913']
# ['At iteration 27 the best fitness is 0.0732594226869913']
# ['At iteration 28 the best fitness is 0.0732594226869913']
# ['At iteration 29 the best fitness is 0.0718463434888316']
#       Selected: 774/3043 (25.4%), Fitness: 0.0718, Time: 1644.2s
#       Modality: D=24%, S=25%, Sk=26%,
#     Test Acc: 94.95%, F1: 94.92%, Features: 774/3043 (25.4%), Model: 2.048MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879}, Total: 3043
# Results table: (90, 32)
# Methods: 18, Folds per method: {'baseline': 5, 'lasso': 5, 'meta_BAT': 5, 'meta_CS': 5, 'meta_DE': 5, 'meta_FFA': 5, 'meta_GA': 5, 'meta_GWO': 5, 'meta_HHO': 5, 'meta_JAYA': 5, 'meta_MFO': 5, 'meta_MVO': 5, 'meta_PSO': 5, 'meta_SCA': 5, 'meta_SSA': 5, 'meta_WOA': 5, 'mutual_info': 5, 'rfe': 5}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          94.755245         97.979798     94.644405
# 1  baseline     2          92.116183         97.979798     92.167292
# 2  baseline     3          90.454545         97.979798     90.287189
# 3  baseline     4          88.181818         98.484848     86.535732
# 4  baseline     5          93.434343         92.116183     93.129515
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        94.644405            95.481602         94.755245               3043
# 1        92.134791            93.190900         92.148760               3043
# 2        90.287189            92.084809         90.454545               3043
# 3        86.535732            91.555011         88.181818               3043
# 4        93.129515            95.234160         93.434343               3043
#
#    Features Total  ...  N Test  depth_retained  depth_total  \
# 0            3043  ...     286             512          512
# 1            3043  ...     241             512          512
# 2            3043  ...     220             512          512
# 3            3043  ...     220             512          512
# 4            3043  ...     198             512          512
#
#    depth_retention_%  sensor_retained  sensor_total  sensor_retention_%  \
# 0              100.0              652           652               100.0
# 1              100.0              652           652               100.0
# 2              100.0              652           652               100.0
# 3              100.0              652           652               100.0
# 4              100.0              652           652               100.0
#
#    skeleton_retained  skeleton_total  skeleton_retention_%
# 0               1879            1879                 100.0
# 1               1879            1879                 100.0
# 2               1879            1879                 100.0
# 3               1879            1879                 100.0
# 4               1879            1879                 100.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              91.79              2.57              91.35              3.12                  3043.0                      100.00              0.00                34.69                34.69          1697046.0                  6.48                        0.00               56.48
# mutual_info              92.50              3.56              91.94              4.38                  1521.0                       49.98             43.71                30.45                74.16           917782.0                  3.51                       50.02               38.46
#         rfe              91.55              4.28              91.20              4.73                  1521.0                       49.98              9.09                31.01                40.10           917782.0                  3.51                       50.02               38.46
#       lasso              82.36              6.37              82.11              6.21                  1521.0                       49.98            269.87                32.56               302.43           917782.0                  3.51                       50.02               38.46
#    meta_BAT              91.47              4.42              90.91              5.40                  1502.6                       49.38           2122.59                33.22              2155.81           908361.2                  3.47                       50.62               38.39
#     meta_CS              92.16              2.45              91.96              2.71                  1500.2                       49.30           4110.09                32.79              4142.89           907132.4                  3.47                       50.70               38.37
#     meta_DE              92.88              3.67              92.59              4.19                  1495.8                       49.16           2091.44                32.45              2123.89           904879.6                  3.46                       50.84               38.46
#    meta_FFA              91.04              4.37              90.79              4.64                  1494.6                       49.12           1981.27                32.56              2013.82           904265.2                  3.46                       50.88               38.35
#     meta_GA              90.02              3.97              89.42              4.79                  1476.0                       48.50           1980.74                32.27              2013.01           894742.0                  3.42                       51.50               38.27
#    meta_GWO              90.99              3.56              90.65              3.75                  1158.8                       38.08           1907.59                29.92              1937.51           732335.6                  2.80                       61.92               34.65
#    meta_HHO              89.30              4.37              88.88              5.09                  1131.0                       37.17           2534.88                30.83              2565.72           718102.0                  2.75                       62.83               34.12
#   meta_JAYA              92.00              3.37              91.84              3.59                  1544.2                       50.75           2006.41                32.03              2038.45           929660.4                  3.55                       49.25               38.78
#    meta_MFO              91.62              3.47              91.18              3.74                  1521.6                       50.00           1910.60                32.93              1943.54           918089.2                  3.51                       50.00               38.53
#    meta_MVO              91.39              2.49              90.95              3.12                  1494.6                       49.12           2036.01                33.83              2069.84           904265.2                  3.46                       50.88               38.39
#    meta_PSO              91.32              2.61              91.14              2.93                  1491.6                       49.02           2032.79                32.53              2065.31           902729.2                  3.45                       50.98               38.35
#    meta_SCA              90.63              2.94              90.12              3.49                   626.6                       20.59           1928.34                31.02              1959.36           459849.2                  1.76                       79.41               28.27
#    meta_SSA              91.91              2.97              91.68              3.15                  1518.6                       49.90           5056.65                33.09              5089.75           916553.2                  3.50                       50.10               38.57
#    meta_WOA              90.72              5.87              90.40              6.53                   673.4                       22.13           1803.32                26.08              1829.40           483810.8                  1.85                       77.87               28.43

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_WOA
#     F1 Macro:           95.45%
#     F1 Weighted:        95.45%
#     Test Accuracy:      95.45%
#     Feature Retention:  15.41% (469/3043)
#     Modality Retention: depth=16.6%, sensor=15.8%, skeleton=15.0%
#
#   Fold 2: Best = meta_DE
#     F1 Macro:           92.37%
#     F1 Weighted:        92.36%
#     Test Accuracy:      92.12%
#     Feature Retention:  48.31% (1470/3043)
#     Modality Retention: depth=48.2%, sensor=48.2%, skeleton=48.4%
#
#   Fold 3: Best = meta_DE
#     F1 Macro:           95.72%
#     F1 Weighted:        95.72%
#     Test Accuracy:      95.91%
#     Feature Retention:  49.59% (1509/3043)
#     Modality Retention: depth=47.5%, sensor=50.0%, skeleton=50.0%
#
#   Fold 4: Best = meta_CS
#     F1 Macro:           89.38%
#     F1 Weighted:        89.38%
#     Test Accuracy:      90.00%
#     Feature Retention:  49.75% (1514/3043)
#     Modality Retention: depth=48.2%, sensor=48.9%, skeleton=50.5%
#
#   Fold 5: Best = meta_JAYA
#     F1 Macro:           95.89%
#     F1 Weighted:        95.89%
#     Test Accuracy:      95.96%
#     Feature Retention:  50.87% (1548/3043)
#     Modality Retention: depth=55.5%, sensor=50.6%, skeleton=49.7%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 93.76% ± 2.85%
#
#   Average F1 Weighted         : 93.76% ± 2.85%
#
#   Average Test Accuracy       : 93.89% ± 2.70%
#
#   Average Feature Retention   : 42.79% ± 15.33%
#
#   Average Modality-wise Feature Retention:
#            depth: 43.20% ± 15.22%
#           sensor: 42.70% ± 15.07%
#         skeleton: 42.70% ± 15.53%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%
#     1           meta_WOA         95.45            95.45              95.45                  15.41              16.60               15.80                 14.95
#     2            meta_DE         92.37            92.36              92.12                  48.31              48.24               48.16                 48.38
#     3            meta_DE         95.72            95.72              95.91                  49.59              47.46               50.00                 50.03
#     4            meta_CS         89.38            89.38              90.00                  49.75              48.24               48.93                 50.45
#     5          meta_JAYA         95.89            95.89              95.96                  50.87              55.47               50.61                 49.71
#
# Saved to: results_noise_10\best_metaheuristic_per_fold.csv

# %% [markdown]
# ## Figure Creation

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from pathlib import Path


BASE_DIR = Path("../")

DATASETS = {
    "CZU-MHAD": BASE_DIR / "czu-mhad",
    "UTD-MHAD": BASE_DIR / "utd-mhad",
    "MM-Fit":   BASE_DIR / "mmfit",
}

NOISE_FOLDERS = {
    "0.2σ": "results_noise_{N}",
    "0.5σ": "results_noise_0.5_{N}",
    "1.0σ": "results_noise_1.0_{N}",
}

CORRUPTION_RATES = [10, 20, 30, 40, 50]
CSV_FILE = "best_metaheuristic_per_fold.csv"
ACC_COL  = "Test Accuracy (%)"


def load_mean_accuracy(folder: Path) -> float | None:
    csv_path = folder / CSV_FILE
    if not csv_path.exists():
        print(f"  [MISSING] {csv_path}")
        return None
    
    df = pd.read_csv(csv_path)
    if ACC_COL not in df.columns:
        print(f"  [BAD COL] {csv_path} — columns: {df.columns.tolist()}")
        return None
    
    return df[ACC_COL].mean()


def build_data() -> pd.DataFrame:
    rows = []
    for dataset, base in DATASETS.items():
        for severity_label, folder_template in NOISE_FOLDERS.items():
            for rate in CORRUPTION_RATES:
                folder_name = folder_template.replace("{N}", str(rate))
                folder_path = base / folder_name
                acc = load_mean_accuracy(folder_path)
                rows.append({
                    "Dataset":        dataset,
                    "Severity":       severity_label,
                    "Corruption (%)": rate,
                    "Accuracy (%)":   acc,
                })

    return pd.DataFrame(rows)



SEVERITY_COLORS = {
    "0.2σ": "#4C72B0",   
    "0.5σ": "#DD8452",   
    "1.0σ": "#C44E52",   
}

SEVERITY_MARKERS = {
    "0.2σ": "o",
    "0.5σ": "s",
    "1.0σ": "^",
}

DATASET_ORDER = ["UTD-MHAD", "CZU-MHAD", "MM-Fit"]
SEVERITY_ORDER = ["0.2σ", "0.5σ", "1.0σ"]

plt.rcParams.update({
    "font.family":      "serif",
    "axes.spines.top":  False,
    "axes.spines.right":False,
    "axes.grid":        True,
    "grid.alpha":       0.3,
    "grid.linestyle":   "--",
    "axes.labelsize":   11,
    "xtick.labelsize":  10,
    "ytick.labelsize":  10,
    "legend.fontsize":  10,
    "figure.dpi":       150,
})



def plot_bar_chart(df: pd.DataFrame, save_path: str = "noise_bar_chart.pdf"):
    fig, axes = plt.subplots(1, 3, figsize=(14, 4.5), sharey=False)
    fig.suptitle("Combined Metaheuristic — Accuracy under Gaussian Noise",
                 fontsize=13, fontweight="bold", y=1.01)

    n_sev   = len(SEVERITY_ORDER)
    n_rates = len(CORRUPTION_RATES)
    bar_w   = 0.22
    group_gap = 0.08
    x = np.arange(n_rates)

    for ax, dataset in zip(axes, DATASET_ORDER):
        sub = df[df["Dataset"] == dataset]

        for i, sev in enumerate(SEVERITY_ORDER):
            vals = []
            for rate in CORRUPTION_RATES:
                row = sub[(sub["Severity"] == sev) & (sub["Corruption (%)"] == rate)]
                vals.append(row["Accuracy (%)"].values[0] if not row.empty else np.nan)

            offset = (i - n_sev / 2 + 0.5) * (bar_w + group_gap / n_sev)
            bars = ax.bar(
                x + offset, vals,
                width=bar_w,
                color=SEVERITY_COLORS[sev],
                label=sev,
                edgecolor="white",
                linewidth=0.5,
                alpha=0.88,
            )

            # value labels on top of each bar
            for bar, v in zip(bars, vals):
                if not np.isnan(v):
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        bar.get_height() + 0.3,
                        f"{v:.1f}",
                        ha="center", va="bottom",
                        fontsize=6.5, color="#333333",
                    )

        ax.set_title(dataset, fontsize=11, fontweight="bold", pad=8)
        ax.set_xticks(x)
        ax.set_xticklabels([f"{r}%" for r in CORRUPTION_RATES])
        ax.set_xlabel("Corruption rate")
        ax.set_ylabel("Mean LOSO accuracy (%)")

        # tighten y-axis around the data range
        valid = df[df["Dataset"] == dataset]["Accuracy (%)"].dropna()
        if len(valid):
            lo, hi = valid.min(), valid.max()
            ax.set_ylim(max(0, lo - 3), min(100, hi + 5))

    # shared legend
    handles = [
        mpatches.Patch(color=SEVERITY_COLORS[s], label=f"Noise strength {s}", alpha=0.88)
        for s in SEVERITY_ORDER
    ]
    fig.legend(handles=handles, loc="lower center", ncol=3,
               bbox_to_anchor=(0.5, -0.07), frameon=False)

    fig.tight_layout()
    fig.savefig(save_path, bbox_inches="tight")
    print(f"Bar chart saved → {save_path}")
    plt.show()



def plot_line_chart(df: pd.DataFrame, save_path: str = "noise_line_chart.pdf"):
    fig, axes = plt.subplots(1, 3, figsize=(14, 4.5), sharey=False)
    fig.suptitle("Combined Metaheuristic — Accuracy under Gaussian Noise",
                 fontsize=13, fontweight="bold", y=1.01)

    for ax, dataset in zip(axes, DATASET_ORDER):
        sub = df[df["Dataset"] == dataset]

        for sev in SEVERITY_ORDER:
            vals = []
            for rate in CORRUPTION_RATES:
                row = sub[(sub["Severity"] == sev) & (sub["Corruption (%)"] == rate)]
                vals.append(row["Accuracy (%)"].values[0] if not row.empty else np.nan)

            ax.plot(
                CORRUPTION_RATES, vals,
                color=SEVERITY_COLORS[sev],
                marker=SEVERITY_MARKERS[sev],
                linewidth=2,
                markersize=6,
                label=f"Noise {sev}",
            )
            # annotate end-point
            if not np.isnan(vals[-1]):
                ax.annotate(
                    f"{vals[-1]:.1f}%",
                    xy=(CORRUPTION_RATES[-1], vals[-1]),
                    xytext=(4, 0), textcoords="offset points",
                    fontsize=8, color=SEVERITY_COLORS[sev], va="center",
                )

        ax.set_title(dataset, fontsize=11, fontweight="bold", pad=8)
        ax.set_xticks(CORRUPTION_RATES)
        ax.set_xticklabels([f"{r}%" for r in CORRUPTION_RATES])
        ax.set_xlabel("Corruption rate")
        ax.set_ylabel("Mean LOSO accuracy (%)")

        valid = df[df["Dataset"] == dataset]["Accuracy (%)"].dropna()
        if len(valid):
            lo, hi = valid.min(), valid.max()
            ax.set_ylim(max(0, lo - 3), min(100, hi + 5))

    # shared legend
    handles = [
        plt.Line2D([0], [0],
                   color=SEVERITY_COLORS[s],
                   marker=SEVERITY_MARKERS[s],
                   linewidth=2, markersize=6,
                   label=f"Noise strength {s}")
        for s in SEVERITY_ORDER
    ]
    fig.legend(handles=handles, loc="lower center", ncol=3,
               bbox_to_anchor=(0.5, -0.07), frameon=False)

    fig.tight_layout()
    fig.savefig(save_path, bbox_inches="tight")
    print(f"Line chart saved → {save_path}")
    plt.show()



if __name__ == "__main__":
    print("Loading data...\n")
    df = build_data()

    print("\nLoaded table (mean accuracies):")
    pivot = df.pivot_table(
        index=["Dataset", "Severity"],
        columns="Corruption (%)",
        values="Accuracy (%)",
    ).round(2)
    print(pivot.to_string())
    print()

    missing = df["Accuracy (%)"].isna().sum()
    if missing:
        print(f"WARNING: {missing} missing values — check folder paths above.\n")

    plot_bar_chart(df, save_path="noise_bar_chart.png")
    plot_line_chart(df, save_path="noise_line_chart.png")
# Out:
# Loading data...
#
#
# Loaded table (mean accuracies):
# Corruption (%)        10     20     30     40      50
# Dataset  Severity
# CZU-MHAD 0.2σ      93.89  94.07  92.90  91.71   92.26
#          0.5σ      89.45  89.00  87.49  87.42   86.92
#          1.0σ      88.31  85.61  83.65  82.36   80.99
# MM-Fit   0.2σ      99.34  98.71  98.71  99.67  100.00
#          0.5σ      99.04  99.71  99.00  98.71   99.37
#          1.0σ      99.71  99.71  99.04  98.71   99.37
# UTD-MHAD 0.2σ      96.17  95.94  95.60  95.13   95.94
#          0.5σ      93.03  92.68  92.22  90.94   91.29
#          1.0σ      93.39  92.46  91.88  90.71   88.85
#
# Bar chart saved → noise_bar_chart.png
# Line chart saved → noise_line_chart.png

# %%
plt.rcParams.update({
    "font.family":      "serif",
    "axes.spines.top":  False,
    "axes.spines.right":False,
    "axes.grid":        True,
    "grid.alpha":       0.3,
    "grid.linestyle":   "--",
    "axes.labelsize":   13,
    "xtick.labelsize":  12,
    "ytick.labelsize":  12,
    "legend.fontsize":  12,
    "figure.dpi":       300,
})

def plot_line_chart(df: pd.DataFrame, save_path: str = "noise_line_chart.pdf"):
    fig, axes = plt.subplots(1, 3, figsize=(16, 5.5), sharey=False)
    fig.suptitle("Combined Metaheuristic — Accuracy under Gaussian Noise",
                 fontsize=14, fontweight="bold", y=1.01)

    for ax, dataset in zip(axes, DATASET_ORDER):
        sub = df[df["Dataset"] == dataset]

        rate_vals = {}
        for sev in SEVERITY_ORDER:
            for idx, rate in enumerate(CORRUPTION_RATES):
                row = sub[(sub["Severity"] == sev) & (sub["Corruption (%)"] == rate)]
                v = row["Accuracy (%)"].values[0] if not row.empty else np.nan
                rate_vals.setdefault(rate, {})[sev] = v

        for sev in SEVERITY_ORDER:
            vals = []
            for rate in CORRUPTION_RATES:
                row = sub[(sub["Severity"] == sev) & (sub["Corruption (%)"] == rate)]
                vals.append(row["Accuracy (%)"].values[0] if not row.empty else np.nan)

            ax.plot(
                CORRUPTION_RATES, vals,
                color=SEVERITY_COLORS[sev],
                marker=SEVERITY_MARKERS[sev],
                linewidth=2,
                markersize=7,
                label=f"Noise {sev}",
            )

            for idx, rate in enumerate(CORRUPTION_RATES):
                if rate in (10, 50) and not np.isnan(vals[idx]):
                    # lowest value at this rate goes below, others above
                    min_sev = min(rate_vals[rate], key=lambda s: rate_vals[rate][s])
                    below = (sev == min_sev)
                    ax.annotate(
                        f"{vals[idx]:.1f}%",
                        xy=(rate, vals[idx]),
                        xytext=(0, -11 if below else 9), textcoords="offset points",
                        fontsize=12, color=SEVERITY_COLORS[sev],
                        ha="center", va="top" if below else "bottom",
                    )

        ax.set_title(dataset, fontsize=12, fontweight="bold", pad=14)
        ax.set_xticks(CORRUPTION_RATES)
        ax.set_xticklabels([f"{r}%" for r in CORRUPTION_RATES])
        ax.set_xlabel("Corruption rate")
        ax.set_ylabel("Mean LOSO accuracy (%)")
        ax.set_xlim(5, 53)

        valid = df[df["Dataset"] == dataset]["Accuracy (%)"].dropna()
        if len(valid):
            lo, hi = valid.min(), valid.max()
            ax.set_ylim(max(0, lo - 3), min(100, hi + 7))  # extra headroom for labels

    handles = [
        plt.Line2D([0], [0],
                   color=SEVERITY_COLORS[s],
                   marker=SEVERITY_MARKERS[s],
                   linewidth=2, markersize=7,
                   label=f"Noise strength {s}")
        for s in SEVERITY_ORDER
    ]
    fig.legend(handles=handles, loc="lower center", ncol=3,
               bbox_to_anchor=(0.5, -0.07), frameon=False)

    fig.tight_layout()
    fig.savefig(save_path, bbox_inches="tight")
    print(f"Line chart saved → {save_path}")
    plt.show()


plot_line_chart(df, save_path="noise_line_chart.png")
# Out:
# Line chart saved → noise_line_chart.png
