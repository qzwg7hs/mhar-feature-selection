# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_no_skeleton")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   depth: 37
#   sensor: 9
#   TOTAL: 46

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, ")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 32.17%, F1: 26.04%, Features: 46/46 (100.0%), Model: 0.063MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 23/46 (50.0%), Time: 0.2s
#     Test Acc: 47.55%, F1: 46.10%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 23/46 (50.0%), Time: 0.1s
#     Test Acc: 41.61%, F1: 38.04%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 23/46 (50.0%), Time: 0.0s
#     Test Acc: 18.88%, F1: 14.17%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.5504844720496894']
# ['At iteration 1 the best fitness is 0.5504844720496894']
# ['At iteration 2 the best fitness is 0.5341987577639751']
# ['At iteration 3 the best fitness is 0.5341987577639751']
# ['At iteration 4 the best fitness is 0.5341987577639751']
# ['At iteration 5 the best fitness is 0.5341987577639751']
# ['At iteration 6 the best fitness is 0.5341987577639751']
# ['At iteration 7 the best fitness is 0.5341987577639751']
# ['At iteration 8 the best fitness is 0.5341987577639751']
# ['At iteration 9 the best fitness is 0.5341987577639751']
# ['At iteration 10 the best fitness is 0.5341987577639751']
# ['At iteration 11 the best fitness is 0.4799130434782608']
# ['At iteration 12 the best fitness is 0.4799130434782608']
# ['At iteration 13 the best fitness is 0.4799130434782608']
# ['At iteration 14 the best fitness is 0.4799130434782608']
# ['At iteration 15 the best fitness is 0.4799130434782608']
# ['At iteration 16 the best fitness is 0.47774534161490684']
# ['At iteration 17 the best fitness is 0.47774534161490684']
# ['At iteration 18 the best fitness is 0.47774534161490684']
# ['At iteration 19 the best fitness is 0.47774534161490684']
# ['At iteration 20 the best fitness is 0.47774534161490684']
# ['At iteration 21 the best fitness is 0.47774534161490684']
# ['At iteration 22 the best fitness is 0.47774534161490684']
# ['At iteration 23 the best fitness is 0.47774534161490684']
# ['At iteration 24 the best fitness is 0.47774534161490684']
# ['At iteration 25 the best fitness is 0.47774534161490684']
# ['At iteration 26 the best fitness is 0.47774534161490684']
# ['At iteration 27 the best fitness is 0.47774534161490684']
# ['At iteration 28 the best fitness is 0.47774534161490684']
# ['At iteration 29 the best fitness is 0.47774534161490684']
#       Selected: 26/46 (56.5%), Fitness: 0.4777, Time: 639.4s
#       Modality: D=51%, S=78%,
#     Test Acc: 33.92%, F1: 28.80%, Features: 26/46 (56.5%), Model: 0.053MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.5124844720496894']
# ['At iteration 10 the best fitness is 0.4907701863354037']
# ['At iteration 20 the best fitness is 0.4614658385093167']
#       Selected: 29/46 (63.0%), Fitness: 0.4615, Time: 1256.0s
#       Modality: D=70%, S=33%,
#     Test Acc: 39.86%, F1: 34.90%, Features: 29/46 (63.0%), Model: 0.055MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.5266024844720496']
# ['At iteration 2 the best fitness is 0.5266024844720496']
# ['At iteration 3 the best fitness is 0.5038074534161491']
# ['At iteration 4 the best fitness is 0.4701428571428571']
# ['At iteration 5 the best fitness is 0.4701428571428571']
# ['At iteration 6 the best fitness is 0.4701428571428571']
# ['At iteration 7 the best fitness is 0.4701428571428571']
# ['At iteration 8 the best fitness is 0.45929192546583847']
# ['At iteration 9 the best fitness is 0.45929192546583847']
# ['At iteration 10 the best fitness is 0.45929192546583847']
# ['At iteration 11 the best fitness is 0.45929192546583847']
# ['At iteration 12 the best fitness is 0.45929192546583847']
# ['At iteration 13 the best fitness is 0.45929192546583847']
# ['At iteration 14 the best fitness is 0.45929192546583847']
# ['At iteration 15 the best fitness is 0.44734782608695645']
# ['At iteration 16 the best fitness is 0.44734782608695645']
# ['At iteration 17 the best fitness is 0.44734782608695645']
# ['At iteration 18 the best fitness is 0.44734782608695645']
# ['At iteration 19 the best fitness is 0.44734782608695645']
# ['At iteration 20 the best fitness is 0.44734782608695645']
# ['At iteration 21 the best fitness is 0.44734782608695645']
# ['At iteration 22 the best fitness is 0.44734782608695645']
# ['At iteration 23 the best fitness is 0.44734782608695645']
# ['At iteration 24 the best fitness is 0.44734782608695645']
# ['At iteration 25 the best fitness is 0.44734782608695645']
# ['At iteration 26 the best fitness is 0.44734782608695645']
# ['At iteration 27 the best fitness is 0.44734782608695645']
# ['At iteration 28 the best fitness is 0.44734782608695645']
# ['At iteration 29 the best fitness is 0.44734782608695645']
# ['At iteration 30 the best fitness is 0.44734782608695645']
#       Selected: 32/46 (69.6%), Fitness: 0.4473, Time: 637.9s
#       Modality: D=68%, S=78%,
#     Test Acc: 34.97%, F1: 29.45%, Features: 32/46 (69.6%), Model: 0.056MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.5103167701863354']
# ['At iteration 1 the best fitness is 0.5124968944099378']
# ['At iteration 2 the best fitness is 0.48535403726708076']
# ['At iteration 3 the best fitness is 0.47015527950310565']
# ['At iteration 4 the best fitness is 0.45929813664596275']
# ['At iteration 5 the best fitness is 0.4983788819875776']
# ['At iteration 6 the best fitness is 0.47775155279503095']
# ['At iteration 7 the best fitness is 0.48860869565217385']
# ['At iteration 8 the best fitness is 0.48752173913043473']
# ['At iteration 9 the best fitness is 0.4668944099378882']
# ['At iteration 10 the best fitness is 0.4668944099378882']
# ['At iteration 11 the best fitness is 0.48318012422360246']
# ['At iteration 12 the best fitness is 0.47775155279503095']
# ['At iteration 13 the best fitness is 0.48860869565217385']
# ['At iteration 14 the best fitness is 0.4668944099378882']
# ['At iteration 15 the best fitness is 0.48318012422360246']
# ['At iteration 16 the best fitness is 0.4614658385093167']
# ['At iteration 17 the best fitness is 0.47232298136645956']
# ['At iteration 18 the best fitness is 0.47775155279503095']
# ['At iteration 19 the best fitness is 0.4668944099378882']
# ['At iteration 20 the best fitness is 0.47775155279503095']
# ['At iteration 21 the best fitness is 0.4560372670807453']
# ['At iteration 22 the best fitness is 0.47775155279503095']
# ['At iteration 23 the best fitness is 0.49946583850931675']
# ['At iteration 24 the best fitness is 0.49403726708074536']
# ['At iteration 25 the best fitness is 0.49403726708074536']
# ['At iteration 26 the best fitness is 0.48860869565217385']
# ['At iteration 27 the best fitness is 0.47232298136645956']
# ['At iteration 28 the best fitness is 0.48318012422360246']
# ['At iteration 29 the best fitness is 0.47775155279503095']
#       Selected: 29/46 (63.0%), Fitness: 0.4778, Time: 617.3s
#       Modality: D=59%, S=78%,
#     Test Acc: 39.51%, F1: 31.84%, Features: 29/46 (63.0%), Model: 0.055MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.5874037267080744
# At iteration 2 the best fitness is 0.5656894409937887
# At iteration 3 the best fitness is 0.5135776397515528
# At iteration 4 the best fitness is 0.519
# At iteration 5 the best fitness is 0.5135714285714285
# At iteration 6 the best fitness is 0.4864285714285715
# At iteration 7 the best fitness is 0.4918571428571429
# At iteration 8 the best fitness is 0.4972919254658385
# At iteration 9 the best fitness is 0.49403105590062113
# At iteration 10 the best fitness is 0.4810062111801242
# At iteration 11 the best fitness is 0.492944099378882
# At iteration 12 the best fitness is 0.48860248447204974
# At iteration 13 the best fitness is 0.47123602484472044
# At iteration 14 the best fitness is 0.48209316770186333
# At iteration 15 the best fitness is 0.46797515527950306
# At iteration 16 the best fitness is 0.47340372670807446
# At iteration 17 the best fitness is 0.4440931677018633
# At iteration 18 the best fitness is 0.4690621118012422
# At iteration 19 the best fitness is 0.4386645962732919
# At iteration 20 the best fitness is 0.4810062111801242
# At iteration 21 the best fitness is 0.4810062111801242
# At iteration 22 the best fitness is 0.47232298136645956
# At iteration 23 the best fitness is 0.45929192546583847
# At iteration 24 the best fitness is 0.4549503105590062
# At iteration 25 the best fitness is 0.47123602484472044
# At iteration 26 the best fitness is 0.45929192546583847
# At iteration 27 the best fitness is 0.47123602484472044
# At iteration 28 the best fitness is 0.4864347826086956
# At iteration 29 the best fitness is 0.4810062111801242
# At iteration 30 the best fitness is 0.4614596273291926
#       Selected: 26/46 (56.5%), Fitness: 0.4615, Time: 619.0s
#       Modality: D=54%, S=67%,
#     Test Acc: 31.47%, F1: 25.25%, Features: 26/46 (56.5%), Model: 0.053MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.5407204968944099']
# ['At iteration 1 the best fitness is 0.5222608695652173']
# ['At iteration 2 the best fitness is 0.5113975155279502']
# ['At iteration 3 the best fitness is 0.5113975155279502']
# ['At iteration 4 the best fitness is 0.4701428571428571']
# ['At iteration 5 the best fitness is 0.4701428571428571']
# ['At iteration 6 the best fitness is 0.4701428571428571']
# ['At iteration 7 the best fitness is 0.4701428571428571']
# ['At iteration 8 the best fitness is 0.4701428571428571']
# ['At iteration 9 the best fitness is 0.4549378881987578']
# ['At iteration 10 the best fitness is 0.4549378881987578']
# ['At iteration 11 the best fitness is 0.4549378881987578']
# ['At iteration 12 the best fitness is 0.4549378881987578']
# ['At iteration 13 the best fitness is 0.4549378881987578']
# ['At iteration 14 the best fitness is 0.4549378881987578']
# ['At iteration 15 the best fitness is 0.4549378881987578']
# ['At iteration 16 the best fitness is 0.4549378881987578']
# ['At iteration 17 the best fitness is 0.4549378881987578']
# ['At iteration 18 the best fitness is 0.43539751552795025']
# ['At iteration 19 the best fitness is 0.43539751552795025']
# ['At iteration 20 the best fitness is 0.43539751552795025']
# ['At iteration 21 the best fitness is 0.43539751552795025']
# ['At iteration 22 the best fitness is 0.43539751552795025']
# ['At iteration 23 the best fitness is 0.43539751552795025']
# ['At iteration 24 the best fitness is 0.43539751552795025']
# ['At iteration 25 the best fitness is 0.43539751552795025']
# ['At iteration 26 the best fitness is 0.43539751552795025']
# ['At iteration 27 the best fitness is 0.43539751552795025']
# ['At iteration 28 the best fitness is 0.43539751552795025']
# ['At iteration 29 the best fitness is 0.43539751552795025']
#       Selected: 16/46 (34.8%), Fitness: 0.4354, Time: 599.5s
#       Modality: D=38%, S=22%,
#     Test Acc: 32.17%, F1: 26.80%, Features: 16/46 (34.8%), Model: 0.048MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.5287701863354036']
# ['At iteration 1 the best fitness is 0.5016211180124223']
# ['At iteration 2 the best fitness is 0.5016211180124223']
# ['At iteration 3 the best fitness is 0.5016211180124223']
# ['At iteration 4 the best fitness is 0.5016211180124223']
# ['At iteration 5 the best fitness is 0.4864223602484472']
# ['At iteration 6 the best fitness is 0.4864223602484472']
# ['At iteration 7 the best fitness is 0.47883229813664596']
# ['At iteration 8 the best fitness is 0.47883229813664596']
# ['At iteration 9 the best fitness is 0.47883229813664596']
# ['At iteration 10 the best fitness is 0.4766708074534161']
# ['At iteration 11 the best fitness is 0.4766708074534161']
# ['At iteration 12 the best fitness is 0.4766708074534161']
# ['At iteration 13 the best fitness is 0.4766708074534161']
# ['At iteration 14 the best fitness is 0.4766708074534161']
# ['At iteration 15 the best fitness is 0.4712422360248448']
# ['At iteration 16 the best fitness is 0.4712422360248448']
# ['At iteration 17 the best fitness is 0.4712422360248448']
# ['At iteration 18 the best fitness is 0.4712422360248448']
# ['At iteration 19 the best fitness is 0.4712422360248448']
# ['At iteration 20 the best fitness is 0.4712422360248448']
# ['At iteration 21 the best fitness is 0.4712422360248448']
# ['At iteration 22 the best fitness is 0.4712422360248448']
# ['At iteration 23 the best fitness is 0.4712422360248448']
# ['At iteration 24 the best fitness is 0.4712422360248448']
# ['At iteration 25 the best fitness is 0.4712422360248448']
# ['At iteration 26 the best fitness is 0.4712422360248448']
# ['At iteration 27 the best fitness is 0.4712422360248448']
# ['At iteration 28 the best fitness is 0.4712422360248448']
# ['At iteration 29 the best fitness is 0.4712422360248448']
#       Selected: 35/46 (76.1%), Fitness: 0.4712, Time: 710.1s
#       Modality: D=73%, S=89%,
#     Test Acc: 32.17%, F1: 26.57%, Features: 35/46 (76.1%), Model: 0.057MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.5070621118012423']
# ['At iteration 1 the best fitness is 0.47883229813664596']
# ['At iteration 2 the best fitness is 0.47883229813664596']
# ['At iteration 3 the best fitness is 0.44734782608695645']
# ['At iteration 4 the best fitness is 0.44734782608695645']
# ['At iteration 5 the best fitness is 0.44734782608695645']
# ['At iteration 6 the best fitness is 0.44734782608695645']
# ['At iteration 7 the best fitness is 0.44734782608695645']
# ['At iteration 8 the best fitness is 0.44734782608695645']
# ['At iteration 9 the best fitness is 0.44734782608695645']
# ['At iteration 10 the best fitness is 0.44734782608695645']
# ['At iteration 11 the best fitness is 0.44734782608695645']
# ['At iteration 12 the best fitness is 0.44734782608695645']
# ['At iteration 13 the best fitness is 0.44734782608695645']
# ['At iteration 14 the best fitness is 0.44734782608695645']
# ['At iteration 15 the best fitness is 0.44734782608695645']
# ['At iteration 16 the best fitness is 0.44734782608695645']
# ['At iteration 17 the best fitness is 0.44734782608695645']
# ['At iteration 18 the best fitness is 0.44734782608695645']
# ['At iteration 19 the best fitness is 0.44734782608695645']
# ['At iteration 20 the best fitness is 0.44734782608695645']
# ['At iteration 21 the best fitness is 0.44734782608695645']
# ['At iteration 22 the best fitness is 0.44734782608695645']
# ['At iteration 23 the best fitness is 0.44734782608695645']
# ['At iteration 24 the best fitness is 0.44734782608695645']
# ['At iteration 25 the best fitness is 0.44734782608695645']
# ['At iteration 26 the best fitness is 0.44734782608695645']
# ['At iteration 27 the best fitness is 0.44734782608695645']
# ['At iteration 28 the best fitness is 0.44734782608695645']
# ['At iteration 29 the best fitness is 0.44734782608695645']
#       Selected: 33/46 (71.7%), Fitness: 0.4473, Time: 635.3s
#       Modality: D=70%, S=78%,
#     Test Acc: 40.91%, F1: 35.32%, Features: 33/46 (71.7%), Model: 0.056MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.5059813664596273']
# ['At iteration 2 the best fitness is 0.5059813664596273']
# ['At iteration 3 the best fitness is 0.5059813664596273']
# ['At iteration 4 the best fitness is 0.47775155279503095']
# ['At iteration 5 the best fitness is 0.47775155279503095']
# ['At iteration 6 the best fitness is 0.47775155279503095']
# ['At iteration 7 the best fitness is 0.47449689440993786']
# ['At iteration 8 the best fitness is 0.47449689440993786']
# ['At iteration 9 the best fitness is 0.47449689440993786']
# ['At iteration 10 the best fitness is 0.47449689440993786']
# ['At iteration 11 the best fitness is 0.44735403726708073']
# ['At iteration 12 the best fitness is 0.44735403726708073']
# ['At iteration 13 the best fitness is 0.43649689440993783']
# ['At iteration 14 the best fitness is 0.43649689440993783']
# ['At iteration 15 the best fitness is 0.43649689440993783']
# ['At iteration 16 the best fitness is 0.43649689440993783']
# ['At iteration 17 the best fitness is 0.43649689440993783']
# ['At iteration 18 the best fitness is 0.43649689440993783']
# ['At iteration 19 the best fitness is 0.43649689440993783']
# ['At iteration 20 the best fitness is 0.43649689440993783']
# ['At iteration 21 the best fitness is 0.43649689440993783']
# ['At iteration 22 the best fitness is 0.43649689440993783']
# ['At iteration 23 the best fitness is 0.4354099378881987']
# ['At iteration 24 the best fitness is 0.4354099378881987']
# ['At iteration 25 the best fitness is 0.4354099378881987']
# ['At iteration 26 the best fitness is 0.4354099378881987']
# ['At iteration 27 the best fitness is 0.4354099378881987']
# ['At iteration 28 the best fitness is 0.4354099378881987']
# ['At iteration 29 the best fitness is 0.4354099378881987']
#       Selected: 28/46 (60.9%), Fitness: 0.4354, Time: 597.0s
#       Modality: D=59%, S=67%,
#     Test Acc: 31.12%, F1: 27.81%, Features: 28/46 (60.9%), Model: 0.054MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.5526583850931677']
# ['At iteration 2 the best fitness is 0.5526583850931677']
# ['At iteration 3 the best fitness is 0.5331180124223601']
# ['At iteration 4 the best fitness is 0.4907701863354037']
# ['At iteration 5 the best fitness is 0.47448447204968947']
# ['At iteration 6 the best fitness is 0.4701428571428571']
# ['At iteration 7 the best fitness is 0.46688819875776394']
# ['At iteration 8 the best fitness is 0.46688819875776394']
# ['At iteration 9 the best fitness is 0.46688819875776394']
# ['At iteration 10 the best fitness is 0.46688819875776394']
# ['At iteration 11 the best fitness is 0.46688819875776394']
# ['At iteration 12 the best fitness is 0.46688819875776394']
# ['At iteration 13 the best fitness is 0.46688819875776394']
# ['At iteration 14 the best fitness is 0.46362732919254657']
# ['At iteration 15 the best fitness is 0.4603726708074535']
# ['At iteration 16 the best fitness is 0.4603726708074535']
# ['At iteration 17 the best fitness is 0.4603726708074535']
# ['At iteration 18 the best fitness is 0.4603726708074535']
# ['At iteration 19 the best fitness is 0.44299999999999995']
# ['At iteration 20 the best fitness is 0.44299999999999995']
# ['At iteration 21 the best fitness is 0.44299999999999995']
# ['At iteration 22 the best fitness is 0.44299999999999995']
# ['At iteration 23 the best fitness is 0.44299999999999995']
# ['At iteration 24 the best fitness is 0.44299999999999995']
# ['At iteration 25 the best fitness is 0.44299999999999995']
# ['At iteration 26 the best fitness is 0.44299999999999995']
# ['At iteration 27 the best fitness is 0.44299999999999995']
# ['At iteration 28 the best fitness is 0.44299999999999995']
# ['At iteration 29 the best fitness is 0.44299999999999995']
# ['At iteration 30 the best fitness is 0.44299999999999995']
#       Selected: 23/46 (50.0%), Fitness: 0.4430, Time: 616.4s
#       Modality: D=46%, S=67%,
#     Test Acc: 33.92%, F1: 29.37%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.5787142857142857']
# ['At iteration 2 the best fitness is 0.5081366459627329']
# ['At iteration 3 the best fitness is 0.4918571428571429']
# ['At iteration 4 the best fitness is 0.47231677018633533']
# ['At iteration 5 the best fitness is 0.47231677018633533']
# ['At iteration 6 the best fitness is 0.47231677018633533']
# ['At iteration 7 the best fitness is 0.47231677018633533']
# ['At iteration 8 the best fitness is 0.47231677018633533']
# ['At iteration 9 the best fitness is 0.4712298136645962']
# ['At iteration 10 the best fitness is 0.4712298136645962']
# ['At iteration 11 the best fitness is 0.4712298136645962']
# ['At iteration 12 the best fitness is 0.4712298136645962']
# ['At iteration 13 the best fitness is 0.4712298136645962']
# ['At iteration 14 the best fitness is 0.4712298136645962']
# ['At iteration 15 the best fitness is 0.44734161490683233']
# ['At iteration 16 the best fitness is 0.44734161490683233']
# ['At iteration 17 the best fitness is 0.44734161490683233']
# ['At iteration 18 the best fitness is 0.44734161490683233']
# ['At iteration 19 the best fitness is 0.44734161490683233']
# ['At iteration 20 the best fitness is 0.44734161490683233']
# ['At iteration 21 the best fitness is 0.44734161490683233']
# ['At iteration 22 the best fitness is 0.44734161490683233']
# ['At iteration 23 the best fitness is 0.44734161490683233']
# ['At iteration 24 the best fitness is 0.44734161490683233']
# ['At iteration 25 the best fitness is 0.44734161490683233']
# ['At iteration 26 the best fitness is 0.44734161490683233']
# ['At iteration 27 the best fitness is 0.44734161490683233']
# ['At iteration 28 the best fitness is 0.44734161490683233']
# ['At iteration 29 the best fitness is 0.44734161490683233']
# ['At iteration 30 the best fitness is 0.44734161490683233']
#       Selected: 23/46 (50.0%), Fitness: 0.4473, Time: 614.8s
#       Modality: D=43%, S=78%,
#     Test Acc: 42.31%, F1: 37.34%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.490776397515528']
# ['At iteration 1 the best fitness is 0.490776397515528']
# ['At iteration 2 the best fitness is 0.490776397515528']
# ['At iteration 3 the best fitness is 0.490776397515528']
# ['At iteration 4 the best fitness is 0.490776397515528']
# ['At iteration 5 the best fitness is 0.490776397515528']
# ['At iteration 6 the best fitness is 0.490776397515528']
# ['At iteration 7 the best fitness is 0.4766583850931677']
# ['At iteration 8 the best fitness is 0.4766583850931677']
# ['At iteration 9 the best fitness is 0.4690496894409938']
# ['At iteration 10 the best fitness is 0.4690496894409938']
# ['At iteration 11 the best fitness is 0.4690496894409938']
# ['At iteration 12 the best fitness is 0.4690496894409938']
# ['At iteration 13 the best fitness is 0.4690496894409938']
# ['At iteration 14 the best fitness is 0.4690496894409938']
# ['At iteration 15 the best fitness is 0.4690496894409938']
# ['At iteration 16 the best fitness is 0.4690496894409938']
# ['At iteration 17 the best fitness is 0.4690496894409938']
# ['At iteration 18 the best fitness is 0.4690496894409938']
# ['At iteration 19 the best fitness is 0.4690496894409938']
# ['At iteration 20 the best fitness is 0.4690496894409938']
# ['At iteration 21 the best fitness is 0.4690496894409938']
# ['At iteration 22 the best fitness is 0.4690496894409938']
# ['At iteration 23 the best fitness is 0.4690496894409938']
# ['At iteration 24 the best fitness is 0.4690496894409938']
# ['At iteration 25 the best fitness is 0.4690496894409938']
# ['At iteration 26 the best fitness is 0.4690496894409938']
# ['At iteration 27 the best fitness is 0.4690496894409938']
# ['At iteration 28 the best fitness is 0.4690496894409938']
# ['At iteration 29 the best fitness is 0.4690496894409938']
#       Selected: 17/46 (37.0%), Fitness: 0.4690, Time: 592.3s
#       Modality: D=30%, S=67%,
#     Test Acc: 38.46%, F1: 33.67%, Features: 17/46 (37.0%), Model: 0.049MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.4701490683229813']
# ['At iteration 2 the best fitness is 0.4701490683229813']
# ['At iteration 3 the best fitness is 0.4701490683229813']
# ['At iteration 4 the best fitness is 0.4701490683229813']
# ['At iteration 5 the best fitness is 0.4701490683229813']
# ['At iteration 6 the best fitness is 0.45928571428571435']
# ['At iteration 7 the best fitness is 0.45928571428571435']
# ['At iteration 8 the best fitness is 0.45928571428571435']
# ['At iteration 9 the best fitness is 0.45928571428571435']
# ['At iteration 10 the best fitness is 0.45928571428571435']
# ['At iteration 11 the best fitness is 0.45928571428571435']
# ['At iteration 12 the best fitness is 0.45385714285714285']
# ['At iteration 13 the best fitness is 0.45385714285714285']
# ['At iteration 14 the best fitness is 0.45385714285714285']
# ['At iteration 15 the best fitness is 0.45385714285714285']
# ['At iteration 16 the best fitness is 0.4440869565217391']
# ['At iteration 17 the best fitness is 0.4440869565217391']
# ['At iteration 18 the best fitness is 0.4440869565217391']
# ['At iteration 19 the best fitness is 0.4440869565217391']
# ['At iteration 20 the best fitness is 0.4332298136645963']
# ['At iteration 21 the best fitness is 0.4332298136645963']
# ['At iteration 22 the best fitness is 0.4332298136645963']
# ['At iteration 23 the best fitness is 0.4332298136645963']
# ['At iteration 24 the best fitness is 0.4332298136645963']
# ['At iteration 25 the best fitness is 0.4332298136645963']
# ['At iteration 26 the best fitness is 0.4332298136645963']
# ['At iteration 27 the best fitness is 0.4332298136645963']
# ['At iteration 28 the best fitness is 0.4332298136645963']
# ['At iteration 29 the best fitness is 0.4332298136645963']
#       Selected: 20/46 (43.5%), Fitness: 0.4332, Time: 1540.1s
#       Modality: D=41%, S=56%,
#     Test Acc: 29.72%, F1: 23.29%, Features: 20/46 (43.5%), Model: 0.050MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.545055900621118']
# ['At iteration 1 the best fitness is 0.48318633540372663']
# ['At iteration 2 the best fitness is 0.48318633540372663']
# ['At iteration 3 the best fitness is 0.47668322981366457']
# ['At iteration 4 the best fitness is 0.47668322981366457']
# ['At iteration 5 the best fitness is 0.4712546583850932']
# ['At iteration 6 the best fitness is 0.4712546583850932']
# ['At iteration 7 the best fitness is 0.4712546583850932']
# ['At iteration 8 the best fitness is 0.4712546583850932']
# ['At iteration 9 the best fitness is 0.4712546583850932']
# ['At iteration 10 the best fitness is 0.4712546583850932']
# ['At iteration 11 the best fitness is 0.4712546583850932']
# ['At iteration 12 the best fitness is 0.4712546583850932']
# ['At iteration 13 the best fitness is 0.4712546583850932']
# ['At iteration 14 the best fitness is 0.4712546583850932']
# ['At iteration 15 the best fitness is 0.4712546583850932']
# ['At iteration 16 the best fitness is 0.4712546583850932']
# ['At iteration 17 the best fitness is 0.4712546583850932']
# ['At iteration 18 the best fitness is 0.4712546583850932']
# ['At iteration 19 the best fitness is 0.4712546583850932']
# ['At iteration 20 the best fitness is 0.4712546583850932']
# ['At iteration 21 the best fitness is 0.4712546583850932']
# ['At iteration 22 the best fitness is 0.4712546583850932']
# ['At iteration 23 the best fitness is 0.4712546583850932']
# ['At iteration 24 the best fitness is 0.4712546583850932']
# ['At iteration 25 the best fitness is 0.4712546583850932']
# ['At iteration 26 the best fitness is 0.4712546583850932']
# ['At iteration 27 the best fitness is 0.4712546583850932']
# ['At iteration 28 the best fitness is 0.4712546583850932']
# ['At iteration 29 the best fitness is 0.4712546583850932']
#       Selected: 43/46 (93.5%), Fitness: 0.4713, Time: 575.1s
#       Modality: D=92%, S=100%,
#     Test Acc: 32.87%, F1: 26.68%, Features: 43/46 (93.5%), Model: 0.061MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 33.61%, F1: 27.45%, Features: 46/46 (100.0%), Model: 0.063MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 23/46 (50.0%), Time: 0.2s
#     Test Acc: 40.25%, F1: 35.03%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 23/46 (50.0%), Time: 0.1s
#     Test Acc: 34.85%, F1: 30.21%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 23/46 (50.0%), Time: 0.0s
#     Test Acc: 31.12%, F1: 27.90%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.4475543478260869']
# ['At iteration 1 the best fitness is 0.38858695652173914']
# ['At iteration 2 the best fitness is 0.38858695652173914']
# ['At iteration 3 the best fitness is 0.38858695652173914']
# ['At iteration 4 the best fitness is 0.38858695652173914']
# ['At iteration 5 the best fitness is 0.38858695652173914']
# ['At iteration 6 the best fitness is 0.38858695652173914']
# ['At iteration 7 the best fitness is 0.38858695652173914']
# ['At iteration 8 the best fitness is 0.38858695652173914']
# ['At iteration 9 the best fitness is 0.38858695652173914']
# ['At iteration 10 the best fitness is 0.38858695652173914']
# ['At iteration 11 the best fitness is 0.38858695652173914']
# ['At iteration 12 the best fitness is 0.38858695652173914']
# ['At iteration 13 the best fitness is 0.38858695652173914']
# ['At iteration 14 the best fitness is 0.38858695652173914']
# ['At iteration 15 the best fitness is 0.38858695652173914']
# ['At iteration 16 the best fitness is 0.38858695652173914']
# ['At iteration 17 the best fitness is 0.38858695652173914']
# ['At iteration 18 the best fitness is 0.38858695652173914']
# ['At iteration 19 the best fitness is 0.38858695652173914']
# ['At iteration 20 the best fitness is 0.38858695652173914']
# ['At iteration 21 the best fitness is 0.38858695652173914']
# ['At iteration 22 the best fitness is 0.38858695652173914']
# ['At iteration 23 the best fitness is 0.38858695652173914']
# ['At iteration 24 the best fitness is 0.38858695652173914']
# ['At iteration 25 the best fitness is 0.38858695652173914']
# ['At iteration 26 the best fitness is 0.38858695652173914']
# ['At iteration 27 the best fitness is 0.38858695652173914']
# ['At iteration 28 the best fitness is 0.38858695652173914']
# ['At iteration 29 the best fitness is 0.38858695652173914']
#       Selected: 27/46 (58.7%), Fitness: 0.3886, Time: 684.9s
#       Modality: D=51%, S=89%,
#     Test Acc: 38.17%, F1: 34.86%, Features: 27/46 (58.7%), Model: 0.054MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.46304347826086956']
# ['At iteration 10 the best fitness is 0.4040760869565217']
# ['At iteration 20 the best fitness is 0.4040760869565217']
#       Selected: 29/46 (63.0%), Fitness: 0.3948, Time: 1343.9s
#       Modality: D=65%, S=56%,
#     Test Acc: 26.97%, F1: 19.60%, Features: 29/46 (63.0%), Model: 0.055MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.42717391304347824']
# ['At iteration 2 the best fitness is 0.42717391304347824']
# ['At iteration 3 the best fitness is 0.42717391304347824']
# ['At iteration 4 the best fitness is 0.42717391304347824']
# ['At iteration 5 the best fitness is 0.4135869565217391']
# ['At iteration 6 the best fitness is 0.4135869565217391']
# ['At iteration 7 the best fitness is 0.41114130434782614']
# ['At iteration 8 the best fitness is 0.41114130434782614']
# ['At iteration 9 the best fitness is 0.41114130434782614']
# ['At iteration 10 the best fitness is 0.4040760869565217']
# ['At iteration 11 the best fitness is 0.4040760869565217']
# ['At iteration 12 the best fitness is 0.4040760869565217']
# ['At iteration 13 the best fitness is 0.4040760869565217']
# ['At iteration 14 the best fitness is 0.3978260869565217']
# ['At iteration 15 the best fitness is 0.3978260869565217']
# ['At iteration 16 the best fitness is 0.39646739130434777']
# ['At iteration 17 the best fitness is 0.39646739130434777']
# ['At iteration 18 the best fitness is 0.39646739130434777']
# ['At iteration 19 the best fitness is 0.38858695652173914']
# ['At iteration 20 the best fitness is 0.38858695652173914']
# ['At iteration 21 the best fitness is 0.38858695652173914']
# ['At iteration 22 the best fitness is 0.38858695652173914']
# ['At iteration 23 the best fitness is 0.37798913043478255']
# ['At iteration 24 the best fitness is 0.37798913043478255']
# ['At iteration 25 the best fitness is 0.37798913043478255']
# ['At iteration 26 the best fitness is 0.37798913043478255']
# ['At iteration 27 the best fitness is 0.37798913043478255']
# ['At iteration 28 the best fitness is 0.37798913043478255']
# ['At iteration 29 the best fitness is 0.37798913043478255']
# ['At iteration 30 the best fitness is 0.37798913043478255']
#       Selected: 19/46 (41.3%), Fitness: 0.3780, Time: 682.3s
#       Modality: D=41%, S=44%,
#     Test Acc: 37.76%, F1: 32.74%, Features: 19/46 (41.3%), Model: 0.050MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.4260869565217391']
# ['At iteration 1 the best fitness is 0.44673913043478264']
# ['At iteration 2 the best fitness is 0.4010869565217391']
# ['At iteration 3 the best fitness is 0.4527173913043478']
# ['At iteration 4 the best fitness is 0.4228260869565217']
# ['At iteration 5 the best fitness is 0.3959239130434783']
# ['At iteration 6 the best fitness is 0.42499999999999993']
# ['At iteration 7 the best fitness is 0.41983695652173914']
# ['At iteration 8 the best fitness is 0.4209239130434783']
# ['At iteration 9 the best fitness is 0.38994565217391297']
# ['At iteration 10 the best fitness is 0.39402173913043476']
# ['At iteration 11 the best fitness is 0.4105978260869565']
# ['At iteration 12 the best fitness is 0.42499999999999993']
# ['At iteration 13 the best fitness is 0.40434782608695646']
# ['At iteration 14 the best fitness is 0.4105978260869565']
# ['At iteration 15 the best fitness is 0.37445652173913047']
# ['At iteration 16 the best fitness is 0.3951086956521739']
# ['At iteration 17 the best fitness is 0.4002717391304348']
# ['At iteration 18 the best fitness is 0.40434782608695646']
# ['At iteration 19 the best fitness is 0.4146739130434782']
# ['At iteration 20 the best fitness is 0.40434782608695646']
# ['At iteration 21 the best fitness is 0.4095108695652173']
# ['At iteration 22 the best fitness is 0.40434782608695646']
# ['At iteration 23 the best fitness is 0.39918478260869567']
# ['At iteration 24 the best fitness is 0.4095108695652173']
# ['At iteration 25 the best fitness is 0.42499999999999993']
# ['At iteration 26 the best fitness is 0.38885869565217385']
# ['At iteration 27 the best fitness is 0.4146739130434782']
# ['At iteration 28 the best fitness is 0.36820652173913043']
# ['At iteration 29 the best fitness is 0.39918478260869567']
#       Selected: 29/46 (63.0%), Fitness: 0.3992, Time: 659.9s
#       Modality: D=65%, S=56%,
#     Test Acc: 35.68%, F1: 31.98%, Features: 29/46 (63.0%), Model: 0.055MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.4660326086956522
# At iteration 2 the best fitness is 0.47934782608695653
# At iteration 3 the best fitness is 0.4641304347826087
# At iteration 4 the best fitness is 0.45461956521739133
# At iteration 5 the best fitness is 0.4535326086956522
# At iteration 6 the best fitness is 0.4494565217391304
# At iteration 7 the best fitness is 0.46902173913043477
# At iteration 8 the best fitness is 0.43831521739130436
# At iteration 9 the best fitness is 0.43396739130434786
# At iteration 10 the best fitness is 0.4133152173913044
# At iteration 11 the best fitness is 0.43396739130434786
# At iteration 12 the best fitness is 0.4184782608695652
# At iteration 13 the best fitness is 0.40298913043478257
# At iteration 14 the best fitness is 0.43288043478260874
# At iteration 15 the best fitness is 0.43288043478260874
# At iteration 16 the best fitness is 0.43179347826086956
# At iteration 17 the best fitness is 0.43478260869565216
# At iteration 18 the best fitness is 0.4296195652173913
# At iteration 19 the best fitness is 0.4380434782608696
# At iteration 20 the best fitness is 0.4296195652173913
# At iteration 21 the best fitness is 0.4233695652173913
# At iteration 22 the best fitness is 0.44538043478260864
# At iteration 23 the best fitness is 0.40298913043478257
# At iteration 24 the best fitness is 0.39375000000000004
# At iteration 25 the best fitness is 0.3956521739130434
# At iteration 26 the best fitness is 0.4277173913043478
# At iteration 27 the best fitness is 0.435054347826087
# At iteration 28 the best fitness is 0.40489130434782605
# At iteration 29 the best fitness is 0.41739130434782606
# At iteration 30 the best fitness is 0.4008152173913043
#       Selected: 19/46 (41.3%), Fitness: 0.4008, Time: 661.7s
#       Modality: D=35%, S=67%,
#     Test Acc: 46.89%, F1: 45.38%, Features: 19/46 (41.3%), Model: 0.050MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.44809782608695653']
# ['At iteration 1 the best fitness is 0.44456521739130433']
# ['At iteration 2 the best fitness is 0.4130434782608695']
# ['At iteration 3 the best fitness is 0.4130434782608695']
# ['At iteration 4 the best fitness is 0.41141304347826085']
# ['At iteration 5 the best fitness is 0.41141304347826085']
# ['At iteration 6 the best fitness is 0.4081521739130435']
# ['At iteration 7 the best fitness is 0.40597826086956523']
# ['At iteration 8 the best fitness is 0.40597826086956523']
# ['At iteration 9 the best fitness is 0.39999999999999997']
# ['At iteration 10 the best fitness is 0.38722826086956524']
# ['At iteration 11 the best fitness is 0.38722826086956524']
# ['At iteration 12 the best fitness is 0.38722826086956524']
# ['At iteration 13 the best fitness is 0.38206521739130433']
# ['At iteration 14 the best fitness is 0.38206521739130433']
# ['At iteration 15 the best fitness is 0.38206521739130433']
# ['At iteration 16 the best fitness is 0.38206521739130433']
# ['At iteration 17 the best fitness is 0.38206521739130433']
# ['At iteration 18 the best fitness is 0.38206521739130433']
# ['At iteration 19 the best fitness is 0.3551630434782609']
# ['At iteration 20 the best fitness is 0.3551630434782609']
# ['At iteration 21 the best fitness is 0.3551630434782609']
# ['At iteration 22 the best fitness is 0.3551630434782609']
# ['At iteration 23 the best fitness is 0.3551630434782609']
# ['At iteration 24 the best fitness is 0.3551630434782609']
# ['At iteration 25 the best fitness is 0.3551630434782609']
# ['At iteration 26 the best fitness is 0.3551630434782609']
# ['At iteration 27 the best fitness is 0.3551630434782609']
# ['At iteration 28 the best fitness is 0.3551630434782609']
# ['At iteration 29 the best fitness is 0.3551630434782609']
#       Selected: 22/46 (47.8%), Fitness: 0.3552, Time: 646.5s
#       Modality: D=49%, S=44%,
#     Test Acc: 31.95%, F1: 26.83%, Features: 22/46 (47.8%), Model: 0.051MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.5095108695652174']
# ['At iteration 1 the best fitness is 0.48641304347826086']
# ['At iteration 2 the best fitness is 0.43288043478260874']
# ['At iteration 3 the best fitness is 0.43288043478260874']
# ['At iteration 4 the best fitness is 0.43288043478260874']
# ['At iteration 5 the best fitness is 0.43288043478260874']
# ['At iteration 6 the best fitness is 0.43288043478260874']
# ['At iteration 7 the best fitness is 0.43288043478260874']
# ['At iteration 8 the best fitness is 0.43288043478260874']
# ['At iteration 9 the best fitness is 0.4320652173913043']
# ['At iteration 10 the best fitness is 0.4320652173913043']
# ['At iteration 11 the best fitness is 0.4320652173913043']
# ['At iteration 12 the best fitness is 0.41657608695652176']
# ['At iteration 13 the best fitness is 0.41657608695652176']
# ['At iteration 14 the best fitness is 0.41657608695652176']
# ['At iteration 15 the best fitness is 0.41657608695652176']
# ['At iteration 16 the best fitness is 0.41657608695652176']
# ['At iteration 17 the best fitness is 0.41657608695652176']
# ['At iteration 18 the best fitness is 0.41657608695652176']
# ['At iteration 19 the best fitness is 0.41657608695652176']
# ['At iteration 20 the best fitness is 0.41657608695652176']
# ['At iteration 21 the best fitness is 0.41141304347826085']
# ['At iteration 22 the best fitness is 0.41141304347826085']
# ['At iteration 23 the best fitness is 0.41141304347826085']
# ['At iteration 24 the best fitness is 0.41141304347826085']
# ['At iteration 25 the best fitness is 0.41141304347826085']
# ['At iteration 26 the best fitness is 0.41141304347826085']
# ['At iteration 27 the best fitness is 0.41141304347826085']
# ['At iteration 28 the best fitness is 0.41141304347826085']
# ['At iteration 29 the best fitness is 0.41141304347826085']
#       Selected: 44/46 (95.7%), Fitness: 0.4114, Time: 831.2s
#       Modality: D=95%, S=100%,
#     Test Acc: 29.88%, F1: 24.77%, Features: 44/46 (95.7%), Model: 0.062MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.39999999999999997']
# ['At iteration 1 the best fitness is 0.39999999999999997']
# ['At iteration 2 the best fitness is 0.3978260869565217']
# ['At iteration 3 the best fitness is 0.3978260869565217']
# ['At iteration 4 the best fitness is 0.3978260869565217']
# ['At iteration 5 the best fitness is 0.3978260869565217']
# ['At iteration 6 the best fitness is 0.3915760869565218']
# ['At iteration 7 the best fitness is 0.3915760869565218']
# ['At iteration 8 the best fitness is 0.3915760869565218']
# ['At iteration 9 the best fitness is 0.3915760869565218']
# ['At iteration 10 the best fitness is 0.3915760869565218']
# ['At iteration 11 the best fitness is 0.3801630434782608']
# ['At iteration 12 the best fitness is 0.3801630434782608']
# ['At iteration 13 the best fitness is 0.3801630434782608']
# ['At iteration 14 the best fitness is 0.3801630434782608']
# ['At iteration 15 the best fitness is 0.3801630434782608']
# ['At iteration 16 the best fitness is 0.3801630434782608']
# ['At iteration 17 the best fitness is 0.375']
# ['At iteration 18 the best fitness is 0.375']
# ['At iteration 19 the best fitness is 0.375']
# ['At iteration 20 the best fitness is 0.36793478260869567']
# ['At iteration 21 the best fitness is 0.36793478260869567']
# ['At iteration 22 the best fitness is 0.36793478260869567']
# ['At iteration 23 the best fitness is 0.36793478260869567']
# ['At iteration 24 the best fitness is 0.3616847826086957']
# ['At iteration 25 the best fitness is 0.3616847826086957']
# ['At iteration 26 the best fitness is 0.3616847826086957']
# ['At iteration 27 the best fitness is 0.3616847826086957']
# ['At iteration 28 the best fitness is 0.3616847826086957']
# ['At iteration 29 the best fitness is 0.3616847826086957']
#       Selected: 26/46 (56.5%), Fitness: 0.3617, Time: 677.7s
#       Modality: D=51%, S=78%,
#     Test Acc: 24.48%, F1: 19.27%, Features: 26/46 (56.5%), Model: 0.053MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.4864130434782608']
# ['At iteration 2 the best fitness is 0.45054347826086955']
# ['At iteration 3 the best fitness is 0.45054347826086955']
# ['At iteration 4 the best fitness is 0.42663043478260865']
# ['At iteration 5 the best fitness is 0.42663043478260865']
# ['At iteration 6 the best fitness is 0.40706521739130436']
# ['At iteration 7 the best fitness is 0.40706521739130436']
# ['At iteration 8 the best fitness is 0.3956521739130434']
# ['At iteration 9 the best fitness is 0.3956521739130434']
# ['At iteration 10 the best fitness is 0.3801630434782608']
# ['At iteration 11 the best fitness is 0.3801630434782608']
# ['At iteration 12 the best fitness is 0.3627717391304348']
# ['At iteration 13 the best fitness is 0.3627717391304348']
# ['At iteration 14 the best fitness is 0.3627717391304348']
# ['At iteration 15 the best fitness is 0.3627717391304348']
# ['At iteration 16 the best fitness is 0.3627717391304348']
# ['At iteration 17 the best fitness is 0.3627717391304348']
# ['At iteration 18 the best fitness is 0.3627717391304348']
# ['At iteration 19 the best fitness is 0.3627717391304348']
# ['At iteration 20 the best fitness is 0.3627717391304348']
# ['At iteration 21 the best fitness is 0.3627717391304348']
# ['At iteration 22 the best fitness is 0.3627717391304348']
# ['At iteration 23 the best fitness is 0.3627717391304348']
# ['At iteration 24 the best fitness is 0.3627717391304348']
# ['At iteration 25 the best fitness is 0.3521739130434782']
# ['At iteration 26 the best fitness is 0.3521739130434782']
# ['At iteration 27 the best fitness is 0.3521739130434782']
# ['At iteration 28 the best fitness is 0.3521739130434782']
# ['At iteration 29 the best fitness is 0.3521739130434782']
#       Selected: 20/46 (43.5%), Fitness: 0.3522, Time: 640.5s
#       Modality: D=38%, S=67%,
#     Test Acc: 35.27%, F1: 32.46%, Features: 20/46 (43.5%), Model: 0.050MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.4578804347826087']
# ['At iteration 2 the best fitness is 0.41657608695652176']
# ['At iteration 3 the best fitness is 0.41657608695652176']
# ['At iteration 4 the best fitness is 0.41657608695652176']
# ['At iteration 5 the best fitness is 0.41657608695652176']
# ['At iteration 6 the best fitness is 0.40298913043478257']
# ['At iteration 7 the best fitness is 0.40298913043478257']
# ['At iteration 8 the best fitness is 0.39999999999999997']
# ['At iteration 9 the best fitness is 0.3834239130434782']
# ['At iteration 10 the best fitness is 0.3834239130434782']
# ['At iteration 11 the best fitness is 0.3834239130434782']
# ['At iteration 12 the best fitness is 0.3834239130434782']
# ['At iteration 13 the best fitness is 0.3834239130434782']
# ['At iteration 14 the best fitness is 0.3834239130434782']
# ['At iteration 15 the best fitness is 0.3834239130434782']
# ['At iteration 16 the best fitness is 0.3793478260869565']
# ['At iteration 17 the best fitness is 0.3793478260869565']
# ['At iteration 18 the best fitness is 0.3793478260869565']
# ['At iteration 19 the best fitness is 0.3793478260869565']
# ['At iteration 20 the best fitness is 0.3793478260869565']
# ['At iteration 21 the best fitness is 0.3793478260869565']
# ['At iteration 22 the best fitness is 0.3782608695652174']
# ['At iteration 23 the best fitness is 0.3782608695652174']
# ['At iteration 24 the best fitness is 0.3782608695652174']
# ['At iteration 25 the best fitness is 0.3782608695652174']
# ['At iteration 26 the best fitness is 0.3782608695652174']
# ['At iteration 27 the best fitness is 0.3782608695652174']
# ['At iteration 28 the best fitness is 0.3782608695652174']
# ['At iteration 29 the best fitness is 0.3782608695652174']
# ['At iteration 30 the best fitness is 0.3782608695652174']
# ...
# ['At iteration 9 the best fitness is 0.4591856273935571']
# ['At iteration 10 the best fitness is 0.4591856273935571']
# ['At iteration 11 the best fitness is 0.4591856273935571']
# ['At iteration 12 the best fitness is 0.4591856273935571']
# ['At iteration 13 the best fitness is 0.4591856273935571']
# ['At iteration 14 the best fitness is 0.4591856273935571']
# ['At iteration 15 the best fitness is 0.4493410678080649']
# ['At iteration 16 the best fitness is 0.4493410678080649']
# ['At iteration 17 the best fitness is 0.4493410678080649']
# ['At iteration 18 the best fitness is 0.4493410678080649']
# ['At iteration 19 the best fitness is 0.4493410678080649']
# ['At iteration 20 the best fitness is 0.4493410678080649']
# ['At iteration 21 the best fitness is 0.4493410678080649']
# ['At iteration 22 the best fitness is 0.43623563865735515']
# ['At iteration 23 the best fitness is 0.43623563865735515']
# ['At iteration 24 the best fitness is 0.43623563865735515']
# ['At iteration 25 the best fitness is 0.43623563865735515']
# ['At iteration 26 the best fitness is 0.43623563865735515']
# ['At iteration 27 the best fitness is 0.43623563865735515']
# ['At iteration 28 the best fitness is 0.43623563865735515']
# ['At iteration 29 the best fitness is 0.43623563865735515']
#       Selected: 32/46 (69.6%), Fitness: 0.4362, Time: 902.2s
#       Modality: D=70%, S=67%,
#     Test Acc: 20.20%, F1: 13.05%, Features: 32/46 (69.6%), Model: 0.056MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.5112187429601261']
# ['At iteration 1 the best fitness is 0.4969644063978373']
# ['At iteration 2 the best fitness is 0.47727528722685286']
# ['At iteration 3 the best fitness is 0.45483780130660056']
# ['At iteration 4 the best fitness is 0.45483780130660056']
# ['At iteration 5 the best fitness is 0.44556769542689795']
# ['At iteration 6 the best fitness is 0.44556769542689795']
# ['At iteration 7 the best fitness is 0.44556769542689795']
# ['At iteration 8 the best fitness is 0.44556769542689795']
# ['At iteration 9 the best fitness is 0.44556769542689795']
# ['At iteration 10 the best fitness is 0.44556769542689795']
# ['At iteration 11 the best fitness is 0.44556769542689795']
# ['At iteration 12 the best fitness is 0.44556769542689795']
# ['At iteration 13 the best fitness is 0.44556769542689795']
# ['At iteration 14 the best fitness is 0.44556769542689795']
# ['At iteration 15 the best fitness is 0.44556769542689795']
# ['At iteration 16 the best fitness is 0.44556769542689795']
# ['At iteration 17 the best fitness is 0.44556769542689795']
# ['At iteration 18 the best fitness is 0.44556769542689795']
# ['At iteration 19 the best fitness is 0.44556769542689795']
# ['At iteration 20 the best fitness is 0.4439062851993692']
# ['At iteration 21 the best fitness is 0.4439062851993692']
# ['At iteration 22 the best fitness is 0.43681009236314483']
# ['At iteration 23 the best fitness is 0.43681009236314483']
# ['At iteration 24 the best fitness is 0.43681009236314483']
# ['At iteration 25 the best fitness is 0.43681009236314483']
# ['At iteration 26 the best fitness is 0.43681009236314483']
# ['At iteration 27 the best fitness is 0.43681009236314483']
# ['At iteration 28 the best fitness is 0.4329747690921378']
# ['At iteration 29 the best fitness is 0.4329747690921378']
#       Selected: 22/46 (47.8%), Fitness: 0.4330, Time: 715.8s
#       Modality: D=41%, S=78%,
#     Test Acc: 24.75%, F1: 17.54%, Features: 22/46 (47.8%), Model: 0.051MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.4614214913268754']
# ['At iteration 2 the best fitness is 0.4614214913268754']
# ['At iteration 3 the best fitness is 0.4614214913268754']
# ['At iteration 4 the best fitness is 0.4614214913268754']
# ['At iteration 5 the best fitness is 0.4614214913268754']
# ['At iteration 6 the best fitness is 0.4614214913268754']
# ['At iteration 7 the best fitness is 0.4614214913268754']
# ['At iteration 8 the best fitness is 0.4406454156341518']
# ['At iteration 9 the best fitness is 0.43623563865735515']
# ['At iteration 10 the best fitness is 0.43623563865735515']
# ['At iteration 11 the best fitness is 0.43623563865735515']
# ['At iteration 12 the best fitness is 0.43623563865735515']
# ['At iteration 13 the best fitness is 0.426391079071863']
# ['At iteration 14 the best fitness is 0.426391079071863']
# ['At iteration 15 the best fitness is 0.426391079071863']
# ['At iteration 16 the best fitness is 0.426391079071863']
# ['At iteration 17 the best fitness is 0.426391079071863']
# ['At iteration 18 the best fitness is 0.426391079071863']
# ['At iteration 19 the best fitness is 0.426391079071863']
# ['At iteration 20 the best fitness is 0.426391079071863']
# ['At iteration 21 the best fitness is 0.426391079071863']
# ['At iteration 22 the best fitness is 0.4089378238341969']
# ['At iteration 23 the best fitness is 0.4089378238341969']
# ['At iteration 24 the best fitness is 0.4089378238341969']
# ['At iteration 25 the best fitness is 0.4089378238341969']
# ['At iteration 26 the best fitness is 0.4089378238341969']
# ['At iteration 27 the best fitness is 0.4089378238341969']
# ['At iteration 28 the best fitness is 0.4089378238341969']
# ['At iteration 29 the best fitness is 0.4089378238341969']
#       Selected: 20/46 (43.5%), Fitness: 0.4089, Time: 678.1s
#       Modality: D=43%, S=44%,
#     Test Acc: 21.21%, F1: 15.76%, Features: 20/46 (43.5%), Model: 0.050MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.5024611398963731']
# ['At iteration 2 the best fitness is 0.4866073439963955']
# ['At iteration 3 the best fitness is 0.4811106104978599']
# ['At iteration 4 the best fitness is 0.45758616805586844']
# ['At iteration 5 the best fitness is 0.4357231358414057']
# ['At iteration 6 the best fitness is 0.4346361793196666']
# ['At iteration 7 the best fitness is 0.4346361793196666']
# ['At iteration 8 the best fitness is 0.4346361793196666']
# ['At iteration 9 the best fitness is 0.4346361793196666']
# ['At iteration 10 the best fitness is 0.4258785762559135']
# ['At iteration 11 the best fitness is 0.4160340166704213']
# ['At iteration 12 the best fitness is 0.4160340166704213']
# ['At iteration 13 the best fitness is 0.4160340166704213']
# ['At iteration 14 the best fitness is 0.4160340166704213']
# ['At iteration 15 the best fitness is 0.4160340166704213']
# ['At iteration 16 the best fitness is 0.4160340166704213']
# ['At iteration 17 the best fitness is 0.4160340166704213']
# ['At iteration 18 the best fitness is 0.4160340166704213']
# ['At iteration 19 the best fitness is 0.4160340166704213']
# ['At iteration 20 the best fitness is 0.4160340166704213']
# ['At iteration 21 the best fitness is 0.4160340166704213']
# ['At iteration 22 the best fitness is 0.4160340166704213']
# ['At iteration 23 the best fitness is 0.4160340166704213']
# ['At iteration 24 the best fitness is 0.4160340166704213']
# ['At iteration 25 the best fitness is 0.4160340166704213']
# ['At iteration 26 the best fitness is 0.4160340166704213']
# ['At iteration 27 the best fitness is 0.4160340166704213']
# ['At iteration 28 the best fitness is 0.4160340166704213']
# ['At iteration 29 the best fitness is 0.4160340166704213']
# ['At iteration 30 the best fitness is 0.4160340166704213']
#       Selected: 25/46 (54.3%), Fitness: 0.4160, Time: 703.9s
#       Modality: D=54%, S=56%,
#     Test Acc: 24.24%, F1: 19.93%, Features: 25/46 (54.3%), Model: 0.053MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.5002252759630547']
# ['At iteration 2 the best fitness is 0.48053615679207023']
# ['At iteration 3 the best fitness is 0.4630209506645641']
# ['At iteration 4 the best fitness is 0.4630209506645641']
# ['At iteration 5 the best fitness is 0.4630209506645641']
# ['At iteration 6 the best fitness is 0.458098670871818']
# ['At iteration 7 the best fitness is 0.4400709619283622']
# ['At iteration 8 the best fitness is 0.4400709619283622']
# ['At iteration 9 the best fitness is 0.4253041225501239']
# ['At iteration 10 the best fitness is 0.4253041225501239']
# ['At iteration 11 the best fitness is 0.4203818427573778']
# ['At iteration 12 the best fitness is 0.4203818427573778']
# ['At iteration 13 the best fitness is 0.4203818427573778']
# ['At iteration 14 the best fitness is 0.4203818427573778']
# ['At iteration 15 the best fitness is 0.4203818427573778']
# ['At iteration 16 the best fitness is 0.4203818427573778']
# ['At iteration 17 the best fitness is 0.4203818427573778']
# ['At iteration 18 the best fitness is 0.4203818427573778']
# ['At iteration 19 the best fitness is 0.4203818427573778']
# ['At iteration 20 the best fitness is 0.4203818427573778']
# ['At iteration 21 the best fitness is 0.4203818427573778']
# ['At iteration 22 the best fitness is 0.4203818427573778']
# ['At iteration 23 the best fitness is 0.4203818427573778']
# ['At iteration 24 the best fitness is 0.4203818427573778']
# ['At iteration 25 the best fitness is 0.4203818427573778']
# ['At iteration 26 the best fitness is 0.4203818427573778']
# ['At iteration 27 the best fitness is 0.4203818427573778']
# ['At iteration 28 the best fitness is 0.4203818427573778']
# ['At iteration 29 the best fitness is 0.4203818427573778']
# ['At iteration 30 the best fitness is 0.4203818427573778']
#       Selected: 27/46 (58.7%), Fitness: 0.4204, Time: 700.0s
#       Modality: D=57%, S=67%,
#     Test Acc: 23.74%, F1: 20.29%, Features: 27/46 (58.7%), Model: 0.054MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.49530299617030854']
# ['At iteration 1 the best fitness is 0.49530299617030854']
# ['At iteration 2 the best fitness is 0.4609089885109258']
# ['At iteration 3 the best fitness is 0.4609089885109258']
# ['At iteration 4 the best fitness is 0.4609089885109258']
# ['At iteration 5 the best fitness is 0.4609089885109258']
# ['At iteration 6 the best fitness is 0.4609089885109258']
# ['At iteration 7 the best fitness is 0.4609089885109258']
# ['At iteration 8 the best fitness is 0.4609089885109258']
# ['At iteration 9 the best fitness is 0.4609089885109258']
# ['At iteration 10 the best fitness is 0.4609089885109258']
# ['At iteration 11 the best fitness is 0.4609089885109258']
# ['At iteration 12 the best fitness is 0.4609089885109258']
# ['At iteration 13 the best fitness is 0.4609089885109258']
# ['At iteration 14 the best fitness is 0.4609089885109258']
# ['At iteration 15 the best fitness is 0.4609089885109258']
# ['At iteration 16 the best fitness is 0.4609089885109258']
# ['At iteration 17 the best fitness is 0.4609089885109258']
# ['At iteration 18 the best fitness is 0.4609089885109258']
# ['At iteration 19 the best fitness is 0.4609089885109258']
# ['At iteration 20 the best fitness is 0.4609089885109258']
# ['At iteration 21 the best fitness is 0.4609089885109258']
# ['At iteration 22 the best fitness is 0.4609089885109258']
# ['At iteration 23 the best fitness is 0.4609089885109258']
# ['At iteration 24 the best fitness is 0.4609089885109258']
# ['At iteration 25 the best fitness is 0.4609089885109258']
# ['At iteration 26 the best fitness is 0.4609089885109258']
# ['At iteration 27 the best fitness is 0.4609089885109258']
# ['At iteration 28 the best fitness is 0.4609089885109258']
# ['At iteration 29 the best fitness is 0.4609089885109258']
#       Selected: 23/46 (50.0%), Fitness: 0.4609, Time: 677.2s
#       Modality: D=51%, S=44%,
#     Test Acc: 20.20%, F1: 15.89%, Features: 23/46 (50.0%), Model: 0.052MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.4898682135616129']
# ['At iteration 2 the best fitness is 0.4477416084703762']
# ['At iteration 3 the best fitness is 0.4477416084703762']
# ['At iteration 4 the best fitness is 0.4477416084703762']
# ['At iteration 5 the best fitness is 0.4477416084703762']
# ['At iteration 6 the best fitness is 0.4477416084703762']
# ['At iteration 7 the best fitness is 0.4477416084703762']
# ['At iteration 8 the best fitness is 0.4477416084703762']
# ['At iteration 9 the best fitness is 0.4477416084703762']
# ['At iteration 10 the best fitness is 0.4477416084703762']
# ['At iteration 11 the best fitness is 0.43732259517909433']
# ['At iteration 12 the best fitness is 0.43732259517909433']
# ['At iteration 13 the best fitness is 0.43732259517909433']
# ['At iteration 14 the best fitness is 0.43732259517909433']
# ['At iteration 15 the best fitness is 0.43732259517909433']
# ['At iteration 16 the best fitness is 0.43732259517909433']
# ['At iteration 17 the best fitness is 0.43732259517909433']
# ['At iteration 18 the best fitness is 0.43732259517909433']
# ['At iteration 19 the best fitness is 0.43732259517909433']
# ['At iteration 20 the best fitness is 0.4274780355936022']
# ['At iteration 21 the best fitness is 0.4274780355936022']
# ['At iteration 22 the best fitness is 0.4274780355936022']
# ['At iteration 23 the best fitness is 0.4274780355936022']
# ['At iteration 24 the best fitness is 0.4274780355936022']
# ['At iteration 25 the best fitness is 0.4274780355936022']
# ['At iteration 26 the best fitness is 0.4274780355936022']
# ['At iteration 27 the best fitness is 0.4274780355936022']
# ['At iteration 28 the best fitness is 0.4274780355936022']
# ['At iteration 29 the best fitness is 0.4274780355936022']
#       Selected: 28/46 (60.9%), Fitness: 0.4275, Time: 1741.6s
#       Modality: D=62%, S=56%,
#     Test Acc: 16.67%, F1: 12.12%, Features: 28/46 (60.9%), Model: 0.054MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.5287339490876323']
# ['At iteration 1 the best fitness is 0.4635954043703536']
# ['At iteration 2 the best fitness is 0.4635954043703536']
# ['At iteration 3 the best fitness is 0.44722910565442664']
# ['At iteration 4 the best fitness is 0.44722910565442664']
# ['At iteration 5 the best fitness is 0.44722910565442664']
# ['At iteration 6 the best fitness is 0.44722910565442664']
# ['At iteration 7 the best fitness is 0.44722910565442664']
# ['At iteration 8 the best fitness is 0.44722910565442664']
# ['At iteration 9 the best fitness is 0.44722910565442664']
# ['At iteration 10 the best fitness is 0.44722910565442664']
# ['At iteration 11 the best fitness is 0.44722910565442664']
# ['At iteration 12 the best fitness is 0.44722910565442664']
# ['At iteration 13 the best fitness is 0.44722910565442664']
# ['At iteration 14 the best fitness is 0.426391079071863']
# ['At iteration 15 the best fitness is 0.426391079071863']
# ['At iteration 16 the best fitness is 0.426391079071863']
# ['At iteration 17 the best fitness is 0.426391079071863']
# ['At iteration 18 the best fitness is 0.426391079071863']
# ['At iteration 19 the best fitness is 0.426391079071863']
# ['At iteration 20 the best fitness is 0.426391079071863']
# ['At iteration 21 the best fitness is 0.426391079071863']
# ['At iteration 22 the best fitness is 0.426391079071863']
# ['At iteration 23 the best fitness is 0.426391079071863']
# ['At iteration 24 the best fitness is 0.426391079071863']
# ['At iteration 25 the best fitness is 0.426391079071863']
# ['At iteration 26 the best fitness is 0.426391079071863']
# ['At iteration 27 the best fitness is 0.426391079071863']
# ['At iteration 28 the best fitness is 0.426391079071863']
# ['At iteration 29 the best fitness is 0.426391079071863']
#       Selected: 34/46 (73.9%), Fitness: 0.4264, Time: 658.3s
#       Modality: D=68%, S=100%,
#     Test Acc: 26.26%, F1: 20.86%, Features: 34/46 (73.9%), Model: 0.057MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_no_skeleton/all_results_per_fold.csv
# Shape: (90, 24)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected
# 0      baseline     1            32.1678           62.2857       26.0431          26.0431              31.7793           32.1678                 46              46                  100.0       0.0000         10.0540         10.0540         16086           0.0628                 0.4089                  0.4089                    0.0        17.6411             100.0000              37              100.0000                9
# 1      baseline     2            33.6100           69.5652       27.4501          27.4570              31.0252           33.6364                 46              46                  100.0       0.0000         10.2920         10.2920         16086           0.0628                 0.4089                  0.4089                    0.0        17.6421             100.0000              37              100.0000                9
# 2      baseline     3            36.8182           65.6085       31.2084          31.2084              35.1750           36.8182                 46              46                  100.0       0.0000         10.8740         10.8740         16086           0.0628                 0.4089                  0.4089                    0.0        17.6431             100.0000              37              100.0000                9
# 3      baseline     4            15.9091           68.2540       12.1728          12.1728              21.8824           15.9091                 46              46                  100.0       0.0000         10.5813         10.5813         16086           0.0628                 0.4089                  0.4089                    0.0        17.6431             100.0000              37              100.0000                9
# 4      baseline     5            31.8182           72.5389       29.1219          29.1219              39.9858           31.8182                 46              46                  100.0       0.0000         11.2953         11.2953         16086           0.0628                 0.4089                  0.4089                    0.0        17.6411             100.0000              37              100.0000                9
# 5   mutual_info     1            47.5524           66.2857       46.0962          46.0962              58.0873           47.5524                 23              46                   50.0       0.2313          9.7552          9.9867         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 6   mutual_info     2            40.2490           75.0000       35.0279          35.1040              43.5993           40.1240                 23              46                   50.0       0.2237         10.2267         10.4505         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 7   mutual_info     3            46.8182           67.1958       44.6596          44.6596              55.5222           46.8182                 23              46                   50.0       0.2317         10.7748         11.0065         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 8   mutual_info     4            24.0909           68.7831       23.3283          23.3283              46.9171           24.0909                 23              46                   50.0       0.2289         10.3977         10.6267         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 9   mutual_info     5            29.7980           70.4663       24.9417          24.9417              33.4004           29.7980                 23              46                   50.0       0.2301         11.1760         11.4062         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 10          rfe     1            41.6084           65.1429       38.0428          38.0428              44.2486           41.6084                 23              46                   50.0       0.1172          9.8249          9.9423         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 11          rfe     2            34.8548           69.5652       30.2144          30.2121              33.8583           34.7934                 23              46                   50.0       0.1077         10.1198         10.2277         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 12          rfe     3            43.6364           62.9630       40.3972          40.3972              49.6315           43.6364                 23              46                   50.0       0.1311         10.6419         10.7734         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 13          rfe     4            28.6364           66.1376       25.7530          25.7530              39.7078           28.6364                 23              46                   50.0       0.1233         10.3422         10.4657         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 14          rfe     5            24.7475           69.4301       20.8115          20.8115              30.8550           24.7475                 23              46                   50.0       0.1221         11.3700         11.4923         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              48.6486              18               55.5556                5
# 15        lasso     1            18.8811           50.2857       14.1681          14.1681              19.9397           18.8811                 23              46                   50.0       0.0066         10.2306         10.2373         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              37.8378              14              100.0000                9
# 16        lasso     2            31.1203           51.6304       27.8965          27.9634              28.7252           31.0331                 23              46                   50.0       0.0065         10.6894         10.6959         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              37.8378              14              100.0000                9
# 17        lasso     3            31.3636           56.6138       28.6884          28.6884              31.3060           31.3636                 23              46                   50.0       0.0065         10.7929         10.7994         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              37.8378              14              100.0000                9
# 18        lasso     4            19.0909           49.2063       17.2485          17.2485              25.9355           19.0909                 23              46                   50.0       0.0069         10.7729         10.7798         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              37.8378              14              100.0000                9
# 19        lasso     5            19.6970           50.2591       14.6440          14.6440              18.0237           19.6970                 23              46                   50.0       0.0068         10.6930         10.6999         13142           0.0516                 0.4089                  0.2044                   50.0        17.5825              37.8378              14              100.0000                9

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              30.06              8.16              25.20              7.53                    46.0                      100.00              0.00                10.62                10.62            16086.0                  0.06                        0.00               17.64
# mutual_info              37.70             10.42              34.81             10.65                    23.0                       50.00              0.23                10.47                10.70            13142.0                  0.05                       50.00               17.58
#         rfe              34.70              8.12              31.04              8.21                    23.0                       50.00              0.12                10.46                10.58            13142.0                  0.05                       50.00               17.58
#       lasso              24.03              6.59              20.53              7.19                    23.0                       50.00              0.01                10.64                10.64            13142.0                  0.05                       50.00               17.58
#    meta_BAT              29.42              9.65              25.06             10.50                    27.4                       59.57            682.60                11.17               693.77            13705.2                  0.05                       40.43               17.59
#     meta_CS              30.03              8.05              24.78              8.78                    27.4                       59.57           1343.60                11.19              1354.79            13705.2                  0.05                       40.43               17.59
#     meta_DE              31.39              8.20              26.78              6.94                    25.2                       54.78            683.16                11.18               694.34            13423.6                  0.05                       45.22               17.59
#    meta_FFA              28.39             13.89              24.62             12.96                    26.8                       58.26            660.42                11.13               671.55            13628.4                  0.05                       41.74               17.59
#     meta_GA              31.00             13.36              27.63             13.18                    24.6                       53.48            661.87                11.10               672.97            13346.8                  0.05                       46.52               17.59
#    meta_GWO              31.25              6.00              26.74              5.71                    20.8                       45.22            647.75                10.78               658.53            12860.4                  0.05                       54.78               17.58
#    meta_HHO              28.63              8.54              23.52              9.61                    35.2                       76.52            829.19                10.41               839.60            14703.6                  0.06                       23.48               17.61
#   meta_JAYA              28.03              8.17              22.67              8.10                    27.6                       60.00            677.60                11.16               688.77            13730.8                  0.05                       40.00               17.59
#    meta_MFO              31.97              6.46              28.88              8.38                    24.2                       52.61            639.89                11.15               651.04            13295.6                  0.05                       47.39               17.58
#    meta_MVO              27.00              5.51              22.93              5.47                    23.8                       51.74            660.58                11.15               671.73            13244.4                  0.05                       48.26               17.58
#    meta_PSO              28.06             10.96              23.68             10.99                    25.0                       54.35            660.13                11.15               671.27            13398.0                  0.05                       45.65               17.59
#    meta_SCA              29.08              6.92              24.87              7.08                    18.0                       39.13            635.69                10.29               645.99            12502.0                  0.05                       60.87               17.57
#    meta_SSA              25.57              6.23              20.72              5.69                    24.0                       52.17           1645.43                11.15              1656.58            13270.0                  0.05                       47.83               17.58
#    meta_WOA              28.64              5.03              23.44              3.72                    36.4                       79.13            618.65                10.50               629.15            14857.2                  0.06                       20.87               17.61

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 37.70% vs Baseline: 30.06%
#   Paired t-test: t=2.6987, p=0.0542
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> better, Not significant
#
# RFE vs BASELINE:
#   Method: 34.70% vs Baseline: 30.06%
#   Paired t-test: t=1.3320, p=0.2537
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 24.03% vs Baseline: 30.06%
#   Paired t-test: t=-1.9708, p=0.1201
#   Wilcoxon test: W=2.0000, p=0.1875
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 29.42% vs Baseline: 30.06%
#   Paired t-test: t=-0.2827, p=0.7915
#   Wilcoxon test: W=5.0000, p=1.0000
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 30.03% vs Baseline: 30.06%
#   Paired t-test: t=-0.0102, p=0.9924
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 31.39% vs Baseline: 30.06%
#   Paired t-test: t=1.0712, p=0.3444
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> better, Not significant
#
# META_FFA vs BASELINE:
#   Method: 28.39% vs Baseline: 30.06%
#   Paired t-test: t=-0.4375, p=0.6843
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 31.00% vs Baseline: 30.06%
#   Paired t-test: t=0.2766, p=0.7958
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> better, Not significant
#
# META_GWO vs BASELINE:
#   Method: 31.25% vs Baseline: 30.06%
#   Paired t-test: t=0.2574, p=0.8096
#   Wilcoxon test: W=5.0000, p=1.0000
#   -> better, Not significant
#
# META_HHO vs BASELINE:
#   Method: 28.63% vs Baseline: 30.06%
#   Paired t-test: t=-0.4882, p=0.6510
#   Wilcoxon test: W=4.0000, p=0.8750
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 28.03% vs Baseline: 30.06%
#   Paired t-test: t=-0.5848, p=0.5901
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 31.97% vs Baseline: 30.06%
#   Paired t-test: t=0.3549, p=0.7406
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> better, Not significant
#
# META_MVO vs BASELINE:
#   Method: 27.00% vs Baseline: 30.06%
#   Paired t-test: t=-1.0600, p=0.3489
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 28.06% vs Baseline: 30.06%
#   Paired t-test: t=-0.6239, p=0.5665
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 29.08% vs Baseline: 30.06%
#   Paired t-test: t=-0.1931, p=0.8563
#   Wilcoxon test: W=6.0000, p=0.8125
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 25.57% vs Baseline: 30.06%
#   Paired t-test: t=-1.0486, p=0.3535
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 28.64% vs Baseline: 30.06%
#   Paired t-test: t=-0.6062, p=0.5771
#   Wilcoxon test: W=3.0000, p=0.6250
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_no_skeleton
#
# Per-method folders:
#   results_no_skeleton/baseline/ (10 files)
#   results_no_skeleton/mutual_info/ (10 files)
#   results_no_skeleton/rfe/ (10 files)
#   results_no_skeleton/lasso/ (10 files)
#   results_no_skeleton/meta_BAT/ (10 files)
#   results_no_skeleton/meta_CS/ (10 files)
#   results_no_skeleton/meta_DE/ (10 files)
#   results_no_skeleton/meta_FFA/ (10 files)
#   results_no_skeleton/meta_GA/ (10 files)
#   results_no_skeleton/meta_GWO/ (10 files)
#   results_no_skeleton/meta_HHO/ (10 files)
#   results_no_skeleton/meta_JAYA/ (10 files)
#   results_no_skeleton/meta_MFO/ (10 files)
#   results_no_skeleton/meta_MVO/ (10 files)
#   results_no_skeleton/meta_PSO/ (10 files)
#   results_no_skeleton/meta_SCA/ (10 files)
#   results_no_skeleton/meta_SSA/ (10 files)
#   results_no_skeleton/meta_WOA/ (10 files)
#
# Plots directory: results_no_skeleton/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   mutual_info         : 37.70% ± 10.42% (Features: 50.0%)
#   rfe                 : 34.70% ± 8.12% (Features: 50.0%)
#   meta_MFO            : 31.97% ± 6.46% (Features: 52.6%)
#   meta_DE             : 31.39% ± 8.20% (Features: 54.8%)
#   meta_GWO            : 31.25% ± 6.00% (Features: 45.2%)
