# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new")

# Master output directory
RESULTS_ROOT = Path("results_skeleton_new")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   skeleton: 1645
#   TOTAL: 1645

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 95.80%, F1: 95.83%, Features: 1645/1645 (100.0%), Model: 3.749MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 822/1645 (50.0%), Time: 8.1s
#     Test Acc: 96.50%, F1: 96.45%, Features: 822/1645 (50.0%), Model: 2.142MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 822/1645 (50.0%), Time: 1.6s
#     Test Acc: 98.60%, F1: 98.60%, Features: 822/1645 (50.0%), Model: 2.142MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 822/1645 (50.0%), Time: 0.2s
#     Test Acc: 93.71%, F1: 93.56%, Features: 822/1645 (50.0%), Model: 2.142MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03590273556231006']
# ['At iteration 1 the best fitness is 0.03590273556231006']
# ['At iteration 2 the best fitness is 0.03590273556231006']
# ['At iteration 3 the best fitness is 0.03590273556231006']
# ['At iteration 4 the best fitness is 0.03590273556231006']
# ['At iteration 5 the best fitness is 0.03575075987841948']
# ['At iteration 6 the best fitness is 0.03575075987841948']
# ['At iteration 7 the best fitness is 0.03575075987841948']
# ['At iteration 8 the best fitness is 0.03575075987841948']
# ['At iteration 9 the best fitness is 0.03575075987841948']
# ['At iteration 10 the best fitness is 0.03575075987841948']
# ['At iteration 11 the best fitness is 0.03575075987841948']
# ['At iteration 12 the best fitness is 0.03575075987841948']
# ['At iteration 13 the best fitness is 0.03575075987841948']
# ['At iteration 14 the best fitness is 0.03575075987841948']
# ['At iteration 15 the best fitness is 0.03575075987841948']
# ['At iteration 16 the best fitness is 0.03575075987841948']
# ['At iteration 17 the best fitness is 0.03575075987841948']
# ['At iteration 18 the best fitness is 0.03575075987841948']
# ['At iteration 19 the best fitness is 0.03575075987841948']
# ['At iteration 20 the best fitness is 0.03575075987841948']
# ['At iteration 21 the best fitness is 0.03575075987841948']
# ['At iteration 22 the best fitness is 0.03575075987841948']
# ['At iteration 23 the best fitness is 0.03575075987841948']
# ['At iteration 24 the best fitness is 0.03575075987841948']
# ['At iteration 25 the best fitness is 0.03575075987841948']
# ['At iteration 26 the best fitness is 0.03575075987841948']
# ['At iteration 27 the best fitness is 0.035720364741641364']
# ['At iteration 28 the best fitness is 0.035720364741641364']
# ['At iteration 29 the best fitness is 0.035720364741641364']
#       Selected: 815/1645 (49.5%), Fitness: 0.0357, Time: 629.0s
#       Modality: Sk=50%
#     Test Acc: 96.50%, F1: 96.51%, Features: 815/1645 (49.5%), Model: 2.128MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03687537993920975']
# ['At iteration 10 the best fitness is 0.034565349544072976']
# ['At iteration 20 the best fitness is 0.034565349544072976']
#       Selected: 790/1645 (48.0%), Fitness: 0.0345, Time: 1230.4s
#       Modality: Sk=48%
#     Test Acc: 94.06%, F1: 93.96%, Features: 790/1645 (48.0%), Model: 2.079MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04102735562310029']
# ['At iteration 2 the best fitness is 0.04102735562310029']
# ['At iteration 3 the best fitness is 0.04102735562310029']
# ['At iteration 4 the best fitness is 0.04038905775075986']
# ['At iteration 5 the best fitness is 0.04038905775075986']
# ['At iteration 6 the best fitness is 0.04038905775075986']
# ['At iteration 7 the best fitness is 0.04038905775075986']
# ['At iteration 8 the best fitness is 0.04038905775075986']
# ['At iteration 9 the best fitness is 0.035872340425531946']
# ['At iteration 10 the best fitness is 0.035872340425531946']
# ['At iteration 11 the best fitness is 0.035689969604863245']
# ['At iteration 12 the best fitness is 0.035689969604863245']
# ['At iteration 13 the best fitness is 0.035689969604863245']
# ['At iteration 14 the best fitness is 0.035689969604863245']
# ['At iteration 15 the best fitness is 0.03477811550151978']
# ['At iteration 16 the best fitness is 0.03477811550151978']
# ['At iteration 17 the best fitness is 0.03477811550151978']
# ['At iteration 18 the best fitness is 0.03477811550151978']
# ['At iteration 19 the best fitness is 0.03477811550151978']
# ['At iteration 20 the best fitness is 0.03477811550151978']
# ['At iteration 21 the best fitness is 0.03477811550151978']
# ['At iteration 22 the best fitness is 0.03477811550151978']
# ['At iteration 23 the best fitness is 0.03477811550151978']
# ['At iteration 24 the best fitness is 0.03477811550151978']
# ['At iteration 25 the best fitness is 0.03477811550151978']
# ['At iteration 26 the best fitness is 0.03477811550151978']
# ['At iteration 27 the best fitness is 0.03477811550151978']
# ['At iteration 28 the best fitness is 0.03477811550151978']
# ['At iteration 29 the best fitness is 0.03477811550151978']
# ['At iteration 30 the best fitness is 0.03477811550151978']
#       Selected: 798/1645 (48.5%), Fitness: 0.0348, Time: 624.0s
#       Modality: Sk=49%
#     Test Acc: 93.36%, F1: 93.15%, Features: 798/1645 (48.5%), Model: 2.095MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.040814589665653475']
# ['At iteration 1 the best fitness is 0.04600000000000005']
# ['At iteration 2 the best fitness is 0.046699088145896704']
# ['At iteration 3 the best fitness is 0.04096656534954406']
# ['At iteration 4 the best fitness is 0.04120972644376898']
# ['At iteration 5 the best fitness is 0.03626747720364744']
# ['At iteration 6 the best fitness is 0.03602431610942251']
# ['At iteration 7 the best fitness is 0.041604863221884475']
# ['At iteration 8 the best fitness is 0.041331306990881445']
# ['At iteration 9 the best fitness is 0.04117933130699086']
# ['At iteration 10 the best fitness is 0.041361702127659564']
# ['At iteration 11 the best fitness is 0.041270516717325206']
# ['At iteration 12 the best fitness is 0.041331306990881445']
# ['At iteration 13 the best fitness is 0.04117933130699086']
# ['At iteration 14 the best fitness is 0.041148936170212744']
# ['At iteration 15 the best fitness is 0.04117933130699086']
# ['At iteration 16 the best fitness is 0.03041337386018233']
# ['At iteration 17 the best fitness is 0.03581155015197571']
# ['At iteration 18 the best fitness is 0.041300911854103325']
# ['At iteration 19 the best fitness is 0.041240121580547094']
# ['At iteration 20 the best fitness is 0.041270516717325206']
# ['At iteration 21 the best fitness is 0.041240121580547094']
# ['At iteration 22 the best fitness is 0.041300911854103325']
# ['At iteration 23 the best fitness is 0.041240121580547094']
# ['At iteration 24 the best fitness is 0.041240121580547094']
# ['At iteration 25 the best fitness is 0.041270516717325206']
# ['At iteration 26 the best fitness is 0.041270516717325206']
# ['At iteration 27 the best fitness is 0.041240121580547094']
# ['At iteration 28 the best fitness is 0.041240121580547094']
# ['At iteration 29 the best fitness is 0.041240121580547094']
#       Selected: 866/1645 (52.6%), Fitness: 0.0412, Time: 607.3s
#       Modality: Sk=53%
#     Test Acc: 97.20%, F1: 97.19%, Features: 866/1645 (52.6%), Model: 2.228MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.04672948328267482
# At iteration 2 the best fitness is 0.0420303951367781
# At iteration 3 the best fitness is 0.0420303951367781
# At iteration 4 the best fitness is 0.04120972644376898
# At iteration 5 the best fitness is 0.03596352583586629
# At iteration 6 the best fitness is 0.03672340425531918
# At iteration 7 the best fitness is 0.036206686930091214
# At iteration 8 the best fitness is 0.036206686930091214
# At iteration 9 the best fitness is 0.030808510638297832
# At iteration 10 the best fitness is 0.03596352583586629
# At iteration 11 the best fitness is 0.03053495440729479
# At iteration 12 the best fitness is 0.03053495440729479
# At iteration 13 the best fitness is 0.03050455927051668
# At iteration 14 the best fitness is 0.03593313069908817
# At iteration 15 the best fitness is 0.03605471124620063
# At iteration 16 the best fitness is 0.035720364741641364
# At iteration 17 the best fitness is 0.036358662613981796
# At iteration 18 the best fitness is 0.03581155015197571
# At iteration 19 the best fitness is 0.035781155015197595
# At iteration 20 the best fitness is 0.035781155015197595
# At iteration 21 the best fitness is 0.035872340425531946
# At iteration 22 the best fitness is 0.035781155015197595
# At iteration 23 the best fitness is 0.03135562310030391
# At iteration 24 the best fitness is 0.035872340425531946
# At iteration 25 the best fitness is 0.03562917933130702
# At iteration 26 the best fitness is 0.036358662613981796
# At iteration 27 the best fitness is 0.03562917933130702
# At iteration 28 the best fitness is 0.03526443768996963
# At iteration 29 the best fitness is 0.0303525835866261
# At iteration 30 the best fitness is 0.03529483282674775
#       Selected: 791/1645 (48.1%), Fitness: 0.0353, Time: 606.4s
#       Modality: Sk=48%
#     Test Acc: 95.80%, F1: 95.60%, Features: 791/1645 (48.1%), Model: 2.081MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03605471124620063']
# ['At iteration 1 the best fitness is 0.03605471124620063']
# ['At iteration 2 the best fitness is 0.03605471124620063']
# ['At iteration 3 the best fitness is 0.03605471124620063']
# ['At iteration 4 the best fitness is 0.03605471124620063']
# ['At iteration 5 the best fitness is 0.02664437689969601']
# ['At iteration 6 the best fitness is 0.026310030395136737']
# ['At iteration 7 the best fitness is 0.026310030395136737']
# ['At iteration 8 the best fitness is 0.026310030395136737']
# ['At iteration 9 the best fitness is 0.026310030395136737']
# ['At iteration 10 the best fitness is 0.0260364741641337']
# ['At iteration 11 the best fitness is 0.0260364741641337']
# ['At iteration 12 the best fitness is 0.0260364741641337']
# ['At iteration 13 the best fitness is 0.0260364741641337']
# ['At iteration 14 the best fitness is 0.0260364741641337']
# ['At iteration 15 the best fitness is 0.0260364741641337']
# ['At iteration 16 the best fitness is 0.0260364741641337']
# ['At iteration 17 the best fitness is 0.0260364741641337']
# ['At iteration 18 the best fitness is 0.0260364741641337']
# ['At iteration 19 the best fitness is 0.0260364741641337']
# ['At iteration 20 the best fitness is 0.0260364741641337']
# ['At iteration 21 the best fitness is 0.026006079027355584']
# ['At iteration 22 the best fitness is 0.026006079027355584']
# ['At iteration 23 the best fitness is 0.026006079027355584']
# ['At iteration 24 the best fitness is 0.026006079027355584']
# ['At iteration 25 the best fitness is 0.026006079027355584']
# ['At iteration 26 the best fitness is 0.026006079027355584']
# ['At iteration 27 the best fitness is 0.026006079027355584']
# ['At iteration 28 the best fitness is 0.026006079027355584']
# ['At iteration 29 the best fitness is 0.026006079027355584']
#       Selected: 715/1645 (43.5%), Fitness: 0.0260, Time: 603.1s
#       Modality: Sk=43%
#     Test Acc: 95.80%, F1: 95.67%, Features: 715/1645 (43.5%), Model: 1.933MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.04657750759878424']
# ['At iteration 1 the best fitness is 0.041331306990881445']
# ['At iteration 2 the best fitness is 0.0381519756838906']
# ['At iteration 3 the best fitness is 0.0381519756838906']
# ['At iteration 4 the best fitness is 0.0381519756838906']
# ['At iteration 5 the best fitness is 0.0381519756838906']
# ['At iteration 6 the best fitness is 0.0381519756838906']
# ['At iteration 7 the best fitness is 0.037337386018237134']
# ['At iteration 8 the best fitness is 0.037337386018237134']
# ['At iteration 9 the best fitness is 0.03269908814589664']
# ['At iteration 10 the best fitness is 0.03269908814589664']
# ['At iteration 11 the best fitness is 0.02730091185410337']
# ['At iteration 12 the best fitness is 0.02730091185410337']
# ['At iteration 13 the best fitness is 0.02730091185410337']
# ['At iteration 14 the best fitness is 0.02730091185410337']
# ['At iteration 15 the best fitness is 0.02730091185410337']
# ['At iteration 16 the best fitness is 0.02730091185410337']
# ['At iteration 17 the best fitness is 0.02730091185410337']
# ['At iteration 18 the best fitness is 0.02730091185410337']
# ['At iteration 19 the best fitness is 0.02730091185410337']
# ['At iteration 20 the best fitness is 0.02730091185410337']
# ['At iteration 21 the best fitness is 0.02730091185410337']
# ['At iteration 22 the best fitness is 0.02730091185410337']
# ['At iteration 23 the best fitness is 0.02730091185410337']
# ['At iteration 24 the best fitness is 0.02730091185410337']
# ['At iteration 25 the best fitness is 0.02730091185410337']
# ['At iteration 26 the best fitness is 0.02730091185410337']
# ['At iteration 27 the best fitness is 0.02730091185410337']
# ['At iteration 28 the best fitness is 0.02730091185410337']
# ['At iteration 29 the best fitness is 0.02730091185410337']
#       Selected: 420/1645 (25.5%), Fitness: 0.0273, Time: 813.2s
#       Modality: Sk=26%
#     Test Acc: 94.06%, F1: 93.80%, Features: 420/1645 (25.5%), Model: 1.357MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04041945288753798']
# ['At iteration 1 the best fitness is 0.030200607902735523']
# ['At iteration 2 the best fitness is 0.030200607902735523']
# ['At iteration 3 the best fitness is 0.030200607902735523']
# ['At iteration 4 the best fitness is 0.030200607902735523']
# ['At iteration 5 the best fitness is 0.030200607902735523']
# ['At iteration 6 the best fitness is 0.030200607902735523']
# ['At iteration 7 the best fitness is 0.030200607902735523']
# ['At iteration 8 the best fitness is 0.030200607902735523']
# ['At iteration 9 the best fitness is 0.030200607902735523']
# ['At iteration 10 the best fitness is 0.030200607902735523']
# ['At iteration 11 the best fitness is 0.030200607902735523']
# ['At iteration 12 the best fitness is 0.030200607902735523']
# ['At iteration 13 the best fitness is 0.030200607902735523']
# ['At iteration 14 the best fitness is 0.030200607902735523']
# ['At iteration 15 the best fitness is 0.030200607902735523']
# ['At iteration 16 the best fitness is 0.030200607902735523']
# ['At iteration 17 the best fitness is 0.030200607902735523']
# ['At iteration 18 the best fitness is 0.030200607902735523']
# ['At iteration 19 the best fitness is 0.030170212765957407']
# ['At iteration 20 the best fitness is 0.030170212765957407']
# ['At iteration 21 the best fitness is 0.030170212765957407']
# ['At iteration 22 the best fitness is 0.030170212765957407']
# ['At iteration 23 the best fitness is 0.030170212765957407']
# ['At iteration 24 the best fitness is 0.030170212765957407']
# ['At iteration 25 the best fitness is 0.030170212765957407']
# ['At iteration 26 the best fitness is 0.030170212765957407']
# ['At iteration 27 the best fitness is 0.030170212765957407']
# ['At iteration 28 the best fitness is 0.030170212765957407']
# ['At iteration 29 the best fitness is 0.030170212765957407']
#       Selected: 804/1645 (48.9%), Fitness: 0.0302, Time: 618.0s
#       Modality: Sk=49%
#     Test Acc: 96.50%, F1: 96.49%, Features: 804/1645 (48.9%), Model: 2.107MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04072340425531913']
# ['At iteration 2 the best fitness is 0.04072340425531913']
# ['At iteration 3 the best fitness is 0.04072340425531913']
# ['At iteration 4 the best fitness is 0.04072340425531913']
# ['At iteration 5 the best fitness is 0.0359939209726444']
# ['At iteration 6 the best fitness is 0.0359939209726444']
# ['At iteration 7 the best fitness is 0.0359939209726444']
# ['At iteration 8 the best fitness is 0.03590273556231006']
# ['At iteration 9 the best fitness is 0.03590273556231006']
# ['At iteration 10 the best fitness is 0.035203647416413394']
# ['At iteration 11 the best fitness is 0.035203647416413394']
# ['At iteration 12 the best fitness is 0.035203647416413394']
# ['At iteration 13 the best fitness is 0.035203647416413394']
# ['At iteration 14 the best fitness is 0.030170212765957407']
# ['At iteration 15 the best fitness is 0.030170212765957407']
# ['At iteration 16 the best fitness is 0.030170212765957407']
# ['At iteration 17 the best fitness is 0.030170212765957407']
# ['At iteration 18 the best fitness is 0.030170212765957407']
# ['At iteration 19 the best fitness is 0.030170212765957407']
# ['At iteration 20 the best fitness is 0.030170212765957407']
# ['At iteration 21 the best fitness is 0.030170212765957407']
# ['At iteration 22 the best fitness is 0.030170212765957407']
# ['At iteration 23 the best fitness is 0.030170212765957407']
# ['At iteration 24 the best fitness is 0.030170212765957407']
# ['At iteration 25 the best fitness is 0.030170212765957407']
# ['At iteration 26 the best fitness is 0.030170212765957407']
# ['At iteration 27 the best fitness is 0.030170212765957407']
# ['At iteration 28 the best fitness is 0.030170212765957407']
# ['At iteration 29 the best fitness is 0.030170212765957407']
#       Selected: 821/1645 (49.9%), Fitness: 0.0302, Time: 586.7s
#       Modality: Sk=50%
#     Test Acc: 95.45%, F1: 95.27%, Features: 821/1645 (49.9%), Model: 2.140MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04157446808510637']
# ['At iteration 2 the best fitness is 0.040996960486322176']
# ['At iteration 3 the best fitness is 0.04075379939209725']
# ['At iteration 4 the best fitness is 0.03593313069908817']
# ['At iteration 5 the best fitness is 0.03593313069908817']
# ['At iteration 6 the best fitness is 0.03593313069908817']
# ['At iteration 7 the best fitness is 0.0355987841945289']
# ['At iteration 8 the best fitness is 0.0355987841945289']
# ['At iteration 9 the best fitness is 0.0355987841945289']
# ['At iteration 10 the best fitness is 0.03544680851063832']
# ['At iteration 11 the best fitness is 0.03544680851063832']
# ['At iteration 12 the best fitness is 0.03544680851063832']
# ['At iteration 13 the best fitness is 0.03544680851063832']
# ['At iteration 14 the best fitness is 0.03544680851063832']
# ['At iteration 15 the best fitness is 0.03544680851063832']
# ['At iteration 16 the best fitness is 0.03544680851063832']
# ['At iteration 17 the best fitness is 0.03544680851063832']
# ['At iteration 18 the best fitness is 0.03544680851063832']
# ['At iteration 19 the best fitness is 0.03544680851063832']
# ['At iteration 20 the best fitness is 0.03544680851063832']
# ['At iteration 21 the best fitness is 0.03544680851063832']
# ['At iteration 22 the best fitness is 0.03544680851063832']
# ['At iteration 23 the best fitness is 0.03544680851063832']
# ['At iteration 24 the best fitness is 0.03544680851063832']
# ['At iteration 25 the best fitness is 0.03544680851063832']
# ['At iteration 26 the best fitness is 0.03544680851063832']
# ['At iteration 27 the best fitness is 0.03544680851063832']
# ['At iteration 28 the best fitness is 0.03544680851063832']
# ['At iteration 29 the best fitness is 0.03544680851063832']
# ['At iteration 30 the best fitness is 0.03544680851063832']
#       Selected: 819/1645 (49.8%), Fitness: 0.0354, Time: 607.6s
#       Modality: Sk=50%
#     Test Acc: 96.15%, F1: 96.13%, Features: 819/1645 (49.8%), Model: 2.136MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.046273556231003085']
# ['At iteration 2 the best fitness is 0.04063221884498479']
# ['At iteration 3 the best fitness is 0.04054103343465044']
# ['At iteration 4 the best fitness is 0.04054103343465044']
# ['At iteration 5 the best fitness is 0.04054103343465044']
# ['At iteration 6 the best fitness is 0.04054103343465044']
# ['At iteration 7 the best fitness is 0.04054103343465044']
# ['At iteration 8 the best fitness is 0.04054103343465044']
# ['At iteration 9 the best fitness is 0.040358662613981744']
# ['At iteration 10 the best fitness is 0.034869300911854126']
# ['At iteration 11 the best fitness is 0.034869300911854126']
# ['At iteration 12 the best fitness is 0.034869300911854126']
# ['At iteration 13 the best fitness is 0.034869300911854126']
# ['At iteration 14 the best fitness is 0.034869300911854126']
# ['At iteration 15 the best fitness is 0.034869300911854126']
# ['At iteration 16 the best fitness is 0.034869300911854126']
# ['At iteration 17 the best fitness is 0.034869300911854126']
# ['At iteration 18 the best fitness is 0.03474772036474166']
# ['At iteration 19 the best fitness is 0.03474772036474166']
# ['At iteration 20 the best fitness is 0.03468693009118544']
# ['At iteration 21 the best fitness is 0.03468693009118544']
# ['At iteration 22 the best fitness is 0.03468693009118544']
# ['At iteration 23 the best fitness is 0.03468693009118544']
# ['At iteration 24 the best fitness is 0.03465653495440732']
# ['At iteration 25 the best fitness is 0.03465653495440732']
# ['At iteration 26 the best fitness is 0.03465653495440732']
# ['At iteration 27 the best fitness is 0.02962310030395133']
# ['At iteration 28 the best fitness is 0.02962310030395133']
# ['At iteration 29 the best fitness is 0.029471124620060747']
# ['At iteration 30 the best fitness is 0.029319148936170172']
#       Selected: 775/1645 (47.1%), Fitness: 0.0293, Time: 607.6s
#       Modality: Sk=47%
#     Test Acc: 96.50%, F1: 96.48%, Features: 775/1645 (47.1%), Model: 2.050MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.041148936170212744']
# ['At iteration 1 the best fitness is 0.038717325227963506']
# ['At iteration 2 the best fitness is 0.03865653495440728']
# ['At iteration 3 the best fitness is 0.03143465045592708']
# ['At iteration 4 the best fitness is 0.03143465045592708']
# ['At iteration 5 the best fitness is 0.03143465045592708']
# ['At iteration 6 the best fitness is 0.03143465045592708']
# ['At iteration 7 the best fitness is 0.03143465045592708']
# ['At iteration 8 the best fitness is 0.025933130699088168']
# ['At iteration 9 the best fitness is 0.025933130699088168']
# ['At iteration 10 the best fitness is 0.025933130699088168']
# ['At iteration 11 the best fitness is 0.023349544072948352']
# ['At iteration 12 the best fitness is 0.023349544072948352']
# ['At iteration 13 the best fitness is 0.021829787234042577']
# ['At iteration 14 the best fitness is 0.021829787234042577']
# ['At iteration 15 the best fitness is 0.021829787234042577']
# ['At iteration 16 the best fitness is 0.021829787234042577']
# ['At iteration 17 the best fitness is 0.021829787234042577']
# ['At iteration 18 the best fitness is 0.021829787234042577']
# ['At iteration 19 the best fitness is 0.021829787234042577']
# ['At iteration 20 the best fitness is 0.021829787234042577']
# ['At iteration 21 the best fitness is 0.021829787234042577']
# ['At iteration 22 the best fitness is 0.021829787234042577']
# ['At iteration 23 the best fitness is 0.021829787234042577']
# ['At iteration 24 the best fitness is 0.021829787234042577']
# ['At iteration 25 the best fitness is 0.021829787234042577']
# ['At iteration 26 the best fitness is 0.021829787234042577']
# ['At iteration 27 the best fitness is 0.021829787234042577']
# ['At iteration 28 the best fitness is 0.021829787234042577']
# ['At iteration 29 the best fitness is 0.021829787234042577']
#       Selected: 374/1645 (22.7%), Fitness: 0.0218, Time: 633.7s
#       Modality: Sk=23%
#     Test Acc: 94.41%, F1: 94.38%, Features: 374/1645 (22.7%), Model: 1.267MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03602431610942251']
# ['At iteration 2 the best fitness is 0.03602431610942251']
# ['At iteration 3 the best fitness is 0.03602431610942251']
# ['At iteration 4 the best fitness is 0.03602431610942251']
# ['At iteration 5 the best fitness is 0.03602431610942251']
# ['At iteration 6 the best fitness is 0.03562917933130702']
# ['At iteration 7 the best fitness is 0.03541641337386021']
# ['At iteration 8 the best fitness is 0.03541641337386021']
# ['At iteration 9 the best fitness is 0.03541641337386021']
# ['At iteration 10 the best fitness is 0.03541641337386021']
# ['At iteration 11 the best fitness is 0.034869300911854126']
# ['At iteration 12 the best fitness is 0.03474772036474166']
# ['At iteration 13 the best fitness is 0.03474772036474166']
# ['At iteration 14 the best fitness is 0.03474772036474166']
# ['At iteration 15 the best fitness is 0.03474772036474166']
# ['At iteration 16 the best fitness is 0.03474772036474166']
# ['At iteration 17 the best fitness is 0.03471732522796355']
# ['At iteration 18 the best fitness is 0.03465653495440732']
# ['At iteration 19 the best fitness is 0.03465653495440732']
# ['At iteration 20 the best fitness is 0.0346261398176292']
# ['At iteration 21 the best fitness is 0.0346261398176292']
# ['At iteration 22 the best fitness is 0.0346261398176292']
# ['At iteration 23 the best fitness is 0.0346261398176292']
# ['At iteration 24 the best fitness is 0.0346261398176292']
# ['At iteration 25 the best fitness is 0.0346261398176292']
# ['At iteration 26 the best fitness is 0.0346261398176292']
# ['At iteration 27 the best fitness is 0.0346261398176292']
# ['At iteration 28 the best fitness is 0.0346261398176292']
# ['At iteration 29 the best fitness is 0.0346261398176292']
#       Selected: 806/1645 (49.0%), Fitness: 0.0346, Time: 1501.1s
#       Modality: Sk=49%
#     Test Acc: 93.36%, F1: 93.01%, Features: 806/1645 (49.0%), Model: 2.110MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.035720364741641364']
# ['At iteration 1 the best fitness is 0.03104559270516722']
# ['At iteration 2 the best fitness is 0.026972644376899745']
# ['At iteration 3 the best fitness is 0.02679027355623105']
# ['At iteration 4 the best fitness is 0.02679027355623105']
# ['At iteration 5 the best fitness is 0.025343465045592685']
# ['At iteration 6 the best fitness is 0.020613981762917958']
# ['At iteration 7 the best fitness is 0.020613981762917958']
# ['At iteration 8 the best fitness is 0.020613981762917958']
# ['At iteration 9 the best fitness is 0.020613981762917958']
# ['At iteration 10 the best fitness is 0.020613981762917958']
# ['At iteration 11 the best fitness is 0.01958054711246203']
# ['At iteration 12 the best fitness is 0.01958054711246203']
# ['At iteration 13 the best fitness is 0.01958054711246203']
# ['At iteration 14 the best fitness is 0.01958054711246203']
# ['At iteration 15 the best fitness is 0.01958054711246203']
# ['At iteration 16 the best fitness is 0.01958054711246203']
# ['At iteration 17 the best fitness is 0.01958054711246203']
# ['At iteration 18 the best fitness is 0.01958054711246203']
# ['At iteration 19 the best fitness is 0.01958054711246203']
# ['At iteration 20 the best fitness is 0.01958054711246203']
# ['At iteration 21 the best fitness is 0.01958054711246203']
# ['At iteration 22 the best fitness is 0.01958054711246203']
# ['At iteration 23 the best fitness is 0.01958054711246203']
# ['At iteration 24 the best fitness is 0.01958054711246203']
# ['At iteration 25 the best fitness is 0.01958054711246203']
# ['At iteration 26 the best fitness is 0.01958054711246203']
# ['At iteration 27 the best fitness is 0.01958054711246203']
# ['At iteration 28 the best fitness is 0.01958054711246203']
# ['At iteration 29 the best fitness is 0.01958054711246203']
#       Selected: 296/1645 (18.0%), Fitness: 0.0196, Time: 627.7s
#       Modality: Sk=18%
#     Test Acc: 90.56%, F1: 90.43%, Features: 296/1645 (18.0%), Model: 1.114MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 86.72%, F1: 86.59%, Features: 1645/1645 (100.0%), Model: 3.749MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 822/1645 (50.0%), Time: 8.1s
#     Test Acc: 87.14%, F1: 87.31%, Features: 822/1645 (50.0%), Model: 2.142MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 822/1645 (50.0%), Time: 1.6s
#     Test Acc: 87.14%, F1: 87.63%, Features: 822/1645 (50.0%), Model: 2.142MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 822/1645 (50.0%), Time: 0.2s
#     Test Acc: 82.99%, F1: 83.25%, Features: 822/1645 (50.0%), Model: 2.142MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03509812343068592']
# ['At iteration 1 the best fitness is 0.03509812343068592']
# ['At iteration 2 the best fitness is 0.03509812343068592']
# ['At iteration 3 the best fitness is 0.03509812343068592']
# ['At iteration 4 the best fitness is 0.03509812343068592']
# ['At iteration 5 the best fitness is 0.03509812343068592']
# ['At iteration 6 the best fitness is 0.03509812343068592']
# ['At iteration 7 the best fitness is 0.03509812343068592']
# ['At iteration 8 the best fitness is 0.03509812343068592']
# ['At iteration 9 the best fitness is 0.03509812343068592']
# ['At iteration 10 the best fitness is 0.03509812343068592']
# ['At iteration 11 the best fitness is 0.03509812343068592']
# ['At iteration 12 the best fitness is 0.03509812343068592']
# ['At iteration 13 the best fitness is 0.03509812343068592']
# ['At iteration 14 the best fitness is 0.03509812343068592']
# ['At iteration 15 the best fitness is 0.03509812343068592']
# ['At iteration 16 the best fitness is 0.03503733315712969']
# ['At iteration 17 the best fitness is 0.03503733315712969']
# ['At iteration 18 the best fitness is 0.03503733315712969']
# ['At iteration 19 the best fitness is 0.03503733315712969']
# ['At iteration 20 the best fitness is 0.03503733315712969']
# ['At iteration 21 the best fitness is 0.03503733315712969']
# ['At iteration 22 the best fitness is 0.03503733315712969']
# ['At iteration 23 the best fitness is 0.03503733315712969']
# ['At iteration 24 the best fitness is 0.03503733315712969']
# ['At iteration 25 the best fitness is 0.03503733315712969']
# ['At iteration 26 the best fitness is 0.03503733315712969']
# ['At iteration 27 the best fitness is 0.03503733315712969']
# ['At iteration 28 the best fitness is 0.03503733315712969']
# ['At iteration 29 the best fitness is 0.03503733315712969']
#       Selected: 835/1645 (50.8%), Fitness: 0.0350, Time: 665.1s
#       Modality: Sk=51%
#     Test Acc: 87.97%, F1: 88.18%, Features: 835/1645 (50.8%), Model: 2.167MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03497654288357346']
# ['At iteration 10 the best fitness is 0.03458140610545796']
# ['At iteration 20 the best fitness is 0.03458140610545796']
#       Selected: 800/1645 (48.6%), Fitness: 0.0345, Time: 1316.8s
#       Modality: Sk=49%
#     Test Acc: 85.06%, F1: 85.28%, Features: 800/1645 (48.6%), Model: 2.099MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04007879608827801']
# ['At iteration 2 the best fitness is 0.04007879608827801']
# ['At iteration 3 the best fitness is 0.04007879608827801']
# ['At iteration 4 the best fitness is 0.035371679661688964']
# ['At iteration 5 the best fitness is 0.035371679661688964']
# ['At iteration 6 the best fitness is 0.035371679661688964']
# ['At iteration 7 the best fitness is 0.035371679661688964']
# ['At iteration 8 the best fitness is 0.035371679661688964']
# ['At iteration 9 the best fitness is 0.03521970397779838']
# ['At iteration 10 the best fitness is 0.034915752610017226']
# ['At iteration 11 the best fitness is 0.03470298665257042']
# ['At iteration 12 the best fitness is 0.03442943042156738']
# ['At iteration 13 the best fitness is 0.03442943042156738']
# ['At iteration 14 the best fitness is 0.03442943042156738']
# ['At iteration 15 the best fitness is 0.03442943042156738']
# ['At iteration 16 the best fitness is 0.03442943042156738']
# ['At iteration 17 the best fitness is 0.03442943042156738']
# ['At iteration 18 the best fitness is 0.03442943042156738']
# ['At iteration 19 the best fitness is 0.03442943042156738']
# ['At iteration 20 the best fitness is 0.03442943042156738']
# ['At iteration 21 the best fitness is 0.03060377296154357']
# ['At iteration 22 the best fitness is 0.03060377296154357']
# ['At iteration 23 the best fitness is 0.03060377296154357']
# ['At iteration 24 the best fitness is 0.03060377296154357']
# ['At iteration 25 the best fitness is 0.03060377296154357']
# ['At iteration 26 the best fitness is 0.03060377296154357']
# ['At iteration 27 the best fitness is 0.03060377296154357']
# ['At iteration 28 the best fitness is 0.03060377296154357']
# ['At iteration 29 the best fitness is 0.03060377296154357']
# ['At iteration 30 the best fitness is 0.03060377296154357']
#       Selected: 811/1645 (49.3%), Fitness: 0.0306, Time: 669.9s
#       Modality: Sk=49%
#     Test Acc: 85.06%, F1: 84.71%, Features: 811/1645 (49.3%), Model: 2.120MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.040413142592837285']
# ['At iteration 1 the best fitness is 0.035006938020351576']
# ['At iteration 2 the best fitness is 0.035341284524910845']
# ['At iteration 3 the best fitness is 0.03503733315712969']
# ['At iteration 4 the best fitness is 0.029752709131756334']
# ['At iteration 5 the best fitness is 0.04053472313994975']
# ['At iteration 6 the best fitness is 0.04108183560195583']
# ['At iteration 7 the best fitness is 0.03567563102947011']
# ['At iteration 8 the best fitness is 0.035645235892691994']
# ['At iteration 9 the best fitness is 0.03600997753402939']
# ['At iteration 10 the best fitness is 0.030421402140874878']
# ['At iteration 11 the best fitness is 0.03552365534557954']
# ['At iteration 12 the best fitness is 0.03552365534557954']
# ['At iteration 13 the best fitness is 0.03561484075591389']
# ['At iteration 14 the best fitness is 0.03561484075591389']
# ['At iteration 15 the best fitness is 0.03561484075591389']
# ['At iteration 16 the best fitness is 0.030360611867318643']
# ['At iteration 17 the best fitness is 0.03543246993524519']
# ['At iteration 18 the best fitness is 0.03543246993524519']
# ['At iteration 19 the best fitness is 0.035402074798467076']
# ['At iteration 20 the best fitness is 0.035402074798467076']
# ['At iteration 21 the best fitness is 0.035402074798467076']
# ['At iteration 22 the best fitness is 0.035402074798467076']
# ['At iteration 23 the best fitness is 0.035402074798467076']
# ['At iteration 24 the best fitness is 0.035402074798467076']
# ['At iteration 25 the best fitness is 0.035402074798467076']
# ['At iteration 26 the best fitness is 0.030239031320206184']
# ['At iteration 27 the best fitness is 0.035402074798467076']
# ['At iteration 28 the best fitness is 0.035402074798467076']
# ['At iteration 29 the best fitness is 0.035402074798467076']
#       Selected: 835/1645 (50.8%), Fitness: 0.0354, Time: 647.2s
#       Modality: Sk=51%
#     Test Acc: 85.89%, F1: 86.29%, Features: 835/1645 (50.8%), Model: 2.167MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.04059551341350598
# At iteration 2 the best fitness is 0.03549326020880142
# At iteration 3 the best fitness is 0.040352352319281054
# At iteration 4 the best fitness is 0.03549326020880142
# At iteration 5 the best fitness is 0.03546286507202331
# At iteration 6 the best fitness is 0.030299821593762412
# At iteration 7 the best fitness is 0.03546286507202331
# At iteration 8 the best fitness is 0.03546286507202331
# At iteration 9 the best fitness is 0.034915752610017226
# At iteration 10 the best fitness is 0.034915752610017226
# At iteration 11 the best fitness is 0.035645235892691994
# At iteration 12 the best fitness is 0.03528049425135461
# At iteration 13 the best fitness is 0.03610116294436373
# At iteration 14 the best fitness is 0.035006938020351576
# At iteration 15 the best fitness is 0.03528049425135461
# At iteration 16 the best fitness is 0.03549326020880142
# At iteration 17 the best fitness is 0.03503733315712969
# At iteration 18 the best fitness is 0.035006938020351576
# At iteration 19 the best fitness is 0.03506772829390781
# At iteration 20 the best fitness is 0.03473338178934853
# At iteration 21 the best fitness is 0.0352500991145765
# At iteration 22 the best fitness is 0.03506772829390781
# At iteration 23 the best fitness is 0.03567563102947011
# At iteration 24 the best fitness is 0.03552365534557954
# At iteration 25 the best fitness is 0.035736421303026344
# At iteration 26 the best fitness is 0.03470298665257042
# At iteration 27 the best fitness is 0.034368640148011144
# At iteration 28 the best fitness is 0.034915752610017226
# At iteration 29 the best fitness is 0.03470298665257042
# At iteration 30 the best fitness is 0.03458140610545796
#       Selected: 801/1645 (48.7%), Fitness: 0.0346, Time: 647.5s
#       Modality: Sk=49%
#     Test Acc: 85.48%, F1: 85.59%, Features: 801/1645 (48.7%), Model: 2.101MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03637471917536677']
# ['At iteration 1 the best fitness is 0.03637471917536677']
# ['At iteration 2 the best fitness is 0.034459825558345494']
# ['At iteration 3 the best fitness is 0.03315283467688653']
# ['At iteration 4 the best fitness is 0.03233216598387741']
# ['At iteration 5 the best fitness is 0.031450707017312056']
# ['At iteration 6 the best fitness is 0.031450707017312056']
# ['At iteration 7 the best fitness is 0.03138991674375583']
# ['At iteration 8 the best fitness is 0.030265296682965556']
# ['At iteration 9 the best fitness is 0.030265296682965556']
# ['At iteration 10 the best fitness is 0.030265296682965556']
# ['At iteration 11 the best fitness is 0.030265296682965556']
# ['At iteration 12 the best fitness is 0.030265296682965556']
# ['At iteration 13 the best fitness is 0.030265296682965556']
# ['At iteration 14 the best fitness is 0.029809369631293825']
# ['At iteration 15 the best fitness is 0.02962699881062513']
# ['At iteration 16 the best fitness is 0.02962699881062513']
# ['At iteration 17 the best fitness is 0.029383837716400206']
# ['At iteration 18 the best fitness is 0.029231862032509624']
# ['At iteration 19 the best fitness is 0.029231862032509624']
# ['At iteration 20 the best fitness is 0.029049491211840937']
# ['At iteration 21 the best fitness is 0.028775934980837893']
# ['At iteration 22 the best fitness is 0.028563169023391087']
# ['At iteration 23 the best fitness is 0.028563169023391087']
# ['At iteration 24 the best fitness is 0.028563169023391087']
# ['At iteration 25 the best fitness is 0.02343052068190831']
# ['At iteration 26 the best fitness is 0.02343052068190831']
# ['At iteration 27 the best fitness is 0.02343052068190831']
# ['At iteration 28 the best fitness is 0.02343052068190831']
# ['At iteration 29 the best fitness is 0.02343052068190831']
#       Selected: 637/1645 (38.7%), Fitness: 0.0234, Time: 649.2s
#       Modality: Sk=39%
#     Test Acc: 85.89%, F1: 85.85%, Features: 637/1645 (38.7%), Model: 1.780MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.035402074798467076']
# ['At iteration 1 the best fitness is 0.035402074798467076']
# ['At iteration 2 the best fitness is 0.03244548698295228']
# ['At iteration 3 the best fitness is 0.03244548698295228']
# ['At iteration 4 the best fitness is 0.03244548698295228']
# ['At iteration 5 the best fitness is 0.030287432271706077']
# ['At iteration 6 the best fitness is 0.030287432271706077']
# ['At iteration 7 the best fitness is 0.026704935905907192']
# ['At iteration 8 the best fitness is 0.026704935905907192']
# ['At iteration 9 the best fitness is 0.026704935905907192']
# ['At iteration 10 the best fitness is 0.026704935905907192']
# ['At iteration 11 the best fitness is 0.025949187260473155']
# ['At iteration 12 the best fitness is 0.025949187260473155']
# ['At iteration 13 the best fitness is 0.025949187260473155']
# ['At iteration 14 the best fitness is 0.025949187260473155']
# ['At iteration 15 the best fitness is 0.025949187260473155']
# ['At iteration 16 the best fitness is 0.025949187260473155']
# ['At iteration 17 the best fitness is 0.025949187260473155']
# ['At iteration 18 the best fitness is 0.025949187260473155']
# ['At iteration 19 the best fitness is 0.025949187260473155']
# ['At iteration 20 the best fitness is 0.025949187260473155']
# ['At iteration 21 the best fitness is 0.025949187260473155']
# ['At iteration 22 the best fitness is 0.025949187260473155']
# ['At iteration 23 the best fitness is 0.025949187260473155']
# ['At iteration 24 the best fitness is 0.025949187260473155']
# ['At iteration 25 the best fitness is 0.025949187260473155']
# ['At iteration 26 the best fitness is 0.025949187260473155']
# ['At iteration 27 the best fitness is 0.025949187260473155']
# ['At iteration 28 the best fitness is 0.025949187260473155']
# ['At iteration 29 the best fitness is 0.025949187260473155']
#       Selected: 540/1645 (32.8%), Fitness: 0.0259, Time: 888.2s
#       Modality: Sk=33%
#     Test Acc: 82.99%, F1: 83.26%, Features: 540/1645 (32.8%), Model: 1.591MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03458140610545796']
# ['At iteration 1 the best fitness is 0.03458140610545796']
# ['At iteration 2 the best fitness is 0.03458140610545796']
# ['At iteration 3 the best fitness is 0.03458140610545796']
# ['At iteration 4 the best fitness is 0.03458140610545796']
# ['At iteration 5 the best fitness is 0.03458140610545796']
# ['At iteration 6 the best fitness is 0.03458140610545796']
# ['At iteration 7 the best fitness is 0.03418626932734246']
# ['At iteration 8 the best fitness is 0.03418626932734246']
# ['At iteration 9 the best fitness is 0.03418626932734246']
# ['At iteration 10 the best fitness is 0.03418626932734246']
# ['At iteration 11 the best fitness is 0.03418626932734246']
# ['At iteration 12 the best fitness is 0.03418626932734246']
# ['At iteration 13 the best fitness is 0.03418626932734246']
# ['At iteration 14 the best fitness is 0.03415587419056434']
# ['At iteration 15 the best fitness is 0.03415587419056434']
# ['At iteration 16 the best fitness is 0.03415587419056434']
# ['At iteration 17 the best fitness is 0.03415587419056434']
# ['At iteration 18 the best fitness is 0.03415587419056434']
# ['At iteration 19 the best fitness is 0.03415587419056434']
# ['At iteration 20 the best fitness is 0.02911441125941591']
# ['At iteration 21 the best fitness is 0.02911441125941591']
# ['At iteration 22 the best fitness is 0.02911441125941591']
# ['At iteration 23 the best fitness is 0.02911441125941591']
# ['At iteration 24 the best fitness is 0.02911441125941591']
# ['At iteration 25 the best fitness is 0.028901645301969103']
# ['At iteration 26 the best fitness is 0.028901645301969103']
# ['At iteration 27 the best fitness is 0.028901645301969103']
# ['At iteration 28 the best fitness is 0.028901645301969103']
# ['At iteration 29 the best fitness is 0.028901645301969103']
#       Selected: 789/1645 (48.0%), Fitness: 0.0289, Time: 673.0s
#       Modality: Sk=48%
#     Test Acc: 89.21%, F1: 89.36%, Features: 789/1645 (48.0%), Model: 2.077MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04432998546319544']
# ['At iteration 2 the best fitness is 0.03974444958371874']
# ['At iteration 3 the best fitness is 0.03974444958371874']
# ['At iteration 4 the best fitness is 0.03974444958371874']
# ['At iteration 5 the best fitness is 0.03974444958371874']
# ['At iteration 6 the best fitness is 0.03974444958371874']
# ['At iteration 7 the best fitness is 0.03461180124223607']
# ['At iteration 8 the best fitness is 0.03461180124223607']
# ['At iteration 9 the best fitness is 0.03461180124223607']
# ['At iteration 10 the best fitness is 0.03461180124223607']
# ['At iteration 11 the best fitness is 0.03461180124223607']
# ['At iteration 12 the best fitness is 0.03461180124223607']
# ['At iteration 13 the best fitness is 0.03461180124223607']
# ['At iteration 14 the best fitness is 0.03461180124223607']
# ['At iteration 15 the best fitness is 0.030634168098321684']
# ['At iteration 16 the best fitness is 0.030634168098321684']
# ['At iteration 17 the best fitness is 0.030634168098321684']
# ['At iteration 18 the best fitness is 0.030634168098321684']
# ['At iteration 19 the best fitness is 0.030634168098321684']
# ['At iteration 20 the best fitness is 0.030634168098321684']
# ['At iteration 21 the best fitness is 0.030634168098321684']
# ['At iteration 22 the best fitness is 0.030634168098321684']
# ['At iteration 23 the best fitness is 0.030634168098321684']
# ['At iteration 24 the best fitness is 0.030634168098321684']
# ['At iteration 25 the best fitness is 0.030634168098321684']
# ['At iteration 26 the best fitness is 0.030634168098321684']
# ['At iteration 27 the best fitness is 0.030634168098321684']
# ['At iteration 28 the best fitness is 0.030634168098321684']
# ['At iteration 29 the best fitness is 0.030634168098321684']
#       Selected: 830/1645 (50.5%), Fitness: 0.0306, Time: 627.8s
#       Modality: Sk=50%
#     Test Acc: 83.40%, F1: 83.15%, Features: 830/1645 (50.5%), Model: 2.157MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.040504328003171636']
# ['At iteration 2 the best fitness is 0.039987610677943666']
# ['At iteration 3 the best fitness is 0.03464219637901419']
# ['At iteration 4 the best fitness is 0.03464219637901419']
# ['At iteration 5 the best fitness is 0.034459825558345494']
# ['At iteration 6 the best fitness is 0.034125479053786226']
# ['At iteration 7 the best fitness is 0.034125479053786226']
# ['At iteration 8 the best fitness is 0.034125479053786226']
# ['At iteration 9 the best fitness is 0.03385192282278319']
# ['At iteration 10 the best fitness is 0.03385192282278319']
# ['At iteration 11 the best fitness is 0.03385192282278319']
# ['At iteration 12 the best fitness is 0.03385192282278319']
# ['At iteration 13 the best fitness is 0.03385192282278319']
# ['At iteration 14 the best fitness is 0.03382152768600507']
# ['At iteration 15 the best fitness is 0.03382152768600507']
# ['At iteration 16 the best fitness is 0.03354797145500203']
# ['At iteration 17 the best fitness is 0.03354797145500203']
# ['At iteration 18 the best fitness is 0.03354797145500203']
# ['At iteration 19 the best fitness is 0.03354797145500203']
# ['At iteration 20 the best fitness is 0.03345678604466768']
# ...
# ['At iteration 13 the best fitness is 0.02014851095327342']
# ['At iteration 14 the best fitness is 0.02014851095327342']
# ['At iteration 15 the best fitness is 0.02014851095327342']
# ['At iteration 16 the best fitness is 0.02014851095327342']
# ['At iteration 17 the best fitness is 0.0201181158164953']
# ['At iteration 18 the best fitness is 0.0201181158164953']
# ['At iteration 19 the best fitness is 0.0201181158164953']
# ['At iteration 20 the best fitness is 0.0201181158164953']
# ['At iteration 21 the best fitness is 0.0201181158164953']
# ['At iteration 22 the best fitness is 0.02005732554293907']
# ['At iteration 23 the best fitness is 0.020026930406160957']
# ['At iteration 24 the best fitness is 0.020026930406160957']
# ['At iteration 25 the best fitness is 0.020026930406160957']
# ['At iteration 26 the best fitness is 0.020026930406160957']
# ['At iteration 27 the best fitness is 0.01695702159157129']
# ['At iteration 28 the best fitness is 0.01695702159157129']
# ['At iteration 29 the best fitness is 0.01695702159157129']
#       Selected: 356/1645 (21.6%), Fitness: 0.0170, Time: 965.3s
#       Modality: Sk=22%
#     Test Acc: 85.86%, F1: 84.83%, Features: 356/1645 (21.6%), Model: 1.232MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.034039088460872204']
# ['At iteration 1 the best fitness is 0.034039088460872204']
# ['At iteration 2 the best fitness is 0.034039088460872204']
# ['At iteration 3 the best fitness is 0.034039088460872204']
# ['At iteration 4 the best fitness is 0.034039088460872204']
# ['At iteration 5 the best fitness is 0.03397829818731597']
# ['At iteration 6 the best fitness is 0.03397829818731597']
# ['At iteration 7 the best fitness is 0.0291775989416823']
# ['At iteration 8 the best fitness is 0.0291775989416823']
# ['At iteration 9 the best fitness is 0.0291775989416823']
# ['At iteration 10 the best fitness is 0.0291775989416823']
# ['At iteration 11 the best fitness is 0.0291775989416823']
# ['At iteration 12 the best fitness is 0.0291775989416823']
# ['At iteration 13 the best fitness is 0.0291775989416823']
# ['At iteration 14 the best fitness is 0.0291775989416823']
# ['At iteration 15 the best fitness is 0.0291775989416823']
# ['At iteration 16 the best fitness is 0.0291775989416823']
# ['At iteration 17 the best fitness is 0.0291775989416823']
# ['At iteration 18 the best fitness is 0.0291775989416823']
# ['At iteration 19 the best fitness is 0.0291775989416823']
# ['At iteration 20 the best fitness is 0.0291775989416823']
# ['At iteration 21 the best fitness is 0.0291775989416823']
# ['At iteration 22 the best fitness is 0.0291775989416823']
# ['At iteration 23 the best fitness is 0.0291775989416823']
# ['At iteration 24 the best fitness is 0.0291775989416823']
# ['At iteration 25 the best fitness is 0.0291775989416823']
# ['At iteration 26 the best fitness is 0.0291775989416823']
# ['At iteration 27 the best fitness is 0.0291775989416823']
# ['At iteration 28 the best fitness is 0.0291775989416823']
# ['At iteration 29 the best fitness is 0.0291775989416823']
#       Selected: 806/1645 (49.0%), Fitness: 0.0292, Time: 713.1s
#       Modality: Sk=49%
#     Test Acc: 93.43%, F1: 93.37%, Features: 806/1645 (49.0%), Model: 2.110MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04026835913507731']
# ['At iteration 2 the best fitness is 0.03644030426634333']
# ['At iteration 3 the best fitness is 0.03644030426634333']
# ['At iteration 4 the best fitness is 0.03644030426634333']
# ['At iteration 5 the best fitness is 0.03644030426634333']
# ['At iteration 6 the best fitness is 0.03644030426634333']
# ['At iteration 7 the best fitness is 0.034586200922878285']
# ['At iteration 8 the best fitness is 0.034586200922878285']
# ['At iteration 9 the best fitness is 0.034586200922878285']
# ['At iteration 10 the best fitness is 0.034586200922878285']
# ['At iteration 11 the best fitness is 0.034586200922878285']
# ['At iteration 12 the best fitness is 0.034586200922878285']
# ['At iteration 13 the best fitness is 0.034586200922878285']
# ['At iteration 14 the best fitness is 0.034586200922878285']
# ['At iteration 15 the best fitness is 0.034586200922878285']
# ['At iteration 16 the best fitness is 0.034586200922878285']
# ['At iteration 17 the best fitness is 0.034586200922878285']
# ['At iteration 18 the best fitness is 0.034586200922878285']
# ['At iteration 19 the best fitness is 0.034586200922878285']
# ['At iteration 20 the best fitness is 0.034586200922878285']
# ['At iteration 21 the best fitness is 0.034586200922878285']
# ['At iteration 22 the best fitness is 0.03385671764020351']
# ['At iteration 23 the best fitness is 0.03385671764020351']
# ['At iteration 24 the best fitness is 0.03385671764020351']
# ['At iteration 25 the best fitness is 0.03385671764020351']
# ['At iteration 26 the best fitness is 0.03385671764020351']
# ['At iteration 27 the best fitness is 0.03379592736664728']
# ['At iteration 28 the best fitness is 0.03379592736664728']
# ['At iteration 29 the best fitness is 0.03379592736664728']
#       Selected: 806/1645 (49.0%), Fitness: 0.0338, Time: 665.4s
#       Modality: Sk=49%
#     Test Acc: 96.97%, F1: 96.97%, Features: 806/1645 (49.0%), Model: 2.110MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.044947477833598405']
# ['At iteration 2 the best fitness is 0.03574121612044667']
# ['At iteration 3 the best fitness is 0.034950942564215666']
# ['At iteration 4 the best fitness is 0.034950942564215666']
# ['At iteration 5 the best fitness is 0.034950942564215666']
# ['At iteration 6 the best fitness is 0.03473817660676886']
# ['At iteration 7 the best fitness is 0.03437343496543147']
# ['At iteration 8 the best fitness is 0.03434303982865336']
# ['At iteration 9 the best fitness is 0.03434303982865336']
# ['At iteration 10 the best fitness is 0.03434303982865336']
# ['At iteration 11 the best fitness is 0.0342214592815409']
# ['At iteration 12 the best fitness is 0.0342214592815409']
# ['At iteration 13 the best fitness is 0.034039088460872204']
# ['At iteration 14 the best fitness is 0.034039088460872204']
# ['At iteration 15 the best fitness is 0.03391750791375974']
# ['At iteration 16 the best fitness is 0.03391750791375974']
# ['At iteration 17 the best fitness is 0.03385671764020351']
# ['At iteration 18 the best fitness is 0.03385671764020351']
# ['At iteration 19 the best fitness is 0.03385671764020351']
# ['At iteration 20 the best fitness is 0.0338263225034254']
# ['At iteration 21 the best fitness is 0.033613556545978585']
# ['At iteration 22 the best fitness is 0.03343118572530989']
# ['At iteration 23 the best fitness is 0.03343118572530989']
# ['At iteration 24 the best fitness is 0.03343118572530989']
# ['At iteration 25 the best fitness is 0.03343118572530989']
# ['At iteration 26 the best fitness is 0.03334000031497555']
# ['At iteration 27 the best fitness is 0.03334000031497555']
# ['At iteration 28 the best fitness is 0.033188024631084966']
# ['At iteration 29 the best fitness is 0.033188024631084966']
# ['At iteration 30 the best fitness is 0.033188024631084966']
#       Selected: 794/1645 (48.3%), Fitness: 0.0332, Time: 692.1s
#       Modality: Sk=48%
#     Test Acc: 92.42%, F1: 92.10%, Features: 794/1645 (48.3%), Model: 2.087MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04418759941414552']
# ['At iteration 2 the best fitness is 0.04418759941414552']
# ['At iteration 3 the best fitness is 0.03437343496543147']
# ['At iteration 4 the best fitness is 0.03437343496543147']
# ['At iteration 5 the best fitness is 0.03406948359765032']
# ['At iteration 6 the best fitness is 0.03358316140920047']
# ['At iteration 7 the best fitness is 0.03355276627242235']
# ['At iteration 8 the best fitness is 0.03346158086208801']
# ['At iteration 9 the best fitness is 0.03346158086208801']
# ['At iteration 10 the best fitness is 0.033279210041419316']
# ['At iteration 11 the best fitness is 0.033279210041419316']
# ['At iteration 12 the best fitness is 0.033218419767863085']
# ['At iteration 13 the best fitness is 0.03303604894719439']
# ['At iteration 14 the best fitness is 0.03303604894719439']
# ['At iteration 15 the best fitness is 0.03303604894719439']
# ['At iteration 16 the best fitness is 0.0328536781265257']
# ['At iteration 17 the best fitness is 0.032823282989747585']
# ['At iteration 18 the best fitness is 0.032823282989747585']
# ['At iteration 19 the best fitness is 0.03267130730585701']
# ['At iteration 20 the best fitness is 0.03267130730585701']
# ['At iteration 21 the best fitness is 0.03267130730585701']
# ['At iteration 22 the best fitness is 0.03267130730585701']
# ['At iteration 23 the best fitness is 0.03248893648518831']
# ['At iteration 24 the best fitness is 0.03248893648518831']
# ['At iteration 25 the best fitness is 0.03248893648518831']
# ['At iteration 26 the best fitness is 0.03248893648518831']
# ['At iteration 27 the best fitness is 0.032428146211632085']
# ['At iteration 28 the best fitness is 0.032428146211632085']
# ['At iteration 29 the best fitness is 0.032428146211632085']
# ['At iteration 30 the best fitness is 0.032397751074853966']
#       Selected: 753/1645 (45.8%), Fitness: 0.0324, Time: 690.2s
#       Modality: Sk=46%
#     Test Acc: 92.93%, F1: 92.83%, Features: 753/1645 (45.8%), Model: 2.007MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.044005228593476824']
# ['At iteration 1 the best fitness is 0.042789423122352205']
# ['At iteration 2 the best fitness is 0.031607477518622966']
# ['At iteration 3 the best fitness is 0.031607477518622966']
# ['At iteration 4 the best fitness is 0.02905428602926126']
# ['At iteration 5 the best fitness is 0.027960061105249102']
# ['At iteration 6 the best fitness is 0.026014772351449715']
# ['At iteration 7 the best fitness is 0.026014772351449715']
# ['At iteration 8 the best fitness is 0.026014772351449715']
# ['At iteration 9 the best fitness is 0.026014772351449715']
# ['At iteration 10 the best fitness is 0.026014772351449715']
# ['At iteration 11 the best fitness is 0.026014772351449715']
# ['At iteration 12 the best fitness is 0.025800274028694323']
# ['At iteration 13 the best fitness is 0.025800274028694323']
# ['At iteration 14 the best fitness is 0.025587508071247513']
# ['At iteration 15 the best fitness is 0.025587508071247513']
# ['At iteration 16 the best fitness is 0.025587508071247513']
# ['At iteration 17 the best fitness is 0.025587508071247513']
# ['At iteration 18 the best fitness is 0.025587508071247513']
# ['At iteration 19 the best fitness is 0.02303431658188581']
# ['At iteration 20 the best fitness is 0.02303431658188581']
# ['At iteration 21 the best fitness is 0.02303431658188581']
# ['At iteration 22 the best fitness is 0.02303431658188581']
# ['At iteration 23 the best fitness is 0.02303431658188581']
# ['At iteration 24 the best fitness is 0.02303431658188581']
# ['At iteration 25 the best fitness is 0.02303431658188581']
# ['At iteration 26 the best fitness is 0.02269997007732654']
# ['At iteration 27 the best fitness is 0.02269997007732654']
# ['At iteration 28 the best fitness is 0.02269997007732654']
# ['At iteration 29 the best fitness is 0.022517599256657847']
#       Selected: 295/1645 (17.9%), Fitness: 0.0225, Time: 729.3s
#       Modality: Sk=18%
#     Test Acc: 88.89%, F1: 88.41%, Features: 295/1645 (17.9%), Model: 1.112MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.033765532229869166']
# ['At iteration 2 the best fitness is 0.033765532229869166']
# ['At iteration 3 the best fitness is 0.033765532229869166']
# ['At iteration 4 the best fitness is 0.033765532229869166']
# ['At iteration 5 the best fitness is 0.033765532229869166']
# ['At iteration 6 the best fitness is 0.033765532229869166']
# ['At iteration 7 the best fitness is 0.033704741956312935']
# ['At iteration 8 the best fitness is 0.03291446840008193']
# ['At iteration 9 the best fitness is 0.03291446840008193']
# ['At iteration 10 the best fitness is 0.0328536781265257']
# ['At iteration 11 the best fitness is 0.0328536781265257']
# ['At iteration 12 the best fitness is 0.0328536781265257']
# ['At iteration 13 the best fitness is 0.03270170244263512']
# ['At iteration 14 the best fitness is 0.03270170244263512']
# ['At iteration 15 the best fitness is 0.03264091216907889']
# ['At iteration 16 the best fitness is 0.03264091216907889']
# ['At iteration 17 the best fitness is 0.03264091216907889']
# ['At iteration 18 the best fitness is 0.03264091216907889']
# ['At iteration 19 the best fitness is 0.03264091216907889']
# ['At iteration 20 the best fitness is 0.03264091216907889']
# ['At iteration 21 the best fitness is 0.03264091216907889']
# ['At iteration 22 the best fitness is 0.03264091216907889']
# ['At iteration 23 the best fitness is 0.03264091216907889']
# ['At iteration 24 the best fitness is 0.03264091216907889']
# ['At iteration 25 the best fitness is 0.03264091216907889']
# ['At iteration 26 the best fitness is 0.03264091216907889']
# ['At iteration 27 the best fitness is 0.03264091216907889']
# ['At iteration 28 the best fitness is 0.03264091216907889']
# ['At iteration 29 the best fitness is 0.03264091216907889']
#       Selected: 757/1645 (46.0%), Fitness: 0.0326, Time: 1725.4s
#       Modality: Sk=46%
#     Test Acc: 94.44%, F1: 94.35%, Features: 757/1645 (46.0%), Model: 2.015MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04075468132352715']
# ['At iteration 1 the best fitness is 0.03084413436855281']
# ['At iteration 2 the best fitness is 0.03084413436855281']
# ['At iteration 3 the best fitness is 0.029782036946627455']
# ['At iteration 4 the best fitness is 0.02649936217459098']
# ['At iteration 5 the best fitness is 0.02649936217459098']
# ['At iteration 6 the best fitness is 0.026438571901034748']
# ['At iteration 7 the best fitness is 0.024979605335685204']
# ['At iteration 8 the best fitness is 0.020726018552057614']
# ['At iteration 9 the best fitness is 0.020726018552057614']
# ['At iteration 10 the best fitness is 0.020726018552057614']
# ['At iteration 11 the best fitness is 0.020726018552057614']
# ['At iteration 12 the best fitness is 0.020726018552057614']
# ['At iteration 13 the best fitness is 0.020726018552057614']
# ['At iteration 14 the best fitness is 0.020726018552057614']
# ['At iteration 15 the best fitness is 0.020726018552057614']
# ['At iteration 16 the best fitness is 0.020726018552057614']
# ['At iteration 17 the best fitness is 0.020726018552057614']
# ['At iteration 18 the best fitness is 0.020726018552057614']
# ['At iteration 19 the best fitness is 0.020726018552057614']
# ['At iteration 20 the best fitness is 0.020726018552057614']
# ['At iteration 21 the best fitness is 0.020726018552057614']
# ['At iteration 22 the best fitness is 0.020726018552057614']
# ['At iteration 23 the best fitness is 0.020726018552057614']
# ['At iteration 24 the best fitness is 0.020726018552057614']
# ['At iteration 25 the best fitness is 0.020726018552057614']
# ['At iteration 26 the best fitness is 0.020361276910720226']
# ['At iteration 27 the best fitness is 0.020361276910720226']
# ['At iteration 28 the best fitness is 0.020361276910720226']
# ['At iteration 29 the best fitness is 0.020361276910720226']
#       Selected: 406/1645 (24.7%), Fitness: 0.0204, Time: 695.2s
#       Modality: Sk=25%
#     Test Acc: 87.37%, F1: 87.00%, Features: 406/1645 (24.7%), Model: 1.329MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_skeleton_new/all_results_per_fold.csv
# Shape: (90, 22)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  skeleton_retention (%)  skeleton_selected
# 0      baseline     1            95.8042           98.8571       95.8342          95.8342              96.4548           95.8042               1645            1645               100.0000       0.0000         10.0551         10.0551        981270           3.7491                14.6212                 14.6212                 0.0000        40.4683                100.0000               1645
# 1      baseline     2            86.7220           98.3696       86.5927          86.5589              90.7601           86.7355               1645            1645               100.0000       0.0000         11.2229         11.2229        981270           3.7491                14.6212                 14.6212                 0.0000        40.4683                100.0000               1645
# 2      baseline     3            98.1818           98.9418       98.1969          98.1969              98.4160           98.1818               1645            1645               100.0000       0.0000         11.2557         11.2557        981270           3.7491                14.6212                 14.6212                 0.0000        40.4683                100.0000               1645
# 3      baseline     4            96.3636           97.3545       96.2617          96.2617              96.9153           96.3636               1645            1645               100.0000       0.0000         11.2195         11.2196        981270           3.7491                14.6212                 14.6212                 0.0000        40.4683                100.0000               1645
# 4      baseline     5            90.9091           98.9637       90.8945          90.8945              92.5224           90.9091               1645            1645               100.0000       0.0000         11.8997         11.8997        981270           3.7491                14.6212                 14.6212                 0.0000        40.4683                100.0000               1645
# 5   mutual_info     1            96.5035           98.8571       96.4541          96.4541              96.8784           96.5035                822            1645                49.9696       8.0773          9.4488         17.5262        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 6   mutual_info     2            87.1369           99.4565       87.3066          87.2758              91.3069           87.1488                822            1645                49.9696       8.0582          9.9160         17.9743        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 7   mutual_info     3            97.2727           98.4127       97.2436          97.2436              97.6240           97.2727                822            1645                49.9696       8.0433         10.0010         18.0444        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 8   mutual_info     4            93.6364           96.8254       93.3938          93.3938              95.1045           93.6364                822            1645                49.9696       8.0230          9.9961         18.0192        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 9   mutual_info     5            92.9293           98.4456       92.6738          92.6738              93.3489           92.9293                822            1645                49.9696       7.9946         10.6049         18.5996        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 10          rfe     1            98.6014           98.8571       98.6004          98.6004              98.6513           98.6014                822            1645                49.9696       1.5644          9.4640         11.0286        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 11          rfe     2            87.1369           98.9130       87.6280          87.5985              91.1007           87.1488                822            1645                49.9696       1.5605         10.0954         11.6563        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 12          rfe     3            95.9091           98.9418       95.7727          95.7727              96.9008           95.9091                822            1645                49.9696       1.5969         10.0712         11.6683        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 13          rfe     4            96.8182           96.8254       96.8019          96.8019              97.3670           96.8182                822            1645                49.9696       1.6132         10.0596         11.6730        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 14          rfe     5            91.9192           98.9637       91.6229          91.6229              93.6774           91.9192                822            1645                49.9696       1.6024         10.6984         12.3010        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 15        lasso     1            93.7063           98.8571       93.5620          93.5620              93.9289           93.7063                822            1645                49.9696       0.2160          9.4866          9.7027        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 16        lasso     2            82.9876           97.2826       83.2528          83.2051              87.6673           83.0165                822            1645                49.9696       0.2425         10.0890         10.3316        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 17        lasso     3            96.8182           97.3545       96.7454          96.7454              97.1763           96.8182                822            1645                49.9696       0.2726         10.2839         10.5566        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 18        lasso     4            89.5455           97.3545       89.5943          89.5943              91.4469           89.5455                822            1645                49.9696       0.2662         10.2055         10.4718        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822
# 19        lasso     5            90.4040           97.9275       90.2643          90.2643              92.1932           90.4040                822            1645                49.9696       0.2718         10.8495         11.1214        559894           2.1417                14.6212                  7.3061                50.0304        30.7251                 49.9696                822

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              93.60              4.69              93.56              4.73                  1645.0                      100.00              0.00                11.13                11.13           981270.0                  3.75                        0.00               40.47
# mutual_info              93.50              4.00              93.41              3.93                   822.0                       49.97              8.04                 9.99                18.03           559894.0                  2.14                       50.03               30.73
#         rfe              94.08              4.59              94.09              4.43                   822.0                       49.97              1.59                10.08                11.67           559894.0                  2.14                       50.03               30.73
#       lasso              90.69              5.18              90.68              5.04                   822.0                       49.97              0.25                10.18                10.44           559894.0                  2.14                       50.03               30.73
#    meta_BAT              92.92              3.18              92.84              3.09                   803.4                       48.84            672.69                10.15               682.84           550370.8                  2.11                       51.16               30.59
#     meta_CS              90.94              3.44              90.78              3.28                   788.6                       47.94           1318.51                10.15              1328.66           542793.2                  2.08                       52.06               30.46
#     meta_DE              91.25              4.08              90.93              4.21                   792.0                       48.15            668.84                10.17               679.01           544534.0                  2.08                       51.85               30.49
#    meta_FFA              91.50              4.55              91.41              4.53                   802.8                       48.80            648.50                10.17               658.67           550063.6                  2.10                       51.20               30.62
#     meta_GA              92.20              5.11              92.10              5.11                   803.8                       48.86            648.68                10.13               658.82           550575.6                  2.11                       51.14               30.58
#    meta_GWO              91.68              3.87              91.56              3.86                   624.8                       37.98            655.28                10.06               665.34           458927.6                  1.76                       62.02               28.95
#    meta_HHO              88.76              4.36              88.42              4.31                   471.6                       28.67            883.63                10.76               894.39           380489.2                  1.46                       71.33               26.65
#   meta_JAYA              93.19              2.64              93.11              2.56                   794.6                       48.30            668.35                10.13               678.48           545865.2                  2.09                       51.70               30.51
#    meta_MFO              92.80              5.62              92.69              5.71                   811.8                       49.35            626.14                10.20               636.34           554671.6                  2.12                       50.65               30.65
#    meta_MVO              92.82              4.63              92.70              4.54                   793.2                       48.22            650.58                10.20               660.79           545148.4                  2.09                       51.78               30.50
#    meta_PSO              90.83              6.03              90.80              6.01                   779.6                       47.39            650.25                10.13               660.38           538185.2                  2.06                       52.61               30.39
#    meta_SCA              90.91              3.46              90.74              3.53                   359.0                       21.82            684.96                11.86               696.83           322838.0                  1.24                       78.18               25.24
#    meta_SSA              91.97              4.87              91.98              4.56                   787.8                       47.89           1613.79                10.17              1623.96           542383.6                  2.07                       52.11               30.45
#    meta_WOA              89.45              4.45              89.24              4.44                   508.2                       30.89            645.75                10.73               656.49           399228.4                  1.53                       69.11               27.08

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 93.50% vs Baseline: 93.60%
#   Paired t-test: t=-0.1247, p=0.9068
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> worse, Not significant
#
# RFE vs BASELINE:
#   Method: 94.08% vs Baseline: 93.60%
#   Paired t-test: t=0.5911, p=0.5862
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 90.69% vs Baseline: 93.60%
#   Paired t-test: t=-2.6084, p=0.0595
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 92.92% vs Baseline: 93.60%
#   Paired t-test: t=-0.5958, p=0.5834
#   Wilcoxon test: W=6.0000, p=0.8125
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 90.94% vs Baseline: 93.60%
#   Paired t-test: t=-1.9120, p=0.1284
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 91.25% vs Baseline: 93.60%
#   Paired t-test: t=-1.9872, p=0.1178
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 91.50% vs Baseline: 93.60%
#   Paired t-test: t=-1.6203, p=0.1805
#   Wilcoxon test: W=2.0000, p=0.1875
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 92.20% vs Baseline: 93.60%
#   Paired t-test: t=-2.4958, p=0.0671
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 91.68% vs Baseline: 93.60%
#   Paired t-test: t=-2.1500, p=0.0980
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 88.76% vs Baseline: 93.60%
#   Paired t-test: t=-4.9510, p=0.0078
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_JAYA vs BASELINE:
#   Method: 93.19% vs Baseline: 93.60%
#   Paired t-test: t=-0.2622, p=0.8061
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 92.80% vs Baseline: 93.60%
#   Paired t-test: t=-0.4287, p=0.6902
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 92.82% vs Baseline: 93.60%
#   Paired t-test: t=-1.0663, p=0.3464
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 90.83% vs Baseline: 93.60%
#   Paired t-test: t=-1.1836, p=0.3021
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 90.91% vs Baseline: 93.60%
#   Paired t-test: t=-2.4631, p=0.0695
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 91.97% vs Baseline: 93.60%
#   Paired t-test: t=-1.1225, p=0.3245
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 89.45% vs Baseline: 93.60%
#   Paired t-test: t=-6.8251, p=0.0024
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_skeleton_new
#
# Per-method folders:
#   results_skeleton_new/baseline/ (10 files)
#   results_skeleton_new/mutual_info/ (10 files)
#   results_skeleton_new/rfe/ (10 files)
#   results_skeleton_new/lasso/ (10 files)
#   results_skeleton_new/meta_BAT/ (10 files)
#   results_skeleton_new/meta_CS/ (10 files)
#   results_skeleton_new/meta_DE/ (10 files)
#   results_skeleton_new/meta_FFA/ (10 files)
#   results_skeleton_new/meta_GA/ (10 files)
#   results_skeleton_new/meta_GWO/ (10 files)
#   results_skeleton_new/meta_HHO/ (10 files)
#   results_skeleton_new/meta_JAYA/ (10 files)
#   results_skeleton_new/meta_MFO/ (10 files)
#   results_skeleton_new/meta_MVO/ (10 files)
#   results_skeleton_new/meta_PSO/ (10 files)
#   results_skeleton_new/meta_SCA/ (10 files)
#   results_skeleton_new/meta_SSA/ (10 files)
#   results_skeleton_new/meta_WOA/ (10 files)
#
# Plots directory: results_skeleton_new/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 94.08% ± 4.59% (Features: 50.0%)
#   baseline            : 93.60% ± 4.69% (Features: 100.0%)
#   mutual_info         : 93.50% ± 4.00% (Features: 50.0%)
#   meta_JAYA           : 93.19% ± 2.64% (Features: 48.3%)
#   meta_BAT            : 92.92% ± 3.18% (Features: 48.8%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_FFA
#     Test Accuracy:      97.20%
#     Feature Retention:  52.64% (866/1645)
#     Modality Retention: skeleton=52.6%
#
#   Fold 2: Best = meta_JAYA
#     Test Accuracy:      89.21%
#     Feature Retention:  47.96% (789/1645)
#     Modality Retention: skeleton=48.0%
#
#   Fold 3: Best = meta_MFO
#     Test Accuracy:      96.36%
#     Feature Retention:  47.23% (777/1645)
#     Modality Retention: skeleton=47.2%
#
#   Fold 4: Best = meta_GA
#     Test Accuracy:      95.91%
#     Feature Retention:  48.45% (797/1645)
#     Modality Retention: skeleton=48.4%
#
#   Fold 5: Best = meta_MFO
#     Test Accuracy:      96.97%
#     Feature Retention:  49.00% (806/1645)
#     Modality Retention: skeleton=49.0%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     95.13% ± 3.35%
#   Average Feature Retention: 49.06% ± 2.11%
#
#   Average Modality-wise Feature Retention:
#       skeleton: 49.06% ± 2.11%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  skeleton Retention (%)
#     1           meta_FFA              97.20                  52.64                   52.64
#     2          meta_JAYA              89.21                  47.96                   47.96
#     3           meta_MFO              96.36                  47.23                   47.23
#     4            meta_GA              95.91                  48.45                   48.45
#     5           meta_MFO              96.97                  49.00                   49.00
#
# Saved to: results_skeleton_new/best_metaheuristic_per_fold.csv
