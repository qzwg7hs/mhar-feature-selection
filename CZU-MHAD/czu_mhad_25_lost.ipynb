# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_25_loss")

# Master output directory
RESULTS_ROOT = Path("results_25_lost")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   depth: 37
#   sensor: 75
#   skeleton: 400
#   TOTAL: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 91.96%, F1: 91.69%, Features: 512/512 (100.0%), Model: 1.536MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 256/512 (50.0%), Time: 2.5s
#     Test Acc: 94.41%, F1: 94.27%, Features: 256/512 (50.0%), Model: 1.036MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 256/512 (50.0%), Time: 0.5s
#     Test Acc: 95.10%, F1: 95.04%, Features: 256/512 (50.0%), Model: 1.036MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 256/512 (50.0%), Time: 0.1s
#     Test Acc: 87.76%, F1: 87.37%, Features: 256/512 (50.0%), Model: 1.036MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07200167410714281']
# ['At iteration 1 the best fitness is 0.07200167410714281']
# ['At iteration 2 the best fitness is 0.07200167410714281']
# ['At iteration 3 the best fitness is 0.06637779017857143']
# ['At iteration 4 the best fitness is 0.06637779017857143']
# ['At iteration 5 the best fitness is 0.06637779017857143']
# ['At iteration 6 the best fitness is 0.062121093750000037']
# ['At iteration 7 the best fitness is 0.062121093750000037']
# ['At iteration 8 the best fitness is 0.062121093750000037']
# ['At iteration 9 the best fitness is 0.062121093750000037']
# ['At iteration 10 the best fitness is 0.062121093750000037']
# ['At iteration 11 the best fitness is 0.062121093750000037']
# ['At iteration 12 the best fitness is 0.062121093750000037']
# ['At iteration 13 the best fitness is 0.062023437500000035']
# ['At iteration 14 the best fitness is 0.062023437500000035']
# ['At iteration 15 the best fitness is 0.062023437500000035']
# ['At iteration 16 the best fitness is 0.062023437500000035']
# ['At iteration 17 the best fitness is 0.062023437500000035']
# ['At iteration 18 the best fitness is 0.062023437500000035']
# ['At iteration 19 the best fitness is 0.062023437500000035']
# ['At iteration 20 the best fitness is 0.062023437500000035']
# ['At iteration 21 the best fitness is 0.062023437500000035']
# ['At iteration 22 the best fitness is 0.062023437500000035']
# ['At iteration 23 the best fitness is 0.062023437500000035']
# ['At iteration 24 the best fitness is 0.062023437500000035']
# ['At iteration 25 the best fitness is 0.062023437500000035']
# ['At iteration 26 the best fitness is 0.062023437500000035']
# ['At iteration 27 the best fitness is 0.062023437500000035']
# ['At iteration 28 the best fitness is 0.062023437500000035']
# ['At iteration 29 the best fitness is 0.062023437500000035']
#       Selected: 256/512 (50.0%), Fitness: 0.0620, Time: 531.5s
#       Modality: D=51%, S=53%, Sk=49%
#     Test Acc: 93.71%, F1: 93.26%, Features: 256/512 (50.0%), Model: 1.036MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06173046875000003']
# ['At iteration 10 the best fitness is 0.05776674107142854']
# ['At iteration 20 the best fitness is 0.05561830357142854']
#       Selected: 237/512 (46.3%), Fitness: 0.0552, Time: 1045.4s
#       Modality: D=43%, S=57%, Sk=44%
#     Test Acc: 86.01%, F1: 85.08%, Features: 237/512 (46.3%), Model: 0.891MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06745200892857142']
# ['At iteration 2 the best fitness is 0.06745200892857142']
# ['At iteration 3 the best fitness is 0.06745200892857142']
# ['At iteration 4 the best fitness is 0.06251171875000003']
# ['At iteration 5 the best fitness is 0.05659486607142854']
# ['At iteration 6 the best fitness is 0.05659486607142854']
# ['At iteration 7 the best fitness is 0.05659486607142854']
# ['At iteration 8 the best fitness is 0.05659486607142854']
# ['At iteration 9 the best fitness is 0.05659486607142854']
# ['At iteration 10 the best fitness is 0.05659486607142854']
# ['At iteration 11 the best fitness is 0.05659486607142854']
# ['At iteration 12 the best fitness is 0.05659486607142854']
# ['At iteration 13 the best fitness is 0.05659486607142854']
# ['At iteration 14 the best fitness is 0.05659486607142854']
# ['At iteration 15 the best fitness is 0.05659486607142854']
# ['At iteration 16 the best fitness is 0.05659486607142854']
# ['At iteration 17 the best fitness is 0.05659486607142854']
# ['At iteration 18 the best fitness is 0.05659486607142854']
# ['At iteration 19 the best fitness is 0.05659486607142854']
# ['At iteration 20 the best fitness is 0.05659486607142854']
# ['At iteration 21 the best fitness is 0.05659486607142854']
# ['At iteration 22 the best fitness is 0.05659486607142854']
# ['At iteration 23 the best fitness is 0.05659486607142854']
# ['At iteration 24 the best fitness is 0.05659486607142854']
# ['At iteration 25 the best fitness is 0.05659486607142854']
# ['At iteration 26 the best fitness is 0.05659486607142854']
# ['At iteration 27 the best fitness is 0.05659486607142854']
# ['At iteration 28 the best fitness is 0.05659486607142854']
# ['At iteration 29 the best fitness is 0.05659486607142854']
# ['At iteration 30 the best fitness is 0.05659486607142854']
#       Selected: 243/512 (47.5%), Fitness: 0.0566, Time: 532.4s
#       Modality: D=43%, S=37%, Sk=50%
#     Test Acc: 90.21%, F1: 89.90%, Features: 243/512 (47.5%), Model: 0.935MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06745200892857142']
# ['At iteration 1 the best fitness is 0.061632812500000037']
# ['At iteration 2 the best fitness is 0.061144531250000037']
# ['At iteration 3 the best fitness is 0.061535156250000035']
# ['At iteration 4 the best fitness is 0.06231640625000004']
# ['At iteration 5 the best fitness is 0.056887834821428535']
# ['At iteration 6 the best fitness is 0.05669252232142854']
# ['At iteration 7 the best fitness is 0.05708314732142854']
# ['At iteration 8 the best fitness is 0.061046875000000035']
# ['At iteration 9 the best fitness is 0.06696372767857142']
# ['At iteration 10 the best fitness is 0.06647544642857142']
# ['At iteration 11 the best fitness is 0.06686607142857143']
# ['At iteration 12 the best fitness is 0.06124218750000003']
# ['At iteration 13 the best fitness is 0.06657310267857142']
# ['At iteration 14 the best fitness is 0.061144531250000037']
# ['At iteration 15 the best fitness is 0.061144531250000037']
# ['At iteration 16 the best fitness is 0.061144531250000037']
# ['At iteration 17 the best fitness is 0.06657310267857142']
# ['At iteration 18 the best fitness is 0.07200167410714281']
# ['At iteration 19 the best fitness is 0.05571595982142854']
# ['At iteration 20 the best fitness is 0.06657310267857142']
# ['At iteration 21 the best fitness is 0.061144531250000037']
# ['At iteration 22 the best fitness is 0.061144531250000037']
# ['At iteration 23 the best fitness is 0.06657310267857142']
# ['At iteration 24 the best fitness is 0.06657310267857142']
# ['At iteration 25 the best fitness is 0.05571595982142854']
# ['At iteration 26 the best fitness is 0.061144531250000037']
# ['At iteration 27 the best fitness is 0.06657310267857142']
# ['At iteration 28 the best fitness is 0.061144531250000037']
# ['At iteration 29 the best fitness is 0.06657310267857142']
#       Selected: 227/512 (44.3%), Fitness: 0.0666, Time: 512.1s
#       Modality: D=49%, S=51%, Sk=43%
#     Test Acc: 89.86%, F1: 89.45%, Features: 227/512 (44.3%), Model: 0.818MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.06872154017857142
# At iteration 2 the best fitness is 0.06881919642857143
# At iteration 3 the best fitness is 0.05854799107142854
# At iteration 4 the best fitness is 0.05854799107142854
# At iteration 5 the best fitness is 0.06290234375000003
# At iteration 6 the best fitness is 0.06290234375000003
# At iteration 7 the best fitness is 0.06280468750000004
# At iteration 8 the best fitness is 0.06833091517857143
# At iteration 9 the best fitness is 0.06706138392857142
# At iteration 10 the best fitness is 0.055911272321428535
# At iteration 11 the best fitness is 0.06133984375000004
# At iteration 12 the best fitness is 0.06173046875000003
# At iteration 13 the best fitness is 0.05571595982142854
# At iteration 14 the best fitness is 0.061632812500000037
# At iteration 15 the best fitness is 0.05571595982142854
# At iteration 16 the best fitness is 0.05630189732142854
# At iteration 17 the best fitness is 0.051947544642857155
# At iteration 18 the best fitness is 0.055520647321428536
# At iteration 19 the best fitness is 0.06173046875000003
# At iteration 20 the best fitness is 0.051361607142857146
# At iteration 21 the best fitness is 0.05679017857142854
# At iteration 22 the best fitness is 0.061437500000000034
# At iteration 23 the best fitness is 0.056008928571428536
# At iteration 24 the best fitness is 0.05610658482142854
# At iteration 25 the best fitness is 0.055911272321428535
# At iteration 26 the best fitness is 0.062023437500000035
# At iteration 27 the best fitness is 0.050970982142857155
# At iteration 28 the best fitness is 0.05679017857142854
# At iteration 29 the best fitness is 0.056887834821428535
# At iteration 30 the best fitness is 0.061632812500000037
#       Selected: 245/512 (47.9%), Fitness: 0.0616, Time: 514.4s
#       Modality: D=57%, S=55%, Sk=46%
#     Test Acc: 87.41%, F1: 86.25%, Features: 245/512 (47.9%), Model: 0.951MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06745200892857142']
# ['At iteration 1 the best fitness is 0.062414062500000034']
# ['At iteration 2 the best fitness is 0.062414062500000034']
# ['At iteration 3 the best fitness is 0.061046875000000035']
# ['At iteration 4 the best fitness is 0.061046875000000035']
# ['At iteration 5 the best fitness is 0.05620424107142854']
# ['At iteration 6 the best fitness is 0.053079241071428536']
# ['At iteration 7 the best fitness is 0.053079241071428536']
# ['At iteration 8 the best fitness is 0.053079241071428536']
# ['At iteration 9 the best fitness is 0.05220033482142854']
# ['At iteration 10 the best fitness is 0.05220033482142854']
# ['At iteration 11 the best fitness is 0.05220033482142854']
# ['At iteration 12 the best fitness is 0.05220033482142854']
# ['At iteration 13 the best fitness is 0.05220033482142854']
# ['At iteration 14 the best fitness is 0.05220033482142854']
# ['At iteration 15 the best fitness is 0.05220033482142854']
# ['At iteration 16 the best fitness is 0.052102678571428536']
# ['At iteration 17 the best fitness is 0.052102678571428536']
# ['At iteration 18 the best fitness is 0.052102678571428536']
# ['At iteration 19 the best fitness is 0.052102678571428536']
# ['At iteration 20 the best fitness is 0.052005022321428535']
# ['At iteration 21 the best fitness is 0.05171205357142854']
# ['At iteration 22 the best fitness is 0.05171205357142854']
# ['At iteration 23 the best fitness is 0.05171205357142854']
# ['At iteration 24 the best fitness is 0.05171205357142854']
# ['At iteration 25 the best fitness is 0.05171205357142854']
# ['At iteration 26 the best fitness is 0.05171205357142854']
# ['At iteration 27 the best fitness is 0.05171205357142854']
# ['At iteration 28 the best fitness is 0.05171205357142854']
# ['At iteration 29 the best fitness is 0.05171205357142854']
#       Selected: 220/512 (43.0%), Fitness: 0.0517, Time: 506.8s
#       Modality: D=38%, S=37%, Sk=44%
#     Test Acc: 90.56%, F1: 90.16%, Features: 220/512 (43.0%), Model: 0.770MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.06901450892857142']
# ['At iteration 1 the best fitness is 0.058117187500000035']
# ['At iteration 2 the best fitness is 0.058117187500000035']
# ['At iteration 3 the best fitness is 0.05684765625000003']
# ['At iteration 4 the best fitness is 0.05684765625000003']
# ['At iteration 5 the best fitness is 0.05684765625000003']
# ['At iteration 6 the best fitness is 0.05684765625000003']
# ['At iteration 7 the best fitness is 0.05684765625000003']
# ['At iteration 8 the best fitness is 0.05684765625000003']
# ['At iteration 9 the best fitness is 0.056164062500000035']
# ['At iteration 10 the best fitness is 0.056164062500000035']
# ['At iteration 11 the best fitness is 0.056164062500000035']
# ['At iteration 12 the best fitness is 0.056164062500000035']
# ['At iteration 13 the best fitness is 0.056164062500000035']
# ['At iteration 14 the best fitness is 0.056164062500000035']
# ['At iteration 15 the best fitness is 0.056164062500000035']
# ['At iteration 16 the best fitness is 0.056164062500000035']
# ['At iteration 17 the best fitness is 0.056066406250000034']
# ['At iteration 18 the best fitness is 0.056066406250000034']
# ['At iteration 19 the best fitness is 0.056066406250000034']
# ['At iteration 20 the best fitness is 0.056066406250000034']
# ['At iteration 21 the best fitness is 0.055773437500000037']
# ['At iteration 22 the best fitness is 0.055773437500000037']
# ['At iteration 23 the best fitness is 0.055675781250000035']
# ['At iteration 24 the best fitness is 0.05426841517857142']
# ['At iteration 25 the best fitness is 0.05426841517857142']
# ['At iteration 26 the best fitness is 0.05426841517857142']
# ['At iteration 27 the best fitness is 0.05426841517857142']
# ['At iteration 28 the best fitness is 0.05426841517857142']
# ['At iteration 29 the best fitness is 0.05426841517857142']
#       Selected: 130/512 (25.4%), Fitness: 0.0543, Time: 640.5s
#       Modality: D=32%, S=23%, Sk=25%
#     Test Acc: 87.76%, F1: 87.05%, Features: 130/512 (25.4%), Model: 0.276MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06378125000000004']
# ['At iteration 1 the best fitness is 0.06378125000000004']
# ['At iteration 2 the best fitness is 0.06378125000000004']
# ['At iteration 3 the best fitness is 0.06378125000000004']
# ['At iteration 4 the best fitness is 0.06378125000000004']
# ['At iteration 5 the best fitness is 0.06378125000000004']
# ['At iteration 6 the best fitness is 0.06378125000000004']
# ['At iteration 7 the best fitness is 0.06378125000000004']
# ['At iteration 8 the best fitness is 0.06221875000000003']
# ['At iteration 9 the best fitness is 0.06221875000000003']
# ['At iteration 10 the best fitness is 0.06221875000000003']
# ['At iteration 11 the best fitness is 0.05718080357142854']
# ['At iteration 12 the best fitness is 0.05718080357142854']
# ['At iteration 13 the best fitness is 0.05718080357142854']
# ['At iteration 14 the best fitness is 0.05718080357142854']
# ['At iteration 15 the best fitness is 0.05718080357142854']
# ['At iteration 16 the best fitness is 0.05718080357142854']
# ['At iteration 17 the best fitness is 0.05718080357142854']
# ['At iteration 18 the best fitness is 0.05718080357142854']
# ['At iteration 19 the best fitness is 0.05718080357142854']
# ['At iteration 20 the best fitness is 0.05718080357142854']
# ['At iteration 21 the best fitness is 0.05718080357142854']
# ['At iteration 22 the best fitness is 0.05718080357142854']
# ['At iteration 23 the best fitness is 0.05718080357142854']
# ['At iteration 24 the best fitness is 0.05718080357142854']
# ['At iteration 25 the best fitness is 0.05718080357142854']
# ['At iteration 26 the best fitness is 0.05718080357142854']
# ['At iteration 27 the best fitness is 0.05718080357142854']
# ['At iteration 28 the best fitness is 0.05718080357142854']
# ['At iteration 29 the best fitness is 0.056985491071428536']
#       Selected: 246/512 (48.0%), Fitness: 0.0570, Time: 531.7s
#       Modality: D=51%, S=49%, Sk=48%
#     Test Acc: 92.66%, F1: 92.17%, Features: 246/512 (48.0%), Model: 0.958MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07018638392857142']
# ['At iteration 2 the best fitness is 0.06852622767857142']
# ['At iteration 3 the best fitness is 0.06852622767857142']
# ['At iteration 4 the best fitness is 0.06348828125000003']
# ['At iteration 5 the best fitness is 0.06348828125000003']
# ['At iteration 6 the best fitness is 0.06348828125000003']
# ['At iteration 7 the best fitness is 0.06348828125000003']
# ['At iteration 8 the best fitness is 0.06221875000000003']
# ['At iteration 9 the best fitness is 0.06221875000000003']
# ['At iteration 10 the best fitness is 0.06221875000000003']
# ['At iteration 11 the best fitness is 0.05903627232142854']
# ['At iteration 12 the best fitness is 0.05903627232142854']
# ['At iteration 13 the best fitness is 0.05903627232142854']
# ['At iteration 14 the best fitness is 0.05903627232142854']
# ['At iteration 15 the best fitness is 0.05903627232142854']
# ['At iteration 16 the best fitness is 0.057962053571428536']
# ['At iteration 17 the best fitness is 0.057962053571428536']
# ['At iteration 18 the best fitness is 0.057962053571428536']
# ['At iteration 19 the best fitness is 0.057962053571428536']
# ['At iteration 20 the best fitness is 0.057962053571428536']
# ['At iteration 21 the best fitness is 0.05727845982142854']
# ['At iteration 22 the best fitness is 0.05727845982142854']
# ['At iteration 23 the best fitness is 0.05727845982142854']
# ['At iteration 24 the best fitness is 0.056008928571428536']
# ['At iteration 25 the best fitness is 0.056008928571428536']
# ['At iteration 26 the best fitness is 0.056008928571428536']
# ['At iteration 27 the best fitness is 0.056008928571428536']
# ['At iteration 28 the best fitness is 0.056008928571428536']
# ['At iteration 29 the best fitness is 0.056008928571428536']
#       Selected: 243/512 (47.5%), Fitness: 0.0560, Time: 497.4s
#       Modality: D=51%, S=49%, Sk=47%
#     Test Acc: 91.26%, F1: 90.36%, Features: 243/512 (47.5%), Model: 0.935MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06950279017857142']
# ['At iteration 2 the best fitness is 0.06358593750000004']
# ['At iteration 3 the best fitness is 0.06270703125000003']
# ['At iteration 4 the best fitness is 0.061925781250000034']
# ['At iteration 5 the best fitness is 0.056497209821428536']
# ['At iteration 6 the best fitness is 0.056497209821428536']
# ['At iteration 7 the best fitness is 0.05610658482142854']
# ['At iteration 8 the best fitness is 0.05126395089285715']
# ['At iteration 9 the best fitness is 0.05126395089285715']
# ['At iteration 10 the best fitness is 0.05126395089285715']
# ['At iteration 11 the best fitness is 0.05126395089285715']
# ['At iteration 12 the best fitness is 0.05126395089285715']
# ['At iteration 13 the best fitness is 0.05126395089285715']
# ['At iteration 14 the best fitness is 0.05126395089285715']
# ['At iteration 15 the best fitness is 0.05126395089285715']
# ['At iteration 16 the best fitness is 0.05126395089285715']
# ['At iteration 17 the best fitness is 0.05126395089285715']
# ['At iteration 18 the best fitness is 0.05126395089285715']
# ['At iteration 19 the best fitness is 0.05126395089285715']
# ['At iteration 20 the best fitness is 0.05126395089285715']
# ['At iteration 21 the best fitness is 0.05126395089285715']
# ['At iteration 22 the best fitness is 0.05126395089285715']
# ['At iteration 23 the best fitness is 0.05126395089285715']
# ['At iteration 24 the best fitness is 0.05126395089285715']
# ['At iteration 25 the best fitness is 0.05126395089285715']
# ['At iteration 26 the best fitness is 0.05126395089285715']
# ['At iteration 27 the best fitness is 0.05126395089285715']
# ['At iteration 28 the best fitness is 0.05126395089285715']
# ['At iteration 29 the best fitness is 0.05126395089285715']
# ['At iteration 30 the best fitness is 0.05126395089285715']
#       Selected: 247/512 (48.2%), Fitness: 0.0513, Time: 513.9s
#       Modality: D=43%, S=51%, Sk=48%
#     Test Acc: 93.71%, F1: 93.70%, Features: 247/512 (48.2%), Model: 0.966MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06549888392857142']
# ['At iteration 2 the best fitness is 0.060070312500000035']
# ['At iteration 3 the best fitness is 0.060070312500000035']
# ['At iteration 4 the best fitness is 0.060070312500000035']
# ['At iteration 5 the best fitness is 0.060070312500000035']
# ['At iteration 6 the best fitness is 0.060070312500000035']
# ['At iteration 7 the best fitness is 0.060070312500000035']
# ['At iteration 8 the best fitness is 0.059972656250000034']
# ['At iteration 9 the best fitness is 0.05987500000000004']
# ['At iteration 10 the best fitness is 0.058996093750000034']
# ['At iteration 11 the best fitness is 0.058996093750000034']
# ['At iteration 12 the best fitness is 0.058996093750000034']
# ['At iteration 13 the best fitness is 0.058996093750000034']
# ['At iteration 14 the best fitness is 0.058996093750000034']
# ['At iteration 15 the best fitness is 0.058996093750000034']
# ['At iteration 16 the best fitness is 0.053567522321428536']
# ['At iteration 17 the best fitness is 0.053567522321428536']
# ['At iteration 18 the best fitness is 0.053567522321428536']
# ['At iteration 19 the best fitness is 0.053567522321428536']
# ['At iteration 20 the best fitness is 0.053567522321428536']
# ['At iteration 21 the best fitness is 0.053567522321428536']
# ['At iteration 22 the best fitness is 0.053567522321428536']
# ['At iteration 23 the best fitness is 0.053567522321428536']
# ['At iteration 24 the best fitness is 0.053567522321428536']
# ['At iteration 25 the best fitness is 0.053567522321428536']
# ['At iteration 26 the best fitness is 0.053567522321428536']
# ['At iteration 27 the best fitness is 0.053567522321428536']
# ['At iteration 28 the best fitness is 0.053567522321428536']
# ['At iteration 29 the best fitness is 0.053567522321428536']
# ['At iteration 30 the best fitness is 0.053567522321428536']
#       Selected: 218/512 (42.6%), Fitness: 0.0536, Time: 512.4s
#       Modality: D=35%, S=35%, Sk=45%
#     Test Acc: 92.66%, F1: 92.48%, Features: 218/512 (42.6%), Model: 0.756MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06803794642857142']
# ['At iteration 1 the best fitness is 0.061144531250000037']
# ['At iteration 2 the best fitness is 0.05889843750000004']
# ['At iteration 3 the best fitness is 0.05889843750000004']
# ['At iteration 4 the best fitness is 0.05889843750000004']
# ['At iteration 5 the best fitness is 0.056164062500000035']
# ['At iteration 6 the best fitness is 0.056164062500000035']
# ['At iteration 7 the best fitness is 0.054308593750000037']
# ['At iteration 8 the best fitness is 0.052746093750000035']
# ['At iteration 9 the best fitness is 0.050207031250000034']
# ['At iteration 10 the best fitness is 0.045755022321428536']
# ['At iteration 11 the best fitness is 0.045755022321428536']
# ['At iteration 12 the best fitness is 0.045755022321428536']
# ['At iteration 13 the best fitness is 0.045755022321428536']
# ['At iteration 14 the best fitness is 0.045755022321428536']
# ['At iteration 15 the best fitness is 0.045755022321428536']
# ['At iteration 16 the best fitness is 0.045755022321428536']
# ['At iteration 17 the best fitness is 0.045755022321428536']
# ['At iteration 18 the best fitness is 0.045755022321428536']
# ['At iteration 19 the best fitness is 0.045755022321428536']
# ['At iteration 20 the best fitness is 0.045755022321428536']
# ['At iteration 21 the best fitness is 0.045755022321428536']
# ['At iteration 22 the best fitness is 0.045755022321428536']
# ['At iteration 23 the best fitness is 0.045755022321428536']
# ['At iteration 24 the best fitness is 0.04302064732142854']
# ['At iteration 25 the best fitness is 0.04253236607142854']
# ['At iteration 26 the best fitness is 0.04253236607142854']
# ['At iteration 27 the best fitness is 0.04253236607142854']
# ['At iteration 28 the best fitness is 0.04253236607142854']
# ['At iteration 29 the best fitness is 0.04253236607142854']
#       Selected: 107/512 (20.9%), Fitness: 0.0425, Time: 486.3s
#       Modality: D=16%, S=21%, Sk=21%
#     Test Acc: 94.76%, F1: 94.56%, Features: 107/512 (20.9%), Model: 0.190MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06725669642857142']
# ['At iteration 2 the best fitness is 0.06260937500000004']
# ['At iteration 3 the best fitness is 0.06221875000000003']
# ['At iteration 4 the best fitness is 0.06221875000000003']
# ['At iteration 5 the best fitness is 0.06221875000000003']
# ['At iteration 6 the best fitness is 0.06221875000000003']
# ['At iteration 7 the best fitness is 0.06221875000000003']
# ['At iteration 8 the best fitness is 0.06221875000000003']
# ['At iteration 9 the best fitness is 0.06221875000000003']
# ['At iteration 10 the best fitness is 0.06221875000000003']
# ['At iteration 11 the best fitness is 0.06221875000000003']
# ['At iteration 12 the best fitness is 0.056985491071428536']
# ['At iteration 13 the best fitness is 0.056985491071428536']
# ['At iteration 14 the best fitness is 0.056985491071428536']
# ['At iteration 15 the best fitness is 0.056985491071428536']
# ['At iteration 16 the best fitness is 0.056985491071428536']
# ['At iteration 17 the best fitness is 0.056985491071428536']
# ['At iteration 18 the best fitness is 0.056985491071428536']
# ['At iteration 19 the best fitness is 0.056985491071428536']
# ['At iteration 20 the best fitness is 0.056985491071428536']
# ['At iteration 21 the best fitness is 0.056985491071428536']
# ['At iteration 22 the best fitness is 0.056985491071428536']
# ['At iteration 23 the best fitness is 0.056985491071428536']
# ['At iteration 24 the best fitness is 0.056985491071428536']
# ['At iteration 25 the best fitness is 0.056985491071428536']
# ['At iteration 26 the best fitness is 0.056985491071428536']
# ['At iteration 27 the best fitness is 0.056985491071428536']
# ['At iteration 28 the best fitness is 0.056985491071428536']
# ['At iteration 29 the best fitness is 0.056985491071428536']
#       Selected: 258/512 (50.4%), Fitness: 0.0570, Time: 1284.0s
#       Modality: D=49%, S=48%, Sk=51%
#     Test Acc: 91.61%, F1: 91.13%, Features: 258/512 (50.4%), Model: 1.040MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07047935267857142']
# ['At iteration 1 the best fitness is 0.0659068080357143']
# ['At iteration 2 the best fitness is 0.06516573660714281']
# ['At iteration 3 the best fitness is 0.06188560267857142']
# ['At iteration 4 the best fitness is 0.06188560267857142']
# ['At iteration 5 the best fitness is 0.06188560267857142']
# ['At iteration 6 the best fitness is 0.05645703125000004']
# ['At iteration 7 the best fitness is 0.05645703125000004']
# ['At iteration 8 the best fitness is 0.05645703125000004']
# ['At iteration 9 the best fitness is 0.05645703125000004']
# ['At iteration 10 the best fitness is 0.05645703125000004']
# ['At iteration 11 the best fitness is 0.05645703125000004']
# ['At iteration 12 the best fitness is 0.05329185267857142']
# ['At iteration 13 the best fitness is 0.05329185267857142']
# ['At iteration 14 the best fitness is 0.05329185267857142']
# ['At iteration 15 the best fitness is 0.05329185267857142']
# ['At iteration 16 the best fitness is 0.05329185267857142']
# ['At iteration 17 the best fitness is 0.047863281250000035']
# ['At iteration 18 the best fitness is 0.047863281250000035']
# ['At iteration 19 the best fitness is 0.047863281250000035']
# ['At iteration 20 the best fitness is 0.047863281250000035']
# ['At iteration 21 the best fitness is 0.047863281250000035']
# ['At iteration 22 the best fitness is 0.047863281250000035']
# ['At iteration 23 the best fitness is 0.047863281250000035']
# ['At iteration 24 the best fitness is 0.047863281250000035']
# ['At iteration 25 the best fitness is 0.047863281250000035']
# ['At iteration 26 the best fitness is 0.047863281250000035']
# ['At iteration 27 the best fitness is 0.047863281250000035']
# ['At iteration 28 the best fitness is 0.047863281250000035']
# ['At iteration 29 the best fitness is 0.047863281250000035']
#       Selected: 126/512 (24.6%), Fitness: 0.0479, Time: 463.0s
#       Modality: D=16%, S=27%, Sk=25%
#     Test Acc: 89.16%, F1: 88.63%, Features: 126/512 (24.6%), Model: 0.260MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 83.82%, F1: 84.24%, Features: 512/512 (100.0%), Model: 1.536MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 256/512 (50.0%), Time: 2.5s
#     Test Acc: 90.87%, F1: 90.97%, Features: 256/512 (50.0%), Model: 1.036MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 256/512 (50.0%), Time: 0.5s
#     Test Acc: 87.97%, F1: 88.61%, Features: 256/512 (50.0%), Model: 1.036MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 256/512 (50.0%), Time: 0.1s
#     Test Acc: 82.16%, F1: 82.17%, Features: 256/512 (50.0%), Model: 1.036MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.029967730978260894']
# ['At iteration 1 the best fitness is 0.029967730978260894']
# ['At iteration 2 the best fitness is 0.029967730978260894']
# ['At iteration 3 the best fitness is 0.029967730978260894']
# ['At iteration 4 the best fitness is 0.029967730978260894']
# ['At iteration 5 the best fitness is 0.029967730978260894']
# ['At iteration 6 the best fitness is 0.029967730978260894']
# ['At iteration 7 the best fitness is 0.029967730978260894']
# ['At iteration 8 the best fitness is 0.029577105978260892']
# ['At iteration 9 the best fitness is 0.029381793478260892']
# ['At iteration 10 the best fitness is 0.029381793478260892']
# ['At iteration 11 the best fitness is 0.029381793478260892']
# ['At iteration 12 the best fitness is 0.029381793478260892']
# ['At iteration 13 the best fitness is 0.029381793478260892']
# ['At iteration 14 the best fitness is 0.029381793478260892']
# ['At iteration 15 the best fitness is 0.029381793478260892']
# ['At iteration 16 the best fitness is 0.029381793478260892']
# ['At iteration 17 the best fitness is 0.029381793478260892']
# ['At iteration 18 the best fitness is 0.029381793478260892']
# ['At iteration 19 the best fitness is 0.029381793478260892']
# ['At iteration 20 the best fitness is 0.029284137228260895']
# ['At iteration 21 the best fitness is 0.029284137228260895']
# ['At iteration 22 the best fitness is 0.029284137228260895']
# ['At iteration 23 the best fitness is 0.029284137228260895']
# ['At iteration 24 the best fitness is 0.029284137228260895']
# ['At iteration 25 the best fitness is 0.029284137228260895']
# ['At iteration 26 the best fitness is 0.029284137228260895']
# ['At iteration 27 the best fitness is 0.029284137228260895']
# ['At iteration 28 the best fitness is 0.029284137228260895']
# ['At iteration 29 the best fitness is 0.029284137228260895']
#       Selected: 247/512 (48.2%), Fitness: 0.0293, Time: 570.2s
#       Modality: D=49%, S=49%, Sk=48%
#     Test Acc: 84.23%, F1: 84.54%, Features: 247/512 (48.2%), Model: 0.966MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.035423743206521786']
# ['At iteration 10 the best fitness is 0.028991168478260894']
# ['At iteration 20 the best fitness is 0.028307574728260895']
#       Selected: 248/512 (48.4%), Fitness: 0.0283, Time: 1122.3s
#       Modality: D=51%, S=43%, Sk=49%
#     Test Acc: 82.57%, F1: 82.69%, Features: 248/512 (48.4%), Model: 0.974MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.034447180706521786']
# ['At iteration 2 the best fitness is 0.034447180706521786']
# ['At iteration 3 the best fitness is 0.034447180706521786']
# ['At iteration 4 the best fitness is 0.030358355978260892']
# ['At iteration 5 the best fitness is 0.029381793478260892']
# ['At iteration 6 the best fitness is 0.028795855978260895']
# ['At iteration 7 the best fitness is 0.028795855978260895']
# ['At iteration 8 the best fitness is 0.028795855978260895']
# ['At iteration 9 the best fitness is 0.028795855978260895']
# ['At iteration 10 the best fitness is 0.02373046875']
# ['At iteration 11 the best fitness is 0.02373046875']
# ['At iteration 12 the best fitness is 0.02373046875']
# ['At iteration 13 the best fitness is 0.02373046875']
# ['At iteration 14 the best fitness is 0.02373046875']
# ['At iteration 15 the best fitness is 0.02373046875']
# ['At iteration 16 the best fitness is 0.02373046875']
# ['At iteration 17 the best fitness is 0.02373046875']
# ['At iteration 18 the best fitness is 0.02373046875']
# ['At iteration 19 the best fitness is 0.02373046875']
# ['At iteration 20 the best fitness is 0.02373046875']
# ['At iteration 21 the best fitness is 0.02373046875']
# ['At iteration 22 the best fitness is 0.02373046875']
# ['At iteration 23 the best fitness is 0.02373046875']
# ['At iteration 24 the best fitness is 0.02373046875']
# ['At iteration 25 the best fitness is 0.02373046875']
# ['At iteration 26 the best fitness is 0.02373046875']
# ['At iteration 27 the best fitness is 0.02373046875']
# ['At iteration 28 the best fitness is 0.02373046875']
# ['At iteration 29 the best fitness is 0.02373046875']
# ['At iteration 30 the best fitness is 0.02373046875']
#       Selected: 259/512 (50.6%), Fitness: 0.0237, Time: 569.8s
#       Modality: D=51%, S=56%, Sk=50%
#     Test Acc: 81.74%, F1: 81.58%, Features: 259/512 (50.6%), Model: 1.042MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.035228430706521784']
# ['At iteration 1 the best fitness is 0.030065387228260892']
# ['At iteration 2 the best fitness is 0.03931725543478257']
# ['At iteration 3 the best fitness is 0.03415421195652179']
# ['At iteration 4 the best fitness is 0.03415421195652179']
# ['At iteration 5 the best fitness is 0.03503311820652179']
# ['At iteration 6 the best fitness is 0.030065387228260892']
# ['At iteration 7 the best fitness is 0.030163043478260893']
# ['At iteration 8 the best fitness is 0.029284137228260895']
# ['At iteration 9 the best fitness is 0.03980553668478257']
# ['At iteration 10 the best fitness is 0.03970788043478257']
# ['At iteration 11 the best fitness is 0.029577105978260892']
# ['At iteration 12 the best fitness is 0.04487092391304347']
# ['At iteration 13 the best fitness is 0.03970788043478257']
# ['At iteration 14 the best fitness is 0.034740149456521784']
# ['At iteration 15 the best fitness is 0.029674762228260893']
# ['At iteration 16 the best fitness is 0.04000084918478257']
# ['At iteration 17 the best fitness is 0.034837805706521785']
# ['At iteration 18 the best fitness is 0.04000084918478257']
# ['At iteration 19 the best fitness is 0.034740149456521784']
# ['At iteration 20 the best fitness is 0.029674762228260893']
# ['At iteration 21 the best fitness is 0.04000084918478257']
# ['At iteration 22 the best fitness is 0.04000084918478257']
# ['At iteration 23 the best fitness is 0.034837805706521785']
# ['At iteration 24 the best fitness is 0.04000084918478257']
# ['At iteration 25 the best fitness is 0.034837805706521785']
# ['At iteration 26 the best fitness is 0.034837805706521785']
# ['At iteration 27 the best fitness is 0.04000084918478257']
# ['At iteration 28 the best fitness is 0.045163892663043465']
# ['At iteration 29 the best fitness is 0.04000084918478257']
#       Selected: 252/512 (49.2%), Fitness: 0.0400, Time: 552.1s
#       Modality: D=54%, S=52%, Sk=48%
#     Test Acc: 80.50%, F1: 80.61%, Features: 252/512 (49.2%), Model: 1.005MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.0317255434782609
# At iteration 2 the best fitness is 0.04263756793478257
# At iteration 3 the best fitness is 0.03610733695652179
# At iteration 4 the best fitness is 0.041856317934782575
# At iteration 5 the best fitness is 0.03698624320652179
# At iteration 6 the best fitness is 0.03659561820652179
# At iteration 7 the best fitness is 0.03649796195652179
# At iteration 8 the best fitness is 0.030553668478260892
# At iteration 9 the best fitness is 0.035716711956521784
# At iteration 10 the best fitness is 0.030651324728260893
# At iteration 11 the best fitness is 0.03513077445652179
# At iteration 12 the best fitness is 0.03454483695652179
# At iteration 13 the best fitness is 0.03454483695652179
# At iteration 14 the best fitness is 0.029870074728260892
# At iteration 15 the best fitness is 0.030944293478260894
# At iteration 16 the best fitness is 0.03454483695652179
# At iteration 17 the best fitness is 0.029772418478260895
# At iteration 18 the best fitness is 0.029772418478260895
# At iteration 19 the best fitness is 0.029577105978260892
# At iteration 20 the best fitness is 0.034935461956521786
# At iteration 21 the best fitness is 0.029577105978260892
# At iteration 22 the best fitness is 0.029186480978260893
# At iteration 23 the best fitness is 0.028698199728260893
# At iteration 24 the best fitness is 0.028698199728260893
# At iteration 25 the best fitness is 0.028698199728260893
# At iteration 26 the best fitness is 0.029284137228260895
# At iteration 27 the best fitness is 0.028698199728260893
# At iteration 28 the best fitness is 0.028698199728260893
# At iteration 29 the best fitness is 0.028698199728260893
# At iteration 30 the best fitness is 0.029284137228260895
#       Selected: 248/512 (48.4%), Fitness: 0.0293, Time: 551.4s
#       Modality: D=49%, S=51%, Sk=48%
#     Test Acc: 86.72%, F1: 87.12%, Features: 248/512 (48.4%), Model: 0.974MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.034837805706521785']
# ['At iteration 1 the best fitness is 0.029479449728260894']
# ['At iteration 2 the best fitness is 0.029479449728260894']
# ['At iteration 3 the best fitness is 0.026354449728260895']
# ['At iteration 4 the best fitness is 0.026354449728260895']
# ['At iteration 5 the best fitness is 0.025866168478260895']
# ['At iteration 6 the best fitness is 0.025475543478260892']
# ['At iteration 7 the best fitness is 0.025475543478260892']
# ['At iteration 8 the best fitness is 0.024596637228260894']
# ['At iteration 9 the best fitness is 0.024010699728260892']
# ['At iteration 10 the best fitness is 0.022057574728260892']
# ['At iteration 11 the best fitness is 0.022057574728260892']
# ['At iteration 12 the best fitness is 0.022057574728260892']
# ['At iteration 13 the best fitness is 0.021178668478260894']
# ['At iteration 14 the best fitness is 0.020104449728260892']
# ['At iteration 15 the best fitness is 0.019420855978260893']
# ['At iteration 16 the best fitness is 0.019420855978260893']
# ['At iteration 17 the best fitness is 0.019030230978260895']
# ['At iteration 18 the best fitness is 0.019030230978260895']
# ['At iteration 19 the best fitness is 0.018444293478260893']
# ['At iteration 20 the best fitness is 0.013769531250000001']
# ['At iteration 21 the best fitness is 0.01357421875']
# ['At iteration 22 the best fitness is 0.012792968750000001']
# ['At iteration 23 the best fitness is 0.012792968750000001']
# ['At iteration 24 the best fitness is 0.0126953125']
# ['At iteration 25 the best fitness is 0.0126953125']
# ['At iteration 26 the best fitness is 0.0125']
# ['At iteration 27 the best fitness is 0.0125']
# ['At iteration 28 the best fitness is 0.012304687500000001']
# ['At iteration 29 the best fitness is 0.012304687500000001']
#       Selected: 155/512 (30.3%), Fitness: 0.0123, Time: 541.1s
#       Modality: D=27%, S=24%, Sk=32%
#     Test Acc: 81.74%, F1: 81.86%, Features: 155/512 (30.3%), Model: 0.389MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.03415421195652179']
# ['At iteration 1 the best fitness is 0.026732336956521788']
# ['At iteration 2 the best fitness is 0.026732336956521788']
# ['At iteration 3 the best fitness is 0.026732336956521788']
# ['At iteration 4 the best fitness is 0.021569293478260892']
# ['At iteration 5 the best fitness is 0.021569293478260892']
# ['At iteration 6 the best fitness is 0.021569293478260892']
# ['At iteration 7 the best fitness is 0.021569293478260892']
# ['At iteration 8 the best fitness is 0.020299762228260892']
# ['At iteration 9 the best fitness is 0.020299762228260892']
# ['At iteration 10 the best fitness is 0.020299762228260892']
# ['At iteration 11 the best fitness is 0.020299762228260892']
# ['At iteration 12 the best fitness is 0.020299762228260892']
# ['At iteration 13 the best fitness is 0.020299762228260892']
# ['At iteration 14 the best fitness is 0.020299762228260892']
# ['At iteration 15 the best fitness is 0.020299762228260892']
# ['At iteration 16 the best fitness is 0.020299762228260892']
# ['At iteration 17 the best fitness is 0.020299762228260892']
# ['At iteration 18 the best fitness is 0.020299762228260892']
# ['At iteration 19 the best fitness is 0.020299762228260892']
# ['At iteration 20 the best fitness is 0.020299762228260892']
# ['At iteration 21 the best fitness is 0.020299762228260892']
# ['At iteration 22 the best fitness is 0.020299762228260892']
# ['At iteration 23 the best fitness is 0.020104449728260892']
# ['At iteration 24 the best fitness is 0.020104449728260892']
# ['At iteration 25 the best fitness is 0.020104449728260892']
# ['At iteration 26 the best fitness is 0.020006793478260895']
# ['At iteration 27 the best fitness is 0.020006793478260895']
# ['At iteration 28 the best fitness is 0.020006793478260895']
# ['At iteration 29 the best fitness is 0.020006793478260895']
#       Selected: 147/512 (28.7%), Fitness: 0.0200, Time: 741.6s
#       Modality: D=30%, S=20%, Sk=30%
#     Test Acc: 80.91%, F1: 81.29%, Features: 147/512 (28.7%), Model: 0.351MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.028209918478260893']
# ['At iteration 1 the best fitness is 0.028209918478260893']
# ['At iteration 2 the best fitness is 0.027331012228260895']
# ['At iteration 3 the best fitness is 0.027331012228260895']
# ['At iteration 4 the best fitness is 0.027331012228260895']
# ['At iteration 5 the best fitness is 0.027233355978260893']
# ['At iteration 6 the best fitness is 0.027233355978260893']
# ['At iteration 7 the best fitness is 0.02177734375']
# ['At iteration 8 the best fitness is 0.02177734375']
# ['At iteration 9 the best fitness is 0.02177734375']
# ['At iteration 10 the best fitness is 0.02177734375']
# ['At iteration 11 the best fitness is 0.02177734375']
# ['At iteration 12 the best fitness is 0.02177734375']
# ['At iteration 13 the best fitness is 0.02177734375']
# ['At iteration 14 the best fitness is 0.02177734375']
# ['At iteration 15 the best fitness is 0.02177734375']
# ['At iteration 16 the best fitness is 0.02177734375']
# ['At iteration 17 the best fitness is 0.02177734375']
# ['At iteration 18 the best fitness is 0.02177734375']
# ['At iteration 19 the best fitness is 0.02177734375']
# ['At iteration 20 the best fitness is 0.02177734375']
# ['At iteration 21 the best fitness is 0.02177734375']
# ['At iteration 22 the best fitness is 0.02177734375']
# ['At iteration 23 the best fitness is 0.02177734375']
# ['At iteration 24 the best fitness is 0.02177734375']
# ['At iteration 25 the best fitness is 0.02177734375']
# ['At iteration 26 the best fitness is 0.02177734375']
# ['At iteration 27 the best fitness is 0.02177734375']
# ['At iteration 28 the best fitness is 0.02177734375']
# ['At iteration 29 the best fitness is 0.02177734375']
#       Selected: 226/512 (44.1%), Fitness: 0.0218, Time: 570.9s
#       Modality: D=38%, S=32%, Sk=47%
#     Test Acc: 81.74%, F1: 81.53%, Features: 226/512 (44.1%), Model: 0.811MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03415421195652179']
# ['At iteration 2 the best fitness is 0.03415421195652179']
# ['At iteration 3 the best fitness is 0.03405655570652179']
# ['At iteration 4 the best fitness is 0.033763586956521784']
# ['At iteration 5 the best fitness is 0.033763586956521784']
# ['At iteration 6 the best fitness is 0.033763586956521784']
# ['At iteration 7 the best fitness is 0.029186480978260893']
# ['At iteration 8 the best fitness is 0.029186480978260893']
# ['At iteration 9 the best fitness is 0.029186480978260893']
# ['At iteration 10 the best fitness is 0.029088824728260892']
# ['At iteration 11 the best fitness is 0.029088824728260892']
# ['At iteration 12 the best fitness is 0.029088824728260892']
# ['At iteration 13 the best fitness is 0.029088824728260892']
# ['At iteration 14 the best fitness is 0.029088824728260892']
# ['At iteration 15 the best fitness is 0.029088824728260892']
# ['At iteration 16 the best fitness is 0.029088824728260892']
# ['At iteration 17 the best fitness is 0.029088824728260892']
# ['At iteration 18 the best fitness is 0.029088824728260892']
# ['At iteration 19 the best fitness is 0.028991168478260894']
# ['At iteration 20 the best fitness is 0.028991168478260894']
# ['At iteration 21 the best fitness is 0.028991168478260894']
# ['At iteration 22 the best fitness is 0.028502887228260894']
# ['At iteration 23 the best fitness is 0.028307574728260895']
# ['At iteration 24 the best fitness is 0.028307574728260895']
# ['At iteration 25 the best fitness is 0.028307574728260895']
# ['At iteration 26 the best fitness is 0.028112262228260892']
# ['At iteration 27 the best fitness is 0.028112262228260892']
# ['At iteration 28 the best fitness is 0.027526324728260894']
# ['At iteration 29 the best fitness is 0.027526324728260894']
#       Selected: 251/512 (49.0%), Fitness: 0.0275, Time: 534.5s
#       Modality: D=41%, S=51%, Sk=50%
#     Test Acc: 83.40%, F1: 83.47%, Features: 251/512 (49.0%), Model: 0.997MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03415421195652179']
# ['At iteration 2 the best fitness is 0.03415421195652179']
# ['At iteration 3 the best fitness is 0.03415421195652179']
# ['At iteration 4 the best fitness is 0.03415421195652179']
# ['At iteration 5 the best fitness is 0.03415421195652179']
# ['At iteration 6 the best fitness is 0.028405230978260892']
# ['At iteration 7 the best fitness is 0.028405230978260892']
# ['At iteration 8 the best fitness is 0.028405230978260892']
# ['At iteration 9 the best fitness is 0.028405230978260892']
# ['At iteration 10 the best fitness is 0.028405230978260892']
# ['At iteration 11 the best fitness is 0.028405230978260892']
# ['At iteration 12 the best fitness is 0.028405230978260892']
# ['At iteration 13 the best fitness is 0.027916949728260892']
# ['At iteration 14 the best fitness is 0.027331012228260895']
# ['At iteration 15 the best fitness is 0.027331012228260895']
# ['At iteration 16 the best fitness is 0.027331012228260895']
# ['At iteration 17 the best fitness is 0.027331012228260895']
# ['At iteration 18 the best fitness is 0.027331012228260895']
# ...
# ['At iteration 14 the best fitness is 0.05160399125647668']
# ['At iteration 15 the best fitness is 0.05160399125647668']
# ['At iteration 16 the best fitness is 0.05160399125647668']
# ['At iteration 17 the best fitness is 0.05160399125647668']
# ['At iteration 18 the best fitness is 0.05160399125647668']
# ['At iteration 19 the best fitness is 0.05160399125647668']
# ['At iteration 20 the best fitness is 0.05160399125647668']
# ['At iteration 21 the best fitness is 0.05160399125647668']
# ['At iteration 22 the best fitness is 0.05160399125647668']
# ['At iteration 23 the best fitness is 0.05160399125647668']
# ['At iteration 24 the best fitness is 0.05160399125647668']
# ['At iteration 25 the best fitness is 0.05160399125647668']
# ['At iteration 26 the best fitness is 0.05160399125647668']
# ['At iteration 27 the best fitness is 0.05160399125647668']
# ['At iteration 28 the best fitness is 0.05160399125647668']
# ['At iteration 29 the best fitness is 0.05160399125647668']
#       Selected: 234/512 (45.7%), Fitness: 0.0516, Time: 766.1s
#       Modality: D=46%, S=45%, Sk=46%
#     Test Acc: 75.76%, F1: 76.06%, Features: 234/512 (45.7%), Model: 0.869MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05511961625647668']
# ['At iteration 1 the best fitness is 0.05511961625647668']
# ['At iteration 2 the best fitness is 0.05078327396373055']
# ['At iteration 3 the best fitness is 0.05078327396373055']
# ['At iteration 4 the best fitness is 0.05078327396373055']
# ['At iteration 5 the best fitness is 0.05078327396373055']
# ['At iteration 6 the best fitness is 0.05078327396373055']
# ['At iteration 7 the best fitness is 0.05078327396373055']
# ['At iteration 8 the best fitness is 0.05078327396373055']
# ['At iteration 9 the best fitness is 0.050002023963730546']
# ['At iteration 10 the best fitness is 0.050002023963730546']
# ['At iteration 11 the best fitness is 0.050002023963730546']
# ['At iteration 12 the best fitness is 0.050002023963730546']
# ['At iteration 13 the best fitness is 0.050002023963730546']
# ['At iteration 14 the best fitness is 0.050002023963730546']
# ['At iteration 15 the best fitness is 0.050002023963730546']
# ['At iteration 16 the best fitness is 0.050002023963730546']
# ['At iteration 17 the best fitness is 0.050002023963730546']
# ['At iteration 18 the best fitness is 0.050002023963730546']
# ['At iteration 19 the best fitness is 0.050002023963730546']
# ['At iteration 20 the best fitness is 0.050002023963730546']
# ['At iteration 21 the best fitness is 0.050002023963730546']
# ['At iteration 22 the best fitness is 0.050002023963730546']
# ['At iteration 23 the best fitness is 0.050002023963730546']
# ['At iteration 24 the best fitness is 0.050002023963730546']
# ['At iteration 25 the best fitness is 0.050002023963730546']
# ['At iteration 26 the best fitness is 0.050002023963730546']
# ['At iteration 27 the best fitness is 0.050002023963730546']
# ['At iteration 28 the best fitness is 0.050002023963730546']
# ['At iteration 29 the best fitness is 0.050002023963730546']
#       Selected: 257/512 (50.2%), Fitness: 0.0500, Time: 601.6s
#       Modality: D=54%, S=48%, Sk=50%
#     Test Acc: 75.76%, F1: 74.38%, Features: 257/512 (50.2%), Model: 1.038MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.058870021049222815']
# ['At iteration 2 the best fitness is 0.058870021049222815']
# ['At iteration 3 the best fitness is 0.05394774125647668']
# ['At iteration 4 the best fitness is 0.05394774125647668']
# ['At iteration 5 the best fitness is 0.05394774125647668']
# ['At iteration 6 the best fitness is 0.05297117875647668']
# ['At iteration 7 the best fitness is 0.05297117875647668']
# ['At iteration 8 the best fitness is 0.05297117875647668']
# ['At iteration 9 the best fitness is 0.05297117875647668']
# ['At iteration 10 the best fitness is 0.050978586463730546']
# ['At iteration 11 the best fitness is 0.050978586463730546']
# ['At iteration 12 the best fitness is 0.050978586463730546']
# ['At iteration 13 the best fitness is 0.050490305213730546']
# ['At iteration 14 the best fitness is 0.050099680213730555']
# ['At iteration 15 the best fitness is 0.04990436771373055']
# ['At iteration 16 the best fitness is 0.04990436771373055']
# ['At iteration 17 the best fitness is 0.04775593021373055']
# ['At iteration 18 the best fitness is 0.04775593021373055']
# ['At iteration 19 the best fitness is 0.04775593021373055']
# ['At iteration 20 the best fitness is 0.04775593021373055']
# ['At iteration 21 the best fitness is 0.04775593021373055']
# ['At iteration 22 the best fitness is 0.04775593021373055']
# ['At iteration 23 the best fitness is 0.04775593021373055']
# ['At iteration 24 the best fitness is 0.04775593021373055']
# ['At iteration 25 the best fitness is 0.04775593021373055']
# ['At iteration 26 the best fitness is 0.04775593021373055']
# ['At iteration 27 the best fitness is 0.04775593021373055']
# ['At iteration 28 the best fitness is 0.04775593021373055']
# ['At iteration 29 the best fitness is 0.04775593021373055']
#       Selected: 252/512 (49.2%), Fitness: 0.0478, Time: 564.6s
#       Modality: D=46%, S=45%, Sk=50%
#     Test Acc: 88.38%, F1: 88.76%, Features: 252/512 (49.2%), Model: 1.005MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05877236479922282']
# ['At iteration 2 the best fitness is 0.05316649125647668']
# ['At iteration 3 the best fitness is 0.05316649125647668']
# ['At iteration 4 the best fitness is 0.05316649125647668']
# ['At iteration 5 the best fitness is 0.05316649125647668']
# ['At iteration 6 the best fitness is 0.05306883500647668']
# ['At iteration 7 the best fitness is 0.05306883500647668']
# ['At iteration 8 the best fitness is 0.05306883500647668']
# ['At iteration 9 the best fitness is 0.05306883500647668']
# ['At iteration 10 the best fitness is 0.04795124271373055']
# ['At iteration 11 the best fitness is 0.04795124271373055']
# ['At iteration 12 the best fitness is 0.04795124271373055']
# ['At iteration 13 the best fitness is 0.04795124271373055']
# ['At iteration 14 the best fitness is 0.04795124271373055']
# ['At iteration 15 the best fitness is 0.04795124271373055']
# ['At iteration 16 the best fitness is 0.04795124271373055']
# ['At iteration 17 the best fitness is 0.04795124271373055']
# ['At iteration 18 the best fitness is 0.04795124271373055']
# ['At iteration 19 the best fitness is 0.04795124271373055']
# ['At iteration 20 the best fitness is 0.04795124271373055']
# ['At iteration 21 the best fitness is 0.04795124271373055']
# ['At iteration 22 the best fitness is 0.04795124271373055']
# ['At iteration 23 the best fitness is 0.04795124271373055']
# ['At iteration 24 the best fitness is 0.04795124271373055']
# ['At iteration 25 the best fitness is 0.047658273963730555']
# ['At iteration 26 the best fitness is 0.047658273963730555']
# ['At iteration 27 the best fitness is 0.04283365042098442']
# ['At iteration 28 the best fitness is 0.04283365042098442']
# ['At iteration 29 the best fitness is 0.04283365042098442']
# ['At iteration 30 the best fitness is 0.04283365042098442']
#       Selected: 226/512 (44.1%), Fitness: 0.0428, Time: 584.2s
#       Modality: D=46%, S=49%, Sk=43%
#     Test Acc: 87.37%, F1: 87.70%, Features: 226/512 (44.1%), Model: 0.811MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06428058209196894']
# ['At iteration 2 the best fitness is 0.06428058209196894']
# ['At iteration 3 the best fitness is 0.06004189604922282']
# ['At iteration 4 the best fitness is 0.058967677299222816']
# ['At iteration 5 the best fitness is 0.05443602250647668']
# ['At iteration 6 the best fitness is 0.05443602250647668']
# ['At iteration 7 the best fitness is 0.05443602250647668']
# ['At iteration 8 the best fitness is 0.05443602250647668']
# ['At iteration 9 the best fitness is 0.05443602250647668']
# ['At iteration 10 the best fitness is 0.04990436771373055']
# ['At iteration 11 the best fitness is 0.04990436771373055']
# ['At iteration 12 the best fitness is 0.04990436771373055']
# ['At iteration 13 the best fitness is 0.04990436771373055']
# ['At iteration 14 the best fitness is 0.04990436771373055']
# ['At iteration 15 the best fitness is 0.04941608646373055']
# ['At iteration 16 the best fitness is 0.04566568167098442']
# ['At iteration 17 the best fitness is 0.04566568167098442']
# ['At iteration 18 the best fitness is 0.04566568167098442']
# ['At iteration 19 the best fitness is 0.04566568167098442']
# ['At iteration 20 the best fitness is 0.04566568167098442']
# ['At iteration 21 the best fitness is 0.04566568167098442']
# ['At iteration 22 the best fitness is 0.04566568167098442']
# ['At iteration 23 the best fitness is 0.04566568167098442']
# ['At iteration 24 the best fitness is 0.04566568167098442']
# ['At iteration 25 the best fitness is 0.04566568167098442']
# ['At iteration 26 the best fitness is 0.04566568167098442']
# ['At iteration 27 the best fitness is 0.04566568167098442']
# ['At iteration 28 the best fitness is 0.04566568167098442']
# ['At iteration 29 the best fitness is 0.04566568167098442']
# ['At iteration 30 the best fitness is 0.04566568167098442']
#       Selected: 267/512 (52.1%), Fitness: 0.0457, Time: 585.0s
#       Modality: D=46%, S=59%, Sk=52%
#     Test Acc: 77.27%, F1: 77.10%, Features: 267/512 (52.1%), Model: 1.058MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.057405177299222815']
# ['At iteration 1 the best fitness is 0.047169992713730555']
# ['At iteration 2 the best fitness is 0.04258014896373055']
# ['At iteration 3 the best fitness is 0.04258014896373055']
# ['At iteration 4 the best fitness is 0.03834146292098442']
# ['At iteration 5 the best fitness is 0.03834146292098442']
# ['At iteration 6 the best fitness is 0.03580240042098442']
# ['At iteration 7 the best fitness is 0.03580240042098442']
# ['At iteration 8 the best fitness is 0.03574421146373055']
# ['At iteration 9 the best fitness is 0.03418171146373055']
# ['At iteration 10 the best fitness is 0.03418171146373055']
# ['At iteration 11 the best fitness is 0.03418171146373055']
# ['At iteration 12 the best fitness is 0.03418171146373055']
# ['At iteration 13 the best fitness is 0.03418171146373055']
# ['At iteration 14 the best fitness is 0.03418171146373055']
# ['At iteration 15 the best fitness is 0.03359577396373055']
# ['At iteration 16 the best fitness is 0.03359577396373055']
# ['At iteration 17 the best fitness is 0.03359577396373055']
# ['At iteration 18 the best fitness is 0.03359577396373055']
# ['At iteration 19 the best fitness is 0.031935617713730546']
# ['At iteration 20 the best fitness is 0.031935617713730546']
# ['At iteration 21 the best fitness is 0.031935617713730546']
# ['At iteration 22 the best fitness is 0.031935617713730546']
# ['At iteration 23 the best fitness is 0.031935617713730546']
# ['At iteration 24 the best fitness is 0.031935617713730546']
# ['At iteration 25 the best fitness is 0.031935617713730546']
# ['At iteration 26 the best fitness is 0.031935617713730546']
# ['At iteration 27 the best fitness is 0.031935617713730546']
# ['At iteration 28 the best fitness is 0.031935617713730546']
# ['At iteration 29 the best fitness is 0.031935617713730546']
#       Selected: 77/512 (15.0%), Fitness: 0.0319, Time: 551.0s
#       Modality: D=22%, S=16%, Sk=14%
#     Test Acc: 75.76%, F1: 75.47%, Features: 77/512 (15.0%), Model: 0.101MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.055803210006476686']
# ['At iteration 2 the best fitness is 0.05297117875647668']
# ['At iteration 3 the best fitness is 0.05029499271373055']
# ['At iteration 4 the best fitness is 0.05029499271373055']
# ['At iteration 5 the best fitness is 0.05029499271373055']
# ['At iteration 6 the best fitness is 0.04795124271373055']
# ['At iteration 7 the best fitness is 0.04795124271373055']
# ['At iteration 8 the best fitness is 0.04795124271373055']
# ['At iteration 9 the best fitness is 0.04785358646373055']
# ['At iteration 10 the best fitness is 0.04726764896373055']
# ['At iteration 11 the best fitness is 0.047169992713730555']
# ['At iteration 12 the best fitness is 0.047169992713730555']
# ['At iteration 13 the best fitness is 0.04677936771373055']
# ['At iteration 14 the best fitness is 0.04677936771373055']
# ['At iteration 15 the best fitness is 0.04677936771373055']
# ['At iteration 16 the best fitness is 0.04677936771373055']
# ['At iteration 17 the best fitness is 0.04224771292098442']
# ['At iteration 18 the best fitness is 0.04224771292098442']
# ['At iteration 19 the best fitness is 0.04224771292098442']
# ['At iteration 20 the best fitness is 0.04224771292098442']
# ['At iteration 21 the best fitness is 0.04224771292098442']
# ['At iteration 22 the best fitness is 0.04224771292098442']
# ['At iteration 23 the best fitness is 0.04224771292098442']
# ['At iteration 24 the best fitness is 0.04224771292098442']
# ['At iteration 25 the best fitness is 0.04224771292098442']
# ['At iteration 26 the best fitness is 0.04224771292098442']
# ['At iteration 27 the best fitness is 0.04224771292098442']
# ['At iteration 28 the best fitness is 0.04224771292098442']
# ['At iteration 29 the best fitness is 0.04224771292098442']
#       Selected: 249/512 (48.6%), Fitness: 0.0422, Time: 1455.4s
#       Modality: D=49%, S=51%, Sk=48%
#     Test Acc: 85.35%, F1: 85.81%, Features: 249/512 (48.6%), Model: 0.981MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.053361803756476686']
# ['At iteration 1 the best fitness is 0.053361803756476686']
# ['At iteration 2 the best fitness is 0.04984617875647668']
# ['At iteration 3 the best fitness is 0.04984617875647668']
# ['At iteration 4 the best fitness is 0.04966958792098442']
# ['At iteration 5 the best fitness is 0.04966958792098442']
# ['At iteration 6 the best fitness is 0.04966958792098442']
# ['At iteration 7 the best fitness is 0.04966958792098442']
# ['At iteration 8 the best fitness is 0.04966958792098442']
# ['At iteration 9 the best fitness is 0.04966958792098442']
# ['At iteration 10 the best fitness is 0.04966958792098442']
# ['At iteration 11 the best fitness is 0.04966958792098442']
# ['At iteration 12 the best fitness is 0.04966958792098442']
# ['At iteration 13 the best fitness is 0.047502428756476686']
# ['At iteration 14 the best fitness is 0.047502428756476686']
# ['At iteration 15 the best fitness is 0.047502428756476686']
# ['At iteration 16 the best fitness is 0.047502428756476686']
# ['At iteration 17 the best fitness is 0.04677936771373055']
# ['At iteration 18 the best fitness is 0.04677936771373055']
# ['At iteration 19 the best fitness is 0.04410318167098442']
# ['At iteration 20 the best fitness is 0.04410318167098442']
# ['At iteration 21 the best fitness is 0.04410318167098442']
# ['At iteration 22 the best fitness is 0.04410318167098442']
# ['At iteration 23 the best fitness is 0.04410318167098442']
# ['At iteration 24 the best fitness is 0.04410318167098442']
# ['At iteration 25 the best fitness is 0.04410318167098442']
# ['At iteration 26 the best fitness is 0.04410318167098442']
# ['At iteration 27 the best fitness is 0.04410318167098442']
# ['At iteration 28 the best fitness is 0.04410318167098442']
# ['At iteration 29 the best fitness is 0.04410318167098442']
#       Selected: 239/512 (46.7%), Fitness: 0.0441, Time: 551.3s
#       Modality: D=49%, S=44%, Sk=47%
#     Test Acc: 84.85%, F1: 86.35%, Features: 239/512 (46.7%), Model: 0.905MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_25_lost/all_results_per_fold.csv
# Shape: (90, 26)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected
# 0      baseline     1            91.9580           96.0000       91.6910          91.6910              92.9140           91.9580                512             512                  100.0       0.0000          8.2310          8.2310        401174           1.5362                 4.5508                  4.5508                    0.0        26.5151             100.0000              37              100.0000               75                  100.00                400
# 1      baseline     2            83.8174           99.4565       84.2393          84.2871              86.5006           83.8017                512             512                  100.0       0.0000          9.3912          9.3912        401174           1.5362                 4.5508                  4.5508                    0.0        26.5151             100.0000              37              100.0000               75                  100.00                400
# 2      baseline     3            89.5455           96.8254       88.8479          88.8479              92.1637           89.5455                512             512                  100.0       0.0000          9.6167          9.6167        401174           1.5362                 4.5508                  4.5508                    0.0        26.5156             100.0000              37              100.0000               75                  100.00                400
# 3      baseline     4            87.2727           96.8254       85.7762          85.7762              90.6950           87.2727                512             512                  100.0       0.0000          9.3992          9.3992        401174           1.5362                 4.5508                  4.5508                    0.0        26.5156             100.0000              37              100.0000               75                  100.00                400
# 4      baseline     5            85.3535           97.4093       84.4028          84.4028              89.4831           85.3535                512             512                  100.0       0.0000          9.9074          9.9074        401174           1.5362                 4.5508                  4.5508                    0.0        26.5151             100.0000              37              100.0000               75                  100.00                400
# 5   mutual_info     1            94.4056           97.1429       94.2672          94.2672              94.7556           94.4056                256             512                   50.0       2.5301          8.2070         10.7372        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              27.0270              10               44.0000               33                   53.25                213
# 6   mutual_info     2            90.8714           99.4565       90.9737          90.9824              92.3043           90.8264                256             512                   50.0       2.4949          7.9164         10.4113        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              32.4324              12               44.0000               33                   52.75                211
# 7   mutual_info     3            90.4545           98.4127       89.9638          89.9638              92.2772           90.4545                256             512                   50.0       2.4827          9.1162         11.5990        270102           1.0362                 4.5508                  2.2754                   50.0        23.4873              37.8378              14               42.6667               32                   52.50                210
# 8   mutual_info     4            92.7273           99.4709       92.6109          92.6109              93.5286           92.7273                256             512                   50.0       2.4689          8.8785         11.3475        270102           1.0362                 4.5508                  2.2754                   50.0        23.4873              32.4324              12               42.6667               32                   53.00                212
# 9   mutual_info     5            93.4343           96.8912       93.2943          93.2943              94.0266           93.4343                256             512                   50.0       2.5016          9.3715         11.8731        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              24.3243               9               42.6667               32                   53.75                215
# 10          rfe     1            95.1049           96.0000       95.0425          95.0425              95.6223           95.1049                256             512                   50.0       0.5482          8.3969          8.9453        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              32.4324              12               46.6667               35                   52.25                209
# 11          rfe     2            87.9668           99.4565       88.6084          88.6072              91.7509           87.9339                256             512                   50.0       0.5362          8.7777          9.3142        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              24.3243               9               46.6667               35                   53.00                212
# 12          rfe     3            88.6364           97.8836       87.7286          87.7286              91.0765           88.6364                256             512                   50.0       0.5408          9.1104          9.6513        270102           1.0362                 4.5508                  2.2754                   50.0        23.4873              24.3243               9               50.6667               38                   52.25                209
# 13          rfe     4            87.7273           98.9418       86.7946          86.7946              90.2952           87.7273                256             512                   50.0       0.5459          8.8987          9.4448        270102           1.0362                 4.5508                  2.2754                   50.0        23.4873              35.1351              13               42.6667               32                   52.75                211
# 14          rfe     5            90.9091           96.8912       90.0697          90.0697              93.7695           90.9091                256             512                   50.0       0.5474          9.3288          9.8763        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              40.5405              15               44.0000               33                   52.00                208
# 15        lasso     1            87.7622           94.2857       87.3676          87.3676              88.0520           87.7622                256             512                   50.0       0.0595          8.6201          8.6797        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              97.2973              36               98.6667               74                   36.50                146
# 16        lasso     2            82.1577           97.8261       82.1663          82.1961              85.8613           82.1901                256             512                   50.0       0.0608          9.1721          9.2331        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              97.2973              36               97.3333               73                   36.75                147
# 17        lasso     3            89.0909           94.1799       88.8530          88.8530              89.7827           89.0909                256             512                   50.0       0.0637          9.2660          9.3298        270102           1.0362                 4.5508                  2.2754                   50.0        23.4873              97.2973              36               97.3333               73                   36.75                147
# 18        lasso     4            80.9091           94.7090       79.1303          79.1303              82.3038           80.9091                256             512                   50.0       0.0665          9.1068          9.1734        270102           1.0362                 4.5508                  2.2754                   50.0        23.4873              97.2973              36               97.3333               73                   36.75                147
# 19        lasso     5            72.7273           94.8187       71.7213          71.7213              77.5960           72.7273                256             512                   50.0       0.0689          9.5748          9.6438        270102           1.0362                 4.5508                  2.2754                   50.0        23.4839              97.2973              36               96.0000               72                   37.00                148

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              87.59              3.25              86.99              3.21                   512.0                      100.00              0.00                 9.31                 9.31           401174.0                  1.54                        0.00               26.52
# mutual_info              92.38              1.68              92.22              1.74                   256.0                       50.00              2.50                 8.70                11.19           270102.0                  1.04                       50.00               23.49
#         rfe              90.07              3.08              89.65              3.25                   256.0                       50.00              0.54                 8.90                 9.45           270102.0                  1.04                       50.00               23.49
#       lasso              82.53              6.51              81.85              6.88                   256.0                       50.00              0.06                 9.15                 9.21           270102.0                  1.04                       50.00               23.49
#    meta_BAT              85.17              4.90              84.82              5.07                   251.8                       49.18            568.62                 9.26               577.88           261494.2                  1.00                       50.82               23.29
#     meta_CS              85.19              2.01              84.30              2.12                   251.0                       49.02           1121.46                 9.25              1130.71           258487.2                  0.99                       50.98               23.22
#     meta_DE              83.72              3.83              82.78              4.02                   245.4                       47.93            569.88                 9.32               579.20           247916.4                  0.95                       52.07               22.98
#    meta_FFA              87.92              4.33              87.58              4.08                   248.8                       48.59            550.59                 9.25               559.84           248959.4                  0.96                       51.41               23.01
#     meta_GA              87.66              1.59              87.25              1.74                   247.8                       48.40            551.04                 9.20               560.24           253447.0                  0.97                       51.60               23.11
#    meta_GWO              86.11              3.26              85.85              3.21                   186.4                       36.41            543.96                 9.18               553.14           146686.8                  0.56                       63.59               20.66
#    meta_HHO              82.07              4.81              81.27              4.95                   184.4                       36.02            705.91                 8.98               714.89           150946.4                  0.58                       63.98               20.76
#   meta_JAYA              84.03              6.33              83.47              6.67                   250.6                       48.95            570.05                 9.26               579.31           255601.2                  0.98                       51.05               23.16
#    meta_MFO              86.79              3.62              86.12              4.19                   247.4                       48.32            533.56                 9.27               542.83           252586.6                  0.97                       51.68               23.09
#    meta_MVO              87.81              4.34              87.53              4.65                   244.4                       47.73            551.43                 9.18               560.61           244622.4                  0.94                       52.27               22.91
#    meta_PSO              85.59              5.86              85.10              5.67                   240.0                       46.88            551.95                 9.21               561.16           235554.6                  0.90                       53.12               22.70
#    meta_SCA              79.14              9.51              78.80              9.70                   100.0                       19.53            523.10                 8.56               531.66            43992.4                  0.17                       80.47               18.29
#    meta_SSA              87.08              3.45              86.90              3.32                   247.0                       48.24           1375.31                 9.18              1384.49           250987.2                  0.96                       51.76               23.05
#    meta_WOA              83.29              3.84              82.69              4.58                   144.6                       28.24            494.77                 8.77               503.54            97422.2                  0.37                       71.76               19.53

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 92.38% vs Baseline: 87.59%
#   Paired t-test: t=3.5237, p=0.0244
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> better, Significant
#
# RFE vs BASELINE:
#   Method: 90.07% vs Baseline: 87.59%
#   Paired t-test: t=2.0852, p=0.1054
#   Wilcoxon test: W=2.0000, p=0.1875
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 82.53% vs Baseline: 87.59%
#   Paired t-test: t=-2.3533, p=0.0782
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 85.17% vs Baseline: 87.59%
#   Paired t-test: t=-1.4217, p=0.2282
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 85.19% vs Baseline: 87.59%
#   Paired t-test: t=-1.5480, p=0.1965
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 83.72% vs Baseline: 87.59%
#   Paired t-test: t=-4.6650, p=0.0096
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_FFA vs BASELINE:
#   Method: 87.92% vs Baseline: 87.59%
#   Paired t-test: t=0.2614, p=0.8067
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> better, Not significant
#
# META_GA vs BASELINE:
#   Method: 87.66% vs Baseline: 87.59%
#   Paired t-test: t=0.0517, p=0.9613
#   Wilcoxon test: W=6.0000, p=0.8125
#   -> better, Not significant
#
# META_GWO vs BASELINE:
#   Method: 86.11% vs Baseline: 87.59%
#   Paired t-test: t=-1.8796, p=0.1333
#   Wilcoxon test: W=2.0000, p=0.1875
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 82.07% vs Baseline: 87.59%
#   Paired t-test: t=-4.3766, p=0.0119
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_JAYA vs BASELINE:
#   Method: 84.03% vs Baseline: 87.59%
#   Paired t-test: t=-1.7782, p=0.1500
#   Wilcoxon test: W=1.0000, p=0.2500
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 86.79% vs Baseline: 87.59%
#   Paired t-test: t=-0.4862, p=0.6523
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 87.81% vs Baseline: 87.59%
#   Paired t-test: t=0.2277, p=0.8311
#   Wilcoxon test: W=6.0000, p=0.8125
#   -> better, Not significant
#
# META_PSO vs BASELINE:
#   Method: 85.59% vs Baseline: 87.59%
#   Paired t-test: t=-1.2525, p=0.2786
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 79.14% vs Baseline: 87.59%
#   Paired t-test: t=-2.3635, p=0.0774
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 87.08% vs Baseline: 87.59%
#   Paired t-test: t=-0.5376, p=0.6194
#   Wilcoxon test: W=3.0000, p=0.6250
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 83.29% vs Baseline: 87.59%
#   Paired t-test: t=-3.4507, p=0.0260
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_25_lost
#
# Per-method folders:
#   results_25_lost/baseline/ (10 files)
#   results_25_lost/mutual_info/ (10 files)
#   results_25_lost/rfe/ (10 files)
#   results_25_lost/lasso/ (10 files)
#   results_25_lost/meta_BAT/ (10 files)
#   results_25_lost/meta_CS/ (10 files)
#   results_25_lost/meta_DE/ (10 files)
#   results_25_lost/meta_FFA/ (10 files)
#   results_25_lost/meta_GA/ (10 files)
#   results_25_lost/meta_GWO/ (10 files)
#   results_25_lost/meta_HHO/ (10 files)
#   results_25_lost/meta_JAYA/ (10 files)
#   results_25_lost/meta_MFO/ (10 files)
#   results_25_lost/meta_MVO/ (10 files)
#   results_25_lost/meta_PSO/ (10 files)
#   results_25_lost/meta_SCA/ (10 files)
#   results_25_lost/meta_SSA/ (10 files)
#   results_25_lost/meta_WOA/ (10 files)
#
# Plots directory: results_25_lost/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   mutual_info         : 92.38% ± 1.68% (Features: 50.0%)
#   rfe                 : 90.07% ± 3.08% (Features: 50.0%)
#   meta_FFA            : 87.92% ± 4.33% (Features: 48.6%)
#   meta_MVO            : 87.81% ± 4.34% (Features: 47.7%)
#   meta_GA             : 87.66% ± 1.59% (Features: 48.4%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_SCA
#     Test Accuracy:      94.76%
#     Feature Retention:  20.90% (107/512)
#     Modality Retention: depth=16.2%, sensor=21.3%, skeleton=21.2%
#
#   Fold 2: Best = meta_GA
#     Test Accuracy:      86.72%
#     Feature Retention:  48.44% (248/512)
#     Modality Retention: depth=48.6%, sensor=50.7%, skeleton=48.0%
#
#   Fold 3: Best = meta_FFA
#     Test Accuracy:      91.36%
#     Feature Retention:  54.49% (279/512)
#     Modality Retention: depth=48.6%, sensor=57.3%, skeleton=54.5%
#
#   Fold 4: Best = meta_FFA
#     Test Accuracy:      90.00%
#     Feature Retention:  46.09% (236/512)
#     Modality Retention: depth=40.5%, sensor=50.7%, skeleton=45.8%
#
#   Fold 5: Best = meta_MFO
#     Test Accuracy:      88.38%
#     Feature Retention:  49.22% (252/512)
#     Modality Retention: depth=45.9%, sensor=45.3%, skeleton=50.2%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     90.24% ± 3.06%
#   Average Feature Retention: 43.83% ± 13.18%
#
#   Average Modality-wise Feature Retention:
#          depth: 40.00% ± 13.70%
#         sensor: 45.07% ± 13.93%
#       skeleton: 43.95% ± 13.10%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)
#     1           meta_SCA              94.76                  20.90                16.22                 21.33                   21.25
#     2            meta_GA              86.72                  48.44                48.65                 50.67                   48.00
#     3           meta_FFA              91.36                  54.49                48.65                 57.33                   54.50
#     4           meta_FFA              90.00                  46.09                40.54                 50.67                   45.75
#     5           meta_MFO              88.38                  49.22                45.95                 45.33                   50.25
#
# Saved to: results_25_lost/best_metaheuristic_per_fold.csv
