# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new")

# Master output directory
RESULTS_ROOT = Path("results_25_lost_new")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   TOTAL: 2513

# %%
# ============================================================================
# SIMULATE 10% DATA LOSS ON EXTRACTED FEATURES
# ============================================================================
# Randomly zero out 10% of feature values across ALL samples and ALL modalities.
# This corrupts the already-extracted features in-place before the pipeline runs.
# ============================================================================

DATA_LOSS_RATIO = 0.25  # 10% of feature values will be set to 0
CORRUPTION_SEED = 42    # For reproducibility

rng = np.random.RandomState(CORRUPTION_SEED)

modalities = ['depth_feat', 'sensor_feat', 'skeleton_feat']

total_values = 0
total_corrupted = 0
per_modality_stats = {m: {'total': 0, 'corrupted': 0} for m in modalities}

for sample in X_feat:
    for mod in modalities:
        feat = sample[mod]
        n = feat.shape[0]
        # Create a random mask: True means this value gets zeroed out
        loss_mask = rng.rand(n) < DATA_LOSS_RATIO
        n_corrupted = np.sum(loss_mask)
        feat[loss_mask] = 0.0  # Set lost values to 0
        
        total_values += n
        total_corrupted += n_corrupted
        per_modality_stats[mod]['total'] += n
        per_modality_stats[mod]['corrupted'] += n_corrupted

print(f"{'='*60}")
print(f"DATA CORRUPTION APPLIED: {DATA_LOSS_RATIO*100:.0f}% random data loss")
print(f"{'='*60}")
print(f"Total feature values:   {total_values:,}")
print(f"Values zeroed out:      {total_corrupted:,} ({total_corrupted/total_values*100:.2f}%)")
print(f"")
print(f"Per-modality breakdown:")
for mod in modalities:
    s = per_modality_stats[mod]
    print(f"  {mod:15s}: {s['corrupted']:>6,} / {s['total']:>8,} zeroed ({s['corrupted']/s['total']*100:.2f}%)")
print(f"{'='*60}")
# Out:
# ============================================================
# DATA CORRUPTION APPLIED: 25% random data loss
# ============================================================
# Total feature values:   2,927,645
# Values zeroed out:      731,571 (24.99%)
#
# Per-modality breakdown:
#   depth_feat     : 62,921 /  251,640 zeroed (25.00%)
#   sensor_feat    : 189,631 /  759,580 zeroed (24.97%)
#   skeleton_feat  : 479,019 / 1,916,425 zeroed (25.00%)
# ============================================================

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 92.66%, F1: 92.75%, Features: 2513/2513 (100.0%), Model: 5.444MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1256/2513 (50.0%), Time: 12.4s
#     Test Acc: 94.06%, F1: 94.13%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1256/2513 (50.0%), Time: 2.6s
#     Test Acc: 94.06%, F1: 94.08%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1256/2513 (50.0%), Time: 0.5s
#     Test Acc: 82.87%, F1: 82.82%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05684520493434139']
# ['At iteration 1 the best fitness is 0.05684520493434139']
# ['At iteration 2 the best fitness is 0.05684520493434139']
# ['At iteration 3 the best fitness is 0.05684520493434139']
# ['At iteration 4 the best fitness is 0.05684520493434139']
# ['At iteration 5 the best fitness is 0.05684520493434139']
# ['At iteration 6 the best fitness is 0.05684520493434139']
# ['At iteration 7 the best fitness is 0.05684520493434139']
# ['At iteration 8 the best fitness is 0.05684520493434139']
# ['At iteration 9 the best fitness is 0.0514365300437724']
# ['At iteration 10 the best fitness is 0.0514365300437724']
# ['At iteration 11 the best fitness is 0.0514365300437724']
# ['At iteration 12 the best fitness is 0.0514365300437724']
# ['At iteration 13 the best fitness is 0.0514365300437724']
# ['At iteration 14 the best fitness is 0.0514365300437724']
# ['At iteration 15 the best fitness is 0.0514365300437724']
# ['At iteration 16 the best fitness is 0.0514365300437724']
# ['At iteration 17 the best fitness is 0.0514365300437724']
# ['At iteration 18 the best fitness is 0.05141663350577']
# ['At iteration 19 the best fitness is 0.05141663350577']
# ['At iteration 20 the best fitness is 0.05141663350577']
# ['At iteration 21 the best fitness is 0.05141663350577']
# ['At iteration 22 the best fitness is 0.05141663350577']
# ['At iteration 23 the best fitness is 0.05141663350577']
# ['At iteration 24 the best fitness is 0.05141663350577']
# ['At iteration 25 the best fitness is 0.05141663350577']
# ['At iteration 26 the best fitness is 0.05141663350577']
# ['At iteration 27 the best fitness is 0.05141663350577']
# ['At iteration 28 the best fitness is 0.05141663350577']
# ['At iteration 29 the best fitness is 0.05141663350577']
#       Selected: 1232/2513 (49.0%), Fitness: 0.0514, Time: 850.7s
#       Modality: D=50%, S=49%, Sk=49%
#     Test Acc: 89.86%, F1: 90.22%, Features: 1232/2513 (49.0%), Model: 2.942MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07370791882212491']
# ['At iteration 10 the best fitness is 0.05193394349383208']
# ['At iteration 20 the best fitness is 0.05193394349383208']
#       Selected: 1236/2513 (49.2%), Fitness: 0.0519, Time: 1700.6s
#       Modality: D=47%, S=49%, Sk=50%
#     Test Acc: 88.81%, F1: 89.09%, Features: 1236/2513 (49.2%), Model: 2.950MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06330839633903704']
# ['At iteration 2 the best fitness is 0.057999204138479865']
# ['At iteration 3 the best fitness is 0.057999204138479865']
# ['At iteration 4 the best fitness is 0.05793951452447271']
# ['At iteration 5 the best fitness is 0.05203342618384402']
# ['At iteration 6 the best fitness is 0.05203342618384402']
# ['At iteration 7 the best fitness is 0.05203342618384402']
# ['At iteration 8 the best fitness is 0.05203342618384402']
# ['At iteration 9 the best fitness is 0.05203342618384402']
# ['At iteration 10 the best fitness is 0.05203342618384402']
# ['At iteration 11 the best fitness is 0.05203342618384402']
# ['At iteration 12 the best fitness is 0.05203342618384402']
# ['At iteration 13 the best fitness is 0.05203342618384402']
# ['At iteration 14 the best fitness is 0.05167528849980105']
# ['At iteration 15 the best fitness is 0.0515957023477915']
# ['At iteration 16 the best fitness is 0.0515957023477915']
# ['At iteration 17 the best fitness is 0.0515957023477915']
# ['At iteration 18 the best fitness is 0.0515957023477915']
# ['At iteration 19 the best fitness is 0.05145642658177478']
# ['At iteration 20 the best fitness is 0.05145642658177478']
# ['At iteration 21 the best fitness is 0.05145642658177478']
# ['At iteration 22 the best fitness is 0.04700278551532038']
# ['At iteration 23 the best fitness is 0.04089773179466771']
# ['At iteration 24 the best fitness is 0.04089773179466771']
# ['At iteration 25 the best fitness is 0.04089773179466771']
# ['At iteration 26 the best fitness is 0.04089773179466771']
# ['At iteration 27 the best fitness is 0.04089773179466771']
# ['At iteration 28 the best fitness is 0.04089773179466771']
# ['At iteration 29 the best fitness is 0.04089773179466771']
# ['At iteration 30 the best fitness is 0.04089773179466771']
#       Selected: 1235/2513 (49.1%), Fitness: 0.0409, Time: 863.5s
#       Modality: D=51%, S=47%, Sk=50%
#     Test Acc: 89.16%, F1: 88.99%, Features: 1235/2513 (49.1%), Model: 2.948MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06293036211699168']
# ['At iteration 1 the best fitness is 0.0689558296856347']
# ['At iteration 2 the best fitness is 0.07402626343016311']
# ['At iteration 3 the best fitness is 0.0571436530043772']
# ['At iteration 4 the best fitness is 0.063049741345006']
# ['At iteration 5 the best fitness is 0.05193394349383208']
# ['At iteration 6 the best fitness is 0.05722323915638675']
# ['At iteration 7 the best fitness is 0.046246717071229654']
# ['At iteration 8 the best fitness is 0.05145642658177478']
# ['At iteration 9 the best fitness is 0.05704417031436527']
# ['At iteration 10 the best fitness is 0.0517349781138082']
# ['At iteration 11 the best fitness is 0.062393155590927216']
# ['At iteration 12 the best fitness is 0.0624130521289296']
# ['At iteration 13 the best fitness is 0.05720334261838437']
# ['At iteration 14 the best fitness is 0.062472741742936766']
# ['At iteration 15 the best fitness is 0.0571436530043772']
# ['At iteration 16 the best fitness is 0.051715081575805816']
# ['At iteration 17 the best fitness is 0.06790131317150816']
# ['At iteration 18 the best fitness is 0.06251253481894153']
# ['At iteration 19 the best fitness is 0.06255232789494632']
# ['At iteration 20 the best fitness is 0.06800079586152008']
# ['At iteration 21 the best fitness is 0.0625722244329487']
# ['At iteration 22 the best fitness is 0.0625722244329487']
# ['At iteration 23 the best fitness is 0.0625722244329487']
# ['At iteration 24 the best fitness is 0.0625722244329487']
# ['At iteration 25 the best fitness is 0.051715081575805816']
# ['At iteration 26 the best fitness is 0.06800079586152008']
# ['At iteration 27 the best fitness is 0.06800079586152008']
# ['At iteration 28 the best fitness is 0.06800079586152008']
# ['At iteration 29 the best fitness is 0.0625722244329487']
#       Selected: 1277/2513 (50.8%), Fitness: 0.0626, Time: 832.5s
#       Modality: D=44%, S=53%, Sk=51%
#     Test Acc: 89.51%, F1: 89.60%, Features: 1277/2513 (50.8%), Model: 3.030MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.07366812574612012
# At iteration 2 the best fitness is 0.07350895344210102
# At iteration 3 the best fitness is 0.05690489454834855
# At iteration 4 the best fitness is 0.06778193394349383
# At iteration 5 the best fitness is 0.062353362514922434
# At iteration 6 the best fitness is 0.0624130521289296
# At iteration 7 the best fitness is 0.06794110624751293
# At iteration 8 the best fitness is 0.06255232789494632
# At iteration 9 the best fitness is 0.06251253481894153
# At iteration 10 the best fitness is 0.06251253481894153
# At iteration 11 the best fitness is 0.06237325905292483
# At iteration 12 the best fitness is 0.06227377636291288
# At iteration 13 the best fitness is 0.06245284520493438
# At iteration 14 the best fitness is 0.0624130521289296
# At iteration 15 the best fitness is 0.05684520493434139
# At iteration 16 the best fitness is 0.06255232789494632
# At iteration 17 the best fitness is 0.05736251492240347
# At iteration 18 the best fitness is 0.05692479108635094
# At iteration 19 the best fitness is 0.05684520493434139
# At iteration 20 the best fitness is 0.05692479108635094
# At iteration 21 the best fitness is 0.04598806207719862
# At iteration 22 the best fitness is 0.05692479108635094
# At iteration 23 the best fitness is 0.05141663350577
# At iteration 24 the best fitness is 0.05197373656983685
# At iteration 25 the best fitness is 0.05149621965777955
# At iteration 26 the best fitness is 0.051715081575805816
# At iteration 27 the best fitness is 0.05694468762435333
# At iteration 28 the best fitness is 0.046187027457222495
# At iteration 29 the best fitness is 0.046266613609232045
# At iteration 30 the best fitness is 0.05712375646637482
#       Selected: 1264/2513 (50.3%), Fitness: 0.0571, Time: 831.8s
#       Modality: D=50%, S=52%, Sk=50%
#     Test Acc: 91.61%, F1: 91.66%, Features: 1264/2513 (50.3%), Model: 3.005MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06295025865499407']
# ['At iteration 1 the best fitness is 0.06295025865499407']
# ['At iteration 2 the best fitness is 0.06295025865499407']
# ['At iteration 3 the best fitness is 0.06295025865499407']
# ['At iteration 4 the best fitness is 0.05988619180262637']
# ['At iteration 5 the best fitness is 0.05988619180262637']
# ['At iteration 6 the best fitness is 0.05988619180262637']
# ['At iteration 7 the best fitness is 0.05942857142857146']
# ['At iteration 8 the best fitness is 0.05942857142857146']
# ['At iteration 9 the best fitness is 0.05926939912455236']
# ['At iteration 10 the best fitness is 0.05871229606048551']
# ['At iteration 11 the best fitness is 0.05833426183844015']
# ['At iteration 12 the best fitness is 0.05833426183844015']
# ['At iteration 13 the best fitness is 0.05833426183844015']
# ['At iteration 14 the best fitness is 0.05833426183844015']
# ['At iteration 15 the best fitness is 0.05833426183844015']
# ['At iteration 16 the best fitness is 0.057916434540390006']
# ['At iteration 17 the best fitness is 0.04717867091126145']
# ['At iteration 18 the best fitness is 0.04682053322721847']
# ['At iteration 19 the best fitness is 0.04682053322721847']
# ['At iteration 20 the best fitness is 0.04123278949462798']
# ['At iteration 21 the best fitness is 0.04123278949462798']
# ['At iteration 22 the best fitness is 0.04123278949462798']
# ['At iteration 23 the best fitness is 0.04123278949462798']
# ['At iteration 24 the best fitness is 0.04123278949462798']
# ['At iteration 25 the best fitness is 0.04123278949462798']
# ['At iteration 26 the best fitness is 0.04123278949462798']
# ['At iteration 27 the best fitness is 0.04123278949462798']
# ['At iteration 28 the best fitness is 0.04123278949462798']
# ['At iteration 29 the best fitness is 0.04123278949462798']
#       Selected: 1053/2513 (41.9%), Fitness: 0.0412, Time: 814.8s
#       Modality: D=42%, S=43%, Sk=41%
#     Test Acc: 88.81%, F1: 88.84%, Features: 1053/2513 (41.9%), Model: 2.593MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.0628905690409869']
# ['At iteration 1 the best fitness is 0.0628905690409869']
# ['At iteration 2 the best fitness is 0.0628905690409869']
# ['At iteration 3 the best fitness is 0.0628905690409869']
# ['At iteration 4 the best fitness is 0.0628905690409869']
# ['At iteration 5 the best fitness is 0.0628905690409869']
# ['At iteration 6 the best fitness is 0.0628905690409869']
# ['At iteration 7 the best fitness is 0.0628905690409869']
# ['At iteration 8 the best fitness is 0.0628905690409869']
# ['At iteration 9 the best fitness is 0.0628905690409869']
# ['At iteration 10 the best fitness is 0.0628905690409869']
# ['At iteration 11 the best fitness is 0.0628905690409869']
# ['At iteration 12 the best fitness is 0.0628905690409869']
# ['At iteration 13 the best fitness is 0.0628905690409869']
# ['At iteration 14 the best fitness is 0.0628905690409869']
# ['At iteration 15 the best fitness is 0.0628905690409869']
# ['At iteration 16 the best fitness is 0.0628905690409869']
# ['At iteration 17 the best fitness is 0.0628905690409869']
# ['At iteration 18 the best fitness is 0.0628905690409869']
# ['At iteration 19 the best fitness is 0.0628905690409869']
# ['At iteration 20 the best fitness is 0.0628905690409869']
# ['At iteration 21 the best fitness is 0.0628905690409869']
# ['At iteration 22 the best fitness is 0.0628905690409869']
# ['At iteration 23 the best fitness is 0.0628905690409869']
# ['At iteration 24 the best fitness is 0.0628905690409869']
# ['At iteration 25 the best fitness is 0.0628905690409869']
# ['At iteration 26 the best fitness is 0.0628905690409869']
# ['At iteration 27 the best fitness is 0.0628905690409869']
# ['At iteration 28 the best fitness is 0.0628905690409869']
# ['At iteration 29 the best fitness is 0.0628905690409869']
#       Selected: 1272/2513 (50.6%), Fitness: 0.0629, Time: 1090.1s
#       Modality: D=48%, S=51%, Sk=51%
#     Test Acc: 90.56%, F1: 90.61%, Features: 1272/2513 (50.6%), Model: 3.021MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0625722244329487']
# ['At iteration 1 the best fitness is 0.0625722244329487']
# ['At iteration 2 the best fitness is 0.0625722244329487']
# ['At iteration 3 the best fitness is 0.06255232789494632']
# ['At iteration 4 the best fitness is 0.06255232789494632']
# ['At iteration 5 the best fitness is 0.06255232789494632']
# ['At iteration 6 the best fitness is 0.06255232789494632']
# ['At iteration 7 the best fitness is 0.06255232789494632']
# ['At iteration 8 the best fitness is 0.06255232789494632']
# ['At iteration 9 the best fitness is 0.05782013529645838']
# ['At iteration 10 the best fitness is 0.057720652606446446']
# ['At iteration 11 the best fitness is 0.05213290887385595']
# ['At iteration 12 the best fitness is 0.05213290887385595']
# ['At iteration 13 the best fitness is 0.05213290887385595']
# ['At iteration 14 the best fitness is 0.05213290887385595']
# ['At iteration 15 the best fitness is 0.05213290887385595']
# ['At iteration 16 the best fitness is 0.05213290887385595']
# ['At iteration 17 the best fitness is 0.05213290887385595']
# ['At iteration 18 the best fitness is 0.05213290887385595']
# ['At iteration 19 the best fitness is 0.05213290887385595']
# ['At iteration 20 the best fitness is 0.05199363310783925']
# ['At iteration 21 the best fitness is 0.05199363310783925']
# ['At iteration 22 the best fitness is 0.05199363310783925']
# ['At iteration 23 the best fitness is 0.05199363310783925']
# ['At iteration 24 the best fitness is 0.05199363310783925']
# ['At iteration 25 the best fitness is 0.05199363310783925']
# ['At iteration 26 the best fitness is 0.05199363310783925']
# ['At iteration 27 the best fitness is 0.05199363310783925']
# ['At iteration 28 the best fitness is 0.05199363310783925']
# ['At iteration 29 the best fitness is 0.05199363310783925']
#       Selected: 1262/2513 (50.2%), Fitness: 0.0520, Time: 869.6s
#       Modality: D=50%, S=50%, Sk=50%
#     Test Acc: 88.11%, F1: 88.16%, Features: 1262/2513 (50.2%), Model: 3.001MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07851969757262238']
# ['At iteration 2 the best fitness is 0.06915479506565857']
# ['At iteration 3 the best fitness is 0.06394508555511344']
# ['At iteration 4 the best fitness is 0.06394508555511344']
# ['At iteration 5 the best fitness is 0.06394508555511344']
# ['At iteration 6 the best fitness is 0.06394508555511344']
# ['At iteration 7 the best fitness is 0.05274970155192997']
# ['At iteration 8 the best fitness is 0.05274970155192997']
# ['At iteration 9 the best fitness is 0.05274970155192997']
# ['At iteration 10 the best fitness is 0.05274970155192997']
# ['At iteration 11 the best fitness is 0.05274970155192997']
# ['At iteration 12 the best fitness is 0.05274970155192997']
# ['At iteration 13 the best fitness is 0.05274970155192997']
# ['At iteration 14 the best fitness is 0.05274970155192997']
# ['At iteration 15 the best fitness is 0.05274970155192997']
# ['At iteration 16 the best fitness is 0.05274970155192997']
# ['At iteration 17 the best fitness is 0.04837564663748513']
# ['At iteration 18 the best fitness is 0.04821647433346603']
# ['At iteration 19 the best fitness is 0.04821647433346603']
# ['At iteration 20 the best fitness is 0.04821647433346603']
# ['At iteration 21 the best fitness is 0.04821647433346603']
# ['At iteration 22 the best fitness is 0.04821647433346603']
# ['At iteration 23 the best fitness is 0.04821647433346603']
# ['At iteration 24 the best fitness is 0.04821647433346603']
# ['At iteration 25 the best fitness is 0.04821647433346603']
# ['At iteration 26 the best fitness is 0.04821647433346603']
# ['At iteration 27 the best fitness is 0.04821647433346603']
# ['At iteration 28 the best fitness is 0.042668523676880205']
# ['At iteration 29 the best fitness is 0.042668523676880205']
#       Selected: 1313/2513 (52.2%), Fitness: 0.0427, Time: 816.5s
#       Modality: D=57%, S=53%, Sk=51%
#     Test Acc: 90.56%, F1: 90.76%, Features: 1313/2513 (52.2%), Model: 3.101MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0686175885395941']
# ['At iteration 2 the best fitness is 0.06310943095901317']
# ['At iteration 3 the best fitness is 0.06310943095901317']
# ['At iteration 4 the best fitness is 0.05728292877039392']
# ['At iteration 5 the best fitness is 0.05215280541185834']
# ['At iteration 6 the best fitness is 0.05215280541185834']
# ['At iteration 7 the best fitness is 0.05215280541185834']
# ['At iteration 8 the best fitness is 0.05215280541185834']
# ['At iteration 9 the best fitness is 0.05215280541185834']
# ['At iteration 10 the best fitness is 0.05215280541185834']
# ['At iteration 11 the best fitness is 0.05215280541185834']
# ['At iteration 12 the best fitness is 0.05215280541185834']
# ['At iteration 13 the best fitness is 0.05215280541185834']
# ['At iteration 14 the best fitness is 0.05215280541185834']
# ['At iteration 15 the best fitness is 0.05215280541185834']
# ['At iteration 16 the best fitness is 0.05215280541185834']
# ['At iteration 17 the best fitness is 0.05215280541185834']
# ['At iteration 18 the best fitness is 0.05215280541185834']
# ['At iteration 19 the best fitness is 0.05215280541185834']
# ['At iteration 20 the best fitness is 0.05215280541185834']
# ['At iteration 21 the best fitness is 0.05215280541185834']
# ['At iteration 22 the best fitness is 0.05215280541185834']
# ['At iteration 23 the best fitness is 0.05215280541185834']
# ['At iteration 24 the best fitness is 0.05215280541185834']
# ['At iteration 25 the best fitness is 0.05215280541185834']
# ['At iteration 26 the best fitness is 0.05215280541185834']
# ['At iteration 27 the best fitness is 0.05215280541185834']
# ['At iteration 28 the best fitness is 0.05215280541185834']
# ['At iteration 29 the best fitness is 0.05215280541185834']
# ['At iteration 30 the best fitness is 0.05215280541185834']
#       Selected: 1240/2513 (49.3%), Fitness: 0.0522, Time: 835.4s
#       Modality: D=50%, S=51%, Sk=49%
#     Test Acc: 92.66%, F1: 92.56%, Features: 1240/2513 (49.3%), Model: 2.958MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.057561480302427345']
# ['At iteration 2 the best fitness is 0.057561480302427345']
# ['At iteration 3 the best fitness is 0.057561480302427345']
# ['At iteration 4 the best fitness is 0.057561480302427345']
# ['At iteration 5 the best fitness is 0.057561480302427345']
# ['At iteration 6 the best fitness is 0.057561480302427345']
# ['At iteration 7 the best fitness is 0.057561480302427345']
# ['At iteration 8 the best fitness is 0.052849184241941904']
# ['At iteration 9 the best fitness is 0.052849184241941904']
# ['At iteration 10 the best fitness is 0.052849184241941904']
# ['At iteration 11 the best fitness is 0.052849184241941904']
# ['At iteration 12 the best fitness is 0.052849184241941904']
# ['At iteration 13 the best fitness is 0.052849184241941904']
# ['At iteration 14 the best fitness is 0.052849184241941904']
# ['At iteration 15 the best fitness is 0.052849184241941904']
# ['At iteration 16 the best fitness is 0.052849184241941904']
# ['At iteration 17 the best fitness is 0.052849184241941904']
# ['At iteration 18 the best fitness is 0.052849184241941904']
# ['At iteration 19 the best fitness is 0.052849184241941904']
# ['At iteration 20 the best fitness is 0.052849184241941904']
# ['At iteration 21 the best fitness is 0.052849184241941904']
# ['At iteration 22 the best fitness is 0.052849184241941904']
# ['At iteration 23 the best fitness is 0.052849184241941904']
# ['At iteration 24 the best fitness is 0.052252288101870284']
# ['At iteration 25 the best fitness is 0.04676402705929174']
# ['At iteration 26 the best fitness is 0.04676402705929174']
# ['At iteration 27 the best fitness is 0.04676402705929174']
# ['At iteration 28 the best fitness is 0.04676402705929174']
# ['At iteration 29 the best fitness is 0.04676402705929174']
# ['At iteration 30 the best fitness is 0.04676402705929174']
#       Selected: 1274/2513 (50.7%), Fitness: 0.0468, Time: 843.2s
#       Modality: D=47%, S=54%, Sk=50%
#     Test Acc: 91.26%, F1: 91.33%, Features: 1274/2513 (50.7%), Model: 3.025MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.062393155590927216']
# ['At iteration 1 the best fitness is 0.062393155590927216']
# ['At iteration 2 the best fitness is 0.062393155590927216']
# ['At iteration 3 the best fitness is 0.062393155590927216']
# ['At iteration 4 the best fitness is 0.062393155590927216']
# ['At iteration 5 the best fitness is 0.059070433744528486']
# ['At iteration 6 the best fitness is 0.059070433744528486']
# ['At iteration 7 the best fitness is 0.059070433744528486']
# ['At iteration 8 the best fitness is 0.059070433744528486']
# ['At iteration 9 the best fitness is 0.059070433744528486']
# ['At iteration 10 the best fitness is 0.059070433744528486']
# ['At iteration 11 the best fitness is 0.059070433744528486']
# ['At iteration 12 the best fitness is 0.059070433744528486']
# ['At iteration 13 the best fitness is 0.059070433744528486']
# ['At iteration 14 the best fitness is 0.059070433744528486']
# ['At iteration 15 the best fitness is 0.059047353760445676']
# ['At iteration 16 the best fitness is 0.059047353760445676']
# ['At iteration 17 the best fitness is 0.059047353760445676']
# ['At iteration 18 the best fitness is 0.059047353760445676']
# ['At iteration 19 the best fitness is 0.059047353760445676']
# ['At iteration 20 the best fitness is 0.059047353760445676']
# ['At iteration 21 the best fitness is 0.059047353760445676']
# ['At iteration 22 the best fitness is 0.059047353760445676']
# ['At iteration 23 the best fitness is 0.059047353760445676']
# ['At iteration 24 the best fitness is 0.059047353760445676']
# ['At iteration 25 the best fitness is 0.059047353760445676']
# ['At iteration 26 the best fitness is 0.059047353760445676']
# ['At iteration 27 the best fitness is 0.059047353760445676']
# ['At iteration 28 the best fitness is 0.059047353760445676']
# ['At iteration 29 the best fitness is 0.05610266613609231']
#       Selected: 689/2513 (27.4%), Fitness: 0.0561, Time: 817.2s
#       Modality: D=27%, S=26%, Sk=28%
#     Test Acc: 84.97%, F1: 84.64%, Features: 689/2513 (27.4%), Model: 1.882MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05161559888579388']
# ['At iteration 2 the best fitness is 0.05161559888579388']
# ['At iteration 3 the best fitness is 0.05161559888579388']
# ['At iteration 4 the best fitness is 0.05161559888579388']
# ['At iteration 5 the best fitness is 0.05161559888579388']
# ['At iteration 6 the best fitness is 0.05161559888579388']
# ['At iteration 7 the best fitness is 0.05161559888579388']
# ['At iteration 8 the best fitness is 0.04662475129327502']
# ['At iteration 9 the best fitness is 0.04662475129327502']
# ['At iteration 10 the best fitness is 0.04662475129327502']
# ['At iteration 11 the best fitness is 0.04662475129327502']
# ['At iteration 12 the best fitness is 0.04662475129327502']
# ['At iteration 13 the best fitness is 0.04662475129327502']
# ['At iteration 14 the best fitness is 0.04662475129327502']
# ['At iteration 15 the best fitness is 0.04662475129327502']
# ['At iteration 16 the best fitness is 0.04662475129327502']
# ['At iteration 17 the best fitness is 0.04662475129327502']
# ['At iteration 18 the best fitness is 0.04662475129327502']
# ['At iteration 19 the best fitness is 0.04662475129327502']
# ['At iteration 20 the best fitness is 0.04662475129327502']
# ['At iteration 21 the best fitness is 0.04662475129327502']
# ['At iteration 22 the best fitness is 0.04662475129327502']
# ['At iteration 23 the best fitness is 0.04662475129327502']
# ['At iteration 24 the best fitness is 0.04662475129327502']
# ['At iteration 25 the best fitness is 0.04662475129327502']
# ['At iteration 26 the best fitness is 0.04662475129327502']
# ['At iteration 27 the best fitness is 0.04662475129327502']
# ['At iteration 28 the best fitness is 0.04662475129327502']
# ['At iteration 29 the best fitness is 0.04662475129327502']
#       Selected: 1270/2513 (50.5%), Fitness: 0.0466, Time: 2062.1s
#       Modality: D=53%, S=50%, Sk=50%
#     Test Acc: 88.46%, F1: 87.87%, Features: 1270/2513 (50.5%), Model: 3.017MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05736251492240347']
# ['At iteration 1 the best fitness is 0.05736251492240347']
# ['At iteration 2 the best fitness is 0.05736251492240347']
# ['At iteration 3 the best fitness is 0.05736251492240347']
# ['At iteration 4 the best fitness is 0.05736251492240347']
# ['At iteration 5 the best fitness is 0.05736251492240347']
# ['At iteration 6 the best fitness is 0.05736251492240347']
# ['At iteration 7 the best fitness is 0.05545563072025468']
# ['At iteration 8 the best fitness is 0.05545563072025468']
# ['At iteration 9 the best fitness is 0.05545563072025468']
# ['At iteration 10 the best fitness is 0.05545563072025468']
# ['At iteration 11 the best fitness is 0.05545563072025468']
# ['At iteration 12 the best fitness is 0.05545563072025468']
# ['At iteration 13 the best fitness is 0.05545563072025468']
# ['At iteration 14 the best fitness is 0.05545563072025468']
# ['At iteration 15 the best fitness is 0.05545563072025468']
# ['At iteration 16 the best fitness is 0.05545563072025468']
# ['At iteration 17 the best fitness is 0.05545563072025468']
# ['At iteration 18 the best fitness is 0.05545563072025468']
# ['At iteration 19 the best fitness is 0.05545563072025468']
# ['At iteration 20 the best fitness is 0.05537604456824513']
# ['At iteration 21 the best fitness is 0.05537604456824513']
# ['At iteration 22 the best fitness is 0.05475925189017111']
# ['At iteration 23 the best fitness is 0.05475925189017111']
# ['At iteration 24 the best fitness is 0.05475925189017111']
# ['At iteration 25 the best fitness is 0.05475925189017111']
# ['At iteration 26 the best fitness is 0.05475925189017111']
# ['At iteration 27 the best fitness is 0.05475925189017111']
# ['At iteration 28 the best fitness is 0.05475925189017111']
# ['At iteration 29 the best fitness is 0.05475925189017111']
#       Selected: 1371/2513 (54.6%), Fitness: 0.0548, Time: 812.9s
#       Modality: D=59%, S=54%, Sk=54%
#     Test Acc: 87.41%, F1: 87.21%, Features: 1371/2513 (54.6%), Model: 3.214MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 80.91%, F1: 81.27%, Features: 2513/2513 (100.0%), Model: 5.444MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1256/2513 (50.0%), Time: 12.5s
#     Test Acc: 83.82%, F1: 84.12%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1256/2513 (50.0%), Time: 2.6s
#     Test Acc: 84.65%, F1: 84.40%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1256/2513 (50.0%), Time: 0.5s
#     Test Acc: 74.27%, F1: 74.37%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06045487378674367']
# ['At iteration 1 the best fitness is 0.06045487378674367']
# ['At iteration 2 the best fitness is 0.06045487378674367']
# ['At iteration 3 the best fitness is 0.06045487378674367']
# ['At iteration 4 the best fitness is 0.06045487378674367']
# ['At iteration 5 the best fitness is 0.06045487378674367']
# ['At iteration 6 the best fitness is 0.06045487378674367']
# ['At iteration 7 the best fitness is 0.06045487378674367']
# ['At iteration 8 the best fitness is 0.06045487378674367']
# ['At iteration 9 the best fitness is 0.06045487378674367']
# ['At iteration 10 the best fitness is 0.06045487378674367']
# ['At iteration 11 the best fitness is 0.06045487378674367']
# ['At iteration 12 the best fitness is 0.06045487378674367']
# ['At iteration 13 the best fitness is 0.06045487378674367']
# ['At iteration 14 the best fitness is 0.06045487378674367']
# ['At iteration 15 the best fitness is 0.06045487378674367']
# ['At iteration 16 the best fitness is 0.06045487378674367']
# ['At iteration 17 the best fitness is 0.06045487378674367']
# ['At iteration 18 the best fitness is 0.06045487378674367']
# ['At iteration 19 the best fitness is 0.06045487378674367']
# ['At iteration 20 the best fitness is 0.06045487378674367']
# ['At iteration 21 the best fitness is 0.06045487378674367']
# ['At iteration 22 the best fitness is 0.06045487378674367']
# ['At iteration 23 the best fitness is 0.06045487378674367']
# ['At iteration 24 the best fitness is 0.06045487378674367']
# ['At iteration 25 the best fitness is 0.06045487378674367']
# ['At iteration 26 the best fitness is 0.06045487378674367']
# ['At iteration 27 the best fitness is 0.06045487378674367']
# ['At iteration 28 the best fitness is 0.06045487378674367']
# ['At iteration 29 the best fitness is 0.06045487378674367']
#       Selected: 1241/2513 (49.4%), Fitness: 0.0605, Time: 926.0s
#       Modality: D=51%, S=48%, Sk=49%
#     Test Acc: 78.42%, F1: 78.41%, Features: 1241/2513 (49.4%), Model: 2.960MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07685924496963617']
# ['At iteration 10 the best fitness is 0.05499338223844706']
# ['At iteration 20 the best fitness is 0.05499338223844706']
#       Selected: 1238/2513 (49.3%), Fitness: 0.0453, Time: 1832.1s
#       Modality: D=52%, S=51%, Sk=48%
#     Test Acc: 79.67%, F1: 79.98%, Features: 1238/2513 (49.3%), Model: 2.954MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07169620149137527']
# ['At iteration 2 the best fitness is 0.07169620149137527']
# ['At iteration 3 the best fitness is 0.07169620149137527']
# ['At iteration 4 the best fitness is 0.07169620149137527']
# ['At iteration 5 the best fitness is 0.06679181300714543']
# ['At iteration 6 the best fitness is 0.06679181300714543']
# ['At iteration 7 the best fitness is 0.06679181300714543']
# ['At iteration 8 the best fitness is 0.06679181300714543']
# ['At iteration 9 the best fitness is 0.06679181300714543']
# ['At iteration 10 the best fitness is 0.05596831260056405']
# ['At iteration 11 the best fitness is 0.05596831260056405']
# ['At iteration 12 the best fitness is 0.05596831260056405']
# ['At iteration 13 the best fitness is 0.05596831260056405']
# ['At iteration 14 the best fitness is 0.05596831260056405']
# ['At iteration 15 the best fitness is 0.05596831260056405']
# ['At iteration 16 the best fitness is 0.05596831260056405']
# ['At iteration 17 the best fitness is 0.05596831260056405']
# ['At iteration 18 the best fitness is 0.05596831260056405']
# ['At iteration 19 the best fitness is 0.05140216526237479']
# ['At iteration 20 the best fitness is 0.05140216526237479']
# ['At iteration 21 the best fitness is 0.05140216526237479']
# ['At iteration 22 the best fitness is 0.05140216526237479']
# ['At iteration 23 the best fitness is 0.05140216526237479']
# ['At iteration 24 the best fitness is 0.05140216526237479']
# ['At iteration 25 the best fitness is 0.05140216526237479']
# ['At iteration 26 the best fitness is 0.05140216526237479']
# ['At iteration 27 the best fitness is 0.05140216526237479']
# ['At iteration 28 the best fitness is 0.05140216526237479']
# ['At iteration 29 the best fitness is 0.05140216526237479']
# ['At iteration 30 the best fitness is 0.05140216526237479']
#       Selected: 1285/2513 (51.1%), Fitness: 0.0514, Time: 932.0s
#       Modality: D=56%, S=53%, Sk=50%
#     Test Acc: 77.18%, F1: 77.20%, Features: 1285/2513 (51.1%), Model: 3.046MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07127837419332514']
# ['At iteration 1 the best fitness is 0.076182762677555']
# ['At iteration 2 the best fitness is 0.07103961573729649']
# ['At iteration 3 the best fitness is 0.07163651187736811']
# ['At iteration 4 the best fitness is 0.05628665720860226']
# ['At iteration 5 the best fitness is 0.0615292868388726']
# ['At iteration 6 the best fitness is 0.07131816726932992']
# ['At iteration 7 the best fitness is 0.06127063184484156']
# ['At iteration 8 the best fitness is 0.06669233031713348']
# ['At iteration 9 the best fitness is 0.07163651187736811']
# ['At iteration 10 the best fitness is 0.0613701145348535']
# ['At iteration 11 the best fitness is 0.06663264070312633']
# ['At iteration 12 the best fitness is 0.07159671880136334']
# ['At iteration 13 the best fitness is 0.056107588366580766']
# ['At iteration 14 the best fitness is 0.06639388224709768']
# ['At iteration 15 the best fitness is 0.061250735306839166']
# ['At iteration 16 the best fitness is 0.06127063184484156']
# ['At iteration 17 the best fitness is 0.06643367532310245']
# ['At iteration 18 the best fitness is 0.061250735306839166']
# ['At iteration 19 the best fitness is 0.06647346839910723']
# ['At iteration 20 the best fitness is 0.06643367532310245']
# ['At iteration 21 the best fitness is 0.06647346839910723']
# ['At iteration 22 the best fitness is 0.06131042492084633']
# ['At iteration 23 the best fitness is 0.06131042492084633']
# ['At iteration 24 the best fitness is 0.07163651187736811']
# ['At iteration 25 the best fitness is 0.06647346839910723']
# ['At iteration 26 the best fitness is 0.06131042492084633']
# ['At iteration 27 the best fitness is 0.06131042492084633']
# ['At iteration 28 the best fitness is 0.06647346839910723']
# ['At iteration 29 the best fitness is 0.06131042492084633']
#       Selected: 1256/2513 (50.0%), Fitness: 0.0613, Time: 897.9s
#       Modality: D=49%, S=50%, Sk=50%
#     Test Acc: 79.25%, F1: 79.58%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.05598820913856644
# At iteration 2 the best fitness is 0.07161661533936572
# At iteration 3 the best fitness is 0.061111459540822456
# At iteration 4 the best fitness is 0.0560478987525736
# At iteration 5 the best fitness is 0.06131042492084633
# At iteration 6 the best fitness is 0.0557295541445354
# At iteration 7 the best fitness is 0.0565254156646309
# At iteration 8 the best fitness is 0.05080526912230316
# At iteration 9 the best fitness is 0.05642593297461897
# At iteration 10 the best fitness is 0.050924648350317486
# At iteration 11 the best fitness is 0.06097218377480575
# At iteration 12 the best fitness is 0.0509047518123151
# At iteration 13 the best fitness is 0.0510639241163342
# At iteration 14 the best fitness is 0.06113135607882485
# At iteration 15 the best fitness is 0.05630655374660464
# At iteration 16 the best fitness is 0.05114351026834375
# At iteration 17 the best fitness is 0.05102413104032943
# At iteration 18 the best fitness is 0.04584119102406615
# At iteration 19 the best fitness is 0.04570191525804944
# At iteration 20 the best fitness is 0.04584119102406615
# At iteration 21 the best fitness is 0.0510639241163342
# At iteration 22 the best fitness is 0.0510639241163342
# At iteration 23 the best fitness is 0.045423363726016006
# At iteration 24 the best fitness is 0.046040156404090024
# At iteration 25 the best fitness is 0.040698044083807644
# At iteration 26 the best fitness is 0.04566212218204466
# At iteration 27 the best fitness is 0.035733965985570736
# At iteration 28 the best fitness is 0.04026032024775512
# At iteration 29 the best fitness is 0.04083731984982436
# At iteration 30 the best fitness is 0.04572181179605182
#       Selected: 1278/2513 (50.9%), Fitness: 0.0457, Time: 902.1s
#       Modality: D=54%, S=51%, Sk=51%
#     Test Acc: 78.42%, F1: 78.51%, Features: 1278/2513 (50.9%), Model: 3.032MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06625460648108096']
# ['At iteration 1 the best fitness is 0.06625460648108096']
# ['At iteration 2 the best fitness is 0.06478226266890427']
# ['At iteration 3 the best fitness is 0.06478226266890427']
# ['At iteration 4 the best fitness is 0.06317064309071088']
# ['At iteration 5 the best fitness is 0.05854480613851446']
# ['At iteration 6 the best fitness is 0.05854480613851446']
# ['At iteration 7 the best fitness is 0.05854480613851446']
# ['At iteration 8 the best fitness is 0.05854480613851446']
# ['At iteration 9 the best fitness is 0.05854480613851446']
# ['At iteration 10 the best fitness is 0.05677401425630196']
# ['At iteration 11 the best fitness is 0.05627660080624228']
# ['At iteration 12 the best fitness is 0.055719497742175425']
# ['At iteration 13 the best fitness is 0.055719497742175425']
# ['At iteration 14 the best fitness is 0.05051666118790986']
# ['At iteration 15 the best fitness is 0.05051666118790986']
# ['At iteration 16 the best fitness is 0.05051666118790986']
# ['At iteration 17 the best fitness is 0.05051666118790986']
# ['At iteration 18 the best fitness is 0.05051666118790986']
# ['At iteration 19 the best fitness is 0.05051666118790986']
# ['At iteration 20 the best fitness is 0.044756721569577336']
# ['At iteration 21 the best fitness is 0.044756721569577336']
# ['At iteration 22 the best fitness is 0.044756721569577336']
# ['At iteration 23 the best fitness is 0.044756721569577336']
# ['At iteration 24 the best fitness is 0.044756721569577336']
# ['At iteration 25 the best fitness is 0.044756721569577336']
# ['At iteration 26 the best fitness is 0.044756721569577336']
# ['At iteration 27 the best fitness is 0.044756721569577336']
# ['At iteration 28 the best fitness is 0.044756721569577336']
# ['At iteration 29 the best fitness is 0.044756721569577336']
#       Selected: 1022/2513 (40.7%), Fitness: 0.0448, Time: 878.9s
#       Modality: D=38%, S=41%, Sk=41%
#     Test Acc: 79.25%, F1: 79.91%, Features: 1022/2513 (40.7%), Model: 2.532MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.07614296960155022']
# ['At iteration 1 the best fitness is 0.06756777798923855']
# ['At iteration 2 the best fitness is 0.06756777798923855']
# ['At iteration 3 the best fitness is 0.06654321441547427']
# ['At iteration 4 the best fitness is 0.06636414557345277']
# ['At iteration 5 the best fitness is 0.06636414557345277']
# ['At iteration 6 the best fitness is 0.06252411373899197']
# ['At iteration 7 the best fitness is 0.06252411373899197']
# ['At iteration 8 the best fitness is 0.06252411373899197']
# ['At iteration 9 the best fitness is 0.06019621879271263']
# ['At iteration 10 the best fitness is 0.06019621879271263']
# ['At iteration 11 the best fitness is 0.06019621879271263']
# ['At iteration 12 the best fitness is 0.06019621879271263']
# ['At iteration 13 the best fitness is 0.06019621879271263']
# ['At iteration 14 the best fitness is 0.06019621879271263']
# ['At iteration 15 the best fitness is 0.06019621879271263']
# ['At iteration 16 the best fitness is 0.05931093098496517']
# ['At iteration 17 the best fitness is 0.05931093098496517']
# ['At iteration 18 the best fitness is 0.05931093098496517']
# ['At iteration 19 the best fitness is 0.05931093098496517']
# ['At iteration 20 the best fitness is 0.05931093098496517']
# ['At iteration 21 the best fitness is 0.05931093098496517']
# ['At iteration 22 the best fitness is 0.05931093098496517']
# ['At iteration 23 the best fitness is 0.05326238343223934']
# ['At iteration 24 the best fitness is 0.05326238343223934']
# ['At iteration 25 the best fitness is 0.05326238343223934']
# ['At iteration 26 the best fitness is 0.05326238343223934']
# ['At iteration 27 the best fitness is 0.05326238343223934']
# ['At iteration 28 the best fitness is 0.05326238343223934']
# ['At iteration 29 the best fitness is 0.05326238343223934']
#       Selected: 1082/2513 (43.1%), Fitness: 0.0533, Time: 1209.8s
#       Modality: D=43%, S=43%, Sk=43%
#     Test Acc: 77.59%, F1: 77.32%, Features: 1082/2513 (43.1%), Model: 2.650MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07548638384747142']
# ['At iteration 1 the best fitness is 0.07548638384747142']
# ['At iteration 2 the best fitness is 0.07548638384747142']
# ['At iteration 3 the best fitness is 0.07548638384747142']
# ['At iteration 4 the best fitness is 0.07548638384747142']
# ['At iteration 5 the best fitness is 0.07109930535130365']
# ['At iteration 6 the best fitness is 0.07109930535130365']
# ['At iteration 7 the best fitness is 0.07109930535130365']
# ['At iteration 8 the best fitness is 0.06567760687901172']
# ['At iteration 9 the best fitness is 0.06567760687901172']
# ['At iteration 10 the best fitness is 0.06567760687901172']
# ['At iteration 11 the best fitness is 0.06567760687901172']
# ['At iteration 12 the best fitness is 0.06567760687901172']
# ['At iteration 13 the best fitness is 0.06567760687901172']
# ['At iteration 14 the best fitness is 0.0505864072042769']
# ['At iteration 15 the best fitness is 0.0505864072042769']
# ['At iteration 16 the best fitness is 0.0505864072042769']
# ['At iteration 17 the best fitness is 0.0505864072042769']
# ['At iteration 18 the best fitness is 0.0505864072042769']
# ['At iteration 19 the best fitness is 0.0505864072042769']
# ['At iteration 20 the best fitness is 0.0505864072042769']
# ['At iteration 21 the best fitness is 0.0505864072042769']
# ['At iteration 22 the best fitness is 0.0505864072042769']
# ['At iteration 23 the best fitness is 0.0505864072042769']
# ['At iteration 24 the best fitness is 0.0505864072042769']
# ['At iteration 25 the best fitness is 0.0505864072042769']
# ['At iteration 26 the best fitness is 0.0505864072042769']
# ['At iteration 27 the best fitness is 0.0505864072042769']
# ['At iteration 28 the best fitness is 0.0505864072042769']
# ['At iteration 29 the best fitness is 0.0505864072042769']
#       Selected: 1274/2513 (50.7%), Fitness: 0.0506, Time: 907.9s
#       Modality: D=51%, S=52%, Sk=50%
#     Test Acc: 75.93%, F1: 76.09%, Features: 1274/2513 (50.7%), Model: 3.025MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06685150262115258']
# ['At iteration 2 the best fitness is 0.06685150262115258']
# ['At iteration 3 the best fitness is 0.06685150262115258']
# ['At iteration 4 the best fitness is 0.06685150262115258']
# ['At iteration 5 the best fitness is 0.06685150262115258']
# ['At iteration 6 the best fitness is 0.06685150262115258']
# ['At iteration 7 the best fitness is 0.06685150262115258']
# ['At iteration 8 the best fitness is 0.06685150262115258']
# ['At iteration 9 the best fitness is 0.06685150262115258']
# ['At iteration 10 the best fitness is 0.06627450301908334']
# ['At iteration 11 the best fitness is 0.06627450301908334']
# ['At iteration 12 the best fitness is 0.06627450301908334']
# ['At iteration 13 the best fitness is 0.0615292868388726']
# ['At iteration 14 the best fitness is 0.05539131299849481']
# ['At iteration 15 the best fitness is 0.05539131299849481']
# ['At iteration 16 the best fitness is 0.05539131299849481']
# ['At iteration 17 the best fitness is 0.05539131299849481']
# ['At iteration 18 the best fitness is 0.05539131299849481']
# ['At iteration 19 the best fitness is 0.05539131299849481']
# ['At iteration 20 the best fitness is 0.05539131299849481']
# ['At iteration 21 the best fitness is 0.05539131299849481']
# ['At iteration 22 the best fitness is 0.05539131299849481']
# ['At iteration 23 the best fitness is 0.05539131299849481']
# ['At iteration 24 the best fitness is 0.05497348570044468']
# ['At iteration 25 the best fitness is 0.05497348570044468']
# ['At iteration 26 the best fitness is 0.05497348570044468']
# ['At iteration 27 the best fitness is 0.05040733836225541']
# ['At iteration 28 the best fitness is 0.05040733836225541']
# ['At iteration 29 the best fitness is 0.05040733836225541']
#       Selected: 1243/2513 (49.5%), Fitness: 0.0504, Time: 872.9s
#       Modality: D=44%, S=51%, Sk=50%
#     Test Acc: 80.50%, F1: 80.00%, Features: 1243/2513 (49.5%), Model: 2.964MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06703057146317408']
# ['At iteration 2 the best fitness is 0.06703057146317408']
# ['At iteration 3 the best fitness is 0.06703057146317408']
# ['At iteration 4 the best fitness is 0.06703057146317408']
# ['At iteration 5 the best fitness is 0.06703057146317408']
# ['At iteration 6 the best fitness is 0.06703057146317408']
# ['At iteration 7 the best fitness is 0.06703057146317408']
# ['At iteration 8 the best fitness is 0.06703057146317408']
# ['At iteration 9 the best fitness is 0.06681170954514781']
# ['At iteration 10 the best fitness is 0.06657295108911916']
# ['At iteration 11 the best fitness is 0.061409907610858266']
# ['At iteration 12 the best fitness is 0.061409907610858266']
# ['At iteration 13 the best fitness is 0.061409907610858266']
# ['At iteration 14 the best fitness is 0.061409907610858266']
# ['At iteration 15 the best fitness is 0.05662489835464284']
# ['At iteration 16 the best fitness is 0.05616727798058793']
# ['At iteration 17 the best fitness is 0.05616727798058793']
# ...
# ['At iteration 13 the best fitness is 0.08100540402343047']
# ['At iteration 14 the best fitness is 0.08100540402343047']
# ['At iteration 15 the best fitness is 0.08100540402343047']
# ['At iteration 16 the best fitness is 0.08100540402343047']
# ['At iteration 17 the best fitness is 0.08100540402343047']
# ['At iteration 18 the best fitness is 0.08100540402343047']
# ['At iteration 19 the best fitness is 0.07879688830516546']
# ['At iteration 20 the best fitness is 0.07879688830516546']
# ['At iteration 21 the best fitness is 0.07879688830516546']
# ['At iteration 22 the best fitness is 0.07879688830516546']
# ['At iteration 23 the best fitness is 0.07437202196247901']
# ['At iteration 24 the best fitness is 0.07437202196247901']
# ['At iteration 25 the best fitness is 0.07437202196247901']
# ['At iteration 26 the best fitness is 0.07437202196247901']
# ['At iteration 27 the best fitness is 0.07437202196247901']
# ['At iteration 28 the best fitness is 0.07437202196247901']
# ['At iteration 29 the best fitness is 0.07437202196247901']
#       Selected: 1245/2513 (49.5%), Fitness: 0.0744, Time: 1338.7s
#       Modality: D=51%, S=53%, Sk=48%
#     Test Acc: 88.89%, F1: 88.34%, Features: 1245/2513 (49.5%), Model: 2.968MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08989492978480813']
# ['At iteration 1 the best fitness is 0.08977555055679382']
# ['At iteration 2 the best fitness is 0.0752076765585793']
# ['At iteration 3 the best fitness is 0.0752076765585793']
# ['At iteration 4 the best fitness is 0.0752076765585793']
# ['At iteration 5 the best fitness is 0.0752076765585793']
# ['At iteration 6 the best fitness is 0.0752076765585793']
# ['At iteration 7 the best fitness is 0.0752076765585793']
# ['At iteration 8 the best fitness is 0.0752076765585793']
# ['At iteration 9 the best fitness is 0.0752076765585793']
# ['At iteration 10 the best fitness is 0.0752076765585793']
# ['At iteration 11 the best fitness is 0.0752076765585793']
# ['At iteration 12 the best fitness is 0.0752076765585793']
# ['At iteration 13 the best fitness is 0.0752076765585793']
# ['At iteration 14 the best fitness is 0.0752076765585793']
# ['At iteration 15 the best fitness is 0.0752076765585793']
# ['At iteration 16 the best fitness is 0.0752076765585793']
# ['At iteration 17 the best fitness is 0.0752076765585793']
# ['At iteration 18 the best fitness is 0.0752076765585793']
# ['At iteration 19 the best fitness is 0.0752076765585793']
# ['At iteration 20 the best fitness is 0.0752076765585793']
# ['At iteration 21 the best fitness is 0.0752076765585793']
# ['At iteration 22 the best fitness is 0.0752076765585793']
# ['At iteration 23 the best fitness is 0.0752076765585793']
# ['At iteration 24 the best fitness is 0.0752076765585793']
# ['At iteration 25 the best fitness is 0.0752076765585793']
# ['At iteration 26 the best fitness is 0.0752076765585793']
# ['At iteration 27 the best fitness is 0.0752076765585793']
# ['At iteration 28 the best fitness is 0.0752076765585793']
# ['At iteration 29 the best fitness is 0.0752076765585793']
#       Selected: 1300/2513 (51.7%), Fitness: 0.0752, Time: 997.2s
#       Modality: D=47%, S=53%, Sk=52%
#     Test Acc: 87.37%, F1: 86.89%, Features: 1300/2513 (51.7%), Model: 3.075MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08425637462397605']
# ['At iteration 2 the best fitness is 0.08425637462397605']
# ['At iteration 3 the best fitness is 0.08425637462397605']
# ['At iteration 4 the best fitness is 0.08425637462397605']
# ['At iteration 5 the best fitness is 0.08425637462397605']
# ['At iteration 6 the best fitness is 0.08413699539596171']
# ['At iteration 7 the best fitness is 0.08413699539596171']
# ['At iteration 8 the best fitness is 0.08009016327532065']
# ['At iteration 9 the best fitness is 0.08009016327532065']
# ['At iteration 10 the best fitness is 0.08009016327532065']
# ['At iteration 11 the best fitness is 0.08009016327532065']
# ['At iteration 12 the best fitness is 0.08009016327532065']
# ['At iteration 13 the best fitness is 0.07102156867192161']
# ['At iteration 14 the best fitness is 0.07102156867192161']
# ['At iteration 15 the best fitness is 0.07102156867192161']
# ['At iteration 16 the best fitness is 0.06996705215779506']
# ['At iteration 17 the best fitness is 0.06996705215779506']
# ['At iteration 18 the best fitness is 0.06996705215779506']
# ['At iteration 19 the best fitness is 0.06996705215779506']
# ['At iteration 20 the best fitness is 0.06996705215779506']
# ['At iteration 21 the best fitness is 0.06996705215779506']
# ['At iteration 22 the best fitness is 0.06996705215779506']
# ['At iteration 23 the best fitness is 0.06996705215779506']
# ['At iteration 24 the best fitness is 0.06996705215779506']
# ['At iteration 25 the best fitness is 0.06996705215779506']
# ['At iteration 26 the best fitness is 0.06996705215779506']
# ['At iteration 27 the best fitness is 0.06996705215779506']
# ['At iteration 28 the best fitness is 0.06996705215779506']
# ['At iteration 29 the best fitness is 0.06996705215779506']
#       Selected: 1296/2513 (51.6%), Fitness: 0.0700, Time: 937.9s
#       Modality: D=52%, S=48%, Sk=53%
#     Test Acc: 90.40%, F1: 89.79%, Features: 1296/2513 (51.6%), Model: 3.067MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09956042052827892']
# ['At iteration 2 the best fitness is 0.089477102486758']
# ['At iteration 3 the best fitness is 0.07548622809061271']
# ['At iteration 4 the best fitness is 0.07548622809061271']
# ['At iteration 5 the best fitness is 0.07548622809061271']
# ['At iteration 6 the best fitness is 0.07548622809061271']
# ['At iteration 7 the best fitness is 0.07548622809061271']
# ['At iteration 8 the best fitness is 0.07548622809061271']
# ['At iteration 9 the best fitness is 0.07548622809061271']
# ['At iteration 10 the best fitness is 0.07548622809061271']
# ['At iteration 11 the best fitness is 0.07548622809061271']
# ['At iteration 12 the best fitness is 0.07548622809061271']
# ['At iteration 13 the best fitness is 0.07548622809061271']
# ['At iteration 14 the best fitness is 0.07548622809061271']
# ['At iteration 15 the best fitness is 0.07548622809061271']
# ['At iteration 16 the best fitness is 0.07548622809061271']
# ['At iteration 17 the best fitness is 0.07548622809061271']
# ['At iteration 18 the best fitness is 0.07548622809061271']
# ['At iteration 19 the best fitness is 0.07544643501460793']
# ['At iteration 20 the best fitness is 0.07544643501460793']
# ['At iteration 21 the best fitness is 0.07544643501460793']
# ['At iteration 22 the best fitness is 0.07544643501460793']
# ['At iteration 23 the best fitness is 0.07544643501460793']
# ['At iteration 24 the best fitness is 0.07544643501460793']
# ['At iteration 25 the best fitness is 0.07544643501460793']
# ['At iteration 26 the best fitness is 0.07544643501460793']
# ['At iteration 27 the best fitness is 0.07544643501460793']
# ['At iteration 28 the best fitness is 0.07544643501460793']
# ['At iteration 29 the best fitness is 0.07542653847660555']
# ['At iteration 30 the best fitness is 0.07542653847660555']
#       Selected: 1328/2513 (52.8%), Fitness: 0.0754, Time: 942.8s
#       Modality: D=52%, S=51%, Sk=54%
#     Test Acc: 88.38%, F1: 87.33%, Features: 1328/2513 (52.8%), Model: 3.130MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09426010651348742']
# ['At iteration 2 the best fitness is 0.0843359607759856']
# ['At iteration 3 the best fitness is 0.0843359607759856']
# ['At iteration 4 the best fitness is 0.06982777639177835']
# ['At iteration 5 the best fitness is 0.06982777639177835']
# ['At iteration 6 the best fitness is 0.06982777639177835']
# ['At iteration 7 the best fitness is 0.06982777639177835']
# ['At iteration 8 the best fitness is 0.06982777639177835']
# ['At iteration 9 the best fitness is 0.06982777639177835']
# ['At iteration 10 the best fitness is 0.06982777639177835']
# ['At iteration 11 the best fitness is 0.06982777639177835']
# ['At iteration 12 the best fitness is 0.06982777639177835']
# ['At iteration 13 the best fitness is 0.06982777639177835']
# ['At iteration 14 the best fitness is 0.06982777639177835']
# ['At iteration 15 the best fitness is 0.06982777639177835']
# ['At iteration 16 the best fitness is 0.06982777639177835']
# ['At iteration 17 the best fitness is 0.06982777639177835']
# ['At iteration 18 the best fitness is 0.06982777639177835']
# ['At iteration 19 the best fitness is 0.06982777639177835']
# ['At iteration 20 the best fitness is 0.06982777639177835']
# ['At iteration 21 the best fitness is 0.06982777639177835']
# ['At iteration 22 the best fitness is 0.06982777639177835']
# ['At iteration 23 the best fitness is 0.06982777639177835']
# ['At iteration 24 the best fitness is 0.06982777639177835']
# ['At iteration 25 the best fitness is 0.06982777639177835']
# ['At iteration 26 the best fitness is 0.06982777639177835']
# ['At iteration 27 the best fitness is 0.06982777639177835']
# ['At iteration 28 the best fitness is 0.06982777639177835']
# ['At iteration 29 the best fitness is 0.06982777639177835']
# ['At iteration 30 the best fitness is 0.06982777639177835']
#       Selected: 1266/2513 (50.4%), Fitness: 0.0698, Time: 947.7s
#       Modality: D=52%, S=49%, Sk=51%
#     Test Acc: 90.40%, F1: 89.98%, Features: 1266/2513 (50.4%), Model: 3.009MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08878072365667443']
# ['At iteration 1 the best fitness is 0.08780579329455744']
# ['At iteration 2 the best fitness is 0.08780579329455744']
# ['At iteration 3 the best fitness is 0.08780579329455744']
# ['At iteration 4 the best fitness is 0.08324948609201067']
# ['At iteration 5 the best fitness is 0.08195621112185549']
# ['At iteration 6 the best fitness is 0.08195621112185549']
# ['At iteration 7 the best fitness is 0.08195621112185549']
# ['At iteration 8 the best fitness is 0.08195621112185549']
# ['At iteration 9 the best fitness is 0.08195621112185549']
# ['At iteration 10 the best fitness is 0.08195621112185549']
# ['At iteration 11 the best fitness is 0.08195621112185549']
# ['At iteration 12 the best fitness is 0.08195621112185549']
# ['At iteration 13 the best fitness is 0.08195621112185549']
# ['At iteration 14 the best fitness is 0.08195621112185549']
# ['At iteration 15 the best fitness is 0.08195621112185549']
# ['At iteration 16 the best fitness is 0.08158601180596653']
# ['At iteration 17 the best fitness is 0.08158601180596653']
# ['At iteration 18 the best fitness is 0.08158601180596653']
# ['At iteration 19 the best fitness is 0.08158601180596653']
# ['At iteration 20 the best fitness is 0.08158601180596653']
# ['At iteration 21 the best fitness is 0.08158601180596653']
# ['At iteration 22 the best fitness is 0.08158601180596653']
# ['At iteration 23 the best fitness is 0.08158601180596653']
# ['At iteration 24 the best fitness is 0.08158601180596653']
# ['At iteration 25 the best fitness is 0.08158601180596653']
# ['At iteration 26 the best fitness is 0.08158601180596653']
# ['At iteration 27 the best fitness is 0.08158601180596653']
# ['At iteration 28 the best fitness is 0.08158601180596653']
# ['At iteration 29 the best fitness is 0.08158601180596653']
#       Selected: 654/2513 (26.0%), Fitness: 0.0816, Time: 930.5s
#       Modality: D=27%, S=24%, Sk=27%
#     Test Acc: 86.36%, F1: 85.93%, Features: 654/2513 (26.0%), Model: 1.814MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08957658517676993']
# ['At iteration 2 the best fitness is 0.08957658517676993']
# ['At iteration 3 the best fitness is 0.08891999942269115']
# ['At iteration 4 the best fitness is 0.08891999942269115']
# ['At iteration 5 the best fitness is 0.08367937502190681']
# ['At iteration 6 the best fitness is 0.08367937502190681']
# ['At iteration 7 the best fitness is 0.08367937502190681']
# ['At iteration 8 the best fitness is 0.08367937502190681']
# ['At iteration 9 the best fitness is 0.08367937502190681']
# ['At iteration 10 the best fitness is 0.08367937502190681']
# ['At iteration 11 the best fitness is 0.08367937502190681']
# ['At iteration 12 the best fitness is 0.08367937502190681']
# ['At iteration 13 the best fitness is 0.08367937502190681']
# ['At iteration 14 the best fitness is 0.08367937502190681']
# ['At iteration 15 the best fitness is 0.08367937502190681']
# ['At iteration 16 the best fitness is 0.08367937502190681']
# ['At iteration 17 the best fitness is 0.08367937502190681']
# ['At iteration 18 the best fitness is 0.08367937502190681']
# ['At iteration 19 the best fitness is 0.08367937502190681']
# ['At iteration 20 the best fitness is 0.08367937502190681']
# ['At iteration 21 the best fitness is 0.08367937502190681']
# ['At iteration 22 the best fitness is 0.08367937502190681']
# ['At iteration 23 the best fitness is 0.08367937502190681']
# ['At iteration 24 the best fitness is 0.08367937502190681']
# ['At iteration 25 the best fitness is 0.08367937502190681']
# ['At iteration 26 the best fitness is 0.08367937502190681']
# ['At iteration 27 the best fitness is 0.08367937502190681']
# ['At iteration 28 the best fitness is 0.08367937502190681']
# ['At iteration 29 the best fitness is 0.08367937502190681']
#       Selected: 1226/2513 (48.8%), Fitness: 0.0837, Time: 2397.7s
#       Modality: D=50%, S=48%, Sk=49%
#     Test Acc: 90.91%, F1: 90.48%, Features: 1226/2513 (48.8%), Model: 2.931MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09918238630623355']
# ['At iteration 1 the best fitness is 0.08934988835258727']
# ['At iteration 2 the best fitness is 0.08934988835258727']
# ['At iteration 3 the best fitness is 0.08934988835258727']
# ['At iteration 4 the best fitness is 0.08934988835258727']
# ['At iteration 5 the best fitness is 0.08934988835258727']
# ['At iteration 6 the best fitness is 0.08925040566257533']
# ['At iteration 7 the best fitness is 0.08925040566257533']
# ['At iteration 8 the best fitness is 0.08925040566257533']
# ['At iteration 9 the best fitness is 0.08925040566257533']
# ['At iteration 10 the best fitness is 0.08925040566257533']
# ['At iteration 11 the best fitness is 0.08925040566257533']
# ['At iteration 12 the best fitness is 0.08925040566257533']
# ['At iteration 13 the best fitness is 0.08925040566257533']
# ['At iteration 14 the best fitness is 0.08925040566257533']
# ['At iteration 15 the best fitness is 0.08925040566257533']
# ['At iteration 16 the best fitness is 0.08925040566257533']
# ['At iteration 17 the best fitness is 0.08925040566257533']
# ['At iteration 18 the best fitness is 0.08925040566257533']
# ['At iteration 19 the best fitness is 0.08925040566257533']
# ['At iteration 20 the best fitness is 0.08925040566257533']
# ['At iteration 21 the best fitness is 0.07912729454504963']
# ['At iteration 22 the best fitness is 0.07912729454504963']
# ['At iteration 23 the best fitness is 0.07912729454504963']
# ['At iteration 24 the best fitness is 0.07912729454504963']
# ['At iteration 25 the best fitness is 0.07912729454504963']
# ['At iteration 26 the best fitness is 0.07912729454504963']
# ['At iteration 27 the best fitness is 0.07912729454504963']
# ['At iteration 28 the best fitness is 0.07912729454504963']
# ['At iteration 29 the best fitness is 0.07912729454504963']
#       Selected: 1506/2513 (59.9%), Fitness: 0.0791, Time: 862.1s
#       Modality: D=66%, S=62%, Sk=58%
#     Test Acc: 89.39%, F1: 88.31%, Features: 1506/2513 (59.9%), Model: 3.478MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_25_lost_new/all_results_per_fold.csv
# Shape: (90, 26)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected
# 0      baseline     1            92.6573           97.1429       92.7510          92.7510              93.8826           92.6573               2513            2513               100.0000       0.0000         10.3058         10.3058       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 1      baseline     2            80.9129           95.6522       81.2736          81.2789              85.1886           80.9091               2513            2513               100.0000       0.0000         14.9473         14.9474       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 2      baseline     3            94.5455           97.3545       94.3016          94.3016              94.6475           94.5455               2513            2513               100.0000       0.0000         14.6803         14.6803       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 3      baseline     4            91.3636           96.8254       91.0150          91.0150              92.8319           91.3636               2513            2513               100.0000       0.0000         14.5849         14.5849       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 4      baseline     5            91.9192           93.7824       90.3836          90.3836              89.9690           91.9192               2513            2513               100.0000       0.0000         15.2247         15.2247       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 5   mutual_info     1            94.0559           98.2857       94.1329          94.1329              94.7134           94.0559               1256            2513                49.9801      12.3549          8.2323         20.5873        782102           2.9894                22.3362                 11.1636                50.0199        35.3267               2.7778               6               69.9387              456                 48.2675                794
# 6   mutual_info     2            83.8174           97.8261       84.1207          84.0963              87.3733           83.8430               1256            2513                49.9801      12.5023         13.2232         25.7256        782102           2.9894                22.3362                 11.1636                50.0199        35.3267               3.7037               8               66.8712              436                 49.3617                812
# 7   mutual_info     3            94.0909           98.9418       93.7872          93.7872              95.4054           94.0909               1256            2513                49.9801      12.6090         13.2793         25.8884        782102           2.9894                22.3362                 11.1636                50.0199        35.3267               4.6296              10               67.0245              437                 49.1793                809
# 8   mutual_info     4            93.1818           98.4127       92.5838          92.5838              95.3322           93.1818               1256            2513                49.9801      12.5611         13.2290         25.7902        782102           2.9894                22.3362                 11.1636                50.0199        35.3267               3.2407               7               66.7178              435                 49.4833                814
# 9   mutual_info     5            94.4444           96.3731       94.3295          94.3295              95.3926           94.4444               1256            2513                49.9801      12.6941         13.6968         26.3910        782102           2.9894                22.3362                 11.1636                50.0199        35.3267               2.7778               6               68.2515              445                 48.9362                805
# 10          rfe     1            94.0559           97.7143       94.0751          94.0751              94.6403           94.0559               1256            2513                49.9801       2.6287         10.1540         12.7830        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              36.1111              78               59.3558              387                 48.0851                791
# 11          rfe     2            84.6473           98.9130       84.4002          84.3573              88.8060           84.6694               1256            2513                49.9801       2.6002         13.2230         15.8234        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              39.3519              85               59.0491              385                 47.7812                786
# 12          rfe     3            95.9091           96.2963       95.5152          95.5152              96.6627           95.9091               1256            2513                49.9801       2.6835         13.2789         15.9626        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              35.1852              76               62.7301              409                 46.8693                771
# 13          rfe     4            93.1818           97.8836       92.5827          92.5827              95.3735           93.1818               1256            2513                49.9801       2.6737         13.2692         15.9432        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              34.2593              74               61.1963              399                 47.5988                783
# 14          rfe     5            97.9798           95.3368       97.9640          97.9640              98.2645           97.9798               1256            2513                49.9801       2.6685         13.7751         16.4438        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              32.8704              71               60.8896              397                 47.9027                788
# 15        lasso     1            82.8671           94.8571       82.8185          82.8185              86.6391           82.8671               1256            2513                49.9801       0.5242          9.6132         10.1375        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422
# 16        lasso     2            74.2739           92.9348       74.3704          74.3295              81.0841           74.2975               1256            2513                49.9801       0.4996         13.2796         13.7793        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422
# 17        lasso     3            85.4545           91.0053       84.0441          84.0441              88.4449           85.4545               1256            2513                49.9801       0.5701         13.3982         13.9684        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422
# 18        lasso     4            85.4545           94.1799       84.7460          84.7460              87.8008           85.4545               1256            2513                49.9801       0.5800         13.3202         13.9003        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422
# 19        lasso     5            86.3636           91.1917       85.5689          85.5689              89.4233           86.3636               1256            2513                49.9801       0.5821         13.8342         14.4164        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              90.28              5.37              89.94              5.08                  2513.0                      100.00              0.00                13.95                13.95          1425686.0                  5.44                        0.00               50.21
# mutual_info              91.92              4.55              91.79              4.34                  1256.0                       49.98             12.54                12.33                24.88           782102.0                  2.99                       50.02               35.33
#         rfe              93.15              5.10              92.91              5.15                  1256.0                       49.98              2.65                12.74                15.39           782102.0                  2.99                       50.02               35.33
#       lasso              82.88              4.99              82.31              4.55                  1256.0                       49.98              0.55                12.69                13.24           782102.0                  2.99                       50.02               35.33
#    meta_BAT              87.12              5.37              87.03              5.42                  1230.6                       48.97            922.69                13.39               936.07           769097.2                  2.94                       51.03               35.13
#     meta_CS              88.14              4.91              88.06              4.68                  1236.6                       49.21           1830.44                13.27              1843.71           772169.2                  2.95                       50.79               35.18
#     meta_DE              86.70              5.44              86.28              5.18                  1248.4                       49.68            930.43                13.25               943.68           778210.8                  2.97                       50.32               35.31
#    meta_FFA              88.82              5.60              88.64              5.38                  1259.2                       50.11            897.33                13.34               910.67           783740.4                  3.00                       49.89               35.38
#     meta_GA              88.52              5.83              88.21              5.64                  1256.2                       49.99            898.72                13.23               911.96           782204.4                  2.99                       50.01               35.36
#    meta_GWO              86.77              4.43              86.83              4.14                  1045.6                       41.61            878.16                12.86               891.02           674377.2                  2.58                       58.39               34.50
#    meta_HHO              86.41              5.09              86.13              5.12                  1231.2                       48.99           1213.21                13.16              1226.38           769404.4                  2.94                       51.01               35.30
#   meta_JAYA              85.37              5.74              85.00              5.44                  1263.4                       50.27            927.04                13.28               940.32           785890.8                  3.00                       49.73               35.45
#    meta_MFO              88.47              4.47              88.10              4.56                  1274.0                       50.70            873.76                13.23               886.99           791318.0                  3.02                       49.30               35.56
#    meta_MVO              87.92              6.43              87.67              6.22                  1271.0                       50.58            895.97                13.28               909.24           789782.0                  3.02                       49.42               35.52
#    meta_PSO              87.73              5.57              87.34              5.66                  1250.8                       49.77            897.14                13.15               910.30           779439.6                  2.98                       50.23               35.31
#    meta_SCA              83.75              3.13              83.47              2.96                   777.0                       30.92            875.12                12.77               887.89           536854.0                  2.05                       69.08               29.98
#    meta_SSA              87.95              3.75              87.64              3.60                  1247.8                       49.65           2240.09                13.09              2253.18           777903.6                  2.97                       50.35               35.28
#    meta_WOA              86.94              4.85              86.62              4.52                  1494.6                       59.47            859.29                12.88               872.17           904265.2                  3.46                       40.53               38.15

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 91.92% vs Baseline: 90.28%
#   Paired t-test: t=2.7976, p=0.0489
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> better, Significant
#
# RFE vs BASELINE:
#   Method: 93.15% vs Baseline: 90.28%
#   Paired t-test: t=3.1685, p=0.0339
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> better, Significant
#
# LASSO vs BASELINE:
#   Method: 82.88% vs Baseline: 90.28%
#   Paired t-test: t=-8.6057, p=0.0010
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 87.12% vs Baseline: 90.28%
#   Paired t-test: t=-2.0414, p=0.1108
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 88.14% vs Baseline: 90.28%
#   Paired t-test: t=-2.0596, p=0.1085
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 86.70% vs Baseline: 90.28%
#   Paired t-test: t=-8.3664, p=0.0011
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_FFA vs BASELINE:
#   Method: 88.82% vs Baseline: 90.28%
#   Paired t-test: t=-2.4325, p=0.0718
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 88.52% vs Baseline: 90.28%
#   Paired t-test: t=-5.6486, p=0.0048
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_GWO vs BASELINE:
#   Method: 86.77% vs Baseline: 90.28%
#   Paired t-test: t=-2.8411, p=0.0468
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_HHO vs BASELINE:
#   Method: 86.41% vs Baseline: 90.28%
#   Paired t-test: t=-4.3582, p=0.0121
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_JAYA vs BASELINE:
#   Method: 85.37% vs Baseline: 90.28%
#   Paired t-test: t=-9.3248, p=0.0007
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_MFO vs BASELINE:
#   Method: 88.47% vs Baseline: 90.28%
#   Paired t-test: t=-3.3969, p=0.0274
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_MVO vs BASELINE:
#   Method: 87.92% vs Baseline: 90.28%
#   Paired t-test: t=-2.9287, p=0.0429
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> worse, Significant
#
# META_PSO vs BASELINE:
#   Method: 87.73% vs Baseline: 90.28%
#   Paired t-test: t=-2.6692, p=0.0559
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 83.75% vs Baseline: 90.28%
#   Paired t-test: t=-4.7451, p=0.0090
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_SSA vs BASELINE:
#   Method: 87.95% vs Baseline: 90.28%
#   Paired t-test: t=-1.6712, p=0.1700
#   Wilcoxon test: W=2.0000, p=0.1875
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 86.94% vs Baseline: 90.28%
#   Paired t-test: t=-4.5023, p=0.0108
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_25_lost_new
#
# Per-method folders:
#   results_25_lost_new/baseline/ (10 files)
#   results_25_lost_new/mutual_info/ (10 files)
#   results_25_lost_new/rfe/ (10 files)
#   results_25_lost_new/lasso/ (10 files)
#   results_25_lost_new/meta_BAT/ (10 files)
#   results_25_lost_new/meta_CS/ (10 files)
#   results_25_lost_new/meta_DE/ (10 files)
#   results_25_lost_new/meta_FFA/ (10 files)
#   results_25_lost_new/meta_GA/ (10 files)
#   results_25_lost_new/meta_GWO/ (10 files)
#   results_25_lost_new/meta_HHO/ (10 files)
#   results_25_lost_new/meta_JAYA/ (10 files)
#   results_25_lost_new/meta_MFO/ (10 files)
#   results_25_lost_new/meta_MVO/ (10 files)
#   results_25_lost_new/meta_PSO/ (10 files)
#   results_25_lost_new/meta_SCA/ (10 files)
#   results_25_lost_new/meta_SSA/ (10 files)
#   results_25_lost_new/meta_WOA/ (10 files)
#
# Plots directory: results_25_lost_new/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 93.15% ± 5.10% (Features: 50.0%)
#   mutual_info         : 91.92% ± 4.55% (Features: 50.0%)
#   baseline            : 90.28% ± 5.37% (Features: 100.0%)
#   meta_FFA            : 88.82% ± 5.60% (Features: 50.1%)
#   meta_GA             : 88.52% ± 5.83% (Features: 50.0%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_MVO
#     Test Accuracy:      92.66%
#     Feature Retention:  49.34% (1240/2513)
#     Modality Retention: depth=50.0%, sensor=50.8%, skeleton=48.7%
#
#   Fold 2: Best = meta_SSA
#     Test Accuracy:      81.74%
#     Feature Retention:  50.30% (1264/2513)
#     Modality Retention: depth=56.5%, sensor=47.9%, skeleton=50.5%
#
#   Fold 3: Best = meta_FFA
#     Test Accuracy:      93.64%
#     Feature Retention:  50.14% (1260/2513)
#     Modality Retention: depth=49.5%, sensor=51.2%, skeleton=49.8%
#
#   Fold 4: Best = meta_CS
#     Test Accuracy:      92.27%
#     Feature Retention:  50.14% (1260/2513)
#     Modality Retention: depth=50.9%, sensor=53.8%, skeleton=48.6%
#
#   Fold 5: Best = meta_BAT
#     Test Accuracy:      91.41%
#     Feature Retention:  49.22% (1237/2513)
#     Modality Retention: depth=47.2%, sensor=50.3%, skeleton=49.1%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     90.34% ± 4.87%
#   Average Feature Retention: 49.83% ± 0.50%
#
#   Average Modality-wise Feature Retention:
#          depth: 50.83% ± 3.44%
#         sensor: 50.80% ± 2.14%
#       skeleton: 49.31% ± 0.80%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)
#     1           meta_MVO              92.66                  49.34                50.00                 50.77                   48.69
#     2           meta_SSA              81.74                  50.30                56.48                 47.85                   50.46
#     3           meta_FFA              93.64                  50.14                49.54                 51.23                   49.79
#     4            meta_CS              92.27                  50.14                50.93                 53.83                   48.57
#     5           meta_BAT              91.41                  49.22                47.22                 50.31                   49.06
#
# Saved to: results_25_lost_new/best_metaheuristic_per_fold.csv
