# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new")

# Master output directory
RESULTS_ROOT = Path("results_no_sensor_new")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   depth: 216
#   skeleton: 1645
#   TOTAL: 1861

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 97.55%, F1: 97.56%, Features: 1861/1861 (100.0%), Model: 4.171MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 930/1861 (50.0%), Time: 9.4s
#     Test Acc: 97.55%, F1: 97.44%, Features: 930/1861 (50.0%), Model: 2.353MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 930/1861 (50.0%), Time: 1.8s
#     Test Acc: 97.90%, F1: 97.90%, Features: 930/1861 (50.0%), Model: 2.353MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 930/1861 (50.0%), Time: 0.3s
#     Test Acc: 95.10%, F1: 95.05%, Features: 930/1861 (50.0%), Model: 2.353MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.036300452905503974']
# ['At iteration 1 the best fitness is 0.036300452905503974']
# ['At iteration 2 the best fitness is 0.036300452905503974']
# ['At iteration 3 the best fitness is 0.035575036462731274']
# ['At iteration 4 the best fitness is 0.035575036462731274']
# ['At iteration 5 the best fitness is 0.035575036462731274']
# ['At iteration 6 the best fitness is 0.035575036462731274']
# ['At iteration 7 the best fitness is 0.035575036462731274']
# ['At iteration 8 the best fitness is 0.035575036462731274']
# ['At iteration 9 the best fitness is 0.035575036462731274']
# ['At iteration 10 the best fitness is 0.035575036462731274']
# ['At iteration 11 the best fitness is 0.035575036462731274']
# ['At iteration 12 the best fitness is 0.035575036462731274']
# ['At iteration 13 the best fitness is 0.035575036462731274']
# ['At iteration 14 the best fitness is 0.035575036462731274']
# ['At iteration 15 the best fitness is 0.035575036462731274']
# ['At iteration 16 the best fitness is 0.03022706686113453']
# ['At iteration 17 the best fitness is 0.03022706686113453']
# ['At iteration 18 the best fitness is 0.03022706686113453']
# ['At iteration 19 the best fitness is 0.03022706686113453']
# ['At iteration 20 the best fitness is 0.03022706686113453']
# ['At iteration 21 the best fitness is 0.03022706686113453']
# ['At iteration 22 the best fitness is 0.03022706686113453']
# ['At iteration 23 the best fitness is 0.03022706686113453']
# ['At iteration 24 the best fitness is 0.03022706686113453']
# ['At iteration 25 the best fitness is 0.03022706686113453']
# ['At iteration 26 the best fitness is 0.03022706686113453']
# ['At iteration 27 the best fitness is 0.03022706686113453']
# ['At iteration 28 the best fitness is 0.03022706686113453']
# ['At iteration 29 the best fitness is 0.03022706686113453']
#       Selected: 923/1861 (49.6%), Fitness: 0.0302, Time: 693.8s
#       Modality: D=46%, Sk=50%
#     Test Acc: 98.25%, F1: 98.23%, Features: 923/1861 (49.6%), Model: 2.339MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04105734244261916']
# ['At iteration 10 the best fitness is 0.03608551470023799']
# ['At iteration 20 the best fitness is 0.034742150917325576']
#       Selected: 933/1861 (50.1%), Fitness: 0.0304, Time: 1379.1s
#       Modality: D=46%, Sk=51%
#     Test Acc: 96.15%, F1: 96.03%, Features: 933/1861 (50.1%), Model: 2.358MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03095248330390723']
# ['At iteration 2 the best fitness is 0.03095248330390723']
# ['At iteration 3 the best fitness is 0.03095248330390723']
# ['At iteration 4 the best fitness is 0.03095248330390723']
# ['At iteration 5 the best fitness is 0.03095248330390723']
# ['At iteration 6 the best fitness is 0.03095248330390723']
# ['At iteration 7 the best fitness is 0.03095248330390723']
# ['At iteration 8 the best fitness is 0.03095248330390723']
# ['At iteration 9 the best fitness is 0.03095248330390723']
# ['At iteration 10 the best fitness is 0.03095248330390723']
# ['At iteration 11 the best fitness is 0.03095248330390723']
# ['At iteration 12 the best fitness is 0.03079127964995774']
# ['At iteration 13 the best fitness is 0.03079127964995774']
# ['At iteration 14 the best fitness is 0.03079127964995774']
# ['At iteration 15 the best fitness is 0.03079127964995774']
# ['At iteration 16 the best fitness is 0.03079127964995774']
# ['At iteration 17 the best fitness is 0.03079127964995774']
# ['At iteration 18 the best fitness is 0.03033453596376752']
# ['At iteration 19 the best fitness is 0.02498656636217088']
# ['At iteration 20 the best fitness is 0.02498656636217088']
# ['At iteration 21 the best fitness is 0.02498656636217088']
# ['At iteration 22 the best fitness is 0.02498656636217088']
# ['At iteration 23 the best fitness is 0.02498656636217088']
# ['At iteration 24 the best fitness is 0.02498656636217088']
# ['At iteration 25 the best fitness is 0.02498656636217088']
# ['At iteration 26 the best fitness is 0.02498656636217088']
# ['At iteration 27 the best fitness is 0.02498656636217088']
# ['At iteration 28 the best fitness is 0.02498656636217088']
# ['At iteration 29 the best fitness is 0.02498656636217088']
# ['At iteration 30 the best fitness is 0.02498656636217088']
#       Selected: 895/1861 (48.1%), Fitness: 0.0250, Time: 693.9s
#       Modality: D=46%, Sk=48%
#     Test Acc: 96.15%, F1: 96.10%, Features: 895/1861 (48.1%), Model: 2.284MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04721133031396336']
# ['At iteration 1 the best fitness is 0.05234436171029401']
# ['At iteration 2 the best fitness is 0.05234436171029401']
# ['At iteration 3 the best fitness is 0.04164842250710062']
# ['At iteration 4 the best fitness is 0.041487218853151125']
# ['At iteration 5 the best fitness is 0.03635418745682048']
# ['At iteration 6 the best fitness is 0.04162155523144237']
# ['At iteration 7 the best fitness is 0.04696952483303912']
# ['At iteration 8 the best fitness is 0.042078298917632595']
# ['At iteration 9 the best fitness is 0.03054947416903351']
# ['At iteration 10 the best fitness is 0.04156782068012588']
# ['At iteration 11 the best fitness is 0.04143348430183463']
# ['At iteration 12 the best fitness is 0.03619298380287099']
# ['At iteration 13 the best fitness is 0.04162155523144237']
# ['At iteration 14 the best fitness is 0.04156782068012588']
# ['At iteration 15 the best fitness is 0.04151408612880938']
# ['At iteration 16 the best fitness is 0.046942657557380876']
# ['At iteration 17 the best fitness is 0.04143348430183463']
# ['At iteration 18 the best fitness is 0.041594687955784124']
# ['At iteration 19 the best fitness is 0.036166116527212744']
# ['At iteration 20 the best fitness is 0.04156782068012588']
# ['At iteration 21 the best fitness is 0.04156782068012588']
# ['At iteration 22 the best fitness is 0.04154095340446763']
# ['At iteration 23 the best fitness is 0.03611238197589624']
# ['At iteration 24 the best fitness is 0.03611238197589624']
# ['At iteration 25 the best fitness is 0.04696952483303912']
# ['At iteration 26 the best fitness is 0.04154095340446763']
# ['At iteration 27 the best fitness is 0.04154095340446763']
# ['At iteration 28 the best fitness is 0.04154095340446763']
# ['At iteration 29 the best fitness is 0.04154095340446763']
#       Selected: 917/1861 (49.3%), Fitness: 0.0415, Time: 673.2s
#       Modality: D=48%, Sk=49%
#     Test Acc: 93.01%, F1: 92.86%, Features: 917/1861 (49.3%), Model: 2.327MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.04653964842250715
# At iteration 2 the best fitness is 0.04137974975051814
# At iteration 3 the best fitness is 0.04127228064788514
# At iteration 4 the best fitness is 0.03584370921931376
# At iteration 5 the best fitness is 0.04140661702617639
# At iteration 6 the best fitness is 0.0404662623781377
# At iteration 7 the best fitness is 0.04602917018500043
# At iteration 8 the best fitness is 0.04608290473631693
# At iteration 9 the best fitness is 0.03635418745682048
# At iteration 10 the best fitness is 0.03506455822522456
# At iteration 11 the best fitness is 0.04089613878866967
# At iteration 12 the best fitness is 0.04017072234589697
# At iteration 13 the best fitness is 0.04033192599984646
# At iteration 14 the best fitness is 0.03576310739233901
# At iteration 15 the best fitness is 0.04033192599984646
# At iteration 16 the best fitness is 0.04033192599984646
# At iteration 17 the best fitness is 0.03570937284102252
# At iteration 18 the best fitness is 0.03562877101404777
# At iteration 19 the best fitness is 0.041084209718277406
# At iteration 20 the best fitness is 0.040869271513011424
# At iteration 21 the best fitness is 0.04094987333998616
# At iteration 22 the best fitness is 0.040869271513011424
# At iteration 23 the best fitness is 0.03544070008444003
# At iteration 24 the best fitness is 0.04084240423735318
# At iteration 25 the best fitness is 0.04089613878866967
# At iteration 26 the best fitness is 0.04089613878866967
# At iteration 27 the best fitness is 0.041030475166960914
# At iteration 28 the best fitness is 0.040761802410378425
# At iteration 29 the best fitness is 0.040761802410378425
# At iteration 30 the best fitness is 0.04089613878866967
#       Selected: 934/1861 (50.2%), Fitness: 0.0409, Time: 681.2s
#       Modality: D=55%, Sk=50%
#     Test Acc: 97.90%, F1: 97.95%, Features: 934/1861 (50.2%), Model: 2.360MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0412454133722269']
# ['At iteration 1 the best fitness is 0.04009012051892222']
# ['At iteration 2 the best fitness is 0.04009012051892222']
# ['At iteration 3 the best fitness is 0.038881093114301046']
# ['At iteration 4 the best fitness is 0.03221662700545025']
# ['At iteration 5 the best fitness is 0.03221662700545025']
# ['At iteration 6 the best fitness is 0.03090013049819608']
# ['At iteration 7 the best fitness is 0.03090013049819608']
# ['At iteration 8 the best fitness is 0.03090013049819608']
# ['At iteration 9 the best fitness is 0.030658325017271847']
# ['At iteration 10 the best fitness is 0.029852306747524395']
# ['At iteration 11 the best fitness is 0.02923435940738469']
# ['At iteration 12 the best fitness is 0.02918062485606819']
# ['At iteration 13 the best fitness is 0.02918062485606819']
# ['At iteration 14 the best fitness is 0.02918062485606819']
# ['At iteration 15 the best fitness is 0.028670146618561473']
# ['At iteration 16 the best fitness is 0.023187840638673483']
# ['At iteration 17 the best fitness is 0.023187840638673483']
# ['At iteration 18 the best fitness is 0.023187840638673483']
# ['At iteration 19 the best fitness is 0.023187840638673483']
# ['At iteration 20 the best fitness is 0.023080371536040492']
# ['At iteration 21 the best fitness is 0.023080371536040492']
# ['At iteration 22 the best fitness is 0.023080371536040492']
# ['At iteration 23 the best fitness is 0.023080371536040492']
# ['At iteration 24 the best fitness is 0.023080371536040492']
# ['At iteration 25 the best fitness is 0.023080371536040492']
# ['At iteration 26 the best fitness is 0.023080371536040492']
# ['At iteration 27 the best fitness is 0.023080371536040492']
# ['At iteration 28 the best fitness is 0.023080371536040492']
# ['At iteration 29 the best fitness is 0.023080371536040492']
#       Selected: 686/1861 (36.9%), Fitness: 0.0231, Time: 669.6s
#       Modality: D=33%, Sk=37%
#     Test Acc: 95.10%, F1: 94.97%, Features: 686/1861 (36.9%), Model: 1.876MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.04713072848698861']
# ['At iteration 1 the best fitness is 0.046781453903431386']
# ['At iteration 2 the best fitness is 0.0432632225378061']
# ['At iteration 3 the best fitness is 0.0432632225378061']
# ['At iteration 4 the best fitness is 0.042536424349428156']
# ['At iteration 5 the best fitness is 0.03718845474783141']
# ['At iteration 6 the best fitness is 0.03718845474783141']
# ['At iteration 7 the best fitness is 0.03718845474783141']
# ['At iteration 8 the best fitness is 0.033453903431334905']
# ['At iteration 9 the best fitness is 0.033453903431334905']
# ['At iteration 10 the best fitness is 0.033453903431334905']
# ['At iteration 11 the best fitness is 0.033453903431334905']
# ['At iteration 12 the best fitness is 0.033453903431334905']
# ['At iteration 13 the best fitness is 0.027434251938282053']
# ['At iteration 14 the best fitness is 0.027434251938282053']
# ['At iteration 15 the best fitness is 0.027434251938282053']
# ['At iteration 16 the best fitness is 0.027434251938282053']
# ['At iteration 17 the best fitness is 0.027434251938282053']
# ['At iteration 18 the best fitness is 0.027434251938282053']
# ['At iteration 19 the best fitness is 0.027434251938282053']
# ['At iteration 20 the best fitness is 0.027380517386965557']
# ['At iteration 21 the best fitness is 0.027380517386965557']
# ['At iteration 22 the best fitness is 0.027380517386965557']
# ['At iteration 23 the best fitness is 0.027380517386965557']
# ['At iteration 24 the best fitness is 0.027380517386965557']
# ['At iteration 25 the best fitness is 0.027380517386965557']
# ['At iteration 26 the best fitness is 0.027380517386965557']
# ['At iteration 27 the best fitness is 0.027380517386965557']
# ['At iteration 28 the best fitness is 0.027380517386965557']
# ['At iteration 29 the best fitness is 0.027380517386965557']
#       Selected: 661/1861 (35.5%), Fitness: 0.0274, Time: 827.5s
#       Modality: D=35%, Sk=36%
#     Test Acc: 93.36%, F1: 92.72%, Features: 661/1861 (35.5%), Model: 1.827MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03487648729561682']
# ['At iteration 1 the best fitness is 0.03487648729561682']
# ['At iteration 2 the best fitness is 0.03487648729561682']
# ['At iteration 3 the best fitness is 0.03487648729561682']
# ['At iteration 4 the best fitness is 0.03487648729561682']
# ['At iteration 5 the best fitness is 0.03487648729561682']
# ['At iteration 6 the best fitness is 0.03487648729561682']
# ['At iteration 7 the best fitness is 0.03487648729561682']
# ['At iteration 8 the best fitness is 0.029313579488754085']
# ['At iteration 9 the best fitness is 0.029313579488754085']
# ['At iteration 10 the best fitness is 0.029313579488754085']
# ['At iteration 11 the best fitness is 0.029313579488754085']
# ['At iteration 12 the best fitness is 0.029313579488754085']
# ['At iteration 13 the best fitness is 0.029313579488754085']
# ['At iteration 14 the best fitness is 0.029313579488754085']
# ['At iteration 15 the best fitness is 0.029313579488754085']
# ['At iteration 16 the best fitness is 0.029313579488754085']
# ['At iteration 17 the best fitness is 0.029313579488754085']
# ['At iteration 18 the best fitness is 0.029313579488754085']
# ['At iteration 19 the best fitness is 0.029313579488754085']
# ['At iteration 20 the best fitness is 0.029313579488754085']
# ['At iteration 21 the best fitness is 0.029313579488754085']
# ['At iteration 22 the best fitness is 0.029313579488754085']
# ['At iteration 23 the best fitness is 0.029313579488754085']
# ['At iteration 24 the best fitness is 0.029313579488754085']
# ['At iteration 25 the best fitness is 0.029313579488754085']
# ['At iteration 26 the best fitness is 0.029313579488754085']
# ['At iteration 27 the best fitness is 0.029313579488754085']
# ['At iteration 28 the best fitness is 0.029313579488754085']
# ['At iteration 29 the best fitness is 0.029313579488754085']
#       Selected: 915/1861 (49.2%), Fitness: 0.0293, Time: 704.4s
#       Modality: D=46%, Sk=50%
#     Test Acc: 94.41%, F1: 94.37%, Features: 915/1861 (49.2%), Model: 2.323MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.041809626161050106']
# ['At iteration 2 the best fitness is 0.03992891686497273']
# ['At iteration 3 the best fitness is 0.03992891686497273']
# ['At iteration 4 the best fitness is 0.03992891686497273']
# ['At iteration 5 the best fitness is 0.03992891686497273']
# ['At iteration 6 the best fitness is 0.03992891686497273']
# ['At iteration 7 the best fitness is 0.035575036462731274']
# ['At iteration 8 the best fitness is 0.035575036462731274']
# ['At iteration 9 the best fitness is 0.035575036462731274']
# ['At iteration 10 the best fitness is 0.035575036462731274']
# ['At iteration 11 the best fitness is 0.035575036462731274']
# ['At iteration 12 the best fitness is 0.035575036462731274']
# ['At iteration 13 the best fitness is 0.035575036462731274']
# ['At iteration 14 the best fitness is 0.035575036462731274']
# ['At iteration 15 the best fitness is 0.035575036462731274']
# ['At iteration 16 the best fitness is 0.035575036462731274']
# ['At iteration 17 the best fitness is 0.03493022184693332']
# ['At iteration 18 the best fitness is 0.034688416366009084']
# ['At iteration 19 the best fitness is 0.034688416366009084']
# ['At iteration 20 the best fitness is 0.03420480540416061']
# ['At iteration 21 the best fitness is 0.030092730482843284']
# ['At iteration 22 the best fitness is 0.030092730482843284']
# ['At iteration 23 the best fitness is 0.030092730482843284']
# ['At iteration 24 the best fitness is 0.030092730482843284']
# ['At iteration 25 the best fitness is 0.030092730482843284']
# ['At iteration 26 the best fitness is 0.030092730482843284']
# ['At iteration 27 the best fitness is 0.030092730482843284']
# ['At iteration 28 the best fitness is 0.029179243110462844']
# ['At iteration 29 the best fitness is 0.029179243110462844']
#       Selected: 902/1861 (48.5%), Fitness: 0.0292, Time: 658.1s
#       Modality: D=44%, Sk=49%
#     Test Acc: 95.45%, F1: 95.40%, Features: 902/1861 (48.5%), Model: 2.298MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.041352882474859895']
# ['At iteration 2 the best fitness is 0.041191678820910405']
# ['At iteration 3 the best fitness is 0.03576310739233901']
# ['At iteration 4 the best fitness is 0.03576310739233901']
# ['At iteration 5 the best fitness is 0.03576310739233901']
# ['At iteration 6 the best fitness is 0.03576310739233901']
# ['At iteration 7 the best fitness is 0.034957089122591566']
# ['At iteration 8 the best fitness is 0.034957089122591566']
# ['At iteration 9 the best fitness is 0.034957089122591566']
# ['At iteration 10 the best fitness is 0.03471528364166733']
# ['At iteration 11 the best fitness is 0.03471528364166733']
# ['At iteration 12 the best fitness is 0.03471528364166733']
# ['At iteration 13 the best fitness is 0.03471528364166733']
# ['At iteration 14 the best fitness is 0.03471528364166733']
# ['At iteration 15 the best fitness is 0.03471528364166733']
# ['At iteration 16 the best fitness is 0.03471528364166733']
# ['At iteration 17 the best fitness is 0.03471528364166733']
# ['At iteration 18 the best fitness is 0.03471528364166733']
# ['At iteration 19 the best fitness is 0.03471528364166733']
# ['At iteration 20 the best fitness is 0.03463468181469259']
# ['At iteration 21 the best fitness is 0.03460781453903434']
# ['At iteration 22 the best fitness is 0.03460781453903434']
# ['At iteration 23 the best fitness is 0.03450034543640135']
# ['At iteration 24 the best fitness is 0.029367314040070584']
# ['At iteration 25 the best fitness is 0.029367314040070584']
# ['At iteration 26 the best fitness is 0.029367314040070584']
# ['At iteration 27 the best fitness is 0.029367314040070584']
# ['At iteration 28 the best fitness is 0.029367314040070584']
# ['At iteration 29 the best fitness is 0.029367314040070584']
# ['At iteration 30 the best fitness is 0.029367314040070584']
#       Selected: 913/1861 (49.1%), Fitness: 0.0294, Time: 675.8s
#       Modality: D=53%, Sk=49%
#     Test Acc: 94.76%, F1: 94.62%, Features: 913/1861 (49.1%), Model: 2.319MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04054686420511244']
# ['At iteration 2 the best fitness is 0.04054686420511244']
# ['At iteration 3 the best fitness is 0.04054686420511244']
# ['At iteration 4 the best fitness is 0.036219851078529236']
# ['At iteration 5 the best fitness is 0.036219851078529236']
# ['At iteration 6 the best fitness is 0.03546756736009828']
# ['At iteration 7 the best fitness is 0.03546756736009828']
# ['At iteration 8 the best fitness is 0.03546756736009828']
# ['At iteration 9 the best fitness is 0.03546756736009828']
# ['At iteration 10 the best fitness is 0.03498395639824982']
# ['At iteration 11 the best fitness is 0.03498395639824982']
# ['At iteration 12 the best fitness is 0.03498395639824982']
# ['At iteration 13 the best fitness is 0.03498395639824982']
# ['At iteration 14 the best fitness is 0.03498395639824982']
# ['At iteration 15 the best fitness is 0.03498395639824982']
# ['At iteration 16 the best fitness is 0.03498395639824982']
# ['At iteration 17 the best fitness is 0.03498395639824982']
# ['At iteration 18 the best fitness is 0.03498395639824982']
# ['At iteration 19 the best fitness is 0.03498395639824982']
# ['At iteration 20 the best fitness is 0.03498395639824982']
# ['At iteration 21 the best fitness is 0.03498395639824982']
# ['At iteration 22 the best fitness is 0.03498395639824982']
# ['At iteration 23 the best fitness is 0.03487648729561682']
# ['At iteration 24 the best fitness is 0.03452721271205959']
# ['At iteration 25 the best fitness is 0.03452721271205959']
# ['At iteration 26 the best fitness is 0.03452721271205959']
# ['At iteration 27 the best fitness is 0.03452721271205959']
# ['At iteration 28 the best fitness is 0.03452721271205959']
# ['At iteration 29 the best fitness is 0.03452721271205959']
# ['At iteration 30 the best fitness is 0.03452721271205959']
#       Selected: 897/1861 (48.2%), Fitness: 0.0345, Time: 680.6s
#       Modality: D=43%, Sk=49%
#     Test Acc: 97.20%, F1: 97.21%, Features: 897/1861 (48.2%), Model: 2.288MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.045975435633683934']
# ['At iteration 1 the best fitness is 0.038988562216934045']
# ['At iteration 2 the best fitness is 0.037269056574806156']
# ['At iteration 3 the best fitness is 0.036221232824134475']
# ['At iteration 4 the best fitness is 0.036221232824134475']
# ['At iteration 5 the best fitness is 0.036221232824134475']
# ['At iteration 6 the best fitness is 0.036221232824134475']
# ['At iteration 7 the best fitness is 0.036221232824134475']
# ['At iteration 8 the best fitness is 0.036221232824134475']
# ['At iteration 9 the best fitness is 0.03608827819144858']
# ['At iteration 10 the best fitness is 0.03608827819144858']
# ['At iteration 11 the best fitness is 0.03358962155523149']
# ['At iteration 12 the best fitness is 0.03305227604206652']
# ['At iteration 13 the best fitness is 0.03227312504797733']
# ['At iteration 14 the best fitness is 0.03205818684271134']
# ['At iteration 15 the best fitness is 0.03205818684271134']
# ['At iteration 16 the best fitness is 0.03205818684271134']
# ['At iteration 17 the best fitness is 0.03205818684271134']
# ['At iteration 18 the best fitness is 0.03071482305979893']
# ['At iteration 19 the best fitness is 0.03071482305979893']
# ['At iteration 20 the best fitness is 0.03001627389268447']
# ['At iteration 21 the best fitness is 0.03001627389268447']
# ['At iteration 22 the best fitness is 0.03001627389268447']
# ['At iteration 23 the best fitness is 0.03001627389268447']
# ['At iteration 24 the best fitness is 0.03001627389268447']
# ['At iteration 25 the best fitness is 0.029666999309127244']
# ['At iteration 26 the best fitness is 0.029666999309127244']
# ['At iteration 27 the best fitness is 0.029505795655177757']
# ['At iteration 28 the best fitness is 0.029505795655177757']
# ['At iteration 29 the best fitness is 0.029505795655177757']
#       Selected: 323/1861 (17.4%), Fitness: 0.0295, Time: 709.4s
#       Modality: D=19%, Sk=17%
#     Test Acc: 92.31%, F1: 91.97%, Features: 323/1861 (17.4%), Model: 1.167MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04078866968603667']
# ['At iteration 2 the best fitness is 0.04073493513472018']
# ['At iteration 3 the best fitness is 0.04073493513472018']
# ['At iteration 4 the best fitness is 0.035413832808781784']
# ['At iteration 5 the best fitness is 0.028883703078222113']
# ['At iteration 6 the best fitness is 0.028883703078222113']
# ['At iteration 7 the best fitness is 0.028883703078222113']
# ['At iteration 8 the best fitness is 0.028883703078222113']
# ['At iteration 9 the best fitness is 0.028883703078222113']
# ['At iteration 10 the best fitness is 0.028883703078222113']
# ['At iteration 11 the best fitness is 0.028883703078222113']
# ['At iteration 12 the best fitness is 0.028883703078222113']
# ['At iteration 13 the best fitness is 0.028883703078222113']
# ['At iteration 14 the best fitness is 0.028883703078222113']
# ['At iteration 15 the best fitness is 0.028883703078222113']
# ['At iteration 16 the best fitness is 0.028883703078222113']
# ['At iteration 17 the best fitness is 0.028883703078222113']
# ['At iteration 18 the best fitness is 0.028883703078222113']
# ['At iteration 19 the best fitness is 0.028883703078222113']
# ['At iteration 20 the best fitness is 0.028883703078222113']
# ['At iteration 21 the best fitness is 0.028883703078222113']
# ['At iteration 22 the best fitness is 0.028883703078222113']
# ['At iteration 23 the best fitness is 0.028883703078222113']
# ['At iteration 24 the best fitness is 0.028883703078222113']
# ['At iteration 25 the best fitness is 0.028883703078222113']
# ['At iteration 26 the best fitness is 0.028883703078222113']
# ['At iteration 27 the best fitness is 0.028883703078222113']
# ['At iteration 28 the best fitness is 0.028829968526905617']
# ['At iteration 29 the best fitness is 0.028829968526905617']
#       Selected: 899/1861 (48.3%), Fitness: 0.0288, Time: 1682.5s
#       Modality: D=47%, Sk=49%
#     Test Acc: 96.85%, F1: 96.79%, Features: 899/1861 (48.3%), Model: 2.292MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.041084209718277406']
# ['At iteration 1 the best fitness is 0.031033085130881977']
# ['At iteration 2 the best fitness is 0.031033085130881977']
# ['At iteration 3 the best fitness is 0.031033085130881977']
# ['At iteration 4 the best fitness is 0.030310432179319856']
# ['At iteration 5 the best fitness is 0.025258002609963946']
# ['At iteration 6 the best fitness is 0.025258002609963946']
# ['At iteration 7 the best fitness is 0.025258002609963946']
# ['At iteration 8 the best fitness is 0.025258002609963946']
# ['At iteration 9 the best fitness is 0.018459200122821793']
# ['At iteration 10 the best fitness is 0.018459200122821793']
# ['At iteration 11 the best fitness is 0.018459200122821793']
# ['At iteration 12 the best fitness is 0.018459200122821793']
# ['At iteration 13 the best fitness is 0.018459200122821793']
# ['At iteration 14 the best fitness is 0.018459200122821793']
# ['At iteration 15 the best fitness is 0.018459200122821793']
# ['At iteration 16 the best fitness is 0.018459200122821793']
# ['At iteration 17 the best fitness is 0.018459200122821793']
# ['At iteration 18 the best fitness is 0.018459200122821793']
# ['At iteration 19 the best fitness is 0.018459200122821793']
# ['At iteration 20 the best fitness is 0.018459200122821793']
# ['At iteration 21 the best fitness is 0.018459200122821793']
# ['At iteration 22 the best fitness is 0.018459200122821793']
# ['At iteration 23 the best fitness is 0.018459200122821793']
# ['At iteration 24 the best fitness is 0.018459200122821793']
# ['At iteration 25 the best fitness is 0.018459200122821793']
# ['At iteration 26 the best fitness is 0.018459200122821793']
# ['At iteration 27 the best fitness is 0.018459200122821793']
# ['At iteration 28 the best fitness is 0.018459200122821793']
# ['At iteration 29 the best fitness is 0.018459200122821793']
#       Selected: 504/1861 (27.1%), Fitness: 0.0185, Time: 670.3s
#       Modality: D=25%, Sk=27%
#     Test Acc: 93.71%, F1: 93.66%, Features: 504/1861 (27.1%), Model: 1.521MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 84.65%, F1: 84.27%, Features: 1861/1861 (100.0%), Model: 4.171MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 930/1861 (50.0%), Time: 9.4s
#     Test Acc: 87.55%, F1: 87.79%, Features: 930/1861 (50.0%), Model: 2.353MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 930/1861 (50.0%), Time: 1.8s
#     Test Acc: 87.14%, F1: 87.11%, Features: 930/1861 (50.0%), Model: 2.353MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 930/1861 (50.0%), Time: 0.3s
#     Test Acc: 85.89%, F1: 85.52%, Features: 930/1861 (50.0%), Model: 2.353MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024610424502955402']
# ['At iteration 1 the best fitness is 0.024610424502955402']
# ['At iteration 2 the best fitness is 0.024583557227297152']
# ['At iteration 3 the best fitness is 0.024583557227297152']
# ['At iteration 4 the best fitness is 0.024583557227297152']
# ['At iteration 5 the best fitness is 0.024583557227297152']
# ['At iteration 6 the best fitness is 0.024583557227297152']
# ['At iteration 7 the best fitness is 0.024556689951638906']
# ['At iteration 8 the best fitness is 0.024556689951638906']
# ['At iteration 9 the best fitness is 0.024556689951638906']
# ['At iteration 10 the best fitness is 0.024556689951638906']
# ['At iteration 11 the best fitness is 0.024556689951638906']
# ['At iteration 12 the best fitness is 0.024556689951638906']
# ['At iteration 13 the best fitness is 0.024556689951638906']
# ['At iteration 14 the best fitness is 0.024556689951638906']
# ['At iteration 15 the best fitness is 0.024556689951638906']
# ['At iteration 16 the best fitness is 0.024449220849005915']
# ['At iteration 17 the best fitness is 0.024449220849005915']
# ['At iteration 18 the best fitness is 0.024449220849005915']
# ['At iteration 19 the best fitness is 0.024449220849005915']
# ['At iteration 20 the best fitness is 0.024422353573347665']
# ['At iteration 21 the best fitness is 0.024422353573347665']
# ['At iteration 22 the best fitness is 0.024368619022031166']
# ['At iteration 23 the best fitness is 0.024368619022031166']
# ['At iteration 24 the best fitness is 0.024341751746372917']
# ['At iteration 25 the best fitness is 0.024341751746372917']
# ['At iteration 26 the best fitness is 0.024341751746372917']
# ['At iteration 27 the best fitness is 0.024341751746372917']
# ['At iteration 28 the best fitness is 0.024341751746372917']
# ['At iteration 29 the best fitness is 0.024341751746372917']
#       Selected: 906/1861 (48.7%), Fitness: 0.0243, Time: 730.2s
#       Modality: D=44%, Sk=49%
#     Test Acc: 85.06%, F1: 85.28%, Features: 906/1861 (48.7%), Model: 2.306MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.030095875289115274']
# ['At iteration 10 the best fitness is 0.023831273508866203']
# ['At iteration 20 the best fitness is 0.023831273508866203']
#       Selected: 893/1861 (48.0%), Fitness: 0.0238, Time: 1475.7s
#       Modality: D=49%, Sk=48%
#     Test Acc: 83.40%, F1: 82.98%, Features: 893/1861 (48.0%), Model: 2.280MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.034399165946312225']
# ['At iteration 2 the best fitness is 0.029880937083849285']
# ['At iteration 3 the best fitness is 0.024422353573347665']
# ['At iteration 4 the best fitness is 0.024422353573347665']
# ['At iteration 5 the best fitness is 0.024422353573347665']
# ['At iteration 6 the best fitness is 0.024422353573347665']
# ['At iteration 7 the best fitness is 0.024422353573347665']
# ['At iteration 8 the best fitness is 0.023696937130574962']
# ['At iteration 9 the best fitness is 0.023696937130574962']
# ['At iteration 10 the best fitness is 0.023696937130574962']
# ['At iteration 11 the best fitness is 0.023696937130574962']
# ['At iteration 12 the best fitness is 0.023696937130574962']
# ['At iteration 13 the best fitness is 0.023696937130574962']
# ['At iteration 14 the best fitness is 0.023696937130574962']
# ['At iteration 15 the best fitness is 0.023696937130574962']
# ['At iteration 16 the best fitness is 0.023696937130574962']
# ['At iteration 17 the best fitness is 0.023481998925308976']
# ['At iteration 18 the best fitness is 0.023481998925308976']
# ['At iteration 19 the best fitness is 0.023481998925308976']
# ['At iteration 20 the best fitness is 0.023481998925308976']
# ['At iteration 21 the best fitness is 0.023481998925308976']
# ['At iteration 22 the best fitness is 0.023481998925308976']
# ['At iteration 23 the best fitness is 0.023347662547017735']
# ['At iteration 24 the best fitness is 0.023347662547017735']
# ['At iteration 25 the best fitness is 0.023347662547017735']
# ['At iteration 26 the best fitness is 0.023347662547017735']
# ['At iteration 27 the best fitness is 0.023347662547017735']
# ['At iteration 28 the best fitness is 0.023347662547017735']
# ['At iteration 29 the best fitness is 0.023347662547017735']
# ['At iteration 30 the best fitness is 0.023347662547017735']
#       Selected: 853/1861 (45.8%), Fitness: 0.0233, Time: 749.5s
#       Modality: D=44%, Sk=46%
#     Test Acc: 87.97%, F1: 88.12%, Features: 853/1861 (45.8%), Model: 2.202MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025389575497044597']
# ['At iteration 1 the best fitness is 0.0296659988785833']
# ['At iteration 2 the best fitness is 0.024502955400322407']
# ['At iteration 3 the best fitness is 0.024852229983879634']
# ['At iteration 4 the best fitness is 0.024825362708221388']
# ['At iteration 5 the best fitness is 0.024879097259537884']
# ['At iteration 6 the best fitness is 0.024234282643739925']
# ['At iteration 7 the best fitness is 0.029397326122000817']
# ['At iteration 8 the best fitness is 0.024744760881246643']
# ['At iteration 9 the best fitness is 0.02495969908651263']
# ['At iteration 10 the best fitness is 0.02463729177861365']
# ['At iteration 11 the best fitness is 0.024691026329930147']
# ['At iteration 12 the best fitness is 0.024744760881246643']
# ['At iteration 13 the best fitness is 0.024744760881246643']
# ['At iteration 14 the best fitness is 0.024879097259537884']
# ['At iteration 15 the best fitness is 0.024825362708221388']
# ['At iteration 16 the best fitness is 0.024798495432563142']
# ['At iteration 17 the best fitness is 0.029880937083849285']
# ['At iteration 18 the best fitness is 0.024717893605588393']
# ['At iteration 19 the best fitness is 0.024771628156904892']
# ['At iteration 20 the best fitness is 0.024771628156904892']
# ['At iteration 21 the best fitness is 0.024798495432563142']
# ['At iteration 22 the best fitness is 0.024771628156904892']
# ['At iteration 23 the best fitness is 0.024771628156904892']
# ['At iteration 24 the best fitness is 0.024744760881246643']
# ['At iteration 25 the best fitness is 0.024744760881246643']
# ['At iteration 26 the best fitness is 0.024771628156904892']
# ['At iteration 27 the best fitness is 0.024798495432563142']
# ['At iteration 28 the best fitness is 0.024798495432563142']
# ['At iteration 29 the best fitness is 0.024798495432563142']
#       Selected: 919/1861 (49.4%), Fitness: 0.0248, Time: 717.4s
#       Modality: D=47%, Sk=50%
#     Test Acc: 83.40%, F1: 83.02%, Features: 919/1861 (49.4%), Model: 2.331MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.040690635002219436
# At iteration 2 the best fitness is 0.024879097259537884
# At iteration 3 the best fitness is 0.030042140737798775
# At iteration 4 the best fitness is 0.031063097212812207
# At iteration 5 the best fitness is 0.029639131602925053
# At iteration 6 the best fitness is 0.029639131602925053
# At iteration 7 the best fitness is 0.02915552064107658
# At iteration 8 the best fitness is 0.024664159054271897
# At iteration 9 the best fitness is 0.029585397051608557
# At iteration 10 the best fitness is 0.025389575497044597
# At iteration 11 the best fitness is 0.029316724295026072
# At iteration 12 the best fitness is 0.024717893605588393
# At iteration 13 the best fitness is 0.024664159054271897
# At iteration 14 the best fitness is 0.024905964535196133
# At iteration 15 the best fitness is 0.024905964535196133
# At iteration 16 the best fitness is 0.029262989743709576
# At iteration 17 the best fitness is 0.029262989743709576
# At iteration 18 the best fitness is 0.02915552064107658
# At iteration 19 the best fitness is 0.024395486297689416
# At iteration 20 the best fitness is 0.02418054809242343
# At iteration 21 the best fitness is 0.02401934443847394
# At iteration 22 the best fitness is 0.023938742611499197
# At iteration 23 the best fitness is 0.02904805153844359
# At iteration 24 the best fitness is 0.02415368081676518
# At iteration 25 the best fitness is 0.023965609887157444
# At iteration 26 the best fitness is 0.02401934443847394
# At iteration 27 the best fitness is 0.023938742611499197
# At iteration 28 the best fitness is 0.02420741536808168
# At iteration 29 the best fitness is 0.023750671681891457
# At iteration 30 the best fitness is 0.023804406233207953
#       Selected: 902/1861 (48.5%), Fitness: 0.0238, Time: 726.3s
#       Modality: D=50%, Sk=48%
#     Test Acc: 84.23%, F1: 84.20%, Features: 902/1861 (48.5%), Model: 2.298MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.035285786043034416']
# ['At iteration 1 the best fitness is 0.029128653365418335']
# ['At iteration 2 the best fitness is 0.028456971473962128']
# ['At iteration 3 the best fitness is 0.028456971473962128']
# ['At iteration 4 the best fitness is 0.027033005864074974']
# ['At iteration 5 the best fitness is 0.027033005864074974']
# ['At iteration 6 the best fitness is 0.027033005864074974']
# ['At iteration 7 the best fitness is 0.026656864004859497']
# ['At iteration 8 the best fitness is 0.02125201504567437']
# ['At iteration 9 the best fitness is 0.02125201504567437']
# ['At iteration 10 the best fitness is 0.019801182160128966']
# ['At iteration 11 the best fitness is 0.01953250940354648']
# ['At iteration 12 the best fitness is 0.01929070392262225']
# ['At iteration 13 the best fitness is 0.01929070392262225']
# ['At iteration 14 the best fitness is 0.01929070392262225']
# ['At iteration 15 the best fitness is 0.01929070392262225']
# ['At iteration 16 the best fitness is 0.019263836646964']
# ['At iteration 17 the best fitness is 0.019263836646964']
# ['At iteration 18 the best fitness is 0.019075765717356263']
# ['At iteration 19 the best fitness is 0.019075765717356263']
# ['At iteration 20 the best fitness is 0.018645889306824287']
# ['At iteration 21 the best fitness is 0.01818914562063407']
# ['At iteration 22 the best fitness is 0.01818914562063407']
# ['At iteration 23 the best fitness is 0.01818914562063407']
# ['At iteration 24 the best fitness is 0.01818914562063407']
# ['At iteration 25 the best fitness is 0.01818914562063407']
# ['At iteration 26 the best fitness is 0.01818914562063407']
# ['At iteration 27 the best fitness is 0.01818914562063407']
# ['At iteration 28 the best fitness is 0.01816227834497582']
# ['At iteration 29 the best fitness is 0.01816227834497582']
#       Selected: 735/1861 (39.5%), Fitness: 0.0182, Time: 720.9s
#       Modality: D=40%, Sk=39%
#     Test Acc: 84.65%, F1: 84.44%, Features: 735/1861 (39.5%), Model: 1.972MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.029880937083849285']
# ['At iteration 1 the best fitness is 0.029880937083849285']
# ['At iteration 2 the best fitness is 0.02641505852393526']
# ['At iteration 3 the best fitness is 0.023670069854916712']
# ['At iteration 4 the best fitness is 0.023670069854916712']
# ['At iteration 5 the best fitness is 0.01786673831273509']
# ['At iteration 6 the best fitness is 0.01786673831273509']
# ['At iteration 7 the best fitness is 0.01786673831273509']
# ['At iteration 8 the best fitness is 0.01786673831273509']
# ['At iteration 9 the best fitness is 0.01786673831273509']
# ['At iteration 10 the best fitness is 0.01786673831273509']
# ['At iteration 11 the best fitness is 0.01786673831273509']
# ['At iteration 12 the best fitness is 0.01786673831273509']
# ['At iteration 13 the best fitness is 0.01786673831273509']
# ['At iteration 14 the best fitness is 0.01786673831273509']
# ['At iteration 15 the best fitness is 0.01786673831273509']
# ['At iteration 16 the best fitness is 0.01786673831273509']
# ['At iteration 17 the best fitness is 0.01786673831273509']
# ['At iteration 18 the best fitness is 0.01786673831273509']
# ['At iteration 19 the best fitness is 0.01786673831273509']
# ['At iteration 20 the best fitness is 0.01786673831273509']
# ['At iteration 21 the best fitness is 0.01786673831273509']
# ['At iteration 22 the best fitness is 0.01786673831273509']
# ['At iteration 23 the best fitness is 0.017517463729177864']
# ['At iteration 24 the best fitness is 0.017517463729177864']
# ['At iteration 25 the best fitness is 0.017517463729177864']
# ['At iteration 26 the best fitness is 0.017517463729177864']
# ['At iteration 27 the best fitness is 0.017517463729177864']
# ['At iteration 28 the best fitness is 0.017517463729177864']
# ['At iteration 29 the best fitness is 0.017517463729177864']
#       Selected: 695/1861 (37.3%), Fitness: 0.0175, Time: 933.8s
#       Modality: D=38%, Sk=37%
#     Test Acc: 82.16%, F1: 82.05%, Features: 695/1861 (37.3%), Model: 1.894MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02418054809242343']
# ['At iteration 1 the best fitness is 0.02418054809242343']
# ['At iteration 2 the best fitness is 0.02418054809242343']
# ['At iteration 3 the best fitness is 0.02418054809242343']
# ['At iteration 4 the best fitness is 0.02418054809242343']
# ['At iteration 5 the best fitness is 0.02418054809242343']
# ['At iteration 6 the best fitness is 0.02418054809242343']
# ['At iteration 7 the best fitness is 0.02418054809242343']
# ['At iteration 8 the best fitness is 0.02418054809242343']
# ['At iteration 9 the best fitness is 0.02418054809242343']
# ['At iteration 10 the best fitness is 0.02418054809242343']
# ['At iteration 11 the best fitness is 0.02418054809242343']
# ['At iteration 12 the best fitness is 0.02418054809242343']
# ['At iteration 13 the best fitness is 0.02418054809242343']
# ['At iteration 14 the best fitness is 0.02418054809242343']
# ['At iteration 15 the best fitness is 0.02418054809242343']
# ['At iteration 16 the best fitness is 0.02418054809242343']
# ['At iteration 17 the best fitness is 0.02418054809242343']
# ['At iteration 18 the best fitness is 0.02418054809242343']
# ['At iteration 19 the best fitness is 0.02418054809242343']
# ['At iteration 20 the best fitness is 0.02418054809242343']
# ['At iteration 21 the best fitness is 0.02407307898979044']
# ['At iteration 22 the best fitness is 0.02407307898979044']
# ['At iteration 23 the best fitness is 0.02407307898979044']
# ['At iteration 24 the best fitness is 0.02407307898979044']
# ['At iteration 25 the best fitness is 0.02407307898979044']
# ['At iteration 26 the best fitness is 0.02407307898979044']
# ['At iteration 27 the best fitness is 0.02407307898979044']
# ['At iteration 28 the best fitness is 0.02407307898979044']
# ['At iteration 29 the best fitness is 0.02407307898979044']
#       Selected: 905/1861 (48.6%), Fitness: 0.0241, Time: 737.7s
#       Modality: D=48%, Sk=49%
#     Test Acc: 89.21%, F1: 89.60%, Features: 905/1861 (48.6%), Model: 2.304MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03055261897530549']
# ['At iteration 2 the best fitness is 0.03055261897530549']
# ['At iteration 3 the best fitness is 0.025819451907576577']
# ['At iteration 4 the best fitness is 0.025819451907576577']
# ['At iteration 5 the best fitness is 0.025819451907576577']
# ['At iteration 6 the best fitness is 0.025819451907576577']
# ['At iteration 7 the best fitness is 0.025819451907576577']
# ['At iteration 8 the best fitness is 0.025819451907576577']
# ['At iteration 9 the best fitness is 0.025819451907576577']
# ['At iteration 10 the best fitness is 0.025819451907576577']
# ['At iteration 11 the best fitness is 0.025819451907576577']
# ['At iteration 12 the best fitness is 0.025819451907576577']
# ['At iteration 13 the best fitness is 0.02528210639441161']
# ['At iteration 14 the best fitness is 0.02528210639441161']
# ['At iteration 15 the best fitness is 0.02528210639441161']
# ['At iteration 16 the best fitness is 0.02528210639441161']
# ['At iteration 17 the best fitness is 0.02528210639441161']
# ['At iteration 18 the best fitness is 0.02528210639441161']
# ['At iteration 19 the best fitness is 0.025147770016120365']
# ['At iteration 20 the best fitness is 0.025147770016120365']
# ['At iteration 21 the best fitness is 0.025147770016120365']
# ['At iteration 22 the best fitness is 0.025147770016120365']
# ['At iteration 23 the best fitness is 0.025147770016120365']
# ['At iteration 24 the best fitness is 0.025147770016120365']
# ['At iteration 25 the best fitness is 0.025147770016120365']
# ['At iteration 26 the best fitness is 0.025147770016120365']
# ['At iteration 27 the best fitness is 0.02498656636217088']
# ['At iteration 28 the best fitness is 0.024610424502955402']
# ['At iteration 29 the best fitness is 0.024610424502955402']
#       Selected: 923/1861 (49.6%), Fitness: 0.0246, Time: 693.3s
#       Modality: D=52%, Sk=49%
#     Test Acc: 85.48%, F1: 85.73%, Features: 923/1861 (49.6%), Model: 2.339MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03504398056211018']
# ['At iteration 2 the best fitness is 0.030498884423988997']
# ['At iteration 3 the best fitness is 0.030498884423988997']
# ['At iteration 4 the best fitness is 0.030042140737798775']
# ['At iteration 5 the best fitness is 0.030042140737798775']
# ['At iteration 6 the best fitness is 0.029262989743709576']
# ['At iteration 7 the best fitness is 0.024368619022031166']
# ['At iteration 8 the best fitness is 0.024368619022031166']
# ['At iteration 9 the best fitness is 0.024368619022031166']
# ['At iteration 10 the best fitness is 0.024368619022031166']
# ['At iteration 11 the best fitness is 0.024368619022031166']
# ['At iteration 12 the best fitness is 0.024368619022031166']
# ['At iteration 13 the best fitness is 0.024368619022031166']
# ['At iteration 14 the best fitness is 0.024368619022031166']
# ['At iteration 15 the best fitness is 0.024368619022031166']
# ...
# ['At iteration 14 the best fitness is 0.026507838840892882']
# ['At iteration 15 the best fitness is 0.026507838840892882']
# ['At iteration 16 the best fitness is 0.026507838840892882']
# ['At iteration 17 the best fitness is 0.026507838840892882']
# ['At iteration 18 the best fitness is 0.026507838840892882']
# ['At iteration 19 the best fitness is 0.026507838840892882']
# ['At iteration 20 the best fitness is 0.026507838840892882']
# ['At iteration 21 the best fitness is 0.022961358454004113']
# ['At iteration 22 the best fitness is 0.022961358454004113']
# ['At iteration 23 the best fitness is 0.022961358454004113']
# ['At iteration 24 the best fitness is 0.022961358454004113']
# ['At iteration 25 the best fitness is 0.022961358454004113']
# ['At iteration 26 the best fitness is 0.022961358454004113']
# ['At iteration 27 the best fitness is 0.022961358454004113']
# ['At iteration 28 the best fitness is 0.022961358454004113']
# ['At iteration 29 the best fitness is 0.022961358454004113']
#       Selected: 402/1861 (21.6%), Fitness: 0.0230, Time: 1018.5s
#       Modality: D=27%, Sk=21%
#     Test Acc: 88.38%, F1: 88.18%, Features: 402/1861 (21.6%), Model: 1.321MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04023701670225774']
# ['At iteration 1 the best fitness is 0.03991460939435876']
# ['At iteration 2 the best fitness is 0.03951160025948504']
# ['At iteration 3 the best fitness is 0.03889365291934533']
# ['At iteration 4 the best fitness is 0.03889365291934533']
# ['At iteration 5 the best fitness is 0.03889365291934533']
# ['At iteration 6 the best fitness is 0.037980165546964886']
# ['At iteration 7 the best fitness is 0.037980165546964886']
# ['At iteration 8 the best fitness is 0.037980165546964886']
# ['At iteration 9 the best fitness is 0.037980165546964886']
# ['At iteration 10 the best fitness is 0.037980165546964886']
# ['At iteration 11 the best fitness is 0.037980165546964886']
# ['At iteration 12 the best fitness is 0.037980165546964886']
# ['At iteration 13 the best fitness is 0.037980165546964886']
# ['At iteration 14 the best fitness is 0.037980165546964886']
# ['At iteration 15 the best fitness is 0.037980165546964886']
# ['At iteration 16 the best fitness is 0.03399824040225744']
# ['At iteration 17 the best fitness is 0.03399824040225744']
# ['At iteration 18 the best fitness is 0.03399824040225744']
# ['At iteration 19 the best fitness is 0.03399824040225744']
# ['At iteration 20 the best fitness is 0.03399824040225744']
# ['At iteration 21 the best fitness is 0.03399824040225744']
# ['At iteration 22 the best fitness is 0.03399824040225744']
# ['At iteration 23 the best fitness is 0.03399824040225744']
# ['At iteration 24 the best fitness is 0.03399824040225744']
# ['At iteration 25 the best fitness is 0.03399824040225744']
# ['At iteration 26 the best fitness is 0.03399824040225744']
# ['At iteration 27 the best fitness is 0.03399824040225744']
# ['At iteration 28 the best fitness is 0.03399824040225744']
# ['At iteration 29 the best fitness is 0.03399824040225744']
#       Selected: 900/1861 (48.4%), Fitness: 0.0340, Time: 777.7s
#       Modality: D=44%, Sk=49%
#     Test Acc: 88.38%, F1: 88.52%, Features: 900/1861 (48.4%), Model: 2.294MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0393235293298773']
# ['At iteration 2 the best fitness is 0.0393235293298773']
# ['At iteration 3 the best fitness is 0.0393235293298773']
# ['At iteration 4 the best fitness is 0.0393235293298773']
# ['At iteration 5 the best fitness is 0.0393235293298773']
# ['At iteration 6 the best fitness is 0.0393235293298773']
# ['At iteration 7 the best fitness is 0.03555654239043584']
# ['At iteration 8 the best fitness is 0.03555654239043584']
# ['At iteration 9 the best fitness is 0.03555654239043584']
# ['At iteration 10 the best fitness is 0.03555654239043584']
# ['At iteration 11 the best fitness is 0.03555654239043584']
# ['At iteration 12 the best fitness is 0.03555654239043584']
# ['At iteration 13 the best fitness is 0.03555654239043584']
# ['At iteration 14 the best fitness is 0.03445498408844767']
# ['At iteration 15 the best fitness is 0.03445498408844767']
# ['At iteration 16 the best fitness is 0.03445498408844767']
# ['At iteration 17 the best fitness is 0.03445498408844767']
# ['At iteration 18 the best fitness is 0.03445498408844767']
# ['At iteration 19 the best fitness is 0.03445498408844767']
# ['At iteration 20 the best fitness is 0.033702700370016714']
# ['At iteration 21 the best fitness is 0.033702700370016714']
# ['At iteration 22 the best fitness is 0.033702700370016714']
# ['At iteration 23 the best fitness is 0.033702700370016714']
# ['At iteration 24 the best fitness is 0.033702700370016714']
# ['At iteration 25 the best fitness is 0.033702700370016714']
# ['At iteration 26 the best fitness is 0.033702700370016714']
# ['At iteration 27 the best fitness is 0.033702700370016714']
# ['At iteration 28 the best fitness is 0.033702700370016714']
# ['At iteration 29 the best fitness is 0.033702700370016714']
#       Selected: 891/1861 (47.9%), Fitness: 0.0337, Time: 745.5s
#       Modality: D=46%, Sk=48%
#     Test Acc: 91.92%, F1: 92.06%, Features: 891/1861 (47.9%), Model: 2.276MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.044245809122623325']
# ['At iteration 2 the best fitness is 0.03886678564368708']
# ['At iteration 3 the best fitness is 0.03846377650881336']
# ['At iteration 4 the best fitness is 0.03846377650881336']
# ['At iteration 5 the best fitness is 0.03846377650881336']
# ['At iteration 6 the best fitness is 0.03846377650881336']
# ['At iteration 7 the best fitness is 0.03846377650881336']
# ['At iteration 8 the best fitness is 0.03846377650881336']
# ['At iteration 9 the best fitness is 0.03838317468183861']
# ['At iteration 10 the best fitness is 0.03838317468183861']
# ['At iteration 11 the best fitness is 0.03346089488909248']
# ['At iteration 12 the best fitness is 0.03343402761343423']
# ['At iteration 13 the best fitness is 0.03343402761343423']
# ['At iteration 14 the best fitness is 0.03343402761343423']
# ['At iteration 15 the best fitness is 0.03343402761343423']
# ['At iteration 16 the best fitness is 0.03343402761343423']
# ['At iteration 17 the best fitness is 0.03343402761343423']
# ['At iteration 18 the best fitness is 0.03329969123514299']
# ['At iteration 19 the best fitness is 0.03329969123514299']
# ['At iteration 20 the best fitness is 0.03329969123514299']
# ['At iteration 21 the best fitness is 0.03329969123514299']
# ['At iteration 22 the best fitness is 0.03329969123514299']
# ['At iteration 23 the best fitness is 0.03329969123514299']
# ['At iteration 24 the best fitness is 0.03329969123514299']
# ['At iteration 25 the best fitness is 0.03329969123514299']
# ['At iteration 26 the best fitness is 0.03327282395948474']
# ['At iteration 27 the best fitness is 0.03327282395948474']
# ['At iteration 28 the best fitness is 0.03327282395948474']
# ['At iteration 29 the best fitness is 0.03327282395948474']
# ['At iteration 30 the best fitness is 0.03327282395948474']
#       Selected: 891/1861 (47.9%), Fitness: 0.0333, Time: 763.0s
#       Modality: D=49%, Sk=48%
#     Test Acc: 89.90%, F1: 89.26%, Features: 891/1861 (47.9%), Model: 2.276MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.044245809122623325']
# ['At iteration 2 the best fitness is 0.04386966726340785']
# ['At iteration 3 the best fitness is 0.04365472905814186']
# ['At iteration 4 the best fitness is 0.043197985371951644']
# ['At iteration 5 the best fitness is 0.043197985371951644']
# ['At iteration 6 the best fitness is 0.04274124168576142']
# ['At iteration 7 the best fitness is 0.04274124168576142']
# ['At iteration 8 the best fitness is 0.04274124168576142']
# ['At iteration 9 the best fitness is 0.04274124168576142']
# ['At iteration 10 the best fitness is 0.04274124168576142']
# ['At iteration 11 the best fitness is 0.04274124168576142']
# ['At iteration 12 the best fitness is 0.04274124168576142']
# ['At iteration 13 the best fitness is 0.03832944013052211']
# ['At iteration 14 the best fitness is 0.03832944013052211']
# ['At iteration 15 the best fitness is 0.03832944013052211']
# ['At iteration 16 the best fitness is 0.03832944013052211']
# ['At iteration 17 the best fitness is 0.03832944013052211']
# ['At iteration 18 the best fitness is 0.03814136920091438']
# ['At iteration 19 the best fitness is 0.03814136920091438']
# ['At iteration 20 the best fitness is 0.033407160337775986']
# ['At iteration 21 the best fitness is 0.033407160337775986']
# ['At iteration 22 the best fitness is 0.033407160337775986']
# ['At iteration 23 the best fitness is 0.033407160337775986']
# ['At iteration 24 the best fitness is 0.033407160337775986']
# ['At iteration 25 the best fitness is 0.033407160337775986']
# ['At iteration 26 the best fitness is 0.033407160337775986']
# ['At iteration 27 the best fitness is 0.033407160337775986']
# ['At iteration 28 the best fitness is 0.033407160337775986']
# ['At iteration 29 the best fitness is 0.033407160337775986']
# ['At iteration 30 the best fitness is 0.033407160337775986']
#       Selected: 885/1861 (47.6%), Fitness: 0.0334, Time: 768.5s
#       Modality: D=40%, Sk=49%
#     Test Acc: 88.89%, F1: 88.41%, Features: 885/1861 (47.6%), Model: 2.265MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.045024960116712524']
# ['At iteration 1 the best fitness is 0.041209806973241274']
# ['At iteration 2 the best fitness is 0.03809320299688447']
# ['At iteration 3 the best fitness is 0.03809320299688447']
# ['At iteration 4 the best fitness is 0.03357393233901217']
# ['At iteration 5 the best fitness is 0.031639488491618295']
# ['At iteration 6 the best fitness is 0.030860337497529096']
# ['At iteration 7 the best fitness is 0.030645399292263113']
# ['At iteration 8 the best fitness is 0.030645399292263113']
# ['At iteration 9 the best fitness is 0.030645399292263113']
# ['At iteration 10 the best fitness is 0.030645399292263113']
# ['At iteration 11 the best fitness is 0.030645399292263113']
# ['At iteration 12 the best fitness is 0.030645399292263113']
# ['At iteration 13 the best fitness is 0.030645399292263113']
# ['At iteration 14 the best fitness is 0.02597049332772792']
# ['At iteration 15 the best fitness is 0.02597049332772792']
# ['At iteration 16 the best fitness is 0.02597049332772792']
# ['At iteration 17 the best fitness is 0.02597049332772792']
# ['At iteration 18 the best fitness is 0.02597049332772792']
# ['At iteration 19 the best fitness is 0.02597049332772792']
# ['At iteration 20 the best fitness is 0.02597049332772792']
# ['At iteration 21 the best fitness is 0.02597049332772792']
# ['At iteration 22 the best fitness is 0.02441219133954952']
# ['At iteration 23 the best fitness is 0.02441219133954952']
# ['At iteration 24 the best fitness is 0.02441219133954952']
# ['At iteration 25 the best fitness is 0.02441219133954952']
# ['At iteration 26 the best fitness is 0.02441219133954952']
# ['At iteration 27 the best fitness is 0.02441219133954952']
# ['At iteration 28 the best fitness is 0.02441219133954952']
# ['At iteration 29 the best fitness is 0.02441219133954952']
#       Selected: 371/1861 (19.9%), Fitness: 0.0244, Time: 800.8s
#       Modality: D=25%, Sk=19%
#     Test Acc: 86.36%, F1: 86.63%, Features: 371/1861 (19.9%), Model: 1.261MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.038651847438421094']
# ['At iteration 2 the best fitness is 0.038651847438421094']
# ['At iteration 3 the best fitness is 0.038651847438421094']
# ['At iteration 4 the best fitness is 0.03822197102788912']
# ['At iteration 5 the best fitness is 0.03822197102788912']
# ['At iteration 6 the best fitness is 0.03822197102788912']
# ['At iteration 7 the best fitness is 0.03822197102788912']
# ['At iteration 8 the best fitness is 0.03814136920091438']
# ['At iteration 9 the best fitness is 0.03808763464959788']
# ['At iteration 10 the best fitness is 0.03808763464959788']
# ['At iteration 11 the best fitness is 0.03808763464959788']
# ['At iteration 12 the best fitness is 0.038033900098281385']
# ['At iteration 13 the best fitness is 0.038033900098281385']
# ['At iteration 14 the best fitness is 0.03789956371999014']
# ['At iteration 15 the best fitness is 0.03789956371999014']
# ['At iteration 16 the best fitness is 0.037872696444331895']
# ['At iteration 17 the best fitness is 0.03779209461735715']
# ['At iteration 18 the best fitness is 0.03779209461735715']
# ['At iteration 19 the best fitness is 0.0377652273416989']
# ['At iteration 20 the best fitness is 0.0377652273416989']
# ['At iteration 21 the best fitness is 0.0377652273416989']
# ['At iteration 22 the best fitness is 0.0377652273416989']
# ['At iteration 23 the best fitness is 0.0377652273416989']
# ['At iteration 24 the best fitness is 0.0377652273416989']
# ['At iteration 25 the best fitness is 0.0377652273416989']
# ['At iteration 26 the best fitness is 0.0377652273416989']
# ['At iteration 27 the best fitness is 0.0377652273416989']
# ['At iteration 28 the best fitness is 0.0377652273416989']
# ['At iteration 29 the best fitness is 0.03773836006604065']
#       Selected: 888/1861 (47.7%), Fitness: 0.0377, Time: 1903.4s
#       Modality: D=52%, Sk=47%
#     Test Acc: 90.91%, F1: 90.95%, Features: 888/1861 (47.7%), Model: 2.271MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.044138340019990334']
# ['At iteration 1 the best fitness is 0.042886714758626064']
# ['At iteration 2 the best fitness is 0.042886714758626064']
# ['At iteration 3 the best fitness is 0.042886714758626064']
# ['At iteration 4 the best fitness is 0.039904447160560505']
# ['At iteration 5 the best fitness is 0.03648673480467628']
# ['At iteration 6 the best fitness is 0.03648673480467628']
# ['At iteration 7 the best fitness is 0.03648673480467628']
# ['At iteration 8 the best fitness is 0.03648673480467628']
# ['At iteration 9 the best fitness is 0.029898683921118756']
# ['At iteration 10 the best fitness is 0.02984494936980226']
# ['At iteration 11 the best fitness is 0.02984494936980226']
# ['At iteration 12 the best fitness is 0.024922669577056238']
# ['At iteration 13 the best fitness is 0.024922669577056238']
# ['At iteration 14 the best fitness is 0.024922669577056238']
# ['At iteration 15 the best fitness is 0.024922669577056238']
# ['At iteration 16 the best fitness is 0.024922669577056238']
# ['At iteration 17 the best fitness is 0.024922669577056238']
# ['At iteration 18 the best fitness is 0.024922669577056238']
# ['At iteration 19 the best fitness is 0.024922669577056238']
# ['At iteration 20 the best fitness is 0.024922669577056238']
# ['At iteration 21 the best fitness is 0.024922669577056238']
# ['At iteration 22 the best fitness is 0.024922669577056238']
# ['At iteration 23 the best fitness is 0.024922669577056238']
# ['At iteration 24 the best fitness is 0.024922669577056238']
# ['At iteration 25 the best fitness is 0.024922669577056238']
# ['At iteration 26 the best fitness is 0.024922669577056238']
# ['At iteration 27 the best fitness is 0.024788333198764993']
# ['At iteration 28 the best fitness is 0.024788333198764993']
# ['At iteration 29 the best fitness is 0.024788333198764993']
#       Selected: 404/1861 (21.7%), Fitness: 0.0248, Time: 788.2s
#       Modality: D=27%, Sk=21%
#     Test Acc: 84.34%, F1: 83.30%, Features: 404/1861 (21.7%), Model: 1.325MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_no_sensor_new/all_results_per_fold.csv
# Shape: (90, 24)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  skeleton_retention (%)  skeleton_selected
# 0      baseline     1            97.5524           99.4286       97.5582          97.5582              97.7889           97.5524               1861            1861               100.0000       0.0000          9.8041          9.8042       1091862           4.1710                 16.541                 16.5410                 0.0000         42.604             100.0000             216                100.0000               1645
# 1      baseline     2            84.6473           99.4565       84.2681          84.2444              88.1136           84.6694               1861            1861               100.0000       0.0000         12.6641         12.6641       1091862           4.1710                 16.541                 16.5410                 0.0000         42.604             100.0000             216                100.0000               1645
# 2      baseline     3            97.7273           98.9418       97.7158          97.7158              97.9614           97.7273               1861            1861               100.0000       0.0000         12.0757         12.0758       1091862           4.1710                 16.541                 16.5410                 0.0000         42.604             100.0000             216                100.0000               1645
# 3      baseline     4            90.9091           98.4127       90.4036          90.4036              93.1549           90.9091               1861            1861               100.0000       0.0000         12.0515         12.0515       1091862           4.1710                 16.541                 16.5410                 0.0000         42.604             100.0000             216                100.0000               1645
# 4      baseline     5            93.9394           97.9275       93.8460          93.8460              94.5776           93.9394               1861            1861               100.0000       0.0000         13.2446         13.2446       1091862           4.1710                 16.541                 16.5410                 0.0000         42.604             100.0000             216                100.0000               1645
# 5   mutual_info     1            97.5524           99.4286       97.4435          97.4435              97.9315           97.5524                930            1861                49.9731       9.3622          8.6019         17.9642        615190           2.3526                 16.541                  8.2661                50.0269         31.582               4.1667               9                 55.9878                921
# 6   mutual_info     2            87.5519          100.0000       87.7929          87.7837              91.2775           87.5620                930            1861                49.9731       9.3819         11.2764         20.6584        615190           2.3526                 16.541                  8.2661                50.0269         31.582               6.0185              13                 55.7447                917
# 7   mutual_info     3            97.7273           99.4709       97.5758          97.5758              98.4848           97.7273                930            1861                49.9731       9.4974         10.7734         20.2708        615190           2.3526                 16.541                  8.2661                50.0269         31.582               5.5556              12                 55.8055                918
# 8   mutual_info     4            95.0000           98.9418       94.9392          94.9392              96.0683           95.0000                930            1861                49.9731       9.4353         10.7631         20.1985        615190           2.3526                 16.541                  8.2661                50.0269         31.582               2.3148               5                 56.2310                925
# 9   mutual_info     5            96.9697           98.4456       96.9747          96.9747              97.4380           96.9697                930            1861                49.9731       9.4433         11.7347         21.1781        615190           2.3526                 16.541                  8.2661                50.0269         31.582               3.2407               7                 56.1094                923
# 10          rfe     1            97.9021           98.8571       97.8969          97.8969              98.0453           97.9021                930            1861                49.9731       1.8092          9.4829         11.2924        615190           2.3526                 16.541                  8.2661                50.0269         31.582              60.1852             130                 48.6322                800
# 11          rfe     2            87.1369          100.0000       87.1132          87.1190              89.6022           87.1488                930            1861                49.9731       1.8300         11.3461         13.1764        615190           2.3526                 16.541                  8.2661                50.0269         31.582              50.9259             110                 49.8480                820
# 12          rfe     3            98.6364           99.4709       98.6341          98.6341              98.7190           98.6364                930            1861                49.9731       1.8283         10.7951         12.6237        615190           2.3526                 16.541                  8.2661                50.0269         31.582              49.0741             106                 50.0912                824
# 13          rfe     4            92.7273           98.9418       92.1468          92.1468              94.5771           92.7273                930            1861                49.9731       1.8234         10.7706         12.5943        615190           2.3526                 16.541                  8.2661                50.0269         31.582              48.1481             104                 50.2128                826
# 14          rfe     5            90.9091           97.9275       90.8668          90.8668              92.4528           90.9091                930            1861                49.9731       1.8438         11.2541         13.0981        615190           2.3526                 16.541                  8.2661                50.0269         31.582              44.4444              96                 50.6991                834
# 15        lasso     1            95.1049           96.5714       95.0507          95.0507              95.4350           95.1049                930            1861                49.9731       0.3129          9.5954          9.9084        615190           2.3526                 16.541                  8.2661                50.0269         31.582              85.1852             184                 45.3495                746
# 16        lasso     2            85.8921           98.3696       85.5197          85.4815              88.9064           85.9091                930            1861                49.9731       0.3409         11.4152         11.7563        615190           2.3526                 16.541                  8.2661                50.0269         31.582              85.1852             184                 45.3495                746
# 17        lasso     3            97.2727           97.3545       97.2631          97.2631              97.8749           97.2727                930            1861                49.9731       0.3491         10.9925         11.3417        615190           2.3526                 16.541                  8.2661                50.0269         31.582              85.1852             184                 45.3495                746
# 18        lasso     4            90.0000           96.8254       89.4785          89.4785              92.1271           90.0000                930            1861                49.9731       0.3666         10.8131         11.1799        615190           2.3526                 16.541                  8.2661                50.0269         31.582              85.1852             184                 45.3495                746
# 19        lasso     5            92.4242           97.4093       92.3145          92.3145              94.4795           92.4242                930            1861                49.9731       0.2832         11.3974         11.6807        615190           2.3526                 16.541                  8.2661                50.0269         31.582              85.1852             184                 45.3495                746

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              92.96              5.43              92.76              5.62                  1861.0                      100.00              0.00                11.97                11.97          1091862.0                  4.17                        0.00               42.60
# mutual_info              94.96              4.28              94.95              4.14                   930.0                       49.97              9.42                10.63                20.05           615190.0                  2.35                       50.03               31.58
#         rfe              93.46              4.84              93.33              4.88                   930.0                       49.97              1.83                10.73                12.56           615190.0                  2.35                       50.03               31.58
#       lasso              92.14              4.44              91.93              4.62                   930.0                       49.97              0.33                10.84                11.17           615190.0                  2.35                       50.03               31.58
#    meta_BAT              91.97              5.77              91.86              5.80                   912.2                       49.02            738.64                11.22               749.87           606076.4                  2.32                       50.98               31.44
#     meta_CS              92.25              5.30              92.04              5.48                   929.2                       49.93           1476.03                11.31              1487.34           614780.4                  2.35                       50.07               31.61
#     meta_DE              92.15              4.67              91.86              4.90                   887.0                       47.66            749.85                11.23               761.09           593174.0                  2.27                       52.34               31.24
#    meta_FFA              89.71              5.38              89.58              5.49                   916.2                       49.23            722.47                11.34               733.81           608124.4                  2.33                       50.77               31.48
#     meta_GA              92.13              5.45              92.02              5.51                   932.0                       50.08            724.41                11.37               735.78           616214.0                  2.36                       49.92               31.63
#    meta_GWO              91.70              4.25              91.54              4.31                   672.0                       36.11            719.21                10.92               730.13           483094.0                  1.85                       63.89               29.09
#    meta_HHO              89.78              4.81              89.51              4.70                   556.8                       29.92            937.09                11.83               948.92           424111.6                  1.62                       70.08               27.39
#   meta_JAYA              91.76              4.61              91.58              4.85                   913.0                       49.06            745.91                11.30               757.22           606486.0                  2.32                       50.94               31.46
#    meta_MFO              92.30              4.28              92.23              4.18                   910.2                       48.91            701.06                11.49               712.55           605052.4                  2.31                       51.09               31.42
#    meta_MVO              91.23              4.73              90.99              4.73                   907.6                       48.77            717.84                11.06               728.90           603721.2                  2.31                       51.23               31.40
#    meta_PSO              91.47              6.43              91.31              6.50                   892.6                       47.96            725.05                11.26               736.31           596041.2                  2.28                       52.04               31.29
#    meta_SCA              89.15              4.74              88.88              4.83                   392.4                       21.09            754.03                12.87               766.90           339938.8                  1.30                       78.91               25.28
#    meta_SSA              92.10              4.68              92.04              4.68                   897.0                       48.20           1798.50                11.37              1809.87           598294.0                  2.29                       51.80               31.32
#    meta_WOA              89.10              5.84              88.88              6.01                   577.0                       31.00            720.01                12.50               732.51           434454.0                  1.66                       69.00               27.40

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 94.96% vs Baseline: 92.96%
#   Paired t-test: t=2.3754, p=0.0764
#   Wilcoxon test: W=0.0000, p=0.2500
#   -> better, Not significant
#
# RFE vs BASELINE:
#   Method: 93.46% vs Baseline: 92.96%
#   Paired t-test: t=0.5296, p=0.6244
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 92.14% vs Baseline: 92.96%
#   Paired t-test: t=-1.3297, p=0.2544
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 91.97% vs Baseline: 92.96%
#   Paired t-test: t=-1.2712, p=0.2726
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 92.25% vs Baseline: 92.96%
#   Paired t-test: t=-1.4267, p=0.2268
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 92.15% vs Baseline: 92.96%
#   Paired t-test: t=-0.5916, p=0.5860
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 89.71% vs Baseline: 92.96%
#   Paired t-test: t=-3.6416, p=0.0219
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_GA vs BASELINE:
#   Method: 92.13% vs Baseline: 92.96%
#   Paired t-test: t=-0.8915, p=0.4230
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 91.70% vs Baseline: 92.96%
#   Paired t-test: t=-1.7406, p=0.1567
#   Wilcoxon test: W=1.0000, p=0.2500
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 89.78% vs Baseline: 92.96%
#   Paired t-test: t=-3.3974, p=0.0273
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> worse, Significant
#
# META_JAYA vs BASELINE:
#   Method: 91.76% vs Baseline: 92.96%
#   Paired t-test: t=-0.6724, p=0.5382
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 92.30% vs Baseline: 92.96%
#   Paired t-test: t=-0.8980, p=0.4200
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 91.23% vs Baseline: 92.96%
#   Paired t-test: t=-2.2892, p=0.0839
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 91.47% vs Baseline: 92.96%
#   Paired t-test: t=-1.4520, p=0.2202
#   Wilcoxon test: W=2.0000, p=0.3750
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 89.15% vs Baseline: 92.96%
#   Paired t-test: t=-3.3372, p=0.0289
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_SSA vs BASELINE:
#   Method: 92.10% vs Baseline: 92.96%
#   Paired t-test: t=-1.3015, p=0.2630
#   Wilcoxon test: W=2.0000, p=0.3750
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 89.10% vs Baseline: 92.96%
#   Paired t-test: t=-2.4174, p=0.0730
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_no_sensor_new
#
# Per-method folders:
#   results_no_sensor_new/baseline/ (10 files)
#   results_no_sensor_new/mutual_info/ (10 files)
#   results_no_sensor_new/rfe/ (10 files)
#   results_no_sensor_new/lasso/ (10 files)
#   results_no_sensor_new/meta_BAT/ (10 files)
#   results_no_sensor_new/meta_CS/ (10 files)
#   results_no_sensor_new/meta_DE/ (10 files)
#   results_no_sensor_new/meta_FFA/ (10 files)
#   results_no_sensor_new/meta_GA/ (10 files)
#   results_no_sensor_new/meta_GWO/ (10 files)
#   results_no_sensor_new/meta_HHO/ (10 files)
#   results_no_sensor_new/meta_JAYA/ (10 files)
#   results_no_sensor_new/meta_MFO/ (10 files)
#   results_no_sensor_new/meta_MVO/ (10 files)
#   results_no_sensor_new/meta_PSO/ (10 files)
#   results_no_sensor_new/meta_SCA/ (10 files)
#   results_no_sensor_new/meta_SSA/ (10 files)
#   results_no_sensor_new/meta_WOA/ (10 files)
#
# Plots directory: results_no_sensor_new/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   mutual_info         : 94.96% ± 4.28% (Features: 50.0%)
#   rfe                 : 93.46% ± 4.84% (Features: 50.0%)
#   baseline            : 92.96% ± 5.43% (Features: 100.0%)
#   meta_MFO            : 92.30% ± 4.28% (Features: 48.9%)
#   meta_CS             : 92.25% ± 5.30% (Features: 49.9%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_BAT
#     Test Accuracy:      98.25%
#     Feature Retention:  49.60% (923/1861)
#     Modality Retention: depth=46.3%, skeleton=50.0%
#
#   Fold 2: Best = meta_JAYA
#     Test Accuracy:      89.21%
#     Feature Retention:  48.63% (905/1861)
#     Modality Retention: depth=47.7%, skeleton=48.8%
#
#   Fold 3: Best = meta_JAYA
#     Test Accuracy:      98.64%
#     Feature Retention:  50.83% (946/1861)
#     Modality Retention: depth=50.0%, skeleton=50.9%
#
#   Fold 4: Best = meta_GA
#     Test Accuracy:      92.27%
#     Feature Retention:  50.19% (934/1861)
#     Modality Retention: depth=56.0%, skeleton=49.4%
#
#   Fold 5: Best = meta_CS
#     Test Accuracy:      94.44%
#     Feature Retention:  52.12% (970/1861)
#     Modality Retention: depth=54.6%, skeleton=51.8%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     94.56% ± 4.00%
#   Average Feature Retention: 50.27% ± 1.31%
#
#   Average Modality-wise Feature Retention:
#          depth: 50.93% ± 4.26%
#       skeleton: 50.19% ± 1.21%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  skeleton Retention (%)
#     1           meta_BAT              98.25                  49.60                46.30                   50.03
#     2          meta_JAYA              89.21                  48.63                47.69                   48.75
#     3          meta_JAYA              98.64                  50.83                50.00                   50.94
#     4            meta_GA              92.27                  50.19                56.02                   49.42
#     5            meta_CS              94.44                  52.12                54.63                   51.79
#
# Saved to: results_no_sensor_new/best_metaheuristic_per_fold.csv
