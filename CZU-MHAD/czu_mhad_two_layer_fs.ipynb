# %% [markdown]
# # CZU-MHAD: Two-Layer Feature Selection (Per-Modality → Combined)
#
# ## Overview
# This notebook implements a **two-layer feature selection** pipeline:
#
# **Layer 1 (already done):** Feature selection was run independently on each modality (depth, sensor, skeleton, video). Results are stored in:
# - `results_new_depth/`
# - `results_new_sensor/`
# - `results_new_skeleton/`
# - `results_new_video/`
#
# **Layer 2 (this notebook):**
# 1. **Combine** the selected features from each modality into a unified feature set
# 2. **Evaluate** the combined features (Layer 1 result) on HAR
# 3. **Run a second layer** of feature selection on the combined set
#
# ### Combination Strategy:
# - **Standard methods** (mutual_info, rfe, lasso): Combine features selected by the *same* method across all 4 modalities. Then run the same FS method again on the combined set.
# - **Metaheuristics**: For each fold, find the *best* metaheuristic (highest test accuracy) per modality. Combine those best-selected features. Then run all 14 metaheuristics on that combined set.
# - **Baseline**: Combine all baseline (all features) from each modality = full feature set.
#
# All results saved in `results_two_layer/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Layer 1 results directories (already computed)
LAYER1_DIRS = {
    'depth': Path("results_depth"),
    'sensor': Path("results_sensor"),
    'skeleton': Path("results_skeleton"),
}

# Master output directory for two-layer results
RESULTS_ROOT = Path("results_two_layer")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters (same as original)
N_FOLDS = 5  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of combined features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

STANDARD_METHODS = ['mutual_info', 'rfe', 'lasso']
META_METHODS = [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]
# For layer 2, we have: 3 standard methods, and meta_best (which runs all 14 metas)
# Output method names for layer 2:
ALL_METHODS_L2 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS_L2:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)
# Also create combined_layer1 directory
(RESULTS_ROOT / "combined_layer1").mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection (Layer 2): {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Layer 1 dirs: {list(LAYER1_DIRS.keys())}")

# Verify layer 1 directories exist
for mod, d in LAYER1_DIRS.items():
    if d.exists():
        print(f"  ✓ {d} exists")
    else:
        print(f"  ✗ {d} MISSING!")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection (Layer 2): 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Layer 1 dirs: ['depth', 'sensor', 'skeleton']
#   ✓ results_depth exists
#   ✓ results_sensor exists
#   ✓ results_skeleton exists

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
    'depth': first_sample['depth_feat'].shape[0],
    'sensor': first_sample['sensor_feat'].shape[0],
    'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")

# Compute modality offsets in the unified feature vector
MODALITY_OFFSETS = {}
offset = 0
for mod, dim in FEATURE_DIMS.items():
    MODALITY_OFFSETS[mod] = (offset, offset + dim)
    offset += dim
print(f"\nModality offsets in unified vector:")
for mod, (s, e) in MODALITY_OFFSETS.items():
    print(f"  {mod}: [{s}, {e})")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   depth: 37
#   sensor: 9
#   skeleton: 400
#   TOTAL: 446
#
# Modality offsets in unified vector:
#   depth: [0, 37)
#   sensor: [37, 46)
#   skeleton: [46, 446)

# %% [markdown]
# ## Neural Network Model

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Load Layer 1 Results (Pre-computed Per-Modality Feature Selection)
#
# Load the feature masks from each modality's per-fold results.

# %%
def load_layer1_masks():
    """
    Load all Layer 1 feature masks from per-modality results directories.
    
    Returns:
        layer1_masks: dict[modality][method][fold_idx] = binary_mask (numpy bool array)
        layer1_results: dict[modality][method][fold_idx] = json_results (dict)
    """
    layer1_masks = {}
    layer1_results = {}
    
    all_methods_l1 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]
    
    for modality, results_dir in LAYER1_DIRS.items():
        layer1_masks[modality] = {}
        layer1_results[modality] = {}
        
        for method in all_methods_l1:
            layer1_masks[modality][method] = {}
            layer1_results[modality][method] = {}
            
            method_dir = results_dir / method
            if not method_dir.exists():
                print(f"  WARNING: {method_dir} does not exist!")
                continue
            
            for fold_idx in range(N_FOLDS):
                mask_path = method_dir / f"fold_{fold_idx+1}_mask.npy"
                json_path = method_dir / f"fold_{fold_idx+1}.json"
                
                if mask_path.exists():
                    mask = np.load(mask_path)
                    layer1_masks[modality][method][fold_idx] = mask
                else:
                    print(f"  WARNING: Missing mask: {mask_path}")
                
                if json_path.exists():
                    with open(json_path) as f:
                        layer1_results[modality][method][fold_idx] = json_lib.load(f)
    
    return layer1_masks, layer1_results

layer1_masks, layer1_results = load_layer1_masks()

# Summary
print("\n" + "="*80)
print("LAYER 1 MASKS LOADED")
print("="*80)
modalities = list(LAYER1_DIRS.keys())
all_methods_l1 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for modality in modalities:
    n_loaded = sum(
        len(layer1_masks[modality].get(m, {})) 
        for m in all_methods_l1
    )
    print(f"  {modality}: {n_loaded} fold-masks loaded across {len(all_methods_l1)} methods")
# Out:
# ================================================================================
# LAYER 1 MASKS LOADED
# ================================================================================
#   depth: 85 fold-masks loaded across 17 methods
#   sensor: 85 fold-masks loaded across 17 methods
#   skeleton: 85 fold-masks loaded across 17 methods

# %% [markdown]
# ## Combine Layer 1 Selected Features Into Unified Masks
#
# ### Strategy:
# - **Standard methods** (mutual_info, rfe, lasso): For each fold, take the selected features from the same method in each modality and combine them (union into unified feature space).
# - **Metaheuristics**: For each fold, find the best metaheuristic per modality (highest test accuracy), then combine those best-selected features.
# - **Baseline**: All features from all modalities (full feature set).
#
# The combined mask is over the full unified feature space (depth + sensor + skeleton + video).

# %%
def build_combined_mask_standard(method, fold_idx):
    """
    For a standard method, combine selected features from the same method 
    across all 3 modalities into a unified mask over the full feature space.
    
    Each modality mask is a boolean array over that modality's features only.
    We map them to their correct positions in the unified vector.
    """
    unified_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    
    for modality in modalities:
        if method not in layer1_masks[modality]:
            continue
        if fold_idx not in layer1_masks[modality][method]:
            continue
        
        mod_mask = layer1_masks[modality][method][fold_idx]
        start, end = MODALITY_OFFSETS[modality]
        mod_dim = end - start
        
        # The modality mask length should match the modality dimension
        if len(mod_mask) == mod_dim:
            unified_mask[start:end] = mod_mask
        else:
            print(f"  WARNING: {modality}/{method}/fold_{fold_idx+1} mask length "
                  f"{len(mod_mask)} != expected {mod_dim}")
    
    return unified_mask


def find_best_meta_per_modality(fold_idx):
    """
    For a given fold, find which metaheuristic gave the highest test accuracy
    in each modality. Returns dict[modality] = (best_method_name, test_acc).
    """
    best_per_mod = {}
    
    for modality in modalities:
        best_method = None
        best_acc = -1.0
        
        for method in META_METHODS:
            if method not in layer1_results[modality]:
                continue
            if fold_idx not in layer1_results[modality][method]:
                continue
            
            result = layer1_results[modality][method][fold_idx]
            test_acc = result.get('test_acc', 0)
            
            if test_acc > best_acc:
                best_acc = test_acc
                best_method = method
        
        best_per_mod[modality] = (best_method, best_acc)
    
    return best_per_mod


def build_combined_mask_best_meta(fold_idx):
    """
    For metaheuristics: find best meta per modality for this fold,
    then combine their selected features into a unified mask.
    """
    unified_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    best_per_mod = find_best_meta_per_modality(fold_idx)
    
    for modality in modalities:
        best_method, best_acc = best_per_mod[modality]
        if best_method is None:
            print(f"  WARNING: No meta results for {modality} fold {fold_idx+1}")
            continue
        
        mod_mask = layer1_masks[modality][best_method][fold_idx]
        start, end = MODALITY_OFFSETS[modality]
        mod_dim = end - start
        
        if len(mod_mask) == mod_dim:
            unified_mask[start:end] = mod_mask
        else:
            print(f"  WARNING: {modality}/{best_method}/fold_{fold_idx+1} mask length "
                  f"{len(mod_mask)} != expected {mod_dim}")
    
    return unified_mask, best_per_mod


# Build all combined masks
combined_masks = {}  # method -> {fold_idx: mask}

# Standard methods
for method in STANDARD_METHODS:
    combined_masks[method] = {}
    for fold_idx in range(N_FOLDS):
        combined_masks[method][fold_idx] = build_combined_mask_standard(method, fold_idx)

# Best metaheuristic combination
combined_masks['meta_best'] = {}
meta_best_info = {}  # fold_idx -> best_per_mod
for fold_idx in range(N_FOLDS):
    mask, best_per_mod = build_combined_mask_best_meta(fold_idx)
    combined_masks['meta_best'][fold_idx] = mask
    meta_best_info[fold_idx] = best_per_mod

# Print summary
print("="*80)
print("COMBINED LAYER 1 MASKS SUMMARY")
print("="*80)

for method in STANDARD_METHODS + ['meta_best']:
    avg_selected = np.mean([np.sum(combined_masks[method][f]) for f in range(N_FOLDS)])
    print(f"  {method:15s}: avg {avg_selected:.0f}/{TOTAL_FEATURES} features selected "
          f"({avg_selected/TOTAL_FEATURES*100:.1f}%)")

print("\nBest metaheuristic per modality per fold:")
for fold_idx in range(N_FOLDS):
    info = meta_best_info[fold_idx]
    parts = [f"{mod}={info[mod][0]}({info[mod][1]*100:.1f}%)" for mod in modalities]
    print(f"  Fold {fold_idx+1}: {', '.join(parts)}")
# Out:
# ================================================================================
# COMBINED LAYER 1 MASKS SUMMARY
# ================================================================================
#   mutual_info    : avg 222/446 features selected (49.8%)
#   rfe            : avg 222/446 features selected (49.8%)
#   lasso          : avg 222/446 features selected (49.8%)
#   meta_best      : avg 203/446 features selected (45.5%)
#
# Best metaheuristic per modality per fold:
#   Fold 1: depth=meta_HHO(34.6%), sensor=meta_FFA(37.8%), skeleton=meta_GWO(95.8%)
#   Fold 2: depth=meta_MVO(27.8%), sensor=meta_GA(35.7%), skeleton=meta_MFO(90.9%)
#   Fold 3: depth=meta_MVO(26.4%), sensor=meta_JAYA(32.7%), skeleton=meta_BAT(97.7%)
#   Fold 4: depth=meta_PSO(10.9%), sensor=meta_WOA(33.6%), skeleton=meta_GA(95.9%)
#   Fold 5: depth=meta_MFO(22.7%), sensor=meta_DE(39.9%), skeleton=meta_GA(93.9%)

# %% [markdown]
# ## Evaluate Combined Layer 1 Features (Before Second Layer FS)
#
# Train and evaluate the neural network on the combined features from Layer 1,
# **without** any additional feature selection. This shows the HAR performance
# of simply combining per-modality selected features.

# %%
def evaluate_combined_layer1():
    """
    Evaluate combined Layer 1 features (no second-layer FS yet).
    This gives us the baseline performance of the combined per-modality selections.
    """
    print("="*80)
    print("EVALUATING COMBINED LAYER 1 FEATURES (before Layer 2 FS)")
    print("="*80)
    
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    layer1_eval_results = {}  # method -> {fold_idx: metrics}
    
    methods_to_eval = STANDARD_METHODS + ['meta_best']
    
    for method in methods_to_eval:
        layer1_eval_results[method] = {}
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*60}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*60}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val (same as original)
        np.random.seed(42)  # ensure same split as original
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        for method in methods_to_eval:
            print(f"\n  --- Combined L1: {method.upper()} ---")
            
            feature_mask = combined_masks[method][fold_idx]
            
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            modality_ret = calculate_modality_retention(feature_mask, FEATURE_DIMS)
            
            fold_result = {
                'fold': fold_idx,
                'method': f'combined_L1_{method}',
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
            }
            
            layer1_eval_results[method][fold_idx] = fold_result
            
            # Save
            save_dir = RESULTS_ROOT / "combined_layer1"
            fold_save = {k: v for k, v in fold_result.items() if k != 'feature_mask'}
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(save_dir / f"combined_L1_{method}_fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(save_dir / f"combined_L1_{method}_fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%)")
            
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    return layer1_eval_results

layer1_eval_results = evaluate_combined_layer1()
# Out:
# ================================================================================
# EVALUATING COMBINED LAYER 1 FEATURES (before Layer 2 FS)
# ================================================================================
#
# ############################################################
# # FOLD 1/5
# ############################################################
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 92.31%, F1: 91.79%, Features: 222/446 (49.8%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 93.71%, F1: 93.34%, Features: 222/446 (49.8%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 90.21%, F1: 89.38%, Features: 222/446 (49.8%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 91.61%, F1: 91.27%, Features: 168/446 (37.7%)
#
# ############################################################
# # FOLD 2/5
# ############################################################
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 89.63%, F1: 89.77%, Features: 222/446 (49.8%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 90.04%, F1: 90.25%, Features: 222/446 (49.8%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 87.14%, F1: 86.74%, Features: 222/446 (49.8%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 90.87%, F1: 91.08%, Features: 211/446 (47.3%)
#
# ############################################################
# # FOLD 3/5
# ############################################################
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 93.18%, F1: 92.98%, Features: 222/446 (49.8%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 98.18%, F1: 98.20%, Features: 222/446 (49.8%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 98.18%, F1: 98.15%, Features: 222/446 (49.8%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 92.73%, F1: 92.56%, Features: 220/446 (49.3%)
#
# ############################################################
# # FOLD 4/5
# ############################################################
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 86.82%, F1: 84.82%, Features: 222/446 (49.8%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 89.55%, F1: 87.02%, Features: 222/446 (49.8%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 84.09%, F1: 83.03%, Features: 222/446 (49.8%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 91.36%, F1: 91.32%, Features: 202/446 (45.3%)
#
# ############################################################
# # FOLD 5/5
# ############################################################
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 86.36%, F1: 86.15%, Features: 222/446 (49.8%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 93.94%, F1: 93.38%, Features: 222/446 (49.8%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 85.35%, F1: 85.41%, Features: 222/446 (49.8%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 86.87%, F1: 88.18%, Features: 213/446 (47.8%)

# %% [markdown]
# ## Layer 1 Combined Results Summary

# %%
print("\n" + "="*80)
print("COMBINED LAYER 1 RESULTS SUMMARY")
print("="*80)

methods_to_eval = STANDARD_METHODS + ['meta_best']

rows = []
for method in methods_to_eval:
    accs = []
    f1s = []
    feats = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in layer1_eval_results[method]:
            r = layer1_eval_results[method][fold_idx]
            accs.append(r['test_acc'] * 100)
            f1s.append(r['test_f1_macro'] * 100)
            feats.append(r['num_features_selected'])
    
    if accs:
        rows.append({
            'Method': f'Combined_L1_{method}',
            'Mean Test Acc (%)': np.mean(accs),
            'Std Test Acc (%)': np.std(accs),
            'Mean F1 Macro (%)': np.mean(f1s),
            'Mean Features': np.mean(feats),
            'Mean Retention (%)': np.mean(feats) / TOTAL_FEATURES * 100,
        })

df_l1_summary = pd.DataFrame(rows).round(2)
print(df_l1_summary.to_string(index=False))

# Save
df_l1_summary.to_csv(RESULTS_ROOT / "combined_layer1_summary.csv", index=False)
print(f"\nSaved: combined_layer1_summary.csv")
# Out:
# ================================================================================
# COMBINED LAYER 1 RESULTS SUMMARY
# ================================================================================
#                  Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Mean Features  Mean Retention (%)
# Combined_L1_mutual_info              89.66              2.77              89.10          222.0               49.78
#         Combined_L1_rfe              93.08              3.13              92.44          222.0               49.78
#       Combined_L1_lasso              88.99              5.03              88.54          222.0               49.78
#   Combined_L1_meta_best              90.69              2.00              90.88          202.8               45.47
#
# Saved: combined_layer1_summary.csv

# %% [markdown]
# ## Feature Selection Methods for Layer 2
#
# These are the same FS methods as the original notebook, but now they operate
# on the **combined Layer 1 features** (a subset of the full feature space).

# %%
def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


def create_fitness_function_evolopy_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Create fitness function for EvoloPy Layer 2"""
    eval_count = [0]
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            alpha = 0.95
            beta = 0.05
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer_l2(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run any EvoloPy optimizer on Layer 2 features"""
    print(f"    Running EvoloPy {optimizer_name} (Layer 2)...")
    print(f"      Features: {n_features_l2}, Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_features_l2, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = np.random.rand(n_features_l2) < s_transfer(solution.bestIndividual)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    
    return results


def run_mutual_info_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run Mutual Information feature selection on Layer 2"""
    print("    Running Mutual Information (Layer 2)...")
    
    start_time = time.time()
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    k = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_features_l2, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run RFE feature selection on Layer 2"""
    print("    Running RFE (Layer 2)...")
    
    start_time = time.time()
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    k = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    step = max(1, min(50, n_features_l2 // 10))
    selector = RFE(estimator, n_features_to_select=k, step=step)
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    execution_time = time.time() - start_time
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run LASSO feature selection on Layer 2"""
    print("    Running LASSO (Layer 2)...")
    start_time = time.time()

    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    target_count = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_features_l2, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Layer 2 feature selection methods defined")
# Out:
# Layer 2 feature selection methods defined

# %% [markdown]
# ## Main Layer 2 Experiment Runner
#
# ### Process for each fold:
# 1. **Standard methods** (mutual_info, rfe, lasso):
#    - Take combined L1 mask → extract those features from unified data
#    - Run the *same* FS method on this subset
#    - The L2 mask is relative to the L1-selected features; map back to unified space
#
# 2. **Metaheuristics**:
#    - Take combined best-meta L1 mask → extract those features
#    - Run ALL 14 metaheuristics on this subset

# %%
def save_fold_result(fold_result, method_name, fold_idx):
    """Save a fold result to disk"""
    fold_dir = RESULTS_ROOT / method_name
    fold_dir.mkdir(exist_ok=True)
    
    fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
    fold_save_clean = {}
    for k, v in fold_save.items():
        if isinstance(v, np.ndarray):
            fold_save_clean[k] = v.tolist()
        elif isinstance(v, (np.floating, np.integer)):
            fold_save_clean[k] = float(v)
        elif isinstance(v, dict):
            fold_save_clean[k] = {}
            for kk, vv in v.items():
                if isinstance(vv, dict):
                    fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                else:
                    fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
            
        else:
            fold_save_clean[k] = v
    
    with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
        json_lib.dump(fold_save_clean, f, indent=2, default=str)
    
    np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", fold_result['feature_mask'])


def run_layer2_experiments():
    """
    Run Layer 2 feature selection on combined Layer 1 features.
    """
    print("="*80)
    print("STARTING LAYER 2 FEATURE SELECTION EXPERIMENTS")
    print("="*80)
    
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    master_results = {m: {} for m in ALL_METHODS_L2}
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data (same as original)
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        np.random.seed(42)
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize full unified features
        scaler = StandardScaler()
        X_train_norm = scaler.fit_transform(X_train)
        X_val_norm = scaler.transform(X_val)
        X_test_norm = scaler.transform(X_test)
        
        orig_dataset_size_mb = get_dataset_size_mb(X_train_norm) + get_dataset_size_mb(X_val_norm) + get_dataset_size_mb(X_test_norm)
        
        # =================================================================
        # STANDARD METHODS: mutual_info, rfe, lasso
        # =================================================================
        for std_method in STANDARD_METHODS:
            print(f"\n  --- Layer 2: {std_method.upper()} ---")
            
            # Get combined L1 mask for this method
            l1_mask = combined_masks[std_method][fold_idx]
            l1_indices = np.where(l1_mask)[0]  # indices in unified space
            n_l1_features = len(l1_indices)
            
            print(f"    L1 combined features: {n_l1_features}/{TOTAL_FEATURES}")
            
            # Extract L1-selected features
            X_train_l1 = X_train_norm[:, l1_mask]
            X_val_l1 = X_val_norm[:, l1_mask]
            X_test_l1 = X_test_norm[:, l1_mask]
            
            fs_start_time = time.time()
            
            # Run Layer 2 FS on the L1-selected features
            if std_method == 'mutual_info':
                fs_results = run_mutual_info_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            elif std_method == 'rfe':
                fs_results = run_rfe_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            elif std_method == 'lasso':
                fs_results = run_lasso_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            
            fs_time = time.time() - fs_start_time
            
            # L2 mask is relative to L1 features; map back to unified space
            l2_mask_relative = fs_results['mask']
            
            # Final unified mask
            final_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
            final_mask[l1_indices[l2_mask_relative]] = True
            
            # Apply final mask
            X_train_sel = X_train_norm[:, final_mask]
            X_val_sel = X_val_norm[:, final_mask]
            X_test_sel = X_test_norm[:, final_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes)
            modality_ret = calculate_modality_retention(final_mask, FEATURE_DIMS)
            
            fold_result = {
                'fold': fold_idx, 'method': std_method,
                'l1_method': std_method, 'l1_features': n_l1_features,
                'val_acc': eval_metrics['val_acc'], 'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'], 'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'], 'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(final_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(final_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret, 'feature_mask': final_mask,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'], 'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb, 'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': None, 'best_fitness': None,
            }
            
            master_results[std_method][fold_idx] = fold_result
            save_fold_result(fold_result, std_method, fold_idx)
            
            print(f"    L2 Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(final_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(final_mask)/TOTAL_FEATURES*100:.1f}%)")
            
            del model, train_dataset, val_dataset, test_dataset, train_loader, val_loader, test_loader
            torch.cuda.empty_cache(); gc.collect()
        
        # =================================================================
        # METAHEURISTICS: Run all 14 on combined best-meta L1 features
        # =================================================================
        l1_mask_meta = combined_masks['meta_best'][fold_idx]
        l1_indices_meta = np.where(l1_mask_meta)[0]
        n_l1_meta_features = len(l1_indices_meta)
        
        print(f"\n  --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---")
        print(f"    L1 combined best-meta features: {n_l1_meta_features}/{TOTAL_FEATURES}")
        best_info = meta_best_info[fold_idx]
        for mod in modalities:
            print(f"      {mod}: {best_info[mod][0]} (acc={best_info[mod][1]*100:.1f}%)")
        
        X_train_l1_meta = X_train_norm[:, l1_mask_meta]
        X_val_l1_meta = X_val_norm[:, l1_mask_meta]
        X_test_l1_meta = X_test_norm[:, l1_mask_meta]
        
        for opt_name, opt_func in EVOLOPY_OPTIMIZERS.items():
            method_name = f'meta_{opt_name}'
            print(f"\n  --- Layer 2: {method_name.upper()} ---")
            
            fs_start_time = time.time()
            fs_results = run_evolopy_optimizer_l2(
                opt_name, opt_func, 
                X_train_l1_meta, y_train, X_val_l1_meta, y_val, 
                num_classes, n_l1_meta_features
            )
            fs_time = time.time() - fs_start_time
            
            l2_mask_relative = fs_results['mask']
            
            final_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
            final_mask[l1_indices_meta[l2_mask_relative]] = True
            
            X_train_sel = X_train_norm[:, final_mask]
            X_val_sel = X_val_norm[:, final_mask]
            X_test_sel = X_test_norm[:, final_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes)
            modality_ret = calculate_modality_retention(final_mask, FEATURE_DIMS)
            
            fold_result = {
                'fold': fold_idx, 'method': method_name,
                'l1_method': 'meta_best', 'l1_features': n_l1_meta_features,
                'l1_best_per_modality': {mod: {'method': best_info[mod][0], 'acc': best_info[mod][1]} for mod in modalities},
                'val_acc': eval_metrics['val_acc'], 'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'], 'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'], 'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(final_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(final_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret, 'feature_mask': final_mask,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'], 'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb, 'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            save_fold_result(fold_result, method_name, fold_idx)
            
            print(f"    L2 Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(final_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(final_mask)/TOTAL_FEATURES*100:.1f}%)")
            
            del model, train_dataset, val_dataset, test_dataset, train_loader, val_loader, test_loader
            torch.cuda.empty_cache(); gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL LAYER 2 EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Layer 2 experiment runner defined")
# Out:
# Layer 2 experiment runner defined

# %% [markdown]
# ## Run Layer 2 Experiments

# %%
master_results = run_layer2_experiments()
# Out:
# ================================================================================
# STARTING LAYER 2 FEATURE SELECTION EXPERIMENTS
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#
#   --- Layer 2: MUTUAL_INFO ---
#     L1 combined features: 222/446
#     Running Mutual Information (Layer 2)...
#       Selected: 111/222 (50.0%), Time: 1.1s
#     L2 Test Acc: 91.26%, F1: 90.76%, Features: 111/446 (24.9%)
#
#   --- Layer 2: RFE ---
#     L1 combined features: 222/446
#     Running RFE (Layer 2)...
#       Selected: 111/222 (50.0%), Time: 0.5s
#     L2 Test Acc: 90.56%, F1: 89.83%, Features: 111/446 (24.9%)
#
#   --- Layer 2: LASSO ---
#     L1 combined features: 222/446
#     Running LASSO (Layer 2)...
#       Selected: 111/222 (50.0%), Time: 0.0s
#     L2 Test Acc: 93.36%, F1: 93.07%, Features: 111/446 (24.9%)
#
#   --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---
#     L1 combined best-meta features: 168/446
#       depth: meta_HHO (acc=34.6%)
#       sensor: meta_FFA (acc=37.8%)
#       skeleton: meta_GWO (acc=95.8%)
#
#   --- Layer 2: META_BAT ---
#     Running EvoloPy BAT (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07177380952380948']
# ['At iteration 1 the best fitness is 0.07177380952380948']
# ['At iteration 2 the best fitness is 0.07177380952380948']
# ['At iteration 3 the best fitness is 0.0663452380952381']
# ['At iteration 4 the best fitness is 0.0663452380952381']
# ['At iteration 5 the best fitness is 0.0663452380952381']
# ['At iteration 6 the best fitness is 0.0663452380952381']
# ['At iteration 7 the best fitness is 0.0663452380952381']
# ['At iteration 8 the best fitness is 0.0663452380952381']
# ['At iteration 9 the best fitness is 0.0663452380952381']
# ['At iteration 10 the best fitness is 0.0663452380952381']
# ['At iteration 11 the best fitness is 0.0663452380952381']
# ['At iteration 12 the best fitness is 0.0663452380952381']
# ['At iteration 13 the best fitness is 0.0663452380952381']
# ['At iteration 14 the best fitness is 0.0663452380952381']
# ['At iteration 15 the best fitness is 0.0663452380952381']
# ['At iteration 16 the best fitness is 0.0663452380952381']
# ['At iteration 17 the best fitness is 0.0663452380952381']
# ['At iteration 18 the best fitness is 0.05578571428571425']
# ['At iteration 19 the best fitness is 0.05578571428571425']
# ['At iteration 20 the best fitness is 0.05578571428571425']
# ['At iteration 21 the best fitness is 0.05578571428571425']
# ['At iteration 22 the best fitness is 0.05578571428571425']
# ['At iteration 23 the best fitness is 0.05578571428571425']
# ['At iteration 24 the best fitness is 0.05578571428571425']
# ['At iteration 25 the best fitness is 0.055488095238095204']
# ['At iteration 26 the best fitness is 0.055488095238095204']
# ['At iteration 27 the best fitness is 0.05005952380952382']
# ['At iteration 28 the best fitness is 0.05005952380952382']
# ['At iteration 29 the best fitness is 0.05005952380952382']
#       Selected: 77/168 (45.8%), Fitness: 0.0501, Time: 335.5s
#     L2 Test Acc: 93.71%, F1: 92.78%, Features: 77/446 (17.3%)
#
#   --- Layer 2: META_CS ---
#     Running EvoloPy CS (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06121428571428575']
# ['At iteration 10 the best fitness is 0.05489285714285711']
# ['At iteration 20 the best fitness is 0.05489285714285711']
#       Selected: 72/168 (42.9%), Fitness: 0.0540, Time: 657.7s
#     L2 Test Acc: 86.71%, F1: 86.25%, Features: 72/446 (16.1%)
#
#   --- Layer 2: META_DE ---
#     Running EvoloPy DE (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06694047619047619']
# ['At iteration 2 the best fitness is 0.06545238095238094']
# ['At iteration 3 the best fitness is 0.06545238095238094']
# ['At iteration 4 the best fitness is 0.06545238095238094']
# ['At iteration 5 the best fitness is 0.06545238095238094']
# ['At iteration 6 the best fitness is 0.059726190476190516']
# ['At iteration 7 the best fitness is 0.059726190476190516']
# ['At iteration 8 the best fitness is 0.059726190476190516']
# ['At iteration 9 the best fitness is 0.059726190476190516']
# ['At iteration 10 the best fitness is 0.05942857142857146']
# ['At iteration 11 the best fitness is 0.05942857142857146']
# ['At iteration 12 the best fitness is 0.05942857142857146']
# ['At iteration 13 the best fitness is 0.05942857142857146']
# ['At iteration 14 the best fitness is 0.0560833333333333']
# ['At iteration 15 the best fitness is 0.05489285714285711']
# ['At iteration 16 the best fitness is 0.05459523809523806']
# ['At iteration 17 the best fitness is 0.05459523809523806']
# ['At iteration 18 the best fitness is 0.05459523809523806']
# ['At iteration 19 the best fitness is 0.05459523809523806']
# ['At iteration 20 the best fitness is 0.05459523809523806']
# ['At iteration 21 the best fitness is 0.05340476190476187']
# ['At iteration 22 the best fitness is 0.05340476190476187']
# ['At iteration 23 the best fitness is 0.05340476190476187']
# ['At iteration 24 the best fitness is 0.05340476190476187']
# ['At iteration 25 the best fitness is 0.0530357142857143']
# ['At iteration 26 the best fitness is 0.0530357142857143']
# ['At iteration 27 the best fitness is 0.0530357142857143']
# ['At iteration 28 the best fitness is 0.0530357142857143']
# ['At iteration 29 the best fitness is 0.0530357142857143']
# ['At iteration 30 the best fitness is 0.0530357142857143']
#       Selected: 76/168 (45.2%), Fitness: 0.0530, Time: 333.8s
#     L2 Test Acc: 88.81%, F1: 87.25%, Features: 76/446 (17.0%)
#
#   --- Layer 2: META_FFA ---
#     Running EvoloPy FFA (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06329761904761907']
# ['At iteration 1 the best fitness is 0.07110714285714285']
# ['At iteration 2 the best fitness is 0.06270238095238098']
# ['At iteration 3 the best fitness is 0.06359523809523812']
# ['At iteration 4 the best fitness is 0.06753571428571428']
# ['At iteration 5 the best fitness is 0.06359523809523812']
# ['At iteration 6 the best fitness is 0.06842857142857142']
# ['At iteration 7 the best fitness is 0.07385714285714282']
# ['At iteration 8 the best fitness is 0.06300000000000003']
# ['At iteration 9 the best fitness is 0.07355952380952377']
# ['At iteration 10 the best fitness is 0.06872619047619047']
# ['At iteration 11 the best fitness is 0.06329761904761907']
# ['At iteration 12 the best fitness is 0.06329761904761907']
# ['At iteration 13 the best fitness is 0.06872619047619047']
# ['At iteration 14 the best fitness is 0.06872619047619047']
# ['At iteration 15 the best fitness is 0.07415476190476186']
# ['At iteration 16 the best fitness is 0.07415476190476186']
# ['At iteration 17 the best fitness is 0.06329761904761907']
# ['At iteration 18 the best fitness is 0.06329761904761907']
# ['At iteration 19 the best fitness is 0.06329761904761907']
# ['At iteration 20 the best fitness is 0.06872619047619047']
# ['At iteration 21 the best fitness is 0.06872619047619047']
# ['At iteration 22 the best fitness is 0.06872619047619047']
# ['At iteration 23 the best fitness is 0.06872619047619047']
# ['At iteration 24 the best fitness is 0.06872619047619047']
# ['At iteration 25 the best fitness is 0.06872619047619047']
# ['At iteration 26 the best fitness is 0.06872619047619047']
# ['At iteration 27 the best fitness is 0.06329761904761907']
# ['At iteration 28 the best fitness is 0.06872619047619047']
# ['At iteration 29 the best fitness is 0.06872619047619047']
#       Selected: 91/168 (54.2%), Fitness: 0.0687, Time: 323.4s
#     L2 Test Acc: 76.92%, F1: 74.27%, Features: 91/446 (20.4%)
#
#   --- Layer 2: META_GA ---
#     Running EvoloPy GA (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.06002380952380956
# At iteration 2 the best fitness is 0.05370238095238092
# At iteration 3 the best fitness is 0.05221428571428568
# At iteration 4 the best fitness is 0.06396428571428571
# At iteration 5 the best fitness is 0.05429761904761901
# At iteration 6 the best fitness is 0.05942857142857146
# At iteration 7 the best fitness is 0.05942857142857146
# At iteration 8 the best fitness is 0.05251190476190473
# At iteration 9 the best fitness is 0.05519047619047616
# At iteration 10 the best fitness is 0.05280952380952378
# At iteration 11 the best fitness is 0.0560833333333333
# At iteration 12 the best fitness is 0.053999999999999965
# At iteration 13 the best fitness is 0.053999999999999965
# At iteration 14 the best fitness is 0.05370238095238092
# At iteration 15 the best fitness is 0.059130952380952416
# At iteration 16 the best fitness is 0.056976190476190444
# At iteration 17 the best fitness is 0.059357142857142824
# At iteration 18 the best fitness is 0.0560833333333333
# At iteration 19 the best fitness is 0.055488095238095204
# At iteration 20 the best fitness is 0.055488095238095204
# At iteration 21 the best fitness is 0.05823809523809527
# At iteration 22 the best fitness is 0.05823809523809527
# At iteration 23 the best fitness is 0.05429761904761901
# At iteration 24 the best fitness is 0.05459523809523806
# At iteration 25 the best fitness is 0.05459523809523806
# At iteration 26 the best fitness is 0.047380952380952385
# At iteration 27 the best fitness is 0.05459523809523806
# At iteration 28 the best fitness is 0.05221428571428568
# At iteration 29 the best fitness is 0.05459523809523806
# At iteration 30 the best fitness is 0.05519047619047616
#       Selected: 83/168 (49.4%), Fitness: 0.0552, Time: 323.0s
#     L2 Test Acc: 94.41%, F1: 93.88%, Features: 83/446 (18.6%)
#
#   --- Layer 2: META_GWO ---
#     Running EvoloPy GWO (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06961904761904761']
# ['At iteration 1 the best fitness is 0.06872619047619047']
# ['At iteration 2 the best fitness is 0.06872619047619047']
# ['At iteration 3 the best fitness is 0.06872619047619047']
# ['At iteration 4 the best fitness is 0.06545238095238094']
# ['At iteration 5 the best fitness is 0.06545238095238094']
# ['At iteration 6 the best fitness is 0.0609166666666667']
# ['At iteration 7 the best fitness is 0.0609166666666667']
# ['At iteration 8 the best fitness is 0.0609166666666667']
# ['At iteration 9 the best fitness is 0.0609166666666667']
# ['At iteration 10 the best fitness is 0.0609166666666667']
# ['At iteration 11 the best fitness is 0.056750000000000037']
# ['At iteration 12 the best fitness is 0.056750000000000037']
# ['At iteration 13 the best fitness is 0.056750000000000037']
# ['At iteration 14 the best fitness is 0.056750000000000037']
# ['At iteration 15 the best fitness is 0.056750000000000037']
# ['At iteration 16 the best fitness is 0.056750000000000037']
# ['At iteration 17 the best fitness is 0.056750000000000037']
# ['At iteration 18 the best fitness is 0.056750000000000037']
# ['At iteration 19 the best fitness is 0.056750000000000037']
# ['At iteration 20 the best fitness is 0.056750000000000037']
# ['At iteration 21 the best fitness is 0.056750000000000037']
# ['At iteration 22 the best fitness is 0.056750000000000037']
# ['At iteration 23 the best fitness is 0.056750000000000037']
# ['At iteration 24 the best fitness is 0.056750000000000037']
# ['At iteration 25 the best fitness is 0.056750000000000037']
# ['At iteration 26 the best fitness is 0.056750000000000037']
# ['At iteration 27 the best fitness is 0.056750000000000037']
# ['At iteration 28 the best fitness is 0.056750000000000037']
# ['At iteration 29 the best fitness is 0.056750000000000037']
#       Selected: 68/168 (40.5%), Fitness: 0.0568, Time: 323.7s
#     L2 Test Acc: 88.46%, F1: 87.33%, Features: 68/446 (15.2%)
#
#   --- Layer 2: META_HHO ---
#     Running EvoloPy HHO (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.07385714285714282']
# ['At iteration 1 the best fitness is 0.0566785714285714']
# ['At iteration 2 the best fitness is 0.0566785714285714']
# ['At iteration 3 the best fitness is 0.0566785714285714']
# ['At iteration 4 the best fitness is 0.0566785714285714']
# ['At iteration 5 the best fitness is 0.0566785714285714']
# ['At iteration 6 the best fitness is 0.0566785714285714']
# ['At iteration 7 the best fitness is 0.0566785714285714']
# ['At iteration 8 the best fitness is 0.0566785714285714']
# ['At iteration 9 the best fitness is 0.0566785714285714']
# ['At iteration 10 the best fitness is 0.0566785714285714']
# ['At iteration 11 the best fitness is 0.0566785714285714']
# ['At iteration 12 the best fitness is 0.0566785714285714']
# ['At iteration 13 the best fitness is 0.0566785714285714']
# ['At iteration 14 the best fitness is 0.0566785714285714']
# ['At iteration 15 the best fitness is 0.0566785714285714']
# ['At iteration 16 the best fitness is 0.0566785714285714']
# ['At iteration 17 the best fitness is 0.0566785714285714']
# ['At iteration 18 the best fitness is 0.04894047619047616']
# ['At iteration 19 the best fitness is 0.04894047619047616']
# ['At iteration 20 the best fitness is 0.04894047619047616']
# ['At iteration 21 the best fitness is 0.04894047619047616']
# ['At iteration 22 the best fitness is 0.04894047619047616']
# ['At iteration 23 the best fitness is 0.04894047619047616']
# ['At iteration 24 the best fitness is 0.04894047619047616']
# ['At iteration 25 the best fitness is 0.04894047619047616']
# ['At iteration 26 the best fitness is 0.04894047619047616']
# ['At iteration 27 the best fitness is 0.04894047619047616']
# ['At iteration 28 the best fitness is 0.04894047619047616']
# ['At iteration 29 the best fitness is 0.04894047619047616']
#       Selected: 53/168 (31.5%), Fitness: 0.0489, Time: 435.1s
#     L2 Test Acc: 88.81%, F1: 88.30%, Features: 53/446 (11.9%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.062404761904761935']
# ['At iteration 1 the best fitness is 0.062404761904761935']
# ['At iteration 2 the best fitness is 0.06210714285714289']
# ['At iteration 3 the best fitness is 0.0609166666666667']
# ['At iteration 4 the best fitness is 0.057869047619047584']
# ['At iteration 5 the best fitness is 0.057869047619047584']
# ['At iteration 6 the best fitness is 0.05757142857142854']
# ['At iteration 7 the best fitness is 0.05757142857142854']
# ['At iteration 8 the best fitness is 0.05757142857142854']
# ['At iteration 9 the best fitness is 0.05757142857142854']
# ['At iteration 10 the best fitness is 0.05757142857142854']
# ['At iteration 11 the best fitness is 0.05757142857142854']
# ['At iteration 12 the best fitness is 0.05757142857142854']
# ['At iteration 13 the best fitness is 0.05757142857142854']
# ['At iteration 14 the best fitness is 0.05727380952380949']
# ['At iteration 15 the best fitness is 0.05727380952380949']
# ['At iteration 16 the best fitness is 0.055488095238095204']
# ['At iteration 17 the best fitness is 0.055488095238095204']
# ['At iteration 18 the best fitness is 0.055488095238095204']
# ['At iteration 19 the best fitness is 0.055488095238095204']
# ['At iteration 20 the best fitness is 0.055488095238095204']
# ['At iteration 21 the best fitness is 0.055488095238095204']
# ['At iteration 22 the best fitness is 0.055488095238095204']
# ['At iteration 23 the best fitness is 0.055488095238095204']
# ['At iteration 24 the best fitness is 0.055488095238095204']
# ['At iteration 25 the best fitness is 0.055488095238095204']
# ['At iteration 26 the best fitness is 0.055488095238095204']
# ['At iteration 27 the best fitness is 0.055488095238095204']
# ['At iteration 28 the best fitness is 0.055488095238095204']
# ['At iteration 29 the best fitness is 0.055488095238095204']
#       Selected: 75/168 (44.6%), Fitness: 0.0555, Time: 334.5s
#     L2 Test Acc: 91.61%, F1: 90.89%, Features: 75/446 (16.8%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06872619047619047']
# ['At iteration 2 the best fitness is 0.06329761904761907']
# ['At iteration 3 the best fitness is 0.06329761904761907']
# ['At iteration 4 the best fitness is 0.06329761904761907']
# ['At iteration 5 the best fitness is 0.06329761904761907']
# ['At iteration 6 the best fitness is 0.06329761904761907']
# ['At iteration 7 the best fitness is 0.06329761904761907']
# ['At iteration 8 the best fitness is 0.06329761904761907']
# ['At iteration 9 the best fitness is 0.06329761904761907']
# ['At iteration 10 the best fitness is 0.062404761904761935']
# ['At iteration 11 the best fitness is 0.062404761904761935']
# ['At iteration 12 the best fitness is 0.05965476190476187']
# ['At iteration 13 the best fitness is 0.05965476190476187']
# ['At iteration 14 the best fitness is 0.05757142857142854']
# ['At iteration 15 the best fitness is 0.05727380952380949']
# ['At iteration 16 the best fitness is 0.05727380952380949']
# ['At iteration 17 the best fitness is 0.05727380952380949']
# ['At iteration 18 the best fitness is 0.056976190476190444']
# ['At iteration 19 the best fitness is 0.056976190476190444']
# ['At iteration 20 the best fitness is 0.056976190476190444']
# ['At iteration 21 the best fitness is 0.056976190476190444']
# ['At iteration 22 the best fitness is 0.0560833333333333']
# ['At iteration 23 the best fitness is 0.0560833333333333']
# ['At iteration 24 the best fitness is 0.0560833333333333']
# ['At iteration 25 the best fitness is 0.0560833333333333']
# ['At iteration 26 the best fitness is 0.0560833333333333']
# ['At iteration 27 the best fitness is 0.0560833333333333']
# ['At iteration 28 the best fitness is 0.0560833333333333']
# ['At iteration 29 the best fitness is 0.05578571428571425']
#       Selected: 77/168 (45.8%), Fitness: 0.0558, Time: 313.7s
#     L2 Test Acc: 89.16%, F1: 88.17%, Features: 77/446 (17.3%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06210714285714289']
# ['At iteration 2 the best fitness is 0.0566785714285714']
# ['At iteration 3 the best fitness is 0.0566785714285714']
# ['At iteration 4 the best fitness is 0.0566785714285714']
# ['At iteration 5 the best fitness is 0.0566785714285714']
# ['At iteration 6 the best fitness is 0.0566785714285714']
# ['At iteration 7 the best fitness is 0.0566785714285714']
# ['At iteration 8 the best fitness is 0.0566785714285714']
# ['At iteration 9 the best fitness is 0.0566785714285714']
# ['At iteration 10 the best fitness is 0.0566785714285714']
# ['At iteration 11 the best fitness is 0.0566785714285714']
# ['At iteration 12 the best fitness is 0.0566785714285714']
# ['At iteration 13 the best fitness is 0.0566785714285714']
# ['At iteration 14 the best fitness is 0.056380952380952344']
# ['At iteration 15 the best fitness is 0.05578571428571425']
# ['At iteration 16 the best fitness is 0.05578571428571425']
# ['At iteration 17 the best fitness is 0.05578571428571425']
# ['At iteration 18 the best fitness is 0.05578571428571425']
# ['At iteration 19 the best fitness is 0.05578571428571425']
# ['At iteration 20 the best fitness is 0.05578571428571425']
# ['At iteration 21 the best fitness is 0.05578571428571425']
# ['At iteration 22 the best fitness is 0.05578571428571425']
# ['At iteration 23 the best fitness is 0.055488095238095204']
# ['At iteration 24 the best fitness is 0.055488095238095204']
# ['At iteration 25 the best fitness is 0.055488095238095204']
# ['At iteration 26 the best fitness is 0.05519047619047616']
# ['At iteration 27 the best fitness is 0.05519047619047616']
# ['At iteration 28 the best fitness is 0.05519047619047616']
# ['At iteration 29 the best fitness is 0.05519047619047616']
# ['At iteration 30 the best fitness is 0.05519047619047616']
#       Selected: 86/168 (51.2%), Fitness: 0.0552, Time: 324.1s
#     L2 Test Acc: 90.91%, F1: 89.97%, Features: 86/446 (19.3%)
#
#   --- Layer 2: META_PSO ---
#     Running EvoloPy PSO (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06902380952380952']
# ['At iteration 2 the best fitness is 0.06723809523809524']
# ['At iteration 3 the best fitness is 0.06723809523809524']
# ['At iteration 4 the best fitness is 0.06723809523809524']
# ['At iteration 5 the best fitness is 0.0663452380952381']
# ['At iteration 6 the best fitness is 0.0663452380952381']
# ['At iteration 7 the best fitness is 0.06545238095238094']
# ['At iteration 8 the best fitness is 0.06545238095238094']
# ['At iteration 9 the best fitness is 0.0609166666666667']
# ['At iteration 10 the best fitness is 0.0609166666666667']
# ['At iteration 11 the best fitness is 0.058535714285714316']
# ['At iteration 12 the best fitness is 0.058535714285714316']
# ['At iteration 13 the best fitness is 0.058535714285714316']
# ['At iteration 14 the best fitness is 0.058535714285714316']
# ['At iteration 15 the best fitness is 0.058535714285714316']
# ['At iteration 16 the best fitness is 0.058535714285714316']
# ['At iteration 17 the best fitness is 0.058535714285714316']
# ['At iteration 18 the best fitness is 0.058535714285714316']
# ['At iteration 19 the best fitness is 0.058535714285714316']
# ['At iteration 20 the best fitness is 0.05429761904761901']
# ['At iteration 21 the best fitness is 0.05429761904761901']
# ['At iteration 22 the best fitness is 0.05429761904761901']
# ['At iteration 23 the best fitness is 0.05429761904761901']
# ['At iteration 24 the best fitness is 0.05370238095238092']
# ['At iteration 25 the best fitness is 0.05370238095238092']
# ['At iteration 26 the best fitness is 0.05370238095238092']
# ['At iteration 27 the best fitness is 0.05340476190476187']
# ['At iteration 28 the best fitness is 0.05340476190476187']
# ['At iteration 29 the best fitness is 0.05340476190476187']
# ['At iteration 30 the best fitness is 0.05340476190476187']
#       Selected: 76/168 (45.2%), Fitness: 0.0534, Time: 323.9s
#     L2 Test Acc: 89.86%, F1: 87.74%, Features: 76/446 (17.0%)
#
#   --- Layer 2: META_SCA ---
#     Running EvoloPy SCA (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06121428571428575']
# ['At iteration 1 the best fitness is 0.06121428571428575']
# ['At iteration 2 the best fitness is 0.06121428571428575']
# ['At iteration 3 the best fitness is 0.06121428571428575']
# ['At iteration 4 the best fitness is 0.06121428571428575']
# ['At iteration 5 the best fitness is 0.06121428571428575']
# ['At iteration 6 the best fitness is 0.06121428571428575']
# ['At iteration 7 the best fitness is 0.06121428571428575']
# ['At iteration 8 the best fitness is 0.06121428571428575']
# ['At iteration 9 the best fitness is 0.05883333333333337']
# ['At iteration 10 the best fitness is 0.05883333333333337']
# ['At iteration 11 the best fitness is 0.05883333333333337']
# ['At iteration 12 the best fitness is 0.05883333333333337']
# ['At iteration 13 the best fitness is 0.05883333333333337']
# ['At iteration 14 the best fitness is 0.05883333333333337']
# ['At iteration 15 the best fitness is 0.05347619047619051']
# ['At iteration 16 the best fitness is 0.05347619047619051']
# ['At iteration 17 the best fitness is 0.05347619047619051']
# ['At iteration 18 the best fitness is 0.05228571428571432']
# ['At iteration 19 the best fitness is 0.05228571428571432']
# ['At iteration 20 the best fitness is 0.05228571428571432']
# ['At iteration 21 the best fitness is 0.05228571428571432']
# ['At iteration 22 the best fitness is 0.05228571428571432']
# ['At iteration 23 the best fitness is 0.05228571428571432']
# ['At iteration 24 the best fitness is 0.05228571428571432']
# ['At iteration 25 the best fitness is 0.05228571428571432']
# ['At iteration 26 the best fitness is 0.05228571428571432']
# ['At iteration 27 the best fitness is 0.05228571428571432']
# ['At iteration 28 the best fitness is 0.05228571428571432']
# ['At iteration 29 the best fitness is 0.04834523809523806']
#       Selected: 57/168 (33.9%), Fitness: 0.0483, Time: 322.6s
#     L2 Test Acc: 88.11%, F1: 85.21%, Features: 57/446 (12.8%)
#
#   --- Layer 2: META_SSA ---
#     Running EvoloPy SSA (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06419047619047623']
# ['At iteration 2 the best fitness is 0.056976190476190444']
# ['At iteration 3 the best fitness is 0.056976190476190444']
# ['At iteration 4 the best fitness is 0.056976190476190444']
# ['At iteration 5 the best fitness is 0.056976190476190444']
# ['At iteration 6 the best fitness is 0.056976190476190444']
# ['At iteration 7 the best fitness is 0.056976190476190444']
# ['At iteration 8 the best fitness is 0.056976190476190444']
# ['At iteration 9 the best fitness is 0.056976190476190444']
# ['At iteration 10 the best fitness is 0.056976190476190444']
# ['At iteration 11 the best fitness is 0.056976190476190444']
# ['At iteration 12 the best fitness is 0.056976190476190444']
# ['At iteration 13 the best fitness is 0.056976190476190444']
# ['At iteration 14 the best fitness is 0.056380952380952344']
# ['At iteration 15 the best fitness is 0.056380952380952344']
# ['At iteration 16 the best fitness is 0.056380952380952344']
# ['At iteration 17 the best fitness is 0.056380952380952344']
# ['At iteration 18 the best fitness is 0.056380952380952344']
# ['At iteration 19 the best fitness is 0.056380952380952344']
# ['At iteration 20 the best fitness is 0.056380952380952344']
# ['At iteration 21 the best fitness is 0.056380952380952344']
# ['At iteration 22 the best fitness is 0.056380952380952344']
# ['At iteration 23 the best fitness is 0.056380952380952344']
# ['At iteration 24 the best fitness is 0.056380952380952344']
# ['At iteration 25 the best fitness is 0.056380952380952344']
# ['At iteration 26 the best fitness is 0.056380952380952344']
# ['At iteration 27 the best fitness is 0.056380952380952344']
# ['At iteration 28 the best fitness is 0.056380952380952344']
# ['At iteration 29 the best fitness is 0.056380952380952344']
#       Selected: 74/168 (44.0%), Fitness: 0.0564, Time: 809.3s
#     L2 Test Acc: 90.91%, F1: 90.18%, Features: 74/446 (16.6%)
#
#   --- Layer 2: META_WOA ---
#     Running EvoloPy WOA (Layer 2)...
#       Features: 168, Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0665714285714286']
# ['At iteration 1 the best fitness is 0.0665714285714286']
# ['At iteration 2 the best fitness is 0.0665714285714286']
# ['At iteration 3 the best fitness is 0.06263095238095234']
# ['At iteration 4 the best fitness is 0.06263095238095234']
# ['At iteration 5 the best fitness is 0.06263095238095234']
# ['At iteration 6 the best fitness is 0.06263095238095234']
# ['At iteration 7 the best fitness is 0.06263095238095234']
# ['At iteration 8 the best fitness is 0.06121428571428575']
# ['At iteration 9 the best fitness is 0.060619047619047656']
# ['At iteration 10 the best fitness is 0.060619047619047656']
# ['At iteration 11 the best fitness is 0.06002380952380956']
# ['At iteration 12 the best fitness is 0.06002380952380956']
# ['At iteration 13 the best fitness is 0.058535714285714316']
# ['At iteration 14 the best fitness is 0.058535714285714316']
# ['At iteration 15 the best fitness is 0.058535714285714316']
# ['At iteration 16 the best fitness is 0.058535714285714316']
# ['At iteration 17 the best fitness is 0.058535714285714316']
# ['At iteration 18 the best fitness is 0.058535714285714316']
# ['At iteration 19 the best fitness is 0.058535714285714316']
# ['At iteration 20 the best fitness is 0.058535714285714316']
# ['At iteration 21 the best fitness is 0.05794047619047622']
# ['At iteration 22 the best fitness is 0.05794047619047622']
# ['At iteration 23 the best fitness is 0.05794047619047622']
# ['At iteration 24 the best fitness is 0.05794047619047622']
# ['At iteration 25 the best fitness is 0.05794047619047622']
# ['At iteration 26 the best fitness is 0.05794047619047622']
# ['At iteration 27 the best fitness is 0.05794047619047622']
# ['At iteration 28 the best fitness is 0.05794047619047622']
# ['At iteration 29 the best fitness is 0.05794047619047622']
#       Selected: 71/168 (42.3%), Fitness: 0.0579, Time: 311.9s
#     L2 Test Acc: 95.80%, F1: 95.62%, Features: 71/446 (15.9%)
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#
#   --- Layer 2: MUTUAL_INFO ---
#     L1 combined features: 222/446
#     Running Mutual Information (Layer 2)...
#       Selected: 111/222 (50.0%), Time: 1.1s
#     L2 Test Acc: 85.06%, F1: 85.22%, Features: 111/446 (24.9%)
#
#   --- Layer 2: RFE ---
#     L1 combined features: 222/446
#     Running RFE (Layer 2)...
#       Selected: 111/222 (50.0%), Time: 0.5s
#     L2 Test Acc: 91.29%, F1: 91.71%, Features: 111/446 (24.9%)
#
#   --- Layer 2: LASSO ---
#     L1 combined features: 222/446
#     Running LASSO (Layer 2)...
#       Selected: 111/222 (50.0%), Time: 0.0s
#     L2 Test Acc: 85.89%, F1: 85.77%, Features: 111/446 (24.9%)
#
#   --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---
#     L1 combined best-meta features: 211/446
#       depth: meta_MVO (acc=27.8%)
#       sensor: meta_GA (acc=35.7%)
#       skeleton: meta_MFO (acc=90.9%)
#
#   --- Layer 2: META_BAT ---
#     Running EvoloPy BAT (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024170616113744076']
# ['At iteration 1 the best fitness is 0.023696682464454978']
# ['At iteration 2 the best fitness is 0.02180094786729858']
# ['At iteration 3 the best fitness is 0.02180094786729858']
# ['At iteration 4 the best fitness is 0.02180094786729858']
# ['At iteration 5 the best fitness is 0.02180094786729858']
# ['At iteration 6 the best fitness is 0.02180094786729858']
# ['At iteration 7 the best fitness is 0.02156398104265403']
# ['At iteration 8 the best fitness is 0.02156398104265403']
# ['At iteration 9 the best fitness is 0.02156398104265403']
# ['At iteration 10 the best fitness is 0.02156398104265403']
# ['At iteration 11 the best fitness is 0.02156398104265403']
# ['At iteration 12 the best fitness is 0.02156398104265403']
# ['At iteration 13 the best fitness is 0.02156398104265403']
# ['At iteration 14 the best fitness is 0.02156398104265403']
# ['At iteration 15 the best fitness is 0.02156398104265403']
# ['At iteration 16 the best fitness is 0.02156398104265403']
# ['At iteration 17 the best fitness is 0.02156398104265403']
# ['At iteration 18 the best fitness is 0.02156398104265403']
# ['At iteration 19 the best fitness is 0.02156398104265403']
# ['At iteration 20 the best fitness is 0.02156398104265403']
# ['At iteration 21 the best fitness is 0.02156398104265403']
# ['At iteration 22 the best fitness is 0.02156398104265403']
# ['At iteration 23 the best fitness is 0.02156398104265403']
# ['At iteration 24 the best fitness is 0.02156398104265403']
# ['At iteration 25 the best fitness is 0.02156398104265403']
# ['At iteration 26 the best fitness is 0.02156398104265403']
# ['At iteration 27 the best fitness is 0.02156398104265403']
# ['At iteration 28 the best fitness is 0.02156398104265403']
# ['At iteration 29 the best fitness is 0.02156398104265403']
#       Selected: 91/211 (43.1%), Fitness: 0.0216, Time: 359.6s
#     L2 Test Acc: 87.14%, F1: 87.21%, Features: 91/446 (20.4%)
#
#   --- Layer 2: META_CS ---
#     Running EvoloPy CS (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02345971563981043']
# ['At iteration 10 the best fitness is 0.022748815165876776']
# ['At iteration 20 the best fitness is 0.022748815165876776']
#       Selected: 93/211 (44.1%), Fitness: 0.0227, Time: 712.5s
#     L2 Test Acc: 87.55%, F1: 87.51%, Features: 93/446 (20.9%)
#
#   --- Layer 2: META_DE ---
#     Running EvoloPy DE (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.025118483412322274']
# ['At iteration 2 the best fitness is 0.02345971563981043']
# ['At iteration 3 the best fitness is 0.02298578199052133']
# ['At iteration 4 the best fitness is 0.02298578199052133']
# ['At iteration 5 the best fitness is 0.02298578199052133']
# ['At iteration 6 the best fitness is 0.02298578199052133']
# ['At iteration 7 the best fitness is 0.02298578199052133']
# ['At iteration 8 the best fitness is 0.02298578199052133']
# ['At iteration 9 the best fitness is 0.02298578199052133']
# ['At iteration 10 the best fitness is 0.02298578199052133']
# ['At iteration 11 the best fitness is 0.02227488151658768']
# ['At iteration 12 the best fitness is 0.02227488151658768']
# ['At iteration 13 the best fitness is 0.02227488151658768']
# ['At iteration 14 the best fitness is 0.02156398104265403']
# ['At iteration 15 the best fitness is 0.02156398104265403']
# ['At iteration 16 the best fitness is 0.02156398104265403']
# ['At iteration 17 the best fitness is 0.02132701421800948']
# ['At iteration 18 the best fitness is 0.02132701421800948']
# ['At iteration 19 the best fitness is 0.02132701421800948']
# ['At iteration 20 the best fitness is 0.02132701421800948']
# ['At iteration 21 the best fitness is 0.02132701421800948']
# ['At iteration 22 the best fitness is 0.02132701421800948']
# ['At iteration 23 the best fitness is 0.02132701421800948']
# ['At iteration 24 the best fitness is 0.02132701421800948']
# ['At iteration 25 the best fitness is 0.02132701421800948']
# ['At iteration 26 the best fitness is 0.02132701421800948']
# ['At iteration 27 the best fitness is 0.02132701421800948']
# ['At iteration 28 the best fitness is 0.02132701421800948']
# ['At iteration 29 the best fitness is 0.02132701421800948']
# ['At iteration 30 the best fitness is 0.02132701421800948']
#       Selected: 90/211 (42.7%), Fitness: 0.0213, Time: 362.8s
#     L2 Test Acc: 83.40%, F1: 82.49%, Features: 90/446 (20.2%)
#
#   --- Layer 2: META_FFA ---
#     Running EvoloPy FFA (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024170616113744076']
# ['At iteration 1 the best fitness is 0.024170616113744076']
# ['At iteration 2 the best fitness is 0.02180094786729858']
# ['At iteration 3 the best fitness is 0.025592417061611375']
# ['At iteration 4 the best fitness is 0.02061611374407583']
# ['At iteration 5 the best fitness is 0.020379146919431282']
# ['At iteration 6 the best fitness is 0.020379146919431282']
# ['At iteration 7 the best fitness is 0.022511848341232227']
# ['At iteration 8 the best fitness is 0.02061611374407583']
# ['At iteration 9 the best fitness is 0.02014218009478673']
# ['At iteration 10 the best fitness is 0.02014218009478673']
# ['At iteration 11 the best fitness is 0.020379146919431282']
# ['At iteration 12 the best fitness is 0.020379146919431282']
# ['At iteration 13 the best fitness is 0.020379146919431282']
# ['At iteration 14 the best fitness is 0.02014218009478673']
# ['At iteration 15 the best fitness is 0.02014218009478673']
# ['At iteration 16 the best fitness is 0.02014218009478673']
# ['At iteration 17 the best fitness is 0.02014218009478673']
# ['At iteration 18 the best fitness is 0.020379146919431282']
# ['At iteration 19 the best fitness is 0.020379146919431282']
# ['At iteration 20 the best fitness is 0.020379146919431282']
# ['At iteration 21 the best fitness is 0.020379146919431282']
# ['At iteration 22 the best fitness is 0.020379146919431282']
# ['At iteration 23 the best fitness is 0.020379146919431282']
# ['At iteration 24 the best fitness is 0.020379146919431282']
# ['At iteration 25 the best fitness is 0.020379146919431282']
# ['At iteration 26 the best fitness is 0.020379146919431282']
# ['At iteration 27 the best fitness is 0.020379146919431282']
# ['At iteration 28 the best fitness is 0.020379146919431282']
# ['At iteration 29 the best fitness is 0.020379146919431282']
#       Selected: 103/211 (48.8%), Fitness: 0.0204, Time: 349.4s
#     L2 Test Acc: 89.63%, F1: 89.69%, Features: 103/446 (23.1%)
#
#   --- Layer 2: META_GA ---
#     Running EvoloPy GA (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.02885972594271587
# At iteration 2 the best fitness is 0.026303317535545025
# At iteration 3 the best fitness is 0.023933649289099527
# At iteration 4 the best fitness is 0.024407582938388628
# At iteration 5 the best fitness is 0.024407582938388628
# At iteration 6 the best fitness is 0.023696682464454978
# At iteration 7 the best fitness is 0.022511848341232227
# At iteration 8 the best fitness is 0.022511848341232227
# At iteration 9 the best fitness is 0.02345971563981043
# At iteration 10 the best fitness is 0.02227488151658768
# At iteration 11 the best fitness is 0.02345971563981043
# At iteration 12 the best fitness is 0.02345971563981043
# At iteration 13 the best fitness is 0.02298578199052133
# At iteration 14 the best fitness is 0.022748815165876776
# At iteration 15 the best fitness is 0.022748815165876776
# At iteration 16 the best fitness is 0.023933649289099527
# At iteration 17 the best fitness is 0.024407582938388628
# At iteration 18 the best fitness is 0.02322274881516588
# At iteration 19 the best fitness is 0.022511848341232227
# At iteration 20 the best fitness is 0.02298578199052133
# At iteration 21 the best fitness is 0.02298578199052133
# At iteration 22 the best fitness is 0.022748815165876776
# At iteration 23 the best fitness is 0.022748815165876776
# At iteration 24 the best fitness is 0.022748815165876776
# At iteration 25 the best fitness is 0.022511848341232227
# At iteration 26 the best fitness is 0.022511848341232227
# At iteration 27 the best fitness is 0.022511848341232227
# At iteration 28 the best fitness is 0.02203791469194313
# At iteration 29 the best fitness is 0.02203791469194313
# At iteration 30 the best fitness is 0.02180094786729858
#       Selected: 92/211 (43.6%), Fitness: 0.0218, Time: 350.6s
#     L2 Test Acc: 90.87%, F1: 91.07%, Features: 92/446 (20.6%)
#
#   --- Layer 2: META_GWO ---
#     Running EvoloPy GWO (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024170616113744076']
# ['At iteration 1 the best fitness is 0.023696682464454978']
# ['At iteration 2 the best fitness is 0.023696682464454978']
# ['At iteration 3 the best fitness is 0.02298578199052133']
# ['At iteration 4 the best fitness is 0.02298578199052133']
# ['At iteration 5 the best fitness is 0.02085308056872038']
# ['At iteration 6 the best fitness is 0.01990521327014218']
# ['At iteration 7 the best fitness is 0.01848341232227488']
# ['At iteration 8 the best fitness is 0.017298578199052134']
# ['At iteration 9 the best fitness is 0.017298578199052134']
# ['At iteration 10 the best fitness is 0.017298578199052134']
# ['At iteration 11 the best fitness is 0.017298578199052134']
# ['At iteration 12 the best fitness is 0.016587677725118485']
# ['At iteration 13 the best fitness is 0.016350710900473932']
# ['At iteration 14 the best fitness is 0.016350710900473932']
# ['At iteration 15 the best fitness is 0.016350710900473932']
# ['At iteration 16 the best fitness is 0.016350710900473932']
# ['At iteration 17 the best fitness is 0.016350710900473932']
# ['At iteration 18 the best fitness is 0.016350710900473932']
# ['At iteration 19 the best fitness is 0.016350710900473932']
# ['At iteration 20 the best fitness is 0.016350710900473932']
# ['At iteration 21 the best fitness is 0.016350710900473932']
# ['At iteration 22 the best fitness is 0.016350710900473932']
# ['At iteration 23 the best fitness is 0.016350710900473932']
# ['At iteration 24 the best fitness is 0.016350710900473932']
# ['At iteration 25 the best fitness is 0.016350710900473932']
# ['At iteration 26 the best fitness is 0.016350710900473932']
# ['At iteration 27 the best fitness is 0.016350710900473932']
# ['At iteration 28 the best fitness is 0.016350710900473932']
# ['At iteration 29 the best fitness is 0.016350710900473932']
#       Selected: 73/211 (34.6%), Fitness: 0.0164, Time: 349.3s
#     L2 Test Acc: 89.63%, F1: 90.01%, Features: 73/446 (16.4%)
#
#   --- Layer 2: META_HHO ---
#     Running EvoloPy HHO (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.026303317535545025']
# ['At iteration 1 the best fitness is 0.022748815165876776']
# ['At iteration 2 the best fitness is 0.022748815165876776']
# ['At iteration 3 the best fitness is 0.022748815165876776']
# ['At iteration 4 the best fitness is 0.022748815165876776']
# ['At iteration 5 the best fitness is 0.022748815165876776']
# ['At iteration 6 the best fitness is 0.022748815165876776']
# ['At iteration 7 the best fitness is 0.022748815165876776']
# ['At iteration 8 the best fitness is 0.022748815165876776']
# ['At iteration 9 the best fitness is 0.020379146919431282']
# ['At iteration 10 the best fitness is 0.020379146919431282']
# ['At iteration 11 the best fitness is 0.020379146919431282']
# ['At iteration 12 the best fitness is 0.020379146919431282']
# ['At iteration 13 the best fitness is 0.020379146919431282']
# ['At iteration 14 the best fitness is 0.020379146919431282']
# ['At iteration 15 the best fitness is 0.020379146919431282']
# ['At iteration 16 the best fitness is 0.020379146919431282']
# ['At iteration 17 the best fitness is 0.020379146919431282']
# ['At iteration 18 the best fitness is 0.020379146919431282']
# ['At iteration 19 the best fitness is 0.020379146919431282']
# ['At iteration 20 the best fitness is 0.020379146919431282']
# ['At iteration 21 the best fitness is 0.020379146919431282']
# ['At iteration 22 the best fitness is 0.020379146919431282']
# ['At iteration 23 the best fitness is 0.020379146919431282']
# ['At iteration 24 the best fitness is 0.020379146919431282']
# ['At iteration 25 the best fitness is 0.020379146919431282']
# ['At iteration 26 the best fitness is 0.020379146919431282']
# ['At iteration 27 the best fitness is 0.020379146919431282']
# ['At iteration 28 the best fitness is 0.020379146919431282']
# ['At iteration 29 the best fitness is 0.020379146919431282']
#       Selected: 84/211 (39.8%), Fitness: 0.0204, Time: 441.8s
#     L2 Test Acc: 88.80%, F1: 89.24%, Features: 84/446 (18.8%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02180094786729858']
# ['At iteration 1 the best fitness is 0.02180094786729858']
# ['At iteration 2 the best fitness is 0.02180094786729858']
# ['At iteration 3 the best fitness is 0.02180094786729858']
# ['At iteration 4 the best fitness is 0.02085308056872038']
# ['At iteration 5 the best fitness is 0.02085308056872038']
# ['At iteration 6 the best fitness is 0.01990521327014218']
# ['At iteration 7 the best fitness is 0.01990521327014218']
# ['At iteration 8 the best fitness is 0.01990521327014218']
# ['At iteration 9 the best fitness is 0.01990521327014218']
# ['At iteration 10 the best fitness is 0.01990521327014218']
# ['At iteration 11 the best fitness is 0.01990521327014218']
# ['At iteration 12 the best fitness is 0.01990521327014218']
# ['At iteration 13 the best fitness is 0.01990521327014218']
# ['At iteration 14 the best fitness is 0.01990521327014218']
# ['At iteration 15 the best fitness is 0.01990521327014218']
# ['At iteration 16 the best fitness is 0.01990521327014218']
# ['At iteration 17 the best fitness is 0.01990521327014218']
# ['At iteration 18 the best fitness is 0.01990521327014218']
# ['At iteration 19 the best fitness is 0.01990521327014218']
# ['At iteration 20 the best fitness is 0.01990521327014218']
# ['At iteration 21 the best fitness is 0.01990521327014218']
# ['At iteration 22 the best fitness is 0.01990521327014218']
# ['At iteration 23 the best fitness is 0.01990521327014218']
# ['At iteration 24 the best fitness is 0.01990521327014218']
# ['At iteration 25 the best fitness is 0.01990521327014218']
# ['At iteration 26 the best fitness is 0.01990521327014218']
# ['At iteration 27 the best fitness is 0.01990521327014218']
# ['At iteration 28 the best fitness is 0.01990521327014218']
# ['At iteration 29 the best fitness is 0.01990521327014218']
#       Selected: 88/211 (41.7%), Fitness: 0.0199, Time: 361.8s
#     L2 Test Acc: 88.38%, F1: 88.52%, Features: 88/446 (19.7%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02203791469194313']
# ['At iteration 2 the best fitness is 0.02203791469194313']
# ['At iteration 3 the best fitness is 0.02203791469194313']
# ['At iteration 4 the best fitness is 0.02203791469194313']
# ['At iteration 5 the best fitness is 0.02203791469194313']
# ['At iteration 6 the best fitness is 0.02203791469194313']
# ['At iteration 7 the best fitness is 0.02203791469194313']
# ['At iteration 8 the best fitness is 0.02203791469194313']
# ['At iteration 9 the best fitness is 0.02180094786729858']
# ['At iteration 10 the best fitness is 0.02180094786729858']
# ['At iteration 11 the best fitness is 0.02180094786729858']
# ['At iteration 12 the best fitness is 0.02180094786729858']
# ['At iteration 13 the best fitness is 0.02180094786729858']
# ['At iteration 14 the best fitness is 0.02180094786729858']
# ['At iteration 15 the best fitness is 0.02180094786729858']
# ['At iteration 16 the best fitness is 0.02180094786729858']
# ['At iteration 17 the best fitness is 0.02156398104265403']
# ['At iteration 18 the best fitness is 0.02156398104265403']
# ['At iteration 19 the best fitness is 0.02156398104265403']
# ['At iteration 20 the best fitness is 0.02156398104265403']
# ['At iteration 21 the best fitness is 0.02156398104265403']
# ['At iteration 22 the best fitness is 0.02132701421800948']
# ['At iteration 23 the best fitness is 0.02132701421800948']
# ['At iteration 24 the best fitness is 0.02132701421800948']
# ['At iteration 25 the best fitness is 0.02132701421800948']
# ['At iteration 26 the best fitness is 0.02132701421800948']
# ['At iteration 27 the best fitness is 0.02132701421800948']
# ['At iteration 28 the best fitness is 0.02061611374407583']
# ['At iteration 29 the best fitness is 0.02061611374407583']
#       Selected: 96/211 (45.5%), Fitness: 0.0206, Time: 338.8s
#     L2 Test Acc: 91.70%, F1: 91.88%, Features: 96/446 (21.5%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 211, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024407582938388628']
# ['At iteration 2 the best fitness is 0.024170616113744076']
# ['At iteration 3 the best fitness is 0.024170616113744076']
# ['At iteration 4 the best fitness is 0.024170616113744076']
# ['At iteration 5 the best fitness is 0.024170616113744076']
# ['At iteration 6 the best fitness is 0.024170616113744076']
# ['At iteration 7 the best fitness is 0.02227488151658768']
# ['At iteration 8 the best fitness is 0.02227488151658768']
# ['At iteration 9 the best fitness is 0.02227488151658768']
# ['At iteration 10 the best fitness is 0.02227488151658768']
# ['At iteration 11 the best fitness is 0.02227488151658768']
# ['At iteration 12 the best fitness is 0.02227488151658768']
# ['At iteration 13 the best fitness is 0.02227488151658768']
# ['At iteration 14 the best fitness is 0.02227488151658768']
# ['At iteration 15 the best fitness is 0.02227488151658768']
# ['At iteration 16 the best fitness is 0.02227488151658768']
# ['At iteration 17 the best fitness is 0.02227488151658768']
# ['At iteration 18 the best fitness is 0.02227488151658768']
# ['At iteration 19 the best fitness is 0.02227488151658768']
# ['At iteration 20 the best fitness is 0.02227488151658768']
# ['At iteration 21 the best fitness is 0.02227488151658768']
# ['At iteration 22 the best fitness is 0.02227488151658768']
# ['At iteration 23 the best fitness is 0.02227488151658768']
# ['At iteration 24 the best fitness is 0.02227488151658768']
# ['At iteration 25 the best fitness is 0.02227488151658768']
# ['At iteration 26 the best fitness is 0.02227488151658768']
# ['At iteration 27 the best fitness is 0.02203791469194313']
# ['At iteration 28 the best fitness is 0.02203791469194313']
# ['At iteration 29 the best fitness is 0.02203791469194313']
# ...
# ['At iteration 8 the best fitness is 0.0391799849181445']
# ['At iteration 9 the best fitness is 0.0391799849181445']
# ['At iteration 10 the best fitness is 0.0391799849181445']
# ['At iteration 11 the best fitness is 0.0391799849181445']
# ['At iteration 12 the best fitness is 0.0391799849181445']
# ['At iteration 13 the best fitness is 0.0391799849181445']
# ['At iteration 14 the best fitness is 0.0391799849181445']
# ['At iteration 15 the best fitness is 0.0391799849181445']
# ['At iteration 16 the best fitness is 0.03730205064584403']
# ['At iteration 17 the best fitness is 0.03730205064584403']
# ['At iteration 18 the best fitness is 0.03730205064584403']
# ['At iteration 19 the best fitness is 0.032372473181055295']
# ['At iteration 20 the best fitness is 0.032372473181055295']
# ['At iteration 21 the best fitness is 0.032372473181055295']
# ['At iteration 22 the best fitness is 0.032372473181055295']
# ['At iteration 23 the best fitness is 0.032372473181055295']
# ['At iteration 24 the best fitness is 0.032372473181055295']
# ['At iteration 25 the best fitness is 0.032372473181055295']
# ['At iteration 26 the best fitness is 0.032372473181055295']
# ['At iteration 27 the best fitness is 0.032372473181055295']
# ['At iteration 28 the best fitness is 0.032372473181055295']
# ['At iteration 29 the best fitness is 0.032372473181055295']
#       Selected: 78/213 (36.6%), Fitness: 0.0324, Time: 498.5s
#     L2 Test Acc: 73.23%, F1: 71.32%, Features: 78/446 (17.5%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 213, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03824101778199426']
# ['At iteration 1 the best fitness is 0.03824101778199426']
# ['At iteration 2 the best fitness is 0.03824101778199426']
# ['At iteration 3 the best fitness is 0.03754409010192419']
# ['At iteration 4 the best fitness is 0.03754409010192419']
# ['At iteration 5 the best fitness is 0.03754409010192419']
# ['At iteration 6 the best fitness is 0.03754409010192419']
# ['At iteration 7 the best fitness is 0.03754409010192419']
# ['At iteration 8 the best fitness is 0.03754409010192419']
# ['At iteration 9 the best fitness is 0.03754409010192419']
# ['At iteration 10 the best fitness is 0.03754409010192419']
# ['At iteration 11 the best fitness is 0.03754409010192419']
# ['At iteration 12 the best fitness is 0.0351966722615486']
# ['At iteration 13 the best fitness is 0.0351966722615486']
# ['At iteration 14 the best fitness is 0.0351966722615486']
# ['At iteration 15 the best fitness is 0.0351966722615486']
# ['At iteration 16 the best fitness is 0.0351966722615486']
# ['At iteration 17 the best fitness is 0.0351966722615486']
# ['At iteration 18 the best fitness is 0.0351966722615486']
# ['At iteration 19 the best fitness is 0.0351966722615486']
# ['At iteration 20 the best fitness is 0.0351966722615486']
# ['At iteration 21 the best fitness is 0.0351966722615486']
# ['At iteration 22 the best fitness is 0.0351966722615486']
# ['At iteration 23 the best fitness is 0.0351966722615486']
# ['At iteration 24 the best fitness is 0.0351966722615486']
# ['At iteration 25 the best fitness is 0.0351966722615486']
# ['At iteration 26 the best fitness is 0.0351966722615486']
# ['At iteration 27 the best fitness is 0.0351966722615486']
# ['At iteration 28 the best fitness is 0.0351966722615486']
# ['At iteration 29 the best fitness is 0.034492446909435925']
#       Selected: 101/213 (47.4%), Fitness: 0.0345, Time: 386.8s
#     L2 Test Acc: 93.43%, F1: 93.46%, Features: 101/446 (22.6%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 213, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03824101778199426']
# ['At iteration 2 the best fitness is 0.03824101778199426']
# ['At iteration 3 the best fitness is 0.03824101778199426']
# ['At iteration 4 the best fitness is 0.03824101778199426']
# ['At iteration 5 the best fitness is 0.034257705125398365']
# ['At iteration 6 the best fitness is 0.034257705125398365']
# ['At iteration 7 the best fitness is 0.034257705125398365']
# ['At iteration 8 the best fitness is 0.034257705125398365']
# ['At iteration 9 the best fitness is 0.034257705125398365']
# ['At iteration 10 the best fitness is 0.034257705125398365']
# ['At iteration 11 the best fitness is 0.034257705125398365']
# ['At iteration 12 the best fitness is 0.034257705125398365']
# ['At iteration 13 the best fitness is 0.034257705125398365']
# ['At iteration 14 the best fitness is 0.034257705125398365']
# ['At iteration 15 the best fitness is 0.034257705125398365']
# ['At iteration 16 the best fitness is 0.033318737989248136']
# ['At iteration 17 the best fitness is 0.033318737989248136']
# ['At iteration 18 the best fitness is 0.033318737989248136']
# ['At iteration 19 the best fitness is 0.033318737989248136']
# ['At iteration 20 the best fitness is 0.033318737989248136']
# ['At iteration 21 the best fitness is 0.033318737989248136']
# ['At iteration 22 the best fitness is 0.033318737989248136']
# ['At iteration 23 the best fitness is 0.033318737989248136']
# ['At iteration 24 the best fitness is 0.033318737989248136']
# ['At iteration 25 the best fitness is 0.033318737989248136']
# ['At iteration 26 the best fitness is 0.033318737989248136']
# ['At iteration 27 the best fitness is 0.0323797708530979']
# ['At iteration 28 the best fitness is 0.0323797708530979']
# ['At iteration 29 the best fitness is 0.0323797708530979']
#       Selected: 101/213 (47.4%), Fitness: 0.0324, Time: 360.2s
#     L2 Test Acc: 89.39%, F1: 89.47%, Features: 101/446 (22.6%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 213, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03894524313410694']
# ['At iteration 2 the best fitness is 0.03894524313410694']
# ['At iteration 3 the best fitness is 0.0351966722615486']
# ['At iteration 4 the best fitness is 0.0351966722615486']
# ['At iteration 5 the best fitness is 0.0351966722615486']
# ['At iteration 6 the best fitness is 0.0351966722615486']
# ['At iteration 7 the best fitness is 0.03402296334136081']
# ['At iteration 8 the best fitness is 0.03402296334136081']
# ['At iteration 9 the best fitness is 0.03402296334136081']
# ['At iteration 10 the best fitness is 0.03402296334136081']
# ['At iteration 11 the best fitness is 0.03261451263713546']
# ['At iteration 12 the best fitness is 0.0323797708530979']
# ['At iteration 13 the best fitness is 0.0323797708530979']
# ['At iteration 14 the best fitness is 0.0323797708530979']
# ['At iteration 15 the best fitness is 0.0323797708530979']
# ['At iteration 16 the best fitness is 0.03214502906906034']
# ['At iteration 17 the best fitness is 0.03214502906906034']
# ['At iteration 18 the best fitness is 0.03191028728502278']
# ['At iteration 19 the best fitness is 0.03191028728502278']
# ['At iteration 20 the best fitness is 0.03191028728502278']
# ['At iteration 21 the best fitness is 0.03191028728502278']
# ['At iteration 22 the best fitness is 0.03191028728502278']
# ['At iteration 23 the best fitness is 0.031440803716947664']
# ['At iteration 24 the best fitness is 0.031440803716947664']
# ['At iteration 25 the best fitness is 0.030971320148872543']
# ['At iteration 26 the best fitness is 0.030971320148872543']
# ['At iteration 27 the best fitness is 0.030971320148872543']
# ['At iteration 28 the best fitness is 0.030971320148872543']
# ['At iteration 29 the best fitness is 0.03073657836483499']
# ['At iteration 30 the best fitness is 0.03073657836483499']
#       Selected: 99/213 (46.5%), Fitness: 0.0307, Time: 372.1s
#     L2 Test Acc: 84.85%, F1: 86.63%, Features: 99/446 (22.2%)
#
#   --- Layer 2: META_PSO ---
#     Running EvoloPy PSO (Layer 2)...
#       Features: 213, Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.048555060935561535']
# ['At iteration 2 the best fitness is 0.04339803935877785']
# ['At iteration 3 the best fitness is 0.03871050135006938']
# ['At iteration 4 the best fitness is 0.03824101778199426']
# ['At iteration 5 the best fitness is 0.03824101778199426']
# ['At iteration 6 the best fitness is 0.03824101778199426']
# ['At iteration 7 the best fitness is 0.03824101778199426']
# ['At iteration 8 the best fitness is 0.03824101778199426']
# ['At iteration 9 the best fitness is 0.03824101778199426']
# ['At iteration 10 the best fitness is 0.03824101778199426']
# ['At iteration 11 the best fitness is 0.03824101778199426']
# ['At iteration 12 the best fitness is 0.03824101778199426']
# ['At iteration 13 the best fitness is 0.03824101778199426']
# ['At iteration 14 the best fitness is 0.0380062759979567']
# ['At iteration 15 the best fitness is 0.0380062759979567']
# ['At iteration 16 the best fitness is 0.0380062759979567']
# ['At iteration 17 the best fitness is 0.0380062759979567']
# ['At iteration 18 the best fitness is 0.0380062759979567']
# ['At iteration 19 the best fitness is 0.0380062759979567']
# ['At iteration 20 the best fitness is 0.0380062759979567']
# ['At iteration 21 the best fitness is 0.0380062759979567']
# ['At iteration 22 the best fitness is 0.0380062759979567']
# ['At iteration 23 the best fitness is 0.0380062759979567']
# ['At iteration 24 the best fitness is 0.0380062759979567']
# ['At iteration 25 the best fitness is 0.03730205064584403']
# ['At iteration 26 the best fitness is 0.03730205064584403']
# ['At iteration 27 the best fitness is 0.03730205064584403']
# ['At iteration 28 the best fitness is 0.03730205064584403']
# ['At iteration 29 the best fitness is 0.03730205064584403']
# ['At iteration 30 the best fitness is 0.03730205064584403']
#       Selected: 101/213 (47.4%), Fitness: 0.0373, Time: 372.1s
#     L2 Test Acc: 89.39%, F1: 90.22%, Features: 101/446 (22.6%)
#
#   --- Layer 2: META_SCA ---
#     Running EvoloPy SCA (Layer 2)...
#       Features: 213, Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0380062759979567']
# ['At iteration 1 the best fitness is 0.0380062759979567']
# ['At iteration 2 the best fitness is 0.03683256707776891']
# ['At iteration 3 the best fitness is 0.03683256707776891']
# ['At iteration 4 the best fitness is 0.03683256707776891']
# ['At iteration 5 the best fitness is 0.03190298961298018']
# ['At iteration 6 the best fitness is 0.03190298961298018']
# ['At iteration 7 the best fitness is 0.03190298961298018']
# ['At iteration 8 the best fitness is 0.03190298961298018']
# ['At iteration 9 the best fitness is 0.03190298961298018']
# ['At iteration 10 the best fitness is 0.03190298961298018']
# ['At iteration 11 the best fitness is 0.03190298961298018']
# ['At iteration 12 the best fitness is 0.03190298961298018']
# ['At iteration 13 the best fitness is 0.03190298961298018']
# ['At iteration 14 the best fitness is 0.03190298961298018']
# ['At iteration 15 the best fitness is 0.03166095015689991']
# ['At iteration 16 the best fitness is 0.026738670364153887']
# ['At iteration 17 the best fitness is 0.026738670364153887']
# ['At iteration 18 the best fitness is 0.026738670364153887']
# ['At iteration 19 the best fitness is 0.026738670364153887']
# ['At iteration 20 the best fitness is 0.02486073609185342']
# ['At iteration 21 the best fitness is 0.02486073609185342']
# ['At iteration 22 the best fitness is 0.02486073609185342']
# ['At iteration 23 the best fitness is 0.02486073609185342']
# ['At iteration 24 the best fitness is 0.02486073609185342']
# ['At iteration 25 the best fitness is 0.02486073609185342']
# ['At iteration 26 the best fitness is 0.02486073609185342']
# ['At iteration 27 the best fitness is 0.02486073609185342']
# ['At iteration 28 the best fitness is 0.02486073609185342']
# ['At iteration 29 the best fitness is 0.021346907003332638']
#       Selected: 49/213 (23.0%), Fitness: 0.0213, Time: 369.1s
#     L2 Test Acc: 86.87%, F1: 88.88%, Features: 49/446 (11.0%)
#
#   --- Layer 2: META_SSA ---
#     Running EvoloPy SSA (Layer 2)...
#       Features: 213, Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03964946848621962']
# ['At iteration 2 the best fitness is 0.03964946848621962']
# ['At iteration 3 the best fitness is 0.03964946848621962']
# ['At iteration 4 the best fitness is 0.03941472670218206']
# ['At iteration 5 the best fitness is 0.03378822155732325']
# ['At iteration 6 the best fitness is 0.03378822155732325']
# ['At iteration 7 the best fitness is 0.03378822155732325']
# ['At iteration 8 the best fitness is 0.03378822155732325']
# ['At iteration 9 the best fitness is 0.03378822155732325']
# ['At iteration 10 the best fitness is 0.03378822155732325']
# ['At iteration 11 the best fitness is 0.03378822155732325']
# ['At iteration 12 the best fitness is 0.03378822155732325']
# ['At iteration 13 the best fitness is 0.03378822155732325']
# ['At iteration 14 the best fitness is 0.03378822155732325']
# ['At iteration 15 the best fitness is 0.03378822155732325']
# ['At iteration 16 the best fitness is 0.03378822155732325']
# ['At iteration 17 the best fitness is 0.03378822155732325']
# ['At iteration 18 the best fitness is 0.03378822155732325']
# ['At iteration 19 the best fitness is 0.03378822155732325']
# ['At iteration 20 the best fitness is 0.03378822155732325']
# ['At iteration 21 the best fitness is 0.03378822155732325']
# ['At iteration 22 the best fitness is 0.03378822155732325']
# ['At iteration 23 the best fitness is 0.03378822155732325']
# ['At iteration 24 the best fitness is 0.03378822155732325']
# ['At iteration 25 the best fitness is 0.03378822155732325']
# ['At iteration 26 the best fitness is 0.03378822155732325']
# ['At iteration 27 the best fitness is 0.03378822155732325']
# ['At iteration 28 the best fitness is 0.03378822155732325']
# ['At iteration 29 the best fitness is 0.03378822155732325']
#       Selected: 103/213 (48.4%), Fitness: 0.0338, Time: 926.2s
#     L2 Test Acc: 92.42%, F1: 93.06%, Features: 103/446 (23.1%)
#
#   --- Layer 2: META_WOA ---
#     Running EvoloPy WOA (Layer 2)...
#       Features: 213, Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04691916611934123']
# ['At iteration 1 the best fitness is 0.04197499331046729']
# ['At iteration 2 the best fitness is 0.03823372010995156']
# ['At iteration 3 the best fitness is 0.03823372010995156']
# ['At iteration 4 the best fitness is 0.0368252694057262']
# ['At iteration 5 the best fitness is 0.03518207691746329']
# ['At iteration 6 the best fitness is 0.032372473181055295']
# ['At iteration 7 the best fitness is 0.032372473181055295']
# ['At iteration 8 the best fitness is 0.032372473181055295']
# ['At iteration 9 the best fitness is 0.032372473181055295']
# ['At iteration 10 the best fitness is 0.032372473181055295']
# ['At iteration 11 the best fitness is 0.032372473181055295']
# ['At iteration 12 the best fitness is 0.032372473181055295']
# ['At iteration 13 the best fitness is 0.032372473181055295']
# ['At iteration 14 the best fitness is 0.032372473181055295']
# ['At iteration 15 the best fitness is 0.032372473181055295']
# ['At iteration 16 the best fitness is 0.032372473181055295']
# ['At iteration 17 the best fitness is 0.032372473181055295']
# ['At iteration 18 the best fitness is 0.032372473181055295']
# ['At iteration 19 the best fitness is 0.032372473181055295']
# ['At iteration 20 the best fitness is 0.030729280692792384']
# ['At iteration 21 the best fitness is 0.030729280692792384']
# ['At iteration 22 the best fitness is 0.030729280692792384']
# ['At iteration 23 the best fitness is 0.030729280692792384']
# ['At iteration 24 the best fitness is 0.030729280692792384']
# ['At iteration 25 the best fitness is 0.030729280692792384']
# ['At iteration 26 the best fitness is 0.030729280692792384']
# ['At iteration 27 the best fitness is 0.030729280692792384']
# ['At iteration 28 the best fitness is 0.030729280692792384']
# ['At iteration 29 the best fitness is 0.030729280692792384']
#       Selected: 74/213 (34.7%), Fitness: 0.0307, Time: 357.1s
#     L2 Test Acc: 90.40%, F1: 91.07%, Features: 74/446 (16.6%)
#
# ================================================================================
# ALL LAYER 2 EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
rows = []

for method_name in ALL_METHODS_L2:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'L1 Features': r.get('l1_features', TOTAL_FEATURES),
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_two_layer/all_results_per_fold.csv
# Shape: (85, 27)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  L1 Features  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected
# 0   mutual_info     1            91.2587           97.1429       90.7563          90.7563              93.7199           91.2587                111             446                24.8879          222       1.0776          5.4237          6.5013         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               0.0000               0               22.2222                2                   27.25                109
# 1   mutual_info     2            85.0622          100.0000       85.2172          85.1777              90.2823           85.0826                111             446                24.8879          222       1.1460          5.9549          7.1011         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               0.0000               0               22.2222                2                   27.25                109
# 2   mutual_info     3            90.9091           98.9418       90.7508          90.7508              93.9152           90.9091                111             446                24.8879          222       1.1087          5.8567          6.9654         52747           0.2038                 3.9642                  0.9866                75.1121        18.4971               0.0000               0               22.2222                2                   27.25                109
# 3   mutual_info     4            91.3636           97.3545       90.1093          90.1093              93.8164           91.3636                111             446                24.8879          222       1.1123          5.9971          7.1094         52747           0.2038                 3.9642                  0.9866                75.1121        18.4971               0.0000               0               22.2222                2                   27.25                109
# 4   mutual_info     5            96.9697           98.4456       96.9900          96.9900              97.2222           96.9697                111             446                24.8879          222       1.1431          6.2347          7.3778         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               0.0000               0               22.2222                2                   27.25                109
# 5           rfe     1            90.5594           97.1429       89.8269          89.8269              92.5669           90.5594                111             446                24.8879          222       0.5428          5.5686          6.1116         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               2.7027               1               33.3333                3                   26.75                107
# 6           rfe     2            91.2863          100.0000       91.7080          91.6955              93.6874           91.2810                111             446                24.8879          222       0.5370          5.8402          6.3774         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               5.4054               2               22.2222                2                   26.75                107
# 7           rfe     3            95.0000           98.4127       95.0422          95.0422              96.3205           95.0000                111             446                24.8879          222       0.5359          5.8924          6.4285         52747           0.2038                 3.9642                  0.9866                75.1121        18.4971               5.4054               2               22.2222                2                   26.75                107
# 8           rfe     4            95.4545           97.3545       95.4171          95.4171              96.4399           95.4545                111             446                24.8879          222       0.5406          5.8196          6.3604         52747           0.2038                 3.9642                  0.9866                75.1121        18.4971               5.4054               2               22.2222                2                   26.75                107
# 9           rfe     5            90.9091           97.9275       90.4842          90.4842              92.2538           90.9091                111             446                24.8879          222       0.5299          6.1674          6.6975         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               5.4054               2               22.2222                2                   26.75                107
# 10        lasso     1            93.3566           96.0000       93.0669          93.0669              94.3080           93.3566                111             446                24.8879          222       0.0313          5.4692          5.5006         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               0.0000               0                0.0000                0                   27.75                111
# 11        lasso     2            85.8921           99.4565       85.7690          85.8261              89.6191           85.9091                111             446                24.8879          222       0.0334          5.8712          5.9047         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               0.0000               0                0.0000                0                   27.75                111
# 12        lasso     3            92.2727           98.4127       91.8487          91.8487              93.9526           92.2727                111             446                24.8879          222       0.0338          5.8733          5.9072         52747           0.2038                 3.9642                  0.9866                75.1121        18.4971               0.0000               0               11.1111                1                   27.50                110
# 13        lasso     4            92.2727           95.2381       91.9652          91.9652              94.3244           92.2727                111             446                24.8879          222       0.0332          5.8516          5.8848         52747           0.2038                 3.9642                  0.9866                75.1121        18.4971               0.0000               0                0.0000                0                   27.75                111
# 14        lasso     5            90.4040           96.8912       90.6733          90.6733              92.9311           90.4040                111             446                24.8879          222       0.0472          6.1828          6.2301         52747           0.2038                 3.9642                  0.9866                75.1121        18.4946               0.0000               0                0.0000                0                   27.75                111
# 15     meta_BAT     1            93.7063           96.5714       92.7845          92.7845              95.4103           93.7063                 77             446                17.2646          168     335.5385          5.3694        340.9079         26125           0.1014                 3.9642                  0.6844                82.7354        17.8872              45.9459              17               22.2222                2                   14.50                 58
# 16     meta_BAT     2            87.1369          100.0000       87.2126          87.1813              91.0838           87.1488                 91             446                20.4036          211     359.5585          5.8251        365.3838         35967           0.1393                 3.9642                  0.8088                79.5964        18.1123              21.6216               8               33.3333                3                   20.00                 80
# 17     meta_BAT     3            88.6364           98.9418       87.2030          87.2030              92.8540           88.6364                100             446                22.4215          220     362.6890          5.7625        368.4516         43122           0.1668                 3.9642                  0.8888                77.5785        18.2788              16.2162               6               33.3333                3                   22.75                 91
# 18     meta_BAT     4            90.0000           96.2963       89.4969          89.4969              91.9276           90.0000                 99             446                22.1973          202     361.7806          5.8851        367.6658         42295           0.1636                 3.9642                  0.8799                77.8027        18.2612              24.3243               9               44.4444                4                   21.50                 86
# 19     meta_BAT     5            89.3939           98.4456       90.2152          90.2152              93.0047           89.3939                 93             446                20.8520          213     379.0697          6.1524        385.2223         37501           0.1452                 3.9642                  0.8266                79.1480        18.1470              29.7297              11               22.2222                2                   20.00                 80

# %% [markdown]
# ## Per-Method Summary Table

# %%
summary_rows = []
for method_name in ALL_METHODS_L2:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean L1 Features': method_df['L1 Features'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean L1 Features  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
# mutual_info              91.11              4.21              90.76              4.18                   111.0                       24.89             222.0              1.12                 5.89                 7.01            52747.0                  0.20                       75.11               18.50
#         rfe              92.64              2.38              92.50              2.59                   111.0                       24.89             222.0              0.54                 5.86                 6.40            52747.0                  0.20                       75.11               18.50
#       lasso              90.84              2.96              90.66              2.86                   111.0                       24.89             222.0              0.04                 5.85                 5.89            52747.0                  0.20                       75.11               18.50
#    meta_BAT              89.77              2.44              89.38              2.33                    92.0                       20.63             202.8            359.73                 5.80               365.53            37002.0                  0.14                       79.37               18.14
#     meta_CS              84.63              8.01              83.29              9.10                    88.0                       19.73             202.8            709.88                 5.80               715.69            34182.0                  0.13                       80.27               18.07
#     meta_DE              87.13              4.74              86.12              5.93                    94.2                       21.12             202.8            361.02                 5.82               366.84            38939.8                  0.15                       78.88               18.18
#    meta_FFA              89.72              8.05              89.26              9.09                    98.6                       22.11             202.8            348.85                 5.84               354.69            42057.0                  0.16                       77.89               18.25
#     meta_GA              90.76              2.99              90.38              3.28                    92.2                       20.67             202.8            349.50                 5.82               355.32            37103.4                  0.14                       79.33               18.14
#    meta_GWO              89.80              1.31              89.73              1.86                    74.8                       16.77             202.8            349.16                 5.83               354.98            24784.0                  0.10                       83.23               17.86
#    meta_HHO              86.99              8.68              86.16              9.48                    77.8                       17.44             202.8            467.95                 5.78               473.73            28313.2                  0.11                       82.56               17.94
#   meta_JAYA              91.78              2.78              91.36              3.09                    92.6                       20.76             202.8            362.31                 5.81               368.12            37637.4                  0.15                       79.24               18.15
#    meta_MFO              89.87              2.48              89.19              3.43                    91.6                       20.54             202.8            339.20                 5.85               345.05            36840.8                  0.14                       79.46               18.13
#    meta_MVO              88.90              4.79              88.60              5.06                    99.4                       22.29             202.8            350.01                 5.87               355.87            43056.2                  0.17                       77.71               18.27
#    meta_PSO              89.21              3.47              88.67              3.79                    92.0                       20.63             202.8            349.68                 5.86               355.54            37192.4                  0.14                       79.37               18.14
#    meta_SCA              88.35              2.00              87.74              1.92                    50.4                       11.30             202.8            347.33                 5.82               353.15            16649.2                  0.06                       88.70               17.66
#    meta_SSA              90.94              3.33              90.77              3.79                    97.4                       21.84             202.8            873.78                 5.83               879.61            41704.6                  0.16                       78.16               18.24
#    meta_WOA              86.39              9.31              85.56             10.47                    72.2                       16.19             202.8            337.48                 5.78               343.25            24263.6                  0.09                       83.81               17.84

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS_L2)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Two-Layer FS: Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Two-Layer FS: Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Two-Layer FS: Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention scatter
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS_L2:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Two-Layer FS: Accuracy vs Feature Retention', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap
# ============================================================================
modality_data = {}
for method in ALL_METHODS_L2:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS_L2)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Two-Layer FS: Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Layer 2 Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Metaheuristics-only comparison
# ============================================================================
meta_method_names = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

if len(meta_method_names) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_method_names)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_method_names)
    bars = axes[0].bar(range(len(meta_method_names)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_method_names))))
    axes[0].set_xticks(range(len(meta_method_names)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_method_names], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Two-Layer FS Metaheuristics: Test Accuracy', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_method_names)
    bars2 = axes[1].bar(range(len(meta_method_names)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_method_names))))
    axes[1].set_xticks(range(len(meta_method_names)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_method_names], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Two-Layer FS Metaheuristics: Feature Retention', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '07_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 07_metaheuristics_comparison.png")
# Out:
# Saved: 07_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 8: Convergence curves for metaheuristics
# ============================================================================
meta_method_names = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

if len(meta_method_names) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_method_names:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Layer 2 Metaheuristic Convergence Curves (averaged)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_convergence_curves.png")
# Out:
# Saved: 08_convergence_curves.png

# %%
# ============================================================================
# PLOT 9: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods_plot = ['mutual_info', 'rfe', 'lasso']
meta_methods_plot = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

all_std = df_all[df_all['Method'].isin(standard_methods_plot)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods_plot)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

all_std_f = df_all[(df_all['Method'].isin(standard_methods_plot)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods_plot)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

all_std_t = df_all[(df_all['Method'].isin(standard_methods_plot)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods_plot)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '09_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 09_standard_vs_metaheuristics.png")
# Out:
# Saved: 09_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 10: Per-fold accuracy line plot
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS_L2:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Two-Layer FS: Test Accuracy Across Folds', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_per_fold_accuracy_lines.png")
# Out:
# Saved: 10_per_fold_accuracy_lines.png

# %% [markdown]
# ## Best Metaheuristic Per Fold (Layer 2)

# %%
meta_methods_l2 = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD - LAYER 2 (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods_l2:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

df_best_meta = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold - Layer 2)")
print("=" * 90)

if len(df_best_meta) > 0:
    avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
    std_test_acc = df_best_meta['Test Accuracy (%)'].std()
    avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
    std_feat_ret = df_best_meta['Feature Retention (%)'].std()

    print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
    print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

    print(f"\n  Average Modality-wise Feature Retention:")
    for mod in modality_names:
        col = f'{mod} Retention (%)'
        if col in df_best_meta.columns:
            avg_mod = df_best_meta[col].mean()
            std_mod = df_best_meta[col].std()
            print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

    csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
    df_best_meta.to_csv(csv_path, index=False)
    print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD - LAYER 2 (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_WOA
#     Test Accuracy:      95.80%
#     Feature Retention:  15.92% (71/446)
#     Modality Retention: depth=32.4%, sensor=22.2%, skeleton=14.2%
#
#   Fold 2: Best = meta_MFO
#     Test Accuracy:      91.70%
#     Feature Retention:  21.52% (96/446)
#     Modality Retention: depth=27.0%, sensor=44.4%, skeleton=20.5%
#
#   Fold 3: Best = meta_HHO
#     Test Accuracy:      97.27%
#     Feature Retention:  21.97% (98/446)
#     Modality Retention: depth=21.6%, sensor=33.3%, skeleton=21.8%
#
#   Fold 4: Best = meta_FFA
#     Test Accuracy:      96.82%
#     Feature Retention:  23.32% (104/446)
#     Modality Retention: depth=27.0%, sensor=22.2%, skeleton=23.0%
#
#   Fold 5: Best = meta_JAYA
#     Test Accuracy:      93.43%
#     Feature Retention:  22.65% (101/446)
#     Modality Retention: depth=27.0%, sensor=33.3%, skeleton=22.0%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold - Layer 2)
# ==========================================================================================
#
#   Average Test Accuracy:     95.01% ± 2.37%
#   Average Feature Retention: 21.08% ± 2.96%
#
#   Average Modality-wise Feature Retention:
#          depth: 27.03% ± 3.82%
#         sensor: 31.11% ± 9.30%
#       skeleton: 20.30% ± 3.50%
#
# Saved to: results_two_layer/best_metaheuristic_per_fold.csv
