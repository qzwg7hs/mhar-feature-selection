# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_10_lost")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   depth: 37
#   sensor: 9
#   skeleton: 400
#   TOTAL: 446

# %%
# ============================================================================
# SIMULATE 10% DATA LOSS ON EXTRACTED FEATURES
# ============================================================================
# Randomly zero out 10% of feature values across ALL samples and ALL modalities.
# This corrupts the already-extracted features in-place before the pipeline runs.
# ============================================================================

DATA_LOSS_RATIO = 0.10  # 10% of feature values will be set to 0
CORRUPTION_SEED = 42    # For reproducibility

rng = np.random.RandomState(CORRUPTION_SEED)

modalities = ['depth_feat', 'sensor_feat', 'skeleton_feat']

total_values = 0
total_corrupted = 0
per_modality_stats = {m: {'total': 0, 'corrupted': 0} for m in modalities}

for sample in X_feat:
    for mod in modalities:
        feat = sample[mod]
        n = feat.shape[0]
        # Create a random mask: True means this value gets zeroed out
        loss_mask = rng.rand(n) < DATA_LOSS_RATIO
        n_corrupted = np.sum(loss_mask)
        feat[loss_mask] = 0.0  # Set lost values to 0
        
        total_values += n
        total_corrupted += n_corrupted
        per_modality_stats[mod]['total'] += n
        per_modality_stats[mod]['corrupted'] += n_corrupted

print(f"{'='*60}")
print(f"DATA CORRUPTION APPLIED: {DATA_LOSS_RATIO*100:.0f}% random data loss")
print(f"{'='*60}")
print(f"Total feature values:   {total_values:,}")
print(f"Values zeroed out:      {total_corrupted:,} ({total_corrupted/total_values*100:.2f}%)")
print(f"")
print(f"Per-modality breakdown:")
for mod in modalities:
    s = per_modality_stats[mod]
    print(f"  {mod:15s}: {s['corrupted']:>6,} / {s['total']:>8,} zeroed ({s['corrupted']/s['total']*100:.2f}%)")
print(f"{'='*60}")
# Out:
# ============================================================
# DATA CORRUPTION APPLIED: 10% random data loss
# ============================================================
# Total feature values:   519,590
# Values zeroed out:      52,039 (10.02%)
#
# Per-modality breakdown:
#   depth_feat     :  4,306 /   43,105 zeroed (9.99%)
#   sensor_feat    :  1,099 /   10,485 zeroed (10.48%)
#   skeleton_feat  : 46,634 /  466,000 zeroed (10.01%)
# ============================================================

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 85.66%, F1: 84.81%, Features: 446/446 (100.0%), Model: 1.407MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 223/446 (50.0%), Time: 2.2s
#     Test Acc: 84.62%, F1: 84.19%, Features: 223/446 (50.0%), Model: 0.790MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 223/446 (50.0%), Time: 0.5s
#     Test Acc: 86.01%, F1: 84.99%, Features: 223/446 (50.0%), Model: 0.790MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 223/446 (50.0%), Time: 0.1s
#     Test Acc: 80.77%, F1: 80.22%, Features: 223/446 (50.0%), Model: 0.790MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.17655156950672649']
# ['At iteration 1 the best fitness is 0.1764394618834081']
# ['At iteration 2 the best fitness is 0.16569442664958361']
# ['At iteration 3 the best fitness is 0.16569442664958361']
# ['At iteration 4 the best fitness is 0.16569442664958361']
# ['At iteration 5 the best fitness is 0.16569442664958361']
# ['At iteration 6 the best fitness is 0.16569442664958361']
# ['At iteration 7 the best fitness is 0.16569442664958361']
# ['At iteration 8 the best fitness is 0.16569442664958361']
# ['At iteration 9 the best fitness is 0.16569442664958361']
# ['At iteration 10 the best fitness is 0.16569442664958361']
# ['At iteration 11 the best fitness is 0.16569442664958361']
# ['At iteration 12 the best fitness is 0.16569442664958361']
# ['At iteration 13 the best fitness is 0.16569442664958361']
# ['At iteration 14 the best fitness is 0.14929660474055095']
# ['At iteration 15 the best fitness is 0.14929660474055095']
# ['At iteration 16 the best fitness is 0.14929660474055095']
# ['At iteration 17 the best fitness is 0.14929660474055095']
# ['At iteration 18 the best fitness is 0.14929660474055095']
# ['At iteration 19 the best fitness is 0.14929660474055095']
# ['At iteration 20 the best fitness is 0.14929660474055095']
# ['At iteration 21 the best fitness is 0.14929660474055095']
# ['At iteration 22 the best fitness is 0.14929660474055095']
# ['At iteration 23 the best fitness is 0.14929660474055095']
# ['At iteration 24 the best fitness is 0.14398014093529785']
# ['At iteration 25 the best fitness is 0.14398014093529785']
# ['At iteration 26 the best fitness is 0.14398014093529785']
# ['At iteration 27 the best fitness is 0.14398014093529785']
# ['At iteration 28 the best fitness is 0.14398014093529785']
# ['At iteration 29 the best fitness is 0.14398014093529785']
#       Selected: 217/446 (48.7%), Fitness: 0.1440, Time: 913.0s
#       Modality: D=54%, S=44%, Sk=48%
#     Test Acc: 80.07%, F1: 79.46%, Features: 217/446 (48.7%), Model: 0.749MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.16547021140294685']
# ['At iteration 10 the best fitness is 0.16547021140294685']
# ['At iteration 20 the best fitness is 0.14996925048046125']
#       Selected: 214/446 (48.0%), Fitness: 0.1423, Time: 1828.9s
#       Modality: D=49%, S=33%, Sk=48%
#     Test Acc: 79.02%, F1: 77.29%, Features: 214/446 (48.0%), Model: 0.729MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1887540038436899']
# ['At iteration 2 the best fitness is 0.1887540038436899']
# ['At iteration 3 the best fitness is 0.1887540038436899']
# ['At iteration 4 the best fitness is 0.1887540038436899']
# ['At iteration 5 the best fitness is 0.17901793721973097']
# ['At iteration 6 the best fitness is 0.17901793721973097']
# ['At iteration 7 the best fitness is 0.17901793721973097']
# ['At iteration 8 the best fitness is 0.17201985906470207']
# ['At iteration 9 the best fitness is 0.17201985906470207']
# ['At iteration 10 the best fitness is 0.17201985906470207']
# ['At iteration 11 the best fitness is 0.15992953235105706']
# ['At iteration 12 the best fitness is 0.15992953235105706']
# ['At iteration 13 the best fitness is 0.15992953235105706']
# ['At iteration 14 the best fitness is 0.1565188981422165']
# ['At iteration 15 the best fitness is 0.1565188981422165']
# ['At iteration 16 the best fitness is 0.1565188981422165']
# ['At iteration 17 the best fitness is 0.1565188981422165']
# ['At iteration 18 the best fitness is 0.13888789237668162']
# ['At iteration 19 the best fitness is 0.13888789237668162']
# ['At iteration 20 the best fitness is 0.13888789237668162']
# ['At iteration 21 the best fitness is 0.13888789237668162']
# ['At iteration 22 the best fitness is 0.13888789237668162']
# ['At iteration 23 the best fitness is 0.13888789237668162']
# ['At iteration 24 the best fitness is 0.13888789237668162']
# ['At iteration 25 the best fitness is 0.13888789237668162']
# ['At iteration 26 the best fitness is 0.13888789237668162']
# ['At iteration 27 the best fitness is 0.13888789237668162']
# ['At iteration 28 the best fitness is 0.13016079436258804']
# ['At iteration 29 the best fitness is 0.13016079436258804']
# ['At iteration 30 the best fitness is 0.13016079436258804']
#       Selected: 242/446 (54.3%), Fitness: 0.1302, Time: 926.7s
#       Modality: D=38%, S=78%, Sk=55%
#     Test Acc: 81.82%, F1: 81.17%, Features: 242/446 (54.3%), Model: 0.928MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.15869634849455483']
# ['At iteration 1 the best fitness is 0.1715714285714285']
# ['At iteration 2 the best fitness is 0.1878571428571428']
# ['At iteration 3 the best fitness is 0.1756547085201794']
# ['At iteration 4 the best fitness is 0.16921716848174242']
# ['At iteration 5 the best fitness is 0.18119538757206918']
# ['At iteration 6 the best fitness is 0.1863997437540038']
# ['At iteration 7 the best fitness is 0.17554260089686102']
# ['At iteration 8 the best fitness is 0.18662395900064058']
# ['At iteration 9 the best fitness is 0.1597053171044203']
# ['At iteration 10 the best fitness is 0.1542767456758488']
# ['At iteration 11 the best fitness is 0.16535810377962845']
# ['At iteration 12 the best fitness is 0.14828763613068546']
# ['At iteration 13 the best fitness is 0.17011402946828952']
# ['At iteration 14 the best fitness is 0.17520627802690586']
# ['At iteration 15 the best fitness is 0.15903267136451']
# ['At iteration 16 the best fitness is 0.17509417040358746']
# ['At iteration 17 the best fitness is 0.1804106342088405']
# ['At iteration 18 the best fitness is 0.17531838565022423']
# ['At iteration 19 the best fitness is 0.17520627802690586']
# ['At iteration 20 the best fitness is 0.17520627802690586']
# ['At iteration 21 the best fitness is 0.16977770659833435']
# ['At iteration 22 the best fitness is 0.17520627802690586']
# ['At iteration 23 the best fitness is 0.17520627802690586']
# ['At iteration 24 the best fitness is 0.18063484945547725']
# ['At iteration 25 the best fitness is 0.1589205637411916']
# ['At iteration 26 the best fitness is 0.16977770659833435']
# ['At iteration 27 the best fitness is 0.164349135169763']
# ['At iteration 28 the best fitness is 0.16977770659833435']
# ['At iteration 29 the best fitness is 0.16977770659833435']
#       Selected: 209/446 (46.9%), Fitness: 0.1698, Time: 895.3s
#       Modality: D=57%, S=56%, Sk=46%
#     Test Acc: 78.67%, F1: 78.32%, Features: 209/446 (46.9%), Model: 0.696MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.16457335041639976
# At iteration 2 the best fitness is 0.1749820627802691
# At iteration 3 the best fitness is 0.1695534913516976
# At iteration 4 the best fitness is 0.16390070467648943
# At iteration 5 the best fitness is 0.1589205637411916
# At iteration 6 the best fitness is 0.14884817424727742
# At iteration 7 the best fitness is 0.15914477898782836
# At iteration 8 the best fitness is 0.1489602818705958
# At iteration 9 the best fitness is 0.1373183856502242
# At iteration 10 the best fitness is 0.13686995515695066
# At iteration 11 the best fitness is 0.1373183856502242
# At iteration 12 the best fitness is 0.137542600896861
# At iteration 13 the best fitness is 0.1381031390134529
# At iteration 14 the best fitness is 0.14884817424727742
# At iteration 15 the best fitness is 0.14341960281870592
# At iteration 16 the best fitness is 0.1335714285714286
# At iteration 17 the best fitness is 0.14297117232543238
# At iteration 18 the best fitness is 0.14795131326073033
# At iteration 19 the best fitness is 0.13245035233824473
# At iteration 20 the best fitness is 0.14795131326073033
# At iteration 21 the best fitness is 0.15394042280589362
# At iteration 22 the best fitness is 0.14761499039077516
# At iteration 23 the best fitness is 0.14839974375400386
# At iteration 24 the best fitness is 0.14319538757206915
# At iteration 25 the best fitness is 0.1313292761050609
# At iteration 26 the best fitness is 0.14884817424727742
# At iteration 27 the best fitness is 0.1373183856502242
# At iteration 28 the best fitness is 0.137542600896861
# At iteration 29 the best fitness is 0.14862395900064063
# At iteration 30 the best fitness is 0.12103267136450994
#       Selected: 213/446 (47.8%), Fitness: 0.1210, Time: 877.3s
#       Modality: D=43%, S=11%, Sk=49%
#     Test Acc: 81.12%, F1: 81.00%, Features: 213/446 (47.8%), Model: 0.722MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2010685458039718']
# ['At iteration 1 the best fitness is 0.2010685458039718']
# ['At iteration 2 the best fitness is 0.18052274183215886']
# ['At iteration 3 the best fitness is 0.18052274183215886']
# ['At iteration 4 the best fitness is 0.18052274183215886']
# ['At iteration 5 the best fitness is 0.18052274183215886']
# ['At iteration 6 the best fitness is 0.18052274183215886']
# ['At iteration 7 the best fitness is 0.18052274183215886']
# ['At iteration 8 the best fitness is 0.17442152466367716']
# ['At iteration 9 the best fitness is 0.17442152466367716']
# ['At iteration 10 the best fitness is 0.16809609224855857']
# ['At iteration 11 the best fitness is 0.15735105701473417']
# ['At iteration 12 the best fitness is 0.15735105701473417']
# ['At iteration 13 the best fitness is 0.15735105701473417']
# ['At iteration 14 the best fitness is 0.13552466367713004']
# ['At iteration 15 the best fitness is 0.13552466367713004']
# ['At iteration 16 the best fitness is 0.13552466367713004']
# ['At iteration 17 the best fitness is 0.13451569506726457']
# ['At iteration 18 the best fitness is 0.13451569506726457']
# ['At iteration 19 the best fitness is 0.1303203074951954']
# ['At iteration 20 the best fitness is 0.12410698270339522']
# ['At iteration 21 the best fitness is 0.11856630365150546']
# ['At iteration 22 the best fitness is 0.11212876361306859']
# ['At iteration 23 the best fitness is 0.11212876361306859']
# ['At iteration 24 the best fitness is 0.11212876361306859']
# ['At iteration 25 the best fitness is 0.11212876361306859']
# ['At iteration 26 the best fitness is 0.11212876361306859']
# ['At iteration 27 the best fitness is 0.11212876361306859']
# ['At iteration 28 the best fitness is 0.11212876361306859']
# ['At iteration 29 the best fitness is 0.11212876361306859']
#       Selected: 176/446 (39.5%), Fitness: 0.1121, Time: 864.0s
#       Modality: D=49%, S=44%, Sk=38%
#     Test Acc: 78.67%, F1: 78.12%, Features: 176/446 (39.5%), Model: 0.498MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.16082639333760415']
# ['At iteration 1 the best fitness is 0.16082639333760415']
# ['At iteration 2 the best fitness is 0.16082639333760415']
# ['At iteration 3 the best fitness is 0.16082639333760415']
# ['At iteration 4 the best fitness is 0.1573683536194747']
# ['At iteration 5 the best fitness is 0.1573683536194747']
# ['At iteration 6 the best fitness is 0.1573683536194747']
# ['At iteration 7 the best fitness is 0.1573683536194747']
# ['At iteration 8 the best fitness is 0.1573683536194747']
# ['At iteration 9 the best fitness is 0.1573683536194747']
# ['At iteration 10 the best fitness is 0.1573683536194747']
# ['At iteration 11 the best fitness is 0.1573683536194747']
# ['At iteration 12 the best fitness is 0.1573683536194747']
# ['At iteration 13 the best fitness is 0.1573683536194747']
# ['At iteration 14 the best fitness is 0.14175528507367074']
# ['At iteration 15 the best fitness is 0.14175528507367074']
# ['At iteration 16 the best fitness is 0.14175528507367074']
# ['At iteration 17 the best fitness is 0.14175528507367074']
# ['At iteration 18 the best fitness is 0.14175528507367074']
# ['At iteration 19 the best fitness is 0.14175528507367074']
# ['At iteration 20 the best fitness is 0.14175528507367074']
# ['At iteration 21 the best fitness is 0.14175528507367074']
# ['At iteration 22 the best fitness is 0.14175528507367074']
# ['At iteration 23 the best fitness is 0.14175528507367074']
# ['At iteration 24 the best fitness is 0.14175528507367074']
# ['At iteration 25 the best fitness is 0.14175528507367074']
# ['At iteration 26 the best fitness is 0.14175528507367074']
# ['At iteration 27 the best fitness is 0.14175528507367074']
# ['At iteration 28 the best fitness is 0.14175528507367074']
# ['At iteration 29 the best fitness is 0.14175528507367074']
#       Selected: 291/446 (65.2%), Fitness: 0.1418, Time: 1227.0s
#       Modality: D=76%, S=56%, Sk=64%
#     Test Acc: 82.87%, F1: 81.65%, Features: 291/446 (65.2%), Model: 1.105MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.17991479820627804']
# ['At iteration 1 the best fitness is 0.17991479820627804']
# ['At iteration 2 the best fitness is 0.1680486867392697']
# ['At iteration 3 the best fitness is 0.1680486867392697']
# ['At iteration 4 the best fitness is 0.1680486867392697']
# ['At iteration 5 the best fitness is 0.15550992953235104']
# ['At iteration 6 the best fitness is 0.15165086483023704']
# ['At iteration 7 the best fitness is 0.15019346572709802']
# ['At iteration 8 the best fitness is 0.15019346572709802']
# ['At iteration 9 the best fitness is 0.14487700192184494']
# ['At iteration 10 the best fitness is 0.14465278667520814']
# ['At iteration 11 the best fitness is 0.13933632286995515']
# ['At iteration 12 the best fitness is 0.13933632286995515']
# ['At iteration 13 the best fitness is 0.13933632286995515']
# ['At iteration 14 the best fitness is 0.13933632286995515']
# ['At iteration 15 the best fitness is 0.13933632286995515']
# ['At iteration 16 the best fitness is 0.13933632286995515']
# ['At iteration 17 the best fitness is 0.13933632286995515']
# ['At iteration 18 the best fitness is 0.13525304292120438']
# ['At iteration 19 the best fitness is 0.13525304292120438']
# ['At iteration 20 the best fitness is 0.13525304292120438']
# ['At iteration 21 the best fitness is 0.13525304292120438']
# ['At iteration 22 the best fitness is 0.12702178090967325']
# ['At iteration 23 the best fitness is 0.12702178090967325']
# ['At iteration 24 the best fitness is 0.12702178090967325']
# ['At iteration 25 the best fitness is 0.12702178090967325']
# ['At iteration 26 the best fitness is 0.12702178090967325']
# ['At iteration 27 the best fitness is 0.12702178090967325']
# ['At iteration 28 the best fitness is 0.12702178090967325']
# ['At iteration 29 the best fitness is 0.12702178090967325']
#       Selected: 215/446 (48.2%), Fitness: 0.1270, Time: 935.4s
#       Modality: D=54%, S=67%, Sk=47%
#     Test Acc: 80.42%, F1: 78.41%, Features: 215/446 (48.2%), Model: 0.736MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.17632735426008972']
# ['At iteration 2 the best fitness is 0.17632735426008972']
# ['At iteration 3 the best fitness is 0.17632735426008972']
# ['At iteration 4 the best fitness is 0.17632735426008972']
# ['At iteration 5 the best fitness is 0.15791159513132613']
# ['At iteration 6 the best fitness is 0.15075400384368998']
# ['At iteration 7 the best fitness is 0.15075400384368998']
# ['At iteration 8 the best fitness is 0.15075400384368998']
# ['At iteration 9 the best fitness is 0.15075400384368998']
# ['At iteration 10 the best fitness is 0.15075400384368998']
# ['At iteration 11 the best fitness is 0.15075400384368998']
# ['At iteration 12 the best fitness is 0.15075400384368998']
# ['At iteration 13 the best fitness is 0.15075400384368998']
# ['At iteration 14 the best fitness is 0.15075400384368998']
# ['At iteration 15 the best fitness is 0.15075400384368998']
# ['At iteration 16 the best fitness is 0.15075400384368998']
# ['At iteration 17 the best fitness is 0.15075400384368998']
# ['At iteration 18 the best fitness is 0.15075400384368998']
# ['At iteration 19 the best fitness is 0.15075400384368998']
# ['At iteration 20 the best fitness is 0.15075400384368998']
# ['At iteration 21 the best fitness is 0.15075400384368998']
# ['At iteration 22 the best fitness is 0.15075400384368998']
# ['At iteration 23 the best fitness is 0.14330749519538752']
# ['At iteration 24 the best fitness is 0.14330749519538752']
# ['At iteration 25 the best fitness is 0.14330749519538752']
# ['At iteration 26 the best fitness is 0.14330749519538752']
# ['At iteration 27 the best fitness is 0.14330749519538752']
# ['At iteration 28 the best fitness is 0.14330749519538752']
# ['At iteration 29 the best fitness is 0.14330749519538752']
#       Selected: 221/446 (49.6%), Fitness: 0.1433, Time: 862.2s
#       Modality: D=43%, S=22%, Sk=51%
#     Test Acc: 79.72%, F1: 78.89%, Features: 221/446 (49.6%), Model: 0.777MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.18265278667520818']
# ['At iteration 2 the best fitness is 0.18265278667520818']
# ['At iteration 3 the best fitness is 0.18265278667520818']
# ['At iteration 4 the best fitness is 0.16771236386931454']
# ['At iteration 5 the best fitness is 0.14940871236386932']
# ['At iteration 6 the best fitness is 0.14940871236386932']
# ['At iteration 7 the best fitness is 0.14940871236386932']
# ['At iteration 8 the best fitness is 0.14884817424727742']
# ['At iteration 9 the best fitness is 0.14884817424727742']
# ['At iteration 10 the best fitness is 0.14884817424727742']
# ['At iteration 11 the best fitness is 0.13776681614349776']
# ['At iteration 12 the best fitness is 0.13776681614349776']
# ['At iteration 13 the best fitness is 0.13776681614349776']
# ['At iteration 14 the best fitness is 0.13776681614349776']
# ['At iteration 15 the best fitness is 0.13776681614349776']
# ['At iteration 16 the best fitness is 0.13776681614349776']
# ['At iteration 17 the best fitness is 0.13776681614349776']
# ['At iteration 18 the best fitness is 0.13776681614349776']
# ['At iteration 19 the best fitness is 0.13776681614349776']
# ['At iteration 20 the best fitness is 0.13776681614349776']
# ['At iteration 21 the best fitness is 0.13776681614349776']
# ['At iteration 22 the best fitness is 0.13776681614349776']
# ['At iteration 23 the best fitness is 0.13776681614349776']
# ['At iteration 24 the best fitness is 0.13776681614349776']
# ['At iteration 25 the best fitness is 0.13776681614349776']
# ['At iteration 26 the best fitness is 0.13776681614349776']
# ['At iteration 27 the best fitness is 0.13776681614349776']
# ['At iteration 28 the best fitness is 0.13776681614349776']
# ['At iteration 29 the best fitness is 0.13776681614349776']
# ['At iteration 30 the best fitness is 0.13776681614349776']
#       Selected: 221/446 (49.6%), Fitness: 0.1378, Time: 905.7s
#       Modality: D=49%, S=44%, Sk=50%
#     Test Acc: 78.67%, F1: 77.71%, Features: 221/446 (49.6%), Model: 0.777MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.17190775144138368']
# ['At iteration 2 the best fitness is 0.1715714285714285']
# ['At iteration 3 the best fitness is 0.1715714285714285']
# ['At iteration 4 the best fitness is 0.16692761050608584']
# ['At iteration 5 the best fitness is 0.16060217809096738']
# ['At iteration 6 the best fitness is 0.1557341447789878']
# ['At iteration 7 the best fitness is 0.14398014093529785']
# ['At iteration 8 the best fitness is 0.14364381806534268']
# ['At iteration 9 the best fitness is 0.14364381806534268']
# ['At iteration 10 the best fitness is 0.14364381806534268']
# ['At iteration 11 the best fitness is 0.14364381806534268']
# ['At iteration 12 the best fitness is 0.14364381806534268']
# ['At iteration 13 the best fitness is 0.14364381806534268']
# ['At iteration 14 the best fitness is 0.14364381806534268']
# ['At iteration 15 the best fitness is 0.14364381806534268']
# ['At iteration 16 the best fitness is 0.14364381806534268']
# ['At iteration 17 the best fitness is 0.14364381806534268']
# ['At iteration 18 the best fitness is 0.14364381806534268']
# ['At iteration 19 the best fitness is 0.14364381806534268']
# ['At iteration 20 the best fitness is 0.14364381806534268']
# ['At iteration 21 the best fitness is 0.14364381806534268']
# ['At iteration 22 the best fitness is 0.14364381806534268']
# ['At iteration 23 the best fitness is 0.14364381806534268']
# ['At iteration 24 the best fitness is 0.14364381806534268']
# ['At iteration 25 the best fitness is 0.14364381806534268']
# ['At iteration 26 the best fitness is 0.14364381806534268']
# ['At iteration 27 the best fitness is 0.14364381806534268']
# ['At iteration 28 the best fitness is 0.14364381806534268']
# ['At iteration 29 the best fitness is 0.14364381806534268']
# ['At iteration 30 the best fitness is 0.14364381806534268']
#       Selected: 219/446 (49.1%), Fitness: 0.1436, Time: 869.4s
#       Modality: D=43%, S=100%, Sk=48%
#     Test Acc: 77.27%, F1: 76.28%, Features: 219/446 (49.1%), Model: 0.763MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.17543049327354263']
# ['At iteration 1 the best fitness is 0.17543049327354263']
# ['At iteration 2 the best fitness is 0.17543049327354263']
# ['At iteration 3 the best fitness is 0.17543049327354263']
# ['At iteration 4 the best fitness is 0.17543049327354263']
# ['At iteration 5 the best fitness is 0.17543049327354263']
# ['At iteration 6 the best fitness is 0.1669750160153747']
# ['At iteration 7 the best fitness is 0.1669750160153747']
# ['At iteration 8 the best fitness is 0.1669750160153747']
# ['At iteration 9 the best fitness is 0.1669750160153747']
# ['At iteration 10 the best fitness is 0.1669750160153747']
# ['At iteration 11 the best fitness is 0.1669750160153747']
# ['At iteration 12 the best fitness is 0.1669750160153747']
# ['At iteration 13 the best fitness is 0.1669750160153747']
# ['At iteration 14 the best fitness is 0.1669750160153747']
# ['At iteration 15 the best fitness is 0.1669750160153747']
# ['At iteration 16 the best fitness is 0.1669750160153747']
# ['At iteration 17 the best fitness is 0.1669750160153747']
# ['At iteration 18 the best fitness is 0.1669750160153747']
# ['At iteration 19 the best fitness is 0.1669750160153747']
# ['At iteration 20 the best fitness is 0.1669750160153747']
# ['At iteration 21 the best fitness is 0.1669750160153747']
# ['At iteration 22 the best fitness is 0.1669750160153747']
# ['At iteration 23 the best fitness is 0.1669750160153747']
# ['At iteration 24 the best fitness is 0.1669750160153747']
# ['At iteration 25 the best fitness is 0.1669750160153747']
# ['At iteration 26 the best fitness is 0.1669750160153747']
# ['At iteration 27 the best fitness is 0.1669750160153747']
# ['At iteration 28 the best fitness is 0.1669750160153747']
# ['At iteration 29 the best fitness is 0.1669750160153747']
#       Selected: 185/446 (41.5%), Fitness: 0.1670, Time: 865.4s
#       Modality: D=51%, S=44%, Sk=40%
#     Test Acc: 78.67%, F1: 77.91%, Features: 185/446 (41.5%), Model: 0.548MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.18186803331197948']
# ['At iteration 2 the best fitness is 0.16457335041639976']
# ['At iteration 3 the best fitness is 0.16457335041639976']
# ['At iteration 4 the best fitness is 0.16457335041639976']
# ['At iteration 5 the best fitness is 0.16457335041639976']
# ['At iteration 6 the best fitness is 0.16457335041639976']
# ['At iteration 7 the best fitness is 0.16457335041639976']
# ['At iteration 8 the best fitness is 0.16457335041639976']
# ['At iteration 9 the best fitness is 0.16457335041639976']
# ['At iteration 10 the best fitness is 0.16457335041639976']
# ['At iteration 11 the best fitness is 0.16457335041639976']
# ['At iteration 12 the best fitness is 0.16457335041639976']
# ['At iteration 13 the best fitness is 0.16457335041639976']
# ['At iteration 14 the best fitness is 0.16457335041639976']
# ['At iteration 15 the best fitness is 0.16457335041639976']
# ['At iteration 16 the best fitness is 0.16457335041639976']
# ['At iteration 17 the best fitness is 0.16457335041639976']
# ['At iteration 18 the best fitness is 0.16457335041639976']
# ['At iteration 19 the best fitness is 0.16457335041639976']
# ['At iteration 20 the best fitness is 0.16457335041639976']
# ['At iteration 21 the best fitness is 0.16457335041639976']
# ['At iteration 22 the best fitness is 0.16457335041639976']
# ['At iteration 23 the best fitness is 0.16457335041639976']
# ['At iteration 24 the best fitness is 0.16457335041639976']
# ['At iteration 25 the best fitness is 0.15914477898782836']
# ['At iteration 26 the best fitness is 0.15914477898782836']
# ['At iteration 27 the best fitness is 0.15914477898782836']
# ['At iteration 28 the best fitness is 0.15914477898782836']
# ['At iteration 29 the best fitness is 0.15914477898782836']
#       Selected: 211/446 (47.3%), Fitness: 0.1591, Time: 2225.6s
#       Modality: D=41%, S=44%, Sk=48%
#     Test Acc: 79.72%, F1: 79.71%, Features: 211/446 (47.3%), Model: 0.709MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.19272517616912235']
# ['At iteration 1 the best fitness is 0.19200512491992308']
# ['At iteration 2 the best fitness is 0.19200512491992308']
# ['At iteration 3 the best fitness is 0.18998718770019213']
# ['At iteration 4 the best fitness is 0.18998718770019213']
# ['At iteration 5 the best fitness is 0.1893619474695708']
# ['At iteration 6 the best fitness is 0.1893619474695708']
# ['At iteration 7 the best fitness is 0.18370916079436256']
# ['At iteration 8 the best fitness is 0.18370916079436256']
# ['At iteration 9 the best fitness is 0.18370916079436256']
# ['At iteration 10 the best fitness is 0.18370916079436256']
# ['At iteration 11 the best fitness is 0.18130749519538755']
# ['At iteration 12 the best fitness is 0.18130749519538755']
# ['At iteration 13 the best fitness is 0.18130749519538755']
# ['At iteration 14 the best fitness is 0.18130749519538755']
# ['At iteration 15 the best fitness is 0.18130749519538755']
# ['At iteration 16 the best fitness is 0.18130749519538755']
# ['At iteration 17 the best fitness is 0.18130749519538755']
# ['At iteration 18 the best fitness is 0.18130749519538755']
# ['At iteration 19 the best fitness is 0.18130749519538755']
# ['At iteration 20 the best fitness is 0.18130749519538755']
# ['At iteration 21 the best fitness is 0.18130749519538755']
# ['At iteration 22 the best fitness is 0.17812107623318388']
# ['At iteration 23 the best fitness is 0.17812107623318388']
# ['At iteration 24 the best fitness is 0.17812107623318388']
# ['At iteration 25 the best fitness is 0.17812107623318388']
# ['At iteration 26 the best fitness is 0.17812107623318388']
# ['At iteration 27 the best fitness is 0.17812107623318388']
# ['At iteration 28 the best fitness is 0.17812107623318388']
# ['At iteration 29 the best fitness is 0.17812107623318388']
#       Selected: 249/446 (55.8%), Fitness: 0.1781, Time: 864.0s
#       Modality: D=57%, S=44%, Sk=56%
#     Test Acc: 76.92%, F1: 76.34%, Features: 249/446 (55.8%), Model: 0.981MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 71.78%, F1: 71.03%, Features: 446/446 (100.0%), Model: 1.407MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 223/446 (50.0%), Time: 2.2s
#     Test Acc: 78.01%, F1: 77.18%, Features: 223/446 (50.0%), Model: 0.790MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 223/446 (50.0%), Time: 0.5s
#     Test Acc: 80.50%, F1: 79.98%, Features: 223/446 (50.0%), Model: 0.790MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 223/446 (50.0%), Time: 0.1s
#     Test Acc: 73.86%, F1: 73.90%, Features: 223/446 (50.0%), Model: 0.790MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.15497294794306887']
# ['At iteration 1 the best fitness is 0.14992201208812636']
# ['At iteration 2 the best fitness is 0.14980990446480796']
# ['At iteration 3 the best fitness is 0.14464686098654708']
# ['At iteration 4 the best fitness is 0.14464686098654708']
# ['At iteration 5 the best fitness is 0.11972850458178981']
# ['At iteration 6 the best fitness is 0.11972850458178981']
# ['At iteration 7 the best fitness is 0.11972850458178981']
# ['At iteration 8 the best fitness is 0.11972850458178981']
# ['At iteration 9 the best fitness is 0.11972850458178981']
# ['At iteration 10 the best fitness is 0.11972850458178981']
# ['At iteration 11 the best fitness is 0.11972850458178981']
# ['At iteration 12 the best fitness is 0.11972850458178981']
# ['At iteration 13 the best fitness is 0.11972850458178981']
# ['At iteration 14 the best fitness is 0.11972850458178981']
# ['At iteration 15 the best fitness is 0.11972850458178981']
# ['At iteration 16 the best fitness is 0.11972850458178981']
# ['At iteration 17 the best fitness is 0.11972850458178981']
# ['At iteration 18 the best fitness is 0.11972850458178981']
# ['At iteration 19 the best fitness is 0.11972850458178981']
# ['At iteration 20 the best fitness is 0.11972850458178981']
# ['At iteration 21 the best fitness is 0.11972850458178981']
# ['At iteration 22 the best fitness is 0.11972850458178981']
# ['At iteration 23 the best fitness is 0.11972850458178981']
# ['At iteration 24 the best fitness is 0.11972850458178981']
# ['At iteration 25 the best fitness is 0.11972850458178981']
# ['At iteration 26 the best fitness is 0.11972850458178981']
# ['At iteration 27 the best fitness is 0.11972850458178981']
# ['At iteration 28 the best fitness is 0.11972850458178981']
# ['At iteration 29 the best fitness is 0.11972850458178981']
#       Selected: 237/446 (53.1%), Fitness: 0.1197, Time: 994.8s
#       Modality: D=51%, S=67%, Sk=53%
#     Test Acc: 73.44%, F1: 73.88%, Features: 237/446 (53.1%), Model: 0.891MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.14397421524663678']
# ['At iteration 10 the best fitness is 0.13881117176837587']
# ['At iteration 20 the best fitness is 0.13881117176837587']
#       Selected: 225/446 (50.4%), Fitness: 0.1388, Time: 1960.8s
#       Modality: D=46%, S=56%, Sk=51%
#     Test Acc: 68.05%, F1: 67.13%, Features: 225/446 (50.4%), Model: 0.804MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.18999317605771104']
# ['At iteration 2 the best fitness is 0.1624963443166309']
# ['At iteration 3 the best fitness is 0.1624963443166309']
# ['At iteration 4 the best fitness is 0.14251681614349776']
# ['At iteration 5 the best fitness is 0.14251681614349776']
# ['At iteration 6 the best fitness is 0.14251681614349776']
# ['At iteration 7 the best fitness is 0.14251681614349776']
# ['At iteration 8 the best fitness is 0.14251681614349776']
# ['At iteration 9 the best fitness is 0.14251681614349776']
# ['At iteration 10 the best fitness is 0.14251681614349776']
# ['At iteration 11 the best fitness is 0.14251681614349776']
# ['At iteration 12 the best fitness is 0.14251681614349776']
# ['At iteration 13 the best fitness is 0.14251681614349776']
# ['At iteration 14 the best fitness is 0.14251681614349776']
# ['At iteration 15 the best fitness is 0.14251681614349776']
# ['At iteration 16 the best fitness is 0.14251681614349776']
# ['At iteration 17 the best fitness is 0.14251681614349776']
# ['At iteration 18 the best fitness is 0.14251681614349776']
# ['At iteration 19 the best fitness is 0.14251681614349776']
# ['At iteration 20 the best fitness is 0.14251681614349776']
# ['At iteration 21 the best fitness is 0.14251681614349776']
# ['At iteration 22 the best fitness is 0.14251681614349776']
# ['At iteration 23 the best fitness is 0.14251681614349776']
# ['At iteration 24 the best fitness is 0.14251681614349776']
# ['At iteration 25 the best fitness is 0.14251681614349776']
# ['At iteration 26 the best fitness is 0.14251681614349776']
# ['At iteration 27 the best fitness is 0.13465709689998046']
# ['At iteration 28 the best fitness is 0.13465709689998046']
# ['At iteration 29 the best fitness is 0.13465709689998046']
# ['At iteration 30 the best fitness is 0.13465709689998046']
#       Selected: 217/446 (48.7%), Fitness: 0.1347, Time: 997.8s
#       Modality: D=35%, S=33%, Sk=50%
#     Test Acc: 70.12%, F1: 69.97%, Features: 217/446 (48.7%), Model: 0.749MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1642900662897251']
# ['At iteration 1 the best fitness is 0.16451428153636186']
# ['At iteration 2 the best fitness is 0.14835250536166897']
# ['At iteration 3 the best fitness is 0.17495247611620202']
# ['At iteration 4 the best fitness is 0.1778733671280951']
# ['At iteration 5 the best fitness is 0.14846461298498734']
# ['At iteration 6 the best fitness is 0.1486888282316241']
# ['At iteration 7 the best fitness is 0.13230283681029434']
# ['At iteration 8 the best fitness is 0.13151808344706564']
# ['At iteration 9 the best fitness is 0.13690534217196332']
# ['At iteration 10 the best fitness is 0.13679323454864492']
# ['At iteration 11 the best fitness is 0.14678299863521155']
# ['At iteration 12 the best fitness is 0.136232696432053']
# ['At iteration 13 the best fitness is 0.13129386820042888']
# ['At iteration 14 the best fitness is 0.14195627802690583']
# ['At iteration 15 the best fitness is 0.12119199649054396']
# ['At iteration 16 the best fitness is 0.13151808344706564']
# ['At iteration 17 the best fitness is 0.14700721388184834']
# ['At iteration 18 the best fitness is 0.12635503996880487']
# ['At iteration 19 the best fitness is 0.12657925521544164']
# ['At iteration 20 the best fitness is 0.14206838565022423']
# ['At iteration 21 the best fitness is 0.1472314291284851']
# ['At iteration 22 the best fitness is 0.11625316825891986']
# ['At iteration 23 the best fitness is 0.14195627802690583']
# ['At iteration 24 the best fitness is 0.12646714759212324']
# ['At iteration 25 the best fitness is 0.13679323454864492']
# ['At iteration 26 the best fitness is 0.12646714759212324']
# ['At iteration 27 the best fitness is 0.14195627802690583']
# ['At iteration 28 the best fitness is 0.12646714759212324']
# ['At iteration 29 the best fitness is 0.14195627802690583']
#       Selected: 200/446 (44.8%), Fitness: 0.1420, Time: 948.7s
#       Modality: D=43%, S=44%, Sk=45%
#     Test Acc: 73.44%, F1: 72.68%, Features: 200/446 (44.8%), Model: 0.639MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.1758493371027491
# At iteration 2 the best fitness is 0.14902515110157927
# At iteration 3 the best fitness is 0.145207399103139
# At iteration 4 the best fitness is 0.13488131214661722
# At iteration 5 the best fitness is 0.13959592513160457
# At iteration 6 the best fitness is 0.13993224800155973
# At iteration 7 the best fitness is 0.1293819457984013
# At iteration 8 the best fitness is 0.09907633066874634
# At iteration 9 the best fitness is 0.13589028075648268
# At iteration 10 the best fitness is 0.1307272372782219
# At iteration 11 the best fitness is 0.13914749463833104
# At iteration 12 the best fitness is 0.1300545915383116
# At iteration 13 the best fitness is 0.13039091440826675
# At iteration 14 the best fitness is 0.11972850458178981
# At iteration 15 the best fitness is 0.13027880678494835
# At iteration 16 the best fitness is 0.12489154806005069
# At iteration 17 the best fitness is 0.10985084811854168
# At iteration 18 the best fitness is 0.12533997855332424
# At iteration 19 the best fitness is 0.1198406122051082
# At iteration 20 the best fitness is 0.1299424839149932
# At iteration 21 the best fitness is 0.12522787093000587
# At iteration 22 the best fitness is 0.1147896763501657
# At iteration 23 the best fitness is 0.12028904269838174
# At iteration 24 the best fitness is 0.12399468707350361
# At iteration 25 the best fitness is 0.12949405342171966
# At iteration 26 the best fitness is 0.11007506336517844
# At iteration 27 the best fitness is 0.12489154806005069
# At iteration 28 the best fitness is 0.125564193799961
# At iteration 29 the best fitness is 0.13959592513160457
# At iteration 30 the best fitness is 0.12500365568336907
#       Selected: 232/446 (52.0%), Fitness: 0.1250, Time: 948.3s
#       Modality: D=54%, S=44%, Sk=52%
#     Test Acc: 68.05%, F1: 66.34%, Features: 232/446 (52.0%), Model: 0.854MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.19358671280951453']
# ['At iteration 1 the best fitness is 0.16361742054981476']
# ['At iteration 2 the best fitness is 0.16316899005654123']
# ['At iteration 3 the best fitness is 0.15621222460518613']
# ['At iteration 4 the best fitness is 0.14667089101189318']
# ['At iteration 5 the best fitness is 0.11041747904074865']
# ['At iteration 6 the best fitness is 0.11041747904074865']
# ['At iteration 7 the best fitness is 0.11041747904074865']
# ['At iteration 8 the best fitness is 0.11041747904074865']
# ['At iteration 9 the best fitness is 0.11041747904074865']
# ['At iteration 10 the best fitness is 0.11041747904074865']
# ['At iteration 11 the best fitness is 0.11041747904074865']
# ['At iteration 12 the best fitness is 0.11041747904074865']
# ['At iteration 13 the best fitness is 0.11041747904074865']
# ['At iteration 14 the best fitness is 0.11041747904074865']
# ['At iteration 15 the best fitness is 0.11041747904074865']
# ['At iteration 16 the best fitness is 0.11041747904074865']
# ['At iteration 17 the best fitness is 0.11041747904074865']
# ['At iteration 18 the best fitness is 0.1034607135893937']
# ['At iteration 19 the best fitness is 0.1034607135893937']
# ['At iteration 20 the best fitness is 0.1034607135893937']
# ['At iteration 21 the best fitness is 0.08819579840124778']
# ['At iteration 22 the best fitness is 0.08819579840124778']
# ['At iteration 23 the best fitness is 0.08819579840124778']
# ['At iteration 24 the best fitness is 0.08819579840124778']
# ['At iteration 25 the best fitness is 0.08819579840124778']
# ['At iteration 26 the best fitness is 0.08819579840124778']
# ['At iteration 27 the best fitness is 0.08819579840124778']
# ['At iteration 28 the best fitness is 0.08819579840124778']
# ['At iteration 29 the best fitness is 0.08819579840124778']
#       Selected: 190/446 (42.6%), Fitness: 0.0882, Time: 942.2s
#       Modality: D=27%, S=78%, Sk=43%
#     Test Acc: 73.03%, F1: 72.46%, Features: 190/446 (42.6%), Model: 0.578MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.17989130434782602']
# ['At iteration 1 the best fitness is 0.17878241372587247']
# ['At iteration 2 the best fitness is 0.17878241372587247']
# ['At iteration 3 the best fitness is 0.17338906219535966']
# ['At iteration 4 the best fitness is 0.16632018912068633']
# ['At iteration 5 the best fitness is 0.15599410216416454']
# ['At iteration 6 the best fitness is 0.15599410216416454']
# ['At iteration 7 the best fitness is 0.15599410216416454']
# ['At iteration 8 the best fitness is 0.15599410216416454']
# ['At iteration 9 the best fitness is 0.15599410216416454']
# ['At iteration 10 the best fitness is 0.15599410216416454']
# ['At iteration 11 the best fitness is 0.15599410216416454']
# ['At iteration 12 the best fitness is 0.15599410216416454']
# ['At iteration 13 the best fitness is 0.15599410216416454']
# ['At iteration 14 the best fitness is 0.15599410216416454']
# ['At iteration 15 the best fitness is 0.15599410216416454']
# ['At iteration 16 the best fitness is 0.13948991031390134']
# ['At iteration 17 the best fitness is 0.13948991031390134']
# ['At iteration 18 the best fitness is 0.13948991031390134']
# ['At iteration 19 the best fitness is 0.13948991031390134']
# ['At iteration 20 the best fitness is 0.13948991031390134']
# ['At iteration 21 the best fitness is 0.13948991031390134']
# ['At iteration 22 the best fitness is 0.13948991031390134']
# ['At iteration 23 the best fitness is 0.13948991031390134']
# ['At iteration 24 the best fitness is 0.13948991031390134']
# ['At iteration 25 the best fitness is 0.13948991031390134']
# ['At iteration 26 the best fitness is 0.13948991031390134']
# ['At iteration 27 the best fitness is 0.13948991031390134']
# ['At iteration 28 the best fitness is 0.13948991031390134']
# ['At iteration 29 the best fitness is 0.13948991031390134']
#       Selected: 181/446 (40.6%), Fitness: 0.1395, Time: 1272.9s
#       Modality: D=32%, S=44%, Sk=41%
#     Test Acc: 70.54%, F1: 70.53%, Features: 181/446 (40.6%), Model: 0.526MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.18606331643595242']
# ['At iteration 1 the best fitness is 0.16563535776954572']
# ['At iteration 2 the best fitness is 0.16563535776954572']
# ['At iteration 3 the best fitness is 0.16563535776954572']
# ['At iteration 4 the best fitness is 0.1603602066679664']
# ['At iteration 5 the best fitness is 0.1603602066679664']
# ['At iteration 6 the best fitness is 0.1603602066679664']
# ['At iteration 7 the best fitness is 0.15687877753948143']
# ['At iteration 8 the best fitness is 0.15687877753948143']
# ['At iteration 9 the best fitness is 0.15687877753948143']
# ['At iteration 10 the best fitness is 0.15687877753948143']
# ['At iteration 11 the best fitness is 0.15687877753948143']
# ['At iteration 12 the best fitness is 0.15687877753948143']
# ['At iteration 13 the best fitness is 0.15687877753948143']
# ['At iteration 14 the best fitness is 0.15687877753948143']
# ['At iteration 15 the best fitness is 0.1496977968414896']
# ['At iteration 16 the best fitness is 0.14913725872489766']
# ['At iteration 17 the best fitness is 0.14913725872489766']
# ['At iteration 18 the best fitness is 0.14913725872489766']
# ['At iteration 19 the best fitness is 0.14913725872489766']
# ['At iteration 20 the best fitness is 0.13982014037824134']
# ['At iteration 21 the best fitness is 0.13982014037824134']
# ['At iteration 22 the best fitness is 0.1283729771885358']
# ['At iteration 23 the best fitness is 0.1283729771885358']
# ['At iteration 24 the best fitness is 0.1283729771885358']
# ['At iteration 25 the best fitness is 0.1283729771885358']
# ['At iteration 26 the best fitness is 0.1283729771885358']
# ['At iteration 27 the best fitness is 0.1283729771885358']
# ['At iteration 28 the best fitness is 0.1283729771885358']
# ['At iteration 29 the best fitness is 0.1283729771885358']
#       Selected: 225/446 (50.4%), Fitness: 0.1284, Time: 1003.2s
#       Modality: D=35%, S=44%, Sk=52%
#     Test Acc: 68.05%, F1: 66.88%, Features: 225/446 (50.4%), Model: 0.804MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.17921865860791572']
# ['At iteration 2 the best fitness is 0.17921865860791572']
# ['At iteration 3 the best fitness is 0.15935123805810095']
# ['At iteration 4 the best fitness is 0.15935123805810095']
# ['At iteration 5 the best fitness is 0.15935123805810095']
# ['At iteration 6 the best fitness is 0.15935123805810095']
# ['At iteration 7 the best fitness is 0.15935123805810095']
# ['At iteration 8 the best fitness is 0.13398445116007013']
# ['At iteration 9 the best fitness is 0.13398445116007013']
# ['At iteration 10 the best fitness is 0.13398445116007013']
# ['At iteration 11 the best fitness is 0.13027880678494835']
# ['At iteration 12 the best fitness is 0.13027880678494835']
# ['At iteration 13 the best fitness is 0.13027880678494835']
# ['At iteration 14 the best fitness is 0.13027880678494835']
# ['At iteration 15 the best fitness is 0.13027880678494835']
# ['At iteration 16 the best fitness is 0.13027880678494835']
# ['At iteration 17 the best fitness is 0.12960616104503805']
# ['At iteration 18 the best fitness is 0.12960616104503805']
# ['At iteration 19 the best fitness is 0.12208885747709106']
# ['At iteration 20 the best fitness is 0.12208885747709106']
# ['At iteration 21 the best fitness is 0.12208885747709106']
# ['At iteration 22 the best fitness is 0.12208885747709106']
# ['At iteration 23 the best fitness is 0.12208885747709106']
# ['At iteration 24 the best fitness is 0.12208885747709106']
# ['At iteration 25 the best fitness is 0.12208885747709106']
# ['At iteration 26 the best fitness is 0.12208885747709106']
# ['At iteration 27 the best fitness is 0.11961639695847143']
# ['At iteration 28 the best fitness is 0.11961639695847143']
# ['At iteration 29 the best fitness is 0.11961639695847143']
#       Selected: 240/446 (53.8%), Fitness: 0.1196, Time: 938.4s
#       Modality: D=62%, S=44%, Sk=53%
#     Test Acc: 78.42%, F1: 78.63%, Features: 240/446 (53.8%), Model: 0.913MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.17753704425813993']
# ['At iteration 2 the best fitness is 0.1473435367518035']
# ['At iteration 3 the best fitness is 0.1473435367518035']
# ['At iteration 4 the best fitness is 0.1473435367518035']
# ['At iteration 5 the best fitness is 0.1473435367518035']
# ['At iteration 6 the best fitness is 0.13364812829011496']
# ['At iteration 7 the best fitness is 0.13364812829011496']
# ['At iteration 8 the best fitness is 0.1325270520569311']
# ['At iteration 9 the best fitness is 0.1325270520569311']
# ['At iteration 10 the best fitness is 0.12702768570871517']
# ['At iteration 11 the best fitness is 0.12141621173718074']
# ['At iteration 12 the best fitness is 0.10121246831741082']
# ['At iteration 13 the best fitness is 0.10121246831741082']
# ['At iteration 14 the best fitness is 0.10121246831741082']
# ['At iteration 15 the best fitness is 0.10121246831741082']
# ['At iteration 16 the best fitness is 0.10121246831741082']
# ['At iteration 17 the best fitness is 0.10121246831741082']
# ['At iteration 18 the best fitness is 0.10121246831741082']
# ['At iteration 19 the best fitness is 0.10121246831741082']
# ['At iteration 20 the best fitness is 0.10121246831741082']
# ['At iteration 21 the best fitness is 0.10121246831741082']
# ...
# ['At iteration 12 the best fitness is 0.18105555426473668']
# ['At iteration 13 the best fitness is 0.18105555426473668']
# ['At iteration 14 the best fitness is 0.18105555426473668']
# ['At iteration 15 the best fitness is 0.18105555426473668']
# ['At iteration 16 the best fitness is 0.18105555426473668']
# ['At iteration 17 the best fitness is 0.18105555426473668']
# ['At iteration 18 the best fitness is 0.18105555426473668']
# ['At iteration 19 the best fitness is 0.18105555426473668']
# ['At iteration 20 the best fitness is 0.18105555426473668']
# ['At iteration 21 the best fitness is 0.17658170496526407']
# ['At iteration 22 the best fitness is 0.17658170496526407']
# ['At iteration 23 the best fitness is 0.17658170496526407']
# ['At iteration 24 the best fitness is 0.17658170496526407']
# ['At iteration 25 the best fitness is 0.17658170496526407']
# ['At iteration 26 the best fitness is 0.17658170496526407']
# ['At iteration 27 the best fitness is 0.17658170496526407']
# ['At iteration 28 the best fitness is 0.17658170496526407']
# ['At iteration 29 the best fitness is 0.17658170496526407']
#       Selected: 213/446 (47.8%), Fitness: 0.1766, Time: 1236.6s
#       Modality: D=43%, S=67%, Sk=48%
#     Test Acc: 82.83%, F1: 83.21%, Features: 213/446 (47.8%), Model: 0.722MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2419166337507842']
# ['At iteration 1 the best fitness is 0.23095099793210808']
# ['At iteration 2 the best fitness is 0.23095099793210808']
# ['At iteration 3 the best fitness is 0.19224540533004947']
# ['At iteration 4 the best fitness is 0.19224540533004947']
# ['At iteration 5 the best fitness is 0.19224540533004947']
# ['At iteration 6 the best fitness is 0.19224540533004947']
# ['At iteration 7 the best fitness is 0.19224540533004947']
# ['At iteration 8 the best fitness is 0.19224540533004947']
# ['At iteration 9 the best fitness is 0.19224540533004947']
# ['At iteration 10 the best fitness is 0.19224540533004947']
# ['At iteration 11 the best fitness is 0.19224540533004947']
# ['At iteration 12 the best fitness is 0.19224540533004947']
# ['At iteration 13 the best fitness is 0.19224540533004947']
# ['At iteration 14 the best fitness is 0.19224540533004947']
# ['At iteration 15 the best fitness is 0.19224540533004947']
# ['At iteration 16 the best fitness is 0.19224540533004947']
# ['At iteration 17 the best fitness is 0.19224540533004947']
# ['At iteration 18 the best fitness is 0.19224540533004947']
# ['At iteration 19 the best fitness is 0.19224540533004947']
# ['At iteration 20 the best fitness is 0.19224540533004947']
# ['At iteration 21 the best fitness is 0.19224540533004947']
# ['At iteration 22 the best fitness is 0.19224540533004947']
# ['At iteration 23 the best fitness is 0.19224540533004947']
# ['At iteration 24 the best fitness is 0.19224540533004947']
# ['At iteration 25 the best fitness is 0.19224540533004947']
# ['At iteration 26 the best fitness is 0.19224540533004947']
# ['At iteration 27 the best fitness is 0.19224540533004947']
# ['At iteration 28 the best fitness is 0.19224540533004947']
# ['At iteration 29 the best fitness is 0.19224540533004947']
#       Selected: 229/446 (51.3%), Fitness: 0.1922, Time: 1039.2s
#       Modality: D=51%, S=33%, Sk=52%
#     Test Acc: 72.73%, F1: 73.03%, Features: 229/446 (51.3%), Model: 0.833MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.25713190362229604']
# ['At iteration 2 the best fitness is 0.23833964543785868']
# ['At iteration 3 the best fitness is 0.23833964543785868']
# ['At iteration 4 the best fitness is 0.21652048142382493']
# ['At iteration 5 the best fitness is 0.21652048142382493']
# ['At iteration 6 the best fitness is 0.21652048142382493']
# ['At iteration 7 the best fitness is 0.21652048142382493']
# ['At iteration 8 the best fitness is 0.21652048142382493']
# ['At iteration 9 the best fitness is 0.21652048142382493']
# ['At iteration 10 the best fitness is 0.21652048142382493']
# ['At iteration 11 the best fitness is 0.2075727828248798']
# ['At iteration 12 the best fitness is 0.2075727828248798']
# ['At iteration 13 the best fitness is 0.19370280443318846']
# ['At iteration 14 the best fitness is 0.19370280443318846']
# ['At iteration 15 the best fitness is 0.19370280443318846']
# ['At iteration 16 the best fitness is 0.19370280443318846']
# ['At iteration 17 the best fitness is 0.19370280443318846']
# ['At iteration 18 the best fitness is 0.19370280443318846']
# ['At iteration 19 the best fitness is 0.19370280443318846']
# ['At iteration 20 the best fitness is 0.19370280443318846']
# ['At iteration 21 the best fitness is 0.19370280443318846']
# ['At iteration 22 the best fitness is 0.18352192197774114']
# ['At iteration 23 the best fitness is 0.18352192197774114']
# ['At iteration 24 the best fitness is 0.18352192197774114']
# ['At iteration 25 the best fitness is 0.18352192197774114']
# ['At iteration 26 the best fitness is 0.18352192197774114']
# ['At iteration 27 the best fitness is 0.18352192197774114']
# ['At iteration 28 the best fitness is 0.18352192197774114']
# ['At iteration 29 the best fitness is 0.18352192197774114']
#       Selected: 230/446 (51.6%), Fitness: 0.1835, Time: 985.2s
#       Modality: D=57%, S=67%, Sk=51%
#     Test Acc: 76.77%, F1: 77.22%, Features: 230/446 (51.6%), Model: 0.840MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.24068344989428198']
# ['At iteration 2 the best fitness is 0.24068344989428198']
# ['At iteration 3 the best fitness is 0.21182241687771558']
# ['At iteration 4 the best fitness is 0.21182241687771558']
# ['At iteration 5 the best fitness is 0.21182241687771558']
# ['At iteration 6 the best fitness is 0.21182241687771558']
# ['At iteration 7 the best fitness is 0.21002869490462142']
# ['At iteration 8 the best fitness is 0.21002869490462142']
# ['At iteration 9 the best fitness is 0.20712435233160623']
# ['At iteration 10 the best fitness is 0.19481342503310947']
# ['At iteration 11 the best fitness is 0.19481342503310947']
# ['At iteration 12 the best fitness is 0.19481342503310947']
# ['At iteration 13 the best fitness is 0.19481342503310947']
# ['At iteration 14 the best fitness is 0.19481342503310947']
# ['At iteration 15 the best fitness is 0.19056379098027368']
# ['At iteration 16 the best fitness is 0.19056379098027368']
# ['At iteration 17 the best fitness is 0.19056379098027368']
# ['At iteration 18 the best fitness is 0.19056379098027368']
# ['At iteration 19 the best fitness is 0.17602116684867214']
# ['At iteration 20 the best fitness is 0.17602116684867214']
# ['At iteration 21 the best fitness is 0.17143520992588118']
# ['At iteration 22 the best fitness is 0.17143520992588118']
# ['At iteration 23 the best fitness is 0.17143520992588118']
# ['At iteration 24 the best fitness is 0.17143520992588118']
# ['At iteration 25 the best fitness is 0.17143520992588118']
# ['At iteration 26 the best fitness is 0.17143520992588118']
# ['At iteration 27 the best fitness is 0.17143520992588118']
# ['At iteration 28 the best fitness is 0.17143520992588118']
# ['At iteration 29 the best fitness is 0.17143520992588118']
# ['At iteration 30 the best fitness is 0.1666250377564534']
#       Selected: 205/446 (46.0%), Fitness: 0.1666, Time: 1008.2s
#       Modality: D=49%, S=56%, Sk=46%
#     Test Acc: 72.73%, F1: 72.59%, Features: 205/446 (46.0%), Model: 0.670MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2498553637398638']
# ['At iteration 2 the best fitness is 0.2122708473709891']
# ['At iteration 3 the best fitness is 0.2122708473709891']
# ['At iteration 4 the best fitness is 0.2122708473709891']
# ['At iteration 5 the best fitness is 0.21204663212435235']
# ['At iteration 6 the best fitness is 0.19974616045911844']
# ['At iteration 7 the best fitness is 0.1874352331606218']
# ['At iteration 8 the best fitness is 0.1874352331606218']
# ['At iteration 9 the best fitness is 0.1874352331606218']
# ['At iteration 10 the best fitness is 0.1874352331606218']
# ['At iteration 11 the best fitness is 0.1874352331606218']
# ['At iteration 12 the best fitness is 0.1874352331606218']
# ['At iteration 13 the best fitness is 0.1874352331606218']
# ['At iteration 14 the best fitness is 0.1874352331606218']
# ['At iteration 15 the best fitness is 0.1874352331606218']
# ['At iteration 16 the best fitness is 0.1874352331606218']
# ['At iteration 17 the best fitness is 0.1874352331606218']
# ['At iteration 18 the best fitness is 0.1874352331606218']
# ['At iteration 19 the best fitness is 0.1874352331606218']
# ['At iteration 20 the best fitness is 0.1874352331606218']
# ['At iteration 21 the best fitness is 0.1874352331606218']
# ['At iteration 22 the best fitness is 0.1874352331606218']
# ['At iteration 23 the best fitness is 0.1874352331606218']
# ['At iteration 24 the best fitness is 0.1874352331606218']
# ['At iteration 25 the best fitness is 0.1874352331606218']
# ['At iteration 26 the best fitness is 0.1874352331606218']
# ['At iteration 27 the best fitness is 0.1874352331606218']
# ['At iteration 28 the best fitness is 0.1874352331606218']
# ['At iteration 29 the best fitness is 0.1874352331606218']
# ['At iteration 30 the best fitness is 0.1874352331606218']
#       Selected: 214/446 (48.0%), Fitness: 0.1874, Time: 864.3s
#       Modality: D=38%, S=78%, Sk=48%
#     Test Acc: 78.79%, F1: 78.43%, Features: 214/446 (48.0%), Model: 0.729MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.22748611724250095']
# ['At iteration 1 the best fitness is 0.22748611724250095']
# ['At iteration 2 the best fitness is 0.22748611724250095']
# ['At iteration 3 the best fitness is 0.2102529101512582']
# ['At iteration 4 the best fitness is 0.2102529101512582']
# ['At iteration 5 the best fitness is 0.20900927066149308']
# ['At iteration 6 the best fitness is 0.20900927066149308']
# ['At iteration 7 the best fitness is 0.20900927066149308']
# ['At iteration 8 the best fitness is 0.20900927066149308']
# ['At iteration 9 the best fitness is 0.2015085155324241']
# ['At iteration 10 the best fitness is 0.1956893747531309']
# ['At iteration 11 the best fitness is 0.1956893747531309']
# ['At iteration 12 the best fitness is 0.1956893747531309']
# ['At iteration 13 the best fitness is 0.1956893747531309']
# ['At iteration 14 the best fitness is 0.1956893747531309']
# ['At iteration 15 the best fitness is 0.1956893747531309']
# ['At iteration 16 the best fitness is 0.1956893747531309']
# ['At iteration 17 the best fitness is 0.1956893747531309']
# ['At iteration 18 the best fitness is 0.1956893747531309']
# ['At iteration 19 the best fitness is 0.1956893747531309']
# ['At iteration 20 the best fitness is 0.1956893747531309']
# ['At iteration 21 the best fitness is 0.1956893747531309']
# ['At iteration 22 the best fitness is 0.1956893747531309']
# ['At iteration 23 the best fitness is 0.1956893747531309']
# ['At iteration 24 the best fitness is 0.1956893747531309']
# ['At iteration 25 the best fitness is 0.1956893747531309']
# ['At iteration 26 the best fitness is 0.1956893747531309']
# ['At iteration 27 the best fitness is 0.19277457654685287']
# ['At iteration 28 the best fitness is 0.19277457654685287']
# ['At iteration 29 the best fitness is 0.19277457654685287']
#       Selected: 94/446 (21.1%), Fitness: 0.1928, Time: 531.3s
#       Modality: D=14%, S=22%, Sk=22%
#     Test Acc: 79.29%, F1: 79.51%, Features: 94/446 (21.1%), Model: 0.148MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.22054590023002388']
# ['At iteration 2 the best fitness is 0.21786577290364556']
# ['At iteration 3 the best fitness is 0.21786577290364556']
# ['At iteration 4 the best fitness is 0.21786577290364556']
# ['At iteration 5 the best fitness is 0.21786577290364556']
# ['At iteration 6 the best fitness is 0.21786577290364556']
# ['At iteration 7 the best fitness is 0.21786577290364556']
# ['At iteration 8 the best fitness is 0.21786577290364556']
# ['At iteration 9 the best fitness is 0.21652048142382493']
# ['At iteration 10 the best fitness is 0.20544273798183044']
# ['At iteration 11 the best fitness is 0.20186574966890491']
# ['At iteration 12 the best fitness is 0.20152942679894978']
# ['At iteration 13 the best fitness is 0.20152942679894978']
# ['At iteration 14 the best fitness is 0.20152942679894978']
# ['At iteration 15 the best fitness is 0.19660714700620366']
# ['At iteration 16 the best fitness is 0.19660714700620366']
# ['At iteration 17 the best fitness is 0.19660714700620366']
# ['At iteration 18 the best fitness is 0.19660714700620366']
# ['At iteration 19 the best fitness is 0.19660714700620366']
# ['At iteration 20 the best fitness is 0.19660714700620366']
# ['At iteration 21 the best fitness is 0.19660714700620366']
# ['At iteration 22 the best fitness is 0.19660714700620366']
# ['At iteration 23 the best fitness is 0.18698680266734827']
# ['At iteration 24 the best fitness is 0.18698680266734827']
# ['At iteration 25 the best fitness is 0.18698680266734827']
# ['At iteration 26 the best fitness is 0.18698680266734827']
# ['At iteration 27 the best fitness is 0.18698680266734827']
# ['At iteration 28 the best fitness is 0.18698680266734827']
# ['At iteration 29 the best fitness is 0.18698680266734827']
#       Selected: 223/446 (50.0%), Fitness: 0.1870, Time: 1365.8s
#       Modality: D=54%, S=67%, Sk=49%
#     Test Acc: 77.27%, F1: 77.49%, Features: 223/446 (50.0%), Model: 0.790MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2470631287901671']
# ['At iteration 1 the best fitness is 0.22984037733218704']
# ['At iteration 2 the best fitness is 0.2286071934756848']
# ['At iteration 3 the best fitness is 0.2244696670461674']
# ['At iteration 4 the best fitness is 0.2244696670461674']
# ['At iteration 5 the best fitness is 0.21552196844722232']
# ['At iteration 6 the best fitness is 0.21002869490462142']
# ['At iteration 7 the best fitness is 0.21002869490462142']
# ['At iteration 8 the best fitness is 0.21002869490462142']
# ['At iteration 9 the best fitness is 0.21002869490462142']
# ['At iteration 10 the best fitness is 0.21002869490462142']
# ['At iteration 11 the best fitness is 0.21002869490462142']
# ['At iteration 12 the best fitness is 0.21002869490462142']
# ['At iteration 13 the best fitness is 0.21002869490462142']
# ['At iteration 14 the best fitness is 0.21002869490462142']
# ['At iteration 15 the best fitness is 0.21002869490462142']
# ['At iteration 16 the best fitness is 0.21002869490462142']
# ['At iteration 17 the best fitness is 0.21002869490462142']
# ['At iteration 18 the best fitness is 0.21002869490462142']
# ['At iteration 19 the best fitness is 0.21002869490462142']
# ['At iteration 20 the best fitness is 0.21002869490462142']
# ['At iteration 21 the best fitness is 0.21002869490462142']
# ['At iteration 22 the best fitness is 0.21002869490462142']
# ['At iteration 23 the best fitness is 0.21002869490462142']
# ['At iteration 24 the best fitness is 0.21002869490462142']
# ['At iteration 25 the best fitness is 0.21002869490462142']
# ['At iteration 26 the best fitness is 0.21002869490462142']
# ['At iteration 27 the best fitness is 0.21002869490462142']
# ['At iteration 28 the best fitness is 0.21002869490462142']
# ['At iteration 29 the best fitness is 0.21002869490462142']
#       Selected: 197/446 (44.2%), Fitness: 0.2100, Time: 536.7s
#       Modality: D=32%, S=22%, Sk=46%
#     Test Acc: 87.88%, F1: 87.82%, Features: 197/446 (44.2%), Model: 0.620MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_10_lost/all_results_per_fold.csv
# Shape: (90, 26)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected
# 0      baseline     1            85.6643           83.4286       84.8145          84.8145              87.4154           85.6643                446             446                  100.0       0.0000         12.0898         12.0898        367382           1.4073                 3.9642                  3.9642                    0.0        25.7339             100.0000              37              100.0000                9                  100.00                400
# 1      baseline     2            71.7842           84.7826       71.0281          70.9981              76.0526           71.8595                446             446                  100.0       0.0000         17.1357         17.1357        367382           1.4073                 3.9642                  3.9642                    0.0        25.7339             100.0000              37              100.0000                9                  100.00                400
# 2      baseline     3            77.2727           86.7725       77.4634          77.4634              81.3049           77.2727                446             446                  100.0       0.0000         17.1852         17.1852        367382           1.4073                 3.9642                  3.9642                    0.0        25.7354             100.0000              37              100.0000                9                  100.00                400
# 3      baseline     4            76.8182           84.6561       75.8387          75.8387              82.1061           76.8182                446             446                  100.0       0.0000         17.0929         17.0929        367382           1.4073                 3.9642                  3.9642                    0.0        25.7354             100.0000              37              100.0000                9                  100.00                400
# 4      baseline     5            79.7980           80.8290       79.9742          79.9742              83.9515           79.7980                446             446                  100.0       0.0000         17.3822         17.3822        367382           1.4073                 3.9642                  3.9642                    0.0        25.7339             100.0000              37              100.0000                9                  100.00                400
# 5   mutual_info     1            84.6154           89.7143       84.1935          84.1935              85.5569           84.6154                223             446                   50.0       2.2222         11.5929         13.8152        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239               8.1081               3               44.4444                4                   54.00                216
# 6   mutual_info     2            78.0083           92.9348       77.1806          77.2122              81.4773           78.0165                223             446                   50.0       2.2300         16.1989         18.4289        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239              16.2162               6               44.4444                4                   53.25                213
# 7   mutual_info     3            86.8182           89.9471       86.6060          86.6060              89.7991           86.8182                223             446                   50.0       2.2838         16.7100         18.9939        205851           0.7904                 3.9642                  1.9821                   50.0        22.0278              13.5135               5               44.4444                4                   53.50                214
# 8   mutual_info     4            84.0909           90.4762       83.5074          83.5074              86.6590           84.0909                223             446                   50.0       2.2386         16.7915         19.0302        205851           0.7904                 3.9642                  1.9821                   50.0        22.0278               8.1081               3               44.4444                4                   54.00                216
# 9   mutual_info     5            90.4040           89.1192       90.5766          90.5766              91.3686           90.4040                223             446                   50.0       2.2914         16.9457         19.2372        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239              10.8108               4               44.4444                4                   53.75                215
# 10          rfe     1            86.0140           90.2857       84.9927          84.9927              87.0201           86.0140                223             446                   50.0       0.4581         13.2550         13.7133        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239               8.1081               3               44.4444                4                   54.00                216
# 11          rfe     2            80.4979           93.4783       79.9788          80.0648              83.7657           80.4959                223             446                   50.0       0.4678         16.5281         16.9962        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239              10.8108               4               33.3333                3                   54.00                216
# 12          rfe     3            85.0000           89.9471       84.9917          84.9917              87.6428           85.0000                223             446                   50.0       0.4870         16.5183         17.0055        205851           0.7904                 3.9642                  1.9821                   50.0        22.0278               8.1081               3               44.4444                4                   54.00                216
# 13          rfe     4            82.7273           87.8307       82.0565          82.0565              84.0270           82.7273                223             446                   50.0       0.4737         16.5399         17.0139        205851           0.7904                 3.9642                  1.9821                   50.0        22.0278              10.8108               4               44.4444                4                   53.75                215
# 14          rfe     5            90.4040           90.1554       90.5638          90.5638              91.8012           90.4040                223             446                   50.0       0.4700         17.2932         17.7640        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239               8.1081               3               44.4444                4                   54.00                216
# 15        lasso     1            80.7692           83.4286       80.2157          80.2157              82.4977           80.7692                223             446                   50.0       0.0667         14.6736         14.7404        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239              81.0811              30                0.0000                0                   48.25                193
# 16        lasso     2            73.8589           84.2391       73.8971          74.0193              78.3258           73.8017                223             446                   50.0       0.0714         16.6563         16.7277        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239              81.0811              30                0.0000                0                   48.25                193
# 17        lasso     3            78.1818           86.2434       77.8348          77.8348              79.9916           78.1818                223             446                   50.0       0.0699         16.7085         16.7785        205851           0.7904                 3.9642                  1.9821                   50.0        22.0278              81.0811              30                0.0000                0                   48.25                193
# 18        lasso     4            75.4545           85.7143       74.3860          74.3860              76.6267           75.4545                223             446                   50.0       0.0743         16.8132         16.8877        205851           0.7904                 3.9642                  1.9821                   50.0        22.0278              81.0811              30                0.0000                0                   48.25                193
# 19        lasso     5            76.2626           79.2746       76.9525          76.9525              83.6137           76.2626                223             446                   50.0       0.0760         17.2888         17.3649        205851           0.7904                 3.9642                  1.9821                   50.0        22.0239              81.0811              30                0.0000                0                   48.25                193

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              78.27              5.05              77.82              5.09                   446.0                      100.00              0.00                16.18                16.18           367382.0                  1.41                        0.00               25.73
# mutual_info              84.79              4.53              84.41              4.90                   223.0                       50.00              2.25                15.65                17.90           205851.0                  0.79                       50.00               22.03
#         rfe              84.93              3.73              84.52              3.99                   223.0                       50.00              0.47                16.03                16.50           205851.0                  0.79                       50.00               22.03
#       lasso              76.91              2.66              76.66              2.59                   223.0                       50.00              0.07                16.43                16.50           205851.0                  0.79                       50.00               22.03
#    meta_BAT              76.04              4.25              75.43              4.48                   225.4                       50.54            990.52                16.47              1006.99           210541.4                  0.81                       49.46               22.13
#     meta_CS              73.60              6.97              72.48              7.58                   220.4                       49.42           1943.90                16.12              1960.02           201249.6                  0.77                       50.58               21.92
#     meta_DE              78.54              5.80              78.08              5.87                   226.0                       50.67            982.55                16.18               998.74           211711.2                  0.81                       49.33               22.16
#    meta_FFA              73.65              3.32              73.10              3.85                   212.2                       47.58            953.99                16.26               970.25           187210.6                  0.72                       52.42               21.60
#     meta_GA              74.97              4.65              74.31              5.24                   222.2                       49.82            956.41                16.49               972.90           204605.4                  0.79                       50.18               21.99
#    meta_GWO              76.56              3.37              76.11              3.51                   175.6                       39.37            941.61                15.98               957.59           129662.4                  0.50                       60.63               20.28
#    meta_HHO              76.79              5.71              76.45              5.66                   214.0                       47.98           1218.57                16.14              1234.71           190166.4                  0.73                       52.02               21.65
#   meta_JAYA              73.88              4.52              72.67              4.22                   223.2                       50.04            985.82                16.40              1002.22           206301.2                  0.79                       49.96               22.03
#    meta_MFO              76.07              3.37              75.98              3.30                   227.2                       50.94            924.12                16.24               940.36           213748.4                  0.82                       49.06               22.20
#    meta_MVO              76.20              4.54              75.63              4.55                   219.2                       49.15            954.16                16.12               970.29           199322.8                  0.77                       50.85               21.87
#    meta_PSO              74.80              4.19              74.09              4.44                   222.2                       49.82            922.86                14.79               937.65           204512.6                  0.79                       50.18               21.99
#    meta_SCA              75.15              3.65              74.39              4.17                   139.4                       31.26            833.54                14.08               847.62            86313.8                  0.33                       68.74               19.27
#    meta_SSA              75.35              4.12              74.64              4.85                   221.8                       49.73           2152.95                14.77              2167.72           204087.4                  0.78                       50.27               21.98
#    meta_WOA              76.04              7.77              75.47              7.65                   254.4                       57.04            840.91                14.71               855.62           225832.8                  0.87                       42.96               22.48

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 84.79% vs Baseline: 78.27%
#   Paired t-test: t=3.1853, p=0.0334
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> better, Significant
#
# RFE vs BASELINE:
#   Method: 84.93% vs Baseline: 78.27%
#   Paired t-test: t=3.8044, p=0.0190
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> better, Significant
#
# LASSO vs BASELINE:
#   Method: 76.91% vs Baseline: 78.27%
#   Paired t-test: t=-1.0420, p=0.3563
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 76.04% vs Baseline: 78.27%
#   Paired t-test: t=-1.3249, p=0.2558
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 73.60% vs Baseline: 78.27%
#   Paired t-test: t=-2.1389, p=0.0992
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 78.54% vs Baseline: 78.27%
#   Paired t-test: t=0.1649, p=0.8771
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> better, Not significant
#
# META_FFA vs BASELINE:
#   Method: 73.65% vs Baseline: 78.27%
#   Paired t-test: t=-2.8852, p=0.0448
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Significant
#
# META_GA vs BASELINE:
#   Method: 74.97% vs Baseline: 78.27%
#   Paired t-test: t=-4.3408, p=0.0122
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_GWO vs BASELINE:
#   Method: 76.56% vs Baseline: 78.27%
#   Paired t-test: t=-0.9685, p=0.3876
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 76.79% vs Baseline: 78.27%
#   Paired t-test: t=-1.2392, p=0.2830
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 73.88% vs Baseline: 78.27%
#   Paired t-test: t=-5.0627, p=0.0072
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_MFO vs BASELINE:
#   Method: 76.07% vs Baseline: 78.27%
#   Paired t-test: t=-0.9605, p=0.3912
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 76.20% vs Baseline: 78.27%
#   Paired t-test: t=-0.9103, p=0.4141
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 74.80% vs Baseline: 78.27%
#   Paired t-test: t=-2.2579, p=0.0869
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 75.15% vs Baseline: 78.27%
#   Paired t-test: t=-2.6356, p=0.0578
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 75.35% vs Baseline: 78.27%
#   Paired t-test: t=-2.7679, p=0.0504
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 76.04% vs Baseline: 78.27%
#   Paired t-test: t=-0.7579, p=0.4907
#   Wilcoxon test: W=3.0000, p=0.6250
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_10_lost
#
# Per-method folders:
#   results_10_lost/baseline/ (10 files)
#   results_10_lost/mutual_info/ (10 files)
#   results_10_lost/rfe/ (10 files)
#   results_10_lost/lasso/ (10 files)
#   results_10_lost/meta_BAT/ (10 files)
#   results_10_lost/meta_CS/ (10 files)
#   results_10_lost/meta_DE/ (10 files)
#   results_10_lost/meta_FFA/ (10 files)
#   results_10_lost/meta_GA/ (10 files)
#   results_10_lost/meta_GWO/ (10 files)
#   results_10_lost/meta_HHO/ (10 files)
#   results_10_lost/meta_JAYA/ (10 files)
#   results_10_lost/meta_MFO/ (10 files)
#   results_10_lost/meta_MVO/ (10 files)
#   results_10_lost/meta_PSO/ (10 files)
#   results_10_lost/meta_SCA/ (10 files)
#   results_10_lost/meta_SSA/ (10 files)
#   results_10_lost/meta_WOA/ (10 files)
#
# Plots directory: results_10_lost/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 84.93% ± 3.73% (Features: 50.0%)
#   mutual_info         : 84.79% ± 4.53% (Features: 50.0%)
#   meta_DE             : 78.54% ± 5.80% (Features: 50.7%)
#   baseline            : 78.27% ± 5.05% (Features: 100.0%)
#   lasso               : 76.91% ± 2.66% (Features: 50.0%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_HHO
#     Test Accuracy:      82.87%
#     Feature Retention:  65.25% (291/446)
#     Modality Retention: depth=75.7%, sensor=55.6%, skeleton=64.5%
#
#   Fold 2: Best = meta_MFO
#     Test Accuracy:      78.42%
#     Feature Retention:  53.81% (240/446)
#     Modality Retention: depth=62.2%, sensor=44.4%, skeleton=53.2%
#
#   Fold 3: Best = meta_MVO
#     Test Accuracy:      82.27%
#     Feature Retention:  51.35% (229/446)
#     Modality Retention: depth=51.4%, sensor=44.4%, skeleton=51.5%
#
#   Fold 4: Best = meta_GWO
#     Test Accuracy:      79.09%
#     Feature Retention:  34.75% (155/446)
#     Modality Retention: depth=32.4%, sensor=22.2%, skeleton=35.2%
#
#   Fold 5: Best = meta_WOA
#     Test Accuracy:      87.88%
#     Feature Retention:  44.17% (197/446)
#     Modality Retention: depth=32.4%, sensor=22.2%, skeleton=45.8%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     82.11% ± 3.76%
#   Average Feature Retention: 49.87% ± 11.35%
#
#   Average Modality-wise Feature Retention:
#          depth: 50.81% ± 18.86%
#         sensor: 37.78% ± 14.91%
#       skeleton: 50.05% ± 10.71%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)
#     1           meta_HHO              82.87                  65.25                75.68                 55.56                   64.50
#     2           meta_MFO              78.42                  53.81                62.16                 44.44                   53.25
#     3           meta_MVO              82.27                  51.35                51.35                 44.44                   51.50
#     4           meta_GWO              79.09                  34.75                32.43                 22.22                   35.25
#     5           meta_WOA              87.88                  44.17                32.43                 22.22                   45.75
#
# Saved to: results_10_lost/best_metaheuristic_per_fold.csv
