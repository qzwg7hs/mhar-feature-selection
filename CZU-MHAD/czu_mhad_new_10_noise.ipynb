# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new_10_noise")

# Master output directory
RESULTS_ROOT = Path("results_10_noise_new")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   TOTAL: 2513

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)

        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 79.37%, F1: 78.55%, Features: 2513/2513 (100.0%), Model: 5.444MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1256/2513 (50.0%), Time: 12.1s
#     Test Acc: 82.17%, F1: 80.83%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1256/2513 (50.0%), Time: 2.5s
#     Test Acc: 83.57%, F1: 83.11%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1256/2513 (50.0%), Time: 0.5s
#     Test Acc: 68.53%, F1: 65.66%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.20347632311977717']
# ['At iteration 1 the best fitness is 0.20347632311977717']
# ['At iteration 2 the best fitness is 0.20347632311977717']
# ['At iteration 3 the best fitness is 0.1980477516912057']
# ['At iteration 4 the best fitness is 0.1980477516912057']
# ['At iteration 5 the best fitness is 0.19766971746916034']
# ['At iteration 6 the best fitness is 0.19766971746916034']
# ['At iteration 7 the best fitness is 0.197550338241146']
# ['At iteration 8 the best fitness is 0.197550338241146']
# ['At iteration 9 the best fitness is 0.197550338241146']
# ['At iteration 10 the best fitness is 0.197550338241146']
# ['At iteration 11 the best fitness is 0.197550338241146']
# ['At iteration 12 the best fitness is 0.197550338241146']
# ['At iteration 13 the best fitness is 0.197550338241146']
# ['At iteration 14 the best fitness is 0.197550338241146']
# ['At iteration 15 the best fitness is 0.19212176681257462']
# ['At iteration 16 the best fitness is 0.18669319538400314']
# ['At iteration 17 the best fitness is 0.18669319538400314']
# ['At iteration 18 the best fitness is 0.18669319538400314']
# ['At iteration 19 the best fitness is 0.18669319538400314']
# ['At iteration 20 the best fitness is 0.18669319538400314']
# ['At iteration 21 the best fitness is 0.18669319538400314']
# ['At iteration 22 the best fitness is 0.18669319538400314']
# ['At iteration 23 the best fitness is 0.18669319538400314']
# ['At iteration 24 the best fitness is 0.18669319538400314']
# ['At iteration 25 the best fitness is 0.18669319538400314']
# ['At iteration 26 the best fitness is 0.18669319538400314']
# ['At iteration 27 the best fitness is 0.17585594906486274']
# ['At iteration 28 the best fitness is 0.17585594906486274']
# ['At iteration 29 the best fitness is 0.17585594906486274']
#       Selected: 1204/2513 (47.9%), Fitness: 0.1759, Time: 538.0s
#       Modality: D=44%, S=47%, Sk=49%
#     Test Acc: 80.07%, F1: 79.88%, Features: 1204/2513 (47.9%), Model: 2.888MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.23694309590131318']
# ['At iteration 10 the best fitness is 0.20435177079188224']
# ['At iteration 20 the best fitness is 0.19971906088340627']
#       Selected: 1285/2513 (51.1%), Fitness: 0.1997, Time: 1069.0s
#       Modality: D=58%, S=50%, Sk=51%
#     Test Acc: 79.37%, F1: 79.00%, Features: 1285/2513 (51.1%), Model: 3.046MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.25257222443294863']
# ['At iteration 2 the best fitness is 0.25257222443294863']
# ['At iteration 3 the best fitness is 0.2425109430959013']
# ['At iteration 4 the best fitness is 0.23684361321130123']
# ['At iteration 5 the best fitness is 0.23049980103462']
# ['At iteration 6 the best fitness is 0.23049980103462']
# ['At iteration 7 the best fitness is 0.22487226422602463']
# ['At iteration 8 the best fitness is 0.22487226422602463']
# ['At iteration 9 the best fitness is 0.22014007162753685']
# ['At iteration 10 the best fitness is 0.21471150019896534']
# ['At iteration 11 the best fitness is 0.21471150019896534']
# ['At iteration 12 the best fitness is 0.2048889773179467']
# ['At iteration 13 the best fitness is 0.2048889773179467']
# ['At iteration 14 the best fitness is 0.2048889773179467']
# ['At iteration 15 the best fitness is 0.2048889773179467']
# ['At iteration 16 the best fitness is 0.2048889773179467']
# ['At iteration 17 the best fitness is 0.2048889773179467']
# ['At iteration 18 the best fitness is 0.2048889773179467']
# ['At iteration 19 the best fitness is 0.2048889773179467']
# ['At iteration 20 the best fitness is 0.2048889773179467']
# ['At iteration 21 the best fitness is 0.2048889773179467']
# ['At iteration 22 the best fitness is 0.2048889773179467']
# ['At iteration 23 the best fitness is 0.2048889773179467']
# ['At iteration 24 the best fitness is 0.20405332272184643']
# ['At iteration 25 the best fitness is 0.20405332272184643']
# ['At iteration 26 the best fitness is 0.20405332272184643']
# ['At iteration 27 the best fitness is 0.20405332272184643']
# ['At iteration 28 the best fitness is 0.20405332272184643']
# ['At iteration 29 the best fitness is 0.20405332272184643']
# ['At iteration 30 the best fitness is 0.20405332272184643']
#       Selected: 1251/2513 (49.8%), Fitness: 0.2041, Time: 544.0s
#       Modality: D=50%, S=47%, Sk=51%
#     Test Acc: 78.67%, F1: 77.79%, Features: 1251/2513 (49.8%), Model: 2.980MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2745451651412655']
# ['At iteration 1 the best fitness is 0.24179466772781533']
# ['At iteration 2 the best fitness is 0.24716354954237965']
# ['At iteration 3 the best fitness is 0.24684520493434145']
# ['At iteration 4 the best fitness is 0.2149104655789892']
# ['At iteration 5 the best fitness is 0.23057938718662957']
# ['At iteration 6 the best fitness is 0.22513091922005568']
# ['At iteration 7 the best fitness is 0.20924313569438915']
# ['At iteration 8 the best fitness is 0.23598806207719858']
# ['At iteration 9 the best fitness is 0.21435336251492235']
# ['At iteration 10 the best fitness is 0.23057938718662957']
# ['At iteration 11 the best fitness is 0.23051969757262242']
# ['At iteration 12 the best fitness is 0.23049980103462']
# ['At iteration 13 the best fitness is 0.2250712296060485']
# ['At iteration 14 the best fitness is 0.22517071229606045']
# ['At iteration 15 the best fitness is 0.21433346597691996']
# ['At iteration 16 the best fitness is 0.2197222443294867']
# ['At iteration 17 the best fitness is 0.20878551532033424']
# ['At iteration 18 the best fitness is 0.21431356943891758']
# ['At iteration 19 the best fitness is 0.20876561878233185']
# ['At iteration 20 the best fitness is 0.2196824512534819']
# ['At iteration 21 the best fitness is 0.23055949064862719']
# ['At iteration 22 the best fitness is 0.2359482690011938']
# ['At iteration 23 the best fitness is 0.2250712296060485']
# ['At iteration 24 the best fitness is 0.21966255471547952']
# ['At iteration 25 the best fitness is 0.2251110226820533']
# ['At iteration 26 the best fitness is 0.2250911261440509']
# ['At iteration 27 the best fitness is 0.20880541185833662']
# ['At iteration 28 the best fitness is 0.21966255471547952']
# ['At iteration 29 the best fitness is 0.23051969757262242']
#       Selected: 1219/2513 (48.5%), Fitness: 0.2305, Time: 522.8s
#       Modality: D=46%, S=51%, Sk=48%
#     Test Acc: 75.52%, F1: 74.02%, Features: 1219/2513 (48.5%), Model: 2.917MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.22658336649422997
# At iteration 2 the best fitness is 0.23185276561878237
# At iteration 3 the best fitness is 0.23807719856744927
# At iteration 4 the best fitness is 0.23730123358535615
# At iteration 5 the best fitness is 0.24239156386788696
# At iteration 6 the best fitness is 0.22081655391961802
# At iteration 7 the best fitness is 0.20474970155192998
# At iteration 8 the best fitness is 0.22612574612017505
# At iteration 9 the best fitness is 0.2318129725427776
# At iteration 10 the best fitness is 0.20989972144846794
# At iteration 11 the best fitness is 0.2098201352964584
# At iteration 12 the best fitness is 0.22065738161559892
# At iteration 13 the best fitness is 0.20980023875845602
# At iteration 14 the best fitness is 0.2098201352964584
# At iteration 15 the best fitness is 0.2311961798647036
# At iteration 16 the best fitness is 0.21562674094707515
# At iteration 17 the best fitness is 0.22568802228412252
# At iteration 18 the best fitness is 0.20985992837246317
# At iteration 19 the best fitness is 0.2098400318344608
# At iteration 20 the best fitness is 0.20437166732988463
# At iteration 21 the best fitness is 0.19882371667329882
# At iteration 22 the best fitness is 0.20978034222045364
# At iteration 23 the best fitness is 0.21502984480700355
# At iteration 24 the best fitness is 0.21522881018702741
# At iteration 25 the best fitness is 0.20993951452447274
# At iteration 26 the best fitness is 0.21538798249104651
# At iteration 27 the best fitness is 0.22049820931157982
# At iteration 28 the best fitness is 0.21514922403501785
# At iteration 29 the best fitness is 0.20433187425387983
# At iteration 30 the best fitness is 0.19872423398328687
#       Selected: 1257/2513 (50.0%), Fitness: 0.1987, Time: 523.6s
#       Modality: D=53%, S=49%, Sk=50%
#     Test Acc: 80.77%, F1: 79.92%, Features: 1257/2513 (50.0%), Model: 2.991MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2373808197373657']
# ['At iteration 1 the best fitness is 0.22471309192200553']
# ['At iteration 2 the best fitness is 0.22471309192200553']
# ['At iteration 3 the best fitness is 0.22471309192200553']
# ['At iteration 4 the best fitness is 0.19647592518901708']
# ['At iteration 5 the best fitness is 0.19647592518901708']
# ['At iteration 6 the best fitness is 0.19647592518901708']
# ['At iteration 7 the best fitness is 0.19647592518901708']
# ['At iteration 8 the best fitness is 0.19647592518901708']
# ['At iteration 9 the best fitness is 0.19647592518901708']
# ['At iteration 10 the best fitness is 0.19647592518901708']
# ['At iteration 11 the best fitness is 0.19647592518901708']
# ['At iteration 12 the best fitness is 0.19647592518901708']
# ['At iteration 13 the best fitness is 0.19647592518901708']
# ['At iteration 14 the best fitness is 0.19647592518901708']
# ['At iteration 15 the best fitness is 0.19647592518901708']
# ['At iteration 16 the best fitness is 0.19647592518901708']
# ['At iteration 17 the best fitness is 0.19647592518901708']
# ['At iteration 18 the best fitness is 0.19647592518901708']
# ['At iteration 19 the best fitness is 0.19647592518901708']
# ['At iteration 20 the best fitness is 0.195341822522881']
# ['At iteration 21 the best fitness is 0.18420612813370468']
# ['At iteration 22 the best fitness is 0.18420612813370468']
# ['At iteration 23 the best fitness is 0.18420612813370468']
# ['At iteration 24 the best fitness is 0.18420612813370468']
# ['At iteration 25 the best fitness is 0.18420612813370468']
# ['At iteration 26 the best fitness is 0.18420612813370468']
# ['At iteration 27 the best fitness is 0.18420612813370468']
# ['At iteration 28 the best fitness is 0.18420612813370468']
# ['At iteration 29 the best fitness is 0.18420612813370468']
#       Selected: 1110/2513 (44.2%), Fitness: 0.1842, Time: 503.5s
#       Modality: D=42%, S=43%, Sk=45%
#     Test Acc: 78.32%, F1: 77.69%, Features: 1110/2513 (44.2%), Model: 2.704MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.22576760843613208']
# ['At iteration 1 the best fitness is 0.22576760843613208']
# ['At iteration 2 the best fitness is 0.22576760843613208']
# ['At iteration 3 the best fitness is 0.22576760843613208']
# ['At iteration 4 the best fitness is 0.224275368085953']
# ['At iteration 5 the best fitness is 0.224275368085953']
# ['At iteration 6 the best fitness is 0.224275368085953']
# ['At iteration 7 the best fitness is 0.224275368085953']
# ['At iteration 8 the best fitness is 0.224275368085953']
# ['At iteration 9 the best fitness is 0.224275368085953']
# ['At iteration 10 the best fitness is 0.224275368085953']
# ['At iteration 11 the best fitness is 0.224275368085953']
# ['At iteration 12 the best fitness is 0.224275368085953']
# ['At iteration 13 the best fitness is 0.224275368085953']
# ['At iteration 14 the best fitness is 0.224275368085953']
# ['At iteration 15 the best fitness is 0.224275368085953']
# ['At iteration 16 the best fitness is 0.224275368085953']
# ['At iteration 17 the best fitness is 0.224275368085953']
# ['At iteration 18 the best fitness is 0.224275368085953']
# ['At iteration 19 the best fitness is 0.224275368085953']
# ['At iteration 20 the best fitness is 0.224275368085953']
# ['At iteration 21 the best fitness is 0.224275368085953']
# ['At iteration 22 the best fitness is 0.224275368085953']
# ['At iteration 23 the best fitness is 0.224275368085953']
# ['At iteration 24 the best fitness is 0.224275368085953']
# ['At iteration 25 the best fitness is 0.224275368085953']
# ['At iteration 26 the best fitness is 0.224275368085953']
# ['At iteration 27 the best fitness is 0.224275368085953']
# ['At iteration 28 the best fitness is 0.224275368085953']
# ['At iteration 29 the best fitness is 0.224275368085953']
#       Selected: 1175/2513 (46.8%), Fitness: 0.2243, Time: 696.6s
#       Modality: D=46%, S=46%, Sk=47%
#     Test Acc: 80.07%, F1: 79.29%, Features: 1175/2513 (46.8%), Model: 2.831MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.24195384003183443']
# ['At iteration 1 the best fitness is 0.232091524074811']
# ['At iteration 2 the best fitness is 0.23159411062475133']
# ['At iteration 3 the best fitness is 0.21542777556705128']
# ['At iteration 4 the best fitness is 0.21542777556705128']
# ['At iteration 5 the best fitness is 0.21542777556705128']
# ['At iteration 6 the best fitness is 0.21542777556705128']
# ['At iteration 7 the best fitness is 0.21542777556705128']
# ['At iteration 8 the best fitness is 0.21542777556705128']
# ['At iteration 9 the best fitness is 0.21542777556705128']
# ['At iteration 10 the best fitness is 0.21542777556705128']
# ['At iteration 11 the best fitness is 0.21516912057302023']
# ['At iteration 12 the best fitness is 0.21516912057302023']
# ['At iteration 13 the best fitness is 0.21516912057302023']
# ['At iteration 14 the best fitness is 0.21516912057302023']
# ['At iteration 15 the best fitness is 0.21516912057302023']
# ['At iteration 16 the best fitness is 0.20960127337843215']
# ['At iteration 17 the best fitness is 0.20944210107441302']
# ['At iteration 18 the best fitness is 0.20944210107441302']
# ['At iteration 19 the best fitness is 0.20944210107441302']
# ['At iteration 20 the best fitness is 0.20944210107441302']
# ['At iteration 21 the best fitness is 0.20944210107441302']
# ['At iteration 22 the best fitness is 0.20944210107441302']
# ['At iteration 23 the best fitness is 0.20944210107441302']
# ['At iteration 24 the best fitness is 0.20944210107441302']
# ['At iteration 25 the best fitness is 0.20944210107441302']
# ['At iteration 26 the best fitness is 0.20465021886191803']
# ['At iteration 27 the best fitness is 0.20465021886191803']
# ['At iteration 28 the best fitness is 0.20465021886191803']
# ['At iteration 29 the best fitness is 0.20465021886191803']
#       Selected: 1260/2513 (50.1%), Fitness: 0.2047, Time: 544.5s
#       Modality: D=52%, S=47%, Sk=51%
#     Test Acc: 77.97%, F1: 76.28%, Features: 1260/2513 (50.1%), Model: 2.997MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2523135694389176']
# ['At iteration 2 the best fitness is 0.24799920413847992']
# ['At iteration 3 the best fitness is 0.23123597294070836']
# ['At iteration 4 the best fitness is 0.21504974134500593']
# ['At iteration 5 the best fitness is 0.21504974134500593']
# ['At iteration 6 the best fitness is 0.21504974134500593']
# ['At iteration 7 the best fitness is 0.21504974134500593']
# ['At iteration 8 the best fitness is 0.21504974134500593']
# ['At iteration 9 the best fitness is 0.21504974134500593']
# ['At iteration 10 the best fitness is 0.21504974134500593']
# ['At iteration 11 the best fitness is 0.21504974134500593']
# ['At iteration 12 the best fitness is 0.21504974134500593']
# ['At iteration 13 the best fitness is 0.21504974134500593']
# ['At iteration 14 the best fitness is 0.21504974134500593']
# ['At iteration 15 the best fitness is 0.21504974134500593']
# ['At iteration 16 the best fitness is 0.2058440111420613']
# ['At iteration 17 the best fitness is 0.2042323915638679']
# ['At iteration 18 the best fitness is 0.2042323915638679']
# ['At iteration 19 the best fitness is 0.2042323915638679']
# ['At iteration 20 the best fitness is 0.2042323915638679']
# ['At iteration 21 the best fitness is 0.2042323915638679']
# ['At iteration 22 the best fitness is 0.2042323915638679']
# ['At iteration 23 the best fitness is 0.1883446080382013']
# ['At iteration 24 the best fitness is 0.1883446080382013']
# ['At iteration 25 the best fitness is 0.1883446080382013']
# ['At iteration 26 the best fitness is 0.1883446080382013']
# ['At iteration 27 the best fitness is 0.1883446080382013']
# ['At iteration 28 the best fitness is 0.1883446080382013']
# ['At iteration 29 the best fitness is 0.1883446080382013']
#       Selected: 1276/2513 (50.8%), Fitness: 0.1883, Time: 514.6s
#       Modality: D=50%, S=50%, Sk=51%
#     Test Acc: 82.52%, F1: 82.27%, Features: 1276/2513 (50.8%), Model: 3.028MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.24129725427775564']
# ['At iteration 2 the best fitness is 0.24129725427775564']
# ['At iteration 3 the best fitness is 0.24129725427775564']
# ['At iteration 4 the best fitness is 0.24129725427775564']
# ['At iteration 5 the best fitness is 0.24129725427775564']
# ['At iteration 6 the best fitness is 0.24129725427775564']
# ['At iteration 7 the best fitness is 0.24129725427775564']
# ['At iteration 8 the best fitness is 0.23610744130521288']
# ['At iteration 9 the best fitness is 0.2360875447672105']
# ['At iteration 10 the best fitness is 0.22497174691603658']
# ['At iteration 11 the best fitness is 0.22497174691603658']
# ['At iteration 12 the best fitness is 0.22497174691603658']
# ['At iteration 13 the best fitness is 0.22497174691603658']
# ['At iteration 14 the best fitness is 0.22497174691603658']
# ['At iteration 15 the best fitness is 0.22497174691603658']
# ['At iteration 16 the best fitness is 0.22497174691603658']
# ['At iteration 17 the best fitness is 0.22497174691603658']
# ['At iteration 18 the best fitness is 0.22497174691603658']
# ['At iteration 19 the best fitness is 0.22497174691603658']
# ['At iteration 20 the best fitness is 0.22489216076402702']
# ['At iteration 21 the best fitness is 0.20842737763629127']
# ['At iteration 22 the best fitness is 0.20842737763629127']
# ['At iteration 23 the best fitness is 0.20842737763629127']
# ['At iteration 24 the best fitness is 0.20842737763629127']
# ['At iteration 25 the best fitness is 0.20842737763629127']
# ['At iteration 26 the best fitness is 0.20842737763629127']
# ['At iteration 27 the best fitness is 0.20842737763629127']
# ['At iteration 28 the best fitness is 0.20842737763629127']
# ['At iteration 29 the best fitness is 0.20842737763629127']
# ['At iteration 30 the best fitness is 0.20842737763629127']
#       Selected: 1220/2513 (48.5%), Fitness: 0.2084, Time: 524.1s
#       Modality: D=51%, S=48%, Sk=48%
#     Test Acc: 78.67%, F1: 77.16%, Features: 1220/2513 (48.5%), Model: 2.919MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.25233346597691997']
# ['At iteration 2 the best fitness is 0.22469319538400315']
# ['At iteration 3 the best fitness is 0.22469319538400315']
# ['At iteration 4 the best fitness is 0.2142538798249104']
# ['At iteration 5 the best fitness is 0.2142538798249104']
# ['At iteration 6 the best fitness is 0.2142538798249104']
# ['At iteration 7 the best fitness is 0.20856665340230798']
# ['At iteration 8 the best fitness is 0.2033967369677676']
# ['At iteration 9 the best fitness is 0.2033967369677676']
# ['At iteration 10 the best fitness is 0.2033967369677676']
# ['At iteration 11 the best fitness is 0.2033967369677676']
# ['At iteration 12 the best fitness is 0.2033967369677676']
# ['At iteration 13 the best fitness is 0.2033967369677676']
# ['At iteration 14 the best fitness is 0.2033967369677676']
# ['At iteration 15 the best fitness is 0.2033967369677676']
# ['At iteration 16 the best fitness is 0.2033967369677676']
# ['At iteration 17 the best fitness is 0.2033967369677676']
# ['At iteration 18 the best fitness is 0.2033967369677676']
# ['At iteration 19 the best fitness is 0.2033967369677676']
# ['At iteration 20 the best fitness is 0.2033967369677676']
# ['At iteration 21 the best fitness is 0.2033967369677676']
# ['At iteration 22 the best fitness is 0.2033967369677676']
# ['At iteration 23 the best fitness is 0.2033967369677676']
# ['At iteration 24 the best fitness is 0.2033967369677676']
# ['At iteration 25 the best fitness is 0.2033967369677676']
# ['At iteration 26 the best fitness is 0.2033967369677676']
# ['At iteration 27 the best fitness is 0.2033967369677676']
# ['At iteration 28 the best fitness is 0.2033967369677676']
# ['At iteration 29 the best fitness is 0.2033967369677676']
# ['At iteration 30 the best fitness is 0.2033967369677676']
#       Selected: 1199/2513 (47.7%), Fitness: 0.2034, Time: 518.3s
#       Modality: D=52%, S=49%, Sk=47%
#     Test Acc: 79.02%, F1: 78.71%, Features: 1199/2513 (47.7%), Model: 2.878MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2416951850378034']
# ['At iteration 1 the best fitness is 0.2416951850378034']
# ['At iteration 2 the best fitness is 0.2416951850378034']
# ['At iteration 3 the best fitness is 0.2384520493434142']
# ['At iteration 4 the best fitness is 0.22103223239156383']
# ['At iteration 5 the best fitness is 0.22103223239156383']
# ['At iteration 6 the best fitness is 0.20661360923199357']
# ['At iteration 7 the best fitness is 0.20661360923199357']
# ['At iteration 8 the best fitness is 0.20661360923199357']
# ['At iteration 9 the best fitness is 0.20661360923199357']
# ['At iteration 10 the best fitness is 0.20661360923199357']
# ['At iteration 11 the best fitness is 0.20661360923199357']
# ['At iteration 12 the best fitness is 0.20661360923199357']
# ['At iteration 13 the best fitness is 0.20661360923199357']
# ['At iteration 14 the best fitness is 0.20661360923199357']
# ['At iteration 15 the best fitness is 0.20661360923199357']
# ['At iteration 16 the best fitness is 0.20661360923199357']
# ['At iteration 17 the best fitness is 0.20661360923199357']
# ['At iteration 18 the best fitness is 0.20661360923199357']
# ['At iteration 19 the best fitness is 0.20661360923199357']
# ['At iteration 20 the best fitness is 0.20661360923199357']
# ['At iteration 21 the best fitness is 0.20661360923199357']
# ['At iteration 22 the best fitness is 0.20661360923199357']
# ['At iteration 23 the best fitness is 0.20661360923199357']
# ['At iteration 24 the best fitness is 0.20661360923199357']
# ['At iteration 25 the best fitness is 0.20661360923199357']
# ['At iteration 26 the best fitness is 0.20661360923199357']
# ['At iteration 27 the best fitness is 0.20661360923199357']
# ['At iteration 28 the best fitness is 0.20661360923199357']
# ['At iteration 29 the best fitness is 0.19601193792280142']
#       Selected: 606/2513 (24.1%), Fitness: 0.1960, Time: 501.4s
#       Modality: D=24%, S=23%, Sk=25%
#     Test Acc: 78.67%, F1: 77.78%, Features: 606/2513 (24.1%), Model: 1.720MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2311364902506964']
# ['At iteration 2 the best fitness is 0.2311364902506964']
# ['At iteration 3 the best fitness is 0.2311364902506964']
# ['At iteration 4 the best fitness is 0.2311364902506964']
# ['At iteration 5 the best fitness is 0.23061918026263434']
# ['At iteration 6 the best fitness is 0.20970075606844407']
# ['At iteration 7 the best fitness is 0.19415121368881816']
# ['At iteration 8 the best fitness is 0.19415121368881816']
# ['At iteration 9 the best fitness is 0.19415121368881816']
# ['At iteration 10 the best fitness is 0.19415121368881816']
# ['At iteration 11 the best fitness is 0.19415121368881816']
# ['At iteration 12 the best fitness is 0.19415121368881816']
# ['At iteration 13 the best fitness is 0.19415121368881816']
# ['At iteration 14 the best fitness is 0.19415121368881816']
# ['At iteration 15 the best fitness is 0.19415121368881816']
# ['At iteration 16 the best fitness is 0.19415121368881816']
# ['At iteration 17 the best fitness is 0.19415121368881816']
# ['At iteration 18 the best fitness is 0.19415121368881816']
# ['At iteration 19 the best fitness is 0.19415121368881816']
# ['At iteration 20 the best fitness is 0.19415121368881816']
# ['At iteration 21 the best fitness is 0.19415121368881816']
# ['At iteration 22 the best fitness is 0.19415121368881816']
# ['At iteration 23 the best fitness is 0.19415121368881816']
# ['At iteration 24 the best fitness is 0.19415121368881816']
# ['At iteration 25 the best fitness is 0.19415121368881816']
# ['At iteration 26 the best fitness is 0.19415121368881816']
# ['At iteration 27 the best fitness is 0.19415121368881816']
# ['At iteration 28 the best fitness is 0.19415121368881816']
# ['At iteration 29 the best fitness is 0.19415121368881816']
#       Selected: 1293/2513 (51.5%), Fitness: 0.1942, Time: 1318.5s
#       Modality: D=51%, S=50%, Sk=52%
#     Test Acc: 77.97%, F1: 77.39%, Features: 1293/2513 (51.5%), Model: 3.062MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.24644727417429368']
# ['At iteration 1 the best fitness is 0.24644727417429368']
# ['At iteration 2 the best fitness is 0.24644727417429368']
# ['At iteration 3 the best fitness is 0.24598647035415835']
# ['At iteration 4 the best fitness is 0.2274755272582571']
# ['At iteration 5 the best fitness is 0.22057461201750891']
# ['At iteration 6 the best fitness is 0.22057461201750891']
# ['At iteration 7 the best fitness is 0.20699164345403895']
# ['At iteration 8 the best fitness is 0.20699164345403895']
# ['At iteration 9 the best fitness is 0.20699164345403895']
# ['At iteration 10 the best fitness is 0.20699164345403895']
# ['At iteration 11 the best fitness is 0.20699164345403895']
# ['At iteration 12 the best fitness is 0.20699164345403895']
# ['At iteration 13 the best fitness is 0.20699164345403895']
# ['At iteration 14 the best fitness is 0.20699164345403895']
# ['At iteration 15 the best fitness is 0.20699164345403895']
# ['At iteration 16 the best fitness is 0.20699164345403895']
# ['At iteration 17 the best fitness is 0.20699164345403895']
# ['At iteration 18 the best fitness is 0.20699164345403895']
# ['At iteration 19 the best fitness is 0.20699164345403895']
# ['At iteration 20 the best fitness is 0.20699164345403895']
# ['At iteration 21 the best fitness is 0.20699164345403895']
# ['At iteration 22 the best fitness is 0.20699164345403895']
# ['At iteration 23 the best fitness is 0.20699164345403895']
# ['At iteration 24 the best fitness is 0.20699164345403895']
# ['At iteration 25 the best fitness is 0.20699164345403895']
# ['At iteration 26 the best fitness is 0.20699164345403895']
# ['At iteration 27 the best fitness is 0.20699164345403895']
# ['At iteration 28 the best fitness is 0.20699164345403895']
# ['At iteration 29 the best fitness is 0.20669319538400313']
#       Selected: 885/2513 (35.2%), Fitness: 0.2067, Time: 499.8s
#       Modality: D=37%, S=35%, Sk=35%
#     Test Acc: 74.83%, F1: 72.87%, Features: 885/2513 (35.2%), Model: 2.265MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 63.07%, F1: 62.36%, Features: 2513/2513 (100.0%), Model: 5.444MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1256/2513 (50.0%), Time: 12.3s
#     Test Acc: 70.54%, F1: 71.04%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1256/2513 (50.0%), Time: 2.5s
#     Test Acc: 63.49%, F1: 63.58%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1256/2513 (50.0%), Time: 0.5s
#     Test Acc: 54.77%, F1: 55.46%, Features: 1256/2513 (50.0%), Model: 2.989MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1797420803128081']
# ['At iteration 1 the best fitness is 0.1794237357047699']
# ['At iteration 2 the best fitness is 0.1794237357047699']
# ['At iteration 3 the best fitness is 0.1794237357047699']
# ['At iteration 4 the best fitness is 0.1794237357047699']
# ['At iteration 5 the best fitness is 0.1794237357047699']
# ['At iteration 6 the best fitness is 0.1794237357047699']
# ['At iteration 7 the best fitness is 0.1794237357047699']
# ['At iteration 8 the best fitness is 0.1794237357047699']
# ['At iteration 9 the best fitness is 0.1794237357047699']
# ['At iteration 10 the best fitness is 0.17424079568850676']
# ['At iteration 11 the best fitness is 0.17424079568850676']
# ['At iteration 12 the best fitness is 0.17424079568850676']
# ['At iteration 13 the best fitness is 0.17424079568850676']
# ['At iteration 14 the best fitness is 0.17424079568850676']
# ['At iteration 15 the best fitness is 0.16907775221024585']
# ['At iteration 16 the best fitness is 0.16907775221024585']
# ['At iteration 17 the best fitness is 0.16907775221024585']
# ['At iteration 18 the best fitness is 0.16907775221024585']
# ['At iteration 19 the best fitness is 0.16907775221024585']
# ['At iteration 20 the best fitness is 0.15358862177546329']
# ['At iteration 21 the best fitness is 0.15358862177546329']
# ['At iteration 22 the best fitness is 0.15358862177546329']
# ['At iteration 23 the best fitness is 0.15358862177546329']
# ['At iteration 24 the best fitness is 0.15358862177546329']
# ['At iteration 25 the best fitness is 0.15358862177546329']
# ['At iteration 26 the best fitness is 0.15358862177546329']
# ['At iteration 27 the best fitness is 0.15358862177546329']
# ['At iteration 28 the best fitness is 0.15358862177546329']
# ['At iteration 29 the best fitness is 0.15358862177546329']
#       Selected: 1222/2513 (48.6%), Fitness: 0.1536, Time: 584.7s
#       Modality: D=46%, S=47%, Sk=50%
#     Test Acc: 64.73%, F1: 64.42%, Features: 1222/2513 (48.6%), Model: 2.923MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.20561698731811964']
# ['At iteration 10 the best fitness is 0.18472605494904754']
# ['At iteration 20 the best fitness is 0.16921702797626256']
#       Selected: 1254/2513 (49.9%), Fitness: 0.1692, Time: 1140.7s
#       Modality: D=52%, S=48%, Sk=51%
#     Test Acc: 63.07%, F1: 62.16%, Features: 1254/2513 (49.9%), Model: 2.985MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2000958061558159']
# ['At iteration 2 the best fitness is 0.2000958061558159']
# ['At iteration 3 the best fitness is 0.2000958061558159']
# ['At iteration 4 the best fitness is 0.1909038218654302']
# ['At iteration 5 the best fitness is 0.19016764995934185']
# ['At iteration 6 the best fitness is 0.19016764995934185']
# ['At iteration 7 the best fitness is 0.19002837419332513']
# ['At iteration 8 the best fitness is 0.19002837419332513']
# ['At iteration 9 the best fitness is 0.19002837419332513']
# ['At iteration 10 the best fitness is 0.19002837419332513']
# ['At iteration 11 the best fitness is 0.19002837419332513']
# ['At iteration 12 the best fitness is 0.18520357186110484']
# ['At iteration 13 the best fitness is 0.18520357186110484']
# ['At iteration 14 the best fitness is 0.18520357186110484']
# ['At iteration 15 the best fitness is 0.18520357186110484']
# ['At iteration 16 the best fitness is 0.18061752798491318']
# ['At iteration 17 the best fitness is 0.16975423450232702']
# ['At iteration 18 the best fitness is 0.16975423450232702']
# ['At iteration 19 the best fitness is 0.16877930414021003']
# ['At iteration 20 the best fitness is 0.16877930414021003']
# ['At iteration 21 the best fitness is 0.16877930414021003']
# ['At iteration 22 the best fitness is 0.16877930414021003']
# ['At iteration 23 the best fitness is 0.16877930414021003']
# ['At iteration 24 the best fitness is 0.16877930414021003']
# ['At iteration 25 the best fitness is 0.16877930414021003']
# ['At iteration 26 the best fitness is 0.16877930414021003']
# ['At iteration 27 the best fitness is 0.16877930414021003']
# ['At iteration 28 the best fitness is 0.16877930414021003']
# ['At iteration 29 the best fitness is 0.16877930414021003']
# ['At iteration 30 the best fitness is 0.16877930414021003']
#       Selected: 1233/2513 (49.1%), Fitness: 0.1688, Time: 578.0s
#       Modality: D=45%, S=49%, Sk=50%
#     Test Acc: 61.00%, F1: 61.87%, Features: 1233/2513 (49.1%), Model: 2.944MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.19531079689960035']
# ['At iteration 1 the best fitness is 0.18504439955708574']
# ['At iteration 2 the best fitness is 0.20507978079205516']
# ['At iteration 3 the best fitness is 0.2110187892524092']
# ['At iteration 4 the best fitness is 0.20537822886209098']
# ['At iteration 5 the best fitness is 0.19979735808578009']
# ['At iteration 6 the best fitness is 0.1686997179882005']
# ['At iteration 7 the best fitness is 0.19467410768352394']
# ['At iteration 8 the best fitness is 0.18933199536324158']
# ['At iteration 9 the best fitness is 0.1841689518849807']
# ['At iteration 10 the best fitness is 0.18907334036921053']
# ['At iteration 11 the best fitness is 0.19411700461945708']
# ['At iteration 12 the best fitness is 0.17890642571670784']
# ['At iteration 13 the best fitness is 0.17380307185245425']
# ['At iteration 14 the best fitness is 0.18410926227097352']
# ['At iteration 15 the best fitness is 0.1892922022872368']
# ['At iteration 16 the best fitness is 0.18939168497724873']
# ['At iteration 17 the best fitness is 0.18937178843924635']
# ['At iteration 18 the best fitness is 0.19449503884150246']
# ['At iteration 19 the best fitness is 0.16865992491219572']
# ['At iteration 20 the best fitness is 0.19961828924375857']
# ['At iteration 21 the best fitness is 0.17384286492845902']
# ['At iteration 22 the best fitness is 0.1841689518849807']
# ['At iteration 23 the best fitness is 0.18933199536324158']
# ['At iteration 24 the best fitness is 0.18933199536324158']
# ['At iteration 25 the best fitness is 0.18933199536324158']
# ['At iteration 26 the best fitness is 0.1790059084067198']
# ['At iteration 27 the best fitness is 0.17384286492845902']
# ['At iteration 28 the best fitness is 0.19449503884150246']
# ['At iteration 29 the best fitness is 0.18933199536324158']
#       Selected: 1246/2513 (49.6%), Fitness: 0.1893, Time: 558.8s
#       Modality: D=56%, S=49%, Sk=49%
#     Test Acc: 62.66%, F1: 61.85%, Features: 1246/2513 (49.6%), Model: 2.970MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.2051792634820671
# At iteration 2 the best fitness is 0.18518367532310245
# At iteration 3 the best fitness is 0.19961828924375857
# At iteration 4 the best fitness is 0.194574624993512
# At iteration 5 the best fitness is 0.19451493537950484
# At iteration 6 the best fitness is 0.19507203844357168
# At iteration 7 the best fitness is 0.20466195349400504
# At iteration 8 the best fitness is 0.19479348691153825
# At iteration 9 the best fitness is 0.17438007145452347
# At iteration 10 the best fitness is 0.18915292652122007
# At iteration 11 the best fitness is 0.18951106420526306
# At iteration 12 the best fitness is 0.19433586653748336
# At iteration 13 the best fitness is 0.19967797885776575
# At iteration 14 the best fitness is 0.18935189190124396
# At iteration 15 the best fitness is 0.19465421114552156
# At iteration 16 the best fitness is 0.18404957265696636
# At iteration 17 the best fitness is 0.18935189190124396
# At iteration 18 the best fitness is 0.1792844599387532
# At iteration 19 the best fitness is 0.1787870464886935
# At iteration 20 the best fitness is 0.18434802072700218
# At iteration 21 the best fitness is 0.18941158151525112
# At iteration 22 the best fitness is 0.184646468797038
# At iteration 23 the best fitness is 0.19465421114552156
# At iteration 24 the best fitness is 0.1791650807107389
# At iteration 25 the best fitness is 0.1791053910967317
# At iteration 26 the best fitness is 0.19459452153151438
# At iteration 27 the best fitness is 0.1738627614664614
# At iteration 28 the best fitness is 0.17414131299849483
# At iteration 29 the best fitness is 0.1896304434332774
# At iteration 30 the best fitness is 0.1790059084067198
#       Selected: 1222/2513 (48.6%), Fitness: 0.1790, Time: 554.3s
#       Modality: D=48%, S=47%, Sk=49%
#     Test Acc: 59.75%, F1: 59.98%, Features: 1222/2513 (48.6%), Model: 2.923MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.21628131542068202']
# ['At iteration 1 the best fitness is 0.20978520389626115']
# ['At iteration 2 the best fitness is 0.1934604188653783']
# ['At iteration 3 the best fitness is 0.1934604188653783']
# ['At iteration 4 the best fitness is 0.1665906849599474']
# ['At iteration 5 the best fitness is 0.1665906849599474']
# ['At iteration 6 the best fitness is 0.1665906849599474']
# ['At iteration 7 the best fitness is 0.1665906849599474']
# ['At iteration 8 the best fitness is 0.1665906849599474']
# ['At iteration 9 the best fitness is 0.1665906849599474']
# ['At iteration 10 the best fitness is 0.1665906849599474']
# ['At iteration 11 the best fitness is 0.16507854807176595']
# ['At iteration 12 the best fitness is 0.16507854807176595']
# ['At iteration 13 the best fitness is 0.16507854807176595']
# ['At iteration 14 the best fitness is 0.16507854807176595']
# ['At iteration 15 the best fitness is 0.16507854807176595']
# ['At iteration 16 the best fitness is 0.16507854807176595']
# ['At iteration 17 the best fitness is 0.16507854807176595']
# ['At iteration 18 the best fitness is 0.16507854807176595']
# ['At iteration 19 the best fitness is 0.16507854807176595']
# ['At iteration 20 the best fitness is 0.16507854807176595']
# ['At iteration 21 the best fitness is 0.16507854807176595']
# ['At iteration 22 the best fitness is 0.16507854807176595']
# ['At iteration 23 the best fitness is 0.16507854807176595']
# ['At iteration 24 the best fitness is 0.16507854807176595']
# ['At iteration 25 the best fitness is 0.16507854807176595']
# ['At iteration 26 the best fitness is 0.16507854807176595']
# ['At iteration 27 the best fitness is 0.16507854807176595']
# ['At iteration 28 the best fitness is 0.16507854807176595']
# ['At iteration 29 the best fitness is 0.16507854807176595']
#       Selected: 1068/2513 (42.5%), Fitness: 0.1651, Time: 547.6s
#       Modality: D=40%, S=44%, Sk=42%
#     Test Acc: 67.22%, F1: 66.72%, Features: 1068/2513 (42.5%), Model: 2.622MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.2166195565667226']
# ['At iteration 1 the best fitness is 0.20885006661014893']
# ['At iteration 2 the best fitness is 0.18819789269710546']
# ['At iteration 3 the best fitness is 0.18819789269710546']
# ['At iteration 4 the best fitness is 0.18819789269710546']
# ['At iteration 5 the best fitness is 0.18819789269710546']
# ['At iteration 6 the best fitness is 0.18819789269710546']
# ['At iteration 7 the best fitness is 0.18819789269710546']
# ['At iteration 8 the best fitness is 0.18819789269710546']
# ['At iteration 9 the best fitness is 0.18819789269710546']
# ['At iteration 10 the best fitness is 0.18147286285229847']
# ['At iteration 11 the best fitness is 0.18147286285229847']
# ['At iteration 12 the best fitness is 0.18147286285229847']
# ['At iteration 13 the best fitness is 0.18147286285229847']
# ['At iteration 14 the best fitness is 0.18147286285229847']
# ['At iteration 15 the best fitness is 0.18147286285229847']
# ['At iteration 16 the best fitness is 0.18147286285229847']
# ['At iteration 17 the best fitness is 0.18147286285229847']
# ['At iteration 18 the best fitness is 0.18147286285229847']
# ['At iteration 19 the best fitness is 0.18147286285229847']
# ['At iteration 20 the best fitness is 0.18147286285229847']
# ['At iteration 21 the best fitness is 0.18147286285229847']
# ['At iteration 22 the best fitness is 0.18147286285229847']
# ['At iteration 23 the best fitness is 0.18147286285229847']
# ['At iteration 24 the best fitness is 0.17913512777037663']
# ['At iteration 25 the best fitness is 0.17913512777037663']
# ['At iteration 26 the best fitness is 0.17913512777037663']
# ['At iteration 27 the best fitness is 0.17913512777037663']
# ['At iteration 28 the best fitness is 0.17913512777037663']
# ['At iteration 29 the best fitness is 0.17913512777037663']
#       Selected: 966/2513 (38.4%), Fitness: 0.1791, Time: 726.7s
#       Modality: D=44%, S=37%, Sk=38%
#     Test Acc: 59.34%, F1: 59.67%, Features: 966/2513 (38.4%), Model: 2.423MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.20492060848803606']
# ['At iteration 1 the best fitness is 0.1897498226612917']
# ['At iteration 2 the best fitness is 0.1897498226612917']
# ['At iteration 3 the best fitness is 0.1897498226612917']
# ['At iteration 4 the best fitness is 0.1897498226612917']
# ['At iteration 5 the best fitness is 0.1897498226612917']
# ['At iteration 6 the best fitness is 0.1897498226612917']
# ['At iteration 7 the best fitness is 0.1897498226612917']
# ['At iteration 8 the best fitness is 0.18498470994307858']
# ['At iteration 9 the best fitness is 0.18498470994307858']
# ['At iteration 10 the best fitness is 0.18498470994307858']
# ['At iteration 11 the best fitness is 0.18498470994307858']
# ['At iteration 12 the best fitness is 0.18498470994307858']
# ['At iteration 13 the best fitness is 0.18442760687901172']
# ['At iteration 14 the best fitness is 0.18442760687901172']
# ['At iteration 15 the best fitness is 0.18442760687901172']
# ['At iteration 16 the best fitness is 0.18442760687901172']
# ['At iteration 17 the best fitness is 0.18442760687901172']
# ['At iteration 18 the best fitness is 0.18442760687901172']
# ['At iteration 19 the best fitness is 0.18442760687901172']
# ['At iteration 20 the best fitness is 0.18442760687901172']
# ['At iteration 21 the best fitness is 0.18442760687901172']
# ['At iteration 22 the best fitness is 0.18442760687901172']
# ['At iteration 23 the best fitness is 0.18442760687901172']
# ['At iteration 24 the best fitness is 0.18442760687901172']
# ['At iteration 25 the best fitness is 0.18442760687901172']
# ['At iteration 26 the best fitness is 0.18442760687901172']
# ['At iteration 27 the best fitness is 0.18442760687901172']
# ['At iteration 28 the best fitness is 0.18442760687901172']
# ['At iteration 29 the best fitness is 0.18442760687901172']
#       Selected: 1244/2513 (49.5%), Fitness: 0.1844, Time: 581.5s
#       Modality: D=43%, S=50%, Sk=50%
#     Test Acc: 60.17%, F1: 60.33%, Features: 1244/2513 (49.5%), Model: 2.966MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.22120560044291424']
# ['At iteration 2 the best fitness is 0.2059751250021626']
# ['At iteration 3 the best fitness is 0.19660407186975554']
# ['At iteration 4 the best fitness is 0.17982166646481768']
# ['At iteration 5 the best fitness is 0.17982166646481768']
# ['At iteration 6 the best fitness is 0.17469841606256167']
# ['At iteration 7 the best fitness is 0.17469841606256167']
# ['At iteration 8 the best fitness is 0.17469841606256167']
# ['At iteration 9 the best fitness is 0.17469841606256167']
# ['At iteration 10 the best fitness is 0.17469841606256167']
# ['At iteration 11 the best fitness is 0.17469841606256167']
# ['At iteration 12 the best fitness is 0.17469841606256167']
# ['At iteration 13 the best fitness is 0.17469841606256167']
# ['At iteration 14 the best fitness is 0.169495579508296']
# ['At iteration 15 the best fitness is 0.169495579508296']
# ['At iteration 16 the best fitness is 0.169495579508296']
# ['At iteration 17 the best fitness is 0.169495579508296']
# ['At iteration 18 the best fitness is 0.169495579508296']
# ['At iteration 19 the best fitness is 0.169495579508296']
# ['At iteration 20 the best fitness is 0.169495579508296']
# ['At iteration 21 the best fitness is 0.169495579508296']
# ['At iteration 22 the best fitness is 0.169495579508296']
# ['At iteration 23 the best fitness is 0.169495579508296']
# ['At iteration 24 the best fitness is 0.169495579508296']
# ['At iteration 25 the best fitness is 0.1643524325680375']
# ['At iteration 26 the best fitness is 0.1643524325680375']
# ['At iteration 27 the best fitness is 0.1643524325680375']
# ['At iteration 28 the best fitness is 0.1643524325680375']
# ['At iteration 29 the best fitness is 0.1643524325680375']
#       Selected: 1282/2513 (51.0%), Fitness: 0.1644, Time: 546.2s
#       Modality: D=50%, S=48%, Sk=52%
#     Test Acc: 63.49%, F1: 63.66%, Features: 1282/2513 (51.0%), Model: 3.040MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.19028702918735618']
# ['At iteration 2 the best fitness is 0.19028702918735618']
# ['At iteration 3 the best fitness is 0.19028702918735618']
# ['At iteration 4 the best fitness is 0.19028702918735618']
# ['At iteration 5 the best fitness is 0.18466636533504038']
# ['At iteration 6 the best fitness is 0.18466636533504038']
# ['At iteration 7 the best fitness is 0.18466636533504038']
# ['At iteration 8 the best fitness is 0.18424853803699023']
# ['At iteration 9 the best fitness is 0.18424853803699023']
# ['At iteration 10 the best fitness is 0.18424853803699023']
# ['At iteration 11 the best fitness is 0.18424853803699023']
# ['At iteration 12 the best fitness is 0.18424853803699023']
# ['At iteration 13 the best fitness is 0.18424853803699023']
# ['At iteration 14 the best fitness is 0.18424853803699023']
# ['At iteration 15 the best fitness is 0.18424853803699023']
# ['At iteration 16 the best fitness is 0.17966249416079857']
# ['At iteration 17 the best fitness is 0.17966249416079857']
# ['At iteration 18 the best fitness is 0.17966249416079857']
# ['At iteration 19 the best fitness is 0.17966249416079857']
# ['At iteration 20 the best fitness is 0.17966249416079857']
# ['At iteration 21 the best fitness is 0.17966249416079857']
# ...
# ['At iteration 12 the best fitness is 0.22372378656890907']
# ['At iteration 13 the best fitness is 0.22372378656890907']
# ['At iteration 14 the best fitness is 0.22372378656890907']
# ['At iteration 15 the best fitness is 0.22372378656890907']
# ['At iteration 16 the best fitness is 0.22372378656890907']
# ['At iteration 17 the best fitness is 0.20403466739792456']
# ['At iteration 18 the best fitness is 0.20403466739792456']
# ['At iteration 19 the best fitness is 0.20403466739792456']
# ['At iteration 20 the best fitness is 0.20403466739792456']
# ['At iteration 21 the best fitness is 0.20403466739792456']
# ['At iteration 22 the best fitness is 0.20403466739792456']
# ['At iteration 23 the best fitness is 0.20403466739792456']
# ['At iteration 24 the best fitness is 0.20403466739792456']
# ['At iteration 25 the best fitness is 0.20403466739792456']
# ['At iteration 26 the best fitness is 0.20403466739792456']
# ['At iteration 27 the best fitness is 0.20403466739792456']
# ['At iteration 28 the best fitness is 0.20403466739792456']
# ['At iteration 29 the best fitness is 0.20403466739792456']
#       Selected: 1602/2513 (63.7%), Fitness: 0.2040, Time: 785.0s
#       Modality: D=63%, S=66%, Sk=63%
#     Test Acc: 72.73%, F1: 72.72%, Features: 1602/2513 (63.7%), Model: 3.665MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.22134403691477886']
# ['At iteration 1 the best fitness is 0.21622279174200892']
# ['At iteration 2 the best fitness is 0.20205284850384217']
# ['At iteration 3 the best fitness is 0.20205284850384217']
# ['At iteration 4 the best fitness is 0.20205284850384217']
# ['At iteration 5 the best fitness is 0.20205284850384217']
# ['At iteration 6 the best fitness is 0.20205284850384217']
# ['At iteration 7 the best fitness is 0.20205284850384217']
# ['At iteration 8 the best fitness is 0.20205284850384217']
# ['At iteration 9 the best fitness is 0.20205284850384217']
# ['At iteration 10 the best fitness is 0.20205284850384217']
# ['At iteration 11 the best fitness is 0.20205284850384217']
# ['At iteration 12 the best fitness is 0.20205284850384217']
# ['At iteration 13 the best fitness is 0.20205284850384217']
# ['At iteration 14 the best fitness is 0.20205284850384217']
# ['At iteration 15 the best fitness is 0.20205284850384217']
# ['At iteration 16 the best fitness is 0.20205284850384217']
# ['At iteration 17 the best fitness is 0.20205284850384217']
# ['At iteration 18 the best fitness is 0.20205284850384217']
# ['At iteration 19 the best fitness is 0.20205284850384217']
# ['At iteration 20 the best fitness is 0.20205284850384217']
# ['At iteration 21 the best fitness is 0.20205284850384217']
# ['At iteration 22 the best fitness is 0.20205284850384217']
# ['At iteration 23 the best fitness is 0.20205284850384217']
# ['At iteration 24 the best fitness is 0.20205284850384217']
# ['At iteration 25 the best fitness is 0.20205284850384217']
# ['At iteration 26 the best fitness is 0.20205284850384217']
# ['At iteration 27 the best fitness is 0.20205284850384217']
# ['At iteration 28 the best fitness is 0.20205284850384217']
# ['At iteration 29 the best fitness is 0.20205284850384217']
#       Selected: 1241/2513 (49.4%), Fitness: 0.2021, Time: 621.5s
#       Modality: D=48%, S=49%, Sk=50%
#     Test Acc: 79.29%, F1: 79.07%, Features: 1241/2513 (49.4%), Model: 2.960MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.24653243548057874']
# ['At iteration 2 the best fitness is 0.22706217822762048']
# ['At iteration 3 the best fitness is 0.22706217822762048']
# ['At iteration 4 the best fitness is 0.22706217822762048']
# ['At iteration 5 the best fitness is 0.22706217822762048']
# ['At iteration 6 the best fitness is 0.2181925490042453']
# ['At iteration 7 the best fitness is 0.2180532732382286']
# ['At iteration 8 the best fitness is 0.2180532732382286']
# ['At iteration 9 the best fitness is 0.2180532732382286']
# ['At iteration 10 the best fitness is 0.2180532732382286']
# ['At iteration 11 the best fitness is 0.2180532732382286']
# ['At iteration 12 the best fitness is 0.2180532732382286']
# ['At iteration 13 the best fitness is 0.2180532732382286']
# ['At iteration 14 the best fitness is 0.2180532732382286']
# ['At iteration 15 the best fitness is 0.2180532732382286']
# ['At iteration 16 the best fitness is 0.2180532732382286']
# ['At iteration 17 the best fitness is 0.2180532732382286']
# ['At iteration 18 the best fitness is 0.2180532732382286']
# ['At iteration 19 the best fitness is 0.2180532732382286']
# ['At iteration 20 the best fitness is 0.2180532732382286']
# ['At iteration 21 the best fitness is 0.21348913112952544']
# ['At iteration 22 the best fitness is 0.20820871365273635']
# ['At iteration 23 the best fitness is 0.20820871365273635']
# ['At iteration 24 the best fitness is 0.20820871365273635']
# ['At iteration 25 the best fitness is 0.20820871365273635']
# ['At iteration 26 the best fitness is 0.20820871365273635']
# ['At iteration 27 the best fitness is 0.20820871365273635']
# ['At iteration 28 the best fitness is 0.20820871365273635']
# ['At iteration 29 the best fitness is 0.20820871365273635']
#       Selected: 1324/2513 (52.7%), Fitness: 0.2082, Time: 585.9s
#       Modality: D=54%, S=54%, Sk=52%
#     Test Acc: 72.73%, F1: 71.00%, Features: 1324/2513 (52.7%), Model: 3.122MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.24155046607382546']
# ['At iteration 2 the best fitness is 0.2166008259640543']
# ['At iteration 3 the best fitness is 0.21648144673603997']
# ['At iteration 4 the best fitness is 0.21648144673603997']
# ['At iteration 5 the best fitness is 0.21648144673603997']
# ['At iteration 6 the best fitness is 0.21588455059596834']
# ['At iteration 7 the best fitness is 0.21588455059596834']
# ['At iteration 8 the best fitness is 0.2113005119492628']
# ['At iteration 9 the best fitness is 0.2113005119492628']
# ['At iteration 10 the best fitness is 0.20611957716248566']
# ['At iteration 11 the best fitness is 0.19681222410305785']
# ['At iteration 12 the best fitness is 0.19681222410305785']
# ['At iteration 13 the best fitness is 0.19681222410305785']
# ['At iteration 14 the best fitness is 0.19681222410305785']
# ['At iteration 15 the best fitness is 0.19681222410305785']
# ['At iteration 16 the best fitness is 0.19681222410305785']
# ['At iteration 17 the best fitness is 0.19681222410305785']
# ['At iteration 18 the best fitness is 0.1916511858542831']
# ['At iteration 19 the best fitness is 0.1916511858542831']
# ['At iteration 20 the best fitness is 0.1916511858542831']
# ['At iteration 21 the best fitness is 0.1916511858542831']
# ['At iteration 22 the best fitness is 0.1916511858542831']
# ['At iteration 23 the best fitness is 0.1916511858542831']
# ['At iteration 24 the best fitness is 0.1916511858542831']
# ['At iteration 25 the best fitness is 0.1916511858542831']
# ['At iteration 26 the best fitness is 0.1916511858542831']
# ['At iteration 27 the best fitness is 0.1916511858542831']
# ['At iteration 28 the best fitness is 0.1916511858542831']
# ['At iteration 29 the best fitness is 0.1916511858542831']
# ['At iteration 30 the best fitness is 0.1916511858542831']
#       Selected: 1229/2513 (48.9%), Fitness: 0.1917, Time: 597.6s
#       Modality: D=56%, S=44%, Sk=50%
#     Test Acc: 75.76%, F1: 75.64%, Features: 1229/2513 (48.9%), Model: 2.937MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2509374052852627']
# ['At iteration 2 the best fitness is 0.2024905723398947']
# ['At iteration 3 the best fitness is 0.2024905723398947']
# ['At iteration 4 the best fitness is 0.2024905723398947']
# ['At iteration 5 the best fitness is 0.2024905723398947']
# ['At iteration 6 the best fitness is 0.2024905723398947']
# ['At iteration 7 the best fitness is 0.2024905723398947']
# ['At iteration 8 the best fitness is 0.20195336581383025']
# ['At iteration 9 the best fitness is 0.20195336581383025']
# ['At iteration 10 the best fitness is 0.20195336581383025']
# ['At iteration 11 the best fitness is 0.20195336581383025']
# ['At iteration 12 the best fitness is 0.20195336581383025']
# ['At iteration 13 the best fitness is 0.20195336581383025']
# ['At iteration 14 the best fitness is 0.20195336581383025']
# ['At iteration 15 the best fitness is 0.20195336581383025']
# ['At iteration 16 the best fitness is 0.20195336581383025']
# ['At iteration 17 the best fitness is 0.20195336581383025']
# ['At iteration 18 the best fitness is 0.20195336581383025']
# ['At iteration 19 the best fitness is 0.20195336581383025']
# ['At iteration 20 the best fitness is 0.20195336581383025']
# ['At iteration 21 the best fitness is 0.20195336581383025']
# ['At iteration 22 the best fitness is 0.20195336581383025']
# ['At iteration 23 the best fitness is 0.20195336581383025']
# ['At iteration 24 the best fitness is 0.20195336581383025']
# ['At iteration 25 the best fitness is 0.20195336581383025']
# ['At iteration 26 the best fitness is 0.20195336581383025']
# ['At iteration 27 the best fitness is 0.20195336581383025']
# ['At iteration 28 the best fitness is 0.20195336581383025']
# ['At iteration 29 the best fitness is 0.20195336581383025']
# ['At iteration 30 the best fitness is 0.20195336581383025']
#       Selected: 1249/2513 (49.7%), Fitness: 0.2020, Time: 597.5s
#       Modality: D=50%, S=49%, Sk=50%
#     Test Acc: 76.26%, F1: 74.99%, Features: 1249/2513 (49.7%), Model: 2.976MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2317059064883332']
# ['At iteration 1 the best fitness is 0.2202895204006523']
# ['At iteration 2 the best fitness is 0.2202895204006523']
# ['At iteration 3 the best fitness is 0.2202895204006523']
# ['At iteration 4 the best fitness is 0.2202895204006523']
# ['At iteration 5 the best fitness is 0.2202895204006523']
# ['At iteration 6 the best fitness is 0.2198198383947514']
# ['At iteration 7 the best fitness is 0.2198198383947514']
# ['At iteration 8 the best fitness is 0.2198198383947514']
# ['At iteration 9 the best fitness is 0.2198198383947514']
# ['At iteration 10 the best fitness is 0.2198198383947514']
# ['At iteration 11 the best fitness is 0.2198198383947514']
# ['At iteration 12 the best fitness is 0.21576094464226434']
# ['At iteration 13 the best fitness is 0.2150048761981736']
# ['At iteration 14 the best fitness is 0.2150048761981736']
# ['At iteration 15 the best fitness is 0.2150048761981736']
# ['At iteration 16 the best fitness is 0.2150048761981736']
# ['At iteration 17 the best fitness is 0.2127764639419062']
# ['At iteration 18 the best fitness is 0.21215967126383217']
# ['At iteration 19 the best fitness is 0.21215967126383217']
# ['At iteration 20 the best fitness is 0.21215967126383217']
# ['At iteration 21 the best fitness is 0.21215967126383217']
# ['At iteration 22 the best fitness is 0.21215967126383217']
# ['At iteration 23 the best fitness is 0.21215967126383217']
# ['At iteration 24 the best fitness is 0.21215967126383217']
# ['At iteration 25 the best fitness is 0.21215967126383217']
# ['At iteration 26 the best fitness is 0.21215967126383217']
# ['At iteration 27 the best fitness is 0.20159883631025408']
# ['At iteration 28 the best fitness is 0.20159883631025408']
# ['At iteration 29 the best fitness is 0.20159883631025408']
#       Selected: 513/2513 (20.4%), Fitness: 0.2016, Time: 581.1s
#       Modality: D=22%, S=19%, Sk=21%
#     Test Acc: 75.76%, F1: 75.15%, Features: 513/2513 (20.4%), Model: 1.538MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.23126818265228066']
# ['At iteration 2 the best fitness is 0.2221995880488815']
# ['At iteration 3 the best fitness is 0.2221995880488815']
# ['At iteration 4 the best fitness is 0.2221995880488815']
# ['At iteration 5 the best fitness is 0.2121361665453631']
# ['At iteration 6 the best fitness is 0.2121361665453631']
# ['At iteration 7 the best fitness is 0.2121361665453631']
# ['At iteration 8 the best fitness is 0.2071939902146146']
# ['At iteration 9 the best fitness is 0.20211253811784935']
# ['At iteration 10 the best fitness is 0.19270570236840961']
# ['At iteration 11 the best fitness is 0.19270570236840961']
# ['At iteration 12 the best fitness is 0.19270570236840961']
# ['At iteration 13 the best fitness is 0.19270570236840961']
# ['At iteration 14 the best fitness is 0.19270570236840961']
# ['At iteration 15 the best fitness is 0.19270570236840961']
# ['At iteration 16 the best fitness is 0.19270570236840961']
# ['At iteration 17 the best fitness is 0.19270570236840961']
# ['At iteration 18 the best fitness is 0.19270570236840961']
# ['At iteration 19 the best fitness is 0.19270570236840961']
# ['At iteration 20 the best fitness is 0.19270570236840961']
# ['At iteration 21 the best fitness is 0.19270570236840961']
# ['At iteration 22 the best fitness is 0.18286114278291749']
# ['At iteration 23 the best fitness is 0.18286114278291749']
# ['At iteration 24 the best fitness is 0.18286114278291749']
# ['At iteration 25 the best fitness is 0.18286114278291749']
# ['At iteration 26 the best fitness is 0.18286114278291749']
# ['At iteration 27 the best fitness is 0.18286114278291749']
# ['At iteration 28 the best fitness is 0.18286114278291749']
# ['At iteration 29 the best fitness is 0.18286114278291749']
#       Selected: 1265/2513 (50.3%), Fitness: 0.1829, Time: 1505.0s
#       Modality: D=51%, S=47%, Sk=52%
#     Test Acc: 70.20%, F1: 68.07%, Features: 1265/2513 (50.3%), Model: 3.007MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.24153056953582308']
# ['At iteration 1 the best fitness is 0.24153056953582308']
# ['At iteration 2 the best fitness is 0.24153056953582308']
# ['At iteration 3 the best fitness is 0.2362224206148752']
# ['At iteration 4 the best fitness is 0.2362224206148752']
# ['At iteration 5 the best fitness is 0.2362224206148752']
# ['At iteration 6 the best fitness is 0.22814442618590583']
# ['At iteration 7 the best fitness is 0.22814442618590583']
# ['At iteration 8 the best fitness is 0.22814442618590583']
# ['At iteration 9 the best fitness is 0.22814442618590583']
# ['At iteration 10 the best fitness is 0.22814442618590583']
# ['At iteration 11 the best fitness is 0.22814442618590583']
# ['At iteration 12 the best fitness is 0.22814442618590583']
# ['At iteration 13 the best fitness is 0.22814442618590583']
# ['At iteration 14 the best fitness is 0.22814442618590583']
# ['At iteration 15 the best fitness is 0.22814442618590583']
# ['At iteration 16 the best fitness is 0.22814442618590583']
# ['At iteration 17 the best fitness is 0.22814442618590583']
# ['At iteration 18 the best fitness is 0.22814442618590583']
# ['At iteration 19 the best fitness is 0.22814442618590583']
# ['At iteration 20 the best fitness is 0.2280250469578915']
# ['At iteration 21 the best fitness is 0.2280250469578915']
# ['At iteration 22 the best fitness is 0.2280250469578915']
# ['At iteration 23 the best fitness is 0.2280250469578915']
# ['At iteration 24 the best fitness is 0.2280250469578915']
# ['At iteration 25 the best fitness is 0.2280250469578915']
# ['At iteration 26 the best fitness is 0.2280250469578915']
# ['At iteration 27 the best fitness is 0.2280250469578915']
# ['At iteration 28 the best fitness is 0.2280250469578915']
# ['At iteration 29 the best fitness is 0.2280250469578915']
#       Selected: 1015/2513 (40.4%), Fitness: 0.2280, Time: 507.7s
#       Modality: D=42%, S=39%, Sk=41%
#     Test Acc: 69.19%, F1: 68.61%, Features: 1015/2513 (40.4%), Model: 2.519MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_10_noise_new/all_results_per_fold.csv
# Shape: (90, 26)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected
# 0      baseline     1            79.3706           77.1429       78.5545          78.5545              80.1266           79.3706               2513            2513               100.0000       0.0000         10.3762         10.3762       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 1      baseline     2            63.0705           82.0652       62.3574          62.3948              68.4005           62.9752               2513            2513               100.0000       0.0000         10.9799         10.9799       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 2      baseline     3            81.3636           83.5979       81.2211          81.2211              82.5236           81.3636               2513            2513               100.0000       0.0000         11.1738         11.1738       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 3      baseline     4            70.0000           84.1270       68.1196          68.1196              72.4913           70.0000               2513            2513               100.0000       0.0000         11.2117         11.2117       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 4      baseline     5            76.2626           79.2746       75.2258          75.2258              76.0502           76.2626               2513            2513               100.0000       0.0000         11.6577         11.6577       1425686           5.4444                22.3362                 22.3362                 0.0000        50.2090             100.0000             216              100.0000              652                100.0000               1645
# 5   mutual_info     1            82.1678           85.7143       80.8322          80.8322              83.2395           82.1678               1256            2513                49.9801      12.1418          8.9159         21.0578        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              36.5741              79               38.9571              254                 56.1094                923
# 6   mutual_info     2            70.5394           85.8696       71.0354          71.1118              74.6202           70.4545               1256            2513                49.9801      12.3213          9.0907         21.4121        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              44.9074              97               36.8098              240                 55.8663                919
# 7   mutual_info     3            86.3636           87.3016       86.2150          86.2150              86.8356           86.3636               1256            2513                49.9801      12.4391          9.2273         21.6665        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              39.8148              86               37.4233              244                 56.2918                926
# 8   mutual_info     4            74.0909           89.9471       72.5196          72.5196              74.4587           74.0909               1256            2513                49.9801      12.1446          9.0742         21.2189        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              44.4444              96               36.0429              235                 56.2310                925
# 9   mutual_info     5            80.8081           81.8653       80.9235          80.9235              82.6780           80.8081               1256            2513                49.9801      12.4718          9.6289         22.1008        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              42.1296              91               36.6564              239                 56.2918                926
# 10          rfe     1            83.5664           84.0000       83.1118          83.1118              84.2700           83.5664               1256            2513                49.9801       2.5326          8.2921         10.8249        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              61.1111             132               47.0859              307                 49.6657                817
# 11          rfe     2            63.4855           86.4130       63.5836          63.6261              73.2930           63.3884               1256            2513                49.9801       2.5426          9.1236         11.6665        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              66.2037             143               38.0368              248                 52.5836                865
# 12          rfe     3            82.7273           87.8307       81.9061          81.9061              83.4022           82.7273               1256            2513                49.9801       2.5725          9.1318         11.7046        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              56.4815             122               44.7853              292                 51.1854                842
# 13          rfe     4            71.8182           86.7725       71.0516          71.0516              76.7503           71.8182               1256            2513                49.9801       2.5896          8.9955         11.5853        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              73.1481             158               38.1902              249                 51.6109                849
# 14          rfe     5            82.8283           84.9741       82.5479          82.5479              83.2587           82.8283               1256            2513                49.9801       2.5887          9.5680         12.1569        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              63.8889             138               41.1043              268                 51.6717                850
# 15        lasso     1            68.5315           72.0000       65.6553          65.6553              70.6094           68.5315               1256            2513                49.9801       0.5073          8.4089          8.9163        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422
# 16        lasso     2            54.7718           79.3478       55.4587          55.4122              61.9907           54.7934               1256            2513                49.9801       0.4915          9.2818          9.7735        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422
# 17        lasso     3            69.5455           78.8360       68.4643          68.4643              72.8436           69.5455               1256            2513                49.9801       0.5681          9.2354          9.8036        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422
# 18        lasso     4            57.2727           83.0688       54.0745          54.0745              65.2675           57.2727               1256            2513                49.9801       0.5037          9.1670          9.6708        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422
# 19        lasso     5            65.1515           73.0570       64.5641          64.5641              65.8449           65.1515               1256            2513                49.9801       0.5387          9.7532         10.2921        782102           2.9894                22.3362                 11.1636                50.0199        35.3267              84.7222             183               99.8466              651                 25.6535                422

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              74.01              7.48              73.10              7.75                  2513.0                      100.00              0.00                11.08                11.08          1425686.0                  5.44                        0.00               50.21
# mutual_info              78.79              6.38              78.31              6.37                  1256.0                       49.98             12.30                 9.19                21.49           782102.0                  2.99                       50.02               35.33
#         rfe              76.89              8.93              76.44              8.75                  1256.0                       49.98              2.57                 9.02                11.59           782102.0                  2.99                       50.02               35.33
#       lasso              63.05              6.68              61.64              6.46                  1256.0                       49.98              0.52                 9.17                 9.69           782102.0                  2.99                       50.02               35.33
#    meta_BAT              72.75              6.46              72.23              6.78                  1233.2                       49.07            582.95                 9.21               592.16           770428.4                  2.94                       50.93               35.15
#     meta_CS              72.15              7.32              71.47              7.49                  1259.6                       50.12           1146.93                 9.21              1156.14           783945.2                  3.00                       49.88               35.39
#     meta_DE              70.44              6.56              69.87              6.18                  1246.8                       49.61            582.10                 9.22               591.33           777391.6                  2.97                       50.39               35.26
#    meta_FFA              73.32              6.10              72.60              6.25                  1253.2                       49.87            563.43                 9.24               572.67           780668.4                  2.98                       50.13               35.34
#     meta_GA              72.12              9.20              71.73              9.05                  1249.0                       49.70            560.42                 9.07               569.50           778518.0                  2.98                       50.30               35.28
#    meta_GWO              73.09              5.04              72.44              5.29                  1065.2                       42.39            543.33                 9.03               552.36           684412.4                  2.62                       57.61               34.32
#    meta_HHO              72.24              8.78              71.90              8.55                  1293.8                       51.48            763.71                 9.36               773.07           801455.6                  3.06                       48.52               36.25
#   meta_JAYA              73.58              8.29              72.80              8.10                  1234.6                       49.13            583.43                 9.13               592.57           771145.2                  2.95                       50.87               35.16
#    meta_MFO              75.20              8.52              74.45              8.63                  1284.8                       51.13            551.15                 9.24               560.39           796847.6                  3.05                       48.87               35.67
#    meta_MVO              72.23              8.91              71.83              8.29                  1244.2                       49.51            565.58                 9.18               574.76           776060.4                  2.97                       50.49               35.24
#    meta_PSO              72.36              7.92              71.95              7.65                  1233.4                       49.08            561.26                 9.12               570.38           770530.8                  2.95                       50.92               35.15
#    meta_SCA              71.27              7.30              70.16              7.74                   604.6                       24.06            543.37                 8.95               552.32           448585.2                  1.72                       75.94               28.08
#    meta_SSA              69.31             10.52              68.58             10.61                  1261.4                       50.19           1418.05                 9.30              1427.35           784866.8                  3.00                       49.81               35.43
#    meta_WOA              67.96              9.11              67.54              8.46                  1127.0                       44.85            534.78                 8.68               543.46           716054.0                  2.74                       55.15               34.21

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 78.79% vs Baseline: 74.01%
#   Paired t-test: t=6.2396, p=0.0034
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> better, Significant
#
# RFE vs BASELINE:
#   Method: 76.89% vs Baseline: 74.01%
#   Paired t-test: t=2.5779, p=0.0615
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 63.05% vs Baseline: 74.01%
#   Paired t-test: t=-14.7908, p=0.0001
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 72.75% vs Baseline: 74.01%
#   Paired t-test: t=-0.9900, p=0.3782
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 72.15% vs Baseline: 74.01%
#   Paired t-test: t=-2.2482, p=0.0878
#   Wilcoxon test: W=0.0000, p=0.2500
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 70.44% vs Baseline: 74.01%
#   Paired t-test: t=-2.7113, p=0.0535
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 73.32% vs Baseline: 74.01%
#   Paired t-test: t=-0.4425, p=0.6810
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 72.12% vs Baseline: 74.01%
#   Paired t-test: t=-1.2613, p=0.2758
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 73.09% vs Baseline: 74.01%
#   Paired t-test: t=-0.5725, p=0.5976
#   Wilcoxon test: W=3.0000, p=0.6250
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 72.24% vs Baseline: 74.01%
#   Paired t-test: t=-2.1155, p=0.1019
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 73.58% vs Baseline: 74.01%
#   Paired t-test: t=-0.4091, p=0.7034
#   Wilcoxon test: W=6.0000, p=0.8125
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 75.20% vs Baseline: 74.01%
#   Paired t-test: t=0.9229, p=0.4083
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> better, Not significant
#
# META_MVO vs BASELINE:
#   Method: 72.23% vs Baseline: 74.01%
#   Paired t-test: t=-2.1464, p=0.0984
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 72.36% vs Baseline: 74.01%
#   Paired t-test: t=-2.3329, p=0.0800
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 71.27% vs Baseline: 74.01%
#   Paired t-test: t=-2.2449, p=0.0881
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 69.31% vs Baseline: 74.01%
#   Paired t-test: t=-3.1765, p=0.0336
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# META_WOA vs BASELINE:
#   Method: 67.96% vs Baseline: 74.01%
#   Paired t-test: t=-5.9830, p=0.0039
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_10_noise_new
#
# Per-method folders:
#   results_10_noise_new/baseline/ (10 files)
#   results_10_noise_new/mutual_info/ (10 files)
#   results_10_noise_new/rfe/ (10 files)
#   results_10_noise_new/lasso/ (10 files)
#   results_10_noise_new/meta_BAT/ (10 files)
#   results_10_noise_new/meta_CS/ (10 files)
#   results_10_noise_new/meta_DE/ (10 files)
#   results_10_noise_new/meta_FFA/ (10 files)
#   results_10_noise_new/meta_GA/ (10 files)
#   results_10_noise_new/meta_GWO/ (10 files)
#   results_10_noise_new/meta_HHO/ (10 files)
#   results_10_noise_new/meta_JAYA/ (10 files)
#   results_10_noise_new/meta_MFO/ (10 files)
#   results_10_noise_new/meta_MVO/ (10 files)
#   results_10_noise_new/meta_PSO/ (10 files)
#   results_10_noise_new/meta_SCA/ (10 files)
#   results_10_noise_new/meta_SSA/ (10 files)
#   results_10_noise_new/meta_WOA/ (10 files)
#
# Plots directory: results_10_noise_new/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   mutual_info         : 78.79% ± 6.38% (Features: 50.0%)
#   rfe                 : 76.89% ± 8.93% (Features: 50.0%)
#   meta_MFO            : 75.20% ± 8.52% (Features: 51.1%)
#   baseline            : 74.01% ± 7.48% (Features: 100.0%)
#   meta_JAYA           : 73.58% ± 8.29% (Features: 49.1%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_MFO
#     Test Accuracy:      82.52%
#     Feature Retention:  50.78% (1276/2513)
#     Modality Retention: depth=49.5%, sensor=50.5%, skeleton=51.1%
#
#   Fold 2: Best = meta_GWO
#     Test Accuracy:      67.22%
#     Feature Retention:  42.50% (1068/2513)
#     Modality Retention: depth=39.8%, sensor=44.3%, skeleton=42.1%
#
#   Fold 3: Best = meta_MFO
#     Test Accuracy:      84.55%
#     Feature Retention:  51.17% (1286/2513)
#     Modality Retention: depth=50.5%, sensor=50.3%, skeleton=51.6%
#
#   Fold 4: Best = meta_FFA
#     Test Accuracy:      75.00%
#     Feature Retention:  50.82% (1277/2513)
#     Modality Retention: depth=57.4%, sensor=45.4%, skeleton=52.1%
#
#   Fold 5: Best = meta_JAYA
#     Test Accuracy:      79.29%
#     Feature Retention:  49.38% (1241/2513)
#     Modality Retention: depth=47.7%, sensor=49.2%, skeleton=49.7%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     77.72% ± 6.89%
#   Average Feature Retention: 48.93% ± 3.66%
#
#   Average Modality-wise Feature Retention:
#          depth: 48.98% ± 6.31%
#         sensor: 47.94% ± 2.88%
#       skeleton: 49.31% ± 4.12%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)
#     1           meta_MFO              82.52                  50.78                49.54                 50.46                   51.06
#     2           meta_GWO              67.22                  42.50                39.81                 44.33                   42.13
#     3           meta_MFO              84.55                  51.17                50.46                 50.31                   51.61
#     4           meta_FFA              75.00                  50.82                57.41                 45.40                   52.10
#     5          meta_JAYA              79.29                  49.38                47.69                 49.23                   49.67
#
# Saved to: results_10_noise_new/best_metaheuristic_per_fold.csv
