# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_no_sensor")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   depth: 37
#   skeleton: 400
#   TOTAL: 437

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 93.01%, F1: 92.20%, Features: 437/437 (100.0%), Model: 1.390MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 218/437 (49.9%), Time: 2.2s
#     Test Acc: 94.76%, F1: 94.15%, Features: 218/437 (49.9%), Model: 0.756MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 218/437 (49.9%), Time: 0.4s
#     Test Acc: 93.01%, F1: 91.85%, Features: 218/437 (49.9%), Model: 0.756MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 218/437 (49.9%), Time: 0.1s
#     Test Acc: 89.51%, F1: 88.37%, Features: 218/437 (49.9%), Model: 0.756MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07008761033017324']
# ['At iteration 1 the best fitness is 0.06443020594965679']
# ['At iteration 2 the best fitness is 0.06443020594965679']
# ['At iteration 3 the best fitness is 0.06443020594965679']
# ['At iteration 4 the best fitness is 0.06443020594965679']
# ['At iteration 5 the best fitness is 0.05911605099705783']
# ['At iteration 6 the best fitness is 0.05911605099705783']
# ['At iteration 7 the best fitness is 0.05911605099705783']
# ['At iteration 8 the best fitness is 0.05911605099705783']
# ['At iteration 9 the best fitness is 0.05911605099705783']
# ['At iteration 10 the best fitness is 0.05911605099705783']
# ['At iteration 11 the best fitness is 0.05911605099705783']
# ['At iteration 12 the best fitness is 0.05911605099705783']
# ['At iteration 13 the best fitness is 0.05911605099705783']
# ['At iteration 14 the best fitness is 0.05911605099705783']
# ['At iteration 15 the best fitness is 0.05911605099705783']
# ['At iteration 16 the best fitness is 0.05911605099705783']
# ['At iteration 17 the best fitness is 0.05911605099705783']
# ['At iteration 18 the best fitness is 0.05911605099705783']
# ['At iteration 19 the best fitness is 0.05911605099705783']
# ['At iteration 20 the best fitness is 0.05911605099705783']
# ['At iteration 21 the best fitness is 0.05911605099705783']
# ['At iteration 22 the best fitness is 0.05911605099705783']
# ['At iteration 23 the best fitness is 0.05911605099705783']
# ['At iteration 24 the best fitness is 0.05911605099705783']
# ['At iteration 25 the best fitness is 0.05911605099705783']
# ['At iteration 26 the best fitness is 0.05911605099705783']
# ['At iteration 27 the best fitness is 0.05911605099705783']
# ['At iteration 28 the best fitness is 0.05911605099705783']
# ['At iteration 29 the best fitness is 0.05911605099705783']
#       Selected: 235/437 (53.8%), Fitness: 0.0591, Time: 642.7s
#       Modality: D=68%, Sk=52%
#     Test Acc: 93.01%, F1: 91.94%, Features: 235/437 (53.8%), Model: 0.876MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06111212814645313']
# ['At iteration 10 the best fitness is 0.057857469761359887']
# ['At iteration 20 the best fitness is 0.056942137953579566']
#       Selected: 220/437 (50.3%), Fitness: 0.0568, Time: 1259.0s
#       Modality: D=41%, Sk=51%
#     Test Acc: 91.26%, F1: 89.92%, Features: 220/437 (50.3%), Model: 0.770MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06156979405034328']
# ['At iteration 2 the best fitness is 0.06156979405034328']
# ['At iteration 3 the best fitness is 0.06156979405034328']
# ['At iteration 4 the best fitness is 0.058429552141222585']
# ['At iteration 5 the best fitness is 0.058429552141222585']
# ['At iteration 6 the best fitness is 0.058429552141222585']
# ['At iteration 7 the best fitness is 0.058429552141222585']
# ['At iteration 8 the best fitness is 0.058429552141222585']
# ['At iteration 9 the best fitness is 0.058429552141222585']
# ['At iteration 10 the best fitness is 0.058429552141222585']
# ['At iteration 11 the best fitness is 0.05717097090552465']
# ['At iteration 12 the best fitness is 0.05717097090552465']
# ['At iteration 13 the best fitness is 0.05717097090552465']
# ['At iteration 14 the best fitness is 0.05717097090552465']
# ['At iteration 15 the best fitness is 0.055225890813991464']
# ['At iteration 16 the best fitness is 0.055225890813991464']
# ['At iteration 17 the best fitness is 0.055225890813991464']
# ['At iteration 18 the best fitness is 0.055225890813991464']
# ['At iteration 19 the best fitness is 0.055225890813991464']
# ['At iteration 20 the best fitness is 0.055225890813991464']
# ['At iteration 21 the best fitness is 0.055225890813991464']
# ['At iteration 22 the best fitness is 0.055225890813991464']
# ['At iteration 23 the best fitness is 0.055225890813991464']
# ['At iteration 24 the best fitness is 0.055225890813991464']
# ['At iteration 25 the best fitness is 0.055225890813991464']
# ['At iteration 26 the best fitness is 0.055225890813991464']
# ['At iteration 27 the best fitness is 0.055225890813991464']
# ['At iteration 28 the best fitness is 0.055225890813991464']
# ['At iteration 29 the best fitness is 0.055225890813991464']
# ['At iteration 30 the best fitness is 0.055225890813991464']
#       Selected: 194/437 (44.4%), Fitness: 0.0552, Time: 637.9s
#       Modality: D=46%, Sk=44%
#     Test Acc: 96.15%, F1: 96.02%, Features: 194/437 (44.4%), Model: 0.602MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06779928081072245']
# ['At iteration 1 the best fitness is 0.06688394900294213']
# ['At iteration 2 the best fitness is 0.061913043478260904']
# ['At iteration 3 the best fitness is 0.060997711670480584']
# ['At iteration 4 the best fitness is 0.061340961098398206']
# ['At iteration 5 the best fitness is 0.06688394900294213']
# ['At iteration 6 the best fitness is 0.06585420071918927']
# ['At iteration 7 the best fitness is 0.060425629290617885']
# ['At iteration 8 the best fitness is 0.06076887871853551']
# ['At iteration 9 the best fitness is 0.06065446224256296']
# ['At iteration 10 the best fitness is 0.05591238966982671']
# ['At iteration 11 the best fitness is 0.061340961098398206']
# ['At iteration 12 the best fitness is 0.060997711670480584']
# ['At iteration 13 the best fitness is 0.061340961098398206']
# ['At iteration 14 the best fitness is 0.06111212814645313']
# ['At iteration 15 the best fitness is 0.061455377574370744']
# ['At iteration 16 the best fitness is 0.061340961098398206']
# ['At iteration 17 the best fitness is 0.0667695325269696']
# ['At iteration 18 the best fitness is 0.05591238966982671']
# ['At iteration 19 the best fitness is 0.06122654462242566']
# ['At iteration 20 the best fitness is 0.06122654462242566']
# ['At iteration 21 the best fitness is 0.06122654462242566']
# ['At iteration 22 the best fitness is 0.06122654462242566']
# ['At iteration 23 the best fitness is 0.06122654462242566']
# ['At iteration 24 the best fitness is 0.06122654462242566']
# ['At iteration 25 the best fitness is 0.06122654462242566']
# ['At iteration 26 the best fitness is 0.06122654462242566']
# ['At iteration 27 the best fitness is 0.06122654462242566']
# ['At iteration 28 the best fitness is 0.06122654462242566']
# ['At iteration 29 the best fitness is 0.06122654462242566']
#       Selected: 200/437 (45.8%), Fitness: 0.0612, Time: 617.5s
#       Modality: D=43%, Sk=46%
#     Test Acc: 93.36%, F1: 92.80%, Features: 200/437 (45.8%), Model: 0.639MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.06488787185354694
# At iteration 2 the best fitness is 0.06431578947368424
# At iteration 3 the best fitness is 0.06511670480549203
# At iteration 4 the best fitness is 0.0642013729977117
# At iteration 5 the best fitness is 0.06259954233409615
# At iteration 6 the best fitness is 0.061913043478260904
# At iteration 7 the best fitness is 0.062370709382151064
# At iteration 8 the best fitness is 0.056942137953579566
# At iteration 9 the best fitness is 0.06328604118993139
# At iteration 10 the best fitness is 0.062370709382151064
# At iteration 11 the best fitness is 0.06454462242562932
# At iteration 12 the best fitness is 0.056942137953579566
# At iteration 13 the best fitness is 0.0624851258581236
# At iteration 14 the best fitness is 0.05797188623733243
# At iteration 15 the best fitness is 0.058429552141222585
# At iteration 16 the best fitness is 0.06271395881006869
# At iteration 17 the best fitness is 0.06168421052631583
# At iteration 18 the best fitness is 0.06168421052631583
# At iteration 19 the best fitness is 0.0624851258581236
# At iteration 20 the best fitness is 0.05625563909774432
# At iteration 21 the best fitness is 0.057514220333442265
# At iteration 22 the best fitness is 0.061340961098398206
# At iteration 23 the best fitness is 0.06156979405034328
# At iteration 24 the best fitness is 0.061913043478260904
# At iteration 25 the best fitness is 0.061798627002288366
# At iteration 26 the best fitness is 0.05637005557371687
# At iteration 27 the best fitness is 0.057514220333442265
# At iteration 28 the best fitness is 0.06168421052631583
# At iteration 29 the best fitness is 0.06271395881006869
# At iteration 30 the best fitness is 0.05139915004903564
#       Selected: 217/437 (49.7%), Fitness: 0.0514, Time: 619.1s
#       Modality: D=49%, Sk=50%
#     Test Acc: 92.31%, F1: 91.11%, Features: 217/437 (49.7%), Model: 0.749MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0642013729977117']
# ['At iteration 1 the best fitness is 0.0642013729977117']
# ['At iteration 2 the best fitness is 0.061798627002288366']
# ['At iteration 3 the best fitness is 0.061798627002288366']
# ['At iteration 4 the best fitness is 0.059510297482837565']
# ['At iteration 5 the best fitness is 0.0590526315789474']
# ['At iteration 6 the best fitness is 0.056764302059496605']
# ['At iteration 7 the best fitness is 0.05110689767898002']
# ['At iteration 8 the best fitness is 0.05110689767898002']
# ['At iteration 9 the best fitness is 0.05110689767898002']
# ['At iteration 10 the best fitness is 0.047674403399803826']
# ['At iteration 11 the best fitness is 0.047674403399803826']
# ['At iteration 12 the best fitness is 0.04710232101994112']
# ['At iteration 13 the best fitness is 0.04698790454396858']
# ['At iteration 14 the best fitness is 0.046301405688133346']
# ['At iteration 15 the best fitness is 0.0461869892121608']
# ['At iteration 16 the best fitness is 0.04584373978424318']
# ['At iteration 17 the best fitness is 0.045386073880353026']
# ['At iteration 18 the best fitness is 0.04515724092840794']
# ['At iteration 19 the best fitness is 0.04492840797646286']
# ['At iteration 20 the best fitness is 0.04492840797646286']
# ['At iteration 21 the best fitness is 0.04492840797646286']
# ['At iteration 22 the best fitness is 0.04469957502451778']
# ['At iteration 23 the best fitness is 0.044470742072572705']
# ['At iteration 24 the best fitness is 0.044470742072572705']
# ['At iteration 25 the best fitness is 0.044470742072572705']
# ['At iteration 26 the best fitness is 0.044127492644655084']
# ['At iteration 27 the best fitness is 0.038355671788166075']
# ['At iteration 28 the best fitness is 0.038355671788166075']
# ['At iteration 29 the best fitness is 0.038355671788166075']
#       Selected: 117/437 (26.8%), Fitness: 0.0384, Time: 601.7s
#       Modality: D=16%, Sk=28%
#     Test Acc: 93.01%, F1: 91.97%, Features: 117/437 (26.8%), Model: 0.225MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.06019679633867281']
# ['At iteration 1 the best fitness is 0.04978489702517166']
# ['At iteration 2 the best fitness is 0.045500490356325564']
# ['At iteration 3 the best fitness is 0.04452173913043482']
# ['At iteration 4 the best fitness is 0.04452173913043482']
# ['At iteration 5 the best fitness is 0.04452173913043482']
# ['At iteration 6 the best fitness is 0.04452173913043482']
# ['At iteration 7 the best fitness is 0.04452173913043482']
# ['At iteration 8 the best fitness is 0.04452173913043482']
# ['At iteration 9 the best fitness is 0.04452173913043482']
# ['At iteration 10 the best fitness is 0.04452173913043482']
# ['At iteration 11 the best fitness is 0.04452173913043482']
# ['At iteration 12 the best fitness is 0.04429290617848974']
# ['At iteration 13 the best fitness is 0.04429290617848974']
# ['At iteration 14 the best fitness is 0.04429290617848974']
# ['At iteration 15 the best fitness is 0.04429290617848974']
# ['At iteration 16 the best fitness is 0.04429290617848974']
# ['At iteration 17 the best fitness is 0.04429290617848974']
# ['At iteration 18 the best fitness is 0.04429290617848974']
# ['At iteration 19 the best fitness is 0.0416103301732592']
# ['At iteration 20 the best fitness is 0.0416103301732592']
# ['At iteration 21 the best fitness is 0.0416103301732592']
# ['At iteration 22 the best fitness is 0.0416103301732592']
# ['At iteration 23 the best fitness is 0.0416103301732592']
# ['At iteration 24 the best fitness is 0.0416103301732592']
# ['At iteration 25 the best fitness is 0.0416103301732592']
# ['At iteration 26 the best fitness is 0.0416103301732592']
# ['At iteration 27 the best fitness is 0.0416103301732592']
# ['At iteration 28 the best fitness is 0.04012291598561618']
# ['At iteration 29 the best fitness is 0.04012291598561618']
#       Selected: 79/437 (18.1%), Fitness: 0.0401, Time: 742.2s
#       Modality: D=11%, Sk=19%
#     Test Acc: 95.10%, F1: 95.01%, Features: 79/437 (18.1%), Model: 0.106MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06688394900294213']
# ['At iteration 1 the best fitness is 0.06351487414187647']
# ['At iteration 2 the best fitness is 0.06317162471395885']
# ['At iteration 3 the best fitness is 0.06317162471395885']
# ['At iteration 4 the best fitness is 0.06282837528604122']
# ['At iteration 5 the best fitness is 0.06282837528604122']
# ['At iteration 6 the best fitness is 0.05865838509316767']
# ['At iteration 7 the best fitness is 0.05774305328538735']
# ['At iteration 8 the best fitness is 0.05774305328538735']
# ['At iteration 9 the best fitness is 0.05774305328538735']
# ['At iteration 10 the best fitness is 0.05774305328538735']
# ['At iteration 11 the best fitness is 0.05774305328538735']
# ['At iteration 12 the best fitness is 0.05545472376593655']
# ['At iteration 13 the best fitness is 0.05545472376593655']
# ['At iteration 14 the best fitness is 0.05545472376593655']
# ['At iteration 15 the best fitness is 0.05545472376593655']
# ['At iteration 16 the best fitness is 0.05545472376593655']
# ['At iteration 17 the best fitness is 0.05545472376593655']
# ['At iteration 18 the best fitness is 0.05545472376593655']
# ['At iteration 19 the best fitness is 0.05545472376593655']
# ['At iteration 20 the best fitness is 0.05545472376593655']
# ['At iteration 21 the best fitness is 0.05545472376593655']
# ['At iteration 22 the best fitness is 0.05545472376593655']
# ['At iteration 23 the best fitness is 0.05545472376593655']
# ['At iteration 24 the best fitness is 0.05545472376593655']
# ['At iteration 25 the best fitness is 0.05545472376593655']
# ['At iteration 26 the best fitness is 0.05545472376593655']
# ['At iteration 27 the best fitness is 0.05545472376593655']
# ['At iteration 28 the best fitness is 0.05545472376593655']
# ['At iteration 29 the best fitness is 0.05545472376593655']
#       Selected: 207/437 (47.4%), Fitness: 0.0555, Time: 638.8s
#       Modality: D=35%, Sk=48%
#     Test Acc: 95.10%, F1: 94.59%, Features: 207/437 (47.4%), Model: 0.683MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06259954233409615']
# ['At iteration 2 the best fitness is 0.06259954233409615']
# ['At iteration 3 the best fitness is 0.06156979405034328']
# ['At iteration 4 the best fitness is 0.061455377574370744']
# ['At iteration 5 the best fitness is 0.061455377574370744']
# ['At iteration 6 the best fitness is 0.061455377574370744']
# ['At iteration 7 the best fitness is 0.061455377574370744']
# ['At iteration 8 the best fitness is 0.061455377574370744']
# ['At iteration 9 the best fitness is 0.05682772147760703']
# ['At iteration 10 the best fitness is 0.05682772147760703']
# ['At iteration 11 the best fitness is 0.05682772147760703']
# ['At iteration 12 the best fitness is 0.05682772147760703']
# ['At iteration 13 the best fitness is 0.05625563909774432']
# ['At iteration 14 the best fitness is 0.05625563909774432']
# ['At iteration 15 the best fitness is 0.05625563909774432']
# ['At iteration 16 the best fitness is 0.05625563909774432']
# ['At iteration 17 the best fitness is 0.05625563909774432']
# ['At iteration 18 the best fitness is 0.05625563909774432']
# ['At iteration 19 the best fitness is 0.05625563909774432']
# ['At iteration 20 the best fitness is 0.05625563909774432']
# ['At iteration 21 the best fitness is 0.05625563909774432']
# ['At iteration 22 the best fitness is 0.05625563909774432']
# ['At iteration 23 the best fitness is 0.05625563909774432']
# ['At iteration 24 the best fitness is 0.05625563909774432']
# ['At iteration 25 the best fitness is 0.05625563909774432']
# ['At iteration 26 the best fitness is 0.05625563909774432']
# ['At iteration 27 the best fitness is 0.055569140241909086']
# ['At iteration 28 the best fitness is 0.055569140241909086']
# ['At iteration 29 the best fitness is 0.055569140241909086']
#       Selected: 197/437 (45.1%), Fitness: 0.0556, Time: 600.2s
#       Modality: D=46%, Sk=45%
#     Test Acc: 91.61%, F1: 89.80%, Features: 197/437 (45.1%), Model: 0.620MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06545995423340964']
# ['At iteration 2 the best fitness is 0.06545995423340964']
# ['At iteration 3 the best fitness is 0.0642013729977117']
# ['At iteration 4 the best fitness is 0.0642013729977117']
# ['At iteration 5 the best fitness is 0.0642013729977117']
# ['At iteration 6 the best fitness is 0.0642013729977117']
# ['At iteration 7 the best fitness is 0.06259954233409615']
# ['At iteration 8 the best fitness is 0.06259954233409615']
# ['At iteration 9 the best fitness is 0.06202745995423345']
# ['At iteration 10 the best fitness is 0.06202745995423345']
# ['At iteration 11 the best fitness is 0.06202745995423345']
# ['At iteration 12 the best fitness is 0.06202745995423345']
# ['At iteration 13 the best fitness is 0.06202745995423345']
# ['At iteration 14 the best fitness is 0.06202745995423345']
# ['At iteration 15 the best fitness is 0.06202745995423345']
# ['At iteration 16 the best fitness is 0.06202745995423345']
# ['At iteration 17 the best fitness is 0.06202745995423345']
# ['At iteration 18 the best fitness is 0.06202745995423345']
# ['At iteration 19 the best fitness is 0.061913043478260904']
# ['At iteration 20 the best fitness is 0.061913043478260904']
# ['At iteration 21 the best fitness is 0.061913043478260904']
# ['At iteration 22 the best fitness is 0.061913043478260904']
# ['At iteration 23 the best fitness is 0.061913043478260904']
# ['At iteration 24 the best fitness is 0.061913043478260904']
# ['At iteration 25 the best fitness is 0.061913043478260904']
# ['At iteration 26 the best fitness is 0.061913043478260904']
# ['At iteration 27 the best fitness is 0.061913043478260904']
# ['At iteration 28 the best fitness is 0.061913043478260904']
# ['At iteration 29 the best fitness is 0.061913043478260904']
# ['At iteration 30 the best fitness is 0.061913043478260904']
#       Selected: 212/437 (48.5%), Fitness: 0.0619, Time: 617.8s
#       Modality: D=54%, Sk=48%
#     Test Acc: 93.36%, F1: 92.47%, Features: 212/437 (48.5%), Model: 0.716MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06573978424321673']
# ['At iteration 2 the best fitness is 0.06031121281464534']
# ['At iteration 3 the best fitness is 0.06031121281464534']
# ['At iteration 4 the best fitness is 0.05973913043478264']
# ['At iteration 5 the best fitness is 0.05973913043478264']
# ['At iteration 6 the best fitness is 0.05973913043478264']
# ['At iteration 7 the best fitness is 0.05973913043478264']
# ['At iteration 8 the best fitness is 0.05973913043478264']
# ['At iteration 9 the best fitness is 0.05973913043478264']
# ['At iteration 10 the best fitness is 0.05973913043478264']
# ['At iteration 11 the best fitness is 0.05973913043478264']
# ['At iteration 12 the best fitness is 0.05973913043478264']
# ['At iteration 13 the best fitness is 0.05973913043478264']
# ['At iteration 14 the best fitness is 0.05973913043478264']
# ['At iteration 15 the best fitness is 0.05973913043478264']
# ['At iteration 16 the best fitness is 0.05973913043478264']
# ['At iteration 17 the best fitness is 0.05973913043478264']
# ['At iteration 18 the best fitness is 0.05973913043478264']
# ['At iteration 19 the best fitness is 0.05973913043478264']
# ['At iteration 20 the best fitness is 0.05973913043478264']
# ['At iteration 21 the best fitness is 0.05973913043478264']
# ['At iteration 22 the best fitness is 0.05973913043478264']
# ['At iteration 23 the best fitness is 0.05973913043478264']
# ['At iteration 24 the best fitness is 0.05973913043478264']
# ['At iteration 25 the best fitness is 0.05973913043478264']
# ['At iteration 26 the best fitness is 0.05973913043478264']
# ['At iteration 27 the best fitness is 0.05973913043478264']
# ['At iteration 28 the best fitness is 0.05973913043478264']
# ['At iteration 29 the best fitness is 0.05973913043478264']
# ['At iteration 30 the best fitness is 0.05973913043478264']
#       Selected: 195/437 (44.6%), Fitness: 0.0597, Time: 616.9s
#       Modality: D=41%, Sk=45%
#     Test Acc: 95.10%, F1: 94.88%, Features: 195/437 (44.6%), Model: 0.608MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.061913043478260904']
# ['At iteration 1 the best fitness is 0.061913043478260904']
# ['At iteration 2 the best fitness is 0.05779405034324946']
# ['At iteration 3 the best fitness is 0.05779405034324946']
# ['At iteration 4 the best fitness is 0.05699313501144168']
# ['At iteration 5 the best fitness is 0.04996273291925463']
# ['At iteration 6 the best fitness is 0.04996273291925463']
# ['At iteration 7 the best fitness is 0.04996273291925463']
# ['At iteration 8 the best fitness is 0.045500490356325564']
# ['At iteration 9 the best fitness is 0.045500490356325564']
# ['At iteration 10 the best fitness is 0.045500490356325564']
# ['At iteration 11 the best fitness is 0.045500490356325564']
# ['At iteration 12 the best fitness is 0.045500490356325564']
# ['At iteration 13 the best fitness is 0.045500490356325564']
# ['At iteration 14 the best fitness is 0.045500490356325564']
# ['At iteration 15 the best fitness is 0.0427544949329846']
# ['At iteration 16 the best fitness is 0.0427544949329846']
# ['At iteration 17 the best fitness is 0.0427544949329846']
# ['At iteration 18 the best fitness is 0.0427544949329846']
# ['At iteration 19 the best fitness is 0.04138149722131412']
# ['At iteration 20 the best fitness is 0.04138149722131412']
# ['At iteration 21 the best fitness is 0.04138149722131412']
# ['At iteration 22 the best fitness is 0.04080941484145142']
# ['At iteration 23 the best fitness is 0.04080941484145142']
# ['At iteration 24 the best fitness is 0.04080941484145142']
# ['At iteration 25 the best fitness is 0.04080941484145142']
# ['At iteration 26 the best fitness is 0.04035174893756126']
# ['At iteration 27 the best fitness is 0.04035174893756126']
# ['At iteration 28 the best fitness is 0.04035174893756126']
# ['At iteration 29 the best fitness is 0.04035174893756126']
#       Selected: 69/437 (15.8%), Fitness: 0.0404, Time: 590.6s
#       Modality: D=14%, Sk=16%
#     Test Acc: 92.66%, F1: 91.68%, Features: 69/437 (15.8%), Model: 0.082MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05774305328538735']
# ['At iteration 2 the best fitness is 0.05774305328538735']
# ['At iteration 3 the best fitness is 0.05774305328538735']
# ['At iteration 4 the best fitness is 0.05774305328538735']
# ['At iteration 5 the best fitness is 0.05774305328538735']
# ['At iteration 6 the best fitness is 0.05774305328538735']
# ['At iteration 7 the best fitness is 0.05774305328538735']
# ['At iteration 8 the best fitness is 0.05774305328538735']
# ['At iteration 9 the best fitness is 0.05774305328538735']
# ['At iteration 10 the best fitness is 0.05774305328538735']
# ['At iteration 11 the best fitness is 0.05774305328538735']
# ['At iteration 12 the best fitness is 0.056942137953579566']
# ['At iteration 13 the best fitness is 0.056942137953579566']
# ['At iteration 14 the best fitness is 0.056942137953579566']
# ['At iteration 15 the best fitness is 0.056942137953579566']
# ['At iteration 16 the best fitness is 0.056942137953579566']
# ['At iteration 17 the best fitness is 0.056942137953579566']
# ['At iteration 18 the best fitness is 0.056942137953579566']
# ['At iteration 19 the best fitness is 0.056942137953579566']
# ['At iteration 20 the best fitness is 0.056942137953579566']
# ['At iteration 21 the best fitness is 0.056942137953579566']
# ['At iteration 22 the best fitness is 0.056942137953579566']
# ['At iteration 23 the best fitness is 0.056942137953579566']
# ['At iteration 24 the best fitness is 0.056942137953579566']
# ['At iteration 25 the best fitness is 0.056942137953579566']
# ['At iteration 26 the best fitness is 0.056942137953579566']
# ['At iteration 27 the best fitness is 0.056942137953579566']
# ['At iteration 28 the best fitness is 0.056942137953579566']
# ['At iteration 29 the best fitness is 0.056942137953579566']
#       Selected: 219/437 (50.1%), Fitness: 0.0569, Time: 1546.3s
#       Modality: D=46%, Sk=50%
#     Test Acc: 95.10%, F1: 94.87%, Features: 219/437 (50.1%), Model: 0.763MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06076887871853551']
# ['At iteration 1 the best fitness is 0.06076887871853551']
# ['At iteration 2 the best fitness is 0.05709512912716569']
# ['At iteration 3 the best fitness is 0.05709512912716569']
# ['At iteration 4 the best fitness is 0.052009807126511924']
# ['At iteration 5 the best fitness is 0.052009807126511924']
# ['At iteration 6 the best fitness is 0.047153318077803236']
# ['At iteration 7 the best fitness is 0.04658123569794054']
# ['At iteration 8 the best fitness is 0.04658123569794054']
# ['At iteration 9 the best fitness is 0.04658123569794054']
# ['At iteration 10 the best fitness is 0.04658123569794054']
# ['At iteration 11 the best fitness is 0.04658123569794054']
# ['At iteration 12 the best fitness is 0.04658123569794054']
# ['At iteration 13 the best fitness is 0.04658123569794054']
# ['At iteration 14 the best fitness is 0.04658123569794054']
# ['At iteration 15 the best fitness is 0.04658123569794054']
# ['At iteration 16 the best fitness is 0.04658123569794054']
# ['At iteration 17 the best fitness is 0.04658123569794054']
# ['At iteration 18 the best fitness is 0.04658123569794054']
# ['At iteration 19 the best fitness is 0.04658123569794054']
# ['At iteration 20 the best fitness is 0.04658123569794054']
# ['At iteration 21 the best fitness is 0.04658123569794054']
# ['At iteration 22 the best fitness is 0.04658123569794054']
# ['At iteration 23 the best fitness is 0.04658123569794054']
# ['At iteration 24 the best fitness is 0.04658123569794054']
# ['At iteration 25 the best fitness is 0.04658123569794054']
# ['At iteration 26 the best fitness is 0.04658123569794054']
# ['At iteration 27 the best fitness is 0.04658123569794054']
# ['At iteration 28 the best fitness is 0.04658123569794054']
# ['At iteration 29 the best fitness is 0.04658123569794054']
#       Selected: 104/437 (23.8%), Fitness: 0.0466, Time: 567.5s
#       Modality: D=11%, Sk=25%
#     Test Acc: 94.76%, F1: 94.29%, Features: 104/437 (23.8%), Model: 0.180MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 90.46%, F1: 90.71%, Features: 437/437 (100.0%), Model: 1.390MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 218/437 (49.9%), Time: 2.1s
#     Test Acc: 89.21%, F1: 89.75%, Features: 218/437 (49.9%), Model: 0.756MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 218/437 (49.9%), Time: 0.5s
#     Test Acc: 88.80%, F1: 88.63%, Features: 218/437 (49.9%), Model: 0.756MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 218/437 (49.9%), Time: 0.1s
#     Test Acc: 88.80%, F1: 89.08%, Features: 218/437 (49.9%), Model: 0.756MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02368421052631579']
# ['At iteration 1 the best fitness is 0.02368421052631579']
# ['At iteration 2 the best fitness is 0.02356979405034325']
# ['At iteration 3 the best fitness is 0.02356979405034325']
# ['At iteration 4 the best fitness is 0.02356979405034325']
# ['At iteration 5 the best fitness is 0.02356979405034325']
# ['At iteration 6 the best fitness is 0.02356979405034325']
# ['At iteration 7 the best fitness is 0.02345537757437071']
# ['At iteration 8 the best fitness is 0.02345537757437071']
# ['At iteration 9 the best fitness is 0.02345537757437071']
# ['At iteration 10 the best fitness is 0.02345537757437071']
# ['At iteration 11 the best fitness is 0.02345537757437071']
# ['At iteration 12 the best fitness is 0.02345537757437071']
# ['At iteration 13 the best fitness is 0.02345537757437071']
# ['At iteration 14 the best fitness is 0.02345537757437071']
# ['At iteration 15 the best fitness is 0.02345537757437071']
# ['At iteration 16 the best fitness is 0.02345537757437071']
# ['At iteration 17 the best fitness is 0.02345537757437071']
# ['At iteration 18 the best fitness is 0.02345537757437071']
# ['At iteration 19 the best fitness is 0.02345537757437071']
# ['At iteration 20 the best fitness is 0.02345537757437071']
# ['At iteration 21 the best fitness is 0.02345537757437071']
# ['At iteration 22 the best fitness is 0.02345537757437071']
# ['At iteration 23 the best fitness is 0.02345537757437071']
# ['At iteration 24 the best fitness is 0.02345537757437071']
# ['At iteration 25 the best fitness is 0.02345537757437071']
# ['At iteration 26 the best fitness is 0.02345537757437071']
# ['At iteration 27 the best fitness is 0.02345537757437071']
# ['At iteration 28 the best fitness is 0.02345537757437071']
# ['At iteration 29 the best fitness is 0.02345537757437071']
#       Selected: 202/437 (46.2%), Fitness: 0.0235, Time: 686.4s
#       Modality: D=43%, Sk=46%
#     Test Acc: 88.38%, F1: 88.34%, Features: 202/437 (46.2%), Model: 0.651MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02345537757437071']
# ['At iteration 10 the best fitness is 0.02242562929061785']
# ['At iteration 20 the best fitness is 0.02162471395881007']
#       Selected: 191/437 (43.7%), Fitness: 0.0214, Time: 1347.0s
#       Modality: D=49%, Sk=43%
#     Test Acc: 89.63%, F1: 89.31%, Features: 191/437 (43.7%), Model: 0.584MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023798627002288332']
# ['At iteration 2 the best fitness is 0.023798627002288332']
# ['At iteration 3 the best fitness is 0.023798627002288332']
# ['At iteration 4 the best fitness is 0.023798627002288332']
# ['At iteration 5 the best fitness is 0.023798627002288332']
# ['At iteration 6 the best fitness is 0.02242562929061785']
# ['At iteration 7 the best fitness is 0.02242562929061785']
# ['At iteration 8 the best fitness is 0.02242562929061785']
# ['At iteration 9 the best fitness is 0.02242562929061785']
# ['At iteration 10 the best fitness is 0.02242562929061785']
# ['At iteration 11 the best fitness is 0.02242562929061785']
# ['At iteration 12 the best fitness is 0.02242562929061785']
# ['At iteration 13 the best fitness is 0.02242562929061785']
# ['At iteration 14 the best fitness is 0.02242562929061785']
# ['At iteration 15 the best fitness is 0.02242562929061785']
# ['At iteration 16 the best fitness is 0.02242562929061785']
# ['At iteration 17 the best fitness is 0.02242562929061785']
# ['At iteration 18 the best fitness is 0.02242562929061785']
# ['At iteration 19 the best fitness is 0.02242562929061785']
# ['At iteration 20 the best fitness is 0.02242562929061785']
# ['At iteration 21 the best fitness is 0.02242562929061785']
# ['At iteration 22 the best fitness is 0.02242562929061785']
# ['At iteration 23 the best fitness is 0.02242562929061785']
# ['At iteration 24 the best fitness is 0.02242562929061785']
# ['At iteration 25 the best fitness is 0.02208237986270023']
# ['At iteration 26 the best fitness is 0.02208237986270023']
# ['At iteration 27 the best fitness is 0.02208237986270023']
# ['At iteration 28 the best fitness is 0.02208237986270023']
# ['At iteration 29 the best fitness is 0.02208237986270023']
# ['At iteration 30 the best fitness is 0.02208237986270023']
#       Selected: 197/437 (45.1%), Fitness: 0.0221, Time: 683.1s
#       Modality: D=41%, Sk=46%
#     Test Acc: 89.21%, F1: 89.22%, Features: 197/437 (45.1%), Model: 0.620MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.031135583524027483']
# ['At iteration 1 the best fitness is 0.025400457665903892']
# ['At iteration 2 the best fitness is 0.028847254004576682']
# ['At iteration 3 the best fitness is 0.02873283752860414']
# ['At iteration 4 the best fitness is 0.02356979405034325']
# ['At iteration 5 the best fitness is 0.02356979405034325']
# ['At iteration 6 the best fitness is 0.028275171624713984']
# ['At iteration 7 the best fitness is 0.02356979405034325']
# ['At iteration 8 the best fitness is 0.027588672768878744']
# ['At iteration 9 the best fitness is 0.027588672768878744']
# ['At iteration 10 the best fitness is 0.02781750572082382']
# ['At iteration 11 the best fitness is 0.02231121281464531']
# ['At iteration 12 the best fitness is 0.02219679633867277']
# ['At iteration 13 the best fitness is 0.02231121281464531']
# ['At iteration 14 the best fitness is 0.027474256292906202']
# ['At iteration 15 the best fitness is 0.02242562929061785']
# ['At iteration 16 the best fitness is 0.027474256292906202']
# ['At iteration 17 the best fitness is 0.02254004576659039']
# ['At iteration 18 the best fitness is 0.02254004576659039']
# ['At iteration 19 the best fitness is 0.027703089244851282']
# ['At iteration 20 the best fitness is 0.027703089244851282']
# ['At iteration 21 the best fitness is 0.02254004576659039']
# ['At iteration 22 the best fitness is 0.027703089244851282']
# ['At iteration 23 the best fitness is 0.02254004576659039']
# ['At iteration 24 the best fitness is 0.027703089244851282']
# ['At iteration 25 the best fitness is 0.02254004576659039']
# ['At iteration 26 the best fitness is 0.02254004576659039']
# ['At iteration 27 the best fitness is 0.027703089244851282']
# ['At iteration 28 the best fitness is 0.02254004576659039']
# ['At iteration 29 the best fitness is 0.027703089244851282']
#       Selected: 202/437 (46.2%), Fitness: 0.0277, Time: 660.3s
#       Modality: D=43%, Sk=46%
#     Test Acc: 88.80%, F1: 88.68%, Features: 202/437 (46.2%), Model: 0.651MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.02873283752860414
# At iteration 2 the best fitness is 0.02964816933638446
# At iteration 3 the best fitness is 0.030220251716247166
# At iteration 4 the best fitness is 0.030220251716247166
# At iteration 5 the best fitness is 0.03389588100686503
# At iteration 6 the best fitness is 0.024027459954233412
# At iteration 7 the best fitness is 0.029190503432494304
# At iteration 8 the best fitness is 0.028961670480549224
# At iteration 9 the best fitness is 0.02964816933638446
# At iteration 10 the best fitness is 0.025057208237986274
# At iteration 11 the best fitness is 0.028961670480549224
# At iteration 12 the best fitness is 0.029190503432494304
# At iteration 13 the best fitness is 0.028618421052631602
# At iteration 14 the best fitness is 0.02276887871853547
# At iteration 15 the best fitness is 0.028046338672768904
# At iteration 16 the best fitness is 0.024027459954233412
# At iteration 17 the best fitness is 0.028618421052631602
# At iteration 18 the best fitness is 0.027703089244851282
# At iteration 19 the best fitness is 0.02254004576659039
# At iteration 20 the best fitness is 0.029419336384439384
# At iteration 21 the best fitness is 0.027474256292906202
# At iteration 22 the best fitness is 0.023798627002288332
# At iteration 23 the best fitness is 0.02208237986270023
# At iteration 24 the best fitness is 0.02678775743707096
# At iteration 25 the best fitness is 0.02162471395881007
# At iteration 26 the best fitness is 0.021967963386727688
# At iteration 27 the best fitness is 0.02701659038901604
# At iteration 28 the best fitness is 0.02276887871853547
# At iteration 29 the best fitness is 0.02185354691075515
# At iteration 30 the best fitness is 0.02356979405034325
#       Selected: 211/437 (48.3%), Fitness: 0.0236, Time: 662.6s
#       Modality: D=62%, Sk=47%
#     Test Acc: 89.21%, F1: 89.64%, Features: 211/437 (48.3%), Model: 0.709MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.028504004576659064']
# ['At iteration 1 the best fitness is 0.021739130434782608']
# ['At iteration 2 the best fitness is 0.02116704805491991']
# ['At iteration 3 the best fitness is 0.02116704805491991']
# ['At iteration 4 the best fitness is 0.02116704805491991']
# ['At iteration 5 the best fitness is 0.02116704805491991']
# ['At iteration 6 the best fitness is 0.02116704805491991']
# ['At iteration 7 the best fitness is 0.02116704805491991']
# ['At iteration 8 the best fitness is 0.02116704805491991']
# ['At iteration 9 the best fitness is 0.02116704805491991']
# ['At iteration 10 the best fitness is 0.02116704805491991']
# ['At iteration 11 the best fitness is 0.02116704805491991']
# ['At iteration 12 the best fitness is 0.02116704805491991']
# ['At iteration 13 the best fitness is 0.01876430205949657']
# ['At iteration 14 the best fitness is 0.01876430205949657']
# ['At iteration 15 the best fitness is 0.01876430205949657']
# ['At iteration 16 the best fitness is 0.01681922196796339']
# ['At iteration 17 the best fitness is 0.01681922196796339']
# ['At iteration 18 the best fitness is 0.01681922196796339']
# ['At iteration 19 the best fitness is 0.01681922196796339']
# ['At iteration 20 the best fitness is 0.01681922196796339']
# ['At iteration 21 the best fitness is 0.01681922196796339']
# ['At iteration 22 the best fitness is 0.01681922196796339']
# ['At iteration 23 the best fitness is 0.01636155606407323']
# ['At iteration 24 the best fitness is 0.016247139588100687']
# ['At iteration 25 the best fitness is 0.016247139588100687']
# ['At iteration 26 the best fitness is 0.016247139588100687']
# ['At iteration 27 the best fitness is 0.016247139588100687']
# ['At iteration 28 the best fitness is 0.016247139588100687']
# ['At iteration 29 the best fitness is 0.016247139588100687']
#       Selected: 175/437 (40.0%), Fitness: 0.0162, Time: 645.7s
#       Modality: D=46%, Sk=40%
#     Test Acc: 87.97%, F1: 88.23%, Features: 175/437 (40.0%), Model: 0.492MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.034239130434782654']
# ['At iteration 1 the best fitness is 0.02096681922196801']
# ['At iteration 2 the best fitness is 0.015331807780320367']
# ['At iteration 3 the best fitness is 0.015331807780320367']
# ['At iteration 4 the best fitness is 0.015331807780320367']
# ['At iteration 5 the best fitness is 0.015331807780320367']
# ['At iteration 6 the best fitness is 0.015331807780320367']
# ['At iteration 7 the best fitness is 0.015331807780320367']
# ['At iteration 8 the best fitness is 0.010755148741418766']
# ['At iteration 9 the best fitness is 0.010755148741418766']
# ['At iteration 10 the best fitness is 0.010755148741418766']
# ['At iteration 11 the best fitness is 0.010755148741418766']
# ['At iteration 12 the best fitness is 0.010755148741418766']
# ['At iteration 13 the best fitness is 0.010755148741418766']
# ['At iteration 14 the best fitness is 0.009954233409610984']
# ['At iteration 15 the best fitness is 0.009954233409610984']
# ['At iteration 16 the best fitness is 0.009954233409610984']
# ['At iteration 17 the best fitness is 0.009954233409610984']
# ['At iteration 18 the best fitness is 0.008466819221967964']
# ['At iteration 19 the best fitness is 0.008466819221967964']
# ['At iteration 20 the best fitness is 0.008466819221967964']
# ['At iteration 21 the best fitness is 0.008466819221967964']
# ['At iteration 22 the best fitness is 0.008466819221967964']
# ['At iteration 23 the best fitness is 0.008466819221967964']
# ['At iteration 24 the best fitness is 0.008466819221967964']
# ['At iteration 25 the best fitness is 0.008466819221967964']
# ['At iteration 26 the best fitness is 0.008466819221967964']
# ['At iteration 27 the best fitness is 0.008466819221967964']
# ['At iteration 28 the best fitness is 0.008466819221967964']
# ['At iteration 29 the best fitness is 0.008466819221967964']
#       Selected: 92/437 (21.1%), Fitness: 0.0085, Time: 860.4s
#       Modality: D=14%, Sk=22%
#     Test Acc: 90.46%, F1: 90.81%, Features: 92/437 (21.1%), Model: 0.142MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025057208237986274']
# ['At iteration 1 the best fitness is 0.024942791762013732']
# ['At iteration 2 the best fitness is 0.024942791762013732']
# ['At iteration 3 the best fitness is 0.02185354691075515']
# ['At iteration 4 the best fitness is 0.021739130434782608']
# ['At iteration 5 the best fitness is 0.021739130434782608']
# ['At iteration 6 the best fitness is 0.021739130434782608']
# ['At iteration 7 the best fitness is 0.021739130434782608']
# ['At iteration 8 the best fitness is 0.021739130434782608']
# ['At iteration 9 the best fitness is 0.021739130434782608']
# ['At iteration 10 the best fitness is 0.021739130434782608']
# ['At iteration 11 the best fitness is 0.021739130434782608']
# ['At iteration 12 the best fitness is 0.021739130434782608']
# ['At iteration 13 the best fitness is 0.021739130434782608']
# ['At iteration 14 the best fitness is 0.021739130434782608']
# ['At iteration 15 the best fitness is 0.021739130434782608']
# ['At iteration 16 the best fitness is 0.021739130434782608']
# ['At iteration 17 the best fitness is 0.021739130434782608']
# ['At iteration 18 the best fitness is 0.021739130434782608']
# ['At iteration 19 the best fitness is 0.021739130434782608']
# ['At iteration 20 the best fitness is 0.021739130434782608']
# ['At iteration 21 the best fitness is 0.021739130434782608']
# ['At iteration 22 the best fitness is 0.021739130434782608']
# ['At iteration 23 the best fitness is 0.021739130434782608']
# ['At iteration 24 the best fitness is 0.021739130434782608']
# ['At iteration 25 the best fitness is 0.021739130434782608']
# ['At iteration 26 the best fitness is 0.02128146453089245']
# ['At iteration 27 the best fitness is 0.02128146453089245']
# ['At iteration 28 the best fitness is 0.02128146453089245']
# ['At iteration 29 the best fitness is 0.020823798627002288']
#       Selected: 192/437 (43.9%), Fitness: 0.0208, Time: 684.3s
#       Modality: D=41%, Sk=44%
#     Test Acc: 88.80%, F1: 88.36%, Features: 192/437 (43.9%), Model: 0.590MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.027359839816933663']
# ['At iteration 2 the best fitness is 0.027359839816933663']
# ['At iteration 3 the best fitness is 0.027359839816933663']
# ['At iteration 4 the best fitness is 0.025858123569794052']
# ['At iteration 5 the best fitness is 0.025858123569794052']
# ['At iteration 6 the best fitness is 0.025858123569794052']
# ['At iteration 7 the best fitness is 0.025858123569794052']
# ['At iteration 8 the best fitness is 0.025858123569794052']
# ['At iteration 9 the best fitness is 0.025858123569794052']
# ['At iteration 10 the best fitness is 0.024713958810068652']
# ['At iteration 11 the best fitness is 0.024713958810068652']
# ['At iteration 12 the best fitness is 0.02299771167048055']
# ['At iteration 13 the best fitness is 0.02299771167048055']
# ['At iteration 14 the best fitness is 0.02299771167048055']
# ['At iteration 15 the best fitness is 0.02299771167048055']
# ['At iteration 16 the best fitness is 0.02231121281464531']
# ['At iteration 17 the best fitness is 0.02231121281464531']
# ['At iteration 18 the best fitness is 0.02231121281464531']
# ['At iteration 19 the best fitness is 0.02231121281464531']
# ['At iteration 20 the best fitness is 0.02231121281464531']
# ['At iteration 21 the best fitness is 0.02231121281464531']
# ['At iteration 22 the best fitness is 0.02231121281464531']
# ['At iteration 23 the best fitness is 0.02231121281464531']
# ['At iteration 24 the best fitness is 0.02231121281464531']
# ['At iteration 25 the best fitness is 0.02231121281464531']
# ['At iteration 26 the best fitness is 0.02231121281464531']
# ['At iteration 27 the best fitness is 0.02231121281464531']
# ['At iteration 28 the best fitness is 0.02185354691075515']
# ['At iteration 29 the best fitness is 0.02185354691075515']
#       Selected: 190/437 (43.5%), Fitness: 0.0219, Time: 642.3s
#       Modality: D=38%, Sk=44%
#     Test Acc: 90.04%, F1: 90.07%, Features: 190/437 (43.5%), Model: 0.578MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.029419336384439384']
# ['At iteration 2 the best fitness is 0.02345537757437071']
# ['At iteration 3 the best fitness is 0.02345537757437071']
# ['At iteration 4 the best fitness is 0.02345537757437071']
# ['At iteration 5 the best fitness is 0.02322654462242563']
# ['At iteration 6 the best fitness is 0.023112128146453092']
# ['At iteration 7 the best fitness is 0.023112128146453092']
# ['At iteration 8 the best fitness is 0.023112128146453092']
# ['At iteration 9 the best fitness is 0.023112128146453092']
# ['At iteration 10 the best fitness is 0.023112128146453092']
# ['At iteration 11 the best fitness is 0.023112128146453092']
# ['At iteration 12 the best fitness is 0.023112128146453092']
# ['At iteration 13 the best fitness is 0.023112128146453092']
# ['At iteration 14 the best fitness is 0.023112128146453092']
# ['At iteration 15 the best fitness is 0.023112128146453092']
# ['At iteration 16 the best fitness is 0.023112128146453092']
# ['At iteration 17 the best fitness is 0.023112128146453092']
# ['At iteration 18 the best fitness is 0.023112128146453092']
# ...
# ['At iteration 13 the best fitness is 0.03948554084016076']
# ['At iteration 14 the best fitness is 0.038799041984325516']
# ['At iteration 15 the best fitness is 0.038799041984325516']
# ['At iteration 16 the best fitness is 0.038799041984325516']
# ['At iteration 17 the best fitness is 0.038799041984325516']
# ['At iteration 18 the best fitness is 0.038799041984325516']
# ['At iteration 19 the best fitness is 0.038799041984325516']
# ['At iteration 20 the best fitness is 0.038799041984325516']
# ['At iteration 21 the best fitness is 0.038799041984325516']
# ['At iteration 22 the best fitness is 0.038799041984325516']
# ['At iteration 23 the best fitness is 0.038799041984325516']
# ['At iteration 24 the best fitness is 0.038799041984325516']
# ['At iteration 25 the best fitness is 0.038799041984325516']
# ['At iteration 26 the best fitness is 0.038799041984325516']
# ['At iteration 27 the best fitness is 0.038799041984325516']
# ['At iteration 28 the best fitness is 0.038799041984325516']
# ['At iteration 29 the best fitness is 0.038799041984325516']
#       Selected: 141/437 (32.3%), Fitness: 0.0388, Time: 890.4s
#       Modality: D=30%, Sk=32%
#     Test Acc: 89.90%, F1: 90.76%, Features: 141/437 (32.3%), Model: 0.323MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.048410025966018885']
# ['At iteration 1 the best fitness is 0.048410025966018885']
# ['At iteration 2 the best fitness is 0.048410025966018885']
# ['At iteration 3 the best fitness is 0.048410025966018885']
# ['At iteration 4 the best fitness is 0.048410025966018885']
# ['At iteration 5 the best fitness is 0.048410025966018885']
# ['At iteration 6 the best fitness is 0.048410025966018885']
# ['At iteration 7 the best fitness is 0.04795236006212872']
# ['At iteration 8 the best fitness is 0.04795236006212872']
# ['At iteration 9 the best fitness is 0.04795236006212872']
# ['At iteration 10 the best fitness is 0.0470370282543484']
# ['At iteration 11 the best fitness is 0.0470370282543484']
# ['At iteration 12 the best fitness is 0.0470370282543484']
# ['At iteration 13 the best fitness is 0.0470370282543484']
# ['At iteration 14 the best fitness is 0.0470370282543484']
# ['At iteration 15 the best fitness is 0.0470370282543484']
# ['At iteration 16 the best fitness is 0.0470370282543484']
# ['At iteration 17 the best fitness is 0.0470370282543484']
# ['At iteration 18 the best fitness is 0.0470370282543484']
# ['At iteration 19 the best fitness is 0.0470370282543484']
# ['At iteration 20 the best fitness is 0.0470370282543484']
# ['At iteration 21 the best fitness is 0.0470370282543484']
# ['At iteration 22 the best fitness is 0.0470370282543484']
# ['At iteration 23 the best fitness is 0.0470370282543484']
# ['At iteration 24 the best fitness is 0.0470370282543484']
# ['At iteration 25 the best fitness is 0.0470370282543484']
# ['At iteration 26 the best fitness is 0.0470370282543484']
# ['At iteration 27 the best fitness is 0.04692261177837586']
# ['At iteration 28 the best fitness is 0.04692261177837586']
# ['At iteration 29 the best fitness is 0.04692261177837586']
#       Selected: 204/437 (46.7%), Fitness: 0.0469, Time: 718.9s
#       Modality: D=49%, Sk=46%
#     Test Acc: 89.90%, F1: 90.13%, Features: 204/437 (46.7%), Model: 0.664MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05253139042695723']
# ['At iteration 2 the best fitness is 0.048982108345881584']
# ['At iteration 3 the best fitness is 0.048982108345881584']
# ['At iteration 4 the best fitness is 0.048410025966018885']
# ['At iteration 5 the best fitness is 0.04623611292254062']
# ['At iteration 6 the best fitness is 0.04623611292254062']
# ['At iteration 7 the best fitness is 0.04623611292254062']
# ['At iteration 8 the best fitness is 0.04623611292254062']
# ['At iteration 9 the best fitness is 0.04623611292254062']
# ['At iteration 10 the best fitness is 0.04623611292254062']
# ['At iteration 11 the best fitness is 0.04623611292254062']
# ['At iteration 12 the best fitness is 0.04623611292254062']
# ['At iteration 13 the best fitness is 0.04623611292254062']
# ['At iteration 14 the best fitness is 0.04623611292254062']
# ['At iteration 15 the best fitness is 0.04623611292254062']
# ['At iteration 16 the best fitness is 0.04623611292254062']
# ['At iteration 17 the best fitness is 0.045435197590732834']
# ['At iteration 18 the best fitness is 0.045435197590732834']
# ['At iteration 19 the best fitness is 0.045435197590732834']
# ['At iteration 20 the best fitness is 0.044863115210870136']
# ['At iteration 21 the best fitness is 0.044863115210870136']
# ['At iteration 22 the best fitness is 0.044863115210870136']
# ['At iteration 23 the best fitness is 0.044863115210870136']
# ['At iteration 24 the best fitness is 0.044863115210870136']
# ['At iteration 25 the best fitness is 0.044863115210870136']
# ['At iteration 26 the best fitness is 0.044863115210870136']
# ['At iteration 27 the best fitness is 0.044519865782952514']
# ['At iteration 28 the best fitness is 0.044519865782952514']
# ['At iteration 29 the best fitness is 0.044519865782952514']
#       Selected: 187/437 (42.8%), Fitness: 0.0445, Time: 680.0s
#       Modality: D=46%, Sk=42%
#     Test Acc: 88.38%, F1: 90.00%, Features: 187/437 (42.8%), Model: 0.560MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05115602138935984']
# ['At iteration 2 the best fitness is 0.05035510605755206']
# ['At iteration 3 the best fitness is 0.04943977424977174']
# ['At iteration 4 the best fitness is 0.04943977424977174']
# ['At iteration 5 the best fitness is 0.04943977424977174']
# ['At iteration 6 the best fitness is 0.04886769186990904']
# ['At iteration 7 the best fitness is 0.04886769186990904']
# ['At iteration 8 the best fitness is 0.048410025966018885']
# ['At iteration 9 the best fitness is 0.048410025966018885']
# ['At iteration 10 the best fitness is 0.04795236006212872']
# ['At iteration 11 the best fitness is 0.04795236006212872']
# ['At iteration 12 the best fitness is 0.04795236006212872']
# ['At iteration 13 the best fitness is 0.04795236006212872']
# ['At iteration 14 the best fitness is 0.04795236006212872']
# ['At iteration 15 the best fitness is 0.047265861206293475']
# ['At iteration 16 the best fitness is 0.047265861206293475']
# ['At iteration 17 the best fitness is 0.0470370282543484']
# ['At iteration 18 the best fitness is 0.0470370282543484']
# ['At iteration 19 the best fitness is 0.046693778826430776']
# ['At iteration 20 the best fitness is 0.046693778826430776']
# ['At iteration 21 the best fitness is 0.046693778826430776']
# ['At iteration 22 the best fitness is 0.0464649458744857']
# ['At iteration 23 the best fitness is 0.046350529398513154']
# ['At iteration 24 the best fitness is 0.046350529398513154']
# ['At iteration 25 the best fitness is 0.046350529398513154']
# ['At iteration 26 the best fitness is 0.046350529398513154']
# ['At iteration 27 the best fitness is 0.046350529398513154']
# ['At iteration 28 the best fitness is 0.046350529398513154']
# ['At iteration 29 the best fitness is 0.046350529398513154']
# ['At iteration 30 the best fitness is 0.046350529398513154']
#       Selected: 214/437 (49.0%), Fitness: 0.0464, Time: 706.7s
#       Modality: D=59%, Sk=48%
#     Test Acc: 85.86%, F1: 85.62%, Features: 214/437 (49.0%), Model: 0.729MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04852444244199142']
# ['At iteration 2 the best fitness is 0.04772352711018364']
# ['At iteration 3 the best fitness is 0.04738027768226602']
# ['At iteration 4 the best fitness is 0.04738027768226602']
# ['At iteration 5 the best fitness is 0.04738027768226602']
# ['At iteration 6 the best fitness is 0.04738027768226602']
# ['At iteration 7 the best fitness is 0.04738027768226602']
# ['At iteration 8 the best fitness is 0.04738027768226602']
# ['At iteration 9 the best fitness is 0.04715144473032094']
# ['At iteration 10 the best fitness is 0.04715144473032094']
# ['At iteration 11 the best fitness is 0.04715144473032094']
# ['At iteration 12 the best fitness is 0.04715144473032094']
# ['At iteration 13 the best fitness is 0.04715144473032094']
# ['At iteration 14 the best fitness is 0.04715144473032094']
# ['At iteration 15 the best fitness is 0.04715144473032094']
# ['At iteration 16 the best fitness is 0.04715144473032094']
# ['At iteration 17 the best fitness is 0.04715144473032094']
# ['At iteration 18 the best fitness is 0.04715144473032094']
# ['At iteration 19 the best fitness is 0.04715144473032094']
# ['At iteration 20 the best fitness is 0.04715144473032094']
# ['At iteration 21 the best fitness is 0.0464649458744857']
# ['At iteration 22 the best fitness is 0.0464649458744857']
# ['At iteration 23 the best fitness is 0.0464649458744857']
# ['At iteration 24 the best fitness is 0.0464649458744857']
# ['At iteration 25 the best fitness is 0.0464649458744857']
# ['At iteration 26 the best fitness is 0.04612169644656808']
# ['At iteration 27 the best fitness is 0.04612169644656808']
# ['At iteration 28 the best fitness is 0.04612169644656808']
# ['At iteration 29 the best fitness is 0.04612169644656808']
# ['At iteration 30 the best fitness is 0.04612169644656808']
#       Selected: 196/437 (44.9%), Fitness: 0.0461, Time: 702.1s
#       Modality: D=54%, Sk=44%
#     Test Acc: 81.82%, F1: 81.03%, Features: 196/437 (44.9%), Model: 0.614MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05070072681139659']
# ['At iteration 1 the best fitness is 0.0453207811147603']
# ['At iteration 2 the best fitness is 0.04440544930697998']
# ['At iteration 3 the best fitness is 0.04383336692711728']
# ['At iteration 4 the best fitness is 0.041773870359611553']
# ['At iteration 5 the best fitness is 0.03857020903238044']
# ['At iteration 6 the best fitness is 0.03857020903238044']
# ['At iteration 7 the best fitness is 0.03822695960446282']
# ['At iteration 8 the best fitness is 0.03799812665251774']
# ['At iteration 9 the best fitness is 0.03582421360903948']
# ['At iteration 10 the best fitness is 0.03548096418112186']
# ['At iteration 11 the best fitness is 0.03399354999347884']
# ['At iteration 12 the best fitness is 0.03399354999347884']
# ['At iteration 13 the best fitness is 0.03399354999347884']
# ['At iteration 14 the best fitness is 0.03399354999347884']
# ['At iteration 15 the best fitness is 0.03353588408958867']
# ['At iteration 16 the best fitness is 0.0327349687577809']
# ['At iteration 17 the best fitness is 0.03227730285389073']
# ['At iteration 18 the best fitness is 0.03227730285389073']
# ['At iteration 19 the best fitness is 0.03227730285389073']
# ['At iteration 20 the best fitness is 0.03227730285389073']
# ['At iteration 21 the best fitness is 0.03227730285389073']
# ['At iteration 22 the best fitness is 0.03227730285389073']
# ['At iteration 23 the best fitness is 0.03227730285389073']
# ['At iteration 24 the best fitness is 0.03227730285389073']
# ['At iteration 25 the best fitness is 0.03227730285389073']
# ['At iteration 26 the best fitness is 0.03227730285389073']
# ['At iteration 27 the best fitness is 0.03227730285389073']
# ['At iteration 28 the best fitness is 0.03227730285389073']
# ['At iteration 29 the best fitness is 0.03227730285389073']
#       Selected: 82/437 (18.8%), Fitness: 0.0323, Time: 677.3s
#       Modality: D=22%, Sk=18%
#     Test Acc: 90.40%, F1: 90.88%, Features: 82/437 (18.8%), Model: 0.114MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04921094129782666']
# ['At iteration 2 the best fitness is 0.04921094129782666']
# ['At iteration 3 the best fitness is 0.04921094129782666']
# ['At iteration 4 the best fitness is 0.048410025966018885']
# ['At iteration 5 the best fitness is 0.04772352711018364']
# ['At iteration 6 the best fitness is 0.04772352711018364']
# ['At iteration 7 the best fitness is 0.04772352711018364']
# ['At iteration 8 the best fitness is 0.04772352711018364']
# ['At iteration 9 the best fitness is 0.04772352711018364']
# ['At iteration 10 the best fitness is 0.04772352711018364']
# ['At iteration 11 the best fitness is 0.047609110634211096']
# ['At iteration 12 the best fitness is 0.047494694158238565']
# ['At iteration 13 the best fitness is 0.047494694158238565']
# ['At iteration 14 the best fitness is 0.04738027768226602']
# ['At iteration 15 the best fitness is 0.047265861206293475']
# ['At iteration 16 the best fitness is 0.047265861206293475']
# ['At iteration 17 the best fitness is 0.047265861206293475']
# ['At iteration 18 the best fitness is 0.047265861206293475']
# ['At iteration 19 the best fitness is 0.047265861206293475']
# ['At iteration 20 the best fitness is 0.047265861206293475']
# ['At iteration 21 the best fitness is 0.047265861206293475']
# ['At iteration 22 the best fitness is 0.047265861206293475']
# ['At iteration 23 the best fitness is 0.047265861206293475']
# ['At iteration 24 the best fitness is 0.047265861206293475']
# ['At iteration 25 the best fitness is 0.047265861206293475']
# ['At iteration 26 the best fitness is 0.047265861206293475']
# ['At iteration 27 the best fitness is 0.047265861206293475']
# ['At iteration 28 the best fitness is 0.047265861206293475']
# ['At iteration 29 the best fitness is 0.047265861206293475']
#       Selected: 206/437 (47.1%), Fitness: 0.0473, Time: 1748.1s
#       Modality: D=46%, Sk=47%
#     Test Acc: 90.91%, F1: 91.39%, Features: 206/437 (47.1%), Model: 0.677MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04921094129782666']
# ['At iteration 1 the best fitness is 0.04578318967050428']
# ['At iteration 2 the best fitness is 0.040860909877758145']
# ['At iteration 3 the best fitness is 0.040860909877758145']
# ['At iteration 4 the best fitness is 0.03456563237334154']
# ['At iteration 5 the best fitness is 0.03456563237334154']
# ['At iteration 6 the best fitness is 0.03456563237334154']
# ['At iteration 7 the best fitness is 0.03456563237334154']
# ['At iteration 8 the best fitness is 0.03456563237334154']
# ['At iteration 9 the best fitness is 0.03456563237334154']
# ['At iteration 10 the best fitness is 0.03456563237334154']
# ['At iteration 11 the best fitness is 0.03456563237334154']
# ['At iteration 12 the best fitness is 0.03456563237334154']
# ['At iteration 13 the best fitness is 0.03456563237334154']
# ['At iteration 14 the best fitness is 0.03456563237334154']
# ['At iteration 15 the best fitness is 0.03456563237334154']
# ['At iteration 16 the best fitness is 0.03456563237334154']
# ['At iteration 17 the best fitness is 0.03456563237334154']
# ['At iteration 18 the best fitness is 0.03456563237334154']
# ['At iteration 19 the best fitness is 0.03445121589736899']
# ['At iteration 20 the best fitness is 0.03445121589736899']
# ['At iteration 21 the best fitness is 0.03445121589736899']
# ['At iteration 22 the best fitness is 0.03445121589736899']
# ['At iteration 23 the best fitness is 0.03445121589736899']
# ['At iteration 24 the best fitness is 0.03445121589736899']
# ['At iteration 25 the best fitness is 0.03445121589736899']
# ['At iteration 26 the best fitness is 0.03445121589736899']
# ['At iteration 27 the best fitness is 0.03445121589736899']
# ['At iteration 28 the best fitness is 0.03445121589736899']
# ['At iteration 29 the best fitness is 0.03445121589736899']
#       Selected: 103/437 (23.6%), Fitness: 0.0345, Time: 614.6s
#       Modality: D=22%, Sk=24%
#     Test Acc: 90.40%, F1: 90.49%, Features: 103/437 (23.6%), Model: 0.177MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_no_sensor/all_results_per_fold.csv
# Shape: (90, 24)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  skeleton_retention (%)  skeleton_selected
# 0      baseline     1            93.0070           95.4286       92.1953          92.1953              94.6425           93.0070                437             437               100.0000       0.0000         10.7178         10.7178        362774           1.3897                 3.8842                  3.8842                 0.0000        25.6274             100.0000              37                  100.00                400
# 1      baseline     2            90.4564          100.0000       90.7101          90.6934              93.1909           90.4545                437             437               100.0000       0.0000         11.3362         11.3362        362774           1.3897                 3.8842                  3.8842                 0.0000        25.6274             100.0000              37                  100.00                400
# 2      baseline     3            94.0909           98.9418       94.0536          94.0536              95.1674           94.0909                437             437               100.0000       0.0000         11.5510         11.5510        362774           1.3897                 3.8842                  3.8842                 0.0000        25.6289             100.0000              37                  100.00                400
# 3      baseline     4            88.6364           96.2963       88.2412          88.2412              91.3719           88.6364                437             437               100.0000       0.0000         11.0111         11.0111        362774           1.3897                 3.8842                  3.8842                 0.0000        25.6289             100.0000              37                  100.00                400
# 4      baseline     5            88.8889           97.4093       88.7713          88.7713              90.5491           88.8889                437             437               100.0000       0.0000         11.6521         11.6521        362774           1.3897                 3.8842                  3.8842                 0.0000        25.6274             100.0000              37                  100.00                400
# 5   mutual_info     1            94.7552           97.1429       94.1460          94.1460              95.7975           94.7552                218             437                49.8856       2.1708         10.2768         12.4477        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154              10.8108               4                   53.50                214
# 6   mutual_info     2            89.2116          100.0000       89.7521          89.7314              92.7194           89.2149                218             437                49.8856       2.1354         11.0765         13.2120        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154              16.2162               6                   53.00                212
# 7   mutual_info     3            93.1818           99.4709       93.0171          93.0171              94.9306           93.1818                218             437                49.8856       2.1586         11.0915         13.2501        196876           0.7560                 3.8842                  1.9376                50.1144        21.8193              13.5135               5                   53.25                213
# 8   mutual_info     4            95.0000           97.3545       94.6598          94.6598              96.2982           95.0000                218             437                49.8856       2.1470         10.8523         12.9994        196876           0.7560                 3.8842                  1.9376                50.1144        21.8193               8.1081               3                   53.75                215
# 9   mutual_info     5            95.9596           97.4093       95.9340          95.9340              96.6230           95.9596                218             437                49.8856       2.1306         11.3357         13.4664        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154               8.1081               3                   53.75                215
# 10          rfe     1            93.0070           97.1429       91.8515          91.8515              94.9633           93.0070                218             437                49.8856       0.4487         10.0983         10.5472        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154               8.1081               3                   53.75                215
# 11          rfe     2            88.7967          100.0000       88.6310          88.6057              91.7854           88.8017                218             437                49.8856       0.4608         11.0966         11.5577        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154              10.8108               4                   53.50                214
# 12          rfe     3            95.4545           99.4709       95.2643          95.2643              96.4399           95.4545                218             437                49.8856       0.4615         11.1908         11.6526        196876           0.7560                 3.8842                  1.9376                50.1144        21.8193               8.1081               3                   53.75                215
# 13          rfe     4            92.7273           97.3545       92.4399          92.4399              94.4928           92.7273                218             437                49.8856       0.4664         10.7488         11.2155        196876           0.7560                 3.8842                  1.9376                50.1144        21.8193               8.1081               3                   53.75                215
# 14          rfe     5            95.9596           97.4093       95.9964          95.9964              96.7562           95.9596                218             437                49.8856       0.4560         11.4068         11.8630        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154              10.8108               4                   53.50                214
# 15        lasso     1            89.5105           95.4286       88.3740          88.3740              91.6601           89.5105                218             437                49.8856       0.0618         10.4116         10.4735        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154              81.0811              30                   47.00                188
# 16        lasso     2            88.7967          100.0000       89.0814          89.0579              91.3688           88.8017                218             437                49.8856       0.0682         11.3382         11.4065        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154              81.0811              30                   47.00                188
# 17        lasso     3            93.1818           98.4127       92.9245          92.9245              94.8642           93.1818                218             437                49.8856       0.0731         10.6499         10.7231        196876           0.7560                 3.8842                  1.9376                50.1144        21.8193              81.0811              30                   47.00                188
# 18        lasso     4            93.6364           96.8254       93.5202          93.5202              94.3395           93.6364                218             437                49.8856       0.0695         10.8795         10.9490        196876           0.7560                 3.8842                  1.9376                50.1144        21.8193              81.0811              30                   47.00                188
# 19        lasso     5            83.8384           97.4093       84.0315          84.0315              87.4414           83.8384                218             437                49.8856       0.0738         11.5912         11.6651        196876           0.7560                 3.8842                  1.9376                50.1144        21.8154              81.0811              30                   47.00                188

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              91.02              2.45              90.79              2.41                   437.0                      100.00              0.00                11.25                11.25           362774.0                  1.39                        0.00               25.63
# mutual_info              93.62              2.66              93.50              2.34                   218.0                       49.89              2.15                10.93                13.08           196876.0                  0.76                       50.11               21.82
#         rfe              93.19              2.84              92.84              2.95                   218.0                       49.89              0.46                10.91                11.37           196876.0                  0.76                       50.11               21.82
#       lasso              89.79              3.96              89.59              3.85                   218.0                       49.89              0.07                10.97                11.04           196876.0                  0.76                       50.11               21.82
#    meta_BAT              89.42              3.37              88.61              3.23                   209.8                       48.01            685.56                11.20               696.76           183382.6                  0.70                       51.99               21.51
#     meta_CS              87.61              4.45              86.87              4.44                   207.4                       47.46           1347.66                11.21              1358.87           179121.0                  0.69                       52.54               21.41
#     meta_DE              92.25              3.52              92.11              3.53                   197.8                       45.26            684.24                11.13               695.37           162684.2                  0.63                       54.74               21.04
#    meta_FFA              89.03              8.03              88.74              8.17                   207.0                       47.37            661.95                11.26               673.20           178049.4                  0.68                       52.63               21.39
#     meta_GA              89.06              3.69              88.84              3.45                   209.4                       47.92            662.62                11.16               673.79           182138.2                  0.70                       52.08               21.48
#    meta_GWO              92.65              5.16              92.20              5.51                   163.0                       37.30            648.72                10.92               659.64           113819.8                  0.44                       62.70               19.91
#    meta_HHO              92.00              3.03              92.00              3.15                    99.8                       22.84            814.75                10.64               825.40            45022.2                  0.17                       77.16               18.32
#   meta_JAYA              91.49              4.27              91.09              4.54                   202.2                       46.27            681.44                11.24               692.68           169945.4                  0.65                       53.73               21.20
#    meta_MFO              88.92              4.29              88.14              5.41                   200.8                       45.95            642.23                11.18               653.42           168211.6                  0.65                       54.05               21.16
#    meta_MVO              88.97              6.68              88.47              7.26                   210.2                       48.10            663.02                11.21               674.23           183332.6                  0.70                       51.90               21.51
#    meta_PSO              90.42              5.55              89.96              5.71                   206.4                       47.23            662.49                11.17               673.66           177234.8                  0.68                       52.77               21.37
#    meta_SCA              91.58              3.90              91.20              4.05                    77.4                       17.71            635.25                10.38               645.62            26849.4                  0.10                       82.29               17.90
#    meta_SSA              91.08              3.33              91.11              3.29                   213.6                       48.88           1653.09                11.22              1664.31           189870.8                  0.73                       51.12               21.66
#    meta_WOA              88.81              3.96              88.55              4.09                   107.4                       24.58            599.84                10.21               610.06            50774.6                  0.20                       75.42               18.45

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 93.62% vs Baseline: 91.02%
#   Paired t-test: t=1.4803, p=0.2129
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> better, Not significant
#
# RFE vs BASELINE:
#   Method: 93.19% vs Baseline: 91.02%
#   Paired t-test: t=1.4066, p=0.2323
#   Wilcoxon test: W=2.0000, p=0.3750
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 89.79% vs Baseline: 91.02%
#   Paired t-test: t=-0.7132, p=0.5151
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 89.42% vs Baseline: 91.02%
#   Paired t-test: t=-1.6734, p=0.1696
#   Wilcoxon test: W=1.0000, p=0.2500
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 87.61% vs Baseline: 91.02%
#   Paired t-test: t=-2.7197, p=0.0530
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 92.25% vs Baseline: 91.02%
#   Paired t-test: t=1.6432, p=0.1757
#   Wilcoxon test: W=2.0000, p=0.1875
#   -> better, Not significant
#
# META_FFA vs BASELINE:
#   Method: 89.03% vs Baseline: 91.02%
#   Paired t-test: t=-0.6513, p=0.5504
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 89.06% vs Baseline: 91.02%
#   Paired t-test: t=-2.1005, p=0.1036
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 92.65% vs Baseline: 91.02%
#   Paired t-test: t=0.8886, p=0.4244
#   Wilcoxon test: W=3.0000, p=0.6250
#   -> better, Not significant
#
# META_HHO vs BASELINE:
#   Method: 92.00% vs Baseline: 91.02%
#   Paired t-test: t=2.7148, p=0.0533
#   Wilcoxon test: W=0.0000, p=0.1250
#   -> better, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 91.49% vs Baseline: 91.02%
#   Paired t-test: t=0.4996, p=0.6436
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> better, Not significant
#
# META_MFO vs BASELINE:
#   Method: 88.92% vs Baseline: 91.02%
#   Paired t-test: t=-1.7538, p=0.1543
#   Wilcoxon test: W=0.0000, p=0.0625
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 88.97% vs Baseline: 91.02%
#   Paired t-test: t=-1.0375, p=0.3581
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 90.42% vs Baseline: 91.02%
#   Paired t-test: t=-0.2611, p=0.8069
#   Wilcoxon test: W=6.0000, p=0.8125
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 91.58% vs Baseline: 91.02%
#   Paired t-test: t=0.5197, p=0.6307
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> better, Not significant
#
# META_SSA vs BASELINE:
#   Method: 91.08% vs Baseline: 91.02%
#   Paired t-test: t=0.0694, p=0.9480
#   Wilcoxon test: W=5.0000, p=1.0000
#   -> better, Not significant
#
# META_WOA vs BASELINE:
#   Method: 88.81% vs Baseline: 91.02%
#   Paired t-test: t=-1.0815, p=0.3403
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_no_sensor
#
# Per-method folders:
#   results_no_sensor/baseline/ (10 files)
#   results_no_sensor/mutual_info/ (10 files)
#   results_no_sensor/rfe/ (10 files)
#   results_no_sensor/lasso/ (10 files)
#   results_no_sensor/meta_BAT/ (10 files)
#   results_no_sensor/meta_CS/ (10 files)
#   results_no_sensor/meta_DE/ (10 files)
#   results_no_sensor/meta_FFA/ (10 files)
#   results_no_sensor/meta_GA/ (10 files)
#   results_no_sensor/meta_GWO/ (10 files)
#   results_no_sensor/meta_HHO/ (10 files)
#   results_no_sensor/meta_JAYA/ (10 files)
#   results_no_sensor/meta_MFO/ (10 files)
#   results_no_sensor/meta_MVO/ (10 files)
#   results_no_sensor/meta_PSO/ (10 files)
#   results_no_sensor/meta_SCA/ (10 files)
#   results_no_sensor/meta_SSA/ (10 files)
#   results_no_sensor/meta_WOA/ (10 files)
#
# Plots directory: results_no_sensor/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   mutual_info         : 93.62% ± 2.66% (Features: 49.9%)
#   rfe                 : 93.19% ± 2.84% (Features: 49.9%)
#   meta_GWO            : 92.65% ± 5.16% (Features: 37.3%)
#   meta_DE             : 92.25% ± 3.52% (Features: 45.3%)
#   meta_HHO            : 92.00% ± 3.03% (Features: 22.8%)
