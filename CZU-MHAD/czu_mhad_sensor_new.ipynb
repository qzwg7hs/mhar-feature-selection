# %% [markdown]
# # CZU-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new")

# Master output directory
RESULTS_ROOT = Path("results_sensor_new")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 5
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 5
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'sensor': first_sample['sensor_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 1165 samples
# Number of classes: 22
# Number of subjects: 5
#
# Feature dimensions:
#   sensor: 652
#   TOTAL: 652

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['sensor_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: "
          f"S={modality_ret['sensor']['percentage']:.0f}%, ")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

        print(f"  Subjects - Train: {np.unique(subjects[train_val_idx][train_indices])}, "
      f"Val: {np.unique(subjects[train_val_idx][val_indices])}, "
      f"Test: {np.unique(subjects[test_idx])}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 5
# ================================================================================
#
# ################################################################################
# # FOLD 1/5
# ################################################################################
#   Train: 704, Val: 175, Test: 286
#   Subjects - Train: ['cyy' 'myj' 'qyh' 'zyh'], Val: ['cyy' 'myj' 'qyh' 'zyh'], Test: ['cx']
#
#   --- BASELINE ---
#     Test Acc: 83.22%, F1: 83.20%, Features: 652/652 (100.0%), Model: 1.810MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 326/652 (50.0%), Time: 3.2s
#     Test Acc: 89.16%, F1: 88.17%, Features: 326/652 (50.0%), Model: 1.173MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 326/652 (50.0%), Time: 0.6s
#     Test Acc: 89.51%, F1: 89.54%, Features: 326/652 (50.0%), Model: 1.173MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 326/652 (50.0%), Time: 0.1s
#     Test Acc: 82.87%, F1: 82.53%, Features: 326/652 (50.0%), Model: 1.173MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.039982033304119174']
# ['At iteration 1 the best fitness is 0.039982033304119174']
# ['At iteration 2 the best fitness is 0.039982033304119174']
# ['At iteration 3 the best fitness is 0.039982033304119174']
# ['At iteration 4 the best fitness is 0.039982033304119174']
# ['At iteration 5 the best fitness is 0.039982033304119174']
# ['At iteration 6 the best fitness is 0.039982033304119174']
# ['At iteration 7 the best fitness is 0.034553461875547795']
# ['At iteration 8 the best fitness is 0.034553461875547795']
# ['At iteration 9 the best fitness is 0.02874145486415421']
# ['At iteration 10 the best fitness is 0.02874145486415421']
# ['At iteration 11 the best fitness is 0.02874145486415421']
# ['At iteration 12 the best fitness is 0.02874145486415421']
# ['At iteration 13 the best fitness is 0.02874145486415421']
# ['At iteration 14 the best fitness is 0.02874145486415421']
# ['At iteration 15 the best fitness is 0.02874145486415421']
# ['At iteration 16 the best fitness is 0.02874145486415421']
# ['At iteration 17 the best fitness is 0.02874145486415421']
# ['At iteration 18 the best fitness is 0.02874145486415421']
# ['At iteration 19 the best fitness is 0.02874145486415421']
# ['At iteration 20 the best fitness is 0.02874145486415421']
# ['At iteration 21 the best fitness is 0.02874145486415421']
# ['At iteration 22 the best fitness is 0.028664767747589793']
# ['At iteration 23 the best fitness is 0.023312883435582823']
# ['At iteration 24 the best fitness is 0.023312883435582823']
# ['At iteration 25 the best fitness is 0.023312883435582823']
# ['At iteration 26 the best fitness is 0.023312883435582823']
# ['At iteration 27 the best fitness is 0.023312883435582823']
# ['At iteration 28 the best fitness is 0.023312883435582823']
# ['At iteration 29 the best fitness is 0.023312883435582823']
#       Selected: 307/652 (47.1%), Fitness: 0.0233, Time: 666.4s
#       Modality: S=47%,
#     Test Acc: 86.01%, F1: 85.52%, Features: 307/652 (47.1%), Model: 1.136MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.040825591586327765']
# ['At iteration 10 the best fitness is 0.03188562664329532']
# ['At iteration 20 the best fitness is 0.0300451358457493']
#       Selected: 321/652 (49.2%), Fitness: 0.0300, Time: 1304.9s
#       Modality: S=49%,
#     Test Acc: 85.31%, F1: 84.69%, Features: 321/652 (49.2%), Model: 1.163MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.040825591586327765']
# ['At iteration 2 the best fitness is 0.040825591586327765']
# ['At iteration 3 the best fitness is 0.03739088518843123']
# ['At iteration 4 the best fitness is 0.03739088518843123']
# ['At iteration 5 the best fitness is 0.03739088518843123']
# ['At iteration 6 the best fitness is 0.03739088518843123']
# ['At iteration 7 the best fitness is 0.03532033304119196']
# ['At iteration 8 the best fitness is 0.03035188431200697']
# ['At iteration 9 the best fitness is 0.03035188431200697']
# ['At iteration 10 the best fitness is 0.03035188431200697']
# ['At iteration 11 the best fitness is 0.03035188431200697']
# ['At iteration 12 the best fitness is 0.029968448729184884']
# ['At iteration 13 the best fitness is 0.029968448729184884']
# ['At iteration 14 the best fitness is 0.029968448729184884']
# ['At iteration 15 the best fitness is 0.029968448729184884']
# ['At iteration 16 the best fitness is 0.029968448729184884']
# ['At iteration 17 the best fitness is 0.029968448729184884']
# ['At iteration 18 the best fitness is 0.029968448729184884']
# ['At iteration 19 the best fitness is 0.02904820333041188']
# ['At iteration 20 the best fitness is 0.028894829097283047']
# ['At iteration 21 the best fitness is 0.028894829097283047']
# ['At iteration 22 the best fitness is 0.028894829097283047']
# ['At iteration 23 the best fitness is 0.028894829097283047']
# ['At iteration 24 the best fitness is 0.02881814198071863']
# ['At iteration 25 the best fitness is 0.02881814198071863']
# ['At iteration 26 the best fitness is 0.02881814198071863']
# ['At iteration 27 the best fitness is 0.02881814198071863']
# ['At iteration 28 the best fitness is 0.02881814198071863']
# ['At iteration 29 the best fitness is 0.02881814198071863']
# ['At iteration 30 the best fitness is 0.02881814198071863']
#       Selected: 316/652 (48.5%), Fitness: 0.0288, Time: 662.0s
#       Modality: S=48%,
#     Test Acc: 78.67%, F1: 77.89%, Features: 316/652 (48.5%), Model: 1.153MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0464075372480281']
# ['At iteration 1 the best fitness is 0.03555039439088521']
# ['At iteration 2 the best fitness is 0.04228264680105169']
# ['At iteration 3 the best fitness is 0.04113234005258544']
# ['At iteration 4 the best fitness is 0.035703768624014046']
# ['At iteration 5 the best fitness is 0.035933829973707296']
# ['At iteration 6 the best fitness is 0.035473707274320795']
# ['At iteration 7 the best fitness is 0.029968448729184884']
# ['At iteration 8 the best fitness is 0.03555039439088521']
# ['At iteration 9 the best fitness is 0.04090227870289218']
# ['At iteration 10 the best fitness is 0.035473707274320795']
# ['At iteration 11 the best fitness is 0.03555039439088521']
# ['At iteration 12 the best fitness is 0.04090227870289218']
# ['At iteration 13 the best fitness is 0.04113234005258544']
# ['At iteration 14 the best fitness is 0.04090227870289218']
# ['At iteration 15 the best fitness is 0.03035188431200697']
# ['At iteration 16 the best fitness is 0.03562708150744963']
# ['At iteration 17 the best fitness is 0.035703768624014046']
# ['At iteration 18 the best fitness is 0.03562708150744963']
# ['At iteration 19 the best fitness is 0.035703768624014046']
# ['At iteration 20 the best fitness is 0.030198510078878138']
# ['At iteration 21 the best fitness is 0.03562708150744963']
# ['At iteration 22 the best fitness is 0.03562708150744963']
# ['At iteration 23 the best fitness is 0.04105565293602102']
# ['At iteration 24 the best fitness is 0.03562708150744963']
# ['At iteration 25 the best fitness is 0.03562708150744963']
# ['At iteration 26 the best fitness is 0.04105565293602102']
# ['At iteration 27 the best fitness is 0.03562708150744963']
# ['At iteration 28 the best fitness is 0.03562708150744963']
# ['At iteration 29 the best fitness is 0.03562708150744963']
#       Selected: 341/652 (52.3%), Fitness: 0.0356, Time: 645.9s
#       Modality: S=52%,
#     Test Acc: 80.07%, F1: 79.85%, Features: 341/652 (52.3%), Model: 1.202MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.04151577563540752
# At iteration 2 the best fitness is 0.040442156003505675
# At iteration 3 the best fitness is 0.04205258545135844
# At iteration 4 the best fitness is 0.03647063978965823
# At iteration 5 the best fitness is 0.03585714285714288
# At iteration 6 the best fitness is 0.04067221735319893
# At iteration 7 the best fitness is 0.03585714285714288
# At iteration 8 the best fitness is 0.036163891323400546
# At iteration 9 the best fitness is 0.03585714285714288
# At iteration 10 the best fitness is 0.03608720420683613
# At iteration 11 the best fitness is 0.03608720420683613
# At iteration 12 the best fitness is 0.03608720420683613
# At iteration 13 the best fitness is 0.03601051709027171
# At iteration 14 the best fitness is 0.03562708150744963
# At iteration 15 the best fitness is 0.035473707274320795
# At iteration 16 the best fitness is 0.03532033304119196
# At iteration 17 the best fitness is 0.04013540753724801
# At iteration 18 the best fitness is 0.03578045574057846
# At iteration 19 the best fitness is 0.030505258545135805
# At iteration 20 the best fitness is 0.029968448729184884
# At iteration 21 the best fitness is 0.034323400525854544
# At iteration 22 the best fitness is 0.034323400525854544
# At iteration 23 the best fitness is 0.029354951796669547
# At iteration 24 the best fitness is 0.034783523225241045
# At iteration 25 the best fitness is 0.03470683610867663
# At iteration 26 the best fitness is 0.029585013146362797
# At iteration 27 the best fitness is 0.030275197195442555
# At iteration 28 the best fitness is 0.035013584574934295
# At iteration 29 the best fitness is 0.03035188431200697
# At iteration 30 the best fitness is 0.03624057843996496
#       Selected: 313/652 (48.0%), Fitness: 0.0362, Time: 642.4s
#       Modality: S=48%,
#     Test Acc: 81.82%, F1: 81.58%, Features: 313/652 (48.0%), Model: 1.148MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04182252410166519']
# ['At iteration 1 the best fitness is 0.04182252410166519']
# ['At iteration 2 the best fitness is 0.03967528483786151']
# ['At iteration 3 the best fitness is 0.038371603856266416']
# ['At iteration 4 the best fitness is 0.03294303242769503']
# ['At iteration 5 the best fitness is 0.02797458369851004']
# ['At iteration 6 the best fitness is 0.02797458369851004']
# ['At iteration 7 the best fitness is 0.02797458369851004']
# ['At iteration 8 the best fitness is 0.02797458369851004']
# ['At iteration 9 the best fitness is 0.02797458369851004']
# ['At iteration 10 the best fitness is 0.02797458369851004']
# ['At iteration 11 the best fitness is 0.02797458369851004']
# ['At iteration 12 the best fitness is 0.02797458369851004']
# ['At iteration 13 the best fitness is 0.02797458369851004']
# ['At iteration 14 the best fitness is 0.02797458369851004']
# ['At iteration 15 the best fitness is 0.02797458369851004']
# ['At iteration 16 the best fitness is 0.026134092900964027']
# ['At iteration 17 the best fitness is 0.026134092900964027']
# ['At iteration 18 the best fitness is 0.026134092900964027']
# ['At iteration 19 the best fitness is 0.026134092900964027']
# ['At iteration 20 the best fitness is 0.026134092900964027']
# ['At iteration 21 the best fitness is 0.026134092900964027']
# ['At iteration 22 the best fitness is 0.026134092900964027']
# ['At iteration 23 the best fitness is 0.026134092900964027']
# ['At iteration 24 the best fitness is 0.026134092900964027']
# ['At iteration 25 the best fitness is 0.026134092900964027']
# ['At iteration 26 the best fitness is 0.026134092900964027']
# ['At iteration 27 the best fitness is 0.026134092900964027']
# ['At iteration 28 the best fitness is 0.026134092900964027']
# ['At iteration 29 the best fitness is 0.026134092900964027']
#       Selected: 283/652 (43.4%), Fitness: 0.0261, Time: 634.7s
#       Modality: S=43%,
#     Test Acc: 84.62%, F1: 84.69%, Features: 283/652 (43.4%), Model: 1.089MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.046484224364592514']
# ['At iteration 1 the best fitness is 0.046484224364592514']
# ['At iteration 2 the best fitness is 0.041806310254163065']
# ['At iteration 3 the best fitness is 0.03367747589833484']
# ['At iteration 4 the best fitness is 0.03367747589833484']
# ['At iteration 5 the best fitness is 0.03145354951796674']
# ['At iteration 6 the best fitness is 0.03145354951796674']
# ['At iteration 7 the best fitness is 0.03145354951796674']
# ['At iteration 8 the best fitness is 0.03145354951796674']
# ['At iteration 9 the best fitness is 0.03145354951796674']
# ['At iteration 10 the best fitness is 0.03145354951796674']
# ['At iteration 11 the best fitness is 0.03145354951796674']
# ['At iteration 12 the best fitness is 0.03145354951796674']
# ['At iteration 13 the best fitness is 0.03145354951796674']
# ['At iteration 14 the best fitness is 0.03145354951796674']
# ['At iteration 15 the best fitness is 0.03145354951796674']
# ['At iteration 16 the best fitness is 0.03145354951796674']
# ['At iteration 17 the best fitness is 0.03145354951796674']
# ['At iteration 18 the best fitness is 0.03145354951796674']
# ['At iteration 19 the best fitness is 0.03145354951796674']
# ['At iteration 20 the best fitness is 0.03145354951796674']
# ['At iteration 21 the best fitness is 0.03145354951796674']
# ['At iteration 22 the best fitness is 0.03145354951796674']
# ['At iteration 23 the best fitness is 0.03145354951796674']
# ['At iteration 24 the best fitness is 0.02610166520595967']
# ['At iteration 25 the best fitness is 0.02610166520595967']
# ['At iteration 26 the best fitness is 0.02610166520595967']
# ['At iteration 27 the best fitness is 0.02610166520595967']
# ['At iteration 28 the best fitness is 0.02610166520595967']
# ['At iteration 29 the best fitness is 0.02610166520595967']
#       Selected: 156/652 (23.9%), Fitness: 0.0261, Time: 782.6s
#       Modality: S=24%,
#     Test Acc: 82.17%, F1: 81.74%, Features: 156/652 (23.9%), Model: 0.393MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03967528483786151']
# ['At iteration 1 the best fitness is 0.03967528483786151']
# ['At iteration 2 the best fitness is 0.03959859772129709']
# ['At iteration 3 the best fitness is 0.02759114811568795']
# ['At iteration 4 the best fitness is 0.02759114811568795']
# ['At iteration 5 the best fitness is 0.02759114811568795']
# ['At iteration 6 the best fitness is 0.02759114811568795']
# ['At iteration 7 the best fitness is 0.02759114811568795']
# ['At iteration 8 the best fitness is 0.02759114811568795']
# ['At iteration 9 the best fitness is 0.02759114811568795']
# ['At iteration 10 the best fitness is 0.02759114811568795']
# ['At iteration 11 the best fitness is 0.02759114811568795']
# ['At iteration 12 the best fitness is 0.02759114811568795']
# ['At iteration 13 the best fitness is 0.02759114811568795']
# ['At iteration 14 the best fitness is 0.02759114811568795']
# ['At iteration 15 the best fitness is 0.02759114811568795']
# ['At iteration 16 the best fitness is 0.02759114811568795']
# ['At iteration 17 the best fitness is 0.02759114811568795']
# ['At iteration 18 the best fitness is 0.02759114811568795']
# ['At iteration 19 the best fitness is 0.02759114811568795']
# ['At iteration 20 the best fitness is 0.02759114811568795']
# ['At iteration 21 the best fitness is 0.02759114811568795']
# ['At iteration 22 the best fitness is 0.02759114811568795']
# ['At iteration 23 the best fitness is 0.02759114811568795']
# ['At iteration 24 the best fitness is 0.02759114811568795']
# ['At iteration 25 the best fitness is 0.02759114811568795']
# ['At iteration 26 the best fitness is 0.02759114811568795']
# ['At iteration 27 the best fitness is 0.02759114811568795']
# ['At iteration 28 the best fitness is 0.02759114811568795']
# ['At iteration 29 the best fitness is 0.02759114811568795']
#       Selected: 278/652 (42.6%), Fitness: 0.0276, Time: 663.8s
#       Modality: S=43%,
#     Test Acc: 76.92%, F1: 76.71%, Features: 278/652 (42.6%), Model: 1.079MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04174583698510077']
# ['At iteration 2 the best fitness is 0.04174583698510077']
# ['At iteration 3 the best fitness is 0.03486021034180546']
# ['At iteration 4 the best fitness is 0.03486021034180546']
# ['At iteration 5 the best fitness is 0.03486021034180546']
# ['At iteration 6 the best fitness is 0.03486021034180546']
# ['At iteration 7 the best fitness is 0.03486021034180546']
# ['At iteration 8 the best fitness is 0.03486021034180546']
# ['At iteration 9 the best fitness is 0.03486021034180546']
# ['At iteration 10 the best fitness is 0.03065863277826464']
# ['At iteration 11 the best fitness is 0.03065863277826464']
# ['At iteration 12 the best fitness is 0.03065863277826464']
# ['At iteration 13 the best fitness is 0.03065863277826464']
# ['At iteration 14 the best fitness is 0.03065863277826464']
# ['At iteration 15 the best fitness is 0.03065863277826464']
# ['At iteration 16 the best fitness is 0.03065863277826464']
# ['At iteration 17 the best fitness is 0.03065863277826464']
# ['At iteration 18 the best fitness is 0.030275197195442555']
# ['At iteration 19 the best fitness is 0.030275197195442555']
# ['At iteration 20 the best fitness is 0.030275197195442555']
# ['At iteration 21 the best fitness is 0.030275197195442555']
# ['At iteration 22 the best fitness is 0.030275197195442555']
# ['At iteration 23 the best fitness is 0.030275197195442555']
# ['At iteration 24 the best fitness is 0.030275197195442555']
# ['At iteration 25 the best fitness is 0.030275197195442555']
# ['At iteration 26 the best fitness is 0.030275197195442555']
# ['At iteration 27 the best fitness is 0.030275197195442555']
# ['At iteration 28 the best fitness is 0.030275197195442555']
# ['At iteration 29 the best fitness is 0.030275197195442555']
#       Selected: 328/652 (50.3%), Fitness: 0.0303, Time: 621.9s
#       Modality: S=50%,
#     Test Acc: 84.62%, F1: 84.11%, Features: 328/652 (50.3%), Model: 1.177MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04074890446976335']
# ['At iteration 2 the best fitness is 0.03562708150744963']
# ['At iteration 3 the best fitness is 0.03516695880806313']
# ['At iteration 4 the best fitness is 0.03516695880806313']
# ['At iteration 5 the best fitness is 0.03516695880806313']
# ['At iteration 6 the best fitness is 0.029891761612620468']
# ['At iteration 7 the best fitness is 0.029891761612620468']
# ['At iteration 8 the best fitness is 0.029891761612620468']
# ['At iteration 9 the best fitness is 0.029891761612620468']
# ['At iteration 10 the best fitness is 0.029891761612620468']
# ['At iteration 11 the best fitness is 0.029891761612620468']
# ['At iteration 12 the best fitness is 0.029891761612620468']
# ['At iteration 13 the best fitness is 0.029891761612620468']
# ['At iteration 14 the best fitness is 0.029891761612620468']
# ['At iteration 15 the best fitness is 0.029891761612620468']
# ['At iteration 16 the best fitness is 0.029891761612620468']
# ['At iteration 17 the best fitness is 0.029891761612620468']
# ['At iteration 18 the best fitness is 0.029891761612620468']
# ['At iteration 19 the best fitness is 0.029891761612620468']
# ['At iteration 20 the best fitness is 0.029891761612620468']
# ['At iteration 21 the best fitness is 0.029891761612620468']
# ['At iteration 22 the best fitness is 0.029891761612620468']
# ['At iteration 23 the best fitness is 0.029891761612620468']
# ['At iteration 24 the best fitness is 0.029891761612620468']
# ['At iteration 25 the best fitness is 0.029891761612620468']
# ['At iteration 26 the best fitness is 0.029891761612620468']
# ['At iteration 27 the best fitness is 0.029891761612620468']
# ['At iteration 28 the best fitness is 0.029891761612620468']
# ['At iteration 29 the best fitness is 0.029891761612620468']
# ['At iteration 30 the best fitness is 0.029891761612620468']
#       Selected: 307/652 (47.1%), Fitness: 0.0299, Time: 646.3s
#       Modality: S=47%,
#     Test Acc: 79.02%, F1: 78.83%, Features: 307/652 (47.1%), Model: 1.136MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03509027169149871']
# ['At iteration 2 the best fitness is 0.034783523225241045']
# ['At iteration 3 the best fitness is 0.034783523225241045']
# ['At iteration 4 the best fitness is 0.034783523225241045']
# ['At iteration 5 the best fitness is 0.034783523225241045']
# ['At iteration 6 the best fitness is 0.034783523225241045']
# ['At iteration 7 the best fitness is 0.034783523225241045']
# ['At iteration 8 the best fitness is 0.034783523225241045']
# ['At iteration 9 the best fitness is 0.03065863277826464']
# ['At iteration 10 the best fitness is 0.03065863277826464']
# ['At iteration 11 the best fitness is 0.03065863277826464']
# ['At iteration 12 the best fitness is 0.03065863277826464']
# ['At iteration 13 the best fitness is 0.03065863277826464']
# ['At iteration 14 the best fitness is 0.03065863277826464']
# ['At iteration 15 the best fitness is 0.03065863277826464']
# ['At iteration 16 the best fitness is 0.03065863277826464']
# ['At iteration 17 the best fitness is 0.03065863277826464']
# ['At iteration 18 the best fitness is 0.03065863277826464']
# ['At iteration 19 the best fitness is 0.03065863277826464']
# ['At iteration 20 the best fitness is 0.03065863277826464']
# ['At iteration 21 the best fitness is 0.03065863277826464']
# ['At iteration 22 the best fitness is 0.03065863277826464']
# ['At iteration 23 the best fitness is 0.03065863277826464']
# ['At iteration 24 the best fitness is 0.03065863277826464']
# ['At iteration 25 the best fitness is 0.03065863277826464']
# ['At iteration 26 the best fitness is 0.03065863277826464']
# ['At iteration 27 the best fitness is 0.03065863277826464']
# ['At iteration 28 the best fitness is 0.03065863277826464']
# ['At iteration 29 the best fitness is 0.03065863277826464']
# ['At iteration 30 the best fitness is 0.03065863277826464']
#       Selected: 318/652 (48.8%), Fitness: 0.0307, Time: 643.2s
#       Modality: S=49%,
#     Test Acc: 81.47%, F1: 81.78%, Features: 318/652 (48.8%), Model: 1.157MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0468676599474146']
# ['At iteration 1 the best fitness is 0.038294916739702']
# ['At iteration 2 the best fitness is 0.0360709903593339']
# ['At iteration 3 the best fitness is 0.0360709903593339']
# ['At iteration 4 the best fitness is 0.0360709903593339']
# ['At iteration 5 the best fitness is 0.03308019281332163']
# ['At iteration 6 the best fitness is 0.03308019281332163']
# ['At iteration 7 the best fitness is 0.019615687992988566']
# ['At iteration 8 the best fitness is 0.019615687992988566']
# ['At iteration 9 the best fitness is 0.019615687992988566']
# ['At iteration 10 the best fitness is 0.019615687992988566']
# ['At iteration 11 the best fitness is 0.019615687992988566']
# ['At iteration 12 the best fitness is 0.019615687992988566']
# ['At iteration 13 the best fitness is 0.019615687992988566']
# ['At iteration 14 the best fitness is 0.019615687992988566']
# ['At iteration 15 the best fitness is 0.019615687992988566']
# ['At iteration 16 the best fitness is 0.019615687992988566']
# ['At iteration 17 the best fitness is 0.019615687992988566']
# ['At iteration 18 the best fitness is 0.019615687992988566']
# ['At iteration 19 the best fitness is 0.019615687992988566']
# ['At iteration 20 the best fitness is 0.019615687992988566']
# ['At iteration 21 the best fitness is 0.019615687992988566']
# ['At iteration 22 the best fitness is 0.019615687992988566']
# ['At iteration 23 the best fitness is 0.019615687992988566']
# ['At iteration 24 the best fitness is 0.019615687992988566']
# ['At iteration 25 the best fitness is 0.019615687992988566']
# ['At iteration 26 the best fitness is 0.019615687992988566']
# ['At iteration 27 the best fitness is 0.019615687992988566']
# ['At iteration 28 the best fitness is 0.019615687992988566']
# ['At iteration 29 the best fitness is 0.019615687992988566']
#       Selected: 191/652 (29.3%), Fitness: 0.0196, Time: 621.1s
#       Modality: S=29%,
#     Test Acc: 83.22%, F1: 82.88%, Features: 191/652 (29.3%), Model: 0.584MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.035243645924627545']
# ['At iteration 2 the best fitness is 0.035243645924627545']
# ['At iteration 3 the best fitness is 0.035243645924627545']
# ['At iteration 4 the best fitness is 0.031118755477651146']
# ['At iteration 5 the best fitness is 0.031118755477651146']
# ['At iteration 6 the best fitness is 0.031118755477651146']
# ['At iteration 7 the best fitness is 0.031118755477651146']
# ['At iteration 8 the best fitness is 0.0300451358457493']
# ['At iteration 9 the best fitness is 0.02881814198071863']
# ['At iteration 10 the best fitness is 0.02881814198071863']
# ['At iteration 11 the best fitness is 0.02881814198071863']
# ['At iteration 12 the best fitness is 0.02881814198071863']
# ['At iteration 13 the best fitness is 0.02874145486415421']
# ['At iteration 14 the best fitness is 0.02874145486415421']
# ['At iteration 15 the best fitness is 0.02874145486415421']
# ['At iteration 16 the best fitness is 0.02874145486415421']
# ['At iteration 17 the best fitness is 0.02874145486415421']
# ['At iteration 18 the best fitness is 0.02874145486415421']
# ['At iteration 19 the best fitness is 0.02874145486415421']
# ['At iteration 20 the best fitness is 0.02874145486415421']
# ['At iteration 21 the best fitness is 0.02874145486415421']
# ['At iteration 22 the best fitness is 0.02874145486415421']
# ['At iteration 23 the best fitness is 0.02874145486415421']
# ['At iteration 24 the best fitness is 0.02874145486415421']
# ['At iteration 25 the best fitness is 0.02874145486415421']
# ['At iteration 26 the best fitness is 0.02851139351446096']
# ['At iteration 27 the best fitness is 0.02851139351446096']
# ['At iteration 28 the best fitness is 0.02851139351446096']
# ['At iteration 29 the best fitness is 0.023082822085889573']
#       Selected: 305/652 (46.8%), Fitness: 0.0231, Time: 1608.0s
#       Modality: S=47%,
#     Test Acc: 84.97%, F1: 84.82%, Features: 305/652 (46.8%), Model: 1.132MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04090227870289218']
# ['At iteration 1 the best fitness is 0.04090227870289218']
# ['At iteration 2 the best fitness is 0.040825591586327765']
# ['At iteration 3 the best fitness is 0.03814154250657316']
# ['At iteration 4 the best fitness is 0.03814154250657316']
# ['At iteration 5 the best fitness is 0.03814154250657316']
# ['At iteration 6 the best fitness is 0.03814154250657316']
# ['At iteration 7 the best fitness is 0.03814154250657316']
# ['At iteration 8 the best fitness is 0.03538080631025414']
# ['At iteration 9 the best fitness is 0.03292681858019279']
# ['At iteration 10 the best fitness is 0.03292681858019279']
# ['At iteration 11 the best fitness is 0.031086327782646785']
# ['At iteration 12 the best fitness is 0.031086327782646785']
# ['At iteration 13 the best fitness is 0.031086327782646785']
# ['At iteration 14 the best fitness is 0.031086327782646785']
# ['At iteration 15 the best fitness is 0.03085626643295353']
# ['At iteration 16 the best fitness is 0.03085626643295353']
# ['At iteration 17 the best fitness is 0.03085626643295353']
# ['At iteration 18 the best fitness is 0.03085626643295353']
# ['At iteration 19 the best fitness is 0.03085626643295353']
# ['At iteration 20 the best fitness is 0.03085626643295353']
# ['At iteration 21 the best fitness is 0.03085626643295353']
# ['At iteration 22 the best fitness is 0.03085626643295353']
# ['At iteration 23 the best fitness is 0.03085626643295353']
# ['At iteration 24 the best fitness is 0.023143295354951757']
# ['At iteration 25 the best fitness is 0.023143295354951757']
# ['At iteration 26 the best fitness is 0.023143295354951757']
# ['At iteration 27 the best fitness is 0.023143295354951757']
# ['At iteration 28 the best fitness is 0.023143295354951757']
# ['At iteration 29 the best fitness is 0.023143295354951757']
#       Selected: 236/652 (36.2%), Fitness: 0.0231, Time: 614.0s
#       Modality: S=36%,
#     Test Acc: 79.02%, F1: 78.06%, Features: 236/652 (36.2%), Model: 0.883MB
#
# ################################################################################
# # FOLD 2/5
# ################################################################################
#   Train: 740, Val: 184, Test: 241
#   Subjects - Train: ['cx' 'cyy' 'myj' 'zyh'], Val: ['cx' 'cyy' 'myj' 'zyh'], Test: ['qyh']
#
#   --- BASELINE ---
#     Test Acc: 85.06%, F1: 84.69%, Features: 652/652 (100.0%), Model: 1.810MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 326/652 (50.0%), Time: 3.2s
#     Test Acc: 90.87%, F1: 90.73%, Features: 326/652 (50.0%), Model: 1.173MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 326/652 (50.0%), Time: 0.6s
#     Test Acc: 94.61%, F1: 94.61%, Features: 326/652 (50.0%), Model: 1.173MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 326/652 (50.0%), Time: 0.1s
#     Test Acc: 85.89%, F1: 85.56%, Features: 326/652 (50.0%), Model: 1.173MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.044041744465190706']
# ['At iteration 1 the best fitness is 0.044041744465190706']
# ['At iteration 2 the best fitness is 0.044041744465190706']
# ['At iteration 3 the best fitness is 0.038955388103494235']
# ['At iteration 4 the best fitness is 0.038955388103494235']
# ['At iteration 5 the best fitness is 0.038955388103494235']
# ['At iteration 6 the best fitness is 0.038955388103494235']
# ['At iteration 7 the best fitness is 0.038955388103494235']
# ['At iteration 8 the best fitness is 0.038955388103494235']
# ['At iteration 9 the best fitness is 0.038955388103494235']
# ['At iteration 10 the best fitness is 0.038955388103494235']
# ['At iteration 11 the best fitness is 0.038955388103494235']
# ['At iteration 12 the best fitness is 0.038955388103494235']
# ['At iteration 13 the best fitness is 0.038955388103494235']
# ['At iteration 14 the best fitness is 0.038955388103494235']
# ['At iteration 15 the best fitness is 0.038955388103494235']
# ['At iteration 16 the best fitness is 0.038955388103494235']
# ['At iteration 17 the best fitness is 0.038955388103494235']
# ['At iteration 18 the best fitness is 0.038955388103494235']
# ['At iteration 19 the best fitness is 0.038955388103494235']
# ['At iteration 20 the best fitness is 0.038955388103494235']
# ['At iteration 21 the best fitness is 0.038955388103494235']
# ['At iteration 22 the best fitness is 0.038955388103494235']
# ['At iteration 23 the best fitness is 0.038955388103494235']
# ['At iteration 24 the best fitness is 0.038955388103494235']
# ['At iteration 25 the best fitness is 0.038955388103494235']
# ['At iteration 26 the best fitness is 0.038955388103494235']
# ['At iteration 27 the best fitness is 0.038955388103494235']
# ['At iteration 28 the best fitness is 0.038955388103494235']
# ['At iteration 29 the best fitness is 0.038955388103494235']
#       Selected: 315/652 (48.3%), Fitness: 0.0390, Time: 713.3s
#       Modality: S=48%,
#     Test Acc: 86.31%, F1: 85.63%, Features: 315/652 (48.3%), Model: 1.151MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05112196585756203']
# ['At iteration 10 the best fitness is 0.04465524139770604']
# ['At iteration 20 the best fitness is 0.03563283542277945']
#       Selected: 325/652 (49.8%), Fitness: 0.0354, Time: 1404.6s
#       Modality: S=50%,
#     Test Acc: 88.38%, F1: 88.21%, Features: 325/652 (49.8%), Model: 1.171MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.051658775673512944']
# ['At iteration 2 the best fitness is 0.04465524139770604']
# ['At iteration 3 the best fitness is 0.04465524139770604']
# ['At iteration 4 the best fitness is 0.04465524139770604']
# ['At iteration 5 the best fitness is 0.04465524139770604']
# ['At iteration 6 the best fitness is 0.04465524139770604']
# ['At iteration 7 the best fitness is 0.04465524139770604']
# ['At iteration 8 the best fitness is 0.04450186716457721']
# ['At iteration 9 the best fitness is 0.03956888503600957']
# ['At iteration 10 the best fitness is 0.03956888503600957']
# ['At iteration 11 the best fitness is 0.03956888503600957']
# ['At iteration 12 the best fitness is 0.03956888503600957']
# ['At iteration 13 the best fitness is 0.03956888503600957']
# ['At iteration 14 the best fitness is 0.03956888503600957']
# ['At iteration 15 the best fitness is 0.03956888503600957']
# ['At iteration 16 the best fitness is 0.03956888503600957']
# ['At iteration 17 the best fitness is 0.03956888503600957']
# ['At iteration 18 the best fitness is 0.03956888503600957']
# ['At iteration 19 the best fitness is 0.03956888503600957']
# ['At iteration 20 the best fitness is 0.03956888503600957']
# ['At iteration 21 the best fitness is 0.03956888503600957']
# ['At iteration 22 the best fitness is 0.037651707121899136']
# ['At iteration 23 the best fitness is 0.037651707121899136']
# ['At iteration 24 the best fitness is 0.037651707121899136']
# ['At iteration 25 the best fitness is 0.037651707121899136']
# ['At iteration 26 the best fitness is 0.037651707121899136']
# ['At iteration 27 the best fitness is 0.037651707121899136']
# ['At iteration 28 the best fitness is 0.037651707121899136']
# ['At iteration 29 the best fitness is 0.037651707121899136']
# ['At iteration 30 the best fitness is 0.037651707121899136']
#       Selected: 302/652 (46.3%), Fitness: 0.0377, Time: 712.8s
#       Modality: S=46%,
#     Test Acc: 85.06%, F1: 84.63%, Features: 302/652 (46.3%), Model: 1.126MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04488530274739929']
# ['At iteration 1 the best fitness is 0.04958822352627368']
# ['At iteration 2 the best fitness is 0.062138236863163464']
# ['At iteration 3 the best fitness is 0.05983762336623095']
# ['At iteration 4 the best fitness is 0.0562083222192585']
# ['At iteration 5 the best fitness is 0.059684249133102114']
# ['At iteration 6 the best fitness is 0.05452120565484132']
# ['At iteration 7 the best fitness is 0.05551813817017874']
# ['At iteration 8 the best fitness is 0.059684249133102114']
# ['At iteration 9 the best fitness is 0.05528807682048549']
# ['At iteration 10 the best fitness is 0.05505801547079224']
# ['At iteration 11 the best fitness is 0.055441451053614324']
# ['At iteration 12 the best fitness is 0.06022105894905303']
# ['At iteration 13 the best fitness is 0.0501250333422246']
# ['At iteration 14 the best fitness is 0.05536476393704991']
# ['At iteration 15 the best fitness is 0.060527807415310705']
# ['At iteration 16 the best fitness is 0.05536476393704991']
# ['At iteration 17 the best fitness is 0.05528807682048549']
# ['At iteration 18 the best fitness is 0.0501250333422246']
# ['At iteration 19 the best fitness is 0.05528807682048549']
# ['At iteration 20 the best fitness is 0.06045112029874629']
# ['At iteration 21 the best fitness is 0.06045112029874629']
# ['At iteration 22 the best fitness is 0.06045112029874629']
# ['At iteration 23 the best fitness is 0.06045112029874629']
# ['At iteration 24 the best fitness is 0.06045112029874629']
# ['At iteration 25 the best fitness is 0.05528807682048549']
# ['At iteration 26 the best fitness is 0.0501250333422246']
# ['At iteration 27 the best fitness is 0.05528807682048549']
# ['At iteration 28 the best fitness is 0.06045112029874629']
# ['At iteration 29 the best fitness is 0.06045112029874629']
#       Selected: 315/652 (48.3%), Fitness: 0.0605, Time: 690.0s
#       Modality: S=48%,
#     Test Acc: 84.23%, F1: 83.44%, Features: 315/652 (48.3%), Model: 1.151MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.05536476393704991
# At iteration 2 the best fitness is 0.06160142704721254
# At iteration 3 the best fitness is 0.044961989863963714
# At iteration 4 the best fitness is 0.04094925313416907
# At iteration 5 the best fitness is 0.05651507068551617
# At iteration 6 the best fitness is 0.04749266471058948
# At iteration 7 the best fitness is 0.05119865297412644
# At iteration 8 the best fitness is 0.04511536409709255
# At iteration 9 the best fitness is 0.050278407575353436
# At iteration 10 the best fitness is 0.05513470258735666
# At iteration 11 the best fitness is 0.05490464123766341
# At iteration 12 the best fitness is 0.05597826086956525
# At iteration 13 the best fitness is 0.050278407575353436
# At iteration 14 the best fitness is 0.0458055481461723
# At iteration 15 the best fitness is 0.03547946118965062
# At iteration 16 the best fitness is 0.04603560949586555
# At iteration 17 the best fitness is 0.04289143771672445
# At iteration 18 the best fitness is 0.04396505734862628
# At iteration 19 the best fitness is 0.03903207522005865
# At iteration 20 the best fitness is 0.0397222592691384
# At iteration 21 the best fitness is 0.04148606295012
# At iteration 22 the best fitness is 0.03995232061883165
# At iteration 23 the best fitness is 0.03903207522005865
# At iteration 24 the best fitness is 0.03670645505468129
# At iteration 25 the best fitness is 0.03910876233662307
# At iteration 26 the best fitness is 0.044808615630834873
# At iteration 27 the best fitness is 0.03949219791944515
# At iteration 28 the best fitness is 0.03949219791944515
# At iteration 29 the best fitness is 0.03949219791944515
# At iteration 30 the best fitness is 0.04488530274739929
#       Selected: 321/652 (49.2%), Fitness: 0.0449, Time: 688.1s
#       Modality: S=49%,
#     Test Acc: 90.46%, F1: 90.32%, Features: 321/652 (49.2%), Model: 1.163MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05135202720725528']
# ['At iteration 1 the best fitness is 0.04549879967991463']
# ['At iteration 2 the best fitness is 0.04549879967991463']
# ['At iteration 3 the best fitness is 0.04258468925046678']
# ['At iteration 4 the best fitness is 0.041894505201387024']
# ['At iteration 5 the best fitness is 0.03864863963723656']
# ['At iteration 6 the best fitness is 0.03172179247799418']
# ['At iteration 7 the best fitness is 0.031338356895172094']
# ['At iteration 8 the best fitness is 0.031338356895172094']
# ['At iteration 9 the best fitness is 0.030801547079221177']
# ['At iteration 10 the best fitness is 0.03034142437983467']
# ['At iteration 11 the best fitness is 0.03034142437983467']
# ['At iteration 12 the best fitness is 0.02425813550280077']
# ['At iteration 13 the best fitness is 0.02425813550280077']
# ['At iteration 14 the best fitness is 0.02425813550280077']
# ['At iteration 15 the best fitness is 0.02425813550280077']
# ['At iteration 16 the best fitness is 0.02425813550280077']
# ['At iteration 17 the best fitness is 0.02425813550280077']
# ['At iteration 18 the best fitness is 0.02425813550280077']
# ['At iteration 19 the best fitness is 0.02425813550280077']
# ['At iteration 20 the best fitness is 0.023337890104027766']
# ['At iteration 21 the best fitness is 0.023337890104027766']
# ['At iteration 22 the best fitness is 0.023337890104027766']
# ['At iteration 23 the best fitness is 0.023337890104027766']
# ['At iteration 24 the best fitness is 0.023337890104027766']
# ['At iteration 25 the best fitness is 0.023337890104027766']
# ['At iteration 26 the best fitness is 0.023337890104027766']
# ['At iteration 27 the best fitness is 0.023337890104027766']
# ['At iteration 28 the best fitness is 0.023337890104027766']
# ['At iteration 29 the best fitness is 0.023337890104027766']
#       Selected: 265/652 (40.6%), Fitness: 0.0233, Time: 686.9s
#       Modality: S=41%,
#     Test Acc: 90.87%, F1: 90.72%, Features: 265/652 (40.6%), Model: 1.054MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.05597826086956525']
# ['At iteration 1 the best fitness is 0.04250800213390236']
# ['At iteration 2 the best fitness is 0.03647472659375835']
# ['At iteration 3 the best fitness is 0.025740197385969638']
# ['At iteration 4 the best fitness is 0.025740197385969638']
# ['At iteration 5 the best fitness is 0.025740197385969638']
# ['At iteration 6 the best fitness is 0.025740197385969638']
# ['At iteration 7 the best fitness is 0.025740197385969638']
# ['At iteration 8 the best fitness is 0.025050013336889887']
# ['At iteration 9 the best fitness is 0.025050013336889887']
# ['At iteration 10 the best fitness is 0.025050013336889887']
# ['At iteration 11 the best fitness is 0.025050013336889887']
# ['At iteration 12 the best fitness is 0.025050013336889887']
# ['At iteration 13 the best fitness is 0.025050013336889887']
# ['At iteration 14 the best fitness is 0.025050013336889887']
# ['At iteration 15 the best fitness is 0.018659975993598317']
# ['At iteration 16 the best fitness is 0.018659975993598317']
# ['At iteration 17 the best fitness is 0.018659975993598317']
# ['At iteration 18 the best fitness is 0.018659975993598317']
# ['At iteration 19 the best fitness is 0.018659975993598317']
# ['At iteration 20 the best fitness is 0.018659975993598317']
# ['At iteration 21 the best fitness is 0.018659975993598317']
# ['At iteration 22 the best fitness is 0.018659975993598317']
# ['At iteration 23 the best fitness is 0.018659975993598317']
# ['At iteration 24 the best fitness is 0.018659975993598317']
# ['At iteration 25 the best fitness is 0.018659975993598317']
# ['At iteration 26 the best fitness is 0.018659975993598317']
# ['At iteration 27 the best fitness is 0.018659975993598317']
# ['At iteration 28 the best fitness is 0.018659975993598317']
# ['At iteration 29 the best fitness is 0.018659975993598317']
#       Selected: 187/652 (28.7%), Fitness: 0.0187, Time: 909.7s
#       Modality: S=29%,
#     Test Acc: 85.89%, F1: 85.26%, Features: 187/652 (28.7%), Model: 0.560MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04503867698052813']
# ['At iteration 1 the best fitness is 0.04503867698052813']
# ['At iteration 2 the best fitness is 0.04488530274739929']
# ['At iteration 3 the best fitness is 0.04488530274739929']
# ['At iteration 4 the best fitness is 0.04488530274739929']
# ['At iteration 5 the best fitness is 0.04488530274739929']
# ['At iteration 6 the best fitness is 0.04488530274739929']
# ['At iteration 7 the best fitness is 0.04488530274739929']
# ['At iteration 8 the best fitness is 0.04488530274739929']
# ['At iteration 9 the best fitness is 0.04488530274739929']
# ['At iteration 10 the best fitness is 0.04488530274739929']
# ['At iteration 11 the best fitness is 0.044808615630834873']
# ['At iteration 12 the best fitness is 0.044808615630834873']
# ['At iteration 13 the best fitness is 0.044808615630834873']
# ['At iteration 14 the best fitness is 0.044808615630834873']
# ['At iteration 15 the best fitness is 0.044808615630834873']
# ['At iteration 16 the best fitness is 0.044808615630834873']
# ['At iteration 17 the best fitness is 0.044808615630834873']
# ['At iteration 18 the best fitness is 0.044808615630834873']
# ['At iteration 19 the best fitness is 0.044808615630834873']
# ['At iteration 20 the best fitness is 0.044808615630834873']
# ['At iteration 21 the best fitness is 0.044808615630834873']
# ['At iteration 22 the best fitness is 0.044808615630834873']
# ['At iteration 23 the best fitness is 0.044808615630834873']
# ['At iteration 24 the best fitness is 0.044808615630834873']
# ['At iteration 25 the best fitness is 0.044808615630834873']
# ['At iteration 26 the best fitness is 0.04025906908508932']
# ['At iteration 27 the best fitness is 0.04025906908508932']
# ['At iteration 28 the best fitness is 0.04025906908508932']
# ['At iteration 29 the best fitness is 0.04025906908508932']
#       Selected: 313/652 (48.0%), Fitness: 0.0403, Time: 714.5s
#       Modality: S=48%,
#     Test Acc: 87.97%, F1: 87.13%, Features: 313/652 (48.0%), Model: 1.148MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06060449453187512']
# ['At iteration 2 the best fitness is 0.050891904507868777']
# ['At iteration 3 the best fitness is 0.050891904507868777']
# ['At iteration 4 the best fitness is 0.049664910642838095']
# ['At iteration 5 the best fitness is 0.049664910642838095']
# ['At iteration 6 the best fitness is 0.049664910642838095']
# ['At iteration 7 the best fitness is 0.04951153640970926']
# ['At iteration 8 the best fitness is 0.039185449453187485']
# ['At iteration 9 the best fitness is 0.039185449453187485']
# ['At iteration 10 the best fitness is 0.039185449453187485']
# ['At iteration 11 the best fitness is 0.039185449453187485']
# ['At iteration 12 the best fitness is 0.039185449453187485']
# ['At iteration 13 the best fitness is 0.034252467324619944']
# ['At iteration 14 the best fitness is 0.034252467324619944']
# ['At iteration 15 the best fitness is 0.034252467324619944']
# ['At iteration 16 the best fitness is 0.034252467324619944']
# ['At iteration 17 the best fitness is 0.034252467324619944']
# ['At iteration 18 the best fitness is 0.034252467324619944']
# ['At iteration 19 the best fitness is 0.034252467324619944']
# ['At iteration 20 the best fitness is 0.03394571885836228']
# ['At iteration 21 the best fitness is 0.03394571885836228']
# ['At iteration 22 the best fitness is 0.03340890904241136']
# ['At iteration 23 the best fitness is 0.03340890904241136']
# ['At iteration 24 the best fitness is 0.028245865564150464']
# ['At iteration 25 the best fitness is 0.028245865564150464']
# ['At iteration 26 the best fitness is 0.028245865564150464']
# ['At iteration 27 the best fitness is 0.028245865564150464']
# ['At iteration 28 the best fitness is 0.028245865564150464']
# ['At iteration 29 the best fitness is 0.028245865564150464']
#       Selected: 302/652 (46.3%), Fitness: 0.0282, Time: 670.1s
#       Modality: S=46%,
#     Test Acc: 86.72%, F1: 86.52%, Features: 302/652 (46.3%), Model: 1.126MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0653074153107495']
# ['At iteration 2 the best fitness is 0.05219558548946386']
# ['At iteration 3 the best fitness is 0.04595892237930113']
# ['At iteration 4 the best fitness is 0.045422112563350214']
# ['At iteration 5 the best fitness is 0.039645572152573985']
# ['At iteration 6 the best fitness is 0.039645572152573985']
# ['At iteration 7 the best fitness is 0.039645572152573985']
# ['At iteration 8 the best fitness is 0.039645572152573985']
# ['At iteration 9 the best fitness is 0.039645572152573985']
# ['At iteration 10 the best fitness is 0.039645572152573985']
# ['At iteration 11 the best fitness is 0.039645572152573985']
# ['At iteration 12 the best fitness is 0.039645572152573985']
# ['At iteration 13 the best fitness is 0.039645572152573985']
# ['At iteration 14 the best fitness is 0.039645572152573985']
# ['At iteration 15 the best fitness is 0.039645572152573985']
# ['At iteration 16 the best fitness is 0.039645572152573985']
# ['At iteration 17 the best fitness is 0.039645572152573985']
# ['At iteration 18 the best fitness is 0.039645572152573985']
# ['At iteration 19 the best fitness is 0.039645572152573985']
# ...
# ['At iteration 13 the best fitness is 0.03570242220032429']
# ['At iteration 14 the best fitness is 0.03570242220032429']
# ['At iteration 15 the best fitness is 0.03570242220032429']
# ['At iteration 16 the best fitness is 0.030856829524142572']
# ['At iteration 17 the best fitness is 0.030856829524142572']
# ['At iteration 18 the best fitness is 0.030856829524142572']
# ['At iteration 19 the best fitness is 0.030856829524142572']
# ['At iteration 20 the best fitness is 0.030473393941320488']
# ['At iteration 21 the best fitness is 0.030473393941320488']
# ['At iteration 22 the best fitness is 0.030473393941320488']
# ['At iteration 23 the best fitness is 0.030473393941320488']
# ['At iteration 24 the best fitness is 0.030473393941320488']
# ['At iteration 25 the best fitness is 0.030473393941320488']
# ['At iteration 26 the best fitness is 0.030473393941320488']
# ['At iteration 27 the best fitness is 0.030473393941320488']
# ['At iteration 28 the best fitness is 0.030473393941320488']
# ['At iteration 29 the best fitness is 0.030473393941320488']
#       Selected: 265/652 (40.6%), Fitness: 0.0305, Time: 945.1s
#       Modality: S=41%,
#     Test Acc: 86.36%, F1: 84.90%, Features: 265/652 (40.6%), Model: 1.054MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04307868972313166']
# ['At iteration 1 the best fitness is 0.04307868972313166']
# ['At iteration 2 the best fitness is 0.04307868972313166']
# ['At iteration 3 the best fitness is 0.04307868972313166']
# ['At iteration 4 the best fitness is 0.03838647128007889']
# ['At iteration 5 the best fitness is 0.03561143075113644']
# ['At iteration 6 the best fitness is 0.03561143075113644']
# ['At iteration 7 the best fitness is 0.033694252837026005']
# ['At iteration 8 the best fitness is 0.029002034393973124']
# ['At iteration 9 the best fitness is 0.029002034393973124']
# ['At iteration 10 the best fitness is 0.029002034393973124']
# ['At iteration 11 the best fitness is 0.029002034393973124']
# ['At iteration 12 the best fitness is 0.029002034393973124']
# ['At iteration 13 the best fitness is 0.029002034393973124']
# ['At iteration 14 the best fitness is 0.029002034393973124']
# ['At iteration 15 the best fitness is 0.029002034393973124']
# ['At iteration 16 the best fitness is 0.029002034393973124']
# ['At iteration 17 the best fitness is 0.029002034393973124']
# ['At iteration 18 the best fitness is 0.029002034393973124']
# ['At iteration 19 the best fitness is 0.029002034393973124']
# ['At iteration 20 the best fitness is 0.029002034393973124']
# ['At iteration 21 the best fitness is 0.029002034393973124']
# ['At iteration 22 the best fitness is 0.029002034393973124']
# ['At iteration 23 the best fitness is 0.029002034393973124']
# ['At iteration 24 the best fitness is 0.029002034393973124']
# ['At iteration 25 the best fitness is 0.029002034393973124']
# ['At iteration 26 the best fitness is 0.028771973044279874']
# ['At iteration 27 the best fitness is 0.028771973044279874']
# ['At iteration 28 the best fitness is 0.028771973044279874']
# ['At iteration 29 the best fitness is 0.028771973044279874']
#       Selected: 307/652 (47.1%), Fitness: 0.0288, Time: 756.6s
#       Modality: S=47%,
#     Test Acc: 87.37%, F1: 85.17%, Features: 307/652 (47.1%), Model: 1.136MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.046299548618837186']
# ['At iteration 2 the best fitness is 0.041147207476397905']
# ['At iteration 3 the best fitness is 0.041147207476397905']
# ['At iteration 4 the best fitness is 0.041147207476397905']
# ['At iteration 5 the best fitness is 0.041147207476397905']
# ['At iteration 6 the best fitness is 0.041147207476397905']
# ['At iteration 7 the best fitness is 0.041147207476397905']
# ['At iteration 8 the best fitness is 0.041147207476397905']
# ['At iteration 9 the best fitness is 0.03538136940144319']
# ['At iteration 10 the best fitness is 0.03538136940144319']
# ['At iteration 11 the best fitness is 0.03538136940144319']
# ['At iteration 12 the best fitness is 0.03538136940144319']
# ['At iteration 13 the best fitness is 0.03538136940144319']
# ['At iteration 14 the best fitness is 0.03538136940144319']
# ['At iteration 15 the best fitness is 0.03214620617311423']
# ['At iteration 16 the best fitness is 0.03214620617311423']
# ['At iteration 17 the best fitness is 0.03214620617311423']
# ['At iteration 18 the best fitness is 0.03214620617311423']
# ['At iteration 19 the best fitness is 0.02938546997679521']
# ['At iteration 20 the best fitness is 0.02938546997679521']
# ['At iteration 21 the best fitness is 0.024539877300613498']
# ['At iteration 22 the best fitness is 0.024539877300613498']
# ['At iteration 23 the best fitness is 0.024539877300613498']
# ['At iteration 24 the best fitness is 0.024539877300613498']
# ['At iteration 25 the best fitness is 0.024539877300613498']
# ['At iteration 26 the best fitness is 0.024539877300613498']
# ['At iteration 27 the best fitness is 0.024539877300613498']
# ['At iteration 28 the best fitness is 0.024539877300613498']
# ['At iteration 29 the best fitness is 0.024539877300613498']
#       Selected: 313/652 (48.0%), Fitness: 0.0245, Time: 710.6s
#       Modality: S=48%,
#     Test Acc: 85.86%, F1: 84.05%, Features: 313/652 (48.0%), Model: 1.148MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04915127626434405']
# ['At iteration 2 the best fitness is 0.037849661464127965']
# ['At iteration 3 the best fitness is 0.037849661464127965']
# ['At iteration 4 the best fitness is 0.037849661464127965']
# ['At iteration 5 the best fitness is 0.037849661464127965']
# ['At iteration 6 the best fitness is 0.037849661464127965']
# ['At iteration 7 the best fitness is 0.037849661464127965']
# ['At iteration 8 the best fitness is 0.037849661464127965']
# ['At iteration 9 the best fitness is 0.037849661464127965']
# ['At iteration 10 the best fitness is 0.037849661464127965']
# ['At iteration 11 the best fitness is 0.037849661464127965']
# ['At iteration 12 the best fitness is 0.037849661464127965']
# ['At iteration 13 the best fitness is 0.037849661464127965']
# ['At iteration 14 the best fitness is 0.037849661464127965']
# ['At iteration 15 the best fitness is 0.037849661464127965']
# ['At iteration 16 the best fitness is 0.037849661464127965']
# ['At iteration 17 the best fitness is 0.037849661464127965']
# ['At iteration 18 the best fitness is 0.037849661464127965']
# ['At iteration 19 the best fitness is 0.037849661464127965']
# ['At iteration 20 the best fitness is 0.037849661464127965']
# ['At iteration 21 the best fitness is 0.037849661464127965']
# ['At iteration 22 the best fitness is 0.037849661464127965']
# ['At iteration 23 the best fitness is 0.037849661464127965']
# ['At iteration 24 the best fitness is 0.037849661464127965']
# ['At iteration 25 the best fitness is 0.037849661464127965']
# ['At iteration 26 the best fitness is 0.037849661464127965']
# ['At iteration 27 the best fitness is 0.037849661464127965']
# ['At iteration 28 the best fitness is 0.037849661464127965']
# ['At iteration 29 the best fitness is 0.037849661464127965']
# ['At iteration 30 the best fitness is 0.037849661464127965']
#       Selected: 318/652 (48.8%), Fitness: 0.0378, Time: 730.5s
#       Modality: S=49%,
#     Test Acc: 85.35%, F1: 83.27%, Features: 318/652 (48.8%), Model: 1.157MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04907458914777963']
# ['At iteration 2 the best fitness is 0.04876784068152196']
# ['At iteration 3 the best fitness is 0.048537779331828707']
# ['At iteration 4 the best fitness is 0.048537779331828707']
# ['At iteration 5 the best fitness is 0.043232063956260496']
# ['At iteration 6 the best fitness is 0.043232063956260496']
# ['At iteration 7 the best fitness is 0.043232063956260496']
# ['At iteration 8 the best fitness is 0.043232063956260496']
# ['At iteration 9 the best fitness is 0.03830978416351447']
# ['At iteration 10 the best fitness is 0.03830978416351447']
# ['At iteration 11 the best fitness is 0.03830978416351447']
# ['At iteration 12 the best fitness is 0.03830978416351447']
# ['At iteration 13 the best fitness is 0.03830978416351447']
# ['At iteration 14 the best fitness is 0.03830978416351447']
# ['At iteration 15 the best fitness is 0.03830978416351447']
# ['At iteration 16 the best fitness is 0.03377093995359042']
# ['At iteration 17 the best fitness is 0.03377093995359042']
# ['At iteration 18 the best fitness is 0.03377093995359042']
# ['At iteration 19 the best fitness is 0.03377093995359042']
# ['At iteration 20 the best fitness is 0.03377093995359042']
# ['At iteration 21 the best fitness is 0.03361756572046159']
# ['At iteration 22 the best fitness is 0.033234130137639505']
# ['At iteration 23 the best fitness is 0.033234130137639505']
# ['At iteration 24 the best fitness is 0.033234130137639505']
# ['At iteration 25 the best fitness is 0.033234130137639505']
# ['At iteration 26 the best fitness is 0.02907872151053754']
# ['At iteration 27 the best fitness is 0.02907872151053754']
# ['At iteration 28 the best fitness is 0.02907872151053754']
# ['At iteration 29 the best fitness is 0.02907872151053754']
# ['At iteration 30 the best fitness is 0.02907872151053754']
#       Selected: 306/652 (46.9%), Fitness: 0.0291, Time: 727.4s
#       Modality: S=47%,
#     Test Acc: 84.34%, F1: 82.64%, Features: 306/652 (46.9%), Model: 1.134MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05183532534409865']
# ['At iteration 1 the best fitness is 0.04708072411710479']
# ['At iteration 2 the best fitness is 0.04031795352681264']
# ['At iteration 3 the best fitness is 0.032941686004005266']
# ['At iteration 4 the best fitness is 0.032941686004005266']
# ['At iteration 5 the best fitness is 0.032941686004005266']
# ['At iteration 6 the best fitness is 0.032941686004005266']
# ['At iteration 7 the best fitness is 0.032941686004005266']
# ['At iteration 8 the best fitness is 0.032941686004005266']
# ['At iteration 9 the best fitness is 0.032941686004005266']
# ['At iteration 10 the best fitness is 0.032941686004005266']
# ['At iteration 11 the best fitness is 0.03280261610349976']
# ['At iteration 12 the best fitness is 0.030118567023745157']
# ['At iteration 13 the best fitness is 0.030118567023745157']
# ['At iteration 14 the best fitness is 0.030118567023745157']
# ['At iteration 15 the best fitness is 0.030118567023745157']
# ['At iteration 16 the best fitness is 0.030118567023745157']
# ['At iteration 17 the best fitness is 0.030118567023745157']
# ['At iteration 18 the best fitness is 0.030118567023745157']
# ['At iteration 19 the best fitness is 0.030118567023745157']
# ['At iteration 20 the best fitness is 0.030118567023745157']
# ['At iteration 21 the best fitness is 0.030118567023745157']
# ['At iteration 22 the best fitness is 0.030118567023745157']
# ['At iteration 23 the best fitness is 0.030118567023745157']
# ['At iteration 24 the best fitness is 0.030118567023745157']
# ['At iteration 25 the best fitness is 0.030118567023745157']
# ['At iteration 26 the best fitness is 0.030118567023745157']
# ['At iteration 27 the best fitness is 0.030118567023745157']
# ['At iteration 28 the best fitness is 0.030118567023745157']
# ['At iteration 29 the best fitness is 0.030118567023745157']
#       Selected: 141/652 (21.6%), Fitness: 0.0301, Time: 656.5s
#       Modality: S=22%,
#     Test Acc: 84.34%, F1: 82.44%, Features: 141/652 (21.6%), Model: 0.323MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.040073587844496064']
# ['At iteration 2 the best fitness is 0.040073587844496064']
# ['At iteration 3 the best fitness is 0.03992021361136723']
# ['At iteration 4 the best fitness is 0.03461449823579901']
# ['At iteration 5 the best fitness is 0.03461449823579901']
# ['At iteration 6 the best fitness is 0.03461449823579901']
# ['At iteration 7 the best fitness is 0.03461449823579901']
# ['At iteration 8 the best fitness is 0.03461449823579901']
# ['At iteration 9 the best fitness is 0.03461449823579901']
# ['At iteration 10 the best fitness is 0.03461449823579901']
# ['At iteration 11 the best fitness is 0.03461449823579901']
# ['At iteration 12 the best fitness is 0.03461449823579901']
# ['At iteration 13 the best fitness is 0.03461449823579901']
# ['At iteration 14 the best fitness is 0.03461449823579901']
# ['At iteration 15 the best fitness is 0.03461449823579901']
# ['At iteration 16 the best fitness is 0.03461449823579901']
# ['At iteration 17 the best fitness is 0.03461449823579901']
# ['At iteration 18 the best fitness is 0.03461449823579901']
# ['At iteration 19 the best fitness is 0.03461449823579901']
# ['At iteration 20 the best fitness is 0.03461449823579901']
# ['At iteration 21 the best fitness is 0.03461449823579901']
# ['At iteration 22 the best fitness is 0.03461449823579901']
# ['At iteration 23 the best fitness is 0.03461449823579901']
# ['At iteration 24 the best fitness is 0.03461449823579901']
# ['At iteration 25 the best fitness is 0.03461449823579901']
# ['At iteration 26 the best fitness is 0.03461449823579901']
# ['At iteration 27 the best fitness is 0.03461449823579901']
# ['At iteration 28 the best fitness is 0.03461449823579901']
# ['At iteration 29 the best fitness is 0.03461449823579901']
#       Selected: 330/652 (50.6%), Fitness: 0.0346, Time: 1412.4s
#       Modality: S=51%,
#     Test Acc: 86.87%, F1: 85.29%, Features: 330/652 (50.6%), Model: 1.181MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.050071521663117055']
# ['At iteration 1 the best fitness is 0.04999483454655264']
# ['At iteration 2 the best fitness is 0.04744985536730344']
# ['At iteration 3 the best fitness is 0.04744985536730344']
# ['At iteration 4 the best fitness is 0.04567174735369852']
# ['At iteration 5 the best fitness is 0.04567174735369852']
# ['At iteration 6 the best fitness is 0.04567174735369852']
# ['At iteration 7 the best fitness is 0.04567174735369852']
# ['At iteration 8 the best fitness is 0.04567174735369852']
# ['At iteration 9 the best fitness is 0.04567174735369852']
# ['At iteration 10 the best fitness is 0.04567174735369852']
# ['At iteration 11 the best fitness is 0.04567174735369852']
# ['At iteration 12 the best fitness is 0.04059609332782355']
# ['At iteration 13 the best fitness is 0.04059609332782355']
# ['At iteration 14 the best fitness is 0.04021265774500147']
# ['At iteration 15 the best fitness is 0.04021265774500147']
# ['At iteration 16 the best fitness is 0.04021265774500147']
# ['At iteration 17 the best fitness is 0.04021265774500147']
# ['At iteration 18 the best fitness is 0.04021265774500147']
# ['At iteration 19 the best fitness is 0.04021265774500147']
# ['At iteration 20 the best fitness is 0.04021265774500147']
# ['At iteration 21 the best fitness is 0.03446112400267018']
# ['At iteration 22 the best fitness is 0.03446112400267018']
# ['At iteration 23 the best fitness is 0.03446112400267018']
# ['At iteration 24 the best fitness is 0.03446112400267018']
# ['At iteration 25 the best fitness is 0.03446112400267018']
# ['At iteration 26 the best fitness is 0.03446112400267018']
# ['At iteration 27 the best fitness is 0.03446112400267018']
# ['At iteration 28 the best fitness is 0.03446112400267018']
# ['At iteration 29 the best fitness is 0.03446112400267018']
#       Selected: 307/652 (47.1%), Fitness: 0.0345, Time: 492.1s
#       Modality: S=47%,
#     Test Acc: 82.83%, F1: 80.52%, Features: 307/652 (47.1%), Model: 1.136MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_sensor_new/all_results_per_fold.csv
# Shape: (90, 22)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  sensor_retention (%)  sensor_selected
# 0      baseline     1            83.2168           98.2857       83.1999          83.1999              85.7652           83.2168                652             652                  100.0       0.0000          8.4530          8.4530        472854           1.8097                 5.7951                  5.7951                    0.0        28.1729                 100.0              652
# 1      baseline     2            85.0622           97.8261       84.6851          84.6434              86.7197           85.0826                652             652                  100.0       0.0000          9.9445          9.9445        472854           1.8097                 5.7951                  5.7951                    0.0        28.1729                 100.0              652
# 2      baseline     3            77.7273           95.2381       75.1507          75.1507              80.2294           77.7273                652             652                  100.0       0.0000          9.9921          9.9921        472854           1.8097                 5.7951                  5.7951                    0.0        28.1729                 100.0              652
# 3      baseline     4            73.1818           98.9418       69.5315          69.5315              80.8658           73.1818                652             652                  100.0       0.0000          9.8892          9.8892        472854           1.8097                 5.7951                  5.7951                    0.0        28.1729                 100.0              652
# 4      baseline     5            87.3737           98.9637       85.9393          85.9393              86.6274           87.3737                652             652                  100.0       0.0000         10.4396         10.4396        472854           1.8097                 5.7951                  5.7951                    0.0        28.1729                 100.0              652
# 5   mutual_info     1            89.1608           99.4286       88.1736          88.1736              89.9153           89.1608                326             652                   50.0       3.1882          9.2833         12.4715        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326
# 6   mutual_info     2            90.8714           98.3696       90.7329          90.6945              91.4768           90.9091                326             652                   50.0       3.1712         11.8861         15.0574        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326
# 7   mutual_info     3            76.3636           97.8836       75.8909          75.8909              80.4896           76.3636                326             652                   50.0       3.1536         12.1348         15.2884        305942           1.1730                 5.7951                  2.8976                   50.0        24.3154                  50.0              326
# 8   mutual_info     4            70.9091           98.9418       66.2411          66.2411              84.0821           70.9091                326             652                   50.0       3.1534         11.7849         14.9383        305942           1.1730                 5.7951                  2.8976                   50.0        24.3154                  50.0              326
# 9   mutual_info     5            86.8687           99.4819       84.7290          84.7290              85.7524           86.8687                326             652                   50.0       3.2214         12.5544         15.7759        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326
# 10          rfe     1            89.5105          100.0000       89.5431          89.5431              91.0156           89.5105                326             652                   50.0       0.6446         10.1732         10.8179        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326
# 11          rfe     2            94.6058           99.4565       94.6136          94.5913              95.2841           94.6281                326             652                   50.0       0.6460         11.8498         12.4959        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326
# 12          rfe     3            84.0909           98.4127       81.9646          81.9646              85.2453           84.0909                326             652                   50.0       0.6440         12.0694         12.7136        305942           1.1730                 5.7951                  2.8976                   50.0        24.3154                  50.0              326
# 13          rfe     4            80.4545          100.0000       77.5820          77.5820              81.6545           80.4545                326             652                   50.0       0.6207         11.9400         12.5608        305942           1.1730                 5.7951                  2.8976                   50.0        24.3154                  50.0              326
# 14          rfe     5            84.8485          100.0000       82.4763          82.4763              85.7686           84.8485                326             652                   50.0       0.6520         12.5499         13.2021        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326
# 15        lasso     1            82.8671           97.7143       82.5282          82.5282              84.6691           82.8671                326             652                   50.0       0.0893         10.4118         10.5012        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326
# 16        lasso     2            85.8921           95.6522       85.5621          85.5022              87.2284           85.9504                326             652                   50.0       0.0892         11.9134         12.0027        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326
# 17        lasso     3            77.2727           96.2963       75.8450          75.8450              78.5755           77.2727                326             652                   50.0       0.0974         11.9831         12.0805        305942           1.1730                 5.7951                  2.8976                   50.0        24.3154                  50.0              326
# 18        lasso     4            68.6364           98.4127       65.2595          65.2595              81.0626           68.6364                326             652                   50.0       0.0958         12.0174         12.1132        305942           1.1730                 5.7951                  2.8976                   50.0        24.3154                  50.0              326
# 19        lasso     5            80.3030           95.8549       77.2494          77.2494              82.5764           80.3030                326             652                   50.0       0.0985         12.5691         12.6677        305942           1.1730                 5.7951                  2.8976                   50.0        24.3130                  50.0              326

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              81.31              5.77              79.70              7.07                   652.0                      100.00              0.00                 9.74                 9.74           472854.0                  1.81                        0.00               28.17
# mutual_info              82.83              8.73              81.15             10.05                   326.0                       50.00              3.18                11.53                14.71           305942.0                  1.17                       50.00               24.31
#         rfe              86.70              5.47              85.24              6.77                   326.0                       50.00              0.64                11.72                12.36           305942.0                  1.17                       50.00               24.31
#       lasso              78.99              6.61              77.29              7.79                   326.0                       50.00              0.09                11.78                11.87           305942.0                  1.17                       50.00               24.31
#    meta_BAT              83.07              3.73              81.50              4.53                   316.2                       48.50            711.75                11.99               723.74           300924.4                  1.15                       51.50               24.20
#     meta_CS              82.06              5.14              80.41              6.50                   314.8                       48.28           1400.89                11.92              1412.81           300207.6                  1.15                       51.72               24.18
#     meta_DE              80.95              5.57              79.63              6.53                   305.2                       46.81            711.40                11.82               723.21           295292.4                  1.13                       53.19               24.07
#    meta_FFA              82.34              3.37              80.91              3.79                   322.2                       49.42            691.16                11.94               703.09           303996.4                  1.17                       50.58               24.27
#     meta_GA              83.12              5.98              81.97              6.38                   316.8                       48.59            689.14                11.91               701.05           301231.6                  1.16                       51.41               24.21
#    meta_GWO              82.99              5.94              81.27              7.57                   281.0                       43.10            684.27                11.76               696.03           282902.0                  1.09                       56.90               23.78
#    meta_HHO              81.79              4.54              80.56              5.17                   218.6                       33.53            875.39                11.67               887.06           189477.8                  0.73                       66.47               21.64
#   meta_JAYA              81.73              5.54              80.19              5.53                   308.0                       47.24            712.20                11.88               724.08           296726.0                  1.14                       52.76               24.10
#    meta_MFO              81.53              5.91              79.84              7.45                   318.6                       48.87            668.99                12.00               680.99           302153.2                  1.16                       51.13               24.23
#    meta_MVO              81.49              5.28              79.79              6.44                   316.8                       48.59            691.64                11.89               703.53           301231.6                  1.15                       51.41               24.21
#    meta_PSO              83.15              3.32              82.28              3.58                   314.0                       48.16            689.34                11.85               701.18           299798.0                  1.15                       51.84               24.17
#    meta_SCA              83.39              3.56              81.77              4.70                   168.4                       25.83            657.11                11.01               668.12           120599.2                  0.46                       74.17               20.07
#    meta_SSA              82.91              4.98              81.51              6.53                   318.4                       48.83           1638.60                11.33              1649.93           302050.8                  1.16                       51.17               24.22
#    meta_WOA              79.90              5.52              78.21              6.56                   265.4                       40.71            623.14                10.56               633.70           249201.0                  0.96                       59.29               23.01

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 82.83% vs Baseline: 81.31%
#   Paired t-test: t=0.8459, p=0.4452
#   Wilcoxon test: W=6.0000, p=0.8125
#   -> better, Not significant
#
# RFE vs BASELINE:
#   Method: 86.70% vs Baseline: 81.31%
#   Paired t-test: t=2.6111, p=0.0594
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 78.99% vs Baseline: 81.31%
#   Paired t-test: t=-1.5487, p=0.1964
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 83.07% vs Baseline: 81.31%
#   Paired t-test: t=1.4243, p=0.2275
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> better, Not significant
#
# META_CS vs BASELINE:
#   Method: 82.06% vs Baseline: 81.31%
#   Paired t-test: t=0.3535, p=0.7415
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> better, Not significant
#
# META_DE vs BASELINE:
#   Method: 80.95% vs Baseline: 81.31%
#   Paired t-test: t=-0.3105, p=0.7717
#   Wilcoxon test: W=1.0000, p=1.0000
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 82.34% vs Baseline: 81.31%
#   Paired t-test: t=0.6266, p=0.5649
#   Wilcoxon test: W=4.0000, p=0.8750
#   -> better, Not significant
#
# META_GA vs BASELINE:
#   Method: 83.12% vs Baseline: 81.31%
#   Paired t-test: t=1.0557, p=0.3507
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> better, Not significant
#
# META_GWO vs BASELINE:
#   Method: 82.99% vs Baseline: 81.31%
#   Paired t-test: t=1.1956, p=0.2979
#   Wilcoxon test: W=4.0000, p=0.4375
#   -> better, Not significant
#
# META_HHO vs BASELINE:
#   Method: 81.79% vs Baseline: 81.31%
#   Paired t-test: t=0.6838, p=0.5317
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> better, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 81.73% vs Baseline: 81.31%
#   Paired t-test: t=0.1964, p=0.8539
#   Wilcoxon test: W=4.0000, p=0.8750
#   -> better, Not significant
#
# META_MFO vs BASELINE:
#   Method: 81.53% vs Baseline: 81.31%
#   Paired t-test: t=0.3486, p=0.7450
#   Wilcoxon test: W=6.0000, p=0.8125
#   -> better, Not significant
#
# META_MVO vs BASELINE:
#   Method: 81.49% vs Baseline: 81.31%
#   Paired t-test: t=0.1142, p=0.9146
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> better, Not significant
#
# META_PSO vs BASELINE:
#   Method: 83.15% vs Baseline: 81.31%
#   Paired t-test: t=0.9103, p=0.4141
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> better, Not significant
#
# META_SCA vs BASELINE:
#   Method: 83.39% vs Baseline: 81.31%
#   Paired t-test: t=1.2501, p=0.2794
#   Wilcoxon test: W=2.0000, p=0.3750
#   -> better, Not significant
#
# META_SSA vs BASELINE:
#   Method: 82.91% vs Baseline: 81.31%
#   Paired t-test: t=1.9234, p=0.1268
#   Wilcoxon test: W=1.0000, p=0.1250
#   -> better, Not significant
#
# META_WOA vs BASELINE:
#   Method: 79.90% vs Baseline: 81.31%
#   Paired t-test: t=-1.0751, p=0.3429
#   Wilcoxon test: W=4.5000, p=0.5000
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_sensor_new
#
# Per-method folders:
#   results_sensor_new/baseline/ (10 files)
#   results_sensor_new/mutual_info/ (10 files)
#   results_sensor_new/rfe/ (10 files)
#   results_sensor_new/lasso/ (10 files)
#   results_sensor_new/meta_BAT/ (10 files)
#   results_sensor_new/meta_CS/ (10 files)
#   results_sensor_new/meta_DE/ (10 files)
#   results_sensor_new/meta_FFA/ (10 files)
#   results_sensor_new/meta_GA/ (10 files)
#   results_sensor_new/meta_GWO/ (10 files)
#   results_sensor_new/meta_HHO/ (10 files)
#   results_sensor_new/meta_JAYA/ (10 files)
#   results_sensor_new/meta_MFO/ (10 files)
#   results_sensor_new/meta_MVO/ (10 files)
#   results_sensor_new/meta_PSO/ (10 files)
#   results_sensor_new/meta_SCA/ (10 files)
#   results_sensor_new/meta_SSA/ (10 files)
#   results_sensor_new/meta_WOA/ (10 files)
#
# Plots directory: results_sensor_new/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 86.70% ± 5.47% (Features: 50.0%)
#   meta_SCA            : 83.39% ± 3.56% (Features: 25.8%)
#   meta_PSO            : 83.15% ± 3.32% (Features: 48.2%)
#   meta_GA             : 83.12% ± 5.98% (Features: 48.6%)
#   meta_BAT            : 83.07% ± 3.73% (Features: 48.5%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_BAT
#     Test Accuracy:      86.01%
#     Feature Retention:  47.09% (307/652)
#     Modality Retention: sensor=47.1%
#
#   Fold 2: Best = meta_GWO
#     Test Accuracy:      90.87%
#     Feature Retention:  40.64% (265/652)
#     Modality Retention: sensor=40.6%
#
#   Fold 3: Best = meta_PSO
#     Test Accuracy:      85.45%
#     Feature Retention:  49.23% (321/652)
#     Modality Retention: sensor=49.2%
#
#   Fold 4: Best = meta_FFA
#     Test Accuracy:      79.55%
#     Feature Retention:  49.69% (324/652)
#     Modality Retention: sensor=49.7%
#
#   Fold 5: Best = meta_GA
#     Test Accuracy:      87.88%
#     Feature Retention:  50.61% (330/652)
#     Modality Retention: sensor=50.6%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     85.95% ± 4.16%
#   Average Feature Retention: 47.45% ± 4.02%
#
#   Average Modality-wise Feature Retention:
#         sensor: 47.45% ± 4.02%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  sensor Retention (%)
#     1           meta_BAT              86.01                  47.09                 47.09
#     2           meta_GWO              90.87                  40.64                 40.64
#     3           meta_PSO              85.45                  49.23                 49.23
#     4           meta_FFA              79.55                  49.69                 49.69
#     5            meta_GA              87.88                  50.61                 50.61
#
# Saved to: results_sensor_new/best_metaheuristic_per_fold.csv
