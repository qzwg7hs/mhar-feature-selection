# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_noise_1.0_10")

# Master output directory
RESULTS_ROOT = Path("results_noise_1.0_10")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

# FEATURE_DIMS will be set dynamically per-fold after PCA
# (depth dim changes if PCA is applied)
print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 93.52%, F1: 92.48%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 51.5s
#     Test Acc: 92.59%, F1: 92.08%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 8.8s
#     Test Acc: 89.81%, F1: 89.20%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 352.0s
#     Test Acc: 89.81%, F1: 88.72%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.069230076579812']
# ['At iteration 1 the best fitness is 0.069230076579812']
# ['At iteration 2 the best fitness is 0.04261696901417889']
# ['At iteration 3 the best fitness is 0.04261696901417889']
# ['At iteration 4 the best fitness is 0.04261696901417889']
# ['At iteration 5 the best fitness is 0.04261696901417889']
# ['At iteration 6 the best fitness is 0.04261696901417889']
# ['At iteration 7 the best fitness is 0.04261696901417889']
# ['At iteration 8 the best fitness is 0.04261696901417889']
# ['At iteration 9 the best fitness is 0.04261696901417889']
# ['At iteration 10 the best fitness is 0.04261696901417889']
# ['At iteration 11 the best fitness is 0.04261696901417889']
# ['At iteration 12 the best fitness is 0.04261696901417889']
# ['At iteration 13 the best fitness is 0.04261696901417889']
# ['At iteration 14 the best fitness is 0.04261696901417889']
# ['At iteration 15 the best fitness is 0.04261696901417889']
# ['At iteration 16 the best fitness is 0.04261696901417889']
# ['At iteration 17 the best fitness is 0.04261696901417889']
# ['At iteration 18 the best fitness is 0.04261696901417889']
# ['At iteration 19 the best fitness is 0.04261696901417889']
# ['At iteration 20 the best fitness is 0.04261696901417889']
# ['At iteration 21 the best fitness is 0.04261696901417889']
# ['At iteration 22 the best fitness is 0.04261696901417889']
# ['At iteration 23 the best fitness is 0.04261696901417889']
# ['At iteration 24 the best fitness is 0.04261696901417889']
# ['At iteration 25 the best fitness is 0.04261696901417889']
# ['At iteration 26 the best fitness is 0.04261696901417889']
# ['At iteration 27 the best fitness is 0.04261696901417889']
# ['At iteration 28 the best fitness is 0.04261696901417889']
# ['At iteration 29 the best fitness is 0.04261696901417889']
#       Selected: 2219/4463 (49.7%), Fitness: 0.0426, Time: 1412.0s
#       Modality: D=48%, S=53%, Sk=49%, V=50%
#     Test Acc: 93.52%, F1: 93.26%, Features: 2219/4463 (49.7%), Model: 4.875MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07749240379360098']
# ['At iteration 1 the best fitness is 0.06942053143080909']
# ['At iteration 2 the best fitness is 0.06942053143080909']
# ['At iteration 3 the best fitness is 0.06942053143080909']
# ['At iteration 4 the best fitness is 0.06942053143080909']
# ['At iteration 5 the best fitness is 0.06942053143080909']
# ['At iteration 6 the best fitness is 0.06942053143080909']
# ['At iteration 7 the best fitness is 0.06942053143080909']
# ['At iteration 8 the best fitness is 0.06942053143080909']
# ['At iteration 9 the best fitness is 0.06942053143080909']
# ['At iteration 10 the best fitness is 0.06942053143080909']
# ['At iteration 11 the best fitness is 0.06942053143080909']
# ['At iteration 12 the best fitness is 0.06942053143080909']
# ['At iteration 13 the best fitness is 0.06942053143080909']
# ['At iteration 14 the best fitness is 0.059600955729455694']
# ['At iteration 15 the best fitness is 0.059600955729455694']
# ['At iteration 16 the best fitness is 0.059600955729455694']
# ['At iteration 17 the best fitness is 0.059600955729455694']
# ['At iteration 18 the best fitness is 0.059600955729455694']
# ['At iteration 19 the best fitness is 0.059600955729455694']
# ['At iteration 20 the best fitness is 0.059600955729455694']
# ['At iteration 21 the best fitness is 0.059600955729455694']
# ['At iteration 22 the best fitness is 0.059600955729455694']
# ['At iteration 23 the best fitness is 0.059600955729455694']
# ['At iteration 24 the best fitness is 0.059600955729455694']
# ['At iteration 25 the best fitness is 0.059600955729455694']
# ['At iteration 26 the best fitness is 0.059600955729455694']
# ['At iteration 27 the best fitness is 0.059600955729455694']
# ['At iteration 28 the best fitness is 0.059600955729455694']
# ['At iteration 29 the best fitness is 0.059600955729455694']
#       Selected: 2150/4463 (48.2%), Fitness: 0.0596, Time: 2774.6s
#       Modality: D=46%, S=47%, Sk=50%, V=47%
#     Test Acc: 89.81%, F1: 89.54%, Features: 2150/4463 (48.2%), Model: 4.740MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0874016053071883']
# ['At iteration 2 the best fitness is 0.07823181674453084']
# ['At iteration 3 the best fitness is 0.07823181674453084']
# ['At iteration 4 the best fitness is 0.07823181674453084']
# ['At iteration 5 the best fitness is 0.07823181674453084']
# ['At iteration 6 the best fitness is 0.07823181674453084']
# ['At iteration 7 the best fitness is 0.07823181674453084']
# ['At iteration 8 the best fitness is 0.07769406187112729']
# ['At iteration 9 the best fitness is 0.0688155571982301']
# ['At iteration 10 the best fitness is 0.0688155571982301']
# ['At iteration 11 the best fitness is 0.0688155571982301']
# ['At iteration 12 the best fitness is 0.060654059023204296']
# ['At iteration 13 the best fitness is 0.060654059023204296']
# ['At iteration 14 the best fitness is 0.060654059023204296']
# ['At iteration 15 the best fitness is 0.060654059023204296']
# ['At iteration 16 the best fitness is 0.060654059023204296']
# ['At iteration 17 the best fitness is 0.060654059023204296']
# ['At iteration 18 the best fitness is 0.060654059023204296']
# ['At iteration 19 the best fitness is 0.060654059023204296']
# ['At iteration 20 the best fitness is 0.060161117055917715']
# ['At iteration 21 the best fitness is 0.060161117055917715']
# ['At iteration 22 the best fitness is 0.060161117055917715']
# ['At iteration 23 the best fitness is 0.060161117055917715']
# ['At iteration 24 the best fitness is 0.060161117055917715']
# ['At iteration 25 the best fitness is 0.05090170268102634']
# ['At iteration 26 the best fitness is 0.05090170268102634']
# ['At iteration 27 the best fitness is 0.05090170268102634']
# ['At iteration 28 the best fitness is 0.05090170268102634']
# ['At iteration 29 the best fitness is 0.05090170268102634']
# ['At iteration 30 the best fitness is 0.05090170268102634']
#       Selected: 2166/4463 (48.5%), Fitness: 0.0509, Time: 1407.0s
#       Modality: D=50%, S=49%, Sk=49%, V=48%
#     Test Acc: 94.44%, F1: 93.85%, Features: 2166/4463 (48.5%), Model: 4.772MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0870991181908988']
# ['At iteration 1 the best fitness is 0.07795173608129982']
# ['At iteration 2 the best fitness is 0.06097895259255227']
# ['At iteration 3 the best fitness is 0.08719994722966196']
# ['At iteration 4 the best fitness is 0.06901721527575644']
# ['At iteration 5 the best fitness is 0.09654898741678726']
# ['At iteration 6 the best fitness is 0.08742401176024678']
# ['At iteration 7 the best fitness is 0.0870431020582526']
# ['At iteration 8 the best fitness is 0.07796293930782906']
# ['At iteration 9 the best fitness is 0.07818700383841387']
# ['At iteration 10 the best fitness is 0.07816459738535539']
# ['At iteration 11 the best fitness is 0.09593280995767903']
# ['At iteration 12 the best fitness is 0.08705430528478184']
# ['At iteration 13 the best fitness is 0.08698708592560639']
# ['At iteration 14 the best fitness is 0.07805256512006299']
# ['At iteration 15 the best fitness is 0.07804136189353375']
# ['At iteration 16 the best fitness is 0.08691986656643094']
# ['At iteration 17 the best fitness is 0.08691986656643094']
# ['At iteration 18 the best fitness is 0.08686385043378475']
# ['At iteration 19 the best fitness is 0.07798534576088754']
# ['At iteration 20 the best fitness is 0.07798534576088754']
# ['At iteration 21 the best fitness is 0.08686385043378475']
# ['At iteration 22 the best fitness is 0.07799654898741679']
# ['At iteration 23 the best fitness is 0.08690866333990171']
# ['At iteration 24 the best fitness is 0.07801895544047527']
# ['At iteration 25 the best fitness is 0.07798534576088754']
# ['At iteration 26 the best fitness is 0.08686385043378475']
# ['At iteration 27 the best fitness is 0.07798534576088754']
# ['At iteration 28 the best fitness is 0.06910684108799035']
# ['At iteration 29 the best fitness is 0.09574235510668194']
#       Selected: 2206/4463 (49.4%), Fitness: 0.0957, Time: 1357.8s
#       Modality: D=46%, S=50%, Sk=51%, V=48%
#     Test Acc: 92.59%, F1: 92.29%, Features: 2206/4463 (49.4%), Model: 4.850MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.06915165399410732
# At iteration 2 the best fitness is 0.07801895544047527
# At iteration 3 the best fitness is 0.060172320282446956
# At iteration 4 the best fitness is 0.06903962172881492
# At iteration 5 the best fitness is 0.06949895401651376
# At iteration 6 the best fitness is 0.06880435397170087
# At iteration 7 the best fitness is 0.06059804289055809
# At iteration 8 the best fitness is 0.06044119771914873
# At iteration 9 the best fitness is 0.060474807398736445
# At iteration 10 the best fitness is 0.07815339415882616
# At iteration 11 the best fitness is 0.051674725311543934
# At iteration 12 the best fitness is 0.07801895544047527
# At iteration 13 the best fitness is 0.06055322998444113
# At iteration 14 the best fitness is 0.06977903467974478
# At iteration 15 the best fitness is 0.04300908194270231
# At iteration 16 the best fitness is 0.0783886619159402
# At iteration 17 the best fitness is 0.06946534433692605
# At iteration 18 the best fitness is 0.06058683966402885
# At iteration 19 the best fitness is 0.06066526224973354
# At iteration 20 the best fitness is 0.06948775078998454
# At iteration 21 the best fitness is 0.06953256369610149
# At iteration 22 the best fitness is 0.051674725311543934
# At iteration 23 the best fitness is 0.08708791496436956
# At iteration 24 the best fitness is 0.06078849774155518
# At iteration 25 the best fitness is 0.05202202533395038
# At iteration 26 the best fitness is 0.06067646547626278
# At iteration 27 the best fitness is 0.07843347482205716
# At iteration 28 the best fitness is 0.06977903467974478
# At iteration 29 the best fitness is 0.05193239952171646
# At iteration 30 the best fitness is 0.07856791354040804
#       Selected: 2258/4463 (50.6%), Fitness: 0.0786, Time: 1358.8s
#       Modality: D=50%, S=52%, Sk=51%, V=50%
#     Test Acc: 93.52%, F1: 92.15%, Features: 2258/4463 (50.6%), Model: 4.951MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10471048559181306']
# ['At iteration 1 the best fitness is 0.06828900555135581']
# ['At iteration 2 the best fitness is 0.06828900555135581']
# ['At iteration 3 the best fitness is 0.06828900555135581']
# ['At iteration 4 the best fitness is 0.06828900555135581']
# ['At iteration 5 the best fitness is 0.06828900555135581']
# ['At iteration 6 the best fitness is 0.06828900555135581']
# ['At iteration 7 the best fitness is 0.06567865377004278']
# ['At iteration 8 the best fitness is 0.06567865377004278']
# ['At iteration 9 the best fitness is 0.06567865377004278']
# ['At iteration 10 the best fitness is 0.06567865377004278']
# ['At iteration 11 the best fitness is 0.04750712504266649']
# ['At iteration 12 the best fitness is 0.04750712504266649']
# ['At iteration 13 the best fitness is 0.04750712504266649']
# ['At iteration 14 the best fitness is 0.04750712504266649']
# ['At iteration 15 the best fitness is 0.04750712504266649']
# ['At iteration 16 the best fitness is 0.04750712504266649']
# ['At iteration 17 the best fitness is 0.04750712504266649']
# ['At iteration 18 the best fitness is 0.04750712504266649']
# ['At iteration 19 the best fitness is 0.04750712504266649']
# ['At iteration 20 the best fitness is 0.04750712504266649']
# ['At iteration 21 the best fitness is 0.04750712504266649']
# ['At iteration 22 the best fitness is 0.04750712504266649']
# ['At iteration 23 the best fitness is 0.04750712504266649']
# ['At iteration 24 the best fitness is 0.04750712504266649']
# ['At iteration 25 the best fitness is 0.04750712504266649']
# ['At iteration 26 the best fitness is 0.04750712504266649']
# ['At iteration 27 the best fitness is 0.04750712504266649']
# ['At iteration 28 the best fitness is 0.04750712504266649']
# ['At iteration 29 the best fitness is 0.04750712504266649']
#       Selected: 1863/4463 (41.7%), Fitness: 0.0475, Time: 1275.9s
#       Modality: D=42%, S=38%, Sk=44%, V=41%
#     Test Acc: 88.89%, F1: 88.43%, Features: 1863/4463 (41.7%), Model: 4.180MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.08683024075419703']
# ['At iteration 1 the best fitness is 0.08653895686443677']
# ['At iteration 2 the best fitness is 0.08653895686443677']
# ['At iteration 3 the best fitness is 0.08653895686443677']
# ['At iteration 4 the best fitness is 0.08653895686443677']
# ['At iteration 5 the best fitness is 0.08653895686443677']
# ['At iteration 6 the best fitness is 0.08653895686443677']
# ['At iteration 7 the best fitness is 0.08350288247501261']
# ['At iteration 8 the best fitness is 0.08350288247501261']
# ['At iteration 9 the best fitness is 0.08350288247501261']
# ['At iteration 10 the best fitness is 0.08350288247501261']
# ['At iteration 11 the best fitness is 0.08350288247501261']
# ['At iteration 12 the best fitness is 0.08350288247501261']
# ['At iteration 13 the best fitness is 0.08350288247501261']
# ['At iteration 14 the best fitness is 0.08350288247501261']
# ['At iteration 15 the best fitness is 0.08350288247501261']
# ['At iteration 16 the best fitness is 0.08350288247501261']
# ['At iteration 17 the best fitness is 0.08350288247501261']
# ['At iteration 18 the best fitness is 0.08350288247501261']
# ['At iteration 19 the best fitness is 0.08350288247501261']
# ['At iteration 20 the best fitness is 0.08350288247501261']
# ['At iteration 21 the best fitness is 0.08350288247501261']
# ['At iteration 22 the best fitness is 0.08350288247501261']
# ['At iteration 23 the best fitness is 0.08350288247501261']
# ['At iteration 24 the best fitness is 0.08350288247501261']
# ['At iteration 25 the best fitness is 0.08350288247501261']
# ['At iteration 26 the best fitness is 0.08350288247501261']
# ['At iteration 27 the best fitness is 0.07561026173668858']
# ['At iteration 28 the best fitness is 0.07561026173668858']
# ['At iteration 29 the best fitness is 0.07561026173668858']
#       Selected: 1994/4463 (44.7%), Fitness: 0.0756, Time: 1648.7s
#       Modality: D=42%, S=47%, Sk=44%, V=45%
#     Test Acc: 88.89%, F1: 88.31%, Features: 1994/4463 (44.7%), Model: 4.436MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09580957446585739']
# ['At iteration 1 the best fitness is 0.06073248160890898']
# ['At iteration 2 the best fitness is 0.06073248160890898']
# ['At iteration 3 the best fitness is 0.06073248160890898']
# ['At iteration 4 the best fitness is 0.06073248160890898']
# ['At iteration 5 the best fitness is 0.051685928538073175']
# ['At iteration 6 the best fitness is 0.051685928538073175']
# ['At iteration 7 the best fitness is 0.051685928538073175']
# ['At iteration 8 the best fitness is 0.051685928538073175']
# ['At iteration 9 the best fitness is 0.051685928538073175']
# ['At iteration 10 the best fitness is 0.051685928538073175']
# ['At iteration 11 the best fitness is 0.051685928538073175']
# ['At iteration 12 the best fitness is 0.051685928538073175']
# ['At iteration 13 the best fitness is 0.051685928538073175']
# ['At iteration 14 the best fitness is 0.051685928538073175']
# ['At iteration 15 the best fitness is 0.051685928538073175']
# ['At iteration 16 the best fitness is 0.051685928538073175']
# ['At iteration 17 the best fitness is 0.051685928538073175']
# ['At iteration 18 the best fitness is 0.051685928538073175']
# ['At iteration 19 the best fitness is 0.051685928538073175']
# ['At iteration 20 the best fitness is 0.051685928538073175']
# ['At iteration 21 the best fitness is 0.051685928538073175']
# ['At iteration 22 the best fitness is 0.051685928538073175']
# ['At iteration 23 the best fitness is 0.051685928538073175']
# ['At iteration 24 the best fitness is 0.051685928538073175']
# ['At iteration 25 the best fitness is 0.051685928538073175']
# ['At iteration 26 the best fitness is 0.051685928538073175']
# ['At iteration 27 the best fitness is 0.051685928538073175']
# ['At iteration 28 the best fitness is 0.051685928538073175']
# ['At iteration 29 the best fitness is 0.051685928538073175']
#       Selected: 2236/4463 (50.1%), Fitness: 0.0517, Time: 1411.5s
#       Modality: D=51%, S=51%, Sk=50%, V=50%
#     Test Acc: 89.81%, F1: 89.34%, Features: 2236/4463 (50.1%), Model: 4.908MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07813098770576768']
# ['At iteration 2 the best fitness is 0.07813098770576768']
# ['At iteration 3 the best fitness is 0.07813098770576768']
# ['At iteration 4 the best fitness is 0.07813098770576768']
# ['At iteration 5 the best fitness is 0.07813098770576768']
# ['At iteration 6 the best fitness is 0.07813098770576768']
# ['At iteration 7 the best fitness is 0.07813098770576768']
# ['At iteration 8 the best fitness is 0.061449488106780366']
# ['At iteration 9 the best fitness is 0.061449488106780366']
# ['At iteration 10 the best fitness is 0.061449488106780366']
# ['At iteration 11 the best fitness is 0.061449488106780366']
# ['At iteration 12 the best fitness is 0.061449488106780366']
# ['At iteration 13 the best fitness is 0.061449488106780366']
# ['At iteration 14 the best fitness is 0.061449488106780366']
# ['At iteration 15 the best fitness is 0.061449488106780366']
# ['At iteration 16 the best fitness is 0.061449488106780366']
# ['At iteration 17 the best fitness is 0.061449488106780366']
# ['At iteration 18 the best fitness is 0.061449488106780366']
# ['At iteration 19 the best fitness is 0.061449488106780366']
# ['At iteration 20 the best fitness is 0.061449488106780366']
# ['At iteration 21 the best fitness is 0.061449488106780366']
# ['At iteration 22 the best fitness is 0.061449488106780366']
# ['At iteration 23 the best fitness is 0.061449488106780366']
# ['At iteration 24 the best fitness is 0.06084451387420138']
# ['At iteration 25 the best fitness is 0.06084451387420138']
# ['At iteration 26 the best fitness is 0.06084451387420138']
# ['At iteration 27 the best fitness is 0.06084451387420138']
# ['At iteration 28 the best fitness is 0.06084451387420138']
# ['At iteration 29 the best fitness is 0.06084451387420138']
#       Selected: 2261/4463 (50.7%), Fitness: 0.0608, Time: 1330.8s
#       Modality: D=51%, S=51%, Sk=52%, V=49%
#     Test Acc: 90.74%, F1: 90.11%, Features: 2261/4463 (50.7%), Model: 4.957MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08711032141742803']
# ['At iteration 2 the best fitness is 0.08711032141742803']
# ['At iteration 3 the best fitness is 0.07882558775058057']
# ['At iteration 4 the best fitness is 0.07882558775058057']
# ['At iteration 5 the best fitness is 0.07859031999346652']
# ['At iteration 6 the best fitness is 0.0608221074211429']
# ['At iteration 7 the best fitness is 0.0608221074211429']
# ['At iteration 8 the best fitness is 0.0608221074211429']
# ['At iteration 9 the best fitness is 0.0608221074211429']
# ['At iteration 10 the best fitness is 0.0608221074211429']
# ['At iteration 11 the best fitness is 0.0608221074211429']
# ['At iteration 12 the best fitness is 0.05201082210742114']
# ['At iteration 13 the best fitness is 0.05201082210742114']
# ['At iteration 14 the best fitness is 0.05201082210742114']
# ['At iteration 15 the best fitness is 0.05201082210742114']
# ['At iteration 16 the best fitness is 0.05201082210742114']
# ['At iteration 17 the best fitness is 0.05201082210742114']
# ['At iteration 18 the best fitness is 0.05201082210742114']
# ['At iteration 19 the best fitness is 0.05186518016254102']
# ['At iteration 20 the best fitness is 0.043210740020228636']
# ['At iteration 21 the best fitness is 0.043210740020228636']
# ['At iteration 22 the best fitness is 0.043210740020228636']
# ['At iteration 23 the best fitness is 0.043210740020228636']
# ['At iteration 24 the best fitness is 0.043210740020228636']
# ['At iteration 25 the best fitness is 0.043210740020228636']
# ['At iteration 26 the best fitness is 0.043210740020228636']
# ['At iteration 27 the best fitness is 0.043210740020228636']
# ['At iteration 28 the best fitness is 0.043210740020228636']
# ['At iteration 29 the best fitness is 0.043210740020228636']
# ['At iteration 30 the best fitness is 0.043210740020228636']
#       Selected: 2272/4463 (50.9%), Fitness: 0.0432, Time: 1371.6s
#       Modality: D=55%, S=52%, Sk=51%, V=49%
#     Test Acc: 89.81%, F1: 89.32%, Features: 2272/4463 (50.9%), Model: 4.979MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10492334689586863']
# ['At iteration 2 the best fitness is 0.08722235368272044']
# ['At iteration 3 the best fitness is 0.069230076579812']
# ['At iteration 4 the best fitness is 0.069230076579812']
# ['At iteration 5 the best fitness is 0.06893879269005175']
# ['At iteration 6 the best fitness is 0.06893879269005175']
# ['At iteration 7 the best fitness is 0.06893879269005175']
# ['At iteration 8 the best fitness is 0.06893879269005175']
# ['At iteration 9 the best fitness is 0.06893879269005175']
# ['At iteration 10 the best fitness is 0.06882676042475935']
# ['At iteration 11 the best fitness is 0.06882676042475935']
# ['At iteration 12 the best fitness is 0.06882676042475935']
# ['At iteration 13 the best fitness is 0.06882676042475935']
# ['At iteration 14 the best fitness is 0.06882676042475935']
# ['At iteration 15 the best fitness is 0.06882676042475935']
# ['At iteration 16 the best fitness is 0.06006028801715455']
# ['At iteration 17 the best fitness is 0.06006028801715455']
# ['At iteration 18 the best fitness is 0.06006028801715455']
# ['At iteration 19 the best fitness is 0.06006028801715455']
# ['At iteration 20 the best fitness is 0.06006028801715455']
# ['At iteration 21 the best fitness is 0.06006028801715455']
# ['At iteration 22 the best fitness is 0.06006028801715455']
# ['At iteration 23 the best fitness is 0.06006028801715455']
# ['At iteration 24 the best fitness is 0.06006028801715455']
# ['At iteration 25 the best fitness is 0.06006028801715455']
# ['At iteration 26 the best fitness is 0.0513610349687252']
# ['At iteration 27 the best fitness is 0.0513610349687252']
# ['At iteration 28 the best fitness is 0.0513610349687252']
# ['At iteration 29 the best fitness is 0.0513610349687252']
# ['At iteration 30 the best fitness is 0.0513610349687252']
#       Selected: 2207/4463 (49.5%), Fitness: 0.0514, Time: 1358.6s
#       Modality: D=51%, S=47%, Sk=49%, V=50%
#     Test Acc: 92.59%, F1: 92.62%, Features: 2207/4463 (49.5%), Model: 4.852MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0785791167669373']
# ['At iteration 1 the best fitness is 0.0785791167669373']
# ['At iteration 2 the best fitness is 0.06687739900867151']
# ['At iteration 3 the best fitness is 0.06687739900867151']
# ['At iteration 4 the best fitness is 0.06687739900867151']
# ['At iteration 5 the best fitness is 0.06687739900867151']
# ['At iteration 6 the best fitness is 0.06687739900867151']
# ['At iteration 7 the best fitness is 0.06687739900867151']
# ['At iteration 8 the best fitness is 0.06687739900867151']
# ['At iteration 9 the best fitness is 0.06687739900867151']
# ['At iteration 10 the best fitness is 0.06687739900867151']
# ['At iteration 11 the best fitness is 0.06687739900867151']
# ['At iteration 12 the best fitness is 0.06687739900867151']
# ['At iteration 13 the best fitness is 0.06687739900867151']
# ['At iteration 14 the best fitness is 0.06687739900867151']
# ['At iteration 15 the best fitness is 0.06687739900867151']
# ['At iteration 16 the best fitness is 0.06687739900867151']
# ['At iteration 17 the best fitness is 0.051814713291633605']
# ['At iteration 18 the best fitness is 0.051814713291633605']
# ['At iteration 19 the best fitness is 0.051814713291633605']
# ['At iteration 20 the best fitness is 0.051814713291633605']
# ['At iteration 21 the best fitness is 0.051814713291633605']
# ['At iteration 22 the best fitness is 0.051814713291633605']
# ['At iteration 23 the best fitness is 0.051814713291633605']
# ['At iteration 24 the best fitness is 0.051814713291633605']
# ['At iteration 25 the best fitness is 0.051814713291633605']
# ['At iteration 26 the best fitness is 0.051814713291633605']
# ['At iteration 27 the best fitness is 0.051814713291633605']
# ['At iteration 28 the best fitness is 0.04809524208392578']
# ['At iteration 29 the best fitness is 0.04809524208392578']
#       Selected: 1123/4463 (25.2%), Fitness: 0.0481, Time: 1160.9s
#       Modality: D=24%, S=24%, Sk=26%, V=25%
#     Test Acc: 86.11%, F1: 86.05%, Features: 1123/4463 (25.2%), Model: 2.734MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06909563786146111']
# ['At iteration 2 the best fitness is 0.06909563786146111']
# ['At iteration 3 the best fitness is 0.06909563786146111']
# ['At iteration 4 the best fitness is 0.06909563786146111']
# ['At iteration 5 the best fitness is 0.06884916687781782']
# ['At iteration 6 the best fitness is 0.06884916687781782']
# ['At iteration 7 the best fitness is 0.06084451387420138']
# ['At iteration 8 the best fitness is 0.06084451387420138']
# ['At iteration 9 the best fitness is 0.06084451387420138']
# ['At iteration 10 the best fitness is 0.06084451387420138']
# ['At iteration 11 the best fitness is 0.06084451387420138']
# ['At iteration 12 the best fitness is 0.06084451387420138']
# ['At iteration 13 the best fitness is 0.06084451387420138']
# ['At iteration 14 the best fitness is 0.06084451387420138']
# ['At iteration 15 the best fitness is 0.06084451387420138']
# ['At iteration 16 the best fitness is 0.06084451387420138']
# ['At iteration 17 the best fitness is 0.06084451387420138']
# ['At iteration 18 the best fitness is 0.05196600920130419']
# ['At iteration 19 the best fitness is 0.05195480597477494']
# ['At iteration 20 the best fitness is 0.05195480597477494']
# ['At iteration 21 the best fitness is 0.05195480597477494']
# ['At iteration 22 the best fitness is 0.05195480597477494']
# ['At iteration 23 the best fitness is 0.05195480597477494']
# ['At iteration 24 the best fitness is 0.05195480597477494']
# ['At iteration 25 the best fitness is 0.05195480597477494']
# ['At iteration 26 the best fitness is 0.05195480597477494']
# ['At iteration 27 the best fitness is 0.05195480597477494']
# ['At iteration 28 the best fitness is 0.05195480597477494']
# ['At iteration 29 the best fitness is 0.05195480597477494']
#       Selected: 2260/4463 (50.6%), Fitness: 0.0520, Time: 3412.7s
#       Modality: D=53%, S=52%, Sk=50%, V=50%
#     Test Acc: 91.67%, F1: 90.97%, Features: 2260/4463 (50.6%), Model: 4.955MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09521580345980765']
# ['At iteration 1 the best fitness is 0.06683813536429332']
# ['At iteration 2 the best fitness is 0.06655805470106232']
# ['At iteration 3 the best fitness is 0.06655805470106232']
# ['At iteration 4 the best fitness is 0.06655805470106232']
# ['At iteration 5 the best fitness is 0.05714189985781326']
# ['At iteration 6 the best fitness is 0.05714189985781326']
# ['At iteration 7 the best fitness is 0.05714189985781326']
# ['At iteration 8 the best fitness is 0.05714189985781326']
# ['At iteration 9 the best fitness is 0.05714189985781326']
# ['At iteration 10 the best fitness is 0.05714189985781326']
# ['At iteration 11 the best fitness is 0.05714189985781326']
# ['At iteration 12 the best fitness is 0.05714189985781326']
# ['At iteration 13 the best fitness is 0.05714189985781326']
# ['At iteration 14 the best fitness is 0.05714189985781326']
# ['At iteration 15 the best fitness is 0.05714189985781326']
# ['At iteration 16 the best fitness is 0.05714189985781326']
# ['At iteration 17 the best fitness is 0.05714189985781326']
# ['At iteration 18 the best fitness is 0.05714189985781326']
# ['At iteration 19 the best fitness is 0.05714189985781326']
# ['At iteration 20 the best fitness is 0.05714189985781326']
# ['At iteration 21 the best fitness is 0.05714189985781326']
# ['At iteration 22 the best fitness is 0.05714189985781326']
# ['At iteration 23 the best fitness is 0.05714189985781326']
# ['At iteration 24 the best fitness is 0.05714189985781326']
# ['At iteration 25 the best fitness is 0.05714189985781326']
# ['At iteration 26 the best fitness is 0.05714189985781326']
# ['At iteration 27 the best fitness is 0.05714189985781326']
# ['At iteration 28 the best fitness is 0.05714189985781326']
# ['At iteration 29 the best fitness is 0.05714189985781326']
#       Selected: 2723/4463 (61.0%), Fitness: 0.0571, Time: 1377.8s
#       Modality: D=62%, S=62%, Sk=61%, V=60%
#     Test Acc: 87.96%, F1: 87.16%, Features: 2723/4463 (61.0%), Model: 5.859MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 84.26%, F1: 81.50%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 59.2s
#     Test Acc: 88.89%, F1: 87.28%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.3s
#     Test Acc: 94.44%, F1: 93.96%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 6.5s
#     Test Acc: 67.59%, F1: 63.59%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05212285437271355']
# ['At iteration 1 the best fitness is 0.05208924469312583']
# ['At iteration 2 the best fitness is 0.05208924469312583']
# ['At iteration 3 the best fitness is 0.05208924469312583']
# ['At iteration 4 the best fitness is 0.05208924469312583']
# ['At iteration 5 the best fitness is 0.05208924469312583']
# ['At iteration 6 the best fitness is 0.052055635013538104']
# ['At iteration 7 the best fitness is 0.052055635013538104']
# ['At iteration 8 the best fitness is 0.03408576436368815']
# ['At iteration 9 the best fitness is 0.03408576436368815']
# ['At iteration 10 the best fitness is 0.03408576436368815']
# ['At iteration 11 the best fitness is 0.03408576436368815']
# ['At iteration 12 the best fitness is 0.03408576436368815']
# ['At iteration 13 the best fitness is 0.03408576436368815']
# ['At iteration 14 the best fitness is 0.03408576436368815']
# ['At iteration 15 the best fitness is 0.03408576436368815']
# ['At iteration 16 the best fitness is 0.03408576436368815']
# ['At iteration 17 the best fitness is 0.03408576436368815']
# ['At iteration 18 the best fitness is 0.03408576436368815']
# ['At iteration 19 the best fitness is 0.03408576436368815']
# ['At iteration 20 the best fitness is 0.03408576436368815']
# ['At iteration 21 the best fitness is 0.03408576436368815']
# ['At iteration 22 the best fitness is 0.03408576436368815']
# ['At iteration 23 the best fitness is 0.03408576436368815']
# ['At iteration 24 the best fitness is 0.03408576436368815']
# ['At iteration 25 the best fitness is 0.03408576436368815']
# ['At iteration 26 the best fitness is 0.03408576436368815']
# ['At iteration 27 the best fitness is 0.03408576436368815']
# ['At iteration 28 the best fitness is 0.03408576436368815']
# ['At iteration 29 the best fitness is 0.03408576436368815']
#       Selected: 2250/4463 (50.4%), Fitness: 0.0341, Time: 1420.2s
#       Modality: D=49%, S=50%, Sk=52%, V=49%
#     Test Acc: 89.81%, F1: 87.27%, Features: 2250/4463 (50.4%), Model: 4.936MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.052234886638005955']
# ['At iteration 1 the best fitness is 0.05115937689119887']
# ['At iteration 2 the best fitness is 0.05115937689119887']
# ['At iteration 3 the best fitness is 0.05115937689119887']
# ['At iteration 4 the best fitness is 0.0424265141631818']
# ['At iteration 5 the best fitness is 0.0424265141631818']
# ['At iteration 6 the best fitness is 0.0424265141631818']
# ['At iteration 7 the best fitness is 0.0424265141631818']
# ['At iteration 8 the best fitness is 0.033682448208635495']
# ['At iteration 9 the best fitness is 0.033682448208635495']
# ['At iteration 10 the best fitness is 0.033682448208635495']
# ['At iteration 11 the best fitness is 0.033682448208635495']
# ['At iteration 12 the best fitness is 0.033682448208635495']
# ['At iteration 13 the best fitness is 0.033682448208635495']
# ['At iteration 14 the best fitness is 0.033682448208635495']
# ['At iteration 15 the best fitness is 0.033682448208635495']
# ['At iteration 16 the best fitness is 0.033682448208635495']
# ['At iteration 17 the best fitness is 0.033682448208635495']
# ['At iteration 18 the best fitness is 0.033682448208635495']
# ['At iteration 19 the best fitness is 0.033682448208635495']
# ['At iteration 20 the best fitness is 0.033682448208635495']
# ['At iteration 21 the best fitness is 0.033682448208635495']
# ['At iteration 22 the best fitness is 0.033682448208635495']
# ['At iteration 23 the best fitness is 0.033682448208635495']
# ['At iteration 24 the best fitness is 0.033682448208635495']
# ['At iteration 25 the best fitness is 0.033682448208635495']
# ['At iteration 26 the best fitness is 0.033682448208635495']
# ['At iteration 27 the best fitness is 0.033682448208635495']
# ['At iteration 28 the best fitness is 0.033682448208635495']
# ['At iteration 29 the best fitness is 0.033682448208635495']
#       Selected: 2214/4463 (49.6%), Fitness: 0.0337, Time: 2782.1s
#       Modality: D=47%, S=52%, Sk=49%, V=51%
#     Test Acc: 90.74%, F1: 89.06%, Features: 2214/4463 (49.6%), Model: 4.865MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.042000791555070666']
# ['At iteration 2 the best fitness is 0.042000791555070666']
# ['At iteration 3 the best fitness is 0.042000791555070666']
# ['At iteration 4 the best fitness is 0.042000791555070666']
# ['At iteration 5 the best fitness is 0.042000791555070666']
# ['At iteration 6 the best fitness is 0.042000791555070666']
# ['At iteration 7 the best fitness is 0.042000791555070666']
# ['At iteration 8 the best fitness is 0.042000791555070666']
# ['At iteration 9 the best fitness is 0.042000791555070666']
# ['At iteration 10 the best fitness is 0.042000791555070666']
# ['At iteration 11 the best fitness is 0.04173191411836889']
# ['At iteration 12 the best fitness is 0.04173191411836889']
# ['At iteration 13 the best fitness is 0.04173191411836889']
# ['At iteration 14 the best fitness is 0.04173191411836889']
# ['At iteration 15 the best fitness is 0.04173191411836889']
# ['At iteration 16 the best fitness is 0.032730173953650056']
# ['At iteration 17 the best fitness is 0.032730173953650056']
# ['At iteration 18 the best fitness is 0.032730173953650056']
# ['At iteration 19 the best fitness is 0.024411830607214878']
# ['At iteration 20 the best fitness is 0.024411830607214878']
# ['At iteration 21 the best fitness is 0.024411830607214878']
# ['At iteration 22 the best fitness is 0.024411830607214878']
# ['At iteration 23 the best fitness is 0.024411830607214878']
# ['At iteration 24 the best fitness is 0.024411830607214878']
# ['At iteration 25 the best fitness is 0.024411830607214878']
# ['At iteration 26 the best fitness is 0.024411830607214878']
# ['At iteration 27 the best fitness is 0.024411830607214878']
# ['At iteration 28 the best fitness is 0.024411830607214878']
# ['At iteration 29 the best fitness is 0.024411830607214878']
# ['At iteration 30 the best fitness is 0.024411830607214878']
#       Selected: 2179/4463 (48.8%), Fitness: 0.0244, Time: 1409.4s
#       Modality: D=49%, S=46%, Sk=48%, V=51%
#     Test Acc: 91.67%, F1: 90.62%, Features: 2179/4463 (48.8%), Model: 4.797MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06053082353138265']
# ['At iteration 1 the best fitness is 0.06919646690022428']
# ['At iteration 2 the best fitness is 0.060317962227327084']
# ['At iteration 3 the best fitness is 0.06021713318856392']
# ['At iteration 4 the best fitness is 0.042785017412117494']
# ['At iteration 5 the best fitness is 0.05148427046054685']
# ['At iteration 6 the best fitness is 0.05131622206260824']
# ['At iteration 7 the best fitness is 0.05137223819525444']
# ['At iteration 8 the best fitness is 0.033435977224992204']
# ['At iteration 9 the best fitness is 0.0334919933576384']
# ['At iteration 10 the best fitness is 0.0334919933576384']
# ['At iteration 11 the best fitness is 0.04244892061624028']
# ['At iteration 12 the best fitness is 0.05114817366466963']
# ['At iteration 13 the best fitness is 0.051338628515666715']
# ['At iteration 14 the best fitness is 0.06013871060285923']
# ['At iteration 15 the best fitness is 0.0423704980305356']
# ['At iteration 16 the best fitness is 0.04238170125706484']
# ['At iteration 17 the best fitness is 0.042471327069298764']
# ['At iteration 18 the best fitness is 0.033570415943343083']
# ['At iteration 19 the best fitness is 0.04244892061624028']
# ['At iteration 20 the best fitness is 0.033514399810696885']
# ['At iteration 21 the best fitness is 0.05126020592996204']
# ['At iteration 22 the best fitness is 0.060149913829388474']
# ['At iteration 23 the best fitness is 0.05127140915649128']
# ['At iteration 24 the best fitness is 0.0512490027034328']
# ['At iteration 25 the best fitness is 0.0423704980305356']
# ['At iteration 26 the best fitness is 0.0512490027034328']
# ['At iteration 27 the best fitness is 0.04238170125706484']
# ['At iteration 28 the best fitness is 0.0423704980305356']
# ['At iteration 29 the best fitness is 0.06012750737632999']
#       Selected: 2197/4463 (49.2%), Fitness: 0.0601, Time: 1362.7s
#       Modality: D=52%, S=48%, Sk=49%, V=49%
#     Test Acc: 89.81%, F1: 88.21%, Features: 2197/4463 (49.2%), Model: 4.832MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.05208924469312583
# At iteration 2 the best fitness is 0.0697566282266863
# At iteration 3 the best fitness is 0.06910684108799035
# At iteration 4 the best fitness is 0.06030675900079784
# At iteration 5 the best fitness is 0.06957737660221845
# At iteration 6 the best fitness is 0.0783886619159402
# At iteration 7 the best fitness is 0.06081090419461366
# At iteration 8 the best fitness is 0.04332277228552104
# At iteration 9 the best fitness is 0.04316592711411167
# At iteration 10 the best fitness is 0.0698126443593325
# At iteration 11 the best fitness is 0.06027314932121012
# At iteration 12 the best fitness is 0.0607660912884967
# At iteration 13 the best fitness is 0.043109910981465466
# At iteration 14 the best fitness is 0.05165231885848545
# At iteration 15 the best fitness is 0.05175314789724861
# At iteration 16 the best fitness is 0.061012562272139984
# At iteration 17 the best fitness is 0.05201082210742114
# At iteration 18 the best fitness is 0.05170833499113166
# At iteration 19 the best fitness is 0.06034036868038556
# At iteration 20 the best fitness is 0.05198841565436266
# At iteration 21 the best fitness is 0.03420899985550979
# At iteration 22 the best fitness is 0.06081090419461366
# At iteration 23 the best fitness is 0.04235929480400636
# At iteration 24 the best fitness is 0.04253854642847421
# At iteration 25 the best fitness is 0.0514170511013714
# At iteration 26 the best fitness is 0.04235929480400636
# At iteration 27 the best fitness is 0.033570415943343083
# At iteration 28 the best fitness is 0.03346958690457993
# At iteration 29 the best fitness is 0.05202202533395038
# At iteration 30 the best fitness is 0.05995945897839139
#       Selected: 2182/4463 (48.9%), Fitness: 0.0600, Time: 1363.6s
#       Modality: D=50%, S=48%, Sk=48%, V=50%
#     Test Acc: 93.52%, F1: 93.16%, Features: 2182/4463 (48.9%), Model: 4.803MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06947654756345528']
# ['At iteration 1 the best fitness is 0.050173492956625716']
# ['At iteration 2 the best fitness is 0.050173492956625716']
# ['At iteration 3 the best fitness is 0.050173492956625716']
# ['At iteration 4 the best fitness is 0.04789923797118991']
# ['At iteration 5 the best fitness is 0.04789923797118991']
# ['At iteration 6 the best fitness is 0.04789923797118991']
# ['At iteration 7 the best fitness is 0.04789923797118991']
# ['At iteration 8 the best fitness is 0.0475631411753127']
# ['At iteration 9 the best fitness is 0.04670049273256119']
# ['At iteration 10 the best fitness is 0.037687549341313104']
# ['At iteration 11 the best fitness is 0.036824900898561594']
# ['At iteration 12 the best fitness is 0.036824900898561594']
# ['At iteration 13 the best fitness is 0.036500007329213616']
# ['At iteration 14 the best fitness is 0.036500007329213616']
# ['At iteration 15 the best fitness is 0.036500007329213616']
# ['At iteration 16 the best fitness is 0.036500007329213616']
# ['At iteration 17 the best fitness is 0.036500007329213616']
# ['At iteration 18 the best fitness is 0.036500007329213616']
# ['At iteration 19 the best fitness is 0.036500007329213616']
# ['At iteration 20 the best fitness is 0.036500007329213616']
# ['At iteration 21 the best fitness is 0.036500007329213616']
# ['At iteration 22 the best fitness is 0.036500007329213616']
# ['At iteration 23 the best fitness is 0.036500007329213616']
# ['At iteration 24 the best fitness is 0.036500007329213616']
# ['At iteration 25 the best fitness is 0.036500007329213616']
# ['At iteration 26 the best fitness is 0.036500007329213616']
# ['At iteration 27 the best fitness is 0.036500007329213616']
# ['At iteration 28 the best fitness is 0.036500007329213616']
# ['At iteration 29 the best fitness is 0.036500007329213616']
#       Selected: 1673/4463 (37.5%), Fitness: 0.0365, Time: 1293.8s
#       Modality: D=38%, S=36%, Sk=38%, V=37%
#     Test Acc: 90.74%, F1: 88.91%, Features: 1673/4463 (37.5%), Model: 3.809MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.06891638623699327']
# ['At iteration 1 the best fitness is 0.06891638623699327']
# ['At iteration 2 the best fitness is 0.06891638623699327']
# ['At iteration 3 the best fitness is 0.06891638623699327']
# ['At iteration 4 the best fitness is 0.03169382314816948']
# ['At iteration 5 the best fitness is 0.03169382314816948']
# ['At iteration 6 the best fitness is 0.03169382314816948']
# ['At iteration 7 the best fitness is 0.03169382314816948']
# ['At iteration 8 the best fitness is 0.03169382314816948']
# ['At iteration 9 the best fitness is 0.03169382314816948']
# ['At iteration 10 the best fitness is 0.03169382314816948']
# ['At iteration 11 the best fitness is 0.03169382314816948']
# ['At iteration 12 the best fitness is 0.03169382314816948']
# ['At iteration 13 the best fitness is 0.03169382314816948']
# ['At iteration 14 the best fitness is 0.03169382314816948']
# ['At iteration 15 the best fitness is 0.03169382314816948']
# ['At iteration 16 the best fitness is 0.03169382314816948']
# ['At iteration 17 the best fitness is 0.03169382314816948']
# ['At iteration 18 the best fitness is 0.03169382314816948']
# ['At iteration 19 the best fitness is 0.03169382314816948']
# ['At iteration 20 the best fitness is 0.03169382314816948']
# ['At iteration 21 the best fitness is 0.03169382314816948']
# ['At iteration 22 the best fitness is 0.03169382314816948']
# ['At iteration 23 the best fitness is 0.03169382314816948']
# ['At iteration 24 the best fitness is 0.03169382314816948']
# ['At iteration 25 the best fitness is 0.03169382314816948']
# ['At iteration 26 the best fitness is 0.03169382314816948']
# ['At iteration 27 the best fitness is 0.03169382314816948']
# ['At iteration 28 the best fitness is 0.03169382314816948']
# ['At iteration 29 the best fitness is 0.03169382314816948']
#       Selected: 1244/4463 (27.9%), Fitness: 0.0317, Time: 1672.6s
#       Modality: D=32%, S=30%, Sk=25%, V=29%
#     Test Acc: 89.81%, F1: 89.66%, Features: 1244/4463 (27.9%), Model: 2.971MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05214526082577203']
# ['At iteration 1 the best fitness is 0.05214526082577203']
# ['At iteration 2 the best fitness is 0.04241531093665256']
# ['At iteration 3 the best fitness is 0.04241531093665256']
# ['At iteration 4 the best fitness is 0.04241531093665256']
# ['At iteration 5 the best fitness is 0.04241531093665256']
# ['At iteration 6 the best fitness is 0.04241531093665256']
# ['At iteration 7 the best fitness is 0.04241531093665256']
# ['At iteration 8 the best fitness is 0.04241531093665256']
# ['At iteration 9 the best fitness is 0.04241531093665256']
# ['At iteration 10 the best fitness is 0.04241531093665256']
# ['At iteration 11 the best fitness is 0.04241531093665256']
# ['At iteration 12 the best fitness is 0.04241531093665256']
# ['At iteration 13 the best fitness is 0.04240410771012332']
# ['At iteration 14 the best fitness is 0.04240410771012332']
# ['At iteration 15 the best fitness is 0.04240410771012332']
# ['At iteration 16 the best fitness is 0.04240410771012332']
# ['At iteration 17 the best fitness is 0.04240410771012332']
# ['At iteration 18 the best fitness is 0.042348091577477126']
# ['At iteration 19 the best fitness is 0.042348091577477126']
# ['At iteration 20 the best fitness is 0.04230327867136016']
# ['At iteration 21 the best fitness is 0.04230327867136016']
# ['At iteration 22 the best fitness is 0.04230327867136016']
# ['At iteration 23 the best fitness is 0.04230327867136016']
# ['At iteration 24 the best fitness is 0.04230327867136016']
# ...
# ['At iteration 15 the best fitness is 0.04733907664472789']
# ['At iteration 16 the best fitness is 0.04733907664472789']
# ['At iteration 17 the best fitness is 0.04733907664472789']
# ['At iteration 18 the best fitness is 0.04733907664472789']
# ['At iteration 19 the best fitness is 0.04733907664472789']
# ['At iteration 20 the best fitness is 0.04733907664472789']
# ['At iteration 21 the best fitness is 0.04733907664472789']
# ['At iteration 22 the best fitness is 0.04733907664472789']
# ['At iteration 23 the best fitness is 0.04733907664472789']
# ['At iteration 24 the best fitness is 0.04733907664472789']
# ['At iteration 25 the best fitness is 0.04733907664472789']
# ['At iteration 26 the best fitness is 0.04733907664472789']
# ['At iteration 27 the best fitness is 0.04733907664472789']
# ['At iteration 28 the best fitness is 0.04733907664472789']
# ['At iteration 29 the best fitness is 0.04733907664472789']
#       Selected: 1848/4463 (41.4%), Fitness: 0.0473, Time: 1823.1s
#       Modality: D=44%, S=44%, Sk=40%, V=42%
#     Test Acc: 96.26%, F1: 96.14%, Features: 1848/4463 (41.4%), Model: 4.151MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07864633612611273']
# ['At iteration 1 the best fitness is 0.06891638623699327']
# ['At iteration 2 the best fitness is 0.06891638623699327']
# ['At iteration 3 the best fitness is 0.051282612383020516']
# ['At iteration 4 the best fitness is 0.051092157532023424']
# ['At iteration 5 the best fitness is 0.051092157532023424']
# ['At iteration 6 the best fitness is 0.051092157532023424']
# ['At iteration 7 the best fitness is 0.051092157532023424']
# ['At iteration 8 the best fitness is 0.051092157532023424']
# ['At iteration 9 the best fitness is 0.051092157532023424']
# ['At iteration 10 the best fitness is 0.051092157532023424']
# ['At iteration 11 the best fitness is 0.051092157532023424']
# ['At iteration 12 the best fitness is 0.051092157532023424']
# ['At iteration 13 the best fitness is 0.051092157532023424']
# ['At iteration 14 the best fitness is 0.051092157532023424']
# ['At iteration 15 the best fitness is 0.051092157532023424']
# ['At iteration 16 the best fitness is 0.051092157532023424']
# ['At iteration 17 the best fitness is 0.04300908194270231']
# ['At iteration 18 the best fitness is 0.04300908194270231']
# ['At iteration 19 the best fitness is 0.04300908194270231']
# ['At iteration 20 the best fitness is 0.04300908194270231']
# ['At iteration 21 the best fitness is 0.04252734320194497']
# ['At iteration 22 the best fitness is 0.04252734320194497']
# ['At iteration 23 the best fitness is 0.04252734320194497']
# ['At iteration 24 the best fitness is 0.04252734320194497']
# ['At iteration 25 the best fitness is 0.04252734320194497']
# ['At iteration 26 the best fitness is 0.04252734320194497']
# ['At iteration 27 the best fitness is 0.04252734320194497']
# ['At iteration 28 the best fitness is 0.04252734320194497']
# ['At iteration 29 the best fitness is 0.04252734320194497']
#       Selected: 2211/4463 (49.5%), Fitness: 0.0425, Time: 1414.0s
#       Modality: D=48%, S=52%, Sk=49%, V=49%
#     Test Acc: 98.13%, F1: 98.12%, Features: 2211/4463 (49.5%), Model: 4.859MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08746882466636373']
# ['At iteration 2 the best fitness is 0.06888277655740555']
# ['At iteration 3 the best fitness is 0.06888277655740555']
# ['At iteration 4 the best fitness is 0.06888277655740555']
# ['At iteration 5 the best fitness is 0.06888277655740555']
# ['At iteration 6 the best fitness is 0.0608221074211429']
# ['At iteration 7 the best fitness is 0.0608221074211429']
# ['At iteration 8 the best fitness is 0.0608221074211429']
# ['At iteration 9 the best fitness is 0.0608221074211429']
# ['At iteration 10 the best fitness is 0.0608221074211429']
# ['At iteration 11 the best fitness is 0.0608221074211429']
# ['At iteration 12 the best fitness is 0.0608221074211429']
# ['At iteration 13 the best fitness is 0.06073248160890898']
# ['At iteration 14 the best fitness is 0.06073248160890898']
# ['At iteration 15 the best fitness is 0.06073248160890898']
# ['At iteration 16 the best fitness is 0.06073248160890898']
# ['At iteration 17 the best fitness is 0.060486010625265686']
# ['At iteration 18 the best fitness is 0.060486010625265686']
# ['At iteration 19 the best fitness is 0.060486010625265686']
# ['At iteration 20 the best fitness is 0.060486010625265686']
# ['At iteration 21 the best fitness is 0.060486010625265686']
# ['At iteration 22 the best fitness is 0.060486010625265686']
# ['At iteration 23 the best fitness is 0.060486010625265686']
# ['At iteration 24 the best fitness is 0.060486010625265686']
# ['At iteration 25 the best fitness is 0.060486010625265686']
# ['At iteration 26 the best fitness is 0.05184277370948254']
# ['At iteration 27 the best fitness is 0.05184277370948254']
# ['At iteration 28 the best fitness is 0.05184277370948254']
# ['At iteration 29 the best fitness is 0.05184277370948254']
#       Selected: 2250/4463 (50.4%), Fitness: 0.0518, Time: 1331.1s
#       Modality: D=54%, S=52%, Sk=51%, V=47%
#     Test Acc: 99.07%, F1: 99.06%, Features: 2250/4463 (50.4%), Model: 4.936MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06886037010434706']
# ['At iteration 2 the best fitness is 0.05129381560954976']
# ['At iteration 3 the best fitness is 0.05129381560954976']
# ['At iteration 4 the best fitness is 0.05129381560954976']
# ['At iteration 5 the best fitness is 0.05129381560954976']
# ['At iteration 6 the best fitness is 0.05129381560954976']
# ['At iteration 7 the best fitness is 0.05129381560954976']
# ['At iteration 8 the best fitness is 0.05129381560954976']
# ['At iteration 9 the best fitness is 0.05129381560954976']
# ['At iteration 10 the best fitness is 0.05129381560954976']
# ['At iteration 11 the best fitness is 0.05129381560954976']
# ['At iteration 12 the best fitness is 0.05129381560954976']
# ['At iteration 13 the best fitness is 0.05129381560954976']
# ['At iteration 14 the best fitness is 0.05129381560954976']
# ['At iteration 15 the best fitness is 0.05129381560954976']
# ['At iteration 16 the best fitness is 0.05129381560954976']
# ['At iteration 17 the best fitness is 0.05129381560954976']
# ['At iteration 18 the best fitness is 0.05129381560954976']
# ['At iteration 19 the best fitness is 0.05129381560954976']
# ['At iteration 20 the best fitness is 0.05129381560954976']
# ['At iteration 21 the best fitness is 0.05129381560954976']
# ['At iteration 22 the best fitness is 0.05129381560954976']
# ['At iteration 23 the best fitness is 0.05129381560954976']
# ['At iteration 24 the best fitness is 0.05129381560954976']
# ['At iteration 25 the best fitness is 0.05129381560954976']
# ['At iteration 26 the best fitness is 0.05129381560954976']
# ['At iteration 27 the best fitness is 0.05129381560954976']
# ['At iteration 28 the best fitness is 0.05129381560954976']
# ['At iteration 29 the best fitness is 0.05129381560954976']
# ['At iteration 30 the best fitness is 0.05129381560954976']
#       Selected: 2201/4463 (49.3%), Fitness: 0.0513, Time: 1368.1s
#       Modality: D=48%, S=50%, Sk=48%, V=51%
#     Test Acc: 91.59%, F1: 89.97%, Features: 2201/4463 (49.3%), Model: 4.840MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0867966310746093']
# ['At iteration 2 the best fitness is 0.08649414395831981']
# ['At iteration 3 the best fitness is 0.08649414395831981']
# ['At iteration 4 the best fitness is 0.06002667833756683']
# ['At iteration 5 the best fitness is 0.0514170511013714']
# ['At iteration 6 the best fitness is 0.0514170511013714']
# ['At iteration 7 the best fitness is 0.0514170511013714']
# ['At iteration 8 the best fitness is 0.0514170511013714']
# ['At iteration 9 the best fitness is 0.0514170511013714']
# ['At iteration 10 the best fitness is 0.0514170511013714']
# ['At iteration 11 the best fitness is 0.04276261095905902']
# ['At iteration 12 the best fitness is 0.04276261095905902']
# ['At iteration 13 the best fitness is 0.04276261095905902']
# ['At iteration 14 the best fitness is 0.04276261095905902']
# ['At iteration 15 the best fitness is 0.04276261095905902']
# ['At iteration 16 the best fitness is 0.04276261095905902']
# ['At iteration 17 the best fitness is 0.04276261095905902']
# ['At iteration 18 the best fitness is 0.04276261095905902']
# ['At iteration 19 the best fitness is 0.04276261095905902']
# ['At iteration 20 the best fitness is 0.04276261095905902']
# ['At iteration 21 the best fitness is 0.04276261095905902']
# ['At iteration 22 the best fitness is 0.04276261095905902']
# ['At iteration 23 the best fitness is 0.04276261095905902']
# ['At iteration 24 the best fitness is 0.04276261095905902']
# ['At iteration 25 the best fitness is 0.04276261095905902']
# ['At iteration 26 the best fitness is 0.04276261095905902']
# ['At iteration 27 the best fitness is 0.04276261095905902']
# ['At iteration 28 the best fitness is 0.04276261095905902']
# ['At iteration 29 the best fitness is 0.04276261095905902']
# ['At iteration 30 the best fitness is 0.04276261095905902']
#       Selected: 2232/4463 (50.0%), Fitness: 0.0428, Time: 1316.4s
#       Modality: D=49%, S=48%, Sk=51%, V=50%
#     Test Acc: 98.13%, F1: 98.12%, Features: 2232/4463 (50.0%), Model: 4.901MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08718874400313273']
# ['At iteration 1 the best fitness is 0.0675383893738967']
# ['At iteration 2 the best fitness is 0.0675383893738967']
# ['At iteration 3 the best fitness is 0.0675383893738967']
# ['At iteration 4 the best fitness is 0.05471634896270687']
# ['At iteration 5 the best fitness is 0.05471634896270687']
# ['At iteration 6 the best fitness is 0.05471634896270687']
# ['At iteration 7 the best fitness is 0.05471634896270687']
# ['At iteration 8 the best fitness is 0.05471634896270687']
# ['At iteration 9 the best fitness is 0.05471634896270687']
# ['At iteration 10 the best fitness is 0.05471634896270687']
# ['At iteration 11 the best fitness is 0.05471634896270687']
# ['At iteration 12 the best fitness is 0.05471634896270687']
# ['At iteration 13 the best fitness is 0.05471634896270687']
# ['At iteration 14 the best fitness is 0.05471634896270687']
# ['At iteration 15 the best fitness is 0.05471634896270687']
# ['At iteration 16 the best fitness is 0.05471634896270687']
# ['At iteration 17 the best fitness is 0.05471634896270687']
# ['At iteration 18 the best fitness is 0.05471634896270687']
# ['At iteration 19 the best fitness is 0.05471634896270687']
# ['At iteration 20 the best fitness is 0.05471634896270687']
# ['At iteration 21 the best fitness is 0.05471634896270687']
# ['At iteration 22 the best fitness is 0.05471634896270687']
# ['At iteration 23 the best fitness is 0.05471634896270687']
# ['At iteration 24 the best fitness is 0.05471634896270687']
# ['At iteration 25 the best fitness is 0.05471634896270687']
# ['At iteration 26 the best fitness is 0.05471634896270687']
# ['At iteration 27 the best fitness is 0.05471634896270687']
# ['At iteration 28 the best fitness is 0.05471634896270687']
# ['At iteration 29 the best fitness is 0.05471634896270687']
#       Selected: 1714/4463 (38.4%), Fitness: 0.0547, Time: 1191.6s
#       Modality: D=37%, S=40%, Sk=38%, V=38%
#     Test Acc: 92.52%, F1: 91.01%, Features: 1714/4463 (38.4%), Model: 3.889MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0687035249329377']
# ['At iteration 2 the best fitness is 0.06062044934361657']
# ['At iteration 3 the best fitness is 0.06062044934361657']
# ['At iteration 4 the best fitness is 0.06062044934361657']
# ['At iteration 5 the best fitness is 0.06044119771914873']
# ['At iteration 6 the best fitness is 0.06044119771914873']
# ['At iteration 7 the best fitness is 0.060105100923271516']
# ['At iteration 8 the best fitness is 0.05189878984212874']
# ['At iteration 9 the best fitness is 0.05189878984212874']
# ['At iteration 10 the best fitness is 0.04284103354476369']
# ['At iteration 11 the best fitness is 0.04284103354476369']
# ['At iteration 12 the best fitness is 0.04284103354476369']
# ['At iteration 13 the best fitness is 0.04284103354476369']
# ['At iteration 14 the best fitness is 0.04284103354476369']
# ['At iteration 15 the best fitness is 0.04284103354476369']
# ['At iteration 16 the best fitness is 0.04284103354476369']
# ['At iteration 17 the best fitness is 0.04284103354476369']
# ['At iteration 18 the best fitness is 0.04284103354476369']
# ['At iteration 19 the best fitness is 0.04284103354476369']
# ['At iteration 20 the best fitness is 0.04284103354476369']
# ['At iteration 21 the best fitness is 0.04284103354476369']
# ['At iteration 22 the best fitness is 0.04284103354476369']
# ['At iteration 23 the best fitness is 0.04284103354476369']
# ['At iteration 24 the best fitness is 0.04284103354476369']
# ['At iteration 25 the best fitness is 0.04284103354476369']
# ['At iteration 26 the best fitness is 0.04284103354476369']
# ['At iteration 27 the best fitness is 0.04284103354476369']
# ['At iteration 28 the best fitness is 0.04284103354476369']
# ['At iteration 29 the best fitness is 0.04284103354476369']
#       Selected: 2239/4463 (50.2%), Fitness: 0.0428, Time: 3407.8s
#       Modality: D=52%, S=52%, Sk=50%, V=49%
#     Test Acc: 90.65%, F1: 89.32%, Features: 2239/4463 (50.2%), Model: 4.914MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07834384900982325']
# ['At iteration 1 the best fitness is 0.07583432626727339']
# ['At iteration 2 the best fitness is 0.0623288890377999']
# ['At iteration 3 the best fitness is 0.0623288890377999']
# ['At iteration 4 the best fitness is 0.0623288890377999']
# ['At iteration 5 the best fitness is 0.0623288890377999']
# ['At iteration 6 the best fitness is 0.05834619435818077']
# ['At iteration 7 the best fitness is 0.05834619435818077']
# ['At iteration 8 the best fitness is 0.05834619435818077']
# ['At iteration 9 the best fitness is 0.05834619435818077']
# ['At iteration 10 the best fitness is 0.05834619435818077']
# ['At iteration 11 the best fitness is 0.05834619435818077']
# ['At iteration 12 the best fitness is 0.05834619435818077']
# ['At iteration 13 the best fitness is 0.05834619435818077']
# ['At iteration 14 the best fitness is 0.05834619435818077']
# ['At iteration 15 the best fitness is 0.05834619435818077']
# ['At iteration 16 the best fitness is 0.05834619435818077']
# ['At iteration 17 the best fitness is 0.05834619435818077']
# ['At iteration 18 the best fitness is 0.05834619435818077']
# ['At iteration 19 the best fitness is 0.05834619435818077']
# ['At iteration 20 the best fitness is 0.05834619435818077']
# ['At iteration 21 the best fitness is 0.05834619435818077']
# ['At iteration 22 the best fitness is 0.05834619435818077']
# ['At iteration 23 the best fitness is 0.05834619435818077']
# ['At iteration 24 the best fitness is 0.05834619435818077']
# ['At iteration 25 the best fitness is 0.05834619435818077']
# ['At iteration 26 the best fitness is 0.05834619435818077']
# ['At iteration 27 the best fitness is 0.05834619435818077']
# ['At iteration 28 the best fitness is 0.05834619435818077']
# ['At iteration 29 the best fitness is 0.05834619435818077']
#       Selected: 2038/4463 (45.7%), Fitness: 0.0583, Time: 992.8s
#       Modality: D=45%, S=50%, Sk=44%, V=46%
#     Test Acc: 91.59%, F1: 90.93%, Features: 2038/4463 (45.7%), Model: 4.522MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          93.518519         91.588785     92.476145
# 1  baseline     2          84.259259         98.130841     81.503127
# 2  baseline     3          82.407407         95.327103     80.159626
# 3  baseline     4          91.666667         93.457944     90.403835
# 4  baseline     5          89.814815         94.392523     89.771792
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        92.476145            92.572016         93.518519               4463
# 1        81.503127            81.684303         84.259259               4463
# 2        80.159626            84.058472         82.407407               4463
# 3        90.403835            91.275720         91.666667               4463
# 4        89.771792            94.708995         89.814815               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              89.67              4.43              88.57              5.20                 4463.00                      100.00              0.00                24.78                24.78          2425371.0                  9.26                        0.00               72.33
# mutual_info              91.99              3.84              90.96              4.46                 2231.00                       49.99             57.34                20.27                77.61          1282587.0                  4.90                       50.01               45.90
#         rfe              90.59              5.55              89.61              6.36                 2231.00                       49.99             10.14                20.99                31.13          1282587.0                  4.90                       50.01               45.90
#       lasso              71.21             11.24              68.53             11.64                 2231.00                       49.99             92.77                22.42               115.19          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              88.39              5.10              86.87              6.12                 2221.88                       49.78           1414.59                22.64              1437.23          1277915.0                  4.88                       50.22               45.85
#     meta_CS              88.74              3.79              87.89              4.25                 2209.88                       49.52           2780.51                22.65              2803.16          1271771.0                  4.86                       50.48               45.75
#     meta_DE              88.27              4.33              86.79              4.75                 2207.88                       49.47           1411.38                22.64              1434.02          1270747.0                  4.85                       50.53               45.75
#    meta_FFA              88.03              4.09              86.23              5.11                 2207.50                       49.46           1364.29                22.65              1386.93          1270555.0                  4.85                       50.54               45.74
#     meta_GA              88.84              4.70              87.48              5.30                 2231.12                       49.99           1360.72                22.13              1382.85          1282651.0                  4.90                       50.01               45.96
#    meta_GWO              86.65              4.99              85.24              5.84                 1779.75                       39.88           1291.41                20.52              1311.94          1051547.0                  4.02                       60.12               40.86
#    meta_HHO              84.10              7.72              82.52              9.06                 1465.12                       32.83           1784.37                22.07              1806.43           890459.0                  3.40                       67.17               37.25
#   meta_JAYA              90.02              4.37              88.80              5.19                 2193.62                       49.15           1411.97                22.59              1434.56          1263451.0                  4.83                       50.85               45.61
#    meta_MFO              91.42              4.07              90.67              4.51                 2249.12                       50.39           1332.15                22.51              1354.67          1291867.0                  4.93                       49.61               46.15
#    meta_MVO              88.28              3.60              86.97              4.01                 2218.00                       49.70           1368.43                22.58              1391.01          1275931.0                  4.87                       50.30               45.85
#    meta_PSO              90.25              4.87              89.44              5.57                 2202.12                       49.34           1348.74                21.57              1370.31          1267803.0                  4.84                       50.66               45.68
#    meta_SCA              86.19              4.35              85.27              4.54                 1299.75                       29.12           1174.65                20.59              1195.24           805787.0                  3.08                       70.88               35.28
#    meta_SSA              88.50              3.20              87.30              3.82                 2221.75                       49.78           3413.81                22.37              3436.18          1277851.0                  4.88                       50.22               45.86
#    meta_WOA              88.05              5.01              86.59              6.22                 2218.25                       49.70           1267.51                20.50              1288.01          1276059.0                  4.87                       50.30               45.97

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_DE
#     F1 Macro:           93.85%
#     F1 Weighted:        93.85%
#     Test Accuracy:      94.44%
#     Feature Retention:  48.53% (2166/4463)
#     Modality Retention: depth=49.6%, sensor=48.9%, skeleton=48.7%, video=47.7%
#
#   Fold 2: Best = meta_PSO
#     F1 Macro:           93.23%
#     F1 Weighted:        93.23%
#     Test Accuracy:      93.52%
#     Feature Retention:  50.32% (2246/4463)
#     Modality Retention: depth=51.0%, sensor=50.9%, skeleton=50.0%, video=50.2%
#
#   Fold 3: Best = meta_GA
#     F1 Macro:           90.28%
#     F1 Weighted:        90.28%
#     Test Accuracy:      91.67%
#     Feature Retention:  50.77% (2266/4463)
#     Modality Retention: depth=49.0%, sensor=53.7%, skeleton=51.0%, video=49.7%
#
#   Fold 4: Best = meta_JAYA
#     F1 Macro:           91.54%
#     F1 Weighted:        91.54%
#     Test Accuracy:      92.59%
#     Feature Retention:  49.47% (2208/4463)
#     Modality Retention: depth=51.0%, sensor=49.5%, skeleton=47.3%, video=51.8%
#
#   Fold 5: Best = meta_MFO
#     F1 Macro:           89.10%
#     F1 Weighted:        89.10%
#     Test Accuracy:      89.81%
#     Feature Retention:  50.95% (2274/4463)
#     Modality Retention: depth=52.0%, sensor=51.5%, skeleton=49.1%, video=52.8%
#
#   Fold 6: Best = meta_MFO
#     F1 Macro:           91.25%
#     F1 Weighted:        91.17%
#     Test Accuracy:      91.59%
#     Feature Retention:  52.03% (2322/4463)
#     Modality Retention: depth=52.3%, sensor=52.1%, skeleton=51.9%, video=52.0%
#
#   Fold 7: Best = meta_MVO
#     F1 Macro:           94.17%
#     F1 Weighted:        94.11%
#     Test Accuracy:      94.39%
#     Feature Retention:  48.08% (2146/4463)
#     Modality Retention: depth=45.5%, sensor=46.8%, skeleton=47.8%, video=50.0%
#
#   Fold 8: Best = meta_MFO
#     F1 Macro:           99.06%
#     F1 Weighted:        99.05%
#     Test Accuracy:      99.07%
#     Feature Retention:  50.41% (2250/4463)
#     Modality Retention: depth=54.1%, sensor=52.0%, skeleton=51.1%, video=47.4%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 92.81% ± 3.08%
#
#   Average F1 Weighted         : 92.79% ± 3.08%
#
#   Average Test Accuracy       : 93.39% ± 2.78%
#
#   Average Feature Retention   : 50.07% ± 1.31%
#
#   Average Modality-wise Feature Retention:
#            depth: 50.56% ± 2.59%
#           sensor: 50.69% ± 2.18%
#         skeleton: 49.62% ± 1.67%
#            video: 50.21% ± 1.96%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1            meta_DE         93.85            93.85              94.44                  48.53              49.61               48.93                 48.70              47.75
#     2           meta_PSO         93.23            93.23              93.52                  50.32              50.98               50.92                 50.03              50.21
#     3            meta_GA         90.28            90.28              91.67                  50.77              49.02               53.68                 51.04              49.72
#     4          meta_JAYA         91.54            91.54              92.59                  49.47              50.98               49.54                 47.31              51.76
#     5           meta_MFO         89.10            89.10              89.81                  50.95              51.95               51.53                 49.07              52.82
#     6           meta_MFO         91.25            91.17              91.59                  52.03              52.34               52.15                 51.89              52.04
#     7           meta_MVO         94.17            94.11              94.39                  48.08              45.51               46.78                 47.79              50.00
#     8           meta_MFO         99.06            99.05              99.07                  50.41              54.10               51.99                 51.14              47.39
#
# Saved to: results_noise_1.0_10/best_metaheuristic_per_fold.csv
