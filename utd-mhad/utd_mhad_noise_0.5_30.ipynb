# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_noise_0.5_30")

# Master output directory
RESULTS_ROOT = Path("results_noise_0.5_30")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

# FEATURE_DIMS will be set dynamically per-fold after PCA
# (depth dim changes if PCA is applied)
print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 93.52%, F1: 93.52%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 61.6s
#     Test Acc: 95.37%, F1: 95.05%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 11.1s
#     Test Acc: 94.44%, F1: 94.17%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 5.6s
#     Test Acc: 58.33%, F1: 56.22%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07823181674453084']
# ['At iteration 1 the best fitness is 0.07823181674453084']
# ['At iteration 2 the best fitness is 0.07823181674453084']
# ['At iteration 3 the best fitness is 0.07823181674453084']
# ['At iteration 4 the best fitness is 0.07823181674453084']
# ['At iteration 5 the best fitness is 0.07823181674453084']
# ['At iteration 6 the best fitness is 0.07823181674453084']
# ['At iteration 7 the best fitness is 0.07823181674453084']
# ['At iteration 8 the best fitness is 0.07823181674453084']
# ['At iteration 9 the best fitness is 0.07823181674453084']
# ['At iteration 10 the best fitness is 0.07823181674453084']
# ['At iteration 11 the best fitness is 0.07823181674453084']
# ['At iteration 12 the best fitness is 0.07823181674453084']
# ['At iteration 13 the best fitness is 0.07823181674453084']
# ['At iteration 14 the best fitness is 0.07823181674453084']
# ['At iteration 15 the best fitness is 0.07823181674453084']
# ['At iteration 16 the best fitness is 0.07823181674453084']
# ['At iteration 17 the best fitness is 0.0695885798287477']
# ['At iteration 18 the best fitness is 0.0695885798287477']
# ['At iteration 19 the best fitness is 0.0695885798287477']
# ['At iteration 20 the best fitness is 0.0695885798287477']
# ['At iteration 21 the best fitness is 0.0695885798287477']
# ['At iteration 22 the best fitness is 0.0695885798287477']
# ['At iteration 23 the best fitness is 0.0695885798287477']
# ['At iteration 24 the best fitness is 0.0695885798287477']
# ['At iteration 25 the best fitness is 0.0695885798287477']
# ['At iteration 26 the best fitness is 0.0695885798287477']
# ['At iteration 27 the best fitness is 0.0695885798287477']
# ['At iteration 28 the best fitness is 0.0695885798287477']
# ['At iteration 29 the best fitness is 0.0695885798287477']
#       Selected: 2249/4463 (50.4%), Fitness: 0.0696, Time: 1407.1s
#       Modality: D=50%, S=55%, Sk=49%, V=50%
#     Test Acc: 88.89%, F1: 89.07%, Features: 2249/4463 (50.4%), Model: 4.934MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09577596478626967']
# ['At iteration 1 the best fitness is 0.07801895544047527']
# ['At iteration 2 the best fitness is 0.07801895544047527']
# ['At iteration 3 the best fitness is 0.07801895544047527']
# ['At iteration 4 the best fitness is 0.07801895544047527']
# ['At iteration 5 the best fitness is 0.07801895544047527']
# ['At iteration 6 the best fitness is 0.07801895544047527']
# ['At iteration 7 the best fitness is 0.07801895544047527']
# ['At iteration 8 the best fitness is 0.07801895544047527']
# ['At iteration 9 the best fitness is 0.07801895544047527']
# ['At iteration 10 the best fitness is 0.07801895544047527']
# ['At iteration 11 the best fitness is 0.07801895544047527']
# ['At iteration 12 the best fitness is 0.07801895544047527']
# ['At iteration 13 the best fitness is 0.07801895544047527']
# ['At iteration 14 the best fitness is 0.07801895544047527']
# ['At iteration 15 the best fitness is 0.07801895544047527']
# ['At iteration 16 the best fitness is 0.07801895544047527']
# ['At iteration 17 the best fitness is 0.07801895544047527']
# ['At iteration 18 the best fitness is 0.07801895544047527']
# ['At iteration 19 the best fitness is 0.07801895544047527']
# ['At iteration 20 the best fitness is 0.07801895544047527']
# ['At iteration 21 the best fitness is 0.07801895544047527']
# ['At iteration 22 the best fitness is 0.07801895544047527']
# ['At iteration 23 the best fitness is 0.07801895544047527']
# ['At iteration 24 the best fitness is 0.07801895544047527']
# ['At iteration 25 the best fitness is 0.07801895544047527']
# ['At iteration 26 the best fitness is 0.07801895544047527']
# ['At iteration 27 the best fitness is 0.07801895544047527']
# ['At iteration 28 the best fitness is 0.07801895544047527']
# ['At iteration 29 the best fitness is 0.07801895544047527']
#       Selected: 2209/4463 (49.5%), Fitness: 0.0780, Time: 2765.2s
#       Modality: D=49%, S=49%, Sk=50%, V=49%
#     Test Acc: 92.59%, F1: 92.32%, Features: 2209/4463 (49.5%), Model: 4.856MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09559671316180182']
# ['At iteration 2 the best fitness is 0.09559671316180182']
# ['At iteration 3 the best fitness is 0.09559671316180182']
# ['At iteration 4 the best fitness is 0.09559671316180182']
# ['At iteration 5 the best fitness is 0.09559671316180182']
# ['At iteration 6 the best fitness is 0.09559671316180182']
# ['At iteration 7 the best fitness is 0.09559671316180182']
# ['At iteration 8 the best fitness is 0.09541746153733398']
# ['At iteration 9 the best fitness is 0.09541746153733398']
# ['At iteration 10 the best fitness is 0.08663978590319994']
# ['At iteration 11 the best fitness is 0.08663978590319994']
# ['At iteration 12 the best fitness is 0.08663978590319994']
# ['At iteration 13 the best fitness is 0.08663978590319994']
# ['At iteration 14 the best fitness is 0.08663978590319994']
# ['At iteration 15 the best fitness is 0.08663978590319994']
# ['At iteration 16 the best fitness is 0.08663978590319994']
# ['At iteration 17 the best fitness is 0.08663978590319994']
# ['At iteration 18 the best fitness is 0.07798534576088754']
# ['At iteration 19 the best fitness is 0.07798534576088754']
# ['At iteration 20 the best fitness is 0.07798534576088754']
# ['At iteration 21 the best fitness is 0.07798534576088754']
# ['At iteration 22 the best fitness is 0.07798534576088754']
# ['At iteration 23 the best fitness is 0.07798534576088754']
# ['At iteration 24 the best fitness is 0.07798534576088754']
# ['At iteration 25 the best fitness is 0.07798534576088754']
# ['At iteration 26 the best fitness is 0.07798534576088754']
# ['At iteration 27 the best fitness is 0.07798534576088754']
# ['At iteration 28 the best fitness is 0.07798534576088754']
# ['At iteration 29 the best fitness is 0.07798534576088754']
# ['At iteration 30 the best fitness is 0.07798534576088754']
#       Selected: 2206/4463 (49.4%), Fitness: 0.0780, Time: 1403.7s
#       Modality: D=47%, S=49%, Sk=51%, V=49%
#     Test Acc: 91.67%, F1: 91.76%, Features: 2206/4463 (49.4%), Model: 4.850MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10494575334892711']
# ['At iteration 1 the best fitness is 0.12255712074984138']
# ['At iteration 2 the best fitness is 0.11373463220959039']
# ['At iteration 3 the best fitness is 0.0965601906433165']
# ['At iteration 4 the best fitness is 0.12296043690489403']
# ['At iteration 5 the best fitness is 0.11430599676258166']
# ['At iteration 6 the best fitness is 0.10538267918356749']
# ['At iteration 7 the best fitness is 0.1054386953162137']
# ['At iteration 8 the best fitness is 0.10547230499580142']
# ['At iteration 9 the best fitness is 0.10555072758150609']
# ['At iteration 10 the best fitness is 0.11423877740340621']
# ['At iteration 11 the best fitness is 0.0877377021030655']
# ['At iteration 12 the best fitness is 0.10529305337133356']
# ['At iteration 13 the best fitness is 0.10533786627745052']
# ['At iteration 14 the best fitness is 0.11427238708299393']
# ['At iteration 15 the best fitness is 0.11431719998911088']
# ['At iteration 16 the best fitness is 0.0966722229086089']
# ['At iteration 17 the best fitness is 0.09653778419025802']
# ['At iteration 18 the best fitness is 0.11428359030952318']
# ['At iteration 19 the best fitness is 0.1054386953162137']
# ['At iteration 20 the best fitness is 0.08767048274389005']
# ['At iteration 21 the best fitness is 0.06984625403892022']
# ['At iteration 22 the best fitness is 0.10539388241009673']
# ['At iteration 23 the best fitness is 0.10542749208968445']
# ['At iteration 24 the best fitness is 0.09657139386984574']
# ['At iteration 25 the best fitness is 0.11432840321564014']
# ['At iteration 26 the best fitness is 0.1054386953162137']
# ['At iteration 27 the best fitness is 0.07880318129752209']
# ['At iteration 28 the best fitness is 0.1054386953162137']
# ['At iteration 29 the best fitness is 0.11431719998911088']
#       Selected: 2279/4463 (51.1%), Fitness: 0.1143, Time: 1364.5s
#       Modality: D=52%, S=50%, Sk=52%, V=51%
#     Test Acc: 89.81%, F1: 89.48%, Features: 2279/4463 (51.1%), Model: 4.992MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.1221762110478472
# At iteration 2 the best fitness is 0.11366741285041496
# At iteration 3 the best fitness is 0.1133201128280085
# At iteration 4 the best fitness is 0.10454243719387446
# At iteration 5 the best fitness is 0.08697588269907715
# At iteration 6 the best fitness is 0.08683024075419703
# At iteration 7 the best fitness is 0.08744641821330525
# At iteration 8 the best fitness is 0.09558550993527258
# At iteration 9 the best fitness is 0.08725596336230816
# At iteration 10 the best fitness is 0.10453123396734522
# At iteration 11 the best fitness is 0.09610085835561764
# At iteration 12 the best fitness is 0.09558550993527258
# At iteration 13 the best fitness is 0.09602243576991296
# At iteration 14 the best fitness is 0.0785791167669373
# At iteration 15 the best fitness is 0.08711032141742803
# At iteration 16 the best fitness is 0.09598882609032523
# At iteration 17 the best fitness is 0.09598882609032523
# At iteration 18 the best fitness is 0.07809737802617996
# At iteration 19 the best fitness is 0.11385786770141204
# At iteration 20 the best fitness is 0.08718874400313273
# At iteration 21 the best fitness is 0.09606724867602992
# At iteration 22 the best fitness is 0.10515861465298268
# At iteration 23 the best fitness is 0.11324169024230381
# At iteration 24 the best fitness is 0.08727836981536664
# At iteration 25 the best fitness is 0.10503537916116104
# At iteration 26 the best fitness is 0.09571994865362346
# At iteration 27 the best fitness is 0.09555190025568486
# At iteration 28 the best fitness is 0.0955631034822141
# At iteration 29 the best fitness is 0.08668459880931689
# At iteration 30 the best fitness is 0.10453123396734522
#       Selected: 2198/4463 (49.2%), Fitness: 0.1045, Time: 1358.3s
#       Modality: D=53%, S=51%, Sk=48%, V=49%
#     Test Acc: 92.59%, F1: 92.74%, Features: 2198/4463 (49.2%), Model: 4.834MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11358899026471027']
# ['At iteration 1 the best fitness is 0.11297281280560204']
# ['At iteration 2 the best fitness is 0.11180767724656104']
# ['At iteration 3 the best fitness is 0.11065374491404928']
# ['At iteration 4 the best fitness is 0.10161839506974271']
# ['At iteration 5 the best fitness is 0.10024039820664613']
# ['At iteration 6 the best fitness is 0.09154114515821679']
# ['At iteration 7 the best fitness is 0.09154114515821679']
# ['At iteration 8 the best fitness is 0.09154114515821679']
# ['At iteration 9 the best fitness is 0.09154114515821679']
# ['At iteration 10 the best fitness is 0.09055526122364363']
# ['At iteration 11 the best fitness is 0.08162074041810023']
# ['At iteration 12 the best fitness is 0.06306830198872977']
# ['At iteration 13 the best fitness is 0.06306830198872977']
# ['At iteration 14 the best fitness is 0.06306830198872977']
# ['At iteration 15 the best fitness is 0.06306830198872977']
# ['At iteration 16 the best fitness is 0.06306830198872977']
# ['At iteration 17 the best fitness is 0.06306830198872977']
# ['At iteration 18 the best fitness is 0.06306830198872977']
# ['At iteration 19 the best fitness is 0.06306830198872977']
# ['At iteration 20 the best fitness is 0.06306830198872977']
# ['At iteration 21 the best fitness is 0.06306830198872977']
# ['At iteration 22 the best fitness is 0.06273220519285255']
# ['At iteration 23 the best fitness is 0.06273220519285255']
# ['At iteration 24 the best fitness is 0.06273220519285255']
# ['At iteration 25 the best fitness is 0.06273220519285255']
# ['At iteration 26 the best fitness is 0.06273220519285255']
# ['At iteration 27 the best fitness is 0.06273220519285255']
# ['At iteration 28 the best fitness is 0.06273220519285255']
# ['At iteration 29 the best fitness is 0.06273220519285255']
#       Selected: 1637/4463 (36.7%), Fitness: 0.0627, Time: 1291.2s
#       Modality: D=38%, S=36%, Sk=38%, V=35%
#     Test Acc: 92.59%, F1: 92.49%, Features: 1637/4463 (36.7%), Model: 3.738MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.1046656726856961']
# ['At iteration 1 the best fitness is 0.1046656726856961']
# ['At iteration 2 the best fitness is 0.1046656726856961']
# ['At iteration 3 the best fitness is 0.1046656726856961']
# ['At iteration 4 the best fitness is 0.1046656726856961']
# ['At iteration 5 the best fitness is 0.1046656726856961']
# ['At iteration 6 the best fitness is 0.1046656726856961']
# ['At iteration 7 the best fitness is 0.1046656726856961']
# ['At iteration 8 the best fitness is 0.1046656726856961']
# ['At iteration 9 the best fitness is 0.1046656726856961']
# ['At iteration 10 the best fitness is 0.1046656726856961']
# ['At iteration 11 the best fitness is 0.1046656726856961']
# ['At iteration 12 the best fitness is 0.1046656726856961']
# ['At iteration 13 the best fitness is 0.1046656726856961']
# ['At iteration 14 the best fitness is 0.1046656726856961']
# ['At iteration 15 the best fitness is 0.1046656726856961']
# ['At iteration 16 the best fitness is 0.1046656726856961']
# ['At iteration 17 the best fitness is 0.1046656726856961']
# ['At iteration 18 the best fitness is 0.1046656726856961']
# ['At iteration 19 the best fitness is 0.1046656726856961']
# ['At iteration 20 the best fitness is 0.1046656726856961']
# ['At iteration 21 the best fitness is 0.1046656726856961']
# ['At iteration 22 the best fitness is 0.1046656726856961']
# ['At iteration 23 the best fitness is 0.1046656726856961']
# ['At iteration 24 the best fitness is 0.1046656726856961']
# ['At iteration 25 the best fitness is 0.1046656726856961']
# ['At iteration 26 the best fitness is 0.1046656726856961']
# ['At iteration 27 the best fitness is 0.1046656726856961']
# ['At iteration 28 the best fitness is 0.1046656726856961']
# ['At iteration 29 the best fitness is 0.1046656726856961']
#       Selected: 2210/4463 (49.5%), Fitness: 0.1047, Time: 1746.2s
#       Modality: D=47%, S=51%, Sk=50%, V=50%
#     Test Acc: 89.81%, F1: 89.39%, Features: 2210/4463 (49.5%), Model: 4.858MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11367861607694418']
# ['At iteration 1 the best fitness is 0.11326409669536229']
# ['At iteration 2 the best fitness is 0.11326409669536229']
# ['At iteration 3 the best fitness is 0.11326409669536229']
# ['At iteration 4 the best fitness is 0.11326409669536229']
# ['At iteration 5 the best fitness is 0.11302882893824824']
# ['At iteration 6 the best fitness is 0.11302882893824824']
# ['At iteration 7 the best fitness is 0.11302882893824824']
# ['At iteration 8 the best fitness is 0.10460965655304989']
# ['At iteration 9 the best fitness is 0.10460965655304989']
# ['At iteration 10 the best fitness is 0.10460965655304989']
# ['At iteration 11 the best fitness is 0.10460965655304989']
# ['At iteration 12 the best fitness is 0.10460965655304989']
# ['At iteration 13 the best fitness is 0.10460965655304989']
# ['At iteration 14 the best fitness is 0.0957311518801527']
# ['At iteration 15 the best fitness is 0.0957311518801527']
# ['At iteration 16 the best fitness is 0.0957311518801527']
# ['At iteration 17 the best fitness is 0.0957311518801527']
# ['At iteration 18 the best fitness is 0.0957311518801527']
# ['At iteration 19 the best fitness is 0.0957311518801527']
# ['At iteration 20 the best fitness is 0.0957311518801527']
# ['At iteration 21 the best fitness is 0.0957311518801527']
# ['At iteration 22 the best fitness is 0.0957311518801527']
# ['At iteration 23 the best fitness is 0.0957311518801527']
# ['At iteration 24 the best fitness is 0.0957311518801527']
# ['At iteration 25 the best fitness is 0.09549588412303865']
# ['At iteration 26 the best fitness is 0.09549588412303865']
# ['At iteration 27 the best fitness is 0.09549588412303865']
# ['At iteration 28 the best fitness is 0.09549588412303865']
# ['At iteration 29 the best fitness is 0.09549588412303865']
#       Selected: 2184/4463 (48.9%), Fitness: 0.0955, Time: 1406.0s
#       Modality: D=48%, S=49%, Sk=50%, V=48%
#     Test Acc: 90.74%, F1: 89.81%, Features: 2184/4463 (48.9%), Model: 4.807MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0955631034822141']
# ['At iteration 2 the best fitness is 0.0955631034822141']
# ['At iteration 3 the best fitness is 0.0955631034822141']
# ['At iteration 4 the best fitness is 0.0955631034822141']
# ['At iteration 5 the best fitness is 0.0955631034822141']
# ['At iteration 6 the best fitness is 0.0955631034822141']
# ['At iteration 7 the best fitness is 0.08780492146224095']
# ['At iteration 8 the best fitness is 0.08780492146224095']
# ['At iteration 9 the best fitness is 0.08780492146224095']
# ['At iteration 10 the best fitness is 0.08780492146224095']
# ['At iteration 11 the best fitness is 0.08780492146224095']
# ['At iteration 12 the best fitness is 0.08780492146224095']
# ['At iteration 13 the best fitness is 0.08780492146224095']
# ['At iteration 14 the best fitness is 0.08780492146224095']
# ['At iteration 15 the best fitness is 0.08780492146224095']
# ['At iteration 16 the best fitness is 0.08780492146224095']
# ['At iteration 17 the best fitness is 0.08780492146224095']
# ['At iteration 18 the best fitness is 0.08780492146224095']
# ['At iteration 19 the best fitness is 0.08780492146224095']
# ['At iteration 20 the best fitness is 0.08780492146224095']
# ['At iteration 21 the best fitness is 0.08689746011337246']
# ['At iteration 22 the best fitness is 0.08689746011337246']
# ['At iteration 23 the best fitness is 0.08689746011337246']
# ['At iteration 24 the best fitness is 0.0698686604919787']
# ['At iteration 25 the best fitness is 0.0698686604919787']
# ['At iteration 26 the best fitness is 0.0698686604919787']
# ['At iteration 27 the best fitness is 0.0698686604919787']
# ['At iteration 28 the best fitness is 0.0698686604919787']
# ['At iteration 29 the best fitness is 0.0698686604919787']
#       Selected: 2274/4463 (51.0%), Fitness: 0.0699, Time: 1328.1s
#       Modality: D=49%, S=50%, Sk=53%, V=49%
#     Test Acc: 87.96%, F1: 88.13%, Features: 2274/4463 (51.0%), Model: 4.983MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10491214366933939']
# ['At iteration 2 the best fitness is 0.10491214366933939']
# ['At iteration 3 the best fitness is 0.09577596478626967']
# ['At iteration 4 the best fitness is 0.09577596478626967']
# ['At iteration 5 the best fitness is 0.09577596478626967']
# ['At iteration 6 the best fitness is 0.09577596478626967']
# ['At iteration 7 the best fitness is 0.09577596478626967']
# ['At iteration 8 the best fitness is 0.09577596478626967']
# ['At iteration 9 the best fitness is 0.09577596478626967']
# ['At iteration 10 the best fitness is 0.09577596478626967']
# ['At iteration 11 the best fitness is 0.09577596478626967']
# ['At iteration 12 the best fitness is 0.09577596478626967']
# ['At iteration 13 the best fitness is 0.09577596478626967']
# ['At iteration 14 the best fitness is 0.09577596478626967']
# ['At iteration 15 the best fitness is 0.09577596478626967']
# ['At iteration 16 the best fitness is 0.09577596478626967']
# ['At iteration 17 the best fitness is 0.09577596478626967']
# ['At iteration 18 the best fitness is 0.09577596478626967']
# ['At iteration 19 the best fitness is 0.09577596478626967']
# ['At iteration 20 the best fitness is 0.08703189883172335']
# ['At iteration 21 the best fitness is 0.08703189883172335']
# ['At iteration 22 the best fitness is 0.08703189883172335']
# ['At iteration 23 the best fitness is 0.08703189883172335']
# ['At iteration 24 the best fitness is 0.08703189883172335']
# ['At iteration 25 the best fitness is 0.08703189883172335']
# ['At iteration 26 the best fitness is 0.08703189883172335']
# ['At iteration 27 the best fitness is 0.08695347624601868']
# ['At iteration 28 the best fitness is 0.08695347624601868']
# ['At iteration 29 the best fitness is 0.08695347624601868']
# ['At iteration 30 the best fitness is 0.08695347624601868']
#       Selected: 2214/4463 (49.6%), Fitness: 0.0870, Time: 1361.1s
#       Modality: D=53%, S=51%, Sk=48%, V=50%
#     Test Acc: 91.67%, F1: 91.28%, Features: 2214/4463 (49.6%), Model: 4.865MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.12255712074984138']
# ['At iteration 2 the best fitness is 0.11329770637495001']
# ['At iteration 3 the best fitness is 0.11329770637495001']
# ['At iteration 4 the best fitness is 0.09536144540468777']
# ['At iteration 5 the best fitness is 0.09532783572510005']
# ['At iteration 6 the best fitness is 0.09532783572510005']
# ['At iteration 7 the best fitness is 0.09530542927204157']
# ['At iteration 8 the best fitness is 0.09530542927204157']
# ['At iteration 9 the best fitness is 0.09530542927204157']
# ['At iteration 10 the best fitness is 0.09530542927204157']
# ['At iteration 11 the best fitness is 0.09530542927204157']
# ['At iteration 12 the best fitness is 0.09530542927204157']
# ['At iteration 13 the best fitness is 0.09530542927204157']
# ['At iteration 14 the best fitness is 0.09519339700674917']
# ['At iteration 15 the best fitness is 0.08634850201343969']
# ['At iteration 16 the best fitness is 0.08634850201343969']
# ['At iteration 17 the best fitness is 0.08634850201343969']
# ['At iteration 18 the best fitness is 0.08634850201343969']
# ['At iteration 19 the best fitness is 0.08620286006855957']
# ['At iteration 20 the best fitness is 0.08620286006855957']
# ['At iteration 21 the best fitness is 0.08620286006855957']
# ['At iteration 22 the best fitness is 0.08620286006855957']
# ['At iteration 23 the best fitness is 0.08620286006855957']
# ['At iteration 24 the best fitness is 0.08620286006855957']
# ['At iteration 25 the best fitness is 0.08620286006855957']
# ['At iteration 26 the best fitness is 0.07738037152830857']
# ['At iteration 27 the best fitness is 0.07738037152830857']
# ['At iteration 28 the best fitness is 0.07738037152830857']
# ['At iteration 29 the best fitness is 0.07738037152830857']
# ['At iteration 30 the best fitness is 0.07738037152830857']
#       Selected: 2152/4463 (48.2%), Fitness: 0.0774, Time: 1356.2s
#       Modality: D=51%, S=49%, Sk=47%, V=48%
#     Test Acc: 90.74%, F1: 90.31%, Features: 2152/4463 (48.2%), Model: 4.744MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1041391210388218']
# ['At iteration 1 the best fitness is 0.10225697898190941']
# ['At iteration 2 the best fitness is 0.08370454055253895']
# ['At iteration 3 the best fitness is 0.08370454055253895']
# ['At iteration 4 the best fitness is 0.08370454055253895']
# ['At iteration 5 the best fitness is 0.08370454055253895']
# ['At iteration 6 the best fitness is 0.08370454055253895']
# ['At iteration 7 the best fitness is 0.08370454055253895']
# ['At iteration 8 the best fitness is 0.08370454055253895']
# ['At iteration 9 the best fitness is 0.08370454055253895']
# ['At iteration 10 the best fitness is 0.08370454055253895']
# ['At iteration 11 the best fitness is 0.08370454055253895']
# ['At iteration 12 the best fitness is 0.08370454055253895']
# ['At iteration 13 the best fitness is 0.08370454055253895']
# ['At iteration 14 the best fitness is 0.08370454055253895']
# ['At iteration 15 the best fitness is 0.08370454055253895']
# ['At iteration 16 the best fitness is 0.08370454055253895']
# ['At iteration 17 the best fitness is 0.08370454055253895']
# ['At iteration 18 the best fitness is 0.08370454055253895']
# ['At iteration 19 the best fitness is 0.08370454055253895']
# ['At iteration 20 the best fitness is 0.08370454055253895']
# ['At iteration 21 the best fitness is 0.08370454055253895']
# ['At iteration 22 the best fitness is 0.08370454055253895']
# ['At iteration 23 the best fitness is 0.08370454055253895']
# ['At iteration 24 the best fitness is 0.08370454055253895']
# ['At iteration 25 the best fitness is 0.08370454055253895']
# ['At iteration 26 the best fitness is 0.08370454055253895']
# ['At iteration 27 the best fitness is 0.08370454055253895']
# ['At iteration 28 the best fitness is 0.08370454055253895']
# ['At iteration 29 the best fitness is 0.07836060149809126']
#       Selected: 1447/4463 (32.4%), Fitness: 0.0784, Time: 1169.0s
#       Modality: D=35%, S=33%, Sk=32%, V=32%
#     Test Acc: 88.89%, F1: 89.12%, Features: 1447/4463 (32.4%), Model: 3.367MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08728957304189588']
# ['At iteration 2 the best fitness is 0.08728957304189588']
# ['At iteration 3 the best fitness is 0.078332645783294']
# ['At iteration 4 the best fitness is 0.078332645783294']
# ['At iteration 5 the best fitness is 0.078332645783294']
# ['At iteration 6 the best fitness is 0.078332645783294']
# ['At iteration 7 the best fitness is 0.078332645783294']
# ['At iteration 8 the best fitness is 0.078332645783294']
# ['At iteration 9 the best fitness is 0.078332645783294']
# ['At iteration 10 the best fitness is 0.078332645783294']
# ['At iteration 11 the best fitness is 0.06965579918792314']
# ['At iteration 12 the best fitness is 0.06965579918792314']
# ['At iteration 13 the best fitness is 0.06965579918792314']
# ['At iteration 14 the best fitness is 0.06965579918792314']
# ['At iteration 15 the best fitness is 0.06965579918792314']
# ['At iteration 16 the best fitness is 0.06965579918792314']
# ['At iteration 17 the best fitness is 0.06965579918792314']
# ['At iteration 18 the best fitness is 0.06965579918792314']
# ['At iteration 19 the best fitness is 0.06965579918792314']
# ['At iteration 20 the best fitness is 0.06965579918792314']
# ['At iteration 21 the best fitness is 0.06965579918792314']
# ['At iteration 22 the best fitness is 0.06965579918792314']
# ['At iteration 23 the best fitness is 0.060777294515025934']
# ['At iteration 24 the best fitness is 0.060777294515025934']
# ['At iteration 25 the best fitness is 0.060777294515025934']
# ['At iteration 26 the best fitness is 0.060777294515025934']
# ['At iteration 27 the best fitness is 0.060777294515025934']
# ['At iteration 28 the best fitness is 0.060777294515025934']
# ['At iteration 29 the best fitness is 0.060777294515025934']
#       Selected: 2255/4463 (50.5%), Fitness: 0.0608, Time: 3399.6s
#       Modality: D=49%, S=50%, Sk=51%, V=50%
#     Test Acc: 90.74%, F1: 90.81%, Features: 2255/4463 (50.5%), Model: 4.945MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08717754077660347']
# ['At iteration 1 the best fitness is 0.08717754077660347']
# ['At iteration 2 the best fitness is 0.08717754077660347']
# ['At iteration 3 the best fitness is 0.08717754077660347']
# ['At iteration 4 the best fitness is 0.08717754077660347']
# ['At iteration 5 the best fitness is 0.08717754077660347']
# ['At iteration 6 the best fitness is 0.08717754077660347']
# ['At iteration 7 the best fitness is 0.08717754077660347']
# ['At iteration 8 the best fitness is 0.08717754077660347']
# ['At iteration 9 the best fitness is 0.08717754077660347']
# ['At iteration 10 the best fitness is 0.08717754077660347']
# ['At iteration 11 the best fitness is 0.08717754077660347']
# ['At iteration 12 the best fitness is 0.08717754077660347']
# ['At iteration 13 the best fitness is 0.08717754077660347']
# ['At iteration 14 the best fitness is 0.08717754077660347']
# ['At iteration 15 the best fitness is 0.08717754077660347']
# ['At iteration 16 the best fitness is 0.08717754077660347']
# ['At iteration 17 the best fitness is 0.08717754077660347']
# ['At iteration 18 the best fitness is 0.08717754077660347']
# ['At iteration 19 the best fitness is 0.08717754077660347']
# ['At iteration 20 the best fitness is 0.08717754077660347']
# ['At iteration 21 the best fitness is 0.08717754077660347']
# ['At iteration 22 the best fitness is 0.08717754077660347']
# ['At iteration 23 the best fitness is 0.08717754077660347']
# ['At iteration 24 the best fitness is 0.08717754077660347']
# ['At iteration 25 the best fitness is 0.08717754077660347']
# ['At iteration 26 the best fitness is 0.08717754077660347']
# ['At iteration 27 the best fitness is 0.08717754077660347']
# ['At iteration 28 the best fitness is 0.08717754077660347']
# ['At iteration 29 the best fitness is 0.08717754077660347']
#       Selected: 2234/4463 (50.1%), Fitness: 0.0872, Time: 1259.4s
#       Modality: D=49%, S=51%, Sk=51%, V=49%
#     Test Acc: 94.44%, F1: 94.13%, Features: 2234/4463 (50.1%), Model: 4.904MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 85.19%, F1: 84.29%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 60.4s
#     Test Acc: 87.96%, F1: 86.24%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.2s
#     Test Acc: 87.04%, F1: 85.58%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 4.3s
#     Test Acc: 56.48%, F1: 55.39%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06940932820427985']
# ['At iteration 1 the best fitness is 0.06940932820427985']
# ['At iteration 2 the best fitness is 0.06940932820427985']
# ['At iteration 3 the best fitness is 0.06940932820427985']
# ['At iteration 4 the best fitness is 0.06940932820427985']
# ['At iteration 5 the best fitness is 0.06940932820427985']
# ['At iteration 6 the best fitness is 0.06940932820427985']
# ['At iteration 7 the best fitness is 0.06940932820427985']
# ['At iteration 8 the best fitness is 0.06940932820427985']
# ['At iteration 9 the best fitness is 0.06940932820427985']
# ['At iteration 10 the best fitness is 0.06940932820427985']
# ['At iteration 11 the best fitness is 0.06940932820427985']
# ['At iteration 12 the best fitness is 0.06940932820427985']
# ['At iteration 13 the best fitness is 0.06940932820427985']
# ['At iteration 14 the best fitness is 0.06940932820427985']
# ['At iteration 15 the best fitness is 0.06940932820427985']
# ['At iteration 16 the best fitness is 0.06940932820427985']
# ['At iteration 17 the best fitness is 0.06939812497775061']
# ['At iteration 18 the best fitness is 0.06939812497775061']
# ['At iteration 19 the best fitness is 0.06939812497775061']
# ['At iteration 20 the best fitness is 0.06939812497775061']
# ['At iteration 21 the best fitness is 0.06939812497775061']
# ['At iteration 22 the best fitness is 0.06926368625939971']
# ['At iteration 23 the best fitness is 0.06926368625939971']
# ['At iteration 24 the best fitness is 0.06926368625939971']
# ['At iteration 25 the best fitness is 0.06926368625939971']
# ['At iteration 26 the best fitness is 0.06926368625939971']
# ['At iteration 27 the best fitness is 0.06926368625939971']
# ['At iteration 28 the best fitness is 0.06926368625939971']
# ['At iteration 29 the best fitness is 0.06926368625939971']
#       Selected: 2220/4463 (49.7%), Fitness: 0.0693, Time: 1412.4s
#       Modality: D=48%, S=51%, Sk=50%, V=49%
#     Test Acc: 86.11%, F1: 84.38%, Features: 2220/4463 (49.7%), Model: 4.877MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06989106694503719']
# ['At iteration 1 the best fitness is 0.06989106694503719']
# ['At iteration 2 the best fitness is 0.06989106694503719']
# ['At iteration 3 the best fitness is 0.06989106694503719']
# ['At iteration 4 the best fitness is 0.06989106694503719']
# ['At iteration 5 the best fitness is 0.06989106694503719']
# ['At iteration 6 the best fitness is 0.06989106694503719']
# ['At iteration 7 the best fitness is 0.06989106694503719']
# ['At iteration 8 the best fitness is 0.06989106694503719']
# ['At iteration 9 the best fitness is 0.06989106694503719']
# ['At iteration 10 the best fitness is 0.06989106694503719']
# ['At iteration 11 the best fitness is 0.06989106694503719']
# ['At iteration 12 the best fitness is 0.06989106694503719']
# ['At iteration 13 the best fitness is 0.06989106694503719']
# ['At iteration 14 the best fitness is 0.06989106694503719']
# ['At iteration 15 the best fitness is 0.06989106694503719']
# ['At iteration 16 the best fitness is 0.06989106694503719']
# ['At iteration 17 the best fitness is 0.06989106694503719']
# ['At iteration 18 the best fitness is 0.06989106694503719']
# ['At iteration 19 the best fitness is 0.06989106694503719']
# ['At iteration 20 the best fitness is 0.06989106694503719']
# ['At iteration 21 the best fitness is 0.06989106694503719']
# ['At iteration 22 the best fitness is 0.06989106694503719']
# ['At iteration 23 the best fitness is 0.06989106694503719']
# ['At iteration 24 the best fitness is 0.06989106694503719']
# ['At iteration 25 the best fitness is 0.06989106694503719']
# ['At iteration 26 the best fitness is 0.069510157243043']
# ['At iteration 27 the best fitness is 0.069510157243043']
# ['At iteration 28 the best fitness is 0.069510157243043']
# ['At iteration 29 the best fitness is 0.069510157243043']
#       Selected: 2242/4463 (50.2%), Fitness: 0.0695, Time: 2774.1s
#       Modality: D=48%, S=49%, Sk=53%, V=48%
#     Test Acc: 84.26%, F1: 82.23%, Features: 2242/4463 (50.2%), Model: 4.920MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0873231827214836']
# ['At iteration 2 the best fitness is 0.0863260955603812']
# ['At iteration 3 the best fitness is 0.0863260955603812']
# ['At iteration 4 the best fitness is 0.0863260955603812']
# ['At iteration 5 the best fitness is 0.07771646832418577']
# ['At iteration 6 the best fitness is 0.07771646832418577']
# ['At iteration 7 the best fitness is 0.07771646832418577']
# ['At iteration 8 the best fitness is 0.0775036070201302']
# ['At iteration 9 the best fitness is 0.0775036070201302']
# ['At iteration 10 the best fitness is 0.0775036070201302']
# ['At iteration 11 the best fitness is 0.0775036070201302']
# ['At iteration 12 the best fitness is 0.0775036070201302']
# ['At iteration 13 the best fitness is 0.0775036070201302']
# ['At iteration 14 the best fitness is 0.0775036070201302']
# ['At iteration 15 the best fitness is 0.0775036070201302']
# ['At iteration 16 the best fitness is 0.0775036070201302']
# ['At iteration 17 the best fitness is 0.0775036070201302']
# ['At iteration 18 the best fitness is 0.0775036070201302']
# ['At iteration 19 the best fitness is 0.0775036070201302']
# ['At iteration 20 the best fitness is 0.06966700241445238']
# ['At iteration 21 the best fitness is 0.06966700241445238']
# ['At iteration 22 the best fitness is 0.06966700241445238']
# ['At iteration 23 the best fitness is 0.06966700241445238']
# ['At iteration 24 the best fitness is 0.06966700241445238']
# ['At iteration 25 the best fitness is 0.06966700241445238']
# ['At iteration 26 the best fitness is 0.06966700241445238']
# ['At iteration 27 the best fitness is 0.06966700241445238']
# ['At iteration 28 the best fitness is 0.06966700241445238']
# ['At iteration 29 the best fitness is 0.06966700241445238']
# ['At iteration 30 the best fitness is 0.06966700241445238']
#       Selected: 2256/4463 (50.5%), Fitness: 0.0697, Time: 1403.0s
#       Modality: D=51%, S=51%, Sk=52%, V=49%
#     Test Acc: 88.89%, F1: 88.47%, Features: 2256/4463 (50.5%), Model: 4.947MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10518102110604116']
# ['At iteration 1 the best fitness is 0.09587679382503284']
# ['At iteration 2 the best fitness is 0.08668459880931689']
# ['At iteration 3 the best fitness is 0.10450882751428674']
# ['At iteration 4 the best fitness is 0.07788451672212439']
# ['At iteration 5 the best fitness is 0.08656136331749525']
# ['At iteration 6 the best fitness is 0.08659497299708298']
# ['At iteration 7 the best fitness is 0.08666219235625841']
# ['At iteration 8 the best fitness is 0.08684144398072627']
# ['At iteration 9 the best fitness is 0.08655016009096601']
# ['At iteration 10 the best fitness is 0.09538385185774625']
# ['At iteration 11 the best fitness is 0.09541746153733398']
# ['At iteration 12 the best fitness is 0.08633729878691045']
# ['At iteration 13 the best fitness is 0.09531663249857081']
# ['At iteration 14 the best fitness is 0.07739157475483781']
# ['At iteration 15 the best fitness is 0.08635970523996893']
# ['At iteration 16 the best fitness is 0.07745879411401324']
# ['At iteration 17 the best fitness is 0.08640451814608589']
# ['At iteration 18 the best fitness is 0.08631489233385196']
# ['At iteration 19 the best fitness is 0.08630368910732272']
# ['At iteration 20 the best fitness is 0.09521580345980765']
# ['At iteration 21 the best fitness is 0.09523820991286613']
# ['At iteration 22 the best fitness is 0.08633729878691045']
# ['At iteration 23 the best fitness is 0.0774699973405425']
# ['At iteration 24 the best fitness is 0.08635970523996893']
# ['At iteration 25 the best fitness is 0.09523820991286613']
# ['At iteration 26 the best fitness is 0.09523820991286613']
# ['At iteration 27 the best fitness is 0.09523820991286613']
# ['At iteration 28 the best fitness is 0.08635970523996893']
# ['At iteration 29 the best fitness is 0.08634850201343969']
#       Selected: 2160/4463 (48.4%), Fitness: 0.0863, Time: 1353.7s
#       Modality: D=47%, S=46%, Sk=49%, V=50%
#     Test Acc: 87.96%, F1: 86.53%, Features: 2160/4463 (48.4%), Model: 4.760MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.11376824188917811
# At iteration 2 the best fitness is 0.09606724867602992
# At iteration 3 the best fitness is 0.08688625688684323
# At iteration 4 the best fitness is 0.07800775221394603
# At iteration 5 the best fitness is 0.07846708450164488
# At iteration 6 the best fitness is 0.08681903752766779
# At iteration 7 the best fitness is 0.09565272929444803
# At iteration 8 the best fitness is 0.08783853114182866
# At iteration 9 the best fitness is 0.08746882466636373
# At iteration 10 the best fitness is 0.07848949095470337
# At iteration 11 the best fitness is 0.07804136189353375
# At iteration 12 the best fitness is 0.10467687591222534
# At iteration 13 the best fitness is 0.08623646974814728
# At iteration 14 the best fitness is 0.08637090846649817
# At iteration 15 the best fitness is 0.08637090846649817
# At iteration 16 the best fitness is 0.051103360758552666
# At iteration 17 the best fitness is 0.09511497442104448
# At iteration 18 the best fitness is 0.08652775363790753
# At iteration 19 the best fitness is 0.07816459738535539
# At iteration 20 the best fitness is 0.09612326480867613
# At iteration 21 the best fitness is 0.08665098912972918
# At iteration 22 the best fitness is 0.08681903752766779
# At iteration 23 the best fitness is 0.07782850058947818
# At iteration 24 the best fitness is 0.07806376834659223
# At iteration 25 the best fitness is 0.09540625831080474
# At iteration 26 the best fitness is 0.0869310697929602
# At iteration 27 the best fitness is 0.07819820706494311
# At iteration 28 the best fitness is 0.07823181674453084
# At iteration 29 the best fitness is 0.07792932962824134
# At iteration 30 the best fitness is 0.09568633897403575
#       Selected: 2201/4463 (49.3%), Fitness: 0.0957, Time: 1360.8s
#       Modality: D=50%, S=52%, Sk=49%, V=48%
#     Test Acc: 86.11%, F1: 84.42%, Features: 2201/4463 (49.3%), Model: 4.840MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10468807913875458']
# ['At iteration 1 the best fitness is 0.09524941313939536']
# ['At iteration 2 the best fitness is 0.09524941313939536']
# ['At iteration 3 the best fitness is 0.06681017964949607']
# ['At iteration 4 the best fitness is 0.06681017964949607']
# ['At iteration 5 the best fitness is 0.06681017964949607']
# ['At iteration 6 the best fitness is 0.06681017964949607']
# ['At iteration 7 the best fitness is 0.06681017964949607']
# ['At iteration 8 the best fitness is 0.06681017964949607']
# ['At iteration 9 the best fitness is 0.06681017964949607']
# ['At iteration 10 the best fitness is 0.06681017964949607']
# ['At iteration 11 the best fitness is 0.06681017964949607']
# ['At iteration 12 the best fitness is 0.05572463935033851']
# ['At iteration 13 the best fitness is 0.05572463935033851']
# ['At iteration 14 the best fitness is 0.05572463935033851']
# ['At iteration 15 the best fitness is 0.05572463935033851']
# ['At iteration 16 the best fitness is 0.05572463935033851']
# ['At iteration 17 the best fitness is 0.05572463935033851']
# ['At iteration 18 the best fitness is 0.05572463935033851']
# ['At iteration 19 the best fitness is 0.05572463935033851']
# ['At iteration 20 the best fitness is 0.05572463935033851']
# ['At iteration 21 the best fitness is 0.05572463935033851']
# ['At iteration 22 the best fitness is 0.05572463935033851']
# ['At iteration 23 the best fitness is 0.05572463935033851']
# ['At iteration 24 the best fitness is 0.05572463935033851']
# ['At iteration 25 the best fitness is 0.05572463935033851']
# ['At iteration 26 the best fitness is 0.05572463935033851']
# ['At iteration 27 the best fitness is 0.05572463935033851']
# ['At iteration 28 the best fitness is 0.05572463935033851']
# ['At iteration 29 the best fitness is 0.05572463935033851']
#       Selected: 1804/4463 (40.4%), Fitness: 0.0557, Time: 1298.4s
#       Modality: D=40%, S=43%, Sk=40%, V=40%
#     Test Acc: 90.74%, F1: 90.30%, Features: 1804/4463 (40.4%), Model: 4.065MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.0963361261127317']
# ['At iteration 1 the best fitness is 0.09448759373540702']
# ['At iteration 2 the best fitness is 0.09448759373540702']
# ['At iteration 3 the best fitness is 0.09448759373540702']
# ['At iteration 4 the best fitness is 0.09448759373540702']
# ['At iteration 5 the best fitness is 0.09448759373540702']
# ['At iteration 6 the best fitness is 0.09448759373540702']
# ['At iteration 7 the best fitness is 0.09448759373540702']
# ['At iteration 8 the best fitness is 0.09448759373540702']
# ['At iteration 9 the best fitness is 0.08594518585838704']
# ['At iteration 10 the best fitness is 0.08594518585838704']
# ['At iteration 11 the best fitness is 0.08594518585838704']
# ['At iteration 12 the best fitness is 0.08594518585838704']
# ['At iteration 13 the best fitness is 0.08594518585838704']
# ['At iteration 14 the best fitness is 0.08594518585838704']
# ['At iteration 15 the best fitness is 0.08594518585838704']
# ['At iteration 16 the best fitness is 0.08594518585838704']
# ['At iteration 17 the best fitness is 0.08594518585838704']
# ['At iteration 18 the best fitness is 0.08594518585838704']
# ['At iteration 19 the best fitness is 0.08594518585838704']
# ['At iteration 20 the best fitness is 0.08594518585838704']
# ['At iteration 21 the best fitness is 0.07612561015703365']
# ['At iteration 22 the best fitness is 0.07612561015703365']
# ['At iteration 23 the best fitness is 0.07612561015703365']
# ['At iteration 24 the best fitness is 0.07612561015703365']
# ['At iteration 25 the best fitness is 0.07612561015703365']
# ['At iteration 26 the best fitness is 0.07612561015703365']
# ['At iteration 27 the best fitness is 0.07612561015703365']
# ['At iteration 28 the best fitness is 0.07612561015703365']
# ['At iteration 29 the best fitness is 0.07612561015703365']
#       Selected: 2040/4463 (45.7%), Fitness: 0.0761, Time: 1755.2s
#       Modality: D=46%, S=46%, Sk=45%, V=47%
#     Test Acc: 89.81%, F1: 89.08%, Features: 2040/4463 (45.7%), Model: 4.526MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0701711476082682']
# ['At iteration 1 the best fitness is 0.0701711476082682']
# ['At iteration 2 the best fitness is 0.0701711476082682']
# ['At iteration 3 the best fitness is 0.0701711476082682']
# ['At iteration 4 the best fitness is 0.0701711476082682']
# ['At iteration 5 the best fitness is 0.0701711476082682']
# ['At iteration 6 the best fitness is 0.0701711476082682']
# ['At iteration 7 the best fitness is 0.0701711476082682']
# ['At iteration 8 the best fitness is 0.0701711476082682']
# ['At iteration 9 the best fitness is 0.0701711476082682']
# ['At iteration 10 the best fitness is 0.0701711476082682']
# ['At iteration 11 the best fitness is 0.0701711476082682']
# ['At iteration 12 the best fitness is 0.0701711476082682']
# ['At iteration 13 the best fitness is 0.0701711476082682']
# ['At iteration 14 the best fitness is 0.0701711476082682']
# ['At iteration 15 the best fitness is 0.0701711476082682']
# ['At iteration 16 the best fitness is 0.0701711476082682']
# ['At iteration 17 the best fitness is 0.0701711476082682']
# ['At iteration 18 the best fitness is 0.0701711476082682']
# ['At iteration 19 the best fitness is 0.0701711476082682']
# ['At iteration 20 the best fitness is 0.0701711476082682']
# ['At iteration 21 the best fitness is 0.0701711476082682']
# ['At iteration 22 the best fitness is 0.0701711476082682']
# ['At iteration 23 the best fitness is 0.0701711476082682']
# ['At iteration 24 the best fitness is 0.0701711476082682']
# ['At iteration 25 the best fitness is 0.0701711476082682']
# ['At iteration 26 the best fitness is 0.0701711476082682']
# ['At iteration 27 the best fitness is 0.0701711476082682']
# ['At iteration 28 the best fitness is 0.0701711476082682']
# ...
# ['At iteration 15 the best fitness is 0.09952339170877475']
# ['At iteration 16 the best fitness is 0.09952339170877475']
# ['At iteration 17 the best fitness is 0.09354652270695082']
# ['At iteration 18 the best fitness is 0.09354652270695082']
# ['At iteration 19 the best fitness is 0.09354652270695082']
# ['At iteration 20 the best fitness is 0.09354652270695082']
# ['At iteration 21 the best fitness is 0.09354652270695082']
# ['At iteration 22 the best fitness is 0.09354652270695082']
# ['At iteration 23 the best fitness is 0.09354652270695082']
# ['At iteration 24 the best fitness is 0.09354652270695082']
# ['At iteration 25 the best fitness is 0.09354652270695082']
# ['At iteration 26 the best fitness is 0.09354652270695082']
# ['At iteration 27 the best fitness is 0.09354652270695082']
# ['At iteration 28 the best fitness is 0.09354652270695082']
# ['At iteration 29 the best fitness is 0.09354652270695082']
#       Selected: 2010/4463 (45.0%), Fitness: 0.0935, Time: 1733.7s
#       Modality: D=48%, S=42%, Sk=46%, V=44%
#     Test Acc: 93.46%, F1: 92.55%, Features: 2010/4463 (45.0%), Model: 4.467MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10411671458576333']
# ['At iteration 1 the best fitness is 0.10411671458576333']
# ['At iteration 2 the best fitness is 0.10411671458576333']
# ['At iteration 3 the best fitness is 0.10411671458576333']
# ['At iteration 4 the best fitness is 0.10411671458576333']
# ['At iteration 5 the best fitness is 0.10411671458576333']
# ['At iteration 6 the best fitness is 0.10411671458576333']
# ['At iteration 7 the best fitness is 0.0957871680127989']
# ['At iteration 8 the best fitness is 0.0957871680127989']
# ['At iteration 9 the best fitness is 0.09557430670874334']
# ['At iteration 10 the best fitness is 0.09557430670874334']
# ['At iteration 11 the best fitness is 0.09557430670874334']
# ['At iteration 12 the best fitness is 0.09557430670874334']
# ['At iteration 13 the best fitness is 0.09557430670874334']
# ['At iteration 14 the best fitness is 0.09557430670874334']
# ['At iteration 15 the best fitness is 0.09557430670874334']
# ['At iteration 16 the best fitness is 0.09557430670874334']
# ['At iteration 17 the best fitness is 0.08683024075419703']
# ['At iteration 18 the best fitness is 0.08683024075419703']
# ['At iteration 19 the best fitness is 0.08683024075419703']
# ['At iteration 20 the best fitness is 0.08683024075419703']
# ['At iteration 21 the best fitness is 0.08683024075419703']
# ['At iteration 22 the best fitness is 0.08683024075419703']
# ['At iteration 23 the best fitness is 0.08683024075419703']
# ['At iteration 24 the best fitness is 0.08683024075419703']
# ['At iteration 25 the best fitness is 0.08683024075419703']
# ['At iteration 26 the best fitness is 0.08683024075419703']
# ['At iteration 27 the best fitness is 0.08683024075419703']
# ['At iteration 28 the best fitness is 0.08683024075419703']
# ['At iteration 29 the best fitness is 0.07826542642411856']
#       Selected: 2231/4463 (50.0%), Fitness: 0.0783, Time: 1406.4s
#       Modality: D=49%, S=48%, Sk=51%, V=50%
#     Test Acc: 93.46%, F1: 92.79%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1140147128728214']
# ['At iteration 2 the best fitness is 0.1140147128728214']
# ['At iteration 3 the best fitness is 0.1140147128728214']
# ['At iteration 4 the best fitness is 0.09640334547190713']
# ['At iteration 5 the best fitness is 0.09640334547190713']
# ['At iteration 6 the best fitness is 0.09640334547190713']
# ['At iteration 7 the best fitness is 0.09640334547190713']
# ['At iteration 8 the best fitness is 0.09640334547190713']
# ['At iteration 9 the best fitness is 0.09640334547190713']
# ['At iteration 10 the best fitness is 0.09640334547190713']
# ['At iteration 11 the best fitness is 0.09640334547190713']
# ['At iteration 12 the best fitness is 0.09640334547190713']
# ['At iteration 13 the best fitness is 0.09640334547190713']
# ['At iteration 14 the best fitness is 0.09640334547190713']
# ['At iteration 15 the best fitness is 0.09640334547190713']
# ['At iteration 16 the best fitness is 0.09640334547190713']
# ['At iteration 17 the best fitness is 0.09640334547190713']
# ['At iteration 18 the best fitness is 0.09640334547190713']
# ['At iteration 19 the best fitness is 0.09640334547190713']
# ['At iteration 20 the best fitness is 0.09640334547190713']
# ['At iteration 21 the best fitness is 0.09640334547190713']
# ['At iteration 22 the best fitness is 0.09640334547190713']
# ['At iteration 23 the best fitness is 0.09622409384743928']
# ['At iteration 24 the best fitness is 0.09622409384743928']
# ['At iteration 25 the best fitness is 0.09622409384743928']
# ['At iteration 26 the best fitness is 0.09622409384743928']
# ['At iteration 27 the best fitness is 0.09613446803520537']
# ['At iteration 28 the best fitness is 0.09613446803520537']
# ['At iteration 29 the best fitness is 0.09613446803520537']
#       Selected: 2241/4463 (50.2%), Fitness: 0.0961, Time: 1329.7s
#       Modality: D=53%, S=51%, Sk=50%, V=49%
#     Test Acc: 94.39%, F1: 92.97%, Features: 2241/4463 (50.2%), Model: 4.918MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1140147128728214']
# ['At iteration 2 the best fitness is 0.1140147128728214']
# ['At iteration 3 the best fitness is 0.11380185156876584']
# ['At iteration 4 the best fitness is 0.11380185156876584']
# ['At iteration 5 the best fitness is 0.11380185156876584']
# ['At iteration 6 the best fitness is 0.11380185156876584']
# ['At iteration 7 the best fitness is 0.10506898884074875']
# ['At iteration 8 the best fitness is 0.10506898884074875']
# ['At iteration 9 the best fitness is 0.10506898884074875']
# ['At iteration 10 the best fitness is 0.10506898884074875']
# ['At iteration 11 the best fitness is 0.10506898884074875']
# ['At iteration 12 the best fitness is 0.10506898884074875']
# ['At iteration 13 the best fitness is 0.10506898884074875']
# ['At iteration 14 the best fitness is 0.10506898884074875']
# ['At iteration 15 the best fitness is 0.09607845190255916']
# ['At iteration 16 the best fitness is 0.09607845190255916']
# ['At iteration 17 the best fitness is 0.09607845190255916']
# ['At iteration 18 the best fitness is 0.09607845190255916']
# ['At iteration 19 the best fitness is 0.09607845190255916']
# ['At iteration 20 the best fitness is 0.09607845190255916']
# ['At iteration 21 the best fitness is 0.09607845190255916']
# ['At iteration 22 the best fitness is 0.09607845190255916']
# ['At iteration 23 the best fitness is 0.09607845190255916']
# ['At iteration 24 the best fitness is 0.09607845190255916']
# ['At iteration 25 the best fitness is 0.09607845190255916']
# ['At iteration 26 the best fitness is 0.09607845190255916']
# ['At iteration 27 the best fitness is 0.09607845190255916']
# ['At iteration 28 the best fitness is 0.09607845190255916']
# ['At iteration 29 the best fitness is 0.09607845190255916']
# ['At iteration 30 the best fitness is 0.09607845190255916']
#       Selected: 2236/4463 (50.1%), Fitness: 0.0961, Time: 1365.5s
#       Modality: D=51%, S=51%, Sk=50%, V=49%
#     Test Acc: 93.46%, F1: 92.81%, Features: 2236/4463 (50.1%), Model: 4.908MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.11346575477288862']
# ['At iteration 2 the best fitness is 0.08683024075419703']
# ['At iteration 3 the best fitness is 0.08683024075419703']
# ['At iteration 4 the best fitness is 0.08683024075419703']
# ['At iteration 5 the best fitness is 0.08683024075419703']
# ['At iteration 6 the best fitness is 0.08683024075419703']
# ['At iteration 7 the best fitness is 0.08683024075419703']
# ['At iteration 8 the best fitness is 0.08683024075419703']
# ['At iteration 9 the best fitness is 0.08683024075419703']
# ['At iteration 10 the best fitness is 0.08683024075419703']
# ['At iteration 11 the best fitness is 0.08677422462155082']
# ['At iteration 12 the best fitness is 0.08674061494196311']
# ['At iteration 13 the best fitness is 0.08674061494196311']
# ['At iteration 14 the best fitness is 0.08667339558278767']
# ['At iteration 15 the best fitness is 0.08667339558278767']
# ['At iteration 16 the best fitness is 0.08667339558278767']
# ['At iteration 17 the best fitness is 0.08667339558278767']
# ['At iteration 18 the best fitness is 0.06877074429211315']
# ['At iteration 19 the best fitness is 0.06877074429211315']
# ['At iteration 20 the best fitness is 0.06877074429211315']
# ['At iteration 21 the best fitness is 0.06877074429211315']
# ['At iteration 22 the best fitness is 0.06877074429211315']
# ['At iteration 23 the best fitness is 0.06877074429211315']
# ['At iteration 24 the best fitness is 0.06877074429211315']
# ['At iteration 25 the best fitness is 0.06877074429211315']
# ['At iteration 26 the best fitness is 0.06877074429211315']
# ['At iteration 27 the best fitness is 0.06877074429211315']
# ['At iteration 28 the best fitness is 0.06877074429211315']
# ['At iteration 29 the best fitness is 0.06877074429211315']
# ['At iteration 30 the best fitness is 0.06877074429211315']
#       Selected: 2176/4463 (48.8%), Fitness: 0.0688, Time: 1354.6s
#       Modality: D=52%, S=48%, Sk=48%, V=48%
#     Test Acc: 88.79%, F1: 86.84%, Features: 2176/4463 (48.8%), Model: 4.791MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10499056625504408']
# ['At iteration 1 the best fitness is 0.10299639193283927']
# ['At iteration 2 the best fitness is 0.10299639193283927']
# ['At iteration 3 the best fitness is 0.10010595948829525']
# ['At iteration 4 the best fitness is 0.10010595948829525']
# ['At iteration 5 the best fitness is 0.10010595948829525']
# ['At iteration 6 the best fitness is 0.10010595948829525']
# ['At iteration 7 the best fitness is 0.10010595948829525']
# ['At iteration 8 the best fitness is 0.09537819789295579']
# ['At iteration 9 the best fitness is 0.09537819789295579']
# ['At iteration 10 the best fitness is 0.0915018815138386']
# ['At iteration 11 the best fitness is 0.0915018815138386']
# ['At iteration 12 the best fitness is 0.08219765423283028']
# ['At iteration 13 the best fitness is 0.08219765423283028']
# ['At iteration 14 the best fitness is 0.08219765423283028']
# ['At iteration 15 the best fitness is 0.07105609780102651']
# ['At iteration 16 the best fitness is 0.07105609780102651']
# ['At iteration 17 the best fitness is 0.07105609780102651']
# ['At iteration 18 the best fitness is 0.07105609780102651']
# ['At iteration 19 the best fitness is 0.07105609780102651']
# ['At iteration 20 the best fitness is 0.07105609780102651']
# ['At iteration 21 the best fitness is 0.07105609780102651']
# ['At iteration 22 the best fitness is 0.07105609780102651']
# ['At iteration 23 the best fitness is 0.07031668485009665']
# ['At iteration 24 the best fitness is 0.07031668485009665']
# ['At iteration 25 the best fitness is 0.07031668485009665']
# ['At iteration 26 the best fitness is 0.07031668485009665']
# ['At iteration 27 the best fitness is 0.07031668485009665']
# ['At iteration 28 the best fitness is 0.07031668485009665']
# ['At iteration 29 the best fitness is 0.07031668485009665']
#       Selected: 729/4463 (16.3%), Fitness: 0.0703, Time: 1151.8s
#       Modality: D=14%, S=18%, Sk=16%, V=16%
#     Test Acc: 89.72%, F1: 88.59%, Features: 729/4463 (16.3%), Model: 1.965MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09563032284138955']
# ['At iteration 2 the best fitness is 0.08689746011337246']
# ['At iteration 3 the best fitness is 0.08689746011337246']
# ['At iteration 4 the best fitness is 0.08629248588079348']
# ['At iteration 5 the best fitness is 0.08629248588079348']
# ['At iteration 6 the best fitness is 0.08629248588079348']
# ['At iteration 7 the best fitness is 0.08629248588079348']
# ['At iteration 8 the best fitness is 0.08629248588079348']
# ['At iteration 9 the best fitness is 0.08629248588079348']
# ['At iteration 10 the best fitness is 0.08629248588079348']
# ['At iteration 11 the best fitness is 0.08629248588079348']
# ['At iteration 12 the best fitness is 0.08629248588079348']
# ['At iteration 13 the best fitness is 0.08629248588079348']
# ['At iteration 14 the best fitness is 0.08629248588079348']
# ['At iteration 15 the best fitness is 0.08629248588079348']
# ['At iteration 16 the best fitness is 0.08629248588079348']
# ['At iteration 17 the best fitness is 0.08629248588079348']
# ['At iteration 18 the best fitness is 0.08629248588079348']
# ['At iteration 19 the best fitness is 0.08629248588079348']
# ['At iteration 20 the best fitness is 0.08629248588079348']
# ['At iteration 21 the best fitness is 0.08629248588079348']
# ['At iteration 22 the best fitness is 0.08629248588079348']
# ['At iteration 23 the best fitness is 0.08629248588079348']
# ['At iteration 24 the best fitness is 0.08629248588079348']
# ['At iteration 25 the best fitness is 0.08629248588079348']
# ['At iteration 26 the best fitness is 0.08629248588079348']
# ['At iteration 27 the best fitness is 0.08629248588079348']
# ['At iteration 28 the best fitness is 0.08629248588079348']
# ['At iteration 29 the best fitness is 0.08629248588079348']
#       Selected: 2155/4463 (48.3%), Fitness: 0.0863, Time: 3408.2s
#       Modality: D=50%, S=48%, Sk=49%, V=46%
#     Test Acc: 94.39%, F1: 93.65%, Features: 2155/4463 (48.3%), Model: 4.750MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.12287081109266011']
# ['At iteration 1 the best fitness is 0.07054074938068144']
# ['At iteration 2 the best fitness is 0.07054074938068144']
# ['At iteration 3 the best fitness is 0.07054074938068144']
# ['At iteration 4 the best fitness is 0.07054074938068144']
# ['At iteration 5 the best fitness is 0.07040631066233057']
# ['At iteration 6 the best fitness is 0.061527805989433366']
# ['At iteration 7 the best fitness is 0.04556331288831744']
# ['At iteration 8 the best fitness is 0.04556331288831744']
# ['At iteration 9 the best fitness is 0.04556331288831744']
# ['At iteration 10 the best fitness is 0.04556331288831744']
# ['At iteration 11 the best fitness is 0.04556331288831744']
# ['At iteration 12 the best fitness is 0.04556331288831744']
# ['At iteration 13 the best fitness is 0.04556331288831744']
# ['At iteration 14 the best fitness is 0.04556331288831744']
# ['At iteration 15 the best fitness is 0.04556331288831744']
# ['At iteration 16 the best fitness is 0.04556331288831744']
# ['At iteration 17 the best fitness is 0.04556331288831744']
# ['At iteration 18 the best fitness is 0.04556331288831744']
# ['At iteration 19 the best fitness is 0.04556331288831744']
# ['At iteration 20 the best fitness is 0.04556331288831744']
# ['At iteration 21 the best fitness is 0.04556331288831744']
# ['At iteration 22 the best fitness is 0.04556331288831744']
# ['At iteration 23 the best fitness is 0.04556331288831744']
# ['At iteration 24 the best fitness is 0.04556331288831744']
# ['At iteration 25 the best fitness is 0.04556331288831744']
# ['At iteration 26 the best fitness is 0.04556331288831744']
# ['At iteration 27 the best fitness is 0.04556331288831744']
# ['At iteration 28 the best fitness is 0.04556331288831744']
# ['At iteration 29 the best fitness is 0.04556331288831744']
#       Selected: 897/4463 (20.1%), Fitness: 0.0456, Time: 1137.3s
#       Modality: D=17%, S=18%, Sk=20%, V=21%
#     Test Acc: 88.79%, F1: 86.29%, Features: 897/4463 (20.1%), Model: 2.293MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          93.518519         91.588785     93.522527
# 1  baseline     2          85.185185         94.392523     84.292662
# 2  baseline     3          86.111111         90.654206     84.066386
# 3  baseline     4          90.740741         91.588785     89.854097
# 4  baseline     5          88.888889         91.588785     87.032227
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        93.522527            94.955908         93.518519               4463
# 1        84.292662            88.412698         85.185185               4463
# 2        84.066386            88.436214         86.111111               4463
# 3        89.854097            93.474427         90.740741               4463
# 4        87.032227            89.400353         88.888889               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              88.50              4.08              87.14              4.54                 4463.00                      100.00              0.00                24.83                24.83          2425371.0                  9.26                        0.00               72.33
# mutual_info              90.36              3.84              89.04              4.61                 2231.00                       49.99             59.03                21.15                80.18          1282587.0                  4.90                       50.01               45.90
#         rfe              91.29              3.98              90.40              4.60                 2231.00                       49.99             10.98                21.95                32.92          1282587.0                  4.90                       50.01               45.90
#       lasso              61.81              6.14              59.30              5.72                 2231.00                       49.99              7.55                22.29                29.84          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              87.11              2.43              86.11              2.56                 2224.12                       49.83           1407.01                22.49              1429.50          1279067.0                  4.89                       50.17               45.87
#     meta_CS              87.11              4.10              85.76              4.77                 2209.00                       49.50           2771.66                22.47              2794.13          1271323.0                  4.86                       50.50               45.73
#     meta_DE              88.38              2.39              87.41              2.62                 2218.12                       49.70           1405.05                22.45              1427.51          1275995.0                  4.87                       50.30               45.82
#    meta_FFA              87.81              3.09              86.59              3.54                 2210.38                       49.53           1359.90                22.51              1382.40          1272027.0                  4.86                       50.47               45.76
#     meta_GA              87.69              2.93              86.49              3.51                 2210.50                       49.53           1360.43                22.13              1382.56          1272091.0                  4.86                       50.47               45.77
#    meta_GWO              88.96              2.77              87.95              3.60                 1856.50                       41.60           1292.21                20.88              1313.08          1090843.0                  4.17                       58.40               41.71
#    meta_HHO              87.57              5.13              86.17              6.02                 1895.00                       42.46           1701.49                22.01              1723.50          1110555.0                  4.24                       57.54               42.36
#   meta_JAYA              87.69              3.46              86.84              3.72                 2222.88                       49.81           1406.84                22.47              1429.31          1278427.0                  4.88                       50.19               45.87
#    meta_MFO              87.69              3.68              86.44              3.99                 2270.38                       50.87           1328.87                22.54              1351.41          1302747.0                  4.98                       49.13               46.37
#    meta_MVO              87.58              3.89              86.73              4.28                 2203.38                       49.37           1362.84                22.43              1385.28          1268443.0                  4.84                       50.63               45.68
#    meta_PSO              87.57              3.59              86.14              4.25                 2185.50                       48.97           1357.63                21.90              1379.53          1259291.0                  4.81                       51.03               45.54
#    meta_SCA              88.62              3.63              87.57              4.30                 1109.12                       24.85           1154.54                20.31              1174.86           708187.0                  2.71                       75.15               32.98
#    meta_SSA              87.35              4.51              86.22              4.75                 2208.38                       49.48           3405.14                22.51              3427.64          1271003.0                  4.85                       50.52               45.74
#    meta_WOA              86.76              4.97              85.45              5.06                 1755.75                       39.34           1245.04                18.64              1263.68          1039259.0                  3.97                       60.66               40.59

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_WOA
#     F1 Macro:           94.13%
#     F1 Weighted:        94.13%
#     Test Accuracy:      94.44%
#     Feature Retention:  50.06% (2234/4463)
#     Modality Retention: depth=48.6%, sensor=50.8%, skeleton=51.1%, video=48.9%
#
#   Fold 2: Best = meta_GWO
#     F1 Macro:           90.30%
#     F1 Weighted:        90.30%
#     Test Accuracy:      90.74%
#     Feature Retention:  40.42% (1804/4463)
#     Modality Retention: depth=39.6%, sensor=42.8%, skeleton=40.4%, video=39.6%
#
#   Fold 3: Best = meta_CS
#     F1 Macro:           88.62%
#     F1 Weighted:        88.62%
#     Test Accuracy:      88.89%
#     Feature Retention:  49.11% (2192/4463)
#     Modality Retention: depth=46.7%, sensor=50.9%, skeleton=50.0%, video=48.0%
#
#   Fold 4: Best = meta_PSO
#     F1 Macro:           89.00%
#     F1 Weighted:        89.00%
#     Test Accuracy:      90.74%
#     Feature Retention:  48.98% (2186/4463)
#     Modality Retention: depth=49.6%, sensor=53.1%, skeleton=47.8%, video=48.4%
#
#   Fold 5: Best = meta_WOA
#     F1 Macro:           91.59%
#     F1 Weighted:        91.59%
#     Test Accuracy:      92.59%
#     Feature Retention:  49.56% (2212/4463)
#     Modality Retention: depth=51.6%, sensor=50.6%, skeleton=49.5%, video=48.4%
#
#   Fold 6: Best = meta_BAT
#     F1 Macro:           88.11%
#     F1 Weighted:        88.00%
#     Test Accuracy:      89.72%
#     Feature Retention:  48.47% (2163/4463)
#     Modality Retention: depth=47.5%, sensor=46.0%, skeleton=48.5%, video=49.9%
#
#   Fold 7: Best = meta_SCA
#     F1 Macro:           96.16%
#     F1 Weighted:        96.12%
#     Test Accuracy:      96.26%
#     Feature Retention:  19.11% (853/4463)
#     Modality Retention: depth=16.4%, sensor=18.4%, skeleton=19.9%, video=19.4%
#
#   Fold 8: Best = meta_SSA
#     F1 Macro:           93.65%
#     F1 Weighted:        93.90%
#     Test Accuracy:      94.39%
#     Feature Retention:  48.29% (2155/4463)
#     Modality Retention: depth=50.2%, sensor=47.9%, skeleton=49.3%, video=46.4%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 91.45% ± 2.94%
#
#   Average F1 Weighted         : 91.46% ± 2.98%
#
#   Average Test Accuracy       : 92.22% ± 2.61%
#
#   Average Feature Retention   : 44.25% ± 10.61%
#
#   Average Modality-wise Feature Retention:
#            depth: 43.77% ± 11.63%
#           sensor: 45.05% ± 11.25%
#         skeleton: 44.57% ± 10.52%
#            video: 43.63% ± 10.28%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1           meta_WOA         94.13            94.13              94.44                  50.06              48.63               50.77                 51.09              48.87
#     2           meta_GWO         90.30            90.30              90.74                  40.42              39.65               42.79                 40.39              39.65
#     3            meta_CS         88.62            88.62              88.89                  49.11              46.68               50.92                 50.03              47.96
#     4           meta_PSO         89.00            89.00              90.74                  48.98              49.61               53.07                 47.84              48.38
#     5           meta_WOA         91.59            91.59              92.59                  49.56              51.56               50.61                 49.55              48.38
#     6           meta_BAT         88.11            88.00              89.72                  48.47              47.46               46.01                 48.48              49.93
#     7           meta_SCA         96.16            96.12              96.26                  19.11              16.41               18.40                 19.85              19.44
#     8           meta_SSA         93.65            93.90              94.39                  48.29              50.20               47.85                 49.33              46.41
#
# Saved to: results_noise_0.5_30/best_metaheuristic_per_fold.csv
