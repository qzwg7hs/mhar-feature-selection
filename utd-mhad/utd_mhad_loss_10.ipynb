# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_loss_10")

# Master output directory
RESULTS_ROOT = Path("results_loss_10")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

# FEATURE_DIMS will be set dynamically per-fold after PCA
# (depth dim changes if PCA is applied)
print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 92.59%, F1: 92.42%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 58.2s
#     Test Acc: 90.74%, F1: 89.78%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 14.0s
#     Test Acc: 87.96%, F1: 87.71%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 347.5s
#     Test Acc: 91.67%, F1: 90.32%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03389530951269106']
# ['At iteration 1 the best fitness is 0.03389530951269106']
# ['At iteration 2 the best fitness is 0.03389530951269106']
# ['At iteration 3 the best fitness is 0.03389530951269106']
# ['At iteration 4 the best fitness is 0.03389530951269106']
# ['At iteration 5 the best fitness is 0.03389530951269106']
# ['At iteration 6 the best fitness is 0.03389530951269106']
# ['At iteration 7 the best fitness is 0.03389530951269106']
# ['At iteration 8 the best fitness is 0.03389530951269106']
# ['At iteration 9 the best fitness is 0.03389530951269106']
# ['At iteration 10 the best fitness is 0.03389530951269106']
# ['At iteration 11 the best fitness is 0.03389530951269106']
# ['At iteration 12 the best fitness is 0.03389530951269106']
# ['At iteration 13 the best fitness is 0.03389530951269106']
# ['At iteration 14 the best fitness is 0.03389530951269106']
# ['At iteration 15 the best fitness is 0.03389530951269106']
# ['At iteration 16 the best fitness is 0.03389530951269106']
# ['At iteration 17 the best fitness is 0.03389530951269106']
# ['At iteration 18 the best fitness is 0.03389530951269106']
# ['At iteration 19 the best fitness is 0.03389530951269106']
# ['At iteration 20 the best fitness is 0.03389530951269106']
# ['At iteration 21 the best fitness is 0.03389530951269106']
# ['At iteration 22 the best fitness is 0.03389530951269106']
# ['At iteration 23 the best fitness is 0.03389530951269106']
# ['At iteration 24 the best fitness is 0.03389530951269106']
# ['At iteration 25 the best fitness is 0.03389530951269106']
# ['At iteration 26 the best fitness is 0.03389530951269106']
# ['At iteration 27 the best fitness is 0.03389530951269106']
# ['At iteration 28 the best fitness is 0.03389530951269106']
# ['At iteration 29 the best fitness is 0.03389530951269106']
#       Selected: 2233/4463 (50.0%), Fitness: 0.0339, Time: 1385.3s
#       Modality: D=46%, S=53%, Sk=49%, V=51%
#     Test Acc: 88.89%, F1: 88.34%, Features: 2233/4463 (50.0%), Model: 4.902MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06027314932121012']
# ['At iteration 1 the best fitness is 0.05224608986453519']
# ['At iteration 2 the best fitness is 0.05127140915649128']
# ['At iteration 3 the best fitness is 0.05127140915649128']
# ['At iteration 4 the best fitness is 0.05127140915649128']
# ['At iteration 5 the best fitness is 0.05127140915649128']
# ['At iteration 6 the best fitness is 0.05127140915649128']
# ['At iteration 7 the best fitness is 0.05121539302384508']
# ['At iteration 8 the best fitness is 0.04204560446118763']
# ['At iteration 9 the best fitness is 0.04204560446118763']
# ['At iteration 10 the best fitness is 0.04204560446118763']
# ['At iteration 11 the best fitness is 0.04204560446118763']
# ['At iteration 12 the best fitness is 0.04204560446118763']
# ['At iteration 13 the best fitness is 0.04204560446118763']
# ['At iteration 14 the best fitness is 0.04204560446118763']
# ['At iteration 15 the best fitness is 0.04204560446118763']
# ['At iteration 16 the best fitness is 0.04204560446118763']
# ['At iteration 17 the best fitness is 0.04204560446118763']
# ['At iteration 18 the best fitness is 0.04204560446118763']
# ['At iteration 19 the best fitness is 0.04204560446118763']
# ['At iteration 20 the best fitness is 0.04204560446118763']
# ['At iteration 21 the best fitness is 0.04204560446118763']
# ['At iteration 22 the best fitness is 0.04204560446118763']
# ['At iteration 23 the best fitness is 0.04204560446118763']
# ['At iteration 24 the best fitness is 0.04204560446118763']
# ['At iteration 25 the best fitness is 0.04204560446118763']
# ['At iteration 26 the best fitness is 0.04204560446118763']
# ['At iteration 27 the best fitness is 0.04204560446118763']
# ['At iteration 28 the best fitness is 0.04204560446118763']
# ['At iteration 29 the best fitness is 0.04204560446118763']
#       Selected: 2168/4463 (48.6%), Fitness: 0.0420, Time: 2768.1s
#       Modality: D=49%, S=47%, Sk=49%, V=49%
#     Test Acc: 87.96%, F1: 87.85%, Features: 2168/4463 (48.6%), Model: 4.776MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.051517880140134566']
# ['At iteration 2 the best fitness is 0.05129381560954976']
# ['At iteration 3 the best fitness is 0.05129381560954976']
# ['At iteration 4 the best fitness is 0.05129381560954976']
# ['At iteration 5 the best fitness is 0.05129381560954976']
# ['At iteration 6 the best fitness is 0.05129381560954976']
# ['At iteration 7 the best fitness is 0.042482530295828005']
# ['At iteration 8 the best fitness is 0.042482530295828005']
# ['At iteration 9 the best fitness is 0.042482530295828005']
# ['At iteration 10 the best fitness is 0.042482530295828005']
# ['At iteration 11 the best fitness is 0.042482530295828005']
# ['At iteration 12 the best fitness is 0.042482530295828005']
# ['At iteration 13 the best fitness is 0.042482530295828005']
# ['At iteration 14 the best fitness is 0.042482530295828005']
# ['At iteration 15 the best fitness is 0.042482530295828005']
# ['At iteration 16 the best fitness is 0.042482530295828005']
# ['At iteration 17 the best fitness is 0.041989588328541425']
# ['At iteration 18 the best fitness is 0.041989588328541425']
# ['At iteration 19 the best fitness is 0.041989588328541425']
# ['At iteration 20 the best fitness is 0.041989588328541425']
# ['At iteration 21 the best fitness is 0.041989588328541425']
# ['At iteration 22 the best fitness is 0.041989588328541425']
# ['At iteration 23 the best fitness is 0.041989588328541425']
# ['At iteration 24 the best fitness is 0.041989588328541425']
# ['At iteration 25 the best fitness is 0.041989588328541425']
# ['At iteration 26 the best fitness is 0.041989588328541425']
# ['At iteration 27 the best fitness is 0.0419559786489537']
# ['At iteration 28 the best fitness is 0.0419559786489537']
# ['At iteration 29 the best fitness is 0.0419559786489537']
# ['At iteration 30 the best fitness is 0.0419559786489537']
#       Selected: 2160/4463 (48.4%), Fitness: 0.0420, Time: 1403.7s
#       Modality: D=47%, S=45%, Sk=49%, V=49%
#     Test Acc: 86.11%, F1: 84.08%, Features: 2160/4463 (48.4%), Model: 4.760MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.060721278382379736']
# ['At iteration 1 the best fitness is 0.06971181532056933']
# ['At iteration 2 the best fitness is 0.06957737660221845']
# ['At iteration 3 the best fitness is 0.051999618880891905']
# ['At iteration 4 the best fitness is 0.06097895259255227']
# ['At iteration 5 the best fitness is 0.06966700241445238']
# ['At iteration 6 the best fitness is 0.061203017123137075']
# ['At iteration 7 the best fitness is 0.06083331064767214']
# ['At iteration 8 the best fitness is 0.06068766870279201']
# ['At iteration 9 the best fitness is 0.06974542500015705']
# ['At iteration 10 the best fitness is 0.06083331064767214']
# ['At iteration 11 the best fitness is 0.08744641821330525']
# ['At iteration 12 the best fitness is 0.07843347482205716']
# ['At iteration 13 the best fitness is 0.06965579918792314']
# ['At iteration 14 the best fitness is 0.06966700241445238']
# ['At iteration 15 the best fitness is 0.07851189740776185']
# ['At iteration 16 the best fitness is 0.06962218950833542']
# ['At iteration 17 the best fitness is 0.060721278382379736']
# ['At iteration 18 the best fitness is 0.06073248160890898']
# ['At iteration 19 the best fitness is 0.042975472263114586']
# ['At iteration 20 the best fitness is 0.060721278382379736']
# ['At iteration 21 the best fitness is 0.0695885798287477']
# ['At iteration 22 the best fitness is 0.06069887192932126']
# ['At iteration 23 the best fitness is 0.06957737660221845']
# ['At iteration 24 the best fitness is 0.07845588127511564']
# ['At iteration 25 the best fitness is 0.0695885798287477']
# ['At iteration 26 the best fitness is 0.060710075155850494']
# ['At iteration 27 the best fitness is 0.0695885798287477']
# ['At iteration 28 the best fitness is 0.060710075155850494']
# ['At iteration 29 the best fitness is 0.060710075155850494']
#       Selected: 2249/4463 (50.4%), Fitness: 0.0607, Time: 1362.8s
#       Modality: D=50%, S=52%, Sk=50%, V=51%
#     Test Acc: 88.89%, F1: 87.94%, Features: 2249/4463 (50.4%), Model: 4.934MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.08688625688684323
# At iteration 2 the best fitness is 0.06918526367369504
# At iteration 3 the best fitness is 0.06918526367369504
# At iteration 4 the best fitness is 0.051685928538073175
# At iteration 5 the best fitness is 0.06905082495534415
# At iteration 6 the best fitness is 0.060317962227327084
# At iteration 7 the best fitness is 0.0688155571982301
# At iteration 8 the best fitness is 0.060396384813031764
# At iteration 9 the best fitness is 0.06883796365128858
# At iteration 10 the best fitness is 0.051349831742195956
# At iteration 11 the best fitness is 0.06069887192932126
# At iteration 12 the best fitness is 0.06925248303287049
# At iteration 13 the best fitness is 0.05149547368707609
# At iteration 14 the best fitness is 0.06045240094567797
# At iteration 15 the best fitness is 0.06935331207163364
# At iteration 16 the best fitness is 0.03409696759021739
# At iteration 17 the best fitness is 0.06926368625939971
# At iteration 18 the best fitness is 0.05118178334425735
# At iteration 19 the best fitness is 0.06020592996203468
# At iteration 20 the best fitness is 0.0422584657652432
# At iteration 21 the best fitness is 0.05127140915649128
# At iteration 22 the best fitness is 0.024770333856150573
# At iteration 23 the best fitness is 0.05122659625037432
# At iteration 24 the best fitness is 0.0602395396416224
# At iteration 25 the best fitness is 0.04303148839576079
# At iteration 26 the best fitness is 0.051506676913605325
# At iteration 27 the best fitness is 0.069230076579812
# At iteration 28 the best fitness is 0.04305389484881926
# At iteration 29 the best fitness is 0.06069887192932126
# At iteration 30 the best fitness is 0.05204443178700886
#       Selected: 2268/4463 (50.8%), Fitness: 0.0520, Time: 1359.2s
#       Modality: D=50%, S=51%, Sk=51%, V=51%
#     Test Acc: 88.89%, F1: 87.94%, Features: 2268/4463 (50.8%), Model: 4.971MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05137223819525444']
# ['At iteration 1 the best fitness is 0.04212402704689231']
# ['At iteration 2 the best fitness is 0.0408468592225589']
# ['At iteration 3 the best fitness is 0.0408468592225589']
# ['At iteration 4 the best fitness is 0.039860975287985746']
# ['At iteration 5 the best fitness is 0.039860975287985746']
# ['At iteration 6 the best fitness is 0.039860975287985746']
# ['At iteration 7 the best fitness is 0.039860975287985746']
# ['At iteration 8 the best fitness is 0.039860975287985746']
# ['At iteration 9 the best fitness is 0.039860975287985746']
# ['At iteration 10 the best fitness is 0.039860975287985746']
# ['At iteration 11 the best fitness is 0.039166375243172846']
# ['At iteration 12 the best fitness is 0.039166375243172846']
# ['At iteration 13 the best fitness is 0.039166375243172846']
# ['At iteration 14 the best fitness is 0.039166375243172846']
# ['At iteration 15 the best fitness is 0.030231854437629442']
# ['At iteration 16 the best fitness is 0.030231854437629442']
# ['At iteration 17 the best fitness is 0.030231854437629442']
# ['At iteration 18 the best fitness is 0.030231854437629442']
# ['At iteration 19 the best fitness is 0.030231854437629442']
# ['At iteration 20 the best fitness is 0.030231854437629442']
# ['At iteration 21 the best fitness is 0.030231854437629442']
# ['At iteration 22 the best fitness is 0.030231854437629442']
# ['At iteration 23 the best fitness is 0.030231854437629442']
# ['At iteration 24 the best fitness is 0.030231854437629442']
# ['At iteration 25 the best fitness is 0.030231854437629442']
# ['At iteration 26 the best fitness is 0.030231854437629442']
# ['At iteration 27 the best fitness is 0.030231854437629442']
# ['At iteration 28 the best fitness is 0.030231854437629442']
# ['At iteration 29 the best fitness is 0.030231854437629442']
#       Selected: 1906/4463 (42.7%), Fitness: 0.0302, Time: 1293.5s
#       Modality: D=41%, S=45%, Sk=43%, V=42%
#     Test Acc: 85.19%, F1: 83.62%, Features: 1906/4463 (42.7%), Model: 4.264MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.069230076579812']
# ['At iteration 1 the best fitness is 0.069230076579812']
# ['At iteration 2 the best fitness is 0.06604836024550773']
# ['At iteration 3 the best fitness is 0.06604836024550773']
# ['At iteration 4 the best fitness is 0.06604836024550773']
# ['At iteration 5 the best fitness is 0.06604836024550773']
# ['At iteration 6 the best fitness is 0.04442623774712538']
# ['At iteration 7 the best fitness is 0.04442623774712538']
# ['At iteration 8 the best fitness is 0.04442623774712538']
# ['At iteration 9 the best fitness is 0.04442623774712538']
# ['At iteration 10 the best fitness is 0.04442623774712538']
# ['At iteration 11 the best fitness is 0.04442623774712538']
# ['At iteration 12 the best fitness is 0.04442623774712538']
# ['At iteration 13 the best fitness is 0.04442623774712538']
# ['At iteration 14 the best fitness is 0.04442623774712538']
# ['At iteration 15 the best fitness is 0.04442623774712538']
# ['At iteration 16 the best fitness is 0.04442623774712538']
# ['At iteration 17 the best fitness is 0.04442623774712538']
# ['At iteration 18 the best fitness is 0.035547733074228184']
# ['At iteration 19 the best fitness is 0.035547733074228184']
# ['At iteration 20 the best fitness is 0.035547733074228184']
# ['At iteration 21 the best fitness is 0.035547733074228184']
# ['At iteration 22 the best fitness is 0.035547733074228184']
# ['At iteration 23 the best fitness is 0.035547733074228184']
# ['At iteration 24 the best fitness is 0.035547733074228184']
# ['At iteration 25 the best fitness is 0.035547733074228184']
# ['At iteration 26 the best fitness is 0.035547733074228184']
# ['At iteration 27 the best fitness is 0.035547733074228184']
# ['At iteration 28 the best fitness is 0.035547733074228184']
# ['At iteration 29 the best fitness is 0.035547733074228184']
#       Selected: 1588/4463 (35.6%), Fitness: 0.0355, Time: 1775.9s
#       Modality: D=37%, S=36%, Sk=35%, V=36%
#     Test Acc: 89.81%, F1: 89.07%, Features: 1588/4463 (35.6%), Model: 3.643MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05203322856047962']
# ['At iteration 1 the best fitness is 0.05203322856047962']
# ['At iteration 2 the best fitness is 0.05184277370948254']
# ['At iteration 3 the best fitness is 0.04312111420799471']
# ['At iteration 4 the best fitness is 0.04312111420799471']
# ['At iteration 5 the best fitness is 0.04312111420799471']
# ['At iteration 6 the best fitness is 0.04305389484881926']
# ['At iteration 7 the best fitness is 0.04305389484881926']
# ['At iteration 8 the best fitness is 0.04305389484881926']
# ['At iteration 9 the best fitness is 0.04305389484881926']
# ['At iteration 10 the best fitness is 0.04305389484881926']
# ['At iteration 11 the best fitness is 0.04305389484881926']
# ['At iteration 12 the best fitness is 0.04305389484881926']
# ['At iteration 13 the best fitness is 0.04305389484881926']
# ['At iteration 14 the best fitness is 0.04305389484881926']
# ['At iteration 15 the best fitness is 0.04305389484881926']
# ['At iteration 16 the best fitness is 0.04305389484881926']
# ['At iteration 17 the best fitness is 0.04305389484881926']
# ['At iteration 18 the best fitness is 0.04290825290393914']
# ['At iteration 19 the best fitness is 0.04290825290393914']
# ['At iteration 20 the best fitness is 0.04290825290393914']
# ['At iteration 21 the best fitness is 0.04290825290393914']
# ['At iteration 22 the best fitness is 0.04290825290393914']
# ['At iteration 23 the best fitness is 0.04290825290393914']
# ['At iteration 24 the best fitness is 0.04290825290393914']
# ['At iteration 25 the best fitness is 0.04290825290393914']
# ['At iteration 26 the best fitness is 0.04290825290393914']
# ['At iteration 27 the best fitness is 0.04290825290393914']
# ['At iteration 28 the best fitness is 0.04290825290393914']
# ['At iteration 29 the best fitness is 0.04290825290393914']
#       Selected: 2245/4463 (50.3%), Fitness: 0.0429, Time: 1405.9s
#       Modality: D=51%, S=50%, Sk=50%, V=51%
#     Test Acc: 87.04%, F1: 85.79%, Features: 2245/4463 (50.3%), Model: 4.926MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06124783002925403']
# ['At iteration 2 the best fitness is 0.06124783002925403']
# ['At iteration 3 the best fitness is 0.06124783002925403']
# ['At iteration 4 the best fitness is 0.06090053000684758']
# ['At iteration 5 the best fitness is 0.06090053000684758']
# ['At iteration 6 the best fitness is 0.060889326780318345']
# ['At iteration 7 the best fitness is 0.060889326780318345']
# ['At iteration 8 the best fitness is 0.052302105997181395']
# ['At iteration 9 the best fitness is 0.052302105997181395']
# ['At iteration 10 the best fitness is 0.052302105997181395']
# ['At iteration 11 the best fitness is 0.052302105997181395']
# ['At iteration 12 the best fitness is 0.052302105997181395']
# ['At iteration 13 the best fitness is 0.052302105997181395']
# ['At iteration 14 the best fitness is 0.05211165114618431']
# ['At iteration 15 the best fitness is 0.05211165114618431']
# ['At iteration 16 the best fitness is 0.05211165114618431']
# ['At iteration 17 the best fitness is 0.05211165114618431']
# ['At iteration 18 the best fitness is 0.05211165114618431']
# ['At iteration 19 the best fitness is 0.05194360274824571']
# ['At iteration 20 the best fitness is 0.05194360274824571']
# ['At iteration 21 the best fitness is 0.05194360274824571']
# ['At iteration 22 the best fitness is 0.04338999164469648']
# ['At iteration 23 the best fitness is 0.04338999164469648']
# ['At iteration 24 the best fitness is 0.04338999164469648']
# ['At iteration 25 the best fitness is 0.04338999164469648']
# ['At iteration 26 the best fitness is 0.04338999164469648']
# ['At iteration 27 the best fitness is 0.04338999164469648']
# ['At iteration 28 the best fitness is 0.04338999164469648']
# ['At iteration 29 the best fitness is 0.04338999164469648']
#       Selected: 2288/4463 (51.3%), Fitness: 0.0434, Time: 1329.4s
#       Modality: D=50%, S=53%, Sk=50%, V=52%
#     Test Acc: 87.96%, F1: 86.46%, Features: 2288/4463 (51.3%), Model: 5.010MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07771646832418577']
# ['At iteration 2 the best fitness is 0.051282612383020516']
# ['At iteration 3 the best fitness is 0.051282612383020516']
# ['At iteration 4 the best fitness is 0.051282612383020516']
# ['At iteration 5 the best fitness is 0.04293065935699762']
# ['At iteration 6 the best fitness is 0.04293065935699762']
# ['At iteration 7 the best fitness is 0.033940122418808026']
# ['At iteration 8 the best fitness is 0.033940122418808026']
# ['At iteration 9 the best fitness is 0.033940122418808026']
# ['At iteration 10 the best fitness is 0.033940122418808026']
# ['At iteration 11 the best fitness is 0.033940122418808026']
# ['At iteration 12 the best fitness is 0.033940122418808026']
# ['At iteration 13 the best fitness is 0.033940122418808026']
# ['At iteration 14 the best fitness is 0.033940122418808026']
# ['At iteration 15 the best fitness is 0.033940122418808026']
# ['At iteration 16 the best fitness is 0.033940122418808026']
# ['At iteration 17 the best fitness is 0.033940122418808026']
# ['At iteration 18 the best fitness is 0.033940122418808026']
# ['At iteration 19 the best fitness is 0.033940122418808026']
# ['At iteration 20 the best fitness is 0.033940122418808026']
# ['At iteration 21 the best fitness is 0.033940122418808026']
# ['At iteration 22 the best fitness is 0.033940122418808026']
# ['At iteration 23 the best fitness is 0.033940122418808026']
# ['At iteration 24 the best fitness is 0.033940122418808026']
# ['At iteration 25 the best fitness is 0.033940122418808026']
# ['At iteration 26 the best fitness is 0.033940122418808026']
# ['At iteration 27 the best fitness is 0.033940122418808026']
# ['At iteration 28 the best fitness is 0.033940122418808026']
# ['At iteration 29 the best fitness is 0.033940122418808026']
# ['At iteration 30 the best fitness is 0.033940122418808026']
#       Selected: 2237/4463 (50.1%), Fitness: 0.0339, Time: 1366.4s
#       Modality: D=47%, S=52%, Sk=50%, V=51%
#     Test Acc: 86.11%, F1: 85.66%, Features: 2237/4463 (50.1%), Model: 4.910MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.051697131764602416']
# ['At iteration 2 the best fitness is 0.051697131764602416']
# ['At iteration 3 the best fitness is 0.051697131764602416']
# ['At iteration 4 the best fitness is 0.051697131764602416']
# ['At iteration 5 the best fitness is 0.042874643224351416']
# ['At iteration 6 the best fitness is 0.042874643224351416']
# ['At iteration 7 the best fitness is 0.042874643224351416']
# ['At iteration 8 the best fitness is 0.042874643224351416']
# ['At iteration 9 the best fitness is 0.04252734320194497']
# ['At iteration 10 the best fitness is 0.04252734320194497']
# ['At iteration 11 the best fitness is 0.04252734320194497']
# ['At iteration 12 the best fitness is 0.04252734320194497']
# ['At iteration 13 the best fitness is 0.04244892061624028']
# ['At iteration 14 the best fitness is 0.04244892061624028']
# ['At iteration 15 the best fitness is 0.04244892061624028']
# ['At iteration 16 the best fitness is 0.04244892061624028']
# ['At iteration 17 the best fitness is 0.04244892061624028']
# ['At iteration 18 the best fitness is 0.04244892061624028']
# ['At iteration 19 the best fitness is 0.04244892061624028']
# ['At iteration 20 the best fitness is 0.04244892061624028']
# ['At iteration 21 the best fitness is 0.04244892061624028']
# ['At iteration 22 the best fitness is 0.04244892061624028']
# ['At iteration 23 the best fitness is 0.04244892061624028']
# ['At iteration 24 the best fitness is 0.04244892061624028']
# ['At iteration 25 the best fitness is 0.04244892061624028']
# ['At iteration 26 the best fitness is 0.04244892061624028']
# ['At iteration 27 the best fitness is 0.04244892061624028']
# ['At iteration 28 the best fitness is 0.04244892061624028']
# ['At iteration 29 the best fitness is 0.04244892061624028']
# ['At iteration 30 the best fitness is 0.04244892061624028']
#       Selected: 2204/4463 (49.4%), Fitness: 0.0424, Time: 1355.3s
#       Modality: D=52%, S=52%, Sk=49%, V=47%
#     Test Acc: 91.67%, F1: 91.27%, Features: 2204/4463 (49.4%), Model: 4.846MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.060418791266090247']
# ['At iteration 1 the best fitness is 0.060418791266090247']
# ['At iteration 2 the best fitness is 0.060418791266090247']
# ['At iteration 3 the best fitness is 0.05701301040120116']
# ['At iteration 4 the best fitness is 0.05701301040120116']
# ['At iteration 5 the best fitness is 0.05701301040120116']
# ['At iteration 6 the best fitness is 0.05295744239761613']
# ['At iteration 7 the best fitness is 0.05295744239761613']
# ['At iteration 8 the best fitness is 0.05114251969987918']
# ['At iteration 9 the best fitness is 0.049730913157194884']
# ['At iteration 10 the best fitness is 0.049730913157194884']
# ['At iteration 11 the best fitness is 0.049730913157194884']
# ['At iteration 12 the best fitness is 0.049730913157194884']
# ['At iteration 13 the best fitness is 0.049730913157194884']
# ['At iteration 14 the best fitness is 0.04678446458000465']
# ['At iteration 15 the best fitness is 0.04678446458000465']
# ['At iteration 16 the best fitness is 0.04678446458000465']
# ['At iteration 17 the best fitness is 0.04678446458000465']
# ['At iteration 18 the best fitness is 0.03621427270119215']
# ['At iteration 19 the best fitness is 0.03621427270119215']
# ['At iteration 20 the best fitness is 0.03621427270119215']
# ['At iteration 21 the best fitness is 0.018614108526807123']
# ['At iteration 22 the best fitness is 0.018614108526807123']
# ['At iteration 23 the best fitness is 0.018614108526807123']
# ['At iteration 24 the best fitness is 0.018614108526807123']
# ['At iteration 25 the best fitness is 0.018614108526807123']
# ['At iteration 26 the best fitness is 0.018614108526807123']
# ['At iteration 27 the best fitness is 0.018614108526807123']
# ['At iteration 28 the best fitness is 0.018614108526807123']
# ['At iteration 29 the best fitness is 0.018614108526807123']
#       Selected: 869/4463 (19.5%), Fitness: 0.0186, Time: 1152.1s
#       Modality: D=21%, S=17%, Sk=19%, V=21%
#     Test Acc: 90.74%, F1: 90.63%, Features: 869/4463 (19.5%), Model: 2.238MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.043333975512050274']
# ['At iteration 2 the best fitness is 0.043333975512050274']
# ['At iteration 3 the best fitness is 0.043333975512050274']
# ['At iteration 4 the best fitness is 0.0428970496774099']
# ['At iteration 5 the best fitness is 0.0428970496774099']
# ['At iteration 6 the best fitness is 0.0428970496774099']
# ['At iteration 7 the best fitness is 0.0428970496774099']
# ['At iteration 8 the best fitness is 0.0428970496774099']
# ['At iteration 9 the best fitness is 0.04244892061624028']
# ['At iteration 10 the best fitness is 0.04228087221830168']
# ['At iteration 11 the best fitness is 0.04228087221830168']
# ['At iteration 12 the best fitness is 0.04228087221830168']
# ['At iteration 13 the best fitness is 0.04228087221830168']
# ['At iteration 14 the best fitness is 0.04228087221830168']
# ['At iteration 15 the best fitness is 0.04228087221830168']
# ['At iteration 16 the best fitness is 0.04228087221830168']
# ['At iteration 17 the best fitness is 0.04228087221830168']
# ['At iteration 18 the best fitness is 0.04228087221830168']
# ['At iteration 19 the best fitness is 0.04228087221830168']
# ['At iteration 20 the best fitness is 0.04228087221830168']
# ['At iteration 21 the best fitness is 0.04228087221830168']
# ['At iteration 22 the best fitness is 0.04228087221830168']
# ['At iteration 23 the best fitness is 0.04228087221830168']
# ['At iteration 24 the best fitness is 0.04228087221830168']
# ['At iteration 25 the best fitness is 0.04228087221830168']
# ['At iteration 26 the best fitness is 0.04228087221830168']
# ['At iteration 27 the best fitness is 0.04228087221830168']
# ['At iteration 28 the best fitness is 0.04228087221830168']
# ['At iteration 29 the best fitness is 0.04228087221830168']
#       Selected: 2189/4463 (49.0%), Fitness: 0.0423, Time: 3399.0s
#       Modality: D=48%, S=48%, Sk=49%, V=50%
#     Test Acc: 90.74%, F1: 89.32%, Features: 2189/4463 (49.0%), Model: 4.817MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06935331207163364']
# ['At iteration 1 the best fitness is 0.06935331207163364']
# ['At iteration 2 the best fitness is 0.064507968949263']
# ['At iteration 3 the best fitness is 0.064507968949263']
# ['At iteration 4 the best fitness is 0.064507968949263']
# ['At iteration 5 the best fitness is 0.04671734992388089']
# ['At iteration 6 the best fitness is 0.04671734992388089']
# ['At iteration 7 the best fitness is 0.04671734992388089']
# ['At iteration 8 the best fitness is 0.04671734992388089']
# ['At iteration 9 the best fitness is 0.04671734992388089']
# ['At iteration 10 the best fitness is 0.04671734992388089']
# ['At iteration 11 the best fitness is 0.04671734992388089']
# ['At iteration 12 the best fitness is 0.04671734992388089']
# ['At iteration 13 the best fitness is 0.04671734992388089']
# ['At iteration 14 the best fitness is 0.04671734992388089']
# ['At iteration 15 the best fitness is 0.04671734992388089']
# ['At iteration 16 the best fitness is 0.04671734992388089']
# ['At iteration 17 the best fitness is 0.04671734992388089']
# ['At iteration 18 the best fitness is 0.04671734992388089']
# ['At iteration 19 the best fitness is 0.04671734992388089']
# ['At iteration 20 the best fitness is 0.04671734992388089']
# ['At iteration 21 the best fitness is 0.04671734992388089']
# ['At iteration 22 the best fitness is 0.04671734992388089']
# ['At iteration 23 the best fitness is 0.04671734992388089']
# ['At iteration 24 the best fitness is 0.04671734992388089']
# ['At iteration 25 the best fitness is 0.04671734992388089']
# ['At iteration 26 the best fitness is 0.04671734992388089']
# ['At iteration 27 the best fitness is 0.04671734992388089']
# ['At iteration 28 the best fitness is 0.04671734992388089']
# ['At iteration 29 the best fitness is 0.04671734992388089']
#       Selected: 2585/4463 (57.9%), Fitness: 0.0467, Time: 1301.4s
#       Modality: D=58%, S=58%, Sk=57%, V=59%
#     Test Acc: 92.59%, F1: 91.77%, Features: 2585/4463 (57.9%), Model: 5.590MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 82.41%, F1: 79.88%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 59.4s
#     Test Acc: 87.04%, F1: 85.62%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 9.6s
#     Test Acc: 89.81%, F1: 89.07%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 7.2s
#     Test Acc: 71.30%, F1: 66.95%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03373846434128169']
# ['At iteration 1 the best fitness is 0.03373846434128169']
# ['At iteration 2 the best fitness is 0.03373846434128169']
# ['At iteration 3 the best fitness is 0.03373846434128169']
# ['At iteration 4 the best fitness is 0.03373846434128169']
# ['At iteration 5 the best fitness is 0.03373846434128169']
# ['At iteration 6 the best fitness is 0.024893569347972218']
# ['At iteration 7 the best fitness is 0.024893569347972218']
# ['At iteration 8 the best fitness is 0.024893569347972218']
# ['At iteration 9 the best fitness is 0.024893569347972218']
# ['At iteration 10 the best fitness is 0.024893569347972218']
# ['At iteration 11 the best fitness is 0.024893569347972218']
# ['At iteration 12 the best fitness is 0.024893569347972218']
# ['At iteration 13 the best fitness is 0.024893569347972218']
# ['At iteration 14 the best fitness is 0.024893569347972218']
# ['At iteration 15 the best fitness is 0.024893569347972218']
# ['At iteration 16 the best fitness is 0.024893569347972218']
# ['At iteration 17 the best fitness is 0.024893569347972218']
# ['At iteration 18 the best fitness is 0.024893569347972218']
# ['At iteration 19 the best fitness is 0.024893569347972218']
# ['At iteration 20 the best fitness is 0.024893569347972218']
# ['At iteration 21 the best fitness is 0.024893569347972218']
# ['At iteration 22 the best fitness is 0.024893569347972218']
# ['At iteration 23 the best fitness is 0.024893569347972218']
# ['At iteration 24 the best fitness is 0.024893569347972218']
# ['At iteration 25 the best fitness is 0.024893569347972218']
# ['At iteration 26 the best fitness is 0.024893569347972218']
# ['At iteration 27 the best fitness is 0.024893569347972218']
# ['At iteration 28 the best fitness is 0.024893569347972218']
# ['At iteration 29 the best fitness is 0.024893569347972218']
#       Selected: 2222/4463 (49.8%), Fitness: 0.0249, Time: 1399.9s
#       Modality: D=50%, S=50%, Sk=49%, V=51%
#     Test Acc: 84.26%, F1: 82.67%, Features: 2222/4463 (49.8%), Model: 4.881MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.033458383678050686']
# ['At iteration 1 the best fitness is 0.033458383678050686']
# ['At iteration 2 the best fitness is 0.033458383678050686']
# ['At iteration 3 the best fitness is 0.033458383678050686']
# ['At iteration 4 the best fitness is 0.033458383678050686']
# ['At iteration 5 the best fitness is 0.033458383678050686']
# ['At iteration 6 the best fitness is 0.033458383678050686']
# ['At iteration 7 the best fitness is 0.033458383678050686']
# ['At iteration 8 the best fitness is 0.033458383678050686']
# ['At iteration 9 the best fitness is 0.033346351412758275']
# ['At iteration 10 the best fitness is 0.033346351412758275']
# ['At iteration 11 the best fitness is 0.033346351412758275']
# ['At iteration 12 the best fitness is 0.033346351412758275']
# ['At iteration 13 the best fitness is 0.033346351412758275']
# ['At iteration 14 the best fitness is 0.033346351412758275']
# ['At iteration 15 the best fitness is 0.033346351412758275']
# ['At iteration 16 the best fitness is 0.033346351412758275']
# ['At iteration 17 the best fitness is 0.033346351412758275']
# ['At iteration 18 the best fitness is 0.033346351412758275']
# ['At iteration 19 the best fitness is 0.033346351412758275']
# ['At iteration 20 the best fitness is 0.033346351412758275']
# ['At iteration 21 the best fitness is 0.033346351412758275']
# ['At iteration 22 the best fitness is 0.033346351412758275']
# ['At iteration 23 the best fitness is 0.033346351412758275']
# ['At iteration 24 the best fitness is 0.033346351412758275']
# ['At iteration 25 the best fitness is 0.033346351412758275']
# ['At iteration 26 the best fitness is 0.033346351412758275']
# ['At iteration 27 the best fitness is 0.033346351412758275']
# ['At iteration 28 the best fitness is 0.033346351412758275']
# ['At iteration 29 the best fitness is 0.033346351412758275']
#       Selected: 2184/4463 (48.9%), Fitness: 0.0333, Time: 2775.8s
#       Modality: D=51%, S=50%, Sk=49%, V=48%
#     Test Acc: 84.26%, F1: 82.94%, Features: 2184/4463 (48.9%), Model: 4.807MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0423144818978894']
# ['At iteration 2 the best fitness is 0.0423144818978894']
# ['At iteration 3 the best fitness is 0.0423144818978894']
# ['At iteration 4 the best fitness is 0.0423144818978894']
# ['At iteration 5 the best fitness is 0.042224856085655474']
# ['At iteration 6 the best fitness is 0.042224856085655474']
# ['At iteration 7 the best fitness is 0.042224856085655474']
# ['At iteration 8 the best fitness is 0.042224856085655474']
# ['At iteration 9 the best fitness is 0.042224856085655474']
# ['At iteration 10 the best fitness is 0.042224856085655474']
# ['At iteration 11 the best fitness is 0.042224856085655474']
# ['At iteration 12 the best fitness is 0.042224856085655474']
# ['At iteration 13 the best fitness is 0.042224856085655474']
# ['At iteration 14 the best fitness is 0.042224856085655474']
# ['At iteration 15 the best fitness is 0.04219124640606775']
# ['At iteration 16 the best fitness is 0.04219124640606775']
# ['At iteration 17 the best fitness is 0.04219124640606775']
# ['At iteration 18 the best fitness is 0.04219124640606775']
# ['At iteration 19 the best fitness is 0.04219124640606775']
# ['At iteration 20 the best fitness is 0.04219124640606775']
# ['At iteration 21 the best fitness is 0.04219124640606775']
# ['At iteration 22 the best fitness is 0.04219124640606775']
# ['At iteration 23 the best fitness is 0.04219124640606775']
# ['At iteration 24 the best fitness is 0.04219124640606775']
# ['At iteration 25 the best fitness is 0.042101620593833836']
# ['At iteration 26 the best fitness is 0.02518485323773247']
# ['At iteration 27 the best fitness is 0.02518485323773247']
# ['At iteration 28 the best fitness is 0.02518485323773247']
# ['At iteration 29 the best fitness is 0.02518485323773247']
# ['At iteration 30 the best fitness is 0.02518485323773247']
#       Selected: 2248/4463 (50.4%), Fitness: 0.0252, Time: 1407.9s
#       Modality: D=51%, S=49%, Sk=50%, V=50%
#     Test Acc: 88.89%, F1: 88.00%, Features: 2248/4463 (50.4%), Model: 4.932MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06046360417220721']
# ['At iteration 1 the best fitness is 0.04240410771012332']
# ['At iteration 2 the best fitness is 0.04202319800812915']
# ['At iteration 3 the best fitness is 0.05964576863557266']
# ['At iteration 4 the best fitness is 0.03298784816382259']
# ['At iteration 5 the best fitness is 0.033111083655644226']
# ['At iteration 6 the best fitness is 0.05092410913408482']
# ['At iteration 7 the best fitness is 0.03299905139035183']
# ['At iteration 8 the best fitness is 0.04219124640606775']
# ['At iteration 9 the best fitness is 0.033200709467878155']
# ['At iteration 10 the best fitness is 0.05087929622796786']
# ['At iteration 11 the best fitness is 0.04201199478159991']
# ['At iteration 12 the best fitness is 0.04201199478159991']
# ['At iteration 13 the best fitness is 0.04203440123465839']
# ['At iteration 14 the best fitness is 0.03324552237399511']
# ['At iteration 15 the best fitness is 0.03329033528011208']
# ['At iteration 16 the best fitness is 0.05092410913408482']
# ['At iteration 17 the best fitness is 0.05979141058045278']
# ['At iteration 18 the best fitness is 0.03313349010870271']
# ['At iteration 19 the best fitness is 0.041989588328541425']
# ['At iteration 20 the best fitness is 0.04202319800812915']
# ['At iteration 21 the best fitness is 0.03314469333523195']
# ['At iteration 22 the best fitness is 0.042000791555070666']
# ['At iteration 23 the best fitness is 0.04202319800812915']
# ['At iteration 24 the best fitness is 0.03313349010870271']
# ['At iteration 25 the best fitness is 0.05087929622796786']
# ['At iteration 26 the best fitness is 0.03314469333523195']
# ['At iteration 27 the best fitness is 0.04202319800812915']
# ['At iteration 28 the best fitness is 0.04204560446118763']
# ['At iteration 29 the best fitness is 0.04204560446118763']
#       Selected: 2168/4463 (48.6%), Fitness: 0.0420, Time: 1357.8s
#       Modality: D=50%, S=48%, Sk=48%, V=50%
#     Test Acc: 87.04%, F1: 85.83%, Features: 2168/4463 (48.6%), Model: 4.776MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.03361522884946005
# At iteration 2 the best fitness is 0.02473672417656285
# At iteration 3 the best fitness is 0.05152908336666381
# At iteration 4 the best fitness is 0.05115937689119887
# At iteration 5 the best fitness is 0.04213523027342155
# At iteration 6 the best fitness is 0.03353680626375537
# At iteration 7 the best fitness is 0.04279622063864674
# At iteration 8 the best fitness is 0.03353680626375537
# At iteration 9 the best fitness is 0.03360402562293081
# At iteration 10 the best fitness is 0.03367124498210625
# At iteration 11 the best fitness is 0.04294186258352686
# At iteration 12 the best fitness is 0.03402974823104195
# At iteration 13 the best fitness is 0.03395132564533726
# At iteration 14 the best fitness is 0.04249373352235725
# At iteration 15 the best fitness is 0.034309828894272955
# At iteration 16 the best fitness is 0.03433223534733144
# At iteration 17 the best fitness is 0.03427621921468523
# At iteration 18 the best fitness is 0.03418659340245131
# At iteration 19 the best fitness is 0.042236059312184715
# At iteration 20 the best fitness is 0.04277381418558826
# At iteration 21 the best fitness is 0.033816886926986374
# At iteration 22 the best fitness is 0.03355921271681385
# At iteration 23 the best fitness is 0.05114817366466963
# At iteration 24 the best fitness is 0.04256095288153269
# At iteration 25 the best fitness is 0.03339116431887524
# At iteration 26 the best fitness is 0.04250493674888649
# At iteration 27 the best fitness is 0.03339116431887524
# At iteration 28 the best fitness is 0.03342477399846296
# At iteration 29 the best fitness is 0.04256095288153269
# At iteration 30 the best fitness is 0.04207921414077535
#       Selected: 2171/4463 (48.6%), Fitness: 0.0421, Time: 1362.0s
#       Modality: D=49%, S=50%, Sk=47%, V=50%
#     Test Acc: 87.04%, F1: 85.84%, Features: 2171/4463 (48.6%), Model: 4.781MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05126020592996204']
# ['At iteration 1 the best fitness is 0.051192986570786594']
# ['At iteration 2 the best fitness is 0.04977017680157306']
# ['At iteration 3 the best fitness is 0.031150519013027157']
# ['At iteration 4 the best fitness is 0.031150519013027157']
# ['At iteration 5 the best fitness is 0.031150519013027157']
# ['At iteration 6 the best fitness is 0.031150519013027157']
# ['At iteration 7 the best fitness is 0.031150519013027157']
# ['At iteration 8 the best fitness is 0.031150519013027157']
# ['At iteration 9 the best fitness is 0.031150519013027157']
# ['At iteration 10 the best fitness is 0.031150519013027157']
# ['At iteration 11 the best fitness is 0.0197064754649339']
# ['At iteration 12 the best fitness is 0.0197064754649339']
# ['At iteration 13 the best fitness is 0.0197064754649339']
# ['At iteration 14 the best fitness is 0.0197064754649339']
# ['At iteration 15 the best fitness is 0.0197064754649339']
# ['At iteration 16 the best fitness is 0.0197064754649339']
# ['At iteration 17 the best fitness is 0.0197064754649339']
# ['At iteration 18 the best fitness is 0.0197064754649339']
# ['At iteration 19 the best fitness is 0.0197064754649339']
# ['At iteration 20 the best fitness is 0.0197064754649339']
# ['At iteration 21 the best fitness is 0.0197064754649339']
# ['At iteration 22 the best fitness is 0.0197064754649339']
# ['At iteration 23 the best fitness is 0.0197064754649339']
# ['At iteration 24 the best fitness is 0.0197064754649339']
# ['At iteration 25 the best fitness is 0.0197064754649339']
# ['At iteration 26 the best fitness is 0.0197064754649339']
# ['At iteration 27 the best fitness is 0.0197064754649339']
# ['At iteration 28 the best fitness is 0.0197064754649339']
# ['At iteration 29 the best fitness is 0.0197064754649339']
#       Selected: 1759/4463 (39.4%), Fitness: 0.0197, Time: 1295.3s
#       Modality: D=37%, S=38%, Sk=42%, V=38%
#     Test Acc: 83.33%, F1: 82.18%, Features: 1759/4463 (39.4%), Model: 3.977MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.051999618880891905']
# ['At iteration 1 the best fitness is 0.051999618880891905']
# ['At iteration 2 the best fitness is 0.051999618880891905']
# ['At iteration 3 the best fitness is 0.04690780477487797']
# ['At iteration 4 the best fitness is 0.043446007777342685']
# ['At iteration 5 the best fitness is 0.043446007777342685']
# ['At iteration 6 the best fitness is 0.043446007777342685']
# ['At iteration 7 the best fitness is 0.043446007777342685']
# ['At iteration 8 the best fitness is 0.043446007777342685']
# ['At iteration 9 the best fitness is 0.043446007777342685']
# ['At iteration 10 the best fitness is 0.043356381965108756']
# ['At iteration 11 the best fitness is 0.043356381965108756']
# ['At iteration 12 the best fitness is 0.043356381965108756']
# ['At iteration 13 the best fitness is 0.043356381965108756']
# ['At iteration 14 the best fitness is 0.043356381965108756']
# ['At iteration 15 the best fitness is 0.043356381965108756']
# ['At iteration 16 the best fitness is 0.043356381965108756']
# ['At iteration 17 the best fitness is 0.043356381965108756']
# ['At iteration 18 the best fitness is 0.04282983031823446']
# ['At iteration 19 the best fitness is 0.037564313849491465']
# ['At iteration 20 the best fitness is 0.037564313849491465']
# ['At iteration 21 the best fitness is 0.037564313849491465']
# ['At iteration 22 the best fitness is 0.037564313849491465']
# ['At iteration 23 the best fitness is 0.036847307351620076']
# ['At iteration 24 the best fitness is 0.036847307351620076']
# ['At iteration 25 the best fitness is 0.036847307351620076']
# ['At iteration 26 the best fitness is 0.036847307351620076']
# ['At iteration 27 the best fitness is 0.036847307351620076']
# ['At iteration 28 the best fitness is 0.036847307351620076']
# ['At iteration 29 the best fitness is 0.036847307351620076']
#       Selected: 1704/4463 (38.2%), Fitness: 0.0368, Time: 1624.9s
#       Modality: D=34%, S=36%, Sk=41%, V=37%
#     Test Acc: 85.19%, F1: 84.10%, Features: 1704/4463 (38.2%), Model: 3.869MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.051349831742195956']
# ['At iteration 1 the best fitness is 0.03366004175557701']
# ['At iteration 2 the best fitness is 0.03366004175557701']
# ['At iteration 3 the best fitness is 0.03366004175557701']
# ['At iteration 4 the best fitness is 0.03366004175557701']
# ['At iteration 5 the best fitness is 0.03366004175557701']
# ['At iteration 6 the best fitness is 0.03366004175557701']
# ['At iteration 7 the best fitness is 0.03366004175557701']
# ['At iteration 8 the best fitness is 0.03366004175557701']
# ['At iteration 9 the best fitness is 0.03366004175557701']
# ['At iteration 10 the best fitness is 0.03366004175557701']
# ['At iteration 11 the best fitness is 0.03366004175557701']
# ['At iteration 12 the best fitness is 0.03366004175557701']
# ['At iteration 13 the best fitness is 0.03366004175557701']
# ['At iteration 14 the best fitness is 0.03366004175557701']
# ['At iteration 15 the best fitness is 0.03366004175557701']
# ['At iteration 16 the best fitness is 0.03366004175557701']
# ['At iteration 17 the best fitness is 0.03366004175557701']
# ['At iteration 18 the best fitness is 0.03366004175557701']
# ['At iteration 19 the best fitness is 0.033570415943343083']
# ['At iteration 20 the best fitness is 0.033570415943343083']
# ['At iteration 21 the best fitness is 0.033570415943343083']
# ['At iteration 22 the best fitness is 0.033570415943343083']
# ['At iteration 23 the best fitness is 0.033570415943343083']
# ...
# ['At iteration 15 the best fitness is 0.04708695169629414']
# ['At iteration 16 the best fitness is 0.04708695169629414']
# ['At iteration 17 the best fitness is 0.04708695169629414']
# ['At iteration 18 the best fitness is 0.04708695169629414']
# ['At iteration 19 the best fitness is 0.04708695169629414']
# ['At iteration 20 the best fitness is 0.04708695169629414']
# ['At iteration 21 the best fitness is 0.04708695169629414']
# ['At iteration 22 the best fitness is 0.04708695169629414']
# ['At iteration 23 the best fitness is 0.04708695169629414']
# ['At iteration 24 the best fitness is 0.03804039862545834']
# ['At iteration 25 the best fitness is 0.03804039862545834']
# ['At iteration 26 the best fitness is 0.03804039862545834']
# ['At iteration 27 the best fitness is 0.03804039862545834']
# ['At iteration 28 the best fitness is 0.03801799217239986']
# ['At iteration 29 the best fitness is 0.03801799217239986']
#       Selected: 1016/4463 (22.8%), Fitness: 0.0380, Time: 1763.0s
#       Modality: D=24%, S=25%, Sk=23%, V=21%
#     Test Acc: 95.33%, F1: 95.22%, Features: 1016/4463 (22.8%), Model: 2.526MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06055322998444113']
# ['At iteration 1 the best fitness is 0.06055322998444113']
# ['At iteration 2 the best fitness is 0.06055322998444113']
# ['At iteration 3 the best fitness is 0.05148427046054685']
# ['At iteration 4 the best fitness is 0.05148427046054685']
# ['At iteration 5 the best fitness is 0.042964269036585345']
# ['At iteration 6 the best fitness is 0.042964269036585345']
# ['At iteration 7 the best fitness is 0.042964269036585345']
# ['At iteration 8 the best fitness is 0.042964269036585345']
# ['At iteration 9 the best fitness is 0.042964269036585345']
# ['At iteration 10 the best fitness is 0.042964269036585345']
# ['At iteration 11 the best fitness is 0.042964269036585345']
# ['At iteration 12 the best fitness is 0.042964269036585345']
# ['At iteration 13 the best fitness is 0.042964269036585345']
# ['At iteration 14 the best fitness is 0.042964269036585345']
# ['At iteration 15 the best fitness is 0.042964269036585345']
# ['At iteration 16 the best fitness is 0.042964269036585345']
# ['At iteration 17 the best fitness is 0.042964269036585345']
# ['At iteration 18 the best fitness is 0.042964269036585345']
# ['At iteration 19 the best fitness is 0.042964269036585345']
# ['At iteration 20 the best fitness is 0.042964269036585345']
# ['At iteration 21 the best fitness is 0.042964269036585345']
# ['At iteration 22 the best fitness is 0.042964269036585345']
# ['At iteration 23 the best fitness is 0.042964269036585345']
# ['At iteration 24 the best fitness is 0.042964269036585345']
# ['At iteration 25 the best fitness is 0.042964269036585345']
# ['At iteration 26 the best fitness is 0.042964269036585345']
# ['At iteration 27 the best fitness is 0.042964269036585345']
# ['At iteration 28 the best fitness is 0.042964269036585345']
# ['At iteration 29 the best fitness is 0.042964269036585345']
#       Selected: 2250/4463 (50.4%), Fitness: 0.0430, Time: 1411.6s
#       Modality: D=48%, S=54%, Sk=50%, V=50%
#     Test Acc: 91.59%, F1: 90.01%, Features: 2250/4463 (50.4%), Model: 4.936MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06937571852469213']
# ['At iteration 2 the best fitness is 0.06930849916551668']
# ['At iteration 3 the best fitness is 0.06930849916551668']
# ['At iteration 4 the best fitness is 0.06110218808437391']
# ['At iteration 5 the best fitness is 0.06110218808437391']
# ['At iteration 6 the best fitness is 0.06110218808437391']
# ['At iteration 7 the best fitness is 0.0602395396416224']
# ['At iteration 8 the best fitness is 0.05244774794206152']
# ['At iteration 9 the best fitness is 0.05244774794206152']
# ['At iteration 10 the best fitness is 0.05244774794206152']
# ['At iteration 11 the best fitness is 0.05244774794206152']
# ['At iteration 12 the best fitness is 0.05244774794206152']
# ['At iteration 13 the best fitness is 0.05244774794206152']
# ['At iteration 14 the best fitness is 0.05244774794206152']
# ['At iteration 15 the best fitness is 0.05244774794206152']
# ['At iteration 16 the best fitness is 0.05244774794206152']
# ['At iteration 17 the best fitness is 0.05244774794206152']
# ['At iteration 18 the best fitness is 0.05244774794206152']
# ['At iteration 19 the best fitness is 0.05244774794206152']
# ['At iteration 20 the best fitness is 0.05244774794206152']
# ['At iteration 21 the best fitness is 0.05244774794206152']
# ['At iteration 22 the best fitness is 0.05244774794206152']
# ['At iteration 23 the best fitness is 0.05244774794206152']
# ['At iteration 24 the best fitness is 0.05244774794206152']
# ['At iteration 25 the best fitness is 0.05244774794206152']
# ['At iteration 26 the best fitness is 0.043580446495693564']
# ['At iteration 27 the best fitness is 0.043580446495693564']
# ['At iteration 28 the best fitness is 0.043580446495693564']
# ['At iteration 29 the best fitness is 0.043580446495693564']
#       Selected: 2305/4463 (51.6%), Fitness: 0.0436, Time: 1329.0s
#       Modality: D=51%, S=53%, Sk=51%, V=52%
#     Test Acc: 94.39%, F1: 94.09%, Features: 2305/4463 (51.6%), Model: 5.043MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06042999449261949']
# ['At iteration 2 the best fitness is 0.06042999449261949']
# ['At iteration 3 the best fitness is 0.05161870917889773']
# ['At iteration 4 the best fitness is 0.05161870917889773']
# ['At iteration 5 the best fitness is 0.05161870917889773']
# ['At iteration 6 the best fitness is 0.05161870917889773']
# ['At iteration 7 the best fitness is 0.04280742386517598']
# ['At iteration 8 the best fitness is 0.04280742386517598']
# ['At iteration 9 the best fitness is 0.04280742386517598']
# ['At iteration 10 the best fitness is 0.04280742386517598']
# ['At iteration 11 the best fitness is 0.04280742386517598']
# ['At iteration 12 the best fitness is 0.04280742386517598']
# ['At iteration 13 the best fitness is 0.04280742386517598']
# ['At iteration 14 the best fitness is 0.04280742386517598']
# ['At iteration 15 the best fitness is 0.04280742386517598']
# ['At iteration 16 the best fitness is 0.04280742386517598']
# ['At iteration 17 the best fitness is 0.04280742386517598']
# ['At iteration 18 the best fitness is 0.04280742386517598']
# ['At iteration 19 the best fitness is 0.04280742386517598']
# ['At iteration 20 the best fitness is 0.04280742386517598']
# ['At iteration 21 the best fitness is 0.04280742386517598']
# ['At iteration 22 the best fitness is 0.04280742386517598']
# ['At iteration 23 the best fitness is 0.04280742386517598']
# ['At iteration 24 the best fitness is 0.04280742386517598']
# ['At iteration 25 the best fitness is 0.04280742386517598']
# ['At iteration 26 the best fitness is 0.04280742386517598']
# ['At iteration 27 the best fitness is 0.04280742386517598']
# ['At iteration 28 the best fitness is 0.04280742386517598']
# ['At iteration 29 the best fitness is 0.04280742386517598']
# ['At iteration 30 the best fitness is 0.04280742386517598']
#       Selected: 2236/4463 (50.1%), Fitness: 0.0428, Time: 1366.9s
#       Modality: D=48%, S=50%, Sk=51%, V=50%
#     Test Acc: 97.20%, F1: 96.79%, Features: 2236/4463 (50.1%), Model: 4.908MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05170833499113166']
# ['At iteration 2 the best fitness is 0.05170833499113166']
# ['At iteration 3 the best fitness is 0.05170833499113166']
# ['At iteration 4 the best fitness is 0.05170833499113166']
# ['At iteration 5 the best fitness is 0.05170833499113166']
# ['At iteration 6 the best fitness is 0.05170833499113166']
# ['At iteration 7 the best fitness is 0.05170833499113166']
# ['At iteration 8 the best fitness is 0.05170833499113166']
# ['At iteration 9 the best fitness is 0.05170833499113166']
# ['At iteration 10 the best fitness is 0.05170833499113166']
# ['At iteration 11 the best fitness is 0.05170833499113166']
# ['At iteration 12 the best fitness is 0.05170833499113166']
# ['At iteration 13 the best fitness is 0.05170833499113166']
# ['At iteration 14 the best fitness is 0.05170833499113166']
# ['At iteration 15 the best fitness is 0.05170833499113166']
# ['At iteration 16 the best fitness is 0.05170833499113166']
# ['At iteration 17 the best fitness is 0.05170833499113166']
# ['At iteration 18 the best fitness is 0.05170833499113166']
# ['At iteration 19 the best fitness is 0.05170833499113166']
# ['At iteration 20 the best fitness is 0.05170833499113166']
# ['At iteration 21 the best fitness is 0.05170833499113166']
# ['At iteration 22 the best fitness is 0.05170833499113166']
# ['At iteration 23 the best fitness is 0.05170833499113166']
# ['At iteration 24 the best fitness is 0.05170833499113166']
# ['At iteration 25 the best fitness is 0.05170833499113166']
# ['At iteration 26 the best fitness is 0.05170833499113166']
# ['At iteration 27 the best fitness is 0.05170833499113166']
# ['At iteration 28 the best fitness is 0.05170833499113166']
# ['At iteration 29 the best fitness is 0.05170833499113166']
# ['At iteration 30 the best fitness is 0.05156269304625152']
#       Selected: 2225/4463 (49.9%), Fitness: 0.0516, Time: 1332.8s
#       Modality: D=51%, S=53%, Sk=49%, V=49%
#     Test Acc: 93.46%, F1: 92.97%, Features: 2225/4463 (49.9%), Model: 4.887MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06962218950833542']
# ['At iteration 1 the best fitness is 0.06962218950833542']
# ['At iteration 2 the best fitness is 0.06962218950833542']
# ['At iteration 3 the best fitness is 0.06962218950833542']
# ['At iteration 4 the best fitness is 0.06962218950833542']
# ['At iteration 5 the best fitness is 0.06547699569251646']
# ['At iteration 6 the best fitness is 0.06547699569251646']
# ['At iteration 7 the best fitness is 0.06547699569251646']
# ['At iteration 8 the best fitness is 0.06547699569251646']
# ['At iteration 9 the best fitness is 0.06547699569251646']
# ['At iteration 10 the best fitness is 0.06547699569251646']
# ['At iteration 11 the best fitness is 0.06076043732370624']
# ['At iteration 12 the best fitness is 0.059662521123840684']
# ['At iteration 13 the best fitness is 0.059662521123840684']
# ['At iteration 14 the best fitness is 0.059662521123840684']
# ['At iteration 15 the best fitness is 0.059662521123840684']
# ['At iteration 16 the best fitness is 0.059662521123840684']
# ['At iteration 17 the best fitness is 0.059662521123840684']
# ['At iteration 18 the best fitness is 0.059662521123840684']
# ['At iteration 19 the best fitness is 0.059662521123840684']
# ['At iteration 20 the best fitness is 0.059662521123840684']
# ['At iteration 21 the best fitness is 0.059662521123840684']
# ['At iteration 22 the best fitness is 0.05667125964053349']
# ['At iteration 23 the best fitness is 0.05667125964053349']
# ['At iteration 24 the best fitness is 0.05667125964053349']
# ['At iteration 25 the best fitness is 0.05667125964053349']
# ['At iteration 26 the best fitness is 0.05667125964053349']
# ['At iteration 27 the best fitness is 0.05667125964053349']
# ['At iteration 28 the best fitness is 0.04809524208392578']
# ['At iteration 29 the best fitness is 0.04809524208392578']
#       Selected: 1123/4463 (25.2%), Fitness: 0.0481, Time: 1225.9s
#       Modality: D=25%, S=25%, Sk=26%, V=25%
#     Test Acc: 91.59%, F1: 91.12%, Features: 1123/4463 (25.2%), Model: 2.734MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05193239952171646']
# ['At iteration 2 the best fitness is 0.05193239952171646']
# ['At iteration 3 the best fitness is 0.05193239952171646']
# ['At iteration 4 the best fitness is 0.05193239952171646']
# ['At iteration 5 the best fitness is 0.051697131764602416']
# ['At iteration 6 the best fitness is 0.051697131764602416']
# ['At iteration 7 the best fitness is 0.051697131764602416']
# ['At iteration 8 the best fitness is 0.05154028659319305']
# ['At iteration 9 the best fitness is 0.051305018836079']
# ['At iteration 10 the best fitness is 0.051305018836079']
# ['At iteration 11 the best fitness is 0.051305018836079']
# ['At iteration 12 the best fitness is 0.051305018836079']
# ['At iteration 13 the best fitness is 0.051305018836079']
# ['At iteration 14 the best fitness is 0.051305018836079']
# ['At iteration 15 the best fitness is 0.051305018836079']
# ['At iteration 16 the best fitness is 0.051305018836079']
# ['At iteration 17 the best fitness is 0.051305018836079']
# ['At iteration 18 the best fitness is 0.051305018836079']
# ['At iteration 19 the best fitness is 0.051305018836079']
# ['At iteration 20 the best fitness is 0.051305018836079']
# ['At iteration 21 the best fitness is 0.051305018836079']
# ['At iteration 22 the best fitness is 0.051305018836079']
# ['At iteration 23 the best fitness is 0.051305018836079']
# ['At iteration 24 the best fitness is 0.043098707754936225']
# ['At iteration 25 the best fitness is 0.043098707754936225']
# ['At iteration 26 the best fitness is 0.043098707754936225']
# ['At iteration 27 the best fitness is 0.043098707754936225']
# ['At iteration 28 the best fitness is 0.043098707754936225']
# ['At iteration 29 the best fitness is 0.043098707754936225']
#       Selected: 2262/4463 (50.7%), Fitness: 0.0431, Time: 3416.6s
#       Modality: D=51%, S=53%, Sk=49%, V=52%
#     Test Acc: 94.39%, F1: 92.95%, Features: 2262/4463 (50.7%), Model: 4.959MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06884916687781782']
# ['At iteration 1 the best fitness is 0.06884916687781782']
# ['At iteration 2 the best fitness is 0.0686475088002915']
# ['At iteration 3 the best fitness is 0.0686475088002915']
# ['At iteration 4 the best fitness is 0.0686475088002915']
# ['At iteration 5 the best fitness is 0.0686475088002915']
# ['At iteration 6 the best fitness is 0.0686475088002915']
# ['At iteration 7 the best fitness is 0.0686475088002915']
# ['At iteration 8 the best fitness is 0.0686475088002915']
# ['At iteration 9 the best fitness is 0.0686475088002915']
# ['At iteration 10 the best fitness is 0.0686475088002915']
# ['At iteration 11 the best fitness is 0.0680872427707778']
# ['At iteration 12 the best fitness is 0.0680872427707778']
# ['At iteration 13 the best fitness is 0.06122531887314388']
# ['At iteration 14 the best fitness is 0.05363518525110934']
# ['At iteration 15 the best fitness is 0.05363518525110934']
# ['At iteration 16 the best fitness is 0.05363518525110934']
# ['At iteration 17 the best fitness is 0.05363518525110934']
# ['At iteration 18 the best fitness is 0.044969541882267705']
# ['At iteration 19 the best fitness is 0.044969541882267705']
# ['At iteration 20 the best fitness is 0.044969541882267705']
# ['At iteration 21 the best fitness is 0.044969541882267705']
# ['At iteration 22 the best fitness is 0.044969541882267705']
# ['At iteration 23 the best fitness is 0.044969541882267705']
# ['At iteration 24 the best fitness is 0.044969541882267705']
# ['At iteration 25 the best fitness is 0.044969541882267705']
# ['At iteration 26 the best fitness is 0.044969541882267705']
# ['At iteration 27 the best fitness is 0.044969541882267705']
# ['At iteration 28 the best fitness is 0.044969541882267705']
# ['At iteration 29 the best fitness is 0.044969541882267705']
#       Selected: 844/4463 (18.9%), Fitness: 0.0450, Time: 1050.7s
#       Modality: D=17%, S=20%, Sk=18%, V=20%
#     Test Acc: 89.72%, F1: 87.76%, Features: 844/4463 (18.9%), Model: 2.190MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          92.592593         96.261682     92.419165
# 1  baseline     2          82.407407         96.261682     79.877674
# 2  baseline     3          89.814815         98.130841     89.704185
# 3  baseline     4          90.740741         96.261682     90.099941
# 4  baseline     5          80.555556         94.392523     78.707601
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        92.419165            94.382716         92.592593               4463
# 1        79.877674            82.109053         82.407407               4463
# 2        89.704185            92.795414         89.814815               4463
# 3        90.099941            93.950617         90.740741               4463
# 4        78.707601            85.007914         80.555556               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              88.74              4.72              87.83              5.43                 4463.00                      100.00              0.00                25.82                25.82          2425371.0                  9.26                        0.00               72.33
# mutual_info              91.29              2.61              90.64              2.79                 2231.00                       49.99             57.45                20.84                78.30          1282587.0                  4.90                       50.01               45.90
#         rfe              90.95              4.05              90.39              4.36                 2231.00                       49.99             10.76                20.22                30.98          1282587.0                  4.90                       50.01               45.90
#       lasso              72.61             14.51              70.17             15.48                 2231.00                       49.99             98.31                19.74               118.05          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              84.11              9.15              83.42              9.44                 2212.62                       49.58           1394.56                22.44              1417.00          1273179.0                  4.86                       50.42               45.76
#     meta_CS              83.65             12.19              83.27             12.38                 2177.00                       48.78           2776.13                22.41              2798.53          1254939.0                  4.79                       51.22               45.48
#     meta_DE              87.35              4.31              86.45              5.00                 2191.50                       49.10           1407.73                22.45              1430.18          1262363.0                  4.82                       50.90               45.60
#    meta_FFA              86.42              5.00              85.34              6.30                 2209.00                       49.50           1361.04                22.46              1383.50          1271323.0                  4.86                       50.50               45.74
#     meta_GA              84.10              7.04              82.54              8.53                 2212.75                       49.58           1361.05                22.30              1383.35          1273243.0                  4.86                       50.42               45.78
#    meta_GWO              84.45              5.63              83.14              6.97                 1873.12                       41.97           1299.26                20.63              1319.90          1099355.0                  4.20                       58.03               42.09
#    meta_HHO              87.23              5.20              86.31              6.14                 1879.12                       42.10           1762.39                21.53              1783.92          1102427.0                  4.21                       57.90               42.08
#   meta_JAYA              84.69              8.36              83.30              9.54                 2238.62                       50.16           1407.95                22.60              1430.54          1286491.0                  4.91                       49.84               46.04
#    meta_MFO              85.39              8.74              84.15              9.85                 2239.25                       50.17           1330.10                22.55              1352.65          1286811.0                  4.91                       49.83               46.04
#    meta_MVO              88.39              4.38              87.60              4.51                 2207.62                       49.47           1366.61                22.46              1389.07          1270619.0                  4.85                       50.53               45.72
#    meta_PSO              86.08              6.98              85.10              7.76                 2196.38                       49.21           1349.58                21.81              1371.39          1264859.0                  4.83                       50.79               45.64
#    meta_SCA              83.65             14.36              82.93             14.69                 1131.50                       25.35           1184.82                19.08              1203.90           719643.0                  2.75                       74.65               33.39
#    meta_SSA              87.23              5.36              86.33              5.49                 2212.12                       49.57           3398.05                22.39              3420.45          1272923.0                  4.86                       50.43               45.77
#    meta_WOA              85.26              7.91              84.01              9.01                 1829.38                       40.99           1258.72                20.52              1279.24          1076955.0                  4.11                       59.01               41.29

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_WOA
#     F1 Macro:           91.77%
#     F1 Weighted:        91.77%
#     Test Accuracy:      92.59%
#     Feature Retention:  57.92% (2585/4463)
#     Modality Retention: depth=58.2%, sensor=58.3%, skeleton=57.1%, video=58.8%
#
#   Fold 2: Best = meta_DE
#     F1 Macro:           88.00%
#     F1 Weighted:        88.00%
#     Test Accuracy:      88.89%
#     Feature Retention:  50.37% (2248/4463)
#     Modality Retention: depth=51.4%, sensor=49.2%, skeleton=50.5%, video=50.4%
#
#   Fold 3: Best = meta_HHO
#     F1 Macro:           88.57%
#     F1 Weighted:        88.57%
#     Test Accuracy:      88.89%
#     Feature Retention:  63.28% (2824/4463)
#     Modality Retention: depth=62.1%, sensor=63.7%, skeleton=63.4%, video=63.4%
#
#   Fold 4: Best = meta_SSA
#     F1 Macro:           92.47%
#     F1 Weighted:        92.47%
#     Test Accuracy:      92.59%
#     Feature Retention:  49.29% (2200/4463)
#     Modality Retention: depth=50.8%, sensor=50.2%, skeleton=48.0%, video=50.1%
#
#   Fold 5: Best = meta_MVO
#     F1 Macro:           89.24%
#     F1 Weighted:        89.24%
#     Test Accuracy:      90.74%
#     Feature Retention:  48.89% (2182/4463)
#     Modality Retention: depth=49.4%, sensor=49.4%, skeleton=48.3%, video=49.3%
#
#   Fold 6: Best = meta_JAYA
#     F1 Macro:           91.79%
#     F1 Weighted:        91.72%
#     Test Accuracy:      92.52%
#     Feature Retention:  50.26% (2243/4463)
#     Modality Retention: depth=48.6%, sensor=51.1%, skeleton=51.6%, video=48.7%
#
#   Fold 7: Best = meta_WOA
#     F1 Macro:           93.47%
#     F1 Weighted:        93.41%
#     Test Accuracy:      93.46%
#     Feature Retention:  57.45% (2564/4463)
#     Modality Retention: depth=62.1%, sensor=56.1%, skeleton=57.2%, video=56.8%
#
#   Fold 8: Best = meta_MVO
#     F1 Macro:           96.79%
#     F1 Weighted:        96.95%
#     Test Accuracy:      97.20%
#     Feature Retention:  50.10% (2236/4463)
#     Modality Retention: depth=48.0%, sensor=49.8%, skeleton=50.6%, video=50.3%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 91.51% ± 2.90%
#
#   Average F1 Weighted         : 91.52% ± 2.93%
#
#   Average Test Accuracy       : 92.11% ± 2.70%
#
#   Average Feature Retention   : 53.44% ± 5.37%
#
#   Average Modality-wise Feature Retention:
#            depth: 53.83% ± 5.99%
#           sensor: 53.47% ± 5.32%
#         skeleton: 53.31% ± 5.38%
#            video: 53.48% ± 5.45%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1           meta_WOA         91.77            91.77              92.59                  57.92              58.20               58.28                 57.05              58.80
#     2            meta_DE         88.00            88.00              88.89                  50.37              51.37               49.23                 50.45              50.42
#     3           meta_HHO         88.57            88.57              88.89                  63.28              62.11               63.65                 63.38              63.38
#     4           meta_SSA         92.47            92.47              92.59                  49.29              50.78               50.15                 47.95              50.14
#     5           meta_MVO         89.24            89.24              90.74                  48.89              49.41               49.39                 48.27              49.30
#     6          meta_JAYA         91.79            91.72              92.52                  50.26              48.63               51.07                 51.57              48.73
#     7           meta_WOA         93.47            93.41              93.46                  57.45              62.11               56.13                 57.16              56.76
#     8           meta_MVO         96.79            96.95              97.20                  50.10              48.05               49.85                 50.61              50.28
#
# Saved to: results_loss_10/best_metaheuristic_per_fold.csv
