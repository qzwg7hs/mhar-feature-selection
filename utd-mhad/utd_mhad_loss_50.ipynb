# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_loss_50")

# Master output directory
RESULTS_ROOT = Path("results_loss_50")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

# FEATURE_DIMS will be set dynamically per-fold after PCA
# (depth dim changes if PCA is applied)
print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 72.22%, F1: 72.28%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 61.4s
#     Test Acc: 73.15%, F1: 72.96%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.0s
#     Test Acc: 72.22%, F1: 70.32%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 8.4s
#     Test Acc: 53.70%, F1: 53.35%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.21109569649517007']
# ['At iteration 1 the best fitness is 0.20254208539162083']
# ['At iteration 2 the best fitness is 0.20254208539162083']
# ['At iteration 3 the best fitness is 0.20254208539162083']
# ['At iteration 4 the best fitness is 0.20254208539162083']
# ['At iteration 5 the best fitness is 0.18472905991318023']
# ['At iteration 6 the best fitness is 0.18472905991318023']
# ['At iteration 7 the best fitness is 0.18472905991318023']
# ['At iteration 8 the best fitness is 0.18472905991318023']
# ['At iteration 9 the best fitness is 0.18472905991318023']
# ['At iteration 10 the best fitness is 0.18472905991318023']
# ['At iteration 11 the best fitness is 0.18472905991318023']
# ['At iteration 12 the best fitness is 0.18472905991318023']
# ['At iteration 13 the best fitness is 0.18472905991318023']
# ['At iteration 14 the best fitness is 0.18472905991318023']
# ['At iteration 15 the best fitness is 0.18472905991318023']
# ['At iteration 16 the best fitness is 0.18472905991318023']
# ['At iteration 17 the best fitness is 0.18472905991318023']
# ['At iteration 18 the best fitness is 0.18472905991318023']
# ['At iteration 19 the best fitness is 0.18472905991318023']
# ['At iteration 20 the best fitness is 0.18472905991318023']
# ['At iteration 21 the best fitness is 0.18472905991318023']
# ['At iteration 22 the best fitness is 0.18472905991318023']
# ['At iteration 23 the best fitness is 0.18472905991318023']
# ['At iteration 24 the best fitness is 0.18472905991318023']
# ['At iteration 25 the best fitness is 0.18472905991318023']
# ['At iteration 26 the best fitness is 0.18472905991318023']
# ['At iteration 27 the best fitness is 0.18472905991318023']
# ['At iteration 28 the best fitness is 0.18472905991318023']
# ['At iteration 29 the best fitness is 0.18472905991318023']
#       Selected: 2224/4463 (49.8%), Fitness: 0.1847, Time: 1281.4s
#       Modality: D=49%, S=52%, Sk=49%, V=50%
#     Test Acc: 72.22%, F1: 72.27%, Features: 2224/4463 (49.8%), Model: 4.885MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.20268772733650098']
# ['At iteration 1 the best fitness is 0.20268772733650098']
# ['At iteration 2 the best fitness is 0.18484109217847264']
# ['At iteration 3 the best fitness is 0.18484109217847264']
# ['At iteration 4 the best fitness is 0.18484109217847264']
# ['At iteration 5 the best fitness is 0.18484109217847264']
# ['At iteration 6 the best fitness is 0.18484109217847264']
# ['At iteration 7 the best fitness is 0.18484109217847264']
# ['At iteration 8 the best fitness is 0.18484109217847264']
# ['At iteration 9 the best fitness is 0.18484109217847264']
# ['At iteration 10 the best fitness is 0.18484109217847264']
# ['At iteration 11 the best fitness is 0.18397844373572111']
# ['At iteration 12 the best fitness is 0.18397844373572111']
# ['At iteration 13 the best fitness is 0.18397844373572111']
# ['At iteration 14 the best fitness is 0.18397844373572111']
# ['At iteration 15 the best fitness is 0.18397844373572111']
# ['At iteration 16 the best fitness is 0.18397844373572111']
# ['At iteration 17 the best fitness is 0.18397844373572111']
# ['At iteration 18 the best fitness is 0.18397844373572111']
# ['At iteration 19 the best fitness is 0.18397844373572111']
# ['At iteration 20 the best fitness is 0.18397844373572111']
# ['At iteration 21 the best fitness is 0.18397844373572111']
# ['At iteration 22 the best fitness is 0.18397844373572111']
# ['At iteration 23 the best fitness is 0.18397844373572111']
# ['At iteration 24 the best fitness is 0.18397844373572111']
# ['At iteration 25 the best fitness is 0.18397844373572111']
# ['At iteration 26 the best fitness is 0.18397844373572111']
# ['At iteration 27 the best fitness is 0.18397844373572111']
# ['At iteration 28 the best fitness is 0.18397844373572111']
# ['At iteration 29 the best fitness is 0.18397844373572111']
#       Selected: 2157/4463 (48.3%), Fitness: 0.1840, Time: 2766.8s
#       Modality: D=48%, S=46%, Sk=49%, V=49%
#     Test Acc: 70.37%, F1: 68.92%, Features: 2157/4463 (48.3%), Model: 4.754MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2204335334557661']
# ['At iteration 2 the best fitness is 0.2204335334557661']
# ['At iteration 3 the best fitness is 0.22025428183129828']
# ['At iteration 4 the best fitness is 0.22025428183129828']
# ['At iteration 5 the best fitness is 0.22000781084765497']
# ['At iteration 6 the best fitness is 0.21139818361145957']
# ['At iteration 7 the best fitness is 0.21139818361145957']
# ['At iteration 8 the best fitness is 0.21139818361145957']
# ['At iteration 9 the best fitness is 0.21139818361145957']
# ['At iteration 10 the best fitness is 0.21139818361145957']
# ['At iteration 11 the best fitness is 0.2108828351911145']
# ['At iteration 12 the best fitness is 0.20263171120385476']
# ['At iteration 13 the best fitness is 0.20263171120385476']
# ['At iteration 14 the best fitness is 0.20263171120385476']
# ['At iteration 15 the best fitness is 0.20263171120385476']
# ['At iteration 16 the best fitness is 0.20263171120385476']
# ['At iteration 17 the best fitness is 0.18465063732747555']
# ['At iteration 18 the best fitness is 0.18465063732747555']
# ['At iteration 19 the best fitness is 0.18465063732747555']
# ['At iteration 20 the best fitness is 0.18465063732747555']
# ['At iteration 21 the best fitness is 0.18465063732747555']
# ['At iteration 22 the best fitness is 0.18465063732747555']
# ['At iteration 23 the best fitness is 0.18419130503977668']
# ['At iteration 24 the best fitness is 0.18419130503977668']
# ['At iteration 25 the best fitness is 0.18419130503977668']
# ['At iteration 26 the best fitness is 0.18419130503977668']
# ['At iteration 27 the best fitness is 0.18419130503977668']
# ['At iteration 28 the best fitness is 0.18419130503977668']
# ['At iteration 29 the best fitness is 0.18419130503977668']
# ['At iteration 30 the best fitness is 0.18419130503977668']
#       Selected: 2176/4463 (48.8%), Fitness: 0.1842, Time: 1404.7s
#       Modality: D=48%, S=50%, Sk=49%, V=49%
#     Test Acc: 66.67%, F1: 64.75%, Features: 2176/4463 (48.8%), Model: 4.791MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2286174380838504']
# ['At iteration 1 the best fitness is 0.20193711115904187']
# ['At iteration 2 the best fitness is 0.1932378581106125']
# ['At iteration 3 the best fitness is 0.2200638269803012']
# ['At iteration 4 the best fitness is 0.2110172739094654']
# ['At iteration 5 the best fitness is 0.19302499680655694']
# ['At iteration 6 the best fitness is 0.22888631552055216']
# ['At iteration 7 the best fitness is 0.22000781084765497']
# ['At iteration 8 the best fitness is 0.21061395775441272']
# ['At iteration 9 the best fitness is 0.21995179471500878']
# ['At iteration 10 the best fitness is 0.21985096567624562']
# ['At iteration 11 the best fitness is 0.2110732900421116']
# ['At iteration 12 the best fitness is 0.2375295524363353']
# ['At iteration 13 the best fitness is 0.2463184312969986']
# ['At iteration 14 the best fitness is 0.23738391049145519']
# ['At iteration 15 the best fitness is 0.228505405818558']
# ['At iteration 16 the best fitness is 0.2462848216174109']
# ['At iteration 17 the best fitness is 0.24635204097658633']
# ['At iteration 18 the best fitness is 0.21969412050483625']
# ['At iteration 19 the best fitness is 0.24630722807046937']
# ['At iteration 20 the best fitness is 0.23742872339757215']
# ['At iteration 21 the best fitness is 0.23750714598327682']
# ['At iteration 22 the best fitness is 0.24637444742964482']
# ['At iteration 23 the best fitness is 0.23751834920980608']
# ['At iteration 24 the best fitness is 0.21087163196458525']
# ['At iteration 25 the best fitness is 0.2197389334109532']
# ['At iteration 26 the best fitness is 0.21975013663748244']
# ['At iteration 27 the best fitness is 0.24636324420311556']
# ['At iteration 28 the best fitness is 0.23747353630368911']
# ['At iteration 29 the best fitness is 0.23748473953021834']
#       Selected: 2178/4463 (48.8%), Fitness: 0.2375, Time: 1356.9s
#       Modality: D=51%, S=48%, Sk=49%, V=49%
#     Test Acc: 66.67%, F1: 65.13%, Features: 2178/4463 (48.8%), Model: 4.795MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.2118799223522169
# At iteration 2 the best fitness is 0.21163345136857362
# At iteration 3 the best fitness is 0.21176789008692448
# At iteration 4 the best fitness is 0.2024972724855039
# At iteration 5 the best fitness is 0.2301410768918271
# At iteration 6 the best fitness is 0.22066880121288016
# At iteration 7 the best fitness is 0.22893112842666913
# At iteration 8 the best fitness is 0.22933444458172178
# At iteration 9 the best fitness is 0.22047834636188307
# At iteration 10 the best fitness is 0.22034390764353218
# At iteration 11 the best fitness is 0.22047834636188307
# At iteration 12 the best fitness is 0.2380224944036219
# At iteration 13 the best fitness is 0.21192473525833386
# At iteration 14 the best fitness is 0.21166706104816133
# At iteration 15 the best fitness is 0.23814572989544353
# At iteration 16 the best fitness is 0.2205119560414708
# At iteration 17 the best fitness is 0.20254208539162083
# At iteration 18 the best fitness is 0.2018362821202787
# At iteration 19 the best fitness is 0.21198075139098005
# At iteration 20 the best fitness is 0.21170067072774906
# At iteration 21 the best fitness is 0.20268772733650098
# At iteration 22 the best fitness is 0.2115214191032812
# At iteration 23 the best fitness is 0.2026989305630302
# At iteration 24 the best fitness is 0.21149901265022272
# At iteration 25 the best fitness is 0.20310224671808286
# At iteration 26 the best fitness is 0.20276614992220565
# At iteration 27 the best fitness is 0.20303502735890744
# At iteration 28 the best fitness is 0.19360756458607745
# At iteration 29 the best fitness is 0.21129735457269638
# At iteration 30 the best fitness is 0.2200414205272427
#       Selected: 2206/4463 (49.4%), Fitness: 0.2200, Time: 1362.0s
#       Modality: D=47%, S=49%, Sk=50%, V=50%
#     Test Acc: 68.52%, F1: 66.89%, Features: 2206/4463 (49.4%), Model: 4.850MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.20312465317114134']
# ['At iteration 1 the best fitness is 0.20312465317114134']
# ['At iteration 2 the best fitness is 0.20312465317114134']
# ['At iteration 3 the best fitness is 0.20312465317114134']
# ['At iteration 4 the best fitness is 0.20312465317114134']
# ['At iteration 5 the best fitness is 0.20312465317114134']
# ['At iteration 6 the best fitness is 0.20312465317114134']
# ['At iteration 7 the best fitness is 0.20312465317114134']
# ['At iteration 8 the best fitness is 0.1997860916654277']
# ['At iteration 9 the best fitness is 0.18254443073997834']
# ['At iteration 10 the best fitness is 0.18254443073997834']
# ['At iteration 11 the best fitness is 0.18254443073997834']
# ['At iteration 12 the best fitness is 0.18254443073997834']
# ['At iteration 13 the best fitness is 0.18254443073997834']
# ['At iteration 14 the best fitness is 0.18254443073997834']
# ['At iteration 15 the best fitness is 0.18254443073997834']
# ['At iteration 16 the best fitness is 0.18254443073997834']
# ['At iteration 17 the best fitness is 0.18254443073997834']
# ['At iteration 18 the best fitness is 0.18254443073997834']
# ['At iteration 19 the best fitness is 0.17328501636508697']
# ['At iteration 20 the best fitness is 0.17328501636508697']
# ['At iteration 21 the best fitness is 0.17328501636508697']
# ['At iteration 22 the best fitness is 0.17328501636508697']
# ['At iteration 23 the best fitness is 0.17328501636508697']
# ['At iteration 24 the best fitness is 0.17328501636508697']
# ['At iteration 25 the best fitness is 0.17328501636508697']
# ['At iteration 26 the best fitness is 0.17328501636508697']
# ['At iteration 27 the best fitness is 0.17328501636508697']
# ['At iteration 28 the best fitness is 0.17328501636508697']
# ['At iteration 29 the best fitness is 0.17328501636508697']
#       Selected: 1995/4463 (44.7%), Fitness: 0.1733, Time: 1316.5s
#       Modality: D=46%, S=49%, Sk=44%, V=43%
#     Test Acc: 66.67%, F1: 66.27%, Features: 1995/4463 (44.7%), Model: 4.438MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.20320307575684604']
# ['At iteration 1 the best fitness is 0.20320307575684604']
# ['At iteration 2 the best fitness is 0.20320307575684604']
# ['At iteration 3 the best fitness is 0.20320307575684604']
# ['At iteration 4 the best fitness is 0.20320307575684604']
# ['At iteration 5 the best fitness is 0.20320307575684604']
# ['At iteration 6 the best fitness is 0.19304185399787663']
# ['At iteration 7 the best fitness is 0.19304185399787663']
# ['At iteration 8 the best fitness is 0.19304185399787663']
# ['At iteration 9 the best fitness is 0.19304185399787663']
# ['At iteration 10 the best fitness is 0.19304185399787663']
# ['At iteration 11 the best fitness is 0.19304185399787663']
# ['At iteration 12 the best fitness is 0.19304185399787663']
# ['At iteration 13 the best fitness is 0.19304185399787663']
# ['At iteration 14 the best fitness is 0.19304185399787663']
# ['At iteration 15 the best fitness is 0.19304185399787663']
# ['At iteration 16 the best fitness is 0.19304185399787663']
# ['At iteration 17 the best fitness is 0.19304185399787663']
# ['At iteration 18 the best fitness is 0.19304185399787663']
# ['At iteration 19 the best fitness is 0.19304185399787663']
# ['At iteration 20 the best fitness is 0.19304185399787663']
# ['At iteration 21 the best fitness is 0.19304185399787663']
# ['At iteration 22 the best fitness is 0.19304185399787663']
# ['At iteration 23 the best fitness is 0.19304185399787663']
# ['At iteration 24 the best fitness is 0.19304185399787663']
# ['At iteration 25 the best fitness is 0.19304185399787663']
# ['At iteration 26 the best fitness is 0.18416334932497944']
# ['At iteration 27 the best fitness is 0.18416334932497944']
# ['At iteration 28 the best fitness is 0.18416334932497944']
# ['At iteration 29 the best fitness is 0.18416334932497944']
#       Selected: 2966/4463 (66.5%), Fitness: 0.1842, Time: 1864.8s
#       Modality: D=68%, S=63%, Sk=66%, V=67%
#     Test Acc: 69.44%, F1: 68.65%, Features: 2966/4463 (66.5%), Model: 6.334MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.21098366422987766']
# ['At iteration 1 the best fitness is 0.18450499538259543']
# ['At iteration 2 the best fitness is 0.18450499538259543']
# ['At iteration 3 the best fitness is 0.18450499538259543']
# ['At iteration 4 the best fitness is 0.18450499538259543']
# ['At iteration 5 the best fitness is 0.18450499538259543']
# ['At iteration 6 the best fitness is 0.18450499538259543']
# ['At iteration 7 the best fitness is 0.18450499538259543']
# ['At iteration 8 the best fitness is 0.18450499538259543']
# ['At iteration 9 the best fitness is 0.16675918926333028']
# ['At iteration 10 the best fitness is 0.16675918926333028']
# ['At iteration 11 the best fitness is 0.16675918926333028']
# ['At iteration 12 the best fitness is 0.16675918926333028']
# ['At iteration 13 the best fitness is 0.1667367828102718']
# ['At iteration 14 the best fitness is 0.1667367828102718']
# ['At iteration 15 the best fitness is 0.1667367828102718']
# ['At iteration 16 the best fitness is 0.1667367828102718']
# ['At iteration 17 the best fitness is 0.1667367828102718']
# ['At iteration 18 the best fitness is 0.1667367828102718']
# ['At iteration 19 the best fitness is 0.1667367828102718']
# ['At iteration 20 the best fitness is 0.1667367828102718']
# ['At iteration 21 the best fitness is 0.1667367828102718']
# ['At iteration 22 the best fitness is 0.1667367828102718']
# ['At iteration 23 the best fitness is 0.1667367828102718']
# ['At iteration 24 the best fitness is 0.1667367828102718']
# ['At iteration 25 the best fitness is 0.1667367828102718']
# ['At iteration 26 the best fitness is 0.1667367828102718']
# ['At iteration 27 the best fitness is 0.1667367828102718']
# ['At iteration 28 the best fitness is 0.1667367828102718']
# ['At iteration 29 the best fitness is 0.1667367828102718']
#       Selected: 2203/4463 (49.4%), Fitness: 0.1667, Time: 1392.8s
#       Modality: D=52%, S=49%, Sk=49%, V=49%
#     Test Acc: 62.04%, F1: 60.93%, Features: 2203/4463 (49.4%), Model: 4.844MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.21142059006451802']
# ['At iteration 2 the best fitness is 0.21142059006451802']
# ['At iteration 3 the best fitness is 0.21142059006451802']
# ['At iteration 4 the best fitness is 0.21142059006451802']
# ['At iteration 5 the best fitness is 0.21142059006451802']
# ['At iteration 6 the best fitness is 0.20325909188949223']
# ['At iteration 7 the best fitness is 0.1941229130064225']
# ['At iteration 8 the best fitness is 0.1941229130064225']
# ['At iteration 9 the best fitness is 0.1941229130064225']
# ['At iteration 10 the best fitness is 0.1941229130064225']
# ['At iteration 11 the best fitness is 0.1941229130064225']
# ['At iteration 12 the best fitness is 0.1941229130064225']
# ['At iteration 13 the best fitness is 0.1941229130064225']
# ['At iteration 14 the best fitness is 0.1941229130064225']
# ['At iteration 15 the best fitness is 0.1941229130064225']
# ['At iteration 16 the best fitness is 0.1941229130064225']
# ['At iteration 17 the best fitness is 0.1758953681464']
# ['At iteration 18 the best fitness is 0.1758953681464']
# ['At iteration 19 the best fitness is 0.1758953681464']
# ['At iteration 20 the best fitness is 0.1758953681464']
# ['At iteration 21 the best fitness is 0.1758953681464']
# ['At iteration 22 the best fitness is 0.16702806670003206']
# ['At iteration 23 the best fitness is 0.16702806670003206']
# ['At iteration 24 the best fitness is 0.16702806670003206']
# ['At iteration 25 the best fitness is 0.16702806670003206']
# ['At iteration 26 the best fitness is 0.16702806670003206']
# ['At iteration 27 the best fitness is 0.16702806670003206']
# ['At iteration 28 the best fitness is 0.16702806670003206']
# ['At iteration 29 the best fitness is 0.16702806670003206']
#       Selected: 2229/4463 (49.9%), Fitness: 0.1670, Time: 1328.7s
#       Modality: D=51%, S=51%, Sk=49%, V=51%
#     Test Acc: 70.37%, F1: 69.27%, Features: 2229/4463 (49.9%), Model: 4.895MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.20256449184467934']
# ['At iteration 2 the best fitness is 0.20256449184467934']
# ['At iteration 3 the best fitness is 0.15807113944143017']
# ['At iteration 4 the best fitness is 0.15807113944143017']
# ['At iteration 5 the best fitness is 0.15807113944143017']
# ['At iteration 6 the best fitness is 0.15807113944143017']
# ['At iteration 7 the best fitness is 0.15807113944143017']
# ['At iteration 8 the best fitness is 0.15807113944143017']
# ['At iteration 9 the best fitness is 0.15807113944143017']
# ['At iteration 10 the best fitness is 0.15807113944143017']
# ['At iteration 11 the best fitness is 0.15807113944143017']
# ['At iteration 12 the best fitness is 0.15807113944143017']
# ['At iteration 13 the best fitness is 0.15807113944143017']
# ['At iteration 14 the best fitness is 0.15807113944143017']
# ['At iteration 15 the best fitness is 0.15807113944143017']
# ['At iteration 16 the best fitness is 0.15807113944143017']
# ['At iteration 17 the best fitness is 0.15807113944143017']
# ['At iteration 18 the best fitness is 0.15807113944143017']
# ['At iteration 19 the best fitness is 0.15807113944143017']
# ['At iteration 20 the best fitness is 0.15807113944143017']
# ['At iteration 21 the best fitness is 0.15807113944143017']
# ['At iteration 22 the best fitness is 0.15807113944143017']
# ['At iteration 23 the best fitness is 0.15807113944143017']
# ['At iteration 24 the best fitness is 0.15807113944143017']
# ['At iteration 25 the best fitness is 0.15807113944143017']
# ['At iteration 26 the best fitness is 0.15807113944143017']
# ['At iteration 27 the best fitness is 0.15807113944143017']
# ['At iteration 28 the best fitness is 0.15807113944143017']
# ['At iteration 29 the best fitness is 0.15807113944143017']
# ['At iteration 30 the best fitness is 0.15807113944143017']
#       Selected: 2222/4463 (49.8%), Fitness: 0.1581, Time: 1366.7s
#       Modality: D=50%, S=53%, Sk=49%, V=50%
#     Test Acc: 62.96%, F1: 61.74%, Features: 2222/4463 (49.8%), Model: 4.881MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2290095510123738']
# ['At iteration 2 the best fitness is 0.2289199252001399']
# ['At iteration 3 the best fitness is 0.21153262232981043']
# ['At iteration 4 the best fitness is 0.2110508835890531']
# ['At iteration 5 the best fitness is 0.2110508835890531']
# ['At iteration 6 the best fitness is 0.2110508835890531']
# ['At iteration 7 the best fitness is 0.2110508835890531']
# ['At iteration 8 the best fitness is 0.2110508835890531']
# ['At iteration 9 the best fitness is 0.2110508835890531']
# ['At iteration 10 the best fitness is 0.19339470328202188']
# ['At iteration 11 the best fitness is 0.1933162806963172']
# ['At iteration 12 the best fitness is 0.1933162806963172']
# ['At iteration 13 the best fitness is 0.18448258892953695']
# ['At iteration 14 the best fitness is 0.18448258892953695']
# ['At iteration 15 the best fitness is 0.18448258892953695']
# ['At iteration 16 the best fitness is 0.18448258892953695']
# ['At iteration 17 the best fitness is 0.18448258892953695']
# ['At iteration 18 the best fitness is 0.18448258892953695']
# ['At iteration 19 the best fitness is 0.18448258892953695']
# ['At iteration 20 the best fitness is 0.18448258892953695']
# ['At iteration 21 the best fitness is 0.18448258892953695']
# ['At iteration 22 the best fitness is 0.18448258892953695']
# ['At iteration 23 the best fitness is 0.18448258892953695']
# ['At iteration 24 the best fitness is 0.18448258892953695']
# ['At iteration 25 the best fitness is 0.18448258892953695']
# ['At iteration 26 the best fitness is 0.18448258892953695']
# ['At iteration 27 the best fitness is 0.18448258892953695']
# ['At iteration 28 the best fitness is 0.18448258892953695']
# ['At iteration 29 the best fitness is 0.18448258892953695']
# ['At iteration 30 the best fitness is 0.18448258892953695']
#       Selected: 2202/4463 (49.3%), Fitness: 0.1845, Time: 1354.6s
#       Modality: D=46%, S=52%, Sk=49%, V=50%
#     Test Acc: 67.59%, F1: 66.46%, Features: 2202/4463 (49.3%), Model: 4.842MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2114878094236935']
# ['At iteration 1 the best fitness is 0.2114878094236935']
# ['At iteration 2 the best fitness is 0.2083621092220354']
# ['At iteration 3 the best fitness is 0.2083621092220354']
# ['At iteration 4 the best fitness is 0.2083621092220354']
# ['At iteration 5 the best fitness is 0.20469865414697377']
# ['At iteration 6 the best fitness is 0.20469865414697377']
# ['At iteration 7 the best fitness is 0.18447693496474651']
# ['At iteration 8 the best fitness is 0.18447693496474651']
# ['At iteration 9 the best fitness is 0.18290848325065284']
# ['At iteration 10 the best fitness is 0.16400874479887592']
# ['At iteration 11 the best fitness is 0.16400874479887592']
# ['At iteration 12 the best fitness is 0.16400874479887592']
# ['At iteration 13 the best fitness is 0.16400874479887592']
# ['At iteration 14 the best fitness is 0.16400874479887592']
# ['At iteration 15 the best fitness is 0.16400874479887592']
# ['At iteration 16 the best fitness is 0.16400874479887592']
# ['At iteration 17 the best fitness is 0.16400874479887592']
# ['At iteration 18 the best fitness is 0.16400874479887592']
# ['At iteration 19 the best fitness is 0.16400874479887592']
# ['At iteration 20 the best fitness is 0.16400874479887592']
# ['At iteration 21 the best fitness is 0.16400874479887592']
# ['At iteration 22 the best fitness is 0.16400874479887592']
# ['At iteration 23 the best fitness is 0.16400874479887592']
# ['At iteration 24 the best fitness is 0.16400874479887592']
# ['At iteration 25 the best fitness is 0.16400874479887592']
# ['At iteration 26 the best fitness is 0.16400874479887592']
# ['At iteration 27 the best fitness is 0.16400874479887592']
# ['At iteration 28 the best fitness is 0.16400874479887592']
# ['At iteration 29 the best fitness is 0.16400874479887592']
#       Selected: 1167/4463 (26.1%), Fitness: 0.1640, Time: 1189.0s
#       Modality: D=25%, S=25%, Sk=26%, V=27%
#     Test Acc: 62.96%, F1: 63.25%, Features: 1167/4463 (26.1%), Model: 2.820MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2115214191032812']
# ['At iteration 2 the best fitness is 0.21136457393187183']
# ['At iteration 3 the best fitness is 0.17581694556069533']
# ['At iteration 4 the best fitness is 0.17581694556069533']
# ['At iteration 5 the best fitness is 0.17581694556069533']
# ['At iteration 6 the best fitness is 0.17581694556069533']
# ['At iteration 7 the best fitness is 0.17581694556069533']
# ['At iteration 8 the best fitness is 0.17581694556069533']
# ['At iteration 9 the best fitness is 0.17581694556069533']
# ['At iteration 10 the best fitness is 0.17581694556069533']
# ['At iteration 11 the best fitness is 0.17581694556069533']
# ['At iteration 12 the best fitness is 0.17581694556069533']
# ['At iteration 13 the best fitness is 0.17581694556069533']
# ['At iteration 14 the best fitness is 0.17581694556069533']
# ['At iteration 15 the best fitness is 0.17581694556069533']
# ['At iteration 16 the best fitness is 0.17581694556069533']
# ['At iteration 17 the best fitness is 0.17581694556069533']
# ['At iteration 18 the best fitness is 0.17581694556069533']
# ['At iteration 19 the best fitness is 0.17581694556069533']
# ['At iteration 20 the best fitness is 0.17581694556069533']
# ['At iteration 21 the best fitness is 0.17581694556069533']
# ['At iteration 22 the best fitness is 0.17581694556069533']
# ['At iteration 23 the best fitness is 0.17581694556069533']
# ['At iteration 24 the best fitness is 0.17581694556069533']
# ['At iteration 25 the best fitness is 0.17581694556069533']
# ['At iteration 26 the best fitness is 0.17581694556069533']
# ['At iteration 27 the best fitness is 0.17581694556069533']
# ['At iteration 28 the best fitness is 0.17581694556069533']
# ['At iteration 29 the best fitness is 0.17581694556069533']
#       Selected: 2221/4463 (49.8%), Fitness: 0.1758, Time: 3360.2s
#       Modality: D=49%, S=52%, Sk=50%, V=49%
#     Test Acc: 66.67%, F1: 62.95%, Features: 2221/4463 (49.8%), Model: 4.879MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.21173428040733677']
# ['At iteration 1 the best fitness is 0.21173428040733677']
# ['At iteration 2 the best fitness is 0.19010095468242522']
# ['At iteration 3 the best fitness is 0.19010095468242522']
# ['At iteration 4 the best fitness is 0.19010095468242522']
# ['At iteration 5 the best fitness is 0.19010095468242522']
# ['At iteration 6 the best fitness is 0.19010095468242522']
# ['At iteration 7 the best fitness is 0.19010095468242522']
# ['At iteration 8 the best fitness is 0.19010095468242522']
# ['At iteration 9 the best fitness is 0.19010095468242522']
# ['At iteration 10 the best fitness is 0.19010095468242522']
# ['At iteration 11 the best fitness is 0.19010095468242522']
# ['At iteration 12 the best fitness is 0.19010095468242522']
# ['At iteration 13 the best fitness is 0.19010095468242522']
# ['At iteration 14 the best fitness is 0.19010095468242522']
# ['At iteration 15 the best fitness is 0.19010095468242522']
# ['At iteration 16 the best fitness is 0.19010095468242522']
# ['At iteration 17 the best fitness is 0.19010095468242522']
# ['At iteration 18 the best fitness is 0.19010095468242522']
# ['At iteration 19 the best fitness is 0.19010095468242522']
# ['At iteration 20 the best fitness is 0.19010095468242522']
# ['At iteration 21 the best fitness is 0.19010095468242522']
# ['At iteration 22 the best fitness is 0.19010095468242522']
# ['At iteration 23 the best fitness is 0.19010095468242522']
# ['At iteration 24 the best fitness is 0.19010095468242522']
# ['At iteration 25 the best fitness is 0.19010095468242522']
# ['At iteration 26 the best fitness is 0.19010095468242522']
# ['At iteration 27 the best fitness is 0.19010095468242522']
# ['At iteration 28 the best fitness is 0.19010095468242522']
# ['At iteration 29 the best fitness is 0.19010095468242522']
#       Selected: 1911/4463 (42.8%), Fitness: 0.1901, Time: 1291.3s
#       Modality: D=47%, S=42%, Sk=42%, V=42%
#     Test Acc: 70.37%, F1: 69.62%, Features: 1911/4463 (42.8%), Model: 4.274MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 77.78%, F1: 75.43%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 56.9s
#     Test Acc: 73.15%, F1: 70.81%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 9.5s
#     Test Acc: 75.93%, F1: 74.46%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 4.2s
#     Test Acc: 60.19%, F1: 57.00%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.18454980828871237']
# ['At iteration 1 the best fitness is 0.18454980828871237']
# ['At iteration 2 the best fitness is 0.17580574233416607']
# ['At iteration 3 the best fitness is 0.16691603443473965']
# ['At iteration 4 the best fitness is 0.16689362798168117']
# ['At iteration 5 the best fitness is 0.16689362798168117']
# ['At iteration 6 the best fitness is 0.16689362798168117']
# ['At iteration 7 the best fitness is 0.16689362798168117']
# ['At iteration 8 the best fitness is 0.16689362798168117']
# ['At iteration 9 the best fitness is 0.14913661863588676']
# ['At iteration 10 the best fitness is 0.14913661863588676']
# ['At iteration 11 the best fitness is 0.14913661863588676']
# ['At iteration 12 the best fitness is 0.14913661863588676']
# ['At iteration 13 the best fitness is 0.14913661863588676']
# ['At iteration 14 the best fitness is 0.14913661863588676']
# ['At iteration 15 the best fitness is 0.14913661863588676']
# ['At iteration 16 the best fitness is 0.14913661863588676']
# ['At iteration 17 the best fitness is 0.14913661863588676']
# ['At iteration 18 the best fitness is 0.14913661863588676']
# ['At iteration 19 the best fitness is 0.14913661863588676']
# ['At iteration 20 the best fitness is 0.14913661863588676']
# ['At iteration 21 the best fitness is 0.14913661863588676']
# ['At iteration 22 the best fitness is 0.14913661863588676']
# ['At iteration 23 the best fitness is 0.14913661863588676']
# ['At iteration 24 the best fitness is 0.14913661863588676']
# ['At iteration 25 the best fitness is 0.14913661863588676']
# ['At iteration 26 the best fitness is 0.14913661863588676']
# ['At iteration 27 the best fitness is 0.14913661863588676']
# ['At iteration 28 the best fitness is 0.14913661863588676']
# ['At iteration 29 the best fitness is 0.14913661863588676']
#       Selected: 2217/4463 (49.7%), Fitness: 0.1491, Time: 1368.8s
#       Modality: D=46%, S=53%, Sk=51%, V=48%
#     Test Acc: 76.85%, F1: 76.10%, Features: 2217/4463 (49.7%), Model: 4.871MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1754584423117596']
# ['At iteration 1 the best fitness is 0.1754584423117596']
# ['At iteration 2 the best fitness is 0.1754584423117596']
# ['At iteration 3 the best fitness is 0.16636707633480685']
# ['At iteration 4 the best fitness is 0.16636707633480685']
# ['At iteration 5 the best fitness is 0.16636707633480685']
# ['At iteration 6 the best fitness is 0.1404821784935744']
# ['At iteration 7 the best fitness is 0.1404821784935744']
# ['At iteration 8 the best fitness is 0.1404821784935744']
# ['At iteration 9 the best fitness is 0.1404821784935744']
# ['At iteration 10 the best fitness is 0.1404821784935744']
# ['At iteration 11 the best fitness is 0.1404821784935744']
# ['At iteration 12 the best fitness is 0.1404821784935744']
# ['At iteration 13 the best fitness is 0.1404821784935744']
# ['At iteration 14 the best fitness is 0.1404821784935744']
# ['At iteration 15 the best fitness is 0.1404821784935744']
# ['At iteration 16 the best fitness is 0.1404821784935744']
# ['At iteration 17 the best fitness is 0.1404821784935744']
# ['At iteration 18 the best fitness is 0.1404821784935744']
# ['At iteration 19 the best fitness is 0.1404821784935744']
# ['At iteration 20 the best fitness is 0.1404821784935744']
# ['At iteration 21 the best fitness is 0.1404821784935744']
# ['At iteration 22 the best fitness is 0.1404821784935744']
# ['At iteration 23 the best fitness is 0.1404821784935744']
# ['At iteration 24 the best fitness is 0.1404821784935744']
# ['At iteration 25 the best fitness is 0.1404821784935744']
# ['At iteration 26 the best fitness is 0.1404821784935744']
# ['At iteration 27 the best fitness is 0.1404821784935744']
# ['At iteration 28 the best fitness is 0.1404821784935744']
# ['At iteration 29 the best fitness is 0.1404821784935744']
#       Selected: 2237/4463 (50.1%), Fitness: 0.1405, Time: 2775.0s
#       Modality: D=51%, S=47%, Sk=50%, V=51%
#     Test Acc: 73.15%, F1: 71.50%, Features: 2237/4463 (50.1%), Model: 4.910MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1760298068647509']
# ['At iteration 2 the best fitness is 0.17574972620151988']
# ['At iteration 3 the best fitness is 0.17554806812399354']
# ['At iteration 4 the best fitness is 0.17554806812399354']
# ['At iteration 5 the best fitness is 0.17554806812399354']
# ['At iteration 6 the best fitness is 0.1669048312082104']
# ['At iteration 7 the best fitness is 0.1669048312082104']
# ['At iteration 8 the best fitness is 0.1669048312082104']
# ['At iteration 9 the best fitness is 0.16663595377150864']
# ['At iteration 10 the best fitness is 0.16663595377150864']
# ['At iteration 11 the best fitness is 0.1582167813863103']
# ['At iteration 12 the best fitness is 0.1582167813863103']
# ['At iteration 13 the best fitness is 0.1582167813863103']
# ['At iteration 14 the best fitness is 0.1582167813863103']
# ['At iteration 15 the best fitness is 0.1582167813863103']
# ['At iteration 16 the best fitness is 0.1582167813863103']
# ['At iteration 17 the best fitness is 0.1582167813863103']
# ['At iteration 18 the best fitness is 0.1582167813863103']
# ['At iteration 19 the best fitness is 0.1582167813863103']
# ['At iteration 20 the best fitness is 0.1582167813863103']
# ['At iteration 21 the best fitness is 0.1582167813863103']
# ['At iteration 22 the best fitness is 0.14876691216042184']
# ['At iteration 23 the best fitness is 0.14876691216042184']
# ['At iteration 24 the best fitness is 0.14876691216042184']
# ['At iteration 25 the best fitness is 0.14876691216042184']
# ['At iteration 26 the best fitness is 0.14876691216042184']
# ['At iteration 27 the best fitness is 0.14876691216042184']
# ['At iteration 28 the best fitness is 0.14876691216042184']
# ['At iteration 29 the best fitness is 0.14876691216042184']
# ['At iteration 30 the best fitness is 0.14876691216042184']
#       Selected: 2184/4463 (48.9%), Fitness: 0.1488, Time: 1410.7s
#       Modality: D=45%, S=48%, Sk=49%, V=50%
#     Test Acc: 74.07%, F1: 73.94%, Features: 2184/4463 (48.9%), Model: 4.807MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.20210515955698047']
# ['At iteration 1 the best fitness is 0.17535761327299645']
# ['At iteration 2 the best fitness is 0.1840792727744843']
# ['At iteration 3 the best fitness is 0.2017802659876325']
# ['At iteration 4 the best fitness is 0.20195951761210035']
# ['At iteration 5 the best fitness is 0.19312582584532012']
# ['At iteration 6 the best fitness is 0.20208275310392199']
# ['At iteration 7 the best fitness is 0.20197072083862957']
# ['At iteration 8 the best fitness is 0.19312582584532012']
# ['At iteration 9 the best fitness is 0.21972773018442396']
# ['At iteration 10 the best fitness is 0.19309221616573238']
# ['At iteration 11 the best fitness is 0.21078200615235132']
# ['At iteration 12 the best fitness is 0.19315943552490783']
# ['At iteration 13 the best fitness is 0.17534641004646723']
# ['At iteration 14 the best fitness is 0.21977254309054092']
# ['At iteration 15 the best fitness is 0.21098366422987766']
# ['At iteration 16 the best fitness is 0.19319304520449554']
# ['At iteration 17 the best fitness is 0.19317063875143708']
# ['At iteration 18 the best fitness is 0.2197389334109532']
# ['At iteration 19 the best fitness is 0.15756699424761436']
# ['At iteration 20 the best fitness is 0.18418010181324745']
# ['At iteration 21 the best fitness is 0.1753128003668795']
# ['At iteration 22 the best fitness is 0.2019483143855711']
# ['At iteration 23 the best fitness is 0.18420250826630594']
# ['At iteration 24 the best fitness is 0.18421371149283516']
# ['At iteration 25 the best fitness is 0.18422491471936442']
# ['At iteration 26 the best fitness is 0.19310341939226164']
# ['At iteration 27 the best fitness is 0.19310341939226164']
# ['At iteration 28 the best fitness is 0.16646790537357004']
# ['At iteration 29 the best fitness is 0.19310341939226164']
#       Selected: 2179/4463 (48.8%), Fitness: 0.1931, Time: 1357.3s
#       Modality: D=46%, S=51%, Sk=49%, V=49%
#     Test Acc: 76.85%, F1: 74.92%, Features: 2179/4463 (48.8%), Model: 4.797MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.14924865090117917
# At iteration 2 the best fitness is 0.15828400074548574
# At iteration 3 the best fitness is 0.19341710973508036
# At iteration 4 the best fitness is 0.17651154560550822
# At iteration 5 the best fitness is 0.16716250541838293
# At iteration 6 the best fitness is 0.18438175989077377
# At iteration 7 the best fitness is 0.1760298068647509
# At iteration 8 the best fitness is 0.14003404943240477
# At iteration 9 the best fitness is 0.15828400074548574
# At iteration 10 the best fitness is 0.15801512330878398
# At iteration 11 the best fitness is 0.16722972477755838
# At iteration 12 the best fitness is 0.1309986995880982
# At iteration 13 the best fitness is 0.15835122010466118
# At iteration 14 the best fitness is 0.15798151362919627
# At iteration 15 the best fitness is 0.17561528748316899
# At iteration 16 the best fitness is 0.14932707348688384
# At iteration 17 the best fitness is 0.1670168634735028
# At iteration 18 the best fitness is 0.14902458637059438
# At iteration 19 the best fitness is 0.15834001687813196
# At iteration 20 the best fitness is 0.15794790394960853
# At iteration 21 the best fitness is 0.14024691073646034
# At iteration 22 the best fitness is 0.14038134945481123
# At iteration 23 the best fitness is 0.14024691073646034
# At iteration 24 the best fitness is 0.14016848815075567
# At iteration 25 the best fitness is 0.1580263265353132
# At iteration 26 the best fitness is 0.14016848815075567
# At iteration 27 the best fitness is 0.15811595234754713
# At iteration 28 the best fitness is 0.13143562542273857
# At iteration 29 the best fitness is 0.1403141300956358
# At iteration 30 the best fitness is 0.14911421218282828
#       Selected: 2215/4463 (49.6%), Fitness: 0.1491, Time: 1363.3s
#       Modality: D=47%, S=50%, Sk=50%, V=50%
#     Test Acc: 66.67%, F1: 64.32%, Features: 2215/4463 (49.6%), Model: 4.867MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.17554806812399354']
# ['At iteration 1 the best fitness is 0.17554806812399354']
# ['At iteration 2 the best fitness is 0.16475381171459624']
# ['At iteration 3 the best fitness is 0.16475381171459624']
# ['At iteration 4 the best fitness is 0.16325257935967802']
# ['At iteration 5 the best fitness is 0.16325257935967802']
# ['At iteration 6 the best fitness is 0.16325257935967802']
# ['At iteration 7 the best fitness is 0.16325257935967802']
# ['At iteration 8 the best fitness is 0.16325257935967802']
# ['At iteration 9 the best fitness is 0.16325257935967802']
# ['At iteration 10 the best fitness is 0.16325257935967802']
# ['At iteration 11 the best fitness is 0.16325257935967802']
# ['At iteration 12 the best fitness is 0.16325257935967802']
# ['At iteration 13 the best fitness is 0.16325257935967802']
# ['At iteration 14 the best fitness is 0.14489059578130464']
# ['At iteration 15 the best fitness is 0.14489059578130464']
# ['At iteration 16 the best fitness is 0.14489059578130464']
# ['At iteration 17 the best fitness is 0.14489059578130464']
# ['At iteration 18 the best fitness is 0.14489059578130464']
# ['At iteration 19 the best fitness is 0.14489059578130464']
# ['At iteration 20 the best fitness is 0.14489059578130464']
# ['At iteration 21 the best fitness is 0.14489059578130464']
# ['At iteration 22 the best fitness is 0.14489059578130464']
# ['At iteration 23 the best fitness is 0.14489059578130464']
# ['At iteration 24 the best fitness is 0.14489059578130464']
# ['At iteration 25 the best fitness is 0.14489059578130464']
# ['At iteration 26 the best fitness is 0.14489059578130464']
# ['At iteration 27 the best fitness is 0.14489059578130464']
# ['At iteration 28 the best fitness is 0.14489059578130464']
# ['At iteration 29 the best fitness is 0.14489059578130464']
#       Selected: 1838/4463 (41.2%), Fitness: 0.1449, Time: 1311.7s
#       Modality: D=41%, S=40%, Sk=41%, V=42%
#     Test Acc: 74.07%, F1: 71.53%, Features: 1838/4463 (41.2%), Model: 4.131MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.17577213265457836']
# ['At iteration 1 the best fitness is 0.17577213265457836']
# ['At iteration 2 the best fitness is 0.17577213265457836']
# ['At iteration 3 the best fitness is 0.16575089887569863']
# ['At iteration 4 the best fitness is 0.15356178841188506']
# ['At iteration 5 the best fitness is 0.15356178841188506']
# ['At iteration 6 the best fitness is 0.15356178841188506']
# ['At iteration 7 the best fitness is 0.15356178841188506']
# ['At iteration 8 the best fitness is 0.15356178841188506']
# ['At iteration 9 the best fitness is 0.15356178841188506']
# ['At iteration 10 the best fitness is 0.15356178841188506']
# ['At iteration 11 the best fitness is 0.15356178841188506']
# ['At iteration 12 the best fitness is 0.15356178841188506']
# ['At iteration 13 the best fitness is 0.15356178841188506']
# ['At iteration 14 the best fitness is 0.15356178841188506']
# ['At iteration 15 the best fitness is 0.15356178841188506']
# ['At iteration 16 the best fitness is 0.15356178841188506']
# ['At iteration 17 the best fitness is 0.15356178841188506']
# ['At iteration 18 the best fitness is 0.15356178841188506']
# ['At iteration 19 the best fitness is 0.15356178841188506']
# ['At iteration 20 the best fitness is 0.15356178841188506']
# ['At iteration 21 the best fitness is 0.15356178841188506']
# ['At iteration 22 the best fitness is 0.15356178841188506']
# ['At iteration 23 the best fitness is 0.15356178841188506']
# ['At iteration 24 the best fitness is 0.15356178841188506']
# ['At iteration 25 the best fitness is 0.15356178841188506']
# ['At iteration 26 the best fitness is 0.15356178841188506']
# ['At iteration 27 the best fitness is 0.15356178841188506']
# ['At iteration 28 the best fitness is 0.15356178841188506']
# ['At iteration 29 the best fitness is 0.15356178841188506']
#       Selected: 1027/4463 (23.0%), Fitness: 0.1536, Time: 1680.0s
#       Modality: D=23%, S=23%, Sk=22%, V=25%
#     Test Acc: 70.37%, F1: 67.69%, Features: 1027/4463 (23.0%), Model: 2.547MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.19294657422085226']
# ['At iteration 1 the best fitness is 0.18422491471936442']
# ['At iteration 2 the best fitness is 0.18409047600101353']
# ['At iteration 3 the best fitness is 0.1750663293832362']
# ['At iteration 4 the best fitness is 0.16645670214704078']
# ['At iteration 5 the best fitness is 0.16645670214704078']
# ['At iteration 6 the best fitness is 0.16645670214704078']
# ['At iteration 7 the best fitness is 0.16645670214704078']
# ['At iteration 8 the best fitness is 0.16645670214704078']
# ['At iteration 9 the best fitness is 0.16645670214704078']
# ['At iteration 10 the best fitness is 0.16645670214704078']
# ['At iteration 11 the best fitness is 0.16645670214704078']
# ['At iteration 12 the best fitness is 0.16645670214704078']
# ['At iteration 13 the best fitness is 0.16645670214704078']
# ['At iteration 14 the best fitness is 0.16645670214704078']
# ['At iteration 15 the best fitness is 0.16645670214704078']
# ['At iteration 16 the best fitness is 0.16645670214704078']
# ['At iteration 17 the best fitness is 0.16645670214704078']
# ['At iteration 18 the best fitness is 0.16645670214704078']
# ['At iteration 19 the best fitness is 0.16632226342868991']
# ['At iteration 20 the best fitness is 0.16632226342868991']
# ['At iteration 21 the best fitness is 0.15724210067826638']
# ['At iteration 22 the best fitness is 0.15724210067826638']
# ['At iteration 23 the best fitness is 0.15724210067826638']
# ['At iteration 24 the best fitness is 0.15724210067826638']
# ['At iteration 25 the best fitness is 0.15724210067826638']
# ['At iteration 26 the best fitness is 0.15724210067826638']
# ['At iteration 27 the best fitness is 0.15724210067826638']
# ['At iteration 28 the best fitness is 0.1484308153645446']
# ...
# ['At iteration 14 the best fitness is 0.15273840361351174']
# ['At iteration 15 the best fitness is 0.15273840361351174']
# ['At iteration 16 the best fitness is 0.15273840361351174']
# ['At iteration 17 the best fitness is 0.15273840361351174']
# ['At iteration 18 the best fitness is 0.15273840361351174']
# ['At iteration 19 the best fitness is 0.15273840361351174']
# ['At iteration 20 the best fitness is 0.15273840361351174']
# ['At iteration 21 the best fitness is 0.15273840361351174']
# ['At iteration 22 the best fitness is 0.15273840361351174']
# ['At iteration 23 the best fitness is 0.15273840361351174']
# ['At iteration 24 the best fitness is 0.15273840361351174']
# ['At iteration 25 the best fitness is 0.15273840361351174']
# ['At iteration 26 the best fitness is 0.15273840361351174']
# ['At iteration 27 the best fitness is 0.15273840361351174']
# ['At iteration 28 the best fitness is 0.15273840361351174']
# ['At iteration 29 the best fitness is 0.15273840361351174']
#       Selected: 1746/4463 (39.1%), Fitness: 0.1527, Time: 1676.4s
#       Modality: D=36%, S=38%, Sk=39%, V=40%
#     Test Acc: 77.57%, F1: 76.74%, Features: 1746/4463 (39.1%), Model: 3.951MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1847738728192972']
# ['At iteration 1 the best fitness is 0.18454980828871237']
# ['At iteration 2 the best fitness is 0.18454980828871237']
# ['At iteration 3 the best fitness is 0.17577213265457836']
# ['At iteration 4 the best fitness is 0.17577213265457836']
# ['At iteration 5 the best fitness is 0.17577213265457836']
# ['At iteration 6 the best fitness is 0.17577213265457836']
# ['At iteration 7 the best fitness is 0.17577213265457836']
# ['At iteration 8 the best fitness is 0.17577213265457836']
# ['At iteration 9 the best fitness is 0.17577213265457836']
# ['At iteration 10 the best fitness is 0.16729694413673382']
# ['At iteration 11 the best fitness is 0.16729694413673382']
# ['At iteration 12 the best fitness is 0.16729694413673382']
# ['At iteration 13 the best fitness is 0.16729694413673382']
# ['At iteration 14 the best fitness is 0.16729694413673382']
# ['At iteration 15 the best fitness is 0.16729694413673382']
# ['At iteration 16 the best fitness is 0.16729694413673382']
# ['At iteration 17 the best fitness is 0.16729694413673382']
# ['At iteration 18 the best fitness is 0.16729694413673382']
# ['At iteration 19 the best fitness is 0.16729694413673382']
# ['At iteration 20 the best fitness is 0.16729694413673382']
# ['At iteration 21 the best fitness is 0.16729694413673382']
# ['At iteration 22 the best fitness is 0.16729694413673382']
# ['At iteration 23 the best fitness is 0.16729694413673382']
# ['At iteration 24 the best fitness is 0.16729694413673382']
# ['At iteration 25 the best fitness is 0.16729694413673382']
# ['At iteration 26 the best fitness is 0.16729694413673382']
# ['At iteration 27 the best fitness is 0.16729694413673382']
# ['At iteration 28 the best fitness is 0.16729694413673382']
# ['At iteration 29 the best fitness is 0.16729694413673382']
#       Selected: 2253/4463 (50.5%), Fitness: 0.1673, Time: 1369.4s
#       Modality: D=52%, S=51%, Sk=49%, V=51%
#     Test Acc: 78.50%, F1: 78.37%, Features: 2253/4463 (50.5%), Model: 4.942MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.18489710831111883']
# ['At iteration 2 the best fitness is 0.18489710831111883']
# ['At iteration 3 the best fitness is 0.18489710831111883']
# ['At iteration 4 the best fitness is 0.18489710831111883']
# ['At iteration 5 the best fitness is 0.18489710831111883']
# ['At iteration 6 the best fitness is 0.18489710831111883']
# ['At iteration 7 the best fitness is 0.18489710831111883']
# ['At iteration 8 the best fitness is 0.15784707491084538']
# ['At iteration 9 the best fitness is 0.15784707491084538']
# ['At iteration 10 the best fitness is 0.15784707491084538']
# ['At iteration 11 the best fitness is 0.15784707491084538']
# ['At iteration 12 the best fitness is 0.15784707491084538']
# ['At iteration 13 the best fitness is 0.15784707491084538']
# ['At iteration 14 the best fitness is 0.15784707491084538']
# ['At iteration 15 the best fitness is 0.15784707491084538']
# ['At iteration 16 the best fitness is 0.15784707491084538']
# ['At iteration 17 the best fitness is 0.15784707491084538']
# ['At iteration 18 the best fitness is 0.15784707491084538']
# ['At iteration 19 the best fitness is 0.14951752833788096']
# ['At iteration 20 the best fitness is 0.14951752833788096']
# ['At iteration 21 the best fitness is 0.14951752833788096']
# ['At iteration 22 the best fitness is 0.14951752833788096']
# ['At iteration 23 the best fitness is 0.14951752833788096']
# ['At iteration 24 the best fitness is 0.14951752833788096']
# ['At iteration 25 the best fitness is 0.14951752833788096']
# ['At iteration 26 the best fitness is 0.14951752833788096']
# ['At iteration 27 the best fitness is 0.14951752833788096']
# ['At iteration 28 the best fitness is 0.14951752833788096']
# ['At iteration 29 the best fitness is 0.14951752833788096']
#       Selected: 2251/4463 (50.4%), Fitness: 0.1495, Time: 1331.4s
#       Modality: D=50%, S=48%, Sk=53%, V=49%
#     Test Acc: 76.64%, F1: 75.24%, Features: 2251/4463 (50.4%), Model: 4.938MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1938428323431915']
# ['At iteration 2 the best fitness is 0.19345071941466807']
# ['At iteration 3 the best fitness is 0.19345071941466807']
# ['At iteration 4 the best fitness is 0.18465063732747555']
# ['At iteration 5 the best fitness is 0.16738656994896775']
# ['At iteration 6 the best fitness is 0.16738656994896775']
# ['At iteration 7 the best fitness is 0.16738656994896775']
# ['At iteration 8 the best fitness is 0.16738656994896775']
# ['At iteration 9 the best fitness is 0.16738656994896775']
# ['At iteration 10 the best fitness is 0.16738656994896775']
# ['At iteration 11 the best fitness is 0.16738656994896775']
# ['At iteration 12 the best fitness is 0.16738656994896775']
# ['At iteration 13 the best fitness is 0.16738656994896775']
# ['At iteration 14 the best fitness is 0.16738656994896775']
# ['At iteration 15 the best fitness is 0.16738656994896775']
# ['At iteration 16 the best fitness is 0.16738656994896775']
# ['At iteration 17 the best fitness is 0.16738656994896775']
# ['At iteration 18 the best fitness is 0.16738656994896775']
# ['At iteration 19 the best fitness is 0.16738656994896775']
# ['At iteration 20 the best fitness is 0.16738656994896775']
# ['At iteration 21 the best fitness is 0.16738656994896775']
# ['At iteration 22 the best fitness is 0.16738656994896775']
# ['At iteration 23 the best fitness is 0.16738656994896775']
# ['At iteration 24 the best fitness is 0.16738656994896775']
# ['At iteration 25 the best fitness is 0.16738656994896775']
# ['At iteration 26 the best fitness is 0.16738656994896775']
# ['At iteration 27 the best fitness is 0.16738656994896775']
# ['At iteration 28 the best fitness is 0.16738656994896775']
# ['At iteration 29 the best fitness is 0.16738656994896775']
# ['At iteration 30 the best fitness is 0.16738656994896775']
#       Selected: 2261/4463 (50.7%), Fitness: 0.1674, Time: 1374.4s
#       Modality: D=52%, S=51%, Sk=52%, V=49%
#     Test Acc: 75.70%, F1: 73.75%, Features: 2261/4463 (50.7%), Model: 4.957MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.21131976102575487']
# ['At iteration 2 the best fitness is 0.2112189319869917']
# ['At iteration 3 the best fitness is 0.2112189319869917']
# ['At iteration 4 the best fitness is 0.2112189319869917']
# ['At iteration 5 the best fitness is 0.2112189319869917']
# ['At iteration 6 the best fitness is 0.2024748660324454']
# ['At iteration 7 the best fitness is 0.2024748660324454']
# ['At iteration 8 the best fitness is 0.2024748660324454']
# ['At iteration 9 the best fitness is 0.2024748660324454']
# ['At iteration 10 the best fitness is 0.17611943267698482']
# ['At iteration 11 the best fitness is 0.17611943267698482']
# ['At iteration 12 the best fitness is 0.17611943267698482']
# ['At iteration 13 the best fitness is 0.17611943267698482']
# ['At iteration 14 the best fitness is 0.17611943267698482']
# ['At iteration 15 the best fitness is 0.17611943267698482']
# ['At iteration 16 the best fitness is 0.17611943267698482']
# ['At iteration 17 the best fitness is 0.17611943267698482']
# ['At iteration 18 the best fitness is 0.17611943267698482']
# ['At iteration 19 the best fitness is 0.17611943267698482']
# ['At iteration 20 the best fitness is 0.17611943267698482']
# ['At iteration 21 the best fitness is 0.17611943267698482']
# ['At iteration 22 the best fitness is 0.1758953681464']
# ['At iteration 23 the best fitness is 0.1758953681464']
# ['At iteration 24 the best fitness is 0.1758953681464']
# ['At iteration 25 the best fitness is 0.1758953681464']
# ['At iteration 26 the best fitness is 0.1758953681464']
# ['At iteration 27 the best fitness is 0.1758953681464']
# ['At iteration 28 the best fitness is 0.1758953681464']
# ['At iteration 29 the best fitness is 0.1758953681464']
# ['At iteration 30 the best fitness is 0.1758953681464']
#       Selected: 2228/4463 (49.9%), Fitness: 0.1759, Time: 1355.4s
#       Modality: D=51%, S=51%, Sk=48%, V=51%
#     Test Acc: 76.64%, F1: 74.90%, Features: 2228/4463 (49.9%), Model: 4.893MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.21095005455028992']
# ['At iteration 1 the best fitness is 0.2093591963831378']
# ['At iteration 2 the best fitness is 0.19025779985383456']
# ['At iteration 3 the best fitness is 0.19025779985383456']
# ['At iteration 4 the best fitness is 0.17744696266917395']
# ['At iteration 5 the best fitness is 0.17744696266917395']
# ['At iteration 6 the best fitness is 0.17744696266917395']
# ['At iteration 7 the best fitness is 0.17419802697569423']
# ['At iteration 8 the best fitness is 0.17419802697569423']
# ['At iteration 9 the best fitness is 0.17419802697569423']
# ['At iteration 10 the best fitness is 0.17419802697569423']
# ['At iteration 11 the best fitness is 0.17419802697569423']
# ['At iteration 12 the best fitness is 0.17419802697569423']
# ['At iteration 13 the best fitness is 0.17419802697569423']
# ['At iteration 14 the best fitness is 0.17419802697569423']
# ['At iteration 15 the best fitness is 0.17419802697569423']
# ['At iteration 16 the best fitness is 0.17419802697569423']
# ['At iteration 17 the best fitness is 0.17419802697569423']
# ['At iteration 18 the best fitness is 0.17419802697569423']
# ['At iteration 19 the best fitness is 0.17419802697569423']
# ['At iteration 20 the best fitness is 0.17419802697569423']
# ['At iteration 21 the best fitness is 0.17036652350269402']
# ['At iteration 22 the best fitness is 0.17036652350269402']
# ['At iteration 23 the best fitness is 0.17036652350269402']
# ['At iteration 24 the best fitness is 0.17036652350269402']
# ['At iteration 25 the best fitness is 0.17036652350269402']
# ['At iteration 26 the best fitness is 0.17036652350269402']
# ['At iteration 27 the best fitness is 0.17036652350269402']
# ['At iteration 28 the best fitness is 0.16972793959052732']
# ['At iteration 29 the best fitness is 0.16972793959052732']
#       Selected: 885/4463 (19.8%), Fitness: 0.1697, Time: 1279.5s
#       Modality: D=20%, S=21%, Sk=20%, V=19%
#     Test Acc: 77.57%, F1: 76.87%, Features: 885/4463 (19.8%), Model: 2.270MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.18467304378053404']
# ['At iteration 2 the best fitness is 0.18467304378053404']
# ['At iteration 3 the best fitness is 0.18440416634383228']
# ['At iteration 4 the best fitness is 0.18440416634383228']
# ['At iteration 5 the best fitness is 0.18440416634383228']
# ['At iteration 6 the best fitness is 0.18440416634383228']
# ['At iteration 7 the best fitness is 0.14941669929911777']
# ['At iteration 8 the best fitness is 0.14941669929911777']
# ['At iteration 9 the best fitness is 0.14941669929911777']
# ['At iteration 10 the best fitness is 0.14941669929911777']
# ['At iteration 11 the best fitness is 0.14941669929911777']
# ['At iteration 12 the best fitness is 0.14941669929911777']
# ['At iteration 13 the best fitness is 0.14941669929911777']
# ['At iteration 14 the best fitness is 0.14941669929911777']
# ['At iteration 15 the best fitness is 0.14941669929911777']
# ['At iteration 16 the best fitness is 0.14941669929911777']
# ['At iteration 17 the best fitness is 0.14941669929911777']
# ['At iteration 18 the best fitness is 0.14941669929911777']
# ['At iteration 19 the best fitness is 0.14941669929911777']
# ['At iteration 20 the best fitness is 0.14941669929911777']
# ['At iteration 21 the best fitness is 0.14941669929911777']
# ['At iteration 22 the best fitness is 0.14941669929911777']
# ['At iteration 23 the best fitness is 0.14941669929911777']
# ['At iteration 24 the best fitness is 0.14941669929911777']
# ['At iteration 25 the best fitness is 0.14941669929911777']
# ['At iteration 26 the best fitness is 0.14941669929911777']
# ['At iteration 27 the best fitness is 0.14941669929911777']
# ['At iteration 28 the best fitness is 0.14941669929911777']
# ['At iteration 29 the best fitness is 0.14941669929911777']
#       Selected: 2242/4463 (50.2%), Fitness: 0.1494, Time: 3333.2s
#       Modality: D=48%, S=54%, Sk=50%, V=50%
#     Test Acc: 78.50%, F1: 78.31%, Features: 2242/4463 (50.2%), Model: 4.920MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1939548646084839']
# ['At iteration 1 the best fitness is 0.1939548646084839']
# ['At iteration 2 the best fitness is 0.19184865802098672']
# ['At iteration 3 the best fitness is 0.19184865802098672']
# ['At iteration 4 the best fitness is 0.18935599246975654']
# ['At iteration 5 the best fitness is 0.18935599246975654']
# ['At iteration 6 the best fitness is 0.18935599246975654']
# ['At iteration 7 the best fitness is 0.18935599246975654']
# ['At iteration 8 the best fitness is 0.18935599246975654']
# ['At iteration 9 the best fitness is 0.18935599246975654']
# ['At iteration 10 the best fitness is 0.18935599246975654']
# ['At iteration 11 the best fitness is 0.17996213937651429']
# ['At iteration 12 the best fitness is 0.17996213937651429']
# ['At iteration 13 the best fitness is 0.17996213937651429']
# ['At iteration 14 the best fitness is 0.17996213937651429']
# ['At iteration 15 the best fitness is 0.17996213937651429']
# ['At iteration 16 the best fitness is 0.17996213937651429']
# ['At iteration 17 the best fitness is 0.17996213937651429']
# ['At iteration 18 the best fitness is 0.17996213937651429']
# ['At iteration 19 the best fitness is 0.17996213937651429']
# ['At iteration 20 the best fitness is 0.17996213937651429']
# ['At iteration 21 the best fitness is 0.17996213937651429']
# ['At iteration 22 the best fitness is 0.17996213937651429']
# ['At iteration 23 the best fitness is 0.17996213937651429']
# ['At iteration 24 the best fitness is 0.17996213937651429']
# ['At iteration 25 the best fitness is 0.17996213937651429']
# ['At iteration 26 the best fitness is 0.17996213937651429']
# ['At iteration 27 the best fitness is 0.1795588232214616']
# ['At iteration 28 the best fitness is 0.1795588232214616']
# ['At iteration 29 the best fitness is 0.1795588232214616']
#       Selected: 2555/4463 (57.2%), Fitness: 0.1796, Time: 1348.5s
#       Modality: D=59%, S=56%, Sk=58%, V=56%
#     Test Acc: 73.83%, F1: 71.86%, Features: 2555/4463 (57.2%), Model: 5.531MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          72.222222         79.439252     72.278873
# 1  baseline     2          77.777778         85.046729     75.425480
# 2  baseline     3          69.444444         83.177570     69.763775
# 3  baseline     4          76.851852         84.112150     76.394845
# 4  baseline     5          64.814815         84.112150     62.095345
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        72.278873            76.309524         72.222222               4463
# 1        75.425480            79.071135         77.777778               4463
# 2        69.763775            74.691358         69.444444               4463
# 3        76.394845            85.740741         76.851852               4463
# 4        62.095345            68.977072         64.814815               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              74.23              5.23              73.27              5.34                 4463.00                      100.00              0.00                26.72                26.72          2425371.0                  9.26                        0.00               72.33
# mutual_info              73.53              3.58              72.54              3.25                 2231.00                       49.99             57.63                21.78                79.41          1282587.0                  4.90                       50.01               45.90
#         rfe              68.89              8.44              66.59             10.07                 2231.00                       49.99             10.34                21.63                31.97          1282587.0                  4.90                       50.01               45.90
#       lasso              55.65              8.49              53.19              9.99                 2231.00                       49.99              5.30                21.11                26.41          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              69.47             14.47              68.18             15.74                 2212.62                       49.58           1342.23                22.54              1364.77          1273179.0                  4.86                       50.42               45.80
#     meta_CS              68.55             13.00              67.00             14.11                 2203.50                       49.37           2776.04                22.62              2798.66          1268507.0                  4.84                       50.63               45.69
#     meta_DE              70.18             10.61              68.84             10.69                 2207.00                       49.45           1409.34                22.58              1431.92          1270299.0                  4.85                       50.55               45.73
#    meta_FFA              69.01             13.48              67.54             13.45                 2210.88                       49.54           1360.86                22.59              1383.45          1272283.0                  4.86                       50.46               45.77
#     meta_GA              69.24              6.10              67.75              6.24                 2227.12                       49.90           1362.93                22.59              1385.52          1280603.0                  4.89                       50.10               45.90
#    meta_GWO              72.71              4.99              71.39              4.98                 1906.50                       42.72           1323.65                20.96              1344.61          1116443.0                  4.26                       57.28               42.73
#    meta_HHO              69.82              5.39              68.34              5.68                 2260.25                       50.64           1750.07                21.85              1771.91          1297563.0                  4.96                       49.36               46.50
#   meta_JAYA              68.66             12.15              67.48             12.78                 2227.50                       49.91           1390.19                22.61              1412.80          1280795.0                  4.89                       50.09               45.92
#    meta_MFO              69.94             11.05              68.60             10.80                 2255.25                       50.53           1331.02                22.74              1353.76          1295003.0                  4.95                       49.47               46.19
#    meta_MVO              69.94              9.81              67.90             10.63                 2210.00                       49.52           1368.48                22.44              1390.92          1271835.0                  4.86                       50.48               45.75
#    meta_PSO              68.32             12.42              66.76             13.15                 2205.50                       49.42           1356.23                22.64              1378.87          1269531.0                  4.85                       50.58               45.72
#    meta_SCA              68.90             13.97              67.89             14.09                 1404.12                       31.46           1232.88                18.42              1251.30           859227.0                  3.28                       68.54               36.82
#    meta_SSA              69.13              6.83              67.39              7.47                 2212.25                       49.57           3346.21                22.48              3368.69          1272987.0                  4.86                       50.43               45.76
#    meta_WOA              68.43              8.23              66.33              8.81                 1904.62                       42.68           1312.98                21.68              1334.66          1115483.0                  4.26                       57.32               42.34

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_BAT
#     F1 Macro:           72.27%
#     F1 Weighted:        72.27%
#     Test Accuracy:      72.22%
#     Feature Retention:  49.83% (2224/4463)
#     Modality Retention: depth=49.2%, sensor=52.3%, skeleton=49.4%, video=49.5%
#
#   Fold 2: Best = meta_BAT
#     F1 Macro:           76.10%
#     F1 Weighted:        76.10%
#     Test Accuracy:      76.85%
#     Feature Retention:  49.68% (2217/4463)
#     Modality Retention: depth=45.9%, sensor=52.6%, skeleton=50.7%, video=48.3%
#
#   Fold 3: Best = meta_BAT
#     F1 Macro:           78.50%
#     F1 Weighted:        78.50%
#     Test Accuracy:      78.70%
#     Feature Retention:  49.99% (2231/4463)
#     Modality Retention: depth=49.6%, sensor=48.6%, skeleton=50.7%, video=49.8%
#
#   Fold 4: Best = meta_MFO
#     F1 Macro:           79.87%
#     F1 Weighted:        79.87%
#     Test Accuracy:      79.63%
#     Feature Retention:  50.35% (2247/4463)
#     Modality Retention: depth=50.4%, sensor=53.5%, skeleton=51.0%, video=48.0%
#
#   Fold 5: Best = meta_GWO
#     F1 Macro:           77.77%
#     F1 Weighted:        77.77%
#     Test Accuracy:      78.70%
#     Feature Retention:  42.08% (1878/4463)
#     Modality Retention: depth=42.8%, sensor=43.7%, skeleton=42.2%, video=40.9%
#
#   Fold 6: Best = meta_MVO
#     F1 Macro:           78.39%
#     F1 Weighted:        78.19%
#     Test Accuracy:      79.44%
#     Feature Retention:  49.83% (2224/4463)
#     Modality Retention: depth=51.2%, sensor=50.2%, skeleton=50.2%, video=48.7%
#
#   Fold 7: Best = meta_SCA
#     F1 Macro:           81.47%
#     F1 Weighted:        81.30%
#     Test Accuracy:      82.24%
#     Feature Retention:  27.20% (1214/4463)
#     Modality Retention: depth=29.3%, sensor=27.9%, skeleton=26.5%, video=27.0%
#
#   Fold 8: Best = meta_DE
#     F1 Macro:           78.48%
#     F1 Weighted:        78.59%
#     Test Accuracy:      80.37%
#     Feature Retention:  49.11% (2192/4463)
#     Modality Retention: depth=47.5%, sensor=53.1%, skeleton=49.4%, video=47.5%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 77.86% ± 2.74%
#
#   Average F1 Weighted         : 77.82% ± 2.71%
#
#   Average Test Accuracy       : 78.52% ± 2.97%
#
#   Average Feature Retention   : 46.01% ± 8.07%
#
#   Average Modality-wise Feature Retention:
#            depth: 45.73% ± 7.18%
#           sensor: 47.74% ± 8.64%
#         skeleton: 46.28% ± 8.49%
#            video: 44.96% ± 7.76%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1           meta_BAT         72.27            72.27              72.22                  49.83              49.22               52.30                 49.39              49.51
#     2           meta_BAT         76.10            76.10              76.85                  49.68              45.90               52.61                 50.72              48.31
#     3           meta_BAT         78.50            78.50              78.70                  49.99              49.61               48.62                 50.72              49.79
#     4           meta_MFO         79.87            79.87              79.63                  50.35              50.39               53.53                 51.04              47.96
#     5           meta_GWO         77.77            77.77              78.70                  42.08              42.77               43.71                 42.20              40.92
#     6           meta_MVO         78.39            78.19              79.44                  49.83              51.17               50.15                 50.24              48.66
#     7           meta_SCA         81.47            81.30              82.24                  27.20              29.30               27.91                 26.50              27.04
#     8            meta_DE         78.48            78.59              80.37                  49.11              47.46               53.07                 49.44              47.46
#
# Saved to: results_loss_50/best_metaheuristic_per_fold.csv
