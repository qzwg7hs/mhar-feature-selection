# %% [markdown]
# # File 2: Feature Selection on Weighted Early Fusion Features
#
# **Prerequisite:** Run File 1 first (`file1_weighted_fusion.ipynb`) to generate `best_weights_per_fold.pkl`.
#
# **Pipeline:**
# 1. Load the best modality weights per fold from File 1
# 2. For each fold, apply those weights to scale the concatenated features
# 3. Run the full feature selection comparison on the **weighted** features:
#    - Baseline (all weighted features, no FS)
#    - Mutual Information
#    - RFE
#    - LASSO
#    - 14 EvoloPy metaheuristics

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")
WEIGHTS_DIR = Path("results_weighted_fusion")

RESULTS_ROOT = Path("results_weighted_fs")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']
N_MODALITIES = len(MODALITY_NAMES)

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")


# Load best weights from File 1
best_weights_per_fold = joblib.load(WEIGHTS_DIR / "best_weights_per_fold.pkl")

print(f"\n{'=' * 60}")
print("LOADED BEST WEIGHTS PER FOLD FROM FILE 1:")
print(f"{'=' * 60}")
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']:25s} | Val: {info['val_acc']*100:.2f}% | [{w_str}]")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512
#
# ============================================================
# LOADED BEST WEIGHTS PER FOLD FROM FILE 1:
# ============================================================
#   Fold 1: weighted_SSA              | Val: 100.00% | [depth=0.995, sensor=0.400, skeleton=1.000, video=0.001]
#   Fold 2: weighted_GWO              | Val: 100.00% | [depth=0.727, sensor=1.000, skeleton=0.645, video=0.130]
#   Fold 3: weighted_CS               | Val: 100.00% | [depth=1.000, sensor=1.000, skeleton=1.000, video=0.005]
#   Fold 4: weighted_FFA              | Val: 99.07% | [depth=0.000, sensor=0.216, skeleton=0.373, video=0.000]
#   Fold 5: weighted_WOA              | Val: 100.00% | [depth=0.151, sensor=0.785, skeleton=0.934, video=0.207]
#   Fold 6: weighted_HHO              | Val: 100.00% | [depth=0.083, sensor=0.233, skeleton=0.360, video=0.183]
#   Fold 7: weighted_CS               | Val: 99.07% | [depth=0.007, sensor=0.582, skeleton=0.902, video=0.000]
#   Fold 8: weighted_DE               | Val: 100.00% | [depth=0.000, sensor=0.606, skeleton=0.976, video=0.018]

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # KernelPCA on depth modality only
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                random_state=42, n_jobs=-1)
            X_tr = pca_obj.fit_transform(X_tr)
            X_v  = pca_obj.transform(X_v)
            X_te = pca_obj.transform(X_te)
            print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)


def apply_modality_weights(X, weights, modality_dims):
    """Apply per-modality scalar weights to concatenated feature matrix.
    modality_dims is a list of per-modality dimensions (post-KernelPCA)."""
    X_weighted = X.copy()
    start_idx = 0
    for i, dim in enumerate(modality_dims):
        end_idx = start_idx + dim
        X_weighted[:, start_idx:end_idx] *= weights[i]
        start_idx = end_idx
    return X_weighted


def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Get best weights for this fold
        fold_weights = best_weights_per_fold[fold_idx]['weights']
        fold_weight_method = best_weights_per_fold[fold_idx]['method']
        w_str = ', '.join([f"{MODALITY_NAMES[i]}={fold_weights[i]:.3f}" for i in range(N_MODALITIES)])
        print(f"  Applying weights from {fold_weight_method}: [{w_str}]")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_modality_dims = [fold_feature_dims[n] for n in MODALITY_NAMES]
        fold_total_features = sum(fold_feature_dims.values())
        
        # =================================================================
        # Step 2: Apply modality weights from File 1 (AFTER normalization)
        # =================================================================
        X_train = apply_modality_weights(X_train, fold_weights, fold_modality_dims)
        X_val   = apply_modality_weights(X_val,   fold_weights, fold_modality_dims)
        X_test  = apply_modality_weights(X_test,  fold_weights, fold_modality_dims)

        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Applying weights from weighted_SSA: [depth=0.995, sensor=0.400, skeleton=1.000, video=0.001]
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 95.37%, F1: 93.99%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 58.2s
#     Test Acc: 96.30%, F1: 96.23%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.4s
#     Test Acc: 97.22%, F1: 97.14%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 336.7s
#     Test Acc: 99.07%, F1: 99.06%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0512490027034328']
# ['At iteration 1 the best fitness is 0.033525603037226126']
# ['At iteration 2 the best fitness is 0.03342477399846296']
# ['At iteration 3 the best fitness is 0.03342477399846296']
# ['At iteration 4 the best fitness is 0.03342477399846296']
# ['At iteration 5 the best fitness is 0.03342477399846296']
# ['At iteration 6 the best fitness is 0.03342477399846296']
# ['At iteration 7 the best fitness is 0.033335148186229034']
# ['At iteration 8 the best fitness is 0.03325672560052435']
# ['At iteration 9 the best fitness is 0.033200709467878155']
# ['At iteration 10 the best fitness is 0.033200709467878155']
# ['At iteration 11 the best fitness is 0.033200709467878155']
# ['At iteration 12 the best fitness is 0.033200709467878155']
# ['At iteration 13 the best fitness is 0.033200709467878155']
# ['At iteration 14 the best fitness is 0.033200709467878155']
# ['At iteration 15 the best fitness is 0.033200709467878155']
# ['At iteration 16 the best fitness is 0.0243894241541564']
# ['At iteration 17 the best fitness is 0.0243894241541564']
# ['At iteration 18 the best fitness is 0.0243894241541564']
# ['At iteration 19 the best fitness is 0.0243894241541564']
# ['At iteration 20 the best fitness is 0.0243894241541564']
# ['At iteration 21 the best fitness is 0.0243894241541564']
# ['At iteration 22 the best fitness is 0.0243894241541564']
# ['At iteration 23 the best fitness is 0.0243894241541564']
# ['At iteration 24 the best fitness is 0.0243894241541564']
# ['At iteration 25 the best fitness is 0.0243894241541564']
# ['At iteration 26 the best fitness is 0.0243894241541564']
# ['At iteration 27 the best fitness is 0.0243894241541564']
# ['At iteration 28 the best fitness is 0.0243894241541564']
# ['At iteration 29 the best fitness is 0.0243894241541564']
#       Selected: 2177/4463 (48.8%), Fitness: 0.0244, Time: 1590.8s
#       Modality: D=50%, S=50%, Sk=47%, V=50%
#     Test Acc: 99.07%, F1: 99.06%, Features: 2177/4463 (48.8%), Model: 4.793MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.033772074020869416']
# ['At iteration 1 the best fitness is 0.025576966166255884']
# ['At iteration 2 the best fitness is 0.025576966166255884']
# ['At iteration 3 the best fitness is 0.025576966166255884']
# ['At iteration 4 the best fitness is 0.025576966166255884']
# ['At iteration 5 the best fitness is 0.025576966166255884']
# ['At iteration 6 the best fitness is 0.025576966166255884']
# ['At iteration 7 the best fitness is 0.025576966166255884']
# ['At iteration 8 the best fitness is 0.02451265964597804']
# ['At iteration 9 the best fitness is 0.02451265964597804']
# ['At iteration 10 the best fitness is 0.02451265964597804']
# ['At iteration 11 the best fitness is 0.02451265964597804']
# ['At iteration 12 the best fitness is 0.02451265964597804']
# ['At iteration 13 the best fitness is 0.02451265964597804']
# ['At iteration 14 the best fitness is 0.02451265964597804']
# ['At iteration 15 the best fitness is 0.02451265964597804']
# ['At iteration 16 the best fitness is 0.02451265964597804']
# ['At iteration 17 the best fitness is 0.02451265964597804']
# ['At iteration 18 the best fitness is 0.02451265964597804']
# ['At iteration 19 the best fitness is 0.02451265964597804']
# ['At iteration 20 the best fitness is 0.02451265964597804']
# ['At iteration 21 the best fitness is 0.02451265964597804']
# ['At iteration 22 the best fitness is 0.02451265964597804']
# ['At iteration 23 the best fitness is 0.02451265964597804']
# ['At iteration 24 the best fitness is 0.02451265964597804']
# ['At iteration 25 the best fitness is 0.02451265964597804']
# ['At iteration 26 the best fitness is 0.02451265964597804']
# ['At iteration 27 the best fitness is 0.02451265964597804']
# ['At iteration 28 the best fitness is 0.02451265964597804']
# ['At iteration 29 the best fitness is 0.02451265964597804']
#       Selected: 2188/4463 (49.0%), Fitness: 0.0245, Time: 3036.9s
#       Modality: D=47%, S=50%, Sk=49%, V=50%
#     Test Acc: 97.22%, F1: 97.23%, Features: 2188/4463 (49.0%), Model: 4.815MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04252734320194497']
# ['At iteration 2 the best fitness is 0.03360402562293081']
# ['At iteration 3 the best fitness is 0.03360402562293081']
# ['At iteration 4 the best fitness is 0.03360402562293081']
# ['At iteration 5 the best fitness is 0.03342477399846296']
# ['At iteration 6 the best fitness is 0.03342477399846296']
# ['At iteration 7 the best fitness is 0.03342477399846296']
# ['At iteration 8 the best fitness is 0.03342477399846296']
# ['At iteration 9 the best fitness is 0.03342477399846296']
# ['At iteration 10 the best fitness is 0.03342477399846296']
# ['At iteration 11 the best fitness is 0.03342477399846296']
# ['At iteration 12 the best fitness is 0.03342477399846296']
# ['At iteration 13 the best fitness is 0.03342477399846296']
# ['At iteration 14 the best fitness is 0.03342477399846296']
# ['At iteration 15 the best fitness is 0.03342477399846296']
# ['At iteration 16 the best fitness is 0.03314469333523195']
# ['At iteration 17 the best fitness is 0.03314469333523195']
# ['At iteration 18 the best fitness is 0.03314469333523195']
# ['At iteration 19 the best fitness is 0.03314469333523195']
# ['At iteration 20 the best fitness is 0.03314469333523195']
# ['At iteration 21 the best fitness is 0.03314469333523195']
# ['At iteration 22 the best fitness is 0.03314469333523195']
# ['At iteration 23 the best fitness is 0.024490253192919562']
# ['At iteration 24 the best fitness is 0.024490253192919562']
# ['At iteration 25 the best fitness is 0.024490253192919562']
# ['At iteration 26 the best fitness is 0.024490253192919562']
# ['At iteration 27 the best fitness is 0.024490253192919562']
# ['At iteration 28 the best fitness is 0.024490253192919562']
# ['At iteration 29 the best fitness is 0.024490253192919562']
# ['At iteration 30 the best fitness is 0.024490253192919562']
#       Selected: 2186/4463 (49.0%), Fitness: 0.0245, Time: 1566.1s
#       Modality: D=45%, S=49%, Sk=49%, V=50%
#     Test Acc: 96.30%, F1: 96.34%, Features: 2186/4463 (49.0%), Model: 4.811MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04276261095905902']
# ['At iteration 1 the best fitness is 0.02524086937037867']
# ['At iteration 2 the best fitness is 0.03362643207598929']
# ['At iteration 3 the best fitness is 0.033816886926986374']
# ['At iteration 4 the best fitness is 0.02493838225408918']
# ['At iteration 5 the best fitness is 0.02529688550302487']
# ['At iteration 6 the best fitness is 0.03417539017592207']
# ['At iteration 7 the best fitness is 0.034074561137158905']
# ['At iteration 8 the best fitness is 0.025128837105086267']
# ['At iteration 9 the best fitness is 0.03395132564533726']
# ['At iteration 10 the best fitness is 0.033984935324924984']
# ['At iteration 11 the best fitness is 0.03397373209839574']
# ['At iteration 12 the best fitness is 0.025016804839793863']
# ['At iteration 13 the best fitness is 0.025117633878557023']
# ['At iteration 14 the best fitness is 0.0340185450045127']
# ['At iteration 15 the best fitness is 0.025207259690790948']
# ['At iteration 16 the best fitness is 0.02521846291732019']
# ['At iteration 17 the best fitness is 0.025207259690790948']
# ['At iteration 18 the best fitness is 0.02518485323773247']
# ['At iteration 19 the best fitness is 0.02524086937037867']
# ['At iteration 20 the best fitness is 0.02524086937037867']
# ['At iteration 21 the best fitness is 0.02521846291732019']
# ['At iteration 22 the best fitness is 0.025207259690790948']
# ['At iteration 23 the best fitness is 0.025196056464261707']
# ['At iteration 24 the best fitness is 0.025196056464261707']
# ['At iteration 25 the best fitness is 0.025196056464261707']
# ['At iteration 26 the best fitness is 0.034063357910629664']
# ['At iteration 27 the best fitness is 0.025196056464261707']
# ['At iteration 28 the best fitness is 0.034074561137158905']
# ['At iteration 29 the best fitness is 0.025196056464261707']
#       Selected: 2249/4463 (50.4%), Fitness: 0.0252, Time: 1486.9s
#       Modality: D=48%, S=50%, Sk=51%, V=51%
#     Test Acc: 97.22%, F1: 97.23%, Features: 2249/4463 (50.4%), Model: 4.934MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.03354800949028461
# At iteration 2 the best fitness is 0.03331274173317056
# At iteration 3 the best fitness is 0.033189506241348914
# At iteration 4 the best fitness is 0.03389530951269106
# At iteration 5 the best fitness is 0.03367124498210625
# At iteration 6 the best fitness is 0.02463589513779969
# At iteration 7 the best fitness is 0.02463589513779969
# At iteration 8 the best fitness is 0.033514399810696885
# At iteration 9 the best fitness is 0.02447904996639032
# At iteration 10 the best fitness is 0.024960788707147658
# At iteration 11 the best fitness is 0.024322204794980956
# At iteration 12 the best fitness is 0.03346958690457993
# At iteration 13 the best fitness is 0.024602285458211966
# At iteration 14 the best fitness is 0.03346958690457993
# At iteration 15 the best fitness is 0.03307747397605651
# At iteration 16 the best fitness is 0.02418776607663007
# At iteration 17 the best fitness is 0.02418776607663007
# At iteration 18 the best fitness is 0.03306627074952727
# At iteration 19 the best fitness is 0.033189506241348914
# At iteration 20 the best fitness is 0.024781537082679814
# At iteration 21 the best fitness is 0.03315589656176119
# At iteration 22 the best fitness is 0.02427739188886399
# At iteration 23 the best fitness is 0.024243782209276272
# At iteration 24 the best fitness is 0.024837553215326016
# At iteration 25 the best fitness is 0.02475913062962133
# At iteration 26 the best fitness is 0.024311001568451715
# At iteration 27 the best fitness is 0.024647098364328927
# At iteration 28 the best fitness is 0.024490253192919562
# At iteration 29 the best fitness is 0.033032661069939545
# At iteration 30 the best fitness is 0.03331274173317056
#       Selected: 2181/4463 (48.9%), Fitness: 0.0333, Time: 1479.3s
#       Modality: D=46%, S=48%, Sk=50%, V=49%
#     Test Acc: 95.37%, F1: 94.35%, Features: 2181/4463 (48.9%), Model: 4.801MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03370485466169397']
# ['At iteration 1 the best fitness is 0.03370485466169397']
# ['At iteration 2 the best fitness is 0.0318003061517231']
# ['At iteration 3 the best fitness is 0.03130736418443652']
# ['At iteration 4 the best fitness is 0.03067998349879906']
# ['At iteration 5 the best fitness is 0.03015343185192476']
# ['At iteration 6 the best fitness is 0.029503644713228812']
# ['At iteration 7 the best fitness is 0.01989693031593099']
# ['At iteration 8 the best fitness is 0.01989693031593099']
# ['At iteration 9 the best fitness is 0.018754201209948466']
# ['At iteration 10 the best fitness is 0.01864216894465606']
# ['At iteration 11 the best fitness is 0.01864216894465606']
# ['At iteration 12 the best fitness is 0.017981178579430875']
# ['At iteration 13 the best fitness is 0.017891552767196953']
# ['At iteration 14 the best fitness is 0.017891552767196953']
# ['At iteration 15 the best fitness is 0.017633878557024425']
# ['At iteration 16 the best fitness is 0.017633878557024425']
# ['At iteration 17 the best fitness is 0.017611472103965943']
# ['At iteration 18 the best fitness is 0.0175442527447905']
# ['At iteration 19 the best fitness is 0.017398610799910376']
# ['At iteration 20 the best fitness is 0.017376204346851894']
# ['At iteration 21 the best fitness is 0.017376204346851894']
# ['At iteration 22 the best fitness is 0.017376204346851894']
# ['At iteration 23 the best fitness is 0.017376204346851894']
# ['At iteration 24 the best fitness is 0.017376204346851894']
# ['At iteration 25 the best fitness is 0.017376204346851894']
# ['At iteration 26 the best fitness is 0.017376204346851894']
# ['At iteration 27 the best fitness is 0.017376204346851894']
# ['At iteration 28 the best fitness is 0.017376204346851894']
# ['At iteration 29 the best fitness is 0.017376204346851894']
#       Selected: 1551/4463 (34.8%), Fitness: 0.0174, Time: 1476.0s
#       Modality: D=35%, S=36%, Sk=34%, V=36%
#     Test Acc: 92.59%, F1: 91.77%, Features: 1551/4463 (34.8%), Model: 3.570MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.03402974823104195']
# ['At iteration 1 the best fitness is 0.021571760330526595']
# ['At iteration 2 the best fitness is 0.021571760330526595']
# ['At iteration 3 the best fitness is 0.021571760330526595']
# ['At iteration 4 the best fitness is 0.021571760330526595']
# ['At iteration 5 the best fitness is 0.021571760330526595']
# ['At iteration 6 the best fitness is 0.021571760330526595']
# ['At iteration 7 the best fitness is 0.021571760330526595']
# ['At iteration 8 the best fitness is 0.021571760330526595']
# ['At iteration 9 the best fitness is 0.021571760330526595']
# ['At iteration 10 the best fitness is 0.021571760330526595']
# ['At iteration 11 the best fitness is 0.021571760330526595']
# ['At iteration 12 the best fitness is 0.021571760330526595']
# ['At iteration 13 the best fitness is 0.021571760330526595']
# ['At iteration 14 the best fitness is 0.021571760330526595']
# ['At iteration 15 the best fitness is 0.021571760330526595']
# ['At iteration 16 the best fitness is 0.021571760330526595']
# ['At iteration 17 the best fitness is 0.021571760330526595']
# ['At iteration 18 the best fitness is 0.021571760330526595']
# ['At iteration 19 the best fitness is 0.021571760330526595']
# ['At iteration 20 the best fitness is 0.021571760330526595']
# ['At iteration 21 the best fitness is 0.021269273214237105']
# ['At iteration 22 the best fitness is 0.021269273214237105']
# ['At iteration 23 the best fitness is 0.020272186053134706']
# ['At iteration 24 the best fitness is 0.020272186053134706']
# ['At iteration 25 the best fitness is 0.020272186053134706']
# ['At iteration 26 the best fitness is 0.020272186053134706']
# ['At iteration 27 the best fitness is 0.020272186053134706']
# ['At iteration 28 the best fitness is 0.020272186053134706']
# ['At iteration 29 the best fitness is 0.020171357014371543']
#       Selected: 1008/4463 (22.6%), Fitness: 0.0202, Time: 1557.4s
#       Modality: D=24%, S=23%, Sk=21%, V=24%
#     Test Acc: 93.52%, F1: 92.10%, Features: 1008/4463 (22.6%), Model: 2.510MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.034141780496334345']
# ['At iteration 1 the best fitness is 0.024792740309209055']
# ['At iteration 2 the best fitness is 0.024792740309209055']
# ['At iteration 3 the best fitness is 0.024792740309209055']
# ['At iteration 4 the best fitness is 0.024792740309209055']
# ['At iteration 5 the best fitness is 0.024792740309209055']
# ['At iteration 6 the best fitness is 0.024792740309209055']
# ['At iteration 7 the best fitness is 0.024792740309209055']
# ['At iteration 8 the best fitness is 0.024792740309209055']
# ['At iteration 9 the best fitness is 0.024792740309209055']
# ['At iteration 10 the best fitness is 0.024792740309209055']
# ['At iteration 11 the best fitness is 0.024792740309209055']
# ['At iteration 12 the best fitness is 0.024535066099036523']
# ['At iteration 13 the best fitness is 0.024411830607214878']
# ['At iteration 14 the best fitness is 0.024411830607214878']
# ['At iteration 15 the best fitness is 0.024411830607214878']
# ['At iteration 16 the best fitness is 0.024411830607214878']
# ['At iteration 17 the best fitness is 0.024411830607214878']
# ['At iteration 18 the best fitness is 0.024411830607214878']
# ['At iteration 19 the best fitness is 0.024411830607214878']
# ['At iteration 20 the best fitness is 0.02418776607663007']
# ['At iteration 21 the best fitness is 0.02418776607663007']
# ['At iteration 22 the best fitness is 0.02418776607663007']
# ['At iteration 23 the best fitness is 0.02418776607663007']
# ['At iteration 24 the best fitness is 0.02418776607663007']
# ['At iteration 25 the best fitness is 0.02418776607663007']
# ['At iteration 26 the best fitness is 0.02418776607663007']
# ['At iteration 27 the best fitness is 0.02418776607663007']
# ['At iteration 28 the best fitness is 0.02418776607663007']
# ['At iteration 29 the best fitness is 0.02418776607663007']
#       Selected: 2159/4463 (48.4%), Fitness: 0.0242, Time: 1095.8s
#       Modality: D=46%, S=45%, Sk=50%, V=49%
#     Test Acc: 95.37%, F1: 93.99%, Features: 2159/4463 (48.4%), Model: 4.758MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.033458383678050686']
# ['At iteration 2 the best fitness is 0.033458383678050686']
# ['At iteration 3 the best fitness is 0.033458383678050686']
# ['At iteration 4 the best fitness is 0.033458383678050686']
# ['At iteration 5 the best fitness is 0.025509746807080444']
# ['At iteration 6 the best fitness is 0.025509746807080444']
# ['At iteration 7 the best fitness is 0.025509746807080444']
# ['At iteration 8 the best fitness is 0.025509746807080444']
# ['At iteration 9 the best fitness is 0.025509746807080444']
# ['At iteration 10 the best fitness is 0.025509746807080444']
# ['At iteration 11 the best fitness is 0.025509746807080444']
# ['At iteration 12 the best fitness is 0.025509746807080444']
# ['At iteration 13 the best fitness is 0.025509746807080444']
# ['At iteration 14 the best fitness is 0.025509746807080444']
# ['At iteration 15 the best fitness is 0.025509746807080444']
# ['At iteration 16 the best fitness is 0.025509746807080444']
# ['At iteration 17 the best fitness is 0.0254985435805512']
# ['At iteration 18 the best fitness is 0.0254985435805512']
# ['At iteration 19 the best fitness is 0.0254985435805512']
# ['At iteration 20 the best fitness is 0.0254985435805512']
# ['At iteration 21 the best fitness is 0.024859959668384498']
# ['At iteration 22 the best fitness is 0.024859959668384498']
# ['At iteration 23 the best fitness is 0.024647098364328927']
# ['At iteration 24 the best fitness is 0.0244454402868026']
# ['At iteration 25 the best fitness is 0.0244454402868026']
# ['At iteration 26 the best fitness is 0.0244454402868026']
# ['At iteration 27 the best fitness is 0.0244454402868026']
# ['At iteration 28 the best fitness is 0.0244454402868026']
# ['At iteration 29 the best fitness is 0.0244454402868026']
#       Selected: 2182/4463 (48.9%), Fitness: 0.0244, Time: 1040.5s
#       Modality: D=52%, S=47%, Sk=50%, V=48%
#     Test Acc: 96.30%, F1: 94.87%, Features: 2182/4463 (48.9%), Model: 4.803MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.025207259690790948']
# ['At iteration 2 the best fitness is 0.025207259690790948']
# ['At iteration 3 the best fitness is 0.025207259690790948']
# ['At iteration 4 the best fitness is 0.025207259690790948']
# ['At iteration 5 the best fitness is 0.025207259690790948']
# ['At iteration 6 the best fitness is 0.024803943535738296']
# ['At iteration 7 the best fitness is 0.024803943535738296']
# ['At iteration 8 the best fitness is 0.02474792740309209']
# ['At iteration 9 the best fitness is 0.02474792740309209']
# ['At iteration 10 the best fitness is 0.02474792740309209']
# ['At iteration 11 the best fitness is 0.02474792740309209']
# ['At iteration 12 the best fitness is 0.02474792740309209']
# ['At iteration 13 the best fitness is 0.02474792740309209']
# ['At iteration 14 the best fitness is 0.02474792740309209']
# ['At iteration 15 the best fitness is 0.02474792740309209']
# ['At iteration 16 the best fitness is 0.02474792740309209']
# ['At iteration 17 the best fitness is 0.02474792740309209']
# ['At iteration 18 the best fitness is 0.02474792740309209']
# ['At iteration 19 the best fitness is 0.02474792740309209']
# ['At iteration 20 the best fitness is 0.02474792740309209']
# ['At iteration 21 the best fitness is 0.02474792740309209']
# ['At iteration 22 the best fitness is 0.02474792740309209']
# ['At iteration 23 the best fitness is 0.02474792740309209']
# ['At iteration 24 the best fitness is 0.02474792740309209']
# ['At iteration 25 the best fitness is 0.02474792740309209']
# ['At iteration 26 the best fitness is 0.02474792740309209']
# ['At iteration 27 the best fitness is 0.02474792740309209']
# ['At iteration 28 the best fitness is 0.02474792740309209']
# ['At iteration 29 the best fitness is 0.02474792740309209']
# ['At iteration 30 the best fitness is 0.02474792740309209']
#       Selected: 2209/4463 (49.5%), Fitness: 0.0247, Time: 1069.7s
#       Modality: D=52%, S=53%, Sk=47%, V=50%
#     Test Acc: 94.44%, F1: 93.54%, Features: 2209/4463 (49.5%), Model: 4.856MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03404095145757118']
# ['At iteration 2 the best fitness is 0.03363763530251853']
# ['At iteration 3 the best fitness is 0.03363763530251853']
# ['At iteration 4 the best fitness is 0.024837553215326016']
# ['At iteration 5 the best fitness is 0.024837553215326016']
# ['At iteration 6 the best fitness is 0.024837553215326016']
# ['At iteration 7 the best fitness is 0.024837553215326016']
# ['At iteration 8 the best fitness is 0.024535066099036523']
# ['At iteration 9 the best fitness is 0.024535066099036523']
# ['At iteration 10 the best fitness is 0.024535066099036523']
# ['At iteration 11 the best fitness is 0.024535066099036523']
# ['At iteration 12 the best fitness is 0.024333408021510197']
# ['At iteration 13 the best fitness is 0.024333408021510197']
# ['At iteration 14 the best fitness is 0.024333408021510197']
# ['At iteration 15 the best fitness is 0.024333408021510197']
# ['At iteration 16 the best fitness is 0.024333408021510197']
# ['At iteration 17 the best fitness is 0.024333408021510197']
# ['At iteration 18 the best fitness is 0.024333408021510197']
# ['At iteration 19 the best fitness is 0.024333408021510197']
# ['At iteration 20 the best fitness is 0.02414295317051311']
# ['At iteration 21 the best fitness is 0.02414295317051311']
# ['At iteration 22 the best fitness is 0.02414295317051311']
# ['At iteration 23 the best fitness is 0.02414295317051311']
# ['At iteration 24 the best fitness is 0.02414295317051311']
# ['At iteration 25 the best fitness is 0.02414295317051311']
# ['At iteration 26 the best fitness is 0.02414295317051311']
# ['At iteration 27 the best fitness is 0.024019717678691464']
# ['At iteration 28 the best fitness is 0.024019717678691464']
# ['At iteration 29 the best fitness is 0.024019717678691464']
# ['At iteration 30 the best fitness is 0.023952498319516024']
#       Selected: 2138/4463 (47.9%), Fitness: 0.0240, Time: 1070.3s
#       Modality: D=47%, S=49%, Sk=48%, V=47%
#     Test Acc: 93.52%, F1: 92.18%, Features: 2138/4463 (47.9%), Model: 4.717MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04204560446118763']
# ['At iteration 1 the best fitness is 0.04081324954297118']
# ['At iteration 2 the best fitness is 0.021868698185077303']
# ['At iteration 3 the best fitness is 0.021868698185077303']
# ['At iteration 4 the best fitness is 0.021868698185077303']
# ['At iteration 5 the best fitness is 0.021868698185077303']
# ['At iteration 6 the best fitness is 0.021868698185077303']
# ['At iteration 7 the best fitness is 0.021868698185077303']
# ['At iteration 8 the best fitness is 0.021868698185077303']
# ['At iteration 9 the best fitness is 0.021868698185077303']
# ['At iteration 10 the best fitness is 0.021868698185077303']
# ['At iteration 11 the best fitness is 0.021868698185077303']
# ['At iteration 12 the best fitness is 0.021868698185077303']
# ['At iteration 13 the best fitness is 0.021868698185077303']
# ['At iteration 14 the best fitness is 0.01512435581447457']
# ['At iteration 15 the best fitness is 0.01408245574725521']
# ['At iteration 16 the best fitness is 0.01408245574725521']
# ['At iteration 17 the best fitness is 0.01408245574725521']
# ['At iteration 18 the best fitness is 0.012558816939278511']
# ['At iteration 19 the best fitness is 0.012558816939278511']
# ['At iteration 20 the best fitness is 0.010743894241541565']
# ['At iteration 21 the best fitness is 0.010743894241541565']
# ['At iteration 22 the best fitness is 0.010743894241541565']
# ['At iteration 23 the best fitness is 0.010743894241541565']
# ['At iteration 24 the best fitness is 0.010743894241541565']
# ['At iteration 25 the best fitness is 0.010743894241541565']
# ['At iteration 26 the best fitness is 0.010743894241541565']
# ['At iteration 27 the best fitness is 0.010743894241541565']
# ['At iteration 28 the best fitness is 0.010743894241541565']
# ['At iteration 29 the best fitness is 0.010743894241541565']
#       Selected: 959/4463 (21.5%), Fitness: 0.0107, Time: 1023.1s
#       Modality: D=21%, S=24%, Sk=21%, V=21%
#     Test Acc: 95.37%, F1: 95.47%, Features: 959/4463 (21.5%), Model: 2.414MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03372726111475245']
# ['At iteration 2 the best fitness is 0.03372726111475245']
# ['At iteration 3 the best fitness is 0.03372726111475245']
# ['At iteration 4 the best fitness is 0.02524086937037867']
# ['At iteration 5 the best fitness is 0.02524086937037867']
# ['At iteration 6 the best fitness is 0.02524086937037867']
# ['At iteration 7 the best fitness is 0.024378220927627158']
# ['At iteration 8 the best fitness is 0.024378220927627158']
# ['At iteration 9 the best fitness is 0.024378220927627158']
# ['At iteration 10 the best fitness is 0.024098140264396148']
# ['At iteration 11 the best fitness is 0.024098140264396148']
# ['At iteration 12 the best fitness is 0.024098140264396148']
# ['At iteration 13 the best fitness is 0.024098140264396148']
# ['At iteration 14 the best fitness is 0.024098140264396148']
# ['At iteration 15 the best fitness is 0.024098140264396148']
# ['At iteration 16 the best fitness is 0.024098140264396148']
# ['At iteration 17 the best fitness is 0.024098140264396148']
# ['At iteration 18 the best fitness is 0.024098140264396148']
# ['At iteration 19 the best fitness is 0.024098140264396148']
# ['At iteration 20 the best fitness is 0.024098140264396148']
# ['At iteration 21 the best fitness is 0.024098140264396148']
# ['At iteration 22 the best fitness is 0.024098140264396148']
# ['At iteration 23 the best fitness is 0.024098140264396148']
# ['At iteration 24 the best fitness is 0.024098140264396148']
# ['At iteration 25 the best fitness is 0.024098140264396148']
# ['At iteration 26 the best fitness is 0.024098140264396148']
# ['At iteration 27 the best fitness is 0.024098140264396148']
# ['At iteration 28 the best fitness is 0.024098140264396148']
# ['At iteration 29 the best fitness is 0.024098140264396148']
#       Selected: 2151/4463 (48.2%), Fitness: 0.0241, Time: 2585.4s
#       Modality: D=51%, S=44%, Sk=49%, V=48%
#     Test Acc: 96.30%, F1: 96.05%, Features: 2151/4463 (48.2%), Model: 4.742MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03423140630856827']
# ['At iteration 1 the best fitness is 0.015466001872090565']
# ['At iteration 2 the best fitness is 0.007663006946000449']
# ['At iteration 3 the best fitness is 0.007663006946000449']
# ['At iteration 4 the best fitness is 0.007663006946000449']
# ['At iteration 5 the best fitness is 0.007663006946000449']
# ['At iteration 6 the best fitness is 0.007663006946000449']
# ['At iteration 7 the best fitness is 0.007663006946000449']
# ['At iteration 8 the best fitness is 0.007663006946000449']
# ['At iteration 9 the best fitness is 0.007663006946000449']
# ['At iteration 10 the best fitness is 0.007663006946000449']
# ['At iteration 11 the best fitness is 0.007663006946000449']
# ['At iteration 12 the best fitness is 0.007663006946000449']
# ['At iteration 13 the best fitness is 0.007663006946000449']
# ['At iteration 14 the best fitness is 0.007663006946000449']
# ['At iteration 15 the best fitness is 0.007663006946000449']
# ['At iteration 16 the best fitness is 0.007663006946000449']
# ['At iteration 17 the best fitness is 0.007663006946000449']
# ['At iteration 18 the best fitness is 0.007663006946000449']
# ['At iteration 19 the best fitness is 0.007663006946000449']
# ['At iteration 20 the best fitness is 0.007663006946000449']
# ['At iteration 21 the best fitness is 0.007663006946000449']
# ['At iteration 22 the best fitness is 0.007562177907237285']
# ['At iteration 23 the best fitness is 0.007562177907237285']
# ['At iteration 24 the best fitness is 0.007528568227649563']
# ['At iteration 25 the best fitness is 0.007528568227649563']
# ['At iteration 26 the best fitness is 0.007528568227649563']
# ['At iteration 27 the best fitness is 0.007528568227649563']
# ['At iteration 28 the best fitness is 0.007528568227649563']
# ['At iteration 29 the best fitness is 0.007528568227649563']
#       Selected: 672/4463 (15.1%), Fitness: 0.0075, Time: 983.8s
#       Modality: D=15%, S=17%, Sk=14%, V=16%
#     Test Acc: 92.59%, F1: 91.44%, Features: 672/4463 (15.1%), Model: 1.854MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Applying weights from weighted_GWO: [depth=0.727, sensor=1.000, skeleton=0.645, video=0.130]
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 92.59%, F1: 90.89%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 55.3s
#     Test Acc: 91.67%, F1: 90.03%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 9.4s
#     Test Acc: 94.44%, F1: 94.34%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 2.9s
#     Test Acc: 84.26%, F1: 82.59%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02493838225408918']
# ['At iteration 1 the best fitness is 0.02493838225408918']
# ['At iteration 2 the best fitness is 0.02493838225408918']
# ['At iteration 3 the best fitness is 0.02493838225408918']
# ['At iteration 4 the best fitness is 0.02493838225408918']
# ['At iteration 5 the best fitness is 0.02493838225408918']
# ['At iteration 6 the best fitness is 0.024826349988796775']
# ['At iteration 7 the best fitness is 0.024826349988796775']
# ['At iteration 8 the best fitness is 0.024826349988796775']
# ['At iteration 9 the best fitness is 0.024826349988796775']
# ['At iteration 10 the best fitness is 0.024826349988796775']
# ['At iteration 11 the best fitness is 0.024826349988796775']
# ['At iteration 12 the best fitness is 0.024826349988796775']
# ['At iteration 13 the best fitness is 0.024826349988796775']
# ['At iteration 14 the best fitness is 0.024826349988796775']
# ['At iteration 15 the best fitness is 0.024826349988796775']
# ['At iteration 16 the best fitness is 0.024826349988796775']
# ['At iteration 17 the best fitness is 0.024826349988796775']
# ['At iteration 18 the best fitness is 0.024826349988796775']
# ['At iteration 19 the best fitness is 0.024826349988796775']
# ['At iteration 20 the best fitness is 0.024826349988796775']
# ['At iteration 21 the best fitness is 0.024826349988796775']
# ['At iteration 22 the best fitness is 0.024826349988796775']
# ['At iteration 23 the best fitness is 0.024826349988796775']
# ['At iteration 24 the best fitness is 0.024826349988796775']
# ['At iteration 25 the best fitness is 0.024826349988796775']
# ['At iteration 26 the best fitness is 0.024826349988796775']
# ['At iteration 27 the best fitness is 0.024826349988796775']
# ['At iteration 28 the best fitness is 0.024826349988796775']
# ['At iteration 29 the best fitness is 0.024826349988796775']
#       Selected: 2216/4463 (49.7%), Fitness: 0.0248, Time: 1112.3s
#       Modality: D=50%, S=52%, Sk=51%, V=47%
#     Test Acc: 91.67%, F1: 90.03%, Features: 2216/4463 (49.7%), Model: 4.869MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04280742386517598']
# ['At iteration 1 the best fitness is 0.033335148186229034']
# ['At iteration 2 the best fitness is 0.02472552095003361']
# ['At iteration 3 the best fitness is 0.02471431772350437']
# ['At iteration 4 the best fitness is 0.02471431772350437']
# ['At iteration 5 the best fitness is 0.02471431772350437']
# ['At iteration 6 the best fitness is 0.02471431772350437']
# ['At iteration 7 the best fitness is 0.02471431772350437']
# ['At iteration 8 the best fitness is 0.0245014564194488']
# ['At iteration 9 the best fitness is 0.0245014564194488']
# ['At iteration 10 the best fitness is 0.0245014564194488']
# ['At iteration 11 the best fitness is 0.0245014564194488']
# ['At iteration 12 the best fitness is 0.0245014564194488']
# ['At iteration 13 the best fitness is 0.0245014564194488']
# ['At iteration 14 the best fitness is 0.0245014564194488']
# ['At iteration 15 the best fitness is 0.0245014564194488']
# ['At iteration 16 the best fitness is 0.0245014564194488']
# ['At iteration 17 the best fitness is 0.0245014564194488']
# ['At iteration 18 the best fitness is 0.0245014564194488']
# ['At iteration 19 the best fitness is 0.0245014564194488']
# ['At iteration 20 the best fitness is 0.0245014564194488']
# ['At iteration 21 the best fitness is 0.0245014564194488']
# ['At iteration 22 the best fitness is 0.0245014564194488']
# ['At iteration 23 the best fitness is 0.0245014564194488']
# ['At iteration 24 the best fitness is 0.0245014564194488']
# ['At iteration 25 the best fitness is 0.0245014564194488']
# ['At iteration 26 the best fitness is 0.0245014564194488']
# ['At iteration 27 the best fitness is 0.0245014564194488']
# ['At iteration 28 the best fitness is 0.0245014564194488']
# ['At iteration 29 the best fitness is 0.0245014564194488']
#       Selected: 2187/4463 (49.0%), Fitness: 0.0245, Time: 2151.3s
#       Modality: D=50%, S=49%, Sk=48%, V=51%
#     Test Acc: 91.67%, F1: 91.24%, Features: 2187/4463 (49.0%), Model: 4.813MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024848756441855257']
# ['At iteration 2 the best fitness is 0.024848756441855257']
# ['At iteration 3 the best fitness is 0.024848756441855257']
# ['At iteration 4 the best fitness is 0.024848756441855257']
# ['At iteration 5 the best fitness is 0.02473672417656285']
# ['At iteration 6 the best fitness is 0.02473672417656285']
# ['At iteration 7 the best fitness is 0.02473672417656285']
# ['At iteration 8 the best fitness is 0.024523862872507282']
# ['At iteration 9 the best fitness is 0.024523862872507282']
# ['At iteration 10 the best fitness is 0.024523862872507282']
# ['At iteration 11 the best fitness is 0.024523862872507282']
# ['At iteration 12 the best fitness is 0.024523862872507282']
# ['At iteration 13 the best fitness is 0.024523862872507282']
# ['At iteration 14 the best fitness is 0.024523862872507282']
# ['At iteration 15 the best fitness is 0.024075733811337666']
# ['At iteration 16 the best fitness is 0.024075733811337666']
# ['At iteration 17 the best fitness is 0.024075733811337666']
# ['At iteration 18 the best fitness is 0.024075733811337666']
# ['At iteration 19 the best fitness is 0.024075733811337666']
# ['At iteration 20 the best fitness is 0.024075733811337666']
# ['At iteration 21 the best fitness is 0.024075733811337666']
# ['At iteration 22 the best fitness is 0.024075733811337666']
# ['At iteration 23 the best fitness is 0.023750840241989694']
# ['At iteration 24 the best fitness is 0.023750840241989694']
# ['At iteration 25 the best fitness is 0.023750840241989694']
# ['At iteration 26 the best fitness is 0.023750840241989694']
# ['At iteration 27 the best fitness is 0.023750840241989694']
# ['At iteration 28 the best fitness is 0.023750840241989694']
# ['At iteration 29 the best fitness is 0.023750840241989694']
# ['At iteration 30 the best fitness is 0.023750840241989694']
#       Selected: 2120/4463 (47.5%), Fitness: 0.0238, Time: 1102.9s
#       Modality: D=48%, S=50%, Sk=47%, V=47%
#     Test Acc: 91.67%, F1: 89.18%, Features: 2120/4463 (47.5%), Model: 4.682MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05087929622796786']
# ['At iteration 1 the best fitness is 0.041743117344898134']
# ['At iteration 2 the best fitness is 0.033189506241348914']
# ['At iteration 3 the best fitness is 0.03305506752299803']
# ['At iteration 4 the best fitness is 0.03305506752299803']
# ['At iteration 5 the best fitness is 0.032640548141416134']
# ['At iteration 6 the best fitness is 0.03307747397605651']
# ['At iteration 7 the best fitness is 0.03266295459447461']
# ['At iteration 8 the best fitness is 0.03275258040670854']
# ['At iteration 9 the best fitness is 0.03277498685976702']
# ['At iteration 10 the best fitness is 0.03266295459447461']
# ['At iteration 11 the best fitness is 0.03262934491488689']
# ['At iteration 12 the best fitness is 0.04164228830613498']
# ['At iteration 13 the best fitness is 0.03275258040670854']
# ['At iteration 14 the best fitness is 0.03261814168835765']
# ['At iteration 15 the best fitness is 0.03269656427406233']
# ['At iteration 16 the best fitness is 0.032718970727120815']
# ['At iteration 17 the best fitness is 0.04157506894695953']
# ['At iteration 18 the best fitness is 0.03266295459447461']
# ['At iteration 19 the best fitness is 0.04158627217348877']
# ['At iteration 20 the best fitness is 0.032718970727120815']
# ['At iteration 21 the best fitness is 0.03267415782100385']
# ['At iteration 22 the best fitness is 0.032651751367945375']
# ['At iteration 23 the best fitness is 0.023795653148106655']
# ['At iteration 24 the best fitness is 0.023773246695048177']
# ['At iteration 25 the best fitness is 0.04154145926737181']
# ['At iteration 26 the best fitness is 0.023784449921577414']
# ['At iteration 27 the best fitness is 0.023773246695048177']
# ['At iteration 28 the best fitness is 0.04153025604084257']
# ['At iteration 29 the best fitness is 0.03266295459447461']
#       Selected: 2123/4463 (47.6%), Fitness: 0.0327, Time: 1028.7s
#       Modality: D=48%, S=47%, Sk=47%, V=48%
#     Test Acc: 89.81%, F1: 88.06%, Features: 2123/4463 (47.6%), Model: 4.688MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.033940122418808026
# At iteration 2 the best fitness is 0.025050414519381583
# At iteration 3 the best fitness is 0.033940122418808026
# At iteration 4 the best fitness is 0.02518485323773247
# At iteration 5 the best fitness is 0.025095227425498547
# At iteration 6 the best fitness is 0.03404095145757118
# At iteration 7 the best fitness is 0.03404095145757118
# At iteration 8 the best fitness is 0.025162446784673987
# At iteration 9 the best fitness is 0.025252072596907912
# At iteration 10 the best fitness is 0.025095227425498547
# At iteration 11 the best fitness is 0.03408576436368815
# At iteration 12 the best fitness is 0.03389530951269106
# At iteration 13 the best fitness is 0.03411937404327587
# At iteration 14 the best fitness is 0.03395132564533726
# At iteration 15 the best fitness is 0.03434343857386068
# At iteration 16 the best fitness is 0.03425381276162675
# At iteration 17 the best fitness is 0.05170833499113166
# At iteration 18 the best fitness is 0.03423140630856827
# At iteration 19 the best fitness is 0.02547613712749272
# At iteration 20 the best fitness is 0.025162446784673987
# At iteration 21 the best fitness is 0.03439945470650688
# At iteration 22 the best fitness is 0.02552095003360968
# At iteration 23 the best fitness is 0.025375308088729554
# At iteration 24 the best fitness is 0.025386511315258792
# At iteration 25 the best fitness is 0.025442527447904997
# At iteration 26 the best fitness is 0.024960788707147658
# At iteration 27 the best fitness is 0.025039211292852345
# At iteration 28 the best fitness is 0.025386511315258792
# At iteration 29 the best fitness is 0.03372726111475245
# At iteration 30 the best fitness is 0.024927179027559938
#       Selected: 2225/4463 (49.9%), Fitness: 0.0249, Time: 1062.7s
#       Modality: D=54%, S=52%, Sk=49%, V=48%
#     Test Acc: 92.59%, F1: 90.89%, Features: 2225/4463 (49.9%), Model: 4.887MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03392891919227878']
# ['At iteration 1 the best fitness is 0.03392891919227878']
# ['At iteration 2 the best fitness is 0.032237231986363475']
# ['At iteration 3 the best fitness is 0.03149781903543361']
# ['At iteration 4 the best fitness is 0.022440062738068565']
# ['At iteration 5 the best fitness is 0.021846291732018824']
# ['At iteration 6 the best fitness is 0.021846291732018824']
# ['At iteration 7 the best fitness is 0.021846291732018824']
# ['At iteration 8 the best fitness is 0.021846291732018824']
# ['At iteration 9 the best fitness is 0.021062065874971992']
# ['At iteration 10 the best fitness is 0.02046829486892225']
# ['At iteration 11 the best fitness is 0.020154604526103518']
# ['At iteration 12 the best fitness is 0.020154604526103518']
# ['At iteration 13 the best fitness is 0.020154604526103518']
# ['At iteration 14 the best fitness is 0.020154604526103518']
# ['At iteration 15 the best fitness is 0.020154604526103518']
# ['At iteration 16 the best fitness is 0.020154604526103518']
# ['At iteration 17 the best fitness is 0.020154604526103518']
# ['At iteration 18 the best fitness is 0.020154604526103518']
# ['At iteration 19 the best fitness is 0.020053775487340355']
# ['At iteration 20 the best fitness is 0.020053775487340355']
# ['At iteration 21 the best fitness is 0.020053775487340355']
# ['At iteration 22 the best fitness is 0.020053775487340355']
# ['At iteration 23 the best fitness is 0.019796101277167827']
# ['At iteration 24 the best fitness is 0.019796101277167827']
# ['At iteration 25 the best fitness is 0.019796101277167827']
# ['At iteration 26 the best fitness is 0.019796101277167827']
# ['At iteration 27 the best fitness is 0.019796101277167827']
# ['At iteration 28 the best fitness is 0.019796101277167827']
# ['At iteration 29 the best fitness is 0.019796101277167827']
#       Selected: 1767/4463 (39.6%), Fitness: 0.0198, Time: 1035.4s
#       Modality: D=41%, S=36%, Sk=40%, V=41%
#     Test Acc: 89.81%, F1: 88.34%, Features: 1767/4463 (39.6%), Model: 3.992MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.04265057869376661']
# ['At iteration 1 the best fitness is 0.02114603772241546']
# ['At iteration 2 the best fitness is 0.02114603772241546']
# ['At iteration 3 the best fitness is 0.02114603772241546']
# ['At iteration 4 the best fitness is 0.02114603772241546']
# ['At iteration 5 the best fitness is 0.012368362088281425']
# ['At iteration 6 the best fitness is 0.012368362088281425']
# ['At iteration 7 the best fitness is 0.012368362088281425']
# ['At iteration 8 the best fitness is 0.012368362088281425']
# ['At iteration 9 the best fitness is 0.012368362088281425']
# ['At iteration 10 the best fitness is 0.012368362088281425']
# ['At iteration 11 the best fitness is 0.012368362088281425']
# ['At iteration 12 the best fitness is 0.012368362088281425']
# ['At iteration 13 the best fitness is 0.012368362088281425']
# ['At iteration 14 the best fitness is 0.012368362088281425']
# ['At iteration 15 the best fitness is 0.012368362088281425']
# ['At iteration 16 the best fitness is 0.012368362088281425']
# ['At iteration 17 the best fitness is 0.012368362088281425']
# ['At iteration 18 the best fitness is 0.012368362088281425']
# ['At iteration 19 the best fitness is 0.012368362088281425']
# ['At iteration 20 the best fitness is 0.012368362088281425']
# ['At iteration 21 the best fitness is 0.012368362088281425']
# ['At iteration 22 the best fitness is 0.012368362088281425']
# ['At iteration 23 the best fitness is 0.012368362088281425']
# ['At iteration 24 the best fitness is 0.012368362088281425']
# ['At iteration 25 the best fitness is 0.012368362088281425']
# ['At iteration 26 the best fitness is 0.010990365225184854']
# ['At iteration 27 the best fitness is 0.010990365225184854']
# ['At iteration 28 the best fitness is 0.010990365225184854']
# ['At iteration 29 the best fitness is 0.010990365225184854']
#       Selected: 981/4463 (22.0%), Fitness: 0.0110, Time: 1224.7s
#       Modality: D=25%, S=22%, Sk=22%, V=21%
#     Test Acc: 95.37%, F1: 94.79%, Features: 981/4463 (22.0%), Model: 2.457MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02471431772350437']
# ['At iteration 1 the best fitness is 0.02471431772350437']
# ['At iteration 2 the best fitness is 0.02471431772350437']
# ['At iteration 3 the best fitness is 0.02471431772350437']
# ['At iteration 4 the best fitness is 0.02471431772350437']
# ['At iteration 5 the best fitness is 0.02471431772350437']
# ['At iteration 6 the best fitness is 0.02471431772350437']
# ['At iteration 7 the best fitness is 0.02471431772350437']
# ['At iteration 8 the best fitness is 0.02471431772350437']
# ['At iteration 9 the best fitness is 0.02471431772350437']
# ['At iteration 10 the best fitness is 0.02471431772350437']
# ['At iteration 11 the best fitness is 0.02471431772350437']
# ['At iteration 12 the best fitness is 0.02471431772350437']
# ['At iteration 13 the best fitness is 0.02471431772350437']
# ['At iteration 14 the best fitness is 0.02471431772350437']
# ['At iteration 15 the best fitness is 0.02471431772350437']
# ['At iteration 16 the best fitness is 0.02471431772350437']
# ['At iteration 17 the best fitness is 0.02471431772350437']
# ['At iteration 18 the best fitness is 0.02471431772350437']
# ...
# ['At iteration 17 the best fitness is 0.004559713197400852']
# ['At iteration 18 the best fitness is 0.004559713197400852']
# ['At iteration 19 the best fitness is 0.004559713197400852']
# ['At iteration 20 the best fitness is 0.004559713197400852']
# ['At iteration 21 the best fitness is 0.004559713197400852']
# ['At iteration 22 the best fitness is 0.004559713197400852']
# ['At iteration 23 the best fitness is 0.004559713197400852']
# ['At iteration 24 the best fitness is 0.004559713197400852']
# ['At iteration 25 the best fitness is 0.004559713197400852']
# ['At iteration 26 the best fitness is 0.004559713197400852']
# ['At iteration 27 the best fitness is 0.004559713197400852']
# ['At iteration 28 the best fitness is 0.004559713197400852']
# ['At iteration 29 the best fitness is 0.00453730674434237']
#       Selected: 405/4463 (9.1%), Fitness: 0.0045, Time: 1622.2s
#       Modality: D=10%, S=9%, Sk=9%, V=9%
#     Test Acc: 97.20%, F1: 97.21%, Features: 405/4463 (9.1%), Model: 1.332MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03348079013110916']
# ['At iteration 1 the best fitness is 0.03348079013110916']
# ['At iteration 2 the best fitness is 0.03348079013110916']
# ['At iteration 3 the best fitness is 0.03348079013110916']
# ['At iteration 4 the best fitness is 0.033279132053582836']
# ['At iteration 5 the best fitness is 0.033200709467878155']
# ['At iteration 6 the best fitness is 0.033200709467878155']
# ['At iteration 7 the best fitness is 0.024613488684741208']
# ['At iteration 8 the best fitness is 0.024613488684741208']
# ['At iteration 9 the best fitness is 0.024613488684741208']
# ['At iteration 10 the best fitness is 0.024613488684741208']
# ['At iteration 11 the best fitness is 0.024613488684741208']
# ['At iteration 12 the best fitness is 0.024613488684741208']
# ['At iteration 13 the best fitness is 0.024613488684741208']
# ['At iteration 14 the best fitness is 0.024613488684741208']
# ['At iteration 15 the best fitness is 0.024613488684741208']
# ['At iteration 16 the best fitness is 0.02459108223168273']
# ['At iteration 17 the best fitness is 0.02418776607663007']
# ['At iteration 18 the best fitness is 0.02418776607663007']
# ['At iteration 19 the best fitness is 0.02418776607663007']
# ['At iteration 20 the best fitness is 0.02418776607663007']
# ['At iteration 21 the best fitness is 0.02418776607663007']
# ['At iteration 22 the best fitness is 0.02418776607663007']
# ['At iteration 23 the best fitness is 0.02418776607663007']
# ['At iteration 24 the best fitness is 0.02418776607663007']
# ['At iteration 25 the best fitness is 0.02418776607663007']
# ['At iteration 26 the best fitness is 0.02418776607663007']
# ['At iteration 27 the best fitness is 0.02418776607663007']
# ['At iteration 28 the best fitness is 0.02418776607663007']
# ['At iteration 29 the best fitness is 0.02418776607663007']
#       Selected: 2159/4463 (48.4%), Fitness: 0.0242, Time: 1485.7s
#       Modality: D=47%, S=50%, Sk=48%, V=49%
#     Test Acc: 100.00%, F1: 100.00%, Features: 2159/4463 (48.4%), Model: 4.758MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03299905139035183']
# ['At iteration 2 the best fitness is 0.03299905139035183']
# ['At iteration 3 the best fitness is 0.03299905139035183']
# ['At iteration 4 the best fitness is 0.02522966614384943']
# ['At iteration 5 the best fitness is 0.02522966614384943']
# ['At iteration 6 the best fitness is 0.02522966614384943']
# ['At iteration 7 the best fitness is 0.02522966614384943']
# ['At iteration 8 the best fitness is 0.02522966614384943']
# ['At iteration 9 the best fitness is 0.02470311449697513']
# ['At iteration 10 the best fitness is 0.02470311449697513']
# ['At iteration 11 the best fitness is 0.02470311449697513']
# ['At iteration 12 the best fitness is 0.02470311449697513']
# ['At iteration 13 the best fitness is 0.02470311449697513']
# ['At iteration 14 the best fitness is 0.02470311449697513']
# ['At iteration 15 the best fitness is 0.02465830159085817']
# ['At iteration 16 the best fitness is 0.02465830159085817']
# ['At iteration 17 the best fitness is 0.02465830159085817']
# ['At iteration 18 the best fitness is 0.02465830159085817']
# ['At iteration 19 the best fitness is 0.02465830159085817']
# ['At iteration 20 the best fitness is 0.02465830159085817']
# ['At iteration 21 the best fitness is 0.02465830159085817']
# ['At iteration 22 the best fitness is 0.02463589513779969']
# ['At iteration 23 the best fitness is 0.02463589513779969']
# ['At iteration 24 the best fitness is 0.02463589513779969']
# ['At iteration 25 the best fitness is 0.02463589513779969']
# ['At iteration 26 the best fitness is 0.024579879005153488']
# ['At iteration 27 the best fitness is 0.024579879005153488']
# ['At iteration 28 the best fitness is 0.024579879005153488']
# ['At iteration 29 the best fitness is 0.024579879005153488']
#       Selected: 2194/4463 (49.2%), Fitness: 0.0246, Time: 1418.9s
#       Modality: D=44%, S=51%, Sk=49%, V=50%
#     Test Acc: 99.07%, F1: 98.94%, Features: 2194/4463 (49.2%), Model: 4.826MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.042706594826412814']
# ['At iteration 2 the best fitness is 0.033828090153515615']
# ['At iteration 3 the best fitness is 0.033828090153515615']
# ['At iteration 4 the best fitness is 0.033828090153515615']
# ['At iteration 5 the best fitness is 0.033828090153515615']
# ['At iteration 6 the best fitness is 0.033828090153515615']
# ['At iteration 7 the best fitness is 0.02542012099484652']
# ['At iteration 8 the best fitness is 0.02542012099484652']
# ['At iteration 9 the best fitness is 0.025061617745910827']
# ['At iteration 10 the best fitness is 0.025061617745910827']
# ['At iteration 11 the best fitness is 0.025061617745910827']
# ['At iteration 12 the best fitness is 0.025061617745910827']
# ['At iteration 13 the best fitness is 0.025061617745910827']
# ['At iteration 14 the best fitness is 0.025061617745910827']
# ['At iteration 15 the best fitness is 0.024915975801030697']
# ['At iteration 16 the best fitness is 0.024915975801030697']
# ['At iteration 17 the best fitness is 0.024915975801030697']
# ['At iteration 18 the best fitness is 0.024915975801030697']
# ['At iteration 19 the best fitness is 0.024915975801030697']
# ['At iteration 20 the best fitness is 0.024915975801030697']
# ['At iteration 21 the best fitness is 0.024915975801030697']
# ['At iteration 22 the best fitness is 0.024915975801030697']
# ['At iteration 23 the best fitness is 0.024882366121442977']
# ['At iteration 24 the best fitness is 0.024882366121442977']
# ['At iteration 25 the best fitness is 0.024882366121442977']
# ['At iteration 26 the best fitness is 0.024882366121442977']
# ['At iteration 27 the best fitness is 0.024882366121442977']
# ['At iteration 28 the best fitness is 0.024882366121442977']
# ['At iteration 29 the best fitness is 0.024803943535738296']
# ['At iteration 30 the best fitness is 0.024803943535738296']
#       Selected: 2214/4463 (49.6%), Fitness: 0.0248, Time: 1451.3s
#       Modality: D=47%, S=53%, Sk=51%, V=48%
#     Test Acc: 97.20%, F1: 96.54%, Features: 2214/4463 (49.6%), Model: 4.865MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04252734320194497']
# ['At iteration 2 the best fitness is 0.033682448208635495']
# ['At iteration 3 the best fitness is 0.024848756441855257']
# ['At iteration 4 the best fitness is 0.024848756441855257']
# ['At iteration 5 the best fitness is 0.024848756441855257']
# ['At iteration 6 the best fitness is 0.024848756441855257']
# ['At iteration 7 the best fitness is 0.024848756441855257']
# ['At iteration 8 the best fitness is 0.024848756441855257']
# ['At iteration 9 the best fitness is 0.024848756441855257']
# ['At iteration 10 the best fitness is 0.024848756441855257']
# ['At iteration 11 the best fitness is 0.024848756441855257']
# ['At iteration 12 the best fitness is 0.024848756441855257']
# ['At iteration 13 the best fitness is 0.024848756441855257']
# ['At iteration 14 the best fitness is 0.024848756441855257']
# ['At iteration 15 the best fitness is 0.024848756441855257']
# ['At iteration 16 the best fitness is 0.024848756441855257']
# ['At iteration 17 the best fitness is 0.024848756441855257']
# ['At iteration 18 the best fitness is 0.024602285458211966']
# ['At iteration 19 the best fitness is 0.024602285458211966']
# ['At iteration 20 the best fitness is 0.024602285458211966']
# ['At iteration 21 the best fitness is 0.02435581447456868']
# ['At iteration 22 the best fitness is 0.02435581447456868']
# ['At iteration 23 the best fitness is 0.02435581447456868']
# ['At iteration 24 the best fitness is 0.02435581447456868']
# ['At iteration 25 the best fitness is 0.02435581447456868']
# ['At iteration 26 the best fitness is 0.02435581447456868']
# ['At iteration 27 the best fitness is 0.02435581447456868']
# ['At iteration 28 the best fitness is 0.02435581447456868']
# ['At iteration 29 the best fitness is 0.02435581447456868']
# ['At iteration 30 the best fitness is 0.02414295317051311']
#       Selected: 2155/4463 (48.3%), Fitness: 0.0241, Time: 1386.7s
#       Modality: D=46%, S=48%, Sk=49%, V=49%
#     Test Acc: 100.00%, F1: 100.00%, Features: 2155/4463 (48.3%), Model: 4.750MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05118178334425735']
# ['At iteration 1 the best fitness is 0.038090865496365756']
# ['At iteration 2 the best fitness is 0.030299073796804882']
# ['At iteration 3 the best fitness is 0.030299073796804882']
# ['At iteration 4 the best fitness is 0.027520673617553254']
# ['At iteration 5 the best fitness is 0.027520673617553254']
# ['At iteration 6 the best fitness is 0.027520673617553254']
# ['At iteration 7 the best fitness is 0.027520673617553254']
# ['At iteration 8 the best fitness is 0.027520673617553254']
# ['At iteration 9 the best fitness is 0.02281531847527228']
# ['At iteration 10 the best fitness is 0.02281531847527228']
# ['At iteration 11 the best fitness is 0.019499163422617115']
# ['At iteration 12 the best fitness is 0.018053947200345102']
# ['At iteration 13 the best fitness is 0.009780416760026889']
# ['At iteration 14 the best fitness is 0.009780416760026889']
# ['At iteration 15 the best fitness is 0.009780416760026889']
# ['At iteration 16 the best fitness is 0.00849204570916424']
# ['At iteration 17 the best fitness is 0.00849204570916424']
# ['At iteration 18 the best fitness is 0.00849204570916424']
# ['At iteration 19 the best fitness is 0.00849204570916424']
# ['At iteration 20 the best fitness is 0.00849204570916424']
# ['At iteration 21 the best fitness is 0.00849204570916424']
# ['At iteration 22 the best fitness is 0.00849204570916424']
# ['At iteration 23 the best fitness is 0.00849204570916424']
# ['At iteration 24 the best fitness is 0.00849204570916424']
# ['At iteration 25 the best fitness is 0.00797669728881918']
# ['At iteration 26 the best fitness is 0.007730226305175891']
# ['At iteration 27 the best fitness is 0.007730226305175891']
# ['At iteration 28 the best fitness is 0.007730226305175891']
# ['At iteration 29 the best fitness is 0.007730226305175891']
#       Selected: 690/4463 (15.5%), Fitness: 0.0077, Time: 1411.9s
#       Modality: D=14%, S=16%, Sk=16%, V=14%
#     Test Acc: 98.13%, F1: 98.00%, Features: 690/4463 (15.5%), Model: 1.889MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03362643207598929']
# ['At iteration 2 the best fitness is 0.03362643207598929']
# ['At iteration 3 the best fitness is 0.03355921271681385']
# ['At iteration 4 the best fitness is 0.024535066099036523']
# ['At iteration 5 the best fitness is 0.024535066099036523']
# ['At iteration 6 the best fitness is 0.024535066099036523']
# ['At iteration 7 the best fitness is 0.024535066099036523']
# ['At iteration 8 the best fitness is 0.024535066099036523']
# ['At iteration 9 the best fitness is 0.02443423706027336']
# ['At iteration 10 the best fitness is 0.02443423706027336']
# ['At iteration 11 the best fitness is 0.02443423706027336']
# ['At iteration 12 the best fitness is 0.02443423706027336']
# ['At iteration 13 the best fitness is 0.02443423706027336']
# ['At iteration 14 the best fitness is 0.02443423706027336']
# ['At iteration 15 the best fitness is 0.02443423706027336']
# ['At iteration 16 the best fitness is 0.02443423706027336']
# ['At iteration 17 the best fitness is 0.02443423706027336']
# ['At iteration 18 the best fitness is 0.02443423706027336']
# ['At iteration 19 the best fitness is 0.02442303383374412']
# ['At iteration 20 the best fitness is 0.02442303383374412']
# ['At iteration 21 the best fitness is 0.02442303383374412']
# ['At iteration 22 the best fitness is 0.02442303383374412']
# ['At iteration 23 the best fitness is 0.02442303383374412']
# ['At iteration 24 the best fitness is 0.02442303383374412']
# ['At iteration 25 the best fitness is 0.02442303383374412']
# ['At iteration 26 the best fitness is 0.02442303383374412']
# ['At iteration 27 the best fitness is 0.02442303383374412']
# ['At iteration 28 the best fitness is 0.02442303383374412']
# ['At iteration 29 the best fitness is 0.02442303383374412']
#       Selected: 2180/4463 (48.8%), Fitness: 0.0244, Time: 3491.4s
#       Modality: D=47%, S=49%, Sk=50%, V=49%
#     Test Acc: 100.00%, F1: 100.00%, Features: 2180/4463 (48.8%), Model: 4.799MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04194477542242446']
# ['At iteration 1 the best fitness is 0.029722055279023163']
# ['At iteration 2 the best fitness is 0.029722055279023163']
# ['At iteration 3 the best fitness is 0.025263171120385477']
# ['At iteration 4 the best fitness is 0.025263171120385477']
# ['At iteration 5 the best fitness is 0.02217673456310558']
# ['At iteration 6 the best fitness is 0.021168444175473942']
# ['At iteration 7 the best fitness is 0.01779072372843379']
# ['At iteration 8 the best fitness is 0.01779072372843379']
# ['At iteration 9 the best fitness is 0.01779072372843379']
# ['At iteration 10 the best fitness is 0.01779072372843379']
# ['At iteration 11 the best fitness is 0.01779072372843379']
# ['At iteration 12 the best fitness is 0.01779072372843379']
# ['At iteration 13 the best fitness is 0.01779072372843379']
# ['At iteration 14 the best fitness is 0.017118530136679366']
# ['At iteration 15 the best fitness is 0.017118530136679366']
# ['At iteration 16 the best fitness is 0.017118530136679366']
# ['At iteration 17 the best fitness is 0.017118530136679366']
# ['At iteration 18 the best fitness is 0.017118530136679366']
# ['At iteration 19 the best fitness is 0.017118530136679366']
# ['At iteration 20 the best fitness is 0.017118530136679366']
# ['At iteration 21 the best fitness is 0.017118530136679366']
# ['At iteration 22 the best fitness is 0.015998207483755324']
# ['At iteration 23 the best fitness is 0.015998207483755324']
# ['At iteration 24 the best fitness is 0.015852565538875197']
# ['At iteration 25 the best fitness is 0.01487788483083128']
# ['At iteration 26 the best fitness is 0.01487788483083128']
# ['At iteration 27 the best fitness is 0.01487788483083128']
# ['At iteration 28 the best fitness is 0.01487788483083128']
# ['At iteration 29 the best fitness is 0.01487788483083128']
#       Selected: 1328/4463 (29.8%), Fitness: 0.0149, Time: 1335.4s
#       Modality: D=27%, S=29%, Sk=31%, V=29%
#     Test Acc: 99.07%, F1: 98.94%, Features: 1328/4463 (29.8%), Model: 3.135MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          95.370370         99.065421     93.991770
# 1  baseline     2          92.592593        100.000000     90.888782
# 2  baseline     3          88.888889        100.000000     86.567794
# 3  baseline     4          91.666667         99.065421     90.888782
# 4  baseline     5          95.370370         97.196262     93.888889
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        93.991770            92.962963         95.370370               4463
# 1        90.888782            92.116402         92.592593               4463
# 2        86.567794            87.795414         88.888889               4463
# 3        90.888782            93.968254         91.666667               4463
# 4        93.888889            92.901235         95.370370               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              93.97              3.25              92.86              3.80                 4463.00                      100.00              0.00                28.60                28.60          2425371.0                  9.26                        0.00               72.33
# mutual_info              94.31              3.08              93.73              3.35                 2231.00                       49.99             59.23                23.63                82.86          1282587.0                  4.90                       50.01               45.90
#         rfe              95.12              2.88              94.61              3.13                 2231.00                       49.99             10.41                23.47                33.88          1282587.0                  4.90                       50.01               45.90
#       lasso              89.66              7.84              88.50              8.76                 2231.00                       49.99            135.91                23.39               159.30          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              94.55              3.07              93.92              3.48                 2207.38                       49.46           1480.70                23.17              1503.87          1270491.0                  4.85                       50.54               45.72
#     meta_CS              94.54              2.14              93.86              2.63                 2172.88                       48.69           2906.96                23.34              2930.30          1252827.0                  4.79                       51.31               45.44
#     meta_DE              95.25              2.73              94.64              3.32                 2158.38                       48.36           1483.02                23.35              1506.37          1245403.0                  4.76                       51.64               45.33
#    meta_FFA              93.04              4.08              92.16              4.66                 2196.25                       49.21           1410.17                23.54              1433.71          1264795.0                  4.83                       50.79               45.65
#     meta_GA              94.78              2.09              93.83              2.54                 2195.75                       49.20           1439.99                23.56              1463.55          1264539.0                  4.83                       50.80               45.62
#    meta_GWO              93.50              3.97              92.62              4.41                 1673.00                       37.49           1415.13                22.43              1437.56           996891.0                  3.81                       62.51               39.46
#    meta_HHO              91.76              4.12              90.57              4.92                 1010.00                       22.63           1736.71                21.32              1758.03           657435.0                  2.51                       77.37               31.74
#   meta_JAYA              94.08              3.54              93.12              4.27                 2170.75                       48.64           1411.77                22.82              1434.59          1251739.0                  4.78                       51.36               45.43
#    meta_MFO              93.38              3.65              92.20              4.41                 2190.62                       49.08           1347.95                22.47              1370.42          1261915.0                  4.82                       50.92               45.58
#    meta_MVO              93.85              3.53              92.62              4.24                 2172.25                       48.67           1347.96                21.93              1369.90          1252507.0                  4.78                       51.33               45.44
#    meta_PSO              93.85              3.80              93.09              4.41                 2162.25                       48.45           1353.90                22.57              1376.48          1247387.0                  4.76                       51.55               45.36
#    meta_SCA              93.27              3.59              92.37              4.44                  810.88                       18.17           1317.79                20.34              1338.13           555483.0                  2.12                       81.83               29.63
#    meta_SSA              94.78              2.88              93.99              3.58                 2160.62                       48.41           3385.76                22.76              3408.52          1246555.0                  4.76                       51.59               45.34
#    meta_WOA              93.04              3.78              92.04              4.57                  949.25                       21.27           1351.65                21.52              1373.17           626331.0                  2.40                       78.73               31.23

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
print("=" * 80)
print("FILE 2 COMPLETE — FEATURE SELECTION ON WEIGHTED FEATURES")
print("=" * 80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nModality weights used (from File 1):")
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']} -> [{w_str}]")

print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'=' * 80}")
print("RESULTS (sorted by mean test accuracy):")
print("=" * 80)
for _, row in df_summary.iterrows():
    print(f"  {row['Method']:20s} | Acc: {row['Mean Test Acc (%)']:6.2f}% "
          f"(+/-{row['Std Test Acc (%)']:.2f}) | F1: {row['Mean F1 Macro (%)']:6.2f}% "
          f"| Feat: {row['Mean Feature Retention (%)']:.1f}%")
# Out:
# ================================================================================
# FILE 2 COMPLETE — FEATURE SELECTION ON WEIGHTED FEATURES
# ================================================================================
#
# Output directory: results_weighted_fs
#
# Modality weights used (from File 1):
#   Fold 1: weighted_SSA -> [depth=0.995, sensor=0.400, skeleton=1.000, video=0.001]
#   Fold 2: weighted_GWO -> [depth=0.727, sensor=1.000, skeleton=0.645, video=0.130]
#   Fold 3: weighted_CS -> [depth=1.000, sensor=1.000, skeleton=1.000, video=0.005]
#   Fold 4: weighted_FFA -> [depth=0.000, sensor=0.216, skeleton=0.373, video=0.000]
#   Fold 5: weighted_WOA -> [depth=0.151, sensor=0.785, skeleton=0.934, video=0.207]
#   Fold 6: weighted_HHO -> [depth=0.083, sensor=0.233, skeleton=0.360, video=0.183]
#   Fold 7: weighted_CS -> [depth=0.007, sensor=0.582, skeleton=0.902, video=0.000]
#   Fold 8: weighted_DE -> [depth=0.000, sensor=0.606, skeleton=0.976, video=0.018]
#
# Per-method folders:
#   results_weighted_fs/baseline/ (16 files)
#   results_weighted_fs/mutual_info/ (16 files)
#   results_weighted_fs/rfe/ (16 files)
#   results_weighted_fs/lasso/ (16 files)
#   results_weighted_fs/meta_BAT/ (16 files)
#   results_weighted_fs/meta_CS/ (16 files)
#   results_weighted_fs/meta_DE/ (16 files)
#   results_weighted_fs/meta_FFA/ (16 files)
#   results_weighted_fs/meta_GA/ (16 files)
#   results_weighted_fs/meta_GWO/ (16 files)
#   results_weighted_fs/meta_HHO/ (16 files)
#   results_weighted_fs/meta_JAYA/ (16 files)
#   results_weighted_fs/meta_MFO/ (16 files)
#   results_weighted_fs/meta_MVO/ (16 files)
#   results_weighted_fs/meta_PSO/ (16 files)
#   results_weighted_fs/meta_SCA/ (16 files)
#   results_weighted_fs/meta_SSA/ (16 files)
#   results_weighted_fs/meta_WOA/ (16 files)
#
# Plots directory: results_weighted_fs/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_folds_results.csv
#   summary_all_methods.csv
#
# ================================================================================
# RESULTS (sorted by mean test accuracy):
# ================================================================================
#   baseline             | Acc:  93.97% (+/-3.25) | F1:  92.86% | Feat: 100.0%
#   mutual_info          | Acc:  94.31% (+/-3.08) | F1:  93.73% | Feat: 50.0%
#   rfe                  | Acc:  95.12% (+/-2.88) | F1:  94.61% | Feat: 50.0%
#   lasso                | Acc:  89.66% (+/-7.84) | F1:  88.50% | Feat: 50.0%
#   meta_BAT             | Acc:  94.55% (+/-3.07) | F1:  93.92% | Feat: 49.5%
#   meta_CS              | Acc:  94.54% (+/-2.14) | F1:  93.86% | Feat: 48.7%
#   meta_DE              | Acc:  95.25% (+/-2.73) | F1:  94.64% | Feat: 48.4%
#   meta_FFA             | Acc:  93.04% (+/-4.08) | F1:  92.16% | Feat: 49.2%
#   meta_GA              | Acc:  94.78% (+/-2.09) | F1:  93.83% | Feat: 49.2%
#   meta_GWO             | Acc:  93.50% (+/-3.97) | F1:  92.62% | Feat: 37.5%
#   meta_HHO             | Acc:  91.76% (+/-4.12) | F1:  90.57% | Feat: 22.6%
#   meta_JAYA            | Acc:  94.08% (+/-3.54) | F1:  93.12% | Feat: 48.6%
#   meta_MFO             | Acc:  93.38% (+/-3.65) | F1:  92.20% | Feat: 49.1%
#   meta_MVO             | Acc:  93.85% (+/-3.53) | F1:  92.62% | Feat: 48.7%
#   meta_PSO             | Acc:  93.85% (+/-3.80) | F1:  93.09% | Feat: 48.5%
#   meta_SCA             | Acc:  93.27% (+/-3.59) | F1:  92.37% | Feat: 18.2%
#   meta_SSA             | Acc:  94.78% (+/-2.88) | F1:  93.99% | Feat: 48.4%
#   meta_WOA             | Acc:  93.04% (+/-3.78) | F1:  92.04% | Feat: 21.3%

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_BAT
#     F1 Macro:           99.06%
#     F1 Weighted:        99.06%
#     Test Accuracy:      99.07%
#     Feature Retention:  48.78% (2177/4463)
#     Modality Retention: depth=50.2%, sensor=50.3%, skeleton=47.2%, video=49.6%
#
#   Fold 2: Best = meta_HHO
#     F1 Macro:           94.79%
#     F1 Weighted:        94.79%
#     Test Accuracy:      95.37%
#     Feature Retention:  21.98% (981/4463)
#     Modality Retention: depth=25.2%, sensor=21.8%, skeleton=22.1%, video=20.7%
#
#   Fold 3: Best = meta_WOA
#     F1 Macro:           95.36%
#     F1 Weighted:        95.36%
#     Test Accuracy:      95.37%
#     Feature Retention:  12.50% (558/4463)
#     Modality Retention: depth=12.3%, sensor=12.1%, skeleton=13.4%, video=11.6%
#
#   Fold 4: Best = meta_CS
#     F1 Macro:           93.87%
#     F1 Weighted:        93.87%
#     Test Accuracy:      94.44%
#     Feature Retention:  48.31% (2156/4463)
#     Modality Retention: depth=49.8%, sensor=49.5%, skeleton=49.0%, video=46.3%
#
#   Fold 5: Best = meta_GWO
#     F1 Macro:           98.02%
#     F1 Weighted:        98.02%
#     Test Accuracy:      98.15%
#     Feature Retention:  40.26% (1797/4463)
#     Modality Retention: depth=36.3%, sensor=41.9%, skeleton=40.6%, video=40.6%
#
#   Fold 6: Best = meta_GA
#     F1 Macro:           97.08%
#     F1 Weighted:        97.06%
#     Test Accuracy:      97.20%
#     Feature Retention:  49.54% (2211/4463)
#     Modality Retention: depth=52.0%, sensor=46.0%, skeleton=51.1%, video=48.2%
#
#   Fold 7: Best = meta_WOA
#     F1 Macro:           97.23%
#     F1 Weighted:        97.20%
#     Test Accuracy:      97.20%
#     Feature Retention:  14.92% (666/4463)
#     Modality Retention: depth=15.8%, sensor=13.0%, skeleton=16.1%, video=13.9%
#
#   Fold 8: Best = meta_DE
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  48.24% (2153/4463)
#     Modality Retention: depth=46.1%, sensor=46.8%, skeleton=49.4%, video=48.1%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 96.93% ± 2.13%
#
#   Average F1 Weighted         : 96.92% ± 2.13%
#
#   Average Test Accuracy       : 97.10% ± 1.94%
#
#   Average Feature Retention   : 35.57% ± 16.29%
#
#   Average Modality-wise Feature Retention:
#            depth: 35.96% ± 16.19%
#           sensor: 35.18% ± 16.62%
#         skeleton: 36.11% ± 16.14%
#            video: 34.89% ± 16.55%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1           meta_BAT         99.06            99.06              99.07                  48.78              50.20               50.31                 47.21              49.65
#     2           meta_HHO         94.79            94.79              95.37                  21.98              25.20               21.78                 22.14              20.70
#     3           meta_WOA         95.36            95.36              95.37                  12.50              12.30               12.12                 13.36              11.62
#     4            meta_CS         93.87            93.87              94.44                  48.31              49.80               49.54                 48.96              46.34
#     5           meta_GWO         98.02            98.02              98.15                  40.26              36.33               41.87                 40.55              40.56
#     6            meta_GA         97.08            97.06              97.20                  49.54              51.95               46.01                 51.09              48.24
#     7           meta_WOA         97.23            97.20              97.20                  14.92              15.82               13.04                 16.13              13.87
#     8            meta_DE        100.00           100.00             100.00                  48.24              46.09               46.78                 49.44              48.10
#
# Saved to: results_weighted_fs/best_metaheuristic_per_fold.csv
