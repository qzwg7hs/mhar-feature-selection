# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_50")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

# FEATURE_DIMS will be set dynamically per-fold after PCA
# (depth dim changes if PCA is applied)
print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.50  # weight for accuracy
            beta = 0.50   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 95.37%, F1: 95.11%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 76.8s
#     Test Acc: 94.44%, F1: 93.09%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 14.8s
#     Test Acc: 93.52%, F1: 92.56%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 517.8s
#     Test Acc: 94.44%, F1: 93.83%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2540567197371535']
# ['At iteration 1 the best fitness is 0.2540567197371535']
# ['At iteration 2 the best fitness is 0.2540567197371535']
# ['At iteration 3 the best fitness is 0.2540567197371535']
# ['At iteration 4 the best fitness is 0.2540567197371535']
# ['At iteration 5 the best fitness is 0.2540567197371535']
# ['At iteration 6 the best fitness is 0.2540567197371535']
# ['At iteration 7 the best fitness is 0.2540567197371535']
# ['At iteration 8 the best fitness is 0.2540567197371535']
# ['At iteration 9 the best fitness is 0.2540567197371535']
# ['At iteration 10 the best fitness is 0.2494958548061842']
# ['At iteration 11 the best fitness is 0.2494958548061842']
# ['At iteration 12 the best fitness is 0.2494958548061842']
# ['At iteration 13 the best fitness is 0.2494958548061842']
# ['At iteration 14 the best fitness is 0.2494958548061842']
# ['At iteration 15 the best fitness is 0.2494958548061842']
# ['At iteration 16 the best fitness is 0.2494958548061842']
# ['At iteration 17 the best fitness is 0.2494958548061842']
# ['At iteration 18 the best fitness is 0.2494958548061842']
# ['At iteration 19 the best fitness is 0.2494958548061842']
# ['At iteration 20 the best fitness is 0.2494958548061842']
# ['At iteration 21 the best fitness is 0.2494958548061842']
# ['At iteration 22 the best fitness is 0.2494958548061842']
# ['At iteration 23 the best fitness is 0.2494958548061842']
# ['At iteration 24 the best fitness is 0.2494958548061842']
# ['At iteration 25 the best fitness is 0.2494958548061842']
# ['At iteration 26 the best fitness is 0.2494958548061842']
# ['At iteration 27 the best fitness is 0.2494958548061842']
# ['At iteration 28 the best fitness is 0.2494958548061842']
# ['At iteration 29 the best fitness is 0.2494958548061842']
#       Selected: 2227/4463 (49.9%), Fitness: 0.2495, Time: 2113.9s
#       Modality: D=46%, S=53%, Sk=50%, V=49%
#     Test Acc: 95.37%, F1: 95.25%, Features: 2227/4463 (49.9%), Model: 4.891MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.253384526145399']
# ['At iteration 1 the best fitness is 0.25021516477119243']
# ['At iteration 2 the best fitness is 0.25021516477119243']
# ['At iteration 3 the best fitness is 0.25021516477119243']
# ['At iteration 4 the best fitness is 0.25021516477119243']
# ['At iteration 5 the best fitness is 0.25021516477119243']
# ['At iteration 6 the best fitness is 0.25021516477119243']
# ['At iteration 7 the best fitness is 0.25021516477119243']
# ['At iteration 8 the best fitness is 0.25021516477119243']
# ['At iteration 9 the best fitness is 0.25021516477119243']
# ['At iteration 10 the best fitness is 0.25021516477119243']
# ['At iteration 11 the best fitness is 0.25021516477119243']
# ['At iteration 12 the best fitness is 0.249542971179438']
# ['At iteration 13 the best fitness is 0.249542971179438']
# ['At iteration 14 the best fitness is 0.249542971179438']
# ['At iteration 15 the best fitness is 0.249542971179438']
# ['At iteration 16 the best fitness is 0.249542971179438']
# ['At iteration 17 the best fitness is 0.249542971179438']
# ['At iteration 18 the best fitness is 0.2448700739831763']
# ['At iteration 19 the best fitness is 0.2448700739831763']
# ['At iteration 20 the best fitness is 0.2448700739831763']
# ['At iteration 21 the best fitness is 0.24019717678691463']
# ['At iteration 22 the best fitness is 0.24019717678691463']
# ['At iteration 23 the best fitness is 0.24019717678691463']
# ['At iteration 24 the best fitness is 0.24019717678691463']
# ['At iteration 25 the best fitness is 0.24019717678691463']
# ['At iteration 26 the best fitness is 0.24019717678691463']
# ['At iteration 27 the best fitness is 0.24019717678691463']
# ['At iteration 28 the best fitness is 0.24019717678691463']
# ['At iteration 29 the best fitness is 0.24019717678691463']
#       Selected: 2144/4463 (48.0%), Fitness: 0.2402, Time: 3905.4s
#       Modality: D=47%, S=50%, Sk=47%, V=49%
#     Test Acc: 91.67%, F1: 90.91%, Features: 2144/4463 (48.0%), Model: 4.729MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.26164245583101764']
# ['At iteration 2 the best fitness is 0.26164245583101764']
# ['At iteration 3 the best fitness is 0.26164245583101764']
# ['At iteration 4 the best fitness is 0.2594018105251696']
# ['At iteration 5 the best fitness is 0.2587296169334151']
# ['At iteration 6 the best fitness is 0.2569046427427174']
# ['At iteration 7 the best fitness is 0.24935136459487248']
# ['At iteration 8 the best fitness is 0.24935136459487248']
# ['At iteration 9 the best fitness is 0.24935136459487248']
# ['At iteration 10 the best fitness is 0.24935136459487248']
# ['At iteration 11 the best fitness is 0.24935136459487248']
# ['At iteration 12 the best fitness is 0.24935136459487248']
# ['At iteration 13 the best fitness is 0.24823104194194845']
# ['At iteration 14 the best fitness is 0.24823104194194845']
# ['At iteration 15 the best fitness is 0.24823104194194845']
# ['At iteration 16 the best fitness is 0.24823104194194845']
# ['At iteration 17 the best fitness is 0.24823104194194845']
# ['At iteration 18 the best fitness is 0.24823104194194845']
# ['At iteration 19 the best fitness is 0.24823104194194845']
# ['At iteration 20 the best fitness is 0.24823104194194845']
# ['At iteration 21 the best fitness is 0.24823104194194845']
# ['At iteration 22 the best fitness is 0.24823104194194845']
# ['At iteration 23 the best fitness is 0.2468866547584396']
# ['At iteration 24 the best fitness is 0.2468866547584396']
# ['At iteration 25 the best fitness is 0.2468866547584396']
# ['At iteration 26 the best fitness is 0.2468866547584396']
# ['At iteration 27 the best fitness is 0.2468866547584396']
# ['At iteration 28 the best fitness is 0.2468866547584396']
# ['At iteration 29 the best fitness is 0.2468866547584396']
# ['At iteration 30 the best fitness is 0.2468866547584396']
#       Selected: 2162/4463 (48.4%), Fitness: 0.2469, Time: 2013.2s
#       Modality: D=48%, S=48%, Sk=47%, V=50%
#     Test Acc: 91.67%, F1: 90.78%, Features: 2162/4463 (48.4%), Model: 4.764MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.25730565543063316']
# ['At iteration 1 the best fitness is 0.2654662112781939']
# ['At iteration 2 the best fitness is 0.2421017252968855']
# ['At iteration 3 the best fitness is 0.2570166750080098']
# ['At iteration 4 the best fitness is 0.2492068743835608']
# ['At iteration 5 the best fitness is 0.25290393913821013']
# ['At iteration 6 the best fitness is 0.25290393913821013']
# ['At iteration 7 the best fitness is 0.25055126156706964']
# ['At iteration 8 the best fitness is 0.2520076810158709']
# ['At iteration 9 the best fitness is 0.2509993906282393']
# ['At iteration 10 the best fitness is 0.2474468160849016']
# ['At iteration 11 the best fitness is 0.25055126156706964']
# ['At iteration 12 the best fitness is 0.24976703571002282']
# ['At iteration 13 the best fitness is 0.24531820304434593']
# ['At iteration 14 the best fitness is 0.25111142289353167']
# ['At iteration 15 the best fitness is 0.25088735836294684']
# ['At iteration 16 the best fitness is 0.24621446116668516']
# ['At iteration 17 the best fitness is 0.25122345515882405']
# ['At iteration 18 the best fitness is 0.25144751968940887']
# ['At iteration 19 the best fitness is 0.25111142289353167']
# ['At iteration 20 the best fitness is 0.25122345515882405']
# ['At iteration 21 the best fitness is 0.2419896930315931']
# ['At iteration 22 the best fitness is 0.25122345515882405']
# ['At iteration 23 the best fitness is 0.25111142289353167']
# ['At iteration 24 the best fitness is 0.25111142289353167']
# ['At iteration 25 the best fitness is 0.25111142289353167']
# ['At iteration 26 the best fitness is 0.24643852569726998']
# ['At iteration 27 the best fitness is 0.25111142289353167']
# ['At iteration 28 the best fitness is 0.25111142289353167']
# ['At iteration 29 the best fitness is 0.25578432008979335']
#       Selected: 2158/4463 (48.4%), Fitness: 0.2558, Time: 1883.6s
#       Modality: D=46%, S=50%, Sk=48%, V=49%
#     Test Acc: 93.52%, F1: 92.93%, Features: 2158/4463 (48.4%), Model: 4.756MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.25828148787224553
# At iteration 2 the best fitness is 0.2597703652670661
# At iteration 3 the best fitness is 0.260074004116924
# At iteration 4 the best fitness is 0.2554806812399354
# At iteration 5 the best fitness is 0.2541687520024459
# At iteration 6 the best fitness is 0.2554806812399354
# At iteration 7 the best fitness is 0.25159200990072056
# At iteration 8 the best fitness is 0.24837553215326014
# At iteration 9 the best fitness is 0.24557472552095003
# At iteration 10 the best fitness is 0.2544399329062845
# At iteration 11 the best fitness is 0.24509413851376113
# At iteration 12 the best fitness is 0.24845510647253324
# At iteration 13 the best fitness is 0.24322204794980953
# At iteration 14 the best fitness is 0.24568675778624244
# At iteration 15 the best fitness is 0.24901526779899527
# At iteration 16 the best fitness is 0.24890323553370286
# At iteration 17 the best fitness is 0.24778291288077883
# At iteration 18 the best fitness is 0.2471107192890244
# At iteration 19 the best fitness is 0.24344611248039436
# At iteration 20 the best fitness is 0.2502476227172117
# At iteration 21 the best fitness is 0.24557472552095003
# At iteration 22 the best fitness is 0.25245581007704054
# At iteration 23 the best fitness is 0.24890323553370286
# At iteration 24 the best fitness is 0.25122345515882405
# At iteration 25 the best fitness is 0.24565429984022313
# At iteration 26 the best fitness is 0.2496550034447304
# At iteration 27 the best fitness is 0.24498210624846872
# At iteration 28 the best fitness is 0.2471107192890244
# At iteration 29 the best fitness is 0.2468866547584396
# At iteration 30 the best fitness is 0.24800697741136363
#       Selected: 2172/4463 (48.7%), Fitness: 0.2480, Time: 2007.5s
#       Modality: D=48%, S=49%, Sk=49%, V=49%
#     Test Acc: 96.30%, F1: 96.17%, Features: 2172/4463 (48.7%), Model: 4.783MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.25682506842344427']
# ['At iteration 1 the best fitness is 0.24565429984022313']
# ['At iteration 2 the best fitness is 0.24009980294885674']
# ['At iteration 3 the best fitness is 0.21974238861165848']
# ['At iteration 4 the best fitness is 0.2047625230084956']
# ['At iteration 5 the best fitness is 0.20316161334838265']
# ['At iteration 6 the best fitness is 0.20036080671607254']
# ['At iteration 7 the best fitness is 0.17880349540667712']
# ['At iteration 8 the best fitness is 0.17723504369258347']
# ['At iteration 9 the best fitness is 0.17723504369258347']
# ['At iteration 10 the best fitness is 0.1703686175637275']
# ['At iteration 11 the best fitness is 0.16065426842930763']
# ['At iteration 12 the best fitness is 0.15874971991933676']
# ['At iteration 13 the best fitness is 0.1567331391440735']
# ['At iteration 14 the best fitness is 0.1567331391440735']
# ['At iteration 15 the best fitness is 0.1539323325117634']
# ['At iteration 16 the best fitness is 0.1515796549406229']
# ['At iteration 17 the best fitness is 0.1515796549406229']
# ['At iteration 18 the best fitness is 0.1515796549406229']
# ['At iteration 19 the best fitness is 0.1515796549406229']
# ['At iteration 20 the best fitness is 0.1515796549406229']
# ['At iteration 21 the best fitness is 0.14754649339009634']
# ['At iteration 22 the best fitness is 0.14754649339009634']
# ['At iteration 23 the best fitness is 0.14754649339009634']
# ['At iteration 24 the best fitness is 0.1465382030024647']
# ['At iteration 25 the best fitness is 0.1465382030024647']
# ['At iteration 26 the best fitness is 0.1465382030024647']
# ['At iteration 27 the best fitness is 0.1465382030024647']
# ['At iteration 28 the best fitness is 0.1465382030024647']
# ['At iteration 29 the best fitness is 0.1465382030024647']
#       Selected: 1308/4463 (29.3%), Fitness: 0.1465, Time: 1915.7s
#       Modality: D=30%, S=30%, Sk=29%, V=29%
#     Test Acc: 96.30%, F1: 95.06%, Features: 1308/4463 (29.3%), Model: 3.096MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.2632580239183651']
# ['At iteration 1 the best fitness is 0.10509778217995942']
# ['At iteration 2 the best fitness is 0.07483441212377576']
# ['At iteration 3 the best fitness is 0.0680004439409391']
# ['At iteration 4 the best fitness is 0.0680004439409391']
# ['At iteration 5 the best fitness is 0.0680004439409391']
# ['At iteration 6 the best fitness is 0.0680004439409391']
# ['At iteration 7 the best fitness is 0.0680004439409391']
# ['At iteration 8 the best fitness is 0.0680004439409391']
# ['At iteration 9 the best fitness is 0.0680004439409391']
# ['At iteration 10 the best fitness is 0.0680004439409391']
# ['At iteration 11 the best fitness is 0.0680004439409391']
# ['At iteration 12 the best fitness is 0.0680004439409391']
# ['At iteration 13 the best fitness is 0.0680004439409391']
# ['At iteration 14 the best fitness is 0.0680004439409391']
# ['At iteration 15 the best fitness is 0.0680004439409391']
# ['At iteration 16 the best fitness is 0.0680004439409391']
# ['At iteration 17 the best fitness is 0.0680004439409391']
# ['At iteration 18 the best fitness is 0.0680004439409391']
# ['At iteration 19 the best fitness is 0.06332754674467742']
# ['At iteration 20 the best fitness is 0.06332754674467742']
# ['At iteration 21 the best fitness is 0.06332754674467742']
# ['At iteration 22 the best fitness is 0.06332754674467742']
# ['At iteration 23 the best fitness is 0.06332754674467742']
# ['At iteration 24 the best fitness is 0.06131096596941415']
# ['At iteration 25 the best fitness is 0.06131096596941415']
# ['At iteration 26 the best fitness is 0.06131096596941415']
# ['At iteration 27 the best fitness is 0.056638068773152465']
# ['At iteration 28 the best fitness is 0.056638068773152465']
# ['At iteration 29 the best fitness is 0.056638068773152465']
#       Selected: 297/4463 (6.7%), Fitness: 0.0566, Time: 2590.0s
#       Modality: D=9%, S=6%, Sk=6%, V=7%
#     Test Acc: 90.74%, F1: 88.79%, Features: 297/4463 (6.7%), Model: 1.121MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2550325521787658']
# ['At iteration 1 the best fitness is 0.25346410046467216']
# ['At iteration 2 the best fitness is 0.25346410046467216']
# ['At iteration 3 the best fitness is 0.24845510647253324']
# ['At iteration 4 the best fitness is 0.24845510647253324']
# ['At iteration 5 the best fitness is 0.24845510647253324']
# ['At iteration 6 the best fitness is 0.24520617077905352']
# ['At iteration 7 the best fitness is 0.24520617077905352']
# ['At iteration 8 the best fitness is 0.24520617077905352']
# ['At iteration 9 the best fitness is 0.24520617077905352']
# ['At iteration 10 the best fitness is 0.24520617077905352']
# ['At iteration 11 the best fitness is 0.24520617077905352']
# ['At iteration 12 the best fitness is 0.24520617077905352']
# ['At iteration 13 the best fitness is 0.24520617077905352']
# ['At iteration 14 the best fitness is 0.24520617077905352']
# ['At iteration 15 the best fitness is 0.24520617077905352']
# ['At iteration 16 the best fitness is 0.24520617077905352']
# ['At iteration 17 the best fitness is 0.24520617077905352']
# ['At iteration 18 the best fitness is 0.24520617077905352']
# ['At iteration 19 the best fitness is 0.24520617077905352']
# ['At iteration 20 the best fitness is 0.24254985435805512']
# ['At iteration 21 the best fitness is 0.24254985435805512']
# ['At iteration 22 the best fitness is 0.24254985435805512']
# ['At iteration 23 the best fitness is 0.24254985435805512']
# ['At iteration 24 the best fitness is 0.24075733811337666']
# ['At iteration 25 the best fitness is 0.24075733811337666']
# ['At iteration 26 the best fitness is 0.24075733811337666']
# ['At iteration 27 the best fitness is 0.24075733811337666']
# ['At iteration 28 the best fitness is 0.24075733811337666']
# ['At iteration 29 the best fitness is 0.24075733811337666']
#       Selected: 2149/4463 (48.2%), Fitness: 0.2408, Time: 2168.3s
#       Modality: D=51%, S=47%, Sk=48%, V=49%
#     Test Acc: 95.37%, F1: 94.12%, Features: 2149/4463 (48.2%), Model: 4.738MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.25959341710973505']
# ['At iteration 2 the best fitness is 0.24823104194194845']
# ['At iteration 3 the best fitness is 0.24823104194194845']
# ['At iteration 4 the best fitness is 0.24823104194194845']
# ['At iteration 5 the best fitness is 0.24823104194194845']
# ['At iteration 6 the best fitness is 0.24823104194194845']
# ['At iteration 7 the best fitness is 0.24823104194194845']
# ['At iteration 8 the best fitness is 0.24823104194194845']
# ['At iteration 9 the best fitness is 0.24823104194194845']
# ['At iteration 10 the best fitness is 0.24823104194194845']
# ['At iteration 11 the best fitness is 0.24823104194194845']
# ['At iteration 12 the best fitness is 0.24823104194194845']
# ['At iteration 13 the best fitness is 0.24823104194194845']
# ['At iteration 14 the best fitness is 0.24823104194194845']
# ['At iteration 15 the best fitness is 0.24823104194194845']
# ['At iteration 16 the best fitness is 0.24823104194194845']
# ['At iteration 17 the best fitness is 0.24823104194194845']
# ['At iteration 18 the best fitness is 0.24823104194194845']
# ['At iteration 19 the best fitness is 0.24823104194194845']
# ['At iteration 20 the best fitness is 0.24823104194194845']
# ['At iteration 21 the best fitness is 0.24823104194194845']
# ['At iteration 22 the best fitness is 0.24823104194194845']
# ['At iteration 23 the best fitness is 0.2467746224931472']
# ['At iteration 24 the best fitness is 0.2467746224931472']
# ['At iteration 25 the best fitness is 0.2467746224931472']
# ['At iteration 26 the best fitness is 0.24411830607214877']
# ['At iteration 27 the best fitness is 0.23784449921577414']
# ['At iteration 28 the best fitness is 0.23784449921577414']
# ['At iteration 29 the best fitness is 0.23739637015460452']
#       Selected: 2119/4463 (47.5%), Fitness: 0.2374, Time: 2044.9s
#       Modality: D=47%, S=52%, Sk=46%, V=47%
#     Test Acc: 95.37%, F1: 95.11%, Features: 2119/4463 (47.5%), Model: 4.680MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.25629736504300155']
# ['At iteration 2 the best fitness is 0.25629736504300155']
# ['At iteration 3 the best fitness is 0.25629736504300155']
# ['At iteration 4 the best fitness is 0.25629736504300155']
# ['At iteration 5 the best fitness is 0.2552566167093506']
# ['At iteration 6 the best fitness is 0.2552566167093506']
# ['At iteration 7 the best fitness is 0.2552566167093506']
# ['At iteration 8 the best fitness is 0.2552566167093506']
# ['At iteration 9 the best fitness is 0.2552566167093506']
# ['At iteration 10 the best fitness is 0.2550325521787658']
# ['At iteration 11 the best fitness is 0.25391222952584175']
# ['At iteration 12 the best fitness is 0.25391222952584175']
# ['At iteration 13 the best fitness is 0.25391222952584175']
# ['At iteration 14 the best fitness is 0.25290393913821013']
# ['At iteration 15 the best fitness is 0.25290393913821013']
# ['At iteration 16 the best fitness is 0.25290393913821013']
# ['At iteration 17 the best fitness is 0.25290393913821013']
# ['At iteration 18 the best fitness is 0.25290393913821013']
# ['At iteration 19 the best fitness is 0.2495754291254573']
# ['At iteration 20 the best fitness is 0.2495754291254573']
# ['At iteration 21 the best fitness is 0.24935136459487248']
# ['At iteration 22 the best fitness is 0.24935136459487248']
# ['At iteration 23 the best fitness is 0.24935136459487248']
# ['At iteration 24 the best fitness is 0.24935136459487248']
# ['At iteration 25 the best fitness is 0.24935136459487248']
# ['At iteration 26 the best fitness is 0.24935136459487248']
# ['At iteration 27 the best fitness is 0.24935136459487248']
# ['At iteration 28 the best fitness is 0.24935136459487248']
# ['At iteration 29 the best fitness is 0.24935136459487248']
# ['At iteration 30 the best fitness is 0.24935136459487248']
#       Selected: 2184/4463 (48.9%), Fitness: 0.2494, Time: 2076.2s
#       Modality: D=47%, S=47%, Sk=50%, V=49%
#     Test Acc: 93.52%, F1: 92.65%, Features: 2184/4463 (48.9%), Model: 4.807MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.24647098364328926']
# ['At iteration 2 the best fitness is 0.24647098364328926']
# ['At iteration 3 the best fitness is 0.24647098364328926']
# ['At iteration 4 the best fitness is 0.24647098364328926']
# ['At iteration 5 the best fitness is 0.24647098364328926']
# ['At iteration 6 the best fitness is 0.24647098364328926']
# ['At iteration 7 the best fitness is 0.24647098364328926']
# ['At iteration 8 the best fitness is 0.24647098364328926']
# ['At iteration 9 the best fitness is 0.24647098364328926']
# ['At iteration 10 the best fitness is 0.24411830607214877']
# ['At iteration 11 the best fitness is 0.24411830607214877']
# ['At iteration 12 the best fitness is 0.24411830607214877']
# ['At iteration 13 the best fitness is 0.24411830607214877']
# ['At iteration 14 the best fitness is 0.24411830607214877']
# ['At iteration 15 the best fitness is 0.24411830607214877']
# ['At iteration 16 the best fitness is 0.24411830607214877']
# ['At iteration 17 the best fitness is 0.24411830607214877']
# ['At iteration 18 the best fitness is 0.24411830607214877']
# ['At iteration 19 the best fitness is 0.24411830607214877']
# ['At iteration 20 the best fitness is 0.24411830607214877']
# ['At iteration 21 the best fitness is 0.24411830607214877']
# ['At iteration 22 the best fitness is 0.24411830607214877']
# ['At iteration 23 the best fitness is 0.24411830607214877']
# ['At iteration 24 the best fitness is 0.24411830607214877']
# ['At iteration 25 the best fitness is 0.24411830607214877']
# ['At iteration 26 the best fitness is 0.24411830607214877']
# ['At iteration 27 the best fitness is 0.24411830607214877']
# ['At iteration 28 the best fitness is 0.24411830607214877']
# ['At iteration 29 the best fitness is 0.24411830607214877']
# ['At iteration 30 the best fitness is 0.24367017701097915']
#       Selected: 2175/4463 (48.7%), Fitness: 0.2437, Time: 2002.6s
#       Modality: D=50%, S=50%, Sk=49%, V=47%
#     Test Acc: 96.30%, F1: 96.19%, Features: 2175/4463 (48.7%), Model: 4.789MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.26048967523207434']
# ['At iteration 1 the best fitness is 0.22684753769833377']
# ['At iteration 2 the best fitness is 0.19637476153879982']
# ['At iteration 3 the best fitness is 0.1691184631267263']
# ['At iteration 4 the best fitness is 0.14981645555041348']
# ['At iteration 5 the best fitness is 0.1318912931036288']
# ['At iteration 6 the best fitness is 0.11900758259500231']
# ['At iteration 7 the best fitness is 0.10758029153517709']
# ['At iteration 8 the best fitness is 0.10758029153517709']
# ['At iteration 9 the best fitness is 0.10140385851686033']
# ['At iteration 10 the best fitness is 0.09431336785741957']
# ['At iteration 11 the best fitness is 0.07085150803805328']
# ['At iteration 12 the best fitness is 0.07085150803805328']
# ['At iteration 13 the best fitness is 0.07085150803805328']
# ['At iteration 14 the best fitness is 0.07085150803805328']
# ['At iteration 15 the best fitness is 0.06737850781398874']
# ['At iteration 16 the best fitness is 0.06737850781398874']
# ['At iteration 17 the best fitness is 0.06648224969164951']
# ['At iteration 18 the best fitness is 0.06648224969164951']
# ['At iteration 19 the best fitness is 0.06648224969164951']
# ['At iteration 20 the best fitness is 0.06648224969164951']
# ['At iteration 21 the best fitness is 0.06648224969164951']
# ['At iteration 22 the best fitness is 0.06219256566451886']
# ['At iteration 23 the best fitness is 0.06219256566451886']
# ['At iteration 24 the best fitness is 0.06020844283527488']
# ['At iteration 25 the best fitness is 0.06020844283527488']
# ['At iteration 26 the best fitness is 0.06020844283527488']
# ['At iteration 27 the best fitness is 0.06020844283527488']
# ['At iteration 28 the best fitness is 0.06020844283527488']
# ['At iteration 29 the best fitness is 0.06020844283527488']
#       Selected: 454/4463 (10.2%), Fitness: 0.0602, Time: 1970.1s
#       Modality: D=9%, S=10%, Sk=10%, V=11%
#     Test Acc: 93.52%, F1: 93.30%, Features: 454/4463 (10.2%), Model: 1.428MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2544723908523038']
# ['At iteration 2 the best fitness is 0.25055126156706964']
# ['At iteration 3 the best fitness is 0.25055126156706964']
# ['At iteration 4 the best fitness is 0.25055126156706964']
# ['At iteration 5 the best fitness is 0.24811900967665604']
# ['At iteration 6 the best fitness is 0.24811900967665604']
# ['At iteration 7 the best fitness is 0.24811900967665604']
# ['At iteration 8 the best fitness is 0.24811900967665604']
# ['At iteration 9 the best fitness is 0.24624691911270447']
# ['At iteration 10 the best fitness is 0.24624691911270447']
# ['At iteration 11 the best fitness is 0.24624691911270447']
# ['At iteration 12 the best fitness is 0.24624691911270447']
# ['At iteration 13 the best fitness is 0.24624691911270447']
# ['At iteration 14 the best fitness is 0.24624691911270447']
# ['At iteration 15 the best fitness is 0.24624691911270447']
# ['At iteration 16 the best fitness is 0.24624691911270447']
# ['At iteration 17 the best fitness is 0.24624691911270447']
# ['At iteration 18 the best fitness is 0.24624691911270447']
# ['At iteration 19 the best fitness is 0.24624691911270447']
# ['At iteration 20 the best fitness is 0.24624691911270447']
# ['At iteration 21 the best fitness is 0.24624691911270447']
# ['At iteration 22 the best fitness is 0.24613488684741205']
# ['At iteration 23 the best fitness is 0.24613488684741205']
# ['At iteration 24 the best fitness is 0.24613488684741205']
# ['At iteration 25 the best fitness is 0.24613488684741205']
# ['At iteration 26 the best fitness is 0.24613488684741205']
# ['At iteration 27 the best fitness is 0.24613488684741205']
# ['At iteration 28 the best fitness is 0.24613488684741205']
# ['At iteration 29 the best fitness is 0.24613488684741205']
#       Selected: 2197/4463 (49.2%), Fitness: 0.2461, Time: 3883.8s
#       Modality: D=48%, S=48%, Sk=49%, V=50%
#     Test Acc: 92.59%, F1: 92.56%, Features: 2197/4463 (49.2%), Model: 4.832MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2570491329540291']
# ['At iteration 1 the best fitness is 0.09533631667228573']
# ['At iteration 2 the best fitness is 0.07832521186662507']
# ['At iteration 3 the best fitness is 0.07515585049241846']
# ['At iteration 4 the best fitness is 0.07334867582050547']
# ['At iteration 5 the best fitness is 0.04938842947516549']
# ['At iteration 6 the best fitness is 0.04938842947516549']
# ['At iteration 7 the best fitness is 0.04101846752425446']
# ['At iteration 8 the best fitness is 0.03925840922559529']
# ['At iteration 9 the best fitness is 0.03925840922559529']
# ['At iteration 10 the best fitness is 0.03925840922559529']
# ['At iteration 11 the best fitness is 0.03925840922559529']
# ['At iteration 12 the best fitness is 0.03925840922559529']
# ['At iteration 13 the best fitness is 0.03925840922559529']
# ['At iteration 14 the best fitness is 0.03925840922559529']
# ['At iteration 15 the best fitness is 0.03925840922559529']
# ['At iteration 16 the best fitness is 0.03925840922559529']
# ['At iteration 17 the best fitness is 0.03925840922559529']
# ['At iteration 18 the best fitness is 0.03925840922559529']
# ['At iteration 19 the best fitness is 0.03925840922559529']
# ['At iteration 20 the best fitness is 0.03925840922559529']
# ['At iteration 21 the best fitness is 0.03925840922559529']
# ['At iteration 22 the best fitness is 0.03925840922559529']
# ['At iteration 23 the best fitness is 0.03925840922559529']
# ['At iteration 24 the best fitness is 0.03925840922559529']
# ['At iteration 25 the best fitness is 0.03925840922559529']
# ['At iteration 26 the best fitness is 0.03925840922559529']
# ['At iteration 27 the best fitness is 0.03925840922559529']
# ['At iteration 28 the best fitness is 0.03925840922559529']
# ['At iteration 29 the best fitness is 0.03925840922559529']
#       Selected: 267/4463 (6.0%), Fitness: 0.0393, Time: 1200.1s
#       Modality: D=5%, S=6%, Sk=6%, V=6%
#     Test Acc: 86.11%, F1: 85.16%, Features: 267/4463 (6.0%), Model: 1.063MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 94.44%, F1: 93.18%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 60.3s
#     Test Acc: 88.89%, F1: 86.54%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.9s
#     Test Acc: 92.59%, F1: 90.89%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 364.9s
#     Test Acc: 88.89%, F1: 85.95%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2501355904519193']
# ['At iteration 1 the best fitness is 0.24322204794980953']
# ['At iteration 2 the best fitness is 0.24322204794980953']
# ['At iteration 3 the best fitness is 0.24322204794980953']
# ['At iteration 4 the best fitness is 0.24322204794980953']
# ['At iteration 5 the best fitness is 0.24322204794980953']
# ['At iteration 6 the best fitness is 0.24322204794980953']
# ['At iteration 7 the best fitness is 0.24322204794980953']
# ['At iteration 8 the best fitness is 0.24322204794980953']
# ['At iteration 9 the best fitness is 0.24322204794980953']
# ['At iteration 10 the best fitness is 0.24322204794980953']
# ['At iteration 11 the best fitness is 0.24322204794980953']
# ['At iteration 12 the best fitness is 0.24322204794980953']
# ['At iteration 13 the best fitness is 0.24322204794980953']
# ['At iteration 14 the best fitness is 0.24322204794980953']
# ['At iteration 15 the best fitness is 0.24288595115393233']
# ['At iteration 16 the best fitness is 0.24288595115393233']
# ['At iteration 17 the best fitness is 0.24288595115393233']
# ['At iteration 18 the best fitness is 0.24288595115393233']
# ['At iteration 19 the best fitness is 0.24288595115393233']
# ['At iteration 20 the best fitness is 0.24288595115393233']
# ['At iteration 21 the best fitness is 0.24288595115393233']
# ['At iteration 22 the best fitness is 0.24288595115393233']
# ['At iteration 23 the best fitness is 0.24288595115393233']
# ['At iteration 24 the best fitness is 0.24288595115393233']
# ['At iteration 25 the best fitness is 0.24288595115393233']
# ['At iteration 26 the best fitness is 0.24288595115393233']
# ['At iteration 27 the best fitness is 0.24288595115393233']
# ['At iteration 28 the best fitness is 0.24288595115393233']
# ['At iteration 29 the best fitness is 0.24288595115393233']
#       Selected: 2168/4463 (48.6%), Fitness: 0.2429, Time: 1492.3s
#       Modality: D=48%, S=48%, Sk=49%, V=48%
#     Test Acc: 90.74%, F1: 88.15%, Features: 2168/4463 (48.6%), Model: 4.776MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.25155955195470125']
# ['At iteration 1 the best fitness is 0.24299798341922474']
# ['At iteration 2 the best fitness is 0.24299798341922474']
# ['At iteration 3 the best fitness is 0.24299798341922474']
# ['At iteration 4 the best fitness is 0.24299798341922474']
# ['At iteration 5 the best fitness is 0.24299798341922474']
# ['At iteration 6 the best fitness is 0.24299798341922474']
# ['At iteration 7 the best fitness is 0.24299798341922474']
# ['At iteration 8 the best fitness is 0.24299798341922474']
# ['At iteration 9 the best fitness is 0.24299798341922474']
# ['At iteration 10 the best fitness is 0.24299798341922474']
# ['At iteration 11 the best fitness is 0.24299798341922474']
# ['At iteration 12 the best fitness is 0.24299798341922474']
# ['At iteration 13 the best fitness is 0.24299798341922474']
# ['At iteration 14 the best fitness is 0.24299798341922474']
# ['At iteration 15 the best fitness is 0.24299798341922474']
# ['At iteration 16 the best fitness is 0.24299798341922474']
# ['At iteration 17 the best fitness is 0.24299798341922474']
# ['At iteration 18 the best fitness is 0.24299798341922474']
# ['At iteration 19 the best fitness is 0.24299798341922474']
# ['At iteration 20 the best fitness is 0.24299798341922474']
# ['At iteration 21 the best fitness is 0.24299798341922474']
# ['At iteration 22 the best fitness is 0.24299798341922474']
# ['At iteration 23 the best fitness is 0.24299798341922474']
# ['At iteration 24 the best fitness is 0.24299798341922474']
# ['At iteration 25 the best fitness is 0.24299798341922474']
# ['At iteration 26 the best fitness is 0.24299798341922474']
# ['At iteration 27 the best fitness is 0.24299798341922474']
# ['At iteration 28 the best fitness is 0.24299798341922474']
# ['At iteration 29 the best fitness is 0.24299798341922474']
#       Selected: 2169/4463 (48.6%), Fitness: 0.2430, Time: 2941.9s
#       Modality: D=49%, S=51%, Sk=48%, V=48%
#     Test Acc: 88.89%, F1: 86.73%, Features: 2169/4463 (48.6%), Model: 4.777MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2550650101247851']
# ['At iteration 2 the best fitness is 0.24509413851376113']
# ['At iteration 3 the best fitness is 0.24509413851376113']
# ['At iteration 4 the best fitness is 0.24509413851376113']
# ['At iteration 5 the best fitness is 0.24509413851376113']
# ['At iteration 6 the best fitness is 0.24509413851376113']
# ['At iteration 7 the best fitness is 0.24509413851376113']
# ['At iteration 8 the best fitness is 0.24509413851376113']
# ['At iteration 9 the best fitness is 0.24509413851376113']
# ['At iteration 10 the best fitness is 0.24509413851376113']
# ['At iteration 11 the best fitness is 0.24016471884089532']
# ['At iteration 12 the best fitness is 0.24016471884089532']
# ['At iteration 13 the best fitness is 0.24016471884089532']
# ['At iteration 14 the best fitness is 0.24016471884089532']
# ['At iteration 15 the best fitness is 0.24016471884089532']
# ['At iteration 16 the best fitness is 0.24016471884089532']
# ['At iteration 17 the best fitness is 0.239749047725745']
# ['At iteration 18 the best fitness is 0.2397165897797257']
# ['At iteration 19 the best fitness is 0.2397165897797257']
# ['At iteration 20 the best fitness is 0.2370602733587273']
# ['At iteration 21 the best fitness is 0.2370602733587273']
# ['At iteration 22 the best fitness is 0.2370602733587273']
# ['At iteration 23 the best fitness is 0.2370602733587273']
# ['At iteration 24 the best fitness is 0.2370602733587273']
# ['At iteration 25 the best fitness is 0.2370602733587273']
# ['At iteration 26 the best fitness is 0.23213085368586153']
# ['At iteration 27 the best fitness is 0.23213085368586153']
# ['At iteration 28 the best fitness is 0.23213085368586153']
# ['At iteration 29 the best fitness is 0.23213085368586153']
# ['At iteration 30 the best fitness is 0.23213085368586153']
#       Selected: 2072/4463 (46.4%), Fitness: 0.2321, Time: 1492.3s
#       Modality: D=47%, S=48%, Sk=47%, V=45%
#     Test Acc: 92.59%, F1: 91.14%, Features: 2072/4463 (46.4%), Model: 4.588MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.25312800366879495']
# ['At iteration 1 the best fitness is 0.2551445844440582']
# ['At iteration 2 the best fitness is 0.2549205199134734']
# ['At iteration 3 the best fitness is 0.2550796685520196']
# ['At iteration 4 the best fitness is 0.25040677135575795']
# ['At iteration 5 the best fitness is 0.2499115259213345']
# ['At iteration 6 the best fitness is 0.25749726201519874']
# ['At iteration 7 the best fitness is 0.24557472552095003']
# ['At iteration 8 the best fitness is 0.25125591310484335']
# ['At iteration 9 the best fitness is 0.2536881649952569']
# ['At iteration 10 the best fitness is 0.2572407395385946']
# ['At iteration 11 the best fitness is 0.25256784234233287']
# ['At iteration 12 the best fitness is 0.25847309445681105']
# ['At iteration 13 the best fitness is 0.2546964553828886']
# ['At iteration 14 the best fitness is 0.2549205199134734']
# ['At iteration 15 the best fitness is 0.25869715898739587']
# ['At iteration 16 the best fitness is 0.24879120326841045']
# ['At iteration 17 the best fitness is 0.24879120326841045']
# ['At iteration 18 the best fitness is 0.257912933130349']
# ['At iteration 19 the best fitness is 0.2578009008650566']
# ['At iteration 20 the best fitness is 0.2581369976609338']
# ['At iteration 21 the best fitness is 0.2582490299262262']
# ['At iteration 22 the best fitness is 0.2533520681993797']
# ['At iteration 23 the best fitness is 0.24890323553370286']
# ['At iteration 24 the best fitness is 0.2582490299262262']
# ['At iteration 25 the best fitness is 0.25346410046467216']
# ['At iteration 26 the best fitness is 0.24890323553370286']
# ['At iteration 27 the best fitness is 0.2581369976609338']
# ['At iteration 28 the best fitness is 0.25357613272996454']
# ['At iteration 29 the best fitness is 0.2581369976609338']
#       Selected: 2179/4463 (48.8%), Fitness: 0.2581, Time: 1447.4s
#       Modality: D=49%, S=48%, Sk=50%, V=48%
#     Test Acc: 87.96%, F1: 85.78%, Features: 2179/4463 (48.8%), Model: 4.797MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.25080778404367376
# At iteration 2 the best fitness is 0.2531604616148142
# At iteration 3 the best fitness is 0.2538326552065686
# At iteration 4 the best fitness is 0.26149796561970595
# At iteration 5 the best fitness is 0.2534965584106914
# At iteration 6 the best fitness is 0.25682506842344427
# At iteration 7 the best fitness is 0.2554011069206623
# At iteration 8 the best fitness is 0.24789494514607122
# At iteration 9 the best fitness is 0.25260030028835223
# At iteration 10 the best fitness is 0.2598174816403199
# At iteration 11 the best fitness is 0.2551445844440582
# At iteration 12 the best fitness is 0.252264203492475
# At iteration 13 the best fitness is 0.2590332557832731
# At iteration 14 the best fitness is 0.2600415461709047
# At iteration 15 the best fitness is 0.25204013896189015
# At iteration 16 the best fitness is 0.24770333856150573
# At iteration 17 the best fitness is 0.24456643513331838
# At iteration 18 the best fitness is 0.2546964553828886
# At iteration 19 the best fitness is 0.25103184857425853
# At iteration 20 the best fitness is 0.2546964553828886
# At iteration 21 the best fitness is 0.2556722878245009
# At iteration 22 the best fitness is 0.2596729914290082
# At iteration 23 the best fitness is 0.25111142289353167
# At iteration 24 the best fitness is 0.26045721728605503
# At iteration 25 the best fitness is 0.24789494514607122
# At iteration 26 the best fitness is 0.2552241587633313
# At iteration 27 the best fitness is 0.24430991265671428
# At iteration 28 the best fitness is 0.24655055796256237
# At iteration 29 the best fitness is 0.25455196517157685
# At iteration 30 the best fitness is 0.25055126156706964
#       Selected: 2153/4463 (48.2%), Fitness: 0.2506, Time: 1432.8s
#       Modality: D=49%, S=50%, Sk=48%, V=48%
#     Test Acc: 91.67%, F1: 89.00%, Features: 2153/4463 (48.2%), Model: 4.746MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2567130361581519']
# ['At iteration 1 the best fitness is 0.25051880362105033']
# ['At iteration 2 the best fitness is 0.24293306752718616']
# ['At iteration 3 the best fitness is 0.2282568407738812']
# ['At iteration 4 the best fitness is 0.22374309221616573']
# ['At iteration 5 the best fitness is 0.21447687214291547']
# ['At iteration 6 the best fitness is 0.2019617163761855']
# ['At iteration 7 the best fitness is 0.1863096571812682']
# ['At iteration 8 the best fitness is 0.17977932784828946']
# ['At iteration 9 the best fitness is 0.17977932784828946']
# ['At iteration 10 the best fitness is 0.17563413403247052']
# ['At iteration 11 the best fitness is 0.1753776115558664']
# ['At iteration 12 the best fitness is 0.16099036522518484']
# ['At iteration 13 the best fitness is 0.16099036522518484']
# ['At iteration 14 the best fitness is 0.15871726197331748']
# ['At iteration 15 the best fitness is 0.15359623571588618']
# ['At iteration 16 the best fitness is 0.15333971323928208']
# ['At iteration 17 the best fitness is 0.148554783777728']
# ['At iteration 18 the best fitness is 0.148554783777728']
# ['At iteration 19 the best fitness is 0.148554783777728']
# ['At iteration 20 the best fitness is 0.148554783777728']
# ['At iteration 21 the best fitness is 0.148554783777728']
# ['At iteration 22 the best fitness is 0.148554783777728']
# ['At iteration 23 the best fitness is 0.148554783777728']
# ['At iteration 24 the best fitness is 0.148554783777728']
# ['At iteration 25 the best fitness is 0.148554783777728']
# ['At iteration 26 the best fitness is 0.148554783777728']
# ['At iteration 27 the best fitness is 0.148554783777728']
# ['At iteration 28 the best fitness is 0.148554783777728']
# ['At iteration 29 the best fitness is 0.148554783777728']
#       Selected: 1326/4463 (29.7%), Fitness: 0.1486, Time: 1303.2s
#       Modality: D=28%, S=31%, Sk=30%, V=30%
#     Test Acc: 93.52%, F1: 91.69%, Features: 1326/4463 (29.7%), Model: 3.131MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.263178449599092']
# ['At iteration 1 the best fitness is 0.06817425100671985']
# ['At iteration 2 the best fitness is 0.05209186226941771']
# ['At iteration 3 the best fitness is 0.04087397731294276']
# ['At iteration 4 the best fitness is 0.04087397731294276']
# ['At iteration 5 the best fitness is 0.04087397731294276']
# ['At iteration 6 the best fitness is 0.04087397731294276']
# ['At iteration 7 the best fitness is 0.04087397731294276']
# ['At iteration 8 the best fitness is 0.04087397731294276']
# ['At iteration 9 the best fitness is 0.04087397731294276']
# ['At iteration 10 the best fitness is 0.04087397731294276']
# ['At iteration 11 the best fitness is 0.04087397731294276']
# ['At iteration 12 the best fitness is 0.04087397731294276']
# ['At iteration 13 the best fitness is 0.032648505573343437']
# ['At iteration 14 the best fitness is 0.032648505573343437']
# ['At iteration 15 the best fitness is 0.032648505573343437']
# ['At iteration 16 the best fitness is 0.032648505573343437']
# ['At iteration 17 the best fitness is 0.032648505573343437']
# ['At iteration 18 the best fitness is 0.032648505573343437']
# ['At iteration 19 the best fitness is 0.032648505573343437']
# ['At iteration 20 the best fitness is 0.032648505573343437']
# ['At iteration 21 the best fitness is 0.032648505573343437']
# ['At iteration 22 the best fitness is 0.032648505573343437']
# ['At iteration 23 the best fitness is 0.032648505573343437']
# ['At iteration 24 the best fitness is 0.032648505573343437']
# ['At iteration 25 the best fitness is 0.032648505573343437']
# ['At iteration 26 the best fitness is 0.03253647330805104']
# ['At iteration 27 the best fitness is 0.03253647330805104']
# ['At iteration 28 the best fitness is 0.03253647330805104']
# ['At iteration 29 the best fitness is 0.03253647330805104']
#       Selected: 207/4463 (4.6%), Fitness: 0.0325, Time: 1867.2s
#       Modality: D=4%, S=6%, Sk=5%, V=4%
#     Test Acc: 84.26%, F1: 82.81%, Features: 207/4463 (4.6%), Model: 0.687MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.25895368146399994']
# ['At iteration 1 the best fitness is 0.2583935201375379']
# ['At iteration 2 the best fitness is 0.2515124355814475']
# ['At iteration 3 the best fitness is 0.2515124355814475']
# ['At iteration 4 the best fitness is 0.2515124355814475']
# ['At iteration 5 the best fitness is 0.2515124355814475']
# ['At iteration 6 the best fitness is 0.250840241989693']
# ['At iteration 7 the best fitness is 0.24935136459487248']
# ['At iteration 8 the best fitness is 0.24935136459487248']
# ['At iteration 9 the best fitness is 0.24800697741136363']
# ['At iteration 10 the best fitness is 0.24800697741136363']
# ['At iteration 11 the best fitness is 0.24800697741136363']
# ['At iteration 12 the best fitness is 0.24800697741136363']
# ['At iteration 13 the best fitness is 0.24800697741136363']
# ['At iteration 14 the best fitness is 0.24800697741136363']
# ['At iteration 15 the best fitness is 0.24800697741136363']
# ['At iteration 16 the best fitness is 0.24800697741136363']
# ['At iteration 17 the best fitness is 0.24800697741136363']
# ['At iteration 18 the best fitness is 0.24576633210551554']
# ['At iteration 19 the best fitness is 0.24576633210551554']
# ['At iteration 20 the best fitness is 0.24576633210551554']
# ['At iteration 21 the best fitness is 0.24576633210551554']
# ['At iteration 22 the best fitness is 0.24576633210551554']
# ['At iteration 23 the best fitness is 0.24576633210551554']
# ['At iteration 24 the best fitness is 0.24576633210551554']
# ['At iteration 25 the best fitness is 0.24576633210551554']
# ['At iteration 26 the best fitness is 0.24576633210551554']
# ['At iteration 27 the best fitness is 0.24576633210551554']
# ['At iteration 28 the best fitness is 0.24262942867732823']
# ['At iteration 29 the best fitness is 0.24262942867732823']
#       Selected: 2124/4463 (47.6%), Fitness: 0.2426, Time: 1485.4s
# ...
# ['At iteration 13 the best fitness is 0.07814826370929406']
# ['At iteration 14 the best fitness is 0.07814826370929406']
# ['At iteration 15 the best fitness is 0.07814826370929406']
# ['At iteration 16 the best fitness is 0.07814826370929406']
# ['At iteration 17 the best fitness is 0.07568355387286119']
# ['At iteration 18 the best fitness is 0.07568355387286119']
# ['At iteration 19 the best fitness is 0.07568355387286119']
# ['At iteration 20 the best fitness is 0.07568355387286119']
# ['At iteration 21 the best fitness is 0.07568355387286119']
# ['At iteration 22 the best fitness is 0.07568355387286119']
# ['At iteration 23 the best fitness is 0.07445119895464473']
# ['At iteration 24 the best fitness is 0.07445119895464473']
# ['At iteration 25 the best fitness is 0.07445119895464473']
# ['At iteration 26 the best fitness is 0.07445119895464473']
# ['At iteration 27 the best fitness is 0.07445119895464473']
# ['At iteration 28 the best fitness is 0.07445119895464473']
# ['At iteration 29 the best fitness is 0.07445119895464473']
#       Selected: 456/4463 (10.2%), Fitness: 0.0745, Time: 1994.3s
#       Modality: D=11%, S=11%, Sk=9%, V=10%
#     Test Acc: 92.52%, F1: 91.59%, Features: 456/4463 (10.2%), Model: 1.432MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.25357613272996454']
# ['At iteration 1 the best fitness is 0.25357613272996454']
# ['At iteration 2 the best fitness is 0.2501031325059']
# ['At iteration 3 the best fitness is 0.247558848350194']
# ['At iteration 4 the best fitness is 0.247558848350194']
# ['At iteration 5 the best fitness is 0.247558848350194']
# ['At iteration 6 the best fitness is 0.247558848350194']
# ['At iteration 7 the best fitness is 0.247558848350194']
# ['At iteration 8 the best fitness is 0.24655055796256237']
# ['At iteration 9 the best fitness is 0.24655055796256237']
# ['At iteration 10 the best fitness is 0.24655055796256237']
# ['At iteration 11 the best fitness is 0.24579879005153485']
# ['At iteration 12 the best fitness is 0.2446784673986108']
# ['At iteration 13 the best fitness is 0.2446784673986108']
# ['At iteration 14 the best fitness is 0.2446784673986108']
# ['At iteration 15 the best fitness is 0.2446784673986108']
# ['At iteration 16 the best fitness is 0.2446784673986108']
# ['At iteration 17 the best fitness is 0.2446784673986108']
# ['At iteration 18 the best fitness is 0.2446784673986108']
# ['At iteration 19 the best fitness is 0.2446784673986108']
# ['At iteration 20 the best fitness is 0.2446784673986108']
# ['At iteration 21 the best fitness is 0.2446784673986108']
# ['At iteration 22 the best fitness is 0.2446784673986108']
# ['At iteration 23 the best fitness is 0.2446784673986108']
# ['At iteration 24 the best fitness is 0.2446784673986108']
# ['At iteration 25 the best fitness is 0.2446784673986108']
# ['At iteration 26 the best fitness is 0.2446784673986108']
# ['At iteration 27 the best fitness is 0.2446784673986108']
# ['At iteration 28 the best fitness is 0.2446784673986108']
# ['At iteration 29 the best fitness is 0.2446784673986108']
#       Selected: 2184/4463 (48.9%), Fitness: 0.2447, Time: 1638.0s
#       Modality: D=49%, S=51%, Sk=49%, V=48%
#     Test Acc: 95.33%, F1: 94.89%, Features: 2184/4463 (48.9%), Model: 4.807MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2580574233416607']
# ['At iteration 2 the best fitness is 0.25136794537013574']
# ['At iteration 3 the best fitness is 0.25136794537013574']
# ['At iteration 4 the best fitness is 0.25136794537013574']
# ['At iteration 5 the best fitness is 0.25136794537013574']
# ['At iteration 6 the best fitness is 0.25136794537013574']
# ['At iteration 7 the best fitness is 0.25136794537013574']
# ['At iteration 8 the best fitness is 0.25136794537013574']
# ['At iteration 9 the best fitness is 0.25136794537013574']
# ['At iteration 10 the best fitness is 0.25136794537013574']
# ['At iteration 11 the best fitness is 0.25136794537013574']
# ['At iteration 12 the best fitness is 0.25136794537013574']
# ['At iteration 13 the best fitness is 0.25136794537013574']
# ['At iteration 14 the best fitness is 0.25136794537013574']
# ['At iteration 15 the best fitness is 0.25136794537013574']
# ['At iteration 16 the best fitness is 0.24859959668384496']
# ['At iteration 17 the best fitness is 0.2471431772350437']
# ['At iteration 18 the best fitness is 0.2471431772350437']
# ['At iteration 19 the best fitness is 0.2471431772350437']
# ['At iteration 20 the best fitness is 0.2471431772350437']
# ['At iteration 21 the best fitness is 0.2471431772350437']
# ['At iteration 22 the best fitness is 0.2471431772350437']
# ['At iteration 23 the best fitness is 0.2471431772350437']
# ['At iteration 24 the best fitness is 0.2471431772350437']
# ['At iteration 25 the best fitness is 0.2471431772350437']
# ['At iteration 26 the best fitness is 0.2471431772350437']
# ['At iteration 27 the best fitness is 0.2471431772350437']
# ['At iteration 28 the best fitness is 0.2471431772350437']
# ['At iteration 29 the best fitness is 0.2471431772350437']
#       Selected: 2206/4463 (49.4%), Fitness: 0.2471, Time: 1593.4s
#       Modality: D=51%, S=50%, Sk=49%, V=49%
#     Test Acc: 100.00%, F1: 100.00%, Features: 2206/4463 (49.4%), Model: 4.850MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2567130361581519']
# ['At iteration 2 the best fitness is 0.2567130361581519']
# ['At iteration 3 the best fitness is 0.2567130361581519']
# ['At iteration 4 the best fitness is 0.2567130361581519']
# ['At iteration 5 the best fitness is 0.24935136459487248']
# ['At iteration 6 the best fitness is 0.24935136459487248']
# ['At iteration 7 the best fitness is 0.24935136459487248']
# ['At iteration 8 the best fitness is 0.24935136459487248']
# ['At iteration 9 the best fitness is 0.24935136459487248']
# ['At iteration 10 the best fitness is 0.24935136459487248']
# ['At iteration 11 the best fitness is 0.24935136459487248']
# ['At iteration 12 the best fitness is 0.24935136459487248']
# ['At iteration 13 the best fitness is 0.24935136459487248']
# ['At iteration 14 the best fitness is 0.24613488684741205']
# ['At iteration 15 the best fitness is 0.24613488684741205']
# ['At iteration 16 the best fitness is 0.24613488684741205']
# ['At iteration 17 the best fitness is 0.24613488684741205']
# ['At iteration 18 the best fitness is 0.24613488684741205']
# ['At iteration 19 the best fitness is 0.2443423706027336']
# ['At iteration 20 the best fitness is 0.2443423706027336']
# ['At iteration 21 the best fitness is 0.2443423706027336']
# ['At iteration 22 the best fitness is 0.2443423706027336']
# ['At iteration 23 the best fitness is 0.24400627380685638']
# ['At iteration 24 the best fitness is 0.24400627380685638']
# ['At iteration 25 the best fitness is 0.24400627380685638']
# ['At iteration 26 the best fitness is 0.24400627380685638']
# ['At iteration 27 the best fitness is 0.24400627380685638']
# ['At iteration 28 the best fitness is 0.24333408021510194']
# ['At iteration 29 the best fitness is 0.24333408021510194']
# ['At iteration 30 the best fitness is 0.24333408021510194']
#       Selected: 2172/4463 (48.7%), Fitness: 0.2433, Time: 1641.1s
#       Modality: D=47%, S=48%, Sk=50%, V=48%
#     Test Acc: 99.07%, F1: 99.06%, Features: 2172/4463 (48.7%), Model: 4.783MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2567130361581519']
# ['At iteration 2 the best fitness is 0.24912730006428768']
# ['At iteration 3 the best fitness is 0.24767088061548642']
# ['At iteration 4 the best fitness is 0.24767088061548642']
# ['At iteration 5 the best fitness is 0.24767088061548642']
# ['At iteration 6 the best fitness is 0.24767088061548642']
# ['At iteration 7 the best fitness is 0.24767088061548642']
# ['At iteration 8 the best fitness is 0.24666259022785478']
# ['At iteration 9 the best fitness is 0.24666259022785478']
# ['At iteration 10 the best fitness is 0.24666259022785478']
# ['At iteration 11 the best fitness is 0.24666259022785478']
# ['At iteration 12 the best fitness is 0.24666259022785478']
# ['At iteration 13 the best fitness is 0.24666259022785478']
# ['At iteration 14 the best fitness is 0.24666259022785478']
# ['At iteration 15 the best fitness is 0.2444219449220067']
# ['At iteration 16 the best fitness is 0.24430991265671428']
# ['At iteration 17 the best fitness is 0.24378220927627156']
# ['At iteration 18 the best fitness is 0.24378220927627156']
# ['At iteration 19 the best fitness is 0.24378220927627156']
# ['At iteration 20 the best fitness is 0.24378220927627156']
# ['At iteration 21 the best fitness is 0.24378220927627156']
# ['At iteration 22 the best fitness is 0.24378220927627156']
# ['At iteration 23 the best fitness is 0.24299798341922474']
# ['At iteration 24 the best fitness is 0.2396370154604526']
# ['At iteration 25 the best fitness is 0.2396370154604526']
# ['At iteration 26 the best fitness is 0.2396370154604526']
# ['At iteration 27 the best fitness is 0.2396370154604526']
# ['At iteration 28 the best fitness is 0.2396370154604526']
# ['At iteration 29 the best fitness is 0.2396370154604526']
# ['At iteration 30 the best fitness is 0.2396370154604526']
#       Selected: 2139/4463 (47.9%), Fitness: 0.2396, Time: 1614.0s
#       Modality: D=46%, S=49%, Sk=48%, V=48%
#     Test Acc: 99.07%, F1: 99.06%, Features: 2139/4463 (47.9%), Model: 4.719MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.24546269325565762']
# ['At iteration 1 the best fitness is 0.22617534410657933']
# ['At iteration 2 the best fitness is 0.17997093443285497']
# ['At iteration 3 the best fitness is 0.17997093443285497']
# ['At iteration 4 the best fitness is 0.1508100875108106']
# ['At iteration 5 the best fitness is 0.13394033182491139']
# ['At iteration 6 the best fitness is 0.10177241325875684']
# ['At iteration 7 the best fitness is 0.09834652940794612']
# ['At iteration 8 the best fitness is 0.0969372263323987']
# ['At iteration 9 the best fitness is 0.09432802628465409']
# ['At iteration 10 the best fitness is 0.092441277293468']
# ['At iteration 11 the best fitness is 0.08000569584601112']
# ['At iteration 12 the best fitness is 0.08000569584601112']
# ['At iteration 13 the best fitness is 0.07747607011753965']
# ['At iteration 14 the best fitness is 0.07747607011753965']
# ['At iteration 15 the best fitness is 0.07425959237007923']
# ['At iteration 16 the best fitness is 0.06476930776624415']
# ['At iteration 17 the best fitness is 0.06132876548819892']
# ['At iteration 18 the best fitness is 0.06099266869232171']
# ['At iteration 19 the best fitness is 0.05030248711628949']
# ['At iteration 20 the best fitness is 0.05030248711628949']
# ['At iteration 21 the best fitness is 0.05030248711628949']
# ['At iteration 22 the best fitness is 0.05030248711628949']
# ['At iteration 23 the best fitness is 0.05030248711628949']
# ['At iteration 24 the best fitness is 0.05030248711628949']
# ['At iteration 25 the best fitness is 0.05030248711628949']
# ['At iteration 26 the best fitness is 0.05030248711628949']
# ['At iteration 27 the best fitness is 0.05030248711628949']
# ['At iteration 28 the best fitness is 0.05030248711628949']
# ['At iteration 29 the best fitness is 0.05030248711628949']
#       Selected: 449/4463 (10.1%), Fitness: 0.0503, Time: 1563.7s
#       Modality: D=10%, S=12%, Sk=9%, V=10%
#     Test Acc: 99.07%, F1: 98.94%, Features: 449/4463 (10.1%), Model: 1.418MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2551445844440582']
# ['At iteration 2 the best fitness is 0.25103184857425853']
# ['At iteration 3 the best fitness is 0.25103184857425853']
# ['At iteration 4 the best fitness is 0.25103184857425853']
# ['At iteration 5 the best fitness is 0.25091981630896615']
# ['At iteration 6 the best fitness is 0.24557472552095003']
# ['At iteration 7 the best fitness is 0.2448700739831763']
# ['At iteration 8 the best fitness is 0.2448700739831763']
# ['At iteration 9 the best fitness is 0.2448700739831763']
# ['At iteration 10 the best fitness is 0.2448700739831763']
# ['At iteration 11 the best fitness is 0.2448700739831763']
# ['At iteration 12 the best fitness is 0.2448700739831763']
# ['At iteration 13 the best fitness is 0.2448700739831763']
# ['At iteration 14 the best fitness is 0.2448700739831763']
# ['At iteration 15 the best fitness is 0.2448700739831763']
# ['At iteration 16 the best fitness is 0.2448700739831763']
# ['At iteration 17 the best fitness is 0.2448700739831763']
# ['At iteration 18 the best fitness is 0.2448700739831763']
# ['At iteration 19 the best fitness is 0.2448700739831763']
# ['At iteration 20 the best fitness is 0.2448700739831763']
# ['At iteration 21 the best fitness is 0.2448700739831763']
# ['At iteration 22 the best fitness is 0.2448700739831763']
# ['At iteration 23 the best fitness is 0.2448700739831763']
# ['At iteration 24 the best fitness is 0.2448700739831763']
# ['At iteration 25 the best fitness is 0.2448700739831763']
# ['At iteration 26 the best fitness is 0.2448700739831763']
# ['At iteration 27 the best fitness is 0.2448700739831763']
# ['At iteration 28 the best fitness is 0.2448700739831763']
# ['At iteration 29 the best fitness is 0.2448700739831763']
#       Selected: 2144/4463 (48.0%), Fitness: 0.2449, Time: 3959.1s
#       Modality: D=47%, S=48%, Sk=48%, V=48%
#     Test Acc: 98.13%, F1: 98.12%, Features: 2144/4463 (48.0%), Model: 4.729MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2606017074973667']
# ['At iteration 1 the best fitness is 0.08402105787775291']
# ['At iteration 2 the best fitness is 0.04593008767833548']
# ['At iteration 3 the best fitness is 0.0412571904820738']
# ['At iteration 4 the best fitness is 0.036584293285812114']
# ['At iteration 5 the best fitness is 0.036584293285812114']
# ['At iteration 6 the best fitness is 0.03482423498715294']
# ['At iteration 7 the best fitness is 0.03482423498715294']
# ['At iteration 8 the best fitness is 0.03482423498715294']
# ['At iteration 9 the best fitness is 0.03482423498715294']
# ['At iteration 10 the best fitness is 0.023909988880535915']
# ['At iteration 11 the best fitness is 0.023909988880535915']
# ['At iteration 12 the best fitness is 0.023909988880535915']
# ['At iteration 13 the best fitness is 0.023909988880535915']
# ['At iteration 14 the best fitness is 0.023909988880535915']
# ['At iteration 15 the best fitness is 0.023909988880535915']
# ['At iteration 16 the best fitness is 0.023909988880535915']
# ['At iteration 17 the best fitness is 0.023909988880535915']
# ['At iteration 18 the best fitness is 0.02379795661524351']
# ['At iteration 19 the best fitness is 0.02379795661524351']
# ['At iteration 20 the best fitness is 0.02379795661524351']
# ['At iteration 21 the best fitness is 0.02379795661524351']
# ['At iteration 22 the best fitness is 0.02379795661524351']
# ['At iteration 23 the best fitness is 0.02379795661524351']
# ['At iteration 24 the best fitness is 0.01890099488839702']
# ['At iteration 25 the best fitness is 0.01890099488839702']
# ['At iteration 26 the best fitness is 0.01890099488839702']
# ['At iteration 27 the best fitness is 0.01890099488839702']
# ['At iteration 28 the best fitness is 0.01890099488839702']
# ['At iteration 29 the best fitness is 0.01890099488839702']
#       Selected: 127/4463 (2.8%), Fitness: 0.0189, Time: 1431.1s
#       Modality: D=2%, S=4%, Sk=3%, V=3%
#     Test Acc: 91.59%, F1: 89.67%, Features: 127/4463 (2.8%), Model: 0.267MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          95.370370        100.000000     95.109828
# 1  baseline     2          94.444444         99.065421     93.180482
# 2  baseline     3          88.888889         99.065421     87.138047
# 3  baseline     4          92.592593         98.130841     91.441460
# 4  baseline     5          95.370370         98.130841     95.532040
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        95.109828            95.943563         95.370370               4463
# 1        93.180482            92.962963         94.444444               4463
# 2        87.138047            91.117524         88.888889               4463
# 3        91.441460            92.078189         92.592593               4463
# 4        95.532040            97.407407         95.370370               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              94.78              3.04              94.20              3.64                 4463.00                      100.00              0.00                31.98                31.98          2425371.0                  9.26                        0.00               72.33
# mutual_info              93.26              4.30              92.22              5.19                 2231.00                       49.99             62.70                26.85                89.55          1282587.0                  4.90                       50.01               45.90
#         rfe              94.31              2.88              93.49              3.41                 2231.00                       49.99             11.79                26.42                38.21          1282587.0                  4.90                       50.01               45.90
#       lasso              93.28              4.27              92.20              5.05                 2231.00                       49.99            380.86                26.40               407.26          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              93.97              3.90              93.19              4.45                 2182.38                       48.90           1733.54                28.30              1761.85          1257691.0                  4.80                       51.10               45.52
#     meta_CS              92.11              3.67              90.67              4.58                 2166.12                       48.54           3593.63                27.12              3620.76          1249371.0                  4.77                       51.46               45.39
#     meta_DE              92.70              3.90              91.64              4.70                 2123.12                       47.57           1827.23                29.09              1856.31          1227355.0                  4.69                       52.43               45.05
#    meta_FFA              94.19              4.33              93.39              5.30                 2165.50                       48.52           1770.08                28.63              1798.71          1249051.0                  4.77                       51.48               45.38
#     meta_GA              94.43              2.97              93.47              3.64                 2128.12                       47.68           1783.28                28.38              1811.67          1229915.0                  4.70                       52.32               45.09
#    meta_GWO              94.78              3.44              94.01              3.80                 1301.75                       29.17           1643.51                24.60              1668.11           806811.0                  3.08                       70.83               35.68
#    meta_HHO              88.74              4.14              87.71              4.54                  238.75                        5.35           2188.66                30.04              2218.71           202622.0                  0.78                       94.65               21.29
#   meta_JAYA              93.39              3.25              92.56              3.71                 2161.75                       48.44           1800.69                29.33              1830.03          1247131.0                  4.76                       51.56               45.35
#    meta_MFO              94.20              3.17              93.45              3.66                 2183.25                       48.92           1732.59                29.29              1761.88          1258139.0                  4.81                       51.08               45.53
#    meta_MVO              93.74              3.69              92.76              4.56                 2147.75                       48.12           1779.96                28.81              1808.77          1239963.0                  4.74                       51.88               45.24
#    meta_PSO              94.78              2.83              93.94              3.45                 2173.00                       48.69           1748.75                28.27              1777.02          1252891.0                  4.79                       51.31               45.45
#    meta_SCA              90.13              5.89              88.84              6.68                  406.25                        9.10           1700.20                29.20              1729.40           348315.0                  1.33                       90.90               24.29
#    meta_SSA              93.73              2.42              93.11              2.87                 2159.25                       48.38           4167.67                27.70              4195.37          1245851.0                  4.76                       51.62               45.33
#    meta_WOA              86.30              2.96              84.22              3.53                  204.25                        4.58           1502.42                27.16              1529.58           171479.0                  0.66                       95.42               20.65

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_PSO
#     F1 Macro:           96.19%
#     F1 Weighted:        96.19%
#     Test Accuracy:      96.30%
#     Feature Retention:  48.73% (2175/4463)
#     Modality Retention: depth=50.0%, sensor=50.3%, skeleton=48.8%, video=47.5%
#
#   Fold 2: Best = meta_JAYA
#     F1 Macro:           92.02%
#     F1 Weighted:        92.02%
#     Test Accuracy:      92.59%
#     Feature Retention:  47.59% (2124/4463)
#     Modality Retention: depth=43.9%, sensor=45.2%, skeleton=49.1%, video=48.0%
#
#   Fold 3: Best = meta_BAT
#     F1 Macro:           99.06%
#     F1 Weighted:        99.06%
#     Test Accuracy:      99.07%
#     Feature Retention:  48.73% (2175/4463)
#     Modality Retention: depth=50.0%, sensor=50.2%, skeleton=47.5%, video=49.2%
#
#   Fold 4: Best = meta_FFA
#     F1 Macro:           92.73%
#     F1 Weighted:        92.73%
#     Test Accuracy:      93.52%
#     Feature Retention:  48.47% (2163/4463)
#     Modality Retention: depth=47.9%, sensor=45.7%, skeleton=48.4%, video=50.0%
#
#   Fold 5: Best = meta_GWO
#     F1 Macro:           97.94%
#     F1 Weighted:        97.94%
#     Test Accuracy:      98.15%
#     Feature Retention:  27.67% (1235/4463)
#     Modality Retention: depth=30.7%, sensor=27.8%, skeleton=26.6%, video=28.0%
#
#   Fold 6: Best = meta_MVO
#     F1 Macro:           96.14%
#     F1 Weighted:        96.11%
#     Test Accuracy:      96.26%
#     Feature Retention:  47.01% (2098/4463)
#     Modality Retention: depth=44.5%, sensor=45.1%, skeleton=47.5%, video=48.2%
#
#   Fold 7: Best = meta_JAYA
#     F1 Macro:           98.20%
#     F1 Weighted:        98.18%
#     Test Accuracy:      98.13%
#     Feature Retention:  48.87% (2181/4463)
#     Modality Retention: depth=46.9%, sensor=48.2%, skeleton=48.6%, video=50.2%
#
#   Fold 8: Best = meta_CS
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  49.25% (2198/4463)
#     Modality Retention: depth=49.2%, sensor=50.0%, skeleton=49.6%, video=48.5%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 96.54% ± 2.88%
#
#   Average F1 Weighted         : 96.53% ± 2.88%
#
#   Average Test Accuracy       : 96.75% ± 2.62%
#
#   Average Feature Retention   : 45.79% ± 7.36%
#
#   Average Modality-wise Feature Retention:
#            depth: 45.39% ± 6.38%
#           sensor: 45.30% ± 7.43%
#         skeleton: 45.76% ± 7.79%
#            video: 46.20% ± 7.40%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1           meta_PSO         96.19            96.19              96.30                  48.73              50.00               50.31                 48.80              47.46
#     2          meta_JAYA         92.02            92.02              92.59                  47.59              43.95               45.25                 49.07              48.03
#     3           meta_BAT         99.06            99.06              99.07                  48.73              50.00               50.15                 47.53              49.23
#     4           meta_FFA         92.73            92.73              93.52                  48.47              47.85               45.71                 48.43              50.00
#     5           meta_GWO         97.94            97.94              98.15                  27.67              30.66               27.76                 26.56              28.03
#     6           meta_MVO         96.14            96.11              96.26                  47.01              44.53               45.09                 47.47              48.17
#     7          meta_JAYA         98.20            98.18              98.13                  48.87              46.88               48.16                 48.64              50.21
#     8            meta_CS        100.00           100.00             100.00                  49.25              49.22               50.00                 49.60              48.45
#
# Saved to: results_50/best_metaheuristic_per_fold.csv
