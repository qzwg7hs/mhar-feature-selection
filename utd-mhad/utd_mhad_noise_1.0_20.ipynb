# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_noise_1.0_20")

# Master output directory
RESULTS_ROOT = Path("results_noise_1.0_20")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

# FEATURE_DIMS will be set dynamically per-fold after PCA
# (depth dim changes if PCA is applied)
print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 92.59%, F1: 92.53%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 59.8s
#     Test Acc: 91.67%, F1: 90.59%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.4s
#     Test Acc: 91.67%, F1: 91.13%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 22.7s
#     Test Acc: 66.67%, F1: 65.14%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0870991181908988']
# ['At iteration 1 the best fitness is 0.0781085812527092']
# ['At iteration 2 the best fitness is 0.0781085812527092']
# ['At iteration 3 the best fitness is 0.0781085812527092']
# ['At iteration 4 the best fitness is 0.06924127980634125']
# ['At iteration 5 the best fitness is 0.06924127980634125']
# ['At iteration 6 the best fitness is 0.06924127980634125']
# ['At iteration 7 the best fitness is 0.06924127980634125']
# ['At iteration 8 the best fitness is 0.06924127980634125']
# ['At iteration 9 the best fitness is 0.06924127980634125']
# ['At iteration 10 the best fitness is 0.06924127980634125']
# ['At iteration 11 the best fitness is 0.06924127980634125']
# ['At iteration 12 the best fitness is 0.06924127980634125']
# ['At iteration 13 the best fitness is 0.06924127980634125']
# ['At iteration 14 the best fitness is 0.06924127980634125']
# ['At iteration 15 the best fitness is 0.06924127980634125']
# ['At iteration 16 the best fitness is 0.06924127980634125']
# ['At iteration 17 the best fitness is 0.06924127980634125']
# ['At iteration 18 the best fitness is 0.06924127980634125']
# ['At iteration 19 the best fitness is 0.06924127980634125']
# ['At iteration 20 the best fitness is 0.06924127980634125']
# ['At iteration 21 the best fitness is 0.06924127980634125']
# ['At iteration 22 the best fitness is 0.06924127980634125']
# ['At iteration 23 the best fitness is 0.06924127980634125']
# ['At iteration 24 the best fitness is 0.06924127980634125']
# ['At iteration 25 the best fitness is 0.06924127980634125']
# ['At iteration 26 the best fitness is 0.06924127980634125']
# ['At iteration 27 the best fitness is 0.06924127980634125']
# ['At iteration 28 the best fitness is 0.06924127980634125']
# ['At iteration 29 the best fitness is 0.06924127980634125']
#       Selected: 2218/4463 (49.7%), Fitness: 0.0692, Time: 1383.2s
#       Modality: D=49%, S=50%, Sk=49%, V=50%
#     Test Acc: 91.67%, F1: 90.50%, Features: 2218/4463 (49.7%), Model: 4.873MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06926368625939971']
# ['At iteration 1 the best fitness is 0.06926368625939971']
# ['At iteration 2 the best fitness is 0.06926368625939971']
# ['At iteration 3 the best fitness is 0.06926368625939971']
# ['At iteration 4 the best fitness is 0.060945342912964544']
# ['At iteration 5 the best fitness is 0.060945342912964544']
# ['At iteration 6 the best fitness is 0.060945342912964544']
# ['At iteration 7 the best fitness is 0.060945342912964544']
# ['At iteration 8 the best fitness is 0.060945342912964544']
# ['At iteration 9 the best fitness is 0.060945342912964544']
# ['At iteration 10 the best fitness is 0.060945342912964544']
# ['At iteration 11 the best fitness is 0.060945342912964544']
# ['At iteration 12 the best fitness is 0.060945342912964544']
# ['At iteration 13 the best fitness is 0.060945342912964544']
# ['At iteration 14 the best fitness is 0.060945342912964544']
# ['At iteration 15 the best fitness is 0.060945342912964544']
# ['At iteration 16 the best fitness is 0.060945342912964544']
# ['At iteration 17 the best fitness is 0.060945342912964544']
# ['At iteration 18 the best fitness is 0.060945342912964544']
# ['At iteration 19 the best fitness is 0.060945342912964544']
# ['At iteration 20 the best fitness is 0.060945342912964544']
# ['At iteration 21 the best fitness is 0.060945342912964544']
# ['At iteration 22 the best fitness is 0.060945342912964544']
# ['At iteration 23 the best fitness is 0.060945342912964544']
# ['At iteration 24 the best fitness is 0.060945342912964544']
# ['At iteration 25 the best fitness is 0.060945342912964544']
# ['At iteration 26 the best fitness is 0.060945342912964544']
# ['At iteration 27 the best fitness is 0.060945342912964544']
# ['At iteration 28 the best fitness is 0.060945342912964544']
# ['At iteration 29 the best fitness is 0.060945342912964544']
#       Selected: 2270/4463 (50.9%), Fitness: 0.0609, Time: 2769.7s
#       Modality: D=49%, S=52%, Sk=52%, V=49%
#     Test Acc: 92.59%, F1: 91.85%, Features: 2270/4463 (50.9%), Model: 4.975MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08658376977055374']
# ['At iteration 2 the best fitness is 0.08658376977055374']
# ['At iteration 3 the best fitness is 0.08658376977055374']
# ['At iteration 4 the best fitness is 0.07806376834659223']
# ['At iteration 5 the best fitness is 0.05166352208501469']
# ['At iteration 6 the best fitness is 0.05166352208501469']
# ['At iteration 7 the best fitness is 0.05166352208501469']
# ['At iteration 8 the best fitness is 0.05166352208501469']
# ['At iteration 9 the best fitness is 0.05166352208501469']
# ['At iteration 10 the best fitness is 0.05166352208501469']
# ['At iteration 11 the best fitness is 0.05166352208501469']
# ['At iteration 12 the best fitness is 0.05166352208501469']
# ['At iteration 13 the best fitness is 0.05166352208501469']
# ['At iteration 14 the best fitness is 0.05166352208501469']
# ['At iteration 15 the best fitness is 0.05166352208501469']
# ['At iteration 16 the best fitness is 0.05166352208501469']
# ['At iteration 17 the best fitness is 0.05166352208501469']
# ['At iteration 18 the best fitness is 0.05166352208501469']
# ['At iteration 19 the best fitness is 0.05166352208501469']
# ['At iteration 20 the best fitness is 0.05166352208501469']
# ['At iteration 21 the best fitness is 0.05166352208501469']
# ['At iteration 22 the best fitness is 0.05166352208501469']
# ['At iteration 23 the best fitness is 0.0513610349687252']
# ['At iteration 24 the best fitness is 0.0513610349687252']
# ['At iteration 25 the best fitness is 0.0513610349687252']
# ['At iteration 26 the best fitness is 0.0513610349687252']
# ['At iteration 27 the best fitness is 0.0513610349687252']
# ['At iteration 28 the best fitness is 0.0513610349687252']
# ['At iteration 29 the best fitness is 0.0513610349687252']
# ['At iteration 30 the best fitness is 0.0513610349687252']
#       Selected: 2207/4463 (49.5%), Fitness: 0.0514, Time: 1408.5s
#       Modality: D=49%, S=52%, Sk=49%, V=49%
#     Test Acc: 90.74%, F1: 90.59%, Features: 2207/4463 (49.5%), Model: 4.852MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06879315074517163']
# ['At iteration 1 the best fitness is 0.0776380457384811']
# ['At iteration 2 the best fitness is 0.060575636437499615']
# ['At iteration 3 the best fitness is 0.07782850058947818']
# ['At iteration 4 the best fitness is 0.07829903610370628']
# ['At iteration 5 the best fitness is 0.06872593138599618']
# ['At iteration 6 the best fitness is 0.06847946040235289']
# ['At iteration 7 the best fitness is 0.07758202960583489']
# ['At iteration 8 the best fitness is 0.0688715733308763']
# ['At iteration 9 the best fitness is 0.05111456398508191']
# ['At iteration 10 the best fitness is 0.06873713461252542']
# ['At iteration 11 the best fitness is 0.07761563928542262']
# ['At iteration 12 the best fitness is 0.0688715733308763']
# ['At iteration 13 the best fitness is 0.06002667833756683']
# ['At iteration 14 the best fitness is 0.05113697043814039']
# ['At iteration 15 the best fitness is 0.06888277655740555']
# ['At iteration 16 the best fitness is 0.0423144818978894']
# ['At iteration 17 the best fitness is 0.06891638623699327']
# ['At iteration 18 the best fitness is 0.07779489090989046']
# ['At iteration 19 the best fitness is 0.0777500780037735']
# ['At iteration 20 the best fitness is 0.05999306865797911']
# ['At iteration 21 the best fitness is 0.06884916687781782']
# ['At iteration 22 the best fitness is 0.08661737945014146']
# ['At iteration 23 the best fitness is 0.06884916687781782']
# ['At iteration 24 the best fitness is 0.06886037010434706']
# ['At iteration 25 the best fitness is 0.05999306865797911']
# ['At iteration 26 the best fitness is 0.0688715733308763']
# ['At iteration 27 the best fitness is 0.06886037010434706']
# ['At iteration 28 the best fitness is 0.05998186543144987']
# ['At iteration 29 the best fitness is 0.06886037010434706']
#       Selected: 2184/4463 (48.9%), Fitness: 0.0689, Time: 1357.5s
#       Modality: D=47%, S=49%, Sk=49%, V=49%
#     Test Acc: 91.67%, F1: 91.27%, Features: 2184/4463 (48.9%), Model: 4.807MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.08658376977055374
# At iteration 2 the best fitness is 0.07783970381600742
# At iteration 3 the best fitness is 0.07787331349559515
# At iteration 4 the best fitness is 0.07790692317518287
# At iteration 5 the best fitness is 0.06003788156409607
# At iteration 6 the best fitness is 0.07766045219153958
# At iteration 7 the best fitness is 0.07792932962824134
# At iteration 8 the best fitness is 0.0692860927124582
# At iteration 9 the best fitness is 0.07734676184872084
# At iteration 10 the best fitness is 0.07757082637930565
# At iteration 11 the best fitness is 0.0782206135180016
# At iteration 12 the best fitness is 0.0865725665440245
# At iteration 13 the best fitness is 0.08713272787048651
# At iteration 14 the best fitness is 0.08680783430113855
# At iteration 15 the best fitness is 0.06940932820427985
# At iteration 16 the best fitness is 0.06940932820427985
# At iteration 17 the best fitness is 0.069230076579812
# At iteration 18 the best fitness is 0.08695347624601868
# At iteration 19 the best fitness is 0.06916285722063656
# At iteration 20 the best fitness is 0.06021713318856392
# At iteration 21 the best fitness is 0.060317962227327084
# At iteration 22 the best fitness is 0.06919646690022428
# At iteration 23 the best fitness is 0.0691180443145196
# At iteration 24 the best fitness is 0.06921887335328276
# At iteration 25 the best fitness is 0.06027314932121012
# At iteration 26 the best fitness is 0.06918526367369504
# At iteration 27 the best fitness is 0.033581619169872325
# At iteration 28 the best fitness is 0.06925248303287049
# At iteration 29 the best fitness is 0.06905082495534415
# At iteration 30 the best fitness is 0.051305018836079
#       Selected: 2202/4463 (49.3%), Fitness: 0.0513, Time: 1360.0s
#       Modality: D=50%, S=51%, Sk=48%, V=49%
#     Test Acc: 90.74%, F1: 90.72%, Features: 2202/4463 (49.3%), Model: 4.842MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08724476013577892']
# ['At iteration 1 the best fitness is 0.0865725665440245']
# ['At iteration 2 the best fitness is 0.08606842135020867']
# ['At iteration 3 the best fitness is 0.07656253599167401']
# ['At iteration 4 the best fitness is 0.07656253599167401']
# ['At iteration 5 the best fitness is 0.06564504409045507']
# ['At iteration 6 the best fitness is 0.06563384086392582']
# ['At iteration 7 the best fitness is 0.06519691502928546']
# ['At iteration 8 the best fitness is 0.06519691502928546']
# ['At iteration 9 the best fitness is 0.0645471278905895']
# ['At iteration 10 the best fitness is 0.0645471278905895']
# ['At iteration 11 the best fitness is 0.0645471278905895']
# ['At iteration 12 the best fitness is 0.0645471278905895']
# ['At iteration 13 the best fitness is 0.0645471278905895']
# ['At iteration 14 the best fitness is 0.05529891674222737']
# ['At iteration 15 the best fitness is 0.05529891674222737']
# ['At iteration 16 the best fitness is 0.05529891674222737']
# ['At iteration 17 the best fitness is 0.05529891674222737']
# ['At iteration 18 the best fitness is 0.05529891674222737']
# ['At iteration 19 the best fitness is 0.05529891674222737']
# ['At iteration 20 the best fitness is 0.05529891674222737']
# ['At iteration 21 the best fitness is 0.05529891674222737']
# ['At iteration 22 the best fitness is 0.05529891674222737']
# ['At iteration 23 the best fitness is 0.05529891674222737']
# ['At iteration 24 the best fitness is 0.05529891674222737']
# ['At iteration 25 the best fitness is 0.05529891674222737']
# ['At iteration 26 the best fitness is 0.04621875399180385']
# ['At iteration 27 the best fitness is 0.04621875399180385']
# ['At iteration 28 the best fitness is 0.04621875399180385']
# ['At iteration 29 the best fitness is 0.04621875399180385']
#       Selected: 1748/4463 (39.2%), Fitness: 0.0462, Time: 1291.0s
#       Modality: D=42%, S=39%, Sk=38%, V=39%
#     Test Acc: 91.67%, F1: 91.29%, Features: 1748/4463 (39.2%), Model: 3.955MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.09606724867602992']
# ['At iteration 1 the best fitness is 0.09606724867602992']
# ['At iteration 2 the best fitness is 0.0922917613356759']
# ['At iteration 3 the best fitness is 0.0922917613356759']
# ['At iteration 4 the best fitness is 0.0922917613356759']
# ['At iteration 5 the best fitness is 0.08593953189359657']
# ['At iteration 6 the best fitness is 0.07701621431458242']
# ['At iteration 7 the best fitness is 0.07701621431458242']
# ['At iteration 8 the best fitness is 0.07587348520859989']
# ['At iteration 9 the best fitness is 0.07587348520859989']
# ['At iteration 10 the best fitness is 0.07587348520859989']
# ['At iteration 11 the best fitness is 0.07587348520859989']
# ['At iteration 12 the best fitness is 0.07587348520859989']
# ['At iteration 13 the best fitness is 0.06321394393360989']
# ['At iteration 14 the best fitness is 0.06321394393360989']
# ['At iteration 15 the best fitness is 0.06321394393360989']
# ['At iteration 16 the best fitness is 0.06321394393360989']
# ['At iteration 17 the best fitness is 0.06321394393360989']
# ['At iteration 18 the best fitness is 0.06321394393360989']
# ['At iteration 19 the best fitness is 0.06321394393360989']
# ['At iteration 20 the best fitness is 0.04242086019839134']
# ['At iteration 21 the best fitness is 0.04242086019839134']
# ['At iteration 22 the best fitness is 0.04242086019839134']
# ['At iteration 23 the best fitness is 0.04242086019839134']
# ['At iteration 24 the best fitness is 0.04242086019839134']
# ['At iteration 25 the best fitness is 0.04242086019839134']
# ['At iteration 26 the best fitness is 0.04242086019839134']
# ['At iteration 27 the best fitness is 0.04242086019839134']
# ['At iteration 28 the best fitness is 0.04242086019839134']
# ['At iteration 29 the best fitness is 0.04242086019839134']
#       Selected: 1409/4463 (31.6%), Fitness: 0.0424, Time: 1733.2s
#       Modality: D=29%, S=31%, Sk=31%, V=33%
#     Test Acc: 87.04%, F1: 86.81%, Features: 1409/4463 (31.6%), Model: 3.293MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0875136375724807']
# ['At iteration 1 the best fitness is 0.0875136375724807']
# ['At iteration 2 the best fitness is 0.08712152464395728']
# ['At iteration 3 the best fitness is 0.06051962030485341']
# ['At iteration 4 the best fitness is 0.06051962030485341']
# ['At iteration 5 the best fitness is 0.06051962030485341']
# ['At iteration 6 the best fitness is 0.06051962030485341']
# ['At iteration 7 the best fitness is 0.06051962030485341']
# ['At iteration 8 the best fitness is 0.06051962030485341']
# ['At iteration 9 the best fitness is 0.06051962030485341']
# ['At iteration 10 the best fitness is 0.06051962030485341']
# ['At iteration 11 the best fitness is 0.06051962030485341']
# ['At iteration 12 the best fitness is 0.06051962030485341']
# ['At iteration 13 the best fitness is 0.06051962030485341']
# ['At iteration 14 the best fitness is 0.06051962030485341']
# ['At iteration 15 the best fitness is 0.06051962030485341']
# ['At iteration 16 the best fitness is 0.06051962030485341']
# ['At iteration 17 the best fitness is 0.06051962030485341']
# ['At iteration 18 the best fitness is 0.06051962030485341']
# ['At iteration 19 the best fitness is 0.06051962030485341']
# ['At iteration 20 the best fitness is 0.06051962030485341']
# ['At iteration 21 the best fitness is 0.06051962030485341']
# ['At iteration 22 the best fitness is 0.06051962030485341']
# ['At iteration 23 the best fitness is 0.06051962030485341']
# ['At iteration 24 the best fitness is 0.06051962030485341']
# ['At iteration 25 the best fitness is 0.06051962030485341']
# ['At iteration 26 the best fitness is 0.06051962030485341']
# ['At iteration 27 the best fitness is 0.06051962030485341']
# ['At iteration 28 the best fitness is 0.06051962030485341']
# ['At iteration 29 the best fitness is 0.06051962030485341']
#       Selected: 2232/4463 (50.0%), Fitness: 0.0605, Time: 1410.6s
#       Modality: D=50%, S=50%, Sk=50%, V=50%
#     Test Acc: 87.96%, F1: 86.19%, Features: 2232/4463 (50.0%), Model: 4.901MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0866285826766707']
# ['At iteration 2 the best fitness is 0.07819820706494311']
# ['At iteration 3 the best fitness is 0.07819820706494311']
# ['At iteration 4 the best fitness is 0.07811978447923844']
# ['At iteration 5 the best fitness is 0.07811978447923844']
# ['At iteration 6 the best fitness is 0.07807497157312147']
# ['At iteration 7 the best fitness is 0.07804136189353375']
# ['At iteration 8 the best fitness is 0.06062044934361657']
# ['At iteration 9 the best fitness is 0.06062044934361657']
# ['At iteration 10 the best fitness is 0.06062044934361657']
# ['At iteration 11 the best fitness is 0.06062044934361657']
# ['At iteration 12 the best fitness is 0.06062044934361657']
# ['At iteration 13 the best fitness is 0.06062044934361657']
# ['At iteration 14 the best fitness is 0.06062044934361657']
# ['At iteration 15 the best fitness is 0.06062044934361657']
# ['At iteration 16 the best fitness is 0.06062044934361657']
# ['At iteration 17 the best fitness is 0.06062044934361657']
# ['At iteration 18 the best fitness is 0.060474807398736445']
# ['At iteration 19 the best fitness is 0.060474807398736445']
# ['At iteration 20 the best fitness is 0.060474807398736445']
# ['At iteration 21 the best fitness is 0.060474807398736445']
# ['At iteration 22 the best fitness is 0.060474807398736445']
# ['At iteration 23 the best fitness is 0.060474807398736445']
# ['At iteration 24 the best fitness is 0.060474807398736445']
# ['At iteration 25 the best fitness is 0.060474807398736445']
# ['At iteration 26 the best fitness is 0.060474807398736445']
# ['At iteration 27 the best fitness is 0.060474807398736445']
# ['At iteration 28 the best fitness is 0.060474807398736445']
# ['At iteration 29 the best fitness is 0.051764351123777856']
#       Selected: 2243/4463 (50.3%), Fitness: 0.0518, Time: 1329.5s
#       Modality: D=50%, S=50%, Sk=49%, V=52%
#     Test Acc: 91.67%, F1: 90.91%, Features: 2243/4463 (50.3%), Model: 4.922MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08706550851131108']
# ['At iteration 2 the best fitness is 0.07876957161793438']
# ['At iteration 3 the best fitness is 0.0783886619159402']
# ['At iteration 4 the best fitness is 0.0783886619159402']
# ['At iteration 5 the best fitness is 0.0783886619159402']
# ['At iteration 6 the best fitness is 0.06949895401651376']
# ['At iteration 7 the best fitness is 0.06078849774155518']
# ['At iteration 8 the best fitness is 0.06078849774155518']
# ['At iteration 9 the best fitness is 0.06078849774155518']
# ['At iteration 10 the best fitness is 0.06078849774155518']
# ['At iteration 11 the best fitness is 0.06078849774155518']
# ['At iteration 12 the best fitness is 0.06078849774155518']
# ['At iteration 13 the best fitness is 0.06078849774155518']
# ['At iteration 14 the best fitness is 0.06078849774155518']
# ['At iteration 15 the best fitness is 0.06078849774155518']
# ['At iteration 16 the best fitness is 0.06078849774155518']
# ['At iteration 17 the best fitness is 0.06078849774155518']
# ['At iteration 18 the best fitness is 0.06078849774155518']
# ['At iteration 19 the best fitness is 0.06078849774155518']
# ['At iteration 20 the best fitness is 0.06078849774155518']
# ['At iteration 21 the best fitness is 0.06078849774155518']
# ['At iteration 22 the best fitness is 0.06078849774155518']
# ['At iteration 23 the best fitness is 0.06078849774155518']
# ['At iteration 24 the best fitness is 0.06078849774155518']
# ['At iteration 25 the best fitness is 0.06078849774155518']
# ['At iteration 26 the best fitness is 0.06078849774155518']
# ['At iteration 27 the best fitness is 0.06078849774155518']
# ['At iteration 28 the best fitness is 0.060710075155850494']
# ['At iteration 29 the best fitness is 0.060710075155850494']
# ['At iteration 30 the best fitness is 0.060710075155850494']
#       Selected: 2249/4463 (50.4%), Fitness: 0.0607, Time: 1371.7s
#       Modality: D=52%, S=45%, Sk=50%, V=53%
#     Test Acc: 88.89%, F1: 88.56%, Features: 2249/4463 (50.4%), Model: 4.934MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08695347624601868']
# ['At iteration 2 the best fitness is 0.08667339558278767']
# ['At iteration 3 the best fitness is 0.08667339558278767']
# ['At iteration 4 the best fitness is 0.08667339558278767']
# ['At iteration 5 the best fitness is 0.08667339558278767']
# ['At iteration 6 the best fitness is 0.06034036868038556']
# ['At iteration 7 the best fitness is 0.06034036868038556']
# ['At iteration 8 the best fitness is 0.06034036868038556']
# ['At iteration 9 the best fitness is 0.06034036868038556']
# ['At iteration 10 the best fitness is 0.06034036868038556']
# ['At iteration 11 the best fitness is 0.06034036868038556']
# ['At iteration 12 the best fitness is 0.06034036868038556']
# ['At iteration 13 the best fitness is 0.06034036868038556']
# ['At iteration 14 the best fitness is 0.06034036868038556']
# ['At iteration 15 the best fitness is 0.06034036868038556']
# ['At iteration 16 the best fitness is 0.06034036868038556']
# ['At iteration 17 the best fitness is 0.06034036868038556']
# ['At iteration 18 the best fitness is 0.06034036868038556']
# ['At iteration 19 the best fitness is 0.06034036868038556']
# ['At iteration 20 the best fitness is 0.06034036868038556']
# ['At iteration 21 the best fitness is 0.06034036868038556']
# ['At iteration 22 the best fitness is 0.06034036868038556']
# ['At iteration 23 the best fitness is 0.06020592996203468']
# ['At iteration 24 the best fitness is 0.06020592996203468']
# ['At iteration 25 the best fitness is 0.06020592996203468']
# ['At iteration 26 the best fitness is 0.06020592996203468']
# ['At iteration 27 the best fitness is 0.06020592996203468']
# ['At iteration 28 the best fitness is 0.06020592996203468']
# ['At iteration 29 the best fitness is 0.06020592996203468']
# ['At iteration 30 the best fitness is 0.06020592996203468']
#       Selected: 2204/4463 (49.4%), Fitness: 0.0602, Time: 1362.1s
#       Modality: D=55%, S=46%, Sk=50%, V=49%
#     Test Acc: 87.96%, F1: 87.25%, Features: 2204/4463 (49.4%), Model: 4.846MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09645936160455333']
# ['At iteration 1 the best fitness is 0.0925158258662607']
# ['At iteration 2 the best fitness is 0.0737057132267177']
# ['At iteration 3 the best fitness is 0.0737057132267177']
# ['At iteration 4 the best fitness is 0.07140905178822342']
# ['At iteration 5 the best fitness is 0.07140905178822342']
# ['At iteration 6 the best fitness is 0.07140905178822342']
# ['At iteration 7 the best fitness is 0.07140905178822342']
# ['At iteration 8 the best fitness is 0.05850858879132892']
# ['At iteration 9 the best fitness is 0.05850858879132892']
# ['At iteration 10 the best fitness is 0.05850858879132892']
# ['At iteration 11 the best fitness is 0.05850858879132892']
# ['At iteration 12 the best fitness is 0.05850858879132892']
# ['At iteration 13 the best fitness is 0.05850858879132892']
# ['At iteration 14 the best fitness is 0.05850858879132892']
# ['At iteration 15 the best fitness is 0.05850858879132892']
# ['At iteration 16 the best fitness is 0.05850858879132892']
# ['At iteration 17 the best fitness is 0.05850858879132892']
# ['At iteration 18 the best fitness is 0.05428497238980528']
# ['At iteration 19 the best fitness is 0.05428497238980528']
# ['At iteration 20 the best fitness is 0.05428497238980528']
# ['At iteration 21 the best fitness is 0.05428497238980528']
# ['At iteration 22 the best fitness is 0.05428497238980528']
# ['At iteration 23 the best fitness is 0.05428497238980528']
# ['At iteration 24 the best fitness is 0.05428497238980528']
# ['At iteration 25 the best fitness is 0.05396007882045731']
# ['At iteration 26 the best fitness is 0.05396007882045731']
# ['At iteration 27 the best fitness is 0.05396007882045731']
# ['At iteration 28 the best fitness is 0.05396007882045731']
# ['At iteration 29 the best fitness is 0.04453261604762733']
#       Selected: 805/4463 (18.0%), Fitness: 0.0445, Time: 1160.8s
#       Modality: D=16%, S=18%, Sk=19%, V=18%
#     Test Acc: 85.19%, F1: 83.43%, Features: 805/4463 (18.0%), Model: 2.113MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06901721527575644']
# ['At iteration 2 the best fitness is 0.06901721527575644']
# ['At iteration 3 the best fitness is 0.0690060120492272']
# ['At iteration 4 the best fitness is 0.0690060120492272']
# ['At iteration 5 the best fitness is 0.0690060120492272']
# ['At iteration 6 the best fitness is 0.0690060120492272']
# ['At iteration 7 the best fitness is 0.0690060120492272']
# ['At iteration 8 the best fitness is 0.051282612383020516']
# ['At iteration 9 the best fitness is 0.051282612383020516']
# ['At iteration 10 the best fitness is 0.051282612383020516']
# ['At iteration 11 the best fitness is 0.051282612383020516']
# ['At iteration 12 the best fitness is 0.051282612383020516']
# ['At iteration 13 the best fitness is 0.051282612383020516']
# ['At iteration 14 the best fitness is 0.051282612383020516']
# ['At iteration 15 the best fitness is 0.051282612383020516']
# ['At iteration 16 the best fitness is 0.051282612383020516']
# ['At iteration 17 the best fitness is 0.051282612383020516']
# ['At iteration 18 the best fitness is 0.051282612383020516']
# ['At iteration 19 the best fitness is 0.051282612383020516']
# ['At iteration 20 the best fitness is 0.051282612383020516']
# ['At iteration 21 the best fitness is 0.051282612383020516']
# ['At iteration 22 the best fitness is 0.051282612383020516']
# ['At iteration 23 the best fitness is 0.051282612383020516']
# ['At iteration 24 the best fitness is 0.051282612383020516']
# ['At iteration 25 the best fitness is 0.051282612383020516']
# ['At iteration 26 the best fitness is 0.051282612383020516']
# ['At iteration 27 the best fitness is 0.051282612383020516']
# ['At iteration 28 the best fitness is 0.051282612383020516']
# ['At iteration 29 the best fitness is 0.051282612383020516']
#       Selected: 2200/4463 (49.3%), Fitness: 0.0513, Time: 3406.6s
#       Modality: D=51%, S=48%, Sk=49%, V=49%
#     Test Acc: 93.52%, F1: 93.08%, Features: 2200/4463 (49.3%), Model: 4.838MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09559671316180182']
# ['At iteration 1 the best fitness is 0.08318919213219389']
# ['At iteration 2 the best fitness is 0.08318919213219389']
# ['At iteration 3 the best fitness is 0.08318919213219389']
# ['At iteration 4 the best fitness is 0.08318919213219389']
# ['At iteration 5 the best fitness is 0.08318919213219389']
# ['At iteration 6 the best fitness is 0.08318919213219389']
# ['At iteration 7 the best fitness is 0.08318919213219389']
# ['At iteration 8 the best fitness is 0.08318919213219389']
# ['At iteration 9 the best fitness is 0.08318919213219389']
# ['At iteration 10 the best fitness is 0.08318919213219389']
# ['At iteration 11 the best fitness is 0.08318919213219389']
# ['At iteration 12 the best fitness is 0.08318919213219389']
# ['At iteration 13 the best fitness is 0.08318919213219389']
# ['At iteration 14 the best fitness is 0.06584115290624261']
# ['At iteration 15 the best fitness is 0.06584115290624261']
# ['At iteration 16 the best fitness is 0.06584115290624261']
# ['At iteration 17 the best fitness is 0.06584115290624261']
# ['At iteration 18 the best fitness is 0.06584115290624261']
# ['At iteration 19 the best fitness is 0.06584115290624261']
# ['At iteration 20 the best fitness is 0.06584115290624261']
# ['At iteration 21 the best fitness is 0.06584115290624261']
# ['At iteration 22 the best fitness is 0.06584115290624261']
# ['At iteration 23 the best fitness is 0.06584115290624261']
# ['At iteration 24 the best fitness is 0.06584115290624261']
# ['At iteration 25 the best fitness is 0.06584115290624261']
# ['At iteration 26 the best fitness is 0.06584115290624261']
# ['At iteration 27 the best fitness is 0.06584115290624261']
# ['At iteration 28 the best fitness is 0.06535941416548527']
# ['At iteration 29 the best fitness is 0.06535941416548527']
#       Selected: 2664/4463 (59.7%), Fitness: 0.0654, Time: 1404.2s
#       Modality: D=58%, S=60%, Sk=59%, V=61%
#     Test Acc: 89.81%, F1: 88.61%, Features: 2664/4463 (59.7%), Model: 5.744MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 90.74%, F1: 90.12%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 58.8s
#     Test Acc: 94.44%, F1: 94.04%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.3s
#     Test Acc: 93.52%, F1: 92.91%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 8.0s
#     Test Acc: 67.59%, F1: 64.71%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06042999449261949']
# ['At iteration 1 the best fitness is 0.05204443178700886']
# ['At iteration 2 the best fitness is 0.05204443178700886']
# ['At iteration 3 the best fitness is 0.05204443178700886']
# ['At iteration 4 the best fitness is 0.05204443178700886']
# ['At iteration 5 the best fitness is 0.05204443178700886']
# ['At iteration 6 the best fitness is 0.05204443178700886']
# ['At iteration 7 the best fitness is 0.05204443178700886']
# ['At iteration 8 the best fitness is 0.05204443178700886']
# ['At iteration 9 the best fitness is 0.04325555292634559']
# ['At iteration 10 the best fitness is 0.04325555292634559']
# ['At iteration 11 the best fitness is 0.04325555292634559']
# ['At iteration 12 the best fitness is 0.04325555292634559']
# ['At iteration 13 the best fitness is 0.04325555292634559']
# ['At iteration 14 the best fitness is 0.04325555292634559']
# ['At iteration 15 the best fitness is 0.04325555292634559']
# ['At iteration 16 the best fitness is 0.04325555292634559']
# ['At iteration 17 the best fitness is 0.04325555292634559']
# ['At iteration 18 the best fitness is 0.04325555292634559']
# ['At iteration 19 the best fitness is 0.04325555292634559']
# ['At iteration 20 the best fitness is 0.04325555292634559']
# ['At iteration 21 the best fitness is 0.04325555292634559']
# ['At iteration 22 the best fitness is 0.04325555292634559']
# ['At iteration 23 the best fitness is 0.04324434969981636']
# ['At iteration 24 the best fitness is 0.04324434969981636']
# ['At iteration 25 the best fitness is 0.04324434969981636']
# ['At iteration 26 the best fitness is 0.04324434969981636']
# ['At iteration 27 the best fitness is 0.04324434969981636']
# ['At iteration 28 the best fitness is 0.04324434969981636']
# ['At iteration 29 the best fitness is 0.04324434969981636']
#       Selected: 2275/4463 (51.0%), Fitness: 0.0432, Time: 1411.0s
#       Modality: D=49%, S=52%, Sk=52%, V=50%
#     Test Acc: 92.59%, F1: 92.32%, Features: 2275/4463 (51.0%), Model: 4.984MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.060777294515025934']
# ['At iteration 1 the best fitness is 0.060777294515025934']
# ['At iteration 2 the best fitness is 0.051338628515666715']
# ['At iteration 3 the best fitness is 0.051338628515666715']
# ['At iteration 4 the best fitness is 0.051338628515666715']
# ['At iteration 5 the best fitness is 0.051338628515666715']
# ['At iteration 6 the best fitness is 0.04256095288153269']
# ['At iteration 7 the best fitness is 0.04256095288153269']
# ['At iteration 8 the best fitness is 0.04256095288153269']
# ['At iteration 9 the best fitness is 0.04256095288153269']
# ['At iteration 10 the best fitness is 0.04256095288153269']
# ['At iteration 11 the best fitness is 0.04256095288153269']
# ['At iteration 12 the best fitness is 0.04256095288153269']
# ['At iteration 13 the best fitness is 0.04256095288153269']
# ['At iteration 14 the best fitness is 0.04256095288153269']
# ['At iteration 15 the best fitness is 0.04256095288153269']
# ['At iteration 16 the best fitness is 0.04256095288153269']
# ['At iteration 17 the best fitness is 0.04256095288153269']
# ['At iteration 18 the best fitness is 0.04256095288153269']
# ['At iteration 19 the best fitness is 0.04256095288153269']
# ['At iteration 20 the best fitness is 0.04256095288153269']
# ['At iteration 21 the best fitness is 0.04254974965500345']
# ['At iteration 22 the best fitness is 0.04254974965500345']
# ['At iteration 23 the best fitness is 0.04254974965500345']
# ['At iteration 24 the best fitness is 0.04254974965500345']
# ['At iteration 25 the best fitness is 0.04235929480400636']
# ['At iteration 26 the best fitness is 0.04235929480400636']
# ['At iteration 27 the best fitness is 0.04235929480400636']
# ['At iteration 28 the best fitness is 0.04235929480400636']
# ['At iteration 29 the best fitness is 0.04235929480400636']
#       Selected: 2196/4463 (49.2%), Fitness: 0.0424, Time: 2780.9s
#       Modality: D=46%, S=52%, Sk=50%, V=48%
#     Test Acc: 90.74%, F1: 90.64%, Features: 2196/4463 (49.2%), Model: 4.830MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06049721385179493']
# ['At iteration 2 the best fitness is 0.06049721385179493']
# ['At iteration 3 the best fitness is 0.06049721385179493']
# ['At iteration 4 the best fitness is 0.06049721385179493']
# ['At iteration 5 the best fitness is 0.06049721385179493']
# ['At iteration 6 the best fitness is 0.060418791266090247']
# ['At iteration 7 the best fitness is 0.03354800949028461']
# ['At iteration 8 the best fitness is 0.0334919933576384']
# ['At iteration 9 the best fitness is 0.0334919933576384']
# ['At iteration 10 the best fitness is 0.0334919933576384']
# ['At iteration 11 the best fitness is 0.0334919933576384']
# ['At iteration 12 the best fitness is 0.0334919933576384']
# ['At iteration 13 the best fitness is 0.0334919933576384']
# ['At iteration 14 the best fitness is 0.0334919933576384']
# ['At iteration 15 the best fitness is 0.0334919933576384']
# ['At iteration 16 the best fitness is 0.0334919933576384']
# ['At iteration 17 the best fitness is 0.0334919933576384']
# ['At iteration 18 the best fitness is 0.0334919933576384']
# ['At iteration 19 the best fitness is 0.0334919933576384']
# ['At iteration 20 the best fitness is 0.0334919933576384']
# ['At iteration 21 the best fitness is 0.0334919933576384']
# ['At iteration 22 the best fitness is 0.0334919933576384']
# ['At iteration 23 the best fitness is 0.0323828739312436']
# ['At iteration 24 the best fitness is 0.0323828739312436']
# ['At iteration 25 the best fitness is 0.0323828739312436']
# ['At iteration 26 the best fitness is 0.0323828739312436']
# ['At iteration 27 the best fitness is 0.0323828739312436']
# ['At iteration 28 the best fitness is 0.0323828739312436']
# ['At iteration 29 the best fitness is 0.0323828739312436']
# ['At iteration 30 the best fitness is 0.0323828739312436']
#       Selected: 2098/4463 (47.0%), Fitness: 0.0324, Time: 1410.3s
#       Modality: D=45%, S=44%, Sk=49%, V=47%
#     Test Acc: 87.96%, F1: 86.02%, Features: 2098/4463 (47.0%), Model: 4.639MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0690620281818734']
# ['At iteration 1 the best fitness is 0.059780207353923545']
# ['At iteration 2 the best fitness is 0.051685928538073175']
# ['At iteration 3 the best fitness is 0.04265057869376661']
# ['At iteration 4 the best fitness is 0.07796293930782906']
# ['At iteration 5 the best fitness is 0.06945414111039681']
# ['At iteration 6 the best fitness is 0.051506676913605325']
# ['At iteration 7 the best fitness is 0.06045240094567797']
# ['At iteration 8 the best fitness is 0.06908443463493187']
# ['At iteration 9 the best fitness is 0.060396384813031764']
# ['At iteration 10 the best fitness is 0.06036277513344404']
# ['At iteration 11 the best fitness is 0.06921887335328276']
# ['At iteration 12 the best fitness is 0.06022833641509316']
# ['At iteration 13 the best fitness is 0.06909563786146111']
# ['At iteration 14 the best fitness is 0.06912924754104884']
# ['At iteration 15 the best fitness is 0.04263937546723737']
# ['At iteration 16 the best fitness is 0.06027314932121012']
# ['At iteration 17 the best fitness is 0.06918526367369504']
# ['At iteration 18 the best fitness is 0.0691740604471658']
# ['At iteration 19 the best fitness is 0.06916285722063656']
# ['At iteration 20 the best fitness is 0.06027314932121012']
# ['At iteration 21 the best fitness is 0.06028435254773936']
# ['At iteration 22 the best fitness is 0.07805256512006299']
# ['At iteration 23 the best fitness is 0.051450660780959126']
# ['At iteration 24 the best fitness is 0.0603515719069148']
# ['At iteration 25 the best fitness is 0.069230076579812']
# ['At iteration 26 the best fitness is 0.0603515719069148']
# ['At iteration 27 the best fitness is 0.069230076579812']
# ['At iteration 28 the best fitness is 0.07809737802617996']
# ['At iteration 29 the best fitness is 0.06036277513344404']
#       Selected: 2218/4463 (49.7%), Fitness: 0.0604, Time: 1363.9s
#       Modality: D=48%, S=50%, Sk=51%, V=49%
#     Test Acc: 92.59%, F1: 92.62%, Features: 2218/4463 (49.7%), Model: 4.873MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.07820941029147235
# At iteration 2 the best fitness is 0.06933090561857516
# At iteration 3 the best fitness is 0.060474807398736445
# At iteration 4 the best fitness is 0.06878194751864239
# At iteration 5 the best fitness is 0.06914045076757808
# At iteration 6 the best fitness is 0.05146186400748837
# At iteration 7 the best fitness is 0.069230076579812
# At iteration 8 the best fitness is 0.05149547368707609
# At iteration 9 the best fitness is 0.05138344142178368
# At iteration 10 the best fitness is 0.05149547368707609
# At iteration 11 the best fitness is 0.0513610349687252
# At iteration 12 the best fitness is 0.06026194609468088
# At iteration 13 the best fitness is 0.042953065810056104
# At iteration 14 the best fitness is 0.05149547368707609
# At iteration 15 the best fitness is 0.05106975107896495
# At iteration 16 the best fitness is 0.05106975107896495
# At iteration 17 the best fitness is 0.05155148981972228
# At iteration 18 the best fitness is 0.0428970496774099
# At iteration 19 the best fitness is 0.06013871060285923
# At iteration 20 the best fitness is 0.05997066220492063
# At iteration 21 the best fitness is 0.04235929480400636
# At iteration 22 the best fitness is 0.051349831742195956
# At iteration 23 the best fitness is 0.04259456256112041
# At iteration 24 the best fitness is 0.05140584787484216
# At iteration 25 the best fitness is 0.05111456398508191
# At iteration 26 the best fitness is 0.051585099499310005
# At iteration 27 the best fitness is 0.05113697043814039
# At iteration 28 the best fitness is 0.04226966899177244
# At iteration 29 the best fitness is 0.059914646072274425
# At iteration 30 the best fitness is 0.033379961092346
#       Selected: 2187/4463 (49.0%), Fitness: 0.0334, Time: 1365.0s
#       Modality: D=46%, S=50%, Sk=49%, V=50%
#     Test Acc: 86.11%, F1: 84.82%, Features: 2187/4463 (49.0%), Model: 4.813MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05232451245023988']
# ['At iteration 1 the best fitness is 0.05232451245023988']
# ['At iteration 2 the best fitness is 0.05232451245023988']
# ['At iteration 3 the best fitness is 0.05232451245023988']
# ['At iteration 4 the best fitness is 0.05232451245023988']
# ['At iteration 5 the best fitness is 0.05232451245023988']
# ['At iteration 6 the best fitness is 0.05232451245023988']
# ['At iteration 7 the best fitness is 0.05232451245023988']
# ['At iteration 8 the best fitness is 0.05232451245023988']
# ['At iteration 9 the best fitness is 0.05232451245023988']
# ['At iteration 10 the best fitness is 0.04908677998328939']
# ['At iteration 11 the best fitness is 0.04908677998328939']
# ['At iteration 12 the best fitness is 0.04903076385064319']
# ['At iteration 13 the best fitness is 0.04903076385064319']
# ['At iteration 14 the best fitness is 0.0407908430899127']
# ['At iteration 15 the best fitness is 0.0407908430899127']
# ['At iteration 16 the best fitness is 0.0407908430899127']
# ['At iteration 17 the best fitness is 0.0407908430899127']
# ['At iteration 18 the best fitness is 0.0407908430899127']
# ['At iteration 19 the best fitness is 0.0407908430899127']
# ['At iteration 20 the best fitness is 0.0407908430899127']
# ['At iteration 21 the best fitness is 0.0407908430899127']
# ['At iteration 22 the best fitness is 0.0407908430899127']
# ['At iteration 23 the best fitness is 0.0407908430899127']
# ['At iteration 24 the best fitness is 0.0407908430899127']
# ['At iteration 25 the best fitness is 0.0407908430899127']
# ['At iteration 26 the best fitness is 0.0407908430899127']
# ['At iteration 27 the best fitness is 0.0407908430899127']
# ['At iteration 28 the best fitness is 0.0407908430899127']
# ['At iteration 29 the best fitness is 0.0407908430899127']
#       Selected: 2056/4463 (46.1%), Fitness: 0.0408, Time: 1304.9s
#       Modality: D=45%, S=45%, Sk=46%, V=47%
#     Test Acc: 83.33%, F1: 79.80%, Features: 2056/4463 (46.1%), Model: 4.557MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.06062044934361657']
# ['At iteration 1 the best fitness is 0.06062044934361657']
# ['At iteration 2 the best fitness is 0.06062044934361657']
# ['At iteration 3 the best fitness is 0.06062044934361657']
# ['At iteration 4 the best fitness is 0.06062044934361657']
# ['At iteration 5 the best fitness is 0.06062044934361657']
# ['At iteration 6 the best fitness is 0.06062044934361657']
# ['At iteration 7 the best fitness is 0.06062044934361657']
# ['At iteration 8 the best fitness is 0.06062044934361657']
# ['At iteration 9 the best fitness is 0.06062044934361657']
# ['At iteration 10 the best fitness is 0.06062044934361657']
# ['At iteration 11 the best fitness is 0.06062044934361657']
# ['At iteration 12 the best fitness is 0.06062044934361657']
# ['At iteration 13 the best fitness is 0.06062044934361657']
# ['At iteration 14 the best fitness is 0.05112576721161115']
# ['At iteration 15 the best fitness is 0.05112576721161115']
# ['At iteration 16 the best fitness is 0.05112576721161115']
# ['At iteration 17 the best fitness is 0.05112576721161115']
# ['At iteration 18 the best fitness is 0.05112576721161115']
# ['At iteration 19 the best fitness is 0.05112576721161115']
# ['At iteration 20 the best fitness is 0.05112576721161115']
# ['At iteration 21 the best fitness is 0.04508167885061179']
# ['At iteration 22 the best fitness is 0.04508167885061179']
# ['At iteration 23 the best fitness is 0.04508167885061179']
# ['At iteration 24 the best fitness is 0.04508167885061179']
# ['At iteration 25 the best fitness is 0.04508167885061179']
# ['At iteration 26 the best fitness is 0.04508167885061179']
# ['At iteration 27 the best fitness is 0.04508167885061179']
# ['At iteration 28 the best fitness is 0.04508167885061179']
# ['At iteration 29 the best fitness is 0.04508167885061179']
#       Selected: 2439/4463 (54.6%), Fitness: 0.0451, Time: 1807.1s
#       Modality: D=54%, S=53%, Sk=54%, V=57%
#     Test Acc: 90.74%, F1: 88.76%, Features: 2439/4463 (54.6%), Model: 5.305MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06066526224973354']
# ['At iteration 1 the best fitness is 0.06066526224973354']
# ['At iteration 2 the best fitness is 0.06066526224973354']
# ['At iteration 3 the best fitness is 0.06028435254773936']
# ['At iteration 4 the best fitness is 0.06021713318856392']
# ['At iteration 5 the best fitness is 0.05161870917889773']
# ['At iteration 6 the best fitness is 0.05118178334425735']
# ['At iteration 7 the best fitness is 0.05118178334425735']
# ['At iteration 8 the best fitness is 0.05090170268102634']
# ['At iteration 9 the best fitness is 0.05090170268102634']
# ['At iteration 10 the best fitness is 0.05090170268102634']
# ['At iteration 11 the best fitness is 0.05090170268102634']
# ['At iteration 12 the best fitness is 0.05090170268102634']
# ['At iteration 13 the best fitness is 0.05090170268102634']
# ['At iteration 14 the best fitness is 0.05090170268102634']
# ['At iteration 15 the best fitness is 0.05090170268102634']
# ['At iteration 16 the best fitness is 0.05090170268102634']
# ['At iteration 17 the best fitness is 0.05090170268102634']
# ['At iteration 18 the best fitness is 0.05090170268102634']
# ['At iteration 19 the best fitness is 0.05090170268102634']
# ['At iteration 20 the best fitness is 0.05090170268102634']
# ['At iteration 21 the best fitness is 0.05076726396267546']
# ['At iteration 22 the best fitness is 0.05076726396267546']
# ['At iteration 23 the best fitness is 0.05076726396267546']
# ['At iteration 24 the best fitness is 0.05076726396267546']
# ['At iteration 25 the best fitness is 0.05076726396267546']
# ['At iteration 26 the best fitness is 0.05076726396267546']
# ...
# ['At iteration 15 the best fitness is 0.056183971638037365']
# ['At iteration 16 the best fitness is 0.056183971638037365']
# ['At iteration 17 the best fitness is 0.05082882935706044']
# ['At iteration 18 the best fitness is 0.05082882935706044']
# ['At iteration 19 the best fitness is 0.05082882935706044']
# ['At iteration 20 the best fitness is 0.050615968053004876']
# ['At iteration 21 the best fitness is 0.04186069887192932']
# ['At iteration 22 the best fitness is 0.04186069887192932']
# ['At iteration 23 the best fitness is 0.04186069887192932']
# ['At iteration 24 the best fitness is 0.04186069887192932']
# ['At iteration 25 the best fitness is 0.04186069887192932']
# ['At iteration 26 the best fitness is 0.04186069887192932']
# ['At iteration 27 the best fitness is 0.04186069887192932']
# ['At iteration 28 the best fitness is 0.04186069887192932']
# ['At iteration 29 the best fitness is 0.04186069887192932']
#       Selected: 1359/4463 (30.5%), Fitness: 0.0419, Time: 1733.0s
#       Modality: D=30%, S=31%, Sk=30%, V=32%
#     Test Acc: 96.26%, F1: 96.19%, Features: 1359/4463 (30.5%), Model: 3.195MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07856791354040804']
# ['At iteration 1 the best fitness is 0.0782206135180016']
# ['At iteration 2 the best fitness is 0.06987986371850795']
# ['At iteration 3 the best fitness is 0.06987986371850795']
# ['At iteration 4 the best fitness is 0.06987986371850795']
# ['At iteration 5 the best fitness is 0.06987986371850795']
# ['At iteration 6 the best fitness is 0.06987986371850795']
# ['At iteration 7 the best fitness is 0.06987986371850795']
# ['At iteration 8 the best fitness is 0.06987986371850795']
# ['At iteration 9 the best fitness is 0.06987986371850795']
# ['At iteration 10 the best fitness is 0.06987986371850795']
# ['At iteration 11 the best fitness is 0.061281439708841756']
# ['At iteration 12 the best fitness is 0.061281439708841756']
# ['At iteration 13 the best fitness is 0.061281439708841756']
# ['At iteration 14 the best fitness is 0.061281439708841756']
# ['At iteration 15 the best fitness is 0.061281439708841756']
# ['At iteration 16 the best fitness is 0.06027314932121012']
# ['At iteration 17 the best fitness is 0.06027314932121012']
# ['At iteration 18 the best fitness is 0.06027314932121012']
# ['At iteration 19 the best fitness is 0.06027314932121012']
# ['At iteration 20 the best fitness is 0.06027314932121012']
# ['At iteration 21 the best fitness is 0.06027314932121012']
# ['At iteration 22 the best fitness is 0.06027314932121012']
# ['At iteration 23 the best fitness is 0.06027314932121012']
# ['At iteration 24 the best fitness is 0.06027314932121012']
# ['At iteration 25 the best fitness is 0.06027314932121012']
# ['At iteration 26 the best fitness is 0.06027314932121012']
# ['At iteration 27 the best fitness is 0.06027314932121012']
# ['At iteration 28 the best fitness is 0.06027314932121012']
# ['At iteration 29 the best fitness is 0.06027314932121012']
#       Selected: 2210/4463 (49.5%), Fitness: 0.0603, Time: 1429.3s
#       Modality: D=46%, S=48%, Sk=51%, V=50%
#     Test Acc: 95.33%, F1: 94.53%, Features: 2210/4463 (49.5%), Model: 4.858MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09595521641073751']
# ['At iteration 2 the best fitness is 0.0870431020582526']
# ['At iteration 3 the best fitness is 0.0870431020582526']
# ['At iteration 4 the best fitness is 0.06991347339809567']
# ['At iteration 5 the best fitness is 0.06991347339809567']
# ['At iteration 6 the best fitness is 0.06982384758586174']
# ['At iteration 7 the best fitness is 0.06982384758586174']
# ['At iteration 8 the best fitness is 0.06982384758586174']
# ['At iteration 9 the best fitness is 0.05198841565436266']
# ['At iteration 10 the best fitness is 0.05198841565436266']
# ['At iteration 11 the best fitness is 0.05198841565436266']
# ['At iteration 12 the best fitness is 0.05198841565436266']
# ['At iteration 13 the best fitness is 0.05198841565436266']
# ['At iteration 14 the best fitness is 0.05198841565436266']
# ['At iteration 15 the best fitness is 0.05198841565436266']
# ['At iteration 16 the best fitness is 0.05198841565436266']
# ['At iteration 17 the best fitness is 0.05198841565436266']
# ['At iteration 18 the best fitness is 0.05198841565436266']
# ['At iteration 19 the best fitness is 0.05198841565436266']
# ['At iteration 20 the best fitness is 0.05198841565436266']
# ['At iteration 21 the best fitness is 0.05198841565436266']
# ['At iteration 22 the best fitness is 0.05198841565436266']
# ['At iteration 23 the best fitness is 0.05198841565436266']
# ['At iteration 24 the best fitness is 0.05198841565436266']
# ['At iteration 25 the best fitness is 0.05198841565436266']
# ['At iteration 26 the best fitness is 0.05198841565436266']
# ['At iteration 27 the best fitness is 0.05198841565436266']
# ['At iteration 28 the best fitness is 0.05198841565436266']
# ['At iteration 29 the best fitness is 0.05198841565436266']
#       Selected: 2263/4463 (50.7%), Fitness: 0.0520, Time: 1336.3s
#       Modality: D=52%, S=49%, Sk=52%, V=50%
#     Test Acc: 89.72%, F1: 89.00%, Features: 2263/4463 (50.7%), Model: 4.961MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06903962172881492']
# ['At iteration 2 the best fitness is 0.06903962172881492']
# ['At iteration 3 the best fitness is 0.06903962172881492']
# ['At iteration 4 the best fitness is 0.06903962172881492']
# ['At iteration 5 the best fitness is 0.0690060120492272']
# ['At iteration 6 the best fitness is 0.05117058011772811']
# ['At iteration 7 the best fitness is 0.05117058011772811']
# ['At iteration 8 the best fitness is 0.05114817366466963']
# ['At iteration 9 the best fitness is 0.05114817366466963']
# ['At iteration 10 the best fitness is 0.05114817366466963']
# ['At iteration 11 the best fitness is 0.05114817366466963']
# ['At iteration 12 the best fitness is 0.05114817366466963']
# ['At iteration 13 the best fitness is 0.05114817366466963']
# ['At iteration 14 the best fitness is 0.05114817366466963']
# ['At iteration 15 the best fitness is 0.05114817366466963']
# ['At iteration 16 the best fitness is 0.05114817366466963']
# ['At iteration 17 the best fitness is 0.05101373494631875']
# ['At iteration 18 the best fitness is 0.05101373494631875']
# ['At iteration 19 the best fitness is 0.050812076868792425']
# ['At iteration 20 the best fitness is 0.050812076868792425']
# ['At iteration 21 the best fitness is 0.050812076868792425']
# ['At iteration 22 the best fitness is 0.050812076868792425']
# ['At iteration 23 the best fitness is 0.0507784671892047']
# ['At iteration 24 the best fitness is 0.0507784671892047']
# ['At iteration 25 the best fitness is 0.0507784671892047']
# ['At iteration 26 the best fitness is 0.041866352836719786']
# ['At iteration 27 the best fitness is 0.041866352836719786']
# ['At iteration 28 the best fitness is 0.032965441710764105']
# ['At iteration 29 the best fitness is 0.032965441710764105']
# ['At iteration 30 the best fitness is 0.032965441710764105']
#       Selected: 2150/4463 (48.2%), Fitness: 0.0330, Time: 1370.6s
#       Modality: D=46%, S=50%, Sk=47%, V=49%
#     Test Acc: 98.13%, F1: 97.94%, Features: 2150/4463 (48.2%), Model: 4.740MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0690620281818734']
# ['At iteration 2 the best fitness is 0.0690620281818734']
# ['At iteration 3 the best fitness is 0.0690620281818734']
# ['At iteration 4 the best fitness is 0.0690620281818734']
# ['At iteration 5 the best fitness is 0.0690620281818734']
# ['At iteration 6 the best fitness is 0.0690620281818734']
# ['At iteration 7 the best fitness is 0.0690620281818734']
# ['At iteration 8 the best fitness is 0.0690620281818734']
# ['At iteration 9 the best fitness is 0.0690620281818734']
# ['At iteration 10 the best fitness is 0.0690620281818734']
# ['At iteration 11 the best fitness is 0.06893879269005175']
# ['At iteration 12 the best fitness is 0.05131622206260824']
# ['At iteration 13 the best fitness is 0.05131622206260824']
# ['At iteration 14 the best fitness is 0.05131622206260824']
# ['At iteration 15 the best fitness is 0.05131622206260824']
# ['At iteration 16 the best fitness is 0.05131622206260824']
# ['At iteration 17 the best fitness is 0.05131622206260824']
# ['At iteration 18 the best fitness is 0.05131622206260824']
# ['At iteration 19 the best fitness is 0.05131622206260824']
# ['At iteration 20 the best fitness is 0.05131622206260824']
# ['At iteration 21 the best fitness is 0.05131622206260824']
# ['At iteration 22 the best fitness is 0.05131622206260824']
# ['At iteration 23 the best fitness is 0.05131622206260824']
# ['At iteration 24 the best fitness is 0.05131622206260824']
# ['At iteration 25 the best fitness is 0.05131622206260824']
# ['At iteration 26 the best fitness is 0.05131622206260824']
# ['At iteration 27 the best fitness is 0.05131622206260824']
# ['At iteration 28 the best fitness is 0.05131622206260824']
# ['At iteration 29 the best fitness is 0.05131622206260824']
# ['At iteration 30 the best fitness is 0.05131622206260824']
#       Selected: 2203/4463 (49.4%), Fitness: 0.0513, Time: 1358.7s
#       Modality: D=52%, S=51%, Sk=47%, V=50%
#     Test Acc: 91.59%, F1: 90.88%, Features: 2203/4463 (49.4%), Model: 4.844MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07910566841381159']
# ['At iteration 1 the best fitness is 0.06743756033513354']
# ['At iteration 2 the best fitness is 0.0649056311395252']
# ['At iteration 3 the best fitness is 0.0649056311395252']
# ['At iteration 4 the best fitness is 0.0649056311395252']
# ['At iteration 5 the best fitness is 0.0649056311395252']
# ['At iteration 6 the best fitness is 0.0649056311395252']
# ['At iteration 7 the best fitness is 0.0649056311395252']
# ['At iteration 8 the best fitness is 0.05987538242789625']
# ['At iteration 9 the best fitness is 0.05987538242789625']
# ['At iteration 10 the best fitness is 0.05987538242789625']
# ['At iteration 11 the best fitness is 0.038701388990683525']
# ['At iteration 12 the best fitness is 0.038701388990683525']
# ['At iteration 13 the best fitness is 0.038701388990683525']
# ['At iteration 14 the best fitness is 0.038701388990683525']
# ['At iteration 15 the best fitness is 0.038701388990683525']
# ['At iteration 16 the best fitness is 0.038701388990683525']
# ['At iteration 17 the best fitness is 0.038701388990683525']
# ['At iteration 18 the best fitness is 0.038701388990683525']
# ['At iteration 19 the best fitness is 0.038701388990683525']
# ['At iteration 20 the best fitness is 0.038701388990683525']
# ['At iteration 21 the best fitness is 0.038701388990683525']
# ['At iteration 22 the best fitness is 0.038701388990683525']
# ['At iteration 23 the best fitness is 0.038701388990683525']
# ['At iteration 24 the best fitness is 0.03622547592772139']
# ['At iteration 25 the best fitness is 0.03578855009308102']
# ['At iteration 26 the best fitness is 0.03578855009308102']
# ['At iteration 27 the best fitness is 0.03578855009308102']
# ['At iteration 28 the best fitness is 0.03578855009308102']
# ['At iteration 29 the best fitness is 0.03578855009308102']
#       Selected: 817/4463 (18.3%), Fitness: 0.0358, Time: 1230.3s
#       Modality: D=20%, S=17%, Sk=17%, V=20%
#     Test Acc: 93.46%, F1: 91.34%, Features: 817/4463 (18.3%), Model: 2.137MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.061214220349666316']
# ['At iteration 2 the best fitness is 0.061214220349666316']
# ['At iteration 3 the best fitness is 0.061124594537432395']
# ['At iteration 4 the best fitness is 0.061124594537432395']
# ['At iteration 5 the best fitness is 0.061124594537432395']
# ['At iteration 6 the best fitness is 0.061124594537432395']
# ['At iteration 7 the best fitness is 0.05177555435030709']
# ['At iteration 8 the best fitness is 0.05177555435030709']
# ['At iteration 9 the best fitness is 0.05177555435030709']
# ['At iteration 10 the best fitness is 0.05177555435030709']
# ['At iteration 11 the best fitness is 0.05177555435030709']
# ['At iteration 12 the best fitness is 0.04269539159988357']
# ['At iteration 13 the best fitness is 0.04269539159988357']
# ['At iteration 14 the best fitness is 0.04269539159988357']
# ['At iteration 15 the best fitness is 0.04269539159988357']
# ['At iteration 16 the best fitness is 0.04269539159988357']
# ['At iteration 17 the best fitness is 0.04269539159988357']
# ['At iteration 18 the best fitness is 0.04269539159988357']
# ['At iteration 19 the best fitness is 0.04269539159988357']
# ['At iteration 20 the best fitness is 0.04269539159988357']
# ['At iteration 21 the best fitness is 0.04269539159988357']
# ['At iteration 22 the best fitness is 0.04269539159988357']
# ['At iteration 23 the best fitness is 0.04269539159988357']
# ['At iteration 24 the best fitness is 0.04269539159988357']
# ['At iteration 25 the best fitness is 0.04269539159988357']
# ['At iteration 26 the best fitness is 0.04269539159988357']
# ['At iteration 27 the best fitness is 0.04269539159988357']
# ['At iteration 28 the best fitness is 0.04269539159988357']
# ['At iteration 29 the best fitness is 0.033816886926986374']
#       Selected: 2226/4463 (49.9%), Fitness: 0.0338, Time: 3348.1s
#       Modality: D=50%, S=48%, Sk=50%, V=51%
#     Test Acc: 93.46%, F1: 92.03%, Features: 2226/4463 (49.9%), Model: 4.889MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0962016873943808']
# ['At iteration 1 the best fitness is 0.09434184708747523']
# ['At iteration 2 the best fitness is 0.08722790294445923']
# ['At iteration 3 the best fitness is 0.06708460634793662']
# ['At iteration 4 the best fitness is 0.06701738698876117']
# ['At iteration 5 the best fitness is 0.06701738698876117']
# ['At iteration 6 the best fitness is 0.06701738698876117']
# ['At iteration 7 the best fitness is 0.06701738698876117']
# ['At iteration 8 the best fitness is 0.06701738698876117']
# ['At iteration 9 the best fitness is 0.06701738698876117']
# ['At iteration 10 the best fitness is 0.06701738698876117']
# ['At iteration 11 the best fitness is 0.06701738698876117']
# ['At iteration 12 the best fitness is 0.06701738698876117']
# ['At iteration 13 the best fitness is 0.06701738698876117']
# ['At iteration 14 the best fitness is 0.06701738698876117']
# ['At iteration 15 the best fitness is 0.06701738698876117']
# ['At iteration 16 the best fitness is 0.057679550028165126']
# ['At iteration 17 the best fitness is 0.057679550028165126']
# ['At iteration 18 the best fitness is 0.057679550028165126']
# ['At iteration 19 the best fitness is 0.057679550028165126']
# ['At iteration 20 the best fitness is 0.057679550028165126']
# ['At iteration 21 the best fitness is 0.057679550028165126']
# ['At iteration 22 the best fitness is 0.057679550028165126']
# ['At iteration 23 the best fitness is 0.057679550028165126']
# ['At iteration 24 the best fitness is 0.057679550028165126']
# ['At iteration 25 the best fitness is 0.057679550028165126']
# ['At iteration 26 the best fitness is 0.057679550028165126']
# ['At iteration 27 the best fitness is 0.057679550028165126']
# ['At iteration 28 the best fitness is 0.057679550028165126']
# ['At iteration 29 the best fitness is 0.057679550028165126']
#       Selected: 1186/4463 (26.6%), Fitness: 0.0577, Time: 1291.3s
#       Modality: D=27%, S=25%, Sk=27%, V=27%
#     Test Acc: 91.59%, F1: 90.73%, Features: 1186/4463 (26.6%), Model: 2.858MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          92.592593         91.588785     92.530864
# 1  baseline     2          90.740741         94.392523     90.118647
# 2  baseline     3          81.481481         95.327103     78.493194
# 3  baseline     4          89.814815         95.327103     88.609641
# 4  baseline     5          87.037037         96.261682     84.103797
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        92.530864            94.135802         92.592593               4463
# 1        90.118647            93.104056         90.740741               4463
# 2        78.493194            80.041152         81.481481               4463
# 3        88.609641            90.185185         89.814815               4463
# 4        84.103797            85.138154         87.037037               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              89.90              4.73              88.66              5.82                 4463.00                      100.00              0.00                26.49                26.49          2425371.0                  9.26                        0.00               72.33
# mutual_info              91.05              3.54              89.97              3.88                 2231.00                       49.99             57.27                19.45                76.71          1282587.0                  4.90                       50.01               45.90
#         rfe              91.18              3.96              90.30              4.66                 2231.00                       49.99             10.63                21.53                32.16          1282587.0                  4.90                       50.01               45.90
#       lasso              66.81              6.61              63.50              7.82                 2231.00                       49.99             10.37                21.04                31.41          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              90.60              4.45              89.88              4.72                 2215.62                       49.64           1386.83                22.50              1409.33          1274715.0                  4.87                       50.36               45.81
#     meta_CS              88.39              4.17              87.23              4.88                 2213.75                       49.60           2780.13                22.53              2802.65          1273755.0                  4.86                       50.40               45.79
#     meta_DE              88.62              2.89              87.12              3.72                 2188.75                       49.04           1411.19                22.51              1433.69          1260955.0                  4.82                       50.96               45.58
#    meta_FFA              90.94              3.76              90.35              4.19                 2212.25                       49.57           1364.45                22.48              1386.93          1272987.0                  4.86                       50.43               45.77
#     meta_GA              87.70              4.57              86.50              5.11                 2208.00                       49.47           1365.65                22.48              1388.13          1270811.0                  4.85                       50.53               45.73
#    meta_GWO              85.61              4.02              84.45              4.79                 1866.62                       41.82           1307.25                20.96              1328.21          1096027.0                  4.19                       58.18               41.88
#    meta_HHO              87.35              5.57              86.52              6.11                 1688.75                       37.84           1747.68                21.25              1768.93          1004955.0                  3.84                       62.16               39.95
#   meta_JAYA              87.23              4.20              85.77              4.77                 2194.50                       49.17           1411.48                22.49              1433.96          1263899.0                  4.83                       50.83               45.61
#    meta_MFO              89.32              2.48              88.16              3.01                 2246.62                       50.34           1333.52                22.65              1356.17          1290587.0                  4.93                       49.66               46.10
#    meta_MVO              87.81              5.31              86.71              6.07                 2203.88                       49.38           1369.85                22.47              1392.32          1268699.0                  4.85                       50.62               45.71
#    meta_PSO              89.55              3.23              88.73              3.51                 2200.12                       49.30           1361.51                22.43              1383.94          1266779.0                  4.84                       50.70               45.66
#    meta_SCA              84.23              9.59              82.54              9.84                  934.62                       20.94           1191.23                18.01              1209.24           618843.0                  2.37                       79.06               30.76
#    meta_SSA              88.62              3.69              87.84              3.78                 2220.62                       49.76           3389.80                22.53              3412.33          1277275.0                  4.88                       50.24               45.83
#    meta_WOA              87.58              3.14              86.23              3.75                 1934.00                       43.33           1307.52                21.95              1329.47          1130523.0                  4.32                       56.67               43.05

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_SSA
#     F1 Macro:           93.08%
#     F1 Weighted:        93.08%
#     Test Accuracy:      93.52%
#     Feature Retention:  49.29% (2200/4463)
#     Modality Retention: depth=51.2%, sensor=47.5%, skeleton=49.4%, video=49.3%
#
#   Fold 2: Best = meta_PSO
#     F1 Macro:           93.41%
#     F1 Weighted:        93.41%
#     Test Accuracy:      93.52%
#     Feature Retention:  49.99% (2231/4463)
#     Modality Retention: depth=51.6%, sensor=54.6%, skeleton=48.5%, video=49.3%
#
#   Fold 3: Best = meta_BAT
#     F1 Macro:           85.14%
#     F1 Weighted:        85.14%
#     Test Accuracy:      85.19%
#     Feature Retention:  50.10% (2236/4463)
#     Modality Retention: depth=47.1%, sensor=49.8%, skeleton=50.8%, video=50.4%
#
#   Fold 4: Best = meta_FFA
#     F1 Macro:           88.98%
#     F1 Weighted:        88.98%
#     Test Accuracy:      89.81%
#     Feature Retention:  49.38% (2204/4463)
#     Modality Retention: depth=49.4%, sensor=49.4%, skeleton=49.8%, video=48.9%
#
#   Fold 5: Best = meta_FFA
#     F1 Macro:           94.28%
#     F1 Weighted:        94.28%
#     Test Accuracy:      94.44%
#     Feature Retention:  50.46% (2252/4463)
#     Modality Retention: depth=48.6%, sensor=51.8%, skeleton=49.8%, video=51.3%
#
#   Fold 6: Best = meta_SSA
#     F1 Macro:           91.50%
#     F1 Weighted:        91.42%
#     Test Accuracy:      91.59%
#     Feature Retention:  49.70% (2218/4463)
#     Modality Retention: depth=53.1%, sensor=51.2%, skeleton=48.7%, video=49.0%
#
#   Fold 7: Best = meta_PSO
#     F1 Macro:           92.37%
#     F1 Weighted:        92.30%
#     Test Accuracy:      92.52%
#     Feature Retention:  49.16% (2194/4463)
#     Modality Retention: depth=51.2%, sensor=48.2%, skeleton=49.6%, video=48.3%
#
#   Fold 8: Best = meta_BAT
#     F1 Macro:           99.06%
#     F1 Weighted:        99.05%
#     Test Accuracy:      99.07%
#     Feature Retention:  49.25% (2198/4463)
#     Modality Retention: depth=50.2%, sensor=49.8%, skeleton=48.5%, video=49.6%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 92.23% ± 4.04%
#
#   Average F1 Weighted         : 92.21% ± 4.04%
#
#   Average Test Accuracy       : 92.46% ± 3.97%
#
#   Average Feature Retention   : 49.67% ± 0.47%
#
#   Average Modality-wise Feature Retention:
#            depth: 50.29% ± 1.89%
#           sensor: 50.31% ± 2.24%
#         skeleton: 49.39% ± 0.79%
#            video: 49.51% ± 0.94%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1           meta_SSA         93.08            93.08              93.52                  49.29              51.17               47.55                 49.39              49.30
#     2           meta_PSO         93.41            93.41              93.52                  49.99              51.56               54.60                 48.48              49.30
#     3           meta_BAT         85.14            85.14              85.19                  50.10              47.07               49.85                 50.82              50.35
#     4           meta_FFA         88.98            88.98              89.81                  49.38              49.41               49.39                 49.76              48.87
#     5           meta_FFA         94.28            94.28              94.44                  50.46              48.63               51.84                 49.81              51.34
#     6           meta_SSA         91.50            91.42              91.59                  49.70              53.12               51.23                 48.75              49.01
#     7           meta_PSO         92.37            92.30              92.52                  49.16              51.17               48.16                 49.60              48.31
#     8           meta_BAT         99.06            99.05              99.07                  49.25              50.20               49.85                 48.54              49.58
#
# Saved to: results_noise_1.0_20/best_metaheuristic_per_fold.csv
