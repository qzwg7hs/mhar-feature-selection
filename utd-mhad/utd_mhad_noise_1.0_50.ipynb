# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_noise_1.0_50")

# Master output directory
RESULTS_ROOT = Path("results_noise_1.0_50")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

# FEATURE_DIMS will be set dynamically per-fold after PCA
# (depth dim changes if PCA is applied)
print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 83.33%, F1: 83.62%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 59.6s
#     Test Acc: 90.74%, F1: 90.35%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.5s
#     Test Acc: 90.74%, F1: 90.65%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 3.6s
#     Test Acc: 55.56%, F1: 52.81%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11396989996670444']
# ['At iteration 1 the best fitness is 0.11396989996670444']
# ['At iteration 2 the best fitness is 0.11396989996670444']
# ['At iteration 3 the best fitness is 0.11396989996670444']
# ['At iteration 4 the best fitness is 0.11396989996670444']
# ['At iteration 5 the best fitness is 0.11396989996670444']
# ['At iteration 6 the best fitness is 0.11396989996670444']
# ['At iteration 7 the best fitness is 0.11396989996670444']
# ['At iteration 8 the best fitness is 0.10506898884074875']
# ['At iteration 9 the best fitness is 0.10506898884074875']
# ['At iteration 10 the best fitness is 0.10506898884074875']
# ['At iteration 11 the best fitness is 0.10506898884074875']
# ['At iteration 12 the best fitness is 0.10506898884074875']
# ['At iteration 13 the best fitness is 0.10506898884074875']
# ['At iteration 14 the best fitness is 0.10506898884074875']
# ['At iteration 15 the best fitness is 0.10506898884074875']
# ['At iteration 16 the best fitness is 0.10506898884074875']
# ['At iteration 17 the best fitness is 0.10506898884074875']
# ['At iteration 18 the best fitness is 0.10506898884074875']
# ['At iteration 19 the best fitness is 0.10506898884074875']
# ['At iteration 20 the best fitness is 0.10506898884074875']
# ['At iteration 21 the best fitness is 0.10506898884074875']
# ['At iteration 22 the best fitness is 0.10506898884074875']
# ['At iteration 23 the best fitness is 0.10506898884074875']
# ['At iteration 24 the best fitness is 0.10506898884074875']
# ['At iteration 25 the best fitness is 0.10506898884074875']
# ['At iteration 26 the best fitness is 0.10506898884074875']
# ['At iteration 27 the best fitness is 0.10506898884074875']
# ['At iteration 28 the best fitness is 0.10506898884074875']
# ['At iteration 29 the best fitness is 0.10506898884074875']
#       Selected: 2246/4463 (50.3%), Fitness: 0.1051, Time: 1388.2s
#       Modality: D=51%, S=51%, Sk=51%, V=50%
#     Test Acc: 88.89%, F1: 87.53%, Features: 2246/4463 (50.3%), Model: 4.928MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13128998347785845']
# ['At iteration 1 the best fitness is 0.13128998347785845']
# ['At iteration 2 the best fitness is 0.13128998347785845']
# ['At iteration 3 the best fitness is 0.09619048416785156']
# ['At iteration 4 the best fitness is 0.09619048416785156']
# ['At iteration 5 the best fitness is 0.09619048416785156']
# ['At iteration 6 the best fitness is 0.09619048416785156']
# ['At iteration 7 the best fitness is 0.09619048416785156']
# ['At iteration 8 the best fitness is 0.09619048416785156']
# ['At iteration 9 the best fitness is 0.09619048416785156']
# ['At iteration 10 the best fitness is 0.09619048416785156']
# ['At iteration 11 the best fitness is 0.09619048416785156']
# ['At iteration 12 the best fitness is 0.09619048416785156']
# ['At iteration 13 the best fitness is 0.09619048416785156']
# ['At iteration 14 the best fitness is 0.09619048416785156']
# ['At iteration 15 the best fitness is 0.09619048416785156']
# ['At iteration 16 the best fitness is 0.09619048416785156']
# ['At iteration 17 the best fitness is 0.09619048416785156']
# ['At iteration 18 the best fitness is 0.09619048416785156']
# ['At iteration 19 the best fitness is 0.09619048416785156']
# ['At iteration 20 the best fitness is 0.09619048416785156']
# ['At iteration 21 the best fitness is 0.09619048416785156']
# ['At iteration 22 the best fitness is 0.09619048416785156']
# ['At iteration 23 the best fitness is 0.09619048416785156']
# ['At iteration 24 the best fitness is 0.09619048416785156']
# ['At iteration 25 the best fitness is 0.09619048416785156']
# ['At iteration 26 the best fitness is 0.09619048416785156']
# ['At iteration 27 the best fitness is 0.09619048416785156']
# ['At iteration 28 the best fitness is 0.09619048416785156']
# ['At iteration 29 the best fitness is 0.09619048416785156']
#       Selected: 2246/4463 (50.3%), Fitness: 0.0962, Time: 2773.6s
#       Modality: D=49%, S=51%, Sk=51%, V=50%
#     Test Acc: 88.89%, F1: 87.70%, Features: 2246/4463 (50.3%), Model: 4.928MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.14041495913439894']
# ['At iteration 2 the best fitness is 0.14041495913439894']
# ['At iteration 3 the best fitness is 0.13090907377586428']
# ['At iteration 4 the best fitness is 0.13090907377586428']
# ['At iteration 5 the best fitness is 0.12244508848454898']
# ['At iteration 6 the best fitness is 0.11432840321564014']
# ['At iteration 7 the best fitness is 0.11432840321564014']
# ['At iteration 8 the best fitness is 0.11432840321564014']
# ['At iteration 9 the best fitness is 0.11432840321564014']
# ['At iteration 10 the best fitness is 0.11432840321564014']
# ['At iteration 11 the best fitness is 0.11432840321564014']
# ['At iteration 12 the best fitness is 0.11432840321564014']
# ['At iteration 13 the best fitness is 0.11432840321564014']
# ['At iteration 14 the best fitness is 0.11432840321564014']
# ['At iteration 15 the best fitness is 0.11432840321564014']
# ['At iteration 16 the best fitness is 0.11432840321564014']
# ['At iteration 17 the best fitness is 0.11432840321564014']
# ['At iteration 18 the best fitness is 0.11319687733618686']
# ['At iteration 19 the best fitness is 0.11319687733618686']
# ['At iteration 20 the best fitness is 0.11319687733618686']
# ['At iteration 21 the best fitness is 0.11319687733618686']
# ['At iteration 22 the best fitness is 0.11319687733618686']
# ['At iteration 23 the best fitness is 0.11319687733618686']
# ['At iteration 24 the best fitness is 0.10462085977957913']
# ['At iteration 25 the best fitness is 0.10462085977957913']
# ['At iteration 26 the best fitness is 0.10462085977957913']
# ['At iteration 27 the best fitness is 0.10462085977957913']
# ['At iteration 28 the best fitness is 0.09607845190255916']
# ['At iteration 29 the best fitness is 0.09607845190255916']
# ['At iteration 30 the best fitness is 0.09607845190255916']
#       Selected: 2236/4463 (50.1%), Fitness: 0.0961, Time: 1407.6s
#       Modality: D=52%, S=50%, Sk=50%, V=50%
#     Test Acc: 87.96%, F1: 87.62%, Features: 2236/4463 (50.1%), Model: 4.908MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.14003404943240477']
# ['At iteration 1 the best fitness is 0.14003404943240477']
# ['At iteration 2 the best fitness is 0.12252351107025367']
# ['At iteration 3 the best fitness is 0.12201936587643784']
# ['At iteration 4 the best fitness is 0.11357778703818103']
# ['At iteration 5 the best fitness is 0.1308866673228058']
# ['At iteration 6 the best fitness is 0.11342094186677167']
# ['At iteration 7 the best fitness is 0.11352177090553482']
# ['At iteration 8 the best fitness is 0.13103230926768591']
# ['At iteration 9 the best fitness is 0.12218741427437645']
# ['At iteration 10 the best fitness is 0.10450882751428674']
# ['At iteration 11 the best fitness is 0.13115554475950755']
# ['At iteration 12 the best fitness is 0.1221762110478472']
# ['At iteration 13 the best fitness is 0.13106591894727365']
# ['At iteration 14 the best fitness is 0.13106591894727365']
# ['At iteration 15 the best fitness is 0.12214260136825948']
# ['At iteration 16 the best fitness is 0.13992201716711236']
# ['At iteration 17 the best fitness is 0.12220982072743493']
# ['At iteration 18 the best fitness is 0.12218741427437645']
# ['At iteration 19 the best fitness is 0.12216500782131796']
# ['At iteration 20 the best fitness is 0.1399332203936416']
# ['At iteration 21 the best fitness is 0.12215380459478872']
# ['At iteration 22 the best fitness is 0.13991081394058313']
# ['At iteration 23 the best fitness is 0.13104351249421514']
# ['At iteration 24 the best fitness is 0.13992201716711236']
# ['At iteration 25 the best fitness is 0.1310547157207444']
# ['At iteration 26 the best fitness is 0.1399332203936416']
# ['At iteration 27 the best fitness is 0.13991081394058313']
# ['At iteration 28 the best fitness is 0.14878931861348033']
# ['At iteration 29 the best fitness is 0.13103230926768591']
#       Selected: 2186/4463 (49.0%), Fitness: 0.1310, Time: 1357.7s
#       Modality: D=45%, S=50%, Sk=50%, V=49%
#     Test Acc: 85.19%, F1: 84.09%, Features: 2186/4463 (49.0%), Model: 4.811MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.14868848957471714
# At iteration 2 the best fitness is 0.13148043832885553
# At iteration 3 the best fitness is 0.12229944653966886
# At iteration 4 the best fitness is 0.13974276554264453
# At iteration 5 the best fitness is 0.13094268345545199
# At iteration 6 the best fitness is 0.14066143011804222
# At iteration 7 the best fitness is 0.11366741285041496
# At iteration 8 the best fitness is 0.1221762110478472
# At iteration 9 the best fitness is 0.12266915301513379
# At iteration 10 the best fitness is 0.11340973864024242
# At iteration 11 the best fitness is 0.11335372250759622
# At iteration 12 the best fitness is 0.10412791781229255
# At iteration 13 the best fitness is 0.11310725152395293
# At iteration 14 the best fitness is 0.11385786770141204
# At iteration 15 the best fitness is 0.0953950550842755
# At iteration 16 the best fitness is 0.11363380317082723
# At iteration 17 the best fitness is 0.11352177090553482
# At iteration 18 the best fitness is 0.10464326623263762
# At iteration 19 the best fitness is 0.13087546409627654
# At iteration 20 the best fitness is 0.10429596621023117
# At iteration 21 the best fitness is 0.11393629028711671
# At iteration 22 the best fitness is 0.12214260136825948
# At iteration 23 the best fitness is 0.11310725152395293
# At iteration 24 the best fitness is 0.11353297413206406
# At iteration 25 the best fitness is 0.11347695799941786
# At iteration 26 the best fitness is 0.1128495773137804
# At iteration 27 the best fitness is 0.11283837408725116
# At iteration 28 the best fitness is 0.12198575619685012
# At iteration 29 the best fitness is 0.11364500639735647
# At iteration 30 the best fitness is 0.12207538200908405
#       Selected: 2179/4463 (48.8%), Fitness: 0.1221, Time: 1360.5s
#       Modality: D=49%, S=48%, Sk=50%, V=48%
#     Test Acc: 88.89%, F1: 88.27%, Features: 2179/4463 (48.8%), Model: 4.797MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.15002167353169676']
# ['At iteration 1 the best fitness is 0.12219861750090569']
# ['At iteration 2 the best fitness is 0.12219861750090569']
# ['At iteration 3 the best fitness is 0.11128112559968674']
# ['At iteration 4 the best fitness is 0.11128112559968674']
# ['At iteration 5 the best fitness is 0.11005997390799954']
# ['At iteration 6 the best fitness is 0.11005997390799954']
# ['At iteration 7 the best fitness is 0.10127109504733625']
# ['At iteration 8 the best fitness is 0.10127109504733625']
# ['At iteration 9 the best fitness is 0.10127109504733625']
# ['At iteration 10 the best fitness is 0.09077932575422844']
# ['At iteration 11 the best fitness is 0.09077932575422844']
# ['At iteration 12 the best fitness is 0.09077932575422844']
# ['At iteration 13 the best fitness is 0.09077932575422844']
# ['At iteration 14 the best fitness is 0.09077932575422844']
# ['At iteration 15 the best fitness is 0.09077932575422844']
# ['At iteration 16 the best fitness is 0.09077932575422844']
# ['At iteration 17 the best fitness is 0.09077932575422844']
# ['At iteration 18 the best fitness is 0.09006231925635705']
# ['At iteration 19 the best fitness is 0.09006231925635705']
# ['At iteration 20 the best fitness is 0.09006231925635705']
# ['At iteration 21 the best fitness is 0.09006231925635705']
# ['At iteration 22 the best fitness is 0.09006231925635705']
# ['At iteration 23 the best fitness is 0.09006231925635705']
# ['At iteration 24 the best fitness is 0.09006231925635705']
# ['At iteration 25 the best fitness is 0.09006231925635705']
# ['At iteration 26 the best fitness is 0.09006231925635705']
# ['At iteration 27 the best fitness is 0.09006231925635705']
# ['At iteration 28 the best fitness is 0.08131825330181074']
# ['At iteration 29 the best fitness is 0.08131825330181074']
#       Selected: 1711/4463 (38.3%), Fitness: 0.0813, Time: 1285.9s
#       Modality: D=37%, S=38%, Sk=39%, V=39%
#     Test Acc: 88.89%, F1: 88.54%, Features: 1711/4463 (38.3%), Model: 3.883MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.14047097526704513']
# ['At iteration 1 the best fitness is 0.11430599676258166']
# ['At iteration 2 the best fitness is 0.11430599676258166']
# ['At iteration 3 the best fitness is 0.11430599676258166']
# ['At iteration 4 the best fitness is 0.11430599676258166']
# ['At iteration 5 the best fitness is 0.11430599676258166']
# ['At iteration 6 the best fitness is 0.11430599676258166']
# ['At iteration 7 the best fitness is 0.11430599676258166']
# ['At iteration 8 the best fitness is 0.11430599676258166']
# ['At iteration 9 the best fitness is 0.11430599676258166']
# ['At iteration 10 the best fitness is 0.11430599676258166']
# ['At iteration 11 the best fitness is 0.11430599676258166']
# ['At iteration 12 the best fitness is 0.10117581527031189']
# ['At iteration 13 the best fitness is 0.10117581527031189']
# ['At iteration 14 the best fitness is 0.10117581527031189']
# ['At iteration 15 the best fitness is 0.10117581527031189']
# ['At iteration 16 the best fitness is 0.10117581527031189']
# ['At iteration 17 the best fitness is 0.10117581527031189']
# ['At iteration 18 the best fitness is 0.10117581527031189']
# ['At iteration 19 the best fitness is 0.10117581527031189']
# ['At iteration 20 the best fitness is 0.10117581527031189']
# ['At iteration 21 the best fitness is 0.10117581527031189']
# ['At iteration 22 the best fitness is 0.10117581527031189']
# ['At iteration 23 the best fitness is 0.10117581527031189']
# ['At iteration 24 the best fitness is 0.10117581527031189']
# ['At iteration 25 the best fitness is 0.10117581527031189']
# ['At iteration 26 the best fitness is 0.10117581527031189']
# ['At iteration 27 the best fitness is 0.10117581527031189']
# ['At iteration 28 the best fitness is 0.10117581527031189']
# ['At iteration 29 the best fitness is 0.10117581527031189']
#       Selected: 1106/4463 (24.8%), Fitness: 0.1012, Time: 1728.4s
#       Modality: D=21%, S=24%, Sk=26%, V=25%
#     Test Acc: 86.11%, F1: 85.71%, Features: 1106/4463 (24.8%), Model: 2.701MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13154765768803098']
# ['At iteration 1 the best fitness is 0.13154765768803098']
# ['At iteration 2 the best fitness is 0.13154765768803098']
# ['At iteration 3 the best fitness is 0.13154765768803098']
# ['At iteration 4 the best fitness is 0.13154765768803098']
# ['At iteration 5 the best fitness is 0.13154765768803098']
# ['At iteration 6 the best fitness is 0.13154765768803098']
# ['At iteration 7 the best fitness is 0.13154765768803098']
# ['At iteration 8 the best fitness is 0.13154765768803098']
# ['At iteration 9 the best fitness is 0.13154765768803098']
# ['At iteration 10 the best fitness is 0.13154765768803098']
# ['At iteration 11 the best fitness is 0.13154765768803098']
# ['At iteration 12 the best fitness is 0.12265794978860455']
# ['At iteration 13 the best fitness is 0.11380185156876584']
# ['At iteration 14 the best fitness is 0.11380185156876584']
# ['At iteration 15 the best fitness is 0.11380185156876584']
# ['At iteration 16 the best fitness is 0.11380185156876584']
# ['At iteration 17 the best fitness is 0.11380185156876584']
# ['At iteration 18 the best fitness is 0.11380185156876584']
# ['At iteration 19 the best fitness is 0.11380185156876584']
# ['At iteration 20 the best fitness is 0.11380185156876584']
# ['At iteration 21 the best fitness is 0.11380185156876584']
# ['At iteration 22 the best fitness is 0.11380185156876584']
# ['At iteration 23 the best fitness is 0.11380185156876584']
# ['At iteration 24 the best fitness is 0.11380185156876584']
# ['At iteration 25 the best fitness is 0.11380185156876584']
# ['At iteration 26 the best fitness is 0.11380185156876584']
# ['At iteration 27 the best fitness is 0.11380185156876584']
# ['At iteration 28 the best fitness is 0.11380185156876584']
# ['At iteration 29 the best fitness is 0.11370102253000267']
#       Selected: 2224/4463 (49.8%), Fitness: 0.1137, Time: 1413.0s
#       Modality: D=53%, S=50%, Sk=51%, V=46%
#     Test Acc: 87.04%, F1: 86.98%, Features: 2224/4463 (49.8%), Model: 4.885MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.14114316885879957']
# ['At iteration 2 the best fitness is 0.1310547157207444']
# ['At iteration 3 the best fitness is 0.12368864662929466']
# ['At iteration 4 the best fitness is 0.12368864662929466']
# ['At iteration 5 the best fitness is 0.12368864662929466']
# ['At iteration 6 the best fitness is 0.12368864662929466']
# ['At iteration 7 the best fitness is 0.12368864662929466']
# ['At iteration 8 the best fitness is 0.12368864662929466']
# ['At iteration 9 the best fitness is 0.12368864662929466']
# ['At iteration 10 the best fitness is 0.12368864662929466']
# ['At iteration 11 the best fitness is 0.12368864662929466']
# ['At iteration 12 the best fitness is 0.10551711790191837']
# ['At iteration 13 the best fitness is 0.10551711790191837']
# ['At iteration 14 the best fitness is 0.10551711790191837']
# ['At iteration 15 the best fitness is 0.10551711790191837']
# ['At iteration 16 the best fitness is 0.10551711790191837']
# ['At iteration 17 the best fitness is 0.10551711790191837']
# ['At iteration 18 the best fitness is 0.10551711790191837']
# ['At iteration 19 the best fitness is 0.10551711790191837']
# ['At iteration 20 the best fitness is 0.10551711790191837']
# ['At iteration 21 the best fitness is 0.10551711790191837']
# ['At iteration 22 the best fitness is 0.10551711790191837']
# ['At iteration 23 the best fitness is 0.10551711790191837']
# ['At iteration 24 the best fitness is 0.10551711790191837']
# ['At iteration 25 the best fitness is 0.10551711790191837']
# ['At iteration 26 the best fitness is 0.10551711790191837']
# ['At iteration 27 the best fitness is 0.10551711790191837']
# ['At iteration 28 the best fitness is 0.10551711790191837']
# ['At iteration 29 the best fitness is 0.10551711790191837']
#       Selected: 2286/4463 (51.2%), Fitness: 0.1055, Time: 1332.8s
#       Modality: D=52%, S=52%, Sk=51%, V=51%
#     Test Acc: 87.04%, F1: 86.71%, Features: 2286/4463 (51.2%), Model: 5.006MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.14880052184000955']
# ['At iteration 2 the best fitness is 0.14044856881398665']
# ['At iteration 3 the best fitness is 0.12203056910296708']
# ['At iteration 4 the best fitness is 0.11336492573412546']
# ['At iteration 5 the best fitness is 0.11336492573412546']
# ['At iteration 6 the best fitness is 0.11336492573412546']
# ['At iteration 7 the best fitness is 0.11336492573412546']
# ['At iteration 8 the best fitness is 0.10482251785710546']
# ['At iteration 9 the best fitness is 0.10482251785710546']
# ['At iteration 10 the best fitness is 0.10482251785710546']
# ['At iteration 11 the best fitness is 0.10482251785710546']
# ['At iteration 12 the best fitness is 0.10482251785710546']
# ['At iteration 13 the best fitness is 0.10482251785710546']
# ['At iteration 14 the best fitness is 0.10482251785710546']
# ['At iteration 15 the best fitness is 0.10482251785710546']
# ['At iteration 16 the best fitness is 0.10482251785710546']
# ['At iteration 17 the best fitness is 0.10482251785710546']
# ['At iteration 18 the best fitness is 0.10482251785710546']
# ['At iteration 19 the best fitness is 0.10482251785710546']
# ['At iteration 20 the best fitness is 0.10482251785710546']
# ['At iteration 21 the best fitness is 0.10482251785710546']
# ['At iteration 22 the best fitness is 0.10482251785710546']
# ['At iteration 23 the best fitness is 0.10482251785710546']
# ['At iteration 24 the best fitness is 0.10482251785710546']
# ['At iteration 25 the best fitness is 0.10482251785710546']
# ['At iteration 26 the best fitness is 0.10478890817751774']
# ['At iteration 27 the best fitness is 0.10478890817751774']
# ['At iteration 28 the best fitness is 0.10478890817751774']
# ['At iteration 29 the best fitness is 0.10478890817751774']
# ['At iteration 30 the best fitness is 0.10478890817751774']
#       Selected: 2221/4463 (49.8%), Fitness: 0.1048, Time: 1370.9s
#       Modality: D=51%, S=52%, Sk=49%, V=49%
#     Test Acc: 84.26%, F1: 84.26%, Features: 2221/4463 (49.8%), Model: 4.879MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.14927105735423765']
# ['At iteration 2 the best fitness is 0.14006765911199248']
# ['At iteration 3 the best fitness is 0.13988840748752465']
# ['At iteration 4 the best fitness is 0.1398435945814077']
# ['At iteration 5 the best fitness is 0.11311845475048217']
# ['At iteration 6 the best fitness is 0.11311845475048217']
# ['At iteration 7 the best fitness is 0.11311845475048217']
# ['At iteration 8 the best fitness is 0.11311845475048217']
# ['At iteration 9 the best fitness is 0.11311845475048217']
# ['At iteration 10 the best fitness is 0.11311845475048217']
# ['At iteration 11 the best fitness is 0.11311845475048217']
# ['At iteration 12 the best fitness is 0.11311845475048217']
# ['At iteration 13 the best fitness is 0.1042511533041142']
# ['At iteration 14 the best fitness is 0.1042511533041142']
# ['At iteration 15 the best fitness is 0.1040270887735294']
# ['At iteration 16 the best fitness is 0.1040270887735294']
# ['At iteration 17 the best fitness is 0.1040270887735294']
# ['At iteration 18 the best fitness is 0.1040270887735294']
# ['At iteration 19 the best fitness is 0.1040270887735294']
# ['At iteration 20 the best fitness is 0.1040270887735294']
# ['At iteration 21 the best fitness is 0.1040270887735294']
# ['At iteration 22 the best fitness is 0.1040270887735294']
# ['At iteration 23 the best fitness is 0.1040270887735294']
# ['At iteration 24 the best fitness is 0.1040270887735294']
# ['At iteration 25 the best fitness is 0.1040270887735294']
# ['At iteration 26 the best fitness is 0.1040270887735294']
# ['At iteration 27 the best fitness is 0.1040270887735294']
# ['At iteration 28 the best fitness is 0.1040270887735294']
# ['At iteration 29 the best fitness is 0.1040270887735294']
# ['At iteration 30 the best fitness is 0.1040270887735294']
#       Selected: 2153/4463 (48.2%), Fitness: 0.1040, Time: 1361.4s
#       Modality: D=46%, S=50%, Sk=49%, V=48%
#     Test Acc: 84.26%, F1: 84.09%, Features: 2153/4463 (48.2%), Model: 4.746MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1318053318982035']
# ['At iteration 1 the best fitness is 0.1120765546832628']
# ['At iteration 2 the best fitness is 0.1120765546832628']
# ['At iteration 3 the best fitness is 0.10926454482442347']
# ['At iteration 4 the best fitness is 0.10483927034537349']
# ['At iteration 5 the best fitness is 0.10483927034537349']
# ['At iteration 6 the best fitness is 0.10483927034537349']
# ['At iteration 7 the best fitness is 0.10236335728241136']
# ['At iteration 8 the best fitness is 0.10236335728241136']
# ['At iteration 9 the best fitness is 0.10236335728241136']
# ['At iteration 10 the best fitness is 0.10236335728241136']
# ['At iteration 11 the best fitness is 0.10236335728241136']
# ['At iteration 12 the best fitness is 0.10236335728241136']
# ['At iteration 13 the best fitness is 0.10236335728241136']
# ['At iteration 14 the best fitness is 0.10236335728241136']
# ['At iteration 15 the best fitness is 0.10236335728241136']
# ['At iteration 16 the best fitness is 0.10236335728241136']
# ['At iteration 17 the best fitness is 0.10236335728241136']
# ['At iteration 18 the best fitness is 0.10236335728241136']
# ['At iteration 19 the best fitness is 0.10236335728241136']
# ['At iteration 20 the best fitness is 0.10236335728241136']
# ['At iteration 21 the best fitness is 0.10236335728241136']
# ['At iteration 22 the best fitness is 0.10236335728241136']
# ['At iteration 23 the best fitness is 0.10236335728241136']
# ['At iteration 24 the best fitness is 0.10236335728241136']
# ['At iteration 25 the best fitness is 0.10236335728241136']
# ['At iteration 26 the best fitness is 0.10236335728241136']
# ['At iteration 27 the best fitness is 0.10236335728241136']
# ['At iteration 28 the best fitness is 0.10236335728241136']
# ['At iteration 29 the best fitness is 0.10236335728241136']
#       Selected: 1212/4463 (27.2%), Fitness: 0.1024, Time: 1155.8s
#       Modality: D=27%, S=24%, Sk=28%, V=28%
#     Test Acc: 87.04%, F1: 86.41%, Features: 1212/4463 (27.2%), Model: 2.908MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10477770495098851']
# ['At iteration 2 the best fitness is 0.10477770495098851']
# ['At iteration 3 the best fitness is 0.10477770495098851']
# ['At iteration 4 the best fitness is 0.10477770495098851']
# ['At iteration 5 the best fitness is 0.10477770495098851']
# ['At iteration 6 the best fitness is 0.10477770495098851']
# ['At iteration 7 the best fitness is 0.10477770495098851']
# ['At iteration 8 the best fitness is 0.10477770495098851']
# ['At iteration 9 the best fitness is 0.10477770495098851']
# ['At iteration 10 the best fitness is 0.10477770495098851']
# ['At iteration 11 the best fitness is 0.10477770495098851']
# ['At iteration 12 the best fitness is 0.10477770495098851']
# ['At iteration 13 the best fitness is 0.10477770495098851']
# ['At iteration 14 the best fitness is 0.10477770495098851']
# ['At iteration 15 the best fitness is 0.10477770495098851']
# ['At iteration 16 the best fitness is 0.10477770495098851']
# ['At iteration 17 the best fitness is 0.10477770495098851']
# ['At iteration 18 the best fitness is 0.10477770495098851']
# ['At iteration 19 the best fitness is 0.10477770495098851']
# ['At iteration 20 the best fitness is 0.10477770495098851']
# ['At iteration 21 the best fitness is 0.10477770495098851']
# ['At iteration 22 the best fitness is 0.10477770495098851']
# ['At iteration 23 the best fitness is 0.10477770495098851']
# ['At iteration 24 the best fitness is 0.10477770495098851']
# ['At iteration 25 the best fitness is 0.10477770495098851']
# ['At iteration 26 the best fitness is 0.10477770495098851']
# ['At iteration 27 the best fitness is 0.10477770495098851']
# ['At iteration 28 the best fitness is 0.10477770495098851']
# ['At iteration 29 the best fitness is 0.10477770495098851']
#       Selected: 2220/4463 (49.7%), Fitness: 0.1048, Time: 3415.6s
#       Modality: D=49%, S=52%, Sk=49%, V=50%
#     Test Acc: 81.48%, F1: 80.63%, Features: 2220/4463 (49.7%), Model: 4.877MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1581271555740764']
# ['At iteration 1 the best fitness is 0.12363263049664847']
# ['At iteration 2 the best fitness is 0.12363263049664847']
# ['At iteration 3 the best fitness is 0.11463654429672007']
# ['At iteration 4 the best fitness is 0.11463654429672007']
# ['At iteration 5 the best fitness is 0.11463654429672007']
# ['At iteration 6 the best fitness is 0.11463654429672007']
# ['At iteration 7 the best fitness is 0.11463654429672007']
# ['At iteration 8 the best fitness is 0.11463654429672007']
# ['At iteration 9 the best fitness is 0.11463654429672007']
# ['At iteration 10 the best fitness is 0.11463654429672007']
# ['At iteration 11 the best fitness is 0.11463654429672007']
# ['At iteration 12 the best fitness is 0.11463654429672007']
# ['At iteration 13 the best fitness is 0.11463654429672007']
# ['At iteration 14 the best fitness is 0.11463654429672007']
# ['At iteration 15 the best fitness is 0.11463654429672007']
# ['At iteration 16 the best fitness is 0.11463654429672007']
# ['At iteration 17 the best fitness is 0.11463654429672007']
# ['At iteration 18 the best fitness is 0.11463654429672007']
# ['At iteration 19 the best fitness is 0.11463654429672007']
# ['At iteration 20 the best fitness is 0.11463654429672007']
# ['At iteration 21 the best fitness is 0.11463654429672007']
# ['At iteration 22 the best fitness is 0.09787662211202808']
# ['At iteration 23 the best fitness is 0.09787662211202808']
# ['At iteration 24 the best fitness is 0.09787662211202808']
# ['At iteration 25 the best fitness is 0.09787662211202808']
# ['At iteration 26 the best fitness is 0.09787662211202808']
# ['At iteration 27 the best fitness is 0.09787662211202808']
# ['At iteration 28 the best fitness is 0.09787662211202808']
# ['At iteration 29 the best fitness is 0.09787662211202808']
#       Selected: 3189/4463 (71.5%), Fitness: 0.0979, Time: 1405.0s
#       Modality: D=72%, S=69%, Sk=72%, V=71%
#     Test Acc: 89.81%, F1: 88.96%, Features: 3189/4463 (71.5%), Model: 6.770MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 84.26%, F1: 82.04%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 64.9s
#     Test Acc: 87.96%, F1: 86.49%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.4s
#     Test Acc: 88.89%, F1: 88.08%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 3.0s
#     Test Acc: 53.70%, F1: 51.35%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09645936160455333']
# ['At iteration 1 the best fitness is 0.08771529565000702']
# ['At iteration 2 the best fitness is 0.08771529565000702']
# ['At iteration 3 the best fitness is 0.08771529565000702']
# ['At iteration 4 the best fitness is 0.07889280710975602']
# ['At iteration 5 the best fitness is 0.07855671031387881']
# ['At iteration 6 the best fitness is 0.07855671031387881']
# ['At iteration 7 the best fitness is 0.06967820564098162']
# ['At iteration 8 the best fitness is 0.06967820564098162']
# ['At iteration 9 the best fitness is 0.06967820564098162']
# ['At iteration 10 the best fitness is 0.06967820564098162']
# ['At iteration 11 the best fitness is 0.06967820564098162']
# ['At iteration 12 the best fitness is 0.06967820564098162']
# ['At iteration 13 the best fitness is 0.06967820564098162']
# ['At iteration 14 the best fitness is 0.06967820564098162']
# ['At iteration 15 the best fitness is 0.06967820564098162']
# ['At iteration 16 the best fitness is 0.06967820564098162']
# ['At iteration 17 the best fitness is 0.06967820564098162']
# ['At iteration 18 the best fitness is 0.06967820564098162']
# ['At iteration 19 the best fitness is 0.060799700968084416']
# ['At iteration 20 the best fitness is 0.060799700968084416']
# ['At iteration 21 the best fitness is 0.060799700968084416']
# ['At iteration 22 the best fitness is 0.060799700968084416']
# ['At iteration 23 the best fitness is 0.060799700968084416']
# ['At iteration 24 the best fitness is 0.060799700968084416']
# ['At iteration 25 the best fitness is 0.060799700968084416']
# ['At iteration 26 the best fitness is 0.060799700968084416']
# ['At iteration 27 the best fitness is 0.060799700968084416']
# ['At iteration 28 the best fitness is 0.060799700968084416']
# ['At iteration 29 the best fitness is 0.060799700968084416']
#       Selected: 2257/4463 (50.6%), Fitness: 0.0608, Time: 1419.4s
#       Modality: D=50%, S=51%, Sk=51%, V=50%
#     Test Acc: 83.33%, F1: 82.87%, Features: 2257/4463 (50.6%), Model: 4.949MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09515978732716145']
# ['At iteration 1 the best fitness is 0.08628128265426424']
# ['At iteration 2 the best fitness is 0.07748120056707172']
# ['At iteration 3 the best fitness is 0.07748120056707172']
# ['At iteration 4 the best fitness is 0.07748120056707172']
# ['At iteration 5 the best fitness is 0.06856908621458682']
# ['At iteration 6 the best fitness is 0.06856908621458682']
# ['At iteration 7 the best fitness is 0.06856908621458682']
# ['At iteration 8 the best fitness is 0.06856908621458682']
# ['At iteration 9 the best fitness is 0.06856908621458682']
# ['At iteration 10 the best fitness is 0.06856908621458682']
# ['At iteration 11 the best fitness is 0.06856908621458682']
# ['At iteration 12 the best fitness is 0.06856908621458682']
# ['At iteration 13 the best fitness is 0.06856908621458682']
# ['At iteration 14 the best fitness is 0.06856908621458682']
# ['At iteration 15 the best fitness is 0.06856908621458682']
# ['At iteration 16 the best fitness is 0.06856908621458682']
# ['At iteration 17 the best fitness is 0.06856908621458682']
# ['At iteration 18 the best fitness is 0.06856908621458682']
# ['At iteration 19 the best fitness is 0.06856908621458682']
# ['At iteration 20 the best fitness is 0.06856908621458682']
# ['At iteration 21 the best fitness is 0.06856908621458682']
# ['At iteration 22 the best fitness is 0.06856908621458682']
# ['At iteration 23 the best fitness is 0.06856908621458682']
# ['At iteration 24 the best fitness is 0.06856908621458682']
# ['At iteration 25 the best fitness is 0.06856908621458682']
# ['At iteration 26 the best fitness is 0.06856908621458682']
# ['At iteration 27 the best fitness is 0.06856908621458682']
# ['At iteration 28 the best fitness is 0.06856908621458682']
# ['At iteration 29 the best fitness is 0.06856908621458682']
#       Selected: 2158/4463 (48.4%), Fitness: 0.0686, Time: 2782.3s
#       Modality: D=50%, S=48%, Sk=49%, V=48%
#     Test Acc: 87.04%, F1: 85.42%, Features: 2158/4463 (48.4%), Model: 4.756MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09631371965967321']
# ['At iteration 2 the best fitness is 0.09584318414544511']
# ['At iteration 3 the best fitness is 0.09584318414544511']
# ['At iteration 4 the best fitness is 0.09584318414544511']
# ['At iteration 5 the best fitness is 0.09584318414544511']
# ['At iteration 6 the best fitness is 0.09584318414544511']
# ['At iteration 7 the best fitness is 0.09540625831080474']
# ['At iteration 8 the best fitness is 0.08685264720725551']
# ['At iteration 9 the best fitness is 0.08685264720725551']
# ['At iteration 10 the best fitness is 0.08685264720725551']
# ['At iteration 11 the best fitness is 0.08685264720725551']
# ['At iteration 12 the best fitness is 0.08685264720725551']
# ['At iteration 13 the best fitness is 0.07835505223635247']
# ['At iteration 14 the best fitness is 0.07835505223635247']
# ['At iteration 15 the best fitness is 0.07835505223635247']
# ['At iteration 16 the best fitness is 0.07835505223635247']
# ['At iteration 17 the best fitness is 0.07835505223635247']
# ['At iteration 18 the best fitness is 0.07835505223635247']
# ['At iteration 19 the best fitness is 0.07835505223635247']
# ['At iteration 20 the best fitness is 0.07832144255676476']
# ['At iteration 21 the best fitness is 0.07832144255676476']
# ['At iteration 22 the best fitness is 0.06092293645990606']
# ['At iteration 23 the best fitness is 0.06092293645990606']
# ['At iteration 24 the best fitness is 0.06092293645990606']
# ['At iteration 25 the best fitness is 0.06092293645990606']
# ['At iteration 26 the best fitness is 0.06092293645990606']
# ['At iteration 27 the best fitness is 0.06092293645990606']
# ['At iteration 28 the best fitness is 0.06092293645990606']
# ['At iteration 29 the best fitness is 0.06092293645990606']
# ['At iteration 30 the best fitness is 0.06092293645990606']
#       Selected: 2268/4463 (50.8%), Fitness: 0.0609, Time: 1411.0s
#       Modality: D=50%, S=52%, Sk=52%, V=49%
#     Test Acc: 86.11%, F1: 84.12%, Features: 2268/4463 (50.8%), Model: 4.971MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10455364042040369']
# ['At iteration 1 the best fitness is 0.11414915159117228']
# ['At iteration 2 the best fitness is 0.12278118528042618']
# ['At iteration 3 the best fitness is 0.11389147738099975']
# ['At iteration 4 the best fitness is 0.09575355833321118']
# ['At iteration 5 the best fitness is 0.10482251785710546']
# ['At iteration 6 the best fitness is 0.10502417593463179']
# ['At iteration 7 the best fitness is 0.0960896551290884']
# ['At iteration 8 the best fitness is 0.11375703866264887']
# ['At iteration 9 the best fitness is 0.08721115045619121']
# ['At iteration 10 the best fitness is 0.09602243576991296']
# ['At iteration 11 the best fitness is 0.12261313688248758']
# ['At iteration 12 the best fitness is 0.08718874400313273']
# ['At iteration 13 the best fitness is 0.1137906483422366']
# ['At iteration 14 the best fitness is 0.08714393109701576']
# ['At iteration 15 the best fitness is 0.09600002931685447']
# ['At iteration 16 the best fitness is 0.06945414111039681']
# ['At iteration 17 the best fitness is 0.0872671665888374']
# ['At iteration 18 the best fitness is 0.09604484222297144']
# ['At iteration 19 the best fitness is 0.078332645783294']
# ['At iteration 20 the best fitness is 0.0960896551290884']
# ['At iteration 21 the best fitness is 0.08719994722966196']
# ['At iteration 22 the best fitness is 0.10495695657545635']
# ['At iteration 23 the best fitness is 0.10497936302851484']
# ['At iteration 24 the best fitness is 0.06945414111039681']
# ['At iteration 25 the best fitness is 0.10499056625504408']
# ['At iteration 26 the best fitness is 0.10497936302851484']
# ['At iteration 27 the best fitness is 0.09611206158214688']
# ['At iteration 28 the best fitness is 0.09610085835561764']
# ['At iteration 29 the best fitness is 0.09610085835561764']
#       Selected: 2238/4463 (50.1%), Fitness: 0.0961, Time: 1364.0s
#       Modality: D=50%, S=50%, Sk=49%, V=51%
#     Test Acc: 84.26%, F1: 82.75%, Features: 2238/4463 (50.1%), Model: 4.912MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.10528185014480432
# At iteration 2 the best fitness is 0.08703189883172335
# At iteration 3 the best fitness is 0.10459845332652065
# At iteration 4 the best fitness is 0.09570874542709423
# At iteration 5 the best fitness is 0.0961456712617346
# At iteration 6 the best fitness is 0.09611206158214688
# At iteration 7 the best fitness is 0.08680783430113855
# At iteration 8 the best fitness is 0.08680783430113855
# At iteration 9 the best fitness is 0.0779405328547706
# At iteration 10 the best fitness is 0.07791812640171211
# At iteration 11 the best fitness is 0.06974542500015705
# At iteration 12 the best fitness is 0.08656136331749525
# At iteration 13 the best fitness is 0.0956191196148603
# At iteration 14 the best fitness is 0.10435198234287738
# At iteration 15 the best fitness is 0.07798534576088754
# At iteration 16 the best fitness is 0.08685264720725551
# At iteration 17 the best fitness is 0.08690866333990171
# At iteration 18 the best fitness is 0.0866285826766707
# At iteration 19 the best fitness is 0.0777500780037735
# At iteration 20 the best fitness is 0.07801895544047527
# At iteration 21 the best fitness is 0.07791812640171211
# At iteration 22 the best fitness is 0.09560791638833106
# At iteration 23 the best fitness is 0.09560791638833106
# At iteration 24 the best fitness is 0.0692860927124582
# At iteration 25 the best fitness is 0.06905082495534415
# At iteration 26 the best fitness is 0.060317962227327084
# At iteration 27 the best fitness is 0.07825422319758932
# At iteration 28 the best fitness is 0.08672941171543386
# At iteration 29 the best fitness is 0.08666219235625841
# At iteration 30 the best fitness is 0.09563032284138955
#       Selected: 2196/4463 (49.2%), Fitness: 0.0956, Time: 1365.8s
#       Modality: D=48%, S=52%, Sk=48%, V=50%
#     Test Acc: 84.26%, F1: 82.41%, Features: 2196/4463 (49.2%), Model: 4.830MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.1042511533041142']
# ['At iteration 1 the best fitness is 0.09517099055369069']
# ['At iteration 2 the best fitness is 0.09517099055369069']
# ['At iteration 3 the best fitness is 0.07563266818974707']
# ['At iteration 4 the best fitness is 0.07479242620005402']
# ['At iteration 5 the best fitness is 0.07479242620005402']
# ['At iteration 6 the best fitness is 0.07368330677365922']
# ['At iteration 7 the best fitness is 0.07368330677365922']
# ['At iteration 8 the best fitness is 0.07368330677365922']
# ['At iteration 9 the best fitness is 0.07368330677365922']
# ['At iteration 10 the best fitness is 0.07357127450836683']
# ['At iteration 11 the best fitness is 0.07357127450836683']
# ['At iteration 12 the best fitness is 0.07296630027578783']
# ['At iteration 13 the best fitness is 0.07293269059620011']
# ['At iteration 14 the best fitness is 0.06347161814378242']
# ['At iteration 15 the best fitness is 0.04577062493063423']
# ['At iteration 16 the best fitness is 0.04577062493063423']
# ['At iteration 17 the best fitness is 0.04577062493063423']
# ['At iteration 18 the best fitness is 0.04577062493063423']
# ['At iteration 19 the best fitness is 0.04577062493063423']
# ['At iteration 20 the best fitness is 0.04577062493063423']
# ['At iteration 21 the best fitness is 0.04577062493063423']
# ['At iteration 22 the best fitness is 0.04577062493063423']
# ['At iteration 23 the best fitness is 0.04577062493063423']
# ['At iteration 24 the best fitness is 0.04577062493063423']
# ['At iteration 25 the best fitness is 0.04560257653269562']
# ['At iteration 26 the best fitness is 0.04560257653269562']
# ['At iteration 27 the best fitness is 0.04560257653269562']
# ['At iteration 28 the best fitness is 0.04560257653269562']
# ['At iteration 29 the best fitness is 0.04560257653269562']
#       Selected: 1693/4463 (37.9%), Fitness: 0.0456, Time: 1297.8s
#       Modality: D=40%, S=38%, Sk=37%, V=38%
#     Test Acc: 83.33%, F1: 80.93%, Features: 1693/4463 (37.9%), Model: 3.848MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.09657139386984574']
# ['At iteration 1 the best fitness is 0.09657139386984574']
# ['At iteration 2 the best fitness is 0.09657139386984574']
# ['At iteration 3 the best fitness is 0.09554069702915562']
# ['At iteration 4 the best fitness is 0.09554069702915562']
# ['At iteration 5 the best fitness is 0.09554069702915562']
# ['At iteration 6 the best fitness is 0.09554069702915562']
# ['At iteration 7 the best fitness is 0.09554069702915562']
# ['At iteration 8 the best fitness is 0.07848949095470337']
# ['At iteration 9 the best fitness is 0.07848949095470337']
# ['At iteration 10 the best fitness is 0.07848949095470337']
# ['At iteration 11 the best fitness is 0.07848949095470337']
# ['At iteration 12 the best fitness is 0.07848949095470337']
# ['At iteration 13 the best fitness is 0.07848949095470337']
# ['At iteration 14 the best fitness is 0.07848949095470337']
# ['At iteration 15 the best fitness is 0.07848949095470337']
# ['At iteration 16 the best fitness is 0.07848949095470337']
# ['At iteration 17 the best fitness is 0.07848949095470337']
# ['At iteration 18 the best fitness is 0.07848949095470337']
# ['At iteration 19 the best fitness is 0.07848949095470337']
# ['At iteration 20 the best fitness is 0.07848949095470337']
# ['At iteration 21 the best fitness is 0.07848949095470337']
# ['At iteration 22 the best fitness is 0.07848949095470337']
# ['At iteration 23 the best fitness is 0.07848949095470337']
# ['At iteration 24 the best fitness is 0.07848949095470337']
# ['At iteration 25 the best fitness is 0.07848949095470337']
# ['At iteration 26 the best fitness is 0.07848949095470337']
# ['At iteration 27 the best fitness is 0.07848949095470337']
# ['At iteration 28 the best fitness is 0.07218772838353146']
# ['At iteration 29 the best fitness is 0.07218772838353146']
#       Selected: 2481/4463 (55.6%), Fitness: 0.0722, Time: 1769.5s
#       Modality: D=55%, S=58%, Sk=56%, V=55%
#     Test Acc: 85.19%, F1: 82.64%, Features: 2481/4463 (55.6%), Model: 5.387MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09678425517390131']
# ['At iteration 1 the best fitness is 0.09678425517390131']
# ['At iteration 2 the best fitness is 0.09623529707396852']
# ['At iteration 3 the best fitness is 0.09616807771479308']
# ['At iteration 4 the best fitness is 0.06968940886751085']
# ['At iteration 5 the best fitness is 0.06968940886751085']
# ['At iteration 6 the best fitness is 0.06968940886751085']
# ['At iteration 7 the best fitness is 0.06968940886751085']
# ['At iteration 8 the best fitness is 0.06968940886751085']
# ['At iteration 9 the best fitness is 0.06968940886751085']
# ['At iteration 10 the best fitness is 0.06968940886751085']
# ['At iteration 11 the best fitness is 0.06968940886751085']
# ['At iteration 12 the best fitness is 0.06968940886751085']
# ['At iteration 13 the best fitness is 0.06968940886751085']
# ['At iteration 14 the best fitness is 0.06968940886751085']
# ['At iteration 15 the best fitness is 0.06968940886751085']
# ['At iteration 16 the best fitness is 0.06968940886751085']
# ['At iteration 17 the best fitness is 0.06968940886751085']
# ['At iteration 18 the best fitness is 0.06968940886751085']
# ['At iteration 19 the best fitness is 0.06968940886751085']
# ['At iteration 20 the best fitness is 0.06968940886751085']
# ['At iteration 21 the best fitness is 0.06968940886751085']
# ['At iteration 22 the best fitness is 0.06968940886751085']
# ['At iteration 23 the best fitness is 0.06968940886751085']
# ['At iteration 24 the best fitness is 0.06968940886751085']
# ['At iteration 25 the best fitness is 0.06968940886751085']
# ['At iteration 26 the best fitness is 0.06968940886751085']
# ['At iteration 27 the best fitness is 0.06968940886751085']
# ...
# ['At iteration 15 the best fitness is 0.10784738902000038']
# ['At iteration 16 the best fitness is 0.10784738902000038']
# ['At iteration 17 the best fitness is 0.10784738902000038']
# ['At iteration 18 the best fitness is 0.10784738902000038']
# ['At iteration 19 the best fitness is 0.10784738902000038']
# ['At iteration 20 the best fitness is 0.10784738902000038']
# ['At iteration 21 the best fitness is 0.10784738902000038']
# ['At iteration 22 the best fitness is 0.10784738902000038']
# ['At iteration 23 the best fitness is 0.10784738902000038']
# ['At iteration 24 the best fitness is 0.10784738902000038']
# ['At iteration 25 the best fitness is 0.10784738902000038']
# ['At iteration 26 the best fitness is 0.10784738902000038']
# ['At iteration 27 the best fitness is 0.10784738902000038']
# ['At iteration 28 the best fitness is 0.10784738902000038']
# ['At iteration 29 the best fitness is 0.10784738902000038']
#       Selected: 2494/4463 (55.9%), Fitness: 0.1078, Time: 1808.6s
#       Modality: D=56%, S=55%, Sk=56%, V=56%
#     Test Acc: 85.98%, F1: 83.63%, Features: 2494/4463 (55.9%), Model: 5.412MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11352177090553482']
# ['At iteration 1 the best fitness is 0.11352177090553482']
# ['At iteration 2 the best fitness is 0.08707671173784032']
# ['At iteration 3 the best fitness is 0.08707671173784032']
# ['At iteration 4 the best fitness is 0.08707671173784032']
# ['At iteration 5 the best fitness is 0.08707671173784032']
# ['At iteration 6 the best fitness is 0.08707671173784032']
# ['At iteration 7 the best fitness is 0.06962218950833542']
# ['At iteration 8 the best fitness is 0.06962218950833542']
# ['At iteration 9 the best fitness is 0.06962218950833542']
# ['At iteration 10 the best fitness is 0.06962218950833542']
# ['At iteration 11 the best fitness is 0.06962218950833542']
# ['At iteration 12 the best fitness is 0.06962218950833542']
# ['At iteration 13 the best fitness is 0.06962218950833542']
# ['At iteration 14 the best fitness is 0.06962218950833542']
# ['At iteration 15 the best fitness is 0.06962218950833542']
# ['At iteration 16 the best fitness is 0.06962218950833542']
# ['At iteration 17 the best fitness is 0.06962218950833542']
# ['At iteration 18 the best fitness is 0.06962218950833542']
# ['At iteration 19 the best fitness is 0.06962218950833542']
# ['At iteration 20 the best fitness is 0.06956617337568921']
# ['At iteration 21 the best fitness is 0.06956617337568921']
# ['At iteration 22 the best fitness is 0.06956617337568921']
# ['At iteration 23 the best fitness is 0.06956617337568921']
# ['At iteration 24 the best fitness is 0.06956617337568921']
# ['At iteration 25 the best fitness is 0.06956617337568921']
# ['At iteration 26 the best fitness is 0.06956617337568921']
# ['At iteration 27 the best fitness is 0.06956617337568921']
# ['At iteration 28 the best fitness is 0.06956617337568921']
# ['At iteration 29 the best fitness is 0.06956617337568921']
#       Selected: 2247/4463 (50.3%), Fitness: 0.0696, Time: 1422.0s
#       Modality: D=49%, S=50%, Sk=52%, V=48%
#     Test Acc: 87.85%, F1: 85.93%, Features: 2247/4463 (50.3%), Model: 4.930MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.13148043832885553']
# ['At iteration 2 the best fitness is 0.11388027415447052']
# ['At iteration 3 the best fitness is 0.09631371965967321']
# ['At iteration 4 the best fitness is 0.09631371965967321']
# ['At iteration 5 the best fitness is 0.09631371965967321']
# ['At iteration 6 the best fitness is 0.09631371965967321']
# ['At iteration 7 the best fitness is 0.09610085835561764']
# ['At iteration 8 the best fitness is 0.09610085835561764']
# ['At iteration 9 the best fitness is 0.09610085835561764']
# ['At iteration 10 the best fitness is 0.09610085835561764']
# ['At iteration 11 the best fitness is 0.09610085835561764']
# ['At iteration 12 the best fitness is 0.09610085835561764']
# ['At iteration 13 the best fitness is 0.09610085835561764']
# ['At iteration 14 the best fitness is 0.09610085835561764']
# ['At iteration 15 the best fitness is 0.08797296986017955']
# ['At iteration 16 the best fitness is 0.08797296986017955']
# ['At iteration 17 the best fitness is 0.08797296986017955']
# ['At iteration 18 the best fitness is 0.08797296986017955']
# ['At iteration 19 the best fitness is 0.08797296986017955']
# ['At iteration 20 the best fitness is 0.08739040208065904']
# ['At iteration 21 the best fitness is 0.08739040208065904']
# ['At iteration 22 the best fitness is 0.08739040208065904']
# ['At iteration 23 the best fitness is 0.07894882324240222']
# ['At iteration 24 the best fitness is 0.07894882324240222']
# ['At iteration 25 the best fitness is 0.07894882324240222']
# ['At iteration 26 the best fitness is 0.07894882324240222']
# ['At iteration 27 the best fitness is 0.07894882324240222']
# ['At iteration 28 the best fitness is 0.07894882324240222']
# ['At iteration 29 the best fitness is 0.07894882324240222']
#       Selected: 2292/4463 (51.4%), Fitness: 0.0789, Time: 1336.1s
#       Modality: D=50%, S=52%, Sk=52%, V=51%
#     Test Acc: 88.79%, F1: 87.52%, Features: 2292/4463 (51.4%), Model: 5.018MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1316372835002649']
# ['At iteration 2 the best fitness is 0.11335372250759622']
# ['At iteration 3 the best fitness is 0.11335372250759622']
# ['At iteration 4 the best fitness is 0.11325289346883305']
# ['At iteration 5 the best fitness is 0.11298401603213129']
# ['At iteration 6 the best fitness is 0.11298401603213129']
# ['At iteration 7 the best fitness is 0.11298401603213129']
# ['At iteration 8 the best fitness is 0.10463206300610838']
# ['At iteration 9 the best fitness is 0.10463206300610838']
# ['At iteration 10 the best fitness is 0.10463206300610838']
# ['At iteration 11 the best fitness is 0.10463206300610838']
# ['At iteration 12 the best fitness is 0.10463206300610838']
# ['At iteration 13 the best fitness is 0.10463206300610838']
# ['At iteration 14 the best fitness is 0.10463206300610838']
# ['At iteration 15 the best fitness is 0.10463206300610838']
# ['At iteration 16 the best fitness is 0.10463206300610838']
# ['At iteration 17 the best fitness is 0.10463206300610838']
# ['At iteration 18 the best fitness is 0.10447521783469901']
# ['At iteration 19 the best fitness is 0.10447521783469901']
# ['At iteration 20 the best fitness is 0.10447521783469901']
# ['At iteration 21 the best fitness is 0.10447521783469901']
# ['At iteration 22 the best fitness is 0.10447521783469901']
# ['At iteration 23 the best fitness is 0.10447521783469901']
# ['At iteration 24 the best fitness is 0.10447521783469901']
# ['At iteration 25 the best fitness is 0.10447521783469901']
# ['At iteration 26 the best fitness is 0.10447521783469901']
# ['At iteration 27 the best fitness is 0.10447521783469901']
# ['At iteration 28 the best fitness is 0.10447521783469901']
# ['At iteration 29 the best fitness is 0.10447521783469901']
# ['At iteration 30 the best fitness is 0.10447521783469901']
#       Selected: 2193/4463 (49.1%), Fitness: 0.1045, Time: 1367.8s
#       Modality: D=49%, S=49%, Sk=49%, V=50%
#     Test Acc: 83.18%, F1: 81.25%, Features: 2193/4463 (49.1%), Model: 4.824MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.13162608027373565']
# ['At iteration 2 the best fitness is 0.13120035766562452']
# ['At iteration 3 the best fitness is 0.12256832397637063']
# ['At iteration 4 the best fitness is 0.08670700526237538']
# ['At iteration 5 the best fitness is 0.08670700526237538']
# ['At iteration 6 the best fitness is 0.08670700526237538']
# ['At iteration 7 the best fitness is 0.08670700526237538']
# ['At iteration 8 the best fitness is 0.08670700526237538']
# ['At iteration 9 the best fitness is 0.08670700526237538']
# ['At iteration 10 the best fitness is 0.08670700526237538']
# ['At iteration 11 the best fitness is 0.08670700526237538']
# ['At iteration 12 the best fitness is 0.08670700526237538']
# ['At iteration 13 the best fitness is 0.08670700526237538']
# ['At iteration 14 the best fitness is 0.08670700526237538']
# ['At iteration 15 the best fitness is 0.08670700526237538']
# ['At iteration 16 the best fitness is 0.08670700526237538']
# ['At iteration 17 the best fitness is 0.08670700526237538']
# ['At iteration 18 the best fitness is 0.08670700526237538']
# ['At iteration 19 the best fitness is 0.08670700526237538']
# ['At iteration 20 the best fitness is 0.08670700526237538']
# ['At iteration 21 the best fitness is 0.08670700526237538']
# ['At iteration 22 the best fitness is 0.08670700526237538']
# ['At iteration 23 the best fitness is 0.08670700526237538']
# ['At iteration 24 the best fitness is 0.08670700526237538']
# ['At iteration 25 the best fitness is 0.08670700526237538']
# ['At iteration 26 the best fitness is 0.08670700526237538']
# ['At iteration 27 the best fitness is 0.08670700526237538']
# ['At iteration 28 the best fitness is 0.08670700526237538']
# ['At iteration 29 the best fitness is 0.08660617622361222']
# ['At iteration 30 the best fitness is 0.08660617622361222']
#       Selected: 2183/4463 (48.9%), Fitness: 0.0866, Time: 1352.0s
#       Modality: D=47%, S=49%, Sk=50%, V=49%
#     Test Acc: 87.85%, F1: 85.79%, Features: 2183/4463 (48.9%), Model: 4.805MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13125637379827074']
# ['At iteration 1 the best fitness is 0.11165083207515167']
# ['At iteration 2 the best fitness is 0.11165083207515167']
# ['At iteration 3 the best fitness is 0.10908529319995562']
# ['At iteration 4 the best fitness is 0.10704630597163386']
# ['At iteration 5 the best fitness is 0.10704630597163386']
# ['At iteration 6 the best fitness is 0.10704630597163386']
# ['At iteration 7 the best fitness is 0.10704630597163386']
# ['At iteration 8 the best fitness is 0.10704630597163386']
# ['At iteration 9 the best fitness is 0.10704630597163386']
# ['At iteration 10 the best fitness is 0.10704630597163386']
# ['At iteration 11 the best fitness is 0.10704630597163386']
# ['At iteration 12 the best fitness is 0.10704630597163386']
# ['At iteration 13 the best fitness is 0.10137747334783821']
# ['At iteration 14 the best fitness is 0.10137747334783821']
# ['At iteration 15 the best fitness is 0.10137747334783821']
# ['At iteration 16 the best fitness is 0.10137747334783821']
# ['At iteration 17 the best fitness is 0.10137747334783821']
# ['At iteration 18 the best fitness is 0.10137747334783821']
# ['At iteration 19 the best fitness is 0.10137747334783821']
# ['At iteration 20 the best fitness is 0.10137747334783821']
# ['At iteration 21 the best fitness is 0.10137747334783821']
# ['At iteration 22 the best fitness is 0.10137747334783821']
# ['At iteration 23 the best fitness is 0.10137747334783821']
# ['At iteration 24 the best fitness is 0.10137747334783821']
# ['At iteration 25 the best fitness is 0.10137747334783821']
# ['At iteration 26 the best fitness is 0.10137747334783821']
# ['At iteration 27 the best fitness is 0.09865508930123279']
# ['At iteration 28 the best fitness is 0.09865508930123279']
# ['At iteration 29 the best fitness is 0.09865508930123279']
#       Selected: 881/4463 (19.7%), Fitness: 0.0987, Time: 1178.6s
#       Modality: D=21%, S=20%, Sk=19%, V=21%
#     Test Acc: 76.64%, F1: 73.87%, Features: 881/4463 (19.7%), Model: 2.262MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.051573896272780764']
# ['At iteration 2 the best fitness is 0.051573896272780764']
# ['At iteration 3 the best fitness is 0.051573896272780764']
# ['At iteration 4 the best fitness is 0.051573896272780764']
# ['At iteration 5 the best fitness is 0.051573896272780764']
# ['At iteration 6 the best fitness is 0.051573896272780764']
# ['At iteration 7 the best fitness is 0.051573896272780764']
# ['At iteration 8 the best fitness is 0.051573896272780764']
# ['At iteration 9 the best fitness is 0.051573896272780764']
# ['At iteration 10 the best fitness is 0.051573896272780764']
# ['At iteration 11 the best fitness is 0.051573896272780764']
# ['At iteration 12 the best fitness is 0.051573896272780764']
# ['At iteration 13 the best fitness is 0.051573896272780764']
# ['At iteration 14 the best fitness is 0.051573896272780764']
# ['At iteration 15 the best fitness is 0.051573896272780764']
# ['At iteration 16 the best fitness is 0.051573896272780764']
# ['At iteration 17 the best fitness is 0.051573896272780764']
# ['At iteration 18 the best fitness is 0.051573896272780764']
# ['At iteration 19 the best fitness is 0.051573896272780764']
# ['At iteration 20 the best fitness is 0.051573896272780764']
# ['At iteration 21 the best fitness is 0.051573896272780764']
# ['At iteration 22 the best fitness is 0.051573896272780764']
# ['At iteration 23 the best fitness is 0.051573896272780764']
# ['At iteration 24 the best fitness is 0.051573896272780764']
# ['At iteration 25 the best fitness is 0.051573896272780764']
# ['At iteration 26 the best fitness is 0.051573896272780764']
# ['At iteration 27 the best fitness is 0.051573896272780764']
# ['At iteration 28 the best fitness is 0.051573896272780764']
# ['At iteration 29 the best fitness is 0.051573896272780764']
#       Selected: 2226/4463 (49.9%), Fitness: 0.0516, Time: 3393.6s
#       Modality: D=52%, S=48%, Sk=51%, V=49%
#     Test Acc: 87.85%, F1: 85.79%, Features: 2226/4463 (49.9%), Model: 4.889MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10477770495098851']
# ['At iteration 1 the best fitness is 0.10477770495098851']
# ['At iteration 2 the best fitness is 0.07138109607342616']
# ['At iteration 3 the best fitness is 0.07138109607342616']
# ['At iteration 4 the best fitness is 0.07138109607342616']
# ['At iteration 5 the best fitness is 0.07138109607342616']
# ['At iteration 6 the best fitness is 0.07138109607342616']
# ['At iteration 7 the best fitness is 0.07138109607342616']
# ['At iteration 8 the best fitness is 0.07138109607342616']
# ['At iteration 9 the best fitness is 0.07138109607342616']
# ['At iteration 10 the best fitness is 0.07138109607342616']
# ['At iteration 11 the best fitness is 0.07138109607342616']
# ['At iteration 12 the best fitness is 0.07138109607342616']
# ['At iteration 13 the best fitness is 0.07138109607342616']
# ['At iteration 14 the best fitness is 0.07138109607342616']
# ['At iteration 15 the best fitness is 0.07138109607342616']
# ['At iteration 16 the best fitness is 0.07138109607342616']
# ['At iteration 17 the best fitness is 0.07138109607342616']
# ['At iteration 18 the best fitness is 0.07138109607342616']
# ['At iteration 19 the best fitness is 0.07138109607342616']
# ['At iteration 20 the best fitness is 0.07138109607342616']
# ['At iteration 21 the best fitness is 0.07138109607342616']
# ['At iteration 22 the best fitness is 0.07138109607342616']
# ['At iteration 23 the best fitness is 0.07138109607342616']
# ['At iteration 24 the best fitness is 0.07138109607342616']
# ['At iteration 25 the best fitness is 0.07138109607342616']
# ['At iteration 26 the best fitness is 0.07138109607342616']
# ['At iteration 27 the best fitness is 0.07138109607342616']
# ['At iteration 28 the best fitness is 0.07138109607342616']
# ['At iteration 29 the best fitness is 0.07138109607342616']
#       Selected: 2409/4463 (54.0%), Fitness: 0.0714, Time: 1223.3s
#       Modality: D=51%, S=58%, Sk=54%, V=52%
#     Test Acc: 88.79%, F1: 88.06%, Features: 2409/4463 (54.0%), Model: 5.246MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          83.333333         90.654206     83.618727
# 1  baseline     2          84.259259         93.457944     82.039976
# 2  baseline     3          82.407407         89.719626     80.930736
# 3  baseline     4          82.407407         91.588785     79.728831
# 4  baseline     5          86.111111         92.523364     85.168617
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        83.618727            86.331570         83.333333               4463
# 1        82.039976            83.456790         84.259259               4463
# 2        80.930736            84.876543         82.407407               4463
# 3        79.728831            82.898295         82.407407               4463
# 4        85.168617            89.894180         86.111111               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              83.97              1.45              82.58              1.78                 4463.00                      100.00              0.00                24.89                24.89          2425371.0                  9.26                        0.00               72.33
# mutual_info              87.45              3.43              86.22              4.12                 2231.00                       49.99             59.38                21.35                80.73          1282587.0                  4.90                       50.01               45.90
#         rfe              86.88              3.75              85.91              3.96                 2231.00                       49.99             10.83                20.90                31.73          1282587.0                  4.90                       50.01               45.90
#       lasso              56.70              6.63              53.24              6.64                 2231.00                       49.99              3.23                21.30                24.53          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              84.79              4.59              83.68              4.90                 2211.75                       49.56           1401.43                22.54              1423.97          1272731.0                  4.86                       50.44               45.78
#     meta_CS              83.98              4.39              82.48              4.82                 2201.38                       49.33           2781.42                22.51              2803.94          1267419.0                  4.84                       50.67               45.68
#     meta_DE              84.44              2.88              82.78              3.18                 2202.75                       49.36           1412.20                22.57              1434.77          1268123.0                  4.84                       50.64               45.71
#    meta_FFA              84.78              1.79              83.34              1.97                 2216.25                       49.66           1364.63                22.62              1387.25          1275035.0                  4.87                       50.34               45.83
#     meta_GA              83.97              2.98              82.22              3.19                 2214.75                       49.62           1365.74                22.43              1388.17          1274267.0                  4.87                       50.38               45.80
#    meta_GWO              85.01              6.53              83.36              7.47                 1804.50                       40.43           1298.17                21.05              1319.21          1064219.0                  4.07                       59.57               41.06
#    meta_HHO              82.80              3.38              81.11              3.77                 2235.00                       50.08           1785.24                22.68              1807.92          1284635.0                  4.91                       49.92               46.16
#   meta_JAYA              85.14              3.69              83.69              4.25                 2225.25                       49.86           1413.23                22.56              1435.80          1279643.0                  4.89                       50.14               45.91
#    meta_MFO              85.60              2.25              84.18              2.73                 2244.75                       50.30           1335.00                22.63              1357.63          1289627.0                  4.93                       49.70               46.13
#    meta_MVO              83.97              2.45              82.71              3.13                 2214.25                       49.61           1369.25                22.55              1391.79          1274011.0                  4.87                       50.39               45.78
#    meta_PSO              83.74              3.80              82.13              4.49                 2193.88                       49.16           1360.46                22.17              1382.62          1263579.0                  4.83                       50.84               45.63
#    meta_SCA              82.68              5.08              80.94              5.82                 1091.75                       24.46           1171.43                19.88              1191.31           699291.0                  2.67                       75.54               32.77
#    meta_SSA              84.67              5.53              83.36              5.78                 2222.62                       49.80           3412.23                22.34              3434.56          1278299.0                  4.88                       50.20               45.85
#    meta_WOA              83.62              3.83              81.64              4.63                 1800.12                       40.33           1295.03                19.97              1315.00          1061979.0                  4.06                       59.67               41.01

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_WOA
#     F1 Macro:           88.96%
#     F1 Weighted:        88.96%
#     Test Accuracy:      89.81%
#     Feature Retention:  71.45% (3189/4463)
#     Modality Retention: depth=72.5%, sensor=69.3%, skeleton=72.1%, video=71.2%
#
#   Fold 2: Best = meta_JAYA
#     F1 Macro:           89.45%
#     F1 Weighted:        89.45%
#     Test Accuracy:      90.74%
#     Feature Retention:  50.59% (2258/4463)
#     Modality Retention: depth=52.3%, sensor=47.5%, skeleton=51.0%, video=50.8%
#
#   Fold 3: Best = meta_FFA
#     F1 Macro:           82.52%
#     F1 Weighted:        82.52%
#     Test Accuracy:      83.33%
#     Feature Retention:  51.94% (2318/4463)
#     Modality Retention: depth=52.1%, sensor=54.3%, skeleton=52.1%, video=50.6%
#
#   Fold 4: Best = meta_MVO
#     F1 Macro:           84.41%
#     F1 Weighted:        84.41%
#     Test Accuracy:      85.19%
#     Feature Retention:  50.01% (2232/4463)
#     Modality Retention: depth=51.0%, sensor=50.2%, skeleton=49.4%, video=50.4%
#
#   Fold 5: Best = meta_GWO
#     F1 Macro:           92.31%
#     F1 Weighted:        92.31%
#     Test Accuracy:      92.59%
#     Feature Retention:  33.97% (1516/4463)
#     Modality Retention: depth=31.6%, sensor=34.2%, skeleton=35.1%, video=33.2%
#
#   Fold 6: Best = meta_JAYA
#     F1 Macro:           84.34%
#     F1 Weighted:        84.19%
#     Test Accuracy:      85.05%
#     Feature Retention:  49.54% (2211/4463)
#     Modality Retention: depth=49.4%, sensor=51.7%, skeleton=48.4%, video=50.1%
#
#   Fold 7: Best = meta_SSA
#     F1 Macro:           92.38%
#     F1 Weighted:        92.31%
#     Test Accuracy:      92.52%
#     Feature Retention:  49.76% (2221/4463)
#     Modality Retention: depth=50.2%, sensor=51.4%, skeleton=48.4%, video=50.6%
#
#   Fold 8: Best = meta_BAT
#     F1 Macro:           90.45%
#     F1 Weighted:        90.93%
#     Test Accuracy:      91.59%
#     Feature Retention:  48.67% (2172/4463)
#     Modality Retention: depth=47.7%, sensor=46.2%, skeleton=49.7%, video=48.8%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 88.10% ± 3.84%
#
#   Average F1 Weighted         : 88.14% ± 3.89%
#
#   Average Test Accuracy       : 88.85% ± 3.74%
#
#   Average Feature Retention   : 50.74% ± 10.14%
#
#   Average Modality-wise Feature Retention:
#            depth: 50.85% ± 11.04%
#           sensor: 50.59% ± 9.74%
#         skeleton: 50.78% ± 10.13%
#            video: 50.71% ± 10.21%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1           meta_WOA         88.96            88.96              89.81                  71.45              72.46               69.33                 72.11              71.20
#     2          meta_JAYA         89.45            89.45              90.74                  50.59              52.34               47.55                 51.04              50.77
#     3           meta_FFA         82.52            82.52              83.33                  51.94              52.15               54.29                 52.10              50.56
#     4           meta_MVO         84.41            84.41              85.19                  50.01              50.98               50.15                 49.39              50.42
#     5           meta_GWO         92.31            92.31              92.59                  33.97              31.64               34.20                 35.07              33.24
#     6          meta_JAYA         84.34            84.19              85.05                  49.54              49.41               51.69                 48.43              50.07
#     7           meta_SSA         92.38            92.31              92.52                  49.76              50.20               51.38                 48.43              50.63
#     8           meta_BAT         90.45            90.93              91.59                  48.67              47.66               46.17                 49.71              48.80
#
# Saved to: results_noise_1.0_50/best_metaheuristic_per_fold.csv
