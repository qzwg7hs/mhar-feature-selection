# %% [markdown]
# # File 1: Weighted Early Fusion — Learn Modality Weights
#
# **Goal:** Instead of simple concatenation (equal contribution), learn optimal per-modality
# scalar weights using all 14 EvoloPy metaheuristics.
#
# **Search space:** 4 continuous values in [0, 1] — one weight per modality (depth, sensor, skeleton, video).
#
# **Pipeline per fold:**
# 1. Metaheuristic optimizes `[w_depth, w_sensor, w_skeleton, w_video]` using quick fitness evaluations
# 2. Apply learned weights → train full classifier → evaluate
#
# **Outputs saved:**
# - Best weights per fold (per optimizer)
# - Best-overall weights per fold (best optimizer chosen per fold by val accuracy)
# - Baseline (unweighted) results for comparison
# - All results CSVs, plots, and a `best_weights_per_fold.pkl` for File 2

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# EvoloPy imports
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

RESULTS_ROOT = Path("results_weighted_fusion")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Training hyperparameters (same as original)
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001

DEPTH_PCA_DIM = 512
DEPTH_DR_METHOD = 'kernel_pca'

# Metaheuristic hyperparameters
N_POPULATION = 20
MAX_ITERATIONS = 30
FITNESS_EPOCHS = 15  # quick training during fitness evaluation

# All 14 EvoloPy optimizers
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline'] + [f'weighted_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  Fitness epochs: {FITNESS_EPOCHS}")
print(f"  Depth DR: {DEPTH_DR_METHOD} -> {DEPTH_PCA_DIM} dims")
print(f"  Optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Metaheuristic pop: 20, iter: 30
#   Fitness epochs: 15
#   Depth DR: kernel_pca -> 512 dims
#   Optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 15

# %% [markdown]
# ## Load Data

# %%
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")

print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

first_sample = X_feat[0]
MODALITY_KEYS   = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES  = ['depth', 'sensor', 'skeleton', 'video']
N_MODALITIES    = len(MODALITY_NAMES)

# Raw (pre-DR) per-modality dims
RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality) for fold-wise processing
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before depth DR):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")
print(f"\nDepth KernelPCA target: {DEPTH_PCA_DIM}")

TOTAL_FEATURES = RAW_FEATURE_DIMS['sensor'] + RAW_FEATURE_DIMS['skeleton'] + RAW_FEATURE_DIMS['video'] + DEPTH_PCA_DIM
print(f"\nTotal features (all modalities combined): {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before depth DR):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth KernelPCA target: 512
#
# Total features (all modalities combined): 4463

# %% [markdown]
# ## Model & Dataset

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (same as original)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)


print("Model and dataset defined")
# Out:
# Model and dataset defined

# %% [markdown]
# ## Helper Functions

# %%
# ─── Per-modality pipeline (split → normalize per modality → KernelPCA on depth → concat) ───

def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline:
      1. Split raw arrays into train / val / test by index
      2. Fit StandardScaler on train, apply to val and test — per modality separately
      3. Apply KernelPCA (rbf) on depth modality only (fit on train, transform val & test)
      4. Concatenate: depth | sensor | skeleton | video

    Returns:
        X_train, X_val, X_test : normalized (and KernelPCA-reduced) concatenated arrays
        fold_feature_dims       : dict {modality: dim} AFTER KernelPCA (used for apply_modality_weights)
        pca_obj                 : fitted KernelPCA object (or None)
    """
    modality_train = {}
    modality_val   = {}
    modality_test  = {}
    scalers        = {}
    pca_obj        = None
    fold_feature_dims = {}

    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]

        # 1. Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]

        # 2. Per-modality normalization — fit on train only
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler

        # 3. KernelPCA on depth only
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                random_state=42, n_jobs=-1)
            X_tr = pca_obj.fit_transform(X_tr)
            X_v  = pca_obj.transform(X_v)
            X_te = pca_obj.transform(X_te)
            print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        fold_feature_dims[name] = X_tr.shape[1]

    # 4. Concatenate
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)

    total = sum(fold_feature_dims.values())
    print(f"    Feature dims after processing: " +
          " | ".join(f"{n}={fold_feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")

    return X_train, X_val, X_test, fold_feature_dims, pca_obj


def apply_modality_weights(X, weights, modality_dims):
    """Apply per-modality scalar weights to concatenated feature matrix.

    Args:
        X            : (N, TOTAL_FEATURES) — already concatenated and scaled
        weights      : (N_MODALITIES,)    — one weight per modality
        modality_dims: list of ints        — feature count per modality (post-DR)
    Returns:
        Weighted copy of X
    """
    X_weighted = X.copy()
    start_idx = 0
    for i, dim in enumerate(modality_dims):
        end_idx = start_idx + dim
        X_weighted[:, start_idx:end_idx] *= weights[i]
        start_idx = end_idx
    return X_weighted


def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)


print("Helper functions defined (per-modality normalization + KernelPCA on depth)")
# Out:
# Helper functions defined (per-modality normalization + KernelPCA on depth)

# %% [markdown]
# ## Fitness Function & Quick Training

# %%
def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation.
    Returns val_loss (continuous) and val_acc.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


def create_fitness_modality_weights(X_train, y_train, X_val, y_val, num_classes, modality_dims=None):
    """Fitness function for optimizing 4 modality weights.
    
    Uses VALIDATION LOSS (continuous) instead of (1 - accuracy).
    
    Why: With only 4 dimensions and ~107 val samples, many weight
    combinations achieve 100% val accuracy -> fitness=0.0 -> optimizer
    cannot differentiate. Val loss is continuous and always provides
    a gradient signal even when accuracy is saturated.
    """
    eval_count = [0]
    _modality_dims = modality_dims  # captured in closure
    
    def fitness(solution):
        try:
            weights = np.clip(solution, 0.0, 1.0)
            
            # Apply modality weights
            X_tr_w = apply_modality_weights(X_train, weights, _modality_dims)
            X_val_w = apply_modality_weights(X_val, weights, _modality_dims)
            
            train_ds = MultiModalDataset(X_tr_w, y_train)
            val_ds = MultiModalDataset(X_val_w, y_val)
            train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE)
            
            model = SimpleNN(TOTAL_FEATURES, num_classes).to(DEVICE)
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=FITNESS_EPOCHS, lr=1e-3, device=DEVICE
            )
            
            del model, train_ds, val_ds, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Use val_loss directly as fitness (continuous, always differentiable)
            # Even when accuracy=100%, loss still varies between solutions
            fitness_val = val_loss
            return fitness_val
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 100.0
    
    return fitness


def run_weight_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, modality_dims=None):
    """Run a single metaheuristic to optimize modality weights."""
    print(f"    Running weighted_{optimizer_name}...")
    print(f"      Search dim: {N_MODALITIES}, Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_modality_weights(X_train, y_train, X_val, y_val, num_classes, modality_dims=modality_dims)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, N_MODALITIES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    learned_weights = np.clip(solution.bestIndividual, 0.0, 1.0)
    convergence = (solution.convergence.tolist()
                   if hasattr(solution.convergence, 'tolist')
                   else list(solution.convergence))
    
    results = {
        'modality_weights': learned_weights,
        'convergence': convergence,
        'best_fitness': float(convergence[-1]) if len(convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'method': f'weighted_{optimizer_name}'
    }
    
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={learned_weights[i]:.3f}" for i in range(N_MODALITIES)])
    print(f"      Weights: {w_str}")
    print(f"      Best fitness: {results['best_fitness']:.6f}, Time: {exec_time:.1f}s")
    
    return results


print("Fitness function and weight optimizer runner defined")
print("NOTE: Using val_loss as fitness (continuous signal, not accuracy)")
# Out:
# Fitness function and weight optimizer runner defined
# NOTE: Using val_loss as fitness (continuous signal, not accuracy)

# %% [markdown]
# ## Full Training & Evaluation

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics (same as original)"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_val_loss = float('inf')
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)
        epoch_val_acc = val_correct / val_total

        # Also track val loss for this epoch
        epoch_val_loss = 0.0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                labels = labels.to(DEVICE)
                outputs = model(features)
                epoch_val_loss += nn.CrossEntropyLoss()(outputs, labels).item()
        epoch_val_loss /= len(val_loader)

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_val_loss = epoch_val_loss
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'val_loss': best_val_loss,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics


print("Full train/eval function defined")
# Out:
# Full train/eval function defined

# %% [markdown]
# ## Main Experiment Runner

# %%
def run_weighted_fusion_all_folds():
    """
    Run baseline + 14 weighted metaheuristics across all 8 LOSO folds.

    Fold logic (adapted from utd_mhad_main.ipynb):
      - GroupKFold: one subject held out as TEST per fold
      - Within remaining subjects, the LAST subject is held out as VAL
      - Per-modality normalization: StandardScaler fit on train, applied to val & test
      - KernelPCA (rbf) on depth modality only (DEPTH_PCA_DIM), fit on train only
      - apply_modality_weights uses per-fold modality_dims (post-KernelPCA)
    """
    print("=" * 80)
    print("WEIGHTED EARLY FUSION: MODALITY WEIGHT OPTIMIZATION")
    print(f"Methods: baseline + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth DR: {DEPTH_DR_METHOD} -> {DEPTH_PCA_DIM} dims")
    print("=" * 80)

    num_classes = len(np.unique(y))

    master_results = {m: {} for m in ALL_METHODS}

    # Use dummy_X for GroupKFold index splitting (matching utd_mhad_main style)
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    gkf = GroupKFold(n_splits=N_FOLDS)

    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#' * 80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#' * 80}")

        # ── Subject-based val split within train_val ──────────────────────────
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]          # last subject → val

        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv

        train_idx_fold = train_val_idx[train_mask_in_tv]
        val_idx_fold   = train_val_idx[val_mask_in_tv]

        print(f"  Test subject : {np.unique(subjects[test_idx])}")
        print(f"  Val  subject : {val_subject}")
        print(f"  Train: {len(train_idx_fold)}, Val: {len(val_idx_fold)}, Test: {len(test_idx)}")

        # ── Per-modality normalization + KernelPCA on depth ─────────────────────
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx_fold, val_idx_fold, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )

        y_train = y[train_idx_fold]
        y_val   = y[val_idx_fold]
        y_test  = y[test_idx]

        fold_modality_dims  = [fold_feature_dims[n] for n in MODALITY_NAMES]
        fold_total_features = sum(fold_modality_dims)

        orig_dataset_size_mb = (get_dataset_size_mb(X_train) +
                                get_dataset_size_mb(X_val) +
                                get_dataset_size_mb(X_test))

        # ── Run each method ───────────────────────────────────────────────────
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")

            fs_start_time = time.time()

            if method_name == 'baseline':
                modality_weights = np.ones(N_MODALITIES)
                weight_results = {
                    'modality_weights': modality_weights,
                    'execution_time': 0,
                    'convergence': None,
                    'best_fitness': None,
                    'method': 'baseline'
                }
            else:
                opt_name = method_name.replace('weighted_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                weight_results = run_weight_optimizer(
                    opt_name, opt_func,
                    X_train, y_train, X_val, y_val, num_classes,
                    modality_dims=fold_modality_dims
                )
                modality_weights = weight_results['modality_weights']

            fs_time = time.time() - fs_start_time

            # Apply weights (using fold-specific dims, post-KernelPCA)
            X_train_w = apply_modality_weights(X_train, modality_weights, fold_modality_dims)
            X_val_w   = apply_modality_weights(X_val,   modality_weights, fold_modality_dims)
            X_test_w  = apply_modality_weights(X_test,  modality_weights, fold_modality_dims)

            # Build and train final model
            model = SimpleNN(fold_total_features, num_classes).to(DEVICE)

            train_dataset = MultiModalDataset(X_train_w, y_train)
            val_dataset   = MultiModalDataset(X_val_w,   y_val)
            test_dataset  = MultiModalDataset(X_test_w,  y_test)

            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE)
            test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE)

            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()

            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )

            # Compile fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                'val_acc': eval_metrics['val_acc'],
                'val_loss': eval_metrics['val_loss'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                'modality_weights': modality_weights,
                'fold_feature_dims': fold_feature_dims,
                'fold_total_features': fold_total_features,
                'weight_optimization_time': weight_results['execution_time'],
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': weight_results.get('convergence', None),
                'best_fitness': weight_results.get('best_fitness', None),
                'test_preds': eval_metrics['test_preds'],
                'test_true': eval_metrics['test_true'],
            }

            master_results[method_name][fold_idx] = fold_result

            # Save per-fold result
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items()
                         if k not in ['test_preds', 'test_true']}
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                else:
                    fold_save_clean[k] = v

            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)

            # Save weights as npy for easy loading
            np.save(fold_dir / f"fold_{fold_idx+1}_weights.npy", modality_weights)

            w_str = ', '.join([f"{MODALITY_NAMES[i]}={modality_weights[i]:.3f}"
                               for i in range(N_MODALITIES)])
            print(f"    Weights: [{w_str}]")
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")

            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()

    print(f"\n{'=' * 80}")
    print("ALL WEIGHTED FUSION EXPERIMENTS COMPLETED")
    print(f"{'=' * 80}")

    return master_results


print("Main experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth DR: {DEPTH_DR_METHOD} -> {DEPTH_PCA_DIM} dims")
# Out:
# Main experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth DR: kernel_pca -> 512 dims

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_weighted_fusion_all_folds()
# Out:
# ================================================================================
# WEIGHTED EARLY FUSION: MODALITY WEIGHT OPTIMIZATION
# Methods: baseline + 14 metaheuristics = 15 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth DR: kernel_pca -> 512 dims
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Test subject : [7]
#   Val  subject : 8
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000, video=1.000]
#     Test Acc: 93.52%, F1: 92.56%, Model: 9.258MB
#
#   --- WEIGHTED_BAT ---
#     Running weighted_BAT...
#       Search dim: 4, Pop: 20, Iter: 30
# BAT is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.12810168508440256']
# ['At iteration 1 the best fitness is 0.12644571252167225']
# ['At iteration 2 the best fitness is 0.12535363156348467']
# ['At iteration 3 the best fitness is 0.12535363156348467']
# ['At iteration 4 the best fitness is 0.12535363156348467']
# ['At iteration 5 the best fitness is 0.12535363156348467']
# ['At iteration 6 the best fitness is 0.12535363156348467']
# ['At iteration 7 the best fitness is 0.12535363156348467']
# ['At iteration 8 the best fitness is 0.1140718562528491']
# ['At iteration 9 the best fitness is 0.1140718562528491']
# ['At iteration 10 the best fitness is 0.1140718562528491']
# ['At iteration 11 the best fitness is 0.1140718562528491']
# ['At iteration 12 the best fitness is 0.1140718562528491']
# ['At iteration 13 the best fitness is 0.1140718562528491']
# ['At iteration 14 the best fitness is 0.1140718562528491']
# ['At iteration 15 the best fitness is 0.11292262841016054']
# ['At iteration 16 the best fitness is 0.11292262841016054']
# ['At iteration 17 the best fitness is 0.11292262841016054']
# ['At iteration 18 the best fitness is 0.11292262841016054']
# ['At iteration 19 the best fitness is 0.11292262841016054']
# ['At iteration 20 the best fitness is 0.11292262841016054']
# ['At iteration 21 the best fitness is 0.11153792589902878']
# ['At iteration 22 the best fitness is 0.11153792589902878']
# ['At iteration 23 the best fitness is 0.11153792589902878']
# ['At iteration 24 the best fitness is 0.10984963830560446']
# ['At iteration 25 the best fitness is 0.09178308770060539']
# ['At iteration 26 the best fitness is 0.09178308770060539']
# ['At iteration 27 the best fitness is 0.09178308770060539']
# ['At iteration 28 the best fitness is 0.09178308770060539']
# ['At iteration 29 the best fitness is 0.09178308770060539']
#       Weights: depth=0.000, sensor=1.000, skeleton=1.000, video=0.000
#       Best fitness: 0.091783, Time: 603.9s
#     Weights: [depth=0.000, sensor=1.000, skeleton=1.000, video=0.000]
#     Test Acc: 95.37%, F1: 94.12%, Model: 9.258MB
#
#   --- WEIGHTED_CS ---
#     Running weighted_CS...
#       Search dim: 4, Pop: 20, Iter: 30
# CS is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.12488874793052673']
# ['At iteration 1 the best fitness is 0.12488874793052673']
# ['At iteration 2 the best fitness is 0.12488874793052673']
# ['At iteration 3 the best fitness is 0.12488874793052673']
# ['At iteration 4 the best fitness is 0.12240749970078468']
# ['At iteration 5 the best fitness is 0.12072665803134441']
# ['At iteration 6 the best fitness is 0.12072665803134441']
# ['At iteration 7 the best fitness is 0.1161852078512311']
# ['At iteration 8 the best fitness is 0.1161852078512311']
# ['At iteration 9 the best fitness is 0.1161852078512311']
# ['At iteration 10 the best fitness is 0.1161852078512311']
# ['At iteration 11 the best fitness is 0.1161852078512311']
# ['At iteration 12 the best fitness is 0.1161852078512311']
# ['At iteration 13 the best fitness is 0.1161852078512311']
# ['At iteration 14 the best fitness is 0.1161852078512311']
# ['At iteration 15 the best fitness is 0.10858693346381187']
# ['At iteration 16 the best fitness is 0.10858693346381187']
# ['At iteration 17 the best fitness is 0.10858693346381187']
# ['At iteration 18 the best fitness is 0.1064990358427167']
# ['At iteration 19 the best fitness is 0.1064990358427167']
# ['At iteration 20 the best fitness is 0.1064990358427167']
# ['At iteration 21 the best fitness is 0.1064990358427167']
# ['At iteration 22 the best fitness is 0.1064990358427167']
# ['At iteration 23 the best fitness is 0.1064990358427167']
# ['At iteration 24 the best fitness is 0.10426597017794847']
# ['At iteration 25 the best fitness is 0.10426597017794847']
# ['At iteration 26 the best fitness is 0.10426597017794847']
# ['At iteration 27 the best fitness is 0.10426597017794847']
# ['At iteration 28 the best fitness is 0.10426597017794847']
# ['At iteration 29 the best fitness is 0.10426597017794847']
#       Weights: depth=0.457, sensor=0.406, skeleton=0.689, video=0.000
#       Best fitness: 0.104266, Time: 1247.6s
#     Weights: [depth=0.457, sensor=0.406, skeleton=0.689, video=0.000]
#     Test Acc: 96.30%, F1: 95.88%, Model: 9.258MB
#
#   --- WEIGHTED_DE ---
#     Running weighted_DE...
#       Search dim: 4, Pop: 20, Iter: 30
# DE is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.1324837552383542']
# ['At iteration 2 the best fitness is 0.1324837552383542']
# ['At iteration 3 the best fitness is 0.12491378095000982']
# ['At iteration 4 the best fitness is 0.11304135108366609']
# ['At iteration 5 the best fitness is 0.11304135108366609']
# ['At iteration 6 the best fitness is 0.11304135108366609']
# ['At iteration 7 the best fitness is 0.11304135108366609']
# ['At iteration 8 the best fitness is 0.11304135108366609']
# ['At iteration 9 the best fitness is 0.11304135108366609']
# ['At iteration 10 the best fitness is 0.11304135108366609']
# ['At iteration 11 the best fitness is 0.11304135108366609']
# ['At iteration 12 the best fitness is 0.11304135108366609']
# ['At iteration 13 the best fitness is 0.11304135108366609']
# ['At iteration 14 the best fitness is 0.11304135108366609']
# ['At iteration 15 the best fitness is 0.11304135108366609']
# ['At iteration 16 the best fitness is 0.11304135108366609']
# ['At iteration 17 the best fitness is 0.11304135108366609']
# ['At iteration 18 the best fitness is 0.11304135108366609']
# ['At iteration 19 the best fitness is 0.11304135108366609']
# ['At iteration 20 the best fitness is 0.11304135108366609']
# ['At iteration 21 the best fitness is 0.11304135108366609']
# ['At iteration 22 the best fitness is 0.11057110037654638']
# ['At iteration 23 the best fitness is 0.11057110037654638']
# ['At iteration 24 the best fitness is 0.11057110037654638']
# ['At iteration 25 the best fitness is 0.11057110037654638']
# ['At iteration 26 the best fitness is 0.11057110037654638']
# ['At iteration 27 the best fitness is 0.11057110037654638']
# ['At iteration 28 the best fitness is 0.11057110037654638']
# ['At iteration 29 the best fitness is 0.09987624920904636']
# ['At iteration 30 the best fitness is 0.09987624920904636']
#       Weights: depth=0.248, sensor=0.404, skeleton=0.607, video=0.000
#       Best fitness: 0.099876, Time: 633.2s
#     Weights: [depth=0.248, sensor=0.404, skeleton=0.607, video=0.000]
#     Test Acc: 95.37%, F1: 94.61%, Model: 9.258MB
#
#   --- WEIGHTED_FFA ---
#     Running weighted_FFA...
#       Search dim: 4, Pop: 20, Iter: 30
# FFA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.12941579893231392']
# ['At iteration 1 the best fitness is 0.12977355625480413']
# ['At iteration 2 the best fitness is 0.11423585284501314']
# ['At iteration 3 the best fitness is 0.1123004537075758']
# ['At iteration 4 the best fitness is 0.11813157610595226']
# ['At iteration 5 the best fitness is 0.12967585120350122']
# ['At iteration 6 the best fitness is 0.10965253598988056']
# ['At iteration 7 the best fitness is 0.1174989677965641']
# ['At iteration 8 the best fitness is 0.11446669604629278']
# ['At iteration 9 the best fitness is 0.13246585242450237']
# ['At iteration 10 the best fitness is 0.11622493527829647']
# ['At iteration 11 the best fitness is 0.11839479580521584']
# ['At iteration 12 the best fitness is 0.13405794464051723']
# ['At iteration 13 the best fitness is 0.11248527746647596']
# ['At iteration 14 the best fitness is 0.13079341873526573']
# ['At iteration 15 the best fitness is 0.13235500268638134']
# ['At iteration 16 the best fitness is 0.1312491800636053']
# ['At iteration 17 the best fitness is 0.11803186777979136']
# ['At iteration 18 the best fitness is 0.13258605916053057']
# ['At iteration 19 the best fitness is 0.12829589005559683']
# ['At iteration 20 the best fitness is 0.12777367793023586']
# ['At iteration 21 the best fitness is 0.10941115021705627']
# ['At iteration 22 the best fitness is 0.12458748184144497']
# ['At iteration 23 the best fitness is 0.12424417957663536']
# ['At iteration 24 the best fitness is 0.12201105430722237']
# ['At iteration 25 the best fitness is 0.11749924626201391']
# ['At iteration 26 the best fitness is 0.12198029831051826']
# ['At iteration 27 the best fitness is 0.12341786921024323']
# ['At iteration 28 the best fitness is 0.10894023068249226']
# ['At iteration 29 the best fitness is 0.12442394718527794']
#       Weights: depth=0.427, sensor=0.281, skeleton=0.775, video=0.000
#       Best fitness: 0.124424, Time: 613.5s
#     Weights: [depth=0.427, sensor=0.281, skeleton=0.775, video=0.000]
#     Test Acc: 95.37%, F1: 94.34%, Model: 9.258MB
#
#   --- WEIGHTED_GA ---
#     Running weighted_GA...
#       Search dim: 4, Pop: 20, Iter: 30
# GA is optimizing  "fitness"
# At iteration 1 the best fitness is 0.1261554528027773
# At iteration 2 the best fitness is 0.10780778806656599
# At iteration 3 the best fitness is 0.14980719238519669
# At iteration 4 the best fitness is 0.12826080154627562
# At iteration 5 the best fitness is 0.1216110484674573
# At iteration 6 the best fitness is 0.11834362428635359
# At iteration 7 the best fitness is 0.1327317589893937
# At iteration 8 the best fitness is 0.13829322531819344
# At iteration 9 the best fitness is 0.11284433305263519
# At iteration 10 the best fitness is 0.10784457996487617
# At iteration 11 the best fitness is 0.10637224651873112
# At iteration 12 the best fitness is 0.11902095191180706
# At iteration 13 the best fitness is 0.14317738264799118
# At iteration 14 the best fitness is 0.11285245418548584
# At iteration 15 the best fitness is 0.14066800102591515
# At iteration 16 the best fitness is 0.13986829575151205
# At iteration 17 the best fitness is 0.12240642122924328
# At iteration 18 the best fitness is 0.11502510216087103
# At iteration 19 the best fitness is 0.12778960168361664
# At iteration 20 the best fitness is 0.14898094814270735
# At iteration 21 the best fitness is 0.11313769221305847
# At iteration 22 the best fitness is 0.13616097159683704
# At iteration 23 the best fitness is 0.13711748830974102
# At iteration 24 the best fitness is 0.12540143635123968
# At iteration 25 the best fitness is 0.13615054078400135
# At iteration 26 the best fitness is 0.11150061618536711
# At iteration 27 the best fitness is 0.13323775678873062
# At iteration 28 the best fitness is 0.13989679515361786
# At iteration 29 the best fitness is 0.11857208423316479
# At iteration 30 the best fitness is 0.1309442799538374
#       Weights: depth=0.480, sensor=0.821, skeleton=0.740, video=0.055
#       Best fitness: 0.130944, Time: 613.4s
#     Weights: [depth=0.480, sensor=0.821, skeleton=0.740, video=0.055]
#     Test Acc: 93.52%, F1: 92.89%, Model: 9.258MB
#
#   --- WEIGHTED_GWO ---
#     Running weighted_GWO...
#       Search dim: 4, Pop: 20, Iter: 30
# GWO is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.12464677449315786']
# ['At iteration 1 the best fitness is 0.12464677449315786']
# ['At iteration 2 the best fitness is 0.12464677449315786']
# ['At iteration 3 the best fitness is 0.12464677449315786']
# ['At iteration 4 the best fitness is 0.10941304080188274']
# ['At iteration 5 the best fitness is 0.10941304080188274']
# ['At iteration 6 the best fitness is 0.10941304080188274']
# ['At iteration 7 the best fitness is 0.10941304080188274']
# ['At iteration 8 the best fitness is 0.10941304080188274']
# ['At iteration 9 the best fitness is 0.10941304080188274']
# ['At iteration 10 the best fitness is 0.10941304080188274']
# ['At iteration 11 the best fitness is 0.10941304080188274']
# ['At iteration 12 the best fitness is 0.10941304080188274']
# ['At iteration 13 the best fitness is 0.10561019740998745']
# ['At iteration 14 the best fitness is 0.10561019740998745']
# ['At iteration 15 the best fitness is 0.10561019740998745']
# ['At iteration 16 the best fitness is 0.097860561683774']
# ['At iteration 17 the best fitness is 0.097860561683774']
# ['At iteration 18 the best fitness is 0.097860561683774']
# ['At iteration 19 the best fitness is 0.097860561683774']
# ['At iteration 20 the best fitness is 0.097860561683774']
# ['At iteration 21 the best fitness is 0.097860561683774']
# ['At iteration 22 the best fitness is 0.097860561683774']
# ['At iteration 23 the best fitness is 0.097860561683774']
# ['At iteration 24 the best fitness is 0.097860561683774']
# ['At iteration 25 the best fitness is 0.097860561683774']
# ['At iteration 26 the best fitness is 0.097860561683774']
# ['At iteration 27 the best fitness is 0.097860561683774']
# ['At iteration 28 the best fitness is 0.097860561683774']
# ['At iteration 29 the best fitness is 0.097860561683774']
#       Weights: depth=0.102, sensor=0.233, skeleton=0.303, video=0.004
#       Best fitness: 0.097861, Time: 614.2s
#     Weights: [depth=0.102, sensor=0.233, skeleton=0.303, video=0.004]
#     Test Acc: 91.67%, F1: 90.59%, Model: 9.258MB
#
#   --- WEIGHTED_HHO ---
#     Running weighted_HHO...
#       Search dim: 4, Pop: 20, Iter: 30
# HHO is now tackling  "fitness"
# ['At iteration 0 the best fitness is 0.13832336198538542']
# ['At iteration 1 the best fitness is 0.11608108039945364']
# ['At iteration 2 the best fitness is 0.11608108039945364']
# ['At iteration 3 the best fitness is 0.11608108039945364']
# ['At iteration 4 the best fitness is 0.11608108039945364']
# ['At iteration 5 the best fitness is 0.11608108039945364']
# ['At iteration 6 the best fitness is 0.11608108039945364']
# ['At iteration 7 the best fitness is 0.11608108039945364']
# ['At iteration 8 the best fitness is 0.11608108039945364']
# ['At iteration 9 the best fitness is 0.11608108039945364']
# ['At iteration 10 the best fitness is 0.11608108039945364']
# ['At iteration 11 the best fitness is 0.11608108039945364']
# ['At iteration 12 the best fitness is 0.11608108039945364']
# ['At iteration 13 the best fitness is 0.11608108039945364']
# ['At iteration 14 the best fitness is 0.11608108039945364']
# ['At iteration 15 the best fitness is 0.11608108039945364']
# ['At iteration 16 the best fitness is 0.11608108039945364']
# ['At iteration 17 the best fitness is 0.11608108039945364']
# ['At iteration 18 the best fitness is 0.11608108039945364']
# ['At iteration 19 the best fitness is 0.11608108039945364']
# ['At iteration 20 the best fitness is 0.11608108039945364']
# ['At iteration 21 the best fitness is 0.11608108039945364']
# ['At iteration 22 the best fitness is 0.11608108039945364']
# ['At iteration 23 the best fitness is 0.11608108039945364']
# ['At iteration 24 the best fitness is 0.11608108039945364']
# ['At iteration 25 the best fitness is 0.11608108039945364']
# ['At iteration 26 the best fitness is 0.11608108039945364']
# ['At iteration 27 the best fitness is 0.1063874620012939']
# ['At iteration 28 the best fitness is 0.10183046944439411']
# ['At iteration 29 the best fitness is 0.10183046944439411']
#       Weights: depth=0.972, sensor=0.469, skeleton=0.516, video=0.209
#       Best fitness: 0.101830, Time: 1054.2s
#     Weights: [depth=0.972, sensor=0.469, skeleton=0.516, video=0.209]
#     Test Acc: 97.22%, F1: 97.14%, Model: 9.258MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 4, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.12189594563096762']
# ['At iteration 1 the best fitness is 0.12189594563096762']
# ['At iteration 2 the best fitness is 0.12189594563096762']
# ['At iteration 3 the best fitness is 0.12189594563096762']
# ['At iteration 4 the best fitness is 0.12189594563096762']
# ['At iteration 5 the best fitness is 0.12189594563096762']
# ['At iteration 6 the best fitness is 0.12189594563096762']
# ['At iteration 7 the best fitness is 0.12189594563096762']
# ['At iteration 8 the best fitness is 0.11364024877548218']
# ['At iteration 9 the best fitness is 0.11364024877548218']
# ['At iteration 10 the best fitness is 0.11364024877548218']
# ['At iteration 11 the best fitness is 0.11364024877548218']
# ['At iteration 12 the best fitness is 0.11364024877548218']
# ['At iteration 13 the best fitness is 0.11364024877548218']
# ['At iteration 14 the best fitness is 0.11364024877548218']
# ['At iteration 15 the best fitness is 0.11364024877548218']
# ['At iteration 16 the best fitness is 0.11364024877548218']
# ['At iteration 17 the best fitness is 0.11364024877548218']
# ['At iteration 18 the best fitness is 0.11364024877548218']
# ['At iteration 19 the best fitness is 0.11364024877548218']
# ['At iteration 20 the best fitness is 0.10995759535580873']
# ['At iteration 21 the best fitness is 0.10995759535580873']
# ['At iteration 22 the best fitness is 0.10995759535580873']
# ['At iteration 23 the best fitness is 0.10780778480693698']
# ['At iteration 24 the best fitness is 0.10780778480693698']
# ['At iteration 25 the best fitness is 0.10780778480693698']
# ['At iteration 26 the best fitness is 0.10780778480693698']
# ['At iteration 27 the best fitness is 0.10780778480693698']
# ['At iteration 28 the best fitness is 0.10780778480693698']
# ['At iteration 29 the best fitness is 0.10780778480693698']
#       Weights: depth=0.594, sensor=0.793, skeleton=0.909, video=0.075
#       Best fitness: 0.107808, Time: 631.4s
#     Weights: [depth=0.594, sensor=0.793, skeleton=0.909, video=0.075]
#     Test Acc: 95.37%, F1: 94.20%, Model: 9.258MB
#
#   --- WEIGHTED_MFO ---
#     Running weighted_MFO...
#       Search dim: 4, Pop: 20, Iter: 30
# MFO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.15115929208695889']
# ['At iteration 2 the best fitness is 0.13237611576914787']
# ['At iteration 3 the best fitness is 0.13237611576914787']
# ['At iteration 4 the best fitness is 0.13237611576914787']
# ['At iteration 5 the best fitness is 0.1302572451531887']
# ['At iteration 6 the best fitness is 0.1302572451531887']
# ['At iteration 7 the best fitness is 0.1302572451531887']
# ['At iteration 8 the best fitness is 0.1302572451531887']
# ['At iteration 9 the best fitness is 0.12422500550746918']
# ['At iteration 10 the best fitness is 0.12422500550746918']
# ['At iteration 11 the best fitness is 0.12422500550746918']
# ['At iteration 12 the best fitness is 0.12422500550746918']
# ['At iteration 13 the best fitness is 0.12422500550746918']
# ['At iteration 14 the best fitness is 0.12422500550746918']
# ['At iteration 15 the best fitness is 0.12422500550746918']
# ['At iteration 16 the best fitness is 0.1178634250536561']
# ['At iteration 17 the best fitness is 0.11763129197061062']
# ['At iteration 18 the best fitness is 0.11763129197061062']
# ['At iteration 19 the best fitness is 0.11763129197061062']
# ['At iteration 20 the best fitness is 0.11763129197061062']
# ['At iteration 21 the best fitness is 0.11763129197061062']
# ['At iteration 22 the best fitness is 0.11763129197061062']
# ['At iteration 23 the best fitness is 0.11763129197061062']
# ['At iteration 24 the best fitness is 0.11763129197061062']
# ['At iteration 25 the best fitness is 0.11763129197061062']
# ['At iteration 26 the best fitness is 0.11763129197061062']
# ['At iteration 27 the best fitness is 0.1118245106190443']
# ['At iteration 28 the best fitness is 0.1118245106190443']
# ['At iteration 29 the best fitness is 0.1118245106190443']
#       Weights: depth=0.597, sensor=0.763, skeleton=1.000, video=0.058
#       Best fitness: 0.111825, Time: 826.3s
#     Weights: [depth=0.597, sensor=0.763, skeleton=1.000, video=0.058]
#     Test Acc: 94.44%, F1: 93.64%, Model: 9.258MB
#
#   --- WEIGHTED_MVO ---
#     Running weighted_MVO...
#       Search dim: 4, Pop: 20, Iter: 30
# MVO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.11890704184770584']
# ['At iteration 2 the best fitness is 0.11890704184770584']
# ['At iteration 3 the best fitness is 0.11890704184770584']
# ['At iteration 4 the best fitness is 0.11890704184770584']
# ['At iteration 5 the best fitness is 0.1145898038521409']
# ['At iteration 6 the best fitness is 0.1145898038521409']
# ['At iteration 7 the best fitness is 0.1145898038521409']
# ['At iteration 8 the best fitness is 0.1145898038521409']
# ['At iteration 9 the best fitness is 0.1046372652053833']
# ['At iteration 10 the best fitness is 0.09608533885329962']
# ['At iteration 11 the best fitness is 0.09608533885329962']
# ['At iteration 12 the best fitness is 0.09608533885329962']
# ['At iteration 13 the best fitness is 0.09608533885329962']
# ['At iteration 14 the best fitness is 0.09608533885329962']
# ['At iteration 15 the best fitness is 0.09608533885329962']
# ['At iteration 16 the best fitness is 0.09608533885329962']
# ['At iteration 17 the best fitness is 0.09608533885329962']
# ['At iteration 18 the best fitness is 0.09608533885329962']
# ['At iteration 19 the best fitness is 0.09608533885329962']
# ['At iteration 20 the best fitness is 0.09608533885329962']
# ['At iteration 21 the best fitness is 0.09608533885329962']
# ['At iteration 22 the best fitness is 0.09608533885329962']
# ['At iteration 23 the best fitness is 0.09608533885329962']
# ['At iteration 24 the best fitness is 0.09608533885329962']
# ['At iteration 25 the best fitness is 0.09608533885329962']
# ['At iteration 26 the best fitness is 0.09608533885329962']
# ['At iteration 27 the best fitness is 0.09608533885329962']
# ['At iteration 28 the best fitness is 0.09608533885329962']
# ['At iteration 29 the best fitness is 0.09608533885329962']
# ['At iteration 30 the best fitness is 0.09608533885329962']
#       Weights: depth=0.111, sensor=0.612, skeleton=0.802, video=0.116
#       Best fitness: 0.096085, Time: 881.2s
#     Weights: [depth=0.111, sensor=0.612, skeleton=0.802, video=0.116]
#     Test Acc: 96.30%, F1: 95.06%, Model: 9.258MB
#
#   --- WEIGHTED_PSO ---
#     Running weighted_PSO...
#       Search dim: 4, Pop: 20, Iter: 30
# PSO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.14075755700469017']
# ['At iteration 2 the best fitness is 0.13392650708556175']
# ['At iteration 3 the best fitness is 0.13317752443253994']
# ['At iteration 4 the best fitness is 0.11229374911636114']
# ['At iteration 5 the best fitness is 0.11229374911636114']
# ['At iteration 6 the best fitness is 0.11229374911636114']
# ['At iteration 7 the best fitness is 0.11229374911636114']
# ['At iteration 8 the best fitness is 0.11229374911636114']
# ['At iteration 9 the best fitness is 0.11229374911636114']
# ['At iteration 10 the best fitness is 0.11229374911636114']
# ['At iteration 11 the best fitness is 0.11229374911636114']
# ['At iteration 12 the best fitness is 0.10558781493455172']
# ['At iteration 13 the best fitness is 0.10558781493455172']
# ['At iteration 14 the best fitness is 0.10558781493455172']
# ['At iteration 15 the best fitness is 0.10558781493455172']
# ['At iteration 16 the best fitness is 0.10558781493455172']
# ['At iteration 17 the best fitness is 0.10558781493455172']
# ['At iteration 18 the best fitness is 0.10558781493455172']
# ['At iteration 19 the best fitness is 0.10558781493455172']
# ['At iteration 20 the best fitness is 0.10558781493455172']
# ['At iteration 21 the best fitness is 0.10521713737398386']
# ['At iteration 22 the best fitness is 0.10521713737398386']
# ['At iteration 23 the best fitness is 0.10521713737398386']
# ['At iteration 24 the best fitness is 0.10521713737398386']
# ['At iteration 25 the best fitness is 0.10521713737398386']
# ['At iteration 26 the best fitness is 0.10521713737398386']
# ['At iteration 27 the best fitness is 0.10201403498649597']
# ['At iteration 28 the best fitness is 0.10201403498649597']
# ['At iteration 29 the best fitness is 0.10201403498649597']
# ['At iteration 30 the best fitness is 0.10201403498649597']
#       Weights: depth=0.065, sensor=0.251, skeleton=0.272, video=0.000
#       Best fitness: 0.102014, Time: 841.5s
#     Weights: [depth=0.065, sensor=0.251, skeleton=0.272, video=0.000]
#     Test Acc: 94.44%, F1: 93.83%, Model: 9.258MB
#
#   --- WEIGHTED_SCA ---
#     Running weighted_SCA...
#       Search dim: 4, Pop: 20, Iter: 30
# SCA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.14809062704443932']
# ['At iteration 1 the best fitness is 0.1272169640287757']
# ['At iteration 2 the best fitness is 0.1272169640287757']
# ['At iteration 3 the best fitness is 0.1272169640287757']
# ['At iteration 4 the best fitness is 0.1272169640287757']
# ['At iteration 5 the best fitness is 0.1272169640287757']
# ['At iteration 6 the best fitness is 0.1272169640287757']
# ['At iteration 7 the best fitness is 0.10764927696436644']
# ['At iteration 8 the best fitness is 0.10764927696436644']
# ['At iteration 9 the best fitness is 0.10764927696436644']
# ['At iteration 10 the best fitness is 0.10764927696436644']
# ['At iteration 11 the best fitness is 0.10764927696436644']
# ['At iteration 12 the best fitness is 0.10764927696436644']
# ['At iteration 13 the best fitness is 0.10764927696436644']
# ['At iteration 14 the best fitness is 0.10764927696436644']
# ['At iteration 15 the best fitness is 0.10764927696436644']
# ['At iteration 16 the best fitness is 0.10764927696436644']
# ['At iteration 17 the best fitness is 0.10764927696436644']
# ['At iteration 18 the best fitness is 0.10764927696436644']
# ['At iteration 19 the best fitness is 0.10764927696436644']
# ['At iteration 20 the best fitness is 0.10764927696436644']
# ['At iteration 21 the best fitness is 0.10764927696436644']
# ['At iteration 22 the best fitness is 0.10764927696436644']
# ['At iteration 23 the best fitness is 0.10764927696436644']
# ['At iteration 24 the best fitness is 0.10764927696436644']
# ['At iteration 25 the best fitness is 0.10764927696436644']
# ['At iteration 26 the best fitness is 0.10764927696436644']
# ['At iteration 27 the best fitness is 0.10764927696436644']
# ['At iteration 28 the best fitness is 0.10764927696436644']
# ['At iteration 29 the best fitness is 0.10764927696436644']
#       Weights: depth=0.051, sensor=1.000, skeleton=0.837, video=0.000
#       Best fitness: 0.107649, Time: 882.8s
#     Weights: [depth=0.051, sensor=1.000, skeleton=0.837, video=0.000]
#     Test Acc: 95.37%, F1: 94.53%, Model: 9.258MB
#
#   --- WEIGHTED_SSA ---
#     Running weighted_SSA...
#       Search dim: 4, Pop: 20, Iter: 30
# SSA is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.11994350142776966']
# ['At iteration 2 the best fitness is 0.11994350142776966']
# ['At iteration 3 the best fitness is 0.11994350142776966']
# ['At iteration 4 the best fitness is 0.11994350142776966']
# ['At iteration 5 the best fitness is 0.11562158912420273']
# ['At iteration 6 the best fitness is 0.11562158912420273']
# ['At iteration 7 the best fitness is 0.10899544972926378']
# ['At iteration 8 the best fitness is 0.10899544972926378']
# ['At iteration 9 the best fitness is 0.10899544972926378']
# ['At iteration 10 the best fitness is 0.10899544972926378']
# ['At iteration 11 the best fitness is 0.10086309630423784']
# ['At iteration 12 the best fitness is 0.10086309630423784']
# ['At iteration 13 the best fitness is 0.10086309630423784']
# ['At iteration 14 the best fitness is 0.10086309630423784']
# ['At iteration 15 the best fitness is 0.10086309630423784']
# ['At iteration 16 the best fitness is 0.10086309630423784']
# ['At iteration 17 the best fitness is 0.10086309630423784']
# ['At iteration 18 the best fitness is 0.10086309630423784']
# ['At iteration 19 the best fitness is 0.10086309630423784']
# ['At iteration 20 the best fitness is 0.09899562411010265']
# ['At iteration 21 the best fitness is 0.09899562411010265']
# ['At iteration 22 the best fitness is 0.09899562411010265']
# ['At iteration 23 the best fitness is 0.09899562411010265']
# ['At iteration 24 the best fitness is 0.09899562411010265']
# ['At iteration 25 the best fitness is 0.09899562411010265']
# ['At iteration 26 the best fitness is 0.09899562411010265']
# ['At iteration 27 the best fitness is 0.09899562411010265']
# ['At iteration 28 the best fitness is 0.09878373704850674']
# ['At iteration 29 the best fitness is 0.09878373704850674']
#       Weights: depth=0.995, sensor=0.400, skeleton=1.000, video=0.001
#       Best fitness: 0.098784, Time: 2206.4s
#     Weights: [depth=0.995, sensor=0.400, skeleton=1.000, video=0.001]
#     Test Acc: 95.37%, F1: 95.47%, Model: 9.258MB
#
#   --- WEIGHTED_WOA ---
#     Running weighted_WOA...
#       Search dim: 4, Pop: 20, Iter: 30
# WOA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.13855174835771322']
# ['At iteration 1 the best fitness is 0.11228058207780123']
# ['At iteration 2 the best fitness is 0.11228058207780123']
# ['At iteration 3 the best fitness is 0.11228058207780123']
# ['At iteration 4 the best fitness is 0.10435118712484837']
# ['At iteration 5 the best fitness is 0.10435118712484837']
# ['At iteration 6 the best fitness is 0.10435118712484837']
# ['At iteration 7 the best fitness is 0.10435118712484837']
# ['At iteration 8 the best fitness is 0.10435118712484837']
# ['At iteration 9 the best fitness is 0.10435118712484837']
# ['At iteration 10 the best fitness is 0.10165602806955576']
# ['At iteration 11 the best fitness is 0.10165602806955576']
# ['At iteration 12 the best fitness is 0.10165602806955576']
# ['At iteration 13 the best fitness is 0.10165602806955576']
# ['At iteration 14 the best fitness is 0.10165602806955576']
# ['At iteration 15 the best fitness is 0.10165602806955576']
# ['At iteration 16 the best fitness is 0.10165602806955576']
# ['At iteration 17 the best fitness is 0.10165602806955576']
# ['At iteration 18 the best fitness is 0.10165602806955576']
# ['At iteration 19 the best fitness is 0.10165602806955576']
# ['At iteration 20 the best fitness is 0.10165602806955576']
# ['At iteration 21 the best fitness is 0.10165602806955576']
# ['At iteration 22 the best fitness is 0.10165602806955576']
# ['At iteration 23 the best fitness is 0.10165602806955576']
# ['At iteration 24 the best fitness is 0.10165602806955576']
# ['At iteration 25 the best fitness is 0.10165602806955576']
# ['At iteration 26 the best fitness is 0.10165602806955576']
# ['At iteration 27 the best fitness is 0.10165602806955576']
# ['At iteration 28 the best fitness is 0.10165602806955576']
# ['At iteration 29 the best fitness is 0.10165602806955576']
#       Weights: depth=0.000, sensor=0.867, skeleton=0.798, video=0.000
#       Best fitness: 0.101656, Time: 883.1s
#     Weights: [depth=0.000, sensor=0.867, skeleton=0.798, video=0.000]
#     Test Acc: 95.37%, F1: 94.61%, Model: 9.258MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Test subject : [5]
#   Val  subject : 8
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000, video=1.000]
#     Test Acc: 90.74%, F1: 88.15%, Model: 9.258MB
#
#   --- WEIGHTED_BAT ---
#     Running weighted_BAT...
#       Search dim: 4, Pop: 20, Iter: 30
# BAT is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.11278279311954975']
# ['At iteration 1 the best fitness is 0.111324368044734']
# ['At iteration 2 the best fitness is 0.111324368044734']
# ['At iteration 3 the best fitness is 0.10434749769046903']
# ['At iteration 4 the best fitness is 0.10434749769046903']
# ['At iteration 5 the best fitness is 0.10434749769046903']
# ['At iteration 6 the best fitness is 0.10434749769046903']
# ['At iteration 7 the best fitness is 0.10434749769046903']
# ['At iteration 8 the best fitness is 0.10434749769046903']
# ['At iteration 9 the best fitness is 0.10434749769046903']
# ['At iteration 10 the best fitness is 0.10434749769046903']
# ['At iteration 11 the best fitness is 0.10434749769046903']
# ['At iteration 12 the best fitness is 0.10434749769046903']
# ['At iteration 13 the best fitness is 0.10434749769046903']
# ['At iteration 14 the best fitness is 0.10434749769046903']
# ['At iteration 15 the best fitness is 0.10434749769046903']
# ['At iteration 16 the best fitness is 0.0999782420694828']
# ['At iteration 17 the best fitness is 0.0999782420694828']
# ['At iteration 18 the best fitness is 0.0999782420694828']
# ['At iteration 19 the best fitness is 0.0999782420694828']
# ['At iteration 20 the best fitness is 0.0999782420694828']
# ['At iteration 21 the best fitness is 0.0999782420694828']
# ['At iteration 22 the best fitness is 0.0999782420694828']
# ['At iteration 23 the best fitness is 0.0999782420694828']
# ['At iteration 24 the best fitness is 0.0999782420694828']
# ['At iteration 25 the best fitness is 0.0999782420694828']
# ['At iteration 26 the best fitness is 0.0999782420694828']
# ['At iteration 27 the best fitness is 0.0999782420694828']
# ['At iteration 28 the best fitness is 0.0999782420694828']
# ['At iteration 29 the best fitness is 0.0999782420694828']
#       Weights: depth=0.000, sensor=1.000, skeleton=1.000, video=0.000
#       Best fitness: 0.099978, Time: 912.7s
#     Weights: [depth=0.000, sensor=1.000, skeleton=1.000, video=0.000]
#     Test Acc: 91.67%, F1: 89.00%, Model: 9.258MB
#
#   --- WEIGHTED_CS ---
#     Running weighted_CS...
#       Search dim: 4, Pop: 20, Iter: 30
# CS is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.11728283949196339']
# ['At iteration 1 the best fitness is 0.11728283949196339']
# ['At iteration 2 the best fitness is 0.11728283949196339']
# ['At iteration 3 the best fitness is 0.11525984108448029']
# ['At iteration 4 the best fitness is 0.11525984108448029']
# ['At iteration 5 the best fitness is 0.11525984108448029']
# ['At iteration 6 the best fitness is 0.11525984108448029']
# ['At iteration 7 the best fitness is 0.11525984108448029']
# ['At iteration 8 the best fitness is 0.10184985492378473']
# ['At iteration 9 the best fitness is 0.10184985492378473']
# ['At iteration 10 the best fitness is 0.10184985492378473']
# ['At iteration 11 the best fitness is 0.10184985492378473']
# ['At iteration 12 the best fitness is 0.10184985492378473']
# ['At iteration 13 the best fitness is 0.10184985492378473']
# ['At iteration 14 the best fitness is 0.10184985492378473']
# ['At iteration 15 the best fitness is 0.10184985492378473']
# ['At iteration 16 the best fitness is 0.10184985492378473']
# ['At iteration 17 the best fitness is 0.10184985492378473']
# ['At iteration 18 the best fitness is 0.10184985492378473']
# ['At iteration 19 the best fitness is 0.10184985492378473']
# ['At iteration 20 the best fitness is 0.10184985492378473']
# ['At iteration 21 the best fitness is 0.10184985492378473']
# ['At iteration 22 the best fitness is 0.10184985492378473']
# ['At iteration 23 the best fitness is 0.10184985492378473']
# ['At iteration 24 the best fitness is 0.10184985492378473']
# ['At iteration 25 the best fitness is 0.10184985492378473']
# ['At iteration 26 the best fitness is 0.10184985492378473']
# ['At iteration 27 the best fitness is 0.10184985492378473']
# ['At iteration 28 the best fitness is 0.10184985492378473']
# ['At iteration 29 the best fitness is 0.10184985492378473']
#       Weights: depth=0.414, sensor=0.223, skeleton=0.187, video=0.000
#       Best fitness: 0.101850, Time: 1794.4s
#     Weights: [depth=0.414, sensor=0.223, skeleton=0.187, video=0.000]
#     Test Acc: 89.81%, F1: 87.21%, Model: 9.258MB
#
#   --- WEIGHTED_DE ---
#     Running weighted_DE...
#       Search dim: 4, Pop: 20, Iter: 30
# DE is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.13192965649068356']
# ['At iteration 2 the best fitness is 0.13192965649068356']
# ['At iteration 3 the best fitness is 0.13192965649068356']
# ['At iteration 4 the best fitness is 0.12945753149688244']
# ['At iteration 5 the best fitness is 0.12833521235734224']
# ['At iteration 6 the best fitness is 0.12833521235734224']
# ['At iteration 7 the best fitness is 0.12833521235734224']
# ['At iteration 8 the best fitness is 0.12833521235734224']
# ['At iteration 9 the best fitness is 0.12774304021149874']
# ['At iteration 10 the best fitness is 0.12774304021149874']
# ['At iteration 11 the best fitness is 0.12774304021149874']
# ['At iteration 12 the best fitness is 0.11218564677983522']
# ['At iteration 13 the best fitness is 0.11218564677983522']
# ['At iteration 14 the best fitness is 0.10634180950000882']
# ['At iteration 15 the best fitness is 0.10634180950000882']
# ['At iteration 16 the best fitness is 0.10634180950000882']
# ['At iteration 17 the best fitness is 0.10634180950000882']
# ['At iteration 18 the best fitness is 0.10634180950000882']
# ['At iteration 19 the best fitness is 0.10634180950000882']
# ['At iteration 20 the best fitness is 0.10634180950000882']
# ['At iteration 21 the best fitness is 0.10634180950000882']
# ['At iteration 22 the best fitness is 0.10634180950000882']
# ['At iteration 23 the best fitness is 0.10634180950000882']
# ['At iteration 24 the best fitness is 0.10634180950000882']
# ['At iteration 25 the best fitness is 0.10634180950000882']
# ['At iteration 26 the best fitness is 0.10634180950000882']
# ['At iteration 27 the best fitness is 0.10634180950000882']
# ['At iteration 28 the best fitness is 0.10634180950000882']
# ['At iteration 29 the best fitness is 0.10634180950000882']
# ['At iteration 30 the best fitness is 0.10634180950000882']
#       Weights: depth=0.822, sensor=0.819, skeleton=1.000, video=0.000
#       Best fitness: 0.106342, Time: 914.2s
#     Weights: [depth=0.822, sensor=0.819, skeleton=1.000, video=0.000]
#     Test Acc: 91.67%, F1: 89.98%, Model: 9.258MB
#
#   --- WEIGHTED_FFA ---
#     Running weighted_FFA...
#       Search dim: 4, Pop: 20, Iter: 30
# FFA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.16094649955630302']
# ['At iteration 1 the best fitness is 0.13309272937476635']
# ['At iteration 2 the best fitness is 0.12304113246500492']
# ['At iteration 3 the best fitness is 0.12451855279505253']
# ['At iteration 4 the best fitness is 0.12448422890156507']
# ['At iteration 5 the best fitness is 0.134230500087142']
# ['At iteration 6 the best fitness is 0.1246893722563982']
# ['At iteration 7 the best fitness is 0.13417647033929825']
# ['At iteration 8 the best fitness is 0.13081516046077013']
# ['At iteration 9 the best fitness is 0.12662064004689455']
# ['At iteration 10 the best fitness is 0.1288079358637333']
# ['At iteration 11 the best fitness is 0.13047791086137295']
# ['At iteration 12 the best fitness is 0.13043876830488443']
# ['At iteration 13 the best fitness is 0.13629781547933817']
# ['At iteration 14 the best fitness is 0.13861507456749678']
# ['At iteration 15 the best fitness is 0.13245661463588476']
# ['At iteration 16 the best fitness is 0.12833357322961092']
# ['At iteration 17 the best fitness is 0.11701722629368305']
# ['At iteration 18 the best fitness is 0.11801553005352616']
# ['At iteration 19 the best fitness is 0.128486561588943']
# ['At iteration 20 the best fitness is 0.12217429373413324']
# ['At iteration 21 the best fitness is 0.12133483402431011']
# ['At iteration 22 the best fitness is 0.1371093224734068']
# ['At iteration 23 the best fitness is 0.13479760754853487']
# ['At iteration 24 the best fitness is 0.1289869761094451']
# ['At iteration 25 the best fitness is 0.13386838044971228']
# ['At iteration 26 the best fitness is 0.12417607102543116']
# ['At iteration 27 the best fitness is 0.15020093508064747']
# ['At iteration 28 the best fitness is 0.13912994414567947']
# ['At iteration 29 the best fitness is 0.13051521684974432']
#       Weights: depth=0.182, sensor=0.958, skeleton=0.920, video=0.350
#       Best fitness: 0.130515, Time: 679.2s
#     Weights: [depth=0.182, sensor=0.958, skeleton=0.920, video=0.350]
#     Test Acc: 91.67%, F1: 89.71%, Model: 9.258MB
#
#   --- WEIGHTED_GA ---
#     Running weighted_GA...
#       Search dim: 4, Pop: 20, Iter: 30
# GA is optimizing  "fitness"
# At iteration 1 the best fitness is 0.12247831653803587
# At iteration 2 the best fitness is 0.123738176189363
# At iteration 3 the best fitness is 0.14989676512777805
# At iteration 4 the best fitness is 0.12928573973476887
# At iteration 5 the best fitness is 0.13312843721359968
# At iteration 6 the best fitness is 0.1217187438160181
# At iteration 7 the best fitness is 0.13733846135437489
# At iteration 8 the best fitness is 0.12951336987316608
# At iteration 9 the best fitness is 0.07263808604329824
# At iteration 10 the best fitness is 0.12436295114457607
# At iteration 11 the best fitness is 0.13035237696021795
# At iteration 12 the best fitness is 0.11165919341146946
# At iteration 13 the best fitness is 0.13677671365439892
# At iteration 14 the best fitness is 0.12494814675301313
# At iteration 15 the best fitness is 0.13405084051191807
# At iteration 16 the best fitness is 0.11978447157889605
# At iteration 17 the best fitness is 0.1306514646857977
# At iteration 18 the best fitness is 0.14092808309942484
# At iteration 19 the best fitness is 0.13142212387174368
# At iteration 20 the best fitness is 0.10032715182751417
# At iteration 21 the best fitness is 0.11933383997529745
# At iteration 22 the best fitness is 0.1425315896049142
# At iteration 23 the best fitness is 0.1303666951134801
# At iteration 24 the best fitness is 0.12382211536169052
# At iteration 25 the best fitness is 0.13978679664433002
# At iteration 26 the best fitness is 0.13038669805973768
# At iteration 27 the best fitness is 0.13318597711622715
# At iteration 28 the best fitness is 0.13063832093030214
# At iteration 29 the best fitness is 0.1288561001420021
# At iteration 30 the best fitness is 0.1361087430268526
#       Weights: depth=0.392, sensor=0.986, skeleton=0.768, video=0.119
#       Best fitness: 0.136109, Time: 646.3s
#     Weights: [depth=0.392, sensor=0.986, skeleton=0.768, video=0.119]
#     Test Acc: 93.52%, F1: 91.69%, Model: 9.258MB
#
#   --- WEIGHTED_GWO ---
#     Running weighted_GWO...
#       Search dim: 4, Pop: 20, Iter: 30
# GWO is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.1465660622343421']
# ['At iteration 1 the best fitness is 0.1269973972812295']
# ['At iteration 2 the best fitness is 0.10818074271082878']
# ['At iteration 3 the best fitness is 0.10818074271082878']
# ['At iteration 4 the best fitness is 0.10818074271082878']
# ['At iteration 5 the best fitness is 0.10818074271082878']
# ['At iteration 6 the best fitness is 0.10818074271082878']
# ['At iteration 7 the best fitness is 0.10818074271082878']
# ['At iteration 8 the best fitness is 0.10818074271082878']
# ['At iteration 9 the best fitness is 0.10818074271082878']
# ['At iteration 10 the best fitness is 0.10818074271082878']
# ['At iteration 11 the best fitness is 0.10818074271082878']
# ['At iteration 12 the best fitness is 0.10818074271082878']
# ['At iteration 13 the best fitness is 0.10818074271082878']
# ['At iteration 14 the best fitness is 0.10818074271082878']
# ['At iteration 15 the best fitness is 0.10818074271082878']
# ['At iteration 16 the best fitness is 0.10818074271082878']
# ['At iteration 17 the best fitness is 0.10691157542169094']
# ['At iteration 18 the best fitness is 0.10691157542169094']
# ['At iteration 19 the best fitness is 0.10691157542169094']
# ['At iteration 20 the best fitness is 0.10691157542169094']
# ['At iteration 21 the best fitness is 0.10691157542169094']
# ['At iteration 22 the best fitness is 0.10691157542169094']
# ['At iteration 23 the best fitness is 0.10691157542169094']
# ['At iteration 24 the best fitness is 0.10691157542169094']
# ['At iteration 25 the best fitness is 0.10691157542169094']
# ['At iteration 26 the best fitness is 0.10691157542169094']
# ['At iteration 27 the best fitness is 0.10691157542169094']
# ['At iteration 28 the best fitness is 0.10691157542169094']
# ['At iteration 29 the best fitness is 0.10691157542169094']
#       Weights: depth=0.727, sensor=1.000, skeleton=0.645, video=0.130
#       Best fitness: 0.106912, Time: 645.8s
#     Weights: [depth=0.727, sensor=1.000, skeleton=0.645, video=0.130]
#     Test Acc: 92.59%, F1: 90.89%, Model: 9.258MB
#
#   --- WEIGHTED_HHO ---
#     Running weighted_HHO...
#       Search dim: 4, Pop: 20, Iter: 30
# HHO is now tackling  "fitness"
# ['At iteration 0 the best fitness is 0.15633486304432154']
# ['At iteration 1 the best fitness is 0.1387337762862444']
# ['At iteration 2 the best fitness is 0.1061551682651043']
# ['At iteration 3 the best fitness is 0.1061551682651043']
# ['At iteration 4 the best fitness is 0.1061551682651043']
# ['At iteration 5 the best fitness is 0.1061551682651043']
# ['At iteration 6 the best fitness is 0.1061551682651043']
# ['At iteration 7 the best fitness is 0.1061551682651043']
# ['At iteration 8 the best fitness is 0.1061551682651043']
# ['At iteration 9 the best fitness is 0.1061551682651043']
# ['At iteration 10 the best fitness is 0.1061551682651043']
# ['At iteration 11 the best fitness is 0.1061551682651043']
# ['At iteration 12 the best fitness is 0.1061551682651043']
# ['At iteration 13 the best fitness is 0.1061551682651043']
# ['At iteration 14 the best fitness is 0.1061551682651043']
# ['At iteration 15 the best fitness is 0.1061551682651043']
# ['At iteration 16 the best fitness is 0.1061551682651043']
# ['At iteration 17 the best fitness is 0.1061551682651043']
# ['At iteration 18 the best fitness is 0.1061551682651043']
# ['At iteration 19 the best fitness is 0.1061551682651043']
# ['At iteration 20 the best fitness is 0.1061551682651043']
# ['At iteration 21 the best fitness is 0.1061551682651043']
# ['At iteration 22 the best fitness is 0.1061551682651043']
# ['At iteration 23 the best fitness is 0.10060254344716668']
# ['At iteration 24 the best fitness is 0.10060254344716668']
# ['At iteration 25 the best fitness is 0.10060254344716668']
# ['At iteration 26 the best fitness is 0.10060254344716668']
# ['At iteration 27 the best fitness is 0.10060254344716668']
# ['At iteration 28 the best fitness is 0.10060254344716668']
# ['At iteration 29 the best fitness is 0.10060254344716668']
#       Weights: depth=0.002, sensor=0.107, skeleton=0.066, video=0.000
#       Best fitness: 0.100603, Time: 1124.8s
#     Weights: [depth=0.002, sensor=0.107, skeleton=0.066, video=0.000]
#     Test Acc: 92.59%, F1: 90.70%, Model: 9.258MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 4, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.11192605271935463']
# ['At iteration 1 the best fitness is 0.11192605271935463']
# ['At iteration 2 the best fitness is 0.11192605271935463']
# ['At iteration 3 the best fitness is 0.11192605271935463']
# ['At iteration 4 the best fitness is 0.11192605271935463']
# ['At iteration 5 the best fitness is 0.09995860978960991']
# ['At iteration 6 the best fitness is 0.09995860978960991']
# ['At iteration 7 the best fitness is 0.09995860978960991']
# ['At iteration 8 the best fitness is 0.09995860978960991']
# ['At iteration 9 the best fitness is 0.09995860978960991']
# ['At iteration 10 the best fitness is 0.09995860978960991']
# ['At iteration 11 the best fitness is 0.09995860978960991']
# ['At iteration 12 the best fitness is 0.09995860978960991']
# ['At iteration 13 the best fitness is 0.09995860978960991']
# ['At iteration 14 the best fitness is 0.09995860978960991']
# ['At iteration 15 the best fitness is 0.09995860978960991']
# ['At iteration 16 the best fitness is 0.09995860978960991']
# ['At iteration 17 the best fitness is 0.09995860978960991']
# ['At iteration 18 the best fitness is 0.09147805813699961']
# ['At iteration 19 the best fitness is 0.09147805813699961']
# ['At iteration 20 the best fitness is 0.09147805813699961']
# ['At iteration 21 the best fitness is 0.09147805813699961']
# ['At iteration 22 the best fitness is 0.09147805813699961']
# ['At iteration 23 the best fitness is 0.09147805813699961']
# ['At iteration 24 the best fitness is 0.09147805813699961']
# ['At iteration 25 the best fitness is 0.09147805813699961']
# ['At iteration 26 the best fitness is 0.09147805813699961']
# ['At iteration 27 the best fitness is 0.09147805813699961']
# ['At iteration 28 the best fitness is 0.09147805813699961']
# ['At iteration 29 the best fitness is 0.09147805813699961']
#       Weights: depth=0.970, sensor=0.692, skeleton=0.858, video=0.013
#       Best fitness: 0.091478, Time: 825.6s
#     Weights: [depth=0.970, sensor=0.692, skeleton=0.858, video=0.013]
# ...
# ['At iteration 18 the best fitness is 0.11051567364484072']
# ['At iteration 19 the best fitness is 0.11051567364484072']
# ['At iteration 20 the best fitness is 0.11051567364484072']
# ['At iteration 21 the best fitness is 0.11051567364484072']
# ['At iteration 22 the best fitness is 0.11051567364484072']
# ['At iteration 23 the best fitness is 0.11051567364484072']
# ['At iteration 24 the best fitness is 0.11051567364484072']
# ['At iteration 25 the best fitness is 0.11051567364484072']
# ['At iteration 26 the best fitness is 0.11051567364484072']
# ['At iteration 27 the best fitness is 0.10328032914549112']
# ['At iteration 28 the best fitness is 0.10328032914549112']
# ['At iteration 29 the best fitness is 0.10328032914549112']
#       Weights: depth=0.564, sensor=0.859, skeleton=0.618, video=0.045
#       Best fitness: 0.103280, Time: 1121.4s
#     Weights: [depth=0.564, sensor=0.859, skeleton=0.618, video=0.045]
#     Test Acc: 100.00%, F1: 100.00%, Model: 9.258MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 4, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.11929592676460743']
# ['At iteration 1 the best fitness is 0.11761319730430841']
# ['At iteration 2 the best fitness is 0.11761319730430841']
# ['At iteration 3 the best fitness is 0.11761319730430841']
# ['At iteration 4 the best fitness is 0.11023848690092564']
# ['At iteration 5 the best fitness is 0.11023848690092564']
# ['At iteration 6 the best fitness is 0.11023848690092564']
# ['At iteration 7 the best fitness is 0.11023848690092564']
# ['At iteration 8 the best fitness is 0.1064174622297287']
# ['At iteration 9 the best fitness is 0.1064174622297287']
# ['At iteration 10 the best fitness is 0.1064174622297287']
# ['At iteration 11 the best fitness is 0.1064174622297287']
# ['At iteration 12 the best fitness is 0.1064174622297287']
# ['At iteration 13 the best fitness is 0.1064174622297287']
# ['At iteration 14 the best fitness is 0.1064174622297287']
# ['At iteration 15 the best fitness is 0.1064174622297287']
# ['At iteration 16 the best fitness is 0.1064174622297287']
# ['At iteration 17 the best fitness is 0.1064174622297287']
# ['At iteration 18 the best fitness is 0.1064174622297287']
# ['At iteration 19 the best fitness is 0.1064174622297287']
# ['At iteration 20 the best fitness is 0.1064174622297287']
# ['At iteration 21 the best fitness is 0.1064174622297287']
# ['At iteration 22 the best fitness is 0.1064174622297287']
# ['At iteration 23 the best fitness is 0.1056798417121172']
# ['At iteration 24 the best fitness is 0.1056798417121172']
# ['At iteration 25 the best fitness is 0.1056798417121172']
# ['At iteration 26 the best fitness is 0.1056798417121172']
# ['At iteration 27 the best fitness is 0.1056798417121172']
# ['At iteration 28 the best fitness is 0.1056798417121172']
# ['At iteration 29 the best fitness is 0.1056798417121172']
#       Weights: depth=0.713, sensor=0.409, skeleton=0.611, video=0.122
#       Best fitness: 0.105680, Time: 817.8s
#     Weights: [depth=0.713, sensor=0.409, skeleton=0.611, video=0.122]
#     Test Acc: 100.00%, F1: 100.00%, Model: 9.258MB
#
#   --- WEIGHTED_MFO ---
#     Running weighted_MFO...
#       Search dim: 4, Pop: 20, Iter: 30
# MFO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.11647345870733261']
# ['At iteration 2 the best fitness is 0.11647345870733261']
# ['At iteration 3 the best fitness is 0.11647345870733261']
# ['At iteration 4 the best fitness is 0.11647345870733261']
# ['At iteration 5 the best fitness is 0.11647345870733261']
# ['At iteration 6 the best fitness is 0.11647345870733261']
# ['At iteration 7 the best fitness is 0.11647345870733261']
# ['At iteration 8 the best fitness is 0.11647345870733261']
# ['At iteration 9 the best fitness is 0.11647345870733261']
# ['At iteration 10 the best fitness is 0.11647345870733261']
# ['At iteration 11 the best fitness is 0.11647345870733261']
# ['At iteration 12 the best fitness is 0.11611192673444748']
# ['At iteration 13 the best fitness is 0.11611192673444748']
# ['At iteration 14 the best fitness is 0.09651452861726284']
# ['At iteration 15 the best fitness is 0.09651452861726284']
# ['At iteration 16 the best fitness is 0.09651452861726284']
# ['At iteration 17 the best fitness is 0.09651452861726284']
# ['At iteration 18 the best fitness is 0.09651452861726284']
# ['At iteration 19 the best fitness is 0.09651452861726284']
# ['At iteration 20 the best fitness is 0.09651452861726284']
# ['At iteration 21 the best fitness is 0.09651452861726284']
# ['At iteration 22 the best fitness is 0.09651452861726284']
# ['At iteration 23 the best fitness is 0.09651452861726284']
# ['At iteration 24 the best fitness is 0.09651452861726284']
# ['At iteration 25 the best fitness is 0.09651452861726284']
# ['At iteration 26 the best fitness is 0.09651452861726284']
# ['At iteration 27 the best fitness is 0.09651452861726284']
# ['At iteration 28 the best fitness is 0.09651452861726284']
# ['At iteration 29 the best fitness is 0.09651452861726284']
#       Weights: depth=1.000, sensor=1.000, skeleton=0.695, video=0.013
#       Best fitness: 0.096515, Time: 779.2s
#     Weights: [depth=1.000, sensor=1.000, skeleton=0.695, video=0.013]
#     Test Acc: 98.13%, F1: 98.00%, Model: 9.258MB
#
#   --- WEIGHTED_MVO ---
#     Running weighted_MVO...
#       Search dim: 4, Pop: 20, Iter: 30
# MVO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.1397251281887293']
# ['At iteration 2 the best fitness is 0.1397251281887293']
# ['At iteration 3 the best fitness is 0.1397251281887293']
# ['At iteration 4 the best fitness is 0.1215071463957429']
# ['At iteration 5 the best fitness is 0.11117927357554436']
# ['At iteration 6 the best fitness is 0.11117927357554436']
# ['At iteration 7 the best fitness is 0.11117927357554436']
# ['At iteration 8 the best fitness is 0.11117927357554436']
# ['At iteration 9 the best fitness is 0.11117927357554436']
# ['At iteration 10 the best fitness is 0.11117927357554436']
# ['At iteration 11 the best fitness is 0.11117927357554436']
# ['At iteration 12 the best fitness is 0.11052223388105631']
# ['At iteration 13 the best fitness is 0.11052223388105631']
# ['At iteration 14 the best fitness is 0.11052223388105631']
# ['At iteration 15 the best fitness is 0.11052223388105631']
# ['At iteration 16 the best fitness is 0.11052223388105631']
# ['At iteration 17 the best fitness is 0.11052223388105631']
# ['At iteration 18 the best fitness is 0.11052223388105631']
# ['At iteration 19 the best fitness is 0.11052223388105631']
# ['At iteration 20 the best fitness is 0.11052223388105631']
# ['At iteration 21 the best fitness is 0.11052223388105631']
# ['At iteration 22 the best fitness is 0.11052223388105631']
# ['At iteration 23 the best fitness is 0.11052223388105631']
# ['At iteration 24 the best fitness is 0.11052223388105631']
# ['At iteration 25 the best fitness is 0.10599688440561295']
# ['At iteration 26 the best fitness is 0.10599688440561295']
# ['At iteration 27 the best fitness is 0.10599688440561295']
# ['At iteration 28 the best fitness is 0.10599688440561295']
# ['At iteration 29 the best fitness is 0.10599688440561295']
# ['At iteration 30 the best fitness is 0.10599688440561295']
#       Weights: depth=0.781, sensor=0.571, skeleton=0.526, video=0.012
#       Best fitness: 0.105997, Time: 817.7s
#     Weights: [depth=0.781, sensor=0.571, skeleton=0.526, video=0.012]
#     Test Acc: 100.00%, F1: 100.00%, Model: 9.258MB
#
#   --- WEIGHTED_PSO ---
#     Running weighted_PSO...
#       Search dim: 4, Pop: 20, Iter: 30
# PSO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.13766376301646233']
# ['At iteration 2 the best fitness is 0.10886240564286709']
# ['At iteration 3 the best fitness is 0.10886240564286709']
# ['At iteration 4 the best fitness is 0.10886240564286709']
# ['At iteration 5 the best fitness is 0.10886240564286709']
# ['At iteration 6 the best fitness is 0.10886240564286709']
# ['At iteration 7 the best fitness is 0.10886240564286709']
# ['At iteration 8 the best fitness is 0.10886240564286709']
# ['At iteration 9 the best fitness is 0.10886240564286709']
# ['At iteration 10 the best fitness is 0.10886240564286709']
# ['At iteration 11 the best fitness is 0.10886240564286709']
# ['At iteration 12 the best fitness is 0.10886240564286709']
# ['At iteration 13 the best fitness is 0.10886240564286709']
# ['At iteration 14 the best fitness is 0.10886240564286709']
# ['At iteration 15 the best fitness is 0.10886240564286709']
# ['At iteration 16 the best fitness is 0.10886240564286709']
# ['At iteration 17 the best fitness is 0.10886240564286709']
# ['At iteration 18 the best fitness is 0.10886240564286709']
# ['At iteration 19 the best fitness is 0.10886240564286709']
# ['At iteration 20 the best fitness is 0.10886240564286709']
# ['At iteration 21 the best fitness is 0.10886240564286709']
# ['At iteration 22 the best fitness is 0.10886240564286709']
# ['At iteration 23 the best fitness is 0.10443796869367361']
# ['At iteration 24 the best fitness is 0.10443796869367361']
# ['At iteration 25 the best fitness is 0.10443796869367361']
# ['At iteration 26 the best fitness is 0.10443796869367361']
# ['At iteration 27 the best fitness is 0.10443796869367361']
# ['At iteration 28 the best fitness is 0.10443796869367361']
# ['At iteration 29 the best fitness is 0.10443796869367361']
# ['At iteration 30 the best fitness is 0.10443796869367361']
#       Weights: depth=0.000, sensor=0.678, skeleton=0.765, video=0.047
#       Best fitness: 0.104438, Time: 837.8s
#     Weights: [depth=0.000, sensor=0.678, skeleton=0.765, video=0.047]
#     Test Acc: 99.07%, F1: 99.06%, Model: 9.258MB
#
#   --- WEIGHTED_SCA ---
#     Running weighted_SCA...
#       Search dim: 4, Pop: 20, Iter: 30
# SCA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.12727593071758747']
# ['At iteration 1 the best fitness is 0.12727593071758747']
# ['At iteration 2 the best fitness is 0.12727593071758747']
# ['At iteration 3 the best fitness is 0.12727593071758747']
# ['At iteration 4 the best fitness is 0.11516693234443665']
# ['At iteration 5 the best fitness is 0.11516693234443665']
# ['At iteration 6 the best fitness is 0.11516693234443665']
# ['At iteration 7 the best fitness is 0.11516693234443665']
# ['At iteration 8 the best fitness is 0.11516693234443665']
# ['At iteration 9 the best fitness is 0.11516693234443665']
# ['At iteration 10 the best fitness is 0.11516693234443665']
# ['At iteration 11 the best fitness is 0.11516693234443665']
# ['At iteration 12 the best fitness is 0.11516693234443665']
# ['At iteration 13 the best fitness is 0.11516693234443665']
# ['At iteration 14 the best fitness is 0.11516693234443665']
# ['At iteration 15 the best fitness is 0.11516693234443665']
# ['At iteration 16 the best fitness is 0.11516693234443665']
# ['At iteration 17 the best fitness is 0.11516693234443665']
# ['At iteration 18 the best fitness is 0.11015976779162884']
# ['At iteration 19 the best fitness is 0.11015976779162884']
# ['At iteration 20 the best fitness is 0.11015976779162884']
# ['At iteration 21 the best fitness is 0.11015976779162884']
# ['At iteration 22 the best fitness is 0.11015976779162884']
# ['At iteration 23 the best fitness is 0.11015976779162884']
# ['At iteration 24 the best fitness is 0.11015976779162884']
# ['At iteration 25 the best fitness is 0.11015976779162884']
# ['At iteration 26 the best fitness is 0.11015976779162884']
# ['At iteration 27 the best fitness is 0.11015976779162884']
# ['At iteration 28 the best fitness is 0.11015976779162884']
# ['At iteration 29 the best fitness is 0.11015976779162884']
#       Weights: depth=0.637, sensor=0.351, skeleton=0.397, video=0.071
#       Best fitness: 0.110160, Time: 839.7s
#     Weights: [depth=0.637, sensor=0.351, skeleton=0.397, video=0.071]
#     Test Acc: 100.00%, F1: 100.00%, Model: 9.258MB
#
#   --- WEIGHTED_SSA ---
#     Running weighted_SSA...
#       Search dim: 4, Pop: 20, Iter: 30
# SSA is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.13733519613742828']
# ['At iteration 2 the best fitness is 0.1353945340961218']
# ['At iteration 3 the best fitness is 0.13524778559803963']
# ['At iteration 4 the best fitness is 0.1289760135114193']
# ['At iteration 5 the best fitness is 0.1289760135114193']
# ['At iteration 6 the best fitness is 0.1289760135114193']
# ['At iteration 7 the best fitness is 0.1289760135114193']
# ['At iteration 8 the best fitness is 0.1289760135114193']
# ['At iteration 9 the best fitness is 0.1289760135114193']
# ['At iteration 10 the best fitness is 0.1289760135114193']
# ['At iteration 11 the best fitness is 0.1289760135114193']
# ['At iteration 12 the best fitness is 0.1289760135114193']
# ['At iteration 13 the best fitness is 0.1289760135114193']
# ['At iteration 14 the best fitness is 0.1289760135114193']
# ['At iteration 15 the best fitness is 0.1289760135114193']
# ['At iteration 16 the best fitness is 0.1289760135114193']
# ['At iteration 17 the best fitness is 0.1289760135114193']
# ['At iteration 18 the best fitness is 0.1289760135114193']
# ['At iteration 19 the best fitness is 0.1289760135114193']
# ['At iteration 20 the best fitness is 0.1289760135114193']
# ['At iteration 21 the best fitness is 0.1289760135114193']
# ['At iteration 22 the best fitness is 0.1289760135114193']
# ['At iteration 23 the best fitness is 0.1289760135114193']
# ['At iteration 24 the best fitness is 0.1289760135114193']
# ['At iteration 25 the best fitness is 0.1289760135114193']
# ['At iteration 26 the best fitness is 0.1289760135114193']
# ['At iteration 27 the best fitness is 0.1289760135114193']
# ['At iteration 28 the best fitness is 0.1289760135114193']
# ['At iteration 29 the best fitness is 0.1289760135114193']
#       Weights: depth=0.507, sensor=0.559, skeleton=0.396, video=0.455
#       Best fitness: 0.128976, Time: 2099.0s
#     Weights: [depth=0.507, sensor=0.559, skeleton=0.396, video=0.455]
#     Test Acc: 100.00%, F1: 100.00%, Model: 9.258MB
#
#   --- WEIGHTED_WOA ---
#     Running weighted_WOA...
#       Search dim: 4, Pop: 20, Iter: 30
# WOA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.16602273471653461']
# ['At iteration 1 the best fitness is 0.12304581888020039']
# ['At iteration 2 the best fitness is 0.12304581888020039']
# ['At iteration 3 the best fitness is 0.12304581888020039']
# ['At iteration 4 the best fitness is 0.12304581888020039']
# ['At iteration 5 the best fitness is 0.12304581888020039']
# ['At iteration 6 the best fitness is 0.12304581888020039']
# ['At iteration 7 the best fitness is 0.12304581888020039']
# ['At iteration 8 the best fitness is 0.12304581888020039']
# ['At iteration 9 the best fitness is 0.12304581888020039']
# ['At iteration 10 the best fitness is 0.12304581888020039']
# ['At iteration 11 the best fitness is 0.1225726567208767']
# ['At iteration 12 the best fitness is 0.1225726567208767']
# ['At iteration 13 the best fitness is 0.1225726567208767']
# ['At iteration 14 the best fitness is 0.1225726567208767']
# ['At iteration 15 the best fitness is 0.1225726567208767']
# ['At iteration 16 the best fitness is 0.1225726567208767']
# ['At iteration 17 the best fitness is 0.1225726567208767']
# ['At iteration 18 the best fitness is 0.1225726567208767']
# ['At iteration 19 the best fitness is 0.1225726567208767']
# ['At iteration 20 the best fitness is 0.1225726567208767']
# ['At iteration 21 the best fitness is 0.1225726567208767']
# ['At iteration 22 the best fitness is 0.1225726567208767']
# ['At iteration 23 the best fitness is 0.1225726567208767']
# ['At iteration 24 the best fitness is 0.1225726567208767']
# ['At iteration 25 the best fitness is 0.1225726567208767']
# ['At iteration 26 the best fitness is 0.1225726567208767']
# ['At iteration 27 the best fitness is 0.1225726567208767']
# ['At iteration 28 the best fitness is 0.1225726567208767']
# ['At iteration 29 the best fitness is 0.1225726567208767']
#       Weights: depth=0.330, sensor=1.000, skeleton=1.000, video=0.817
#       Best fitness: 0.122573, Time: 840.3s
#     Weights: [depth=0.330, sensor=1.000, skeleton=1.000, video=0.817]
#     Test Acc: 99.07%, F1: 99.06%, Model: 9.258MB
#
# ================================================================================
# ALL WEIGHTED FUSION EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Per-Fold Results CSV

# %%
rows = []
for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'Val Loss': r.get('val_loss', float('inf')),
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Weight Opt Time (s)': r['weight_optimization_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality weights
        mod_w = r['modality_weights']
        for i, mod_name in enumerate(MODALITY_NAMES):
            row[f'w_{mod_name}'] = mod_w[i]
        
        rows.append(row)

df_all = pd.DataFrame(rows).round(4)
df_all.to_csv(RESULTS_ROOT / "all_results_per_fold.csv", index=False)
print(f"Saved: {RESULTS_ROOT / 'all_results_per_fold.csv'}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved: results_weighted_fusion/all_results_per_fold.csv
# Shape: (120, 19)
#           Method  Fold  Test Accuracy (%)  Val Accuracy (%)  Val Loss  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Weight Opt Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  GPU Peak (MB)  w_depth  w_sensor  w_skeleton  w_video
# 0       baseline     1            93.5185           98.1308    0.1598       92.5573          92.5573              93.2099           93.5185               0.0000         18.1693         18.1693       2425371           9.2579       118.7090   1.0000    1.0000      1.0000   1.0000
# 1       baseline     2            90.7407          100.0000    0.0791       88.1481          88.1481              87.6543           90.7407               0.0000         29.8136         29.8136       2425371           9.2579        72.3281   1.0000    1.0000      1.0000   1.0000
# 2       baseline     3            89.8148           99.0654    0.0989       87.9229          87.9229              91.1523           89.8148               0.0000         28.9276         28.9276       2425371           9.2579        72.3281   1.0000    1.0000      1.0000   1.0000
# 3       baseline     4            91.6667           98.1308    0.0807       90.4067          90.4067              91.3757           91.6667               0.0000         29.0632         29.0632       2425371           9.2579        72.3281   1.0000    1.0000      1.0000   1.0000
# 4       baseline     5            92.5926           98.1308    0.1510       91.8636          91.8636              93.1987           92.5926               0.0000         29.1465         29.1465       2425371           9.2579        72.3281   1.0000    1.0000      1.0000   1.0000
# 5       baseline     6            85.9813           98.1481    0.0358       82.8865          82.7266              82.5926           86.1111               0.0000         28.9916         28.9916       2425371           9.2579        72.3281   1.0000    1.0000      1.0000   1.0000
# 6       baseline     7            92.5234           98.1308    0.2156       91.2857          91.2042              91.0288           92.5926               0.0000         28.7949         28.7949       2425371           9.2579        72.3281   1.0000    1.0000      1.0000   1.0000
# 7       baseline     8            99.0654          100.0000    0.1493       98.9418          99.0654              99.0741           99.0741               0.0000         23.4999         23.5000       2425371           9.2579        72.3281   1.0000    1.0000      1.0000   1.0000
# 8   weighted_BAT     1            95.3704           98.1308    0.6191       94.1211          94.1211              93.7037           95.3704             603.9499         21.6277        625.5777       2425371           9.2579        72.3281   0.0000    1.0000      1.0000   0.0000
# 9   weighted_BAT     2            91.6667           97.1963    0.1029       88.9958          88.9958              87.6720           91.6667             912.7445         29.6109        942.3555       2425371           9.2579        72.3281   0.0000    1.0000      1.0000   0.0000
# 10  weighted_BAT     3            92.5926           99.0654    0.0891       91.6541          91.6541              95.3439           92.5926             879.7556         28.7276        908.4833       2425371           9.2579        72.3281   0.6951    1.0000      0.7615   0.0000
# 11  weighted_BAT     4            91.6667           99.0654    0.1369       90.5008          90.5008              91.3374           91.6667             898.8153         29.3187        928.1342       2425371           9.2579        72.3281   0.6004    1.0000      1.0000   0.0000
# 12  weighted_BAT     5            92.5926           99.0654    0.0534       92.1616          92.1616              94.7707           92.5926             898.4322         28.6566        927.0889       2425371           9.2579        72.3281   0.0000    0.3858      1.0000   0.0000
# 13  weighted_BAT     6            96.2617           99.0741    0.0343       95.8271          95.7881              97.6720           96.2963             895.6796         28.8019        924.4816       2425371           9.2579        72.3281   1.0000    0.2441      1.0000   0.0000
# 14  weighted_BAT     7            96.2617           98.1308    0.3014       96.1199          96.0837              96.5432           96.2963             776.4526         24.5018        800.9545       2425371           9.2579        72.3281   0.0000    1.0000      1.0000   1.0000
# 15  weighted_BAT     8            98.1308          100.0000    0.0472       98.0247          98.0062              98.7654           98.1481             701.0773         24.2431        725.3204       2425371           9.2579        72.3281   0.8418    1.0000      0.6761   0.0000
# 16   weighted_CS     1            96.2963           99.0654    0.0960       95.8848          95.8848              95.9259           96.2963            1247.6411         21.5189       1269.1601       2425371           9.2579        72.3281   0.4574    0.4056      0.6894   0.0000
# 17   weighted_CS     2            89.8148           99.0654    0.1350       87.2075          87.2075              86.9136           89.8148            1794.4078         30.0244       1824.4323       2425371           9.2579        72.3281   0.4142    0.2233      0.1866   0.0000
# 18   weighted_CS     3            94.4444          100.0000    0.0226       93.8517          93.8517              96.4374           94.4444            1750.3731         28.9290       1779.3021       2425371           9.2579        72.3281   1.0000    1.0000      1.0000   0.0048
# 19   weighted_CS     4            93.5185           98.1308    0.0511       92.0635          92.0635              92.2222           93.5185            1750.8513         28.0154       1778.8669       2425371           9.2579        72.3281   0.9662    0.9798      0.6684   0.3405

# %% [markdown]
# ## Summary Table

# %%
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Weight Opt Time (s)': method_df['Weight Opt Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    
    for mod_name in MODALITY_NAMES:
        row[f'Mean w_{mod_name}'] = method_df[f'w_{mod_name}'].mean()
        row[f'Std w_{mod_name}'] = method_df[f'w_{mod_name}'].std()
    
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary = df_summary.sort_values('Mean Test Acc (%)', ascending=False)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#        Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Weight Opt Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean GPU Peak (MB)  Mean w_depth  Std w_depth  Mean w_sensor  Std w_sensor  Mean w_skeleton  Std w_skeleton  Mean w_video  Std w_video
#  weighted_SCA              95.83              3.80              94.95              4.64                    844.52                28.22               872.74               72.33          0.42         0.40           0.74          0.30             0.79            0.21          0.05         0.11
#  weighted_HHO              95.59              4.04              95.04              4.70                   1225.83                26.25              1252.07               72.33          0.30         0.34           0.27          0.27             0.28            0.21          0.06         0.09
#  weighted_PSO              95.36              2.88              94.72              3.40                    840.10                28.40               868.50               72.33          0.37         0.42           0.63          0.28             0.71            0.27          0.07         0.11
# weighted_JAYA              94.90              3.50              94.04              4.20                    816.63                27.34               843.96               72.33          0.64         0.34           0.60          0.23             0.62            0.20          0.07         0.08
#  weighted_MVO              94.89              2.72              94.07              3.16                    835.18                28.19               863.38               72.33          0.31         0.25           0.74          0.15             0.70            0.20          0.07         0.07
#   weighted_DE              94.66              2.61              93.84              3.02                    817.46                26.89               844.35               72.33          0.47         0.37           0.63          0.27             0.80            0.22          0.08         0.20
#   weighted_CS              94.66              3.58              93.62              4.56                   1613.10                26.80              1639.90               72.33          0.53         0.41           0.65          0.27             0.67            0.28          0.12         0.17
#   weighted_GA              94.43              3.13              93.74              3.65                    771.87                26.14               798.01               72.33          0.30         0.12           0.79          0.22             0.76            0.09          0.20         0.19
#  weighted_GWO              94.43              3.12              93.49              3.77                    771.08                25.91               796.99               72.33          0.35         0.26           0.59          0.29             0.64            0.23          0.05         0.05
#  weighted_BAT              94.32              2.48              93.43              3.11                    820.86                26.94               847.80               72.33          0.39         0.43           0.83          0.32             0.93            0.13          0.12         0.35
#  weighted_WOA              94.31              3.15              93.41              3.55                    845.58                28.31               873.90               72.33          0.45         0.40           0.90          0.12             0.89            0.13          0.57         0.39
#  weighted_MFO              94.20              2.65              93.15              3.05                    801.32                28.03               829.35               72.33          0.64         0.36           0.79          0.21             0.77            0.16          0.03         0.03
#  weighted_SSA              93.73              2.84              92.61              3.47                   2103.44                28.35              2131.79               72.33          0.35         0.31           0.71          0.21             0.84            0.21          0.13         0.17
#  weighted_FFA              92.69              3.65              91.61              4.20                    773.66                26.13               799.79               72.33          0.36         0.25           0.46          0.27             0.71            0.20          0.17         0.27
#      baseline              91.99              3.69              90.50              4.60                      0.00                27.05                27.05               78.13          1.00         0.00           1.00          0.00             1.00            0.00          1.00         0.00

# %% [markdown]
# ## Select Best Weights Per Fold
#
# For each fold, pick the metaheuristic whose weighted fusion achieved the **highest val accuracy**.
# Save these best weights so File 2 can load and apply them.

# %%
best_weights_per_fold = {}  # {fold_idx: {'weights': array, 'method': str, 'val_loss': float, ...}}

weighted_methods = [m for m in ALL_METHODS if m != 'baseline']

print("=" * 80)
print("BEST WEIGHTED METHOD PER FOLD (selected by lowest val loss)")
print("=" * 80)

for fold_idx in range(N_FOLDS):
    best_val_loss = float('inf')
    best_method = None
    best_weights = None
    best_test_acc = None
    best_val_acc = None
    
    for method_name in weighted_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['val_loss'] < best_val_loss:
                best_val_loss = r['val_loss']
                best_method = method_name
                best_weights = r['modality_weights'].copy()
                best_test_acc = r['test_acc']
                best_val_acc = r['val_acc']
    
    best_weights_per_fold[fold_idx] = {
        'weights': best_weights,
        'method': best_method,
        'val_loss': best_val_loss,
        'val_acc': best_val_acc,
        'test_acc': best_test_acc,
    }
    
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={best_weights[i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {best_method} | Val loss: {best_val_loss:.6f} | "
          f"Val acc: {best_val_acc*100:.2f}% | Test: {best_test_acc*100:.2f}% | Weights: [{w_str}]")

# Compare with baseline
print(f"\n  {'---' * 20}")
print(f"  Baseline comparison:")
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        bl = master_results['baseline'][fold_idx]
        bw = best_weights_per_fold[fold_idx]
        diff = bw['test_acc'] - bl['test_acc']
        print(f"    Fold {fold_idx+1}: Baseline={bl['test_acc']*100:.2f}%, "
              f"Best weighted={bw['test_acc']*100:.2f}%, Diff={diff*100:+.2f}%")

# Save for File 2
save_obj = {}
for fold_idx, info in best_weights_per_fold.items():
    save_obj[fold_idx] = {
        'weights': info['weights'],
        'method': info['method'],
        'val_loss': info['val_loss'],
        'val_acc': info['val_acc'],
        'test_acc': info['test_acc'],
    }

joblib.dump(save_obj, RESULTS_ROOT / "best_weights_per_fold.pkl")
print(f"\nSaved: {RESULTS_ROOT / 'best_weights_per_fold.pkl'}")
print("This file will be loaded by File 2 for weighted feature selection.")
# Out:
# ================================================================================
# BEST WEIGHTED METHOD PER FOLD (selected by lowest val loss)
# ================================================================================
#   Fold 1: weighted_SSA | Val loss: 0.019584 | Val acc: 100.00% | Test: 95.37% | Weights: [depth=0.995, sensor=0.400, skeleton=1.000, video=0.001]
#   Fold 2: weighted_GWO | Val loss: 0.029835 | Val acc: 100.00% | Test: 92.59% | Weights: [depth=0.727, sensor=1.000, skeleton=0.645, video=0.130]
#   Fold 3: weighted_CS | Val loss: 0.022612 | Val acc: 100.00% | Test: 94.44% | Weights: [depth=1.000, sensor=1.000, skeleton=1.000, video=0.005]
#   Fold 4: weighted_FFA | Val loss: 0.031495 | Val acc: 99.07% | Test: 89.81% | Weights: [depth=0.000, sensor=0.216, skeleton=0.373, video=0.000]
#   Fold 5: weighted_WOA | Val loss: 0.030725 | Val acc: 100.00% | Test: 95.37% | Weights: [depth=0.151, sensor=0.785, skeleton=0.934, video=0.207]
#   Fold 6: weighted_HHO | Val loss: 0.025565 | Val acc: 100.00% | Test: 88.79% | Weights: [depth=0.083, sensor=0.233, skeleton=0.360, video=0.183]
#   Fold 7: weighted_CS | Val loss: 0.152516 | Val acc: 99.07% | Test: 96.26% | Weights: [depth=0.007, sensor=0.582, skeleton=0.902, video=0.000]
#   Fold 8: weighted_DE | Val loss: 0.013477 | Val acc: 100.00% | Test: 100.00% | Weights: [depth=0.000, sensor=0.606, skeleton=0.976, video=0.018]
#
#   ------------------------------------------------------------
#   Baseline comparison:
#     Fold 1: Baseline=93.52%, Best weighted=95.37%, Diff=+1.85%
#     Fold 2: Baseline=90.74%, Best weighted=92.59%, Diff=+1.85%
#     Fold 3: Baseline=89.81%, Best weighted=94.44%, Diff=+4.63%
#     Fold 4: Baseline=91.67%, Best weighted=89.81%, Diff=-1.85%
#     Fold 5: Baseline=92.59%, Best weighted=95.37%, Diff=+2.78%
#     Fold 6: Baseline=85.98%, Best weighted=88.79%, Diff=+2.80%
#     Fold 7: Baseline=92.52%, Best weighted=96.26%, Diff=+3.74%
#     Fold 8: Baseline=99.07%, Best weighted=100.00%, Diff=+0.93%
#
# Saved: results_weighted_fusion/best_weights_per_fold.pkl
# This file will be loaded by File 2 for weighted feature selection.

# %% [markdown]
# ## Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy comparison (box plot)
# ============================================================================
fig, ax = plt.subplots(figsize=(18, 7))
order = df_summary['Method'].tolist()
sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax,
              color='black', alpha=0.5, size=4)
ax.set_title('Weighted Early Fusion: Test Accuracy Comparison', fontsize=14)
ax.set_ylabel('Test Accuracy (%)')
plt.xticks(rotation=60, ha='right')
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'accuracy_boxplot.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 2: Learned modality weights heatmap (all methods x folds)
# ============================================================================
for mod_name in MODALITY_NAMES:
    fig, ax = plt.subplots(figsize=(12, 8))
    pivot = df_all[df_all['Method'] != 'baseline'].pivot_table(
        values=f'w_{mod_name}', index='Method', columns='Fold'
    )
    sns.heatmap(pivot, annot=True, fmt='.3f', cmap='YlOrRd', ax=ax,
                vmin=0, vmax=1, linewidths=0.5, cbar_kws={'label': 'Weight'})
    ax.set_title(f'Learned Weight for {mod_name.upper()} Modality', fontsize=14)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'weights_heatmap_{mod_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
# ============================================================================
# PLOT 3: Average modality weights bar chart (all optimizers)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))

weight_methods = [m for m in ALL_METHODS if m != 'baseline']
x = np.arange(len(weight_methods))
width = 0.18
colors = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']

for i, mod_name in enumerate(MODALITY_NAMES):
    means, stds = [], []
    for method in weight_methods:
        mdf = df_all[df_all['Method'] == method]
        means.append(mdf[f'w_{mod_name}'].mean())
        stds.append(mdf[f'w_{mod_name}'].std())
    ax.bar(x + i * width, means, width, yerr=stds, capsize=2,
           label=mod_name, color=colors[i], alpha=0.8)

ax.set_ylabel('Weight', fontsize=12)
ax.set_title('Average Learned Modality Weights by Optimizer', fontsize=14)
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels([m.replace('weighted_', '') for m in weight_methods], rotation=45, ha='right')
ax.legend()
ax.set_ylim(0, 1.15)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'avg_modality_weights_bar.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 4: Improvement over baseline
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 6))

baseline_mean = df_summary[df_summary['Method'] == 'baseline']['Mean Test Acc (%)'].values[0]

improvements = []
method_labels = []
for _, row in df_summary.iterrows():
    if row['Method'] == 'baseline':
        continue
    improvements.append(row['Mean Test Acc (%)'] - baseline_mean)
    method_labels.append(row['Method'].replace('weighted_', ''))

colors_imp = ['green' if x >= 0 else 'red' for x in improvements]
bars = ax.bar(range(len(improvements)), improvements, color=colors_imp, alpha=0.7)
ax.axhline(y=0, color='black', linewidth=0.8)
ax.set_xticks(range(len(improvements)))
ax.set_xticklabels(method_labels, rotation=45, ha='right')
ax.set_ylabel('Accuracy Improvement over Baseline (%)', fontsize=12)
ax.set_title('Weighted Fusion vs Simple Concatenation', fontsize=14)

for bar, val in zip(bars, improvements):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            f'{val:+.2f}%', ha='center', va='bottom' if val >= 0 else 'top', fontsize=9)

plt.tight_layout()
plt.savefig(PLOTS_DIR / 'improvement_over_baseline.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 5: Convergence curves
# ============================================================================
fig, ax = plt.subplots(figsize=(14, 8))

for method in weight_methods:
    all_conv = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            conv = master_results[method][fold_idx].get('convergence', None)
            if conv is not None and len(conv) > 0:
                all_conv.append(conv)
    
    if len(all_conv) > 0:
        min_len = min(len(c) for c in all_conv)
        all_conv_arr = np.array([c[:min_len] for c in all_conv])
        mean_conv = np.mean(all_conv_arr, axis=0)
        ax.plot(range(1, min_len + 1), mean_conv,
                label=method.replace('weighted_', ''), linewidth=2)

ax.set_xlabel('Iteration', fontsize=12)
ax.set_ylabel('Fitness (lower is better)', fontsize=12)
ax.set_title('Weight Optimization Convergence (averaged across folds)', fontsize=14)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'convergence_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 6: Best weights per fold (the ones that will be used in File 2)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 6))

fold_labels = [f"Fold {i+1}\n({best_weights_per_fold[i]['method'].replace('weighted_', '')})" 
               for i in range(N_FOLDS)]
x = np.arange(N_FOLDS)
width = 0.18
colors = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']

for i, mod_name in enumerate(MODALITY_NAMES):
    weights = [best_weights_per_fold[fold_idx]['weights'][i] for fold_idx in range(N_FOLDS)]
    ax.bar(x + i * width, weights, width, label=mod_name, color=colors[i], alpha=0.8)

ax.set_ylabel('Weight', fontsize=12)
ax.set_title('Best Learned Modality Weights Per Fold (used in File 2)', fontsize=14)
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels(fold_labels, fontsize=9)
ax.legend()
ax.set_ylim(0, 1.15)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'best_weights_per_fold.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Statistical Significance

# %%
from scipy.stats import wilcoxon, ttest_rel

print("=" * 80)
print("STATISTICAL SIGNIFICANCE: each weighted method vs baseline")
print("=" * 80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []
for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) == len(baseline_accs) and len(method_accs) >= 2:
        try:
            t_stat, t_pval = ttest_rel(method_accs, baseline_accs)
        except:
            t_stat, t_pval = np.nan, np.nan
        try:
            w_stat, w_pval = wilcoxon(np.array(method_accs) - np.array(baseline_accs))
        except:
            w_stat, w_pval = np.nan, np.nan
        
        diff = np.mean(method_accs) - np.mean(baseline_accs)
        sig = '***' if t_pval < 0.001 else '**' if t_pval < 0.01 else '*' if t_pval < 0.05 else ''
        
        stat_rows.append({
            'Method': method,
            'Mean Diff (%)': diff,
            'Paired t p-val': t_pval,
            'Wilcoxon p-val': w_pval,
            'Sig': sig
        })
        
        print(f"  {method:25s}: diff={diff:+.2f}%, t-test p={t_pval:.4f}, "
              f"wilcoxon p={w_pval:.4f} {sig}")

df_stats = pd.DataFrame(stat_rows)
df_stats.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE: each weighted method vs baseline
# ================================================================================
#   weighted_BAT             : diff=+2.33%, t-test p=0.1072, wilcoxon p=0.0938
#   weighted_CS              : diff=+2.67%, t-test p=0.0061, wilcoxon p=0.0156 **
#   weighted_DE              : diff=+2.68%, t-test p=0.0183, wilcoxon p=0.0078 *
#   weighted_FFA             : diff=+0.70%, t-test p=0.4882, wilcoxon p=0.7969
#   weighted_GA              : diff=+2.44%, t-test p=0.1133, wilcoxon p=0.1250
#   weighted_GWO             : diff=+2.45%, t-test p=0.1109, wilcoxon p=0.1641
#   weighted_HHO             : diff=+3.60%, t-test p=0.0106, wilcoxon p=0.0156 *
#   weighted_JAYA            : diff=+2.91%, t-test p=0.0689, wilcoxon p=0.0703
#   weighted_MFO             : diff=+2.21%, t-test p=0.1434, wilcoxon p=0.1719
#   weighted_MVO             : diff=+2.90%, t-test p=0.0034, wilcoxon p=0.0078 **
#   weighted_PSO             : diff=+3.37%, t-test p=0.0463, wilcoxon p=0.0312 *
#   weighted_SCA             : diff=+3.84%, t-test p=0.0451, wilcoxon p=0.0547 *
#   weighted_SSA             : diff=+1.74%, t-test p=0.0910, wilcoxon p=0.0625
#   weighted_WOA             : diff=+2.33%, t-test p=0.0661, wilcoxon p=0.0938

# %% [markdown]
# ## Final Summary

# %%
print("=" * 80)
print("FILE 1 COMPLETE — WEIGHTED EARLY FUSION")
print("=" * 80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")
print(f"\nPlots:")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\n{'=' * 80}")
print("RESULTS (sorted by mean test accuracy):")
print("=" * 80)
for _, row in df_summary.iterrows():
    w_str = ' | '.join([f"{m}={row[f'Mean w_{m}']:.3f}" for m in MODALITY_NAMES])
    print(f"  {row['Method']:25s} | Acc: {row['Mean Test Acc (%)']:6.2f}% "
          f"(+/-{row['Std Test Acc (%)']:.2f}) | {w_str}")

print(f"\n{'=' * 80}")
print("BEST WEIGHTS PER FOLD (to be used in File 2):")
print("=" * 80)
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']:25s} | Val loss: {info['val_loss']:.6f} | Val acc: {info['val_acc']*100:.2f}% | [{w_str}]")

print(f"\nKey output for File 2: {RESULTS_ROOT / 'best_weights_per_fold.pkl'}")
# Out:
# ================================================================================
# FILE 1 COMPLETE — WEIGHTED EARLY FUSION
# ================================================================================
#
# Output directory: results_weighted_fusion
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# Plots:
#   accuracy_boxplot.png
#   avg_modality_weights_bar.png
#   best_weights_per_fold.png
#   convergence_curves.png
#   improvement_over_baseline.png
#   weights_heatmap_depth.png
#   weights_heatmap_sensor.png
#   weights_heatmap_skeleton.png
#   weights_heatmap_video.png
#
# ================================================================================
# RESULTS (sorted by mean test accuracy):
# ================================================================================
#   weighted_SCA              | Acc:  95.83% (+/-3.80) | depth=0.420 | sensor=0.740 | skeleton=0.790 | video=0.050
#   weighted_HHO              | Acc:  95.59% (+/-4.04) | depth=0.300 | sensor=0.270 | skeleton=0.280 | video=0.060
#   weighted_PSO              | Acc:  95.36% (+/-2.88) | depth=0.370 | sensor=0.630 | skeleton=0.710 | video=0.070
#   weighted_JAYA             | Acc:  94.90% (+/-3.50) | depth=0.640 | sensor=0.600 | skeleton=0.620 | video=0.070
#   weighted_MVO              | Acc:  94.89% (+/-2.72) | depth=0.310 | sensor=0.740 | skeleton=0.700 | video=0.070
#   weighted_DE               | Acc:  94.66% (+/-2.61) | depth=0.470 | sensor=0.630 | skeleton=0.800 | video=0.080
#   weighted_CS               | Acc:  94.66% (+/-3.58) | depth=0.530 | sensor=0.650 | skeleton=0.670 | video=0.120
#   weighted_GA               | Acc:  94.43% (+/-3.13) | depth=0.300 | sensor=0.790 | skeleton=0.760 | video=0.200
#   weighted_GWO              | Acc:  94.43% (+/-3.12) | depth=0.350 | sensor=0.590 | skeleton=0.640 | video=0.050
#   weighted_BAT              | Acc:  94.32% (+/-2.48) | depth=0.390 | sensor=0.830 | skeleton=0.930 | video=0.120
#   weighted_WOA              | Acc:  94.31% (+/-3.15) | depth=0.450 | sensor=0.900 | skeleton=0.890 | video=0.570
#   weighted_MFO              | Acc:  94.20% (+/-2.65) | depth=0.640 | sensor=0.790 | skeleton=0.770 | video=0.030
#   weighted_SSA              | Acc:  93.73% (+/-2.84) | depth=0.350 | sensor=0.710 | skeleton=0.840 | video=0.130
#   weighted_FFA              | Acc:  92.69% (+/-3.65) | depth=0.360 | sensor=0.460 | skeleton=0.710 | video=0.170
#   baseline                  | Acc:  91.99% (+/-3.69) | depth=1.000 | sensor=1.000 | skeleton=1.000 | video=1.000
#
# ================================================================================
# BEST WEIGHTS PER FOLD (to be used in File 2):
# ================================================================================
#   Fold 1: weighted_SSA              | Val loss: 0.019584 | Val acc: 100.00% | [depth=0.995, sensor=0.400, skeleton=1.000, video=0.001]
#   Fold 2: weighted_GWO              | Val loss: 0.029835 | Val acc: 100.00% | [depth=0.727, sensor=1.000, skeleton=0.645, video=0.130]
#   Fold 3: weighted_CS               | Val loss: 0.022612 | Val acc: 100.00% | [depth=1.000, sensor=1.000, skeleton=1.000, video=0.005]
#   Fold 4: weighted_FFA              | Val loss: 0.031495 | Val acc: 99.07% | [depth=0.000, sensor=0.216, skeleton=0.373, video=0.000]
#   Fold 5: weighted_WOA              | Val loss: 0.030725 | Val acc: 100.00% | [depth=0.151, sensor=0.785, skeleton=0.934, video=0.207]
#   Fold 6: weighted_HHO              | Val loss: 0.025565 | Val acc: 100.00% | [depth=0.083, sensor=0.233, skeleton=0.360, video=0.183]
#   Fold 7: weighted_CS               | Val loss: 0.152516 | Val acc: 99.07% | [depth=0.007, sensor=0.582, skeleton=0.902, video=0.000]
#   Fold 8: weighted_DE               | Val loss: 0.013477 | Val acc: 100.00% | [depth=0.000, sensor=0.606, skeleton=0.976, video=0.018]
#
# Key output for File 2: results_weighted_fusion/best_weights_per_fold.pkl
