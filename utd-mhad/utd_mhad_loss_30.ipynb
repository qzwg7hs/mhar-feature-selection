# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_loss_30")

# Master output directory
RESULTS_ROOT = Path("results_loss_30")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']
MODALITY_NAMES = ['depth', 'sensor', 'skeleton', 'video']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")

# FEATURE_DIMS will be set dynamically per-fold after PCA
# (depth dim changes if PCA is applied)
print(f"\nDepth PCA target: {DEPTH_PCA_DIM}" if DEPTH_PCA_DIM else "\nDepth PCA: disabled")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Raw feature dimensions (before PCA):
#   depth: 5508
#   sensor: 652
#   skeleton: 1879
#   video: 1420
#   TOTAL: 9459
#
# Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.
    
    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}
    
    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]
        
        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]
        
        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler
        
        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'. ")
        
        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]
    
    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)
    
    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " + 
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")
    
    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality in MODALITY_NAMES:
        dim = feature_dims[modality]
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined (with per-modality normalization + depth PCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth PCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. PCA on depth modality (fit on train only)  
    3. Concatenation AFTER normalization+PCA
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # Build sample indices for GroupKFold
    # We use a dummy X just for splitting indices
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        
        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv
        
        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]
        
        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")
        
        # =================================================================
        # Per-modality normalization + depth PCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )
        
        fold_total_features = sum(fold_feature_dims.values())
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y[train_idx])
            val_dataset = MultiModalDataset(X_val_sel, y[val_idx])
            test_dataset = MultiModalDataset(X_test_sel, y[test_idx])
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', 
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} 
                               for m, d in fold_feature_dims.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 90.74%, F1: 90.54%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 60.2s
#     Test Acc: 88.89%, F1: 88.37%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.2s
#     Test Acc: 82.41%, F1: 82.16%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 346.5s
#     Test Acc: 90.74%, F1: 90.46%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07825422319758932']
# ['At iteration 1 the best fitness is 0.07825422319758932']
# ['At iteration 2 the best fitness is 0.07825422319758932']
# ['At iteration 3 the best fitness is 0.07825422319758932']
# ['At iteration 4 the best fitness is 0.06944293788386757']
# ['At iteration 5 the best fitness is 0.06944293788386757']
# ['At iteration 6 the best fitness is 0.06944293788386757']
# ['At iteration 7 the best fitness is 0.06944293788386757']
# ['At iteration 8 the best fitness is 0.06944293788386757']
# ['At iteration 9 the best fitness is 0.06944293788386757']
# ['At iteration 10 the best fitness is 0.06944293788386757']
# ['At iteration 11 the best fitness is 0.0601835235089762']
# ['At iteration 12 the best fitness is 0.0601835235089762']
# ['At iteration 13 the best fitness is 0.0601835235089762']
# ['At iteration 14 the best fitness is 0.0601835235089762']
# ['At iteration 15 the best fitness is 0.0601835235089762']
# ['At iteration 16 the best fitness is 0.0601835235089762']
# ['At iteration 17 the best fitness is 0.0601835235089762']
# ['At iteration 18 the best fitness is 0.0601835235089762']
# ['At iteration 19 the best fitness is 0.0601835235089762']
# ['At iteration 20 the best fitness is 0.0601835235089762']
# ['At iteration 21 the best fitness is 0.0601835235089762']
# ['At iteration 22 the best fitness is 0.0601835235089762']
# ['At iteration 23 the best fitness is 0.0601835235089762']
# ['At iteration 24 the best fitness is 0.0601835235089762']
# ['At iteration 25 the best fitness is 0.0601835235089762']
# ['At iteration 26 the best fitness is 0.0601835235089762']
# ['At iteration 27 the best fitness is 0.0601835235089762']
# ['At iteration 28 the best fitness is 0.0601835235089762']
# ['At iteration 29 the best fitness is 0.0601835235089762']
#       Selected: 2202/4463 (49.3%), Fitness: 0.0602, Time: 1405.8s
#       Modality: D=49%, S=51%, Sk=48%, V=50%
#     Test Acc: 82.41%, F1: 80.52%, Features: 2202/4463 (49.3%), Model: 4.842MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08760326338471461']
# ['At iteration 1 the best fitness is 0.08760326338471461']
# ['At iteration 2 the best fitness is 0.05208924469312583']
# ['At iteration 3 the best fitness is 0.05208924469312583']
# ['At iteration 4 the best fitness is 0.05208924469312583']
# ['At iteration 5 the best fitness is 0.05208924469312583']
# ['At iteration 6 the best fitness is 0.05208924469312583']
# ['At iteration 7 the best fitness is 0.05208924469312583']
# ['At iteration 8 the best fitness is 0.05208924469312583']
# ['At iteration 9 the best fitness is 0.05208924469312583']
# ['At iteration 10 the best fitness is 0.05208924469312583']
# ['At iteration 11 the best fitness is 0.05208924469312583']
# ['At iteration 12 the best fitness is 0.05208924469312583']
# ['At iteration 13 the best fitness is 0.05208924469312583']
# ['At iteration 14 the best fitness is 0.05208924469312583']
# ['At iteration 15 the best fitness is 0.05208924469312583']
# ['At iteration 16 the best fitness is 0.05208924469312583']
# ['At iteration 17 the best fitness is 0.05208924469312583']
# ['At iteration 18 the best fitness is 0.05208924469312583']
# ['At iteration 19 the best fitness is 0.05208924469312583']
# ['At iteration 20 the best fitness is 0.05208924469312583']
# ['At iteration 21 the best fitness is 0.05208924469312583']
# ['At iteration 22 the best fitness is 0.05208924469312583']
# ['At iteration 23 the best fitness is 0.05208924469312583']
# ['At iteration 24 the best fitness is 0.05208924469312583']
# ['At iteration 25 the best fitness is 0.05208924469312583']
# ['At iteration 26 the best fitness is 0.05208924469312583']
# ['At iteration 27 the best fitness is 0.05208924469312583']
# ['At iteration 28 the best fitness is 0.05208924469312583']
# ['At iteration 29 the best fitness is 0.05208924469312583']
#       Selected: 2272/4463 (50.9%), Fitness: 0.0521, Time: 2770.9s
#       Modality: D=51%, S=53%, Sk=50%, V=51%
#     Test Acc: 87.04%, F1: 86.62%, Features: 2272/4463 (50.9%), Model: 4.979MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08672941171543386']
# ['At iteration 2 the best fitness is 0.07823181674453084']
# ['At iteration 3 the best fitness is 0.07823181674453084']
# ['At iteration 4 the best fitness is 0.07823181674453084']
# ['At iteration 5 the best fitness is 0.07773887477724425']
# ['At iteration 6 the best fitness is 0.07773887477724425']
# ['At iteration 7 the best fitness is 0.06946534433692605']
# ['At iteration 8 the best fitness is 0.06946534433692605']
# ['At iteration 9 the best fitness is 0.03387290305963258']
# ['At iteration 10 the best fitness is 0.03387290305963258']
# ['At iteration 11 the best fitness is 0.03387290305963258']
# ['At iteration 12 the best fitness is 0.03387290305963258']
# ['At iteration 13 the best fitness is 0.03387290305963258']
# ['At iteration 14 the best fitness is 0.03387290305963258']
# ['At iteration 15 the best fitness is 0.03387290305963258']
# ['At iteration 16 the best fitness is 0.03387290305963258']
# ['At iteration 17 the best fitness is 0.03387290305963258']
# ['At iteration 18 the best fitness is 0.03387290305963258']
# ['At iteration 19 the best fitness is 0.03387290305963258']
# ['At iteration 20 the best fitness is 0.03387290305963258']
# ['At iteration 21 the best fitness is 0.03387290305963258']
# ['At iteration 22 the best fitness is 0.03387290305963258']
# ['At iteration 23 the best fitness is 0.03387290305963258']
# ['At iteration 24 the best fitness is 0.03387290305963258']
# ['At iteration 25 the best fitness is 0.03387290305963258']
# ['At iteration 26 the best fitness is 0.03387290305963258']
# ['At iteration 27 the best fitness is 0.03387290305963258']
# ['At iteration 28 the best fitness is 0.03387290305963258']
# ['At iteration 29 the best fitness is 0.03387290305963258']
# ['At iteration 30 the best fitness is 0.03387290305963258']
#       Selected: 2231/4463 (50.0%), Fitness: 0.0339, Time: 1402.4s
#       Modality: D=52%, S=48%, Sk=52%, V=48%
#     Test Acc: 87.04%, F1: 85.72%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06955497014915997']
# ['At iteration 1 the best fitness is 0.08705430528478184']
# ['At iteration 2 the best fitness is 0.10485612753669318']
# ['At iteration 3 the best fitness is 0.0870991181908988']
# ['At iteration 4 the best fitness is 0.07848949095470337']
# ['At iteration 5 the best fitness is 0.09610085835561764']
# ['At iteration 6 the best fitness is 0.07799654898741679']
# ['At iteration 7 the best fitness is 0.08707671173784032']
# ['At iteration 8 the best fitness is 0.07839986514246944']
# ['At iteration 9 the best fitness is 0.08727836981536664']
# ['At iteration 10 the best fitness is 0.07834384900982325']
# ['At iteration 11 the best fitness is 0.09604484222297144']
# ['At iteration 12 the best fitness is 0.06053082353138265']
# ['At iteration 13 the best fitness is 0.07828783287717704']
# ['At iteration 14 the best fitness is 0.09604484222297144']
# ['At iteration 15 the best fitness is 0.0782766296506478']
# ['At iteration 16 the best fitness is 0.08713272787048651']
# ['At iteration 17 the best fitness is 0.07823181674453084']
# ['At iteration 18 the best fitness is 0.08711032141742803']
# ['At iteration 19 the best fitness is 0.07818700383841387']
# ['At iteration 20 the best fitness is 0.08708791496436956']
# ['At iteration 21 the best fitness is 0.0782206135180016']
# ['At iteration 22 the best fitness is 0.08707671173784032']
# ['At iteration 23 the best fitness is 0.07819820706494311']
# ['At iteration 24 the best fitness is 0.09594401318420827']
# ['At iteration 25 the best fitness is 0.07820941029147235']
# ['At iteration 26 the best fitness is 0.0693421088451044']
# ['At iteration 27 the best fitness is 0.08708791496436956']
# ['At iteration 28 the best fitness is 0.08711032141742803']
# ['At iteration 29 the best fitness is 0.06045240094567797']
#       Selected: 2226/4463 (49.9%), Fitness: 0.0605, Time: 1362.4s
#       Modality: D=49%, S=45%, Sk=51%, V=51%
#     Test Acc: 90.74%, F1: 90.32%, Features: 2226/4463 (49.9%), Model: 4.889MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.09546227444345093
# At iteration 2 the best fitness is 0.08752484079900993
# At iteration 3 the best fitness is 0.08711032141742803
# At iteration 4 the best fitness is 0.07805256512006299
# At iteration 5 the best fitness is 0.0869310697929602
# At iteration 6 the best fitness is 0.0869310697929602
# At iteration 7 the best fitness is 0.05139464464831292
# At iteration 8 the best fitness is 0.07836625546288173
# At iteration 9 the best fitness is 0.07846708450164488
# At iteration 10 the best fitness is 0.08737919885412981
# At iteration 11 the best fitness is 0.07871355548528818
# At iteration 12 the best fitness is 0.07869114903222969
# At iteration 13 the best fitness is 0.08669580203584615
# At iteration 14 the best fitness is 0.08698708592560639
# At iteration 15 the best fitness is 0.06977903467974478
# At iteration 16 the best fitness is 0.06069887192932126
# At iteration 17 the best fitness is 0.07845588127511564
# At iteration 18 the best fitness is 0.07845588127511564
# At iteration 19 the best fitness is 0.07787331349559515
# At iteration 20 the best fitness is 0.06967820564098162
# At iteration 21 the best fitness is 0.078332645783294
# At iteration 22 the best fitness is 0.06083331064767214
# At iteration 23 the best fitness is 0.07808617479965071
# At iteration 24 the best fitness is 0.08656136331749525
# At iteration 25 the best fitness is 0.0784446780485864
# At iteration 26 the best fitness is 0.06902841850228568
# At iteration 27 the best fitness is 0.06902841850228568
# At iteration 28 the best fitness is 0.06929729593898745
# At iteration 29 the best fitness is 0.06966700241445238
# At iteration 30 the best fitness is 0.06905082495534415
#       Selected: 2201/4463 (49.3%), Fitness: 0.0691, Time: 1359.1s
#       Modality: D=50%, S=49%, Sk=49%, V=50%
#     Test Acc: 87.96%, F1: 87.99%, Features: 2201/4463 (49.3%), Model: 4.840MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09601123254338371']
# ['At iteration 1 the best fitness is 0.09601123254338371']
# ['At iteration 2 the best fitness is 0.08549705679721742']
# ['At iteration 3 the best fitness is 0.08429831155858869']
# ['At iteration 4 the best fitness is 0.08335724053013249']
# ['At iteration 5 the best fitness is 0.08268504693837807']
# ['At iteration 6 the best fitness is 0.07324638093901885']
# ['At iteration 7 the best fitness is 0.07324638093901885']
# ['At iteration 8 the best fitness is 0.05496281994635016']
# ['At iteration 9 the best fitness is 0.05496281994635016']
# ['At iteration 10 the best fitness is 0.05496281994635016']
# ['At iteration 11 the best fitness is 0.05496281994635016']
# ['At iteration 12 the best fitness is 0.05496281994635016']
# ['At iteration 13 the best fitness is 0.05496281994635016']
# ['At iteration 14 the best fitness is 0.05496281994635016']
# ['At iteration 15 the best fitness is 0.05496281994635016']
# ['At iteration 16 the best fitness is 0.05496281994635016']
# ['At iteration 17 the best fitness is 0.05496281994635016']
# ['At iteration 18 the best fitness is 0.05496281994635016']
# ['At iteration 19 the best fitness is 0.05496281994635016']
# ['At iteration 20 the best fitness is 0.05496281994635016']
# ['At iteration 21 the best fitness is 0.05496281994635016']
# ['At iteration 22 the best fitness is 0.05496281994635016']
# ['At iteration 23 the best fitness is 0.05496281994635016']
# ['At iteration 24 the best fitness is 0.05496281994635016']
# ['At iteration 25 the best fitness is 0.05496281994635016']
# ['At iteration 26 the best fitness is 0.05496281994635016']
# ['At iteration 27 the best fitness is 0.05496281994635016']
# ['At iteration 28 the best fitness is 0.05496281994635016']
# ['At iteration 29 the best fitness is 0.05496281994635016']
#       Selected: 1736/4463 (38.9%), Fitness: 0.0550, Time: 1287.7s
#       Modality: D=42%, S=40%, Sk=39%, V=37%
#     Test Acc: 83.33%, F1: 82.74%, Features: 1736/4463 (38.9%), Model: 3.932MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.08715513432354499']
# ['At iteration 1 the best fitness is 0.08715513432354499']
# ['At iteration 2 the best fitness is 0.08715513432354499']
# ['At iteration 3 the best fitness is 0.08385583646220952']
# ['At iteration 4 the best fitness is 0.06903407246707613']
# ['At iteration 5 the best fitness is 0.06903407246707613']
# ['At iteration 6 the best fitness is 0.06903407246707613']
# ['At iteration 7 the best fitness is 0.06903407246707613']
# ['At iteration 8 the best fitness is 0.06903407246707613']
# ['At iteration 9 the best fitness is 0.06903407246707613']
# ['At iteration 10 the best fitness is 0.06903407246707613']
# ['At iteration 11 the best fitness is 0.06903407246707613']
# ['At iteration 12 the best fitness is 0.06903407246707613']
# ['At iteration 13 the best fitness is 0.06903407246707613']
# ['At iteration 14 the best fitness is 0.06903407246707613']
# ['At iteration 15 the best fitness is 0.06903407246707613']
# ['At iteration 16 the best fitness is 0.06903407246707613']
# ['At iteration 17 the best fitness is 0.06903407246707613']
# ['At iteration 18 the best fitness is 0.06903407246707613']
# ['At iteration 19 the best fitness is 0.0627042494780553']
# ['At iteration 20 the best fitness is 0.0627042494780553']
# ['At iteration 21 the best fitness is 0.0627042494780553']
# ['At iteration 22 the best fitness is 0.0627042494780553']
# ['At iteration 23 the best fitness is 0.0627042494780553']
# ['At iteration 24 the best fitness is 0.0627042494780553']
# ['At iteration 25 the best fitness is 0.0627042494780553']
# ['At iteration 26 the best fitness is 0.0627042494780553']
# ['At iteration 27 the best fitness is 0.0627042494780553']
# ['At iteration 28 the best fitness is 0.0627042494780553']
# ['At iteration 29 the best fitness is 0.0627042494780553']
#       Selected: 2427/4463 (54.4%), Fitness: 0.0627, Time: 1901.1s
#       Modality: D=52%, S=54%, Sk=55%, V=55%
#     Test Acc: 86.11%, F1: 85.60%, Features: 2427/4463 (54.4%), Model: 5.281MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0601835235089762']
# ['At iteration 1 the best fitness is 0.0601835235089762']
# ['At iteration 2 the best fitness is 0.0601835235089762']
# ['At iteration 3 the best fitness is 0.0601835235089762']
# ['At iteration 4 the best fitness is 0.0601835235089762']
# ['At iteration 5 the best fitness is 0.0601835235089762']
# ['At iteration 6 the best fitness is 0.0601835235089762']
# ['At iteration 7 the best fitness is 0.0601835235089762']
# ['At iteration 8 the best fitness is 0.0601835235089762']
# ['At iteration 9 the best fitness is 0.0601835235089762']
# ['At iteration 10 the best fitness is 0.0601835235089762']
# ['At iteration 11 the best fitness is 0.0601835235089762']
# ['At iteration 12 the best fitness is 0.0601835235089762']
# ['At iteration 13 the best fitness is 0.0601835235089762']
# ['At iteration 14 the best fitness is 0.0601835235089762']
# ['At iteration 15 the best fitness is 0.0601835235089762']
# ['At iteration 16 the best fitness is 0.0601835235089762']
# ['At iteration 17 the best fitness is 0.06006028801715455']
# ['At iteration 18 the best fitness is 0.06006028801715455']
# ['At iteration 19 the best fitness is 0.06006028801715455']
# ['At iteration 20 the best fitness is 0.06006028801715455']
# ['At iteration 21 the best fitness is 0.06006028801715455']
# ['At iteration 22 the best fitness is 0.06006028801715455']
# ['At iteration 23 the best fitness is 0.06006028801715455']
# ['At iteration 24 the best fitness is 0.06006028801715455']
# ['At iteration 25 the best fitness is 0.06006028801715455']
# ['At iteration 26 the best fitness is 0.06006028801715455']
# ['At iteration 27 the best fitness is 0.06006028801715455']
# ['At iteration 28 the best fitness is 0.06006028801715455']
# ['At iteration 29 the best fitness is 0.06006028801715455']
#       Selected: 2191/4463 (49.1%), Fitness: 0.0601, Time: 1409.1s
#       Modality: D=51%, S=48%, Sk=49%, V=49%
#     Test Acc: 87.96%, F1: 87.02%, Features: 2191/4463 (49.1%), Model: 4.820MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08671820848890463']
# ['At iteration 2 the best fitness is 0.07892641678934374']
# ['At iteration 3 the best fitness is 0.06956617337568921']
# ['At iteration 4 the best fitness is 0.06956617337568921']
# ['At iteration 5 the best fitness is 0.06956617337568921']
# ['At iteration 6 the best fitness is 0.06956617337568921']
# ['At iteration 7 the best fitness is 0.06956617337568921']
# ['At iteration 8 the best fitness is 0.06956617337568921']
# ['At iteration 9 the best fitness is 0.06956617337568921']
# ['At iteration 10 the best fitness is 0.06956617337568921']
# ['At iteration 11 the best fitness is 0.06956617337568921']
# ['At iteration 12 the best fitness is 0.06956617337568921']
# ['At iteration 13 the best fitness is 0.06956617337568921']
# ['At iteration 14 the best fitness is 0.06956617337568921']
# ['At iteration 15 the best fitness is 0.06956617337568921']
# ['At iteration 16 the best fitness is 0.06956617337568921']
# ['At iteration 17 the best fitness is 0.06956617337568921']
# ['At iteration 18 the best fitness is 0.06956617337568921']
# ['At iteration 19 the best fitness is 0.06956617337568921']
# ['At iteration 20 the best fitness is 0.06956617337568921']
# ['At iteration 21 the best fitness is 0.06956617337568921']
# ['At iteration 22 the best fitness is 0.0688155571982301']
# ['At iteration 23 the best fitness is 0.0688155571982301']
# ['At iteration 24 the best fitness is 0.0688155571982301']
# ['At iteration 25 the best fitness is 0.0688155571982301']
# ['At iteration 26 the best fitness is 0.0688155571982301']
# ['At iteration 27 the best fitness is 0.0688155571982301']
# ['At iteration 28 the best fitness is 0.0688155571982301']
# ['At iteration 29 the best fitness is 0.0688155571982301']
#       Selected: 2180/4463 (48.8%), Fitness: 0.0688, Time: 1328.5s
#       Modality: D=51%, S=49%, Sk=47%, V=51%
#     Test Acc: 85.19%, F1: 83.77%, Features: 2180/4463 (48.8%), Model: 4.799MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08652775363790753']
# ['At iteration 2 the best fitness is 0.06871472815946694']
# ['At iteration 3 the best fitness is 0.06028435254773936']
# ['At iteration 4 the best fitness is 0.06028435254773936']
# ['At iteration 5 the best fitness is 0.06028435254773936']
# ['At iteration 6 the best fitness is 0.06028435254773936']
# ['At iteration 7 the best fitness is 0.06028435254773936']
# ['At iteration 8 the best fitness is 0.06028435254773936']
# ['At iteration 9 the best fitness is 0.06028435254773936']
# ['At iteration 10 the best fitness is 0.06028435254773936']
# ['At iteration 11 the best fitness is 0.06028435254773936']
# ['At iteration 12 the best fitness is 0.06028435254773936']
# ['At iteration 13 the best fitness is 0.06028435254773936']
# ['At iteration 14 the best fitness is 0.06028435254773936']
# ['At iteration 15 the best fitness is 0.06028435254773936']
# ['At iteration 16 the best fitness is 0.06028435254773936']
# ['At iteration 17 the best fitness is 0.06028435254773936']
# ['At iteration 18 the best fitness is 0.06028435254773936']
# ['At iteration 19 the best fitness is 0.06028435254773936']
# ['At iteration 20 the best fitness is 0.06028435254773936']
# ['At iteration 21 the best fitness is 0.06028435254773936']
# ['At iteration 22 the best fitness is 0.06028435254773936']
# ['At iteration 23 the best fitness is 0.06028435254773936']
# ['At iteration 24 the best fitness is 0.06028435254773936']
# ['At iteration 25 the best fitness is 0.06028435254773936']
# ['At iteration 26 the best fitness is 0.051305018836079']
# ['At iteration 27 the best fitness is 0.05129381560954976']
# ['At iteration 28 the best fitness is 0.05129381560954976']
# ['At iteration 29 the best fitness is 0.05129381560954976']
# ['At iteration 30 the best fitness is 0.05129381560954976']
#       Selected: 2201/4463 (49.3%), Fitness: 0.0513, Time: 1367.2s
#       Modality: D=48%, S=49%, Sk=48%, V=52%
#     Test Acc: 87.04%, F1: 85.87%, Features: 2201/4463 (49.3%), Model: 4.840MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0954510712169217']
# ['At iteration 2 the best fitness is 0.0954510712169217']
# ['At iteration 3 the best fitness is 0.08670700526237538']
# ['At iteration 4 the best fitness is 0.08652775363790753']
# ['At iteration 5 the best fitness is 0.08652775363790753']
# ['At iteration 6 the best fitness is 0.08652775363790753']
# ['At iteration 7 the best fitness is 0.06865871202682074']
# ['At iteration 8 the best fitness is 0.06865871202682074']
# ['At iteration 9 the best fitness is 0.06865871202682074']
# ['At iteration 10 the best fitness is 0.06865871202682074']
# ['At iteration 11 the best fitness is 0.05972419122127734']
# ['At iteration 12 the best fitness is 0.05972419122127734']
# ['At iteration 13 the best fitness is 0.05972419122127734']
# ['At iteration 14 the best fitness is 0.05972419122127734']
# ['At iteration 15 the best fitness is 0.05972419122127734']
# ['At iteration 16 the best fitness is 0.05972419122127734']
# ['At iteration 17 the best fitness is 0.05972419122127734']
# ['At iteration 18 the best fitness is 0.05972419122127734']
# ['At iteration 19 the best fitness is 0.05972419122127734']
# ['At iteration 20 the best fitness is 0.05972419122127734']
# ['At iteration 21 the best fitness is 0.05972419122127734']
# ['At iteration 22 the best fitness is 0.05972419122127734']
# ['At iteration 23 the best fitness is 0.05972419122127734']
# ['At iteration 24 the best fitness is 0.05972419122127734']
# ['At iteration 25 the best fitness is 0.05972419122127734']
# ['At iteration 26 the best fitness is 0.05972419122127734']
# ['At iteration 27 the best fitness is 0.05972419122127734']
# ['At iteration 28 the best fitness is 0.05972419122127734']
# ['At iteration 29 the best fitness is 0.05972419122127734']
# ['At iteration 30 the best fitness is 0.05972419122127734']
#       Selected: 2161/4463 (48.4%), Fitness: 0.0597, Time: 1347.0s
#       Modality: D=46%, S=49%, Sk=49%, V=48%
#     Test Acc: 87.04%, F1: 85.60%, Features: 2161/4463 (48.4%), Model: 4.762MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08698708592560639']
# ['At iteration 1 the best fitness is 0.08698708592560639']
# ['At iteration 2 the best fitness is 0.07530777462039909']
# ['At iteration 3 the best fitness is 0.07530777462039909']
# ['At iteration 4 the best fitness is 0.07530777462039909']
# ['At iteration 5 the best fitness is 0.07530777462039909']
# ['At iteration 6 the best fitness is 0.07530777462039909']
# ['At iteration 7 the best fitness is 0.07530777462039909']
# ['At iteration 8 the best fitness is 0.07530777462039909']
# ['At iteration 9 the best fitness is 0.07530777462039909']
# ['At iteration 10 the best fitness is 0.07530777462039909']
# ['At iteration 11 the best fitness is 0.0688547161395566']
# ['At iteration 12 the best fitness is 0.06805928705598054']
# ['At iteration 13 the best fitness is 0.06805928705598054']
# ['At iteration 14 the best fitness is 0.05810527263627626']
# ['At iteration 15 the best fitness is 0.05810527263627626']
# ['At iteration 16 the best fitness is 0.05810527263627626']
# ['At iteration 17 the best fitness is 0.05609989508754223']
# ['At iteration 18 the best fitness is 0.05609989508754223']
# ['At iteration 19 the best fitness is 0.05609989508754223']
# ['At iteration 20 the best fitness is 0.05609989508754223']
# ['At iteration 21 the best fitness is 0.05609989508754223']
# ['At iteration 22 the best fitness is 0.054811524036679576']
# ['At iteration 23 the best fitness is 0.054811524036679576']
# ['At iteration 24 the best fitness is 0.054811524036679576']
# ['At iteration 25 the best fitness is 0.054811524036679576']
# ['At iteration 26 the best fitness is 0.054811524036679576']
# ['At iteration 27 the best fitness is 0.054811524036679576']
# ['At iteration 28 the best fitness is 0.054811524036679576']
# ['At iteration 29 the best fitness is 0.054811524036679576']
#       Selected: 930/4463 (20.8%), Fitness: 0.0548, Time: 1143.5s
#       Modality: D=18%, S=21%, Sk=22%, V=21%
#     Test Acc: 87.04%, F1: 86.55%, Features: 930/4463 (20.8%), Model: 2.358MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07818700383841387']
# ['At iteration 2 the best fitness is 0.07762684251195186']
# ['At iteration 3 the best fitness is 0.07762684251195186']
# ['At iteration 4 the best fitness is 0.07762684251195186']
# ['At iteration 5 the best fitness is 0.07762684251195186']
# ['At iteration 6 the best fitness is 0.07762684251195186']
# ['At iteration 7 the best fitness is 0.07762684251195186']
# ['At iteration 8 the best fitness is 0.07762684251195186']
# ['At iteration 9 the best fitness is 0.0603515719069148']
# ['At iteration 10 the best fitness is 0.0603515719069148']
# ['At iteration 11 the best fitness is 0.0603515719069148']
# ['At iteration 12 the best fitness is 0.0603515719069148']
# ['At iteration 13 the best fitness is 0.0603515719069148']
# ['At iteration 14 the best fitness is 0.0603515719069148']
# ['At iteration 15 the best fitness is 0.0603515719069148']
# ['At iteration 16 the best fitness is 0.0603515719069148']
# ['At iteration 17 the best fitness is 0.06028435254773936']
# ['At iteration 18 the best fitness is 0.06028435254773936']
# ['At iteration 19 the best fitness is 0.06028435254773936']
# ['At iteration 20 the best fitness is 0.06028435254773936']
# ['At iteration 21 the best fitness is 0.06028435254773936']
# ['At iteration 22 the best fitness is 0.06028435254773936']
# ['At iteration 23 the best fitness is 0.06028435254773936']
# ['At iteration 24 the best fitness is 0.06028435254773936']
# ['At iteration 25 the best fitness is 0.06028435254773936']
# ['At iteration 26 the best fitness is 0.06028435254773936']
# ['At iteration 27 the best fitness is 0.06028435254773936']
# ['At iteration 28 the best fitness is 0.051450660780959126']
# ['At iteration 29 the best fitness is 0.051450660780959126']
#       Selected: 2215/4463 (49.6%), Fitness: 0.0515, Time: 3408.1s
#       Modality: D=53%, S=48%, Sk=50%, V=49%
#     Test Acc: 87.96%, F1: 87.21%, Features: 2215/4463 (49.6%), Model: 4.867MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08674061494196311']
# ['At iteration 1 the best fitness is 0.07754276596145672']
# ['At iteration 2 the best fitness is 0.07754276596145672']
# ['At iteration 3 the best fitness is 0.07729629497781343']
# ['At iteration 4 the best fitness is 0.07729629497781343']
# ['At iteration 5 the best fitness is 0.06911239034972913']
# ['At iteration 6 the best fitness is 0.06743190637034308']
# ['At iteration 7 the best fitness is 0.06743190637034308']
# ['At iteration 8 the best fitness is 0.06743190637034308']
# ['At iteration 9 the best fitness is 0.06743190637034308']
# ['At iteration 10 the best fitness is 0.06743190637034308']
# ['At iteration 11 the best fitness is 0.06743190637034308']
# ['At iteration 12 the best fitness is 0.06743190637034308']
# ['At iteration 13 the best fitness is 0.06743190637034308']
# ['At iteration 14 the best fitness is 0.06743190637034308']
# ['At iteration 15 the best fitness is 0.06743190637034308']
# ['At iteration 16 the best fitness is 0.06743190637034308']
# ['At iteration 17 the best fitness is 0.06743190637034308']
# ['At iteration 18 the best fitness is 0.06743190637034308']
# ['At iteration 19 the best fitness is 0.06743190637034308']
# ['At iteration 20 the best fitness is 0.06743190637034308']
# ['At iteration 21 the best fitness is 0.06743190637034308']
# ['At iteration 22 the best fitness is 0.06743190637034308']
# ['At iteration 23 the best fitness is 0.06743190637034308']
# ['At iteration 24 the best fitness is 0.06743190637034308']
# ['At iteration 25 the best fitness is 0.06743190637034308']
# ['At iteration 26 the best fitness is 0.06743190637034308']
# ['At iteration 27 the best fitness is 0.06743190637034308']
# ['At iteration 28 the best fitness is 0.06743190637034308']
# ['At iteration 29 the best fitness is 0.06743190637034308']
#       Selected: 1264/4463 (28.3%), Fitness: 0.0674, Time: 1226.4s
#       Modality: D=30%, S=27%, Sk=29%, V=28%
#     Test Acc: 82.41%, F1: 81.75%, Features: 1264/4463 (28.3%), Model: 3.010MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#     KernelPCA on depth: 5508 -> 512
#     Feature dims after processing: depth=512 | sensor=652 | skeleton=1879 | video=1420 | TOTAL=4463
#
#   --- BASELINE ---
#     Test Acc: 75.93%, F1: 72.07%, Features: 4463/4463 (100.0%), Model: 9.258MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 2231/4463 (50.0%), Time: 58.7s
#     Test Acc: 77.78%, F1: 75.69%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 2231/4463 (50.0%), Time: 10.0s
#     Test Acc: 82.41%, F1: 80.20%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 2231/4463 (50.0%), Time: 4.7s
#     Test Acc: 65.74%, F1: 63.74%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04274020450600054']
# ['At iteration 1 the best fitness is 0.04274020450600054']
# ['At iteration 2 the best fitness is 0.04274020450600054']
# ['At iteration 3 the best fitness is 0.04274020450600054']
# ['At iteration 4 the best fitness is 0.04274020450600054']
# ['At iteration 5 the best fitness is 0.042729001279471296']
# ['At iteration 6 the best fitness is 0.042729001279471296']
# ['At iteration 7 the best fitness is 0.042729001279471296']
# ['At iteration 8 the best fitness is 0.042729001279471296']
# ['At iteration 9 the best fitness is 0.042729001279471296']
# ['At iteration 10 the best fitness is 0.042729001279471296']
# ['At iteration 11 the best fitness is 0.042729001279471296']
# ['At iteration 12 the best fitness is 0.042729001279471296']
# ['At iteration 13 the best fitness is 0.042729001279471296']
# ['At iteration 14 the best fitness is 0.042729001279471296']
# ['At iteration 15 the best fitness is 0.042729001279471296']
# ['At iteration 16 the best fitness is 0.042729001279471296']
# ['At iteration 17 the best fitness is 0.042729001279471296']
# ['At iteration 18 the best fitness is 0.042729001279471296']
# ['At iteration 19 the best fitness is 0.042729001279471296']
# ['At iteration 20 the best fitness is 0.042729001279471296']
# ['At iteration 21 the best fitness is 0.042729001279471296']
# ['At iteration 22 the best fitness is 0.042729001279471296']
# ['At iteration 23 the best fitness is 0.042729001279471296']
# ['At iteration 24 the best fitness is 0.042729001279471296']
# ['At iteration 25 the best fitness is 0.042729001279471296']
# ['At iteration 26 the best fitness is 0.042729001279471296']
# ['At iteration 27 the best fitness is 0.042729001279471296']
# ['At iteration 28 the best fitness is 0.042729001279471296']
# ['At iteration 29 the best fitness is 0.042729001279471296']
#       Selected: 2229/4463 (49.9%), Fitness: 0.0427, Time: 1413.7s
#       Modality: D=47%, S=51%, Sk=50%, V=51%
#     Test Acc: 77.78%, F1: 76.11%, Features: 2229/4463 (49.9%), Model: 4.895MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05185397693601178']
# ['At iteration 1 the best fitness is 0.05185397693601178']
# ['At iteration 2 the best fitness is 0.042336888350947885']
# ['At iteration 3 the best fitness is 0.042336888350947885']
# ['At iteration 4 the best fitness is 0.042336888350947885']
# ['At iteration 5 the best fitness is 0.042336888350947885']
# ['At iteration 6 the best fitness is 0.042336888350947885']
# ['At iteration 7 the best fitness is 0.042336888350947885']
# ['At iteration 8 the best fitness is 0.042336888350947885']
# ['At iteration 9 the best fitness is 0.042336888350947885']
# ['At iteration 10 the best fitness is 0.042336888350947885']
# ['At iteration 11 the best fitness is 0.042336888350947885']
# ['At iteration 12 the best fitness is 0.042336888350947885']
# ['At iteration 13 the best fitness is 0.042336888350947885']
# ['At iteration 14 the best fitness is 0.042336888350947885']
# ['At iteration 15 the best fitness is 0.042336888350947885']
# ['At iteration 16 the best fitness is 0.042336888350947885']
# ['At iteration 17 the best fitness is 0.042336888350947885']
# ['At iteration 18 the best fitness is 0.042336888350947885']
# ['At iteration 19 the best fitness is 0.042336888350947885']
# ['At iteration 20 the best fitness is 0.04213523027342155']
# ['At iteration 21 the best fitness is 0.04213523027342155']
# ['At iteration 22 the best fitness is 0.03362643207598929']
# ['At iteration 23 the best fitness is 0.03362643207598929']
# ['At iteration 24 the best fitness is 0.03362643207598929']
# ['At iteration 25 the best fitness is 0.03362643207598929']
# ['At iteration 26 the best fitness is 0.03362643207598929']
# ['At iteration 27 the best fitness is 0.03362643207598929']
# ['At iteration 28 the best fitness is 0.03362643207598929']
# ['At iteration 29 the best fitness is 0.03362643207598929']
#       Selected: 2209/4463 (49.5%), Fitness: 0.0336, Time: 2775.8s
#       Modality: D=48%, S=50%, Sk=49%, V=50%
#     Test Acc: 82.41%, F1: 80.97%, Features: 2209/4463 (49.5%), Model: 4.856MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05131622206260824']
# ['At iteration 2 the best fitness is 0.05131622206260824']
# ['At iteration 3 the best fitness is 0.05131622206260824']
# ['At iteration 4 the best fitness is 0.05131622206260824']
# ['At iteration 5 the best fitness is 0.05131622206260824']
# ['At iteration 6 the best fitness is 0.05131622206260824']
# ['At iteration 7 the best fitness is 0.05131622206260824']
# ['At iteration 8 the best fitness is 0.05123779947690356']
# ['At iteration 9 the best fitness is 0.05123779947690356']
# ['At iteration 10 the best fitness is 0.05123779947690356']
# ['At iteration 11 the best fitness is 0.05123779947690356']
# ['At iteration 12 the best fitness is 0.042863439997822175']
# ['At iteration 13 the best fitness is 0.042863439997822175']
# ['At iteration 14 the best fitness is 0.042863439997822175']
# ['At iteration 15 the best fitness is 0.042863439997822175']
# ['At iteration 16 the best fitness is 0.042863439997822175']
# ['At iteration 17 the best fitness is 0.042863439997822175']
# ['At iteration 18 the best fitness is 0.042863439997822175']
# ['At iteration 19 the best fitness is 0.042863439997822175']
# ['At iteration 20 the best fitness is 0.042863439997822175']
# ['At iteration 21 the best fitness is 0.042863439997822175']
# ['At iteration 22 the best fitness is 0.042863439997822175']
# ['At iteration 23 the best fitness is 0.042863439997822175']
# ['At iteration 24 the best fitness is 0.042863439997822175']
# ['At iteration 25 the best fitness is 0.042863439997822175']
# ['At iteration 26 the best fitness is 0.042863439997822175']
# ['At iteration 27 the best fitness is 0.042863439997822175']
# ['At iteration 28 the best fitness is 0.04259456256112041']
# ['At iteration 29 the best fitness is 0.04259456256112041']
# ['At iteration 30 the best fitness is 0.04259456256112041']
#       Selected: 2217/4463 (49.7%), Fitness: 0.0426, Time: 1409.6s
#       Modality: D=45%, S=52%, Sk=50%, V=50%
#     Test Acc: 76.85%, F1: 75.06%, Features: 2217/4463 (49.7%), Model: 4.871MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.051517880140134566']
# ['At iteration 1 the best fitness is 0.0602955557742686']
# ['At iteration 2 the best fitness is 0.04253854642847421']
# ['At iteration 3 the best fitness is 0.0514170511013714']
# ['At iteration 4 the best fitness is 0.05197721242783342']
# ['At iteration 5 the best fitness is 0.05164111563195621']
# ['At iteration 6 the best fitness is 0.05166352208501469']
# ['At iteration 7 the best fitness is 0.051428254327900644']
# ['At iteration 8 the best fitness is 0.051697131764602416']
# ['At iteration 9 the best fitness is 0.05161870917889773']
# ['At iteration 10 the best fitness is 0.051573896272780764']
# ['At iteration 11 the best fitness is 0.05170833499113166']
# ['At iteration 12 the best fitness is 0.06051962030485341']
# ['At iteration 13 the best fitness is 0.051506676913605325']
# ['At iteration 14 the best fitness is 0.06042999449261949']
# ['At iteration 15 the best fitness is 0.060396384813031764']
# ['At iteration 16 the best fitness is 0.05155148981972228']
# ['At iteration 17 the best fitness is 0.05155148981972228']
# ['At iteration 18 the best fitness is 0.05156269304625152']
# ['At iteration 19 the best fitness is 0.060407588039561005']
# ['At iteration 20 the best fitness is 0.051517880140134566']
# ['At iteration 21 the best fitness is 0.051506676913605325']
# ['At iteration 22 the best fitness is 0.05154028659319305']
# ['At iteration 23 the best fitness is 0.060418791266090247']
# ['At iteration 24 the best fitness is 0.03378327724739866']
# ['At iteration 25 the best fitness is 0.04266178192029585']
# ['At iteration 26 the best fitness is 0.060418791266090247']
# ['At iteration 27 the best fitness is 0.05154028659319305']
# ['At iteration 28 the best fitness is 0.060407588039561005']
# ['At iteration 29 the best fitness is 0.060418791266090247']
#       Selected: 2223/4463 (49.8%), Fitness: 0.0604, Time: 1359.2s
#       Modality: D=47%, S=52%, Sk=50%, V=49%
#     Test Acc: 79.63%, F1: 75.98%, Features: 2223/4463 (49.8%), Model: 4.883MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.060407588039561005
# At iteration 2 the best fitness is 0.05160750595236849
# At iteration 3 the best fitness is 0.051831570482953296
# At iteration 4 the best fitness is 0.06022833641509316
# At iteration 5 the best fitness is 0.06083331064767214
# At iteration 6 the best fitness is 0.05105854785243571
# At iteration 7 the best fitness is 0.0423704980305356
# At iteration 8 the best fitness is 0.051204189797315836
# At iteration 9 the best fitness is 0.05118178334425735
# At iteration 10 the best fitness is 0.042392904483594084
# At iteration 11 the best fitness is 0.04282983031823446
# At iteration 12 the best fitness is 0.04249373352235725
# At iteration 13 the best fitness is 0.04243771738971104
# At iteration 14 the best fitness is 0.051305018836079
# At iteration 15 the best fitness is 0.05114817366466963
# At iteration 16 the best fitness is 0.05114817366466963
# At iteration 17 the best fitness is 0.0601835235089762
# At iteration 18 the best fitness is 0.043109910981465466
# At iteration 19 the best fitness is 0.05195480597477494
# At iteration 20 the best fitness is 0.04290825290393914
# At iteration 21 the best fitness is 0.042336888350947885
# At iteration 22 the best fitness is 0.04218004317953851
# At iteration 23 the best fitness is 0.04205680768771687
# At iteration 24 the best fitness is 0.04218004317953851
# At iteration 25 the best fitness is 0.05127140915649128
# At iteration 26 the best fitness is 0.04226966899177244
# At iteration 27 the best fitness is 0.04244892061624028
# At iteration 28 the best fitness is 0.05186518016254102
# At iteration 29 the best fitness is 0.0518875866155995
# At iteration 30 the best fitness is 0.04275140773252978
#       Selected: 2231/4463 (50.0%), Fitness: 0.0428, Time: 1359.2s
#       Modality: D=48%, S=54%, Sk=50%, V=50%
#     Test Acc: 81.48%, F1: 79.37%, Features: 2231/4463 (50.0%), Model: 4.899MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04216883995300927']
# ['At iteration 1 the best fitness is 0.04216883995300927']
# ['At iteration 2 the best fitness is 0.040746030183795745']
# ['At iteration 3 the best fitness is 0.04069001405114954']
# ['At iteration 4 the best fitness is 0.030982470615088548']
# ['At iteration 5 the best fitness is 0.030982470615088548']
# ['At iteration 6 the best fitness is 0.030982470615088548']
# ['At iteration 7 the best fitness is 0.030982470615088548']
# ['At iteration 8 the best fitness is 0.030982470615088548']
# ['At iteration 9 the best fitness is 0.030982470615088548']
# ['At iteration 10 the best fitness is 0.029940570547869187']
# ['At iteration 11 the best fitness is 0.029940570547869187']
# ['At iteration 12 the best fitness is 0.029940570547869187']
# ['At iteration 13 the best fitness is 0.029940570547869187']
# ['At iteration 14 the best fitness is 0.029313189862231727']
# ['At iteration 15 the best fitness is 0.029313189862231727']
# ['At iteration 16 the best fitness is 0.029313189862231727']
# ['At iteration 17 the best fitness is 0.029313189862231727']
# ['At iteration 18 the best fitness is 0.029313189862231727']
# ['At iteration 19 the best fitness is 0.029313189862231727']
# ['At iteration 20 the best fitness is 0.029313189862231727']
# ['At iteration 21 the best fitness is 0.029313189862231727']
# ['At iteration 22 the best fitness is 0.029313189862231727']
# ['At iteration 23 the best fitness is 0.029313189862231727']
# ['At iteration 24 the best fitness is 0.029313189862231727']
# ['At iteration 25 the best fitness is 0.029313189862231727']
# ['At iteration 26 the best fitness is 0.029313189862231727']
# ['At iteration 27 the best fitness is 0.029313189862231727']
# ['At iteration 28 the best fitness is 0.029313189862231727']
# ['At iteration 29 the best fitness is 0.029313189862231727']
#       Selected: 1824/4463 (40.9%), Fitness: 0.0293, Time: 1285.6s
#       Modality: D=42%, S=40%, Sk=40%, V=42%
#     Test Acc: 79.63%, F1: 77.68%, Features: 1824/4463 (40.9%), Model: 4.104MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.06037397835997328']
# ['At iteration 1 the best fitness is 0.06037397835997328']
# ['At iteration 2 the best fitness is 0.06037397835997328']
# ['At iteration 3 the best fitness is 0.05104169066111601']
# ['At iteration 4 the best fitness is 0.05104169066111601']
# ['At iteration 5 the best fitness is 0.05104169066111601']
# ['At iteration 6 the best fitness is 0.0413565536781135']
# ['At iteration 7 the best fitness is 0.0413565536781135']
# ['At iteration 8 the best fitness is 0.0413565536781135']
# ['At iteration 9 the best fitness is 0.0413565536781135']
# ['At iteration 10 the best fitness is 0.0413565536781135']
# ['At iteration 11 the best fitness is 0.0413565536781135']
# ['At iteration 12 the best fitness is 0.0413565536781135']
# ['At iteration 13 the best fitness is 0.0413565536781135']
# ['At iteration 14 the best fitness is 0.0413565536781135']
# ['At iteration 15 the best fitness is 0.0413565536781135']
# ['At iteration 16 the best fitness is 0.037306639639318934']
# ['At iteration 17 the best fitness is 0.037306639639318934']
# ['At iteration 18 the best fitness is 0.037306639639318934']
# ['At iteration 19 the best fitness is 0.03726182673320197']
# ['At iteration 20 the best fitness is 0.03726182673320197']
# ['At iteration 21 the best fitness is 0.03726182673320197']
# ['At iteration 22 the best fitness is 0.03726182673320197']
# ['At iteration 23 the best fitness is 0.03726182673320197']
# ['At iteration 24 the best fitness is 0.03726182673320197']
# ['At iteration 25 the best fitness is 0.03726182673320197']
# ['At iteration 26 the best fitness is 0.03726182673320197']
# ['At iteration 27 the best fitness is 0.03726182673320197']
# ['At iteration 28 the best fitness is 0.03726182673320197']
# ['At iteration 29 the best fitness is 0.026837276799269595']
#       Selected: 1603/4463 (35.9%), Fitness: 0.0268, Time: 1752.1s
#       Modality: D=37%, S=37%, Sk=36%, V=35%
#     Test Acc: 79.63%, F1: 76.49%, Features: 1603/4463 (35.9%), Model: 3.672MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.051450660780959126']
# ['At iteration 1 the best fitness is 0.05099132849326027']
# ['At iteration 2 the best fitness is 0.05099132849326027']
# ['At iteration 3 the best fitness is 0.0508904994544971']
# ['At iteration 4 the best fitness is 0.04252734320194497']
# ['At iteration 5 the best fitness is 0.04252734320194497']
# ['At iteration 6 the best fitness is 0.04252734320194497']
# ['At iteration 7 the best fitness is 0.04252734320194497']
# ['At iteration 8 the best fitness is 0.0424265141631818']
# ['At iteration 9 the best fitness is 0.0424265141631818']
# ['At iteration 10 the best fitness is 0.0424265141631818']
# ['At iteration 11 the best fitness is 0.0424265141631818']
# ['At iteration 12 the best fitness is 0.03389530951269106']
# ['At iteration 13 the best fitness is 0.03389530951269106']
# ['At iteration 14 the best fitness is 0.03389530951269106']
# ['At iteration 15 the best fitness is 0.03389530951269106']
# ['At iteration 16 the best fitness is 0.03389530951269106']
# ['At iteration 17 the best fitness is 0.03389530951269106']
# ['At iteration 18 the best fitness is 0.03389530951269106']
# ['At iteration 19 the best fitness is 0.03389530951269106']
# ['At iteration 20 the best fitness is 0.03389530951269106']
# ['At iteration 21 the best fitness is 0.03389530951269106']
# ['At iteration 22 the best fitness is 0.03389530951269106']
# ['At iteration 23 the best fitness is 0.03389530951269106']
# ['At iteration 24 the best fitness is 0.03389530951269106']
# ['At iteration 25 the best fitness is 0.03389530951269106']
# ['At iteration 26 the best fitness is 0.03389530951269106']
# ...
# ['At iteration 14 the best fitness is 0.06558902795780887']
# ['At iteration 15 the best fitness is 0.06558902795780887']
# ['At iteration 16 the best fitness is 0.06558902795780887']
# ['At iteration 17 the best fitness is 0.06558902795780887']
# ['At iteration 18 the best fitness is 0.06558902795780887']
# ['At iteration 19 the best fitness is 0.06558902795780887']
# ['At iteration 20 the best fitness is 0.06558902795780887']
# ['At iteration 21 the best fitness is 0.06558902795780887']
# ['At iteration 22 the best fitness is 0.06558902795780887']
# ['At iteration 23 the best fitness is 0.06558902795780887']
# ['At iteration 24 the best fitness is 0.06558902795780887']
# ['At iteration 25 the best fitness is 0.06558902795780887']
# ['At iteration 26 the best fitness is 0.06558902795780887']
# ['At iteration 27 the best fitness is 0.06558902795780887']
# ['At iteration 28 the best fitness is 0.06558902795780887']
# ['At iteration 29 the best fitness is 0.06558902795780887']
#       Selected: 1892/4463 (42.4%), Fitness: 0.0656, Time: 1726.1s
#       Modality: D=44%, S=43%, Sk=41%, V=43%
#     Test Acc: 84.11%, F1: 81.77%, Features: 1892/4463 (42.4%), Model: 4.236MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0781421909322969']
# ['At iteration 1 the best fitness is 0.0781421909322969']
# ['At iteration 2 the best fitness is 0.0781421909322969']
# ['At iteration 3 the best fitness is 0.07803015866700451']
# ['At iteration 4 the best fitness is 0.07803015866700451']
# ['At iteration 5 the best fitness is 0.07803015866700451']
# ['At iteration 6 the best fitness is 0.07803015866700451']
# ['At iteration 7 the best fitness is 0.07803015866700451']
# ['At iteration 8 the best fitness is 0.07803015866700451']
# ['At iteration 9 the best fitness is 0.07803015866700451']
# ['At iteration 10 the best fitness is 0.07803015866700451']
# ['At iteration 11 the best fitness is 0.07803015866700451']
# ['At iteration 12 the best fitness is 0.07803015866700451']
# ['At iteration 13 the best fitness is 0.07803015866700451']
# ['At iteration 14 the best fitness is 0.07803015866700451']
# ['At iteration 15 the best fitness is 0.07803015866700451']
# ['At iteration 16 the best fitness is 0.07803015866700451']
# ['At iteration 17 the best fitness is 0.07803015866700451']
# ['At iteration 18 the best fitness is 0.07803015866700451']
# ['At iteration 19 the best fitness is 0.07803015866700451']
# ['At iteration 20 the best fitness is 0.07803015866700451']
# ['At iteration 21 the best fitness is 0.07803015866700451']
# ['At iteration 22 the best fitness is 0.07803015866700451']
# ['At iteration 23 the best fitness is 0.07803015866700451']
# ['At iteration 24 the best fitness is 0.07782850058947818']
# ['At iteration 25 the best fitness is 0.07782850058947818']
# ['At iteration 26 the best fitness is 0.0696445959613939']
# ['At iteration 27 the best fitness is 0.0696445959613939']
# ['At iteration 28 the best fitness is 0.0696445959613939']
# ['At iteration 29 the best fitness is 0.0696445959613939']
#       Selected: 2254/4463 (50.5%), Fitness: 0.0696, Time: 1411.8s
#       Modality: D=52%, S=51%, Sk=50%, V=50%
#     Test Acc: 89.72%, F1: 89.03%, Features: 2254/4463 (50.5%), Model: 4.943MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.10462085977957913']
# ['At iteration 2 the best fitness is 0.09584318414544511']
# ['At iteration 3 the best fitness is 0.0782766296506478']
# ['At iteration 4 the best fitness is 0.0782766296506478']
# ['At iteration 5 the best fitness is 0.0782766296506478']
# ['At iteration 6 the best fitness is 0.0782766296506478']
# ['At iteration 7 the best fitness is 0.0782766296506478']
# ['At iteration 8 the best fitness is 0.0782766296506478']
# ['At iteration 9 the best fitness is 0.0782766296506478']
# ['At iteration 10 the best fitness is 0.0782766296506478']
# ['At iteration 11 the best fitness is 0.0782766296506478']
# ['At iteration 12 the best fitness is 0.0782766296506478']
# ['At iteration 13 the best fitness is 0.0782766296506478']
# ['At iteration 14 the best fitness is 0.0782766296506478']
# ['At iteration 15 the best fitness is 0.0782766296506478']
# ['At iteration 16 the best fitness is 0.06124783002925403']
# ['At iteration 17 the best fitness is 0.06124783002925403']
# ['At iteration 18 the best fitness is 0.06124783002925403']
# ['At iteration 19 the best fitness is 0.06124783002925403']
# ['At iteration 20 the best fitness is 0.06124783002925403']
# ['At iteration 21 the best fitness is 0.06124783002925403']
# ['At iteration 22 the best fitness is 0.06124783002925403']
# ['At iteration 23 the best fitness is 0.06124783002925403']
# ['At iteration 24 the best fitness is 0.06124783002925403']
# ['At iteration 25 the best fitness is 0.06124783002925403']
# ['At iteration 26 the best fitness is 0.06124783002925403']
# ['At iteration 27 the best fitness is 0.06124783002925403']
# ['At iteration 28 the best fitness is 0.06124783002925403']
# ['At iteration 29 the best fitness is 0.060945342912964544']
#       Selected: 2270/4463 (50.9%), Fitness: 0.0609, Time: 1327.5s
#       Modality: D=54%, S=50%, Sk=51%, V=50%
#     Test Acc: 89.72%, F1: 89.06%, Features: 2270/4463 (50.9%), Model: 4.975MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0864605342787321']
# ['At iteration 2 the best fitness is 0.06916285722063656']
# ['At iteration 3 the best fitness is 0.06916285722063656']
# ['At iteration 4 the best fitness is 0.06916285722063656']
# ['At iteration 5 the best fitness is 0.06916285722063656']
# ['At iteration 6 the best fitness is 0.051103360758552666']
# ['At iteration 7 the best fitness is 0.051103360758552666']
# ['At iteration 8 the best fitness is 0.051103360758552666']
# ['At iteration 9 the best fitness is 0.051103360758552666']
# ['At iteration 10 the best fitness is 0.051103360758552666']
# ['At iteration 11 the best fitness is 0.051103360758552666']
# ['At iteration 12 the best fitness is 0.051103360758552666']
# ['At iteration 13 the best fitness is 0.051103360758552666']
# ['At iteration 14 the best fitness is 0.051103360758552666']
# ['At iteration 15 the best fitness is 0.051103360758552666']
# ['At iteration 16 the best fitness is 0.051103360758552666']
# ['At iteration 17 the best fitness is 0.051103360758552666']
# ['At iteration 18 the best fitness is 0.051103360758552666']
# ['At iteration 19 the best fitness is 0.051103360758552666']
# ['At iteration 20 the best fitness is 0.051103360758552666']
# ['At iteration 21 the best fitness is 0.04219124640606775']
# ['At iteration 22 the best fitness is 0.04219124640606775']
# ['At iteration 23 the best fitness is 0.04219124640606775']
# ['At iteration 24 the best fitness is 0.04219124640606775']
# ['At iteration 25 the best fitness is 0.04219124640606775']
# ['At iteration 26 the best fitness is 0.04219124640606775']
# ['At iteration 27 the best fitness is 0.04219124640606775']
# ['At iteration 28 the best fitness is 0.04219124640606775']
# ['At iteration 29 the best fitness is 0.04219124640606775']
# ['At iteration 30 the best fitness is 0.04219124640606775']
#       Selected: 2181/4463 (48.9%), Fitness: 0.0422, Time: 1364.3s
#       Modality: D=51%, S=51%, Sk=48%, V=48%
#     Test Acc: 91.59%, F1: 90.35%, Features: 2181/4463 (48.9%), Model: 4.801MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08735679240107133']
# ['At iteration 2 the best fitness is 0.08735679240107133']
# ['At iteration 3 the best fitness is 0.08735679240107133']
# ['At iteration 4 the best fitness is 0.08691986656643094']
# ['At iteration 5 the best fitness is 0.07805256512006299']
# ['At iteration 6 the best fitness is 0.07805256512006299']
# ['At iteration 7 the best fitness is 0.07805256512006299']
# ['At iteration 8 the best fitness is 0.07805256512006299']
# ['At iteration 9 the best fitness is 0.07805256512006299']
# ['At iteration 10 the best fitness is 0.06942053143080909']
# ['At iteration 11 the best fitness is 0.06926368625939971']
# ['At iteration 12 the best fitness is 0.06902841850228568']
# ['At iteration 13 the best fitness is 0.06902841850228568']
# ['At iteration 14 the best fitness is 0.06884916687781782']
# ['At iteration 15 the best fitness is 0.06884916687781782']
# ['At iteration 16 the best fitness is 0.06884916687781782']
# ['At iteration 17 the best fitness is 0.06884916687781782']
# ['At iteration 18 the best fitness is 0.06884916687781782']
# ['At iteration 19 the best fitness is 0.06880435397170087']
# ['At iteration 20 the best fitness is 0.06880435397170087']
# ['At iteration 21 the best fitness is 0.05990344284574518']
# ['At iteration 22 the best fitness is 0.05990344284574518']
# ['At iteration 23 the best fitness is 0.05990344284574518']
# ['At iteration 24 the best fitness is 0.05990344284574518']
# ['At iteration 25 the best fitness is 0.05990344284574518']
# ['At iteration 26 the best fitness is 0.05113697043814039']
# ['At iteration 27 the best fitness is 0.05113697043814039']
# ['At iteration 28 the best fitness is 0.05113697043814039']
# ['At iteration 29 the best fitness is 0.05113697043814039']
# ['At iteration 30 the best fitness is 0.05113697043814039']
#       Selected: 2187/4463 (49.0%), Fitness: 0.0511, Time: 1330.2s
#       Modality: D=50%, S=49%, Sk=49%, V=49%
#     Test Acc: 89.72%, F1: 87.65%, Features: 2187/4463 (49.0%), Model: 4.813MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07761563928542262']
# ['At iteration 1 the best fitness is 0.07761563928542262']
# ['At iteration 2 the best fitness is 0.07761563928542262']
# ['At iteration 3 the best fitness is 0.07761563928542262']
# ['At iteration 4 the best fitness is 0.07761563928542262']
# ['At iteration 5 the best fitness is 0.07761563928542262']
# ['At iteration 6 the best fitness is 0.07761563928542262']
# ['At iteration 7 the best fitness is 0.07761563928542262']
# ['At iteration 8 the best fitness is 0.07761563928542262']
# ['At iteration 9 the best fitness is 0.07761563928542262']
# ['At iteration 10 the best fitness is 0.07761563928542262']
# ['At iteration 11 the best fitness is 0.07761563928542262']
# ['At iteration 12 the best fitness is 0.07761563928542262']
# ['At iteration 13 the best fitness is 0.07761563928542262']
# ['At iteration 14 the best fitness is 0.07761563928542262']
# ['At iteration 15 the best fitness is 0.05541094900751978']
# ['At iteration 16 the best fitness is 0.05541094900751978']
# ['At iteration 17 the best fitness is 0.05541094900751978']
# ['At iteration 18 the best fitness is 0.05541094900751978']
# ['At iteration 19 the best fitness is 0.05541094900751978']
# ['At iteration 20 the best fitness is 0.05541094900751978']
# ['At iteration 21 the best fitness is 0.05541094900751978']
# ['At iteration 22 the best fitness is 0.05541094900751978']
# ['At iteration 23 the best fitness is 0.05541094900751978']
# ['At iteration 24 the best fitness is 0.05541094900751978']
# ['At iteration 25 the best fitness is 0.05541094900751978']
# ['At iteration 26 the best fitness is 0.05541094900751978']
# ['At iteration 27 the best fitness is 0.05541094900751978']
# ['At iteration 28 the best fitness is 0.05541094900751978']
# ['At iteration 29 the best fitness is 0.05541094900751978']
#       Selected: 1776/4463 (39.8%), Fitness: 0.0554, Time: 1227.4s
#       Modality: D=44%, S=38%, Sk=40%, V=38%
#     Test Acc: 88.79%, F1: 88.29%, Features: 1776/4463 (39.8%), Model: 4.010MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0697566282266863']
# ['At iteration 2 the best fitness is 0.0697566282266863']
# ['At iteration 3 the best fitness is 0.0697566282266863']
# ['At iteration 4 the best fitness is 0.0697566282266863']
# ['At iteration 5 the best fitness is 0.0697566282266863']
# ['At iteration 6 the best fitness is 0.0697566282266863']
# ['At iteration 7 the best fitness is 0.0697566282266863']
# ['At iteration 8 the best fitness is 0.0697566282266863']
# ['At iteration 9 the best fitness is 0.06953256369610149']
# ['At iteration 10 the best fitness is 0.06953256369610149']
# ['At iteration 11 the best fitness is 0.0693421088451044']
# ['At iteration 12 the best fitness is 0.0693421088451044']
# ['At iteration 13 the best fitness is 0.0693421088451044']
# ['At iteration 14 the best fitness is 0.0693421088451044']
# ['At iteration 15 the best fitness is 0.0693421088451044']
# ['At iteration 16 the best fitness is 0.0693421088451044']
# ['At iteration 17 the best fitness is 0.0693421088451044']
# ['At iteration 18 the best fitness is 0.06933090561857516']
# ['At iteration 19 the best fitness is 0.06930849916551668']
# ['At iteration 20 the best fitness is 0.06930849916551668']
# ['At iteration 21 the best fitness is 0.06924127980634125']
# ['At iteration 22 the best fitness is 0.0603515719069148']
# ['At iteration 23 the best fitness is 0.0603515719069148']
# ['At iteration 24 the best fitness is 0.0603515719069148']
# ['At iteration 25 the best fitness is 0.0603515719069148']
# ['At iteration 26 the best fitness is 0.0603515719069148']
# ['At iteration 27 the best fitness is 0.0603515719069148']
# ['At iteration 28 the best fitness is 0.0603515719069148']
# ['At iteration 29 the best fitness is 0.05148427046054685']
#       Selected: 2218/4463 (49.7%), Fitness: 0.0515, Time: 3416.3s
#       Modality: D=49%, S=53%, Sk=49%, V=49%
#     Test Acc: 89.72%, F1: 89.52%, Features: 2218/4463 (49.7%), Model: 4.873MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0777500780037735']
# ['At iteration 1 the best fitness is 0.0777500780037735']
# ['At iteration 2 the best fitness is 0.0777500780037735']
# ['At iteration 3 the best fitness is 0.0777500780037735']
# ['At iteration 4 the best fitness is 0.0777500780037735']
# ['At iteration 5 the best fitness is 0.07708908763854831']
# ['At iteration 6 the best fitness is 0.07708908763854831']
# ['At iteration 7 the best fitness is 0.07708908763854831']
# ['At iteration 8 the best fitness is 0.07708908763854831']
# ['At iteration 9 the best fitness is 0.07708908763854831']
# ['At iteration 10 the best fitness is 0.07708908763854831']
# ['At iteration 11 the best fitness is 0.07708908763854831']
# ['At iteration 12 the best fitness is 0.07708908763854831']
# ['At iteration 13 the best fitness is 0.07708908763854831']
# ['At iteration 14 the best fitness is 0.07708908763854831']
# ['At iteration 15 the best fitness is 0.07708908763854831']
# ['At iteration 16 the best fitness is 0.07708908763854831']
# ['At iteration 17 the best fitness is 0.06815456683300491']
# ['At iteration 18 the best fitness is 0.06815456683300491']
# ['At iteration 19 the best fitness is 0.06815456683300491']
# ['At iteration 20 the best fitness is 0.06815456683300491']
# ['At iteration 21 the best fitness is 0.06815456683300491']
# ['At iteration 22 the best fitness is 0.06815456683300491']
# ['At iteration 23 the best fitness is 0.06594753120674456']
# ['At iteration 24 the best fitness is 0.06594753120674456']
# ['At iteration 25 the best fitness is 0.06594753120674456']
# ['At iteration 26 the best fitness is 0.06594753120674456']
# ['At iteration 27 the best fitness is 0.06594753120674456']
# ['At iteration 28 the best fitness is 0.06594753120674456']
# ['At iteration 29 the best fitness is 0.06594753120674456']
#       Selected: 1924/4463 (43.1%), Fitness: 0.0659, Time: 1089.3s
#       Modality: D=44%, S=41%, Sk=44%, V=44%
#     Test Acc: 84.11%, F1: 79.82%, Features: 1924/4463 (43.1%), Model: 4.299MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }
        
        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'depth': 512, 'sensor': 652, 'skeleton': 1879, 'video': 1420}, Total: 4463
# Results table: (144, 35)
# Methods: 18, Folds per method: {'baseline': 8, 'lasso': 8, 'meta_BAT': 8, 'meta_CS': 8, 'meta_DE': 8, 'meta_FFA': 8, 'meta_GA': 8, 'meta_GWO': 8, 'meta_HHO': 8, 'meta_JAYA': 8, 'meta_MFO': 8, 'meta_MVO': 8, 'meta_PSO': 8, 'meta_SCA': 8, 'meta_SSA': 8, 'meta_WOA': 8, 'mutual_info': 8, 'rfe': 8}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1          90.740741         93.457944     90.537919
# 1  baseline     2          75.925926         99.065421     72.074572
# 2  baseline     3          78.703704         96.261682     78.119083
# 3  baseline     4          84.259259         93.457944     83.994709
# 4  baseline     5          65.740741         94.392523     62.276851
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0        90.537919            92.407407         90.740741               4463
# 1        72.074572            75.823045         75.925926               4463
# 2        78.119083            85.385068         78.703704               4463
# 3        83.994709            87.910053         84.259259               4463
# 4        62.276851            67.772433         65.740741               4463
#
#    Features Total  ...  depth_retention_%  sensor_retained  sensor_total  \
# 0            4463  ...              100.0              652           652
# 1            4463  ...              100.0              652           652
# 2            4463  ...              100.0              652           652
# 3            4463  ...              100.0              652           652
# 4            4463  ...              100.0              652           652
#
#    sensor_retention_%  skeleton_retained  skeleton_total  \
# 0               100.0               1879            1879
# 1               100.0               1879            1879
# 2               100.0               1879            1879
# 3               100.0               1879            1879
# 4               100.0               1879            1879
#
#    skeleton_retention_%  video_retained  video_total  video_retention_%
# 0                 100.0            1420         1420              100.0
# 1                 100.0            1420         1420              100.0
# 2                 100.0            1420         1420              100.0
# 3                 100.0            1420         1420              100.0
# 4                 100.0            1420         1420              100.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              82.13              8.96              80.79             10.29                 4463.00                      100.00              0.00                26.53                26.53          2425371.0                  9.26                        0.00               72.33
# mutual_info              87.58              5.31              86.99              5.81                 2231.00                       49.99             58.33                20.12                78.45          1282587.0                  4.90                       50.01               45.90
#         rfe              83.51              4.16              82.67              4.47                 2231.00                       49.99             10.18                20.92                31.10          1282587.0                  4.90                       50.01               45.90
#       lasso              68.56             16.53              66.26             17.70                 2231.00                       49.99             91.41                21.56               112.97          1282587.0                  4.90                       50.01               45.90
#    meta_BAT              82.71              4.23              81.24              4.28                 2232.12                       50.01           1410.52                22.52              1433.03          1283163.0                  4.90                       49.99               45.96
#     meta_CS              85.15              4.33              84.42              4.13                 2230.38                       49.97           2776.17                22.54              2798.71          1282267.0                  4.90                       50.03               45.95
#     meta_DE              82.37              8.04              81.04              9.31                 2212.00                       49.56           1408.38                22.57              1430.96          1272859.0                  4.86                       50.44               45.75
#    meta_FFA              84.69              6.35              83.42              7.19                 2205.62                       49.42           1361.02                22.54              1383.56          1269595.0                  4.85                       50.58               45.70
#     meta_GA              80.86             13.28              79.33             15.48                 2207.50                       49.46           1357.85                21.98              1379.83          1270555.0                  4.85                       50.54               45.72
#    meta_GWO              82.02              6.75              80.79              7.31                 1794.88                       40.22           1290.51                20.58              1311.10          1059291.0                  4.05                       59.78               40.80
#    meta_HHO              84.79              4.75              83.91              5.53                 1799.62                       40.32           1783.91                21.95              1805.86          1061723.0                  4.06                       59.68               41.29
#   meta_JAYA              85.37              3.93              84.57              4.35                 2208.12                       49.48           1410.21                22.59              1432.80          1270875.0                  4.85                       50.52               45.73
#    meta_MFO              80.63             15.88              79.09             17.35                 2245.62                       50.32           1329.34                22.50              1351.84          1290075.0                  4.93                       49.68               46.10
#    meta_MVO              86.30              3.57              85.42              3.61                 2200.12                       49.30           1366.53                22.52              1389.05          1266779.0                  4.84                       50.70               45.66
#    meta_PSO              80.04             10.78              78.36             12.02                 2203.88                       49.38           1341.56                21.18              1362.74          1268699.0                  4.85                       50.62               45.71
#    meta_SCA              85.03              2.96              84.26              3.60                 1387.25                       31.08           1180.12                20.75              1200.87           850587.0                  3.25                       68.92               36.04
#    meta_SSA              78.88             13.04              77.95             14.06                 2216.25                       49.66           3406.07                21.99              3428.06          1275035.0                  4.87                       50.34               45.82
#    meta_WOA              83.06              5.56              81.24              6.22                 2000.25                       44.82           1241.82                19.65              1261.47          1164443.0                  4.45                       55.18               43.41

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_FFA
#     F1 Macro:           90.32%
#     F1 Weighted:        90.32%
#     Test Accuracy:      90.74%
#     Feature Retention:  49.88% (2226/4463)
#     Modality Retention: depth=49.0%, sensor=44.9%, skeleton=51.3%, video=50.6%
#
#   Fold 2: Best = meta_MFO
#     F1 Macro:           81.59%
#     F1 Weighted:        81.59%
#     Test Accuracy:      83.33%
#     Feature Retention:  49.94% (2229/4463)
#     Modality Retention: depth=53.1%, sensor=48.3%, skeleton=49.8%, video=49.8%
#
#   Fold 3: Best = meta_MFO
#     F1 Macro:           85.78%
#     F1 Weighted:        85.78%
#     Test Accuracy:      86.11%
#     Feature Retention:  49.88% (2226/4463)
#     Modality Retention: depth=45.7%, sensor=50.6%, skeleton=50.7%, video=50.0%
#
#   Fold 4: Best = meta_HHO
#     F1 Macro:           86.88%
#     F1 Weighted:        86.88%
#     Test Accuracy:      86.11%
#     Feature Retention:  48.42% (2161/4463)
#     Modality Retention: depth=46.9%, sensor=48.9%, skeleton=48.6%, video=48.5%
#
#   Fold 5: Best = meta_MVO
#     F1 Macro:           90.12%
#     F1 Weighted:        90.12%
#     Test Accuracy:      90.74%
#     Feature Retention:  47.48% (2119/4463)
#     Modality Retention: depth=41.2%, sensor=47.2%, skeleton=48.9%, video=48.0%
#
#   Fold 6: Best = meta_WOA
#     F1 Macro:           89.60%
#     F1 Weighted:        89.50%
#     Test Accuracy:      89.72%
#     Feature Retention:  38.05% (1698/4463)
#     Modality Retention: depth=35.2%, sensor=36.3%, skeleton=39.3%, video=38.2%
#
#   Fold 7: Best = meta_WOA
#     F1 Macro:           90.48%
#     F1 Weighted:        90.52%
#     Test Accuracy:      91.59%
#     Feature Retention:  48.87% (2181/4463)
#     Modality Retention: depth=48.2%, sensor=46.9%, skeleton=48.7%, video=50.1%
#
#   Fold 8: Best = meta_MVO
#     F1 Macro:           90.35%
#     F1 Weighted:        90.73%
#     Test Accuracy:      91.59%
#     Feature Retention:  48.87% (2181/4463)
#     Modality Retention: depth=50.6%, sensor=50.8%, skeleton=48.3%, video=48.1%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 88.14% ± 3.19%
#
#   Average F1 Weighted         : 88.18% ± 3.23%
#
#   Average Test Accuracy       : 88.74% ± 3.12%
#
#   Average Feature Retention   : 47.67% ± 3.98%
#
#   Average Modality-wise Feature Retention:
#            depth: 46.24% ± 5.69%
#           sensor: 46.76% ± 4.63%
#         skeleton: 48.20% ± 3.76%
#            video: 47.90% ± 4.03%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  depth_retention_%  sensor_retention_%  skeleton_retention_%  video_retention_%
#     1           meta_FFA         90.32            90.32              90.74                  49.88              49.02               44.94                 51.30              50.56
#     2           meta_MFO         81.59            81.59              83.33                  49.94              53.12               48.31                 49.76              49.79
#     3           meta_MFO         85.78            85.78              86.11                  49.88              45.70               50.61                 50.67              50.00
#     4           meta_HHO         86.88            86.88              86.11                  48.42              46.88               48.93                 48.64              48.45
#     5           meta_MVO         90.12            90.12              90.74                  47.48              41.21               47.24                 48.91              47.96
#     6           meta_WOA         89.60            89.50              89.72                  38.05              35.16               36.35                 39.28              38.24
#     7           meta_WOA         90.48            90.52              91.59                  48.87              48.24               46.93                 48.75              50.14
#     8           meta_MVO         90.35            90.73              91.59                  48.87              50.59               50.77                 48.32              48.10
#
# Saved to: results_loss_30/best_metaheuristic_per_fold.csv
