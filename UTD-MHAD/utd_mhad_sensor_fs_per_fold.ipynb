# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (Sensor Features Only)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_per_fold_sensor")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions - SENSOR ONLY
first_sample = X_feat[0]
FEATURE_DIMS = {
'sensor': first_sample['sensor_feat'].shape[0],
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions (SENSOR ONLY):")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions (SENSOR ONLY):
#   sensor: 54
#   TOTAL: 54

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Use only sensor features"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['sensor_feat'],
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['sensor']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 79.63%, F1: 75.88%, Features: 54/54 (100.0%), Model: 0.068MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 27/54 (50.0%), Time: 0.3s
#     Test Acc: 82.41%, F1: 80.08%, Features: 27/54 (50.0%), Model: 0.055MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 27/54 (50.0%), Time: 0.1s
#     Test Acc: 82.41%, F1: 80.02%, Features: 27/54 (50.0%), Model: 0.055MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 27/54 (50.0%), Time: 0.0s
#     Test Acc: 73.15%, F1: 71.16%, Features: 27/54 (50.0%), Model: 0.055MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.12555555555555553']
# ['At iteration 1 the best fitness is 0.12555555555555553']
# ['At iteration 2 the best fitness is 0.12555555555555553']
# ['At iteration 3 the best fitness is 0.12555555555555553']
# ['At iteration 4 the best fitness is 0.12555555555555553']
# ['At iteration 5 the best fitness is 0.12555555555555553']
# ['At iteration 6 the best fitness is 0.12555555555555553']
# ['At iteration 7 the best fitness is 0.10918518518518519']
# ['At iteration 8 the best fitness is 0.10007407407407404']
# ['At iteration 9 the best fitness is 0.10007407407407404']
# ['At iteration 10 the best fitness is 0.10007407407407404']
# ['At iteration 11 the best fitness is 0.10007407407407404']
# ['At iteration 12 the best fitness is 0.10007407407407404']
# ['At iteration 13 the best fitness is 0.09374074074074076']
# ['At iteration 14 the best fitness is 0.09374074074074076']
# ['At iteration 15 the best fitness is 0.09374074074074076']
# ['At iteration 16 the best fitness is 0.09374074074074076']
# ['At iteration 17 the best fitness is 0.09374074074074076']
# ['At iteration 18 the best fitness is 0.09374074074074076']
# ['At iteration 19 the best fitness is 0.09374074074074076']
# ['At iteration 20 the best fitness is 0.09374074074074076']
# ['At iteration 21 the best fitness is 0.09374074074074076']
# ['At iteration 22 the best fitness is 0.09374074074074076']
# ['At iteration 23 the best fitness is 0.09374074074074076']
# ['At iteration 24 the best fitness is 0.09374074074074076']
# ['At iteration 25 the best fitness is 0.09374074074074076']
# ['At iteration 26 the best fitness is 0.09374074074074076']
# ['At iteration 27 the best fitness is 0.09374074074074076']
# ['At iteration 28 the best fitness is 0.09374074074074076']
# ['At iteration 29 the best fitness is 0.09374074074074076']
#       Selected: 26/54 (48.1%), Fitness: 0.0937, Time: 646.5s
#       Modality: D=48%
#     Test Acc: 78.70%, F1: 76.03%, Features: 26/54 (48.1%), Model: 0.054MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.10996296296296301']
# ['At iteration 10 the best fitness is 0.10996296296296301']
# ['At iteration 20 the best fitness is 0.10996296296296301']
#       Selected: 28/54 (51.9%), Fitness: 0.1010, Time: 1270.8s
#       Modality: D=52%
#     Test Acc: 73.15%, F1: 70.00%, Features: 28/54 (51.9%), Model: 0.055MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.11644444444444449']
# ['At iteration 2 the best fitness is 0.10548148148148148']
# ['At iteration 3 the best fitness is 0.10548148148148148']
# ['At iteration 4 the best fitness is 0.10548148148148148']
# ['At iteration 5 the best fitness is 0.10548148148148148']
# ['At iteration 6 the best fitness is 0.10007407407407404']
# ['At iteration 7 the best fitness is 0.10007407407407404']
# ['At iteration 8 the best fitness is 0.10007407407407404']
# ['At iteration 9 the best fitness is 0.10007407407407404']
# ['At iteration 10 the best fitness is 0.10007407407407404']
# ['At iteration 11 the best fitness is 0.10007407407407404']
# ['At iteration 12 the best fitness is 0.10007407407407404']
# ['At iteration 13 the best fitness is 0.10007407407407404']
# ['At iteration 14 the best fitness is 0.10007407407407404']
# ['At iteration 15 the best fitness is 0.10007407407407404']
# ['At iteration 16 the best fitness is 0.10007407407407404']
# ['At iteration 17 the best fitness is 0.10007407407407404']
# ['At iteration 18 the best fitness is 0.10007407407407404']
# ['At iteration 19 the best fitness is 0.10007407407407404']
# ['At iteration 20 the best fitness is 0.10007407407407404']
# ['At iteration 21 the best fitness is 0.10007407407407404']
# ['At iteration 22 the best fitness is 0.10007407407407404']
# ['At iteration 23 the best fitness is 0.08570370370370375']
# ['At iteration 24 the best fitness is 0.08570370370370375']
# ['At iteration 25 the best fitness is 0.08570370370370375']
# ['At iteration 26 the best fitness is 0.08570370370370375']
# ['At iteration 27 the best fitness is 0.08570370370370375']
# ['At iteration 28 the best fitness is 0.08570370370370375']
# ['At iteration 29 the best fitness is 0.08570370370370375']
# ['At iteration 30 the best fitness is 0.08570370370370375']
#       Selected: 28/54 (51.9%), Fitness: 0.0857, Time: 646.9s
#       Modality: D=52%
#     Test Acc: 77.78%, F1: 75.12%, Features: 28/54 (51.9%), Model: 0.055MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13359259259259254']
# ['At iteration 1 the best fitness is 0.14611111111111108']
# ['At iteration 2 the best fitness is 0.13899999999999998']
# ['At iteration 3 the best fitness is 0.11181481481481487']
# ['At iteration 4 the best fitness is 0.12262962962962964']
# ['At iteration 5 the best fitness is 0.13714814814814813']
# ['At iteration 6 the best fitness is 0.11814814814814813']
# ['At iteration 7 the best fitness is 0.09822222222222218']
# ['At iteration 8 the best fitness is 0.11088888888888894']
# ['At iteration 9 the best fitness is 0.12170370370370372']
# ['At iteration 10 the best fitness is 0.12355555555555557']
# ['At iteration 11 the best fitness is 0.1172222222222222']
# ['At iteration 12 the best fitness is 0.1172222222222222']
# ['At iteration 13 the best fitness is 0.1172222222222222']
# ['At iteration 14 the best fitness is 0.11088888888888894']
# ['At iteration 15 the best fitness is 0.11181481481481487']
# ['At iteration 16 the best fitness is 0.10548148148148148']
# ['At iteration 17 the best fitness is 0.11814814814814813']
# ['At iteration 18 the best fitness is 0.09914814814814811']
# ['At iteration 19 the best fitness is 0.11181481481481487']
# ['At iteration 20 the best fitness is 0.1172222222222222']
# ['At iteration 21 the best fitness is 0.10548148148148148']
# ['At iteration 22 the best fitness is 0.11088888888888894']
# ['At iteration 23 the best fitness is 0.1172222222222222']
# ['At iteration 24 the best fitness is 0.09188888888888892']
# ['At iteration 25 the best fitness is 0.1172222222222222']
# ['At iteration 26 the best fitness is 0.09822222222222218']
# ['At iteration 27 the best fitness is 0.10455555555555555']
# ['At iteration 28 the best fitness is 0.10455555555555555']
# ['At iteration 29 the best fitness is 0.10455555555555555']
#       Selected: 28/54 (51.9%), Fitness: 0.1046, Time: 627.5s
#       Modality: D=52%
#     Test Acc: 76.85%, F1: 73.88%, Features: 28/54 (51.9%), Model: 0.055MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.1209259259259259
# At iteration 2 the best fitness is 0.15259259259259256
# At iteration 3 the best fitness is 0.13807407407407407
# At iteration 4 the best fitness is 0.1201481481481482
# At iteration 5 the best fitness is 0.1318888888888889
# At iteration 6 the best fitness is 0.09559259259259262
# At iteration 7 the best fitness is 0.10470370370370366
# At iteration 8 the best fitness is 0.10192592592592588
# At iteration 9 the best fitness is 0.10192592592592588
# At iteration 10 the best fitness is 0.12725925925925927
# At iteration 11 the best fitness is 0.10918518518518519
# At iteration 12 the best fitness is 0.1246296296296296
# At iteration 13 the best fitness is 0.11829629629629634
# At iteration 14 the best fitness is 0.11459259259259263
# At iteration 15 the best fitness is 0.09744444444444447
# At iteration 16 the best fitness is 0.10455555555555555
# At iteration 17 the best fitness is 0.09929629629629633
# At iteration 18 the best fitness is 0.10733333333333334
# At iteration 19 the best fitness is 0.10377777777777773
# At iteration 20 the best fitness is 0.09559259259259262
# At iteration 21 the best fitness is 0.10825925925925925
# At iteration 22 the best fitness is 0.10192592592592588
# At iteration 23 the best fitness is 0.10825925925925925
# At iteration 24 the best fitness is 0.10918518518518519
# At iteration 25 the best fitness is 0.11907407407407405
# At iteration 26 the best fitness is 0.11907407407407405
# At iteration 27 the best fitness is 0.0946666666666667
# At iteration 28 the best fitness is 0.1028518518518518
# At iteration 29 the best fitness is 0.10192592592592588
# At iteration 30 the best fitness is 0.10099999999999995
#       Selected: 26/54 (48.1%), Fitness: 0.1010, Time: 626.1s
#       Modality: D=48%
#     Test Acc: 77.78%, F1: 76.99%, Features: 26/54 (48.1%), Model: 0.054MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13729629629629625']
# ['At iteration 1 the best fitness is 0.12725925925925927']
# ['At iteration 2 the best fitness is 0.11922222222222227']
# ['At iteration 3 the best fitness is 0.10192592592592588']
# ['At iteration 4 the best fitness is 0.10192592592592588']
# ['At iteration 5 the best fitness is 0.10192592592592588']
# ['At iteration 6 the best fitness is 0.10192592592592588']
# ['At iteration 7 the best fitness is 0.10192592592592588']
# ['At iteration 8 the best fitness is 0.10192592592592588']
# ['At iteration 9 the best fitness is 0.10099999999999995']
# ['At iteration 10 the best fitness is 0.10099999999999995']
# ['At iteration 11 the best fitness is 0.10099999999999995']
# ['At iteration 12 the best fitness is 0.10099999999999995']
# ['At iteration 13 the best fitness is 0.10099999999999995']
# ['At iteration 14 the best fitness is 0.10099999999999995']
# ['At iteration 15 the best fitness is 0.10099999999999995']
# ['At iteration 16 the best fitness is 0.10099999999999995']
# ['At iteration 17 the best fitness is 0.09374074074074076']
# ['At iteration 18 the best fitness is 0.09374074074074076']
# ['At iteration 19 the best fitness is 0.09374074074074076']
# ['At iteration 20 the best fitness is 0.09374074074074076']
# ['At iteration 21 the best fitness is 0.09374074074074076']
# ['At iteration 22 the best fitness is 0.09374074074074076']
# ['At iteration 23 the best fitness is 0.09374074074074076']
# ['At iteration 24 the best fitness is 0.09374074074074076']
# ['At iteration 25 the best fitness is 0.09374074074074076']
# ['At iteration 26 the best fitness is 0.08200000000000005']
# ['At iteration 27 the best fitness is 0.08200000000000005']
# ['At iteration 28 the best fitness is 0.08200000000000005']
# ['At iteration 29 the best fitness is 0.08200000000000005']
#       Selected: 28/54 (51.9%), Fitness: 0.0820, Time: 638.6s
#       Modality: D=52%
#     Test Acc: 73.15%, F1: 69.12%, Features: 28/54 (51.9%), Model: 0.055MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.1209259259259259']
# ['At iteration 1 the best fitness is 0.1209259259259259']
# ['At iteration 2 the best fitness is 0.1209259259259259']
# ['At iteration 3 the best fitness is 0.1209259259259259']
# ['At iteration 4 the best fitness is 0.11566666666666667']
# ['At iteration 5 the best fitness is 0.11566666666666667']
# ['At iteration 6 the best fitness is 0.11566666666666667']
# ['At iteration 7 the best fitness is 0.11566666666666667']
# ['At iteration 8 the best fitness is 0.11566666666666667']
# ['At iteration 9 the best fitness is 0.11566666666666667']
# ['At iteration 10 the best fitness is 0.11566666666666667']
# ['At iteration 11 the best fitness is 0.11566666666666667']
# ['At iteration 12 the best fitness is 0.10762962962962966']
# ['At iteration 13 the best fitness is 0.10762962962962966']
# ['At iteration 14 the best fitness is 0.10762962962962966']
# ['At iteration 15 the best fitness is 0.10762962962962966']
# ['At iteration 16 the best fitness is 0.10762962962962966']
# ['At iteration 17 the best fitness is 0.10762962962962966']
# ['At iteration 18 the best fitness is 0.10762962962962966']
# ['At iteration 19 the best fitness is 0.10762962962962966']
# ['At iteration 20 the best fitness is 0.10762962962962966']
# ['At iteration 21 the best fitness is 0.10762962962962966']
# ['At iteration 22 the best fitness is 0.10762962962962966']
# ['At iteration 23 the best fitness is 0.10762962962962966']
# ['At iteration 24 the best fitness is 0.10762962962962966']
# ['At iteration 25 the best fitness is 0.10762962962962966']
# ['At iteration 26 the best fitness is 0.10762962962962966']
# ['At iteration 27 the best fitness is 0.10314814814814813']
# ['At iteration 28 the best fitness is 0.10314814814814813']
# ['At iteration 29 the best fitness is 0.1022222222222222']
#       Selected: 42/54 (77.8%), Fitness: 0.1022, Time: 962.1s
#       Modality: D=78%
#     Test Acc: 71.30%, F1: 67.85%, Features: 42/54 (77.8%), Model: 0.062MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11196296296296296']
# ['At iteration 1 the best fitness is 0.11196296296296296']
# ['At iteration 2 the best fitness is 0.11196296296296296']
# ['At iteration 3 the best fitness is 0.10022222222222225']
# ['At iteration 4 the best fitness is 0.10022222222222225']
# ['At iteration 5 the best fitness is 0.0946666666666667']
# ['At iteration 6 the best fitness is 0.0946666666666667']
# ['At iteration 7 the best fitness is 0.0946666666666667']
# ['At iteration 8 the best fitness is 0.0946666666666667']
# ['At iteration 9 the best fitness is 0.0946666666666667']
# ['At iteration 10 the best fitness is 0.0946666666666667']
# ['At iteration 11 the best fitness is 0.0946666666666667']
# ['At iteration 12 the best fitness is 0.0946666666666667']
# ['At iteration 13 the best fitness is 0.0946666666666667']
# ['At iteration 14 the best fitness is 0.0946666666666667']
# ['At iteration 15 the best fitness is 0.0946666666666667']
# ['At iteration 16 the best fitness is 0.0946666666666667']
# ['At iteration 17 the best fitness is 0.0946666666666667']
# ['At iteration 18 the best fitness is 0.0946666666666667']
# ['At iteration 19 the best fitness is 0.0946666666666667']
# ['At iteration 20 the best fitness is 0.0838518518518519']
# ['At iteration 21 the best fitness is 0.0838518518518519']
# ['At iteration 22 the best fitness is 0.0838518518518519']
# ['At iteration 23 the best fitness is 0.0838518518518519']
# ['At iteration 24 the best fitness is 0.0838518518518519']
# ['At iteration 25 the best fitness is 0.0838518518518519']
# ['At iteration 26 the best fitness is 0.0838518518518519']
# ['At iteration 27 the best fitness is 0.0838518518518519']
# ['At iteration 28 the best fitness is 0.0838518518518519']
# ['At iteration 29 the best fitness is 0.0838518518518519']
#       Selected: 32/54 (59.3%), Fitness: 0.0839, Time: 703.5s
#       Modality: D=59%
#     Test Acc: 76.85%, F1: 74.57%, Features: 32/54 (59.3%), Model: 0.057MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.11381481481481481']
# ['At iteration 2 the best fitness is 0.11381481481481481']
# ['At iteration 3 the best fitness is 0.11381481481481481']
# ['At iteration 4 the best fitness is 0.11381481481481481']
# ['At iteration 5 the best fitness is 0.11381481481481481']
# ['At iteration 6 the best fitness is 0.11381481481481481']
# ['At iteration 7 the best fitness is 0.11381481481481481']
# ['At iteration 8 the best fitness is 0.11381481481481481']
# ['At iteration 9 the best fitness is 0.11274074074074078']
# ['At iteration 10 the best fitness is 0.09759259259259256']
# ['At iteration 11 the best fitness is 0.09759259259259256']
# ['At iteration 12 the best fitness is 0.09759259259259256']
# ['At iteration 13 the best fitness is 0.09759259259259256']
# ['At iteration 14 the best fitness is 0.09759259259259256']
# ['At iteration 15 the best fitness is 0.09759259259259256']
# ['At iteration 16 the best fitness is 0.09759259259259256']
# ['At iteration 17 the best fitness is 0.09759259259259256']
# ['At iteration 18 the best fitness is 0.09759259259259256']
# ['At iteration 19 the best fitness is 0.09759259259259256']
# ['At iteration 20 the best fitness is 0.09759259259259256']
# ['At iteration 21 the best fitness is 0.09759259259259256']
# ['At iteration 22 the best fitness is 0.09759259259259256']
# ['At iteration 23 the best fitness is 0.09759259259259256']
# ['At iteration 24 the best fitness is 0.09759259259259256']
# ['At iteration 25 the best fitness is 0.09759259259259256']
# ['At iteration 26 the best fitness is 0.09759259259259256']
# ['At iteration 27 the best fitness is 0.09759259259259256']
# ['At iteration 28 the best fitness is 0.09296296296296294']
# ['At iteration 29 the best fitness is 0.08662962962962968']
#       Selected: 34/54 (63.0%), Fitness: 0.0866, Time: 657.0s
#       Modality: D=63%
#     Test Acc: 76.85%, F1: 74.84%, Features: 34/54 (63.0%), Model: 0.058MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.13266666666666663']
# ['At iteration 2 the best fitness is 0.11288888888888889']
# ['At iteration 3 the best fitness is 0.11288888888888889']
# ['At iteration 4 the best fitness is 0.11196296296296296']
# ['At iteration 5 the best fitness is 0.09296296296296294']
# ['At iteration 6 the best fitness is 0.09296296296296294']
# ['At iteration 7 the best fitness is 0.09296296296296294']
# ['At iteration 8 the best fitness is 0.09296296296296294']
# ['At iteration 9 the best fitness is 0.09296296296296294']
# ['At iteration 10 the best fitness is 0.09296296296296294']
# ['At iteration 11 the best fitness is 0.09296296296296294']
# ['At iteration 12 the best fitness is 0.09296296296296294']
# ['At iteration 13 the best fitness is 0.09296296296296294']
# ['At iteration 14 the best fitness is 0.09296296296296294']
# ['At iteration 15 the best fitness is 0.09296296296296294']
# ['At iteration 16 the best fitness is 0.08940740740740746']
# ['At iteration 17 the best fitness is 0.08940740740740746']
# ['At iteration 18 the best fitness is 0.08940740740740746']
# ['At iteration 19 the best fitness is 0.08940740740740746']
# ['At iteration 20 the best fitness is 0.08940740740740746']
# ['At iteration 21 the best fitness is 0.08940740740740746']
# ['At iteration 22 the best fitness is 0.08755555555555561']
# ['At iteration 23 the best fitness is 0.08755555555555561']
# ['At iteration 24 the best fitness is 0.08755555555555561']
# ['At iteration 25 the best fitness is 0.08755555555555561']
# ['At iteration 26 the best fitness is 0.08755555555555561']
# ['At iteration 27 the best fitness is 0.08755555555555561']
# ['At iteration 28 the best fitness is 0.08755555555555561']
# ['At iteration 29 the best fitness is 0.08755555555555561']
# ['At iteration 30 the best fitness is 0.08755555555555561']
#       Selected: 32/54 (59.3%), Fitness: 0.0876, Time: 679.5s
#       Modality: D=59%
#     Test Acc: 78.70%, F1: 74.46%, Features: 32/54 (59.3%), Model: 0.057MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1209259259259259']
# ['At iteration 2 the best fitness is 0.1209259259259259']
# ['At iteration 3 the best fitness is 0.10903703703703709']
# ['At iteration 4 the best fitness is 0.10903703703703709']
# ['At iteration 5 the best fitness is 0.10007407407407404']
# ['At iteration 6 the best fitness is 0.10007407407407404']
# ['At iteration 7 the best fitness is 0.09914814814814811']
# ['At iteration 8 the best fitness is 0.09914814814814811']
# ['At iteration 9 the best fitness is 0.09914814814814811']
# ['At iteration 10 the best fitness is 0.09914814814814811']
# ['At iteration 11 the best fitness is 0.08029629629629631']
# ['At iteration 12 the best fitness is 0.08029629629629631']
# ['At iteration 13 the best fitness is 0.08029629629629631']
# ['At iteration 14 the best fitness is 0.07751851851851853']
# ['At iteration 15 the best fitness is 0.07751851851851853']
# ['At iteration 16 the best fitness is 0.062222222222222213']
# ['At iteration 17 the best fitness is 0.062222222222222213']
# ['At iteration 18 the best fitness is 0.062222222222222213']
# ['At iteration 19 the best fitness is 0.062222222222222213']
# ['At iteration 20 the best fitness is 0.062222222222222213']
# ['At iteration 21 the best fitness is 0.062222222222222213']
# ['At iteration 22 the best fitness is 0.062222222222222213']
# ['At iteration 23 the best fitness is 0.062222222222222213']
# ['At iteration 24 the best fitness is 0.062222222222222213']
# ['At iteration 25 the best fitness is 0.062222222222222213']
# ['At iteration 26 the best fitness is 0.062222222222222213']
# ['At iteration 27 the best fitness is 0.062222222222222213']
# ['At iteration 28 the best fitness is 0.062222222222222213']
# ['At iteration 29 the best fitness is 0.062222222222222213']
# ['At iteration 30 the best fitness is 0.062222222222222213']
#       Selected: 29/54 (53.7%), Fitness: 0.0622, Time: 680.3s
#       Modality: D=54%
#     Test Acc: 84.26%, F1: 83.28%, Features: 29/54 (53.7%), Model: 0.056MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.128037037037037']
# ['At iteration 1 the best fitness is 0.12633333333333335']
# ['At iteration 2 the best fitness is 0.12633333333333335']
# ['At iteration 3 the best fitness is 0.12633333333333335']
# ['At iteration 4 the best fitness is 0.12633333333333335']
# ['At iteration 5 the best fitness is 0.12633333333333335']
# ['At iteration 6 the best fitness is 0.12633333333333335']
# ['At iteration 7 the best fitness is 0.12633333333333335']
# ['At iteration 8 the best fitness is 0.12633333333333335']
# ['At iteration 9 the best fitness is 0.12077777777777779']
# ['At iteration 10 the best fitness is 0.12077777777777779']
# ['At iteration 11 the best fitness is 0.12077777777777779']
# ['At iteration 12 the best fitness is 0.12077777777777779']
# ['At iteration 13 the best fitness is 0.12077777777777779']
# ['At iteration 14 the best fitness is 0.12077777777777779']
# ['At iteration 15 the best fitness is 0.12077777777777779']
# ['At iteration 16 the best fitness is 0.12077777777777779']
# ['At iteration 17 the best fitness is 0.12077777777777779']
# ['At iteration 18 the best fitness is 0.12077777777777779']
# ['At iteration 19 the best fitness is 0.12077777777777779']
# ['At iteration 20 the best fitness is 0.12077777777777779']
# ['At iteration 21 the best fitness is 0.12077777777777779']
# ['At iteration 22 the best fitness is 0.12077777777777779']
# ['At iteration 23 the best fitness is 0.12077777777777779']
# ['At iteration 24 the best fitness is 0.12077777777777779']
# ['At iteration 25 the best fitness is 0.12077777777777779']
# ['At iteration 26 the best fitness is 0.12077777777777779']
# ['At iteration 27 the best fitness is 0.12077777777777779']
# ['At iteration 28 the best fitness is 0.12077777777777779']
# ['At iteration 29 the best fitness is 0.12077777777777779']
#       Selected: 21/54 (38.9%), Fitness: 0.1208, Time: 669.4s
#       Modality: D=39%
#     Test Acc: 80.56%, F1: 79.42%, Features: 21/54 (38.9%), Model: 0.052MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1020740740740741']
# ['At iteration 2 the best fitness is 0.1020740740740741']
# ['At iteration 3 the best fitness is 0.1020740740740741']
# ['At iteration 4 the best fitness is 0.1020740740740741']
# ['At iteration 5 the best fitness is 0.1020740740740741']
# ['At iteration 6 the best fitness is 0.1020740740740741']
# ['At iteration 7 the best fitness is 0.1020740740740741']
# ['At iteration 8 the best fitness is 0.1020740740740741']
# ['At iteration 9 the best fitness is 0.1020740740740741']
# ['At iteration 10 the best fitness is 0.1020740740740741']
# ['At iteration 11 the best fitness is 0.1020740740740741']
# ['At iteration 12 the best fitness is 0.1020740740740741']
# ['At iteration 13 the best fitness is 0.10114814814814818']
# ['At iteration 14 the best fitness is 0.0948148148148148']
# ['At iteration 15 the best fitness is 0.0948148148148148']
# ['At iteration 16 the best fitness is 0.0948148148148148']
# ['At iteration 17 the best fitness is 0.0948148148148148']
# ['At iteration 18 the best fitness is 0.0948148148148148']
# ['At iteration 19 the best fitness is 0.0948148148148148']
# ['At iteration 20 the best fitness is 0.0948148148148148']
# ['At iteration 21 the best fitness is 0.0948148148148148']
# ['At iteration 22 the best fitness is 0.0948148148148148']
# ['At iteration 23 the best fitness is 0.0948148148148148']
# ['At iteration 24 the best fitness is 0.0948148148148148']
# ['At iteration 25 the best fitness is 0.0948148148148148']
# ['At iteration 26 the best fitness is 0.0948148148148148']
# ['At iteration 27 the best fitness is 0.0948148148148148']
# ['At iteration 28 the best fitness is 0.0948148148148148']
# ['At iteration 29 the best fitness is 0.0948148148148148']
#       Selected: 32/54 (59.3%), Fitness: 0.0948, Time: 1704.3s
#       Modality: D=59%
#     Test Acc: 75.93%, F1: 73.19%, Features: 32/54 (59.3%), Model: 0.057MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.12633333333333335']
# ['At iteration 1 the best fitness is 0.124']
# ['At iteration 2 the best fitness is 0.1051481481481482']
# ['At iteration 3 the best fitness is 0.1051481481481482']
# ['At iteration 4 the best fitness is 0.09974074074074074']
# ['At iteration 5 the best fitness is 0.09974074074074074']
# ['At iteration 6 the best fitness is 0.09974074074074074']
# ['At iteration 7 the best fitness is 0.09248148148148144']
# ['At iteration 8 the best fitness is 0.09248148148148144']
# ['At iteration 9 the best fitness is 0.09248148148148144']
# ['At iteration 10 the best fitness is 0.09248148148148144']
# ['At iteration 11 the best fitness is 0.08614814814814818']
# ['At iteration 12 the best fitness is 0.08614814814814818']
# ['At iteration 13 the best fitness is 0.08614814814814818']
# ['At iteration 14 the best fitness is 0.08614814814814818']
# ['At iteration 15 the best fitness is 0.08614814814814818']
# ['At iteration 16 the best fitness is 0.08614814814814818']
# ['At iteration 17 the best fitness is 0.08614814814814818']
# ['At iteration 18 the best fitness is 0.08614814814814818']
# ['At iteration 19 the best fitness is 0.08614814814814818']
# ['At iteration 20 the best fitness is 0.08614814814814818']
# ['At iteration 21 the best fitness is 0.08614814814814818']
# ['At iteration 22 the best fitness is 0.08614814814814818']
# ['At iteration 23 the best fitness is 0.08614814814814818']
# ['At iteration 24 the best fitness is 0.08614814814814818']
# ['At iteration 25 the best fitness is 0.08614814814814818']
# ['At iteration 26 the best fitness is 0.08614814814814818']
# ['At iteration 27 the best fitness is 0.08614814814814818']
# ['At iteration 28 the best fitness is 0.08614814814814818']
# ['At iteration 29 the best fitness is 0.08614814814814818']
#       Selected: 49/54 (90.7%), Fitness: 0.0861, Time: 646.5s
#       Modality: D=91%
#     Test Acc: 82.41%, F1: 78.25%, Features: 49/54 (90.7%), Model: 0.066MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 75.93%, F1: 70.78%, Features: 54/54 (100.0%), Model: 0.068MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 27/54 (50.0%), Time: 0.3s
#     Test Acc: 66.67%, F1: 60.61%, Features: 27/54 (50.0%), Model: 0.055MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 27/54 (50.0%), Time: 0.1s
#     Test Acc: 81.48%, F1: 78.78%, Features: 27/54 (50.0%), Model: 0.055MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 27/54 (50.0%), Time: 0.0s
#     Test Acc: 59.26%, F1: 54.41%, Features: 27/54 (50.0%), Model: 0.055MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06855555555555559']
# ['At iteration 1 the best fitness is 0.06855555555555559']
# ['At iteration 2 the best fitness is 0.06855555555555559']
# ['At iteration 3 the best fitness is 0.06855555555555559']
# ['At iteration 4 the best fitness is 0.06855555555555559']
# ['At iteration 5 the best fitness is 0.06855555555555559']
# ['At iteration 6 the best fitness is 0.06855555555555559']
# ['At iteration 7 the best fitness is 0.06855555555555559']
# ['At iteration 8 the best fitness is 0.06855555555555559']
# ['At iteration 9 the best fitness is 0.06855555555555559']
# ['At iteration 10 the best fitness is 0.06855555555555559']
# ['At iteration 11 the best fitness is 0.06855555555555559']
# ['At iteration 12 the best fitness is 0.06855555555555559']
# ['At iteration 13 the best fitness is 0.06855555555555559']
# ['At iteration 14 the best fitness is 0.06855555555555559']
# ['At iteration 15 the best fitness is 0.06855555555555559']
# ['At iteration 16 the best fitness is 0.06855555555555559']
# ['At iteration 17 the best fitness is 0.06855555555555559']
# ['At iteration 18 the best fitness is 0.06855555555555559']
# ['At iteration 19 the best fitness is 0.06855555555555559']
# ['At iteration 20 the best fitness is 0.06855555555555559']
# ['At iteration 21 the best fitness is 0.06855555555555559']
# ['At iteration 22 the best fitness is 0.06855555555555559']
# ['At iteration 23 the best fitness is 0.06855555555555559']
# ['At iteration 24 the best fitness is 0.06855555555555559']
# ['At iteration 25 the best fitness is 0.06855555555555559']
# ['At iteration 26 the best fitness is 0.06855555555555559']
# ['At iteration 27 the best fitness is 0.06855555555555559']
# ['At iteration 28 the best fitness is 0.06855555555555559']
# ['At iteration 29 the best fitness is 0.06855555555555559']
#       Selected: 32/54 (59.3%), Fitness: 0.0686, Time: 701.6s
#       Modality: D=59%
#     Test Acc: 79.63%, F1: 75.43%, Features: 32/54 (59.3%), Model: 0.057MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07025925925925923']
# ['At iteration 10 the best fitness is 0.07025925925925923']
# ['At iteration 20 the best fitness is 0.06948148148148152']
#       Selected: 31/54 (57.4%), Fitness: 0.0686, Time: 1381.9s
#       Modality: D=57%
#     Test Acc: 71.30%, F1: 66.36%, Features: 31/54 (57.4%), Model: 0.057MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09111111111111109']
# ['At iteration 2 the best fitness is 0.08755555555555561']
# ['At iteration 3 the best fitness is 0.08755555555555561']
# ['At iteration 4 the best fitness is 0.08570370370370375']
# ['At iteration 5 the best fitness is 0.07581481481481478']
# ['At iteration 6 the best fitness is 0.07025925925925923']
# ['At iteration 7 the best fitness is 0.07025925925925923']
# ['At iteration 8 the best fitness is 0.07025925925925923']
# ['At iteration 9 the best fitness is 0.05944444444444444']
# ['At iteration 10 the best fitness is 0.05944444444444444']
# ['At iteration 11 the best fitness is 0.05944444444444444']
# ['At iteration 12 the best fitness is 0.05944444444444444']
# ['At iteration 13 the best fitness is 0.05944444444444444']
# ['At iteration 14 the best fitness is 0.05944444444444444']
# ['At iteration 15 the best fitness is 0.05944444444444444']
# ['At iteration 16 the best fitness is 0.05944444444444444']
# ['At iteration 17 the best fitness is 0.05944444444444444']
# ['At iteration 18 the best fitness is 0.05944444444444444']
# ['At iteration 19 the best fitness is 0.05944444444444444']
# ['At iteration 20 the best fitness is 0.05944444444444444']
# ['At iteration 21 the best fitness is 0.05944444444444444']
# ['At iteration 22 the best fitness is 0.05944444444444444']
# ['At iteration 23 the best fitness is 0.05944444444444444']
# ['At iteration 24 the best fitness is 0.05944444444444444']
# ['At iteration 25 the best fitness is 0.05944444444444444']
# ['At iteration 26 the best fitness is 0.05944444444444444']
# ['At iteration 27 the best fitness is 0.05944444444444444']
# ['At iteration 28 the best fitness is 0.05944444444444444']
# ['At iteration 29 the best fitness is 0.05944444444444444']
# ['At iteration 30 the best fitness is 0.05944444444444444']
#       Selected: 32/54 (59.3%), Fitness: 0.0594, Time: 703.9s
#       Modality: D=59%
#     Test Acc: 73.15%, F1: 69.15%, Features: 32/54 (59.3%), Model: 0.057MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07118518518518516']
# ['At iteration 1 the best fitness is 0.07844444444444446']
# ['At iteration 2 the best fitness is 0.08677777777777779']
# ['At iteration 3 the best fitness is 0.08044444444444442']
# ['At iteration 4 the best fitness is 0.08137037037037034']
# ['At iteration 5 the best fitness is 0.0722592592592593']
# ['At iteration 6 the best fitness is 0.08214814814814816']
# ['At iteration 7 the best fitness is 0.08122222222222222']
# ['At iteration 8 the best fitness is 0.08122222222222222']
# ['At iteration 9 the best fitness is 0.09388888888888887']
# ['At iteration 10 the best fitness is 0.06855555555555559']
# ['At iteration 11 the best fitness is 0.08755555555555561']
# ['At iteration 12 the best fitness is 0.08755555555555561']
# ['At iteration 13 the best fitness is 0.08122222222222222']
# ['At iteration 14 the best fitness is 0.08122222222222222']
# ['At iteration 15 the best fitness is 0.08755555555555561']
# ['At iteration 16 the best fitness is 0.08122222222222222']
# ['At iteration 17 the best fitness is 0.08755555555555561']
# ['At iteration 18 the best fitness is 0.08755555555555561']
# ['At iteration 19 the best fitness is 0.08122222222222222']
# ['At iteration 20 the best fitness is 0.07488888888888887']
# ['At iteration 21 the best fitness is 0.09388888888888887']
# ['At iteration 22 the best fitness is 0.08122222222222222']
# ['At iteration 23 the best fitness is 0.09388888888888887']
# ['At iteration 24 the best fitness is 0.09388888888888887']
# ['At iteration 25 the best fitness is 0.07488888888888887']
# ['At iteration 26 the best fitness is 0.08122222222222222']
# ['At iteration 27 the best fitness is 0.08755555555555561']
# ['At iteration 28 the best fitness is 0.10022222222222225']
# ['At iteration 29 the best fitness is 0.09388888888888887']
#       Selected: 34/54 (63.0%), Fitness: 0.0939, Time: 681.8s
#       Modality: D=63%
#     Test Acc: 75.93%, F1: 71.51%, Features: 34/54 (63.0%), Model: 0.058MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.061296296296296286
# At iteration 2 the best fitness is 0.07381481481481482
# At iteration 3 the best fitness is 0.07381481481481482
# At iteration 4 the best fitness is 0.07751851851851853
# At iteration 5 the best fitness is 0.0838518518518519
# At iteration 6 the best fitness is 0.09018518518518517
# At iteration 7 the best fitness is 0.0765925925925926
# At iteration 8 the best fitness is 0.05311111111111107
# At iteration 9 the best fitness is 0.07474074074074075
# At iteration 10 the best fitness is 0.08029629629629631
# At iteration 11 the best fitness is 0.07581481481481478
# At iteration 12 the best fitness is 0.0765925925925926
# At iteration 13 the best fitness is 0.07488888888888887
# At iteration 14 the best fitness is 0.07751851851851853
# At iteration 15 the best fitness is 0.07025925925925923
# At iteration 16 the best fitness is 0.0838518518518519
# At iteration 17 the best fitness is 0.07118518518518516
# At iteration 18 the best fitness is 0.07118518518518516
# At iteration 19 the best fitness is 0.07488888888888887
# At iteration 20 the best fitness is 0.08029629629629631
# At iteration 21 the best fitness is 0.08214814814814816
# At iteration 22 the best fitness is 0.07844444444444446
# At iteration 23 the best fitness is 0.08122222222222222
# At iteration 24 the best fitness is 0.07937037037037037
# At iteration 25 the best fitness is 0.05403703703703699
# At iteration 26 the best fitness is 0.06762962962962966
# At iteration 27 the best fitness is 0.07937037037037037
# At iteration 28 the best fitness is 0.07937037037037037
# At iteration 29 the best fitness is 0.062222222222222213
# At iteration 30 the best fitness is 0.07488888888888887
#       Selected: 28/54 (51.9%), Fitness: 0.0749, Time: 682.7s
#       Modality: D=52%
#     Test Acc: 76.85%, F1: 73.84%, Features: 28/54 (51.9%), Model: 0.055MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07922222222222228']
# ['At iteration 1 the best fitness is 0.06655555555555552']
# ['At iteration 2 the best fitness is 0.06655555555555552']
# ['At iteration 3 the best fitness is 0.06655555555555552']
# ['At iteration 4 the best fitness is 0.06655555555555552']
# ['At iteration 5 the best fitness is 0.06655555555555552']
# ['At iteration 6 the best fitness is 0.06655555555555552']
# ['At iteration 7 the best fitness is 0.06655555555555552']
# ['At iteration 8 the best fitness is 0.06655555555555552']
# ['At iteration 9 the best fitness is 0.06655555555555552']
# ['At iteration 10 the best fitness is 0.06655555555555552']
# ['At iteration 11 the best fitness is 0.06655555555555552']
# ['At iteration 12 the best fitness is 0.06655555555555552']
# ['At iteration 13 the best fitness is 0.05744444444444448']
# ['At iteration 14 the best fitness is 0.05744444444444448']
# ['At iteration 15 the best fitness is 0.05744444444444448']
# ['At iteration 16 the best fitness is 0.05744444444444448']
# ['At iteration 17 the best fitness is 0.05744444444444448']
# ['At iteration 18 the best fitness is 0.05744444444444448']
# ['At iteration 19 the best fitness is 0.05744444444444448']
# ['At iteration 20 the best fitness is 0.05744444444444448']
# ['At iteration 21 the best fitness is 0.05744444444444448']
# ['At iteration 22 the best fitness is 0.05744444444444448']
# ['At iteration 23 the best fitness is 0.05744444444444448']
# ['At iteration 24 the best fitness is 0.05744444444444448']
# ['At iteration 25 the best fitness is 0.05744444444444448']
# ['At iteration 26 the best fitness is 0.05744444444444448']
# ['At iteration 27 the best fitness is 0.05744444444444448']
# ['At iteration 28 the best fitness is 0.05744444444444448']
# ['At iteration 29 the best fitness is 0.05744444444444448']
#       Selected: 29/54 (53.7%), Fitness: 0.0574, Time: 677.7s
#       Modality: D=54%
#     Test Acc: 73.15%, F1: 69.04%, Features: 29/54 (53.7%), Model: 0.056MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.07844444444444446']
# ['At iteration 1 the best fitness is 0.07751851851851853']
# ['At iteration 2 the best fitness is 0.07148148148148148']
# ['At iteration 3 the best fitness is 0.07148148148148148']
# ['At iteration 4 the best fitness is 0.07148148148148148']
# ['At iteration 5 the best fitness is 0.07148148148148148']
# ['At iteration 6 the best fitness is 0.07148148148148148']
# ['At iteration 7 the best fitness is 0.07148148148148148']
# ['At iteration 8 the best fitness is 0.07148148148148148']
# ['At iteration 9 the best fitness is 0.07148148148148148']
# ['At iteration 10 the best fitness is 0.07148148148148148']
# ['At iteration 11 the best fitness is 0.07148148148148148']
# ['At iteration 12 the best fitness is 0.07148148148148148']
# ['At iteration 13 the best fitness is 0.07148148148148148']
# ['At iteration 14 the best fitness is 0.06962962962962962']
# ['At iteration 15 the best fitness is 0.06962962962962962']
# ['At iteration 16 the best fitness is 0.06962962962962962']
# ['At iteration 17 the best fitness is 0.06962962962962962']
# ['At iteration 18 the best fitness is 0.06962962962962962']
# ['At iteration 19 the best fitness is 0.06437037037037038']
# ['At iteration 20 the best fitness is 0.06437037037037038']
# ['At iteration 21 the best fitness is 0.06437037037037038']
# ['At iteration 22 the best fitness is 0.06437037037037038']
# ['At iteration 23 the best fitness is 0.06437037037037038']
# ['At iteration 24 the best fitness is 0.06437037037037038']
# ['At iteration 25 the best fitness is 0.06437037037037038']
# ['At iteration 26 the best fitness is 0.06437037037037038']
# ['At iteration 27 the best fitness is 0.06437037037037038']
# ['At iteration 28 the best fitness is 0.06437037037037038']
# ['At iteration 29 the best fitness is 0.06437037037037038']
#       Selected: 51/54 (94.4%), Fitness: 0.0644, Time: 929.6s
#       Modality: D=94%
#     Test Acc: 75.00%, F1: 70.17%, Features: 51/54 (94.4%), Model: 0.067MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08848148148148154']
# ['At iteration 1 the best fitness is 0.08585185185185186']
# ['At iteration 2 the best fitness is 0.08585185185185186']
# ['At iteration 3 the best fitness is 0.08585185185185186']
# ['At iteration 4 the best fitness is 0.08214814814814816']
# ['At iteration 5 the best fitness is 0.08214814814814816']
# ['At iteration 6 the best fitness is 0.08214814814814816']
# ['At iteration 7 the best fitness is 0.08214814814814816']
# ['At iteration 8 the best fitness is 0.08214814814814816']
# ['At iteration 9 the best fitness is 0.07318518518518521']
# ['At iteration 10 the best fitness is 0.07318518518518521']
# ['At iteration 11 the best fitness is 0.07318518518518521']
# ['At iteration 12 the best fitness is 0.07318518518518521']
# ['At iteration 13 the best fitness is 0.07318518518518521']
# ['At iteration 14 the best fitness is 0.07318518518518521']
# ['At iteration 15 the best fitness is 0.07318518518518521']
# ['At iteration 16 the best fitness is 0.07318518518518521']
# ['At iteration 17 the best fitness is 0.07318518518518521']
# ['At iteration 18 the best fitness is 0.05866666666666662']
# ['At iteration 19 the best fitness is 0.05866666666666662']
# ['At iteration 20 the best fitness is 0.05866666666666662']
# ['At iteration 21 the best fitness is 0.05866666666666662']
# ['At iteration 22 the best fitness is 0.05866666666666662']
# ['At iteration 23 the best fitness is 0.05866666666666662']
# ['At iteration 24 the best fitness is 0.05866666666666662']
# ['At iteration 25 the best fitness is 0.05866666666666662']
# ['At iteration 26 the best fitness is 0.05866666666666662']
# ['At iteration 27 the best fitness is 0.05866666666666662']
# ['At iteration 28 the best fitness is 0.05866666666666662']
# ['At iteration 29 the best fitness is 0.05866666666666662']
#       Selected: 33/54 (61.1%), Fitness: 0.0587, Time: 703.0s
#       Modality: D=61%
#     Test Acc: 74.07%, F1: 70.66%, Features: 33/54 (61.1%), Model: 0.058MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07118518518518516']
# ['At iteration 2 the best fitness is 0.07118518518518516']
# ['At iteration 3 the best fitness is 0.07118518518518516']
# ['At iteration 4 the best fitness is 0.07118518518518516']
# ['At iteration 5 the best fitness is 0.06485185185185188']
# ['At iteration 6 the best fitness is 0.06485185185185188']
# ['At iteration 7 the best fitness is 0.06485185185185188']
# ['At iteration 8 the best fitness is 0.06485185185185188']
# ['At iteration 9 the best fitness is 0.06485185185185188']
# ['At iteration 10 the best fitness is 0.06485185185185188']
# ['At iteration 11 the best fitness is 0.06485185185185188']
# ['At iteration 12 the best fitness is 0.06485185185185188']
# ['At iteration 13 the best fitness is 0.06485185185185188']
# ['At iteration 14 the best fitness is 0.06485185185185188']
# ['At iteration 15 the best fitness is 0.06485185185185188']
# ['At iteration 16 the best fitness is 0.06485185185185188']
# ['At iteration 17 the best fitness is 0.06485185185185188']
# ['At iteration 18 the best fitness is 0.06485185185185188']
# ['At iteration 19 the best fitness is 0.06485185185185188']
# ['At iteration 20 the best fitness is 0.06485185185185188']
# ['At iteration 21 the best fitness is 0.06485185185185188']
# ['At iteration 22 the best fitness is 0.06485185185185188']
# ['At iteration 23 the best fitness is 0.06485185185185188']
# ['At iteration 24 the best fitness is 0.06485185185185188']
# ['At iteration 25 the best fitness is 0.06485185185185188']
# ['At iteration 26 the best fitness is 0.06485185185185188']
# ['At iteration 27 the best fitness is 0.06485185185185188']
# ['At iteration 28 the best fitness is 0.06485185185185188']
# ['At iteration 29 the best fitness is 0.06485185185185188']
#       Selected: 27/54 (50.0%), Fitness: 0.0649, Time: 660.2s
#       Modality: D=50%
#     Test Acc: 73.15%, F1: 68.23%, Features: 27/54 (50.0%), Model: 0.055MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07937037037037037']
# ['At iteration 2 the best fitness is 0.07937037037037037']
# ['At iteration 3 the best fitness is 0.07844444444444446']
# ['At iteration 4 the best fitness is 0.07751851851851853']
# ['At iteration 5 the best fitness is 0.07751851851851853']
# ['At iteration 6 the best fitness is 0.0765925925925926']
# ['At iteration 7 the best fitness is 0.0765925925925926']
# ['At iteration 8 the best fitness is 0.07488888888888887']
# ['At iteration 9 the best fitness is 0.07303703703703701']
# ['At iteration 10 the best fitness is 0.07118518518518516']
# ['At iteration 11 the best fitness is 0.07118518518518516']
# ['At iteration 12 the best fitness is 0.07118518518518516']
# ['At iteration 13 the best fitness is 0.07025925925925923']
# ['At iteration 14 the best fitness is 0.06485185185185188']
# ['At iteration 15 the best fitness is 0.06485185185185188']
# ['At iteration 16 the best fitness is 0.06485185185185188']
# ['At iteration 17 the best fitness is 0.06485185185185188']
# ['At iteration 18 the best fitness is 0.06485185185185188']
# ['At iteration 19 the best fitness is 0.05851851851851851']
# ['At iteration 20 the best fitness is 0.05851851851851851']
# ['At iteration 21 the best fitness is 0.05851851851851851']
# ['At iteration 22 the best fitness is 0.05851851851851851']
# ['At iteration 23 the best fitness is 0.05851851851851851']
# ['At iteration 24 the best fitness is 0.05851851851851851']
# ['At iteration 25 the best fitness is 0.05851851851851851']
# ['At iteration 26 the best fitness is 0.05851851851851851']
# ['At iteration 27 the best fitness is 0.05851851851851851']
# ['At iteration 28 the best fitness is 0.05851851851851851']
# ['At iteration 29 the best fitness is 0.05851851851851851']
# ['At iteration 30 the best fitness is 0.05851851851851851']
#       Selected: 30/54 (55.6%), Fitness: 0.0585, Time: 680.5s
#       Modality: D=56%
# ...
# ['At iteration 10 the best fitness is 0.09140740740740741']
# ['At iteration 11 the best fitness is 0.09140740740740741']
# ['At iteration 12 the best fitness is 0.09140740740740741']
# ['At iteration 13 the best fitness is 0.09140740740740741']
# ['At iteration 14 the best fitness is 0.09140740740740741']
# ['At iteration 15 the best fitness is 0.09140740740740741']
# ['At iteration 16 the best fitness is 0.09140740740740741']
# ['At iteration 17 the best fitness is 0.09140740740740741']
# ['At iteration 18 the best fitness is 0.09140740740740741']
# ['At iteration 19 the best fitness is 0.09140740740740741']
# ['At iteration 20 the best fitness is 0.09140740740740741']
# ['At iteration 21 the best fitness is 0.09140740740740741']
# ['At iteration 22 the best fitness is 0.09140740740740741']
# ['At iteration 23 the best fitness is 0.09140740740740741']
# ['At iteration 24 the best fitness is 0.09140740740740741']
# ['At iteration 25 the best fitness is 0.09140740740740741']
# ['At iteration 26 the best fitness is 0.09140740740740741']
# ['At iteration 27 the best fitness is 0.09140740740740741']
# ['At iteration 28 the best fitness is 0.09140740740740741']
# ['At iteration 29 the best fitness is 0.09140740740740741']
#       Selected: 44/54 (81.5%), Fitness: 0.0914, Time: 973.6s
#       Modality: D=81%
#     Test Acc: 81.31%, F1: 76.62%, Features: 44/54 (81.5%), Model: 0.063MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.11922222222222227']
# ['At iteration 1 the best fitness is 0.11922222222222227']
# ['At iteration 2 the best fitness is 0.10377777777777773']
# ['At iteration 3 the best fitness is 0.10377777777777773']
# ['At iteration 4 the best fitness is 0.10377777777777773']
# ['At iteration 5 the best fitness is 0.09651851851851856']
# ['At iteration 6 the best fitness is 0.09651851851851856']
# ['At iteration 7 the best fitness is 0.09651851851851856']
# ['At iteration 8 the best fitness is 0.09651851851851856']
# ['At iteration 9 the best fitness is 0.09651851851851856']
# ['At iteration 10 the best fitness is 0.09651851851851856']
# ['At iteration 11 the best fitness is 0.09651851851851856']
# ['At iteration 12 the best fitness is 0.09651851851851856']
# ['At iteration 13 the best fitness is 0.09651851851851856']
# ['At iteration 14 the best fitness is 0.09651851851851856']
# ['At iteration 15 the best fitness is 0.09651851851851856']
# ['At iteration 16 the best fitness is 0.09651851851851856']
# ['At iteration 17 the best fitness is 0.09651851851851856']
# ['At iteration 18 the best fitness is 0.09651851851851856']
# ['At iteration 19 the best fitness is 0.09651851851851856']
# ['At iteration 20 the best fitness is 0.09651851851851856']
# ['At iteration 21 the best fitness is 0.09651851851851856']
# ['At iteration 22 the best fitness is 0.09651851851851856']
# ['At iteration 23 the best fitness is 0.09651851851851856']
# ['At iteration 24 the best fitness is 0.09651851851851856']
# ['At iteration 25 the best fitness is 0.09651851851851856']
# ['At iteration 26 the best fitness is 0.09651851851851856']
# ['At iteration 27 the best fitness is 0.09651851851851856']
# ['At iteration 28 the best fitness is 0.09651851851851856']
# ['At iteration 29 the best fitness is 0.09651851851851856']
#       Selected: 29/54 (53.7%), Fitness: 0.0965, Time: 709.9s
#       Modality: D=54%
#     Test Acc: 83.18%, F1: 79.09%, Features: 29/54 (53.7%), Model: 0.056MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.14718518518518522']
# ['At iteration 2 the best fitness is 0.1436296296296296']
# ['At iteration 3 the best fitness is 0.13992592592592593']
# ['At iteration 4 the best fitness is 0.1020740740740741']
# ['At iteration 5 the best fitness is 0.1020740740740741']
# ['At iteration 6 the best fitness is 0.1020740740740741']
# ['At iteration 7 the best fitness is 0.1020740740740741']
# ['At iteration 8 the best fitness is 0.1020740740740741']
# ['At iteration 9 the best fitness is 0.1020740740740741']
# ['At iteration 10 the best fitness is 0.1020740740740741']
# ['At iteration 11 the best fitness is 0.1020740740740741']
# ['At iteration 12 the best fitness is 0.1020740740740741']
# ['At iteration 13 the best fitness is 0.1020740740740741']
# ['At iteration 14 the best fitness is 0.1020740740740741']
# ['At iteration 15 the best fitness is 0.1020740740740741']
# ['At iteration 16 the best fitness is 0.1020740740740741']
# ['At iteration 17 the best fitness is 0.1020740740740741']
# ['At iteration 18 the best fitness is 0.08848148148148154']
# ['At iteration 19 the best fitness is 0.08848148148148154']
# ['At iteration 20 the best fitness is 0.08848148148148154']
# ['At iteration 21 the best fitness is 0.08848148148148154']
# ['At iteration 22 the best fitness is 0.08848148148148154']
# ['At iteration 23 the best fitness is 0.08848148148148154']
# ['At iteration 24 the best fitness is 0.08848148148148154']
# ['At iteration 25 the best fitness is 0.08848148148148154']
# ['At iteration 26 the best fitness is 0.08848148148148154']
# ['At iteration 27 the best fitness is 0.08848148148148154']
# ['At iteration 28 the best fitness is 0.08848148148148154']
# ['At iteration 29 the best fitness is 0.08848148148148154']
#       Selected: 32/54 (59.3%), Fitness: 0.0885, Time: 667.8s
#       Modality: D=59%
#     Test Acc: 85.05%, F1: 83.30%, Features: 32/54 (59.3%), Model: 0.057MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.14177777777777778']
# ['At iteration 2 the best fitness is 0.13096296296296298']
# ['At iteration 3 the best fitness is 0.11288888888888889']
# ['At iteration 4 the best fitness is 0.11288888888888889']
# ['At iteration 5 the best fitness is 0.11288888888888889']
# ['At iteration 6 the best fitness is 0.11288888888888889']
# ['At iteration 7 the best fitness is 0.11288888888888889']
# ['At iteration 8 the best fitness is 0.10918518518518519']
# ['At iteration 9 the best fitness is 0.10918518518518519']
# ['At iteration 10 the best fitness is 0.10918518518518519']
# ['At iteration 11 the best fitness is 0.10918518518518519']
# ['At iteration 12 the best fitness is 0.10918518518518519']
# ['At iteration 13 the best fitness is 0.10470370370370366']
# ['At iteration 14 the best fitness is 0.09388888888888887']
# ['At iteration 15 the best fitness is 0.09388888888888887']
# ['At iteration 16 the best fitness is 0.09388888888888887']
# ['At iteration 17 the best fitness is 0.09388888888888887']
# ['At iteration 18 the best fitness is 0.09388888888888887']
# ['At iteration 19 the best fitness is 0.09388888888888887']
# ['At iteration 20 the best fitness is 0.09388888888888887']
# ['At iteration 21 the best fitness is 0.09388888888888887']
# ['At iteration 22 the best fitness is 0.09388888888888887']
# ['At iteration 23 the best fitness is 0.09388888888888887']
# ['At iteration 24 the best fitness is 0.09388888888888887']
# ['At iteration 25 the best fitness is 0.09388888888888887']
# ['At iteration 26 the best fitness is 0.09388888888888887']
# ['At iteration 27 the best fitness is 0.08755555555555561']
# ['At iteration 28 the best fitness is 0.08755555555555561']
# ['At iteration 29 the best fitness is 0.08755555555555561']
# ['At iteration 30 the best fitness is 0.08755555555555561']
#       Selected: 27/54 (50.0%), Fitness: 0.0876, Time: 679.9s
#       Modality: D=50%
#     Test Acc: 87.85%, F1: 86.12%, Features: 27/54 (50.0%), Model: 0.055MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.12262962962962964']
# ['At iteration 2 the best fitness is 0.12262962962962964']
# ['At iteration 3 the best fitness is 0.11644444444444449']
# ['At iteration 4 the best fitness is 0.10918518518518519']
# ['At iteration 5 the best fitness is 0.10470370370370366']
# ['At iteration 6 the best fitness is 0.10470370370370366']
# ['At iteration 7 the best fitness is 0.1028518518518518']
# ['At iteration 8 the best fitness is 0.1028518518518518']
# ['At iteration 9 the best fitness is 0.10192592592592588']
# ['At iteration 10 the best fitness is 0.10192592592592588']
# ['At iteration 11 the best fitness is 0.10192592592592588']
# ['At iteration 12 the best fitness is 0.10192592592592588']
# ['At iteration 13 the best fitness is 0.09559259259259262']
# ['At iteration 14 the best fitness is 0.09559259259259262']
# ['At iteration 15 the best fitness is 0.09559259259259262']
# ['At iteration 16 the best fitness is 0.09559259259259262']
# ['At iteration 17 the best fitness is 0.09559259259259262']
# ['At iteration 18 the best fitness is 0.09559259259259262']
# ['At iteration 19 the best fitness is 0.09559259259259262']
# ['At iteration 20 the best fitness is 0.09559259259259262']
# ['At iteration 21 the best fitness is 0.09559259259259262']
# ['At iteration 22 the best fitness is 0.09559259259259262']
# ['At iteration 23 the best fitness is 0.09559259259259262']
# ['At iteration 24 the best fitness is 0.09559259259259262']
# ['At iteration 25 the best fitness is 0.09559259259259262']
# ['At iteration 26 the best fitness is 0.09559259259259262']
# ['At iteration 27 the best fitness is 0.09559259259259262']
# ['At iteration 28 the best fitness is 0.09559259259259262']
# ['At iteration 29 the best fitness is 0.09559259259259262']
# ['At iteration 30 the best fitness is 0.09559259259259262']
#       Selected: 29/54 (53.7%), Fitness: 0.0956, Time: 673.6s
#       Modality: D=54%
#     Test Acc: 85.98%, F1: 83.93%, Features: 29/54 (53.7%), Model: 0.056MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.14533333333333337']
# ['At iteration 1 the best fitness is 0.1354444444444444']
# ['At iteration 2 the best fitness is 0.1354444444444444']
# ['At iteration 3 the best fitness is 0.11274074074074078']
# ['At iteration 4 the best fitness is 0.11274074074074078']
# ['At iteration 5 the best fitness is 0.11274074074074078']
# ['At iteration 6 the best fitness is 0.11274074074074078']
# ['At iteration 7 the best fitness is 0.11274074074074078']
# ['At iteration 8 the best fitness is 0.11274074074074078']
# ['At iteration 9 the best fitness is 0.11274074074074078']
# ['At iteration 10 the best fitness is 0.11274074074074078']
# ['At iteration 11 the best fitness is 0.11274074074074078']
# ['At iteration 12 the best fitness is 0.11274074074074078']
# ['At iteration 13 the best fitness is 0.11274074074074078']
# ['At iteration 14 the best fitness is 0.11274074074074078']
# ['At iteration 15 the best fitness is 0.11274074074074078']
# ['At iteration 16 the best fitness is 0.11274074074074078']
# ['At iteration 17 the best fitness is 0.11274074074074078']
# ['At iteration 18 the best fitness is 0.11274074074074078']
# ['At iteration 19 the best fitness is 0.11274074074074078']
# ['At iteration 20 the best fitness is 0.11274074074074078']
# ['At iteration 21 the best fitness is 0.11274074074074078']
# ['At iteration 22 the best fitness is 0.11274074074074078']
# ['At iteration 23 the best fitness is 0.11274074074074078']
# ['At iteration 24 the best fitness is 0.11274074074074078']
# ['At iteration 25 the best fitness is 0.11274074074074078']
# ['At iteration 26 the best fitness is 0.11274074074074078']
# ['At iteration 27 the best fitness is 0.11274074074074078']
# ['At iteration 28 the best fitness is 0.11274074074074078']
# ['At iteration 29 the best fitness is 0.11274074074074078']
#       Selected: 25/54 (46.3%), Fitness: 0.1127, Time: 657.8s
#       Modality: D=46%
#     Test Acc: 84.11%, F1: 82.57%, Features: 25/54 (46.3%), Model: 0.054MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.1201481481481482']
# ['At iteration 2 the best fitness is 0.1201481481481482']
# ['At iteration 3 the best fitness is 0.10300000000000004']
# ['At iteration 4 the best fitness is 0.10300000000000004']
# ['At iteration 5 the best fitness is 0.10300000000000004']
# ['At iteration 6 the best fitness is 0.09929629629629633']
# ['At iteration 7 the best fitness is 0.09929629629629633']
# ['At iteration 8 the best fitness is 0.09929629629629633']
# ['At iteration 9 the best fitness is 0.09929629629629633']
# ['At iteration 10 the best fitness is 0.09929629629629633']
# ['At iteration 11 the best fitness is 0.09929629629629633']
# ['At iteration 12 the best fitness is 0.09929629629629633']
# ['At iteration 13 the best fitness is 0.09929629629629633']
# ['At iteration 14 the best fitness is 0.09929629629629633']
# ['At iteration 15 the best fitness is 0.09929629629629633']
# ['At iteration 16 the best fitness is 0.09929629629629633']
# ['At iteration 17 the best fitness is 0.09929629629629633']
# ['At iteration 18 the best fitness is 0.09929629629629633']
# ['At iteration 19 the best fitness is 0.09929629629629633']
# ['At iteration 20 the best fitness is 0.09929629629629633']
# ['At iteration 21 the best fitness is 0.09929629629629633']
# ['At iteration 22 the best fitness is 0.09929629629629633']
# ['At iteration 23 the best fitness is 0.09929629629629633']
# ['At iteration 24 the best fitness is 0.09929629629629633']
# ['At iteration 25 the best fitness is 0.09929629629629633']
# ['At iteration 26 the best fitness is 0.09929629629629633']
# ['At iteration 27 the best fitness is 0.08214814814814816']
# ['At iteration 28 the best fitness is 0.08214814814814816']
# ['At iteration 29 the best fitness is 0.08214814814814816']
#       Selected: 31/54 (57.4%), Fitness: 0.0821, Time: 1656.9s
#       Modality: D=57%
#     Test Acc: 77.57%, F1: 75.30%, Features: 31/54 (57.4%), Model: 0.057MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.13729629629629625']
# ['At iteration 1 the best fitness is 0.12307407407407407']
# ['At iteration 2 the best fitness is 0.11318518518518522']
# ['At iteration 3 the best fitness is 0.11318518518518522']
# ['At iteration 4 the best fitness is 0.11318518518518522']
# ['At iteration 5 the best fitness is 0.11318518518518522']
# ['At iteration 6 the best fitness is 0.11133333333333337']
# ['At iteration 7 the best fitness is 0.11133333333333337']
# ['At iteration 8 the best fitness is 0.11133333333333337']
# ['At iteration 9 the best fitness is 0.11133333333333337']
# ['At iteration 10 the best fitness is 0.11133333333333337']
# ['At iteration 11 the best fitness is 0.11133333333333337']
# ['At iteration 12 the best fitness is 0.11133333333333337']
# ['At iteration 13 the best fitness is 0.11133333333333337']
# ['At iteration 14 the best fitness is 0.11133333333333337']
# ['At iteration 15 the best fitness is 0.10685185185185184']
# ['At iteration 16 the best fitness is 0.10685185185185184']
# ['At iteration 17 the best fitness is 0.10685185185185184']
# ['At iteration 18 the best fitness is 0.10685185185185184']
# ['At iteration 19 the best fitness is 0.10685185185185184']
# ['At iteration 20 the best fitness is 0.09418518518518519']
# ['At iteration 21 the best fitness is 0.09418518518518519']
# ['At iteration 22 the best fitness is 0.09418518518518519']
# ['At iteration 23 the best fitness is 0.09418518518518519']
# ['At iteration 24 the best fitness is 0.09418518518518519']
# ['At iteration 25 the best fitness is 0.09418518518518519']
# ['At iteration 26 the best fitness is 0.09418518518518519']
# ['At iteration 27 the best fitness is 0.09418518518518519']
# ['At iteration 28 the best fitness is 0.09418518518518519']
# ['At iteration 29 the best fitness is 0.09418518518518519']
#       Selected: 45/54 (83.3%), Fitness: 0.0942, Time: 527.1s
#       Modality: D=83%
#     Test Acc: 86.92%, F1: 84.38%, Features: 45/54 (83.3%), Model: 0.064MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_per_fold_sensor/all_results_per_fold.csv
# Shape: (144, 22)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  sensor_retention (%)  sensor_selected
# 0      baseline     1            79.6296           97.3333       75.8826          75.8826              77.1429           79.6296                 54              54                  100.0       0.0000          8.4801          8.4801         17435           0.0680                 0.3547                  0.3547                    0.0        17.8936                 100.0               54
# 1      baseline     2            75.9259           98.0000       70.7783          70.7783              72.3045           75.9259                 54              54                  100.0       0.0000         11.4074         11.4074         17435           0.0680                 0.3547                  0.3547                    0.0        17.6748                 100.0               54
# 2      baseline     3            83.3333           98.0000       81.3425          81.3425              86.4550           83.3333                 54              54                  100.0       0.0000         11.3558         11.3558         17435           0.0680                 0.3547                  0.3547                    0.0        17.6748                 100.0               54
# 3      baseline     4            75.9259           94.6667       70.1224          70.1224              69.5062           75.9259                 54              54                  100.0       0.0000         11.3672         11.3672         17435           0.0680                 0.3547                  0.3547                    0.0        17.6748                 100.0               54
# 4      baseline     5            76.8519           99.3333       75.5879          75.5879              79.3827           76.8519                 54              54                  100.0       0.0000         11.2168         11.2168         17435           0.0680                 0.3547                  0.3547                    0.0        17.6748                 100.0               54
# 5      baseline     6            78.5047           99.3333       75.7458          75.5191              77.4427           78.7037                 54              54                  100.0       0.0000         11.4415         11.4415         17435           0.0680                 0.3547                  0.3547                    0.0        17.6748                 100.0               54
# 6      baseline     7            84.1121           99.3333       82.1282          81.9611              83.6925           84.2593                 54              54                  100.0       0.0000         11.7569         11.7569         17435           0.0680                 0.3547                  0.3547                    0.0        17.6748                 100.0               54
# 7      baseline     8            79.4393           96.6667       74.5551          74.7421              75.1102           79.6296                 54              54                  100.0       0.0000         11.4806         11.4806         17435           0.0680                 0.3547                  0.3547                    0.0        17.6748                 100.0               54
# 8   mutual_info     1            82.4074           95.3333       80.0794          80.0794              81.0494           82.4074                 27              54                   50.0       0.3095          8.5849          8.8945         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 9   mutual_info     2            66.6667           94.6667       60.6089          60.6089              64.7801           66.6667                 27              54                   50.0       0.2928         11.4651         11.7579         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 10  mutual_info     3            72.2222           98.6667       68.8761          68.8761              74.3915           72.2222                 27              54                   50.0       0.2946         11.4327         11.7274         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 11  mutual_info     4            58.3333           96.6667       51.2698          51.2698              50.4714           58.3333                 27              54                   50.0       0.2979         11.2176         11.5156         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 12  mutual_info     5            76.8519           96.6667       75.7565          75.7565              80.6966           76.8519                 27              54                   50.0       0.3054         11.3306         11.6361         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 13  mutual_info     6            69.1589           98.0000       63.6928          63.3535              63.9238           69.4444                 27              54                   50.0       0.3011         11.4381         11.7393         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 14  mutual_info     7            82.2430           98.0000       79.2150          79.1543              80.3371           82.4074                 27              54                   50.0       0.3137         11.7427         12.0564         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 15  mutual_info     8            84.1121           95.3333       81.9158          82.0583              86.6020           84.2593                 27              54                   50.0       0.3093         11.4961         11.8054         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 16          rfe     1            82.4074           96.6667       80.0224          80.0224              84.1975           82.4074                 27              54                   50.0       0.1194         10.6590         10.7786         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 17          rfe     2            81.4815           96.6667       78.7754          78.7754              82.2634           81.4815                 27              54                   50.0       0.1134         11.2818         11.3953         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 18          rfe     3            79.6296           98.0000       77.3735          77.3735              79.6581           79.6296                 27              54                   50.0       0.1343         11.5783         11.7128         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27
# 19          rfe     4            69.4444           96.0000       65.0723          65.0723              69.9888           69.4444                 27              54                   50.0       0.1302         11.3477         11.4781         13979           0.0548                 0.3547                  0.1774                   50.0        17.5986                  50.0               27

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              79.22              3.14              75.77              4.31                   54.00                      100.00              0.00                11.06                11.06            17435.0                  0.07                        0.00               17.70
# mutual_info              74.00              9.06              70.18             10.96                   27.00                       50.00              0.30                11.09                11.39            13979.0                  0.05                       50.00               17.60
#         rfe              79.92              5.61              76.99              6.43                   27.00                       50.00              0.13                11.40                11.53            13979.0                  0.05                       50.00               17.60
#       lasso              67.25              6.49              63.86              7.61                   27.00                       50.00              0.01                11.03                11.03            13979.0                  0.05                       50.00               17.60
#    meta_BAT              78.64              4.34              75.02              4.82                   26.38                       48.84            694.91                11.31               706.22            13899.0                  0.05                       51.16               17.60
#     meta_CS              75.96              4.77              72.61              5.47                   30.38                       56.25           1365.50                11.43              1376.93            14411.0                  0.06                       43.75               17.61
#     meta_DE              75.96              3.20              73.09              3.46                   28.75                       53.24            695.11                11.39               706.51            14203.0                  0.06                       46.76               17.60
#    meta_FFA              75.85              7.25              72.81              7.98                   28.12                       52.08            673.10                11.31               684.42            14123.0                  0.06                       47.92               17.60
#     meta_GA              74.22              8.17              71.31              9.92                   29.00                       53.70            674.77                11.42               686.19            14235.0                  0.06                       46.30               17.60
#    meta_GWO              75.27              6.03              72.13              6.30                   27.12                       50.23            672.89                11.54               684.43            13995.0                  0.05                       49.77               17.60
#    meta_HHO              76.65              5.74              72.90              6.83                   36.88                       68.29            914.21                11.55               925.76            15243.0                  0.06                       31.71               17.63
#   meta_JAYA              73.07              7.40              69.42              8.36                   29.25                       54.17            707.72                11.71               719.43            14267.0                  0.06                       45.83               17.60
#    meta_MFO              75.73              4.76              72.78              5.28                   31.00                       57.41            663.27                11.67               674.94            14491.0                  0.06                       42.59               17.61
#    meta_MVO              75.38              8.50              72.01              9.18                   29.50                       54.63            681.99                11.21               693.20            14299.0                  0.06                       45.37               17.60
#    meta_PSO              74.22              9.25              71.26             10.41                   27.38                       50.69            677.28                11.49               688.77            14027.0                  0.05                       49.31               17.60
#    meta_SCA              76.08              6.31              73.08              7.65                   24.88                       46.06            669.00                11.41               680.42            13707.0                  0.05                       53.94               17.59
#    meta_SSA              75.73              4.42              72.34              4.80                   27.88                       51.62           1693.38                11.17              1704.54            14091.0                  0.06                       48.38               17.60
#    meta_WOA              78.18              6.34              74.72              7.36                   39.00                       72.22            642.70                10.81               653.51            15515.0                  0.06                       27.78               17.63

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 74.00% vs Baseline: 79.22%
#   Paired t-test: t=-1.9013, p=0.0990
#   Wilcoxon test: W=5.0000, p=0.1562
#   -> worse, Not significant
#
# RFE vs BASELINE:
#   Method: 79.92% vs Baseline: 79.22%
#   Paired t-test: t=0.4030, p=0.6989
#   Wilcoxon test: W=16.0000, p=0.8438
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 67.25% vs Baseline: 79.22%
#   Paired t-test: t=-8.3658, p=0.0001
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 78.64% vs Baseline: 79.22%
#   Paired t-test: t=-0.4493, p=0.6668
#   Wilcoxon test: W=15.0000, p=0.7422
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 75.96% vs Baseline: 79.22%
#   Paired t-test: t=-2.4256, p=0.0457
#   Wilcoxon test: W=1.0000, p=0.0625
#   -> worse, Significant
#
# META_DE vs BASELINE:
#   Method: 75.96% vs Baseline: 79.22%
#   Paired t-test: t=-2.9732, p=0.0207
#   Wilcoxon test: W=3.0000, p=0.0391
#   -> worse, Significant
#
# META_FFA vs BASELINE:
#   Method: 75.85% vs Baseline: 79.22%
#   Paired t-test: t=-1.6673, p=0.1394
#   Wilcoxon test: W=5.0000, p=0.1562
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 74.22% vs Baseline: 79.22%
#   Paired t-test: t=-1.9055, p=0.0984
#   Wilcoxon test: W=6.0000, p=0.1016
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 75.27% vs Baseline: 79.22%
#   Paired t-test: t=-2.7247, p=0.0296
#   Wilcoxon test: W=4.0000, p=0.0547
#   -> worse, Significant
#
# META_HHO vs BASELINE:
#   Method: 76.65% vs Baseline: 79.22%
#   Paired t-test: t=-1.5721, p=0.1599
#   Wilcoxon test: W=9.0000, p=0.2344
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 73.07% vs Baseline: 79.22%
#   Paired t-test: t=-2.5803, p=0.0365
#   Wilcoxon test: W=4.0000, p=0.0547
#   -> worse, Significant
#
# META_MFO vs BASELINE:
#   Method: 75.73% vs Baseline: 79.22%
#   Paired t-test: t=-2.1098, p=0.0728
#   Wilcoxon test: W=5.5000, p=0.0859
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 75.38% vs Baseline: 79.22%
#   Paired t-test: t=-1.3859, p=0.2083
#   Wilcoxon test: W=8.0000, p=0.1953
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 74.22% vs Baseline: 79.22%
#   Paired t-test: t=-1.6682, p=0.1392
#   Wilcoxon test: W=8.0000, p=0.1953
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 76.08% vs Baseline: 79.22%
#   Paired t-test: t=-1.8184, p=0.1118
#   Wilcoxon test: W=5.0000, p=0.1406
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 75.73% vs Baseline: 79.22%
#   Paired t-test: t=-4.1662, p=0.0042
#   Wilcoxon test: W=0.0000, p=0.0156
#   -> worse, Significant
#
# META_WOA vs BASELINE:
#   Method: 78.18% vs Baseline: 79.22%
#   Paired t-test: t=-0.6085, p=0.5621
#   Wilcoxon test: W=11.5000, p=0.4141
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_per_fold_sensor
#
# Per-method folders:
#   results_per_fold_sensor/baseline/ (16 files)
#   results_per_fold_sensor/mutual_info/ (16 files)
#   results_per_fold_sensor/rfe/ (16 files)
#   results_per_fold_sensor/lasso/ (16 files)
#   results_per_fold_sensor/meta_BAT/ (16 files)
#   results_per_fold_sensor/meta_CS/ (16 files)
#   results_per_fold_sensor/meta_DE/ (16 files)
#   results_per_fold_sensor/meta_FFA/ (16 files)
#   results_per_fold_sensor/meta_GA/ (16 files)
#   results_per_fold_sensor/meta_GWO/ (16 files)
#   results_per_fold_sensor/meta_HHO/ (16 files)
#   results_per_fold_sensor/meta_JAYA/ (16 files)
#   results_per_fold_sensor/meta_MFO/ (16 files)
#   results_per_fold_sensor/meta_MVO/ (16 files)
#   results_per_fold_sensor/meta_PSO/ (16 files)
#   results_per_fold_sensor/meta_SCA/ (16 files)
#   results_per_fold_sensor/meta_SSA/ (16 files)
#   results_per_fold_sensor/meta_WOA/ (16 files)
#
# Plots directory: results_per_fold_sensor/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 79.92% ± 5.61% (Features: 50.0%)
#   baseline            : 79.22% ± 3.14% (Features: 100.0%)
#   meta_BAT            : 78.64% ± 4.34% (Features: 48.8%)
#   meta_WOA            : 78.18% ± 6.34% (Features: 72.2%)
#   meta_HHO            : 76.65% ± 5.74% (Features: 68.3%)
