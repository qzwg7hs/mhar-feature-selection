# %% [markdown]
# # File 2: Feature Selection on Weighted Early Fusion Features
#
# **Prerequisite:** Run File 1 first (`file1_weighted_fusion.ipynb`) to generate `best_weights_per_fold.pkl`.
#
# **Pipeline:**
# 1. Load the best modality weights per fold from File 1
# 2. For each fold, apply those weights to scale the concatenated features
# 3. Run the full feature selection comparison on the **weighted** features:
#    - Baseline (all weighted features, no FS)
#    - Mutual Information
#    - RFE
#    - LASSO
#    - 14 EvoloPy metaheuristics
#
# This is the same pipeline as `utd_mhad_new_val.ipynb`, but features are pre-scaled
# by learned modality weights before any feature selection happens.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# EvoloPy imports
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new")
WEIGHTS_DIR = Path("results_weighted_fusion")  # output of File 1

RESULTS_ROOT = Path("results_weighted_fs")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Training hyperparameters (same as original)
N_FOLDS = 8
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters
N_POPULATION = 20
MAX_ITERATIONS = 30
TARGET_FEATURE_PERCENTAGE = 0.5

# All 14 EvoloPy optimizers
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data & Best Weights from File 1

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")

print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

first_sample = X_feat[0]
FEATURE_DIMS = {
    'depth': first_sample['depth_feat'].shape[0],
    'sensor': first_sample['sensor_feat'].shape[0],
    'skeleton': first_sample['skeleton_feat'].shape[0],
    'video': first_sample['video_feat'].shape[0]
}
MODALITY_NAMES = list(FEATURE_DIMS.keys())
MODALITY_DIMS = list(FEATURE_DIMS.values())
TOTAL_FEATURES = sum(MODALITY_DIMS)
N_MODALITIES = len(MODALITY_NAMES)

print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")

# Load best weights from File 1
best_weights_per_fold = joblib.load(WEIGHTS_DIR / "best_weights_per_fold.pkl")

print(f"\n{'=' * 60}")
print("LOADED BEST WEIGHTS PER FOLD FROM FILE 1:")
print(f"{'=' * 60}")
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']:25s} | Val: {info['val_acc']*100:.2f}% | [{w_str}]")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   video: 1420
#   TOTAL: 3933
#
# ============================================================
# LOADED BEST WEIGHTS PER FOLD FROM FILE 1:
# ============================================================
#   Fold 1: weighted_JAYA             | Val: 100.00% | [depth=0.154, sensor=0.385, skeleton=0.668, video=0.168]
#   Fold 2: weighted_SCA              | Val: 100.00% | [depth=0.000, sensor=0.986, skeleton=0.981, video=0.000]
#   Fold 3: weighted_SSA              | Val: 100.00% | [depth=0.000, sensor=0.984, skeleton=0.785, video=0.008]
#   Fold 4: weighted_JAYA             | Val: 100.00% | [depth=0.000, sensor=0.570, skeleton=0.606, video=0.000]
#   Fold 5: weighted_BAT              | Val: 100.00% | [depth=0.060, sensor=0.659, skeleton=0.660, video=0.000]
#   Fold 6: weighted_GWO              | Val: 100.00% | [depth=0.074, sensor=0.969, skeleton=0.916, video=0.426]
#   Fold 7: weighted_JAYA             | Val: 99.07% | [depth=0.776, sensor=0.504, skeleton=0.510, video=0.025]
#   Fold 8: weighted_GA               | Val: 99.07% | [depth=0.206, sensor=0.764, skeleton=0.866, video=0.260]

# %% [markdown]
# ## Model & Dataset (same as original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (same as original)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)


print("Model and dataset defined")
# Out:
# Model and dataset defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified = []
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        unified.append(feat_vector)
    return np.array(unified)


def apply_modality_weights(X, weights):
    """Apply per-modality scalar weights to concatenated feature matrix."""
    X_weighted = X.copy()
    start_idx = 0
    for i, dim in enumerate(MODALITY_DIMS):
        end_idx = start_idx + dim
        X_weighted[:, start_idx:end_idx] *= weights[i]
        start_idx = end_idx
    return X_weighted


def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    return retention


def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)


print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Full Training & Evaluation (same as original)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics (same as original)"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)
        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics


print("Full train/eval function defined")
# Out:
# Full train/eval function defined

# %% [markdown]
# ## Feature Selection Methods (same as original)

# %%
# ============================================================================
# Quick training for metaheuristic fitness evaluation
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


# ============================================================================
# Metaheuristic fitness function (same as original)
# ============================================================================

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            alpha = 0.95
            beta = 0.05
            feature_ratio = num_selected / len(binary_mask)
            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically (same as original)"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results


# ============================================================================
# Standard FS methods (same as original)
# ============================================================================

def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    print("    Running Mutual Information...")
    start_time = time.time()
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    results = {
        'mask': binary_mask, 'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)), 'num_total': len(binary_mask),
        'modality_retention': modality_retention, 'mi_scores': mi_scores, 'method': 'mutual_info'
    }
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), Time: {execution_time:.1f}s")
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    print("    Running RFE...")
    start_time = time.time()
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)
    selector.fit(X_train, y_train)
    binary_mask = selector.support_
    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    results = {
        'mask': binary_mask, 'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)), 'num_total': len(binary_mask),
        'modality_retention': modality_retention, 'ranking': selector.ranking_, 'method': 'rfe'
    }
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), Time: {execution_time:.1f}s")
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    print("    Running LASSO...")
    start_time = time.time()
    lasso = LogisticRegression(penalty='l1', C=0.01, solver='liblinear', random_state=42, max_iter=1000)
    lasso.fit(X_train, y_train)
    coef_abs = np.abs(lasso.coef_).sum(axis=0)
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True
    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    results = {
        'mask': binary_mask, 'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)), 'num_total': len(binary_mask),
        'modality_retention': modality_retention, 'coefficients': coef_abs, 'method': 'lasso'
    }
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), Time: {execution_time:.1f}s")
    return results


print("All feature selection methods defined")
# Out:
# All feature selection methods defined

# %% [markdown]
# ## Main Experiment Runner
#
# Key difference from original: **before normalizing, we apply the best modality weights per fold.**

# %%
def run_all_methods_per_fold():
    """
    Run ALL FS methods across ALL folds on WEIGHTED features.
    For each fold, the best modality weights from File 1 are applied
    before normalization and feature selection.
    """
    print("=" * 80)
    print("FEATURE SELECTION ON WEIGHTED EARLY FUSION FEATURES")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("Using best modality weights from File 1 per fold")
    print("=" * 80)
    
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    master_results = {m: {} for m in ALL_METHODS}
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#' * 80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#' * 80}")
        
        # Get best weights for this fold
        fold_weights = best_weights_per_fold[fold_idx]['weights']
        fold_weight_method = best_weights_per_fold[fold_idx]['method']
        w_str = ', '.join([f"{MODALITY_NAMES[i]}={fold_weights[i]:.3f}" for i in range(N_MODALITIES)])
        print(f"  Applying weights from {fold_weight_method}: [{w_str}]")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Reserve 1 subject for validation (same as original)
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        val_mask = subjects[train_val_idx] == val_subject
        train_mask = ~val_mask
        
        X_train, y_train = X_train_val[train_mask], y_train_val[train_mask]
        X_val, y_val = X_train_val[val_mask], y_train_val[val_mask]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # *** APPLY MODALITY WEIGHTS (from File 1) ***
        X_train = apply_modality_weights(X_train, fold_weights)
        X_val = apply_modality_weights(X_val, fold_weights)
        X_test = apply_modality_weights(X_test, fold_weights)
        
        # Normalize (AFTER weighting)
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =================================================================
        # Run each FS method
        # =================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask, 'execution_time': 0,
                    'num_selected': TOTAL_FEATURES, 'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                'modality_weights_used': fold_weights,
                'weight_method_used': fold_weight_method,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'=' * 80}")
    print("ALL EXPERIMENTS COMPLETED")
    print(f"{'=' * 80}")
    
    return master_results


print("Main experiment runner defined")
# Out:
# Main experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# FEATURE SELECTION ON WEIGHTED EARLY FUSION FEATURES
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# Using best modality weights from File 1 per fold
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Applying weights from weighted_JAYA: [depth=0.154, sensor=0.385, skeleton=0.668, video=0.168]
#   Train: 646, Val: 107, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 93.52%, F1: 92.89%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 21.4s
#     Test Acc: 94.44%, F1: 93.83%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.2s
#     Test Acc: 93.52%, F1: 92.84%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.4s
#     Test Acc: 87.04%, F1: 86.35%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.033745018784262566']
# ['At iteration 1 the best fitness is 0.033745018784262566']
# ['At iteration 2 the best fitness is 0.024510551741673024']
# ['At iteration 3 the best fitness is 0.024510551741673024']
# ['At iteration 4 the best fitness is 0.024510551741673024']
# ['At iteration 5 the best fitness is 0.024510551741673024']
# ['At iteration 6 the best fitness is 0.024510551741673024']
# ['At iteration 7 the best fitness is 0.024396135265700485']
# ['At iteration 8 the best fitness is 0.024396135265700485']
# ['At iteration 9 the best fitness is 0.024396135265700485']
# ['At iteration 10 the best fitness is 0.024396135265700485']
# ['At iteration 11 the best fitness is 0.024396135265700485']
# ['At iteration 12 the best fitness is 0.024396135265700485']
# ['At iteration 13 the best fitness is 0.024396135265700485']
# ['At iteration 14 the best fitness is 0.024230867022629037']
# ['At iteration 15 the best fitness is 0.024230867022629037']
# ['At iteration 16 the best fitness is 0.024230867022629037']
# ['At iteration 17 the best fitness is 0.024230867022629037']
# ['At iteration 18 the best fitness is 0.024230867022629037']
# ['At iteration 19 the best fitness is 0.024230867022629037']
# ['At iteration 20 the best fitness is 0.024230867022629037']
# ['At iteration 21 the best fitness is 0.024230867022629037']
# ['At iteration 22 the best fitness is 0.024230867022629037']
# ['At iteration 23 the best fitness is 0.024230867022629037']
# ['At iteration 24 the best fitness is 0.024230867022629037']
# ['At iteration 25 the best fitness is 0.024230867022629037']
# ['At iteration 26 the best fitness is 0.024230867022629037']
# ['At iteration 27 the best fitness is 0.024230867022629037']
# ['At iteration 28 the best fitness is 0.024230867022629037']
# ['At iteration 29 the best fitness is 0.024230867022629037']
#       Selected: 1905/3933 (48.4%), Fitness: 0.0242, Time: 454.0s
#       Modality: D=55%, S=47%, Sk=48%, V=49%
#     Test Acc: 95.37%, F1: 94.53%, Features: 1905/3933 (48.4%), Model: 4.262MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.033503472890542764']
# ['At iteration 10 the best fitness is 0.024815662344266465']
# ['At iteration 20 the best fitness is 0.02476481057716756']
#       Selected: 1922/3933 (48.9%), Fitness: 0.0246, Time: 804.7s
#       Modality: D=45%, S=50%, Sk=50%, V=47%
#     Test Acc: 96.30%, F1: 95.06%, Features: 1922/3933 (48.9%), Model: 4.295MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.033045806986652604']
# ['At iteration 2 the best fitness is 0.025375031782354437']
# ['At iteration 3 the best fitness is 0.024841088227815916']
# ['At iteration 4 the best fitness is 0.024841088227815916']
# ['At iteration 5 the best fitness is 0.024841088227815916']
# ['At iteration 6 the best fitness is 0.024841088227815916']
# ['At iteration 7 the best fitness is 0.024841088227815916']
# ['At iteration 8 the best fitness is 0.024841088227815916']
# ['At iteration 9 the best fitness is 0.024841088227815916']
# ['At iteration 10 the best fitness is 0.024841088227815916']
# ['At iteration 11 the best fitness is 0.024841088227815916']
# ['At iteration 12 the best fitness is 0.024841088227815916']
# ['At iteration 13 the best fitness is 0.024841088227815916']
# ['At iteration 14 the best fitness is 0.024841088227815916']
# ['At iteration 15 the best fitness is 0.024841088227815916']
# ['At iteration 16 the best fitness is 0.024841088227815916']
# ['At iteration 17 the best fitness is 0.024841088227815916']
# ['At iteration 18 the best fitness is 0.024841088227815916']
# ['At iteration 19 the best fitness is 0.024841088227815916']
# ['At iteration 20 the best fitness is 0.024841088227815916']
# ['At iteration 21 the best fitness is 0.024841088227815916']
# ['At iteration 22 the best fitness is 0.024841088227815916']
# ['At iteration 23 the best fitness is 0.024701245868293923']
# ['At iteration 24 the best fitness is 0.024701245868293923']
# ['At iteration 25 the best fitness is 0.024396135265700485']
# ['At iteration 26 the best fitness is 0.024396135265700485']
# ['At iteration 27 the best fitness is 0.024396135265700485']
# ['At iteration 28 the best fitness is 0.024396135265700485']
# ['At iteration 29 the best fitness is 0.024396135265700485']
# ['At iteration 30 the best fitness is 0.024396135265700485']
#       Selected: 1935/3933 (49.2%), Fitness: 0.0244, Time: 407.7s
#       Modality: D=51%, S=46%, Sk=51%, V=49%
#     Test Acc: 95.37%, F1: 94.53%, Features: 1935/3933 (49.2%), Model: 4.320MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.042750652874907036']
# ['At iteration 1 the best fitness is 0.03394842585265819']
# ['At iteration 2 the best fitness is 0.03373230584248784']
# ['At iteration 3 the best fitness is 0.03360517642474058']
# ['At iteration 4 the best fitness is 0.034444230581872536']
# ['At iteration 5 the best fitness is 0.04299219876862684']
# ['At iteration 6 the best fitness is 0.025527587083651156']
# ['At iteration 7 the best fitness is 0.03440609175654835']
# ['At iteration 8 the best fitness is 0.03458407294139453']
# ['At iteration 9 the best fitness is 0.03450779529074617']
# ['At iteration 10 the best fitness is 0.03430438822235054']
# ['At iteration 11 the best fitness is 0.03426624939702636']
# ['At iteration 12 the best fitness is 0.025540300025425886']
# ['At iteration 13 the best fitness is 0.034418804698323084']
# ['At iteration 14 the best fitness is 0.03440609175654835']
# ['At iteration 15 the best fitness is 0.03440609175654835']
# ['At iteration 16 the best fitness is 0.034367952931224174']
# ['At iteration 17 the best fitness is 0.025489448258326976']
# ['At iteration 18 the best fitness is 0.025502161200101705']
# ['At iteration 19 the best fitness is 0.025514874141876434']
# ['At iteration 20 the best fitness is 0.025502161200101705']
# ['At iteration 21 the best fitness is 0.0343806658729989']
# ['At iteration 22 the best fitness is 0.025502161200101705']
# ['At iteration 23 the best fitness is 0.03440609175654835']
# ['At iteration 24 the best fitness is 0.025451309433002795']
# ['At iteration 25 the best fitness is 0.025451309433002795']
# ['At iteration 26 the best fitness is 0.03432981410589999']
# ['At iteration 27 the best fitness is 0.03432981410589999']
# ['At iteration 28 the best fitness is 0.025451309433002795']
# ['At iteration 29 the best fitness is 0.04320831877879719']
#       Selected: 1980/3933 (50.3%), Fitness: 0.0432, Time: 396.9s
#       Modality: D=53%, S=55%, Sk=49%, V=49%
#     Test Acc: 94.44%, F1: 93.83%, Features: 1980/3933 (50.3%), Model: 4.408MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.03360517642474058
# At iteration 2 the best fitness is 0.025324180015255535
# At iteration 3 the best fitness is 0.03347804700699331
# At iteration 4 the best fitness is 0.0336178893665153
# At iteration 5 the best fitness is 0.03387214820200984
# At iteration 6 the best fitness is 0.024624968217645565
# At iteration 7 the best fitness is 0.03351618583231749
# At iteration 8 the best fitness is 0.024917365878464277
# At iteration 9 the best fitness is 0.033795870551361476
# At iteration 10 the best fitness is 0.03385943526023511
# At iteration 11 the best fitness is 0.03383400937668565
# At iteration 12 the best fitness is 0.024980930587337913
# At iteration 13 the best fitness is 0.03365602819183948
# At iteration 14 the best fitness is 0.033770444667812025
# At iteration 15 the best fitness is 0.025057208237986274
# At iteration 16 the best fitness is 0.025222476481057715
# At iteration 17 the best fitness is 0.025006356470887364
# At iteration 18 the best fitness is 0.025019069412662093
# At iteration 19 the best fitness is 0.03375773172603729
# At iteration 20 the best fitness is 0.024701245868293923
# At iteration 21 the best fitness is 0.024955504703788458
# At iteration 22 the best fitness is 0.02437070938215103
# At iteration 23 the best fitness is 0.03324921405504823
# At iteration 24 the best fitness is 0.02486651411136537
# At iteration 25 the best fitness is 0.024434274091024666
# At iteration 26 the best fitness is 0.03366874113361421
# At iteration 27 the best fitness is 0.024497838799898298
# At iteration 28 the best fitness is 0.03366874113361421
# At iteration 29 the best fitness is 0.025146198830409357
# At iteration 30 the best fitness is 0.03363060230829003
#       Selected: 1990/3933 (50.6%), Fitness: 0.0336, Time: 395.6s
#       Modality: D=53%, S=51%, Sk=51%, V=50%
#     Test Acc: 97.22%, F1: 97.23%, Features: 1990/3933 (50.6%), Model: 4.428MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03359246348296585']
# ['At iteration 1 the best fitness is 0.032880538743581156']
# ['At iteration 2 the best fitness is 0.032105049295322825']
# ['At iteration 3 the best fitness is 0.032105049295322825']
# ['At iteration 4 the best fitness is 0.032105049295322825']
# ['At iteration 5 the best fitness is 0.031024449244471057']
# ['At iteration 6 the best fitness is 0.030541357457031446']
# ['At iteration 7 the best fitness is 0.021039918637172642']
# ['At iteration 8 the best fitness is 0.02025171624713959']
# ['At iteration 9 the best fitness is 0.019895753877447242']
# ['At iteration 10 the best fitness is 0.019005847953216373']
# ['At iteration 11 the best fitness is 0.019005847953216373']
# ['At iteration 12 the best fitness is 0.01840833968980422']
# ['At iteration 13 the best fitness is 0.01840833968980422']
# ['At iteration 14 the best fitness is 0.01840833968980422']
# ['At iteration 15 the best fitness is 0.018357487922705317']
# ['At iteration 16 the best fitness is 0.018230358504958046']
# ['At iteration 17 the best fitness is 0.018230358504958046']
# ['At iteration 18 the best fitness is 0.018230358504958046']
# ['At iteration 19 the best fitness is 0.018230358504958046']
# ['At iteration 20 the best fitness is 0.018230358504958046']
# ['At iteration 21 the best fitness is 0.018230358504958046']
# ['At iteration 22 the best fitness is 0.018230358504958046']
# ['At iteration 23 the best fitness is 0.018230358504958046']
# ['At iteration 24 the best fitness is 0.018230358504958046']
# ['At iteration 25 the best fitness is 0.018230358504958046']
# ['At iteration 26 the best fitness is 0.018230358504958046']
# ['At iteration 27 the best fitness is 0.018230358504958046']
# ['At iteration 28 the best fitness is 0.018230358504958046']
# ['At iteration 29 the best fitness is 0.018230358504958046']
#       Selected: 1497/3933 (38.1%), Fitness: 0.0182, Time: 381.6s
#       Modality: D=37%, S=39%, Sk=38%, V=39%
#     Test Acc: 96.30%, F1: 96.17%, Features: 1497/3933 (38.1%), Model: 3.465MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.03406284232863074']
# ['At iteration 1 the best fitness is 0.03406284232863074']
# ['At iteration 2 the best fitness is 0.03406284232863074']
# ['At iteration 3 the best fitness is 0.03406284232863074']
# ['At iteration 4 the best fitness is 0.03406284232863074']
# ['At iteration 5 the best fitness is 0.0336178893665153']
# ['At iteration 6 the best fitness is 0.0336178893665153']
# ['At iteration 7 the best fitness is 0.03206691046999865']
# ['At iteration 8 the best fitness is 0.018789727943046022']
# ['At iteration 9 the best fitness is 0.018789727943046022']
# ['At iteration 10 the best fitness is 0.018789727943046022']
# ['At iteration 11 the best fitness is 0.018789727943046022']
# ['At iteration 12 the best fitness is 0.018789727943046022']
# ['At iteration 13 the best fitness is 0.018789727943046022']
# ['At iteration 14 the best fitness is 0.018789727943046022']
# ['At iteration 15 the best fitness is 0.018789727943046022']
# ['At iteration 16 the best fitness is 0.018789727943046022']
# ['At iteration 17 the best fitness is 0.018789727943046022']
# ['At iteration 18 the best fitness is 0.018789727943046022']
# ['At iteration 19 the best fitness is 0.018789727943046022']
# ['At iteration 20 the best fitness is 0.01775997965929316']
# ['At iteration 21 the best fitness is 0.01775997965929316']
# ['At iteration 22 the best fitness is 0.01775997965929316']
# ['At iteration 23 the best fitness is 0.01775997965929316']
# ['At iteration 24 the best fitness is 0.01775997965929316']
# ['At iteration 25 the best fitness is 0.013437579455886093']
# ['At iteration 26 the best fitness is 0.013437579455886093']
# ['At iteration 27 the best fitness is 0.013437579455886093']
# ['At iteration 28 the best fitness is 0.013437579455886093']
# ['At iteration 29 the best fitness is 0.013437579455886093']
#       Selected: 1144/3933 (29.1%), Fitness: 0.0134, Time: 492.8s
#       Modality: D=29%, S=28%, Sk=28%, V=30%
#     Test Acc: 96.30%, F1: 96.17%, Features: 1144/3933 (29.1%), Model: 2.776MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.033122084637300965']
# ['At iteration 1 the best fitness is 0.03286782580180643']
# ['At iteration 2 the best fitness is 0.023811339944063058']
# ['At iteration 3 the best fitness is 0.023811339944063058']
# ['At iteration 4 the best fitness is 0.023811339944063058']
# ['At iteration 5 the best fitness is 0.023811339944063058']
# ['At iteration 6 the best fitness is 0.023811339944063058']
# ['At iteration 7 the best fitness is 0.023811339944063058']
# ['At iteration 8 the best fitness is 0.023811339944063058']
# ['At iteration 9 the best fitness is 0.023811339944063058']
# ['At iteration 10 the best fitness is 0.023811339944063058']
# ['At iteration 11 the best fitness is 0.023811339944063058']
# ['At iteration 12 the best fitness is 0.023811339944063058']
# ['At iteration 13 the best fitness is 0.023811339944063058']
# ['At iteration 14 the best fitness is 0.023811339944063058']
# ['At iteration 15 the best fitness is 0.023811339944063058']
# ['At iteration 16 the best fitness is 0.023811339944063058']
# ['At iteration 17 the best fitness is 0.023811339944063058']
# ['At iteration 18 the best fitness is 0.023811339944063058']
# ['At iteration 19 the best fitness is 0.023811339944063058']
# ['At iteration 20 the best fitness is 0.023811339944063058']
# ['At iteration 21 the best fitness is 0.023811339944063058']
# ['At iteration 22 the best fitness is 0.023811339944063058']
# ['At iteration 23 the best fitness is 0.023811339944063058']
# ['At iteration 24 the best fitness is 0.023811339944063058']
# ['At iteration 25 the best fitness is 0.023811339944063058']
# ['At iteration 26 the best fitness is 0.023811339944063058']
# ['At iteration 27 the best fitness is 0.023811339944063058']
# ['At iteration 28 the best fitness is 0.023811339944063058']
# ['At iteration 29 the best fitness is 0.023811339944063058']
#       Selected: 1918/3933 (48.8%), Fitness: 0.0238, Time: 409.4s
#       Modality: D=50%, S=48%, Sk=50%, V=48%
#     Test Acc: 94.44%, F1: 93.83%, Features: 1918/3933 (48.8%), Model: 4.287MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03356703759941639']
# ['At iteration 2 the best fitness is 0.03356703759941639']
# ['At iteration 3 the best fitness is 0.03356703759941639']
# ['At iteration 4 the best fitness is 0.026570048309178747']
# ['At iteration 5 the best fitness is 0.026570048309178747']
# ['At iteration 6 the best fitness is 0.026570048309178747']
# ['At iteration 7 the best fitness is 0.026570048309178747']
# ['At iteration 8 the best fitness is 0.026303076531909487']
# ['At iteration 9 the best fitness is 0.024739384693618104']
# ['At iteration 10 the best fitness is 0.024739384693618104']
# ['At iteration 11 the best fitness is 0.024739384693618104']
# ['At iteration 12 the best fitness is 0.024739384693618104']
# ['At iteration 13 the best fitness is 0.024739384693618104']
# ['At iteration 14 the best fitness is 0.024739384693618104']
# ['At iteration 15 the best fitness is 0.024739384693618104']
# ['At iteration 16 the best fitness is 0.024739384693618104']
# ['At iteration 17 the best fitness is 0.024739384693618104']
# ['At iteration 18 the best fitness is 0.024739384693618104']
# ['At iteration 19 the best fitness is 0.024739384693618104']
# ['At iteration 20 the best fitness is 0.024739384693618104']
# ['At iteration 21 the best fitness is 0.024739384693618104']
# ['At iteration 22 the best fitness is 0.024739384693618104']
# ['At iteration 23 the best fitness is 0.024739384693618104']
# ['At iteration 24 the best fitness is 0.024739384693618104']
# ['At iteration 25 the best fitness is 0.024739384693618104']
# ['At iteration 26 the best fitness is 0.024739384693618104']
# ['At iteration 27 the best fitness is 0.024739384693618104']
# ['At iteration 28 the best fitness is 0.024739384693618104']
# ['At iteration 29 the best fitness is 0.024739384693618104']
#       Selected: 1941/3933 (49.4%), Fitness: 0.0247, Time: 389.6s
#       Modality: D=56%, S=52%, Sk=49%, V=48%
#     Test Acc: 98.15%, F1: 98.20%, Features: 1941/3933 (49.4%), Model: 4.332MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03385943526023511']
# ['At iteration 2 the best fitness is 0.033643315250064754']
# ['At iteration 3 the best fitness is 0.033643315250064754']
# ['At iteration 4 the best fitness is 0.033643315250064754']
# ['At iteration 5 the best fitness is 0.03346533406521858']
# ['At iteration 6 the best fitness is 0.0334271952398944']
# ['At iteration 7 the best fitness is 0.03337634347279549']
# ['At iteration 8 the best fitness is 0.03337634347279549']
# ['At iteration 9 the best fitness is 0.024726671751843378']
# ['At iteration 10 the best fitness is 0.024726671751843378']
# ['At iteration 11 the best fitness is 0.024726671751843378']
# ['At iteration 12 the best fitness is 0.024726671751843378']
# ['At iteration 13 the best fitness is 0.024726671751843378']
# ['At iteration 14 the best fitness is 0.024726671751843378']
# ['At iteration 15 the best fitness is 0.024726671751843378']
# ['At iteration 16 the best fitness is 0.024726671751843378']
# ['At iteration 17 the best fitness is 0.024726671751843378']
# ['At iteration 18 the best fitness is 0.024726671751843378']
# ['At iteration 19 the best fitness is 0.024726671751843378']
# ['At iteration 20 the best fitness is 0.024726671751843378']
# ['At iteration 21 the best fitness is 0.024726671751843378']
# ['At iteration 22 the best fitness is 0.024726671751843378']
# ['At iteration 23 the best fitness is 0.024726671751843378']
# ['At iteration 24 the best fitness is 0.024726671751843378']
# ['At iteration 25 the best fitness is 0.024726671751843378']
# ['At iteration 26 the best fitness is 0.024726671751843378']
# ['At iteration 27 the best fitness is 0.024650394101195017']
# ['At iteration 28 the best fitness is 0.024650394101195017']
# ['At iteration 29 the best fitness is 0.024650394101195017']
# ['At iteration 30 the best fitness is 0.024650394101195017']
#       Selected: 1935/3933 (49.2%), Fitness: 0.0247, Time: 401.7s
#       Modality: D=49%, S=48%, Sk=51%, V=48%
#     Test Acc: 94.44%, F1: 93.83%, Features: 1935/3933 (49.2%), Model: 4.320MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03341448229811968']
# ['At iteration 2 the best fitness is 0.03294410345245479']
# ['At iteration 3 the best fitness is 0.03294410345245479']
# ['At iteration 4 the best fitness is 0.03294410345245479']
# ['At iteration 5 the best fitness is 0.03262627990808662']
# ['At iteration 6 the best fitness is 0.03262627990808662']
# ['At iteration 7 the best fitness is 0.0324737246067899']
# ['At iteration 8 the best fitness is 0.0324737246067899']
# ['At iteration 9 the best fitness is 0.0324737246067899']
# ['At iteration 10 the best fitness is 0.0324737246067899']
# ['At iteration 11 the best fitness is 0.0324737246067899']
# ['At iteration 12 the best fitness is 0.0324737246067899']
# ['At iteration 13 the best fitness is 0.032232178713070096']
# ['At iteration 14 the best fitness is 0.032232178713070096']
# ['At iteration 15 the best fitness is 0.03211776223709755']
# ['At iteration 16 the best fitness is 0.03211776223709755']
# ['At iteration 17 the best fitness is 0.03211776223709755']
# ['At iteration 18 the best fitness is 0.03211776223709755']
# ['At iteration 19 the best fitness is 0.03211776223709755']
# ['At iteration 20 the best fitness is 0.03211776223709755']
# ['At iteration 21 the best fitness is 0.03211776223709755']
# ['At iteration 22 the best fitness is 0.03205419752822392']
# ['At iteration 23 the best fitness is 0.03205419752822392']
# ['At iteration 24 the best fitness is 0.03205419752822392']
# ['At iteration 25 the best fitness is 0.03205419752822392']
# ['At iteration 26 the best fitness is 0.03205419752822392']
# ['At iteration 27 the best fitness is 0.03205419752822392']
# ['At iteration 28 the best fitness is 0.03205419752822392']
# ['At iteration 29 the best fitness is 0.03205419752822392']
# ['At iteration 30 the best fitness is 0.03205419752822392']
#       Selected: 1861/3933 (47.3%), Fitness: 0.0321, Time: 398.3s
#       Modality: D=50%, S=47%, Sk=48%, V=46%
#     Test Acc: 94.44%, F1: 94.17%, Features: 1861/3933 (47.3%), Model: 4.176MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02480294940249174']
# ['At iteration 1 the best fitness is 0.02276887871853547']
# ['At iteration 2 the best fitness is 0.02276887871853547']
# ['At iteration 3 the best fitness is 0.02276887871853547']
# ['At iteration 4 the best fitness is 0.02276887871853547']
# ['At iteration 5 the best fitness is 0.02276887871853547']
# ['At iteration 6 the best fitness is 0.02276887871853547']
# ['At iteration 7 the best fitness is 0.02276887871853547']
# ['At iteration 8 the best fitness is 0.02276887871853547']
# ['At iteration 9 the best fitness is 0.02276887871853547']
# ['At iteration 10 the best fitness is 0.02276887871853547']
# ['At iteration 11 the best fitness is 0.02276887871853547']
# ['At iteration 12 the best fitness is 0.02276887871853547']
# ['At iteration 13 the best fitness is 0.02276887871853547']
# ['At iteration 14 the best fitness is 0.016704805491990847']
# ['At iteration 15 the best fitness is 0.015598779557589627']
# ['At iteration 16 the best fitness is 0.015598779557589627']
# ['At iteration 17 the best fitness is 0.015598779557589627']
# ['At iteration 18 the best fitness is 0.015598779557589627']
# ['At iteration 19 the best fitness is 0.015598779557589627']
# ['At iteration 20 the best fitness is 0.015598779557589627']
# ['At iteration 21 the best fitness is 0.015598779557589627']
# ['At iteration 22 the best fitness is 0.015598779557589627']
# ['At iteration 23 the best fitness is 0.01280193236714976']
# ['At iteration 24 the best fitness is 0.01280193236714976']
# ['At iteration 25 the best fitness is 0.01280193236714976']
# ['At iteration 26 the best fitness is 0.01280193236714976']
# ['At iteration 27 the best fitness is 0.01280193236714976']
# ['At iteration 28 the best fitness is 0.01280193236714976']
# ['At iteration 29 the best fitness is 0.01280193236714976']
#       Selected: 1046/3933 (26.6%), Fitness: 0.0128, Time: 368.1s
#       Modality: D=27%, S=26%, Sk=26%, V=27%
#     Test Acc: 93.52%, F1: 92.84%, Features: 1046/3933 (26.6%), Model: 2.584MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.025108060005085177']
# ['At iteration 2 the best fitness is 0.025108060005085177']
# ['At iteration 3 the best fitness is 0.024726671751843378']
# ['At iteration 4 the best fitness is 0.02434528349860158']
# ['At iteration 5 the best fitness is 0.02434528349860158']
# ['At iteration 6 the best fitness is 0.02434528349860158']
# ['At iteration 7 the best fitness is 0.02434528349860158']
# ['At iteration 8 the best fitness is 0.02434528349860158']
# ['At iteration 9 the best fitness is 0.02434528349860158']
# ['At iteration 10 the best fitness is 0.02434528349860158']
# ['At iteration 11 the best fitness is 0.02434528349860158']
# ['At iteration 12 the best fitness is 0.02434528349860158']
# ['At iteration 13 the best fitness is 0.02434528349860158']
# ['At iteration 14 the best fitness is 0.02434528349860158']
# ['At iteration 15 the best fitness is 0.02434528349860158']
# ['At iteration 16 the best fitness is 0.02434528349860158']
# ['At iteration 17 the best fitness is 0.0243071446732774']
# ['At iteration 18 the best fitness is 0.0243071446732774']
# ['At iteration 19 the best fitness is 0.0243071446732774']
# ['At iteration 20 the best fitness is 0.0243071446732774']
# ['At iteration 21 the best fitness is 0.0243071446732774']
# ['At iteration 22 the best fitness is 0.0243071446732774']
# ['At iteration 23 the best fitness is 0.0243071446732774']
# ['At iteration 24 the best fitness is 0.0243071446732774']
# ['At iteration 25 the best fitness is 0.0243071446732774']
# ['At iteration 26 the best fitness is 0.0243071446732774']
# ['At iteration 27 the best fitness is 0.0243071446732774']
# ['At iteration 28 the best fitness is 0.0243071446732774']
# ['At iteration 29 the best fitness is 0.0243071446732774']
#       Selected: 1949/3933 (49.6%), Fitness: 0.0243, Time: 1000.9s
#       Modality: D=49%, S=49%, Sk=50%, V=50%
#     Test Acc: 99.07%, F1: 99.06%, Features: 1949/3933 (49.6%), Model: 4.348MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.042305699912791594']
# ['At iteration 1 the best fitness is 0.03254703194393949']
# ['At iteration 2 the best fitness is 0.03254703194393949']
# ['At iteration 3 the best fitness is 0.03254703194393949']
# ['At iteration 4 the best fitness is 0.03254703194393949']
# ['At iteration 5 the best fitness is 0.03254703194393949']
# ['At iteration 6 the best fitness is 0.0147900225981451']
# ['At iteration 7 the best fitness is 0.0147900225981451']
# ['At iteration 8 the best fitness is 0.0147900225981451']
# ['At iteration 9 the best fitness is 0.0147900225981451']
# ['At iteration 10 the best fitness is 0.0147900225981451']
# ['At iteration 11 the best fitness is 0.0147900225981451']
# ['At iteration 12 the best fitness is 0.014701032005722012']
# ['At iteration 13 the best fitness is 0.014701032005722012']
# ['At iteration 14 the best fitness is 0.014701032005722012']
# ['At iteration 15 the best fitness is 0.014701032005722012']
# ['At iteration 16 the best fitness is 0.014701032005722012']
# ['At iteration 17 the best fitness is 0.014701032005722012']
# ['At iteration 18 the best fitness is 0.014701032005722012']
# ['At iteration 19 the best fitness is 0.014701032005722012']
# ['At iteration 20 the best fitness is 0.014701032005722012']
# ['At iteration 21 the best fitness is 0.014701032005722012']
# ['At iteration 22 the best fitness is 0.014701032005722012']
# ['At iteration 23 the best fitness is 0.014701032005722012']
# ['At iteration 24 the best fitness is 0.00615306381896771']
# ['At iteration 25 the best fitness is 0.00615306381896771']
# ['At iteration 26 the best fitness is 0.00615306381896771']
# ['At iteration 27 the best fitness is 0.00615306381896771']
# ['At iteration 28 the best fitness is 0.00615306381896771']
# ['At iteration 29 the best fitness is 0.00615306381896771']
#       Selected: 554/3933 (14.1%), Fitness: 0.0062, Time: 322.1s
#       Modality: D=12%, S=12%, Sk=14%, V=15%
#     Test Acc: 98.15%, F1: 98.12%, Features: 554/3933 (14.1%), Model: 1.623MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Applying weights from weighted_SCA: [depth=0.000, sensor=0.986, skeleton=0.981, video=0.000]
#   Train: 646, Val: 107, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 91.67%, F1: 89.18%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 20.9s
#     Test Acc: 88.89%, F1: 86.94%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 3.8s
#     Test Acc: 94.44%, F1: 93.09%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 0.4s
#     Test Acc: 76.85%, F1: 72.88%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025184337655733538']
# ['At iteration 1 the best fitness is 0.025184337655733538']
# ['At iteration 2 the best fitness is 0.025184337655733538']
# ['At iteration 3 the best fitness is 0.025184337655733538']
# ['At iteration 4 the best fitness is 0.025184337655733538']
# ['At iteration 5 the best fitness is 0.024917365878464277']
# ['At iteration 6 the best fitness is 0.024917365878464277']
# ['At iteration 7 the best fitness is 0.024917365878464277']
# ['At iteration 8 the best fitness is 0.02490465293668955']
# ['At iteration 9 the best fitness is 0.024853801169590642']
# ['At iteration 10 the best fitness is 0.024726671751843378']
# ['At iteration 11 the best fitness is 0.024726671751843378']
# ['At iteration 12 the best fitness is 0.024726671751843378']
# ['At iteration 13 the best fitness is 0.024726671751843378']
# ['At iteration 14 the best fitness is 0.024726671751843378']
# ['At iteration 15 the best fitness is 0.024726671751843378']
# ['At iteration 16 the best fitness is 0.024726671751843378']
# ['At iteration 17 the best fitness is 0.024726671751843378']
# ['At iteration 18 the best fitness is 0.024726671751843378']
# ['At iteration 19 the best fitness is 0.024726671751843378']
# ['At iteration 20 the best fitness is 0.024726671751843378']
# ['At iteration 21 the best fitness is 0.024726671751843378']
# ['At iteration 22 the best fitness is 0.024726671751843378']
# ['At iteration 23 the best fitness is 0.024726671751843378']
# ['At iteration 24 the best fitness is 0.024726671751843378']
# ['At iteration 25 the best fitness is 0.024726671751843378']
# ['At iteration 26 the best fitness is 0.024726671751843378']
# ['At iteration 27 the best fitness is 0.024726671751843378']
# ['At iteration 28 the best fitness is 0.024726671751843378']
# ['At iteration 29 the best fitness is 0.024726671751843378']
#       Selected: 1952/3933 (49.6%), Fitness: 0.0247, Time: 414.1s
#       Modality: D=56%, S=47%, Sk=48%, V=51%
#     Test Acc: 94.44%, F1: 93.18%, Features: 1952/3933 (49.6%), Model: 4.354MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.033312778763921864']
# ['At iteration 10 the best fitness is 0.024091024663107044']
# ['At iteration 20 the best fitness is 0.024091024663107044']
#       Selected: 1870/3933 (47.5%), Fitness: 0.0241, Time: 805.4s
#       Modality: D=51%, S=49%, Sk=47%, V=47%
#     Test Acc: 91.67%, F1: 90.73%, Features: 1870/3933 (47.5%), Model: 4.193MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024739384693618104']
# ['At iteration 2 the best fitness is 0.024739384693618104']
# ['At iteration 3 the best fitness is 0.024739384693618104']
# ['At iteration 4 the best fitness is 0.024739384693618104']
# ['At iteration 5 the best fitness is 0.024739384693618104']
# ['At iteration 6 the best fitness is 0.024739384693618104']
# ['At iteration 7 the best fitness is 0.024739384693618104']
# ['At iteration 8 the best fitness is 0.024739384693618104']
# ['At iteration 9 the best fitness is 0.024739384693618104']
# ['At iteration 10 the best fitness is 0.024739384693618104']
# ['At iteration 11 the best fitness is 0.024739384693618104']
# ['At iteration 12 the best fitness is 0.024739384693618104']
# ['At iteration 13 the best fitness is 0.024739384693618104']
# ['At iteration 14 the best fitness is 0.024739384693618104']
# ['At iteration 15 the best fitness is 0.024739384693618104']
# ['At iteration 16 the best fitness is 0.024739384693618104']
# ['At iteration 17 the best fitness is 0.024739384693618104']
# ['At iteration 18 the best fitness is 0.024739384693618104']
# ['At iteration 19 the best fitness is 0.024739384693618104']
# ['At iteration 20 the best fitness is 0.024739384693618104']
# ['At iteration 21 the best fitness is 0.024739384693618104']
# ['At iteration 22 the best fitness is 0.024739384693618104']
# ['At iteration 23 the best fitness is 0.024739384693618104']
# ['At iteration 24 the best fitness is 0.024739384693618104']
# ['At iteration 25 the best fitness is 0.024739384693618104']
# ['At iteration 26 the best fitness is 0.02438342232392576']
# ['At iteration 27 the best fitness is 0.02365878464276634']
# ['At iteration 28 the best fitness is 0.02365878464276634']
# ['At iteration 29 the best fitness is 0.02365878464276634']
# ['At iteration 30 the best fitness is 0.02365878464276634']
#       Selected: 1915/3933 (48.7%), Fitness: 0.0237, Time: 406.1s
#       Modality: D=54%, S=48%, Sk=48%, V=49%
#     Test Acc: 92.59%, F1: 90.12%, Features: 1915/3933 (48.7%), Model: 4.281MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03313479757907569']
# ['At iteration 1 the best fitness is 0.03313479757907569']
# ['At iteration 2 the best fitness is 0.033147510520850416']
# ['At iteration 3 the best fitness is 0.03319836228794932']
# ['At iteration 4 the best fitness is 0.04226756108746742']
# ['At iteration 5 the best fitness is 0.04245825521408832']
# ['At iteration 6 the best fitness is 0.024841088227815916']
# ['At iteration 7 the best fitness is 0.02438342232392576']
# ['At iteration 8 the best fitness is 0.041975163426648705']
# ['At iteration 9 the best fitness is 0.03317293640439987']
# ['At iteration 10 the best fitness is 0.03317293640439987']
# ['At iteration 11 the best fitness is 0.02429443173150267']
# ['At iteration 12 the best fitness is 0.0332365011132735']
# ['At iteration 13 the best fitness is 0.024357996440376305']
# ['At iteration 14 the best fitness is 0.033338204647471316']
# ['At iteration 15 the best fitness is 0.04214043166972015']
# ['At iteration 16 the best fitness is 0.02438342232392576']
# ['At iteration 17 the best fitness is 0.033185649346174594']
# ['At iteration 18 the best fitness is 0.024319857615052124']
# ['At iteration 19 the best fitness is 0.02429443173150267']
# ['At iteration 20 the best fitness is 0.03319836228794932']
# ['At iteration 21 the best fitness is 0.02433257055682685']
# ['At iteration 22 the best fitness is 0.033185649346174594']
# ['At iteration 23 the best fitness is 0.04206415401907179']
# ['At iteration 24 the best fitness is 0.02429443173150267']
# ['At iteration 25 the best fitness is 0.03317293640439987']
# ['At iteration 26 the best fitness is 0.03317293640439987']
# ['At iteration 27 the best fitness is 0.03317293640439987']
# ['At iteration 28 the best fitness is 0.03317293640439987']
# ['At iteration 29 the best fitness is 0.02429443173150267']
#       Selected: 1925/3933 (48.9%), Fitness: 0.0243, Time: 391.6s
#       Modality: D=47%, S=48%, Sk=47%, V=51%
#     Test Acc: 94.44%, F1: 93.78%, Features: 1925/3933 (48.9%), Model: 4.301MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.0336178893665153
# At iteration 2 the best fitness is 0.03430438822235054
# At iteration 3 the best fitness is 0.034444230581872536
# At iteration 4 the best fitness is 0.042496394039412494
# At iteration 5 the best fitness is 0.04277607875845649
# At iteration 6 the best fitness is 0.04308118936104993
# At iteration 7 the best fitness is 0.03366874113361421
# At iteration 8 the best fitness is 0.04278879170023121
# At iteration 9 the best fitness is 0.025044495296211545
# At iteration 10 the best fitness is 0.034151832921053824
# At iteration 11 the best fitness is 0.03430438822235054
# At iteration 12 the best fitness is 0.025044495296211545
# At iteration 13 the best fitness is 0.025095347063310455
# At iteration 14 the best fitness is 0.033401769356344944
# At iteration 15 the best fitness is 0.024879227053140097
# At iteration 16 the best fitness is 0.025400457665903892
# At iteration 17 the best fitness is 0.033719592900713115
# At iteration 18 the best fitness is 0.024790236460717013
# At iteration 19 the best fitness is 0.025222476481057715
# At iteration 20 the best fitness is 0.024930078820239007
# At iteration 21 the best fitness is 0.024942791762013732
# At iteration 22 the best fitness is 0.024968217645563187
# At iteration 23 the best fitness is 0.034037416445081285
# At iteration 24 the best fitness is 0.025375031782354437
# At iteration 25 the best fitness is 0.025336892957030257
# At iteration 26 the best fitness is 0.025069921179760996
# At iteration 27 the best fitness is 0.025120772946859906
# At iteration 28 the best fitness is 0.024790236460717013
# At iteration 29 the best fitness is 0.03366874113361421
# At iteration 30 the best fitness is 0.024790236460717013
#       Selected: 1905/3933 (48.4%), Fitness: 0.0248, Time: 395.6s
#       Modality: D=50%, S=51%, Sk=49%, V=47%
#     Test Acc: 90.74%, F1: 88.60%, Features: 1905/3933 (48.4%), Model: 4.262MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02490465293668955']
# ['At iteration 1 the best fitness is 0.02490465293668955']
# ['At iteration 2 the best fitness is 0.02490465293668955']
# ['At iteration 3 the best fitness is 0.02490465293668955']
# ['At iteration 4 the best fitness is 0.022171370455123317']
# ['At iteration 5 the best fitness is 0.022171370455123317']
# ['At iteration 6 the best fitness is 0.022171370455123317']
# ['At iteration 7 the best fitness is 0.022171370455123317']
# ['At iteration 8 the best fitness is 0.022171370455123317']
# ['At iteration 9 the best fitness is 0.022171370455123317']
# ['At iteration 10 the best fitness is 0.02208237986270023']
# ['At iteration 11 the best fitness is 0.021523010424612257']
# ['At iteration 12 the best fitness is 0.021523010424612257']
# ['At iteration 13 the best fitness is 0.021523010424612257']
# ['At iteration 14 the best fitness is 0.021523010424612257']
# ['At iteration 15 the best fitness is 0.02123061276379354']
# ['At iteration 16 the best fitness is 0.02123061276379354']
# ['At iteration 17 the best fitness is 0.020811085685227562']
# ['At iteration 18 the best fitness is 0.020696669209255024']
# ['At iteration 19 the best fitness is 0.02044241037376049']
# ['At iteration 20 the best fitness is 0.020391558606661583']
# ['At iteration 21 the best fitness is 0.020391558606661583']
# ['At iteration 22 the best fitness is 0.020391558606661583']
# ['At iteration 23 the best fitness is 0.02028985507246377']
# ['At iteration 24 the best fitness is 0.02028985507246377']
# ['At iteration 25 the best fitness is 0.020111873887617596']
# ['At iteration 26 the best fitness is 0.020111873887617596']
# ['At iteration 27 the best fitness is 0.020010170353419784']
# ['At iteration 28 the best fitness is 0.020010170353419784']
# ['At iteration 29 the best fitness is 0.020010170353419784']
#       Selected: 1685/3933 (42.8%), Fitness: 0.0200, Time: 386.3s
#       Modality: D=42%, S=42%, Sk=43%, V=43%
#     Test Acc: 90.74%, F1: 89.02%, Features: 1685/3933 (42.8%), Model: 3.832MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.03427896233880109']
# ['At iteration 1 the best fitness is 0.03060979348004306']
# ['At iteration 2 the best fitness is 0.03060979348004306']
# ['At iteration 3 the best fitness is 0.027197853770278335']
# ['At iteration 4 the best fitness is 0.027197853770278335']
# ['At iteration 5 the best fitness is 0.027197853770278335']
# ['At iteration 6 the best fitness is 0.027197853770278335']
# ['At iteration 7 the best fitness is 0.027197853770278335']
# ['At iteration 8 the best fitness is 0.027197853770278335']
# ['At iteration 9 the best fitness is 0.027197853770278335']
# ['At iteration 10 the best fitness is 0.027197853770278335']
# ['At iteration 11 the best fitness is 0.027197853770278335']
# ['At iteration 12 the best fitness is 0.027197853770278335']
# ['At iteration 13 the best fitness is 0.027197853770278335']
# ['At iteration 14 the best fitness is 0.027172427886728877']
# ['At iteration 15 the best fitness is 0.027172427886728877']
# ['At iteration 16 the best fitness is 0.027172427886728877']
# ['At iteration 17 the best fitness is 0.027172427886728877']
# ['At iteration 18 the best fitness is 0.025120772946859906']
# ['At iteration 19 the best fitness is 0.025120772946859906']
# ['At iteration 20 the best fitness is 0.025120772946859906']
# ['At iteration 21 the best fitness is 0.025120772946859906']
# ['At iteration 22 the best fitness is 0.025120772946859906']
# ['At iteration 23 the best fitness is 0.025120772946859906']
# ['At iteration 24 the best fitness is 0.025120772946859906']
# ['At iteration 25 the best fitness is 0.025120772946859906']
# ['At iteration 26 the best fitness is 0.025120772946859906']
# ['At iteration 27 the best fitness is 0.025120772946859906']
# ['At iteration 28 the best fitness is 0.025044495296211545']
# ['At iteration 29 the best fitness is 0.025044495296211545']
#       Selected: 1986/3933 (50.5%), Fitness: 0.0250, Time: 513.2s
#       Modality: D=47%, S=53%, Sk=50%, V=50%
#     Test Acc: 90.74%, F1: 88.24%, Features: 1986/3933 (50.5%), Model: 4.420MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03330006582214714']
# ['At iteration 1 the best fitness is 0.024650394101195017']
# ['At iteration 2 the best fitness is 0.024650394101195017']
# ['At iteration 3 the best fitness is 0.024650394101195017']
# ['At iteration 4 the best fitness is 0.024650394101195017']
# ['At iteration 5 the best fitness is 0.024256292906178492']
# ['At iteration 6 the best fitness is 0.024256292906178492']
# ['At iteration 7 the best fitness is 0.024256292906178492']
# ['At iteration 8 the best fitness is 0.024256292906178492']
# ['At iteration 9 the best fitness is 0.024256292906178492']
# ['At iteration 10 the best fitness is 0.02418001525553013']
# ['At iteration 11 the best fitness is 0.02418001525553013']
# ['At iteration 12 the best fitness is 0.02418001525553013']
# ['At iteration 13 the best fitness is 0.02418001525553013']
# ['At iteration 14 the best fitness is 0.02418001525553013']
# ['At iteration 15 the best fitness is 0.02418001525553013']
# ['At iteration 16 the best fitness is 0.02418001525553013']
# ['At iteration 17 the best fitness is 0.02418001525553013']
# ['At iteration 18 the best fitness is 0.02418001525553013']
# ['At iteration 19 the best fitness is 0.02418001525553013']
# ['At iteration 20 the best fitness is 0.02418001525553013']
# ['At iteration 21 the best fitness is 0.02418001525553013']
# ['At iteration 22 the best fitness is 0.02418001525553013']
# ['At iteration 23 the best fitness is 0.02418001525553013']
# ['At iteration 24 the best fitness is 0.02418001525553013']
# ['At iteration 25 the best fitness is 0.02418001525553013']
# ['At iteration 26 the best fitness is 0.02418001525553013']
# ['At iteration 27 the best fitness is 0.02418001525553013']
# ['At iteration 28 the best fitness is 0.02418001525553013']
# ['At iteration 29 the best fitness is 0.02418001525553013']
#       Selected: 1926/3933 (49.0%), Fitness: 0.0242, Time: 408.0s
#       Modality: D=49%, S=48%, Sk=50%, V=49%
#     Test Acc: 90.74%, F1: 88.91%, Features: 1926/3933 (49.0%), Model: 4.303MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03336363053102077']
# ['At iteration 2 the best fitness is 0.03336363053102077']
# ['At iteration 3 the best fitness is 0.03336363053102077']
# ['At iteration 4 the best fitness is 0.03336363053102077']
# ['At iteration 5 the best fitness is 0.024815662344266465']
# ['At iteration 6 the best fitness is 0.024815662344266465']
# ['At iteration 7 the best fitness is 0.024815662344266465']
# ['At iteration 8 the best fitness is 0.024815662344266465']
# ['At iteration 9 the best fitness is 0.024815662344266465']
# ['At iteration 10 the best fitness is 0.024815662344266465']
# ['At iteration 11 the best fitness is 0.024815662344266465']
# ['At iteration 12 the best fitness is 0.024815662344266465']
# ['At iteration 13 the best fitness is 0.024815662344266465']
# ['At iteration 14 the best fitness is 0.024815662344266465']
# ['At iteration 15 the best fitness is 0.024815662344266465']
# ['At iteration 16 the best fitness is 0.024815662344266465']
# ['At iteration 17 the best fitness is 0.024815662344266465']
# ['At iteration 18 the best fitness is 0.024815662344266465']
# ['At iteration 19 the best fitness is 0.024815662344266465']
# ['At iteration 20 the best fitness is 0.024815662344266465']
# ['At iteration 21 the best fitness is 0.024815662344266465']
# ['At iteration 22 the best fitness is 0.024815662344266465']
# ['At iteration 23 the best fitness is 0.024815662344266465']
# ['At iteration 24 the best fitness is 0.024815662344266465']
# ['At iteration 25 the best fitness is 0.024815662344266465']
# ['At iteration 26 the best fitness is 0.024815662344266465']
# ['At iteration 27 the best fitness is 0.024815662344266465']
# ['At iteration 28 the best fitness is 0.024815662344266465']
# ['At iteration 29 the best fitness is 0.024815662344266465']
#       Selected: 1960/3933 (49.8%), Fitness: 0.0248, Time: 387.7s
#       Modality: D=54%, S=47%, Sk=50%, V=51%
#     Test Acc: 89.81%, F1: 87.35%, Features: 1960/3933 (49.8%), Model: 4.369MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02407831172133232']
# ['At iteration 2 the best fitness is 0.02407831172133232']
# ['At iteration 3 the best fitness is 0.02407831172133232']
# ['At iteration 4 the best fitness is 0.02407831172133232']
# ['At iteration 5 the best fitness is 0.02407831172133232']
# ['At iteration 6 the best fitness is 0.02407831172133232']
# ['At iteration 7 the best fitness is 0.02407831172133232']
# ...
# ['At iteration 17 the best fitness is 0.020459994629673198']
# ['At iteration 18 the best fitness is 0.01979892165738741']
# ['At iteration 19 the best fitness is 0.01979892165738741']
# ['At iteration 20 the best fitness is 0.011873887617594711']
# ['At iteration 21 the best fitness is 0.011873887617594711']
# ['At iteration 22 the best fitness is 0.011873887617594711']
# ['At iteration 23 the best fitness is 0.011873887617594711']
# ['At iteration 24 the best fitness is 0.011873887617594711']
# ['At iteration 25 the best fitness is 0.011873887617594711']
# ['At iteration 26 the best fitness is 0.011873887617594711']
# ['At iteration 27 the best fitness is 0.011873887617594711']
# ['At iteration 28 the best fitness is 0.011873887617594711']
# ['At iteration 29 the best fitness is 0.011873887617594711']
#       Selected: 848/3933 (21.6%), Fitness: 0.0119, Time: 459.9s
#       Modality: D=23%, S=24%, Sk=21%, V=21%
#     Test Acc: 93.46%, F1: 91.60%, Features: 848/3933 (21.6%), Model: 2.197MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0336178893665153']
# ['At iteration 1 the best fitness is 0.0336178893665153']
# ['At iteration 2 the best fitness is 0.0336178893665153']
# ['At iteration 3 the best fitness is 0.033528898774092215']
# ['At iteration 4 the best fitness is 0.033528898774092215']
# ['At iteration 5 the best fitness is 0.033528898774092215']
# ['At iteration 6 the best fitness is 0.024968217645563187']
# ['At iteration 7 the best fitness is 0.024955504703788458']
# ['At iteration 8 the best fitness is 0.024955504703788458']
# ['At iteration 9 the best fitness is 0.024955504703788458']
# ['At iteration 10 the best fitness is 0.024955504703788458']
# ['At iteration 11 the best fitness is 0.024955504703788458']
# ['At iteration 12 the best fitness is 0.024955504703788458']
# ['At iteration 13 the best fitness is 0.024955504703788458']
# ['At iteration 14 the best fitness is 0.024955504703788458']
# ['At iteration 15 the best fitness is 0.024955504703788458']
# ['At iteration 16 the best fitness is 0.024955504703788458']
# ['At iteration 17 the best fitness is 0.024955504703788458']
# ['At iteration 18 the best fitness is 0.024955504703788458']
# ['At iteration 19 the best fitness is 0.024955504703788458']
# ['At iteration 20 the best fitness is 0.024955504703788458']
# ['At iteration 21 the best fitness is 0.024955504703788458']
# ['At iteration 22 the best fitness is 0.024955504703788458']
# ['At iteration 23 the best fitness is 0.024955504703788458']
# ['At iteration 24 the best fitness is 0.024955504703788458']
# ['At iteration 25 the best fitness is 0.024955504703788458']
# ['At iteration 26 the best fitness is 0.024955504703788458']
# ['At iteration 27 the best fitness is 0.024955504703788458']
# ['At iteration 28 the best fitness is 0.024955504703788458']
# ['At iteration 29 the best fitness is 0.024955504703788458']
#       Selected: 1962/3933 (49.9%), Fitness: 0.0250, Time: 409.2s
#       Modality: D=48%, S=50%, Sk=50%, V=50%
#     Test Acc: 99.07%, F1: 98.94%, Features: 1962/3933 (49.9%), Model: 4.373MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.051158778702139335']
# ['At iteration 2 the best fitness is 0.04290320817620375']
# ['At iteration 3 the best fitness is 0.03356703759941639']
# ['At iteration 4 the best fitness is 0.03356703759941639']
# ['At iteration 5 the best fitness is 0.03356703759941639']
# ['At iteration 6 the best fitness is 0.03356703759941639']
# ['At iteration 7 the best fitness is 0.03356703759941639']
# ['At iteration 8 the best fitness is 0.03356703759941639']
# ['At iteration 9 the best fitness is 0.025451309433002795']
# ['At iteration 10 the best fitness is 0.025451309433002795']
# ['At iteration 11 the best fitness is 0.025451309433002795']
# ['At iteration 12 the best fitness is 0.025451309433002795']
# ['At iteration 13 the best fitness is 0.025451309433002795']
# ['At iteration 14 the best fitness is 0.025298754131706076']
# ['At iteration 15 the best fitness is 0.025298754131706076']
# ['At iteration 16 the best fitness is 0.025298754131706076']
# ['At iteration 17 the best fitness is 0.025298754131706076']
# ['At iteration 18 the best fitness is 0.025298754131706076']
# ['At iteration 19 the best fitness is 0.025298754131706076']
# ['At iteration 20 the best fitness is 0.025298754131706076']
# ['At iteration 21 the best fitness is 0.025298754131706076']
# ['At iteration 22 the best fitness is 0.025298754131706076']
# ['At iteration 23 the best fitness is 0.025298754131706076']
# ['At iteration 24 the best fitness is 0.025298754131706076']
# ['At iteration 25 the best fitness is 0.025298754131706076']
# ['At iteration 26 the best fitness is 0.025298754131706076']
# ['At iteration 27 the best fitness is 0.025298754131706076']
# ['At iteration 28 the best fitness is 0.025298754131706076']
# ['At iteration 29 the best fitness is 0.024879227053140097']
#       Selected: 1940/3933 (49.3%), Fitness: 0.0249, Time: 388.7s
#       Modality: D=52%, S=50%, Sk=49%, V=49%
#     Test Acc: 98.13%, F1: 98.12%, Features: 1940/3933 (49.3%), Model: 4.330MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.034177258804603275']
# ['At iteration 2 the best fitness is 0.024841088227815916']
# ['At iteration 3 the best fitness is 0.024841088227815916']
# ['At iteration 4 the best fitness is 0.024841088227815916']
# ['At iteration 5 the best fitness is 0.024586829392321385']
# ['At iteration 6 the best fitness is 0.024586829392321385']
# ['At iteration 7 the best fitness is 0.024586829392321385']
# ['At iteration 8 the best fitness is 0.024586829392321385']
# ['At iteration 9 the best fitness is 0.024586829392321385']
# ['At iteration 10 the best fitness is 0.02457411645054666']
# ['At iteration 11 the best fitness is 0.02457411645054666']
# ['At iteration 12 the best fitness is 0.02457411645054666']
# ['At iteration 13 the best fitness is 0.02457411645054666']
# ['At iteration 14 the best fitness is 0.02457411645054666']
# ['At iteration 15 the best fitness is 0.02457411645054666']
# ['At iteration 16 the best fitness is 0.02457411645054666']
# ['At iteration 17 the best fitness is 0.02457411645054666']
# ['At iteration 18 the best fitness is 0.02457411645054666']
# ['At iteration 19 the best fitness is 0.02457411645054666']
# ['At iteration 20 the best fitness is 0.02434528349860158']
# ['At iteration 21 the best fitness is 0.024319857615052124']
# ['At iteration 22 the best fitness is 0.024230867022629037']
# ['At iteration 23 the best fitness is 0.024230867022629037']
# ['At iteration 24 the best fitness is 0.024230867022629037']
# ['At iteration 25 the best fitness is 0.024230867022629037']
# ['At iteration 26 the best fitness is 0.024230867022629037']
# ['At iteration 27 the best fitness is 0.024230867022629037']
# ['At iteration 28 the best fitness is 0.024230867022629037']
# ['At iteration 29 the best fitness is 0.024230867022629037']
# ['At iteration 30 the best fitness is 0.024230867022629037']
#       Selected: 1933/3933 (49.1%), Fitness: 0.0242, Time: 399.5s
#       Modality: D=50%, S=51%, Sk=49%, V=48%
#     Test Acc: 99.07%, F1: 98.94%, Features: 1933/3933 (49.1%), Model: 4.317MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03382129643491093']
# ['At iteration 2 the best fitness is 0.03382129643491093']
# ['At iteration 3 the best fitness is 0.03382129643491093']
# ['At iteration 4 the best fitness is 0.033261926996822955']
# ['At iteration 5 the best fitness is 0.033261926996822955']
# ['At iteration 6 the best fitness is 0.033185649346174594']
# ['At iteration 7 the best fitness is 0.033185649346174594']
# ['At iteration 8 the best fitness is 0.033185649346174594']
# ['At iteration 9 the best fitness is 0.024510551741673024']
# ['At iteration 10 the best fitness is 0.024510551741673024']
# ['At iteration 11 the best fitness is 0.024510551741673024']
# ['At iteration 12 the best fitness is 0.024510551741673024']
# ['At iteration 13 the best fitness is 0.024510551741673024']
# ['At iteration 14 the best fitness is 0.024510551741673024']
# ['At iteration 15 the best fitness is 0.024510551741673024']
# ['At iteration 16 the best fitness is 0.024510551741673024']
# ['At iteration 17 the best fitness is 0.024510551741673024']
# ['At iteration 18 the best fitness is 0.024510551741673024']
# ['At iteration 19 the best fitness is 0.024510551741673024']
# ['At iteration 20 the best fitness is 0.024510551741673024']
# ['At iteration 21 the best fitness is 0.024510551741673024']
# ['At iteration 22 the best fitness is 0.024510551741673024']
# ['At iteration 23 the best fitness is 0.024510551741673024']
# ['At iteration 24 the best fitness is 0.024510551741673024']
# ['At iteration 25 the best fitness is 0.024510551741673024']
# ['At iteration 26 the best fitness is 0.024510551741673024']
# ['At iteration 27 the best fitness is 0.024510551741673024']
# ['At iteration 28 the best fitness is 0.024510551741673024']
# ['At iteration 29 the best fitness is 0.024510551741673024']
# ['At iteration 30 the best fitness is 0.024510551741673024']
#       Selected: 1926/3933 (49.0%), Fitness: 0.0245, Time: 400.3s
#       Modality: D=43%, S=46%, Sk=51%, V=49%
#     Test Acc: 100.00%, F1: 100.00%, Features: 1926/3933 (49.0%), Model: 4.303MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03343990818166913']
# ['At iteration 1 the best fitness is 0.03343990818166913']
# ['At iteration 2 the best fitness is 0.03098631041914688']
# ['At iteration 3 the best fitness is 0.03098631041914688']
# ['At iteration 4 the best fitness is 0.02778264909191576']
# ['At iteration 5 the best fitness is 0.027032585527206887']
# ['At iteration 6 the best fitness is 0.027032585527206887']
# ['At iteration 7 the best fitness is 0.027032585527206887']
# ['At iteration 8 the best fitness is 0.02323141593656361']
# ['At iteration 9 the best fitness is 0.02207453823506348']
# ['At iteration 10 the best fitness is 0.021375326437453518']
# ['At iteration 11 the best fitness is 0.0205108463967721']
# ['At iteration 12 the best fitness is 0.019506523996568693']
# ['At iteration 13 the best fitness is 0.019506523996568693']
# ['At iteration 14 the best fitness is 0.01892172867493127']
# ['At iteration 15 the best fitness is 0.009216882786676837']
# ['At iteration 16 the best fitness is 0.009216882786676837']
# ['At iteration 17 the best fitness is 0.009216882786676837']
# ['At iteration 18 the best fitness is 0.009216882786676837']
# ['At iteration 19 the best fitness is 0.009216882786676837']
# ['At iteration 20 the best fitness is 0.009216882786676837']
# ['At iteration 21 the best fitness is 0.009216882786676837']
# ['At iteration 22 the best fitness is 0.009216882786676837']
# ['At iteration 23 the best fitness is 0.009216882786676837']
# ['At iteration 24 the best fitness is 0.009216882786676837']
# ['At iteration 25 the best fitness is 0.008263412153572338']
# ['At iteration 26 the best fitness is 0.008263412153572338']
# ['At iteration 27 the best fitness is 0.008263412153572338']
# ['At iteration 28 the best fitness is 0.008263412153572338']
# ['At iteration 29 the best fitness is 0.006903127383676583']
#       Selected: 601/3933 (15.3%), Fitness: 0.0069, Time: 350.4s
#       Modality: D=16%, S=17%, Sk=16%, V=14%
#     Test Acc: 99.07%, F1: 99.06%, Features: 601/3933 (15.3%), Model: 1.715MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03351618583231749']
# ['At iteration 2 the best fitness is 0.03351618583231749']
# ['At iteration 3 the best fitness is 0.03316022346262514']
# ['At iteration 4 the best fitness is 0.03316022346262514']
# ['At iteration 5 the best fitness is 0.03316022346262514']
# ['At iteration 6 the best fitness is 0.03316022346262514']
# ['At iteration 7 the best fitness is 0.03316022346262514']
# ['At iteration 8 the best fitness is 0.02438342232392576']
# ['At iteration 9 the best fitness is 0.02438342232392576']
# ['At iteration 10 the best fitness is 0.02438342232392576']
# ['At iteration 11 the best fitness is 0.02438342232392576']
# ['At iteration 12 the best fitness is 0.02438342232392576']
# ['At iteration 13 the best fitness is 0.02438342232392576']
# ['At iteration 14 the best fitness is 0.024281718789727944']
# ['At iteration 15 the best fitness is 0.024281718789727944']
# ['At iteration 16 the best fitness is 0.024281718789727944']
# ['At iteration 17 the best fitness is 0.024281718789727944']
# ['At iteration 18 the best fitness is 0.024281718789727944']
# ['At iteration 19 the best fitness is 0.024281718789727944']
# ['At iteration 20 the best fitness is 0.024281718789727944']
# ['At iteration 21 the best fitness is 0.024281718789727944']
# ['At iteration 22 the best fitness is 0.024281718789727944']
# ['At iteration 23 the best fitness is 0.024281718789727944']
# ['At iteration 24 the best fitness is 0.024281718789727944']
# ['At iteration 25 the best fitness is 0.024281718789727944']
# ['At iteration 26 the best fitness is 0.024281718789727944']
# ['At iteration 27 the best fitness is 0.024281718789727944']
# ['At iteration 28 the best fitness is 0.024281718789727944']
# ['At iteration 29 the best fitness is 0.024281718789727944']
#       Selected: 1934/3933 (49.2%), Fitness: 0.0243, Time: 999.0s
#       Modality: D=49%, S=51%, Sk=47%, V=51%
#     Test Acc: 92.52%, F1: 90.46%, Features: 1934/3933 (49.2%), Model: 4.318MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.034711202359141796']
# ['At iteration 1 the best fitness is 0.023167851227689974']
# ['At iteration 2 the best fitness is 0.023167851227689974']
# ['At iteration 3 the best fitness is 0.023167851227689974']
# ['At iteration 4 the best fitness is 0.023167851227689974']
# ['At iteration 5 the best fitness is 0.023167851227689974']
# ['At iteration 6 the best fitness is 0.023167851227689974']
# ['At iteration 7 the best fitness is 0.023167851227689974']
# ['At iteration 8 the best fitness is 0.023167851227689974']
# ['At iteration 9 the best fitness is 0.023167851227689974']
# ['At iteration 10 the best fitness is 0.023167851227689974']
# ['At iteration 11 the best fitness is 0.023167851227689974']
# ['At iteration 12 the best fitness is 0.023167851227689974']
# ['At iteration 13 the best fitness is 0.023167851227689974']
# ['At iteration 14 the best fitness is 0.023167851227689974']
# ['At iteration 15 the best fitness is 0.023167851227689974']
# ['At iteration 16 the best fitness is 0.02250677825540419']
# ['At iteration 17 the best fitness is 0.02250677825540419']
# ['At iteration 18 the best fitness is 0.02250677825540419']
# ['At iteration 19 the best fitness is 0.02250677825540419']
# ['At iteration 20 the best fitness is 0.02250677825540419']
# ['At iteration 21 the best fitness is 0.02250677825540419']
# ['At iteration 22 the best fitness is 0.02250677825540419']
# ['At iteration 23 the best fitness is 0.02250677825540419']
# ['At iteration 24 the best fitness is 0.02250677825540419']
# ['At iteration 25 the best fitness is 0.02250677825540419']
# ['At iteration 26 the best fitness is 0.02250677825540419']
# ['At iteration 27 the best fitness is 0.02250677825540419']
# ['At iteration 28 the best fitness is 0.02250677825540419']
# ['At iteration 29 the best fitness is 0.02212539000216239']
#       Selected: 1178/3933 (30.0%), Fitness: 0.0221, Time: 347.5s
#       Modality: D=27%, S=33%, Sk=28%, V=31%
#     Test Acc: 95.33%, F1: 94.77%, Features: 1178/3933 (30.0%), Model: 2.842MB
#
# ================================================================================
# ALL EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Per-Fold Results CSV

# %%
rows = []
for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'Weight Method Used': r['weight_method_used'],
        }
        
        # Per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        # Per-modality weights used
        mod_w = r['modality_weights_used']
        for i, mod_name in enumerate(MODALITY_NAMES):
            row[f'w_{mod_name}'] = mod_w[i]
        
        rows.append(row)

df_all = pd.DataFrame(rows).round(4)
df_all.to_csv(RESULTS_ROOT / "all_results_per_fold.csv", index=False)
print(f"Saved: {RESULTS_ROOT / 'all_results_per_fold.csv'}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved: results_weighted_fs/all_results_per_fold.csv
# Shape: (144, 33)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB) Weight Method Used  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected  w_depth  w_sensor  w_skeleton  w_video
# 0      baseline     1            93.5185           99.0654       92.8865          92.8865              93.7037           93.5185               3933            3933               100.0000       0.0000          9.6238          9.6238       2154011           8.2228                25.8355                 25.8355                 0.0000        85.5093      weighted_JAYA             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420   0.1540    0.3849      0.6681   0.1675
# 1      baseline     2            91.6667           99.0654       89.1828          89.1828              88.1481           91.6667               3933            3933               100.0000       0.0000          8.8257          8.8257       2154011           8.2228                25.8355                 25.8355                 0.0000        85.5093       weighted_SCA             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420   0.0000    0.9861      0.9812   0.0000
# 2      baseline     3            96.2963           99.0654       96.1434          96.1434              97.2840           96.2963               3933            3933               100.0000       0.0000          8.4127          8.4127       2154011           8.2228                25.8355                 25.8355                 0.0000        85.5093       weighted_SSA             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420   0.0000    0.9843      0.7851   0.0082
# 3      baseline     4            90.7407          100.0000       89.4044          89.4044              90.5350           90.7407               3933            3933               100.0000       0.0000          8.5555          8.5555       2154011           8.2228                25.8355                 25.8355                 0.0000        85.5093      weighted_JAYA             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420   0.0000    0.5701      0.6062   0.0000
# 4      baseline     5            95.3704           99.0654       94.8864          94.8864              96.9312           95.3704               3933            3933               100.0000       0.0000          8.5178          8.5179       2154011           8.2228                25.8355                 25.8355                 0.0000        85.5093       weighted_BAT             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420   0.0598    0.6588      0.6602   0.0000
# 5      baseline     6            94.3925          100.0000       93.1805          93.1167              92.9630           94.4444               3933            3933               100.0000       0.0000          8.3491          8.3492       2154011           8.2228                25.8355                 25.8355                 0.0000        85.5093       weighted_GWO             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420   0.0741    0.9687      0.9162   0.4256
# 6      baseline     7            95.3271           99.0654       95.2381          95.1936              96.2963           95.3704               3933            3933               100.0000       0.0000          8.4054          8.4054       2154011           8.2228                25.8355                 25.8355                 0.0000        85.5093      weighted_JAYA             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420   0.7757    0.5042      0.5096   0.0253
# 7      baseline     8            98.1308           98.1308       98.0159          98.2310              98.5185           98.1481               3933            3933               100.0000       0.0000          8.5208          8.5208       2154011           8.2228                25.8355                 25.8355                 0.0000        85.5093        weighted_GA             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420   0.2064    0.7639      0.8659   0.2599
# 8   mutual_info     1            94.4444           97.1963       93.8272          93.8272              94.4444           94.4444               1966            3933                49.9873      21.3645          7.3689         28.7335       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202      weighted_JAYA              22.2222              48               59.3558              387                 45.8967                755              54.6479             776   0.1540    0.3849      0.6681   0.1675
# 9   mutual_info     2            88.8889          100.0000       86.9382          86.9382              89.6473           88.8889               1966            3933                49.9873      20.8717          6.6037         27.4755       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202       weighted_SCA               0.0000               0               95.2454              621                 81.7629               1345               0.0000               0   0.0000    0.9861      0.9812   0.0000
# 10  mutual_info     3            83.3333           99.0654       80.4343          80.4343              82.4045           83.3333               1966            3933                49.9873      20.8395          6.5308         27.3703       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202       weighted_SSA               0.0000               0               59.9693              391                 47.9027                788              55.4225             787   0.0000    0.9843      0.7851   0.0082
# 11  mutual_info     4            92.5926          100.0000       92.3497          92.3497              95.0176           92.5926               1966            3933                49.9873      21.0249          6.6039         27.6289       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202      weighted_JAYA               0.0000               0               94.6319              617                 82.0061               1349               0.0000               0   0.0000    0.5701      0.6062   0.0000
# 12  mutual_info     5            96.2963           99.0654       96.1434          96.1434              97.2840           96.2963               1966            3933                49.9873      20.9519          6.5757         27.5277       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202       weighted_BAT              66.6667             144               89.4172              583                 75.3191               1239               0.0000               0   0.0598    0.6588      0.6602   0.0000
# 13  mutual_info     6            94.3925           98.1481       94.4150          94.3629              96.6667           94.4444               1966            3933                49.9873      20.9280          6.5494         27.4774       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202       weighted_GWO              22.2222              48               59.3558              387                 45.8967                755              54.6479             776   0.0741    0.9687      0.9162   0.4256
# 14  mutual_info     7            91.5888           99.0654       89.9706          90.0638              90.7407           91.3580               1966            3933                49.9873      20.9448          6.7144         27.6592       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202      weighted_JAYA              23.1481              50               59.3558              387                 47.2948                778              52.8873             751   0.7757    0.5042      0.5096   0.0253
# 15  mutual_info     8            99.0654           99.0654       98.9418          99.0654              99.0741           99.0741               1966            3933                49.9873      21.0591          6.6256         27.6848       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202        weighted_GA              24.5370              53               61.9632              404                 46.2614                761              52.6761             748   0.2064    0.7639      0.8659   0.2599
# 16          rfe     1            93.5185           96.2617       92.8395          92.8395              94.4444           93.5185               1966            3933                49.9873       4.1950          7.4827         11.6780       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202      weighted_JAYA             100.0000             216               73.4663              479                 34.7720                572              49.2254             699   0.1540    0.3849      0.6681   0.1675
# 17          rfe     2            94.4444           98.1308       93.0864          93.0864              93.2099           94.4444               1966            3933                49.9873       3.7735          6.7071         10.4808       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202       weighted_SCA              99.5370             215               88.9571              580                 56.8389                935              16.6197             236   0.0000    0.9861      0.9812   0.0000
# 18          rfe     3            93.5185           98.1308       93.0533          93.0533              96.0847           93.5185               1966            3933                49.9873       4.1480          6.5980         10.7463       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202       weighted_SSA              85.6481             185               75.6135              493                 36.7173                604              48.1690             684   0.0000    0.9843      0.7851   0.0082
# 19          rfe     4            89.8148          100.0000       89.8119          89.8119              94.1975           89.8148               1966            3933                49.9873       3.7920          6.6685         10.4608       1146907           4.3810                25.8355                 12.9145                50.0127        62.2202      weighted_JAYA              99.0741             214               87.5767              571                 58.1763                957              15.7746             224   0.0000    0.5701      0.6062   0.0000

# %% [markdown]
# ## Summary Table

# %%
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary = df_summary.sort_values('Mean Test Acc (%)', ascending=False)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#     meta_GA              95.12              2.84              94.53              3.48                 1957.62                       49.77            395.31                 6.64               401.95          1142619.0                  4.36                       50.23               62.15
#    meta_FFA              95.01              2.56              94.47              3.03                 1945.75                       49.47            394.43                 6.63               401.06          1136539.0                  4.34                       50.53               62.06
#    meta_BAT              94.43              2.58              93.80              2.76                 1938.50                       49.29            416.87                 6.65               423.52          1132827.0                  4.33                       50.71               62.00
#    baseline              94.43              2.42              93.62              3.12                 3933.00                      100.00              0.00                 8.65                 8.65          2154011.0                  8.22                        0.00               85.51
#    meta_PSO              94.20              3.92              93.38              4.83                 1909.75                       48.56            399.57                 6.62               406.19          1118107.0                  4.27                       51.44               61.77
#    meta_MFO              94.08              3.24              93.35              3.94                 1970.62                       50.10            388.44                 6.69               395.13          1149275.0                  4.39                       49.90               62.26
#    meta_GWO              93.97              3.05              93.27              3.42                 1633.50                       41.53            383.68                 6.41               390.10           976667.0                  3.73                       58.47               57.90
#   meta_JAYA              93.97              4.28              93.27              4.73                 1935.00                       49.20            409.53                 6.65               416.18          1131035.0                  4.32                       50.80               61.97
#         rfe              93.96              1.97              93.54              1.92                 1966.00                       49.99              4.03                 6.75                10.78          1146907.0                  4.38                       50.01               62.22
#     meta_DE              93.85              2.71              92.86              3.02                 1939.50                       49.31            408.43                 6.61               415.05          1133339.0                  4.33                       50.69               62.01
#    meta_SCA              93.50              4.04              92.78              4.64                  726.75                       18.48            352.15                 5.68               357.83           512411.0                  1.96                       81.52               47.20
#    meta_MVO              93.39              3.44              92.69              3.81                 1928.50                       49.03            398.46                 6.63               405.09          1127707.0                  4.31                       50.97               61.92
#    meta_SSA              92.81              3.88              92.01              4.40                 1939.88                       49.32            995.82                 6.66              1002.47          1133531.0                  4.33                       50.68               62.01
#     meta_CS              92.80              4.09              91.95              4.51                 1931.00                       49.10            806.08                 6.62               812.70          1128987.0                  4.31                       50.90               61.94
# mutual_info              92.58              4.82              91.63              5.82                 1966.00                       49.99             21.00                 6.70                27.69          1146907.0                  4.38                       50.01               62.22
#    meta_WOA              92.58              5.01              91.78              5.60                  808.00                       20.54            337.78                 5.78               343.56           554011.0                  2.12                       79.46               48.29
#    meta_HHO              91.64              3.54              90.35              4.13                 1176.75                       29.92            481.61                 6.02               487.63           742811.0                  2.84                       70.08               52.65
#       lasso              87.60              9.61              86.09             10.78                 1966.00                       49.99              0.89                 6.79                 7.68          1146907.0                  4.38                       50.01               62.22

# %% [markdown]
# ## Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy heatmap (method x fold)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5,
            cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold (Weighted Features)', fontsize=16)
ax.set_ylabel('Method')
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'accuracy_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax,
              color='black', alpha=0.5, size=4)
ax.set_title('Test Accuracy Distribution (Weighted Features + FS)', fontsize=14)
plt.xticks(rotation=60, ha='right')
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'accuracy_boxplot.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 3: Feature retention bar chart
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method (Weighted Features)', fontsize=14)
plt.xticks(rotation=60, ha='right')
ax.legend()
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'feature_retention.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention scatter
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))
for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'],
               label=method, s=60, alpha=0.7)
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, alpha=1.0, edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention (Weighted Features)', fontsize=14)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'accuracy_vs_retention.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Per-Modality Feature Retention (Weighted Features)', fontsize=14)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'modality_retention_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')

total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='coral')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')

plt.suptitle('Execution Time Comparison (Weighted Features)', fontsize=14)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'execution_time.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 7: Convergence curves for metaheuristics
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None and len(conv) > 0:
                    all_conv.append(conv)
        
        if len(all_conv) > 0:
            min_len = min(len(c) for c in all_conv)
            all_conv_arr = np.array([c[:min_len] for c in all_conv])
            mean_conv = np.mean(all_conv_arr, axis=0)
            ax.plot(range(1, min_len + 1), mean_conv,
                    label=method.replace('meta_', ''), linewidth=2)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (lower is better)', fontsize=12)
    ax.set_title('FS Convergence on Weighted Features (avg across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / 'convergence_curves.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "=" * 80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("=" * 80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []
for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) == len(baseline_accs) and len(method_accs) >= 2:
        try:
            t_stat, t_pval = ttest_rel(method_accs, baseline_accs)
        except:
            t_stat, t_pval = np.nan, np.nan
        try:
            w_stat, w_pval = wilcoxon(np.array(method_accs) - np.array(baseline_accs))
        except:
            w_stat, w_pval = np.nan, np.nan
        
        diff = np.mean(method_accs) - np.mean(baseline_accs)
        sig = '***' if t_pval < 0.001 else '**' if t_pval < 0.01 else '*' if t_pval < 0.05 else ''
        
        stat_rows.append({
            'Method': method,
            'Mean Diff (%)': diff,
            'Paired t p-val': t_pval,
            'Wilcoxon p-val': w_pval,
            'Sig': sig
        })
        
        print(f"  {method:20s}: diff={diff:+.2f}%, t-test p={t_pval:.4f}, "
              f"wilcoxon p={w_pval:.4f} {sig}")

df_stats = pd.DataFrame(stat_rows)
df_stats.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#   mutual_info         : diff=-1.86%, t-test p=0.3200, wilcoxon p=0.5469
#   rfe                 : diff=-0.47%, t-test p=0.4851, wilcoxon p=0.6562
#   lasso               : diff=-6.84%, t-test p=0.0672, wilcoxon p=0.0469
#   meta_BAT            : diff=-0.00%, t-test p=0.9953, wilcoxon p=0.8438
#   meta_CS             : diff=-1.63%, t-test p=0.1857, wilcoxon p=0.2188
#   meta_DE             : diff=-0.58%, t-test p=0.4588, wilcoxon p=0.6250
#   meta_FFA            : diff=+0.58%, t-test p=0.3870, wilcoxon p=0.4688
#   meta_GA             : diff=+0.69%, t-test p=0.3530, wilcoxon p=0.3750
#   meta_GWO            : diff=-0.46%, t-test p=0.5535, wilcoxon p=0.8438
#   meta_HHO            : diff=-2.79%, t-test p=0.0532, wilcoxon p=0.0781
#   meta_JAYA           : diff=-0.46%, t-test p=0.6682, wilcoxon p=1.0000
#   meta_MFO            : diff=-0.35%, t-test p=0.6902, wilcoxon p=0.6250
#   meta_MVO            : diff=-1.04%, t-test p=0.2768, wilcoxon p=0.6094
#   meta_PSO            : diff=-0.23%, t-test p=0.7141, wilcoxon p=1.0000
#   meta_SCA            : diff=-0.93%, t-test p=0.4368, wilcoxon p=0.9844
#   meta_SSA            : diff=-1.62%, t-test p=0.3284, wilcoxon p=0.3750
#   meta_WOA            : diff=-1.85%, t-test p=0.3677, wilcoxon p=0.4844

# %% [markdown]
# ## Final Summary

# %%
print("=" * 80)
print("FILE 2 COMPLETE — FEATURE SELECTION ON WEIGHTED FEATURES")
print("=" * 80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nModality weights used (from File 1):")
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']} -> [{w_str}]")

print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'=' * 80}")
print("RESULTS (sorted by mean test accuracy):")
print("=" * 80)
for _, row in df_summary.iterrows():
    print(f"  {row['Method']:20s} | Acc: {row['Mean Test Acc (%)']:6.2f}% "
          f"(+/-{row['Std Test Acc (%)']:.2f}) | F1: {row['Mean F1 Macro (%)']:6.2f}% "
          f"| Feat: {row['Mean Feature Retention (%)']:.1f}%")
# Out:
# ================================================================================
# FILE 2 COMPLETE — FEATURE SELECTION ON WEIGHTED FEATURES
# ================================================================================
#
# Output directory: results_weighted_fs
#
# Modality weights used (from File 1):
#   Fold 1: weighted_JAYA -> [depth=0.154, sensor=0.385, skeleton=0.668, video=0.168]
#   Fold 2: weighted_SCA -> [depth=0.000, sensor=0.986, skeleton=0.981, video=0.000]
#   Fold 3: weighted_SSA -> [depth=0.000, sensor=0.984, skeleton=0.785, video=0.008]
#   Fold 4: weighted_JAYA -> [depth=0.000, sensor=0.570, skeleton=0.606, video=0.000]
#   Fold 5: weighted_BAT -> [depth=0.060, sensor=0.659, skeleton=0.660, video=0.000]
#   Fold 6: weighted_GWO -> [depth=0.074, sensor=0.969, skeleton=0.916, video=0.426]
#   Fold 7: weighted_JAYA -> [depth=0.776, sensor=0.504, skeleton=0.510, video=0.025]
#   Fold 8: weighted_GA -> [depth=0.206, sensor=0.764, skeleton=0.866, video=0.260]
#
# Per-method folders:
#   results_weighted_fs/baseline/ (16 files)
#   results_weighted_fs/mutual_info/ (16 files)
#   results_weighted_fs/rfe/ (16 files)
#   results_weighted_fs/lasso/ (16 files)
#   results_weighted_fs/meta_BAT/ (16 files)
#   results_weighted_fs/meta_CS/ (16 files)
#   results_weighted_fs/meta_DE/ (16 files)
#   results_weighted_fs/meta_FFA/ (16 files)
#   results_weighted_fs/meta_GA/ (16 files)
#   results_weighted_fs/meta_GWO/ (16 files)
#   results_weighted_fs/meta_HHO/ (16 files)
#   results_weighted_fs/meta_JAYA/ (16 files)
#   results_weighted_fs/meta_MFO/ (16 files)
#   results_weighted_fs/meta_MVO/ (16 files)
#   results_weighted_fs/meta_PSO/ (16 files)
#   results_weighted_fs/meta_SCA/ (16 files)
#   results_weighted_fs/meta_SSA/ (16 files)
#   results_weighted_fs/meta_WOA/ (16 files)
#
# Plots directory: results_weighted_fs/plots
#   accuracy_boxplot.png
#   accuracy_heatmap.png
#   accuracy_vs_retention.png
#   convergence_curves.png
#   execution_time.png
#   feature_retention.png
#   modality_retention_heatmap.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# RESULTS (sorted by mean test accuracy):
# ================================================================================
#   meta_GA              | Acc:  95.12% (+/-2.84) | F1:  94.53% | Feat: 49.8%
#   meta_FFA             | Acc:  95.01% (+/-2.56) | F1:  94.47% | Feat: 49.5%
#   meta_BAT             | Acc:  94.43% (+/-2.58) | F1:  93.80% | Feat: 49.3%
#   baseline             | Acc:  94.43% (+/-2.42) | F1:  93.62% | Feat: 100.0%
#   meta_PSO             | Acc:  94.20% (+/-3.92) | F1:  93.38% | Feat: 48.6%
#   meta_MFO             | Acc:  94.08% (+/-3.24) | F1:  93.35% | Feat: 50.1%
#   meta_GWO             | Acc:  93.97% (+/-3.05) | F1:  93.27% | Feat: 41.5%
#   meta_JAYA            | Acc:  93.97% (+/-4.28) | F1:  93.27% | Feat: 49.2%
#   rfe                  | Acc:  93.96% (+/-1.97) | F1:  93.54% | Feat: 50.0%
#   meta_DE              | Acc:  93.85% (+/-2.71) | F1:  92.86% | Feat: 49.3%
#   meta_SCA             | Acc:  93.50% (+/-4.04) | F1:  92.78% | Feat: 18.5%
#   meta_MVO             | Acc:  93.39% (+/-3.44) | F1:  92.69% | Feat: 49.0%
#   meta_SSA             | Acc:  92.81% (+/-3.88) | F1:  92.01% | Feat: 49.3%
#   meta_CS              | Acc:  92.80% (+/-4.09) | F1:  91.95% | Feat: 49.1%
#   mutual_info          | Acc:  92.58% (+/-4.82) | F1:  91.63% | Feat: 50.0%
#   meta_WOA             | Acc:  92.58% (+/-5.01) | F1:  91.78% | Feat: 20.5%
#   meta_HHO             | Acc:  91.64% (+/-3.54) | F1:  90.35% | Feat: 29.9%
#   lasso                | Acc:  87.60% (+/-9.61) | F1:  86.09% | Feat: 50.0%

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_SSA
#     Test Accuracy:      99.07%
#     Feature Retention:  49.56% (1949/3933)
#     Modality Retention: depth=48.6%, sensor=48.6%, skeleton=49.7%, video=49.9%
#
#   Fold 2: Best = meta_BAT
#     Test Accuracy:      94.44%
#     Feature Retention:  49.63% (1952/3933)
#     Modality Retention: depth=56.0%, sensor=47.4%, skeleton=48.3%, video=51.2%
#
#   Fold 3: Best = meta_GA
#     Test Accuracy:      98.15%
#     Feature Retention:  50.62% (1991/3933)
#     Modality Retention: depth=45.8%, sensor=49.1%, skeleton=50.2%, video=52.6%
#
#   Fold 4: Best = meta_WOA
#     Test Accuracy:      94.44%
#     Feature Retention:  32.55% (1280/3933)
#     Modality Retention: depth=30.1%, sensor=33.0%, skeleton=32.4%, video=32.9%
#
#   Fold 5: Best = meta_DE
#     Test Accuracy:      96.30%
#     Feature Retention:  49.12% (1932/3933)
#     Modality Retention: depth=54.6%, sensor=48.2%, skeleton=50.7%, video=46.9%
#
#   Fold 6: Best = meta_JAYA
#     Test Accuracy:      98.13%
#     Feature Retention:  48.54% (1909/3933)
#     Modality Retention: depth=47.7%, sensor=49.5%, skeleton=48.4%, video=48.4%
#
#   Fold 7: Best = meta_FFA
#     Test Accuracy:      97.20%
#     Feature Retention:  48.89% (1923/3933)
#     Modality Retention: depth=50.9%, sensor=50.3%, skeleton=48.0%, video=48.9%
#
#   Fold 8: Best = meta_GWO
#     Test Accuracy:      100.00%
#     Feature Retention:  40.99% (1612/3933)
#     Modality Retention: depth=38.4%, sensor=41.7%, skeleton=41.6%, video=40.3%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     97.22% ± 2.04%
#   Average Feature Retention: 46.24% ± 6.30%
#
#   Average Modality-wise Feature Retention:
#          depth: 46.53% ± 8.59%
#         sensor: 45.97% ± 5.88%
#       skeleton: 46.17% ± 6.23%
#          video: 46.39% ± 6.60%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)  video Retention (%)
#     1           meta_SSA              99.07                  49.56                48.61                 48.62                   49.73                49.93
#     2           meta_BAT              94.44                  49.63                56.02                 47.39                   48.33                51.20
#     3            meta_GA              98.15                  50.62                45.83                 49.08                   50.15                52.61
#     4           meta_WOA              94.44                  32.55                30.09                 32.98                   32.40                32.89
#     5            meta_DE              96.30                  49.12                54.63                 48.16                   50.70                46.90
#     6          meta_JAYA              98.13                  48.54                47.69                 49.54                   48.39                48.38
#     7           meta_FFA              97.20                  48.89                50.93                 50.31                   48.02                48.94
#     8           meta_GWO             100.00                  40.99                38.43                 41.72                   41.64                40.28
#
# Saved to: results_weighted_fs/best_metaheuristic_per_fold.csv
