# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (10% Random Zeroing)
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.
#
#
# > **Modification:** This notebook randomly zeros out 10% of all data elements before any processing.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_25_noise")

# Master output directory
RESULTS_ROOT = Path("results_25_noise")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 37
#   sensor: 54
#   skeleton: 240
#   video: 264
#   TOTAL: 595

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 91.67%, F1: 89.88%, Features: 595/595 (100.0%), Model: 1.703MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 297/595 (49.9%), Time: 3.4s
#     Test Acc: 93.52%, F1: 93.05%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 297/595 (49.9%), Time: 0.5s
#     Test Acc: 95.37%, F1: 94.65%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 297/595 (49.9%), Time: 0.1s
#     Test Acc: 94.44%, F1: 94.18%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.038633053221288495']
# ['At iteration 1 the best fitness is 0.031711484593837574']
# ['At iteration 2 the best fitness is 0.031711484593837574']
# ['At iteration 3 the best fitness is 0.031711484593837574']
# ['At iteration 4 the best fitness is 0.031711484593837574']
# ['At iteration 5 the best fitness is 0.031711484593837574']
# ['At iteration 6 the best fitness is 0.031711484593837574']
# ['At iteration 7 the best fitness is 0.031711484593837574']
# ['At iteration 8 the best fitness is 0.031711484593837574']
# ['At iteration 9 the best fitness is 0.03145938375350144']
# ['At iteration 10 the best fitness is 0.03145938375350144']
# ['At iteration 11 the best fitness is 0.03145938375350144']
# ['At iteration 12 the best fitness is 0.03145938375350144']
# ['At iteration 13 the best fitness is 0.03145938375350144']
# ['At iteration 14 the best fitness is 0.03145938375350144']
# ['At iteration 15 the best fitness is 0.03145938375350144']
# ['At iteration 16 the best fitness is 0.03145938375350144']
# ['At iteration 17 the best fitness is 0.03145938375350144']
# ['At iteration 18 the best fitness is 0.03145938375350144']
# ['At iteration 19 the best fitness is 0.03145938375350144']
# ['At iteration 20 the best fitness is 0.03145938375350144']
# ['At iteration 21 the best fitness is 0.03145938375350144']
# ['At iteration 22 the best fitness is 0.03145938375350144']
# ['At iteration 23 the best fitness is 0.03145938375350144']
# ['At iteration 24 the best fitness is 0.03145938375350144']
# ['At iteration 25 the best fitness is 0.03145938375350144']
# ['At iteration 26 the best fitness is 0.03145938375350144']
# ['At iteration 27 the best fitness is 0.025630252100840335']
# ['At iteration 28 the best fitness is 0.025630252100840335']
# ['At iteration 29 the best fitness is 0.025630252100840335']
#       Selected: 305/595 (51.3%), Fitness: 0.0256, Time: 775.2s
#       Modality: D=59%, S=59%, Sk=45%, V=55%
#     Test Acc: 94.44%, F1: 94.20%, Features: 305/595 (51.3%), Model: 1.137MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.038380952380952356']
# ['At iteration 10 the best fitness is 0.03061904761904766']
# ['At iteration 20 the best fitness is 0.030450980392156907']
#       Selected: 299/595 (50.3%), Fitness: 0.0305, Time: 1516.9s
#       Modality: D=43%, S=59%, Sk=46%, V=53%
#     Test Acc: 89.81%, F1: 88.65%, Features: 299/595 (50.3%), Model: 1.125MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05146778711484589']
# ['At iteration 2 the best fitness is 0.05146778711484589']
# ['At iteration 3 the best fitness is 0.05079551820728286']
# ['At iteration 4 the best fitness is 0.04286554621848741']
# ['At iteration 5 the best fitness is 0.04286554621848741']
# ['At iteration 6 the best fitness is 0.04286554621848741']
# ['At iteration 7 the best fitness is 0.04286554621848741']
# ['At iteration 8 the best fitness is 0.03779271708683471']
# ['At iteration 9 the best fitness is 0.03779271708683471']
# ['At iteration 10 the best fitness is 0.030366946778711528']
# ['At iteration 11 the best fitness is 0.030366946778711528']
# ['At iteration 12 the best fitness is 0.030366946778711528']
# ['At iteration 13 the best fitness is 0.030366946778711528']
# ['At iteration 14 the best fitness is 0.030366946778711528']
# ['At iteration 15 the best fitness is 0.026386554621848742']
# ['At iteration 16 the best fitness is 0.026386554621848742']
# ['At iteration 17 the best fitness is 0.026386554621848742']
# ['At iteration 18 the best fitness is 0.026386554621848742']
# ['At iteration 19 the best fitness is 0.026386554621848742']
# ['At iteration 20 the best fitness is 0.026386554621848742']
# ['At iteration 21 the best fitness is 0.026386554621848742']
# ['At iteration 22 the best fitness is 0.026386554621848742']
# ['At iteration 23 the best fitness is 0.026386554621848742']
# ['At iteration 24 the best fitness is 0.026386554621848742']
# ['At iteration 25 the best fitness is 0.026386554621848742']
# ['At iteration 26 the best fitness is 0.026386554621848742']
# ['At iteration 27 the best fitness is 0.026386554621848742']
# ['At iteration 28 the best fitness is 0.026386554621848742']
# ['At iteration 29 the best fitness is 0.026386554621848742']
# ['At iteration 30 the best fitness is 0.026386554621848742']
#       Selected: 310/595 (52.1%), Fitness: 0.0264, Time: 770.7s
#       Modality: D=46%, S=61%, Sk=52%, V=52%
#     Test Acc: 92.59%, F1: 91.82%, Features: 310/595 (52.1%), Model: 1.147MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.057464985994397755']
# ['At iteration 1 the best fitness is 0.04362184873949582']
# ['At iteration 2 the best fitness is 0.049955182072829084']
# ['At iteration 3 the best fitness is 0.04303361344537817']
# ['At iteration 4 the best fitness is 0.03661624649859942']
# ['At iteration 5 the best fitness is 0.04353781512605044']
# ['At iteration 6 the best fitness is 0.03653221288515404']
# ['At iteration 7 the best fitness is 0.04294957983193279']
# ['At iteration 8 the best fitness is 0.0491148459383753']
# ['At iteration 9 the best fitness is 0.03644817927170866']
# ['At iteration 10 the best fitness is 0.03661624649859942']
# ['At iteration 11 the best fitness is 0.04894677871148455']
# ['At iteration 12 the best fitness is 0.042613445378151274']
# ['At iteration 13 the best fitness is 0.0432857142857143']
# ['At iteration 14 the best fitness is 0.04303361344537817']
# ['At iteration 15 the best fitness is 0.030366946778711528']
# ['At iteration 16 the best fitness is 0.04286554621848741']
# ['At iteration 17 the best fitness is 0.03661624649859942']
# ['At iteration 18 the best fitness is 0.03653221288515404']
# ['At iteration 19 the best fitness is 0.03653221288515404']
# ['At iteration 20 the best fitness is 0.04286554621848741']
# ['At iteration 21 the best fitness is 0.04919887955182068']
# ['At iteration 22 the best fitness is 0.03653221288515404']
# ['At iteration 23 the best fitness is 0.04286554621848741']
# ['At iteration 24 the best fitness is 0.03019887955182077']
# ['At iteration 25 the best fitness is 0.03019887955182077']
# ['At iteration 26 the best fitness is 0.03653221288515404']
# ['At iteration 27 the best fitness is 0.04286554621848741']
# ['At iteration 28 the best fitness is 0.04286554621848741']
# ['At iteration 29 the best fitness is 0.04286554621848741']
#       Selected: 294/595 (49.4%), Fitness: 0.0429, Time: 745.8s
#       Modality: D=46%, S=52%, Sk=50%, V=49%
#     Test Acc: 90.74%, F1: 89.56%, Features: 294/595 (49.4%), Model: 1.115MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.04227731092436977
# At iteration 2 the best fitness is 0.037288515406162445
# At iteration 3 the best fitness is 0.04227731092436977
# At iteration 4 the best fitness is 0.03754061624649858
# At iteration 5 the best fitness is 0.030787114845938417
# At iteration 6 the best fitness is 0.03661624649859942
# At iteration 7 the best fitness is 0.029778711484593882
# At iteration 8 the best fitness is 0.02336134453781513
# At iteration 9 the best fitness is 0.042193277310924385
# At iteration 10 the best fitness is 0.03619607843137253
# At iteration 11 the best fitness is 0.029526610644257746
# At iteration 12 the best fitness is 0.029694677871148503
# At iteration 13 the best fitness is 0.029190476190476232
# At iteration 14 the best fitness is 0.02927450980392161
# At iteration 15 the best fitness is 0.029694677871148503
# At iteration 16 the best fitness is 0.02327731092436975
# At iteration 17 the best fitness is 0.029442577030812368
# At iteration 18 the best fitness is 0.02369747899159664
# At iteration 19 the best fitness is 0.029442577030812368
# At iteration 20 the best fitness is 0.02327731092436975
# At iteration 21 the best fitness is 0.02935854341736699
# At iteration 22 the best fitness is 0.029610644257703125
# At iteration 23 the best fitness is 0.030535014005602285
# At iteration 24 the best fitness is 0.02935854341736699
# At iteration 25 the best fitness is 0.02369747899159664
# At iteration 26 the best fitness is 0.023109243697478993
# At iteration 27 the best fitness is 0.029190476190476232
# At iteration 28 the best fitness is 0.02319327731092437
# At iteration 29 the best fitness is 0.029526610644257746
# At iteration 30 the best fitness is 0.029526610644257746
#       Selected: 299/595 (50.3%), Fitness: 0.0295, Time: 745.6s
#       Modality: D=49%, S=50%, Sk=45%, V=55%
#     Test Acc: 92.59%, F1: 91.34%, Features: 299/595 (50.3%), Model: 1.125MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0382128851540616']
# ['At iteration 1 the best fitness is 0.03670028011204479']
# ['At iteration 2 the best fitness is 0.03670028011204479']
# ['At iteration 3 the best fitness is 0.03670028011204479']
# ['At iteration 4 the best fitness is 0.035691876750700256']
# ['At iteration 5 the best fitness is 0.02151260504201681']
# ['At iteration 6 the best fitness is 0.02151260504201681']
# ['At iteration 7 the best fitness is 0.02151260504201681']
# ['At iteration 8 the best fitness is 0.02151260504201681']
# ['At iteration 9 the best fitness is 0.02151260504201681']
# ['At iteration 10 the best fitness is 0.02151260504201681']
# ['At iteration 11 the best fitness is 0.02151260504201681']
# ['At iteration 12 the best fitness is 0.02151260504201681']
# ['At iteration 13 the best fitness is 0.02151260504201681']
# ['At iteration 14 the best fitness is 0.02151260504201681']
# ['At iteration 15 the best fitness is 0.02151260504201681']
# ['At iteration 16 the best fitness is 0.02151260504201681']
# ['At iteration 17 the best fitness is 0.02134453781512605']
# ['At iteration 18 the best fitness is 0.02134453781512605']
# ['At iteration 19 the best fitness is 0.02134453781512605']
# ['At iteration 20 the best fitness is 0.02134453781512605']
# ['At iteration 21 the best fitness is 0.02134453781512605']
# ['At iteration 22 the best fitness is 0.02134453781512605']
# ['At iteration 23 the best fitness is 0.02134453781512605']
# ['At iteration 24 the best fitness is 0.02134453781512605']
# ['At iteration 25 the best fitness is 0.02134453781512605']
# ['At iteration 26 the best fitness is 0.02134453781512605']
# ['At iteration 27 the best fitness is 0.02134453781512605']
# ['At iteration 28 the best fitness is 0.02134453781512605']
# ['At iteration 29 the best fitness is 0.02134453781512605']
#       Selected: 252/595 (42.4%), Fitness: 0.0213, Time: 742.4s
#       Modality: D=38%, S=50%, Sk=41%, V=42%
#     Test Acc: 89.81%, F1: 88.94%, Features: 252/595 (42.4%), Model: 1.009MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.05054341736694673']
# ['At iteration 1 the best fitness is 0.05054341736694673']
# ['At iteration 2 the best fitness is 0.05054341736694673']
# ['At iteration 3 the best fitness is 0.05054341736694673']
# ['At iteration 4 the best fitness is 0.05054341736694673']
# ['At iteration 5 the best fitness is 0.05054341736694673']
# ['At iteration 6 the best fitness is 0.05054341736694673']
# ['At iteration 7 the best fitness is 0.05054341736694673']
# ['At iteration 8 the best fitness is 0.05054341736694673']
# ['At iteration 9 the best fitness is 0.05054341736694673']
# ['At iteration 10 the best fitness is 0.05054341736694673']
# ['At iteration 11 the best fitness is 0.05054341736694673']
# ['At iteration 12 the best fitness is 0.05054341736694673']
# ['At iteration 13 the best fitness is 0.043820728291316474']
# ['At iteration 14 the best fitness is 0.043820728291316474']
# ['At iteration 15 the best fitness is 0.043820728291316474']
# ['At iteration 16 the best fitness is 0.030733893557422946']
# ['At iteration 17 the best fitness is 0.030733893557422946']
# ['At iteration 18 the best fitness is 0.030733893557422946']
# ['At iteration 19 the best fitness is 0.030733893557422946']
# ['At iteration 20 the best fitness is 0.030733893557422946']
# ['At iteration 21 the best fitness is 0.030733893557422946']
# ['At iteration 22 the best fitness is 0.030733893557422946']
# ['At iteration 23 the best fitness is 0.030733893557422946']
# ['At iteration 24 the best fitness is 0.030733893557422946']
# ['At iteration 25 the best fitness is 0.030733893557422946']
# ['At iteration 26 the best fitness is 0.030733893557422946']
# ['At iteration 27 the best fitness is 0.030733893557422946']
# ['At iteration 28 the best fitness is 0.030733893557422946']
# ['At iteration 29 the best fitness is 0.030733893557422946']
#       Selected: 219/595 (36.8%), Fitness: 0.0307, Time: 936.6s
#       Modality: D=38%, S=41%, Sk=33%, V=39%
#     Test Acc: 92.59%, F1: 91.02%, Features: 219/595 (36.8%), Model: 0.767MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03754061624649858']
# ['At iteration 1 the best fitness is 0.036868347338935556']
# ['At iteration 2 the best fitness is 0.036868347338935556']
# ['At iteration 3 the best fitness is 0.036868347338935556']
# ['At iteration 4 the best fitness is 0.03602801120448177']
# ['At iteration 5 the best fitness is 0.03602801120448177']
# ['At iteration 6 the best fitness is 0.03602801120448177']
# ['At iteration 7 the best fitness is 0.03602801120448177']
# ['At iteration 8 the best fitness is 0.03602801120448177']
# ['At iteration 9 the best fitness is 0.03028291316526615']
# ['At iteration 10 the best fitness is 0.03028291316526615']
# ['At iteration 11 the best fitness is 0.03028291316526615']
# ['At iteration 12 the best fitness is 0.03028291316526615']
# ['At iteration 13 the best fitness is 0.03028291316526615']
# ['At iteration 14 the best fitness is 0.03028291316526615']
# ['At iteration 15 the best fitness is 0.03028291316526615']
# ['At iteration 16 the best fitness is 0.03028291316526615']
# ['At iteration 17 the best fitness is 0.03028291316526615']
# ['At iteration 18 the best fitness is 0.03028291316526615']
# ['At iteration 19 the best fitness is 0.03028291316526615']
# ['At iteration 20 the best fitness is 0.03028291316526615']
# ['At iteration 21 the best fitness is 0.03028291316526615']
# ['At iteration 22 the best fitness is 0.03028291316526615']
# ['At iteration 23 the best fitness is 0.03028291316526615']
# ['At iteration 24 the best fitness is 0.03028291316526615']
# ['At iteration 25 the best fitness is 0.03028291316526615']
# ['At iteration 26 the best fitness is 0.03028291316526615']
# ['At iteration 27 the best fitness is 0.03028291316526615']
# ['At iteration 28 the best fitness is 0.03028291316526615']
# ['At iteration 29 the best fitness is 0.023865546218487396']
#       Selected: 286/595 (48.1%), Fitness: 0.0239, Time: 774.3s
#       Modality: D=51%, S=54%, Sk=45%, V=49%
#     Test Acc: 87.96%, F1: 85.67%, Features: 286/595 (48.1%), Model: 1.100MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05205602240896354']
# ['At iteration 2 the best fitness is 0.051047619047618994']
# ['At iteration 3 the best fitness is 0.030030812324930014']
# ['At iteration 4 the best fitness is 0.030030812324930014']
# ['At iteration 5 the best fitness is 0.030030812324930014']
# ['At iteration 6 the best fitness is 0.030030812324930014']
# ['At iteration 7 the best fitness is 0.030030812324930014']
# ['At iteration 8 the best fitness is 0.030030812324930014']
# ['At iteration 9 the best fitness is 0.030030812324930014']
# ['At iteration 10 the best fitness is 0.030030812324930014']
# ['At iteration 11 the best fitness is 0.030030812324930014']
# ['At iteration 12 the best fitness is 0.030030812324930014']
# ['At iteration 13 the best fitness is 0.030030812324930014']
# ['At iteration 14 the best fitness is 0.030030812324930014']
# ['At iteration 15 the best fitness is 0.030030812324930014']
# ['At iteration 16 the best fitness is 0.030030812324930014']
# ['At iteration 17 the best fitness is 0.030030812324930014']
# ['At iteration 18 the best fitness is 0.030030812324930014']
# ['At iteration 19 the best fitness is 0.030030812324930014']
# ['At iteration 20 the best fitness is 0.025210084033613446']
# ['At iteration 21 the best fitness is 0.025210084033613446']
# ['At iteration 22 the best fitness is 0.025210084033613446']
# ['At iteration 23 the best fitness is 0.025210084033613446']
# ['At iteration 24 the best fitness is 0.025210084033613446']
# ['At iteration 25 the best fitness is 0.025210084033613446']
# ['At iteration 26 the best fitness is 0.025210084033613446']
# ['At iteration 27 the best fitness is 0.025210084033613446']
# ['At iteration 28 the best fitness is 0.025210084033613446']
# ['At iteration 29 the best fitness is 0.02327731092436975']
#       Selected: 282/595 (47.4%), Fitness: 0.0233, Time: 724.5s
#       Modality: D=35%, S=56%, Sk=50%, V=45%
#     Test Acc: 88.89%, F1: 87.34%, Features: 282/595 (47.4%), Model: 1.092MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.049535014005602195']
# ['At iteration 2 the best fitness is 0.037456582633053195']
# ['At iteration 3 the best fitness is 0.037456582633053195']
# ['At iteration 4 the best fitness is 0.0362801120448179']
# ['At iteration 5 the best fitness is 0.03602801120448177']
# ['At iteration 6 the best fitness is 0.03602801120448177']
# ['At iteration 7 the best fitness is 0.029862745098039257']
# ['At iteration 8 the best fitness is 0.029862745098039257']
# ['At iteration 9 the best fitness is 0.029862745098039257']
# ['At iteration 10 the best fitness is 0.023949579831932775']
# ['At iteration 11 the best fitness is 0.023949579831932775']
# ['At iteration 12 the best fitness is 0.023949579831932775']
# ['At iteration 13 the best fitness is 0.023949579831932775']
# ['At iteration 14 the best fitness is 0.023949579831932775']
# ['At iteration 15 the best fitness is 0.023949579831932775']
# ['At iteration 16 the best fitness is 0.023949579831932775']
# ['At iteration 17 the best fitness is 0.023949579831932775']
# ['At iteration 18 the best fitness is 0.023949579831932775']
# ['At iteration 19 the best fitness is 0.023949579831932775']
# ['At iteration 20 the best fitness is 0.023949579831932775']
# ['At iteration 21 the best fitness is 0.023949579831932775']
# ['At iteration 22 the best fitness is 0.023949579831932775']
# ['At iteration 23 the best fitness is 0.023949579831932775']
# ['At iteration 24 the best fitness is 0.023949579831932775']
# ['At iteration 25 the best fitness is 0.023949579831932775']
# ['At iteration 26 the best fitness is 0.023949579831932775']
# ['At iteration 27 the best fitness is 0.023949579831932775']
# ['At iteration 28 the best fitness is 0.023949579831932775']
# ['At iteration 29 the best fitness is 0.023949579831932775']
# ['At iteration 30 the best fitness is 0.023949579831932775']
#       Selected: 268/595 (45.0%), Fitness: 0.0239, Time: 746.0s
#       Modality: D=51%, S=56%, Sk=41%, V=46%
#     Test Acc: 89.81%, F1: 88.74%, Features: 268/595 (45.0%), Model: 1.065MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.050459383753501355']
# ['At iteration 2 the best fitness is 0.0432857142857143']
# ['At iteration 3 the best fitness is 0.0432857142857143']
# ['At iteration 4 the best fitness is 0.0362801120448179']
# ['At iteration 5 the best fitness is 0.0362801120448179']
# ['At iteration 6 the best fitness is 0.03019887955182077']
# ['At iteration 7 the best fitness is 0.03019887955182077']
# ['At iteration 8 the best fitness is 0.03019887955182077']
# ['At iteration 9 the best fitness is 0.03019887955182077']
# ['At iteration 10 the best fitness is 0.03019887955182077']
# ['At iteration 11 the best fitness is 0.03019887955182077']
# ['At iteration 12 the best fitness is 0.03019887955182077']
# ['At iteration 13 the best fitness is 0.03019887955182077']
# ['At iteration 14 the best fitness is 0.03019887955182077']
# ['At iteration 15 the best fitness is 0.03019887955182077']
# ['At iteration 16 the best fitness is 0.03019887955182077']
# ['At iteration 17 the best fitness is 0.03019887955182077']
# ['At iteration 18 the best fitness is 0.03019887955182077']
# ['At iteration 19 the best fitness is 0.030030812324930014']
# ['At iteration 20 the best fitness is 0.030030812324930014']
# ['At iteration 21 the best fitness is 0.030030812324930014']
# ['At iteration 22 the best fitness is 0.030030812324930014']
# ['At iteration 23 the best fitness is 0.030030812324930014']
# ['At iteration 24 the best fitness is 0.030030812324930014']
# ['At iteration 25 the best fitness is 0.02420168067226891']
# ['At iteration 26 the best fitness is 0.02420168067226891']
# ['At iteration 27 the best fitness is 0.02420168067226891']
# ['At iteration 28 the best fitness is 0.02420168067226891']
# ['At iteration 29 the best fitness is 0.02420168067226891']
# ['At iteration 30 the best fitness is 0.02420168067226891']
#       Selected: 291/595 (48.9%), Fitness: 0.0242, Time: 746.7s
#       Modality: D=46%, S=50%, Sk=45%, V=53%
#     Test Acc: 92.59%, F1: 92.04%, Features: 291/595 (48.9%), Model: 1.109MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.049535014005602195']
# ['At iteration 1 the best fitness is 0.04945098039215681']
# ['At iteration 2 the best fitness is 0.04945098039215681']
# ['At iteration 3 the best fitness is 0.04945098039215681']
# ['At iteration 4 the best fitness is 0.03916806722689077']
# ['At iteration 5 the best fitness is 0.03916806722689077']
# ['At iteration 6 the best fitness is 0.03597478991596641']
# ['At iteration 7 the best fitness is 0.035050420168067246']
# ['At iteration 8 the best fitness is 0.03387394957983195']
# ['At iteration 9 the best fitness is 0.03387394957983195']
# ['At iteration 10 the best fitness is 0.029756302521008422']
# ['At iteration 11 the best fitness is 0.029756302521008422']
# ['At iteration 12 the best fitness is 0.029756302521008422']
# ['At iteration 13 the best fitness is 0.029756302521008422']
# ['At iteration 14 the best fitness is 0.029756302521008422']
# ['At iteration 15 the best fitness is 0.029756302521008422']
# ['At iteration 16 the best fitness is 0.021826330532212862']
# ['At iteration 17 the best fitness is 0.021826330532212862']
# ['At iteration 18 the best fitness is 0.021826330532212862']
# ['At iteration 19 the best fitness is 0.021826330532212862']
# ['At iteration 20 the best fitness is 0.021826330532212862']
# ['At iteration 21 the best fitness is 0.021826330532212862']
# ['At iteration 22 the best fitness is 0.021826330532212862']
# ['At iteration 23 the best fitness is 0.021826330532212862']
# ['At iteration 24 the best fitness is 0.021826330532212862']
# ['At iteration 25 the best fitness is 0.021826330532212862']
# ['At iteration 26 the best fitness is 0.021826330532212862']
# ['At iteration 27 the best fitness is 0.021826330532212862']
# ['At iteration 28 the best fitness is 0.021826330532212862']
# ['At iteration 29 the best fitness is 0.021826330532212862']
#       Selected: 103/595 (17.3%), Fitness: 0.0218, Time: 682.2s
#       Modality: D=24%, S=26%, Sk=17%, V=15%
#     Test Acc: 87.04%, F1: 85.70%, Features: 103/595 (17.3%), Model: 0.179MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0316274509803922']
# ['At iteration 2 the best fitness is 0.0316274509803922']
# ['At iteration 3 the best fitness is 0.0316274509803922']
# ['At iteration 4 the best fitness is 0.0316274509803922']
# ['At iteration 5 the best fitness is 0.0316274509803922']
# ['At iteration 6 the best fitness is 0.0316274509803922']
# ['At iteration 7 the best fitness is 0.0316274509803922']
# ['At iteration 8 the best fitness is 0.0316274509803922']
# ['At iteration 9 the best fitness is 0.0316274509803922']
# ['At iteration 10 the best fitness is 0.03019887955182077']
# ['At iteration 11 the best fitness is 0.03019887955182077']
# ['At iteration 12 the best fitness is 0.03019887955182077']
# ['At iteration 13 the best fitness is 0.03019887955182077']
# ['At iteration 14 the best fitness is 0.03019887955182077']
# ['At iteration 15 the best fitness is 0.03019887955182077']
# ['At iteration 16 the best fitness is 0.03019887955182077']
# ['At iteration 17 the best fitness is 0.029946778711484635']
# ['At iteration 18 the best fitness is 0.029946778711484635']
# ['At iteration 19 the best fitness is 0.029946778711484635']
# ['At iteration 20 the best fitness is 0.029946778711484635']
# ['At iteration 21 the best fitness is 0.029946778711484635']
# ['At iteration 22 the best fitness is 0.029946778711484635']
# ['At iteration 23 the best fitness is 0.029946778711484635']
# ['At iteration 24 the best fitness is 0.029946778711484635']
# ['At iteration 25 the best fitness is 0.029946778711484635']
# ['At iteration 26 the best fitness is 0.029946778711484635']
# ['At iteration 27 the best fitness is 0.029946778711484635']
# ['At iteration 28 the best fitness is 0.029946778711484635']
# ['At iteration 29 the best fitness is 0.029946778711484635']
#       Selected: 298/595 (50.1%), Fitness: 0.0299, Time: 1866.6s
#       Modality: D=41%, S=56%, Sk=51%, V=50%
#     Test Acc: 90.74%, F1: 89.32%, Features: 298/595 (50.1%), Model: 1.123MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.050459383753501355']
# ['At iteration 1 the best fitness is 0.050459383753501355']
# ['At iteration 2 the best fitness is 0.050459383753501355']
# ['At iteration 3 the best fitness is 0.04291876750700278']
# ['At iteration 4 the best fitness is 0.04291876750700278']
# ['At iteration 5 the best fitness is 0.04291876750700278']
# ['At iteration 6 the best fitness is 0.04291876750700278']
# ['At iteration 7 the best fitness is 0.04291876750700278']
# ['At iteration 8 the best fitness is 0.04291876750700278']
# ['At iteration 9 the best fitness is 0.042613445378151274']
# ['At iteration 10 the best fitness is 0.03835014005602245']
# ['At iteration 11 the best fitness is 0.03835014005602245']
# ['At iteration 12 the best fitness is 0.03835014005602245']
# ['At iteration 13 the best fitness is 0.03835014005602245']
# ['At iteration 14 the best fitness is 0.03835014005602245']
# ['At iteration 15 the best fitness is 0.03835014005602245']
# ['At iteration 16 the best fitness is 0.03835014005602245']
# ['At iteration 17 the best fitness is 0.03835014005602245']
# ['At iteration 18 the best fitness is 0.03835014005602245']
# ['At iteration 19 the best fitness is 0.03835014005602245']
# ['At iteration 20 the best fitness is 0.03835014005602245']
# ['At iteration 21 the best fitness is 0.03835014005602245']
# ['At iteration 22 the best fitness is 0.03835014005602245']
# ['At iteration 23 the best fitness is 0.03835014005602245']
# ['At iteration 24 the best fitness is 0.03835014005602245']
# ['At iteration 25 the best fitness is 0.03835014005602245']
# ['At iteration 26 the best fitness is 0.03835014005602245']
# ['At iteration 27 the best fitness is 0.03835014005602245']
# ['At iteration 28 the best fitness is 0.03835014005602245']
# ['At iteration 29 the best fitness is 0.03835014005602245']
#       Selected: 389/595 (65.4%), Fitness: 0.0384, Time: 715.7s
#       Modality: D=65%, S=57%, Sk=62%, V=70%
#     Test Acc: 91.67%, F1: 90.11%, Features: 389/595 (65.4%), Model: 1.301MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 76.85%, F1: 72.41%, Features: 595/595 (100.0%), Model: 1.703MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 297/595 (49.9%), Time: 3.4s
#     Test Acc: 78.70%, F1: 73.86%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 297/595 (49.9%), Time: 0.6s
#     Test Acc: 82.41%, F1: 78.96%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 297/595 (49.9%), Time: 0.1s
#     Test Acc: 76.85%, F1: 72.29%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.029946778711484635']
# ['At iteration 1 the best fitness is 0.029946778711484635']
# ['At iteration 2 the best fitness is 0.029946778711484635']
# ['At iteration 3 the best fitness is 0.029946778711484635']
# ['At iteration 4 the best fitness is 0.029946778711484635']
# ['At iteration 5 the best fitness is 0.029946778711484635']
# ['At iteration 6 the best fitness is 0.029946778711484635']
# ['At iteration 7 the best fitness is 0.029946778711484635']
# ['At iteration 8 the best fitness is 0.029946778711484635']
# ['At iteration 9 the best fitness is 0.029946778711484635']
# ['At iteration 10 the best fitness is 0.029946778711484635']
# ['At iteration 11 the best fitness is 0.029946778711484635']
# ['At iteration 12 the best fitness is 0.029946778711484635']
# ['At iteration 13 the best fitness is 0.029946778711484635']
# ['At iteration 14 the best fitness is 0.029946778711484635']
# ['At iteration 15 the best fitness is 0.029946778711484635']
# ['At iteration 16 the best fitness is 0.029946778711484635']
# ['At iteration 17 the best fitness is 0.029946778711484635']
# ['At iteration 18 the best fitness is 0.029946778711484635']
# ['At iteration 19 the best fitness is 0.029946778711484635']
# ['At iteration 20 the best fitness is 0.029946778711484635']
# ['At iteration 21 the best fitness is 0.029946778711484635']
# ['At iteration 22 the best fitness is 0.029946778711484635']
# ['At iteration 23 the best fitness is 0.024369747899159664']
# ['At iteration 24 the best fitness is 0.024369747899159664']
# ['At iteration 25 the best fitness is 0.024369747899159664']
# ['At iteration 26 the best fitness is 0.024285714285714285']
# ['At iteration 27 the best fitness is 0.024285714285714285']
# ['At iteration 28 the best fitness is 0.024285714285714285']
# ['At iteration 29 the best fitness is 0.024285714285714285']
#       Selected: 288/595 (48.4%), Fitness: 0.0243, Time: 770.7s
#       Modality: D=46%, S=44%, Sk=48%, V=50%
#     Test Acc: 80.56%, F1: 77.01%, Features: 288/595 (48.4%), Model: 1.104MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025546218487394957']
# ['At iteration 10 the best fitness is 0.022941176470588236']
# ['At iteration 20 the best fitness is 0.022941176470588236']
#       Selected: 282/595 (47.4%), Fitness: 0.0229, Time: 1521.3s
#       Modality: D=51%, S=48%, Sk=49%, V=45%
#     Test Acc: 81.48%, F1: 78.84%, Features: 282/595 (47.4%), Model: 1.092MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024957983193277314']
# ['At iteration 2 the best fitness is 0.024957983193277314']
# ['At iteration 3 the best fitness is 0.024873949579831935']
# ['At iteration 4 the best fitness is 0.024453781512605043']
# ['At iteration 5 the best fitness is 0.024453781512605043']
# ['At iteration 6 the best fitness is 0.024453781512605043']
# ['At iteration 7 the best fitness is 0.024453781512605043']
# ['At iteration 8 the best fitness is 0.024453781512605043']
# ['At iteration 9 the best fitness is 0.02420168067226891']
# ['At iteration 10 the best fitness is 0.02420168067226891']
# ['At iteration 11 the best fitness is 0.02420168067226891']
# ['At iteration 12 the best fitness is 0.02420168067226891']
# ['At iteration 13 the best fitness is 0.023865546218487396']
# ['At iteration 14 the best fitness is 0.023865546218487396']
# ['At iteration 15 the best fitness is 0.023865546218487396']
# ['At iteration 16 the best fitness is 0.022689075630252103']
# ['At iteration 17 the best fitness is 0.022689075630252103']
# ['At iteration 18 the best fitness is 0.022689075630252103']
# ['At iteration 19 the best fitness is 0.022689075630252103']
# ['At iteration 20 the best fitness is 0.022689075630252103']
# ['At iteration 21 the best fitness is 0.022184873949579832']
# ['At iteration 22 the best fitness is 0.022184873949579832']
# ['At iteration 23 the best fitness is 0.022184873949579832']
# ['At iteration 24 the best fitness is 0.02134453781512605']
# ['At iteration 25 the best fitness is 0.02134453781512605']
# ['At iteration 26 the best fitness is 0.02134453781512605']
# ['At iteration 27 the best fitness is 0.02134453781512605']
# ['At iteration 28 the best fitness is 0.02134453781512605']
# ['At iteration 29 the best fitness is 0.02134453781512605']
# ['At iteration 30 the best fitness is 0.02134453781512605']
#       Selected: 268/595 (45.0%), Fitness: 0.0213, Time: 772.9s
#       Modality: D=22%, S=52%, Sk=45%, V=47%
#     Test Acc: 82.41%, F1: 79.32%, Features: 268/595 (45.0%), Model: 1.065MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.030871148459383796']
# ['At iteration 1 the best fitness is 0.025966386554621853']
# ['At iteration 2 the best fitness is 0.024705882352941178']
# ['At iteration 3 the best fitness is 0.023781512605042018']
# ['At iteration 4 the best fitness is 0.023781512605042018']
# ['At iteration 5 the best fitness is 0.024033613445378153']
# ['At iteration 6 the best fitness is 0.02504201680672269']
# ['At iteration 7 the best fitness is 0.024705882352941178']
# ['At iteration 8 the best fitness is 0.024369747899159664']
# ['At iteration 9 the best fitness is 0.024453781512605043']
# ['At iteration 10 the best fitness is 0.02453781512605042']
# ['At iteration 11 the best fitness is 0.024453781512605043']
# ['At iteration 12 the best fitness is 0.024705882352941178']
# ['At iteration 13 the best fitness is 0.024705882352941178']
# ['At iteration 14 the best fitness is 0.024705882352941178']
# ['At iteration 15 the best fitness is 0.024789915966386557']
# ['At iteration 16 the best fitness is 0.024705882352941178']
# ['At iteration 17 the best fitness is 0.0246218487394958']
# ['At iteration 18 the best fitness is 0.0246218487394958']
# ['At iteration 19 the best fitness is 0.0246218487394958']
# ['At iteration 20 the best fitness is 0.0246218487394958']
# ['At iteration 21 the best fitness is 0.0246218487394958']
# ['At iteration 22 the best fitness is 0.0246218487394958']
# ['At iteration 23 the best fitness is 0.0246218487394958']
# ['At iteration 24 the best fitness is 0.0246218487394958']
# ['At iteration 25 the best fitness is 0.0246218487394958']
# ['At iteration 26 the best fitness is 0.0246218487394958']
# ['At iteration 27 the best fitness is 0.0246218487394958']
# ['At iteration 28 the best fitness is 0.0246218487394958']
# ['At iteration 29 the best fitness is 0.0246218487394958']
#       Selected: 304/595 (51.1%), Fitness: 0.0246, Time: 748.9s
#       Modality: D=38%, S=63%, Sk=50%, V=52%
#     Test Acc: 74.07%, F1: 70.41%, Features: 304/595 (51.1%), Model: 1.135MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.03695238095238093
# At iteration 2 the best fitness is 0.03120728291316531
# At iteration 3 the best fitness is 0.03213165266106447
# At iteration 4 the best fitness is 0.03070308123249304
# At iteration 5 the best fitness is 0.03145938375350144
# At iteration 6 the best fitness is 0.03070308123249304
# At iteration 7 the best fitness is 0.030030812324930014
# At iteration 8 the best fitness is 0.030871148459383796
# At iteration 9 the best fitness is 0.025630252100840335
# At iteration 10 the best fitness is 0.025546218487394957
# At iteration 11 the best fitness is 0.024369747899159664
# At iteration 12 the best fitness is 0.024369747899159664
# At iteration 13 the best fitness is 0.024789915966386557
# At iteration 14 the best fitness is 0.024789915966386557
# At iteration 15 the best fitness is 0.024789915966386557
# At iteration 16 the best fitness is 0.023781512605042018
# At iteration 17 the best fitness is 0.03028291316526615
# At iteration 18 the best fitness is 0.0246218487394958
# At iteration 19 the best fitness is 0.02504201680672269
# At iteration 20 the best fitness is 0.024033613445378153
# At iteration 21 the best fitness is 0.030871148459383796
# At iteration 22 the best fitness is 0.029946778711484635
# At iteration 23 the best fitness is 0.024033613445378153
# At iteration 24 the best fitness is 0.024117647058823532
# At iteration 25 the best fitness is 0.02319327731092437
# At iteration 26 the best fitness is 0.02504201680672269
# At iteration 27 the best fitness is 0.024705882352941178
# At iteration 28 the best fitness is 0.02361344537815126
# At iteration 29 the best fitness is 0.024453781512605043
# At iteration 30 the best fitness is 0.02361344537815126
#       Selected: 302/595 (50.8%), Fitness: 0.0236, Time: 747.2s
#       Modality: D=43%, S=57%, Sk=51%, V=50%
#     Test Acc: 82.41%, F1: 79.04%, Features: 302/595 (50.8%), Model: 1.131MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03871708683473388']
# ['At iteration 1 the best fitness is 0.03493557422969186']
# ['At iteration 2 the best fitness is 0.029610644257703125']
# ['At iteration 3 the best fitness is 0.02750980392156867']
# ['At iteration 4 the best fitness is 0.022941176470588236']
# ['At iteration 5 the best fitness is 0.022941176470588236']
# ['At iteration 6 the best fitness is 0.019915966386554622']
# ['At iteration 7 the best fitness is 0.018907563025210086']
# ['At iteration 8 the best fitness is 0.01773109243697479']
# ['At iteration 9 the best fitness is 0.017058823529411765']
# ['At iteration 10 the best fitness is 0.01689075630252101']
# ['At iteration 11 the best fitness is 0.01588235294117647']
# ['At iteration 12 the best fitness is 0.015042016806722689']
# ['At iteration 13 the best fitness is 0.014957983193277312']
# ['At iteration 14 the best fitness is 0.014285714285714285']
# ['At iteration 15 the best fitness is 0.013109243697478993']
# ['At iteration 16 the best fitness is 0.013109243697478993']
# ['At iteration 17 the best fitness is 0.012941176470588237']
# ['At iteration 18 the best fitness is 0.012773109243697478']
# ['At iteration 19 the best fitness is 0.012773109243697478']
# ['At iteration 20 the best fitness is 0.012689075630252102']
# ['At iteration 21 the best fitness is 0.012689075630252102']
# ['At iteration 22 the best fitness is 0.012521008403361344']
# ['At iteration 23 the best fitness is 0.012521008403361344']
# ['At iteration 24 the best fitness is 0.012352941176470589']
# ['At iteration 25 the best fitness is 0.01226890756302521']
# ['At iteration 26 the best fitness is 0.012100840336134455']
# ['At iteration 27 the best fitness is 0.012100840336134455']
# ['At iteration 28 the best fitness is 0.011932773109243698']
# ['At iteration 29 the best fitness is 0.01184873949579832']
#       Selected: 190/595 (31.9%), Fitness: 0.0118, Time: 726.6s
#       Modality: D=38%, S=46%, Sk=32%, V=28%
#     Test Acc: 78.70%, F1: 77.06%, Features: 190/595 (31.9%), Model: 0.581MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.029442577030812368']
# ['At iteration 1 the best fitness is 0.02843417366946783']
# ['At iteration 2 the best fitness is 0.02750980392156867']
# ['At iteration 3 the best fitness is 0.02750980392156867']
# ['At iteration 4 the best fitness is 0.01781512605042017']
# ['At iteration 5 the best fitness is 0.01781512605042017']
# ['At iteration 6 the best fitness is 0.01781512605042017']
# ['At iteration 7 the best fitness is 0.01781512605042017']
# ['At iteration 8 the best fitness is 0.01781512605042017']
# ['At iteration 9 the best fitness is 0.01781512605042017']
# ['At iteration 10 the best fitness is 0.01781512605042017']
# ['At iteration 11 the best fitness is 0.01781512605042017']
# ['At iteration 12 the best fitness is 0.01781512605042017']
# ['At iteration 13 the best fitness is 0.01781512605042017']
# ['At iteration 14 the best fitness is 0.01781512605042017']
# ['At iteration 15 the best fitness is 0.01781512605042017']
# ['At iteration 16 the best fitness is 0.01781512605042017']
# ['At iteration 17 the best fitness is 0.01781512605042017']
# ['At iteration 18 the best fitness is 0.01773109243697479']
# ['At iteration 19 the best fitness is 0.01773109243697479']
# ['At iteration 20 the best fitness is 0.01773109243697479']
# ['At iteration 21 the best fitness is 0.01773109243697479']
# ['At iteration 22 the best fitness is 0.01773109243697479']
# ['At iteration 23 the best fitness is 0.01773109243697479']
# ['At iteration 24 the best fitness is 0.01773109243697479']
# ['At iteration 25 the best fitness is 0.01773109243697479']
# ['At iteration 26 the best fitness is 0.01773109243697479']
# ['At iteration 27 the best fitness is 0.01773109243697479']
# ['At iteration 28 the best fitness is 0.01773109243697479']
# ['At iteration 29 the best fitness is 0.01773109243697479']
#       Selected: 202/595 (33.9%), Fitness: 0.0177, Time: 884.4s
#       Modality: D=46%, S=37%, Sk=34%, V=32%
#     Test Acc: 74.07%, F1: 71.19%, Features: 202/595 (33.9%), Model: 0.655MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02327731092436975']
# ['At iteration 1 the best fitness is 0.02327731092436975']
# ['At iteration 2 the best fitness is 0.023109243697478993']
# ['At iteration 3 the best fitness is 0.023109243697478993']
# ['At iteration 4 the best fitness is 0.023109243697478993']
# ['At iteration 5 the best fitness is 0.022941176470588236']
# ['At iteration 6 the best fitness is 0.022941176470588236']
# ['At iteration 7 the best fitness is 0.022941176470588236']
# ['At iteration 8 the best fitness is 0.022100840336134454']
# ['At iteration 9 the best fitness is 0.022100840336134454']
# ['At iteration 10 the best fitness is 0.022100840336134454']
# ['At iteration 11 the best fitness is 0.022100840336134454']
# ['At iteration 12 the best fitness is 0.022100840336134454']
# ['At iteration 13 the best fitness is 0.022100840336134454']
# ['At iteration 14 the best fitness is 0.022100840336134454']
# ['At iteration 15 the best fitness is 0.022100840336134454']
# ['At iteration 16 the best fitness is 0.022100840336134454']
# ['At iteration 17 the best fitness is 0.022100840336134454']
# ['At iteration 18 the best fitness is 0.022100840336134454']
# ['At iteration 19 the best fitness is 0.022100840336134454']
# ['At iteration 20 the best fitness is 0.022100840336134454']
# ['At iteration 21 the best fitness is 0.022100840336134454']
# ['At iteration 22 the best fitness is 0.022100840336134454']
# ['At iteration 23 the best fitness is 0.022100840336134454']
# ['At iteration 24 the best fitness is 0.022100840336134454']
# ['At iteration 25 the best fitness is 0.0219327731092437']
# ['At iteration 26 the best fitness is 0.0219327731092437']
# ['At iteration 27 the best fitness is 0.0219327731092437']
# ['At iteration 28 the best fitness is 0.0219327731092437']
# ['At iteration 29 the best fitness is 0.0219327731092437']
#       Selected: 262/595 (44.0%), Fitness: 0.0219, Time: 768.2s
#       Modality: D=46%, S=59%, Sk=45%, V=39%
#     Test Acc: 81.48%, F1: 78.38%, Features: 262/595 (44.0%), Model: 1.053MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.025966386554621853']
# ['At iteration 2 the best fitness is 0.025966386554621853']
# ['At iteration 3 the best fitness is 0.025966386554621853']
# ['At iteration 4 the best fitness is 0.025966386554621853']
# ['At iteration 5 the best fitness is 0.025966386554621853']
# ['At iteration 6 the best fitness is 0.025966386554621853']
# ['At iteration 7 the best fitness is 0.025966386554621853']
# ['At iteration 8 the best fitness is 0.025966386554621853']
# ['At iteration 9 the best fitness is 0.025294117647058825']
# ['At iteration 10 the best fitness is 0.025294117647058825']
# ['At iteration 11 the best fitness is 0.024705882352941178']
# ['At iteration 12 the best fitness is 0.024117647058823532']
# ['At iteration 13 the best fitness is 0.024117647058823532']
# ['At iteration 14 the best fitness is 0.024117647058823532']
# ['At iteration 15 the best fitness is 0.024117647058823532']
# ['At iteration 16 the best fitness is 0.024117647058823532']
# ['At iteration 17 the best fitness is 0.024117647058823532']
# ['At iteration 18 the best fitness is 0.02361344537815126']
# ['At iteration 19 the best fitness is 0.02319327731092437']
# ['At iteration 20 the best fitness is 0.02319327731092437']
# ['At iteration 21 the best fitness is 0.02319327731092437']
# ['At iteration 22 the best fitness is 0.02319327731092437']
# ['At iteration 23 the best fitness is 0.02319327731092437']
# ['At iteration 24 the best fitness is 0.022941176470588236']
# ['At iteration 25 the best fitness is 0.022941176470588236']
# ['At iteration 26 the best fitness is 0.022521008403361346']
# ['At iteration 27 the best fitness is 0.022521008403361346']
# ['At iteration 28 the best fitness is 0.022521008403361346']
# ['At iteration 29 the best fitness is 0.02235294117647059']
#       Selected: 280/595 (47.1%), Fitness: 0.0224, Time: 722.7s
#       Modality: D=27%, S=57%, Sk=51%, V=44%
#     Test Acc: 74.07%, F1: 70.72%, Features: 280/595 (47.1%), Model: 1.088MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0316274509803922']
# ['At iteration 2 the best fitness is 0.0316274509803922']
# ['At iteration 3 the best fitness is 0.0316274509803922']
# ['At iteration 4 the best fitness is 0.0316274509803922']
# ['At iteration 5 the best fitness is 0.0316274509803922']
# ['At iteration 6 the best fitness is 0.0316274509803922']
# ['At iteration 7 the best fitness is 0.0316274509803922']
# ['At iteration 8 the best fitness is 0.0316274509803922']
# ['At iteration 9 the best fitness is 0.0316274509803922']
# ['At iteration 10 the best fitness is 0.0316274509803922']
# ['At iteration 11 the best fitness is 0.0316274509803922']
# ['At iteration 12 the best fitness is 0.0316274509803922']
# ['At iteration 13 the best fitness is 0.0316274509803922']
# ['At iteration 14 the best fitness is 0.03112324929971993']
# ['At iteration 15 the best fitness is 0.03112324929971993']
# ...
# ['At iteration 17 the best fitness is 0.016554621848739497']
# ['At iteration 18 the best fitness is 0.016554621848739497']
# ['At iteration 19 the best fitness is 0.016554621848739497']
# ['At iteration 20 the best fitness is 0.016554621848739497']
# ['At iteration 21 the best fitness is 0.016554621848739497']
# ['At iteration 22 the best fitness is 0.016554621848739497']
# ['At iteration 23 the best fitness is 0.016554621848739497']
# ['At iteration 24 the best fitness is 0.016554621848739497']
# ['At iteration 25 the best fitness is 0.016554621848739497']
# ['At iteration 26 the best fitness is 0.016554621848739497']
# ['At iteration 27 the best fitness is 0.016554621848739497']
# ['At iteration 28 the best fitness is 0.016554621848739497']
# ['At iteration 29 the best fitness is 0.016554621848739497']
#       Selected: 213/595 (35.8%), Fitness: 0.0166, Time: 984.2s
#       Modality: D=38%, S=46%, Sk=36%, V=33%
#     Test Acc: 94.39%, F1: 94.52%, Features: 213/595 (35.8%), Model: 0.727MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.030787114845938417']
# ['At iteration 1 the best fitness is 0.030787114845938417']
# ['At iteration 2 the best fitness is 0.030787114845938417']
# ['At iteration 3 the best fitness is 0.030787114845938417']
# ['At iteration 4 the best fitness is 0.030787114845938417']
# ['At iteration 5 the best fitness is 0.030787114845938417']
# ['At iteration 6 the best fitness is 0.030787114845938417']
# ['At iteration 7 the best fitness is 0.030787114845938417']
# ['At iteration 8 the best fitness is 0.030787114845938417']
# ['At iteration 9 the best fitness is 0.030787114845938417']
# ['At iteration 10 the best fitness is 0.030787114845938417']
# ['At iteration 11 the best fitness is 0.030787114845938417']
# ['At iteration 12 the best fitness is 0.030787114845938417']
# ['At iteration 13 the best fitness is 0.030787114845938417']
# ['At iteration 14 the best fitness is 0.030787114845938417']
# ['At iteration 15 the best fitness is 0.030787114845938417']
# ['At iteration 16 the best fitness is 0.030787114845938417']
# ['At iteration 17 the best fitness is 0.030787114845938417']
# ['At iteration 18 the best fitness is 0.030787114845938417']
# ['At iteration 19 the best fitness is 0.030787114845938417']
# ['At iteration 20 the best fitness is 0.030787114845938417']
# ['At iteration 21 the best fitness is 0.030787114845938417']
# ['At iteration 22 the best fitness is 0.030787114845938417']
# ['At iteration 23 the best fitness is 0.03070308123249304']
# ['At iteration 24 the best fitness is 0.029862745098039257']
# ['At iteration 25 the best fitness is 0.029862745098039257']
# ['At iteration 26 the best fitness is 0.029862745098039257']
# ['At iteration 27 the best fitness is 0.029862745098039257']
# ['At iteration 28 the best fitness is 0.029610644257703125']
# ['At iteration 29 the best fitness is 0.029610644257703125']
#       Selected: 285/595 (47.9%), Fitness: 0.0296, Time: 772.3s
#       Modality: D=65%, S=43%, Sk=46%, V=48%
#     Test Acc: 90.65%, F1: 90.09%, Features: 285/595 (47.9%), Model: 1.098MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.039305322128851516']
# ['At iteration 2 the best fitness is 0.03796078431372547']
# ['At iteration 3 the best fitness is 0.026386554621848742']
# ['At iteration 4 the best fitness is 0.026386554621848742']
# ['At iteration 5 the best fitness is 0.026386554621848742']
# ['At iteration 6 the best fitness is 0.026386554621848742']
# ['At iteration 7 the best fitness is 0.026386554621848742']
# ['At iteration 8 the best fitness is 0.026386554621848742']
# ['At iteration 9 the best fitness is 0.026386554621848742']
# ['At iteration 10 the best fitness is 0.026386554621848742']
# ['At iteration 11 the best fitness is 0.026386554621848742']
# ['At iteration 12 the best fitness is 0.026386554621848742']
# ['At iteration 13 the best fitness is 0.026386554621848742']
# ['At iteration 14 the best fitness is 0.026386554621848742']
# ['At iteration 15 the best fitness is 0.026386554621848742']
# ['At iteration 16 the best fitness is 0.025882352941176474']
# ['At iteration 17 the best fitness is 0.025882352941176474']
# ['At iteration 18 the best fitness is 0.025882352941176474']
# ['At iteration 19 the best fitness is 0.025882352941176474']
# ['At iteration 20 the best fitness is 0.025882352941176474']
# ['At iteration 21 the best fitness is 0.025882352941176474']
# ['At iteration 22 the best fitness is 0.025882352941176474']
# ['At iteration 23 the best fitness is 0.025882352941176474']
# ['At iteration 24 the best fitness is 0.025882352941176474']
# ['At iteration 25 the best fitness is 0.025882352941176474']
# ['At iteration 26 the best fitness is 0.025882352941176474']
# ['At iteration 27 the best fitness is 0.025882352941176474']
# ['At iteration 28 the best fitness is 0.025294117647058825']
# ['At iteration 29 the best fitness is 0.025294117647058825']
#       Selected: 309/595 (51.9%), Fitness: 0.0253, Time: 735.2s
#       Modality: D=46%, S=54%, Sk=52%, V=52%
#     Test Acc: 92.52%, F1: 92.27%, Features: 309/595 (51.9%), Model: 1.145MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04463025210084035']
# ['At iteration 2 the best fitness is 0.038633053221288495']
# ['At iteration 3 the best fitness is 0.038633053221288495']
# ['At iteration 4 the best fitness is 0.03070308123249304']
# ['At iteration 5 the best fitness is 0.03070308123249304']
# ['At iteration 6 the best fitness is 0.03070308123249304']
# ['At iteration 7 the best fitness is 0.03070308123249304']
# ['At iteration 8 the best fitness is 0.03070308123249304']
# ['At iteration 9 the best fitness is 0.03070308123249304']
# ['At iteration 10 the best fitness is 0.025294117647058825']
# ['At iteration 11 the best fitness is 0.025294117647058825']
# ['At iteration 12 the best fitness is 0.025294117647058825']
# ['At iteration 13 the best fitness is 0.025294117647058825']
# ['At iteration 14 the best fitness is 0.025294117647058825']
# ['At iteration 15 the best fitness is 0.025294117647058825']
# ['At iteration 16 the best fitness is 0.025294117647058825']
# ['At iteration 17 the best fitness is 0.025294117647058825']
# ['At iteration 18 the best fitness is 0.025294117647058825']
# ['At iteration 19 the best fitness is 0.025294117647058825']
# ['At iteration 20 the best fitness is 0.025294117647058825']
# ['At iteration 21 the best fitness is 0.025294117647058825']
# ['At iteration 22 the best fitness is 0.025294117647058825']
# ['At iteration 23 the best fitness is 0.025294117647058825']
# ['At iteration 24 the best fitness is 0.025294117647058825']
# ['At iteration 25 the best fitness is 0.025294117647058825']
# ['At iteration 26 the best fitness is 0.025294117647058825']
# ['At iteration 27 the best fitness is 0.025294117647058825']
# ['At iteration 28 the best fitness is 0.025294117647058825']
# ['At iteration 29 the best fitness is 0.025294117647058825']
# ['At iteration 30 the best fitness is 0.025294117647058825']
#       Selected: 298/595 (50.1%), Fitness: 0.0253, Time: 760.6s
#       Modality: D=41%, S=52%, Sk=50%, V=51%
#     Test Acc: 92.52%, F1: 92.26%, Features: 298/595 (50.1%), Model: 1.123MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.043873949579831956']
# ['At iteration 2 the best fitness is 0.03120728291316531']
# ['At iteration 3 the best fitness is 0.03120728291316531']
# ['At iteration 4 the best fitness is 0.03120728291316531']
# ['At iteration 5 the best fitness is 0.03120728291316531']
# ['At iteration 6 the best fitness is 0.03120728291316531']
# ['At iteration 7 the best fitness is 0.03120728291316531']
# ['At iteration 8 the best fitness is 0.03120728291316531']
# ['At iteration 9 the best fitness is 0.03019887955182077']
# ['At iteration 10 the best fitness is 0.03019887955182077']
# ['At iteration 11 the best fitness is 0.03019887955182077']
# ['At iteration 12 the best fitness is 0.03019887955182077']
# ['At iteration 13 the best fitness is 0.03019887955182077']
# ['At iteration 14 the best fitness is 0.03019887955182077']
# ['At iteration 15 the best fitness is 0.03019887955182077']
# ['At iteration 16 the best fitness is 0.03019887955182077']
# ['At iteration 17 the best fitness is 0.03019887955182077']
# ['At iteration 18 the best fitness is 0.029442577030812368']
# ['At iteration 19 the best fitness is 0.029442577030812368']
# ['At iteration 20 the best fitness is 0.029442577030812368']
# ['At iteration 21 the best fitness is 0.029442577030812368']
# ['At iteration 22 the best fitness is 0.029106442577030853']
# ['At iteration 23 the best fitness is 0.029106442577030853']
# ['At iteration 24 the best fitness is 0.029106442577030853']
# ['At iteration 25 the best fitness is 0.029106442577030853']
# ['At iteration 26 the best fitness is 0.029106442577030853']
# ['At iteration 27 the best fitness is 0.029106442577030853']
# ['At iteration 28 the best fitness is 0.029106442577030853']
# ['At iteration 29 the best fitness is 0.029106442577030853']
# ['At iteration 30 the best fitness is 0.029106442577030853']
#       Selected: 273/595 (45.9%), Fitness: 0.0291, Time: 758.4s
#       Modality: D=62%, S=39%, Sk=44%, V=47%
#     Test Acc: 89.72%, F1: 89.37%, Features: 273/595 (45.9%), Model: 1.074MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04278151260504204']
# ['At iteration 1 the best fitness is 0.041352941176470606']
# ['At iteration 2 the best fitness is 0.03653221288515404']
# ['At iteration 3 the best fitness is 0.03653221288515404']
# ['At iteration 4 the best fitness is 0.03098599439775908']
# ['At iteration 5 the best fitness is 0.02913725490196076']
# ['At iteration 6 the best fitness is 0.02913725490196076']
# ['At iteration 7 the best fitness is 0.02913725490196076']
# ['At iteration 8 the best fitness is 0.026364145658263283']
# ['At iteration 9 the best fitness is 0.026364145658263283']
# ['At iteration 10 the best fitness is 0.01708963585434178']
# ['At iteration 11 the best fitness is 0.01708963585434178']
# ['At iteration 12 the best fitness is 0.01708963585434178']
# ['At iteration 13 the best fitness is 0.01708963585434178']
# ['At iteration 14 the best fitness is 0.01708963585434178']
# ['At iteration 15 the best fitness is 0.01708963585434178']
# ['At iteration 16 the best fitness is 0.01708963585434178']
# ['At iteration 17 the best fitness is 0.01708963585434178']
# ['At iteration 18 the best fitness is 0.01708963585434178']
# ['At iteration 19 the best fitness is 0.01708963585434178']
# ['At iteration 20 the best fitness is 0.014736694677871191']
# ['At iteration 21 the best fitness is 0.014736694677871191']
# ['At iteration 22 the best fitness is 0.014736694677871191']
# ['At iteration 23 the best fitness is 0.014736694677871191']
# ['At iteration 24 the best fitness is 0.014736694677871191']
# ['At iteration 25 the best fitness is 0.014736694677871191']
# ['At iteration 26 the best fitness is 0.014736694677871191']
# ['At iteration 27 the best fitness is 0.014736694677871191']
# ['At iteration 28 the best fitness is 0.014736694677871191']
# ['At iteration 29 the best fitness is 0.014736694677871191']
#       Selected: 114/595 (19.2%), Fitness: 0.0147, Time: 723.9s
#       Modality: D=14%, S=22%, Sk=16%, V=22%
#     Test Acc: 89.72%, F1: 88.99%, Features: 114/595 (19.2%), Model: 0.217MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03137535014005606']
# ['At iteration 2 the best fitness is 0.03137535014005606']
# ['At iteration 3 the best fitness is 0.03061904761904766']
# ['At iteration 4 the best fitness is 0.03061904761904766']
# ['At iteration 5 the best fitness is 0.03028291316526615']
# ['At iteration 6 the best fitness is 0.03028291316526615']
# ['At iteration 7 the best fitness is 0.024705882352941178']
# ['At iteration 8 the best fitness is 0.02420168067226891']
# ['At iteration 9 the best fitness is 0.02420168067226891']
# ['At iteration 10 the best fitness is 0.02420168067226891']
# ['At iteration 11 the best fitness is 0.02420168067226891']
# ['At iteration 12 the best fitness is 0.02420168067226891']
# ['At iteration 13 the best fitness is 0.02420168067226891']
# ['At iteration 14 the best fitness is 0.02420168067226891']
# ['At iteration 15 the best fitness is 0.02420168067226891']
# ['At iteration 16 the best fitness is 0.02420168067226891']
# ['At iteration 17 the best fitness is 0.02420168067226891']
# ['At iteration 18 the best fitness is 0.02420168067226891']
# ['At iteration 19 the best fitness is 0.02420168067226891']
# ['At iteration 20 the best fitness is 0.02420168067226891']
# ['At iteration 21 the best fitness is 0.02420168067226891']
# ['At iteration 22 the best fitness is 0.02420168067226891']
# ['At iteration 23 the best fitness is 0.02420168067226891']
# ['At iteration 24 the best fitness is 0.02420168067226891']
# ['At iteration 25 the best fitness is 0.02420168067226891']
# ['At iteration 26 the best fitness is 0.02420168067226891']
# ['At iteration 27 the best fitness is 0.02420168067226891']
# ['At iteration 28 the best fitness is 0.02420168067226891']
# ['At iteration 29 the best fitness is 0.02420168067226891']
#       Selected: 288/595 (48.4%), Fitness: 0.0242, Time: 1874.6s
#       Modality: D=51%, S=56%, Sk=46%, V=48%
#     Test Acc: 91.59%, F1: 90.32%, Features: 288/595 (48.4%), Model: 1.104MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03737254901960782']
# ['At iteration 1 the best fitness is 0.03336974789915968']
# ['At iteration 2 the best fitness is 0.030008403361344554']
# ['At iteration 3 the best fitness is 0.030008403361344554']
# ['At iteration 4 the best fitness is 0.030008403361344554']
# ['At iteration 5 the best fitness is 0.016753501400560266']
# ['At iteration 6 the best fitness is 0.016753501400560266']
# ['At iteration 7 the best fitness is 0.016753501400560266']
# ['At iteration 8 the best fitness is 0.016753501400560266']
# ['At iteration 9 the best fitness is 0.016753501400560266']
# ['At iteration 10 the best fitness is 0.016753501400560266']
# ['At iteration 11 the best fitness is 0.016753501400560266']
# ['At iteration 12 the best fitness is 0.016753501400560266']
# ['At iteration 13 the best fitness is 0.016753501400560266']
# ['At iteration 14 the best fitness is 0.016753501400560266']
# ['At iteration 15 the best fitness is 0.016753501400560266']
# ['At iteration 16 the best fitness is 0.016753501400560266']
# ['At iteration 17 the best fitness is 0.016753501400560266']
# ['At iteration 18 the best fitness is 0.016753501400560266']
# ['At iteration 19 the best fitness is 0.016753501400560266']
# ['At iteration 20 the best fitness is 0.016753501400560266']
# ['At iteration 21 the best fitness is 0.016753501400560266']
# ['At iteration 22 the best fitness is 0.016753501400560266']
# ['At iteration 23 the best fitness is 0.016753501400560266']
# ['At iteration 24 the best fitness is 0.016753501400560266']
# ['At iteration 25 the best fitness is 0.016753501400560266']
# ['At iteration 26 the best fitness is 0.016753501400560266']
# ['At iteration 27 the best fitness is 0.016753501400560266']
# ['At iteration 28 the best fitness is 0.016753501400560266']
# ['At iteration 29 the best fitness is 0.016753501400560266']
#       Selected: 136/595 (22.9%), Fitness: 0.0168, Time: 707.7s
#       Modality: D=19%, S=26%, Sk=22%, V=23%
#     Test Acc: 80.37%, F1: 76.52%, Features: 136/595 (22.9%), Model: 0.304MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_25_noise/all_results_per_fold.csv
# Shape: (144, 28)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            91.6667           99.3333       89.8765          89.8765              91.3580           91.6667                595             595                100.000       0.0000          8.7620          8.7620        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 1      baseline     2            76.8519          100.0000       72.4055          72.4055              71.8695           76.8519                595             595                100.000       0.0000         10.1635         10.1635        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 2      baseline     3            76.8519           99.3333       73.2195          73.2195              72.6984           76.8519                595             595                100.000       0.0000         10.2179         10.2180        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 3      baseline     4            86.1111           98.6667       84.2045          84.2045              84.5473           86.1111                595             595                100.000       0.0000          9.8914          9.8914        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 4      baseline     5            91.6667           99.3333       91.3003          91.3003              94.7090           91.6667                595             595                100.000       0.0000          9.8906          9.8906        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 5      baseline     6            65.4206           98.6667       60.7715          60.4049              65.4159           65.7407                595             595                100.000       0.0000          9.9579          9.9579        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 6      baseline     7            82.2430           98.6667       78.7868          78.5886              79.4885           82.4074                595             595                100.000       0.0000          9.8779          9.8779        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 7      baseline     8            90.6542          100.0000       90.8036          90.9046              93.9918           90.4321                595             595                100.000       0.0000         10.2508         10.2508        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 8   mutual_info     1            93.5185          100.0000       93.0533          93.0533              96.0847           93.5185                297             595                 49.916       3.4167         12.1086         15.5253        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               35.1852               19                  5.0000                 12             100.0000             264
# 9   mutual_info     2            78.7037          100.0000       73.8617          73.8617              74.2451           78.7037                297             595                 49.916       3.4198         12.2707         15.6907        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               31.4815               17                  5.8333                 14             100.0000             264
# 10  mutual_info     3            78.7037          100.0000       74.8036          74.8036              74.7815           78.7037                297             595                 49.916       3.3333         12.4667         15.8000        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               37.0370               20                  4.5833                 11             100.0000             264
# 11  mutual_info     4            76.8519          100.0000       74.5981          74.5981              75.9649           76.8519                297             595                 49.916       3.3327         11.8383         15.1711        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               37.0370               20                  4.5833                 11             100.0000             264
# 12  mutual_info     5            77.7778          100.0000       73.8753          73.8753              77.0322           77.7778                297             595                 49.916       3.3941         11.8475         15.2417        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               35.1852               19                  5.0000                 12             100.0000             264
# 13  mutual_info     6            71.9626          100.0000       69.6542          69.3706              68.4127           72.2222                297             595                 49.916       3.3714         12.2340         15.6054        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               35.1852               19                  5.0000                 12             100.0000             264
# 14  mutual_info     7            84.1121          100.0000       80.5879          80.4065              81.3468           84.2593                297             595                 49.916       3.4268         11.9234         15.3503        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               33.3333               18                  5.4167                 13             100.0000             264
# 15  mutual_info     8           100.0000          100.0000      100.0000         100.0000             100.0000          100.0000                297             595                 49.916       3.4280         12.2638         15.6919        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               35.1852               19                  5.0000                 12             100.0000             264
# 16          rfe     1            95.3704          100.0000       94.6502          94.6502              96.7901           95.3704                297             595                 49.916       0.5436         12.4016         12.9453        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              27.0270              10              100.0000               54                 19.1667                 46              70.8333             187
# 17          rfe     2            82.4074          100.0000       78.9614          78.9614              78.4186           82.4074                297             595                 49.916       0.5593         12.4985         13.0580        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              24.3243               9               92.5926               50                 16.6667                 40              75.0000             198
# 18          rfe     3            78.7037          100.0000       74.0293          74.0293              74.8971           78.7037                297             595                 49.916       0.5538         12.3731         12.9272        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              18.9189               7              100.0000               54                 19.1667                 46              71.9697             190
# 19          rfe     4            84.2593          100.0000       82.5367          82.5367              85.3175           84.2593                297             595                 49.916       0.5597         11.9259         12.4859        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              24.3243               9               96.2963               52                 20.0000                 48              71.2121             188

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              82.68              9.28              80.17             10.92                  595.00                      100.00              0.00                 9.88                 9.88           444955.0                  1.70                        0.00               27.79
# mutual_info              82.70              9.44              80.05             10.75                  297.00                       49.92              3.39                12.12                15.51           292379.0                  1.12                       50.08               24.00
#         rfe              86.88              7.19              84.84              8.72                  297.00                       49.92              0.55                12.19                12.74           292379.0                  1.12                       50.08               24.00
#       lasso              80.48              8.26              78.13              9.62                  297.00                       49.92              0.08                12.08                12.16           292379.0                  1.12                       50.08               24.00
#    meta_BAT              84.31              8.25              82.49              9.67                  294.12                       49.43            769.49                12.38               781.87           290907.0                  1.12                       50.57               23.97
#     meta_CS              78.50             11.13              76.06             12.50                  284.75                       47.86           1523.25                12.27              1535.51           286107.0                  1.10                       52.14               23.85
#     meta_DE              83.50              7.79              81.32              8.69                  284.25                       47.77            774.30                12.29               786.59           285851.0                  1.10                       52.23               23.85
#    meta_FFA              82.23              9.16              79.31             11.04                  294.50                       49.50            750.55                12.32               762.87           291099.0                  1.12                       50.50               23.97
#     meta_GA              83.73              7.09              81.51              8.67                  298.38                       50.15            750.67                12.37               763.04           293083.0                  1.12                       49.85               24.02
#    meta_GWO              82.57              6.52              81.07              7.10                  236.25                       39.71            741.42                12.05               753.47           232945.0                  0.89                       60.29               22.64
#    meta_HHO              82.12              9.52              80.08             10.85                  226.38                       38.05            939.71                12.04               951.75           209736.0                  0.81                       61.95               22.11
#   meta_JAYA              82.34              7.42              80.32              7.79                  283.50                       47.65            769.49                12.34               781.83           285467.0                  1.09                       52.35               23.84
#    meta_MFO              81.54              8.36              79.28              9.41                  292.75                       49.20            727.26                12.26               739.52           290203.0                  1.11                       50.80               23.95
#    meta_MVO              81.41              8.08              79.15              9.51                  296.25                       49.79            751.83                12.33               764.17           291995.0                  1.12                       50.21               23.99
#    meta_PSO              83.03              6.13              81.09              6.93                  281.12                       47.25            749.95                12.24               762.19           284251.0                  1.09                       52.75               23.81
#    meta_SCA              80.26             11.00              78.28             11.91                  130.88                       22.00            708.45                11.23               719.68            75570.0                  0.29                       78.00               19.03
#    meta_SSA              82.24              7.02              79.81              8.16                  287.12                       48.26           1858.42                12.26              1870.67           287323.0                  1.10                       51.74               23.88
#    meta_WOA              81.41              8.11              79.13              9.02                  219.88                       36.95            706.70                11.98               718.68           188649.0                  0.72                       63.05               21.63

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 82.70% vs Baseline: 82.68%
#   Paired t-test: t=0.0075, p=0.9942
#   Wilcoxon test: W=14.0000, p=0.6328
#   -> better, Not significant
#
# RFE vs BASELINE:
#   Method: 86.88% vs Baseline: 82.68%
#   Paired t-test: t=2.0247, p=0.0826
#   Wilcoxon test: W=3.5000, p=0.0469
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 80.48% vs Baseline: 82.68%
#   Paired t-test: t=-1.5060, p=0.1758
#   Wilcoxon test: W=4.0000, p=0.2188
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 84.31% vs Baseline: 82.68%
#   Paired t-test: t=1.4887, p=0.1802
#   Wilcoxon test: W=9.5000, p=0.2812
#   -> better, Not significant
#
# META_CS vs BASELINE:
#   Method: 78.50% vs Baseline: 82.68%
#   Paired t-test: t=-1.5761, p=0.1590
#   Wilcoxon test: W=8.0000, p=0.1953
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 83.50% vs Baseline: 82.68%
#   Paired t-test: t=0.4263, p=0.6827
#   Wilcoxon test: W=15.0000, p=0.7422
#   -> better, Not significant
#
# META_FFA vs BASELINE:
#   Method: 82.23% vs Baseline: 82.68%
#   Paired t-test: t=-0.3151, p=0.7619
#   Wilcoxon test: W=11.0000, p=0.6562
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 83.73% vs Baseline: 82.68%
#   Paired t-test: t=0.8402, p=0.4286
#   Wilcoxon test: W=11.5000, p=0.3984
#   -> better, Not significant
#
# META_GWO vs BASELINE:
#   Method: 82.57% vs Baseline: 82.68%
#   Paired t-test: t=-0.0677, p=0.9479
#   Wilcoxon test: W=15.0000, p=0.7422
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 82.12% vs Baseline: 82.68%
#   Paired t-test: t=-0.2247, p=0.8286
#   Wilcoxon test: W=15.0000, p=0.7422
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 82.34% vs Baseline: 82.68%
#   Paired t-test: t=-0.1452, p=0.8886
#   Wilcoxon test: W=13.0000, p=0.9375
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 81.54% vs Baseline: 82.68%
#   Paired t-test: t=-0.4308, p=0.6796
#   Wilcoxon test: W=17.0000, p=0.9219
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 81.41% vs Baseline: 82.68%
#   Paired t-test: t=-0.8315, p=0.4331
#   Wilcoxon test: W=12.0000, p=0.7812
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 83.03% vs Baseline: 82.68%
#   Paired t-test: t=0.1900, p=0.8547
#   Wilcoxon test: W=17.5000, p=0.9766
#   -> better, Not significant
#
# META_SCA vs BASELINE:
#   Method: 80.26% vs Baseline: 82.68%
#   Paired t-test: t=-0.7938, p=0.4534
#   Wilcoxon test: W=10.0000, p=0.3125
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 82.24% vs Baseline: 82.68%
#   Paired t-test: t=-0.1551, p=0.8811
#   Wilcoxon test: W=13.0000, p=0.9375
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 81.41% vs Baseline: 82.68%
#   Paired t-test: t=-0.5537, p=0.5970
#   Wilcoxon test: W=14.0000, p=1.0000
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_25_noise
#
# Per-method folders:
#   results_25_noise/baseline/ (16 files)
#   results_25_noise/mutual_info/ (16 files)
#   results_25_noise/rfe/ (16 files)
#   results_25_noise/lasso/ (16 files)
#   results_25_noise/meta_BAT/ (16 files)
#   results_25_noise/meta_CS/ (16 files)
#   results_25_noise/meta_DE/ (16 files)
#   results_25_noise/meta_FFA/ (16 files)
#   results_25_noise/meta_GA/ (16 files)
#   results_25_noise/meta_GWO/ (16 files)
#   results_25_noise/meta_HHO/ (16 files)
#   results_25_noise/meta_JAYA/ (16 files)
#   results_25_noise/meta_MFO/ (16 files)
#   results_25_noise/meta_MVO/ (16 files)
#   results_25_noise/meta_PSO/ (16 files)
#   results_25_noise/meta_SCA/ (16 files)
#   results_25_noise/meta_SSA/ (16 files)
#   results_25_noise/meta_WOA/ (16 files)
#
# Plots directory: results_25_noise/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 86.88% ± 7.19% (Features: 49.9%)
#   meta_BAT            : 84.31% ± 8.25% (Features: 49.4%)
#   meta_GA             : 83.73% ± 7.09% (Features: 50.1%)
#   meta_DE             : 83.50% ± 7.79% (Features: 47.8%)
#   meta_PSO            : 83.03% ± 6.13% (Features: 47.2%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_BAT
#     Test Accuracy:      94.44%
#     Feature Retention:  51.26% (305/595)
#     Modality Retention: depth=59.5%, sensor=59.3%, skeleton=44.6%, video=54.5%
#
#   Fold 2: Best = meta_DE
#     Test Accuracy:      82.41%
#     Feature Retention:  45.04% (268/595)
#     Modality Retention: depth=21.6%, sensor=51.9%, skeleton=45.0%, video=47.0%
#
#   Fold 3: Best = meta_JAYA
#     Test Accuracy:      87.04%
#     Feature Retention:  47.06% (280/595)
#     Modality Retention: depth=54.1%, sensor=46.3%, skeleton=45.4%, video=47.7%
#
#   Fold 4: Best = meta_DE
#     Test Accuracy:      83.33%
#     Feature Retention:  48.24% (287/595)
#     Modality Retention: depth=54.1%, sensor=55.6%, skeleton=42.9%, video=50.8%
#
#   Fold 5: Best = meta_BAT
#     Test Accuracy:      92.59%
#     Feature Retention:  49.24% (293/595)
#     Modality Retention: depth=40.5%, sensor=55.6%, skeleton=50.4%, video=48.1%
#
#   Fold 6: Best = meta_GWO
#     Test Accuracy:      74.77%
#     Feature Retention:  37.31% (222/595)
#     Modality Retention: depth=27.0%, sensor=51.9%, skeleton=32.5%, video=40.2%
#
#   Fold 7: Best = meta_SCA
#     Test Accuracy:      96.26%
#     Feature Retention:  22.02% (131/595)
#     Modality Retention: depth=24.3%, sensor=33.3%, skeleton=20.0%, video=21.2%
#
#   Fold 8: Best = meta_DE
#     Test Accuracy:      95.33%
#     Feature Retention:  45.38% (270/595)
#     Modality Retention: depth=37.8%, sensor=50.0%, skeleton=44.2%, video=46.6%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     88.27% ± 7.68%
#   Average Feature Retention: 43.19% ± 9.51%
#
#   Average Modality-wise Feature Retention:
#          depth: 39.86% ± 14.79%
#         sensor: 50.46% ± 7.97%
#       skeleton: 40.62% ± 9.73%
#          video: 44.51% ± 10.25%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)  video Retention (%)
#     1           meta_BAT              94.44                  51.26                59.46                 59.26                   44.58                54.55
#     2            meta_DE              82.41                  45.04                21.62                 51.85                   45.00                46.97
#     3          meta_JAYA              87.04                  47.06                54.05                 46.30                   45.42                47.73
#     4            meta_DE              83.33                  48.24                54.05                 55.56                   42.92                50.76
#     5           meta_BAT              92.59                  49.24                40.54                 55.56                   50.42                48.11
#     6           meta_GWO              74.77                  37.31                27.03                 51.85                   32.50                40.15
#     7           meta_SCA              96.26                  22.02                24.32                 33.33                   20.00                21.21
#     8            meta_DE              95.33                  45.38                37.84                 50.00                   44.17                46.59
#
# Saved to: results_25_noise/best_metaheuristic_per_fold.csv
