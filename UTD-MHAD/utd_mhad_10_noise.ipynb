# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (10% Random Zeroing)
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.
#
#
# > **Modification:** This notebook randomly zeros out 10% of all data elements before any processing.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_10_noise")

# Master output directory
RESULTS_ROOT = Path("results_10_noise")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 37
#   sensor: 54
#   skeleton: 240
#   video: 264
#   TOTAL: 595

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 89.81%, F1: 87.98%, Features: 595/595 (100.0%), Model: 1.703MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 297/595 (49.9%), Time: 3.4s
#     Test Acc: 92.59%, F1: 90.12%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 297/595 (49.9%), Time: 0.6s
#     Test Acc: 90.74%, F1: 89.08%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 297/595 (49.9%), Time: 0.1s
#     Test Acc: 94.44%, F1: 93.77%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02680672268907563']
# ['At iteration 1 the best fitness is 0.02680672268907563']
# ['At iteration 2 the best fitness is 0.02680672268907563']
# ['At iteration 3 the best fitness is 0.02680672268907563']
# ['At iteration 4 the best fitness is 0.02680672268907563']
# ['At iteration 5 the best fitness is 0.02680672268907563']
# ['At iteration 6 the best fitness is 0.02680672268907563']
# ['At iteration 7 the best fitness is 0.02680672268907563']
# ['At iteration 8 the best fitness is 0.02680672268907563']
# ['At iteration 9 the best fitness is 0.02680672268907563']
# ['At iteration 10 the best fitness is 0.02680672268907563']
# ['At iteration 11 the best fitness is 0.02680672268907563']
# ['At iteration 12 the best fitness is 0.02680672268907563']
# ['At iteration 13 the best fitness is 0.02680672268907563']
# ['At iteration 14 the best fitness is 0.02680672268907563']
# ['At iteration 15 the best fitness is 0.02680672268907563']
# ['At iteration 16 the best fitness is 0.02680672268907563']
# ['At iteration 17 the best fitness is 0.02680672268907563']
# ['At iteration 18 the best fitness is 0.02680672268907563']
# ['At iteration 19 the best fitness is 0.02680672268907563']
# ['At iteration 20 the best fitness is 0.02680672268907563']
# ['At iteration 21 the best fitness is 0.02680672268907563']
# ['At iteration 22 the best fitness is 0.02680672268907563']
# ['At iteration 23 the best fitness is 0.02680672268907563']
# ['At iteration 24 the best fitness is 0.02680672268907563']
# ['At iteration 25 the best fitness is 0.02680672268907563']
# ['At iteration 26 the best fitness is 0.02680672268907563']
# ['At iteration 27 the best fitness is 0.02680672268907563']
# ['At iteration 28 the best fitness is 0.02680672268907563']
# ['At iteration 29 the best fitness is 0.02680672268907563']
#       Selected: 312/595 (52.4%), Fitness: 0.0268, Time: 775.5s
#       Modality: D=57%, S=50%, Sk=54%, V=51%
#     Test Acc: 92.59%, F1: 91.71%, Features: 312/595 (52.4%), Model: 1.151MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.038380952380952356']
# ['At iteration 10 the best fitness is 0.025546218487394957']
# ['At iteration 20 the best fitness is 0.025546218487394957']
#       Selected: 314/595 (52.8%), Fitness: 0.0255, Time: 1517.4s
#       Modality: D=54%, S=57%, Sk=50%, V=54%
#     Test Acc: 89.81%, F1: 88.16%, Features: 314/595 (52.8%), Model: 1.154MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03145938375350144']
# ['At iteration 2 the best fitness is 0.03145938375350144']
# ['At iteration 3 the best fitness is 0.03145938375350144']
# ['At iteration 4 the best fitness is 0.03145938375350144']
# ['At iteration 5 the best fitness is 0.026638655462184874']
# ['At iteration 6 the best fitness is 0.026638655462184874']
# ['At iteration 7 the best fitness is 0.025210084033613446']
# ['At iteration 8 the best fitness is 0.025210084033613446']
# ['At iteration 9 the best fitness is 0.025210084033613446']
# ['At iteration 10 the best fitness is 0.025210084033613446']
# ['At iteration 11 the best fitness is 0.025210084033613446']
# ['At iteration 12 the best fitness is 0.025210084033613446']
# ['At iteration 13 the best fitness is 0.025210084033613446']
# ['At iteration 14 the best fitness is 0.025210084033613446']
# ['At iteration 15 the best fitness is 0.025210084033613446']
# ['At iteration 16 the best fitness is 0.025210084033613446']
# ['At iteration 17 the best fitness is 0.025210084033613446']
# ['At iteration 18 the best fitness is 0.025210084033613446']
# ['At iteration 19 the best fitness is 0.025210084033613446']
# ['At iteration 20 the best fitness is 0.025210084033613446']
# ['At iteration 21 the best fitness is 0.025210084033613446']
# ['At iteration 22 the best fitness is 0.025210084033613446']
# ['At iteration 23 the best fitness is 0.025210084033613446']
# ['At iteration 24 the best fitness is 0.025210084033613446']
# ['At iteration 25 the best fitness is 0.025210084033613446']
# ['At iteration 26 the best fitness is 0.025210084033613446']
# ['At iteration 27 the best fitness is 0.025210084033613446']
# ['At iteration 28 the best fitness is 0.0246218487394958']
# ['At iteration 29 the best fitness is 0.0246218487394958']
# ['At iteration 30 the best fitness is 0.0246218487394958']
#       Selected: 285/595 (47.9%), Fitness: 0.0246, Time: 771.2s
#       Modality: D=35%, S=50%, Sk=47%, V=50%
#     Test Acc: 86.11%, F1: 83.68%, Features: 285/595 (47.9%), Model: 1.098MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04395798319327733']
# ['At iteration 1 the best fitness is 0.03762464985994396']
# ['At iteration 2 the best fitness is 0.030871148459383796']
# ['At iteration 3 the best fitness is 0.037456582633053195']
# ['At iteration 4 the best fitness is 0.03712044817927168']
# ['At iteration 5 the best fitness is 0.03712044817927168']
# ['At iteration 6 the best fitness is 0.03888515406162463']
# ['At iteration 7 the best fitness is 0.04421008403361346']
# ['At iteration 8 the best fitness is 0.0382128851540616']
# ['At iteration 9 the best fitness is 0.0382128851540616']
# ['At iteration 10 the best fitness is 0.038380952380952356']
# ['At iteration 11 the best fitness is 0.038380952380952356']
# ['At iteration 12 the best fitness is 0.03871708683473388']
# ['At iteration 13 the best fitness is 0.03229971988795523']
# ['At iteration 14 the best fitness is 0.038128851540616224']
# ['At iteration 15 the best fitness is 0.038128851540616224']
# ['At iteration 16 the best fitness is 0.038128851540616224']
# ['At iteration 17 the best fitness is 0.038296918767506974']
# ['At iteration 18 the best fitness is 0.038380952380952356']
# ['At iteration 19 the best fitness is 0.03213165266106447']
# ['At iteration 20 the best fitness is 0.03846498599439774']
# ['At iteration 21 the best fitness is 0.03846498599439774']
# ['At iteration 22 the best fitness is 0.03213165266106447']
# ['At iteration 23 the best fitness is 0.03846498599439774']
# ['At iteration 24 the best fitness is 0.03846498599439774']
# ['At iteration 25 the best fitness is 0.04479831932773111']
# ['At iteration 26 the best fitness is 0.03846498599439774']
# ['At iteration 27 the best fitness is 0.03213165266106447']
# ['At iteration 28 the best fitness is 0.03213165266106447']
# ['At iteration 29 the best fitness is 0.03846498599439774']
#       Selected: 296/595 (49.7%), Fitness: 0.0385, Time: 746.3s
#       Modality: D=57%, S=54%, Sk=48%, V=50%
#     Test Acc: 93.52%, F1: 92.83%, Features: 296/595 (49.7%), Model: 1.119MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.037456582633053195
# At iteration 2 the best fitness is 0.03737254901960782
# At iteration 3 the best fitness is 0.026302521008403364
# At iteration 4 the best fitness is 0.03288795518207287
# At iteration 5 the best fitness is 0.03179551820728295
# At iteration 6 the best fitness is 0.03179551820728295
# At iteration 7 the best fitness is 0.03229971988795523
# At iteration 8 the best fitness is 0.025294117647058825
# At iteration 9 the best fitness is 0.0246218487394958
# At iteration 10 the best fitness is 0.03061904761904766
# At iteration 11 the best fitness is 0.031291316526610685
# At iteration 12 the best fitness is 0.025798319327731096
# At iteration 13 the best fitness is 0.03112324929971993
# At iteration 14 the best fitness is 0.03737254901960782
# At iteration 15 the best fitness is 0.025546218487394957
# At iteration 16 the best fitness is 0.02504201680672269
# At iteration 17 the best fitness is 0.025126050420168067
# At iteration 18 the best fitness is 0.031039215686274553
# At iteration 19 the best fitness is 0.031711484593837574
# At iteration 20 the best fitness is 0.024873949579831935
# At iteration 21 the best fitness is 0.025126050420168067
# At iteration 22 the best fitness is 0.024705882352941178
# At iteration 23 the best fitness is 0.024705882352941178
# At iteration 24 the best fitness is 0.025126050420168067
# At iteration 25 the best fitness is 0.0246218487394958
# At iteration 26 the best fitness is 0.02504201680672269
# At iteration 27 the best fitness is 0.0246218487394958
# At iteration 28 the best fitness is 0.0246218487394958
# At iteration 29 the best fitness is 0.0246218487394958
# At iteration 30 the best fitness is 0.0246218487394958
#       Selected: 291/595 (48.9%), Fitness: 0.0246, Time: 746.2s
#       Modality: D=38%, S=57%, Sk=50%, V=47%
#     Test Acc: 90.74%, F1: 89.76%, Features: 291/595 (48.9%), Model: 1.109MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04303361344537817']
# ['At iteration 1 the best fitness is 0.037036414565826306']
# ['At iteration 2 the best fitness is 0.030114845938375392']
# ['At iteration 3 the best fitness is 0.030114845938375392']
# ['At iteration 4 the best fitness is 0.030114845938375392']
# ['At iteration 5 the best fitness is 0.02750980392156867']
# ['At iteration 6 the best fitness is 0.02750980392156867']
# ['At iteration 7 the best fitness is 0.02750980392156867']
# ['At iteration 8 the best fitness is 0.026249299719887997']
# ['At iteration 9 the best fitness is 0.026249299719887997']
# ['At iteration 10 the best fitness is 0.02008403361344538']
# ['At iteration 11 the best fitness is 0.02008403361344538']
# ['At iteration 12 the best fitness is 0.02008403361344538']
# ['At iteration 13 the best fitness is 0.02008403361344538']
# ['At iteration 14 the best fitness is 0.02008403361344538']
# ['At iteration 15 the best fitness is 0.02008403361344538']
# ['At iteration 16 the best fitness is 0.02008403361344538']
# ['At iteration 17 the best fitness is 0.02008403361344538']
# ['At iteration 18 the best fitness is 0.02008403361344538']
# ['At iteration 19 the best fitness is 0.02008403361344538']
# ['At iteration 20 the best fitness is 0.018571428571428572']
# ['At iteration 21 the best fitness is 0.018571428571428572']
# ['At iteration 22 the best fitness is 0.018571428571428572']
# ['At iteration 23 the best fitness is 0.018571428571428572']
# ['At iteration 24 the best fitness is 0.018571428571428572']
# ['At iteration 25 the best fitness is 0.018571428571428572']
# ['At iteration 26 the best fitness is 0.018571428571428572']
# ['At iteration 27 the best fitness is 0.018571428571428572']
# ['At iteration 28 the best fitness is 0.018571428571428572']
# ['At iteration 29 the best fitness is 0.018571428571428572']
#       Selected: 236/595 (39.7%), Fitness: 0.0186, Time: 741.6s
#       Modality: D=30%, S=44%, Sk=38%, V=41%
#     Test Acc: 91.67%, F1: 90.67%, Features: 236/595 (39.7%), Model: 0.888MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.04353781512605044']
# ['At iteration 1 the best fitness is 0.03958823529411766']
# ['At iteration 2 the best fitness is 0.03510364145658261']
# ['At iteration 3 the best fitness is 0.03510364145658261']
# ['At iteration 4 the best fitness is 0.03392717086834732']
# ['At iteration 5 the best fitness is 0.03392717086834732']
# ['At iteration 6 the best fitness is 0.03392717086834732']
# ['At iteration 7 the best fitness is 0.033338935574229664']
# ['At iteration 8 the best fitness is 0.029977591036414543']
# ['At iteration 9 the best fitness is 0.029442577030812368']
# ['At iteration 10 the best fitness is 0.022941176470588236']
# ['At iteration 11 the best fitness is 0.022941176470588236']
# ['At iteration 12 the best fitness is 0.022941176470588236']
# ['At iteration 13 the best fitness is 0.022941176470588236']
# ['At iteration 14 the best fitness is 0.022941176470588236']
# ['At iteration 15 the best fitness is 0.022941176470588236']
# ['At iteration 16 the best fitness is 0.022941176470588236']
# ['At iteration 17 the best fitness is 0.022941176470588236']
# ['At iteration 18 the best fitness is 0.022941176470588236']
# ['At iteration 19 the best fitness is 0.022941176470588236']
# ['At iteration 20 the best fitness is 0.022941176470588236']
# ['At iteration 21 the best fitness is 0.022941176470588236']
# ['At iteration 22 the best fitness is 0.022941176470588236']
# ['At iteration 23 the best fitness is 0.022941176470588236']
# ['At iteration 24 the best fitness is 0.022941176470588236']
# ['At iteration 25 the best fitness is 0.022941176470588236']
# ['At iteration 26 the best fitness is 0.022941176470588236']
# ['At iteration 27 the best fitness is 0.022941176470588236']
# ['At iteration 28 the best fitness is 0.022941176470588236']
# ['At iteration 29 the best fitness is 0.022941176470588236']
#       Selected: 284/595 (47.7%), Fitness: 0.0229, Time: 968.8s
#       Modality: D=32%, S=54%, Sk=48%, V=48%
#     Test Acc: 92.59%, F1: 92.02%, Features: 284/595 (47.7%), Model: 1.096MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03112324929971993']
# ['At iteration 1 the best fitness is 0.03112324929971993']
# ['At iteration 2 the best fitness is 0.03112324929971993']
# ['At iteration 3 the best fitness is 0.03112324929971993']
# ['At iteration 4 the best fitness is 0.03112324929971993']
# ['At iteration 5 the best fitness is 0.03112324929971993']
# ['At iteration 6 the best fitness is 0.030871148459383796']
# ['At iteration 7 the best fitness is 0.030871148459383796']
# ['At iteration 8 the best fitness is 0.030871148459383796']
# ['At iteration 9 the best fitness is 0.030871148459383796']
# ['At iteration 10 the best fitness is 0.030871148459383796']
# ['At iteration 11 the best fitness is 0.03061904761904766']
# ['At iteration 12 the best fitness is 0.03061904761904766']
# ['At iteration 13 the best fitness is 0.03061904761904766']
# ['At iteration 14 the best fitness is 0.03061904761904766']
# ['At iteration 15 the best fitness is 0.03061904761904766']
# ['At iteration 16 the best fitness is 0.03061904761904766']
# ['At iteration 17 the best fitness is 0.0246218487394958']
# ['At iteration 18 the best fitness is 0.0246218487394958']
# ['At iteration 19 the best fitness is 0.0246218487394958']
# ['At iteration 20 the best fitness is 0.0246218487394958']
# ['At iteration 21 the best fitness is 0.0246218487394958']
# ['At iteration 22 the best fitness is 0.0246218487394958']
# ['At iteration 23 the best fitness is 0.0246218487394958']
# ['At iteration 24 the best fitness is 0.0246218487394958']
# ['At iteration 25 the best fitness is 0.0246218487394958']
# ['At iteration 26 the best fitness is 0.0246218487394958']
# ['At iteration 27 the best fitness is 0.0246218487394958']
# ['At iteration 28 the best fitness is 0.0246218487394958']
# ['At iteration 29 the best fitness is 0.0246218487394958']
#       Selected: 307/595 (51.6%), Fitness: 0.0246, Time: 774.8s
#       Modality: D=70%, S=57%, Sk=50%, V=50%
#     Test Acc: 88.89%, F1: 88.06%, Features: 307/595 (51.6%), Model: 1.141MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04852661064425766']
# ['At iteration 2 the best fitness is 0.037876750700280085']
# ['At iteration 3 the best fitness is 0.037876750700280085']
# ['At iteration 4 the best fitness is 0.03280392156862749']
# ['At iteration 5 the best fitness is 0.03280392156862749']
# ['At iteration 6 the best fitness is 0.03280392156862749']
# ['At iteration 7 the best fitness is 0.0316274509803922']
# ['At iteration 8 the best fitness is 0.0316274509803922']
# ['At iteration 9 the best fitness is 0.0316274509803922']
# ['At iteration 10 the best fitness is 0.0316274509803922']
# ['At iteration 11 the best fitness is 0.0316274509803922']
# ['At iteration 12 the best fitness is 0.0316274509803922']
# ['At iteration 13 the best fitness is 0.0316274509803922']
# ['At iteration 14 the best fitness is 0.026218487394957985']
# ['At iteration 15 the best fitness is 0.025798319327731096']
# ['At iteration 16 the best fitness is 0.025798319327731096']
# ['At iteration 17 the best fitness is 0.025798319327731096']
# ['At iteration 18 the best fitness is 0.025714285714285714']
# ['At iteration 19 the best fitness is 0.025714285714285714']
# ['At iteration 20 the best fitness is 0.025714285714285714']
# ['At iteration 21 the best fitness is 0.0246218487394958']
# ['At iteration 22 the best fitness is 0.0246218487394958']
# ['At iteration 23 the best fitness is 0.0246218487394958']
# ['At iteration 24 the best fitness is 0.0246218487394958']
# ['At iteration 25 the best fitness is 0.0246218487394958']
# ['At iteration 26 the best fitness is 0.0246218487394958']
# ['At iteration 27 the best fitness is 0.0246218487394958']
# ['At iteration 28 the best fitness is 0.0246218487394958']
# ['At iteration 29 the best fitness is 0.0246218487394958']
#       Selected: 301/595 (50.6%), Fitness: 0.0246, Time: 724.4s
#       Modality: D=41%, S=59%, Sk=48%, V=53%
#     Test Acc: 88.89%, F1: 86.29%, Features: 301/595 (50.6%), Model: 1.129MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03339215686274514']
# ['At iteration 2 the best fitness is 0.03339215686274514']
# ['At iteration 3 the best fitness is 0.03339215686274514']
# ['At iteration 4 the best fitness is 0.03339215686274514']
# ['At iteration 5 the best fitness is 0.03204761904761909']
# ['At iteration 6 the best fitness is 0.030787114845938417']
# ['At iteration 7 the best fitness is 0.030787114845938417']
# ['At iteration 8 the best fitness is 0.025126050420168067']
# ['At iteration 9 the best fitness is 0.025126050420168067']
# ['At iteration 10 the best fitness is 0.025126050420168067']
# ['At iteration 11 the best fitness is 0.025126050420168067']
# ['At iteration 12 the best fitness is 0.025126050420168067']
# ['At iteration 13 the best fitness is 0.025126050420168067']
# ['At iteration 14 the best fitness is 0.025126050420168067']
# ['At iteration 15 the best fitness is 0.025126050420168067']
# ['At iteration 16 the best fitness is 0.025126050420168067']
# ['At iteration 17 the best fitness is 0.025126050420168067']
# ['At iteration 18 the best fitness is 0.025126050420168067']
# ['At iteration 19 the best fitness is 0.025126050420168067']
# ['At iteration 20 the best fitness is 0.025126050420168067']
# ['At iteration 21 the best fitness is 0.025126050420168067']
# ['At iteration 22 the best fitness is 0.024873949579831935']
# ['At iteration 23 the best fitness is 0.024873949579831935']
# ['At iteration 24 the best fitness is 0.024873949579831935']
# ['At iteration 25 the best fitness is 0.024873949579831935']
# ['At iteration 26 the best fitness is 0.024873949579831935']
# ['At iteration 27 the best fitness is 0.024873949579831935']
# ['At iteration 28 the best fitness is 0.024873949579831935']
# ['At iteration 29 the best fitness is 0.024873949579831935']
# ['At iteration 30 the best fitness is 0.024873949579831935']
#       Selected: 283/595 (47.6%), Fitness: 0.0249, Time: 746.0s
#       Modality: D=49%, S=56%, Sk=44%, V=49%
#     Test Acc: 89.81%, F1: 89.20%, Features: 283/595 (47.6%), Model: 1.094MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.038380952380952356']
# ['At iteration 2 the best fitness is 0.037708683473389334']
# ['At iteration 3 the best fitness is 0.037288515406162445']
# ['At iteration 4 the best fitness is 0.03636414565826328']
# ['At iteration 5 the best fitness is 0.031039215686274553']
# ['At iteration 6 the best fitness is 0.024705882352941178']
# ['At iteration 7 the best fitness is 0.024705882352941178']
# ['At iteration 8 the best fitness is 0.024705882352941178']
# ['At iteration 9 the best fitness is 0.024705882352941178']
# ['At iteration 10 the best fitness is 0.024705882352941178']
# ['At iteration 11 the best fitness is 0.024705882352941178']
# ['At iteration 12 the best fitness is 0.024705882352941178']
# ['At iteration 13 the best fitness is 0.02420168067226891']
# ['At iteration 14 the best fitness is 0.02420168067226891']
# ['At iteration 15 the best fitness is 0.02420168067226891']
# ['At iteration 16 the best fitness is 0.02420168067226891']
# ['At iteration 17 the best fitness is 0.02420168067226891']
# ['At iteration 18 the best fitness is 0.02420168067226891']
# ['At iteration 19 the best fitness is 0.02369747899159664']
# ['At iteration 20 the best fitness is 0.02369747899159664']
# ['At iteration 21 the best fitness is 0.02369747899159664']
# ['At iteration 22 the best fitness is 0.02369747899159664']
# ['At iteration 23 the best fitness is 0.02369747899159664']
# ['At iteration 24 the best fitness is 0.02369747899159664']
# ['At iteration 25 the best fitness is 0.02369747899159664']
# ['At iteration 26 the best fitness is 0.02369747899159664']
# ['At iteration 27 the best fitness is 0.02369747899159664']
# ['At iteration 28 the best fitness is 0.02369747899159664']
# ['At iteration 29 the best fitness is 0.02369747899159664']
# ['At iteration 30 the best fitness is 0.02369747899159664']
#       Selected: 278/595 (46.7%), Fitness: 0.0237, Time: 747.3s
#       Modality: D=46%, S=59%, Sk=45%, V=45%
#     Test Acc: 92.59%, F1: 91.61%, Features: 278/595 (46.7%), Model: 1.084MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03636414565826328']
# ['At iteration 1 the best fitness is 0.035439775910364124']
# ['At iteration 2 the best fitness is 0.032498599439775885']
# ['At iteration 3 the best fitness is 0.02633333333333338']
# ['At iteration 4 the best fitness is 0.02633333333333338']
# ['At iteration 5 the best fitness is 0.02633333333333338']
# ['At iteration 6 the best fitness is 0.02633333333333338']
# ['At iteration 7 the best fitness is 0.02213165266106447']
# ['At iteration 8 the best fitness is 0.02213165266106447']
# ['At iteration 9 the best fitness is 0.02213165266106447']
# ['At iteration 10 the best fitness is 0.02213165266106447']
# ['At iteration 11 the best fitness is 0.02213165266106447']
# ['At iteration 12 the best fitness is 0.02213165266106447']
# ['At iteration 13 the best fitness is 0.02213165266106447']
# ['At iteration 14 the best fitness is 0.02213165266106447']
# ['At iteration 15 the best fitness is 0.02213165266106447']
# ['At iteration 16 the best fitness is 0.019526610644257744']
# ['At iteration 17 the best fitness is 0.019526610644257744']
# ['At iteration 18 the best fitness is 0.019526610644257744']
# ['At iteration 19 the best fitness is 0.019526610644257744']
# ['At iteration 20 the best fitness is 0.019526610644257744']
# ['At iteration 21 the best fitness is 0.019526610644257744']
# ['At iteration 22 the best fitness is 0.019526610644257744']
# ['At iteration 23 the best fitness is 0.019526610644257744']
# ['At iteration 24 the best fitness is 0.019526610644257744']
# ['At iteration 25 the best fitness is 0.019526610644257744']
# ['At iteration 26 the best fitness is 0.019526610644257744']
# ['At iteration 27 the best fitness is 0.019526610644257744']
# ['At iteration 28 the best fitness is 0.019526610644257744']
# ['At iteration 29 the best fitness is 0.019526610644257744']
#       Selected: 158/595 (26.6%), Fitness: 0.0195, Time: 679.0s
#       Modality: D=22%, S=35%, Sk=27%, V=25%
#     Test Acc: 96.30%, F1: 95.83%, Features: 158/595 (26.6%), Model: 0.406MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.030787114845938417']
# ['At iteration 2 the best fitness is 0.030787114845938417']
# ['At iteration 3 the best fitness is 0.030787114845938417']
# ['At iteration 4 the best fitness is 0.030787114845938417']
# ['At iteration 5 the best fitness is 0.025462184873949578']
# ['At iteration 6 the best fitness is 0.025462184873949578']
# ['At iteration 7 the best fitness is 0.025462184873949578']
# ['At iteration 8 the best fitness is 0.025462184873949578']
# ['At iteration 9 the best fitness is 0.025462184873949578']
# ['At iteration 10 the best fitness is 0.025462184873949578']
# ['At iteration 11 the best fitness is 0.025462184873949578']
# ['At iteration 12 the best fitness is 0.025462184873949578']
# ['At iteration 13 the best fitness is 0.025462184873949578']
# ['At iteration 14 the best fitness is 0.025462184873949578']
# ['At iteration 15 the best fitness is 0.025462184873949578']
# ['At iteration 16 the best fitness is 0.025462184873949578']
# ['At iteration 17 the best fitness is 0.025462184873949578']
# ['At iteration 18 the best fitness is 0.025462184873949578']
# ['At iteration 19 the best fitness is 0.025462184873949578']
# ['At iteration 20 the best fitness is 0.02504201680672269']
# ['At iteration 21 the best fitness is 0.02504201680672269']
# ['At iteration 22 the best fitness is 0.02504201680672269']
# ['At iteration 23 the best fitness is 0.02504201680672269']
# ['At iteration 24 the best fitness is 0.02504201680672269']
# ['At iteration 25 the best fitness is 0.02504201680672269']
# ['At iteration 26 the best fitness is 0.02504201680672269']
# ['At iteration 27 the best fitness is 0.02504201680672269']
# ['At iteration 28 the best fitness is 0.02504201680672269']
# ['At iteration 29 the best fitness is 0.02504201680672269']
#       Selected: 308/595 (51.8%), Fitness: 0.0250, Time: 1870.7s
#       Modality: D=49%, S=56%, Sk=51%, V=52%
#     Test Acc: 88.89%, F1: 87.75%, Features: 308/595 (51.8%), Model: 1.143MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.037456582633053195']
# ['At iteration 1 the best fitness is 0.03112324929971993']
# ['At iteration 2 the best fitness is 0.03112324929971993']
# ['At iteration 3 the best fitness is 0.03070308123249304']
# ['At iteration 4 the best fitness is 0.03070308123249304']
# ['At iteration 5 the best fitness is 0.03070308123249304']
# ['At iteration 6 the best fitness is 0.03070308123249304']
# ['At iteration 7 the best fitness is 0.03070308123249304']
# ['At iteration 8 the best fitness is 0.03070308123249304']
# ['At iteration 9 the best fitness is 0.03070308123249304']
# ['At iteration 10 the best fitness is 0.03070308123249304']
# ['At iteration 11 the best fitness is 0.03070308123249304']
# ['At iteration 12 the best fitness is 0.03070308123249304']
# ['At iteration 13 the best fitness is 0.03070308123249304']
# ['At iteration 14 the best fitness is 0.03070308123249304']
# ['At iteration 15 the best fitness is 0.03070308123249304']
# ['At iteration 16 the best fitness is 0.03070308123249304']
# ['At iteration 17 the best fitness is 0.03070308123249304']
# ['At iteration 18 the best fitness is 0.03070308123249304']
# ['At iteration 19 the best fitness is 0.03070308123249304']
# ['At iteration 20 the best fitness is 0.030450980392156907']
# ['At iteration 21 the best fitness is 0.030450980392156907']
# ['At iteration 22 the best fitness is 0.030450980392156907']
# ['At iteration 23 the best fitness is 0.030450980392156907']
# ['At iteration 24 the best fitness is 0.030450980392156907']
# ['At iteration 25 the best fitness is 0.030450980392156907']
# ['At iteration 26 the best fitness is 0.030450980392156907']
# ['At iteration 27 the best fitness is 0.030450980392156907']
# ['At iteration 28 the best fitness is 0.030450980392156907']
# ['At iteration 29 the best fitness is 0.030450980392156907']
#       Selected: 269/595 (45.2%), Fitness: 0.0305, Time: 723.2s
#       Modality: D=54%, S=57%, Sk=42%, V=45%
#     Test Acc: 90.74%, F1: 90.24%, Features: 269/595 (45.2%), Model: 1.067MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 79.63%, F1: 77.02%, Features: 595/595 (100.0%), Model: 1.703MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 297/595 (49.9%), Time: 3.4s
#     Test Acc: 80.56%, F1: 77.18%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 297/595 (49.9%), Time: 0.5s
#     Test Acc: 78.70%, F1: 75.41%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 297/595 (49.9%), Time: 0.1s
#     Test Acc: 71.30%, F1: 63.20%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.029610644257703125']
# ['At iteration 1 the best fitness is 0.029610644257703125']
# ['At iteration 2 the best fitness is 0.029610644257703125']
# ['At iteration 3 the best fitness is 0.029610644257703125']
# ['At iteration 4 the best fitness is 0.029610644257703125']
# ['At iteration 5 the best fitness is 0.029610644257703125']
# ['At iteration 6 the best fitness is 0.029610644257703125']
# ['At iteration 7 the best fitness is 0.029610644257703125']
# ['At iteration 8 the best fitness is 0.029610644257703125']
# ['At iteration 9 the best fitness is 0.029610644257703125']
# ['At iteration 10 the best fitness is 0.029610644257703125']
# ['At iteration 11 the best fitness is 0.029610644257703125']
# ['At iteration 12 the best fitness is 0.029610644257703125']
# ['At iteration 13 the best fitness is 0.029610644257703125']
# ['At iteration 14 the best fitness is 0.029610644257703125']
# ['At iteration 15 the best fitness is 0.029610644257703125']
# ['At iteration 16 the best fitness is 0.029610644257703125']
# ['At iteration 17 the best fitness is 0.029610644257703125']
# ['At iteration 18 the best fitness is 0.029610644257703125']
# ['At iteration 19 the best fitness is 0.029610644257703125']
# ['At iteration 20 the best fitness is 0.029610644257703125']
# ['At iteration 21 the best fitness is 0.029610644257703125']
# ['At iteration 22 the best fitness is 0.029610644257703125']
# ['At iteration 23 the best fitness is 0.029610644257703125']
# ['At iteration 24 the best fitness is 0.029610644257703125']
# ['At iteration 25 the best fitness is 0.029610644257703125']
# ['At iteration 26 the best fitness is 0.029610644257703125']
# ['At iteration 27 the best fitness is 0.029610644257703125']
# ['At iteration 28 the best fitness is 0.029610644257703125']
# ['At iteration 29 the best fitness is 0.029610644257703125']
#       Selected: 277/595 (46.6%), Fitness: 0.0296, Time: 773.4s
#       Modality: D=38%, S=54%, Sk=48%, V=45%
#     Test Acc: 79.63%, F1: 74.63%, Features: 277/595 (46.6%), Model: 1.082MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.026386554621848742']
# ['At iteration 10 the best fitness is 0.026386554621848742']
# ['At iteration 20 the best fitness is 0.025630252100840335']
#       Selected: 309/595 (51.9%), Fitness: 0.0256, Time: 1522.6s
#       Modality: D=57%, S=56%, Sk=48%, V=54%
#     Test Acc: 80.56%, F1: 77.37%, Features: 309/595 (51.9%), Model: 1.145MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03137535014005606']
# ['At iteration 2 the best fitness is 0.03137535014005606']
# ['At iteration 3 the best fitness is 0.030450980392156907']
# ['At iteration 4 the best fitness is 0.030450980392156907']
# ['At iteration 5 the best fitness is 0.030450980392156907']
# ['At iteration 6 the best fitness is 0.030450980392156907']
# ['At iteration 7 the best fitness is 0.03019887955182077']
# ['At iteration 8 the best fitness is 0.03019887955182077']
# ['At iteration 9 the best fitness is 0.03019887955182077']
# ['At iteration 10 the best fitness is 0.03019887955182077']
# ['At iteration 11 the best fitness is 0.03019887955182077']
# ['At iteration 12 the best fitness is 0.02902240896358548']
# ['At iteration 13 the best fitness is 0.02902240896358548']
# ['At iteration 14 the best fitness is 0.02902240896358548']
# ['At iteration 15 the best fitness is 0.02902240896358548']
# ['At iteration 16 the best fitness is 0.02902240896358548']
# ['At iteration 17 the best fitness is 0.02902240896358548']
# ['At iteration 18 the best fitness is 0.024117647058823532']
# ['At iteration 19 the best fitness is 0.024117647058823532']
# ['At iteration 20 the best fitness is 0.024117647058823532']
# ['At iteration 21 the best fitness is 0.024117647058823532']
# ['At iteration 22 the best fitness is 0.024117647058823532']
# ['At iteration 23 the best fitness is 0.024117647058823532']
# ['At iteration 24 the best fitness is 0.024117647058823532']
# ['At iteration 25 the best fitness is 0.024117647058823532']
# ['At iteration 26 the best fitness is 0.024117647058823532']
# ['At iteration 27 the best fitness is 0.024117647058823532']
# ['At iteration 28 the best fitness is 0.024117647058823532']
# ['At iteration 29 the best fitness is 0.022605042016806725']
# ['At iteration 30 the best fitness is 0.022605042016806725']
#       Selected: 280/595 (47.1%), Fitness: 0.0226, Time: 773.7s
#       Modality: D=51%, S=65%, Sk=42%, V=48%
#     Test Acc: 79.63%, F1: 75.90%, Features: 280/595 (47.1%), Model: 1.088MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03028291316526615']
# ['At iteration 1 the best fitness is 0.03196358543417371']
# ['At iteration 2 the best fitness is 0.03028291316526615']
# ['At iteration 3 the best fitness is 0.035439775910364124']
# ['At iteration 4 the best fitness is 0.030114845938375392']
# ['At iteration 5 the best fitness is 0.029946778711484635']
# ['At iteration 6 the best fitness is 0.0289383753501401']
# ['At iteration 7 the best fitness is 0.029610644257703125']
# ['At iteration 8 the best fitness is 0.029610644257703125']
# ['At iteration 9 the best fitness is 0.02319327731092437']
# ['At iteration 10 the best fitness is 0.02927450980392161']
# ['At iteration 11 the best fitness is 0.02927450980392161']
# ['At iteration 12 the best fitness is 0.02935854341736699']
# ['At iteration 13 the best fitness is 0.023025210084033614']
# ['At iteration 14 the best fitness is 0.02927450980392161']
# ['At iteration 15 the best fitness is 0.029442577030812368']
# ['At iteration 16 the best fitness is 0.029442577030812368']
# ['At iteration 17 the best fitness is 0.02935854341736699']
# ['At iteration 18 the best fitness is 0.02927450980392161']
# ['At iteration 19 the best fitness is 0.02927450980392161']
# ['At iteration 20 the best fitness is 0.029442577030812368']
# ['At iteration 21 the best fitness is 0.029442577030812368']
# ['At iteration 22 the best fitness is 0.035691876750700256']
# ['At iteration 23 the best fitness is 0.035691876750700256']
# ['At iteration 24 the best fitness is 0.02935854341736699']
# ['At iteration 25 the best fitness is 0.02935854341736699']
# ['At iteration 26 the best fitness is 0.035691876750700256']
# ['At iteration 27 the best fitness is 0.035691876750700256']
# ['At iteration 28 the best fitness is 0.035691876750700256']
# ['At iteration 29 the best fitness is 0.035691876750700256']
#       Selected: 300/595 (50.4%), Fitness: 0.0357, Time: 749.4s
#       Modality: D=62%, S=44%, Sk=48%, V=52%
#     Test Acc: 76.85%, F1: 71.04%, Features: 300/595 (50.4%), Model: 1.127MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.030535014005602285
# At iteration 2 the best fitness is 0.03594397759103639
# At iteration 3 the best fitness is 0.03535574229691875
# At iteration 4 the best fitness is 0.03535574229691875
# At iteration 5 the best fitness is 0.03594397759103639
# At iteration 6 the best fitness is 0.03019887955182077
# At iteration 7 the best fitness is 0.03019887955182077
# At iteration 8 the best fitness is 0.028686274509803964
# At iteration 9 the best fitness is 0.030114845938375392
# At iteration 10 the best fitness is 0.0289383753501401
# At iteration 11 the best fitness is 0.02885434173669472
# At iteration 12 the best fitness is 0.029862745098039257
# At iteration 13 the best fitness is 0.029442577030812368
# At iteration 14 the best fitness is 0.028770308123249343
# At iteration 15 the best fitness is 0.029442577030812368
# At iteration 16 the best fitness is 0.022184873949579832
# At iteration 17 the best fitness is 0.02885434173669472
# At iteration 18 the best fitness is 0.029694677871148503
# At iteration 19 the best fitness is 0.028770308123249343
# At iteration 20 the best fitness is 0.029106442577030853
# At iteration 21 the best fitness is 0.02935854341736699
# At iteration 22 the best fitness is 0.022689075630252103
# At iteration 23 the best fitness is 0.028182072829131696
# At iteration 24 the best fitness is 0.028686274509803964
# At iteration 25 the best fitness is 0.02692156862745102
# At iteration 26 the best fitness is 0.02860224089635859
# At iteration 27 the best fitness is 0.02860224089635859
# At iteration 28 the best fitness is 0.022268907563025214
# At iteration 29 the best fitness is 0.02835014005602245
# At iteration 30 the best fitness is 0.027341736694677914
#       Selected: 259/595 (43.5%), Fitness: 0.0273, Time: 746.8s
#       Modality: D=46%, S=44%, Sk=44%, V=43%
#     Test Acc: 73.15%, F1: 67.70%, Features: 259/595 (43.5%), Model: 1.047MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.029190476190476232']
# ['At iteration 1 the best fitness is 0.029190476190476232']
# ['At iteration 2 the best fitness is 0.027341736694677914']
# ['At iteration 3 the best fitness is 0.026501400560224132']
# ['At iteration 4 the best fitness is 0.025577030812324975']
# ['At iteration 5 the best fitness is 0.02482072829131657']
# ['At iteration 6 the best fitness is 0.024484593837535054']
# ['At iteration 7 the best fitness is 0.024232492997198922']
# ['At iteration 8 the best fitness is 0.022635854341736737']
# ['At iteration 9 the best fitness is 0.022467787114845983']
# ['At iteration 10 the best fitness is 0.02204761904761909']
# ['At iteration 11 the best fitness is 0.02204761904761909']
# ['At iteration 12 the best fitness is 0.021879551820728333']
# ['At iteration 13 the best fitness is 0.02154341736694682']
# ['At iteration 14 the best fitness is 0.020955182072829173']
# ['At iteration 15 the best fitness is 0.020955182072829173']
# ['At iteration 16 the best fitness is 0.020114845938375394']
# ['At iteration 17 the best fitness is 0.020114845938375394']
# ['At iteration 18 the best fitness is 0.020114845938375394']
# ['At iteration 19 the best fitness is 0.020114845938375394']
# ['At iteration 20 the best fitness is 0.020114845938375394']
# ['At iteration 21 the best fitness is 0.020114845938375394']
# ['At iteration 22 the best fitness is 0.020114845938375394']
# ['At iteration 23 the best fitness is 0.01977871148459388']
# ['At iteration 24 the best fitness is 0.01977871148459388']
# ['At iteration 25 the best fitness is 0.01977871148459388']
# ['At iteration 26 the best fitness is 0.01977871148459388']
# ['At iteration 27 the best fitness is 0.01977871148459388']
# ['At iteration 28 the best fitness is 0.01977871148459388']
# ['At iteration 29 the best fitness is 0.01977871148459388']
#       Selected: 182/595 (30.6%), Fitness: 0.0198, Time: 725.7s
#       Modality: D=27%, S=24%, Sk=31%, V=32%
#     Test Acc: 77.78%, F1: 74.38%, Features: 182/595 (30.6%), Model: 0.535MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.030787114845938417']
# ['At iteration 1 the best fitness is 0.030787114845938417']
# ['At iteration 2 the best fitness is 0.030787114845938417']
# ['At iteration 3 the best fitness is 0.030787114845938417']
# ['At iteration 4 the best fitness is 0.030787114845938417']
# ['At iteration 5 the best fitness is 0.030787114845938417']
# ['At iteration 6 the best fitness is 0.030787114845938417']
# ['At iteration 7 the best fitness is 0.030787114845938417']
# ['At iteration 8 the best fitness is 0.030787114845938417']
# ['At iteration 9 the best fitness is 0.030787114845938417']
# ['At iteration 10 the best fitness is 0.030787114845938417']
# ['At iteration 11 the best fitness is 0.030787114845938417']
# ['At iteration 12 the best fitness is 0.030787114845938417']
# ['At iteration 13 the best fitness is 0.030787114845938417']
# ['At iteration 14 the best fitness is 0.030787114845938417']
# ['At iteration 15 the best fitness is 0.030787114845938417']
# ['At iteration 16 the best fitness is 0.030787114845938417']
# ['At iteration 17 the best fitness is 0.030787114845938417']
# ['At iteration 18 the best fitness is 0.030787114845938417']
# ['At iteration 19 the best fitness is 0.030787114845938417']
# ['At iteration 20 the best fitness is 0.030787114845938417']
# ['At iteration 21 the best fitness is 0.030787114845938417']
# ['At iteration 22 the best fitness is 0.030787114845938417']
# ['At iteration 23 the best fitness is 0.030787114845938417']
# ['At iteration 24 the best fitness is 0.030787114845938417']
# ['At iteration 25 the best fitness is 0.030787114845938417']
# ['At iteration 26 the best fitness is 0.030787114845938417']
# ['At iteration 27 the best fitness is 0.030787114845938417']
# ['At iteration 28 the best fitness is 0.030787114845938417']
# ['At iteration 29 the best fitness is 0.030787114845938417']
#       Selected: 283/595 (47.6%), Fitness: 0.0308, Time: 940.3s
#       Modality: D=46%, S=52%, Sk=47%, V=48%
#     Test Acc: 74.07%, F1: 68.02%, Features: 283/595 (47.6%), Model: 1.094MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.030787114845938417']
# ['At iteration 1 the best fitness is 0.030787114845938417']
# ['At iteration 2 the best fitness is 0.030787114845938417']
# ['At iteration 3 the best fitness is 0.030450980392156907']
# ['At iteration 4 the best fitness is 0.030450980392156907']
# ['At iteration 5 the best fitness is 0.02369747899159664']
# ['At iteration 6 the best fitness is 0.02369747899159664']
# ['At iteration 7 the best fitness is 0.02369747899159664']
# ['At iteration 8 the best fitness is 0.02369747899159664']
# ['At iteration 9 the best fitness is 0.02369747899159664']
# ['At iteration 10 the best fitness is 0.02369747899159664']
# ['At iteration 11 the best fitness is 0.02369747899159664']
# ['At iteration 12 the best fitness is 0.02369747899159664']
# ['At iteration 13 the best fitness is 0.02369747899159664']
# ['At iteration 14 the best fitness is 0.02369747899159664']
# ['At iteration 15 the best fitness is 0.02369747899159664']
# ['At iteration 16 the best fitness is 0.02369747899159664']
# ['At iteration 17 the best fitness is 0.02369747899159664']
# ['At iteration 18 the best fitness is 0.02369747899159664']
# ['At iteration 19 the best fitness is 0.02369747899159664']
# ['At iteration 20 the best fitness is 0.02369747899159664']
# ['At iteration 21 the best fitness is 0.02369747899159664']
# ['At iteration 22 the best fitness is 0.02369747899159664']
# ['At iteration 23 the best fitness is 0.02369747899159664']
# ['At iteration 24 the best fitness is 0.02369747899159664']
# ['At iteration 25 the best fitness is 0.02369747899159664']
# ['At iteration 26 the best fitness is 0.02369747899159664']
# ['At iteration 27 the best fitness is 0.02369747899159664']
# ['At iteration 28 the best fitness is 0.02369747899159664']
# ['At iteration 29 the best fitness is 0.02369747899159664']
#       Selected: 278/595 (46.7%), Fitness: 0.0237, Time: 770.9s
#       Modality: D=43%, S=50%, Sk=46%, V=47%
#     Test Acc: 79.63%, F1: 74.90%, Features: 278/595 (46.7%), Model: 1.084MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.029862745098039257']
# ['At iteration 2 the best fitness is 0.029862745098039257']
# ['At iteration 3 the best fitness is 0.029862745098039257']
# ['At iteration 4 the best fitness is 0.023445378151260507']
# ['At iteration 5 the best fitness is 0.023445378151260507']
# ['At iteration 6 the best fitness is 0.023445378151260507']
# ['At iteration 7 the best fitness is 0.023445378151260507']
# ['At iteration 8 the best fitness is 0.023445378151260507']
# ['At iteration 9 the best fitness is 0.023445378151260507']
# ['At iteration 10 the best fitness is 0.023445378151260507']
# ['At iteration 11 the best fitness is 0.023445378151260507']
# ['At iteration 12 the best fitness is 0.023445378151260507']
# ['At iteration 13 the best fitness is 0.023445378151260507']
# ['At iteration 14 the best fitness is 0.023445378151260507']
# ['At iteration 15 the best fitness is 0.023445378151260507']
# ['At iteration 16 the best fitness is 0.023445378151260507']
# ['At iteration 17 the best fitness is 0.023445378151260507']
# ['At iteration 18 the best fitness is 0.023445378151260507']
# ['At iteration 19 the best fitness is 0.023445378151260507']
# ['At iteration 20 the best fitness is 0.023445378151260507']
# ['At iteration 21 the best fitness is 0.02336134453781513']
# ['At iteration 22 the best fitness is 0.02336134453781513']
# ['At iteration 23 the best fitness is 0.02336134453781513']
# ['At iteration 24 the best fitness is 0.02336134453781513']
# ['At iteration 25 the best fitness is 0.023025210084033614']
# ['At iteration 26 the best fitness is 0.023025210084033614']
# ['At iteration 27 the best fitness is 0.023025210084033614']
# ['At iteration 28 the best fitness is 0.023025210084033614']
# ['At iteration 29 the best fitness is 0.023025210084033614']
#       Selected: 286/595 (48.1%), Fitness: 0.0230, Time: 723.3s
#       Modality: D=57%, S=50%, Sk=47%, V=47%
#     Test Acc: 77.78%, F1: 74.49%, Features: 286/595 (48.1%), Model: 1.100MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03644817927170866']
# ['At iteration 2 the best fitness is 0.03019887955182077']
# ['At iteration 3 the best fitness is 0.030114845938375392']
# ['At iteration 4 the best fitness is 0.029778711484593882']
# ['At iteration 5 the best fitness is 0.029610644257703125']
# ['At iteration 6 the best fitness is 0.024873949579831935']
# ['At iteration 7 the best fitness is 0.024873949579831935']
# ['At iteration 8 the best fitness is 0.024873949579831935']
# ['At iteration 9 the best fitness is 0.024873949579831935']
# ['At iteration 10 the best fitness is 0.02327731092436975']
# ['At iteration 11 the best fitness is 0.02327731092436975']
# ['At iteration 12 the best fitness is 0.02327731092436975']
# ['At iteration 13 the best fitness is 0.02327731092436975']
# ['At iteration 14 the best fitness is 0.02327731092436975']
# ...
# ['At iteration 17 the best fitness is 0.025271708683473365']
# ['At iteration 18 the best fitness is 0.025271708683473365']
# ['At iteration 19 the best fitness is 0.025271708683473365']
# ['At iteration 20 the best fitness is 0.025271708683473365']
# ['At iteration 21 the best fitness is 0.025271708683473365']
# ['At iteration 22 the best fitness is 0.025271708683473365']
# ['At iteration 23 the best fitness is 0.025271708683473365']
# ['At iteration 24 the best fitness is 0.025271708683473365']
# ['At iteration 25 the best fitness is 0.025271708683473365']
# ['At iteration 26 the best fitness is 0.025271708683473365']
# ['At iteration 27 the best fitness is 0.025187675070027987']
# ['At iteration 28 the best fitness is 0.025187675070027987']
# ['At iteration 29 the best fitness is 0.025187675070027987']
#       Selected: 151/595 (25.4%), Fitness: 0.0252, Time: 953.0s
#       Modality: D=22%, S=24%, Sk=22%, V=29%
#     Test Acc: 84.11%, F1: 83.86%, Features: 151/595 (25.4%), Model: 0.372MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.030030812324930014']
# ['At iteration 1 the best fitness is 0.025378151260504203']
# ['At iteration 2 the best fitness is 0.025378151260504203']
# ['At iteration 3 the best fitness is 0.025378151260504203']
# ['At iteration 4 the best fitness is 0.024033613445378153']
# ['At iteration 5 the best fitness is 0.024033613445378153']
# ['At iteration 6 the best fitness is 0.024033613445378153']
# ['At iteration 7 the best fitness is 0.024033613445378153']
# ['At iteration 8 the best fitness is 0.024033613445378153']
# ['At iteration 9 the best fitness is 0.024033613445378153']
# ['At iteration 10 the best fitness is 0.024033613445378153']
# ['At iteration 11 the best fitness is 0.024033613445378153']
# ['At iteration 12 the best fitness is 0.024033613445378153']
# ['At iteration 13 the best fitness is 0.024033613445378153']
# ['At iteration 14 the best fitness is 0.024033613445378153']
# ['At iteration 15 the best fitness is 0.024033613445378153']
# ['At iteration 16 the best fitness is 0.02361344537815126']
# ['At iteration 17 the best fitness is 0.02361344537815126']
# ['At iteration 18 the best fitness is 0.02336134453781513']
# ['At iteration 19 the best fitness is 0.02336134453781513']
# ['At iteration 20 the best fitness is 0.02327731092436975']
# ['At iteration 21 the best fitness is 0.02327731092436975']
# ['At iteration 22 the best fitness is 0.02327731092436975']
# ['At iteration 23 the best fitness is 0.022605042016806725']
# ['At iteration 24 the best fitness is 0.022605042016806725']
# ['At iteration 25 the best fitness is 0.022605042016806725']
# ['At iteration 26 the best fitness is 0.022605042016806725']
# ['At iteration 27 the best fitness is 0.022605042016806725']
# ['At iteration 28 the best fitness is 0.022605042016806725']
# ['At iteration 29 the best fitness is 0.022605042016806725']
#       Selected: 276/595 (46.4%), Fitness: 0.0226, Time: 783.6s
#       Modality: D=49%, S=54%, Sk=48%, V=44%
#     Test Acc: 92.52%, F1: 90.81%, Features: 276/595 (46.4%), Model: 1.080MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02453781512605042']
# ['At iteration 2 the best fitness is 0.02453781512605042']
# ['At iteration 3 the best fitness is 0.02453781512605042']
# ['At iteration 4 the best fitness is 0.02453781512605042']
# ['At iteration 5 the best fitness is 0.02453781512605042']
# ['At iteration 6 the best fitness is 0.02453781512605042']
# ['At iteration 7 the best fitness is 0.02453781512605042']
# ['At iteration 8 the best fitness is 0.023949579831932775']
# ['At iteration 9 the best fitness is 0.023781512605042018']
# ['At iteration 10 the best fitness is 0.023781512605042018']
# ['At iteration 11 the best fitness is 0.023781512605042018']
# ['At iteration 12 the best fitness is 0.023781512605042018']
# ['At iteration 13 the best fitness is 0.023781512605042018']
# ['At iteration 14 the best fitness is 0.023781512605042018']
# ['At iteration 15 the best fitness is 0.023781512605042018']
# ['At iteration 16 the best fitness is 0.023781512605042018']
# ['At iteration 17 the best fitness is 0.023781512605042018']
# ['At iteration 18 the best fitness is 0.023781512605042018']
# ['At iteration 19 the best fitness is 0.023781512605042018']
# ['At iteration 20 the best fitness is 0.023781512605042018']
# ['At iteration 21 the best fitness is 0.023781512605042018']
# ['At iteration 22 the best fitness is 0.023781512605042018']
# ['At iteration 23 the best fitness is 0.023781512605042018']
# ['At iteration 24 the best fitness is 0.023781512605042018']
# ['At iteration 25 the best fitness is 0.023781512605042018']
# ['At iteration 26 the best fitness is 0.023781512605042018']
# ['At iteration 27 the best fitness is 0.023781512605042018']
# ['At iteration 28 the best fitness is 0.023781512605042018']
# ['At iteration 29 the best fitness is 0.023781512605042018']
#       Selected: 288/595 (48.4%), Fitness: 0.0238, Time: 735.6s
#       Modality: D=43%, S=46%, Sk=48%, V=50%
#     Test Acc: 87.85%, F1: 85.63%, Features: 288/595 (48.4%), Model: 1.104MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02504201680672269']
# ['At iteration 2 the best fitness is 0.02504201680672269']
# ['At iteration 3 the best fitness is 0.02504201680672269']
# ['At iteration 4 the best fitness is 0.02453781512605042']
# ['At iteration 5 the best fitness is 0.02453781512605042']
# ['At iteration 6 the best fitness is 0.02453781512605042']
# ['At iteration 7 the best fitness is 0.02453781512605042']
# ['At iteration 8 the best fitness is 0.024285714285714285']
# ['At iteration 9 the best fitness is 0.024285714285714285']
# ['At iteration 10 the best fitness is 0.024285714285714285']
# ['At iteration 11 the best fitness is 0.023949579831932775']
# ['At iteration 12 the best fitness is 0.023949579831932775']
# ['At iteration 13 the best fitness is 0.02369747899159664']
# ['At iteration 14 the best fitness is 0.02369747899159664']
# ['At iteration 15 the best fitness is 0.02336134453781513']
# ['At iteration 16 the best fitness is 0.02336134453781513']
# ['At iteration 17 the best fitness is 0.02336134453781513']
# ['At iteration 18 the best fitness is 0.02336134453781513']
# ['At iteration 19 the best fitness is 0.02336134453781513']
# ['At iteration 20 the best fitness is 0.02336134453781513']
# ['At iteration 21 the best fitness is 0.02336134453781513']
# ['At iteration 22 the best fitness is 0.02336134453781513']
# ['At iteration 23 the best fitness is 0.02336134453781513']
# ['At iteration 24 the best fitness is 0.02336134453781513']
# ['At iteration 25 the best fitness is 0.023109243697478993']
# ['At iteration 26 the best fitness is 0.022857142857142857']
# ['At iteration 27 the best fitness is 0.022857142857142857']
# ['At iteration 28 the best fitness is 0.022857142857142857']
# ['At iteration 29 the best fitness is 0.022857142857142857']
# ['At iteration 30 the best fitness is 0.022857142857142857']
#       Selected: 287/595 (48.2%), Fitness: 0.0229, Time: 760.1s
#       Modality: D=51%, S=46%, Sk=45%, V=52%
#     Test Acc: 94.39%, F1: 93.11%, Features: 287/595 (48.2%), Model: 1.102MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024957983193277314']
# ['At iteration 2 the best fitness is 0.024957983193277314']
# ['At iteration 3 the best fitness is 0.024957983193277314']
# ['At iteration 4 the best fitness is 0.024957983193277314']
# ['At iteration 5 the best fitness is 0.024957983193277314']
# ['At iteration 6 the best fitness is 0.0246218487394958']
# ['At iteration 7 the best fitness is 0.024369747899159664']
# ['At iteration 8 the best fitness is 0.024369747899159664']
# ['At iteration 9 the best fitness is 0.023529411764705882']
# ['At iteration 10 the best fitness is 0.023529411764705882']
# ['At iteration 11 the best fitness is 0.023529411764705882']
# ['At iteration 12 the best fitness is 0.022857142857142857']
# ['At iteration 13 the best fitness is 0.022605042016806725']
# ['At iteration 14 the best fitness is 0.022605042016806725']
# ['At iteration 15 the best fitness is 0.022521008403361346']
# ['At iteration 16 the best fitness is 0.022100840336134454']
# ['At iteration 17 the best fitness is 0.02184873949579832']
# ['At iteration 18 the best fitness is 0.02184873949579832']
# ['At iteration 19 the best fitness is 0.02184873949579832']
# ['At iteration 20 the best fitness is 0.02184873949579832']
# ['At iteration 21 the best fitness is 0.02184873949579832']
# ['At iteration 22 the best fitness is 0.02184873949579832']
# ['At iteration 23 the best fitness is 0.02184873949579832']
# ['At iteration 24 the best fitness is 0.021764705882352943']
# ['At iteration 25 the best fitness is 0.021764705882352943']
# ['At iteration 26 the best fitness is 0.021764705882352943']
# ['At iteration 27 the best fitness is 0.021764705882352943']
# ['At iteration 28 the best fitness is 0.021764705882352943']
# ['At iteration 29 the best fitness is 0.021596638655462186']
# ['At iteration 30 the best fitness is 0.021596638655462186']
#       Selected: 272/595 (45.7%), Fitness: 0.0216, Time: 753.5s
#       Modality: D=46%, S=59%, Sk=40%, V=48%
#     Test Acc: 91.59%, F1: 90.33%, Features: 272/595 (45.7%), Model: 1.072MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0316274509803922']
# ['At iteration 1 the best fitness is 0.029190476190476232']
# ['At iteration 2 the best fitness is 0.026165266106442618']
# ['At iteration 3 the best fitness is 0.026165266106442618']
# ['At iteration 4 the best fitness is 0.026165266106442618']
# ['At iteration 5 the best fitness is 0.0243165266106443']
# ['At iteration 6 the best fitness is 0.0243165266106443']
# ['At iteration 7 the best fitness is 0.02213165266106447']
# ['At iteration 8 the best fitness is 0.02213165266106447']
# ['At iteration 9 the best fitness is 0.02213165266106447']
# ['At iteration 10 the best fitness is 0.01919047619047623']
# ['At iteration 11 the best fitness is 0.01919047619047623']
# ['At iteration 12 the best fitness is 0.01919047619047623']
# ['At iteration 13 the best fitness is 0.018182072829131694']
# ['At iteration 14 the best fitness is 0.018182072829131694']
# ['At iteration 15 the best fitness is 0.018182072829131694']
# ['At iteration 16 the best fitness is 0.018182072829131694']
# ['At iteration 17 the best fitness is 0.016333333333333377']
# ['At iteration 18 the best fitness is 0.015997198879551863']
# ['At iteration 19 the best fitness is 0.015997198879551863']
# ['At iteration 20 the best fitness is 0.015997198879551863']
# ['At iteration 21 the best fitness is 0.015997198879551863']
# ['At iteration 22 the best fitness is 0.015997198879551863']
# ['At iteration 23 the best fitness is 0.015997198879551863']
# ['At iteration 24 the best fitness is 0.015997198879551863']
# ['At iteration 25 the best fitness is 0.015997198879551863']
# ['At iteration 26 the best fitness is 0.015997198879551863']
# ['At iteration 27 the best fitness is 0.015997198879551863']
# ['At iteration 28 the best fitness is 0.015997198879551863']
# ['At iteration 29 the best fitness is 0.015997198879551863']
#       Selected: 123/595 (20.7%), Fitness: 0.0160, Time: 701.6s
#       Modality: D=24%, S=30%, Sk=18%, V=21%
#     Test Acc: 93.46%, F1: 93.38%, Features: 123/595 (20.7%), Model: 0.251MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023949579831932775']
# ['At iteration 2 the best fitness is 0.023865546218487396']
# ['At iteration 3 the best fitness is 0.023865546218487396']
# ['At iteration 4 the best fitness is 0.023865546218487396']
# ['At iteration 5 the best fitness is 0.023865546218487396']
# ['At iteration 6 the best fitness is 0.023865546218487396']
# ['At iteration 7 the best fitness is 0.023865546218487396']
# ['At iteration 8 the best fitness is 0.023865546218487396']
# ['At iteration 9 the best fitness is 0.02361344537815126']
# ['At iteration 10 the best fitness is 0.02319327731092437']
# ['At iteration 11 the best fitness is 0.02319327731092437']
# ['At iteration 12 the best fitness is 0.02319327731092437']
# ['At iteration 13 the best fitness is 0.02319327731092437']
# ['At iteration 14 the best fitness is 0.02319327731092437']
# ['At iteration 15 the best fitness is 0.023109243697478993']
# ['At iteration 16 the best fitness is 0.023025210084033614']
# ['At iteration 17 the best fitness is 0.023025210084033614']
# ['At iteration 18 the best fitness is 0.023025210084033614']
# ['At iteration 19 the best fitness is 0.023025210084033614']
# ['At iteration 20 the best fitness is 0.023025210084033614']
# ['At iteration 21 the best fitness is 0.023025210084033614']
# ['At iteration 22 the best fitness is 0.023025210084033614']
# ['At iteration 23 the best fitness is 0.023025210084033614']
# ['At iteration 24 the best fitness is 0.023025210084033614']
# ['At iteration 25 the best fitness is 0.023025210084033614']
# ['At iteration 26 the best fitness is 0.023025210084033614']
# ['At iteration 27 the best fitness is 0.023025210084033614']
# ['At iteration 28 the best fitness is 0.023025210084033614']
# ['At iteration 29 the best fitness is 0.023025210084033614']
#       Selected: 279/595 (46.9%), Fitness: 0.0230, Time: 1896.6s
#       Modality: D=46%, S=46%, Sk=48%, V=47%
#     Test Acc: 89.72%, F1: 88.56%, Features: 279/595 (46.9%), Model: 1.086MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.036868347338935556']
# ['At iteration 1 the best fitness is 0.029075630252100845']
# ['At iteration 2 the best fitness is 0.029075630252100845']
# ['At iteration 3 the best fitness is 0.029075630252100845']
# ['At iteration 4 the best fitness is 0.029075630252100845']
# ['At iteration 5 the best fitness is 0.029075630252100845']
# ['At iteration 6 the best fitness is 0.029075630252100845']
# ['At iteration 7 the best fitness is 0.029075630252100845']
# ['At iteration 8 the best fitness is 0.029075630252100845']
# ['At iteration 9 the best fitness is 0.029075630252100845']
# ['At iteration 10 the best fitness is 0.029075630252100845']
# ['At iteration 11 the best fitness is 0.029075630252100845']
# ['At iteration 12 the best fitness is 0.029075630252100845']
# ['At iteration 13 the best fitness is 0.029075630252100845']
# ['At iteration 14 the best fitness is 0.029075630252100845']
# ['At iteration 15 the best fitness is 0.029075630252100845']
# ['At iteration 16 the best fitness is 0.029075630252100845']
# ['At iteration 17 the best fitness is 0.029075630252100845']
# ['At iteration 18 the best fitness is 0.029075630252100845']
# ['At iteration 19 the best fitness is 0.029075630252100845']
# ['At iteration 20 the best fitness is 0.029075630252100845']
# ['At iteration 21 the best fitness is 0.029075630252100845']
# ['At iteration 22 the best fitness is 0.029075630252100845']
# ['At iteration 23 the best fitness is 0.029075630252100845']
# ['At iteration 24 the best fitness is 0.029075630252100845']
# ['At iteration 25 the best fitness is 0.029075630252100845']
# ['At iteration 26 the best fitness is 0.029075630252100845']
# ['At iteration 27 the best fitness is 0.029075630252100845']
# ['At iteration 28 the best fitness is 0.029075630252100845']
# ['At iteration 29 the best fitness is 0.029075630252100845']
#       Selected: 337/595 (56.6%), Fitness: 0.0291, Time: 639.0s
#       Modality: D=57%, S=54%, Sk=57%, V=57%
#     Test Acc: 92.52%, F1: 90.74%, Features: 337/595 (56.6%), Model: 1.199MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_10_noise/all_results_per_fold.csv
# Shape: (144, 28)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            89.8148           99.3333       87.9799          87.9799              88.4774           89.8148                595             595                100.000       0.0000          8.6389          8.6389        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 1      baseline     2            79.6296          100.0000       77.0242          77.0242              80.6061           79.6296                595             595                100.000       0.0000          9.2510          9.2511        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 2      baseline     3            80.5556          100.0000       76.1825          76.1825              74.2921           80.5556                595             595                100.000       0.0000         10.1806         10.1806        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 3      baseline     4            85.1852           99.3333       83.3520          83.3520              86.4262           85.1852                595             595                100.000       0.0000         10.2616         10.2616        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 4      baseline     5            90.7407           98.6667       89.2181          89.2181              90.1543           90.7407                595             595                100.000       0.0000         10.1629         10.1629        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 5      baseline     6            80.3738          100.0000       78.7882          78.5900              82.5279           80.5556                595             595                100.000       0.0000         10.1609         10.1609        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 6      baseline     7            91.5888          100.0000       91.3580          91.2773              92.8395           91.6667                595             595                100.000       0.0000          9.9789          9.9789        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 7      baseline     8            91.5888          100.0000       90.4519          90.3627              91.9106           91.6667                595             595                100.000       0.0000         10.0395         10.0395        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 8   mutual_info     1            92.5926          100.0000       90.1235          90.1235              88.8889           92.5926                297             595                 49.916       3.4095         11.2706         14.6802        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               25.9259               14                  7.0833                 17             100.0000             264
# 9   mutual_info     2            80.5556          100.0000       77.1760          77.1760              79.7354           80.5556                297             595                 49.916       3.3690         12.2251         15.5941        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               24.0741               13                  7.5000                 18             100.0000             264
# 10  mutual_info     3            81.4815          100.0000       78.0464          78.0464              80.7707           81.4815                297             595                 49.916       3.3477         12.3879         15.7357        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               25.9259               14                  7.0833                 17             100.0000             264
# 11  mutual_info     4            73.1481          100.0000       69.9155          69.9155              71.9526           73.1481                297             595                 49.916       3.3888         12.2576         15.6465        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               25.9259               14                  7.0833                 17             100.0000             264
# 12  mutual_info     5            84.2593          100.0000       79.7942          79.7942              77.5309           84.2593                297             595                 49.916       3.3612         12.2397         15.6010        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               25.9259               14                  7.0833                 17             100.0000             264
# 13  mutual_info     6            69.1589          100.0000       64.9774          64.6501              63.0091           69.4444                297             595                 49.916       3.4278         12.3144         15.7423        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               25.9259               14                  7.0833                 17             100.0000             264
# 14  mutual_info     7            76.6355          100.0000       71.4296          71.1626              71.6226           76.8519                297             595                 49.916       3.4033         12.4742         15.8776        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               20.3704               11                  8.3333                 20             100.0000             264
# 15  mutual_info     8            91.5888          100.0000       89.8453          89.9840              91.3757           91.6667                297             595                 49.916       3.3630         12.5167         15.8798        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               22.2222               12                  7.9167                 19             100.0000             264
# 16          rfe     1            90.7407          100.0000       89.0770          89.0770              90.6173           90.7407                297             595                 49.916       0.5517         12.3313         12.8832        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              13.5135               5               98.1481               53                 26.6667                 64              66.2879             175
# 17          rfe     2            78.7037          100.0000       75.4068          75.4068              78.5597           78.7037                297             595                 49.916       0.5439         12.4317         12.9757        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              13.5135               5               96.2963               52                 25.4167                 61              67.8030             179
# 18          rfe     3            85.1852          100.0000       82.7025          82.7025              86.3262           85.1852                297             595                 49.916       0.5405         11.3550         11.8957        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              10.8108               4               94.4444               51                 27.0833                 65              67.0455             177
# 19          rfe     4            84.2593          100.0000       82.0811          82.0811              84.2048           84.2593                297             595                 49.916       0.5443         12.2450         12.7894        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              10.8108               4              100.0000               54                 27.0833                 65              65.9091             174

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              86.18              5.37              84.29              6.27                  595.00                      100.00              0.00                 9.83                 9.83           444955.0                  1.70                        0.00               27.79
# mutual_info              81.18              8.27              77.66              9.01                  297.00                       49.92              3.38                12.21                15.59           292379.0                  1.12                       50.08               24.00
#         rfe              86.41              6.47              84.17              7.44                  297.00                       49.92              0.54                12.22                12.77           292379.0                  1.12                       50.08               24.00
#       lasso              79.09              9.33              76.02             11.25                  297.00                       49.92              0.08                12.16                12.24           292379.0                  1.12                       50.08               24.00
#    meta_BAT              83.17              6.57              80.55              7.69                  291.88                       49.05            774.57                12.28               786.85           289755.0                  1.11                       50.95               23.94
#     meta_CS              82.33              6.48              79.56              7.53                  288.50                       48.49           1523.79                12.30              1536.09           288027.0                  1.10                       51.51               23.90
#     meta_DE              82.69              6.65              80.05              7.81                  274.88                       46.20            774.77                12.29               787.06           280466.0                  1.08                       53.80               23.72
#    meta_FFA              83.61              9.28              81.44             10.66                  288.38                       48.47            751.35                12.40               763.75           287963.0                  1.10                       51.53               23.90
#     meta_GA              83.62              6.89              80.84              7.98                  284.12                       47.75            749.86                12.26               762.12           285787.0                  1.10                       52.25               23.85
#    meta_GWO              80.01              8.57              77.33              8.78                  209.12                       35.15            736.59                12.01               748.61           184361.0                  0.71                       64.85               21.53
#    meta_HHO              82.22              7.26              80.00              9.08                  213.12                       35.82            977.27                12.13               989.40           188199.0                  0.72                       64.18               21.61
#   meta_JAYA              82.58              6.79              79.99              7.74                  287.75                       48.36            775.72                12.29               788.01           287643.0                  1.10                       51.64               23.89
#    meta_MFO              82.81              5.49              80.32              6.20                  283.50                       47.65            727.52                12.37               739.89           285467.0                  1.09                       52.35               23.84
#    meta_MVO              82.10              9.52              79.92             10.92                  273.25                       45.92            750.96                12.34               763.31           279441.0                  1.07                       54.08               23.70
#    meta_PSO              85.95              5.21              83.73              6.15                  273.12                       45.90            748.39                12.05               760.44           277079.0                  1.06                       54.10               23.65
#    meta_SCA              81.76              9.15              79.12             10.81                  141.62                       23.80            693.92                11.91               705.84            88483.0                  0.34                       76.20               19.32
#    meta_SSA              82.00              5.95              79.74              6.78                  287.62                       48.34           1872.22                12.11              1884.33           287579.0                  1.10                       51.66               23.89
#    meta_WOA              82.11              8.34              79.59              9.64                  276.62                       46.49            698.87                11.64               710.50           265144.0                  1.02                       53.51               23.38

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 81.18% vs Baseline: 86.18%
#   Paired t-test: t=-2.0169, p=0.0835
#   Wilcoxon test: W=6.0000, p=0.2031
#   -> worse, Not significant
#
# RFE vs BASELINE:
#   Method: 86.41% vs Baseline: 86.18%
#   Paired t-test: t=0.1839, p=0.8593
#   Wilcoxon test: W=16.5000, p=0.8672
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 79.09% vs Baseline: 86.18%
#   Paired t-test: t=-2.7074, p=0.0303
#   Wilcoxon test: W=3.0000, p=0.0391
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 83.17% vs Baseline: 86.18%
#   Paired t-test: t=-1.6221, p=0.1488
#   Wilcoxon test: W=3.0000, p=0.1562
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 82.33% vs Baseline: 86.18%
#   Paired t-test: t=-2.3437, p=0.0516
#   Wilcoxon test: W=1.0000, p=0.0312
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 82.69% vs Baseline: 86.18%
#   Paired t-test: t=-2.0236, p=0.0827
#   Wilcoxon test: W=3.0000, p=0.0625
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 83.61% vs Baseline: 86.18%
#   Paired t-test: t=-1.0462, p=0.3302
#   Wilcoxon test: W=12.0000, p=0.4609
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 83.62% vs Baseline: 86.18%
#   Paired t-test: t=-1.6307, p=0.1470
#   Wilcoxon test: W=8.5000, p=0.2109
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 80.01% vs Baseline: 86.18%
#   Paired t-test: t=-2.1982, p=0.0639
#   Wilcoxon test: W=4.5000, p=0.0625
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 82.22% vs Baseline: 86.18%
#   Paired t-test: t=-2.3007, p=0.0549
#   Wilcoxon test: W=5.0000, p=0.0703
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 82.58% vs Baseline: 86.18%
#   Paired t-test: t=-1.9306, p=0.0948
#   Wilcoxon test: W=3.0000, p=0.1562
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 82.81% vs Baseline: 86.18%
#   Paired t-test: t=-2.4535, p=0.0439
#   Wilcoxon test: W=0.0000, p=0.0312
#   -> worse, Significant
#
# META_MVO vs BASELINE:
#   Method: 82.10% vs Baseline: 86.18%
#   Paired t-test: t=-1.6112, p=0.1512
#   Wilcoxon test: W=3.0000, p=0.1562
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 85.95% vs Baseline: 86.18%
#   Paired t-test: t=-0.1610, p=0.8766
#   Wilcoxon test: W=12.0000, p=0.8125
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 81.76% vs Baseline: 86.18%
#   Paired t-test: t=-1.8947, p=0.1000
#   Wilcoxon test: W=5.5000, p=0.0859
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 82.00% vs Baseline: 86.18%
#   Paired t-test: t=-3.9006, p=0.0059
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_WOA vs BASELINE:
#   Method: 82.11% vs Baseline: 86.18%
#   Paired t-test: t=-2.2268, p=0.0613
#   Wilcoxon test: W=6.0000, p=0.1094
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_10_noise
#
# Per-method folders:
#   results_10_noise/baseline/ (16 files)
#   results_10_noise/mutual_info/ (16 files)
#   results_10_noise/rfe/ (16 files)
#   results_10_noise/lasso/ (16 files)
#   results_10_noise/meta_BAT/ (16 files)
#   results_10_noise/meta_CS/ (16 files)
#   results_10_noise/meta_DE/ (16 files)
#   results_10_noise/meta_FFA/ (16 files)
#   results_10_noise/meta_GA/ (16 files)
#   results_10_noise/meta_GWO/ (16 files)
#   results_10_noise/meta_HHO/ (16 files)
#   results_10_noise/meta_JAYA/ (16 files)
#   results_10_noise/meta_MFO/ (16 files)
#   results_10_noise/meta_MVO/ (16 files)
#   results_10_noise/meta_PSO/ (16 files)
#   results_10_noise/meta_SCA/ (16 files)
#   results_10_noise/meta_SSA/ (16 files)
#   results_10_noise/meta_WOA/ (16 files)
#
# Plots directory: results_10_noise/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 86.41% ± 6.47% (Features: 49.9%)
#   baseline            : 86.18% ± 5.37% (Features: 100.0%)
#   meta_PSO            : 85.95% ± 5.21% (Features: 45.9%)
#   meta_GA             : 83.62% ± 6.89% (Features: 47.8%)
#   meta_FFA            : 83.61% ± 9.28% (Features: 48.5%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_SCA
#     Test Accuracy:      96.30%
#     Feature Retention:  26.55% (158/595)
#     Modality Retention: depth=21.6%, sensor=35.2%, skeleton=26.7%, video=25.4%
#
#   Fold 2: Best = meta_CS
#     Test Accuracy:      80.56%
#     Feature Retention:  51.93% (309/595)
#     Modality Retention: depth=56.8%, sensor=55.6%, skeleton=47.9%, video=54.2%
#
#   Fold 3: Best = meta_FFA
#     Test Accuracy:      87.04%
#     Feature Retention:  47.39% (282/595)
#     Modality Retention: depth=48.6%, sensor=55.6%, skeleton=45.0%, video=47.7%
#
#   Fold 4: Best = meta_PSO
#     Test Accuracy:      87.96%
#     Feature Retention:  46.39% (276/595)
#     Modality Retention: depth=43.2%, sensor=50.0%, skeleton=47.1%, video=45.5%
#
#   Fold 5: Best = meta_MFO
#     Test Accuracy:      90.74%
#     Feature Retention:  50.59% (301/595)
#     Modality Retention: depth=43.2%, sensor=55.6%, skeleton=48.8%, video=52.3%
#
#   Fold 6: Best = meta_MFO
#     Test Accuracy:      80.37%
#     Feature Retention:  43.53% (259/595)
#     Modality Retention: depth=37.8%, sensor=55.6%, skeleton=42.5%, video=42.8%
#
#   Fold 7: Best = meta_PSO
#     Test Accuracy:      87.85%
#     Feature Retention:  48.24% (287/595)
#     Modality Retention: depth=48.6%, sensor=57.4%, skeleton=42.9%, video=51.1%
#
#   Fold 8: Best = meta_MVO
#     Test Accuracy:      94.39%
#     Feature Retention:  48.24% (287/595)
#     Modality Retention: depth=51.4%, sensor=46.3%, skeleton=44.6%, video=51.5%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     88.15% ± 5.75%
#   Average Feature Retention: 45.36% ± 8.01%
#
#   Average Modality-wise Feature Retention:
#          depth: 43.92% ± 10.69%
#         sensor: 51.39% ± 7.52%
#       skeleton: 43.18% ± 7.04%
#          video: 46.31% ± 9.26%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)  video Retention (%)
#     1           meta_SCA              96.30                  26.55                21.62                 35.19                   26.67                25.38
#     2            meta_CS              80.56                  51.93                56.76                 55.56                   47.92                54.17
#     3           meta_FFA              87.04                  47.39                48.65                 55.56                   45.00                47.73
#     4           meta_PSO              87.96                  46.39                43.24                 50.00                   47.08                45.45
#     5           meta_MFO              90.74                  50.59                43.24                 55.56                   48.75                52.27
#     6           meta_MFO              80.37                  43.53                37.84                 55.56                   42.50                42.80
#     7           meta_PSO              87.85                  48.24                48.65                 57.41                   42.92                51.14
#     8           meta_MVO              94.39                  48.24                51.35                 46.30                   44.58                51.52
#
# Saved to: results_10_noise/best_metaheuristic_per_fold.csv
