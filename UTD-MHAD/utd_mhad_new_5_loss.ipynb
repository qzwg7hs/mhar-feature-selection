# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (25% Random Zeroing)
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.
#
#
# > **Modification:** This notebook randomly zeros out 10% of all data elements before any processing.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new_5_loss")

# Master output directory
RESULTS_ROOT = Path("results_new_5_loss")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   video: 1420
#   TOTAL: 3933

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 89.81%, F1: 89.04%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 21.7s
#     Test Acc: 92.59%, F1: 91.02%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.1s
#     Test Acc: 97.22%, F1: 97.14%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.3s
#     Test Acc: 78.70%, F1: 76.09%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03750775489448256']
# ['At iteration 1 the best fitness is 0.037393338418510016']
# ['At iteration 2 the best fitness is 0.03707551487414185']
# ['At iteration 3 the best fitness is 0.03707551487414185']
# ['At iteration 4 the best fitness is 0.03706280193236713']
# ['At iteration 5 the best fitness is 0.03699923722349349']
# ['At iteration 6 the best fitness is 0.036986524281718766']
# ['At iteration 7 the best fitness is 0.036986524281718766']
# ['At iteration 8 the best fitness is 0.036986524281718766']
# ['At iteration 9 the best fitness is 0.03694838545639459']
# ['At iteration 10 the best fitness is 0.03691024663107041']
# ['At iteration 11 the best fitness is 0.03691024663107041']
# ['At iteration 12 the best fitness is 0.03691024663107041']
# ['At iteration 13 the best fitness is 0.03691024663107041']
# ['At iteration 14 the best fitness is 0.03691024663107041']
# ['At iteration 15 the best fitness is 0.03691024663107041']
# ['At iteration 16 the best fitness is 0.03057691329773714']
# ['At iteration 17 the best fitness is 0.03057691329773714']
# ['At iteration 18 the best fitness is 0.030564200355962412']
# ['At iteration 19 the best fitness is 0.030564200355962412']
# ['At iteration 20 the best fitness is 0.030564200355962412']
# ['At iteration 21 the best fitness is 0.030564200355962412']
# ['At iteration 22 the best fitness is 0.030564200355962412']
# ['At iteration 23 the best fitness is 0.030564200355962412']
# ['At iteration 24 the best fitness is 0.030564200355962412']
# ['At iteration 25 the best fitness is 0.030564200355962412']
# ['At iteration 26 the best fitness is 0.030564200355962412']
# ['At iteration 27 the best fitness is 0.030564200355962412']
# ['At iteration 28 the best fitness is 0.030564200355962412']
# ['At iteration 29 the best fitness is 0.030564200355962412']
#       Selected: 1908/3933 (48.5%), Fitness: 0.0306, Time: 498.9s
#       Modality: D=48%, S=47%, Sk=49%, V=48%
#     Test Acc: 89.81%, F1: 89.16%, Features: 1908/3933 (48.5%), Model: 4.268MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03673226544622424']
# ['At iteration 10 the best fitness is 0.0304624968217646']
# ['At iteration 20 the best fitness is 0.03044978387998987']
#       Selected: 1993/3933 (50.7%), Fitness: 0.0256, Time: 982.6s
#       Modality: D=50%, S=52%, Sk=53%, V=48%
#     Test Acc: 88.89%, F1: 87.20%, Features: 1993/3933 (50.7%), Model: 4.434MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.037495041952707836']
# ['At iteration 2 the best fitness is 0.037367912534960565']
# ['At iteration 3 the best fitness is 0.037367912534960565']
# ['At iteration 4 the best fitness is 0.03098372743452839']
# ['At iteration 5 the best fitness is 0.03098372743452839']
# ['At iteration 6 the best fitness is 0.03098372743452839']
# ['At iteration 7 the best fitness is 0.024599542334096114']
# ['At iteration 8 the best fitness is 0.024599542334096114']
# ['At iteration 9 the best fitness is 0.024599542334096114']
# ['At iteration 10 the best fitness is 0.024599542334096114']
# ['At iteration 11 the best fitness is 0.024599542334096114']
# ['At iteration 12 the best fitness is 0.024599542334096114']
# ['At iteration 13 the best fitness is 0.024599542334096114']
# ['At iteration 14 the best fitness is 0.024599542334096114']
# ['At iteration 15 the best fitness is 0.024599542334096114']
# ['At iteration 16 the best fitness is 0.024599542334096114']
# ['At iteration 17 the best fitness is 0.024599542334096114']
# ['At iteration 18 the best fitness is 0.024599542334096114']
# ['At iteration 19 the best fitness is 0.024599542334096114']
# ['At iteration 20 the best fitness is 0.024599542334096114']
# ['At iteration 21 the best fitness is 0.024599542334096114']
# ['At iteration 22 the best fitness is 0.024599542334096114']
# ['At iteration 23 the best fitness is 0.024599542334096114']
# ['At iteration 24 the best fitness is 0.024599542334096114']
# ['At iteration 25 the best fitness is 0.024599542334096114']
# ['At iteration 26 the best fitness is 0.024599542334096114']
# ['At iteration 27 the best fitness is 0.024599542334096114']
# ['At iteration 28 the best fitness is 0.024599542334096114']
# ['At iteration 29 the best fitness is 0.024599542334096114']
# ['At iteration 30 the best fitness is 0.024599542334096114']
#       Selected: 1929/3933 (49.0%), Fitness: 0.0246, Time: 499.2s
#       Modality: D=50%, S=50%, Sk=48%, V=49%
#     Test Acc: 92.59%, F1: 91.21%, Features: 1929/3933 (49.0%), Model: 4.309MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03702466310704294']
# ['At iteration 1 the best fitness is 0.03754589371980674']
# ['At iteration 2 the best fitness is 0.04328171878972796']
# ['At iteration 3 the best fitness is 0.04328171878972796']
# ['At iteration 4 the best fitness is 0.04371395881006867']
# ['At iteration 5 the best fitness is 0.043866514111365384']
# ['At iteration 6 the best fitness is 0.04385380116959066']
# ['At iteration 7 the best fitness is 0.037685736079328735']
# ['At iteration 8 the best fitness is 0.03782557843885073']
# ['At iteration 9 the best fitness is 0.037749300788202364']
# ['At iteration 10 the best fitness is 0.031504958047292184']
# ['At iteration 11 the best fitness is 0.044120772946859926']
# ['At iteration 12 the best fitness is 0.037774726671751815']
# ['At iteration 13 the best fitness is 0.031466819221968007']
# ['At iteration 14 the best fitness is 0.04405720823798629']
# ['At iteration 15 the best fitness is 0.03144139333841855']
# ['At iteration 16 the best fitness is 0.03144139333841855']
# ['At iteration 17 the best fitness is 0.03147953216374273']
# ['At iteration 18 the best fitness is 0.037812865497076']
# ['At iteration 19 the best fitness is 0.03778743961352655']
# ['At iteration 20 the best fitness is 0.037774726671751815']
# ['At iteration 21 the best fitness is 0.03145410628019328']
# ['At iteration 22 the best fitness is 0.037812865497076']
# ['At iteration 23 the best fitness is 0.03778743961352655']
# ['At iteration 24 the best fitness is 0.03778743961352655']
# ['At iteration 25 the best fitness is 0.03778743961352655']
# ['At iteration 26 the best fitness is 0.03780015255530128']
# ['At iteration 27 the best fitness is 0.04413348588863465']
# ['At iteration 28 the best fitness is 0.03780015255530128']
# ['At iteration 29 the best fitness is 0.03780015255530128']
#       Selected: 1952/3933 (49.6%), Fitness: 0.0378, Time: 483.3s
#       Modality: D=48%, S=51%, Sk=50%, V=49%
#     Test Acc: 94.44%, F1: 93.98%, Features: 1952/3933 (49.6%), Model: 4.354MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.030856598016781124
# At iteration 2 the best fitness is 0.03718993135011439
# At iteration 3 the best fitness is 0.03680854309687259
# At iteration 4 the best fitness is 0.030627765064836044
# At iteration 5 the best fitness is 0.03682125603864732
# At iteration 6 the best fitness is 0.030627765064836044
# At iteration 7 the best fitness is 0.030678616831934954
# At iteration 8 the best fitness is 0.03694838545639459
# At iteration 9 the best fitness is 0.03694838545639459
# At iteration 10 the best fitness is 0.036859394863971495
# At iteration 11 the best fitness is 0.030754894482583315
# At iteration 12 the best fitness is 0.03694838545639459
# At iteration 13 the best fitness is 0.030640478006610773
# At iteration 14 the best fitness is 0.03697381133994404
# At iteration 15 the best fitness is 0.03697381133994404
# At iteration 16 the best fitness is 0.036389016018306616
# At iteration 17 the best fitness is 0.03076760742435804
# At iteration 18 the best fitness is 0.030805746249682218
# At iteration 19 the best fitness is 0.03713907958301549
# At iteration 20 the best fitness is 0.03701195016526822
# At iteration 21 the best fitness is 0.03699923722349349
# At iteration 22 the best fitness is 0.03050063564708878
# At iteration 23 the best fitness is 0.0308438850750064
# At iteration 24 the best fitness is 0.030411645054665693
# At iteration 25 the best fitness is 0.03052606153063823
# At iteration 26 the best fitness is 0.03052606153063823
# At iteration 27 the best fitness is 0.030640478006610773
# At iteration 28 the best fitness is 0.03093287566742949
# At iteration 29 the best fitness is 0.030716755657259134
# At iteration 30 the best fitness is 0.03069132977370968
#       Selected: 1941/3933 (49.4%), Fitness: 0.0307, Time: 481.2s
#       Modality: D=48%, S=50%, Sk=51%, V=48%
#     Test Acc: 86.11%, F1: 85.57%, Features: 1941/3933 (49.4%), Model: 4.332MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04356140350877195']
# ['At iteration 1 the best fitness is 0.03731706076786166']
# ['At iteration 2 the best fitness is 0.035638952453597744']
# ['At iteration 3 the best fitness is 0.03466005593694378']
# ['At iteration 4 the best fitness is 0.034558352402745976']
# ['At iteration 5 the best fitness is 0.027169844902110392']
# ['At iteration 6 the best fitness is 0.027169844902110392']
# ['At iteration 7 the best fitness is 0.026012967200610266']
# ['At iteration 8 the best fitness is 0.025402745995423383']
# ['At iteration 9 the best fitness is 0.025402745995423383']
# ['At iteration 10 the best fitness is 0.01867531146707348']
# ['At iteration 11 the best fitness is 0.01867531146707348']
# ['At iteration 12 the best fitness is 0.01867531146707348']
# ['At iteration 13 the best fitness is 0.01867531146707348']
# ['At iteration 14 the best fitness is 0.01867531146707348']
# ['At iteration 15 the best fitness is 0.017315026697177726']
# ['At iteration 16 the best fitness is 0.017315026697177726']
# ['At iteration 17 the best fitness is 0.017315026697177726']
# ['At iteration 18 the best fitness is 0.017315026697177726']
# ['At iteration 19 the best fitness is 0.017315026697177726']
# ['At iteration 20 the best fitness is 0.017315026697177726']
# ['At iteration 21 the best fitness is 0.01727688787185355']
# ['At iteration 22 the best fitness is 0.01727688787185355']
# ['At iteration 23 the best fitness is 0.01727688787185355']
# ['At iteration 24 the best fitness is 0.01727688787185355']
# ['At iteration 25 the best fitness is 0.01727688787185355']
# ['At iteration 26 the best fitness is 0.01727688787185355']
# ['At iteration 27 the best fitness is 0.01727688787185355']
# ['At iteration 28 the best fitness is 0.01727688787185355']
# ['At iteration 29 the best fitness is 0.01727688787185355']
#       Selected: 1452/3933 (36.9%), Fitness: 0.0173, Time: 469.8s
#       Modality: D=37%, S=37%, Sk=38%, V=35%
#     Test Acc: 93.52%, F1: 93.42%, Features: 1452/3933 (36.9%), Model: 3.377MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.04394279176201375']
# ['At iteration 1 the best fitness is 0.04104652936689545']
# ['At iteration 2 the best fitness is 0.04104652936689545']
# ['At iteration 3 the best fitness is 0.03933257055682684']
# ['At iteration 4 the best fitness is 0.03933257055682684']
# ['At iteration 5 the best fitness is 0.03933257055682684']
# ['At iteration 6 the best fitness is 0.033215357233663825']
# ['At iteration 7 the best fitness is 0.033215357233663825']
# ['At iteration 8 the best fitness is 0.033215357233663825']
# ['At iteration 9 the best fitness is 0.033215357233663825']
# ['At iteration 10 the best fitness is 0.021184337655733514']
# ['At iteration 11 the best fitness is 0.021184337655733514']
# ['At iteration 12 the best fitness is 0.021184337655733514']
# ['At iteration 13 the best fitness is 0.021184337655733514']
# ['At iteration 14 the best fitness is 0.021184337655733514']
# ['At iteration 15 the best fitness is 0.021184337655733514']
# ['At iteration 16 the best fitness is 0.021184337655733514']
# ['At iteration 17 the best fitness is 0.021184337655733514']
# ['At iteration 18 the best fitness is 0.021184337655733514']
# ['At iteration 19 the best fitness is 0.021184337655733514']
# ['At iteration 20 the best fitness is 0.021184337655733514']
# ['At iteration 21 the best fitness is 0.021184337655733514']
# ['At iteration 22 the best fitness is 0.021184337655733514']
# ['At iteration 23 the best fitness is 0.021184337655733514']
# ['At iteration 24 the best fitness is 0.021184337655733514']
# ['At iteration 25 the best fitness is 0.021184337655733514']
# ['At iteration 26 the best fitness is 0.021184337655733514']
# ['At iteration 27 the best fitness is 0.021184337655733514']
# ['At iteration 28 the best fitness is 0.021184337655733514']
# ['At iteration 29 the best fitness is 0.021184337655733514']
#       Selected: 807/3933 (20.5%), Fitness: 0.0212, Time: 562.6s
#       Modality: D=19%, S=21%, Sk=21%, V=20%
#     Test Acc: 88.89%, F1: 89.01%, Features: 807/3933 (20.5%), Model: 2.117MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03238215102974833']
# ['At iteration 1 the best fitness is 0.031466819221968007']
# ['At iteration 2 the best fitness is 0.031466819221968007']
# ['At iteration 3 the best fitness is 0.031466819221968007']
# ['At iteration 4 the best fitness is 0.031466819221968007']
# ['At iteration 5 the best fitness is 0.031466819221968007']
# ['At iteration 6 the best fitness is 0.031466819221968007']
# ['At iteration 7 the best fitness is 0.031466819221968007']
# ['At iteration 8 the best fitness is 0.031466819221968007']
# ['At iteration 9 the best fitness is 0.031466819221968007']
# ['At iteration 10 the best fitness is 0.031466819221968007']
# ['At iteration 11 the best fitness is 0.031466819221968007']
# ['At iteration 12 the best fitness is 0.031466819221968007']
# ['At iteration 13 the best fitness is 0.031466819221968007']
# ['At iteration 14 the best fitness is 0.031466819221968007']
# ['At iteration 15 the best fitness is 0.031466819221968007']
# ['At iteration 16 the best fitness is 0.031187134502924017']
# ['At iteration 17 the best fitness is 0.030754894482583315']
# ['At iteration 18 the best fitness is 0.030754894482583315']
# ['At iteration 19 the best fitness is 0.03050063564708878']
# ['At iteration 20 the best fitness is 0.030398932112890967']
# ['At iteration 21 the best fitness is 0.030398932112890967']
# ['At iteration 22 the best fitness is 0.030398932112890967']
# ['At iteration 23 the best fitness is 0.030398932112890967']
# ['At iteration 24 the best fitness is 0.024586829392321385']
# ['At iteration 25 the best fitness is 0.024586829392321385']
# ['At iteration 26 the best fitness is 0.024586829392321385']
# ['At iteration 27 the best fitness is 0.024586829392321385']
# ['At iteration 28 the best fitness is 0.024586829392321385']
# ['At iteration 29 the best fitness is 0.024586829392321385']
#       Selected: 1961/3933 (49.9%), Fitness: 0.0246, Time: 500.0s
#       Modality: D=48%, S=49%, Sk=49%, V=51%
#     Test Acc: 87.96%, F1: 87.21%, Features: 1961/3933 (49.9%), Model: 4.371MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03740605136028474']
# ['At iteration 2 the best fitness is 0.03740605136028474']
# ['At iteration 3 the best fitness is 0.031085430968726208']
# ['At iteration 4 the best fitness is 0.031085430968726208']
# ['At iteration 5 the best fitness is 0.031085430968726208']
# ['At iteration 6 the best fitness is 0.031085430968726208']
# ['At iteration 7 the best fitness is 0.031085430968726208']
# ['At iteration 8 the best fitness is 0.031085430968726208']
# ['At iteration 9 the best fitness is 0.031085430968726208']
# ['At iteration 10 the best fitness is 0.031085430968726208']
# ['At iteration 11 the best fitness is 0.031085430968726208']
# ['At iteration 12 the best fitness is 0.031085430968726208']
# ['At iteration 13 the best fitness is 0.03092016272565476']
# ['At iteration 14 the best fitness is 0.03092016272565476']
# ['At iteration 15 the best fitness is 0.03092016272565476']
# ['At iteration 16 the best fitness is 0.03092016272565476']
# ['At iteration 17 the best fitness is 0.03092016272565476']
# ['At iteration 18 the best fitness is 0.03092016272565476']
# ['At iteration 19 the best fitness is 0.03092016272565476']
# ['At iteration 20 the best fitness is 0.03092016272565476']
# ['At iteration 21 the best fitness is 0.03092016272565476']
# ['At iteration 22 the best fitness is 0.03092016272565476']
# ['At iteration 23 the best fitness is 0.03092016272565476']
# ['At iteration 24 the best fitness is 0.03092016272565476']
# ['At iteration 25 the best fitness is 0.03092016272565476']
# ['At iteration 26 the best fitness is 0.03092016272565476']
# ['At iteration 27 the best fitness is 0.03092016272565476']
# ['At iteration 28 the best fitness is 0.03092016272565476']
# ['At iteration 29 the best fitness is 0.03092016272565476']
#       Selected: 1969/3933 (50.1%), Fitness: 0.0309, Time: 474.4s
#       Modality: D=51%, S=52%, Sk=49%, V=50%
#     Test Acc: 91.67%, F1: 91.01%, Features: 1969/3933 (50.1%), Model: 4.387MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.037342486651411114']
# ['At iteration 2 the best fitness is 0.037342486651411114']
# ['At iteration 3 the best fitness is 0.037342486651411114']
# ['At iteration 4 the best fitness is 0.03713907958301549']
# ['At iteration 5 the best fitness is 0.03713907958301549']
# ['At iteration 6 the best fitness is 0.03144139333841855']
# ['At iteration 7 the best fitness is 0.03144139333841855']
# ['At iteration 8 the best fitness is 0.03144139333841855']
# ['At iteration 9 the best fitness is 0.03144139333841855']
# ['At iteration 10 the best fitness is 0.030869310958555853']
# ['At iteration 11 the best fitness is 0.030856598016781124']
# ['At iteration 12 the best fitness is 0.03069132977370968']
# ['At iteration 13 the best fitness is 0.03069132977370968']
# ['At iteration 14 the best fitness is 0.03069132977370968']
# ['At iteration 15 the best fitness is 0.03069132977370968']
# ['At iteration 16 the best fitness is 0.03069132977370968']
# ['At iteration 17 the best fitness is 0.03069132977370968']
# ['At iteration 18 the best fitness is 0.03069132977370968']
# ['At iteration 19 the best fitness is 0.03069132977370968']
# ['At iteration 20 the best fitness is 0.03069132977370968']
# ['At iteration 21 the best fitness is 0.0306531909483855']
# ['At iteration 22 the best fitness is 0.0306531909483855']
# ['At iteration 23 the best fitness is 0.0306531909483855']
# ['At iteration 24 the best fitness is 0.0306531909483855']
# ['At iteration 25 the best fitness is 0.0306531909483855']
# ['At iteration 26 the best fitness is 0.030589626239511867']
# ['At iteration 27 the best fitness is 0.030589626239511867']
# ['At iteration 28 the best fitness is 0.030589626239511867']
# ['At iteration 29 the best fitness is 0.030589626239511867']
# ['At iteration 30 the best fitness is 0.030589626239511867']
#       Selected: 1960/3933 (49.8%), Fitness: 0.0306, Time: 487.4s
#       Modality: D=58%, S=53%, Sk=47%, V=50%
#     Test Acc: 91.67%, F1: 91.18%, Features: 1960/3933 (49.8%), Model: 4.369MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04343427409102468']
# ['At iteration 2 the best fitness is 0.04343427409102468']
# ['At iteration 3 the best fitness is 0.042976608187134516']
# ['At iteration 4 the best fitness is 0.042976608187134516']
# ['At iteration 5 the best fitness is 0.042976608187134516']
# ['At iteration 6 the best fitness is 0.042976608187134516']
# ['At iteration 7 the best fitness is 0.042951182303585064']
# ['At iteration 8 the best fitness is 0.042951182303585064']
# ['At iteration 9 the best fitness is 0.042951182303585064']
# ['At iteration 10 the best fitness is 0.042951182303585064']
# ['At iteration 11 the best fitness is 0.042951182303585064']
# ['At iteration 12 the best fitness is 0.042951182303585064']
# ['At iteration 13 the best fitness is 0.03678311721332314']
# ['At iteration 14 the best fitness is 0.03678311721332314']
# ['At iteration 15 the best fitness is 0.03678311721332314']
# ['At iteration 16 the best fitness is 0.03678311721332314']
# ['At iteration 17 the best fitness is 0.03678311721332314']
# ['At iteration 18 the best fitness is 0.03670683956267478']
# ['At iteration 19 the best fitness is 0.03670683956267478']
# ['At iteration 20 the best fitness is 0.036694126620900054']
# ['At iteration 21 the best fitness is 0.036554284261378064']
# ['At iteration 22 the best fitness is 0.036554284261378064']
# ['At iteration 23 the best fitness is 0.036554284261378064']
# ['At iteration 24 the best fitness is 0.036554284261378064']
# ['At iteration 25 the best fitness is 0.036554284261378064']
# ['At iteration 26 the best fitness is 0.036554284261378064']
# ['At iteration 27 the best fitness is 0.030220950928044794']
# ['At iteration 28 the best fitness is 0.029890414441901898']
# ['At iteration 29 the best fitness is 0.029890414441901898']
# ['At iteration 30 the best fitness is 0.029890414441901898']
#       Selected: 1872/3933 (47.6%), Fitness: 0.0299, Time: 484.6s
#       Modality: D=49%, S=48%, Sk=48%, V=46%
#     Test Acc: 93.52%, F1: 93.29%, Features: 1872/3933 (47.6%), Model: 4.197MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03788914314772436']
# ['At iteration 1 the best fitness is 0.036478006610729696']
# ['At iteration 2 the best fitness is 0.036478006610729696']
# ['At iteration 3 the best fitness is 0.036478006610729696']
# ['At iteration 4 the best fitness is 0.036478006610729696']
# ['At iteration 5 the best fitness is 0.030274091024663084']
# ['At iteration 6 the best fitness is 0.030274091024663084']
# ['At iteration 7 the best fitness is 0.027489956775997942']
# ['At iteration 8 the best fitness is 0.027489956775997942']
# ['At iteration 9 the best fitness is 0.02615509788965164']
# ['At iteration 10 the best fitness is 0.019402237477752392']
# ['At iteration 11 the best fitness is 0.019402237477752392']
# ['At iteration 12 the best fitness is 0.019402237477752392']
# ['At iteration 13 the best fitness is 0.019402237477752392']
# ['At iteration 14 the best fitness is 0.019402237477752392']
# ['At iteration 15 the best fitness is 0.01674523264683452']
# ['At iteration 16 the best fitness is 0.01674523264683452']
# ['At iteration 17 the best fitness is 0.01497813374014751']
# ['At iteration 18 the best fitness is 0.008606661581489957']
# ['At iteration 19 the best fitness is 0.00851767098906687']
# ['At iteration 20 the best fitness is 0.00851767098906687']
# ['At iteration 21 the best fitness is 0.00851767098906687']
# ['At iteration 22 the best fitness is 0.00851767098906687']
# ['At iteration 23 the best fitness is 0.00851767098906687']
# ['At iteration 24 the best fitness is 0.00851767098906687']
# ['At iteration 25 the best fitness is 0.00851767098906687']
# ['At iteration 26 the best fitness is 0.00851767098906687']
# ['At iteration 27 the best fitness is 0.00851767098906687']
# ['At iteration 28 the best fitness is 0.00851767098906687']
# ['At iteration 29 the best fitness is 0.00851767098906687']
#       Selected: 733/3933 (18.6%), Fitness: 0.0085, Time: 435.6s
#       Modality: D=22%, S=19%, Sk=17%, V=20%
#     Test Acc: 87.04%, F1: 85.67%, Features: 733/3933 (18.6%), Model: 1.973MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.031606661581489996']
# ['At iteration 2 the best fitness is 0.031606661581489996']
# ['At iteration 3 the best fitness is 0.031606661581489996']
# ['At iteration 4 the best fitness is 0.031606661581489996']
# ['At iteration 5 the best fitness is 0.031606661581489996']
# ['At iteration 6 the best fitness is 0.03149224510551746']
# ['At iteration 7 the best fitness is 0.03137782862954492']
# ['At iteration 8 the best fitness is 0.03137782862954492']
# ['At iteration 9 the best fitness is 0.031314263920671284']
# ['At iteration 10 the best fitness is 0.030793033307907492']
# ['At iteration 11 the best fitness is 0.030793033307907492']
# ['At iteration 12 the best fitness is 0.030793033307907492']
# ['At iteration 13 the best fitness is 0.030793033307907492']
# ['At iteration 14 the best fitness is 0.030793033307907492']
# ['At iteration 15 the best fitness is 0.024459699974574117']
# ['At iteration 16 the best fitness is 0.024459699974574117']
# ['At iteration 17 the best fitness is 0.024459699974574117']
# ['At iteration 18 the best fitness is 0.024459699974574117']
# ['At iteration 19 the best fitness is 0.024459699974574117']
# ['At iteration 20 the best fitness is 0.024459699974574117']
# ['At iteration 21 the best fitness is 0.024459699974574117']
# ['At iteration 22 the best fitness is 0.024459699974574117']
# ['At iteration 23 the best fitness is 0.024459699974574117']
# ['At iteration 24 the best fitness is 0.024459699974574117']
# ['At iteration 25 the best fitness is 0.024459699974574117']
# ['At iteration 26 the best fitness is 0.024459699974574117']
# ['At iteration 27 the best fitness is 0.024459699974574117']
# ['At iteration 28 the best fitness is 0.024459699974574117']
# ['At iteration 29 the best fitness is 0.024459699974574117']
#       Selected: 1939/3933 (49.3%), Fitness: 0.0245, Time: 1210.5s
#       Modality: D=49%, S=51%, Sk=49%, V=49%
#     Test Acc: 92.59%, F1: 91.20%, Features: 1939/3933 (49.3%), Model: 4.328MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04344698703279941']
# ['At iteration 1 the best fitness is 0.04344698703279941']
# ['At iteration 2 the best fitness is 0.04179659293160433']
# ['At iteration 3 the best fitness is 0.029017798118484636']
# ['At iteration 4 the best fitness is 0.029017798118484636']
# ['At iteration 5 the best fitness is 0.027797355708110875']
# ['At iteration 6 the best fitness is 0.027797355708110875']
# ['At iteration 7 the best fitness is 0.027797355708110875']
# ['At iteration 8 the best fitness is 0.027797355708110875']
# ['At iteration 9 the best fitness is 0.027797355708110875']
# ['At iteration 10 the best fitness is 0.027797355708110875']
# ['At iteration 11 the best fitness is 0.027797355708110875']
# ['At iteration 12 the best fitness is 0.027797355708110875']
# ['At iteration 13 the best fitness is 0.027797355708110875']
# ['At iteration 14 the best fitness is 0.027797355708110875']
# ['At iteration 15 the best fitness is 0.027797355708110875']
# ['At iteration 16 the best fitness is 0.027797355708110875']
# ['At iteration 17 the best fitness is 0.027797355708110875']
# ['At iteration 18 the best fitness is 0.023587083651156852']
# ['At iteration 19 the best fitness is 0.023587083651156852']
# ['At iteration 20 the best fitness is 0.023587083651156852']
# ['At iteration 21 the best fitness is 0.023587083651156852']
# ['At iteration 22 the best fitness is 0.023587083651156852']
# ['At iteration 23 the best fitness is 0.023587083651156852']
# ['At iteration 24 the best fitness is 0.023587083651156852']
# ['At iteration 25 the best fitness is 0.023587083651156852']
# ['At iteration 26 the best fitness is 0.023587083651156852']
# ['At iteration 27 the best fitness is 0.023587083651156852']
# ['At iteration 28 the best fitness is 0.023587083651156852']
# ['At iteration 29 the best fitness is 0.023587083651156852']
#       Selected: 930/3933 (23.6%), Fitness: 0.0236, Time: 428.6s
#       Modality: D=20%, S=22%, Sk=24%, V=24%
#     Test Acc: 94.44%, F1: 93.85%, Features: 930/3933 (23.6%), Model: 2.358MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 93.52%, F1: 92.91%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 21.6s
#     Test Acc: 87.04%, F1: 86.08%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.1s
#     Test Acc: 95.37%, F1: 95.20%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.2s
#     Test Acc: 75.00%, F1: 73.05%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.031034579201627298']
# ['At iteration 1 the best fitness is 0.030971014492753666']
# ['At iteration 2 the best fitness is 0.03061505212306132']
# ['At iteration 3 the best fitness is 0.03061505212306132']
# ['At iteration 4 the best fitness is 0.030589626239511867']
# ['At iteration 5 the best fitness is 0.030589626239511867']
# ['At iteration 6 the best fitness is 0.030589626239511867']
# ['At iteration 7 the best fitness is 0.030589626239511867']
# ['At iteration 8 the best fitness is 0.030589626239511867']
# ['At iteration 9 the best fitness is 0.030589626239511867']
# ['At iteration 10 the best fitness is 0.030589626239511867']
# ['At iteration 11 the best fitness is 0.030589626239511867']
# ['At iteration 12 the best fitness is 0.030589626239511867']
# ['At iteration 13 the best fitness is 0.030589626239511867']
# ['At iteration 14 the best fitness is 0.030589626239511867']
# ['At iteration 15 the best fitness is 0.030589626239511867']
# ['At iteration 16 the best fitness is 0.030589626239511867']
# ['At iteration 17 the best fitness is 0.030589626239511867']
# ['At iteration 18 the best fitness is 0.030589626239511867']
# ['At iteration 19 the best fitness is 0.030589626239511867']
# ['At iteration 20 the best fitness is 0.030589626239511867']
# ['At iteration 21 the best fitness is 0.030589626239511867']
# ['At iteration 22 the best fitness is 0.030589626239511867']
# ['At iteration 23 the best fitness is 0.030589626239511867']
# ['At iteration 24 the best fitness is 0.030589626239511867']
# ['At iteration 25 the best fitness is 0.030589626239511867']
# ['At iteration 26 the best fitness is 0.030589626239511867']
# ['At iteration 27 the best fitness is 0.030589626239511867']
# ['At iteration 28 the best fitness is 0.030589626239511867']
# ['At iteration 29 the best fitness is 0.030589626239511867']
#       Selected: 1902/3933 (48.4%), Fitness: 0.0306, Time: 500.6s
#       Modality: D=52%, S=49%, Sk=48%, V=48%
#     Test Acc: 90.74%, F1: 89.03%, Features: 1902/3933 (48.4%), Model: 4.256MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.031085430968726208']
# ['At iteration 10 the best fitness is 0.030716755657259134']
# ['At iteration 20 the best fitness is 0.030602339181286593']
#       Selected: 1909/3933 (48.5%), Fitness: 0.0243, Time: 984.2s
#       Modality: D=45%, S=48%, Sk=50%, V=48%
#     Test Acc: 93.52%, F1: 93.05%, Features: 1909/3933 (48.5%), Model: 4.270MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.030996440376303117']
# ['At iteration 2 the best fitness is 0.030996440376303117']
# ['At iteration 3 the best fitness is 0.030996440376303117']
# ['At iteration 4 the best fitness is 0.030996440376303117']
# ['At iteration 5 the best fitness is 0.030996440376303117']
# ['At iteration 6 the best fitness is 0.030818459191456943']
# ['At iteration 7 the best fitness is 0.030818459191456943']
# ['At iteration 8 the best fitness is 0.030818459191456943']
# ['At iteration 9 the best fitness is 0.030818459191456943']
# ['At iteration 10 the best fitness is 0.030818459191456943']
# ['At iteration 11 the best fitness is 0.030818459191456943']
# ['At iteration 12 the best fitness is 0.030818459191456943']
# ['At iteration 13 the best fitness is 0.030818459191456943']
# ['At iteration 14 the best fitness is 0.024548690566997204']
# ['At iteration 15 the best fitness is 0.024548690566997204']
# ['At iteration 16 the best fitness is 0.024548690566997204']
# ['At iteration 17 the best fitness is 0.024548690566997204']
# ['At iteration 18 the best fitness is 0.024548690566997204']
# ['At iteration 19 the best fitness is 0.024548690566997204']
# ['At iteration 20 the best fitness is 0.024548690566997204']
# ['At iteration 21 the best fitness is 0.024548690566997204']
# ['At iteration 22 the best fitness is 0.024548690566997204']
# ['At iteration 23 the best fitness is 0.024548690566997204']
# ['At iteration 24 the best fitness is 0.024548690566997204']
# ['At iteration 25 the best fitness is 0.024548690566997204']
# ['At iteration 26 the best fitness is 0.024548690566997204']
# ['At iteration 27 the best fitness is 0.024548690566997204']
# ['At iteration 28 the best fitness is 0.024548690566997204']
# ['At iteration 29 the best fitness is 0.024548690566997204']
# ['At iteration 30 the best fitness is 0.024154589371980676']
#       Selected: 1969/3933 (50.1%), Fitness: 0.0242, Time: 500.1s
#       Modality: D=51%, S=51%, Sk=50%, V=49%
#     Test Acc: 90.74%, F1: 89.68%, Features: 1969/3933 (50.1%), Model: 4.387MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.031390541571319645']
# ['At iteration 1 the best fitness is 0.03757131960335619']
# ['At iteration 2 the best fitness is 0.030869310958555853']
# ['At iteration 3 the best fitness is 0.0312252733282482']
# ['At iteration 4 the best fitness is 0.0312252733282482']
# ['At iteration 5 the best fitness is 0.03121256038647347']
# ['At iteration 6 the best fitness is 0.03725349605898803']
# ['At iteration 7 the best fitness is 0.037469616069158385']
# ['At iteration 8 the best fitness is 0.03127612509534711']
# ['At iteration 9 the best fitness is 0.031237986270022926']
# ['At iteration 10 the best fitness is 0.03750775489448256']
# ['At iteration 11 the best fitness is 0.03759674548690565']
# ['At iteration 12 the best fitness is 0.03127612509534711']
# ['At iteration 13 the best fitness is 0.03135240274599547']
# ['At iteration 14 the best fitness is 0.037660310195779284']
# ['At iteration 15 the best fitness is 0.03771116196287819']
# ['At iteration 16 the best fitness is 0.03145410628019328']
# ['At iteration 17 the best fitness is 0.03769844902110346']
# ['At iteration 18 the best fitness is 0.037660310195779284']
# ['At iteration 19 the best fitness is 0.03769844902110346']
# ['At iteration 20 the best fitness is 0.03769844902110346']
# ['At iteration 21 the best fitness is 0.037685736079328735']
# ['At iteration 22 the best fitness is 0.03769844902110346']
# ['At iteration 23 the best fitness is 0.03767302313755401']
# ['At iteration 24 the best fitness is 0.037660310195779284']
# ['At iteration 25 the best fitness is 0.037660310195779284']
# ['At iteration 26 the best fitness is 0.037660310195779284']
# ['At iteration 27 the best fitness is 0.037660310195779284']
# ['At iteration 28 the best fitness is 0.037685736079328735']
# ['At iteration 29 the best fitness is 0.03135240274599547']
#       Selected: 1965/3933 (50.0%), Fitness: 0.0314, Time: 482.2s
#       Modality: D=44%, S=48%, Sk=52%, V=50%
#     Test Acc: 91.67%, F1: 91.32%, Features: 1965/3933 (50.0%), Model: 4.379MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.031237986270022926
# At iteration 2 the best fitness is 0.03121256038647347
# At iteration 3 the best fitness is 0.0312252733282482
# At iteration 4 the best fitness is 0.03034808034579206
# At iteration 5 the best fitness is 0.030678616831934954
# At iteration 6 the best fitness is 0.031161708619374565
# At iteration 7 the best fitness is 0.030793033307907492
# At iteration 8 the best fitness is 0.030551487414187686
# At iteration 9 the best fitness is 0.030627765064836044
# At iteration 10 the best fitness is 0.030564200355962412
# At iteration 11 the best fitness is 0.030678616831934954
# At iteration 12 the best fitness is 0.03050063564708878
# At iteration 13 the best fitness is 0.031060005085176753
# At iteration 14 the best fitness is 0.031085430968726208
# At iteration 15 the best fitness is 0.030742181540808586
# At iteration 16 the best fitness is 0.030742181540808586
# At iteration 17 the best fitness is 0.030742181540808586
# At iteration 18 the best fitness is 0.03052606153063823
# At iteration 19 the best fitness is 0.03052606153063823
# At iteration 20 the best fitness is 0.030793033307907492
# At iteration 21 the best fitness is 0.030551487414187686
# At iteration 22 the best fitness is 0.030551487414187686
# At iteration 23 the best fitness is 0.0306531909483855
# At iteration 24 the best fitness is 0.030602339181286593
# At iteration 25 the best fitness is 0.0306531909483855
# At iteration 26 the best fitness is 0.030627765064836044
# At iteration 27 the best fitness is 0.030716755657259134
# At iteration 28 the best fitness is 0.030589626239511867
# At iteration 29 the best fitness is 0.030589626239511867
# At iteration 30 the best fitness is 0.030678616831934954
#       Selected: 1950/3933 (49.6%), Fitness: 0.0307, Time: 481.7s
#       Modality: D=47%, S=50%, Sk=49%, V=50%
#     Test Acc: 91.67%, F1: 91.12%, Features: 1950/3933 (49.6%), Model: 4.350MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.030894736842105305']
# ['At iteration 1 the best fitness is 0.030894736842105305']
# ['At iteration 2 the best fitness is 0.02934375794558865']
# ['At iteration 3 the best fitness is 0.028034324942791806']
# ['At iteration 4 the best fitness is 0.0279834731756929']
# ['At iteration 5 the best fitness is 0.02697915077548949']
# ['At iteration 6 the best fitness is 0.02697915077548949']
# ['At iteration 7 the best fitness is 0.025669717772692644']
# ['At iteration 8 the best fitness is 0.025555301296720102']
# ['At iteration 9 the best fitness is 0.024817950673785956']
# ['At iteration 10 the best fitness is 0.024436562420544157']
# ['At iteration 11 the best fitness is 0.023673785914060556']
# ['At iteration 12 the best fitness is 0.02311441647597258']
# ['At iteration 13 the best fitness is 0.022694889397406603']
# ['At iteration 14 the best fitness is 0.022389778794813162']
# ['At iteration 15 the best fitness is 0.022173658784642808']
# ['At iteration 16 the best fitness is 0.02208466819221972']
# ['At iteration 17 the best fitness is 0.021843122298499915']
# ['At iteration 18 the best fitness is 0.021576150521230655']
# ['At iteration 19 the best fitness is 0.015433511314518181']
# ['At iteration 20 the best fitness is 0.015433511314518181']
# ['At iteration 21 the best fitness is 0.015064836003051106']
# ['At iteration 22 the best fitness is 0.015064836003051106']
# ['At iteration 23 the best fitness is 0.015064836003051106']
# ['At iteration 24 the best fitness is 0.015064836003051106']
# ['At iteration 25 the best fitness is 0.015064836003051106']
# ['At iteration 26 the best fitness is 0.015064836003051106']
# ['At iteration 27 the best fitness is 0.015064836003051106']
# ['At iteration 28 the best fitness is 0.015064836003051106']
# ['At iteration 29 the best fitness is 0.015064836003051106']
#       Selected: 1283/3933 (32.6%), Fitness: 0.0151, Time: 465.7s
#       Modality: D=33%, S=34%, Sk=32%, V=33%
#     Test Acc: 92.59%, F1: 92.34%, Features: 1283/3933 (32.6%), Model: 3.047MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.031034579201627298']
# ['At iteration 1 the best fitness is 0.031034579201627298']
# ['At iteration 2 the best fitness is 0.031034579201627298']
# ['At iteration 3 the best fitness is 0.031034579201627298']
# ['At iteration 4 the best fitness is 0.031034579201627298']
# ['At iteration 5 the best fitness is 0.030312229849987264']
# ['At iteration 6 the best fitness is 0.029117213323162954']
# ['At iteration 7 the best fitness is 0.029117213323162954']
# ['At iteration 8 the best fitness is 0.029117213323162954']
# ['At iteration 9 the best fitness is 0.02775464022374782']
# ['At iteration 10 the best fitness is 0.02775464022374782']
# ['At iteration 11 the best fitness is 0.027614797864225826']
# ['At iteration 12 the best fitness is 0.027614797864225826']
# ['At iteration 13 the best fitness is 0.027614797864225826']
# ['At iteration 14 the best fitness is 0.027614797864225826']
# ['At iteration 15 the best fitness is 0.027614797864225826']
# ['At iteration 16 the best fitness is 0.027614797864225826']
# ['At iteration 17 the best fitness is 0.027614797864225826']
# ['At iteration 18 the best fitness is 0.027614797864225826']
# ['At iteration 19 the best fitness is 0.02758937198067637']
# ['At iteration 20 the best fitness is 0.02758937198067637']
# ['At iteration 21 the best fitness is 0.02758937198067637']
# ['At iteration 22 the best fitness is 0.026089244851258624']
# ['At iteration 23 the best fitness is 0.026089244851258624']
# ['At iteration 24 the best fitness is 0.026089244851258624']
# ['At iteration 25 the best fitness is 0.02602568014238499']
# ['At iteration 26 the best fitness is 0.02602568014238499']
# ['At iteration 27 the best fitness is 0.02602568014238499']
# ['At iteration 28 the best fitness is 0.02602568014238499']
# ['At iteration 29 the best fitness is 0.02602568014238499']
#       Selected: 1551/3933 (39.4%), Fitness: 0.0260, Time: 625.1s
#       Modality: D=38%, S=40%, Sk=40%, V=38%
#     Test Acc: 89.81%, F1: 89.57%, Features: 1551/3933 (39.4%), Model: 3.570MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.030754894482583315']
# ['At iteration 1 the best fitness is 0.030754894482583315']
# ['At iteration 2 the best fitness is 0.030754894482583315']
# ['At iteration 3 the best fitness is 0.030627765064836044']
# ['At iteration 4 the best fitness is 0.02482837528604119']
# ['At iteration 5 the best fitness is 0.02482837528604119']
# ['At iteration 6 the best fitness is 0.02482837528604119']
# ['At iteration 7 the best fitness is 0.024497838799898298']
# ['At iteration 8 the best fitness is 0.024497838799898298']
# ['At iteration 9 the best fitness is 0.024497838799898298']
# ['At iteration 10 the best fitness is 0.024497838799898298']
# ['At iteration 11 the best fitness is 0.024497838799898298']
# ['At iteration 12 the best fitness is 0.024497838799898298']
# ['At iteration 13 the best fitness is 0.024497838799898298']
# ['At iteration 14 the best fitness is 0.024497838799898298']
# ['At iteration 15 the best fitness is 0.024497838799898298']
# ['At iteration 16 the best fitness is 0.024497838799898298']
# ['At iteration 17 the best fitness is 0.024497838799898298']
# ['At iteration 18 the best fitness is 0.024497838799898298']
# ['At iteration 19 the best fitness is 0.024497838799898298']
# ['At iteration 20 the best fitness is 0.024497838799898298']
# ['At iteration 21 the best fitness is 0.024497838799898298']
# ['At iteration 22 the best fitness is 0.024497838799898298']
# ['At iteration 23 the best fitness is 0.024497838799898298']
# ['At iteration 24 the best fitness is 0.024497838799898298']
# ['At iteration 25 the best fitness is 0.024497838799898298']
# ['At iteration 26 the best fitness is 0.024497838799898298']
# ['At iteration 27 the best fitness is 0.024497838799898298']
# ['At iteration 28 the best fitness is 0.024497838799898298']
# ['At iteration 29 the best fitness is 0.024497838799898298']
#       Selected: 1894/3933 (48.2%), Fitness: 0.0245, Time: 497.9s
#       Modality: D=51%, S=52%, Sk=47%, V=47%
#     Test Acc: 93.52%, F1: 92.72%, Features: 1894/3933 (48.2%), Model: 4.240MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03140325451309437']
# ['At iteration 2 the best fitness is 0.025324180015255535']
# ['At iteration 3 the best fitness is 0.025324180015255535']
# ['At iteration 4 the best fitness is 0.025324180015255535']
# ['At iteration 5 the best fitness is 0.025324180015255535']
# ['At iteration 6 the best fitness is 0.025324180015255535']
# ['At iteration 7 the best fitness is 0.025324180015255535']
# ['At iteration 8 the best fitness is 0.025324180015255535']
# ['At iteration 9 the best fitness is 0.025324180015255535']
# ['At iteration 10 the best fitness is 0.025324180015255535']
# ['At iteration 11 the best fitness is 0.025324180015255535']
# ['At iteration 12 the best fitness is 0.025324180015255535']
# ['At iteration 13 the best fitness is 0.025324180015255535']
# ['At iteration 14 the best fitness is 0.025324180015255535']
# ['At iteration 15 the best fitness is 0.025298754131706076']
# ['At iteration 16 the best fitness is 0.025298754131706076']
# ['At iteration 17 the best fitness is 0.025298754131706076']
# ['At iteration 18 the best fitness is 0.025298754131706076']
# ['At iteration 19 the best fitness is 0.025298754131706076']
# ['At iteration 20 the best fitness is 0.025298754131706076']
# ['At iteration 21 the best fitness is 0.025298754131706076']
# ['At iteration 22 the best fitness is 0.025298754131706076']
# ['At iteration 23 the best fitness is 0.025298754131706076']
# ['At iteration 24 the best fitness is 0.025298754131706076']
# ['At iteration 25 the best fitness is 0.025298754131706076']
# ['At iteration 26 the best fitness is 0.025298754131706076']
# ['At iteration 27 the best fitness is 0.025298754131706076']
# ['At iteration 28 the best fitness is 0.025298754131706076']
# ['At iteration 29 the best fitness is 0.025298754131706076']
#       Selected: 1992/3933 (50.6%), Fitness: 0.0253, Time: 473.2s
#       Modality: D=50%, S=50%, Sk=51%, V=51%
#     Test Acc: 87.96%, F1: 86.10%, Features: 1992/3933 (50.6%), Model: 4.432MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03740605136028474']
# ['At iteration 2 the best fitness is 0.030869310958555853']
# ['At iteration 3 the best fitness is 0.030869310958555853']
# ['At iteration 4 the best fitness is 0.030869310958555853']
# ['At iteration 5 the best fitness is 0.030869310958555853']
# ['At iteration 6 the best fitness is 0.030869310958555853']
# ['At iteration 7 the best fitness is 0.030678616831934954']
# ['At iteration 8 the best fitness is 0.030678616831934954']
# ['At iteration 9 the best fitness is 0.030678616831934954']
# ['At iteration 10 the best fitness is 0.030398932112890967']
# ...
# ['At iteration 17 the best fitness is 0.017749555047037926']
# ['At iteration 18 the best fitness is 0.017749555047037926']
# ['At iteration 19 the best fitness is 0.017749555047037926']
# ['At iteration 20 the best fitness is 0.017457157386219214']
# ['At iteration 21 the best fitness is 0.017457157386219214']
# ['At iteration 22 the best fitness is 0.017457157386219214']
# ['At iteration 23 the best fitness is 0.017457157386219214']
# ['At iteration 24 the best fitness is 0.017457157386219214']
# ['At iteration 25 the best fitness is 0.017457157386219214']
# ['At iteration 26 the best fitness is 0.017457157386219214']
# ['At iteration 27 the best fitness is 0.017457157386219214']
# ['At iteration 28 the best fitness is 0.017457157386219214']
# ['At iteration 29 the best fitness is 0.017457157386219214']
#       Selected: 973/3933 (24.7%), Fitness: 0.0175, Time: 646.3s
#       Modality: D=23%, S=23%, Sk=24%, V=26%
#     Test Acc: 93.46%, F1: 93.22%, Features: 973/3933 (24.7%), Model: 2.442MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.031187134502924017']
# ['At iteration 1 the best fitness is 0.030831172133231673']
# ['At iteration 2 the best fitness is 0.025362318840579712']
# ['At iteration 3 the best fitness is 0.025362318840579712']
# ['At iteration 4 the best fitness is 0.025362318840579712']
# ['At iteration 5 the best fitness is 0.025362318840579712']
# ['At iteration 6 the best fitness is 0.025362318840579712']
# ['At iteration 7 the best fitness is 0.025362318840579712']
# ['At iteration 8 the best fitness is 0.025362318840579712']
# ['At iteration 9 the best fitness is 0.025362318840579712']
# ['At iteration 10 the best fitness is 0.025362318840579712']
# ['At iteration 11 the best fitness is 0.025362318840579712']
# ['At iteration 12 the best fitness is 0.025362318840579712']
# ['At iteration 13 the best fitness is 0.025362318840579712']
# ['At iteration 14 the best fitness is 0.025362318840579712']
# ['At iteration 15 the best fitness is 0.025362318840579712']
# ['At iteration 16 the best fitness is 0.025362318840579712']
# ['At iteration 17 the best fitness is 0.025362318840579712']
# ['At iteration 18 the best fitness is 0.025362318840579712']
# ['At iteration 19 the best fitness is 0.025362318840579712']
# ['At iteration 20 the best fitness is 0.025362318840579712']
# ['At iteration 21 the best fitness is 0.025362318840579712']
# ['At iteration 22 the best fitness is 0.025362318840579712']
# ['At iteration 23 the best fitness is 0.025362318840579712']
# ['At iteration 24 the best fitness is 0.025362318840579712']
# ['At iteration 25 the best fitness is 0.025362318840579712']
# ['At iteration 26 the best fitness is 0.025362318840579712']
# ['At iteration 27 the best fitness is 0.025362318840579712']
# ['At iteration 28 the best fitness is 0.025362318840579712']
# ['At iteration 29 the best fitness is 0.025362318840579712']
#       Selected: 2009/3933 (51.1%), Fitness: 0.0254, Time: 499.3s
#       Modality: D=56%, S=50%, Sk=51%, V=50%
#     Test Acc: 92.52%, F1: 91.86%, Features: 2009/3933 (51.1%), Model: 4.465MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03726620900076276']
# ['At iteration 2 the best fitness is 0.03726620900076276']
# ['At iteration 3 the best fitness is 0.03145410628019328']
# ['At iteration 4 the best fitness is 0.03145410628019328']
# ['At iteration 5 the best fitness is 0.03145410628019328']
# ['At iteration 6 the best fitness is 0.03145410628019328']
# ['At iteration 7 the best fitness is 0.03145410628019328']
# ['At iteration 8 the best fitness is 0.03145410628019328']
# ['At iteration 9 the best fitness is 0.03145410628019328']
# ['At iteration 10 the best fitness is 0.03145410628019328']
# ['At iteration 11 the best fitness is 0.031085430968726208']
# ['At iteration 12 the best fitness is 0.031085430968726208']
# ['At iteration 13 the best fitness is 0.031085430968726208']
# ['At iteration 14 the best fitness is 0.025362318840579712']
# ['At iteration 15 the best fitness is 0.025362318840579712']
# ['At iteration 16 the best fitness is 0.025362318840579712']
# ['At iteration 17 the best fitness is 0.025362318840579712']
# ['At iteration 18 the best fitness is 0.025362318840579712']
# ['At iteration 19 the best fitness is 0.025362318840579712']
# ['At iteration 20 the best fitness is 0.025362318840579712']
# ['At iteration 21 the best fitness is 0.025362318840579712']
# ['At iteration 22 the best fitness is 0.025362318840579712']
# ['At iteration 23 the best fitness is 0.025362318840579712']
# ['At iteration 24 the best fitness is 0.025362318840579712']
# ['At iteration 25 the best fitness is 0.025362318840579712']
# ['At iteration 26 the best fitness is 0.025362318840579712']
# ['At iteration 27 the best fitness is 0.025362318840579712']
# ['At iteration 28 the best fitness is 0.025362318840579712']
# ['At iteration 29 the best fitness is 0.025362318840579712']
#       Selected: 1993/3933 (50.7%), Fitness: 0.0254, Time: 470.8s
#       Modality: D=54%, S=53%, Sk=51%, V=49%
#     Test Acc: 96.26%, F1: 96.01%, Features: 1993/3933 (50.7%), Model: 4.434MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03126341215357238']
# ['At iteration 2 the best fitness is 0.030907449783880034']
# ['At iteration 3 the best fitness is 0.030335367404017332']
# ['At iteration 4 the best fitness is 0.030335367404017332']
# ['At iteration 5 the best fitness is 0.030335367404017332']
# ['At iteration 6 the best fitness is 0.030335367404017332']
# ['At iteration 7 the best fitness is 0.024841088227815916']
# ['At iteration 8 the best fitness is 0.024841088227815916']
# ['At iteration 9 the best fitness is 0.024841088227815916']
# ['At iteration 10 the best fitness is 0.024841088227815916']
# ['At iteration 11 the best fitness is 0.024790236460717013']
# ['At iteration 12 the best fitness is 0.024319857615052124']
# ['At iteration 13 the best fitness is 0.024319857615052124']
# ['At iteration 14 the best fitness is 0.024319857615052124']
# ['At iteration 15 the best fitness is 0.024319857615052124']
# ['At iteration 16 the best fitness is 0.02429443173150267']
# ['At iteration 17 the best fitness is 0.02421815408085431']
# ['At iteration 18 the best fitness is 0.02421815408085431']
# ['At iteration 19 the best fitness is 0.02418001525553013']
# ['At iteration 20 the best fitness is 0.02418001525553013']
# ['At iteration 21 the best fitness is 0.02418001525553013']
# ['At iteration 22 the best fitness is 0.02418001525553013']
# ['At iteration 23 the best fitness is 0.02418001525553013']
# ['At iteration 24 the best fitness is 0.023963895245359777']
# ['At iteration 25 the best fitness is 0.023963895245359777']
# ['At iteration 26 the best fitness is 0.023963895245359777']
# ['At iteration 27 the best fitness is 0.023963895245359777']
# ['At iteration 28 the best fitness is 0.023963895245359777']
# ['At iteration 29 the best fitness is 0.023963895245359777']
# ['At iteration 30 the best fitness is 0.023963895245359777']
#       Selected: 1947/3933 (49.5%), Fitness: 0.0240, Time: 483.3s
#       Modality: D=50%, S=47%, Sk=51%, V=49%
#     Test Acc: 94.39%, F1: 93.64%, Features: 1947/3933 (49.5%), Model: 4.344MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.031237986270022926']
# ['At iteration 2 the best fitness is 0.031237986270022926']
# ['At iteration 3 the best fitness is 0.031237986270022926']
# ['At iteration 4 the best fitness is 0.031237986270022926']
# ['At iteration 5 the best fitness is 0.031237986270022926']
# ['At iteration 6 the best fitness is 0.031237986270022926']
# ['At iteration 7 the best fitness is 0.031237986270022926']
# ['At iteration 8 the best fitness is 0.031237986270022926']
# ['At iteration 9 the best fitness is 0.031237986270022926']
# ['At iteration 10 the best fitness is 0.031237986270022926']
# ['At iteration 11 the best fitness is 0.031237986270022926']
# ['At iteration 12 the best fitness is 0.031237986270022926']
# ['At iteration 13 the best fitness is 0.031237986270022926']
# ['At iteration 14 the best fitness is 0.031237986270022926']
# ['At iteration 15 the best fitness is 0.031237986270022926']
# ['At iteration 16 the best fitness is 0.031237986270022926']
# ['At iteration 17 the best fitness is 0.031237986270022926']
# ['At iteration 18 the best fitness is 0.031237986270022926']
# ['At iteration 19 the best fitness is 0.025413170607678615']
# ['At iteration 20 the best fitness is 0.025413170607678615']
# ['At iteration 21 the best fitness is 0.025413170607678615']
# ['At iteration 22 the best fitness is 0.025413170607678615']
# ['At iteration 23 the best fitness is 0.025413170607678615']
# ['At iteration 24 the best fitness is 0.025413170607678615']
# ['At iteration 25 the best fitness is 0.025413170607678615']
# ['At iteration 26 the best fitness is 0.025108060005085177']
# ['At iteration 27 the best fitness is 0.025108060005085177']
# ['At iteration 28 the best fitness is 0.025108060005085177']
# ['At iteration 29 the best fitness is 0.025108060005085177']
# ['At iteration 30 the best fitness is 0.025108060005085177']
#       Selected: 1981/3933 (50.4%), Fitness: 0.0251, Time: 487.4s
#       Modality: D=48%, S=47%, Sk=50%, V=53%
#     Test Acc: 91.59%, F1: 90.74%, Features: 1981/3933 (50.4%), Model: 4.410MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024752097635392833']
# ['At iteration 1 the best fitness is 0.024752097635392833']
# ['At iteration 2 the best fitness is 0.024752097635392833']
# ['At iteration 3 the best fitness is 0.02151029748283753']
# ['At iteration 4 the best fitness is 0.02151029748283753']
# ['At iteration 5 the best fitness is 0.02151029748283753']
# ['At iteration 6 the best fitness is 0.02151029748283753']
# ['At iteration 7 the best fitness is 0.02151029748283753']
# ['At iteration 8 the best fitness is 0.02151029748283753']
# ['At iteration 9 the best fitness is 0.02151029748283753']
# ['At iteration 10 the best fitness is 0.02151029748283753']
# ['At iteration 11 the best fitness is 0.02151029748283753']
# ['At iteration 12 the best fitness is 0.02151029748283753']
# ['At iteration 13 the best fitness is 0.02151029748283753']
# ['At iteration 14 the best fitness is 0.02151029748283753']
# ['At iteration 15 the best fitness is 0.02151029748283753']
# ['At iteration 16 the best fitness is 0.02151029748283753']
# ['At iteration 17 the best fitness is 0.02151029748283753']
# ['At iteration 18 the best fitness is 0.02151029748283753']
# ['At iteration 19 the best fitness is 0.02151029748283753']
# ['At iteration 20 the best fitness is 0.015420798372743454']
# ['At iteration 21 the best fitness is 0.015420798372743454']
# ['At iteration 22 the best fitness is 0.015420798372743454']
# ['At iteration 23 the best fitness is 0.015420798372743454']
# ['At iteration 24 the best fitness is 0.015420798372743454']
# ['At iteration 25 the best fitness is 0.015420798372743454']
# ['At iteration 26 the best fitness is 0.015420798372743454']
# ['At iteration 27 the best fitness is 0.015420798372743454']
# ['At iteration 28 the best fitness is 0.015420798372743454']
# ['At iteration 29 the best fitness is 0.015420798372743454']
#       Selected: 1243/3933 (31.6%), Fitness: 0.0154, Time: 451.8s
#       Modality: D=29%, S=33%, Sk=32%, V=30%
#     Test Acc: 96.26%, F1: 95.93%, Features: 1243/3933 (31.6%), Model: 2.969MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03137782862954492']
# ['At iteration 2 the best fitness is 0.03121256038647347']
# ['At iteration 3 the best fitness is 0.031021866259852572']
# ['At iteration 4 the best fitness is 0.031021866259852572']
# ['At iteration 5 the best fitness is 0.03050063564708878']
# ['At iteration 6 the best fitness is 0.03050063564708878']
# ['At iteration 7 the best fitness is 0.03050063564708878']
# ['At iteration 8 the best fitness is 0.03050063564708878']
# ['At iteration 9 the best fitness is 0.03050063564708878']
# ['At iteration 10 the best fitness is 0.03050063564708878']
# ['At iteration 11 the best fitness is 0.03050063564708878']
# ['At iteration 12 the best fitness is 0.03050063564708878']
# ['At iteration 13 the best fitness is 0.030360793287566787']
# ['At iteration 14 the best fitness is 0.030360793287566787']
# ['At iteration 15 the best fitness is 0.030360793287566787']
# ['At iteration 16 the best fitness is 0.030360793287566787']
# ['At iteration 17 the best fitness is 0.030360793287566787']
# ['At iteration 18 the best fitness is 0.030360793287566787']
# ['At iteration 19 the best fitness is 0.030360793287566787']
# ['At iteration 20 the best fitness is 0.030360793287566787']
# ['At iteration 21 the best fitness is 0.03034808034579206']
# ['At iteration 22 the best fitness is 0.03034808034579206']
# ['At iteration 23 the best fitness is 0.03034808034579206']
# ['At iteration 24 the best fitness is 0.03034808034579206']
# ['At iteration 25 the best fitness is 0.03034808034579206']
# ['At iteration 26 the best fitness is 0.03034808034579206']
# ['At iteration 27 the best fitness is 0.024052885837782867']
# ['At iteration 28 the best fitness is 0.024014747012458686']
# ['At iteration 29 the best fitness is 0.024014747012458686']
#       Selected: 1924/3933 (48.9%), Fitness: 0.0240, Time: 1214.8s
#       Modality: D=53%, S=47%, Sk=49%, V=49%
#     Test Acc: 92.52%, F1: 90.52%, Features: 1924/3933 (48.9%), Model: 4.299MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03721535723366384']
# ['At iteration 1 the best fitness is 0.02940961098398167']
# ['At iteration 2 the best fitness is 0.02325654716501396']
# ['At iteration 3 the best fitness is 0.02325654716501396']
# ['At iteration 4 the best fitness is 0.02325654716501396']
# ['At iteration 5 the best fitness is 0.02325654716501396']
# ['At iteration 6 the best fitness is 0.02325654716501396']
# ['At iteration 7 the best fitness is 0.016046020849224553']
# ['At iteration 8 the best fitness is 0.016046020849224553']
# ['At iteration 9 the best fitness is 0.016046020849224553']
# ['At iteration 10 the best fitness is 0.016046020849224553']
# ['At iteration 11 the best fitness is 0.016046020849224553']
# ['At iteration 12 the best fitness is 0.016046020849224553']
# ['At iteration 13 the best fitness is 0.016046020849224553']
# ['At iteration 14 the best fitness is 0.016046020849224553']
# ['At iteration 15 the best fitness is 0.016046020849224553']
# ['At iteration 16 the best fitness is 0.016046020849224553']
# ['At iteration 17 the best fitness is 0.016046020849224553']
# ['At iteration 18 the best fitness is 0.016046020849224553']
# ['At iteration 19 the best fitness is 0.016046020849224553']
# ['At iteration 20 the best fitness is 0.016046020849224553']
# ['At iteration 21 the best fitness is 0.016046020849224553']
# ['At iteration 22 the best fitness is 0.016046020849224553']
# ['At iteration 23 the best fitness is 0.016046020849224553']
# ['At iteration 24 the best fitness is 0.016046020849224553']
# ['At iteration 25 the best fitness is 0.016046020849224553']
# ['At iteration 26 the best fitness is 0.016046020849224553']
# ['At iteration 27 the best fitness is 0.016046020849224553']
# ['At iteration 28 the best fitness is 0.016046020849224553']
# ['At iteration 29 the best fitness is 0.016046020849224553']
#       Selected: 851/3933 (21.6%), Fitness: 0.0160, Time: 389.1s
#       Modality: D=22%, S=22%, Sk=22%, V=22%
#     Test Acc: 91.59%, F1: 91.58%, Features: 851/3933 (21.6%), Model: 2.203MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_new_5_loss/all_results_per_fold.csv
# Shape: (144, 28)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            89.8148           98.6667       89.0370          89.0370              89.4856           89.8148               3933            3933               100.0000       0.0000          9.5119          9.5119       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 1      baseline     2            93.5185           99.3333       92.9111          92.9111              95.6966           93.5185               3933            3933               100.0000       0.0000          8.5660          8.5660       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 2      baseline     3            91.6667           98.0000       90.9005          90.9005              95.0794           91.6667               3933            3933               100.0000       0.0000         10.6977         10.6977       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 3      baseline     4            85.1852          100.0000       82.4908          82.4908              87.6955           85.1852               3933            3933               100.0000       0.0000         10.1746         10.1746       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 4      baseline     5            81.4815           98.6667       79.0832          79.0832              82.7925           81.4815               3933            3933               100.0000       0.0000         10.4531         10.4531       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 5      baseline     6            91.5888           99.3333       90.4890          90.4001              93.9683           91.6667               3933            3933               100.0000       0.0000         10.4680         10.4680       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 6      baseline     7            93.4579          100.0000       93.3198          93.2573              96.7078           93.5185               3933            3933               100.0000       0.0000         10.2760         10.2760       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 7      baseline     8            96.2617           99.3333       96.2257          96.1905              97.5309           96.2963               3933            3933               100.0000       0.0000         10.4985         10.4985       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 8   mutual_info     1            92.5926           98.6667       91.0170          91.0170              90.6173           92.5926               1966            3933                49.9873      21.6939          6.4362         28.1302       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              18.9815              41               59.5092              388                 43.1003                709              58.3099             828
# 9   mutual_info     2            87.0370           98.6667       86.0828          86.0828              90.0794           87.0370               1966            3933                49.9873      21.6357          7.7930         29.4288       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              19.9074              43               57.6687              376                 44.5593                733              57.3239             814
# 10  mutual_info     3            87.0370           96.0000       85.2404          85.2404              89.2181           87.0370               1966            3933                49.9873      21.1413          7.2751         28.4165       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              17.1296              37               58.1288              379                 44.3161                729              57.8169             821
# 11  mutual_info     4            87.0370           99.3333       84.6561          84.6561              84.1975           87.0370               1966            3933                49.9873      21.4019          7.7865         29.1884       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              16.2037              35               58.5890              382                 45.1064                742              56.8310             807
# 12  mutual_info     5            85.1852           98.6667       84.7090          84.7090              85.8951           85.1852               1966            3933                49.9873      21.6158          7.9225         29.5384       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              18.5185              40               57.5153              375                 45.2888                745              56.7606             806
# 13  mutual_info     6            95.3271           99.3333       95.2851          95.2411              96.7901           95.3704               1966            3933                49.9873      21.7236          8.0273         29.7510       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              19.9074              43               59.5092              388                 43.4650                715              57.7465             820
# 14  mutual_info     7            87.8505           98.6667       87.0628          86.9419              91.5638           87.9630               1966            3933                49.9873      21.0161          7.8511         28.8672       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              22.6852              49               58.5890              382                 44.6201                734              56.4085             801
# 15  mutual_info     8            98.1308           98.6667       98.1188          98.1012              98.5185           98.1481               1966            3933                49.9873      21.5972          8.0059         29.6032       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              21.2963              46               57.6687              376                 45.1672                743              56.4085             801
# 16          rfe     1            97.2222           99.3333       97.1429          97.1429              97.5309           97.2222               1966            3933                49.9873       4.0853          7.7441         11.8298       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              74.0741             160               60.8896              397                 41.0942                676              51.6197             733
# 17          rfe     2            95.3704           98.6667       95.2028          95.2028              96.5432           95.3704               1966            3933                49.9873       4.1085          7.9226         12.0314       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727             100.0000             216               59.2025              386                 36.0486                593              54.2958             771
# 18          rfe     3            88.8889           99.3333       87.3960          87.3960              90.3233           88.8889               1966            3933                49.9873       4.1776          7.6666         11.8444       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              89.3519             193               58.1288              379                 37.9939                625              54.1549             769
# 19          rfe     4            87.0370           99.3333       85.9298          85.9298              89.5523           87.0370               1966            3933                49.9873       4.0477          7.9892         12.0371       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              87.0370             188               62.8834              410                 41.1550                677              48.6620             691

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              90.37              4.83              89.31              5.76                 3933.00                      100.00              0.00                10.08                10.08          2154011.0                  8.22                        0.00               67.05
# mutual_info              90.02              4.71              89.02              5.22                 1966.00                       49.99             21.48                 7.64                29.12          1146907.0                  4.38                       50.01               44.47
#         rfe              91.64              4.80              90.76              5.37                 1966.00                       49.99              4.10                 7.90                12.00          1146907.0                  4.38                       50.01               44.47
#       lasso              74.48             16.21              72.78             15.83                 1966.00                       49.99              1.24                 7.94                 9.19          1146907.0                  4.38                       50.01               44.47
#    meta_BAT              85.39             12.56              84.44             12.16                 1935.25                       49.21            500.91                 7.97               508.89          1131163.0                  4.32                       50.79               44.52
#     meta_CS              86.55             13.56              85.89             13.34                 1939.38                       49.31            985.65                 8.02               993.67          1133275.0                  4.33                       50.69               44.49
#     meta_DE              89.09              4.78              87.79              5.28                 1930.88                       49.09            499.32                 7.96               507.29          1128923.0                  4.31                       50.91               44.47
#    meta_FFA              88.63             10.64              87.86             10.86                 1954.88                       49.70            481.77                 8.01               489.78          1141211.0                  4.36                       50.30               44.49
#     meta_GA              88.05              8.05              87.47              8.06                 1938.00                       49.28            481.65                 7.96               489.61          1132571.0                  4.33                       50.72               44.47
#    meta_GWO              89.45              6.75              88.70              7.31                 1480.00                       37.63            470.53                 7.47               478.00           898075.0                  3.43                       62.37               38.13
#    meta_HHO              82.95             20.12              82.78             19.15                 1098.75                       27.94            614.64                 7.18               621.81           702875.0                  2.69                       72.06               33.91
#   meta_JAYA              89.21              5.12              88.31              5.68                 1936.12                       49.23            499.06                 7.97               507.03          1131611.0                  4.32                       50.77               44.49
#    meta_MFO              87.13             11.17              86.80             10.01                 1975.00                       50.22            473.46                 8.03               481.49          1151515.0                  4.40                       49.78               44.52
#    meta_MVO              89.44              4.52              88.44              5.29                 1934.88                       49.20            485.71                 8.00               493.71          1130971.0                  4.32                       50.80               44.47
#    meta_PSO              90.02              4.80              89.38              4.92                 1896.38                       48.22            485.13                 7.91               493.04          1111259.0                  4.24                       51.78               44.32
#    meta_SCA              88.51              4.88              87.41              5.66                  899.12                       22.86            441.06                 7.03               448.09           600667.0                  2.30                       77.14               31.53
#    meta_SSA              87.70              8.14              86.40              8.52                 1926.25                       48.98           1211.77                 7.95              1219.72          1126555.0                  4.30                       51.02               44.48
#    meta_WOA              88.97              3.39              87.87              3.85                 1166.25                       29.65            431.29                 6.88               438.17           737435.0                  2.82                       70.35               34.66

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 90.02% vs Baseline: 90.37%
#   Paired t-test: t=-0.2226, p=0.8302
#   Wilcoxon test: W=15.0000, p=0.7422
#   -> worse, Not significant
#
# RFE vs BASELINE:
#   Method: 91.64% vs Baseline: 90.37%
#   Paired t-test: t=1.0156, p=0.3436
#   Wilcoxon test: W=10.0000, p=0.5469
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 74.48% vs Baseline: 90.37%
#   Paired t-test: t=-3.4638, p=0.0105
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 85.39% vs Baseline: 90.37%
#   Paired t-test: t=-1.6232, p=0.1486
#   Wilcoxon test: W=1.0000, p=0.0312
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 86.55% vs Baseline: 90.37%
#   Paired t-test: t=-1.0746, p=0.3182
#   Wilcoxon test: W=9.0000, p=0.4688
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 89.09% vs Baseline: 90.37%
#   Paired t-test: t=-1.4886, p=0.1802
#   Wilcoxon test: W=6.5000, p=0.2344
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 88.63% vs Baseline: 90.37%
#   Paired t-test: t=-0.6913, p=0.5117
#   Wilcoxon test: W=18.0000, p=1.0000
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 88.05% vs Baseline: 90.37%
#   Paired t-test: t=-1.4986, p=0.1776
#   Wilcoxon test: W=7.0000, p=0.1406
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 89.45% vs Baseline: 90.37%
#   Paired t-test: t=-0.9658, p=0.3663
#   Wilcoxon test: W=8.0000, p=0.3750
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 82.95% vs Baseline: 90.37%
#   Paired t-test: t=-1.2628, p=0.2471
#   Wilcoxon test: W=4.0000, p=0.0547
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 89.21% vs Baseline: 90.37%
#   Paired t-test: t=-1.0936, p=0.3103
#   Wilcoxon test: W=3.0000, p=0.3125
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 87.13% vs Baseline: 90.37%
#   Paired t-test: t=-1.1682, p=0.2810
#   Wilcoxon test: W=5.0000, p=0.3125
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 89.44% vs Baseline: 90.37%
#   Paired t-test: t=-0.9351, p=0.3808
#   Wilcoxon test: W=11.0000, p=0.3828
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 90.02% vs Baseline: 90.37%
#   Paired t-test: t=-0.3536, p=0.7340
#   Wilcoxon test: W=12.5000, p=0.8438
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 88.51% vs Baseline: 90.37%
#   Paired t-test: t=-0.8841, p=0.4060
#   Wilcoxon test: W=7.0000, p=0.2969
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 87.70% vs Baseline: 90.37%
#   Paired t-test: t=-1.5621, p=0.1622
#   Wilcoxon test: W=4.0000, p=0.1094
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 88.97% vs Baseline: 90.37%
#   Paired t-test: t=-1.0138, p=0.3444
#   Wilcoxon test: W=10.0000, p=0.3125
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_new_5_loss
#
# Per-method folders:
#   results_new_5_loss/baseline/ (16 files)
#   results_new_5_loss/mutual_info/ (16 files)
#   results_new_5_loss/rfe/ (16 files)
#   results_new_5_loss/lasso/ (16 files)
#   results_new_5_loss/meta_BAT/ (16 files)
#   results_new_5_loss/meta_CS/ (16 files)
#   results_new_5_loss/meta_DE/ (16 files)
#   results_new_5_loss/meta_FFA/ (16 files)
#   results_new_5_loss/meta_GA/ (16 files)
#   results_new_5_loss/meta_GWO/ (16 files)
#   results_new_5_loss/meta_HHO/ (16 files)
#   results_new_5_loss/meta_JAYA/ (16 files)
#   results_new_5_loss/meta_MFO/ (16 files)
#   results_new_5_loss/meta_MVO/ (16 files)
#   results_new_5_loss/meta_PSO/ (16 files)
#   results_new_5_loss/meta_SCA/ (16 files)
#   results_new_5_loss/meta_SSA/ (16 files)
#   results_new_5_loss/meta_WOA/ (16 files)
#
# Plots directory: results_new_5_loss/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 91.64% ± 4.80% (Features: 50.0%)
#   baseline            : 90.37% ± 4.83% (Features: 100.0%)
#   mutual_info         : 90.02% ± 4.71% (Features: 50.0%)
#   meta_PSO            : 90.02% ± 4.80% (Features: 48.2%)
#   meta_GWO            : 89.45% ± 6.75% (Features: 37.6%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_FFA
#     Test Accuracy:      94.44%
#     Feature Retention:  49.63% (1952/3933)
#     Modality Retention: depth=48.1%, sensor=50.8%, skeleton=49.5%, video=49.4%
#
#   Fold 2: Best = meta_CS
#     Test Accuracy:      93.52%
#     Feature Retention:  48.54% (1909/3933)
#     Modality Retention: depth=45.4%, sensor=48.3%, skeleton=49.8%, video=47.7%
#
#   Fold 3: Best = meta_FFA
#     Test Accuracy:      94.44%
#     Feature Retention:  49.12% (1932/3933)
#     Modality Retention: depth=48.1%, sensor=51.7%, skeleton=48.3%, video=49.0%
#
#   Fold 4: Best = meta_MFO
#     Test Accuracy:      88.89%
#     Feature Retention:  49.71% (1955/3933)
#     Modality Retention: depth=52.8%, sensor=50.0%, skeleton=49.0%, video=49.9%
#
#   Fold 5: Best = meta_SCA
#     Test Accuracy:      91.67%
#     Feature Retention:  30.92% (1216/3933)
#     Modality Retention: depth=32.9%, sensor=31.3%, skeleton=30.4%, video=31.1%
#
#   Fold 6: Best = meta_CS
#     Test Accuracy:      95.33%
#     Feature Retention:  50.44% (1984/3933)
#     Modality Retention: depth=53.7%, sensor=50.0%, skeleton=50.2%, video=50.5%
#
#   Fold 7: Best = meta_GWO
#     Test Accuracy:      93.46%
#     Feature Retention:  43.45% (1709/3933)
#     Modality Retention: depth=45.8%, sensor=44.3%, skeleton=43.4%, video=42.7%
#
#   Fold 8: Best = meta_FFA
#     Test Accuracy:      97.20%
#     Feature Retention:  49.45% (1945/3933)
#     Modality Retention: depth=50.9%, sensor=51.2%, skeleton=48.4%, video=49.6%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     93.62% ± 2.49%
#   Average Feature Retention: 46.41% ± 6.63%
#
#   Average Modality-wise Feature Retention:
#          depth: 47.22% ± 6.54%
#         sensor: 47.20% ± 6.84%
#       skeleton: 46.12% ± 6.70%
#          video: 46.25% ± 6.61%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)  video Retention (%)
#     1           meta_FFA              94.44                  49.63                48.15                 50.77                   49.54                49.44
#     2            meta_CS              93.52                  48.54                45.37                 48.31                   49.79                47.68
#     3           meta_FFA              94.44                  49.12                48.15                 51.69                   48.33                49.01
#     4           meta_MFO              88.89                  49.71                52.78                 50.00                   49.00                49.93
#     5           meta_SCA              91.67                  30.92                32.87                 31.29                   30.40                31.06
#     6            meta_CS              95.33                  50.44                53.70                 50.00                   50.15                50.49
#     7           meta_GWO              93.46                  43.45                45.83                 44.33                   43.40                42.75
#     8           meta_FFA              97.20                  49.45                50.93                 51.23                   48.39                49.65
#
# Saved to: results_new_5_loss/best_metaheuristic_per_fold.csv
