# %% [markdown]
# # File 1: Weighted Early Fusion — Learn Modality Weights
#
# **Goal:** Instead of simple concatenation (equal contribution), learn optimal per-modality
# scalar weights using all 14 EvoloPy metaheuristics.
#
# **Search space:** 4 continuous values in [0, 1] — one weight per modality (depth, sensor, skeleton, video).
#
# **Pipeline per fold:**
# 1. Metaheuristic optimizes `[w_depth, w_sensor, w_skeleton, w_video]` using quick fitness evaluations
# 2. Apply learned weights → train full classifier → evaluate
#
# **Outputs saved:**
# - Best weights per fold (per optimizer)
# - Best-overall weights per fold (best optimizer chosen per fold by val accuracy)
# - Baseline (unweighted) results for comparison
# - All results CSVs, plots, and a `best_weights_per_fold.pkl` for File 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# EvoloPy imports
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new")

RESULTS_ROOT = Path("results_weighted_fusion")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Training hyperparameters (same as original)
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001

# Metaheuristic hyperparameters
N_POPULATION = 20
MAX_ITERATIONS = 30
FITNESS_EPOCHS = 15  # quick training during fitness evaluation

# All 14 EvoloPy optimizers
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline'] + [f'weighted_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  Fitness epochs: {FITNESS_EPOCHS}")
print(f"  Optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Metaheuristic pop: 20, iter: 30
#   Fitness epochs: 15
#   Optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 15

# %% [markdown]
# ## Load Data

# %%
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")

print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

first_sample = X_feat[0]
FEATURE_DIMS = {
    'depth': first_sample['depth_feat'].shape[0],
    'sensor': first_sample['sensor_feat'].shape[0],
    'skeleton': first_sample['skeleton_feat'].shape[0],
    'video': first_sample['video_feat'].shape[0]
}
MODALITY_NAMES = list(FEATURE_DIMS.keys())
MODALITY_DIMS = list(FEATURE_DIMS.values())
TOTAL_FEATURES = sum(MODALITY_DIMS)
N_MODALITIES = len(MODALITY_NAMES)

print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   video: 1420
#   TOTAL: 3933

# %% [markdown]
# ## Model & Dataset

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (same as original)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)


print("Model and dataset defined")
# Out:
# Model and dataset defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list):
    """Concatenate all modality features into unified vector (no weighting)"""
    unified = []
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        unified.append(feat_vector)
    return np.array(unified)


def apply_modality_weights(X, weights):
    """Apply per-modality scalar weights to concatenated feature matrix.
    
    Args:
        X: (N, TOTAL_FEATURES) — already concatenated and scaled
        weights: (N_MODALITIES,) — one weight per modality
    Returns:
        Weighted copy of X
    """
    X_weighted = X.copy()
    start_idx = 0
    for i, dim in enumerate(MODALITY_DIMS):
        end_idx = start_idx + dim
        X_weighted[:, start_idx:end_idx] *= weights[i]
        start_idx = end_idx
    return X_weighted


def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)


print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Fitness Function & Quick Training

# %%
def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation.
    Returns val_loss (continuous) and val_acc.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


def create_fitness_modality_weights(X_train, y_train, X_val, y_val, num_classes):
    """Fitness function for optimizing 4 modality weights.
    
    Uses VALIDATION LOSS (continuous) instead of (1 - accuracy).
    
    Why: With only 4 dimensions and ~107 val samples, many weight
    combinations achieve 100% val accuracy -> fitness=0.0 -> optimizer
    cannot differentiate. Val loss is continuous and always provides
    a gradient signal even when accuracy is saturated.
    """
    eval_count = [0]
    
    def fitness(solution):
        try:
            weights = np.clip(solution, 0.0, 1.0)
            
            # Apply modality weights
            X_tr_w = apply_modality_weights(X_train, weights)
            X_val_w = apply_modality_weights(X_val, weights)
            
            train_ds = MultiModalDataset(X_tr_w, y_train)
            val_ds = MultiModalDataset(X_val_w, y_val)
            train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE)
            
            model = SimpleNN(TOTAL_FEATURES, num_classes).to(DEVICE)
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=FITNESS_EPOCHS, lr=1e-3, device=DEVICE
            )
            
            del model, train_ds, val_ds, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Use val_loss directly as fitness (continuous, always differentiable)
            # Even when accuracy=100%, loss still varies between solutions
            fitness_val = val_loss
            return fitness_val
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 100.0
    
    return fitness


def run_weight_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run a single metaheuristic to optimize modality weights."""
    print(f"    Running weighted_{optimizer_name}...")
    print(f"      Search dim: {N_MODALITIES}, Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_modality_weights(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, N_MODALITIES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    learned_weights = np.clip(solution.bestIndividual, 0.0, 1.0)
    convergence = (solution.convergence.tolist()
                   if hasattr(solution.convergence, 'tolist')
                   else list(solution.convergence))
    
    results = {
        'modality_weights': learned_weights,
        'convergence': convergence,
        'best_fitness': float(convergence[-1]) if len(convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'method': f'weighted_{optimizer_name}'
    }
    
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={learned_weights[i]:.3f}" for i in range(N_MODALITIES)])
    print(f"      Weights: {w_str}")
    print(f"      Best fitness: {results['best_fitness']:.6f}, Time: {exec_time:.1f}s")
    
    return results


print("Fitness function and weight optimizer runner defined")
print("NOTE: Using val_loss as fitness (continuous signal, not accuracy)")
# Out:
# Fitness function and weight optimizer runner defined
# NOTE: Using val_loss as fitness (continuous signal, not accuracy)

# %% [markdown]
# ## Full Training & Evaluation

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics (same as original)"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_val_loss = float('inf')
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)
        epoch_val_acc = val_correct / val_total

        # Also track val loss for this epoch
        epoch_val_loss = 0.0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                labels = labels.to(DEVICE)
                outputs = model(features)
                epoch_val_loss += nn.CrossEntropyLoss()(outputs, labels).item()
        epoch_val_loss /= len(val_loader)

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_val_loss = epoch_val_loss
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'val_loss': best_val_loss,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics


print("Full train/eval function defined")
# Out:
# Full train/eval function defined

# %% [markdown]
# ## Main Experiment Runner

# %%
def run_weighted_fusion_all_folds():
    """
    Run baseline + 14 weighted metaheuristics across all 8 LOSO folds.
    """
    print("=" * 80)
    print("WEIGHTED EARLY FUSION: MODALITY WEIGHT OPTIMIZATION")
    print(f"Methods: baseline + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("=" * 80)
    
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    master_results = {m: {} for m in ALL_METHODS}
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#' * 80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#' * 80}")
        
        # Split
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Reserve 1 subject for validation (same as original)
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]
        val_mask = subjects[train_val_idx] == val_subject
        train_mask = ~val_mask
        
        X_train, y_train = X_train_val[train_mask], y_train_val[train_mask]
        X_val, y_val = X_train_val[val_mask], y_train_val[val_mask]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =================================================================
        # Run each method
        # =================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            if method_name == 'baseline':
                # No weighting — simple concatenation
                modality_weights = np.ones(N_MODALITIES)
                weight_results = {
                    'modality_weights': modality_weights,
                    'execution_time': 0,
                    'convergence': None,
                    'best_fitness': None,
                    'method': 'baseline'
                }
            else:
                opt_name = method_name.replace('weighted_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                weight_results = run_weight_optimizer(
                    opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes
                )
                modality_weights = weight_results['modality_weights']
            
            fs_time = time.time() - fs_start_time
            
            # Apply weights
            X_train_w = apply_modality_weights(X_train, modality_weights)
            X_val_w = apply_modality_weights(X_val, modality_weights)
            X_test_w = apply_modality_weights(X_test, modality_weights)
            
            # Build and train final model
            model = SimpleNN(TOTAL_FEATURES, num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_w, y_train)
            val_dataset = MultiModalDataset(X_val_w, y_val)
            test_dataset = MultiModalDataset(X_test_w, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Compile fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                'val_acc': eval_metrics['val_acc'],
                'val_loss': eval_metrics['val_loss'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                'modality_weights': modality_weights,
                'weight_optimization_time': weight_results['execution_time'],
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': weight_results.get('convergence', None),
                'best_fitness': weight_results.get('best_fitness', None),
                'test_preds': eval_metrics['test_preds'],
                'test_true': eval_metrics['test_true'],
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items()
                         if k not in ['test_preds', 'test_true']}
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            # Save weights as npy for easy loading
            np.save(fold_dir / f"fold_{fold_idx+1}_weights.npy", modality_weights)
            
            w_str = ', '.join([f"{MODALITY_NAMES[i]}={modality_weights[i]:.3f}" for i in range(N_MODALITIES)])
            print(f"    Weights: [{w_str}]")
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'=' * 80}")
    print("ALL WEIGHTED FUSION EXPERIMENTS COMPLETED")
    print(f"{'=' * 80}")
    
    return master_results


print("Main experiment runner defined")
# Out:
# Main experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_weighted_fusion_all_folds()
# Out:
# ================================================================================
# WEIGHTED EARLY FUSION: MODALITY WEIGHT OPTIMIZATION
# Methods: baseline + 14 metaheuristics = 15 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#
#   --- BASELINE ---
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000, video=1.000]
#     Test Acc: 95.37%, F1: 94.53%, Model: 8.223MB
#
#   --- WEIGHTED_BAT ---
#     Running weighted_BAT...
#       Search dim: 4, Pop: 20, Iter: 30
# BAT is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.12641067244112492']
# ['At iteration 1 the best fitness is 0.12641067244112492']
# ['At iteration 2 the best fitness is 0.12641067244112492']
# ['At iteration 3 the best fitness is 0.11619953624904156']
# ['At iteration 4 the best fitness is 0.11619953624904156']
# ['At iteration 5 the best fitness is 0.11619953624904156']
# ['At iteration 6 the best fitness is 0.11446900945156813']
# ['At iteration 7 the best fitness is 0.11186151579022408']
# ['At iteration 8 the best fitness is 0.11186151579022408']
# ['At iteration 9 the best fitness is 0.11186151579022408']
# ['At iteration 10 the best fitness is 0.11186151579022408']
# ['At iteration 11 the best fitness is 0.11186151579022408']
# ['At iteration 12 the best fitness is 0.11186151579022408']
# ['At iteration 13 the best fitness is 0.11186151579022408']
# ['At iteration 14 the best fitness is 0.11186151579022408']
# ['At iteration 15 the best fitness is 0.11186151579022408']
# ['At iteration 16 the best fitness is 0.11186151579022408']
# ['At iteration 17 the best fitness is 0.11186151579022408']
# ['At iteration 18 the best fitness is 0.11186151579022408']
# ['At iteration 19 the best fitness is 0.11186151579022408']
# ['At iteration 20 the best fitness is 0.11186151579022408']
# ['At iteration 21 the best fitness is 0.11186151579022408']
# ['At iteration 22 the best fitness is 0.10921102296561003']
# ['At iteration 23 the best fitness is 0.10876189265400171']
# ['At iteration 24 the best fitness is 0.10876189265400171']
# ['At iteration 25 the best fitness is 0.10876189265400171']
# ['At iteration 26 the best fitness is 0.10876189265400171']
# ['At iteration 27 the best fitness is 0.10876189265400171']
# ['At iteration 28 the best fitness is 0.10876189265400171']
# ['At iteration 29 the best fitness is 0.10848594270646572']
#       Weights: depth=0.000, sensor=0.080, skeleton=0.375, video=0.000
#       Best fitness: 0.108486, Time: 268.5s
#     Weights: [depth=0.000, sensor=0.080, skeleton=0.375, video=0.000]
#     Test Acc: 93.52%, F1: 92.64%, Model: 8.223MB
#
#   --- WEIGHTED_CS ---
#     Running weighted_CS...
#       Search dim: 4, Pop: 20, Iter: 30
# CS is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.11424455977976322']
# ['At iteration 10 the best fitness is 0.0892692906782031']
# ['At iteration 20 the best fitness is 0.0892692906782031']
#       Weights: depth=0.587, sensor=0.438, skeleton=0.884, video=0.121
#       Best fitness: 0.089269, Time: 536.6s
#     Weights: [depth=0.587, sensor=0.438, skeleton=0.884, video=0.121]
#     Test Acc: 92.59%, F1: 91.95%, Model: 8.223MB
#
#   --- WEIGHTED_DE ---
#     Running weighted_DE...
#       Search dim: 4, Pop: 20, Iter: 30
# DE is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.12472992576658726']
# ['At iteration 2 the best fitness is 0.12472992576658726']
# ['At iteration 3 the best fitness is 0.12472992576658726']
# ['At iteration 4 the best fitness is 0.12472992576658726']
# ['At iteration 5 the best fitness is 0.11064301151782274']
# ['At iteration 6 the best fitness is 0.11064301151782274']
# ['At iteration 7 the best fitness is 0.08949968311935663']
# ['At iteration 8 the best fitness is 0.08949968311935663']
# ['At iteration 9 the best fitness is 0.08949968311935663']
# ['At iteration 10 the best fitness is 0.08949968311935663']
# ['At iteration 11 the best fitness is 0.08949968311935663']
# ['At iteration 12 the best fitness is 0.08949968311935663']
# ['At iteration 13 the best fitness is 0.08949968311935663']
# ['At iteration 14 the best fitness is 0.08949968311935663']
# ['At iteration 15 the best fitness is 0.08949968311935663']
# ['At iteration 16 the best fitness is 0.08949968311935663']
# ['At iteration 17 the best fitness is 0.08949968311935663']
# ['At iteration 18 the best fitness is 0.08949968311935663']
# ['At iteration 19 the best fitness is 0.08949968311935663']
# ['At iteration 20 the best fitness is 0.08949968311935663']
# ['At iteration 21 the best fitness is 0.08949968311935663']
# ['At iteration 22 the best fitness is 0.08949968311935663']
# ['At iteration 23 the best fitness is 0.08949968311935663']
# ['At iteration 24 the best fitness is 0.08949968311935663']
# ['At iteration 25 the best fitness is 0.08949968311935663']
# ['At iteration 26 the best fitness is 0.08949968311935663']
# ['At iteration 27 the best fitness is 0.08514769654721022']
# ['At iteration 28 the best fitness is 0.08514769654721022']
# ['At iteration 29 the best fitness is 0.08514769654721022']
# ['At iteration 30 the best fitness is 0.08514769654721022']
#       Weights: depth=0.250, sensor=0.391, skeleton=0.858, video=0.000
#       Best fitness: 0.085148, Time: 272.7s
#     Weights: [depth=0.250, sensor=0.391, skeleton=0.858, video=0.000]
#     Test Acc: 94.44%, F1: 93.83%, Model: 8.223MB
#
#   --- WEIGHTED_FFA ---
#     Running weighted_FFA...
#       Search dim: 4, Pop: 20, Iter: 30
# FFA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.14589242450892925']
# ['At iteration 1 the best fitness is 0.12253074161708355']
# ['At iteration 2 the best fitness is 0.11181014310568571']
# ['At iteration 3 the best fitness is 0.09583420027047396']
# ['At iteration 4 the best fitness is 0.11109111830592155']
# ['At iteration 5 the best fitness is 0.11137138865888119']
# ['At iteration 6 the best fitness is 0.10823117755353451']
# ['At iteration 7 the best fitness is 0.10042607132345438']
# ['At iteration 8 the best fitness is 0.11575968749821186']
# ['At iteration 9 the best fitness is 0.1146203326061368']
# ['At iteration 10 the best fitness is 0.11487584933638573']
# ['At iteration 11 the best fitness is 0.10966116469353437']
# ['At iteration 12 the best fitness is 0.1124236136674881']
# ['At iteration 13 the best fitness is 0.10829856898635626']
# ['At iteration 14 the best fitness is 0.10179845429956913']
# ['At iteration 15 the best fitness is 0.09967965446412563']
# ['At iteration 16 the best fitness is 0.11523518152534962']
# ['At iteration 17 the best fitness is 0.11411906406283379']
# ['At iteration 18 the best fitness is 0.10340751148760319']
# ['At iteration 19 the best fitness is 0.12102738674730062']
# ['At iteration 20 the best fitness is 0.12440001405775547']
# ['At iteration 21 the best fitness is 0.104623693972826']
# ['At iteration 22 the best fitness is 0.10592096578329802']
# ['At iteration 23 the best fitness is 0.10934361349791288']
# ['At iteration 24 the best fitness is 0.11882071103900671']
# ['At iteration 25 the best fitness is 0.11597638577222824']
# ['At iteration 26 the best fitness is 0.1029440350830555']
# ['At iteration 27 the best fitness is 0.12179025821387768']
# ['At iteration 28 the best fitness is 0.11345546133816242']
# ['At iteration 29 the best fitness is 0.11000287253409624']
#       Weights: depth=0.229, sensor=0.374, skeleton=0.415, video=0.000
#       Best fitness: 0.110003, Time: 263.8s
#     Weights: [depth=0.229, sensor=0.374, skeleton=0.415, video=0.000]
#     Test Acc: 92.59%, F1: 91.30%, Model: 8.223MB
#
#   --- WEIGHTED_GA ---
#     Running weighted_GA...
#       Search dim: 4, Pop: 20, Iter: 30
# GA is optimizing  "fitness"
# At iteration 1 the best fitness is 0.1260542795062065
# At iteration 2 the best fitness is 0.11832676362246275
# At iteration 3 the best fitness is 0.1139074731618166
# At iteration 4 the best fitness is 0.12068102322518826
# At iteration 5 the best fitness is 0.11541168857365847
# At iteration 6 the best fitness is 0.1047139996662736
# At iteration 7 the best fitness is 0.10993831418454647
# At iteration 8 the best fitness is 0.11337293311953545
# At iteration 9 the best fitness is 0.11826231051236391
# At iteration 10 the best fitness is 0.10605979058891535
# At iteration 11 the best fitness is 0.11645262874662876
# At iteration 12 the best fitness is 0.08855130709707737
# At iteration 13 the best fitness is 0.10010145325213671
# At iteration 14 the best fitness is 0.12673091143369675
# At iteration 15 the best fitness is 0.12054958287626505
# At iteration 16 the best fitness is 0.11413975618779659
# At iteration 17 the best fitness is 0.10835684090852737
# At iteration 18 the best fitness is 0.11341489106416702
# At iteration 19 the best fitness is 0.10427145473659039
# At iteration 20 the best fitness is 0.10930105019360781
# At iteration 21 the best fitness is 0.11701235361397266
# At iteration 22 the best fitness is 0.10824293456971645
# At iteration 23 the best fitness is 0.11312682926654816
# At iteration 24 the best fitness is 0.12634461745619774
# At iteration 25 the best fitness is 0.11011922918260098
# At iteration 26 the best fitness is 0.10407892055809498
# At iteration 27 the best fitness is 0.12582511827349663
# At iteration 28 the best fitness is 0.12400544341653585
# At iteration 29 the best fitness is 0.11321743112057447
# At iteration 30 the best fitness is 0.1050259917974472
#       Weights: depth=0.078, sensor=0.192, skeleton=0.686, video=0.047
#       Best fitness: 0.105026, Time: 262.6s
#     Weights: [depth=0.078, sensor=0.192, skeleton=0.686, video=0.047]
#     Test Acc: 96.30%, F1: 96.28%, Model: 8.223MB
#
#   --- WEIGHTED_GWO ---
#     Running weighted_GWO...
#       Search dim: 4, Pop: 20, Iter: 30
# GWO is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.14590905979275703']
# ['At iteration 1 the best fitness is 0.14361980557441711']
# ['At iteration 2 the best fitness is 0.11958130821585655']
# ['At iteration 3 the best fitness is 0.11958130821585655']
# ['At iteration 4 the best fitness is 0.10507545806467533']
# ['At iteration 5 the best fitness is 0.1042528823018074']
# ['At iteration 6 the best fitness is 0.1042528823018074']
# ['At iteration 7 the best fitness is 0.1042528823018074']
# ['At iteration 8 the best fitness is 0.1042528823018074']
# ['At iteration 9 the best fitness is 0.1042528823018074']
# ['At iteration 10 the best fitness is 0.1042528823018074']
# ['At iteration 11 the best fitness is 0.1042528823018074']
# ['At iteration 12 the best fitness is 0.1042528823018074']
# ['At iteration 13 the best fitness is 0.0998707078397274']
# ['At iteration 14 the best fitness is 0.0998707078397274']
# ['At iteration 15 the best fitness is 0.0998707078397274']
# ['At iteration 16 the best fitness is 0.09326403215527534']
# ['At iteration 17 the best fitness is 0.09326403215527534']
# ['At iteration 18 the best fitness is 0.09326403215527534']
# ['At iteration 19 the best fitness is 0.09326403215527534']
# ['At iteration 20 the best fitness is 0.09326403215527534']
# ['At iteration 21 the best fitness is 0.09326403215527534']
# ['At iteration 22 the best fitness is 0.09326403215527534']
# ['At iteration 23 the best fitness is 0.09058608952909708']
# ['At iteration 24 the best fitness is 0.09058608952909708']
# ['At iteration 25 the best fitness is 0.09058608952909708']
# ['At iteration 26 the best fitness is 0.09058608952909708']
# ['At iteration 27 the best fitness is 0.09058608952909708']
# ['At iteration 28 the best fitness is 0.09058608952909708']
# ['At iteration 29 the best fitness is 0.09058608952909708']
#       Weights: depth=0.867, sensor=0.440, skeleton=1.000, video=0.166
#       Best fitness: 0.090586, Time: 264.9s
#     Weights: [depth=0.867, sensor=0.440, skeleton=1.000, video=0.166]
#     Test Acc: 98.15%, F1: 97.94%, Model: 8.223MB
#
#   --- WEIGHTED_HHO ---
#     Running weighted_HHO...
#       Search dim: 4, Pop: 20, Iter: 30
# HHO is now tackling  "fitness"
# ['At iteration 0 the best fitness is 0.14064029790461063']
# ['At iteration 1 the best fitness is 0.11262498795986176']
# ['At iteration 2 the best fitness is 0.11262498795986176']
# ['At iteration 3 the best fitness is 0.11262498795986176']
# ['At iteration 4 the best fitness is 0.11262498795986176']
# ['At iteration 5 the best fitness is 0.10667949542403221']
# ['At iteration 6 the best fitness is 0.10667949542403221']
# ['At iteration 7 the best fitness is 0.10667949542403221']
# ['At iteration 8 the best fitness is 0.10667949542403221']
# ['At iteration 9 the best fitness is 0.10667949542403221']
# ['At iteration 10 the best fitness is 0.10667949542403221']
# ['At iteration 11 the best fitness is 0.10667949542403221']
# ['At iteration 12 the best fitness is 0.10667949542403221']
# ['At iteration 13 the best fitness is 0.10667949542403221']
# ['At iteration 14 the best fitness is 0.10667949542403221']
# ['At iteration 15 the best fitness is 0.09934422746300697']
# ['At iteration 16 the best fitness is 0.09934422746300697']
# ['At iteration 17 the best fitness is 0.09934422746300697']
# ['At iteration 18 the best fitness is 0.09934422746300697']
# ['At iteration 19 the best fitness is 0.09934422746300697']
# ['At iteration 20 the best fitness is 0.09934422746300697']
# ['At iteration 21 the best fitness is 0.09934422746300697']
# ['At iteration 22 the best fitness is 0.09934422746300697']
# ['At iteration 23 the best fitness is 0.09934422746300697']
# ['At iteration 24 the best fitness is 0.09934422746300697']
# ['At iteration 25 the best fitness is 0.09934422746300697']
# ['At iteration 26 the best fitness is 0.09934422746300697']
# ['At iteration 27 the best fitness is 0.09934422746300697']
# ['At iteration 28 the best fitness is 0.09934422746300697']
# ['At iteration 29 the best fitness is 0.09934422746300697']
#       Weights: depth=0.664, sensor=0.174, skeleton=0.664, video=0.159
#       Best fitness: 0.099344, Time: 419.1s
#     Weights: [depth=0.664, sensor=0.174, skeleton=0.664, video=0.159]
#     Test Acc: 97.22%, F1: 97.12%, Model: 8.223MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 4, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.11328250542283058']
# ['At iteration 1 the best fitness is 0.11328250542283058']
# ['At iteration 2 the best fitness is 0.11019029468297958']
# ['At iteration 3 the best fitness is 0.11019029468297958']
# ['At iteration 4 the best fitness is 0.1038690721616149']
# ['At iteration 5 the best fitness is 0.1038690721616149']
# ['At iteration 6 the best fitness is 0.1038690721616149']
# ['At iteration 7 the best fitness is 0.1038690721616149']
# ['At iteration 8 the best fitness is 0.1038690721616149']
# ['At iteration 9 the best fitness is 0.09900007024407387']
# ['At iteration 10 the best fitness is 0.09900007024407387']
# ['At iteration 11 the best fitness is 0.09900007024407387']
# ['At iteration 12 the best fitness is 0.09900007024407387']
# ['At iteration 13 the best fitness is 0.09900007024407387']
# ['At iteration 14 the best fitness is 0.09900007024407387']
# ['At iteration 15 the best fitness is 0.09900007024407387']
# ['At iteration 16 the best fitness is 0.09900007024407387']
# ['At iteration 17 the best fitness is 0.09900007024407387']
# ['At iteration 18 the best fitness is 0.09900007024407387']
# ['At iteration 19 the best fitness is 0.09900007024407387']
# ['At iteration 20 the best fitness is 0.09900007024407387']
# ['At iteration 21 the best fitness is 0.09900007024407387']
# ['At iteration 22 the best fitness is 0.09900007024407387']
# ['At iteration 23 the best fitness is 0.09900007024407387']
# ['At iteration 24 the best fitness is 0.09900007024407387']
# ['At iteration 25 the best fitness is 0.08843944873660803']
# ['At iteration 26 the best fitness is 0.08843944873660803']
# ['At iteration 27 the best fitness is 0.08843944873660803']
# ['At iteration 28 the best fitness is 0.08843944873660803']
# ['At iteration 29 the best fitness is 0.08843944873660803']
#       Weights: depth=0.154, sensor=0.385, skeleton=0.668, video=0.168
#       Best fitness: 0.088439, Time: 272.1s
#     Weights: [depth=0.154, sensor=0.385, skeleton=0.668, video=0.168]
#     Test Acc: 94.44%, F1: 94.17%, Model: 8.223MB
#
#   --- WEIGHTED_MFO ---
#     Running weighted_MFO...
#       Search dim: 4, Pop: 20, Iter: 30
# MFO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.1487598791718483']
# ['At iteration 2 the best fitness is 0.14396700263023376']
# ['At iteration 3 the best fitness is 0.11645687744021416']
# ['At iteration 4 the best fitness is 0.11645687744021416']
# ['At iteration 5 the best fitness is 0.11128903366625309']
# ['At iteration 6 the best fitness is 0.11128903366625309']
# ['At iteration 7 the best fitness is 0.11128903366625309']
# ['At iteration 8 the best fitness is 0.09831147082149982']
# ['At iteration 9 the best fitness is 0.09831147082149982']
# ['At iteration 10 the best fitness is 0.09831147082149982']
# ['At iteration 11 the best fitness is 0.09831147082149982']
# ['At iteration 12 the best fitness is 0.09831147082149982']
# ['At iteration 13 the best fitness is 0.09831147082149982']
# ['At iteration 14 the best fitness is 0.09831147082149982']
# ['At iteration 15 the best fitness is 0.08575698640197515']
# ['At iteration 16 the best fitness is 0.08575698640197515']
# ['At iteration 17 the best fitness is 0.08575698640197515']
# ['At iteration 18 the best fitness is 0.08575698640197515']
# ['At iteration 19 the best fitness is 0.08575698640197515']
# ['At iteration 20 the best fitness is 0.08575698640197515']
# ['At iteration 21 the best fitness is 0.08575698640197515']
# ['At iteration 22 the best fitness is 0.08575698640197515']
# ['At iteration 23 the best fitness is 0.08575698640197515']
# ['At iteration 24 the best fitness is 0.08575698640197515']
# ['At iteration 25 the best fitness is 0.08575698640197515']
# ['At iteration 26 the best fitness is 0.08575698640197515']
# ['At iteration 27 the best fitness is 0.08575698640197515']
# ['At iteration 28 the best fitness is 0.08575698640197515']
# ['At iteration 29 the best fitness is 0.08575698640197515']
#       Weights: depth=1.000, sensor=0.482, skeleton=0.967, video=0.000
#       Best fitness: 0.085757, Time: 255.9s
#     Weights: [depth=1.000, sensor=0.482, skeleton=0.967, video=0.000]
#     Test Acc: 92.59%, F1: 91.85%, Model: 8.223MB
#
#   --- WEIGHTED_MVO ---
#     Running weighted_MVO...
#       Search dim: 4, Pop: 20, Iter: 30
# MVO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.14050497394055128']
# ['At iteration 2 the best fitness is 0.11918252892792225']
# ['At iteration 3 the best fitness is 0.11918252892792225']
# ['At iteration 4 the best fitness is 0.09201746620237827']
# ['At iteration 5 the best fitness is 0.09201746620237827']
# ['At iteration 6 the best fitness is 0.09201746620237827']
# ['At iteration 7 the best fitness is 0.09201746620237827']
# ['At iteration 8 the best fitness is 0.09201746620237827']
# ['At iteration 9 the best fitness is 0.09201746620237827']
# ['At iteration 10 the best fitness is 0.09201746620237827']
# ['At iteration 11 the best fitness is 0.09201746620237827']
# ['At iteration 12 the best fitness is 0.09201746620237827']
# ['At iteration 13 the best fitness is 0.09201746620237827']
# ['At iteration 14 the best fitness is 0.09201746620237827']
# ['At iteration 15 the best fitness is 0.09201746620237827']
# ['At iteration 16 the best fitness is 0.09201746620237827']
# ['At iteration 17 the best fitness is 0.09201746620237827']
# ['At iteration 18 the best fitness is 0.09201746620237827']
# ['At iteration 19 the best fitness is 0.09201746620237827']
# ['At iteration 20 the best fitness is 0.09201746620237827']
# ['At iteration 21 the best fitness is 0.09201746620237827']
# ['At iteration 22 the best fitness is 0.09201746620237827']
# ['At iteration 23 the best fitness is 0.09201746620237827']
# ['At iteration 24 the best fitness is 0.09201746620237827']
# ['At iteration 25 the best fitness is 0.09201746620237827']
# ['At iteration 26 the best fitness is 0.09201746620237827']
# ['At iteration 27 the best fitness is 0.09201746620237827']
# ['At iteration 28 the best fitness is 0.09201746620237827']
# ['At iteration 29 the best fitness is 0.09201746620237827']
# ['At iteration 30 the best fitness is 0.09201746620237827']
#       Weights: depth=0.737, sensor=0.229, skeleton=0.309, video=0.046
#       Best fitness: 0.092017, Time: 264.7s
#     Weights: [depth=0.737, sensor=0.229, skeleton=0.309, video=0.046]
#     Test Acc: 94.44%, F1: 93.83%, Model: 8.223MB
#
#   --- WEIGHTED_PSO ---
#     Running weighted_PSO...
#       Search dim: 4, Pop: 20, Iter: 30
# PSO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.10943643189966679']
# ['At iteration 2 the best fitness is 0.10943643189966679']
# ['At iteration 3 the best fitness is 0.09388194791972637']
# ['At iteration 4 the best fitness is 0.09388194791972637']
# ['At iteration 5 the best fitness is 0.09388194791972637']
# ['At iteration 6 the best fitness is 0.09388194791972637']
# ['At iteration 7 the best fitness is 0.09388194791972637']
# ['At iteration 8 the best fitness is 0.09388194791972637']
# ['At iteration 9 the best fitness is 0.09388194791972637']
# ['At iteration 10 the best fitness is 0.09327967651188374']
# ['At iteration 11 the best fitness is 0.09327967651188374']
# ['At iteration 12 the best fitness is 0.09327967651188374']
# ['At iteration 13 the best fitness is 0.09327967651188374']
# ['At iteration 14 the best fitness is 0.09327967651188374']
# ['At iteration 15 the best fitness is 0.09327967651188374']
# ['At iteration 16 the best fitness is 0.09327967651188374']
# ['At iteration 17 the best fitness is 0.09327967651188374']
# ['At iteration 18 the best fitness is 0.09327967651188374']
# ['At iteration 19 the best fitness is 0.09327967651188374']
# ['At iteration 20 the best fitness is 0.09327967651188374']
# ['At iteration 21 the best fitness is 0.09327967651188374']
# ['At iteration 22 the best fitness is 0.09327967651188374']
# ['At iteration 23 the best fitness is 0.08822963386774063']
# ['At iteration 24 the best fitness is 0.08822963386774063']
# ['At iteration 25 the best fitness is 0.08535491768270731']
# ['At iteration 26 the best fitness is 0.08535491768270731']
# ['At iteration 27 the best fitness is 0.08535491768270731']
# ['At iteration 28 the best fitness is 0.08535491768270731']
# ['At iteration 29 the best fitness is 0.08535491768270731']
# ['At iteration 30 the best fitness is 0.08535491768270731']
#       Weights: depth=0.706, sensor=0.404, skeleton=1.000, video=0.000
#       Best fitness: 0.085355, Time: 264.7s
#     Weights: [depth=0.706, sensor=0.404, skeleton=1.000, video=0.000]
#     Test Acc: 98.15%, F1: 98.02%, Model: 8.223MB
#
#   --- WEIGHTED_SCA ---
#     Running weighted_SCA...
#       Search dim: 4, Pop: 20, Iter: 30
# SCA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.1098408019170165']
# ['At iteration 1 the best fitness is 0.1098408019170165']
# ['At iteration 2 the best fitness is 0.1098408019170165']
# ['At iteration 3 the best fitness is 0.1098408019170165']
# ['At iteration 4 the best fitness is 0.1098408019170165']
# ['At iteration 5 the best fitness is 0.1098408019170165']
# ['At iteration 6 the best fitness is 0.1098408019170165']
# ['At iteration 7 the best fitness is 0.1098408019170165']
# ['At iteration 8 the best fitness is 0.10834872908890247']
# ['At iteration 9 the best fitness is 0.10834872908890247']
# ['At iteration 10 the best fitness is 0.10834872908890247']
# ['At iteration 11 the best fitness is 0.10834872908890247']
# ['At iteration 12 the best fitness is 0.10834872908890247']
# ['At iteration 13 the best fitness is 0.10834872908890247']
# ['At iteration 14 the best fitness is 0.1083153486251831']
# ['At iteration 15 the best fitness is 0.1083153486251831']
# ['At iteration 16 the best fitness is 0.1083153486251831']
# ['At iteration 17 the best fitness is 0.1083153486251831']
# ['At iteration 18 the best fitness is 0.1083153486251831']
# ['At iteration 19 the best fitness is 0.1083153486251831']
# ['At iteration 20 the best fitness is 0.1083153486251831']
# ['At iteration 21 the best fitness is 0.1083153486251831']
# ['At iteration 22 the best fitness is 0.10240147821605206']
# ['At iteration 23 the best fitness is 0.10240147821605206']
# ['At iteration 24 the best fitness is 0.10240147821605206']
# ['At iteration 25 the best fitness is 0.10240147821605206']
# ['At iteration 26 the best fitness is 0.10240147821605206']
# ['At iteration 27 the best fitness is 0.10240147821605206']
# ['At iteration 28 the best fitness is 0.10240147821605206']
# ['At iteration 29 the best fitness is 0.10240147821605206']
#       Weights: depth=0.552, sensor=0.417, skeleton=1.000, video=0.000
#       Best fitness: 0.102401, Time: 264.9s
#     Weights: [depth=0.552, sensor=0.417, skeleton=1.000, video=0.000]
#     Test Acc: 93.52%, F1: 93.78%, Model: 8.223MB
#
#   --- WEIGHTED_SSA ---
#     Running weighted_SSA...
#       Search dim: 4, Pop: 20, Iter: 30
# SSA is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.11568669974803925']
# ['At iteration 2 the best fitness is 0.11568669974803925']
# ['At iteration 3 the best fitness is 0.11568669974803925']
# ['At iteration 4 the best fitness is 0.11568669974803925']
# ['At iteration 5 the best fitness is 0.11239149514585733']
# ['At iteration 6 the best fitness is 0.11033430881798267']
# ['At iteration 7 the best fitness is 0.10955310519784689']
# ['At iteration 8 the best fitness is 0.10955310519784689']
# ['At iteration 9 the best fitness is 0.10955310519784689']
# ['At iteration 10 the best fitness is 0.10109197814017534']
# ['At iteration 11 the best fitness is 0.10109197814017534']
# ['At iteration 12 the best fitness is 0.09733953885734081']
# ['At iteration 13 the best fitness is 0.09733953885734081']
# ['At iteration 14 the best fitness is 0.09733953885734081']
# ['At iteration 15 the best fitness is 0.09733953885734081']
# ['At iteration 16 the best fitness is 0.09733953885734081']
# ['At iteration 17 the best fitness is 0.09733953885734081']
# ['At iteration 18 the best fitness is 0.09733953885734081']
# ['At iteration 19 the best fitness is 0.09733953885734081']
# ['At iteration 20 the best fitness is 0.09733953885734081']
# ['At iteration 21 the best fitness is 0.09733953885734081']
# ['At iteration 22 the best fitness is 0.09733953885734081']
# ['At iteration 23 the best fitness is 0.09733953885734081']
# ['At iteration 24 the best fitness is 0.09733953885734081']
# ['At iteration 25 the best fitness is 0.09733953885734081']
# ['At iteration 26 the best fitness is 0.09733953885734081']
# ['At iteration 27 the best fitness is 0.09733953885734081']
# ['At iteration 28 the best fitness is 0.09733953885734081']
# ['At iteration 29 the best fitness is 0.09733953885734081']
#       Weights: depth=0.328, sensor=0.868, skeleton=0.878, video=0.021
#       Best fitness: 0.097340, Time: 661.1s
#     Weights: [depth=0.328, sensor=0.868, skeleton=0.878, video=0.021]
#     Test Acc: 95.37%, F1: 94.53%, Model: 8.223MB
#
#   --- WEIGHTED_WOA ---
#     Running weighted_WOA...
#       Search dim: 4, Pop: 20, Iter: 30
# WOA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.12718644738197327']
# ['At iteration 1 the best fitness is 0.10508527513593435']
# ['At iteration 2 the best fitness is 0.10508527513593435']
# ['At iteration 3 the best fitness is 0.10272651026025414']
# ['At iteration 4 the best fitness is 0.09511649515479803']
# ['At iteration 5 the best fitness is 0.09511649515479803']
# ['At iteration 6 the best fitness is 0.09511649515479803']
# ['At iteration 7 the best fitness is 0.09511649515479803']
# ['At iteration 8 the best fitness is 0.09511649515479803']
# ['At iteration 9 the best fitness is 0.09511649515479803']
# ['At iteration 10 the best fitness is 0.0935776848345995']
# ['At iteration 11 the best fitness is 0.0935776848345995']
# ['At iteration 12 the best fitness is 0.0935776848345995']
# ['At iteration 13 the best fitness is 0.0935776848345995']
# ['At iteration 14 the best fitness is 0.0935776848345995']
# ['At iteration 15 the best fitness is 0.0935776848345995']
# ['At iteration 16 the best fitness is 0.0935776848345995']
# ['At iteration 17 the best fitness is 0.0935776848345995']
# ['At iteration 18 the best fitness is 0.0935776848345995']
# ['At iteration 19 the best fitness is 0.0935776848345995']
# ['At iteration 20 the best fitness is 0.0935776848345995']
# ['At iteration 21 the best fitness is 0.0935776848345995']
# ['At iteration 22 the best fitness is 0.0935776848345995']
# ['At iteration 23 the best fitness is 0.0935776848345995']
# ['At iteration 24 the best fitness is 0.0935776848345995']
# ['At iteration 25 the best fitness is 0.09132535941898823']
# ['At iteration 26 the best fitness is 0.09132535941898823']
# ['At iteration 27 the best fitness is 0.09132535941898823']
# ['At iteration 28 the best fitness is 0.08835050463676453']
# ['At iteration 29 the best fitness is 0.08835050463676453']
#       Weights: depth=0.194, sensor=0.377, skeleton=0.639, video=0.005
#       Best fitness: 0.088351, Time: 263.7s
#     Weights: [depth=0.194, sensor=0.377, skeleton=0.639, video=0.005]
#     Test Acc: 94.44%, F1: 93.70%, Model: 8.223MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 646, Val: 107, Test: 108
#
#   --- BASELINE ---
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000, video=1.000]
#     Test Acc: 91.67%, F1: 89.18%, Model: 8.223MB
#
#   --- WEIGHTED_BAT ---
#     Running weighted_BAT...
#       Search dim: 4, Pop: 20, Iter: 30
# BAT is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.13436008989810944']
# ['At iteration 1 the best fitness is 0.13431949727237225']
# ['At iteration 2 the best fitness is 0.08553483942523599']
# ['At iteration 3 the best fitness is 0.08553483942523599']
# ['At iteration 4 the best fitness is 0.08553483942523599']
# ['At iteration 5 the best fitness is 0.08553483942523599']
# ['At iteration 6 the best fitness is 0.08553483942523599']
# ['At iteration 7 the best fitness is 0.08553483942523599']
# ['At iteration 8 the best fitness is 0.08553483942523599']
# ['At iteration 9 the best fitness is 0.08553483942523599']
# ['At iteration 10 the best fitness is 0.08553483942523599']
# ['At iteration 11 the best fitness is 0.08553483942523599']
# ['At iteration 12 the best fitness is 0.08553483942523599']
# ['At iteration 13 the best fitness is 0.08553483942523599']
# ['At iteration 14 the best fitness is 0.08553483942523599']
# ['At iteration 15 the best fitness is 0.08553483942523599']
# ['At iteration 16 the best fitness is 0.08553483942523599']
# ['At iteration 17 the best fitness is 0.08553483942523599']
# ['At iteration 18 the best fitness is 0.08553483942523599']
# ['At iteration 19 the best fitness is 0.08553483942523599']
# ['At iteration 20 the best fitness is 0.08553483942523599']
# ['At iteration 21 the best fitness is 0.08553483942523599']
# ['At iteration 22 the best fitness is 0.08553483942523599']
# ['At iteration 23 the best fitness is 0.08553483942523599']
# ['At iteration 24 the best fitness is 0.08553483942523599']
# ['At iteration 25 the best fitness is 0.0720664020627737']
# ['At iteration 26 the best fitness is 0.0720664020627737']
# ['At iteration 27 the best fitness is 0.0720664020627737']
# ['At iteration 28 the best fitness is 0.0720664020627737']
# ['At iteration 29 the best fitness is 0.0720664020627737']
#       Weights: depth=0.000, sensor=1.000, skeleton=1.000, video=0.000
#       Best fitness: 0.072066, Time: 273.3s
#     Weights: [depth=0.000, sensor=1.000, skeleton=1.000, video=0.000]
#     Test Acc: 89.81%, F1: 87.13%, Model: 8.223MB
#
#   --- WEIGHTED_CS ---
#     Running weighted_CS...
#       Search dim: 4, Pop: 20, Iter: 30
# CS is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.13031253404915333']
# ['At iteration 10 the best fitness is 0.0972787057980895']
# ['At iteration 20 the best fitness is 0.0972787057980895']
#       Weights: depth=1.000, sensor=1.000, skeleton=1.000, video=0.362
#       Best fitness: 0.095672, Time: 536.9s
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000, video=0.362]
#     Test Acc: 83.33%, F1: 80.36%, Model: 8.223MB
#
#   --- WEIGHTED_DE ---
#     Running weighted_DE...
#       Search dim: 4, Pop: 20, Iter: 30
# DE is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.13779383059591055']
# ['At iteration 2 the best fitness is 0.13779383059591055']
# ['At iteration 3 the best fitness is 0.13062740582972765']
# ['At iteration 4 the best fitness is 0.1130939144641161']
# ['At iteration 5 the best fitness is 0.10780936293303967']
# ['At iteration 6 the best fitness is 0.10780936293303967']
# ['At iteration 7 the best fitness is 0.10780936293303967']
# ['At iteration 8 the best fitness is 0.10780936293303967']
# ['At iteration 9 the best fitness is 0.10385452024638653']
# ['At iteration 10 the best fitness is 0.10385452024638653']
# ['At iteration 11 the best fitness is 0.10385452024638653']
# ['At iteration 12 the best fitness is 0.10385452024638653']
# ['At iteration 13 the best fitness is 0.10385452024638653']
# ['At iteration 14 the best fitness is 0.10296773351728916']
# ['At iteration 15 the best fitness is 0.09973754454404116']
# ['At iteration 16 the best fitness is 0.09973754454404116']
# ['At iteration 17 the best fitness is 0.09973754454404116']
# ['At iteration 18 the best fitness is 0.09973754454404116']
# ['At iteration 19 the best fitness is 0.09973754454404116']
# ['At iteration 20 the best fitness is 0.09973754454404116']
# ['At iteration 21 the best fitness is 0.0962213333696127']
# ['At iteration 22 the best fitness is 0.0962213333696127']
# ['At iteration 23 the best fitness is 0.0962213333696127']
# ['At iteration 24 the best fitness is 0.0962213333696127']
# ['At iteration 25 the best fitness is 0.0962213333696127']
# ['At iteration 26 the best fitness is 0.0962213333696127']
# ['At iteration 27 the best fitness is 0.0962213333696127']
# ['At iteration 28 the best fitness is 0.0962213333696127']
# ['At iteration 29 the best fitness is 0.0962213333696127']
# ['At iteration 30 the best fitness is 0.0962213333696127']
#       Weights: depth=0.075, sensor=0.722, skeleton=0.720, video=0.000
#       Best fitness: 0.096221, Time: 272.8s
#     Weights: [depth=0.075, sensor=0.722, skeleton=0.720, video=0.000]
#     Test Acc: 89.81%, F1: 87.53%, Model: 8.223MB
#
#   --- WEIGHTED_FFA ---
#     Running weighted_FFA...
#       Search dim: 4, Pop: 20, Iter: 30
# FFA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.11134385410696268']
# ['At iteration 1 the best fitness is 0.11748888902366161']
# ['At iteration 2 the best fitness is 0.10282283183187246']
# ['At iteration 3 the best fitness is 0.11927361227571964']
# ['At iteration 4 the best fitness is 0.10832129418849945']
# ['At iteration 5 the best fitness is 0.12348174676299095']
# ['At iteration 6 the best fitness is 0.11316825170069933']
# ['At iteration 7 the best fitness is 0.11572853103280067']
# ['At iteration 8 the best fitness is 0.10945353284478188']
# ['At iteration 9 the best fitness is 0.10353263467550278']
# ['At iteration 10 the best fitness is 0.09586801985278726']
# ['At iteration 11 the best fitness is 0.10313170962035656']
# ['At iteration 12 the best fitness is 0.1063367947936058']
# ['At iteration 13 the best fitness is 0.10086083598434925']
# ['At iteration 14 the best fitness is 0.10220844950526953']
# ['At iteration 15 the best fitness is 0.08870855905115604']
# ['At iteration 16 the best fitness is 0.1022335086017847']
# ['At iteration 17 the best fitness is 0.0959139559417963']
# ['At iteration 18 the best fitness is 0.10436676628887653']
# ['At iteration 19 the best fitness is 0.09068822581321001']
# ['At iteration 20 the best fitness is 0.09214111929759383']
# ['At iteration 21 the best fitness is 0.0987113886512816']
# ['At iteration 22 the best fitness is 0.10208004526793957']
# ['At iteration 23 the best fitness is 0.12062084767967463']
# ['At iteration 24 the best fitness is 0.1003441447392106']
# ['At iteration 25 the best fitness is 0.0865741241723299']
# ['At iteration 26 the best fitness is 0.09939312655478716']
# ['At iteration 27 the best fitness is 0.10086777526885271']
# ['At iteration 28 the best fitness is 0.1165186669677496']
# ['At iteration 29 the best fitness is 0.10177475586533546']
#       Weights: depth=0.061, sensor=0.636, skeleton=0.994, video=0.123
#       Best fitness: 0.101775, Time: 264.3s
#     Weights: [depth=0.061, sensor=0.636, skeleton=0.994, video=0.123]
#     Test Acc: 90.74%, F1: 88.91%, Model: 8.223MB
#
#   --- WEIGHTED_GA ---
#     Running weighted_GA...
#       Search dim: 4, Pop: 20, Iter: 30
# GA is optimizing  "fitness"
# At iteration 1 the best fitness is 0.0862790821120143
# At iteration 2 the best fitness is 0.11347097810357809
# At iteration 3 the best fitness is 0.1247366014868021
# At iteration 4 the best fitness is 0.11628502607345581
# At iteration 5 the best fitness is 0.11899867840111256
# At iteration 6 the best fitness is 0.12000059988349676
# At iteration 7 the best fitness is 0.09968944266438484
# At iteration 8 the best fitness is 0.11532688699662685
# At iteration 9 the best fitness is 0.10468952637165785
# At iteration 10 the best fitness is 0.11835131980478764
# At iteration 11 the best fitness is 0.1087178522720933
# At iteration 12 the best fitness is 0.12142847292125225
# At iteration 13 the best fitness is 0.10249313293024898
# At iteration 14 the best fitness is 0.12268072133883834
# At iteration 15 the best fitness is 0.10499862860888243
# At iteration 16 the best fitness is 0.11153166648000479
# At iteration 17 the best fitness is 0.10096526797860861
# At iteration 18 the best fitness is 0.12341915722936392
# At iteration 19 the best fitness is 0.09564449544996023
# At iteration 20 the best fitness is 0.11106771975755692
# At iteration 21 the best fitness is 0.10621268302202225
# At iteration 22 the best fitness is 0.10850643459707499
# At iteration 23 the best fitness is 0.09989288542419672
# At iteration 24 the best fitness is 0.111900819465518
# At iteration 25 the best fitness is 0.11175645887851715
# At iteration 26 the best fitness is 0.11296771839261055
# At iteration 27 the best fitness is 0.10845740744844079
# At iteration 28 the best fitness is 0.103013401851058
# At iteration 29 the best fitness is 0.12141545210033655
# At iteration 30 the best fitness is 0.10957788676023483
#       Weights: depth=0.223, sensor=0.560, skeleton=0.949, video=0.008
#       Best fitness: 0.109578, Time: 264.0s
#     Weights: [depth=0.223, sensor=0.560, skeleton=0.949, video=0.008]
#     Test Acc: 91.67%, F1: 90.10%, Model: 8.223MB
#
#   --- WEIGHTED_GWO ---
#     Running weighted_GWO...
#       Search dim: 4, Pop: 20, Iter: 30
# GWO is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.14489329420030117']
# ['At iteration 1 the best fitness is 0.09872861579060555']
# ['At iteration 2 the best fitness is 0.09872861579060555']
# ['At iteration 3 the best fitness is 0.09872861579060555']
# ['At iteration 4 the best fitness is 0.09872861579060555']
# ['At iteration 5 the best fitness is 0.09872861579060555']
# ['At iteration 6 the best fitness is 0.09368106443434954']
# ['At iteration 7 the best fitness is 0.09368106443434954']
# ['At iteration 8 the best fitness is 0.09368106443434954']
# ['At iteration 9 the best fitness is 0.09368106443434954']
# ['At iteration 10 the best fitness is 0.08919905126094818']
# ['At iteration 11 the best fitness is 0.08919905126094818']
# ['At iteration 12 the best fitness is 0.08919905126094818']
# ['At iteration 13 the best fitness is 0.08919905126094818']
# ['At iteration 14 the best fitness is 0.08919905126094818']
# ['At iteration 15 the best fitness is 0.08919905126094818']
# ['At iteration 16 the best fitness is 0.08919905126094818']
# ['At iteration 17 the best fitness is 0.08919905126094818']
# ['At iteration 18 the best fitness is 0.08919905126094818']
# ['At iteration 19 the best fitness is 0.08919905126094818']
# ['At iteration 20 the best fitness is 0.08919905126094818']
# ['At iteration 21 the best fitness is 0.08919905126094818']
# ['At iteration 22 the best fitness is 0.08919905126094818']
# ['At iteration 23 the best fitness is 0.08919905126094818']
# ['At iteration 24 the best fitness is 0.06943162251263857']
# ['At iteration 25 the best fitness is 0.06943162251263857']
# ['At iteration 26 the best fitness is 0.06943162251263857']
# ['At iteration 27 the best fitness is 0.06943162251263857']
# ['At iteration 28 the best fitness is 0.06943162251263857']
# ['At iteration 29 the best fitness is 0.06943162251263857']
#       Weights: depth=0.021, sensor=0.360, skeleton=0.549, video=0.000
#       Best fitness: 0.069432, Time: 264.6s
#     Weights: [depth=0.021, sensor=0.360, skeleton=0.549, video=0.000]
#     Test Acc: 89.81%, F1: 88.09%, Model: 8.223MB
#
#   --- WEIGHTED_HHO ---
#     Running weighted_HHO...
#       Search dim: 4, Pop: 20, Iter: 30
# HHO is now tackling  "fitness"
# ['At iteration 0 the best fitness is 0.11708050593733788']
# ['At iteration 1 the best fitness is 0.09376384038478136']
# ['At iteration 2 the best fitness is 0.09376384038478136']
# ['At iteration 3 the best fitness is 0.09376384038478136']
# ['At iteration 4 the best fitness is 0.09376384038478136']
# ['At iteration 5 the best fitness is 0.09376384038478136']
# ['At iteration 6 the best fitness is 0.09376384038478136']
# ['At iteration 7 the best fitness is 0.09376384038478136']
# ['At iteration 8 the best fitness is 0.09376384038478136']
# ['At iteration 9 the best fitness is 0.09277405077591538']
# ['At iteration 10 the best fitness is 0.09277405077591538']
# ['At iteration 11 the best fitness is 0.09277405077591538']
# ['At iteration 12 the best fitness is 0.09277405077591538']
# ['At iteration 13 the best fitness is 0.09277405077591538']
# ['At iteration 14 the best fitness is 0.09277405077591538']
# ['At iteration 15 the best fitness is 0.09277405077591538']
# ['At iteration 16 the best fitness is 0.09277405077591538']
# ['At iteration 17 the best fitness is 0.09277405077591538']
# ['At iteration 18 the best fitness is 0.09047140832990408']
# ['At iteration 19 the best fitness is 0.09047140832990408']
# ['At iteration 20 the best fitness is 0.09047140832990408']
# ['At iteration 21 the best fitness is 0.09047140832990408']
# ['At iteration 22 the best fitness is 0.09047140832990408']
# ['At iteration 23 the best fitness is 0.09047140832990408']
# ['At iteration 24 the best fitness is 0.0892132013104856']
# ['At iteration 25 the best fitness is 0.0892132013104856']
# ['At iteration 26 the best fitness is 0.0892132013104856']
# ['At iteration 27 the best fitness is 0.0892132013104856']
# ['At iteration 28 the best fitness is 0.0892132013104856']
# ['At iteration 29 the best fitness is 0.0892132013104856']
#       Weights: depth=0.001, sensor=0.167, skeleton=0.139, video=0.000
#       Best fitness: 0.089213, Time: 426.9s
#     Weights: [depth=0.001, sensor=0.167, skeleton=0.139, video=0.000]
#     Test Acc: 92.59%, F1: 90.89%, Model: 8.223MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 4, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.1054565804079175']
# ['At iteration 1 the best fitness is 0.1054565804079175']
# ['At iteration 2 the best fitness is 0.1054565804079175']
# ['At iteration 3 the best fitness is 0.1054565804079175']
# ['At iteration 4 the best fitness is 0.1054565804079175']
# ['At iteration 5 the best fitness is 0.1054565804079175']
# ['At iteration 6 the best fitness is 0.10305404383689165']
# ['At iteration 7 the best fitness is 0.10305404383689165']
# ['At iteration 8 the best fitness is 0.10305404383689165']
# ['At iteration 9 the best fitness is 0.10305404383689165']
# ['At iteration 10 the best fitness is 0.10305404383689165']
# ['At iteration 11 the best fitness is 0.10305404383689165']
# ['At iteration 12 the best fitness is 0.10259799938648939']
# ['At iteration 13 the best fitness is 0.10259799938648939']
# ['At iteration 14 the best fitness is 0.10154268890619278']
# ['At iteration 15 the best fitness is 0.10154268890619278']
# ['At iteration 16 the best fitness is 0.10154268890619278']
# ['At iteration 17 the best fitness is 0.10154268890619278']
# ['At iteration 18 the best fitness is 0.10154268890619278']
# ['At iteration 19 the best fitness is 0.10154268890619278']
# ['At iteration 20 the best fitness is 0.10154268890619278']
# ['At iteration 21 the best fitness is 0.10154268890619278']
# ['At iteration 22 the best fitness is 0.10154268890619278']
# ['At iteration 23 the best fitness is 0.10154268890619278']
# ['At iteration 24 the best fitness is 0.10154268890619278']
# ['At iteration 25 the best fitness is 0.09178086835891008']
# ['At iteration 26 the best fitness is 0.07700586505234241']
# ['At iteration 27 the best fitness is 0.07700586505234241']
# ['At iteration 28 the best fitness is 0.07700586505234241']
# ['At iteration 29 the best fitness is 0.07700586505234241']
#       Weights: depth=0.034, sensor=0.871, skeleton=0.968, video=0.033
#       Best fitness: 0.077006, Time: 272.7s
#     Weights: [depth=0.034, sensor=0.871, skeleton=0.968, video=0.033]
#     Test Acc: 92.59%, F1: 91.65%, Model: 8.223MB
#
#   --- WEIGHTED_MFO ---
#     Running weighted_MFO...
#       Search dim: 4, Pop: 20, Iter: 30
# MFO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.13883784785866737']
# ['At iteration 2 the best fitness is 0.13883784785866737']
# ['At iteration 3 the best fitness is 0.1156449057161808']
# ['At iteration 4 the best fitness is 0.1156449057161808']
# ['At iteration 5 the best fitness is 0.1015558885410428']
# ['At iteration 6 the best fitness is 0.0984426774084568']
# ['At iteration 7 the best fitness is 0.0984426774084568']
# ['At iteration 8 the best fitness is 0.0984426774084568']
# ['At iteration 9 the best fitness is 0.0984426774084568']
# ['At iteration 10 the best fitness is 0.0984426774084568']
# ['At iteration 11 the best fitness is 0.0984426774084568']
# ['At iteration 12 the best fitness is 0.0984426774084568']
# ['At iteration 13 the best fitness is 0.0984426774084568']
# ['At iteration 14 the best fitness is 0.0984426774084568']
# ['At iteration 15 the best fitness is 0.0984426774084568']
# ['At iteration 16 the best fitness is 0.0984426774084568']
# ['At iteration 17 the best fitness is 0.0984426774084568']
# ['At iteration 18 the best fitness is 0.0984426774084568']
# ['At iteration 19 the best fitness is 0.0984426774084568']
# ['At iteration 20 the best fitness is 0.0984426774084568']
# ['At iteration 21 the best fitness is 0.0984426774084568']
# ['At iteration 22 the best fitness is 0.0984426774084568']
# ['At iteration 23 the best fitness is 0.09759946819394827']
# ['At iteration 24 the best fitness is 0.09193267952650785']
# ['At iteration 25 the best fitness is 0.09193267952650785']
# ['At iteration 26 the best fitness is 0.09193267952650785']
# ['At iteration 27 the best fitness is 0.09193267952650785']
# ['At iteration 28 the best fitness is 0.09193267952650785']
# ['At iteration 29 the best fitness is 0.09193267952650785']
#       Weights: depth=0.001, sensor=1.000, skeleton=1.000, video=0.109
#       Best fitness: 0.091933, Time: 254.9s
#     Weights: [depth=0.001, sensor=1.000, skeleton=1.000, video=0.109]
#     Test Acc: 89.81%, F1: 87.35%, Model: 8.223MB
#
#   --- WEIGHTED_MVO ---
#     Running weighted_MVO...
#       Search dim: 4, Pop: 20, Iter: 30
# MVO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.12368165794759989']
# ['At iteration 2 the best fitness is 0.12368165794759989']
# ['At iteration 3 the best fitness is 0.12368165794759989']
# ['At iteration 4 the best fitness is 0.10722803324460983']
# ['At iteration 5 the best fitness is 0.10722803324460983']
# ['At iteration 6 the best fitness is 0.10722803324460983']
# ['At iteration 7 the best fitness is 0.10722803324460983']
# ['At iteration 8 the best fitness is 0.10101075377315283']
# ['At iteration 9 the best fitness is 0.10101075377315283']
# ['At iteration 10 the best fitness is 0.09238912537693977']
# ['At iteration 11 the best fitness is 0.09238912537693977']
# ['At iteration 12 the best fitness is 0.08776721637696028']
# ['At iteration 13 the best fitness is 0.08776721637696028']
# ['At iteration 14 the best fitness is 0.08776721637696028']
# ['At iteration 15 the best fitness is 0.08776721637696028']
# ['At iteration 16 the best fitness is 0.08776721637696028']
# ['At iteration 17 the best fitness is 0.08776721637696028']
# ['At iteration 18 the best fitness is 0.08776721637696028']
# ['At iteration 19 the best fitness is 0.08776721637696028']
# ['At iteration 20 the best fitness is 0.08776721637696028']
# ['At iteration 21 the best fitness is 0.08776721637696028']
# ['At iteration 22 the best fitness is 0.08776721637696028']
# ['At iteration 23 the best fitness is 0.08776721637696028']
# ...
# ['At iteration 19 the best fitness is 0.09234838280826807']
# ['At iteration 20 the best fitness is 0.09234838280826807']
# ['At iteration 21 the best fitness is 0.09234838280826807']
# ['At iteration 22 the best fitness is 0.09234838280826807']
# ['At iteration 23 the best fitness is 0.09234838280826807']
# ['At iteration 24 the best fitness is 0.09234838280826807']
# ['At iteration 25 the best fitness is 0.09234838280826807']
# ['At iteration 26 the best fitness is 0.09234838280826807']
# ['At iteration 27 the best fitness is 0.09234838280826807']
# ['At iteration 28 the best fitness is 0.09234838280826807']
# ['At iteration 29 the best fitness is 0.09234838280826807']
#       Weights: depth=0.000, sensor=0.002, skeleton=0.005, video=0.000
#       Best fitness: 0.092348, Time: 426.7s
#     Weights: [depth=0.000, sensor=0.002, skeleton=0.005, video=0.000]
#     Test Acc: 96.26%, F1: 96.12%, Model: 8.223MB
#
#   --- WEIGHTED_JAYA ---
#     Running weighted_JAYA...
#       Search dim: 4, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.10558173060417175']
# ['At iteration 1 the best fitness is 0.10558173060417175']
# ['At iteration 2 the best fitness is 0.10558173060417175']
# ['At iteration 3 the best fitness is 0.10558173060417175']
# ['At iteration 4 the best fitness is 0.10558173060417175']
# ['At iteration 5 the best fitness is 0.10558173060417175']
# ['At iteration 6 the best fitness is 0.10558173060417175']
# ['At iteration 7 the best fitness is 0.10558173060417175']
# ['At iteration 8 the best fitness is 0.10558173060417175']
# ['At iteration 9 the best fitness is 0.10558173060417175']
# ['At iteration 10 the best fitness is 0.10558173060417175']
# ['At iteration 11 the best fitness is 0.10558173060417175']
# ['At iteration 12 the best fitness is 0.10558173060417175']
# ['At iteration 13 the best fitness is 0.10558173060417175']
# ['At iteration 14 the best fitness is 0.10558173060417175']
# ['At iteration 15 the best fitness is 0.10558173060417175']
# ['At iteration 16 the best fitness is 0.10558173060417175']
# ['At iteration 17 the best fitness is 0.10558173060417175']
# ['At iteration 18 the best fitness is 0.10558173060417175']
# ['At iteration 19 the best fitness is 0.10558173060417175']
# ['At iteration 20 the best fitness is 0.10558173060417175']
# ['At iteration 21 the best fitness is 0.10558173060417175']
# ['At iteration 22 the best fitness is 0.10558173060417175']
# ['At iteration 23 the best fitness is 0.10558173060417175']
# ['At iteration 24 the best fitness is 0.10558173060417175']
# ['At iteration 25 the best fitness is 0.10558173060417175']
# ['At iteration 26 the best fitness is 0.10558173060417175']
# ['At iteration 27 the best fitness is 0.10558173060417175']
# ['At iteration 28 the best fitness is 0.10558173060417175']
# ['At iteration 29 the best fitness is 0.10558173060417175']
#       Weights: depth=0.605, sensor=0.422, skeleton=0.648, video=0.088
#       Best fitness: 0.105582, Time: 271.1s
#     Weights: [depth=0.605, sensor=0.422, skeleton=0.648, video=0.088]
#     Test Acc: 93.46%, F1: 92.86%, Model: 8.223MB
#
#   --- WEIGHTED_MFO ---
#     Running weighted_MFO...
#       Search dim: 4, Pop: 20, Iter: 30
# MFO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.13727904111146927']
# ['At iteration 2 the best fitness is 0.13727904111146927']
# ['At iteration 3 the best fitness is 0.11290474608540535']
# ['At iteration 4 the best fitness is 0.11290474608540535']
# ['At iteration 5 the best fitness is 0.11290474608540535']
# ['At iteration 6 the best fitness is 0.11290474608540535']
# ['At iteration 7 the best fitness is 0.11290474608540535']
# ['At iteration 8 the best fitness is 0.11121012922376394']
# ['At iteration 9 the best fitness is 0.11121012922376394']
# ['At iteration 10 the best fitness is 0.11121012922376394']
# ['At iteration 11 the best fitness is 0.11121012922376394']
# ['At iteration 12 the best fitness is 0.11121012922376394']
# ['At iteration 13 the best fitness is 0.11121012922376394']
# ['At iteration 14 the best fitness is 0.11121012922376394']
# ['At iteration 15 the best fitness is 0.11121012922376394']
# ['At iteration 16 the best fitness is 0.11121012922376394']
# ['At iteration 17 the best fitness is 0.10238111391663551']
# ['At iteration 18 the best fitness is 0.10238111391663551']
# ['At iteration 19 the best fitness is 0.10238111391663551']
# ['At iteration 20 the best fitness is 0.10238111391663551']
# ['At iteration 21 the best fitness is 0.10238111391663551']
# ['At iteration 22 the best fitness is 0.10238111391663551']
# ['At iteration 23 the best fitness is 0.10238111391663551']
# ['At iteration 24 the best fitness is 0.10238111391663551']
# ['At iteration 25 the best fitness is 0.10238111391663551']
# ['At iteration 26 the best fitness is 0.09221608098596334']
# ['At iteration 27 the best fitness is 0.09221608098596334']
# ['At iteration 28 the best fitness is 0.09221608098596334']
# ['At iteration 29 the best fitness is 0.09221608098596334']
#       Weights: depth=0.028, sensor=1.000, skeleton=1.000, video=0.048
#       Best fitness: 0.092216, Time: 254.4s
#     Weights: [depth=0.028, sensor=1.000, skeleton=1.000, video=0.048]
#     Test Acc: 100.00%, F1: 100.00%, Model: 8.223MB
#
#   --- WEIGHTED_MVO ---
#     Running weighted_MVO...
#       Search dim: 4, Pop: 20, Iter: 30
# MVO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.150654012337327']
# ['At iteration 2 the best fitness is 0.12845386937260628']
# ['At iteration 3 the best fitness is 0.11510087735950947']
# ['At iteration 4 the best fitness is 0.11510087735950947']
# ['At iteration 5 the best fitness is 0.11510087735950947']
# ['At iteration 6 the best fitness is 0.11494497396051884']
# ['At iteration 7 the best fitness is 0.11121853347867727']
# ['At iteration 8 the best fitness is 0.11121853347867727']
# ['At iteration 9 the best fitness is 0.11121853347867727']
# ['At iteration 10 the best fitness is 0.11121853347867727']
# ['At iteration 11 the best fitness is 0.10643746145069599']
# ['At iteration 12 the best fitness is 0.10643746145069599']
# ['At iteration 13 the best fitness is 0.10643746145069599']
# ['At iteration 14 the best fitness is 0.10643746145069599']
# ['At iteration 15 the best fitness is 0.10643746145069599']
# ['At iteration 16 the best fitness is 0.10643746145069599']
# ['At iteration 17 the best fitness is 0.10643746145069599']
# ['At iteration 18 the best fitness is 0.10643746145069599']
# ['At iteration 19 the best fitness is 0.10643746145069599']
# ['At iteration 20 the best fitness is 0.10643746145069599']
# ['At iteration 21 the best fitness is 0.10643746145069599']
# ['At iteration 22 the best fitness is 0.10643746145069599']
# ['At iteration 23 the best fitness is 0.10643746145069599']
# ['At iteration 24 the best fitness is 0.10643746145069599']
# ['At iteration 25 the best fitness is 0.10643746145069599']
# ['At iteration 26 the best fitness is 0.10643746145069599']
# ['At iteration 27 the best fitness is 0.10643746145069599']
# ['At iteration 28 the best fitness is 0.10643746145069599']
# ['At iteration 29 the best fitness is 0.10643746145069599']
# ['At iteration 30 the best fitness is 0.10643746145069599']
#       Weights: depth=0.370, sensor=0.905, skeleton=0.579, video=0.010
#       Best fitness: 0.106437, Time: 264.6s
#     Weights: [depth=0.370, sensor=0.905, skeleton=0.579, video=0.010]
#     Test Acc: 98.13%, F1: 98.02%, Model: 8.223MB
#
#   --- WEIGHTED_PSO ---
#     Running weighted_PSO...
#       Search dim: 4, Pop: 20, Iter: 30
# PSO is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.14342514239251614']
# ['At iteration 2 the best fitness is 0.1270089726895094']
# ['At iteration 3 the best fitness is 0.1270089726895094']
# ['At iteration 4 the best fitness is 0.12618192378431559']
# ['At iteration 5 the best fitness is 0.10775990132242441']
# ['At iteration 6 the best fitness is 0.10376160033047199']
# ['At iteration 7 the best fitness is 0.10376160033047199']
# ['At iteration 8 the best fitness is 0.10376160033047199']
# ['At iteration 9 the best fitness is 0.10376160033047199']
# ['At iteration 10 the best fitness is 0.10376160033047199']
# ['At iteration 11 the best fitness is 0.10376160033047199']
# ['At iteration 12 the best fitness is 0.10376160033047199']
# ['At iteration 13 the best fitness is 0.10376160033047199']
# ['At iteration 14 the best fitness is 0.10376160033047199']
# ['At iteration 15 the best fitness is 0.10376160033047199']
# ['At iteration 16 the best fitness is 0.10376160033047199']
# ['At iteration 17 the best fitness is 0.10376160033047199']
# ['At iteration 18 the best fitness is 0.10376160033047199']
# ['At iteration 19 the best fitness is 0.10376160033047199']
# ['At iteration 20 the best fitness is 0.10376160033047199']
# ['At iteration 21 the best fitness is 0.10376160033047199']
# ['At iteration 22 the best fitness is 0.10376160033047199']
# ['At iteration 23 the best fitness is 0.10376160033047199']
# ['At iteration 24 the best fitness is 0.08605188131332397']
# ['At iteration 25 the best fitness is 0.08605188131332397']
# ['At iteration 26 the best fitness is 0.08605188131332397']
# ['At iteration 27 the best fitness is 0.08605188131332397']
# ['At iteration 28 the best fitness is 0.08605188131332397']
# ['At iteration 29 the best fitness is 0.08605188131332397']
# ['At iteration 30 the best fitness is 0.08605188131332397']
#       Weights: depth=0.294, sensor=0.995, skeleton=1.000, video=0.000
#       Best fitness: 0.086052, Time: 263.8s
#     Weights: [depth=0.294, sensor=0.995, skeleton=1.000, video=0.000]
#     Test Acc: 100.00%, F1: 100.00%, Model: 8.223MB
#
#   --- WEIGHTED_SCA ---
#     Running weighted_SCA...
#       Search dim: 4, Pop: 20, Iter: 30
# SCA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.17707468941807747']
# ['At iteration 1 the best fitness is 0.15071810875087976']
# ['At iteration 2 the best fitness is 0.1383916549384594']
# ['At iteration 3 the best fitness is 0.12249377742409706']
# ['At iteration 4 the best fitness is 0.12249377742409706']
# ['At iteration 5 the best fitness is 0.10519667156040668']
# ['At iteration 6 the best fitness is 0.10519667156040668']
# ['At iteration 7 the best fitness is 0.10519667156040668']
# ['At iteration 8 the best fitness is 0.10519667156040668']
# ['At iteration 9 the best fitness is 0.10519667156040668']
# ['At iteration 10 the best fitness is 0.10519667156040668']
# ['At iteration 11 the best fitness is 0.10519667156040668']
# ['At iteration 12 the best fitness is 0.10519667156040668']
# ['At iteration 13 the best fitness is 0.10519667156040668']
# ['At iteration 14 the best fitness is 0.10519667156040668']
# ['At iteration 15 the best fitness is 0.10519667156040668']
# ['At iteration 16 the best fitness is 0.10519667156040668']
# ['At iteration 17 the best fitness is 0.10519667156040668']
# ['At iteration 18 the best fitness is 0.10519667156040668']
# ['At iteration 19 the best fitness is 0.10519667156040668']
# ['At iteration 20 the best fitness is 0.10519667156040668']
# ['At iteration 21 the best fitness is 0.10519667156040668']
# ['At iteration 22 the best fitness is 0.10519667156040668']
# ['At iteration 23 the best fitness is 0.10519667156040668']
# ['At iteration 24 the best fitness is 0.10519667156040668']
# ['At iteration 25 the best fitness is 0.10519667156040668']
# ['At iteration 26 the best fitness is 0.10519667156040668']
# ['At iteration 27 the best fitness is 0.10519667156040668']
# ['At iteration 28 the best fitness is 0.10519667156040668']
# ['At iteration 29 the best fitness is 0.10519667156040668']
#       Weights: depth=1.000, sensor=1.000, skeleton=1.000, video=0.000
#       Best fitness: 0.105197, Time: 263.7s
#     Weights: [depth=1.000, sensor=1.000, skeleton=1.000, video=0.000]
#     Test Acc: 99.07%, F1: 98.94%, Model: 8.223MB
#
#   --- WEIGHTED_SSA ---
#     Running weighted_SSA...
#       Search dim: 4, Pop: 20, Iter: 30
# SSA is optimizing  "fitness"
# ['At iteration 1 the best fitness is 0.1140089351683855']
# ['At iteration 2 the best fitness is 0.11316990293562412']
# ['At iteration 3 the best fitness is 0.11316990293562412']
# ['At iteration 4 the best fitness is 0.11316990293562412']
# ['At iteration 5 the best fitness is 0.11316990293562412']
# ['At iteration 6 the best fitness is 0.11316990293562412']
# ['At iteration 7 the best fitness is 0.11316990293562412']
# ['At iteration 8 the best fitness is 0.11316990293562412']
# ['At iteration 9 the best fitness is 0.11316990293562412']
# ['At iteration 10 the best fitness is 0.10547522362321615']
# ['At iteration 11 the best fitness is 0.09694801922887564']
# ['At iteration 12 the best fitness is 0.09694801922887564']
# ['At iteration 13 the best fitness is 0.09694801922887564']
# ['At iteration 14 the best fitness is 0.09077518433332443']
# ['At iteration 15 the best fitness is 0.09077518433332443']
# ['At iteration 16 the best fitness is 0.09077518433332443']
# ['At iteration 17 the best fitness is 0.09077518433332443']
# ['At iteration 18 the best fitness is 0.09077518433332443']
# ['At iteration 19 the best fitness is 0.09077518433332443']
# ['At iteration 20 the best fitness is 0.09077518433332443']
# ['At iteration 21 the best fitness is 0.09077518433332443']
# ['At iteration 22 the best fitness is 0.09077518433332443']
# ['At iteration 23 the best fitness is 0.09077518433332443']
# ['At iteration 24 the best fitness is 0.09077518433332443']
# ['At iteration 25 the best fitness is 0.09077518433332443']
# ['At iteration 26 the best fitness is 0.09077518433332443']
# ['At iteration 27 the best fitness is 0.09077518433332443']
# ['At iteration 28 the best fitness is 0.09077518433332443']
# ['At iteration 29 the best fitness is 0.09077518433332443']
#       Weights: depth=0.211, sensor=0.429, skeleton=0.864, video=0.024
#       Best fitness: 0.090775, Time: 659.1s
#     Weights: [depth=0.211, sensor=0.429, skeleton=0.864, video=0.024]
#     Test Acc: 97.20%, F1: 97.08%, Model: 8.223MB
#
#   --- WEIGHTED_WOA ---
#     Running weighted_WOA...
#       Search dim: 4, Pop: 20, Iter: 30
# WOA is optimizing  "fitness"
# ['At iteration 0 the best fitness is 0.14152526669204235']
# ['At iteration 1 the best fitness is 0.14152526669204235']
# ['At iteration 2 the best fitness is 0.1202880460768938']
# ['At iteration 3 the best fitness is 0.1153931226581335']
# ['At iteration 4 the best fitness is 0.10280459094792604']
# ['At iteration 5 the best fitness is 0.10280459094792604']
# ['At iteration 6 the best fitness is 0.10280459094792604']
# ['At iteration 7 the best fitness is 0.10280459094792604']
# ['At iteration 8 the best fitness is 0.10280459094792604']
# ['At iteration 9 the best fitness is 0.10280459094792604']
# ['At iteration 10 the best fitness is 0.10280459094792604']
# ['At iteration 11 the best fitness is 0.10280459094792604']
# ['At iteration 12 the best fitness is 0.10280459094792604']
# ['At iteration 13 the best fitness is 0.10280459094792604']
# ['At iteration 14 the best fitness is 0.10280459094792604']
# ['At iteration 15 the best fitness is 0.10280459094792604']
# ['At iteration 16 the best fitness is 0.10280459094792604']
# ['At iteration 17 the best fitness is 0.10280459094792604']
# ['At iteration 18 the best fitness is 0.10280459094792604']
# ['At iteration 19 the best fitness is 0.10280459094792604']
# ['At iteration 20 the best fitness is 0.10280459094792604']
# ['At iteration 21 the best fitness is 0.10280459094792604']
# ['At iteration 22 the best fitness is 0.10280459094792604']
# ['At iteration 23 the best fitness is 0.10280459094792604']
# ['At iteration 24 the best fitness is 0.10280459094792604']
# ['At iteration 25 the best fitness is 0.10280459094792604']
# ['At iteration 26 the best fitness is 0.10280459094792604']
# ['At iteration 27 the best fitness is 0.10280459094792604']
# ['At iteration 28 the best fitness is 0.10280459094792604']
# ['At iteration 29 the best fitness is 0.09798882342875004']
#       Weights: depth=0.000, sensor=1.000, skeleton=1.000, video=0.000
#       Best fitness: 0.097989, Time: 263.8s
#     Weights: [depth=0.000, sensor=1.000, skeleton=1.000, video=0.000]
#     Test Acc: 98.13%, F1: 98.02%, Model: 8.223MB
#
# ================================================================================
# ALL WEIGHTED FUSION EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Per-Fold Results CSV

# %%
rows = []
for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'Val Loss': r.get('val_loss', float('inf')),
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Weight Opt Time (s)': r['weight_optimization_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality weights
        mod_w = r['modality_weights']
        for i, mod_name in enumerate(MODALITY_NAMES):
            row[f'w_{mod_name}'] = mod_w[i]
        
        rows.append(row)

df_all = pd.DataFrame(rows).round(4)
df_all.to_csv(RESULTS_ROOT / "all_results_per_fold.csv", index=False)
print(f"Saved: {RESULTS_ROOT / 'all_results_per_fold.csv'}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved: results_weighted_fusion/all_results_per_fold.csv
# Shape: (120, 19)
#           Method  Fold  Test Accuracy (%)  Val Accuracy (%)  Val Loss  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Weight Opt Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  GPU Peak (MB)  w_depth  w_sensor  w_skeleton  w_video
# 0       baseline     1            95.3704           99.0654    0.1984       94.5326          94.5326              94.4444           95.3704               0.0000          8.6391          8.6391       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   1.0000
# 1       baseline     2            91.6667           97.1963    0.2742       89.1828          89.1828              88.1481           91.6667               0.0000          9.5397          9.5397       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   1.0000
# 2       baseline     3            98.1481           99.0654    0.0450       98.1188          98.1188              98.5185           98.1481               0.0000          9.4120          9.4120       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   1.0000
# 3       baseline     4            91.6667           99.0654    0.1253       91.1221          91.1221              95.6143           91.6667               0.0000          9.3842          9.3842       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   1.0000
# 4       baseline     5            92.5926           99.0654    0.1870       91.2092          91.2092              91.0670           92.5926               0.0000          9.3868          9.3869       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   1.0000
# 5       baseline     6            92.5234           99.0741    0.0355       90.6643          90.5771              91.4815           92.5926               0.0000          9.2965          9.2965       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   1.0000
# 6       baseline     7            96.2617           99.0654    0.0579       95.8271          95.7881              97.6720           96.2963               0.0000          9.4916          9.4916       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   1.0000
# 7       baseline     8            96.2617           99.0654    0.8314       95.7095          95.8029              97.4868           96.2963               0.0000          9.3643          9.3643       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   1.0000
# 8   weighted_BAT     1            93.5185           99.0654    0.0964       92.6396          92.6396              92.2222           93.5185             268.4991          9.4418        277.9410       2154011           8.2228        67.0527   0.0000    0.0804      0.3745   0.0000
# 9   weighted_BAT     2            89.8148           97.1963    0.2341       87.1252          87.1252              86.6667           89.8148             273.3387          9.5212        282.8600       2154011           8.2228        67.0527   0.0000    1.0000      1.0000   0.0000
# 10  weighted_BAT     3            92.5926          100.0000    0.0324       90.8888          90.8888              92.1164           92.5926             271.5578          9.4727        281.0306       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   0.0000
# 11  weighted_BAT     4            92.5926          100.0000    0.0644       92.3222          92.3222              94.3210           92.5926             272.1303          9.4181        281.5485       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   0.0000
# 12  weighted_BAT     5            96.2963          100.0000    0.0335       95.8271          95.8271              97.6720           96.2963             272.1664          9.3696        281.5362       2154011           8.2228        67.0527   0.0598    0.6588      0.6602   0.0000
# 13  weighted_BAT     6            96.2617          100.0000    0.1034       95.0617          95.0156              94.4444           96.2963             273.0411          9.4138        282.4550       2154011           8.2228        67.0527   0.2190    0.2930      0.5681   0.3707
# 14  weighted_BAT     7            92.5234           99.0654    0.0801       91.3915          91.4980              92.2634           92.2840             271.4294          9.3932        280.8227       2154011           8.2228        67.0527   0.0000    0.1648      0.4122   0.0000
# 15  weighted_BAT     8            98.1308           99.0654    0.0490       98.1188          98.1012              98.5185           98.1481             272.4012          9.3678        281.7691       2154011           8.2228        67.0527   0.0000    0.9969      1.0000   0.1529
# 16   weighted_CS     1            92.5926           99.0654    0.0975       91.9459          91.9459              92.9630           92.5926             536.6383          9.3362        545.9747       2154011           8.2228        67.0527   0.5874    0.4376      0.8842   0.1209
# 17   weighted_CS     2            83.3333          100.0000    0.0360       80.3616          80.3616              81.7901           83.3333             536.9178          9.4201        546.3381       2154011           8.2228        67.0527   1.0000    1.0000      1.0000   0.3624
# 18   weighted_CS     3            93.5185           99.0654    0.0586       92.2399          92.2399              92.2222           93.5185             533.9371          9.3359        543.2732       2154011           8.2228        67.0527   0.4976    0.9295      0.9874   0.0478
# 19   weighted_CS     4            86.1111          100.0000    0.0743       83.7066          83.7066              85.6173           86.1111             534.5020          9.4569        543.9590       2154011           8.2228        67.0527   0.8060    0.6935      0.6983   0.0000

# %% [markdown]
# ## Summary Table

# %%
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Weight Opt Time (s)': method_df['Weight Opt Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    
    for mod_name in MODALITY_NAMES:
        row[f'Mean w_{mod_name}'] = method_df[f'w_{mod_name}'].mean()
        row[f'Std w_{mod_name}'] = method_df[f'w_{mod_name}'].std()
    
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary = df_summary.sort_values('Mean Test Acc (%)', ascending=False)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#        Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Weight Opt Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean GPU Peak (MB)  Mean w_depth  Std w_depth  Mean w_sensor  Std w_sensor  Mean w_skeleton  Std w_skeleton  Mean w_video  Std w_video
#   weighted_GA              94.78              3.05              93.85              3.64                    262.94                 9.39               272.33               67.05          0.23         0.16           0.64          0.30             0.84            0.12          0.18         0.15
#  weighted_GWO              94.43              4.02              93.81              4.51                    263.20                 9.39               272.58               67.05          0.23         0.27           0.60          0.21             0.81            0.17          0.10         0.15
#  weighted_PSO              94.43              3.57              93.56              4.32                    263.81                 9.47               273.27               67.05          0.51         0.36           0.71          0.26             0.82            0.16          0.03         0.09
#  weighted_MFO              94.32              3.85              93.46              4.54                    254.58                 9.46               264.04               67.05          0.23         0.34           0.86          0.19             0.94            0.10          0.02         0.04
#      baseline              94.31              2.50              93.30              3.16                      0.00                 9.31                 9.31               67.05          1.00         0.00           1.00          0.00             1.00            0.00          1.00         0.00
#  weighted_HHO              94.08              2.56              92.99              3.36                    425.76                 9.42               435.18               67.05          0.20         0.32           0.21          0.19             0.37            0.34          0.08         0.13
#  weighted_FFA              93.97              3.63              92.90              4.20                    263.07                 9.40               272.47               67.05          0.50         0.39           0.60          0.27             0.80            0.30          0.16         0.19
#  weighted_BAT              93.97              2.71              92.92              3.39                    271.82                 9.42               281.25               67.05          0.28         0.45           0.65          0.41             0.75            0.28          0.07         0.13
# weighted_JAYA              93.85              2.51              93.09              2.92                    271.88                 9.45               281.33               67.05          0.53         0.41           0.61          0.21             0.73            0.17          0.06         0.07
#   weighted_DE              93.62              3.62              92.70              4.29                    272.24                 9.43               281.66               67.05          0.27         0.27           0.57          0.15             0.85            0.12          0.07         0.14
#  weighted_WOA              93.39              3.40              92.69              3.83                    263.28                 9.46               272.74               67.05          0.44         0.39           0.64          0.34             0.75            0.27          0.16         0.35
#  weighted_SSA              93.38              3.58              92.49              4.06                    659.07                 9.42               668.50               67.05          0.29         0.26           0.65          0.25             0.76            0.15          0.12         0.16
#  weighted_MVO              93.04              2.84              92.10              3.42                    263.52                 9.42               272.94               67.05          0.39         0.26           0.49          0.24             0.81            0.25          0.06         0.08
#  weighted_SCA              92.69              4.57              91.90              5.12                    263.98                 9.49               273.46               67.05          0.44         0.41           0.89          0.20             1.00            0.01          0.11         0.24
#   weighted_CS              92.58              5.42              91.48              6.46                    534.80                 9.38               544.18               67.05          0.51         0.30           0.78          0.17             0.89            0.12          0.20         0.17

# %% [markdown]
# ## Select Best Weights Per Fold
#
# For each fold, pick the metaheuristic whose weighted fusion achieved the **highest val accuracy**.
# Save these best weights so File 2 can load and apply them.

# %%
best_weights_per_fold = {}  # {fold_idx: {'weights': array, 'method': str, 'val_loss': float, ...}}

weighted_methods = [m for m in ALL_METHODS if m != 'baseline']

print("=" * 80)
print("BEST WEIGHTED METHOD PER FOLD (selected by lowest val loss)")
print("=" * 80)

for fold_idx in range(N_FOLDS):
    best_val_loss = float('inf')
    best_method = None
    best_weights = None
    best_test_acc = None
    best_val_acc = None
    
    for method_name in weighted_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['val_loss'] < best_val_loss:
                best_val_loss = r['val_loss']
                best_method = method_name
                best_weights = r['modality_weights'].copy()
                best_test_acc = r['test_acc']
                best_val_acc = r['val_acc']
    
    best_weights_per_fold[fold_idx] = {
        'weights': best_weights,
        'method': best_method,
        'val_loss': best_val_loss,
        'val_acc': best_val_acc,
        'test_acc': best_test_acc,
    }
    
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={best_weights[i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {best_method} | Val loss: {best_val_loss:.6f} | "
          f"Val acc: {best_val_acc*100:.2f}% | Test: {best_test_acc*100:.2f}% | Weights: [{w_str}]")

# Compare with baseline
print(f"\n  {'---' * 20}")
print(f"  Baseline comparison:")
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        bl = master_results['baseline'][fold_idx]
        bw = best_weights_per_fold[fold_idx]
        diff = bw['test_acc'] - bl['test_acc']
        print(f"    Fold {fold_idx+1}: Baseline={bl['test_acc']*100:.2f}%, "
              f"Best weighted={bw['test_acc']*100:.2f}%, Diff={diff*100:+.2f}%")

# Save for File 2
save_obj = {}
for fold_idx, info in best_weights_per_fold.items():
    save_obj[fold_idx] = {
        'weights': info['weights'],
        'method': info['method'],
        'val_loss': info['val_loss'],
        'val_acc': info['val_acc'],
        'test_acc': info['test_acc'],
    }

joblib.dump(save_obj, RESULTS_ROOT / "best_weights_per_fold.pkl")
print(f"\nSaved: {RESULTS_ROOT / 'best_weights_per_fold.pkl'}")
print("This file will be loaded by File 2 for weighted feature selection.")
# Out:
# ================================================================================
# BEST WEIGHTED METHOD PER FOLD (selected by lowest val loss)
# ================================================================================
#   Fold 1: weighted_JAYA | Val loss: 0.028060 | Val acc: 100.00% | Test: 94.44% | Weights: [depth=0.154, sensor=0.385, skeleton=0.668, video=0.168]
#   Fold 2: weighted_SCA | Val loss: 0.014594 | Val acc: 100.00% | Test: 93.52% | Weights: [depth=0.000, sensor=0.986, skeleton=0.981, video=0.000]
#   Fold 3: weighted_SSA | Val loss: 0.013213 | Val acc: 100.00% | Test: 98.15% | Weights: [depth=0.000, sensor=0.984, skeleton=0.785, video=0.008]
#   Fold 4: weighted_JAYA | Val loss: 0.013496 | Val acc: 100.00% | Test: 88.89% | Weights: [depth=0.000, sensor=0.570, skeleton=0.606, video=0.000]
#   Fold 5: weighted_BAT | Val loss: 0.033486 | Val acc: 100.00% | Test: 96.30% | Weights: [depth=0.060, sensor=0.659, skeleton=0.660, video=0.000]
#   Fold 6: weighted_GWO | Val loss: 0.022203 | Val acc: 100.00% | Test: 95.33% | Weights: [depth=0.074, sensor=0.969, skeleton=0.916, video=0.426]
#   Fold 7: weighted_JAYA | Val loss: 0.044334 | Val acc: 99.07% | Test: 97.20% | Weights: [depth=0.776, sensor=0.504, skeleton=0.510, video=0.025]
#   Fold 8: weighted_GA | Val loss: 0.038080 | Val acc: 99.07% | Test: 100.00% | Weights: [depth=0.206, sensor=0.764, skeleton=0.866, video=0.260]
#
#   ------------------------------------------------------------
#   Baseline comparison:
#     Fold 1: Baseline=95.37%, Best weighted=94.44%, Diff=-0.93%
#     Fold 2: Baseline=91.67%, Best weighted=93.52%, Diff=+1.85%
#     Fold 3: Baseline=98.15%, Best weighted=98.15%, Diff=+0.00%
#     Fold 4: Baseline=91.67%, Best weighted=88.89%, Diff=-2.78%
#     Fold 5: Baseline=92.59%, Best weighted=96.30%, Diff=+3.70%
#     Fold 6: Baseline=92.52%, Best weighted=95.33%, Diff=+2.80%
#     Fold 7: Baseline=96.26%, Best weighted=97.20%, Diff=+0.93%
#     Fold 8: Baseline=96.26%, Best weighted=100.00%, Diff=+3.74%
#
# Saved: results_weighted_fusion/best_weights_per_fold.pkl
# This file will be loaded by File 2 for weighted feature selection.

# %% [markdown]
# ## Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy comparison (box plot)
# ============================================================================
fig, ax = plt.subplots(figsize=(18, 7))
order = df_summary['Method'].tolist()
sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax,
              color='black', alpha=0.5, size=4)
ax.set_title('Weighted Early Fusion: Test Accuracy Comparison', fontsize=14)
ax.set_ylabel('Test Accuracy (%)')
plt.xticks(rotation=60, ha='right')
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'accuracy_boxplot.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 2: Learned modality weights heatmap (all methods x folds)
# ============================================================================
for mod_name in MODALITY_NAMES:
    fig, ax = plt.subplots(figsize=(12, 8))
    pivot = df_all[df_all['Method'] != 'baseline'].pivot_table(
        values=f'w_{mod_name}', index='Method', columns='Fold'
    )
    sns.heatmap(pivot, annot=True, fmt='.3f', cmap='YlOrRd', ax=ax,
                vmin=0, vmax=1, linewidths=0.5, cbar_kws={'label': 'Weight'})
    ax.set_title(f'Learned Weight for {mod_name.upper()} Modality', fontsize=14)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'weights_heatmap_{mod_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
# ============================================================================
# PLOT 3: Average modality weights bar chart (all optimizers)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))

weight_methods = [m for m in ALL_METHODS if m != 'baseline']
x = np.arange(len(weight_methods))
width = 0.18
colors = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']

for i, mod_name in enumerate(MODALITY_NAMES):
    means, stds = [], []
    for method in weight_methods:
        mdf = df_all[df_all['Method'] == method]
        means.append(mdf[f'w_{mod_name}'].mean())
        stds.append(mdf[f'w_{mod_name}'].std())
    ax.bar(x + i * width, means, width, yerr=stds, capsize=2,
           label=mod_name, color=colors[i], alpha=0.8)

ax.set_ylabel('Weight', fontsize=12)
ax.set_title('Average Learned Modality Weights by Optimizer', fontsize=14)
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels([m.replace('weighted_', '') for m in weight_methods], rotation=45, ha='right')
ax.legend()
ax.set_ylim(0, 1.15)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'avg_modality_weights_bar.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 4: Improvement over baseline
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 6))

baseline_mean = df_summary[df_summary['Method'] == 'baseline']['Mean Test Acc (%)'].values[0]

improvements = []
method_labels = []
for _, row in df_summary.iterrows():
    if row['Method'] == 'baseline':
        continue
    improvements.append(row['Mean Test Acc (%)'] - baseline_mean)
    method_labels.append(row['Method'].replace('weighted_', ''))

colors_imp = ['green' if x >= 0 else 'red' for x in improvements]
bars = ax.bar(range(len(improvements)), improvements, color=colors_imp, alpha=0.7)
ax.axhline(y=0, color='black', linewidth=0.8)
ax.set_xticks(range(len(improvements)))
ax.set_xticklabels(method_labels, rotation=45, ha='right')
ax.set_ylabel('Accuracy Improvement over Baseline (%)', fontsize=12)
ax.set_title('Weighted Fusion vs Simple Concatenation', fontsize=14)

for bar, val in zip(bars, improvements):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            f'{val:+.2f}%', ha='center', va='bottom' if val >= 0 else 'top', fontsize=9)

plt.tight_layout()
plt.savefig(PLOTS_DIR / 'improvement_over_baseline.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 5: Convergence curves
# ============================================================================
fig, ax = plt.subplots(figsize=(14, 8))

for method in weight_methods:
    all_conv = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            conv = master_results[method][fold_idx].get('convergence', None)
            if conv is not None and len(conv) > 0:
                all_conv.append(conv)
    
    if len(all_conv) > 0:
        min_len = min(len(c) for c in all_conv)
        all_conv_arr = np.array([c[:min_len] for c in all_conv])
        mean_conv = np.mean(all_conv_arr, axis=0)
        ax.plot(range(1, min_len + 1), mean_conv,
                label=method.replace('weighted_', ''), linewidth=2)

ax.set_xlabel('Iteration', fontsize=12)
ax.set_ylabel('Fitness (lower is better)', fontsize=12)
ax.set_title('Weight Optimization Convergence (averaged across folds)', fontsize=14)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'convergence_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ============================================================================
# PLOT 6: Best weights per fold (the ones that will be used in File 2)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 6))

fold_labels = [f"Fold {i+1}\n({best_weights_per_fold[i]['method'].replace('weighted_', '')})" 
               for i in range(N_FOLDS)]
x = np.arange(N_FOLDS)
width = 0.18
colors = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']

for i, mod_name in enumerate(MODALITY_NAMES):
    weights = [best_weights_per_fold[fold_idx]['weights'][i] for fold_idx in range(N_FOLDS)]
    ax.bar(x + i * width, weights, width, label=mod_name, color=colors[i], alpha=0.8)

ax.set_ylabel('Weight', fontsize=12)
ax.set_title('Best Learned Modality Weights Per Fold (used in File 2)', fontsize=14)
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels(fold_labels, fontsize=9)
ax.legend()
ax.set_ylim(0, 1.15)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'best_weights_per_fold.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Statistical Significance

# %%
from scipy.stats import wilcoxon, ttest_rel

print("=" * 80)
print("STATISTICAL SIGNIFICANCE: each weighted method vs baseline")
print("=" * 80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []
for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) == len(baseline_accs) and len(method_accs) >= 2:
        try:
            t_stat, t_pval = ttest_rel(method_accs, baseline_accs)
        except:
            t_stat, t_pval = np.nan, np.nan
        try:
            w_stat, w_pval = wilcoxon(np.array(method_accs) - np.array(baseline_accs))
        except:
            w_stat, w_pval = np.nan, np.nan
        
        diff = np.mean(method_accs) - np.mean(baseline_accs)
        sig = '***' if t_pval < 0.001 else '**' if t_pval < 0.01 else '*' if t_pval < 0.05 else ''
        
        stat_rows.append({
            'Method': method,
            'Mean Diff (%)': diff,
            'Paired t p-val': t_pval,
            'Wilcoxon p-val': w_pval,
            'Sig': sig
        })
        
        print(f"  {method:25s}: diff={diff:+.2f}%, t-test p={t_pval:.4f}, "
              f"wilcoxon p={w_pval:.4f} {sig}")

df_stats = pd.DataFrame(stat_rows)
df_stats.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE: each weighted method vs baseline
# ================================================================================
#   weighted_BAT             : diff=-0.35%, t-test p=0.7848, wilcoxon p=0.8750
#   weighted_CS              : diff=-1.73%, t-test p=0.3248, wilcoxon p=0.4609
#   weighted_DE              : diff=-0.69%, t-test p=0.4243, wilcoxon p=0.5469
#   weighted_FFA             : diff=-0.34%, t-test p=0.8258, wilcoxon p=0.8125
#   weighted_GA              : diff=+0.47%, t-test p=0.6319, wilcoxon p=0.7344
#   weighted_GWO             : diff=+0.12%, t-test p=0.9119, wilcoxon p=0.9297
#   weighted_HHO             : diff=-0.23%, t-test p=0.8025, wilcoxon p=0.6875
#   weighted_JAYA            : diff=-0.46%, t-test p=0.6569, wilcoxon p=0.8438
#   weighted_MFO             : diff=+0.01%, t-test p=0.9939, wilcoxon p=0.9219
#   weighted_MVO             : diff=-1.27%, t-test p=0.2948, wilcoxon p=0.4375
#   weighted_PSO             : diff=+0.12%, t-test p=0.9044, wilcoxon p=0.9375
#   weighted_SCA             : diff=-1.62%, t-test p=0.2826, wilcoxon p=0.4453
#   weighted_SSA             : diff=-0.93%, t-test p=0.2275, wilcoxon p=0.3125
#   weighted_WOA             : diff=-0.92%, t-test p=0.3464, wilcoxon p=0.4844

# %% [markdown]
# ## Final Summary

# %%
print("=" * 80)
print("FILE 1 COMPLETE — WEIGHTED EARLY FUSION")
print("=" * 80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")
print(f"\nPlots:")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\n{'=' * 80}")
print("RESULTS (sorted by mean test accuracy):")
print("=" * 80)
for _, row in df_summary.iterrows():
    w_str = ' | '.join([f"{m}={row[f'Mean w_{m}']:.3f}" for m in MODALITY_NAMES])
    print(f"  {row['Method']:25s} | Acc: {row['Mean Test Acc (%)']:6.2f}% "
          f"(+/-{row['Std Test Acc (%)']:.2f}) | {w_str}")

print(f"\n{'=' * 80}")
print("BEST WEIGHTS PER FOLD (to be used in File 2):")
print("=" * 80)
for fold_idx in range(N_FOLDS):
    info = best_weights_per_fold[fold_idx]
    w_str = ', '.join([f"{MODALITY_NAMES[i]}={info['weights'][i]:.3f}" for i in range(N_MODALITIES)])
    print(f"  Fold {fold_idx+1}: {info['method']:25s} | Val loss: {info['val_loss']:.6f} | Val acc: {info['val_acc']*100:.2f}% | [{w_str}]")

print(f"\nKey output for File 2: {RESULTS_ROOT / 'best_weights_per_fold.pkl'}")
# Out:
# ================================================================================
# FILE 1 COMPLETE — WEIGHTED EARLY FUSION
# ================================================================================
#
# Output directory: results_weighted_fusion
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# Plots:
#   accuracy_boxplot.png
#   avg_modality_weights_bar.png
#   best_weights_per_fold.png
#   convergence_curves.png
#   improvement_over_baseline.png
#   weights_heatmap_depth.png
#   weights_heatmap_sensor.png
#   weights_heatmap_skeleton.png
#   weights_heatmap_video.png
#
# ================================================================================
# RESULTS (sorted by mean test accuracy):
# ================================================================================
#   weighted_GA               | Acc:  94.78% (+/-3.05) | depth=0.230 | sensor=0.640 | skeleton=0.840 | video=0.180
#   weighted_GWO              | Acc:  94.43% (+/-4.02) | depth=0.230 | sensor=0.600 | skeleton=0.810 | video=0.100
#   weighted_PSO              | Acc:  94.43% (+/-3.57) | depth=0.510 | sensor=0.710 | skeleton=0.820 | video=0.030
#   weighted_MFO              | Acc:  94.32% (+/-3.85) | depth=0.230 | sensor=0.860 | skeleton=0.940 | video=0.020
#   baseline                  | Acc:  94.31% (+/-2.50) | depth=1.000 | sensor=1.000 | skeleton=1.000 | video=1.000
#   weighted_HHO              | Acc:  94.08% (+/-2.56) | depth=0.200 | sensor=0.210 | skeleton=0.370 | video=0.080
#   weighted_FFA              | Acc:  93.97% (+/-3.63) | depth=0.500 | sensor=0.600 | skeleton=0.800 | video=0.160
#   weighted_BAT              | Acc:  93.97% (+/-2.71) | depth=0.280 | sensor=0.650 | skeleton=0.750 | video=0.070
#   weighted_JAYA             | Acc:  93.85% (+/-2.51) | depth=0.530 | sensor=0.610 | skeleton=0.730 | video=0.060
#   weighted_DE               | Acc:  93.62% (+/-3.62) | depth=0.270 | sensor=0.570 | skeleton=0.850 | video=0.070
#   weighted_WOA              | Acc:  93.39% (+/-3.40) | depth=0.440 | sensor=0.640 | skeleton=0.750 | video=0.160
#   weighted_SSA              | Acc:  93.38% (+/-3.58) | depth=0.290 | sensor=0.650 | skeleton=0.760 | video=0.120
#   weighted_MVO              | Acc:  93.04% (+/-2.84) | depth=0.390 | sensor=0.490 | skeleton=0.810 | video=0.060
#   weighted_SCA              | Acc:  92.69% (+/-4.57) | depth=0.440 | sensor=0.890 | skeleton=1.000 | video=0.110
#   weighted_CS               | Acc:  92.58% (+/-5.42) | depth=0.510 | sensor=0.780 | skeleton=0.890 | video=0.200
#
# ================================================================================
# BEST WEIGHTS PER FOLD (to be used in File 2):
# ================================================================================
#   Fold 1: weighted_JAYA             | Val loss: 0.028060 | Val acc: 100.00% | [depth=0.154, sensor=0.385, skeleton=0.668, video=0.168]
#   Fold 2: weighted_SCA              | Val loss: 0.014594 | Val acc: 100.00% | [depth=0.000, sensor=0.986, skeleton=0.981, video=0.000]
#   Fold 3: weighted_SSA              | Val loss: 0.013213 | Val acc: 100.00% | [depth=0.000, sensor=0.984, skeleton=0.785, video=0.008]
#   Fold 4: weighted_JAYA             | Val loss: 0.013496 | Val acc: 100.00% | [depth=0.000, sensor=0.570, skeleton=0.606, video=0.000]
#   Fold 5: weighted_BAT              | Val loss: 0.033486 | Val acc: 100.00% | [depth=0.060, sensor=0.659, skeleton=0.660, video=0.000]
#   Fold 6: weighted_GWO              | Val loss: 0.022203 | Val acc: 100.00% | [depth=0.074, sensor=0.969, skeleton=0.916, video=0.426]
#   Fold 7: weighted_JAYA             | Val loss: 0.044334 | Val acc: 99.07% | [depth=0.776, sensor=0.504, skeleton=0.510, video=0.025]
#   Fold 8: weighted_GA               | Val loss: 0.038080 | Val acc: 99.07% | [depth=0.206, sensor=0.764, skeleton=0.866, video=0.260]
#
# Key output for File 2: results_weighted_fusion/best_weights_per_fold.pkl
