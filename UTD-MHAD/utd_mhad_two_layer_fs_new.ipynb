# %% [markdown]
# # UTD-MHAD: Two-Layer Feature Selection (Per-Modality → Combined)
#
# ## Overview
# This notebook implements a **two-layer feature selection** pipeline:
#
# **Layer 1 (already done):** Feature selection was run independently on each modality (depth, sensor, skeleton, video). Results are stored in:
# - `results_new_depth/`
# - `results_new_sensor/`
# - `results_new_skeleton/`
# - `results_new_video/`
#
# **Layer 2 (this notebook):**
# 1. **Combine** the selected features from each modality into a unified feature set
# 2. **Evaluate** the combined features (Layer 1 result) on HAR
# 3. **Run a second layer** of feature selection on the combined set
#
# ### Combination Strategy:
# - **Standard methods** (mutual_info, rfe, lasso): Combine features selected by the *same* method across all 4 modalities. Then run the same FS method again on the combined set.
# - **Metaheuristics**: For each fold, find the *best* metaheuristic (highest test accuracy) per modality. Combine those best-selected features. Then run all 14 metaheuristics on that combined set.
# - **Baseline**: Combine all baseline (all features) from each modality = full feature set.
#
# All results saved in `results_two_layer/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new")

# Layer 1 results directories (already computed)
LAYER1_DIRS = {
    'depth': Path("results_new_depth"),
    'sensor': Path("results_new_sensor"),
    'skeleton': Path("results_new_skeleton"),
    'video': Path("results_new_video"),
}

# Master output directory for two-layer results
RESULTS_ROOT = Path("results_two_layer")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters (same as original)
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of combined features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

STANDARD_METHODS = ['mutual_info', 'rfe', 'lasso']
META_METHODS = [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]
# For layer 2, we have: baseline, 3 standard methods, and meta_best (which runs all 14 metas)
# Output method names for layer 2:
ALL_METHODS_L2 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS_L2:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)
# Also create combined_layer1 directory
(RESULTS_ROOT / "combined_layer1").mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection (Layer 2): {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Layer 1 dirs: {list(LAYER1_DIRS.keys())}")

# Verify layer 1 directories exist
for mod, d in LAYER1_DIRS.items():
    if d.exists():
        print(f"  ✓ {d} exists")
    else:
        print(f"  ✗ {d} MISSING!")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection (Layer 2): 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Layer 1 dirs: ['depth', 'sensor', 'skeleton', 'video']
#   ✓ results_new_depth exists
#   ✓ results_new_sensor exists
#   ✓ results_new_skeleton exists
#   ✓ results_new_video exists

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
    'depth': first_sample['depth_feat'].shape[0],
    'sensor': first_sample['sensor_feat'].shape[0],
    'skeleton': first_sample['skeleton_feat'].shape[0],
    'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")

# Compute modality offsets in the unified feature vector
MODALITY_OFFSETS = {}
offset = 0
for mod, dim in FEATURE_DIMS.items():
    MODALITY_OFFSETS[mod] = (offset, offset + dim)
    offset += dim
print(f"\nModality offsets in unified vector:")
for mod, (s, e) in MODALITY_OFFSETS.items():
    print(f"  {mod}: [{s}, {e})")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   video: 1420
#   TOTAL: 3933
#
# Modality offsets in unified vector:
#   depth: [0, 216)
#   sensor: [216, 868)
#   skeleton: [868, 2513)
#   video: [2513, 3933)

# %% [markdown]
# ## Neural Network Model

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Load Layer 1 Results (Pre-computed Per-Modality Feature Selection)
#
# Load the feature masks from each modality's per-fold results.

# %%
def load_layer1_masks():
    """
    Load all Layer 1 feature masks from per-modality results directories.
    
    Returns:
        layer1_masks: dict[modality][method][fold_idx] = binary_mask (numpy bool array)
        layer1_results: dict[modality][method][fold_idx] = json_results (dict)
    """
    layer1_masks = {}
    layer1_results = {}
    
    all_methods_l1 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]
    
    for modality, results_dir in LAYER1_DIRS.items():
        layer1_masks[modality] = {}
        layer1_results[modality] = {}
        
        for method in all_methods_l1:
            layer1_masks[modality][method] = {}
            layer1_results[modality][method] = {}
            
            method_dir = results_dir / method
            if not method_dir.exists():
                print(f"  WARNING: {method_dir} does not exist!")
                continue
            
            for fold_idx in range(N_FOLDS):
                mask_path = method_dir / f"fold_{fold_idx+1}_mask.npy"
                json_path = method_dir / f"fold_{fold_idx+1}.json"
                
                if mask_path.exists():
                    mask = np.load(mask_path)
                    layer1_masks[modality][method][fold_idx] = mask
                else:
                    print(f"  WARNING: Missing mask: {mask_path}")
                
                if json_path.exists():
                    with open(json_path) as f:
                        layer1_results[modality][method][fold_idx] = json_lib.load(f)
    
    return layer1_masks, layer1_results

layer1_masks, layer1_results = load_layer1_masks()

# Summary
print("\n" + "="*80)
print("LAYER 1 MASKS LOADED")
print("="*80)
modalities = list(LAYER1_DIRS.keys())
all_methods_l1 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for modality in modalities:
    n_loaded = sum(
        len(layer1_masks[modality].get(m, {})) 
        for m in all_methods_l1
    )
    print(f"  {modality}: {n_loaded} fold-masks loaded across {len(all_methods_l1)} methods")
# Out:
# ================================================================================
# LAYER 1 MASKS LOADED
# ================================================================================
#   depth: 136 fold-masks loaded across 17 methods
#   sensor: 136 fold-masks loaded across 17 methods
#   skeleton: 136 fold-masks loaded across 17 methods
#   video: 136 fold-masks loaded across 17 methods

# %% [markdown]
# ## Combine Layer 1 Selected Features Into Unified Masks
#
# ### Strategy:
# - **Standard methods** (mutual_info, rfe, lasso): For each fold, take the selected features from the same method in each modality and combine them (union into unified feature space).
# - **Metaheuristics**: For each fold, find the best metaheuristic per modality (highest test accuracy), then combine those best-selected features.
# - **Baseline**: All features from all modalities (full feature set).
#
# The combined mask is over the full unified feature space (depth + sensor + skeleton + video).

# %%
def build_combined_mask_standard(method, fold_idx):
    """
    For a standard method, combine selected features from the same method 
    across all 4 modalities into a unified mask over the full feature space.
    
    Each modality mask is a boolean array over that modality's features only.
    We map them to their correct positions in the unified vector.
    """
    unified_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    
    for modality in modalities:
        if method not in layer1_masks[modality]:
            continue
        if fold_idx not in layer1_masks[modality][method]:
            continue
        
        mod_mask = layer1_masks[modality][method][fold_idx]
        start, end = MODALITY_OFFSETS[modality]
        mod_dim = end - start
        
        # The modality mask length should match the modality dimension
        if len(mod_mask) == mod_dim:
            unified_mask[start:end] = mod_mask
        else:
            print(f"  WARNING: {modality}/{method}/fold_{fold_idx+1} mask length "
                  f"{len(mod_mask)} != expected {mod_dim}")
    
    return unified_mask


def find_best_meta_per_modality(fold_idx):
    """
    For a given fold, find which metaheuristic gave the highest test accuracy
    in each modality. Returns dict[modality] = (best_method_name, test_acc).
    """
    best_per_mod = {}
    
    for modality in modalities:
        best_method = None
        best_acc = -1.0
        
        for method in META_METHODS:
            if method not in layer1_results[modality]:
                continue
            if fold_idx not in layer1_results[modality][method]:
                continue
            
            result = layer1_results[modality][method][fold_idx]
            test_acc = result.get('test_acc', 0)
            
            if test_acc > best_acc:
                best_acc = test_acc
                best_method = method
        
        best_per_mod[modality] = (best_method, best_acc)
    
    return best_per_mod


def build_combined_mask_best_meta(fold_idx):
    """
    For metaheuristics: find best meta per modality for this fold,
    then combine their selected features into a unified mask.
    """
    unified_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    best_per_mod = find_best_meta_per_modality(fold_idx)
    
    for modality in modalities:
        best_method, best_acc = best_per_mod[modality]
        if best_method is None:
            print(f"  WARNING: No meta results for {modality} fold {fold_idx+1}")
            continue
        
        mod_mask = layer1_masks[modality][best_method][fold_idx]
        start, end = MODALITY_OFFSETS[modality]
        mod_dim = end - start
        
        if len(mod_mask) == mod_dim:
            unified_mask[start:end] = mod_mask
        else:
            print(f"  WARNING: {modality}/{best_method}/fold_{fold_idx+1} mask length "
                  f"{len(mod_mask)} != expected {mod_dim}")
    
    return unified_mask, best_per_mod


# Build all combined masks
combined_masks = {}  # method -> {fold_idx: mask}

# Standard methods
for method in STANDARD_METHODS:
    combined_masks[method] = {}
    for fold_idx in range(N_FOLDS):
        combined_masks[method][fold_idx] = build_combined_mask_standard(method, fold_idx)

# Best metaheuristic combination
combined_masks['meta_best'] = {}
meta_best_info = {}  # fold_idx -> best_per_mod
for fold_idx in range(N_FOLDS):
    mask, best_per_mod = build_combined_mask_best_meta(fold_idx)
    combined_masks['meta_best'][fold_idx] = mask
    meta_best_info[fold_idx] = best_per_mod

# Print summary
print("="*80)
print("COMBINED LAYER 1 MASKS SUMMARY")
print("="*80)

for method in STANDARD_METHODS + ['meta_best']:
    avg_selected = np.mean([np.sum(combined_masks[method][f]) for f in range(N_FOLDS)])
    print(f"  {method:15s}: avg {avg_selected:.0f}/{TOTAL_FEATURES} features selected "
          f"({avg_selected/TOTAL_FEATURES*100:.1f}%)")

print("\nBest metaheuristic per modality per fold:")
for fold_idx in range(N_FOLDS):
    info = meta_best_info[fold_idx]
    parts = [f"{mod}={info[mod][0]}({info[mod][1]*100:.1f}%)" for mod in modalities]
    print(f"  Fold {fold_idx+1}: {', '.join(parts)}")
# Out:
# ================================================================================
# COMBINED LAYER 1 MASKS SUMMARY
# ================================================================================
#   mutual_info    : avg 1966/3933 features selected (50.0%)
#   rfe            : avg 1966/3933 features selected (50.0%)
#   lasso          : avg 1966/3933 features selected (50.0%)
#   meta_best      : avg 1857/3933 features selected (47.2%)
#
# Best metaheuristic per modality per fold:
#   Fold 1: depth=meta_SSA(65.7%), sensor=meta_MVO(89.8%), skeleton=meta_BAT(91.7%), video=meta_DE(74.1%)
#   Fold 2: depth=meta_DE(55.6%), sensor=meta_BAT(87.0%), skeleton=meta_GA(81.5%), video=meta_SCA(75.9%)
#   Fold 3: depth=meta_DE(59.3%), sensor=meta_BAT(91.7%), skeleton=meta_GWO(91.7%), video=meta_FFA(73.1%)
#   Fold 4: depth=meta_FFA(63.0%), sensor=meta_MFO(89.8%), skeleton=meta_GA(84.3%), video=meta_CS(72.2%)
#   Fold 5: depth=meta_HHO(71.3%), sensor=meta_MVO(88.0%), skeleton=meta_BAT(89.8%), video=meta_GA(71.3%)
#   Fold 6: depth=meta_BAT(57.9%), sensor=meta_BAT(79.4%), skeleton=meta_SSA(93.5%), video=meta_FFA(77.6%)
#   Fold 7: depth=meta_JAYA(57.0%), sensor=meta_HHO(91.6%), skeleton=meta_BAT(89.7%), video=meta_CS(77.6%)
#   Fold 8: depth=meta_DE(76.6%), sensor=meta_DE(89.7%), skeleton=meta_MFO(94.4%), video=meta_GA(85.0%)

# %% [markdown]
# ## Evaluate Combined Layer 1 Features (Before Second Layer FS)
#
# Train and evaluate the neural network on the combined features from Layer 1,
# **without** any additional feature selection. This shows the HAR performance
# of simply combining per-modality selected features.

# %%
def evaluate_combined_layer1():
    """
    Evaluate combined Layer 1 features (no second-layer FS yet).
    This gives us the baseline performance of the combined per-modality selections.
    """
    print("="*80)
    print("EVALUATING COMBINED LAYER 1 FEATURES (before Layer 2 FS)")
    print("="*80)
    
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    layer1_eval_results = {}  # method -> {fold_idx: metrics}
    
    methods_to_eval = STANDARD_METHODS + ['meta_best']
    
    for method in methods_to_eval:
        layer1_eval_results[method] = {}
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*60}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*60}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val (same as original)
        np.random.seed(42)  # ensure same split as original
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        for method in methods_to_eval:
            print(f"\n  --- Combined L1: {method.upper()} ---")
            
            feature_mask = combined_masks[method][fold_idx]
            
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            modality_ret = calculate_modality_retention(feature_mask, FEATURE_DIMS)
            
            fold_result = {
                'fold': fold_idx,
                'method': f'combined_L1_{method}',
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
            }
            
            layer1_eval_results[method][fold_idx] = fold_result
            
            # Save
            save_dir = RESULTS_ROOT / "combined_layer1"
            fold_save = {k: v for k, v in fold_result.items() if k != 'feature_mask'}
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(save_dir / f"combined_L1_{method}_fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(save_dir / f"combined_L1_{method}_fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%)")
            
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    return layer1_eval_results

layer1_eval_results = evaluate_combined_layer1()
# Out:
# ================================================================================
# EVALUATING COMBINED LAYER 1 FEATURES (before Layer 2 FS)
# ================================================================================
#
# ############################################################
# # FOLD 1/8
# ############################################################
#
#   --- Combined L1: BASELINE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3933/3933 (100.0%)
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 93.52%, F1: 92.27%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 96.30%, F1: 95.83%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 93.52%, F1: 93.69%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 94.44%, F1: 93.85%, Features: 1884/3933 (47.9%)
#
# ############################################################
# # FOLD 2/8
# ############################################################
#
#   --- Combined L1: BASELINE ---
#     Test Acc: 95.37%, F1: 94.12%, Features: 3933/3933 (100.0%)
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 88.89%, F1: 87.23%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 93.52%, F1: 92.91%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 95.37%, F1: 95.03%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 92.59%, F1: 92.11%, Features: 1744/3933 (44.3%)
#
# ############################################################
# # FOLD 3/8
# ############################################################
#
#   --- Combined L1: BASELINE ---
#     Test Acc: 94.44%, F1: 94.25%, Features: 3933/3933 (100.0%)
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 92.59%, F1: 90.89%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 91.67%, F1: 89.95%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 91.67%, F1: 90.39%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 93.52%, F1: 93.10%, Features: 1712/3933 (43.5%)
#
# ############################################################
# # FOLD 4/8
# ############################################################
#
#   --- Combined L1: BASELINE ---
#     Test Acc: 92.59%, F1: 91.61%, Features: 3933/3933 (100.0%)
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 94.44%, F1: 93.99%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 94.44%, F1: 93.87%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 87.04%, F1: 85.96%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 93.52%, F1: 92.53%, Features: 1902/3933 (48.4%)
#
# ############################################################
# # FOLD 5/8
# ############################################################
#
#   --- Combined L1: BASELINE ---
#     Test Acc: 93.52%, F1: 93.01%, Features: 3933/3933 (100.0%)
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 94.44%, F1: 93.09%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 93.52%, F1: 92.15%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 82.41%, F1: 78.97%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 98.15%, F1: 98.12%, Features: 1939/3933 (49.3%)
#
# ############################################################
# # FOLD 6/8
# ############################################################
#
#   --- Combined L1: BASELINE ---
#     Test Acc: 96.26%, F1: 95.83%, Features: 3933/3933 (100.0%)
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 92.52%, F1: 91.88%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 98.13%, F1: 98.12%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 93.46%, F1: 92.77%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 94.39%, F1: 93.54%, Features: 1891/3933 (48.1%)
#
# ############################################################
# # FOLD 7/8
# ############################################################
#
#   --- Combined L1: BASELINE ---
#     Test Acc: 91.59%, F1: 90.21%, Features: 3933/3933 (100.0%)
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 93.46%, F1: 91.93%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 94.39%, F1: 93.09%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 95.33%, F1: 95.36%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 92.52%, F1: 91.23%, Features: 1842/3933 (46.8%)
#
# ############################################################
# # FOLD 8/8
# ############################################################
#
#   --- Combined L1: BASELINE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3933/3933 (100.0%)
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 99.07%, F1: 98.94%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 96.26%, F1: 96.17%, Features: 1966/3933 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 98.13%, F1: 98.12%, Features: 1939/3933 (49.3%)

# %% [markdown]
# ## Layer 1 Combined Results Summary

# %%
print("\n" + "="*80)
print("COMBINED LAYER 1 RESULTS SUMMARY")
print("="*80)

methods_to_eval = ['baseline'] + STANDARD_METHODS + ['meta_best']

rows = []
for method in methods_to_eval:
    accs = []
    f1s = []
    feats = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in layer1_eval_results[method]:
            r = layer1_eval_results[method][fold_idx]
            accs.append(r['test_acc'] * 100)
            f1s.append(r['test_f1_macro'] * 100)
            feats.append(r['num_features_selected'])
    
    if accs:
        rows.append({
            'Method': f'Combined_L1_{method}',
            'Mean Test Acc (%)': np.mean(accs),
            'Std Test Acc (%)': np.std(accs),
            'Mean F1 Macro (%)': np.mean(f1s),
            'Mean Features': np.mean(feats),
            'Mean Retention (%)': np.mean(feats) / TOTAL_FEATURES * 100,
        })

df_l1_summary = pd.DataFrame(rows).round(2)
print(df_l1_summary.to_string(index=False))

# Save
df_l1_summary.to_csv(RESULTS_ROOT / "combined_layer1_summary.csv", index=False)
print(f"\nSaved: combined_layer1_summary.csv")
# Out:
# ================================================================================
# COMBINED LAYER 1 RESULTS SUMMARY
# ================================================================================
#                  Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Mean Features  Mean Retention (%)
#    Combined_L1_baseline              95.47              2.96              94.88        3933.00              100.00
# Combined_L1_mutual_info              93.62              2.64              92.53        1966.00               49.99
#         Combined_L1_rfe              95.25              2.55              94.49        1966.00               49.99
#       Combined_L1_lasso              91.88              4.50              91.04        1966.00               49.99
#   Combined_L1_meta_best              94.66              2.11              94.07        1856.62               47.21
#
# Saved: combined_layer1_summary.csv

# %% [markdown]
# ## Feature Selection Methods for Layer 2
#
# These are the same FS methods as the original notebook, but now they operate
# on the **combined Layer 1 features** (a subset of the full feature space).

# %%
def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


def create_fitness_function_evolopy_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Create fitness function for EvoloPy Layer 2"""
    eval_count = [0]
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            alpha = 0.95
            beta = 0.05
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer_l2(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run any EvoloPy optimizer on Layer 2 features"""
    print(f"    Running EvoloPy {optimizer_name} (Layer 2)...")
    print(f"      Features: {n_features_l2}, Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_features_l2, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = np.random.rand(n_features_l2) < s_transfer(solution.bestIndividual)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    
    return results


def run_mutual_info_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run Mutual Information feature selection on Layer 2"""
    print("    Running Mutual Information (Layer 2)...")
    
    start_time = time.time()
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    k = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_features_l2, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run RFE feature selection on Layer 2"""
    print("    Running RFE (Layer 2)...")
    
    start_time = time.time()
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    k = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    step = max(1, min(50, n_features_l2 // 10))
    selector = RFE(estimator, n_features_to_select=k, step=step)
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    execution_time = time.time() - start_time
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run LASSO feature selection on Layer 2"""
    print("    Running LASSO (Layer 2)...")
    start_time = time.time()

    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    target_count = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_features_l2, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Layer 2 feature selection methods defined")
# Out:
# Layer 2 feature selection methods defined

# %% [markdown]
# ## Main Layer 2 Experiment Runner
#
# ### Process for each fold:
# 1. **Standard methods** (mutual_info, rfe, lasso):
#    - Take combined L1 mask → extract those features from unified data
#    - Run the *same* FS method on this subset
#    - The L2 mask is relative to the L1-selected features; map back to unified space
#
# 2. **Metaheuristics**:
#    - Take combined best-meta L1 mask → extract those features
#    - Run ALL 14 metaheuristics on this subset

# %%
def save_fold_result(fold_result, method_name, fold_idx):
    """Save a fold result to disk"""
    fold_dir = RESULTS_ROOT / method_name
    fold_dir.mkdir(exist_ok=True)
    
    fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
    fold_save_clean = {}
    for k, v in fold_save.items():
        if isinstance(v, np.ndarray):
            fold_save_clean[k] = v.tolist()
        elif isinstance(v, (np.floating, np.integer)):
            fold_save_clean[k] = float(v)
        elif isinstance(v, dict):
            fold_save_clean[k] = {}
            for kk, vv in v.items():
                if isinstance(vv, dict):
                    fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                else:
                    fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
            
        else:
            fold_save_clean[k] = v
    
    with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
        json_lib.dump(fold_save_clean, f, indent=2, default=str)
    
    np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", fold_result['feature_mask'])


def run_layer2_experiments():
    """
    Run Layer 2 feature selection on combined Layer 1 features.
    """
    print("="*80)
    print("STARTING LAYER 2 FEATURE SELECTION EXPERIMENTS")
    print("="*80)
    
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    master_results = {m: {} for m in ALL_METHODS_L2}
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data (same as original)
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        np.random.seed(42)
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize full unified features
        scaler = StandardScaler()
        X_train_norm = scaler.fit_transform(X_train)
        X_val_norm = scaler.transform(X_val)
        X_test_norm = scaler.transform(X_test)
        
        orig_dataset_size_mb = get_dataset_size_mb(X_train_norm) + get_dataset_size_mb(X_val_norm) + get_dataset_size_mb(X_test_norm)
        
        # =================================================================
        # STANDARD METHODS: mutual_info, rfe, lasso
        # =================================================================
        for std_method in STANDARD_METHODS:
            print(f"\n  --- Layer 2: {std_method.upper()} ---")
            
            # Get combined L1 mask for this method
            l1_mask = combined_masks[std_method][fold_idx]
            l1_indices = np.where(l1_mask)[0]  # indices in unified space
            n_l1_features = len(l1_indices)
            
            print(f"    L1 combined features: {n_l1_features}/{TOTAL_FEATURES}")
            
            # Extract L1-selected features
            X_train_l1 = X_train_norm[:, l1_mask]
            X_val_l1 = X_val_norm[:, l1_mask]
            X_test_l1 = X_test_norm[:, l1_mask]
            
            fs_start_time = time.time()
            
            # Run Layer 2 FS on the L1-selected features
            if std_method == 'mutual_info':
                fs_results = run_mutual_info_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            elif std_method == 'rfe':
                fs_results = run_rfe_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            elif std_method == 'lasso':
                fs_results = run_lasso_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            
            fs_time = time.time() - fs_start_time
            
            # L2 mask is relative to L1 features; map back to unified space
            l2_mask_relative = fs_results['mask']
            
            # Final unified mask
            final_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
            final_mask[l1_indices[l2_mask_relative]] = True
            
            # Apply final mask
            X_train_sel = X_train_norm[:, final_mask]
            X_val_sel = X_val_norm[:, final_mask]
            X_test_sel = X_test_norm[:, final_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes)
            modality_ret = calculate_modality_retention(final_mask, FEATURE_DIMS)
            
            fold_result = {
                'fold': fold_idx, 'method': std_method,
                'l1_method': std_method, 'l1_features': n_l1_features,
                'val_acc': eval_metrics['val_acc'], 'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'], 'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'], 'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(final_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(final_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret, 'feature_mask': final_mask,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'], 'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb, 'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': None, 'best_fitness': None,
            }
            
            master_results[std_method][fold_idx] = fold_result
            save_fold_result(fold_result, std_method, fold_idx)
            
            print(f"    L2 Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(final_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(final_mask)/TOTAL_FEATURES*100:.1f}%)")
            
            del model, train_dataset, val_dataset, test_dataset, train_loader, val_loader, test_loader
            torch.cuda.empty_cache(); gc.collect()
        
        # =================================================================
        # METAHEURISTICS: Run all 14 on combined best-meta L1 features
        # =================================================================
        l1_mask_meta = combined_masks['meta_best'][fold_idx]
        l1_indices_meta = np.where(l1_mask_meta)[0]
        n_l1_meta_features = len(l1_indices_meta)
        
        print(f"\n  --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---")
        print(f"    L1 combined best-meta features: {n_l1_meta_features}/{TOTAL_FEATURES}")
        best_info = meta_best_info[fold_idx]
        for mod in modalities:
            print(f"      {mod}: {best_info[mod][0]} (acc={best_info[mod][1]*100:.1f}%)")
        
        X_train_l1_meta = X_train_norm[:, l1_mask_meta]
        X_val_l1_meta = X_val_norm[:, l1_mask_meta]
        X_test_l1_meta = X_test_norm[:, l1_mask_meta]
        
        for opt_name, opt_func in EVOLOPY_OPTIMIZERS.items():
            method_name = f'meta_{opt_name}'
            print(f"\n  --- Layer 2: {method_name.upper()} ---")
            
            fs_start_time = time.time()
            fs_results = run_evolopy_optimizer_l2(
                opt_name, opt_func, 
                X_train_l1_meta, y_train, X_val_l1_meta, y_val, 
                num_classes, n_l1_meta_features
            )
            fs_time = time.time() - fs_start_time
            
            l2_mask_relative = fs_results['mask']
            
            final_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
            final_mask[l1_indices_meta[l2_mask_relative]] = True
            
            X_train_sel = X_train_norm[:, final_mask]
            X_val_sel = X_val_norm[:, final_mask]
            X_test_sel = X_test_norm[:, final_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes)
            modality_ret = calculate_modality_retention(final_mask, FEATURE_DIMS)
            
            fold_result = {
                'fold': fold_idx, 'method': method_name,
                'l1_method': 'meta_best', 'l1_features': n_l1_meta_features,
                'l1_best_per_modality': {mod: {'method': best_info[mod][0], 'acc': best_info[mod][1]} for mod in modalities},
                'val_acc': eval_metrics['val_acc'], 'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'], 'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'], 'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(final_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(final_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret, 'feature_mask': final_mask,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'], 'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb, 'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            save_fold_result(fold_result, method_name, fold_idx)
            
            print(f"    L2 Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(final_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(final_mask)/TOTAL_FEATURES*100:.1f}%)")
            
            del model, train_dataset, val_dataset, test_dataset, train_loader, val_loader, test_loader
            torch.cuda.empty_cache(); gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL LAYER 2 EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Layer 2 experiment runner defined")
# Out:
# Layer 2 experiment runner defined

# %% [markdown]
# ## Run Layer 2 Experiments

# %%
master_results = run_layer2_experiments()
# Out:
# ================================================================================
# STARTING LAYER 2 FEATURE SELECTION EXPERIMENTS
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- Layer 2: MUTUAL_INFO ---
#     L1 combined features: 1966/3933
#     Running Mutual Information (Layer 2)...
#       Selected: 983/1966 (50.0%), Time: 11.2s
#     L2 Test Acc: 99.07%, F1: 99.06%, Features: 983/3933 (25.0%)
#
#   --- Layer 2: RFE ---
#     L1 combined features: 1966/3933
#     Running RFE (Layer 2)...
#       Selected: 983/1966 (50.0%), Time: 1.9s
#     L2 Test Acc: 96.30%, F1: 96.05%, Features: 983/3933 (25.0%)
#
#   --- Layer 2: LASSO ---
#     L1 combined features: 1966/3933
#     Running LASSO (Layer 2)...
#       Selected: 983/1966 (50.0%), Time: 0.2s
#     L2 Test Acc: 71.30%, F1: 68.92%, Features: 983/3933 (25.0%)
#
#   --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---
#     L1 combined best-meta features: 1884/3933
#       depth: meta_SSA (acc=65.7%)
#       sensor: meta_MVO (acc=89.8%)
#       skeleton: meta_BAT (acc=91.7%)
#       video: meta_DE (acc=74.1%)
#
#   --- Layer 2: META_BAT ---
#     Running EvoloPy BAT (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023195329087048834']
# ['At iteration 1 the best fitness is 0.0231687898089172']
# ['At iteration 2 the best fitness is 0.0231687898089172']
# ['At iteration 3 the best fitness is 0.02290339702760085']
# ['At iteration 4 the best fitness is 0.022823779193205947']
# ['At iteration 5 the best fitness is 0.022823779193205947']
# ['At iteration 6 the best fitness is 0.022717622080679407']
# ['At iteration 7 the best fitness is 0.022691082802547773']
# ['At iteration 8 the best fitness is 0.022691082802547773']
# ['At iteration 9 the best fitness is 0.022691082802547773']
# ['At iteration 10 the best fitness is 0.022691082802547773']
# ['At iteration 11 the best fitness is 0.022691082802547773']
# ['At iteration 12 the best fitness is 0.022691082802547773']
# ['At iteration 13 the best fitness is 0.022691082802547773']
# ['At iteration 14 the best fitness is 0.022691082802547773']
# ['At iteration 15 the best fitness is 0.022691082802547773']
# ['At iteration 16 the best fitness is 0.022691082802547773']
# ['At iteration 17 the best fitness is 0.022691082802547773']
# ['At iteration 18 the best fitness is 0.022691082802547773']
# ['At iteration 19 the best fitness is 0.022691082802547773']
# ['At iteration 20 the best fitness is 0.022691082802547773']
# ['At iteration 21 the best fitness is 0.022691082802547773']
# ['At iteration 22 the best fitness is 0.022691082802547773']
# ['At iteration 23 the best fitness is 0.022691082802547773']
# ['At iteration 24 the best fitness is 0.022691082802547773']
# ['At iteration 25 the best fitness is 0.022691082802547773']
# ['At iteration 26 the best fitness is 0.022691082802547773']
# ['At iteration 27 the best fitness is 0.022691082802547773']
# ['At iteration 28 the best fitness is 0.022691082802547773']
# ['At iteration 29 the best fitness is 0.022691082802547773']
#       Selected: 855/1884 (45.4%), Fitness: 0.0227, Time: 353.6s
#     L2 Test Acc: 97.22%, F1: 97.08%, Features: 855/3933 (21.7%)
#
#   --- Layer 2: META_CS ---
#     Running EvoloPy CS (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023911889596602974']
# ['At iteration 10 the best fitness is 0.0231687898089172']
# ['At iteration 20 the best fitness is 0.0231687898089172']
#       Selected: 887/1884 (47.1%), Fitness: 0.0230, Time: 708.3s
#     L2 Test Acc: 98.15%, F1: 98.12%, Features: 887/3933 (22.6%)
#
#   --- Layer 2: META_DE ---
#     Running EvoloPy DE (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023487261146496817']
# ['At iteration 2 the best fitness is 0.023487261146496817']
# ['At iteration 3 the best fitness is 0.023036093418259025']
# ['At iteration 4 the best fitness is 0.022983014861995756']
# ['At iteration 5 the best fitness is 0.022983014861995756']
# ['At iteration 6 the best fitness is 0.022983014861995756']
# ['At iteration 7 the best fitness is 0.022983014861995756']
# ['At iteration 8 the best fitness is 0.022983014861995756']
# ['At iteration 9 the best fitness is 0.022797239915074312']
# ['At iteration 10 the best fitness is 0.022797239915074312']
# ['At iteration 11 the best fitness is 0.022797239915074312']
# ['At iteration 12 the best fitness is 0.022372611464968155']
# ['At iteration 13 the best fitness is 0.021921443736730363']
# ['At iteration 14 the best fitness is 0.021921443736730363']
# ['At iteration 15 the best fitness is 0.021921443736730363']
# ['At iteration 16 the best fitness is 0.021921443736730363']
# ['At iteration 17 the best fitness is 0.021921443736730363']
# ['At iteration 18 the best fitness is 0.021894904458598728']
# ['At iteration 19 the best fitness is 0.021894904458598728']
# ['At iteration 20 the best fitness is 0.021894904458598728']
# ['At iteration 21 the best fitness is 0.021709129511677284']
# ['At iteration 22 the best fitness is 0.021709129511677284']
# ['At iteration 23 the best fitness is 0.021709129511677284']
# ['At iteration 24 the best fitness is 0.021709129511677284']
# ['At iteration 25 the best fitness is 0.021443736730360936']
# ['At iteration 26 the best fitness is 0.021204883227176223']
# ['At iteration 27 the best fitness is 0.021204883227176223']
# ['At iteration 28 the best fitness is 0.020647558386411892']
# ['At iteration 29 the best fitness is 0.020647558386411892']
# ['At iteration 30 the best fitness is 0.020647558386411892']
#       Selected: 843/1884 (44.7%), Fitness: 0.0206, Time: 354.3s
#     L2 Test Acc: 98.15%, F1: 98.02%, Features: 843/3933 (21.4%)
#
#   --- Layer 2: META_FFA ---
#     Running EvoloPy FFA (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02393842887473461']
# ['At iteration 1 the best fitness is 0.023354564755838643']
# ['At iteration 2 the best fitness is 0.023354564755838643']
# ['At iteration 3 the best fitness is 0.023142250530785564']
# ['At iteration 4 the best fitness is 0.02300955414012739']
# ['At iteration 5 the best fitness is 0.02300955414012739']
# ['At iteration 6 the best fitness is 0.02300955414012739']
# ['At iteration 7 the best fitness is 0.02290339702760085']
# ['At iteration 8 the best fitness is 0.022770700636942677']
# ['At iteration 9 the best fitness is 0.022717622080679407']
# ['At iteration 10 the best fitness is 0.022717622080679407']
# ['At iteration 11 the best fitness is 0.022664543524416138']
# ['At iteration 12 the best fitness is 0.022664543524416138']
# ['At iteration 13 the best fitness is 0.022664543524416138']
# ['At iteration 14 the best fitness is 0.022531847133757964']
# ['At iteration 15 the best fitness is 0.02250530785562633']
# ['At iteration 16 the best fitness is 0.02250530785562633']
# ['At iteration 17 the best fitness is 0.02250530785562633']
# ['At iteration 18 the best fitness is 0.02250530785562633']
# ['At iteration 19 the best fitness is 0.02250530785562633']
# ['At iteration 20 the best fitness is 0.02245222929936306']
# ['At iteration 21 the best fitness is 0.02245222929936306']
# ['At iteration 22 the best fitness is 0.02245222929936306']
# ['At iteration 23 the best fitness is 0.02245222929936306']
# ['At iteration 24 the best fitness is 0.02245222929936306']
# ['At iteration 25 the best fitness is 0.02245222929936306']
# ['At iteration 26 the best fitness is 0.02245222929936306']
# ['At iteration 27 the best fitness is 0.02245222929936306']
# ['At iteration 28 the best fitness is 0.02245222929936306']
# ['At iteration 29 the best fitness is 0.02245222929936306']
#       Selected: 897/1884 (47.6%), Fitness: 0.0225, Time: 339.1s
#     L2 Test Acc: 97.22%, F1: 97.18%, Features: 897/3933 (22.8%)
#
#   --- Layer 2: META_GA ---
#     Running EvoloPy GA (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024230360934182592
# At iteration 2 the best fitness is 0.023964968152866244
# At iteration 3 the best fitness is 0.023593418259023356
# At iteration 4 the best fitness is 0.023513800424628452
# At iteration 5 the best fitness is 0.023513800424628452
# At iteration 6 the best fitness is 0.023513800424628452
# At iteration 7 the best fitness is 0.023354564755838643
# At iteration 8 the best fitness is 0.023248407643312104
# At iteration 9 the best fitness is 0.023248407643312104
# At iteration 10 the best fitness is 0.02290339702760085
# At iteration 11 the best fitness is 0.02290339702760085
# At iteration 12 the best fitness is 0.022797239915074312
# At iteration 13 the best fitness is 0.022797239915074312
# At iteration 14 the best fitness is 0.022797239915074312
# At iteration 15 the best fitness is 0.022797239915074312
# At iteration 16 the best fitness is 0.022744161358811042
# At iteration 17 the best fitness is 0.022638004246284503
# At iteration 18 the best fitness is 0.022638004246284503
# At iteration 19 the best fitness is 0.022638004246284503
# At iteration 20 the best fitness is 0.022638004246284503
# At iteration 21 the best fitness is 0.022638004246284503
# At iteration 22 the best fitness is 0.022638004246284503
# At iteration 23 the best fitness is 0.022372611464968155
# At iteration 24 the best fitness is 0.022372611464968155
# At iteration 25 the best fitness is 0.022372611464968155
# At iteration 26 the best fitness is 0.022372611464968155
# At iteration 27 the best fitness is 0.022372611464968155
# At iteration 28 the best fitness is 0.022372611464968155
# At iteration 29 the best fitness is 0.02229299363057325
# At iteration 30 the best fitness is 0.02229299363057325
#       Selected: 860/1884 (45.6%), Fitness: 0.0223, Time: 337.7s
#     L2 Test Acc: 98.15%, F1: 98.15%, Features: 860/3933 (21.9%)
#
#   --- Layer 2: META_GWO ---
#     Running EvoloPy GWO (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024018046709129513']
# ['At iteration 1 the best fitness is 0.022797239915074312']
# ['At iteration 2 the best fitness is 0.02162951167728238']
# ['At iteration 3 the best fitness is 0.019904458598726117']
# ['At iteration 4 the best fitness is 0.01926751592356688']
# ['At iteration 5 the best fitness is 0.01839171974522293']
# ['At iteration 6 the best fitness is 0.01772823779193206']
# ['At iteration 7 the best fitness is 0.016533970276008492']
# ['At iteration 8 the best fitness is 0.01602972399150743']
# ['At iteration 9 the best fitness is 0.015737791932059448']
# ['At iteration 10 the best fitness is 0.014888535031847134']
# ['At iteration 11 the best fitness is 0.014357749469214438']
# ['At iteration 12 the best fitness is 0.013614649681528663']
# ['At iteration 13 the best fitness is 0.01321656050955414']
# ['At iteration 14 the best fitness is 0.0125']
# ['At iteration 15 the best fitness is 0.012314225053078557']
# ['At iteration 16 the best fitness is 0.011756900212314226']
# ['At iteration 17 the best fitness is 0.011703821656050956']
# ['At iteration 18 the best fitness is 0.011650743099787687']
# ['At iteration 19 the best fitness is 0.011332271762208069']
# ['At iteration 20 the best fitness is 0.011040339702760086']
# ['At iteration 21 the best fitness is 0.010881104033970277']
# ['At iteration 22 the best fitness is 0.010854564755838642']
# ['At iteration 23 the best fitness is 0.010801486199575373']
# ['At iteration 24 the best fitness is 0.010668789808917199']
# ['At iteration 25 the best fitness is 0.010642250530785564']
# ['At iteration 26 the best fitness is 0.010615711252653929']
# ['At iteration 27 the best fitness is 0.010589171974522294']
# ['At iteration 28 the best fitness is 0.010429936305732485']
# ['At iteration 29 the best fitness is 0.010429936305732485']
#       Selected: 514/1884 (27.3%), Fitness: 0.0104, Time: 326.3s
#     L2 Test Acc: 99.07%, F1: 99.06%, Features: 514/3933 (13.1%)
#
#   --- Layer 2: META_HHO ---
#     Running EvoloPy HHO (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.0243895966029724']
# ['At iteration 1 the best fitness is 0.00979299363057325']
# ['At iteration 2 the best fitness is 0.00973991507430998']
# ['At iteration 3 the best fitness is 0.00870488322717622']
# ['At iteration 4 the best fitness is 0.00870488322717622']
# ['At iteration 5 the best fitness is 0.008174097664543524']
# ['At iteration 6 the best fitness is 0.00809447983014862']
# ['At iteration 7 the best fitness is 0.007165605095541401']
# ['At iteration 8 the best fitness is 0.006369426751592357']
# ['At iteration 9 the best fitness is 0.006369426751592357']
# ['At iteration 10 the best fitness is 0.006369426751592357']
# ['At iteration 11 the best fitness is 0.006369426751592357']
# ['At iteration 12 the best fitness is 0.006104033970276009']
# ['At iteration 13 the best fitness is 0.006104033970276009']
# ['At iteration 14 the best fitness is 0.006104033970276009']
# ['At iteration 15 the best fitness is 0.006104033970276009']
# ['At iteration 16 the best fitness is 0.006104033970276009']
# ['At iteration 17 the best fitness is 0.006104033970276009']
# ['At iteration 18 the best fitness is 0.006104033970276009']
# ['At iteration 19 the best fitness is 0.006104033970276009']
# ['At iteration 20 the best fitness is 0.006024416135881104']
# ['At iteration 21 the best fitness is 0.006024416135881104']
# ['At iteration 22 the best fitness is 0.006024416135881104']
# ['At iteration 23 the best fitness is 0.006024416135881104']
# ['At iteration 24 the best fitness is 0.006024416135881104']
# ['At iteration 25 the best fitness is 0.006024416135881104']
# ['At iteration 26 the best fitness is 0.006024416135881104']
# ['At iteration 27 the best fitness is 0.006024416135881104']
# ['At iteration 28 the best fitness is 0.006024416135881104']
# ['At iteration 29 the best fitness is 0.006024416135881104']
#       Selected: 164/1884 (8.7%), Fitness: 0.0060, Time: 369.6s
#     L2 Test Acc: 83.33%, F1: 81.62%, Features: 164/3933 (4.2%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023752653927813165']
# ['At iteration 1 the best fitness is 0.023752653927813165']
# ['At iteration 2 the best fitness is 0.02361995753715499']
# ['At iteration 3 the best fitness is 0.023460721868365182']
# ['At iteration 4 the best fitness is 0.023381104033970278']
# ['At iteration 5 the best fitness is 0.023301486199575373']
# ['At iteration 6 the best fitness is 0.023301486199575373']
# ['At iteration 7 the best fitness is 0.023301486199575373']
# ['At iteration 8 the best fitness is 0.023301486199575373']
# ['At iteration 9 the best fitness is 0.023301486199575373']
# ['At iteration 10 the best fitness is 0.023036093418259025']
# ['At iteration 11 the best fitness is 0.02295647558386412']
# ['At iteration 12 the best fitness is 0.02290339702760085']
# ['At iteration 13 the best fitness is 0.022823779193205947']
# ['At iteration 14 the best fitness is 0.022823779193205947']
# ['At iteration 15 the best fitness is 0.022664543524416138']
# ['At iteration 16 the best fitness is 0.022664543524416138']
# ['At iteration 17 the best fitness is 0.022664543524416138']
# ['At iteration 18 the best fitness is 0.022664543524416138']
# ['At iteration 19 the best fitness is 0.02245222929936306']
# ['At iteration 20 the best fitness is 0.022213375796178346']
# ['At iteration 21 the best fitness is 0.022213375796178346']
# ['At iteration 22 the best fitness is 0.022213375796178346']
# ['At iteration 23 the best fitness is 0.022213375796178346']
# ['At iteration 24 the best fitness is 0.022213375796178346']
# ['At iteration 25 the best fitness is 0.022213375796178346']
# ['At iteration 26 the best fitness is 0.022213375796178346']
# ['At iteration 27 the best fitness is 0.022213375796178346']
# ['At iteration 28 the best fitness is 0.022213375796178346']
# ['At iteration 29 the best fitness is 0.022213375796178346']
#       Selected: 858/1884 (45.5%), Fitness: 0.0222, Time: 363.6s
#     L2 Test Acc: 96.30%, F1: 96.14%, Features: 858/3933 (21.8%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024044585987261148']
# ['At iteration 2 the best fitness is 0.024044585987261148']
# ['At iteration 3 the best fitness is 0.023911889596602974']
# ['At iteration 4 the best fitness is 0.023911889596602974']
# ['At iteration 5 the best fitness is 0.023911889596602974']
# ['At iteration 6 the best fitness is 0.023911889596602974']
# ['At iteration 7 the best fitness is 0.023911889596602974']
# ['At iteration 8 the best fitness is 0.023646496815286626']
# ['At iteration 9 the best fitness is 0.023646496815286626']
# ['At iteration 10 the best fitness is 0.023646496815286626']
# ['At iteration 11 the best fitness is 0.023646496815286626']
# ['At iteration 12 the best fitness is 0.023646496815286626']
# ['At iteration 13 the best fitness is 0.02361995753715499']
# ['At iteration 14 the best fitness is 0.02356687898089172']
# ['At iteration 15 the best fitness is 0.02356687898089172']
# ['At iteration 16 the best fitness is 0.023354564755838643']
# ['At iteration 17 the best fitness is 0.023354564755838643']
# ['At iteration 18 the best fitness is 0.023354564755838643']
# ['At iteration 19 the best fitness is 0.023354564755838643']
# ['At iteration 20 the best fitness is 0.023248407643312104']
# ['At iteration 21 the best fitness is 0.023195329087048834']
# ['At iteration 22 the best fitness is 0.023195329087048834']
# ['At iteration 23 the best fitness is 0.023195329087048834']
# ['At iteration 24 the best fitness is 0.02306263269639066']
# ['At iteration 25 the best fitness is 0.023036093418259025']
# ['At iteration 26 the best fitness is 0.022929936305732486']
# ['At iteration 27 the best fitness is 0.02290339702760085']
# ['At iteration 28 the best fitness is 0.022876857749469216']
# ['At iteration 29 the best fitness is 0.022638004246284503']
#       Selected: 860/1884 (45.6%), Fitness: 0.0226, Time: 332.9s
#     L2 Test Acc: 94.44%, F1: 93.98%, Features: 860/3933 (21.9%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024230360934182592']
# ['At iteration 2 the best fitness is 0.02388535031847134']
# ['At iteration 3 the best fitness is 0.02356687898089172']
# ['At iteration 4 the best fitness is 0.023460721868365182']
# ['At iteration 5 the best fitness is 0.023354564755838643']
# ['At iteration 6 the best fitness is 0.023301486199575373']
# ['At iteration 7 the best fitness is 0.022929936305732486']
# ['At iteration 8 the best fitness is 0.022929936305732486']
# ['At iteration 9 the best fitness is 0.022929936305732486']
# ['At iteration 10 the best fitness is 0.022797239915074312']
# ['At iteration 11 the best fitness is 0.022797239915074312']
# ['At iteration 12 the best fitness is 0.022797239915074312']
# ['At iteration 13 the best fitness is 0.022797239915074312']
# ['At iteration 14 the best fitness is 0.022531847133757964']
# ['At iteration 15 the best fitness is 0.022531847133757964']
# ['At iteration 16 the best fitness is 0.022531847133757964']
# ['At iteration 17 the best fitness is 0.022531847133757964']
# ['At iteration 18 the best fitness is 0.022531847133757964']
# ['At iteration 19 the best fitness is 0.02229299363057325']
# ['At iteration 20 the best fitness is 0.02229299363057325']
# ['At iteration 21 the best fitness is 0.02229299363057325']
# ['At iteration 22 the best fitness is 0.02229299363057325']
# ['At iteration 23 the best fitness is 0.022266454352441616']
# ['At iteration 24 the best fitness is 0.02223991507430998']
# ['At iteration 25 the best fitness is 0.022160297239915076']
# ['At iteration 26 the best fitness is 0.022160297239915076']
# ['At iteration 27 the best fitness is 0.022160297239915076']
# ['At iteration 28 the best fitness is 0.022160297239915076']
# ['At iteration 29 the best fitness is 0.02213375796178344']
# ['At iteration 30 the best fitness is 0.022080679405520172']
#       Selected: 876/1884 (46.5%), Fitness: 0.0221, Time: 357.5s
#     L2 Test Acc: 99.07%, F1: 99.06%, Features: 876/3933 (22.3%)
#
#   --- Layer 2: META_PSO ---
#     Running EvoloPy PSO (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024071125265392783']
# ['At iteration 2 the best fitness is 0.02367303609341826']
# ['At iteration 3 the best fitness is 0.023407643312101913']
# ['At iteration 4 the best fitness is 0.023089171974522295']
# ['At iteration 5 the best fitness is 0.02290339702760085']
# ['At iteration 6 the best fitness is 0.022584925690021233']
# ['At iteration 7 the best fitness is 0.022584925690021233']
# ['At iteration 8 the best fitness is 0.022584925690021233']
# ['At iteration 9 the best fitness is 0.022584925690021233']
# ['At iteration 10 the best fitness is 0.022584925690021233']
# ['At iteration 11 the best fitness is 0.022584925690021233']
# ['At iteration 12 the best fitness is 0.022584925690021233']
# ['At iteration 13 the best fitness is 0.022584925690021233']
# ['At iteration 14 the best fitness is 0.022584925690021233']
# ['At iteration 15 the best fitness is 0.022584925690021233']
# ['At iteration 16 the best fitness is 0.022584925690021233']
# ['At iteration 17 the best fitness is 0.022478768577494694']
# ['At iteration 18 the best fitness is 0.022372611464968155']
# ['At iteration 19 the best fitness is 0.022372611464968155']
# ['At iteration 20 the best fitness is 0.022319532908704885']
# ['At iteration 21 the best fitness is 0.02213375796178344']
# ['At iteration 22 the best fitness is 0.022001061571125267']
# ['At iteration 23 the best fitness is 0.022001061571125267']
# ['At iteration 24 the best fitness is 0.021921443736730363']
# ['At iteration 25 the best fitness is 0.021868365180467093']
# ['At iteration 26 the best fitness is 0.021709129511677284']
# ['At iteration 27 the best fitness is 0.02152335456475584']
# ['At iteration 28 the best fitness is 0.021390658174097667']
# ['At iteration 29 the best fitness is 0.021390658174097667']
# ['At iteration 30 the best fitness is 0.021390658174097667']
#       Selected: 817/1884 (43.4%), Fitness: 0.0214, Time: 358.3s
#     L2 Test Acc: 96.30%, F1: 95.06%, Features: 817/3933 (20.8%)
#
#   --- Layer 2: META_SCA ---
#     Running EvoloPy SCA (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02372611464968153']
# ['At iteration 1 the best fitness is 0.01942675159235669']
# ['At iteration 2 the best fitness is 0.01735668789808917']
# ['At iteration 3 the best fitness is 0.013880042462845011']
# ['At iteration 4 the best fitness is 0.011650743099787687']
# ['At iteration 5 the best fitness is 0.010031847133757963']
# ['At iteration 6 the best fitness is 0.008067940552016985']
# ['At iteration 7 the best fitness is 0.008067940552016985']
# ['At iteration 8 the best fitness is 0.008067940552016985']
# ['At iteration 9 the best fitness is 0.008067940552016985']
# ['At iteration 10 the best fitness is 0.007882165605095541']
# ['At iteration 11 the best fitness is 0.006847133757961784']
# ['At iteration 12 the best fitness is 0.006847133757961784']
# ['At iteration 13 the best fitness is 0.0064490445859872614']
# ['At iteration 14 the best fitness is 0.005812101910828026']
# ['At iteration 15 the best fitness is 0.005254777070063695']
# ['At iteration 16 the best fitness is 0.005254777070063695']
# ['At iteration 17 the best fitness is 0.005254777070063695']
# ['At iteration 18 the best fitness is 0.005254777070063695']
# ['At iteration 19 the best fitness is 0.005254777070063695']
# ['At iteration 20 the best fitness is 0.005122080679405521']
# ['At iteration 21 the best fitness is 0.00440552016985138']
# ['At iteration 22 the best fitness is 0.00440552016985138']
# ['At iteration 23 the best fitness is 0.004060509554140127']
# ['At iteration 24 the best fitness is 0.004060509554140127']
# ['At iteration 25 the best fitness is 0.004060509554140127']
# ['At iteration 26 the best fitness is 0.004060509554140127']
# ['At iteration 27 the best fitness is 0.004060509554140127']
# ['At iteration 28 the best fitness is 0.004060509554140127']
# ['At iteration 29 the best fitness is 0.004060509554140127']
#       Selected: 180/1884 (9.6%), Fitness: 0.0041, Time: 325.7s
#     L2 Test Acc: 92.59%, F1: 92.37%, Features: 180/3933 (4.6%)
#
#   --- Layer 2: META_SSA ---
#     Running EvoloPy SSA (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023911889596602974']
# ['At iteration 2 the best fitness is 0.023248407643312104']
# ['At iteration 3 the best fitness is 0.023248407643312104']
# ['At iteration 4 the best fitness is 0.023248407643312104']
# ['At iteration 5 the best fitness is 0.023248407643312104']
# ['At iteration 6 the best fitness is 0.023248407643312104']
# ['At iteration 7 the best fitness is 0.023195329087048834']
# ['At iteration 8 the best fitness is 0.022770700636942677']
# ['At iteration 9 the best fitness is 0.022770700636942677']
# ['At iteration 10 the best fitness is 0.022770700636942677']
# ['At iteration 11 the best fitness is 0.022478768577494694']
# ['At iteration 12 the best fitness is 0.022372611464968155']
# ['At iteration 13 the best fitness is 0.022001061571125267']
# ['At iteration 14 the best fitness is 0.022001061571125267']
# ['At iteration 15 the best fitness is 0.021974522292993633']
# ['At iteration 16 the best fitness is 0.021921443736730363']
# ['At iteration 17 the best fitness is 0.021868365180467093']
# ['At iteration 18 the best fitness is 0.02184182590233546']
# ['At iteration 19 the best fitness is 0.021815286624203824']
# ['At iteration 20 the best fitness is 0.021762208067940554']
# ['At iteration 21 the best fitness is 0.021762208067940554']
# ['At iteration 22 the best fitness is 0.021762208067940554']
# ['At iteration 23 the best fitness is 0.021762208067940554']
# ['At iteration 24 the best fitness is 0.021762208067940554']
# ['At iteration 25 the best fitness is 0.021762208067940554']
# ['At iteration 26 the best fitness is 0.021762208067940554']
# ['At iteration 27 the best fitness is 0.021762208067940554']
# ['At iteration 28 the best fitness is 0.021762208067940554']
# ['At iteration 29 the best fitness is 0.021762208067940554']
#       Selected: 882/1884 (46.8%), Fitness: 0.0218, Time: 883.7s
#     L2 Test Acc: 97.22%, F1: 96.63%, Features: 882/3933 (22.4%)
#
#   --- Layer 2: META_WOA ---
#     Running EvoloPy WOA (Layer 2)...
#       Features: 1884, Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024018046709129513']
# ['At iteration 1 the best fitness is 0.016533970276008492']
# ['At iteration 2 the best fitness is 0.014109341825902375']
# ['At iteration 3 the best fitness is 0.012685774946921444']
# ['At iteration 4 the best fitness is 0.011720806794055242']
# ['At iteration 5 the best fitness is 0.011720806794055242']
# ['At iteration 6 the best fitness is 0.011720806794055242']
# ['At iteration 7 the best fitness is 0.011720806794055242']
# ['At iteration 8 the best fitness is 0.011720806794055242']
# ['At iteration 9 the best fitness is 0.011720806794055242']
# ['At iteration 10 the best fitness is 0.011694267515923607']
# ['At iteration 11 the best fitness is 0.007537154989384289']
# ['At iteration 12 the best fitness is 0.007537154989384289']
# ['At iteration 13 the best fitness is 0.005520169851380043']
# ['At iteration 14 the best fitness is 0.005520169851380043']
# ['At iteration 15 the best fitness is 0.005360934182590234']
# ['At iteration 16 the best fitness is 0.005360934182590234']
# ['At iteration 17 the best fitness is 0.005360934182590234']
# ['At iteration 18 the best fitness is 0.005122080679405521']
# ['At iteration 19 the best fitness is 0.005122080679405521']
# ['At iteration 20 the best fitness is 0.005122080679405521']
# ['At iteration 21 the best fitness is 0.005122080679405521']
# ['At iteration 22 the best fitness is 0.005122080679405521']
# ['At iteration 23 the best fitness is 0.005122080679405521']
# ['At iteration 24 the best fitness is 0.005122080679405521']
# ['At iteration 25 the best fitness is 0.005122080679405521']
# ['At iteration 26 the best fitness is 0.005122080679405521']
# ['At iteration 27 the best fitness is 0.005122080679405521']
# ['At iteration 28 the best fitness is 0.005122080679405521']
# ['At iteration 29 the best fitness is 0.005122080679405521']
#       Selected: 236/1884 (12.5%), Fitness: 0.0051, Time: 311.8s
#     L2 Test Acc: 92.59%, F1: 92.00%, Features: 236/3933 (6.0%)
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- Layer 2: MUTUAL_INFO ---
#     L1 combined features: 1966/3933
#     Running Mutual Information (Layer 2)...
#       Selected: 983/1966 (50.0%), Time: 11.3s
#     L2 Test Acc: 90.74%, F1: 89.10%, Features: 983/3933 (25.0%)
#
#   --- Layer 2: RFE ---
#     L1 combined features: 1966/3933
#     Running RFE (Layer 2)...
#       Selected: 983/1966 (50.0%), Time: 1.9s
#     L2 Test Acc: 94.44%, F1: 93.99%, Features: 983/3933 (25.0%)
#
#   --- Layer 2: LASSO ---
#     L1 combined features: 1966/3933
#     Running LASSO (Layer 2)...
#       Selected: 983/1966 (50.0%), Time: 0.4s
#     L2 Test Acc: 71.30%, F1: 67.46%, Features: 983/3933 (25.0%)
#
#   --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---
#     L1 combined best-meta features: 1744/3933
#       depth: meta_DE (acc=55.6%)
#       sensor: meta_BAT (acc=87.0%)
#       skeleton: meta_GA (acc=81.5%)
#       video: meta_SCA (acc=75.9%)
#
#   --- Layer 2: META_BAT ---
#     Running EvoloPy BAT (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023881880733944955']
# ['At iteration 1 the best fitness is 0.023881880733944955']
# ['At iteration 2 the best fitness is 0.023853211009174313']
# ['At iteration 3 the best fitness is 0.02379587155963303']
# ['At iteration 4 the best fitness is 0.023709862385321103']
# ['At iteration 5 the best fitness is 0.023709862385321103']
# ['At iteration 6 the best fitness is 0.023709862385321103']
# ['At iteration 7 the best fitness is 0.023709862385321103']
# ['At iteration 8 the best fitness is 0.023709862385321103']
# ['At iteration 9 the best fitness is 0.023681192660550462']
# ['At iteration 10 the best fitness is 0.023681192660550462']
# ['At iteration 11 the best fitness is 0.023623853211009176']
# ['At iteration 12 the best fitness is 0.023623853211009176']
# ['At iteration 13 the best fitness is 0.023623853211009176']
# ['At iteration 14 the best fitness is 0.023623853211009176']
# ['At iteration 15 the best fitness is 0.023623853211009176']
# ['At iteration 16 the best fitness is 0.023623853211009176']
# ['At iteration 17 the best fitness is 0.023623853211009176']
# ['At iteration 18 the best fitness is 0.023623853211009176']
# ['At iteration 19 the best fitness is 0.023623853211009176']
# ['At iteration 20 the best fitness is 0.023623853211009176']
# ['At iteration 21 the best fitness is 0.023623853211009176']
# ['At iteration 22 the best fitness is 0.023623853211009176']
# ['At iteration 23 the best fitness is 0.023623853211009176']
# ['At iteration 24 the best fitness is 0.023623853211009176']
# ['At iteration 25 the best fitness is 0.023623853211009176']
# ['At iteration 26 the best fitness is 0.023623853211009176']
# ['At iteration 27 the best fitness is 0.023623853211009176']
# ['At iteration 28 the best fitness is 0.023623853211009176']
# ['At iteration 29 the best fitness is 0.023623853211009176']
#       Selected: 824/1744 (47.2%), Fitness: 0.0236, Time: 359.5s
#     L2 Test Acc: 88.89%, F1: 87.56%, Features: 824/3933 (21.0%)
#
#   --- Layer 2: META_CS ---
#     Running EvoloPy CS (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024025229357798165']
# ['At iteration 10 the best fitness is 0.023308486238532114']
# ['At iteration 20 the best fitness is 0.02290711009174312']
#       Selected: 818/1744 (46.9%), Fitness: 0.0228, Time: 707.3s
#     L2 Test Acc: 92.59%, F1: 91.21%, Features: 818/3933 (20.8%)
#
#   --- Layer 2: META_DE ---
#     Running EvoloPy DE (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023881880733944955']
# ['At iteration 2 the best fitness is 0.023853211009174313']
# ['At iteration 3 the best fitness is 0.023853211009174313']
# ['At iteration 4 the best fitness is 0.023623853211009176']
# ['At iteration 5 the best fitness is 0.023623853211009176']
# ['At iteration 6 the best fitness is 0.023623853211009176']
# ['At iteration 7 the best fitness is 0.023308486238532114']
# ['At iteration 8 the best fitness is 0.023308486238532114']
# ['At iteration 9 the best fitness is 0.023079128440366973']
# ['At iteration 10 the best fitness is 0.023079128440366973']
# ['At iteration 11 the best fitness is 0.02305045871559633']
# ['At iteration 12 the best fitness is 0.02305045871559633']
# ['At iteration 13 the best fitness is 0.022792431192660553']
# ['At iteration 14 the best fitness is 0.022792431192660553']
# ['At iteration 15 the best fitness is 0.022792431192660553']
# ['At iteration 16 the best fitness is 0.022792431192660553']
# ['At iteration 17 the best fitness is 0.02276376146788991']
# ['At iteration 18 the best fitness is 0.02236238532110092']
# ['At iteration 19 the best fitness is 0.022305045871559636']
# ['At iteration 20 the best fitness is 0.022305045871559636']
# ['At iteration 21 the best fitness is 0.02213302752293578']
# ['At iteration 22 the best fitness is 0.02213302752293578']
# ['At iteration 23 the best fitness is 0.02161697247706422']
# ['At iteration 24 the best fitness is 0.02161697247706422']
# ['At iteration 25 the best fitness is 0.021473623853211013']
# ['At iteration 26 the best fitness is 0.021473623853211013']
# ['At iteration 27 the best fitness is 0.021473623853211013']
# ['At iteration 28 the best fitness is 0.021473623853211013']
# ['At iteration 29 the best fitness is 0.021272935779816513']
# ['At iteration 30 the best fitness is 0.021272935779816513']
#       Selected: 770/1744 (44.2%), Fitness: 0.0213, Time: 350.0s
#     L2 Test Acc: 88.89%, F1: 86.35%, Features: 770/3933 (19.6%)
#
#   --- Layer 2: META_FFA ---
#     Running EvoloPy FFA (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023480504587155962']
# ['At iteration 1 the best fitness is 0.023480504587155962']
# ['At iteration 2 the best fitness is 0.023337155963302755']
# ['At iteration 3 the best fitness is 0.023337155963302755']
# ['At iteration 4 the best fitness is 0.023251146788990828']
# ['At iteration 5 the best fitness is 0.022821100917431194']
# ['At iteration 6 the best fitness is 0.02250573394495413']
# ['At iteration 7 the best fitness is 0.022391055045871563']
# ['At iteration 8 the best fitness is 0.022391055045871563']
# ['At iteration 9 the best fitness is 0.022391055045871563']
# ['At iteration 10 the best fitness is 0.022391055045871563']
# ['At iteration 11 the best fitness is 0.022391055045871563']
# ['At iteration 12 the best fitness is 0.022190366972477064']
# ['At iteration 13 the best fitness is 0.02213302752293578']
# ['At iteration 14 the best fitness is 0.02213302752293578']
# ['At iteration 15 the best fitness is 0.02213302752293578']
# ['At iteration 16 the best fitness is 0.02213302752293578']
# ['At iteration 17 the best fitness is 0.02213302752293578']
# ['At iteration 18 the best fitness is 0.022104357798165136']
# ['At iteration 19 the best fitness is 0.022075688073394495']
# ['At iteration 20 the best fitness is 0.022075688073394495']
# ['At iteration 21 the best fitness is 0.022075688073394495']
# ['At iteration 22 the best fitness is 0.022075688073394495']
# ['At iteration 23 the best fitness is 0.022075688073394495']
# ['At iteration 24 the best fitness is 0.022075688073394495']
# ['At iteration 25 the best fitness is 0.022075688073394495']
# ['At iteration 26 the best fitness is 0.022075688073394495']
# ['At iteration 27 the best fitness is 0.022075688073394495']
# ['At iteration 28 the best fitness is 0.022075688073394495']
# ['At iteration 29 the best fitness is 0.022075688073394495']
#       Selected: 820/1744 (47.0%), Fitness: 0.0221, Time: 338.0s
#     L2 Test Acc: 95.37%, F1: 94.86%, Features: 820/3933 (20.8%)
#
#   --- Layer 2: META_GA ---
#     Running EvoloPy GA (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024655963302752295
# At iteration 2 the best fitness is 0.0244552752293578
# At iteration 3 the best fitness is 0.024426605504587157
# At iteration 4 the best fitness is 0.02408256880733945
# At iteration 5 the best fitness is 0.02408256880733945
# At iteration 6 the best fitness is 0.02379587155963303
# At iteration 7 the best fitness is 0.02379587155963303
# At iteration 8 the best fitness is 0.02379587155963303
# At iteration 9 the best fitness is 0.02379587155963303
# At iteration 10 the best fitness is 0.02379587155963303
# At iteration 11 the best fitness is 0.02379587155963303
# At iteration 12 the best fitness is 0.02379587155963303
# At iteration 13 the best fitness is 0.02379587155963303
# At iteration 14 the best fitness is 0.023738532110091744
# At iteration 15 the best fitness is 0.023738532110091744
# At iteration 16 the best fitness is 0.023537844036697248
# At iteration 17 the best fitness is 0.023537844036697248
# At iteration 18 the best fitness is 0.023537844036697248
# At iteration 19 the best fitness is 0.023537844036697248
# At iteration 20 the best fitness is 0.023537844036697248
# At iteration 21 the best fitness is 0.023509174311926607
# At iteration 22 the best fitness is 0.023509174311926607
# At iteration 23 the best fitness is 0.023509174311926607
# At iteration 24 the best fitness is 0.023537844036697248
# At iteration 25 the best fitness is 0.023480504587155962
# At iteration 26 the best fitness is 0.023222477064220187
# At iteration 27 the best fitness is 0.023079128440366973
# At iteration 28 the best fitness is 0.02319380733944954
# At iteration 29 the best fitness is 0.022964449541284404
# At iteration 30 the best fitness is 0.02287844036697248
#       Selected: 820/1744 (47.0%), Fitness: 0.0229, Time: 338.8s
#     L2 Test Acc: 89.81%, F1: 87.99%, Features: 820/3933 (20.8%)
#
#   --- Layer 2: META_GWO ---
#     Running EvoloPy GWO (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023537844036697248']
# ['At iteration 1 the best fitness is 0.022305045871559636']
# ['At iteration 2 the best fitness is 0.020728211009174314']
# ['At iteration 3 the best fitness is 0.02012614678899083']
# ['At iteration 4 the best fitness is 0.018950688073394496']
# ['At iteration 5 the best fitness is 0.01817660550458716']
# ['At iteration 6 the best fitness is 0.016800458715596333']
# ['At iteration 7 the best fitness is 0.016112385321100917']
# ['At iteration 8 the best fitness is 0.015366972477064221']
# ['At iteration 9 the best fitness is 0.014506880733944955']
# ['At iteration 10 the best fitness is 0.014076834862385321']
# ['At iteration 11 the best fitness is 0.013933486238532113']
# ['At iteration 12 the best fitness is 0.013560779816513763']
# ['At iteration 13 the best fitness is 0.013245412844036698']
# ['At iteration 14 the best fitness is 0.01315940366972477']
# ['At iteration 15 the best fitness is 0.012672018348623854']
# ['At iteration 16 the best fitness is 0.012528669724770642']
# ['At iteration 17 the best fitness is 0.012184633027522936']
# ['At iteration 18 the best fitness is 0.011926605504587157']
# ['At iteration 19 the best fitness is 0.011897935779816515']
# ['At iteration 20 the best fitness is 0.011410550458715597']
# ['At iteration 21 the best fitness is 0.011152522935779818']
# ['At iteration 22 the best fitness is 0.010980504587155965']
# ['At iteration 23 the best fitness is 0.010894495412844037']
# ['At iteration 24 the best fitness is 0.010894495412844037']
# ['At iteration 25 the best fitness is 0.010894495412844037']
# ['At iteration 26 the best fitness is 0.01080848623853211']
# ['At iteration 27 the best fitness is 0.01080848623853211']
# ['At iteration 28 the best fitness is 0.010751146788990827']
# ['At iteration 29 the best fitness is 0.010751146788990827']
#       Selected: 483/1744 (27.7%), Fitness: 0.0108, Time: 325.4s
#     L2 Test Acc: 89.81%, F1: 87.21%, Features: 483/3933 (12.3%)
#
#   --- Layer 2: META_HHO ---
#     Running EvoloPy HHO (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.024283256880733947']
# ['At iteration 1 the best fitness is 0.012038608562691172']
# ['At iteration 2 the best fitness is 0.012038608562691172']
# ['At iteration 3 the best fitness is 0.010605122324159062']
# ['At iteration 4 the best fitness is 0.010605122324159062']
# ['At iteration 5 the best fitness is 0.010605122324159062']
# ['At iteration 6 the best fitness is 0.010605122324159062']
# ['At iteration 7 the best fitness is 0.010605122324159062']
# ['At iteration 8 the best fitness is 0.010605122324159062']
# ['At iteration 9 the best fitness is 0.010605122324159062']
# ['At iteration 10 the best fitness is 0.010605122324159062']
# ['At iteration 11 the best fitness is 0.010605122324159062']
# ['At iteration 12 the best fitness is 0.010605122324159062']
# ['At iteration 13 the best fitness is 0.010605122324159062']
# ['At iteration 14 the best fitness is 0.010605122324159062']
# ['At iteration 15 the best fitness is 0.010605122324159062']
# ['At iteration 16 the best fitness is 0.010605122324159062']
# ['At iteration 17 the best fitness is 0.010605122324159062']
# ['At iteration 18 the best fitness is 0.010605122324159062']
# ['At iteration 19 the best fitness is 0.010605122324159062']
# ['At iteration 20 the best fitness is 0.010605122324159062']
# ['At iteration 21 the best fitness is 0.010605122324159062']
# ['At iteration 22 the best fitness is 0.010605122324159062']
# ['At iteration 23 the best fitness is 0.010605122324159062']
# ['At iteration 24 the best fitness is 0.010605122324159062']
# ['At iteration 25 the best fitness is 0.010605122324159062']
# ['At iteration 26 the best fitness is 0.010605122324159062']
# ['At iteration 27 the best fitness is 0.010605122324159062']
# ['At iteration 28 the best fitness is 0.010605122324159062']
# ['At iteration 29 the best fitness is 0.010605122324159062']
#       Selected: 220/1744 (12.6%), Fitness: 0.0106, Time: 382.2s
#     L2 Test Acc: 81.48%, F1: 79.94%, Features: 220/3933 (5.6%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023738532110091744']
# ['At iteration 1 the best fitness is 0.023681192660550462']
# ['At iteration 2 the best fitness is 0.023681192660550462']
# ['At iteration 3 the best fitness is 0.023681192660550462']
# ['At iteration 4 the best fitness is 0.023480504587155962']
# ['At iteration 5 the best fitness is 0.023480504587155962']
# ['At iteration 6 the best fitness is 0.023394495412844038']
# ['At iteration 7 the best fitness is 0.023394495412844038']
# ['At iteration 8 the best fitness is 0.023251146788990828']
# ['At iteration 9 the best fitness is 0.023079128440366973']
# ['At iteration 10 the best fitness is 0.023079128440366973']
# ['At iteration 11 the best fitness is 0.023079128440366973']
# ['At iteration 12 the best fitness is 0.023079128440366973']
# ['At iteration 13 the best fitness is 0.023079128440366973']
# ['At iteration 14 the best fitness is 0.023079128440366973']
# ['At iteration 15 the best fitness is 0.023079128440366973']
# ['At iteration 16 the best fitness is 0.023079128440366973']
# ['At iteration 17 the best fitness is 0.023079128440366973']
# ['At iteration 18 the best fitness is 0.022935779816513763']
# ['At iteration 19 the best fitness is 0.022935779816513763']
# ['At iteration 20 the best fitness is 0.022935779816513763']
# ['At iteration 21 the best fitness is 0.02287844036697248']
# ['At iteration 22 the best fitness is 0.02287844036697248']
# ['At iteration 23 the best fitness is 0.02287844036697248']
# ['At iteration 24 the best fitness is 0.02287844036697248']
# ['At iteration 25 the best fitness is 0.02287844036697248']
# ['At iteration 26 the best fitness is 0.02287844036697248']
# ['At iteration 27 the best fitness is 0.022477064220183487']
# ['At iteration 28 the best fitness is 0.022419724770642205']
# ['At iteration 29 the best fitness is 0.022419724770642205']
#       Selected: 813/1744 (46.6%), Fitness: 0.0224, Time: 344.0s
#     L2 Test Acc: 93.52%, F1: 92.32%, Features: 813/3933 (20.7%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02434059633027523']
# ['At iteration 2 the best fitness is 0.024225917431192664']
# ['At iteration 3 the best fitness is 0.023365825688073397']
# ['At iteration 4 the best fitness is 0.023365825688073397']
# ['At iteration 5 the best fitness is 0.023365825688073397']
# ['At iteration 6 the best fitness is 0.023365825688073397']
# ['At iteration 7 the best fitness is 0.023365825688073397']
# ['At iteration 8 the best fitness is 0.023365825688073397']
# ['At iteration 9 the best fitness is 0.023365825688073397']
# ['At iteration 10 the best fitness is 0.023365825688073397']
# ['At iteration 11 the best fitness is 0.023365825688073397']
# ['At iteration 12 the best fitness is 0.023365825688073397']
# ['At iteration 13 the best fitness is 0.02327981651376147']
# ['At iteration 14 the best fitness is 0.02327981651376147']
# ['At iteration 15 the best fitness is 0.02327981651376147']
# ['At iteration 16 the best fitness is 0.0231651376146789']
# ['At iteration 17 the best fitness is 0.0231651376146789']
# ['At iteration 18 the best fitness is 0.0231651376146789']
# ['At iteration 19 the best fitness is 0.023107798165137614']
# ['At iteration 20 the best fitness is 0.022993119266055045']
# ['At iteration 21 the best fitness is 0.022993119266055045']
# ['At iteration 22 the best fitness is 0.02287844036697248']
# ['At iteration 23 the best fitness is 0.022706422018348625']
# ['At iteration 24 the best fitness is 0.022706422018348625']
# ['At iteration 25 the best fitness is 0.022706422018348625']
# ['At iteration 26 the best fitness is 0.022706422018348625']
# ['At iteration 27 the best fitness is 0.02264908256880734']
# ['At iteration 28 the best fitness is 0.02264908256880734']
# ['At iteration 29 the best fitness is 0.02264908256880734']
#       Selected: 837/1744 (48.0%), Fitness: 0.0226, Time: 335.5s
#     L2 Test Acc: 89.81%, F1: 88.06%, Features: 837/3933 (21.3%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 1744, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024025229357798165']
# ['At iteration 2 the best fitness is 0.02319380733944954']
# ['At iteration 3 the best fitness is 0.023107798165137614']
# ['At iteration 4 the best fitness is 0.023107798165137614']
# ['At iteration 5 the best fitness is 0.022620412844036698']
# ['At iteration 6 the best fitness is 0.022591743119266056']
# ['At iteration 7 the best fitness is 0.022591743119266056']
# ['At iteration 8 the best fitness is 0.022591743119266056']
# ['At iteration 9 the best fitness is 0.02250573394495413']
# ['At iteration 10 the best fitness is 0.022305045871559636']
# ['At iteration 11 the best fitness is 0.02213302752293578']
# ['At iteration 12 the best fitness is 0.02213302752293578']
# ['At iteration 13 the best fitness is 0.022075688073394495']
# ['At iteration 14 the best fitness is 0.02198967889908257']
# ['At iteration 15 the best fitness is 0.021817660550458716']
# ['At iteration 16 the best fitness is 0.02158830275229358']
# ['At iteration 17 the best fitness is 0.02158830275229358']
# ['At iteration 18 the best fitness is 0.0213302752293578']
# ['At iteration 19 the best fitness is 0.0213302752293578']
# ['At iteration 20 the best fitness is 0.0213302752293578']
# ...
# ['At iteration 10 the best fitness is 0.014043493209558233']
# ['At iteration 11 the best fitness is 0.014043493209558233']
# ['At iteration 12 the best fitness is 0.013295685061028063']
# ['At iteration 13 the best fitness is 0.013115179645865609']
# ['At iteration 14 the best fitness is 0.012341585009455086']
# ['At iteration 15 the best fitness is 0.006085611139762765']
# ['At iteration 16 the best fitness is 0.006085611139762765']
# ['At iteration 17 the best fitness is 0.006085611139762765']
# ['At iteration 18 the best fitness is 0.006085611139762765']
# ['At iteration 19 the best fitness is 0.006085611139762765']
# ['At iteration 20 the best fitness is 0.006085611139762765']
# ['At iteration 21 the best fitness is 0.006085611139762765']
# ['At iteration 22 the best fitness is 0.006085611139762765']
# ['At iteration 23 the best fitness is 0.006085611139762765']
# ['At iteration 24 the best fitness is 0.006085611139762765']
# ['At iteration 25 the best fitness is 0.006085611139762765']
# ['At iteration 26 the best fitness is 0.006085611139762765']
# ['At iteration 27 the best fitness is 0.006085611139762765']
# ['At iteration 28 the best fitness is 0.006085611139762765']
# ['At iteration 29 the best fitness is 0.006085611139762765']
#       Selected: 296/1939 (15.3%), Fitness: 0.0061, Time: 417.2s
#     L2 Test Acc: 97.20%, F1: 96.97%, Features: 296/3933 (7.5%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 1939, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02501289324394018']
# ['At iteration 1 the best fitness is 0.02403300670448685']
# ['At iteration 2 the best fitness is 0.02403300670448685']
# ['At iteration 3 the best fitness is 0.02403300670448685']
# ['At iteration 4 the best fitness is 0.02403300670448685']
# ['At iteration 5 the best fitness is 0.02403300670448685']
# ['At iteration 6 the best fitness is 0.02403300670448685']
# ['At iteration 7 the best fitness is 0.02398143372872615']
# ['At iteration 8 the best fitness is 0.02398143372872615']
# ['At iteration 9 the best fitness is 0.02398143372872615']
# ['At iteration 10 the best fitness is 0.02398143372872615']
# ['At iteration 11 the best fitness is 0.02398143372872615']
# ['At iteration 12 the best fitness is 0.02398143372872615']
# ['At iteration 13 the best fitness is 0.02398143372872615']
# ['At iteration 14 the best fitness is 0.02354306343476019']
# ['At iteration 15 the best fitness is 0.02354306343476019']
# ['At iteration 16 the best fitness is 0.02354306343476019']
# ['At iteration 17 the best fitness is 0.02354306343476019']
# ['At iteration 18 the best fitness is 0.02354306343476019']
# ['At iteration 19 the best fitness is 0.02354306343476019']
# ['At iteration 20 the best fitness is 0.02333677153171738']
# ['At iteration 21 the best fitness is 0.02333677153171738']
# ['At iteration 22 the best fitness is 0.02333677153171738']
# ['At iteration 23 the best fitness is 0.02333677153171738']
# ['At iteration 24 the best fitness is 0.02333677153171738']
# ['At iteration 25 the best fitness is 0.023104693140794226']
# ['At iteration 26 the best fitness is 0.023104693140794226']
# ['At iteration 27 the best fitness is 0.023104693140794226']
# ['At iteration 28 the best fitness is 0.023104693140794226']
# ['At iteration 29 the best fitness is 0.023104693140794226']
#       Selected: 926/1939 (47.8%), Fitness: 0.0231, Time: 351.4s
#     L2 Test Acc: 99.07%, F1: 98.94%, Features: 926/3933 (23.5%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 1939, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.025116039195461577']
# ['At iteration 2 the best fitness is 0.02501289324394018']
# ['At iteration 3 the best fitness is 0.02501289324394018']
# ['At iteration 4 the best fitness is 0.024935533780299127']
# ['At iteration 5 the best fitness is 0.024935533780299127']
# ['At iteration 6 the best fitness is 0.02480660134089737']
# ['At iteration 7 the best fitness is 0.02480660134089737']
# ['At iteration 8 the best fitness is 0.02480660134089737']
# ['At iteration 9 the best fitness is 0.02480660134089737']
# ['At iteration 10 the best fitness is 0.02480660134089737']
# ['At iteration 11 the best fitness is 0.02480660134089737']
# ['At iteration 12 the best fitness is 0.02480660134089737']
# ['At iteration 13 the best fitness is 0.02480660134089737']
# ['At iteration 14 the best fitness is 0.02480660134089737']
# ['At iteration 15 the best fitness is 0.02480660134089737']
# ['At iteration 16 the best fitness is 0.02480660134089737']
# ['At iteration 17 the best fitness is 0.02472924187725632']
# ['At iteration 18 the best fitness is 0.02472924187725632']
# ['At iteration 19 the best fitness is 0.02431665807117071']
# ['At iteration 20 the best fitness is 0.02431665807117071']
# ['At iteration 21 the best fitness is 0.024239298607529658']
# ['At iteration 22 the best fitness is 0.024239298607529658']
# ['At iteration 23 the best fitness is 0.02408457968024755']
# ['At iteration 24 the best fitness is 0.02408457968024755']
# ['At iteration 25 the best fitness is 0.023697782362042293']
# ['At iteration 26 the best fitness is 0.023697782362042293']
# ['At iteration 27 the best fitness is 0.023594636410520887']
# ['At iteration 28 the best fitness is 0.023594636410520887']
# ['At iteration 29 the best fitness is 0.023594636410520887']
#       Selected: 934/1939 (48.2%), Fitness: 0.0236, Time: 328.2s
#     L2 Test Acc: 98.13%, F1: 98.13%, Features: 934/3933 (23.7%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 1939, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02364620938628159']
# ['At iteration 2 the best fitness is 0.02364620938628159']
# ['At iteration 3 the best fitness is 0.02364620938628159']
# ['At iteration 4 the best fitness is 0.023594636410520887']
# ['At iteration 5 the best fitness is 0.023104693140794226']
# ['At iteration 6 the best fitness is 0.023027333677153174']
# ['At iteration 7 the best fitness is 0.023027333677153174']
# ['At iteration 8 the best fitness is 0.023027333677153174']
# ['At iteration 9 the best fitness is 0.022769468798349665']
# ['At iteration 10 the best fitness is 0.022769468798349665']
# ['At iteration 11 the best fitness is 0.022692109334708613']
# ['At iteration 12 the best fitness is 0.022408457968024757']
# ['At iteration 13 the best fitness is 0.022408457968024757']
# ['At iteration 14 the best fitness is 0.02220216606498195']
# ['At iteration 15 the best fitness is 0.02220216606498195']
# ['At iteration 16 the best fitness is 0.02220216606498195']
# ['At iteration 17 the best fitness is 0.02215059308922125']
# ['At iteration 18 the best fitness is 0.02215059308922125']
# ['At iteration 19 the best fitness is 0.02215059308922125']
# ['At iteration 20 the best fitness is 0.02215059308922125']
# ['At iteration 21 the best fitness is 0.021970087674058794']
# ['At iteration 22 the best fitness is 0.021970087674058794']
# ['At iteration 23 the best fitness is 0.021970087674058794']
# ['At iteration 24 the best fitness is 0.021970087674058794']
# ['At iteration 25 the best fitness is 0.021944301186178444']
# ['At iteration 26 the best fitness is 0.021944301186178444']
# ['At iteration 27 the best fitness is 0.021892728210417742']
# ['At iteration 28 the best fitness is 0.02184115523465704']
# ['At iteration 29 the best fitness is 0.02171222279525529']
# ['At iteration 30 the best fitness is 0.021660649819494587']
#       Selected: 910/1939 (46.9%), Fitness: 0.0217, Time: 332.9s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 910/3933 (23.1%)
#
#   --- Layer 2: META_PSO ---
#     Running EvoloPy PSO (Layer 2)...
#       Features: 1939, Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02555440948942754']
# ['At iteration 2 the best fitness is 0.024832387828777724']
# ['At iteration 3 the best fitness is 0.024445590510572462']
# ['At iteration 4 the best fitness is 0.023414130995358433']
# ['At iteration 5 the best fitness is 0.02328519855595668']
# ['At iteration 6 the best fitness is 0.02328519855595668']
# ['At iteration 7 the best fitness is 0.02320783909231563']
# ['At iteration 8 the best fitness is 0.02320783909231563']
# ['At iteration 9 the best fitness is 0.02320783909231563']
# ['At iteration 10 the best fitness is 0.02320783909231563']
# ['At iteration 11 the best fitness is 0.02320783909231563']
# ['At iteration 12 the best fitness is 0.02320783909231563']
# ['At iteration 13 the best fitness is 0.023078906652913872']
# ['At iteration 14 the best fitness is 0.023078906652913872']
# ['At iteration 15 the best fitness is 0.023053120165033525']
# ['At iteration 16 the best fitness is 0.022872614749871067']
# ['At iteration 17 the best fitness is 0.022666322846828263']
# ['At iteration 18 the best fitness is 0.022614749871067562']
# ['At iteration 19 the best fitness is 0.02246003094378546']
# ['At iteration 20 the best fitness is 0.02246003094378546']
# ['At iteration 21 the best fitness is 0.02246003094378546']
# ['At iteration 22 the best fitness is 0.022356884992264056']
# ['At iteration 23 the best fitness is 0.022331098504383706']
# ['At iteration 24 the best fitness is 0.022253739040742654']
# ['At iteration 25 the best fitness is 0.022253739040742654']
# ['At iteration 26 the best fitness is 0.022099020113460547']
# ['At iteration 27 the best fitness is 0.022099020113460547']
# ['At iteration 28 the best fitness is 0.022099020113460547']
# ['At iteration 29 the best fitness is 0.022099020113460547']
# ['At iteration 30 the best fitness is 0.022021660649819495']
#       Selected: 854/1939 (44.0%), Fitness: 0.0220, Time: 335.4s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 854/3933 (21.7%)
#
#   --- Layer 2: META_SCA ---
#     Running EvoloPy SCA (Layer 2)...
#       Features: 1939, Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025296544610624035']
# ['At iteration 1 the best fitness is 0.023182052604435278']
# ['At iteration 2 the best fitness is 0.01854048478597215']
# ['At iteration 3 the best fitness is 0.01854048478597215']
# ['At iteration 4 the best fitness is 0.017276946879834967']
# ['At iteration 5 the best fitness is 0.014337287261474988']
# ['At iteration 6 the best fitness is 0.01188757091284167']
# ['At iteration 7 the best fitness is 0.01183599793708097']
# ['At iteration 8 the best fitness is 0.00961835997937081']
# ['At iteration 9 the best fitness is 0.00961835997937081']
# ['At iteration 10 the best fitness is 0.008793192367199587']
# ['At iteration 11 the best fitness is 0.008793192367199587']
# ['At iteration 12 the best fitness is 0.008174316658071171']
# ['At iteration 13 the best fitness is 0.008174316658071171']
# ['At iteration 14 the best fitness is 0.00812274368231047']
# ['At iteration 15 the best fitness is 0.007194430118617844']
# ['At iteration 16 the best fitness is 0.007194430118617844']
# ['At iteration 17 the best fitness is 0.007194430118617844']
# ['At iteration 18 the best fitness is 0.006704486848891181']
# ['At iteration 19 the best fitness is 0.006704486848891181']
# ['At iteration 20 the best fitness is 0.006472408457968025']
# ['At iteration 21 the best fitness is 0.005853532748839608']
# ['At iteration 22 the best fitness is 0.005853532748839608']
# ['At iteration 23 the best fitness is 0.005466735430634348']
# ['At iteration 24 the best fitness is 0.005466735430634348']
# ['At iteration 25 the best fitness is 0.005440948942753997']
# ['At iteration 26 the best fitness is 0.005440948942753997']
# ['At iteration 27 the best fitness is 0.005440948942753997']
# ['At iteration 28 the best fitness is 0.005440948942753997']
# ['At iteration 29 the best fitness is 0.005440948942753997']
#       Selected: 224/1939 (11.6%), Fitness: 0.0054, Time: 315.7s
#     L2 Test Acc: 98.13%, F1: 98.12%, Features: 224/3933 (5.7%)
#
#   --- Layer 2: META_SSA ---
#     Running EvoloPy SSA (Layer 2)...
#       Features: 1939, Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.025038679731820526']
# ['At iteration 2 the best fitness is 0.024832387828777724']
# ['At iteration 3 the best fitness is 0.024265085095410005']
# ['At iteration 4 the best fitness is 0.024265085095410005']
# ['At iteration 5 the best fitness is 0.02362042289840124']
# ['At iteration 6 the best fitness is 0.02362042289840124']
# ['At iteration 7 the best fitness is 0.023594636410520887']
# ['At iteration 8 the best fitness is 0.023594636410520887']
# ['At iteration 9 the best fitness is 0.023078906652913872']
# ['At iteration 10 the best fitness is 0.023078906652913872']
# ['At iteration 11 the best fitness is 0.023078906652913872']
# ['At iteration 12 the best fitness is 0.022949974213512123']
# ['At iteration 13 the best fitness is 0.022898401237751418']
# ['At iteration 14 the best fitness is 0.02284682826199072']
# ['At iteration 15 the best fitness is 0.02284682826199072']
# ['At iteration 16 the best fitness is 0.02284682826199072']
# ['At iteration 17 the best fitness is 0.022795255286230016']
# ['At iteration 18 the best fitness is 0.022769468798349665']
# ['At iteration 19 the best fitness is 0.022743682310469318']
# ['At iteration 20 the best fitness is 0.022717895822588964']
# ['At iteration 21 the best fitness is 0.022717895822588964']
# ['At iteration 22 the best fitness is 0.022717895822588964']
# ['At iteration 23 the best fitness is 0.022717895822588964']
# ['At iteration 24 the best fitness is 0.022717895822588964']
# ['At iteration 25 the best fitness is 0.022717895822588964']
# ['At iteration 26 the best fitness is 0.022717895822588964']
# ['At iteration 27 the best fitness is 0.022717895822588964']
# ['At iteration 28 the best fitness is 0.022717895822588964']
# ['At iteration 29 the best fitness is 0.022717895822588964']
#       Selected: 904/1939 (46.6%), Fitness: 0.0227, Time: 844.3s
#     L2 Test Acc: 99.07%, F1: 98.94%, Features: 904/3933 (23.0%)
#
#   --- Layer 2: META_WOA ---
#     Running EvoloPy WOA (Layer 2)...
#       Features: 1939, Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024290871583290356']
# ['At iteration 1 the best fitness is 0.01577118789754173']
# ['At iteration 2 the best fitness is 0.013434760185662711']
# ['At iteration 3 the best fitness is 0.013434760185662711']
# ['At iteration 4 the best fitness is 0.013434760185662711']
# ['At iteration 5 the best fitness is 0.010897541688155448']
# ['At iteration 6 the best fitness is 0.010897541688155448']
# ['At iteration 7 the best fitness is 0.010897541688155448']
# ['At iteration 8 the best fitness is 0.010897541688155448']
# ['At iteration 9 the best fitness is 0.010897541688155448']
# ['At iteration 10 the best fitness is 0.010897541688155448']
# ['At iteration 11 the best fitness is 0.010897541688155448']
# ['At iteration 12 the best fitness is 0.010897541688155448']
# ['At iteration 13 the best fitness is 0.010897541688155448']
# ['At iteration 14 the best fitness is 0.006781846312532234']
# ['At iteration 15 the best fitness is 0.00665291387313048']
# ['At iteration 16 the best fitness is 0.00665291387313048']
# ['At iteration 17 the best fitness is 0.00665291387313048']
# ['At iteration 18 the best fitness is 0.00665291387313048']
# ['At iteration 19 the best fitness is 0.00665291387313048']
# ['At iteration 20 the best fitness is 0.00665291387313048']
# ['At iteration 21 the best fitness is 0.00665291387313048']
# ['At iteration 22 the best fitness is 0.006369262506446621']
# ['At iteration 23 the best fitness is 0.006369262506446621']
# ['At iteration 24 the best fitness is 0.006369262506446621']
# ['At iteration 25 the best fitness is 0.006369262506446621']
# ['At iteration 26 the best fitness is 0.006369262506446621']
# ['At iteration 27 the best fitness is 0.006369262506446621']
# ['At iteration 28 the best fitness is 0.006369262506446621']
# ['At iteration 29 the best fitness is 0.006369262506446621']
#       Selected: 262/1939 (13.5%), Fitness: 0.0064, Time: 299.0s
#     L2 Test Acc: 97.20%, F1: 97.18%, Features: 262/3933 (6.7%)
#
# ================================================================================
# ALL LAYER 2 EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
rows = []

for method_name in ALL_METHODS_L2:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'L1 Features': r.get('l1_features', TOTAL_FEATURES),
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_two_layer/all_results_per_fold.csv
# Shape: (136, 29)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  L1 Features  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0   mutual_info     1            99.0741          100.0000       99.0594          99.0594              99.2593           99.0741                983            3933                24.9936         1966      11.2235          5.7450         16.9686        643611           2.4611                25.8355                  6.4572                75.0064        32.4775               6.0185              13               37.4233              244                 22.5532                371              25.0000             355
# 1   mutual_info     2            90.7407          100.0000       89.1005          89.1005              91.3580           90.7407                983            3933                24.9936         1966      11.3144          5.7452         17.0597        643611           2.4611                25.8355                  6.4572                75.0064        32.4775               5.0926              11               38.0368              248                 22.6748                373              24.7183             351
# 2   mutual_info     3            95.3704          100.0000       95.1088          95.1088              96.7901           95.3704                983            3933                24.9936         1966      11.1429          6.0689         17.2119        643611           2.4611                25.8355                  6.4572                75.0064        32.4775               5.0926              11               38.8037              253                 22.6140                372              24.4366             347
# 3   mutual_info     4            97.2222           99.3333       97.0018          97.0018              97.7778           97.2222                983            3933                24.9936         1966      10.9127          5.6656         16.5784        643611           2.4611                25.8355                  6.4572                75.0064        32.4775               5.0926              11               38.0368              248                 23.3435                384              23.9437             340
# 4   mutual_info     5            94.4444          100.0000       93.1805          93.1805              92.9630           94.4444                983            3933                24.9936         1966      11.1278          6.0162         17.1441        643611           2.4611                25.8355                  6.4572                75.0064        32.4775               6.0185              13               38.4969              251                 22.8571                376              24.1549             343
# 5   mutual_info     6            96.2617          100.0000       95.8271          95.7881              97.6720           96.2963                983            3933                24.9936         1966      11.1437          5.9715         17.1153        643611           2.4611                25.8355                  6.4572                75.0064        32.4775               6.4815              14               40.0307              261                 22.9179                377              23.3099             331
# 6   mutual_info     7            91.5888           99.3333       89.4044          89.3054              88.6831           91.6667                983            3933                24.9936         1966      10.5614          5.7222         16.2837        643611           2.4611                25.8355                  6.4572                75.0064        32.4775               6.9444              15               39.8773              260                 23.0395                379              23.1690             329
# 7   mutual_info     8            95.3271          100.0000       94.0837          94.4532              93.9815           95.3704                983            3933                24.9936         1966      10.6694          5.5968         16.2663        643611           2.4611                25.8355                  6.4572                75.0064        32.4775               6.4815              14               38.8037              253                 23.3435                384              23.3803             332
# 8           rfe     1            96.2963          100.0000       96.0494          96.0494              96.2963           96.2963                983            3933                24.9936         1966       1.9123          5.5213          7.4338        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              26.3889              57               39.5706              258                 21.7629                358              21.8310             310
# 9           rfe     2            94.4444          100.0000       93.9939          93.9939              96.8254           94.4444                983            3933                24.9936         1966       1.9212          5.7660          7.6874        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              26.8519              58               36.9632              241                 22.6748                373              21.9014             311
# 10          rfe     3            93.5185          100.0000       92.1458          92.1458              92.4691           93.5185                983            3933                24.9936         1966       1.9020          6.1352          8.0374        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              27.3148              59               39.4172              257                 20.4255                336              23.3099             331
# 11          rfe     4            93.5185          100.0000       92.6094          92.6094              95.8995           93.5185                983            3933                24.9936         1966       1.9398          5.7612          7.7012        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              32.4074              70               38.9571              254                 20.9119                344              22.1831             315
# 12          rfe     5           100.0000          100.0000      100.0000         100.0000             100.0000          100.0000                983            3933                24.9936         1966       1.9355          6.0460          7.9817        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              24.5370              53               41.1043              268                 20.5471                338              22.8169             324
# 13          rfe     6            96.2617          100.0000       95.0617          95.0156              94.4444           96.2963                983            3933                24.9936         1966       1.9217          6.0014          7.9233        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              32.8704              71               38.6503              252                 20.0608                330              23.2394             330
# 14          rfe     7            95.3271          100.0000       94.8618          95.0007              97.4074           95.0617                983            3933                24.9936         1966       1.9086          5.8188          7.7276        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              25.9259              56               41.4110              270                 21.1550                348              21.7606             309
# 15          rfe     8           100.0000          100.0000      100.0000         100.0000             100.0000          100.0000                983            3933                24.9936         1966       1.9182          5.5816          7.5000        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              26.8519              58               38.9571              254                 19.9392                328              24.1549             343
# 16        lasso     1            71.2963           95.3333       68.9248          68.9248              73.6714           71.2963                983            3933                24.9936         1966       0.2400          5.6439          5.8840        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              15.2778              33                0.0000                0                 16.5957                273              47.6761             677
# 17        lasso     2            71.2963           96.0000       67.4595          67.4595              71.9561           71.2963                983            3933                24.9936         1966       0.3587          5.8208          6.1796        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              15.2778              33                0.0000                0                 16.5957                273              47.6761             677
# 18        lasso     3            70.3704           97.3333       68.4867          68.4867              73.7125           70.3704                983            3933                24.9936         1966       0.3542          6.1339          6.4883        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              15.2778              33                0.0000                0                 16.5957                273              47.6761             677
# 19        lasso     4            71.2963           97.3333       71.4588          71.4588              80.1675           71.2963                983            3933                24.9936         1966       0.2756          5.7546          6.0303        643611           2.4611                25.8355                  6.4572                75.0064        32.4775              15.2778              33                0.0000                0                 16.5957                273              47.6761             677

# %% [markdown]
# ## Per-Method Summary Table

# %%
summary_rows = []
for method_name in ALL_METHODS_L2:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean L1 Features': method_df['L1 Features'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean L1 Features  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
# mutual_info              95.00              2.76              94.10              3.48                  983.00                       24.99           1966.00             11.01                 5.82                16.83           643611.0                  2.46                       75.01               32.48
#         rfe              96.17              2.59              95.59              3.01                  983.00                       24.99           1966.00              1.92                 5.83                 7.75           643611.0                  2.46                       75.01               32.48
#       lasso              79.46             10.30              77.37             11.04                  983.00                       24.99           1966.00              0.31                 5.85                 6.17           643611.0                  2.46                       75.01               32.48
#    meta_BAT              93.61              3.67              92.90              4.24                  872.25                       22.18           1856.62            355.79                 5.84               361.63           586907.0                  2.24                       77.82               31.88
#     meta_CS              94.54              3.71              93.64              4.43                  879.75                       22.37           1856.62            702.25                 5.75               708.01           590747.0                  2.26                       77.63               32.00
#     meta_DE              93.61              3.99              92.78              4.76                  835.75                       21.25           1856.62            354.20                 5.87               360.07           568219.0                  2.17                       78.75               31.10
#    meta_FFA              94.89              3.26              94.42              3.67                  890.12                       22.63           1856.62            338.53                 5.76               344.29           596059.0                  2.28                       77.37               32.16
#     meta_GA              94.20              3.35              93.66              3.86                  867.12                       22.05           1856.62            342.99                 5.73               348.71           584283.0                  2.23                       77.95               31.99
#    meta_GWO              92.57              4.93              91.63              5.92                  500.75                       12.73           1856.62            331.48                 5.49               336.97           396699.0                  1.52                       87.27               26.67
#    meta_HHO              89.10              5.03              87.83              5.45                  287.62                        7.31           1856.62            408.67                 5.34               414.01           267307.0                  1.03                       92.69               23.43
#   meta_JAYA              94.31              2.47              93.76              2.88                  861.12                       21.89           1856.62            353.93                 5.78               359.71           581211.0                  2.22                       78.11               31.59
#    meta_MFO              93.85              2.96              93.09              3.46                  861.75                       21.91           1856.62            332.91                 5.79               338.69           581531.0                  2.22                       78.09               32.00
#    meta_MVO              94.20              4.22              93.43              4.94                  865.50                       22.01           1856.62            344.99                 5.83               350.83           583451.0                  2.23                       77.99               31.80
#    meta_PSO              94.08              3.33              93.42              3.57                  815.00                       20.72           1856.62            344.55                 5.75               350.30           557595.0                  2.13                       79.28               30.76
#    meta_SCA              90.01              4.73              89.07              5.67                  206.38                        5.25           1856.62            322.12                 5.26               327.38           179888.0                  0.69                       94.75               21.42
#    meta_SSA              94.89              2.85              94.51              3.09                  872.12                       22.17           1856.62            862.47                 5.69               868.16           586843.0                  2.24                       77.83               32.05
#    meta_WOA              91.87              3.42              91.25              3.74                  297.25                        7.56           1856.62            303.03                 5.39               308.42           285581.0                  1.10                       92.44               23.85

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS_L2)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Two-Layer FS: Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Two-Layer FS: Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Two-Layer FS: Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention scatter
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS_L2:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Two-Layer FS: Accuracy vs Feature Retention', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap
# ============================================================================
modality_data = {}
for method in ALL_METHODS_L2:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS_L2)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Two-Layer FS: Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Layer 2 Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Metaheuristics-only comparison
# ============================================================================
meta_method_names = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

if len(meta_method_names) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_method_names)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_method_names)
    bars = axes[0].bar(range(len(meta_method_names)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_method_names))))
    axes[0].set_xticks(range(len(meta_method_names)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_method_names], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Two-Layer FS Metaheuristics: Test Accuracy', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_method_names)
    bars2 = axes[1].bar(range(len(meta_method_names)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_method_names))))
    axes[1].set_xticks(range(len(meta_method_names)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_method_names], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Two-Layer FS Metaheuristics: Feature Retention', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '07_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 07_metaheuristics_comparison.png")
# Out:
# Saved: 07_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 8: Convergence curves for metaheuristics
# ============================================================================
meta_method_names = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

if len(meta_method_names) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_method_names:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Layer 2 Metaheuristic Convergence Curves (averaged)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_convergence_curves.png")
# Out:
# Saved: 08_convergence_curves.png

# %%
# ============================================================================
# PLOT 9: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods_plot = ['mutual_info', 'rfe', 'lasso']
meta_methods_plot = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

all_std = df_all[df_all['Method'].isin(standard_methods_plot)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods_plot)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

all_std_f = df_all[(df_all['Method'].isin(standard_methods_plot)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods_plot)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

all_std_t = df_all[(df_all['Method'].isin(standard_methods_plot)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods_plot)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '09_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 09_standard_vs_metaheuristics.png")
# Out:
# Saved: 09_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 10: Per-fold accuracy line plot
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS_L2:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Two-Layer FS: Test Accuracy Across Folds', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_per_fold_accuracy_lines.png")
# Out:
# Saved: 10_per_fold_accuracy_lines.png

# %% [markdown]
# ## Best Metaheuristic Per Fold (Layer 2)

# %%
meta_methods_l2 = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD - LAYER 2 (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods_l2:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

df_best_meta = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold - Layer 2)")
print("=" * 90)

if len(df_best_meta) > 0:
    avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
    std_test_acc = df_best_meta['Test Accuracy (%)'].std()
    avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
    std_feat_ret = df_best_meta['Feature Retention (%)'].std()

    print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
    print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

    print(f"\n  Average Modality-wise Feature Retention:")
    for mod in modality_names:
        col = f'{mod} Retention (%)'
        if col in df_best_meta.columns:
            avg_mod = df_best_meta[col].mean()
            std_mod = df_best_meta[col].std()
            print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

    csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
    df_best_meta.to_csv(csv_path, index=False)
    print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD - LAYER 2 (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_GWO
#     Test Accuracy:      99.07%
#     Feature Retention:  13.07% (514/3933)
#     Modality Retention: depth=12.0%, sensor=13.8%, skeleton=13.7%, video=12.2%
#
#   Fold 2: Best = meta_FFA
#     Test Accuracy:      95.37%
#     Feature Retention:  20.85% (820/3933)
#     Modality Retention: depth=19.9%, sensor=26.8%, skeleton=23.5%, video=15.1%
#
#   Fold 3: Best = meta_SSA
#     Test Accuracy:      96.30%
#     Feature Retention:  21.36% (840/3933)
#     Modality Retention: depth=24.1%, sensor=23.9%, skeleton=16.8%, video=25.1%
#
#   Fold 4: Best = meta_CS
#     Test Accuracy:      98.15%
#     Feature Retention:  23.24% (914/3933)
#     Modality Retention: depth=26.4%, sensor=22.4%, skeleton=22.6%, video=23.9%
#
#   Fold 5: Best = meta_GWO
#     Test Accuracy:      97.22%
#     Feature Retention:  12.92% (508/3933)
#     Modality Retention: depth=18.5%, sensor=12.0%, skeleton=12.3%, video=13.2%
#
#   Fold 6: Best = meta_FFA
#     Test Accuracy:      97.20%
#     Feature Retention:  23.44% (922/3933)
#     Modality Retention: depth=21.3%, sensor=22.9%, skeleton=23.3%, video=24.2%
#
#   Fold 7: Best = meta_MFO
#     Test Accuracy:      96.26%
#     Feature Retention:  21.92% (862/3933)
#     Modality Retention: depth=21.3%, sensor=16.1%, skeleton=23.5%, video=22.9%
#
#   Fold 8: Best = meta_BAT
#     Test Accuracy:      100.00%
#     Feature Retention:  23.42% (921/3933)
#     Modality Retention: depth=22.7%, sensor=22.1%, skeleton=24.1%, video=23.3%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold - Layer 2)
# ==========================================================================================
#
#   Average Test Accuracy:     97.45% ± 1.55%
#   Average Feature Retention: 20.03% ± 4.45%
#
#   Average Modality-wise Feature Retention:
#          depth: 20.78% ± 4.29%
#         sensor: 20.00% ± 5.33%
#       skeleton: 19.98% ± 4.90%
#          video: 19.98% ± 5.47%
#
# Saved to: results_two_layer/best_metaheuristic_per_fold.csv
