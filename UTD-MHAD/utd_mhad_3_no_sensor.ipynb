# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_3_no_sensor")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 37
#   skeleton: 240
#   video: 264
#   TOTAL: 541

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 85.19%, F1: 81.63%, Features: 541/541 (100.0%), Model: 1.598MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 270/541 (49.9%), Time: 3.1s
#     Test Acc: 81.48%, F1: 79.01%, Features: 270/541 (49.9%), Model: 1.068MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 270/541 (49.9%), Time: 0.5s
#     Test Acc: 83.33%, F1: 79.91%, Features: 270/541 (49.9%), Model: 1.068MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 270/541 (49.9%), Time: 0.1s
#     Test Acc: 82.41%, F1: 77.01%, Features: 270/541 (49.9%), Model: 1.068MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025970425138632167']
# ['At iteration 1 the best fitness is 0.025970425138632167']
# ['At iteration 2 the best fitness is 0.02532347504621072']
# ['At iteration 3 the best fitness is 0.02532347504621072']
# ['At iteration 4 the best fitness is 0.02532347504621072']
# ['At iteration 5 the best fitness is 0.02532347504621072']
# ['At iteration 6 the best fitness is 0.02532347504621072']
# ['At iteration 7 the best fitness is 0.025231053604436227']
# ['At iteration 8 the best fitness is 0.025231053604436227']
# ['At iteration 9 the best fitness is 0.02513863216266174']
# ['At iteration 10 the best fitness is 0.02513863216266174']
# ['At iteration 11 the best fitness is 0.02513863216266174']
# ['At iteration 12 the best fitness is 0.02513863216266174']
# ['At iteration 13 the best fitness is 0.02513863216266174']
# ['At iteration 14 the best fitness is 0.02467652495378928']
# ['At iteration 15 the best fitness is 0.02467652495378928']
# ['At iteration 16 the best fitness is 0.024491682070240297']
# ['At iteration 17 the best fitness is 0.024399260628465806']
# ['At iteration 18 the best fitness is 0.024399260628465806']
# ['At iteration 19 the best fitness is 0.024399260628465806']
# ['At iteration 20 the best fitness is 0.024306839186691312']
# ['At iteration 21 the best fitness is 0.024306839186691312']
# ['At iteration 22 the best fitness is 0.024306839186691312']
# ['At iteration 23 the best fitness is 0.024214417744916825']
# ['At iteration 24 the best fitness is 0.024214417744916825']
# ['At iteration 25 the best fitness is 0.024214417744916825']
# ['At iteration 26 the best fitness is 0.024214417744916825']
# ['At iteration 27 the best fitness is 0.024214417744916825']
# ['At iteration 28 the best fitness is 0.024214417744916825']
# ['At iteration 29 the best fitness is 0.024214417744916825']
#       Selected: 262/541 (48.4%), Fitness: 0.0242, Time: 823.2s
#       Modality: D=43%, Sk=45%, V=52%
#     Test Acc: 84.26%, F1: 80.29%, Features: 262/541 (48.4%), Model: 1.053MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02301293900184843']
# ['At iteration 10 the best fitness is 0.022920517560073937']
# ['At iteration 20 the best fitness is 0.022920517560073937']
#       Selected: 254/541 (47.0%), Fitness: 0.0229, Time: 1592.9s
#       Modality: D=41%, Sk=45%, V=50%
#     Test Acc: 73.15%, F1: 70.72%, Features: 254/541 (47.0%), Model: 1.025MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023844731977818855']
# ['At iteration 2 the best fitness is 0.023844731977818855']
# ['At iteration 3 the best fitness is 0.023844731977818855']
# ['At iteration 4 the best fitness is 0.023844731977818855']
# ['At iteration 5 the best fitness is 0.023844731977818855']
# ['At iteration 6 the best fitness is 0.023844731977818855']
# ['At iteration 7 the best fitness is 0.023844731977818855']
# ['At iteration 8 the best fitness is 0.023844731977818855']
# ['At iteration 9 the best fitness is 0.023844731977818855']
# ['At iteration 10 the best fitness is 0.023567467652495382']
# ['At iteration 11 the best fitness is 0.023567467652495382']
# ['At iteration 12 the best fitness is 0.023567467652495382']
# ['At iteration 13 the best fitness is 0.023567467652495382']
# ['At iteration 14 the best fitness is 0.023567467652495382']
# ['At iteration 15 the best fitness is 0.023567467652495382']
# ['At iteration 16 the best fitness is 0.023197781885397412']
# ['At iteration 17 the best fitness is 0.023197781885397412']
# ['At iteration 18 the best fitness is 0.023197781885397412']
# ['At iteration 19 the best fitness is 0.023197781885397412']
# ['At iteration 20 the best fitness is 0.023197781885397412']
# ['At iteration 21 the best fitness is 0.023197781885397412']
# ['At iteration 22 the best fitness is 0.02255083179297597']
# ['At iteration 23 the best fitness is 0.02255083179297597']
# ['At iteration 24 the best fitness is 0.02255083179297597']
# ['At iteration 25 the best fitness is 0.02255083179297597']
# ['At iteration 26 the best fitness is 0.02255083179297597']
# ['At iteration 27 the best fitness is 0.02255083179297597']
# ['At iteration 28 the best fitness is 0.02255083179297597']
# ['At iteration 29 the best fitness is 0.02255083179297597']
# ['At iteration 30 the best fitness is 0.02255083179297597']
#       Selected: 245/541 (45.3%), Fitness: 0.0226, Time: 788.9s
#       Modality: D=38%, Sk=50%, V=42%
#     Test Acc: 86.11%, F1: 82.82%, Features: 245/541 (45.3%), Model: 0.955MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025693160813308687']
# ['At iteration 1 the best fitness is 0.02467652495378928']
# ['At iteration 2 the best fitness is 0.024214417744916825']
# ['At iteration 3 the best fitness is 0.022273567467652494']
# ['At iteration 4 the best fitness is 0.023475046210720888']
# ['At iteration 5 the best fitness is 0.02301293900184843']
# ['At iteration 6 the best fitness is 0.023382624768946397']
# ['At iteration 7 the best fitness is 0.02255083179297597']
# ['At iteration 8 the best fitness is 0.022273567467652494']
# ['At iteration 9 the best fitness is 0.02301293900184843']
# ['At iteration 10 the best fitness is 0.02236598890942699']
# ['At iteration 11 the best fitness is 0.02236598890942699']
# ['At iteration 12 the best fitness is 0.02236598890942699']
# ['At iteration 13 the best fitness is 0.022181146025878007']
# ['At iteration 14 the best fitness is 0.022273567467652494']
# ['At iteration 15 the best fitness is 0.022181146025878007']
# ['At iteration 16 the best fitness is 0.022088724584103513']
# ['At iteration 17 the best fitness is 0.022088724584103513']
# ['At iteration 18 the best fitness is 0.022088724584103513']
# ['At iteration 19 the best fitness is 0.022088724584103513']
# ['At iteration 20 the best fitness is 0.022088724584103513']
# ['At iteration 21 the best fitness is 0.022088724584103513']
# ['At iteration 22 the best fitness is 0.022088724584103513']
# ['At iteration 23 the best fitness is 0.022088724584103513']
# ['At iteration 24 the best fitness is 0.022088724584103513']
# ['At iteration 25 the best fitness is 0.022088724584103513']
# ['At iteration 26 the best fitness is 0.022088724584103513']
# ['At iteration 27 the best fitness is 0.022088724584103513']
# ['At iteration 28 the best fitness is 0.022088724584103513']
# ['At iteration 29 the best fitness is 0.022088724584103513']
#       Selected: 247/541 (45.7%), Fitness: 0.0221, Time: 756.6s
#       Modality: D=35%, Sk=44%, V=49%
#     Test Acc: 85.19%, F1: 83.73%, Features: 247/541 (45.7%), Model: 0.971MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.030917436845348163
# At iteration 2 the best fitness is 0.02513863216266174
# At iteration 3 the best fitness is 0.024768946395563773
# At iteration 4 the best fitness is 0.024029574861367836
# At iteration 5 the best fitness is 0.02504621072088725
# At iteration 6 the best fitness is 0.024214417744916825
# At iteration 7 the best fitness is 0.024861367837338263
# At iteration 8 the best fitness is 0.02532347504621072
# At iteration 9 the best fitness is 0.024491682070240297
# At iteration 10 the best fitness is 0.025508317929759706
# At iteration 11 the best fitness is 0.02532347504621072
# At iteration 12 the best fitness is 0.023659889094269873
# At iteration 13 the best fitness is 0.024306839186691312
# At iteration 14 the best fitness is 0.022735674676524955
# At iteration 15 the best fitness is 0.024399260628465806
# At iteration 16 the best fitness is 0.024029574861367836
# At iteration 17 the best fitness is 0.024861367837338263
# At iteration 18 the best fitness is 0.02393715341959335
# At iteration 19 the best fitness is 0.024861367837338263
# At iteration 20 the best fitness is 0.023382624768946397
# At iteration 21 the best fitness is 0.023844731977818855
# At iteration 22 the best fitness is 0.024584103512014788
# At iteration 23 the best fitness is 0.022920517560073937
# At iteration 24 the best fitness is 0.024214417744916825
# At iteration 25 the best fitness is 0.024491682070240297
# At iteration 26 the best fitness is 0.024584103512014788
# At iteration 27 the best fitness is 0.024306839186691312
# At iteration 28 the best fitness is 0.023567467652495382
# At iteration 29 the best fitness is 0.023752310536044364
# At iteration 30 the best fitness is 0.02393715341959335
#       Selected: 253/541 (46.8%), Fitness: 0.0239, Time: 764.6s
#       Modality: D=51%, Sk=45%, V=48%
#     Test Acc: 83.33%, F1: 79.82%, Features: 253/541 (46.8%), Model: 1.017MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.031009858287122653']
# ['At iteration 1 the best fitness is 0.022643253234750464']
# ['At iteration 2 the best fitness is 0.022643253234750464']
# ['At iteration 3 the best fitness is 0.021534195933456565']
# ['At iteration 4 the best fitness is 0.021534195933456565']
# ['At iteration 5 the best fitness is 0.02014787430683919']
# ['At iteration 6 the best fitness is 0.02014787430683919']
# ['At iteration 7 the best fitness is 0.0200554528650647']
# ['At iteration 8 the best fitness is 0.018299445471349356']
# ['At iteration 9 the best fitness is 0.01756007393715342']
# ['At iteration 10 the best fitness is 0.016820702402957487']
# ['At iteration 11 the best fitness is 0.016820702402957487']
# ['At iteration 12 the best fitness is 0.016358595194085026']
# ['At iteration 13 the best fitness is 0.016358595194085026']
# ['At iteration 14 the best fitness is 0.016081330868761554']
# ['At iteration 15 the best fitness is 0.016081330868761554']
# ['At iteration 16 the best fitness is 0.016081330868761554']
# ['At iteration 17 the best fitness is 0.015526802218114602']
# ['At iteration 18 the best fitness is 0.015526802218114602']
# ['At iteration 19 the best fitness is 0.015526802218114602']
# ['At iteration 20 the best fitness is 0.015526802218114602']
# ['At iteration 21 the best fitness is 0.015526802218114602']
# ['At iteration 22 the best fitness is 0.015526802218114602']
# ['At iteration 23 the best fitness is 0.015526802218114602']
# ['At iteration 24 the best fitness is 0.015526802218114602']
# ['At iteration 25 the best fitness is 0.015526802218114602']
# ['At iteration 26 the best fitness is 0.015526802218114602']
# ['At iteration 27 the best fitness is 0.015526802218114602']
# ['At iteration 28 the best fitness is 0.015526802218114602']
# ['At iteration 29 the best fitness is 0.015526802218114602']
#       Selected: 197/541 (36.4%), Fitness: 0.0155, Time: 717.1s
#       Modality: D=49%, Sk=37%, V=34%
#     Test Acc: 87.04%, F1: 84.69%, Features: 197/541 (36.4%), Model: 0.624MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.02962353666050528']
# ['At iteration 1 the best fitness is 0.02962353666050528']
# ['At iteration 2 the best fitness is 0.02962353666050528']
# ['At iteration 3 the best fitness is 0.023290203327171907']
# ['At iteration 4 the best fitness is 0.023290203327171907']
# ['At iteration 5 the best fitness is 0.023290203327171907']
# ['At iteration 6 the best fitness is 0.023197781885397412']
# ['At iteration 7 the best fitness is 0.021626617375231055']
# ['At iteration 8 the best fitness is 0.021626617375231055']
# ['At iteration 9 the best fitness is 0.021626617375231055']
# ['At iteration 10 the best fitness is 0.021626617375231055']
# ['At iteration 11 the best fitness is 0.021626617375231055']
# ['At iteration 12 the best fitness is 0.021626617375231055']
# ['At iteration 13 the best fitness is 0.021626617375231055']
# ['At iteration 14 the best fitness is 0.021626617375231055']
# ['At iteration 15 the best fitness is 0.021626617375231055']
# ['At iteration 16 the best fitness is 0.021626617375231055']
# ['At iteration 17 the best fitness is 0.021626617375231055']
# ['At iteration 18 the best fitness is 0.021626617375231055']
# ['At iteration 19 the best fitness is 0.021626617375231055']
# ['At iteration 20 the best fitness is 0.021626617375231055']
# ['At iteration 21 the best fitness is 0.021626617375231055']
# ['At iteration 22 the best fitness is 0.020979667282809613']
# ['At iteration 23 the best fitness is 0.020425138632162665']
# ['At iteration 24 the best fitness is 0.020425138632162665']
# ['At iteration 25 the best fitness is 0.020425138632162665']
# ['At iteration 26 the best fitness is 0.020425138632162665']
# ['At iteration 27 the best fitness is 0.020425138632162665']
# ['At iteration 28 the best fitness is 0.020425138632162665']
# ['At iteration 29 the best fitness is 0.020425138632162665']
#       Selected: 226/541 (41.8%), Fitness: 0.0204, Time: 1010.6s
#       Modality: D=46%, Sk=42%, V=41%
#     Test Acc: 86.11%, F1: 82.98%, Features: 226/541 (41.8%), Model: 0.816MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024399260628465806']
# ['At iteration 1 the best fitness is 0.024399260628465806']
# ['At iteration 2 the best fitness is 0.023290203327171907']
# ['At iteration 3 the best fitness is 0.023290203327171907']
# ['At iteration 4 the best fitness is 0.023290203327171907']
# ['At iteration 5 the best fitness is 0.023290203327171907']
# ['At iteration 6 the best fitness is 0.023290203327171907']
# ['At iteration 7 the best fitness is 0.023290203327171907']
# ['At iteration 8 the best fitness is 0.023290203327171907']
# ['At iteration 9 the best fitness is 0.023290203327171907']
# ['At iteration 10 the best fitness is 0.023290203327171907']
# ['At iteration 11 the best fitness is 0.023290203327171907']
# ['At iteration 12 the best fitness is 0.023290203327171907']
# ['At iteration 13 the best fitness is 0.023290203327171907']
# ['At iteration 14 the best fitness is 0.023290203327171907']
# ['At iteration 15 the best fitness is 0.023290203327171907']
# ['At iteration 16 the best fitness is 0.023290203327171907']
# ['At iteration 17 the best fitness is 0.023290203327171907']
# ['At iteration 18 the best fitness is 0.023290203327171907']
# ['At iteration 19 the best fitness is 0.023290203327171907']
# ['At iteration 20 the best fitness is 0.023290203327171907']
# ['At iteration 21 the best fitness is 0.023290203327171907']
# ['At iteration 22 the best fitness is 0.023290203327171907']
# ['At iteration 23 the best fitness is 0.023290203327171907']
# ['At iteration 24 the best fitness is 0.023290203327171907']
# ['At iteration 25 the best fitness is 0.023290203327171907']
# ['At iteration 26 the best fitness is 0.023290203327171907']
# ['At iteration 27 the best fitness is 0.023290203327171907']
# ['At iteration 28 the best fitness is 0.023290203327171907']
# ['At iteration 29 the best fitness is 0.023290203327171907']
#       Selected: 265/541 (49.0%), Fitness: 0.0233, Time: 790.1s
#       Modality: D=54%, Sk=50%, V=47%
#     Test Acc: 82.41%, F1: 78.81%, Features: 265/541 (49.0%), Model: 1.059MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.030825015403573672']
# ['At iteration 2 the best fitness is 0.023752310536044364']
# ['At iteration 3 the best fitness is 0.023752310536044364']
# ['At iteration 4 the best fitness is 0.023752310536044364']
# ['At iteration 5 the best fitness is 0.023659889094269873']
# ['At iteration 6 the best fitness is 0.023197781885397412']
# ['At iteration 7 the best fitness is 0.023197781885397412']
# ['At iteration 8 the best fitness is 0.023197781885397412']
# ['At iteration 9 the best fitness is 0.023197781885397412']
# ['At iteration 10 the best fitness is 0.022920517560073937']
# ['At iteration 11 the best fitness is 0.022920517560073937']
# ['At iteration 12 the best fitness is 0.022920517560073937']
# ['At iteration 13 the best fitness is 0.022920517560073937']
# ['At iteration 14 the best fitness is 0.022920517560073937']
# ['At iteration 15 the best fitness is 0.022920517560073937']
# ['At iteration 16 the best fitness is 0.022735674676524955']
# ['At iteration 17 the best fitness is 0.022735674676524955']
# ['At iteration 18 the best fitness is 0.022273567467652494']
# ['At iteration 19 the best fitness is 0.022273567467652494']
# ['At iteration 20 the best fitness is 0.022273567467652494']
# ['At iteration 21 the best fitness is 0.022273567467652494']
# ['At iteration 22 the best fitness is 0.022273567467652494']
# ['At iteration 23 the best fitness is 0.022273567467652494']
# ['At iteration 24 the best fitness is 0.022273567467652494']
# ['At iteration 25 the best fitness is 0.022273567467652494']
# ['At iteration 26 the best fitness is 0.022273567467652494']
# ['At iteration 27 the best fitness is 0.02125693160813309']
# ['At iteration 28 the best fitness is 0.02125693160813309']
# ['At iteration 29 the best fitness is 0.02125693160813309']
#       Selected: 242/541 (44.7%), Fitness: 0.0213, Time: 738.7s
#       Modality: D=30%, Sk=43%, V=48%
#     Test Acc: 79.63%, F1: 74.46%, Features: 242/541 (44.7%), Model: 0.933MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03036290819470121']
# ['At iteration 2 the best fitness is 0.022735674676524955']
# ['At iteration 3 the best fitness is 0.022735674676524955']
# ['At iteration 4 the best fitness is 0.022088724584103513']
# ['At iteration 5 the best fitness is 0.022088724584103513']
# ['At iteration 6 the best fitness is 0.022088724584103513']
# ['At iteration 7 the best fitness is 0.022088724584103513']
# ['At iteration 8 the best fitness is 0.022088724584103513']
# ['At iteration 9 the best fitness is 0.022088724584103513']
# ['At iteration 10 the best fitness is 0.022088724584103513']
# ['At iteration 11 the best fitness is 0.022088724584103513']
# ['At iteration 12 the best fitness is 0.022088724584103513']
# ['At iteration 13 the best fitness is 0.021626617375231055']
# ['At iteration 14 the best fitness is 0.021626617375231055']
# ['At iteration 15 the best fitness is 0.021626617375231055']
# ['At iteration 16 the best fitness is 0.021626617375231055']
# ['At iteration 17 the best fitness is 0.021626617375231055']
# ['At iteration 18 the best fitness is 0.021626617375231055']
# ['At iteration 19 the best fitness is 0.02125693160813309']
# ['At iteration 20 the best fitness is 0.02125693160813309']
# ['At iteration 21 the best fitness is 0.021164510166358595']
# ['At iteration 22 the best fitness is 0.021164510166358595']
# ['At iteration 23 the best fitness is 0.021164510166358595']
# ['At iteration 24 the best fitness is 0.020979667282809613']
# ['At iteration 25 the best fitness is 0.020979667282809613']
# ['At iteration 26 the best fitness is 0.020794824399260628']
# ['At iteration 27 the best fitness is 0.020794824399260628']
# ['At iteration 28 the best fitness is 0.020794824399260628']
# ['At iteration 29 the best fitness is 0.02070240295748614']
# ['At iteration 30 the best fitness is 0.02070240295748614']
#       Selected: 246/541 (45.5%), Fitness: 0.0207, Time: 756.9s
#       Modality: D=43%, Sk=42%, V=49%
#     Test Acc: 80.56%, F1: 77.15%, Features: 246/541 (45.5%), Model: 0.963MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.030825015403573672']
# ['At iteration 2 the best fitness is 0.023567467652495382']
# ['At iteration 3 the best fitness is 0.023567467652495382']
# ['At iteration 4 the best fitness is 0.02255083179297597']
# ['At iteration 5 the best fitness is 0.02255083179297597']
# ['At iteration 6 the best fitness is 0.02255083179297597']
# ['At iteration 7 the best fitness is 0.02255083179297597']
# ['At iteration 8 the best fitness is 0.02255083179297597']
# ['At iteration 9 the best fitness is 0.02255083179297597']
# ['At iteration 10 the best fitness is 0.02255083179297597']
# ['At iteration 11 the best fitness is 0.02255083179297597']
# ['At iteration 12 the best fitness is 0.02255083179297597']
# ['At iteration 13 the best fitness is 0.02236598890942699']
# ['At iteration 14 the best fitness is 0.022181146025878007']
# ['At iteration 15 the best fitness is 0.022181146025878007']
# ['At iteration 16 the best fitness is 0.022181146025878007']
# ['At iteration 17 the best fitness is 0.022181146025878007']
# ['At iteration 18 the best fitness is 0.02134935304990758']
# ['At iteration 19 the best fitness is 0.02134935304990758']
# ['At iteration 20 the best fitness is 0.02134935304990758']
# ['At iteration 21 the best fitness is 0.02134935304990758']
# ['At iteration 22 the best fitness is 0.02134935304990758']
# ['At iteration 23 the best fitness is 0.02134935304990758']
# ['At iteration 24 the best fitness is 0.02134935304990758']
# ['At iteration 25 the best fitness is 0.02134935304990758']
# ['At iteration 26 the best fitness is 0.02134935304990758']
# ['At iteration 27 the best fitness is 0.020979667282809613']
# ['At iteration 28 the best fitness is 0.020979667282809613']
# ['At iteration 29 the best fitness is 0.020979667282809613']
# ['At iteration 30 the best fitness is 0.020979667282809613']
#       Selected: 239/541 (44.2%), Fitness: 0.0210, Time: 753.8s
#       Modality: D=51%, Sk=42%, V=45%
#     Test Acc: 86.11%, F1: 83.16%, Features: 239/541 (44.2%), Model: 0.910MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.030640172520024687']
# ['At iteration 1 the best fitness is 0.02181146025878004']
# ['At iteration 2 the best fitness is 0.0200554528650647']
# ['At iteration 3 the best fitness is 0.0200554528650647']
# ['At iteration 4 the best fitness is 0.0200554528650647']
# ['At iteration 5 the best fitness is 0.0200554528650647']
# ['At iteration 6 the best fitness is 0.0200554528650647']
# ['At iteration 7 the best fitness is 0.0200554528650647']
# ['At iteration 8 the best fitness is 0.0200554528650647']
# ['At iteration 9 the best fitness is 0.0200554528650647']
# ['At iteration 10 the best fitness is 0.0200554528650647']
# ['At iteration 11 the best fitness is 0.0200554528650647']
# ['At iteration 12 the best fitness is 0.0200554528650647']
# ['At iteration 13 the best fitness is 0.0200554528650647']
# ['At iteration 14 the best fitness is 0.0200554528650647']
# ['At iteration 15 the best fitness is 0.0200554528650647']
# ['At iteration 16 the best fitness is 0.0200554528650647']
# ['At iteration 17 the best fitness is 0.0200554528650647']
# ['At iteration 18 the best fitness is 0.0200554528650647']
# ['At iteration 19 the best fitness is 0.0200554528650647']
# ['At iteration 20 the best fitness is 0.0200554528650647']
# ['At iteration 21 the best fitness is 0.015619223659889096']
# ['At iteration 22 the best fitness is 0.015619223659889096']
# ['At iteration 23 the best fitness is 0.015619223659889096']
# ['At iteration 24 the best fitness is 0.015619223659889096']
# ['At iteration 25 the best fitness is 0.015619223659889096']
# ['At iteration 26 the best fitness is 0.015619223659889096']
# ['At iteration 27 the best fitness is 0.015619223659889096']
# ['At iteration 28 the best fitness is 0.013216266173752312']
# ['At iteration 29 the best fitness is 0.013216266173752312']
#       Selected: 154/541 (28.5%), Fitness: 0.0132, Time: 706.0s
#       Modality: D=27%, Sk=29%, V=28%
#     Test Acc: 83.33%, F1: 78.18%, Features: 154/541 (28.5%), Model: 0.387MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023475046210720888']
# ['At iteration 2 the best fitness is 0.023475046210720888']
# ['At iteration 3 the best fitness is 0.023290203327171907']
# ['At iteration 4 the best fitness is 0.023290203327171907']
# ['At iteration 5 the best fitness is 0.023290203327171907']
# ['At iteration 6 the best fitness is 0.023290203327171907']
# ['At iteration 7 the best fitness is 0.023290203327171907']
# ['At iteration 8 the best fitness is 0.023290203327171907']
# ['At iteration 9 the best fitness is 0.02310536044362292']
# ['At iteration 10 the best fitness is 0.02310536044362292']
# ['At iteration 11 the best fitness is 0.02310536044362292']
# ['At iteration 12 the best fitness is 0.02310536044362292']
# ['At iteration 13 the best fitness is 0.02310536044362292']
# ['At iteration 14 the best fitness is 0.02301293900184843']
# ['At iteration 15 the best fitness is 0.02301293900184843']
# ['At iteration 16 the best fitness is 0.022920517560073937']
# ['At iteration 17 the best fitness is 0.022920517560073937']
# ['At iteration 18 the best fitness is 0.022920517560073937']
# ['At iteration 19 the best fitness is 0.022828096118299446']
# ['At iteration 20 the best fitness is 0.022828096118299446']
# ['At iteration 21 the best fitness is 0.022828096118299446']
# ['At iteration 22 the best fitness is 0.022828096118299446']
# ['At iteration 23 the best fitness is 0.022828096118299446']
# ['At iteration 24 the best fitness is 0.022828096118299446']
# ['At iteration 25 the best fitness is 0.022828096118299446']
# ['At iteration 26 the best fitness is 0.022828096118299446']
# ['At iteration 27 the best fitness is 0.022828096118299446']
# ['At iteration 28 the best fitness is 0.022828096118299446']
# ['At iteration 29 the best fitness is 0.022828096118299446']
#       Selected: 254/541 (47.0%), Fitness: 0.0228, Time: 1888.1s
#       Modality: D=51%, Sk=45%, V=48%
#     Test Acc: 85.19%, F1: 81.76%, Features: 254/541 (47.0%), Model: 1.025MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03165680837954409']
# ['At iteration 1 the best fitness is 0.02236598890942699']
# ['At iteration 2 the best fitness is 0.02236598890942699']
# ['At iteration 3 the best fitness is 0.020425138632162665']
# ['At iteration 4 the best fitness is 0.020425138632162665']
# ['At iteration 5 the best fitness is 0.020425138632162665']
# ['At iteration 6 the best fitness is 0.020425138632162665']
# ['At iteration 7 the best fitness is 0.020425138632162665']
# ['At iteration 8 the best fitness is 0.020425138632162665']
# ['At iteration 9 the best fitness is 0.020425138632162665']
# ['At iteration 10 the best fitness is 0.020425138632162665']
# ['At iteration 11 the best fitness is 0.020425138632162665']
# ['At iteration 12 the best fitness is 0.020425138632162665']
# ['At iteration 13 the best fitness is 0.020425138632162665']
# ['At iteration 14 the best fitness is 0.020425138632162665']
# ['At iteration 15 the best fitness is 0.020425138632162665']
# ['At iteration 16 the best fitness is 0.020425138632162665']
# ['At iteration 17 the best fitness is 0.020425138632162665']
# ['At iteration 18 the best fitness is 0.02033271719038817']
# ['At iteration 19 the best fitness is 0.02033271719038817']
# ['At iteration 20 the best fitness is 0.02033271719038817']
# ['At iteration 21 the best fitness is 0.02033271719038817']
# ['At iteration 22 the best fitness is 0.02033271719038817']
# ['At iteration 23 the best fitness is 0.02033271719038817']
# ['At iteration 24 the best fitness is 0.02033271719038817']
# ['At iteration 25 the best fitness is 0.02033271719038817']
# ['At iteration 26 the best fitness is 0.02033271719038817']
# ['At iteration 27 the best fitness is 0.02033271719038817']
# ['At iteration 28 the best fitness is 0.02033271719038817']
# ['At iteration 29 the best fitness is 0.02033271719038817']
#       Selected: 209/541 (38.6%), Fitness: 0.0203, Time: 695.8s
#       Modality: D=43%, Sk=36%, V=40%
#     Test Acc: 72.22%, F1: 66.84%, Features: 209/541 (38.6%), Model: 0.700MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 71.30%, F1: 65.80%, Features: 541/541 (100.0%), Model: 1.598MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 270/541 (49.9%), Time: 3.0s
#     Test Acc: 62.96%, F1: 56.60%, Features: 270/541 (49.9%), Model: 1.068MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 270/541 (49.9%), Time: 0.5s
#     Test Acc: 73.15%, F1: 69.25%, Features: 270/541 (49.9%), Model: 1.068MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 270/541 (49.9%), Time: 0.1s
#     Test Acc: 69.44%, F1: 63.26%, Features: 270/541 (49.9%), Model: 1.068MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024491682070240297']
# ['At iteration 1 the best fitness is 0.024491682070240297']
# ['At iteration 2 the best fitness is 0.024491682070240297']
# ['At iteration 3 the best fitness is 0.02412199630314233']
# ['At iteration 4 the best fitness is 0.02412199630314233']
# ['At iteration 5 the best fitness is 0.02412199630314233']
# ['At iteration 6 the best fitness is 0.023659889094269873']
# ['At iteration 7 the best fitness is 0.023659889094269873']
# ['At iteration 8 the best fitness is 0.023659889094269873']
# ['At iteration 9 the best fitness is 0.023659889094269873']
# ['At iteration 10 the best fitness is 0.023659889094269873']
# ['At iteration 11 the best fitness is 0.023567467652495382']
# ['At iteration 12 the best fitness is 0.023567467652495382']
# ['At iteration 13 the best fitness is 0.023567467652495382']
# ['At iteration 14 the best fitness is 0.023567467652495382']
# ['At iteration 15 the best fitness is 0.023567467652495382']
# ['At iteration 16 the best fitness is 0.023567467652495382']
# ['At iteration 17 the best fitness is 0.023567467652495382']
# ['At iteration 18 the best fitness is 0.023382624768946397']
# ['At iteration 19 the best fitness is 0.023382624768946397']
# ['At iteration 20 the best fitness is 0.023290203327171907']
# ['At iteration 21 the best fitness is 0.023290203327171907']
# ['At iteration 22 the best fitness is 0.023290203327171907']
# ['At iteration 23 the best fitness is 0.023290203327171907']
# ['At iteration 24 the best fitness is 0.023290203327171907']
# ['At iteration 25 the best fitness is 0.023290203327171907']
# ['At iteration 26 the best fitness is 0.023290203327171907']
# ['At iteration 27 the best fitness is 0.023290203327171907']
# ['At iteration 28 the best fitness is 0.023290203327171907']
# ['At iteration 29 the best fitness is 0.023290203327171907']
#       Selected: 252/541 (46.6%), Fitness: 0.0233, Time: 784.6s
#       Modality: D=41%, Sk=52%, V=43%
#     Test Acc: 75.00%, F1: 71.30%, Features: 252/541 (46.6%), Model: 1.009MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02301293900184843']
# ['At iteration 10 the best fitness is 0.02301293900184843']
# ['At iteration 20 the best fitness is 0.022458410351201483']
#       Selected: 253/541 (46.8%), Fitness: 0.0219, Time: 1559.4s
#       Modality: D=35%, Sk=46%, V=49%
#     Test Acc: 74.07%, F1: 70.00%, Features: 253/541 (46.8%), Model: 1.017MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023197781885397412']
# ['At iteration 2 the best fitness is 0.022735674676524955']
# ['At iteration 3 the best fitness is 0.022735674676524955']
# ['At iteration 4 the best fitness is 0.022735674676524955']
# ['At iteration 5 the best fitness is 0.022735674676524955']
# ['At iteration 6 the best fitness is 0.022458410351201483']
# ['At iteration 7 the best fitness is 0.021996303142329022']
# ['At iteration 8 the best fitness is 0.02134935304990758']
# ['At iteration 9 the best fitness is 0.02134935304990758']
# ['At iteration 10 the best fitness is 0.02134935304990758']
# ['At iteration 11 the best fitness is 0.02134935304990758']
# ['At iteration 12 the best fitness is 0.02134935304990758']
# ['At iteration 13 the best fitness is 0.02134935304990758']
# ['At iteration 14 the best fitness is 0.02134935304990758']
# ['At iteration 15 the best fitness is 0.020887245841035122']
# ['At iteration 16 the best fitness is 0.020887245841035122']
# ['At iteration 17 the best fitness is 0.020887245841035122']
# ['At iteration 18 the best fitness is 0.02070240295748614']
# ['At iteration 19 the best fitness is 0.02070240295748614']
# ['At iteration 20 the best fitness is 0.02033271719038817']
# ['At iteration 21 the best fitness is 0.02033271719038817']
# ['At iteration 22 the best fitness is 0.02033271719038817']
# ['At iteration 23 the best fitness is 0.02033271719038817']
# ['At iteration 24 the best fitness is 0.02033271719038817']
# ['At iteration 25 the best fitness is 0.02033271719038817']
# ['At iteration 26 the best fitness is 0.02033271719038817']
# ['At iteration 27 the best fitness is 0.02033271719038817']
# ['At iteration 28 the best fitness is 0.02033271719038817']
# ['At iteration 29 the best fitness is 0.02033271719038817']
# ['At iteration 30 the best fitness is 0.02033271719038817']
#       Selected: 229/541 (42.3%), Fitness: 0.0203, Time: 783.9s
#       Modality: D=35%, Sk=40%, V=45%
#     Test Acc: 77.78%, F1: 74.87%, Features: 229/541 (42.3%), Model: 0.837MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024584103512014788']
# ['At iteration 1 the best fitness is 0.02412199630314233']
# ['At iteration 2 the best fitness is 0.022735674676524955']
# ['At iteration 3 the best fitness is 0.022735674676524955']
# ['At iteration 4 the best fitness is 0.023290203327171907']
# ['At iteration 5 the best fitness is 0.022828096118299446']
# ['At iteration 6 the best fitness is 0.022181146025878007']
# ['At iteration 7 the best fitness is 0.022181146025878007']
# ['At iteration 8 the best fitness is 0.02255083179297597']
# ['At iteration 9 the best fitness is 0.022458410351201483']
# ['At iteration 10 the best fitness is 0.022458410351201483']
# ['At iteration 11 the best fitness is 0.02255083179297597']
# ['At iteration 12 the best fitness is 0.022735674676524955']
# ['At iteration 13 the best fitness is 0.022643253234750464']
# ['At iteration 14 the best fitness is 0.022273567467652494']
# ['At iteration 15 the best fitness is 0.022458410351201483']
# ['At iteration 16 the best fitness is 0.022458410351201483']
# ['At iteration 17 the best fitness is 0.022458410351201483']
# ['At iteration 18 the best fitness is 0.022458410351201483']
# ['At iteration 19 the best fitness is 0.022458410351201483']
# ['At iteration 20 the best fitness is 0.022458410351201483']
# ['At iteration 21 the best fitness is 0.022458410351201483']
# ['At iteration 22 the best fitness is 0.022458410351201483']
# ['At iteration 23 the best fitness is 0.022458410351201483']
# ['At iteration 24 the best fitness is 0.022458410351201483']
# ['At iteration 25 the best fitness is 0.022458410351201483']
# ['At iteration 26 the best fitness is 0.022458410351201483']
# ['At iteration 27 the best fitness is 0.022458410351201483']
# ['At iteration 28 the best fitness is 0.022458410351201483']
# ['At iteration 29 the best fitness is 0.022458410351201483']
#       Selected: 275/541 (50.8%), Fitness: 0.0225, Time: 752.6s
#       Modality: D=49%, Sk=50%, V=52%
#     Test Acc: 65.74%, F1: 60.80%, Features: 275/541 (50.8%), Model: 1.078MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024953789279112754
# At iteration 2 the best fitness is 0.023475046210720888
# At iteration 3 the best fitness is 0.024306839186691312
# At iteration 4 the best fitness is 0.02513863216266174
# At iteration 5 the best fitness is 0.023752310536044364
# At iteration 6 the best fitness is 0.024306839186691312
# At iteration 7 the best fitness is 0.023567467652495382
# At iteration 8 the best fitness is 0.023752310536044364
# At iteration 9 the best fitness is 0.02412199630314233
# At iteration 10 the best fitness is 0.023290203327171907
# At iteration 11 the best fitness is 0.029715958102279772
# At iteration 12 the best fitness is 0.023659889094269873
# At iteration 13 the best fitness is 0.023659889094269873
# At iteration 14 the best fitness is 0.023659889094269873
# At iteration 15 the best fitness is 0.023659889094269873
# At iteration 16 the best fitness is 0.023382624768946397
# At iteration 17 the best fitness is 0.022735674676524955
# At iteration 18 the best fitness is 0.02301293900184843
# At iteration 19 the best fitness is 0.02301293900184843
# At iteration 20 the best fitness is 0.022181146025878007
# At iteration 21 the best fitness is 0.023752310536044364
# At iteration 22 the best fitness is 0.02393715341959335
# At iteration 23 the best fitness is 0.02255083179297597
# At iteration 24 the best fitness is 0.02255083179297597
# At iteration 25 the best fitness is 0.023382624768946397
# At iteration 26 the best fitness is 0.02236598890942699
# At iteration 27 the best fitness is 0.02310536044362292
# At iteration 28 the best fitness is 0.022458410351201483
# At iteration 29 the best fitness is 0.022920517560073937
# At iteration 30 the best fitness is 0.022920517560073937
#       Selected: 254/541 (47.0%), Fitness: 0.0229, Time: 755.2s
#       Modality: D=35%, Sk=45%, V=50%
#     Test Acc: 62.04%, F1: 56.07%, Features: 254/541 (47.0%), Model: 1.025MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024768946395563773']
# ['At iteration 1 the best fitness is 0.02393715341959335']
# ['At iteration 2 the best fitness is 0.02255083179297597']
# ['At iteration 3 the best fitness is 0.021719038817005546']
# ['At iteration 4 the best fitness is 0.021164510166358595']
# ['At iteration 5 the best fitness is 0.019500924214417747']
# ['At iteration 6 the best fitness is 0.01913123844731978']
# ['At iteration 7 the best fitness is 0.017097966728280962']
# ['At iteration 8 the best fitness is 0.017097966728280962']
# ['At iteration 9 the best fitness is 0.016728280961182996']
# ['At iteration 10 the best fitness is 0.016543438077634014']
# ['At iteration 11 the best fitness is 0.01534195933456562']
# ['At iteration 12 the best fitness is 0.01534195933456562']
# ['At iteration 13 the best fitness is 0.01478743068391867']
# ['At iteration 14 the best fitness is 0.014417744916820702']
# ['At iteration 15 the best fitness is 0.014417744916820702']
# ['At iteration 16 the best fitness is 0.014417744916820702']
# ['At iteration 17 the best fitness is 0.014048059149722736']
# ['At iteration 18 the best fitness is 0.014048059149722736']
# ['At iteration 19 the best fitness is 0.014048059149722736']
# ['At iteration 20 the best fitness is 0.014048059149722736']
# ['At iteration 21 the best fitness is 0.014048059149722736']
# ['At iteration 22 the best fitness is 0.014048059149722736']
# ['At iteration 23 the best fitness is 0.014048059149722736']
# ['At iteration 24 the best fitness is 0.013863216266173754']
# ['At iteration 25 the best fitness is 0.013863216266173754']
# ['At iteration 26 the best fitness is 0.013863216266173754']
# ['At iteration 27 the best fitness is 0.013863216266173754']
# ['At iteration 28 the best fitness is 0.01377079482439926']
# ['At iteration 29 the best fitness is 0.01377079482439926']
#       Selected: 166/541 (30.7%), Fitness: 0.0138, Time: 704.9s
#       Modality: D=19%, Sk=35%, V=28%
#     Test Acc: 75.00%, F1: 71.01%, Features: 166/541 (30.7%), Model: 0.447MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.023382624768946397']
# ['At iteration 1 the best fitness is 0.019593345656192238']
# ['At iteration 2 the best fitness is 0.019593345656192238']
# ['At iteration 3 the best fitness is 0.019593345656192238']
# ['At iteration 4 the best fitness is 0.019593345656192238']
# ['At iteration 5 the best fitness is 0.019038817005545286']
# ['At iteration 6 the best fitness is 0.019038817005545286']
# ['At iteration 7 the best fitness is 0.019038817005545286']
# ['At iteration 8 the best fitness is 0.019038817005545286']
# ['At iteration 9 the best fitness is 0.019038817005545286']
# ['At iteration 10 the best fitness is 0.019038817005545286']
# ['At iteration 11 the best fitness is 0.01645101663585952']
# ['At iteration 12 the best fitness is 0.01645101663585952']
# ['At iteration 13 the best fitness is 0.01645101663585952']
# ['At iteration 14 the best fitness is 0.01645101663585952']
# ['At iteration 15 the best fitness is 0.01645101663585952']
# ['At iteration 16 the best fitness is 0.01645101663585952']
# ['At iteration 17 the best fitness is 0.016173752310536044']
# ['At iteration 18 the best fitness is 0.016173752310536044']
# ['At iteration 19 the best fitness is 0.016173752310536044']
# ['At iteration 20 the best fitness is 0.016173752310536044']
# ['At iteration 21 the best fitness is 0.016173752310536044']
# ['At iteration 22 the best fitness is 0.016173752310536044']
# ['At iteration 23 the best fitness is 0.016173752310536044']
# ['At iteration 24 the best fitness is 0.016173752310536044']
# ['At iteration 25 the best fitness is 0.016173752310536044']
# ['At iteration 26 the best fitness is 0.016173752310536044']
# ['At iteration 27 the best fitness is 0.016173752310536044']
# ['At iteration 28 the best fitness is 0.016173752310536044']
# ['At iteration 29 the best fitness is 0.016173752310536044']
#       Selected: 184/541 (34.0%), Fitness: 0.0162, Time: 974.2s
#       Modality: D=32%, Sk=32%, V=36%
#     Test Acc: 68.52%, F1: 63.73%, Features: 184/541 (34.0%), Model: 0.546MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.022643253234750464']
# ['At iteration 1 the best fitness is 0.021996303142329022']
# ['At iteration 2 the best fitness is 0.02134935304990758']
# ['At iteration 3 the best fitness is 0.02134935304990758']
# ['At iteration 4 the best fitness is 0.02134935304990758']
# ['At iteration 5 the best fitness is 0.02134935304990758']
# ['At iteration 6 the best fitness is 0.02134935304990758']
# ['At iteration 7 the best fitness is 0.02134935304990758']
# ['At iteration 8 the best fitness is 0.02134935304990758']
# ['At iteration 9 the best fitness is 0.02134935304990758']
# ['At iteration 10 the best fitness is 0.02134935304990758']
# ['At iteration 11 the best fitness is 0.02134935304990758']
# ['At iteration 12 the best fitness is 0.02134935304990758']
# ['At iteration 13 the best fitness is 0.02134935304990758']
# ['At iteration 14 the best fitness is 0.02134935304990758']
# ['At iteration 15 the best fitness is 0.02134935304990758']
# ['At iteration 16 the best fitness is 0.020887245841035122']
# ['At iteration 17 the best fitness is 0.020887245841035122']
# ['At iteration 18 the best fitness is 0.020887245841035122']
# ['At iteration 19 the best fitness is 0.020887245841035122']
# ['At iteration 20 the best fitness is 0.020887245841035122']
# ['At iteration 21 the best fitness is 0.020887245841035122']
# ['At iteration 22 the best fitness is 0.020887245841035122']
# ['At iteration 23 the best fitness is 0.020887245841035122']
# ['At iteration 24 the best fitness is 0.020887245841035122']
# ['At iteration 25 the best fitness is 0.020887245841035122']
# ['At iteration 26 the best fitness is 0.020887245841035122']
# ['At iteration 27 the best fitness is 0.020887245841035122']
# ['At iteration 28 the best fitness is 0.020887245841035122']
# ['At iteration 29 the best fitness is 0.020887245841035122']
#       Selected: 234/541 (43.3%), Fitness: 0.0209, Time: 784.9s
#       Modality: D=41%, Sk=42%, V=44%
#     Test Acc: 73.15%, F1: 68.65%, Features: 234/541 (43.3%), Model: 0.873MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02467652495378928']
# ['At iteration 2 the best fitness is 0.023659889094269873']
# ['At iteration 3 the best fitness is 0.023659889094269873']
# ['At iteration 4 the best fitness is 0.023659889094269873']
# ['At iteration 5 the best fitness is 0.023659889094269873']
# ['At iteration 6 the best fitness is 0.023659889094269873']
# ['At iteration 7 the best fitness is 0.023659889094269873']
# ['At iteration 8 the best fitness is 0.023659889094269873']
# ['At iteration 9 the best fitness is 0.02310536044362292']
# ['At iteration 10 the best fitness is 0.02310536044362292']
# ['At iteration 11 the best fitness is 0.02310536044362292']
# ['At iteration 12 the best fitness is 0.02310536044362292']
# ['At iteration 13 the best fitness is 0.02310536044362292']
# ['At iteration 14 the best fitness is 0.02310536044362292']
# ['At iteration 15 the best fitness is 0.02310536044362292']
# ['At iteration 16 the best fitness is 0.02310536044362292']
# ['At iteration 17 the best fitness is 0.02310536044362292']
# ['At iteration 18 the best fitness is 0.02310536044362292']
# ['At iteration 19 the best fitness is 0.022828096118299446']
# ['At iteration 20 the best fitness is 0.022458410351201483']
# ['At iteration 21 the best fitness is 0.022458410351201483']
# ['At iteration 22 the best fitness is 0.022458410351201483']
# ['At iteration 23 the best fitness is 0.022458410351201483']
# ['At iteration 24 the best fitness is 0.022181146025878007']
# ['At iteration 25 the best fitness is 0.022181146025878007']
# ['At iteration 26 the best fitness is 0.022181146025878007']
# ['At iteration 27 the best fitness is 0.021996303142329022']
# ['At iteration 28 the best fitness is 0.02181146025878004']
# ['At iteration 29 the best fitness is 0.02181146025878004']
#       Selected: 261/541 (48.2%), Fitness: 0.0218, Time: 733.4s
#       Modality: D=59%, Sk=46%, V=48%
#     Test Acc: 71.30%, F1: 67.04%, Features: 261/541 (48.2%), Model: 1.051MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023475046210720888']
# ['At iteration 2 the best fitness is 0.023475046210720888']
# ['At iteration 3 the best fitness is 0.023475046210720888']
# ['At iteration 4 the best fitness is 0.023382624768946397']
# ['At iteration 5 the best fitness is 0.022828096118299446']
# ['At iteration 6 the best fitness is 0.022828096118299446']
# ['At iteration 7 the best fitness is 0.022828096118299446']
# ['At iteration 8 the best fitness is 0.022828096118299446']
# ['At iteration 9 the best fitness is 0.02190388170055453']
# ['At iteration 10 the best fitness is 0.02190388170055453']
# ['At iteration 11 the best fitness is 0.02190388170055453']
# ['At iteration 12 the best fitness is 0.02190388170055453']
# ['At iteration 13 the best fitness is 0.02190388170055453']
# ['At iteration 14 the best fitness is 0.02190388170055453']
# ['At iteration 15 the best fitness is 0.021719038817005546']
# ...
# ['At iteration 16 the best fitness is 0.017097966728280962']
# ['At iteration 17 the best fitness is 0.017097966728280962']
# ['At iteration 18 the best fitness is 0.017097966728280962']
# ['At iteration 19 the best fitness is 0.017097966728280962']
# ['At iteration 20 the best fitness is 0.017097966728280962']
# ['At iteration 21 the best fitness is 0.017097966728280962']
# ['At iteration 22 the best fitness is 0.017097966728280962']
# ['At iteration 23 the best fitness is 0.017097966728280962']
# ['At iteration 24 the best fitness is 0.01534195933456562']
# ['At iteration 25 the best fitness is 0.015249537892791126']
# ['At iteration 26 the best fitness is 0.01414048059149723']
# ['At iteration 27 the best fitness is 0.01414048059149723']
# ['At iteration 28 the best fitness is 0.01414048059149723']
# ['At iteration 29 the best fitness is 0.014048059149722736']
#       Selected: 165/541 (30.5%), Fitness: 0.0140, Time: 1008.8s
#       Modality: D=27%, Sk=28%, V=33%
#     Test Acc: 81.31%, F1: 77.19%, Features: 165/541 (30.5%), Model: 0.442MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024861367837338263']
# ['At iteration 1 the best fitness is 0.022643253234750464']
# ['At iteration 2 the best fitness is 0.022643253234750464']
# ['At iteration 3 the best fitness is 0.022643253234750464']
# ['At iteration 4 the best fitness is 0.022643253234750464']
# ['At iteration 5 the best fitness is 0.022643253234750464']
# ['At iteration 6 the best fitness is 0.022643253234750464']
# ['At iteration 7 the best fitness is 0.022088724584103513']
# ['At iteration 8 the best fitness is 0.022088724584103513']
# ['At iteration 9 the best fitness is 0.022088724584103513']
# ['At iteration 10 the best fitness is 0.022088724584103513']
# ['At iteration 11 the best fitness is 0.022088724584103513']
# ['At iteration 12 the best fitness is 0.021996303142329022']
# ['At iteration 13 the best fitness is 0.021996303142329022']
# ['At iteration 14 the best fitness is 0.021996303142329022']
# ['At iteration 15 the best fitness is 0.021996303142329022']
# ['At iteration 16 the best fitness is 0.021996303142329022']
# ['At iteration 17 the best fitness is 0.021996303142329022']
# ['At iteration 18 the best fitness is 0.021996303142329022']
# ['At iteration 19 the best fitness is 0.021626617375231055']
# ['At iteration 20 the best fitness is 0.021626617375231055']
# ['At iteration 21 the best fitness is 0.021626617375231055']
# ['At iteration 22 the best fitness is 0.021626617375231055']
# ['At iteration 23 the best fitness is 0.021626617375231055']
# ['At iteration 24 the best fitness is 0.021626617375231055']
# ['At iteration 25 the best fitness is 0.02134935304990758']
# ['At iteration 26 the best fitness is 0.02134935304990758']
# ['At iteration 27 the best fitness is 0.02134935304990758']
# ['At iteration 28 the best fitness is 0.02134935304990758']
# ['At iteration 29 the best fitness is 0.02125693160813309']
#       Selected: 243/541 (44.9%), Fitness: 0.0213, Time: 796.4s
#       Modality: D=49%, Sk=45%, V=44%
#     Test Acc: 79.44%, F1: 75.14%, Features: 243/541 (44.9%), Model: 0.940MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023382624768946397']
# ['At iteration 2 the best fitness is 0.023382624768946397']
# ['At iteration 3 the best fitness is 0.023382624768946397']
# ['At iteration 4 the best fitness is 0.023382624768946397']
# ['At iteration 5 the best fitness is 0.023290203327171907']
# ['At iteration 6 the best fitness is 0.023290203327171907']
# ['At iteration 7 the best fitness is 0.023290203327171907']
# ['At iteration 8 the best fitness is 0.023197781885397412']
# ['At iteration 9 the best fitness is 0.023197781885397412']
# ['At iteration 10 the best fitness is 0.02301293900184843']
# ['At iteration 11 the best fitness is 0.02255083179297597']
# ['At iteration 12 the best fitness is 0.02255083179297597']
# ['At iteration 13 the best fitness is 0.02255083179297597']
# ['At iteration 14 the best fitness is 0.02255083179297597']
# ['At iteration 15 the best fitness is 0.02255083179297597']
# ['At iteration 16 the best fitness is 0.022273567467652494']
# ['At iteration 17 the best fitness is 0.022273567467652494']
# ['At iteration 18 the best fitness is 0.022273567467652494']
# ['At iteration 19 the best fitness is 0.022088724584103513']
# ['At iteration 20 the best fitness is 0.022088724584103513']
# ['At iteration 21 the best fitness is 0.022088724584103513']
# ['At iteration 22 the best fitness is 0.021072088724584104']
# ['At iteration 23 the best fitness is 0.021072088724584104']
# ['At iteration 24 the best fitness is 0.021072088724584104']
# ['At iteration 25 the best fitness is 0.021072088724584104']
# ['At iteration 26 the best fitness is 0.021072088724584104']
# ['At iteration 27 the best fitness is 0.021072088724584104']
# ['At iteration 28 the best fitness is 0.021072088724584104']
# ['At iteration 29 the best fitness is 0.021072088724584104']
#       Selected: 250/541 (46.2%), Fitness: 0.0211, Time: 743.2s
#       Modality: D=46%, Sk=44%, V=48%
#     Test Acc: 80.37%, F1: 76.75%, Features: 250/541 (46.2%), Model: 0.994MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023844731977818855']
# ['At iteration 2 the best fitness is 0.023659889094269873']
# ['At iteration 3 the best fitness is 0.022828096118299446']
# ['At iteration 4 the best fitness is 0.022828096118299446']
# ['At iteration 5 the best fitness is 0.022735674676524955']
# ['At iteration 6 the best fitness is 0.022735674676524955']
# ['At iteration 7 the best fitness is 0.02190388170055453']
# ['At iteration 8 the best fitness is 0.02190388170055453']
# ['At iteration 9 the best fitness is 0.02181146025878004']
# ['At iteration 10 the best fitness is 0.021719038817005546']
# ['At iteration 11 the best fitness is 0.02134935304990758']
# ['At iteration 12 the best fitness is 0.020887245841035122']
# ['At iteration 13 the best fitness is 0.020517560073937152']
# ['At iteration 14 the best fitness is 0.02014787430683919']
# ['At iteration 15 the best fitness is 0.02014787430683919']
# ['At iteration 16 the best fitness is 0.02014787430683919']
# ['At iteration 17 the best fitness is 0.02014787430683919']
# ['At iteration 18 the best fitness is 0.02014787430683919']
# ['At iteration 19 the best fitness is 0.02014787430683919']
# ['At iteration 20 the best fitness is 0.019870609981515713']
# ['At iteration 21 the best fitness is 0.019870609981515713']
# ['At iteration 22 the best fitness is 0.019870609981515713']
# ['At iteration 23 the best fitness is 0.019870609981515713']
# ['At iteration 24 the best fitness is 0.01968576709796673']
# ['At iteration 25 the best fitness is 0.019316081330868762']
# ['At iteration 26 the best fitness is 0.019316081330868762']
# ['At iteration 27 the best fitness is 0.019316081330868762']
# ['At iteration 28 the best fitness is 0.019316081330868762']
# ['At iteration 29 the best fitness is 0.019316081330868762']
# ['At iteration 30 the best fitness is 0.019316081330868762']
#       Selected: 232/541 (42.9%), Fitness: 0.0193, Time: 760.6s
#       Modality: D=54%, Sk=43%, V=41%
#     Test Acc: 81.31%, F1: 77.64%, Features: 232/541 (42.9%), Model: 0.859MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.025415896487985215']
# ['At iteration 2 the best fitness is 0.024399260628465806']
# ['At iteration 3 the best fitness is 0.024399260628465806']
# ['At iteration 4 the best fitness is 0.023752310536044364']
# ['At iteration 5 the best fitness is 0.022458410351201483']
# ['At iteration 6 the best fitness is 0.022458410351201483']
# ['At iteration 7 the best fitness is 0.022458410351201483']
# ['At iteration 8 the best fitness is 0.022458410351201483']
# ['At iteration 9 the best fitness is 0.022458410351201483']
# ['At iteration 10 the best fitness is 0.022458410351201483']
# ['At iteration 11 the best fitness is 0.022181146025878007']
# ['At iteration 12 the best fitness is 0.022181146025878007']
# ['At iteration 13 the best fitness is 0.022088724584103513']
# ['At iteration 14 the best fitness is 0.022088724584103513']
# ['At iteration 15 the best fitness is 0.022088724584103513']
# ['At iteration 16 the best fitness is 0.022088724584103513']
# ['At iteration 17 the best fitness is 0.022088724584103513']
# ['At iteration 18 the best fitness is 0.022088724584103513']
# ['At iteration 19 the best fitness is 0.022088724584103513']
# ['At iteration 20 the best fitness is 0.021996303142329022']
# ['At iteration 21 the best fitness is 0.021719038817005546']
# ['At iteration 22 the best fitness is 0.021719038817005546']
# ['At iteration 23 the best fitness is 0.021534195933456565']
# ['At iteration 24 the best fitness is 0.021534195933456565']
# ['At iteration 25 the best fitness is 0.021534195933456565']
# ['At iteration 26 the best fitness is 0.02144177449168207']
# ['At iteration 27 the best fitness is 0.02144177449168207']
# ['At iteration 28 the best fitness is 0.02144177449168207']
# ['At iteration 29 the best fitness is 0.02144177449168207']
# ['At iteration 30 the best fitness is 0.02144177449168207']
#       Selected: 246/541 (45.5%), Fitness: 0.0214, Time: 730.5s
#       Modality: D=49%, Sk=47%, V=44%
#     Test Acc: 82.24%, F1: 78.44%, Features: 246/541 (45.5%), Model: 0.963MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024029574861367836']
# ['At iteration 1 the best fitness is 0.018853974121996304']
# ['At iteration 2 the best fitness is 0.018853974121996304']
# ['At iteration 3 the best fitness is 0.017744916820702405']
# ['At iteration 4 the best fitness is 0.016358595194085026']
# ['At iteration 5 the best fitness is 0.016358595194085026']
# ['At iteration 6 the best fitness is 0.015064695009242145']
# ['At iteration 7 the best fitness is 0.015064695009242145']
# ['At iteration 8 the best fitness is 0.015064695009242145']
# ['At iteration 9 the best fitness is 0.015064695009242145']
# ['At iteration 10 the best fitness is 0.01155268022181146']
# ['At iteration 11 the best fitness is 0.010998151571164511']
# ['At iteration 12 the best fitness is 0.010998151571164511']
# ['At iteration 13 the best fitness is 0.010998151571164511']
# ['At iteration 14 the best fitness is 0.010998151571164511']
# ['At iteration 15 the best fitness is 0.010998151571164511']
# ['At iteration 16 the best fitness is 0.010998151571164511']
# ['At iteration 17 the best fitness is 0.010998151571164511']
# ['At iteration 18 the best fitness is 0.010998151571164511']
# ['At iteration 19 the best fitness is 0.010998151571164511']
# ['At iteration 20 the best fitness is 0.010998151571164511']
# ['At iteration 21 the best fitness is 0.010998151571164511']
# ['At iteration 22 the best fitness is 0.010998151571164511']
# ['At iteration 23 the best fitness is 0.010998151571164511']
# ['At iteration 24 the best fitness is 0.010998151571164511']
# ['At iteration 25 the best fitness is 0.010998151571164511']
# ['At iteration 26 the best fitness is 0.010998151571164511']
# ['At iteration 27 the best fitness is 0.010998151571164511']
# ['At iteration 28 the best fitness is 0.010998151571164511']
# ['At iteration 29 the best fitness is 0.010998151571164511']
#       Selected: 125/541 (23.1%), Fitness: 0.0110, Time: 740.1s
#       Modality: D=19%, Sk=22%, V=24%
#     Test Acc: 91.59%, F1: 90.42%, Features: 125/541 (23.1%), Model: 0.259MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.023197781885397412']
# ['At iteration 2 the best fitness is 0.023197781885397412']
# ['At iteration 3 the best fitness is 0.023197781885397412']
# ['At iteration 4 the best fitness is 0.023197781885397412']
# ['At iteration 5 the best fitness is 0.023197781885397412']
# ['At iteration 6 the best fitness is 0.023197781885397412']
# ['At iteration 7 the best fitness is 0.023197781885397412']
# ['At iteration 8 the best fitness is 0.022643253234750464']
# ['At iteration 9 the best fitness is 0.022458410351201483']
# ['At iteration 10 the best fitness is 0.021534195933456565']
# ['At iteration 11 the best fitness is 0.021534195933456565']
# ['At iteration 12 the best fitness is 0.021534195933456565']
# ['At iteration 13 the best fitness is 0.021534195933456565']
# ['At iteration 14 the best fitness is 0.021534195933456565']
# ['At iteration 15 the best fitness is 0.02125693160813309']
# ['At iteration 16 the best fitness is 0.02125693160813309']
# ['At iteration 17 the best fitness is 0.02125693160813309']
# ['At iteration 18 the best fitness is 0.021164510166358595']
# ['At iteration 19 the best fitness is 0.021164510166358595']
# ['At iteration 20 the best fitness is 0.021164510166358595']
# ['At iteration 21 the best fitness is 0.021164510166358595']
# ['At iteration 22 the best fitness is 0.021164510166358595']
# ['At iteration 23 the best fitness is 0.021164510166358595']
# ['At iteration 24 the best fitness is 0.021164510166358595']
# ['At iteration 25 the best fitness is 0.021164510166358595']
# ['At iteration 26 the best fitness is 0.021164510166358595']
# ['At iteration 27 the best fitness is 0.021164510166358595']
# ['At iteration 28 the best fitness is 0.021164510166358595']
# ['At iteration 29 the best fitness is 0.021164510166358595']
#       Selected: 253/541 (46.8%), Fitness: 0.0212, Time: 1884.0s
#       Modality: D=41%, Sk=47%, V=48%
#     Test Acc: 85.05%, F1: 82.78%, Features: 253/541 (46.8%), Model: 1.017MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.022828096118299446']
# ['At iteration 1 the best fitness is 0.020517560073937152']
# ['At iteration 2 the best fitness is 0.01802218114602588']
# ['At iteration 3 the best fitness is 0.01802218114602588']
# ['At iteration 4 the best fitness is 0.01802218114602588']
# ['At iteration 5 the best fitness is 0.014695009242144178']
# ['At iteration 6 the best fitness is 0.014695009242144178']
# ['At iteration 7 the best fitness is 0.013863216266173754']
# ['At iteration 8 the best fitness is 0.013863216266173754']
# ['At iteration 9 the best fitness is 0.013216266173752312']
# ['At iteration 10 the best fitness is 0.013216266173752312']
# ['At iteration 11 the best fitness is 0.01312384473197782']
# ['At iteration 12 the best fitness is 0.01312384473197782']
# ['At iteration 13 the best fitness is 0.01312384473197782']
# ['At iteration 14 the best fitness is 0.01312384473197782']
# ['At iteration 15 the best fitness is 0.01312384473197782']
# ['At iteration 16 the best fitness is 0.01312384473197782']
# ['At iteration 17 the best fitness is 0.01312384473197782']
# ['At iteration 18 the best fitness is 0.01312384473197782']
# ['At iteration 19 the best fitness is 0.01312384473197782']
# ['At iteration 20 the best fitness is 0.01312384473197782']
# ['At iteration 21 the best fitness is 0.012384473197781886']
# ['At iteration 22 the best fitness is 0.012199630314232903']
# ['At iteration 23 the best fitness is 0.012199630314232903']
# ['At iteration 24 the best fitness is 0.012199630314232903']
# ['At iteration 25 the best fitness is 0.011460258780036968']
# ['At iteration 26 the best fitness is 0.011460258780036968']
# ['At iteration 27 the best fitness is 0.011460258780036968']
# ['At iteration 28 the best fitness is 0.010628465804066544']
# ['At iteration 29 the best fitness is 0.010628465804066544']
#       Selected: 120/541 (22.2%), Fitness: 0.0106, Time: 349.2s
#       Modality: D=24%, Sk=24%, V=20%
#     Test Acc: 85.98%, F1: 82.02%, Features: 120/541 (22.2%), Model: 0.239MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_3_no_sensor/all_results_per_fold.csv
# Shape: (144, 26)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            85.1852          100.0000       81.6295          81.6295              82.2399           85.1852                541             541               100.0000       0.0000         11.1446         11.1446        417307           1.5978                 3.5538                  3.5538                 0.0000        27.4688             100.0000              37                100.0000                240             100.0000             264
# 1      baseline     2            71.2963          100.0000       65.8025          65.8025              64.9780           71.2963                541             541               100.0000       0.0000         10.3481         10.3481        417307           1.5978                 3.5538                  3.5538                 0.0000        27.4688             100.0000              37                100.0000                240             100.0000             264
# 2      baseline     3            75.0000          100.0000       70.1833          70.1833              68.8139           75.0000                541             541               100.0000       0.0000         10.2791         10.2791        417307           1.5978                 3.5538                  3.5538                 0.0000        27.4688             100.0000              37                100.0000                240             100.0000             264
# 3      baseline     4            66.6667          100.0000       62.5525          62.5525              63.7831           66.6667                541             541               100.0000       0.0000         10.1947         10.1947        417307           1.5978                 3.5538                  3.5538                 0.0000        27.4688             100.0000              37                100.0000                240             100.0000             264
# 4      baseline     5            73.1481           98.6667       65.0423          65.0423              61.5114           73.1481                541             541               100.0000       0.0000         10.5067         10.5067        417307           1.5978                 3.5538                  3.5538                 0.0000        27.4688             100.0000              37                100.0000                240             100.0000             264
# 5      baseline     6            67.2897          100.0000       63.8907          63.5532              66.2520           67.5926                541             541               100.0000       0.0000         10.4839         10.4839        417307           1.5978                 3.5538                  3.5538                 0.0000        27.4688             100.0000              37                100.0000                240             100.0000             264
# 6      baseline     7            63.5514           98.6667       55.6106          55.6630              56.5168           63.2716                541             541               100.0000       0.0000         10.5014         10.5014        417307           1.5978                 3.5538                  3.5538                 0.0000        27.4688             100.0000              37                100.0000                240             100.0000             264
# 7      baseline     8            83.1776          100.0000       79.8765          79.6885              80.8642           83.3333                541             541               100.0000       0.0000         10.5399         10.5399        417307           1.5978                 3.5538                  3.5538                 0.0000        27.4688             100.0000              37                100.0000                240             100.0000             264
# 8   mutual_info     1            81.4815          100.0000       79.0123          79.0123              77.7778           81.4815                270             541                49.9076       3.0816         12.2864         15.3681        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797               2.7027               1                  2.0833                  5             100.0000             264
# 9   mutual_info     2            62.9630          100.0000       56.6002          56.6002              53.4979           62.9630                270             541                49.9076       3.0131         12.7550         15.7683        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797               2.7027               1                  2.0833                  5             100.0000             264
# 10  mutual_info     3            78.7037          100.0000       73.9282          73.9282              73.7213           78.7037                270             541                49.9076       3.0947         12.8904         15.9851        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797               0.0000               0                  2.5000                  6             100.0000             264
# 11  mutual_info     4            62.9630          100.0000       57.0146          57.0146              54.5855           62.9630                270             541                49.9076       3.0799         12.3132         15.3932        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797               2.7027               1                  2.0833                  5             100.0000             264
# 12  mutual_info     5            70.3704          100.0000       61.1111          61.1111              56.7901           70.3704                270             541                49.9076       3.0597         12.7104         15.7702        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797               0.0000               0                  2.5000                  6             100.0000             264
# 13  mutual_info     6            55.1402          100.0000       46.1199          45.6164              42.5926           55.5556                270             541                49.9076       3.0297         12.7713         15.8011        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797               2.7027               1                  2.0833                  5             100.0000             264
# 14  mutual_info     7            67.2897          100.0000       57.6319          58.1705              53.9683           66.6667                270             541                49.9076       3.0657         12.7767         15.8426        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797               2.7027               1                  2.0833                  5             100.0000             264
# 15  mutual_info     8            81.3084          100.0000       75.9259          75.7009              73.4568           81.4815                270             541                49.9076       3.0710         12.5296         15.6008        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797               0.0000               0                  2.5000                  6             100.0000             264
# 16          rfe     1            83.3333          100.0000       79.9140          79.9140              80.2822           83.3333                270             541                49.9076       0.5413         13.3092         13.8507        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797              16.2162               6                 40.0000                 96              63.6364             168
# 17          rfe     2            73.1481          100.0000       69.2548          69.2548              71.9459           73.1481                270             541                49.9076       0.5469         12.6206         13.1677        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797              18.9189               7                 39.5833                 95              63.6364             168
# 18          rfe     3            73.1481          100.0000       70.2406          70.2406              72.0547           73.1481                270             541                49.9076       0.5434         12.3487         12.8925        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797              24.3243               9                 43.3333                104              59.4697             157
# 19          rfe     4            72.2222          100.0000       67.6436          67.6436              67.1164           72.2222                270             541                49.9076       0.5384         12.3402         12.8789        278555           1.0685                 3.5538                  1.7736                50.0924        23.6797              18.9189               7                 43.7500                105              59.8485             158

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              73.16              7.75              68.07              8.83                  541.00                      100.00              0.00                10.50                10.50           417307.0                  1.60                        0.00               27.47
# mutual_info              70.03              9.73              63.42             11.56                  270.00                       49.91              3.06                12.63                15.69           278555.0                  1.07                       50.09               23.68
#         rfe              77.71              7.00              73.42              7.88                  270.00                       49.91              0.54                12.68                13.22           278555.0                  1.07                       50.09               23.68
#       lasso              74.57              5.70              69.62              5.92                  270.00                       49.91              0.07                12.84                12.92           278555.0                  1.07                       50.09               23.68
#    meta_BAT              74.22              7.75              69.80              7.83                  260.88                       48.22            795.69                12.85               808.54           267451.0                  1.03                       51.78               23.43
#     meta_CS              73.52              6.01              68.80              6.99                  249.50                       46.12           1568.89                12.78              1581.67           256679.0                  0.98                       53.88               23.18
#     meta_DE              73.62              8.78              69.83              9.15                  243.25                       44.96            791.46                12.80               804.27           245439.0                  0.94                       55.04               22.92
#    meta_FFA              74.34              7.97              70.62              9.13                  264.12                       48.82            762.56                12.65               775.21           270958.0                  1.04                       51.18               23.51
#     meta_GA              72.84              8.56              67.58             10.25                  253.62                       46.88            751.84                12.27               764.11           266287.0                  1.02                       53.12               23.40
#    meta_GWO              73.86             10.92              70.27             11.40                  189.00                       34.94            715.00                11.99               726.99           153008.0                  0.59                       65.06               20.81
#    meta_HHO              72.12              7.70              67.52              8.16                  194.88                       36.02            998.52                12.39              1010.91           162373.0                  0.62                       63.98               21.02
#   meta_JAYA              74.69              8.36              70.55              8.39                  246.75                       45.61            781.03                12.44               793.47           250476.0                  0.96                       54.39               23.04
#    meta_MFO              72.24              6.85              67.54              6.93                  251.62                       46.51            740.89                12.68               753.58           256381.0                  0.98                       53.49               23.17
#    meta_MVO              75.49              4.66              71.51              5.15                  246.12                       45.49            758.60                12.69               771.29           247174.0                  0.95                       54.51               22.96
#    meta_PSO              73.75              9.33              69.03              9.97                  238.75                       44.13            740.25                11.94               752.19           237026.0                  0.91                       55.87               22.73
#    meta_SCA              73.64             10.50              68.90             12.13                  144.88                       26.78            724.45                12.52               736.97            91837.0                  0.35                       73.22               19.40
#    meta_SSA              75.14              7.06              70.55              8.14                  251.25                       46.44           1888.68                12.15              1900.82           259816.0                  1.00                       53.56               23.25
#    meta_WOA              72.83              6.92              67.95              7.06                  203.00                       37.52            664.74                11.77               676.51           170724.0                  0.66                       62.48               21.21

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 70.03% vs Baseline: 73.16%
#   Paired t-test: t=-1.6408, p=0.1448
#   Wilcoxon test: W=10.5000, p=0.3281
#   -> worse, Not significant
#
# RFE vs BASELINE:
#   Method: 77.71% vs Baseline: 73.16%
#   Paired t-test: t=1.9850, p=0.0875
#   Wilcoxon test: W=5.0000, p=0.0781
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 74.57% vs Baseline: 73.16%
#   Paired t-test: t=0.7119, p=0.4996
#   Wilcoxon test: W=12.0000, p=0.8125
#   -> better, Not significant
#
# META_BAT vs BASELINE:
#   Method: 74.22% vs Baseline: 73.16%
#   Paired t-test: t=0.3903, p=0.7079
#   Wilcoxon test: W=15.0000, p=0.7422
#   -> better, Not significant
#
# META_CS vs BASELINE:
#   Method: 73.52% vs Baseline: 73.16%
#   Paired t-test: t=0.1413, p=0.8916
#   Wilcoxon test: W=16.0000, p=0.8203
#   -> better, Not significant
#
# META_DE vs BASELINE:
#   Method: 73.62% vs Baseline: 73.16%
#   Paired t-test: t=0.2019, p=0.8457
#   Wilcoxon test: W=16.0000, p=0.8438
#   -> better, Not significant
#
# META_FFA vs BASELINE:
#   Method: 74.34% vs Baseline: 73.16%
#   Paired t-test: t=0.4046, p=0.6978
#   Wilcoxon test: W=10.0000, p=0.5781
#   -> better, Not significant
#
# META_GA vs BASELINE:
#   Method: 72.84% vs Baseline: 73.16%
#   Paired t-test: t=-0.1125, p=0.9136
#   Wilcoxon test: W=8.5000, p=0.4062
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 73.86% vs Baseline: 73.16%
#   Paired t-test: t=0.2425, p=0.8154
#   Wilcoxon test: W=17.0000, p=0.9453
#   -> better, Not significant
#
# META_HHO vs BASELINE:
#   Method: 72.12% vs Baseline: 73.16%
#   Paired t-test: t=-0.8908, p=0.4026
#   Wilcoxon test: W=9.0000, p=0.4375
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 74.69% vs Baseline: 73.16%
#   Paired t-test: t=0.4785, p=0.6469
#   Wilcoxon test: W=16.0000, p=0.8203
#   -> better, Not significant
#
# META_MFO vs BASELINE:
#   Method: 72.24% vs Baseline: 73.16%
#   Paired t-test: t=-0.5065, p=0.6281
#   Wilcoxon test: W=10.0000, p=0.5469
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 75.49% vs Baseline: 73.16%
#   Paired t-test: t=1.2588, p=0.2485
#   Wilcoxon test: W=9.0000, p=0.2422
#   -> better, Not significant
#
# META_PSO vs BASELINE:
#   Method: 73.75% vs Baseline: 73.16%
#   Paired t-test: t=0.2533, p=0.8073
#   Wilcoxon test: W=18.0000, p=1.0000
#   -> better, Not significant
#
# META_SCA vs BASELINE:
#   Method: 73.64% vs Baseline: 73.16%
#   Paired t-test: t=0.2149, p=0.8359
#   Wilcoxon test: W=15.0000, p=0.7422
#   -> better, Not significant
#
# META_SSA vs BASELINE:
#   Method: 75.14% vs Baseline: 73.16%
#   Paired t-test: t=1.3594, p=0.2162
#   Wilcoxon test: W=7.0000, p=0.2812
#   -> better, Not significant
#
# META_WOA vs BASELINE:
#   Method: 72.83% vs Baseline: 73.16%
#   Paired t-test: t=-0.1312, p=0.8993
#   Wilcoxon test: W=17.5000, p=0.9766
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_3_no_sensor
#
# Per-method folders:
#   results_3_no_sensor/baseline/ (16 files)
#   results_3_no_sensor/mutual_info/ (16 files)
#   results_3_no_sensor/rfe/ (16 files)
#   results_3_no_sensor/lasso/ (16 files)
#   results_3_no_sensor/meta_BAT/ (16 files)
#   results_3_no_sensor/meta_CS/ (16 files)
#   results_3_no_sensor/meta_DE/ (16 files)
#   results_3_no_sensor/meta_FFA/ (16 files)
#   results_3_no_sensor/meta_GA/ (16 files)
#   results_3_no_sensor/meta_GWO/ (16 files)
#   results_3_no_sensor/meta_HHO/ (16 files)
#   results_3_no_sensor/meta_JAYA/ (16 files)
#   results_3_no_sensor/meta_MFO/ (16 files)
#   results_3_no_sensor/meta_MVO/ (16 files)
#   results_3_no_sensor/meta_PSO/ (16 files)
#   results_3_no_sensor/meta_SCA/ (16 files)
#   results_3_no_sensor/meta_SSA/ (16 files)
#   results_3_no_sensor/meta_WOA/ (16 files)
#
# Plots directory: results_3_no_sensor/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 77.71% ± 7.00% (Features: 49.9%)
#   meta_MVO            : 75.49% ± 4.66% (Features: 45.5%)
#   meta_SSA            : 75.14% ± 7.06% (Features: 46.4%)
#   meta_JAYA           : 74.69% ± 8.36% (Features: 45.6%)
#   lasso               : 74.57% ± 5.70% (Features: 49.9%)
