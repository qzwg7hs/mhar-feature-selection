# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (25% Data Loss)
#
# This notebook is **identical** to the original, with one addition:
# **25% of extracted feature values are randomly set to 0** to simulate corrupted/lost data.
#
# This tests the robustness of all 17 feature selection methods under data loss conditions.
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_25_lost")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 37
#   sensor: 54
#   skeleton: 240
#   video: 264
#   TOTAL: 595

# %% [markdown]
# ## Simulate 25% Data Loss on Extracted Features
#
# Randomly set 25% of all extracted feature values to **0** (simulating corrupted/lost data).
# This is applied directly on the already-extracted feature vectors before any further processing.
#
# **Why this works on extracted features:**
# - Simulates feature-level data loss (transmission errors, storage corruption, partial sensor dropout)
# - Commonly used in the literature for robustness testing
# - Each individual scalar value in each sample's feature vector has a 25% chance of being zeroed out

# %%
# ============================================================================
# SIMULATE 10% DATA LOSS ON EXTRACTED FEATURES
# ============================================================================
# Randomly zero out 25% of feature values across ALL samples and ALL modalities.
# This corrupts the already-extracted features in-place before the pipeline runs.
# ============================================================================

DATA_LOSS_RATIO = 0.25
CORRUPTION_SEED = 42    # For reproducibility

rng = np.random.RandomState(CORRUPTION_SEED)

modalities = ['depth_feat', 'sensor_feat', 'skeleton_feat', 'video_feat']

total_values = 0
total_corrupted = 0
per_modality_stats = {m: {'total': 0, 'corrupted': 0} for m in modalities}

for sample in X_feat:
    for mod in modalities:
        feat = sample[mod]
        n = feat.shape[0]
        # Create a random mask: True means this value gets zeroed out
        loss_mask = rng.rand(n) < DATA_LOSS_RATIO
        n_corrupted = np.sum(loss_mask)
        feat[loss_mask] = 0.0  # Set lost values to 0
        
        total_values += n
        total_corrupted += n_corrupted
        per_modality_stats[mod]['total'] += n
        per_modality_stats[mod]['corrupted'] += n_corrupted

print(f"{'='*60}")
print(f"DATA CORRUPTION APPLIED: {DATA_LOSS_RATIO*100:.0f}% random data loss")
print(f"{'='*60}")
print(f"Total feature values:   {total_values:,}")
print(f"Values zeroed out:      {total_corrupted:,} ({total_corrupted/total_values*100:.2f}%)")
print(f"")
print(f"Per-modality breakdown:")
for mod in modalities:
    s = per_modality_stats[mod]
    print(f"  {mod:15s}: {s['corrupted']:>6,} / {s['total']:>8,} zeroed ({s['corrupted']/s['total']*100:.2f}%)")
print(f"{'='*60}")
# Out:
# ============================================================
# DATA CORRUPTION APPLIED: 25% random data loss
# ============================================================
# Total feature values:   512,295
# Values zeroed out:      128,108 (25.01%)
#
# Per-modality breakdown:
#   depth_feat     :  7,952 /   31,857 zeroed (24.96%)
#   sensor_feat    : 11,552 /   46,494 zeroed (24.85%)
#   skeleton_feat  : 51,770 /  206,640 zeroed (25.05%)
#   video_feat     : 56,834 /  227,304 zeroed (25.00%)
# ============================================================

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 70.37%, F1: 68.08%, Features: 595/595 (100.0%), Model: 1.703MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 297/595 (49.9%), Time: 3.4s
#     Test Acc: 65.74%, F1: 64.65%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 297/595 (49.9%), Time: 0.5s
#     Test Acc: 80.56%, F1: 79.72%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 297/595 (49.9%), Time: 0.1s
#     Test Acc: 57.41%, F1: 54.02%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2712016806722689']
# ['At iteration 1 the best fitness is 0.2712016806722689']
# ['At iteration 2 the best fitness is 0.2451120448179271']
# ['At iteration 3 the best fitness is 0.2451120448179271']
# ['At iteration 4 the best fitness is 0.21977871148459382']
# ['At iteration 5 the best fitness is 0.21977871148459382']
# ['At iteration 6 the best fitness is 0.21977871148459382']
# ['At iteration 7 the best fitness is 0.21977871148459382']
# ['At iteration 8 the best fitness is 0.21977871148459382']
# ['At iteration 9 the best fitness is 0.21977871148459382']
# ['At iteration 10 the best fitness is 0.21977871148459382']
# ['At iteration 11 the best fitness is 0.21977871148459382']
# ['At iteration 12 the best fitness is 0.21977871148459382']
# ['At iteration 13 the best fitness is 0.21977871148459382']
# ['At iteration 14 the best fitness is 0.21977871148459382']
# ['At iteration 15 the best fitness is 0.21977871148459382']
# ['At iteration 16 the best fitness is 0.21977871148459382']
# ['At iteration 17 the best fitness is 0.21977871148459382']
# ['At iteration 18 the best fitness is 0.21977871148459382']
# ['At iteration 19 the best fitness is 0.21977871148459382']
# ['At iteration 20 the best fitness is 0.21977871148459382']
# ['At iteration 21 the best fitness is 0.21977871148459382']
# ['At iteration 22 the best fitness is 0.21977871148459382']
# ['At iteration 23 the best fitness is 0.21977871148459382']
# ['At iteration 24 the best fitness is 0.21977871148459382']
# ['At iteration 25 the best fitness is 0.21977871148459382']
# ['At iteration 26 the best fitness is 0.21977871148459382']
# ['At iteration 27 the best fitness is 0.21977871148459382']
# ['At iteration 28 the best fitness is 0.21977871148459382']
# ['At iteration 29 the best fitness is 0.21977871148459382']
#       Selected: 272/595 (45.7%), Fitness: 0.2198, Time: 500.8s
#       Modality: D=43%, S=44%, Sk=46%, V=46%
#     Test Acc: 68.52%, F1: 64.80%, Features: 272/595 (45.7%), Model: 1.072MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2753193277310924']
# ['At iteration 10 the best fitness is 0.2595434173669468']
# ['At iteration 20 the best fitness is 0.24071148459383757']
#       Selected: 304/595 (51.1%), Fitness: 0.2405, Time: 1228.9s
#       Modality: D=57%, S=57%, Sk=51%, V=49%
#     Test Acc: 60.19%, F1: 56.75%, Features: 304/595 (51.1%), Model: 1.135MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.27719887955182076']
# ['At iteration 2 the best fitness is 0.2715378151260504']
# ['At iteration 3 the best fitness is 0.23928291316526612']
# ['At iteration 4 the best fitness is 0.23928291316526612']
# ['At iteration 5 the best fitness is 0.23928291316526612']
# ['At iteration 6 the best fitness is 0.23928291316526612']
# ['At iteration 7 the best fitness is 0.23903081232492998']
# ['At iteration 8 the best fitness is 0.23903081232492998']
# ['At iteration 9 the best fitness is 0.23903081232492998']
# ['At iteration 10 the best fitness is 0.23903081232492998']
# ['At iteration 11 the best fitness is 0.23903081232492998']
# ['At iteration 12 the best fitness is 0.23903081232492998']
# ['At iteration 13 the best fitness is 0.23903081232492998']
# ['At iteration 14 the best fitness is 0.23903081232492998']
# ['At iteration 15 the best fitness is 0.23521848739495796']
# ['At iteration 16 the best fitness is 0.22103921568627452']
# ['At iteration 17 the best fitness is 0.22053501400560224']
# ['At iteration 18 the best fitness is 0.21969467787114846']
# ['At iteration 19 the best fitness is 0.21504201680672264']
# ['At iteration 20 the best fitness is 0.21504201680672264']
# ['At iteration 21 the best fitness is 0.21504201680672264']
# ['At iteration 22 the best fitness is 0.21504201680672264']
# ['At iteration 23 the best fitness is 0.21504201680672264']
# ['At iteration 24 the best fitness is 0.21504201680672264']
# ['At iteration 25 the best fitness is 0.2140336134453781']
# ['At iteration 26 the best fitness is 0.2140336134453781']
# ['At iteration 27 the best fitness is 0.2140336134453781']
# ['At iteration 28 the best fitness is 0.2140336134453781']
# ['At iteration 29 the best fitness is 0.2074481792717087']
# ['At iteration 30 the best fitness is 0.2074481792717087']
#       Selected: 298/595 (50.1%), Fitness: 0.2074, Time: 661.9s
#       Modality: D=59%, S=61%, Sk=50%, V=46%
#     Test Acc: 62.96%, F1: 60.03%, Features: 298/595 (50.1%), Model: 1.123MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2792997198879552']
# ['At iteration 1 the best fitness is 0.27829131652661065']
# ['At iteration 2 the best fitness is 0.26172829131652664']
# ['At iteration 3 the best fitness is 0.2724621848739496']
# ['At iteration 4 the best fitness is 0.26621288515406155']
# ['At iteration 5 the best fitness is 0.2719579831932773']
# ['At iteration 6 the best fitness is 0.2417198879551821']
# ['At iteration 7 the best fitness is 0.2346302521008403']
# ['At iteration 8 the best fitness is 0.2532941176470588']
# ['At iteration 9 the best fitness is 0.2470448179271708']
# ['At iteration 10 the best fitness is 0.2599635854341737']
# ['At iteration 11 the best fitness is 0.22204761904761905']
# ['At iteration 12 the best fitness is 0.24729691876750692']
# ['At iteration 13 the best fitness is 0.2597114845938376']
# ['At iteration 14 the best fitness is 0.24071148459383757']
# ['At iteration 15 the best fitness is 0.24721288515406156']
# ['At iteration 16 the best fitness is 0.2532941176470588']
# ['At iteration 17 the best fitness is 0.2532941176470588']
# ['At iteration 18 the best fitness is 0.2342941176470588']
# ['At iteration 19 the best fitness is 0.2532941176470588']
# ['At iteration 20 the best fitness is 0.2342100840336134']
# ['At iteration 21 the best fitness is 0.24679271708683467']
# ['At iteration 22 the best fitness is 0.2342100840336134']
# ['At iteration 23 the best fitness is 0.2342941176470588']
# ['At iteration 24 the best fitness is 0.25312605042016806']
# ['At iteration 25 the best fitness is 0.24687675070028003']
# ['At iteration 26 the best fitness is 0.23412605042016804']
# ['At iteration 27 the best fitness is 0.24045938375350143']
# ['At iteration 28 the best fitness is 0.2594593837535014']
# ['At iteration 29 the best fitness is 0.24045938375350143']
#       Selected: 310/595 (52.1%), Fitness: 0.2405, Time: 639.2s
#       Modality: D=65%, S=46%, Sk=48%, V=55%
#     Test Acc: 62.96%, F1: 60.96%, Features: 310/595 (52.1%), Model: 1.147MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.29205042016806726
# At iteration 2 the best fitness is 0.27288235294117646
# At iteration 3 the best fitness is 0.2592913165266107
# At iteration 4 the best fitness is 0.2719579831932773
# At iteration 5 the best fitness is 0.2481372549019607
# At iteration 6 the best fitness is 0.23521848739495796
# At iteration 7 the best fitness is 0.24155182072829134
# At iteration 8 the best fitness is 0.24079551820728293
# At iteration 9 the best fitness is 0.25346218487394956
# At iteration 10 the best fitness is 0.24712885154061617
# At iteration 11 the best fitness is 0.23673109243697477
# At iteration 12 the best fitness is 0.23454621848739493
# At iteration 13 the best fitness is 0.22964145658263307
# At iteration 14 the best fitness is 0.23395798319327726
# At iteration 15 the best fitness is 0.21613445378151255
# At iteration 16 the best fitness is 0.23605882352941174
# At iteration 17 the best fitness is 0.2108095238095238
# At iteration 18 the best fitness is 0.2401232492997199
# At iteration 19 the best fitness is 0.2303137254901961
# At iteration 20 the best fitness is 0.2108095238095238
# At iteration 21 the best fitness is 0.23006162464985996
# At iteration 22 the best fitness is 0.20287955182072828
# At iteration 23 the best fitness is 0.22770868347338938
# At iteration 24 the best fitness is 0.20153501400560223
# At iteration 25 the best fitness is 0.2361428571428571
# At iteration 26 the best fitness is 0.22246778711484594
# At iteration 27 the best fitness is 0.2241484593837535
# At iteration 28 the best fitness is 0.2222156862745098
# At iteration 29 the best fitness is 0.23521848739495796
# At iteration 30 the best fitness is 0.223812324929972
#       Selected: 302/595 (50.8%), Fitness: 0.2238, Time: 641.1s
#       Modality: D=46%, S=56%, Sk=51%, V=50%
#     Test Acc: 60.19%, F1: 58.41%, Features: 302/595 (50.8%), Model: 1.131MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2804761904761905']
# ['At iteration 1 the best fitness is 0.2804761904761905']
# ['At iteration 2 the best fitness is 0.2804761904761905']
# ['At iteration 3 the best fitness is 0.2804761904761905']
# ['At iteration 4 the best fitness is 0.24645658263305315']
# ['At iteration 5 the best fitness is 0.24645658263305315']
# ['At iteration 6 the best fitness is 0.23303361344537812']
# ['At iteration 7 the best fitness is 0.22485154061624651']
# ['At iteration 8 the best fitness is 0.22485154061624651']
# ['At iteration 9 the best fitness is 0.22485154061624651']
# ['At iteration 10 the best fitness is 0.22485154061624651']
# ['At iteration 11 the best fitness is 0.21868627450980394']
# ['At iteration 12 the best fitness is 0.21868627450980394']
# ['At iteration 13 the best fitness is 0.21201680672268902']
# ['At iteration 14 the best fitness is 0.21201680672268902']
# ['At iteration 15 the best fitness is 0.21201680672268902']
# ['At iteration 16 the best fitness is 0.21201680672268902']
# ['At iteration 17 the best fitness is 0.21201680672268902']
# ['At iteration 18 the best fitness is 0.21193277310924363']
# ['At iteration 19 the best fitness is 0.21193277310924363']
# ['At iteration 20 the best fitness is 0.19977030812324928']
# ['At iteration 21 the best fitness is 0.19977030812324928']
# ['At iteration 22 the best fitness is 0.19977030812324928']
# ['At iteration 23 the best fitness is 0.19977030812324928']
# ['At iteration 24 the best fitness is 0.19977030812324928']
# ['At iteration 25 the best fitness is 0.19977030812324928']
# ['At iteration 26 the best fitness is 0.19977030812324928']
# ['At iteration 27 the best fitness is 0.19977030812324928']
# ['At iteration 28 the best fitness is 0.187187675070028']
# ['At iteration 29 the best fitness is 0.187187675070028']
#       Selected: 263/595 (44.2%), Fitness: 0.1872, Time: 635.5s
#       Modality: D=38%, S=59%, Sk=43%, V=43%
#     Test Acc: 69.44%, F1: 67.49%, Features: 263/595 (44.2%), Model: 1.055MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.2720420168067227']
# ['At iteration 1 the best fitness is 0.2720420168067227']
# ['At iteration 2 the best fitness is 0.2720420168067227']
# ['At iteration 3 the best fitness is 0.2720420168067227']
# ['At iteration 4 the best fitness is 0.2720420168067227']
# ['At iteration 5 the best fitness is 0.2720420168067227']
# ['At iteration 6 the best fitness is 0.2720420168067227']
# ['At iteration 7 the best fitness is 0.2720420168067227']
# ['At iteration 8 the best fitness is 0.2720420168067227']
# ['At iteration 9 the best fitness is 0.2720420168067227']
# ['At iteration 10 the best fitness is 0.262422969187675']
# ['At iteration 11 the best fitness is 0.24325490196078434']
# ['At iteration 12 the best fitness is 0.2380140056022409']
# ['At iteration 13 the best fitness is 0.23663865546218482']
# ['At iteration 14 the best fitness is 0.23663865546218482']
# ['At iteration 15 the best fitness is 0.23655462184873943']
# ['At iteration 16 the best fitness is 0.23655462184873943']
# ['At iteration 17 the best fitness is 0.23655462184873943']
# ['At iteration 18 the best fitness is 0.23655462184873943']
# ['At iteration 19 the best fitness is 0.23655462184873943']
# ['At iteration 20 the best fitness is 0.23655462184873943']
# ['At iteration 21 the best fitness is 0.23655462184873943']
# ['At iteration 22 the best fitness is 0.23655462184873943']
# ['At iteration 23 the best fitness is 0.23655462184873943']
# ['At iteration 24 the best fitness is 0.23655462184873943']
# ['At iteration 25 the best fitness is 0.23655462184873943']
# ['At iteration 26 the best fitness is 0.23655462184873943']
# ['At iteration 27 the best fitness is 0.22414005602240894']
# ['At iteration 28 the best fitness is 0.22414005602240894']
# ['At iteration 29 the best fitness is 0.22414005602240894']
#       Selected: 557/595 (93.6%), Fitness: 0.2241, Time: 763.8s
#       Modality: D=92%, S=94%, Sk=95%, V=93%
#     Test Acc: 66.67%, F1: 63.78%, Features: 557/595 (93.6%), Model: 1.629MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.28072829131652666']
# ['At iteration 1 the best fitness is 0.2551428571428571']
# ['At iteration 2 the best fitness is 0.2532941176470588']
# ['At iteration 3 the best fitness is 0.2532941176470588']
# ['At iteration 4 the best fitness is 0.2405434173669468']
# ['At iteration 5 the best fitness is 0.2405434173669468']
# ['At iteration 6 the best fitness is 0.2405434173669468']
# ['At iteration 7 the best fitness is 0.2405434173669468']
# ['At iteration 8 the best fitness is 0.2405434173669468']
# ['At iteration 9 the best fitness is 0.2405434173669468']
# ['At iteration 10 the best fitness is 0.21579831932773105']
# ['At iteration 11 the best fitness is 0.21579831932773105']
# ['At iteration 12 the best fitness is 0.21579831932773105']
# ['At iteration 13 the best fitness is 0.21579831932773105']
# ['At iteration 14 the best fitness is 0.21579831932773105']
# ['At iteration 15 the best fitness is 0.21579831932773105']
# ['At iteration 16 the best fitness is 0.21579831932773105']
# ['At iteration 17 the best fitness is 0.21579831932773105']
# ['At iteration 18 the best fitness is 0.21579831932773105']
# ['At iteration 19 the best fitness is 0.21579831932773105']
# ['At iteration 20 the best fitness is 0.21579831932773105']
# ['At iteration 21 the best fitness is 0.21579831932773105']
# ['At iteration 22 the best fitness is 0.21579831932773105']
# ['At iteration 23 the best fitness is 0.21579831932773105']
# ['At iteration 24 the best fitness is 0.21579831932773105']
# ['At iteration 25 the best fitness is 0.21579831932773105']
# ['At iteration 26 the best fitness is 0.21579831932773105']
# ['At iteration 27 the best fitness is 0.21579831932773105']
# ['At iteration 28 the best fitness is 0.21579831932773105']
# ['At iteration 29 the best fitness is 0.21579831932773105']
#       Selected: 297/595 (49.9%), Fitness: 0.2158, Time: 643.5s
#       Modality: D=54%, S=65%, Sk=47%, V=49%
#     Test Acc: 64.81%, F1: 61.59%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.28454061624649857']
# ['At iteration 2 the best fitness is 0.28454061624649857']
# ['At iteration 3 the best fitness is 0.27372268907563024']
# ['At iteration 4 the best fitness is 0.26013165266106447']
# ['At iteration 5 the best fitness is 0.26013165266106447']
# ['At iteration 6 the best fitness is 0.26013165266106447']
# ['At iteration 7 the best fitness is 0.24922969187675065']
# ['At iteration 8 the best fitness is 0.24922969187675065']
# ['At iteration 9 the best fitness is 0.23370588235294115']
# ['At iteration 10 the best fitness is 0.23370588235294115']
# ['At iteration 11 the best fitness is 0.22854901960784316']
# ['At iteration 12 the best fitness is 0.22854901960784316']
# ['At iteration 13 the best fitness is 0.22854901960784316']
# ['At iteration 14 the best fitness is 0.22787675070028013']
# ['At iteration 15 the best fitness is 0.20195518207282911']
# ['At iteration 16 the best fitness is 0.20195518207282911']
# ['At iteration 17 the best fitness is 0.20195518207282911']
# ['At iteration 18 the best fitness is 0.20195518207282911']
# ['At iteration 19 the best fitness is 0.20195518207282911']
# ['At iteration 20 the best fitness is 0.20195518207282911']
# ['At iteration 21 the best fitness is 0.20195518207282911']
# ['At iteration 22 the best fitness is 0.20195518207282911']
# ['At iteration 23 the best fitness is 0.1898767507002801']
# ['At iteration 24 the best fitness is 0.1898767507002801']
# ['At iteration 25 the best fitness is 0.1898767507002801']
# ['At iteration 26 the best fitness is 0.1898767507002801']
# ['At iteration 27 the best fitness is 0.1898767507002801']
# ['At iteration 28 the best fitness is 0.1894565826330532']
# ['At iteration 29 the best fitness is 0.1894565826330532']
#       Selected: 294/595 (49.4%), Fitness: 0.1895, Time: 610.7s
#       Modality: D=51%, S=65%, Sk=50%, V=45%
#     Test Acc: 70.37%, F1: 69.11%, Features: 294/595 (49.4%), Model: 1.115MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2871456582633053']
# ['At iteration 2 the best fitness is 0.24796918767506995']
# ['At iteration 3 the best fitness is 0.23479831932773107']
# ['At iteration 4 the best fitness is 0.23479831932773107']
# ['At iteration 5 the best fitness is 0.22972549019607846']
# ['At iteration 6 the best fitness is 0.22972549019607846']
# ['At iteration 7 the best fitness is 0.22955742296918769']
# ['At iteration 8 the best fitness is 0.2287170868347339']
# ['At iteration 9 the best fitness is 0.2287170868347339']
# ['At iteration 10 the best fitness is 0.22280392156862744']
# ['At iteration 11 the best fitness is 0.22280392156862744']
# ['At iteration 12 the best fitness is 0.2155462184873949']
# ['At iteration 13 the best fitness is 0.2155462184873949']
# ['At iteration 14 the best fitness is 0.21529411764705877']
# ['At iteration 15 the best fitness is 0.2088767507002801']
# ['At iteration 16 the best fitness is 0.20870868347338936']
# ['At iteration 17 the best fitness is 0.19612605042016812']
# ['At iteration 18 the best fitness is 0.19612605042016812']
# ['At iteration 19 the best fitness is 0.18937254901960784']
# ['At iteration 20 the best fitness is 0.18937254901960784']
# ['At iteration 21 the best fitness is 0.18937254901960784']
# ['At iteration 22 the best fitness is 0.18937254901960784']
# ['At iteration 23 the best fitness is 0.18937254901960784']
# ['At iteration 24 the best fitness is 0.18937254901960784']
# ['At iteration 25 the best fitness is 0.18937254901960784']
# ['At iteration 26 the best fitness is 0.18937254901960784']
# ['At iteration 27 the best fitness is 0.18937254901960784']
# ['At iteration 28 the best fitness is 0.18937254901960784']
# ['At iteration 29 the best fitness is 0.18937254901960784']
# ['At iteration 30 the best fitness is 0.18937254901960784']
#       Selected: 303/595 (50.9%), Fitness: 0.1894, Time: 640.5s
#       Modality: D=68%, S=63%, Sk=47%, V=50%
#     Test Acc: 69.44%, F1: 66.19%, Features: 303/595 (50.9%), Model: 1.133MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.27812324929971993']
# ['At iteration 2 the best fitness is 0.2774509803921569']
# ['At iteration 3 the best fitness is 0.2594593837535014']
# ['At iteration 4 the best fitness is 0.239703081232493']
# ['At iteration 5 the best fitness is 0.239703081232493']
# ['At iteration 6 the best fitness is 0.23454621848739493']
# ['At iteration 7 the best fitness is 0.23454621848739493']
# ['At iteration 8 the best fitness is 0.2291372549019608']
# ['At iteration 9 the best fitness is 0.2291372549019608']
# ['At iteration 10 the best fitness is 0.2291372549019608']
# ['At iteration 11 the best fitness is 0.2291372549019608']
# ['At iteration 12 the best fitness is 0.2291372549019608']
# ['At iteration 13 the best fitness is 0.2267843137254902']
# ['At iteration 14 the best fitness is 0.2267843137254902']
# ['At iteration 15 the best fitness is 0.2218795518207283']
# ['At iteration 16 the best fitness is 0.2167226890756302']
# ['At iteration 17 the best fitness is 0.2167226890756302']
# ['At iteration 18 the best fitness is 0.1973865546218488']
# ['At iteration 19 the best fitness is 0.1973865546218488']
# ['At iteration 20 the best fitness is 0.1973865546218488']
# ['At iteration 21 the best fitness is 0.1973865546218488']
# ['At iteration 22 the best fitness is 0.1973865546218488']
# ['At iteration 23 the best fitness is 0.1957899159663866']
# ['At iteration 24 the best fitness is 0.1957899159663866']
# ['At iteration 25 the best fitness is 0.1957899159663866']
# ['At iteration 26 the best fitness is 0.1957899159663866']
# ['At iteration 27 the best fitness is 0.1957899159663866']
# ['At iteration 28 the best fitness is 0.1957899159663866']
# ['At iteration 29 the best fitness is 0.1957899159663866']
# ['At iteration 30 the best fitness is 0.1957899159663866']
#       Selected: 292/595 (49.1%), Fitness: 0.1958, Time: 637.6s
#       Modality: D=57%, S=48%, Sk=51%, V=47%
#     Test Acc: 63.89%, F1: 62.06%, Features: 292/595 (49.1%), Model: 1.111MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.27321848739495797']
# ['At iteration 1 the best fitness is 0.27321848739495797']
# ['At iteration 2 the best fitness is 0.25794677871148464']
# ['At iteration 3 the best fitness is 0.25794677871148464']
# ['At iteration 4 the best fitness is 0.25794677871148464']
# ['At iteration 5 the best fitness is 0.25794677871148464']
# ['At iteration 6 the best fitness is 0.25794677871148464']
# ['At iteration 7 the best fitness is 0.25794677871148464']
# ['At iteration 8 the best fitness is 0.25794677871148464']
# ['At iteration 9 the best fitness is 0.2575574229691876']
# ['At iteration 10 the best fitness is 0.2575574229691876']
# ['At iteration 11 the best fitness is 0.2575574229691876']
# ['At iteration 12 the best fitness is 0.2575574229691876']
# ['At iteration 13 the best fitness is 0.2575574229691876']
# ['At iteration 14 the best fitness is 0.2575574229691876']
# ['At iteration 15 the best fitness is 0.2541960784313725']
# ['At iteration 16 the best fitness is 0.2541960784313725']
# ['At iteration 17 the best fitness is 0.2541960784313725']
# ['At iteration 18 the best fitness is 0.2541960784313725']
# ['At iteration 19 the best fitness is 0.2541960784313725']
# ['At iteration 20 the best fitness is 0.2541960784313725']
# ['At iteration 21 the best fitness is 0.2541960784313725']
# ['At iteration 22 the best fitness is 0.2541960784313725']
# ['At iteration 23 the best fitness is 0.2541960784313725']
# ['At iteration 24 the best fitness is 0.2541960784313725']
# ['At iteration 25 the best fitness is 0.2541960784313725']
# ['At iteration 26 the best fitness is 0.2541960784313725']
# ['At iteration 27 the best fitness is 0.2541960784313725']
# ['At iteration 28 the best fitness is 0.2541960784313725']
# ['At iteration 29 the best fitness is 0.2541960784313725']
#       Selected: 177/595 (29.7%), Fitness: 0.2542, Time: 620.8s
#       Modality: D=32%, S=43%, Sk=28%, V=29%
#     Test Acc: 63.89%, F1: 62.18%, Features: 177/595 (29.7%), Model: 0.507MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2585350140056023']
# ['At iteration 2 the best fitness is 0.23336974789915962']
# ['At iteration 3 the best fitness is 0.23336974789915962']
# ['At iteration 4 the best fitness is 0.23336974789915962']
# ['At iteration 5 the best fitness is 0.23336974789915962']
# ['At iteration 6 the best fitness is 0.23336974789915962']
# ['At iteration 7 the best fitness is 0.23336974789915962']
# ['At iteration 8 the best fitness is 0.23336974789915962']
# ['At iteration 9 the best fitness is 0.23336974789915962']
# ['At iteration 10 the best fitness is 0.23336974789915962']
# ['At iteration 11 the best fitness is 0.23336974789915962']
# ['At iteration 12 the best fitness is 0.23336974789915962']
# ['At iteration 13 the best fitness is 0.23336974789915962']
# ['At iteration 14 the best fitness is 0.23336974789915962']
# ['At iteration 15 the best fitness is 0.23336974789915962']
# ['At iteration 16 the best fitness is 0.23336974789915962']
# ['At iteration 17 the best fitness is 0.23336974789915962']
# ['At iteration 18 the best fitness is 0.23336974789915962']
# ['At iteration 19 the best fitness is 0.23336974789915962']
# ['At iteration 20 the best fitness is 0.23336974789915962']
# ['At iteration 21 the best fitness is 0.23336974789915962']
# ['At iteration 22 the best fitness is 0.23336974789915962']
# ['At iteration 23 the best fitness is 0.23336974789915962']
# ['At iteration 24 the best fitness is 0.23336974789915962']
# ['At iteration 25 the best fitness is 0.23336974789915962']
# ['At iteration 26 the best fitness is 0.23336974789915962']
# ['At iteration 27 the best fitness is 0.23336974789915962']
# ['At iteration 28 the best fitness is 0.23336974789915962']
# ['At iteration 29 the best fitness is 0.23336974789915962']
#       Selected: 299/595 (50.3%), Fitness: 0.2334, Time: 1581.3s
#       Modality: D=62%, S=63%, Sk=50%, V=47%
#     Test Acc: 62.96%, F1: 61.15%, Features: 299/595 (50.3%), Model: 1.125MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.25363025210084034']
# ['At iteration 1 the best fitness is 0.25363025210084034']
# ['At iteration 2 the best fitness is 0.24494397759103634']
# ['At iteration 3 the best fitness is 0.23555462184873946']
# ['At iteration 4 the best fitness is 0.23555462184873946']
# ['At iteration 5 the best fitness is 0.23555462184873946']
# ['At iteration 6 the best fitness is 0.23555462184873946']
# ['At iteration 7 the best fitness is 0.22431652661064427']
# ['At iteration 8 the best fitness is 0.22431652661064427']
# ['At iteration 9 the best fitness is 0.22431652661064427']
# ['At iteration 10 the best fitness is 0.22431652661064427']
# ['At iteration 11 the best fitness is 0.22431652661064427']
# ['At iteration 12 the best fitness is 0.22431652661064427']
# ['At iteration 13 the best fitness is 0.22431652661064427']
# ['At iteration 14 the best fitness is 0.22431652661064427']
# ['At iteration 15 the best fitness is 0.22431652661064427']
# ['At iteration 16 the best fitness is 0.22431652661064427']
# ['At iteration 17 the best fitness is 0.22431652661064427']
# ['At iteration 18 the best fitness is 0.22431652661064427']
# ['At iteration 19 the best fitness is 0.22431652661064427']
# ['At iteration 20 the best fitness is 0.22431652661064427']
# ['At iteration 21 the best fitness is 0.22431652661064427']
# ['At iteration 22 the best fitness is 0.22431652661064427']
# ['At iteration 23 the best fitness is 0.22431652661064427']
# ['At iteration 24 the best fitness is 0.22431652661064427']
# ['At iteration 25 the best fitness is 0.22431652661064427']
# ['At iteration 26 the best fitness is 0.22431652661064427']
# ['At iteration 27 the best fitness is 0.22431652661064427']
# ['At iteration 28 the best fitness is 0.22431652661064427']
# ['At iteration 29 the best fitness is 0.22431652661064427']
#       Selected: 321/595 (53.9%), Fitness: 0.2243, Time: 624.2s
#       Modality: D=59%, S=57%, Sk=55%, V=51%
#     Test Acc: 66.67%, F1: 64.35%, Features: 321/595 (53.9%), Model: 1.168MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 73.15%, F1: 70.78%, Features: 595/595 (100.0%), Model: 1.703MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 297/595 (49.9%), Time: 3.3s
#     Test Acc: 59.26%, F1: 57.91%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 297/595 (49.9%), Time: 0.5s
#     Test Acc: 79.63%, F1: 78.08%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 297/595 (49.9%), Time: 0.1s
#     Test Acc: 57.41%, F1: 53.97%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2323613445378151']
# ['At iteration 1 the best fitness is 0.2323613445378151']
# ['At iteration 2 the best fitness is 0.2323613445378151']
# ['At iteration 3 the best fitness is 0.2323613445378151']
# ['At iteration 4 the best fitness is 0.22602801120448182']
# ['At iteration 5 the best fitness is 0.22602801120448182']
# ['At iteration 6 the best fitness is 0.22602801120448182']
# ['At iteration 7 the best fitness is 0.22602801120448182']
# ['At iteration 8 the best fitness is 0.22602801120448182']
# ['At iteration 9 the best fitness is 0.22602801120448182']
# ['At iteration 10 the best fitness is 0.22602801120448182']
# ['At iteration 11 the best fitness is 0.19436134453781517']
# ['At iteration 12 the best fitness is 0.19436134453781517']
# ['At iteration 13 the best fitness is 0.19436134453781517']
# ['At iteration 14 the best fitness is 0.19436134453781517']
# ['At iteration 15 the best fitness is 0.19436134453781517']
# ['At iteration 16 the best fitness is 0.19436134453781517']
# ['At iteration 17 the best fitness is 0.19436134453781517']
# ['At iteration 18 the best fitness is 0.19436134453781517']
# ['At iteration 19 the best fitness is 0.19436134453781517']
# ['At iteration 20 the best fitness is 0.19436134453781517']
# ['At iteration 21 the best fitness is 0.19436134453781517']
# ['At iteration 22 the best fitness is 0.19436134453781517']
# ['At iteration 23 the best fitness is 0.19436134453781517']
# ['At iteration 24 the best fitness is 0.19436134453781517']
# ['At iteration 25 the best fitness is 0.19436134453781517']
# ['At iteration 26 the best fitness is 0.19436134453781517']
# ['At iteration 27 the best fitness is 0.19436134453781517']
# ['At iteration 28 the best fitness is 0.19436134453781517']
# ['At iteration 29 the best fitness is 0.19436134453781517']
#       Selected: 289/595 (48.6%), Fitness: 0.1944, Time: 650.5s
#       Modality: D=38%, S=54%, Sk=47%, V=51%
#     Test Acc: 64.81%, F1: 61.64%, Features: 289/595 (48.6%), Model: 1.106MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2777871148459384']
# ['At iteration 10 the best fitness is 0.2401232492997199']
# ['At iteration 20 the best fitness is 0.23919887955182073']
#       Selected: 310/595 (52.1%), Fitness: 0.1966, Time: 1292.5s
#       Modality: D=54%, S=54%, Sk=52%, V=52%
#     Test Acc: 67.59%, F1: 67.27%, Features: 310/595 (52.1%), Model: 1.147MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2848767507002801']
# ['At iteration 2 the best fitness is 0.2653725490196078']
# ['At iteration 3 the best fitness is 0.23244537815126048']
# ['At iteration 4 the best fitness is 0.23244537815126048']
# ['At iteration 5 the best fitness is 0.23244537815126048']
# ['At iteration 6 the best fitness is 0.2267843137254902']
# ['At iteration 7 the best fitness is 0.2267843137254902']
# ['At iteration 8 the best fitness is 0.2267843137254902']
# ['At iteration 9 the best fitness is 0.20371988795518206']
# ['At iteration 10 the best fitness is 0.20371988795518206']
# ['At iteration 11 the best fitness is 0.20371988795518206']
# ['At iteration 12 the best fitness is 0.20371988795518206']
# ['At iteration 13 the best fitness is 0.20371988795518206']
# ['At iteration 14 the best fitness is 0.20371988795518206']
# ['At iteration 15 the best fitness is 0.20371988795518206']
# ['At iteration 16 the best fitness is 0.20371988795518206']
# ['At iteration 17 the best fitness is 0.2011988795518207']
# ['At iteration 18 the best fitness is 0.2011988795518207']
# ['At iteration 19 the best fitness is 0.2011988795518207']
# ['At iteration 20 the best fitness is 0.18979271708683473']
# ['At iteration 21 the best fitness is 0.18979271708683473']
# ['At iteration 22 the best fitness is 0.18979271708683473']
# ['At iteration 23 the best fitness is 0.18203081232492993']
# ['At iteration 24 the best fitness is 0.18203081232492993']
# ['At iteration 25 the best fitness is 0.18203081232492993']
# ['At iteration 26 the best fitness is 0.18203081232492993']
# ['At iteration 27 the best fitness is 0.18203081232492993']
# ['At iteration 28 the best fitness is 0.18203081232492993']
# ['At iteration 29 the best fitness is 0.17779831932773113']
# ['At iteration 30 the best fitness is 0.17779831932773113']
#       Selected: 304/595 (51.1%), Fitness: 0.1778, Time: 660.0s
#       Modality: D=38%, S=74%, Sk=54%, V=46%
#     Test Acc: 69.44%, F1: 67.02%, Features: 304/595 (51.1%), Model: 1.135MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2800560224089636']
# ['At iteration 1 the best fitness is 0.2743949579831933']
# ['At iteration 2 the best fitness is 0.2678095238095238']
# ['At iteration 3 the best fitness is 0.2665490196078431']
# ['At iteration 4 the best fitness is 0.2674733893557422']
# ['At iteration 5 the best fitness is 0.261140056022409']
# ['At iteration 6 the best fitness is 0.22955742296918769']
# ['At iteration 7 the best fitness is 0.24239215686274512']
# ['At iteration 8 the best fitness is 0.22280392156862744']
# ['At iteration 9 the best fitness is 0.2361428571428571']
# ['At iteration 10 the best fitness is 0.2672212885154061']
# ['At iteration 11 the best fitness is 0.25455462184873945']
# ['At iteration 12 the best fitness is 0.27330252100840335']
# ['At iteration 13 the best fitness is 0.2668851540616246']
# ['At iteration 14 the best fitness is 0.2858851540616246']
# ['At iteration 15 the best fitness is 0.25430252100840334']
# ['At iteration 16 the best fitness is 0.26705322128851533']
# ['At iteration 17 the best fitness is 0.2797198879551821']
# ['At iteration 18 the best fitness is 0.26055182072829136']
# ['At iteration 19 the best fitness is 0.27321848739495797']
# ['At iteration 20 the best fitness is 0.2795518207282913']
# ['At iteration 21 the best fitness is 0.2795518207282913']
# ['At iteration 22 the best fitness is 0.27321848739495797']
# ['At iteration 23 the best fitness is 0.27330252100840335']
# ['At iteration 24 the best fitness is 0.26696918767507']
# ['At iteration 25 the best fitness is 0.28596918767507']
# ['At iteration 26 the best fitness is 0.26696918767507']
# ['At iteration 27 the best fitness is 0.2796358543417367']
# ['At iteration 28 the best fitness is 0.26696918767507']
# ['At iteration 29 the best fitness is 0.27330252100840335']
#       Selected: 331/595 (55.6%), Fitness: 0.2733, Time: 638.5s
#       Modality: D=70%, S=67%, Sk=54%, V=53%
#     Test Acc: 71.30%, F1: 69.40%, Features: 331/595 (55.6%), Model: 1.188MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.24754901960784306
# At iteration 2 the best fitness is 0.22854901960784316
# At iteration 3 the best fitness is 0.24121568627450982
# At iteration 4 the best fitness is 0.2526218487394958
# At iteration 5 the best fitness is 0.24645658263305315
# At iteration 6 the best fitness is 0.2353865546218487
# At iteration 7 the best fitness is 0.24045938375350143
# At iteration 8 the best fitness is 0.22288795518207283
# At iteration 9 the best fitness is 0.2362268907563025
# At iteration 10 the best fitness is 0.22863305322128855
# At iteration 11 the best fitness is 0.23496638655462182
# At iteration 12 the best fitness is 0.22863305322128855
# At iteration 13 the best fitness is 0.24062745098039218
# At iteration 14 the best fitness is 0.2350504201680672
# At iteration 15 the best fitness is 0.22238375350140055
# At iteration 16 the best fitness is 0.2412997198879552
# At iteration 17 the best fitness is 0.21537815126050414
# At iteration 18 the best fitness is 0.23496638655462182
# At iteration 19 the best fitness is 0.22246778711484594
# At iteration 20 the best fitness is 0.20963305322128853
# At iteration 21 the best fitness is 0.24696078431372542
# At iteration 22 the best fitness is 0.22322408963585433
# At iteration 23 the best fitness is 0.23631092436974788
# At iteration 24 the best fitness is 0.22930532212885157
# At iteration 25 the best fitness is 0.20414005602240895
# At iteration 26 the best fitness is 0.22930532212885157
# At iteration 27 the best fitness is 0.21705882352941172
# At iteration 28 the best fitness is 0.22947338935574232
# At iteration 29 the best fitness is 0.22938935574229694
# At iteration 30 the best fitness is 0.21655462184873944
#       Selected: 310/595 (52.1%), Fitness: 0.2166, Time: 638.1s
#       Modality: D=49%, S=56%, Sk=56%, V=48%
#     Test Acc: 68.52%, F1: 67.99%, Features: 310/595 (52.1%), Model: 1.147MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2650364145658263']
# ['At iteration 1 the best fitness is 0.2650364145658263']
# ['At iteration 2 the best fitness is 0.23143697478991593']
# ['At iteration 3 the best fitness is 0.22543977591036418']
# ['At iteration 4 the best fitness is 0.22543977591036418']
# ['At iteration 5 the best fitness is 0.21193277310924363']
# ['At iteration 6 the best fitness is 0.20475910364145658']
# ['At iteration 7 the best fitness is 0.20475910364145658']
# ['At iteration 8 the best fitness is 0.16025770308123244']
# ['At iteration 9 the best fitness is 0.16025770308123244']
# ['At iteration 10 the best fitness is 0.16025770308123244']
# ['At iteration 11 the best fitness is 0.16025770308123244']
# ['At iteration 12 the best fitness is 0.16025770308123244']
# ['At iteration 13 the best fitness is 0.16025770308123244']
# ['At iteration 14 the best fitness is 0.16025770308123244']
# ['At iteration 15 the best fitness is 0.16025770308123244']
# ['At iteration 16 the best fitness is 0.16025770308123244']
# ['At iteration 17 the best fitness is 0.16025770308123244']
# ['At iteration 18 the best fitness is 0.16025770308123244']
# ['At iteration 19 the best fitness is 0.16025770308123244']
# ['At iteration 20 the best fitness is 0.16025770308123244']
# ['At iteration 21 the best fitness is 0.16025770308123244']
# ['At iteration 22 the best fitness is 0.16025770308123244']
# ['At iteration 23 the best fitness is 0.16025770308123244']
# ['At iteration 24 the best fitness is 0.16025770308123244']
# ['At iteration 25 the best fitness is 0.16025770308123244']
# ['At iteration 26 the best fitness is 0.16025770308123244']
# ['At iteration 27 the best fitness is 0.16025770308123244']
# ['At iteration 28 the best fitness is 0.16025770308123244']
# ['At iteration 29 the best fitness is 0.16025770308123244']
#       Selected: 247/595 (41.5%), Fitness: 0.1603, Time: 633.3s
#       Modality: D=35%, S=39%, Sk=42%, V=42%
#     Test Acc: 62.04%, F1: 61.13%, Features: 247/595 (41.5%), Model: 0.971MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.2528739495798319']
# ['At iteration 1 the best fitness is 0.2509411764705882']
# ['At iteration 2 the best fitness is 0.2509411764705882']
# ['At iteration 3 the best fitness is 0.2509411764705882']
# ['At iteration 4 the best fitness is 0.2509411764705882']
# ['At iteration 5 the best fitness is 0.23350700280112047']
# ['At iteration 6 the best fitness is 0.23350700280112047']
# ['At iteration 7 the best fitness is 0.23350700280112047']
# ['At iteration 8 the best fitness is 0.23350700280112047']
# ['At iteration 9 the best fitness is 0.23350700280112047']
# ['At iteration 10 the best fitness is 0.23350700280112047']
# ['At iteration 11 the best fitness is 0.23350700280112047']
# ['At iteration 12 the best fitness is 0.23350700280112047']
# ['At iteration 13 the best fitness is 0.23350700280112047']
# ['At iteration 14 the best fitness is 0.23350700280112047']
# ['At iteration 15 the best fitness is 0.23350700280112047']
# ['At iteration 16 the best fitness is 0.23350700280112047']
# ['At iteration 17 the best fitness is 0.23350700280112047']
# ['At iteration 18 the best fitness is 0.23350700280112047']
# ['At iteration 19 the best fitness is 0.23350700280112047']
# ['At iteration 20 the best fitness is 0.23350700280112047']
# ['At iteration 21 the best fitness is 0.23350700280112047']
# ['At iteration 22 the best fitness is 0.23350700280112047']
# ['At iteration 23 the best fitness is 0.23350700280112047']
# ['At iteration 24 the best fitness is 0.23350700280112047']
# ['At iteration 25 the best fitness is 0.23350700280112047']
# ['At iteration 26 the best fitness is 0.23350700280112047']
# ['At iteration 27 the best fitness is 0.23350700280112047']
# ['At iteration 28 the best fitness is 0.23350700280112047']
# ['At iteration 29 the best fitness is 0.23350700280112047']
#       Selected: 353/595 (59.3%), Fitness: 0.2335, Time: 896.3s
#       Modality: D=62%, S=59%, Sk=57%, V=61%
#     Test Acc: 73.15%, F1: 72.69%, Features: 353/595 (59.3%), Model: 1.231MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.27296638655462185']
# ['At iteration 1 the best fitness is 0.2599635854341737']
# ['At iteration 2 the best fitness is 0.25979551820728297']
# ['At iteration 3 the best fitness is 0.25979551820728297']
# ['At iteration 4 the best fitness is 0.25979551820728297']
# ['At iteration 5 the best fitness is 0.25979551820728297']
# ['At iteration 6 the best fitness is 0.25979551820728297']
# ['At iteration 7 the best fitness is 0.24721288515406156']
# ['At iteration 8 the best fitness is 0.2416358543417367']
# ['At iteration 9 the best fitness is 0.2416358543417367']
# ['At iteration 10 the best fitness is 0.24096358543417368']
# ['At iteration 11 the best fitness is 0.24096358543417368']
# ['At iteration 12 the best fitness is 0.24096358543417368']
# ['At iteration 13 the best fitness is 0.24096358543417368']
# ['At iteration 14 the best fitness is 0.24096358543417368']
# ['At iteration 15 the best fitness is 0.24037535014005604']
# ['At iteration 16 the best fitness is 0.24037535014005604']
# ['At iteration 17 the best fitness is 0.20963305322128853']
# ['At iteration 18 the best fitness is 0.20963305322128853']
# ['At iteration 19 the best fitness is 0.20963305322128853']
# ['At iteration 20 the best fitness is 0.20963305322128853']
# ['At iteration 21 the best fitness is 0.20963305322128853']
# ['At iteration 22 the best fitness is 0.20963305322128853']
# ['At iteration 23 the best fitness is 0.20963305322128853']
# ['At iteration 24 the best fitness is 0.20963305322128853']
# ['At iteration 25 the best fitness is 0.20963305322128853']
# ['At iteration 26 the best fitness is 0.20963305322128853']
# ['At iteration 27 the best fitness is 0.20963305322128853']
# ['At iteration 28 the best fitness is 0.20963305322128853']
# ['At iteration 29 the best fitness is 0.20963305322128853']
#       Selected: 303/595 (50.9%), Fitness: 0.2096, Time: 641.9s
#       Modality: D=51%, S=63%, Sk=52%, V=47%
#     Test Acc: 70.37%, F1: 67.72%, Features: 303/595 (50.9%), Model: 1.133MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2602997198879552']
# ['At iteration 2 the best fitness is 0.2602997198879552']
# ['At iteration 3 the best fitness is 0.2602997198879552']
# ['At iteration 4 the best fitness is 0.2602997198879552']
# ['At iteration 5 the best fitness is 0.2602997198879552']
# ['At iteration 6 the best fitness is 0.2163025210084033']
# ['At iteration 7 the best fitness is 0.2163025210084033']
# ['At iteration 8 the best fitness is 0.2163025210084033']
# ['At iteration 9 the best fitness is 0.2163025210084033']
# ['At iteration 10 the best fitness is 0.2163025210084033']
# ['At iteration 11 the best fitness is 0.2163025210084033']
# ['At iteration 12 the best fitness is 0.2163025210084033']
# ['At iteration 13 the best fitness is 0.2163025210084033']
# ['At iteration 14 the best fitness is 0.2163025210084033']
# ['At iteration 15 the best fitness is 0.2163025210084033']
# ['At iteration 16 the best fitness is 0.2163025210084033']
# ['At iteration 17 the best fitness is 0.19763865546218493']
# ['At iteration 18 the best fitness is 0.19763865546218493']
# ['At iteration 19 the best fitness is 0.19763865546218493']
# ['At iteration 20 the best fitness is 0.19763865546218493']
# ['At iteration 21 the best fitness is 0.19763865546218493']
# ['At iteration 22 the best fitness is 0.19763865546218493']
# ['At iteration 23 the best fitness is 0.19763865546218493']
# ['At iteration 24 the best fitness is 0.19763865546218493']
# ['At iteration 25 the best fitness is 0.1841316526610644']
# ['At iteration 26 the best fitness is 0.1841316526610644']
# ['At iteration 27 the best fitness is 0.1841316526610644']
# ['At iteration 28 the best fitness is 0.1841316526610644']
# ['At iteration 29 the best fitness is 0.1841316526610644']
#       Selected: 302/595 (50.8%), Fitness: 0.1841, Time: 618.1s
#       Modality: D=54%, S=63%, Sk=54%, V=45%
#     Test Acc: 65.74%, F1: 63.00%, Features: 302/595 (50.8%), Model: 1.131MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.25312605042016806']
# ['At iteration 2 the best fitness is 0.25304201680672267']
# ['At iteration 3 the best fitness is 0.24037535014005604']
# ['At iteration 4 the best fitness is 0.24037535014005604']
# ['At iteration 5 the best fitness is 0.24037535014005604']
# ['At iteration 6 the best fitness is 0.24037535014005604']
# ['At iteration 7 the best fitness is 0.24037535014005604']
# ['At iteration 8 the best fitness is 0.24037535014005604']
# ['At iteration 9 the best fitness is 0.24037535014005604']
# ['At iteration 10 the best fitness is 0.24037535014005604']
# ['At iteration 11 the best fitness is 0.208624649859944']
# ['At iteration 12 the best fitness is 0.208624649859944']
# ['At iteration 13 the best fitness is 0.208624649859944']
# ['At iteration 14 the best fitness is 0.208624649859944']
# ['At iteration 15 the best fitness is 0.208624649859944']
# ['At iteration 16 the best fitness is 0.208624649859944']
# ['At iteration 17 the best fitness is 0.208624649859944']
# ['At iteration 18 the best fitness is 0.208624649859944']
# ['At iteration 19 the best fitness is 0.208624649859944']
# ['At iteration 20 the best fitness is 0.208624649859944']
# ['At iteration 21 the best fitness is 0.208624649859944']
# ['At iteration 22 the best fitness is 0.208624649859944']
# ['At iteration 23 the best fitness is 0.208624649859944']
# ...
# ['At iteration 14 the best fitness is 0.24874789915966383']
# ['At iteration 15 the best fitness is 0.24874789915966383']
# ['At iteration 16 the best fitness is 0.24723529411764703']
# ['At iteration 17 the best fitness is 0.24199439775910367']
# ['At iteration 18 the best fitness is 0.23868627450980393']
# ['At iteration 19 the best fitness is 0.23868627450980393']
# ['At iteration 20 the best fitness is 0.23868627450980393']
# ['At iteration 21 the best fitness is 0.23868627450980393']
# ['At iteration 22 the best fitness is 0.23868627450980393']
# ['At iteration 23 the best fitness is 0.23868627450980393']
# ['At iteration 24 the best fitness is 0.23860224089635854']
# ['At iteration 25 the best fitness is 0.23860224089635854']
# ['At iteration 26 the best fitness is 0.23226890756302515']
# ['At iteration 27 the best fitness is 0.23226890756302515']
# ['At iteration 28 the best fitness is 0.23226890756302515']
# ['At iteration 29 the best fitness is 0.23226890756302515']
#       Selected: 501/595 (84.2%), Fitness: 0.2323, Time: 815.8s
#       Modality: D=86%, S=83%, Sk=85%, V=83%
#     Test Acc: 77.57%, F1: 75.92%, Features: 501/595 (84.2%), Model: 1.520MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2664649859943977']
# ['At iteration 1 the best fitness is 0.24138375350140057']
# ['At iteration 2 the best fitness is 0.24138375350140057']
# ['At iteration 3 the best fitness is 0.24096358543417368']
# ['At iteration 4 the best fitness is 0.24096358543417368']
# ['At iteration 5 the best fitness is 0.24096358543417368']
# ['At iteration 6 the best fitness is 0.24096358543417368']
# ['At iteration 7 the best fitness is 0.2346302521008403']
# ['At iteration 8 the best fitness is 0.2346302521008403']
# ['At iteration 9 the best fitness is 0.2346302521008403']
# ['At iteration 10 the best fitness is 0.2346302521008403']
# ['At iteration 11 the best fitness is 0.2346302521008403']
# ['At iteration 12 the best fitness is 0.2346302521008403']
# ['At iteration 13 the best fitness is 0.2346302521008403']
# ['At iteration 14 the best fitness is 0.2346302521008403']
# ['At iteration 15 the best fitness is 0.2346302521008403']
# ['At iteration 16 the best fitness is 0.2346302521008403']
# ['At iteration 17 the best fitness is 0.22829691876750702']
# ['At iteration 18 the best fitness is 0.22829691876750702']
# ['At iteration 19 the best fitness is 0.22829691876750702']
# ['At iteration 20 the best fitness is 0.22829691876750702']
# ['At iteration 21 the best fitness is 0.22196358543417366']
# ['At iteration 22 the best fitness is 0.22196358543417366']
# ['At iteration 23 the best fitness is 0.22196358543417366']
# ['At iteration 24 the best fitness is 0.2088767507002801']
# ['At iteration 25 the best fitness is 0.2088767507002801']
# ['At iteration 26 the best fitness is 0.2088767507002801']
# ['At iteration 27 the best fitness is 0.2088767507002801']
# ['At iteration 28 the best fitness is 0.2088767507002801']
# ['At iteration 29 the best fitness is 0.2088767507002801']
#       Selected: 301/595 (50.6%), Fitness: 0.2089, Time: 635.9s
#       Modality: D=54%, S=54%, Sk=52%, V=48%
#     Test Acc: 67.29%, F1: 64.92%, Features: 301/595 (50.6%), Model: 1.129MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.26512044817927166']
# ['At iteration 2 the best fitness is 0.26512044817927166']
# ['At iteration 3 the best fitness is 0.26512044817927166']
# ['At iteration 4 the best fitness is 0.26285154061624644']
# ['At iteration 5 the best fitness is 0.20946498599439778']
# ['At iteration 6 the best fitness is 0.20946498599439778']
# ['At iteration 7 the best fitness is 0.20946498599439778']
# ['At iteration 8 the best fitness is 0.20946498599439778']
# ['At iteration 9 the best fitness is 0.20946498599439778']
# ['At iteration 10 the best fitness is 0.20946498599439778']
# ['At iteration 11 the best fitness is 0.20946498599439778']
# ['At iteration 12 the best fitness is 0.20946498599439778']
# ['At iteration 13 the best fitness is 0.20946498599439778']
# ['At iteration 14 the best fitness is 0.20946498599439778']
# ['At iteration 15 the best fitness is 0.20946498599439778']
# ['At iteration 16 the best fitness is 0.20946498599439778']
# ['At iteration 17 the best fitness is 0.20946498599439778']
# ['At iteration 18 the best fitness is 0.20946498599439778']
# ['At iteration 19 the best fitness is 0.20946498599439778']
# ['At iteration 20 the best fitness is 0.20946498599439778']
# ['At iteration 21 the best fitness is 0.20946498599439778']
# ['At iteration 22 the best fitness is 0.20946498599439778']
# ['At iteration 23 the best fitness is 0.20946498599439778']
# ['At iteration 24 the best fitness is 0.20338375350140053']
# ['At iteration 25 the best fitness is 0.20338375350140053']
# ['At iteration 26 the best fitness is 0.20338375350140053']
# ['At iteration 27 the best fitness is 0.20338375350140053']
# ['At iteration 28 the best fitness is 0.20338375350140053']
# ['At iteration 29 the best fitness is 0.20338375350140053']
#       Selected: 303/595 (50.9%), Fitness: 0.2034, Time: 604.3s
#       Modality: D=46%, S=59%, Sk=47%, V=53%
#     Test Acc: 67.29%, F1: 65.56%, Features: 303/595 (50.9%), Model: 1.133MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.28538095238095235']
# ['At iteration 2 the best fitness is 0.23353781512605037']
# ['At iteration 3 the best fitness is 0.21546218487394952']
# ['At iteration 4 the best fitness is 0.21546218487394952']
# ['At iteration 5 the best fitness is 0.21546218487394952']
# ['At iteration 6 the best fitness is 0.21546218487394952']
# ['At iteration 7 the best fitness is 0.21546218487394952']
# ['At iteration 8 the best fitness is 0.21546218487394952']
# ['At iteration 9 the best fitness is 0.21546218487394952']
# ['At iteration 10 the best fitness is 0.21546218487394952']
# ['At iteration 11 the best fitness is 0.21546218487394952']
# ['At iteration 12 the best fitness is 0.21546218487394952']
# ['At iteration 13 the best fitness is 0.21546218487394952']
# ['At iteration 14 the best fitness is 0.21546218487394952']
# ['At iteration 15 the best fitness is 0.21546218487394952']
# ['At iteration 16 the best fitness is 0.21546218487394952']
# ['At iteration 17 the best fitness is 0.21546218487394952']
# ['At iteration 18 the best fitness is 0.21546218487394952']
# ['At iteration 19 the best fitness is 0.21546218487394952']
# ['At iteration 20 the best fitness is 0.21546218487394952']
# ['At iteration 21 the best fitness is 0.21546218487394952']
# ['At iteration 22 the best fitness is 0.21521008403361339']
# ['At iteration 23 the best fitness is 0.19612605042016812']
# ['At iteration 24 the best fitness is 0.19612605042016812']
# ['At iteration 25 the best fitness is 0.19604201680672273']
# ['At iteration 26 the best fitness is 0.19604201680672273']
# ['At iteration 27 the best fitness is 0.19604201680672273']
# ['At iteration 28 the best fitness is 0.19604201680672273']
# ['At iteration 29 the best fitness is 0.19604201680672273']
# ['At iteration 30 the best fitness is 0.19604201680672273']
#       Selected: 289/595 (48.6%), Fitness: 0.1960, Time: 621.8s
#       Modality: D=54%, S=46%, Sk=52%, V=45%
#     Test Acc: 69.16%, F1: 67.52%, Features: 289/595 (48.6%), Model: 1.106MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.2724621848739496']
# ['At iteration 2 the best fitness is 0.2723781512605042']
# ['At iteration 3 the best fitness is 0.24729691876750692']
# ['At iteration 4 the best fitness is 0.2284649859943978']
# ['At iteration 5 the best fitness is 0.2284649859943978']
# ['At iteration 6 the best fitness is 0.22238375350140055']
# ['At iteration 7 the best fitness is 0.22238375350140055']
# ['At iteration 8 the best fitness is 0.19671428571428576']
# ['At iteration 9 the best fitness is 0.19671428571428576']
# ['At iteration 10 the best fitness is 0.19671428571428576']
# ['At iteration 11 the best fitness is 0.19671428571428576']
# ['At iteration 12 the best fitness is 0.19671428571428576']
# ['At iteration 13 the best fitness is 0.19671428571428576']
# ['At iteration 14 the best fitness is 0.19671428571428576']
# ['At iteration 15 the best fitness is 0.19671428571428576']
# ['At iteration 16 the best fitness is 0.19671428571428576']
# ['At iteration 17 the best fitness is 0.19671428571428576']
# ['At iteration 18 the best fitness is 0.19671428571428576']
# ['At iteration 19 the best fitness is 0.19671428571428576']
# ['At iteration 20 the best fitness is 0.19671428571428576']
# ['At iteration 21 the best fitness is 0.19671428571428576']
# ['At iteration 22 the best fitness is 0.19671428571428576']
# ['At iteration 23 the best fitness is 0.19671428571428576']
# ['At iteration 24 the best fitness is 0.19671428571428576']
# ['At iteration 25 the best fitness is 0.19671428571428576']
# ['At iteration 26 the best fitness is 0.19671428571428576']
# ['At iteration 27 the best fitness is 0.19671428571428576']
# ['At iteration 28 the best fitness is 0.19671428571428576']
# ['At iteration 29 the best fitness is 0.19671428571428576']
# ['At iteration 30 the best fitness is 0.19671428571428576']
#       Selected: 310/595 (52.1%), Fitness: 0.1967, Time: 624.4s
#       Modality: D=51%, S=70%, Sk=52%, V=48%
#     Test Acc: 69.16%, F1: 66.69%, Features: 310/595 (52.1%), Model: 1.147MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.2954425770308122']
# ['At iteration 1 the best fitness is 0.2831120448179272']
# ['At iteration 2 the best fitness is 0.28101120448179273']
# ['At iteration 3 the best fitness is 0.28101120448179273']
# ['At iteration 4 the best fitness is 0.28101120448179273']
# ['At iteration 5 the best fitness is 0.28101120448179273']
# ['At iteration 6 the best fitness is 0.2715686274509804']
# ['At iteration 7 the best fitness is 0.25629691876750693']
# ['At iteration 8 the best fitness is 0.25629691876750693']
# ['At iteration 9 the best fitness is 0.25629691876750693']
# ['At iteration 10 the best fitness is 0.25629691876750693']
# ['At iteration 11 the best fitness is 0.25629691876750693']
# ['At iteration 12 the best fitness is 0.25629691876750693']
# ['At iteration 13 the best fitness is 0.25629691876750693']
# ['At iteration 14 the best fitness is 0.25629691876750693']
# ['At iteration 15 the best fitness is 0.25629691876750693']
# ['At iteration 16 the best fitness is 0.25629691876750693']
# ['At iteration 17 the best fitness is 0.25629691876750693']
# ['At iteration 18 the best fitness is 0.25629691876750693']
# ['At iteration 19 the best fitness is 0.25629691876750693']
# ['At iteration 20 the best fitness is 0.25629691876750693']
# ['At iteration 21 the best fitness is 0.25629691876750693']
# ['At iteration 22 the best fitness is 0.25629691876750693']
# ['At iteration 23 the best fitness is 0.25629691876750693']
# ['At iteration 24 the best fitness is 0.25629691876750693']
# ['At iteration 25 the best fitness is 0.25629691876750693']
# ['At iteration 26 the best fitness is 0.25629691876750693']
# ['At iteration 27 the best fitness is 0.25629691876750693']
# ['At iteration 28 the best fitness is 0.25629691876750693']
# ['At iteration 29 the best fitness is 0.25629691876750693']
#       Selected: 179/595 (30.1%), Fitness: 0.2563, Time: 590.2s
#       Modality: D=27%, S=33%, Sk=28%, V=32%
#     Test Acc: 58.88%, F1: 55.71%, Features: 179/595 (30.1%), Model: 0.518MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.25363025210084034']
# ['At iteration 2 the best fitness is 0.25363025210084034']
# ['At iteration 3 the best fitness is 0.25363025210084034']
# ['At iteration 4 the best fitness is 0.25278991596638656']
# ['At iteration 5 the best fitness is 0.25278991596638656']
# ['At iteration 6 the best fitness is 0.25278991596638656']
# ['At iteration 7 the best fitness is 0.24696078431372542']
# ['At iteration 8 the best fitness is 0.24696078431372542']
# ['At iteration 9 the best fitness is 0.22314005602240897']
# ['At iteration 10 the best fitness is 0.22314005602240897']
# ['At iteration 11 the best fitness is 0.22314005602240897']
# ['At iteration 12 the best fitness is 0.22314005602240897']
# ['At iteration 13 the best fitness is 0.21613445378151255']
# ['At iteration 14 the best fitness is 0.21005322128851542']
# ['At iteration 15 the best fitness is 0.21005322128851542']
# ['At iteration 16 the best fitness is 0.19763865546218493']
# ['At iteration 17 the best fitness is 0.19763865546218493']
# ['At iteration 18 the best fitness is 0.19763865546218493']
# ['At iteration 19 the best fitness is 0.19763865546218493']
# ['At iteration 20 the best fitness is 0.19763865546218493']
# ['At iteration 21 the best fitness is 0.19763865546218493']
# ['At iteration 22 the best fitness is 0.19763865546218493']
# ['At iteration 23 the best fitness is 0.19763865546218493']
# ['At iteration 24 the best fitness is 0.19763865546218493']
# ['At iteration 25 the best fitness is 0.19763865546218493']
# ['At iteration 26 the best fitness is 0.18497198879551818']
# ['At iteration 27 the best fitness is 0.18497198879551818']
# ['At iteration 28 the best fitness is 0.18497198879551818']
# ['At iteration 29 the best fitness is 0.18497198879551818']
#       Selected: 330/595 (55.5%), Fitness: 0.1850, Time: 1555.4s
#       Modality: D=57%, S=70%, Sk=57%, V=51%
#     Test Acc: 75.70%, F1: 73.85%, Features: 330/595 (55.5%), Model: 1.186MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.25979551820728297']
# ['At iteration 1 the best fitness is 0.25979551820728297']
# ['At iteration 2 the best fitness is 0.22495798319327726']
# ['At iteration 3 the best fitness is 0.22495798319327726']
# ['At iteration 4 the best fitness is 0.22495798319327726']
# ['At iteration 5 the best fitness is 0.22495798319327726']
# ['At iteration 6 the best fitness is 0.22495798319327726']
# ['At iteration 7 the best fitness is 0.22495798319327726']
# ['At iteration 8 the best fitness is 0.22495798319327726']
# ['At iteration 9 the best fitness is 0.22495798319327726']
# ['At iteration 10 the best fitness is 0.22495798319327726']
# ['At iteration 11 the best fitness is 0.22495798319327726']
# ['At iteration 12 the best fitness is 0.22495798319327726']
# ['At iteration 13 the best fitness is 0.22495798319327726']
# ['At iteration 14 the best fitness is 0.22495798319327726']
# ['At iteration 15 the best fitness is 0.22495798319327726']
# ['At iteration 16 the best fitness is 0.22495798319327726']
# ['At iteration 17 the best fitness is 0.22495798319327726']
# ['At iteration 18 the best fitness is 0.22495798319327726']
# ['At iteration 19 the best fitness is 0.22495798319327726']
# ['At iteration 20 the best fitness is 0.22495798319327726']
# ['At iteration 21 the best fitness is 0.22495798319327726']
# ['At iteration 22 the best fitness is 0.21862464985994398']
# ['At iteration 23 the best fitness is 0.21229131652661062']
# ['At iteration 24 the best fitness is 0.21229131652661062']
# ['At iteration 25 the best fitness is 0.21229131652661062']
# ['At iteration 26 the best fitness is 0.21229131652661062']
# ['At iteration 27 the best fitness is 0.21229131652661062']
# ['At iteration 28 the best fitness is 0.21229131652661062']
# ['At iteration 29 the best fitness is 0.21229131652661062']
#       Selected: 416/595 (69.9%), Fitness: 0.2123, Time: 583.7s
#       Modality: D=65%, S=80%, Sk=69%, V=70%
#     Test Acc: 72.90%, F1: 70.90%, Features: 416/595 (69.9%), Model: 1.354MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_25_lost/all_results_per_fold.csv
# Shape: (144, 28)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            70.3704           78.6667       68.0789          68.0789              73.6949           70.3704                595             595                100.000       0.0000          8.7350          8.7350        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 1      baseline     2            73.1481           77.3333       70.7790          70.7790              70.6790           73.1481                595             595                100.000       0.0000          9.1155          9.1155        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 2      baseline     3            69.4444           72.0000       70.8142          70.8142              78.3333           69.4444                595             595                100.000       0.0000          9.3034          9.3034        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 3      baseline     4            75.0000           80.6667       72.3537          72.3537              74.4797           75.0000                595             595                100.000       0.0000          9.1250          9.1250        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 4      baseline     5            60.1852           78.0000       58.0455          58.0455              60.6750           60.1852                595             595                100.000       0.0000          8.9097          8.9097        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 5      baseline     6            65.4206           80.6667       62.8711          62.5241              66.3859           65.7407                595             595                100.000       0.0000          8.8549          8.8549        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 6      baseline     7            61.6822           76.6667       60.0155          60.2026              66.8078           61.4198                595             595                100.000       0.0000          8.9827          8.9827        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 7      baseline     8            75.7009           80.6667       74.6224          74.8525              82.2840           75.3086                595             595                100.000       0.0000          8.3953          8.3953        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 8   mutual_info     1            65.7407           62.6667       64.6480          64.6480              70.5908           65.7407                297             595                 49.916       3.3809          8.3107         11.6917        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               20.3704               11                 16.2500                 39              92.8030             245
# 9   mutual_info     2            59.2593           64.0000       57.9101          57.9101              61.4198           59.2593                297             595                 49.916       3.3206         10.6293         13.9499        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               25.9259               14                 15.8333                 38              92.0455             243
# 10  mutual_info     3            50.9259           60.6667       49.2084          49.2084              51.0470           50.9259                297             595                 49.916       3.3819         10.8056         14.1876        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               22.2222               12                 17.9167                 43              90.9091             240
# 11  mutual_info     4            58.3333           70.0000       56.6803          56.6803              62.0238           58.3333                297             595                 49.916       3.3038         10.8346         14.1385        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               24.0741               13                 17.9167                 43              90.5303             239
# 12  mutual_info     5            55.5556           68.0000       54.5334          54.5334              57.5750           55.5556                297             595                 49.916       3.2997         10.5122         13.8120        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               22.2222               12                 15.4167                 37              93.1818             246
# 13  mutual_info     6            54.2056           64.0000       50.1418          49.6758              52.8748           54.6296                297             595                 49.916       3.3555         10.5401         13.8957        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               24.0741               13                 15.8333                 38              92.4242             244
# 14  mutual_info     7            61.6822           66.6667       59.5925          59.3484              60.9362           62.0370                297             595                 49.916       3.2860         10.2010         13.4871        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               22.2222               12                 17.0833                 41              91.6667             242
# 15  mutual_info     8            54.2056           65.3333       52.4617          52.6849              58.9109           54.0123                297             595                 49.916       3.3531          9.5055         12.8586        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               27.7778               15                 16.6667                 40              90.9091             240
# 16          rfe     1            80.5556           81.3333       79.7216          79.7216              81.4638           80.5556                297             595                 49.916       0.5364          8.2618          8.7984        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              10.8108               4               92.5926               50                 44.1667                106              51.8939             137
# 17          rfe     2            79.6296           84.6667       78.0787          78.0787              81.7078           79.6296                297             595                 49.916       0.5407         10.3884         10.9294        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              10.8108               4               94.4444               51                 44.5833                107              51.1364             135
# 18          rfe     3            78.7037           80.6667       77.9835          77.9835              83.2099           78.7037                297             595                 49.916       0.5449         10.6008         11.1458        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              18.9189               7               92.5926               50                 45.8333                110              49.2424             130
# 19          rfe     4            73.1481           84.0000       70.6806          70.6806              70.7672           73.1481                297             595                 49.916       0.5544         10.6985         11.2530        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              13.5135               5               90.7407               49                 42.0833                101              53.7879             142

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              68.87              5.91              67.20              6.12                  595.00                      100.00              0.00                 8.93                 8.93           444955.0                  1.70                        0.00               27.79
# mutual_info              57.49              4.75              55.65              5.15                  297.00                       49.92              3.34                10.17                13.50           292379.0                  1.12                       50.08               24.00
#         rfe              74.90              5.42              73.31              5.79                  297.00                       49.92              0.54                10.17                10.71           292379.0                  1.12                       50.08               24.00
#       lasso              53.66              8.43              51.73              8.27                  297.00                       49.92              0.08                10.22                10.30           292379.0                  1.12                       50.08               24.00
#    meta_BAT              63.05              4.46              60.67              4.56                  294.75                       49.54            624.93                10.38               635.31           291227.0                  1.12                       50.46               23.97
#     meta_CS              65.16              4.64              63.04              5.67                  292.50                       49.16           1281.21                10.78              1291.98           290075.0                  1.11                       50.84               23.95
#     meta_DE              63.30              5.83              61.16              6.13                  299.12                       50.27            657.24                10.63               667.86           293467.0                  1.13                       49.73               24.02
#    meta_FFA              64.69              3.66              62.55              3.59                  306.12                       51.45            634.70                10.95               645.65           297051.0                  1.14                       48.55               24.11
#     meta_GA              63.89              5.82              62.20              6.15                  297.38                       49.98            635.76                10.70               646.46           292571.0                  1.12                       50.02               24.00
#    meta_GWO              64.22              5.46              62.60              5.11                  249.88                       42.00            626.45                10.53               636.98           254098.0                  0.97                       58.00               23.12
#    meta_HHO              66.43              6.66              64.39              7.71                  437.50                       73.53            827.51                10.22               837.73           364315.0                  1.40                       26.47               25.82
#   meta_JAYA              66.07              4.58              64.12              5.05                  300.00                       50.42            637.12                10.69               647.81           293915.0                  1.13                       49.58               24.03
#    meta_MFO              66.77              5.33              64.78              6.35                  304.00                       51.09            614.74                10.97               625.71           295963.0                  1.13                       48.91               24.08
#    meta_MVO              66.08              3.90              64.26              4.05                  301.00                       50.59            634.98                10.76               645.74           294427.0                  1.13                       49.41               24.05
#    meta_PSO              63.18              4.48              61.36              4.89                  292.25                       49.12            635.62                10.72               646.34           289947.0                  1.11                       50.88               23.94
#    meta_SCA              57.60              3.91              55.39              4.37                  181.38                       30.48            612.96                10.52               623.48           143991.0                  0.55                       69.52               20.60
#    meta_SSA              66.78              5.65              64.84              6.18                  302.88                       50.90           1572.87                10.67              1583.54           295387.0                  1.13                       49.10               24.07
#    meta_WOA              66.67              3.00              64.93              2.96                  452.00                       75.97            604.26                 9.79               614.05           371739.0                  1.42                       24.03               25.95

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 57.49% vs Baseline: 68.87%
#   Paired t-test: t=-4.2152, p=0.0040
#   Wilcoxon test: W=0.0000, p=0.0156
#   -> worse, Significant
#
# RFE vs BASELINE:
#   Method: 74.90% vs Baseline: 68.87%
#   Paired t-test: t=2.5135, p=0.0402
#   Wilcoxon test: W=6.0000, p=0.1094
#   -> better, Significant
#
# LASSO vs BASELINE:
#   Method: 53.66% vs Baseline: 68.87%
#   Paired t-test: t=-4.4843, p=0.0029
#   Wilcoxon test: W=1.0000, p=0.0156
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 63.05% vs Baseline: 68.87%
#   Paired t-test: t=-3.3050, p=0.0130
#   Wilcoxon test: W=2.0000, p=0.0234
#   -> worse, Significant
#
# META_CS vs BASELINE:
#   Method: 65.16% vs Baseline: 68.87%
#   Paired t-test: t=-1.7483, p=0.1239
#   Wilcoxon test: W=7.0000, p=0.1484
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 63.30% vs Baseline: 68.87%
#   Paired t-test: t=-4.2805, p=0.0037
#   Wilcoxon test: W=1.0000, p=0.0156
#   -> worse, Significant
#
# META_FFA vs BASELINE:
#   Method: 64.69% vs Baseline: 68.87%
#   Paired t-test: t=-1.9121, p=0.0975
#   Wilcoxon test: W=6.0000, p=0.1094
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 63.89% vs Baseline: 68.87%
#   Paired t-test: t=-2.4782, p=0.0423
#   Wilcoxon test: W=3.0000, p=0.0781
#   -> worse, Significant
#
# META_GWO vs BASELINE:
#   Method: 64.22% vs Baseline: 68.87%
#   Paired t-test: t=-1.9433, p=0.0931
#   Wilcoxon test: W=6.0000, p=0.1094
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 66.43% vs Baseline: 68.87%
#   Paired t-test: t=-1.0607, p=0.3241
#   Wilcoxon test: W=5.0000, p=0.3125
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 66.07% vs Baseline: 68.87%
#   Paired t-test: t=-1.5606, p=0.1626
#   Wilcoxon test: W=5.0000, p=0.1562
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 66.77% vs Baseline: 68.87%
#   Paired t-test: t=-0.8876, p=0.4042
#   Wilcoxon test: W=8.0000, p=0.3750
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 66.08% vs Baseline: 68.87%
#   Paired t-test: t=-1.0879, p=0.3127
#   Wilcoxon test: W=9.0000, p=0.2500
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 63.18% vs Baseline: 68.87%
#   Paired t-test: t=-6.5636, p=0.0003
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_SCA vs BASELINE:
#   Method: 57.60% vs Baseline: 68.87%
#   Paired t-test: t=-5.3711, p=0.0010
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_SSA vs BASELINE:
#   Method: 66.78% vs Baseline: 68.87%
#   Paired t-test: t=-0.8894, p=0.4033
#   Wilcoxon test: W=8.0000, p=0.3750
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 66.67% vs Baseline: 68.87%
#   Paired t-test: t=-1.2348, p=0.2567
#   Wilcoxon test: W=11.0000, p=0.3828
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_25_lost
#
# Per-method folders:
#   results_25_lost/baseline/ (16 files)
#   results_25_lost/mutual_info/ (16 files)
#   results_25_lost/rfe/ (16 files)
#   results_25_lost/lasso/ (16 files)
#   results_25_lost/meta_BAT/ (16 files)
#   results_25_lost/meta_CS/ (16 files)
#   results_25_lost/meta_DE/ (16 files)
#   results_25_lost/meta_FFA/ (16 files)
#   results_25_lost/meta_GA/ (16 files)
#   results_25_lost/meta_GWO/ (16 files)
#   results_25_lost/meta_HHO/ (16 files)
#   results_25_lost/meta_JAYA/ (16 files)
#   results_25_lost/meta_MFO/ (16 files)
#   results_25_lost/meta_MVO/ (16 files)
#   results_25_lost/meta_PSO/ (16 files)
#   results_25_lost/meta_SCA/ (16 files)
#   results_25_lost/meta_SSA/ (16 files)
#   results_25_lost/meta_WOA/ (16 files)
#
# Plots directory: results_25_lost/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 74.90% ± 5.42% (Features: 49.9%)
#   baseline            : 68.87% ± 5.91% (Features: 100.0%)
#   meta_SSA            : 66.78% ± 5.65% (Features: 50.9%)
#   meta_MFO            : 66.77% ± 5.33% (Features: 51.1%)
#   meta_WOA            : 66.67% ± 3.00% (Features: 76.0%)
