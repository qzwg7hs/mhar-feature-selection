# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (25% Random Zeroing)
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.
#
#
# > **Modification:** This notebook randomly zeros out 10% of all data elements before any processing.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new_25_loss")

# Master output directory
RESULTS_ROOT = Path("results_new_25_loss")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   video: 1420
#   TOTAL: 3933

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 87.96%, F1: 87.52%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 22.7s
#     Test Acc: 89.81%, F1: 89.16%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.1s
#     Test Acc: 90.74%, F1: 90.89%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.3s
#     Test Acc: 74.07%, F1: 70.85%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08203178235443687']
# ['At iteration 1 the best fitness is 0.08203178235443687']
# ['At iteration 2 the best fitness is 0.08198093058733796']
# ['At iteration 3 the best fitness is 0.06939054157131958']
# ['At iteration 4 the best fitness is 0.06939054157131958']
# ['At iteration 5 the best fitness is 0.06318433765573357']
# ['At iteration 6 the best fitness is 0.06318433765573357']
# ['At iteration 7 the best fitness is 0.06318433765573357']
# ['At iteration 8 the best fitness is 0.06318433765573357']
# ['At iteration 9 the best fitness is 0.06318433765573357']
# ['At iteration 10 the best fitness is 0.06318433765573357']
# ['At iteration 11 the best fitness is 0.06318433765573357']
# ['At iteration 12 the best fitness is 0.06318433765573357']
# ['At iteration 13 the best fitness is 0.06318433765573357']
# ['At iteration 14 the best fitness is 0.05051767098906682']
# ['At iteration 15 the best fitness is 0.05051767098906682']
# ['At iteration 16 the best fitness is 0.05051767098906682']
# ['At iteration 17 the best fitness is 0.05051767098906682']
# ['At iteration 18 the best fitness is 0.05051767098906682']
# ['At iteration 19 the best fitness is 0.05051767098906682']
# ['At iteration 20 the best fitness is 0.05051767098906682']
# ['At iteration 21 the best fitness is 0.05051767098906682']
# ['At iteration 22 the best fitness is 0.05051767098906682']
# ['At iteration 23 the best fitness is 0.05051767098906682']
# ['At iteration 24 the best fitness is 0.05051767098906682']
# ['At iteration 25 the best fitness is 0.05051767098906682']
# ['At iteration 26 the best fitness is 0.05051767098906682']
# ['At iteration 27 the best fitness is 0.05051767098906682']
# ['At iteration 28 the best fitness is 0.05051767098906682']
# ['At iteration 29 the best fitness is 0.05051767098906682']
#       Selected: 1983/3933 (50.4%), Fitness: 0.0505, Time: 915.9s
#       Modality: D=53%, S=49%, Sk=50%, V=51%
#     Test Acc: 85.19%, F1: 84.85%, Features: 1983/3933 (50.4%), Model: 4.414MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07623239257564202']
# ['At iteration 10 the best fitness is 0.06911085685227558']
# ['At iteration 20 the best fitness is 0.06911085685227558']
#       Selected: 1952/3933 (49.6%), Fitness: 0.0562, Time: 1803.8s
#       Modality: D=48%, S=49%, Sk=51%, V=49%
#     Test Acc: 88.89%, F1: 87.98%, Features: 1952/3933 (49.6%), Model: 4.354MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06961937452326465']
# ['At iteration 2 the best fitness is 0.06961937452326465']
# ['At iteration 3 the best fitness is 0.06961937452326465']
# ['At iteration 4 the best fitness is 0.0695939486397152']
# ['At iteration 5 the best fitness is 0.0695939486397152']
# ['At iteration 6 the best fitness is 0.06879303330790743']
# ['At iteration 7 the best fitness is 0.06879303330790743']
# ['At iteration 8 the best fitness is 0.06879303330790743']
# ['At iteration 9 the best fitness is 0.06879303330790743']
# ['At iteration 10 the best fitness is 0.06879303330790743']
# ['At iteration 11 the best fitness is 0.06879303330790743']
# ['At iteration 12 the best fitness is 0.06879303330790743']
# ['At iteration 13 the best fitness is 0.06879303330790743']
# ['At iteration 14 the best fitness is 0.06879303330790743']
# ['At iteration 15 the best fitness is 0.06879303330790743']
# ['At iteration 16 the best fitness is 0.06879303330790743']
# ['At iteration 17 the best fitness is 0.06879303330790743']
# ['At iteration 18 the best fitness is 0.06879303330790743']
# ['At iteration 19 the best fitness is 0.06879303330790743']
# ['At iteration 20 the best fitness is 0.06879303330790743']
# ['At iteration 21 the best fitness is 0.06879303330790743']
# ['At iteration 22 the best fitness is 0.06879303330790743']
# ['At iteration 23 the best fitness is 0.06879303330790743']
# ['At iteration 24 the best fitness is 0.06879303330790743']
# ['At iteration 25 the best fitness is 0.06879303330790743']
# ['At iteration 26 the best fitness is 0.06879303330790743']
# ['At iteration 27 the best fitness is 0.06879303330790743']
# ['At iteration 28 the best fitness is 0.06879303330790743']
# ['At iteration 29 the best fitness is 0.06879303330790743']
# ['At iteration 30 the best fitness is 0.06879303330790743']
#       Selected: 1948/3933 (49.5%), Fitness: 0.0688, Time: 914.3s
#       Modality: D=49%, S=49%, Sk=51%, V=48%
#     Test Acc: 87.96%, F1: 86.93%, Features: 1948/3933 (49.5%), Model: 4.346MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08153597762522252']
# ['At iteration 1 the best fitness is 0.08823798627002286']
# ['At iteration 2 the best fitness is 0.09429163488431226']
# ['At iteration 3 the best fitness is 0.08156140350877197']
# ['At iteration 4 the best fitness is 0.09462217137045516']
# ['At iteration 5 the best fitness is 0.08173938469361816']
# ['At iteration 6 the best fitness is 0.09440605136028479']
# ['At iteration 7 the best fitness is 0.08799644037630305']
# ['At iteration 8 the best fitness is 0.09413907958301554']
# ['At iteration 9 the best fitness is 0.09425349605898808']
# ['At iteration 10 the best fitness is 0.0878693109585558']
# ['At iteration 11 the best fitness is 0.10035799644037627']
# ['At iteration 12 the best fitness is 0.08788202390033051']
# ['At iteration 13 the best fitness is 0.1004215611492499']
# ['At iteration 14 the best fitness is 0.09408822781591664']
# ['At iteration 15 the best fitness is 0.10031985761505208']
# ['At iteration 16 the best fitness is 0.08774218154080853']
# ['At iteration 17 the best fitness is 0.08780574624968215']
# ['At iteration 18 the best fitness is 0.0878311721332316']
# ['At iteration 19 the best fitness is 0.10048512585812353']
# ['At iteration 20 the best fitness is 0.09413907958301554']
# ['At iteration 21 the best fitness is 0.09417721840833972']
# ['At iteration 22 the best fitness is 0.10045969997457407']
# ['At iteration 23 the best fitness is 0.09412636664124081']
# ['At iteration 24 the best fitness is 0.08145969997457417']
# ['At iteration 25 the best fitness is 0.10048512585812353']
# ['At iteration 26 the best fitness is 0.08781845919145688']
# ['At iteration 27 the best fitness is 0.1004724129163488']
# ['At iteration 28 the best fitness is 0.08780574624968215']
# ['At iteration 29 the best fitness is 0.09413907958301554']
#       Selected: 1969/3933 (50.1%), Fitness: 0.0941, Time: 884.4s
#       Modality: D=50%, S=53%, Sk=50%, V=49%
#     Test Acc: 82.41%, F1: 81.59%, Features: 1969/3933 (50.1%), Model: 4.387MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.0882506992117976
# At iteration 2 the best fitness is 0.08170124586829397
# At iteration 3 the best fitness is 0.08795830155097888
# At iteration 4 the best fitness is 0.08766590389016016
# At iteration 5 the best fitness is 0.08212077294685996
# At iteration 6 the best fitness is 0.06303178235443685
# At iteration 7 the best fitness is 0.0756094584286804
# At iteration 8 the best fitness is 0.07592728197304857
# At iteration 9 the best fitness is 0.0622944317315027
# At iteration 10 the best fitness is 0.07585100432240022
# At iteration 11 the best fitness is 0.07501195016526825
# At iteration 12 the best fitness is 0.08118001525553017
# At iteration 13 the best fitness is 0.06892016272565468
# At iteration 14 the best fitness is 0.07562217137045513
# At iteration 15 the best fitness is 0.0750373760488177
# At iteration 16 the best fitness is 0.08126900584795327
# At iteration 17 the best fitness is 0.06894558860920413
# At iteration 18 the best fitness is 0.07511365369946607
# At iteration 19 the best fitness is 0.06876760742435797
# At iteration 20 the best fitness is 0.06872946859903378
# At iteration 21 the best fitness is 0.0625741164505467
# At iteration 22 the best fitness is 0.06890744978387996
# At iteration 23 the best fitness is 0.06870404271548433
# At iteration 24 the best fitness is 0.06931426392067122
# At iteration 25 the best fitness is 0.056304347826086946
# At iteration 26 the best fitness is 0.049971014492753575
# At iteration 27 the best fitness is 0.07510094075769133
# At iteration 28 the best fitness is 0.06293007882023904
# At iteration 29 the best fitness is 0.07540605136028478
# At iteration 30 the best fitness is 0.06898372743452832
#       Selected: 1940/3933 (49.3%), Fitness: 0.0690, Time: 883.4s
#       Modality: D=50%, S=49%, Sk=51%, V=47%
#     Test Acc: 87.96%, F1: 87.41%, Features: 1940/3933 (49.3%), Model: 4.330MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08189193999491487']
# ['At iteration 1 the best fitness is 0.08105288583778292']
# ['At iteration 2 the best fitness is 0.07436359013475718']
# ['At iteration 3 the best fitness is 0.06694965675057205']
# ['At iteration 4 the best fitness is 0.06645385202135771']
# ['At iteration 5 the best fitness is 0.06645385202135771']
# ['At iteration 6 the best fitness is 0.06645385202135771']
# ['At iteration 7 the best fitness is 0.06645385202135771']
# ['At iteration 8 the best fitness is 0.06645385202135771']
# ['At iteration 9 the best fitness is 0.06552580727180266']
# ['At iteration 10 the best fitness is 0.06500457665903887']
# ['At iteration 11 the best fitness is 0.0578576150521231']
# ['At iteration 12 the best fitness is 0.0578576150521231']
# ['At iteration 13 the best fitness is 0.0578576150521231']
# ['At iteration 14 the best fitness is 0.0578576150521231']
# ['At iteration 15 the best fitness is 0.057628782100178015']
# ['At iteration 16 the best fitness is 0.051053902873124835']
# ['At iteration 17 the best fitness is 0.051053902873124835']
# ['At iteration 18 the best fitness is 0.051003051106025925']
# ['At iteration 19 the best fitness is 0.051003051106025925']
# ['At iteration 20 the best fitness is 0.050761505212306116']
# ['At iteration 21 the best fitness is 0.050761505212306116']
# ['At iteration 22 the best fitness is 0.050761505212306116']
# ['At iteration 23 the best fitness is 0.050761505212306116']
# ['At iteration 24 the best fitness is 0.050761505212306116']
# ['At iteration 25 the best fitness is 0.050761505212306116']
# ['At iteration 26 the best fitness is 0.050761505212306116']
# ['At iteration 27 the best fitness is 0.050761505212306116']
# ['At iteration 28 the best fitness is 0.044529875413170564']
# ['At iteration 29 the best fitness is 0.044529875413170564']
#       Selected: 1623/3933 (41.3%), Fitness: 0.0445, Time: 913.7s
#       Modality: D=39%, S=41%, Sk=43%, V=39%
#     Test Acc: 80.56%, F1: 78.61%, Features: 1623/3933 (41.3%), Model: 3.711MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.07497381133994407']
# ['At iteration 1 the best fitness is 0.064114670734808']
# ['At iteration 2 the best fitness is 0.064114670734808']
# ['At iteration 3 the best fitness is 0.064114670734808']
# ['At iteration 4 the best fitness is 0.064114670734808']
# ['At iteration 5 the best fitness is 0.064114670734808']
# ['At iteration 6 the best fitness is 0.064114670734808']
# ['At iteration 7 the best fitness is 0.064114670734808']
# ['At iteration 8 the best fitness is 0.064114670734808']
# ['At iteration 9 the best fitness is 0.064114670734808']
# ['At iteration 10 the best fitness is 0.06305949656750569']
# ['At iteration 11 the best fitness is 0.06305949656750569']
# ['At iteration 12 the best fitness is 0.06305949656750569']
# ['At iteration 13 the best fitness is 0.062044749555047046']
# ['At iteration 14 the best fitness is 0.062044749555047046']
# ['At iteration 15 the best fitness is 0.062044749555047046']
# ['At iteration 16 the best fitness is 0.062044749555047046']
# ['At iteration 17 the best fitness is 0.062044749555047046']
# ['At iteration 18 the best fitness is 0.062044749555047046']
# ['At iteration 19 the best fitness is 0.062044749555047046']
# ['At iteration 20 the best fitness is 0.062044749555047046']
# ['At iteration 21 the best fitness is 0.062044749555047046']
# ['At iteration 22 the best fitness is 0.062044749555047046']
# ['At iteration 23 the best fitness is 0.062044749555047046']
# ['At iteration 24 the best fitness is 0.062044749555047046']
# ['At iteration 25 the best fitness is 0.062044749555047046']
# ['At iteration 26 the best fitness is 0.06195575896262396']
# ['At iteration 27 the best fitness is 0.06195575896262396']
# ['At iteration 28 the best fitness is 0.06195575896262396']
# ['At iteration 29 the best fitness is 0.06195575896262396']
#       Selected: 1009/3933 (25.7%), Fitness: 0.0620, Time: 1099.2s
#       Modality: D=29%, S=27%, Sk=26%, V=25%
#     Test Acc: 89.81%, F1: 88.84%, Features: 1009/3933 (25.7%), Model: 2.512MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08173938469361816']
# ['At iteration 1 the best fitness is 0.06925069921179758']
# ['At iteration 2 the best fitness is 0.06925069921179758']
# ['At iteration 3 the best fitness is 0.06925069921179758']
# ['At iteration 4 the best fitness is 0.06925069921179758']
# ['At iteration 5 the best fitness is 0.06925069921179758']
# ['At iteration 6 the best fitness is 0.06925069921179758']
# ['At iteration 7 the best fitness is 0.06925069921179758']
# ['At iteration 8 the best fitness is 0.06356572590897537']
# ['At iteration 9 the best fitness is 0.06356572590897537']
# ['At iteration 10 the best fitness is 0.06356572590897537']
# ['At iteration 11 the best fitness is 0.06356572590897537']
# ['At iteration 12 the best fitness is 0.06356572590897537']
# ['At iteration 13 the best fitness is 0.06356572590897537']
# ['At iteration 14 the best fitness is 0.06356572590897537']
# ['At iteration 15 the best fitness is 0.06356572590897537']
# ['At iteration 16 the best fitness is 0.06356572590897537']
# ['At iteration 17 the best fitness is 0.06356572590897537']
# ['At iteration 18 the best fitness is 0.06356572590897537']
# ['At iteration 19 the best fitness is 0.06356572590897537']
# ['At iteration 20 the best fitness is 0.06336231884057975']
# ['At iteration 21 the best fitness is 0.06336231884057975']
# ['At iteration 22 the best fitness is 0.06336231884057975']
# ['At iteration 23 the best fitness is 0.06336231884057975']
# ['At iteration 24 the best fitness is 0.06336231884057975']
# ['At iteration 25 the best fitness is 0.06336231884057975']
# ['At iteration 26 the best fitness is 0.06336231884057975']
# ['At iteration 27 the best fitness is 0.06336231884057975']
# ['At iteration 28 the best fitness is 0.06336231884057975']
# ['At iteration 29 the best fitness is 0.06336231884057975']
#       Selected: 2032/3933 (51.7%), Fitness: 0.0634, Time: 913.8s
#       Modality: D=52%, S=52%, Sk=52%, V=51%
#     Test Acc: 85.19%, F1: 83.29%, Features: 2032/3933 (51.7%), Model: 4.510MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.09416450546656499']
# ['At iteration 2 the best fitness is 0.056736587846427655']
# ['At iteration 3 the best fitness is 0.056736587846427655']
# ['At iteration 4 the best fitness is 0.056736587846427655']
# ['At iteration 5 the best fitness is 0.056736587846427655']
# ['At iteration 6 the best fitness is 0.056736587846427655']
# ['At iteration 7 the best fitness is 0.056736587846427655']
# ['At iteration 8 the best fitness is 0.056736587846427655']
# ['At iteration 9 the best fitness is 0.056736587846427655']
# ['At iteration 10 the best fitness is 0.056736587846427655']
# ['At iteration 11 the best fitness is 0.056736587846427655']
# ['At iteration 12 the best fitness is 0.056736587846427655']
# ['At iteration 13 the best fitness is 0.056736587846427655']
# ['At iteration 14 the best fitness is 0.056736587846427655']
# ['At iteration 15 the best fitness is 0.056736587846427655']
# ['At iteration 16 the best fitness is 0.056736587846427655']
# ['At iteration 17 the best fitness is 0.056736587846427655']
# ['At iteration 18 the best fitness is 0.056736587846427655']
# ['At iteration 19 the best fitness is 0.056736587846427655']
# ['At iteration 20 the best fitness is 0.056736587846427655']
# ['At iteration 21 the best fitness is 0.056736587846427655']
# ['At iteration 22 the best fitness is 0.056736587846427655']
# ['At iteration 23 the best fitness is 0.056736587846427655']
# ['At iteration 24 the best fitness is 0.056736587846427655']
# ['At iteration 25 the best fitness is 0.056736587846427655']
# ['At iteration 26 the best fitness is 0.056736587846427655']
# ['At iteration 27 the best fitness is 0.056736587846427655']
# ['At iteration 28 the best fitness is 0.056736587846427655']
# ['At iteration 29 the best fitness is 0.056736587846427655']
#       Selected: 1972/3933 (50.1%), Fitness: 0.0567, Time: 863.4s
#       Modality: D=51%, S=48%, Sk=50%, V=51%
#     Test Acc: 87.96%, F1: 87.31%, Features: 1972/3933 (50.1%), Model: 4.393MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07634680905161456']
# ['At iteration 2 the best fitness is 0.07634680905161456']
# ['At iteration 3 the best fitness is 0.07634680905161456']
# ['At iteration 4 the best fitness is 0.06931426392067122']
# ['At iteration 5 the best fitness is 0.06931426392067122']
# ['At iteration 6 the best fitness is 0.06931426392067122']
# ['At iteration 7 the best fitness is 0.06931426392067122']
# ['At iteration 8 the best fitness is 0.06931426392067122']
# ['At iteration 9 the best fitness is 0.06931426392067122']
# ['At iteration 10 the best fitness is 0.06931426392067122']
# ['At iteration 11 the best fitness is 0.06931426392067122']
# ['At iteration 12 the best fitness is 0.06931426392067122']
# ['At iteration 13 the best fitness is 0.06931426392067122']
# ['At iteration 14 the best fitness is 0.06931426392067122']
# ['At iteration 15 the best fitness is 0.0692634121535723']
# ['At iteration 16 the best fitness is 0.0692634121535723']
# ['At iteration 17 the best fitness is 0.06919984744469868']
# ['At iteration 18 the best fitness is 0.06919984744469868']
# ['At iteration 19 the best fitness is 0.06919984744469868']
# ['At iteration 20 the best fitness is 0.06919984744469868']
# ['At iteration 21 the best fitness is 0.06919984744469868']
# ['At iteration 22 the best fitness is 0.05659674548690566']
# ['At iteration 23 the best fitness is 0.05659674548690566']
# ['At iteration 24 the best fitness is 0.05659674548690566']
# ['At iteration 25 the best fitness is 0.05659674548690566']
# ['At iteration 26 the best fitness is 0.05659674548690566']
# ['At iteration 27 the best fitness is 0.05659674548690566']
# ['At iteration 28 the best fitness is 0.05659674548690566']
# ['At iteration 29 the best fitness is 0.05659674548690566']
# ['At iteration 30 the best fitness is 0.05659674548690566']
#       Selected: 1946/3933 (49.5%), Fitness: 0.0566, Time: 885.6s
#       Modality: D=52%, S=47%, Sk=50%, V=49%
#     Test Acc: 82.41%, F1: 79.68%, Features: 1946/3933 (49.5%), Model: 4.342MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07591456903127385']
# ['At iteration 2 the best fitness is 0.06950495804729212']
# ['At iteration 3 the best fitness is 0.06930155097889648']
# ['At iteration 4 the best fitness is 0.06312077294685994']
# ['At iteration 5 the best fitness is 0.06312077294685994']
# ['At iteration 6 the best fitness is 0.06312077294685994']
# ['At iteration 7 the best fitness is 0.05704169844902109']
# ['At iteration 8 the best fitness is 0.05704169844902109']
# ['At iteration 9 the best fitness is 0.05704169844902109']
# ['At iteration 10 the best fitness is 0.05701627256547164']
# ['At iteration 11 the best fitness is 0.05701627256547164']
# ['At iteration 12 the best fitness is 0.05701627256547164']
# ['At iteration 13 the best fitness is 0.05701627256547164']
# ['At iteration 14 the best fitness is 0.05701627256547164']
# ['At iteration 15 the best fitness is 0.05701627256547164']
# ['At iteration 16 the best fitness is 0.05701627256547164']
# ['At iteration 17 the best fitness is 0.05701627256547164']
# ['At iteration 18 the best fitness is 0.05701627256547164']
# ['At iteration 19 the best fitness is 0.05701627256547164']
# ['At iteration 20 the best fitness is 0.05701627256547164']
# ['At iteration 21 the best fitness is 0.05701627256547164']
# ['At iteration 22 the best fitness is 0.05672387490465293']
# ['At iteration 23 the best fitness is 0.05672387490465293']
# ['At iteration 24 the best fitness is 0.05672387490465293']
# ['At iteration 25 the best fitness is 0.05672387490465293']
# ['At iteration 26 the best fitness is 0.05672387490465293']
# ['At iteration 27 the best fitness is 0.05672387490465293']
# ['At iteration 28 the best fitness is 0.05672387490465293']
# ['At iteration 29 the best fitness is 0.05672387490465293']
# ['At iteration 30 the best fitness is 0.05672387490465293']
#       Selected: 1977/3933 (50.3%), Fitness: 0.0567, Time: 886.6s
#       Modality: D=50%, S=51%, Sk=50%, V=51%
#     Test Acc: 87.96%, F1: 87.01%, Features: 1977/3933 (50.3%), Model: 4.402MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08190465293668961']
# ['At iteration 1 the best fitness is 0.07400762776506484']
# ['At iteration 2 the best fitness is 0.0721769641495042']
# ['At iteration 3 the best fitness is 0.0721769641495042']
# ['At iteration 4 the best fitness is 0.06596033562166286']
# ['At iteration 5 the best fitness is 0.06596033562166286']
# ['At iteration 6 the best fitness is 0.06596033562166286']
# ['At iteration 7 the best fitness is 0.06596033562166286']
# ['At iteration 8 the best fitness is 0.06596033562166286']
# ['At iteration 9 the best fitness is 0.06596033562166286']
# ['At iteration 10 the best fitness is 0.06596033562166286']
# ['At iteration 11 the best fitness is 0.055330027968471876']
# ['At iteration 12 the best fitness is 0.055330027968471876']
# ['At iteration 13 the best fitness is 0.055330027968471876']
# ['At iteration 14 the best fitness is 0.055330027968471876']
# ['At iteration 15 the best fitness is 0.055330027968471876']
# ['At iteration 16 the best fitness is 0.055330027968471876']
# ['At iteration 17 the best fitness is 0.055330027968471876']
# ['At iteration 18 the best fitness is 0.055330027968471876']
# ['At iteration 19 the best fitness is 0.055330027968471876']
# ['At iteration 20 the best fitness is 0.055330027968471876']
# ['At iteration 21 the best fitness is 0.055330027968471876']
# ['At iteration 22 the best fitness is 0.055330027968471876']
# ['At iteration 23 the best fitness is 0.055330027968471876']
# ['At iteration 24 the best fitness is 0.055330027968471876']
# ['At iteration 25 the best fitness is 0.055330027968471876']
# ['At iteration 26 the best fitness is 0.055330027968471876']
# ['At iteration 27 the best fitness is 0.055330027968471876']
# ['At iteration 28 the best fitness is 0.055330027968471876']
# ['At iteration 29 the best fitness is 0.055330027968471876']
#       Selected: 888/3933 (22.6%), Fitness: 0.0553, Time: 837.0s
#       Modality: D=22%, S=22%, Sk=22%, V=23%
#     Test Acc: 81.48%, F1: 80.00%, Features: 888/3933 (22.6%), Model: 2.276MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06304449529621158']
# ['At iteration 2 the best fitness is 0.06304449529621158']
# ['At iteration 3 the best fitness is 0.06304449529621158']
# ['At iteration 4 the best fitness is 0.06265039410119505']
# ['At iteration 5 the best fitness is 0.06265039410119505']
# ['At iteration 6 the best fitness is 0.06265039410119505']
# ['At iteration 7 the best fitness is 0.06265039410119505']
# ['At iteration 8 the best fitness is 0.06265039410119505']
# ['At iteration 9 the best fitness is 0.06265039410119505']
# ['At iteration 10 the best fitness is 0.06265039410119505']
# ['At iteration 11 the best fitness is 0.06265039410119505']
# ['At iteration 12 the best fitness is 0.06265039410119505']
# ['At iteration 13 the best fitness is 0.05645690312738367']
# ['At iteration 14 the best fitness is 0.05645690312738367']
# ['At iteration 15 the best fitness is 0.05645690312738367']
# ['At iteration 16 the best fitness is 0.05645690312738367']
# ['At iteration 17 the best fitness is 0.05645690312738367']
# ['At iteration 18 the best fitness is 0.056444190185608936']
# ['At iteration 19 the best fitness is 0.056444190185608936']
# ['At iteration 20 the best fitness is 0.056444190185608936']
# ['At iteration 21 the best fitness is 0.056444190185608936']
# ['At iteration 22 the best fitness is 0.056444190185608936']
# ['At iteration 23 the best fitness is 0.056444190185608936']
# ['At iteration 24 the best fitness is 0.056444190185608936']
# ['At iteration 25 the best fitness is 0.056444190185608936']
# ['At iteration 26 the best fitness is 0.056444190185608936']
# ['At iteration 27 the best fitness is 0.056444190185608936']
# ['At iteration 28 the best fitness is 0.056444190185608936']
# ['At iteration 29 the best fitness is 0.056444190185608936']
#       Selected: 1949/3933 (49.6%), Fitness: 0.0564, Time: 2211.8s
#       Modality: D=50%, S=49%, Sk=49%, V=50%
#     Test Acc: 87.96%, F1: 87.05%, Features: 1949/3933 (49.6%), Model: 4.348MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08851767098906685']
# ['At iteration 1 the best fitness is 0.07106280193236712']
# ['At iteration 2 the best fitness is 0.07106280193236712']
# ['At iteration 3 the best fitness is 0.07106280193236712']
# ['At iteration 4 the best fitness is 0.07106280193236712']
# ['At iteration 5 the best fitness is 0.07106280193236712']
# ['At iteration 6 the best fitness is 0.07106280193236712']
# ['At iteration 7 the best fitness is 0.07106280193236712']
# ['At iteration 8 the best fitness is 0.07106280193236712']
# ['At iteration 9 the best fitness is 0.07106280193236712']
# ['At iteration 10 the best fitness is 0.07106280193236712']
# ['At iteration 11 the best fitness is 0.07106280193236712']
# ['At iteration 12 the best fitness is 0.07106280193236712']
# ['At iteration 13 the best fitness is 0.07106280193236712']
# ['At iteration 14 the best fitness is 0.07106280193236712']
# ['At iteration 15 the best fitness is 0.07106280193236712']
# ['At iteration 16 the best fitness is 0.07106280193236712']
# ['At iteration 17 the best fitness is 0.07106280193236712']
# ['At iteration 18 the best fitness is 0.07106280193236712']
# ['At iteration 19 the best fitness is 0.07106280193236712']
# ['At iteration 20 the best fitness is 0.07103737604881767']
# ['At iteration 21 the best fitness is 0.07103737604881767']
# ['At iteration 22 the best fitness is 0.07103737604881767']
# ['At iteration 23 the best fitness is 0.07103737604881767']
# ['At iteration 24 the best fitness is 0.07103737604881767']
# ['At iteration 25 the best fitness is 0.07103737604881767']
# ['At iteration 26 the best fitness is 0.07103737604881767']
# ['At iteration 27 the best fitness is 0.07103737604881767']
# ['At iteration 28 the best fitness is 0.07103737604881767']
# ['At iteration 29 the best fitness is 0.07103737604881767']
#       Selected: 706/3933 (18.0%), Fitness: 0.0710, Time: 832.7s
#       Modality: D=17%, S=18%, Sk=19%, V=17%
#     Test Acc: 76.85%, F1: 75.04%, Features: 706/3933 (18.0%), Model: 1.920MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 87.96%, F1: 87.86%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 22.1s
#     Test Acc: 82.41%, F1: 81.29%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.0s
#     Test Acc: 85.19%, F1: 85.00%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.2s
#     Test Acc: 69.44%, F1: 66.31%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06961937452326465']
# ['At iteration 1 the best fitness is 0.06949224510551738']
# ['At iteration 2 the best fitness is 0.06949224510551738']
# ['At iteration 3 the best fitness is 0.06949224510551738']
# ['At iteration 4 the best fitness is 0.06949224510551738']
# ['At iteration 5 the best fitness is 0.06949224510551738']
# ['At iteration 6 the best fitness is 0.06949224510551738']
# ['At iteration 7 the best fitness is 0.06949224510551738']
# ['At iteration 8 the best fitness is 0.06949224510551738']
# ['At iteration 9 the best fitness is 0.0692634121535723']
# ['At iteration 10 the best fitness is 0.0692634121535723']
# ['At iteration 11 the best fitness is 0.0692634121535723']
# ['At iteration 12 the best fitness is 0.0692634121535723']
# ['At iteration 13 the best fitness is 0.0692634121535723']
# ['At iteration 14 the best fitness is 0.0692634121535723']
# ['At iteration 15 the best fitness is 0.0692634121535723']
# ['At iteration 16 the best fitness is 0.0692634121535723']
# ['At iteration 17 the best fitness is 0.06906000508517668']
# ['At iteration 18 the best fitness is 0.06906000508517668']
# ['At iteration 19 the best fitness is 0.06906000508517668']
# ['At iteration 20 the best fitness is 0.06906000508517668']
# ['At iteration 21 the best fitness is 0.06271395881006869']
# ['At iteration 22 the best fitness is 0.06254869056699724']
# ['At iteration 23 the best fitness is 0.06254869056699724']
# ['At iteration 24 the best fitness is 0.06254869056699724']
# ['At iteration 25 the best fitness is 0.06254869056699724']
# ['At iteration 26 the best fitness is 0.06254869056699724']
# ['At iteration 27 the best fitness is 0.06254869056699724']
# ['At iteration 28 the best fitness is 0.06254869056699724']
# ['At iteration 29 the best fitness is 0.06254869056699724']
#       Selected: 1935/3933 (49.2%), Fitness: 0.0625, Time: 908.9s
#       Modality: D=46%, S=47%, Sk=48%, V=51%
#     Test Acc: 83.33%, F1: 82.57%, Features: 1935/3933 (49.2%), Model: 4.320MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0630572082379863']
# ['At iteration 10 the best fitness is 0.05618993135011441']
# ['At iteration 20 the best fitness is 0.056037376048817686']
#       Selected: 1917/3933 (48.7%), Fitness: 0.0503, Time: 1797.5s
#       Modality: D=50%, S=51%, Sk=47%, V=49%
#     Test Acc: 87.04%, F1: 86.90%, Features: 1917/3933 (48.7%), Model: 4.285MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06299364352911267']
# ['At iteration 2 the best fitness is 0.06299364352911267']
# ['At iteration 3 the best fitness is 0.06249783879989833']
# ['At iteration 4 the best fitness is 0.06249783879989833']
# ['At iteration 5 the best fitness is 0.06249783879989833']
# ['At iteration 6 the best fitness is 0.06249783879989833']
# ['At iteration 7 the best fitness is 0.06249783879989833']
# ['At iteration 8 the best fitness is 0.06249783879989833']
# ['At iteration 9 the best fitness is 0.06249783879989833']
# ['At iteration 10 the best fitness is 0.06249783879989833']
# ['At iteration 11 the best fitness is 0.05640605136028476']
# ['At iteration 12 the best fitness is 0.05640605136028476']
# ['At iteration 13 the best fitness is 0.05640605136028476']
# ['At iteration 14 the best fitness is 0.05640605136028476']
# ['At iteration 15 the best fitness is 0.05640605136028476']
# ['At iteration 16 the best fitness is 0.05640605136028476']
# ['At iteration 17 the best fitness is 0.05640605136028476']
# ['At iteration 18 the best fitness is 0.05640605136028476']
# ['At iteration 19 the best fitness is 0.05640605136028476']
# ['At iteration 20 the best fitness is 0.05640605136028476']
# ['At iteration 21 the best fitness is 0.05640605136028476']
# ['At iteration 22 the best fitness is 0.05606280193236714']
# ['At iteration 23 the best fitness is 0.05606280193236714']
# ['At iteration 24 the best fitness is 0.05606280193236714']
# ['At iteration 25 the best fitness is 0.05606280193236714']
# ['At iteration 26 the best fitness is 0.055770404271548425']
# ['At iteration 27 the best fitness is 0.055770404271548425']
# ['At iteration 28 the best fitness is 0.055770404271548425']
# ['At iteration 29 the best fitness is 0.055770404271548425']
# ['At iteration 30 the best fitness is 0.055770404271548425']
#       Selected: 1953/3933 (49.7%), Fitness: 0.0558, Time: 912.8s
#       Modality: D=41%, S=51%, Sk=50%, V=50%
#     Test Acc: 87.96%, F1: 87.87%, Features: 1953/3933 (49.7%), Model: 4.356MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06277752351894232']
# ['At iteration 1 the best fitness is 0.07543147724383423']
# ['At iteration 2 the best fitness is 0.07505008899059243']
# ['At iteration 3 the best fitness is 0.06156979405034328']
# ['At iteration 4 the best fitness is 0.07494838545639462']
# ['At iteration 5 the best fitness is 0.07505008899059243']
# ['At iteration 6 the best fitness is 0.06847520976353925']
# ['At iteration 7 the best fitness is 0.07459242308670228']
# ['At iteration 8 the best fitness is 0.06817009916094581']
# ['At iteration 9 the best fitness is 0.06833536740401726']
# ['At iteration 10 the best fitness is 0.07460513602847699']
# ['At iteration 11 the best fitness is 0.06837350622934144']
# ['At iteration 12 the best fitness is 0.06841164505466563']
# ['At iteration 13 the best fitness is 0.07480854309687263']
# ['At iteration 14 the best fitness is 0.06211645054665653']
# ['At iteration 15 the best fitness is 0.0747958301550979']
# ['At iteration 16 the best fitness is 0.07487210780574625']
# ['At iteration 17 the best fitness is 0.07488482074752098']
# ['At iteration 18 the best fitness is 0.07488482074752098']
# ['At iteration 19 the best fitness is 0.07485939486397153']
# ['At iteration 20 the best fitness is 0.0748466819221968']
# ['At iteration 21 the best fitness is 0.08110373760488182']
# ['At iteration 22 the best fitness is 0.07477040427154844']
# ['At iteration 23 the best fitness is 0.07477040427154844']
# ['At iteration 24 the best fitness is 0.08110373760488182']
# ['At iteration 25 the best fitness is 0.07475769132977372']
# ['At iteration 26 the best fitness is 0.07477040427154844']
# ['At iteration 27 the best fitness is 0.062103737604881804']
# ['At iteration 28 the best fitness is 0.07477040427154844']
# ['At iteration 29 the best fitness is 0.08743707093821508']
#       Selected: 1924/3933 (48.9%), Fitness: 0.0874, Time: 880.7s
#       Modality: D=49%, S=46%, Sk=50%, V=49%
#     Test Acc: 83.33%, F1: 82.60%, Features: 1924/3933 (48.9%), Model: 4.299MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.08149783879989835
# At iteration 2 the best fitness is 0.06296821764556322
# At iteration 3 the best fitness is 0.06296821764556322
# At iteration 4 the best fitness is 0.06279023646071705
# At iteration 5 the best fitness is 0.0690218662598525
# At iteration 6 the best fitness is 0.06289193999491485
# At iteration 7 the best fitness is 0.06270124586829395
# At iteration 8 the best fitness is 0.06320976353928302
# At iteration 9 the best fitness is 0.06874218154080851
# At iteration 10 the best fitness is 0.06323518942283247
# At iteration 11 the best fitness is 0.0631970505975083
# At iteration 12 the best fitness is 0.06889473684210523
# At iteration 13 the best fitness is 0.0631461988304094
# At iteration 14 the best fitness is 0.06916170861937448
# At iteration 15 the best fitness is 0.05030155097889647
# At iteration 16 the best fitness is 0.06271395881006869
# At iteration 17 the best fitness is 0.056736587846427655
# At iteration 18 the best fitness is 0.05653318077803203
# At iteration 19 the best fitness is 0.05662217137045511
# At iteration 20 the best fitness is 0.06284108822781595
# At iteration 21 the best fitness is 0.056609458428680384
# At iteration 22 the best fitness is 0.05033968980422065
# At iteration 23 the best fitness is 0.05664759725400457
# At iteration 24 the best fitness is 0.056469616069158395
# At iteration 25 the best fitness is 0.06289193999491485
# At iteration 26 the best fitness is 0.056545893719806756
# At iteration 27 the best fitness is 0.050504958047292096
# At iteration 28 the best fitness is 0.056736587846427655
# At iteration 29 the best fitness is 0.056660310195779294
# At iteration 30 the best fitness is 0.05672387490465293
#       Selected: 2018/3933 (51.3%), Fitness: 0.0567, Time: 884.1s
#       Modality: D=53%, S=51%, Sk=52%, V=50%
#     Test Acc: 86.11%, F1: 85.52%, Features: 2018/3933 (51.3%), Model: 4.483MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06944139333841848']
# ['At iteration 1 the best fitness is 0.06220544113907962']
# ['At iteration 2 the best fitness is 0.06220544113907962']
# ['At iteration 3 the best fitness is 0.055045766590389004']
# ['At iteration 4 the best fitness is 0.055045766590389004']
# ['At iteration 5 the best fitness is 0.055045766590389004']
# ['At iteration 6 the best fitness is 0.053405797101449264']
# ['At iteration 7 the best fitness is 0.053405797101449264']
# ['At iteration 8 the best fitness is 0.053405797101449264']
# ['At iteration 9 the best fitness is 0.053405797101449264']
# ['At iteration 10 the best fitness is 0.053405797101449264']
# ['At iteration 11 the best fitness is 0.053405797101449264']
# ['At iteration 12 the best fitness is 0.05298627002288329']
# ['At iteration 13 the best fitness is 0.05293541825578438']
# ['At iteration 14 the best fitness is 0.052376048817696405']
# ['At iteration 15 the best fitness is 0.052376048817696405']
# ['At iteration 16 the best fitness is 0.052376048817696405']
# ['At iteration 17 the best fitness is 0.052376048817696405']
# ['At iteration 18 the best fitness is 0.05228705822527332']
# ['At iteration 19 the best fitness is 0.052185354691075506']
# ['At iteration 20 the best fitness is 0.052185354691075506']
# ['At iteration 21 the best fitness is 0.052134502923976596']
# ['At iteration 22 the best fitness is 0.052134502923976596']
# ['At iteration 23 the best fitness is 0.052134502923976596']
# ['At iteration 24 the best fitness is 0.052134502923976596']
# ['At iteration 25 the best fitness is 0.052134502923976596']
# ['At iteration 26 the best fitness is 0.052134502923976596']
# ['At iteration 27 the best fitness is 0.052134502923976596']
# ['At iteration 28 the best fitness is 0.052134502923976596']
# ['At iteration 29 the best fitness is 0.052134502923976596']
#       Selected: 1680/3933 (42.7%), Fitness: 0.0521, Time: 888.7s
#       Modality: D=51%, S=43%, Sk=44%, V=40%
#     Test Acc: 84.26%, F1: 83.70%, Features: 1680/3933 (42.7%), Model: 3.822MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.07585100432240022']
# ['At iteration 1 the best fitness is 0.07585100432240022']
# ['At iteration 2 the best fitness is 0.07585100432240022']
# ['At iteration 3 the best fitness is 0.07585100432240022']
# ['At iteration 4 the best fitness is 0.07585100432240022']
# ['At iteration 5 the best fitness is 0.07081667937960845']
# ['At iteration 6 the best fitness is 0.07081667937960845']
# ['At iteration 7 the best fitness is 0.07081667937960845']
# ['At iteration 8 the best fitness is 0.06475031782354435']
# ['At iteration 9 the best fitness is 0.06475031782354435']
# ['At iteration 10 the best fitness is 0.06475031782354435']
# ['At iteration 11 the best fitness is 0.06475031782354435']
# ['At iteration 12 the best fitness is 0.06475031782354435']
# ['At iteration 13 the best fitness is 0.06475031782354435']
# ['At iteration 14 the best fitness is 0.06475031782354435']
# ['At iteration 15 the best fitness is 0.06475031782354435']
# ['At iteration 16 the best fitness is 0.06475031782354435']
# ['At iteration 17 the best fitness is 0.06475031782354435']
# ['At iteration 18 the best fitness is 0.06475031782354435']
# ['At iteration 19 the best fitness is 0.06475031782354435']
# ['At iteration 20 the best fitness is 0.06475031782354435']
# ['At iteration 21 the best fitness is 0.06475031782354435']
# ['At iteration 22 the best fitness is 0.06472489193999488']
# ['At iteration 23 the best fitness is 0.06472489193999488']
# ['At iteration 24 the best fitness is 0.06472489193999488']
# ['At iteration 25 the best fitness is 0.06472489193999488']
# ['At iteration 26 the best fitness is 0.06472489193999488']
# ['At iteration 27 the best fitness is 0.06472489193999488']
# ['At iteration 28 the best fitness is 0.06472489193999488']
# ['At iteration 29 the best fitness is 0.06472489193999488']
#       Selected: 1605/3933 (40.8%), Fitness: 0.0647, Time: 1161.0s
#       Modality: D=43%, S=42%, Sk=41%, V=40%
#     Test Acc: 82.41%, F1: 82.51%, Features: 1605/3933 (40.8%), Model: 3.676MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07601627256547167']
# ['At iteration 1 the best fitness is 0.06306992117976103']
# ['At iteration 2 the best fitness is 0.06306992117976103']
# ['At iteration 3 the best fitness is 0.06306992117976103']
# ['At iteration 4 the best fitness is 0.06306992117976103']
# ['At iteration 5 the best fitness is 0.0507465039410119']
# ['At iteration 6 the best fitness is 0.0507465039410119']
# ['At iteration 7 the best fitness is 0.0507465039410119']
# ['At iteration 8 the best fitness is 0.0507465039410119']
# ['At iteration 9 the best fitness is 0.0507465039410119']
# ['At iteration 10 the best fitness is 0.0507465039410119']
# ['At iteration 11 the best fitness is 0.0507465039410119']
# ['At iteration 12 the best fitness is 0.0507465039410119']
# ['At iteration 13 the best fitness is 0.0507465039410119']
# ['At iteration 14 the best fitness is 0.0507465039410119']
# ['At iteration 15 the best fitness is 0.0507465039410119']
# ['At iteration 16 the best fitness is 0.0507465039410119']
# ['At iteration 17 the best fitness is 0.0507465039410119']
# ['At iteration 18 the best fitness is 0.0507465039410119']
# ['At iteration 19 the best fitness is 0.0507465039410119']
# ['At iteration 20 the best fitness is 0.0507465039410119']
# ['At iteration 21 the best fitness is 0.0507465039410119']
# ['At iteration 22 the best fitness is 0.0507465039410119']
# ['At iteration 23 the best fitness is 0.0507465039410119']
# ['At iteration 24 the best fitness is 0.0507465039410119']
# ['At iteration 25 the best fitness is 0.0507465039410119']
# ['At iteration 26 the best fitness is 0.0507465039410119']
# ['At iteration 27 the best fitness is 0.0507465039410119']
# ['At iteration 28 the best fitness is 0.0507465039410119']
# ['At iteration 29 the best fitness is 0.0507465039410119']
#       Selected: 2008/3933 (51.1%), Fitness: 0.0507, Time: 909.6s
#       Modality: D=57%, S=49%, Sk=51%, V=52%
#     Test Acc: 86.11%, F1: 85.83%, Features: 2008/3933 (51.1%), Model: 4.463MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08229875413170612']
# ['At iteration 2 the best fitness is 0.0757493007882024']
# ['At iteration 3 the best fitness is 0.0757493007882024']
# ['At iteration 4 the best fitness is 0.0757493007882024']
# ['At iteration 5 the best fitness is 0.05748665141113653']
# ['At iteration 6 the best fitness is 0.05748665141113653']
# ['At iteration 7 the best fitness is 0.05748665141113653']
# ['At iteration 8 the best fitness is 0.05748665141113653']
# ['At iteration 9 the best fitness is 0.05748665141113653']
# ['At iteration 10 the best fitness is 0.05748665141113653']
# ['At iteration 11 the best fitness is 0.05748665141113653']
# ['At iteration 12 the best fitness is 0.05748665141113653']
# ['At iteration 13 the best fitness is 0.05748665141113653']
# ['At iteration 14 the best fitness is 0.05748665141113653']
# ['At iteration 15 the best fitness is 0.05748665141113653']
# ['At iteration 16 the best fitness is 0.05748665141113653']
# ['At iteration 17 the best fitness is 0.05748665141113653']
# ['At iteration 18 the best fitness is 0.05687643020594965']
# ['At iteration 19 the best fitness is 0.05687643020594965']
# ['At iteration 20 the best fitness is 0.05687643020594965']
# ['At iteration 21 the best fitness is 0.05687643020594965']
# ['At iteration 22 the best fitness is 0.05687643020594965']
# ['At iteration 23 the best fitness is 0.05687643020594965']
# ['At iteration 24 the best fitness is 0.05687643020594965']
# ['At iteration 25 the best fitness is 0.05687643020594965']
# ['At iteration 26 the best fitness is 0.05687643020594965']
# ['At iteration 27 the best fitness is 0.05687643020594965']
# ['At iteration 28 the best fitness is 0.05687643020594965']
# ['At iteration 29 the best fitness is 0.05687643020594965']
#       Selected: 1985/3933 (50.5%), Fitness: 0.0569, Time: 860.8s
#       Modality: D=50%, S=51%, Sk=50%, V=51%
#     Test Acc: 87.04%, F1: 86.46%, Features: 1985/3933 (50.5%), Model: 4.418MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07582557843885077']
# ['At iteration 2 the best fitness is 0.06301906941266212']
# ['At iteration 3 the best fitness is 0.06301906941266212']
# ['At iteration 4 the best fitness is 0.06301906941266212']
# ['At iteration 5 the best fitness is 0.05718154080854309']
# ['At iteration 6 the best fitness is 0.05718154080854309']
# ['At iteration 7 the best fitness is 0.05718154080854309']
# ['At iteration 8 the best fitness is 0.05718154080854309']
# ['At iteration 9 the best fitness is 0.05718154080854309']
# ['At iteration 10 the best fitness is 0.05716882786676836']
# ['At iteration 11 the best fitness is 0.05078464276633608']
# ['At iteration 12 the best fitness is 0.05078464276633608']
# ['At iteration 13 the best fitness is 0.05078464276633608']
# ['At iteration 14 the best fitness is 0.05078464276633608']
# ['At iteration 15 the best fitness is 0.05078464276633608']
# ['At iteration 16 the best fitness is 0.05078464276633608']
# ...
# ['At iteration 15 the best fitness is 0.04688176964149499']
# ['At iteration 16 the best fitness is 0.04688176964149499']
# ['At iteration 17 the best fitness is 0.04688176964149499']
# ['At iteration 18 the best fitness is 0.04688176964149499']
# ['At iteration 19 the best fitness is 0.04688176964149499']
# ['At iteration 20 the best fitness is 0.04688176964149499']
# ['At iteration 21 the best fitness is 0.04688176964149499']
# ['At iteration 22 the best fitness is 0.04688176964149499']
# ['At iteration 23 the best fitness is 0.04688176964149499']
# ['At iteration 24 the best fitness is 0.04596643783371467']
# ['At iteration 25 the best fitness is 0.04596643783371467']
# ['At iteration 26 the best fitness is 0.04596643783371467']
# ['At iteration 27 the best fitness is 0.04596643783371467']
# ['At iteration 28 the best fitness is 0.04596643783371467']
# ['At iteration 29 the best fitness is 0.04596643783371467']
#       Selected: 1577/3933 (40.1%), Fitness: 0.0460, Time: 835.2s
#       Modality: D=45%, S=40%, Sk=40%, V=40%
#     Test Acc: 86.92%, F1: 85.28%, Features: 1577/3933 (40.1%), Model: 3.621MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05663488431222984']
# ['At iteration 1 the best fitness is 0.05663488431222984']
# ['At iteration 2 the best fitness is 0.05070836511568772']
# ['At iteration 3 the best fitness is 0.05070836511568772']
# ['At iteration 4 the best fitness is 0.05070836511568772']
# ['At iteration 5 the best fitness is 0.04414619883040938']
# ['At iteration 6 the best fitness is 0.04414619883040938']
# ['At iteration 7 the best fitness is 0.04414619883040938']
# ['At iteration 8 the best fitness is 0.04400635647088738']
# ['At iteration 9 the best fitness is 0.04400635647088738']
# ['At iteration 10 the best fitness is 0.04400635647088738']
# ['At iteration 11 the best fitness is 0.04400635647088738']
# ['At iteration 12 the best fitness is 0.04400635647088738']
# ['At iteration 13 the best fitness is 0.04400635647088738']
# ['At iteration 14 the best fitness is 0.04400635647088738']
# ['At iteration 15 the best fitness is 0.04394279176201375']
# ['At iteration 16 the best fitness is 0.04394279176201375']
# ['At iteration 17 the best fitness is 0.04394279176201375']
# ['At iteration 18 the best fitness is 0.04394279176201375']
# ['At iteration 19 the best fitness is 0.04394279176201375']
# ['At iteration 20 the best fitness is 0.04394279176201375']
# ['At iteration 21 the best fitness is 0.04394279176201375']
# ['At iteration 22 the best fitness is 0.04394279176201375']
# ['At iteration 23 the best fitness is 0.04394279176201375']
# ['At iteration 24 the best fitness is 0.04394279176201375']
# ['At iteration 25 the best fitness is 0.04394279176201375']
# ['At iteration 26 the best fitness is 0.04394279176201375']
# ['At iteration 27 the best fitness is 0.04394279176201375']
# ['At iteration 28 the best fitness is 0.04394279176201375']
# ['At iteration 29 the best fitness is 0.04394279176201375']
#       Selected: 1938/3933 (49.3%), Fitness: 0.0439, Time: 639.6s
#       Modality: D=46%, S=50%, Sk=51%, V=47%
#     Test Acc: 85.05%, F1: 84.68%, Features: 1938/3933 (49.3%), Model: 4.326MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06263768115942032']
# ['At iteration 2 the best fitness is 0.05640605136028476']
# ['At iteration 3 the best fitness is 0.05075921688278663']
# ['At iteration 4 the best fitness is 0.05075921688278663']
# ['At iteration 5 the best fitness is 0.03759674548690565']
# ['At iteration 6 the best fitness is 0.03759674548690565']
# ['At iteration 7 the best fitness is 0.03759674548690565']
# ['At iteration 8 the best fitness is 0.03759674548690565']
# ['At iteration 9 the best fitness is 0.03759674548690565']
# ['At iteration 10 the best fitness is 0.03759674548690565']
# ['At iteration 11 the best fitness is 0.03759674548690565']
# ['At iteration 12 the best fitness is 0.03759674548690565']
# ['At iteration 13 the best fitness is 0.03759674548690565']
# ['At iteration 14 the best fitness is 0.03759674548690565']
# ['At iteration 15 the best fitness is 0.03759674548690565']
# ['At iteration 16 the best fitness is 0.03759674548690565']
# ['At iteration 17 the best fitness is 0.03759674548690565']
# ['At iteration 18 the best fitness is 0.03759674548690565']
# ['At iteration 19 the best fitness is 0.03759674548690565']
# ['At iteration 20 the best fitness is 0.03759674548690565']
# ['At iteration 21 the best fitness is 0.03759674548690565']
# ['At iteration 22 the best fitness is 0.03759674548690565']
# ['At iteration 23 the best fitness is 0.03759674548690565']
# ['At iteration 24 the best fitness is 0.03759674548690565']
# ['At iteration 25 the best fitness is 0.03759674548690565']
# ['At iteration 26 the best fitness is 0.03759674548690565']
# ['At iteration 27 the best fitness is 0.03759674548690565']
# ['At iteration 28 the best fitness is 0.03759674548690565']
# ['At iteration 29 the best fitness is 0.03759674548690565']
#       Selected: 1946/3933 (49.5%), Fitness: 0.0376, Time: 604.9s
#       Modality: D=49%, S=50%, Sk=49%, V=50%
#     Test Acc: 86.92%, F1: 85.90%, Features: 1946/3933 (49.5%), Model: 4.342MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0569018560894991']
# ['At iteration 2 the best fitness is 0.05054309687261628']
# ['At iteration 3 the best fitness is 0.05054309687261628']
# ['At iteration 4 the best fitness is 0.05054309687261628']
# ['At iteration 5 the best fitness is 0.04465471650139844']
# ['At iteration 6 the best fitness is 0.04465471650139844']
# ['At iteration 7 the best fitness is 0.04465471650139844']
# ['At iteration 8 the best fitness is 0.04465471650139844']
# ['At iteration 9 the best fitness is 0.04465471650139844']
# ['At iteration 10 the best fitness is 0.04465471650139844']
# ['At iteration 11 the best fitness is 0.04465471650139844']
# ['At iteration 12 the best fitness is 0.04465471650139844']
# ['At iteration 13 the best fitness is 0.04465471650139844']
# ['At iteration 14 the best fitness is 0.04465471650139844']
# ['At iteration 15 the best fitness is 0.04465471650139844']
# ['At iteration 16 the best fitness is 0.04465471650139844']
# ['At iteration 17 the best fitness is 0.04465471650139844']
# ['At iteration 18 the best fitness is 0.04465471650139844']
# ['At iteration 19 the best fitness is 0.044591151792524805']
# ['At iteration 20 the best fitness is 0.044591151792524805']
# ['At iteration 21 the best fitness is 0.044591151792524805']
# ['At iteration 22 the best fitness is 0.044591151792524805']
# ['At iteration 23 the best fitness is 0.044591151792524805']
# ['At iteration 24 the best fitness is 0.044591151792524805']
# ['At iteration 25 the best fitness is 0.044591151792524805']
# ['At iteration 26 the best fitness is 0.044591151792524805']
# ['At iteration 27 the best fitness is 0.044591151792524805']
# ['At iteration 28 the best fitness is 0.044591151792524805']
# ['At iteration 29 the best fitness is 0.044591151792524805']
# ['At iteration 30 the best fitness is 0.044591151792524805']
#       Selected: 2025/3933 (51.5%), Fitness: 0.0446, Time: 621.2s
#       Modality: D=54%, S=53%, Sk=49%, V=53%
#     Test Acc: 85.98%, F1: 85.35%, Features: 2025/3933 (51.5%), Model: 4.496MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05072107805746245']
# ['At iteration 2 the best fitness is 0.0447309941520468']
# ['At iteration 3 the best fitness is 0.0447309941520468']
# ['At iteration 4 the best fitness is 0.0447309941520468']
# ['At iteration 5 the best fitness is 0.0447309941520468']
# ['At iteration 6 the best fitness is 0.0447309941520468']
# ['At iteration 7 the best fitness is 0.0447309941520468']
# ['At iteration 8 the best fitness is 0.0447309941520468']
# ['At iteration 9 the best fitness is 0.0447309941520468']
# ['At iteration 10 the best fitness is 0.0447309941520468']
# ['At iteration 11 the best fitness is 0.0447309941520468']
# ['At iteration 12 the best fitness is 0.0447309941520468']
# ['At iteration 13 the best fitness is 0.0447309941520468']
# ['At iteration 14 the best fitness is 0.0447309941520468']
# ['At iteration 15 the best fitness is 0.0447309941520468']
# ['At iteration 16 the best fitness is 0.0447309941520468']
# ['At iteration 17 the best fitness is 0.0447309941520468']
# ['At iteration 18 the best fitness is 0.0447309941520468']
# ['At iteration 19 the best fitness is 0.044108060005085194']
# ['At iteration 20 the best fitness is 0.044108060005085194']
# ['At iteration 21 the best fitness is 0.044108060005085194']
# ['At iteration 22 the best fitness is 0.044108060005085194']
# ['At iteration 23 the best fitness is 0.044108060005085194']
# ['At iteration 24 the best fitness is 0.044108060005085194']
# ['At iteration 25 the best fitness is 0.044108060005085194']
# ['At iteration 26 the best fitness is 0.044108060005085194']
# ['At iteration 27 the best fitness is 0.044108060005085194']
# ['At iteration 28 the best fitness is 0.044108060005085194']
# ['At iteration 29 the best fitness is 0.044108060005085194']
# ['At iteration 30 the best fitness is 0.044108060005085194']
#       Selected: 1968/3933 (50.0%), Fitness: 0.0441, Time: 617.0s
#       Modality: D=52%, S=53%, Sk=51%, V=47%
#     Test Acc: 90.65%, F1: 90.39%, Features: 1968/3933 (50.0%), Model: 4.385MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.044209763539283006']
# ['At iteration 1 the best fitness is 0.044209763539283006']
# ['At iteration 2 the best fitness is 0.044209763539283006']
# ['At iteration 3 the best fitness is 0.044209763539283006']
# ['At iteration 4 the best fitness is 0.044209763539283006']
# ['At iteration 5 the best fitness is 0.044209763539283006']
# ['At iteration 6 the best fitness is 0.044209763539283006']
# ['At iteration 7 the best fitness is 0.044209763539283006']
# ['At iteration 8 the best fitness is 0.044209763539283006']
# ['At iteration 9 the best fitness is 0.044209763539283006']
# ['At iteration 10 the best fitness is 0.044209763539283006']
# ['At iteration 11 the best fitness is 0.044209763539283006']
# ['At iteration 12 the best fitness is 0.044209763539283006']
# ['At iteration 13 the best fitness is 0.044209763539283006']
# ['At iteration 14 the best fitness is 0.044209763539283006']
# ['At iteration 15 the best fitness is 0.044209763539283006']
# ['At iteration 16 the best fitness is 0.044209763539283006']
# ['At iteration 17 the best fitness is 0.044209763539283006']
# ['At iteration 18 the best fitness is 0.044209763539283006']
# ['At iteration 19 the best fitness is 0.044209763539283006']
# ['At iteration 20 the best fitness is 0.044209763539283006']
# ['At iteration 21 the best fitness is 0.044209763539283006']
# ['At iteration 22 the best fitness is 0.044209763539283006']
# ['At iteration 23 the best fitness is 0.044209763539283006']
# ['At iteration 24 the best fitness is 0.044209763539283006']
# ['At iteration 25 the best fitness is 0.044209763539283006']
# ['At iteration 26 the best fitness is 0.044209763539283006']
# ['At iteration 27 the best fitness is 0.044209763539283006']
# ['At iteration 28 the best fitness is 0.044209763539283006']
# ['At iteration 29 the best fitness is 0.044209763539283006']
#       Selected: 1985/3933 (50.5%), Fitness: 0.0442, Time: 593.1s
#       Modality: D=50%, S=52%, Sk=49%, V=51%
#     Test Acc: 89.72%, F1: 88.92%, Features: 1985/3933 (50.5%), Model: 4.418MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05046681922196792']
# ['At iteration 2 the best fitness is 0.05046681922196792']
# ['At iteration 3 the best fitness is 0.05046681922196792']
# ['At iteration 4 the best fitness is 0.04356140350877195']
# ['At iteration 5 the best fitness is 0.04356140350877195']
# ['At iteration 6 the best fitness is 0.04356140350877195']
# ['At iteration 7 the best fitness is 0.04356140350877195']
# ['At iteration 8 the best fitness is 0.04356140350877195']
# ['At iteration 9 the best fitness is 0.04356140350877195']
# ['At iteration 10 the best fitness is 0.04356140350877195']
# ['At iteration 11 the best fitness is 0.04356140350877195']
# ['At iteration 12 the best fitness is 0.04356140350877195']
# ['At iteration 13 the best fitness is 0.04356140350877195']
# ['At iteration 14 the best fitness is 0.04356140350877195']
# ['At iteration 15 the best fitness is 0.04356140350877195']
# ['At iteration 16 the best fitness is 0.04356140350877195']
# ['At iteration 17 the best fitness is 0.04356140350877195']
# ['At iteration 18 the best fitness is 0.04356140350877195']
# ['At iteration 19 the best fitness is 0.04356140350877195']
# ['At iteration 20 the best fitness is 0.04356140350877195']
# ['At iteration 21 the best fitness is 0.04356140350877195']
# ['At iteration 22 the best fitness is 0.04356140350877195']
# ['At iteration 23 the best fitness is 0.04356140350877195']
# ['At iteration 24 the best fitness is 0.04356140350877195']
# ['At iteration 25 the best fitness is 0.04356140350877195']
# ['At iteration 26 the best fitness is 0.04356140350877195']
# ['At iteration 27 the best fitness is 0.04356140350877195']
# ['At iteration 28 the best fitness is 0.04356140350877195']
# ['At iteration 29 the best fitness is 0.04356140350877195']
#       Selected: 1946/3933 (49.5%), Fitness: 0.0436, Time: 1544.7s
#       Modality: D=50%, S=51%, Sk=49%, V=50%
#     Test Acc: 86.92%, F1: 85.79%, Features: 1946/3933 (49.5%), Model: 4.342MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.057359521993389256']
# ['At iteration 1 the best fitness is 0.04633740147470124']
# ['At iteration 2 the best fitness is 0.04529265191965416']
# ['At iteration 3 the best fitness is 0.04529265191965416']
# ['At iteration 4 the best fitness is 0.04529265191965416']
# ['At iteration 5 the best fitness is 0.04529265191965416']
# ['At iteration 6 the best fitness is 0.04529265191965416']
# ['At iteration 7 the best fitness is 0.04529265191965416']
# ['At iteration 8 the best fitness is 0.04529265191965416']
# ['At iteration 9 the best fitness is 0.04529265191965416']
# ['At iteration 10 the best fitness is 0.04529265191965416']
# ['At iteration 11 the best fitness is 0.04529265191965416']
# ['At iteration 12 the best fitness is 0.04529265191965416']
# ['At iteration 13 the best fitness is 0.04529265191965416']
# ['At iteration 14 the best fitness is 0.04529265191965416']
# ['At iteration 15 the best fitness is 0.04529265191965416']
# ['At iteration 16 the best fitness is 0.04529265191965416']
# ['At iteration 17 the best fitness is 0.04529265191965416']
# ['At iteration 18 the best fitness is 0.04529265191965416']
# ['At iteration 19 the best fitness is 0.04529265191965416']
# ['At iteration 20 the best fitness is 0.04529265191965416']
# ['At iteration 21 the best fitness is 0.04529265191965416']
# ['At iteration 22 the best fitness is 0.04529265191965416']
# ['At iteration 23 the best fitness is 0.04529265191965416']
# ['At iteration 24 the best fitness is 0.04529265191965416']
# ['At iteration 25 the best fitness is 0.04529265191965416']
# ['At iteration 26 the best fitness is 0.04529265191965416']
# ['At iteration 27 the best fitness is 0.04529265191965416']
# ['At iteration 28 the best fitness is 0.04529265191965416']
# ['At iteration 29 the best fitness is 0.04529265191965416']
#       Selected: 1528/3933 (38.9%), Fitness: 0.0453, Time: 528.2s
#       Modality: D=39%, S=41%, Sk=38%, V=39%
#     Test Acc: 86.92%, F1: 85.97%, Features: 1528/3933 (38.9%), Model: 3.526MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_new_25_loss/all_results_per_fold.csv
# Shape: (144, 28)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            87.9630           94.0000       87.5191          87.5191              90.7407           87.9630               3933            3933               100.0000       0.0000         15.0917         15.0917       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 1      baseline     2            87.9630           95.3333       87.8638          87.8638              90.8466           87.9630               3933            3933               100.0000       0.0000         15.8006         15.8006       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 2      baseline     3            82.4074           92.6667       81.5267          81.5267              87.3251           82.4074               3933            3933               100.0000       0.0000         15.8076         15.8076       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 3      baseline     4            84.2593           94.6667       82.6965          82.6965              86.3644           84.2593               3933            3933               100.0000       0.0000         15.4721         15.4721       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 4      baseline     5            70.3704           97.3333       67.2485          67.2485              72.5926           70.3704               3933            3933               100.0000       0.0000         16.0606         16.0606       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 5      baseline     6            89.7196           96.0000       89.1486          89.0472              92.7337           89.8148               3933            3933               100.0000       0.0000         15.5256         15.5256       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 6      baseline     7            86.9159           97.3333       86.3944          86.4008              91.3374           87.0370               3933            3933               100.0000       0.0000         12.2218         12.2218       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 7      baseline     8            89.7196           97.3333       89.1093          89.4749              92.7778           89.1975               3933            3933               100.0000       0.0000         12.7287         12.7287       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 8   mutual_info     1            89.8148           97.3333       89.1593          89.1593              93.2099           89.8148               1966            3933                49.9873      22.7323          9.6019         32.3343       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              21.7593              47               68.8650              449                 32.1581                529              66.2676             941
# 9   mutual_info     2            82.4074           96.0000       81.2934          81.2934              86.4374           82.4074               1966            3933                49.9873      22.1215         12.6363         34.7579       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              16.6667              36               68.8650              449                 32.4620                534              66.6901             947
# 10  mutual_info     3            83.3333           93.3333       82.7543          82.7543              87.3457           83.3333               1966            3933                49.9873      22.1955         12.5203         34.7160       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              22.2222              48               68.0982              444                 31.0638                511              67.8169             963
# 11  mutual_info     4            79.6296           94.0000       77.6901          77.6901              84.8971           79.6296               1966            3933                49.9873      21.9494         10.3001         32.2496       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              19.4444              42               68.8650              449                 32.4012                533              66.3380             942
# 12  mutual_info     5            84.2593           98.0000       83.3510          83.3510              87.2840           84.2593               1966            3933                49.9873      22.3187         12.9144         35.2332       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              19.9074              43               66.8712              436                 32.8875                541              66.6197             946
# 13  mutual_info     6            87.8505           94.6667       87.0459          86.9248              90.9259           87.9630               1966            3933                49.9873      22.2223         12.6019         34.8243       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              17.5926              38               69.0184              450                 33.1915                546              65.6338             932
# 14  mutual_info     7            85.0467           94.0000       84.6248          84.6146              90.5002           85.1852               1966            3933                49.9873      21.8022          9.5899         31.3923       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              22.6852              49               67.0245              437                 33.0091                543              65.9859             937
# 15  mutual_info     8            85.9813           97.3333       83.7770          83.8123              86.0779           85.8025               1966            3933                49.9873      22.0742          9.7241         31.7984       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              22.2222              48               69.1718              451                 31.7933                523              66.4789             944
# 16          rfe     1            90.7407           96.0000       90.8885          90.8885              93.0071           90.7407               1966            3933                49.9873       4.1184         11.2920         15.4106       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              87.5000             189               55.2147              360                 27.1125                446              68.3803             971
# 17          rfe     2            85.1852           95.3333       84.9992          84.9992              88.9242           85.1852               1966            3933                49.9873       4.0409         13.8992         17.9402       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              95.3704             206               50.1534              327                 32.3404                532              63.4507             901
# 18          rfe     3            78.7037           93.3333       78.5509          78.5509              86.7078           78.7037               1966            3933                49.9873       4.0687         12.3308         16.3998       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              91.6667             198               50.1534              327                 31.6717                521              64.7887             920
# 19          rfe     4            80.5556           94.6667       80.1186          80.1186              84.7163           80.5556               1966            3933                49.9873       4.0313         12.2409         16.2724       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              87.5000             189               51.6871              337                 32.1581                529              64.1549             911

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              84.91              6.40              83.94              7.31                 3933.00                      100.00              0.00                14.84                14.84          2154011.0                  8.22                        0.00               67.05
# mutual_info              84.79              3.18              83.71              3.48                 1966.00                       49.99             22.18                11.24                33.41          1146907.0                  4.38                       50.01               44.47
#         rfe              85.61              4.51              85.03              4.40                 1966.00                       49.99              4.08                11.78                15.86          1146907.0                  4.38                       50.01               44.47
#       lasso              68.09             12.97              65.37             13.94                 1966.00                       49.99              1.21                11.70                12.91          1146907.0                  4.38                       50.01               44.47
#    meta_BAT              79.93             14.78              79.20             14.63                 1957.62                       49.77            837.17                12.10               849.27          1142619.0                  4.36                       50.23               44.51
#     meta_CS              78.53             16.41              77.74             15.91                 1937.12                       49.25           1660.15                12.15              1672.31          1132123.0                  4.32                       50.75               44.47
#     meta_DE              84.91              5.45              84.03              5.55                 1948.62                       49.55            841.45                12.15               853.59          1138011.0                  4.35                       50.45               44.47
#    meta_FFA              82.01              6.00              80.86              6.26                 1942.88                       49.40            813.42                12.15               825.57          1135067.0                  4.34                       50.60               44.48
#     meta_GA              82.47              5.17              81.62              4.91                 1940.25                       49.33            816.84                12.09               828.92          1133723.0                  4.33                       50.67               44.49
#    meta_GWO              81.54              4.72              80.13              5.52                 1658.12                       42.16            826.39                11.87               838.26           989275.0                  3.78                       57.84               40.94
#    meta_HHO              81.08              6.97              79.78              7.62                 1392.88                       35.42           1059.53                11.26              1070.80           853467.0                  3.26                       64.58               37.21
#   meta_JAYA              82.23              3.57              81.00              3.79                 1968.75                       50.06            809.30                11.85               821.15          1148315.0                  4.39                       49.94               44.54
#    meta_MFO              83.52              5.46              82.65              5.97                 1984.38                       50.45            764.92                11.83               776.75          1156315.0                  4.42                       49.55               44.55
#    meta_MVO              81.66              5.58              80.19              6.73                 1966.75                       50.01            782.59                11.75               794.35          1147291.0                  4.38                       49.99               44.53
#    meta_PSO              84.45              6.45              83.79              6.77                 1936.12                       49.23            784.99                11.71               796.70          1131611.0                  4.32                       50.77               44.35
#    meta_SCA              80.16              7.22              78.97              7.66                 1170.50                       29.76            745.50                10.90               756.41           739611.0                  2.83                       70.24               35.09
#    meta_SSA              78.89             13.97              78.47             13.46                 1953.25                       49.66           1958.82                11.73              1970.55          1140379.0                  4.36                       50.34               44.48
#    meta_WOA              81.66              3.59              80.48              3.97                 1598.12                       40.63            735.91                10.83               746.75           958555.0                  3.66                       59.37               39.77

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 84.79% vs Baseline: 84.91%
#   Paired t-test: t=-0.0566, p=0.9564
#   Wilcoxon test: W=11.0000, p=0.3828
#   -> worse, Not significant
#
# RFE vs BASELINE:
#   Method: 85.61% vs Baseline: 84.91%
#   Paired t-test: t=0.3428, p=0.7418
#   Wilcoxon test: W=18.0000, p=1.0000
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 68.09% vs Baseline: 84.91%
#   Paired t-test: t=-6.4675, p=0.0003
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 79.93% vs Baseline: 84.91%
#   Paired t-test: t=-1.5997, p=0.1537
#   Wilcoxon test: W=3.0000, p=0.0781
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 78.53% vs Baseline: 84.91%
#   Paired t-test: t=-1.6852, p=0.1358
#   Wilcoxon test: W=4.5000, p=0.0625
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 84.91% vs Baseline: 84.91%
#   Paired t-test: t=0.0000, p=1.0000
#   Wilcoxon test: W=7.0000, p=1.0000
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 82.01% vs Baseline: 84.91%
#   Paired t-test: t=-4.0919, p=0.0046
#   Wilcoxon test: W=0.0000, p=0.0156
#   -> worse, Significant
#
# META_GA vs BASELINE:
#   Method: 82.47% vs Baseline: 84.91%
#   Paired t-test: t=-2.5881, p=0.0360
#   Wilcoxon test: W=2.0000, p=0.0469
#   -> worse, Significant
#
# META_GWO vs BASELINE:
#   Method: 81.54% vs Baseline: 84.91%
#   Paired t-test: t=-1.9751, p=0.0888
#   Wilcoxon test: W=6.0000, p=0.1094
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 81.08% vs Baseline: 84.91%
#   Paired t-test: t=-3.3511, p=0.0122
#   Wilcoxon test: W=1.0000, p=0.0156
#   -> worse, Significant
#
# META_JAYA vs BASELINE:
#   Method: 82.23% vs Baseline: 84.91%
#   Paired t-test: t=-1.3653, p=0.2144
#   Wilcoxon test: W=8.0000, p=0.1797
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 83.52% vs Baseline: 84.91%
#   Paired t-test: t=-1.8224, p=0.1112
#   Wilcoxon test: W=3.0000, p=0.1562
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 81.66% vs Baseline: 84.91%
#   Paired t-test: t=-5.5983, p=0.0008
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_PSO vs BASELINE:
#   Method: 84.45% vs Baseline: 84.91%
#   Paired t-test: t=-0.3071, p=0.7677
#   Wilcoxon test: W=9.0000, p=0.8438
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 80.16% vs Baseline: 84.91%
#   Paired t-test: t=-3.6165, p=0.0085
#   Wilcoxon test: W=0.0000, p=0.0312
#   -> worse, Significant
#
# META_SSA vs BASELINE:
#   Method: 78.89% vs Baseline: 84.91%
#   Paired t-test: t=-2.1839, p=0.0653
#   Wilcoxon test: W=0.0000, p=0.0156
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 81.66% vs Baseline: 84.91%
#   Paired t-test: t=-1.1139, p=0.3021
#   Wilcoxon test: W=9.0000, p=0.2500
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_new_25_loss
#
# Per-method folders:
#   results_new_25_loss/baseline/ (16 files)
#   results_new_25_loss/mutual_info/ (16 files)
#   results_new_25_loss/rfe/ (16 files)
#   results_new_25_loss/lasso/ (16 files)
#   results_new_25_loss/meta_BAT/ (16 files)
#   results_new_25_loss/meta_CS/ (16 files)
#   results_new_25_loss/meta_DE/ (16 files)
#   results_new_25_loss/meta_FFA/ (16 files)
#   results_new_25_loss/meta_GA/ (16 files)
#   results_new_25_loss/meta_GWO/ (16 files)
#   results_new_25_loss/meta_HHO/ (16 files)
#   results_new_25_loss/meta_JAYA/ (16 files)
#   results_new_25_loss/meta_MFO/ (16 files)
#   results_new_25_loss/meta_MVO/ (16 files)
#   results_new_25_loss/meta_PSO/ (16 files)
#   results_new_25_loss/meta_SCA/ (16 files)
#   results_new_25_loss/meta_SSA/ (16 files)
#   results_new_25_loss/meta_WOA/ (16 files)
#
# Plots directory: results_new_25_loss/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 85.61% ± 4.51% (Features: 50.0%)
#   baseline            : 84.91% ± 6.40% (Features: 100.0%)
#   meta_DE             : 84.91% ± 5.45% (Features: 49.5%)
#   mutual_info         : 84.79% ± 3.18% (Features: 50.0%)
#   meta_PSO            : 84.45% ± 6.45% (Features: 49.2%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_HHO
#     Test Accuracy:      89.81%
#     Feature Retention:  25.65% (1009/3933)
#     Modality Retention: depth=29.2%, sensor=27.1%, skeleton=25.6%, video=24.5%
#
#   Fold 2: Best = meta_DE
#     Test Accuracy:      87.96%
#     Feature Retention:  49.66% (1953/3933)
#     Modality Retention: depth=41.2%, sensor=50.8%, skeleton=49.7%, video=50.4%
#
#   Fold 3: Best = meta_CS
#     Test Accuracy:      83.33%
#     Feature Retention:  49.94% (1964/3933)
#     Modality Retention: depth=51.9%, sensor=49.1%, skeleton=48.2%, video=52.0%
#
#   Fold 4: Best = meta_PSO
#     Test Accuracy:      89.81%
#     Feature Retention:  49.63% (1952/3933)
#     Modality Retention: depth=51.9%, sensor=51.1%, skeleton=50.3%, video=47.9%
#
#   Fold 5: Best = meta_WOA
#     Test Accuracy:      85.19%
#     Feature Retention:  72.87% (2866/3933)
#     Modality Retention: depth=71.3%, sensor=72.1%, skeleton=71.7%, video=74.8%
#
#   Fold 6: Best = meta_DE
#     Test Accuracy:      88.79%
#     Feature Retention:  50.14% (1972/3933)
#     Modality Retention: depth=52.3%, sensor=48.0%, skeleton=51.3%, video=49.4%
#
#   Fold 7: Best = meta_DE
#     Test Accuracy:      87.85%
#     Feature Retention:  48.69% (1915/3933)
#     Modality Retention: depth=48.6%, sensor=49.2%, skeleton=47.7%, video=49.6%
#
#   Fold 8: Best = meta_PSO
#     Test Accuracy:      90.65%
#     Feature Retention:  50.04% (1968/3933)
#     Modality Retention: depth=51.9%, sensor=52.9%, skeleton=50.9%, video=47.5%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     87.93% ± 2.51%
#   Average Feature Retention: 49.58% ± 12.63%
#
#   Average Modality-wise Feature Retention:
#          depth: 49.77% ± 11.84%
#         sensor: 50.04% ± 12.10%
#       skeleton: 49.42% ± 12.40%
#          video: 49.52% ± 13.51%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)  video Retention (%)
#     1           meta_HHO              89.81                  25.65                29.17                 27.15                   25.59                24.51
#     2            meta_DE              87.96                  49.66                41.20                 50.77                   49.73                50.35
#     3            meta_CS              83.33                  49.94                51.85                 49.08                   48.21                52.04
#     4           meta_PSO              89.81                  49.63                51.85                 51.07                   50.27                47.89
#     5           meta_WOA              85.19                  72.87                71.30                 72.09                   71.73                74.79
#     6            meta_DE              88.79                  50.14                52.31                 48.01                   51.31                49.44
#     7            meta_DE              87.85                  48.69                48.61                 49.23                   47.66                49.65
#     8           meta_PSO              90.65                  50.04                51.85                 52.91                   50.88                47.46
#
# Saved to: results_new_25_loss/best_metaheuristic_per_fold.csv
