# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (10% Random Zeroing)
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.
#
#
# > **Modification:** This notebook randomly zeros out 10% of all data elements before any processing.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_10_loss")

# Master output directory
RESULTS_ROOT = Path("results_10_loss")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 37
#   sensor: 54
#   skeleton: 240
#   video: 264
#   TOTAL: 595

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 87.96%, F1: 86.86%, Features: 595/595 (100.0%), Model: 1.703MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 297/595 (49.9%), Time: 3.5s
#     Test Acc: 89.81%, F1: 87.97%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 297/595 (49.9%), Time: 0.6s
#     Test Acc: 85.19%, F1: 83.59%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 297/595 (49.9%), Time: 0.1s
#     Test Acc: 80.56%, F1: 77.19%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.07587675070028012']
# ['At iteration 1 the best fitness is 0.07587675070028012']
# ['At iteration 2 the best fitness is 0.07587675070028012']
# ['At iteration 3 the best fitness is 0.07587675070028012']
# ['At iteration 4 the best fitness is 0.07587675070028012']
# ['At iteration 5 the best fitness is 0.07587675070028012']
# ['At iteration 6 the best fitness is 0.07587675070028012']
# ['At iteration 7 the best fitness is 0.07587675070028012']
# ['At iteration 8 the best fitness is 0.07587675070028012']
# ['At iteration 9 the best fitness is 0.07587675070028012']
# ['At iteration 10 the best fitness is 0.07587675070028012']
# ['At iteration 11 the best fitness is 0.07587675070028012']
# ['At iteration 12 the best fitness is 0.07587675070028012']
# ['At iteration 13 the best fitness is 0.07587675070028012']
# ['At iteration 14 the best fitness is 0.07587675070028012']
# ['At iteration 15 the best fitness is 0.07587675070028012']
# ['At iteration 16 the best fitness is 0.07587675070028012']
# ['At iteration 17 the best fitness is 0.07587675070028012']
# ['At iteration 18 the best fitness is 0.07587675070028012']
# ['At iteration 19 the best fitness is 0.07587675070028012']
# ['At iteration 20 the best fitness is 0.07587675070028012']
# ['At iteration 21 the best fitness is 0.07587675070028012']
# ['At iteration 22 the best fitness is 0.07587675070028012']
# ['At iteration 23 the best fitness is 0.07587675070028012']
# ['At iteration 24 the best fitness is 0.07587675070028012']
# ['At iteration 25 the best fitness is 0.07587675070028012']
# ['At iteration 26 the best fitness is 0.07587675070028012']
# ['At iteration 27 the best fitness is 0.07587675070028012']
# ['At iteration 28 the best fitness is 0.07587675070028012']
# ['At iteration 29 the best fitness is 0.07587675070028012']
#       Selected: 296/595 (49.7%), Fitness: 0.0759, Time: 775.2s
#       Modality: D=46%, S=39%, Sk=52%, V=50%
#     Test Acc: 80.56%, F1: 78.21%, Features: 296/595 (49.7%), Model: 1.119MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.088375350140056']
# ['At iteration 10 the best fitness is 0.06962745098039212']
# ['At iteration 20 the best fitness is 0.06962745098039212']
#       Selected: 305/595 (51.3%), Fitness: 0.0696, Time: 1517.8s
#       Modality: D=38%, S=48%, Sk=52%, V=53%
#     Test Acc: 85.19%, F1: 85.01%, Features: 305/595 (51.3%), Model: 1.137MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0876190476190476']
# ['At iteration 2 the best fitness is 0.0876190476190476']
# ['At iteration 3 the best fitness is 0.0876190476190476']
# ['At iteration 4 the best fitness is 0.08728291316526608']
# ['At iteration 5 the best fitness is 0.07503641456582634']
# ['At iteration 6 the best fitness is 0.07503641456582634']
# ['At iteration 7 the best fitness is 0.07503641456582634']
# ['At iteration 8 the best fitness is 0.06912324929971986']
# ['At iteration 9 the best fitness is 0.06912324929971986']
# ['At iteration 10 the best fitness is 0.06912324929971986']
# ['At iteration 11 the best fitness is 0.06912324929971986']
# ['At iteration 12 the best fitness is 0.06912324929971986']
# ['At iteration 13 the best fitness is 0.06912324929971986']
# ['At iteration 14 the best fitness is 0.06912324929971986']
# ['At iteration 15 the best fitness is 0.06912324929971986']
# ['At iteration 16 the best fitness is 0.06819887955182069']
# ['At iteration 17 the best fitness is 0.06819887955182069']
# ['At iteration 18 the best fitness is 0.06819887955182069']
# ['At iteration 19 the best fitness is 0.06819887955182069']
# ['At iteration 20 the best fitness is 0.06819887955182069']
# ['At iteration 21 the best fitness is 0.06819887955182069']
# ['At iteration 22 the best fitness is 0.06794677871148457']
# ['At iteration 23 the best fitness is 0.06794677871148457']
# ['At iteration 24 the best fitness is 0.06794677871148457']
# ['At iteration 25 the best fitness is 0.06794677871148457']
# ['At iteration 26 the best fitness is 0.06794677871148457']
# ['At iteration 27 the best fitness is 0.06794677871148457']
# ['At iteration 28 the best fitness is 0.06794677871148457']
# ['At iteration 29 the best fitness is 0.06794677871148457']
# ['At iteration 30 the best fitness is 0.06794677871148457']
#       Selected: 281/595 (47.2%), Fitness: 0.0679, Time: 770.9s
#       Modality: D=46%, S=44%, Sk=46%, V=49%
#     Test Acc: 78.70%, F1: 75.28%, Features: 281/595 (47.2%), Model: 1.090MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09056022408963584']
# ['At iteration 1 the best fitness is 0.10305882352941172']
# ['At iteration 2 the best fitness is 0.09596918767507007']
# ['At iteration 3 the best fitness is 0.0958011204481793']
# ['At iteration 4 the best fitness is 0.10129411764705878']
# ['At iteration 5 the best fitness is 0.08854341736694676']
# ['At iteration 6 the best fitness is 0.09496078431372552']
# ['At iteration 7 the best fitness is 0.09462464985994401']
# ['At iteration 8 the best fitness is 0.09479271708683476']
# ['At iteration 9 the best fitness is 0.08854341736694676']
# ['At iteration 10 the best fitness is 0.08170588235294123']
# ['At iteration 11 the best fitness is 0.09479271708683476']
# ['At iteration 12 the best fitness is 0.09462464985994401']
# ['At iteration 13 the best fitness is 0.09454061624649863']
# ['At iteration 14 the best fitness is 0.10095798319327727']
# ['At iteration 15 the best fitness is 0.08845938375350137']
# ['At iteration 16 the best fitness is 0.10112605042016802']
# ['At iteration 17 the best fitness is 0.09479271708683476']
# ['At iteration 18 the best fitness is 0.088375350140056']
# ['At iteration 19 the best fitness is 0.10104201680672265']
# ['At iteration 20 the best fitness is 0.10112605042016802']
# ['At iteration 21 the best fitness is 0.10104201680672265']
# ['At iteration 22 the best fitness is 0.09470868347338939']
# ['At iteration 23 the best fitness is 0.088375350140056']
# ['At iteration 24 the best fitness is 0.09470868347338939']
# ['At iteration 25 the best fitness is 0.088375350140056']
# ['At iteration 26 the best fitness is 0.10104201680672265']
# ['At iteration 27 the best fitness is 0.09470868347338939']
# ['At iteration 28 the best fitness is 0.09470868347338939']
# ['At iteration 29 the best fitness is 0.09470868347338939']
#       Selected: 306/595 (51.4%), Fitness: 0.0947, Time: 745.7s
#       Modality: D=49%, S=43%, Sk=51%, V=54%
#     Test Acc: 87.04%, F1: 85.95%, Features: 306/595 (51.4%), Model: 1.139MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.10196638655462181
# At iteration 2 the best fitness is 0.10188235294117642
# At iteration 3 the best fitness is 0.0950448179271709
# At iteration 4 the best fitness is 0.09563305322128855
# At iteration 5 the best fitness is 0.08829131652661062
# At iteration 6 the best fitness is 0.09554901960784318
# At iteration 7 the best fitness is 0.09538095238095241
# At iteration 8 the best fitness is 0.08305042016806728
# At iteration 9 the best fitness is 0.08271428571428577
# At iteration 10 the best fitness is 0.08212605042016811
# At iteration 11 the best fitness is 0.07705322128851541
# At iteration 12 the best fitness is 0.08397478991596644
# At iteration 13 the best fitness is 0.07646498599439777
# At iteration 14 the best fitness is 0.08871148459383751
# At iteration 15 the best fitness is 0.082546218487395
# At iteration 16 the best fitness is 0.08271428571428577
# At iteration 17 the best fitness is 0.07772549019607844
# At iteration 18 the best fitness is 0.0701316526610644
# At iteration 19 the best fitness is 0.07696918767507004
# At iteration 20 the best fitness is 0.08963585434173668
# At iteration 21 the best fitness is 0.06346218487394961
# At iteration 22 the best fitness is 0.07029971988795515
# At iteration 23 the best fitness is 0.082546218487395
# At iteration 24 the best fitness is 0.07029971988795515
# At iteration 25 the best fitness is 0.07004761904761901
# At iteration 26 the best fitness is 0.08305042016806728
# At iteration 27 the best fitness is 0.07671708683473391
# At iteration 28 the best fitness is 0.07612885154061624
# At iteration 29 the best fitness is 0.07021568627450978
# At iteration 30 the best fitness is 0.08271428571428577
#       Selected: 304/595 (51.1%), Fitness: 0.0827, Time: 745.9s
#       Modality: D=54%, S=57%, Sk=48%, V=52%
#     Test Acc: 76.85%, F1: 76.37%, Features: 304/595 (51.1%), Model: 1.135MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0989411764705882']
# ['At iteration 1 the best fitness is 0.08669467787114844']
# ['At iteration 2 the best fitness is 0.08010924369747904']
# ['At iteration 3 the best fitness is 0.08010924369747904']
# ['At iteration 4 the best fitness is 0.08010924369747904']
# ['At iteration 5 the best fitness is 0.07792436974789921']
# ['At iteration 6 the best fitness is 0.07691596638655468']
# ['At iteration 7 the best fitness is 0.07142296918767507']
# ['At iteration 8 the best fitness is 0.07142296918767507']
# ['At iteration 9 the best fitness is 0.07142296918767507']
# ['At iteration 10 the best fitness is 0.07142296918767507']
# ['At iteration 11 the best fitness is 0.07142296918767507']
# ['At iteration 12 the best fitness is 0.07142296918767507']
# ['At iteration 13 the best fitness is 0.07142296918767507']
# ['At iteration 14 the best fitness is 0.07007843137254903']
# ['At iteration 15 the best fitness is 0.07007843137254903']
# ['At iteration 16 the best fitness is 0.06458543417366944']
# ['At iteration 17 the best fitness is 0.06458543417366944']
# ['At iteration 18 the best fitness is 0.0643333333333333']
# ['At iteration 19 the best fitness is 0.0643333333333333']
# ['At iteration 20 the best fitness is 0.0643333333333333']
# ['At iteration 21 the best fitness is 0.0643333333333333']
# ['At iteration 22 the best fitness is 0.0643333333333333']
# ['At iteration 23 the best fitness is 0.0643333333333333']
# ['At iteration 24 the best fitness is 0.0643333333333333']
# ['At iteration 25 the best fitness is 0.0643333333333333']
# ['At iteration 26 the best fitness is 0.05875630252100844']
# ['At iteration 27 the best fitness is 0.05875630252100844']
# ['At iteration 28 the best fitness is 0.05875630252100844']
# ['At iteration 29 the best fitness is 0.05875630252100844']
#       Selected: 260/595 (43.7%), Fitness: 0.0588, Time: 741.9s
#       Modality: D=38%, S=43%, Sk=41%, V=47%
#     Test Acc: 85.19%, F1: 83.67%, Features: 260/595 (43.7%), Model: 1.049MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.09403641456582636']
# ['At iteration 1 the best fitness is 0.09403641456582636']
# ['At iteration 2 the best fitness is 0.09403641456582636']
# ['At iteration 3 the best fitness is 0.09403641456582636']
# ['At iteration 4 the best fitness is 0.09403641456582636']
# ['At iteration 5 the best fitness is 0.09403641456582636']
# ['At iteration 6 the best fitness is 0.09403641456582636']
# ['At iteration 7 the best fitness is 0.09313445378151267']
# ['At iteration 8 the best fitness is 0.09313445378151267']
# ['At iteration 9 the best fitness is 0.09313445378151267']
# ['At iteration 10 the best fitness is 0.09313445378151267']
# ['At iteration 11 the best fitness is 0.09313445378151267']
# ['At iteration 12 the best fitness is 0.09313445378151267']
# ['At iteration 13 the best fitness is 0.09313445378151267']
# ['At iteration 14 the best fitness is 0.09288235294117653']
# ['At iteration 15 the best fitness is 0.09246218487394964']
# ['At iteration 16 the best fitness is 0.09246218487394964']
# ['At iteration 17 the best fitness is 0.09246218487394964']
# ['At iteration 18 the best fitness is 0.09246218487394964']
# ['At iteration 19 the best fitness is 0.09246218487394964']
# ['At iteration 20 the best fitness is 0.09246218487394964']
# ['At iteration 21 the best fitness is 0.09246218487394964']
# ['At iteration 22 the best fitness is 0.09246218487394964']
# ['At iteration 23 the best fitness is 0.09246218487394964']
# ['At iteration 24 the best fitness is 0.09246218487394964']
# ['At iteration 25 the best fitness is 0.09246218487394964']
# ['At iteration 26 the best fitness is 0.09246218487394964']
# ['At iteration 27 the best fitness is 0.09246218487394964']
# ['At iteration 28 the best fitness is 0.09246218487394964']
# ['At iteration 29 the best fitness is 0.09246218487394964']
#       Selected: 409/595 (68.7%), Fitness: 0.0925, Time: 987.8s
#       Modality: D=65%, S=65%, Sk=70%, V=69%
#     Test Acc: 87.96%, F1: 87.00%, Features: 409/595 (68.7%), Model: 1.340MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.08330252100840341']
# ['At iteration 1 the best fitness is 0.08330252100840341']
# ['At iteration 2 the best fitness is 0.07722128851540616']
# ['At iteration 3 the best fitness is 0.07722128851540616']
# ['At iteration 4 the best fitness is 0.07722128851540616']
# ['At iteration 5 the best fitness is 0.07722128851540616']
# ['At iteration 6 the best fitness is 0.07722128851540616']
# ['At iteration 7 the best fitness is 0.07722128851540616']
# ['At iteration 8 the best fitness is 0.07722128851540616']
# ['At iteration 9 the best fitness is 0.07722128851540616']
# ['At iteration 10 the best fitness is 0.07428011204481794']
# ['At iteration 11 the best fitness is 0.07428011204481794']
# ['At iteration 12 the best fitness is 0.07428011204481794']
# ['At iteration 13 the best fitness is 0.06836694677871145']
# ['At iteration 14 the best fitness is 0.06836694677871145']
# ['At iteration 15 the best fitness is 0.06836694677871145']
# ['At iteration 16 the best fitness is 0.06836694677871145']
# ['At iteration 17 the best fitness is 0.06836694677871145']
# ['At iteration 18 the best fitness is 0.06836694677871145']
# ['At iteration 19 the best fitness is 0.06836694677871145']
# ['At iteration 20 the best fitness is 0.06836694677871145']
# ['At iteration 21 the best fitness is 0.06836694677871145']
# ['At iteration 22 the best fitness is 0.06752661064425768']
# ['At iteration 23 the best fitness is 0.06752661064425768']
# ['At iteration 24 the best fitness is 0.06752661064425768']
# ['At iteration 25 the best fitness is 0.06752661064425768']
# ['At iteration 26 the best fitness is 0.06752661064425768']
# ['At iteration 27 the best fitness is 0.06752661064425768']
# ['At iteration 28 the best fitness is 0.06752661064425768']
# ['At iteration 29 the best fitness is 0.06752661064425768']
#       Selected: 276/595 (46.4%), Fitness: 0.0675, Time: 775.0s
#       Modality: D=46%, S=54%, Sk=43%, V=48%
#     Test Acc: 81.48%, F1: 80.14%, Features: 276/595 (46.4%), Model: 1.080MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07545658263305323']
# ['At iteration 2 the best fitness is 0.07545658263305323']
# ['At iteration 3 the best fitness is 0.07545658263305323']
# ['At iteration 4 the best fitness is 0.07545658263305323']
# ['At iteration 5 the best fitness is 0.07545658263305323']
# ['At iteration 6 the best fitness is 0.07545658263305323']
# ['At iteration 7 the best fitness is 0.07545658263305323']
# ['At iteration 8 the best fitness is 0.07545658263305323']
# ['At iteration 9 the best fitness is 0.07545658263305323']
# ['At iteration 10 the best fitness is 0.07545658263305323']
# ['At iteration 11 the best fitness is 0.07545658263305323']
# ['At iteration 12 the best fitness is 0.06262184873949583']
# ['At iteration 13 the best fitness is 0.06262184873949583']
# ['At iteration 14 the best fitness is 0.06262184873949583']
# ['At iteration 15 the best fitness is 0.06262184873949583']
# ['At iteration 16 the best fitness is 0.06262184873949583']
# ['At iteration 17 the best fitness is 0.06262184873949583']
# ['At iteration 18 the best fitness is 0.06262184873949583']
# ['At iteration 19 the best fitness is 0.06262184873949583']
# ['At iteration 20 the best fitness is 0.06262184873949583']
# ['At iteration 21 the best fitness is 0.06262184873949583']
# ['At iteration 22 the best fitness is 0.06262184873949583']
# ['At iteration 23 the best fitness is 0.06262184873949583']
# ['At iteration 24 the best fitness is 0.06262184873949583']
# ['At iteration 25 the best fitness is 0.06262184873949583']
# ['At iteration 26 the best fitness is 0.06262184873949583']
# ['At iteration 27 the best fitness is 0.06262184873949583']
# ['At iteration 28 the best fitness is 0.06262184873949583']
# ['At iteration 29 the best fitness is 0.06262184873949583']
#       Selected: 298/595 (50.1%), Fitness: 0.0626, Time: 724.1s
#       Modality: D=51%, S=48%, Sk=51%, V=49%
#     Test Acc: 83.33%, F1: 81.43%, Features: 298/595 (50.1%), Model: 1.123MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.07570868347338935']
# ['At iteration 2 the best fitness is 0.07570868347338935']
# ['At iteration 3 the best fitness is 0.07411204481792719']
# ['At iteration 4 the best fitness is 0.07411204481792719']
# ['At iteration 5 the best fitness is 0.06836694677871145']
# ['At iteration 6 the best fitness is 0.06836694677871145']
# ['At iteration 7 the best fitness is 0.06836694677871145']
# ['At iteration 8 the best fitness is 0.06836694677871145']
# ['At iteration 9 the best fitness is 0.06836694677871145']
# ['At iteration 10 the best fitness is 0.06836694677871145']
# ['At iteration 11 the best fitness is 0.06836694677871145']
# ['At iteration 12 the best fitness is 0.06836694677871145']
# ['At iteration 13 the best fitness is 0.06836694677871145']
# ['At iteration 14 the best fitness is 0.06836694677871145']
# ['At iteration 15 the best fitness is 0.06836694677871145']
# ['At iteration 16 the best fitness is 0.06836694677871145']
# ['At iteration 17 the best fitness is 0.06836694677871145']
# ['At iteration 18 the best fitness is 0.06836694677871145']
# ['At iteration 19 the best fitness is 0.06836694677871145']
# ['At iteration 20 the best fitness is 0.06836694677871145']
# ['At iteration 21 the best fitness is 0.06836694677871145']
# ['At iteration 22 the best fitness is 0.062453781512605076']
# ['At iteration 23 the best fitness is 0.062453781512605076']
# ['At iteration 24 the best fitness is 0.062453781512605076']
# ['At iteration 25 the best fitness is 0.062453781512605076']
# ['At iteration 26 the best fitness is 0.062453781512605076']
# ['At iteration 27 the best fitness is 0.062453781512605076']
# ['At iteration 28 the best fitness is 0.062453781512605076']
# ['At iteration 29 the best fitness is 0.062453781512605076']
# ['At iteration 30 the best fitness is 0.06228571428571432']
#       Selected: 296/595 (49.7%), Fitness: 0.0623, Time: 746.5s
#       Modality: D=41%, S=61%, Sk=47%, V=51%
#     Test Acc: 82.41%, F1: 80.84%, Features: 296/595 (49.7%), Model: 1.119MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08887955182072826']
# ['At iteration 2 the best fitness is 0.08237815126050425']
# ['At iteration 3 the best fitness is 0.08237815126050425']
# ['At iteration 4 the best fitness is 0.08221008403361349']
# ['At iteration 5 the best fitness is 0.07520448179271709']
# ['At iteration 6 the best fitness is 0.07436414565826331']
# ['At iteration 7 the best fitness is 0.07436414565826331']
# ['At iteration 8 the best fitness is 0.07436414565826331']
# ['At iteration 9 the best fitness is 0.07436414565826331']
# ['At iteration 10 the best fitness is 0.07436414565826331']
# ['At iteration 11 the best fitness is 0.07436414565826331']
# ['At iteration 12 the best fitness is 0.07004761904761901']
# ['At iteration 13 the best fitness is 0.07004761904761901']
# ['At iteration 14 the best fitness is 0.07004761904761901']
# ['At iteration 15 the best fitness is 0.06861904761904758']
# ['At iteration 16 the best fitness is 0.06752661064425768']
# ['At iteration 17 the best fitness is 0.06752661064425768']
# ['At iteration 18 the best fitness is 0.06752661064425768']
# ['At iteration 19 the best fitness is 0.06752661064425768']
# ['At iteration 20 the best fitness is 0.06752661064425768']
# ['At iteration 21 the best fitness is 0.06752661064425768']
# ['At iteration 22 the best fitness is 0.06752661064425768']
# ['At iteration 23 the best fitness is 0.06752661064425768']
# ['At iteration 24 the best fitness is 0.06752661064425768']
# ['At iteration 25 the best fitness is 0.06752661064425768']
# ['At iteration 26 the best fitness is 0.06752661064425768']
# ['At iteration 27 the best fitness is 0.06752661064425768']
# ['At iteration 28 the best fitness is 0.06752661064425768']
# ['At iteration 29 the best fitness is 0.06752661064425768']
# ['At iteration 30 the best fitness is 0.06752661064425768']
#       Selected: 281/595 (47.2%), Fitness: 0.0675, Time: 746.9s
#       Modality: D=43%, S=52%, Sk=45%, V=49%
#     Test Acc: 87.04%, F1: 85.45%, Features: 281/595 (47.2%), Model: 1.090MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09370028011204484']
# ['At iteration 1 the best fitness is 0.08467787114845936']
# ['At iteration 2 the best fitness is 0.08450980392156861']
# ['At iteration 3 the best fitness is 0.08324929971988793']
# ['At iteration 4 the best fitness is 0.08324929971988793']
# ['At iteration 5 the best fitness is 0.07963585434173667']
# ['At iteration 6 the best fitness is 0.07963585434173667']
# ['At iteration 7 the best fitness is 0.0768627450980392']
# ['At iteration 8 the best fitness is 0.0768627450980392']
# ['At iteration 9 the best fitness is 0.0761064425770308']
# ['At iteration 10 the best fitness is 0.0761064425770308']
# ['At iteration 11 the best fitness is 0.06851260504201685']
# ['At iteration 12 the best fitness is 0.06851260504201685']
# ['At iteration 13 the best fitness is 0.06851260504201685']
# ['At iteration 14 the best fitness is 0.06851260504201685']
# ['At iteration 15 the best fitness is 0.06851260504201685']
# ['At iteration 16 the best fitness is 0.06851260504201685']
# ['At iteration 17 the best fitness is 0.06851260504201685']
# ['At iteration 18 the best fitness is 0.06851260504201685']
# ['At iteration 19 the best fitness is 0.06851260504201685']
# ['At iteration 20 the best fitness is 0.06851260504201685']
# ['At iteration 21 the best fitness is 0.06851260504201685']
# ['At iteration 22 the best fitness is 0.06851260504201685']
# ['At iteration 23 the best fitness is 0.06851260504201685']
# ['At iteration 24 the best fitness is 0.06851260504201685']
# ['At iteration 25 the best fitness is 0.06851260504201685']
# ['At iteration 26 the best fitness is 0.06851260504201685']
# ['At iteration 27 the best fitness is 0.06851260504201685']
# ['At iteration 28 the best fitness is 0.06851260504201685']
# ['At iteration 29 the best fitness is 0.06851260504201685']
#       Selected: 144/595 (24.2%), Fitness: 0.0685, Time: 677.8s
#       Modality: D=30%, S=37%, Sk=19%, V=25%
#     Test Acc: 81.48%, F1: 79.36%, Features: 144/595 (24.2%), Model: 0.340MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.08313445378151266']
# ['At iteration 2 the best fitness is 0.08313445378151266']
# ['At iteration 3 the best fitness is 0.08313445378151266']
# ['At iteration 4 the best fitness is 0.07629691876750701']
# ['At iteration 5 the best fitness is 0.07629691876750701']
# ['At iteration 6 the best fitness is 0.07629691876750701']
# ['At iteration 7 the best fitness is 0.07629691876750701']
# ['At iteration 8 the best fitness is 0.07080392156862741']
# ['At iteration 9 the best fitness is 0.07080392156862741']
# ['At iteration 10 the best fitness is 0.07080392156862741']
# ['At iteration 11 the best fitness is 0.07080392156862741']
# ['At iteration 12 the best fitness is 0.07080392156862741']
# ['At iteration 13 the best fitness is 0.07080392156862741']
# ['At iteration 14 the best fitness is 0.07080392156862741']
# ['At iteration 15 the best fitness is 0.07080392156862741']
# ['At iteration 16 the best fitness is 0.07080392156862741']
# ['At iteration 17 the best fitness is 0.07080392156862741']
# ['At iteration 18 the best fitness is 0.07080392156862741']
# ['At iteration 19 the best fitness is 0.07080392156862741']
# ['At iteration 20 the best fitness is 0.07080392156862741']
# ['At iteration 21 the best fitness is 0.07080392156862741']
# ['At iteration 22 the best fitness is 0.07080392156862741']
# ['At iteration 23 the best fitness is 0.07080392156862741']
# ['At iteration 24 the best fitness is 0.07080392156862741']
# ['At iteration 25 the best fitness is 0.07080392156862741']
# ['At iteration 26 the best fitness is 0.07080392156862741']
# ['At iteration 27 the best fitness is 0.07080392156862741']
# ['At iteration 28 the best fitness is 0.07080392156862741']
# ['At iteration 29 the best fitness is 0.07080392156862741']
#       Selected: 306/595 (51.4%), Fitness: 0.0708, Time: 1871.7s
#       Modality: D=49%, S=63%, Sk=47%, V=53%
#     Test Acc: 87.04%, F1: 85.80%, Features: 306/595 (51.4%), Model: 1.139MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.09277591036414569']
# ['At iteration 1 the best fitness is 0.09277591036414569']
# ['At iteration 2 the best fitness is 0.08548739495798324']
# ['At iteration 3 the best fitness is 0.08548739495798324']
# ['At iteration 4 the best fitness is 0.08305042016806728']
# ['At iteration 5 the best fitness is 0.08215686274509802']
# ['At iteration 6 the best fitness is 0.08215686274509802']
# ['At iteration 7 the best fitness is 0.08215686274509802']
# ['At iteration 8 the best fitness is 0.08198879551820726']
# ['At iteration 9 the best fitness is 0.08198879551820726']
# ['At iteration 10 the best fitness is 0.08198879551820726']
# ['At iteration 11 the best fitness is 0.08198879551820726']
# ['At iteration 12 the best fitness is 0.08198879551820726']
# ['At iteration 13 the best fitness is 0.08198879551820726']
# ['At iteration 14 the best fitness is 0.08198879551820726']
# ['At iteration 15 the best fitness is 0.08198879551820726']
# ['At iteration 16 the best fitness is 0.08198879551820726']
# ['At iteration 17 the best fitness is 0.08089635854341734']
# ['At iteration 18 the best fitness is 0.075655462184874']
# ['At iteration 19 the best fitness is 0.075655462184874']
# ['At iteration 20 the best fitness is 0.075655462184874']
# ['At iteration 21 the best fitness is 0.075655462184874']
# ['At iteration 22 the best fitness is 0.075655462184874']
# ['At iteration 23 the best fitness is 0.075655462184874']
# ['At iteration 24 the best fitness is 0.075655462184874']
# ['At iteration 25 the best fitness is 0.075655462184874']
# ['At iteration 26 the best fitness is 0.075655462184874']
# ['At iteration 27 the best fitness is 0.075655462184874']
# ['At iteration 28 the best fitness is 0.075655462184874']
# ['At iteration 29 the best fitness is 0.075655462184874']
#       Selected: 230/595 (38.7%), Fitness: 0.0757, Time: 706.9s
#       Modality: D=30%, S=44%, Sk=34%, V=43%
#     Test Acc: 83.33%, F1: 80.97%, Features: 230/595 (38.7%), Model: 0.844MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 78.70%, F1: 76.47%, Features: 595/595 (100.0%), Model: 1.703MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 297/595 (49.9%), Time: 3.4s
#     Test Acc: 79.63%, F1: 76.60%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 297/595 (49.9%), Time: 0.5s
#     Test Acc: 81.48%, F1: 78.61%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 297/595 (49.9%), Time: 0.1s
#     Test Acc: 76.85%, F1: 73.89%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.049535014005602195']
# ['At iteration 1 the best fitness is 0.049535014005602195']
# ['At iteration 2 the best fitness is 0.049535014005602195']
# ['At iteration 3 the best fitness is 0.049535014005602195']
# ['At iteration 4 the best fitness is 0.049535014005602195']
# ['At iteration 5 the best fitness is 0.049535014005602195']
# ['At iteration 6 the best fitness is 0.049535014005602195']
# ['At iteration 7 the best fitness is 0.049535014005602195']
# ['At iteration 8 the best fitness is 0.049535014005602195']
# ['At iteration 9 the best fitness is 0.049535014005602195']
# ['At iteration 10 the best fitness is 0.049535014005602195']
# ['At iteration 11 the best fitness is 0.049535014005602195']
# ['At iteration 12 the best fitness is 0.049535014005602195']
# ['At iteration 13 the best fitness is 0.049535014005602195']
# ['At iteration 14 the best fitness is 0.049535014005602195']
# ['At iteration 15 the best fitness is 0.049535014005602195']
# ['At iteration 16 the best fitness is 0.049535014005602195']
# ['At iteration 17 the best fitness is 0.049535014005602195']
# ['At iteration 18 the best fitness is 0.049535014005602195']
# ['At iteration 19 the best fitness is 0.049535014005602195']
# ['At iteration 20 the best fitness is 0.049535014005602195']
# ['At iteration 21 the best fitness is 0.049535014005602195']
# ['At iteration 22 the best fitness is 0.049535014005602195']
# ['At iteration 23 the best fitness is 0.049535014005602195']
# ['At iteration 24 the best fitness is 0.049535014005602195']
# ['At iteration 25 the best fitness is 0.049535014005602195']
# ['At iteration 26 the best fitness is 0.049535014005602195']
# ['At iteration 27 the best fitness is 0.049535014005602195']
# ['At iteration 28 the best fitness is 0.049535014005602195']
# ['At iteration 29 the best fitness is 0.049535014005602195']
#       Selected: 283/595 (47.6%), Fitness: 0.0495, Time: 772.7s
#       Modality: D=51%, S=43%, Sk=48%, V=48%
#     Test Acc: 74.07%, F1: 70.45%, Features: 283/595 (47.6%), Model: 1.094MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.050879551820728244']
# ['At iteration 10 the best fitness is 0.043789915966386574']
# ['At iteration 20 the best fitness is 0.043789915966386574']
#       Selected: 303/595 (50.9%), Fitness: 0.0438, Time: 1523.0s
#       Modality: D=51%, S=67%, Sk=50%, V=49%
#     Test Acc: 77.78%, F1: 74.67%, Features: 303/595 (50.9%), Model: 1.133MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04903081232492992']
# ['At iteration 2 the best fitness is 0.04903081232492992']
# ['At iteration 3 the best fitness is 0.04903081232492992']
# ['At iteration 4 the best fitness is 0.04345378151260506']
# ['At iteration 5 the best fitness is 0.04345378151260506']
# ['At iteration 6 the best fitness is 0.04345378151260506']
# ['At iteration 7 the best fitness is 0.04345378151260506']
# ['At iteration 8 the best fitness is 0.04345378151260506']
# ['At iteration 9 the best fitness is 0.04345378151260506']
# ['At iteration 10 the best fitness is 0.04345378151260506']
# ['At iteration 11 the best fitness is 0.04345378151260506']
# ['At iteration 12 the best fitness is 0.04345378151260506']
# ['At iteration 13 the best fitness is 0.04278151260504204']
# ['At iteration 14 the best fitness is 0.04278151260504204']
# ['At iteration 15 the best fitness is 0.04278151260504204']
# ['At iteration 16 the best fitness is 0.04185714285714287']
# ['At iteration 17 the best fitness is 0.04185714285714287']
# ['At iteration 18 the best fitness is 0.04185714285714287']
# ['At iteration 19 the best fitness is 0.04185714285714287']
# ['At iteration 20 the best fitness is 0.04185714285714287']
# ['At iteration 21 the best fitness is 0.04185714285714287']
# ['At iteration 22 the best fitness is 0.04185714285714287']
# ['At iteration 23 the best fitness is 0.04185714285714287']
# ['At iteration 24 the best fitness is 0.04185714285714287']
# ['At iteration 25 the best fitness is 0.041352941176470606']
# ['At iteration 26 the best fitness is 0.041352941176470606']
# ['At iteration 27 the best fitness is 0.041352941176470606']
# ['At iteration 28 the best fitness is 0.041352941176470606']
# ['At iteration 29 the best fitness is 0.041352941176470606']
# ['At iteration 30 the best fitness is 0.041352941176470606']
#       Selected: 273/595 (45.9%), Fitness: 0.0414, Time: 773.6s
#       Modality: D=51%, S=61%, Sk=41%, V=46%
#     Test Acc: 75.00%, F1: 71.73%, Features: 273/595 (45.9%), Model: 1.074MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.061781512605042055']
# ['At iteration 1 the best fitness is 0.05113165266106438']
# ['At iteration 2 the best fitness is 0.051383753501400516']
# ['At iteration 3 the best fitness is 0.05012324929971984']
# ['At iteration 4 the best fitness is 0.05079551820728286']
# ['At iteration 5 the best fitness is 0.05012324929971984']
# ['At iteration 6 the best fitness is 0.04488235294117649']
# ['At iteration 7 the best fitness is 0.05146778711484589']
# ['At iteration 8 the best fitness is 0.05037535014005597']
# ['At iteration 9 the best fitness is 0.050039215686274466']
# ['At iteration 10 the best fitness is 0.043873949579831956']
# ['At iteration 11 the best fitness is 0.04362184873949582']
# ['At iteration 12 the best fitness is 0.04370588235294119']
# ['At iteration 13 the best fitness is 0.04970308123249295']
# ['At iteration 14 the best fitness is 0.04353781512605044']
# ['At iteration 15 the best fitness is 0.04345378151260506']
# ['At iteration 16 the best fitness is 0.04320168067226893']
# ['At iteration 17 the best fitness is 0.04336974789915968']
# ['At iteration 18 the best fitness is 0.0432857142857143']
# ['At iteration 19 the best fitness is 0.04336974789915968']
# ['At iteration 20 the best fitness is 0.04336974789915968']
# ['At iteration 21 the best fitness is 0.04970308123249295']
# ['At iteration 22 the best fitness is 0.04336974789915968']
# ['At iteration 23 the best fitness is 0.04336974789915968']
# ['At iteration 24 the best fitness is 0.04345378151260506']
# ['At iteration 25 the best fitness is 0.04970308123249295']
# ['At iteration 26 the best fitness is 0.04970308123249295']
# ['At iteration 27 the best fitness is 0.04336974789915968']
# ['At iteration 28 the best fitness is 0.04970308123249295']
# ['At iteration 29 the best fitness is 0.04336974789915968']
#       Selected: 301/595 (50.6%), Fitness: 0.0434, Time: 749.2s
#       Modality: D=43%, S=46%, Sk=52%, V=51%
#     Test Acc: 73.15%, F1: 70.62%, Features: 301/595 (50.6%), Model: 1.129MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.05645658263305321
# At iteration 2 the best fitness is 0.04320168067226893
# At iteration 3 the best fitness is 0.04978711484593833
# At iteration 4 the best fitness is 0.04362184873949582
# At iteration 5 the best fitness is 0.0432857142857143
# At iteration 6 the best fitness is 0.04936694677871144
# At iteration 7 the best fitness is 0.05595238095238094
# At iteration 8 the best fitness is 0.04961904761904757
# At iteration 9 the best fitness is 0.04353781512605044
# At iteration 10 the best fitness is 0.04370588235294119
# At iteration 11 the best fitness is 0.04370588235294119
# At iteration 12 the best fitness is 0.04978711484593833
# At iteration 13 the best fitness is 0.04336974789915968
# At iteration 14 the best fitness is 0.03070308123249304
# At iteration 15 the best fitness is 0.04362184873949582
# At iteration 16 the best fitness is 0.04928291316526606
# At iteration 17 the best fitness is 0.04311764705882355
# At iteration 18 the best fitness is 0.04320168067226893
# At iteration 19 the best fitness is 0.037456582633053195
# At iteration 20 the best fitness is 0.036868347338935556
# At iteration 21 the best fitness is 0.0432857142857143
# At iteration 22 the best fitness is 0.04311764705882355
# At iteration 23 the best fitness is 0.03720448179271706
# At iteration 24 the best fitness is 0.024453781512605043
# At iteration 25 the best fitness is 0.04919887955182068
# At iteration 26 the best fitness is 0.044042016806722706
# At iteration 27 the best fitness is 0.04353781512605044
# At iteration 28 the best fitness is 0.03154341736694682
# At iteration 29 the best fitness is 0.0432857142857143
# At iteration 30 the best fitness is 0.030366946778711528
#       Selected: 291/595 (48.9%), Fitness: 0.0304, Time: 747.2s
#       Modality: D=57%, S=67%, Sk=45%, V=48%
#     Test Acc: 83.33%, F1: 81.14%, Features: 291/595 (48.9%), Model: 1.109MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06329411764705886']
# ['At iteration 1 the best fitness is 0.054187675070028']
# ['At iteration 2 the best fitness is 0.054187675070028']
# ['At iteration 3 the best fitness is 0.04667787114845934']
# ['At iteration 4 the best fitness is 0.040176470588235313']
# ['At iteration 5 the best fitness is 0.03916806722689077']
# ['At iteration 6 the best fitness is 0.03824369747899162']
# ['At iteration 7 the best fitness is 0.03824369747899162']
# ['At iteration 8 the best fitness is 0.03689915966386556']
# ['At iteration 9 the best fitness is 0.03689915966386556']
# ['At iteration 10 the best fitness is 0.03689915966386556']
# ['At iteration 11 the best fitness is 0.036394957983193296']
# ['At iteration 12 the best fitness is 0.036394957983193296']
# ['At iteration 13 the best fitness is 0.030733893557422946']
# ['At iteration 14 the best fitness is 0.030733893557422946']
# ['At iteration 15 the best fitness is 0.029389355742296893']
# ['At iteration 16 the best fitness is 0.029389355742296893']
# ['At iteration 17 the best fitness is 0.029389355742296893']
# ['At iteration 18 the best fitness is 0.029389355742296893']
# ['At iteration 19 the best fitness is 0.029053221288515382']
# ['At iteration 20 the best fitness is 0.028969187675070004']
# ['At iteration 21 the best fitness is 0.028885154061624625']
# ['At iteration 22 the best fitness is 0.028885154061624625']
# ['At iteration 23 the best fitness is 0.022383753501400604']
# ['At iteration 24 the best fitness is 0.022383753501400604']
# ['At iteration 25 the best fitness is 0.022383753501400604']
# ['At iteration 26 the best fitness is 0.022383753501400604']
# ['At iteration 27 the best fitness is 0.022383753501400604']
# ['At iteration 28 the best fitness is 0.022383753501400604']
# ['At iteration 29 the best fitness is 0.022299719887955222']
#       Selected: 221/595 (37.1%), Fitness: 0.0223, Time: 726.1s
#       Modality: D=27%, S=44%, Sk=38%, V=36%
#     Test Acc: 77.78%, F1: 74.76%, Features: 221/595 (37.1%), Model: 0.781MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.04903081232492992']
# ['At iteration 1 the best fitness is 0.04903081232492992']
# ['At iteration 2 the best fitness is 0.04903081232492992']
# ['At iteration 3 the best fitness is 0.040428571428571446']
# ['At iteration 4 the best fitness is 0.040428571428571446']
# ['At iteration 5 the best fitness is 0.040428571428571446']
# ['At iteration 6 the best fitness is 0.040428571428571446']
# ['At iteration 7 the best fitness is 0.040428571428571446']
# ['At iteration 8 the best fitness is 0.040428571428571446']
# ['At iteration 9 the best fitness is 0.040428571428571446']
# ['At iteration 10 the best fitness is 0.03824369747899162']
# ['At iteration 11 the best fitness is 0.03824369747899162']
# ['At iteration 12 the best fitness is 0.03824369747899162']
# ['At iteration 13 the best fitness is 0.03824369747899162']
# ['At iteration 14 the best fitness is 0.037655462184873964']
# ['At iteration 15 the best fitness is 0.037655462184873964']
# ['At iteration 16 the best fitness is 0.037655462184873964']
# ['At iteration 17 the best fitness is 0.037655462184873964']
# ['At iteration 18 the best fitness is 0.03757142857142859']
# ['At iteration 19 the best fitness is 0.03107002801120446']
# ['At iteration 20 the best fitness is 0.03107002801120446']
# ['At iteration 21 the best fitness is 0.03107002801120446']
# ['At iteration 22 the best fitness is 0.03107002801120446']
# ['At iteration 23 the best fitness is 0.03107002801120446']
# ['At iteration 24 the best fitness is 0.03107002801120446']
# ['At iteration 25 the best fitness is 0.03098599439775908']
# ['At iteration 26 the best fitness is 0.03098599439775908']
# ['At iteration 27 the best fitness is 0.03098599439775908']
# ['At iteration 28 the best fitness is 0.03098599439775908']
# ['At iteration 29 the best fitness is 0.03098599439775908']
#       Selected: 238/595 (40.0%), Fitness: 0.0310, Time: 941.7s
#       Modality: D=22%, S=46%, Sk=37%, V=44%
#     Test Acc: 80.56%, F1: 77.72%, Features: 238/595 (40.0%), Model: 0.903MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.04928291316526606']
# ['At iteration 1 the best fitness is 0.04928291316526606']
# ['At iteration 2 the best fitness is 0.04928291316526606']
# ['At iteration 3 the best fitness is 0.04928291316526606']
# ['At iteration 4 the best fitness is 0.0432857142857143']
# ['At iteration 5 the best fitness is 0.0432857142857143']
# ['At iteration 6 the best fitness is 0.0432857142857143']
# ['At iteration 7 the best fitness is 0.0432857142857143']
# ['At iteration 8 the best fitness is 0.0432857142857143']
# ['At iteration 9 the best fitness is 0.0432857142857143']
# ['At iteration 10 the best fitness is 0.0432857142857143']
# ['At iteration 11 the best fitness is 0.0432857142857143']
# ['At iteration 12 the best fitness is 0.0432857142857143']
# ['At iteration 13 the best fitness is 0.0432857142857143']
# ['At iteration 14 the best fitness is 0.0432857142857143']
# ['At iteration 15 the best fitness is 0.0432857142857143']
# ['At iteration 16 the best fitness is 0.0432857142857143']
# ['At iteration 17 the best fitness is 0.0432857142857143']
# ['At iteration 18 the best fitness is 0.0432857142857143']
# ['At iteration 19 the best fitness is 0.0432857142857143']
# ['At iteration 20 the best fitness is 0.0432857142857143']
# ['At iteration 21 the best fitness is 0.0432857142857143']
# ['At iteration 22 the best fitness is 0.0432857142857143']
# ['At iteration 23 the best fitness is 0.0432857142857143']
# ['At iteration 24 the best fitness is 0.0432857142857143']
# ['At iteration 25 the best fitness is 0.0432857142857143']
# ['At iteration 26 the best fitness is 0.0432857142857143']
# ['At iteration 27 the best fitness is 0.0432857142857143']
# ['At iteration 28 the best fitness is 0.0432857142857143']
# ['At iteration 29 the best fitness is 0.0432857142857143']
#       Selected: 281/595 (47.2%), Fitness: 0.0433, Time: 771.3s
#       Modality: D=51%, S=54%, Sk=49%, V=44%
#     Test Acc: 77.78%, F1: 76.05%, Features: 281/595 (47.2%), Model: 1.090MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05553221288515405']
# ['At iteration 2 the best fitness is 0.05155182072829127']
# ['At iteration 3 the best fitness is 0.05155182072829127']
# ['At iteration 4 the best fitness is 0.05155182072829127']
# ['At iteration 5 the best fitness is 0.05155182072829127']
# ['At iteration 6 the best fitness is 0.05155182072829127']
# ['At iteration 7 the best fitness is 0.050879551820728244']
# ['At iteration 8 the best fitness is 0.050879551820728244']
# ['At iteration 9 the best fitness is 0.050879551820728244']
# ['At iteration 10 the best fitness is 0.050879551820728244']
# ['At iteration 11 the best fitness is 0.050879551820728244']
# ['At iteration 12 the best fitness is 0.0498711484593837']
# ['At iteration 13 the best fitness is 0.04513445378151262']
# ['At iteration 14 the best fitness is 0.04513445378151262']
# ['At iteration 15 the best fitness is 0.04513445378151262']
# ['At iteration 16 the best fitness is 0.04513445378151262']
# ['At iteration 17 the best fitness is 0.04513445378151262']
# ['At iteration 18 the best fitness is 0.044714285714285734']
# ['At iteration 19 the best fitness is 0.044714285714285734']
# ['At iteration 20 the best fitness is 0.044294117647058845']
# ['At iteration 21 the best fitness is 0.044294117647058845']
# ['At iteration 22 the best fitness is 0.044294117647058845']
# ['At iteration 23 the best fitness is 0.044294117647058845']
# ['At iteration 24 the best fitness is 0.044294117647058845']
# ['At iteration 25 the best fitness is 0.044294117647058845']
# ['At iteration 26 the best fitness is 0.044294117647058845']
# ['At iteration 27 the best fitness is 0.044294117647058845']
# ['At iteration 28 the best fitness is 0.044294117647058845']
# ['At iteration 29 the best fitness is 0.044294117647058845']
#       Selected: 298/595 (50.1%), Fitness: 0.0443, Time: 723.3s
#       Modality: D=41%, S=57%, Sk=48%, V=52%
#     Test Acc: 78.70%, F1: 75.85%, Features: 298/595 (50.1%), Model: 1.123MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0568767507002801']
# ['At iteration 2 the best fitness is 0.0568767507002801']
# ['At iteration 3 the best fitness is 0.0568767507002801']
# ['At iteration 4 the best fitness is 0.0568767507002801']
# ['At iteration 5 the best fitness is 0.0568767507002801']
# ['At iteration 6 the best fitness is 0.0568767507002801']
# ['At iteration 7 the best fitness is 0.0568767507002801']
# ['At iteration 8 the best fitness is 0.037456582633053195']
# ['At iteration 9 the best fitness is 0.037456582633053195']
# ['At iteration 10 the best fitness is 0.037456582633053195']
# ['At iteration 11 the best fitness is 0.037456582633053195']
# ['At iteration 12 the best fitness is 0.037456582633053195']
# ['At iteration 13 the best fitness is 0.037456582633053195']
# ['At iteration 14 the best fitness is 0.037456582633053195']
# ['At iteration 15 the best fitness is 0.037456582633053195']
# ['At iteration 16 the best fitness is 0.037456582633053195']
# ['At iteration 17 the best fitness is 0.037456582633053195']
# ['At iteration 18 the best fitness is 0.037456582633053195']
# ['At iteration 19 the best fitness is 0.037456582633053195']
# ...
# ['At iteration 15 the best fitness is 0.053599439775910356']
# ['At iteration 16 the best fitness is 0.053599439775910356']
# ['At iteration 17 the best fitness is 0.053599439775910356']
# ['At iteration 18 the best fitness is 0.053599439775910356']
# ['At iteration 19 the best fitness is 0.04712885154061624']
# ['At iteration 20 the best fitness is 0.04712885154061624']
# ['At iteration 21 the best fitness is 0.04712885154061624']
# ['At iteration 22 the best fitness is 0.04712885154061624']
# ['At iteration 23 the best fitness is 0.04712885154061624']
# ['At iteration 24 the best fitness is 0.04712885154061624']
# ['At iteration 25 the best fitness is 0.04712885154061624']
# ['At iteration 26 the best fitness is 0.04712885154061624']
# ['At iteration 27 the best fitness is 0.04712885154061624']
# ['At iteration 28 the best fitness is 0.04712885154061624']
# ['At iteration 29 the best fitness is 0.04712885154061624']
#       Selected: 186/595 (31.3%), Fitness: 0.0471, Time: 920.5s
#       Modality: D=24%, S=35%, Sk=28%, V=34%
#     Test Acc: 82.24%, F1: 80.19%, Features: 186/595 (31.3%), Model: 0.558MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.055616246498599434']
# ['At iteration 1 the best fitness is 0.055616246498599434']
# ['At iteration 2 the best fitness is 0.055616246498599434']
# ['At iteration 3 the best fitness is 0.055616246498599434']
# ['At iteration 4 the best fitness is 0.055616246498599434']
# ['At iteration 5 the best fitness is 0.055616246498599434']
# ['At iteration 6 the best fitness is 0.055616246498599434']
# ['At iteration 7 the best fitness is 0.055616246498599434']
# ['At iteration 8 the best fitness is 0.055616246498599434']
# ['At iteration 9 the best fitness is 0.055616246498599434']
# ['At iteration 10 the best fitness is 0.055616246498599434']
# ['At iteration 11 the best fitness is 0.055616246498599434']
# ['At iteration 12 the best fitness is 0.055616246498599434']
# ['At iteration 13 the best fitness is 0.055616246498599434']
# ['At iteration 14 the best fitness is 0.055616246498599434']
# ['At iteration 15 the best fitness is 0.055616246498599434']
# ['At iteration 16 the best fitness is 0.055616246498599434']
# ['At iteration 17 the best fitness is 0.055616246498599434']
# ['At iteration 18 the best fitness is 0.055616246498599434']
# ['At iteration 19 the best fitness is 0.055616246498599434']
# ['At iteration 20 the best fitness is 0.055616246498599434']
# ['At iteration 21 the best fitness is 0.055616246498599434']
# ['At iteration 22 the best fitness is 0.055616246498599434']
# ['At iteration 23 the best fitness is 0.055616246498599434']
# ['At iteration 24 the best fitness is 0.055616246498599434']
# ['At iteration 25 the best fitness is 0.055616246498599434']
# ['At iteration 26 the best fitness is 0.055616246498599434']
# ['At iteration 27 the best fitness is 0.055616246498599434']
# ['At iteration 28 the best fitness is 0.055616246498599434']
# ['At iteration 29 the best fitness is 0.055616246498599434']
#       Selected: 300/595 (50.4%), Fitness: 0.0556, Time: 783.3s
#       Modality: D=51%, S=52%, Sk=48%, V=52%
#     Test Acc: 87.85%, F1: 86.22%, Features: 300/595 (50.4%), Model: 1.127MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05696078431372548']
# ['At iteration 2 the best fitness is 0.05696078431372548']
# ['At iteration 3 the best fitness is 0.05696078431372548']
# ['At iteration 4 the best fitness is 0.050207282913165216']
# ['At iteration 5 the best fitness is 0.050207282913165216']
# ['At iteration 6 the best fitness is 0.050207282913165216']
# ['At iteration 7 the best fitness is 0.050207282913165216']
# ['At iteration 8 the best fitness is 0.050207282913165216']
# ['At iteration 9 the best fitness is 0.050207282913165216']
# ['At iteration 10 the best fitness is 0.050207282913165216']
# ['At iteration 11 the best fitness is 0.050207282913165216']
# ['At iteration 12 the best fitness is 0.050207282913165216']
# ['At iteration 13 the best fitness is 0.050207282913165216']
# ['At iteration 14 the best fitness is 0.050207282913165216']
# ['At iteration 15 the best fitness is 0.050207282913165216']
# ['At iteration 16 the best fitness is 0.050207282913165216']
# ['At iteration 17 the best fitness is 0.04572268907563027']
# ['At iteration 18 the best fitness is 0.04572268907563027']
# ['At iteration 19 the best fitness is 0.04572268907563027']
# ['At iteration 20 the best fitness is 0.04572268907563027']
# ['At iteration 21 the best fitness is 0.04572268907563027']
# ['At iteration 22 the best fitness is 0.04572268907563027']
# ['At iteration 23 the best fitness is 0.04572268907563027']
# ['At iteration 24 the best fitness is 0.04572268907563027']
# ['At iteration 25 the best fitness is 0.04572268907563027']
# ['At iteration 26 the best fitness is 0.04572268907563027']
# ['At iteration 27 the best fitness is 0.04572268907563027']
# ['At iteration 28 the best fitness is 0.04572268907563027']
# ['At iteration 29 the best fitness is 0.04572268907563027']
#       Selected: 318/595 (53.4%), Fitness: 0.0457, Time: 735.9s
#       Modality: D=57%, S=63%, Sk=51%, V=53%
#     Test Acc: 89.72%, F1: 88.82%, Features: 318/595 (53.4%), Model: 1.162MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0712240896358543']
# ['At iteration 2 the best fitness is 0.062201680672268944']
# ['At iteration 3 the best fitness is 0.062201680672268944']
# ['At iteration 4 the best fitness is 0.062201680672268944']
# ['At iteration 5 the best fitness is 0.062201680672268944']
# ['At iteration 6 the best fitness is 0.062201680672268944']
# ['At iteration 7 the best fitness is 0.062201680672268944']
# ['At iteration 8 the best fitness is 0.056708683473389344']
# ['At iteration 9 the best fitness is 0.056708683473389344']
# ['At iteration 10 the best fitness is 0.05637254901960784']
# ['At iteration 11 the best fitness is 0.05637254901960784']
# ['At iteration 12 the best fitness is 0.050039215686274466']
# ['At iteration 13 the best fitness is 0.050039215686274466']
# ['At iteration 14 the best fitness is 0.050039215686274466']
# ['At iteration 15 the best fitness is 0.050039215686274466']
# ['At iteration 16 the best fitness is 0.050039215686274466']
# ['At iteration 17 the best fitness is 0.050039215686274466']
# ['At iteration 18 the best fitness is 0.050039215686274466']
# ['At iteration 19 the best fitness is 0.050039215686274466']
# ['At iteration 20 the best fitness is 0.050039215686274466']
# ['At iteration 21 the best fitness is 0.050039215686274466']
# ['At iteration 22 the best fitness is 0.050039215686274466']
# ['At iteration 23 the best fitness is 0.050039215686274466']
# ['At iteration 24 the best fitness is 0.04970308123249295']
# ['At iteration 25 the best fitness is 0.04970308123249295']
# ['At iteration 26 the best fitness is 0.04970308123249295']
# ['At iteration 27 the best fitness is 0.04970308123249295']
# ['At iteration 28 the best fitness is 0.04970308123249295']
# ['At iteration 29 the best fitness is 0.04970308123249295']
# ['At iteration 30 the best fitness is 0.04970308123249295']
#       Selected: 297/595 (49.9%), Fitness: 0.0497, Time: 761.3s
#       Modality: D=54%, S=46%, Sk=47%, V=53%
#     Test Acc: 85.05%, F1: 82.80%, Features: 297/595 (49.9%), Model: 1.121MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0697114845938375']
# ['At iteration 2 the best fitness is 0.0697114845938375']
# ['At iteration 3 the best fitness is 0.0638823529411765']
# ['At iteration 4 the best fitness is 0.0638823529411765']
# ['At iteration 5 the best fitness is 0.06337815126050424']
# ['At iteration 6 the best fitness is 0.06287394957983197']
# ['At iteration 7 the best fitness is 0.06287394957983197']
# ['At iteration 8 the best fitness is 0.06287394957983197']
# ['At iteration 9 the best fitness is 0.057128851540616234']
# ['At iteration 10 the best fitness is 0.057128851540616234']
# ['At iteration 11 the best fitness is 0.057128851540616234']
# ['At iteration 12 the best fitness is 0.057128851540616234']
# ['At iteration 13 the best fitness is 0.057128851540616234']
# ['At iteration 14 the best fitness is 0.057128851540616234']
# ['At iteration 15 the best fitness is 0.057128851540616234']
# ['At iteration 16 the best fitness is 0.057128851540616234']
# ['At iteration 17 the best fitness is 0.05654061624649859']
# ['At iteration 18 the best fitness is 0.05121568627450976']
# ['At iteration 19 the best fitness is 0.05121568627450976']
# ['At iteration 20 the best fitness is 0.05121568627450976']
# ['At iteration 21 the best fitness is 0.05121568627450976']
# ['At iteration 22 the best fitness is 0.05121568627450976']
# ['At iteration 23 the best fitness is 0.05121568627450976']
# ['At iteration 24 the best fitness is 0.05121568627450976']
# ['At iteration 25 the best fitness is 0.05121568627450976']
# ['At iteration 26 the best fitness is 0.05054341736694673']
# ['At iteration 27 the best fitness is 0.05054341736694673']
# ['At iteration 28 the best fitness is 0.05054341736694673']
# ['At iteration 29 the best fitness is 0.04961904761904757']
# ['At iteration 30 the best fitness is 0.048862745098039166']
#       Selected: 282/595 (47.4%), Fitness: 0.0489, Time: 756.2s
#       Modality: D=49%, S=56%, Sk=46%, V=47%
#     Test Acc: 81.31%, F1: 78.27%, Features: 282/595 (47.4%), Model: 1.092MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06912324929971986']
# ['At iteration 1 the best fitness is 0.06052100840336138']
# ['At iteration 2 the best fitness is 0.06052100840336138']
# ['At iteration 3 the best fitness is 0.04990196078431371']
# ['At iteration 4 the best fitness is 0.04990196078431371']
# ['At iteration 5 the best fitness is 0.04990196078431371']
# ['At iteration 6 the best fitness is 0.04990196078431371']
# ['At iteration 7 the best fitness is 0.04990196078431371']
# ['At iteration 8 the best fitness is 0.04990196078431371']
# ['At iteration 9 the best fitness is 0.04990196078431371']
# ['At iteration 10 the best fitness is 0.04990196078431371']
# ['At iteration 11 the best fitness is 0.04990196078431371']
# ['At iteration 12 the best fitness is 0.04990196078431371']
# ['At iteration 13 the best fitness is 0.04990196078431371']
# ['At iteration 14 the best fitness is 0.04990196078431371']
# ['At iteration 15 the best fitness is 0.04990196078431371']
# ['At iteration 16 the best fitness is 0.04990196078431371']
# ['At iteration 17 the best fitness is 0.04990196078431371']
# ['At iteration 18 the best fitness is 0.04990196078431371']
# ['At iteration 19 the best fitness is 0.04990196078431371']
# ['At iteration 20 the best fitness is 0.04990196078431371']
# ['At iteration 21 the best fitness is 0.04990196078431371']
# ['At iteration 22 the best fitness is 0.04990196078431371']
# ['At iteration 23 the best fitness is 0.04990196078431371']
# ['At iteration 24 the best fitness is 0.04990196078431371']
# ['At iteration 25 the best fitness is 0.04990196078431371']
# ['At iteration 26 the best fitness is 0.04990196078431371']
# ['At iteration 27 the best fitness is 0.04990196078431371']
# ['At iteration 28 the best fitness is 0.04990196078431371']
# ['At iteration 29 the best fitness is 0.04990196078431371']
#       Selected: 227/595 (38.2%), Fitness: 0.0499, Time: 702.7s
#       Modality: D=32%, S=41%, Sk=40%, V=36%
#     Test Acc: 81.31%, F1: 79.22%, Features: 227/595 (38.2%), Model: 0.823MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06203361344537819']
# ['At iteration 2 the best fitness is 0.055784313725490184']
# ['At iteration 3 the best fitness is 0.055784313725490184']
# ['At iteration 4 the best fitness is 0.055784313725490184']
# ['At iteration 5 the best fitness is 0.05528011204481792']
# ['At iteration 6 the best fitness is 0.05528011204481792']
# ['At iteration 7 the best fitness is 0.05528011204481792']
# ['At iteration 8 the best fitness is 0.05528011204481792']
# ['At iteration 9 the best fitness is 0.05502801120448178']
# ['At iteration 10 the best fitness is 0.05502801120448178']
# ['At iteration 11 the best fitness is 0.05502801120448178']
# ['At iteration 12 the best fitness is 0.04877871148459379']
# ['At iteration 13 the best fitness is 0.04877871148459379']
# ['At iteration 14 the best fitness is 0.04877871148459379']
# ['At iteration 15 the best fitness is 0.04877871148459379']
# ['At iteration 16 the best fitness is 0.04877871148459379']
# ['At iteration 17 the best fitness is 0.04877871148459379']
# ['At iteration 18 the best fitness is 0.04877871148459379']
# ['At iteration 19 the best fitness is 0.04869467787114841']
# ['At iteration 20 the best fitness is 0.04869467787114841']
# ['At iteration 21 the best fitness is 0.04869467787114841']
# ['At iteration 22 the best fitness is 0.04869467787114841']
# ['At iteration 23 the best fitness is 0.04869467787114841']
# ['At iteration 24 the best fitness is 0.04869467787114841']
# ['At iteration 25 the best fitness is 0.04869467787114841']
# ['At iteration 26 the best fitness is 0.04236134453781515']
# ['At iteration 27 the best fitness is 0.04236134453781515']
# ['At iteration 28 the best fitness is 0.04236134453781515']
# ['At iteration 29 the best fitness is 0.04236134453781515']
#       Selected: 276/595 (46.4%), Fitness: 0.0424, Time: 1897.0s
#       Modality: D=43%, S=48%, Sk=47%, V=46%
#     Test Acc: 85.98%, F1: 83.85%, Features: 276/595 (46.4%), Model: 1.080MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06828291316526608']
# ['At iteration 1 the best fitness is 0.06828291316526608']
# ['At iteration 2 the best fitness is 0.06828291316526608']
# ['At iteration 3 the best fitness is 0.06828291316526608']
# ['At iteration 4 the best fitness is 0.06806162464985994']
# ['At iteration 5 the best fitness is 0.06806162464985994']
# ['At iteration 6 the best fitness is 0.06794677871148457']
# ['At iteration 7 the best fitness is 0.0650588235294118']
# ['At iteration 8 the best fitness is 0.0650588235294118']
# ['At iteration 9 the best fitness is 0.0650588235294118']
# ['At iteration 10 the best fitness is 0.0650588235294118']
# ['At iteration 11 the best fitness is 0.0650588235294118']
# ['At iteration 12 the best fitness is 0.0650588235294118']
# ['At iteration 13 the best fitness is 0.0650588235294118']
# ['At iteration 14 the best fitness is 0.0650588235294118']
# ['At iteration 15 the best fitness is 0.05875630252100844']
# ['At iteration 16 the best fitness is 0.05875630252100844']
# ['At iteration 17 the best fitness is 0.05875630252100844']
# ['At iteration 18 the best fitness is 0.05875630252100844']
# ['At iteration 19 the best fitness is 0.05875630252100844']
# ['At iteration 20 the best fitness is 0.05875630252100844']
# ['At iteration 21 the best fitness is 0.05875630252100844']
# ['At iteration 22 the best fitness is 0.05875630252100844']
# ['At iteration 23 the best fitness is 0.05875630252100844']
# ['At iteration 24 the best fitness is 0.05875630252100844']
# ['At iteration 25 the best fitness is 0.05875630252100844']
# ['At iteration 26 the best fitness is 0.05875630252100844']
# ['At iteration 27 the best fitness is 0.05875630252100844']
# ['At iteration 28 the best fitness is 0.05875630252100844']
# ['At iteration 29 the best fitness is 0.05875630252100844']
#       Selected: 266/595 (44.7%), Fitness: 0.0588, Time: 659.7s
#       Modality: D=27%, S=52%, Sk=45%, V=45%
#     Test Acc: 85.05%, F1: 83.24%, Features: 266/595 (44.7%), Model: 1.061MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_10_loss/all_results_per_fold.csv
# Shape: (144, 28)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            87.9630           96.6667       86.8607          86.8607              88.3838           87.9630                595             595                100.000       0.0000          6.0764          6.0764        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 1      baseline     2            78.7037           98.0000       76.4654          76.4654              78.5185           78.7037                595             595                100.000       0.0000         10.1085         10.1085        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 2      baseline     3            79.6296           94.0000       77.1204          77.1204              81.6114           79.6296                595             595                100.000       0.0000         10.2104         10.2104        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 3      baseline     4            81.4815           96.0000       80.2744          80.2744              82.4956           81.4815                595             595                100.000       0.0000         10.1072         10.1072        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 4      baseline     5            76.8519           94.6667       76.1505          76.1505              83.1893           76.8519                595             595                100.000       0.0000         10.1266         10.1266        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 5      baseline     6            66.3551           96.0000       63.5861          63.2458              67.2134           66.6667                595             595                100.000       0.0000         10.2581         10.2581        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 6      baseline     7            67.2897           97.3333       65.3597          65.0360              73.2510           67.5926                595             595                100.000       0.0000         10.0240         10.0240        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 7      baseline     8            84.1121           97.3333       82.3810          82.2163              86.9136           84.2593                595             595                100.000       0.0000         10.0978         10.0978        444955           1.7032                 3.9085                  3.9085                  0.000        27.7915             100.0000              37              100.0000               54                100.0000                240             100.0000             264
# 8   mutual_info     1            89.8148           98.0000       87.9729          87.9729              90.1411           89.8148                297             595                 49.916       3.5454          9.9000         13.4455        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              10.8108               4               35.1852               19                 31.6667                 76              75.0000             198
# 9   mutual_info     2            79.6296           98.0000       76.5972          76.5972              79.8942           79.6296                297             595                 49.916       3.4013         11.4762         14.8776        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               2.7027               1               38.8889               21                 32.0833                 77              75.0000             198
# 10  mutual_info     3            79.6296           97.3333       77.8924          77.8924              79.6384           79.6296                297             595                 49.916       3.3650         12.3947         15.7598        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               2.7027               1               37.0370               20                 32.5000                 78              75.0000             198
# 11  mutual_info     4            74.0741           97.3333       72.0763          72.0763              76.3139           74.0741                297             595                 49.916       3.3363         11.8946         15.2310        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               2.7027               1               42.5926               23                 31.2500                 75              75.0000             198
# 12  mutual_info     5            81.4815           98.0000       80.2833          80.2833              91.0758           81.4815                297             595                 49.916       3.3483         12.2039         15.5523        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               2.7027               1               33.3333               18                 33.3333                 80              75.0000             198
# 13  mutual_info     6            51.4019           98.6667       46.3444          45.8429              48.0133           51.8519                297             595                 49.916       3.4151         12.2352         15.6504        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               5.4054               2               42.5926               23                 30.8333                 74              75.0000             198
# 14  mutual_info     7            81.3084           99.3333       79.4142          79.2219              83.8624           81.4815                297             595                 49.916       3.4164         12.0454         15.4619        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               8.1081               3               40.7407               22                 30.8333                 74              75.0000             198
# 15  mutual_info     8            83.1776           99.3333       80.4714          80.5226              82.0165           83.3333                297             595                 49.916       3.3335         12.5579         15.8915        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995               8.1081               3               31.4815               17                 32.9167                 79              75.0000             198
# 16          rfe     1            85.1852           98.0000       83.5861          83.5861              85.0617           85.1852                297             595                 49.916       0.5631         11.6227         12.1859        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              13.5135               5               90.7407               49                 44.1667                106              51.8939             137
# 17          rfe     2            81.4815          100.0000       78.6126          78.6126              79.0741           81.4815                297             595                 49.916       0.5410         12.2500         12.7913        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              13.5135               5               87.0370               47                 43.7500                105              53.0303             140
# 18          rfe     3            82.4074           97.3333       80.1099          80.1099              81.7695           82.4074                297             595                 49.916       0.5398         12.3039         12.8439        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              18.9189               7               94.4444               51                 42.9167                103              51.5152             136
# 19          rfe     4            80.5556           98.0000       78.1786          78.1786              82.0002           80.5556                297             595                 49.916       0.5463         12.0814         12.6279        292379           1.1212                 3.9085                  1.9510                 50.084        23.9995              16.2162               6               92.5926               50                 41.2500                 99              53.7879             142

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              77.80              7.59              76.02              7.98                  595.00                      100.00              0.00                 9.63                 9.63           444955.0                  1.70                        0.00               27.79
# mutual_info              77.56             11.44              75.13             12.46                  297.00                       49.92              3.40                11.84                15.23           292379.0                  1.12                       50.08               24.00
#         rfe              81.30              6.62              78.99              7.96                  297.00                       49.92              0.55                12.02                12.57           292379.0                  1.12                       50.08               24.00
#       lasso              72.34             12.31              68.57             13.81                  297.00                       49.92              0.07                12.38                12.45           292379.0                  1.12                       50.08               24.00
#    meta_BAT              75.61              8.18              72.65              9.43                  289.88                       48.72            774.06                12.32               786.38           288731.0                  1.11                       51.28               23.91
#     meta_CS              76.06              8.69              73.58             10.05                  296.12                       49.77           1524.08                12.34              1536.43           291931.0                  1.12                       50.23               23.99
#     meta_DE              75.25              9.03              72.02             10.23                  287.75                       48.36            774.82                12.38               787.20           287643.0                  1.10                       51.64               23.89
#    meta_FFA              78.16              8.07              76.27              8.97                  297.38                       49.98            751.47                12.40               763.87           292571.0                  1.12                       50.02               24.00
#     meta_GA              77.35              6.42              75.16              6.99                  297.88                       50.06            750.38                12.33               762.70           292827.0                  1.12                       49.94               24.01
#    meta_GWO              77.69              6.32              75.01              7.75                  245.25                       41.22            738.01                12.01               750.02           245480.0                  0.94                       58.78               22.92
#    meta_HHO              76.29             10.22              73.74             11.22                  232.75                       39.12            973.82                12.12               985.94           203696.0                  0.78                       60.88               21.97
#   meta_JAYA              76.29              8.95              73.64             10.63                  286.75                       48.19            775.39                12.37               787.75           287131.0                  1.10                       51.81               23.88
#    meta_MFO              78.04              8.40              75.93              9.73                  301.88                       50.74            727.71                12.36               740.07           294875.0                  1.13                       49.26               24.06
#    meta_MVO              77.47              6.37              75.74              6.44                  293.00                       49.24            751.69                12.37               764.06           290331.0                  1.11                       50.76               23.95
#    meta_PSO              77.45              7.13              75.37              7.73                  287.38                       48.30            749.61                12.23               761.84           287451.0                  1.10                       51.70               23.89
#    meta_SCA              75.70              9.27              72.87             10.87                  192.25                       32.31            694.27                11.79               706.06           159442.0                  0.61                       67.69               20.96
#    meta_SSA              76.53              7.91              74.07              9.42                  289.00                       48.57           1872.56                12.26              1884.82           288283.0                  1.11                       51.43               23.90
#    meta_WOA              76.53              7.72              74.13              8.63                  239.25                       40.21            695.60                11.90               707.50           217631.0                  0.84                       59.79               22.29

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 77.56% vs Baseline: 77.80%
#   Paired t-test: t=-0.0781, p=0.9399
#   Wilcoxon test: W=14.0000, p=1.0000
#   -> worse, Not significant
#
# RFE vs BASELINE:
#   Method: 81.30% vs Baseline: 77.80%
#   Paired t-test: t=1.7272, p=0.1278
#   Wilcoxon test: W=5.0000, p=0.0781
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 72.34% vs Baseline: 77.80%
#   Paired t-test: t=-1.5178, p=0.1729
#   Wilcoxon test: W=8.0000, p=0.1953
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 75.61% vs Baseline: 77.80%
#   Paired t-test: t=-0.8918, p=0.4021
#   Wilcoxon test: W=12.0000, p=0.4609
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 76.06% vs Baseline: 77.80%
#   Paired t-test: t=-0.8293, p=0.4343
#   Wilcoxon test: W=5.0000, p=0.3125
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 75.25% vs Baseline: 77.80%
#   Paired t-test: t=-1.4164, p=0.1996
#   Wilcoxon test: W=9.5000, p=0.2656
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 78.16% vs Baseline: 77.80%
#   Paired t-test: t=0.2241, p=0.8291
#   Wilcoxon test: W=12.0000, p=0.8125
#   -> better, Not significant
#
# META_GA vs BASELINE:
#   Method: 77.35% vs Baseline: 77.80%
#   Paired t-test: t=-0.1706, p=0.8693
#   Wilcoxon test: W=11.0000, p=0.6875
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 77.69% vs Baseline: 77.80%
#   Paired t-test: t=-0.0626, p=0.9518
#   Wilcoxon test: W=11.0000, p=0.6875
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 76.29% vs Baseline: 77.80%
#   Paired t-test: t=-0.6399, p=0.5426
#   Wilcoxon test: W=8.5000, p=0.4062
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 76.29% vs Baseline: 77.80%
#   Paired t-test: t=-0.9807, p=0.3594
#   Wilcoxon test: W=9.0000, p=0.4531
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 78.04% vs Baseline: 77.80%
#   Paired t-test: t=0.1177, p=0.9096
#   Wilcoxon test: W=10.0000, p=1.0000
#   -> better, Not significant
#
# META_MVO vs BASELINE:
#   Method: 77.47% vs Baseline: 77.80%
#   Paired t-test: t=-0.1500, p=0.8850
#   Wilcoxon test: W=9.0000, p=0.4531
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 77.45% vs Baseline: 77.80%
#   Paired t-test: t=-0.2618, p=0.8010
#   Wilcoxon test: W=15.5000, p=0.7656
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 75.70% vs Baseline: 77.80%
#   Paired t-test: t=-1.3719, p=0.2124
#   Wilcoxon test: W=10.0000, p=0.3125
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 76.53% vs Baseline: 77.80%
#   Paired t-test: t=-0.8225, p=0.4379
#   Wilcoxon test: W=14.0000, p=0.6406
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 76.53% vs Baseline: 77.80%
#   Paired t-test: t=-0.7119, p=0.4995
#   Wilcoxon test: W=14.5000, p=0.6641
#   -> worse, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_10_loss
#
# Per-method folders:
#   results_10_loss/baseline/ (16 files)
#   results_10_loss/mutual_info/ (16 files)
#   results_10_loss/rfe/ (16 files)
#   results_10_loss/lasso/ (16 files)
#   results_10_loss/meta_BAT/ (16 files)
#   results_10_loss/meta_CS/ (16 files)
#   results_10_loss/meta_DE/ (16 files)
#   results_10_loss/meta_FFA/ (16 files)
#   results_10_loss/meta_GA/ (16 files)
#   results_10_loss/meta_GWO/ (16 files)
#   results_10_loss/meta_HHO/ (16 files)
#   results_10_loss/meta_JAYA/ (16 files)
#   results_10_loss/meta_MFO/ (16 files)
#   results_10_loss/meta_MVO/ (16 files)
#   results_10_loss/meta_PSO/ (16 files)
#   results_10_loss/meta_SCA/ (16 files)
#   results_10_loss/meta_SSA/ (16 files)
#   results_10_loss/meta_WOA/ (16 files)
#
# Plots directory: results_10_loss/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   rfe                 : 81.30% ± 6.62% (Features: 49.9%)
#   meta_FFA            : 78.16% ± 8.07% (Features: 50.0%)
#   meta_MFO            : 78.04% ± 8.40% (Features: 50.7%)
#   baseline            : 77.80% ± 7.59% (Features: 100.0%)
#   meta_GWO            : 77.69% ± 6.32% (Features: 41.2%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_HHO
#     Test Accuracy:      87.96%
#     Feature Retention:  68.74% (409/595)
#     Modality Retention: depth=64.9%, sensor=64.8%, skeleton=70.0%, video=68.9%
#
#   Fold 2: Best = meta_GA
#     Test Accuracy:      83.33%
#     Feature Retention:  48.91% (291/595)
#     Modality Retention: depth=56.8%, sensor=66.7%, skeleton=45.0%, video=47.7%
#
#   Fold 3: Best = meta_WOA
#     Test Accuracy:      85.19%
#     Feature Retention:  30.59% (182/595)
#     Modality Retention: depth=43.2%, sensor=38.9%, skeleton=26.2%, video=31.1%
#
#   Fold 4: Best = meta_JAYA
#     Test Accuracy:      80.56%
#     Feature Retention:  49.92% (297/595)
#     Modality Retention: depth=56.8%, sensor=51.9%, skeleton=49.6%, video=48.9%
#
#   Fold 5: Best = meta_FFA
#     Test Accuracy:      83.33%
#     Feature Retention:  50.25% (299/595)
#     Modality Retention: depth=59.5%, sensor=50.0%, skeleton=47.1%, video=51.9%
#
#   Fold 6: Best = meta_FFA
#     Test Accuracy:      66.36%
#     Feature Retention:  50.25% (299/595)
#     Modality Retention: depth=62.2%, sensor=40.7%, skeleton=45.0%, video=55.3%
#
#   Fold 7: Best = meta_GA
#     Test Accuracy:      81.31%
#     Feature Retention:  50.92% (303/595)
#     Modality Retention: depth=48.6%, sensor=48.1%, skeleton=50.4%, video=52.3%
#
#   Fold 8: Best = meta_BAT
#     Test Accuracy:      90.65%
#     Feature Retention:  49.08% (292/595)
#     Modality Retention: depth=45.9%, sensor=48.1%, skeleton=48.3%, video=50.4%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     82.34% ± 7.28%
#   Average Feature Retention: 49.83% ± 10.22%
#
#   Average Modality-wise Feature Retention:
#          depth: 54.73% ± 7.88%
#         sensor: 51.16% ± 10.04%
#       skeleton: 47.71% ± 11.85%
#          video: 50.80% ± 10.39%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)  video Retention (%)
#     1           meta_HHO              87.96                  68.74                64.86                 64.81                   70.00                68.94
#     2            meta_GA              83.33                  48.91                56.76                 66.67                   45.00                47.73
#     3           meta_WOA              85.19                  30.59                43.24                 38.89                   26.25                31.06
#     4          meta_JAYA              80.56                  49.92                56.76                 51.85                   49.58                48.86
#     5           meta_FFA              83.33                  50.25                59.46                 50.00                   47.08                51.89
#     6           meta_FFA              66.36                  50.25                62.16                 40.74                   45.00                55.30
#     7            meta_GA              81.31                  50.92                48.65                 48.15                   50.42                52.27
#     8           meta_BAT              90.65                  49.08                45.95                 48.15                   48.33                50.38
#
# Saved to: results_10_loss/best_metaheuristic_per_fold.csv
