# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (10% Random Noise)
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.
#
#
# > **Modification:** This notebook randomly zeros out 10% of all data elements before any processing.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new_10_noise")

# Master output directory
RESULTS_ROOT = Path("results_new_10_noise")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   video: 1420
#   TOTAL: 3933

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 94.44%, F1: 94.17%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 22.5s
#     Test Acc: 96.30%, F1: 95.83%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.3s
#     Test Acc: 99.07%, F1: 99.06%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.2s
#     Test Acc: 75.00%, F1: 74.29%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03731706076786166']
# ['At iteration 1 the best fitness is 0.03098372743452839']
# ['At iteration 2 the best fitness is 0.024790236460717013']
# ['At iteration 3 the best fitness is 0.024790236460717013']
# ['At iteration 4 the best fitness is 0.024790236460717013']
# ['At iteration 5 the best fitness is 0.024790236460717013']
# ['At iteration 6 the best fitness is 0.024790236460717013']
# ['At iteration 7 the best fitness is 0.024790236460717013']
# ['At iteration 8 the best fitness is 0.024790236460717013']
# ['At iteration 9 the best fitness is 0.024790236460717013']
# ['At iteration 10 the best fitness is 0.024790236460717013']
# ['At iteration 11 the best fitness is 0.024790236460717013']
# ['At iteration 12 the best fitness is 0.024790236460717013']
# ['At iteration 13 the best fitness is 0.024790236460717013']
# ['At iteration 14 the best fitness is 0.024790236460717013']
# ['At iteration 15 the best fitness is 0.024790236460717013']
# ['At iteration 16 the best fitness is 0.024790236460717013']
# ['At iteration 17 the best fitness is 0.024790236460717013']
# ['At iteration 18 the best fitness is 0.024790236460717013']
# ['At iteration 19 the best fitness is 0.024790236460717013']
# ['At iteration 20 the best fitness is 0.024790236460717013']
# ['At iteration 21 the best fitness is 0.024790236460717013']
# ['At iteration 22 the best fitness is 0.024790236460717013']
# ['At iteration 23 the best fitness is 0.024790236460717013']
# ['At iteration 24 the best fitness is 0.024790236460717013']
# ['At iteration 25 the best fitness is 0.024790236460717013']
# ['At iteration 26 the best fitness is 0.024790236460717013']
# ['At iteration 27 the best fitness is 0.024790236460717013']
# ['At iteration 28 the best fitness is 0.024790236460717013']
# ['At iteration 29 the best fitness is 0.024790236460717013']
#       Selected: 1952/3933 (49.6%), Fitness: 0.0248, Time: 911.6s
#       Modality: D=47%, S=49%, Sk=52%, V=48%
#     Test Acc: 92.59%, F1: 91.21%, Features: 1952/3933 (49.6%), Model: 4.354MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03092016272565476']
# ['At iteration 10 the best fitness is 0.024586829392321385']
# ['At iteration 20 the best fitness is 0.024586829392321385']
#       Selected: 1978/3933 (50.3%), Fitness: 0.0246, Time: 1795.6s
#       Modality: D=51%, S=53%, Sk=49%, V=50%
#     Test Acc: 95.37%, F1: 94.34%, Features: 1978/3933 (50.3%), Model: 4.404MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.037660310195779284']
# ['At iteration 2 the best fitness is 0.030627765064836044']
# ['At iteration 3 the best fitness is 0.030627765064836044']
# ['At iteration 4 the best fitness is 0.030627765064836044']
# ['At iteration 5 the best fitness is 0.030627765064836044']
# ['At iteration 6 the best fitness is 0.030627765064836044']
# ['At iteration 7 the best fitness is 0.030627765064836044']
# ['At iteration 8 the best fitness is 0.030627765064836044']
# ['At iteration 9 the best fitness is 0.030627765064836044']
# ['At iteration 10 the best fitness is 0.030627765064836044']
# ['At iteration 11 the best fitness is 0.030627765064836044']
# ['At iteration 12 the best fitness is 0.030627765064836044']
# ['At iteration 13 the best fitness is 0.030627765064836044']
# ['At iteration 14 the best fitness is 0.030627765064836044']
# ['At iteration 15 the best fitness is 0.030627765064836044']
# ['At iteration 16 the best fitness is 0.030627765064836044']
# ['At iteration 17 the best fitness is 0.030627765064836044']
# ['At iteration 18 the best fitness is 0.030627765064836044']
# ['At iteration 19 the best fitness is 0.024472412916348843']
# ['At iteration 20 the best fitness is 0.024472412916348843']
# ['At iteration 21 the best fitness is 0.024472412916348843']
# ['At iteration 22 the best fitness is 0.024256292906178492']
# ['At iteration 23 the best fitness is 0.024256292906178492']
# ['At iteration 24 the best fitness is 0.024256292906178492']
# ['At iteration 25 the best fitness is 0.024256292906178492']
# ['At iteration 26 the best fitness is 0.024256292906178492']
# ['At iteration 27 the best fitness is 0.024256292906178492']
# ['At iteration 28 the best fitness is 0.024256292906178492']
# ['At iteration 29 the best fitness is 0.024256292906178492']
# ['At iteration 30 the best fitness is 0.024167302313755405']
#       Selected: 1947/3933 (49.5%), Fitness: 0.0242, Time: 910.0s
#       Modality: D=47%, S=53%, Sk=49%, V=49%
#     Test Acc: 95.37%, F1: 93.93%, Features: 1947/3933 (49.5%), Model: 4.344MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.038067124332570534']
# ['At iteration 1 the best fitness is 0.04393007882023903']
# ['At iteration 2 the best fitness is 0.03731706076786166']
# ['At iteration 3 the best fitness is 0.03167022629036363']
# ['At iteration 4 the best fitness is 0.03200076277650653']
# ['At iteration 5 the best fitness is 0.03161937452326473']
# ['At iteration 6 the best fitness is 0.031555809814391086']
# ['At iteration 7 the best fitness is 0.025362318840579712']
# ['At iteration 8 the best fitness is 0.03159394863971527']
# ['At iteration 9 the best fitness is 0.031581235697940545']
# ['At iteration 10 the best fitness is 0.025336892957030257']
# ['At iteration 11 the best fitness is 0.031530383930841635']
# ['At iteration 12 the best fitness is 0.031530383930841635']
# ['At iteration 13 the best fitness is 0.031504958047292184']
# ['At iteration 14 the best fitness is 0.03167022629036363']
# ['At iteration 15 the best fitness is 0.03167022629036363']
# ['At iteration 16 the best fitness is 0.03168293923213836']
# ['At iteration 17 the best fitness is 0.03170836511568781']
# ['At iteration 18 the best fitness is 0.03168293923213836']
# ['At iteration 19 the best fitness is 0.03804169844902108']
# ['At iteration 20 the best fitness is 0.03168293923213836']
# ['At iteration 21 the best fitness is 0.03167022629036363']
# ['At iteration 22 the best fitness is 0.031657513348588906']
# ['At iteration 23 the best fitness is 0.031657513348588906']
# ['At iteration 24 the best fitness is 0.025349605898804986']
# ['At iteration 25 the best fitness is 0.03167022629036363']
# ['At iteration 26 the best fitness is 0.03168293923213836']
# ['At iteration 27 the best fitness is 0.03168293923213836']
# ['At iteration 28 the best fitness is 0.03801627256547163']
# ['At iteration 29 the best fitness is 0.03168293923213836']
#       Selected: 1987/3933 (50.5%), Fitness: 0.0317, Time: 880.7s
#       Modality: D=50%, S=49%, Sk=50%, V=52%
#     Test Acc: 94.44%, F1: 94.52%, Features: 1987/3933 (50.5%), Model: 4.422MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.037342486651411114
# At iteration 2 the best fitness is 0.03154309687261637
# At iteration 3 the best fitness is 0.030996440376303117
# At iteration 4 the best fitness is 0.03095830155097894
# At iteration 5 the best fitness is 0.03144139333841855
# At iteration 6 the best fitness is 0.031339689804220736
# At iteration 7 the best fitness is 0.03069132977370968
# At iteration 8 the best fitness is 0.030856598016781124
# At iteration 9 the best fitness is 0.024942791762013732
# At iteration 10 the best fitness is 0.030869310958555853
# At iteration 11 the best fitness is 0.030869310958555853
# At iteration 12 the best fitness is 0.030805746249682218
# At iteration 13 the best fitness is 0.030704042715484405
# At iteration 14 the best fitness is 0.030780320366132766
# At iteration 15 the best fitness is 0.0308438850750064
# At iteration 16 the best fitness is 0.02461225527587084
# At iteration 17 the best fitness is 0.02448512585812357
# At iteration 18 the best fitness is 0.02453597762522248
# At iteration 19 the best fitness is 0.02461225527587084
# At iteration 20 the best fitness is 0.024663107042969742
# At iteration 21 the best fitness is 0.030805746249682218
# At iteration 22 the best fitness is 0.02437070938215103
# At iteration 23 the best fitness is 0.030793033307907492
# At iteration 24 the best fitness is 0.024434274091024666
# At iteration 25 the best fitness is 0.02444698703279939
# At iteration 26 the best fitness is 0.024319857615052124
# At iteration 27 the best fitness is 0.02453597762522248
# At iteration 28 the best fitness is 0.0243071446732774
# At iteration 29 the best fitness is 0.024230867022629037
# At iteration 30 the best fitness is 0.024459699974574117
#       Selected: 1949/3933 (49.6%), Fitness: 0.0245, Time: 878.6s
#       Modality: D=55%, S=50%, Sk=50%, V=48%
#     Test Acc: 93.52%, F1: 92.97%, Features: 1949/3933 (49.6%), Model: 4.348MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03740605136028474']
# ['At iteration 1 the best fitness is 0.030704042715484405']
# ['At iteration 2 the best fitness is 0.02919120264429193']
# ['At iteration 3 the best fitness is 0.02861912026442923']
# ['At iteration 4 the best fitness is 0.022145944571573862']
# ['At iteration 5 the best fitness is 0.022145944571573862']
# ['At iteration 6 the best fitness is 0.022145944571573862']
# ['At iteration 7 the best fitness is 0.022145944571573862']
# ['At iteration 8 the best fitness is 0.02025171624713959']
# ['At iteration 9 the best fitness is 0.02025171624713959']
# ['At iteration 10 the best fitness is 0.02025171624713959']
# ['At iteration 11 the best fitness is 0.02025171624713959']
# ['At iteration 12 the best fitness is 0.02025171624713959']
# ['At iteration 13 the best fitness is 0.02025171624713959']
# ['At iteration 14 the best fitness is 0.02025171624713959']
# ['At iteration 15 the best fitness is 0.02025171624713959']
# ['At iteration 16 the best fitness is 0.02025171624713959']
# ['At iteration 17 the best fitness is 0.02025171624713959']
# ['At iteration 18 the best fitness is 0.02025171624713959']
# ['At iteration 19 the best fitness is 0.02025171624713959']
# ['At iteration 20 the best fitness is 0.02025171624713959']
# ['At iteration 21 the best fitness is 0.02025171624713959']
# ['At iteration 22 the best fitness is 0.02025171624713959']
# ['At iteration 23 the best fitness is 0.02025171624713959']
# ['At iteration 24 the best fitness is 0.02025171624713959']
# ['At iteration 25 the best fitness is 0.02025171624713959']
# ['At iteration 26 the best fitness is 0.02025171624713959']
# ['At iteration 27 the best fitness is 0.02025171624713959']
# ['At iteration 28 the best fitness is 0.02025171624713959']
# ['At iteration 29 the best fitness is 0.02025171624713959']
#       Selected: 1622/3933 (41.2%), Fitness: 0.0203, Time: 907.7s
#       Modality: D=40%, S=45%, Sk=39%, V=42%
#     Test Acc: 95.37%, F1: 94.89%, Features: 1622/3933 (41.2%), Model: 3.709MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.03711365369946604']
# ['At iteration 1 the best fitness is 0.027797355708110875']
# ['At iteration 2 the best fitness is 0.027797355708110875']
# ['At iteration 3 the best fitness is 0.027797355708110875']
# ['At iteration 4 the best fitness is 0.027797355708110875']
# ['At iteration 5 the best fitness is 0.027797355708110875']
# ['At iteration 6 the best fitness is 0.027797355708110875']
# ['At iteration 7 the best fitness is 0.027797355708110875']
# ['At iteration 8 the best fitness is 0.027797355708110875']
# ['At iteration 9 the best fitness is 0.027797355708110875']
# ['At iteration 10 the best fitness is 0.027797355708110875']
# ['At iteration 11 the best fitness is 0.02716170861937454']
# ['At iteration 12 the best fitness is 0.02716170861937454']
# ['At iteration 13 the best fitness is 0.02716170861937454']
# ['At iteration 14 the best fitness is 0.02716170861937454']
# ['At iteration 15 the best fitness is 0.02716170861937454']
# ['At iteration 16 the best fitness is 0.02716170861937454']
# ['At iteration 17 the best fitness is 0.02716170861937454']
# ['At iteration 18 the best fitness is 0.02716170861937454']
# ['At iteration 19 the best fitness is 0.02716170861937454']
# ['At iteration 20 the best fitness is 0.02716170861937454']
# ['At iteration 21 the best fitness is 0.02716170861937454']
# ['At iteration 22 the best fitness is 0.02716170861937454']
# ['At iteration 23 the best fitness is 0.02716170861937454']
# ['At iteration 24 the best fitness is 0.02716170861937454']
# ['At iteration 25 the best fitness is 0.02716170861937454']
# ['At iteration 26 the best fitness is 0.02716170861937454']
# ['At iteration 27 the best fitness is 0.02716170861937454']
# ['At iteration 28 the best fitness is 0.02716170861937454']
# ['At iteration 29 the best fitness is 0.02716170861937454']
#       Selected: 758/3933 (19.3%), Fitness: 0.0272, Time: 1132.7s
#       Modality: D=18%, S=19%, Sk=19%, V=21%
#     Test Acc: 87.96%, F1: 87.41%, Features: 758/3933 (19.3%), Model: 2.022MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03178464276633617']
# ['At iteration 1 the best fitness is 0.03178464276633617']
# ['At iteration 2 the best fitness is 0.03178464276633617']
# ['At iteration 3 the best fitness is 0.031581235697940545']
# ['At iteration 4 the best fitness is 0.031581235697940545']
# ['At iteration 5 the best fitness is 0.031555809814391086']
# ['At iteration 6 the best fitness is 0.031555809814391086']
# ['At iteration 7 the best fitness is 0.031555809814391086']
# ['At iteration 8 the best fitness is 0.031555809814391086']
# ['At iteration 9 the best fitness is 0.031555809814391086']
# ['At iteration 10 the best fitness is 0.031555809814391086']
# ['At iteration 11 the best fitness is 0.031555809814391086']
# ['At iteration 12 the best fitness is 0.031555809814391086']
# ['At iteration 13 the best fitness is 0.02499364352911264']
# ['At iteration 14 the best fitness is 0.02499364352911264']
# ['At iteration 15 the best fitness is 0.02499364352911264']
# ['At iteration 16 the best fitness is 0.02499364352911264']
# ['At iteration 17 the best fitness is 0.02499364352911264']
# ['At iteration 18 the best fitness is 0.02457411645054666']
# ['At iteration 19 the best fitness is 0.02457411645054666']
# ['At iteration 20 the best fitness is 0.02457411645054666']
# ['At iteration 21 the best fitness is 0.02457411645054666']
# ['At iteration 22 the best fitness is 0.02457411645054666']
# ['At iteration 23 the best fitness is 0.02457411645054666']
# ['At iteration 24 the best fitness is 0.02457411645054666']
# ['At iteration 25 the best fitness is 0.02457411645054666']
# ['At iteration 26 the best fitness is 0.02457411645054666']
# ['At iteration 27 the best fitness is 0.02457411645054666']
# ['At iteration 28 the best fitness is 0.02457411645054666']
# ['At iteration 29 the best fitness is 0.02457411645054666']
#       Selected: 1956/3933 (49.7%), Fitness: 0.0246, Time: 907.8s
#       Modality: D=49%, S=51%, Sk=50%, V=49%
#     Test Acc: 92.59%, F1: 92.09%, Features: 1956/3933 (49.7%), Model: 4.361MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0441589117721841']
# ['At iteration 2 the best fitness is 0.03816882786676835']
# ['At iteration 3 the best fitness is 0.031390541571319645']
# ['At iteration 4 the best fitness is 0.031390541571319645']
# ['At iteration 5 the best fitness is 0.031390541571319645']
# ['At iteration 6 the best fitness is 0.031390541571319645']
# ['At iteration 7 the best fitness is 0.024955504703788458']
# ['At iteration 8 the best fitness is 0.024955504703788458']
# ['At iteration 9 the best fitness is 0.024955504703788458']
# ['At iteration 10 the best fitness is 0.024955504703788458']
# ['At iteration 11 the best fitness is 0.024955504703788458']
# ['At iteration 12 the best fitness is 0.024955504703788458']
# ['At iteration 13 the best fitness is 0.024955504703788458']
# ['At iteration 14 the best fitness is 0.024955504703788458']
# ['At iteration 15 the best fitness is 0.024955504703788458']
# ['At iteration 16 the best fitness is 0.024955504703788458']
# ['At iteration 17 the best fitness is 0.024955504703788458']
# ['At iteration 18 the best fitness is 0.024955504703788458']
# ['At iteration 19 the best fitness is 0.024955504703788458']
# ['At iteration 20 the best fitness is 0.024955504703788458']
# ['At iteration 21 the best fitness is 0.024955504703788458']
# ['At iteration 22 the best fitness is 0.024955504703788458']
# ['At iteration 23 the best fitness is 0.024713958810068652']
# ['At iteration 24 the best fitness is 0.024713958810068652']
# ['At iteration 25 the best fitness is 0.024713958810068652']
# ['At iteration 26 the best fitness is 0.024713958810068652']
# ['At iteration 27 the best fitness is 0.024713958810068652']
# ['At iteration 28 the best fitness is 0.024713958810068652']
# ['At iteration 29 the best fitness is 0.024713958810068652']
#       Selected: 1922/3933 (48.9%), Fitness: 0.0247, Time: 857.5s
#       Modality: D=50%, S=50%, Sk=47%, V=50%
#     Test Acc: 95.37%, F1: 94.20%, Features: 1922/3933 (48.9%), Model: 4.295MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.043726671751843395']
# ['At iteration 2 the best fitness is 0.0372407831172133']
# ['At iteration 3 the best fitness is 0.030907449783880034']
# ['At iteration 4 the best fitness is 0.030907449783880034']
# ['At iteration 5 the best fitness is 0.030907449783880034']
# ['At iteration 6 the best fitness is 0.030894736842105305']
# ['At iteration 7 the best fitness is 0.030831172133231673']
# ['At iteration 8 the best fitness is 0.02457411645054666']
# ['At iteration 9 the best fitness is 0.02457411645054666']
# ['At iteration 10 the best fitness is 0.02433257055682685']
# ['At iteration 11 the best fitness is 0.02433257055682685']
# ['At iteration 12 the best fitness is 0.02433257055682685']
# ['At iteration 13 the best fitness is 0.02433257055682685']
# ['At iteration 14 the best fitness is 0.02433257055682685']
# ['At iteration 15 the best fitness is 0.02433257055682685']
# ['At iteration 16 the best fitness is 0.02433257055682685']
# ['At iteration 17 the best fitness is 0.02433257055682685']
# ['At iteration 18 the best fitness is 0.02433257055682685']
# ['At iteration 19 the best fitness is 0.02433257055682685']
# ['At iteration 20 the best fitness is 0.02433257055682685']
# ['At iteration 21 the best fitness is 0.02433257055682685']
# ['At iteration 22 the best fitness is 0.024243579964403766']
# ['At iteration 23 the best fitness is 0.024243579964403766']
# ['At iteration 24 the best fitness is 0.024243579964403766']
# ['At iteration 25 the best fitness is 0.024243579964403766']
# ['At iteration 26 the best fitness is 0.024243579964403766']
# ['At iteration 27 the best fitness is 0.024243579964403766']
# ['At iteration 28 the best fitness is 0.024243579964403766']
# ['At iteration 29 the best fitness is 0.024243579964403766']
# ['At iteration 30 the best fitness is 0.02421815408085431']
#       Selected: 1926/3933 (49.0%), Fitness: 0.0242, Time: 881.1s
#       Modality: D=48%, S=50%, Sk=49%, V=49%
#     Test Acc: 96.30%, F1: 96.05%, Features: 1926/3933 (49.0%), Model: 4.303MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03750775489448256']
# ['At iteration 2 the best fitness is 0.03750775489448256']
# ['At iteration 3 the best fitness is 0.03750775489448256']
# ['At iteration 4 the best fitness is 0.03750775489448256']
# ['At iteration 5 the best fitness is 0.030780320366132766']
# ['At iteration 6 the best fitness is 0.030780320366132766']
# ['At iteration 7 the best fitness is 0.030780320366132766']
# ['At iteration 8 the best fitness is 0.030780320366132766']
# ['At iteration 9 the best fitness is 0.030780320366132766']
# ['At iteration 10 the best fitness is 0.030780320366132766']
# ['At iteration 11 the best fitness is 0.030780320366132766']
# ['At iteration 12 the best fitness is 0.030780320366132766']
# ['At iteration 13 the best fitness is 0.030780320366132766']
# ['At iteration 14 the best fitness is 0.030780320366132766']
# ['At iteration 15 the best fitness is 0.030780320366132766']
# ['At iteration 16 the best fitness is 0.030780320366132766']
# ['At iteration 17 the best fitness is 0.030780320366132766']
# ['At iteration 18 the best fitness is 0.030780320366132766']
# ['At iteration 19 the best fitness is 0.030780320366132766']
# ['At iteration 20 the best fitness is 0.024624968217645565']
# ['At iteration 21 the best fitness is 0.024624968217645565']
# ['At iteration 22 the best fitness is 0.024624968217645565']
# ['At iteration 23 the best fitness is 0.024624968217645565']
# ['At iteration 24 the best fitness is 0.024624968217645565']
# ['At iteration 25 the best fitness is 0.024624968217645565']
# ['At iteration 26 the best fitness is 0.024624968217645565']
# ['At iteration 27 the best fitness is 0.024624968217645565']
# ['At iteration 28 the best fitness is 0.024624968217645565']
# ['At iteration 29 the best fitness is 0.024624968217645565']
# ['At iteration 30 the best fitness is 0.024624968217645565']
#       Selected: 1972/3933 (50.1%), Fitness: 0.0246, Time: 882.8s
#       Modality: D=51%, S=53%, Sk=49%, V=50%
#     Test Acc: 94.44%, F1: 93.67%, Features: 1972/3933 (50.1%), Model: 4.393MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.037901856089499086']
# ['At iteration 1 the best fitness is 0.037901856089499086']
# ['At iteration 2 the best fitness is 0.03432951945080089']
# ['At iteration 3 the best fitness is 0.03432951945080089']
# ['At iteration 4 the best fitness is 0.02456369183829142']
# ['At iteration 5 the best fitness is 0.016552250190694128']
# ['At iteration 6 the best fitness is 0.016552250190694128']
# ['At iteration 7 the best fitness is 0.016552250190694128']
# ['At iteration 8 the best fitness is 0.016552250190694128']
# ['At iteration 9 the best fitness is 0.016552250190694128']
# ['At iteration 10 the best fitness is 0.016552250190694128']
# ['At iteration 11 the best fitness is 0.016552250190694128']
# ['At iteration 12 the best fitness is 0.012674802949402493']
# ['At iteration 13 the best fitness is 0.011530638189677091']
# ['At iteration 14 the best fitness is 0.011530638189677091']
# ['At iteration 15 the best fitness is 0.01061530638189677']
# ['At iteration 16 the best fitness is 0.010195779303330791']
# ['At iteration 17 the best fitness is 0.010195779303330791']
# ['At iteration 18 the best fitness is 0.010195779303330791']
# ['At iteration 19 the best fitness is 0.010195779303330791']
# ['At iteration 20 the best fitness is 0.00897533689295703']
# ['At iteration 21 the best fitness is 0.008492245105517417']
# ['At iteration 22 the best fitness is 0.008492245105517417']
# ['At iteration 23 the best fitness is 0.008492245105517417']
# ['At iteration 24 the best fitness is 0.008492245105517417']
# ['At iteration 25 the best fitness is 0.008492245105517417']
# ['At iteration 26 the best fitness is 0.008492245105517417']
# ['At iteration 27 the best fitness is 0.008492245105517417']
# ['At iteration 28 the best fitness is 0.008492245105517417']
# ['At iteration 29 the best fitness is 0.008492245105517417']
#       Selected: 704/3933 (17.9%), Fitness: 0.0085, Time: 833.1s
#       Modality: D=23%, S=19%, Sk=18%, V=17%
#     Test Acc: 92.59%, F1: 92.22%, Features: 704/3933 (17.9%), Model: 1.916MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024980930587337913']
# ['At iteration 2 the best fitness is 0.024980930587337913']
# ['At iteration 3 the best fitness is 0.024980930587337913']
# ['At iteration 4 the best fitness is 0.024980930587337913']
# ['At iteration 5 the best fitness is 0.024980930587337913']
# ['At iteration 6 the best fitness is 0.024980930587337913']
# ['At iteration 7 the best fitness is 0.024980930587337913']
# ['At iteration 8 the best fitness is 0.024980930587337913']
# ['At iteration 9 the best fitness is 0.024980930587337913']
# ['At iteration 10 the best fitness is 0.024980930587337913']
# ['At iteration 11 the best fitness is 0.024980930587337913']
# ['At iteration 12 the best fitness is 0.024980930587337913']
# ['At iteration 13 the best fitness is 0.024980930587337913']
# ['At iteration 14 the best fitness is 0.024968217645563187']
# ['At iteration 15 the best fitness is 0.024968217645563187']
# ['At iteration 16 the best fitness is 0.024968217645563187']
# ['At iteration 17 the best fitness is 0.024968217645563187']
# ['At iteration 18 the best fitness is 0.024968217645563187']
# ['At iteration 19 the best fitness is 0.024968217645563187']
# ['At iteration 20 the best fitness is 0.024968217645563187']
# ['At iteration 21 the best fitness is 0.024968217645563187']
# ['At iteration 22 the best fitness is 0.024968217645563187']
# ['At iteration 23 the best fitness is 0.024968217645563187']
# ['At iteration 24 the best fitness is 0.024968217645563187']
# ['At iteration 25 the best fitness is 0.024968217645563187']
# ['At iteration 26 the best fitness is 0.024968217645563187']
# ['At iteration 27 the best fitness is 0.024968217645563187']
# ['At iteration 28 the best fitness is 0.024968217645563187']
# ['At iteration 29 the best fitness is 0.024968217645563187']
#       Selected: 1968/3933 (50.0%), Fitness: 0.0250, Time: 2198.2s
#       Modality: D=55%, S=51%, Sk=49%, V=50%
#     Test Acc: 93.52%, F1: 93.07%, Features: 1968/3933 (50.0%), Model: 4.385MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03121256038647347']
# ['At iteration 1 the best fitness is 0.03121256038647347']
# ['At iteration 2 the best fitness is 0.03121256038647347']
# ['At iteration 3 the best fitness is 0.03121256038647347']
# ['At iteration 4 the best fitness is 0.03121256038647347']
# ['At iteration 5 the best fitness is 0.03121256038647347']
# ['At iteration 6 the best fitness is 0.03121256038647347']
# ['At iteration 7 the best fitness is 0.03121256038647347']
# ['At iteration 8 the best fitness is 0.03121256038647347']
# ['At iteration 9 the best fitness is 0.03121256038647347']
# ['At iteration 10 the best fitness is 0.03121256038647347']
# ['At iteration 11 the best fitness is 0.026500635647088752']
# ['At iteration 12 the best fitness is 0.026500635647088752']
# ['At iteration 13 the best fitness is 0.026500635647088752']
# ['At iteration 14 the best fitness is 0.026500635647088752']
# ['At iteration 15 the best fitness is 0.026500635647088752']
# ['At iteration 16 the best fitness is 0.026500635647088752']
# ['At iteration 17 the best fitness is 0.026500635647088752']
# ['At iteration 18 the best fitness is 0.021667429443173125']
# ['At iteration 19 the best fitness is 0.021667429443173125']
# ['At iteration 20 the best fitness is 0.021667429443173125']
# ['At iteration 21 the best fitness is 0.02030714467327737']
# ['At iteration 22 the best fitness is 0.019735062293414672']
# ['At iteration 23 the best fitness is 0.019735062293414672']
# ['At iteration 24 the best fitness is 0.019735062293414672']
# ['At iteration 25 the best fitness is 0.019735062293414672']
# ['At iteration 26 the best fitness is 0.019735062293414672']
# ['At iteration 27 the best fitness is 0.019735062293414672']
# ['At iteration 28 the best fitness is 0.019735062293414672']
# ['At iteration 29 the best fitness is 0.019735062293414672']
#       Selected: 685/3933 (17.4%), Fitness: 0.0197, Time: 812.4s
#       Modality: D=22%, S=16%, Sk=17%, V=17%
#     Test Acc: 88.89%, F1: 88.11%, Features: 685/3933 (17.4%), Model: 1.879MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 92.59%, F1: 90.89%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 22.1s
#     Test Acc: 96.30%, F1: 95.06%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.3s
#     Test Acc: 92.59%, F1: 90.12%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.2s
#     Test Acc: 75.93%, F1: 74.71%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03125069921179765']
# ['At iteration 1 the best fitness is 0.03125069921179765']
# ['At iteration 2 the best fitness is 0.031047292143402027']
# ['At iteration 3 the best fitness is 0.030793033307907492']
# ['At iteration 4 the best fitness is 0.030754894482583315']
# ['At iteration 5 the best fitness is 0.030754894482583315']
# ['At iteration 6 the best fitness is 0.030754894482583315']
# ['At iteration 7 the best fitness is 0.030754894482583315']
# ['At iteration 8 the best fitness is 0.030754894482583315']
# ['At iteration 9 the best fitness is 0.030754894482583315']
# ['At iteration 10 the best fitness is 0.030754894482583315']
# ['At iteration 11 the best fitness is 0.03072946859903386']
# ['At iteration 12 the best fitness is 0.03072946859903386']
# ['At iteration 13 the best fitness is 0.03072946859903386']
# ['At iteration 14 the best fitness is 0.03072946859903386']
# ['At iteration 15 the best fitness is 0.03072946859903386']
# ['At iteration 16 the best fitness is 0.03072946859903386']
# ['At iteration 17 the best fitness is 0.03072946859903386']
# ['At iteration 18 the best fitness is 0.03072946859903386']
# ['At iteration 19 the best fitness is 0.03072946859903386']
# ['At iteration 20 the best fitness is 0.030716755657259134']
# ['At iteration 21 the best fitness is 0.030716755657259134']
# ['At iteration 22 the best fitness is 0.030716755657259134']
# ['At iteration 23 the best fitness is 0.030716755657259134']
# ['At iteration 24 the best fitness is 0.030716755657259134']
# ['At iteration 25 the best fitness is 0.030716755657259134']
# ['At iteration 26 the best fitness is 0.030716755657259134']
# ['At iteration 27 the best fitness is 0.030716755657259134']
# ['At iteration 28 the best fitness is 0.030716755657259134']
# ['At iteration 29 the best fitness is 0.030716755657259134']
#       Selected: 1918/3933 (48.8%), Fitness: 0.0307, Time: 898.3s
#       Modality: D=46%, S=46%, Sk=50%, V=50%
#     Test Acc: 87.04%, F1: 84.11%, Features: 1918/3933 (48.8%), Model: 4.287MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.031034579201627298']
# ['At iteration 10 the best fitness is 0.030805746249682218']
# ['At iteration 20 the best fitness is 0.03042435799644042']
#       Selected: 1907/3933 (48.5%), Fitness: 0.0304, Time: 1789.1s
#       Modality: D=46%, S=50%, Sk=49%, V=47%
#     Test Acc: 89.81%, F1: 88.05%, Features: 1907/3933 (48.5%), Model: 4.266MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.037469616069158385']
# ['At iteration 2 the best fitness is 0.037469616069158385']
# ['At iteration 3 the best fitness is 0.031123569794050388']
# ['At iteration 4 the best fitness is 0.031123569794050388']
# ['At iteration 5 the best fitness is 0.031098143910500933']
# ['At iteration 6 the best fitness is 0.03107271802695148']
# ['At iteration 7 the best fitness is 0.030131960335621707']
# ['At iteration 8 the best fitness is 0.030131960335621707']
# ['At iteration 9 the best fitness is 0.030131960335621707']
# ['At iteration 10 the best fitness is 0.030131960335621707']
# ['At iteration 11 the best fitness is 0.030131960335621707']
# ['At iteration 12 the best fitness is 0.030131960335621707']
# ['At iteration 13 the best fitness is 0.030131960335621707']
# ['At iteration 14 the best fitness is 0.030131960335621707']
# ['At iteration 15 the best fitness is 0.030131960335621707']
# ['At iteration 16 the best fitness is 0.030131960335621707']
# ['At iteration 17 the best fitness is 0.030131960335621707']
# ['At iteration 18 the best fitness is 0.030131960335621707']
# ['At iteration 19 the best fitness is 0.030131960335621707']
# ['At iteration 20 the best fitness is 0.030131960335621707']
# ['At iteration 21 the best fitness is 0.029864988558352446']
# ['At iteration 22 the best fitness is 0.02958530383930846']
# ['At iteration 23 the best fitness is 0.02958530383930846']
# ['At iteration 24 the best fitness is 0.02958530383930846']
# ['At iteration 25 the best fitness is 0.02958530383930846']
# ['At iteration 26 the best fitness is 0.02958530383930846']
# ['At iteration 27 the best fitness is 0.02958530383930846']
# ['At iteration 28 the best fitness is 0.02958530383930846']
# ['At iteration 29 the best fitness is 0.02958530383930846']
# ['At iteration 30 the best fitness is 0.02958530383930846']
#       Selected: 1887/3933 (48.0%), Fitness: 0.0296, Time: 906.9s
#       Modality: D=44%, S=48%, Sk=48%, V=49%
#     Test Acc: 91.67%, F1: 90.44%, Features: 1887/3933 (48.0%), Model: 4.227MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03140325451309437']
# ['At iteration 1 the best fitness is 0.030831172133231673']
# ['At iteration 2 the best fitness is 0.030831172133231673']
# ['At iteration 3 the best fitness is 0.03130155097889656']
# ['At iteration 4 the best fitness is 0.03726620900076276']
# ['At iteration 5 the best fitness is 0.03726620900076276']
# ['At iteration 6 the best fitness is 0.0370500889905924']
# ['At iteration 7 the best fitness is 0.031161708619374565']
# ['At iteration 8 the best fitness is 0.03722807017543857']
# ['At iteration 9 the best fitness is 0.03720264429188912']
# ['At iteration 10 the best fitness is 0.03735519959318584']
# ['At iteration 11 the best fitness is 0.0372407831172133']
# ['At iteration 12 the best fitness is 0.03716450546656494']
# ['At iteration 13 the best fitness is 0.03725349605898803']
# ['At iteration 14 the best fitness is 0.03095830155097894']
# ['At iteration 15 the best fitness is 0.031034579201627298']
# ['At iteration 16 the best fitness is 0.037342486651411114']
# ['At iteration 17 the best fitness is 0.037342486651411114']
# ['At iteration 18 the best fitness is 0.03732977370963639']
# ['At iteration 19 the best fitness is 0.03098372743452839']
# ['At iteration 20 the best fitness is 0.03098372743452839']
# ['At iteration 21 the best fitness is 0.037342486651411114']
# ['At iteration 22 the best fitness is 0.03731706076786166']
# ['At iteration 23 the best fitness is 0.03731706076786166']
# ['At iteration 24 the best fitness is 0.03732977370963639']
# ['At iteration 25 the best fitness is 0.03732977370963639']
# ['At iteration 26 the best fitness is 0.03731706076786166']
# ['At iteration 27 the best fitness is 0.03098372743452839']
# ['At iteration 28 the best fitness is 0.03731706076786166']
# ['At iteration 29 the best fitness is 0.03731706076786166']
#       Selected: 1970/3933 (50.1%), Fitness: 0.0373, Time: 877.5s
#       Modality: D=49%, S=52%, Sk=49%, V=50%
#     Test Acc: 90.74%, F1: 89.01%, Features: 1970/3933 (50.1%), Model: 4.389MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.03156852275616582
# At iteration 2 the best fitness is 0.030856598016781124
# At iteration 3 the best fitness is 0.031161708619374565
# At iteration 4 the best fitness is 0.03126341215357238
# At iteration 5 the best fitness is 0.031161708619374565
# At iteration 6 the best fitness is 0.030716755657259134
# At iteration 7 the best fitness is 0.030894736842105305
# At iteration 8 the best fitness is 0.031034579201627298
# At iteration 9 the best fitness is 0.030869310958555853
# At iteration 10 the best fitness is 0.03069132977370968
# At iteration 11 the best fitness is 0.030971014492753666
# At iteration 12 the best fitness is 0.03061505212306132
# At iteration 13 the best fitness is 0.030589626239511867
# At iteration 14 the best fitness is 0.03076760742435804
# At iteration 15 the best fitness is 0.030716755657259134
# At iteration 16 the best fitness is 0.03092016272565476
# At iteration 17 the best fitness is 0.030513348588863506
# At iteration 18 the best fitness is 0.030754894482583315
# At iteration 19 the best fitness is 0.03061505212306132
# At iteration 20 the best fitness is 0.030665903890160225
# At iteration 21 the best fitness is 0.030754894482583315
# At iteration 22 the best fitness is 0.030640478006610773
# At iteration 23 the best fitness is 0.030742181540808586
# At iteration 24 the best fitness is 0.03095830155097894
# At iteration 25 the best fitness is 0.030665903890160225
# At iteration 26 the best fitness is 0.030640478006610773
# At iteration 27 the best fitness is 0.030640478006610773
# At iteration 28 the best fitness is 0.03061505212306132
# At iteration 29 the best fitness is 0.030411645054665693
# At iteration 30 the best fitness is 0.030640478006610773
#       Selected: 1880/3933 (47.8%), Fitness: 0.0306, Time: 879.2s
#       Modality: D=47%, S=50%, Sk=48%, V=47%
#     Test Acc: 92.59%, F1: 91.97%, Features: 1880/3933 (47.8%), Model: 4.213MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03111085685227566']
# ['At iteration 1 the best fitness is 0.03052606153063823']
# ['At iteration 2 the best fitness is 0.030220950928044794']
# ['At iteration 3 the best fitness is 0.029000508517671032']
# ['At iteration 4 the best fitness is 0.028377574370709428']
# ['At iteration 5 the best fitness is 0.026712178998220232']
# ['At iteration 6 the best fitness is 0.026000254258835537']
# ['At iteration 7 the best fitness is 0.026000254258835537']
# ['At iteration 8 the best fitness is 0.025250190694126665']
# ['At iteration 9 the best fitness is 0.024512840071192518']
# ['At iteration 10 the best fitness is 0.024017035341978174']
# ['At iteration 11 the best fitness is 0.023750063564708917']
# ['At iteration 12 the best fitness is 0.023292397660818753']
# ['At iteration 13 the best fitness is 0.022796592931604416']
# ['At iteration 14 the best fitness is 0.022796592931604416']
# ['At iteration 15 the best fitness is 0.022593185863208787']
# ['At iteration 16 the best fitness is 0.022593185863208787']
# ['At iteration 17 the best fitness is 0.022453343503686794']
# ['At iteration 18 the best fitness is 0.022453343503686794']
# ['At iteration 19 the best fitness is 0.022453343503686794']
# ['At iteration 20 the best fitness is 0.02227536231884062']
# ['At iteration 21 the best fitness is 0.022148232901093357']
# ['At iteration 22 the best fitness is 0.022071955250444995']
# ['At iteration 23 the best fitness is 0.022071955250444995']
# ['At iteration 24 the best fitness is 0.022071955250444995']
# ['At iteration 25 the best fitness is 0.02202110348334609']
# ['At iteration 26 the best fitness is 0.021792270531401006']
# ['At iteration 27 the best fitness is 0.021792270531401006']
# ['At iteration 28 the best fitness is 0.021792270531401006']
# ['At iteration 29 the best fitness is 0.021792270531401006']
#       Selected: 1362/3933 (34.6%), Fitness: 0.0218, Time: 879.2s
#       Modality: D=36%, S=32%, Sk=36%, V=34%
#     Test Acc: 91.67%, F1: 89.95%, Features: 1362/3933 (34.6%), Model: 3.201MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.0314159674548691']
# ['At iteration 1 the best fitness is 0.0314159674548691']
# ['At iteration 2 the best fitness is 0.0314159674548691']
# ['At iteration 3 the best fitness is 0.0314159674548691']
# ['At iteration 4 the best fitness is 0.0314159674548691']
# ['At iteration 5 the best fitness is 0.0314159674548691']
# ['At iteration 6 the best fitness is 0.0314159674548691']
# ['At iteration 7 the best fitness is 0.0314159674548691']
# ['At iteration 8 the best fitness is 0.0314159674548691']
# ['At iteration 9 the best fitness is 0.0314159674548691']
# ['At iteration 10 the best fitness is 0.0314159674548691']
# ['At iteration 11 the best fitness is 0.0314159674548691']
# ['At iteration 12 the best fitness is 0.0314159674548691']
# ['At iteration 13 the best fitness is 0.0314159674548691']
# ['At iteration 14 the best fitness is 0.0314159674548691']
# ['At iteration 15 the best fitness is 0.03128883803712183']
# ['At iteration 16 the best fitness is 0.03128883803712183']
# ['At iteration 17 the best fitness is 0.03128883803712183']
# ['At iteration 18 the best fitness is 0.03128883803712183']
# ['At iteration 19 the best fitness is 0.03128883803712183']
# ['At iteration 20 the best fitness is 0.03128883803712183']
# ['At iteration 21 the best fitness is 0.029979405034324984']
# ['At iteration 22 the best fitness is 0.029979405034324984']
# ['At iteration 23 the best fitness is 0.029979405034324984']
# ['At iteration 24 the best fitness is 0.029979405034324984']
# ['At iteration 25 the best fitness is 0.029979405034324984']
# ['At iteration 26 the best fitness is 0.029953979150775533']
# ['At iteration 27 the best fitness is 0.029953979150775533']
# ['At iteration 28 the best fitness is 0.029953979150775533']
# ['At iteration 29 the best fitness is 0.029712433257055724']
#       Selected: 1860/3933 (47.3%), Fitness: 0.0297, Time: 1185.8s
#       Modality: D=50%, S=47%, Sk=47%, V=47%
#     Test Acc: 88.89%, F1: 87.89%, Features: 1860/3933 (47.3%), Model: 4.174MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.036884820747520954']
# ['At iteration 1 the best fitness is 0.030805746249682218']
# ['At iteration 2 the best fitness is 0.030805746249682218']
# ['At iteration 3 the best fitness is 0.030780320366132766']
# ['At iteration 4 the best fitness is 0.030780320366132766']
# ['At iteration 5 the best fitness is 0.030780320366132766']
# ['At iteration 6 the best fitness is 0.030780320366132766']
# ['At iteration 7 the best fitness is 0.030780320366132766']
# ['At iteration 8 the best fitness is 0.030780320366132766']
# ['At iteration 9 the best fitness is 0.030335367404017332']
# ['At iteration 10 the best fitness is 0.030335367404017332']
# ['At iteration 11 the best fitness is 0.030335367404017332']
# ['At iteration 12 the best fitness is 0.030335367404017332']
# ['At iteration 13 the best fitness is 0.030335367404017332']
# ['At iteration 14 the best fitness is 0.030335367404017332']
# ['At iteration 15 the best fitness is 0.030335367404017332']
# ['At iteration 16 the best fitness is 0.030284515636918426']
# ['At iteration 17 the best fitness is 0.030284515636918426']
# ['At iteration 18 the best fitness is 0.030284515636918426']
# ['At iteration 19 the best fitness is 0.030284515636918426']
# ['At iteration 20 the best fitness is 0.030284515636918426']
# ['At iteration 21 the best fitness is 0.030284515636918426']
# ['At iteration 22 the best fitness is 0.030284515636918426']
# ['At iteration 23 the best fitness is 0.030284515636918426']
# ['At iteration 24 the best fitness is 0.030284515636918426']
# ['At iteration 25 the best fitness is 0.030284515636918426']
# ['At iteration 26 the best fitness is 0.030284515636918426']
# ['At iteration 27 the best fitness is 0.030284515636918426']
# ['At iteration 28 the best fitness is 0.030284515636918426']
# ['At iteration 29 the best fitness is 0.03025908975336897']
#       Selected: 1901/3933 (48.3%), Fitness: 0.0303, Time: 906.0s
#       Modality: D=42%, S=49%, Sk=48%, V=49%
#     Test Acc: 88.89%, F1: 88.39%, Features: 1901/3933 (48.3%), Model: 4.254MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.037151792524790214']
# ['At iteration 2 the best fitness is 0.03057691329773714']
# ['At iteration 3 the best fitness is 0.03057691329773714']
# ['At iteration 4 the best fitness is 0.03057691329773714']
# ['At iteration 5 the best fitness is 0.03057691329773714']
# ['At iteration 6 the best fitness is 0.03057691329773714']
# ['At iteration 7 the best fitness is 0.03057691329773714']
# ['At iteration 8 the best fitness is 0.03057691329773714']
# ['At iteration 9 the best fitness is 0.03057691329773714']
# ['At iteration 10 the best fitness is 0.03057691329773714']
# ['At iteration 11 the best fitness is 0.03057691329773714']
# ['At iteration 12 the best fitness is 0.03057691329773714']
# ['At iteration 13 the best fitness is 0.03057691329773714']
# ['At iteration 14 the best fitness is 0.03057691329773714']
# ['At iteration 15 the best fitness is 0.03057691329773714']
# ['At iteration 16 the best fitness is 0.03057691329773714']
# ['At iteration 17 the best fitness is 0.03057691329773714']
# ['At iteration 18 the best fitness is 0.03057691329773714']
# ['At iteration 19 the best fitness is 0.03057691329773714']
# ['At iteration 20 the best fitness is 0.03057691329773714']
# ['At iteration 21 the best fitness is 0.03057691329773714']
# ['At iteration 22 the best fitness is 0.030551487414187686']
# ['At iteration 23 the best fitness is 0.03044978387998987']
# ['At iteration 24 the best fitness is 0.03044978387998987']
# ['At iteration 25 the best fitness is 0.030322654462242606']
# ['At iteration 26 the best fitness is 0.030220950928044794']
# ['At iteration 27 the best fitness is 0.030220950928044794']
# ['At iteration 28 the best fitness is 0.030220950928044794']
# ['At iteration 29 the best fitness is 0.030220950928044794']
#       Selected: 1916/3933 (48.7%), Fitness: 0.0302, Time: 856.9s
#       Modality: D=50%, S=50%, Sk=47%, V=50%
#     Test Acc: 88.89%, F1: 87.99%, Features: 1916/3933 (48.7%), Model: 4.283MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.037088227815916586']
# ['At iteration 2 the best fitness is 0.03144139333841855']
# ['At iteration 3 the best fitness is 0.031047292143402027']
# ['At iteration 4 the best fitness is 0.031047292143402027']
# ['At iteration 5 the best fitness is 0.031047292143402027']
# ['At iteration 6 the best fitness is 0.031047292143402027']
# ['At iteration 7 the best fitness is 0.031047292143402027']
# ['At iteration 8 the best fitness is 0.030411645054665693']
# ['At iteration 9 the best fitness is 0.030411645054665693']
# ['At iteration 10 the best fitness is 0.030411645054665693']
# ['At iteration 11 the best fitness is 0.030411645054665693']
# ...
# ['At iteration 17 the best fitness is 0.020915077548944866']
# ['At iteration 18 the best fitness is 0.020915077548944866']
# ['At iteration 19 the best fitness is 0.020915077548944866']
# ['At iteration 20 the best fitness is 0.020915077548944866']
# ['At iteration 21 the best fitness is 0.020915077548944866']
# ['At iteration 22 the best fitness is 0.020915077548944866']
# ['At iteration 23 the best fitness is 0.019961606915840365']
# ['At iteration 24 the best fitness is 0.019287821001779854']
# ['At iteration 25 the best fitness is 0.019287821001779854']
# ['At iteration 26 the best fitness is 0.019287821001779854']
# ['At iteration 27 the best fitness is 0.019173404525807316']
# ['At iteration 28 the best fitness is 0.019173404525807316']
# ['At iteration 29 the best fitness is 0.019173404525807316']
#       Selected: 1068/3933 (27.2%), Fitness: 0.0192, Time: 745.6s
#       Modality: D=27%, S=26%, Sk=28%, V=26%
#     Test Acc: 96.26%, F1: 96.04%, Features: 1068/3933 (27.2%), Model: 2.627MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024230867022629037']
# ['At iteration 1 the best fitness is 0.024230867022629037']
# ['At iteration 2 the best fitness is 0.024230867022629037']
# ['At iteration 3 the best fitness is 0.024230867022629037']
# ['At iteration 4 the best fitness is 0.024230867022629037']
# ['At iteration 5 the best fitness is 0.024230867022629037']
# ['At iteration 6 the best fitness is 0.024230867022629037']
# ['At iteration 7 the best fitness is 0.024230867022629037']
# ['At iteration 8 the best fitness is 0.024230867022629037']
# ['At iteration 9 the best fitness is 0.024230867022629037']
# ['At iteration 10 the best fitness is 0.024230867022629037']
# ['At iteration 11 the best fitness is 0.024014747012458686']
# ['At iteration 12 the best fitness is 0.024014747012458686']
# ['At iteration 13 the best fitness is 0.024014747012458686']
# ['At iteration 14 the best fitness is 0.024014747012458686']
# ['At iteration 15 the best fitness is 0.024014747012458686']
# ['At iteration 16 the best fitness is 0.023900330536486145']
# ['At iteration 17 the best fitness is 0.023900330536486145']
# ['At iteration 18 the best fitness is 0.023900330536486145']
# ['At iteration 19 the best fitness is 0.023900330536486145']
# ['At iteration 20 the best fitness is 0.023900330536486145']
# ['At iteration 21 the best fitness is 0.023900330536486145']
# ['At iteration 22 the best fitness is 0.023900330536486145']
# ['At iteration 23 the best fitness is 0.023900330536486145']
# ['At iteration 24 the best fitness is 0.023900330536486145']
# ['At iteration 25 the best fitness is 0.023900330536486145']
# ['At iteration 26 the best fitness is 0.023900330536486145']
# ['At iteration 27 the best fitness is 0.023900330536486145']
# ['At iteration 28 the best fitness is 0.02368421052631579']
# ['At iteration 29 the best fitness is 0.02368421052631579']
#       Selected: 1925/3933 (48.9%), Fitness: 0.0237, Time: 634.8s
#       Modality: D=54%, S=49%, Sk=49%, V=49%
#     Test Acc: 91.59%, F1: 91.25%, Features: 1925/3933 (48.9%), Model: 4.301MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.03107271802695148']
# ['At iteration 2 the best fitness is 0.03107271802695148']
# ['At iteration 3 the best fitness is 0.03107271802695148']
# ['At iteration 4 the best fitness is 0.025019069412662093']
# ['At iteration 5 the best fitness is 0.025019069412662093']
# ['At iteration 6 the best fitness is 0.025019069412662093']
# ['At iteration 7 the best fitness is 0.025019069412662093']
# ['At iteration 8 the best fitness is 0.025019069412662093']
# ['At iteration 9 the best fitness is 0.025019069412662093']
# ['At iteration 10 the best fitness is 0.025019069412662093']
# ['At iteration 11 the best fitness is 0.025019069412662093']
# ['At iteration 12 the best fitness is 0.025019069412662093']
# ['At iteration 13 the best fitness is 0.025019069412662093']
# ['At iteration 14 the best fitness is 0.025019069412662093']
# ['At iteration 15 the best fitness is 0.025019069412662093']
# ['At iteration 16 the best fitness is 0.025019069412662093']
# ['At iteration 17 the best fitness is 0.024853801169590642']
# ['At iteration 18 the best fitness is 0.024853801169590642']
# ['At iteration 19 the best fitness is 0.024853801169590642']
# ['At iteration 20 the best fitness is 0.024853801169590642']
# ['At iteration 21 the best fitness is 0.024853801169590642']
# ['At iteration 22 the best fitness is 0.024853801169590642']
# ['At iteration 23 the best fitness is 0.024853801169590642']
# ['At iteration 24 the best fitness is 0.024853801169590642']
# ['At iteration 25 the best fitness is 0.024853801169590642']
# ['At iteration 26 the best fitness is 0.024853801169590642']
# ['At iteration 27 the best fitness is 0.024853801169590642']
# ['At iteration 28 the best fitness is 0.024790236460717013']
# ['At iteration 29 the best fitness is 0.024663107042969742']
#       Selected: 1938/3933 (49.3%), Fitness: 0.0247, Time: 605.0s
#       Modality: D=50%, S=48%, Sk=50%, V=49%
#     Test Acc: 90.65%, F1: 90.36%, Features: 1938/3933 (49.3%), Model: 4.326MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.025031782354436816']
# ['At iteration 2 the best fitness is 0.025031782354436816']
# ['At iteration 3 the best fitness is 0.024879227053140097']
# ['At iteration 4 the best fitness is 0.024879227053140097']
# ['At iteration 5 the best fitness is 0.024879227053140097']
# ['At iteration 6 the best fitness is 0.024879227053140097']
# ['At iteration 7 the best fitness is 0.024879227053140097']
# ['At iteration 8 the best fitness is 0.024879227053140097']
# ['At iteration 9 the best fitness is 0.024879227053140097']
# ['At iteration 10 the best fitness is 0.024879227053140097']
# ['At iteration 11 the best fitness is 0.024879227053140097']
# ['At iteration 12 the best fitness is 0.024853801169590642']
# ['At iteration 13 the best fitness is 0.024853801169590642']
# ['At iteration 14 the best fitness is 0.024726671751843378']
# ['At iteration 15 the best fitness is 0.024663107042969742']
# ['At iteration 16 the best fitness is 0.024663107042969742']
# ['At iteration 17 the best fitness is 0.02461225527587084']
# ['At iteration 18 the best fitness is 0.02448512585812357']
# ['At iteration 19 the best fitness is 0.02448512585812357']
# ['At iteration 20 the best fitness is 0.02448512585812357']
# ['At iteration 21 the best fitness is 0.02448512585812357']
# ['At iteration 22 the best fitness is 0.02448512585812357']
# ['At iteration 23 the best fitness is 0.02448512585812357']
# ['At iteration 24 the best fitness is 0.02448512585812357']
# ['At iteration 25 the best fitness is 0.02433257055682685']
# ['At iteration 26 the best fitness is 0.02433257055682685']
# ['At iteration 27 the best fitness is 0.02433257055682685']
# ['At iteration 28 the best fitness is 0.02433257055682685']
# ['At iteration 29 the best fitness is 0.02433257055682685']
# ['At iteration 30 the best fitness is 0.02433257055682685']
#       Selected: 1985/3933 (50.5%), Fitness: 0.0243, Time: 621.0s
#       Modality: D=49%, S=51%, Sk=51%, V=50%
#     Test Acc: 98.13%, F1: 98.12%, Features: 1985/3933 (50.5%), Model: 4.418MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02467581998474447']
# ['At iteration 2 the best fitness is 0.024586829392321385']
# ['At iteration 3 the best fitness is 0.024586829392321385']
# ['At iteration 4 the best fitness is 0.02453597762522248']
# ['At iteration 5 the best fitness is 0.02452326468344775']
# ['At iteration 6 the best fitness is 0.024269005847953218']
# ['At iteration 7 the best fitness is 0.024192728197304857']
# ['At iteration 8 the best fitness is 0.023900330536486145']
# ['At iteration 9 the best fitness is 0.023900330536486145']
# ['At iteration 10 the best fitness is 0.023900330536486145']
# ['At iteration 11 the best fitness is 0.023874904652936693']
# ['At iteration 12 the best fitness is 0.023874904652936693']
# ['At iteration 13 the best fitness is 0.023785914060513603']
# ['At iteration 14 the best fitness is 0.023518942283244346']
# ['At iteration 15 the best fitness is 0.02341723874904653']
# ['At iteration 16 the best fitness is 0.023315535214848717']
# ['At iteration 17 the best fitness is 0.023315535214848717']
# ['At iteration 18 the best fitness is 0.023315535214848717']
# ['At iteration 19 the best fitness is 0.023315535214848717']
# ['At iteration 20 the best fitness is 0.023315535214848717']
# ['At iteration 21 the best fitness is 0.023315535214848717']
# ['At iteration 22 the best fitness is 0.023315535214848717']
# ['At iteration 23 the best fitness is 0.023315535214848717']
# ['At iteration 24 the best fitness is 0.023315535214848717']
# ['At iteration 25 the best fitness is 0.023315535214848717']
# ['At iteration 26 the best fitness is 0.023315535214848717']
# ['At iteration 27 the best fitness is 0.023315535214848717']
# ['At iteration 28 the best fitness is 0.023315535214848717']
# ['At iteration 29 the best fitness is 0.023315535214848717']
# ['At iteration 30 the best fitness is 0.023315535214848717']
#       Selected: 1869/3933 (47.5%), Fitness: 0.0233, Time: 616.6s
#       Modality: D=51%, S=48%, Sk=46%, V=48%
#     Test Acc: 95.33%, F1: 94.97%, Features: 1869/3933 (47.5%), Model: 4.192MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03042435799644042']
# ['At iteration 1 the best fitness is 0.029140350877193025']
# ['At iteration 2 the best fitness is 0.021268751589117722']
# ['At iteration 3 the best fitness is 0.01723874904652937']
# ['At iteration 4 the best fitness is 0.01723874904652937']
# ['At iteration 5 the best fitness is 0.015992880752606155']
# ['At iteration 6 the best fitness is 0.014454614797864227']
# ['At iteration 7 the best fitness is 0.014454614797864227']
# ['At iteration 8 the best fitness is 0.01306890414441902']
# ['At iteration 9 the best fitness is 0.01306890414441902']
# ['At iteration 10 the best fitness is 0.011301805237732013']
# ['At iteration 11 the best fitness is 0.011301805237732013']
# ['At iteration 12 the best fitness is 0.011301805237732013']
# ['At iteration 13 the best fitness is 0.011301805237732013']
# ['At iteration 14 the best fitness is 0.011301805237732013']
# ['At iteration 15 the best fitness is 0.011301805237732013']
# ['At iteration 16 the best fitness is 0.011301805237732013']
# ['At iteration 17 the best fitness is 0.011301805237732013']
# ['At iteration 18 the best fitness is 0.011301805237732013']
# ['At iteration 19 the best fitness is 0.00893719806763285']
# ['At iteration 20 the best fitness is 0.00893719806763285']
# ['At iteration 21 the best fitness is 0.008199847444698703']
# ['At iteration 22 the best fitness is 0.008199847444698703']
# ['At iteration 23 the best fitness is 0.008199847444698703']
# ['At iteration 24 the best fitness is 0.008199847444698703']
# ['At iteration 25 the best fitness is 0.008199847444698703']
# ['At iteration 26 the best fitness is 0.008199847444698703']
# ['At iteration 27 the best fitness is 0.008123569794050343']
# ['At iteration 28 the best fitness is 0.00798372743452835']
# ['At iteration 29 the best fitness is 0.00798372743452835']
#       Selected: 659/3933 (16.8%), Fitness: 0.0080, Time: 585.3s
#       Modality: D=19%, S=16%, Sk=16%, V=17%
#     Test Acc: 85.05%, F1: 82.18%, Features: 659/3933 (16.8%), Model: 1.828MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024205441139079586']
# ['At iteration 2 the best fitness is 0.024205441139079586']
# ['At iteration 3 the best fitness is 0.024205441139079586']
# ['At iteration 4 the best fitness is 0.024205441139079586']
# ['At iteration 5 the best fitness is 0.024205441139079586']
# ['At iteration 6 the best fitness is 0.024192728197304857']
# ['At iteration 7 the best fitness is 0.024192728197304857']
# ['At iteration 8 the best fitness is 0.024192728197304857']
# ['At iteration 9 the best fitness is 0.02407831172133232']
# ['At iteration 10 the best fitness is 0.02407831172133232']
# ['At iteration 11 the best fitness is 0.02376048817696415']
# ['At iteration 12 the best fitness is 0.02376048817696415']
# ['At iteration 13 the best fitness is 0.02376048817696415']
# ['At iteration 14 the best fitness is 0.02376048817696415']
# ['At iteration 15 the best fitness is 0.02369692346809052']
# ['At iteration 16 the best fitness is 0.023671497584541065']
# ['At iteration 17 the best fitness is 0.02364607170099161']
# ['At iteration 18 the best fitness is 0.023620645817442158']
# ['At iteration 19 the best fitness is 0.023620645817442158']
# ['At iteration 20 the best fitness is 0.02356979405034325']
# ['At iteration 21 the best fitness is 0.02356979405034325']
# ['At iteration 22 the best fitness is 0.02356979405034325']
# ['At iteration 23 the best fitness is 0.02356979405034325']
# ['At iteration 24 the best fitness is 0.02356979405034325']
# ['At iteration 25 the best fitness is 0.02356979405034325']
# ['At iteration 26 the best fitness is 0.02356979405034325']
# ['At iteration 27 the best fitness is 0.02356979405034325']
# ['At iteration 28 the best fitness is 0.02356979405034325']
# ['At iteration 29 the best fitness is 0.02356979405034325']
#       Selected: 1880/3933 (47.8%), Fitness: 0.0236, Time: 1539.4s
#       Modality: D=50%, S=50%, Sk=47%, V=47%
#     Test Acc: 97.20%, F1: 97.08%, Features: 1880/3933 (47.8%), Model: 4.213MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024968217645563187']
# ['At iteration 1 the best fitness is 0.024968217645563187']
# ['At iteration 2 the best fitness is 0.0182557843885075']
# ['At iteration 3 the best fitness is 0.0182557843885075']
# ['At iteration 4 the best fitness is 0.0182557843885075']
# ['At iteration 5 the best fitness is 0.016643529112636706']
# ['At iteration 6 the best fitness is 0.015344520722095092']
# ['At iteration 7 the best fitness is 0.015344520722095092']
# ['At iteration 8 the best fitness is 0.015344520722095092']
# ['At iteration 9 the best fitness is 0.015344520722095092']
# ['At iteration 10 the best fitness is 0.01063030765319099']
# ['At iteration 11 the best fitness is 0.01063030765319099']
# ['At iteration 12 the best fitness is 0.01063030765319099']
# ['At iteration 13 the best fitness is 0.01063030765319099']
# ['At iteration 14 the best fitness is 0.01063030765319099']
# ['At iteration 15 the best fitness is 0.010452326468344816']
# ['At iteration 16 the best fitness is 0.010452326468344816']
# ['At iteration 17 the best fitness is 0.010452326468344816']
# ['At iteration 18 the best fitness is 0.010452326468344816']
# ['At iteration 19 the best fitness is 0.010452326468344816']
# ['At iteration 20 the best fitness is 0.010452326468344816']
# ['At iteration 21 the best fitness is 0.010452326468344816']
# ['At iteration 22 the best fitness is 0.010452326468344816']
# ['At iteration 23 the best fitness is 0.010452326468344816']
# ['At iteration 24 the best fitness is 0.010452326468344816']
# ['At iteration 25 the best fitness is 0.010388761759471182']
# ['At iteration 26 the best fitness is 0.010388761759471182']
# ['At iteration 27 the best fitness is 0.010388761759471182']
# ['At iteration 28 the best fitness is 0.010388761759471182']
# ['At iteration 29 the best fitness is 0.010388761759471182']
#       Selected: 410/3933 (10.4%), Fitness: 0.0104, Time: 593.0s
#       Modality: D=10%, S=12%, Sk=9%, V=11%
#     Test Acc: 93.46%, F1: 92.95%, Features: 410/3933 (10.4%), Model: 1.342MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_new_10_noise/all_results_per_fold.csv
# Shape: (144, 28)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            94.4444           98.6667       94.1681          94.1681              94.8148           94.4444               3933            3933               100.0000       0.0000         15.7632         15.7632       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 1      baseline     2            92.5926           99.3333       90.8888          90.8888              92.1164           92.5926               3933            3933               100.0000       0.0000         15.1437         15.1437       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 2      baseline     3            88.8889           98.0000       88.7713          88.7713              93.8272           88.8889               3933            3933               100.0000       0.0000         14.5433         14.5434       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 3      baseline     4            89.8148           99.3333       89.6796          89.6796              93.8889           89.8148               3933            3933               100.0000       0.0000         13.1592         13.1592       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 4      baseline     5            91.6667           98.6667       90.9024          90.9024              93.6420           91.6667               3933            3933               100.0000       0.0000         14.4754         14.4754       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 5      baseline     6            95.3271          100.0000       95.2969          95.2529              96.2963           95.3704               3933            3933               100.0000       0.0000         15.8341         15.8341       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 6      baseline     7            95.3271           99.3333       95.2509          95.2065              97.1781           95.3704               3933            3933               100.0000       0.0000         12.7026         12.7026       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 7      baseline     8            95.3271           99.3333       95.4615          95.4191              96.7901           95.3704               3933            3933               100.0000       0.0000         12.4627         12.4627       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 8   mutual_info     1            96.2963           99.3333       95.8271          95.8271              97.6720           96.2963               1966            3933                49.9873      22.4766         10.9933         33.4700       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              12.9630              28               70.5521              460                 33.7994                556              64.9296             922
# 9   mutual_info     2            96.2963           99.3333       95.0617          95.0617              94.4444           96.2963               1966            3933                49.9873      22.1154         12.2008         34.3163       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              13.4259              29               70.8589              462                 34.8328                573              63.5211             902
# 10  mutual_info     3            91.6667          100.0000       90.6194          90.6194              94.8501           91.6667               1966            3933                49.9873      22.1131         12.1828         34.2961       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              13.8889              30               71.0123              463                 33.6170                553              64.7887             920
# 11  mutual_info     4            93.5185          100.0000       93.1022          93.1022              95.5115           93.5185               1966            3933                49.9873      22.1024         12.0149         34.1174       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              12.9630              28               69.9387              456                 35.1368                578              63.6620             904
# 12  mutual_info     5            94.4444           99.3333       92.9934          92.9934              92.4868           94.4444               1966            3933                49.9873      22.3696         12.6813         35.0510       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              13.4259              29               70.3988              459                 34.9544                575              63.5915             903
# 13  mutual_info     6            92.5234          100.0000       92.1576          92.0843              95.4321           92.5926               1966            3933                49.9873      22.1879         12.9657         35.1537       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              13.8889              30               73.9264              482                 33.7386                555              63.3099             899
# 14  mutual_info     7            94.3925           99.3333       93.7096          93.6508              96.0494           94.4444               1966            3933                49.9873      22.2103          9.6442         31.8546       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              14.3519              31               71.7791              468                 34.5897                569              63.2394             898
# 15  mutual_info     8            95.3271          100.0000       94.6502          94.9740              97.1429           95.3704               1966            3933                49.9873      21.9152          9.4132         31.3286       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              18.0556              39               71.9325              469                 34.4073                566              62.8169             892
# 16          rfe     1            99.0741           99.3333       99.0594          99.0594              99.2593           99.0741               1966            3933                49.9873       4.2608         11.7595         16.0206       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              90.2778             195               76.3804              498                 26.9909                444              58.3803             829
# 17          rfe     2            92.5926           99.3333       90.1235          90.1235              88.8889           92.5926               1966            3933                49.9873       4.2776         13.7761         18.0539       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727             100.0000             216               75.3067              491                 21.7629                358              63.4507             901
# 18          rfe     3            88.8889          100.0000       88.1375          88.1375              93.9683           88.8889               1966            3933                49.9873       4.2340         12.1571         16.3914       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              83.7963             181               78.0675              509                 25.1064                413              60.7746             863
# 19          rfe     4            91.6667           99.3333       91.3709          91.3709              94.7942           91.6667               1966            3933                49.9873       4.2573         12.5306         16.7882       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              86.1111             186               79.1411              516                 27.4164                451              57.2535             813

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              92.92              2.60              92.55              2.78                 3933.00                      100.00              0.00                14.26                14.26          2154011.0                  8.22                        0.00               67.05
# mutual_info              94.31              1.68              93.52              1.68                 1966.00                       49.99             22.19                11.51                33.70          1146907.0                  4.38                       50.01               44.47
#         rfe              92.45              4.03              91.71              4.29                 1966.00                       49.99              4.23                12.14                16.37          1146907.0                  4.38                       50.01               44.47
#       lasso              72.51             10.27              70.11             11.18                 1966.00                       49.99              1.26                11.01                12.27          1146907.0                  4.38                       50.01               44.47
#    meta_BAT              90.95              2.90              89.61              3.85                 1917.62                       48.76            829.18                11.95               841.13          1122139.0                  4.29                       51.24               44.47
#     meta_CS              91.30              4.71              90.57              5.04                 1938.75                       49.29           1654.69                11.95              1666.64          1132955.0                  4.33                       50.71               44.48
#     meta_DE              92.81              2.68              91.96              3.04                 1907.38                       48.50            839.01                11.94               850.96          1116891.0                  4.27                       51.50               44.47
#    meta_FFA              93.61              2.46              93.07              2.95                 1954.88                       49.70            810.37                12.00               822.37          1141211.0                  4.36                       50.30               44.48
#     meta_GA              91.07              4.24              90.54              4.80                 1924.75                       48.94            813.92                11.95               825.87          1125787.0                  4.30                       51.06               44.47
#    meta_GWO              90.13              3.60              88.96              3.89                 1381.25                       35.12            819.73                11.83               831.56           847515.0                  3.24                       64.88               36.95
#    meta_HHO              89.44              3.46              88.60              3.77                 1057.25                       26.88           1091.58                11.00              1102.58           681627.0                  2.61                       73.12               33.35
#   meta_JAYA              91.29              2.15              90.52              2.54                 1919.62                       48.81            806.35                11.67               818.02          1123163.0                  4.29                       51.19               44.47
#    meta_MFO              91.52              2.35              90.94              2.54                 1945.25                       49.46            762.62                11.66               774.28          1136283.0                  4.34                       50.54               44.51
#    meta_MVO              92.57              3.09              91.65              3.58                 1922.50                       48.88            779.57                11.53               791.11          1124635.0                  4.30                       51.12               44.35
#    meta_PSO              92.46              3.36              91.77              3.94                 1897.25                       48.24            782.52                11.59               794.11          1111707.0                  4.25                       51.76               44.47
#    meta_SCA              87.00              5.18              85.51              6.08                  717.38                       18.24            745.88                10.61               756.49           507611.0                  1.94                       81.76               29.29
#    meta_SSA              91.18              3.67              90.09              4.15                 1934.12                       49.18           1950.49                11.44              1961.93          1130587.0                  4.32                       50.82               44.48
#    meta_WOA              88.05              5.72              87.19              6.19                  837.12                       21.28            736.52                11.02               747.54           568923.0                  2.18                       78.72               30.96

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 94.31% vs Baseline: 92.92%
#   Paired t-test: t=1.6445, p=0.1441
#   Wilcoxon test: W=6.0000, p=0.2188
#   -> better, Not significant
#
# RFE vs BASELINE:
#   Method: 92.45% vs Baseline: 92.92%
#   Paired t-test: t=-0.3251, p=0.7546
#   Wilcoxon test: W=10.0000, p=1.0000
#   -> worse, Not significant
#
# LASSO vs BASELINE:
#   Method: 72.51% vs Baseline: 92.92%
#   Paired t-test: t=-7.0890, p=0.0002
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 90.95% vs Baseline: 92.92%
#   Paired t-test: t=-2.5507, p=0.0381
#   Wilcoxon test: W=1.0000, p=0.0625
#   -> worse, Significant
#
# META_CS vs BASELINE:
#   Method: 91.30% vs Baseline: 92.92%
#   Paired t-test: t=-1.4694, p=0.1852
#   Wilcoxon test: W=8.5000, p=0.2031
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 92.81% vs Baseline: 92.92%
#   Paired t-test: t=-0.2170, p=0.8344
#   Wilcoxon test: W=15.5000, p=0.7656
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 93.61% vs Baseline: 92.92%
#   Paired t-test: t=0.5937, p=0.5714
#   Wilcoxon test: W=10.0000, p=0.5781
#   -> better, Not significant
#
# META_GA vs BASELINE:
#   Method: 91.07% vs Baseline: 92.92%
#   Paired t-test: t=-2.3065, p=0.0545
#   Wilcoxon test: W=4.0000, p=0.1094
#   -> worse, Not significant
#
# META_GWO vs BASELINE:
#   Method: 90.13% vs Baseline: 92.92%
#   Paired t-test: t=-2.4784, p=0.0423
#   Wilcoxon test: W=3.0000, p=0.0391
#   -> worse, Significant
#
# META_HHO vs BASELINE:
#   Method: 89.44% vs Baseline: 92.92%
#   Paired t-test: t=-2.9572, p=0.0212
#   Wilcoxon test: W=1.0000, p=0.0312
#   -> worse, Significant
#
# META_JAYA vs BASELINE:
#   Method: 91.29% vs Baseline: 92.92%
#   Paired t-test: t=-1.7288, p=0.1275
#   Wilcoxon test: W=3.0000, p=0.1562
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 91.52% vs Baseline: 92.92%
#   Paired t-test: t=-1.1901, p=0.2728
#   Wilcoxon test: W=10.0000, p=0.3125
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 92.57% vs Baseline: 92.92%
#   Paired t-test: t=-0.4167, p=0.6894
#   Wilcoxon test: W=11.5000, p=0.7344
#   -> worse, Not significant
#
# META_PSO vs BASELINE:
#   Method: 92.46% vs Baseline: 92.92%
#   Paired t-test: t=-0.7614, p=0.4713
#   Wilcoxon test: W=7.5000, p=0.6250
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 87.00% vs Baseline: 92.92%
#   Paired t-test: t=-3.4687, p=0.0104
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_SSA vs BASELINE:
#   Method: 91.18% vs Baseline: 92.92%
#   Paired t-test: t=-1.9258, p=0.0955
#   Wilcoxon test: W=8.0000, p=0.1797
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 88.05% vs Baseline: 92.92%
#   Paired t-test: t=-3.2213, p=0.0146
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_new_10_noise
#
# Per-method folders:
#   results_new_10_noise/baseline/ (16 files)
#   results_new_10_noise/mutual_info/ (16 files)
#   results_new_10_noise/rfe/ (16 files)
#   results_new_10_noise/lasso/ (16 files)
#   results_new_10_noise/meta_BAT/ (16 files)
#   results_new_10_noise/meta_CS/ (16 files)
#   results_new_10_noise/meta_DE/ (16 files)
#   results_new_10_noise/meta_FFA/ (16 files)
#   results_new_10_noise/meta_GA/ (16 files)
#   results_new_10_noise/meta_GWO/ (16 files)
#   results_new_10_noise/meta_HHO/ (16 files)
#   results_new_10_noise/meta_JAYA/ (16 files)
#   results_new_10_noise/meta_MFO/ (16 files)
#   results_new_10_noise/meta_MVO/ (16 files)
#   results_new_10_noise/meta_PSO/ (16 files)
#   results_new_10_noise/meta_SCA/ (16 files)
#   results_new_10_noise/meta_SSA/ (16 files)
#   results_new_10_noise/meta_WOA/ (16 files)
#
# Plots directory: results_new_10_noise/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   mutual_info         : 94.31% ± 1.68% (Features: 50.0%)
#   meta_FFA            : 93.61% ± 2.46% (Features: 49.7%)
#   baseline            : 92.92% ± 2.60% (Features: 100.0%)
#   meta_DE             : 92.81% ± 2.68% (Features: 48.5%)
#   meta_MVO            : 92.57% ± 3.09% (Features: 48.9%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_MVO
#     Test Accuracy:      96.30%
#     Feature Retention:  48.97% (1926/3933)
#     Modality Retention: depth=48.1%, sensor=49.5%, skeleton=49.1%, video=48.7%
#
#   Fold 2: Best = meta_GA
#     Test Accuracy:      92.59%
#     Feature Retention:  47.80% (1880/3933)
#     Modality Retention: depth=47.2%, sensor=49.5%, skeleton=48.3%, video=46.5%
#
#   Fold 3: Best = meta_FFA
#     Test Accuracy:      93.52%
#     Feature Retention:  49.91% (1963/3933)
#     Modality Retention: depth=48.1%, sensor=50.3%, skeleton=49.1%, video=51.0%
#
#   Fold 4: Best = meta_FFA
#     Test Accuracy:      92.59%
#     Feature Retention:  49.68% (1954/3933)
#     Modality Retention: depth=38.9%, sensor=51.4%, skeleton=50.9%, video=49.1%
#
#   Fold 5: Best = meta_FFA
#     Test Accuracy:      95.37%
#     Feature Retention:  48.56% (1910/3933)
#     Modality Retention: depth=46.3%, sensor=52.8%, skeleton=48.0%, video=47.6%
#
#   Fold 6: Best = meta_JAYA
#     Test Accuracy:      95.33%
#     Feature Retention:  48.51% (1908/3933)
#     Modality Retention: depth=51.4%, sensor=51.1%, skeleton=48.1%, video=47.4%
#
#   Fold 7: Best = meta_PSO
#     Test Accuracy:      97.20%
#     Feature Retention:  48.49% (1907/3933)
#     Modality Retention: depth=47.2%, sensor=49.8%, skeleton=48.3%, video=48.2%
#
#   Fold 8: Best = meta_FFA
#     Test Accuracy:      98.13%
#     Feature Retention:  50.01% (1967/3933)
#     Modality Retention: depth=54.2%, sensor=50.6%, skeleton=49.1%, video=50.2%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     95.13% ± 2.08%
#   Average Feature Retention: 48.99% ± 0.80%
#
#   Average Modality-wise Feature Retention:
#          depth: 47.69% ± 4.41%
#         sensor: 50.63% ± 1.10%
#       skeleton: 48.85% ± 0.96%
#          video: 48.60% ± 1.48%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)  video Retention (%)
#     1           meta_MVO              96.30                  48.97                48.15                 49.54                   49.06                48.73
#     2            meta_GA              92.59                  47.80                47.22                 49.54                   48.27                46.55
#     3           meta_FFA              93.52                  49.91                48.15                 50.31                   49.06                50.99
#     4           meta_FFA              92.59                  49.68                38.89                 51.38                   50.94                49.08
#     5           meta_FFA              95.37                  48.56                46.30                 52.76                   48.02                47.61
#     6          meta_JAYA              95.33                  48.51                51.39                 51.07                   48.09                47.39
#     7           meta_PSO              97.20                  48.49                47.22                 49.85                   48.33                48.24
#     8           meta_FFA              98.13                  50.01                54.17                 50.61                   49.06                50.21
#
# Saved to: results_new_10_noise/best_metaheuristic_per_fold.csv
