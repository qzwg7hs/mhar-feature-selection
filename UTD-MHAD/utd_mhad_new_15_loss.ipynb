# %% [markdown]
# # UTD-MHAD: Comprehensive Per-Fold Feature Selection Comparison (25% Random Zeroing)
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# All results are saved **per fold** (no averaging) inside `results_per_fold/`.
# Comprehensive plots and CSVs are saved inside `results_per_fold/plots/`.
#
#
# > **Modification:** This notebook randomly zeros out 10% of all data elements before any processing.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce RTX 4090

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.9.1+cu128
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features_new_15_loss")

# Master output directory
RESULTS_ROOT = Path("results_new_15_loss")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 8  # LOSO
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 8
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "subjects.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")
# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
'depth': first_sample['depth_feat'].shape[0],
'sensor': first_sample['sensor_feat'].shape[0],
'skeleton': first_sample['skeleton_feat'].shape[0],
'video': first_sample['video_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")
# Out:
# Loaded 861 samples
# Number of classes: 27
# Number of subjects: 8
#
# Feature dimensions:
#   depth: 216
#   sensor: 652
#   skeleton: 1645
#   video: 1420
#   TOTAL: 3933

# %% [markdown]
# ## Neural Network Model (Same as Original)

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['depth_feat'],
            sample['sensor_feat'],
            sample['skeleton_feat'],
            sample['video_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    model.train()
    for epoch in range(num_epochs):
        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        val_acc = accuracy_score(val_true, val_preds)
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
        test_acc = accuracy_score(test_true, test_preds)
    
    return val_acc, test_acc

def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)
    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        # Test
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Feature Selection Methods\n### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc

# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, TOTAL_FEATURES, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    # binary_mask = solution.bestIndividual > 0.5
    binary_mask = np.random.rand(TOTAL_FEATURES) < s_transfer(solution.bestIndividual)
    modality_ret = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality: D={modality_ret['depth']['percentage']:.0f}%, "
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, "
          f"V={modality_ret['video']['percentage']:.0f}%")
    
    return results

print("All EvoloPy metaheuristic runners defined")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")
    
    start_time = time.time()
    
    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    # Select top k features (target percentage)
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run RFE feature selection"""
    print("    Running RFE...")
    
    start_time = time.time()
    
    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    # Select top k features
    k = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    
    execution_time = time.time() - start_time
    
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    target_count = int(TOTAL_FEATURES * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    modality_retention = calculate_modality_retention(binary_mask, FEATURE_DIMS)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds, saving comprehensive per-fold results.
    Each fold is treated as an independent dataset version (no averaging).
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print("="*80)
    
    # Prepare unified features
    X_unified = prepare_unified_features(X_feat)
    num_classes = len(np.unique(y))
    
    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}
    
    # LOSO cross-validation
    gkf = GroupKFold(n_splits=N_FOLDS)
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(X_unified, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")
        
        # Split data
        X_train_val = X_unified[train_val_idx]
        y_train_val = y[train_val_idx]
        X_test = X_unified[test_idx]
        y_test = y[test_idx]
        
        # Further split train_val into train and val
        n_val = len(train_val_idx) // 5
        val_indices = np.random.choice(len(train_val_idx), n_val, replace=False)
        train_indices = np.array([i for i in range(len(train_val_idx)) if i not in val_indices])
        
        X_train = X_train_val[train_indices]
        y_train = y_train_val[train_indices]
        X_val = X_train_val[val_indices]
        y_val = y_train_val[val_indices]
        
        print(f"  Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
        
        # Normalize
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)
        
        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")
            
            fs_start_time = time.time()
            
            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(TOTAL_FEATURES, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': TOTAL_FEATURES,
                    'num_total': TOTAL_FEATURES,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func, X_train, y_train, X_val, y_val, num_classes)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")
            
            fs_time = time.time() - fs_start_time
            
            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]
            
            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            # Build and train final model
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention', calculate_modality_retention(feature_mask, FEATURE_DIMS))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0} for m, d in FEATURE_DIMS.items()}
            
            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(X_train),
                'num_val': len(X_val),
                'num_test': len(X_test),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': TOTAL_FEATURES,
                'feature_retention_pct': float(np.sum(feature_mask) / TOTAL_FEATURES * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            
            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{TOTAL_FEATURES} "
                  f"({np.sum(feature_mask)/TOTAL_FEATURES*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")
            
            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED")
    print(f"{'='*80}")
    
    return master_results

print("Per-fold experiment runner defined")
# Out:
# Per-fold experiment runner defined

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 8
# ================================================================================
#
# ################################################################################
# # FOLD 1/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 92.59%, F1: 92.57%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 21.7s
#     Test Acc: 95.37%, F1: 94.71%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.1s
#     Test Acc: 97.22%, F1: 97.23%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.2s
#     Test Acc: 66.67%, F1: 62.06%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06285380116959068']
# ['At iteration 1 the best fitness is 0.05648232901093312']
# ['At iteration 2 the best fitness is 0.050161708619374475']
# ['At iteration 3 the best fitness is 0.050161708619374475']
# ['At iteration 4 the best fitness is 0.050161708619374475']
# ['At iteration 5 the best fitness is 0.050161708619374475']
# ['At iteration 6 the best fitness is 0.050161708619374475']
# ['At iteration 7 the best fitness is 0.050161708619374475']
# ['At iteration 8 the best fitness is 0.050161708619374475']
# ['At iteration 9 the best fitness is 0.050161708619374475']
# ['At iteration 10 the best fitness is 0.050161708619374475']
# ['At iteration 11 the best fitness is 0.050161708619374475']
# ['At iteration 12 the best fitness is 0.050161708619374475']
# ['At iteration 13 the best fitness is 0.050161708619374475']
# ['At iteration 14 the best fitness is 0.050161708619374475']
# ['At iteration 15 the best fitness is 0.050161708619374475']
# ['At iteration 16 the best fitness is 0.050161708619374475']
# ['At iteration 17 the best fitness is 0.050161708619374475']
# ['At iteration 18 the best fitness is 0.050161708619374475']
# ['At iteration 19 the best fitness is 0.050161708619374475']
# ['At iteration 20 the best fitness is 0.050161708619374475']
# ['At iteration 21 the best fitness is 0.050161708619374475']
# ['At iteration 22 the best fitness is 0.050161708619374475']
# ['At iteration 23 the best fitness is 0.050161708619374475']
# ['At iteration 24 the best fitness is 0.050161708619374475']
# ['At iteration 25 the best fitness is 0.050161708619374475']
# ['At iteration 26 the best fitness is 0.050161708619374475']
# ['At iteration 27 the best fitness is 0.050161708619374475']
# ['At iteration 28 the best fitness is 0.050161708619374475']
# ['At iteration 29 the best fitness is 0.050161708619374475']
#       Selected: 1977/3933 (50.3%), Fitness: 0.0502, Time: 499.3s
#       Modality: D=53%, S=49%, Sk=49%, V=52%
#     Test Acc: 88.89%, F1: 88.18%, Features: 1977/3933 (50.3%), Model: 4.402MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06356572590897537']
# ['At iteration 10 the best fitness is 0.04422247648105773']
# ['At iteration 20 the best fitness is 0.04385380116959066']
#       Selected: 1990/3933 (50.6%), Fitness: 0.0439, Time: 982.1s
#       Modality: D=49%, S=52%, Sk=51%, V=50%
#     Test Acc: 87.04%, F1: 85.57%, Features: 1990/3933 (50.6%), Model: 4.428MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05700355962369691']
# ['At iteration 2 the best fitness is 0.05700355962369691']
# ['At iteration 3 the best fitness is 0.05658403254513093']
# ['At iteration 4 the best fitness is 0.05658403254513093']
# ['At iteration 5 the best fitness is 0.05658403254513093']
# ['At iteration 6 the best fitness is 0.05658403254513093']
# ['At iteration 7 the best fitness is 0.05658403254513093']
# ['At iteration 8 the best fitness is 0.05658403254513093']
# ['At iteration 9 the best fitness is 0.05658403254513093']
# ['At iteration 10 the best fitness is 0.05658403254513093']
# ['At iteration 11 the best fitness is 0.04974218154080849']
# ['At iteration 12 the best fitness is 0.03753318077803201']
# ['At iteration 13 the best fitness is 0.03753318077803201']
# ['At iteration 14 the best fitness is 0.03753318077803201']
# ['At iteration 15 the best fitness is 0.03753318077803201']
# ['At iteration 16 the best fitness is 0.03753318077803201']
# ['At iteration 17 the best fitness is 0.03753318077803201']
# ['At iteration 18 the best fitness is 0.03753318077803201']
# ['At iteration 19 the best fitness is 0.03753318077803201']
# ['At iteration 20 the best fitness is 0.03753318077803201']
# ['At iteration 21 the best fitness is 0.03753318077803201']
# ['At iteration 22 the best fitness is 0.03753318077803201']
# ['At iteration 23 the best fitness is 0.03753318077803201']
# ['At iteration 24 the best fitness is 0.03753318077803201']
# ['At iteration 25 the best fitness is 0.03753318077803201']
# ['At iteration 26 the best fitness is 0.03753318077803201']
# ['At iteration 27 the best fitness is 0.03753318077803201']
# ['At iteration 28 the best fitness is 0.03753318077803201']
# ['At iteration 29 the best fitness is 0.03753318077803201']
# ['At iteration 30 the best fitness is 0.03753318077803201']
#       Selected: 1942/3933 (49.4%), Fitness: 0.0375, Time: 498.7s
#       Modality: D=48%, S=45%, Sk=51%, V=49%
#     Test Acc: 88.89%, F1: 88.40%, Features: 1942/3933 (49.4%), Model: 4.334MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06904729214340195']
# ['At iteration 1 the best fitness is 0.05655860666158148']
# ['At iteration 2 the best fitness is 0.050428680396643735']
# ['At iteration 3 the best fitness is 0.05006000508517666']
# ['At iteration 4 the best fitness is 0.062370709382151064']
# ['At iteration 5 the best fitness is 0.04385380116959066']
# ['At iteration 6 the best fitness is 0.06252326468344778']
# ['At iteration 7 the best fitness is 0.04990744978387994']
# ['At iteration 8 the best fitness is 0.05591024663107042']
# ['At iteration 9 the best fitness is 0.05593567251461987']
# ['At iteration 10 the best fitness is 0.05591024663107042']
# ['At iteration 11 the best fitness is 0.049589626239511776']
# ['At iteration 12 the best fitness is 0.06220544113907962']
# ['At iteration 13 the best fitness is 0.06855148741418761']
# ['At iteration 14 the best fitness is 0.05589753368929569']
# ['At iteration 15 the best fitness is 0.06226900584795325']
# ['At iteration 16 the best fitness is 0.06220544113907962']
# ['At iteration 17 the best fitness is 0.0622435799644038']
# ['At iteration 18 the best fitness is 0.06226900584795325']
# ['At iteration 19 the best fitness is 0.0559483854563946']
# ['At iteration 20 the best fitness is 0.05589753368929569']
# ['At iteration 21 the best fitness is 0.05587210780574624']
# ['At iteration 22 the best fitness is 0.05587210780574624']
# ['At iteration 23 the best fitness is 0.06216730231375544']
# ['At iteration 24 the best fitness is 0.05585939486397151']
# ['At iteration 25 the best fitness is 0.062180015255530165']
# ['At iteration 26 the best fitness is 0.062180015255530165']
# ['At iteration 27 the best fitness is 0.06219272819730489']
# ['At iteration 28 the best fitness is 0.062180015255530165']
# ['At iteration 29 the best fitness is 0.062180015255530165']
#       Selected: 1900/3933 (48.3%), Fitness: 0.0622, Time: 480.3s
#       Modality: D=51%, S=49%, Sk=48%, V=48%
#     Test Acc: 85.19%, F1: 83.58%, Features: 1900/3933 (48.3%), Model: 4.252MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.06885659801678105
# At iteration 2 the best fitness is 0.05655860666158148
# At iteration 3 the best fitness is 0.04999644037630303
# At iteration 4 the best fitness is 0.05019984744469866
# At iteration 5 the best fitness is 0.0565204678362573
# At iteration 6 the best fitness is 0.056545893719806756
# At iteration 7 the best fitness is 0.056202644291889134
# At iteration 8 the best fitness is 0.056469616069158395
# At iteration 9 the best fitness is 0.049920162725654665
# At iteration 10 the best fitness is 0.05578311721332315
# At iteration 11 the best fitness is 0.04980574624968213
# At iteration 12 the best fitness is 0.049513348588863415
# At iteration 13 the best fitness is 0.04955148741418759
# At iteration 14 the best fitness is 0.05058123569794046
# At iteration 15 the best fitness is 0.04950063564708869
# At iteration 16 the best fitness is 0.043294431731502686
# At iteration 17 the best fitness is 0.049945588609204124
# At iteration 18 the best fitness is 0.05626620900076277
# At iteration 19 the best fitness is 0.049894736842105214
# At iteration 20 the best fitness is 0.04354869056699722
# At iteration 21 the best fitness is 0.049894736842105214
# At iteration 22 the best fitness is 0.04984388507500631
# At iteration 23 the best fitness is 0.05035240274599538
# At iteration 24 the best fitness is 0.04356140350877195
# At iteration 25 the best fitness is 0.04403178235443683
# At iteration 26 the best fitness is 0.05008543096872611
# At iteration 27 the best fitness is 0.04373938469361812
# At iteration 28 the best fitness is 0.04375209763539285
# At iteration 29 the best fitness is 0.04375209763539285
# At iteration 30 the best fitness is 0.043968217645563204
#       Selected: 2000/3933 (50.9%), Fitness: 0.0440, Time: 481.3s
#       Modality: D=56%, S=50%, Sk=49%, V=53%
#     Test Acc: 87.96%, F1: 86.47%, Features: 2000/3933 (50.9%), Model: 4.447MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06988634630053392']
# ['At iteration 1 the best fitness is 0.06233257055682688']
# ['At iteration 2 the best fitness is 0.06085786931095859']
# ['At iteration 3 the best fitness is 0.0535202135774218']
# ['At iteration 4 the best fitness is 0.05266844647851512']
# ['At iteration 5 the best fitness is 0.04557233663869815']
# ['At iteration 6 the best fitness is 0.04557233663869815']
# ['At iteration 7 the best fitness is 0.04557233663869815']
# ['At iteration 8 the best fitness is 0.04418662598525294']
# ['At iteration 9 the best fitness is 0.031710653445207196']
# ['At iteration 10 the best fitness is 0.031710653445207196']
# ['At iteration 11 the best fitness is 0.031710653445207196']
# ['At iteration 12 the best fitness is 0.031710653445207196']
# ['At iteration 13 the best fitness is 0.030795321637426876']
# ['At iteration 14 the best fitness is 0.030795321637426876']
# ['At iteration 15 the best fitness is 0.030795321637426876']
# ['At iteration 16 the best fitness is 0.030795321637426876']
# ['At iteration 17 the best fitness is 0.030795321637426876']
# ['At iteration 18 the best fitness is 0.030795321637426876']
# ['At iteration 19 the best fitness is 0.030795321637426876']
# ['At iteration 20 the best fitness is 0.030795321637426876']
# ['At iteration 21 the best fitness is 0.030795321637426876']
# ['At iteration 22 the best fitness is 0.030795321637426876']
# ['At iteration 23 the best fitness is 0.030795321637426876']
# ['At iteration 24 the best fitness is 0.030795321637426876']
# ['At iteration 25 the best fitness is 0.030795321637426876']
# ['At iteration 26 the best fitness is 0.030795321637426876']
# ['At iteration 27 the best fitness is 0.030795321637426876']
# ['At iteration 28 the best fitness is 0.030795321637426876']
# ['At iteration 29 the best fitness is 0.030795321637426876']
#       Selected: 1518/3933 (38.6%), Fitness: 0.0308, Time: 469.9s
#       Modality: D=38%, S=39%, Sk=39%, V=38%
#     Test Acc: 89.81%, F1: 88.30%, Features: 1518/3933 (38.6%), Model: 3.506MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.04390465293668957']
# ['At iteration 1 the best fitness is 0.040908975336892944']
# ['At iteration 2 the best fitness is 0.040908975336892944']
# ['At iteration 3 the best fitness is 0.03555453852021353']
# ['At iteration 4 the best fitness is 0.03555453852021353']
# ['At iteration 5 the best fitness is 0.03555453852021353']
# ['At iteration 6 the best fitness is 0.03555453852021353']
# ['At iteration 7 the best fitness is 0.03555453852021353']
# ['At iteration 8 the best fitness is 0.03555453852021353']
# ['At iteration 9 the best fitness is 0.03555453852021353']
# ['At iteration 10 the best fitness is 0.03555453852021353']
# ['At iteration 11 the best fitness is 0.03555453852021353']
# ['At iteration 12 the best fitness is 0.03555453852021353']
# ['At iteration 13 the best fitness is 0.03555453852021353']
# ['At iteration 14 the best fitness is 0.03555453852021353']
# ['At iteration 15 the best fitness is 0.03555453852021353']
# ['At iteration 16 the best fitness is 0.03555453852021353']
# ['At iteration 17 the best fitness is 0.03555453852021353']
# ['At iteration 18 the best fitness is 0.03555453852021353']
# ['At iteration 19 the best fitness is 0.03555453852021353']
# ['At iteration 20 the best fitness is 0.03555453852021353']
# ['At iteration 21 the best fitness is 0.03555453852021353']
# ['At iteration 22 the best fitness is 0.03555453852021353']
# ['At iteration 23 the best fitness is 0.03555453852021353']
# ['At iteration 24 the best fitness is 0.03414340198321887']
# ['At iteration 25 the best fitness is 0.03414340198321887']
# ['At iteration 26 the best fitness is 0.03414340198321887']
# ['At iteration 27 the best fitness is 0.03414340198321887']
# ['At iteration 28 the best fitness is 0.027899059242308687']
# ['At iteration 29 the best fitness is 0.027899059242308687']
#       Selected: 840/3933 (21.4%), Fitness: 0.0279, Time: 579.9s
#       Modality: D=16%, S=19%, Sk=21%, V=23%
#     Test Acc: 85.19%, F1: 85.17%, Features: 840/3933 (21.4%), Model: 2.182MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05662217137045511']
# ['At iteration 1 the best fitness is 0.05662217137045511']
# ['At iteration 2 the best fitness is 0.05032697686244592']
# ['At iteration 3 the best fitness is 0.05032697686244592']
# ['At iteration 4 the best fitness is 0.05032697686244592']
# ['At iteration 5 the best fitness is 0.05032697686244592']
# ['At iteration 6 the best fitness is 0.04417162471395883']
# ['At iteration 7 the best fitness is 0.04417162471395883']
# ['At iteration 8 the best fitness is 0.04417162471395883']
# ['At iteration 9 the best fitness is 0.04417162471395883']
# ['At iteration 10 the best fitness is 0.04417162471395883']
# ['At iteration 11 the best fitness is 0.04417162471395883']
# ['At iteration 12 the best fitness is 0.04417162471395883']
# ['At iteration 13 the best fitness is 0.04417162471395883']
# ['At iteration 14 the best fitness is 0.04417162471395883']
# ['At iteration 15 the best fitness is 0.04417162471395883']
# ['At iteration 16 the best fitness is 0.04417162471395883']
# ['At iteration 17 the best fitness is 0.04417162471395883']
# ['At iteration 18 the best fitness is 0.04417162471395883']
# ['At iteration 19 the best fitness is 0.04417162471395883']
# ['At iteration 20 the best fitness is 0.04417162471395883']
# ['At iteration 21 the best fitness is 0.04417162471395883']
# ['At iteration 22 the best fitness is 0.04417162471395883']
# ['At iteration 23 the best fitness is 0.04417162471395883']
# ['At iteration 24 the best fitness is 0.04417162471395883']
# ['At iteration 25 the best fitness is 0.04417162471395883']
# ['At iteration 26 the best fitness is 0.04417162471395883']
# ['At iteration 27 the best fitness is 0.04359954233409613']
# ['At iteration 28 the best fitness is 0.04359954233409613']
# ['At iteration 29 the best fitness is 0.04359954233409613']
#       Selected: 1951/3933 (49.6%), Fitness: 0.0436, Time: 500.4s
#       Modality: D=50%, S=51%, Sk=50%, V=49%
#     Test Acc: 90.74%, F1: 89.97%, Features: 1951/3933 (49.6%), Model: 4.352MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05657131960335621']
# ['At iteration 2 the best fitness is 0.05657131960335621']
# ['At iteration 3 the best fitness is 0.05657131960335621']
# ['At iteration 4 the best fitness is 0.05657131960335621']
# ['At iteration 5 the best fitness is 0.05657131960335621']
# ['At iteration 6 the best fitness is 0.05657131960335621']
# ['At iteration 7 the best fitness is 0.05657131960335621']
# ['At iteration 8 the best fitness is 0.05657131960335621']
# ['At iteration 9 the best fitness is 0.05657131960335621']
# ['At iteration 10 the best fitness is 0.05657131960335621']
# ['At iteration 11 the best fitness is 0.05657131960335621']
# ['At iteration 12 the best fitness is 0.05657131960335621']
# ['At iteration 13 the best fitness is 0.05657131960335621']
# ['At iteration 14 the best fitness is 0.05657131960335621']
# ['At iteration 15 the best fitness is 0.05657131960335621']
# ['At iteration 16 the best fitness is 0.05657131960335621']
# ['At iteration 17 the best fitness is 0.05657131960335621']
# ['At iteration 18 the best fitness is 0.05657131960335621']
# ['At iteration 19 the best fitness is 0.05657131960335621']
# ['At iteration 20 the best fitness is 0.05657131960335621']
# ['At iteration 21 the best fitness is 0.05051767098906682']
# ['At iteration 22 the best fitness is 0.05035240274599538']
# ['At iteration 23 the best fitness is 0.05035240274599538']
# ['At iteration 24 the best fitness is 0.05035240274599538']
# ['At iteration 25 the best fitness is 0.05035240274599538']
# ['At iteration 26 the best fitness is 0.04351055174167304']
# ['At iteration 27 the best fitness is 0.04351055174167304']
# ['At iteration 28 the best fitness is 0.04351055174167304']
# ['At iteration 29 the best fitness is 0.04351055174167304']
#       Selected: 1962/3933 (49.9%), Fitness: 0.0435, Time: 474.2s
#       Modality: D=49%, S=54%, Sk=50%, V=48%
#     Test Acc: 86.11%, F1: 85.38%, Features: 1962/3933 (49.9%), Model: 4.373MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.06271395881006869']
# ['At iteration 2 the best fitness is 0.06271395881006869']
# ['At iteration 3 the best fitness is 0.05638062547673531']
# ['At iteration 4 the best fitness is 0.05638062547673531']
# ['At iteration 5 the best fitness is 0.05638062547673531']
# ['At iteration 6 the best fitness is 0.05638062547673531']
# ['At iteration 7 the best fitness is 0.05638062547673531']
# ['At iteration 8 the best fitness is 0.05638062547673531']
# ['At iteration 9 the best fitness is 0.05638062547673531']
# ['At iteration 10 the best fitness is 0.05638062547673531']
# ['At iteration 11 the best fitness is 0.05638062547673531']
# ['At iteration 12 the best fitness is 0.05638062547673531']
# ['At iteration 13 the best fitness is 0.05638062547673531']
# ['At iteration 14 the best fitness is 0.05638062547673531']
# ['At iteration 15 the best fitness is 0.05638062547673531']
# ['At iteration 16 the best fitness is 0.05638062547673531']
# ['At iteration 17 the best fitness is 0.05638062547673531']
# ['At iteration 18 the best fitness is 0.05638062547673531']
# ['At iteration 19 the best fitness is 0.05638062547673531']
# ['At iteration 20 the best fitness is 0.05638062547673531']
# ['At iteration 21 the best fitness is 0.05634248665141113']
# ['At iteration 22 the best fitness is 0.05634248665141113']
# ['At iteration 23 the best fitness is 0.050047292143401936']
# ['At iteration 24 the best fitness is 0.04363768115942031']
# ['At iteration 25 the best fitness is 0.04363768115942031']
# ['At iteration 26 the best fitness is 0.04363768115942031']
# ['At iteration 27 the best fitness is 0.04363768115942031']
# ['At iteration 28 the best fitness is 0.04363768115942031']
# ['At iteration 29 the best fitness is 0.04363768115942031']
# ['At iteration 30 the best fitness is 0.04363768115942031']
#       Selected: 1945/3933 (49.5%), Fitness: 0.0436, Time: 487.5s
#       Modality: D=51%, S=51%, Sk=49%, V=49%
#     Test Acc: 90.74%, F1: 89.95%, Features: 1945/3933 (49.5%), Model: 4.340MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0628665141113654']
# ['At iteration 2 the best fitness is 0.06270124586829395']
# ['At iteration 3 the best fitness is 0.06256140350877196']
# ['At iteration 4 the best fitness is 0.06247241291634888']
# ['At iteration 5 the best fitness is 0.05617721840833968']
# ['At iteration 6 the best fitness is 0.05617721840833968']
# ['At iteration 7 the best fitness is 0.056088227815916596']
# ['At iteration 8 the best fitness is 0.056088227815916596']
# ['At iteration 9 the best fitness is 0.056088227815916596']
# ['At iteration 10 the best fitness is 0.056088227815916596']
# ['At iteration 11 the best fitness is 0.056088227815916596']
# ['At iteration 12 the best fitness is 0.056088227815916596']
# ['At iteration 13 the best fitness is 0.0557576913297737']
# ['At iteration 14 the best fitness is 0.0557576913297737']
# ['At iteration 15 the best fitness is 0.0557576913297737']
# ['At iteration 16 the best fitness is 0.055744978387998974']
# ['At iteration 17 the best fitness is 0.04930994152046779']
# ['At iteration 18 the best fitness is 0.04930994152046779']
# ['At iteration 19 the best fitness is 0.04896669209255017']
# ['At iteration 20 the best fitness is 0.04896669209255017']
# ['At iteration 21 the best fitness is 0.04315458937198069']
# ['At iteration 22 the best fitness is 0.04315458937198069']
# ['At iteration 23 the best fitness is 0.04315458937198069']
# ['At iteration 24 the best fitness is 0.04315458937198069']
# ['At iteration 25 the best fitness is 0.04315458937198069']
# ['At iteration 26 the best fitness is 0.04315458937198069']
# ['At iteration 27 the best fitness is 0.04279862700228835']
# ['At iteration 28 the best fitness is 0.04279862700228835']
# ['At iteration 29 the best fitness is 0.04279862700228835']
# ['At iteration 30 the best fitness is 0.04279862700228835']
#       Selected: 1894/3933 (48.2%), Fitness: 0.0428, Time: 484.1s
#       Modality: D=45%, S=46%, Sk=49%, V=48%
#     Test Acc: 87.96%, F1: 86.52%, Features: 1894/3933 (48.2%), Model: 4.240MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.0633368929570303']
# ['At iteration 1 the best fitness is 0.05551614543605389']
# ['At iteration 2 the best fitness is 0.05551614543605389']
# ['At iteration 3 the best fitness is 0.05219806763285023']
# ['At iteration 4 the best fitness is 0.05219806763285023']
# ['At iteration 5 the best fitness is 0.05219806763285023']
# ['At iteration 6 the best fitness is 0.047748538011695894']
# ['At iteration 7 the best fitness is 0.047748538011695894']
# ['At iteration 8 the best fitness is 0.04549834731756928']
# ['At iteration 9 the best fitness is 0.04549834731756928']
# ['At iteration 10 the best fitness is 0.04549834731756928']
# ['At iteration 11 the best fitness is 0.04549834731756928']
# ['At iteration 12 the best fitness is 0.04549834731756928']
# ['At iteration 13 the best fitness is 0.04549834731756928']
# ['At iteration 14 the best fitness is 0.04549834731756928']
# ['At iteration 15 the best fitness is 0.04177345537757436']
# ['At iteration 16 the best fitness is 0.04177345537757436']
# ['At iteration 17 the best fitness is 0.033838291380625427']
# ['At iteration 18 the best fitness is 0.033838291380625427']
# ['At iteration 19 the best fitness is 0.033838291380625427']
# ['At iteration 20 the best fitness is 0.02081566234426644']
# ['At iteration 21 the best fitness is 0.02081566234426644']
# ['At iteration 22 the best fitness is 0.02081566234426644']
# ['At iteration 23 the best fitness is 0.02081566234426644']
# ['At iteration 24 the best fitness is 0.02081566234426644']
# ['At iteration 25 the best fitness is 0.02081566234426644']
# ['At iteration 26 the best fitness is 0.02081566234426644']
# ['At iteration 27 the best fitness is 0.02081566234426644']
# ['At iteration 28 the best fitness is 0.02081566234426644']
# ['At iteration 29 the best fitness is 0.02081566234426644']
#       Selected: 696/3933 (17.7%), Fitness: 0.0208, Time: 434.0s
#       Modality: D=17%, S=21%, Sk=17%, V=17%
#     Test Acc: 83.33%, F1: 83.54%, Features: 696/3933 (17.7%), Model: 1.901MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05598652428171878']
# ['At iteration 2 the best fitness is 0.05598652428171878']
# ['At iteration 3 the best fitness is 0.05059394863971518']
# ['At iteration 4 the best fitness is 0.05059394863971518']
# ['At iteration 5 the best fitness is 0.05059394863971518']
# ['At iteration 6 the best fitness is 0.05059394863971518']
# ['At iteration 7 the best fitness is 0.05059394863971518']
# ['At iteration 8 the best fitness is 0.05059394863971518']
# ['At iteration 9 the best fitness is 0.05059394863971518']
# ['At iteration 10 the best fitness is 0.050161708619374475']
# ['At iteration 11 the best fitness is 0.050161708619374475']
# ['At iteration 12 the best fitness is 0.050161708619374475']
# ['At iteration 13 the best fitness is 0.050161708619374475']
# ['At iteration 14 the best fitness is 0.050161708619374475']
# ['At iteration 15 the best fitness is 0.050161708619374475']
# ['At iteration 16 the best fitness is 0.050161708619374475']
# ['At iteration 17 the best fitness is 0.050161708619374475']
# ['At iteration 18 the best fitness is 0.050161708619374475']
# ['At iteration 19 the best fitness is 0.04384108822781593']
# ['At iteration 20 the best fitness is 0.04384108822781593']
# ['At iteration 21 the best fitness is 0.04384108822781593']
# ['At iteration 22 the best fitness is 0.04384108822781593']
# ['At iteration 23 the best fitness is 0.04384108822781593']
# ['At iteration 24 the best fitness is 0.04384108822781593']
# ['At iteration 25 the best fitness is 0.04384108822781593']
# ['At iteration 26 the best fitness is 0.04384108822781593']
# ['At iteration 27 the best fitness is 0.04384108822781593']
# ['At iteration 28 the best fitness is 0.04384108822781593']
# ['At iteration 29 the best fitness is 0.04384108822781593']
#       Selected: 1953/3933 (49.7%), Fitness: 0.0438, Time: 1213.2s
#       Modality: D=46%, S=50%, Sk=51%, V=49%
#     Test Acc: 89.81%, F1: 89.15%, Features: 1953/3933 (49.7%), Model: 4.356MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06361657767607427']
# ['At iteration 1 the best fitness is 0.06361657767607427']
# ['At iteration 2 the best fitness is 0.06361657767607427']
# ['At iteration 3 the best fitness is 0.0631461988304094']
# ['At iteration 4 the best fitness is 0.06056547165013988']
# ['At iteration 5 the best fitness is 0.06024764810577171']
# ['At iteration 6 the best fitness is 0.06024764810577171']
# ['At iteration 7 the best fitness is 0.05203737604881767']
# ['At iteration 8 the best fitness is 0.05203737604881767']
# ['At iteration 9 the best fitness is 0.05203737604881767']
# ['At iteration 10 the best fitness is 0.05203737604881767']
# ['At iteration 11 the best fitness is 0.032973811339944016']
# ['At iteration 12 the best fitness is 0.032973811339944016']
# ['At iteration 13 the best fitness is 0.032973811339944016']
# ['At iteration 14 the best fitness is 0.032973811339944016']
# ['At iteration 15 the best fitness is 0.032973811339944016']
# ['At iteration 16 the best fitness is 0.032973811339944016']
# ['At iteration 17 the best fitness is 0.032973811339944016']
# ['At iteration 18 the best fitness is 0.032973811339944016']
# ['At iteration 19 the best fitness is 0.032973811339944016']
# ['At iteration 20 the best fitness is 0.032973811339944016']
# ['At iteration 21 the best fitness is 0.032973811339944016']
# ['At iteration 22 the best fitness is 0.032973811339944016']
# ['At iteration 23 the best fitness is 0.032973811339944016']
# ['At iteration 24 the best fitness is 0.032973811339944016']
# ['At iteration 25 the best fitness is 0.032973811339944016']
# ['At iteration 26 the best fitness is 0.032973811339944016']
# ['At iteration 27 the best fitness is 0.032973811339944016']
# ['At iteration 28 the best fitness is 0.032973811339944016']
# ['At iteration 29 the best fitness is 0.032973811339944016']
#       Selected: 988/3933 (25.1%), Fitness: 0.0330, Time: 388.8s
#       Modality: D=24%, S=25%, Sk=26%, V=25%
#     Test Acc: 92.59%, F1: 92.11%, Features: 988/3933 (25.1%), Model: 2.471MB
#
# ################################################################################
# # FOLD 2/8
# ################################################################################
#   Train: 603, Val: 150, Test: 108
#
#   --- BASELINE ---
#     Test Acc: 90.74%, F1: 89.71%, Features: 3933/3933 (100.0%), Model: 8.223MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 1966/3933 (50.0%), Time: 21.5s
#     Test Acc: 86.11%, F1: 85.16%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 1966/3933 (50.0%), Time: 4.0s
#     Test Acc: 87.04%, F1: 86.04%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 1966/3933 (50.0%), Time: 1.2s
#     Test Acc: 72.22%, F1: 68.28%, Features: 1966/3933 (50.0%), Model: 4.381MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.03694838545639459']
# ['At iteration 1 the best fitness is 0.03694838545639459']
# ['At iteration 2 the best fitness is 0.03694838545639459']
# ['At iteration 3 the best fitness is 0.03694838545639459']
# ['At iteration 4 the best fitness is 0.03694838545639459']
# ['At iteration 5 the best fitness is 0.03694838545639459']
# ['At iteration 6 the best fitness is 0.03694838545639459']
# ['At iteration 7 the best fitness is 0.03694838545639459']
# ['At iteration 8 the best fitness is 0.03694838545639459']
# ['At iteration 9 the best fitness is 0.03694838545639459']
# ['At iteration 10 the best fitness is 0.03694838545639459']
# ['At iteration 11 the best fitness is 0.03694838545639459']
# ['At iteration 12 the best fitness is 0.03694838545639459']
# ['At iteration 13 the best fitness is 0.03694838545639459']
# ['At iteration 14 the best fitness is 0.03694838545639459']
# ['At iteration 15 the best fitness is 0.03694838545639459']
# ['At iteration 16 the best fitness is 0.03694838545639459']
# ['At iteration 17 the best fitness is 0.03694838545639459']
# ['At iteration 18 the best fitness is 0.03694838545639459']
# ['At iteration 19 the best fitness is 0.03694838545639459']
# ['At iteration 20 the best fitness is 0.03694838545639459']
# ['At iteration 21 the best fitness is 0.03694838545639459']
# ['At iteration 22 the best fitness is 0.03694838545639459']
# ['At iteration 23 the best fitness is 0.03694838545639459']
# ['At iteration 24 the best fitness is 0.03694838545639459']
# ['At iteration 25 the best fitness is 0.03694838545639459']
# ['At iteration 26 the best fitness is 0.03694838545639459']
# ['At iteration 27 the best fitness is 0.03694838545639459']
# ['At iteration 28 the best fitness is 0.03694838545639459']
# ['At iteration 29 the best fitness is 0.03694838545639459']
#       Selected: 1908/3933 (48.5%), Fitness: 0.0369, Time: 501.1s
#       Modality: D=49%, S=49%, Sk=49%, V=47%
#     Test Acc: 91.67%, F1: 90.17%, Features: 1908/3933 (48.5%), Model: 4.268MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05025069921179756']
# ['At iteration 10 the best fitness is 0.04405720823798629']
# ['At iteration 20 the best fitness is 0.04384108822781593']
#       Selected: 1962/3933 (49.9%), Fitness: 0.0438, Time: 984.8s
#       Modality: D=45%, S=53%, Sk=49%, V=50%
#     Test Acc: 91.67%, F1: 90.46%, Features: 1962/3933 (49.9%), Model: 4.373MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.051026188660055885']
# ['At iteration 2 the best fitness is 0.05046681922196792']
# ['At iteration 3 the best fitness is 0.05046681922196792']
# ['At iteration 4 the best fitness is 0.050237986270022836']
# ['At iteration 5 the best fitness is 0.050237986270022836']
# ['At iteration 6 the best fitness is 0.050237986270022836']
# ['At iteration 7 the best fitness is 0.050237986270022836']
# ['At iteration 8 the best fitness is 0.044400457665903906']
# ['At iteration 9 the best fitness is 0.044400457665903906']
# ['At iteration 10 the best fitness is 0.044400457665903906']
# ['At iteration 11 the best fitness is 0.04408263412153574']
# ['At iteration 12 the best fitness is 0.04408263412153574']
# ['At iteration 13 the best fitness is 0.04408263412153574']
# ['At iteration 14 the best fitness is 0.04408263412153574']
# ['At iteration 15 the best fitness is 0.04404449529621156']
# ['At iteration 16 the best fitness is 0.04404449529621156']
# ['At iteration 17 the best fitness is 0.04404449529621156']
# ['At iteration 18 the best fitness is 0.04404449529621156']
# ['At iteration 19 the best fitness is 0.04404449529621156']
# ['At iteration 20 the best fitness is 0.04404449529621156']
# ['At iteration 21 the best fitness is 0.04404449529621156']
# ['At iteration 22 the best fitness is 0.04379023646071703']
# ['At iteration 23 the best fitness is 0.04379023646071703']
# ['At iteration 24 the best fitness is 0.04368853292651921']
# ['At iteration 25 the best fitness is 0.04368853292651921']
# ['At iteration 26 the best fitness is 0.04368853292651921']
# ['At iteration 27 the best fitness is 0.04368853292651921']
# ['At iteration 28 the best fitness is 0.04368853292651921']
# ['At iteration 29 the best fitness is 0.04368853292651921']
# ['At iteration 30 the best fitness is 0.04368853292651921']
#       Selected: 1953/3933 (49.7%), Fitness: 0.0437, Time: 499.9s
#       Modality: D=50%, S=50%, Sk=49%, V=50%
#     Test Acc: 86.11%, F1: 83.51%, Features: 1953/3933 (49.7%), Model: 4.356MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.043726671751843395']
# ['At iteration 1 the best fitness is 0.04985659801678104']
# ['At iteration 2 the best fitness is 0.05605008899059241']
# ['At iteration 3 the best fitness is 0.05616450546656496']
# ['At iteration 4 the best fitness is 0.04980574624968213']
# ['At iteration 5 the best fitness is 0.043802949402491756']
# ['At iteration 6 the best fitness is 0.04981845919145685']
# ['At iteration 7 the best fitness is 0.04999644037630303']
# ['At iteration 8 the best fitness is 0.06233257055682688']
# ['At iteration 9 the best fitness is 0.050110856852275565']
# ['At iteration 10 the best fitness is 0.049729468599033766']
# ['At iteration 11 the best fitness is 0.0499328756674294']
# ['At iteration 12 the best fitness is 0.04980574624968213']
# ['At iteration 13 the best fitness is 0.056202644291889134']
# ['At iteration 14 the best fitness is 0.049920162725654665']
# ['At iteration 15 the best fitness is 0.056202644291889134']
# ['At iteration 16 the best fitness is 0.043535977625222495']
# ['At iteration 17 the best fitness is 0.05618993135011441']
# ['At iteration 18 the best fitness is 0.05617721840833968']
# ['At iteration 19 the best fitness is 0.04988202390033049']
# ['At iteration 20 the best fitness is 0.04988202390033049']
# ['At iteration 21 the best fitness is 0.05618993135011441']
# ['At iteration 22 the best fitness is 0.04984388507500631']
# ['At iteration 23 the best fitness is 0.05621535723366386']
# ['At iteration 24 the best fitness is 0.056228070175438585']
# ['At iteration 25 the best fitness is 0.04356140350877195']
# ['At iteration 26 the best fitness is 0.04990744978387994']
# ['At iteration 27 the best fitness is 0.04990744978387994']
# ['At iteration 28 the best fitness is 0.04990744978387994']
# ['At iteration 29 the best fitness is 0.04990744978387994']
#       Selected: 1922/3933 (48.9%), Fitness: 0.0499, Time: 481.7s
#       Modality: D=46%, S=50%, Sk=50%, V=47%
#     Test Acc: 84.26%, F1: 82.05%, Features: 1922/3933 (48.9%), Model: 4.295MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.05674930078820238
# At iteration 2 the best fitness is 0.05027612509534701
# At iteration 3 the best fitness is 0.05645690312738367
# At iteration 4 the best fitness is 0.050428680396643735
# At iteration 5 the best fitness is 0.04984388507500631
# At iteration 6 the best fitness is 0.056660310195779294
# At iteration 7 the best fitness is 0.05059394863971518
# At iteration 8 the best fitness is 0.05059394863971518
# At iteration 9 the best fitness is 0.05063208746503936
# At iteration 10 the best fitness is 0.05653318077803203
# At iteration 11 the best fitness is 0.03750775489448256
# At iteration 12 the best fitness is 0.05006000508517666
# At iteration 13 the best fitness is 0.05056852275616573
# At iteration 14 the best fitness is 0.049945588609204124
# At iteration 15 the best fitness is 0.043535977625222495
# At iteration 16 the best fitness is 0.05056852275616573
# At iteration 17 the best fitness is 0.04349783879989831
# At iteration 18 the best fitness is 0.04990744978387994
# At iteration 19 the best fitness is 0.043535977625222495
# At iteration 20 the best fitness is 0.049831172133231585
# At iteration 21 the best fitness is 0.04352326468344776
# At iteration 22 the best fitness is 0.04347241291634886
# At iteration 23 the best fitness is 0.04373938469361812
# At iteration 24 the best fitness is 0.04342156114924996
# At iteration 25 the best fitness is 0.049780320366132676
# At iteration 26 the best fitness is 0.049640478006610686
# At iteration 27 the best fitness is 0.04335799644037632
# At iteration 28 the best fitness is 0.04969132977370959
# At iteration 29 the best fitness is 0.043396135265700506
# At iteration 30 the best fitness is 0.04363768115942031
#       Selected: 1964/3933 (49.9%), Fitness: 0.0436, Time: 481.6s
#       Modality: D=57%, S=51%, Sk=48%, V=50%
#     Test Acc: 89.81%, F1: 89.13%, Features: 1964/3933 (49.9%), Model: 4.377MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.050644800406814086']
# ['At iteration 1 the best fitness is 0.050644800406814086']
# ['At iteration 2 the best fitness is 0.047949656750572035']
# ['At iteration 3 the best fitness is 0.034888888888888865']
# ['At iteration 4 the best fitness is 0.034888888888888865']
# ['At iteration 5 the best fitness is 0.034888888888888865']
# ['At iteration 6 the best fitness is 0.034888888888888865']
# ['At iteration 7 the best fitness is 0.034888888888888865']
# ['At iteration 8 the best fitness is 0.034888888888888865']
# ['At iteration 9 the best fitness is 0.034888888888888865']
# ['At iteration 10 the best fitness is 0.034888888888888865']
# ['At iteration 11 the best fitness is 0.034888888888888865']
# ['At iteration 12 the best fitness is 0.034888888888888865']
# ['At iteration 13 the best fitness is 0.034888888888888865']
# ['At iteration 14 the best fitness is 0.034888888888888865']
# ['At iteration 15 the best fitness is 0.034888888888888865']
# ['At iteration 16 the best fitness is 0.0332362064581744']
# ['At iteration 17 the best fitness is 0.0332362064581744']
# ['At iteration 18 the best fitness is 0.0332362064581744']
# ['At iteration 19 the best fitness is 0.0332362064581744']
# ['At iteration 20 the best fitness is 0.033058225273328225']
# ['At iteration 21 the best fitness is 0.033058225273328225']
# ['At iteration 22 the best fitness is 0.033058225273328225']
# ['At iteration 23 the best fitness is 0.033058225273328225']
# ['At iteration 24 the best fitness is 0.033058225273328225']
# ['At iteration 25 the best fitness is 0.033058225273328225']
# ['At iteration 26 the best fitness is 0.033058225273328225']
# ['At iteration 27 the best fitness is 0.033058225273328225']
# ['At iteration 28 the best fitness is 0.033058225273328225']
# ['At iteration 29 the best fitness is 0.033058225273328225']
#       Selected: 1681/3933 (42.7%), Fitness: 0.0331, Time: 470.6s
#       Modality: D=44%, S=43%, Sk=43%, V=42%
#     Test Acc: 88.89%, F1: 87.50%, Features: 1681/3933 (42.7%), Model: 3.824MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.0559483854563946']
# ['At iteration 1 the best fitness is 0.04967861683193486']
# ['At iteration 2 the best fitness is 0.04967861683193486']
# ['At iteration 3 the best fitness is 0.04822934146961602']
# ['At iteration 4 the best fitness is 0.04822934146961602']
# ['At iteration 5 the best fitness is 0.04296389524535979']
# ['At iteration 6 the best fitness is 0.04296389524535979']
# ['At iteration 7 the best fitness is 0.04296389524535979']
# ['At iteration 8 the best fitness is 0.04274777523518944']
# ['At iteration 9 the best fitness is 0.04274777523518944']
# ['At iteration 10 the best fitness is 0.04274777523518944']
# ['At iteration 11 the best fitness is 0.04274777523518944']
# ['At iteration 12 the best fitness is 0.04274777523518944']
# ['At iteration 13 the best fitness is 0.04274777523518944']
# ['At iteration 14 the best fitness is 0.04274777523518944']
# ['At iteration 15 the best fitness is 0.04274777523518944']
# ['At iteration 16 the best fitness is 0.04274777523518944']
# ['At iteration 17 the best fitness is 0.04274777523518944']
# ['At iteration 18 the best fitness is 0.04274777523518944']
# ['At iteration 19 the best fitness is 0.04273506229341471']
# ['At iteration 20 the best fitness is 0.042699211797609916']
# ['At iteration 21 the best fitness is 0.042699211797609916']
# ['At iteration 22 the best fitness is 0.04266107297228573']
# ['At iteration 23 the best fitness is 0.04266107297228573']
# ['At iteration 24 the best fitness is 0.04266107297228573']
# ['At iteration 25 the best fitness is 0.04247037884566483']
# ['At iteration 26 the best fitness is 0.04247037884566483']
# ['At iteration 27 the best fitness is 0.036048054919908486']
# ['At iteration 28 the best fitness is 0.036048054919908486']
# ['At iteration 29 the best fitness is 0.036048054919908486']
#       Selected: 1433/3933 (36.4%), Fitness: 0.0360, Time: 631.0s
#       Modality: D=34%, S=34%, Sk=37%, V=38%
#     Test Acc: 88.89%, F1: 88.06%, Features: 1433/3933 (36.4%), Model: 3.340MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05047953216374264']
# ['At iteration 1 the best fitness is 0.05047953216374264']
# ['At iteration 2 the best fitness is 0.050110856852275565']
# ['At iteration 3 the best fitness is 0.050110856852275565']
# ['At iteration 4 the best fitness is 0.04429875413170609']
# ['At iteration 5 the best fitness is 0.04429875413170609']
# ['At iteration 6 the best fitness is 0.04429875413170609']
# ['At iteration 7 the best fitness is 0.04429875413170609']
# ['At iteration 8 the best fitness is 0.04429875413170609']
# ['At iteration 9 the best fitness is 0.04429875413170609']
# ['At iteration 10 the best fitness is 0.04429875413170609']
# ['At iteration 11 the best fitness is 0.04429875413170609']
# ['At iteration 12 the best fitness is 0.04429875413170609']
# ['At iteration 13 the best fitness is 0.04429875413170609']
# ['At iteration 14 the best fitness is 0.03753318077803201']
# ['At iteration 15 the best fitness is 0.03753318077803201']
# ['At iteration 16 the best fitness is 0.03753318077803201']
# ['At iteration 17 the best fitness is 0.03753318077803201']
# ['At iteration 18 the best fitness is 0.03753318077803201']
# ['At iteration 19 the best fitness is 0.03753318077803201']
# ['At iteration 20 the best fitness is 0.03753318077803201']
# ['At iteration 21 the best fitness is 0.03753318077803201']
# ['At iteration 22 the best fitness is 0.03753318077803201']
# ['At iteration 23 the best fitness is 0.03753318077803201']
# ['At iteration 24 the best fitness is 0.03753318077803201']
# ['At iteration 25 the best fitness is 0.03753318077803201']
# ['At iteration 26 the best fitness is 0.03753318077803201']
# ['At iteration 27 the best fitness is 0.03753318077803201']
# ['At iteration 28 the best fitness is 0.03753318077803201']
# ['At iteration 29 the best fitness is 0.03753318077803201']
#       Selected: 1977/3933 (50.3%), Fitness: 0.0375, Time: 499.3s
#       Modality: D=47%, S=49%, Sk=51%, V=50%
#     Test Acc: 92.59%, F1: 92.35%, Features: 1977/3933 (50.3%), Model: 4.402MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05013628273582502']
# ['At iteration 2 the best fitness is 0.05013628273582502']
# ['At iteration 3 the best fitness is 0.04427332824815664']
# ['At iteration 4 the best fitness is 0.04427332824815664']
# ['At iteration 5 the best fitness is 0.04427332824815664']
# ['At iteration 6 the best fitness is 0.04427332824815664']
# ['At iteration 7 the best fitness is 0.04427332824815664']
# ['At iteration 8 the best fitness is 0.04427332824815664']
# ['At iteration 9 the best fitness is 0.044184337655733555']
# ['At iteration 10 the best fitness is 0.044184337655733555']
# ['At iteration 11 the best fitness is 0.044184337655733555']
# ['At iteration 12 the best fitness is 0.044184337655733555']
# ['At iteration 13 the best fitness is 0.044184337655733555']
# ['At iteration 14 the best fitness is 0.044184337655733555']
# ['At iteration 15 the best fitness is 0.044184337655733555']
# ['At iteration 16 the best fitness is 0.044184337655733555']
# ['At iteration 17 the best fitness is 0.044184337655733555']
# ['At iteration 18 the best fitness is 0.044184337655733555']
# ['At iteration 19 the best fitness is 0.04400635647088738']
# ['At iteration 20 the best fitness is 0.038092550216119986']
# ['At iteration 21 the best fitness is 0.038092550216119986']
# ['At iteration 22 the best fitness is 0.0377620137299771']
# ['At iteration 23 the best fitness is 0.0377620137299771']
# ['At iteration 24 the best fitness is 0.0377620137299771']
# ['At iteration 25 the best fitness is 0.0377620137299771']
# ['At iteration 26 the best fitness is 0.0377620137299771']
# ['At iteration 27 the best fitness is 0.0377620137299771']
# ['At iteration 28 the best fitness is 0.0377620137299771']
# ['At iteration 29 the best fitness is 0.0377620137299771']
#       Selected: 2006/3933 (51.0%), Fitness: 0.0378, Time: 473.0s
#       Modality: D=53%, S=49%, Sk=51%, V=51%
#     Test Acc: 87.04%, F1: 85.51%, Features: 2006/3933 (51.0%), Model: 4.459MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.051216882786676785']
# ['At iteration 2 the best fitness is 0.03811797609966944']
# ['At iteration 3 the best fitness is 0.03811797609966944']
# ['At iteration 4 the best fitness is 0.03811797609966944']
# ['At iteration 5 the best fitness is 0.03811797609966944']
# ['At iteration 6 the best fitness is 0.03811797609966944']
# ['At iteration 7 the best fitness is 0.03811797609966944']
# ['At iteration 8 the best fitness is 0.03811797609966944']
# ['At iteration 9 the best fitness is 0.03811797609966944']
# ['At iteration 10 the best fitness is 0.03811797609966944']
# ['At iteration 11 the best fitness is 0.03811797609966944']
# ['At iteration 12 the best fitness is 0.03811797609966944']
# ['At iteration 13 the best fitness is 0.03811797609966944']
# ['At iteration 14 the best fitness is 0.03811797609966944']
# ['At iteration 15 the best fitness is 0.03811797609966944']
# ...
# ['At iteration 16 the best fitness is 0.04702161200101699']
# ['At iteration 17 the best fitness is 0.04702161200101699']
# ['At iteration 18 the best fitness is 0.04702161200101699']
# ['At iteration 19 the best fitness is 0.04702161200101699']
# ['At iteration 20 the best fitness is 0.04702161200101699']
# ['At iteration 21 the best fitness is 0.04702161200101699']
# ['At iteration 22 the best fitness is 0.04702161200101699']
# ['At iteration 23 the best fitness is 0.04702161200101699']
# ['At iteration 24 the best fitness is 0.04702161200101699']
# ['At iteration 25 the best fitness is 0.04702161200101699']
# ['At iteration 26 the best fitness is 0.04702161200101699']
# ['At iteration 27 the best fitness is 0.04702161200101699']
# ['At iteration 28 the best fitness is 0.04702161200101699']
# ['At iteration 29 the best fitness is 0.04702161200101699']
#       Selected: 1714/3933 (43.6%), Fitness: 0.0470, Time: 627.9s
#       Modality: D=44%, S=41%, Sk=45%, V=43%
#     Test Acc: 93.46%, F1: 93.11%, Features: 1714/3933 (43.6%), Model: 3.889MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05688914314772437']
# ['At iteration 1 the best fitness is 0.0501235697940503']
# ['At iteration 2 the best fitness is 0.0501235697940503']
# ['At iteration 3 the best fitness is 0.0501235697940503']
# ['At iteration 4 the best fitness is 0.0501235697940503']
# ['At iteration 5 the best fitness is 0.043612255275870856']
# ['At iteration 6 the best fitness is 0.043612255275870856']
# ['At iteration 7 the best fitness is 0.043612255275870856']
# ['At iteration 8 the best fitness is 0.043612255275870856']
# ['At iteration 9 the best fitness is 0.043612255275870856']
# ['At iteration 10 the best fitness is 0.043612255275870856']
# ['At iteration 11 the best fitness is 0.043612255275870856']
# ['At iteration 12 the best fitness is 0.043612255275870856']
# ['At iteration 13 the best fitness is 0.043612255275870856']
# ['At iteration 14 the best fitness is 0.043612255275870856']
# ['At iteration 15 the best fitness is 0.043612255275870856']
# ['At iteration 16 the best fitness is 0.043612255275870856']
# ['At iteration 17 the best fitness is 0.043612255275870856']
# ['At iteration 18 the best fitness is 0.043612255275870856']
# ['At iteration 19 the best fitness is 0.037609458428680374']
# ['At iteration 20 the best fitness is 0.037609458428680374']
# ['At iteration 21 the best fitness is 0.037609458428680374']
# ['At iteration 22 the best fitness is 0.037609458428680374']
# ['At iteration 23 the best fitness is 0.037609458428680374']
# ['At iteration 24 the best fitness is 0.037609458428680374']
# ['At iteration 25 the best fitness is 0.037609458428680374']
# ['At iteration 26 the best fitness is 0.037609458428680374']
# ['At iteration 27 the best fitness is 0.037609458428680374']
# ['At iteration 28 the best fitness is 0.037609458428680374']
# ['At iteration 29 the best fitness is 0.037609458428680374']
#       Selected: 1956/3933 (49.7%), Fitness: 0.0376, Time: 492.2s
#       Modality: D=46%, S=51%, Sk=49%, V=50%
#     Test Acc: 90.65%, F1: 89.25%, Features: 1956/3933 (49.7%), Model: 4.361MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.062103737604881804']
# ['At iteration 2 the best fitness is 0.056151792524790224']
# ['At iteration 3 the best fitness is 0.056151792524790224']
# ['At iteration 4 the best fitness is 0.056151792524790224']
# ['At iteration 5 the best fitness is 0.04376481057716758']
# ['At iteration 6 the best fitness is 0.04376481057716758']
# ['At iteration 7 the best fitness is 0.04376481057716758']
# ['At iteration 8 the best fitness is 0.04376481057716758']
# ['At iteration 9 the best fitness is 0.04376481057716758']
# ['At iteration 10 the best fitness is 0.04376481057716758']
# ['At iteration 11 the best fitness is 0.04376481057716758']
# ['At iteration 12 the best fitness is 0.04376481057716758']
# ['At iteration 13 the best fitness is 0.04376481057716758']
# ['At iteration 14 the best fitness is 0.04376481057716758']
# ['At iteration 15 the best fitness is 0.04376481057716758']
# ['At iteration 16 the best fitness is 0.04376481057716758']
# ['At iteration 17 the best fitness is 0.04376481057716758']
# ['At iteration 18 the best fitness is 0.04376481057716758']
# ['At iteration 19 the best fitness is 0.04376481057716758']
# ['At iteration 20 the best fitness is 0.04376481057716758']
# ['At iteration 21 the best fitness is 0.04376481057716758']
# ['At iteration 22 the best fitness is 0.04376481057716758']
# ['At iteration 23 the best fitness is 0.04376481057716758']
# ['At iteration 24 the best fitness is 0.04376481057716758']
# ['At iteration 25 the best fitness is 0.04376481057716758']
# ['At iteration 26 the best fitness is 0.04376481057716758']
# ['At iteration 27 the best fitness is 0.04376481057716758']
# ['At iteration 28 the best fitness is 0.04376481057716758']
# ['At iteration 29 the best fitness is 0.04376481057716758']
#       Selected: 1935/3933 (49.2%), Fitness: 0.0438, Time: 471.9s
#       Modality: D=53%, S=50%, Sk=50%, V=47%
#     Test Acc: 92.52%, F1: 91.74%, Features: 1935/3933 (49.2%), Model: 4.320MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.05639333841851003']
# ['At iteration 2 the best fitness is 0.05639333841851003']
# ['At iteration 3 the best fitness is 0.050212560386473384']
# ['At iteration 4 the best fitness is 0.050212560386473384']
# ['At iteration 5 the best fitness is 0.050212560386473384']
# ['At iteration 6 the best fitness is 0.050212560386473384']
# ['At iteration 7 the best fitness is 0.050212560386473384']
# ['At iteration 8 the best fitness is 0.050047292143401936']
# ['At iteration 9 the best fitness is 0.050047292143401936']
# ['At iteration 10 the best fitness is 0.050047292143401936']
# ['At iteration 11 the best fitness is 0.05000915331807776']
# ['At iteration 12 the best fitness is 0.05000915331807776']
# ['At iteration 13 the best fitness is 0.04354869056699722']
# ['At iteration 14 the best fitness is 0.04354869056699722']
# ['At iteration 15 the best fitness is 0.04354869056699722']
# ['At iteration 16 the best fitness is 0.04347241291634886']
# ['At iteration 17 the best fitness is 0.04342156114924996']
# ['At iteration 18 the best fitness is 0.04342156114924996']
# ['At iteration 19 the best fitness is 0.04342156114924996']
# ['At iteration 20 the best fitness is 0.04342156114924996']
# ['At iteration 21 the best fitness is 0.04342156114924996']
# ['At iteration 22 the best fitness is 0.04342156114924996']
# ['At iteration 23 the best fitness is 0.04342156114924996']
# ['At iteration 24 the best fitness is 0.04342156114924996']
# ['At iteration 25 the best fitness is 0.04342156114924996']
# ['At iteration 26 the best fitness is 0.04342156114924996']
# ['At iteration 27 the best fitness is 0.04342156114924996']
# ['At iteration 28 the best fitness is 0.04342156114924996']
# ['At iteration 29 the best fitness is 0.04342156114924996']
# ['At iteration 30 the best fitness is 0.04342156114924996']
#       Selected: 1931/3933 (49.1%), Fitness: 0.0434, Time: 483.8s
#       Modality: D=50%, S=48%, Sk=48%, V=50%
#     Test Acc: 94.39%, F1: 94.45%, Features: 1931/3933 (49.1%), Model: 4.313MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.0624342740910247']
# ['At iteration 2 the best fitness is 0.049538774472412866']
# ['At iteration 3 the best fitness is 0.049538774472412866']
# ['At iteration 4 the best fitness is 0.04309102466310706']
# ['At iteration 5 the best fitness is 0.04309102466310706']
# ['At iteration 6 the best fitness is 0.04309102466310706']
# ['At iteration 7 the best fitness is 0.04309102466310706']
# ['At iteration 8 the best fitness is 0.04309102466310706']
# ['At iteration 9 the best fitness is 0.04309102466310706']
# ['At iteration 10 the best fitness is 0.04309102466310706']
# ['At iteration 11 the best fitness is 0.04309102466310706']
# ['At iteration 12 the best fitness is 0.04273506229341471']
# ['At iteration 13 the best fitness is 0.04273506229341471']
# ['At iteration 14 the best fitness is 0.04273506229341471']
# ['At iteration 15 the best fitness is 0.04273506229341471']
# ['At iteration 16 the best fitness is 0.04273506229341471']
# ['At iteration 17 the best fitness is 0.04273506229341471']
# ['At iteration 18 the best fitness is 0.04273506229341471']
# ['At iteration 19 the best fitness is 0.04273506229341471']
# ['At iteration 20 the best fitness is 0.04273506229341471']
# ['At iteration 21 the best fitness is 0.04273506229341471']
# ['At iteration 22 the best fitness is 0.04273506229341471']
# ['At iteration 23 the best fitness is 0.04273506229341471']
# ['At iteration 24 the best fitness is 0.04273506229341471']
# ['At iteration 25 the best fitness is 0.04273506229341471']
# ['At iteration 26 the best fitness is 0.04273506229341471']
# ['At iteration 27 the best fitness is 0.04273506229341471']
# ['At iteration 28 the best fitness is 0.04273506229341471']
# ['At iteration 29 the best fitness is 0.04273506229341471']
# ['At iteration 30 the best fitness is 0.04273506229341471']
#       Selected: 1883/3933 (47.9%), Fitness: 0.0427, Time: 482.8s
#       Modality: D=46%, S=50%, Sk=47%, V=48%
#     Test Acc: 93.46%, F1: 92.91%, Features: 1883/3933 (47.9%), Model: 4.219MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.06346402237477755']
# ['At iteration 1 the best fitness is 0.054664378337147206']
# ['At iteration 2 the best fitness is 0.047682684973302775']
# ['At iteration 3 the best fitness is 0.047682684973302775']
# ['At iteration 4 the best fitness is 0.047682684973302775']
# ['At iteration 5 the best fitness is 0.047682684973302775']
# ['At iteration 6 the best fitness is 0.047682684973302775']
# ['At iteration 7 the best fitness is 0.047682684973302775']
# ['At iteration 8 the best fitness is 0.047682684973302775']
# ['At iteration 9 the best fitness is 0.04689677091278921']
# ['At iteration 10 the best fitness is 0.038173404525807225']
# ['At iteration 11 the best fitness is 0.038173404525807225']
# ['At iteration 12 the best fitness is 0.038173404525807225']
# ['At iteration 13 the best fitness is 0.038173404525807225']
# ['At iteration 14 the best fitness is 0.038173404525807225']
# ['At iteration 15 the best fitness is 0.038173404525807225']
# ['At iteration 16 the best fitness is 0.038173404525807225']
# ['At iteration 17 the best fitness is 0.038173404525807225']
# ['At iteration 18 the best fitness is 0.038173404525807225']
# ['At iteration 19 the best fitness is 0.029475464022374796']
# ['At iteration 20 the best fitness is 0.029475464022374796']
# ['At iteration 21 the best fitness is 0.029475464022374796']
# ['At iteration 22 the best fitness is 0.029475464022374796']
# ['At iteration 23 the best fitness is 0.028788965166539553']
# ['At iteration 24 the best fitness is 0.028788965166539553']
# ['At iteration 25 the best fitness is 0.028788965166539553']
# ['At iteration 26 the best fitness is 0.028788965166539553']
# ['At iteration 27 the best fitness is 0.028788965166539553']
# ['At iteration 28 the best fitness is 0.028788965166539553']
# ['At iteration 29 the best fitness is 0.028788965166539553']
#       Selected: 816/3933 (20.7%), Fitness: 0.0288, Time: 447.5s
#       Modality: D=20%, S=19%, Sk=21%, V=21%
#     Test Acc: 92.52%, F1: 91.64%, Features: 816/3933 (20.7%), Model: 2.135MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.04381566234426648']
# ['At iteration 2 the best fitness is 0.04381566234426648']
# ['At iteration 3 the best fitness is 0.04381566234426648']
# ['At iteration 4 the best fitness is 0.04381566234426648']
# ['At iteration 5 the best fitness is 0.04381566234426648']
# ['At iteration 6 the best fitness is 0.04381566234426648']
# ['At iteration 7 the best fitness is 0.04381566234426648']
# ['At iteration 8 the best fitness is 0.04381566234426648']
# ['At iteration 9 the best fitness is 0.04381566234426648']
# ['At iteration 10 the best fitness is 0.04381566234426648']
# ['At iteration 11 the best fitness is 0.04381566234426648']
# ['At iteration 12 the best fitness is 0.04381566234426648']
# ['At iteration 13 the best fitness is 0.04381566234426648']
# ['At iteration 14 the best fitness is 0.04381566234426648']
# ['At iteration 15 the best fitness is 0.04381566234426648']
# ['At iteration 16 the best fitness is 0.04381566234426648']
# ['At iteration 17 the best fitness is 0.04381566234426648']
# ['At iteration 18 the best fitness is 0.04381566234426648']
# ['At iteration 19 the best fitness is 0.04381566234426648']
# ['At iteration 20 the best fitness is 0.04381566234426648']
# ['At iteration 21 the best fitness is 0.04381566234426648']
# ['At iteration 22 the best fitness is 0.04381566234426648']
# ['At iteration 23 the best fitness is 0.04381566234426648']
# ['At iteration 24 the best fitness is 0.04381566234426648']
# ['At iteration 25 the best fitness is 0.04381566234426648']
# ['At iteration 26 the best fitness is 0.04381566234426648']
# ['At iteration 27 the best fitness is 0.04381566234426648']
# ['At iteration 28 the best fitness is 0.04381566234426648']
# ['At iteration 29 the best fitness is 0.04381566234426648']
#       Selected: 1949/3933 (49.6%), Fitness: 0.0438, Time: 1206.8s
#       Modality: D=50%, S=53%, Sk=49%, V=49%
#     Test Acc: 98.13%, F1: 98.12%, Features: 1949/3933 (49.6%), Model: 4.348MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.05611365369946605']
# ['At iteration 1 the best fitness is 0.05611365369946605']
# ['At iteration 2 the best fitness is 0.04689219425375034']
# ['At iteration 3 the best fitness is 0.04689219425375034']
# ['At iteration 4 the best fitness is 0.04689219425375034']
# ['At iteration 5 the best fitness is 0.04689219425375034']
# ['At iteration 6 the best fitness is 0.04689219425375034']
# ['At iteration 7 the best fitness is 0.04689219425375034']
# ['At iteration 8 the best fitness is 0.04689219425375034']
# ['At iteration 9 the best fitness is 0.04689219425375034']
# ['At iteration 10 the best fitness is 0.04689219425375034']
# ['At iteration 11 the best fitness is 0.04689219425375034']
# ['At iteration 12 the best fitness is 0.04689219425375034']
# ['At iteration 13 the best fitness is 0.03847622679888128']
# ['At iteration 14 the best fitness is 0.03847622679888128']
# ['At iteration 15 the best fitness is 0.03847622679888128']
# ['At iteration 16 the best fitness is 0.03847622679888128']
# ['At iteration 17 the best fitness is 0.03847622679888128']
# ['At iteration 18 the best fitness is 0.03847622679888128']
# ['At iteration 19 the best fitness is 0.03847622679888128']
# ['At iteration 20 the best fitness is 0.03847622679888128']
# ['At iteration 21 the best fitness is 0.03847622679888128']
# ['At iteration 22 the best fitness is 0.03847622679888128']
# ['At iteration 23 the best fitness is 0.03847622679888128']
# ['At iteration 24 the best fitness is 0.03847622679888128']
# ['At iteration 25 the best fitness is 0.03847622679888128']
# ['At iteration 26 the best fitness is 0.03847622679888128']
# ['At iteration 27 the best fitness is 0.03691024663107041']
# ['At iteration 28 the best fitness is 0.03691024663107041']
# ['At iteration 29 the best fitness is 0.03691024663107041']
#       Selected: 1932/3933 (49.1%), Fitness: 0.0369, Time: 452.6s
#       Modality: D=48%, S=52%, Sk=48%, V=49%
#     Test Acc: 94.39%, F1: 94.05%, Features: 1932/3933 (49.1%), Model: 4.315MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        # Add per-modality retention
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

# Save
csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_new_15_loss/all_results_per_fold.csv
# Shape: (144, 28)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  depth_retention (%)  depth_selected  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected  video_retention (%)  video_selected
# 0      baseline     1            92.5926           97.3333       92.5720          92.5720              94.1358           92.5926               3933            3933               100.0000       0.0000          9.1454          9.1454       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 1      baseline     2            90.7407           97.3333       89.7141          89.7141              93.8624           90.7407               3933            3933               100.0000       0.0000         10.0125         10.0126       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 2      baseline     3            78.7037           98.0000       76.2191          76.2191              79.3563           78.7037               3933            3933               100.0000       0.0000         10.1839         10.1839       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 3      baseline     4            79.6296           96.6667       79.6572          79.6572              87.0635           79.6296               3933            3933               100.0000       0.0000         10.5526         10.5526       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 4      baseline     5            76.8519           98.6667       75.4161          75.4161              80.1675           76.8519               3933            3933               100.0000       0.0000          9.9258          9.9258       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 5      baseline     6            85.0467           98.0000       82.9199          82.7603              85.1411           85.1852               3933            3933               100.0000       0.0000          9.8209          9.8210       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 6      baseline     7            90.6542           97.3333       90.9024          90.8174              93.5185           90.7407               3933            3933               100.0000       0.0000         10.0668         10.0668       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 7      baseline     8            92.5234           97.3333       92.2663          92.3810              94.3827           92.2840               3933            3933               100.0000       0.0000          9.7438          9.7438       2154011           8.2228                25.8355                 25.8355                 0.0000        67.0527             100.0000             216              100.0000              652                100.0000               1645             100.0000            1420
# 8   mutual_info     1            95.3704           98.0000       94.7101          94.7101              96.9312           95.3704               1966            3933                49.9873      21.7393          7.6913         29.4307       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              18.9815              41               70.7055              461                 32.6444                537              65.2817             927
# 9   mutual_info     2            86.1111           98.0000       85.1627          85.1627              90.8818           86.1111               1966            3933                49.9873      21.5050          6.4282         27.9333       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              18.5185              40               69.6319              454                 33.6170                553              64.7183             919
# 10  mutual_info     3            84.2593           96.6667       83.7577          83.7577              86.6843           84.2593               1966            3933                49.9873      21.3512          7.5799         28.9312       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              17.1296              37               69.0184              450                 33.6778                554              65.1408             925
# 11  mutual_info     4            79.6296           97.3333       78.4549          78.4549              87.1781           79.6296               1966            3933                49.9873      21.3696          8.0734         29.4431       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              18.0556              39               69.0184              450                 34.5289                568              64.0141             909
# 12  mutual_info     5            91.6667           97.3333       90.8535          90.8535              94.2152           91.6667               1966            3933                49.9873      21.2703          7.7949         29.0653       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              17.1296              37               69.4785              453                 33.7994                556              64.7887             920
# 13  mutual_info     6            91.5888           98.0000       91.0299          90.9460              94.2152           91.6667               1966            3933                49.9873      21.2846          7.8139         29.0986       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              20.8333              45               70.2454              458                 33.5562                552              64.1549             911
# 14  mutual_info     7            86.9159           96.6667       86.3257          86.1979              91.4815           87.0370               1966            3933                49.9873      21.0739          7.9189         28.9929       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              18.9815              41               68.7117              448                 34.4073                566              64.1549             911
# 15  mutual_info     8            90.6542           97.3333       90.1961          90.2380              93.9242           90.7407               1966            3933                49.9873      21.3761          7.6642         29.0404       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              19.9074              43               71.1656              464                 34.1641                562              63.1690             897
# 16          rfe     1            97.2222           97.3333       97.2262          97.2262              98.4127           97.2222               1966            3933                49.9873       4.1087          8.0521         12.1610       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727              89.3519             193               67.4847              440                 28.6322                471              60.7042             862
# 17          rfe     2            87.0370           98.0000       86.0368          86.0368              91.3316           87.0370               1966            3933                49.9873       4.0147          7.3910         11.4060       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727             100.0000             216               60.4294              394                 30.3951                500              60.2817             856
# 18          rfe     3            80.5556           97.3333       79.0528          79.0528              83.1452           80.5556               1966            3933                49.9873       4.0611          7.7799         11.8412       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727             100.0000             216               66.2577              432                 32.5228                535              55.1408             783
# 19          rfe     4            87.9630           98.0000       88.2216          88.2216              92.6543           87.9630               1966            3933                49.9873       3.9460          9.0075         12.9538       1146907           4.3810                25.8355                 12.9145                50.0127        44.4727             100.0000             216               61.8098              403                 28.0243                461              62.3944             886

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              85.84              6.64              84.96              7.26                 3933.00                      100.00              0.00                 9.93                 9.93          2154011.0                  8.22                        0.00               67.05
# mutual_info              88.27              5.01              87.56              5.15                 1966.00                       49.99             21.37                 7.62                28.99          1146907.0                  4.38                       50.01               44.47
#         rfe              86.77              7.10              86.25              7.22                 1966.00                       49.99              4.03                 7.94                11.97          1146907.0                  4.38                       50.01               44.47
#       lasso              65.77             15.33              62.94             14.92                 1966.00                       49.99              1.23                 7.82                 9.05          1146907.0                  4.38                       50.01               44.47
#    meta_BAT              87.23              4.77              86.03              5.19                 1954.00                       49.68            496.84                 7.94               504.77          1140763.0                  4.36                       50.32               44.51
#     meta_CS              82.48             13.08              81.90             12.01                 1951.25                       49.61            983.11                 7.95               991.07          1139355.0                  4.35                       50.39               44.51
#     meta_DE              85.26              4.19              84.05              4.73                 1935.75                       49.22            498.45                 7.94               506.39          1131419.0                  4.32                       50.78               44.47
#    meta_FFA              83.76              6.24              82.02              7.14                 1956.62                       49.75            480.44                 7.94               488.39          1142107.0                  4.36                       50.25               44.51
#     meta_GA              90.14              4.10              89.59              4.39                 1962.62                       49.90            480.92                 7.97               488.89          1145179.0                  4.37                       50.10               44.52
#    meta_GWO              84.34              8.15              82.83              8.82                 1589.00                       40.40            471.71                 7.58               479.30           953883.0                  3.64                       59.60               39.53
#    meta_HHO              78.42             18.85              77.60             19.33                 1274.38                       32.40            604.66                 7.33               612.00           792795.0                  3.03                       67.60               36.25
#   meta_JAYA              85.72              5.80              84.80              6.17                 1956.88                       49.76            496.87                 7.93               504.80          1142235.0                  4.36                       50.24               44.49
#    meta_MFO              85.61              4.17              84.64              4.36                 1972.25                       50.15            472.60                 7.97               480.57          1150107.0                  4.39                       49.85               44.54
#    meta_MVO              86.30              5.41              85.04              6.00                 1949.25                       49.56            485.72                 7.93               493.66          1138331.0                  4.35                       50.44               44.51
#    meta_PSO              85.61              6.15              84.75              6.17                 1924.50                       48.93            484.76                 7.86               492.62          1125659.0                  4.30                       51.07               44.47
#    meta_SCA              84.09              4.30              82.93              4.96                 1009.88                       25.68            442.66                 7.03               449.69           657371.0                  2.51                       74.32               32.54
#    meta_SSA              83.65             13.90              83.23             13.91                 1950.38                       49.59           1208.46                 7.89              1216.35          1138907.0                  4.35                       50.41               44.50
#    meta_WOA              87.69              4.66              86.99              4.87                 1284.50                       32.66            436.00                 7.32               443.32           797979.0                  3.05                       67.34               36.29

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 88.27% vs Baseline: 85.84%
#   Paired t-test: t=1.0640, p=0.3226
#   Wilcoxon test: W=8.0000, p=0.3750
#   -> better, Not significant
#
# RFE vs BASELINE:
#   Method: 86.77% vs Baseline: 85.84%
#   Paired t-test: t=0.6117, p=0.5601
#   Wilcoxon test: W=15.0000, p=0.7422
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 65.77% vs Baseline: 85.84%
#   Paired t-test: t=-4.7202, p=0.0022
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_BAT vs BASELINE:
#   Method: 87.23% vs Baseline: 85.84%
#   Paired t-test: t=0.7569, p=0.4738
#   Wilcoxon test: W=14.0000, p=0.6406
#   -> better, Not significant
#
# META_CS vs BASELINE:
#   Method: 82.48% vs Baseline: 85.84%
#   Paired t-test: t=-1.0081, p=0.3470
#   Wilcoxon test: W=5.0000, p=0.6250
#   -> worse, Not significant
#
# META_DE vs BASELINE:
#   Method: 85.26% vs Baseline: 85.84%
#   Paired t-test: t=-0.5033, p=0.6302
#   Wilcoxon test: W=12.0000, p=0.4609
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 83.76% vs Baseline: 85.84%
#   Paired t-test: t=-1.6519, p=0.1425
#   Wilcoxon test: W=5.5000, p=0.1719
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 90.14% vs Baseline: 85.84%
#   Paired t-test: t=2.0673, p=0.0775
#   Wilcoxon test: W=4.5000, p=0.0625
#   -> better, Not significant
#
# META_GWO vs BASELINE:
#   Method: 84.34% vs Baseline: 85.84%
#   Paired t-test: t=-1.1124, p=0.3027
#   Wilcoxon test: W=6.0000, p=0.2344
#   -> worse, Not significant
#
# META_HHO vs BASELINE:
#   Method: 78.42% vs Baseline: 85.84%
#   Paired t-test: t=-1.3435, p=0.2210
#   Wilcoxon test: W=10.0000, p=0.3125
#   -> worse, Not significant
#
# META_JAYA vs BASELINE:
#   Method: 85.72% vs Baseline: 85.84%
#   Paired t-test: t=-0.0907, p=0.9303
#   Wilcoxon test: W=16.5000, p=0.8672
#   -> worse, Not significant
#
# META_MFO vs BASELINE:
#   Method: 85.61% vs Baseline: 85.84%
#   Paired t-test: t=-0.1608, p=0.8768
#   Wilcoxon test: W=12.5000, p=0.8438
#   -> worse, Not significant
#
# META_MVO vs BASELINE:
#   Method: 86.30% vs Baseline: 85.84%
#   Paired t-test: t=0.3452, p=0.7401
#   Wilcoxon test: W=15.5000, p=0.7656
#   -> better, Not significant
#
# META_PSO vs BASELINE:
#   Method: 85.61% vs Baseline: 85.84%
#   Paired t-test: t=-0.1831, p=0.8599
#   Wilcoxon test: W=17.5000, p=0.9844
#   -> worse, Not significant
#
# META_SCA vs BASELINE:
#   Method: 84.09% vs Baseline: 85.84%
#   Paired t-test: t=-0.7098, p=0.5008
#   Wilcoxon test: W=9.5000, p=0.5000
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 83.65% vs Baseline: 85.84%
#   Paired t-test: t=-0.6650, p=0.5273
#   Wilcoxon test: W=14.0000, p=1.0000
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 87.69% vs Baseline: 85.84%
#   Paired t-test: t=1.1538, p=0.2865
#   Wilcoxon test: W=9.0000, p=0.4688
#   -> better, Not significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_new_15_loss
#
# Per-method folders:
#   results_new_15_loss/baseline/ (16 files)
#   results_new_15_loss/mutual_info/ (16 files)
#   results_new_15_loss/rfe/ (16 files)
#   results_new_15_loss/lasso/ (16 files)
#   results_new_15_loss/meta_BAT/ (16 files)
#   results_new_15_loss/meta_CS/ (16 files)
#   results_new_15_loss/meta_DE/ (16 files)
#   results_new_15_loss/meta_FFA/ (16 files)
#   results_new_15_loss/meta_GA/ (16 files)
#   results_new_15_loss/meta_GWO/ (16 files)
#   results_new_15_loss/meta_HHO/ (16 files)
#   results_new_15_loss/meta_JAYA/ (16 files)
#   results_new_15_loss/meta_MFO/ (16 files)
#   results_new_15_loss/meta_MVO/ (16 files)
#   results_new_15_loss/meta_PSO/ (16 files)
#   results_new_15_loss/meta_SCA/ (16 files)
#   results_new_15_loss/meta_SSA/ (16 files)
#   results_new_15_loss/meta_WOA/ (16 files)
#
# Plots directory: results_new_15_loss/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_results_per_fold.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   meta_GA             : 90.14% ± 4.10% (Features: 49.9%)
#   mutual_info         : 88.27% ± 5.01% (Features: 50.0%)
#   meta_WOA            : 87.69% ± 4.66% (Features: 32.7%)
#   meta_BAT            : 87.23% ± 4.77% (Features: 49.7%)
#   rfe                 : 86.77% ± 7.10% (Features: 50.0%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: Test Accuracy & Feature Retention
# ============================================================================

# Identify metaheuristic-only methods
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())  # ['depth', 'sensor', 'skeleton', 'video']

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)")
print("=" * 90)

best_per_fold = []  # collect per-fold best results

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    # Extract modality-wise retention
    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    # Print per-fold info
    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

# Build DataFrame
df_best_meta = pd.DataFrame(best_per_fold)

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
std_test_acc = df_best_meta['Test Accuracy (%)'].std()
avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
std_feat_ret = df_best_meta['Feature Retention (%)'].std()

print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

print(f"\n  Average Modality-wise Feature Retention:")
for mod in modality_names:
    col = f'{mod} Retention (%)'
    avg_mod = df_best_meta[col].mean()
    std_mod = df_best_meta[col].std()
    print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)
display_cols = ['Fold', 'Best Metaheuristic', 'Test Accuracy (%)', 'Feature Retention (%)']
display_cols += [f'{mod} Retention (%)' for mod in modality_names]
print(df_best_meta[display_cols].to_string(index=False, float_format='%.2f'))

# Save to CSV
csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best_meta.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest test accuracy)
# ==========================================================================================
#
#   Fold 1: Best = meta_WOA
#     Test Accuracy:      92.59%
#     Feature Retention:  25.12% (988/3933)
#     Modality Retention: depth=24.1%, sensor=25.3%, skeleton=25.5%, video=24.7%
#
#   Fold 2: Best = meta_JAYA
#     Test Accuracy:      92.59%
#     Feature Retention:  50.27% (1977/3933)
#     Modality Retention: depth=47.2%, sensor=49.4%, skeleton=50.8%, video=50.5%
#
#   Fold 3: Best = meta_DE
#     Test Accuracy:      84.26%
#     Feature Retention:  48.18% (1895/3933)
#     Modality Retention: depth=48.1%, sensor=44.6%, skeleton=49.0%, video=48.9%
#
#   Fold 4: Best = meta_GA
#     Test Accuracy:      90.74%
#     Feature Retention:  50.52% (1987/3933)
#     Modality Retention: depth=46.3%, sensor=49.8%, skeleton=50.0%, video=52.1%
#
#   Fold 5: Best = meta_GA
#     Test Accuracy:      89.81%
#     Feature Retention:  48.82% (1920/3933)
#     Modality Retention: depth=49.1%, sensor=47.5%, skeleton=49.8%, video=48.2%
#
#   Fold 6: Best = meta_GA
#     Test Accuracy:      89.72%
#     Feature Retention:  50.17% (1973/3933)
#     Modality Retention: depth=53.7%, sensor=50.3%, skeleton=50.8%, video=48.9%
#
#   Fold 7: Best = meta_GA
#     Test Accuracy:      91.59%
#     Feature Retention:  48.44% (1905/3933)
#     Modality Retention: depth=50.5%, sensor=51.1%, skeleton=48.0%, video=47.5%
#
#   Fold 8: Best = meta_GA
#     Test Accuracy:      98.13%
#     Feature Retention:  49.73% (1956/3933)
#     Modality Retention: depth=54.2%, sensor=51.8%, skeleton=49.4%, video=48.5%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average Test Accuracy:     91.18% ± 3.86%
#   Average Feature Retention: 46.41% ± 8.65%
#
#   Average Modality-wise Feature Retention:
#          depth: 46.64% ± 9.55%
#         sensor: 46.24% ± 8.76%
#       skeleton: 46.65% ± 8.58%
#          video: 46.16% ± 8.79%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  Test Accuracy (%)  Feature Retention (%)  depth Retention (%)  sensor Retention (%)  skeleton Retention (%)  video Retention (%)
#     1           meta_WOA              92.59                  25.12                24.07                 25.31                   25.53                24.72
#     2          meta_JAYA              92.59                  50.27                47.22                 49.39                   50.82                50.49
#     3            meta_DE              84.26                  48.18                48.15                 44.63                   49.00                48.87
#     4            meta_GA              90.74                  50.52                46.30                 49.85                   49.97                52.11
#     5            meta_GA              89.81                  48.82                49.07                 47.55                   49.79                48.24
#     6            meta_GA              89.72                  50.17                53.70                 50.31                   50.76                48.87
#     7            meta_GA              91.59                  48.44                50.46                 51.07                   47.96                47.46
#     8            meta_GA              98.13                  49.73                54.17                 51.84                   49.36                48.52
#
# Saved to: results_new_15_loss/best_metaheuristic_per_fold.csv
