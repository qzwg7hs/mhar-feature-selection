# %% [markdown]
# # MM-Fit: Comprehensive Per-Fold Feature Selection Comparison
# # **Transformer Encoder (Modality-Token) Model**
#
# This notebook compares **17 feature selection methods** across all 8 LOSO folds (treated individually):
#
# **Standard Methods:**
# 1. Mutual Information (filter)
# 2. RFE (wrapper)
# 3. LASSO/L1 (embedded)
#
# **14 EvoloPy Metaheuristics:**
# BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA
#
# **Model:** Transformer Encoder with modality tokens — each modality (sensor, skeleton) is treated as a separate token.
# Feature selection masks are applied per-modality before projection.

# %%
import torch
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA, SparsePCA
try:
    import umap
except ImportError:
    umap = None  # install with: pip install umap-learn
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Master output directory
RESULTS_ROOT = Path("results_transformer")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters
N_FOLDS = 10
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

DEPTH_PCA_DIM = 512

DEPTH_DR_METHOD = 'kernel_pca'

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of features)
TARGET_FEATURE_PERCENTAGE = 0.5

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

ALL_METHODS = ['baseline', 'mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection: {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Total methods (incl. baseline): {len(ALL_METHODS)}")
# Out:
# Configuration:
#   N_FOLDS: 10
#   N_EPOCHS: 300
#   Target feature selection: 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Total methods (incl. baseline): 18

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "participants.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions from first sample
first_sample = X_feat[0]
MODALITY_KEYS = ['sensor_feat', 'skeleton_feat']
MODALITY_NAMES = ['sensor', 'skeleton']

RAW_FEATURE_DIMS = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    RAW_FEATURE_DIMS[name] = first_sample[key].shape[0]

# Store per-modality arrays (N_samples x D_modality)
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions:")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  TOTAL: {sum(RAW_FEATURE_DIMS.values())}")
# Out:
# Loaded 616 samples
# Number of classes: 10
# Number of subjects: 10
#
# Raw feature dimensions:
#   sensor: 4480
#   skeleton: 1879
#   TOTAL: 6359

# %% [markdown]
# ## Neural Network Model (Transformer Encoder with Modality Tokens)

# %%
import math

class MultiModalDataset(Dataset):
    """Dataset that returns per-modality features as separate tensors + label."""
    def __init__(self, X_feat_list, labels, feature_dims, feature_mask=None):
        """
        X_feat_list : list of dicts with keys 'sensor_feat', 'skeleton_feat'
        labels      : np.array of int labels
        feature_dims: dict {modality_name: dim} — used to split a unified masked vector
        feature_mask: optional boolean mask over the concatenated feature vector
        """
        self.labels = torch.LongTensor(labels)
        self.modality_names = list(feature_dims.keys())  # fixed order

        # Build per-modality arrays
        modality_arrays = {m: [] for m in self.modality_names}

        for sample in X_feat_list:
            concat = np.concatenate([
                sample['sensor_feat'],
                sample['skeleton_feat']
            ])
            if feature_mask is not None:
                concat = concat[feature_mask]

            # Split back into per-modality chunks
            # When a mask is applied, we need per-modality sizes from the mask
            if feature_mask is not None:
                start = 0
                for m_name in self.modality_names:
                    m_dim = feature_dims[m_name]  # original dim
                    modality_arrays[m_name].append(concat[start:start + m_dim])
                    start += m_dim
            else:
                start = 0
                for m_name in self.modality_names:
                    m_dim = feature_dims[m_name]
                    modality_arrays[m_name].append(concat[start:start + m_dim])
                    start += m_dim

        self.modality_tensors = {}
        for m_name in self.modality_names:
            self.modality_tensors[m_name] = torch.FloatTensor(np.array(modality_arrays[m_name]))

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        # Return dict of modality tensors + label
        mod_feats = {m: self.modality_tensors[m][idx] for m in self.modality_names}
        return mod_feats, self.labels[idx]


class MultiModalDatasetFromUnified(Dataset):
    """Dataset that takes a pre-built unified (and optionally masked) numpy array
    and splits it back into per-modality chunks for the Transformer.
    This is the drop-in replacement used wherever the original code passes
    a unified numpy matrix (after scaling, after feature selection, etc.)."""

    def __init__(self, X_unified, labels, modality_dims_after_mask):
        """
        X_unified              : np.array (N, total_selected_features)
        labels                 : np.array (N,)
        modality_dims_after_mask: dict {modality: dim_after_mask} — how many features
                                  each modality contributes AFTER masking
        """
        self.labels = torch.LongTensor(labels)
        self.modality_names = list(modality_dims_after_mask.keys())

        self.modality_tensors = {}
        start = 0
        for m_name in self.modality_names:
            m_dim = modality_dims_after_mask[m_name]
            self.modality_tensors[m_name] = torch.FloatTensor(X_unified[:, start:start + m_dim])
            start += m_dim

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        mod_feats = {m: self.modality_tensors[m][idx] for m in self.modality_names}
        return mod_feats, self.labels[idx]


def get_modality_dims_after_mask(feature_mask, feature_dims):
    """Given a boolean mask over the concatenated feature vector,
    compute how many features survive per modality."""
    dims = {}
    start = 0
    for m_name, m_dim in feature_dims.items():
        dims[m_name] = int(np.sum(feature_mask[start:start + m_dim]))
        start += m_dim
    return dims


class ModalityTokenTransformer(nn.Module):
    """
    Transformer Encoder that treats each modality as a separate token.

    1. Each modality is projected to a shared embedding dimension via a
       modality-specific linear layer.
    2. A learnable modality-type embedding is added.
    3. A learnable [CLS] token is prepended.
    4. Tokens pass through a standard Transformer encoder.
    5. The [CLS] output is fed to a classification head.
    """

    def __init__(self, modality_dims, num_classes, d_model=128, nhead=4,
                 num_layers=2, dim_feedforward=256, dropout=0.3):
        """
        modality_dims : dict {modality_name: feature_dim_after_mask}
                        e.g. {'depth': 512, 'sensor': 60, 'skeleton': 200, 'video': 512}
        """
        super().__init__()
        self.modality_names = list(modality_dims.keys())
        self.d_model = d_model
        self.num_modalities = len(self.modality_names)

        # Per-modality projection to d_model
        self.modality_projections = nn.ModuleDict()
        for m_name, m_dim in modality_dims.items():
            if m_dim > 0:
                self.modality_projections[m_name] = nn.Sequential(
                    nn.Linear(m_dim, d_model),
                    nn.LayerNorm(d_model),
                    nn.ReLU(),
                    nn.Dropout(dropout),
                )
            else:
                # If mask removed all features from this modality, use a dummy
                self.modality_projections[m_name] = None

        # Learnable modality-type embeddings (one per modality)
        self.modality_embeddings = nn.Embedding(self.num_modalities, d_model)

        # Learnable [CLS] token
        self.cls_token = nn.Parameter(torch.randn(1, 1, d_model) * 0.02)

        # Transformer encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
            activation='gelu',
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer, num_layers=num_layers
        )

        # Classification head (from [CLS] token)
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model // 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, num_classes),
        )

    def forward(self, modality_dict):
        """
        modality_dict: dict {modality_name: tensor (B, m_dim)}
        Returns: logits (B, num_classes)
        """
        batch_size = None
        tokens = []

        for idx, m_name in enumerate(self.modality_names):
            proj = self.modality_projections[m_name]
            if proj is None:
                continue  # skip modalities with 0 features after masking

            x = modality_dict[m_name]  # (B, m_dim)
            if batch_size is None:
                batch_size = x.size(0)

            token = proj(x)  # (B, d_model)
            # Add modality embedding
            mod_emb = self.modality_embeddings(
                torch.tensor(idx, device=x.device)
            )  # (d_model,)
            token = token + mod_emb  # (B, d_model)
            tokens.append(token.unsqueeze(1))  # (B, 1, d_model)

        if len(tokens) == 0:
            # Edge case: all modalities masked out
            # Return uniform logits
            device = self.cls_token.device
            return torch.zeros(batch_size or 1, self.classifier[-1].out_features, device=device)

        # Concatenate modality tokens: (B, num_active_modalities, d_model)
        tokens = torch.cat(tokens, dim=1)

        # Prepend [CLS] token
        cls = self.cls_token.expand(tokens.size(0), -1, -1)  # (B, 1, d_model)
        tokens = torch.cat([cls, tokens], dim=1)  # (B, 1 + num_mod, d_model)

        # Transformer
        encoded = self.transformer_encoder(tokens)  # (B, 1 + num_mod, d_model)

        # Take [CLS] output
        cls_output = encoded[:, 0, :]  # (B, d_model)

        return self.classifier(cls_output)


print("Transformer Encoder (Modality-Token) model defined")
print("Datasets: MultiModalDatasetFromUnified, MultiModalDataset")
# Out:
# Transformer Encoder (Modality-Token) model defined
# Datasets: MultiModalDatasetFromUnified, MultiModalDataset

# %% [markdown]
# ## Helper Functions

# %%
def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> PCA on depth -> concatenate.

    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA (needed for retention calc)
        pca_obj: fitted PCA object (or None) for reference
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    scalers = {}
    pca_obj = None
    feature_dims = {}

    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]

        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]

        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)
        scalers[name] = scaler

        # Dimensionality reduction on depth only (method chosen by DEPTH_DR_METHOD)
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            dr_method = DEPTH_DR_METHOD.lower()

            if dr_method == 'kernel_pca':
                # ── Kernel PCA (non-linear, rbf kernel) ────────────────────
                pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                    random_state=42, n_jobs=-1)
                X_tr = pca_obj.fit_transform(X_tr)
                X_v  = pca_obj.transform(X_v)
                X_te = pca_obj.transform(X_te)
                print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

            else:
                raise ValueError(f"Unknown DEPTH_DR_METHOD: '{DEPTH_DR_METHOD}'.")

        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]

    # Concatenate: sensor | skeleton 
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)

    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " +
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")

    return X_train, X_val, X_test, feature_dims, pca_obj


def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector (legacy, used for masks)"""
    unified_features = []

    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])

        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]

        unified_features.append(feat_vector)

    return np.array(unified_features)


def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}

    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100

        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx

    return retention


def build_transformer_dataloader(X_unified, y, feature_mask, feature_dims, batch_size, shuffle=False):
    """Build a DataLoader that feeds the Transformer model from unified numpy arrays.

    This splits the unified (and optionally masked) feature vector back into
    per-modality chunks so the Transformer can process each as a token.
    """
    mod_dims = get_modality_dims_after_mask(feature_mask, feature_dims)
    dataset = MultiModalDatasetFromUnified(X_unified, y, mod_dims)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)


def collate_modality_batch_to_device(batch, device):
    """Move a modality-dict batch to device."""
    mod_feats, labels = batch
    mod_feats = {k: v.to(device) for k, v in mod_feats.items()}
    labels = labels.to(device)
    return mod_feats, labels


def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, lr):
    """Train model and return metrics"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    model.train()
    for epoch in range(num_epochs):
        for batch in train_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            optimizer.zero_grad()
            outputs = model(mod_feats)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

    # Evaluate
    model.eval()
    with torch.no_grad():
        # Validation
        val_preds, val_true = [], []
        for batch in val_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            outputs = model(mod_feats)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.cpu().numpy())
        val_acc = accuracy_score(val_true, val_preds)

        # Test
        test_preds, test_true = [], []
        for batch in test_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            outputs = model(mod_feats)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.cpu().numpy())
        test_acc = accuracy_score(test_true, test_preds)

    return val_acc, test_acc


def count_model_parameters(model):
    """Count trainable parameters in a model"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def get_model_size_mb(model):
    """Get model size in MB"""
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)


def get_gpu_memory_mb():
    """Get current GPU memory usage in MB"""
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0


def get_dataset_size_mb(X):
    """Get dataset size in MB"""
    return X.nbytes / (1024 ** 2)


print("Helper functions defined (with per-modality normalization + depth KernelPCA)")
# Out:
# Helper functions defined (with per-modality normalization + depth KernelPCA)

# %% [markdown]
# ## Enhanced Evaluation (returns full metrics per fold)

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Track GPU memory before training
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for batch in train_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            optimizer.zero_grad()
            outputs = model(mod_feats)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        # Check validation accuracy after each epoch
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for batch in val_loader:
                mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
                outputs = model(mod_feats)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())

    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    # Restore best model
    model.load_state_dict(best_model_state)

    # Final evaluation
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for batch in val_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            outputs = model(mod_feats)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.cpu().numpy())

        # Test
        test_preds, test_true = [], []
        for batch in test_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, DEVICE)
            outputs = model(mod_feats)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.cpu().numpy())

    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)

    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined (Transformer-compatible)")
# Out:
# Enhanced evaluation function defined (Transformer-compatible)

# %% [markdown]
# ## Feature Selection Methods
# ### 0. EvoloPy Metaheuristics

# %%
# ============================================================================
# EXACT EVOLOPY BAT IMPLEMENTATION FROM ORIGINAL CODE
# (Updated for Transformer Encoder model)
# ============================================================================

def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation (Transformer-compatible)"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    best_val_loss = float('inf')
    best_val_acc = 0.0

    for epoch in range(epochs):
        model.train()
        for batch in train_loader:
            mod_feats, labels = collate_modality_batch_to_device(batch, device)
            optimizer.zero_grad()
            loss = criterion(model(mod_feats), labels)
            loss.backward()
            optimizer.step()

        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for batch in val_loader:
                mod_feats, labels = collate_modality_batch_to_device(batch, device)
                outputs = model(mod_feats)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)

        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc

    return best_val_loss, best_val_acc


# ============================================================================
# FITNESS FUNCTION: Using (1 - accuracy)
# ============================================================================
# Rationale: (1 - accuracy) is preferred over loss because:
#   - It directly optimizes the metric we care about (accuracy)
#   - It is bounded in [0, 1], making it cleaner for metaheuristic optimization
#   - Loss can vary in scale across different feature subsets
#   - Accuracy-based fitness is more interpretable and comparable across methods
#   - Less sensitive to calibration issues of the neural network

def create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Create fitness function for EvoloPy using (1 - accuracy) + feature penalty"""
    eval_count = [0]  # track evaluations

    # Use passed feature_dims if available, otherwise fall back to global FEATURE_DIMS
    fold_feature_dims = feature_dims if feature_dims is not None else FEATURE_DIMS

    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0

            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]

            # Get per-modality dims after this mask
            mod_dims = get_modality_dims_after_mask(binary_mask, fold_feature_dims)

            train_dataset = MultiModalDatasetFromUnified(X_tr_sel, y_train, mod_dims)
            val_dataset = MultiModalDatasetFromUnified(X_val_sel, y_val, mod_dims)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

            model = ModalityTokenTransformer(mod_dims, num_classes).to(DEVICE)

            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )

            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()

            eval_count[0] += 1

            # Weighted fitness: accuracy + feature reduction pressure
            alpha = 0.95  # weight for accuracy
            beta = 0.05   # weight for feature reduction
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness

        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0

    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run any EvoloPy optimizer generically"""
    print(f"    Running EvoloPy {optimizer_name}...")
    print(f"      Fitness: (1 - accuracy), Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")

    n_feats = total_features if total_features is not None else X_train.shape[1]
    fitness_func = create_fitness_function_evolopy(X_train, y_train, X_val, y_val, num_classes, n_feats, feature_dims)

    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_feats, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start

    binary_mask = solution.bestIndividual > 0.5
    feat_dims = feature_dims if feature_dims is not None else RAW_FEATURE_DIMS
    modality_ret = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_ret,
        'method': f'meta_{optimizer_name}'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    print(f"      Modality:"
          f"S={modality_ret['sensor']['percentage']:.0f}%, "
          f"Sk={modality_ret['skeleton']['percentage']:.0f}%, ")

    return results


print("All EvoloPy metaheuristic runners defined (Transformer model)")
print(f"Available optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
# Out:
# All EvoloPy metaheuristic runners defined (Transformer model)
# Available optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']

# %% [markdown]
# ### 1-3. Standard Feature Selection Methods (Mutual Info, RFE, LASSO)

# %%
def run_mutual_info_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run Mutual Information feature selection"""
    print("    Running Mutual Information...")

    start_time = time.time()

    # Calculate mutual information scores
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)

    # Select top k features (target percentage)
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_k_indices = np.argsort(mi_scores)[::-1][:k]

    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_k_indices] = True

    execution_time = time.time() - start_time

    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'mi_scores': mi_scores,
        'method': 'mutual_info'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results


def run_rfe_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run RFE feature selection"""
    print("    Running RFE...")

    start_time = time.time()

    # Use Random Forest as base estimator
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)

    # Select top k features
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    k = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    selector = RFE(estimator, n_features_to_select=k, step=50)  # Remove 50 features at a time
    selector.fit(X_train, y_train)

    binary_mask = selector.support_

    execution_time = time.time() - start_time

    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'ranking': selector.ranking_,
        'method': 'rfe'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results


def run_lasso_fs(X_train, y_train, X_val, y_val, num_classes, total_features=None, feature_dims=None):
    """Run LASSO feature selection"""
    print("    Running LASSO...")
    start_time = time.time()

    # Train Lasso to get feature importance scores
    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='saga',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    # Rank features by coefficient magnitude across all classes
    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    # Select top-k features to match target percentage
    n_feats = total_features if total_features is not None else TOTAL_FEATURES
    target_count = int(n_feats * TARGET_FEATURE_PERCENTAGE)
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_feats, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time
    feat_dims = feature_dims if feature_dims is not None else FEATURE_DIMS
    modality_retention = calculate_modality_retention(binary_mask, feat_dims)

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': len(binary_mask),
        'modality_retention': modality_retention,
        'coefficients': coef_abs,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results


print("Standard FS methods defined (Mutual Info, RFE, LASSO)")
# Out:
# Standard FS methods defined (Mutual Info, RFE, LASSO)

# %% [markdown]
# ## Main Per-Fold Experiment Runner

# %%
def run_all_methods_per_fold():
    """
    Run ALL methods across ALL folds with:
    1. Per-modality normalization (fit on train only)
    2. KernelPCA on depth modality (fit on train only)
    3. Concatenation AFTER normalization+PCA
    Uses ModalityTokenTransformer instead of SimpleNN.
    """
    print("="*80)
    print("STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS (Transformer Model)")
    print(f"Methods: baseline + 3 standard + {len(EVOLOPY_OPTIMIZERS)} metaheuristics = {len(ALL_METHODS)} total")
    print(f"Folds: {N_FOLDS}")
    print(f"Per-modality normalization: ENABLED")
    print(f"Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
    print("="*80)

    num_classes = len(np.unique(y))

    # Master results dict: {method_name: {fold_idx: {...}}}
    master_results = {m: {} for m in ALL_METHODS}

    # Build sample indices for GroupKFold
    n_samples = len(y)
    dummy_X = np.zeros((n_samples, 1))

    gkf = GroupKFold(n_splits=N_FOLDS)

    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")

        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]

        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv

        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]

        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")

        # =================================================================
        # Per-modality normalization + depth KernelPCA  (fit on train only)
        # =================================================================
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )

        fold_total_features = sum(fold_feature_dims.values())

        # Original dataset size
        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)

        # =====================================================================
        # Run each method
        # =====================================================================
        for method_name in ALL_METHODS:
            print(f"\n  --- {method_name.upper()} ---")

            fs_start_time = time.time()

            # Feature selection
            if method_name == 'baseline':
                feature_mask = np.ones(fold_total_features, dtype=bool)
                fs_results = {
                    'mask': feature_mask,
                    'execution_time': 0,
                    'num_selected': fold_total_features,
                    'num_total': fold_total_features,
                    'method': 'baseline'
                }
            elif method_name == 'mutual_info':
                fs_results = run_mutual_info_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'rfe':
                fs_results = run_rfe_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                        total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name == 'lasso':
                fs_results = run_lasso_fs(X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                          total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            elif method_name.startswith('meta_'):
                opt_name = method_name.replace('meta_', '')
                opt_func = EVOLOPY_OPTIMIZERS[opt_name]
                fs_results = run_evolopy_optimizer(opt_name, opt_func,
                                                   X_train, y[train_idx], X_val, y[val_idx], num_classes,
                                                   total_features=fold_total_features, feature_dims=fold_feature_dims)
                feature_mask = fs_results['mask']
            else:
                raise ValueError(f"Unknown method: {method_name}")

            fs_time = time.time() - fs_start_time

            # Apply feature mask
            X_train_sel = X_train[:, feature_mask]
            X_val_sel = X_val[:, feature_mask]
            X_test_sel = X_test[:, feature_mask]

            # Dataset size after selection
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)

            # Build per-modality dims after mask
            mod_dims = get_modality_dims_after_mask(feature_mask, fold_feature_dims)

            # Build Transformer model
            model = ModalityTokenTransformer(mod_dims, num_classes).to(DEVICE)

            # Build DataLoaders (splits unified back to per-modality)
            train_dataset = MultiModalDatasetFromUnified(X_train_sel, y[train_idx], mod_dims)
            val_dataset = MultiModalDatasetFromUnified(X_val_sel, y[val_idx], mod_dims)
            test_dataset = MultiModalDatasetFromUnified(X_test_sel, y[test_idx], mod_dims)

            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()

            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )

            # Modality retention
            if method_name != 'baseline':
                modality_ret = fs_results.get('modality_retention',
                    calculate_modality_retention(feature_mask, fold_feature_dims))
            else:
                modality_ret = {m: {'selected': d, 'total': d, 'percentage': 100.0}
                               for m, d in fold_feature_dims.items()}

            # Compile comprehensive fold result
            fold_result = {
                'fold': fold_idx,
                'method': method_name,
                'num_train': len(train_idx),
                'num_val': len(val_idx),
                'num_test': len(test_idx),
                # Accuracy & classification metrics
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                # Feature selection info
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                # Feature dims for this fold (post-PCA)
                'feature_dims': fold_feature_dims,
                # Timing
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                # Model size
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                # Dataset size
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                # GPU
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                # Convergence (metaheuristics only)
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
                # PCA info
                'depth_pca_dim': DEPTH_PCA_DIM,
                'depth_pca_variance_explained': float(pca_obj.explained_variance_ratio_.sum()) if (pca_obj is not None and hasattr(pca_obj, 'explained_variance_ratio_')) else None,
            }

            master_results[method_name][fold_idx] = fold_result

            # Save per-fold result immediately
            fold_dir = RESULTS_ROOT / method_name
            fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
            # Convert numpy to python types for JSON
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v

            with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)

            np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", feature_mask)

            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%), "
                  f"Model: {eval_metrics['model_size_mb']:.3f}MB")

            # Cleanup
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()

    print(f"\n{'='*80}")
    print("ALL PER-FOLD EXPERIMENTS COMPLETED (Transformer Model)")
    print(f"{'='*80}")

    return master_results


print("Per-fold experiment runner defined (Transformer)")
print("  -> Per-modality normalization: ENABLED")
print(f"  -> Depth PCA: {'ENABLED -> ' + str(DEPTH_PCA_DIM) if DEPTH_PCA_DIM else 'DISABLED'}")
# Out:
# Per-fold experiment runner defined (Transformer)
#   -> Per-modality normalization: ENABLED
#   -> Depth PCA: ENABLED -> 512

# %% [markdown]
# ## Run All Experiments

# %%
master_results = run_all_methods_per_fold()
# Out:
# ================================================================================
# STARTING COMPREHENSIVE PER-FOLD EXPERIMENTS (Transformer Model)
# Methods: baseline + 3 standard + 14 metaheuristics = 18 total
# Folds: 10
# Per-modality normalization: ENABLED
# Depth PCA: ENABLED -> 512
# ================================================================================
#
# ################################################################################
# # FOLD 1/10
# ################################################################################
#   Train: 405, Val: 27, Test: 184
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- BASELINE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 6359/6359 (100.0%), Model: 4.155MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 3179/6359 (50.0%), Time: 31.4s
#     Test Acc: 99.46%, F1: 99.44%, Features: 3179/6359 (50.0%), Model: 2.602MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 3179/6359 (50.0%), Time: 7.9s
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%), Model: 2.602MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 3179/6359 (50.0%), Time: 107.3s
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%), Model: 2.602MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02442207894323007']
# ['At iteration 1 the best fitness is 0.02441421607170939']
# ['At iteration 2 the best fitness is 0.02440635320018871']
# ['At iteration 3 the best fitness is 0.024398490328668032']
# ['At iteration 4 the best fitness is 0.024390627457147353']
# ['At iteration 5 the best fitness is 0.024390627457147353']
# ['At iteration 6 the best fitness is 0.024374901714105994']
# ['At iteration 7 the best fitness is 0.024374901714105994']
# ['At iteration 8 the best fitness is 0.024359175971064635']
# ['At iteration 9 the best fitness is 0.024351313099543956']
# ['At iteration 10 the best fitness is 0.024335587356502597']
# ['At iteration 11 the best fitness is 0.024335587356502597']
# ['At iteration 12 the best fitness is 0.024327724484981918']
# ['At iteration 13 the best fitness is 0.024327724484981918']
# ['At iteration 14 the best fitness is 0.024327724484981918']
# ['At iteration 15 the best fitness is 0.024327724484981918']
# ['At iteration 16 the best fitness is 0.024327724484981918']
# ['At iteration 17 the best fitness is 0.024327724484981918']
# ['At iteration 18 the best fitness is 0.024327724484981918']
# ['At iteration 19 the best fitness is 0.024327724484981918']
# ['At iteration 20 the best fitness is 0.024327724484981918']
# ['At iteration 21 the best fitness is 0.024327724484981918']
# ['At iteration 22 the best fitness is 0.024327724484981918']
# ['At iteration 23 the best fitness is 0.024327724484981918']
# ['At iteration 24 the best fitness is 0.02431199874194056']
# ['At iteration 25 the best fitness is 0.02430413587041988']
# ['At iteration 26 the best fitness is 0.02430413587041988']
# ['At iteration 27 the best fitness is 0.02430413587041988']
# ['At iteration 28 the best fitness is 0.02430413587041988']
# ['At iteration 29 the best fitness is 0.02430413587041988']
#       Selected: 3091/6359 (48.6%), Fitness: 0.0243, Time: 2361.7s
#       Modality:S=50%, Sk=46%,
#     Test Acc: 99.46%, F1: 99.44%, Features: 3091/6359 (48.6%), Model: 2.559MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02416260418304765']
# ['At iteration 1 the best fitness is 0.02416260418304765']
# ['At iteration 2 the best fitness is 0.02416260418304765']
# ['At iteration 3 the best fitness is 0.02416260418304765']
# ['At iteration 4 the best fitness is 0.02416260418304765']
# ['At iteration 5 the best fitness is 0.02416260418304765']
# ['At iteration 6 the best fitness is 0.02416260418304765']
# ['At iteration 7 the best fitness is 0.024139015568485613']
# ['At iteration 8 the best fitness is 0.024139015568485613']
# ['At iteration 9 the best fitness is 0.024139015568485613']
# ['At iteration 10 the best fitness is 0.024139015568485613']
# ['At iteration 11 the best fitness is 0.024115426953923574']
# ['At iteration 12 the best fitness is 0.024076112596320177']
# ['At iteration 13 the best fitness is 0.024076112596320177']
# ['At iteration 14 the best fitness is 0.0240289353671961']
# ['At iteration 15 the best fitness is 0.0240289353671961']
# ['At iteration 16 the best fitness is 0.0240289353671961']
# ['At iteration 17 the best fitness is 0.0240289353671961']
# ['At iteration 18 the best fitness is 0.02377732347853436']
# ['At iteration 19 the best fitness is 0.02377732347853436']
# ['At iteration 20 the best fitness is 0.02377732347853436']
# ['At iteration 21 the best fitness is 0.02377732347853436']
# ['At iteration 22 the best fitness is 0.02377732347853436']
# ['At iteration 23 the best fitness is 0.02377732347853436']
# ['At iteration 24 the best fitness is 0.02377732347853436']
# ['At iteration 25 the best fitness is 0.02377732347853436']
# ['At iteration 26 the best fitness is 0.02377732347853436']
# ['At iteration 27 the best fitness is 0.02377732347853436']
# ['At iteration 28 the best fitness is 0.02377732347853436']
# ['At iteration 29 the best fitness is 0.02377732347853436']
#       Selected: 3024/6359 (47.6%), Fitness: 0.0238, Time: 4777.9s
#       Modality:S=48%, Sk=47%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3024/6359 (47.6%), Model: 2.527MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024469256172354143']
# ['At iteration 2 the best fitness is 0.024469256172354143']
# ['At iteration 3 the best fitness is 0.024469256172354143']
# ['At iteration 4 the best fitness is 0.024469256172354143']
# ['At iteration 5 the best fitness is 0.024083975467840857']
# ['At iteration 6 the best fitness is 0.024083975467840857']
# ['At iteration 7 the best fitness is 0.024083975467840857']
# ['At iteration 8 the best fitness is 0.024083975467840857']
# ['At iteration 9 the best fitness is 0.024083975467840857']
# ['At iteration 10 the best fitness is 0.023879540808303193']
# ['At iteration 11 the best fitness is 0.023848089322220475']
# ['At iteration 12 the best fitness is 0.023486397232269224']
# ['At iteration 13 the best fitness is 0.023486397232269224']
# ['At iteration 14 the best fitness is 0.02342349426010379']
# ['At iteration 15 the best fitness is 0.02342349426010379']
# ['At iteration 16 the best fitness is 0.02342349426010379']
# ['At iteration 17 the best fitness is 0.02342349426010379']
# ['At iteration 18 the best fitness is 0.02342349426010379']
# ['At iteration 19 the best fitness is 0.023384179902500395']
# ['At iteration 20 the best fitness is 0.023384179902500395']
# ['At iteration 21 the best fitness is 0.023384179902500395']
# ['At iteration 22 the best fitness is 0.023384179902500395']
# ['At iteration 23 the best fitness is 0.023384179902500395']
# ['At iteration 24 the best fitness is 0.02333700267337632']
# ['At iteration 25 the best fitness is 0.02333700267337632']
# ['At iteration 26 the best fitness is 0.023093253656235258']
# ['At iteration 27 the best fitness is 0.023093253656235258']
# ['At iteration 28 the best fitness is 0.023093253656235258']
# ['At iteration 29 the best fitness is 0.023093253656235258']
# ['At iteration 30 the best fitness is 0.023093253656235258']
#       Selected: 2937/6359 (46.2%), Fitness: 0.0231, Time: 2406.1s
#       Modality:S=46%, Sk=46%,
#     Test Acc: 92.93%, F1: 92.54%, Features: 2937/6359 (46.2%), Model: 2.484MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024823085390784715']
# ['At iteration 1 the best fitness is 0.024650102217329772']
# ['At iteration 2 the best fitness is 0.024359175971064635']
# ['At iteration 3 the best fitness is 0.024091838339361536']
# ['At iteration 4 the best fitness is 0.024091838339361536']
# ['At iteration 5 the best fitness is 0.024115426953923574']
# ['At iteration 6 the best fitness is 0.024139015568485613']
# ['At iteration 7 the best fitness is 0.024146878440006292']
# ['At iteration 8 the best fitness is 0.02403679823871678']
# ['At iteration 9 the best fitness is 0.024013209624154742']
# ['At iteration 10 the best fitness is 0.023989621009592704']
# ['At iteration 11 the best fitness is 0.02391885516590659']
# ['At iteration 12 the best fitness is 0.02391885516590659']
# ['At iteration 13 the best fitness is 0.023887403679823872']
# ['At iteration 14 the best fitness is 0.023816637836137758']
# ['At iteration 15 the best fitness is 0.023816637836137758']
# ['At iteration 16 the best fitness is 0.023816637836137758']
# ['At iteration 17 the best fitness is 0.023816637836137758']
# ['At iteration 18 the best fitness is 0.02379304922157572']
# ['At iteration 19 the best fitness is 0.02379304922157572']
# ['At iteration 20 the best fitness is 0.02377732347853436']
# ['At iteration 21 the best fitness is 0.02377732347853436']
# ['At iteration 22 the best fitness is 0.02377732347853436']
# ['At iteration 23 the best fitness is 0.02377732347853436']
# ['At iteration 24 the best fitness is 0.02377732347853436']
# ['At iteration 25 the best fitness is 0.02377732347853436']
# ['At iteration 26 the best fitness is 0.02377732347853436']
# ['At iteration 27 the best fitness is 0.02377732347853436']
# ['At iteration 28 the best fitness is 0.02377732347853436']
# ['At iteration 29 the best fitness is 0.02377732347853436']
#       Selected: 3024/6359 (47.6%), Fitness: 0.0238, Time: 2334.7s
#       Modality:S=48%, Sk=47%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3024/6359 (47.6%), Model: 2.527MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024359175971064635
# At iteration 2 the best fitness is 0.024359175971064635
# At iteration 3 the best fitness is 0.024359175971064635
# At iteration 4 the best fitness is 0.024359175971064635
# At iteration 5 the best fitness is 0.024359175971064635
# At iteration 6 the best fitness is 0.02428841012737852
# At iteration 7 the best fitness is 0.02428841012737852
# At iteration 8 the best fitness is 0.02415474131152697
# At iteration 9 the best fitness is 0.02415474131152697
# At iteration 10 the best fitness is 0.02415474131152697
# At iteration 11 the best fitness is 0.024367038842585315
# At iteration 12 the best fitness is 0.02416260418304765
# At iteration 13 the best fitness is 0.024343450228023276
# At iteration 14 the best fitness is 0.02442994181475075
# At iteration 15 the best fitness is 0.02431199874194056
# At iteration 16 the best fitness is 0.02431199874194056
# At iteration 17 the best fitness is 0.02431199874194056
# At iteration 18 the best fitness is 0.023973895266551346
# At iteration 19 the best fitness is 0.024524296272998902
# At iteration 20 the best fitness is 0.024013209624154742
# At iteration 21 the best fitness is 0.024013209624154742
# At iteration 22 the best fitness is 0.024013209624154742
# At iteration 23 the best fitness is 0.024076112596320177
# At iteration 24 the best fitness is 0.024076112596320177
# At iteration 25 the best fitness is 0.024076112596320177
# At iteration 26 the best fitness is 0.023871677936782514
# At iteration 27 the best fitness is 0.024021072495675422
# At iteration 28 the best fitness is 0.023942443780468628
# At iteration 29 the best fitness is 0.023832363579179117
# At iteration 30 the best fitness is 0.023832363579179117
#       Selected: 3031/6359 (47.7%), Fitness: 0.0238, Time: 2323.7s
#       Modality:S=48%, Sk=47%,
#     Test Acc: 99.46%, F1: 99.46%, Features: 3031/6359 (47.7%), Model: 2.530MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024587199245164337']
# ['At iteration 1 the best fitness is 0.023541437332913983']
# ['At iteration 2 the best fitness is 0.02223620066048121']
# ['At iteration 3 the best fitness is 0.02110394716150338']
# ['At iteration 4 the best fitness is 0.020207579808145935']
# ['At iteration 5 the best fitness is 0.019185406510457623']
# ['At iteration 6 the best fitness is 0.01819468469885202']
# ['At iteration 7 the best fitness is 0.01736908318918069']
# ['At iteration 8 the best fitness is 0.01651203019342664']
# ['At iteration 9 the best fitness is 0.015945903443937728']
# ['At iteration 10 the best fitness is 0.015293285107721342']
# ['At iteration 11 the best fitness is 0.014845101431042618']
# ['At iteration 12 the best fitness is 0.014554175184777482']
# ['At iteration 13 the best fitness is 0.014121717251140118']
# ['At iteration 14 the best fitness is 0.01361063060229596']
# ['At iteration 15 the best fitness is 0.013476961786444412']
# ['At iteration 16 the best fitness is 0.013170309797137915']
# ['At iteration 17 the best fitness is 0.013044503852807046']
# ['At iteration 18 the best fitness is 0.012659223148293758']
# ['At iteration 19 the best fitness is 0.01251769146092153']
# ['At iteration 20 the best fitness is 0.01251769146092153']
# ['At iteration 21 the best fitness is 0.012344708287466583']
# ['At iteration 22 the best fitness is 0.012226765214656392']
# ['At iteration 23 the best fitness is 0.012226765214656392']
# ['At iteration 24 the best fitness is 0.012203176600094356']
# ['At iteration 25 the best fitness is 0.012085233527284165']
# ['At iteration 26 the best fitness is 0.01201446768359805']
# ['At iteration 27 the best fitness is 0.01201446768359805']
# ['At iteration 28 the best fitness is 0.011935838968391257']
# ['At iteration 29 the best fitness is 0.011927976096870577']
#       Selected: 1517/6359 (23.9%), Fitness: 0.0119, Time: 2456.5s
#       Modality:S=24%, Sk=23%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 1517/6359 (23.9%), Model: 1.791MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.024359175971064635']
# ['At iteration 1 the best fitness is 0.018037427268438433']
# ['At iteration 2 the best fitness is 0.0029249882056927193']
# ['At iteration 3 the best fitness is 0.0013995911306809248']
# ['At iteration 4 the best fitness is 0.0007626985375058972']
# ['At iteration 5 the best fitness is 0.00025947476018241863']
# ['At iteration 6 the best fitness is 0.0002280232740997012']
# ['At iteration 7 the best fitness is 0.00017298317345494575']
# ['At iteration 8 the best fitness is 0.00017298317345494575']
# ['At iteration 9 the best fitness is 0.00017298317345494575']
# ['At iteration 10 the best fitness is 0.00017298317345494575']
# ['At iteration 11 the best fitness is 0.00017298317345494575']
# ['At iteration 12 the best fitness is 0.00017298317345494575']
# ['At iteration 13 the best fitness is 0.00017298317345494575']
# ['At iteration 14 the best fitness is 0.00017298317345494575']
# ['At iteration 15 the best fitness is 0.00017298317345494575']
# ['At iteration 16 the best fitness is 0.00017298317345494575']
# ['At iteration 17 the best fitness is 0.00017298317345494575']
# ['At iteration 18 the best fitness is 0.00017298317345494575']
# ['At iteration 19 the best fitness is 0.0001651203019342664']
# ['At iteration 20 the best fitness is 0.0001651203019342664']
# ['At iteration 21 the best fitness is 0.0001651203019342664']
# ['At iteration 22 the best fitness is 0.00011008020128951094']
# ['At iteration 23 the best fitness is 0.00011008020128951094']
# ['At iteration 24 the best fitness is 0.00011008020128951094']
# ['At iteration 25 the best fitness is 0.00011008020128951094']
# ['At iteration 26 the best fitness is 0.00011008020128951094']
# ['At iteration 27 the best fitness is 0.00011008020128951094']
# ['At iteration 28 the best fitness is 0.00011008020128951094']
# ['At iteration 29 the best fitness is 0.00011008020128951094']
#       Selected: 14/6359 (0.2%), Fitness: 0.0001, Time: 3454.6s
#       Modality:S=0%, Sk=0%,
#     Test Acc: 94.57%, F1: 94.49%, Features: 14/6359 (0.2%), Model: 1.057MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02404466111023746']
# ['At iteration 1 the best fitness is 0.02404466111023746']
# ['At iteration 2 the best fitness is 0.02404466111023746']
# ['At iteration 3 the best fitness is 0.02404466111023746']
# ['At iteration 4 the best fitness is 0.02404466111023746']
# ['At iteration 5 the best fitness is 0.02404466111023746']
# ['At iteration 6 the best fitness is 0.02404466111023746']
# ['At iteration 7 the best fitness is 0.02404466111023746']
# ['At iteration 8 the best fitness is 0.02404466111023746']
# ['At iteration 9 the best fitness is 0.02404466111023746']
# ['At iteration 10 the best fitness is 0.02404466111023746']
# ['At iteration 11 the best fitness is 0.0240289353671961']
# ['At iteration 12 the best fitness is 0.0240289353671961']
# ['At iteration 13 the best fitness is 0.024021072495675422']
# ['At iteration 14 the best fitness is 0.024021072495675422']
# ['At iteration 15 the best fitness is 0.024021072495675422']
# ['At iteration 16 the best fitness is 0.024021072495675422']
# ['At iteration 17 the best fitness is 0.024021072495675422']
# ['At iteration 18 the best fitness is 0.024021072495675422']
# ['At iteration 19 the best fitness is 0.023848089322220475']
# ['At iteration 20 the best fitness is 0.02379304922157572']
# ['At iteration 21 the best fitness is 0.02379304922157572']
# ['At iteration 22 the best fitness is 0.023753734863972323']
# ['At iteration 23 the best fitness is 0.023722283377889605']
# ['At iteration 24 the best fitness is 0.023604340305079418']
# ['At iteration 25 the best fitness is 0.023604340305079418']
# ['At iteration 26 the best fitness is 0.02358861456203806']
# ['At iteration 27 the best fitness is 0.02344708287466583']
# ['At iteration 28 the best fitness is 0.02344708287466583']
# ['At iteration 29 the best fitness is 0.02344708287466583']
#       Selected: 2982/6359 (46.9%), Fitness: 0.0234, Time: 2444.5s
#       Modality:S=47%, Sk=47%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 2982/6359 (46.9%), Model: 2.506MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02428054725585784']
# ['At iteration 2 the best fitness is 0.02428054725585784']
# ['At iteration 3 the best fitness is 0.02428054725585784']
# ['At iteration 4 the best fitness is 0.02428054725585784']
# ['At iteration 5 the best fitness is 0.02428054725585784']
# ['At iteration 6 the best fitness is 0.02428054725585784']
# ['At iteration 7 the best fitness is 0.02428054725585784']
# ['At iteration 8 the best fitness is 0.02428054725585784']
# ['At iteration 9 the best fitness is 0.02428054725585784']
# ['At iteration 10 the best fitness is 0.02428054725585784']
# ['At iteration 11 the best fitness is 0.02428054725585784']
# ['At iteration 12 the best fitness is 0.02428054725585784']
# ['At iteration 13 the best fitness is 0.02428054725585784']
# ['At iteration 14 the best fitness is 0.02428054725585784']
# ['At iteration 15 the best fitness is 0.02428054725585784']
# ['At iteration 16 the best fitness is 0.02428054725585784']
# ['At iteration 17 the best fitness is 0.024131152696964933']
# ['At iteration 18 the best fitness is 0.02405252398175814']
# ['At iteration 19 the best fitness is 0.024005346752634063']
# ['At iteration 20 the best fitness is 0.024005346752634063']
# ['At iteration 21 the best fitness is 0.024005346752634063']
# ['At iteration 22 the best fitness is 0.024005346752634063']
# ['At iteration 23 the best fitness is 0.023981758138072025']
# ['At iteration 24 the best fitness is 0.023855952193741155']
# ['At iteration 25 the best fitness is 0.023855952193741155']
# ['At iteration 26 the best fitness is 0.023855952193741155']
# ['At iteration 27 the best fitness is 0.023855952193741155']
# ['At iteration 28 the best fitness is 0.023855952193741155']
# ['At iteration 29 the best fitness is 0.02379304922157572']
#       Selected: 3026/6359 (47.6%), Fitness: 0.0238, Time: 2287.4s
#       Modality:S=47%, Sk=49%,
#     Test Acc: 98.37%, F1: 98.32%, Features: 3026/6359 (47.6%), Model: 2.528MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024477119043874826']
# ['At iteration 2 the best fitness is 0.024201918540651048']
# ['At iteration 3 the best fitness is 0.024201918540651048']
# ['At iteration 4 the best fitness is 0.02406038685327882']
# ['At iteration 5 the best fitness is 0.02367510614876553']
# ['At iteration 6 the best fitness is 0.023635791791162136']
# ['At iteration 7 the best fitness is 0.023635791791162136']
# ['At iteration 8 the best fitness is 0.023470671489227865']
# ['At iteration 9 the best fitness is 0.02342349426010379']
# ['At iteration 10 the best fitness is 0.02342349426010379']
# ['At iteration 11 the best fitness is 0.02332913980185564']
# ['At iteration 12 the best fitness is 0.02332913980185564']
# ['At iteration 13 the best fitness is 0.02332913980185564']
# ['At iteration 14 the best fitness is 0.02332913980185564']
# ['At iteration 15 the best fitness is 0.023297688315772922']
# ['At iteration 16 the best fitness is 0.02305393929863186']
# ['At iteration 17 the best fitness is 0.02305393929863186']
# ['At iteration 18 the best fitness is 0.02305393929863186']
# ['At iteration 19 the best fitness is 0.023030350684069823']
# ['At iteration 20 the best fitness is 0.023030350684069823']
# ['At iteration 21 the best fitness is 0.023030350684069823']
# ['At iteration 22 the best fitness is 0.023030350684069823']
# ['At iteration 23 the best fitness is 0.023014624941028464']
# ['At iteration 24 the best fitness is 0.022912407611259636']
# ['At iteration 25 the best fitness is 0.022912407611259636']
# ['At iteration 26 the best fitness is 0.0228495046390942']
# ['At iteration 27 the best fitness is 0.02272369869476333']
# ['At iteration 28 the best fitness is 0.02272369869476333']
# ['At iteration 29 the best fitness is 0.02272369869476333']
# ['At iteration 30 the best fitness is 0.022692247208680613']
#       Selected: 2886/6359 (45.4%), Fitness: 0.0227, Time: 2334.5s
#       Modality:S=46%, Sk=44%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 2886/6359 (45.4%), Model: 2.459MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02464223934580909']
# ['At iteration 2 the best fitness is 0.02464223934580909']
# ['At iteration 3 the best fitness is 0.02444566755779211']
# ['At iteration 4 the best fitness is 0.02444566755779211']
# ['At iteration 5 the best fitness is 0.024209781412171727']
# ['At iteration 6 the best fitness is 0.024209781412171727']
# ['At iteration 7 the best fitness is 0.024209781412171727']
# ['At iteration 8 the best fitness is 0.024209781412171727']
# ['At iteration 9 the best fitness is 0.024209781412171727']
# ['At iteration 10 the best fitness is 0.024209781412171727']
# ['At iteration 11 the best fitness is 0.024209781412171727']
# ['At iteration 12 the best fitness is 0.024209781412171727']
# ['At iteration 13 the best fitness is 0.024209781412171727']
# ['At iteration 14 the best fitness is 0.024201918540651048']
# ['At iteration 15 the best fitness is 0.023973895266551346']
# ['At iteration 16 the best fitness is 0.02392671803742727']
# ['At iteration 17 the best fitness is 0.023863815065261834']
# ['At iteration 18 the best fitness is 0.023722283377889605']
# ['At iteration 19 the best fitness is 0.023722283377889605']
# ['At iteration 20 the best fitness is 0.023722283377889605']
# ['At iteration 21 the best fitness is 0.023722283377889605']
# ['At iteration 22 the best fitness is 0.023722283377889605']
# ['At iteration 23 the best fitness is 0.023722283377889605']
# ['At iteration 24 the best fitness is 0.023722283377889605']
# ['At iteration 25 the best fitness is 0.023722283377889605']
# ['At iteration 26 the best fitness is 0.023722283377889605']
# ['At iteration 27 the best fitness is 0.023706557634848247']
# ['At iteration 28 the best fitness is 0.023635791791162136']
# ['At iteration 29 the best fitness is 0.023620066048120777']
# ['At iteration 30 the best fitness is 0.023525711589872624']
#       Selected: 2992/6359 (47.1%), Fitness: 0.0235, Time: 2355.3s
#       Modality:S=47%, Sk=47%,
#     Test Acc: 98.37%, F1: 98.35%, Features: 2992/6359 (47.1%), Model: 2.511MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024398490328668032']
# ['At iteration 1 the best fitness is 0.022904544739738953']
# ['At iteration 2 the best fitness is 0.018399119358389684']
# ['At iteration 3 the best fitness is 0.01540336530901085']
# ['At iteration 4 the best fitness is 0.01540336530901085']
# ['At iteration 5 the best fitness is 0.01166063846516748']
# ['At iteration 6 the best fitness is 0.01166063846516748']
# ['At iteration 7 the best fitness is 0.01166063846516748']
# ['At iteration 8 the best fitness is 0.010158830004717723']
# ['At iteration 9 the best fitness is 0.009042302248781255']
# ['At iteration 10 the best fitness is 0.008539078471457778']
# ['At iteration 11 the best fitness is 0.0073124705142317975']
# ['At iteration 12 the best fitness is 0.0073124705142317975']
# ['At iteration 13 the best fitness is 0.006848561094511716']
# ['At iteration 14 the best fitness is 0.005975782355716308']
# ['At iteration 15 the best fitness is 0.005975782355716308']
# ['At iteration 16 the best fitness is 0.005975782355716308']
# ['At iteration 17 the best fitness is 0.004804214499135085']
# ['At iteration 18 the best fitness is 0.004316716464852964']
# ['At iteration 19 the best fitness is 0.004316716464852964']
# ['At iteration 20 the best fitness is 0.0037427268438433715']
# ['At iteration 21 the best fitness is 0.0037427268438433715']
# ['At iteration 22 the best fitness is 0.003483252083660953']
# ['At iteration 23 the best fitness is 0.003483252083660953']
# ['At iteration 24 the best fitness is 0.0031687372228337792']
# ['At iteration 25 the best fitness is 0.0031687372228337792']
# ['At iteration 26 the best fitness is 0.0031687372228337792']
# ['At iteration 27 the best fitness is 0.0031530114797924205']
# ['At iteration 28 the best fitness is 0.0031530114797924205']
# ['At iteration 29 the best fitness is 0.0031530114797924205']
#       Selected: 401/6359 (6.3%), Fitness: 0.0032, Time: 2584.5s
#       Modality:S=7%, Sk=6%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 401/6359 (6.3%), Model: 1.246MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024335587356502597']
# ['At iteration 2 the best fitness is 0.024335587356502597']
# ['At iteration 3 the best fitness is 0.024335587356502597']
# ['At iteration 4 the best fitness is 0.02404466111023746']
# ['At iteration 5 the best fitness is 0.02404466111023746']
# ['At iteration 6 the best fitness is 0.02404466111023746']
# ['At iteration 7 the best fitness is 0.02404466111023746']
# ['At iteration 8 the best fitness is 0.02404466111023746']
# ['At iteration 9 the best fitness is 0.02404466111023746']
# ['At iteration 10 the best fitness is 0.02404466111023746']
# ['At iteration 11 the best fitness is 0.02404466111023746']
# ['At iteration 12 the best fitness is 0.02404466111023746']
# ['At iteration 13 the best fitness is 0.02404466111023746']
# ['At iteration 14 the best fitness is 0.02404466111023746']
# ['At iteration 15 the best fitness is 0.024021072495675422']
# ['At iteration 16 the best fitness is 0.02391885516590659']
# ['At iteration 17 the best fitness is 0.02389526655134455']
# ['At iteration 18 the best fitness is 0.023855952193741155']
# ['At iteration 19 the best fitness is 0.023840226450699796']
# ['At iteration 20 the best fitness is 0.0238009120930964']
# ['At iteration 21 the best fitness is 0.02379304922157572']
# ['At iteration 22 the best fitness is 0.02379304922157572']
# ['At iteration 23 the best fitness is 0.02379304922157572']
# ['At iteration 24 the best fitness is 0.02379304922157572']
# ['At iteration 25 the best fitness is 0.02379304922157572']
# ['At iteration 26 the best fitness is 0.02379304922157572']
# ['At iteration 27 the best fitness is 0.02379304922157572']
# ['At iteration 28 the best fitness is 0.02379304922157572']
# ['At iteration 29 the best fitness is 0.02379304922157572']
#       Selected: 3026/6359 (47.6%), Fitness: 0.0238, Time: 5909.9s
#       Modality:S=47%, Sk=50%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3026/6359 (47.6%), Model: 2.528MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024390627457147353']
# ['At iteration 1 the best fitness is 0.005802799182261362']
# ['At iteration 2 the best fitness is 0.002327409970121088']
# ['At iteration 3 the best fitness is 0.000668344079257745']
# ['At iteration 4 the best fitness is 0.000668344079257745']
# ['At iteration 5 the best fitness is 0.0004639094197200818']
# ['At iteration 6 the best fitness is 0.000424595062116685']
# ['At iteration 7 the best fitness is 0.000424595062116685']
# ['At iteration 8 the best fitness is 0.0003459663469098915']
# ['At iteration 9 the best fitness is 0.0003459663469098915']
# ['At iteration 10 the best fitness is 0.0001808460449756251']
# ['At iteration 11 the best fitness is 0.0001808460449756251']
# ['At iteration 12 the best fitness is 0.0001808460449756251']
# ['At iteration 13 the best fitness is 0.0001808460449756251']
# ['At iteration 14 the best fitness is 0.0001808460449756251']
# ['At iteration 15 the best fitness is 0.0001808460449756251']
# ['At iteration 16 the best fitness is 0.0001808460449756251']
# ['At iteration 17 the best fitness is 0.0001808460449756251']
# ['At iteration 18 the best fitness is 0.0001808460449756251']
# ['At iteration 19 the best fitness is 0.0001808460449756251']
# ['At iteration 20 the best fitness is 0.0001808460449756251']
# ['At iteration 21 the best fitness is 0.0001808460449756251']
# ['At iteration 22 the best fitness is 0.0001808460449756251']
# ['At iteration 23 the best fitness is 0.0001808460449756251']
# ['At iteration 24 the best fitness is 0.0001808460449756251']
# ['At iteration 25 the best fitness is 0.0001808460449756251']
# ['At iteration 26 the best fitness is 0.0001808460449756251']
# ['At iteration 27 the best fitness is 0.0001808460449756251']
# ['At iteration 28 the best fitness is 0.0001808460449756251']
# ['At iteration 29 the best fitness is 0.0001808460449756251']
#       Selected: 23/6359 (0.4%), Fitness: 0.0002, Time: 2228.9s
#       Modality:S=0%, Sk=0%,
#     Test Acc: 86.96%, F1: 85.77%, Features: 23/6359 (0.4%), Model: 1.061MB
#
# ################################################################################
# # FOLD 2/10
# ################################################################################
#   Train: 419, Val: 27, Test: 170
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- BASELINE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 6359/6359 (100.0%), Model: 4.155MB
#
#   --- MUTUAL_INFO ---
#     Running Mutual Information...
#       Selected: 3179/6359 (50.0%), Time: 32.0s
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%), Model: 2.602MB
#
#   --- RFE ---
#     Running RFE...
#       Selected: 3179/6359 (50.0%), Time: 8.4s
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%), Model: 2.602MB
#
#   --- LASSO ---
#     Running LASSO...
#       Selected: 3179/6359 (50.0%), Time: 111.4s
#     Test Acc: 99.41%, F1: 99.38%, Features: 3179/6359 (50.0%), Model: 2.602MB
#
#   --- META_BAT ---
#     Running EvoloPy BAT...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024547884887560937']
# ['At iteration 1 the best fitness is 0.02454002201604026']
# ['At iteration 2 the best fitness is 0.02451643340147822']
# ['At iteration 3 the best fitness is 0.02451643340147822']
# ['At iteration 4 the best fitness is 0.02450070765843686']
# ['At iteration 5 the best fitness is 0.02450070765843686']
# ['At iteration 6 the best fitness is 0.024492844786916185']
# ['At iteration 7 the best fitness is 0.024492844786916185']
# ['At iteration 8 the best fitness is 0.024492844786916185']
# ['At iteration 9 the best fitness is 0.024484981915395502']
# ['At iteration 10 the best fitness is 0.024484981915395502']
# ['At iteration 11 the best fitness is 0.024477119043874826']
# ['At iteration 12 the best fitness is 0.024477119043874826']
# ['At iteration 13 the best fitness is 0.02444566755779211']
# ['At iteration 14 the best fitness is 0.02444566755779211']
# ['At iteration 15 the best fitness is 0.02444566755779211']
# ['At iteration 16 the best fitness is 0.02444566755779211']
# ['At iteration 17 the best fitness is 0.02444566755779211']
# ['At iteration 18 the best fitness is 0.02443780468627143']
# ['At iteration 19 the best fitness is 0.02443780468627143']
# ['At iteration 20 the best fitness is 0.02442994181475075']
# ['At iteration 21 the best fitness is 0.02442994181475075']
# ['At iteration 22 the best fitness is 0.02442207894323007']
# ['At iteration 23 the best fitness is 0.02442207894323007']
# ['At iteration 24 the best fitness is 0.02442207894323007']
# ['At iteration 25 the best fitness is 0.02442207894323007']
# ['At iteration 26 the best fitness is 0.02441421607170939']
# ['At iteration 27 the best fitness is 0.02441421607170939']
# ['At iteration 28 the best fitness is 0.02441421607170939']
# ['At iteration 29 the best fitness is 0.02441421607170939']
#       Selected: 3105/6359 (48.8%), Fitness: 0.0244, Time: 2643.4s
#       Modality:S=49%, Sk=47%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3105/6359 (48.8%), Model: 2.566MB
#
#   --- META_CS ---
#     Running EvoloPy CS...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024736593804057242']
# ['At iteration 1 the best fitness is 0.024736593804057242']
# ['At iteration 2 the best fitness is 0.024610787859726372']
# ['At iteration 3 the best fitness is 0.024610787859726372']
# ['At iteration 4 the best fitness is 0.024610787859726372']
# ['At iteration 5 the best fitness is 0.024610787859726372']
# ['At iteration 6 the best fitness is 0.024610787859726372']
# ['At iteration 7 the best fitness is 0.024610787859726372']
# ['At iteration 8 the best fitness is 0.024595062116685013']
# ['At iteration 9 the best fitness is 0.024595062116685013']
# ['At iteration 10 the best fitness is 0.024595062116685013']
# ['At iteration 11 the best fitness is 0.024595062116685013']
# ['At iteration 12 the best fitness is 0.024595062116685013']
# ['At iteration 13 the best fitness is 0.024595062116685013']
# ['At iteration 14 the best fitness is 0.024508570529957543']
# ['At iteration 15 the best fitness is 0.024508570529957543']
# ['At iteration 16 the best fitness is 0.024508570529957543']
# ['At iteration 17 the best fitness is 0.024508570529957543']
# ['At iteration 18 the best fitness is 0.02450070765843686']
# ['At iteration 19 the best fitness is 0.024453530429312784']
# ['At iteration 20 the best fitness is 0.024453530429312784']
# ['At iteration 21 the best fitness is 0.024453530429312784']
# ['At iteration 22 the best fitness is 0.024453530429312784']
# ['At iteration 23 the best fitness is 0.024453530429312784']
# ['At iteration 24 the best fitness is 0.024453530429312784']
# ['At iteration 25 the best fitness is 0.024453530429312784']
# ['At iteration 26 the best fitness is 0.024453530429312784']
# ['At iteration 27 the best fitness is 0.02443780468627143']
# ['At iteration 28 the best fitness is 0.02443780468627143']
# ['At iteration 29 the best fitness is 0.02443780468627143']
#       Selected: 3108/6359 (48.9%), Fitness: 0.0244, Time: 5153.0s
#       Modality:S=49%, Sk=50%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3108/6359 (48.9%), Model: 2.568MB
#
#   --- META_DE ---
#     Running EvoloPy DE...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02454002201604026']
# ['At iteration 2 the best fitness is 0.02454002201604026']
# ['At iteration 3 the best fitness is 0.02454002201604026']
# ['At iteration 4 the best fitness is 0.02450070765843686']
# ['At iteration 5 the best fitness is 0.024327724484981918']
# ['At iteration 6 the best fitness is 0.024327724484981918']
# ['At iteration 7 the best fitness is 0.024327724484981918']
# ['At iteration 8 the best fitness is 0.02431986161346124']
# ['At iteration 9 the best fitness is 0.02431986161346124']
# ['At iteration 10 the best fitness is 0.02431986161346124']
# ['At iteration 11 the best fitness is 0.02431986161346124']
# ['At iteration 12 the best fitness is 0.02431986161346124']
# ['At iteration 13 the best fitness is 0.02428841012737852']
# ['At iteration 14 the best fitness is 0.02428841012737852']
# ['At iteration 15 the best fitness is 0.024256958641295803']
# ['At iteration 16 the best fitness is 0.024256958641295803']
# ['At iteration 17 the best fitness is 0.024256958641295803']
# ['At iteration 18 the best fitness is 0.024256958641295803']
# ['At iteration 19 the best fitness is 0.02393458090894795']
# ['At iteration 20 the best fitness is 0.02393458090894795']
# ['At iteration 21 the best fitness is 0.02393458090894795']
# ['At iteration 22 the best fitness is 0.02393458090894795']
# ['At iteration 23 the best fitness is 0.02393458090894795']
# ['At iteration 24 the best fitness is 0.02393458090894795']
# ['At iteration 25 the best fitness is 0.02371442050636893']
# ['At iteration 26 the best fitness is 0.02371442050636893']
# ['At iteration 27 the best fitness is 0.02371442050636893']
# ['At iteration 28 the best fitness is 0.02371442050636893']
# ['At iteration 29 the best fitness is 0.02371442050636893']
# ['At iteration 30 the best fitness is 0.02371442050636893']
#       Selected: 3016/6359 (47.4%), Fitness: 0.0237, Time: 2622.5s
#       Modality:S=48%, Sk=46%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3016/6359 (47.4%), Model: 2.523MB
#
#   --- META_FFA ---
#     Running EvoloPy FFA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024728730932536566']
# ['At iteration 1 the best fitness is 0.02442994181475075']
# ['At iteration 2 the best fitness is 0.02431199874194056']
# ['At iteration 3 the best fitness is 0.024351313099543956']
# ['At iteration 4 the best fitness is 0.024713005189495207']
# ['At iteration 5 the best fitness is 0.024524296272998902']
# ['At iteration 6 the best fitness is 0.02443780468627143']
# ['At iteration 7 the best fitness is 0.02443780468627143']
# ['At iteration 8 the best fitness is 0.02443780468627143']
# ['At iteration 9 the best fitness is 0.024492844786916185']
# ['At iteration 10 the best fitness is 0.024492844786916185']
# ['At iteration 11 the best fitness is 0.024524296272998902']
# ['At iteration 12 the best fitness is 0.024524296272998902']
# ['At iteration 13 the best fitness is 0.024461393300833467']
# ['At iteration 14 the best fitness is 0.024469256172354143']
# ['At iteration 15 the best fitness is 0.024469256172354143']
# ['At iteration 16 the best fitness is 0.024563610630602296']
# ['At iteration 17 the best fitness is 0.024547884887560937']
# ['At iteration 18 the best fitness is 0.02450070765843686']
# ['At iteration 19 the best fitness is 0.024469256172354143']
# ['At iteration 20 the best fitness is 0.024484981915395502']
# ['At iteration 21 the best fitness is 0.024484981915395502']
# ['At iteration 22 the best fitness is 0.024484981915395502']
# ['At iteration 23 the best fitness is 0.024484981915395502']
# ['At iteration 24 the best fitness is 0.024477119043874826']
# ['At iteration 25 the best fitness is 0.024484981915395502']
# ['At iteration 26 the best fitness is 0.024492844786916185']
# ['At iteration 27 the best fitness is 0.024484981915395502']
# ['At iteration 28 the best fitness is 0.024484981915395502']
# ['At iteration 29 the best fitness is 0.024484981915395502']
#       Selected: 3114/6359 (49.0%), Fitness: 0.0245, Time: 2533.5s
#       Modality:S=49%, Sk=49%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3114/6359 (49.0%), Model: 2.571MB
#
#   --- META_GA ---
#     Running EvoloPy GA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.02462651360276773
# At iteration 2 the best fitness is 0.024689416574933166
# At iteration 3 the best fitness is 0.024823085390784715
# At iteration 4 the best fitness is 0.025098285894008494
# At iteration 5 the best fitness is 0.024854536876867433
# At iteration 6 the best fitness is 0.024854536876867433
# At iteration 7 the best fitness is 0.024972479949677624
# At iteration 8 the best fitness is 0.024972479949677624
# At iteration 9 the best fitness is 0.024972479949677624
# At iteration 10 the best fitness is 0.024972479949677624
# At iteration 11 the best fitness is 0.024815222519264036
# At iteration 12 the best fitness is 0.02489385123447083
# At iteration 13 the best fitness is 0.024846674005346753
# At iteration 14 the best fitness is 0.02480735964774336
# At iteration 15 the best fitness is 0.02466582796037113
# At iteration 16 the best fitness is 0.02466582796037113
# At iteration 17 the best fitness is 0.024760182418619284
# At iteration 18 the best fitness is 0.024563610630602296
# At iteration 19 the best fitness is 0.024563610630602296
# At iteration 20 the best fitness is 0.02462651360276773
# At iteration 21 the best fitness is 0.024524296272998902
# At iteration 22 the best fitness is 0.02455574775908162
# At iteration 23 the best fitness is 0.02441421607170939
# At iteration 24 the best fitness is 0.024524296272998902
# At iteration 25 the best fitness is 0.024469256172354143
# At iteration 26 the best fitness is 0.024469256172354143
# At iteration 27 the best fitness is 0.024508570529957543
# At iteration 28 the best fitness is 0.024547884887560937
# At iteration 29 the best fitness is 0.024484981915395502
# At iteration 30 the best fitness is 0.02464223934580909
#       Selected: 3134/6359 (49.3%), Fitness: 0.0246, Time: 2516.7s
#       Modality:S=49%, Sk=49%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3134/6359 (49.3%), Model: 2.580MB
#
#   --- META_GWO ---
#     Running EvoloPy GWO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02487026261990879']
# ['At iteration 1 the best fitness is 0.023494260103789907']
# ['At iteration 2 the best fitness is 0.022527126906746346']
# ['At iteration 3 the best fitness is 0.02123761597735493']
# ['At iteration 4 the best fitness is 0.020467054568328355']
# ['At iteration 5 the best fitness is 0.019397704041515963']
# ['At iteration 6 the best fitness is 0.018532788174241234']
# ['At iteration 7 the best fitness is 0.017840855480421452']
# ['At iteration 8 the best fitness is 0.017266865859411857']
# ['At iteration 9 the best fitness is 0.01637836137757509']
# ['At iteration 10 the best fitness is 0.01615033810347539']
# ['At iteration 11 the best fitness is 0.015584211353986478']
# ['At iteration 12 the best fitness is 0.015309010850762701']
# ['At iteration 13 the best fitness is 0.0148136499449599']
# ['At iteration 14 the best fitness is 0.014420506368925931']
# ['At iteration 15 the best fitness is 0.014098128636578078']
# ['At iteration 16 the best fitness is 0.013752162289668189']
# ['At iteration 17 the best fitness is 0.013500550401006449']
# ['At iteration 18 the best fitness is 0.013421921685799655']
# ['At iteration 19 the best fitness is 0.013288252869948107']
# ['At iteration 20 the best fitness is 0.013193898411699954']
# ['At iteration 21 the best fitness is 0.012973738009120932']
# ['At iteration 22 the best fitness is 0.012973738009120932']
# ['At iteration 23 the best fitness is 0.012973738009120932']
# ['At iteration 24 the best fitness is 0.012950149394558894']
# ['At iteration 25 the best fitness is 0.012950149394558894']
# ['At iteration 26 the best fitness is 0.012950149394558894']
# ['At iteration 27 the best fitness is 0.012950149394558894']
# ['At iteration 28 the best fitness is 0.012950149394558894']
# ['At iteration 29 the best fitness is 0.012950149394558894']
#       Selected: 1647/6359 (25.9%), Fitness: 0.0130, Time: 2689.8s
#       Modality:S=26%, Sk=25%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 1647/6359 (25.9%), Model: 1.854MB
#
#   --- META_HHO ---
#     Running EvoloPy HHO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.02500393143576034']
# ['At iteration 1 the best fitness is 0.02500393143576034']
# ['At iteration 2 the best fitness is 0.011841484510143106']
# ['At iteration 3 the best fitness is 0.011841484510143106']
# ['At iteration 4 the best fitness is 0.005598364522723699']
# ['At iteration 5 the best fitness is 0.005598364522723699']
# ['At iteration 6 the best fitness is 0.003011479792420192']
# ['At iteration 7 the best fitness is 0.0029800283063374745']
# ['At iteration 8 the best fitness is 0.0029800283063374745']
# ['At iteration 9 the best fitness is 0.0029800283063374745']
# ['At iteration 10 the best fitness is 0.0029800283063374745']
# ['At iteration 11 the best fitness is 0.0029800283063374745']
# ['At iteration 12 the best fitness is 0.0029800283063374745']
# ['At iteration 13 the best fitness is 0.00018870891649630446']
# ['At iteration 14 the best fitness is 0.00017298317345494575']
# ['At iteration 15 the best fitness is 0.00014939455889290772']
# ['At iteration 16 the best fitness is 0.00014939455889290772']
# ['At iteration 17 the best fitness is 0.00014939455889290772']
# ['At iteration 18 the best fitness is 0.00014153168737222833']
# ['At iteration 19 the best fitness is 0.00014153168737222833']
# ['At iteration 20 the best fitness is 0.00014153168737222833']
# ['At iteration 21 the best fitness is 0.00014153168737222833']
# ['At iteration 22 the best fitness is 0.00014153168737222833']
# ['At iteration 23 the best fitness is 0.00014153168737222833']
# ['At iteration 24 the best fitness is 0.00014153168737222833']
# ['At iteration 25 the best fitness is 0.00014153168737222833']
# ['At iteration 26 the best fitness is 0.00014153168737222833']
# ['At iteration 27 the best fitness is 0.00014153168737222833']
# ['At iteration 28 the best fitness is 0.00014153168737222833']
# ['At iteration 29 the best fitness is 0.000133668815851549']
#       Selected: 17/6359 (0.3%), Fitness: 0.0001, Time: 3575.9s
#       Modality:S=0%, Sk=0%,
#     Test Acc: 94.12%, F1: 94.20%, Features: 17/6359 (0.3%), Model: 1.058MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024744456675577925']
# ['At iteration 1 the best fitness is 0.024634376474288414']
# ['At iteration 2 the best fitness is 0.024532159144519578']
# ['At iteration 3 the best fitness is 0.02451643340147822']
# ['At iteration 4 the best fitness is 0.02451643340147822']
# ['At iteration 5 the best fitness is 0.024209781412171727']
# ['At iteration 6 the best fitness is 0.024209781412171727']
# ['At iteration 7 the best fitness is 0.024209781412171727']
# ['At iteration 8 the best fitness is 0.02417832992608901']
# ['At iteration 9 the best fitness is 0.02417832992608901']
# ['At iteration 10 the best fitness is 0.02417832992608901']
# ['At iteration 11 the best fitness is 0.02417832992608901']
# ['At iteration 12 the best fitness is 0.024005346752634063']
# ['At iteration 13 the best fitness is 0.024005346752634063']
# ['At iteration 14 the best fitness is 0.024005346752634063']
# ['At iteration 15 the best fitness is 0.023997483881113384']
# ['At iteration 16 the best fitness is 0.023997483881113384']
# ['At iteration 17 the best fitness is 0.023997483881113384']
# ['At iteration 18 the best fitness is 0.023997483881113384']
# ['At iteration 19 the best fitness is 0.023997483881113384']
# ['At iteration 20 the best fitness is 0.023997483881113384']
# ['At iteration 21 the best fitness is 0.023997483881113384']
# ['At iteration 22 the best fitness is 0.023997483881113384']
# ['At iteration 23 the best fitness is 0.023997483881113384']
# ...
# ['At iteration 17 the best fitness is 0.00032237773234785347']
# ['At iteration 18 the best fitness is 0.00032237773234785347']
# ['At iteration 19 the best fitness is 0.00032237773234785347']
# ['At iteration 20 the best fitness is 0.00032237773234785347']
# ['At iteration 21 the best fitness is 0.00032237773234785347']
# ['At iteration 22 the best fitness is 0.0003145148608271741']
# ['At iteration 23 the best fitness is 0.0003145148608271741']
# ['At iteration 24 the best fitness is 0.0003145148608271741']
# ['At iteration 25 the best fitness is 0.00030665198930649476']
# ['At iteration 26 the best fitness is 0.00029878911778581543']
# ['At iteration 27 the best fitness is 0.00029878911778581543']
# ['At iteration 28 the best fitness is 0.00029878911778581543']
# ['At iteration 29 the best fitness is 0.00029878911778581543']
#       Selected: 38/6359 (0.6%), Fitness: 0.0003, Time: 4013.4s
#       Modality:S=1%, Sk=1%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 38/6359 (0.6%), Model: 1.069MB
#
#   --- META_JAYA ---
#     Running EvoloPy JAYA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02430413587041988']
# ['At iteration 1 the best fitness is 0.02430413587041988']
# ['At iteration 2 the best fitness is 0.024115426953923574']
# ['At iteration 3 the best fitness is 0.023997483881113384']
# ['At iteration 4 the best fitness is 0.023997483881113384']
# ['At iteration 5 the best fitness is 0.023966032395030666']
# ['At iteration 6 the best fitness is 0.023950306651989307']
# ['At iteration 7 the best fitness is 0.023950306651989307']
# ['At iteration 8 the best fitness is 0.023950306651989307']
# ['At iteration 9 the best fitness is 0.023950306651989307']
# ['At iteration 10 the best fitness is 0.023950306651989307']
# ['At iteration 11 the best fitness is 0.023950306651989307']
# ['At iteration 12 the best fitness is 0.023950306651989307']
# ['At iteration 13 the best fitness is 0.02380877496461708']
# ['At iteration 14 the best fitness is 0.02380877496461708']
# ['At iteration 15 the best fitness is 0.02379304922157572']
# ['At iteration 16 the best fitness is 0.02379304922157572']
# ['At iteration 17 the best fitness is 0.02379304922157572']
# ['At iteration 18 the best fitness is 0.02379304922157572']
# ['At iteration 19 the best fitness is 0.02379304922157572']
# ['At iteration 20 the best fitness is 0.023738009120930964']
# ['At iteration 21 the best fitness is 0.023738009120930964']
# ['At iteration 22 the best fitness is 0.023738009120930964']
# ['At iteration 23 the best fitness is 0.023738009120930964']
# ['At iteration 24 the best fitness is 0.023738009120930964']
# ['At iteration 25 the best fitness is 0.023738009120930964']
# ['At iteration 26 the best fitness is 0.023738009120930964']
# ['At iteration 27 the best fitness is 0.023722283377889605']
# ['At iteration 28 the best fitness is 0.023722283377889605']
# ['At iteration 29 the best fitness is 0.023722283377889605']
#       Selected: 3017/6359 (47.4%), Fitness: 0.0237, Time: 3067.7s
#       Modality:S=47%, Sk=48%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 3017/6359 (47.4%), Model: 2.523MB
#
#   --- META_MFO ---
#     Running EvoloPy MFO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024264821512816483']
# ['At iteration 2 the best fitness is 0.024264821512816483']
# ['At iteration 3 the best fitness is 0.024264821512816483']
# ['At iteration 4 the best fitness is 0.024264821512816483']
# ['At iteration 5 the best fitness is 0.024264821512816483']
# ['At iteration 6 the best fitness is 0.024264821512816483']
# ['At iteration 7 the best fitness is 0.024264821512816483']
# ['At iteration 8 the best fitness is 0.024264821512816483']
# ['At iteration 9 the best fitness is 0.024264821512816483']
# ['At iteration 10 the best fitness is 0.024264821512816483']
# ['At iteration 11 the best fitness is 0.024264821512816483']
# ['At iteration 12 the best fitness is 0.024217644283692406']
# ['At iteration 13 the best fitness is 0.024217644283692406']
# ['At iteration 14 the best fitness is 0.024217644283692406']
# ['At iteration 15 the best fitness is 0.024217644283692406']
# ['At iteration 16 the best fitness is 0.024217644283692406']
# ['At iteration 17 the best fitness is 0.024217644283692406']
# ['At iteration 18 the best fitness is 0.024201918540651048']
# ['At iteration 19 the best fitness is 0.023981758138072025']
# ['At iteration 20 the best fitness is 0.023981758138072025']
# ['At iteration 21 the best fitness is 0.023981758138072025']
# ['At iteration 22 the best fitness is 0.02391885516590659']
# ['At iteration 23 the best fitness is 0.02391885516590659']
# ['At iteration 24 the best fitness is 0.02391885516590659']
# ['At iteration 25 the best fitness is 0.02391885516590659']
# ['At iteration 26 the best fitness is 0.023541437332913983']
# ['At iteration 27 the best fitness is 0.023541437332913983']
# ['At iteration 28 the best fitness is 0.023541437332913983']
# ['At iteration 29 the best fitness is 0.023541437332913983']
#       Selected: 2994/6359 (47.1%), Fitness: 0.0235, Time: 2962.7s
#       Modality:S=47%, Sk=46%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 2994/6359 (47.1%), Model: 2.512MB
#
#   --- META_MVO ---
#     Running EvoloPy MVO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024587199245164337']
# ['At iteration 2 the best fitness is 0.02444566755779211']
# ['At iteration 3 the best fitness is 0.02444566755779211']
# ['At iteration 4 the best fitness is 0.02416260418304765']
# ['At iteration 5 the best fitness is 0.024115426953923574']
# ['At iteration 6 the best fitness is 0.02391099229438591']
# ['At iteration 7 the best fitness is 0.02390312942286523']
# ['At iteration 8 the best fitness is 0.02390312942286523']
# ['At iteration 9 the best fitness is 0.02358861456203806']
# ['At iteration 10 the best fitness is 0.02358861456203806']
# ['At iteration 11 the best fitness is 0.02358861456203806']
# ['At iteration 12 the best fitness is 0.023439220003145148']
# ['At iteration 13 the best fitness is 0.023439220003145148']
# ['At iteration 14 the best fitness is 0.023439220003145148']
# ['At iteration 15 the best fitness is 0.02340776851706243']
# ['At iteration 16 the best fitness is 0.02340776851706243']
# ['At iteration 17 the best fitness is 0.02340776851706243']
# ['At iteration 18 the best fitness is 0.02340776851706243']
# ['At iteration 19 the best fitness is 0.02340776851706243']
# ['At iteration 20 the best fitness is 0.02340776851706243']
# ['At iteration 21 the best fitness is 0.02340776851706243']
# ['At iteration 22 the best fitness is 0.02340776851706243']
# ['At iteration 23 the best fitness is 0.023376317030979712']
# ['At iteration 24 the best fitness is 0.023297688315772922']
# ['At iteration 25 the best fitness is 0.023266236829690205']
# ['At iteration 26 the best fitness is 0.023250511086648846']
# ['At iteration 27 the best fitness is 0.023171882371442052']
# ['At iteration 28 the best fitness is 0.023108979399276617']
# ['At iteration 29 the best fitness is 0.023093253656235258']
# ['At iteration 30 the best fitness is 0.02306180217015254']
#       Selected: 2933/6359 (46.1%), Fitness: 0.0231, Time: 2978.8s
#       Modality:S=46%, Sk=46%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 2933/6359 (46.1%), Model: 2.482MB
#
#   --- META_PSO ---
#     Running EvoloPy PSO...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024461393300833467']
# ['At iteration 2 the best fitness is 0.024201918540651048']
# ['At iteration 3 the best fitness is 0.024201918540651048']
# ['At iteration 4 the best fitness is 0.02415474131152697']
# ['At iteration 5 the best fitness is 0.02415474131152697']
# ['At iteration 6 the best fitness is 0.02415474131152697']
# ['At iteration 7 the best fitness is 0.024068249724799498']
# ['At iteration 8 the best fitness is 0.02392671803742727']
# ['At iteration 9 the best fitness is 0.02390312942286523']
# ['At iteration 10 the best fitness is 0.023871677936782514']
# ['At iteration 11 the best fitness is 0.023871677936782514']
# ['At iteration 12 the best fitness is 0.02380877496461708']
# ['At iteration 13 the best fitness is 0.02380877496461708']
# ['At iteration 14 the best fitness is 0.023682969020286212']
# ['At iteration 15 the best fitness is 0.023620066048120777']
# ['At iteration 16 the best fitness is 0.023344865544897']
# ['At iteration 17 the best fitness is 0.023344865544897']
# ['At iteration 18 the best fitness is 0.023274099701210884']
# ['At iteration 19 the best fitness is 0.023274099701210884']
# ['At iteration 20 the best fitness is 0.023234785343607487']
# ['At iteration 21 the best fitness is 0.02305393929863186']
# ['At iteration 22 the best fitness is 0.02305393929863186']
# ['At iteration 23 the best fitness is 0.02305393929863186']
# ['At iteration 24 the best fitness is 0.02305393929863186']
# ['At iteration 25 the best fitness is 0.02305393929863186']
# ['At iteration 26 the best fitness is 0.02297531058342507']
# ['At iteration 27 the best fitness is 0.02297531058342507']
# ['At iteration 28 the best fitness is 0.02297531058342507']
# ['At iteration 29 the best fitness is 0.02297531058342507']
# ['At iteration 30 the best fitness is 0.02297531058342507']
#       Selected: 2922/6359 (46.0%), Fitness: 0.0230, Time: 3108.2s
#       Modality:S=46%, Sk=46%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 2922/6359 (46.0%), Model: 2.477MB
#
#   --- META_SCA ---
#     Running EvoloPy SCA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02466582796037113']
# ['At iteration 1 the best fitness is 0.020805158043717565']
# ['At iteration 2 the best fitness is 0.017895895581066204']
# ['At iteration 3 the best fitness is 0.017895895581066204']
# ['At iteration 4 the best fitness is 0.013909419720081773']
# ['At iteration 5 the best fitness is 0.01178644440949835']
# ['At iteration 6 the best fitness is 0.009993709702783458']
# ['At iteration 7 the best fitness is 0.008601981443623211']
# ['At iteration 8 the best fitness is 0.007359647743355874']
# ['At iteration 9 the best fitness is 0.006345337317188238']
# ['At iteration 10 the best fitness is 0.005653404623368455']
# ['At iteration 11 the best fitness is 0.004898568957383237']
# ['At iteration 12 the best fitness is 0.004395345180059758']
# ['At iteration 13 the best fitness is 0.0038921214027362798']
# ['At iteration 14 the best fitness is 0.003475389212140274']
# ['At iteration 15 the best fitness is 0.003184462965875138']
# ['At iteration 16 the best fitness is 0.002956439691775437']
# ['At iteration 17 the best fitness is 0.0028384966189652465']
# ['At iteration 18 the best fitness is 0.002523981758138072']
# ['At iteration 19 the best fitness is 0.002523981758138072']
# ['At iteration 20 the best fitness is 0.002523981758138072']
# ['At iteration 21 the best fitness is 0.002162289668186822']
# ['At iteration 22 the best fitness is 0.002162289668186822']
# ['At iteration 23 the best fitness is 0.0021072495675420666']
# ['At iteration 24 the best fitness is 0.001981443623211197']
# ['At iteration 25 the best fitness is 0.0019578550086491587']
# ['At iteration 26 the best fitness is 0.0019578550086491587']
# ['At iteration 27 the best fitness is 0.0019264035225664414']
# ['At iteration 28 the best fitness is 0.0019264035225664414']
# ['At iteration 29 the best fitness is 0.001894952036483724']
#       Selected: 241/6359 (3.8%), Fitness: 0.0019, Time: 3280.9s
#       Modality:S=3%, Sk=5%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 241/6359 (3.8%), Model: 1.168MB
#
#   --- META_SSA ---
#     Running EvoloPy SSA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02442207894323007']
# ['At iteration 2 the best fitness is 0.024139015568485613']
# ['At iteration 3 the best fitness is 0.024139015568485613']
# ['At iteration 4 the best fitness is 0.02406038685327882']
# ['At iteration 5 the best fitness is 0.023950306651989307']
# ['At iteration 6 the best fitness is 0.023950306651989307']
# ['At iteration 7 the best fitness is 0.023887403679823872']
# ['At iteration 8 the best fitness is 0.023832363579179117']
# ['At iteration 9 the best fitness is 0.023832363579179117']
# ['At iteration 10 the best fitness is 0.0238009120930964']
# ['At iteration 11 the best fitness is 0.02379304922157572']
# ['At iteration 12 the best fitness is 0.023730146249410285']
# ['At iteration 13 the best fitness is 0.0235728888189967']
# ['At iteration 14 the best fitness is 0.0235728888189967']
# ['At iteration 15 the best fitness is 0.023470671489227865']
# ['At iteration 16 the best fitness is 0.023360591287938354']
# ['At iteration 17 the best fitness is 0.02332127693033496']
# ['At iteration 18 the best fitness is 0.023281962572731563']
# ['At iteration 19 the best fitness is 0.023266236829690205']
# ['At iteration 20 the best fitness is 0.023250511086648846']
# ['At iteration 21 the best fitness is 0.023234785343607487']
# ['At iteration 22 the best fitness is 0.02321905960056613']
# ['At iteration 23 the best fitness is 0.02321905960056613']
# ['At iteration 24 the best fitness is 0.02321905960056613']
# ['At iteration 25 the best fitness is 0.02321905960056613']
# ['At iteration 26 the best fitness is 0.02321905960056613']
# ['At iteration 27 the best fitness is 0.02321905960056613']
# ['At iteration 28 the best fitness is 0.02321905960056613']
# ['At iteration 29 the best fitness is 0.02321905960056613']
#       Selected: 2953/6359 (46.4%), Fitness: 0.0232, Time: 7472.4s
#       Modality:S=46%, Sk=47%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 2953/6359 (46.4%), Model: 2.492MB
#
#   --- META_WOA ---
#     Running EvoloPy WOA...
#       Fitness: (1 - accuracy), Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024579336373643654']
# ['At iteration 1 the best fitness is 0.0054411070923101115']
# ['At iteration 2 the best fitness is 0.0016197515332599466']
# ['At iteration 3 the best fitness is 0.0011086648844157887']
# ['At iteration 4 the best fitness is 0.001022173297688316']
# ['At iteration 5 the best fitness is 0.001022173297688316']
# ['At iteration 6 the best fitness is 0.001022173297688316']
# ['At iteration 7 the best fitness is 0.0009985846831262778']
# ['At iteration 8 the best fitness is 0.0009985846831262778']
# ['At iteration 9 the best fitness is 0.000959270325522881']
# ['At iteration 10 the best fitness is 0.000959270325522881']
# ['At iteration 11 the best fitness is 0.0008334643811920115']
# ['At iteration 12 the best fitness is 0.0007076584368611418']
# ['At iteration 13 the best fitness is 0.0007076584368611418']
# ['At iteration 14 the best fitness is 0.0006997955653404624']
# ['At iteration 15 the best fitness is 0.0006997955653404624']
# ['At iteration 16 the best fitness is 0.0006997955653404624']
# ['At iteration 17 the best fitness is 0.0006997955653404624']
# ['At iteration 18 the best fitness is 0.0006997955653404624']
# ['At iteration 19 the best fitness is 0.0006997955653404624']
# ['At iteration 20 the best fitness is 0.0006762069507784242']
# ['At iteration 21 the best fitness is 0.0006762069507784242']
# ['At iteration 22 the best fitness is 0.0006762069507784242']
# ['At iteration 23 the best fitness is 0.0006762069507784242']
# ['At iteration 24 the best fitness is 0.0006762069507784242']
# ['At iteration 25 the best fitness is 0.0006762069507784242']
# ['At iteration 26 the best fitness is 0.0006762069507784242']
# ['At iteration 27 the best fitness is 0.0006762069507784242']
# ['At iteration 28 the best fitness is 0.0006762069507784242']
# ['At iteration 29 the best fitness is 0.0006762069507784242']
#       Selected: 86/6359 (1.4%), Fitness: 0.0007, Time: 2971.7s
#       Modality:S=1%, Sk=2%,
#     Test Acc: 100.00%, F1: 100.00%, Features: 86/6359 (1.4%), Model: 1.092MB
#
# ================================================================================
# ALL PER-FOLD EXPERIMENTS COMPLETED (Transformer Model)
# ================================================================================

# %%
# ============================================================================
# RECOVERY CELL: Reconstruct master_results from saved per-fold files
# ============================================================================

import json as json_lib
import numpy as np
from pathlib import Path

print("=" * 80)
print("RECOVERING master_results FROM SAVED FILES")
print("=" * 80)

master_results = {m: {} for m in ALL_METHODS}

recovered = 0
missing = 0

for method_name in ALL_METHODS:
    method_dir = RESULTS_ROOT / method_name
    for fold_idx in range(N_FOLDS):
        json_path = method_dir / f"fold_{fold_idx+1}.json"
        mask_path = method_dir / f"fold_{fold_idx+1}_mask.npy"

        if not json_path.exists():
            print(f"  [MISSING] {json_path}")
            missing += 1
            continue

        # Load JSON (all metrics except feature_mask)
        with open(json_path, 'r') as f:
            fold_data = json_lib.load(f)

        # Load feature mask
        if mask_path.exists():
            fold_data['feature_mask'] = np.load(mask_path)
        else:
            # Reconstruct a mask from num_features_selected if mask file is missing
            print(f"  [WARN] Mask missing: {mask_path}, feature_mask set to None")
            fold_data['feature_mask'] = None

        # Convert convergence back to list if it was saved as such
        if 'convergence' in fold_data and fold_data['convergence'] is not None:
            fold_data['convergence'] = list(fold_data['convergence'])

        master_results[method_name][fold_idx] = fold_data
        recovered += 1

print(f"\nRecovered: {recovered} fold results")
if missing > 0:
    print(f"Missing:   {missing} fold results")
print(f"Methods:   {len([m for m in ALL_METHODS if master_results[m]])}")
print(f"Expected:  {len(ALL_METHODS)} methods × {N_FOLDS} folds = {len(ALL_METHODS) * N_FOLDS}")

# Quick sanity check
for method_name in ALL_METHODS:
    n_folds = len(master_results[method_name])
    if n_folds != N_FOLDS:
        print(f"  [WARN] {method_name}: only {n_folds}/{N_FOLDS} folds recovered")

# Show a sample to confirm
sample_method = 'baseline'
sample_fold = 0
if sample_fold in master_results[sample_method]:
    r = master_results[sample_method][sample_fold]
    print(f"\nSample check — {sample_method}, fold {sample_fold+1}:")
    print(f"  test_acc:       {r['test_acc']:.4f}")
    print(f"  test_f1_macro:  {r['test_f1_macro']:.4f}")
    print(f"  feature_mask:   {'loaded (' + str(r['feature_mask'].shape) + ')' if r['feature_mask'] is not None else 'None'}")
# Out:
# ================================================================================
# RECOVERING master_results FROM SAVED FILES
# ================================================================================
#
# Recovered: 180 fold results
# Methods:   18
# Expected:  18 methods × 10 folds = 180
#
# Sample check — baseline, fold 1:
#   test_acc:       1.0000
#   test_f1_macro:  1.0000
#   feature_mask:   loaded ((6359,))

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
# Build a single massive DataFrame with every fold x method combination
# Also extract FEATURE_DIMS from fold results (post-PCA) for downstream plots
FEATURE_DIMS = None
TOTAL_FEATURES = None

rows = []

for method_name in ALL_METHODS:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]

        # Extract feature dims from first available result
        if FEATURE_DIMS is None and 'feature_dims' in r:
            FEATURE_DIMS = r['feature_dims']
            TOTAL_FEATURES = sum(FEATURE_DIMS.values())
            print(f"Post-PCA feature dims: {FEATURE_DIMS}, Total: {TOTAL_FEATURES}")

        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Orig Dataset (MB)': r['original_dataset_size_mb'],
            'Opt Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
            'N Train': r['num_train'],
            'N Val': r['num_val'],
            'N Test': r['num_test'],
        }

        # Per-modality retention
        for mod in MODALITY_NAMES:
            if mod in r.get('modality_retention', {}):
                row[f'{mod}_retained'] = r['modality_retention'][mod]['selected']
                row[f'{mod}_total'] = r['modality_retention'][mod]['total']
                row[f'{mod}_retention_%'] = r['modality_retention'][mod]['percentage']

        rows.append(row)

df_all = pd.DataFrame(rows)
df_all.to_csv(RESULTS_ROOT / "all_folds_results.csv", index=False)
print(f"Results table: {df_all.shape}")
print(f"Methods: {df_all['Method'].nunique()}, Folds per method: {df_all.groupby('Method')['Fold'].count().to_dict()}")
df_all.head()
# Out:
# Post-PCA feature dims: {'sensor': 4480, 'skeleton': 1879}, Total: 6359
# Results table: (180, 29)
# Methods: 18, Folds per method: {'baseline': 10, 'lasso': 10, 'meta_BAT': 10, 'meta_CS': 10, 'meta_DE': 10, 'meta_FFA': 10, 'meta_GA': 10, 'meta_GWO': 10, 'meta_HHO': 10, 'meta_JAYA': 10, 'meta_MFO': 10, 'meta_MVO': 10, 'meta_PSO': 10, 'meta_SCA': 10, 'meta_SSA': 10, 'meta_WOA': 10, 'mutual_info': 10, 'rfe': 10}
#      Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  \
# 0  baseline     1         100.000000             100.0    100.000000
# 1  baseline     2         100.000000             100.0    100.000000
# 2  baseline     3         100.000000             100.0    100.000000
# 3  baseline     4          97.058824             100.0     97.460317
# 4  baseline     5         100.000000             100.0    100.000000
#
#    F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  \
# 0       100.000000                100.0             100.0               6359
# 1       100.000000                100.0             100.0               6359
# 2       100.000000                100.0             100.0               6359
# 3        97.012138                 98.0              97.5               6359
# 4       100.000000                100.0             100.0               6359
#
#    Features Total  ...  GPU Peak (MB)  N Train  N Val  N Test  \
# 0            6359  ...      54.330566      405     27     184
# 1            6359  ...      54.330566      419     27     170
# 2            6359  ...      54.330566      529     27      60
# 3            6359  ...      54.330566      555     27      34
# 4            6359  ...      54.330566      556     27      33
#
#    sensor_retained  sensor_total  sensor_retention_%  skeleton_retained  \
# 0             4480          4480               100.0               1879
# 1             4480          4480               100.0               1879
# 2             4480          4480               100.0               1879
# 3             4480          4480               100.0               1879
# 4             4480          4480               100.0               1879
#
#    skeleton_total  skeleton_retention_%
# 0            1879                 100.0
# 1            1879                 100.0
# 2            1879                 100.0
# 3            1879                 100.0
# 4            1879                 100.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Per-Method Summary Table (with per-fold detail)

# %%
# Also create a summary table (mean/std across folds)
summary_rows = []
for method_name in ALL_METHODS:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
#    baseline              97.57              3.69              96.92              5.03                  6359.0                      100.00              0.00                53.44                53.44          1089226.0                  4.16                        0.00               54.33
# mutual_info              98.58              3.23              98.23              4.23                  3179.0                       49.99             36.10                49.42                85.52           682186.0                  2.60                       50.01               44.63
#         rfe              97.59              4.40              96.93              5.86                  3179.0                       49.99             10.89                49.36                60.25           682186.0                  2.60                       50.01               44.63
#       lasso              96.29              7.34              95.72              8.73                  3179.0                       49.99            156.60                53.90               210.50           682186.0                  2.60                       50.01               45.31
#    meta_BAT              97.54              4.37              96.57              6.33                  3068.4                       48.25           2936.96                46.98              2983.95           668029.2                  2.55                       51.75               44.85
#     meta_CS              97.97              3.68              97.58              4.66                  3050.6                       47.97           5661.25                48.16              5709.42           665750.8                  2.54                       52.03               44.84
#     meta_DE              96.87              3.81              95.63              5.40                  2954.7                       46.46           2919.54                47.58              2967.13           653475.6                  2.49                       53.54               44.49
#    meta_FFA              97.26              4.32              96.59              5.76                  3046.5                       47.91           2810.57                48.14              2858.70           665226.0                  2.54                       52.09               44.83
#     meta_GA              98.20              3.70              97.78              4.69                  3050.8                       47.98           2725.91                46.90              2772.81           665776.4                  2.54                       52.02               44.84
#    meta_GWO              98.63              3.25              97.47              5.35                  1562.5                       24.57           2895.48                50.70              2946.18           475274.0                  1.81                       75.43               39.69
#    meta_HHO              84.58             18.24              81.91             21.92                    20.0                        0.31           3899.93                50.99              3950.92           277795.6                  1.06                       99.69               35.40
#   meta_JAYA              98.34              3.24              98.03              4.22                  3009.9                       47.33           2907.45                48.52              2955.98           660541.2                  2.52                       52.67               44.75
#    meta_MFO              97.73              4.40              97.02              5.88                  3027.3                       47.61           2778.14                48.33              2826.48           662768.4                  2.53                       52.39               44.79
#    meta_MVO              99.00              3.16              98.67              4.22                  2935.0                       46.16           2869.31                49.63              2918.95           650954.0                  2.48                       53.84               44.51
#    meta_PSO              98.10              3.67              97.63              4.72                  2930.4                       46.08           2867.75                48.69              2916.43           650365.2                  2.48                       53.92               44.28
#    meta_SCA              97.14              4.83              96.48              6.30                   373.9                        5.88           3026.56                53.06              3079.61           323133.2                  1.23                       94.12               36.19
#    meta_SSA              96.26              5.58              94.74              8.56                  2979.4                       46.85           7252.77                49.17              7301.93           656637.2                  2.50                       53.15               44.69
#    meta_WOA              84.20              8.97              81.49             11.32                    27.3                        0.43           2642.15                52.17              2694.31           278768.4                  1.06                       99.57               35.45

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds for each method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()
order = methods_sorted

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=order, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method (bar chart with error bars)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

# Value labels
for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention trade-off (scatter)
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    # Draw mean point larger
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Feature Retention Trade-off', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap (average across folds)
# ============================================================================
modality_data = {}
for method in ALL_METHODS:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# FS time
time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Total time
total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Model size & dataset size comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Model params
param_summary = df_all.groupby('Method')['Model Params'].mean().reindex(ALL_METHODS)
axes[0].bar(param_summary.index, param_summary.values, alpha=0.7, color='mediumpurple')
axes[0].set_ylabel('Model Parameters', fontsize=12)
axes[0].set_title('Average Model Parameters', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

# Dataset reduction
ds_summary = df_all.groupby('Method')['Dataset Reduction (%)'].mean().reindex(ALL_METHODS)
axes[1].bar(ds_summary.index, ds_summary.values, alpha=0.7, color='seagreen')
axes[1].set_ylabel('Dataset Size Reduction (%)', fontsize=12)
axes[1].set_title('Average Dataset Size Reduction', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '07_model_dataset_size.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 07_model_dataset_size.png")
# Out:
# Saved: 07_model_dataset_size.png

# %%
# ============================================================================
# PLOT 8: Metaheuristics-only comparison (grouped bar: accuracy & retention)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_methods)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    # Accuracy
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars = axes[0].bar(range(len(meta_methods)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[0].set_xticks(range(len(meta_methods)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Metaheuristics: Test Accuracy Comparison', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    # Feature retention
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_methods)
    bars2 = axes[1].bar(range(len(meta_methods)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_methods))))
    axes[1].set_xticks(range(len(meta_methods)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_methods], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Metaheuristics: Feature Retention Comparison', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_metaheuristics_comparison.png")
# Out:
# Saved: 08_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 9: Convergence curves for metaheuristics (average across folds)
# ============================================================================
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

if len(meta_methods) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_methods:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            # Pad to same length
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Metaheuristic Convergence Curves (averaged across folds)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '09_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 09_convergence_curves.png")
# Out:
# Saved: 09_convergence_curves.png

# %%
# ============================================================================
# PLOT 10: Feature importance - which features most commonly retained/removed
# ============================================================================
# Count how many times each feature index was selected across all methods and folds
feature_freq = np.zeros(TOTAL_FEATURES)
feature_freq_per_method = {}

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    method_freq = np.zeros(TOTAL_FEATURES)
    count = 0
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            mask = master_results[method][fold_idx]['feature_mask']
            feature_freq += mask.astype(float)
            method_freq += mask.astype(float)
            count += 1
    if count > 0:
        feature_freq_per_method[method] = method_freq / count

# Normalize overall
total_runs = (len(ALL_METHODS) - 1) * N_FOLDS  # exclude baseline
feature_freq_normalized = feature_freq / max(total_runs, 1)

# Plot feature selection frequency
fig, axes = plt.subplots(2, 1, figsize=(18, 10))

# Overall
axes[0].bar(range(TOTAL_FEATURES), feature_freq_normalized, width=1.0, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Feature Index')
axes[0].set_ylabel('Selection Frequency')
axes[0].set_title('Feature Selection Frequency Across All Methods and Folds', fontsize=14)

# Add modality boundaries
start = 0
colors = ['red', 'green', 'blue', 'purple']
for i, (mod, dim) in enumerate(FEATURE_DIMS.items()):
    axes[0].axvline(x=start, color=colors[i], linestyle='--', alpha=0.5, label=f'{mod} start')
    start += dim
axes[0].legend(fontsize=8)
axes[0].grid(axis='y', alpha=0.3)

# Top 20 most and least selected features
top_20_selected = np.argsort(feature_freq_normalized)[::-1][:20]
top_20_removed = np.argsort(feature_freq_normalized)[:20]

x_pos = np.arange(20)
width = 0.35
axes[1].bar(x_pos - width/2, feature_freq_normalized[top_20_selected], width, label='Top 20 Most Selected', color='green', alpha=0.7)
axes[1].bar(x_pos + width/2, feature_freq_normalized[top_20_removed], width, label='Top 20 Least Selected', color='red', alpha=0.7)
axes[1].set_xlabel('Rank')
axes[1].set_ylabel('Selection Frequency')
axes[1].set_title('Most vs Least Frequently Selected Features', fontsize=14)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_feature_frequency.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_feature_frequency.png")

# Save feature frequency data
freq_df = pd.DataFrame({
    'feature_index': range(TOTAL_FEATURES),
    'overall_selection_freq': feature_freq_normalized,
})
# Add modality labels
start = 0
modality_labels = []
for mod, dim in FEATURE_DIMS.items():
    modality_labels.extend([mod] * dim)
freq_df['modality'] = modality_labels
freq_df.to_csv(PLOTS_DIR / 'feature_selection_frequency.csv', index=False)
print("Saved: feature_selection_frequency.csv")
# Out:
# Saved: 10_feature_frequency.png
# Saved: feature_selection_frequency.csv

# %%
# ============================================================================
# PLOT 11: Radar/spider chart comparing methods on multiple metrics
# ============================================================================
from matplotlib.patches import FancyBboxPatch
import matplotlib.patches as mpatches

# Select key metrics for radar
radar_metrics = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Mean Total Time (s)']

# Normalize to [0, 1] for radar
radar_data = df_summary[['Method'] + radar_metrics].copy()
for col in radar_metrics:
    min_val = radar_data[col].min()
    max_val = radar_data[col].max()
    if max_val > min_val:
        radar_data[col] = (radar_data[col] - min_val) / (max_val - min_val)
    else:
        radar_data[col] = 0.5

# For time, invert (lower is better)
radar_data['Mean Total Time (s)'] = 1 - radar_data['Mean Total Time (s)']
radar_data = radar_data.rename(columns={'Mean Total Time (s)': 'Speed (inv. time)'})
radar_cols = ['Mean Test Acc (%)', 'Mean F1 Macro (%)', 'Mean Feature Retention (%)', 'Speed (inv. time)']

# Select subset for readability (standard + top 5 metaheuristics)
top_meta = df_summary[df_summary['Method'].str.startswith('meta_')].nlargest(5, 'Mean Test Acc (%)')['Method'].tolist()
methods_to_plot = ['baseline', 'mutual_info', 'rfe', 'lasso'] + top_meta

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
angles = np.linspace(0, 2 * np.pi, len(radar_cols), endpoint=False).tolist()
angles += angles[:1]

for method in methods_to_plot:
    row = radar_data[radar_data['Method'] == method]
    if len(row) == 0:
        continue
    values = row[radar_cols].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1.5, label=method)
    ax.fill(angles, values, alpha=0.05)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(radar_cols, fontsize=9)
ax.set_title('Multi-Metric Comparison (Normalized)', fontsize=14, pad=20)
ax.legend(bbox_to_anchor=(1.3, 1.1), fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '11_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 11_radar_comparison.png")
# Out:
# Saved: 11_radar_comparison.png

# %%
# ============================================================================
# PLOT 12: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods = ['baseline', 'mutual_info', 'rfe', 'lasso']
meta_methods = [m for m in ALL_METHODS if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

# Group averages
std_accs = df_all[df_all['Method'].isin(standard_methods)].groupby('Method')['Test Accuracy (%)'].mean()
meta_accs = df_all[df_all['Method'].isin(meta_methods)].groupby('Method')['Test Accuracy (%)'].mean()

# Accuracy: standard vs meta
all_std = df_all[df_all['Method'].isin(standard_methods)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

# Feature retention
all_std_f = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

# Time
all_std_t = df_all[(df_all['Method'].isin(standard_methods)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '12_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 12_standard_vs_metaheuristics.png")
# Out:
# Saved: 12_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 13: GPU memory usage comparison
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
gpu_summary = df_all.groupby('Method')['GPU Peak (MB)'].agg(['mean', 'std']).reindex(ALL_METHODS)
bars = ax.bar(gpu_summary.index, gpu_summary['mean'], yerr=gpu_summary['std'], capsize=3, alpha=0.7, color='gold')
ax.set_ylabel('GPU Peak Memory (MB)', fontsize=12)
ax.set_title('GPU Peak Memory Usage by Method', fontsize=16)
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '13_gpu_memory.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 13_gpu_memory.png")
# Out:
# Saved: 13_gpu_memory.png

# %%
# ============================================================================
# PLOT 14: Per-fold accuracy line plot (all methods)
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['baseline', 'mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Test Accuracy Across Folds (All Methods)', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '14_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 14_per_fold_accuracy_lines.png")
# Out:
# Saved: 14_per_fold_accuracy_lines.png

# %% [markdown]
# ## Statistical Significance Tests

# %%
from scipy.stats import ttest_rel, wilcoxon

print("\n" + "="*80)
print("STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)")
print("="*80)

baseline_accs = []
for fold_idx in range(N_FOLDS):
    if fold_idx in master_results['baseline']:
        baseline_accs.append(master_results['baseline'][fold_idx]['test_acc'] * 100)

stat_rows = []

for method in ALL_METHODS:
    if method == 'baseline':
        continue
    
    method_accs = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in master_results[method]:
            method_accs.append(master_results[method][fold_idx]['test_acc'] * 100)
    
    if len(method_accs) != len(baseline_accs):
        continue
    
    try:
        t_stat, p_value_t = ttest_rel(method_accs, baseline_accs)
    except:
        t_stat, p_value_t = 0, 1
    
    try:
        w_stat, p_value_w = wilcoxon(method_accs, baseline_accs)
    except:
        w_stat, p_value_w = 0, 1
    
    direction = "better" if np.mean(method_accs) > np.mean(baseline_accs) else "worse"
    significant = "Yes" if p_value_t < 0.05 else "No"
    
    stat_rows.append({
        'Method': method,
        'Mean Acc (%)': np.mean(method_accs),
        'Baseline Acc (%)': np.mean(baseline_accs),
        'Diff (%)': np.mean(method_accs) - np.mean(baseline_accs),
        't-stat': t_stat,
        'p-value (t-test)': p_value_t,
        'W-stat': w_stat,
        'p-value (Wilcoxon)': p_value_w,
        'Direction': direction,
        'Significant (p<0.05)': significant,
    })
    
    print(f"\n{method.upper()} vs BASELINE:")
    print(f"  Method: {np.mean(method_accs):.2f}% vs Baseline: {np.mean(baseline_accs):.2f}%")
    print(f"  Paired t-test: t={t_stat:.4f}, p={p_value_t:.4f}")
    print(f"  Wilcoxon test: W={w_stat:.4f}, p={p_value_w:.4f}")
    print(f"  -> {direction}, {'Significant' if significant == 'Yes' else 'Not significant'}")

stat_df = pd.DataFrame(stat_rows).round(4)
stat_df.to_csv(RESULTS_ROOT / "statistical_tests.csv", index=False)
print(f"\nSaved: statistical_tests.csv")
print("\n" + "="*80)
# Out:
# ================================================================================
# STATISTICAL SIGNIFICANCE TESTS (each method vs baseline)
# ================================================================================
#
# MUTUAL_INFO vs BASELINE:
#   Method: 98.58% vs Baseline: 97.57%
#   Paired t-test: t=1.2576, p=0.2402
#   Wilcoxon test: W=1.0000, p=0.5000
#   -> better, Not significant
#
# RFE vs BASELINE:
#   Method: 97.59% vs Baseline: 97.57%
#   Paired t-test: t=0.0162, p=0.9874
#   Wilcoxon test: W=5.0000, p=1.0000
#   -> better, Not significant
#
# LASSO vs BASELINE:
#   Method: 96.29% vs Baseline: 97.57%
#   Paired t-test: t=-0.7242, p=0.4873
#   Wilcoxon test: W=7.0000, p=0.5625
#   -> worse, Not significant
#
# META_BAT vs BASELINE:
#   Method: 97.54% vs Baseline: 97.57%
#   Paired t-test: t=-0.0229, p=0.9822
#   Wilcoxon test: W=3.0000, p=1.0000
#   -> worse, Not significant
#
# META_CS vs BASELINE:
#   Method: 97.97% vs Baseline: 97.57%
#   Paired t-test: t=0.4481, p=0.6647
#   Wilcoxon test: W=1.0000, p=1.0000
#   -> better, Not significant
#
# META_DE vs BASELINE:
#   Method: 96.87% vs Baseline: 97.57%
#   Paired t-test: t=-0.7653, p=0.4637
#   Wilcoxon test: W=2.0000, p=0.7500
#   -> worse, Not significant
#
# META_FFA vs BASELINE:
#   Method: 97.26% vs Baseline: 97.57%
#   Paired t-test: t=-0.2595, p=0.8011
#   Wilcoxon test: W=3.0000, p=1.0000
#   -> worse, Not significant
#
# META_GA vs BASELINE:
#   Method: 98.20% vs Baseline: 97.57%
#   Paired t-test: t=0.6871, p=0.5094
#   Wilcoxon test: W=4.0000, p=0.8750
#   -> better, Not significant
#
# META_GWO vs BASELINE:
#   Method: 98.63% vs Baseline: 97.57%
#   Paired t-test: t=1.3419, p=0.2125
#   Wilcoxon test: W=0.0000, p=0.5000
#   -> better, Not significant
#
# META_HHO vs BASELINE:
#   Method: 84.58% vs Baseline: 97.57%
#   Paired t-test: t=-2.3041, p=0.0467
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# META_JAYA vs BASELINE:
#   Method: 98.34% vs Baseline: 97.57%
#   Paired t-test: t=1.0000, p=0.3434
#   Wilcoxon test: W=0.0000, p=1.0000
#   -> better, Not significant
#
# META_MFO vs BASELINE:
#   Method: 97.73% vs Baseline: 97.57%
#   Paired t-test: t=0.1353, p=0.8953
#   Wilcoxon test: W=4.0000, p=0.8750
#   -> better, Not significant
#
# META_MVO vs BASELINE:
#   Method: 99.00% vs Baseline: 97.57%
#   Paired t-test: t=1.7417, p=0.1155
#   Wilcoxon test: W=0.0000, p=0.2500
#   -> better, Not significant
#
# META_PSO vs BASELINE:
#   Method: 98.10% vs Baseline: 97.57%
#   Paired t-test: t=0.5573, p=0.5909
#   Wilcoxon test: W=4.0000, p=0.8750
#   -> better, Not significant
#
# META_SCA vs BASELINE:
#   Method: 97.14% vs Baseline: 97.57%
#   Paired t-test: t=-0.2552, p=0.8043
#   Wilcoxon test: W=5.0000, p=1.0000
#   -> worse, Not significant
#
# META_SSA vs BASELINE:
#   Method: 96.26% vs Baseline: 97.57%
#   Paired t-test: t=-1.1325, p=0.2867
#   Wilcoxon test: W=1.0000, p=0.5000
#   -> worse, Not significant
#
# META_WOA vs BASELINE:
#   Method: 84.20% vs Baseline: 97.57%
#   Paired t-test: t=-4.2188, p=0.0022
#   Wilcoxon test: W=0.0000, p=0.0078
#   -> worse, Significant
#
# Saved: statistical_tests.csv
#
# ================================================================================

# %% [markdown]
# ## Final Summary

# %%
print("\n" + "="*80)
print("EXPERIMENT COMPLETE - RESULTS SUMMARY")
print("="*80)

print(f"\nOutput directory: {RESULTS_ROOT}")
print(f"\nPer-method folders:")
for method in ALL_METHODS:
    method_dir = RESULTS_ROOT / method
    n_files = len(list(method_dir.glob('*')))
    print(f"  {method_dir}/ ({n_files} files)")

print(f"\nPlots directory: {PLOTS_DIR}")
for p in sorted(PLOTS_DIR.glob('*.png')):
    print(f"  {p.name}")

print(f"\nCSV files:")
for p in sorted(RESULTS_ROOT.glob('*.csv')):
    print(f"  {p.name}")

print(f"\n{'='*80}")
print("KEY FILES:")
print(f"  - all_results_per_fold.csv : Every metric for every fold x method")
print(f"  - summary_all_methods.csv  : Aggregated summary")
print(f"  - statistical_tests.csv    : Significance tests vs baseline")
print(f"  - Per-method folders       : Individual fold JSONs + feature masks")
print(f"  - plots/                   : 14 comprehensive visualizations")
print(f"{'='*80}")

# Print top 5 methods by mean accuracy
print("\nTOP 5 METHODS BY MEAN TEST ACCURACY:")
top5 = df_summary.nlargest(5, 'Mean Test Acc (%)')
for i, row in top5.iterrows():
    print(f"  {row['Method']:20s}: {row['Mean Test Acc (%)']:.2f}% ± {row['Std Test Acc (%)']:.2f}% "
          f"(Features: {row['Mean Feature Retention (%)']:.1f}%)")
# Out:
# ================================================================================
# EXPERIMENT COMPLETE - RESULTS SUMMARY
# ================================================================================
#
# Output directory: results_transformer
#
# Per-method folders:
#   results_transformer/baseline/ (20 files)
#   results_transformer/mutual_info/ (20 files)
#   results_transformer/rfe/ (20 files)
#   results_transformer/lasso/ (20 files)
#   results_transformer/meta_BAT/ (20 files)
#   results_transformer/meta_CS/ (20 files)
#   results_transformer/meta_DE/ (20 files)
#   results_transformer/meta_FFA/ (20 files)
#   results_transformer/meta_GA/ (20 files)
#   results_transformer/meta_GWO/ (20 files)
#   results_transformer/meta_HHO/ (20 files)
#   results_transformer/meta_JAYA/ (20 files)
#   results_transformer/meta_MFO/ (20 files)
#   results_transformer/meta_MVO/ (20 files)
#   results_transformer/meta_PSO/ (20 files)
#   results_transformer/meta_SCA/ (20 files)
#   results_transformer/meta_SSA/ (20 files)
#   results_transformer/meta_WOA/ (20 files)
#
# Plots directory: results_transformer/plots
#   01_accuracy_heatmap.png
#   02_accuracy_boxplot.png
#   03_feature_retention.png
#   04_accuracy_vs_retention.png
#   05_modality_retention_heatmap.png
#   06_execution_time.png
#   07_model_dataset_size.png
#   08_metaheuristics_comparison.png
#   09_convergence_curves.png
#   10_feature_frequency.png
#   11_radar_comparison.png
#   12_standard_vs_metaheuristics.png
#   13_gpu_memory.png
#   14_per_fold_accuracy_lines.png
#
# CSV files:
#   all_folds_results.csv
#   statistical_tests.csv
#   summary_all_methods.csv
#
# ================================================================================
# KEY FILES:
#   - all_results_per_fold.csv : Every metric for every fold x method
#   - summary_all_methods.csv  : Aggregated summary
#   - statistical_tests.csv    : Significance tests vs baseline
#   - Per-method folders       : Individual fold JSONs + feature masks
#   - plots/                   : 14 comprehensive visualizations
# ================================================================================
#
# TOP 5 METHODS BY MEAN TEST ACCURACY:
#   meta_MVO            : 99.00% ± 3.16% (Features: 46.2%)
#   meta_GWO            : 98.63% ± 3.25% (Features: 24.6%)
#   mutual_info         : 98.58% ± 3.23% (Features: 50.0%)
#   meta_JAYA           : 98.34% ± 3.24% (Features: 47.3%)
#   meta_GA             : 98.20% ± 3.70% (Features: 48.0%)

# %%
# ============================================================================
# BEST METAHEURISTIC PER FOLD: F1 Macro
# ============================================================================

df_all = pd.read_csv(RESULTS_ROOT / "all_folds_results.csv")

meta_methods   = sorted([m for m in df_all['Method'].unique() if m.startswith('meta_')])
fold_ids       = sorted(df_all['Fold'].unique())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)")
print("=" * 90)

best_per_fold = []

for fold in fold_ids:
    fold_df = df_all[(df_all['Fold'] == fold) & (df_all['Method'].isin(meta_methods))]
    if fold_df.empty:
        print(f"\n  Fold {fold}: No metaheuristic results found!")
        continue

    best_row = fold_df.loc[fold_df['F1 Macro (%)'].idxmax()]

    entry = {
        'Fold':                   fold,
        'Best Metaheuristic':     best_row['Method'],
        'F1 Macro (%)':           best_row['F1 Macro (%)'],
        'F1 Weighted (%)':        best_row['F1 Weighted (%)'],
        'Test Accuracy (%)':      best_row['Test Accuracy (%)'],
        'Feature Retention (%)':  best_row['Feature Retention (%)'],
        'Features Selected':      best_row['Features Selected'],
        'Features Total':         best_row['Features Total'],
    }

    # Per-modality retention — grab whatever *_retention_% columns exist
    mod_cols = [c for c in df_all.columns if c.endswith('_retention_%')]
    for col in mod_cols:
        entry[col] = best_row[col]

    best_per_fold.append(entry)

    mod_str = ', '.join([f"{c.replace('_retention_%','')}={best_row[c]:.1f}%"
                         for c in mod_cols])
    print(f"\n  Fold {fold}: Best = {best_row['Method']}")
    print(f"    F1 Macro:           {entry['F1 Macro (%)']:.2f}%")
    print(f"    F1 Weighted:        {entry['F1 Weighted (%)']:.2f}%")
    print(f"    Test Accuracy:      {entry['Test Accuracy (%)']:.2f}%")
    print(f"    Feature Retention:  {entry['Feature Retention (%)']:.2f}%"
          f" ({int(entry['Features Selected'])}/{int(entry['Features Total'])})")
    if mod_str:
        print(f"    Modality Retention: {mod_str}")

# ============================================================================
# AVERAGE ACROSS FOLDS
# ============================================================================
df_best = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)")
print("=" * 90)

for col, label in [
    ('F1 Macro (%)',          'Average F1 Macro'),
    ('F1 Weighted (%)',       'Average F1 Weighted'),
    ('Test Accuracy (%)',     'Average Test Accuracy'),
    ('Feature Retention (%)', 'Average Feature Retention'),
]:
    print(f"\n  {label:28s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

mod_cols = [c for c in df_best.columns if c.endswith('_retention_%')]
if mod_cols:
    print(f"\n  Average Modality-wise Feature Retention:")
    for col in mod_cols:
        mod = col.replace('_retention_%', '')
        print(f"    {mod:>12s}: {df_best[col].mean():.2f}% ± {df_best[col].std():.2f}%")

# ============================================================================
# SUMMARY TABLE
# ============================================================================
print("\n" + "=" * 90)
print("PER-FOLD SUMMARY TABLE")
print("=" * 90)

display_cols = ['Fold', 'Best Metaheuristic', 'F1 Macro (%)', 'F1 Weighted (%)',
                'Test Accuracy (%)', 'Feature Retention (%)'] + mod_cols
print(df_best[display_cols].to_string(index=False, float_format='%.2f'))

csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
df_best.to_csv(csv_path, index=False)
print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD (selected by highest F1 Macro)
# ==========================================================================================
#
#   Fold 1: Best = meta_CS
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  47.55% (3024/6359)
#     Modality Retention: sensor=47.7%, skeleton=47.2%
#
#   Fold 2: Best = meta_BAT
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  48.83% (3105/6359)
#     Modality Retention: sensor=49.4%, skeleton=47.5%
#
#   Fold 3: Best = meta_BAT
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  48.42% (3079/6359)
#     Modality Retention: sensor=48.7%, skeleton=47.8%
#
#   Fold 4: Best = meta_GA
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  49.39% (3141/6359)
#     Modality Retention: sensor=49.2%, skeleton=49.9%
#
#   Fold 5: Best = meta_BAT
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  48.33% (3073/6359)
#     Modality Retention: sensor=48.1%, skeleton=49.0%
#
#   Fold 6: Best = meta_BAT
#     F1 Macro:           86.67%
#     F1 Weighted:        86.67%
#     Test Accuracy:      90.00%
#     Feature Retention:  47.85% (3043/6359)
#     Modality Retention: sensor=48.2%, skeleton=47.0%
#
#   Fold 7: Best = meta_BAT
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  48.73% (3099/6359)
#     Modality Retention: sensor=48.7%, skeleton=48.9%
#
#   Fold 8: Best = meta_MVO
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  45.59% (2899/6359)
#     Modality Retention: sensor=46.1%, skeleton=44.3%
#
#   Fold 9: Best = meta_BAT
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  48.67% (3095/6359)
#     Modality Retention: sensor=48.8%, skeleton=48.4%
#
#   Fold 10: Best = meta_BAT
#     F1 Macro:           100.00%
#     F1 Weighted:        100.00%
#     Test Accuracy:      100.00%
#     Feature Retention:  47.54% (3023/6359)
#     Modality Retention: sensor=47.6%, skeleton=47.3%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold)
# ==========================================================================================
#
#   Average F1 Macro            : 98.67% ± 4.22%
#
#   Average F1 Weighted         : 98.67% ± 4.22%
#
#   Average Test Accuracy       : 99.00% ± 3.16%
#
#   Average Feature Retention   : 48.09% ± 1.06%
#
#   Average Modality-wise Feature Retention:
#           sensor: 48.24% ± 0.94%
#         skeleton: 47.73% ± 1.53%
#
# ==========================================================================================
# PER-FOLD SUMMARY TABLE
# ==========================================================================================
#  Fold Best Metaheuristic  F1 Macro (%)  F1 Weighted (%)  Test Accuracy (%)  Feature Retention (%)  sensor_retention_%  skeleton_retention_%
#     1            meta_CS        100.00           100.00             100.00                  47.55               47.70                 47.21
#     2           meta_BAT        100.00           100.00             100.00                  48.83               49.40                 47.47
#     3           meta_BAT        100.00           100.00             100.00                  48.42               48.68                 47.79
#     4            meta_GA        100.00           100.00             100.00                  49.39               49.17                 49.92
#     5           meta_BAT        100.00           100.00             100.00                  48.33               48.06                 48.96
#     6           meta_BAT         86.67            86.67              90.00                  47.85               48.19                 47.05
#     7           meta_BAT        100.00           100.00             100.00                  48.73               48.66                 48.91
#     8           meta_MVO        100.00           100.00             100.00                  45.59               46.14                 44.28
#     9           meta_BAT        100.00           100.00             100.00                  48.67               48.77                 48.43
#    10           meta_BAT        100.00           100.00             100.00                  47.54               47.63                 47.31
#
# Saved to: results_transformer/best_metaheuristic_per_fold.csv
