# %% [markdown]
# # MM-Fit: Two-Layer Feature Selection (Per-Modality → Combined)
#
# ## Overview
# This notebook implements a **two-layer feature selection** pipeline:
#
# **Layer 1 (already done):** Feature selection was run independently on each modality (depth, sensor, skeleton, video). Results are stored in:
# - `results_new_inertial/`
# - `results_new_skeleton/`
#
# **Layer 2 (this notebook):**
# 1. **Combine** the selected features from each modality into a unified feature set
# 2. **Evaluate** the combined features (Layer 1 result) on HAR
# 3. **Run a second layer** of feature selection on the combined set
#
# ### Combination Strategy:
# - **Standard methods** (mutual_info, rfe, lasso): Combine features selected by the *same* method across all 4 modalities. Then run the same FS method again on the combined set.
# - **Metaheuristics**: For each fold, find the *best* metaheuristic (highest test accuracy) per modality. Combine those best-selected features. Then run all 14 metaheuristics on that combined set.
# - **Baseline**: Combine all baseline (all features) from each modality = full feature set.
#
# All results saved in `results_two_layer/`.

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time
import warnings
from pathlib import Path
from tqdm import tqdm
from copy import deepcopy
import random
import sys
from scipy import stats
import psutil
import tracemalloc
import gc
import json as json_lib

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score,
                             precision_score, recall_score, classification_report)

# Standard feature selection imports
from sklearn.feature_selection import mutual_info_classif, RFE, SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Import ALL EvoloPy optimizers
sys.path.append('../EvoloPy-master')
from EvoloPy.optimizers import BAT, CS, DE, FFA, GA, GWO, HHO, JAYA, MFO, MVO, PSO, SCA, SSA, WOA

warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Global device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"PyTorch version: {torch.__version__}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# PyTorch version: 2.6.0+cu124
# GPU: NVIDIA GeForce GTX 1080 Ti

# %% [markdown]
# ## Configuration

# %%
# Paths
FEATURE_DIR = Path("features")

# Layer 1 results directories (already computed)
LAYER1_DIRS = {
    'sensor': Path("results_inertial"),
    'skeleton': Path("results_skeleton"),
}

# Master output directory for two-layer results
RESULTS_ROOT = Path("results_two_layer")
RESULTS_ROOT.mkdir(exist_ok=True)
PLOTS_DIR = RESULTS_ROOT / "plots"
PLOTS_DIR.mkdir(exist_ok=True)

# Hyperparameters (same as original)
N_FOLDS = 10
N_EPOCHS = 300
BATCH_SIZE = 32
LEARNING_RATE = 0.001
HIDDEN_DIM = 128

# Feature selection hyperparameters - metaheuristic
N_POPULATION = 20
MAX_ITERATIONS = 30

# For standard methods (target: select ~50% of combined features)
TARGET_FEATURE_PERCENTAGE = 0.5

DEPTH_PCA_DIM = 512
DEPTH_DR_METHOD = 'kernel_pca'

# All EvoloPy optimizer names and their callable entry points
EVOLOPY_OPTIMIZERS = {
    'BAT': BAT.BAT,
    'CS':  CS.CS,
    'DE':  DE.DE,
    'FFA': FFA.FFA,
    'GA':  GA.GA,
    'GWO': GWO.GWO,
    'HHO': HHO.HHO,
    'JAYA': JAYA.JAYA,
    'MFO': MFO.MFO,
    'MVO': MVO.MVO,
    'PSO': PSO.PSO,
    'SCA': SCA.SCA,
    'SSA': SSA.SSA,
    'WOA': WOA.WOA,
}

STANDARD_METHODS = ['mutual_info', 'rfe', 'lasso']
META_METHODS = [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]
# For layer 2, we have: baseline, 3 standard methods, and meta_best (which runs all 14 metas)
# Output method names for layer 2:
ALL_METHODS_L2 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

# Create per-method subdirectories
for method in ALL_METHODS_L2:
    (RESULTS_ROOT / method).mkdir(exist_ok=True)
# Also create combined_layer1 directory
(RESULTS_ROOT / "combined_layer1").mkdir(exist_ok=True)

print(f"Configuration:")
print(f"  N_FOLDS: {N_FOLDS}")
print(f"  N_EPOCHS: {N_EPOCHS}")
print(f"  Target feature selection (Layer 2): {TARGET_FEATURE_PERCENTAGE*100:.0f}%")
print(f"  Metaheuristic pop: {N_POPULATION}, iter: {MAX_ITERATIONS}")
print(f"  EvoloPy optimizers: {list(EVOLOPY_OPTIMIZERS.keys())}")
print(f"  Layer 1 dirs: {list(LAYER1_DIRS.keys())}")

# Verify layer 1 directories exist
for mod, d in LAYER1_DIRS.items():
    if d.exists():
        print(f"{d} exists")
    else:
        print(f"{d} MISSING!")
# Out:
# Configuration:
#   N_FOLDS: 10
#   N_EPOCHS: 300
#   Target feature selection (Layer 2): 50%
#   Metaheuristic pop: 20, iter: 30
#   EvoloPy optimizers: ['BAT', 'CS', 'DE', 'FFA', 'GA', 'GWO', 'HHO', 'JAYA', 'MFO', 'MVO', 'PSO', 'SCA', 'SSA', 'WOA']
#   Layer 1 dirs: ['sensor', 'skeleton']
# results_inertial exists
# results_skeleton exists

# %% [markdown]
# ## Load Data

# %%
# Load features
X_feat = joblib.load(FEATURE_DIR / "X_feat.pkl")
y = np.load(FEATURE_DIR / "y.npy")
subjects = np.load(FEATURE_DIR / "participants.npy")
le = joblib.load(FEATURE_DIR / "label_encoder.pkl")
print(f"Loaded {len(X_feat)} samples")
print(f"Number of classes: {len(np.unique(y))}")
print(f"Number of subjects: {len(np.unique(subjects))}")

# Get feature dimensions
first_sample = X_feat[0]
FEATURE_DIMS = {
    'sensor': first_sample['sensor_feat'].shape[0],
    'skeleton': first_sample['skeleton_feat'].shape[0]
}
TOTAL_FEATURES = sum(FEATURE_DIMS.values())
print(f"\nFeature dimensions:")
for modality, dim in FEATURE_DIMS.items():
    print(f"  {modality}: {dim}")
print(f"  TOTAL: {TOTAL_FEATURES}")

# Compute modality offsets in the unified feature vector
MODALITY_OFFSETS = {}
offset = 0
for mod, dim in FEATURE_DIMS.items():
    MODALITY_OFFSETS[mod] = (offset, offset + dim)
    offset += dim
print(f"\nModality offsets in unified vector:")
for mod, (s, e) in MODALITY_OFFSETS.items():
    print(f"  {mod}: [{s}, {e})")

# Store raw per-modality feature dims (before PCA)
MODALITY_KEYS = ['sensor_feat', 'skeleton_feat']
MODALITY_NAMES = list(FEATURE_DIMS.keys())
RAW_FEATURE_DIMS = {name: first_sample[key].shape[0] for key, name in zip(MODALITY_KEYS, MODALITY_NAMES)}

# Store per-modality arrays (N_samples x D_modality) for per-modality pipeline
X_per_modality = {}
for key, name in zip(MODALITY_KEYS, MODALITY_NAMES):
    X_per_modality[name] = np.array([s[key] for s in X_feat])

print(f"\nRaw feature dimensions (before depth PCA):")
for name, dim in RAW_FEATURE_DIMS.items():
    print(f"  {name}: {dim}")
print(f"  Depth PCA target: {DEPTH_PCA_DIM}")
# Out:
# Loaded 616 samples
# Number of classes: 10
# Number of subjects: 10
#
# Feature dimensions:
#   sensor: 4480
#   skeleton: 1879
#   TOTAL: 6359
#
# Modality offsets in unified vector:
#   sensor: [0, 4480)
#   skeleton: [4480, 6359)
#
# Raw feature dimensions (before depth PCA):
#   sensor: 4480
#   skeleton: 1879
#   Depth PCA target: 512

# %% [markdown]
# ## Neural Network Model

# %%
class MultiModalDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.FloatTensor(features)
        self.labels = torch.LongTensor(labels)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


class SimpleNN(nn.Module):
    """MLP for unified feature vector (adaptive to feature subset size)"""
    def __init__(self, input_dim, num_classes):
        super().__init__()
        
        # Adaptive hidden layer sizing based on input dimension
        hidden1 = max(128, min(512, input_dim * 2))
        hidden2 = max(64, min(256, hidden1 // 2))
        
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden2, num_classes)
        )
    
    def forward(self, x):
        return self.classifier(x)

print("Neural network model defined")
# Out:
# Neural network model defined

# %% [markdown]
# ## Helper Functions

# %%
def prepare_unified_features(X_feat_list, feature_mask=None):
    """Concatenate all modality features into unified vector"""
    unified_features = []
    
    for sample in X_feat_list:
        feat_vector = np.concatenate([
            sample['sensor_feat'],
            sample['skeleton_feat']
        ])
        
        if feature_mask is not None:
            feat_vector = feat_vector[feature_mask]
        
        unified_features.append(feat_vector)
    
    return np.array(unified_features)

def calculate_modality_retention(binary_mask, feature_dims):
    """Calculate how many features retained per modality"""
    start_idx = 0
    retention = {}
    
    for modality, dim in feature_dims.items():
        end_idx = start_idx + dim
        modality_mask = binary_mask[start_idx:end_idx]
        num_selected = np.sum(modality_mask)
        percentage = (num_selected / dim) * 100
        
        retention[modality] = {
            'selected': int(num_selected),
            'total': dim,
            'percentage': percentage
        }
        start_idx = end_idx
    
    return retention

def count_model_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_model_size_mb(model):
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())
    return (param_size + buffer_size) / (1024 ** 2)

def get_gpu_memory_mb():
    if torch.cuda.is_available():
        return torch.cuda.memory_allocated() / (1024 ** 2)
    return 0.0

def get_dataset_size_mb(X):
    return X.nbytes / (1024 ** 2)

def prepare_fold_data_per_modality(X_per_modality, train_idx, val_idx, test_idx,
                                    depth_pca_dim=None):
    """
    Per-modality pipeline: split -> normalize per modality -> KernelPCA on depth -> concatenate.

    Returns:
        X_train, X_val, X_test: normalized (and PCA-reduced) concatenated arrays
        feature_dims: dict of {modality: dim} AFTER PCA
        pca_obj: fitted KernelPCA object (or None)
    """
    modality_train = {}
    modality_val = {}
    modality_test = {}
    pca_obj = None
    feature_dims = {}

    for name in MODALITY_NAMES:
        X_mod = X_per_modality[name]

        # Split
        X_tr = X_mod[train_idx]
        X_v  = X_mod[val_idx]
        X_te = X_mod[test_idx]

        # Per-modality normalization (fit on train only)
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_v  = scaler.transform(X_v)
        X_te = scaler.transform(X_te)

        # KernelPCA on depth only
        if name == 'depth' and depth_pca_dim is not None and depth_pca_dim < X_tr.shape[1]:
            pca_obj = KernelPCA(n_components=depth_pca_dim, kernel='rbf',
                                random_state=42, n_jobs=-1)
            X_tr = pca_obj.fit_transform(X_tr)
            X_v  = pca_obj.transform(X_v)
            X_te = pca_obj.transform(X_te)
            print(f"    KernelPCA on depth: {RAW_FEATURE_DIMS['depth']} -> {depth_pca_dim}")

        modality_train[name] = X_tr
        modality_val[name]   = X_v
        modality_test[name]  = X_te
        feature_dims[name]   = X_tr.shape[1]

    # Concatenate: depth | sensor | skeleton | video
    X_train = np.concatenate([modality_train[n] for n in MODALITY_NAMES], axis=1)
    X_val   = np.concatenate([modality_val[n]   for n in MODALITY_NAMES], axis=1)
    X_test  = np.concatenate([modality_test[n]  for n in MODALITY_NAMES], axis=1)

    total = sum(feature_dims.values())
    print(f"    Feature dims after processing: " +
          " | ".join(f"{n}={feature_dims[n]}" for n in MODALITY_NAMES) +
          f" | TOTAL={total}")

    return X_train, X_val, X_test, feature_dims, pca_obj


print("Helper functions defined (with per-modality normalization + KernelPCA on depth)")
# Out:
# Helper functions defined (with per-modality normalization + KernelPCA on depth)

# %% [markdown]
# ## Enhanced Evaluation

# %%
def train_and_evaluate_full(model, train_loader, val_loader, test_loader, num_epochs, lr, num_classes):
    """Train model and return comprehensive metrics including predictions for confusion matrix"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    gpu_mem_before = get_gpu_memory_mb()
    train_start = time.time()

    train_losses = []
    best_val_acc = -1.0
    best_model_state = None
    
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0

        for features, labels in train_loader:
            features = features.to(DEVICE)
            labels = labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        train_losses.append(epoch_loss / len(train_loader))

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features = features.to(DEVICE)
                outputs = model(features)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds.cpu() == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_acc = val_correct / val_total

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            best_model_state = deepcopy(model.state_dict())
    
    train_time = time.time() - train_start
    gpu_mem_after = get_gpu_memory_mb()

    model.load_state_dict(best_model_state)
    
    model.eval()
    with torch.no_grad():
        val_preds, val_true = [], []
        for features, labels in val_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            val_preds.extend(preds)
            val_true.extend(labels.numpy())
        
        test_preds, test_true = [], []
        for features, labels in test_loader:
            features = features.to(DEVICE)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            test_preds.extend(preds)
            test_true.extend(labels.numpy())
    
    val_acc = accuracy_score(val_true, val_preds)
    test_acc = accuracy_score(test_true, test_preds)
    
    metrics = {
        'val_acc': val_acc,
        'test_acc': test_acc,
        'test_f1_macro': f1_score(test_true, test_preds, average='macro', zero_division=0),
        'test_f1_weighted': f1_score(test_true, test_preds, average='weighted', zero_division=0),
        'test_precision_macro': precision_score(test_true, test_preds, average='macro', zero_division=0),
        'test_recall_macro': recall_score(test_true, test_preds, average='macro', zero_division=0),
        'test_preds': np.array(test_preds),
        'test_true': np.array(test_true),
        'val_preds': np.array(val_preds),
        'val_true': np.array(val_true),
        'train_time_sec': train_time,
        'gpu_mem_before_mb': gpu_mem_before,
        'gpu_mem_after_mb': gpu_mem_after,
        'gpu_mem_peak_mb': torch.cuda.max_memory_allocated() / (1024**2) if torch.cuda.is_available() else 0,
        'model_params': count_model_parameters(model),
        'model_size_mb': get_model_size_mb(model),
        'train_losses': train_losses,
    }
    return metrics

print("Enhanced evaluation function defined")
# Out:
# Enhanced evaluation function defined

# %% [markdown]
# ## Load Layer 1 Results (Pre-computed Per-Modality Feature Selection)
#
# Load the feature masks from each modality's per-fold results.

# %%
def load_layer1_masks():
    """
    Load all Layer 1 feature masks from per-modality results directories.
    
    Returns:
        layer1_masks: dict[modality][method][fold_idx] = binary_mask (numpy bool array)
        layer1_results: dict[modality][method][fold_idx] = json_results (dict)
    """
    layer1_masks = {}
    layer1_results = {}
    
    all_methods_l1 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]
    
    for modality, results_dir in LAYER1_DIRS.items():
        layer1_masks[modality] = {}
        layer1_results[modality] = {}
        
        for method in all_methods_l1:
            layer1_masks[modality][method] = {}
            layer1_results[modality][method] = {}
            
            method_dir = results_dir / method
            if not method_dir.exists():
                print(f"  WARNING: {method_dir} does not exist!")
                continue
            
            for fold_idx in range(N_FOLDS):
                mask_path = method_dir / f"fold_{fold_idx+1}_mask.npy"
                json_path = method_dir / f"fold_{fold_idx+1}.json"
                
                if mask_path.exists():
                    mask = np.load(mask_path)
                    layer1_masks[modality][method][fold_idx] = mask
                else:
                    print(f"  WARNING: Missing mask: {mask_path}")
                
                if json_path.exists():
                    with open(json_path) as f:
                        layer1_results[modality][method][fold_idx] = json_lib.load(f)
    
    return layer1_masks, layer1_results

layer1_masks, layer1_results = load_layer1_masks()

# Summary
print("\n" + "="*80)
print("LAYER 1 MASKS LOADED")
print("="*80)
modalities = list(LAYER1_DIRS.keys())
all_methods_l1 = ['mutual_info', 'rfe', 'lasso'] + [f'meta_{k}' for k in EVOLOPY_OPTIMIZERS.keys()]

for modality in modalities:
    n_loaded = sum(
        len(layer1_masks[modality].get(m, {})) 
        for m in all_methods_l1
    )
    print(f"  {modality}: {n_loaded} fold-masks loaded across {len(all_methods_l1)} methods")
# Out:
# ================================================================================
# LAYER 1 MASKS LOADED
# ================================================================================
#   sensor: 170 fold-masks loaded across 17 methods
#   skeleton: 170 fold-masks loaded across 17 methods

# %% [markdown]
# ## Combine Layer 1 Selected Features Into Unified Masks
#
# ### Strategy:
# - **Standard methods** (mutual_info, rfe, lasso): For each fold, take the selected features from the same method in each modality and combine them (union into unified feature space).
# - **Metaheuristics**: For each fold, find the best metaheuristic per modality (highest test accuracy), then combine those best-selected features.
# - **Baseline**: All features from all modalities (full feature set).
#
# The combined mask is over the full unified feature space (depth + sensor + skeleton + video).

# %%
def build_combined_mask_standard(method, fold_idx):
    """
    For a standard method, combine selected features from the same method 
    across all 4 modalities into a unified mask over the full feature space.
    
    Each modality mask is a boolean array over that modality's features only.
    We map them to their correct positions in the unified vector.
    """
    unified_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    
    for modality in modalities:
        if method not in layer1_masks[modality]:
            continue
        if fold_idx not in layer1_masks[modality][method]:
            continue
        
        mod_mask = layer1_masks[modality][method][fold_idx]
        start, end = MODALITY_OFFSETS[modality]
        mod_dim = end - start
        
        # The modality mask length should match the modality dimension
        if len(mod_mask) == mod_dim:
            unified_mask[start:end] = mod_mask
        else:
            print(f"  WARNING: {modality}/{method}/fold_{fold_idx+1} mask length "
                  f"{len(mod_mask)} != expected {mod_dim}")
    
    return unified_mask


def find_best_meta_per_modality(fold_idx):
    """
    For a given fold, find which metaheuristic gave the highest test accuracy
    in each modality. Returns dict[modality] = (best_method_name, test_acc).
    """
    best_per_mod = {}
    
    for modality in modalities:
        best_method = None
        best_acc = -1.0
        
        for method in META_METHODS:
            if method not in layer1_results[modality]:
                continue
            if fold_idx not in layer1_results[modality][method]:
                continue
            
            result = layer1_results[modality][method][fold_idx]
            test_acc = result.get('test_acc', 0)
            
            if test_acc > best_acc:
                best_acc = test_acc
                best_method = method
        
        best_per_mod[modality] = (best_method, best_acc)
    
    return best_per_mod


def build_combined_mask_best_meta(fold_idx):
    """
    For metaheuristics: find best meta per modality for this fold,
    then combine their selected features into a unified mask.
    """
    unified_mask = np.zeros(TOTAL_FEATURES, dtype=bool)
    best_per_mod = find_best_meta_per_modality(fold_idx)
    
    for modality in modalities:
        best_method, best_acc = best_per_mod[modality]
        if best_method is None:
            print(f"  WARNING: No meta results for {modality} fold {fold_idx+1}")
            continue
        
        mod_mask = layer1_masks[modality][best_method][fold_idx]
        start, end = MODALITY_OFFSETS[modality]
        mod_dim = end - start
        
        if len(mod_mask) == mod_dim:
            unified_mask[start:end] = mod_mask
        else:
            print(f"  WARNING: {modality}/{best_method}/fold_{fold_idx+1} mask length "
                  f"{len(mod_mask)} != expected {mod_dim}")
    
    return unified_mask, best_per_mod


# Build all combined masks
combined_masks = {}  # method -> {fold_idx: mask}

# Standard methods
for method in STANDARD_METHODS:
    combined_masks[method] = {}
    for fold_idx in range(N_FOLDS):
        combined_masks[method][fold_idx] = build_combined_mask_standard(method, fold_idx)

# Best metaheuristic combination
combined_masks['meta_best'] = {}
meta_best_info = {}  # fold_idx -> best_per_mod
for fold_idx in range(N_FOLDS):
    mask, best_per_mod = build_combined_mask_best_meta(fold_idx)
    combined_masks['meta_best'][fold_idx] = mask
    meta_best_info[fold_idx] = best_per_mod

# Print summary
print("="*80)
print("COMBINED LAYER 1 MASKS SUMMARY")
print("="*80)

for method in STANDARD_METHODS + ['meta_best']:
    avg_selected = np.mean([np.sum(combined_masks[method][f]) for f in range(N_FOLDS)])
    print(f"  {method:15s}: avg {avg_selected:.0f}/{TOTAL_FEATURES} features selected "
          f"({avg_selected/TOTAL_FEATURES*100:.1f}%)")

print("\nBest metaheuristic per modality per fold:")
for fold_idx in range(N_FOLDS):
    info = meta_best_info[fold_idx]
    parts = [f"{mod}={info[mod][0]}({info[mod][1]*100:.1f}%)" for mod in modalities]
    print(f"  Fold {fold_idx+1}: {', '.join(parts)}")
# Out:
# ================================================================================
# COMBINED LAYER 1 MASKS SUMMARY
# ================================================================================
#   mutual_info    : avg 3179/6359 features selected (50.0%)
#   rfe            : avg 3179/6359 features selected (50.0%)
#   lasso          : avg 3179/6359 features selected (50.0%)
#   meta_best      : avg 3015/6359 features selected (47.4%)
#
# Best metaheuristic per modality per fold:
#   Fold 1: sensor=meta_BAT(100.0%), skeleton=meta_DE(98.9%)
#   Fold 2: sensor=meta_BAT(100.0%), skeleton=meta_BAT(100.0%)
#   Fold 3: sensor=meta_BAT(100.0%), skeleton=meta_BAT(100.0%)
#   Fold 4: sensor=meta_BAT(97.1%), skeleton=meta_GWO(100.0%)
#   Fold 5: sensor=meta_CS(100.0%), skeleton=meta_GA(100.0%)
#   Fold 6: sensor=meta_JAYA(100.0%), skeleton=meta_BAT(100.0%)
#   Fold 7: sensor=meta_BAT(100.0%), skeleton=meta_BAT(100.0%)
#   Fold 8: sensor=meta_JAYA(100.0%), skeleton=meta_BAT(88.9%)
#   Fold 9: sensor=meta_BAT(100.0%), skeleton=meta_BAT(100.0%)
#   Fold 10: sensor=meta_BAT(100.0%), skeleton=meta_BAT(100.0%)

# %% [markdown]
# ## Evaluate Combined Layer 1 Features (Before Second Layer FS)
#
# Train and evaluate the neural network on the combined features from Layer 1,
# **without** any additional feature selection. This shows the HAR performance
# of simply combining per-modality selected features.

# %%
def evaluate_combined_layer1():
    """
    Evaluate combined Layer 1 features (no second-layer FS yet).
    This gives us the baseline performance of the combined per-modality selections.
    """
    print("="*80)
    print("EVALUATING COMBINED LAYER 1 FEATURES (before Layer 2 FS)")
    print("="*80)
    
    num_classes = len(np.unique(y))
    
    gkf = GroupKFold(n_splits=N_FOLDS)
    dummy_X = np.zeros((len(y), 1))

    layer1_eval_results = {}  # method -> {fold_idx: metrics}
    
    methods_to_eval = STANDARD_METHODS + ['meta_best']
    
    for method in methods_to_eval:
        layer1_eval_results[method] = {}
    
    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*60}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*60}")
        
        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]

        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv

        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]

        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")

        # Per-modality normalization + KernelPCA on depth (fit on train only)
        X_train, X_val, X_test, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )

        y_train = y[train_idx]
        y_val   = y[val_idx]
        y_test  = y[test_idx]

        # Rebuild unified offsets for this fold (post-PCA dims may differ from FEATURE_DIMS)
        fold_offsets = {}
        offset = 0
        for mod_name, dim in fold_feature_dims.items():
            fold_offsets[mod_name] = (offset, offset + dim)
            offset += dim
        fold_total_features = sum(fold_feature_dims.values())

        orig_dataset_size_mb = get_dataset_size_mb(X_train) + get_dataset_size_mb(X_val) + get_dataset_size_mb(X_test)

        for method in methods_to_eval:
            print(f"\n  --- Combined L1: {method.upper()} ---")

            # Remap L1 mask (defined over raw FEATURE_DIMS space) to post-PCA space.
            # For depth: the L1 mask covered raw depth features; after KernelPCA the
            # depth block is always fully kept (all DEPTH_PCA_DIM components), so we
            # set the depth block to True and preserve the other modalities from the L1 mask.
            raw_l1_mask = combined_masks[method][fold_idx]  # over TOTAL_FEATURES (raw)
            feature_mask = np.zeros(fold_total_features, dtype=bool)
            for mod_name in MODALITY_NAMES:
                raw_start, raw_end = MODALITY_OFFSETS[mod_name]
                fold_start, fold_end = fold_offsets[mod_name]
                if mod_name == 'depth':
                    # After KernelPCA all depth components are kept
                    feature_mask[fold_start:fold_end] = True
                else:
                    mod_raw_mask = raw_l1_mask[raw_start:raw_end]
                    feature_mask[fold_start:fold_end] = mod_raw_mask

            X_train_sel = X_train[:, feature_mask]
            X_val_sel   = X_val[:, feature_mask]
            X_test_sel  = X_test[:, feature_mask]
            
            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)
            
            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
            
            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()
            
            eval_metrics = train_and_evaluate_full(
                model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes
            )
            
            modality_ret = calculate_modality_retention(feature_mask, fold_feature_dims)
            
            fold_result = {
                'fold': fold_idx,
                'method': f'combined_L1_{method}',
                'val_acc': eval_metrics['val_acc'],
                'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'],
                'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'],
                'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(feature_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(feature_mask) / fold_total_features * 100),
                'modality_retention': modality_ret,
                'feature_mask': feature_mask,
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'],
                'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb,
                'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
            }
            
            layer1_eval_results[method][fold_idx] = fold_result
            
            # Save
            save_dir = RESULTS_ROOT / "combined_layer1"
            fold_save = {k: v for k, v in fold_result.items() if k != 'feature_mask'}
            fold_save_clean = {}
            for k, v in fold_save.items():
                if isinstance(v, np.ndarray):
                    fold_save_clean[k] = v.tolist()
                elif isinstance(v, (np.floating, np.integer)):
                    fold_save_clean[k] = float(v)
                elif isinstance(v, dict):
                    fold_save_clean[k] = {}
                    for kk, vv in v.items():
                        if isinstance(vv, dict):
                            fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                        else:
                            fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
                else:
                    fold_save_clean[k] = v
            
            with open(save_dir / f"combined_L1_{method}_fold_{fold_idx+1}.json", 'w') as f:
                json_lib.dump(fold_save_clean, f, indent=2, default=str)
            
            np.save(save_dir / f"combined_L1_{method}_fold_{fold_idx+1}_mask.npy", feature_mask)
            
            print(f"    Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(feature_mask)}/{fold_total_features} "
                  f"({np.sum(feature_mask)/fold_total_features*100:.1f}%)")
            
            del model, train_dataset, val_dataset, test_dataset
            del train_loader, val_loader, test_loader
            torch.cuda.empty_cache()
            gc.collect()
    
    return layer1_eval_results

layer1_eval_results = evaluate_combined_layer1()
# Out:
# ================================================================================
# EVALUATING COMBINED LAYER 1 FEATURES (before Layer 2 FS)
# ================================================================================
#
# ############################################################
# # FOLD 1/10
# ############################################################
#   Train: 405, Val: 27, Test: 184
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 99.46%, F1: 99.44%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 98.37%, F1: 98.36%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 98.91%, F1: 98.89%, Features: 2997/6359 (47.1%)
#
# ############################################################
# # FOLD 2/10
# ############################################################
#   Train: 419, Val: 27, Test: 170
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 98.24%, F1: 98.27%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3039/6359 (47.8%)
#
# ############################################################
# # FOLD 3/10
# ############################################################
#   Train: 529, Val: 27, Test: 60
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 96.67%, F1: 96.57%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 96.67%, F1: 96.57%, Features: 3061/6359 (48.1%)
#
# ############################################################
# # FOLD 4/10
# ############################################################
#   Train: 555, Val: 27, Test: 34
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 97.06%, F1: 97.46%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 97.06%, F1: 97.14%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 97.06%, F1: 97.46%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 97.06%, F1: 97.46%, Features: 2810/6359 (44.2%)
#
# ############################################################
# # FOLD 5/10
# ############################################################
#   Train: 556, Val: 27, Test: 33
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 96.97%, F1: 97.14%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 90.91%, F1: 90.64%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3050/6359 (48.0%)
#
# ############################################################
# # FOLD 6/10
# ############################################################
#   Train: 559, Val: 27, Test: 30
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 96.67%, F1: 96.57%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 90.00%, F1: 86.67%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 90.00%, F1: 86.67%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 90.00%, F1: 86.67%, Features: 2995/6359 (47.1%)
#
# ############################################################
# # FOLD 7/10
# ############################################################
#   Train: 559, Val: 27, Test: 30
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3059/6359 (48.1%)
#
# ############################################################
# # FOLD 8/10
# ############################################################
#   Train: 563, Val: 26, Test: 27
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 92.59%, F1: 91.67%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 92.59%, F1: 91.67%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 88.89%, F1: 80.50%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 88.89%, F1: 85.19%, Features: 2942/6359 (46.3%)
#
# ############################################################
# # FOLD 9/10
# ############################################################
#   Train: 563, Val: 27, Test: 26
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 84.62%, F1: 84.44%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3085/6359 (48.5%)
#
# ############################################################
# # FOLD 10/10
# ############################################################
#   Train: 567, Val: 27, Test: 22
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Combined L1: MUTUAL_INFO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: RFE ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: LASSO ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3179/6359 (50.0%)
#
#   --- Combined L1: META_BEST ---
#     Test Acc: 100.00%, F1: 100.00%, Features: 3113/6359 (49.0%)

# %% [markdown]
# ## Layer 1 Combined Results Summary

# %%
print("\n" + "="*80)
print("COMBINED LAYER 1 RESULTS SUMMARY")
print("="*80)

methods_to_eval = STANDARD_METHODS + ['meta_best']

rows = []
for method in methods_to_eval:
    accs = []
    f1s = []
    feats = []
    for fold_idx in range(N_FOLDS):
        if fold_idx in layer1_eval_results[method]:
            r = layer1_eval_results[method][fold_idx]
            accs.append(r['test_acc'] * 100)
            f1s.append(r['test_f1_macro'] * 100)
            feats.append(r['num_features_selected'])
    
    if accs:
        rows.append({
            'Method': f'Combined_L1_{method}',
            'Mean Test Acc (%)': np.mean(accs),
            'Std Test Acc (%)': np.std(accs),
            'Mean F1 Macro (%)': np.mean(f1s),
            'Mean Features': np.mean(feats),
            'Mean Retention (%)': np.mean(feats) / TOTAL_FEATURES * 100,
        })

df_l1_summary = pd.DataFrame(rows).round(2)
print(df_l1_summary.to_string(index=False))

# Save
df_l1_summary.to_csv(RESULTS_ROOT / "combined_layer1_summary.csv", index=False)
print(f"\nSaved: combined_layer1_summary.csv")
# Out:
# ================================================================================
# COMBINED LAYER 1 RESULTS SUMMARY
# ================================================================================
#                  Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Mean Features  Mean Retention (%)
# Combined_L1_mutual_info              98.63              2.36              98.57         3179.0               49.99
#         Combined_L1_rfe              97.61              3.40              97.21         3179.0               49.99
#       Combined_L1_lasso              94.47              5.13              93.29         3179.0               49.99
#   Combined_L1_meta_best              97.15              4.04              96.48         3015.1               47.41
#
# Saved: combined_layer1_summary.csv

# %% [markdown]
# ## Feature Selection Methods for Layer 2
#
# These are the same FS methods as the original notebook, but now they operate
# on the **combined Layer 1 features** (a subset of the full feature space).

# %%
def train_model_quick(model, train_loader, val_loader, epochs, lr, device):
    """Quick training for fitness evaluation"""
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    best_val_loss = float('inf')
    best_val_acc = 0.0
    
    for epoch in range(epochs):
        model.train()
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = criterion(model(features), labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                val_loss += criterion(outputs, labels).item()
                val_correct += (torch.argmax(outputs, 1) == labels).sum().item()
                val_total += labels.size(0)
        
        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        if val_loss < best_val_loss:
            best_val_loss, best_val_acc = val_loss, val_acc
    
    return best_val_loss, best_val_acc


def create_fitness_function_evolopy_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Create fitness function for EvoloPy Layer 2"""
    eval_count = [0]
    
    def fitness_function(binary_mask):
        try:
            if binary_mask.dtype != bool:
                binary_mask = binary_mask > 0.5

            num_selected = np.sum(binary_mask)
            if num_selected == 0:
                return 1.0
            
            X_tr_sel = X_train[:, binary_mask]
            X_val_sel = X_val[:, binary_mask]
            
            train_dataset = MultiModalDataset(X_tr_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            
            model = SimpleNN(X_tr_sel.shape[1], num_classes).to(DEVICE)
            
            val_loss, val_acc = train_model_quick(
                model, train_loader, val_loader,
                epochs=30, lr=1e-3, device=DEVICE
            )
            
            del model, train_dataset, val_dataset, train_loader, val_loader
            torch.cuda.empty_cache()
            
            eval_count[0] += 1
            
            alpha = 0.95
            beta = 0.05
            feature_ratio = num_selected / len(binary_mask)

            fitness = alpha * (1.0 - val_acc) + beta * feature_ratio
            return fitness
            
        except Exception as e:
            print(f"Error in fitness: {e}")
            return 1.0
        
    return fitness_function


def s_transfer(x):
    return 1 / (1 + np.exp(-10 * (x - 0.5)))


def run_evolopy_optimizer_l2(optimizer_name, optimizer_func, X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run any EvoloPy optimizer on Layer 2 features"""
    print(f"    Running EvoloPy {optimizer_name} (Layer 2)...")
    print(f"      Features: {n_features_l2}, Pop: {N_POPULATION}, Iter: {MAX_ITERATIONS}")
    
    fitness_func = create_fitness_function_evolopy_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2)
    
    start = time.time()
    solution = optimizer_func(fitness_func, 0, 1, n_features_l2, N_POPULATION, MAX_ITERATIONS)
    exec_time = time.time() - start
    
    binary_mask = np.random.rand(n_features_l2) < s_transfer(solution.bestIndividual)
    
    results = {
        'mask': binary_mask,
        'convergence': solution.convergence.tolist() if hasattr(solution.convergence, 'tolist') else list(solution.convergence),
        'best_fitness': float(solution.convergence[-1]) if len(solution.convergence) > 0 else float('inf'),
        'execution_time': exec_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': f'meta_{optimizer_name}'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Fitness: {results['best_fitness']:.4f}, Time: {exec_time:.1f}s")
    
    return results


def run_mutual_info_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run Mutual Information feature selection on Layer 2"""
    print("    Running Mutual Information (Layer 2)...")
    
    start_time = time.time()
    mi_scores = mutual_info_classif(X_train, y_train, random_state=42)
    
    k = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    top_k_indices = np.argsort(mi_scores)[::-1][:k]
    
    binary_mask = np.zeros(n_features_l2, dtype=bool)
    binary_mask[top_k_indices] = True
    
    execution_time = time.time() - start_time
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'mutual_info'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_rfe_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run RFE feature selection on Layer 2"""
    print("    Running RFE (Layer 2)...")
    
    start_time = time.time()
    estimator = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
    
    k = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    step = max(1, min(50, n_features_l2 // 10))
    selector = RFE(estimator, n_features_to_select=k, step=step)
    selector.fit(X_train, y_train)
    
    binary_mask = selector.support_
    execution_time = time.time() - start_time
    
    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'rfe'
    }
    
    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")
    
    return results


def run_lasso_fs_l2(X_train, y_train, X_val, y_val, num_classes, n_features_l2):
    """Run LASSO feature selection on Layer 2"""
    print("    Running LASSO (Layer 2)...")
    start_time = time.time()

    lasso = LogisticRegression(
        penalty='l1',
        C=0.01,
        solver='liblinear',
        random_state=42,
        max_iter=1000
    )
    lasso.fit(X_train, y_train)

    coef_abs = np.abs(lasso.coef_).sum(axis=0)

    target_count = max(1, int(n_features_l2 * TARGET_FEATURE_PERCENTAGE))
    top_indices = np.argsort(coef_abs)[::-1][:target_count]
    binary_mask = np.zeros(n_features_l2, dtype=bool)
    binary_mask[top_indices] = True

    execution_time = time.time() - start_time

    results = {
        'mask': binary_mask,
        'execution_time': execution_time,
        'num_selected': int(np.sum(binary_mask)),
        'num_total': n_features_l2,
        'method': 'lasso'
    }

    print(f"      Selected: {results['num_selected']}/{results['num_total']} "
          f"({results['num_selected']/results['num_total']*100:.1f}%), "
          f"Time: {results['execution_time']:.1f}s")

    return results

print("Layer 2 feature selection methods defined")
# Out:
# Layer 2 feature selection methods defined

# %% [markdown]
# ## Main Layer 2 Experiment Runner
#
# ### Process for each fold:
# 1. **Standard methods** (mutual_info, rfe, lasso):
#    - Take combined L1 mask → extract those features from unified data
#    - Run the *same* FS method on this subset
#    - The L2 mask is relative to the L1-selected features; map back to unified space
#
# 2. **Metaheuristics**:
#    - Take combined best-meta L1 mask → extract those features
#    - Run ALL 14 metaheuristics on this subset

# %%
def save_fold_result(fold_result, method_name, fold_idx):
    """Save a fold result to disk"""
    fold_dir = RESULTS_ROOT / method_name
    fold_dir.mkdir(exist_ok=True)
    
    fold_save = {k: v for k, v in fold_result.items() if k not in ['feature_mask']}
    fold_save_clean = {}
    for k, v in fold_save.items():
        if isinstance(v, np.ndarray):
            fold_save_clean[k] = v.tolist()
        elif isinstance(v, (np.floating, np.integer)):
            fold_save_clean[k] = float(v)
        elif isinstance(v, dict):
            fold_save_clean[k] = {}
            for kk, vv in v.items():
                if isinstance(vv, dict):
                    fold_save_clean[k][kk] = {kkk: float(vvv) if isinstance(vvv, (np.floating, np.integer)) else vvv for kkk, vvv in vv.items()}
                else:
                    fold_save_clean[k][kk] = float(vv) if isinstance(vv, (np.floating, np.integer)) else vv
            
        else:
            fold_save_clean[k] = v
    
    with open(fold_dir / f"fold_{fold_idx+1}.json", 'w') as f:
        json_lib.dump(fold_save_clean, f, indent=2, default=str)
    
    np.save(fold_dir / f"fold_{fold_idx+1}_mask.npy", fold_result['feature_mask'])


def run_layer2_experiments():
    """
    Run Layer 2 feature selection on combined Layer 1 features.
    """
    print("="*80)
    print("STARTING LAYER 2 FEATURE SELECTION EXPERIMENTS")
    print("="*80)
    
    num_classes = len(np.unique(y))

    master_results = {m: {} for m in ALL_METHODS_L2}

    gkf = GroupKFold(n_splits=N_FOLDS)
    dummy_X = np.zeros((len(y), 1))

    for fold_idx, (train_val_idx, test_idx) in enumerate(gkf.split(dummy_X, y, groups=subjects)):
        print(f"\n{'#'*80}")
        print(f"# FOLD {fold_idx + 1}/{N_FOLDS}")
        print(f"{'#'*80}")

        # --- Subject-based val split within train_val ---
        train_val_subjects = np.unique(subjects[train_val_idx])
        val_subject = train_val_subjects[-1]

        val_mask_in_tv   = subjects[train_val_idx] == val_subject
        train_mask_in_tv = ~val_mask_in_tv

        train_idx = train_val_idx[train_mask_in_tv]
        val_idx   = train_val_idx[val_mask_in_tv]

        y_train = y[train_idx]
        y_val   = y[val_idx]
        y_test  = y[test_idx]

        print(f"  Train: {len(train_idx)}, Val: {len(val_idx)}, Test: {len(test_idx)}")

        # Per-modality normalization + KernelPCA on depth (fit on train only)
        X_train_norm, X_val_norm, X_test_norm, fold_feature_dims, pca_obj = prepare_fold_data_per_modality(
            X_per_modality, train_idx, val_idx, test_idx,
            depth_pca_dim=DEPTH_PCA_DIM
        )

        # Rebuild unified offsets for this fold (post-PCA dims may differ from FEATURE_DIMS)
        fold_offsets = {}
        offset = 0
        for mod_name, dim in fold_feature_dims.items():
            fold_offsets[mod_name] = (offset, offset + dim)
            offset += dim
        fold_total_features = sum(fold_feature_dims.values())

        orig_dataset_size_mb = get_dataset_size_mb(X_train_norm) + get_dataset_size_mb(X_val_norm) + get_dataset_size_mb(X_test_norm)
        
        # =================================================================
        # STANDARD METHODS: mutual_info, rfe, lasso
        # =================================================================
        for std_method in STANDARD_METHODS:
            print(f"\n  --- Layer 2: {std_method.upper()} ---")
            
            # Get combined L1 mask for this method (defined over raw FEATURE_DIMS space)
            # Remap to post-PCA fold space: depth block is always fully kept after KernelPCA
            raw_l1_mask = combined_masks[std_method][fold_idx]
            fold_l1_mask = np.zeros(fold_total_features, dtype=bool)
            for mod_name in MODALITY_NAMES:
                raw_start, raw_end = MODALITY_OFFSETS[mod_name]
                fold_start, fold_end = fold_offsets[mod_name]
                if mod_name == 'depth':
                    fold_l1_mask[fold_start:fold_end] = True
                else:
                    fold_l1_mask[fold_start:fold_end] = raw_l1_mask[raw_start:raw_end]

            l1_indices = np.where(fold_l1_mask)[0]
            n_l1_features = len(l1_indices)

            print(f"    L1 combined features: {n_l1_features}/{fold_total_features}")

            # Extract L1-selected features
            X_train_l1 = X_train_norm[:, fold_l1_mask]
            X_val_l1   = X_val_norm[:, fold_l1_mask]
            X_test_l1  = X_test_norm[:, fold_l1_mask]
            
            fs_start_time = time.time()
            
            # Run Layer 2 FS on the L1-selected features
            if std_method == 'mutual_info':
                fs_results = run_mutual_info_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            elif std_method == 'rfe':
                fs_results = run_rfe_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            elif std_method == 'lasso':
                fs_results = run_lasso_fs_l2(X_train_l1, y_train, X_val_l1, y_val, num_classes, n_l1_features)
            
            fs_time = time.time() - fs_start_time
            
            # L2 mask is relative to L1 features; map back to unified space
            l2_mask_relative = fs_results['mask']
            
            # Final mask in fold space
            final_mask = np.zeros(fold_total_features, dtype=bool)
            final_mask[l1_indices[l2_mask_relative]] = True

            # Apply final mask
            X_train_sel = X_train_norm[:, final_mask]
            X_val_sel   = X_val_norm[:, final_mask]
            X_test_sel  = X_test_norm[:, final_mask]

            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)

            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()

            eval_metrics = train_and_evaluate_full(model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes)
            modality_ret = calculate_modality_retention(final_mask, fold_feature_dims)

            fold_result = {
                'fold': fold_idx, 'method': std_method,
                'l1_method': std_method, 'l1_features': n_l1_features,
                'val_acc': eval_metrics['val_acc'], 'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'], 'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'], 'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(final_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(final_mask) / fold_total_features * 100),
                'modality_retention': modality_ret, 'feature_mask': final_mask,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'], 'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb, 'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': None, 'best_fitness': None,
            }
            
            master_results[std_method][fold_idx] = fold_result
            save_fold_result(fold_result, std_method, fold_idx)
            
            print(f"    L2 Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(final_mask)}/{fold_total_features} "
                  f"({np.sum(final_mask)/fold_total_features*100:.1f}%)")

            del model, train_dataset, val_dataset, test_dataset, train_loader, val_loader, test_loader
            torch.cuda.empty_cache(); gc.collect()

        # =================================================================
        # METAHEURISTICS: Run all 14 on combined best-meta L1 features
        # =================================================================
        # Remap best-meta L1 mask to post-PCA fold space
        raw_l1_mask_meta = combined_masks['meta_best'][fold_idx]
        fold_l1_mask_meta = np.zeros(fold_total_features, dtype=bool)
        for mod_name in MODALITY_NAMES:
            raw_start, raw_end = MODALITY_OFFSETS[mod_name]
            fold_start, fold_end = fold_offsets[mod_name]
            if mod_name == 'depth':
                fold_l1_mask_meta[fold_start:fold_end] = True
            else:
                fold_l1_mask_meta[fold_start:fold_end] = raw_l1_mask_meta[raw_start:raw_end]

        l1_indices_meta = np.where(fold_l1_mask_meta)[0]
        n_l1_meta_features = len(l1_indices_meta)

        print(f"\n  --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---")
        print(f"    L1 combined best-meta features: {n_l1_meta_features}/{fold_total_features}")
        best_info = meta_best_info[fold_idx]
        for mod in modalities:
            print(f"      {mod}: {best_info[mod][0]} (acc={best_info[mod][1]*100:.1f}%)")

        X_train_l1_meta = X_train_norm[:, fold_l1_mask_meta]
        X_val_l1_meta   = X_val_norm[:, fold_l1_mask_meta]
        X_test_l1_meta  = X_test_norm[:, fold_l1_mask_meta]
        
        for opt_name, opt_func in EVOLOPY_OPTIMIZERS.items():
            method_name = f'meta_{opt_name}'
            print(f"\n  --- Layer 2: {method_name.upper()} ---")
            
            fs_start_time = time.time()
            fs_results = run_evolopy_optimizer_l2(
                opt_name, opt_func, 
                X_train_l1_meta, y_train, X_val_l1_meta, y_val, 
                num_classes, n_l1_meta_features
            )
            fs_time = time.time() - fs_start_time
            
            l2_mask_relative = fs_results['mask']

            # Final mask in fold space
            final_mask = np.zeros(fold_total_features, dtype=bool)
            final_mask[l1_indices_meta[l2_mask_relative]] = True

            X_train_sel = X_train_norm[:, final_mask]
            X_val_sel   = X_val_norm[:, final_mask]
            X_test_sel  = X_test_norm[:, final_mask]

            opt_dataset_size_mb = get_dataset_size_mb(X_train_sel) + get_dataset_size_mb(X_val_sel) + get_dataset_size_mb(X_test_sel)

            model = SimpleNN(X_train_sel.shape[1], num_classes).to(DEVICE)
            train_dataset = MultiModalDataset(X_train_sel, y_train)
            val_dataset = MultiModalDataset(X_val_sel, y_val)
            test_dataset = MultiModalDataset(X_test_sel, y_test)
            train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

            if torch.cuda.is_available():
                torch.cuda.reset_peak_memory_stats()

            eval_metrics = train_and_evaluate_full(model, train_loader, val_loader, test_loader, N_EPOCHS, LEARNING_RATE, num_classes)
            modality_ret = calculate_modality_retention(final_mask, fold_feature_dims)

            fold_result = {
                'fold': fold_idx, 'method': method_name,
                'l1_method': 'meta_best', 'l1_features': n_l1_meta_features,
                'l1_best_per_modality': {mod: {'method': best_info[mod][0], 'acc': best_info[mod][1]} for mod in modalities},
                'val_acc': eval_metrics['val_acc'], 'test_acc': eval_metrics['test_acc'],
                'test_f1_macro': eval_metrics['test_f1_macro'], 'test_f1_weighted': eval_metrics['test_f1_weighted'],
                'test_precision_macro': eval_metrics['test_precision_macro'], 'test_recall_macro': eval_metrics['test_recall_macro'],
                'num_features_selected': int(np.sum(final_mask)),
                'num_features_total': fold_total_features,
                'feature_retention_pct': float(np.sum(final_mask) / fold_total_features * 100),
                'modality_retention': modality_ret, 'feature_mask': final_mask,
                'fs_execution_time': fs_results.get('execution_time', 0),
                'train_time_sec': eval_metrics['train_time_sec'],
                'total_time_sec': fs_time + eval_metrics['train_time_sec'],
                'model_params': eval_metrics['model_params'], 'model_size_mb': eval_metrics['model_size_mb'],
                'original_dataset_size_mb': orig_dataset_size_mb, 'optimized_dataset_size_mb': opt_dataset_size_mb,
                'dataset_reduction_pct': float((1 - opt_dataset_size_mb / orig_dataset_size_mb) * 100) if orig_dataset_size_mb > 0 else 0,
                'gpu_mem_peak_mb': eval_metrics['gpu_mem_peak_mb'],
                'convergence': fs_results.get('convergence', None),
                'best_fitness': fs_results.get('best_fitness', None),
            }
            
            master_results[method_name][fold_idx] = fold_result
            save_fold_result(fold_result, method_name, fold_idx)
            
            print(f"    L2 Test Acc: {eval_metrics['test_acc']*100:.2f}%, "
                  f"F1: {eval_metrics['test_f1_macro']*100:.2f}%, "
                  f"Features: {np.sum(final_mask)}/{fold_total_features} "
                  f"({np.sum(final_mask)/fold_total_features*100:.1f}%)")

            del model, train_dataset, val_dataset, test_dataset, train_loader, val_loader, test_loader
            torch.cuda.empty_cache(); gc.collect()

    print(f"\n{'='*80}")
    print("ALL LAYER 2 EXPERIMENTS COMPLETED")
    print(f"{'='*80}")

    return master_results

print("Layer 2 experiment runner defined")
# Out:
# Layer 2 experiment runner defined

# %% [markdown]
# ## Run Layer 2 Experiments

# %%
master_results = run_layer2_experiments()
# Out:
# ================================================================================
# STARTING LAYER 2 FEATURE SELECTION EXPERIMENTS
# ================================================================================
#
# ################################################################################
# # FOLD 1/10
# ################################################################################
#   Train: 405, Val: 27, Test: 184
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Layer 2: MUTUAL_INFO ---
#     L1 combined features: 3179/6359
#     Running Mutual Information (Layer 2)...
#       Selected: 1589/3179 (50.0%), Time: 15.5s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1589/6359 (25.0%)
#
#   --- Layer 2: RFE ---
#     L1 combined features: 3179/6359
#     Running RFE (Layer 2)...
#       Selected: 1589/3179 (50.0%), Time: 3.6s
#     L2 Test Acc: 98.91%, F1: 98.89%, Features: 1589/6359 (25.0%)
#
#   --- Layer 2: LASSO ---
#     L1 combined features: 3179/6359
#     Running LASSO (Layer 2)...
#       Selected: 1589/3179 (50.0%), Time: 0.2s
#     L2 Test Acc: 88.59%, F1: 88.22%, Features: 1589/6359 (25.0%)
#
#   --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---
#     L1 combined best-meta features: 2997/6359
#       sensor: meta_BAT (acc=100.0%)
#       skeleton: meta_DE (acc=98.9%)
#
#   --- Layer 2: META_BAT ---
#     Running EvoloPy BAT (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02414080747414081']
# ['At iteration 1 the best fitness is 0.02414080747414081']
# ['At iteration 2 the best fitness is 0.02390724057390724']
# ['At iteration 3 the best fitness is 0.02389055722389056']
# ['At iteration 4 the best fitness is 0.02389055722389056']
# ['At iteration 5 the best fitness is 0.023873873873873876']
# ['At iteration 6 the best fitness is 0.023857190523857194']
# ['At iteration 7 the best fitness is 0.023857190523857194']
# ['At iteration 8 the best fitness is 0.023857190523857194']
# ['At iteration 9 the best fitness is 0.023857190523857194']
# ['At iteration 10 the best fitness is 0.023857190523857194']
# ['At iteration 11 the best fitness is 0.023857190523857194']
# ['At iteration 12 the best fitness is 0.023823823823823823']
# ['At iteration 13 the best fitness is 0.023823823823823823']
# ['At iteration 14 the best fitness is 0.023790457123790458']
# ['At iteration 15 the best fitness is 0.023790457123790458']
# ['At iteration 16 the best fitness is 0.023790457123790458']
# ['At iteration 17 the best fitness is 0.023773773773773776']
# ['At iteration 18 the best fitness is 0.023773773773773776']
# ['At iteration 19 the best fitness is 0.023773773773773776']
# ['At iteration 20 the best fitness is 0.023773773773773776']
# ['At iteration 21 the best fitness is 0.023773773773773776']
# ['At iteration 22 the best fitness is 0.023773773773773776']
# ['At iteration 23 the best fitness is 0.023757090423757093']
# ['At iteration 24 the best fitness is 0.023757090423757093']
# ['At iteration 25 the best fitness is 0.023757090423757093']
# ['At iteration 26 the best fitness is 0.023757090423757093']
# ['At iteration 27 the best fitness is 0.023757090423757093']
# ['At iteration 28 the best fitness is 0.023757090423757093']
# ['At iteration 29 the best fitness is 0.023757090423757093']
#       Selected: 1424/2997 (47.5%), Fitness: 0.0238, Time: 990.7s
#     L2 Test Acc: 98.91%, F1: 98.89%, Features: 1424/6359 (22.4%)
#
#   --- Layer 2: META_CS ---
#     Running EvoloPy CS (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.023857190523857194']
# ['At iteration 1 the best fitness is 0.023857190523857194']
# ['At iteration 2 the best fitness is 0.023723723723723725']
# ['At iteration 3 the best fitness is 0.023723723723723725']
# ['At iteration 4 the best fitness is 0.023723723723723725']
# ['At iteration 5 the best fitness is 0.023723723723723725']
# ['At iteration 6 the best fitness is 0.023723723723723725']
# ['At iteration 7 the best fitness is 0.023723723723723725']
# ['At iteration 8 the best fitness is 0.023723723723723725']
# ['At iteration 9 the best fitness is 0.023540206873540206']
# ['At iteration 10 the best fitness is 0.023540206873540206']
# ['At iteration 11 the best fitness is 0.023540206873540206']
# ['At iteration 12 the best fitness is 0.023540206873540206']
# ['At iteration 13 the best fitness is 0.02349015682349016']
# ['At iteration 14 the best fitness is 0.02349015682349016']
# ['At iteration 15 the best fitness is 0.02349015682349016']
# ['At iteration 16 the best fitness is 0.02349015682349016']
# ['At iteration 17 the best fitness is 0.02349015682349016']
# ['At iteration 18 the best fitness is 0.02349015682349016']
# ['At iteration 19 the best fitness is 0.02349015682349016']
# ['At iteration 20 the best fitness is 0.02349015682349016']
# ['At iteration 21 the best fitness is 0.02349015682349016']
# ['At iteration 22 the best fitness is 0.02349015682349016']
# ['At iteration 23 the best fitness is 0.02349015682349016']
# ['At iteration 24 the best fitness is 0.02349015682349016']
# ['At iteration 25 the best fitness is 0.02349015682349016']
# ['At iteration 26 the best fitness is 0.02349015682349016']
# ['At iteration 27 the best fitness is 0.02349015682349016']
# ['At iteration 28 the best fitness is 0.02349015682349016']
# ['At iteration 29 the best fitness is 0.02349015682349016']
#       Selected: 1399/2997 (46.7%), Fitness: 0.0235, Time: 1897.9s
#     L2 Test Acc: 98.91%, F1: 98.89%, Features: 1399/6359 (22.0%)
#
#   --- Layer 2: META_DE ---
#     Running EvoloPy DE (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024224224224224225']
# ['At iteration 2 the best fitness is 0.024224224224224225']
# ['At iteration 3 the best fitness is 0.024224224224224225']
# ['At iteration 4 the best fitness is 0.024224224224224225']
# ['At iteration 5 the best fitness is 0.024224224224224225']
# ['At iteration 6 the best fitness is 0.023773773773773776']
# ['At iteration 7 the best fitness is 0.023773773773773776']
# ['At iteration 8 the best fitness is 0.023773773773773776']
# ['At iteration 9 the best fitness is 0.02349015682349016']
# ['At iteration 10 the best fitness is 0.02349015682349016']
# ['At iteration 11 the best fitness is 0.02349015682349016']
# ['At iteration 12 the best fitness is 0.02335669002335669']
# ['At iteration 13 the best fitness is 0.02335669002335669']
# ['At iteration 14 the best fitness is 0.022922922922922924']
# ['At iteration 15 the best fitness is 0.022922922922922924']
# ['At iteration 16 the best fitness is 0.022689356022689358']
# ['At iteration 17 the best fitness is 0.022689356022689358']
# ['At iteration 18 the best fitness is 0.022689356022689358']
# ['At iteration 19 the best fitness is 0.022689356022689358']
# ['At iteration 20 the best fitness is 0.022689356022689358']
# ['At iteration 21 the best fitness is 0.022622622622622626']
# ['At iteration 22 the best fitness is 0.022405739072405742']
# ['At iteration 23 the best fitness is 0.022405739072405742']
# ['At iteration 24 the best fitness is 0.022405739072405742']
# ['At iteration 25 the best fitness is 0.022405739072405742']
# ['At iteration 26 the best fitness is 0.02220553887220554']
# ['At iteration 27 the best fitness is 0.022188855522188855']
# ['At iteration 28 the best fitness is 0.022188855522188855']
# ['At iteration 29 the best fitness is 0.022188855522188855']
# ['At iteration 30 the best fitness is 0.022188855522188855']
#       Selected: 1366/2997 (45.6%), Fitness: 0.0222, Time: 957.6s
#     L2 Test Acc: 98.91%, F1: 98.87%, Features: 1366/6359 (21.5%)
#
#   --- Layer 2: META_FFA ---
#     Running EvoloPy FFA (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024024024024024024']
# ['At iteration 1 the best fitness is 0.02459125792459126']
# ['At iteration 2 the best fitness is 0.025108441775108445']
# ['At iteration 3 the best fitness is 0.024607941274607942']
# ['At iteration 4 the best fitness is 0.024190857524190857']
# ['At iteration 5 the best fitness is 0.023573573573573574']
# ['At iteration 6 the best fitness is 0.023573573573573574']
# ['At iteration 7 the best fitness is 0.023573573573573574']
# ['At iteration 8 the best fitness is 0.023573573573573574']
# ['At iteration 9 the best fitness is 0.023573573573573574']
# ['At iteration 10 the best fitness is 0.023573573573573574']
# ['At iteration 11 the best fitness is 0.02380714047380714']
# ['At iteration 12 the best fitness is 0.023757090423757093']
# ['At iteration 13 the best fitness is 0.023757090423757093']
# ['At iteration 14 the best fitness is 0.023707040373707043']
# ['At iteration 15 the best fitness is 0.023707040373707043']
# ['At iteration 16 the best fitness is 0.023707040373707043']
# ['At iteration 17 the best fitness is 0.023707040373707043']
# ['At iteration 18 the best fitness is 0.023707040373707043']
# ['At iteration 19 the best fitness is 0.023673673673673675']
# ['At iteration 20 the best fitness is 0.023640306973640307']
# ['At iteration 21 the best fitness is 0.023640306973640307']
# ['At iteration 22 the best fitness is 0.023623623623623625']
# ['At iteration 23 the best fitness is 0.023623623623623625']
# ['At iteration 24 the best fitness is 0.023623623623623625']
# ['At iteration 25 the best fitness is 0.023623623623623625']
# ['At iteration 26 the best fitness is 0.023623623623623625']
# ['At iteration 27 the best fitness is 0.023623623623623625']
# ['At iteration 28 the best fitness is 0.023623623623623625']
# ['At iteration 29 the best fitness is 0.023623623623623625']
#       Selected: 1468/2997 (49.0%), Fitness: 0.0236, Time: 951.7s
#     L2 Test Acc: 99.46%, F1: 99.44%, Features: 1468/6359 (23.1%)
#
#   --- Layer 2: META_GA ---
#     Running EvoloPy GA (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.02509175842509176
# At iteration 2 the best fitness is 0.02450784117450784
# At iteration 3 the best fitness is 0.02390724057390724
# At iteration 4 the best fitness is 0.024107440774107442
# At iteration 5 the best fitness is 0.024107440774107442
# At iteration 6 the best fitness is 0.024057390724057392
# At iteration 7 the best fitness is 0.024057390724057392
# At iteration 8 the best fitness is 0.024057390724057392
# At iteration 9 the best fitness is 0.024107440774107442
# At iteration 10 the best fitness is 0.02400734067400734
# At iteration 11 the best fitness is 0.02394060727394061
# At iteration 12 the best fitness is 0.02394060727394061
# At iteration 13 the best fitness is 0.02359025692359026
# At iteration 14 the best fitness is 0.02359025692359026
# At iteration 15 the best fitness is 0.02359025692359026
# At iteration 16 the best fitness is 0.02359025692359026
# At iteration 17 the best fitness is 0.02359025692359026
# At iteration 18 the best fitness is 0.02359025692359026
# At iteration 19 the best fitness is 0.023523523523523524
# At iteration 20 the best fitness is 0.023523523523523524
# At iteration 21 the best fitness is 0.023523523523523524
# At iteration 22 the best fitness is 0.023473473473473477
# At iteration 23 the best fitness is 0.023473473473473477
# At iteration 24 the best fitness is 0.02349015682349016
# At iteration 25 the best fitness is 0.02349015682349016
# At iteration 26 the best fitness is 0.02349015682349016
# At iteration 27 the best fitness is 0.023323323323323323
# At iteration 28 the best fitness is 0.023273273273273276
# At iteration 29 the best fitness is 0.023223223223223226
# At iteration 30 the best fitness is 0.023223223223223226
#       Selected: 1399/2997 (46.7%), Fitness: 0.0232, Time: 954.4s
#     L2 Test Acc: 99.46%, F1: 99.44%, Features: 1399/6359 (22.0%)
#
#   --- Layer 2: META_GWO ---
#     Running EvoloPy GWO (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024074074074074074']
# ['At iteration 1 the best fitness is 0.02205538872205539']
# ['At iteration 2 the best fitness is 0.021871871871871874']
# ['At iteration 3 the best fitness is 0.02122122122122122']
# ['At iteration 4 the best fitness is 0.019986653319986655']
# ['At iteration 5 the best fitness is 0.019085752419085753']
# ['At iteration 6 the best fitness is 0.018351685018351684']
# ['At iteration 7 the best fitness is 0.016866866866866868']
# ['At iteration 8 the best fitness is 0.01648314981648315']
# ['At iteration 9 the best fitness is 0.0156322989656323']
# ['At iteration 10 the best fitness is 0.015081748415081747']
# ['At iteration 11 the best fitness is 0.014414414414414415']
# ['At iteration 12 the best fitness is 0.013963963963963964']
# ['At iteration 13 the best fitness is 0.013463463463463464']
# ['At iteration 14 the best fitness is 0.01294627961294628']
# ['At iteration 15 the best fitness is 0.012479145812479147']
# ['At iteration 16 the best fitness is 0.012479145812479147']
# ['At iteration 17 the best fitness is 0.012128795462128797']
# ['At iteration 18 the best fitness is 0.012012012012012012']
# ['At iteration 19 the best fitness is 0.011911911911911911']
# ['At iteration 20 the best fitness is 0.011861861861861863']
# ['At iteration 21 the best fitness is 0.011628294961628295']
# ['At iteration 22 the best fitness is 0.011294627961294629']
# ['At iteration 23 the best fitness is 0.011294627961294629']
# ['At iteration 24 the best fitness is 0.011194527861194528']
# ['At iteration 25 the best fitness is 0.011194527861194528']
# ['At iteration 26 the best fitness is 0.011144477811144478']
# ['At iteration 27 the best fitness is 0.011094427761094428']
# ['At iteration 28 the best fitness is 0.011077744411077745']
# ['At iteration 29 the best fitness is 0.011027694361027695']
#       Selected: 835/2997 (27.9%), Fitness: 0.0110, Time: 946.2s
#     L2 Test Acc: 98.37%, F1: 98.29%, Features: 835/6359 (13.1%)
#
#   --- Layer 2: META_HHO ---
#     Running EvoloPy HHO (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.024724724724724728']
# ['At iteration 1 the best fitness is 0.015665665665665667']
# ['At iteration 2 the best fitness is 0.009642976309642977']
# ['At iteration 3 the best fitness is 0.009642976309642977']
# ['At iteration 4 the best fitness is 0.006840173506840174']
# ['At iteration 5 the best fitness is 0.006840173506840174']
# ['At iteration 6 the best fitness is 0.006840173506840174']
# ['At iteration 7 the best fitness is 0.006840173506840174']
# ['At iteration 8 the best fitness is 0.006840173506840174']
# ['At iteration 9 the best fitness is 0.006840173506840174']
# ['At iteration 10 the best fitness is 0.006840173506840174']
# ['At iteration 11 the best fitness is 0.006840173506840174']
# ['At iteration 12 the best fitness is 0.006840173506840174']
# ['At iteration 13 the best fitness is 0.004888221554888222']
# ['At iteration 14 the best fitness is 0.004888221554888222']
# ['At iteration 15 the best fitness is 0.004888221554888222']
# ['At iteration 16 the best fitness is 0.0046546546546546545']
# ['At iteration 17 the best fitness is 0.0046546546546546545']
# ['At iteration 18 the best fitness is 0.0046546546546546545']
# ['At iteration 19 the best fitness is 0.0046546546546546545']
# ['At iteration 20 the best fitness is 0.0043877210543877216']
# ['At iteration 21 the best fitness is 0.0043877210543877216']
# ['At iteration 22 the best fitness is 0.004137470804137471']
# ['At iteration 23 the best fitness is 0.0029696363029696367']
# ['At iteration 24 the best fitness is 0.0029696363029696367']
# ['At iteration 25 the best fitness is 0.0029696363029696367']
# ['At iteration 26 the best fitness is 0.0027694361027694363']
# ['At iteration 27 the best fitness is 0.0027694361027694363']
# ['At iteration 28 the best fitness is 0.0027694361027694363']
# ['At iteration 29 the best fitness is 0.0027694361027694363']
#       Selected: 299/2997 (10.0%), Fitness: 0.0028, Time: 1305.4s
#     L2 Test Acc: 98.37%, F1: 98.33%, Features: 299/6359 (4.7%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02424090757424091']
# ['At iteration 1 the best fitness is 0.023923923923923923']
# ['At iteration 2 the best fitness is 0.023773773773773776']
# ['At iteration 3 the best fitness is 0.023757090423757093']
# ['At iteration 4 the best fitness is 0.023707040373707043']
# ['At iteration 5 the best fitness is 0.023656990323656993']
# ['At iteration 6 the best fitness is 0.023540206873540206']
# ['At iteration 7 the best fitness is 0.023540206873540206']
# ['At iteration 8 the best fitness is 0.023373373373373377']
# ['At iteration 9 the best fitness is 0.023373373373373377']
# ['At iteration 10 the best fitness is 0.023189856523189858']
# ['At iteration 11 the best fitness is 0.023073073073073075']
# ['At iteration 12 the best fitness is 0.023073073073073075']
# ['At iteration 13 the best fitness is 0.022972972972972974']
# ['At iteration 14 the best fitness is 0.022972972972972974']
# ['At iteration 15 the best fitness is 0.022939606272939606']
# ['At iteration 16 the best fitness is 0.022939606272939606']
# ['At iteration 17 the best fitness is 0.022822822822822823']
# ['At iteration 18 the best fitness is 0.022822822822822823']
# ['At iteration 19 the best fitness is 0.022822822822822823']
# ['At iteration 20 the best fitness is 0.022822822822822823']
# ['At iteration 21 the best fitness is 0.02280613947280614']
# ['At iteration 22 the best fitness is 0.02273940607273941']
# ['At iteration 23 the best fitness is 0.02273940607273941']
# ['At iteration 24 the best fitness is 0.022572572572572572']
# ['At iteration 25 the best fitness is 0.022572572572572572']
# ['At iteration 26 the best fitness is 0.022539205872539207']
# ['At iteration 27 the best fitness is 0.022539205872539207']
# ['At iteration 28 the best fitness is 0.022539205872539207']
# ['At iteration 29 the best fitness is 0.022539205872539207']
#       Selected: 1360/2997 (45.4%), Fitness: 0.0225, Time: 983.4s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1360/6359 (21.4%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02394060727394061']
# ['At iteration 2 the best fitness is 0.02394060727394061']
# ['At iteration 3 the best fitness is 0.02394060727394061']
# ['At iteration 4 the best fitness is 0.02394060727394061']
# ['At iteration 5 the best fitness is 0.02394060727394061']
# ['At iteration 6 the best fitness is 0.02394060727394061']
# ['At iteration 7 the best fitness is 0.02394060727394061']
# ['At iteration 8 the best fitness is 0.02394060727394061']
# ['At iteration 9 the best fitness is 0.02394060727394061']
# ['At iteration 10 the best fitness is 0.023873873873873876']
# ['At iteration 11 the best fitness is 0.023873873873873876']
# ['At iteration 12 the best fitness is 0.02384050717384051']
# ['At iteration 13 the best fitness is 0.023823823823823823']
# ['At iteration 14 the best fitness is 0.023823823823823823']
# ['At iteration 15 the best fitness is 0.023823823823823823']
# ['At iteration 16 the best fitness is 0.023823823823823823']
# ['At iteration 17 the best fitness is 0.023773773773773776']
# ['At iteration 18 the best fitness is 0.023773773773773776']
# ['At iteration 19 the best fitness is 0.023773773773773776']
# ['At iteration 20 the best fitness is 0.023623623623623625']
# ['At iteration 21 the best fitness is 0.023623623623623625']
# ['At iteration 22 the best fitness is 0.023623623623623625']
# ['At iteration 23 the best fitness is 0.023506840173506842']
# ['At iteration 24 the best fitness is 0.023506840173506842']
# ['At iteration 25 the best fitness is 0.023506840173506842']
# ['At iteration 26 the best fitness is 0.023506840173506842']
# ['At iteration 27 the best fitness is 0.02340674007340674']
# ['At iteration 28 the best fitness is 0.02340674007340674']
# ['At iteration 29 the best fitness is 0.02340674007340674']
#       Selected: 1429/2997 (47.7%), Fitness: 0.0234, Time: 799.3s
#     L2 Test Acc: 99.46%, F1: 99.44%, Features: 1429/6359 (22.5%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024124124124124124']
# ['At iteration 2 the best fitness is 0.024124124124124124']
# ['At iteration 3 the best fitness is 0.024124124124124124']
# ['At iteration 4 the best fitness is 0.024074074074074074']
# ['At iteration 5 the best fitness is 0.023790457123790458']
# ['At iteration 6 the best fitness is 0.023790457123790458']
# ['At iteration 7 the best fitness is 0.02349015682349016']
# ['At iteration 8 the best fitness is 0.02345679012345679']
# ['At iteration 9 the best fitness is 0.02345679012345679']
# ['At iteration 10 the best fitness is 0.02335669002335669']
# ['At iteration 11 the best fitness is 0.02335669002335669']
# ['At iteration 12 the best fitness is 0.02335669002335669']
# ['At iteration 13 the best fitness is 0.023173173173173175']
# ['At iteration 14 the best fitness is 0.023173173173173175']
# ['At iteration 15 the best fitness is 0.02280613947280614']
# ['At iteration 16 the best fitness is 0.02280613947280614']
# ['At iteration 17 the best fitness is 0.02280613947280614']
# ['At iteration 18 the best fitness is 0.02280613947280614']
# ['At iteration 19 the best fitness is 0.02280613947280614']
# ['At iteration 20 the best fitness is 0.02280613947280614']
# ['At iteration 21 the best fitness is 0.02280613947280614']
# ['At iteration 22 the best fitness is 0.02280613947280614']
# ['At iteration 23 the best fitness is 0.02280613947280614']
# ['At iteration 24 the best fitness is 0.02280613947280614']
# ['At iteration 25 the best fitness is 0.02280613947280614']
# ['At iteration 26 the best fitness is 0.02280613947280614']
# ['At iteration 27 the best fitness is 0.02280613947280614']
# ['At iteration 28 the best fitness is 0.02280613947280614']
# ['At iteration 29 the best fitness is 0.02280613947280614']
# ['At iteration 30 the best fitness is 0.02280613947280614']
#       Selected: 1422/2997 (47.4%), Fitness: 0.0228, Time: 808.0s
#     L2 Test Acc: 98.91%, F1: 98.87%, Features: 1422/6359 (22.4%)
#
#   --- Layer 2: META_PSO ---
#     Running EvoloPy PSO (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024607941274607942']
# ['At iteration 2 the best fitness is 0.024274274274274275']
# ['At iteration 3 the best fitness is 0.02399065732399066']
# ['At iteration 4 the best fitness is 0.023656990323656993']
# ['At iteration 5 the best fitness is 0.023623623623623625']
# ['At iteration 6 the best fitness is 0.02339005672339006']
# ['At iteration 7 the best fitness is 0.02339005672339006']
# ['At iteration 8 the best fitness is 0.02339005672339006']
# ['At iteration 9 the best fitness is 0.02325658992325659']
# ['At iteration 10 the best fitness is 0.02325658992325659']
# ['At iteration 11 the best fitness is 0.02325658992325659']
# ['At iteration 12 the best fitness is 0.02325658992325659']
# ['At iteration 13 the best fitness is 0.023239906573239908']
# ['At iteration 14 the best fitness is 0.023106439773106443']
# ['At iteration 15 the best fitness is 0.023106439773106443']
# ['At iteration 16 the best fitness is 0.023039706373039707']
# ['At iteration 17 the best fitness is 0.023023023023023025']
# ['At iteration 18 the best fitness is 0.02298965632298966']
# ['At iteration 19 the best fitness is 0.02298965632298966']
# ['At iteration 20 the best fitness is 0.02298965632298966']
# ['At iteration 21 the best fitness is 0.02298965632298966']
# ['At iteration 22 the best fitness is 0.022922922922922924']
# ['At iteration 23 the best fitness is 0.02290623957290624']
# ['At iteration 24 the best fitness is 0.02290623957290624']
# ['At iteration 25 the best fitness is 0.02290623957290624']
# ['At iteration 26 the best fitness is 0.02285618952285619']
# ['At iteration 27 the best fitness is 0.022689356022689358']
# ['At iteration 28 the best fitness is 0.022689356022689358']
# ['At iteration 29 the best fitness is 0.022672672672672672']
# ['At iteration 30 the best fitness is 0.022672672672672672']
#       Selected: 1375/2997 (45.9%), Fitness: 0.0227, Time: 799.5s
#     L2 Test Acc: 98.91%, F1: 98.89%, Features: 1375/6359 (21.6%)
#
#   --- Layer 2: META_SCA ---
#     Running EvoloPy SCA (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02335669002335669']
# ['At iteration 1 the best fitness is 0.022589255922589258']
# ['At iteration 2 the best fitness is 0.01856856856856857']
# ['At iteration 3 the best fitness is 0.015215215215215218']
# ['At iteration 4 the best fitness is 0.012412412412412414']
# ['At iteration 5 the best fitness is 0.010293626960293628']
# ['At iteration 6 the best fitness is 0.010293626960293628']
# ['At iteration 7 the best fitness is 0.010293626960293628']
# ['At iteration 8 the best fitness is 0.009743076409743076']
# ['At iteration 9 the best fitness is 0.008875542208875542']
# ['At iteration 10 the best fitness is 0.008675342008675343']
# ['At iteration 11 the best fitness is 0.00747414080747414']
# ['At iteration 12 the best fitness is 0.00672339005672339']
# ['At iteration 13 the best fitness is 0.005839172505839173']
# ['At iteration 14 the best fitness is 0.005839172505839173']
# ['At iteration 15 the best fitness is 0.005839172505839173']
# ['At iteration 16 the best fitness is 0.004738071404738072']
# ['At iteration 17 the best fitness is 0.004738071404738072']
# ['At iteration 18 the best fitness is 0.0046713380046713385']
# ['At iteration 19 the best fitness is 0.0046713380046713385']
# ['At iteration 20 the best fitness is 0.004437771104437771']
# ['At iteration 21 the best fitness is 0.004170837504170837']
# ['At iteration 22 the best fitness is 0.004070737404070737']
# ['At iteration 23 the best fitness is 0.004070737404070737']
# ['At iteration 24 the best fitness is 0.003970637303970638']
# ['At iteration 25 the best fitness is 0.003970637303970638']
# ['At iteration 26 the best fitness is 0.003970637303970638']
# ['At iteration 27 the best fitness is 0.003970637303970638']
# ['At iteration 28 the best fitness is 0.003970637303970638']
# ['At iteration 29 the best fitness is 0.003970637303970638']
#       Selected: 264/2997 (8.8%), Fitness: 0.0040, Time: 801.1s
#     L2 Test Acc: 96.74%, F1: 96.57%, Features: 264/6359 (4.2%)
#
#   --- Layer 2: META_SSA ---
#     Running EvoloPy SSA (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02414080747414081']
# ['At iteration 2 the best fitness is 0.02414080747414081']
# ['At iteration 3 the best fitness is 0.02414080747414081']
# ['At iteration 4 the best fitness is 0.02414080747414081']
# ['At iteration 5 the best fitness is 0.02414080747414081']
# ['At iteration 6 the best fitness is 0.024024024024024024']
# ['At iteration 7 the best fitness is 0.024024024024024024']
# ['At iteration 8 the best fitness is 0.02399065732399066']
# ['At iteration 9 the best fitness is 0.023673673673673675']
# ['At iteration 10 the best fitness is 0.023673673673673675']
# ['At iteration 11 the best fitness is 0.023540206873540206']
# ['At iteration 12 the best fitness is 0.02345679012345679']
# ['At iteration 13 the best fitness is 0.02315648982315649']
# ['At iteration 14 the best fitness is 0.02315648982315649']
# ['At iteration 15 the best fitness is 0.02315648982315649']
# ['At iteration 16 the best fitness is 0.02315648982315649']
# ['At iteration 17 the best fitness is 0.023106439773106443']
# ['At iteration 18 the best fitness is 0.023023023023023025']
# ['At iteration 19 the best fitness is 0.02298965632298966']
# ['At iteration 20 the best fitness is 0.022972972972972974']
# ['At iteration 21 the best fitness is 0.022972972972972974']
# ['At iteration 22 the best fitness is 0.022972972972972974']
# ['At iteration 23 the best fitness is 0.022972972972972974']
# ['At iteration 24 the best fitness is 0.022972972972972974']
# ['At iteration 25 the best fitness is 0.022972972972972974']
# ['At iteration 26 the best fitness is 0.022972972972972974']
# ['At iteration 27 the best fitness is 0.022972972972972974']
# ['At iteration 28 the best fitness is 0.022972972972972974']
# ['At iteration 29 the best fitness is 0.022972972972972974']
#       Selected: 1415/2997 (47.2%), Fitness: 0.0230, Time: 2013.3s
#     L2 Test Acc: 98.91%, F1: 98.89%, Features: 1415/6359 (22.3%)
#
#   --- Layer 2: META_WOA ---
#     Running EvoloPy WOA (Layer 2)...
#       Features: 2997, Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024324324324324326']
# ['At iteration 1 the best fitness is 0.00642308975642309']
# ['At iteration 2 the best fitness is 0.00642308975642309']
# ['At iteration 3 the best fitness is 0.00642308975642309']
# ['At iteration 4 the best fitness is 0.00642308975642309']
# ['At iteration 5 the best fitness is 0.00642308975642309']
# ['At iteration 6 the best fitness is 0.00642308975642309']
# ['At iteration 7 the best fitness is 0.00642308975642309']
# ['At iteration 8 the best fitness is 0.00642308975642309']
# ['At iteration 9 the best fitness is 0.00642308975642309']
# ['At iteration 10 the best fitness is 0.001001001001001001']
# ['At iteration 11 the best fitness is 0.000717384050717384']
# ['At iteration 12 the best fitness is 0.000717384050717384']
# ['At iteration 13 the best fitness is 0.0006006006006006007']
# ['At iteration 14 the best fitness is 0.0005839172505839173']
# ['At iteration 15 the best fitness is 0.0005839172505839173']
# ['At iteration 16 the best fitness is 0.0005839172505839173']
# ['At iteration 17 the best fitness is 0.0005839172505839173']
# ['At iteration 18 the best fitness is 0.0005672339005672338']
# ['At iteration 19 the best fitness is 0.0004004004004004004']
# ['At iteration 20 the best fitness is 0.0004004004004004004']
# ['At iteration 21 the best fitness is 0.0004004004004004004']
# ['At iteration 22 the best fitness is 0.0004004004004004004']
# ['At iteration 23 the best fitness is 0.0004004004004004004']
# ['At iteration 24 the best fitness is 0.0004004004004004004']
# ['At iteration 25 the best fitness is 0.0004004004004004004']
# ['At iteration 26 the best fitness is 0.0004004004004004004']
# ['At iteration 27 the best fitness is 0.0004004004004004004']
# ['At iteration 28 the best fitness is 0.0004004004004004004']
# ['At iteration 29 the best fitness is 0.0004004004004004004']
#       Selected: 113/2997 (3.8%), Fitness: 0.0004, Time: 640.1s
#     L2 Test Acc: 94.02%, F1: 93.94%, Features: 113/6359 (1.8%)
#
# ################################################################################
# # FOLD 2/10
# ################################################################################
#   Train: 419, Val: 27, Test: 170
#     Feature dims after processing: sensor=4480 | skeleton=1879 | TOTAL=6359
#
#   --- Layer 2: MUTUAL_INFO ---
#     L1 combined features: 3179/6359
#     Running Mutual Information (Layer 2)...
#       Selected: 1589/3179 (50.0%), Time: 15.6s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1589/6359 (25.0%)
#
#   --- Layer 2: RFE ---
#     L1 combined features: 3179/6359
#     Running RFE (Layer 2)...
#       Selected: 1589/3179 (50.0%), Time: 3.5s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1589/6359 (25.0%)
#
#   --- Layer 2: LASSO ---
#     L1 combined features: 3179/6359
#     Running LASSO (Layer 2)...
#       Selected: 1589/3179 (50.0%), Time: 0.2s
#     L2 Test Acc: 79.41%, F1: 73.52%, Features: 1589/6359 (25.0%)
#
#   --- Layer 2: METAHEURISTICS (on best-meta combined L1) ---
#     L1 combined best-meta features: 3039/6359
#       sensor: meta_BAT (acc=100.0%)
#       skeleton: meta_BAT (acc=100.0%)
#
#   --- Layer 2: META_BAT ---
#     Running EvoloPy BAT (Layer 2)...
#       Features: 3039, Pop: 20, Iter: 30
# BAT is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.025156301414939127']
# ['At iteration 1 the best fitness is 0.0248930569266206']
# ['At iteration 2 the best fitness is 0.0248930569266206']
# ['At iteration 3 the best fitness is 0.0248930569266206']
# ['At iteration 4 the best fitness is 0.0248930569266206']
# ['At iteration 5 the best fitness is 0.024564001316222443']
# ['At iteration 6 the best fitness is 0.024564001316222443']
# ['At iteration 7 the best fitness is 0.024564001316222443']
# ['At iteration 8 the best fitness is 0.024547548535702537']
# ['At iteration 9 the best fitness is 0.024547548535702537']
# ['At iteration 10 the best fitness is 0.02428430404738401']
# ['At iteration 11 the best fitness is 0.02421849292530438']
# ['At iteration 12 the best fitness is 0.02410332346166502']
# ['At iteration 13 the best fitness is 0.024086870681145116']
# ['At iteration 14 the best fitness is 0.024086870681145116']
# ['At iteration 15 the best fitness is 0.024086870681145116']
# ['At iteration 16 the best fitness is 0.024086870681145116']
# ['At iteration 17 the best fitness is 0.024086870681145116']
# ['At iteration 18 the best fitness is 0.02397170121750576']
# ['At iteration 19 the best fitness is 0.02397170121750576']
# ['At iteration 20 the best fitness is 0.02397170121750576']
# ['At iteration 21 the best fitness is 0.023922342875946037']
# ['At iteration 22 the best fitness is 0.023922342875946037']
# ['At iteration 23 the best fitness is 0.023905890095426128']
# ['At iteration 24 the best fitness is 0.023905890095426128']
# ['At iteration 25 the best fitness is 0.023905890095426128']
# ['At iteration 26 the best fitness is 0.023905890095426128']
# ['At iteration 27 the best fitness is 0.023905890095426128']
# ['At iteration 28 the best fitness is 0.023905890095426128']
# ['At iteration 29 the best fitness is 0.023905890095426128']
#       Selected: 1453/3039 (47.8%), Fitness: 0.0239, Time: 880.5s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1453/6359 (22.8%)
#
#   --- Layer 2: META_CS ---
#     Running EvoloPy CS (Layer 2)...
#       Features: 3039, Pop: 20, Iter: 30
# CS is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02411977624218493']
# ['At iteration 1 the best fitness is 0.02411977624218493']
# ['At iteration 2 the best fitness is 0.02411977624218493']
# ['At iteration 3 the best fitness is 0.02411977624218493']
# ['At iteration 4 the best fitness is 0.02411977624218493']
# ['At iteration 5 the best fitness is 0.02411977624218493']
# ['At iteration 6 the best fitness is 0.02411977624218493']
# ['At iteration 7 the best fitness is 0.02411977624218493']
# ['At iteration 8 the best fitness is 0.02411977624218493']
# ['At iteration 9 the best fitness is 0.02411977624218493']
# ['At iteration 10 the best fitness is 0.02411977624218493']
# ['At iteration 11 the best fitness is 0.02411977624218493']
# ['At iteration 12 the best fitness is 0.02411977624218493']
# ['At iteration 13 the best fitness is 0.02411977624218493']
# ['At iteration 14 the best fitness is 0.02411977624218493']
# ['At iteration 15 the best fitness is 0.02411977624218493']
# ['At iteration 16 the best fitness is 0.02411977624218493']
# ['At iteration 17 the best fitness is 0.02411977624218493']
# ['At iteration 18 the best fitness is 0.02411977624218493']
# ['At iteration 19 the best fitness is 0.02411977624218493']
# ['At iteration 20 the best fitness is 0.02411977624218493']
# ['At iteration 21 the best fitness is 0.02411977624218493']
# ['At iteration 22 the best fitness is 0.02411977624218493']
# ['At iteration 23 the best fitness is 0.02411977624218493']
# ['At iteration 24 the best fitness is 0.02411977624218493']
# ['At iteration 25 the best fitness is 0.02411977624218493']
# ['At iteration 26 the best fitness is 0.02411977624218493']
# ['At iteration 27 the best fitness is 0.02411977624218493']
# ['At iteration 28 the best fitness is 0.024021059559065486']
# ['At iteration 29 the best fitness is 0.024021059559065486']
#       Selected: 1497/3039 (49.3%), Fitness: 0.0240, Time: 1762.2s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1497/6359 (23.5%)
#
#   --- Layer 2: META_DE ---
#     Running EvoloPy DE (Layer 2)...
#       Features: 3039, Pop: 20, Iter: 30
# DE is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024169134583744655']
# ['At iteration 2 the best fitness is 0.024169134583744655']
# ['At iteration 3 the best fitness is 0.024169134583744655']
# ['At iteration 4 the best fitness is 0.024169134583744655']
# ['At iteration 5 the best fitness is 0.023922342875946037']
# ['At iteration 6 the best fitness is 0.023922342875946037']
# ['At iteration 7 the best fitness is 0.023922342875946037']
# ['At iteration 8 the best fitness is 0.023922342875946037']
# ['At iteration 9 the best fitness is 0.023922342875946037']
# ['At iteration 10 the best fitness is 0.023922342875946037']
# ['At iteration 11 the best fitness is 0.023922342875946037']
# ['At iteration 12 the best fitness is 0.02369200394866733']
# ['At iteration 13 the best fitness is 0.02369200394866733']
# ['At iteration 14 the best fitness is 0.02369200394866733']
# ['At iteration 15 the best fitness is 0.02369200394866733']
# ['At iteration 16 the best fitness is 0.02369200394866733']
# ['At iteration 17 the best fitness is 0.02369200394866733']
# ['At iteration 18 the best fitness is 0.02369200394866733']
# ['At iteration 19 the best fitness is 0.02369200394866733']
# ['At iteration 20 the best fitness is 0.023099703849950644']
# ['At iteration 21 the best fitness is 0.023099703849950644']
# ['At iteration 22 the best fitness is 0.023099703849950644']
# ['At iteration 23 the best fitness is 0.023099703849950644']
# ['At iteration 24 the best fitness is 0.023099703849950644']
# ['At iteration 25 the best fitness is 0.023099703849950644']
# ['At iteration 26 the best fitness is 0.023066798288910825']
# ['At iteration 27 the best fitness is 0.023066798288910825']
# ['At iteration 28 the best fitness is 0.023066798288910825']
# ['At iteration 29 the best fitness is 0.023066798288910825']
# ['At iteration 30 the best fitness is 0.023066798288910825']
#       Selected: 1418/3039 (46.7%), Fitness: 0.0231, Time: 892.8s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1418/6359 (22.3%)
#
#   --- Layer 2: META_FFA ---
#     Running EvoloPy FFA (Layer 2)...
#       Features: 3039, Pop: 20, Iter: 30
# FFA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024761434682461336']
# ['At iteration 1 the best fitness is 0.02479434024350115']
# ['At iteration 2 the best fitness is 0.02430075682790392']
# ['At iteration 3 the best fitness is 0.02430075682790392']
# ['At iteration 4 the best fitness is 0.02418558736426456']
# ['At iteration 5 the best fitness is 0.024383020730503455']
# ['At iteration 6 the best fitness is 0.02421849292530438']
# ['At iteration 7 the best fitness is 0.02410332346166502']
# ['At iteration 8 the best fitness is 0.02403751233958539']
# ['At iteration 9 the best fitness is 0.02403751233958539']
# ['At iteration 10 the best fitness is 0.02403751233958539']
# ['At iteration 11 the best fitness is 0.024021059559065486']
# ['At iteration 12 the best fitness is 0.02397170121750576']
# ['At iteration 13 the best fitness is 0.023938795656465943']
# ['At iteration 14 the best fitness is 0.023889437314906222']
# ['At iteration 15 the best fitness is 0.02380717341230668']
# ['At iteration 16 the best fitness is 0.023790720631786774']
# ['At iteration 17 the best fitness is 0.023774267851266864']
# ['At iteration 18 the best fitness is 0.023774267851266864']
# ['At iteration 19 the best fitness is 0.02382362619282659']
# ['At iteration 20 the best fitness is 0.023790720631786774']
# ['At iteration 21 the best fitness is 0.023790720631786774']
# ['At iteration 22 the best fitness is 0.023774267851266864']
# ['At iteration 23 the best fitness is 0.023790720631786774']
# ['At iteration 24 the best fitness is 0.023774267851266864']
# ['At iteration 25 the best fitness is 0.023774267851266864']
# ['At iteration 26 the best fitness is 0.023774267851266864']
# ['At iteration 27 the best fitness is 0.023774267851266864']
# ['At iteration 28 the best fitness is 0.023774267851266864']
# ['At iteration 29 the best fitness is 0.023774267851266864']
#       Selected: 1492/3039 (49.1%), Fitness: 0.0238, Time: 862.6s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1492/6359 (23.5%)
#
#   --- Layer 2: META_GA ---
#     Running EvoloPy GA (Layer 2)...
#       Features: 3039, Pop: 20, Iter: 30
# GA is optimizing  "fitness_function"
# At iteration 1 the best fitness is 0.024251398486344194
# At iteration 2 the best fitness is 0.024613359657782167
# At iteration 3 the best fitness is 0.024448831852583088
# At iteration 4 the best fitness is 0.024152681803224746
# At iteration 5 the best fitness is 0.02418558736426456
# At iteration 6 the best fitness is 0.02411977624218493
# At iteration 7 the best fitness is 0.02420204014478447
# At iteration 8 the best fitness is 0.024021059559065486
# At iteration 9 the best fitness is 0.023938795656465943
# At iteration 10 the best fitness is 0.02369200394866733
# At iteration 11 the best fitness is 0.023642645607107604
# At iteration 12 the best fitness is 0.023642645607107604
# At iteration 13 the best fitness is 0.023642645607107604
# At iteration 14 the best fitness is 0.02351102336294834
# At iteration 15 the best fitness is 0.02351102336294834
# At iteration 16 the best fitness is 0.02365909838762751
# At iteration 17 the best fitness is 0.02365909838762751
# At iteration 18 the best fitness is 0.02365909838762751
# At iteration 19 the best fitness is 0.02365909838762751
# At iteration 20 the best fitness is 0.02369200394866733
# At iteration 21 the best fitness is 0.02369200394866733
# At iteration 22 the best fitness is 0.02369200394866733
# At iteration 23 the best fitness is 0.02374136229022705
# At iteration 24 the best fitness is 0.02382362619282659
# At iteration 25 the best fitness is 0.023675551168147416
# At iteration 26 the best fitness is 0.023708456729187234
# At iteration 27 the best fitness is 0.023708456729187234
# At iteration 28 the best fitness is 0.023708456729187234
# At iteration 29 the best fitness is 0.023708456729187234
# At iteration 30 the best fitness is 0.023708456729187234
#       Selected: 1447/3039 (47.6%), Fitness: 0.0237, Time: 861.8s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1447/6359 (22.8%)
#
#   --- Layer 2: META_GWO ---
#     Running EvoloPy GWO (Layer 2)...
#       Features: 3039, Pop: 20, Iter: 30
# GWO is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02436656794998355']
# ['At iteration 1 the best fitness is 0.02430075682790392']
# ['At iteration 2 the best fitness is 0.022754195459032577']
# ['At iteration 3 the best fitness is 0.02188219809147746']
# ['At iteration 4 the best fitness is 0.0205001645278052']
# ['At iteration 5 the best fitness is 0.019628167160250082']
# ['At iteration 6 the best fitness is 0.01832839749917736']
# ['At iteration 7 the best fitness is 0.01773609740046068']
# ['At iteration 8 the best fitness is 0.0173576834485028']
# ['At iteration 9 the best fitness is 0.016617308325106946']
# ['At iteration 10 the best fitness is 0.015893385982230997']
# ['At iteration 11 the best fitness is 0.015136558078315236']
# ['At iteration 12 the best fitness is 0.014840408028956895']
# ['At iteration 13 the best fitness is 0.01441263573543929']
# ['At iteration 14 the best fitness is 0.014198749588680488']
# ['At iteration 15 the best fitness is 0.013688713392563343']
# ['At iteration 16 the best fitness is 0.01340901612372491']
# ['At iteration 17 the best fitness is 0.013162224415926292']
# ['At iteration 18 the best fitness is 0.012997696610727215']
# ['At iteration 19 the best fitness is 0.012668641000329058']
# ['At iteration 20 the best fitness is 0.012553471536689701']
# ['At iteration 21 the best fitness is 0.01248766041461007']
# ['At iteration 22 the best fitness is 0.01240539651201053']
# ['At iteration 23 the best fitness is 0.012372490950970715']
# ['At iteration 24 the best fitness is 0.012026982560052649']
# ['At iteration 25 the best fitness is 0.012026982560052649']
# ['At iteration 26 the best fitness is 0.012010529779532743']
# ['At iteration 27 the best fitness is 0.012010529779532743']
# ['At iteration 28 the best fitness is 0.011944718657453111']
# ['At iteration 29 the best fitness is 0.011928265876933202']
#       Selected: 877/3039 (28.9%), Fitness: 0.0119, Time: 853.9s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 877/6359 (13.8%)
#
#   --- Layer 2: META_HHO ---
#     Running EvoloPy HHO (Layer 2)...
#       Features: 3039, Pop: 20, Iter: 30
# HHO is now tackling  "fitness_function"
# ['At iteration 0 the best fitness is 0.02443237907206318']
# ['At iteration 1 the best fitness is 0.007847976307996052']
# ['At iteration 2 the best fitness is 0.00686080947680158']
# ['At iteration 3 the best fitness is 0.004754853570253373']
# ['At iteration 4 the best fitness is 0.004754853570253373']
# ['At iteration 5 the best fitness is 0.004754853570253373']
# ['At iteration 6 the best fitness is 0.004754853570253373']
# ['At iteration 7 the best fitness is 0.004754853570253373']
# ['At iteration 8 the best fitness is 0.004754853570253373']
# ['At iteration 9 the best fitness is 0.004754853570253373']
# ['At iteration 10 the best fitness is 0.004754853570253373']
# ['At iteration 11 the best fitness is 0.004754853570253373']
# ['At iteration 12 the best fitness is 0.004754853570253373']
# ['At iteration 13 the best fitness is 0.004754853570253373']
# ['At iteration 14 the best fitness is 0.004754853570253373']
# ['At iteration 15 the best fitness is 0.004754853570253373']
# ['At iteration 16 the best fitness is 0.004754853570253373']
# ['At iteration 17 the best fitness is 0.004754853570253373']
# ['At iteration 18 the best fitness is 0.004754853570253373']
# ['At iteration 19 the best fitness is 0.0038170450806186244']
# ['At iteration 20 the best fitness is 0.0038170450806186244']
# ['At iteration 21 the best fitness is 0.0038170450806186244']
# ['At iteration 22 the best fitness is 0.0034550839091806516']
# ['At iteration 23 the best fitness is 0.0033399144455412964']
# ['At iteration 24 the best fitness is 0.0022211253701875616']
# ['At iteration 25 the best fitness is 0.002105955906548207']
# ['At iteration 26 the best fitness is 0.002105955906548207']
# ['At iteration 27 the best fitness is 0.002073050345508391']
# ['At iteration 28 the best fitness is 0.002073050345508391']
# ['At iteration 29 the best fitness is 0.0019743336623889436']
#       Selected: 338/3039 (11.1%), Fitness: 0.0020, Time: 1083.8s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 338/6359 (5.3%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 3039, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024498190194142812']
# ['At iteration 1 the best fitness is 0.023938795656465943']
# ['At iteration 2 the best fitness is 0.023938795656465943']
# ['At iteration 3 the best fitness is 0.023774267851266864']
# ['At iteration 4 the best fitness is 0.02374136229022705']
# ['At iteration 5 the best fitness is 0.023445212240868707']
# ['At iteration 6 the best fitness is 0.023445212240868707']
# ['At iteration 7 the best fitness is 0.023445212240868707']
# ['At iteration 8 the best fitness is 0.023445212240868707']
# ['At iteration 9 the best fitness is 0.023445212240868707']
# ['At iteration 10 the best fitness is 0.023445212240868707']
# ['At iteration 11 the best fitness is 0.023445212240868707']
# ['At iteration 12 the best fitness is 0.023445212240868707']
# ['At iteration 13 the best fitness is 0.023445212240868707']
# ['At iteration 14 the best fitness is 0.023445212240868707']
# ['At iteration 15 the best fitness is 0.023330042777229353']
# ['At iteration 16 the best fitness is 0.023330042777229353']
# ['At iteration 17 the best fitness is 0.023330042777229353']
# ['At iteration 18 the best fitness is 0.023297137216189538']
# ['At iteration 19 the best fitness is 0.023181967752550183']
# ['At iteration 20 the best fitness is 0.023181967752550183']
# ['At iteration 21 the best fitness is 0.023181967752550183']
# ['At iteration 22 the best fitness is 0.023181967752550183']
# ['At iteration 23 the best fitness is 0.023181967752550183']
# ['At iteration 24 the best fitness is 0.023181967752550183']
# ['At iteration 25 the best fitness is 0.023165514972030274']
# ['At iteration 26 the best fitness is 0.02305034550839092']
# ['At iteration 27 the best fitness is 0.02305034550839092']
# ['At iteration 28 the best fitness is 0.02305034550839092']
# ['At iteration 29 the best fitness is 0.022737742678512668']
#       Selected: 1436/3039 (47.3%), Fitness: 0.0227, Time: 869.3s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1436/6359 (22.6%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
# ...
# ['At iteration 12 the best fitness is 0.000819145518792162']
# ['At iteration 13 the best fitness is 0.000819145518792162']
# ['At iteration 14 the best fitness is 0.0007709604882749759']
# ['At iteration 15 the best fitness is 0.0007709604882749759']
# ['At iteration 16 the best fitness is 0.0007709604882749759']
# ['At iteration 17 the best fitness is 0.0007709604882749759']
# ['At iteration 18 the best fitness is 0.0007709604882749759']
# ['At iteration 19 the best fitness is 0.0007709604882749759']
# ['At iteration 20 the best fitness is 0.000578220366206232']
# ['At iteration 21 the best fitness is 0.000530035335689046']
# ['At iteration 22 the best fitness is 0.00036941856729842595']
# ['At iteration 23 the best fitness is 0.00036941856729842595']
# ['At iteration 24 the best fitness is 0.00036941856729842595']
# ['At iteration 25 the best fitness is 0.00036941856729842595']
# ['At iteration 26 the best fitness is 0.00036941856729842595']
# ['At iteration 27 the best fitness is 0.00036941856729842595']
# ['At iteration 28 the best fitness is 0.00036941856729842595']
# ['At iteration 29 the best fitness is 0.00036941856729842595']
#       Selected: 295/3113 (9.5%), Fitness: 0.0004, Time: 1367.5s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 295/6359 (4.6%)
#
#   --- Layer 2: META_JAYA ---
#     Running EvoloPy JAYA (Layer 2)...
#       Features: 3113, Pop: 20, Iter: 30
# JAYA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.024156761965949246']
# ['At iteration 1 the best fitness is 0.02402826855123675']
# ['At iteration 2 the best fitness is 0.023755220044972696']
# ['At iteration 3 the best fitness is 0.023755220044972696']
# ['At iteration 4 the best fitness is 0.023755220044972696']
# ['At iteration 5 the best fitness is 0.023433986508191455']
# ['At iteration 6 the best fitness is 0.023433986508191455']
# ['At iteration 7 the best fitness is 0.023433986508191455']
# ['At iteration 8 the best fitness is 0.023433986508191455']
# ['At iteration 9 the best fitness is 0.02340186315451333']
# ['At iteration 10 the best fitness is 0.023337616447157084']
# ['At iteration 11 the best fitness is 0.023337616447157084']
# ['At iteration 12 the best fitness is 0.023337616447157084']
# ['At iteration 13 the best fitness is 0.023337616447157084']
# ['At iteration 14 the best fitness is 0.023337616447157084']
# ['At iteration 15 the best fitness is 0.023337616447157084']
# ['At iteration 16 the best fitness is 0.023337616447157084']
# ['At iteration 17 the best fitness is 0.023337616447157084']
# ['At iteration 18 the best fitness is 0.023257308062961776']
# ['At iteration 19 the best fitness is 0.023257308062961776']
# ['At iteration 20 the best fitness is 0.023257308062961776']
# ['At iteration 21 the best fitness is 0.023257308062961776']
# ['At iteration 22 the best fitness is 0.023257308062961776']
# ['At iteration 23 the best fitness is 0.023209123032444587']
# ['At iteration 24 the best fitness is 0.023080629617732093']
# ['At iteration 25 the best fitness is 0.02288788949566335']
# ['At iteration 26 the best fitness is 0.02288788949566335']
# ['At iteration 27 the best fitness is 0.02288788949566335']
# ['At iteration 28 the best fitness is 0.02288788949566335']
# ['At iteration 29 the best fitness is 0.02288788949566335']
#       Selected: 1469/3113 (47.2%), Fitness: 0.0229, Time: 1140.8s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1469/6359 (23.1%)
#
#   --- Layer 2: META_MFO ---
#     Running EvoloPy MFO (Layer 2)...
#       Features: 3113, Pop: 20, Iter: 30
# MFO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024285255380661744']
# ['At iteration 2 the best fitness is 0.024285255380661744']
# ['At iteration 3 the best fitness is 0.024285255380661744']
# ['At iteration 4 the best fitness is 0.024285255380661744']
# ['At iteration 5 the best fitness is 0.024285255380661744']
# ['At iteration 6 the best fitness is 0.024285255380661744']
# ['At iteration 7 the best fitness is 0.024285255380661744']
# ['At iteration 8 the best fitness is 0.024285255380661744']
# ['At iteration 9 the best fitness is 0.024285255380661744']
# ['At iteration 10 the best fitness is 0.024285255380661744']
# ['At iteration 11 the best fitness is 0.024285255380661744']
# ['At iteration 12 the best fitness is 0.024285255380661744']
# ['At iteration 13 the best fitness is 0.024285255380661744']
# ['At iteration 14 the best fitness is 0.024285255380661744']
# ['At iteration 15 the best fitness is 0.024285255380661744']
# ['At iteration 16 the best fitness is 0.024285255380661744']
# ['At iteration 17 the best fitness is 0.024285255380661744']
# ['At iteration 18 the best fitness is 0.02402826855123675']
# ['At iteration 19 the best fitness is 0.02402826855123675']
# ['At iteration 20 the best fitness is 0.02394796016704144']
# ['At iteration 21 the best fitness is 0.02394796016704144']
# ['At iteration 22 the best fitness is 0.02394796016704144']
# ['At iteration 23 the best fitness is 0.023819466752328947']
# ['At iteration 24 the best fitness is 0.023787343398650823']
# ['At iteration 25 the best fitness is 0.023787343398650823']
# ['At iteration 26 the best fitness is 0.023578541599743014']
# ['At iteration 27 the best fitness is 0.023385801477674273']
# ['At iteration 28 the best fitness is 0.023369739800835208']
# ['At iteration 29 the best fitness is 0.02324124638612271']
#       Selected: 1474/3113 (47.3%), Fitness: 0.0232, Time: 1153.6s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1474/6359 (23.2%)
#
#   --- Layer 2: META_MVO ---
#     Running EvoloPy MVO (Layer 2)...
#       Features: 3113, Pop: 20, Iter: 30
# MVO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024606488917442982']
# ['At iteration 2 the best fitness is 0.024606488917442982']
# ['At iteration 3 the best fitness is 0.024606488917442982']
# ['At iteration 4 the best fitness is 0.0244298104722133']
# ['At iteration 5 the best fitness is 0.02434950208801799']
# ['At iteration 6 the best fitness is 0.024172823642788308']
# ['At iteration 7 the best fitness is 0.024172823642788308']
# ['At iteration 8 the best fitness is 0.024172823642788308']
# ['At iteration 9 the best fitness is 0.023867651782846132']
# ['At iteration 10 the best fitness is 0.02385159010600707']
# ['At iteration 11 the best fitness is 0.02370703501445551']
# ['At iteration 12 the best fitness is 0.02370703501445551']
# ['At iteration 13 the best fitness is 0.023562479922903952']
# ['At iteration 14 the best fitness is 0.023562479922903952']
# ['At iteration 15 the best fitness is 0.023562479922903952']
# ['At iteration 16 the best fitness is 0.023562479922903952']
# ['At iteration 17 the best fitness is 0.023562479922903952']
# ['At iteration 18 the best fitness is 0.023562479922903952']
# ['At iteration 19 the best fitness is 0.023562479922903952']
# ['At iteration 20 the best fitness is 0.023562479922903952']
# ['At iteration 21 the best fitness is 0.023482171538708643']
# ['At iteration 22 the best fitness is 0.023482171538708643']
# ['At iteration 23 the best fitness is 0.023482171538708643']
# ['At iteration 24 the best fitness is 0.02346610986186958']
# ['At iteration 25 the best fitness is 0.023417924831352396']
# ['At iteration 26 the best fitness is 0.023417924831352396']
# ['At iteration 27 the best fitness is 0.023417924831352396']
# ['At iteration 28 the best fitness is 0.023369739800835208']
# ['At iteration 29 the best fitness is 0.023337616447157084']
# ['At iteration 30 the best fitness is 0.023321554770318022']
#       Selected: 1504/3113 (48.3%), Fitness: 0.0233, Time: 1197.4s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1504/6359 (23.7%)
#
#   --- Layer 2: META_PSO ---
#     Running EvoloPy PSO (Layer 2)...
#       Features: 3113, Pop: 20, Iter: 30
# PSO is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.024542242210086735']
# ['At iteration 2 the best fitness is 0.024076453581753934']
# ['At iteration 3 the best fitness is 0.023739158368133634']
# ['At iteration 4 the best fitness is 0.023739158368133634']
# ['At iteration 5 the best fitness is 0.023739158368133634']
# ['At iteration 6 the best fitness is 0.023739158368133634']
# ['At iteration 7 the best fitness is 0.023739158368133634']
# ['At iteration 8 the best fitness is 0.023739158368133634']
# ['At iteration 9 the best fitness is 0.023353678123996146']
# ['At iteration 10 the best fitness is 0.02319306135560553']
# ['At iteration 11 the best fitness is 0.02319306135560553']
# ['At iteration 12 the best fitness is 0.02319306135560553']
# ['At iteration 13 the best fitness is 0.02304850626405397']
# ['At iteration 14 the best fitness is 0.022855766141985225']
# ['At iteration 15 the best fitness is 0.022807581111468037']
# ['At iteration 16 the best fitness is 0.022582717635721172']
# ['At iteration 17 the best fitness is 0.022582717635721172']
# ['At iteration 18 the best fitness is 0.022582717635721172']
# ['At iteration 19 the best fitness is 0.02255059428204305']
# ['At iteration 20 the best fitness is 0.02255059428204305']
# ['At iteration 21 the best fitness is 0.022534532605203984']
# ['At iteration 22 the best fitness is 0.022534532605203984']
# ['At iteration 23 the best fitness is 0.022534532605203984']
# ['At iteration 24 the best fitness is 0.022534532605203984']
# ['At iteration 25 the best fitness is 0.022518470928364925']
# ['At iteration 26 the best fitness is 0.022325730806296178']
# ['At iteration 27 the best fitness is 0.022277545775778992']
# ['At iteration 28 the best fitness is 0.022277545775778992']
# ['At iteration 29 the best fitness is 0.022277545775778992']
# ['At iteration 30 the best fitness is 0.022277545775778992']
#       Selected: 1414/3113 (45.4%), Fitness: 0.0223, Time: 1156.2s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1414/6359 (22.2%)
#
#   --- Layer 2: META_SCA ---
#     Running EvoloPy SCA (Layer 2)...
#       Features: 3113, Pop: 20, Iter: 30
# SCA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02483135239318985']
# ['At iteration 1 the best fitness is 0.022277545775778992']
# ['At iteration 2 the best fitness is 0.02136203019595246']
# ['At iteration 3 the best fitness is 0.018053324767105687']
# ['At iteration 4 the best fitness is 0.01628654031480887']
# ['At iteration 5 the best fitness is 0.015579826533890138']
# ['At iteration 6 the best fitness is 0.013122389977513652']
# ['At iteration 7 the best fitness is 0.013122389977513652']
# ['At iteration 8 the best fitness is 0.01013491808544812']
# ['At iteration 9 the best fitness is 0.008625120462576293']
# ['At iteration 10 the best fitness is 0.007324124638612272']
# ['At iteration 11 the best fitness is 0.006296177320912304']
# ['At iteration 12 the best fitness is 0.005493093478959203']
# ['At iteration 13 the best fitness is 0.004754256344362352']
# ['At iteration 14 the best fitness is 0.00433665274654674']
# ['At iteration 15 the best fitness is 0.00393511082557019']
# ['At iteration 16 the best fitness is 0.0033087054288467714']
# ['At iteration 17 the best fitness is 0.0033087054288467714']
# ['At iteration 18 the best fitness is 0.0031320269836170897']
# ['At iteration 19 the best fitness is 0.0030035335689045936']
# ['At iteration 20 the best fitness is 0.002858978477353036']
# ['At iteration 21 the best fitness is 0.00281079344683585']
# ['At iteration 22 the best fitness is 0.0024734982332155478']
# ['At iteration 23 the best fitness is 0.0024734982332155478']
# ['At iteration 24 the best fitness is 0.0024734982332155478']
# ['At iteration 25 the best fitness is 0.0023931898490202382']
# ['At iteration 26 the best fitness is 0.0023931898490202382']
# ['At iteration 27 the best fitness is 0.0023931898490202382']
# ['At iteration 28 the best fitness is 0.002312881464824928']
# ['At iteration 29 the best fitness is 0.0022968197879858657']
#       Selected: 188/3113 (6.0%), Fitness: 0.0023, Time: 1170.1s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 188/6359 (3.0%)
#
#   --- Layer 2: META_SSA ---
#     Running EvoloPy SSA (Layer 2)...
#       Features: 3113, Pop: 20, Iter: 30
# SSA is optimizing  "fitness_function"
# ['At iteration 1 the best fitness is 0.02402826855123675']
# ['At iteration 2 the best fitness is 0.02402826855123675']
# ['At iteration 3 the best fitness is 0.02402826855123675']
# ['At iteration 4 the best fitness is 0.02402826855123675']
# ['At iteration 5 the best fitness is 0.02402826855123675']
# ['At iteration 6 the best fitness is 0.02402826855123675']
# ['At iteration 7 the best fitness is 0.02402826855123675']
# ['At iteration 8 the best fitness is 0.023980083520719564']
# ['At iteration 9 the best fitness is 0.02380340507548988']
# ['At iteration 10 the best fitness is 0.02346610986186958']
# ['At iteration 11 the best fitness is 0.02346610986186958']
# ['At iteration 12 the best fitness is 0.02346610986186958']
# ['At iteration 13 the best fitness is 0.02346610986186958']
# ['At iteration 14 the best fitness is 0.02346610986186958']
# ['At iteration 15 the best fitness is 0.023385801477674273']
# ['At iteration 16 the best fitness is 0.023385801477674273']
# ['At iteration 17 the best fitness is 0.023257308062961776']
# ['At iteration 18 the best fitness is 0.023257308062961776']
# ['At iteration 19 the best fitness is 0.02324124638612271']
# ['At iteration 20 the best fitness is 0.023225184709283652']
# ['At iteration 21 the best fitness is 0.023225184709283652']
# ['At iteration 22 the best fitness is 0.023225184709283652']
# ['At iteration 23 the best fitness is 0.023225184709283652']
# ['At iteration 24 the best fitness is 0.023225184709283652']
# ['At iteration 25 the best fitness is 0.023225184709283652']
# ['At iteration 26 the best fitness is 0.023225184709283652']
# ['At iteration 27 the best fitness is 0.023225184709283652']
# ['At iteration 28 the best fitness is 0.023225184709283652']
# ['At iteration 29 the best fitness is 0.023225184709283652']
#       Selected: 1487/3113 (47.8%), Fitness: 0.0232, Time: 2699.5s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 1487/6359 (23.4%)
#
#   --- Layer 2: META_WOA ---
#     Running EvoloPy WOA (Layer 2)...
#       Features: 3113, Pop: 20, Iter: 30
# WOA is optimizing  "fitness_function"
# ['At iteration 0 the best fitness is 0.02459042724060392']
# ['At iteration 1 the best fitness is 0.010970125281079345']
# ['At iteration 2 the best fitness is 0.004127850947638934']
# ['At iteration 3 the best fitness is 0.0018631545133311917']
# ['At iteration 4 the best fitness is 0.0018631545133311917']
# ['At iteration 5 the best fitness is 0.0012367491166077739']
# ['At iteration 6 the best fitness is 0.0010921940250562159']
# ['At iteration 7 the best fitness is 0.0010921940250562159']
# ['At iteration 8 the best fitness is 0.0010921940250562159']
# ['At iteration 9 the best fitness is 0.0010921940250562159']
# ['At iteration 10 the best fitness is 0.0010921940250562159']
# ['At iteration 11 the best fitness is 0.0010921940250562159']
# ['At iteration 12 the best fitness is 0.0010921940250562159']
# ['At iteration 13 the best fitness is 0.0010921940250562159']
# ['At iteration 14 the best fitness is 0.0010921940250562159']
# ['At iteration 15 the best fitness is 0.0010921940250562159']
# ['At iteration 16 the best fitness is 0.0010921940250562159']
# ['At iteration 17 the best fitness is 0.0010921940250562159']
# ['At iteration 18 the best fitness is 0.0010921940250562159']
# ['At iteration 19 the best fitness is 0.0010921940250562159']
# ['At iteration 20 the best fitness is 0.0010921940250562159']
# ['At iteration 21 the best fitness is 0.0010921940250562159']
# ['At iteration 22 the best fitness is 0.0010921940250562159']
# ['At iteration 23 the best fitness is 0.0010921940250562159']
# ['At iteration 24 the best fitness is 0.0010921940250562159']
# ['At iteration 25 the best fitness is 0.0010921940250562159']
# ['At iteration 26 the best fitness is 0.0010921940250562159']
# ['At iteration 27 the best fitness is 0.0010921940250562159']
# ['At iteration 28 the best fitness is 0.0010921940250562159']
# ['At iteration 29 the best fitness is 0.0010921940250562159']
#       Selected: 108/3113 (3.5%), Fitness: 0.0011, Time: 1009.7s
#     L2 Test Acc: 100.00%, F1: 100.00%, Features: 108/6359 (1.7%)
#
# ================================================================================
# ALL LAYER 2 EXPERIMENTS COMPLETED
# ================================================================================

# %% [markdown]
# ## Build Comprehensive Per-Fold Results CSV

# %%
rows = []

for method_name in ALL_METHODS_L2:
    for fold_idx in range(N_FOLDS):
        if fold_idx not in master_results[method_name]:
            continue
        r = master_results[method_name][fold_idx]
        
        row = {
            'Method': method_name,
            'Fold': fold_idx + 1,
            'Test Accuracy (%)': r['test_acc'] * 100,
            'Val Accuracy (%)': r['val_acc'] * 100,
            'F1 Macro (%)': r['test_f1_macro'] * 100,
            'F1 Weighted (%)': r['test_f1_weighted'] * 100,
            'Precision Macro (%)': r['test_precision_macro'] * 100,
            'Recall Macro (%)': r['test_recall_macro'] * 100,
            'Features Selected': r['num_features_selected'],
            'Features Total': r['num_features_total'],
            'Feature Retention (%)': r['feature_retention_pct'],
            'L1 Features': r.get('l1_features', TOTAL_FEATURES),
            'FS Time (s)': r['fs_execution_time'],
            'Train Time (s)': r['train_time_sec'],
            'Total Time (s)': r['total_time_sec'],
            'Model Params': r['model_params'],
            'Model Size (MB)': r['model_size_mb'],
            'Original Dataset (MB)': r['original_dataset_size_mb'],
            'Optimized Dataset (MB)': r['optimized_dataset_size_mb'],
            'Dataset Reduction (%)': r['dataset_reduction_pct'],
            'GPU Peak (MB)': r['gpu_mem_peak_mb'],
        }
        
        for mod_name in FEATURE_DIMS.keys():
            mod_ret = r['modality_retention'].get(mod_name, {})
            if isinstance(mod_ret, dict):
                row[f'{mod_name}_retention (%)'] = mod_ret.get('percentage', 0)
                row[f'{mod_name}_selected'] = mod_ret.get('selected', 0)
            else:
                row[f'{mod_name}_retention (%)'] = float(mod_ret)
        
        rows.append(row)

df_all = pd.DataFrame(rows)
df_all = df_all.round(4)

csv_path = RESULTS_ROOT / "all_results_per_fold.csv"
df_all.to_csv(csv_path, index=False)
print(f"Saved comprehensive per-fold CSV: {csv_path}")
print(f"Shape: {df_all.shape}")
print(df_all.head(20).to_string())
# Out:
# Saved comprehensive per-fold CSV: results_two_layer/all_results_per_fold.csv
# Shape: (170, 25)
#          Method  Fold  Test Accuracy (%)  Val Accuracy (%)  F1 Macro (%)  F1 Weighted (%)  Precision Macro (%)  Recall Macro (%)  Features Selected  Features Total  Feature Retention (%)  L1 Features  FS Time (s)  Train Time (s)  Total Time (s)  Model Params  Model Size (MB)  Original Dataset (MB)  Optimized Dataset (MB)  Dataset Reduction (%)  GPU Peak (MB)  sensor_retention (%)  sensor_selected  skeleton_retention (%)  skeleton_selected
# 0   mutual_info     1           100.0000           92.5926      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179      15.4823         15.1648         30.6473        949514            3.628                29.8854                  7.4678                75.0118         49.126               19.2857              864                 38.5844                725
# 1   mutual_info     2           100.0000           88.8889      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179      15.5574         13.8825         29.4399        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.1339              902                 36.5620                687
# 2   mutual_info     3           100.0000           88.8889      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179      16.9522         19.1465         36.0988        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.9598              939                 34.5929                650
# 3   mutual_info     4           100.0000           88.8889      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179      17.0102         14.6258         31.6361        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.0446              898                 36.7749                691
# 4   mutual_info     5            96.9697           96.2963       97.1429          96.9697              97.5000           97.5000               1589            6359                24.9882         3179      16.9055         14.4164         31.3220        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.5357              920                 35.6040                669
# 5   mutual_info     6            90.0000           88.8889       86.6667          86.6667              85.0000           90.0000               1589            6359                24.9882         3179      18.5365         19.6265         38.1631        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.0670              899                 36.7217                690
# 6   mutual_info     7           100.0000           92.5926      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179      18.2934         19.1722         37.4657        949514            3.628                29.8854                  7.4678                75.0118         49.126               19.8884              891                 37.1474                698
# 7   mutual_info     8            88.8889          100.0000       85.1852          85.1852              83.3333           88.8889               1589            6359                24.9882         3179      18.5594         19.4820         38.0415        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.1786              904                 36.4556                685
# 8   mutual_info     9           100.0000          100.0000      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179      18.7047         19.5811         38.2859        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.1786              904                 36.4556                685
# 9   mutual_info    10           100.0000          100.0000      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179      18.4307         17.3956         35.8264        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.6027              923                 35.4444                666
# 10          rfe     1            98.9130          100.0000       98.8854          98.9097              99.0000           98.8889               1589            6359                24.9882         3179       3.6399         15.0221         18.6622        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.6250              924                 35.3912                665
# 11          rfe     2           100.0000           96.2963      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179       3.4756         13.8926         17.3684        949514            3.628                29.8854                  7.4678                75.0118         49.126               19.9777              895                 36.9345                694
# 12          rfe     3           100.0000          100.0000      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179       4.2736         19.3269         23.6008        949514            3.628                29.8854                  7.4678                75.0118         49.126               21.1384              947                 34.1671                642
# 13          rfe     4           100.0000           92.5926      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179       4.1734         14.4651         18.6387        949514            3.628                29.8854                  7.4678                75.0118         49.126               19.7991              887                 37.3603                702
# 14          rfe     5           100.0000           96.2963      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179       4.1273         14.7060         18.8335        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.5134              919                 35.6573                670
# 15          rfe     6            90.0000          100.0000       86.6667          86.6667              85.0000           90.0000               1589            6359                24.9882         3179       4.6577         19.5872         24.2454        949514            3.628                29.8854                  7.4678                75.0118         49.126               19.9330              893                 37.0410                696
# 16          rfe     7            96.6667          100.0000       96.5714          96.5714              97.5000           96.6667               1589            6359                24.9882         3179       4.6442         19.3497         23.9942        949514            3.628                29.8854                  7.4678                75.0118         49.126               19.7768              886                 37.4135                703
# 17          rfe     8            88.8889          100.0000       85.1852          85.1852              83.3333           88.8889               1589            6359                24.9882         3179       4.7818         19.7038         24.4858        949514            3.628                29.8854                  7.4678                75.0118         49.126               19.9554              894                 36.9878                695
# 18          rfe     9            96.1538          100.0000       96.1905          96.0440              97.2222           96.2963               1589            6359                24.9882         3179       4.7612         19.5723         24.3339        949514            3.628                29.8854                  7.4678                75.0118         49.126               19.9554              894                 36.9878                695
# 19          rfe    10           100.0000           92.5926      100.0000         100.0000             100.0000          100.0000               1589            6359                24.9882         3179       4.6220         17.6638         22.2861        949514            3.628                29.8854                  7.4678                75.0118         49.126               20.6473              925                 35.3379                664

# %% [markdown]
# ## Per-Method Summary Table

# %%
summary_rows = []
for method_name in ALL_METHODS_L2:
    method_df = df_all[df_all['Method'] == method_name]
    if len(method_df) == 0:
        continue
    
    row = {
        'Method': method_name,
        'Mean Test Acc (%)': method_df['Test Accuracy (%)'].mean(),
        'Std Test Acc (%)': method_df['Test Accuracy (%)'].std(),
        'Mean F1 Macro (%)': method_df['F1 Macro (%)'].mean(),
        'Std F1 Macro (%)': method_df['F1 Macro (%)'].std(),
        'Mean Features Selected': method_df['Features Selected'].mean(),
        'Mean Feature Retention (%)': method_df['Feature Retention (%)'].mean(),
        'Mean L1 Features': method_df['L1 Features'].mean(),
        'Mean FS Time (s)': method_df['FS Time (s)'].mean(),
        'Mean Train Time (s)': method_df['Train Time (s)'].mean(),
        'Mean Total Time (s)': method_df['Total Time (s)'].mean(),
        'Mean Model Params': method_df['Model Params'].mean(),
        'Mean Model Size (MB)': method_df['Model Size (MB)'].mean(),
        'Mean Dataset Reduction (%)': method_df['Dataset Reduction (%)'].mean(),
        'Mean GPU Peak (MB)': method_df['GPU Peak (MB)'].mean(),
    }
    summary_rows.append(row)

df_summary = pd.DataFrame(summary_rows).round(2)
df_summary.to_csv(RESULTS_ROOT / "summary_all_methods.csv", index=False)
print("\nSUMMARY TABLE (mean across folds):")
print(df_summary.to_string(index=False))
# Out:
# SUMMARY TABLE (mean across folds):
#      Method  Mean Test Acc (%)  Std Test Acc (%)  Mean F1 Macro (%)  Std F1 Macro (%)  Mean Features Selected  Mean Feature Retention (%)  Mean L1 Features  Mean FS Time (s)  Mean Train Time (s)  Mean Total Time (s)  Mean Model Params  Mean Model Size (MB)  Mean Dataset Reduction (%)  Mean GPU Peak (MB)
# mutual_info              97.59              4.40              96.90              5.86                  1589.0                       24.99            3179.0             17.44                17.25                34.69           949514.0                  3.63                       75.01               49.13
#         rfe              97.06              4.27              96.35              5.69                  1589.0                       24.99            3179.0              4.32                17.33                21.64           949514.0                  3.63                       75.01               49.13
#       lasso              90.99              7.37              88.56             10.32                  1589.0                       24.99            3179.0              0.38                17.34                17.72           949514.0                  3.63                       75.01               49.13
#    meta_BAT              97.49              4.35              96.82              5.81                  1460.0                       22.96            3015.1           1091.64                17.46              1109.09           883466.0                  3.38                       77.04               48.07
#     meta_CS              98.15              3.50              97.81              4.61                  1437.5                       22.61            3015.1           2124.31                16.94              2141.24           871946.0                  3.33                       77.39               47.84
#     meta_DE              98.15              3.50              97.81              4.61                  1400.7                       22.03            3015.1           1047.24                16.94              1064.19           853104.4                  3.26                       77.97               47.47
#    meta_FFA              97.91              3.65              97.52              4.63                  1462.9                       23.01            3015.1           1020.41                17.43              1037.84           884950.8                  3.38                       76.99               48.04
#     meta_GA              97.24              4.29              96.52              5.88                  1451.1                       22.82            3015.1           1036.98                17.15              1054.13           878909.2                  3.36                       77.18               47.92
#    meta_GWO              97.43              4.33              96.76              5.79                   835.2                       13.13            3015.1           1008.51                16.01              1024.52           563568.4                  2.16                       86.87               40.20
#    meta_HHO              98.17              3.19              97.86              4.16                   281.5                        4.43            3015.1           1238.84                18.75              1257.58           249574.2                  0.96                       95.57               33.13
#   meta_JAYA              97.33              3.53              96.28              5.69                  1422.2                       22.37            3015.1           1063.86                17.00              1080.86           864112.4                  3.30                       77.63               47.64
#    meta_MFO              98.28              3.22              97.98              4.19                  1446.6                       22.75            3015.1            979.30                16.75               996.04           876605.2                  3.35                       77.25               47.86
#    meta_MVO              98.60              3.16              98.30              4.17                  1433.5                       22.54            3015.1           1020.65                16.95              1037.60           869898.0                  3.32                       77.46               47.85
#    meta_PSO              97.55              3.56              96.37              6.07                  1383.1                       21.75            3015.1           1022.50                16.85              1039.35           844093.2                  3.23                       78.25               47.29
#    meta_SCA              96.88              4.22              95.44              7.52                   255.5                        4.02            3015.1           1028.90                18.50              1047.40           230860.7                  0.89                       95.98               32.74
#    meta_SSA              97.18              4.26              96.38              5.96                  1450.1                       22.80            3015.1           2544.75                16.42              2561.16           878397.2                  3.36                       77.20               48.00
#    meta_WOA              96.43              3.73              96.13              4.60                    97.8                        1.54            3015.1            905.96                17.89               923.85            56435.7                  0.22                       98.46               29.33

# %% [markdown]
# ## Comprehensive Visualizations

# %%
# ============================================================================
# PLOT 1: Test Accuracy per fold for all methods (heatmap)
# ============================================================================
pivot = df_all.pivot_table(values='Test Accuracy (%)', index='Method', columns='Fold')
pivot = pivot.reindex(ALL_METHODS_L2)

fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax, linewidths=0.5, cbar_kws={'label': 'Test Accuracy (%)'})
ax.set_title('Two-Layer FS: Test Accuracy (%) per Method per Fold', fontsize=16)
ax.set_ylabel('Method')
ax.set_xlabel('Fold')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '01_accuracy_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 01_accuracy_heatmap.png")
# Out:
# Saved: 01_accuracy_heatmap.png

# %%
# ============================================================================
# PLOT 2: Box plot of test accuracy across folds
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
methods_sorted = df_summary.sort_values('Mean Test Acc (%)', ascending=False)['Method'].tolist()

sns.boxplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, palette='Set2')
sns.stripplot(data=df_all, x='Method', y='Test Accuracy (%)', order=methods_sorted, ax=ax, 
              color='black', alpha=0.5, size=4, jitter=True)
ax.set_title('Two-Layer FS: Test Accuracy Distribution Across Folds', fontsize=16)
ax.set_xlabel('')
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '02_accuracy_boxplot.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 02_accuracy_boxplot.png")
# Out:
# Saved: 02_accuracy_boxplot.png

# %%
# ============================================================================
# PLOT 3: Feature Retention per method
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 7))
feat_summary = df_all.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars = ax.bar(feat_summary.index, feat_summary['mean'], yerr=feat_summary['std'], capsize=3, alpha=0.7, color='coral')
ax.axhline(y=100, color='r', linestyle='--', label='All Features (100%)')
ax.set_ylabel('Feature Retention (%)', fontsize=12)
ax.set_title('Two-Layer FS: Feature Retention by Method', fontsize=16)
ax.legend()
plt.xticks(rotation=60, ha='right')
ax.grid(axis='y', alpha=0.3)

for bar, mean_val in zip(bars, feat_summary['mean']):
    if not np.isnan(mean_val):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 2,
                f'{mean_val:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig(PLOTS_DIR / '03_feature_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 03_feature_retention.png")
# Out:
# Saved: 03_feature_retention.png

# %%
# ============================================================================
# PLOT 4: Accuracy vs Feature Retention scatter
# ============================================================================
fig, ax = plt.subplots(figsize=(12, 8))

for method in ALL_METHODS_L2:
    mdf = df_all[df_all['Method'] == method]
    if len(mdf) == 0:
        continue
    ax.scatter(mdf['Feature Retention (%)'], mdf['Test Accuracy (%)'], 
               label=method, s=60, alpha=0.7)
    ax.scatter(mdf['Feature Retention (%)'].mean(), mdf['Test Accuracy (%)'].mean(),
               s=150, marker='X', edgecolors='black', linewidths=1.5)

ax.set_xlabel('Feature Retention (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Two-Layer FS: Accuracy vs Feature Retention', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / '04_accuracy_vs_retention.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 04_accuracy_vs_retention.png")
# Out:
# Saved: 04_accuracy_vs_retention.png

# %%
# ============================================================================
# PLOT 5: Per-modality retention heatmap
# ============================================================================
modality_data = {}
for method in ALL_METHODS_L2:
    modality_data[method] = {}
    for mod in FEATURE_DIMS.keys():
        col = f'{mod}_retention (%)'
        if col in df_all.columns:
            mdf = df_all[df_all['Method'] == method]
            modality_data[method][mod] = mdf[col].mean() if len(mdf) > 0 else 0

mod_df = pd.DataFrame(modality_data).T
mod_df = mod_df.reindex(ALL_METHODS_L2)

fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mod_df, annot=True, fmt='.1f', cmap='RdYlGn', ax=ax, linewidths=0.5,
            vmin=0, vmax=100, cbar_kws={'label': 'Retention (%)'})
ax.set_title('Two-Layer FS: Average Modality-wise Feature Retention (%)', fontsize=14)
ax.set_ylabel('Method')
ax.set_xlabel('Modality')
plt.tight_layout()
plt.savefig(PLOTS_DIR / '05_modality_retention_heatmap.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 05_modality_retention_heatmap.png")
# Out:
# Saved: 05_modality_retention_heatmap.png

# %%
# ============================================================================
# PLOT 6: Execution time comparison
# ============================================================================
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

time_summary = df_all.groupby('Method')['FS Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars = axes[0].bar(time_summary.index, time_summary['mean'], yerr=time_summary['std'], capsize=3, alpha=0.7, color='steelblue')
axes[0].set_ylabel('Feature Selection Time (s)', fontsize=12)
axes[0].set_title('Layer 2 Feature Selection Time', fontsize=14)
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[0].grid(axis='y', alpha=0.3)

total_summary = df_all.groupby('Method')['Total Time (s)'].agg(['mean', 'std']).reindex(ALL_METHODS_L2)
bars2 = axes[1].bar(total_summary.index, total_summary['mean'], yerr=total_summary['std'], capsize=3, alpha=0.7, color='darkorange')
axes[1].set_ylabel('Total Time (s)', fontsize=12)
axes[1].set_title('Total Time (FS + Training)', fontsize=14)
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=60, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '06_execution_time.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 06_execution_time.png")
# Out:
# Saved: 06_execution_time.png

# %%
# ============================================================================
# PLOT 7: Metaheuristics-only comparison
# ============================================================================
meta_method_names = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

if len(meta_method_names) > 0:
    meta_df = df_all[df_all['Method'].isin(meta_method_names)]
    
    fig, axes = plt.subplots(2, 1, figsize=(16, 12))
    
    meta_acc = meta_df.groupby('Method')['Test Accuracy (%)'].agg(['mean', 'std']).reindex(meta_method_names)
    bars = axes[0].bar(range(len(meta_method_names)), meta_acc['mean'], yerr=meta_acc['std'], 
                        capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_method_names))))
    axes[0].set_xticks(range(len(meta_method_names)))
    axes[0].set_xticklabels([m.replace('meta_', '') for m in meta_method_names], rotation=45, ha='right')
    axes[0].set_ylabel('Test Accuracy (%)')
    axes[0].set_title('Two-Layer FS Metaheuristics: Test Accuracy', fontsize=14)
    axes[0].grid(axis='y', alpha=0.3)
    
    for i, (bar, val) in enumerate(zip(bars, meta_acc['mean'])):
        if not np.isnan(val):
            axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height() + meta_acc['std'].iloc[i] + 0.5,
                        f'{val:.1f}', ha='center', va='bottom', fontsize=8)
    
    meta_feat = meta_df.groupby('Method')['Feature Retention (%)'].agg(['mean', 'std']).reindex(meta_method_names)
    bars2 = axes[1].bar(range(len(meta_method_names)), meta_feat['mean'], yerr=meta_feat['std'],
                         capsize=4, alpha=0.7, color=plt.cm.tab20(np.linspace(0, 1, len(meta_method_names))))
    axes[1].set_xticks(range(len(meta_method_names)))
    axes[1].set_xticklabels([m.replace('meta_', '') for m in meta_method_names], rotation=45, ha='right')
    axes[1].set_ylabel('Feature Retention (%)')
    axes[1].set_title('Two-Layer FS Metaheuristics: Feature Retention', fontsize=14)
    axes[1].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '07_metaheuristics_comparison.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 07_metaheuristics_comparison.png")
# Out:
# Saved: 07_metaheuristics_comparison.png

# %%
# ============================================================================
# PLOT 8: Convergence curves for metaheuristics
# ============================================================================
meta_method_names = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

if len(meta_method_names) > 0:
    fig, ax = plt.subplots(figsize=(14, 8))
    
    for method in meta_method_names:
        all_conv = []
        for fold_idx in range(N_FOLDS):
            if fold_idx in master_results[method]:
                conv = master_results[method][fold_idx].get('convergence', None)
                if conv is not None:
                    all_conv.append(conv)
        
        if all_conv:
            max_len = max(len(c) for c in all_conv)
            padded = []
            for c in all_conv:
                if len(c) < max_len:
                    c = list(c) + [c[-1]] * (max_len - len(c))
                padded.append(c)
            
            avg_conv = np.mean(padded, axis=0)
            ax.plot(avg_conv, label=method.replace('meta_', ''), linewidth=1.5)
    
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Fitness (1 - Accuracy)', fontsize=12)
    ax.set_title('Layer 2 Metaheuristic Convergence Curves (averaged)', fontsize=14)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / '08_convergence_curves.png', dpi=300, bbox_inches='tight')
    plt.close()
    print("Saved: 08_convergence_curves.png")
# Out:
# Saved: 08_convergence_curves.png

# %%
# ============================================================================
# PLOT 9: Standard vs Metaheuristics grouped comparison
# ============================================================================
standard_methods_plot = ['mutual_info', 'rfe', 'lasso']
meta_methods_plot = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]

fig, axes = plt.subplots(1, 3, figsize=(20, 7))

all_std = df_all[df_all['Method'].isin(standard_methods_plot)]['Test Accuracy (%)']
all_meta = df_all[df_all['Method'].isin(meta_methods_plot)]['Test Accuracy (%)']
bp = axes[0].boxplot([all_std, all_meta], labels=['Standard\n(MI, RFE, LASSO)', 'Metaheuristics\n(14 optimizers)'],
                      patch_artist=True)
bp['boxes'][0].set_facecolor('lightblue')
bp['boxes'][1].set_facecolor('lightsalmon')
axes[0].set_ylabel('Test Accuracy (%)')
axes[0].set_title('Standard vs Metaheuristic Accuracy', fontsize=13)
axes[0].grid(axis='y', alpha=0.3)

all_std_f = df_all[(df_all['Method'].isin(standard_methods_plot)) & (df_all['Method'] != 'baseline')]['Feature Retention (%)']
all_meta_f = df_all[df_all['Method'].isin(meta_methods_plot)]['Feature Retention (%)']
bp2 = axes[1].boxplot([all_std_f, all_meta_f], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp2['boxes'][0].set_facecolor('lightblue')
bp2['boxes'][1].set_facecolor('lightsalmon')
axes[1].set_ylabel('Feature Retention (%)')
axes[1].set_title('Standard vs Metaheuristic Feature Retention', fontsize=13)
axes[1].grid(axis='y', alpha=0.3)

all_std_t = df_all[(df_all['Method'].isin(standard_methods_plot)) & (df_all['Method'] != 'baseline')]['Total Time (s)']
all_meta_t = df_all[df_all['Method'].isin(meta_methods_plot)]['Total Time (s)']
bp3 = axes[2].boxplot([all_std_t, all_meta_t], labels=['Standard', 'Metaheuristics'],
                       patch_artist=True)
bp3['boxes'][0].set_facecolor('lightblue')
bp3['boxes'][1].set_facecolor('lightsalmon')
axes[2].set_ylabel('Total Time (s)')
axes[2].set_title('Standard vs Metaheuristic Time', fontsize=13)
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(PLOTS_DIR / '09_standard_vs_metaheuristics.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 09_standard_vs_metaheuristics.png")
# Out:
# Saved: 09_standard_vs_metaheuristics.png

# %%
# ============================================================================
# PLOT 10: Per-fold accuracy line plot
# ============================================================================
fig, ax = plt.subplots(figsize=(16, 8))

for method in ALL_METHODS_L2:
    mdf = df_all[df_all['Method'] == method].sort_values('Fold')
    if len(mdf) > 0:
        linewidth = 2.5 if method in ['mutual_info', 'rfe', 'lasso'] else 1.0
        alpha = 1.0 if method in ['mutual_info', 'rfe', 'lasso'] else 0.6
        ax.plot(mdf['Fold'], mdf['Test Accuracy (%)'], marker='o', markersize=4,
                label=method, linewidth=linewidth, alpha=alpha)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title('Two-Layer FS: Test Accuracy Across Folds', fontsize=16)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
ax.grid(alpha=0.3)
ax.set_xticks(range(1, N_FOLDS + 1))
plt.tight_layout()
plt.savefig(PLOTS_DIR / '10_per_fold_accuracy_lines.png', dpi=300, bbox_inches='tight')
plt.close()
print("Saved: 10_per_fold_accuracy_lines.png")
# Out:
# Saved: 10_per_fold_accuracy_lines.png

# %% [markdown]
# ## Best Metaheuristic Per Fold (Layer 2)

# %%
meta_methods_l2 = [m for m in ALL_METHODS_L2 if m.startswith('meta_')]
modality_names = list(FEATURE_DIMS.keys())

print("=" * 90)
print("BEST METAHEURISTIC PER FOLD - LAYER 2")
print("=" * 90)

best_per_fold = []

for fold_idx in range(N_FOLDS):
    best_method = None
    best_test_acc = -1.0
    best_result = None

    for method_name in meta_methods_l2:
        if fold_idx in master_results[method_name]:
            r = master_results[method_name][fold_idx]
            if r['test_acc'] > best_test_acc:
                best_test_acc = r['test_acc']
                best_method = method_name
                best_result = r

    if best_result is None:
        print(f"  Fold {fold_idx + 1}: No metaheuristic results found!")
        continue

    mod_ret = best_result['modality_retention']
    mod_retention_pct = {}
    for mod in modality_names:
        if mod in mod_ret and isinstance(mod_ret[mod], dict):
            mod_retention_pct[mod] = mod_ret[mod].get('percentage', 0.0)
        else:
            mod_retention_pct[mod] = float(mod_ret.get(mod, 0.0))

    fold_entry = {
        'Fold': fold_idx + 1,
        'Best Metaheuristic': best_method,
        'Test Accuracy (%)': best_result['test_acc'] * 100,
        'Test F1 Macro (%)': best_result['test_f1_macro'] * 100,
        'Feature Retention (%)': best_result['feature_retention_pct'],
        'Features Selected': best_result['num_features_selected'],
        'Features Total': best_result['num_features_total'],
    }
    for mod in modality_names:
        fold_entry[f'{mod} Retention (%)'] = mod_retention_pct[mod]

    best_per_fold.append(fold_entry)

    print(f"\n  Fold {fold_idx + 1}: Best = {best_method}")
    print(f"    Test Accuracy:      {fold_entry['Test Accuracy (%)']:.2f}%")
    print(f"    Test F1 Macro:      {fold_entry['Test F1 Macro (%)']:.2f}%")
    print(f"    Feature Retention:  {fold_entry['Feature Retention (%)']:.2f}% "
          f"({fold_entry['Features Selected']}/{fold_entry['Features Total']})")
    mod_str = ', '.join([f"{mod}={mod_retention_pct[mod]:.1f}%" for mod in modality_names])
    print(f"    Modality Retention: {mod_str}")

df_best_meta = pd.DataFrame(best_per_fold)

print("\n" + "=" * 90)
print("AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold - Layer 2)")
print("=" * 90)

if len(df_best_meta) > 0:
    avg_test_acc = df_best_meta['Test Accuracy (%)'].mean()
    std_test_acc = df_best_meta['Test Accuracy (%)'].std()
    avg_test_f1_macro = df_best_meta['Test F1 Macro (%)'].mean()
    std_test_f1_macro = df_best_meta['Test F1 Macro (%)'].std()
    avg_feat_ret = df_best_meta['Feature Retention (%)'].mean()
    std_feat_ret = df_best_meta['Feature Retention (%)'].std()

    print(f"\n  Average Test Accuracy:     {avg_test_acc:.2f}% ± {std_test_acc:.2f}%")
    print(f"  Average Test F1 Macro:     {avg_test_f1_macro:.2f}% ± {std_test_f1_macro:.2f}%")
    print(f"  Average Feature Retention: {avg_feat_ret:.2f}% ± {std_feat_ret:.2f}%")

    print(f"\n  Average Modality-wise Feature Retention:")
    for mod in modality_names:
        col = f'{mod} Retention (%)'
        if col in df_best_meta.columns:
            avg_mod = df_best_meta[col].mean()
            std_mod = df_best_meta[col].std()
            print(f"    {mod:>10s}: {avg_mod:.2f}% ± {std_mod:.2f}%")

    csv_path = RESULTS_ROOT / "best_metaheuristic_per_fold.csv"
    df_best_meta.to_csv(csv_path, index=False)
    print(f"\nSaved to: {csv_path}")
# Out:
# ==========================================================================================
# BEST METAHEURISTIC PER FOLD - LAYER 2
# ==========================================================================================
#
#   Fold 1: Best = meta_JAYA
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  21.39% (1360/6359)
#     Modality Retention: sensor=21.6%, skeleton=20.9%
#
#   Fold 2: Best = meta_BAT
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  22.85% (1453/6359)
#     Modality Retention: sensor=23.3%, skeleton=21.7%
#
#   Fold 3: Best = meta_BAT
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  23.10% (1469/6359)
#     Modality Retention: sensor=22.7%, skeleton=24.0%
#
#   Fold 4: Best = meta_BAT
#     Test Accuracy:      97.06%
#     Test F1 Macro:      97.46%
#     Feature Retention:  21.42% (1362/6359)
#     Modality Retention: sensor=22.8%, skeleton=18.1%
#
#   Fold 5: Best = meta_BAT
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  22.36% (1422/6359)
#     Modality Retention: sensor=21.8%, skeleton=23.8%
#
#   Fold 6: Best = meta_CS
#     Test Accuracy:      96.67%
#     Test F1 Macro:      96.57%
#     Feature Retention:  22.19% (1411/6359)
#     Modality Retention: sensor=21.9%, skeleton=23.0%
#
#   Fold 7: Best = meta_BAT
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  24.33% (1547/6359)
#     Modality Retention: sensor=24.0%, skeleton=25.1%
#
#   Fold 8: Best = meta_MVO
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  21.26% (1352/6359)
#     Modality Retention: sensor=21.0%, skeleton=21.9%
#
#   Fold 9: Best = meta_BAT
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  23.62% (1502/6359)
#     Modality Retention: sensor=23.2%, skeleton=24.6%
#
#   Fold 10: Best = meta_BAT
#     Test Accuracy:      100.00%
#     Test F1 Macro:      100.00%
#     Feature Retention:  24.14% (1535/6359)
#     Modality Retention: sensor=24.3%, skeleton=23.7%
#
# ==========================================================================================
# AVERAGE ACROSS ALL FOLDS (Best Metaheuristic per Fold - Layer 2)
# ==========================================================================================
#
#   Average Test Accuracy:     99.37% ± 1.33%
#   Average Test F1 Macro:     99.40% ± 1.28%
#   Average Feature Retention: 22.67% ± 1.13%
#
#   Average Modality-wise Feature Retention:
#         sensor: 22.65% ± 1.09%
#       skeleton: 22.69% ± 2.09%
#
# Saved to: results_two_layer/best_metaheuristic_per_fold.csv
